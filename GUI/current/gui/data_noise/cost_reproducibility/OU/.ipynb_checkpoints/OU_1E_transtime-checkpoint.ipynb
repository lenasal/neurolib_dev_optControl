# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import sys
import pickle
import matplotlib
import ipyparams

path = os.getcwd().split(os.sep + 'GUI')[0]
if path not in sys.path:
    print("not here")
    sys.path.append(path)

from neurolib.models.aln import ALNModel
from neurolib.utils import plotFunctions as plotFunc
from neurolib.utils import func_optimize as fo
from neurolib.utils import costFunctions as cost
import neurolib.dashboard.functions as functions
import neurolib.dashboard.data as data
import neurolib.dashboard.layout as layout
    
# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2 

#path = os.path.join(os.getcwd(), "plots")

cmap_ = layout.getcolormap()
darkgrey, midgrey, lightgrey, color_bi_updown, color_LC, color_bi_uposc = layout.getcolors_rgba()
exc_red = cmap_(3)
inh_blue=cmap_(0)
green = cmap_(2)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
aln = ALNModel()
N = aln.params.N

data.set_parameters(aln)

state_vars = aln.state_vars
init_vars = aln.init_vars

##############################################################
def setinit(init_vars_, model):
    state_vars = model.state_vars
    init_vars = model.init_vars
    for iv in range(len(init_vars)):
        for sv in range(len(state_vars)):
            if state_vars[sv] in init_vars[iv]:
                #print("set init vars ", )
                if model.params[init_vars[iv]].ndim == 2:
                    model.params[init_vars[iv]][0,:] = init_vars_[sv]
                else:
                    model.params[init_vars[iv]][0] = init_vars_[sv]
                    
##############################################################               
def setmaxmincontrol(max_c_c, min_c_c, max_c_r, min_c_r):
    import numpy as np
    
    max_cntrl = np.zeros(( 6 ))
    min_cntrl = np.zeros(( 6 ))
    
    max_cntrl[0] = max_c_c
    min_cntrl[0] = min_c_c
    max_cntrl[1] = max_c_c
    min_cntrl[1] = min_c_c
    max_cntrl[2] = max_c_r
    min_cntrl[2] = min_c_r
    max_cntrl[3] = max_c_r
    min_cntrl[3] = min_c_r
    max_cntrl[4] = max_c_r
    min_cntrl[4] = min_c_r
    max_cntrl[5] = max_c_r
    min_cntrl[5] = min_c_r
            
    return max_cntrl, min_cntrl

def rep_ind(c0, c1):
    abs_diff = np.abs(c0-c1)
    res = 0.
    for n in range(c0.shape[0]):
        for v in range(c0.shape[1]):
            res += sum(abs_diff[n,v,:]) * dt
            
    return res

# %%
points = np.array( [ [0.4, 0.322] ])

# 10 points, two costs, 4 methods, N

# %%
def create_dict(task, point, cost_params, init, init_vars, target, sigma_array, N_max_array, it_array):
    return dict( {'task':task, 'point':point, 'cost_params':cost_params, 'init':init, 'init_vars':init_vars,
            'target':target, 'sigma':sigma_array, 'N_array':N_max_array, 'it_array':it_array,
            'cost':np.zeros(( len(sigma_array), 4, 2, len(N_max_array), len(it_array) )),
            'rep_ind':np.zeros(( len(sigma_array), 4, 2, len(N_max_array), len(it_array) ))     } )

params_list = ['task', 'point', 'cost_params', 'init', 'init_vars', 'target', 'sigma', 'N_array',
               'cost', 'rep_ind']

# %%
dict_list = []
sigma_array = np.arange(0.01, 0.031, 0.01)
N_array = [2,10,30,50]
it_array = np.arange(0,25,6)

for p in points:
    dict_list.append(create_dict('DU', p, [None]*len(sigma_array), [0], None,
                [None]*len(sigma_array), sigma_array, N_array, it_array) )

# %%
for d in dict_list:
    print(d['target'])
# Out:
# [None, None, None]

# %%
dict_file = "OU_1E_transtime.pickle"

if False:
    file=open(dict_file, "wb")
    pickle.dump(dict_list, file)
    file.close()

if True:
    file = open(dict_file, "rb")
    dict_list = pickle.load(file)
    file.close()

# %%
dur_pre = 10
dur_post = 10
dur = 500.
dur_comp = 2000.
dt = aln.params.dt
T = int(1 + dur / dt)

prec_vars = [0,1]
trans_time = 0.7

n_pre = int(np.around(dur_pre/aln.params.dt,1))
n_post = int(np.around(dur_post/aln.params.dt,1))

tol = 1e-16
start_step = 10.
c_scheme = np.zeros(( 1,1 ))
c_scheme[0,0] = 1.
u_mat = np.identity(1)
u_scheme = np.array([[1.]])

maxC = [5., -5., 0.18, 0.]
n_dur = int(np.around(dur/aln.params.dt + 1.,1))
max_cntrl, min_cntrl = setmaxmincontrol(maxC[0], maxC[1], maxC[2], maxC[3])

noise_realizations_final = 10000
noise_realizations_target_compute = 1000
init_it = 3

# %%
# get init vars without noise
aln = ALNModel()
data.set_parameters(aln)
aln.params.duration = dur_comp

# initial without noise
control0 = aln.getZeroControl()

for d in dict_list:
    
    print("Point = ", d['point'])
    aln.params.ext_exc_current = d['point'][0] * 5.
    aln.params.ext_inh_current = d['point'][1] * 5.
    aln.params.duration = dur_comp
    
    if type(d['init_vars']) == type(None):
    
        control0[0,0,:500] = -5.

        aln.run(control=control0)

        init_state_vars = np.zeros(( len(state_vars) ))
        for j in range(len(state_vars)):
            if aln.state[state_vars[j]].size == 1:
                init_state_vars[j] = aln.state[state_vars[j]][0]
            else:
                init_state_vars[j] = aln.state[state_vars[j]][0,-1]

        initVars = init_state_vars.copy()
        d['init_vars'] = initVars
    
    for ind_s in range(len(d['sigma'])):
        
        if type(d['target'][ind_s]) != type(None):
            continue        
        
        s = d['sigma'][ind_s]
        aln.params.sigma_ou = s
        aln.params.duration = dur_comp
        control0[0,0,:500] = 5.
        
        stateswitchcount = 0
        target_rates_e = []
        target_rates_i = []

        for j in range(noise_realizations_target_compute):
            if j % 100 == 0:
                print(j)
            aln.run(control=control0)
            #plt.plot(aln.t, aln.rates_exc[0,:])
            if np.amin(aln.rates_exc[0,1000:]) < 1.:
                #print("fell in down state, repeat")
                j -= 1
                stateswitchcount += 1
                if stateswitchcount > 0.8 * noise_realizations_target_compute:
                    print("UNSTABLE: point, sigma ", d['point'], s)
                    break
                continue
            target_rates_e.append(aln.rates_exc[0,1000:])
            target_rates_i.append(aln.rates_inh[0,1000:])
        
        #plt.show()            

        aln.params.duration = dur
        target = aln.getZeroTarget()
        target[:,0,:] = np.mean(target_rates_e)
        target[:,1,:] = np.mean(target_rates_i)
        stddev = np.std(target_rates_e) + np.std(target_rates_i)
        
        d['target'][ind_s] = target
        d['cost_params'][ind_s] = [1. / ( stddev * (1. - trans_time) * dur ), 0., 1.]
        
        #print(stddev)
        
    file=open(dict_file, "wb")
    pickle.dump(dict_list, file)
    file.close()
    
    break
# Out:
# Point =  [0.4   0.322]

# %%
for d in dict_list:
     for s_ind in range(len(d['sigma'])):
            for i_it in range(1,len(d['it_array'])):
                for n_ind in range(len(d['N_array'])):
                    if np.isnan(d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it]):
                        print(s_ind, i_it, n_ind)
                        d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it] = 0.
                        d['rep_ind'][s_ind, method_ind, step_method_ind, n_ind, i_it] = 0.
                    if np.isnan(d['rep_ind'][s_ind, method_ind, step_method_ind, n_ind, i_it]):
                        print(s_ind, i_it, n_ind)
                        d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it] = 0.
                        d['rep_ind'][s_ind, method_ind, step_method_ind, n_ind, i_it] = 0.
# Out:
# 0 1 1
# 0 1 1
# 0 1 2
# 0 1 3
# 0 2 2
# 0 2 3
# 0 3 2
# 0 3 3
# 0 4 3
# 1 1 3
# 1 4 1
# 1 4 3
# 2 2 2
# 2 4 3

# %%
#len(sigma_array), 4, N_max, max_it

##### METHOD 1
method_ind = 0
step_method_ind = 0

for d in dict_list:
    print("Point = ", d['point'])
    aln.params.ext_exc_current = d['point'][0] * 5.
    aln.params.ext_inh_current = d['point'][1] * 5.
    
    max_it = d['cost'].shape[3]
    
    for s_ind in range(len(d['sigma'])):
        
        print("sigma = ", d['sigma'][s_ind])
        
        s = d['sigma'][s_ind]
        aln.params.sigma_ou = s
        c_p = d['cost_params'][s_ind]
        cost.setParams(c_p[0], c_p[1], c_p[2])
        aln.params.duration = dur
        zero_init = aln.getZeroControl()
        
        target_ = d['target'][s_ind].copy()
        target_[0,0,:int(trans_time * dur / aln.params.dt)] = -1000
        target_[0,1,:int(trans_time * dur / aln.params.dt)] = -1000
        
        if np.amin(d['cost'][s_ind, method_ind, step_method_ind, :, 0]) == 0.:
        
            setinit(d['init_vars'], aln)
            cost_final = 0.

            for n_ in range(noise_realizations_final):
                state_ = fo.updateState(aln, zero_init)
                cost_final += cost.numba_cost_precision_int(1, T, dt, d['cost_params'][s_ind][0],
                                                               state_, target_, list(prec_vars) )

            d['cost'][s_ind, :, :, :, 0] = cost_final/noise_realizations_final
            
        print('cost = ', d['cost'][s_ind, 0, 0, 0])    
        
        for i_it in range(1,len(d['it_array'])):
            
            it = d['it_array'][i_it]
            print("iteration = ", it)
        
            for n_ind in range(len(d['N_array'])):

                if ( d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it] > 0.
                    and d['rep_ind'][s_ind, method_ind, step_method_ind, n_ind, i_it] > 0. ) :
                    continue
                    
                n_max = d['N_array'][n_ind]
                print("n max = ", n_max)

                aln.params.duration = dur
                           
                    
                n_ = 0
                control_sum = aln.getZeroControl()
                
                while n_ < n_max:
                
                    print('--------', n_)

                    aln.params.duration = dur
                    control_init = aln.getZeroControl()         
                    setinit(d['init_vars'], aln)
                    
                    c_vars = d['init']

                    bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                        control_init, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_ = init_it,
                        tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                        t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                        control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                        noise_real=0, init_params = d['init_vars'])
                    
                    control_init = bc[:,:,n_pre:-n_post]
                    c_vars = [0,1]
                    aln.params.duration = dur
                    setinit(d['init_vars'], aln)
                    
                    bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                        control_init, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_ = it-init_it,
                        tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                        t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                        control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                        noise_real=0, init_params = d['init_vars'])
                    
                    control_sum += bc[:,:,n_pre:-n_post]
                    n_ += 1

                control_init = control_sum / n_max
        
                aln.params.duration = dur
                setinit(d['init_vars'], aln)

                cost_final = 0.

                for j in range(noise_realizations_final):
                    state_ = fo.updateState(aln, control_init)
                    cost_final += cost.numba_cost_precision_int(1, T, dt, d['cost_params'][s_ind][0],
                                                                   state_, target_, list(prec_vars) )
                    cost_final += cost.numba_cost_sparsity_int(1, 6, T, d['cost_params'][s_ind][2],
                                                                   dt, control_init)

                d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it] = cost_final/noise_realizations_final
                print('cost = ', d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it])
                
                ###############################################################
                
                aln.params.duration = dur
                setinit(d['init_vars'], aln)
                                   
                    
                n_ = 0
                control_sum = aln.getZeroControl()
                
                while n_ < n_max:
                
                    print('--------', n_)

                    aln.params.duration = dur
                    control_init1 = aln.getZeroControl() 
                    setinit(d['init_vars'], aln)
                    
                    c_vars = d['init']

                    bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                        control_init1, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_ = init_it,
                        tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                        t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                        control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                        noise_real=0, init_params = d['init_vars'])
                    
                    control_init1 = bc[:,:,n_pre:-n_post]
                    c_vars = [0,1]
                    aln.params.duration = dur
                    setinit(d['init_vars'], aln)
                    
                    bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                        control_init1, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_ = it-init_it,
                        tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                        t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                        control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                        noise_real=0, init_params = d['init_vars'])
                    
                    control_sum += bc[:,:,n_pre:-n_post]
                    n_ += 1

                control_init1 = control_sum / n_max
                
                d['rep_ind'][s_ind, method_ind, step_method_ind, n_ind, i_it] = rep_ind(control_init, control_init1)
                print('rep_ind = ', d['rep_ind'][s_ind, method_ind, step_method_ind, n_ind, i_it])
                
                file=open(dict_file, "wb")
                pickle.dump(dict_list, file)
                file.close()
                                
    break
# Out:
# Point =  [0.4   0.322]
# sigma =  0.01
# set cost params:  0.005531732932180352 0.0 1.0
# cost =  [1384.41588995 1335.67303034   22.06521342    5.05339446    6.8933818 ]
# iteration =  6
# n max =  10
# -------- 0
# interpolate adjoint :  True True True
# initial cost =  1310.6429494931758
# RUN  0 , total integrated cost =  1310.6429494931758
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14.53589788023861
# RUN  2 , total integrated cost =  68.39091164821292
# RUN  3 , total integrated cost =  23.103632064599907
# RUN  3 , total integrated cost =  23.103632064599907
# Improved over  3  iterations in  3.1706169929821044  seconds by  98.23722913448441  percent.
# interpolate adjoint :  True True True
# initial cost =  26.819364656443195
# RUN  0 , total integrated cost =  26.819364656443195
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.8636638440576085
# RUN  2 , total integrated cost =  7.449290515660386
# RUN  3 , total integrated cost =  7.199815307964329
# RUN  3 , total integrated cost =  7.199815307964329
# Improved over  3  iterations in  10.45975986495614  seconds by  73.15441510194532  percent.
# -------- 1
# interpolate adjoint :  True True True
# initial cost =  1359.0158148952485
# RUN  0 , total integrated cost =  1359.0158148952485
# Gradient descend method:  None
# RUN  1 , total integrated cost =  9.518565550340766
# RUN  2 , total integrated cost =  8.708198222421029
# RUN  3 , total integrated cost =  2.565166031761461
# RUN  3 , total integrated cost =  2.565166031761461
# Improved over  3  iterations in  3.1377362109487876  seconds by  99.81124825747821  percent.
# interpolate adjoint :  True True True
# initial cost =  2.7406172121641443
# RUN  0 , total integrated cost =  2.7406172121641443
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.1270549053982775
# RUN  2 , total integrated cost =  1.8923972085721315
# RUN  3 , total integrated cost =  1.6909446330695592
# RUN  3 , total integrated cost =  1.6909446330695592
# Improved over  3  iterations in  9.573717313935049  seconds by  38.30059062738298  percent.
# -------- 2
# interpolate adjoint :  True True True
# initial cost =  1379.599759868966
# RUN  0 , total integrated cost =  1379.599759868966
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.102036107567691
# RUN  2 , total integrated cost =  1.8885922543666334
# RUN  3 , total integrated cost =  2.306691925235879
# RUN  3 , total integrated cost =  2.306691925235879
# Improved over  3  iterations in  4.042122976970859  seconds by  99.83279991832885  percent.
# interpolate adjoint :  True True True
# initial cost =  3.0321920987497144
# RUN  0 , total integrated cost =  3.0321920987497144
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.898928646361756
# RUN  2 , total integrated cost =  1.7681745309383714
# RUN  3 , total integrated cost =  1.6319520982042632
# RUN  3 , total integrated cost =  1.6319520982042632
# Improved over  3  iterations in  12.744919313001446  seconds by  46.17913228923795  percent.
# -------- 3
# interpolate adjoint :  True True True
# initial cost =  1368.6085516348421
# RUN  0 , total integrated cost =  1368.6085516348421
# Gradient descend method:  None
# RUN  1 , total integrated cost =  9.397873080950257
# RUN  2 , total integrated cost =  3.237132945342065
# RUN  3 , total integrated cost =  2.0271750948170206
# RUN  3 , total integrated cost =  2.0271750948170206
# Improved over  3  iterations in  2.489187699975446  seconds by  99.85188057663417  percent.
# interpolate adjoint :  True True True
# initial cost =  2.350720228676638
# RUN  0 , total integrated cost =  2.350720228676638
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.9325604664218607
# RUN  2 , total integrated cost =  1.8466396444940627
# RUN  3 , total integrated cost =  1.902024528639076
# Control only changes marginally.
# RUN  3 , total integrated cost =  1.902024528639076
# Improved over  3  iterations in  18.3860607779352  seconds by  19.08758407588809  percent.
# -------- 4
# interpolate adjoint :  True True True
# initial cost =  1411.2475936951143
# RUN  0 , total integrated cost =  1411.2475936951143
# Gradient descend method:  None
# RUN  1 , total integrated cost =  35.39960163659547
# RUN  2 , total integrated cost =  14.286458591779029
# RUN  3 , total integrated cost =  4.385738390894711
# RUN  3 , total integrated cost =  4.385738390894711
# Improved over  3  iterations in  3.6060876849805936  seconds by  99.68922969927542  percent.
# interpolate adjoint :  True True True
# initial cost =  5.7590768299963395
# RUN  0 , total integrated cost =  5.7590768299963395
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.6335990427795202
# RUN  2 , total integrated cost =  1.2696660767912484
# RUN  3 , total integrated cost =  1.227114202168991
# RUN  3 , total integrated cost =  1.227114202168991
# Improved over  3  iterations in  9.046916177030653  seconds by  78.69251898537755  percent.
# -------- 5
# interpolate adjoint :  True True True
# initial cost =  1405.686854609801
# RUN  0 , total integrated cost =  1405.686854609801
# Gradient descend method:  None
# RUN  1 , total integrated cost =  18.171204575299775
# RUN  2 , total integrated cost =  4.700748730574509
# RUN  3 , total integrated cost =  2.2199917500339077
# RUN  3 , total integrated cost =  2.2199917500339077
# Improved over  3  iterations in  3.004898145911284  seconds by  99.84207067578717  percent.
# interpolate adjoint :  True True True
# initial cost =  1257.9175184362646
# RUN  0 , total integrated cost =  1257.9175184362646
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.0289845634446895
# RUN  2 , total integrated cost =  1.7099666270822393
# RUN  3 , total integrated cost =  1.8088385785258374
# RUN  3 , total integrated cost =  1.8088385785258374
# Improved over  3  iterations in  12.415994556969963  seconds by  99.85620372146701  percent.
# -------- 6
# interpolate adjoint :  True True True
# initial cost =  1386.412900929944
# RUN  0 , total integrated cost =  1386.412900929944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  9.278932440306548
# RUN  2 , total integrated cost =  31.396281101434873
# RUN  3 , total integrated cost =  14.469457522881587
# RUN  3 , total integrated cost =  14.469457522881587
# Improved over  3  iterations in  3.5017910479800776  seconds by  98.95633851119128  percent.
# interpolate adjoint :  True True True
# initial cost =  16.047268586262188
# RUN  0 , total integrated cost =  16.047268586262188
# Gradient descend method:  None
# RUN  1 , total integrated cost =  9.92721248843037
# RUN  2 , total integrated cost =  7.260886311929939
# RUN  3 , total integrated cost =  6.953641313325839
# RUN  3 , total integrated cost =  6.953641313325839
# Improved over  3  iterations in  11.25756324804388  seconds by  56.66775765641051  percent.
# -------- 7
# interpolate adjoint :  True True True
# initial cost =  1370.236338753788
# RUN  0 , total integrated cost =  1370.236338753788
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.650409544037663
# RUN  2 , total integrated cost =  2.124667143864249
# RUN  3 , total integrated cost =  2.241997237366814
# RUN  3 , total integrated cost =  2.241997237366814
# Improved over  3  iterations in  3.6111364760436118  seconds by  99.83637879291642  percent.
# interpolate adjoint :  True True True
# initial cost =  2.531047508563878
# RUN  0 , total integrated cost =  2.531047508563878
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.9507636665824046
# RUN  2 , total integrated cost =  1.9746050132846957
# RUN  3 , total integrated cost =  1.991080733645806
# RUN  3 , total integrated cost =  1.991080733645806
# Improved over  3  iterations in  11.256550873978995  seconds by  21.333727363515607  percent.
# -------- 8
# interpolate adjoint :  True True True
# initial cost =  1373.5797145056763
# RUN  0 , total integrated cost =  1373.5797145056763
# Gradient descend method:  None
# RUN  1 , total integrated cost =  185.27409119519334
# RUN  2 , total integrated cost =  97.52157396722151
# RUN  3 , total integrated cost =  10.59284069057001
# RUN  3 , total integrated cost =  10.59284069057001
# Improved over  3  iterations in  3.2487827150616795  seconds by  99.228815002238  percent.
# interpolate adjoint :  True True True
# initial cost =  14.9981340926592
# RUN  0 , total integrated cost =  14.9981340926592
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.5214245936746575
# RUN  2 , total integrated cost =  4.728564572104239
# RUN  3 , total integrated cost =  4.416173362954689
# RUN  3 , total integrated cost =  4.416173362954689
# Improved over  3  iterations in  9.546956136939116  seconds by  70.55518149343541  percent.
# -------- 9
# interpolate adjoint :  True True True
# initial cost =  1327.8967903066273
# RUN  0 , total integrated cost =  1327.8967903066273
# Gradient descend method:  None
# RUN  1 , total integrated cost =  9.82839601562479
# RUN  2 , total integrated cost =  155.80303899540908
# RUN  3 , total integrated cost =  116.16582233492932
# RUN  3 , total integrated cost =  116.16582233492932
# Improved over  3  iterations in  3.0820939110126346  seconds by  91.25189373278738  percent.
# interpolate adjoint :  True True True
# initial cost =  114.23663746501506
# RUN  0 , total integrated cost =  114.23663746501506
# Gradient descend method:  None
# step size too small or too large
# step size too small or too large
# RUN  1 , total integrated cost =  77.0999590747859
# RUN  2 , total integrated cost =  73.96359067071457
# RUN  3 , total integrated cost =  72.66306082114774
# RUN  3 , total integrated cost =  72.66306082114774
# Improved over  3  iterations in  19.411451508989558  seconds by  36.39250731325072  percent.
# cost =  8.167863685919222
# -------- 0
# interpolate adjoint :  True True True
# initial cost =  1393.5583704627595
# RUN  0 , total integrated cost =  1393.5583704627595
# Gradient descend method:  None
# RUN  1 , total integrated cost =  17.054439578449667
# RUN  2 , total integrated cost =  15.417989282903472
# RUN  3 , total integrated cost =  2.8649898333989166
# RUN  3 , total integrated cost =  2.8649898333989166
# Improved over  3  iterations in  6.404780425014906  seconds by  99.7944119246008  percent.
# interpolate adjoint :  True True True
# initial cost =  32.7695109650345
# RUN  0 , total integrated cost =  32.7695109650345
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.223885801889658
# RUN  2 , total integrated cost =  2.100930060257614
# RUN  3 , total integrated cost =  2.0018569026575106
# RUN  3 , total integrated cost =  2.0018569026575106
# Improved over  3  iterations in  14.142432429012842  seconds by  93.89109924529079  percent.
# -------- 1
# interpolate adjoint :  True True True
# initial cost =  1322.3308910744624
# RUN  0 , total integrated cost =  1322.3308910744624
# Gradient descend method:  None
# RUN  1 , total integrated cost =  28.388047758198688
# RUN  2 , total integrated cost =  7.465793222630772
# RUN  3 , total integrated cost =  9.143227895294253
# RUN  3 , total integrated cost =  9.143227895294253
# Improved over  3  iterations in  3.1007951740175486  seconds by  99.30855219695692  percent.
# interpolate adjoint :  True True True
# initial cost =  10.077936836595768
# RUN  0 , total integrated cost =  10.077936836595768
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.26967527625398
# RUN  2 , total integrated cost =  2.472353593388137
# RUN  3 , total integrated cost =  2.170777137500283
# RUN  3 , total integrated cost =  2.170777137500283
# Improved over  3  iterations in  10.911194002022967  seconds by  78.46010376233366  percent.
# -------- 2
# interpolate adjoint :  True True True
# initial cost =  1368.8248004197515
# RUN  0 , total integrated cost =  1368.8248004197515
# Gradient descend method:  None
# RUN  1 , total integrated cost =  128.56162866956768
# RUN  2 , total integrated cost =  65.67795158181787
# RUN  3 , total integrated cost =  67.42142348644174
# RUN  3 , total integrated cost =  67.42142348644174
# Improved over  3  iterations in  3.8468413549708202  seconds by  95.07450307257972  percent.
# interpolate adjoint :  True True True
# initial cost =  72.04688361980836
# RUN  0 , total integrated cost =  72.04688361980836
# Gradient descend method:  None
# RUN  1 , total integrated cost =  15.404337086995307
# RUN  2 , total integrated cost =  13.01646006748567
# RUN  3 , total integrated cost =  12.689039505206017
# RUN  3 , total integrated cost =  12.689039505206017
# Improved over  3  iterations in  11.990554542979226  seconds by  82.3878024035486  percent.
# -------- 3
# interpolate adjoint :  True True True
# initial cost =  1399.0648167450715
# RUN  0 , total integrated cost =  1399.0648167450715
# Gradient descend method:  None
# RUN  1 , total integrated cost =  18.38254876330125
# RUN  2 , total integrated cost =  64.58560867078556
# RUN  3 , total integrated cost =  66.94700314041224
# RUN  3 , total integrated cost =  66.94700314041224
# Improved over  3  iterations in  3.337084608967416  seconds by  95.214874797855  percent.
# interpolate adjoint :  True True True
# initial cost =  67.32904986242018
# RUN  0 , total integrated cost =  67.32904986242018
# Gradient descend method:  None
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  1 , total integrated cost =  67.32904986242018
# Control only changes marginally.
# RUN  1 , total integrated cost =  67.32904986242018
# Improved over  1  iterations in  18.8097355379723  seconds by  0.0  percent.
# -------- 4
# interpolate adjoint :  True True True
# initial cost =  1408.456566660864
# RUN  0 , total integrated cost =  1408.456566660864
# Gradient descend method:  None
# RUN  1 , total integrated cost =  10.360815403225901
# RUN  2 , total integrated cost =  2.4710618906762387
# RUN  3 , total integrated cost =  1.5510757123236134
# RUN  3 , total integrated cost =  1.5510757123236134
# Improved over  3  iterations in  3.771696474053897  seconds by  99.88987408280535  percent.
# interpolate adjoint :  True True True
# initial cost =  1.6110664930588408
# RUN  0 , total integrated cost =  1.6110664930588408
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.399923685448638
# RUN  2 , total integrated cost =  1.6127594448956257
# RUN  3 , total integrated cost =  1.5213712978504217
# RUN  3 , total integrated cost =  1.5213712978504217
# Improved over  3  iterations in  12.945040752063505  seconds by  5.56744216299353  percent.
# -------- 5
# interpolate adjoint :  True True True
# initial cost =  1387.4126537244672
# RUN  0 , total integrated cost =  1387.4126537244672
# Gradient descend method:  None
# RUN  1 , total integrated cost =  72.65064395916815
# RUN  2 , total integrated cost =  43.61783015833568
# RUN  3 , total integrated cost =  5.09833059016336
# RUN  3 , total integrated cost =  5.09833059016336
# Improved over  3  iterations in  3.562089779996313  seconds by  99.6325296171635  percent.
# interpolate adjoint :  True True True
# initial cost =  7.0530420803866765
# RUN  0 , total integrated cost =  7.0530420803866765
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.6687950099553412
# RUN  2 , total integrated cost =  3.326482574459412
# RUN  3 , total integrated cost =  3.0973532452068304
# RUN  3 , total integrated cost =  3.0973532452068304
# Improved over  3  iterations in  11.03804521204438  seconds by  56.084860831611245  percent.
# -------- 6
# interpolate adjoint :  True True True
# initial cost =  1357.8184955009515
# RUN  0 , total integrated cost =  1357.8184955009515
# Gradient descend method:  None
# RUN  1 , total integrated cost =  32.071168979682774
# RUN  2 , total integrated cost =  226.22091651173014
# RUN  3 , total integrated cost =  110.495685030581
# RUN  3 , total integrated cost =  110.495685030581
# Improved over  3  iterations in  2.8949666019761935  seconds by  91.8622639626208  percent.
# interpolate adjoint :  True True True
# initial cost =  111.25812143112506
# RUN  0 , total integrated cost =  111.25812143112506
# Gradient descend method:  None
# RUN  1 , total integrated cost =  38.073986888661565
# RUN  2 , total integrated cost =  27.423837452115283
# RUN  3 , total integrated cost =  24.85318889746477
# RUN  3 , total integrated cost =  24.85318889746477
# Improved over  3  iterations in  13.71342717797961  seconds by  77.661685656943  percent.
# -------- 7
# interpolate adjoint :  True True True
# initial cost =  1394.7865590865129
# RUN  0 , total integrated cost =  1394.7865590865129
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.416786498746992
# RUN  2 , total integrated cost =  10.133092911858371
# RUN  3 , total integrated cost =  10.940442499301392
# RUN  3 , total integrated cost =  10.940442499301392
# Improved over  3  iterations in  4.159949042019434  seconds by  99.21561887530186  percent.
# interpolate adjoint :  True True True
# initial cost =  10.13067518544098
# RUN  0 , total integrated cost =  10.13067518544098
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.2579094201069525
# RUN  2 , total integrated cost =  1.9809626532115612
# RUN  3 , total integrated cost =  1.800007304460895
# RUN  3 , total integrated cost =  1.800007304460895
# Improved over  3  iterations in  14.826253206003457  seconds by  82.23210919793652  percent.
# -------- 8
# interpolate adjoint :  True True True
# initial cost =  1380.7833954493672
# RUN  0 , total integrated cost =  1380.7833954493672
# Gradient descend method:  None
# RUN  1 , total integrated cost =  60.380214378985386
# RUN  2 , total integrated cost =  44.29362378380996
# RUN  3 , total integrated cost =  5.582766672475505
# RUN  3 , total integrated cost =  5.582766672475505
# Improved over  3  iterations in  3.5904530569678172  seconds by  99.59568121322471  percent.
# interpolate adjoint :  True True True
# initial cost =  7.020953052389416
# RUN  0 , total integrated cost =  7.020953052389416
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.6816413729416433
# RUN  2 , total integrated cost =  3.02821745535233
# RUN  3 , total integrated cost =  3.0085545071250426
# RUN  3 , total integrated cost =  3.0085545071250426
# Improved over  3  iterations in  10.20604318601545  seconds by  57.14891575722541  percent.
# -------- 9
# interpolate adjoint :  True True True
# initial cost =  1340.4951674374158
# RUN  0 , total integrated cost =  1340.4951674374158
# Gradient descend method:  None
# RUN  1 , total integrated cost =  154.43075391783995
# RUN  2 , total integrated cost =  79.82483298754914
# RUN  3 , total integrated cost =  23.47092165762715
# RUN  3 , total integrated cost =  23.47092165762715
# Improved over  3  iterations in  3.4339687660103664  seconds by  98.24908569402038  percent.
# interpolate adjoint :  True True True
# initial cost =  23.049739717290578
# RUN  0 , total integrated cost =  23.049739717290578
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.981695533616378
# RUN  2 , total integrated cost =  8.494677752870878
# RUN  3 , total integrated cost =  7.709258296346269
# RUN  3 , total integrated cost =  7.709258296346269
# Improved over  3  iterations in  12.005365237011574  seconds by  66.55381626473104  percent.
# rep_ind =  132.22675822623975
# n max =  30
# -------- 0
# interpolate adjoint :  True True True
# initial cost =  1403.3815236275889
# RUN  0 , total integrated cost =  1403.3815236275889
# Gradient descend method:  None
# RUN  1 , total integrated cost =  0.7315649732999179
# RUN  2 , total integrated cost =  0.6333190050640081
# RUN  3 , total integrated cost =  1.4283827145230272
# RUN  3 , total integrated cost =  1.4283827145230272
# Improved over  3  iterations in  3.99499305896461  seconds by  99.89821850363037  percent.
# interpolate adjoint :  True True True
# initial cost =  1.3072939369135144
# RUN  0 , total integrated cost =  1.3072939369135144
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.0893284494390714
# RUN  2 , total integrated cost =  0.9424163289708201
# RUN  3 , total integrated cost =  6.539001881627664
# RUN  3 , total integrated cost =  6.539001881627664
# Improved over  3  iterations in  22.909344654995948  seconds by  -400.1936976060694  percent.
# -------- 1
# interpolate adjoint :  True True True
# initial cost =  1361.8753179281166
# RUN  0 , total integrated cost =  1361.8753179281166
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12.117868709380804
# RUN  2 , total integrated cost =  6.583394543531922
# RUN  3 , total integrated cost =  3.3900454620288936
# RUN  3 , total integrated cost =  3.3900454620288936
# Improved over  3  iterations in  3.989222145988606  seconds by  99.75107519628256  percent.
# interpolate adjoint :  True True True
# initial cost =  3.9016653159050674
# RUN  0 , total integrated cost =  3.9016653159050674
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.1518913257992605
# RUN  2 , total integrated cost =  2.8946831905820343
# RUN  3 , total integrated cost =  2.9159387739022113
# RUN  3 , total integrated cost =  2.9159387739022113
# Improved over  3  iterations in  11.205905143986456  seconds by  25.264251600068306  percent.
# -------- 2
# interpolate adjoint :  True True True
# initial cost =  1366.9848078804398
# RUN  0 , total integrated cost =  1366.9848078804398
# Gradient descend method:  None
# RUN  1 , total integrated cost =  51.13714315915483
# RUN  2 , total integrated cost =  41.08839580192205
# RUN  3 , total integrated cost =  14.274767248782506
# RUN  3 , total integrated cost =  14.274767248782506
# Improved over  3  iterations in  3.097251206985675  seconds by  98.95574792298416  percent.
# interpolate adjoint :  True True True
# initial cost =  15.28020042456992
# RUN  0 , total integrated cost =  15.28020042456992
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12.24424249504907
# RUN  2 , total integrated cost =  11.411930016000868
# RUN  3 , total integrated cost =  11.342521779581494
# RUN  3 , total integrated cost =  11.342521779581494
# Improved over  3  iterations in  12.760656932950951  seconds by  25.76981018296594  percent.
# -------- 3
# interpolate adjoint :  True True True
# initial cost =  1414.2450710270468
# RUN  0 , total integrated cost =  1414.2450710270468
# Gradient descend method:  None
# RUN  1 , total integrated cost =  10.785030952598216
# RUN  2 , total integrated cost =  13.229890591394739
# RUN  3 , total integrated cost =  3.4350698756327294
# RUN  3 , total integrated cost =  3.4350698756327294
# Improved over  3  iterations in  4.348170637967996  seconds by  99.75710929130987  percent.
# interpolate adjoint :  True True True
# initial cost =  3.5795014219465897
# RUN  0 , total integrated cost =  3.5795014219465897
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.660077138538757
# RUN  2 , total integrated cost =  2.6059891154196535
# RUN  3 , total integrated cost =  2.559538984282833
# RUN  3 , total integrated cost =  2.559538984282833
# Improved over  3  iterations in  10.826756053022109  seconds by  28.494539250918507  percent.
# -------- 4
# interpolate adjoint :  True True True
# initial cost =  1416.689177931872
# RUN  0 , total integrated cost =  1416.689177931872
# Gradient descend method:  None
# RUN  1 , total integrated cost =  19.780989349872325
# RUN  2 , total integrated cost =  93.46267042949815
# RUN  3 , total integrated cost =  72.77299985108958
# RUN  3 , total integrated cost =  72.77299985108958
# Improved over  3  iterations in  3.351713959942572  seconds by  94.86316398934268  percent.
# interpolate adjoint :  True True True
# initial cost =  74.92810483323974
# RUN  0 , total integrated cost =  74.92810483323974
# Gradient descend method:  None
# step size too small or too large
# step size too small or too large
# RUN  1 , total integrated cost =  67.9669303808685
# RUN  2 , total integrated cost =  66.97429827691691
# RUN  3 , total integrated cost =  66.6509900466687
# RUN  3 , total integrated cost =  66.6509900466687
# Improved over  3  iterations in  20.425733832991682  seconds by  11.046742480665458  percent.
# -------- 5
# interpolate adjoint :  True True True
# initial cost =  1329.9453419392014
# RUN  0 , total integrated cost =  1329.9453419392014
# Gradient descend method:  None
# RUN  1 , total integrated cost =  144.46152123250806
# RUN  2 , total integrated cost =  16.071308536795687
# RUN  3 , total integrated cost =  207.72617976192447
# RUN  3 , total integrated cost =  207.72617976192447
# Improved over  3  iterations in  3.678932184004225  seconds by  84.38084835433631  percent.
# interpolate adjoint :  True True True
# initial cost =  213.6534426405546
# RUN  0 , total integrated cost =  213.6534426405546
# Gradient descend method:  None
# RUN  1 , total integrated cost =  148.81445668534386
# step size too small or too large
# step size too small or too large
# RUN  2 , total integrated cost =  88.72112127794747
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  3 , total integrated cost =  90.19512935147367
# RUN  3 , total integrated cost =  90.19512935147367
# Improved over  3  iterations in  40.79562027892098  seconds by  57.784378179566346  percent.
# -------- 6
# interpolate adjoint :  True True True
# initial cost =  1344.7438651247621
# RUN  0 , total integrated cost =  1344.7438651247621
# Gradient descend method:  None
# RUN  1 , total integrated cost =  43.49868702952891
# RUN  2 , total integrated cost =  16.540765336980037
# RUN  3 , total integrated cost =  8.914175521445792
# RUN  3 , total integrated cost =  8.914175521445792
# Improved over  3  iterations in  3.700887721963227  seconds by  99.33710978331038  percent.
# interpolate adjoint :  True True True
# initial cost =  9.331392505514996
# RUN  0 , total integrated cost =  9.331392505514996
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.1479845207787855
# RUN  2 , total integrated cost =  6.890470957252708
# RUN  3 , total integrated cost =  6.761881012530015
# RUN  3 , total integrated cost =  6.761881012530015
# Improved over  3  iterations in  8.324999812990427  seconds by  27.53620632147195  percent.
# -------- 7
# interpolate adjoint :  True True True
# initial cost =  1405.6363416457564
# RUN  0 , total integrated cost =  1405.6363416457564
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.126668796381571
# RUN  2 , total integrated cost =  49.97942396327813
# RUN  3 , total integrated cost =  35.39824801641259
# RUN  3 , total integrated cost =  35.39824801641259
# Improved over  3  iterations in  3.7412686849711463  seconds by  97.48169231488656  percent.
# interpolate adjoint :  True True True
# initial cost =  42.03655315746276
# RUN  0 , total integrated cost =  42.03655315746276
# Gradient descend method:  None
# RUN  1 , total integrated cost =  34.99059640749493
# RUN  2 , total integrated cost =  13.09198175006132
# RUN  3 , total integrated cost =  11.510905528701262
# RUN  3 , total integrated cost =  11.510905528701262
# Improved over  3  iterations in  13.667370312963612  seconds by  72.61691393777436  percent.
# -------- 8
# interpolate adjoint :  True True True
# initial cost =  1360.7012710531103
# RUN  0 , total integrated cost =  1360.7012710531103
# Gradient descend method:  None
# RUN  1 , total integrated cost =  13.086588540888352
# RUN  2 , total integrated cost =  10.189364957393742
# RUN  3 , total integrated cost =  266.52471814555855
# RUN  3 , total integrated cost =  266.52471814555855
# Improved over  3  iterations in  3.597504074918106  seconds by  80.4126942617403  percent.
# interpolate adjoint :  True True True
# initial cost =  270.7876294265219
# RUN  0 , total integrated cost =  270.7876294265219
# Gradient descend method:  None
# RUN  1 , total integrated cost =  9.49180294656476
# RUN  2 , total integrated cost =  2.1012972436019712
# RUN  3 , total integrated cost =  1.7434511825069339
# RUN  3 , total integrated cost =  1.7434511825069339
# Improved over  3  iterations in  10.460753917926922  seconds by  99.35615552815347  percent.
# -------- 9
# interpolate adjoint :  True True True
# initial cost =  1398.3849274226484
# RUN  0 , total integrated cost =  1398.3849274226484
# Gradient descend method:  None
# RUN  1 , total integrated cost =  10.715576661274339
# RUN  2 , total integrated cost =  2.4665878785004187
# RUN  3 , total integrated cost =  1.958404925535147
# RUN  3 , total integrated cost =  1.958404925535147
# Improved over  3  iterations in  4.2013192740269005  seconds by  99.85995237168748  percent.
# interpolate adjoint :  True True True
# initial cost =  1.8099239047277256
# RUN  0 , total integrated cost =  1.8099239047277256
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.7374938778979159
# RUN  2 , total integrated cost =  1.7453027173173135
# RUN  3 , total integrated cost =  1.6217500742153799
# RUN  3 , total integrated cost =  1.6217500742153799
# Improved over  3  iterations in  16.653474475024268  seconds by  10.396781324386865  percent.
# -------- 10
# interpolate adjoint :  True True True
# initial cost =  1419.1648876451106
# RUN  0 , total integrated cost =  1419.1648876451106
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.216613701360576
# RUN  2 , total integrated cost =  5.14705564851403
# RUN  3 , total integrated cost =  1.9612928359697315
# RUN  3 , total integrated cost =  1.9612928359697315
# Improved over  3  iterations in  5.138415972935036  seconds by  99.86179950948306  percent.
# interpolate adjoint :  True True True
# initial cost =  2.278985637617026
# RUN  0 , total integrated cost =  2.278985637617026
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.7243619585247743
# RUN  2 , total integrated cost =  1.5450128417011093
# RUN  3 , total integrated cost =  1.6997915609563679
# RUN  3 , total integrated cost =  1.6997915609563679
# Improved over  3  iterations in  18.250754358014092  seconds by  25.414555805023866  percent.
# -------- 11
# interpolate adjoint :  True True True
# initial cost =  1313.1335894156855
# RUN  0 , total integrated cost =  1313.1335894156855
# Gradient descend method:  None
# RUN  1 , total integrated cost =  131.06309172721038
# RUN  2 , total integrated cost =  30.908902895428536
# RUN  3 , total integrated cost =  19.828430331945867
# RUN  3 , total integrated cost =  19.828430331945867
# Improved over  3  iterations in  3.237307609990239  seconds by  98.4899913845956  percent.
# interpolate adjoint :  True True True
# initial cost =  20.76663359475652
# RUN  0 , total integrated cost =  20.76663359475652
# Gradient descend method:  None
# RUN  1 , total integrated cost =  8.679658994021498
# RUN  2 , total integrated cost =  7.7475348162209565
# RUN  3 , total integrated cost =  6.9408969610538644
# RUN  3 , total integrated cost =  6.9408969610538644
# Improved over  3  iterations in  17.119706251076423  seconds by  66.57668692721381  percent.
# -------- 12
# interpolate adjoint :  True True True
# initial cost =  1373.8231835615413
# RUN  0 , total integrated cost =  1373.8231835615413
# Gradient descend method:  None
# RUN  1 , total integrated cost =  10.568302537730654
# RUN  2 , total integrated cost =  11.742044608179196
# RUN  3 , total integrated cost =  9.719683817768763
# RUN  3 , total integrated cost =  9.719683817768763
# Improved over  3  iterations in  6.001320866984315  seconds by  99.29250838579014  percent.
# interpolate adjoint :  True True True
# initial cost =  10.572272152108349
# RUN  0 , total integrated cost =  10.572272152108349
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.2150950681373756
# RUN  2 , total integrated cost =  2.4355578348836513
# RUN  3 , total integrated cost =  1.920314982703809
# RUN  3 , total integrated cost =  1.920314982703809
# Improved over  3  iterations in  13.891173961921595  seconds by  81.83630770117041  percent.
# -------- 13
# interpolate adjoint :  True True True
# initial cost =  1383.232189866202
# RUN  0 , total integrated cost =  1383.232189866202
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.077845253008475
# RUN  2 , total integrated cost =  5.289266247428601
# RUN  3 , total integrated cost =  5.640860467675316
# RUN  3 , total integrated cost =  5.640860467675316
# Improved over  3  iterations in  3.745350445038639  seconds by  99.59219713732797  percent.
# interpolate adjoint :  True True True
# initial cost =  6.227222292870489
# RUN  0 , total integrated cost =  6.227222292870489
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.491988918221474
# RUN  2 , total integrated cost =  2.0703195738152393
# RUN  3 , total integrated cost =  1.8384421779110085
# RUN  3 , total integrated cost =  1.8384421779110085
# Improved over  3  iterations in  13.640369507018477  seconds by  70.47733176289805  percent.
# -------- 14
# interpolate adjoint :  True True True
# initial cost =  1403.3700792165787
# RUN  0 , total integrated cost =  1403.3700792165787
# Gradient descend method:  None
# RUN  1 , total integrated cost =  9.657161947443063
# RUN  2 , total integrated cost =  5.910638434060324
# RUN  3 , total integrated cost =  4.546681269058002
# RUN  3 , total integrated cost =  4.546681269058002
# Improved over  3  iterations in  4.547574208001606  seconds by  99.67601694404115  percent.
# interpolate adjoint :  True True True
# initial cost =  4.856905154279011
# RUN  0 , total integrated cost =  4.856905154279011
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.386086707187607
# RUN  2 , total integrated cost =  4.278950495153172
# RUN  3 , total integrated cost =  4.158319558240929
# RUN  3 , total integrated cost =  4.158319558240929
# Improved over  3  iterations in  12.880305371014401  seconds by  14.38334852848871  percent.
# -------- 15
# interpolate adjoint :  True True True
# initial cost =  1347.174305033062
# RUN  0 , total integrated cost =  1347.174305033062
# Gradient descend method:  None
# RUN  1 , total integrated cost =  75.3109954949839
# RUN  2 , total integrated cost =  13.234736260494344
# RUN  3 , total integrated cost =  8.161529103999298
# RUN  3 , total integrated cost =  8.161529103999298
# Improved over  3  iterations in  3.630050606909208  seconds by  99.39417423020112  percent.
# interpolate adjoint :  True True True
# initial cost =  9.255121447012069
# RUN  0 , total integrated cost =  9.255121447012069
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.821698541626768
# RUN  2 , total integrated cost =  4.972236768142584
# RUN  3 , total integrated cost =  4.641945897676734
# RUN  3 , total integrated cost =  4.641945897676734
# Improved over  3  iterations in  14.20525528700091  seconds by  49.84457066011443  percent.
# -------- 16
# interpolate adjoint :  True True True
# initial cost =  1338.4853017319936
# RUN  0 , total integrated cost =  1338.4853017319936
# Gradient descend method:  None
# RUN  1 , total integrated cost =  29.81292350494534
# RUN  2 , total integrated cost =  25.492693346518355
# RUN  3 , total integrated cost =  4.110712662733165
# RUN  3 , total integrated cost =  4.110712662733165
# Improved over  3  iterations in  4.924542669090442  seconds by  99.69288324216829  percent.
# interpolate adjoint :  True True True
# initial cost =  5.953783029405135
# RUN  0 , total integrated cost =  5.953783029405135
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.858859098021139
# RUN  2 , total integrated cost =  1.3305285822528807
# RUN  3 , total integrated cost =  1.2353126672669172
# RUN  3 , total integrated cost =  1.2353126672669172
# Improved over  3  iterations in  12.989758345996961  seconds by  79.2516344454302  percent.
# -------- 17
# interpolate adjoint :  True True True
# initial cost =  1376.372598950836
# RUN  0 , total integrated cost =  1376.372598950836
# Gradient descend method:  None
# RUN  1 , total integrated cost =  36.081078263720194
# RUN  2 , total integrated cost =  14.874295073614736
# RUN  3 , total integrated cost =  12.749470303893899
# RUN  3 , total integrated cost =  12.749470303893899
# Improved over  3  iterations in  3.1725568649126217  seconds by  99.07369048805444  percent.
# interpolate adjoint :  True True True
# initial cost =  13.720768213282033
# RUN  0 , total integrated cost =  13.720768213282033
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.7776731234495102
# RUN  2 , total integrated cost =  2.5446886356758247
# RUN  3 , total integrated cost =  2.4006901123930335
# RUN  3 , total integrated cost =  2.4006901123930335
# Improved over  3  iterations in  12.196455448982306  seconds by  82.50323833858582  percent.
# -------- 18
# interpolate adjoint :  True True True
# initial cost =  1358.7706483977552
# RUN  0 , total integrated cost =  1358.7706483977552
# Gradient descend method:  None
# RUN  1 , total integrated cost =  21.309914870586418
# RUN  2 , total integrated cost =  13.478601364537134
# RUN  3 , total integrated cost =  104.316362313799
# RUN  3 , total integrated cost =  104.316362313799
# Improved over  3  iterations in  3.3996464039664716  seconds by  92.32273949714711  percent.
# interpolate adjoint :  True True True
# initial cost =  101.01434780036763
# RUN  0 , total integrated cost =  101.01434780036763
# Gradient descend method:  None
# step size too small or too large
# step size too small or too large
# RUN  1 , total integrated cost =  75.88189863702314
# step size too small or too large
# step size too small or too large
# RUN  2 , total integrated cost =  71.22402574737508
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  3 , total integrated cost =  72.0669055797537
# RUN  3 , total integrated cost =  72.0669055797537
# Improved over  3  iterations in  51.068973382003605  seconds by  28.65676297571322  percent.
# -------- 19
# interpolate adjoint :  True True True
# initial cost =  1409.0603533602753
# RUN  0 , total integrated cost =  1409.0603533602753
# Gradient descend method:  None
# RUN  1 , total integrated cost =  10.833345716672916
# RUN  2 , total integrated cost =  2.864385102638215
# RUN  3 , total integrated cost =  1.8304011817462034
# RUN  3 , total integrated cost =  1.8304011817462034
# Improved over  3  iterations in  4.218918936094269  seconds by  99.87009774440241  percent.
# interpolate adjoint :  True True True
# initial cost =  1.656339924651
# RUN  0 , total integrated cost =  1.656339924651
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.6094855321136323
# RUN  2 , total integrated cost =  1.5532952798716622
# RUN  3 , total integrated cost =  1.521882027020935
# RUN  3 , total integrated cost =  1.521882027020935
# Improved over  3  iterations in  22.522701845970005  seconds by  8.117771939742141  percent.
# -------- 20
# interpolate adjoint :  True True True
# initial cost =  1419.0686839839739
# RUN  0 , total integrated cost =  1419.0686839839739
# Gradient descend method:  None
# RUN  1 , total integrated cost =  8.272779594426103
# RUN  2 , total integrated cost =  2.3115416958003663
# RUN  3 , total integrated cost =  59.90389840575732
# RUN  3 , total integrated cost =  59.90389840575732
# Improved over  3  iterations in  4.108738206094131  seconds by  95.77864700406327  percent.
# interpolate adjoint :  True True True
# initial cost =  67.57801607169841
# RUN  0 , total integrated cost =  67.57801607169841
# Gradient descend method:  None
# step size too small or too large
# step size too small or too large
# RUN  1 , total integrated cost =  53.57891770324055
# step size too small or too large
# step size too small or too large
# RUN  2 , total integrated cost =  46.335412994964585

# %%
#len(sigma_array), 4, N_max, max_it

##### METHOD 2
method_ind = 1
step_method_ind = 0

for d in dict_list:
    print("Point = ", d['point'])
    aln.params.ext_exc_current = d['point'][0] * 5.
    aln.params.ext_inh_current = d['point'][1] * 5.
    
    max_it = d['cost'].shape[3]
    
    for s_ind in range(len(d['sigma'])):
        
        print("sigma = ", d['sigma'][s_ind])
        
        s = d['sigma'][s_ind]
        aln.params.sigma_ou = s
        c_p = d['cost_params'][s_ind]
        cost.setParams(c_p[0], c_p[1], c_p[2])
        
        target_ = d['target'][s_ind].copy()
        target_[0,0,:int(trans_time * dur / aln.params.dt)] = -1000
        target_[0,1,:int(trans_time * dur / aln.params.dt)] = -1000
                
        for n_ind in range(len(d['N_array'])):
            
            n_ = d['N_array'][n_ind]
            
            print("n = ", n_)
            aln.params.duration = dur
        
            for i_it in range(1,len(d['it_array'])):
            
                it = d['it_array'][i_it]
                print("iteration = ", it)
                
                if ( d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it] > 0.
                    and d['rep_ind'][s_ind, method_ind, step_method_ind, n_ind, i_it] > 0. ) :
                    continue
                
                c_vars = d['init']
                aln.params.duration = dur
                setinit(d['init_vars'], aln)
                control_init = aln.getZeroControl()
                    
                
                bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                    control_init, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_ = init_it,
                    tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                    t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                    control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                    noise_real=n_, init_params = d['init_vars'], method='M2')
            
                control_init = bc[:,:,100:-100]
                c_vars = [0,1]
                aln.params.duration = dur
                setinit(d['init_vars'], aln)
                
                bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                    control_init, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_=it-init_it,
                    tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                    t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                    control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                    noise_real=n_, init_params = d['init_vars'], method='M2')

                control_init = bc[:,:,100:-100]
                aln.params.duration = dur
                setinit(d['init_vars'], aln)
                cost_final = 0.
                cs = cost.numba_cost_sparsity_int(1, 6, T, d['cost_params'][s_ind][2], dt, control_init)

                for j in range(noise_realizations_final):
                    state_ = fo.updateState(aln, control_init)
                    cost_final += cost.numba_cost_precision_int(1, T, dt, d['cost_params'][s_ind][0],
                                                                   state_, target_, list(prec_vars) )

                d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it] = (
                                cost_final / noise_realizations_final + cs )
                print('cost = ', d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it])
                
                c_vars = d['init']                    
                aln.params.duration = dur
                control_init1 = aln.getZeroControl()
                setinit(d['init_vars'], aln)
                
                bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                    control_init1, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_ = init_it,
                    tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                    t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                    control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                    noise_real=n_, init_params = d['init_vars'], method='M2')
            
                control_init1 = bc[:,:,100:-100]
                c_vars = [0,1]
                aln.params.duration = dur
                setinit(d['init_vars'], aln)
                
                bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                    control_init1, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_=it-init_it,
                    tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                    t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                    control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                    noise_real=n_, init_params = d['init_vars'], method='M2')

                control_init1 = bc[:,:,100:-100]
                d['rep_ind'][s_ind, method_ind, step_method_ind, n_ind, i_it] = rep_ind(control_init, control_init1)
                print('rep_ind = ', d['rep_ind'][s_ind, method_ind, step_method_ind, n_ind, i_it])
                
                file=open(dict_file, "wb")
                pickle.dump(dict_list, file)
                file.close()
                
    break
# Out:
# Point =  [0.4   0.322]
# sigma =  0.01
# set cost params:  0.005531732932180352 0.0 1.0
# n =  2
# iteration =  6
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1340.4809303538013
# Gradient descend method:  None
# RUN  1 , total integrated cost =  100.80449888229111
# RUN  2 , total integrated cost =  32.28018877344694
# RUN  3 , total integrated cost =  5.123194312907906
# RUN  3 , total integrated cost mean =  5.123194312907906
# Improved over  3  iterations in  13.452258391014766  seconds by  99.61780923570798  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5.197869166134003
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.8103733276008116
# RUN  2 , total integrated cost =  2.514830495613076
# RUN  3 , total integrated cost =  2.3822363795726997
# RUN  3 , total integrated cost mean =  2.3822363795726997
# Improved over  3  iterations in  1.2726237500319257  seconds by  54.16898149161139  percent.
# cost =  2.590832510911002
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1383.5953163274307
# Gradient descend method:  None
# RUN  1 , total integrated cost =  127.43388078155633
# RUN  2 , total integrated cost =  14.269595009528263
# RUN  3 , total integrated cost =  2.1423983121297203
# RUN  3 , total integrated cost mean =  2.1423983121297203
# Improved over  3  iterations in  0.8037687439937145  seconds by  99.84515715781573  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.3414605941803632
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.8082527632547225
# RUN  2 , total integrated cost =  1.6928690801583528
# RUN  3 , total integrated cost =  1.6427123603935168
# RUN  3 , total integrated cost mean =  1.6427123603935168
# Improved over  3  iterations in  1.615991685015615  seconds by  29.84240843188077  percent.
# rep_ind =  29.23191386009814
# iteration =  12
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1412.817643958349
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22.51983737390936
# RUN  2 , total integrated cost =  36.95453294381269
# RUN  3 , total integrated cost =  16.124342003790368
# RUN  3 , total integrated cost mean =  16.124342003790368
# Improved over  3  iterations in  0.8848015069961548  seconds by  98.85871031744662  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  15.873791828961888
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.247390253893652
# RUN  2 , total integrated cost =  3.9992338316209306
# RUN  3 , total integrated cost =  3.7996466706003957
# RUN  4 , total integrated cost =  3.6210186923496157
# RUN  5 , total integrated cost =  3.6681121961737304
# RUN  6 , total integrated cost =  3.4765767663357967
# RUN  7 , total integrated cost =  3.41127820144126
# RUN  8 , total integrated cost =  3.4379553333178645
# RUN  9 , total integrated cost =  3.347265574209233
# RUN  9 , total integrated cost mean =  3.347265574209233
# Improved over  9  iterations in  4.175535836955532  seconds by  78.91325771261461  percent.
# cost =  3.4479854827005463
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1314.5346998323691
# Gradient descend method:  None
# RUN  1 , total integrated cost =  33.59644848637778
# RUN  2 , total integrated cost =  31.495353126316992
# RUN  3 , total integrated cost =  18.21047063069871
# RUN  3 , total integrated cost mean =  18.21047063069871
# Improved over  3  iterations in  0.7668461689609103  seconds by  98.6146831549581  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  17.91328027092141
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14.132822540312857
# RUN  2 , total integrated cost =  12.475503909095535
# RUN  3 , total integrated cost =  11.797342751383326
# RUN  4 , total integrated cost =  11.629664779879471
# RUN  5 , total integrated cost =  11.59814925768561
# RUN  6 , total integrated cost =  11.47882890552919
# RUN  7 , total integrated cost =  11.37848359223812
# step size too small or too large
# RUN  8 , total integrated cost =  11.275638425664646
# RUN  9 , total integrated cost =  11.298111853081444
# RUN  9 , total integrated cost mean =  11.298111853081444
# Improved over  9  iterations in  4.525182451994624  seconds by  36.928850092176326  percent.
# rep_ind =  134.26269426418966
# iteration =  18
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1320.6061589908181
# Gradient descend method:  None
# RUN  1 , total integrated cost =  19.74142965184363
# RUN  2 , total integrated cost =  19.240277079285136
# RUN  3 , total integrated cost =  4.796273844573992
# RUN  3 , total integrated cost mean =  4.796273844573992
# Improved over  3  iterations in  0.8108490940066986  seconds by  99.6368127005981  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  4.822910897066238
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.621464369403477
# RUN  2 , total integrated cost =  2.164421299398393
# RUN  3 , total integrated cost =  1.981792994034108
# RUN  4 , total integrated cost =  1.901627762698214
# RUN  5 , total integrated cost =  1.8528658690386188
# RUN  6 , total integrated cost =  1.9016341687246388
# RUN  7 , total integrated cost =  1.9027955670295609
# RUN  8 , total integrated cost =  1.8587773283296858
# RUN  9 , total integrated cost =  1.8201844634159778
# RUN  10 , total integrated cost =  1.7355358552399505
# RUN  11 , total integrated cost =  1.7554739414010527
# RUN  12 , total integrated cost =  1.7458586290496605
# RUN  13 , total integrated cost =  1.7524600277233247
# RUN  14 , total integrated cost =  1.6903978724145596
# RUN  15 , total integrated cost =  1.657740657000031
# RUN  15 , total integrated cost mean =  1.657740657000031
# Improved over  15  iterations in  6.468701378966216  seconds by  65.62779839021223  percent.
# cost =  2.8103972170209275
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1400.3324170252463
# Gradient descend method:  None
# RUN  1 , total integrated cost =  23.145793128321174
# RUN  2 , total integrated cost =  59.51384121723735
# RUN  3 , total integrated cost =  118.91142315017039
# RUN  3 , total integrated cost mean =  118.91142315017039
# Improved over  3  iterations in  3.751128688978497  seconds by  91.50834318305819  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  114.87264384277205
# Gradient descend method:  None
# RUN  1 , total integrated cost =  46.80760003843611
# RUN  2 , total integrated cost =  17.31314286034452
# RUN  3 , total integrated cost =  12.86936142006235
# RUN  4 , total integrated cost =  12.00111779184994
# RUN  5 , total integrated cost =  11.354101845058103
# RUN  6 , total integrated cost =  11.00662496449798
# RUN  7 , total integrated cost =  10.642616685615458
# RUN  8 , total integrated cost =  10.59018650622609
# RUN  9 , total integrated cost =  10.4101501971319
# RUN  10 , total integrated cost =  10.305235696502859
# RUN  11 , total integrated cost =  10.199953152409414
# RUN  12 , total integrated cost =  10.01137417804147
# RUN  13 , total integrated cost =  10.031691257887923
# RUN  14 , total integrated cost =  9.94211338246633
# RUN  15 , total integrated cost =  9.78651217093959
# RUN  15 , total integrated cost mean =  9.78651217093959
# Improved over  15  iterations in  6.162553494039457  seconds by  91.48055460068062  percent.
# rep_ind =  112.78986735563656
# iteration =  24
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1368.2894314847554
# Gradient descend method:  None
# RUN  1 , total integrated cost =  87.64438424182366
# RUN  2 , total integrated cost =  11.11102344301921
# RUN  3 , total integrated cost =  2.412334459223276
# RUN  3 , total integrated cost mean =  2.412334459223276
# Improved over  3  iterations in  0.8088497780263424  seconds by  99.82369706264518  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.3452302047018208
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.7294943024578946
# RUN  2 , total integrated cost =  1.649167323177374
# RUN  3 , total integrated cost =  1.5935140002106989
# step size too small or too large
# step size too small or too large
# RUN  4 , total integrated cost =  1.6896419468683277
# RUN  5 , total integrated cost =  1.7029657103038645
# RUN  6 , total integrated cost =  1.6848579033881874
# no cost improvement
# RUN  7 , total integrated cost =  1.696464307669329
# RUN  8 , total integrated cost =  1.6168163971390532
# RUN  8 , total integrated cost mean =  1.6168163971390532
# Improved over  8  iterations in  4.704624342964962  seconds by  31.05937345094786  percent.
# cost =  496.8748118624722
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1404.519996315702
# Gradient descend method:  None
# RUN  1 , total integrated cost =  513.7949401015651
# RUN  2 , total integrated cost =  197.46234031585902
# RUN  3 , total integrated cost =  192.266874625036
# RUN  3 , total integrated cost mean =  192.266874625036
# Improved over  3  iterations in  1.8350047779968008  seconds by  86.31084818091696  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  181.41619405936692
# Gradient descend method:  None
# RUN  1 , total integrated cost =  60.22485145045202
# RUN  2 , total integrated cost =  11.615195644127486
# RUN  3 , total integrated cost =  8.077799640517611
# RUN  4 , total integrated cost =  7.148349647206942
# RUN  5 , total integrated cost =  6.88850960088098
# RUN  6 , total integrated cost =  6.8720390275803
# RUN  7 , total integrated cost =  6.94356181572663
# RUN  8 , total integrated cost =  6.815526662224716
# RUN  9 , total integrated cost =  6.889606610521206
# RUN  10 , total integrated cost =  6.840301083001737
# RUN  11 , total integrated cost =  6.77015812571981
# RUN  12 , total integrated cost =  6.664537543346459
# RUN  13 , total integrated cost =  6.780769062485813
# RUN  14 , total integrated cost =  6.724870994434054
# RUN  15 , total integrated cost =  6.780605255098372
# RUN  16 , total integrated cost =  6.6824114257192715
# RUN  17 , total integrated cost =  6.75778236378408
# RUN  18 , total integrated cost =  6.556362395484138
# RUN  19 , total integrated cost =  6.546227581249836
# RUN  20 , total integrated cost =  6.607821142250639
# RUN  21 , total integrated cost mean =  6.513222579824998
# Improved over  21  iterations in  9.732888297992758  seconds by  96.40978986821122  percent.
# rep_ind =  93.30280087210612
# n =  10
# iteration =  6
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1384.3141876721077
# Gradient descend method:  None
# RUN  1 , total integrated cost =  136.47469541221318
# RUN  2 , total integrated cost =  71.12069743399522
# RUN  3 , total integrated cost =  36.88795274320853
# RUN  3 , total integrated cost mean =  36.88795274320853
# Improved over  3  iterations in  5.813746288011316  seconds by  97.33529042238308  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  28.42804074354341
# Gradient descend method:  None
# RUN  1 , total integrated cost =  8.406145282659475
# RUN  2 , total integrated cost =  5.093720429642717
# step size too small or too large
# RUN  3 , total integrated cost =  3.876702292206126
# RUN  3 , total integrated cost mean =  3.876702292206126
# Improved over  3  iterations in  6.511394665983971  seconds by  86.36310420693835  percent.
# cost =  3.6228436001648454
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1373.8236746266543
# Gradient descend method:  None
# RUN  1 , total integrated cost =  107.88820449847495
# RUN  2 , total integrated cost =  124.89937190118262
# RUN  3 , total integrated cost =  54.540942796126195
# RUN  3 , total integrated cost mean =  54.540942796126195
# Improved over  3  iterations in  4.9164763780427165  seconds by  96.02998959739516  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  54.58276552222016
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14.38408985513875
# RUN  2 , total integrated cost =  8.508043610906428
# RUN  3 , total integrated cost =  6.684926000573336
# RUN  3 , total integrated cost mean =  6.684926000573336
# Improved over  3  iterations in  6.345616805017926  seconds by  87.75267992265441  percent.
# rep_ind =  37.23517157837991
# iteration =  12
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1375.0728967028112
# Gradient descend method:  None
# RUN  1 , total integrated cost =  197.5056970636652
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  2 , total integrated cost =  74.89311225337312
# RUN  3 , total integrated cost =  47.06839358392003
# RUN  3 , total integrated cost mean =  47.06839358392003
# Improved over  3  iterations in  9.034126610029489  seconds by  96.57702557465994  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  21.401183282434168
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.490983086781268
# RUN  2 , total integrated cost =  4.100928096254878
# RUN  3 , total integrated cost =  3.792709009589898
# step size too small or too large
# RUN  4 , total integrated cost =  3.5851176850276003
# step size too small or too large
# RUN  5 , total integrated cost =  3.5211883475121093
# RUN  6 , total integrated cost =  3.5244142665200746
# RUN  7 , total integrated cost =  3.4802469764516686
# step size too small or too large
# RUN  8 , total integrated cost =  3.449015968430681
# RUN  9 , total integrated cost =  3.443910658664257
# RUN  9 , total integrated cost mean =  3.443910658664257
# Improved over  9  iterations in  21.01913395599695  seconds by  83.90784933143871  percent.
# cost =  3.495192542998683
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1379.8835836156218
# Gradient descend method:  None
# RUN  1 , total integrated cost =  49.10081342521205
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  2 , total integrated cost =  32.991867569904606
# RUN  3 , total integrated cost =  29.5701265631893
# RUN  3 , total integrated cost mean =  29.5701265631893
# Improved over  3  iterations in  8.739949525042903  seconds by  97.85705642749161  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  25.200315233484
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.046966388307059
# RUN  2 , total integrated cost =  2.798654819979146
# RUN  3 , total integrated cost =  1.935357749842721
# RUN  4 , total integrated cost =  1.717099901519386
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  5 , total integrated cost =  1.6065287026013053
# RUN  6 , total integrated cost =  1.525722976067938
# RUN  7 , total integrated cost =  1.5262008614938762
# RUN  8 , total integrated cost =  1.4746495580872256
# RUN  9 , total integrated cost =  1.4279855086983142
# RUN  9 , total integrated cost mean =  1.4279855086983142
# Improved over  9  iterations in  22.727250107971486  seconds by  94.33346172272904  percent.
# rep_ind =  36.24242262393107
# iteration =  18
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1373.0964049253862
# Gradient descend method:  None
# RUN  1 , total integrated cost =  269.56357720482777
# RUN  2 , total integrated cost =  114.54394752312874
# RUN  3 , total integrated cost =  11.519929459982588
# RUN  3 , total integrated cost mean =  11.519929459982588
# Improved over  3  iterations in  6.598406000994146  seconds by  99.16102544448738  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  6.933724172029597
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.036666342631493
# step size too small or too large
# step size too small or too large
# RUN  2 , total integrated cost =  4.6735162246425705
# RUN  3 , total integrated cost =  4.511198785345189
# RUN  4 , total integrated cost =  4.432669729624678
# RUN  5 , total integrated cost =  4.364966954001961
# RUN  6 , total integrated cost =  4.317667829962023
# RUN  7 , total integrated cost =  4.2807919261920615
# RUN  8 , total integrated cost =  4.263054596303666
# RUN  9 , total integrated cost =  4.275716616186913
# RUN  10 , total integrated cost =  4.203566573894021
# RUN  11 , total integrated cost =  4.273603318945033
# step size too small or too large
# RUN  12 , total integrated cost =  4.210970652199743
# RUN  13 , total integrated cost =  4.215513535941756
# RUN  14 , total integrated cost =  4.179044768749391
# RUN  15 , total integrated cost =  4.174341025125364
# RUN  15 , total integrated cost mean =  4.174341025125364
# Improved over  15  iterations in  34.836385531001724  seconds by  39.796552017968764  percent.
# cost =  4.236374257429654
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1375.952673993363
# Gradient descend method:  None
# RUN  1 , total integrated cost =  283.4925023984924
# RUN  2 , total integrated cost =  61.62566974218858
# RUN  3 , total integrated cost =  27.285440898113762
# RUN  3 , total integrated cost mean =  27.285440898113762
# Improved over  3  iterations in  11.945611175964586  seconds by  98.01697824250564  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  26.682631077772168
# Gradient descend method:  None
# RUN  1 , total integrated cost =  8.957396780588464
# RUN  2 , total integrated cost =  6.934418208794132
# RUN  3 , total integrated cost =  5.917317531575608
# RUN  4 , total integrated cost =  5.536903020970928
# RUN  5 , total integrated cost =  5.221841499048574
# RUN  6 , total integrated cost =  5.114732181604296
# RUN  7 , total integrated cost =  4.987152735582564
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  8 , total integrated cost =  4.923016214981231
# step size too small or too large
# RUN  9 , total integrated cost =  4.841634247750453
# RUN  10 , total integrated cost =  4.81293511295677
# RUN  11 , total integrated cost =  4.806102837022069
# RUN  12 , total integrated cost =  4.798109047807928
# RUN  13 , total integrated cost =  4.70162126996813
# RUN  14 , total integrated cost =  4.736285096978566
# step size too small or too large
# RUN  15 , total integrated cost =  4.707109436541567
# RUN  15 , total integrated cost mean =  4.707109436541567
# Improved over  15  iterations in  33.1613968059537  seconds by  82.35890072901094  percent.
# rep_ind =  61.18853392137665
# iteration =  24
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1357.8420041480367
# Gradient descend method:  None
# RUN  1 , total integrated cost =  231.43883888658598
# RUN  2 , total integrated cost =  78.19747539069986
# RUN  3 , total integrated cost =  45.48420576963359
# RUN  3 , total integrated cost mean =  45.48420576963359
# Improved over  3  iterations in  4.513990064966492  seconds by  96.65025786279368  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  36.516678054933074
# Gradient descend method:  None
# RUN  1 , total integrated cost =  9.635925850007713
# RUN  2 , total integrated cost =  5.938200223100726
# RUN  3 , total integrated cost =  4.592799333774346
# RUN  4 , total integrated cost =  4.204608547051569
# RUN  5 , total integrated cost =  3.9319470103125957
# RUN  6 , total integrated cost =  3.87046282257511
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  7 , total integrated cost =  3.790305359324093
# RUN  8 , total integrated cost =  3.805521872564692
# RUN  9 , total integrated cost =  3.7210004286277423
# RUN  10 , total integrated cost =  3.7125566608420213
# RUN  11 , total integrated cost =  3.682243252290013
# RUN  12 , total integrated cost =  3.6431967366748887
# RUN  13 , total integrated cost =  3.5803185127283372
# RUN  14 , total integrated cost =  3.624889096353962
# RUN  15 , total integrated cost =  3.5646667983318516
# step size too small or too large
# RUN  16 , total integrated cost =  3.570179339179795
# RUN  17 , total integrated cost =  3.5414342742869622
# step size too small or too large
# RUN  18 , total integrated cost =  3.5492698557915703
# RUN  19 , total integrated cost =  3.4945752388308775
# RUN  20 , total integrated cost =  3.5089821412607405
# RUN  21 , total integrated cost mean =  3.5184923320525052
# Improved over  21  iterations in  46.7415585849667  seconds by  90.36469766839268  percent.
# cost =  3.545594787216031
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1374.0801160347776
# Gradient descend method:  None
# RUN  1 , total integrated cost =  158.34985337189215
# step size too small or too large
# step size too small or too large
# RUN  2 , total integrated cost =  68.13441143991727
# RUN  3 , total integrated cost =  98.93714285272367
# RUN  3 , total integrated cost mean =  98.93714285272367
# Improved over  3  iterations in  9.79583704995457  seconds by  92.79975441765147  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  97.08834164055766
# Gradient descend method:  None
# RUN  1 , total integrated cost =  30.945060874183298
# RUN  2 , total integrated cost =  9.170563816752505
# step size too small or too large
# RUN  3 , total integrated cost =  6.024028934160125
# RUN  4 , total integrated cost =  5.372074304790461
# RUN  5 , total integrated cost =  4.876807649930303
# RUN  6 , total integrated cost =  4.660369148471267
# step size too small or too large
# RUN  7 , total integrated cost =  4.516807418756253
# RUN  8 , total integrated cost =  4.400603720584867
# RUN  9 , total integrated cost =  4.3497460472681935
# RUN  10 , total integrated cost =  4.229513662666937
# RUN  11 , total integrated cost =  4.170603325894525
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  12 , total integrated cost =  4.140713718266836
# RUN  13 , total integrated cost =  4.097026931816832
# RUN  14 , total integrated cost =  4.048774630076007
# step size too small or too large
# RUN  15 , total integrated cost =  3.9807278857657318
# RUN  16 , total integrated cost =  3.994451979767007
# RUN  17 , total integrated cost =  3.978159046041777
# RUN  18 , total integrated cost =  3.8875686279156176
# RUN  19 , total integrated cost =  3.90584745309422
# RUN  20 , total integrated cost =  3.8333158411859545
# RUN  21 , total integrated cost mean =  3.8629807358111377
# Improved over  21  iterations in  47.878935276996344  seconds by  96.02116930772931  percent.
# rep_ind =  31.26270313186798
# n =  30
# iteration =  6
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1376.7912017624708
# Gradient descend method:  None
# RUN  1 , total integrated cost =  247.0639115844673
# RUN  2 , total integrated cost =  85.77609868160329
# RUN  3 , total integrated cost =  69.10170916568525
# RUN  3 , total integrated cost mean =  69.10170916568525
# Improved over  3  iterations in  32.53699265001342  seconds by  94.98095941656032  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  53.29382744972009
# Gradient descend method:  None
# RUN  1 , total integrated cost =  23.862503724842288
# RUN  2 , total integrated cost =  5.3267629473598594
# step size too small or too large
# RUN  3 , total integrated cost =  3.560541973902821
# RUN  3 , total integrated cost mean =  3.560541973902821
# Improved over  3  iterations in  19.84698755701538  seconds by  93.31903497217947  percent.
# cost =  3.5237756370285243
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1379.2423188063406
# Gradient descend method:  None
# RUN  1 , total integrated cost =  190.5281799791953
# RUN  2 , total integrated cost =  89.14918382071254
# RUN  3 , total integrated cost =  71.0996982351128
# RUN  3 , total integrated cost mean =  71.0996982351128
# Improved over  3  iterations in  41.74550596304471  seconds by  94.84501764007315  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  67.03398613767244
# Gradient descend method:  None
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  1 , total integrated cost =  24.30375347801067
# RUN  2 , total integrated cost =  7.85835547763828
# RUN  3 , total integrated cost =  6.0993418703925775
# RUN  3 , total integrated cost mean =  6.0993418703925775
# Improved over  3  iterations in  19.132090125989635  seconds by  90.90112013051719  percent.
# rep_ind =  83.87236957149375
# iteration =  12
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1385.523375079665
# Gradient descend method:  None
# RUN  1 , total integrated cost =  151.6838903977666
# RUN  2 , total integrated cost =  91.63671914795863
# RUN  3 , total integrated cost =  43.23428909736727
# RUN  3 , total integrated cost mean =  43.23428909736727
# Improved over  3  iterations in  27.361550998990424  seconds by  96.8795698524479  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  41.378012834961204
# Gradient descend method:  None
# RUN  1 , total integrated cost =  21.91898346883173
# RUN  2 , total integrated cost =  8.695540718609866
# RUN  3 , total integrated cost =  3.108326764842844
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  4 , total integrated cost =  2.5974922518300447
# RUN  5 , total integrated cost =  2.4460477688450006
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  6 , total integrated cost =  2.3899460467384896
# step size too small or too large
# step size too small or too large
# RUN  7 , total integrated cost =  2.3537359588321665
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  8 , total integrated cost =  2.3042555713737682
# RUN  9 , total integrated cost =  2.2653582433417374
# RUN  9 , total integrated cost mean =  2.2653582433417374
# Improved over  9  iterations in  67.42007502098568  seconds by  94.52521257514888  percent.
# cost =  2.5566812423053733
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1369.9763532692734
# Gradient descend method:  None
# RUN  1 , total integrated cost =  159.20051791828124
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  2 , total integrated cost =  80.77504838809355
# RUN  3 , total integrated cost =  4.167043361289692
# RUN  3 , total integrated cost mean =  4.167043361289692
# Improved over  3  iterations in  30.0427005069796  seconds by  99.69583100092599  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.1415873218700248
# Gradient descend method:  None
# step size too small or too large
# RUN  1 , total integrated cost =  1.9380818316801813
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  2 , total integrated cost =  1.7294212824061987
# step size too small or too large
# step size too small or too large
# RUN  3 , total integrated cost =  1.6452548179453328
# step size too small or too large
# RUN  4 , total integrated cost =  1.5764961872103924
# step size too small or too large
# RUN  5 , total integrated cost =  1.551607611986143
# step size too small or too large
# step size too small or too large
# RUN  6 , total integrated cost =  1.530289349004971
# RUN  7 , total integrated cost =  1.502844575026166
# RUN  8 , total integrated cost =  1.5040309324339871
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  9 , total integrated cost =  1.4834568719528527
# RUN  9 , total integrated cost mean =  1.4834568719528527
# Improved over  9  iterations in  65.52352692803834  seconds by  52.78002105413936  percent.
# rep_ind =  33.108622449168365
# iteration =  18
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1379.1676625211956
# Gradient descend method:  None
# RUN  1 , total integrated cost =  221.98833339079604
# RUN  2 , total integrated cost =  84.17496738832264
# RUN  3 , total integrated cost =  29.263653046325594
# RUN  3 , total integrated cost mean =  29.263653046325594
# Improved over  3  iterations in  18.72402223997051  seconds by  97.87816566168395  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  29.568974337552824
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.524322974453591
# step size too small or too large
# RUN  2 , total integrated cost =  4.456445546927013
# step size too small or too large
# RUN  3 , total integrated cost =  3.552974770389026
# RUN  4 , total integrated cost =  3.1433997956320976
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  5 , total integrated cost =  2.939987967664813
# step size too small or too large
# RUN  6 , total integrated cost =  2.8451673908346007
# RUN  7 , total integrated cost =  2.7223354530461332
# RUN  8 , total integrated cost =  2.708466469804696
# RUN  9 , total integrated cost =  2.6492949460258095
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  10 , total integrated cost =  2.6265663488640048
# step size too small or too large
# RUN  11 , total integrated cost =  2.5937227933796794
# step size too small or too large
# step size too small or too large
# RUN  12 , total integrated cost =  2.551898153049029
# RUN  13 , total integrated cost =  2.521240003852966
# step size too small or too large
# RUN  14 , total integrated cost =  2.512883453323342
# RUN  15 , total integrated cost =  2.4714675417792176
# RUN  15 , total integrated cost mean =  2.4714675417792176
# Improved over  15  iterations in  103.19405548699433  seconds by  91.64168660851914  percent.
# cost =  2.5283183893231174
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1373.2061330851727
# Gradient descend method:  None
# RUN  1 , total integrated cost =  116.30738119814247
# RUN  2 , total integrated cost =  94.99138210893196
# RUN  3 , total integrated cost =  36.70865684080267
# RUN  3 , total integrated cost mean =  36.70865684080267
# Improved over  3  iterations in  17.632228950038552  seconds by  97.32679195378121  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  39.247693461795734
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.524726050398401
# RUN  2 , total integrated cost =  7.838528219542676
# RUN  3 , total integrated cost =  6.477958119892693
# RUN  4 , total integrated cost =  6.052789128745606
# step size too small or too large
# RUN  5 , total integrated cost =  5.9015519516098225
# step size too small or too large
# step size too small or too large
# RUN  6 , total integrated cost =  5.7817443363715
# step size too small or too large
# RUN  7 , total integrated cost =  5.659389155829058
# step size too small or too large
# RUN  8 , total integrated cost =  5.567957659023273
# step size too small or too large
# RUN  9 , total integrated cost =  5.5102190315667325
# step size too small or too large
# RUN  10 , total integrated cost =  5.4704740480554355
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  11 , total integrated cost =  5.402225388577092
# RUN  12 , total integrated cost =  5.379938730792863
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  13 , total integrated cost =  5.358937125261503
# step size too small or too large
# RUN  14 , total integrated cost =  5.303926050903267
# RUN  15 , total integrated cost =  5.258055830992522
# RUN  15 , total integrated cost mean =  5.258055830992522
# Improved over  15  iterations in  103.2349520699936  seconds by  86.6028921263595  percent.
# rep_ind =  35.722122876952945
# iteration =  24
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1382.9975314203043
# Gradient descend method:  None
# RUN  1 , total integrated cost =  148.2000980973613
# RUN  2 , total integrated cost =  100.05510762689718
# RUN  3 , total integrated cost =  26.746841684567812
# RUN  3 , total integrated cost mean =  26.746841684567812
# Improved over  3  iterations in  30.084303842042573  seconds by  98.066023902653  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  24.45911068315822
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.795368882697912
# RUN  2 , total integrated cost =  2.863120938940398
# RUN  3 , total integrated cost =  2.457698766776288
# RUN  4 , total integrated cost =  2.3729488717607845
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  5 , total integrated cost =  2.3209842474938993
# step size too small or too large
# RUN  6 , total integrated cost =  2.2626055721189626
# step size too small or too large
# step size too small or too large
# RUN  7 , total integrated cost =  2.2625749521114025
# step size too small or too large
# RUN  8 , total integrated cost =  2.186141021471038
# RUN  9 , total integrated cost =  2.1534732345563588
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  10 , total integrated cost =  2.139117625029043
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  11 , total integrated cost =  2.118407176234956
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  12 , total integrated cost =  2.067950980928101
# step size too small or too large
# RUN  13 , total integrated cost =  2.0522475641690763
# step size too small or too large
# RUN  14 , total integrated cost =  2.0303598936667826
# step size too small or too large
# step size too small or too large
# RUN  15 , total integrated cost =  2.0486387887982658
# RUN  16 , total integrated cost =  1.977959322808277
# RUN  17 , total integrated cost =  2.0462259601145014
# RUN  18 , total integrated cost =  2.0160806957083235
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  19 , total integrated cost =  2.0203959801079425
# step size too small or too large
# step size too small or too large
# RUN  20 , total integrated cost =  1.9669044398147473
# step size too small or too large
# RUN  21 , total integrated cost mean =  1.9624282873192962
# Improved over  21  iterations in  161.09466635697754  seconds by  91.97669811981119  percent.
# cost =  3.010905604339304
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1379.6897570262565
# Gradient descend method:  None
# RUN  1 , total integrated cost =  136.9347299148982
# RUN  2 , total integrated cost =  111.05346493765617
# RUN  3 , total integrated cost =  35.10960300429624
# RUN  3 , total integrated cost mean =  35.10960300429624
# Improved over  3  iterations in  27.20070276397746  seconds by  97.45525377531465  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  28.621332851747812
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.120669004164142
# step size too small or too large
# RUN  2 , total integrated cost =  3.7718388025722542
# RUN  3 , total integrated cost =  2.906825292228681
# RUN  4 , total integrated cost =  2.7426575524715577
# RUN  5 , total integrated cost =  2.7470040910979576
# RUN  6 , total integrated cost =  2.7050350590745444
# RUN  7 , total integrated cost =  2.6642253387633934
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  8 , total integrated cost =  2.6252213837482903
# RUN  9 , total integrated cost =  2.573959134344808
# RUN  10 , total integrated cost =  2.5365995116548934
# RUN  11 , total integrated cost =  2.5433981633452567
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  12 , total integrated cost =  2.471004035673784
# step size too small or too large
# RUN  13 , total integrated cost =  2.507676320106662
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  14 , total integrated cost =  2.4969363488490894
# RUN  15 , total integrated cost =  2.4590925765593097
# RUN  16 , total integrated cost =  2.557136242894228
# step size too small or too large
# RUN  17 , total integrated cost =  2.5066397705761423
# step size too small or too large
# RUN  18 , total integrated cost =  2.4455188180628817
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  19 , total integrated cost =  2.477424104953717
# RUN  20 , total integrated cost =  2.395997397056367
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  21 , total integrated cost mean =  2.356850712822559
# Improved over  21  iterations in  157.3024568569963  seconds by  91.7654054581227  percent.
# rep_ind =  17.445927485291403
# n =  50
# iteration =  6
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1372.1629239511387
# Gradient descend method:  None
# RUN  1 , total integrated cost =  232.11761857410605
# RUN  2 , total integrated cost =  84.71105712651764
# RUN  3 , total integrated cost =  27.011384437518874
# RUN  3 , total integrated cost mean =  27.011384437518874
# Improved over  3  iterations in  39.87779970600968  seconds by  98.03147396230911  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  26.88644067352151
# Gradient descend method:  None
# step size too small or too large
# step size too small or too large
# RUN  1 , total integrated cost =  7.235558706059869
# step size too small or too large
# step size too small or too large
# RUN  2 , total integrated cost =  4.045273621914872
# step size too small or too large
# RUN  3 , total integrated cost =  3.4944627131649217
# RUN  3 , total integrated cost mean =  3.4944627131649217
# Improved over  3  iterations in  33.81405389396241  seconds by  87.00288091087356  percent.
# cost =  3.520052042466089
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1373.406442818848
# Gradient descend method:  None
# RUN  1 , total integrated cost =  174.5738386008912
# RUN  2 , total integrated cost =  66.01940073962756
# RUN  3 , total integrated cost =  27.495260327602374
# RUN  3 , total integrated cost mean =  27.495260327602374
# Improved over  3  iterations in  35.724455514980946  seconds by  97.99802451260024  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  23.38784198851978
# Gradient descend method:  None
# step size too small or too large
# RUN  1 , total integrated cost =  3.8110556598816148
# step size too small or too large
# RUN  2 , total integrated cost =  2.5329720240982594
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  3 , total integrated cost =  2.318701797672184
# RUN  3 , total integrated cost mean =  2.318701797672184
# Improved over  3  iterations in  35.14151978195878  seconds by  90.08586684136849  percent.
# rep_ind =  53.98332377849983
# iteration =  12
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1378.115065560824
# Gradient descend method:  None
# RUN  1 , total integrated cost =  269.1440026901402
# RUN  2 , total integrated cost =  115.97340060088423
# RUN  3 , total integrated cost =  26.253336426316825
# RUN  3 , total integrated cost mean =  26.253336426316825
# Improved over  3  iterations in  37.57601097796578  seconds by  98.0949822636448  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  23.59945186923123
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.510318983635517
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  2 , total integrated cost =  3.279473073377522
# step size too small or too large
# step size too small or too large
# RUN  3 , total integrated cost =  2.657943363459377
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  4 , total integrated cost =  2.5059596858230346
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  5 , total integrated cost =  2.405167432043201
# RUN  6 , total integrated cost =  2.4057342383047358
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  7 , total integrated cost =  2.3741176320568047
# RUN  8 , total integrated cost =  2.2639083105264715
# step size too small or too large
# step size too small or too large
# RUN  9 , total integrated cost =  2.25462181528037
# RUN  9 , total integrated cost mean =  2.25462181528037
# Improved over  9  iterations in  110.6738039010088  seconds by  90.44629583867612  percent.
# cost =  2.45985526884069
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1371.645112138088
# Gradient descend method:  None
# RUN  1 , total integrated cost =  154.15566085486324
# RUN  2 , total integrated cost =  65.12968027981897
# RUN  3 , total integrated cost =  24.423224688461897
# RUN  3 , total integrated cost mean =  24.423224688461897
# Improved over  3  iterations in  32.64283200504724  seconds by  98.21942100968147  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22.611045254322253
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.72361649031931
# RUN  2 , total integrated cost =  4.047854410988074
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  3 , total integrated cost =  3.658647587495054
# RUN  4 , total integrated cost =  3.5540760168192027
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  5 , total integrated cost =  3.5054527303664322
# step size too small or too large
# step size too small or too large
# RUN  6 , total integrated cost =  3.4407497249556633
# RUN  7 , total integrated cost =  3.4144091999163617
# step size too small or too large
# RUN  8 , total integrated cost =  3.38712089114263
# step size too small or too large
# RUN  9 , total integrated cost =  3.335150794145733
# RUN  9 , total integrated cost mean =  3.335150794145733
# Improved over  9  iterations in  108.48991749202833  seconds by  85.24990438684742  percent.
# rep_ind =  37.515646781214386
# iteration =  18
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1378.5944956462197
# Gradient descend method:  None
# RUN  1 , total integrated cost =  180.9688537878132
# RUN  2 , total integrated cost =  109.43268259961273
# RUN  3 , total integrated cost =  26.09485275177263
# RUN  3 , total integrated cost mean =  26.09485275177263
# Improved over  3  iterations in  54.796206468949094  seconds by  98.10714079925725  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  24.1899576419396
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.12466108190322
# RUN  2 , total integrated cost =  3.0560893145033314
# step size too small or too large
# RUN  3 , total integrated cost =  2.357939282980245
# step size too small or too large
# RUN  4 , total integrated cost =  2.1825273161740895
# step size too small or too large
# step size too small or too large
# RUN  5 , total integrated cost =  2.129900042703531
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  6 , total integrated cost =  2.1288558678226486
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  7 , total integrated cost =  2.0945002589486816
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  8 , total integrated cost =  2.085102633821732
# step size too small or too large
# RUN  9 , total integrated cost =  2.0609279255713226
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  10 , total integrated cost =  2.05611917208559
# step size too small or too large
# RUN  11 , total integrated cost =  2.02825334391529
# RUN  12 , total integrated cost =  1.9997301436935744
# step size too small or too large
# RUN  13 , total integrated cost =  1.9859329591259467
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  14 , total integrated cost =  1.9811808941756575
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  15 , total integrated cost =  1.9591758893807256
# RUN  15 , total integrated cost mean =  1.9591758893807256
# Improved over  15  iterations in  184.36284542898647  seconds by  91.9008709383435  percent.
# cost =  2.082281622882363
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1381.3753615235278
# Gradient descend method:  None
# RUN  1 , total integrated cost =  171.73225366365827
# RUN  2 , total integrated cost =  90.20837357384498
# RUN  3 , total integrated cost =  22.181366404255982
# RUN  3 , total integrated cost mean =  22.181366404255982
# Improved over  3  iterations in  34.247130755044054  seconds by  98.39425495617701  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22.283221998941123
# Gradient descend method:  None
# step size too small or too large
# RUN  1 , total integrated cost =  5.154597854677075
# RUN  2 , total integrated cost =  3.244166675084397
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  3 , total integrated cost =  3.025211249436623
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  4 , total integrated cost =  2.9544194677021256
# step size too small or too large
# step size too small or too large
# RUN  5 , total integrated cost =  2.879571321484177
# RUN  6 , total integrated cost =  2.87147739526869
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  7 , total integrated cost =  2.8502129035703785
# step size too small or too large
# step size too small or too large
# RUN  8 , total integrated cost =  2.824874441956257
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  9 , total integrated cost =  2.7944528591329463
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  10 , total integrated cost =  2.7917354205417904
# step size too small or too large
# RUN  11 , total integrated cost =  2.778695274071668
# step size too small or too large
# step size too small or too large
# RUN  12 , total integrated cost =  2.719388136425824
# step size too small or too large
# step size too small or too large
# ...
# Improved over  3  iterations in  24.12623492599232  seconds by  99.20346558064035  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  52.08330324593629
# Gradient descend method:  None
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  1 , total integrated cost =  1.9740054660149706
# step size too small or too large
# step size too small or too large
# RUN  2 , total integrated cost =  1.791606292354398
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  3 , total integrated cost =  1.8338421625000276
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  4 , total integrated cost =  1.770398977462708
# RUN  5 , total integrated cost =  1.7684430005675722
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  6 , total integrated cost =  1.6816296799368096
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  7 , total integrated cost =  1.8282809805760292
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  8 , total integrated cost =  1.792412208358565
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  9 , total integrated cost =  1.8867428188504787
# no cost improvement
# RUN  9 , total integrated cost mean =  1.8867428188504787
# Improved over  9  iterations in  183.7146196460235  seconds by  96.37745169514054  percent.
# rep_ind =  25.47650414994131
# iteration =  18
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  249.95714564525215
# Gradient descend method:  None
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  1 , total integrated cost =  60.52745330246024
# RUN  2 , total integrated cost =  21.949421514184074
# RUN  3 , total integrated cost =  23.131076755643868
# RUN  3 , total integrated cost mean =  23.131076755643868
# Improved over  3  iterations in  48.34525259799557  seconds by  90.74598299803267  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  144.86768052216658
# Gradient descend method:  None
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  1 , total integrated cost =  11.262749198630935
# RUN  2 , total integrated cost =  5.374726898887801
# step size too small or too large
# step size too small or too large
# RUN  3 , total integrated cost =  4.496517434727787
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  4 , total integrated cost =  3.355577077633679
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  5 , total integrated cost =  2.9531054460942077
# step size too small or too large
# step size too small or too large
# RUN  6 , total integrated cost =  2.7798015787688115
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  7 , total integrated cost =  2.7385489089327057
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  8 , total integrated cost =  2.6519206430142996
# step size too small or too large
# RUN  9 , total integrated cost =  2.6151663265477856
# RUN  10 , total integrated cost =  2.563559918396783
# RUN  11 , total integrated cost =  2.4956195205291922
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  12 , total integrated cost =  2.4075277865185183
# step size too small or too large
# RUN  13 , total integrated cost =  2.452267902986505
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  14 , total integrated cost =  2.3902737272401984
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  15 , total integrated cost =  2.415710845525268
# RUN  15 , total integrated cost mean =  2.415710845525268
# Improved over  15  iterations in  198.32789727899944  seconds by  98.33247081970389  percent.
# cost =  9.37097085940326
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  319.1616533367203
# Gradient descend method:  None
# step size too small or too large
# RUN  1 , total integrated cost =  91.97630360514069
# step size too small or too large
# step size too small or too large
# RUN  2 , total integrated cost =  48.24307229996262
# RUN  3 , total integrated cost =  14.389026540549937
# RUN  3 , total integrated cost mean =  14.389026540549937
# Improved over  3  iterations in  36.070626944012474  seconds by  95.49161799667415  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  180.07437531878466
# Gradient descend method:  None
# step size too small or too large
# step size too small or too large
# RUN  1 , total integrated cost =  9.702482008812108
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  2 , total integrated cost =  5.517807757080513
# step size too small or too large
# RUN  3 , total integrated cost =  3.7975046666764674
# RUN  4 , total integrated cost =  2.7905375469262337
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  5 , total integrated cost =  2.5401054723591074
# step size too small or too large
# step size too small or too large
# RUN  6 , total integrated cost =  2.5122199962649154
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  7 , total integrated cost =  2.4381461492658456
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  8 , total integrated cost =  2.46454615945983
# RUN  9 , total integrated cost =  2.3624961256250954
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  10 , total integrated cost =  2.310213040122224
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  11 , total integrated cost =  2.31295799982964
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  12 , total integrated cost =  2.2477403248533254
# RUN  13 , total integrated cost =  2.2826734580360557
# RUN  14 , total integrated cost =  2.2405851187272843
# RUN  15 , total integrated cost =  2.204547310101206
# RUN  15 , total integrated cost mean =  2.204547310101206
# Improved over  15  iterations in  195.61151161103044  seconds by  98.77575734681933  percent.
# rep_ind =  19.963117636327244
# iteration =  24
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  290.56971252178744
# Gradient descend method:  None
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  1 , total integrated cost =  59.89196502498044
# RUN  2 , total integrated cost =  29.06636884839335
# RUN  3 , total integrated cost =  15.011409467519139
# RUN  3 , total integrated cost mean =  15.011409467519139
# Improved over  3  iterations in  32.95504676899873  seconds by  94.83380103960644  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  176.47420585817338
# Gradient descend method:  None
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  1 , total integrated cost =  6.868759415796888
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  2 , total integrated cost =  5.224032696536949
# RUN  3 , total integrated cost =  3.8451435037106614
# RUN  4 , total integrated cost =  3.0862374388013256
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  5 , total integrated cost =  2.8479107487925286
# step size too small or too large
# step size too small or too large
# RUN  6 , total integrated cost =  2.8623491938049574
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  7 , total integrated cost =  2.6780639655906056
# step size too small or too large
# step size too small or too large
# RUN  8 , total integrated cost =  2.6414276676211146
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  9 , total integrated cost =  2.597647768029138
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  10 , total integrated cost =  2.507858699276129
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  11 , total integrated cost =  2.44664797617654
# RUN  12 , total integrated cost =  2.487604021684172
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  13 , total integrated cost =  2.542335060904351
# step size too small or too large
# step size too small or too large
# RUN  14 , total integrated cost =  2.457222142326963
# step size too small or too large
# RUN  15 , total integrated cost =  2.4183970860027726
# step size too small or too large
# RUN  16 , total integrated cost =  2.3986164755043786
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  17 , total integrated cost =  2.32417136946308
# RUN  18 , total integrated cost =  2.3425456909073437
# step size too small or too large
# step size too small or too large
# RUN  19 , total integrated cost =  2.2856182863766104
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  20 , total integrated cost =  2.304926376943458
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  21 , total integrated cost mean =  2.2555073493043873
# Improved over  21  iterations in  271.3102730619721  seconds by  98.72190536949232  percent.
# cost =  9.871440409896017
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  293.27643689801533
# Gradient descend method:  None
# RUN  1 , total integrated cost =  75.80064257677985
# step size too small or too large
# step size too small or too large
# RUN  2 , total integrated cost =  35.229996631802265
# step size too small or too large
# step size too small or too large
# RUN  3 , total integrated cost =  12.526108283836948
# RUN  3 , total integrated cost mean =  12.526108283836948
# Improved over  3  iterations in  32.12658427999122  seconds by  95.72890736933195  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  168.39197752320788
# Gradient descend method:  None
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  1 , total integrated cost =  5.471123666576585
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  2 , total integrated cost =  3.533044045774281
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  3 , total integrated cost =  3.596540303393066
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  4 , total integrated cost =  2.8912717719407284
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  5 , total integrated cost =  2.4815342567758587
# step size too small or too large
# step size too small or too large
# RUN  6 , total integrated cost =  2.4755418137532024
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  7 , total integrated cost =  2.409034627348347
# step size too small or too large
# step size too small or too large
# RUN  8 , total integrated cost =  2.3981686973600698
# RUN  9 , total integrated cost =  2.3456901602012525
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  10 , total integrated cost =  2.352709773666104
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  11 , total integrated cost =  2.3689561365806338
# step size too small or too large
# RUN  12 , total integrated cost =  2.318731205326543
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  13 , total integrated cost =  2.3706389727450103
# RUN  14 , total integrated cost =  2.1983584402917953
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  15 , total integrated cost =  2.255600474453651
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  16 , total integrated cost =  2.2773801665182747
# step size too small or too large
# step size too small or too large
# RUN  17 , total integrated cost =  2.2153873672542947
# step size too small or too large
# RUN  18 , total integrated cost =  2.217594328162717
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  19 , total integrated cost =  2.1763543645619627
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  20 , total integrated cost =  2.17735967127285
# step size too small or too large
# RUN  21 , total integrated cost mean =  2.1873900845783556
# Improved over  21  iterations in  284.6244613660383  seconds by  98.70101288864733  percent.
# rep_ind =  16.12055137979954

# %%
#len(sigma_array), 4, N_max, max_it

##### METHOD 3
method_ind = 2
step_method_ind = 0

for d in dict_list:
    print("Point = ", d['point'])
    aln.params.ext_exc_current = d['point'][0] * 5.
    aln.params.ext_inh_current = d['point'][1] * 5.
    
    max_it = d['cost'].shape[3]
    
    for s_ind in range(len(d['sigma'])):
        
        print("sigma = ", d['sigma'][s_ind])
        
        s = d['sigma'][s_ind]
        aln.params.sigma_ou = s
        c_p = d['cost_params'][s_ind]
        cost.setParams(c_p[0], c_p[1], c_p[2])
        
        target_ = d['target'][s_ind].copy()
        target_[0,0,:int(trans_time * dur / aln.params.dt)] = -1000
        target_[0,1,:int(trans_time * dur / aln.params.dt)] = -1000
                
        for n_ind in range(len(d['N_array'])):
            
            n_ = d['N_array'][n_ind]
            
            print("n = ", n_)
            aln.params.duration = dur
        
            for i_it in range(1,len(d['it_array'])):
                
                print('cost = ', d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it])
            
                it = d['it_array'][i_it]
                print("iteration = ", it)
                
                if ( d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it] > 0.
                    and d['rep_ind'][s_ind, method_ind, step_method_ind, n_ind, i_it] > 0. ) :
                    continue
                
                c_vars = d['init']
                aln.params.duration = dur
                setinit(d['init_vars'], aln)
                control_init = aln.getZeroControl()
                    
                
                bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                    control_init, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_ = init_it,
                    tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                    t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                    control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                    noise_real=n_, init_params = d['init_vars'], method='M3')
            
                control_init = bc[:,:,100:-100]
                c_vars = [0,1]
                aln.params.duration = dur
                setinit(d['init_vars'], aln)
                
                bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                    control_init, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_=it-init_it,
                    tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                    t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                    control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                    noise_real=n_, init_params = d['init_vars'], method='M3')

                control_init = bc[:,:,100:-100]
                aln.params.duration = dur
                setinit(d['init_vars'], aln)
                cost_final = 0.
                cs = cost.numba_cost_sparsity_int(1, 6, T, d['cost_params'][s_ind][2], dt, control_init)

                for j in range(noise_realizations_final):
                    state_ = fo.updateState(aln, control_init)
                    cost_final += cost.numba_cost_precision_int(1, T, dt, d['cost_params'][s_ind][0],
                                                                   state_, target_, list(prec_vars) )

                d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it] = (
                                cost_final / noise_realizations_final + cs )
                print('cost = ', d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it])
                
                c_vars = d['init']                    
                aln.params.duration = dur
                control_init1 = aln.getZeroControl()
                setinit(d['init_vars'], aln)
                
                bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                    control_init1, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_ = init_it,
                    tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                    t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                    control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                    noise_real=n_, init_params = d['init_vars'], method='M3')
            
                control_init1 = bc[:,:,100:-100]
                c_vars = [0,1]
                aln.params.duration = dur
                setinit(d['init_vars'], aln)
                
                bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                    control_init1, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_=it-init_it,
                    tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                    t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                    control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                    noise_real=n_, init_params = d['init_vars'], method='M3')

                control_init1 = bc[:,:,100:-100]
                d['rep_ind'][s_ind, method_ind, step_method_ind, n_ind, i_it] = rep_ind(control_init, control_init1)
                print('rep_ind = ', d['rep_ind'][s_ind, method_ind, step_method_ind, n_ind, i_it])
                
                file=open(dict_file, "wb")
                pickle.dump(dict_list, file)
                file.close()
                
    break
# Out:
# Point =  [0.4   0.322]
# sigma =  0.01
# set cost params:  0.005531732932180352 0.0 1.0
# n =  2
# cost =  0.0
# iteration =  6
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1383.2384249946786
# Gradient descend method:  None
# RUN  1 , total integrated cost =  53.585210605947864
# RUN  2 , total integrated cost =  41.40146124567089
# RUN  3 , total integrated cost =  4.713074876030599
# RUN  3 , total integrated cost mean =  4.713074876030599
# Improved over  3  iterations in  13.305757738999091  seconds by  99.65927241530694  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5.512367966913271
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.3031365750139257
# RUN  2 , total integrated cost =  2.0069702271607173
# RUN  3 , total integrated cost =  1.7985699631473095
# RUN  3 , total integrated cost mean =  1.7985699631473095
# Improved over  3  iterations in  1.353291462000925  seconds by  67.37209899733082  percent.
# cost =  2.0185040314600613
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1392.086377967987
# Gradient descend method:  None
# RUN  1 , total integrated cost =  15.433867641606573
# RUN  2 , total integrated cost =  9.208551856241728
# RUN  3 , total integrated cost =  2.7532786247306147
# RUN  3 , total integrated cost mean =  2.7532786247306147
# Improved over  3  iterations in  0.8441044079954736  seconds by  99.80221926826484  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.2903236361621566
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.7217405147906506
# RUN  2 , total integrated cost =  2.3186991573235716
# RUN  3 , total integrated cost =  2.1810028148011744
# RUN  3 , total integrated cost mean =  2.1810028148011744
# Improved over  3  iterations in  1.5773993619950488  seconds by  33.71464159844463  percent.
# rep_ind =  28.15844202310928
# cost =  0.0
# iteration =  12
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1348.0715789410535
# Gradient descend method:  None
# RUN  1 , total integrated cost =  118.0871270178724
# RUN  2 , total integrated cost =  3.173962794045951
# RUN  3 , total integrated cost =  2.819130133561062
# RUN  3 , total integrated cost mean =  2.819130133561062
# Improved over  3  iterations in  1.0224415329867043  seconds by  99.79087682155753  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.050495644938765
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.7725061018596948
# RUN  2 , total integrated cost =  1.737899012594868
# RUN  3 , total integrated cost =  1.5270945667620237
# RUN  4 , total integrated cost =  1.593450754138403
# RUN  5 , total integrated cost =  1.595034560031238
# RUN  6 , total integrated cost =  1.5995999585222773
# RUN  7 , total integrated cost =  1.6227391937437003
# RUN  8 , total integrated cost =  1.614175887497971
# RUN  9 , total integrated cost =  1.635494876656801
# RUN  9 , total integrated cost mean =  1.635494876656801
# Improved over  9  iterations in  5.396960477984976  seconds by  46.385929795692874  percent.
# cost =  396.5731365551234
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1353.1197400719761
# Gradient descend method:  None
# RUN  1 , total integrated cost =  41.620457125777264
# RUN  2 , total integrated cost =  42.73871938945972
# RUN  3 , total integrated cost =  8.290684896316183
# RUN  3 , total integrated cost mean =  8.290684896316183
# Improved over  3  iterations in  0.7894660820020363  seconds by  99.38729111321108  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7.974207284245699
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.905730176308354
# RUN  2 , total integrated cost =  5.673250191477966
# RUN  3 , total integrated cost =  5.556265117975114
# RUN  4 , total integrated cost =  5.524861558271981
# RUN  5 , total integrated cost =  5.50992419806486
# RUN  6 , total integrated cost =  5.467884155568506
# RUN  7 , total integrated cost =  5.4202368292124925
# RUN  8 , total integrated cost =  5.371468293031185
# RUN  9 , total integrated cost =  5.353776608548532
# RUN  9 , total integrated cost mean =  5.353776608548532
# Improved over  9  iterations in  3.9072704190039076  seconds by  32.86133131846522  percent.
# rep_ind =  62.02699796211646
# cost =  0.0
# iteration =  18
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1398.4860352215355
# Gradient descend method:  None
# RUN  1 , total integrated cost =  585.2152312937662
# RUN  2 , total integrated cost =  697.1935208527211
# RUN  3 , total integrated cost =  1063.4117929285921
# RUN  3 , total integrated cost mean =  1063.4117929285921
# Improved over  3  iterations in  0.8095512799918652  seconds by  23.959784642387504  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  738.7600071584089
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22.819921412544716
# RUN  2 , total integrated cost =  16.917499919108856
# RUN  3 , total integrated cost =  10.326087876965321
# RUN  4 , total integrated cost =  9.461716136116081
# step size too small or too large
# RUN  5 , total integrated cost =  9.300263537824021
# RUN  6 , total integrated cost =  9.312832585897603
# RUN  7 , total integrated cost =  9.086388627574813
# RUN  8 , total integrated cost =  9.24492665781111
# RUN  9 , total integrated cost =  9.147964282969907
# RUN  10 , total integrated cost =  9.08538858124617
# RUN  11 , total integrated cost =  9.087949866777366
# RUN  12 , total integrated cost =  8.995595615730473
# RUN  13 , total integrated cost =  9.156080579510805
# RUN  14 , total integrated cost =  9.068717337824497
# RUN  15 , total integrated cost =  9.102549344591132
# RUN  15 , total integrated cost mean =  9.102549344591132
# Improved over  15  iterations in  7.117153619998135  seconds by  98.76786111099821  percent.
# cost =  9.218544879869953
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1392.387585619049
# Gradient descend method:  None
# RUN  1 , total integrated cost =  32.14394522846293
# RUN  2 , total integrated cost =  31.423690173138652
# RUN  3 , total integrated cost =  4.31944546872645
# RUN  3 , total integrated cost mean =  4.31944546872645
# Improved over  3  iterations in  0.7782287889858708  seconds by  99.68978138606384  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  4.749135494646242
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.7797513427927054
# RUN  2 , total integrated cost =  2.4791003083175216
# RUN  3 , total integrated cost =  2.4392467406870995
# RUN  4 , total integrated cost =  2.367236969381543
# RUN  5 , total integrated cost =  2.2740067044442367
# RUN  6 , total integrated cost =  2.3469806692070696
# RUN  7 , total integrated cost =  2.26916019175894
# RUN  8 , total integrated cost =  2.2390746993667903
# RUN  9 , total integrated cost =  2.163803883027323
# RUN  10 , total integrated cost =  2.170591784355768
# RUN  11 , total integrated cost =  2.114929444312874
# RUN  12 , total integrated cost =  2.166276076197984
# RUN  13 , total integrated cost =  2.1571971726862555
# RUN  14 , total integrated cost =  2.1273360355531103
# RUN  15 , total integrated cost =  2.1212405079928804
# RUN  15 , total integrated cost mean =  2.1212405079928804
# Improved over  15  iterations in  6.761594107025303  seconds by  55.334175864550915  percent.
# rep_ind =  97.97054111762512
# cost =  0.0
# iteration =  24
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1384.8366370350445
# Gradient descend method:  None
# RUN  1 , total integrated cost =  21.832957643003805
# RUN  2 , total integrated cost =  5.290023460877604
# RUN  3 , total integrated cost =  2.8184079077577007
# RUN  3 , total integrated cost mean =  2.8184079077577007
# Improved over  3  iterations in  0.8426025059889071  seconds by  99.79648083879468  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.5639836047951476
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.4416365235460695
# RUN  2 , total integrated cost =  2.359162894830798
# RUN  3 , total integrated cost =  2.3588895118106272
# RUN  4 , total integrated cost =  2.2194393519084987
# RUN  5 , total integrated cost =  2.193527905320858
# RUN  6 , total integrated cost =  2.198807773270843
# RUN  7 , total integrated cost =  2.108349674622162
# RUN  8 , total integrated cost =  2.1598183487640794
# RUN  9 , total integrated cost =  2.1007162104320836
# RUN  10 , total integrated cost =  2.0831505304638505
# RUN  11 , total integrated cost =  2.095523485122475
# RUN  12 , total integrated cost =  2.036127664833526
# RUN  13 , total integrated cost =  1.900922176493902
# RUN  14 , total integrated cost =  1.9536186612745987
# RUN  15 , total integrated cost =  2.0060507614238627
# RUN  16 , total integrated cost =  2.0045317520277877
# RUN  17 , total integrated cost =  1.861101739836252
# step size too small or too large
# RUN  18 , total integrated cost =  1.8445995937384998
# RUN  19 , total integrated cost =  1.702325584259131
# RUN  20 , total integrated cost =  1.824753469428876
# RUN  21 , total integrated cost mean =  1.838199139635929
# Improved over  21  iterations in  10.245119646016974  seconds by  28.30690741554902  percent.
# cost =  18.567616520816284
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1381.1299137164028
# Gradient descend method:  None
# RUN  1 , total integrated cost =  585.8650594410742
# RUN  2 , total integrated cost =  16.913044886617854
# RUN  3 , total integrated cost =  16.995052685216002
# RUN  3 , total integrated cost mean =  16.995052685216002
# Improved over  3  iterations in  0.8495127969654277  seconds by  98.76948196426468  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  15.227601104268874
# Gradient descend method:  None
# step size too small or too large
# RUN  1 , total integrated cost =  14.85374862015804
# RUN  2 , total integrated cost =  14.324725296727113
# RUN  3 , total integrated cost =  15.45917411425213
# RUN  4 , total integrated cost =  15.975712094575416
# RUN  5 , total integrated cost =  13.171370053338192
# RUN  6 , total integrated cost =  12.224272889872756
# RUN  7 , total integrated cost =  12.066222804716304
# RUN  8 , total integrated cost =  11.754163507577449
# RUN  9 , total integrated cost =  11.818536597078852
# RUN  10 , total integrated cost =  11.77206991234171
# RUN  11 , total integrated cost =  11.652190322109622
# RUN  12 , total integrated cost =  11.668516108288447
# RUN  13 , total integrated cost =  11.59580044239368
# RUN  14 , total integrated cost =  11.538128368672194
# RUN  15 , total integrated cost =  11.495179295763503
# RUN  16 , total integrated cost =  11.574495015842011
# RUN  17 , total integrated cost =  11.400381672512502
# RUN  18 , total integrated cost =  11.520099408552277
# RUN  19 , total integrated cost =  11.379646319443097
# RUN  20 , total integrated cost =  11.461902693537741
# RUN  21 , total integrated cost mean =  11.340564945028724
# Improved over  21  iterations in  10.036945640982594  seconds by  25.526254152733657  percent.
# rep_ind =  113.24768765219487
# n =  10
# cost =  0.0
# iteration =  6
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1389.184990224308
# Gradient descend method:  None
# RUN  1 , total integrated cost =  88.3186496016011
# RUN  2 , total integrated cost =  143.72156567724085
# RUN  3 , total integrated cost =  67.55200714285215
# RUN  3 , total integrated cost mean =  67.55200714285215
# Improved over  3  iterations in  4.218037604005076  seconds by  95.13729218079554  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  67.27602410073372
# Gradient descend method:  None
# RUN  1 , total integrated cost =  23.847550904045967
# RUN  2 , total integrated cost =  16.616225754708474
# RUN  3 , total integrated cost =  14.368926733932804
# RUN  3 , total integrated cost mean =  14.368926733932804
# Improved over  3  iterations in  6.322263198031578  seconds by  78.64183128239279  percent.
# cost =  14.493109837289637
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1372.1852041644386
# Gradient descend method:  None
# RUN  1 , total integrated cost =  60.63183187778874
# step size too small or too large
# RUN  2 , total integrated cost =  27.55070897531118
# RUN  3 , total integrated cost =  4.017892985205515
# RUN  3 , total integrated cost mean =  4.017892985205515
# Improved over  3  iterations in  4.124314244952984  seconds by  99.70719018300069  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  136.82108471719926
# Gradient descend method:  None
# step size too small or too large
# RUN  1 , total integrated cost =  75.98417681976058
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  2 , total integrated cost =  75.13371092178758
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  3 , total integrated cost =  74.67767837103553
# RUN  3 , total integrated cost mean =  74.67767837103553
# Improved over  3  iterations in  14.920409918995574  seconds by  45.419466213566665  percent.
# rep_ind =  1268.9518785528494
# cost =  0.0
# iteration =  12
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1382.761294081685
# Gradient descend method:  None
# RUN  1 , total integrated cost =  159.6780804788366
# RUN  2 , total integrated cost =  63.54201567019861
# RUN  3 , total integrated cost =  14.428093352793463
# RUN  3 , total integrated cost mean =  14.428093352793463
# Improved over  3  iterations in  3.8576927299727686  seconds by  98.95657381975134  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  13.967975725502237
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.5247300939201605
# RUN  2 , total integrated cost =  4.195734176746328
# step size too small or too large
# RUN  3 , total integrated cost =  3.2928407968858395
# RUN  4 , total integrated cost =  3.1645961103030285
# RUN  5 , total integrated cost =  3.045223659138782
# RUN  6 , total integrated cost =  2.994863494702252
# step size too small or too large
# RUN  7 , total integrated cost =  2.9591640685203973
# RUN  8 , total integrated cost =  2.953492270935332
# step size too small or too large
# step size too small or too large
# RUN  9 , total integrated cost =  2.883914905698743
# RUN  9 , total integrated cost mean =  2.883914905698743
# Improved over  9  iterations in  20.326666006003506  seconds by  79.35337974253926  percent.
# cost =  2.869896182194321
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1372.2375489519695
# Gradient descend method:  None
# RUN  1 , total integrated cost =  88.76467728089347
# RUN  2 , total integrated cost =  33.18450058562933
# RUN  3 , total integrated cost =  5.095583082410849
# RUN  3 , total integrated cost mean =  5.095583082410849
# Improved over  3  iterations in  4.076380177983083  seconds by  99.62866610913667  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  4.977059640682402
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.2998811036229325
# RUN  2 , total integrated cost =  3.0304465757203745
# RUN  3 , total integrated cost =  2.811072745982453
# RUN  4 , total integrated cost =  2.7882452181342905
# RUN  5 , total integrated cost =  2.8671192544519206
# RUN  6 , total integrated cost =  2.6648017654951883
# RUN  7 , total integrated cost =  2.5991713765578908
# RUN  8 , total integrated cost =  2.5500199673990496
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  9 , total integrated cost =  2.4464189530988976
# RUN  9 , total integrated cost mean =  2.4464189530988976
# Improved over  9  iterations in  20.351544504985213  seconds by  50.846099309280724  percent.
# rep_ind =  40.590487779838256
# cost =  0.0
# iteration =  18
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1369.890521818723
# Gradient descend method:  None
# RUN  1 , total integrated cost =  86.99289346874093
# RUN  2 , total integrated cost =  88.1025894429327
# RUN  3 , total integrated cost =  39.41561604612359
# RUN  3 , total integrated cost mean =  39.41561604612359
# Improved over  3  iterations in  3.963778796023689  seconds by  97.12271780712857  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  39.88958162917647
# Gradient descend method:  None
# RUN  1 , total integrated cost =  19.257605904180753
# RUN  2 , total integrated cost =  16.005386013161985
# RUN  3 , total integrated cost =  14.513129436481927
# RUN  4 , total integrated cost =  14.00211222327005
# RUN  5 , total integrated cost =  13.69537695734904
# step size too small or too large
# RUN  6 , total integrated cost =  13.408191413310671
# RUN  7 , total integrated cost =  13.257757499988823
# step size too small or too large
# RUN  8 , total integrated cost =  13.112613268034732
# RUN  9 , total integrated cost =  13.030502547239141
# RUN  10 , total integrated cost =  13.019532017701303
# step size too small or too large
# RUN  11 , total integrated cost =  12.993343972435497
# RUN  12 , total integrated cost =  12.958334086488259
# RUN  13 , total integrated cost =  12.940563236670709
# step size too small or too large
# step size too small or too large
# RUN  14 , total integrated cost =  12.867455781327806
# RUN  15 , total integrated cost =  12.787641066866666
# RUN  15 , total integrated cost mean =  12.787641066866666
# Improved over  15  iterations in  31.682817314984277  seconds by  67.94240364377902  percent.
# cost =  12.833815178013719
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1381.4449255514369
# Gradient descend method:  None
# RUN  1 , total integrated cost =  44.764704414519926
# step size too small or too large
# RUN  2 , total integrated cost =  39.49982265908761
# RUN  3 , total integrated cost =  5.299210249952391
# RUN  3 , total integrated cost mean =  5.299210249952391
# Improved over  3  iterations in  4.390626471024007  seconds by  99.61640090372498  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5.275204103875377
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.4573378734084605
# RUN  2 , total integrated cost =  3.2288726667474834
# step size too small or too large
# RUN  3 , total integrated cost =  3.1378414037669193
# RUN  4 , total integrated cost =  2.996281240049899
# RUN  5 , total integrated cost =  3.0070053010476174
# RUN  6 , total integrated cost =  2.9680111572245513
# RUN  7 , total integrated cost =  2.885018269856155
# RUN  8 , total integrated cost =  2.847070303023758
# step size too small or too large
# RUN  9 , total integrated cost =  2.690601369911127
# RUN  10 , total integrated cost =  2.6607926585494983
# RUN  11 , total integrated cost =  2.648374131591048
# RUN  12 , total integrated cost =  2.6256485729640575
# step size too small or too large
# RUN  13 , total integrated cost =  2.614684950764908
# RUN  14 , total integrated cost =  2.6356982623363683
# RUN  15 , total integrated cost =  2.5518081176984793
# RUN  15 , total integrated cost mean =  2.5518081176984793
# Improved over  15  iterations in  43.02641395298997  seconds by  51.626362365319316  percent.
# rep_ind =  152.68143053954205
# cost =  0.0
# iteration =  24
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1389.3024012146557
# Gradient descend method:  None
# RUN  1 , total integrated cost =  62.78261788110471
# RUN  2 , total integrated cost =  52.5394358516529
# RUN  3 , total integrated cost =  30.731140317063016
# RUN  3 , total integrated cost mean =  30.731140317063016
# Improved over  3  iterations in  3.930399695003871  seconds by  97.78801646853881  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  30.685449525754642
# Gradient descend method:  None
# RUN  1 , total integrated cost =  27.969481204357873
# RUN  2 , total integrated cost =  25.86107156344997
# RUN  3 , total integrated cost =  25.76775371266001
# RUN  4 , total integrated cost =  25.72314528823215
# RUN  5 , total integrated cost =  25.682035070778788
# RUN  6 , total integrated cost =  25.70661137259392
# RUN  7 , total integrated cost =  25.589383885874604
# RUN  8 , total integrated cost =  25.546870893177942
# RUN  9 , total integrated cost =  25.461396924830566
# RUN  10 , total integrated cost =  25.367202423163235
# RUN  11 , total integrated cost =  25.35236340109833
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  12 , total integrated cost =  25.328307708927017
# RUN  13 , total integrated cost =  25.303987873480033
# RUN  14 , total integrated cost =  25.230448604253063
# RUN  15 , total integrated cost =  25.17593472897932
# RUN  16 , total integrated cost =  25.18376774925259
# RUN  17 , total integrated cost =  25.094985726205756
# step size too small or too large
# step size too small or too large
# RUN  18 , total integrated cost =  25.155083713477882
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  19 , total integrated cost =  25.067047698090573
# RUN  20 , total integrated cost =  25.013962840708793
# RUN  21 , total integrated cost mean =  24.938393314184776
# Improved over  21  iterations in  47.080433130962774  seconds by  18.72892951021069  percent.
# cost =  24.97202551795842
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1387.0174724705253
# Gradient descend method:  None
# RUN  1 , total integrated cost =  85.04591573395845
# RUN  2 , total integrated cost =  52.695965787471536
# RUN  3 , total integrated cost =  5.441471183098769
# RUN  3 , total integrated cost mean =  5.441471183098769
# Improved over  3  iterations in  3.9410282900207676  seconds by  99.60768546243281  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5.3209734687633246
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.0302257883515695
# RUN  2 , total integrated cost =  2.5288451570736017
# RUN  3 , total integrated cost =  2.426227321441819
# step size too small or too large
# step size too small or too large
# RUN  4 , total integrated cost =  2.3403973822928377
# step size too small or too large
# RUN  5 , total integrated cost =  2.342946791674125
# RUN  6 , total integrated cost =  2.3078885142564616
# RUN  7 , total integrated cost =  2.2586836171229256
# RUN  8 , total integrated cost =  2.1807049933129408
# RUN  9 , total integrated cost =  2.154046097513193
# RUN  10 , total integrated cost =  2.1529438889484993
# RUN  11 , total integrated cost =  1.9419985189198286
# step size too small or too large
# RUN  12 , total integrated cost =  1.874892984467547
# RUN  13 , total integrated cost =  1.890247642967497
# RUN  14 , total integrated cost =  1.7988715932933264
# RUN  15 , total integrated cost =  1.7387874879594232
# step size too small or too large
# RUN  16 , total integrated cost =  1.6756832121588494
# RUN  17 , total integrated cost =  1.6901642952032532
# RUN  18 , total integrated cost =  1.5932140873979184
# RUN  19 , total integrated cost =  1.5432673766616753
# RUN  20 , total integrated cost =  1.45097442001932
# step size too small or too large
# step size too small or too large
# RUN  21 , total integrated cost mean =  1.4593452435403171
# Improved over  21  iterations in  54.83448156900704  seconds by  72.57371696913401  percent.
# rep_ind =  235.4150543242229
# n =  30
# cost =  0.0
# iteration =  6
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1383.6417459462925
# Gradient descend method:  None
# RUN  1 , total integrated cost =  83.81808721641512
# RUN  2 , total integrated cost =  36.08540440926257
# RUN  3 , total integrated cost =  13.568266239520808
# RUN  3 , total integrated cost mean =  13.568266239520808
# Improved over  3  iterations in  11.807428167026956  seconds by  99.01938010476539  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  13.511631586144153
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.965127999226521
# step size too small or too large
# step size too small or too large
# RUN  2 , total integrated cost =  11.788906323836756
# RUN  3 , total integrated cost =  11.725858242037107
# RUN  3 , total integrated cost mean =  11.725858242037107
# Improved over  3  iterations in  19.64497670700075  seconds by  13.216563319697912  percent.
# cost =  11.71823234325646
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1379.9742276921415
# Gradient descend method:  None
# RUN  1 , total integrated cost =  65.8825459380314
# step size too small or too large
# RUN  2 , total integrated cost =  45.82954689927628
# RUN  3 , total integrated cost =  32.95686415555995
# RUN  3 , total integrated cost mean =  32.95686415555995
# Improved over  3  iterations in  12.793815626006108  seconds by  97.61177683653725  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  31.321841017937587
# Gradient descend method:  None
# step size too small or too large
# RUN  1 , total integrated cost =  21.995007455158127
# RUN  2 , total integrated cost =  15.347573946793323
# RUN  3 , total integrated cost =  14.438314506396104
# RUN  3 , total integrated cost mean =  14.438314506396104
# Improved over  3  iterations in  19.592976630025078  seconds by  53.90336571171701  percent.
# rep_ind =  271.98982760442664
# cost =  0.0
# iteration =  12
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1373.2542740816587
# Gradient descend method:  None
# RUN  1 , total integrated cost =  88.09812373598048
# RUN  2 , total integrated cost =  33.74468135507275
# RUN  3 , total integrated cost =  12.986233883150001
# RUN  3 , total integrated cost mean =  12.986233883150001
# Improved over  3  iterations in  11.631580673973076  seconds by  99.0543460065446  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12.95188978874553
# Gradient descend method:  None
# step size too small or too large
# RUN  1 , total integrated cost =  11.826767260167218
# RUN  2 , total integrated cost =  11.739188933631965
# RUN  3 , total integrated cost =  11.677958978786931
# step size too small or too large
# RUN  4 , total integrated cost =  11.611837479389875
# step size too small or too large
# RUN  5 , total integrated cost =  11.515087797093676
# RUN  6 , total integrated cost =  11.448572149237224
# step size too small or too large
# step size too small or too large
# RUN  7 , total integrated cost =  11.383370125991117
# step size too small or too large
# RUN  8 , total integrated cost =  11.309254636941128
# step size too small or too large
# RUN  9 , total integrated cost =  11.255584159340769
# RUN  9 , total integrated cost mean =  11.255584159340769
# Improved over  9  iterations in  58.20780949102482  seconds by  13.096973932551194  percent.
# cost =  11.267312559425788
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1375.638765448387
# Gradient descend method:  None
# RUN  1 , total integrated cost =  102.60657688390152
# RUN  2 , total integrated cost =  39.31620312755822
# RUN  3 , total integrated cost =  7.233418798550546
# RUN  3 , total integrated cost mean =  7.233418798550546
# Improved over  3  iterations in  12.299207183998078  seconds by  99.47417745266921  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7.0353654315478975
# Gradient descend method:  None
# step size too small or too large
# RUN  1 , total integrated cost =  3.7187102364979947
# step size too small or too large
# RUN  2 , total integrated cost =  2.419693302856591
# step size too small or too large
# RUN  3 , total integrated cost =  2.2893450383736558
# step size too small or too large
# step size too small or too large
# RUN  4 , total integrated cost =  2.2476809269104385
# RUN  5 , total integrated cost =  2.2115011646204774
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  6 , total integrated cost =  2.1055380180641774
# step size too small or too large
# RUN  7 , total integrated cost =  2.0258225971749586
# RUN  8 , total integrated cost =  1.9992934875207273
# RUN  9 , total integrated cost =  1.9311084470055715
# RUN  9 , total integrated cost mean =  1.9311084470055715
# Improved over  9  iterations in  59.748702512995806  seconds by  72.55141234958288  percent.
# rep_ind =  122.77996191620919
# cost =  0.0
# iteration =  18
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1365.9614955071033
# Gradient descend method:  None
# RUN  1 , total integrated cost =  120.71496072827868
# RUN  2 , total integrated cost =  66.2621925735246
# RUN  3 , total integrated cost =  33.990163817859546
# RUN  3 , total integrated cost mean =  33.990163817859546
# Improved over  3  iterations in  12.343816965003498  seconds by  97.51163089664976  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  34.305881351222645
# Gradient descend method:  None
# RUN  1 , total integrated cost =  18.419416086967253
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  2 , total integrated cost =  17.151368652595
# step size too small or too large
# step size too small or too large
# RUN  3 , total integrated cost =  16.766031588809184
# RUN  4 , total integrated cost =  16.53465653981303
# step size too small or too large
# step size too small or too large
# RUN  5 , total integrated cost =  16.40499919797017
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  6 , total integrated cost =  16.319831762704563
# step size too small or too large
# RUN  7 , total integrated cost =  16.23840440861125
# RUN  8 , total integrated cost =  16.194408198774443
# step size too small or too large
# RUN  9 , total integrated cost =  16.09065585058781
# RUN  10 , total integrated cost =  16.03657092517728
# RUN  11 , total integrated cost =  15.973660833305429
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  12 , total integrated cost =  15.927457696256207
# step size too small or too large
# step size too small or too large
# RUN  13 , total integrated cost =  15.8513056883886
# step size too small or too large
# RUN  14 , total integrated cost =  15.74746477446002
# RUN  15 , total integrated cost =  15.720135973561446
# RUN  15 , total integrated cost mean =  15.720135973561446
# Improved over  15  iterations in  98.61381501000142  seconds by  54.176557038080034  percent.
# cost =  15.726263214328393
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1377.5487414877102
# Gradient descend method:  None
# RUN  1 , total integrated cost =  69.68092113155525
# RUN  2 , total integrated cost =  61.74819963863701
# RUN  3 , total integrated cost =  29.937153276917233
# RUN  3 , total integrated cost mean =  29.937153276917233
# Improved over  3  iterations in  12.75952248997055  seconds by  97.82678083357065  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  29.75256788793732
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.762216799134229
# RUN  2 , total integrated cost =  4.409631855804322
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  3 , total integrated cost =  4.178026282058256
# RUN  4 , total integrated cost =  4.054949438599696
# step size too small or too large
# step size too small or too large
# RUN  5 , total integrated cost =  3.991761459814753
# step size too small or too large
# step size too small or too large
# RUN  6 , total integrated cost =  3.9430925706939557
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  7 , total integrated cost =  3.8740557062676957
# RUN  8 , total integrated cost =  3.80929137096991
# step size too small or too large
# RUN  9 , total integrated cost =  3.6982525823685615
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  10 , total integrated cost =  3.6841323510569333
# step size too small or too large
# step size too small or too large
# RUN  11 , total integrated cost =  3.516804340842158
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  12 , total integrated cost =  3.7577179649965706
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  13 , total integrated cost =  3.602154695008601
# RUN  14 , total integrated cost =  3.576839391506568
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  15 , total integrated cost =  3.544994015171305
# RUN  15 , total integrated cost mean =  3.544994015171305
# Improved over  15  iterations in  212.59663907298818  seconds by  88.08508217333213  percent.
# rep_ind =  178.94210283669878
# cost =  0.0
# iteration =  24
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1379.1912329082
# Gradient descend method:  None
# RUN  1 , total integrated cost =  74.78477807967896
# RUN  2 , total integrated cost =  103.40294917695101
# RUN  3 , total integrated cost =  31.997086473607684
# RUN  3 , total integrated cost mean =  31.997086473607684
# Improved over  3  iterations in  11.63552799494937  seconds by  97.68001088535505  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  32.014131021782894
# Gradient descend method:  None
# RUN  1 , total integrated cost =  10.640411651692851
# step size too small or too large
# RUN  2 , total integrated cost =  9.23915654700122
# RUN  3 , total integrated cost =  8.556654702992969
# RUN  4 , total integrated cost =  8.426122759260332
# RUN  5 , total integrated cost =  8.336911006864932
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  6 , total integrated cost =  8.225061125468503
# RUN  7 , total integrated cost =  8.126779582150574
# step size too small or too large
# step size too small or too large
# RUN  8 , total integrated cost =  8.030882848583584
# RUN  9 , total integrated cost =  7.993108415176372
# step size too small or too large
# RUN  10 , total integrated cost =  7.9130992825091715
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  11 , total integrated cost =  7.841032705141498
# step size too small or too large
# step size too small or too large
# RUN  12 , total integrated cost =  7.8054949443342165
# step size too small or too large
# RUN  13 , total integrated cost =  7.692972954001546
# RUN  14 , total integrated cost =  7.6802051777645355
# RUN  15 , total integrated cost =  7.5859200716617075
# RUN  16 , total integrated cost =  7.51508722845422
# step size too small or too large
# step size too small or too large
# RUN  17 , total integrated cost =  7.467535954529272
# RUN  18 , total integrated cost =  7.460539621152994
# RUN  19 , total integrated cost =  7.3393838307459385
# step size too small or too large
# RUN  20 , total integrated cost =  7.320613367535291
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  21 , total integrated cost mean =  7.259901986222711
# Improved over  21  iterations in  148.75420871702954  seconds by  77.32282040926563  percent.
# cost =  7.286623628427203
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1379.036182683707
# Gradient descend method:  None
# RUN  1 , total integrated cost =  143.34487804258603
# step size too small or too large
# RUN  2 , total integrated cost =  43.06613917579332
# RUN  3 , total integrated cost =  5.275598236755105
# RUN  3 , total integrated cost mean =  5.275598236755105
# Improved over  3  iterations in  12.028621326084249  seconds by  99.61744308793345  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5.460084044007514
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.208763384525079
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  2 , total integrated cost =  2.827351048855056
# RUN  3 , total integrated cost =  2.756794906840222
# RUN  4 , total integrated cost =  2.6435981642101507
# RUN  5 , total integrated cost =  2.5857034783047173
# RUN  6 , total integrated cost =  2.482569909116377
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  7 , total integrated cost =  2.4530398704038463
# RUN  8 , total integrated cost =  2.4094798079541944
# step size too small or too large
# RUN  9 , total integrated cost =  2.2628465157108053
# step size too small or too large
# RUN  10 , total integrated cost =  2.1750732226013407
# step size too small or too large
# RUN  11 , total integrated cost =  2.1850635677171013
# RUN  12 , total integrated cost =  2.1471731716438134
# RUN  13 , total integrated cost =  2.0356134742377296
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  14 , total integrated cost =  1.9405663382875429
# RUN  15 , total integrated cost =  1.937540965460794
# RUN  16 , total integrated cost =  1.874373909231003
# RUN  17 , total integrated cost =  1.7371505128851659
# RUN  18 , total integrated cost =  1.6954995694508843
# RUN  19 , total integrated cost =  1.6823684230212417
# RUN  20 , total integrated cost =  1.6015387804614074
# step size too small or too large
# step size too small or too large
# RUN  21 , total integrated cost mean =  1.601113674282228
# Improved over  21  iterations in  145.0332992959302  seconds by  70.67602510552081  percent.
# rep_ind =  92.45476878460627
# n =  50
# cost =  0.0
# iteration =  6
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1381.8232973324748
# Gradient descend method:  None
# RUN  1 , total integrated cost =  89.0205926482118
# RUN  2 , total integrated cost =  42.88029886569218
# RUN  3 , total integrated cost =  37.06378693158035
# RUN  3 , total integrated cost mean =  37.06378693158035
# Improved over  3  iterations in  21.590384748997167  seconds by  97.31776219122013  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  36.939303971023875
# Gradient descend method:  None
# RUN  1 , total integrated cost =  9.484244951617326
# RUN  2 , total integrated cost =  6.778184848732149
# step size too small or too large
# step size too small or too large
# RUN  3 , total integrated cost =  5.392307426597956
# RUN  3 , total integrated cost mean =  5.392307426597956
# Improved over  3  iterations in  32.96445297601167  seconds by  85.4022495095527  percent.
# cost =  5.417022646041764
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1382.1932289990086
# Gradient descend method:  None
# RUN  1 , total integrated cost =  98.86038041312003
# RUN  2 , total integrated cost =  36.30111985575628
# RUN  3 , total integrated cost =  6.733533670400066
# RUN  3 , total integrated cost mean =  6.733533670400066
# Improved over  3  iterations in  20.56312968209386  seconds by  99.51283702385979  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  6.599145378614124
# Gradient descend method:  None
# step size too small or too large
# RUN  1 , total integrated cost =  3.700689310017184
# RUN  2 , total integrated cost =  2.707137725733154
# step size too small or too large
# RUN  3 , total integrated cost =  2.528189900396248
# RUN  3 , total integrated cost mean =  2.528189900396248
# Improved over  3  iterations in  32.438962818006985  seconds by  61.68913161711268  percent.
# rep_ind =  44.928640144993196
# cost =  0.0
# iteration =  12
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1376.5138468083874
# Gradient descend method:  None
# RUN  1 , total integrated cost =  108.62879407594599
# RUN  2 , total integrated cost =  54.22840498787365
# RUN  3 , total integrated cost =  11.062406809582773
# RUN  3 , total integrated cost mean =  11.062406809582773
# Improved over  3  iterations in  19.941372485016473  seconds by  99.19634612937368  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11.064336640081025
# Gradient descend method:  None
# step size too small or too large
# RUN  1 , total integrated cost =  8.48535355098065
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  2 , total integrated cost =  8.080290162079363
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  3 , total integrated cost =  7.985044902799425
# RUN  4 , total integrated cost =  7.859251108698827
# RUN  5 , total integrated cost =  7.830576028136078
# step size too small or too large
# RUN  6 , total integrated cost =  7.7369454270964555
# RUN  7 , total integrated cost =  7.655267063122446
# RUN  8 , total integrated cost =  7.511168082853564
# RUN  9 , total integrated cost =  7.4508111639126255
# RUN  9 , total integrated cost mean =  7.4508111639126255
# Improved over  9  iterations in  100.53829917800613  seconds by  32.659214860457624  percent.
# cost =  7.460152595031796
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1377.1611505107796
# Gradient descend method:  None
# RUN  1 , total integrated cost =  102.48447708976391
# RUN  2 , total integrated cost =  53.837507636280996
# RUN  3 , total integrated cost =  21.691913389997694
# RUN  3 , total integrated cost mean =  21.691913389997694
# Improved over  3  iterations in  19.112183484015986  seconds by  98.42488198407628  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  21.42443710339733
# Gradient descend method:  None
# step size too small or too large
# step size too small or too large
# RUN  1 , total integrated cost =  16.202940359568927
# step size too small or too large
# RUN  2 , total integrated cost =  14.385929580166072
# step size too small or too large
# RUN  3 , total integrated cost =  13.990046739719064
# step size too small or too large
# RUN  4 , total integrated cost =  13.765706932521184
# RUN  5 , total integrated cost =  13.598114831686214
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  6 , total integrated cost =  13.487520837013244
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  7 , total integrated cost =  13.364200794343919
# RUN  8 , total integrated cost =  13.268433294223533
# step size too small or too large
# step size too small or too large
# RUN  9 , total integrated cost =  13.186087803673017
# RUN  9 , total integrated cost mean =  13.186087803673017
# Improved over  9  iterations in  97.97768745105714  seconds by  38.45304901111235  percent.
# rep_ind =  137.06368794024385
# cost =  0.0
# iteration =  18
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1373.8986776341196
# Gradient descend method:  None
# RUN  1 , total integrated cost =  124.91311563298952
# RUN  2 , total integrated cost =  46.13159808591912
# RUN  3 , total integrated cost =  7.306810942872915
# RUN  3 , total integrated cost mean =  7.306810942872915
# Improved over  3  iterations in  20.161307801958174  seconds by  99.46816959199238  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7.462377531155381
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.934839802075572
# RUN  2 , total integrated cost =  3.047356249079733
# step size too small or too large
# RUN  3 , total integrated cost =  2.9000208297267847
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  4 , total integrated cost =  2.7620381853631284
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  5 , total integrated cost =  2.7017258124885712
# RUN  6 , total integrated cost =  2.6396678953102124
# RUN  7 , total integrated cost =  2.592049254785843
# RUN  8 , total integrated cost =  2.4967472497428655
# RUN  9 , total integrated cost =  2.43176109624202
# step size too small or too large
# RUN  10 , total integrated cost =  2.2902568999506463
# RUN  11 , total integrated cost =  2.237968115340364
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  12 , total integrated cost =  2.0819203230292764
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  13 , total integrated cost =  2.0222211405162245
# step size too small or too large
# RUN  14 , total integrated cost =  1.8990154054878665
# RUN  15 , total integrated cost =  1.8263769227341522
# RUN  15 , total integrated cost mean =  1.8263769227341522
# Improved over  15  iterations in  167.51628346997313  seconds by  75.52553572760102  percent.
# cost =  4.2569501909392855
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1374.2982019385215
# Gradient descend method:  None
# RUN  1 , total integrated cost =  150.00307738624403
# RUN  2 , total integrated cost =  68.74203215313713
# RUN  3 , total integrated cost =  20.043769786180853
# RUN  3 , total integrated cost mean =  20.043769786180853
# Improved over  3  iterations in  18.71111391100567  seconds by  98.5415268856564  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  19.820064469667326
# ...
# step size too small or too large
# step size too small or too large
# RUN  8 , total integrated cost =  58.42709257548245
# step size too small or too large
# step size too small or too large
# RUN  9 , total integrated cost =  58.19836063019645
# RUN  9 , total integrated cost mean =  58.19836063019645
# Improved over  9  iterations in  94.78944865404628  seconds by  16.915791743449233  percent.
# cost =  58.262439991791126
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  301.70494939357843
# Gradient descend method:  None
# step size too small or too large
# RUN  1 , total integrated cost =  65.30256552300402
# RUN  2 , total integrated cost =  108.00474114142733
# step size too small or too large
# RUN  3 , total integrated cost =  64.72830292615865
# RUN  3 , total integrated cost mean =  64.72830292615865
# Improved over  3  iterations in  21.846797425998375  seconds by  78.54582662423624  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  62.47447734178452
# Gradient descend method:  None
# RUN  1 , total integrated cost =  21.30782234943919
# RUN  2 , total integrated cost =  6.230605433246995
# RUN  3 , total integrated cost =  5.27550086586162
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  4 , total integrated cost =  5.061711407877547
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  5 , total integrated cost =  4.895535887758705
# step size too small or too large
# RUN  6 , total integrated cost =  4.655005147652099
# step size too small or too large
# step size too small or too large
# RUN  7 , total integrated cost =  4.51688525203042
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  8 , total integrated cost =  4.436133970578562
# RUN  9 , total integrated cost =  4.342442169351305
# RUN  9 , total integrated cost mean =  4.342442169351305
# Improved over  9  iterations in  97.30513821402565  seconds by  93.04925410484871  percent.
# rep_ind =  766.4008121034133
# cost =  0.0
# iteration =  18
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  271.0787241085768
# Gradient descend method:  None
# step size too small or too large
# RUN  1 , total integrated cost =  84.42072576719977
# step size too small or too large
# RUN  2 , total integrated cost =  15.832485912397555
# RUN  3 , total integrated cost =  7.915388334800772
# RUN  3 , total integrated cost mean =  7.915388334800772
# Improved over  3  iterations in  21.76908831798937  seconds by  97.0800407295593  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  8.099716832280098
# Gradient descend method:  None
# step size too small or too large
# RUN  1 , total integrated cost =  5.273079008713122
# step size too small or too large
# RUN  2 , total integrated cost =  4.749526249402958
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  3 , total integrated cost =  4.638195540341545
# step size too small or too large
# RUN  4 , total integrated cost =  4.4381601840575335
# RUN  5 , total integrated cost =  4.247628098433852
# step size too small or too large
# RUN  6 , total integrated cost =  3.9657955266278306
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  7 , total integrated cost =  3.6418538021673963
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  8 , total integrated cost =  3.03013850030716
# RUN  9 , total integrated cost =  3.007383124901218
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  10 , total integrated cost =  2.8384497224028653
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  11 , total integrated cost =  2.9574556618436763
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  12 , total integrated cost =  2.990173691405378
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  13 , total integrated cost =  3.1724889571740946
# step size too small or too large
# RUN  14 , total integrated cost =  2.9131553102215526
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  15 , total integrated cost =  3.0078428007174796
# RUN  15 , total integrated cost mean =  3.0078428007174796
# Improved over  15  iterations in  200.71828117896803  seconds by  62.86484005551634  percent.
# cost =  8.67667937495312
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  252.14144539242142
# Gradient descend method:  None
# RUN  1 , total integrated cost =  148.42348692955053
# RUN  2 , total integrated cost =  84.90146069874366
# step size too small or too large
# RUN  3 , total integrated cost =  155.23540239050723
# RUN  3 , total integrated cost mean =  155.23540239050723
# Improved over  3  iterations in  22.506124921957962  seconds by  38.433206746750436  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  197.02039643928535
# Gradient descend method:  None
# step size too small or too large
# step size too small or too large
# RUN  1 , total integrated cost =  53.89152380534858
# step size too small or too large
# RUN  2 , total integrated cost =  2.8701692996809856
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  3 , total integrated cost =  3.16871995306474
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  4 , total integrated cost =  2.336648240467491
# RUN  5 , total integrated cost =  2.3690660089215543
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  6 , total integrated cost =  10.863389166298594
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  7 , total integrated cost =  142.3871216634305
# no cost improvement
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  8 , total integrated cost =  173.4747478766725
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  9 , total integrated cost =  45.16532600568825
# step size too small or too large
# RUN  10 , total integrated cost =  12.833327005027895
# RUN  10 , total integrated cost mean =  12.833327005027895
# Improved over  10  iterations in  414.0586255360395  seconds by  93.48629520752047  percent.
# rep_ind =  117.33151887788392
# cost =  0.0
# iteration =  24
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  277.27457622391483
# Gradient descend method:  None
# step size too small or too large
# RUN  1 , total integrated cost =  80.28107612132199
# RUN  2 , total integrated cost =  21.42927212547652
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  3 , total integrated cost =  239.50542050345018
# RUN  3 , total integrated cost mean =  239.50542050345018
# Improved over  3  iterations in  66.87928382703103  seconds by  13.621571885467034  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  319.6503768068941
# Gradient descend method:  None
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  1 , total integrated cost =  23.65373293875549
# step size too small or too large
# step size too small or too large
# RUN  2 , total integrated cost =  45.723801682794864
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  3 , total integrated cost =  65.28880317504843
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  4 , total integrated cost =  14.820674389147484
# RUN  5 , total integrated cost =  13.286269676949297
# step size too small or too large
# RUN  6 , total integrated cost =  12.705355628403698
# RUN  7 , total integrated cost =  12.096207924579273
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  8 , total integrated cost =  11.8742828911841
# RUN  9 , total integrated cost =  11.781799367667881
# step size too small or too large
# RUN  10 , total integrated cost =  11.5289249572261
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  11 , total integrated cost =  11.279103778202302
# step size too small or too large
# step size too small or too large
# RUN  12 , total integrated cost =  11.092923440660057
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  13 , total integrated cost =  10.412218468978374
# RUN  14 , total integrated cost =  9.775067668951921
# RUN  15 , total integrated cost =  9.428227691986335
# step size too small or too large
# RUN  16 , total integrated cost =  9.246395226346378
# step size too small or too large
# step size too small or too large
# RUN  17 , total integrated cost =  8.788291908976376
# RUN  18 , total integrated cost =  8.573354975462571
# step size too small or too large
# RUN  19 , total integrated cost =  8.600513964862682
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  20 , total integrated cost =  8.194634137633363
# RUN  21 , total integrated cost mean =  7.806874739240641
# Improved over  21  iterations in  255.55781793396454  seconds by  97.55768323590718  percent.
# cost =  10.764901207725813
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  301.26423423446465
# Gradient descend method:  None
# RUN  1 , total integrated cost =  77.24720650969252
# step size too small or too large
# RUN  2 , total integrated cost =  15.384358879388206
# RUN  3 , total integrated cost =  12.749431102151082
# RUN  3 , total integrated cost mean =  12.749431102151082
# Improved over  3  iterations in  25.33176764496602  seconds by  95.76802366382842  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12.763869668954849
# Gradient descend method:  None
# step size too small or too large
# RUN  1 , total integrated cost =  11.966061597984043
# step size too small or too large
# RUN  2 , total integrated cost =  11.848722051130462
# step size too small or too large
# RUN  3 , total integrated cost =  11.69009712838056
# step size too small or too large
# step size too small or too large
# RUN  4 , total integrated cost =  11.388390136178863
# step size too small or too large
# step size too small or too large
# RUN  5 , total integrated cost =  11.090541039603465
# step size too small or too large
# step size too small or too large
# RUN  6 , total integrated cost =  10.845474033204423
# RUN  7 , total integrated cost =  10.874747451171437
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  8 , total integrated cost =  10.616971307453532
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  9 , total integrated cost =  10.395051976998197
# step size too small or too large
# RUN  10 , total integrated cost =  10.07006215651419
# RUN  11 , total integrated cost =  10.023354580384918
# step size too small or too large
# step size too small or too large
# RUN  12 , total integrated cost =  9.814409740311003
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  13 , total integrated cost =  9.54611469234181
# RUN  14 , total integrated cost =  9.23831039055462
# step size too small or too large
# RUN  15 , total integrated cost =  8.964022355534711
# RUN  16 , total integrated cost =  8.732219513495
# step size too small or too large
# step size too small or too large
# RUN  17 , total integrated cost =  8.396074815687937
# RUN  18 , total integrated cost =  8.022391917794472
# step size too small or too large
# step size too small or too large
# RUN  19 , total integrated cost =  7.867520838162315
# step size too small or too large
# step size too small or too large
# RUN  20 , total integrated cost =  7.641809902430086
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  21 , total integrated cost mean =  7.4202796421617965
# Improved over  21  iterations in  247.08973363798577  seconds by  41.86496858229519  percent.
# rep_ind =  125.10482606255404

# %%
#len(sigma_array), 4, N_max, max_it

##### METHOD 4
method_ind = 3
step_method_ind = 0
step_m = 'S1'

for d in dict_list:
    print("Point = ", d['point'])
    aln.params.ext_exc_current = d['point'][0] * 5.
    aln.params.ext_inh_current = d['point'][1] * 5.
    
    max_it = d['cost'].shape[3]
    
    for s_ind in range(len(d['sigma'])):
        
        print("sigma = ", d['sigma'][s_ind])
        
        s = d['sigma'][s_ind]
        aln.params.sigma_ou = s
        c_p = d['cost_params'][s_ind]
        cost.setParams(c_p[0], c_p[1], c_p[2])
        
        target_ = d['target'][s_ind].copy()
        target_[0,0,:int(trans_time * dur / aln.params.dt)] = -1000
        target_[0,1,:int(trans_time * dur / aln.params.dt)] = -1000
                
        for n_ind in range(len(d['N_array'])):
            
            n_ = d['N_array'][n_ind]
            
            print("n = ", n_)
            aln.params.duration = dur
        
            for i_it in range(1,len(d['it_array'])):
            
                it = d['it_array'][i_it]
                print("iteration = ", it)
                
                if ( d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it] > 0.
                    and d['rep_ind'][s_ind, method_ind, step_method_ind, n_ind, i_it] > 0. ) :
                    continue
                
                c_vars = d['init']
                aln.params.duration = dur
                setinit(d['init_vars'], aln)
                control_init = aln.getZeroControl()
                    
                bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                    control_init, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_ = init_it,
                    tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                    t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                    control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                    noise_real=n_, init_params = d['init_vars'], method='M4', method_step=step_m)
                            
                control_init = bc[:,:,100:-100]
                c_vars = [0,1]
                aln.params.duration = dur
                setinit(d['init_vars'], aln)

                bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                    control_init, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_=it-init_it,
                    tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                    t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                    control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                    noise_real=n_, init_params = d['init_vars'], method='M4', method_step=step_m)

                
                control_init = bc[:,:,100:-100]
                aln.params.duration = dur
                setinit(d['init_vars'], aln)
                cost_final = 0.
                cs = cost.numba_cost_sparsity_int(1, 6, T, d['cost_params'][s_ind][2], dt, control_init)

                for j in range(noise_realizations_final):
                    state_ = fo.updateState(aln, control_init)
                    cost_final += cost.numba_cost_precision_int(1, T, dt, d['cost_params'][s_ind][0],
                                                                   state_, target_, list(prec_vars) )

                d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it] = (
                                cost_final / noise_realizations_final + cs )
                print('cost = ', d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it])
                
                c_vars = d['init']                    
                aln.params.duration = dur
                control_init1 = aln.getZeroControl()
                setinit(d['init_vars'], aln)
                
                bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                    control_init1, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_ = init_it,
                    tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                    t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                    control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                    noise_real=n_, init_params = d['init_vars'], method='M4', method_step=step_m)
                            
                control_init1 = bc[:,:,100:-100]
                c_vars = [0,1]
                aln.params.duration = dur
                setinit(d['init_vars'], aln)

                bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                    control_init1, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_=it-init_it,
                    tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                    t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                    control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                    noise_real=n_, init_params = d['init_vars'], method='M4', method_step=step_m)
                                

                control_init1 = bc[:,:,100:-100]
                d['rep_ind'][s_ind, method_ind, step_method_ind, n_ind, i_it] = rep_ind(control_init, control_init1)
                print('rep_ind = ', d['rep_ind'][s_ind, method_ind, step_method_ind, n_ind, i_it])
                
                file=open(dict_file, "wb")
                pickle.dump(dict_list, file)
                file.close()
                
    break
# Out:
# Point =  [0.4   0.322]
# sigma =  0.01
# set cost params:  0.005531732932180352 0.0 1.0
# n =  2
# iteration =  6
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1386.5329802022952
# Gradient descend method:  None
# RUN  1 , total integrated cost =  50.61772232497243
# RUN  2 , total integrated cost =  42.659479938207795
# RUN  3 , total integrated cost =  3.9952848968569663
# RUN  3 , total integrated cost mean =  3.9952848968569663
# Improved over  3  iterations in  14.890807365067303  seconds by  99.71185071297229  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.6232543076051886
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.9021659590352562
# RUN  2 , total integrated cost =  1.8738955972882874
# RUN  3 , total integrated cost =  1.744252481980538
# RUN  3 , total integrated cost mean =  1.744252481980538
# Improved over  3  iterations in  1.2291324740508571  seconds by  51.8595071199015  percent.
# cost =  1.906655460756725
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1410.3982390991878
# Gradient descend method:  None
# RUN  1 , total integrated cost =  29.397283318458612
# RUN  2 , total integrated cost =  5.219710920905537
# RUN  3 , total integrated cost =  2.894915127423389
# RUN  3 , total integrated cost mean =  2.894915127423389
# Improved over  3  iterations in  0.6943471960257739  seconds by  99.79474484247284  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  611.42136909395
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.3025599178957608
# step size too small or too large
# RUN  2 , total integrated cost =  2.4493852769891085
# RUN  3 , total integrated cost =  2.175735554782831
# RUN  3 , total integrated cost mean =  2.175735554782831
# Improved over  3  iterations in  2.4084299079841003  seconds by  99.644151208191  percent.
# rep_ind =  32.111464448879914
# iteration =  12
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1365.8185521377736
# Gradient descend method:  None
# RUN  1 , total integrated cost =  110.05698530602652
# RUN  2 , total integrated cost =  31.275689865010143
# RUN  3 , total integrated cost =  5.388905851721186
# RUN  3 , total integrated cost mean =  5.388905851721186
# Improved over  3  iterations in  0.6746121479663998  seconds by  99.60544496607646  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  6.211828615574599
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.34010831834904
# RUN  2 , total integrated cost =  2.461903348313524
# RUN  3 , total integrated cost =  2.39316081103578
# RUN  4 , total integrated cost =  2.313862519878535
# RUN  5 , total integrated cost =  2.355693101971708
# RUN  6 , total integrated cost =  2.334331896263973
# RUN  7 , total integrated cost =  2.2718001706045308
# RUN  8 , total integrated cost =  2.2456150892299673
# RUN  9 , total integrated cost =  2.098060439870485
# RUN  9 , total integrated cost mean =  2.098060439870485
# Improved over  9  iterations in  3.7687311969930306  seconds by  66.22475329389923  percent.
# cost =  2.285256132600407
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1402.986722753312
# Gradient descend method:  None
# RUN  1 , total integrated cost =  69.15735038849918
# RUN  2 , total integrated cost =  14.017867831384587
# RUN  3 , total integrated cost =  4.097926989407821
# RUN  3 , total integrated cost mean =  4.097926989407821
# Improved over  3  iterations in  0.7367405280238017  seconds by  99.70791405770642  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.81201622899565
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.3076373654077553
# step size too small or too large
# RUN  2 , total integrated cost =  3.347651371032669
# RUN  3 , total integrated cost =  3.2654780080551093
# RUN  4 , total integrated cost =  3.259632266536024
# step size too small or too large
# step size too small or too large
# RUN  5 , total integrated cost =  3.2733569750124687
# RUN  6 , total integrated cost =  3.152347157017198
# RUN  7 , total integrated cost =  3.087475917575434
# RUN  8 , total integrated cost =  3.1049231059794544
# RUN  9 , total integrated cost =  3.122109371800069
# RUN  9 , total integrated cost mean =  3.122109371800069
# Improved over  9  iterations in  4.991116484045051  seconds by  18.098214061836515  percent.
# rep_ind =  37.03116140931594
# iteration =  18
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1347.0785397840566
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.298963617665235
# RUN  2 , total integrated cost =  11.084799780794981
# RUN  3 , total integrated cost =  3.1373502210438673
# RUN  3 , total integrated cost mean =  3.1373502210438673
# Improved over  3  iterations in  0.5806905019562691  seconds by  99.76709968065063  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.8922139135912666
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.069026353773901
# RUN  2 , total integrated cost =  2.0314462734804613
# RUN  3 , total integrated cost =  1.9231427064275244
# RUN  4 , total integrated cost =  1.7985962008100307
# RUN  5 , total integrated cost =  1.743131607612386
# RUN  6 , total integrated cost =  1.8646083276820344
# RUN  7 , total integrated cost =  1.7314929529903405
# RUN  8 , total integrated cost =  1.6544892058062675
# RUN  9 , total integrated cost =  1.684769591135711
# RUN  10 , total integrated cost =  1.6767129491687895
# RUN  11 , total integrated cost =  1.751250995238697
# RUN  12 , total integrated cost =  1.6411770026951416
# step size too small or too large
# step size too small or too large
# RUN  13 , total integrated cost =  1.5509432972113788
# RUN  14 , total integrated cost =  1.6505204839645584
# RUN  15 , total integrated cost =  1.4856569164687299
# RUN  15 , total integrated cost mean =  1.4856569164687299
# Improved over  15  iterations in  7.035947756958194  seconds by  61.830029144057384  percent.
# cost =  70.19974657648852
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1395.510062984467
# Gradient descend method:  None
# RUN  1 , total integrated cost =  125.11096011806586
# RUN  2 , total integrated cost =  131.84805451306454
# RUN  3 , total integrated cost =  52.31826233834931
# RUN  3 , total integrated cost mean =  52.31826233834931
# Improved over  3  iterations in  0.5566130739171058  seconds by  96.25095771602962  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  51.729197812506044
# Gradient descend method:  None
# RUN  1 , total integrated cost =  27.262759138274372
# RUN  2 , total integrated cost =  25.53848525055213
# RUN  3 , total integrated cost =  25.298103586059327
# RUN  4 , total integrated cost =  25.233536283355704
# RUN  5 , total integrated cost =  25.329839500175417
# RUN  6 , total integrated cost =  25.14317035739655
# RUN  7 , total integrated cost =  25.126887128389782
# RUN  8 , total integrated cost =  25.368307291343356
# RUN  9 , total integrated cost =  25.16850013731664
# RUN  10 , total integrated cost =  25.341845345403815
# RUN  11 , total integrated cost =  25.134331506811325
# RUN  12 , total integrated cost =  25.316940019584763
# RUN  13 , total integrated cost =  25.20569019621982
# RUN  14 , total integrated cost =  24.947933510281082
# RUN  15 , total integrated cost =  24.952801342037773
# RUN  15 , total integrated cost mean =  24.952801342037773
# Improved over  15  iterations in  6.544194680056535  seconds by  51.76263619536511  percent.
# rep_ind =  331.17638346540497
# iteration =  24
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1390.0539165659943
# Gradient descend method:  None
# RUN  1 , total integrated cost =  67.88517372919688
# RUN  2 , total integrated cost =  3.857963100821701
# RUN  3 , total integrated cost =  2.1452161207148146
# RUN  3 , total integrated cost mean =  2.1452161207148146
# Improved over  3  iterations in  0.8265717820031568  seconds by  99.845673891124  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  596.4772177610726
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.1498993486969056
# RUN  2 , total integrated cost =  1.9826518333769911
# RUN  3 , total integrated cost =  2.022336894694776
# RUN  4 , total integrated cost =  1.903140250944602
# RUN  5 , total integrated cost =  1.8271086385707942
# step size too small or too large
# step size too small or too large
# RUN  6 , total integrated cost =  1.9194149020106757
# RUN  7 , total integrated cost =  1.755361677573492
# RUN  8 , total integrated cost =  1.7064703203571732
# RUN  9 , total integrated cost =  1.743646779172762
# RUN  10 , total integrated cost =  1.5830539018938414
# RUN  11 , total integrated cost =  1.7663864193081167
# RUN  12 , total integrated cost =  1.7237797839286622
# RUN  13 , total integrated cost =  1.7252225640407173
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  14 , total integrated cost =  1.7957640747112125
# RUN  15 , total integrated cost =  1.7824698051338657
# step size too small or too large
# RUN  16 , total integrated cost =  1.7781159863677138
# RUN  17 , total integrated cost =  1.6810911004493847
# RUN  18 , total integrated cost =  1.777611552366944
# RUN  19 , total integrated cost =  1.5845049331073622
# RUN  20 , total integrated cost =  1.5486906335165949
# RUN  21 , total integrated cost mean =  1.4762227877103697
# Improved over  21  iterations in  14.058859772980213  seconds by  99.75250977845366  percent.
# cost =  105.36800880025484
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1373.292455514817
# Gradient descend method:  None
# RUN  1 , total integrated cost =  69.92258117606619
# RUN  2 , total integrated cost =  50.05508540189791
# RUN  3 , total integrated cost =  6.061673186639832
# RUN  3 , total integrated cost mean =  6.061673186639832
# Improved over  3  iterations in  0.5253780130296946  seconds by  99.55860289173674  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  6.0018226805705925
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.406903654902101
# RUN  2 , total integrated cost =  3.0848381954187927
# RUN  3 , total integrated cost =  2.908151660808665
# RUN  4 , total integrated cost =  2.7879032880807997
# RUN  5 , total integrated cost =  2.776960446673149
# step size too small or too large
# step size too small or too large
# RUN  6 , total integrated cost =  2.8764116905169805
# RUN  7 , total integrated cost =  2.891120344216578
# RUN  8 , total integrated cost =  2.7612915650833143
# RUN  9 , total integrated cost =  2.6332720898664377
# RUN  10 , total integrated cost =  2.6552451313648358
# RUN  11 , total integrated cost =  2.5232869742287485
# RUN  12 , total integrated cost =  2.537097582172457
# RUN  13 , total integrated cost =  2.524462809609072
# RUN  14 , total integrated cost =  2.6790567525921762
# RUN  15 , total integrated cost =  2.5919188309883743
# RUN  16 , total integrated cost =  2.588788296059255
# RUN  17 , total integrated cost =  2.451236419795649
# RUN  18 , total integrated cost =  2.4006096098008634
# RUN  19 , total integrated cost =  2.4953418903558937
# RUN  20 , total integrated cost =  2.5083161963228617
# RUN  21 , total integrated cost mean =  2.5159871370478464
# Improved over  21  iterations in  9.031930417055264  seconds by  58.0796156275538  percent.
# rep_ind =  32.01657127104514
# n =  10
# iteration =  6
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1387.7441101396719
# Gradient descend method:  None
# RUN  1 , total integrated cost =  111.72896330684685
# step size too small or too large
# RUN  2 , total integrated cost =  10.363793092576639
# RUN  3 , total integrated cost =  3.10417624454641
# RUN  3 , total integrated cost mean =  3.10417624454641
# Improved over  3  iterations in  2.4240500659216195  seconds by  99.7763149400624  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.7737348047458696
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.940765815131251
# RUN  2 , total integrated cost =  1.8593635568651243
# RUN  3 , total integrated cost =  1.7956282649490998
# RUN  3 , total integrated cost mean =  1.7956282649490998
# Improved over  3  iterations in  6.307910450035706  seconds by  35.263159914322955  percent.
# cost =  11.08936029116024
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1382.0102683339444
# Gradient descend method:  None
# RUN  1 , total integrated cost =  147.8967892120511
# RUN  2 , total integrated cost =  39.72949399395536
# RUN  3 , total integrated cost =  48.28503610499957
# RUN  3 , total integrated cost mean =  48.28503610499957
# Improved over  3  iterations in  3.694409902091138  seconds by  96.50617385330945  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  26.116493314123392
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.038573582472051
# RUN  2 , total integrated cost =  2.163438790893522
# step size too small or too large
# RUN  3 , total integrated cost =  2.0993152847381484
# RUN  3 , total integrated cost mean =  2.0993152847381484
# Improved over  3  iterations in  8.46727748599369  seconds by  91.96172602696676  percent.
# rep_ind =  11.545463428048631
# iteration =  12
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1372.1378959840963
# Gradient descend method:  None
# RUN  1 , total integrated cost =  40.24554220973485
# RUN  2 , total integrated cost =  25.447191954487995
# RUN  3 , total integrated cost =  6.527165330504525
# RUN  3 , total integrated cost mean =  6.527165330504525
# Improved over  3  iterations in  2.106923319050111  seconds by  99.52430689731638  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  6.029430236949368
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.880630217353768
# RUN  2 , total integrated cost =  3.620327508755507
# RUN  3 , total integrated cost =  3.570425266629397
# RUN  4 , total integrated cost =  3.4954450529478516
# RUN  5 , total integrated cost =  3.4966015198145213
# RUN  6 , total integrated cost =  3.4814903535460204
# RUN  7 , total integrated cost =  3.365965480341129
# RUN  8 , total integrated cost =  3.3819736378678598
# step size too small or too large
# step size too small or too large
# RUN  9 , total integrated cost =  3.2305006606404105
# RUN  9 , total integrated cost mean =  3.2305006606404105
# Improved over  9  iterations in  15.549453706014901  seconds by  46.42112880180027  percent.
# cost =  3.2733502204931537
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1383.462726466382
# Gradient descend method:  None
# RUN  1 , total integrated cost =  75.60532983681804
# RUN  2 , total integrated cost =  16.642798553215567
# RUN  3 , total integrated cost =  5.084407082885538
# RUN  3 , total integrated cost mean =  5.084407082885538
# Improved over  3  iterations in  2.0382802420062944  seconds by  99.63248687618263  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5.144629046057077
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.246844949261598
# RUN  2 , total integrated cost =  3.9494587926833105
# step size too small or too large
# step size too small or too large
# RUN  3 , total integrated cost =  3.9243971910311375
# RUN  4 , total integrated cost =  3.8424392342650213
# RUN  5 , total integrated cost =  3.8224681658621407
# RUN  6 , total integrated cost =  3.7277293624925085
# RUN  7 , total integrated cost =  3.691985961428182
# RUN  8 , total integrated cost =  3.553575623202755
# RUN  9 , total integrated cost =  3.528885964391237
# RUN  9 , total integrated cost mean =  3.528885964391237
# Improved over  9  iterations in  15.018726094043814  seconds by  31.406405927443316  percent.
# rep_ind =  29.664742471693774
# iteration =  18
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1366.128301162336
# Gradient descend method:  None
# RUN  1 , total integrated cost =  66.07031645011797
# RUN  2 , total integrated cost =  18.084200726079494
# RUN  3 , total integrated cost =  3.2547111095767525
# RUN  3 , total integrated cost mean =  3.2547111095767525
# Improved over  3  iterations in  2.535662924987264  seconds by  99.7617565563346  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.4067332767628367
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.2980725246141196
# RUN  2 , total integrated cost =  2.1240833901668545
# RUN  3 , total integrated cost =  2.025762828265976
# step size too small or too large
# step size too small or too large
# RUN  4 , total integrated cost =  1.9381483074163899
# RUN  5 , total integrated cost =  1.9333822567768344
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  6 , total integrated cost =  1.8049619079612664
# RUN  7 , total integrated cost =  1.6867145332654865
# step size too small or too large
# RUN  8 , total integrated cost =  1.607260748882989
# RUN  9 , total integrated cost =  1.6275739122704103
# RUN  10 , total integrated cost =  1.557722861826662
# step size too small or too large
# step size too small or too large
# RUN  11 , total integrated cost =  1.5297635913393848
# RUN  12 , total integrated cost =  1.4829595594442355
# RUN  13 , total integrated cost =  1.3921910838700962
# RUN  14 , total integrated cost =  1.431104689638253
# RUN  15 , total integrated cost =  1.3352496109932068
# RUN  15 , total integrated cost mean =  1.3352496109932068
# Improved over  15  iterations in  25.669760831980966  seconds by  60.805572302919046  percent.
# cost =  10.172033120354678
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1380.900341704329
# Gradient descend method:  None
# RUN  1 , total integrated cost =  63.378035496929876
# RUN  2 , total integrated cost =  32.00452110780343
# RUN  3 , total integrated cost =  6.261904513737378
# RUN  3 , total integrated cost mean =  6.261904513737378
# Improved over  3  iterations in  2.2645247189793736  seconds by  99.54653465390494  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  6.104986925035139
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.21568549146377
# RUN  2 , total integrated cost =  2.741023691089518
# RUN  3 , total integrated cost =  2.65489652481252
# RUN  4 , total integrated cost =  2.594368326405097
# step size too small or too large
# step size too small or too large
# RUN  5 , total integrated cost =  2.4492564408870763
# RUN  6 , total integrated cost =  2.4081712621474005
# RUN  7 , total integrated cost =  2.36557196359367
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  8 , total integrated cost =  2.3572280211751107
# step size too small or too large
# step size too small or too large
# RUN  9 , total integrated cost =  2.256778151712568
# RUN  10 , total integrated cost =  2.209899043981489
# step size too small or too large
# step size too small or too large
# RUN  11 , total integrated cost =  2.2017777850421134
# RUN  12 , total integrated cost =  2.154753752643246
# RUN  13 , total integrated cost =  2.1250873201121734
# RUN  14 , total integrated cost =  2.0788335936058657
# RUN  15 , total integrated cost =  2.030262939396388
# RUN  15 , total integrated cost mean =  2.030262939396388
# Improved over  15  iterations in  27.276668841950595  seconds by  66.74418857359467  percent.
# rep_ind =  29.287329610746426
# iteration =  24
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1362.9069805200086
# Gradient descend method:  None
# RUN  1 , total integrated cost =  85.93623366948754
# RUN  2 , total integrated cost =  22.18606030312736
# RUN  3 , total integrated cost =  2.9412420709662777
# RUN  3 , total integrated cost mean =  2.9412420709662777
# Improved over  3  iterations in  2.687527159927413  seconds by  99.78419348400108  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.1417903483344785
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.075113378811359
# RUN  2 , total integrated cost =  1.803551085198869
# step size too small or too large
# step size too small or too large
# RUN  3 , total integrated cost =  1.8511807495800248
# RUN  4 , total integrated cost =  1.7946809750882857
# RUN  5 , total integrated cost =  1.7053252123983558
# step size too small or too large
# step size too small or too large
# RUN  6 , total integrated cost =  1.7642120166246378
# RUN  7 , total integrated cost =  1.6330742067296338
# step size too small or too large
# step size too small or too large
# RUN  8 , total integrated cost =  1.7005850353212497
# step size too small or too large
# RUN  9 , total integrated cost =  1.6218074407229863
# step size too small or too large
# RUN  10 , total integrated cost =  1.649198674855731
# RUN  11 , total integrated cost =  1.5743163705423164
# RUN  12 , total integrated cost =  1.6252305661171866
# RUN  13 , total integrated cost =  1.6243428169407426
# RUN  14 , total integrated cost =  1.6091589499631662
# RUN  15 , total integrated cost =  1.7176317084139598
# RUN  16 , total integrated cost =  1.6052464876953934
# RUN  17 , total integrated cost =  1.5037524242540155
# RUN  18 , total integrated cost =  2.1125660970335822
# no cost improvement
# RUN  19 , total integrated cost =  1.7546805439760167
# RUN  20 , total integrated cost =  1.5306844966732225
# RUN  20 , total integrated cost mean =  1.5306844966732225
# Improved over  20  iterations in  100.24493137688842  seconds by  51.27986507805441  percent.
# cost =  342.96267650408197
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1387.8148558595312
# Gradient descend method:  None
# RUN  1 , total integrated cost =  162.20615450739137
# RUN  2 , total integrated cost =  8.341597856169882
# RUN  3 , total integrated cost =  2.554503893285742
# RUN  3 , total integrated cost mean =  2.554503893285742
# Improved over  3  iterations in  2.384375949972309  seconds by  99.81593338027041  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.573444468797818
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.7866075278703328
# RUN  2 , total integrated cost =  1.7294322322737532
# RUN  3 , total integrated cost =  1.633144880538897
# RUN  4 , total integrated cost =  1.5892922608908717
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  5 , total integrated cost =  1.5478884677720315
# RUN  6 , total integrated cost =  1.5753239719004515
# RUN  7 , total integrated cost =  1.5441502502589757
# RUN  8 , total integrated cost =  1.6501927358946067
# RUN  9 , total integrated cost =  1.6617421350554777
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  10 , total integrated cost =  1.469872205671671
# RUN  11 , total integrated cost =  1.4191974130694671
# RUN  12 , total integrated cost =  1.4501107372066224
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  13 , total integrated cost =  1.3916912303931097
# step size too small or too large
# step size too small or too large
# RUN  14 , total integrated cost =  1.4641066996467913
# RUN  15 , total integrated cost =  1.3641777143854688
# RUN  16 , total integrated cost =  1.399704410042735
# RUN  17 , total integrated cost =  1.313426488209034
# RUN  18 , total integrated cost =  1.371373674508505
# RUN  19 , total integrated cost =  1.323669348243576
# RUN  20 , total integrated cost =  1.3905941420331451
# RUN  21 , total integrated cost mean =  1.320991898489225
# Improved over  21  iterations in  238.90021626802627  seconds by  48.66833481328917  percent.
# rep_ind =  19.11859760403649
# n =  30
# iteration =  6
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1379.1495623663504
# Gradient descend method:  None
# RUN  1 , total integrated cost =  64.59951283541629
# RUN  2 , total integrated cost =  27.00903618307847
# RUN  3 , total integrated cost =  4.4551991925990055
# RUN  3 , total integrated cost mean =  4.4551991925990055
# Improved over  3  iterations in  5.400082232081331  seconds by  99.67696040268797  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  4.444326873997874
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.7698766949622824
# step size too small or too large
# RUN  2 , total integrated cost =  2.476240905487317
# RUN  3 , total integrated cost =  2.3761595463129286
# RUN  3 , total integrated cost mean =  2.3761595463129286
# Improved over  3  iterations in  13.247664701077156  seconds by  46.53499587946678  percent.
# cost =  2.3779528987719383
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1377.399180597325
# Gradient descend method:  None
# RUN  1 , total integrated cost =  37.81475479146463
# RUN  2 , total integrated cost =  12.850848591916003
# RUN  3 , total integrated cost =  2.6473562145457463
# RUN  3 , total integrated cost mean =  2.6473562145457463
# Improved over  3  iterations in  7.686515648965724  seconds by  99.8078003637698  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.6216672319610805
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.9177429088767766
# RUN  2 , total integrated cost =  1.8527113647955389
# RUN  3 , total integrated cost =  1.7492112944342435
# RUN  3 , total integrated cost mean =  1.7492112944342435
# Improved over  3  iterations in  15.837170036975294  seconds by  33.278668127312855  percent.
# rep_ind =  26.7687563694813
# iteration =  12
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1378.103232883451
# Gradient descend method:  None
# RUN  1 , total integrated cost =  46.58005525605389
# RUN  2 , total integrated cost =  18.42879181228528
# RUN  3 , total integrated cost =  2.8626302737757023
# RUN  3 , total integrated cost mean =  2.8626302737757023
# Improved over  3  iterations in  7.143626459990628  seconds by  99.79227751553952  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.764676739678686
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.1378976857741776
# RUN  2 , total integrated cost =  2.0563527664587506
# step size too small or too large
# RUN  3 , total integrated cost =  1.9452333765510375
# RUN  4 , total integrated cost =  1.905434370071054
# RUN  5 , total integrated cost =  1.8244247074942246
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  6 , total integrated cost =  1.5977488467116536
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_371421/2894795037.py in <module>
#      59                 setinit(d['init_vars'], aln)
#      60
# ---> 61                 bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
#      62                     control_init, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_=it-init_it,
#      63                     tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
#
# ~/Promotion/neurolib_dev_optControl/neurolib/models/model.py in A1(self, control_, target_state_, c_scheme_, u_mat_, u_scheme_, max_iteration_, tolerance_, startStep_, max_control_, min_control_, t_sim_, t_sim_pre_, t_sim_post_, CGVar, line_search_, control_variables_, prec_variables_, separate_comp, transition_time_, noise_real, init_params, method, method_step, numerical)
#     690                                                     line_search_, control_variables_, prec_variables_, separate_comp, transition_time_)
#     691                         elif method == 'M4':
# --> 692                             return M4_noise.M4(self, noise_real, init_params, control_, target_state_, c_scheme_, u_mat_, u_scheme_, max_iteration_,
#     693                                                     tolerance_, startStep_, max_control_, min_control_, t_sim_, t_sim_pre_, t_sim_post_, method_step, CGVar,
#     694                                                     line_search_, control_variables_, prec_variables_, separate_comp, transition_time_)
#
# ~/Promotion/neurolib_dev_optControl/neurolib/utils/M4_noise.py in M4(model, noise_real, init_params, control_, target_state, c_scheme_, u_mat_, u_scheme_, max_iteration_, tolerance_, startStep_, cntrl_max_, cntrl_min_, t_sim_, t_sim_pre_, t_sim_post_, method_step, CGVar, line_search_, control_variables_, prec_variables_, separate_comp, transition_time_)
#     413         dir0_ = fo.set_direction(N, T, n_control_vars, grad0_, grad1_, dir0_, i, CGVar, tolerance_)
#     414
# --> 415         step_, dir0_, cost_ = fo.get_step_noise(line_search_func, model, N, n_control_vars, T, dt, noise_real, state0_, target_state_,
#     416                     best_control_, dir0_, ip_, ie_, is_, startstep_exc_, startstep_inh_, start_step_noise_, cntrl_max_,
#     417                     cntrl_min_, grad1_, total_cost_[:,i-1], init_vars_sim, startind_, prec_vars=prec_variables, control_vars=control_variables, separate_comp=True, noise_in_step_comp = noise_in_step_comp_)
#
# ~/Promotion/neurolib_dev_optControl/neurolib/utils/func_optimize.py in get_step_noise(line_search_func, model, N, n_control_vars, T, dt, noise_real, state0_, target_state_, best_control_, dir0_, ip_, ie_, is_, startstep_exc_, startstep_inh_, start_step_noise_, cntrl_max_, cntrl_min_, grad1_, cost_init, init_vars, startind, prec_vars, control_vars, separate_comp, noise_in_step_comp)
#     472
#     473             if noise_in_step_comp == False:
# --> 474                 s_exc, tc_exc, startstep_exc_ = step_noise_1(line_search_func, model, noise_real, N, n_control_vars, T, dt, state0_, target_state_,
#     475                             best_control_, d_exc, ip_, ie_, is_, cost_init, startstep_exc_,
#     476                             cntrl_max_, cntrl_min_, prec_vars, grad1_, init_vars, startind)
#
# ~/Promotion/neurolib_dev_optControl/neurolib/utils/func_optimize.py in step_noise_1(line_search_func, model, noise_real, N, n_control_vars, T, dt, state0_, target_state_, best_control_, d_, ip_, ie_, is_, cost_init, startstep_, cntrl_max_, cntrl_min_, prec_vars, grad1_, init_vars_, startind_)
#     390             #print("Noise step ", n_)
#     391
# --> 392             s_[n_], tc_[n_], ss_[n_] = line_search_func(model, N, n_control_vars, T, dt, state0_[n_][:,:2,:], target_state_,
#     393                                 best_control_, d_, ip_, ie_, is_, start_step_ = ss_[n_], max_it_ = 500,
#     394                                 max_control_ = cntrl_max_, min_control_ = cntrl_min_, variables_ = prec_vars, grad_ = grad1_, noise_real=0, init_vars=init_vars_[n_], startind_=startind_)
#
# ~/Promotion/neurolib_dev_optControl/neurolib/utils/func_optimize.py in step_size(model, N, V, T, dt, state_, target_, control_, dir_, ip_, ie_, is_, start_step_, max_it_, bisec_factor_, max_control_, min_control_, tolerance_, substep_, variables_, alg, control_parameter, grad_, noise_real, init_vars, startind_)
#     235                 #print(init_vars)
#     236                 set_init(model, init_vars, model.init_vars, model.state_vars, startind_)
# --> 237             state1_ = updateState(model, test_control_)
#     238             cost1_int_ = cost.f_int(N, V, T, dt, state1_, target_, test_control_, ip_, ie_, is_, v_ = variables_)
#     239         else:
#
# ~/Promotion/neurolib_dev_optControl/neurolib/utils/func_optimize.py in updateState(model, control_)
#       8     state_ = model.getZeroState()
#       9     output_vars = model.output_vars
# ---> 10     model.run(control = control_)
#      11     for i in range(len(output_vars)):
#      12         state_[:,i,:] = model[output_vars[i]][:,:]
#
# ~/Promotion/neurolib_dev_optControl/neurolib/models/model.py in run(self, inputs, chunkwise, chunksize, bold, append, append_outputs, continue_run, control)
#     188         if chunkwise is False:
#     189             if self.name == 'aln':
# --> 190                 self.integrate(append_outputs=append, simulate_bold=bold, control=cntrl)
#     191             else:
#     192                 self.integrate(append_outputs=append, simulate_bold=bold)
#
# ~/Promotion/neurolib_dev_optControl/neurolib/models/model.py in integrate(self, append_outputs, simulate_bold, control)
#     232         #print("before integration")
#     233         if self.name == 'aln':
# --> 234             t, *variables = self.integration(self.params, control=control)
#     235         else:
#     236             t, *variables = self.integration(self.params)
#
# ~/Promotion/neurolib_dev_optControl/neurolib/models/aln/timeIntegration.py in timeIntegration(params, control)
#     286     # ------------------------------------------------------------------------
#     287
# --> 288     return timeIntegration_njit_elementwise(
#     289         dt,
#     290         duration,
#
# KeyboardInterrupt:

# %%
#len(sigma_array), 4, N_max, max_it

##### METHOD 3
method_ind = 2
step_method_ind = 1
step_m = 'S1'
if step_method_ind == 1:
    step_m = 'S2'

for d in dict_list:
    print("Point = ", d['point'])
    aln.params.ext_exc_current = d['point'][0] * 5.
    aln.params.ext_inh_current = d['point'][1] * 5.
    
    max_it = d['cost'].shape[3]
    
    for s_ind in range(len(d['sigma'])):
        
        print("sigma = ", d['sigma'][s_ind])
        
        s = d['sigma'][s_ind]
        aln.params.sigma_ou = s
        c_p = d['cost_params'][s_ind]
        cost.setParams(c_p[0], c_p[1], c_p[2])
        
        target_ = d['target'][s_ind].copy()
        target_[0,0,:int(trans_time * dur / aln.params.dt)] = -1000
        target_[0,1,:int(trans_time * dur / aln.params.dt)] = -1000
                
        for n_ind in range(len(d['N_array'])):
            
            n_ = d['N_array'][n_ind]
            
            print("n = ", n_)
            aln.params.duration = dur
        
            for i_it in range(1,len(d['it_array'])):
            
                it = d['it_array'][i_it]
                print("iteration = ", it)
                
                if ( d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it] > 0.
                    and d['rep_ind'][s_ind, method_ind, step_method_ind, n_ind, i_it] > 0. ) :
                    continue
                
                c_vars = d['init']
                aln.params.duration = dur
                setinit(d['init_vars'], aln)
                control_init = aln.getZeroControl()
                    
                
                bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                    control_init, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_ = init_it,
                    tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                    t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                    control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                    noise_real=n_, init_params = d['init_vars'], method='M3', method_step=step_m)
            
                control_init = bc[:,:,100:-100]
                c_vars = [0,1]
                aln.params.duration = dur
                setinit(d['init_vars'], aln)
                
                bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                    control_init, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_=it-init_it,
                    tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                    t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                    control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                    noise_real=n_, init_params = d['init_vars'], method='M3', method_step=step_m)

                control_init = bc[:,:,100:-100]
                aln.params.duration = dur
                setinit(d['init_vars'], aln)
                cost_final = 0.
                cs = cost.numba_cost_sparsity_int(1, 6, T, d['cost_params'][s_ind][2], dt, control_init)

                for j in range(noise_realizations_final):
                    state_ = fo.updateState(aln, control_init)
                    cost_final += cost.numba_cost_precision_int(1, T, dt, d['cost_params'][s_ind][0],
                                                                   state_, target_, list(prec_vars) )

                d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it] = (
                                cost_final / noise_realizations_final + cs )
                print('cost = ', d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it])
                
                c_vars = d['init']                    
                aln.params.duration = dur
                control_init1 = aln.getZeroControl()
                setinit(d['init_vars'], aln)
                
                bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                    control_init1, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_ = init_it,
                    tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                    t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                    control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                    noise_real=n_, init_params = d['init_vars'], method='M3', method_step=step_m)
            
                control_init1 = bc[:,:,100:-100]
                c_vars = [0,1]
                aln.params.duration = dur
                setinit(d['init_vars'], aln)
                
                bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                    control_init1, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_=it-init_it,
                    tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                    t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                    control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                    noise_real=n_, init_params = d['init_vars'], method='M3', method_step=step_m)

                control_init1 = bc[:,:,100:-100]
                d['rep_ind'][s_ind, method_ind, step_method_ind, n_ind, i_it] = rep_ind(control_init, control_init1)
                print('rep_ind = ', d['rep_ind'][s_ind, method_ind, step_method_ind, n_ind, i_it])
                
                file=open(dict_file, "wb")
                pickle.dump(dict_list, file)
                file.close()
                
    break
# Out:
# Point =  [0.4   0.322]
# sigma =  0.01
# set cost params:  0.005531732932180352 0.0 1.0
# n =  2
# iteration =  6
# iteration =  12
# iteration =  18
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1361.2823013139632
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22.232219047513794
# RUN  2 , total integrated cost =  20.028228437795
# RUN  3 , total integrated cost =  3.7293661983064235
# RUN  3 , total integrated cost mean =  3.7293661983064235
# Improved over  3  iterations in  16.534322593011893  seconds by  99.72604020527508  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.3208585478839563
# Gradient descend method:  None
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_371421/1073042887.py in <module>
#      62                 setinit(d['init_vars'], aln)
#      63
# ---> 64                 bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
#      65                     control_init, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_=it-init_it,
#      66                     tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
#
# ~/Promotion/neurolib_dev_optControl/neurolib/models/model.py in A1(self, control_, target_state_, c_scheme_, u_mat_, u_scheme_, max_iteration_, tolerance_, startStep_, max_control_, min_control_, t_sim_, t_sim_pre_, t_sim_post_, CGVar, line_search_, control_variables_, prec_variables_, separate_comp, transition_time_, noise_real, init_params, method, method_step, numerical)
#     686                                                     line_search_, control_variables_, prec_variables_, separate_comp, transition_time_)
#     687                         elif method == 'M3':
# --> 688                             return M3_noise.M3(self, noise_real, init_params, control_, target_state_, c_scheme_, u_mat_, u_scheme_, max_iteration_,
#     689                                                     tolerance_, startStep_, max_control_, min_control_, t_sim_, t_sim_pre_, t_sim_post_, method_step, CGVar,
#     690                                                     line_search_, control_variables_, prec_variables_, separate_comp, transition_time_)
#
# ~/Promotion/neurolib_dev_optControl/neurolib/utils/M3_noise.py in M3(model, noise_real, init_params, control_, target_state, c_scheme_, u_mat_, u_scheme_, max_iteration_, tolerance_, startStep_, cntrl_max_, cntrl_min_, t_sim_, t_sim_pre_, t_sim_post_, method_step, CGVar, line_search_, control_variables_, prec_variables_, separate_comp, transition_time_)
#     426         dir0_ = fo.set_direction(N, T, n_control_vars, grad0_, grad1_, dir0_, i, CGVar, tolerance_)
#     427
# --> 428         step_, dir0_, cost_ = fo.get_step_noise(line_search_func, model, N, n_control_vars, T, dt, noise_real, state0_, target_state_,
#     429                     best_control_, dir0_, ip_, ie_, is_, startstep_exc_, startstep_inh_, start_step_noise_, cntrl_max_,
#     430                     cntrl_min_, grad1_, total_cost_[:,i-1], init_vars_sim, startind_, prec_vars=prec_variables, control_vars=control_variables, separate_comp=True, noise_in_step_comp = False)
#
# ~/Promotion/neurolib_dev_optControl/neurolib/utils/func_optimize.py in get_step_noise(line_search_func, model, N, n_control_vars, T, dt, noise_real, state0_, target_state_, best_control_, dir0_, ip_, ie_, is_, startstep_exc_, startstep_inh_, start_step_noise_, cntrl_max_, cntrl_min_, grad1_, cost_init, init_vars, startind, prec_vars, control_vars, separate_comp, noise_in_step_comp)
#     472
#     473             if noise_in_step_comp == False:
# --> 474                 s_exc, tc_exc, startstep_exc_ = step_noise_1(line_search_func, model, noise_real, N, n_control_vars, T, dt, state0_, target_state_,
#     475                             best_control_, d_exc, ip_, ie_, is_, cost_init, startstep_exc_,
#     476                             cntrl_max_, cntrl_min_, prec_vars, grad1_, init_vars, startind)
#
# ~/Promotion/neurolib_dev_optControl/neurolib/utils/func_optimize.py in step_noise_1(line_search_func, model, noise_real, N, n_control_vars, T, dt, state0_, target_state_, best_control_, d_, ip_, ie_, is_, cost_init, startstep_, cntrl_max_, cntrl_min_, prec_vars, grad1_, init_vars_, startind_)
#     390             #print("Noise step ", n_)
#     391
# --> 392             s_[n_], tc_[n_], ss_[n_] = line_search_func(model, N, n_control_vars, T, dt, state0_[n_][:,:2,:], target_state_,
#     393                                 best_control_, d_, ip_, ie_, is_, start_step_ = ss_[n_], max_it_ = 500,
#     394                                 max_control_ = cntrl_max_, min_control_ = cntrl_min_, variables_ = prec_vars, grad_ = grad1_, noise_real=0, init_vars=init_vars_[n_], startind_=startind_)
#
# ~/Promotion/neurolib_dev_optControl/neurolib/utils/func_optimize.py in step_size(model, N, V, T, dt, state_, target_, control_, dir_, ip_, ie_, is_, start_step_, max_it_, bisec_factor_, max_control_, min_control_, tolerance_, substep_, variables_, alg, control_parameter, grad_, noise_real, init_vars, startind_)
#     236                 set_init(model, init_vars, model.init_vars, model.state_vars, startind_)
#     237             state1_ = updateState(model, test_control_)
# --> 238             cost1_int_ = cost.f_int(N, V, T, dt, state1_, target_, test_control_, ip_, ie_, is_, v_ = variables_)
#     239         else:
#     240             cost1_int_ = 0.
#
# ~/Promotion/neurolib_dev_optControl/neurolib/utils/costFunctions.py in f_int(N, V, T, dt, state_, target_, control_, i_p, i_e, i_s, v_)
#     300
#     301     if not i_p < 1e-12:
# --> 302         cost_prec = cost_precision_int(N, T, dt, i_p, state_, target_, va_ = var)
#     303     if not i_e < 1e-12:
#     304         cost_energy = cost_energy_int(N, V, T, dt, i_e, control_)
#
# ~/Promotion/neurolib_dev_optControl/neurolib/utils/costFunctions.py in cost_precision_int(N, T, dt, i_p, state_, target_, va_)
#      72 def cost_precision_int(N, T, dt, i_p, state_, target_, va_):
#      73     if N == 1:
# ---> 74         return numba_cost_precision_int(N, T, dt, i_p, state_, target_, var_ = va_ )
#      75     else:
#      76         return numba_cost_precision_int_network(N, T, dt, i_p, state_, target_, var_ = va_ )
#
# ~/Promotion/neurolib_dev_optControl/neurolib/utils/costFunctions.py in numba_cost_precision_int(N, T, dt, i_p, state_, target_state_, var_)
#      83         for ind_node in range(N):
#      84             for ind_var in var_:
# ---> 85                 diff = np.abs(state_[ind_node, ind_var, ind_time] - target_state_[ind_node, ind_var, ind_time])
#      86                 if target_state_[ind_node, ind_var, ind_time] == -1000:
#      87                     cost += 0.
#
# KeyboardInterrupt:

# %%
#len(sigma_array), 4, N_max, max_it

##### METHOD 3
method_ind = 3
step_method_ind = 1
step_m = 'S1'
if step_method_ind == 1:
    step_m = 'S2'

for d in dict_list:
    print("Point = ", d['point'])
    aln.params.ext_exc_current = d['point'][0] * 5.
    aln.params.ext_inh_current = d['point'][1] * 5.
    
    max_it = d['cost'].shape[3]
    
    for s_ind in range(len(d['sigma'])):

        print("sigma = ", d['sigma'][s_ind])
        
        s = d['sigma'][s_ind]
        aln.params.sigma_ou = s
        c_p = d['cost_params'][s_ind]
        cost.setParams(c_p[0], c_p[1], c_p[2])
        
        target_ = d['target'][s_ind].copy()
        target_[0,0,:int(trans_time * dur / aln.params.dt)] = -1000
        target_[0,1,:int(trans_time * dur / aln.params.dt)] = -1000
                
        for n_ind in range(len(d['N_array'])):
            
            n_ = d['N_array'][n_ind]
            
            print("n = ", n_)
            aln.params.duration = dur
        
            for i_it in range(1,len(d['it_array'])):
            
                it = d['it_array'][i_it]
                print("iteration = ", it)
                
                if ( d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it] > 0.
                    and d['rep_ind'][s_ind, method_ind, step_method_ind, n_ind, i_it] > 0. ) :
                    continue
                
                c_vars = d['init']
                aln.params.duration = dur
                setinit(d['init_vars'], aln)
                control_init = aln.getZeroControl()
                    
                
                bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                    control_init, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_ = init_it,
                    tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                    t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                    control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                    noise_real=n_, init_params = d['init_vars'], method='M4', method_step=step_m)
            
                control_init = bc[:,:,100:-100]
                c_vars = [0,1]
                aln.params.duration = dur
                setinit(d['init_vars'], aln)
                
                bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                    control_init, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_=it-init_it,
                    tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                    t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                    control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                    noise_real=n_, init_params = d['init_vars'], method='M4', method_step=step_m)

                control_init = bc[:,:,100:-100]
                aln.params.duration = dur
                setinit(d['init_vars'], aln)
                cost_final = 0.
                cs = cost.numba_cost_sparsity_int(1, 6, T, d['cost_params'][s_ind][2], dt, control_init)

                for j in range(noise_realizations_final):
                    state_ = fo.updateState(aln, control_init)
                    cost_final += cost.numba_cost_precision_int(1, T, dt, d['cost_params'][s_ind][0],
                                                                   state_, target_, list(prec_vars) )

                d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it] = (
                                cost_final / noise_realizations_final + cs )
                print('cost = ', d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it])
                
                c_vars = d['init']                    
                aln.params.duration = dur
                control_init1 = aln.getZeroControl()
                setinit(d['init_vars'], aln)
                
                bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                    control_init1, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_ = init_it,
                    tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                    t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                    control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                    noise_real=n_, init_params = d['init_vars'], method='M4', method_step=step_m)
            
                control_init1 = bc[:,:,100:-100]
                c_vars = [0,1]
                aln.params.duration = dur
                setinit(d['init_vars'], aln)
                
                bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                    control_init1, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_=it-init_it,
                    tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                    t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                    control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                    noise_real=n_, init_params = d['init_vars'], method='M4', method_step=step_m)

                control_init1 = bc[:,:,100:-100]
                d['rep_ind'][s_ind, method_ind, step_method_ind, n_ind, i_it] = rep_ind(control_init, control_init1)
                print('rep_ind = ', d['rep_ind'][s_ind, method_ind, step_method_ind, n_ind, i_it])
                
                file=open(dict_file, "wb")
                pickle.dump(dict_list, file)
                file.close()
                
    break
# Out:
# Point =  [0.4   0.322]
# sigma =  0.01
# set cost params:  0.005531732932180352 0.0 1.0
# n =  2
# iteration =  6
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1331.3708555529129
# Gradient descend method:  None
# RUN  1 , total integrated cost =  63.347012032763075
# RUN  2 , total integrated cost =  11.710423264809485
# RUN  3 , total integrated cost =  6.155706621248046
# RUN  3 , total integrated cost mean =  6.155706621248046
# Improved over  3  iterations in  11.134747543022968  seconds by  99.53764147716065  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.725899958738537
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.065928734392399
# RUN  2 , total integrated cost =  4.026722073459791
# RUN  3 , total integrated cost =  4.399332683724202
# RUN  3 , total integrated cost mean =  4.399332683724202
# Improved over  3  iterations in  24.15765842201654  seconds by  -61.390100528857204  percent.
