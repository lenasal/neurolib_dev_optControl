# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import sys
import pickle
import matplotlib
import ipyparams

path = os.getcwd().split(os.sep + 'GUI')[0]
if path not in sys.path:
    print("not here")
    sys.path.append(path)

from neurolib.models.aln import ALNModel
from neurolib.utils import plotFunctions as plotFunc
from neurolib.utils import func_optimize as fo
from neurolib.utils import costFunctions as cost
import neurolib.dashboard.functions as functions
import neurolib.dashboard.data as data
import neurolib.dashboard.layout as layout
    
# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2 

#path = os.path.join(os.getcwd(), "plots")

cmap_ = layout.getcolormap()
darkgrey, midgrey, lightgrey, color_bi_updown, color_LC, color_bi_uposc = layout.getcolors_rgba()
exc_red = cmap_(3)
inh_blue=cmap_(0)
green = cmap_(2)
# Out:
# not here

# %%
aln = ALNModel()
N = aln.params.N

aln.params.sigma_ou = 0.
aln.params.mue_ext_mean = 0.
aln.params.mui_ext_mean = 0.
aln.params.ext_exc_current = 0.
aln.params.ext_inh_current = 0.

state_vars = aln.state_vars
init_vars = aln.init_vars

##############################################################
def setinit(init_vars_, model):
    state_vars = model.state_vars
    init_vars = model.init_vars
    for iv in range(len(init_vars)):
        for sv in range(len(state_vars)):
            if state_vars[sv] in init_vars[iv]:
                #print("set init vars ", )
                if model.params[init_vars[iv]].ndim == 2:
                    model.params[init_vars[iv]][0,:] = init_vars_[sv]
                else:
                    model.params[init_vars[iv]][0] = init_vars_[sv]
                    
##############################################################               
def setmaxmincontrol(max_c_c, min_c_c, max_c_r, min_c_r):
    import numpy as np
    
    max_cntrl = np.zeros(( 6 ))
    min_cntrl = np.zeros(( 6 ))
    
    max_cntrl[0] = max_c_c
    min_cntrl[0] = min_c_c
    max_cntrl[1] = max_c_c
    min_cntrl[1] = min_c_c
    max_cntrl[2] = max_c_r
    min_cntrl[2] = min_c_r
    max_cntrl[3] = max_c_r
    min_cntrl[3] = min_c_r
    max_cntrl[4] = max_c_r
    min_cntrl[4] = min_c_r
    max_cntrl[5] = max_c_r
    min_cntrl[5] = min_c_r
            
    return max_cntrl, min_cntrl

def rep_ind(c0, c1):
    abs_diff = np.abs(c0-c1)
    res = 0.
    for n in range(c0.shape[0]):
        for v in range(c0.shape[1]):
            res += sum(abs_diff[n,v,:]) * dt
            
    return res

# %%
points = np.array( [ [0.74, 0.37] ])

# 10 points, two costs, 4 methods, N

# %%
def create_dict(task, point, cost_params, init, init_vars, target, sigma_array, N_max_array, it_array):
    return dict( {'task':task, 'point':point, 'cost_params':cost_params, 'init':init, 'init_vars':init_vars,
            'target':target, 'sigma':sigma_array, 'N_array':N_max_array, 'it_array':it_array,
            'cost':np.zeros(( len(sigma_array), 4, 2, len(N_max_array), len(it_array) )),
            'rep_ind':np.zeros(( len(sigma_array), 4, 2, len(N_max_array), len(it_array) ))     } )

params_list = ['task', 'point', 'cost_params', 'init', 'init_vars', 'target', 'sigma', 'N_array',
               'cost', 'rep_ind']

# %%
dict_list = []
sigma_array = np.arange(0.01, 0.081, 0.02)
N_array = [2,10,30,50]
it_array = np.arange(0,25,6)

for p in points:
    dict_list.append(create_dict('DU', p, [None]*len(sigma_array), [1], None,
                [None]*len(sigma_array), sigma_array, N_array, it_array) )

# %%
for d in dict_list:
    print(d['target'])
# Out:
# [None, None, None, None]

# %%
dict_file = "DU_1I.pickle"

if False:
    file=open(dict_file, "wb")
    pickle.dump(dict_list, file)
    file.close()

if True:
    file = open(dict_file, "rb")
    dict_list = pickle.load(file)
    file.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_492051/991823539.py in <module>
#       7
#       8 if True:
# ----> 9     file = open(dict_file, "rb")
#      10     dict_list = pickle.load(file)
#      11     file.close()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'DU_1I.pickle'

# %%
dur_pre = 10
dur_post = 10
dur = 500.
dur_comp = 2000.
dt = aln.params.dt
T = int(1 + dur / dt)

prec_vars = [0,1]
trans_time = 0.6

n_pre = int(np.around(dur_pre/aln.params.dt,1))
n_post = int(np.around(dur_post/aln.params.dt,1))

tol = 1e-16
start_step = 10.
c_scheme = np.zeros(( 1,1 ))
c_scheme[0,0] = 1.
u_mat = np.identity(1)
u_scheme = np.array([[1.]])

maxC = [5., -5., 0.18, 0.]
n_dur = int(np.around(dur/aln.params.dt + 1.,1))
max_cntrl, min_cntrl = setmaxmincontrol(maxC[0], maxC[1], maxC[2], maxC[3])

noise_realizations_final = 10000
dur_target_compute = 100000
init_it = 3

# %%
# get init vars without noise
aln.params.duration = dur_comp

# initial without noise
control0 = aln.getZeroControl()

for d in dict_list:
    
    print("Point = ", d['point'])
    aln.params.ext_exc_current = d['point'][0] * 5.
    aln.params.ext_inh_current = d['point'][1] * 5.
    aln.params.duration = dur_comp
    
    control0[0,0,:500] = -5.

    aln.run(control=control0)

    plt.plot(aln.t, aln.rates_exc[0,:])
    plt.show() 

    init_state_vars = np.zeros(( len(state_vars) ))
    for j in range(len(state_vars)):
        if aln.state[state_vars[j]].size == 1:
            init_state_vars[j] = aln.state[state_vars[j]][0]
        else:
            init_state_vars[j] = aln.state[state_vars[j]][0,-1]

    initVars = init_state_vars.copy()
    d['init_vars'] = initVars
# Out:
# Point =  [0.74 0.37]

# %%
for d in dict_list:
    
    print("Point = ", d['point'])
    aln.params.ext_exc_current = d['point'][0] * 5.
    aln.params.ext_inh_current = d['point'][1] * 5.
        
    aln.params.sigma_ou = 0.15
    aln.params.duration = dur_target_compute

    setinit(d['init_vars'], aln)

    target_rates_e = []
    target_rates_i = []

    aln.run(control=aln.getZeroControl())
    for t in range(len(aln.t)):
        if aln.rates_exc[0,t] < 10.:
            continue
        if aln.rates_inh[0,t] < 50.:
            continue

        target_rates_e.append(aln.rates_exc[0,t])
        target_rates_i.append(aln.rates_inh[0,t])

    plt.plot(aln.t, aln.rates_exc[0,:])
    plt.show()            

    aln.params.duration = dur
    target = aln.getZeroTarget()
    target[:,0,:] = np.mean(target_rates_e)
    target[:,1,:] = np.mean(target_rates_i)
    stddev = np.std(target_rates_e) + np.std(target_rates_i)
        
    for ind_s in range(len(d['sigma'])): 
        
        d['target'][ind_s] = target
        d['cost_params'][ind_s] = [1. / ( stddev * (1. - trans_time) * dur ), 0., 1.]
        
        
    print(d['target'][0][0,:,-1])
    print(d['cost_params'][0][0])
        
    file=open(dict_file, "wb")
    pickle.dump(dict_list, file)
    file.close()
# Out:
# Point =  [0.74 0.37]
# [23.192105   69.93081136]
# 0.0002954157700293939

# %%
#len(sigma_array), 4, N_max, max_it

##### METHOD 1
method_ind = 0
step_method_ind = 0

for d in dict_list:
        
        
    print("Point = ", d['point'])
    aln.params.ext_exc_current = d['point'][0] * 5.
    aln.params.ext_inh_current = d['point'][1] * 5.
    
    max_it = d['cost'].shape[3]
    
    for s_ind in range(len(d['sigma'])):
        
        print("sigma = ", d['sigma'][s_ind])
        
        s = d['sigma'][s_ind]
        aln.params.sigma_ou = s
        c_p = d['cost_params'][s_ind]
        cost.setParams(c_p[0], c_p[1], c_p[2])
        aln.params.duration = dur
        zero_init = aln.getZeroControl()
        
        target_ = d['target'][s_ind].copy()
        target_[0,0,:int(trans_time * dur / aln.params.dt)] = -1000
        target_[0,1,:int(trans_time * dur / aln.params.dt)] = -1000
        
        if np.amin(d['cost'][s_ind, method_ind, step_method_ind, :, 0]) == 0.:
        
            setinit(d['init_vars'], aln)
            cost_final = 0.

            for n_ in range(noise_realizations_final):
                state_ = fo.updateState(aln, zero_init)
                cost_final += cost.numba_cost_precision_int(1, T, dt, d['cost_params'][s_ind][0],
                                                               state_, target_, list(prec_vars) )

            d['cost'][s_ind, :, :, :, 0] = cost_final/noise_realizations_final
            
        print('cost = ', d['cost'][s_ind, 0, 0, 0])    
        
        for i_it in range(1,len(d['it_array'])):
            
            it = d['it_array'][i_it]
            print("iteration = ", it)
        
            for n_ind in range(len(d['N_array'])):

                if ( d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it] > 0.
                    and d['rep_ind'][s_ind, method_ind, step_method_ind, n_ind, i_it] > 0. ) :
                    continue
                    
                n_max = d['N_array'][n_ind]
                print("n max = ", n_max)

                aln.params.duration = dur
                     
                    
                n_ = 0
                control_sum = aln.getZeroControl()
                
                while n_ < n_max:
                
                    print('--------', n_)

                    aln.params.duration = dur
                    control_init = aln.getZeroControl()               
                    setinit(d['init_vars'], aln)
                    
                    c_vars = d['init']

                    bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                        control_init, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_ = init_it,
                        tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                        t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                        control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                        noise_real=0, init_params = d['init_vars'])
                    
                    if np.isnan(c_).any():
                        continue
                    
                    control_init = bc[:,:,n_pre:-n_post]
                    c_vars = [0,1]
                    aln.params.duration = dur
                    setinit(d['init_vars'], aln)
                    
                    bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                        control_init, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_ = it-init_it,
                        tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                        t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                        control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                        noise_real=0, init_params = d['init_vars'])
                    
                    if np.isnan(c_).any():
                        continue
                    
                    control_sum += bc[:,:,n_pre:-n_post]
                    n_ += 1

                control_init = control_sum / n_max
        
                aln.params.duration = dur
                setinit(d['init_vars'], aln)

                cost_final = 0.

                for j in range(noise_realizations_final):
                    state_ = fo.updateState(aln, control_init)
                    cost_final += cost.numba_cost_precision_int(1, T, dt, d['cost_params'][s_ind][0],
                                                                   state_, target_, list(prec_vars) )
                    cost_final += cost.numba_cost_sparsity_int(1, 6, T, d['cost_params'][s_ind][2],
                                                                   dt, control_init)

                d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it] = cost_final/noise_realizations_final
                print('cost = ', d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it])
                
                ###############################################################
                
                aln.params.duration = dur
                setinit(d['init_vars'], aln)
                     
                    
                n_ = 0
                control_sum = aln.getZeroControl()
                
                while n_ < n_max:
                
                    print('--------', n_)

                    aln.params.duration = dur
                    control_init1 = aln.getZeroControl()               
                    setinit(d['init_vars'], aln)
                    
                    c_vars = d['init']

                    bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                        control_init1, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_ = init_it,
                        tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                        t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                        control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                        noise_real=0, init_params = d['init_vars'])
                    
                    if np.isnan(c_).any():
                        continue
                    
                    control_init1 = bc[:,:,n_pre:-n_post]
                    c_vars = [0,1]
                    aln.params.duration = dur
                    setinit(d['init_vars'], aln)
                    
                    bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                        control_init1, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_ = it-init_it,
                        tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                        t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                        control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                        noise_real=0, init_params = d['init_vars'])
                    
                    if np.isnan(c_).any():
                        continue
                    
                    control_sum += bc[:,:,n_pre:-n_post]
                    n_ += 1

                control_init1 = control_sum / n_max
                
                d['rep_ind'][s_ind, method_ind, step_method_ind, n_ind, i_it] = rep_ind(control_init, control_init1)
                print('rep_ind = ', d['rep_ind'][s_ind, method_ind, step_method_ind, n_ind, i_it])
                
                file=open(dict_file, "wb")
                pickle.dump(dict_list, file)
                file.close()
# Out:
# Point =  [0.74 0.37]
# sigma =  0.01
# set cost params:  0.0002954157700293939 0.0 1.0
# /home/lena/.local/lib/python3.9/site-packages/numba/core/ir_utils.py:2119: NumbaPendingDeprecationWarning:
# Encountered the use of a type that is scheduled for deprecation: type 'reflected list' found for argument 'var_' of function 'numba_cost_precision_int'.
#
# For more information visit https://numba.pydata.org/numba-doc/latest/reference/deprecation.html#deprecation-of-reflection-for-list-and-set-types
#
# File "../../../../../../neurolib/utils/costFunctions.py", line 79:
# @numba.njit
# def numba_cost_precision_int(N, T, dt, i_p, state_, target_state_, var_):
# ^
#
#   warnings.warn(NumbaPendingDeprecationWarning(msg, loc=loc))
# cost =  [97.94427958  0.          0.          0.          0.        ]
# iteration =  6
# n max =  2
# -------- 0
# interpolate adjoint :  True True True
# initial cost =  98.43816714805233
# RUN  0 , total integrated cost =  98.43816714805233
# Gradient descend method:  None
# RUN  1 , total integrated cost =  34.2889774524528
# RUN  2 , total integrated cost =  42.46822219293458
# RUN  3 , total integrated cost =  64.22769567897046
# RUN  3 , total integrated cost =  64.22769567897046
# Improved over  3  iterations in  21.794130679103546  seconds by  34.75325928979241  percent.
# interpolate adjoint :  True True True
# initial cost =  65.81211683093925
# RUN  0 , total integrated cost =  65.81211683093925
# Gradient descend method:  None
# RUN  1 , total integrated cost =  61.962913268398935
# RUN  2 , total integrated cost =  42.6379392369469
# RUN  3 , total integrated cost =  33.526993995755305
# RUN  3 , total integrated cost =  33.526993995755305
# Improved over  3  iterations in  1.0990747150499374  seconds by  49.05650264695062  percent.
# -------- 1
# interpolate adjoint :  True True True
# initial cost =  98.10324412027083
# RUN  0 , total integrated cost =  98.10324412027083
# Gradient descend method:  None
# RUN  1 , total integrated cost =  43.84367852029331
# RUN  2 , total integrated cost =  36.44984245209797
# RUN  3 , total integrated cost =  34.02754860823649
# RUN  3 , total integrated cost =  34.02754860823649
# Improved over  3  iterations in  0.41870043508242816  seconds by  65.31455313901748  percent.
# interpolate adjoint :  True True True
# initial cost =  34.735934059092834
# RUN  0 , total integrated cost =  34.735934059092834
# Gradient descend method:  None
# RUN  1 , total integrated cost =  29.262723682999408

# %%
#len(sigma_array), 4, N_max, max_it

##### METHOD 2
method_ind = 1
step_method_ind = 0

for d in dict_list:
    
    if d['point'][0] != 0.5:
        continue
    if d['point'][1] != 0.5:
        continue
        
    print("Point = ", d['point'])
    aln.params.ext_exc_current = d['point'][0] * 5.
    aln.params.ext_inh_current = d['point'][1] * 5.
    
    max_it = d['cost'].shape[3]
    
    for s_ind in range(len(d['sigma'])):
        
        print("sigma = ", d['sigma'][s_ind])
        
        s = d['sigma'][s_ind]
        aln.params.sigma_ou = s
        c_p = d['cost_params'][s_ind]
        cost.setParams(c_p[0], c_p[1], c_p[2])
        
        target_ = d['target'][s_ind].copy()
        target_[0,0,:int(trans_time * dur / aln.params.dt)] = -1000
        target_[0,1,:int(trans_time * dur / aln.params.dt)] = -1000
                
        for n_ind in range(len(d['N_array'])):
            
            n_ = d['N_array'][n_ind]
            
            print("n = ", n_)
            aln.params.duration = dur
        
            for i_it in range(1,len(d['it_array'])):
            
                it = d['it_array'][i_it]
                print("iteration = ", it)
                
                if ( d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it] > 0.
                    and d['rep_ind'][s_ind, method_ind, step_method_ind, n_ind, i_it] > 0. ) :
                    continue
                
                c_vars = d['init']
                aln.params.duration = dur
                setinit(d['init_vars'], aln)
                control_init = aln.getZeroControl()
                    
                
                bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                    control_init, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_ = init_it,
                    tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                    t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                    control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                    noise_real=n_, init_params = d['init_vars'], method='M2')
            
                control_init = bc[:,:,100:-100]
                c_vars = [0,1]
                aln.params.duration = dur
                setinit(d['init_vars'], aln)
                
                bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                    control_init, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_=it-init_it,
                    tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                    t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                    control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                    noise_real=n_, init_params = d['init_vars'], method='M2')

                control_init = bc[:,:,100:-100]
                aln.params.duration = dur
                setinit(d['init_vars'], aln)
                cost_final = 0.
                cs = cost.numba_cost_sparsity_int(1, 6, T, d['cost_params'][s_ind][2], dt, control_init)

                for j in range(noise_realizations_final):
                    state_ = fo.updateState(aln, control_init)
                    cost_final += cost.numba_cost_precision_int(1, T, dt, d['cost_params'][s_ind][0],
                                                                   state_, target_, list(prec_vars) )

                d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it] = (
                                cost_final / noise_realizations_final + cs )
                print('cost = ', d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it])
                
                c_vars = d['init']                    
                aln.params.duration = dur
                control_init1 = aln.getZeroControl()
                setinit(d['init_vars'], aln)
                
                bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                    control_init1, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_ = init_it,
                    tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                    t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                    control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                    noise_real=n_, init_params = d['init_vars'], method='M2')
            
                control_init1 = bc[:,:,100:-100]
                c_vars = [0,1]
                aln.params.duration = dur
                setinit(d['init_vars'], aln)
                
                bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                    control_init1, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_=it-init_it,
                    tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                    t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                    control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                    noise_real=n_, init_params = d['init_vars'], method='M2')

                control_init1 = bc[:,:,100:-100]
                d['rep_ind'][s_ind, method_ind, step_method_ind, n_ind, i_it] = rep_ind(control_init, control_init1)
                print('rep_ind = ', d['rep_ind'][s_ind, method_ind, step_method_ind, n_ind, i_it])
                
                file=open(dict_file, "wb")
                pickle.dump(dict_list, file)
                file.close()
                
    break
# Out:
# Point =  [0.5 0.5]
# sigma =  0.01
# set cost params:  0.026458600489613113 0.0 1.0
# n =  2
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24
# n =  10
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24
# n =  30
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24
# n =  50
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3684.031047163612
# Gradient descend method:  None
# RUN  1 , total integrated cost =  157.09574190890905
# RUN  2 , total integrated cost =  33.301617297873825
# RUN  3 , total integrated cost =  7.916348218967609
# RUN  3 , total integrated cost mean =  7.916348218967609
# Improved over  3  iterations in  9.6430786139681  seconds by  99.78511722301954  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7.581444871688859
# Gradient descend method:  None
# step size too small or too large
# step size too small or too large
# RUN  1 , total integrated cost =  6.121905529628411
# RUN  2 , total integrated cost =  5.705655932773138
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  3 , total integrated cost =  5.537478439896321
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  4 , total integrated cost =  5.477505825160793
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  5 , total integrated cost =  5.398410677559683
# RUN  6 , total integrated cost =  5.381993283977461
# step size too small or too large
# RUN  7 , total integrated cost =  5.346347832676778
# step size too small or too large
# step size too small or too large
# RUN  8 , total integrated cost =  5.313734402794494
# step size too small or too large
# RUN  9 , total integrated cost =  5.294947404089164
# RUN  10 , total integrated cost =  5.280932007714238
# step size too small or too large
# step size too small or too large
# RUN  11 , total integrated cost =  5.271685520440628
# step size too small or too large
# step size too small or too large
# RUN  12 , total integrated cost =  5.260725205331296
# step size too small or too large
# RUN  13 , total integrated cost =  5.238957665780983
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  14 , total integrated cost =  5.225045758732438
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  15 , total integrated cost =  5.2128863612032195
# RUN  16 , total integrated cost =  5.204945296921713
# step size too small or too large
# step size too small or too large
# RUN  17 , total integrated cost =  5.17737499613755
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  18 , total integrated cost =  5.182222077597251
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  19 , total integrated cost =  5.168015580891041
# step size too small or too large
# RUN  20 , total integrated cost =  5.186976522984113
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  21 , total integrated cost mean =  5.148205172081707
# Improved over  21  iterations in  127.62884531496093  seconds by  32.09466982597894  percent.
# cost =  5.283526787025281
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3685.3001767653286
# Gradient descend method:  None
# RUN  1 , total integrated cost =  149.0775528706452
# RUN  2 , total integrated cost =  26.124960426857946
# RUN  3 , total integrated cost =  7.552553208388901
# RUN  3 , total integrated cost mean =  7.552553208388901
# Improved over  3  iterations in  8.912217762030195  seconds by  99.79506273990907  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7.181891304541125
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.827148889146992
# step size too small or too large
# step size too small or too large
# RUN  2 , total integrated cost =  5.512179219321036
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  3 , total integrated cost =  5.341460897495505
# RUN  4 , total integrated cost =  5.303956193768621
# step size too small or too large
# RUN  5 , total integrated cost =  5.277760360642776
# RUN  6 , total integrated cost =  5.242235661740732
# step size too small or too large
# RUN  7 , total integrated cost =  5.200422898726863
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  8 , total integrated cost =  5.160770201666249
# RUN  9 , total integrated cost =  5.138807251686985
# step size too small or too large
# RUN  10 , total integrated cost =  5.121775554348591
# RUN  11 , total integrated cost =  5.113968436369315
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  12 , total integrated cost =  5.106782509300616
# RUN  13 , total integrated cost =  5.084727989282488
# RUN  14 , total integrated cost =  5.066161063417507
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  15 , total integrated cost =  5.048738538700885
# step size too small or too large
# RUN  16 , total integrated cost =  5.031173733181057
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  17 , total integrated cost =  5.043331987872799
# step size too small or too large
# step size too small or too large
# RUN  18 , total integrated cost =  5.011674838892083
# RUN  19 , total integrated cost =  5.003878645425965
# step size too small or too large
# RUN  20 , total integrated cost =  4.990966529697087
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  21 , total integrated cost mean =  4.977972663721468
# Improved over  21  iterations in  127.64494883699808  seconds by  30.687162299798587  percent.
# rep_ind =  1.357657865974999
# sigma =  0.03
# set cost params:  0.008817022660197538 0.0 1.0
# n =  2
# iteration =  6
# iteration =  12
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1222.1233268600095
# Gradient descend method:  None
# RUN  1 , total integrated cost =  70.73239969297532
# RUN  2 , total integrated cost =  124.38731171575006
# RUN  3 , total integrated cost =  30.736842536137733
# RUN  3 , total integrated cost mean =  30.736842536137733
# Improved over  3  iterations in  0.3702971250168048  seconds by  97.4849639262586  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  32.57680323189021
# Gradient descend method:  None
# RUN  1 , total integrated cost =  8.858529849504642
# RUN  2 , total integrated cost =  7.581347747094485
# RUN  3 , total integrated cost =  7.41236192138763
# RUN  4 , total integrated cost =  6.915588679797435
# RUN  5 , total integrated cost =  6.884327039660947
# RUN  6 , total integrated cost =  6.968354831393015
# RUN  7 , total integrated cost =  6.625978864768923
# RUN  8 , total integrated cost =  7.133691492925018
# RUN  9 , total integrated cost =  6.85765708039039
# RUN  9 , total integrated cost mean =  6.85765708039039
# Improved over  9  iterations in  1.8528346699895337  seconds by  78.9492632792242  percent.
# cost =  7.2343760927557765
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1220.5727804488974
# Gradient descend method:  None
# RUN  1 , total integrated cost =  43.232914668909956
# RUN  2 , total integrated cost =  53.8608959999501
# RUN  3 , total integrated cost =  34.57903391984475
# RUN  3 , total integrated cost mean =  34.57903391984475
# Improved over  3  iterations in  0.33140583796193823  seconds by  97.166983036675  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  17.30384302158405
# Gradient descend method:  None
# RUN  1 , total integrated cost =  8.507373968745235
# RUN  2 , total integrated cost =  7.263509391053621
# RUN  3 , total integrated cost =  4.621990630434575
# RUN  4 , total integrated cost =  4.434072468020153
# RUN  5 , total integrated cost =  5.5121558420283945
# step size too small or too large
# RUN  6 , total integrated cost =  4.124629986973841
# RUN  7 , total integrated cost =  4.39635947598344
# RUN  8 , total integrated cost =  4.559777241790084
# RUN  9 , total integrated cost =  4.543211869374958
# RUN  9 , total integrated cost mean =  4.543211869374958
# Improved over  9  iterations in  2.1919245300232433  seconds by  73.74449211248648  percent.
# rep_ind =  19.054417184722954
# iteration =  18
# iteration =  24
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1223.0240426676482
# Gradient descend method:  None
# RUN  1 , total integrated cost =  117.23082943929883
# RUN  2 , total integrated cost =  26.988882981653376
# RUN  3 , total integrated cost =  8.554014231103759
# RUN  3 , total integrated cost mean =  8.554014231103759
# Improved over  3  iterations in  0.5243382799671963  seconds by  99.30058494905417  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  8.543025979319502
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.935905987385681
# RUN  2 , total integrated cost =  7.064741391774129
# RUN  3 , total integrated cost =  7.208770774562509
# RUN  4 , total integrated cost =  6.998662942607599
# RUN  5 , total integrated cost =  7.108896639648668
# RUN  6 , total integrated cost =  6.71171764011495
# RUN  7 , total integrated cost =  6.897523806619667
# RUN  8 , total integrated cost =  6.9288615831034
# RUN  9 , total integrated cost =  7.083868348987733
# RUN  10 , total integrated cost =  6.610931956957257
# RUN  11 , total integrated cost =  6.476777751725908
# RUN  12 , total integrated cost =  6.480477174115802
# RUN  13 , total integrated cost =  6.432391255026637
# RUN  14 , total integrated cost =  6.647283889306376
# RUN  15 , total integrated cost =  6.4125809800681575
# RUN  16 , total integrated cost =  6.280652184559019
# RUN  17 , total integrated cost =  6.097028331142898
# RUN  18 , total integrated cost =  6.193619555341987
# RUN  19 , total integrated cost =  6.324382183552518
# RUN  20 , total integrated cost =  6.323070423464233
# step size too small or too large
# RUN  21 , total integrated cost mean =  6.132990264236302
# Improved over  21  iterations in  4.513957705989014  seconds by  28.21056287218704  percent.
# cost =  6.433151937706373
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1239.5149416416652
# Gradient descend method:  None
# RUN  1 , total integrated cost =  42.68090979253424
# RUN  2 , total integrated cost =  18.96113667769724
# RUN  3 , total integrated cost =  6.962907669127277
# RUN  3 , total integrated cost mean =  6.962907669127277
# Improved over  3  iterations in  0.3248069650144316  seconds by  99.43825544693271  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  6.331993237868291
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.442162564472776
# RUN  2 , total integrated cost =  5.265313172764836
# RUN  3 , total integrated cost =  4.6986316625664415
# RUN  4 , total integrated cost =  4.890158093077782
# RUN  5 , total integrated cost =  4.957036159250993
# RUN  6 , total integrated cost =  4.855625383801486
# RUN  7 , total integrated cost =  4.867631956834172
# RUN  8 , total integrated cost =  4.972402057660984
# RUN  9 , total integrated cost =  4.737084288965978
# RUN  10 , total integrated cost =  4.803359128139573
# RUN  11 , total integrated cost =  4.564788637593248
# RUN  12 , total integrated cost =  4.841214682611618
# RUN  13 , total integrated cost =  4.817805294375468
# RUN  14 , total integrated cost =  5.199139458663554
# no cost improvement
# RUN  15 , total integrated cost =  4.810777794177243
# RUN  16 , total integrated cost =  4.638887130886021
# RUN  16 , total integrated cost mean =  4.638887130886021
# Improved over  16  iterations in  3.7618226520135067  seconds by  26.73891211469875  percent.
# rep_ind =  13.212999603166386
# n =  10
# iteration =  6
# iteration =  12
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1219.3783287972185
# Gradient descend method:  None
# RUN  1 , total integrated cost =  76.5987112105709
# RUN  2 , total integrated cost =  37.49340425149821
# RUN  3 , total integrated cost =  10.852144715390283
# RUN  3 , total integrated cost mean =  10.852144715390283
# Improved over  3  iterations in  1.6210836739628576  seconds by  99.1100264405966  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  10.344433737761133
# Gradient descend method:  None
# RUN  1 , total integrated cost =  9.289895897060699
# RUN  2 , total integrated cost =  8.722901144766963
# RUN  3 , total integrated cost =  8.632365551910782
# RUN  4 , total integrated cost =  8.513928121566341
# RUN  5 , total integrated cost =  8.424913733266866
# RUN  6 , total integrated cost =  8.378171292273276
# RUN  7 , total integrated cost =  8.45495713487951
# RUN  8 , total integrated cost =  8.403298662307323
# RUN  9 , total integrated cost =  8.405439957575762
# RUN  9 , total integrated cost mean =  8.405439957575762
# Improved over  9  iterations in  9.737072258023545  seconds by  18.744320175857496  percent.
# cost =  8.570092403053764
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1225.5683137433718
# Gradient descend method:  None
# RUN  1 , total integrated cost =  63.54299237870923
# RUN  2 , total integrated cost =  35.07314373061247
# RUN  3 , total integrated cost =  8.356665929515845
# RUN  3 , total integrated cost mean =  8.356665929515845
# Improved over  3  iterations in  1.7117423940217122  seconds by  99.3181395246756  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  8.204548825804022
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.015027352653078
# step size too small or too large
# step size too small or too large
# RUN  2 , total integrated cost =  6.943172619226229
# RUN  3 , total integrated cost =  6.69107955710656
# RUN  4 , total integrated cost =  6.68748835822575
# step size too small or too large
# RUN  5 , total integrated cost =  6.459597690120157
# RUN  6 , total integrated cost =  6.450895395302152
# RUN  7 , total integrated cost =  6.368426762347694
# step size too small or too large
# RUN  8 , total integrated cost =  6.3949246056355245
# RUN  9 , total integrated cost =  6.383826434495994
# RUN  9 , total integrated cost mean =  6.383826434495994
# Improved over  9  iterations in  10.200068673002534  seconds by  22.191621135603427  percent.
# rep_ind =  15.142434252422472
# iteration =  18
# iteration =  24
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1236.2266672325643
# Gradient descend method:  None
# RUN  1 , total integrated cost =  85.5099673490772
# RUN  2 , total integrated cost =  34.38787708522186
# RUN  3 , total integrated cost =  10.242519338146915
# RUN  3 , total integrated cost mean =  10.242519338146915
# Improved over  3  iterations in  1.7419801949872635  seconds by  99.17146914804258  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  10.08446042893289
# Gradient descend method:  None
# RUN  1 , total integrated cost =  8.861838598637764
# RUN  2 , total integrated cost =  8.604503754951228
# RUN  3 , total integrated cost =  8.46629207027078
# RUN  4 , total integrated cost =  8.442568018818239
# step size too small or too large
# RUN  5 , total integrated cost =  8.268904069980772
# RUN  6 , total integrated cost =  8.135889522540973
# RUN  7 , total integrated cost =  8.276669196582182
# step size too small or too large
# RUN  8 , total integrated cost =  8.041179891795045
# step size too small or too large
# RUN  9 , total integrated cost =  8.065072273727543
# RUN  10 , total integrated cost =  8.053864740326878
# RUN  11 , total integrated cost =  8.163228200299317
# RUN  12 , total integrated cost =  8.042316086289741
# RUN  13 , total integrated cost =  8.045791713052761
# RUN  14 , total integrated cost =  7.908863711081764
# RUN  15 , total integrated cost =  7.9483421451953
# RUN  16 , total integrated cost =  7.860724572028644
# RUN  17 , total integrated cost =  7.843895975225197
# RUN  18 , total integrated cost =  7.8372538360163855
# RUN  19 , total integrated cost =  7.851919958656309
# RUN  20 , total integrated cost =  7.789243546007131
# RUN  21 , total integrated cost mean =  7.686532428865999
# Improved over  21  iterations in  22.845268054981716  seconds by  23.778446223925854  percent.
# cost =  7.940797476023635
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1224.3916168542103
# Gradient descend method:  None
# RUN  1 , total integrated cost =  52.04404418440301
# RUN  2 , total integrated cost =  25.30895565906036
# RUN  3 , total integrated cost =  5.942701501460452
# RUN  3 , total integrated cost mean =  5.942701501460452
# Improved over  3  iterations in  1.6796986749977805  seconds by  99.5146404614621  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5.520653440047587
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.055187849469001
# RUN  2 , total integrated cost =  4.742903101838152
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  3 , total integrated cost =  4.735762210203254
# RUN  4 , total integrated cost =  4.507102371418226
# RUN  5 , total integrated cost =  4.506486351476152
# step size too small or too large
# RUN  6 , total integrated cost =  4.495558979202895
# step size too small or too large
# step size too small or too large
# RUN  7 , total integrated cost =  4.4202270521301354
# RUN  8 , total integrated cost =  4.431533786729187
# RUN  9 , total integrated cost =  4.326646280368918
# RUN  10 , total integrated cost =  4.429613278319349
# RUN  11 , total integrated cost =  4.376103328338855
# RUN  12 , total integrated cost =  4.331135758839822
# RUN  13 , total integrated cost =  4.389994208294617
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  14 , total integrated cost =  4.418083148520541
# RUN  15 , total integrated cost =  4.301647851001822
# RUN  16 , total integrated cost =  4.308286289703708
# RUN  17 , total integrated cost =  4.312200148795055
# RUN  18 , total integrated cost =  4.182218299582667
# step size too small or too large
# RUN  19 , total integrated cost =  4.282797057746141
# RUN  20 , total integrated cost =  4.261544066967204
# RUN  21 , total integrated cost mean =  4.174159001788265
# Improved over  21  iterations in  24.620808783976827  seconds by  24.39012796006473  percent.
# rep_ind =  26.066905024475364
# n =  30
# iteration =  6
# iteration =  12
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1224.913975374977
# Gradient descend method:  None
# RUN  1 , total integrated cost =  62.65020912682633
# RUN  2 , total integrated cost =  24.58738956684165
# RUN  3 , total integrated cost =  9.211528172895067
# RUN  3 , total integrated cost mean =  9.211528172895067
# Improved over  3  iterations in  5.240432570979465  seconds by  99.24798570690851  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  8.528855968912852
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.912062540801483
# step size too small or too large
# RUN  2 , total integrated cost =  7.585864595554807
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  3 , total integrated cost =  7.428360856582895
# RUN  4 , total integrated cost =  7.360867134372076
# RUN  5 , total integrated cost =  7.299107608122262
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  6 , total integrated cost =  7.230321526369063
# step size too small or too large
# RUN  7 , total integrated cost =  7.235905980927933
# step size too small or too large
# step size too small or too large
# RUN  8 , total integrated cost =  7.12368736005429
# RUN  9 , total integrated cost =  7.144746384500038
# RUN  9 , total integrated cost mean =  7.144746384500038
# Improved over  9  iterations in  31.211577786016278  seconds by  16.228549168350455  percent.
# cost =  7.358184486144352
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1226.6415878874666
# Gradient descend method:  None
# RUN  1 , total integrated cost =  67.90328520407002
# step size too small or too large
# RUN  2 , total integrated cost =  28.975747908788794
# RUN  3 , total integrated cost =  10.006824037584883
# RUN  3 , total integrated cost mean =  10.006824037584883
# Improved over  3  iterations in  5.622909706027713  seconds by  99.18420962272943  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  9.517461956094365
# Gradient descend method:  None
# RUN  1 , total integrated cost =  8.357780801281239
# RUN  2 , total integrated cost =  7.92651756773418
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  3 , total integrated cost =  7.789050860884172
# RUN  4 , total integrated cost =  7.632155536487145
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  5 , total integrated cost =  7.676011416118897
# step size too small or too large
# step size too small or too large
# RUN  6 , total integrated cost =  7.623111433365779
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  7 , total integrated cost =  7.5806732726498085
# step size too small or too large
# RUN  8 , total integrated cost =  7.498072850479148
# step size too small or too large
# RUN  9 , total integrated cost =  7.434356523006027
# RUN  9 , total integrated cost mean =  7.434356523006027
# Improved over  9  iterations in  31.656043439987116  seconds by  21.88719474475495  percent.
# rep_ind =  2.613271967710131
# iteration =  18
# iteration =  24
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1227.3090583115859
# Gradient descend method:  None
# RUN  1 , total integrated cost =  66.4511097419127
# RUN  2 , total integrated cost =  27.421552487009578
# RUN  3 , total integrated cost =  9.959623365165822
# RUN  3 , total integrated cost mean =  9.959623365165822
# Improved over  3  iterations in  5.288433364999946  seconds by  99.18849915612394  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  9.129252810607662
# Gradient descend method:  None
# RUN  1 , total integrated cost =  8.334254664207071
# RUN  2 , total integrated cost =  7.907049677145711
# RUN  3 , total integrated cost =  7.640341744925054
# RUN  4 , total integrated cost =  7.556883661992245
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  5 , total integrated cost =  7.547316900261172
# step size too small or too large
# RUN  6 , total integrated cost =  7.531175531695391
# RUN  7 , total integrated cost =  7.3963158122566695
# RUN  8 , total integrated cost =  7.410930854829497
# RUN  9 , total integrated cost =  7.309050145693936
# RUN  10 , total integrated cost =  7.312066828635127
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  11 , total integrated cost =  7.386891402694131
# RUN  12 , total integrated cost =  7.3033394395557325
# step size too small or too large
# RUN  13 , total integrated cost =  7.248577149080179
# RUN  14 , total integrated cost =  7.200999876238189
# RUN  15 , total integrated cost =  7.226447782281408
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  16 , total integrated cost =  7.12032345077586
# RUN  17 , total integrated cost =  7.132585574420231
# RUN  18 , total integrated cost =  7.116463280434256
# RUN  19 , total integrated cost =  7.084580676342963
# step size too small or too large
# RUN  20 , total integrated cost =  7.095873511057119
# RUN  21 , total integrated cost mean =  7.030509749521093
# Improved over  21  iterations in  72.43116504797945  seconds by  22.98920957307648  percent.
# cost =  7.2860063198224765
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1222.3694928694413
# Gradient descend method:  None
# RUN  1 , total integrated cost =  83.31155571087257
# RUN  2 , total integrated cost =  35.13534030013433
# RUN  3 , total integrated cost =  9.681433923729877
# RUN  3 , total integrated cost mean =  9.681433923729877
# Improved over  3  iterations in  5.008161586010829  seconds by  99.20797811298421  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  9.364030479187813
# Gradient descend method:  None
# RUN  1 , total integrated cost =  8.241575514673226
# step size too small or too large
# RUN  2 , total integrated cost =  7.7690591387373376
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  3 , total integrated cost =  7.669604452553543
# step size too small or too large
# RUN  4 , total integrated cost =  7.574950846083044
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  5 , total integrated cost =  7.4078075196682365
# RUN  6 , total integrated cost =  7.4546280503179085
# RUN  7 , total integrated cost =  7.413044586360578
# RUN  8 , total integrated cost =  7.302457972445844
# RUN  9 , total integrated cost =  7.246746870139607
# step size too small or too large
# step size too small or too large
# RUN  10 , total integrated cost =  7.216938843781807
# step size too small or too large
# step size too small or too large
# RUN  11 , total integrated cost =  7.152981216872193
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  12 , total integrated cost =  7.260606249611993
# RUN  13 , total integrated cost =  7.2262719739257415
# step size too small or too large
# step size too small or too large
# RUN  14 , total integrated cost =  7.143673819191857
# step size too small or too large
# RUN  15 , total integrated cost =  7.181586492249717
# step size too small or too large
# RUN  16 , total integrated cost =  7.132820899798376
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  17 , total integrated cost =  7.117957458743441
# RUN  18 , total integrated cost =  7.031205536575299
# RUN  19 , total integrated cost =  7.075090062303343
# step size too small or too large
# RUN  20 , total integrated cost =  7.015330216023491
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  21 , total integrated cost mean =  7.023284952546431
# Improved over  21  iterations in  73.39024420501664  seconds by  24.99720106468945  percent.
# rep_ind =  0.703407858844698
# n =  50
# iteration =  6
# iteration =  12
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1226.7307558380135
# Gradient descend method:  None
# RUN  1 , total integrated cost =  59.60691977531781
# RUN  2 , total integrated cost =  33.74035906593585
# RUN  3 , total integrated cost =  7.902443953492566
# RUN  3 , total integrated cost mean =  7.902443953492566
# Improved over  3  iterations in  8.317286561999936  seconds by  99.35581268213218  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7.3947965937279925
# Gradient descend method:  None
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  1 , total integrated cost =  6.684115848197178
# step size too small or too large
# RUN  2 , total integrated cost =  6.249050177354154
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  3 , total integrated cost =  6.097750852355693
# RUN  4 , total integrated cost =  6.001704612152806
# step size too small or too large
# RUN  5 , total integrated cost =  5.961509101938162
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  6 , total integrated cost =  5.961568954359092
# step size too small or too large
# RUN  7 , total integrated cost =  5.883749553649442
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  8 , total integrated cost =  5.856480123573728
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  9 , total integrated cost =  5.812258266094414
# RUN  9 , total integrated cost mean =  5.812258266094414
# Improved over  9  iterations in  52.88511389394989  seconds by  21.400701257636115  percent.
# cost =  6.060885574075035
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1224.184083973762
# Gradient descend method:  None
# RUN  1 , total integrated cost =  71.79289489294108
# RUN  2 , total integrated cost =  28.711817674739567
# RUN  3 , total integrated cost =  10.651933206856706
# RUN  3 , total integrated cost mean =  10.651933206856706
# Improved over  3  iterations in  8.680657291028183  seconds by  99.1298748818658  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  10.027983447013746
# Gradient descend method:  None
# step size too small or too large
# RUN  1 , total integrated cost =  9.056437111413635
# step size too small or too large
# step size too small or too large
# RUN  2 , total integrated cost =  8.541869264007088
# step size too small or too large
# RUN  3 , total integrated cost =  8.422507802343464
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  4 , total integrated cost =  8.369864216117598
# RUN  5 , total integrated cost =  8.343230993653943
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  6 , total integrated cost =  8.279884182616465
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  7 , total integrated cost =  8.233301593540991
# step size too small or too large
# step size too small or too large
# RUN  8 , total integrated cost =  8.210452681086307
# step size too small or too large
# step size too small or too large
# RUN  9 , total integrated cost =  8.199413191439579
# RUN  9 , total integrated cost mean =  8.199413191439579
# Improved over  9  iterations in  52.323858956980985  seconds by  18.234675647761478  percent.
# rep_ind =  18.1523879031228
# iteration =  18
# iteration =  24
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1227.0633066796217
# Gradient descend method:  None
# RUN  1 , total integrated cost =  59.78642596688831
# RUN  2 , total integrated cost =  28.680385558918097
# RUN  3 , total integrated cost =  7.756006530095166
# RUN  3 , total integrated cost mean =  7.756006530095166
# Improved over  3  iterations in  8.456980381975882  seconds by  99.3679212402592  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7.467104626933901
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.600314272901825
# RUN  2 , total integrated cost =  6.203187708790526
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  3 , total integrated cost =  6.085114968213016
# step size too small or too large
# RUN  4 , total integrated cost =  6.064562009903517
# step size too small or too large
# RUN  5 , total integrated cost =  6.023678310962205
# step size too small or too large
# step size too small or too large
# RUN  6 , total integrated cost =  5.950716667542367
# step size too small or too large
# RUN  7 , total integrated cost =  5.916357977140575
# RUN  8 , total integrated cost =  5.844401533034411
# step size too small or too large
# step size too small or too large
# RUN  9 , total integrated cost =  5.795376316986468
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  10 , total integrated cost =  5.790993542613328
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  11 , total integrated cost =  5.737314208837484
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  12 , total integrated cost =  5.761942914770508
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  13 , total integrated cost =  5.6676346852280775
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  14 , total integrated cost =  5.718104213627629
# RUN  15 , total integrated cost =  5.696526434423345
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  16 , total integrated cost =  5.656422486128196
# step size too small or too large
# step size too small or too large
# RUN  17 , total integrated cost =  5.634539832458589
# step size too small or too large
# step size too small or too large
# RUN  18 , total integrated cost =  5.6087283577035825
# step size too small or too large
# step size too small or too large
# RUN  19 , total integrated cost =  5.565746631093034
# RUN  20 , total integrated cost =  5.551044863943122
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  21 , total integrated cost mean =  5.521841380428863
# Improved over  21  iterations in  122.99086375901243  seconds by  26.05110472790831  percent.
# cost =  5.744433366314669
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1227.7926837979455
# Gradient descend method:  None
# RUN  1 , total integrated cost =  63.7513607208112
# RUN  2 , total integrated cost =  27.168926682950627
# RUN  3 , total integrated cost =  8.429808449853683
# RUN  3 , total integrated cost mean =  8.429808449853683
# Improved over  3  iterations in  8.548348534968682  seconds by  99.31341760208429  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7.9751331756443
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.224566317159101
# step size too small or too large
# step size too small or too large
# RUN  2 , total integrated cost =  6.783476031487238
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  3 , total integrated cost =  6.697450714537804
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  4 , total integrated cost =  6.616652684851233
# step size too small or too large
# step size too small or too large
# RUN  5 , total integrated cost =  6.5785588849998575
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  6 , total integrated cost =  6.522874881487889
# step size too small or too large
# step size too small or too large
# RUN  7 , total integrated cost =  6.4894771399368665
# step size too small or too large
# step size too small or too large
# RUN  8 , total integrated cost =  6.460324566931339
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  9 , total integrated cost =  6.410640943218754
# step size too small or too large
# step size too small or too large
# RUN  10 , total integrated cost =  6.433592266859182
# RUN  11 , total integrated cost =  6.3475561278137915
# step size too small or too large
# step size too small or too large
# RUN  12 , total integrated cost =  6.353066827191586
# RUN  13 , total integrated cost =  6.297915976546056
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  14 , total integrated cost =  6.291146177050874
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  15 , total integrated cost =  6.298119525971856
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  16 , total integrated cost =  6.240374999695498
# RUN  17 , total integrated cost =  6.2344815790904
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  18 , total integrated cost =  6.178786949569198
# step size too small or too large
# step size too small or too large
# RUN  19 , total integrated cost =  6.2042435012504935
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  20 , total integrated cost =  6.169454279552176
# step size too small or too large
# RUN  21 , total integrated cost mean =  6.117593106584898
# Improved over  21  iterations in  122.91771764901932  seconds by  23.29164953297891  percent.
# rep_ind =  4.8179624279985696
# sigma =  0.049999999999999996
# set cost params:  0.005282379365665093 0.0 1.0
# n =  2
# iteration =  6
# iteration =  12
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  719.0712460589813
# Gradient descend method:  None
# RUN  1 , total integrated cost =  32.09676199473657
# RUN  2 , total integrated cost =  24.124583464335885
# RUN  3 , total integrated cost =  5.594384550303163
# RUN  3 , total integrated cost mean =  5.594384550303163
# Improved over  3  iterations in  0.3308773699682206  seconds by  99.22199857372071  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  6.473454139908499
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.092834529402319
# RUN  2 , total integrated cost =  5.31335826114957
# RUN  3 , total integrated cost =  5.140552227057592
# RUN  4 , total integrated cost =  4.847028629844399
# RUN  5 , total integrated cost =  4.957067054269806
# RUN  6 , total integrated cost =  5.060153891122427
# step size too small or too large
# RUN  7 , total integrated cost =  5.585099716098949
# no cost improvement
# RUN  8 , total integrated cost =  5.168260521856492
# step size too small or too large
# RUN  9 , total integrated cost =  4.933586487920984
# RUN  9 , total integrated cost mean =  4.933586487920984
# Improved over  9  iterations in  2.380936957022641  seconds by  23.787418875717577  percent.
# cost =  5.473908554566054
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  713.8828727159554
# Gradient descend method:  None
# RUN  1 , total integrated cost =  24.164947953115703
# RUN  2 , total integrated cost =  12.360935326021153
# RUN  3 , total integrated cost =  10.23077769023594
# RUN  3 , total integrated cost mean =  10.23077769023594
# Improved over  3  iterations in  0.3546725169871934  seconds by  98.56688287655464  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  17.293844660062277
# Gradient descend method:  None
# RUN  1 , total integrated cost =  13.000350439810111
# RUN  2 , total integrated cost =  5.372410202176372
# RUN  3 , total integrated cost =  4.764833704652121
# RUN  4 , total integrated cost =  4.971455524731374
# RUN  5 , total integrated cost =  5.28719144104188
# RUN  6 , total integrated cost =  4.733160286091948
# RUN  7 , total integrated cost =  4.896524998784247
# RUN  8 , total integrated cost =  4.938983952019933
# RUN  9 , total integrated cost =  4.886505702042603
# RUN  9 , total integrated cost mean =  4.886505702042603
# Improved over  9  iterations in  1.9011236689984798  seconds by  71.7442489041936  percent.
# rep_ind =  8.222003848915453
# iteration =  18
# iteration =  24
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  742.9570245638581
# Gradient descend method:  None
# RUN  1 , total integrated cost =  50.31222073998558
# RUN  2 , total integrated cost =  15.643091829287659
# RUN  3 , total integrated cost =  7.289860101920943
# RUN  3 , total integrated cost mean =  7.289860101920943
# Improved over  3  iterations in  0.34839206899050623  seconds by  99.01880460633637  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7.048996571252235
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.859478627865918
# RUN  2 , total integrated cost =  5.374403963857505
# RUN  3 , total integrated cost =  5.19762185741509
# RUN  4 , total integrated cost =  5.585086054245093
# RUN  5 , total integrated cost =  5.510671208556229
# RUN  6 , total integrated cost =  5.320892200076186
# RUN  7 , total integrated cost =  5.119393035438999
# RUN  8 , total integrated cost =  5.587256723394836
# RUN  9 , total integrated cost =  5.1226154967803454
# RUN  10 , total integrated cost =  5.497651071825774
# RUN  11 , total integrated cost =  4.934411476054709
# RUN  12 , total integrated cost =  4.913291069756305
# RUN  13 , total integrated cost =  5.108105225880218
# step size too small or too large
# step size too small or too large
# RUN  14 , total integrated cost =  5.39624285317368
# RUN  15 , total integrated cost =  5.263119353421749
# RUN  16 , total integrated cost =  4.784306863922877
# RUN  17 , total integrated cost =  5.036108262860674
# RUN  18 , total integrated cost =  5.412951944442467
# RUN  19 , total integrated cost =  4.78127279953997
# RUN  20 , total integrated cost =  5.002066468466889
# RUN  21 , total integrated cost mean =  4.850339231489263
# Improved over  21  iterations in  4.842359413043596  seconds by  31.191068367513566  percent.
# cost =  5.639730551852386
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  723.9525122910621
# Gradient descend method:  None
# RUN  1 , total integrated cost =  70.58369208540702
# RUN  2 , total integrated cost =  17.668016972508536
# RUN  3 , total integrated cost =  7.8525176715020155
# RUN  3 , total integrated cost mean =  7.8525176715020155
# Improved over  3  iterations in  0.3155555630219169  seconds by  98.91532696714437  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  6.792780293582463
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.245048817215946
# RUN  2 , total integrated cost =  6.594361699335273
# RUN  3 , total integrated cost =  5.464741672161157
# RUN  4 , total integrated cost =  5.475978609515751
# RUN  5 , total integrated cost =  5.85526858925958
# RUN  6 , total integrated cost =  5.310433974253194
# RUN  7 , total integrated cost =  5.357944332591755
# RUN  8 , total integrated cost =  5.2703069935358755
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  9 , total integrated cost =  5.200832665623695
# RUN  10 , total integrated cost =  5.107777716799603
# RUN  11 , total integrated cost =  4.921232984501557
# RUN  12 , total integrated cost =  5.103942363530056
# RUN  13 , total integrated cost =  5.64761675055969
# RUN  14 , total integrated cost =  5.166505378005697
# RUN  15 , total integrated cost =  4.82834895366861
# RUN  16 , total integrated cost =  5.300896600638925
# step size too small or too large
# step size too small or too large
# RUN  17 , total integrated cost =  5.009224543897997
# RUN  18 , total integrated cost =  4.818645784162273
# RUN  19 , total integrated cost =  4.8861368788319925
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  20 , total integrated cost =  5.018140937317886
# RUN  21 , total integrated cost mean =  4.817450279642651
# Improved over  21  iterations in  5.0396543520037085  seconds by  29.079845491337636  percent.
# rep_ind =  3.3473442077136633
# n =  10
# iteration =  6
# iteration =  12
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  734.2679890933065
# Gradient descend method:  None
# RUN  1 , total integrated cost =  46.61904423730685
# RUN  2 , total integrated cost =  27.251644143718426
# RUN  3 , total integrated cost =  9.12558210118286
# RUN  3 , total integrated cost mean =  9.12558210118286
# Improved over  3  iterations in  1.702635282999836  seconds by  98.75718644463156  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  8.1129470981939
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.5355968500300605
# RUN  2 , total integrated cost =  7.392248519011213
# RUN  3 , total integrated cost =  7.236248040830193
# step size too small or too large
# RUN  4 , total integrated cost =  7.091998477732818
# RUN  5 , total integrated cost =  7.22465329394394
# RUN  6 , total integrated cost =  6.941018748619465
# RUN  7 , total integrated cost =  7.136409562596619
# RUN  8 , total integrated cost =  7.005363155543132
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  9 , total integrated cost =  6.9348717376848015
# RUN  9 , total integrated cost mean =  6.9348717376848015
# Improved over  9  iterations in  10.38682841998525  seconds by  14.520929894530681  percent.
# cost =  7.3116615420352655
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  733.1481587334886
# Gradient descend method:  None
# RUN  1 , total integrated cost =  42.54472616148982
# RUN  2 , total integrated cost =  24.866181021820402
# RUN  3 , total integrated cost =  9.858130141318219
# RUN  3 , total integrated cost mean =  9.858130141318219
# Improved over  3  iterations in  1.6405491210171022  seconds by  98.65536999256084  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7.2266539044728235
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.540181577789701
# RUN  2 , total integrated cost =  6.448335585712634
# step size too small or too large
# RUN  3 , total integrated cost =  6.238235887623444
# RUN  4 , total integrated cost =  6.146811937751512
# RUN  5 , total integrated cost =  6.042209169222359
# RUN  6 , total integrated cost =  5.945498680595348
# RUN  7 , total integrated cost =  5.929055387326894
# RUN  8 , total integrated cost =  5.7057134256236095
# RUN  9 , total integrated cost =  5.821732690351597
# RUN  9 , total integrated cost mean =  5.821732690351597
# Improved over  9  iterations in  10.110332734009717  seconds by  19.44082604055069  percent.
# rep_ind =  9.104426270321222
# iteration =  18
# iteration =  24
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  747.1515796915461
# Gradient descend method:  None
# RUN  1 , total integrated cost =  58.25576903909771
# RUN  2 , total integrated cost =  37.67919356668443
# RUN  3 , total integrated cost =  10.500494925642439
# RUN  3 , total integrated cost mean =  10.500494925642439
# Improved over  3  iterations in  1.6420357080060057  seconds by  98.59459643651192  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  10.064603649937705
# ...
# RUN  2 , total integrated cost =  33.67004929065418
# RUN  3 , total integrated cost =  7.12300568785472
# RUN  3 , total integrated cost mean =  7.12300568785472
# Improved over  3  iterations in  5.21418927598279  seconds by  98.63201338025378  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  6.783556261088222
# Gradient descend method:  None
# step size too small or too large
# RUN  1 , total integrated cost =  5.6531325752180015
# RUN  2 , total integrated cost =  5.577366892619675
# RUN  3 , total integrated cost =  5.200337842641463
# RUN  4 , total integrated cost =  5.219079971726975
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  5 , total integrated cost =  5.230800275750012
# RUN  6 , total integrated cost =  5.288876799478045
# step size too small or too large
# RUN  7 , total integrated cost =  5.201948409766083
# RUN  8 , total integrated cost =  5.1884807277433005
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  9 , total integrated cost =  5.061614296485667
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  10 , total integrated cost =  5.148418553844545
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  11 , total integrated cost =  5.200726168250877
# step size too small or too large
# RUN  12 , total integrated cost =  5.1656740372307945
# step size too small or too large
# RUN  13 , total integrated cost =  5.132982280203695
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  14 , total integrated cost =  4.997596916667475
# RUN  15 , total integrated cost =  4.969194895085213
# step size too small or too large
# step size too small or too large
# RUN  16 , total integrated cost =  5.233691533558337
# step size too small or too large
# step size too small or too large
# RUN  17 , total integrated cost =  5.1339228893600835
# RUN  18 , total integrated cost =  5.096054136389615
# RUN  19 , total integrated cost =  5.181714859249003
# RUN  20 , total integrated cost =  5.124943464471161
# step size too small or too large
# step size too small or too large
# RUN  21 , total integrated cost mean =  5.080825077167956
# Improved over  21  iterations in  75.1432537449873  seconds by  25.100863299202786  percent.
# cost =  6.614123120020022
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  525.867692712694
# Gradient descend method:  None
# RUN  1 , total integrated cost =  49.601927067667226
# RUN  2 , total integrated cost =  22.540096782195594
# RUN  3 , total integrated cost =  8.575084179196658
# RUN  3 , total integrated cost mean =  8.575084179196658
# Improved over  3  iterations in  4.788436682021711  seconds by  98.36934569321762  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7.4219264818850785
# Gradient descend method:  None
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  1 , total integrated cost =  6.676918044818957
# RUN  2 , total integrated cost =  6.4941982283974555
# RUN  3 , total integrated cost =  6.310495106571376
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  4 , total integrated cost =  6.215442195651039
# RUN  5 , total integrated cost =  6.274031181599342
# RUN  6 , total integrated cost =  6.199574517645788
# step size too small or too large
# RUN  7 , total integrated cost =  6.038262952925934
# RUN  8 , total integrated cost =  6.185844181305939
# step size too small or too large
# RUN  9 , total integrated cost =  5.908529878725365
# RUN  10 , total integrated cost =  5.842736154829681
# RUN  11 , total integrated cost =  5.710957292624723
# step size too small or too large
# RUN  12 , total integrated cost =  5.738832132749196
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  13 , total integrated cost =  5.768711977983505
# RUN  14 , total integrated cost =  5.807439295941327
# step size too small or too large
# RUN  15 , total integrated cost =  5.657139485795
# RUN  16 , total integrated cost =  5.636092351003745
# step size too small or too large
# step size too small or too large
# RUN  17 , total integrated cost =  5.533003685455
# step size too small or too large
# RUN  18 , total integrated cost =  5.460551580059922
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  19 , total integrated cost =  5.451534376126989
# step size too small or too large
# step size too small or too large
# RUN  20 , total integrated cost =  5.414953648859159
# RUN  21 , total integrated cost mean =  5.437080405288039
# Improved over  21  iterations in  70.67286921699997  seconds by  26.74300373954813  percent.
# rep_ind =  4.3718245554014565
# n =  50
# iteration =  6
# iteration =  12
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  521.6663846463947
# Gradient descend method:  None
# RUN  1 , total integrated cost =  50.768946415469145
# RUN  2 , total integrated cost =  25.83619893136535
# RUN  3 , total integrated cost =  8.237609931494763
# RUN  3 , total integrated cost mean =  8.237609931494763
# Improved over  3  iterations in  8.480246853956487  seconds by  98.42090459076091  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7.0902920778993135
# Gradient descend method:  None
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  1 , total integrated cost =  6.4238906771918085
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  2 , total integrated cost =  6.192214563153681
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  3 , total integrated cost =  6.190823992055219
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  4 , total integrated cost =  6.020719920417062
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  5 , total integrated cost =  5.941892251404712
# RUN  6 , total integrated cost =  6.057782581784071
# step size too small or too large
# RUN  7 , total integrated cost =  5.897266082779631
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  8 , total integrated cost =  5.799593990359287
# RUN  9 , total integrated cost =  5.708538041589017
# RUN  9 , total integrated cost mean =  5.708538041589017
# Improved over  9  iterations in  51.31613347900566  seconds by  19.48797061008632  percent.
# cost =  6.212850472765085
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  523.1881076436775
# Gradient descend method:  None
# RUN  1 , total integrated cost =  44.71740452225607
# RUN  2 , total integrated cost =  23.70888310884979
# RUN  3 , total integrated cost =  8.43404710580889
# RUN  3 , total integrated cost mean =  8.43404710580889
# Improved over  3  iterations in  8.505538404977415  seconds by  98.38795129656253  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7.174762247475785
# Gradient descend method:  None
# step size too small or too large
# step size too small or too large
# RUN  1 , total integrated cost =  6.676757595057975
# RUN  2 , total integrated cost =  6.463114950342794
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  3 , total integrated cost =  6.225159766347798
# RUN  4 , total integrated cost =  6.121556409678974
# RUN  5 , total integrated cost =  6.088044036186364
# step size too small or too large
# RUN  6 , total integrated cost =  6.071585630365973
# RUN  7 , total integrated cost =  5.974557375154899
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  8 , total integrated cost =  5.8779263436224145
# RUN  9 , total integrated cost =  5.874029988763583
# RUN  9 , total integrated cost mean =  5.874029988763583
# Improved over  9  iterations in  50.95179525099229  seconds by  18.129273331249735  percent.
# rep_ind =  1.4167360920345076
# iteration =  18
# iteration =  24
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  522.6810911490119
# Gradient descend method:  None
# RUN  1 , total integrated cost =  44.57776191437869
# RUN  2 , total integrated cost =  24.947171862074487
# RUN  3 , total integrated cost =  8.609703738032627
# RUN  3 , total integrated cost mean =  8.609703738032627
# Improved over  3  iterations in  8.336540101037826  seconds by  98.35278071393287  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  8.286148921988117
# Gradient descend method:  None
# step size too small or too large
# step size too small or too large
# RUN  1 , total integrated cost =  7.150898663047251
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  2 , total integrated cost =  7.207550726839199
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  3 , total integrated cost =  6.911876499860228
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  4 , total integrated cost =  6.738132306632105
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  5 , total integrated cost =  6.7145695006783805
# RUN  6 , total integrated cost =  6.672129680259291
# RUN  7 , total integrated cost =  6.641171084624914
# RUN  8 , total integrated cost =  6.462421898799319
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  9 , total integrated cost =  6.335894587924316
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  10 , total integrated cost =  6.365746977412326
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  11 , total integrated cost =  6.385740924936621
# step size too small or too large
# RUN  12 , total integrated cost =  6.291070406598469
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  13 , total integrated cost =  6.278906239809046
# RUN  14 , total integrated cost =  6.2026090213433065
# step size too small or too large
# RUN  15 , total integrated cost =  6.26074293566232
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  16 , total integrated cost =  6.226702579295815
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  17 , total integrated cost =  6.068810430100537
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  18 , total integrated cost =  5.88906790350154
# step size too small or too large
# step size too small or too large
# RUN  19 , total integrated cost =  6.059391050333029
# step size too small or too large
# step size too small or too large
# RUN  20 , total integrated cost =  5.868941809564568
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  21 , total integrated cost mean =  5.766343576784382
# Improved over  21  iterations in  120.9309029559954  seconds by  30.409848639301927  percent.
# cost =  6.280937894572203
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  521.7654365426832
# Gradient descend method:  None
# RUN  1 , total integrated cost =  48.265186084212516
# RUN  2 , total integrated cost =  28.823271655527762
# RUN  3 , total integrated cost =  7.52233009532072
# RUN  3 , total integrated cost mean =  7.52233009532072
# Improved over  3  iterations in  8.578379191050772  seconds by  98.55829275600064  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  6.6090914871206685
# Gradient descend method:  None
# step size too small or too large
# RUN  1 , total integrated cost =  5.808619111424362
# RUN  2 , total integrated cost =  5.593450649365509
# RUN  3 , total integrated cost =  5.401295821322733
# RUN  4 , total integrated cost =  5.3391599755064165
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  5 , total integrated cost =  5.357358136921335
# RUN  6 , total integrated cost =  5.29521515733779
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  7 , total integrated cost =  5.272206053123354
# RUN  8 , total integrated cost =  5.43974162702852
# step size too small or too large
# step size too small or too large
# RUN  9 , total integrated cost =  5.278168823365828
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  10 , total integrated cost =  5.207999335105487
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  11 , total integrated cost =  5.303285941390714
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  12 , total integrated cost =  5.031606756093447
# step size too small or too large
# step size too small or too large
# RUN  13 , total integrated cost =  5.085575319348737
# step size too small or too large
# RUN  14 , total integrated cost =  5.16888727703611
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  15 , total integrated cost =  5.215038921474165
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  16 , total integrated cost =  5.126107937993664
# RUN  17 , total integrated cost =  5.015560135521071
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  18 , total integrated cost =  5.227552248080863
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  19 , total integrated cost =  5.129783997629077
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  20 , total integrated cost =  5.053496384214791
# step size too small or too large
# RUN  21 , total integrated cost mean =  5.113834069933524
# Improved over  21  iterations in  122.65930549800396  seconds by  22.624250550941795  percent.
# rep_ind =  7.161775493748285

# %%
#len(sigma_array), 4, N_max, max_it

##### METHOD 3
method_ind = 2
step_method_ind = 0

for d in dict_list:
    
    if d['point'][0] != 0.5:
        continue
    if d['point'][1] != 0.5:
        continue
        
    print("Point = ", d['point'])
    aln.params.ext_exc_current = d['point'][0] * 5.
    aln.params.ext_inh_current = d['point'][1] * 5.
    
    max_it = d['cost'].shape[3]
    
    for s_ind in range(len(d['sigma'])):
        
        print("sigma = ", d['sigma'][s_ind])
        
        s = d['sigma'][s_ind]
        aln.params.sigma_ou = s
        c_p = d['cost_params'][s_ind]
        cost.setParams(c_p[0], c_p[1], c_p[2])
        
        target_ = d['target'][s_ind].copy()
        target_[0,0,:int(trans_time * dur / aln.params.dt)] = -1000
        target_[0,1,:int(trans_time * dur / aln.params.dt)] = -1000
                
        for n_ind in range(len(d['N_array'])):
            
            n_ = d['N_array'][n_ind]
            
            print("n = ", n_)
            aln.params.duration = dur
        
            for i_it in range(1,len(d['it_array'])):
                
                print('cost = ', d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it])
            
                it = d['it_array'][i_it]
                print("iteration = ", it)
                
                if d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it] > 0.:
                    continue
                
                c_vars = d['init']
                aln.params.duration = dur
                setinit(d['init_vars'], aln)
                control_init = aln.getZeroControl()
                    
                
                bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                    control_init, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_ = init_it,
                    tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                    t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                    control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                    noise_real=n_, init_params = d['init_vars'], method='M3')
            
                control_init = bc[:,:,100:-100]
                c_vars = [0,1]
                aln.params.duration = dur
                setinit(d['init_vars'], aln)
                
                bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                    control_init, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_=it-init_it,
                    tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                    t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                    control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                    noise_real=n_, init_params = d['init_vars'], method='M3')

                control_init = bc[:,:,100:-100]
                aln.params.duration = dur
                setinit(d['init_vars'], aln)
                cost_final = 0.
                cs = cost.numba_cost_sparsity_int(1, 6, T, d['cost_params'][s_ind][2], dt, control_init)

                for j in range(noise_realizations_final):
                    state_ = fo.updateState(aln, control_init)
                    cost_final += cost.numba_cost_precision_int(1, T, dt, d['cost_params'][s_ind][0],
                                                                   state_, target_, list(prec_vars) )

                d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it] = (
                                cost_final / noise_realizations_final + cs )
                print('cost = ', d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it])
                
                c_vars = d['init']                    
                aln.params.duration = dur
                control_init1 = aln.getZeroControl()
                setinit(d['init_vars'], aln)
                
                bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                    control_init1, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_ = init_it,
                    tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                    t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                    control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                    noise_real=n_, init_params = d['init_vars'], method='M3')
            
                control_init1 = bc[:,:,100:-100]
                c_vars = [0,1]
                aln.params.duration = dur
                setinit(d['init_vars'], aln)
                
                bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                    control_init1, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_=it-init_it,
                    tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                    t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                    control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                    noise_real=n_, init_params = d['init_vars'], method='M3')

                control_init1 = bc[:,:,100:-100]
                d['rep_ind'][s_ind, method_ind, step_method_ind, n_ind, i_it] = rep_ind(control_init, control_init1)
                print('rep_ind = ', d['rep_ind'][s_ind, method_ind, step_method_ind, n_ind, i_it])
                
                file=open(dict_file, "wb")
                pickle.dump(dict_list, file)
                file.close()
                
    break
# Out:
# Point =  [0.5 0.5]
# sigma =  0.01
# set cost params:  0.026458600489613113 0.0 1.0
# n =  2
# cost =  6.847291243414146
# iteration =  6
# cost =  0.0
# iteration =  12
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3671.419530522828
# Gradient descend method:  None
# RUN  1 , total integrated cost =  157.97532921640914
# RUN  2 , total integrated cost =  116.74358730722034
# RUN  3 , total integrated cost =  60.7874760865377
# RUN  3 , total integrated cost mean =  60.7874760865377
# Improved over  3  iterations in  0.385289358033333  seconds by  98.34430591270834  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  62.25829332238937
# Gradient descend method:  None
# RUN  1 , total integrated cost =  15.31616180404004
# RUN  2 , total integrated cost =  11.335102445748444
# RUN  3 , total integrated cost =  10.725320979059322
# RUN  4 , total integrated cost =  10.542590119794168
# RUN  5 , total integrated cost =  10.404612767393779
# RUN  6 , total integrated cost =  10.259430019140778
# RUN  7 , total integrated cost =  10.258358911623592
# RUN  8 , total integrated cost =  10.152237038628815
# RUN  9 , total integrated cost =  10.16638924306862
# RUN  9 , total integrated cost mean =  10.16638924306862
# Improved over  9  iterations in  2.031189021014143  seconds by  83.67062651328321  percent.
# cost =  10.405111987070422
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3688.5845628069846
# Gradient descend method:  None
# RUN  1 , total integrated cost =  166.738849849926
# RUN  2 , total integrated cost =  24.252265946932596
# RUN  3 , total integrated cost =  7.298325361779436
# RUN  3 , total integrated cost mean =  7.298325361779436
# Improved over  3  iterations in  0.3357215950381942  seconds by  99.80213750728747  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7.935017052153681
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.363234292426322
# RUN  2 , total integrated cost =  4.9927899381401115
# RUN  3 , total integrated cost =  4.75547271796456
# RUN  4 , total integrated cost =  4.743556562999513
# RUN  5 , total integrated cost =  4.56688654076401
# RUN  6 , total integrated cost =  4.611074293889821
# RUN  7 , total integrated cost =  4.52522076840735
# RUN  8 , total integrated cost =  4.532116135294094
# RUN  9 , total integrated cost =  4.575557623856103
# RUN  9 , total integrated cost mean =  4.575557623856103
# Improved over  9  iterations in  2.0021560880122706  seconds by  42.33714188913773  percent.
# rep_ind =  42.23238320125828
# cost =  60.371935156459124
# iteration =  18
# cost =  0.0
# iteration =  24
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3684.335215484866
# Gradient descend method:  None
# RUN  1 , total integrated cost =  141.56676495581354
# RUN  2 , total integrated cost =  72.29000274180564
# RUN  3 , total integrated cost =  14.954649501790787
# RUN  3 , total integrated cost mean =  14.954649501790787
# Improved over  3  iterations in  0.40271220199065283  seconds by  99.59410182225173  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  14.703317279002547
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.028878119493728
# RUN  2 , total integrated cost =  10.630595133383432
# RUN  3 , total integrated cost =  10.439513995294018
# RUN  4 , total integrated cost =  10.289283435057751
# RUN  5 , total integrated cost =  10.116378055211166
# RUN  6 , total integrated cost =  10.055057094165697
# RUN  7 , total integrated cost =  10.075629773425234
# RUN  8 , total integrated cost =  10.153917187965716
# RUN  9 , total integrated cost =  9.992532954790727
# RUN  10 , total integrated cost =  10.028873913982792
# step size too small or too large
# step size too small or too large
# RUN  11 , total integrated cost =  9.980641762538937
# RUN  12 , total integrated cost =  9.980522790125912
# RUN  13 , total integrated cost =  9.89473380715649
# RUN  14 , total integrated cost =  9.85155380668574
# RUN  15 , total integrated cost =  9.827724706047633
# RUN  16 , total integrated cost =  9.738550868923937
# RUN  17 , total integrated cost =  9.814304005158473
# RUN  18 , total integrated cost =  9.773131016602619
# RUN  19 , total integrated cost =  9.695389132804689
# RUN  20 , total integrated cost =  9.665228126701424
# RUN  21 , total integrated cost mean =  9.552873989141318
# Improved over  21  iterations in  5.07147038297262  seconds by  35.029124327041856  percent.
# cost =  9.783755805641988
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3688.582977295504
# Gradient descend method:  None
# RUN  1 , total integrated cost =  158.90674320357056
# RUN  2 , total integrated cost =  11.504871946941646
# RUN  3 , total integrated cost =  6.204252262130073
# RUN  3 , total integrated cost mean =  6.204252262130073
# Improved over  3  iterations in  0.5452195669640787  seconds by  99.83179849008903  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  6.013847763992472
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.00585699149346
# RUN  2 , total integrated cost =  4.0989350824354664
# RUN  3 , total integrated cost =  4.178219643110028
# RUN  4 , total integrated cost =  4.040670158362724
# RUN  5 , total integrated cost =  4.311994065929072
# RUN  6 , total integrated cost =  4.262260721086637
# RUN  7 , total integrated cost =  4.004703986572738
# RUN  8 , total integrated cost =  3.920978570370788
# RUN  9 , total integrated cost =  4.029429712307242
# RUN  10 , total integrated cost =  4.089075165828151
# RUN  11 , total integrated cost =  3.6854382957615037
# RUN  12 , total integrated cost =  3.8863058064808778
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  13 , total integrated cost =  3.8759729712474678
# RUN  14 , total integrated cost =  3.9039787691683014
# RUN  15 , total integrated cost =  4.030736178345733
# RUN  16 , total integrated cost =  3.8368505345296047
# RUN  17 , total integrated cost =  3.860404434347818
# RUN  18 , total integrated cost =  3.8852175264887014
# RUN  19 , total integrated cost =  3.8151625044973594
# RUN  20 , total integrated cost =  3.9366664665675297
# RUN  21 , total integrated cost mean =  3.8298399799922476
# Improved over  21  iterations in  6.361859573982656  seconds by  36.31631311116372  percent.
# rep_ind =  45.695697667861495
# n =  10
# cost =  4.869245152481968
# iteration =  6
# cost =  0.0
# iteration =  12
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3685.655587566708
# Gradient descend method:  None
# RUN  1 , total integrated cost =  152.7553993732409
# RUN  2 , total integrated cost =  73.07473139346152
# RUN  3 , total integrated cost =  46.81773291029426
# RUN  3 , total integrated cost mean =  46.81773291029426
# Improved over  3  iterations in  1.878693389997352  seconds by  98.72973120255104  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  47.38410198207498
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.693513420219055
# RUN  2 , total integrated cost =  8.81582272631483
# step size too small or too large
# step size too small or too large
# RUN  3 , total integrated cost =  8.2279823394739
# RUN  4 , total integrated cost =  8.123411523600012
# RUN  5 , total integrated cost =  7.889680362378009
# RUN  6 , total integrated cost =  7.764899672814953
# step size too small or too large
# RUN  7 , total integrated cost =  7.716660720215738
# RUN  8 , total integrated cost =  7.695892845873814
# RUN  9 , total integrated cost =  7.605592482197693
# RUN  9 , total integrated cost mean =  7.605592482197693
# Improved over  9  iterations in  9.799696443020366  seconds by  83.94906273611595  percent.
# cost =  7.6975712791123625
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3670.759700837458
# Gradient descend method:  None
# RUN  1 , total integrated cost =  149.37030270909992
# RUN  2 , total integrated cost =  12.604520951441403
# RUN  3 , total integrated cost =  8.737674238869134
# RUN  3 , total integrated cost mean =  8.737674238869134
# Improved over  3  iterations in  1.8138320469879545  seconds by  99.76196550711626  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  9.082436128422989
# Gradient descend method:  None
# step size too small or too large
# RUN  1 , total integrated cost =  6.233785036998936
# RUN  2 , total integrated cost =  5.190593949866109
# RUN  3 , total integrated cost =  5.11065408445219
# RUN  4 , total integrated cost =  5.025010729231113
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  5 , total integrated cost =  4.755125600717352
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  6 , total integrated cost =  4.413662292713976
# RUN  7 , total integrated cost =  4.276418153020814
# step size too small or too large
# RUN  8 , total integrated cost =  4.170034350044666
# step size too small or too large
# RUN  9 , total integrated cost =  4.147757789051479
# RUN  9 , total integrated cost mean =  4.147757789051479
# Improved over  9  iterations in  11.32688413496362  seconds by  54.33210065665866  percent.
# rep_ind =  30.177845936037365
# cost =  6.604402815147046
# iteration =  18
# cost =  0.0
# iteration =  24
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3688.660142101727
# Gradient descend method:  None
# RUN  1 , total integrated cost =  158.67533222826688
# RUN  2 , total integrated cost =  14.714503020837338
# RUN  3 , total integrated cost =  10.994852561096046
# RUN  3 , total integrated cost mean =  10.994852561096046
# Improved over  3  iterations in  1.6810618589515798  seconds by  99.70192828459302  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  10.964655691064914
# Gradient descend method:  None
# RUN  1 , total integrated cost =  8.796919571994263
# RUN  2 , total integrated cost =  7.904397634684483
# RUN  3 , total integrated cost =  6.499621232586675
# RUN  4 , total integrated cost =  5.939971793662547
# RUN  5 , total integrated cost =  5.280528748298321
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  6 , total integrated cost =  5.211831847121343
# RUN  7 , total integrated cost =  5.231014186133258
# step size too small or too large
# step size too small or too large
# RUN  8 , total integrated cost =  5.103912110244848
# RUN  9 , total integrated cost =  5.264057904149196
# RUN  10 , total integrated cost =  4.952019629980145
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  11 , total integrated cost =  4.90789601205631
# step size too small or too large
# RUN  12 , total integrated cost =  4.910588065919815
# RUN  13 , total integrated cost =  4.547764954880145
# RUN  14 , total integrated cost =  4.415121984366324
# RUN  15 , total integrated cost =  4.616950236065728
# step size too small or too large
# step size too small or too large
# RUN  16 , total integrated cost =  4.659915587518246
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  17 , total integrated cost =  4.831745952736114
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  18 , total integrated cost =  4.423537067265142
# step size too small or too large
# RUN  19 , total integrated cost =  4.360613491416929
# RUN  20 , total integrated cost =  4.1119665995472445
# RUN  21 , total integrated cost mean =  4.268173634596915
# Improved over  21  iterations in  27.105423950997647  seconds by  61.07334553081275  percent.
# cost =  4.507279090367318
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3675.353662305545
# Gradient descend method:  None
# RUN  1 , total integrated cost =  140.9644404002105
# RUN  2 , total integrated cost =  44.32262109046659
# RUN  3 , total integrated cost =  11.891464505337197
# RUN  3 , total integrated cost mean =  11.891464505337197
# Improved over  3  iterations in  1.7194940809858963  seconds by  99.67645387089422  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11.971781423371887
# Gradient descend method:  None
# RUN  1 , total integrated cost =  9.65780560048773
# RUN  2 , total integrated cost =  9.1783558230404
# step size too small or too large
# RUN  3 , total integrated cost =  9.058419258188822
# RUN  4 , total integrated cost =  8.92574796019135
# RUN  5 , total integrated cost =  8.742837420069575
# RUN  6 , total integrated cost =  8.696649699059424
# RUN  7 , total integrated cost =  8.629577983840326
# step size too small or too large
# step size too small or too large
# RUN  8 , total integrated cost =  8.564587796569473
# RUN  9 , total integrated cost =  8.557698278777362
# RUN  10 , total integrated cost =  8.496047725073993
# RUN  11 , total integrated cost =  8.48179406848027
# RUN  12 , total integrated cost =  8.446342957653949
# RUN  13 , total integrated cost =  8.402530750641402
# RUN  14 , total integrated cost =  8.334144931335045
# RUN  15 , total integrated cost =  8.28837883957721
# step size too small or too large
# step size too small or too large
# RUN  16 , total integrated cost =  8.232629060359852
# RUN  17 , total integrated cost =  8.196011397090675
# RUN  18 , total integrated cost =  8.189039233745326
# step size too small or too large
# RUN  19 , total integrated cost =  8.07745143591037
# step size too small or too large
# RUN  20 , total integrated cost =  8.045726494997714
# RUN  21 , total integrated cost mean =  8.024369040363224
# Improved over  21  iterations in  24.38784174801549  seconds by  32.972639938967944  percent.
# rep_ind =  36.86875796558927
# n =  30
# cost =  8.420241236679468
# iteration =  6
# cost =  0.0
# iteration =  12
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3681.9462500293175
# Gradient descend method:  None
# RUN  1 , total integrated cost =  155.48132006961012
# RUN  2 , total integrated cost =  98.92785435502748
# RUN  3 , total integrated cost =  52.47353338653674
# RUN  3 , total integrated cost mean =  52.47353338653674
# Improved over  3  iterations in  5.137132359028328  seconds by  98.57484249298537  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  52.33076300077026
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12.293605052937602
# RUN  2 , total integrated cost =  9.529401116026905
# step size too small or too large
# RUN  3 , total integrated cost =  8.939027630492346
# RUN  4 , total integrated cost =  8.627490687403567
# step size too small or too large
# RUN  5 , total integrated cost =  8.522206500258246
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  6 , total integrated cost =  8.40045137043714
# RUN  7 , total integrated cost =  8.359168890121603
# RUN  8 , total integrated cost =  8.245564862276847
# RUN  9 , total integrated cost =  8.028228584815656
# RUN  9 , total integrated cost mean =  8.028228584815656
# Improved over  9  iterations in  29.604930511966813  seconds by  84.65868234197639  percent.
# cost =  8.108575243867724
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3689.060158054663
# Gradient descend method:  None
# RUN  1 , total integrated cost =  149.27907346372743
# RUN  2 , total integrated cost =  13.87053945631269
# RUN  3 , total integrated cost =  10.336711367052626
# RUN  3 , total integrated cost mean =  10.336711367052626
# Improved over  3  iterations in  5.822945698047988  seconds by  99.71980095405917  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  10.183495406745296
# Gradient descend method:  None
# RUN  1 , total integrated cost =  8.324951107470014
# step size too small or too large
# step size too small or too large
# RUN  2 , total integrated cost =  7.283752804657236
# step size too small or too large
# step size too small or too large
# RUN  3 , total integrated cost =  5.735700781042212
# RUN  4 , total integrated cost =  4.34656322833093
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  5 , total integrated cost =  4.212978852584778
# RUN  6 , total integrated cost =  4.105027126496257
# step size too small or too large
# RUN  7 , total integrated cost =  4.009917304809796
# RUN  8 , total integrated cost =  3.971768691377519
# RUN  9 , total integrated cost =  3.9456472989245364
# RUN  9 , total integrated cost mean =  3.9456472989245364
# Improved over  9  iterations in  30.50190150004346  seconds by  61.254489334663646  percent.
# rep_ind =  31.240032797048155
# cost =  5.666586037520678
# iteration =  18
# cost =  0.0
# iteration =  24
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3681.8429328905745
# Gradient descend method:  None
# RUN  1 , total integrated cost =  155.2481207061651
# RUN  2 , total integrated cost =  10.717708962639783
# RUN  3 , total integrated cost =  9.398602472264363
# RUN  3 , total integrated cost mean =  9.398602472264363
# Improved over  3  iterations in  5.118403328990098  seconds by  99.7447310316172  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  8.810185305176573
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.872273386049579
# step size too small or too large
# RUN  2 , total integrated cost =  5.485781866966002
# RUN  3 , total integrated cost =  5.001682631287553
# step size too small or too large
# RUN  4 , total integrated cost =  4.324611401576507
# RUN  5 , total integrated cost =  4.101502491028481
# step size too small or too large
# step size too small or too large
# RUN  6 , total integrated cost =  4.001573054324293
# RUN  7 , total integrated cost =  3.9281248908455546
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  8 , total integrated cost =  3.904970382440545
# step size too small or too large
# RUN  9 , total integrated cost =  3.8666868857920416
# step size too small or too large
# step size too small or too large
# RUN  10 , total integrated cost =  3.9356561376919306
# step size too small or too large
# step size too small or too large
# RUN  11 , total integrated cost =  3.8398133474162437
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  12 , total integrated cost =  3.8510326873438867
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  13 , total integrated cost =  3.8522585477263176
# step size too small or too large
# step size too small or too large
# RUN  14 , total integrated cost =  3.859894996040089
# step size too small or too large
# step size too small or too large
# RUN  15 , total integrated cost =  3.8211420596313093
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  16 , total integrated cost =  3.810841678532986
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  17 , total integrated cost =  3.852897403479874
# RUN  18 , total integrated cost =  3.83292241414442
# step size too small or too large
# RUN  19 , total integrated cost =  3.8376057039178133
# step size too small or too large
# step size too small or too large
# RUN  20 , total integrated cost =  3.8059767554256907
# step size too small or too large
# step size too small or too large
# RUN  21 , total integrated cost mean =  3.8290088814034617
# Improved over  21  iterations in  74.1063894930412  seconds by  56.538838301690845  percent.
# cost =  3.8591503736575796
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3682.9679545056
# Gradient descend method:  None
# RUN  1 , total integrated cost =  148.54141927088412
# RUN  2 , total integrated cost =  54.77104567032564
# RUN  3 , total integrated cost =  38.27128364721995
# RUN  3 , total integrated cost mean =  38.27128364721995
# Improved over  3  iterations in  5.112824999028817  seconds by  98.96085754424226  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  37.867871969843925
# Gradient descend method:  None
# RUN  1 , total integrated cost =  8.98708661897006
# RUN  2 , total integrated cost =  6.795575297940056
# RUN  3 , total integrated cost =  6.206560275641601
# RUN  4 , total integrated cost =  6.0602467654199295
# step size too small or too large
# step size too small or too large
# RUN  5 , total integrated cost =  5.947525219424368
# step size too small or too large
# step size too small or too large
# RUN  6 , total integrated cost =  5.82428208581689
# RUN  7 , total integrated cost =  5.80841803288851
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  8 , total integrated cost =  5.736004780873445
# step size too small or too large
# RUN  9 , total integrated cost =  5.718954231466922
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  10 , total integrated cost =  5.60973088077028
# RUN  11 , total integrated cost =  5.557468570783373
# step size too small or too large
# step size too small or too large
# RUN  12 , total integrated cost =  5.472214399262324
# RUN  13 , total integrated cost =  5.441426567308263
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  14 , total integrated cost =  5.3718140309004685
# step size too small or too large
# RUN  15 , total integrated cost =  5.308900456143447
# RUN  16 , total integrated cost =  5.264496308456882
# step size too small or too large
# step size too small or too large
# RUN  17 , total integrated cost =  5.228026692470063
# step size too small or too large
# step size too small or too large
# RUN  18 , total integrated cost =  5.197347513118968
# step size too small or too large
# step size too small or too large
# RUN  19 , total integrated cost =  5.130174237540838
# step size too small or too large
# step size too small or too large
# RUN  20 , total integrated cost =  5.055440383094688
# RUN  21 , total integrated cost mean =  4.98146021229604
# Improved over  21  iterations in  70.12843626900576  seconds by  86.84515407609113  percent.
# rep_ind =  9.799626851509583
# n =  50
# cost =  8.3714383752926
# iteration =  6
# cost =  0.0
# iteration =  12
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3680.6728836339717
# Gradient descend method:  None
# RUN  1 , total integrated cost =  152.05761595369106
# RUN  2 , total integrated cost =  24.672125636112074
# RUN  3 , total integrated cost =  12.275866490785736
# RUN  3 , total integrated cost mean =  12.275866490785736
# Improved over  3  iterations in  8.981107798987068  seconds by  99.66647765561102  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12.075819030168192
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.99833506523519
# RUN  2 , total integrated cost =  5.578448500532447
# RUN  3 , total integrated cost =  4.832887817289628
# step size too small or too large
# RUN  4 , total integrated cost =  4.643107057146984
# step size too small or too large
# step size too small or too large
# RUN  5 , total integrated cost =  4.754833986548556
# RUN  6 , total integrated cost =  4.577056060083724
# step size too small or too large
# RUN  7 , total integrated cost =  4.8320135968071565
# step size too small or too large
# step size too small or too large
# RUN  8 , total integrated cost =  4.552182055542257
# step size too small or too large
# RUN  9 , total integrated cost =  4.547725685880312
# RUN  9 , total integrated cost mean =  4.547725685880312
# Improved over  9  iterations in  53.78942601796007  seconds by  62.34022988818364  percent.
# cost =  4.862726957166849
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3680.831472646616
# Gradient descend method:  None
# RUN  1 , total integrated cost =  154.71879962242946
# RUN  2 , total integrated cost =  33.000598814170246
# RUN  3 , total integrated cost =  20.685412737209113
# RUN  3 , total integrated cost mean =  20.685412737209113
# Improved over  3  iterations in  9.078852329985239  seconds by  99.4380233680643  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  20.699360044044067
# Gradient descend method:  None
# RUN  1 , total integrated cost =  10.152654468913285
# RUN  2 , total integrated cost =  8.08777068186928
# RUN  3 , total integrated cost =  5.619178433186877
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  4 , total integrated cost =  5.366785575991695
# RUN  5 , total integrated cost =  5.000518394142294
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  6 , total integrated cost =  4.792395398986302
# step size too small or too large
# step size too small or too large
# RUN  7 , total integrated cost =  4.583443380300462
# step size too small or too large
# RUN  8 , total integrated cost =  4.58372036263933
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  9 , total integrated cost =  4.634254383176394
# RUN  9 , total integrated cost mean =  4.634254383176394
# Improved over  9  iterations in  55.7926889579976  seconds by  77.61160551188232  percent.
# rep_ind =  2.695803931053713
# cost =  3.844146035587097
# iteration =  18
# cost =  0.0
# iteration =  24
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3681.429017950654
# Gradient descend method:  None
# RUN  1 , total integrated cost =  145.71112468639984
# RUN  2 , total integrated cost =  32.49142644250884
# RUN  3 , total integrated cost =  9.120875205667645
# RUN  3 , total integrated cost mean =  9.120875205667645
# Improved over  3  iterations in  9.38738241797546  seconds by  99.7522463380064  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  9.039041803142128
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.212658400419614
# step size too small or too large
# RUN  2 , total integrated cost =  6.836204719292358
# step size too small or too large
# step size too small or too large
# RUN  3 , total integrated cost =  6.704560499036046
# step size too small or too large
# RUN  4 , total integrated cost =  6.60491124845171
# RUN  5 , total integrated cost =  6.544669980981874
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  6 , total integrated cost =  6.482793387740092
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  7 , total integrated cost =  6.365343036434561
# RUN  8 , total integrated cost =  6.325765585687286
# RUN  9 , total integrated cost =  6.261929361434183
# step size too small or too large
# step size too small or too large
# RUN  10 , total integrated cost =  6.178752535104728
# RUN  11 , total integrated cost =  6.160434564187628
# step size too small or too large
# RUN  12 , total integrated cost =  6.113663795820863
# step size too small or too large
# RUN  13 , total integrated cost =  6.076992026491227
# step size too small or too large
# RUN  14 , total integrated cost =  6.0088203432033245
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  15 , total integrated cost =  5.961144085005453
# step size too small or too large
# step size too small or too large
# RUN  16 , total integrated cost =  5.902908707312752
# RUN  17 , total integrated cost =  5.845520016149602
# RUN  18 , total integrated cost =  5.794812362815927
# step size too small or too large
# RUN  19 , total integrated cost =  5.7501713435691535
# step size too small or too large
# RUN  20 , total integrated cost =  5.705481703435026
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  21 , total integrated cost mean =  5.6664440335368536
# Improved over  21  iterations in  114.0182920700172  seconds by  37.311452287264565  percent.
# cost =  5.698869847862167
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3683.9674644561014
# Gradient descend method:  None
# RUN  1 , total integrated cost =  143.96494413781488
# RUN  2 , total integrated cost =  25.32380014430614
# RUN  3 , total integrated cost =  7.493996306870038
# RUN  3 , total integrated cost mean =  7.493996306870038
# Improved over  3  iterations in  8.754792046034709  seconds by  99.7965781082712  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7.438529641188573
# Gradient descend method:  None
# step size too small or too large
# step size too small or too large
# RUN  1 , total integrated cost =  5.783791788494865
# step size too small or too large
# step size too small or too large
# RUN  2 , total integrated cost =  5.443006738993742
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  3 , total integrated cost =  5.316740746058858
# step size too small or too large
# RUN  4 , total integrated cost =  5.237817757050955
# RUN  5 , total integrated cost =  5.140652791353171
# step size too small or too large
# RUN  6 , total integrated cost =  5.084198758944889
# step size too small or too large
# RUN  7 , total integrated cost =  4.994841750268057
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  8 , total integrated cost =  4.964756376458722
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  9 , total integrated cost =  4.956209256802311
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  10 , total integrated cost =  4.842437731613675
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  11 , total integrated cost =  4.793742972888104
# step size too small or too large
# step size too small or too large
# RUN  12 , total integrated cost =  4.727942819190607
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  13 , total integrated cost =  4.695269383948682
# step size too small or too large
# step size too small or too large
# RUN  14 , total integrated cost =  4.633281306238561
# step size too small or too large
# RUN  15 , total integrated cost =  4.57249237221136
# step size too small or too large
# step size too small or too large
# RUN  16 , total integrated cost =  4.517609560935935
# step size too small or too large
# RUN  17 , total integrated cost =  4.46632933215297
# RUN  18 , total integrated cost =  4.421037617031174
# step size too small or too large
# RUN  19 , total integrated cost =  4.353953387201486
# step size too small or too large
# RUN  20 , total integrated cost =  4.238998491619604
# RUN  21 , total integrated cost mean =  4.20316493938062
# Improved over  21  iterations in  114.28746774303727  seconds by  43.494680506388185  percent.
# rep_ind =  11.815657120011657
# sigma =  0.03
# set cost params:  0.008817022660197538 0.0 1.0
# n =  2
# cost =  6.034617451189613
# iteration =  6
# cost =  0.0
# iteration =  12
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1214.5795434473885
# Gradient descend method:  None
# RUN  1 , total integrated cost =  68.40985761525616
# RUN  2 , total integrated cost =  44.98765720630158
# RUN  3 , total integrated cost =  11.083591491454857
# RUN  3 , total integrated cost mean =  11.083591491454857
# Improved over  3  iterations in  0.395487270958256  seconds by  99.08745445687354  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12.482498662371139
# Gradient descend method:  None
# RUN  1 , total integrated cost =  8.985861466851969
# RUN  2 , total integrated cost =  8.892268551653938
# step size too small or too large
# RUN  3 , total integrated cost =  8.098094693826006
# RUN  4 , total integrated cost =  8.60422981876507
# RUN  5 , total integrated cost =  8.280311261689704
# RUN  6 , total integrated cost =  8.312690174400851
# RUN  7 , total integrated cost =  7.98632226523745
# RUN  8 , total integrated cost =  8.155443587227584
# RUN  9 , total integrated cost =  7.944778460428717
# RUN  9 , total integrated cost mean =  7.944778460428717
# Improved over  9  iterations in  1.966172607964836  seconds by  36.35265922856866  percent.
# cost =  8.204714449466445
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1237.7064954706116
# Gradient descend method:  None
# RUN  1 , total integrated cost =  66.40092472896485
# RUN  2 , total integrated cost =  50.6047748179797
# RUN  3 , total integrated cost =  21.926714028612153
# RUN  3 , total integrated cost mean =  21.926714028612153
# Improved over  3  iterations in  0.3299844849971123  seconds by  98.22843993233832  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  20.247470897365986
# Gradient descend method:  None
# RUN  1 , total integrated cost =  10.193086539842998
# RUN  2 , total integrated cost =  9.26515279385978
# RUN  3 , total integrated cost =  8.756646686849212
# RUN  4 , total integrated cost =  8.86237948170801
# RUN  5 , total integrated cost =  8.694209209136593
# RUN  6 , total integrated cost =  8.616784883723913
# RUN  7 , total integrated cost =  8.872299059060708
# RUN  8 , total integrated cost =  8.392758736173104
# RUN  9 , total integrated cost =  8.609393179182495
# RUN  9 , total integrated cost mean =  8.609393179182495
# Improved over  9  iterations in  1.8755463999696076  seconds by  57.479167532462036  percent.
# rep_ind =  8.403551035677982
# cost =  7.9792319701713685
# iteration =  18
# cost =  0.0
# iteration =  24
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1222.1670973127796
# Gradient descend method:  None
# RUN  1 , total integrated cost =  81.74190211713844
# RUN  2 , total integrated cost =  28.59756187955551
# RUN  3 , total integrated cost =  10.338615536976665
# RUN  3 , total integrated cost mean =  10.338615536976665
# Improved over  3  iterations in  0.4254006079863757  seconds by  99.15407512117545  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  9.620994487540454
# Gradient descend method:  None
# RUN  1 , total integrated cost =  8.985549263536248
# RUN  2 , total integrated cost =  8.928581892496794
# RUN  3 , total integrated cost =  8.330223311378328
# RUN  4 , total integrated cost =  8.481914272510576
# RUN  5 , total integrated cost =  8.322314067132217
# RUN  6 , total integrated cost =  8.19881431156048
# RUN  7 , total integrated cost =  8.544373082248306
# RUN  8 , total integrated cost =  8.075701432709197
# RUN  9 , total integrated cost =  7.999114365056428
# RUN  10 , total integrated cost =  7.889592574220654
# RUN  11 , total integrated cost =  7.830657508709809
# RUN  12 , total integrated cost =  7.837831491680445
# RUN  13 , total integrated cost =  7.531112606656807
# RUN  14 , total integrated cost =  7.827519107317405
# RUN  15 , total integrated cost =  7.5945818808138945
# RUN  16 , total integrated cost =  7.734350969343462
# RUN  17 , total integrated cost =  7.281206384968248
# RUN  18 , total integrated cost =  7.418413636008691
# RUN  19 , total integrated cost =  7.463694835388391
# RUN  20 , total integrated cost =  7.380041963081668
# RUN  21 , total integrated cost mean =  7.398232838450247
# Improved over  21  iterations in  4.544955566991121  seconds by  23.10324210214199  percent.
# cost =  7.586064637505087
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1233.6318633088458
# Gradient descend method:  None
# RUN  1 , total integrated cost =  73.9239945633355
# RUN  2 , total integrated cost =  37.331360304304795
# RUN  3 , total integrated cost =  41.18560449242634
# RUN  3 , total integrated cost mean =  41.18560449242634
# Improved over  3  iterations in  0.44585158000700176  seconds by  96.6614347669362  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  39.123736891021046
# Gradient descend method:  None
# RUN  1 , total integrated cost =  38.42937535628509
# RUN  2 , total integrated cost =  42.02452149338004
# RUN  3 , total integrated cost =  43.26122354008975
# RUN  4 , total integrated cost =  40.96288348326367
# RUN  5 , total integrated cost =  20.860040177801658
# RUN  6 , total integrated cost =  18.32821523674368
# RUN  7 , total integrated cost =  18.350364589286485
# RUN  8 , total integrated cost =  17.80169741679961
# RUN  9 , total integrated cost =  17.802758369377578
# RUN  10 , total integrated cost =  17.8721203484608
# RUN  11 , total integrated cost =  17.38831723627932
# RUN  12 , total integrated cost =  17.425743950205195
# RUN  13 , total integrated cost =  17.21029107412164
# RUN  14 , total integrated cost =  16.917624095097093
# RUN  15 , total integrated cost =  16.782733798446138
# RUN  16 , total integrated cost =  16.580079584635012
# RUN  17 , total integrated cost =  16.680987248536987
# RUN  18 , total integrated cost =  16.52428386392293
# RUN  19 , total integrated cost =  16.473826229464773
# RUN  20 , total integrated cost =  16.30210140710897
# RUN  21 , total integrated cost mean =  16.487797053315994
# Improved over  21  iterations in  5.38240791100543  seconds by  57.85730514638042  percent.
# rep_ind =  66.49031216394215
# n =  10
# cost =  7.088383324495073
# iteration =  6
# cost =  0.0
# iteration =  12
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1231.2358651506063
# Gradient descend method:  None
# RUN  1 , total integrated cost =  57.2219139900507
# RUN  2 , total integrated cost =  19.240118264757093
# RUN  3 , total integrated cost =  9.155861932623855
# RUN  3 , total integrated cost mean =  9.155861932623855
# Improved over  3  iterations in  1.726882544986438  seconds by  99.25636815887394  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  9.406301038476425
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.8379831247878355
# step size too small or too large
# RUN  2 , total integrated cost =  7.741963255791637
# RUN  3 , total integrated cost =  7.48127667404884
# step size too small or too large
# step size too small or too large
# RUN  4 , total integrated cost =  7.434863000602047
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  5 , total integrated cost =  7.2514962685671005
# RUN  6 , total integrated cost =  7.041718563367617
# RUN  7 , total integrated cost =  6.9380438652038805
# RUN  8 , total integrated cost =  6.799156760059759
# RUN  9 , total integrated cost =  6.724710494831879
# RUN  9 , total integrated cost mean =  6.724710494831879
# Improved over  9  iterations in  9.850461649009958  seconds by  28.508449098912664  percent.
# cost =  6.835812453035855
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1226.2761318092678
# Gradient descend method:  None
# RUN  1 , total integrated cost =  52.491662009118826
# RUN  2 , total integrated cost =  27.837463070722343
# RUN  3 , total integrated cost =  12.170670911353266
# RUN  3 , total integrated cost mean =  12.170670911353266
# Improved over  3  iterations in  1.6746558040031232  seconds by  99.0075097610033  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12.04308777763943
# Gradient descend method:  None
# RUN  1 , total integrated cost =  10.352001075488236
# RUN  2 , total integrated cost =  9.981671719406554
# RUN  3 , total integrated cost =  9.942467091286513
# RUN  4 , total integrated cost =  9.837122804541076
# RUN  5 , total integrated cost =  9.7858261867112
# RUN  6 , total integrated cost =  9.821091676464151
# RUN  7 , total integrated cost =  9.598124888406899
# RUN  8 , total integrated cost =  9.523561947150371
# RUN  9 , total integrated cost =  9.387775218366613
# RUN  9 , total integrated cost mean =  9.387775218366613
# Improved over  9  iterations in  9.183187075948808  seconds by  22.04843648323292  percent.
# rep_ind =  22.111874136357258
# cost =  4.841245880860131
# iteration =  18
# cost =  0.0
# iteration =  24
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1224.697820899119
# Gradient descend method:  None
# RUN  1 , total integrated cost =  48.38363434700456
# RUN  2 , total integrated cost =  14.321452282804188
# RUN  3 , total integrated cost =  6.681327688138774
# RUN  3 , total integrated cost mean =  6.681327688138774
# Improved over  3  iterations in  1.5829096379457042  seconds by  99.45445092053535  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  6.80105095735762
# Gradient descend method:  None
# step size too small or too large
# RUN  1 , total integrated cost =  6.14646257887812
# RUN  2 , total integrated cost =  5.864041606918965
# RUN  3 , total integrated cost =  5.59636271331169
# step size too small or too large
# RUN  4 , total integrated cost =  5.6809138818612155
# RUN  5 , total integrated cost =  5.329561138927724
# RUN  6 , total integrated cost =  5.258755724520367
# RUN  7 , total integrated cost =  5.054356596284302
# RUN  8 , total integrated cost =  4.819172923835437
# step size too small or too large
# step size too small or too large
# RUN  9 , total integrated cost =  4.825858924318695
# RUN  10 , total integrated cost =  4.729236565593908
# RUN  11 , total integrated cost =  4.722619675189482
# step size too small or too large
# RUN  12 , total integrated cost =  4.605953377570864
# step size too small or too large
# step size too small or too large
# RUN  13 , total integrated cost =  4.583010633985446
# RUN  14 , total integrated cost =  4.404408900819705
# RUN  15 , total integrated cost =  4.550715444172216
# step size too small or too large
# step size too small or too large
# RUN  16 , total integrated cost =  4.592022405545248
# RUN  17 , total integrated cost =  4.4388385893122715
# RUN  18 , total integrated cost =  4.454354160456917
# RUN  19 , total integrated cost =  4.561879404678433
# RUN  20 , total integrated cost =  4.353418739644824
# RUN  21 , total integrated cost mean =  4.303344110412476
# Improved over  21  iterations in  22.040691875037737  seconds by  36.725307053361156  percent.
# cost =  4.50266772807846
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1228.705723228213
# Gradient descend method:  None
# RUN  1 , total integrated cost =  52.45366556737732
# RUN  2 , total integrated cost =  10.965805093213387
# RUN  3 , total integrated cost =  5.90511188254751
# RUN  3 , total integrated cost mean =  5.90511188254751
# Improved over  3  iterations in  1.5518798130215146  seconds by  99.5194038921677  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5.757533388957981
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.085953751839024
# RUN  2 , total integrated cost =  4.8779687334432875
# RUN  3 , total integrated cost =  4.672975767869843
# step size too small or too large
# RUN  4 , total integrated cost =  4.505659706915688
# RUN  5 , total integrated cost =  4.593659565736706
# RUN  6 , total integrated cost =  4.56904913300008
# RUN  7 , total integrated cost =  4.6261123950689065
# RUN  8 , total integrated cost =  4.5531554070766
# RUN  9 , total integrated cost =  4.342451545413321
# RUN  10 , total integrated cost =  4.235817511906896
# RUN  11 , total integrated cost =  4.329546028934216
# RUN  12 , total integrated cost =  4.374462503577081
# RUN  13 , total integrated cost =  4.338705764900082
# RUN  14 , total integrated cost =  4.449954709042538
# RUN  15 , total integrated cost =  4.1809620710969995
# RUN  16 , total integrated cost =  4.29921282399034
# step size too small or too large
# RUN  17 , total integrated cost =  4.265591127470338
# step size too small or too large
# RUN  18 , total integrated cost =  4.345069939025697
# step size too small or too large
# step size too small or too large
# RUN  19 , total integrated cost =  4.350056804471878
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  20 , total integrated cost =  4.175729085776376
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  21 , total integrated cost mean =  4.167514077383382
# Improved over  21  iterations in  22.935401635011658  seconds by  27.61632810717171  percent.
# rep_ind =  2.234291418985073
# n =  30
# cost =  5.6308505162360944
# iteration =  6
# cost =  0.0
# iteration =  12
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1223.7489005215868
# Gradient descend method:  None
# RUN  1 , total integrated cost =  57.37682881113651
# RUN  2 , total integrated cost =  20.240105785921504
# RUN  3 , total integrated cost =  9.065190668435802
# RUN  3 , total integrated cost mean =  9.065190668435802
# Improved over  3  iterations in  4.973652236978523  seconds by  99.2592278804441  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  9.275154374686585
# Gradient descend method:  None
# RUN  1 , total integrated cost =  8.320409052021827
# step size too small or too large
# step size too small or too large
# RUN  2 , total integrated cost =  7.9783187005766125
# step size too small or too large
# RUN  3 , total integrated cost =  7.859502374584495
# RUN  4 , total integrated cost =  7.433091240329703
# RUN  5 , total integrated cost =  7.4126039989376915
# RUN  6 , total integrated cost =  7.065899202059883
# RUN  7 , total integrated cost =  6.728252867873794
# step size too small or too large
# RUN  8 , total integrated cost =  6.514081126132369
# step size too small or too large
# RUN  9 , total integrated cost =  6.342677136344256
# RUN  9 , total integrated cost mean =  6.342677136344256
# Improved over  9  iterations in  28.02280300599523  seconds by  31.61647903506102  percent.
# cost =  6.494734729093741
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1227.6685012989385
# Gradient descend method:  None
# RUN  1 , total integrated cost =  57.65549133924982
# RUN  2 , total integrated cost =  16.332457306357842
# RUN  3 , total integrated cost =  7.488509546442506
# RUN  3 , total integrated cost mean =  7.488509546442506
# Improved over  3  iterations in  4.9397357199923135  seconds by  99.390021855369  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7.474433127464619
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.616396735993748
# step size too small or too large
# step size too small or too large
# RUN  2 , total integrated cost =  6.294221397777739
# RUN  3 , total integrated cost =  6.0961139998036575
# step size too small or too large
# step size too small or too large
# RUN  4 , total integrated cost =  6.0410134099978965
# step size too small or too large
# step size too small or too large
# RUN  5 , total integrated cost =  5.9777892726878745
# step size too small or too large
# step size too small or too large
# RUN  6 , total integrated cost =  5.7715049439227615
# step size too small or too large
# RUN  7 , total integrated cost =  5.552183130062162
# RUN  8 , total integrated cost =  5.555795652816584
# step size too small or too large
# RUN  9 , total integrated cost =  5.5171647713481695
# RUN  9 , total integrated cost mean =  5.5171647713481695
# Improved over  9  iterations in  28.550570530002005  seconds by  26.186177904576  percent.
# rep_ind =  8.525022484492876
# cost =  4.504938603718155
# iteration =  18
# cost =  0.0
# iteration =  24
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1225.1235396319476
# Gradient descend method:  None
# RUN  1 , total integrated cost =  59.39458553288852
# RUN  2 , total integrated cost =  14.000913626739653
# RUN  3 , total integrated cost =  6.601951736273795
# RUN  3 , total integrated cost mean =  6.601951736273795
# Improved over  3  iterations in  4.962664449994918  seconds by  99.46111950977146  percent.
# interpolate adjoint :  True True True
# ...
# cost =  6.65518096567059
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  520.4408918051873
# Gradient descend method:  None
# RUN  1 , total integrated cost =  35.10176838322168
# RUN  2 , total integrated cost =  13.116514268713548
# RUN  3 , total integrated cost =  8.055116826507613
# RUN  3 , total integrated cost mean =  8.055116826507613
# Improved over  3  iterations in  4.546487411018461  seconds by  98.45225135969469  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  8.233592795119192
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.574186784681151
# step size too small or too large
# RUN  2 , total integrated cost =  7.415091461537881
# RUN  3 , total integrated cost =  7.004262461459125
# step size too small or too large
# RUN  4 , total integrated cost =  6.936118770874802
# RUN  5 , total integrated cost =  6.657169348916023
# step size too small or too large
# step size too small or too large
# RUN  6 , total integrated cost =  6.155924733439231
# RUN  7 , total integrated cost =  6.387240126040321
# step size too small or too large
# RUN  8 , total integrated cost =  6.230963973078672
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  9 , total integrated cost =  6.0915035643254685
# RUN  9 , total integrated cost mean =  6.0915035643254685
# Improved over  9  iterations in  26.933885877020657  seconds by  26.01645823514052  percent.
# rep_ind =  8.713116104028463
# cost =  6.643703946029167
# iteration =  18
# cost =  0.0
# iteration =  24
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  524.2255053493755
# Gradient descend method:  None
# RUN  1 , total integrated cost =  40.984094769647854
# RUN  2 , total integrated cost =  19.550622575790783
# RUN  3 , total integrated cost =  10.230841097667446
# RUN  3 , total integrated cost mean =  10.230841097667446
# Improved over  3  iterations in  4.63812619401142  seconds by  98.04838929177072  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  10.211104287962321
# Gradient descend method:  None
# RUN  1 , total integrated cost =  9.4374705037231
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  2 , total integrated cost =  8.83575648341969
# step size too small or too large
# RUN  3 , total integrated cost =  8.130134235761664
# step size too small or too large
# step size too small or too large
# RUN  4 , total integrated cost =  8.162407240946603
# RUN  5 , total integrated cost =  7.8416471074027045
# RUN  6 , total integrated cost =  7.563580379264878
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  7 , total integrated cost =  7.2826436551746525
# step size too small or too large
# RUN  8 , total integrated cost =  6.946268496502189
# RUN  9 , total integrated cost =  6.875240974093404
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  10 , total integrated cost =  6.54499925958599
# RUN  11 , total integrated cost =  6.225513894837648
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  12 , total integrated cost =  6.076684508152783
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  13 , total integrated cost =  5.69213486673267
# step size too small or too large
# RUN  14 , total integrated cost =  6.0079566602250685
# RUN  15 , total integrated cost =  5.793120942881824
# step size too small or too large
# RUN  16 , total integrated cost =  5.7425111537546885
# RUN  17 , total integrated cost =  5.768062665281752
# RUN  18 , total integrated cost =  5.833624367651162
# RUN  19 , total integrated cost =  5.523753555412297
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  20 , total integrated cost =  5.599613918289146
# step size too small or too large
# RUN  21 , total integrated cost mean =  5.752134496173629
# Improved over  21  iterations in  64.85401267197449  seconds by  43.66785086158886  percent.
# cost =  5.906071389446372
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  522.7656159238168
# Gradient descend method:  None
# RUN  1 , total integrated cost =  39.02430812590658
# RUN  2 , total integrated cost =  10.139372083631041
# RUN  3 , total integrated cost =  7.2114333813187885
# RUN  3 , total integrated cost mean =  7.2114333813187885
# Improved over  3  iterations in  4.896314111014362  seconds by  98.62052262779851  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7.32324289765006
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.388213609785989
# RUN  2 , total integrated cost =  6.071986528078416
# step size too small or too large
# RUN  3 , total integrated cost =  5.851093912382813
# step size too small or too large
# step size too small or too large
# RUN  4 , total integrated cost =  5.817918952406329
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  5 , total integrated cost =  5.858027790684222
# RUN  6 , total integrated cost =  5.9181338535035755
# RUN  7 , total integrated cost =  5.889215075220735
# RUN  8 , total integrated cost =  5.690831903465489
# RUN  9 , total integrated cost =  5.753425854559049
# step size too small or too large
# step size too small or too large
# RUN  10 , total integrated cost =  5.897484172131696
# step size too small or too large
# RUN  11 , total integrated cost =  6.642095404326006
# no cost improvement
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  12 , total integrated cost =  5.620080827442256
# step size too small or too large
# step size too small or too large
# RUN  13 , total integrated cost =  5.78255258758531
# RUN  13 , total integrated cost mean =  5.78255258758531
# Improved over  13  iterations in  41.3200392969884  seconds by  21.038361441747867  percent.
# rep_ind =  3.0549867652119547
# n =  50
# cost =  7.819066669299548
# iteration =  6
# cost =  0.0
# iteration =  12
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  518.2743203624734
# Gradient descend method:  None
# RUN  1 , total integrated cost =  20.816751463880145
# RUN  2 , total integrated cost =  11.067707387446779
# RUN  3 , total integrated cost =  7.471298299136938
# RUN  3 , total integrated cost mean =  7.471298299136938
# Improved over  3  iterations in  8.006460387026891  seconds by  98.55842784301726  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7.178605039809139
# Gradient descend method:  None
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  1 , total integrated cost =  6.865468738992608
# step size too small or too large
# step size too small or too large
# RUN  2 , total integrated cost =  6.363159766968184
# RUN  3 , total integrated cost =  5.922952812438968
# step size too small or too large
# RUN  4 , total integrated cost =  5.7128127591105855
# RUN  5 , total integrated cost =  5.933556976388405
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  6 , total integrated cost =  5.6820784500503905
# step size too small or too large
# RUN  7 , total integrated cost =  5.9460538632493956
# step size too small or too large
# RUN  8 , total integrated cost =  5.959108631183287
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  9 , total integrated cost =  5.799422396901189
# RUN  9 , total integrated cost mean =  5.799422396901189
# Improved over  9  iterations in  45.922118271992076  seconds by  19.212404572471357  percent.
# cost =  5.930604966965232
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  529.5530748481815
# Gradient descend method:  None
# RUN  1 , total integrated cost =  38.189558630135885
# RUN  2 , total integrated cost =  25.534569599676892
# RUN  3 , total integrated cost =  10.168844017392713
# RUN  3 , total integrated cost mean =  10.168844017392713
# Improved over  3  iterations in  8.396340081992093  seconds by  98.07973090887857  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  10.039647491833167
# Gradient descend method:  None
# step size too small or too large
# RUN  1 , total integrated cost =  9.244373200440453
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  2 , total integrated cost =  8.81553510068655
# step size too small or too large
# step size too small or too large
# RUN  3 , total integrated cost =  8.491602544383374
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  4 , total integrated cost =  8.053664976209289
# step size too small or too large
# RUN  5 , total integrated cost =  7.790844400685212
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  6 , total integrated cost =  7.226037673932092
# step size too small or too large
# RUN  7 , total integrated cost =  6.631820192483283
# RUN  8 , total integrated cost =  6.067230637495252
# step size too small or too large
# RUN  9 , total integrated cost =  5.764871586141444
# RUN  9 , total integrated cost mean =  5.764871586141444
# Improved over  9  iterations in  45.46547515800921  seconds by  42.57894422258425  percent.
# rep_ind =  3.847540199403106
# cost =  5.767866376962189
# iteration =  18
# cost =  0.0
# iteration =  24
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  524.0132643123321
# Gradient descend method:  None
# RUN  1 , total integrated cost =  28.32383794463382
# step size too small or too large
# RUN  2 , total integrated cost =  15.306684629533885
# RUN  3 , total integrated cost =  8.308362766128836
# RUN  3 , total integrated cost mean =  8.308362766128836
# Improved over  3  iterations in  8.097239969007205  seconds by  98.41447472192675  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  8.280933294640342
# Gradient descend method:  None
# step size too small or too large
# RUN  1 , total integrated cost =  7.766097055115786
# step size too small or too large
# RUN  2 , total integrated cost =  7.327562862097668
# step size too small or too large
# RUN  3 , total integrated cost =  7.013344108781947
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  4 , total integrated cost =  6.791486726033013
# step size too small or too large
# RUN  5 , total integrated cost =  6.13648575679563
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  6 , total integrated cost =  6.137272308719735
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  7 , total integrated cost =  5.983587079296569
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  8 , total integrated cost =  5.8102993958811116
# step size too small or too large
# RUN  9 , total integrated cost =  5.961436638789772
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  10 , total integrated cost =  5.863249663471806
# RUN  11 , total integrated cost =  5.931416186209671
# RUN  12 , total integrated cost =  5.931225714098787
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  13 , total integrated cost =  5.682368001460102
# step size too small or too large
# RUN  14 , total integrated cost =  5.632389468325372
# step size too small or too large
# RUN  15 , total integrated cost =  5.65976895234482
# RUN  16 , total integrated cost =  5.723117052289814
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  17 , total integrated cost =  5.934856499133463
# step size too small or too large
# RUN  18 , total integrated cost =  5.54455372908611
# RUN  19 , total integrated cost =  5.495289229325054
# step size too small or too large
# step size too small or too large
# RUN  20 , total integrated cost =  5.709459462943175
# step size too small or too large
# step size too small or too large
# RUN  21 , total integrated cost mean =  5.584250806620457
# Improved over  21  iterations in  112.65184280497488  seconds by  32.56495846627885  percent.
# cost =  5.919304988612426
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  520.8865349577228
# Gradient descend method:  None
# RUN  1 , total integrated cost =  26.963844449821813
# RUN  2 , total integrated cost =  10.932317222999732
# RUN  3 , total integrated cost =  7.7133736080385065
# RUN  3 , total integrated cost mean =  7.7133736080385065
# Improved over  3  iterations in  7.979397222981788  seconds by  98.51918352839269  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7.503069651300377
# Gradient descend method:  None
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  1 , total integrated cost =  6.691984408014192
# step size too small or too large
# RUN  2 , total integrated cost =  6.331617015900994
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  3 , total integrated cost =  6.202225213086541
# step size too small or too large
# step size too small or too large
# RUN  4 , total integrated cost =  5.90481307726196
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  5 , total integrated cost =  5.828098737759655
# RUN  6 , total integrated cost =  5.861903164229404
# step size too small or too large
# RUN  7 , total integrated cost =  5.7727565194886985
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  8 , total integrated cost =  5.7297474849965315
# step size too small or too large
# RUN  9 , total integrated cost =  5.505526324294542
# RUN  10 , total integrated cost =  5.788513795970053
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  11 , total integrated cost =  5.935029220400152
# step size too small or too large
# RUN  12 , total integrated cost =  6.102614053946976
# step size too small or too large
# step size too small or too large
# RUN  13 , total integrated cost =  5.6146379780208795
# RUN  14 , total integrated cost =  6.085180811859898
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  15 , total integrated cost =  5.626849544976219
# step size too small or too large
# RUN  16 , total integrated cost =  5.848831738709378
# RUN  17 , total integrated cost =  5.525524563577517
# step size too small or too large
# step size too small or too large
# RUN  18 , total integrated cost =  5.744068669788565
# RUN  19 , total integrated cost =  5.646000962231126
# RUN  20 , total integrated cost =  5.709693276351617
# RUN  21 , total integrated cost mean =  5.6655690982834015
# Improved over  21  iterations in  108.34533552796347  seconds by  24.489983945417777  percent.
# rep_ind =  3.5853449024474227

# %%
#len(sigma_array), 4, N_max, max_it

##### METHOD 4
method_ind = 3
step_method_ind = 0
step_m = 'S1'

for d in dict_list:
    
    if d['point'][0] != 0.5:
        continue
    if d['point'][1] != 0.5:
        continue
        
    print("Point = ", d['point'])
    aln.params.ext_exc_current = d['point'][0] * 5.
    aln.params.ext_inh_current = d['point'][1] * 5.
    
    max_it = d['cost'].shape[3]
    
    for s_ind in range(len(d['sigma'])):
        
        print("sigma = ", d['sigma'][s_ind])
        
        s = d['sigma'][s_ind]
        aln.params.sigma_ou = s
        c_p = d['cost_params'][s_ind]
        cost.setParams(c_p[0], c_p[1], c_p[2])
        
        target_ = d['target'][s_ind].copy()
        target_[0,0,:int(trans_time * dur / aln.params.dt)] = -1000
        target_[0,1,:int(trans_time * dur / aln.params.dt)] = -1000
                
        for n_ind in range(len(d['N_array'])):
            
            n_ = d['N_array'][n_ind]
            
            print("n = ", n_)
            aln.params.duration = dur
        
            for i_it in range(1,len(d['it_array'])):
            
                it = d['it_array'][i_it]
                print("iteration = ", it)
                
                if ( d['rep_ind'][s_ind, method_ind, step_method_ind, n_ind, i_it] > 0.
                    and d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it] > 0. ):
                    continue
                
                c_vars = d['init']
                aln.params.duration = dur
                setinit(d['init_vars'], aln)
                control_init = aln.getZeroControl()
                    
                bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                    control_init, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_ = init_it,
                    tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                    t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                    control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                    noise_real=n_, init_params = d['init_vars'], method='M4', method_step=step_m)
                            
                control_init = bc[:,:,100:-100]
                c_vars = [0,1]
                aln.params.duration = dur
                setinit(d['init_vars'], aln)

                bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                    control_init, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_=it-init_it,
                    tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                    t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                    control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                    noise_real=n_, init_params = d['init_vars'], method='M4', method_step=step_m)

                
                control_init = bc[:,:,100:-100]
                aln.params.duration = dur
                setinit(d['init_vars'], aln)
                cost_final = 0.
                cs = cost.numba_cost_sparsity_int(1, 6, T, d['cost_params'][s_ind][2], dt, control_init)

                for j in range(noise_realizations_final):
                    state_ = fo.updateState(aln, control_init)
                    cost_final += cost.numba_cost_precision_int(1, T, dt, d['cost_params'][s_ind][0],
                                                                   state_, target_, list(prec_vars) )

                d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it] = (
                                cost_final / noise_realizations_final + cs )
                print('cost = ', d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it])
                
                c_vars = d['init']                    
                aln.params.duration = dur
                control_init1 = aln.getZeroControl()
                setinit(d['init_vars'], aln)
                
                bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                    control_init1, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_ = init_it,
                    tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                    t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                    control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                    noise_real=n_, init_params = d['init_vars'], method='M4', method_step=step_m)
                            
                control_init1 = bc[:,:,100:-100]
                c_vars = [0,1]
                aln.params.duration = dur
                setinit(d['init_vars'], aln)

                bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                    control_init1, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_=it-init_it,
                    tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                    t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                    control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                    noise_real=n_, init_params = d['init_vars'], method='M4', method_step=step_m)
                                

                control_init1 = bc[:,:,100:-100]
                d['rep_ind'][s_ind, method_ind, step_method_ind, n_ind, i_it] = rep_ind(control_init, control_init1)
                print('rep_ind = ', d['rep_ind'][s_ind, method_ind, step_method_ind, n_ind, i_it])
                
                file=open(dict_file, "wb")
                pickle.dump(dict_list, file)
                file.close()
                
    break
# Out:
# Point =  [0.5 0.5]
# sigma =  0.01
# set cost params:  0.026458600489613113 0.0 1.0
# n =  2
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24
# n =  10
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24
# n =  30
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24
# n =  50
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24
# sigma =  0.03
# set cost params:  0.008817022660197538 0.0 1.0
# n =  2
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24
# n =  10
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24
# n =  30
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24
# n =  50
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24
# sigma =  0.049999999999999996
# set cost params:  0.005282379365665093 0.0 1.0
# n =  2
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24
# n =  10
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24
# n =  30
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24
# n =  50
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24
# sigma =  0.06999999999999999
# set cost params:  0.003772423157889073 0.0 1.0
# n =  2
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24
# n =  10
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24
# n =  30
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24
# n =  50
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24

# %%
for s_ind in range(len(d['sigma'])):
    for n_ind in range(len(d['N_array'])):
        for i_it in range(1,len(d['it_array'])):
            #d['cost'][s_ind, 3, 0, n_ind, i_it] = 0.

# %%
#len(sigma_array), 4, N_max, max_it

##### METHOD 3
method_ind = 2
step_method_ind = 1
step_m = 'S1'
if step_method_ind == 1:
    step_m = 'S2'

for d in dict_list:
    
    if d['point'][0] != 0.5:
        continue
    if d['point'][1] != 0.5:
        continue
        
    print("Point = ", d['point'])
    aln.params.ext_exc_current = d['point'][0] * 5.
    aln.params.ext_inh_current = d['point'][1] * 5.
    
    max_it = d['cost'].shape[3]
    
    for s_ind in range(len(d['sigma'])):
        
        print("sigma = ", d['sigma'][s_ind])
        
        s = d['sigma'][s_ind]
        aln.params.sigma_ou = s
        c_p = d['cost_params'][s_ind]
        cost.setParams(c_p[0], c_p[1], c_p[2])
        
        target_ = d['target'][s_ind].copy()
        target_[0,0,:int(trans_time * dur / aln.params.dt)] = -1000
        target_[0,1,:int(trans_time * dur / aln.params.dt)] = -1000
                
        for n_ind in range(len(d['N_array'])):
            
            n_ = d['N_array'][n_ind]
            
            print("n = ", n_)
            aln.params.duration = dur
        
            for i_it in range(1,len(d['it_array'])):
            
                it = d['it_array'][i_it]
                print("iteration = ", it)
                
                if d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it] > 0.:
                    continue
                
                c_vars = d['init']
                aln.params.duration = dur
                setinit(d['init_vars'], aln)
                control_init = aln.getZeroControl()
                    
                
                bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                    control_init, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_ = init_it,
                    tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                    t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                    control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                    noise_real=n_, init_params = d['init_vars'], method='M3', method_step=step_m)
            
                control_init = bc[:,:,100:-100]
                c_vars = [0,1]
                aln.params.duration = dur
                setinit(d['init_vars'], aln)
                
                bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                    control_init, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_=it-init_it,
                    tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                    t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                    control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                    noise_real=n_, init_params = d['init_vars'], method='M3', method_step=step_m)

                control_init = bc[:,:,100:-100]
                aln.params.duration = dur
                setinit(d['init_vars'], aln)
                cost_final = 0.
                cs = cost.numba_cost_sparsity_int(1, 6, T, d['cost_params'][s_ind][2], dt, control_init)

                for j in range(noise_realizations_final):
                    state_ = fo.updateState(aln, control_init)
                    cost_final += cost.numba_cost_precision_int(1, T, dt, d['cost_params'][s_ind][0],
                                                                   state_, target_, list(prec_vars) )

                d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it] = (
                                cost_final / noise_realizations_final + cs )
                print('cost = ', d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it])
                
                c_vars = d['init']                    
                aln.params.duration = dur
                control_init1 = aln.getZeroControl()
                setinit(d['init_vars'], aln)
                
                bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                    control_init1, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_ = init_it,
                    tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                    t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                    control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                    noise_real=n_, init_params = d['init_vars'], method='M3', method_step=step_m)
            
                control_init1 = bc[:,:,100:-100]
                c_vars = [0,1]
                aln.params.duration = dur
                setinit(d['init_vars'], aln)
                
                bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                    control_init1, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_=it-init_it,
                    tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                    t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                    control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                    noise_real=n_, init_params = d['init_vars'], method='M3', method_step=step_m)

                control_init1 = bc[:,:,100:-100]
                d['rep_ind'][s_ind, method_ind, step_method_ind, n_ind, i_it] = rep_ind(control_init, control_init1)
                print('rep_ind = ', d['rep_ind'][s_ind, method_ind, step_method_ind, n_ind, i_it])
                
                file=open(dict_file, "wb")
                pickle.dump(dict_list, file)
                file.close()
                
    break
# Out:
# Point =  [0.5 0.5]
# sigma =  0.01
# set cost params:  0.026458600489613113 0.0 1.0
# n =  2
# iteration =  6
# iteration =  12
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3670.5459710649557
# Gradient descend method:  None
# RUN  1 , total integrated cost =  165.6427619143517
# RUN  2 , total integrated cost =  138.12580829189324
# RUN  3 , total integrated cost =  68.26767758769049
# RUN  3 , total integrated cost mean =  68.26767758769049
# Improved over  3  iterations in  0.40914111700840294  seconds by  98.1401219838725  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  67.07675598213858
# Gradient descend method:  None
# RUN  1 , total integrated cost =  15.256401650984115
# RUN  2 , total integrated cost =  11.643674298251842
# RUN  3 , total integrated cost =  10.803286235229432
# RUN  4 , total integrated cost =  10.74094940624164
# RUN  5 , total integrated cost =  10.643876634233138
# RUN  6 , total integrated cost =  10.33477296514653
# RUN  7 , total integrated cost =  10.306730675176636
# RUN  8 , total integrated cost =  10.292745544491734
# RUN  9 , total integrated cost =  10.291838364954858
# RUN  9 , total integrated cost mean =  10.291838364954858
# Improved over  9  iterations in  2.0009897539857775  seconds by  84.65662476626717  percent.
# cost =  10.439993960438535
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3700.4749965594156
# Gradient descend method:  None
# RUN  1 , total integrated cost =  153.72427524831087
# RUN  2 , total integrated cost =  42.411165925812604
# RUN  3 , total integrated cost =  11.295047233334143
# RUN  3 , total integrated cost mean =  11.295047233334143
# Improved over  3  iterations in  0.33177397696999833  seconds by  99.69476763810495  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11.769800672883534
# Gradient descend method:  None
# RUN  1 , total integrated cost =  9.258168497386762
# RUN  2 , total integrated cost =  8.948420497822237
# RUN  3 , total integrated cost =  8.380749936313075
# RUN  4 , total integrated cost =  8.39712626509483
# RUN  5 , total integrated cost =  8.304216594949356
# RUN  6 , total integrated cost =  8.239425194856533
# RUN  7 , total integrated cost =  8.18786273133249
# RUN  8 , total integrated cost =  8.265590242313378
# RUN  9 , total integrated cost =  8.205440629775918
# RUN  9 , total integrated cost mean =  8.205440629775918
# Improved over  9  iterations in  1.856068780994974  seconds by  30.283945685839456  percent.
# rep_ind =  15.507307693981213
# iteration =  18
# iteration =  24
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3696.5990133396936
# Gradient descend method:  None
# RUN  1 , total integrated cost =  142.7144197784742
# RUN  2 , total integrated cost =  34.51555136312471
# RUN  3 , total integrated cost =  30.53360646068277
# RUN  3 , total integrated cost mean =  30.53360646068277
# Improved over  3  iterations in  0.34999739099293947  seconds by  99.1740081531565  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  32.03461295702832
# Gradient descend method:  None
# RUN  1 , total integrated cost =  9.34545435419686
# RUN  2 , total integrated cost =  7.2904320331607035
# RUN  3 , total integrated cost =  6.735576400951304
# RUN  4 , total integrated cost =  6.524103996447973
# step size too small or too large
# RUN  5 , total integrated cost =  6.512045750493995
# RUN  6 , total integrated cost =  6.494681963972882
# RUN  7 , total integrated cost =  6.424195818309192
# RUN  8 , total integrated cost =  6.4200059069287425
# RUN  9 , total integrated cost =  6.393874867164713
# RUN  10 , total integrated cost =  6.36088305062136
# RUN  11 , total integrated cost =  6.351841073942351
# RUN  12 , total integrated cost =  6.384243225251307
# RUN  13 , total integrated cost =  6.314755154402466
# RUN  14 , total integrated cost =  6.313081024619139
# RUN  15 , total integrated cost =  6.354693695231494
# RUN  16 , total integrated cost =  6.250535492246771
# RUN  17 , total integrated cost =  6.14181766939302
# RUN  18 , total integrated cost =  6.127071525307275
# RUN  19 , total integrated cost =  6.187201166800225
# RUN  20 , total integrated cost =  6.089837768171366
# RUN  21 , total integrated cost mean =  6.191720874857971
# Improved over  21  iterations in  5.143119077954907  seconds by  80.67177873145016  percent.
# cost =  6.2949040344521725
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3688.5465653201472
# Gradient descend method:  None
# RUN  1 , total integrated cost =  146.42822151746287
# RUN  2 , total integrated cost =  25.76659115931415
# RUN  3 , total integrated cost =  7.427746001860237
# RUN  3 , total integrated cost mean =  7.427746001860237
# Improved over  3  iterations in  0.3435769909992814  seconds by  99.79862675256167  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7.095030695866409
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.825038941935205
# RUN  2 , total integrated cost =  5.514842360999194
# RUN  3 , total integrated cost =  5.162681894394472
# RUN  4 , total integrated cost =  5.084156958394422
# RUN  5 , total integrated cost =  5.145014228196187
# RUN  6 , total integrated cost =  5.106793052584582
# RUN  7 , total integrated cost =  5.026311073667426
# RUN  8 , total integrated cost =  5.041300966269942
# RUN  9 , total integrated cost =  5.0056242179958526
# RUN  10 , total integrated cost =  4.844296096286833
# RUN  11 , total integrated cost =  4.885414627910842
# RUN  12 , total integrated cost =  4.932835124444348
# RUN  13 , total integrated cost =  4.931034831815099
# RUN  14 , total integrated cost =  4.907015121456354
# RUN  15 , total integrated cost =  4.938259042115412
# RUN  16 , total integrated cost =  4.888113820729271
# RUN  17 , total integrated cost =  4.853440326143616
# RUN  18 , total integrated cost =  4.862975541279479
# RUN  19 , total integrated cost =  4.925945454121558
# RUN  20 , total integrated cost =  4.917773447373285
# RUN  21 , total integrated cost mean =  4.918136329197841
# Improved over  21  iterations in  4.976058319036383  seconds by  30.681958401347515  percent.
# rep_ind =  9.715992729890502
# n =  10
# iteration =  6
# iteration =  12
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3679.9369622161407
# Gradient descend method:  None
# RUN  1 , total integrated cost =  150.82830870133017
# RUN  2 , total integrated cost =  77.58262808864706
# RUN  3 , total integrated cost =  42.644597480674584
# RUN  3 , total integrated cost mean =  42.644597480674584
# Improved over  3  iterations in  1.853265895973891  seconds by  98.84115956554339  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  43.880901999109525
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.265605730519496
# RUN  2 , total integrated cost =  8.635141902722808
# RUN  3 , total integrated cost =  8.170199775460077
# RUN  4 , total integrated cost =  7.78801575349638
# step size too small or too large
# RUN  5 , total integrated cost =  7.649124758491617
# step size too small or too large
# step size too small or too large
# RUN  6 , total integrated cost =  7.542613965702246
# step size too small or too large
# step size too small or too large
# RUN  7 , total integrated cost =  7.487733455007938
# RUN  8 , total integrated cost =  7.4898879560624065
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  9 , total integrated cost =  7.394553672349742
# RUN  9 , total integrated cost mean =  7.394553672349742
# Improved over  9  iterations in  10.21985663002124  seconds by  83.14858324357189  percent.
# cost =  7.5580774307049525
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3690.149684070739
# Gradient descend method:  None
# RUN  1 , total integrated cost =  133.91522782672
# RUN  2 , total integrated cost =  28.270724281062463
# RUN  3 , total integrated cost =  8.453630500487002
# RUN  3 , total integrated cost mean =  8.453630500487002
# Improved over  3  iterations in  1.760853211977519  seconds by  99.77091361532084  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  8.045162133624224
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.292627441517633
# RUN  2 , total integrated cost =  6.077730649064388
# RUN  3 , total integrated cost =  5.8565880563295085
# step size too small or too large
# RUN  4 , total integrated cost =  5.7707453052804905
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  5 , total integrated cost =  5.723316236112643
# RUN  6 , total integrated cost =  5.636111114230714
# RUN  7 , total integrated cost =  5.589327230686396
# RUN  8 , total integrated cost =  5.49251255635822
# RUN  9 , total integrated cost =  5.460171376073022
# RUN  9 , total integrated cost mean =  5.460171376073022
# Improved over  9  iterations in  9.661612530006096  seconds by  32.13099642513609  percent.
# rep_ind =  14.525402205281393
# iteration =  18
# iteration =  24
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3688.2964628924065
# Gradient descend method:  None
# RUN  1 , total integrated cost =  144.85664181613205
# RUN  2 , total integrated cost =  30.29002694512396
# RUN  3 , total integrated cost =  8.345370578650037
# RUN  3 , total integrated cost mean =  8.345370578650037
# Improved over  3  iterations in  1.6883874369668774  seconds by  99.77373373689963  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  8.423037433975104
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.8662351381357905
# step size too small or too large
# RUN  2 , total integrated cost =  6.518427078529562
# RUN  3 , total integrated cost =  6.357783166410941
# RUN  4 , total integrated cost =  6.159797680578439
# RUN  5 , total integrated cost =  6.119887199603352
# step size too small or too large
# step size too small or too large
# RUN  6 , total integrated cost =  6.138801142561701
# RUN  7 , total integrated cost =  6.0932122721534325
# RUN  8 , total integrated cost =  6.020356882538266
# step size too small or too large
# RUN  9 , total integrated cost =  5.932786253730409
# RUN  10 , total integrated cost =  5.808012015111592
# RUN  11 , total integrated cost =  5.787420538998761
# RUN  12 , total integrated cost =  5.73900985392841
# RUN  13 , total integrated cost =  5.748583568222297
# step size too small or too large
# step size too small or too large
# RUN  14 , total integrated cost =  5.6971572324744075
# step size too small or too large
# RUN  15 , total integrated cost =  5.680776761655773
# RUN  16 , total integrated cost =  5.621667485756755
# RUN  17 , total integrated cost =  5.546109090499149
# RUN  18 , total integrated cost =  5.522410469452645
# RUN  19 , total integrated cost =  5.537350865506427
# RUN  20 , total integrated cost =  5.526625972002969
# RUN  21 , total integrated cost mean =  5.419400224149091
# Improved over  21  iterations in  23.783592885010876  seconds by  35.65978702303475  percent.
# cost =  5.4726589216295825
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3686.76274706717
# Gradient descend method:  None
# RUN  1 , total integrated cost =  132.49974662067189
# RUN  2 , total integrated cost =  27.014619341547625
# RUN  3 , total integrated cost =  7.8183050538577445
# RUN  3 , total integrated cost mean =  7.8183050538577445
# Improved over  3  iterations in  1.6762114450102672  seconds by  99.78793576939343  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  8.00561318149421
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.255365966816162
# RUN  2 , total integrated cost =  5.982510953264386
# RUN  3 , total integrated cost =  5.858872130288717
# step size too small or too large
# RUN  4 , total integrated cost =  5.779597314109932
# RUN  5 , total integrated cost =  5.760066673187032
# RUN  6 , total integrated cost =  5.734025394043742
# RUN  7 , total integrated cost =  5.668317070648202
# RUN  8 , total integrated cost =  5.6615347801082985
# RUN  9 , total integrated cost =  5.59338380954342
# RUN  10 , total integrated cost =  5.581395749792245
# step size too small or too large
# step size too small or too large
# RUN  11 , total integrated cost =  5.508585721642258
# RUN  12 , total integrated cost =  5.45178026740805
# RUN  13 , total integrated cost =  5.452668144039135
# RUN  14 , total integrated cost =  5.338415650577322
# RUN  15 , total integrated cost =  5.2398773434576364
# RUN  16 , total integrated cost =  5.232537673166481
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  17 , total integrated cost =  5.220472990331214
# RUN  18 , total integrated cost =  5.173214502750227
# RUN  19 , total integrated cost =  5.118514759888633
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  20 , total integrated cost =  4.947544127295623
# RUN  21 , total integrated cost mean =  4.933395924467384
# Improved over  21  iterations in  23.36772605101578  seconds by  38.375789428954285  percent.
# rep_ind =  4.5339619023533695
# n =  30
# iteration =  6
# iteration =  12
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3682.825115656099
# Gradient descend method:  None
# RUN  1 , total integrated cost =  137.48349731177495
# RUN  2 , total integrated cost =  31.270186519091787
# RUN  3 , total integrated cost =  8.934460011731383
# RUN  3 , total integrated cost mean =  8.934460011731383
# Improved over  3  iterations in  5.144683983002324  seconds by  99.75740200169294  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  8.893302375934837
# Gradient descend method:  None
# step size too small or too large
# RUN  1 , total integrated cost =  7.058611046868959
# RUN  2 , total integrated cost =  6.702830867751283
# step size too small or too large
# RUN  3 , total integrated cost =  6.491803544176197
# step size too small or too large
# RUN  4 , total integrated cost =  6.413234002621334
# step size too small or too large
# RUN  5 , total integrated cost =  6.345001826786155
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  6 , total integrated cost =  6.311263355756002
# step size too small or too large
# RUN  7 , total integrated cost =  6.238298340392947
# RUN  8 , total integrated cost =  6.174893296278581
# step size too small or too large
# step size too small or too large
# RUN  9 , total integrated cost =  6.079983180795961
# RUN  9 , total integrated cost mean =  6.079983180795961
# Improved over  9  iterations in  29.076303827983793  seconds by  31.634134050717563  percent.
# cost =  6.171836334376415
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3682.282665503895
# Gradient descend method:  None
# RUN  1 , total integrated cost =  148.87596254251653
# RUN  2 , total integrated cost =  13.807907450100817
# RUN  3 , total integrated cost =  9.984326633111857
# RUN  3 , total integrated cost mean =  9.984326633111857
# Improved over  3  iterations in  5.235393520037178  seconds by  99.7288549647031  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  9.843084894689953
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.502968809976668
# RUN  2 , total integrated cost =  5.346627189413928
# RUN  3 , total integrated cost =  4.863328201079286
# RUN  4 , total integrated cost =  4.711694194780365
# RUN  5 , total integrated cost =  4.810216271284019
# RUN  6 , total integrated cost =  4.475297025158658
# RUN  7 , total integrated cost =  4.333577799129855
# RUN  8 , total integrated cost =  4.422487932671872
# step size too small or too large
# step size too small or too large
# RUN  9 , total integrated cost =  4.416941132715986
# RUN  9 , total integrated cost mean =  4.416941132715986
# Improved over  9  iterations in  30.831140580994543  seconds by  55.12645496841348  percent.
# rep_ind =  20.03330033900974
# iteration =  18
# iteration =  24
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3682.1955576764108
# Gradient descend method:  None
# RUN  1 , total integrated cost =  154.91196364176986
# RUN  2 , total integrated cost =  10.570184769016324
# step size too small or too large
# RUN  3 , total integrated cost =  9.844903948431629
# RUN  3 , total integrated cost mean =  9.844903948431629
# Improved over  3  iterations in  5.194165723980404  seconds by  99.73263495123426  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  9.750328331219666
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.836881648895458
# step size too small or too large
# RUN  2 , total integrated cost =  7.218179767818029
# step size too small or too large
# RUN  3 , total integrated cost =  6.844347776097098
# RUN  4 , total integrated cost =  5.940477539713699
# RUN  5 , total integrated cost =  5.597786284035296
# RUN  6 , total integrated cost =  5.502184660287966
# RUN  7 , total integrated cost =  5.33829325244365
# step size too small or too large
# RUN  8 , total integrated cost =  4.956389238260133
# RUN  9 , total integrated cost =  5.063116003702141
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  10 , total integrated cost =  4.760229890653608
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  11 , total integrated cost =  4.685842903345636
# RUN  12 , total integrated cost =  4.568853552179683
# step size too small or too large
# step size too small or too large
# RUN  13 , total integrated cost =  4.280343985522509
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  14 , total integrated cost =  4.52574115358543
# step size too small or too large
# RUN  15 , total integrated cost =  4.331138610135605
# step size too small or too large
# step size too small or too large
# RUN  16 , total integrated cost =  4.40434672518234
# step size too small or too large
# RUN  17 , total integrated cost =  4.50222295005447
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  18 , total integrated cost =  4.329168512542831
# RUN  19 , total integrated cost =  4.44156460032888
# RUN  20 , total integrated cost =  4.241277676667155
# step size too small or too large
# RUN  21 , total integrated cost mean =  4.349588505224032
# Improved over  21  iterations in  76.95906565600308  seconds by  55.39033807408265  percent.
# cost =  4.493573455755442
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3680.8654119503194
# Gradient descend method:  None
# RUN  1 , total integrated cost =  149.15064668257259
# RUN  2 , total integrated cost =  16.2771108325788
# RUN  3 , total integrated cost =  6.398199127521383
# RUN  3 , total integrated cost mean =  6.398199127521383
# Improved over  3  iterations in  5.467688800999895  seconds by  99.82617677063799  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  6.694204259631014
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.184580321613781
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  2 , total integrated cost =  5.690427730742127
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  3 , total integrated cost =  5.609503820519683
# step size too small or too large
# step size too small or too large
# RUN  4 , total integrated cost =  5.424894924800086
# RUN  5 , total integrated cost =  5.240035615686762
# RUN  6 , total integrated cost =  5.259437233815245
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  7 , total integrated cost =  4.717323157293382
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  8 , total integrated cost =  4.797341387474209
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  9 , total integrated cost =  4.785208170846096
# RUN  10 , total integrated cost =  4.690762430223227
# RUN  11 , total integrated cost =  4.585604755713482
# RUN  12 , total integrated cost =  4.5788783227306595
# RUN  13 , total integrated cost =  4.491461855834147
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  14 , total integrated cost =  4.2524815884370915
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  15 , total integrated cost =  4.703172261226617
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  16 , total integrated cost =  4.46242658075459
# step size too small or too large
# RUN  17 , total integrated cost =  4.382946922070804
# RUN  18 , total integrated cost =  4.39666225768158
# RUN  19 , total integrated cost =  4.3599124127225695
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  20 , total integrated cost =  4.530956257075686
# step size too small or too large
# RUN  21 , total integrated cost mean =  4.3994217354243
# Improved over  21  iterations in  78.47656955796992  seconds by  34.28013898597713  percent.
# rep_ind =  1.122465906853487
# n =  50
# iteration =  6
# iteration =  12
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3682.242463075812
# Gradient descend method:  None
# RUN  1 , total integrated cost =  147.26589563183944
# RUN  2 , total integrated cost =  24.083445708497297
# RUN  3 , total integrated cost =  6.998408452092365
# RUN  3 , total integrated cost mean =  6.998408452092365
# Improved over  3  iterations in  8.613868461980019  seconds by  99.80994167216663  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7.055216331578521
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.475851259197849
# RUN  2 , total integrated cost =  5.102854809821179
# step size too small or too large
# RUN  3 , total integrated cost =  4.951215809792841
# RUN  4 , total integrated cost =  4.864434904709871
# RUN  5 , total integrated cost =  4.781277927875224
# step size too small or too large
# RUN  6 , total integrated cost =  4.708538140905177
# RUN  7 , total integrated cost =  4.688341343188732
# step size too small or too large
# step size too small or too large
# RUN  8 , total integrated cost =  4.594588682991184
# step size too small or too large
# RUN  9 , total integrated cost =  4.46426148074399
# RUN  9 , total integrated cost mean =  4.46426148074399
# Improved over  9  iterations in  49.480129030009266  seconds by  36.7239603871202  percent.
# cost =  4.542424983160324
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3681.3631585002145
# Gradient descend method:  None
# RUN  1 , total integrated cost =  144.91333193914767
# RUN  2 , total integrated cost =  18.364692358426225
# RUN  3 , total integrated cost =  5.280297051447206
# RUN  3 , total integrated cost mean =  5.280297051447206
# Improved over  3  iterations in  9.097462367033586  seconds by  99.85656679810968  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5.3078153458767074
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.881929644722361
# RUN  2 , total integrated cost =  4.580103611785307
# step size too small or too large
# RUN  3 , total integrated cost =  4.401348712391286
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  4 , total integrated cost =  4.250303686702074
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  5 , total integrated cost =  4.134271755929424
# step size too small or too large
# step size too small or too large
# RUN  6 , total integrated cost =  4.122964423561649
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  7 , total integrated cost =  4.020835800173143
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  8 , total integrated cost =  4.007026730192759
# step size too small or too large
# step size too small or too large
# RUN  9 , total integrated cost =  4.036484601814114
# RUN  9 , total integrated cost mean =  4.036484601814114
# Improved over  9  iterations in  55.027402371983044  seconds by  23.952052986361082  percent.
# rep_ind =  8.225692123143439
# iteration =  18
# iteration =  24
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3680.4316256725865
# Gradient descend method:  None
# RUN  1 , total integrated cost =  149.89121781418527
# RUN  2 , total integrated cost =  65.20066229694
# RUN  3 , total integrated cost =  43.13887391777335
# RUN  3 , total integrated cost mean =  43.13887391777335
# Improved over  3  iterations in  8.570678355987184  seconds by  98.8278854681918  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  42.841499671270505
# Gradient descend method:  None
# RUN  1 , total integrated cost =  10.947232566043887
# RUN  2 , total integrated cost =  8.550195544606739
# step size too small or too large
# step size too small or too large
# RUN  3 , total integrated cost =  7.936036860415763
# step size too small or too large
# RUN  4 , total integrated cost =  7.732587171449795
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  5 , total integrated cost =  7.551985889023417
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  6 , total integrated cost =  7.494774143841048
# step size too small or too large
# step size too small or too large
# RUN  7 , total integrated cost =  7.384571274015086
# step size too small or too large
# step size too small or too large
# RUN  8 , total integrated cost =  7.321776370211036
# step size too small or too large
# step size too small or too large
# RUN  9 , total integrated cost =  7.262099724002874
# step size too small or too large
# step size too small or too large
# RUN  10 , total integrated cost =  7.185952414979371
# RUN  11 , total integrated cost =  7.155929957680694
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  12 , total integrated cost =  7.098029981803355
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  13 , total integrated cost =  7.04590463448605
# RUN  14 , total integrated cost =  7.003402294225857
# step size too small or too large
# step size too small or too large
# RUN  15 , total integrated cost =  6.922208069425128
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  16 , total integrated cost =  6.884434077332998
# step size too small or too large
# step size too small or too large
# RUN  17 , total integrated cost =  6.880546047239282
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  18 , total integrated cost =  6.851511370431657
# step size too small or too large
# step size too small or too large
# RUN  19 , total integrated cost =  6.769741486580914
# RUN  20 , total integrated cost =  6.745485525127236
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  21 , total integrated cost mean =  6.655381938448682
# Improved over  21  iterations in  115.12630679301219  seconds by  84.46510512116414  percent.
# cost =  6.719800976755077
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3683.458535312034
# Gradient descend method:  None
# RUN  1 , total integrated cost =  152.8827606503632
# RUN  2 , total integrated cost =  23.384290409278023
# step size too small or too large
# step size too small or too large
# RUN  3 , total integrated cost =  10.110398585777528
# RUN  3 , total integrated cost mean =  10.110398585777528
# Improved over  3  iterations in  9.515604345011525  seconds by  99.72551887067948  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  10.421474538745954
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.469665040302971
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  2 , total integrated cost =  4.847780779048993
# step size too small or too large
# RUN  3 , total integrated cost =  4.731938377776498
# step size too small or too large
# step size too small or too large
# RUN  4 , total integrated cost =  4.635755147688907
# step size too small or too large
# step size too small or too large
# RUN  5 , total integrated cost =  4.60311995774367
# RUN  6 , total integrated cost =  4.566903306713223
# step size too small or too large
# RUN  7 , total integrated cost =  4.659705919255833
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  8 , total integrated cost =  4.551252145593832
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  9 , total integrated cost =  4.51892108026061
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  10 , total integrated cost =  4.471991369118057
# step size too small or too large
# RUN  11 , total integrated cost =  4.521488490727673
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  12 , total integrated cost =  4.434198368362335
# RUN  13 , total integrated cost =  4.485249790565643
# step size too small or too large
# RUN  14 , total integrated cost =  4.432765732950004
# step size too small or too large
# step size too small or too large
# RUN  15 , total integrated cost =  4.259466648002379
# step size too small or too large
# RUN  16 , total integrated cost =  4.474144069348167
# RUN  17 , total integrated cost =  4.3287185361027305
# RUN  18 , total integrated cost =  4.329804347974192
# step size too small or too large
# step size too small or too large
# RUN  19 , total integrated cost =  4.320413481199193
# step size too small or too large
# RUN  20 , total integrated cost =  4.222051680991511
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  21 , total integrated cost mean =  4.231778017471166
# Improved over  21  iterations in  126.4505916290218  seconds by  59.393673114703134  percent.
# rep_ind =  25.227582532333304
# sigma =  0.03
# set cost params:  0.008817022660197538 0.0 1.0
# n =  2
# iteration =  6
# iteration =  12
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1236.0971818006906
# Gradient descend method:  None
# RUN  1 , total integrated cost =  37.13319301185623
# RUN  2 , total integrated cost =  18.879671455528733
# RUN  3 , total integrated cost =  8.57865599692413
# RUN  3 , total integrated cost mean =  8.57865599692413
# Improved over  3  iterations in  0.3186252269661054  seconds by  99.30598854821211  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  9.132923375085998
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.525666861624861
# RUN  2 , total integrated cost =  7.2523767237976955
# RUN  3 , total integrated cost =  7.263479533344076
# RUN  4 , total integrated cost =  6.7845564750906435
# RUN  5 , total integrated cost =  6.637261784616697
# RUN  6 , total integrated cost =  6.916385953545818
# RUN  7 , total integrated cost =  6.669758393147594
# RUN  8 , total integrated cost =  6.628350581761024
# RUN  9 , total integrated cost =  6.9210026506312765
# RUN  9 , total integrated cost mean =  6.9210026506312765
# Improved over  9  iterations in  1.9126839879900217  seconds by  24.21919722318806  percent.
# cost =  7.035148916145636
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1215.116843727842
# Gradient descend method:  None
# RUN  1 , total integrated cost =  82.12716790554052
# RUN  2 , total integrated cost =  22.467068611650873
# RUN  3 , total integrated cost =  8.807128059229257
# RUN  3 , total integrated cost mean =  8.807128059229257
# Improved over  3  iterations in  0.39481522602727637  seconds by  99.27520319509274  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  8.790239642653649
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.757735096678928
# RUN  2 , total integrated cost =  7.7748803770086745
# RUN  3 , total integrated cost =  7.677383502169377
# RUN  4 , total integrated cost =  7.7361490667695065
# RUN  5 , total integrated cost =  7.580448718253036
# RUN  6 , total integrated cost =  7.701105591628753
# RUN  7 , total integrated cost =  7.655736696472698
# RUN  8 , total integrated cost =  7.613766220939651
# RUN  9 , total integrated cost =  7.67325916740304
# RUN  9 , total integrated cost mean =  7.67325916740304
# Improved over  9  iterations in  1.7931155869737267  seconds by  12.707053739816004  percent.
# rep_ind =  5.936300949087974
# iteration =  18
# iteration =  24
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1221.4034710574642
# Gradient descend method:  None
# RUN  1 , total integrated cost =  47.83628399433937
# RUN  2 , total integrated cost =  12.619560500469117
# RUN  3 , total integrated cost =  6.925255120509121
# RUN  3 , total integrated cost mean =  6.925255120509121
# Improved over  3  iterations in  0.31116071401629597  seconds by  99.43300839692937  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  6.180239365779029
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.284188501914918
# RUN  2 , total integrated cost =  5.362249154032353
# RUN  3 , total integrated cost =  5.4032138720507
# RUN  4 , total integrated cost =  5.292137889801539
# RUN  5 , total integrated cost =  5.2851207165255225
# RUN  6 , total integrated cost =  4.965095650628847
# RUN  7 , total integrated cost =  5.049105909749159
# RUN  8 , total integrated cost =  4.855041546305996
# RUN  9 , total integrated cost =  4.987777193296132
# RUN  10 , total integrated cost =  5.221052591780531
# RUN  11 , total integrated cost =  4.712749368055071
# RUN  12 , total integrated cost =  4.912294442772668
# RUN  13 , total integrated cost =  4.756731449614145
# RUN  14 , total integrated cost =  4.689008397691226
# RUN  15 , total integrated cost =  4.950156633076064
# RUN  16 , total integrated cost =  5.252787672983144
# RUN  17 , total integrated cost =  4.840598878456413
# RUN  18 , total integrated cost =  4.5924409908040005
# RUN  19 , total integrated cost =  4.83613136070048
# RUN  20 , total integrated cost =  4.404580410011645
# RUN  21 , total integrated cost mean =  4.6781680757761865
# Improved over  21  iterations in  4.366521068033762  seconds by  24.30441931294847  percent.
# cost =  4.66009055888366
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1239.2106764271275
# Gradient descend method:  None
# RUN  1 , total integrated cost =  71.01392561237137
# RUN  2 , total integrated cost =  70.02954560959705
# RUN  3 , total integrated cost =  66.16384199347465
# RUN  3 , total integrated cost mean =  66.16384199347465
# Improved over  3  iterations in  0.3654592459788546  seconds by  94.66080762116759  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  37.61524590525664
# Gradient descend method:  None
# RUN  1 , total integrated cost =  17.828114006458417
# RUN  2 , total integrated cost =  14.106819545780535
# RUN  3 , total integrated cost =  12.87357671278911
# RUN  4 , total integrated cost =  14.247297688589912
# RUN  5 , total integrated cost =  10.738343436497622
# RUN  6 , total integrated cost =  9.0709585042927
# RUN  7 , total integrated cost =  10.771882840374884
# RUN  8 , total integrated cost =  10.434005640328193
# RUN  9 , total integrated cost =  5.107888695311061
# RUN  10 , total integrated cost =  7.1138055464356045
# RUN  11 , total integrated cost =  5.771935835559824
# RUN  12 , total integrated cost =  5.031964773209054
# RUN  13 , total integrated cost =  6.846136795405706
# RUN  14 , total integrated cost =  6.081598933258103
# RUN  15 , total integrated cost =  5.403264067394492
# RUN  16 , total integrated cost =  5.129895834301395
# RUN  17 , total integrated cost =  5.161217274544626
# RUN  18 , total integrated cost =  5.62219175159475
# RUN  19 , total integrated cost =  5.319034959691408
# RUN  20 , total integrated cost =  4.901256562495718
# RUN  21 , total integrated cost mean =  5.192143762223289
# Improved over  21  iterations in  4.649127592041623  seconds by  86.19670392345435  percent.
# rep_ind =  31.745659442815853
# n =  10
# iteration =  6
# iteration =  12
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1229.6791608426638
# Gradient descend method:  None
# RUN  1 , total integrated cost =  48.62749676879256
# RUN  2 , total integrated cost =  16.904657457964966
# RUN  3 , total integrated cost =  7.382311499951601
# RUN  3 , total integrated cost mean =  7.382311499951601
# Improved over  3  iterations in  1.603320415946655  seconds by  99.39965547640145  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7.661523400656033
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.523321902139917
# RUN  2 , total integrated cost =  6.592776280507358
# step size too small or too large
# step size too small or too large
# RUN  3 , total integrated cost =  6.509408023541655
# RUN  4 , total integrated cost =  6.217698038329941
# RUN  5 , total integrated cost =  6.234117082691918
# RUN  6 , total integrated cost =  6.054362757617885
# RUN  7 , total integrated cost =  5.719003431652569
# RUN  8 , total integrated cost =  5.693076891335265
# step size too small or too large
# step size too small or too large
# RUN  9 , total integrated cost =  5.480510498600831
# RUN  9 , total integrated cost mean =  5.480510498600831
# Improved over  9  iterations in  9.406692756980192  seconds by  28.467091830176344  percent.
# cost =  5.608469962981115
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1228.181240180002
# Gradient descend method:  None
# RUN  1 , total integrated cost =  52.69498590257895
# RUN  2 , total integrated cost =  12.357395597376447
# RUN  3 , total integrated cost =  6.34653938018874
# RUN  3 , total integrated cost mean =  6.34653938018874
# Improved over  3  iterations in  1.6675919170374982  seconds by  99.483257098174  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  6.318043607978568
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.846615689041715
# RUN  2 , total integrated cost =  5.421974289940556
# RUN  3 , total integrated cost =  5.615082136669644
# RUN  4 , total integrated cost =  5.5078246138642095
# step size too small or too large
# step size too small or too large
# RUN  5 , total integrated cost =  4.95951687980501
# RUN  6 , total integrated cost =  4.589295666030693
# RUN  7 , total integrated cost =  4.547325153477153
# RUN  8 , total integrated cost =  4.440203147028542
# RUN  9 , total integrated cost =  4.392132160935764
# RUN  9 , total integrated cost mean =  4.392132160935764
# Improved over  9  iterations in  9.426196816959418  seconds by  30.482718489165208  percent.
# rep_ind =  9.463715171159837
# iteration =  18
# iteration =  24
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1222.0487851034547
# Gradient descend method:  None
# RUN  1 , total integrated cost =  57.864055483628114
# RUN  2 , total integrated cost =  28.765796861761505
# RUN  3 , total integrated cost =  11.870051916245554
# RUN  3 , total integrated cost mean =  11.870051916245554
# Improved over  3  iterations in  1.8078236970468424  seconds by  99.02867610025564  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11.682389185679847
# Gradient descend method:  None
# RUN  1 , total integrated cost =  10.200085967179294
# step size too small or too large
# RUN  2 , total integrated cost =  9.873450035028227
# RUN  3 , total integrated cost =  9.778571403580747
# RUN  4 , total integrated cost =  9.465426470806133
# RUN  5 , total integrated cost =  9.129564564218096
# RUN  6 , total integrated cost =  8.999595214552988
# RUN  7 , total integrated cost =  8.97590389615596
# step size too small or too large
# step size too small or too large
# RUN  8 , total integrated cost =  8.804119090514028
# RUN  9 , total integrated cost =  8.805190419382487
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  10 , total integrated cost =  8.48259064383802
# RUN  11 , total integrated cost =  8.327146559038308
# RUN  12 , total integrated cost =  8.125836747746375
# RUN  13 , total integrated cost =  8.107661700780543
# step size too small or too large
# step size too small or too large
# RUN  14 , total integrated cost =  8.269830891367292
# RUN  15 , total integrated cost =  7.868190895822562
# RUN  16 , total integrated cost =  7.7444109726090264
# RUN  17 , total integrated cost =  7.632686346703096
# RUN  18 , total integrated cost =  7.436758846282972
# RUN  19 , total integrated cost =  7.393073971546403
# RUN  20 , total integrated cost =  7.310984444939213
# RUN  21 , total integrated cost mean =  7.074816510688277
# Improved over  21  iterations in  21.53562390297884  seconds by  39.44032853005347  percent.
# cost =  7.180892126996504
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1225.6303610971952
# Gradient descend method:  None
# RUN  1 , total integrated cost =  57.29494761583352
# RUN  2 , total integrated cost =  25.383534868778842
# RUN  3 , total integrated cost =  11.812243466999961
# RUN  3 , total integrated cost mean =  11.812243466999961
# Improved over  3  iterations in  1.555886215006467  seconds by  99.03623116382124  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11.365308096983597
# Gradient descend method:  None
# step size too small or too large
# step size too small or too large
# RUN  1 , total integrated cost =  9.829751803182615
# RUN  2 , total integrated cost =  9.394212604307471
# step size too small or too large
# step size too small or too large
# RUN  3 , total integrated cost =  9.189628339745305
# RUN  4 , total integrated cost =  8.9512432918678
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  5 , total integrated cost =  8.918331365130864
# RUN  6 , total integrated cost =  8.752352619456524
# RUN  7 , total integrated cost =  8.649940429061788
# step size too small or too large
# RUN  8 , total integrated cost =  8.484520741668197
# RUN  9 , total integrated cost =  8.24120265621863
# RUN  10 , total integrated cost =  8.215856891415147
# RUN  11 , total integrated cost =  8.172560495767888
# step size too small or too large
# step size too small or too large
# RUN  12 , total integrated cost =  8.006461616449805
# RUN  13 , total integrated cost =  7.8115388417028555
# step size too small or too large
# RUN  14 , total integrated cost =  7.558591994978698
# step size too small or too large
# step size too small or too large
# RUN  15 , total integrated cost =  7.643841254807638
# RUN  16 , total integrated cost =  7.323401921743948
# RUN  17 , total integrated cost =  7.434982112108022
# RUN  18 , total integrated cost =  7.215210458602608
# RUN  19 , total integrated cost =  7.373010541863191
# RUN  20 , total integrated cost =  7.272831236259243
# RUN  21 , total integrated cost mean =  7.114216087290816
# Improved over  21  iterations in  22.553608004003763  seconds by  37.40410707230224  percent.
# rep_ind =  2.6109156525184245
# n =  30
# iteration =  6
# iteration =  12
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1224.9891769097826
# Gradient descend method:  None
# RUN  1 , total integrated cost =  53.97076162685774
# RUN  2 , total integrated cost =  10.716657399671975
# RUN  3 , total integrated cost =  5.2305740805145
# RUN  3 , total integrated cost mean =  5.2305740805145
# Improved over  3  iterations in  5.040119394019712  seconds by  99.57301058824785  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5.320774345042493
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.778956158875682
# step size too small or too large
# RUN  2 , total integrated cost =  4.603413023689631
# RUN  3 , total integrated cost =  4.555050791877914
# RUN  4 , total integrated cost =  4.626652141545206
# step size too small or too large
# RUN  5 , total integrated cost =  4.565477761526197
# step size too small or too large
# RUN  6 , total integrated cost =  4.506441339327977
# RUN  7 , total integrated cost =  4.53930542897125
# RUN  8 , total integrated cost =  4.560467751304854
# step size too small or too large
# step size too small or too large
# RUN  9 , total integrated cost =  4.515832499230659
# RUN  9 , total integrated cost mean =  4.515832499230659
# Improved over  9  iterations in  28.48651128995698  seconds by  15.128283847666268  percent.
# cost =  4.634168204008366
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1225.6313382153014
# Gradient descend method:  None
# RUN  1 , total integrated cost =  51.5525625459383
# RUN  2 , total integrated cost =  15.019040278283876
# RUN  3 , total integrated cost =  7.460185460483939
# RUN  3 , total integrated cost mean =  7.460185460483939
# Improved over  3  iterations in  4.810355374997016  seconds by  99.39131896942624  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7.5319993823441775
# Gradient descend method:  None
# step size too small or too large
# RUN  1 , total integrated cost =  6.690630381744183
# RUN  2 , total integrated cost =  6.3759563986262355
# step size too small or too large
# RUN  3 , total integrated cost =  6.268799034842231
# RUN  4 , total integrated cost =  5.996068876419884
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  5 , total integrated cost =  5.887924213503408
# step size too small or too large
# RUN  6 , total integrated cost =  5.631718614663397
# RUN  7 , total integrated cost =  5.401581570291253
# step size too small or too large
# step size too small or too large
# RUN  8 , total integrated cost =  5.167271484464856
# step size too small or too large
# RUN  9 , total integrated cost =  4.97663042349761
# RUN  9 , total integrated cost mean =  4.97663042349761
# Improved over  9  iterations in  28.262100037012715  seconds by  33.926834418449744  percent.
# rep_ind =  5.858952906744916
# iteration =  18
# iteration =  24
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1222.5105891337519
# Gradient descend method:  None
# RUN  1 , total integrated cost =  59.03788492945743
# RUN  2 , total integrated cost =  23.552204166498274
# RUN  3 , total integrated cost =  10.51379978342964
# RUN  3 , total integrated cost mean =  10.51379978342964
# Improved over  3  iterations in  5.008058920968324  seconds by  99.13998292719252  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  10.323098691495378
# Gradient descend method:  None
# RUN  1 , total integrated cost =  9.240981830578276
# ...
# step size too small or too large
# RUN  5 , total integrated cost =  5.932154993606178
# step size too small or too large
# RUN  6 , total integrated cost =  6.01676235389562
# RUN  7 , total integrated cost =  5.6923218679444725
# RUN  8 , total integrated cost =  5.853201313129081
# step size too small or too large
# RUN  9 , total integrated cost =  5.768568514403589
# RUN  9 , total integrated cost mean =  5.768568514403589
# Improved over  9  iterations in  27.92268785496708  seconds by  18.745264674873724  percent.
# rep_ind =  5.930081263775156
# iteration =  18
# iteration =  24
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  518.5920917847176
# Gradient descend method:  None
# RUN  1 , total integrated cost =  41.07733299844761
# RUN  2 , total integrated cost =  11.540726427582422
# RUN  3 , total integrated cost =  7.3366006098555125
# RUN  3 , total integrated cost mean =  7.3366006098555125
# Improved over  3  iterations in  4.663684720988385  seconds by  98.58528490386215  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7.667483492517525
# Gradient descend method:  None
# step size too small or too large
# RUN  1 , total integrated cost =  7.441575857247818
# RUN  2 , total integrated cost =  6.926964989277878
# RUN  3 , total integrated cost =  6.736283879220311
# step size too small or too large
# RUN  4 , total integrated cost =  6.5515528356023385
# RUN  5 , total integrated cost =  6.56839588195551
# RUN  6 , total integrated cost =  5.9823645723268
# step size too small or too large
# RUN  7 , total integrated cost =  5.810566423131035
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  8 , total integrated cost =  5.660586595281102
# RUN  9 , total integrated cost =  5.435157505431836
# RUN  10 , total integrated cost =  5.586312153195313
# RUN  11 , total integrated cost =  5.736632570207245
# RUN  12 , total integrated cost =  5.9649027302805875
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  13 , total integrated cost =  5.739547685011652
# RUN  14 , total integrated cost =  5.754802557739565
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  15 , total integrated cost =  5.741174088939368
# RUN  16 , total integrated cost =  5.642416657553197
# step size too small or too large
# step size too small or too large
# RUN  17 , total integrated cost =  6.090631548153209
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  18 , total integrated cost =  5.5007656912979845
# step size too small or too large
# step size too small or too large
# RUN  19 , total integrated cost =  5.371057751056077
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  20 , total integrated cost =  6.067740446514914
# step size too small or too large
# RUN  21 , total integrated cost mean =  5.465259702973239
# Improved over  21  iterations in  68.21014782402199  seconds by  28.721598053564406  percent.
# cost =  6.26205251113899
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  516.3973286765716
# Gradient descend method:  None
# RUN  1 , total integrated cost =  26.351589550346848
# step size too small or too large
# RUN  2 , total integrated cost =  19.93311268275444
# RUN  3 , total integrated cost =  9.242419512630336
# RUN  3 , total integrated cost mean =  9.242419512630336
# Improved over  3  iterations in  4.895690550969448  seconds by  98.21021159495211  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  9.54779840090065
# Gradient descend method:  None
# RUN  1 , total integrated cost =  8.655279743743682
# step size too small or too large
# RUN  2 , total integrated cost =  8.29162345158939
# RUN  3 , total integrated cost =  7.808031895841149
# RUN  4 , total integrated cost =  7.510371393435724
# step size too small or too large
# RUN  5 , total integrated cost =  7.257716230756179
# step size too small or too large
# step size too small or too large
# RUN  6 , total integrated cost =  6.530165761070128
# step size too small or too large
# RUN  7 , total integrated cost =  5.999127141513153
# RUN  8 , total integrated cost =  5.844077676072737
# step size too small or too large
# RUN  9 , total integrated cost =  5.5415433959417335
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  10 , total integrated cost =  5.448341716996837
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  11 , total integrated cost =  5.5673265334493065
# RUN  12 , total integrated cost =  5.4170010181540915
# RUN  13 , total integrated cost =  5.604683843236891
# RUN  14 , total integrated cost =  5.434485463333183
# RUN  15 , total integrated cost =  5.562477055378745
# step size too small or too large
# RUN  16 , total integrated cost =  5.438946184155414
# RUN  17 , total integrated cost =  5.314458544006694
# RUN  18 , total integrated cost =  5.785413709054497
# RUN  19 , total integrated cost =  5.7106559447033804
# step size too small or too large
# step size too small or too large
# RUN  20 , total integrated cost =  5.487892372513168
# step size too small or too large
# RUN  21 , total integrated cost mean =  5.662240081334059
# Improved over  21  iterations in  65.81589836801868  seconds by  40.69585632641828  percent.
# rep_ind =  4.559513464777007
# n =  50
# iteration =  6
# iteration =  12
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  524.2425475162604
# Gradient descend method:  None
# RUN  1 , total integrated cost =  34.253972376259824
# RUN  2 , total integrated cost =  17.38368929491306
# RUN  3 , total integrated cost =  9.678076992012329
# RUN  3 , total integrated cost mean =  9.678076992012329
# Improved over  3  iterations in  8.221887957013678  seconds by  98.15389326221903  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  9.614709246992042
# Gradient descend method:  None
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  1 , total integrated cost =  8.937149158851575
# RUN  2 , total integrated cost =  8.315806805773278
# RUN  3 , total integrated cost =  7.997962535699461
# RUN  4 , total integrated cost =  7.680145463380772
# RUN  5 , total integrated cost =  7.293863668376485
# RUN  6 , total integrated cost =  7.027299218332837
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  7 , total integrated cost =  6.336774498192697
# step size too small or too large
# step size too small or too large
# RUN  8 , total integrated cost =  5.734995114342617
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  9 , total integrated cost =  5.879811604842477
# RUN  9 , total integrated cost mean =  5.879811604842477
# Improved over  9  iterations in  44.134024940023664  seconds by  38.84566393225075  percent.
# cost =  5.918358239599088
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  524.7564967559194
# Gradient descend method:  None
# RUN  1 , total integrated cost =  30.15332115387966
# step size too small or too large
# step size too small or too large
# RUN  2 , total integrated cost =  13.137131361640138
# RUN  3 , total integrated cost =  8.097171754081934
# RUN  3 , total integrated cost mean =  8.097171754081934
# Improved over  3  iterations in  8.307936602970585  seconds by  98.45696588719926  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  8.033604696354667
# Gradient descend method:  None
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  1 , total integrated cost =  7.62325865772365
# RUN  2 , total integrated cost =  7.069309756471633
# step size too small or too large
# RUN  3 , total integrated cost =  7.002207951280711
# step size too small or too large
# step size too small or too large
# RUN  4 , total integrated cost =  6.388489088822992
# RUN  5 , total integrated cost =  6.075435358222637
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  6 , total integrated cost =  6.028016675318703
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  7 , total integrated cost =  5.959144433836087
# step size too small or too large
# step size too small or too large
# RUN  8 , total integrated cost =  5.817904539310928
# step size too small or too large
# step size too small or too large
# RUN  9 , total integrated cost =  5.772091275670553
# RUN  9 , total integrated cost mean =  5.772091275670553
# Improved over  9  iterations in  46.1805487810052  seconds by  28.150668425474052  percent.
# rep_ind =  3.401183833448206
# iteration =  18
# iteration =  24
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  521.1797374971142
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22.00943948807169
# RUN  2 , total integrated cost =  8.467016493320095
# step size too small or too large
# RUN  3 , total integrated cost =  6.6751303134963385
# RUN  3 , total integrated cost mean =  6.6751303134963385
# Improved over  3  iterations in  7.692456846009009  seconds by  98.71922681692259  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  6.633983038635054
# Gradient descend method:  None
# step size too small or too large
# RUN  1 , total integrated cost =  6.328307298465711
# step size too small or too large
# RUN  2 , total integrated cost =  5.906918201316711
# step size too small or too large
# step size too small or too large
# RUN  3 , total integrated cost =  5.681487170590336
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  4 , total integrated cost =  5.820313132608008
# RUN  5 , total integrated cost =  6.146980004016569
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  6 , total integrated cost =  5.866212636335267
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  7 , total integrated cost =  5.713128548118536
# step size too small or too large
# RUN  8 , total integrated cost =  5.663435343901212
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  9 , total integrated cost =  5.747013555375979
# step size too small or too large
# step size too small or too large
# RUN  10 , total integrated cost =  5.798515369776136
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  11 , total integrated cost =  5.539062967288934
# step size too small or too large
# step size too small or too large
# RUN  12 , total integrated cost =  5.677869247630204
# step size too small or too large
# step size too small or too large
# RUN  13 , total integrated cost =  5.755723186045706
# RUN  14 , total integrated cost =  5.7771328221916205
# RUN  15 , total integrated cost =  5.658598541324742
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  16 , total integrated cost =  5.569611956095554
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  17 , total integrated cost =  5.567916899915506
# RUN  18 , total integrated cost =  5.508717617838714
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  19 , total integrated cost =  5.695594916740785
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  20 , total integrated cost =  5.640493019285743
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  21 , total integrated cost mean =  5.620306397945652
# Improved over  21  iterations in  109.78047368995612  seconds by  15.280060783784677  percent.
# cost =  6.6589061243530425
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  519.915208619477
# Gradient descend method:  None
# RUN  1 , total integrated cost =  29.21185577473852
# RUN  2 , total integrated cost =  10.195170728368339
# RUN  3 , total integrated cost =  6.902290017501349
# RUN  3 , total integrated cost mean =  6.902290017501349
# Improved over  3  iterations in  8.177746066008694  seconds by  98.6724200594499  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  6.864969602769795
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.39838877034146
# step size too small or too large
# step size too small or too large
# RUN  2 , total integrated cost =  5.9452511073431005
# step size too small or too large
# step size too small or too large
# RUN  3 , total integrated cost =  6.0821726633244815
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  4 , total integrated cost =  5.787927597173531
# step size too small or too large
# RUN  5 , total integrated cost =  5.95617401702348
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  6 , total integrated cost =  5.831546972290352
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  7 , total integrated cost =  5.712396003539099
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  8 , total integrated cost =  5.637122063365271
# RUN  9 , total integrated cost =  5.894941865124258
# RUN  10 , total integrated cost =  6.099533278451023
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  11 , total integrated cost =  5.570050735409019
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  12 , total integrated cost =  5.648607898430165
# RUN  13 , total integrated cost =  5.903248647609133
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  14 , total integrated cost =  5.695832388931542
# RUN  15 , total integrated cost =  5.703500908116592
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  16 , total integrated cost =  5.5494234420683135
# RUN  17 , total integrated cost =  5.526168133040438
# RUN  18 , total integrated cost =  5.7837681529492055
# RUN  19 , total integrated cost =  5.590265871485892
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  20 , total integrated cost =  5.577648496531608
# step size too small or too large
# step size too small or too large
# RUN  21 , total integrated cost mean =  5.819835031417149
# Improved over  21  iterations in  109.88172043801751  seconds by  15.224168959626098  percent.
# rep_ind =  5.372840595307696

# %%
#len(sigma_array), 4, N_max, max_it

##### METHOD 3
method_ind = 3
step_method_ind = 1
step_m = 'S1'
if step_method_ind == 1:
    step_m = 'S2'

for d in dict_list:
    
    if d['point'][0] != 0.5:
        continue
    if d['point'][1] != 0.5:
        continue
        
    print("Point = ", d['point'])
    aln.params.ext_exc_current = d['point'][0] * 5.
    aln.params.ext_inh_current = d['point'][1] * 5.
    
    max_it = d['cost'].shape[3]
    
    for s_ind in range(len(d['sigma'])):

        print("sigma = ", d['sigma'][s_ind])
        
        s = d['sigma'][s_ind]
        aln.params.sigma_ou = s
        c_p = d['cost_params'][s_ind]
        cost.setParams(c_p[0], c_p[1], c_p[2])
        
        target_ = d['target'][s_ind].copy()
        target_[0,0,:int(trans_time * dur / aln.params.dt)] = -1000
        target_[0,1,:int(trans_time * dur / aln.params.dt)] = -1000
                
        for n_ind in range(len(d['N_array'])):
            
            n_ = d['N_array'][n_ind]
            
            print("n = ", n_)
            aln.params.duration = dur
        
            for i_it in range(1,len(d['it_array'])):
            
                it = d['it_array'][i_it]
                print("iteration = ", it)
                
                if d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it] > 0.:
                    continue
                
                c_vars = d['init']
                aln.params.duration = dur
                setinit(d['init_vars'], aln)
                control_init = aln.getZeroControl()
                    
                
                bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                    control_init, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_ = init_it,
                    tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                    t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                    control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                    noise_real=n_, init_params = d['init_vars'], method='M4', method_step=step_m)
            
                control_init = bc[:,:,100:-100]
                c_vars = [0,1]
                aln.params.duration = dur
                setinit(d['init_vars'], aln)
                
                bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                    control_init, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_=it-init_it,
                    tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                    t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                    control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                    noise_real=n_, init_params = d['init_vars'], method='M4', method_step=step_m)

                control_init = bc[:,:,100:-100]
                aln.params.duration = dur
                setinit(d['init_vars'], aln)
                cost_final = 0.
                cs = cost.numba_cost_sparsity_int(1, 6, T, d['cost_params'][s_ind][2], dt, control_init)

                for j in range(noise_realizations_final):
                    state_ = fo.updateState(aln, control_init)
                    cost_final += cost.numba_cost_precision_int(1, T, dt, d['cost_params'][s_ind][0],
                                                                   state_, target_, list(prec_vars) )

                d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it] = (
                                cost_final / noise_realizations_final + cs )
                print('cost = ', d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it])
                
                c_vars = d['init']                    
                aln.params.duration = dur
                control_init1 = aln.getZeroControl()
                setinit(d['init_vars'], aln)
                
                bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                    control_init1, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_ = init_it,
                    tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                    t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                    control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                    noise_real=n_, init_params = d['init_vars'], method='M4', method_step=step_m)
            
                control_init1 = bc[:,:,100:-100]
                c_vars = [0,1]
                aln.params.duration = dur
                setinit(d['init_vars'], aln)
                
                bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                    control_init1, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_=it-init_it,
                    tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                    t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                    control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                    noise_real=n_, init_params = d['init_vars'], method='M4', method_step=step_m)

                control_init1 = bc[:,:,100:-100]
                d['rep_ind'][s_ind, method_ind, step_method_ind, n_ind, i_it] = rep_ind(control_init, control_init1)
                print('rep_ind = ', d['rep_ind'][s_ind, method_ind, step_method_ind, n_ind, i_it])
                
                file=open(dict_file, "wb")
                pickle.dump(dict_list, file)
                file.close()
                
    break
# Out:
# Point =  [0.5 0.5]
# sigma =  0.01
# set cost params:  0.026458600489613113 0.0 1.0
# n =  2
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24
# n =  10
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24
# n =  30
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24
# n =  50
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24
# sigma =  0.03
# set cost params:  0.008817022660197538 0.0 1.0
# n =  2
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24
# n =  10
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24
# n =  30
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24
# n =  50
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24
# sigma =  0.049999999999999996
# set cost params:  0.005282379365665093 0.0 1.0
# n =  2
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24
# n =  10
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24
# n =  30
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24
# n =  50
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24
# sigma =  0.06999999999999999
# set cost params:  0.003772423157889073 0.0 1.0
# n =  2
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24
# n =  10
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24
# n =  30
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24
# n =  50
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24
