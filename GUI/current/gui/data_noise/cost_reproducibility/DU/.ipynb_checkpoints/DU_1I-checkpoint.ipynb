# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import sys
import pickle
import matplotlib
import ipyparams

path = os.getcwd().split(os.sep + 'GUI')[0]
if path not in sys.path:
    print("not here")
    sys.path.append(path)

from neurolib.models.aln import ALNModel
from neurolib.utils import plotFunctions as plotFunc
from neurolib.utils import func_optimize as fo
from neurolib.utils import costFunctions as cost
import neurolib.dashboard.functions as functions
import neurolib.dashboard.data as data
import neurolib.dashboard.layout as layout
    
# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2 

#path = os.path.join(os.getcwd(), "plots")

cmap_ = layout.getcolormap()
darkgrey, midgrey, lightgrey, color_bi_updown, color_LC, color_bi_uposc = layout.getcolors_rgba()
exc_red = cmap_(3)
inh_blue=cmap_(0)
green = cmap_(2)
# Out:
# not here

# %%
aln = ALNModel()
N = aln.params.N

data.set_parameters(aln)

state_vars = aln.state_vars
init_vars = aln.init_vars

##############################################################
def setinit(init_vars_, model):
    state_vars = model.state_vars
    init_vars = model.init_vars
    for iv in range(len(init_vars)):
        for sv in range(len(state_vars)):
            if state_vars[sv] in init_vars[iv]:
                #print("set init vars ", )
                if model.params[init_vars[iv]].ndim == 2:
                    model.params[init_vars[iv]][0,:] = init_vars_[sv]
                else:
                    model.params[init_vars[iv]][0] = init_vars_[sv]
                    
##############################################################               
def setmaxmincontrol(max_c_c, min_c_c, max_c_r, min_c_r):
    import numpy as np
    
    max_cntrl = np.zeros(( 6 ))
    min_cntrl = np.zeros(( 6 ))
    
    max_cntrl[0] = max_c_c
    min_cntrl[0] = min_c_c
    max_cntrl[1] = max_c_c
    min_cntrl[1] = min_c_c
    max_cntrl[2] = max_c_r
    min_cntrl[2] = min_c_r
    max_cntrl[3] = max_c_r
    min_cntrl[3] = min_c_r
    max_cntrl[4] = max_c_r
    min_cntrl[4] = min_c_r
    max_cntrl[5] = max_c_r
    min_cntrl[5] = min_c_r
            
    return max_cntrl, min_cntrl

def rep_ind(c0, c1):
    abs_diff = np.abs(c0-c1)
    res = 0.
    for n in range(c0.shape[0]):
        for v in range(c0.shape[1]):
            res += sum(abs_diff[n,v,:]) * dt
            
    return res

# %%
points = np.array( [ [0.4, 0.35], [0.4, 0.4], [0.45, 0.4], [0.425, 0.45], [0.475, 0.45], [0.45, 0.5],
                    [0.5, 0.5], [0.45, 0.65], [0.5, 0.65], [0.55, 0.65] ])

# 10 points, two costs, 4 methods, N

# %%
def create_dict(task, point, cost_params, init, init_vars, target, sigma_array, N_max_array, it_array):
    return dict( {'task':task, 'point':point, 'cost_params':cost_params, 'init':init, 'init_vars':init_vars,
            'target':target, 'sigma':sigma_array, 'N_array':N_max_array, 'it_array':it_array,
            'cost':np.zeros(( len(sigma_array), 4, 2, len(N_max_array), len(it_array) )),
            'rep_ind':np.zeros(( len(sigma_array), 4, 2, len(N_max_array), len(it_array) ))     } )

params_list = ['task', 'point', 'cost_params', 'init', 'init_vars', 'target', 'sigma', 'N_array',
               'cost', 'rep_ind']

# %%
dict_list = []
sigma_array = np.arange(0.01, 0.081, 0.02)
N_array = [2,10,30,50]
it_array = np.arange(0,25,6)

for p in points:
    dict_list.append(create_dict('DU', p, [None]*len(sigma_array), [1], None,
                [None]*len(sigma_array), sigma_array, N_array, it_array) )

# %%
for d in dict_list:
    print(d['target'])
# Out:
# [None, None, None, None]
# [None, None, None, None]
# [None, None, None, None]
# [None, None, None, None]
# [None, None, None, None]
# [None, None, None, None]
# [None, None, None, None]
# [None, None, None, None]
# [None, None, None, None]
# [None, None, None, None]

# %%
dict_file = "DU_1I.pickle"

if False:
    file=open(dict_file, "wb")
    pickle.dump(dict_list, file)
    file.close()

if True:
    file = open(dict_file, "rb")
    dict_list = pickle.load(file)
    file.close()

# %%
dur_pre = 10
dur_post = 10
dur = 200.
dur_comp = 2000.
dt = aln.params.dt
T = int(1 + dur / dt)

prec_vars = [0,1]
trans_time = 0.8

n_pre = int(np.around(dur_pre/aln.params.dt,1))
n_post = int(np.around(dur_post/aln.params.dt,1))

tol = 1e-16
start_step = 10.
c_scheme = np.zeros(( 1,1 ))
c_scheme[0,0] = 1.
u_mat = np.identity(1)
u_scheme = np.array([[1.]])

maxC = [5., -5., 0.18, 0.]
n_dur = int(np.around(dur/aln.params.dt + 1.,1))
max_cntrl, min_cntrl = setmaxmincontrol(maxC[0], maxC[1], maxC[2], maxC[3])

noise_realizations_final = 10000
noise_realizations_target_compute = 1000
init_it = 3

# %%
# get init vars without noise
aln = ALNModel()
data.set_parameters(aln)
aln.params.duration = dur_comp

# initial without noise
control0 = aln.getZeroControl()

for d in dict_list:
    
    if d['point'][0] != 0.5:
        continue
    if d['point'][1] != 0.5:
        continue
    
    print("Point = ", d['point'])
    aln.params.ext_exc_current = d['point'][0] * 5.
    aln.params.ext_inh_current = d['point'][1] * 5.
    aln.params.duration = dur_comp
    
    if type(d['init_vars']) == type(None):
    
        control0[0,0,:500] = -5.

        aln.run(control=control0)

        init_state_vars = np.zeros(( len(state_vars) ))
        for j in range(len(state_vars)):
            if aln.state[state_vars[j]].size == 1:
                init_state_vars[j] = aln.state[state_vars[j]][0]
            else:
                init_state_vars[j] = aln.state[state_vars[j]][0,-1]

        initVars = init_state_vars.copy()
        d['init_vars'] = initVars
    
    for ind_s in range(len(d['sigma'])):
        
        if type(d['target'][ind_s]) != type(None):
            continue        
        
        s = d['sigma'][ind_s]
        aln.params.sigma_ou = s
        aln.params.duration = dur_comp
        control0[0,0,:500] = 5.
        
        stateswitchcount = 0
        target_rates_e = []
        target_rates_i = []

        for j in range(noise_realizations_target_compute):
            if j % 100 == 0:
                print(j)
            aln.run(control=control0)
            #plt.plot(aln.t, aln.rates_exc[0,:])
            if np.amin(aln.rates_exc[0,1000:]) < 1.:
                #print("fell in down state, repeat")
                j -= 1
                stateswitchcount += 1
                if stateswitchcount > 0.8 * noise_realizations_target_compute:
                    print("UNSTABLE: point, sigma ", d['point'], s)
                    break
                continue
            target_rates_e.append(aln.rates_exc[0,1000:])
            target_rates_i.append(aln.rates_inh[0,1000:])
        
        #plt.show()            

        aln.params.duration = dur
        target = aln.getZeroTarget()
        target[:,0,:] = np.mean(target_rates_e)
        target[:,1,:] = np.mean(target_rates_i)
        stddev = np.std(target_rates_e) + np.std(target_rates_i)
        
        d['target'][ind_s] = target
        d['cost_params'][ind_s] = [1. / ( stddev * (1. - trans_time) * dur ), 0., 1.]
        
        #print(stddev)
        
    file=open(dict_file, "wb")
    pickle.dump(dict_list, file)
    file.close()
    
    break
# Out:
# Point =  [0.5 0.5]
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900

# %%
#len(sigma_array), 4, N_max, max_it

##### METHOD 1
method_ind = 0
step_method_ind = 0

for d in dict_list:
    
    if d['point'][0] != 0.5:
        continue
    if d['point'][1] != 0.5:
        continue
        
    print("Point = ", d['point'])
    aln.params.ext_exc_current = d['point'][0] * 5.
    aln.params.ext_inh_current = d['point'][1] * 5.
    
    max_it = d['cost'].shape[3]
    
    for s_ind in range(len(d['sigma'])):
        
        print("sigma = ", d['sigma'][s_ind])
        
        s = d['sigma'][s_ind]
        aln.params.sigma_ou = s
        c_p = d['cost_params'][s_ind]
        cost.setParams(c_p[0], c_p[1], c_p[2])
        aln.params.duration = dur
        zero_init = aln.getZeroControl()
        
        target_ = d['target'][s_ind].copy()
        target_[0,0,:int(trans_time * dur / aln.params.dt)] = -1000
        target_[0,1,:int(trans_time * dur / aln.params.dt)] = -1000
        
        if np.amin(d['cost'][s_ind, method_ind, step_method_ind, :, 0]) == 0.:
        
            setinit(d['init_vars'], aln)
            cost_final = 0.

            for n_ in range(noise_realizations_final):
                state_ = fo.updateState(aln, zero_init)
                cost_final += cost.numba_cost_precision_int(1, T, dt, d['cost_params'][s_ind][0],
                                                               state_, target_, list(prec_vars) )

            d['cost'][s_ind, :, :, :, 0] = cost_final/noise_realizations_final
            
        print('cost = ', d['cost'][s_ind, 0, 0, 0])    
        
        for i_it in range(1,len(d['it_array'])):

            
            it = d['it_array'][i_it]
            print("iteration = ", it)
        
            for n_ind in range(len(d['N_array'])):

                if d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it] > 0.:
                    continue
                    
                n_max = d['N_array'][n_ind]
                print("n max = ", n_max)

                aln.params.duration = dur
                control_init = aln.getZeroControl()                    
                    
                n_ = 0
                control_sum = aln.getZeroControl()
                
                while n_ < n_max:
                
                    print('--------', n_)

                    aln.params.duration = dur
                    setinit(d['init_vars'], aln)
                    
                    c_vars = d['init_vars']

                    bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                        control_init, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_ = init_it,
                        tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                        t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                        control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                        noise_real=0, init_params = d['init_vars'])
                    
                    control_init = bc[:,:,n_pre:-n_post]
                    c_vars = [0,1]
                    aln.params.duration = dur
                    setinit(d['init_vars'], aln)
                    
                    bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                        control_init, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_ = it-init_it,
                        tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                        t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                        control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                        noise_real=0, init_params = d['init_vars'])
                    
                    control_sum += bc[:,:,n_pre:-n_post]
                    n_ += 1

                control_init = control_sum / n_max
        
                aln.params.duration = dur
                setinit(d['init_vars'], aln)

                cost_final = 0.

                for j in range(noise_realizations_final):
                    state_ = fo.updateState(aln, control_init)
                    cost_final += cost.numba_cost_precision_int(1, T, dt, d['cost_params'][s_ind][0],
                                                                   state_, target_, list(prec_vars) )
                    cost_final += cost.numba_cost_sparsity_int(1, 6, T, d['cost_params'][s_ind][2],
                                                                   dt, control_init)

                d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it] = cost_final/noise_realizations_final
                print('cost = ', d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it])
                
                ###############################################################
                
                aln.params.duration = dur
                setinit(d['init_vars'], aln)
                control_init1 = aln.getZeroControl()                    
                    
                n_ = 0
                control_sum = aln.getZeroControl()
                
                while n_ < n_max:
                
                    print('--------', n_)

                    aln.params.duration = dur
                    setinit(d['init_vars'], aln)
                    
                    c_vars = d['init_vars']

                    bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                        control_init1, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_ = init_it,
                        tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                        t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                        control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                        noise_real=0, init_params = d['init_vars'])
                    
                    control_init1 = bc[:,:,n_pre:-n_post]
                    c_vars = [0,1]
                    aln.params.duration = dur
                    setinit(d['init_vars'], aln)
                    
                    bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                        control_init, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_ = it-init_it,
                        tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                        t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                        control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                        noise_real=0, init_params = d['init_vars'])
                    
                    control_sum += bc[:,:,n_pre:-n_post]
                    n_ += 1

                control_init1 = control_sum / n_max
                
                d['rep_ind'][s_ind, method_ind, step_method_ind, n_ind, i_it] = rep_ind(control_init, control_init1)
                print('rep_ind = ', d['rep_ind'][s_ind, method_ind, step_method_ind, n_ind, i_it])
                
                file=open(dict_file, "wb")
                pickle.dump(dict_list, file)
                file.close()
                                
    break
# Out:
# Point =  [0.5 0.5]
# sigma =  0.01
# set cost params:  0.026412476147033622 0.0 1.0
# cost =  [3685.59647294    4.95574641   17.70404803    5.02231914    4.08217471]
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24
# n max =  10
# -------- 0
# interpolate adjoint :  True True True
# initial cost =  3683.470964635735
# RUN  0 , total integrated cost =  3683.470964635735
# Gradient descend method:  None
# RUN  1 , total integrated cost =  157.33994480672436
# RUN  2 , total integrated cost =  19.655393244890515
# RUN  3 , total integrated cost =  5.994039315644635
# RUN  3 , total integrated cost =  5.994039315644635
# Improved over  3  iterations in  11.119281253020745  seconds by  99.83727198142208  percent.
# interpolate adjoint :  True True True
# initial cost =  6.866802760459578
# RUN  0 , total integrated cost =  6.866802760459578
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.703528060062772
# RUN  2 , total integrated cost =  4.171017209262689
# RUN  3 , total integrated cost =  4.188946031189435
# RUN  4 , total integrated cost =  4.153466212046738
# RUN  5 , total integrated cost =  4.13579077339249
# RUN  6 , total integrated cost =  4.153738432838401
# RUN  7 , total integrated cost =  4.12657164520713
# RUN  8 , total integrated cost =  4.048087016456581
# RUN  9 , total integrated cost =  4.0495476038116385
# RUN  10 , total integrated cost =  4.059845178922998
# RUN  11 , total integrated cost =  4.035300176096706
# RUN  12 , total integrated cost =  3.877677454232432
# RUN  13 , total integrated cost =  3.8621998252648506
# RUN  14 , total integrated cost =  3.8773696081394347
# RUN  15 , total integrated cost =  3.8501676891618266
# RUN  16 , total integrated cost =  3.8563254469495307
# RUN  17 , total integrated cost =  3.742771282576657
# RUN  18 , total integrated cost =  3.7323059489581842
# RUN  19 , total integrated cost =  3.7647620321640436
# RUN  20 , total integrated cost =  3.731142506554337
# RUN  21 , total integrated cost =  3.7412568314506034
# Improved over  21  iterations in  1.3764418109785765  seconds by  45.51675704166854  percent.
# -------- 1
# interpolate adjoint :  True True True
# initial cost =  6.617722878605882
# RUN  0 , total integrated cost =  6.617722878605882
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.72663248097215
# RUN  2 , total integrated cost =  4.148545164905498
# RUN  3 , total integrated cost =  4.075697133476968
# RUN  3 , total integrated cost =  4.075697133476968
# Improved over  3  iterations in  0.1270105839939788  seconds by  38.41239338303068  percent.
# interpolate adjoint :  True True True
# initial cost =  4.346313701036531
# RUN  0 , total integrated cost =  4.346313701036531
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.052198098226334
# RUN  2 , total integrated cost =  4.008864877535951
# RUN  3 , total integrated cost =  3.970673538316344
# RUN  4 , total integrated cost =  3.950857153568556
# RUN  5 , total integrated cost =  3.935315956097321
# RUN  6 , total integrated cost =  3.9002175722443426
# RUN  7 , total integrated cost =  3.9498462941147556
# RUN  8 , total integrated cost =  3.8749460765182318
# RUN  9 , total integrated cost =  3.9460812784023758
# RUN  10 , total integrated cost =  3.848695463180155
# RUN  11 , total integrated cost =  3.893433910938553
# RUN  12 , total integrated cost =  3.8256728844960275
# RUN  13 , total integrated cost =  3.7960815929810012
# RUN  14 , total integrated cost =  3.7859950007121306
# RUN  15 , total integrated cost =  3.8479324313748746
# RUN  16 , total integrated cost =  3.7686122780267475
# RUN  17 , total integrated cost =  3.7481939809029243
# RUN  18 , total integrated cost =  3.7498848234016604
# RUN  19 , total integrated cost =  3.6997657580371976
# RUN  20 , total integrated cost =  3.7134263547148176
# RUN  21 , total integrated cost =  3.6642806624896505
# Improved over  21  iterations in  1.3251016900176182  seconds by  15.692218405317277  percent.
# -------- 2
# interpolate adjoint :  True True True
# initial cost =  4.168409291269911
# RUN  0 , total integrated cost =  4.168409291269911
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.087577110167781
# RUN  2 , total integrated cost =  4.025297137932035
# RUN  3 , total integrated cost =  4.054358013712132
# RUN  3 , total integrated cost =  4.054358013712132
# Improved over  3  iterations in  0.1343553079641424  seconds by  2.7360863482538065  percent.
# interpolate adjoint :  True True True
# initial cost =  4.001501260434908
# RUN  0 , total integrated cost =  4.001501260434908
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.9393843723927224
# RUN  2 , total integrated cost =  3.8776086994298162
# RUN  3 , total integrated cost =  3.8236610947797782
# RUN  4 , total integrated cost =  3.834577230303761
# RUN  5 , total integrated cost =  3.8229074819723343
# RUN  6 , total integrated cost =  3.83433119856048
# RUN  7 , total integrated cost =  3.846360832855369
# RUN  8 , total integrated cost =  3.8482831678651404
# RUN  9 , total integrated cost =  3.8138958337310753
# RUN  10 , total integrated cost =  3.8379412102275894
# RUN  11 , total integrated cost =  3.7738427013306928
# RUN  12 , total integrated cost =  3.726313013496492
# RUN  13 , total integrated cost =  3.7349498210697125
# RUN  14 , total integrated cost =  3.7769323412072406
# RUN  15 , total integrated cost =  3.751018295850075
# RUN  16 , total integrated cost =  3.814638910746595
# RUN  17 , total integrated cost =  3.7765227516143227
# RUN  18 , total integrated cost =  3.7825386358251167
# RUN  19 , total integrated cost =  3.7746419963809665
# RUN  20 , total integrated cost =  3.823079018749756
# RUN  21 , total integrated cost =  3.7437939197844576
# Improved over  21  iterations in  1.406506736006122  seconds by  6.440266386981989  percent.
# -------- 3
# interpolate adjoint :  True True True
# initial cost =  4.11959389307076
# RUN  0 , total integrated cost =  4.11959389307076
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.9854296314281314
# RUN  2 , total integrated cost =  3.9937489521152982
# RUN  3 , total integrated cost =  3.9041577049374308
# RUN  3 , total integrated cost =  3.9041577049374308
# Improved over  3  iterations in  0.13914209097856656  seconds by  5.229549167351095  percent.
# interpolate adjoint :  True True True
# initial cost =  4.1290183053487395
# RUN  0 , total integrated cost =  4.1290183053487395
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.9086556166694746
# RUN  2 , total integrated cost =  3.9168979555061347
# RUN  3 , total integrated cost =  3.8533915661054907
# RUN  4 , total integrated cost =  3.8717732201160397
# RUN  5 , total integrated cost =  3.875421045132255
# RUN  6 , total integrated cost =  3.921338877301409

# %%
#len(sigma_array), 4, N_max, max_it

##### METHOD 2
method_ind = 1
step_method_ind = 0

for d in dict_list:
    
    if d['point'][0] != 0.5:
        continue
    if d['point'][1] != 0.5:
        continue
        
        
    print("Point = ", d['point'])
    aln.params.ext_exc_current = d['point'][0] * 5.
    aln.params.ext_inh_current = d['point'][1] * 5.
    
    max_it = d['cost'].shape[3]
    
    for s_ind in range(len(d['sigma'])):

        print("sigma = ", d['sigma'][s_ind])
        
        s = d['sigma'][s_ind]
        aln.params.sigma_ou = s
        c_p = d['cost_params'][s_ind]
        cost.setParams(c_p[0], c_p[1], c_p[2])
        
        target_ = d['target'][s_ind].copy()
        target_[0,0,:int(trans_time * dur / aln.params.dt)] = -1000
        target_[0,1,:int(trans_time * dur / aln.params.dt)] = -1000
                
        for n_ind in range(len(d['N_array'])):
            
            n_ = d['N_array'][n_ind]
            
            print("n = ", n_)
            aln.params.duration = dur
        
            for i_it in range(1,len(d['it_array'])):
                
                if i_it in [2,4]:
                    continue
            
                it = d['it_array'][i_it]
                print("iteration = ", it)
                
                if ( d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it] > 0.
                    and d['rep_ind'][s_ind, method_ind, step_method_ind, n_ind, i_it] > 0. ) :
                    continue
                
                c_vars = d['init']
                aln.params.duration = dur
                setinit(d['init_vars'], aln)
                control_init = aln.getZeroControl()
                    
                
                bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                    control_init, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_ = init_it,
                    tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                    t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                    control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                    noise_real=n_, init_params = d['init_vars'], method='M2')
            
                control_init = bc[:,:,100:-100]
                c_vars = [0,1]
                aln.params.duration = dur
                setinit(d['init_vars'], aln)
                
                bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                    control_init, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_=it-init_it,
                    tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                    t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                    control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                    noise_real=n_, init_params = d['init_vars'], method='M2')

                control_init = bc[:,:,100:-100]
                aln.params.duration = dur
                setinit(d['init_vars'], aln)
                cost_final = 0.
                cs = cost.numba_cost_sparsity_int(1, 6, T, d['cost_params'][s_ind][2], dt, control_init)

                for j in range(noise_realizations_final):
                    state_ = fo.updateState(aln, control_init)
                    cost_final += cost.numba_cost_precision_int(1, T, dt, d['cost_params'][s_ind][0],
                                                                   state_, target_, list(prec_vars) )

                d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it] = (
                                cost_final / noise_realizations_final + cs )
                print('cost = ', d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it])
                
                c_vars = d['init']                    
                aln.params.duration = dur
                control_init1 = aln.getZeroControl()
                setinit(d['init_vars'], aln)
                
                bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                    control_init1, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_ = init_it,
                    tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                    t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                    control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                    noise_real=n_, init_params = d['init_vars'], method='M2')
            
                control_init1 = bc[:,:,100:-100]
                c_vars = [0,1]
                aln.params.duration = dur
                setinit(d['init_vars'], aln)
                
                bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                    control_init1, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_=it-init_it,
                    tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                    t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                    control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                    noise_real=n_, init_params = d['init_vars'], method='M2')

                control_init1 = bc[:,:,100:-100]
                d['rep_ind'][s_ind, method_ind, step_method_ind, n_ind, i_it] = rep_ind(control_init, control_init1)
                print('rep_ind = ', d['rep_ind'][s_ind, method_ind, step_method_ind, n_ind, i_it])
                
                file=open(dict_file, "wb")
                pickle.dump(dict_list, file)
                file.close()
                
    break
# Out:
# Point =  [0.5 0.5]
# sigma =  0.01
# set cost params:  0.026412476147033622 0.0 1.0
# n =  2
# iteration =  6
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3665.998582618984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1166.569995447161
# RUN  2 , total integrated cost =  1144.7197420352968
# RUN  3 , total integrated cost =  1141.9013263522265
# RUN  3 , total integrated cost mean =  1141.9013263522265
# Improved over  3  iterations in  21.344656175991986  seconds by  68.85156116082146  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1141.8985830902334
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1141.500216904869
# RUN  2 , total integrated cost =  1141.282789641747
# RUN  3 , total integrated cost =  1141.3063823602038
# RUN  3 , total integrated cost mean =  1141.3063823602038
# Improved over  3  iterations in  0.9064889019937254  seconds by  0.051861061813994525  percent.
# cost =  1144.291595988991
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3684.4439213429605
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1166.9051427987074
# RUN  2 , total integrated cost =  1144.3211079652024
# RUN  3 , total integrated cost =  1142.0372823522061
# RUN  3 , total integrated cost mean =  1142.0372823522061
# Improved over  3  iterations in  0.3875954360119067  seconds by  69.0038088044521  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1141.9614464070592
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1141.5510360444398
# RUN  2 , total integrated cost =  1141.26515704246
# RUN  3 , total integrated cost =  1141.1986334991725
# RUN  3 , total integrated cost mean =  1141.1986334991725
# Improved over  3  iterations in  0.7064421999966726  seconds by  0.06679848170765013  percent.
# rep_ind =  0.5915862723353565
# iteration =  18
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3673.6212227066294
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1166.4780774482508
# RUN  2 , total integrated cost =  1144.3456988789094
# RUN  3 , total integrated cost =  1141.8599319955667
# RUN  3 , total integrated cost mean =  1141.8599319955667
# Improved over  3  iterations in  0.5251204979722388  seconds by  68.91731992025368  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1141.8429077233661
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1141.386498585196
# RUN  2 , total integrated cost =  1141.3937849044137
# RUN  3 , total integrated cost =  1141.2443851914218
# RUN  4 , total integrated cost =  1141.124192240868
# RUN  5 , total integrated cost =  927.4177988465655
# RUN  6 , total integrated cost =  112.32829667419603
# RUN  7 , total integrated cost =  24.301946239828844
# RUN  8 , total integrated cost =  14.89857592567084
# RUN  9 , total integrated cost =  13.57122053939155
# RUN  10 , total integrated cost =  12.91578440011952
# RUN  11 , total integrated cost =  12.444536312122906
# RUN  12 , total integrated cost =  12.182296974295127
# RUN  13 , total integrated cost =  11.930280071031815
# RUN  14 , total integrated cost =  11.931542346086559
# RUN  15 , total integrated cost =  11.613207802030976
# RUN  15 , total integrated cost mean =  11.613207802030976
# Improved over  15  iterations in  5.6304269270040095  seconds by  98.98294172311446  percent.
# cost =  13.12500129938768
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3685.338785681324
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1167.757945389607
# RUN  2 , total integrated cost =  1144.146695978304
# RUN  3 , total integrated cost =  1141.9635436383778
# RUN  3 , total integrated cost mean =  1141.9635436383778
# Improved over  3  iterations in  0.6483867340139113  seconds by  69.0133360852669  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1141.8225005072404
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1141.4940356886418
# RUN  2 , total integrated cost =  1141.379344537896
# RUN  3 , total integrated cost =  1141.285951585614
# RUN  4 , total integrated cost =  1141.1398611870363
# RUN  5 , total integrated cost =  1141.156074601422
# RUN  6 , total integrated cost =  1141.1510402813462
# RUN  7 , total integrated cost =  1141.076923308452
# RUN  8 , total integrated cost =  1141.0416423612855
# RUN  9 , total integrated cost =  1141.054999153159
# RUN  10 , total integrated cost =  1141.0380894264388
# RUN  11 , total integrated cost =  1141.0261839587745
# step size too small or too large
# RUN  12 , total integrated cost =  1141.015235244452
# RUN  13 , total integrated cost =  1141.032205747618
# RUN  14 , total integrated cost =  1141.0255714460714
# RUN  15 , total integrated cost =  1141.0524310743833
# RUN  15 , total integrated cost mean =  1141.0524310743833
# Improved over  15  iterations in  6.586498141987249  seconds by  0.0674421315497824  percent.
# rep_ind =  172.1719558612172
# n =  10
# iteration =  6
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3679.18822132528
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1166.5461641780425
# RUN  2 , total integrated cost =  1144.3369176667416
# RUN  3 , total integrated cost =  1141.9829156298852
# RUN  3 , total integrated cost mean =  1141.9829156298852
# Improved over  3  iterations in  2.0929391339886934  seconds by  68.96100859937708  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1141.7489767778354
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1141.4803138202255
# step size too small or too large
# step size too small or too large
# RUN  2 , total integrated cost =  1141.302322539539
# RUN  3 , total integrated cost =  1133.5811220517148
# RUN  3 , total integrated cost mean =  1133.5811220517148
# Improved over  3  iterations in  4.141735659039114  seconds by  0.715380954329504  percent.
# cost =  1150.7411744863537
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3675.5850691476016
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1166.005998374687
# RUN  2 , total integrated cost =  1144.3358843535736
# RUN  3 , total integrated cost =  1141.9035729235843
# RUN  3 , total integrated cost mean =  1141.9035729235843
# Improved over  3  iterations in  2.271759302006103  seconds by  68.93273991918785  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1141.6815015800757
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1141.4476431691432
# RUN  2 , total integrated cost =  1141.280745420149
# RUN  3 , total integrated cost =  1141.229411614953
# RUN  3 , total integrated cost mean =  1141.229411614953
# Improved over  3  iterations in  4.128880036994815  seconds by  0.039598606484986476  percent.
# rep_ind =  8.869593964671058
# iteration =  18
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3673.9646824842653
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1166.6442822246095
# RUN  2 , total integrated cost =  1144.1363564020576
# RUN  3 , total integrated cost =  1141.9588241144045
# RUN  3 , total integrated cost mean =  1141.9588241144045
# Improved over  3  iterations in  2.152918386971578  seconds by  68.9175339774297  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1141.7399899796733
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1141.4435336893941
# RUN  2 , total integrated cost =  1141.2923762323771
# RUN  3 , total integrated cost =  1099.7314907463285
# RUN  4 , total integrated cost =  1141.5053081625479
# step size too small or too large
# RUN  5 , total integrated cost =  1140.291990433081
# RUN  6 , total integrated cost =  897.023748156242
# RUN  7 , total integrated cost =  22.52546591862535
# RUN  8 , total integrated cost =  10.595487494601679
# RUN  9 , total integrated cost =  8.972304065742255
# RUN  10 , total integrated cost =  8.469282022894665
# step size too small or too large
# RUN  11 , total integrated cost =  8.257474780720482
# step size too small or too large
# RUN  12 , total integrated cost =  8.13375581350134
# RUN  13 , total integrated cost =  7.933194803045607
# RUN  14 , total integrated cost =  7.872411693021846
# RUN  15 , total integrated cost =  7.803930908293855
# RUN  15 , total integrated cost mean =  7.803930908293855
# Improved over  15  iterations in  24.418607608997263  seconds by  99.31648790645997  percent.
# cost =  8.23176139163475
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3675.2668442316417
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1165.9926264864266
# RUN  2 , total integrated cost =  1144.3705585262474
# RUN  3 , total integrated cost =  1141.9028080050816
# RUN  3 , total integrated cost mean =  1141.9028080050816
# Improved over  3  iterations in  2.0251037449925207  seconds by  68.9300707567042  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1141.7475951961346
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1141.4335637672048
# step size too small or too large
# RUN  2 , total integrated cost =  1141.2790214191996
# step size too small or too large
# RUN  3 , total integrated cost =  1130.2018892816955
# RUN  4 , total integrated cost =  1141.7589133310887
# step size too small or too large
# RUN  5 , total integrated cost =  1141.4922830063383
# RUN  6 , total integrated cost =  1141.090453861141
# no cost improvement
# RUN  7 , total integrated cost =  1093.2415242901081
# RUN  7 , total integrated cost mean =  1093.2415242901081
# Improved over  7  iterations in  10.748053536983207  seconds by  4.248405786893201  percent.
# rep_ind =  119.86521859871256
# n =  30
# iteration =  6
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3676.7841645025037
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1166.2190900430974
# RUN  2 , total integrated cost =  1144.269396065773
# RUN  3 , total integrated cost =  1142.063212570781
# RUN  3 , total integrated cost mean =  1142.063212570781
# Improved over  3  iterations in  9.962387801962905  seconds by  68.93852993611033  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1141.7877013843895
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1141.480577588564
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  2 , total integrated cost =  1141.3108584940346
# step size too small or too large
# step size too small or too large
# RUN  3 , total integrated cost =  1118.5402765130927
# RUN  3 , total integrated cost mean =  1118.5402765130927
# Improved over  3  iterations in  18.24775492498884  seconds by  2.0360549376306807  percent.
# cost =  1147.1977328552596
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3676.7970994667767
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1166.481954519382
# RUN  2 , total integrated cost =  1144.2419414261442
# RUN  3 , total integrated cost =  1141.9800401160317
# RUN  3 , total integrated cost mean =  1141.9800401160317
# Improved over  3  iterations in  6.15946548699867  seconds by  68.94090130016568  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1141.7589122414313
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1141.4626724153293
# RUN  2 , total integrated cost =  1141.2767609438333
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  3 , total integrated cost =  1093.7854843308235
# RUN  3 , total integrated cost mean =  1093.7854843308235
# Improved over  3  iterations in  11.564531213021837  seconds by  4.20171258540293  percent.
# rep_ind =  14.59928733610866
# iteration =  18
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3675.0613217527757
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1166.3037251928556
# RUN  2 , total integrated cost =  1144.2783839883448
# RUN  3 , total integrated cost =  1141.950601955454
# RUN  3 , total integrated cost mean =  1141.950601955454
# Improved over  3  iterations in  9.49980663700262  seconds by  68.92703272197879  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1141.7575996457197
# Gradient descend method:  None
# step size too small or too large
# RUN  1 , total integrated cost =  1141.4379311132107
# step size too small or too large
# RUN  2 , total integrated cost =  1141.2871625581217
# step size too small or too large
# RUN  3 , total integrated cost =  1054.7656596374577
# RUN  4 , total integrated cost =  1136.3291481046983
# step size too small or too large
# RUN  5 , total integrated cost =  1134.662673093604
# step size too small or too large
# step size too small or too large
# RUN  6 , total integrated cost =  891.2185216362781
# RUN  7 , total integrated cost =  33.9361431908564
# RUN  8 , total integrated cost =  13.639169614304405
# step size too small or too large
# RUN  9 , total integrated cost =  11.654727466238235
# RUN  10 , total integrated cost =  10.981876562952914
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  11 , total integrated cost =  10.755385456670862
# step size too small or too large
# step size too small or too large
# RUN  12 , total integrated cost =  10.683099457437903
# RUN  13 , total integrated cost =  10.52862409908443
# step size too small or too large
# RUN  14 , total integrated cost =  10.444573771918053
# RUN  15 , total integrated cost =  10.380140135721271
# RUN  15 , total integrated cost mean =  10.380140135721271
# Improved over  15  iterations in  68.12852206401294  seconds by  99.09086305718988  percent.
# cost =  10.960914983186436
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3673.344336367154
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1166.206412586079
# RUN  2 , total integrated cost =  1144.2637188295762
# RUN  3 , total integrated cost =  1141.9333600867838
# RUN  3 , total integrated cost mean =  1141.9333600867838
# Improved over  3  iterations in  5.903170544013847  seconds by  68.91297805159951  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1141.7305241837107
# Gradient descend method:  None
# step size too small or too large
# RUN  1 , total integrated cost =  1141.4308630770813
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  2 , total integrated cost =  1141.29821787987
# step size too small or too large
# RUN  3 , total integrated cost =  1051.7842127356312
# RUN  4 , total integrated cost =  1129.0535491913768
# RUN  5 , total integrated cost =  1099.7506669458855
# RUN  6 , total integrated cost =  1112.0235814900777
# RUN  7 , total integrated cost =  1016.0593566052817
# RUN  8 , total integrated cost =  47.6753309604229
# RUN  9 , total integrated cost =  15.596311549065526
# RUN  10 , total integrated cost =  12.055010290933913
# step size too small or too large
# RUN  11 , total integrated cost =  10.882647682638384
# step size too small or too large
# RUN  12 , total integrated cost =  10.563831708679981
# RUN  13 , total integrated cost =  10.33214187606496
# step size too small or too large
# RUN  14 , total integrated cost =  10.218236796597926
# RUN  15 , total integrated cost =  10.129989948434204
# RUN  15 , total integrated cost mean =  10.129989948434204
# Improved over  15  iterations in  67.86580627999501  seconds by  99.11275123736604  percent.
# rep_ind =  32.076813771608535
# n =  50
# iteration =  6
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3675.662551036656
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1166.6347402928866
# RUN  2 , total integrated cost =  1144.2640156310144
# RUN  3 , total integrated cost =  1142.0267697292277
# RUN  3 , total integrated cost mean =  1142.0267697292277
# Improved over  3  iterations in  15.815931670018472  seconds by  68.9300431181546  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1141.7795077105216
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1141.4603337435335
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  2 , total integrated cost =  1141.2993015513978
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  3 , total integrated cost =  1130.4712609333028
# RUN  3 , total integrated cost mean =  1130.4712609333028
# Improved over  3  iterations in  27.539697999018244  seconds by  0.9904054767889363  percent.
# cost =  1147.2152354991892
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3672.4441005163994
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1166.2841972199258
# RUN  2 , total integrated cost =  1144.26484156746
# RUN  3 , total integrated cost =  1141.9451175010395
# RUN  3 , total integrated cost mean =  1141.9451175010395
# Improved over  3  iterations in  13.769077425007708  seconds by  68.90503745610545  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1141.7396764628556
# Gradient descend method:  None
# step size too small or too large
# RUN  1 , total integrated cost =  1141.442163747337
# step size too small or too large
# RUN  2 , total integrated cost =  1141.2893310632692
# RUN  3 , total integrated cost =  1114.4454292388928
# RUN  3 , total integrated cost mean =  1114.4454292388928
# Improved over  3  iterations in  18.345812434970867  seconds by  2.3905841048216274  percent.
# rep_ind =  2.904525562738285
# iteration =  18
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3677.1310658612783
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1166.2786418453684
# RUN  2 , total integrated cost =  1144.2811470637603
# RUN  3 , total integrated cost =  1141.9797844487327
# RUN  3 , total integrated cost mean =  1141.9797844487327
# Improved over  3  iterations in  13.903402189025655  seconds by  68.94372911939564  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1141.755373540927
# Gradient descend method:  None
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  1 , total integrated cost =  1141.4782465606536
# step size too small or too large
# RUN  2 , total integrated cost =  1141.307252563828
# RUN  3 , total integrated cost =  1114.4344504189773
# RUN  4 , total integrated cost =  1141.5503185890664
# step size too small or too large
# step size too small or too large
# RUN  5 , total integrated cost =  1141.2614623028517
# step size too small or too large
# step size too small or too large
# RUN  6 , total integrated cost =  1141.1099960975832
# no cost improvement
# step size too small or too large
# RUN  7 , total integrated cost =  1141.079750308493
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  8 , total integrated cost =  1141.0254876021029
# RUN  9 , total integrated cost =  1141.0176031730994
# RUN  10 , total integrated cost =  1141.013793847514
# step size too small or too large
# step size too small or too large
# RUN  11 , total integrated cost =  1123.1870861439302
# RUN  11 , total integrated cost mean =  1123.1870861439302
# Improved over  11  iterations in  71.71773213299457  seconds by  1.6262929719709547  percent.
# cost =  1147.7157224548432
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3679.1139048167474
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1166.470364248812
# RUN  2 , total integrated cost =  1144.2575666473629
# RUN  3 , total integrated cost =  1141.9465219985693
# RUN  3 , total integrated cost mean =  1141.9465219985693
# Improved over  3  iterations in  9.692535053007305  seconds by  68.96137082074254  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1141.7422604299943
# Gradient descend method:  None
# step size too small or too large
# step size too small or too large
# RUN  1 , total integrated cost =  1141.4298653079122
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  2 , total integrated cost =  1141.2883751485947
# step size too small or too large
# step size too small or too large
# RUN  3 , total integrated cost =  1104.984094079847
# RUN  4 , total integrated cost =  1141.7082808497785
# step size too small or too large
# RUN  5 , total integrated cost =  1133.1921855925334
# RUN  6 , total integrated cost =  1141.4501866356625
# no cost improvement
# step size too small or too large
# RUN  7 , total integrated cost =  1141.177499839562
# step size too small or too large
# RUN  8 , total integrated cost =  1141.0676504340458
# RUN  9 , total integrated cost =  1141.0228764349165
# step size too small or too large
# step size too small or too large
# RUN  10 , total integrated cost =  1140.9873943678485
# RUN  11 , total integrated cost =  1140.9626798114273
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  12 , total integrated cost =  1140.9609859531386
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  13 , total integrated cost =  1135.3273073309115
# RUN  14 , total integrated cost =  1141.2098069184021
# step size too small or too large
# step size too small or too large
# RUN  15 , total integrated cost =  1141.0268071457651
# RUN  15 , total integrated cost mean =  1141.0268071457651
# Improved over  15  iterations in  88.6023369319737  seconds by  0.06266329179754848  percent.
# rep_ind =  7.285806782512638
# sigma =  0.03
# set cost params:  0.008806764401767317 0.0 1.0
# n =  2
# iteration =  6
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1217.853796195525
# Gradient descend method:  None
# RUN  1 , total integrated cost =  398.51837145911895
# RUN  2 , total integrated cost =  392.0637778431752
# RUN  3 , total integrated cost =  391.6334000367159
# RUN  3 , total integrated cost mean =  391.6334000367159
# Improved over  3  iterations in  0.41009356896393  seconds by  67.84233039629663  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  390.8104469263974
# Gradient descend method:  None
# RUN  1 , total integrated cost =  390.4461563841347
# RUN  2 , total integrated cost =  390.4457744702255
# RUN  3 , total integrated cost =  390.3118709994698
# RUN  3 , total integrated cost mean =  390.3118709994698
# Improved over  3  iterations in  0.7123895800323226  seconds by  0.12757487187170113  percent.
# cost =  391.53484840055756
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1219.8692841909647
# Gradient descend method:  None
# RUN  1 , total integrated cost =  755.6042342969673
# RUN  2 , total integrated cost =  391.381200495906
# RUN  3 , total integrated cost =  391.0614070312977
# RUN  3 , total integrated cost mean =  391.0614070312977
# Improved over  3  iterations in  0.3424512470373884  seconds by  67.94235152083075  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  390.9840410816446
# Gradient descend method:  None
# RUN  1 , total integrated cost =  390.82591923418045
# RUN  2 , total integrated cost =  390.8782091775107
# RUN  3 , total integrated cost =  390.8109515151423
# RUN  3 , total integrated cost mean =  390.8109515151423
# Improved over  3  iterations in  0.671490052016452  seconds by  0.04427023824898413  percent.
# rep_ind =  10.036406242072978
# iteration =  18
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1246.3322451197073
# Gradient descend method:  None
# RUN  1 , total integrated cost =  399.57184761939754
# RUN  2 , total integrated cost =  391.5362840054422
# RUN  3 , total integrated cost =  391.1840806645953
# RUN  3 , total integrated cost mean =  391.1840806645953
# Improved over  3  iterations in  0.41219580196775496  seconds by  68.61317821179995  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  390.6808994504887
# Gradient descend method:  None
# RUN  1 , total integrated cost =  390.59305802587005
# RUN  2 , total integrated cost =  390.6439582714859
# RUN  3 , total integrated cost =  390.56516636147984
# RUN  4 , total integrated cost =  390.6350935860956
# step size too small or too large
# RUN  5 , total integrated cost =  390.433821453533
# RUN  6 , total integrated cost =  390.5370547562188
# RUN  7 , total integrated cost =  390.5135470091238
# RUN  8 , total integrated cost =  347.69795835479283
# RUN  9 , total integrated cost =  242.15255178527056
# RUN  10 , total integrated cost =  23.861275492259182
# RUN  11 , total integrated cost =  18.34761554889782
# RUN  12 , total integrated cost =  17.726388574168695
# RUN  13 , total integrated cost =  16.722144352618148
# RUN  14 , total integrated cost =  16.620686072799174
# RUN  15 , total integrated cost =  16.200082961440152
# RUN  15 , total integrated cost mean =  16.200082961440152
# Improved over  15  iterations in  3.678412153967656  seconds by  95.85337215506918  percent.
# cost =  17.60307456194856
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1223.9181709904792
# Gradient descend method:  None
# RUN  1 , total integrated cost =  761.237046274418
# RUN  2 , total integrated cost =  391.43146999580006
# RUN  3 , total integrated cost =  391.2622916378751
# RUN  3 , total integrated cost mean =  391.2622916378751
# Improved over  3  iterations in  0.3925543310469948  seconds by  68.03198931826965  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  391.2143641568673
# Gradient descend method:  None
# RUN  1 , total integrated cost =  391.15666414756106
# RUN  2 , total integrated cost =  390.8722152762758
# RUN  3 , total integrated cost =  390.8999323202204
# RUN  4 , total integrated cost =  390.9860983709385
# RUN  5 , total integrated cost =  390.74938841265487
# RUN  6 , total integrated cost =  390.8734882324279
# RUN  7 , total integrated cost =  390.8889540436827
# RUN  8 , total integrated cost =  390.83433294005675
# RUN  9 , total integrated cost =  390.94956279210385
# RUN  10 , total integrated cost =  390.8173038229566
# RUN  11 , total integrated cost =  390.82922952696873
# RUN  12 , total integrated cost =  390.85298135611066
# RUN  13 , total integrated cost =  390.78937335152125
# RUN  14 , total integrated cost =  390.7763842250552
# RUN  15 , total integrated cost =  390.73283151242583
# RUN  15 , total integrated cost mean =  390.73283151242583
# Improved over  15  iterations in  3.7913680400233716  seconds by  0.12308664726032248  percent.
# rep_ind =  203.37650042503975
# n =  10
# iteration =  6
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1232.1006881194182
# Gradient descend method:  None
# RUN  1 , total integrated cost =  611.8569869400641
# RUN  2 , total integrated cost =  391.26815108397375
# RUN  3 , total integrated cost =  390.9457691476036
# RUN  3 , total integrated cost mean =  390.9457691476036
# Improved over  3  iterations in  1.8777723859529942  seconds by  68.26998207879322  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  390.7156054199326
# Gradient descend method:  None
# RUN  1 , total integrated cost =  390.5833087499811
# RUN  2 , total integrated cost =  390.49810559333406
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  3 , total integrated cost =  378.6031572492484
# RUN  3 , total integrated cost mean =  378.6031572492484
# Improved over  3  iterations in  3.9801432009553537  seconds by  3.1000676713862134  percent.
# cost =  400.25914651486977
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1221.1320934038954
# Gradient descend method:  None
# RUN  1 , total integrated cost =  545.5486265007004
# RUN  2 , total integrated cost =  390.9127396697419
# RUN  3 , total integrated cost =  390.7717339364521
# RUN  3 , total integrated cost mean =  390.7717339364521
# Improved over  3  iterations in  2.1423027210403234  seconds by  67.99922497760426  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  390.80850617691675
# Gradient descend method:  None
# step size too small or too large
# step size too small or too large
# RUN  1 , total integrated cost =  390.47242796095895
# step size too small or too large
# RUN  2 , total integrated cost =  390.5461862214855
# step size too small or too large
# RUN  3 , total integrated cost =  382.44155391947595
# RUN  3 , total integrated cost mean =  382.44155391947595
# Improved over  3  iterations in  4.500519399007317  seconds by  2.140934018885744  percent.
# rep_ind =  10.847550592574636
# iteration =  18
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1233.486001459824
# Gradient descend method:  None
# RUN  1 , total integrated cost =  611.6563642549793
# RUN  2 , total integrated cost =  391.4414731128454
# RUN  3 , total integrated cost =  390.94299950090834
# RUN  3 , total integrated cost mean =  390.94299950090834
# Improved over  3  iterations in  2.1040461259544827  seconds by  68.3058422196742  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  390.63972314663846
# Gradient descend method:  None
# RUN  1 , total integrated cost =  390.6242369274265
# step size too small or too large
# step size too small or too large
# RUN  2 , total integrated cost =  390.60688266547623
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  3 , total integrated cost =  390.5782651592774
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  4 , total integrated cost =  368.63457979603027
# RUN  5 , total integrated cost =  391.25038317922065
# step size too small or too large
# RUN  6 , total integrated cost =  384.8317681717746
# RUN  7 , total integrated cost =  390.7752102219184
# no cost improvement
# RUN  8 , total integrated cost =  390.5019167078682
# RUN  9 , total integrated cost =  390.43158970454294
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  10 , total integrated cost =  390.33898878547905
# RUN  11 , total integrated cost =  390.355820955459
# RUN  12 , total integrated cost =  378.8453311186846
# RUN  12 , total integrated cost mean =  378.8453311186846
# Improved over  12  iterations in  17.918284707993735  seconds by  3.0192505598122352  percent.
# cost =  395.4338319324808
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1231.2804120697788
# Gradient descend method:  None
# RUN  1 , total integrated cost =  607.7794238701823
# RUN  2 , total integrated cost =  391.08246039360625
# RUN  3 , total integrated cost =  390.78364539810116
# RUN  3 , total integrated cost mean =  390.78364539810116
# Improved over  3  iterations in  2.0732732539763674  seconds by  68.26201070305382  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  390.6973864265988
# Gradient descend method:  None
# step size too small or too large
# RUN  1 , total integrated cost =  390.628036360955
# RUN  2 , total integrated cost =  390.583983690132
# RUN  3 , total integrated cost =  390.6016709344507
# RUN  4 , total integrated cost =  377.68400766567436
# RUN  5 , total integrated cost =  391.3772386186089
# RUN  6 , total integrated cost =  390.6587255228868
# RUN  7 , total integrated cost =  390.4676822757716
# no cost improvement
# step size too small or too large
# RUN  8 , total integrated cost =  390.4100730625843
# RUN  9 , total integrated cost =  390.39578891846134
# RUN  10 , total integrated cost =  390.3540009736842
# RUN  11 , total integrated cost =  390.3594360223745
# RUN  12 , total integrated cost =  390.38125553913795
# RUN  13 , total integrated cost =  374.3125364424469
# RUN  13 , total integrated cost mean =  374.3125364424469
# Improved over  13  iterations in  22.041126815020107  seconds by  4.193744456294226  percent.
# rep_ind =  20.982647928631515
# n =  30
# iteration =  6
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1221.201998018513
# Gradient descend method:  None
# RUN  1 , total integrated cost =  520.6237563383954
# RUN  2 , total integrated cost =  391.0627674891827
# RUN  3 , total integrated cost =  390.71908795173005
# RUN  3 , total integrated cost mean =  390.71908795173005
# Improved over  3  iterations in  8.02870109397918  seconds by  68.0053677781645  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  390.63754869171385
# Gradient descend method:  None
# step size too small or too large
# step size too small or too large
# RUN  1 , total integrated cost =  390.50420379819894
# RUN  2 , total integrated cost =  390.52307240894464
# RUN  3 , total integrated cost =  365.2432437603074
# RUN  3 , total integrated cost mean =  365.2432437603074
# Improved over  3  iterations in  12.551483063958585  seconds by  6.500733228655221  percent.
# cost =  404.6175676026146
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1228.4179837534853
# Gradient descend method:  None
# RUN  1 , total integrated cost =  562.2231828679345
# RUN  2 , total integrated cost =  391.23964628623196
# RUN  3 , total integrated cost =  390.9487007205156
# RUN  3 , total integrated cost mean =  390.9487007205156
# Improved over  3  iterations in  6.133470825967379  seconds by  68.174619234574  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  390.6868839682348
# Gradient descend method:  None
# RUN  1 , total integrated cost =  390.56897195690465
# step size too small or too large
# step size too small or too large
# RUN  2 , total integrated cost =  390.5373073544873
# RUN  3 , total integrated cost =  371.0906287232088
# RUN  3 , total integrated cost mean =  371.0906287232088
# Improved over  3  iterations in  13.116992661962286  seconds by  5.015846717449378  percent.
# rep_ind =  13.309268684859001
# iteration =  18
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1221.587938015668
# Gradient descend method:  None
# RUN  1 , total integrated cost =  446.0945884576069
# RUN  2 , total integrated cost =  391.3336719925404
# RUN  3 , total integrated cost =  391.01365440970693
# RUN  3 , total integrated cost mean =  391.01365440970693
# Improved over  3  iterations in  6.6428417499992065  seconds by  67.99136253384553  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  390.7034015761231
# Gradient descend method:  None
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  1 , total integrated cost =  390.58516011030855
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  2 , total integrated cost =  390.5561840521341
# RUN  3 , total integrated cost =  381.9113436590549
# step size too small or too large
# step size too small or too large
# RUN  4 , total integrated cost =  390.9842356669697
# step size too small or too large
# step size too small or too large
# RUN  5 , total integrated cost =  390.6026373078952
# RUN  6 , total integrated cost =  390.39945640924003
# no cost improvement
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  7 , total integrated cost =  390.3344566606896
# RUN  8 , total integrated cost =  390.28619826060236
# step size too small or too large
# step size too small or too large
# RUN  9 , total integrated cost =  390.26896341850187
# step size too small or too large
# RUN  10 , total integrated cost =  389.8221192375758
# RUN  11 , total integrated cost =  390.35509581879677
# step size too small or too large
# RUN  12 , total integrated cost =  390.28675394955764
# RUN  13 , total integrated cost =  380.9748932184027
# RUN  13 , total integrated cost mean =  380.9748932184027
# Improved over  13  iterations in  66.048812818015  seconds by  2.4899983768953575  percent.
# cost =  394.14404216295526
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1226.4420013828133
# Gradient descend method:  None
# RUN  1 , total integrated cost =  540.1133577440065
# RUN  2 , total integrated cost =  391.15474072261145
# RUN  3 , total integrated cost =  390.8454306814167
# RUN  3 , total integrated cost mean =  390.8454306814167
# Improved over  3  iterations in  8.696614994958509  seconds by  68.13176405890059  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  390.6500875959234
# Gradient descend method:  None
# step size too small or too large
# RUN  1 , total integrated cost =  390.54620530697696
# RUN  2 , total integrated cost =  390.5304445908005
# RUN  3 , total integrated cost =  386.42833427727794
# RUN  4 , total integrated cost =  390.834274311451
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  5 , total integrated cost =  390.5474246437543
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  6 , total integrated cost =  390.4244582775818
# no cost improvement
# RUN  7 , total integrated cost =  390.3799124160875
# RUN  8 , total integrated cost =  390.37812928452985
# RUN  9 , total integrated cost =  390.3244673714596
# RUN  10 , total integrated cost =  390.30149035737907
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  11 , total integrated cost =  390.33885660693375
# step size too small or too large
# step size too small or too large
# RUN  12 , total integrated cost =  378.7565029392529
# RUN  12 , total integrated cost mean =  378.7565029392529
# Improved over  12  iterations in  60.94226616102969  seconds by  3.0445621374013  percent.
# rep_ind =  6.208919759060761
# n =  50
# iteration =  6
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1225.9580960913916
# Gradient descend method:  None
# RUN  1 , total integrated cost =  512.2848399896133
# RUN  2 , total integrated cost =  391.19961254520854
# step size too small or too large
# RUN  3 , total integrated cost =  390.8394017427097
# RUN  3 , total integrated cost mean =  390.8394017427097
# Improved over  3  iterations in  13.476492701040115  seconds by  68.11967692951441  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  390.7168759773462
# Gradient descend method:  None
# RUN  1 , total integrated cost =  390.5578483675918
# step size too small or too large
# RUN  2 , total integrated cost =  390.51019834635895
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  3 , total integrated cost =  371.7249898042769
# RUN  3 , total integrated cost mean =  371.7249898042769
# Improved over  3  iterations in  22.34367176500382  seconds by  4.860779592783814  percent.
# cost =  396.4487408518522
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1224.0068495074522
# Gradient descend method:  None
# RUN  1 , total integrated cost =  469.08619997806016
# RUN  2 , total integrated cost =  391.25879429593203
# RUN  3 , total integrated cost =  390.9982137547044
# RUN  3 , total integrated cost mean =  390.9982137547044
# Improved over  3  iterations in  9.908743860956747  seconds by  68.05588025001293  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  390.6691760835378
# Gradient descend method:  None
# step size too small or too large
# step size too small or too large
# RUN  1 , total integrated cost =  390.5370669136878
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  2 , total integrated cost =  390.49752330941715
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  3 , total integrated cost =  377.98244254177456
# RUN  3 , total integrated cost mean =  377.98244254177456
# Improved over  3  iterations in  21.965412192977965  seconds by  3.2474365315809877  percent.
# rep_ind =  5.143550348290237
# iteration =  18
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1221.5954561814872
# Gradient descend method:  None
# RUN  1 , total integrated cost =  455.5044414725534
# RUN  2 , total integrated cost =  391.39814420083866
# RUN  3 , total integrated cost =  390.9714865893053
# RUN  3 , total integrated cost mean =  390.9714865893053
# Improved over  3  iterations in  9.480201428988948  seconds by  67.99501139178923  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  390.7195078280689
# Gradient descend method:  None
# step size too small or too large
# RUN  1 , total integrated cost =  390.5649328079784
# step size too small or too large
# RUN  2 , total integrated cost =  390.5101771633625
# step size too small or too large
# step size too small or too large
# RUN  3 , total integrated cost =  382.8561646116429
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  4 , total integrated cost =  390.90909471626867
# step size too small or too large
# RUN  5 , total integrated cost =  390.56155318542335
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  6 , total integrated cost =  390.38494661645296
# no cost improvement
# step size too small or too large
# step size too small or too large
# RUN  7 , total integrated cost =  390.3185634486908
# step size too small or too large
# RUN  8 , total integrated cost =  390.27369049087554
# step size too small or too large
# step size too small or too large
# RUN  9 , total integrated cost =  388.8574831764301
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  10 , total integrated cost =  390.51676058329036
# step size too small or too large
# RUN  11 , total integrated cost =  390.3445146258496
# step size too small or too large
# step size too small or too large
# RUN  12 , total integrated cost =  390.29566582558874
# step size too small or too large
# RUN  13 , total integrated cost =  390.26995045053286
# RUN  14 , total integrated cost =  390.2439980904372
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  15 , total integrated cost =  377.96542225383973
# RUN  15 , total integrated cost mean =  377.96542225383973
# Improved over  15  iterations in  111.41893539502053  seconds by  3.26425615273898  percent.
# cost =  397.1412673691288
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1223.9237882452626
# Gradient descend method:  None
# RUN  1 , total integrated cost =  468.7890139550282
# RUN  2 , total integrated cost =  391.321049545855
# step size too small or too large
# RUN  3 , total integrated cost =  390.90331013760283
# RUN  3 , total integrated cost mean =  390.90331013760283
# Improved over  3  iterations in  12.78723782801535  seconds by  68.06146641711734  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  390.7715872851937
# Gradient descend method:  None
# RUN  1 , total integrated cost =  390.6183050646931
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  2 , total integrated cost =  390.5273223995417
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  3 , total integrated cost =  383.6434597164351
# RUN  4 , total integrated cost =  391.03954364569
# step size too small or too large
# step size too small or too large
# RUN  5 , total integrated cost =  390.6125983691992
# step size too small or too large
# step size too small or too large
# RUN  6 , total integrated cost =  390.41651533527147
# no cost improvement
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  7 , total integrated cost =  390.3525202658483
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  8 , total integrated cost =  390.30118434444177
# RUN  9 , total integrated cost =  390.2571784739586
# RUN  10 , total integrated cost =  384.5195072330267
# RUN  10 , total integrated cost mean =  384.5195072330267
# Improved over  10  iterations in  66.11398473201552  seconds by  1.5999320973159854  percent.
# rep_ind =  9.190391658760559
# sigma =  0.049999999999999996
# set cost params:  0.005285084401824156 0.0 1.0
# n =  2
# iteration =  6
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  746.4856048639042
# Gradient descend method:  None
# RUN  1 , total integrated cost =  466.7666506023263
# RUN  2 , total integrated cost =  240.63027209560119
# RUN  3 , total integrated cost =  240.7597198825933
# RUN  3 , total integrated cost mean =  240.7597198825933
# Improved over  3  iterations in  0.36168638395611197  seconds by  67.74757365529004  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  240.68463741353963
# Gradient descend method:  None
# step size too small or too large
# RUN  1 , total integrated cost =  240.77075116940546
# RUN  2 , total integrated cost =  240.46216787411413
# step size too small or too large
# RUN  3 , total integrated cost =  233.08242372919307
# RUN  3 , total integrated cost mean =  233.08242372919307
# Improved over  3  iterations in  0.947412152949255  seconds by  3.158578697021113  percent.
# cost =  259.34504720178916
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  759.6084384360546
# Gradient descend method:  None
# RUN  1 , total integrated cost =  245.06208439793642
# RUN  2 , total integrated cost =  240.93468918166297
# RUN  3 , total integrated cost =  241.01174039766295
# RUN  3 , total integrated cost mean =  241.01174039766295
# Improved over  3  iterations in  0.3608046870213002  seconds by  68.27158201482357  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  241.48331867751006
# Gradient descend method:  None
# RUN  1 , total integrated cost =  240.50865456773482
# RUN  2 , total integrated cost =  240.34237144698787
# RUN  3 , total integrated cost =  240.13877118062663
# RUN  3 , total integrated cost mean =  240.13877118062663
# Improved over  3  iterations in  0.6195230669691227  seconds by  0.5567869053013226  percent.
# rep_ind =  34.67767342057718
# iteration =  18
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  728.465293807137
# Gradient descend method:  None
# RUN  1 , total integrated cost =  679.7685179898147
# RUN  2 , total integrated cost =  250.59305127121453
# RUN  3 , total integrated cost =  250.338717372416
# RUN  3 , total integrated cost mean =  250.338717372416
# Improved over  3  iterations in  0.5786986650200561  seconds by  65.63477773057863  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  250.24312698538097
# Gradient descend method:  None
# RUN  1 , total integrated cost =  249.67173598388783
# RUN  2 , total integrated cost =  249.77836794498808
# RUN  3 , total integrated cost =  249.7655108957905
# RUN  4 , total integrated cost =  249.52961109651986
# RUN  5 , total integrated cost =  249.31214663453602
# RUN  6 , total integrated cost =  249.34398931659598
# RUN  7 , total integrated cost =  249.36696133762143
# ...
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  175.3967415022535
# Gradient descend method:  None
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  1 , total integrated cost =  175.29490831637628
# RUN  2 , total integrated cost =  175.27659593388927
# step size too small or too large
# RUN  3 , total integrated cost =  170.89129072459735
# RUN  3 , total integrated cost mean =  170.89129072459735
# Improved over  3  iterations in  3.519694396003615  seconds by  2.5687197715689933  percent.
# rep_ind =  10.15589445442832
# iteration =  18
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  519.4073033120249
# Gradient descend method:  None
# RUN  1 , total integrated cost =  245.21480367588342
# RUN  2 , total integrated cost =  176.4270974153688
# RUN  3 , total integrated cost =  175.88874015002884
# RUN  3 , total integrated cost mean =  175.88874015002884
# Improved over  3  iterations in  1.691688078979496  seconds by  66.13664478176065  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  175.58479901550845
# Gradient descend method:  None
# RUN  1 , total integrated cost =  175.3453872284281
# RUN  2 , total integrated cost =  175.41028594810453
# RUN  3 , total integrated cost =  175.37030715884163
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  4 , total integrated cost =  175.45560742173475
# RUN  5 , total integrated cost =  161.1962900833227
# RUN  6 , total integrated cost =  174.3211380099955
# step size too small or too large
# step size too small or too large
# RUN  7 , total integrated cost =  175.7673832904705
# RUN  8 , total integrated cost =  177.07655720351335
# no cost improvement
# RUN  9 , total integrated cost =  175.06153644079544
# RUN  10 , total integrated cost =  175.3240524616094
# RUN  11 , total integrated cost =  176.36438120245126
# RUN  12 , total integrated cost =  174.41539633347855
# RUN  13 , total integrated cost =  175.00983151660188
# RUN  14 , total integrated cost =  174.32064008534905
# RUN  15 , total integrated cost =  170.4289809763759
# RUN  15 , total integrated cost mean =  170.4289809763759
# Improved over  15  iterations in  24.79774664103752  seconds by  2.936369246108356  percent.
# cost =  194.91869735142828
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  522.91506516891
# Gradient descend method:  None
# RUN  1 , total integrated cost =  207.15924068370177
# RUN  2 , total integrated cost =  176.63710247638278
# step size too small or too large
# RUN  3 , total integrated cost =  176.2932254801898
# RUN  3 , total integrated cost mean =  176.2932254801898
# Improved over  3  iterations in  3.399281546007842  seconds by  66.28645123788044  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  175.63276399871242
# Gradient descend method:  None
# step size too small or too large
# RUN  1 , total integrated cost =  175.57835202106276
# RUN  2 , total integrated cost =  175.3239525190947
# step size too small or too large
# RUN  3 , total integrated cost =  171.6957544172488
# RUN  4 , total integrated cost =  175.6890806625973
# RUN  5 , total integrated cost =  175.26388786283601
# step size too small or too large
# step size too small or too large
# RUN  6 , total integrated cost =  175.10626408778506
# no cost improvement
# step size too small or too large
# RUN  7 , total integrated cost =  175.22191033257425
# RUN  8 , total integrated cost =  175.36486664764297
# RUN  9 , total integrated cost =  175.12739846712086
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  10 , total integrated cost =  175.14660410188486
# step size too small or too large
# RUN  11 , total integrated cost =  172.75200650899814
# RUN  11 , total integrated cost mean =  172.75200650899814
# Improved over  11  iterations in  18.545641436008736  seconds by  1.640216451718203  percent.
# rep_ind =  24.386907377600615
# n =  30
# iteration =  6
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  525.8276432799688
# Gradient descend method:  None
# RUN  1 , total integrated cost =  270.97043857543105
# RUN  2 , total integrated cost =  176.57750707460988
# step size too small or too large
# RUN  3 , total integrated cost =  175.86094431660317
# RUN  3 , total integrated cost mean =  175.86094431660317
# Improved over  3  iterations in  9.32691700902069  seconds by  66.55540145823625  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  175.73156179446283
# Gradient descend method:  None
# RUN  1 , total integrated cost =  175.50596767187028
# RUN  2 , total integrated cost =  163.7592492095866
# step size too small or too large
# RUN  3 , total integrated cost =  176.53392598866728
# RUN  3 , total integrated cost mean =  176.53392598866728
# Improved over  3  iterations in  14.881735565024428  seconds by  -0.45658513815685353  percent.
# cost =  178.17210283660538
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  529.547100794204
# Gradient descend method:  None
# RUN  1 , total integrated cost =  242.19691427738044
# RUN  2 , total integrated cost =  176.55207976095338
# RUN  3 , total integrated cost =  175.9901541736563
# RUN  3 , total integrated cost mean =  175.9901541736563
# Improved over  3  iterations in  5.756560351990629  seconds by  66.7659111135327  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  175.72088062303004
# Gradient descend method:  None
# step size too small or too large
# RUN  1 , total integrated cost =  175.49704233593658
# step size too small or too large
# step size too small or too large
# RUN  2 , total integrated cost =  175.51410889915437
# step size too small or too large
# RUN  3 , total integrated cost =  175.3585039228978
# RUN  3 , total integrated cost mean =  175.3585039228978
# Improved over  3  iterations in  10.705448505992536  seconds by  0.20622290239350605  percent.
# rep_ind =  19.06291011889225
# iteration =  18
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  524.3417763538953
# Gradient descend method:  None
# RUN  1 , total integrated cost =  223.1139222811992
# RUN  2 , total integrated cost =  176.27915147909167
# step size too small or too large
# RUN  3 , total integrated cost =  175.75260209724087
# RUN  3 , total integrated cost mean =  175.75260209724087
# Improved over  3  iterations in  6.961433379037771  seconds by  66.48128949034574  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  175.60772406023463
# Gradient descend method:  None
# RUN  1 , total integrated cost =  175.39108224397486
# step size too small or too large
# step size too small or too large
# RUN  2 , total integrated cost =  175.34688285199758
# RUN  3 , total integrated cost =  170.90225093943818
# step size too small or too large
# step size too small or too large
# RUN  4 , total integrated cost =  176.25757824457048
# RUN  5 , total integrated cost =  175.58562462164892
# RUN  6 , total integrated cost =  175.49000247769763
# no cost improvement
# RUN  7 , total integrated cost =  175.26490264830926
# RUN  8 , total integrated cost =  175.3284684297881
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  9 , total integrated cost =  175.14926248212785
# step size too small or too large
# RUN  10 , total integrated cost =  175.16854272117598
# RUN  11 , total integrated cost =  173.2668604553799
# RUN  11 , total integrated cost mean =  173.2668604553799
# Improved over  11  iterations in  37.20721981796669  seconds by  1.3330071996444701  percent.
# cost =  176.32072048841349
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  525.1541461970169
# Gradient descend method:  None
# RUN  1 , total integrated cost =  245.17394102943476
# RUN  2 , total integrated cost =  176.5061799900386
# RUN  3 , total integrated cost =  175.8474458393295
# RUN  3 , total integrated cost mean =  175.8474458393295
# Improved over  3  iterations in  5.17544837197056  seconds by  66.51507997932505  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  175.68163399116727
# Gradient descend method:  None
# step size too small or too large
# RUN  1 , total integrated cost =  175.4224980239423
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  2 , total integrated cost =  175.40838423809643
# step size too small or too large
# RUN  3 , total integrated cost =  165.6615792280894
# RUN  4 , total integrated cost =  176.66143863508944
# step size too small or too large
# step size too small or too large
# RUN  5 , total integrated cost =  175.91181029447623
# RUN  6 , total integrated cost =  175.758652252958
# no cost improvement
# step size too small or too large
# step size too small or too large
# RUN  7 , total integrated cost =  175.59351918808755
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  8 , total integrated cost =  175.29496333271635
# RUN  9 , total integrated cost =  175.2062506149475
# step size too small or too large
# RUN  10 , total integrated cost =  175.17794726114062
# RUN  11 , total integrated cost =  175.17753788669705
# RUN  12 , total integrated cost =  175.25418162102434
# step size too small or too large
# step size too small or too large
# RUN  13 , total integrated cost =  175.19505654465559
# RUN  14 , total integrated cost =  175.2252803548899
# step size too small or too large
# RUN  15 , total integrated cost =  173.97249718831247
# RUN  15 , total integrated cost mean =  173.97249718831247
# Improved over  15  iterations in  51.768977771978825  seconds by  0.9728602609312702  percent.
# rep_ind =  3.763780834273609
# n =  50
# iteration =  6
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  518.9004186177517
# Gradient descend method:  None
# RUN  1 , total integrated cost =  301.2302063557127
# RUN  2 , total integrated cost =  176.8575829534483
# RUN  3 , total integrated cost =  176.13661699528612
# RUN  3 , total integrated cost mean =  176.13661699528612
# Improved over  3  iterations in  8.95644745201571  seconds by  66.0557959339329  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  175.9088501848484
# Gradient descend method:  None
# RUN  1 , total integrated cost =  175.61020134200507
# RUN  2 , total integrated cost =  175.54069129544052
# step size too small or too large
# step size too small or too large
# RUN  3 , total integrated cost =  169.87902944128885
# RUN  3 , total integrated cost mean =  169.87902944128885
# Improved over  3  iterations in  17.533883882977534  seconds by  3.4278097646726167  percent.
# cost =  177.88402949683274
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  524.2334794902835
# Gradient descend method:  None
# RUN  1 , total integrated cost =  256.8760746488324
# RUN  2 , total integrated cost =  176.3743467484273
# RUN  3 , total integrated cost =  175.7369303743149
# RUN  3 , total integrated cost mean =  175.7369303743149
# Improved over  3  iterations in  9.301352643000428  seconds by  66.47735460444355  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  175.62053922948087
# Gradient descend method:  None
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  1 , total integrated cost =  175.43185414084437
# step size too small or too large
# step size too small or too large
# RUN  2 , total integrated cost =  175.4539305078514
# step size too small or too large
# RUN  3 , total integrated cost =  172.63138705185688
# RUN  3 , total integrated cost mean =  172.63138705185688
# Improved over  3  iterations in  19.05943925702013  seconds by  1.7020515884637604  percent.
# rep_ind =  7.306983035292979
# iteration =  18
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  522.506976338825
# Gradient descend method:  None
# RUN  1 , total integrated cost =  248.7526285066597
# RUN  2 , total integrated cost =  176.61000383023486
# step size too small or too large
# RUN  3 , total integrated cost =  175.76333127953424
# RUN  3 , total integrated cost mean =  175.76333127953424
# Improved over  3  iterations in  10.548324286006391  seconds by  66.3615340581484  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  175.6345198242699
# Gradient descend method:  None
# step size too small or too large
# RUN  1 , total integrated cost =  175.45387834784444
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  2 , total integrated cost =  175.37156667063772
# RUN  3 , total integrated cost =  167.47700076608146
# RUN  4 , total integrated cost =  176.00033644558167
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  5 , total integrated cost =  175.63608559101473
# RUN  6 , total integrated cost =  175.07012505275577
# no cost improvement
# RUN  7 , total integrated cost =  175.43446813261974
# step size too small or too large
# step size too small or too large
# RUN  8 , total integrated cost =  175.29070756692323
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  9 , total integrated cost =  175.21504679382852
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  10 , total integrated cost =  175.19279235825482
# step size too small or too large
# step size too small or too large
# RUN  11 , total integrated cost =  173.4662156318092
# RUN  11 , total integrated cost mean =  173.4662156318092
# Improved over  11  iterations in  63.107809481967706  seconds by  1.23455468471127  percent.
# cost =  176.49790060951307
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  525.4236381624673
# Gradient descend method:  None
# RUN  1 , total integrated cost =  252.75553398665838
# RUN  2 , total integrated cost =  176.37785169303442
# RUN  3 , total integrated cost =  175.84202409696235
# RUN  3 , total integrated cost mean =  175.84202409696235
# Improved over  3  iterations in  7.0582811599597335  seconds by  66.5332864140022  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  175.6790682382671
# Gradient descend method:  None
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  1 , total integrated cost =  175.47864477654167
# RUN  2 , total integrated cost =  175.42160431521094
# step size too small or too large
# RUN  3 , total integrated cost =  165.88501311766228
# step size too small or too large
# step size too small or too large
# RUN  4 , total integrated cost =  176.42094763059475
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  5 , total integrated cost =  175.82171243996217
# RUN  6 , total integrated cost =  175.74370536410947
# no cost improvement
# RUN  7 , total integrated cost =  174.14065601231258
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  8 , total integrated cost =  175.46150708592074
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  9 , total integrated cost =  173.6602286017347
# step size too small or too large
# RUN  10 , total integrated cost =  175.33244439318244
# step size too small or too large
# RUN  11 , total integrated cost =  175.1324666787406
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  12 , total integrated cost =  175.20842346874207
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  13 , total integrated cost =  172.3640988714146
# RUN  13 , total integrated cost mean =  172.3640988714146
# Improved over  13  iterations in  61.940576850029174  seconds by  1.8869461228907056  percent.
# rep_ind =  4.1563346985132945

# %%
#len(sigma_array), 4, N_max, max_it

##### METHOD 3
method_ind = 2
step_method_ind = 0

for d in dict_list:
    
    if d['point'][0] != 0.5:
        continue
    if d['point'][1] != 0.5:
        continue
        
    print("Point = ", d['point'])
    aln.params.ext_exc_current = d['point'][0] * 5.
    aln.params.ext_inh_current = d['point'][1] * 5.
    
    max_it = d['cost'].shape[3]
    
    for s_ind in range(len(d['sigma'])):
        
        print("sigma = ", d['sigma'][s_ind])
        
        s = d['sigma'][s_ind]
        aln.params.sigma_ou = s
        c_p = d['cost_params'][s_ind]
        cost.setParams(c_p[0], c_p[1], c_p[2])
        
        target_ = d['target'][s_ind].copy()
        target_[0,0,:int(trans_time * dur / aln.params.dt)] = -1000
        target_[0,1,:int(trans_time * dur / aln.params.dt)] = -1000
                
        for n_ind in range(len(d['N_array'])):
            
            n_ = d['N_array'][n_ind]
            
            print("n = ", n_)
            aln.params.duration = dur
        
            for i_it in range(1,len(d['it_array'])):

                it = d['it_array'][i_it]
                print("iteration = ", it)
                
                if ( d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it] > 0.
                    and d['rep_ind'][s_ind, method_ind, step_method_ind, n_ind, i_it] > 0. ) :
                    continue
                
                c_vars = d['init']
                aln.params.duration = dur
                setinit(d['init_vars'], aln)
                control_init = aln.getZeroControl()
                    
                
                bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                    control_init, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_ = init_it,
                    tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                    t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                    control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                    noise_real=n_, init_params = d['init_vars'], method='M3')
            
                control_init = bc[:,:,100:-100]
                c_vars = [0,1]
                aln.params.duration = dur
                setinit(d['init_vars'], aln)
                
                bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                    control_init, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_=it-init_it,
                    tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                    t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                    control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                    noise_real=n_, init_params = d['init_vars'], method='M3')

                control_init = bc[:,:,100:-100]
                aln.params.duration = dur
                setinit(d['init_vars'], aln)
                cost_final = 0.
                cs = cost.numba_cost_sparsity_int(1, 6, T, d['cost_params'][s_ind][2], dt, control_init)

                for j in range(noise_realizations_final):
                    state_ = fo.updateState(aln, control_init)
                    cost_final += cost.numba_cost_precision_int(1, T, dt, d['cost_params'][s_ind][0],
                                                                   state_, target_, list(prec_vars) )

                d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it] = (
                                cost_final / noise_realizations_final + cs )
                print('cost = ', d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it])
                
                c_vars = d['init']                    
                aln.params.duration = dur
                control_init1 = aln.getZeroControl()
                setinit(d['init_vars'], aln)
                
                bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                    control_init1, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_ = init_it,
                    tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                    t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                    control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                    noise_real=n_, init_params = d['init_vars'], method='M3')
            
                control_init1 = bc[:,:,100:-100]
                c_vars = [0,1]
                aln.params.duration = dur
                setinit(d['init_vars'], aln)
                
                bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                    control_init1, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_=it-init_it,
                    tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                    t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                    control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                    noise_real=n_, init_params = d['init_vars'], method='M3')

                control_init1 = bc[:,:,100:-100]
                d['rep_ind'][s_ind, method_ind, step_method_ind, n_ind, i_it] = rep_ind(control_init, control_init1)
                print('rep_ind = ', d['rep_ind'][s_ind, method_ind, step_method_ind, n_ind, i_it])
                
                file=open(dict_file, "wb")
                pickle.dump(dict_list, file)
                file.close()
                
    break

# %%
#len(sigma_array), 4, N_max, max_it

##### METHOD 4
method_ind = 3
step_method_ind = 0

for d in dict_list:
    
    if d['point'][0] != 0.5:
        continue
    if d['point'][1] != 0.5:
        continue
        
        
    print("Point = ", d['point'])
    aln.params.ext_exc_current = d['point'][0] * 5.
    aln.params.ext_inh_current = d['point'][1] * 5.
    
    max_it = d['cost'].shape[3]
    
    for s_ind in range(len(d['sigma'])):
        
        print("sigma = ", d['sigma'][s_ind])
        
        s = d['sigma'][s_ind]
        aln.params.sigma_ou = s
        c_p = d['cost_params'][s_ind]
        cost.setParams(c_p[0], c_p[1], c_p[2])
        
        target_ = d['target'][s_ind].copy()
        target_[0,0,:int(trans_time * dur / aln.params.dt)] = -1000
        target_[0,1,:int(trans_time * dur / aln.params.dt)] = -1000
                
        for n_ind in range(len(d['N_array'])):
            
            n_ = d['N_array'][n_ind]
            
            print("n = ", n_)
            aln.params.duration = dur
        
            for i_it in range(1,len(d['it_array'])):

            
                it = d['it_array'][i_it]
                print("iteration = ", it)
                
                if d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it] > 0.:
                    continue
                
                c_vars = d['init']
                aln.params.duration = dur
                setinit(d['init_vars'], aln)
                control_init = aln.getZeroControl()
                    
                
                bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                    control_init, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_ = init_it,
                    tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                    t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                    control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                    noise_real=n_, init_params = d['init_vars'], method='M4')
            
                control_init = bc[:,:,100:-100]
                c_vars = [0,1]
                aln.params.duration = dur
                setinit(d['init_vars'], aln)
                
                bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                    control_init, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_=it-init_it,
                    tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                    t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                    control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                    noise_real=n_, init_params = d['init_vars'], method='M4')

                control_init = bc[:,:,100:-100]
                aln.params.duration = dur
                setinit(d['init_vars'], aln)
                cost_final = 0.
                cs = cost.numba_cost_sparsity_int(1, 6, T, d['cost_params'][s_ind][2], dt, control_init)

                for j in range(noise_realizations_final):
                    state_ = fo.updateState(aln, control_init)
                    cost_final += cost.numba_cost_precision_int(1, T, dt, d['cost_params'][s_ind][0],
                                                                   state_, target_, list(prec_vars) )

                d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it] = (
                                cost_final / noise_realizations_final + cs )
                print('cost = ', d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it])
                
                c_vars = d['init']                    
                aln.params.duration = dur
                control_init1 = aln.getZeroControl()
                setinit(d['init_vars'], aln)
                
                bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                    control_init1, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_ = init_it,
                    tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                    t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                    control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                    noise_real=n_, init_params = d['init_vars'], method='M4')
            
                control_init1 = bc[:,:,100:-100]
                c_vars = [0,1]
                aln.params.duration = dur
                setinit(d['init_vars'], aln)
                
                bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                    control_init1, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_=it-init_it,
                    tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                    t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                    control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                    noise_real=n_, init_params = d['init_vars'], method='M4')

                control_init1 = bc[:,:,100:-100]
                d['rep_ind'][s_ind, method_ind, step_method_ind, n_ind, i_it] = rep_ind(control_init, control_init1)
                print('rep_ind = ', d['rep_ind'][s_ind, method_ind, step_method_ind, n_ind, i_it])
                
                file=open(dict_file, "wb")
                pickle.dump(dict_list, file)
                file.close()
                
    break

# %%
for s_ind in range(len(d['sigma'])):
    for n_ind in range(len(d['N_array'])):
        for i_it in range(1,len(d['it_array'])):
            #d['cost'][2, 2, 0, n_ind, i_it] = 0.

# %%
#len(sigma_array), 4, N_max, max_it

##### METHOD 3
method_ind = 2
step_method_ind = 1
step_m = 'S1'
if step_method_ind == 1:
    step_m = 'S2'

for d in dict_list:
    
    if d['point'][0] != 0.5:
        continue
    if d['point'][1] != 0.5:
        continue
        
        
    print("Point = ", d['point'])
    aln.params.ext_exc_current = d['point'][0] * 5.
    aln.params.ext_inh_current = d['point'][1] * 5.
    
    max_it = d['cost'].shape[3]
    
    for s_ind in range(len(d['sigma'])):
        
        print("sigma = ", d['sigma'][s_ind])
        
        s = d['sigma'][s_ind]
        aln.params.sigma_ou = s
        c_p = d['cost_params'][s_ind]
        cost.setParams(c_p[0], c_p[1], c_p[2])
        
        target_ = d['target'][s_ind].copy()
        target_[0,0,:int(trans_time * dur / aln.params.dt)] = -1000
        target_[0,1,:int(trans_time * dur / aln.params.dt)] = -1000
                
        for n_ind in range(len(d['N_array'])):
            
            n_ = d['N_array'][n_ind]
            
            print("n = ", n_)
            aln.params.duration = dur
        
            for i_it in range(1,len(d['it_array'])):
                
                if i_it in [2,4]:
                    continue
            
                it = d['it_array'][i_it]
                print("iteration = ", it)
                
                if d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it] > 0.:
                    continue
                
                c_vars = d['init']
                aln.params.duration = dur
                setinit(d['init_vars'], aln)
                control_init = aln.getZeroControl()
                    
                
                bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                    control_init, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_ = init_it,
                    tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                    t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                    control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                    noise_real=n_, init_params = d['init_vars'], method='M3', method_step=step_m)
            
                control_init = bc[:,:,100:-100]
                c_vars = [0,1]
                aln.params.duration = dur
                setinit(d['init_vars'], aln)
                
                bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                    control_init, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_=it-init_it,
                    tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                    t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                    control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                    noise_real=n_, init_params = d['init_vars'], method='M3', method_step=step_m)

                control_init = bc[:,:,100:-100]
                aln.params.duration = dur
                setinit(d['init_vars'], aln)
                cost_final = 0.
                cs = cost.numba_cost_sparsity_int(1, 6, T, d['cost_params'][s_ind][2], dt, control_init)

                for j in range(noise_realizations_final):
                    state_ = fo.updateState(aln, control_init)
                    cost_final += cost.numba_cost_precision_int(1, T, dt, d['cost_params'][s_ind][0],
                                                                   state_, target_, list(prec_vars) )

                d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it] = (
                                cost_final / noise_realizations_final + cs )
                print('cost = ', d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it])
                
                c_vars = d['init']                    
                aln.params.duration = dur
                control_init1 = aln.getZeroControl()
                setinit(d['init_vars'], aln)
                
                bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                    control_init1, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_ = init_it,
                    tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                    t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                    control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                    noise_real=n_, init_params = d['init_vars'], method='M3', method_step=step_m)
            
                control_init1 = bc[:,:,100:-100]
                c_vars = [0,1]
                aln.params.duration = dur
                setinit(d['init_vars'], aln)
                
                bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                    control_init1, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_=it-init_it,
                    tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                    t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                    control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                    noise_real=n_, init_params = d['init_vars'], method='M3', method_step=step_m)

                control_init1 = bc[:,:,100:-100]
                d['rep_ind'][s_ind, method_ind, step_method_ind, n_ind, i_it] = rep_ind(control_init, control_init1)
                print('rep_ind = ', d['rep_ind'][s_ind, method_ind, step_method_ind, n_ind, i_it])
                
                file=open(dict_file, "wb")
                pickle.dump(dict_list, file)
                file.close()
                
    break
# Out:
# Point =  [0.4  0.35]
# sigma =  0.01
# set cost params:  0.02018278188257825 0.0 1.0
# n =  2
# iteration =  6
# iteration =  12
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1628.6254837790343
# Gradient descend method:  None
# RUN  1 , total integrated cost =  105.03790261836195
# RUN  2 , total integrated cost =  19.36513058081341
# RUN  3 , total integrated cost =  6.118748250685479
# RUN  3 , total integrated cost mean =  6.118748250685479
# Improved over  3  iterations in  25.309855481027626  seconds by  99.62429985827757  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5.7802585470201695
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.2534261388526255
# RUN  2 , total integrated cost =  4.4182953986499385
# RUN  3 , total integrated cost =  4.181736542495442
# RUN  4 , total integrated cost =  4.103193721940745
# RUN  5 , total integrated cost =  3.9497612800898696
# RUN  6 , total integrated cost =  3.6663496706426404
# RUN  7 , total integrated cost =  3.7673803191150226
# RUN  8 , total integrated cost =  3.585600982488603
# RUN  9 , total integrated cost =  3.5539747422099754
# RUN  9 , total integrated cost mean =  3.5539747422099754
# Improved over  9  iterations in  3.898158876982052  seconds by  38.515298004409935  percent.
# cost =  3.7811877951353647
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1618.614677216381
# Gradient descend method:  None
# RUN  1 , total integrated cost =  128.1808524026304
# RUN  2 , total integrated cost =  21.386857890215154
# RUN  3 , total integrated cost =  6.3090005565171925
# RUN  3 , total integrated cost mean =  6.3090005565171925
# Improved over  3  iterations in  0.708737358043436  seconds by  99.6102222075876  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  6.302446449225389
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.145148663333307
# RUN  2 , total integrated cost =  4.777959349248547
# RUN  3 , total integrated cost =  4.953597235162441
# RUN  4 , total integrated cost =  4.7905209067648205
# RUN  5 , total integrated cost =  4.655647301330097
# RUN  6 , total integrated cost =  4.705503046827901
# RUN  7 , total integrated cost =  4.655341939887993
# RUN  8 , total integrated cost =  4.482845778597937
# RUN  9 , total integrated cost =  4.398327877180246
# RUN  9 , total integrated cost mean =  4.398327877180246
# Improved over  9  iterations in  3.94006456900388  seconds by  30.212372090510527  percent.
# rep_ind =  4.842037769612908
# iteration =  18
# iteration =  24
# n =  10
# iteration =  6
# iteration =  12
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1620.5900119531354
# Gradient descend method:  None
# RUN  1 , total integrated cost =  134.46793301300823
# RUN  2 , total integrated cost =  19.880792410808226
# RUN  3 , total integrated cost =  5.785568343075558
# RUN  3 , total integrated cost mean =  5.785568343075558
# Improved over  3  iterations in  3.4346635779947974  seconds by  99.64299617420801  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5.623780118636415
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.601283902401386
# RUN  2 , total integrated cost =  4.431222475574993
# RUN  3 , total integrated cost =  4.301842249391258
# step size too small or too large
# step size too small or too large
# RUN  4 , total integrated cost =  4.141644379599376
# RUN  5 , total integrated cost =  4.151241559655335
# RUN  6 , total integrated cost =  3.9249940953208444
# RUN  7 , total integrated cost =  3.8214294087856198
# RUN  8 , total integrated cost =  3.668001612774512
# RUN  9 , total integrated cost =  3.53005168940805
# RUN  9 , total integrated cost mean =  3.53005168940805
# Improved over  9  iterations in  19.19738955097273  seconds by  37.22991271102588  percent.
# cost =  3.5914624173266287
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1621.6232057810712
# Gradient descend method:  None
# RUN  1 , total integrated cost =  111.4793453758974
# RUN  2 , total integrated cost =  17.96685461013364
# RUN  3 , total integrated cost =  5.864306860197236
# RUN  3 , total integrated cost mean =  5.864306860197236
# Improved over  3  iterations in  3.5422867970191874  seconds by  99.63836809689877  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5.870616686066846
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.5063766317022065
# step size too small or too large
# RUN  2 , total integrated cost =  4.385240596979712
# RUN  3 , total integrated cost =  4.2768969550813205
# step size too small or too large
# RUN  4 , total integrated cost =  4.123708282942675
# RUN  5 , total integrated cost =  3.993139480898961
# RUN  6 , total integrated cost =  4.003035177551265
# step size too small or too large
# step size too small or too large
# RUN  7 , total integrated cost =  3.9571133699145045
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  8 , total integrated cost =  3.8440114743416425
# RUN  9 , total integrated cost =  3.7997985218713217
# RUN  9 , total integrated cost mean =  3.7997985218713217
# Improved over  9  iterations in  21.06681327096885  seconds by  35.27428675611448  percent.
# rep_ind =  2.9995465003907738
# iteration =  18
# iteration =  24
# n =  30
# iteration =  6
# iteration =  12
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1617.079846564625
# Gradient descend method:  None
# RUN  1 , total integrated cost =  121.34187808260954
# RUN  2 , total integrated cost =  19.308242586281747
# RUN  3 , total integrated cost =  6.198496356711491
# RUN  3 , total integrated cost mean =  6.198496356711491
# Improved over  3  iterations in  10.417787740996573  seconds by  99.61668581982023  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  6.070559596090878
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.083582457046892
# RUN  2 , total integrated cost =  4.762813704306405
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  3 , total integrated cost =  4.4900836213146675
# RUN  4 , total integrated cost =  4.22881350127339
# step size too small or too large
# RUN  5 , total integrated cost =  4.112436306118306
# step size too small or too large
# step size too small or too large
# RUN  6 , total integrated cost =  3.983550787820597
# step size too small or too large
# RUN  7 , total integrated cost =  3.879513499369511
# RUN  8 , total integrated cost =  3.775143676355404
# step size too small or too large
# RUN  9 , total integrated cost =  3.669616135612397
# RUN  9 , total integrated cost mean =  3.669616135612397
# Improved over  9  iterations in  55.28085108904634  seconds by  39.550611808910716  percent.
# cost =  3.6896154728797486
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1618.6818395848697
# Gradient descend method:  None
# RUN  1 , total integrated cost =  130.39101007246248
# RUN  2 , total integrated cost =  20.116450613741712
# RUN  3 , total integrated cost =  5.990200585875981
# RUN  3 , total integrated cost mean =  5.990200585875981
# Improved over  3  iterations in  10.649785690009594  seconds by  99.62993341622884  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  6.23680677452846
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.999788192805484
# step size too small or too large
# step size too small or too large
# RUN  2 , total integrated cost =  4.616285857708478
# step size too small or too large
# step size too small or too large
# RUN  3 , total integrated cost =  4.31013931949029
# RUN  4 , total integrated cost =  4.1596073971725644
# RUN  5 , total integrated cost =  4.065242636144759
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  6 , total integrated cost =  4.015849533045938
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  7 , total integrated cost =  3.9557572548915823
# RUN  8 , total integrated cost =  3.81468308974032
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  9 , total integrated cost =  3.691929621832123
# RUN  9 , total integrated cost mean =  3.691929621832123
# Improved over  9  iterations in  59.33040258899564  seconds by  40.80416861862366  percent.
# rep_ind =  2.1666910743876198
# iteration =  18
# iteration =  24
# n =  50
# iteration =  6
# iteration =  12
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1619.4526865450252
# Gradient descend method:  None
# RUN  1 , total integrated cost =  130.25675266468372
# RUN  2 , total integrated cost =  20.9027089314865
# RUN  3 , total integrated cost =  6.251890713141176
# RUN  3 , total integrated cost mean =  6.251890713141176
# Improved over  3  iterations in  14.898213923966978  seconds by  99.61395039416193  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  6.289601491559805
# Gradient descend method:  None
# step size too small or too large
# step size too small or too large
# RUN  1 , total integrated cost =  5.092422368860102
# step size too small or too large
# RUN  2 , total integrated cost =  4.754246644507552
# RUN  3 , total integrated cost =  4.5510713303667165
# RUN  4 , total integrated cost =  4.274049788927945
# RUN  5 , total integrated cost =  4.083053631422572
# step size too small or too large
# RUN  6 , total integrated cost =  3.9710899621376514
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  7 , total integrated cost =  3.7949998556991886
# step size too small or too large
# step size too small or too large
# RUN  8 , total integrated cost =  3.6264318993460565
# RUN  9 , total integrated cost =  3.455493993415238
# RUN  9 , total integrated cost mean =  3.455493993415238
# Improved over  9  iterations in  95.35331381496508  seconds by  45.06020774047029  percent.
# cost =  3.4958886432903857
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1614.8583378591647
# Gradient descend method:  None
# RUN  1 , total integrated cost =  133.6429337931589
# RUN  2 , total integrated cost =  19.181448135743537
# RUN  3 , total integrated cost =  6.008381000627179
# RUN  3 , total integrated cost mean =  6.008381000627179
# Improved over  3  iterations in  18.31904570001643  seconds by  99.62793138817412  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  6.074678119711315
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.704537048541451
# step size too small or too large
# RUN  2 , total integrated cost =  4.406815367856128
# step size too small or too large
# RUN  3 , total integrated cost =  4.165175374923901
# step size too small or too large
# step size too small or too large
# RUN  4 , total integrated cost =  3.9207655638574623
# RUN  5 , total integrated cost =  3.730130735101601
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  6 , total integrated cost =  3.5491020022559474
# RUN  7 , total integrated cost =  3.462369326030006
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  8 , total integrated cost =  3.3990509068672576
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  9 , total integrated cost =  3.2276536185545566
# RUN  9 , total integrated cost mean =  3.2276536185545566
# Improved over  9  iterations in  99.94083735201275  seconds by  46.86708406686834  percent.
# rep_ind =  2.909403068966504
# iteration =  18
# iteration =  24
# sigma =  0.03
# set cost params:  0.006629458876833602 0.0 1.0
# n =  2
# iteration =  6
# iteration =  12
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  521.3423611911306
# Gradient descend method:  None
# RUN  1 , total integrated cost =  33.22824472545427
# RUN  2 , total integrated cost =  6.108553131011449
# RUN  3 , total integrated cost =  5.797215970807013
# RUN  3 , total integrated cost mean =  5.797215970807013
# Improved over  3  iterations in  0.6597317850100808  seconds by  98.88802130761792  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  4.898761736838175
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.407227037926596
# RUN  2 , total integrated cost =  2.5529120879213756
# RUN  3 , total integrated cost =  3.2087362750600192
# RUN  4 , total integrated cost =  2.616251715687521
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  5 , total integrated cost =  2.611558201592109
# RUN  6 , total integrated cost =  2.871171531034267
# RUN  7 , total integrated cost =  3.1663414050023437
# RUN  8 , total integrated cost =  3.036922620815081
# no cost improvement
# RUN  9 , total integrated cost =  2.936740329947135
# RUN  9 , total integrated cost mean =  2.936740329947135
# Improved over  9  iterations in  4.281818992982153  seconds by  40.05137445523926  percent.
# cost =  3.180301460816863
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  527.7758318517829
# Gradient descend method:  None
# RUN  1 , total integrated cost =  40.346552740506425
# RUN  2 , total integrated cost =  8.065606771228707
# RUN  3 , total integrated cost =  5.054745725285588
# RUN  3 , total integrated cost mean =  5.054745725285588
# Improved over  3  iterations in  0.6782340990030207  seconds by  99.04225517346063  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  4.100052559285729
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.6894756608420396
# RUN  2 , total integrated cost =  3.8510422488032647
# RUN  3 , total integrated cost =  3.72478029963197
# RUN  4 , total integrated cost =  3.073889454848511
# RUN  5 , total integrated cost =  3.4916580875350807
# RUN  6 , total integrated cost =  3.3770910318547402
# RUN  7 , total integrated cost =  2.978626736856956
# RUN  8 , total integrated cost =  3.1554203774070277
# RUN  9 , total integrated cost =  4.5949640515070165
# no cost improvement
# RUN  9 , total integrated cost mean =  4.5949640515070165
# Improved over  9  iterations in  3.7756184979807585  seconds by  -12.070857264998239  percent.
# rep_ind =  8.007138823541732
# iteration =  18
# iteration =  24
# n =  10
# iteration =  6
# iteration =  12
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  527.1720374811915
# Gradient descend method:  None
# RUN  1 , total integrated cost =  60.83235442234292
# RUN  2 , total integrated cost =  14.62706132679195
# RUN  3 , total integrated cost =  6.110950289639843
# RUN  3 , total integrated cost mean =  6.110950289639843
# Improved over  3  iterations in  3.3549200060078874  seconds by  98.84080530544873  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  6.530876360082805
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.7204314435441175
# RUN  2 , total integrated cost =  5.388204434528367
# RUN  3 , total integrated cost =  4.96062558448586
# RUN  4 , total integrated cost =  4.930880923107766
# RUN  5 , total integrated cost =  4.629521591428089
# RUN  6 , total integrated cost =  4.56079336400846
# RUN  7 , total integrated cost =  4.2937891557568895
# RUN  8 , total integrated cost =  4.025373231182553
# step size too small or too large
# RUN  9 , total integrated cost =  3.614992824324033
# RUN  9 , total integrated cost mean =  3.614992824324033
# Improved over  9  iterations in  17.42936844401993  seconds by  44.647660972130254  percent.
# cost =  3.7961986966810253
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  522.3988661390233
# Gradient descend method:  None
# RUN  1 , total integrated cost =  40.06442410280735
# RUN  2 , total integrated cost =  8.220811646943144
# RUN  3 , total integrated cost =  4.843794858682377
# RUN  3 , total integrated cost mean =  4.843794858682377
# Improved over  3  iterations in  2.975154051964637  seconds by  99.072778450979  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  4.690876778592215
# Gradient descend method:  None
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  1 , total integrated cost =  4.011903056892579
# step size too small or too large
# step size too small or too large
# RUN  2 , total integrated cost =  3.1777548411185745
# RUN  3 , total integrated cost =  3.0905913047406086
# step size too small or too large
# RUN  4 , total integrated cost =  3.3282660072663703
# RUN  5 , total integrated cost =  3.0989475530059405
# RUN  6 , total integrated cost =  2.9630609784348425
# RUN  7 , total integrated cost =  2.904203604014763
# RUN  8 , total integrated cost =  2.843464962526698
# RUN  9 , total integrated cost =  2.857201565766476
# RUN  9 , total integrated cost mean =  2.857201565766476
# Improved over  9  iterations in  15.767865419969894  seconds by  39.09024473194636  percent.
# rep_ind =  8.29627051922245
# iteration =  18
# iteration =  24
# n =  30
# iteration =  6
# iteration =  12
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  521.6105527184907
# Gradient descend method:  None
# RUN  1 , total integrated cost =  50.8337545103935
# RUN  2 , total integrated cost =  7.7222422265709785
# RUN  3 , total integrated cost =  4.738872059938895
# RUN  3 , total integrated cost mean =  4.738872059938895
# Improved over  3  iterations in  8.061489035957493  seconds by  99.09149229530706  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  4.82342788551995
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.920484967251561
# RUN  2 , total integrated cost =  3.5978578986644023
# step size too small or too large
# RUN  3 , total integrated cost =  3.201238750517031
# step size too small or too large
# RUN  4 , total integrated cost =  3.1492388437053833
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  5 , total integrated cost =  2.8970699301795895
# step size too small or too large
# RUN  6 , total integrated cost =  2.5396435262588977
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  7 , total integrated cost =  2.646033325673464
# step size too small or too large
# step size too small or too large
# RUN  8 , total integrated cost =  2.79949586822571
# RUN  9 , total integrated cost =  2.8397537597680236
# RUN  9 , total integrated cost mean =  2.8397537597680236
# Improved over  9  iterations in  45.66358686599415  seconds by  41.12581700883236  percent.
# cost =  2.870693248538238
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  525.1877091361918
# Gradient descend method:  None
# RUN  1 , total integrated cost =  33.01230791160349
# RUN  2 , total integrated cost =  7.254966268296558
# RUN  3 , total integrated cost =  4.108613024382318
# RUN  3 , total integrated cost mean =  4.108613024382318
# Improved over  3  iterations in  7.780477209016681  seconds by  99.21768675220142  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  4.217290716655221
# Gradient descend method:  None
# step size too small or too large
# RUN  1 , total integrated cost =  3.4138693357720937
# RUN  2 , total integrated cost =  3.0086560961686475
# step size too small or too large
# step size too small or too large
# RUN  3 , total integrated cost =  2.6510904733680287
# RUN  4 , total integrated cost =  2.8903248014628615
# RUN  5 , total integrated cost =  2.8407194333548276
# RUN  6 , total integrated cost =  2.814068724626074
# step size too small or too large
# step size too small or too large
# RUN  7 , total integrated cost =  2.7485620775204276
# RUN  8 , total integrated cost =  2.5832620690594235
# step size too small or too large
# RUN  9 , total integrated cost =  2.5767236053470497
# RUN  9 , total integrated cost mean =  2.5767236053470497
# Improved over  9  iterations in  50.58058794098906  seconds by  38.900972722348214  percent.
# rep_ind =  3.260870637486371
# iteration =  18
# iteration =  24
# n =  50
# iteration =  6
# iteration =  12
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  527.8975593407657
# Gradient descend method:  None
# RUN  1 , total integrated cost =  24.127197647579333
# RUN  2 , total integrated cost =  7.20982324101406
# RUN  3 , total integrated cost =  4.324892360548037
# RUN  3 , total integrated cost mean =  4.324892360548037
# Improved over  3  iterations in  16.393594029999804  seconds by  99.18073264707854  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  4.321723381567658
# Gradient descend method:  None
# step size too small or too large
# RUN  1 , total integrated cost =  3.8577155224805795
# RUN  2 , total integrated cost =  3.1985845765810774
# RUN  3 , total integrated cost =  3.113340605304698
# step size too small or too large
# RUN  4 , total integrated cost =  3.0292589760763513
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  5 , total integrated cost =  2.718227850181599
# RUN  6 , total integrated cost =  2.801667429015228
# step size too small or too large
# RUN  7 , total integrated cost =  2.6806153625668183
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  8 , total integrated cost =  2.7036946993731634
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  9 , total integrated cost =  2.7491732987867525
# RUN  9 , total integrated cost mean =  2.7491732987867525
# Improved over  9  iterations in  71.0273651900352  seconds by  36.387106344841534  percent.
# cost =  2.8593439623168497
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  524.4931958857806
# Gradient descend method:  None
# RUN  1 , total integrated cost =  31.11992295954284
# RUN  2 , total integrated cost =  7.363968146902706
# RUN  3 , total integrated cost =  4.381109766890823
# RUN  3 , total integrated cost mean =  4.381109766890823
# Improved over  3  iterations in  14.522111302998383  seconds by  99.1646965487337  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  4.442275945937995
# Gradient descend method:  None
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  1 , total integrated cost =  3.7040660196850967
# step size too small or too large
# RUN  2 , total integrated cost =  3.0837882233501683
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  3 , total integrated cost =  2.757549338701545
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  4 , total integrated cost =  2.7639586315967346
# step size too small or too large
# RUN  5 , total integrated cost =  2.7814249344399427
# RUN  6 , total integrated cost =  2.6787553300716964
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  7 , total integrated cost =  2.6618366880360975
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  8 , total integrated cost =  2.712237458740915
# step size too small or too large
# step size too small or too large
# RUN  9 , total integrated cost =  2.825551813793528
# RUN  9 , total integrated cost mean =  2.825551813793528
# Improved over  9  iterations in  86.23000543698436  seconds by  36.394050072976555  percent.
# rep_ind =  3.3564774586378783
# iteration =  18
# iteration =  24
# sigma =  0.049999999999999996
# set cost params:  0.0038189836656619975 0.0 1.0
# n =  2
# iteration =  6
# iteration =  12
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  300.1803107212346
# Gradient descend method:  None
# RUN  1 , total integrated cost =  15.179056593075522
# RUN  2 , total integrated cost =  6.28015178941839
# RUN  3 , total integrated cost =  6.763328506214068
# RUN  3 , total integrated cost mean =  6.763328506214068
# Improved over  3  iterations in  0.6223772520315833  seconds by  97.74691135139277  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5.438271328976702
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.590585107797076
# RUN  2 , total integrated cost =  4.860039016890623
# RUN  3 , total integrated cost =  5.360341244671776
# RUN  4 , total integrated cost =  4.627224585673293
# RUN  5 , total integrated cost =  5.083351790799318
# RUN  6 , total integrated cost =  4.942976144429581
# RUN  7 , total integrated cost =  3.9702758604551067
# RUN  8 , total integrated cost =  3.821675619725951
# RUN  9 , total integrated cost =  4.258938289856845
# RUN  9 , total integrated cost mean =  4.258938289856845
# Improved over  9  iterations in  3.391744997992646  seconds by  21.68580726812995  percent.
# cost =  4.500119745703078
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  286.452833990983
# Gradient descend method:  None
# RUN  1 , total integrated cost =  64.85815076363548
# RUN  2 , total integrated cost =  10.997686400603229
# RUN  3 , total integrated cost =  6.59071658105816
# RUN  3 , total integrated cost mean =  6.59071658105816
# Improved over  3  iterations in  0.544791148044169  seconds by  97.69919658701453  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5.75075076977459
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.359137224158577
# RUN  2 , total integrated cost =  5.486777393720296
# RUN  3 , total integrated cost =  5.583173852534307
# RUN  4 , total integrated cost =  5.468635607789757
# RUN  5 , total integrated cost =  5.10628529006425
# RUN  6 , total integrated cost =  5.21187217384526
# RUN  7 , total integrated cost =  4.455406770711682
# RUN  8 , total integrated cost =  4.515891291975038
# RUN  9 , total integrated cost =  5.128830539132441
# RUN  9 , total integrated cost mean =  5.128830539132441
# Improved over  9  iterations in  2.5133399100159295  seconds by  10.814591964424963  percent.
# rep_ind =  12.103535317193133
# iteration =  18
# iteration =  24
# n =  10
# iteration =  6
# iteration =  12
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  295.48625022665
# Gradient descend method:  None
# RUN  1 , total integrated cost =  47.39340531142343
# RUN  2 , total integrated cost =  8.773230668268274
# RUN  3 , total integrated cost =  5.992543542118158
# RUN  3 , total integrated cost mean =  5.992543542118158
# Improved over  3  iterations in  2.0615740490029566  seconds by  97.97197211798463  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5.260101330762074
# Gradient descend method:  None
# step size too small or too large
# step size too small or too large
# RUN  1 , total integrated cost =  5.382058837415628
# RUN  2 , total integrated cost =  5.24222621416674
# RUN  3 , total integrated cost =  4.41961719633722
# RUN  4 , total integrated cost =  4.3636904193522605
# RUN  5 , total integrated cost =  3.673898976291292
# RUN  6 , total integrated cost =  3.6174605752688835
# step size too small or too large
# RUN  7 , total integrated cost =  3.8465401149927443
# RUN  8 , total integrated cost =  3.804108655876002
# step size too small or too large
# RUN  9 , total integrated cost =  3.764959433888726
# RUN  9 , total integrated cost mean =  3.764959433888726
# Improved over  9  iterations in  11.431945073010866  seconds by  28.42420331580827  percent.
# cost =  3.986293602577266
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  290.30147203987815
# Gradient descend method:  None
# RUN  1 , total integrated cost =  16.936246564616
# RUN  2 , total integrated cost =  5.937925029938336
# RUN  3 , total integrated cost =  4.9123690213543005
# RUN  3 , total integrated cost mean =  4.9123690213543005
# Improved over  3  iterations in  3.031930025026668  seconds by  98.30783874885778  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  4.851659010673751
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.576866465934332
# RUN  2 , total integrated cost =  4.11696450990448
# RUN  3 , total integrated cost =  3.853061433110637
# RUN  4 , total integrated cost =  4.015111452613207
# RUN  5 , total integrated cost =  3.539897560559666
# RUN  6 , total integrated cost =  3.8309813825588193
# RUN  7 , total integrated cost =  3.4384035130798543
# RUN  8 , total integrated cost =  3.677476008542345
# RUN  9 , total integrated cost =  3.1808583146153695
# RUN  9 , total integrated cost mean =  3.1808583146153695
# Improved over  9  iterations in  12.112808838952333  seconds by  34.43771898195206  percent.
# rep_ind =  6.045496599840884
# iteration =  18
# iteration =  24
# n =  30
# iteration =  6
# iteration =  12
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  290.79585997148405
# Gradient descend method:  None
# RUN  1 , total integrated cost =  19.960570809133213
# RUN  2 , total integrated cost =  6.716875828397875
# RUN  3 , total integrated cost =  5.046756504417838
# RUN  3 , total integrated cost mean =  5.046756504417838
# Improved over  3  iterations in  7.436416091979481  seconds by  98.26450194135751  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5.195836915512015
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.447865611456155
# step size too small or too large
# step size too small or too large
# RUN  2 , total integrated cost =  3.8726454050039893
# RUN  3 , total integrated cost =  3.5416485271609415
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  4 , total integrated cost =  3.817475560760443
# RUN  5 , total integrated cost =  3.5200748081771076
# step size too small or too large
# step size too small or too large
# RUN  6 , total integrated cost =  3.9343168995552467
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  7 , total integrated cost =  3.623717675658029
# RUN  8 , total integrated cost =  3.7713048190516085
# RUN  9 , total integrated cost =  3.7169772243982657
# RUN  9 , total integrated cost mean =  3.7169772243982657
# Improved over  9  iterations in  40.1182957229903  seconds by  28.462396244552224  percent.
# cost =  5.553088293912101
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  288.65748090744006
# Gradient descend method:  None
# RUN  1 , total integrated cost =  16.632188561395015
# RUN  2 , total integrated cost =  6.045403835924063
# RUN  3 , total integrated cost =  4.836603309365862
# RUN  3 , total integrated cost mean =  4.836603309365862
# Improved over  3  iterations in  6.405638868978713  seconds by  98.32444899949891  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5.334832067151188
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.122729258215512
# step size too small or too large
# RUN  2 , total integrated cost =  3.4472521090237462
# RUN  3 , total integrated cost =  3.7162596761669557
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  4 , total integrated cost =  4.098459511127178
# step size too small or too large
# step size too small or too large
# RUN  5 , total integrated cost =  3.439252664230053
# RUN  6 , total integrated cost =  3.1351416424426453
# step size too small or too large
# step size too small or too large
# RUN  7 , total integrated cost =  3.4845323549267935
# step size too small or too large
# RUN  8 , total integrated cost =  3.548671647384761
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  9 , total integrated cost =  3.2477769682095987
# RUN  9 , total integrated cost mean =  3.2477769682095987
# Improved over  9  iterations in  43.271560103981756  seconds by  39.12128953022661  percent.
# rep_ind =  8.661653813915157
# iteration =  18
# iteration =  24
# n =  50
# iteration =  6
# iteration =  12
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  290.47266541684706
# Gradient descend method:  None
# RUN  1 , total integrated cost =  21.34646296221022
# RUN  2 , total integrated cost =  7.8147221083839895
# step size too small or too large
# RUN  3 , total integrated cost =  5.223918817300234
# RUN  3 , total integrated cost mean =  5.223918817300234
# Improved over  3  iterations in  10.952059911971446  seconds by  98.20157989399671  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5.290707243582052
# Gradient descend method:  None
# step size too small or too large
# RUN  1 , total integrated cost =  3.9935717495416174
# RUN  2 , total integrated cost =  3.92300043041658
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  3 , total integrated cost =  3.454257477659884
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  4 , total integrated cost =  3.492382742936227
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  5 , total integrated cost =  9.331909851158139
# no cost improvement
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  6 , total integrated cost =  3.293372267761207
# RUN  7 , total integrated cost =  3.47844895422337
# RUN  7 , total integrated cost mean =  3.47844895422337
# Improved over  7  iterations in  57.305599830986466  seconds by  34.25361120778439  percent.
# cost =  3.738998940088636
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  297.5045601323277
# Gradient descend method:  None
# RUN  1 , total integrated cost =  23.5474015872567
# RUN  2 , total integrated cost =  6.802616737841906
# RUN  3 , total integrated cost =  4.6356407445545855
# RUN  3 , total integrated cost mean =  4.6356407445545855
# Improved over  3  iterations in  10.896912997995969  seconds by  98.44182531437747  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  4.710723303788306
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.9803030110374986
# step size too small or too large
# step size too small or too large
# RUN  2 , total integrated cost =  3.9101041578034663
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  3 , total integrated cost =  3.8330995395775482
# RUN  4 , total integrated cost =  3.533798896547395
# RUN  5 , total integrated cost =  3.9515360862376525
# RUN  6 , total integrated cost =  3.6898161412603843
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  7 , total integrated cost =  3.668311148861933
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  8 , total integrated cost =  3.6453376918919673
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  9 , total integrated cost =  3.531635486534539
# RUN  9 , total integrated cost mean =  3.531635486534539
# Improved over  9  iterations in  63.474318583030254  seconds by  25.02986784015863  percent.
# rep_ind =  4.778993672413833
# iteration =  18
# iteration =  24
# sigma =  0.06999999999999999
# set cost params:  0.0026461291712439284 0.0 1.0
# n =  2
# iteration =  6
# iteration =  12
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  206.37425051410446
# Gradient descend method:  None
# RUN  1 , total integrated cost =  15.012085256961097
# RUN  2 , total integrated cost =  16.419207551358774
# RUN  3 , total integrated cost =  8.261776856068678
# RUN  3 , total integrated cost mean =  8.261776856068678
# Improved over  3  iterations in  0.4090548339881934  seconds by  95.99670170310127  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  6.861877355146436
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.580016336246899
# RUN  2 , total integrated cost =  5.43804294615143
# RUN  3 , total integrated cost =  5.413177556711773
# RUN  4 , total integrated cost =  5.8073134465930085
# RUN  5 , total integrated cost =  5.213550071694051
# RUN  6 , total integrated cost =  5.012298233145449
# RUN  7 , total integrated cost =  3.1972657595565295
# RUN  8 , total integrated cost =  4.009899963272556
# RUN  9 , total integrated cost =  4.412993220915519
# RUN  9 , total integrated cost mean =  4.412993220915519
# Improved over  9  iterations in  2.855908151017502  seconds by  35.688252754827275  percent.
# cost =  9.765201028851731
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  199.38070388331698
# Gradient descend method:  None
# RUN  1 , total integrated cost =  48.9673918976158
# step size too small or too large
# step size too small or too large
# RUN  2 , total integrated cost =  51.973941202910524
# Control only changes marginally.
# RUN  2 , total integrated cost mean =  51.973941202910524
# Improved over  2  iterations in  0.525133231014479  seconds by  73.93231130665129  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  50.21583664511582
# Gradient descend method:  None
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  1 , total integrated cost =  48.78718340023623
# Control only changes marginally.
# RUN  1 , total integrated cost mean =  48.78718340023623
# Improved over  1  iterations in  1.0271475929766893  seconds by  2.845025275544316  percent.
# rep_ind =  489.9847675497565
# iteration =  18
# iteration =  24
# n =  10
# iteration =  6
# iteration =  12
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  178.73746814184722
# Gradient descend method:  None
# RUN  1 , total integrated cost =  33.43780347335005
# RUN  2 , total integrated cost =  61.605928560175286
# RUN  3 , total integrated cost =  73.61566512362505
# RUN  3 , total integrated cost mean =  73.61566512362505
# Improved over  3  iterations in  3.276921647018753  seconds by  58.813523605916146  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  4.012293034293372
# Gradient descend method:  None
# step size too small or too large
# RUN  1 , total integrated cost =  21.155554893880968
# RUN  2 , total integrated cost =  33.554291875824546
# RUN  3 , total integrated cost =  22.74739074084459
# RUN  4 , total integrated cost =  5.308223102644365
# RUN  5 , total integrated cost =  5.036077541128003
# RUN  6 , total integrated cost =  4.803974889780914
# RUN  7 , total integrated cost =  4.6744220307900495
# RUN  8 , total integrated cost =  4.27855074319119
# RUN  9 , total integrated cost =  4.198365445658222
# RUN  9 , total integrated cost mean =  4.198365445658222
# Improved over  9  iterations in  23.908945328032132  seconds by  -4.6375578696389965  percent.
# cost =  6.734009254365577
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  159.9946425335247
# Gradient descend method:  None
# RUN  1 , total integrated cost =  40.84946101974124
# RUN  2 , total integrated cost =  10.823464374586543
# RUN  3 , total integrated cost =  6.807626036738978
# RUN  3 , total integrated cost mean =  6.807626036738978
# Improved over  3  iterations in  3.0573626389959827  seconds by  95.74509125496965  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7.210049243671058
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.683475727763941
# RUN  2 , total integrated cost =  5.255077207056338
# step size too small or too large
# RUN  3 , total integrated cost =  4.305365863685555
# RUN  4 , total integrated cost =  4.569611900177304
# RUN  5 , total integrated cost =  4.430924131497096
# step size too small or too large
# RUN  6 , total integrated cost =  4.530006256054437
# RUN  7 , total integrated cost =  4.712084850777396
# RUN  8 , total integrated cost =  4.573552344087199
# RUN  9 , total integrated cost =  4.05156035560495
# RUN  9 , total integrated cost mean =  4.05156035560495
# Improved over  9  iterations in  13.809952866984531  seconds by  43.8067588905667  percent.
# rep_ind =  19.74456356405607
# iteration =  18
# iteration =  24
# n =  30
# iteration =  6
# iteration =  12
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  176.4726972692915
# Gradient descend method:  None
# RUN  1 , total integrated cost =  39.998790219692374
# RUN  2 , total integrated cost =  7.039108579677949
# RUN  3 , total integrated cost =  6.314078275317949
# RUN  3 , total integrated cost mean =  6.314078275317949
# Improved over  3  iterations in  8.024143514980096  seconds by  96.4220650712428  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  6.643643053658717
# Gradient descend method:  None
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  1 , total integrated cost =  5.782822850148836
# RUN  2 , total integrated cost =  5.581468372986853
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  3 , total integrated cost =  7.984749268572019
# step size too small or too large
# RUN  4 , total integrated cost =  5.99830096903935
# RUN  5 , total integrated cost =  5.783214376896452
# RUN  6 , total integrated cost =  5.47067943849888
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  7 , total integrated cost =  5.888886552625821
# RUN  8 , total integrated cost =  5.411820774015534
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  9 , total integrated cost =  5.353714165847336
# RUN  9 , total integrated cost mean =  5.353714165847336
# Improved over  9  iterations in  38.03796261298703  seconds by  19.41598724364046  percent.
# cost =  11.131808437929616
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  182.39618511119397
# Gradient descend method:  None
# RUN  1 , total integrated cost =  10.275096890684713
# RUN  2 , total integrated cost =  47.78144858021335
# RUN  3 , total integrated cost =  13.900045813570705
# RUN  3 , total integrated cost mean =  13.900045813570705
# Improved over  3  iterations in  8.406221067998558  seconds by  92.37920145912217  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  8.678559954261207
# Gradient descend method:  None
# step size too small or too large
# step size too small or too large
# RUN  1 , total integrated cost =  13.316239095389141
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  2 , total integrated cost =  12.535106406091593
# step size too small or too large
# step size too small or too large
# RUN  3 , total integrated cost =  8.965880468823855
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  4 , total integrated cost =  5.079775284714639
# RUN  5 , total integrated cost =  4.527474610295502
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  6 , total integrated cost =  4.939402525983703
# RUN  7 , total integrated cost =  4.849591162327262
# step size too small or too large
# step size too small or too large
# RUN  8 , total integrated cost =  4.7868879087355545
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  9 , total integrated cost =  4.737167073794406
# RUN  9 , total integrated cost mean =  4.737167073794406
# Improved over  9  iterations in  42.85646782501135  seconds by  45.415286651693435  percent.
# rep_ind =  28.05846266080097
# iteration =  18
# iteration =  24
# n =  50
# iteration =  6
# iteration =  12
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  177.67794063887865
# Gradient descend method:  None
# step size too small or too large
# RUN  1 , total integrated cost =  5.878221448812096
# step size too small or too large
# RUN  2 , total integrated cost =  7.3224427359245245
# step size too small or too large
# RUN  3 , total integrated cost =  5.812975940021992
# RUN  3 , total integrated cost mean =  5.812975940021992
# Improved over  3  iterations in  11.817042749025859  seconds by  96.72836373546417  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5.989464295547082
# Gradient descend method:  None
# step size too small or too large
# step size too small or too large
# RUN  1 , total integrated cost =  5.265078415131404
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  2 , total integrated cost =  5.350748304044377
# step size too small or too large
# RUN  3 , total integrated cost =  4.922671874607536
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  4 , total integrated cost =  5.4926941732456624
# RUN  5 , total integrated cost =  5.283899922145079
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  6 , total integrated cost =  5.101816571989857
# step size too small or too large
# RUN  7 , total integrated cost =  5.415531895695882
# RUN  8 , total integrated cost =  5.13879296540577
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  9 , total integrated cost =  5.051387909179626
# RUN  9 , total integrated cost mean =  5.051387909179626
# Improved over  9  iterations in  63.509733903978486  seconds by  15.662108330203708  percent.
# cost =  5.666010254698786
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  177.94615819093386
# Gradient descend method:  None
# RUN  1 , total integrated cost =  18.532121076803353
# RUN  2 , total integrated cost =  7.5841988512841105
# RUN  3 , total integrated cost =  5.73015660519092
# RUN  3 , total integrated cost mean =  5.73015660519092
# Improved over  3  iterations in  9.111167534952983  seconds by  96.77983685433516  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5.243920977735862
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.475961386334599
# step size too small or too large
# RUN  2 , total integrated cost =  5.692129294425821
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  3 , total integrated cost =  5.500712649237191
# RUN  4 , total integrated cost =  5.6338864831412305
# RUN  5 , total integrated cost =  5.860443962651739
# no cost improvement
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  6 , total integrated cost =  4.798466874357624
# RUN  6 , total integrated cost mean =  4.798466874357624
# Improved over  6  iterations in  38.3098885579966  seconds by  8.494676126309002  percent.
# rep_ind =  21.52776816342375
# iteration =  18
# iteration =  24

# %%
#len(sigma_array), 4, N_max, max_it

##### METHOD 3
method_ind = 3
step_method_ind = 1
step_m = 'S1'
if step_method_ind == 1:
    step_m = 'S2'

for d in dict_list:
    
    print("Point = ", d['point'])
    aln.params.ext_exc_current = d['point'][0] * 5.
    aln.params.ext_inh_current = d['point'][1] * 5.
    
    max_it = d['cost'].shape[3]
    
    for s_ind in range(len(d['sigma'])):
        
        print("sigma = ", d['sigma'][s_ind])
        
        s = d['sigma'][s_ind]
        aln.params.sigma_ou = s
        c_p = d['cost_params'][s_ind]
        cost.setParams(c_p[0], c_p[1], c_p[2])
        
        target_ = d['target'][s_ind].copy()
        target_[0,0,:int(trans_time * dur / aln.params.dt)] = -1000
        target_[0,1,:int(trans_time * dur / aln.params.dt)] = -1000
                
        for n_ind in range(len(d['N_array'])):
            
            n_ = d['N_array'][n_ind]
            
            print("n = ", n_)
            aln.params.duration = dur
        
            for i_it in range(1,len(d['it_array'])):
                
                if i_it in [2,4]:
                    continue
            
                it = d['it_array'][i_it]
                print("iteration = ", it)
                
                if d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it] > 0.:
                    continue
                
                c_vars = d['init']
                aln.params.duration = dur
                setinit(d['init_vars'], aln)
                control_init = aln.getZeroControl()
                    
                
                bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                    control_init, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_ = init_it,
                    tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                    t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                    control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                    noise_real=n_, init_params = d['init_vars'], method='M4', method_step=step_m)
            
                control_init = bc[:,:,100:-100]
                c_vars = [0,1]
                aln.params.duration = dur
                setinit(d['init_vars'], aln)
                
                bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                    control_init, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_=it-init_it,
                    tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                    t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                    control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                    noise_real=n_, init_params = d['init_vars'], method='M4', method_step=step_m)

                control_init = bc[:,:,100:-100]
                aln.params.duration = dur
                setinit(d['init_vars'], aln)
                cost_final = 0.
                cs = cost.numba_cost_sparsity_int(1, 6, T, d['cost_params'][s_ind][2], dt, control_init)

                for j in range(noise_realizations_final):
                    state_ = fo.updateState(aln, control_init)
                    cost_final += cost.numba_cost_precision_int(1, T, dt, d['cost_params'][s_ind][0],
                                                                   state_, target_, list(prec_vars) )

                d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it] = (
                                cost_final / noise_realizations_final + cs )
                print('cost = ', d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it])
                
                c_vars = d['init']                    
                aln.params.duration = dur
                control_init1 = aln.getZeroControl()
                setinit(d['init_vars'], aln)
                
                bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                    control_init1, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_ = init_it,
                    tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                    t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                    control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                    noise_real=n_, init_params = d['init_vars'], method='M4', method_step=step_m)
            
                control_init1 = bc[:,:,100:-100]
                c_vars = [0,1]
                aln.params.duration = dur
                setinit(d['init_vars'], aln)
                
                bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                    control_init1, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_=it-init_it,
                    tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                    t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                    control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                    noise_real=n_, init_params = d['init_vars'], method='M4', method_step=step_m)

                control_init1 = bc[:,:,100:-100]
                d['rep_ind'][s_ind, method_ind, step_method_ind, n_ind, i_it] = rep_ind(control_init, control_init1)
                print('rep_ind = ', d['rep_ind'][s_ind, method_ind, step_method_ind, n_ind, i_it])
                
                file=open(dict_file, "wb")
                pickle.dump(dict_list, file)
                file.close()
                
    break
# Out:
# Point =  [0.4  0.35]
# sigma =  0.01
# set cost params:  0.02018278188257825 0.0 1.0
# n =  2
# iteration =  6
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1613.915740363415
# Gradient descend method:  None
# RUN  1 , total integrated cost =  442.8125388384691
# RUN  2 , total integrated cost =  43.37255973256756
# RUN  3 , total integrated cost =  20.340832754299356
# RUN  3 , total integrated cost mean =  20.340832754299356
# Improved over  3  iterations in  12.323896098008845  seconds by  98.73965955932005  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  8.239893829870773
# Gradient descend method:  None
# RUN  1 , total integrated cost =  10.534216119990388
# RUN  2 , total integrated cost =  15.198374238181206
# RUN  3 , total integrated cost =  8.98400130371089
# RUN  3 , total integrated cost mean =  8.98400130371089
# Improved over  3  iterations in  0.5262274269480258  seconds by  -9.030546863876125  percent.
# cost =  6.248898340337053
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1618.8420954215585
# Gradient descend method:  None
# RUN  1 , total integrated cost =  434.60239343380516
# RUN  2 , total integrated cost =  51.438177123387895
# RUN  3 , total integrated cost =  18.686534439206774
# RUN  3 , total integrated cost mean =  18.686534439206774
# Improved over  3  iterations in  0.2554971590288915  seconds by  98.84568516644975  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  8.27771969295571
# Gradient descend method:  None
# RUN  1 , total integrated cost =  10.263934192260091
# RUN  2 , total integrated cost =  8.17468081542145
# RUN  3 , total integrated cost =  8.304936475182718
# RUN  3 , total integrated cost mean =  8.304936475182718
# Improved over  3  iterations in  0.5117458229651675  seconds by  -0.3287956494850732  percent.
# rep_ind =  6.699336486366796
# iteration =  12
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1607.814202232777
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1079.2204543804926
# RUN  2 , total integrated cost =  25.218385540903753
# RUN  3 , total integrated cost =  14.564933251578777
# RUN  3 , total integrated cost mean =  14.564933251578777
# Improved over  3  iterations in  0.24404540698742494  seconds by  99.0941158977603  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  6.00025438173249
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.632402678467541
# RUN  2 , total integrated cost =  6.608544567628357
# RUN  3 , total integrated cost =  6.337509311497632
# RUN  4 , total integrated cost =  6.293510441285821
# RUN  5 , total integrated cost =  6.381019640927304
# RUN  6 , total integrated cost =  6.019858657864812
# RUN  7 , total integrated cost =  6.279572081918413
# RUN  8 , total integrated cost =  6.090767265981725
# RUN  9 , total integrated cost =  6.323796380062544
# RUN  9 , total integrated cost mean =  6.323796380062544
# Improved over  9  iterations in  1.4590889340033755  seconds by  -5.392138028598637  percent.
# cost =  4.371904492729014
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1614.7033408338975
# Gradient descend method:  None
# RUN  1 , total integrated cost =  325.52261146972575
# RUN  2 , total integrated cost =  28.89737370495851
# RUN  3 , total integrated cost =  16.887734292948743
# RUN  3 , total integrated cost mean =  16.887734292948743
# Improved over  3  iterations in  0.23458635999122635  seconds by  98.95412774186575  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7.566407561900755
# Gradient descend method:  None
# RUN  1 , total integrated cost =  8.52963078236536
# RUN  2 , total integrated cost =  8.61394685659476
# RUN  3 , total integrated cost =  7.880170111613365
# RUN  4 , total integrated cost =  7.500162751271056
# RUN  5 , total integrated cost =  7.767776631450872
# RUN  6 , total integrated cost =  7.330526247501238
# RUN  7 , total integrated cost =  7.300849839717369
# RUN  8 , total integrated cost =  7.042727776830006
# step size too small or too large
# step size too small or too large
# RUN  9 , total integrated cost =  4.460282371643265
# Control only changes marginally.
# RUN  9 , total integrated cost mean =  4.460282371643265
# Improved over  9  iterations in  1.5942224969621748  seconds by  41.051518370459036  percent.
# rep_ind =  6.071571682226278
# iteration =  18
# iteration =  24
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1613.7030484246945
# Gradient descend method:  None
# RUN  1 , total integrated cost =  217.31921994466012
# RUN  2 , total integrated cost =  30.740540163791813
# RUN  3 , total integrated cost =  12.752536000479976
# RUN  3 , total integrated cost mean =  12.752536000479976
# Improved over  3  iterations in  0.28874431998701766  seconds by  99.20973465267176  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  4.377037314349735
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.094967761090011
# RUN  2 , total integrated cost =  6.223739898673112
# RUN  3 , total integrated cost =  6.036202028165384
# RUN  4 , total integrated cost =  5.338282638742928
# RUN  5 , total integrated cost =  5.52536574306273
# step size too small or too large
# RUN  6 , total integrated cost =  3.6006116516025606
# Control only changes marginally.
# RUN  6 , total integrated cost mean =  3.6006116516025606
# Improved over  6  iterations in  0.9224203350022435  seconds by  17.738611919110923  percent.
# cost =  3.8101405719322563
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1623.0352436852804
# Gradient descend method:  None
# RUN  1 , total integrated cost =  292.9799978126596
# RUN  2 , total integrated cost =  40.084064824496714
# RUN  3 , total integrated cost =  19.71797783567777
# RUN  3 , total integrated cost mean =  19.71797783567777
# Improved over  3  iterations in  0.2415528810233809  seconds by  98.78511708772842  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  8.112627073714235
# Gradient descend method:  None
# RUN  1 , total integrated cost =  10.354213319600145
# RUN  2 , total integrated cost =  9.218480715085132
# RUN  3 , total integrated cost =  8.375574168201604
# RUN  4 , total integrated cost =  8.149197048132418
# RUN  5 , total integrated cost =  8.12955564672422
# RUN  6 , total integrated cost =  8.07754976674559
# RUN  7 , total integrated cost =  8.014178557416999
# RUN  8 , total integrated cost =  8.233739259696629
# RUN  9 , total integrated cost =  7.750692999306968
# RUN  10 , total integrated cost =  12.967731579362068
# no cost improvement
# RUN  11 , total integrated cost =  8.630979510699959
# RUN  12 , total integrated cost =  7.961479332820737
# RUN  12 , total integrated cost mean =  7.961479332820737
# Improved over  12  iterations in  1.5990937909809873  seconds by  1.8631170830375368  percent.
# rep_ind =  9.712815139070944
# n =  10
# iteration =  6
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1618.3633183070472
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1010.8550043014575
# RUN  2 , total integrated cost =  160.34584435328705
# RUN  3 , total integrated cost =  48.3540284072656
# RUN  3 , total integrated cost mean =  48.3540284072656
# Improved over  3  iterations in  0.6622601979761384  seconds by  97.01216482972141  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7.57796772302432
# Gradient descend method:  None
# RUN  1 , total integrated cost =  36.62374087304549
# RUN  2 , total integrated cost =  36.768749845732565
# RUN  3 , total integrated cost =  27.90243529465395
# RUN  3 , total integrated cost mean =  27.90243529465395
# Improved over  3  iterations in  1.944857813010458  seconds by  -268.20472604914005  percent.
# cost =  4.997352404534826
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1620.572560974934
# Gradient descend method:  None
# RUN  1 , total integrated cost =  974.0503947033225
# RUN  2 , total integrated cost =  156.2697375870959
# RUN  3 , total integrated cost =  40.937244438693156
# RUN  3 , total integrated cost mean =  40.937244438693156
# Improved over  3  iterations in  1.0140879600076005  seconds by  97.47390240804366  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  6.581105406794407
# Gradient descend method:  None
# RUN  1 , total integrated cost =  29.509774857855945
# RUN  2 , total integrated cost =  27.387552013488413
# RUN  3 , total integrated cost =  25.65361082424896
# RUN  3 , total integrated cost mean =  25.65361082424896
# Improved over  3  iterations in  1.8862302440102212  seconds by  -289.8070193156895  percent.
# rep_ind =  3.8894596197851588
# iteration =  12
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1618.2311011515092
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1121.5900744597923
# RUN  2 , total integrated cost =  147.42971439261242
# RUN  3 , total integrated cost =  54.00461555658298
# RUN  3 , total integrated cost mean =  54.00461555658298
# Improved over  3  iterations in  1.0002313259756193  seconds by  96.66273775617375  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  8.36778611691824
# Gradient descend method:  None
# RUN  1 , total integrated cost =  37.40540804149479
# RUN  2 , total integrated cost =  39.28568326328572
# RUN  3 , total integrated cost =  32.413432478819516
# RUN  4 , total integrated cost =  30.714036473387836
# RUN  5 , total integrated cost =  29.808462353702083
# RUN  6 , total integrated cost =  30.080800363710534
# RUN  7 , total integrated cost =  29.1477148967142
# RUN  8 , total integrated cost =  29.174269438396756
# RUN  9 , total integrated cost =  29.07638877203896
# RUN  9 , total integrated cost mean =  29.07638877203896
# Improved over  9  iterations in  6.747016939974856  seconds by  -247.4800666003096  percent.
# cost =  5.34336492537258
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1621.4649865128847
# Gradient descend method:  None
# RUN  1 , total integrated cost =  665.7178331887372
# RUN  2 , total integrated cost =  138.75721129712832
# RUN  3 , total integrated cost =  42.65404500302498
# RUN  3 , total integrated cost mean =  42.65404500302498
# Improved over  3  iterations in  1.2865859549492598  seconds by  97.3694131320864  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  6.73439301748824
# Gradient descend method:  None
# RUN  1 , total integrated cost =  30.53793019129529
# RUN  2 , total integrated cost =  32.413061235124445
# RUN  3 , total integrated cost =  26.99339531150941
# step size too small or too large
# RUN  4 , total integrated cost =  4.785906350645425
# Control only changes marginally.
# RUN  4 , total integrated cost mean =  4.785906350645425
# Improved over  4  iterations in  4.473600153985899  seconds by  28.933367295061004  percent.
# rep_ind =  8.185921230420826
# iteration =  18
# iteration =  24
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1618.8002213723335
# Gradient descend method:  None
# RUN  1 , total integrated cost =  976.4992708671034
# RUN  2 , total integrated cost =  141.11907240511385
# RUN  3 , total integrated cost =  48.4024630036035
# RUN  3 , total integrated cost mean =  48.4024630036035
# Improved over  3  iterations in  0.8172175909858197  seconds by  97.00997922013067  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  8.057263052167421
# Gradient descend method:  None
# RUN  1 , total integrated cost =  38.05764832868301
# RUN  2 , total integrated cost =  39.48932693930982
# RUN  3 , total integrated cost =  30.41269600587405
# RUN  4 , total integrated cost =  29.62443471694804
# RUN  5 , total integrated cost =  29.682401447632355
# RUN  6 , total integrated cost =  29.56054025418289
# RUN  7 , total integrated cost =  29.293777767079774
# RUN  8 , total integrated cost =  28.68298412569893
# RUN  9 , total integrated cost =  28.569101980320134
# RUN  10 , total integrated cost =  27.960764468270316
# RUN  11 , total integrated cost =  27.72508206802032
# RUN  12 , total integrated cost =  27.228001189562708
# RUN  13 , total integrated cost =  27.57046107633719
# RUN  14 , total integrated cost =  27.094674194351107
# RUN  15 , total integrated cost =  26.930228820677353
# RUN  16 , total integrated cost =  27.018450705060456
# RUN  17 , total integrated cost =  26.865376228399214
# RUN  18 , total integrated cost =  27.235436954073172
# RUN  19 , total integrated cost =  27.130618361363634
# RUN  20 , total integrated cost =  26.802621117054446
# RUN  21 , total integrated cost mean =  26.412925117331913
# Improved over  21  iterations in  14.64863367099315  seconds by  -227.81510230358901  percent.
# cost =  4.9208048676359555
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1616.2162182812488
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1019.2809891530196
# RUN  2 , total integrated cost =  153.39341627334912
# RUN  3 , total integrated cost =  43.45848961063639
# RUN  3 , total integrated cost mean =  43.45848961063639
# Improved over  3  iterations in  0.7397136079962365  seconds by  97.31109680010191  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  6.896320331949466
# Gradient descend method:  None
# RUN  1 , total integrated cost =  29.58380074006079
# RUN  2 , total integrated cost =  28.05695576537345
# RUN  3 , total integrated cost =  26.635484428749685
# RUN  4 , total integrated cost =  26.649420460427063
# RUN  5 , total integrated cost =  26.03762113050052
# RUN  6 , total integrated cost =  25.639129922140135
# RUN  7 , total integrated cost =  26.01039789857495
# RUN  8 , total integrated cost =  25.991606669578914
# RUN  9 , total integrated cost =  25.35454551893024
# RUN  10 , total integrated cost =  25.852414390436984
# RUN  11 , total integrated cost =  25.511976816032
# RUN  12 , total integrated cost =  25.112695773267486
# RUN  13 , total integrated cost =  25.09730186387344
# RUN  14 , total integrated cost =  28.779871786685412
# RUN  15 , total integrated cost =  24.824642314830303
# RUN  16 , total integrated cost =  24.499307361741707
# RUN  17 , total integrated cost =  24.315650437201846
# RUN  18 , total integrated cost =  24.36893639758199
# RUN  19 , total integrated cost =  24.432172108065913
# RUN  20 , total integrated cost =  24.38420558751556
# RUN  21 , total integrated cost mean =  24.372092059508812
# Improved over  21  iterations in  22.939316522039007  seconds by  -253.4071923341075  percent.
# rep_ind =  3.6637987783314943
# n =  30
# iteration =  6
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1619.958599737194
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2747.1359060632267
# RUN  2 , total integrated cost =  339.86744658994877
# RUN  3 , total integrated cost =  122.25725617980225
# RUN  3 , total integrated cost mean =  122.25725617980225
# Improved over  3  iterations in  3.04520658304682  seconds by  92.4530629239762  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7.19183898577755
# Gradient descend method:  None
# RUN  1 , total integrated cost =  95.48890235714948
# RUN  2 , total integrated cost =  92.28570946034348
# RUN  3 , total integrated cost =  89.11612554944506
# RUN  3 , total integrated cost mean =  89.11612554944506
# Improved over  3  iterations in  7.433697358996142  seconds by  -1139.128486131009  percent.
# cost =  5.883645573535686
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1617.3680912890452
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2505.7084730799106
# RUN  2 , total integrated cost =  419.6700632232886
# RUN  3 , total integrated cost =  109.99493135460656
# RUN  3 , total integrated cost mean =  109.99493135460656
# Improved over  3  iterations in  2.60147508000955  seconds by  93.19914050814862  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  6.464742957622704
# Gradient descend method:  None
# RUN  1 , total integrated cost =  81.10538615729546
# RUN  2 , total integrated cost =  80.08665008586007
# RUN  3 , total integrated cost =  78.23199333814082
# RUN  3 , total integrated cost mean =  78.23199333814082
# Improved over  3  iterations in  5.636867929017171  seconds by  -1110.13308419163  percent.
# rep_ind =  5.382324812207157
# iteration =  12
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1617.9651321122246
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2514.7024604125268
# RUN  2 , total integrated cost =  363.2464438869368
# RUN  3 , total integrated cost =  129.55947246982313
# RUN  3 , total integrated cost mean =  129.55947246982313
# Improved over  3  iterations in  2.409422308963258  seconds by  91.99244347740142  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  8.147245735814524
# Gradient descend method:  None
# RUN  1 , total integrated cost =  106.32688383116351
# RUN  2 , total integrated cost =  98.96005593227703
# RUN  3 , total integrated cost =  91.20176860803558
# RUN  4 , total integrated cost =  86.04164711915334
# RUN  5 , total integrated cost =  90.09248754224564
# RUN  6 , total integrated cost =  83.465055546113
# RUN  7 , total integrated cost =  84.04622985414652
# RUN  8 , total integrated cost =  83.01226792866711
# RUN  9 , total integrated cost =  83.61834661769966
# RUN  9 , total integrated cost mean =  83.61834661769966
# Improved over  9  iterations in  24.181772622978315  seconds by  -926.3388306814079  percent.
# cost =  5.461106406155636
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1617.6242796084955
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2601.072736817807
# RUN  2 , total integrated cost =  362.51272181090934
# RUN  3 , total integrated cost =  126.83653027224334
# RUN  3 , total integrated cost mean =  126.83653027224334
# Improved over  3  iterations in  4.428607439040206  seconds by  92.15908589706994  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7.477297432663554
# Gradient descend method:  None
# RUN  1 , total integrated cost =  94.853395121151
# RUN  2 , total integrated cost =  94.55014325580959
# RUN  3 , total integrated cost =  86.60393436568656
# RUN  4 , total integrated cost =  90.16107610004568
# RUN  5 , total integrated cost =  84.86696569906692
# RUN  6 , total integrated cost =  83.92757529249812
# RUN  7 , total integrated cost =  88.8207961670571
# RUN  8 , total integrated cost =  82.59728468411386
# RUN  9 , total integrated cost =  83.56776104893034
# RUN  9 , total integrated cost mean =  83.56776104893034
# Improved over  9  iterations in  21.40418218099512  seconds by  -1017.6198593341489  percent.
# rep_ind =  1.3009772023786967
# iteration =  18
# iteration =  24
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1617.6231424012722
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2546.9342760385534
# RUN  2 , total integrated cost =  421.79155660812313
# RUN  3 , total integrated cost =  111.55837239569118
# RUN  3 , total integrated cost mean =  111.55837239569118
# Improved over  3  iterations in  2.3490637979703024  seconds by  93.10356229015808  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7.048744979219037
# Gradient descend method:  None
# RUN  1 , total integrated cost =  89.52355311981455
# RUN  2 , total integrated cost =  84.01184015916374
# RUN  3 , total integrated cost =  79.51115665548261
# RUN  4 , total integrated cost =  73.62841559764597
# RUN  5 , total integrated cost =  74.31699774619634
# RUN  6 , total integrated cost =  74.03804169418504
# RUN  7 , total integrated cost =  75.22586202939547
# RUN  8 , total integrated cost =  72.40394871610359
# RUN  9 , total integrated cost =  72.34875487969988
# RUN  10 , total integrated cost =  71.33908218719439
# RUN  11 , total integrated cost =  71.72750791385971
# RUN  12 , total integrated cost =  71.92975978800446
# RUN  13 , total integrated cost =  71.9106568337548
# RUN  14 , total integrated cost =  71.83406220030496
# RUN  15 , total integrated cost =  71.70347011120407
# RUN  16 , total integrated cost =  70.30722172040443
# RUN  17 , total integrated cost =  70.56159371254283
# RUN  18 , total integrated cost =  70.86142193053097
# RUN  19 , total integrated cost =  70.78824557962882
# RUN  20 , total integrated cost =  69.72446904854108
# RUN  21 , total integrated cost mean =  70.08026369782438
# Improved over  21  iterations in  58.06473546801135  seconds by  -894.2232823635067  percent.
# cost =  4.493479523674024
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1617.9299121188487
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2735.9875356046773
# RUN  2 , total integrated cost =  357.64900354458604
# RUN  3 , total integrated cost =  114.337962065843
# RUN  3 , total integrated cost mean =  114.337962065843
# Improved over  3  iterations in  3.5172433509724215  seconds by  92.93307075854074  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7.154124733994725
# Gradient descend method:  None
# RUN  1 , total integrated cost =  94.29429670462015
# RUN  2 , total integrated cost =  93.41459680571688
# RUN  3 , total integrated cost =  82.7486204967863
# RUN  4 , total integrated cost =  83.70358298235712
# RUN  5 , total integrated cost =  80.23958432784424
# RUN  6 , total integrated cost =  84.98319247295491
# RUN  7 , total integrated cost =  79.45453869000407
# RUN  8 , total integrated cost =  80.3606364404876
# RUN  9 , total integrated cost =  79.97818299414386
# RUN  10 , total integrated cost =  79.03810198977791
# RUN  11 , total integrated cost =  79.0935137671744
# RUN  12 , total integrated cost =  79.08404467245805
# RUN  13 , total integrated cost =  79.08343387692739
# RUN  14 , total integrated cost =  78.27110637464062
# RUN  15 , total integrated cost =  77.66995421868788
# RUN  16 , total integrated cost =  79.29605019055239
# RUN  17 , total integrated cost =  71.40108304789717
# RUN  18 , total integrated cost =  70.52998500592238
# RUN  19 , total integrated cost =  70.18593973682461
# RUN  20 , total integrated cost =  70.5193189751125
# RUN  21 , total integrated cost mean =  69.35842742581976
# Improved over  21  iterations in  65.3760852959822  seconds by  -869.4886517178651  percent.
# rep_ind =  2.712083633229165
# n =  50
# iteration =  6
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1614.836677665248
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4460.517500082643
# RUN  2 , total integrated cost =  596.453193198166
# RUN  3 , total integrated cost =  173.2556555009712
# RUN  3 , total integrated cost mean =  173.2556555009712
# Improved over  3  iterations in  7.561614377016667  seconds by  89.2710106292937  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  6.390909208819909
# Gradient descend method:  None
# RUN  1 , total integrated cost =  120.56290957610712
# RUN  2 , total integrated cost =  112.9306605993992
# RUN  3 , total integrated cost =  105.19233332492057
# RUN  3 , total integrated cost mean =  105.19233332492057
# Improved over  3  iterations in  14.813245727971662  seconds by  -1545.968200889909  percent.
# cost =  4.174994896736177
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1614.8743789067769
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4437.129928340127
# RUN  2 , total integrated cost =  573.4503894454975
# RUN  3 , total integrated cost =  199.4279592140724
# RUN  3 , total integrated cost mean =  199.4279592140724
# Improved over  3  iterations in  6.524733047001064  seconds by  87.65055896489736  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7.345554117103166
# Gradient descend method:  None
# RUN  1 , total integrated cost =  157.94749971721726
# RUN  2 , total integrated cost =  154.33346149261462
# RUN  3 , total integrated cost =  146.79118437998278
# RUN  3 , total integrated cost mean =  146.79118437998278
# Improved over  3  iterations in  14.7758324110182  seconds by  -1898.367747889824  percent.
# rep_ind =  10.833973637104034
# iteration =  12
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1617.7091684363288
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3918.4705395661217
# RUN  2 , total integrated cost =  929.3633909772223
# RUN  3 , total integrated cost =  165.9638450733033
# RUN  3 , total integrated cost mean =  165.9638450733033
# Improved over  3  iterations in  6.943018238001969  seconds by  89.74081075192747  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  6.22265119386116
# Gradient descend method:  None
# RUN  1 , total integrated cost =  117.76920041196199
# RUN  2 , total integrated cost =  106.41133835750833
# RUN  3 , total integrated cost =  101.52885762945111
# RUN  4 , total integrated cost =  97.16136925715438
# RUN  5 , total integrated cost =  92.18147648721448
# RUN  6 , total integrated cost =  93.12267460968336
# RUN  7 , total integrated cost =  91.92690426235914
# RUN  8 , total integrated cost =  91.50048467635261
# RUN  9 , total integrated cost =  90.93474361276388
# RUN  9 , total integrated cost mean =  90.93474361276388
# Improved over  9  iterations in  43.48591581301298  seconds by  -1361.3504883975154  percent.
# cost =  3.5510209276707254
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1619.3937486360003
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3061.880658658541
# RUN  2 , total integrated cost =  536.7479573447928
# RUN  3 , total integrated cost =  161.5225257799417
# RUN  3 , total integrated cost mean =  161.5225257799417
# Improved over  3  iterations in  6.171083463996183  seconds by  90.02574105797366  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  6.316165472856187
# Gradient descend method:  None
# RUN  1 , total integrated cost =  132.03518442650477
# RUN  2 , total integrated cost =  130.81785329056217
# RUN  3 , total integrated cost =  121.31024859484971
# RUN  4 , total integrated cost =  120.17574380381703
# RUN  5 , total integrated cost =  122.32499734155188
# RUN  6 , total integrated cost =  118.42917475015342
# RUN  7 , total integrated cost =  119.96335976988141
# RUN  8 , total integrated cost =  114.44123868377652
# RUN  9 , total integrated cost =  114.19035031902105
# RUN  9 , total integrated cost mean =  114.19035031902105
# Improved over  9  iterations in  40.90697618597187  seconds by  -1707.9062496027968  percent.
# rep_ind =  8.825520608594257
# iteration =  18
# iteration =  24
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1618.933398286328
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4441.64347520984
# RUN  2 , total integrated cost =  670.6517995058068
# RUN  3 , total integrated cost =  187.17197512616363
# RUN  3 , total integrated cost mean =  187.17197512616363
# Improved over  3  iterations in  4.990200470027048  seconds by  88.43856236925566  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7.1134334924372205
# Gradient descend method:  None
# RUN  1 , total integrated cost =  145.3198485423643
# RUN  2 , total integrated cost =  145.18264035755425
# RUN  3 , total integrated cost =  143.04435936999815
# RUN  4 , total integrated cost =  134.87581935055832
# RUN  5 , total integrated cost =  134.2199073467137
# RUN  6 , total integrated cost =  132.71212319822192
# RUN  7 , total integrated cost =  135.24680537515925
# RUN  8 , total integrated cost =  133.35154608879512
# RUN  9 , total integrated cost =  133.36583001261423
# RUN  10 , total integrated cost =  131.55529549213452
# RUN  11 , total integrated cost =  132.20349265886267
# RUN  12 , total integrated cost =  131.02641443984948
# RUN  13 , total integrated cost =  129.90363196993746
# RUN  14 , total integrated cost =  131.31542612423516
# RUN  15 , total integrated cost =  129.7071899375952
# RUN  16 , total integrated cost =  128.93353664581838
# RUN  17 , total integrated cost =  129.5684287768029
# RUN  18 , total integrated cost =  127.21911024124556
# RUN  19 , total integrated cost =  127.76779038568051
# RUN  20 , total integrated cost =  126.50996602057279
# RUN  21 , total integrated cost mean =  125.30899742524876
# Improved over  21  iterations in  107.03550458600512  seconds by  -1661.5824701035492  percent.
# cost =  4.978573384862752
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1618.5380494930462
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4261.012033167337
# RUN  2 , total integrated cost =  722.9071696993624
# RUN  3 , total integrated cost =  166.28992189424298
# RUN  3 , total integrated cost mean =  166.28992189424298
# Improved over  3  iterations in  5.2203371379873715  seconds by  89.72591827876225  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  6.373093748273923
# Gradient descend method:  None
# RUN  1 , total integrated cost =  121.78696972477914
# RUN  2 , total integrated cost =  114.15155583311231
# RUN  3 , total integrated cost =  103.87391890395317
# RUN  4 , total integrated cost =  101.93725560235357
# RUN  5 , total integrated cost =  102.10875614844058
# RUN  6 , total integrated cost =  103.03628179936051
# RUN  7 , total integrated cost =  98.11167977071278
# RUN  8 , total integrated cost =  99.73636300767159
# RUN  9 , total integrated cost =  99.05943439691127
# RUN  10 , total integrated cost =  97.55917967018148
# step size too small or too large
# step size too small or too large
# RUN  11 , total integrated cost =  3.7481854182024144
# Control only changes marginally.
# RUN  11 , total integrated cost mean =  3.7481854182024144
# Improved over  11  iterations in  64.87815962801687  seconds by  41.18734846451041  percent.
# rep_ind =  8.213766386521813
# sigma =  0.03
# set cost params:  0.006629458876833602 0.0 1.0
# n =  2
# iteration =  6
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  527.8742071358026
# Gradient descend method:  None
# RUN  1 , total integrated cost =  176.03513873423202
# RUN  2 , total integrated cost =  11.934220350396291
# RUN  3 , total integrated cost =  27.139199183717757
# RUN  3 , total integrated cost mean =  27.139199183717757
# Improved over  3  iterations in  0.25693153304746374  seconds by  94.8587752883452  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11.269509045718788
# Gradient descend method:  None
# RUN  1 , total integrated cost =  15.575308177702073
# RUN  2 , total integrated cost =  13.5275216652979
# RUN  3 , total integrated cost =  13.155004359445195
# RUN  3 , total integrated cost mean =  13.155004359445195
# Improved over  3  iterations in  0.5152572190272622  seconds by  -16.730944587534566  percent.
# cost =  10.155165116551366
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  518.3519400649112
# Gradient descend method:  None
# RUN  1 , total integrated cost =  191.47023814879915
# RUN  2 , total integrated cost =  16.43906576028853
# RUN  3 , total integrated cost =  13.50620202270329
# RUN  3 , total integrated cost mean =  13.50620202270329
# Improved over  3  iterations in  0.2826641339925118  seconds by  97.39439539456302  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  6.747469584406796
# Gradient descend method:  None
# RUN  1 , total integrated cost =  10.236043000958464
# RUN  2 , total integrated cost =  8.991709494008935
# RUN  3 , total integrated cost =  15.017091170400203
# RUN  3 , total integrated cost mean =  15.017091170400203
# Improved over  3  iterations in  0.8610040850471705  seconds by  -122.55885680617604  percent.
# rep_ind =  18.360721527023713
# iteration =  12
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  536.5578085787004
# Gradient descend method:  None
# RUN  1 , total integrated cost =  156.4048219856051
# RUN  2 , total integrated cost =  30.67057815381262
# RUN  3 , total integrated cost =  14.13173200144804
# RUN  3 , total integrated cost mean =  14.13173200144804
# Improved over  3  iterations in  0.4205410159775056  seconds by  97.36622377393371  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  6.676028595473404
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.070979208629227
# RUN  2 , total integrated cost =  6.864238657903192
# RUN  3 , total integrated cost =  7.483337701603189
# RUN  4 , total integrated cost =  6.762907116847158
# RUN  5 , total integrated cost =  6.0817544528207765
# RUN  6 , total integrated cost =  10.890177127233262
# no cost improvement
# RUN  7 , total integrated cost =  6.288904893355654
# RUN  8 , total integrated cost =  6.1373324064396355
# RUN  8 , total integrated cost mean =  6.1373324064396355
# Improved over  8  iterations in  2.2078437120071612  seconds by  8.069111468441363  percent.
# cost =  4.799787791997498
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  510.08461386293186
# Gradient descend method:  None
# RUN  1 , total integrated cost =  624.623947957425
# RUN  2 , total integrated cost =  9.737081778532044
# RUN  3 , total integrated cost =  14.353942209018282
# RUN  3 , total integrated cost mean =  14.353942209018282
# Improved over  3  iterations in  0.2679486580309458  seconds by  97.18596840231777  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  6.910432927004145
# Gradient descend method:  None
# RUN  1 , total integrated cost =  8.580516691460332
# RUN  2 , total integrated cost =  8.523557172168726
# RUN  3 , total integrated cost =  8.138763430127614
# RUN  4 , total integrated cost =  8.192947067879883
# RUN  5 , total integrated cost =  7.793259019999828
# RUN  6 , total integrated cost =  8.935848338994868
# RUN  7 , total integrated cost =  7.591332703156971
# RUN  8 , total integrated cost =  8.349709708370717
# RUN  9 , total integrated cost =  8.160083192707878
# RUN  9 , total integrated cost mean =  8.160083192707878
# Improved over  9  iterations in  2.5243589050369337  seconds by  -18.083530784597173  percent.
# rep_ind =  11.999611805302935
# iteration =  18
# iteration =  24
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  529.0250468185468
# Gradient descend method:  None
# RUN  1 , total integrated cost =  93.59742372234061
# RUN  2 , total integrated cost =  10.517416785710545
# RUN  3 , total integrated cost =  10.331577580431691
# RUN  3 , total integrated cost mean =  10.331577580431691
# Improved over  3  iterations in  0.4014239669777453  seconds by  98.04705322695706  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7.2362865642267
# Gradient descend method:  None
# RUN  1 , total integrated cost =  10.653486948652837
# step size too small or too large
# RUN  2 , total integrated cost =  5.562306028818297
# Control only changes marginally.
# RUN  2 , total integrated cost mean =  5.562306028818297
# Improved over  2  iterations in  0.8220503780175932  seconds by  23.133143229621282  percent.
# cost =  6.613077686380352
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  540.5596930348083
# Gradient descend method:  None
# RUN  1 , total integrated cost =  41.986117473040544
# RUN  2 , total integrated cost =  13.051033370836047
# RUN  3 , total integrated cost =  13.692580991781469
# RUN  3 , total integrated cost mean =  13.692580991781469
# Improved over  3  iterations in  0.27897223900072277  seconds by  97.46696226740313  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5.57384886155756
# Gradient descend method:  None
# RUN  1 , total integrated cost =  9.332097370605087
# RUN  2 , total integrated cost =  8.92694742611836
# RUN  3 , total integrated cost =  9.414146719672042
# RUN  4 , total integrated cost =  8.959812091203494
# RUN  5 , total integrated cost =  8.389330865106103
# RUN  6 , total integrated cost =  8.31845643648442
# RUN  7 , total integrated cost =  8.445175874868681
# RUN  8 , total integrated cost =  8.751353240730237
# RUN  9 , total integrated cost =  8.72926531700297
# RUN  10 , total integrated cost =  8.191373936198527
# RUN  11 , total integrated cost =  7.951781519839003
# RUN  12 , total integrated cost =  7.922196268317741
# RUN  13 , total integrated cost =  8.32386545970109
# RUN  14 , total integrated cost =  9.80564620772447
# no cost improvement
# RUN  15 , total integrated cost =  8.211123393865464
# RUN  16 , total integrated cost =  8.940025205745087
# RUN  17 , total integrated cost =  7.885663462438908
# RUN  17 , total integrated cost mean =  7.885663462438908
# Improved over  17  iterations in  3.752889769966714  seconds by  -41.47609054895207  percent.
# rep_ind =  9.5765877339914
# n =  10
# iteration =  6
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  522.916753505582
# Gradient descend method:  None
# RUN  1 , total integrated cost =  323.67472778229904
# RUN  2 , total integrated cost =  45.59283957105443
# RUN  3 , total integrated cost =  36.18860564151138
# RUN  3 , total integrated cost mean =  36.18860564151138
# Improved over  3  iterations in  0.8985780029906891  seconds by  93.0794709867476  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5.476823865366167
# Gradient descend method:  None
# RUN  1 , total integrated cost =  28.791129670662464
# RUN  2 , total integrated cost =  28.26010049160261
# RUN  3 , total integrated cost =  27.978943231615226
# RUN  3 , total integrated cost mean =  27.978943231615226
# Improved over  3  iterations in  2.9634913209592924  seconds by  -410.86074555995646  percent.
# cost =  5.232080597140607
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  525.3043713919049
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1612.8021196608984
# RUN  2 , total integrated cost =  63.723161200234756
# RUN  3 , total integrated cost =  34.27501583105367
# RUN  3 , total integrated cost mean =  34.27501583105367
# Improved over  3  iterations in  0.9258169840322807  seconds by  93.47520833679057  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5.639153383447206
# Gradient descend method:  None
# RUN  1 , total integrated cost =  26.631887034843167
# RUN  2 , total integrated cost =  25.861124379742467
# RUN  3 , total integrated cost =  24.58278295373379
# RUN  3 , total integrated cost mean =  24.58278295373379
# Improved over  3  iterations in  2.8185725469957106  seconds by  -335.9303832006494  percent.
# rep_ind =  6.055026104614405
# iteration =  12
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  524.5119605346188
# Gradient descend method:  None
# RUN  1 , total integrated cost =  284.32899025328925
# RUN  2 , total integrated cost =  48.33025088045156
# RUN  3 , total integrated cost =  30.514719583251367
# RUN  3 , total integrated cost mean =  30.514719583251367
# Improved over  3  iterations in  0.9891362189664505  seconds by  94.18226429914989  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  4.89515186899253
# Gradient descend method:  None
# RUN  1 , total integrated cost =  24.637856923760786
# RUN  2 , total integrated cost =  23.61017670432452
# RUN  3 , total integrated cost =  23.848524363296953
# RUN  4 , total integrated cost =  24.505611722670007
# RUN  5 , total integrated cost =  27.30948156401657
# no cost improvement
# RUN  6 , total integrated cost =  23.90019755887666
# RUN  7 , total integrated cost =  22.92901087947611
# RUN  7 , total integrated cost mean =  22.92901087947611
# Improved over  7  iterations in  7.6767478859983385  seconds by  -368.4024417039205  percent.
# cost =  4.23463652492958
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  523.1782062851246
# Gradient descend method:  None
# RUN  1 , total integrated cost =  485.2709663560066
# RUN  2 , total integrated cost =  73.93746655525656
# RUN  3 , total integrated cost =  51.251308835192006
# RUN  3 , total integrated cost mean =  51.251308835192006
# Improved over  3  iterations in  1.1249008320155554  seconds by  90.20385248859913  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7.7085173856013025
# Gradient descend method:  None
# RUN  1 , total integrated cost =  37.815211134172614
# RUN  2 , total integrated cost =  40.722353270422204
# RUN  3 , total integrated cost =  36.389193898285484
# RUN  4 , total integrated cost =  39.45817604905433
# RUN  5 , total integrated cost =  35.988731976668035
# RUN  6 , total integrated cost =  34.62770332901029
# RUN  7 , total integrated cost =  35.391198936419485
# RUN  8 , total integrated cost =  34.69447761315551
# RUN  9 , total integrated cost =  33.92612436165691
# RUN  9 , total integrated cost mean =  33.92612436165691
# Improved over  9  iterations in  8.167140715988353  seconds by  -340.11218584039693  percent.
# rep_ind =  12.613368446609622
# iteration =  18
# iteration =  24
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  529.2693130636554
# Gradient descend method:  None
# RUN  1 , total integrated cost =  391.26507153928833
# RUN  2 , total integrated cost =  60.35648350063899
# RUN  3 , total integrated cost =  53.661348045478135
# RUN  3 , total integrated cost mean =  53.661348045478135
# Improved over  3  iterations in  0.8935833200230263  seconds by  89.8612395011414  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  8.663730372276842
# Gradient descend method:  None
# RUN  1 , total integrated cost =  44.37152263328052
# RUN  2 , total integrated cost =  43.682532962900325
# RUN  3 , total integrated cost =  43.40216001725831
# RUN  4 , total integrated cost =  43.6732499938522
# RUN  5 , total integrated cost =  44.41915629776643
# RUN  6 , total integrated cost =  43.501653435557
# RUN  7 , total integrated cost =  43.10856376551497
# RUN  8 , total integrated cost =  43.780364974674086
# RUN  9 , total integrated cost =  42.83383248021438
# RUN  10 , total integrated cost =  42.326174827600106
# RUN  11 , total integrated cost =  51.14162017883301
# no cost improvement
# RUN  12 , total integrated cost =  43.12333911017564
# RUN  13 , total integrated cost =  45.02123076030097
# RUN  14 , total integrated cost =  42.59880629833283
# RUN  14 , total integrated cost mean =  42.59880629833283
# Improved over  14  iterations in  13.115430128993466  seconds by  -391.69127463436746  percent.
# cost =  8.069033348662197
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  515.5296906646223
# Gradient descend method:  None
# RUN  1 , total integrated cost =  734.8893421735726
# RUN  2 , total integrated cost =  60.46875871369184
# RUN  3 , total integrated cost =  31.850361022063993
# RUN  3 , total integrated cost mean =  31.850361022063993
# Improved over  3  iterations in  1.2619478620472364  seconds by  93.82181829702138  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5.135980045296111
# Gradient descend method:  None
# RUN  1 , total integrated cost =  26.836415785613053
# RUN  2 , total integrated cost =  25.620561352876848
# RUN  3 , total integrated cost =  23.07215266735498
# RUN  4 , total integrated cost =  27.09624693393544
# RUN  5 , total integrated cost =  26.44234770078565
# RUN  6 , total integrated cost =  23.286834556216256
# RUN  7 , total integrated cost =  27.41706950470184
# RUN  8 , total integrated cost =  24.053220268901022
# RUN  9 , total integrated cost =  23.0962848559689
# RUN  10 , total integrated cost =  23.002276909162322
# RUN  11 , total integrated cost =  23.7870134247485
# RUN  12 , total integrated cost =  24.585452094915986
# RUN  13 , total integrated cost =  23.561699994000087
# RUN  14 , total integrated cost =  24.811507377535563
# RUN  15 , total integrated cost =  26.56216453102159
# no cost improvement
# RUN  16 , total integrated cost =  22.600189366687722
# RUN  16 , total integrated cost mean =  22.600189366687722
# Improved over  16  iterations in  16.430890378949698  seconds by  -340.03654935121006  percent.
# rep_ind =  26.10269603112763
# n =  30
# iteration =  6
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  528.4542498325804
# Gradient descend method:  None
# RUN  1 , total integrated cost =  616.9382340975396
# RUN  2 , total integrated cost =  114.95749069616686
# RUN  3 , total integrated cost =  90.89470719738168
# RUN  3 , total integrated cost mean =  90.89470719738168
# Improved over  3  iterations in  3.369959480012767  seconds by  82.7998909600636  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5.804673651205436
# Gradient descend method:  None
# RUN  1 , total integrated cost =  82.93866085452491
# RUN  2 , total integrated cost =  88.25359602464238
# RUN  3 , total integrated cost =  87.5447439226576
# RUN  3 , total integrated cost mean =  87.5447439226576
# Improved over  3  iterations in  7.433194423967507  seconds by  -1408.1768447822642  percent.
# cost =  5.545317147184591
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  525.165853069814
# Gradient descend method:  None
# RUN  1 , total integrated cost =  587.167208499996
# RUN  2 , total integrated cost =  94.20701478718836
# RUN  3 , total integrated cost =  118.0026101164254
# RUN  3 , total integrated cost mean =  118.0026101164254
# Improved over  3  iterations in  2.77590639697155  seconds by  77.53041074040691  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7.142690966177782
# Gradient descend method:  None
# RUN  1 , total integrated cost =  105.12676516684841
# RUN  2 , total integrated cost =  102.93554173407846
# RUN  3 , total integrated cost =  107.72014254282189
# RUN  3 , total integrated cost mean =  107.72014254282189
# Improved over  3  iterations in  7.472478114999831  seconds by  -1408.117081543924  percent.
# rep_ind =  8.009383110835309
# iteration =  12
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  524.5351325908134
# Gradient descend method:  None
# RUN  1 , total integrated cost =  474.86150576325355
# RUN  2 , total integrated cost =  165.79939703099737
# RUN  3 , total integrated cost =  69.76854814713833
# RUN  3 , total integrated cost mean =  69.76854814713833
# Improved over  3  iterations in  2.857456397032365  seconds by  86.69897518541158  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  4.243635155156584
# Gradient descend method:  None
# RUN  1 , total integrated cost =  61.15472432699844
# RUN  2 , total integrated cost =  58.95411114004441
# RUN  3 , total integrated cost =  59.21351038086182
# RUN  4 , total integrated cost =  57.647072482816185
# RUN  5 , total integrated cost =  59.10629003654279
# RUN  6 , total integrated cost =  56.63942743438663
# RUN  7 , total integrated cost =  59.105643016403
# RUN  8 , total integrated cost =  55.81528155145199
# RUN  9 , total integrated cost =  60.224184598219416
# RUN  9 , total integrated cost mean =  60.224184598219416
# Improved over  9  iterations in  18.690591381979175  seconds by  -1319.1649940744549  percent.
# cost =  3.711444305003957
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  520.6559655556965
# Gradient descend method:  None
# RUN  1 , total integrated cost =  747.3690805299447
# RUN  2 , total integrated cost =  128.53363293324935
# RUN  3 , total integrated cost =  85.94280034899253
# RUN  3 , total integrated cost mean =  85.94280034899253
# Improved over  3  iterations in  2.9369872100069188  seconds by  83.49336106093287  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5.37249830461917
# Gradient descend method:  None
# RUN  1 , total integrated cost =  79.14349093411703
# RUN  2 , total integrated cost =  78.25200972328608
# RUN  3 , total integrated cost =  76.52441719696229
# RUN  4 , total integrated cost =  75.30176780225239
# RUN  5 , total integrated cost =  75.79967559003468
# RUN  6 , total integrated cost =  77.37067540778624
# RUN  7 , total integrated cost =  76.18398223764486
# RUN  8 , total integrated cost =  77.1803056548315
# RUN  9 , total integrated cost =  74.82453844168337
# RUN  9 , total integrated cost mean =  74.82453844168337
# Improved over  9  iterations in  19.579133950988762  seconds by  -1292.7326580512959  percent.
# ...
# RUN  3 , total integrated cost =  26.596815606599193
# RUN  4 , total integrated cost =  30.250192663952106
# RUN  5 , total integrated cost =  24.66023769927115
# RUN  6 , total integrated cost =  26.906208719548125
# RUN  7 , total integrated cost =  26.882287940836193
# RUN  8 , total integrated cost =  27.448935819965648
# no cost improvement
# RUN  9 , total integrated cost =  30.76381016554234
# step size too small or too large
# RUN  10 , total integrated cost =  4.075491898182692
# Control only changes marginally.
# RUN  10 , total integrated cost mean =  4.075491898182692
# Improved over  10  iterations in  13.528994732012507  seconds by  17.09159212518962  percent.
# cost =  5.422561104083039
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  191.68622583508665
# Gradient descend method:  None
# RUN  1 , total integrated cost =  143.06213386197908
# RUN  2 , total integrated cost =  39.415775921737236
# RUN  3 , total integrated cost =  44.78359531111546
# RUN  3 , total integrated cost mean =  44.78359531111546
# Improved over  3  iterations in  1.113841651007533  seconds by  76.63703006514191  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  4.748144477282375
# Gradient descend method:  None
# RUN  1 , total integrated cost =  27.00580485080552
# RUN  2 , total integrated cost =  23.44094646296752
# RUN  3 , total integrated cost =  31.426838365893495
# RUN  4 , total integrated cost =  29.697158005285395
# RUN  5 , total integrated cost =  30.748325345989212
# no cost improvement
# RUN  6 , total integrated cost =  27.130235935385304
# RUN  7 , total integrated cost =  26.546267978482074
# RUN  7 , total integrated cost mean =  26.546267978482074
# Improved over  7  iterations in  5.854778761975467  seconds by  -459.08719933635984  percent.
# rep_ind =  12.501011028850584
# n =  30
# iteration =  6
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  178.65700481781775
# Gradient descend method:  None
# RUN  1 , total integrated cost =  407.139646796018
# RUN  2 , total integrated cost =  99.46556250955882
# RUN  3 , total integrated cost =  102.32702252863952
# RUN  3 , total integrated cost mean =  102.32702252863952
# Improved over  3  iterations in  2.056670935009606  seconds by  42.72431543728965  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  6.0182089016251386
# Gradient descend method:  None
# RUN  1 , total integrated cost =  90.95900625211343
# RUN  2 , total integrated cost =  90.17377438745936
# RUN  3 , total integrated cost =  86.3770301650345
# RUN  3 , total integrated cost mean =  86.3770301650345
# Improved over  3  iterations in  6.986746263981331  seconds by  -1335.2614137689623  percent.
# cost =  5.856199128671056
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  168.45499631237695
# Gradient descend method:  None
# RUN  1 , total integrated cost =  459.69165106058443
# RUN  2 , total integrated cost =  99.49494212361927
# RUN  3 , total integrated cost =  93.22364888460264
# RUN  3 , total integrated cost mean =  93.22364888460264
# Improved over  3  iterations in  2.0420824059983715  seconds by  44.65961181006942  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5.627506809999302
# Gradient descend method:  None
# RUN  1 , total integrated cost =  83.63793893645854
# RUN  2 , total integrated cost =  79.75479496488465
# RUN  3 , total integrated cost =  77.89805196680565
# RUN  3 , total integrated cost mean =  77.89805196680565
# Improved over  3  iterations in  6.163820268993732  seconds by  -1284.2373647312445  percent.
# rep_ind =  7.733767312269613
# iteration =  12
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  192.52668086318835
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1326.8462478159886
# RUN  2 , total integrated cost =  98.49431200233644
# RUN  3 , total integrated cost =  90.81770307572012
# RUN  3 , total integrated cost mean =  90.81770307572012
# Improved over  3  iterations in  1.8306081679766066  seconds by  52.82851048564214  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5.16392627655072
# Gradient descend method:  None
# RUN  1 , total integrated cost =  79.62405351630149
# RUN  2 , total integrated cost =  74.85023099993587
# RUN  3 , total integrated cost =  92.38478865350729
# RUN  4 , total integrated cost =  79.6048370747577
# RUN  5 , total integrated cost =  76.24699994430198
# RUN  6 , total integrated cost =  73.43962053325184
# RUN  7 , total integrated cost =  73.21570270553482
# RUN  8 , total integrated cost =  67.95727423528132
# RUN  9 , total integrated cost =  79.29848131198204
# RUN  9 , total integrated cost mean =  79.29848131198204
# Improved over  9  iterations in  17.35650778602576  seconds by  -1435.623807645643  percent.
# cost =  5.5364057175818475
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  175.99805703087256
# Gradient descend method:  None
# RUN  1 , total integrated cost =  170.13941635353612
# RUN  2 , total integrated cost =  109.225766154558
# RUN  3 , total integrated cost =  92.03240040645058
# RUN  3 , total integrated cost mean =  92.03240040645058
# Improved over  3  iterations in  2.0661215650034137  seconds by  47.70828612596173  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5.654702947670116
# Gradient descend method:  None
# RUN  1 , total integrated cost =  86.84862398790139
# RUN  2 , total integrated cost =  86.15818281949971
# RUN  3 , total integrated cost =  92.7845495400925
# RUN  4 , total integrated cost =  85.3569844599477
# RUN  5 , total integrated cost =  85.4705326770505
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  6 , total integrated cost =  5.051877974529928
# Control only changes marginally.
# RUN  6 , total integrated cost mean =  5.051877974529928
# Improved over  6  iterations in  24.251421244989615  seconds by  10.660594883919899  percent.
# rep_ind =  9.36075666862299
# iteration =  18
# iteration =  24
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  167.9226879677171
# Gradient descend method:  None
# RUN  1 , total integrated cost =  545.6866321866862
# RUN  2 , total integrated cost =  133.48733693284075
# RUN  3 , total integrated cost =  97.95105332854367
# RUN  3 , total integrated cost mean =  97.95105332854367
# Improved over  3  iterations in  2.3495578590082005  seconds by  41.66895818903601  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5.596473660338442
# Gradient descend method:  None
# RUN  1 , total integrated cost =  81.7076345326775
# RUN  2 , total integrated cost =  76.9829396361728
# RUN  3 , total integrated cost =  81.29330961502754
# RUN  4 , total integrated cost =  80.70978944953582
# RUN  5 , total integrated cost =  79.28969330928354
# RUN  6 , total integrated cost =  74.74570123491064
# RUN  7 , total integrated cost =  78.71034236636183
# RUN  8 , total integrated cost =  71.87702554162824
# RUN  9 , total integrated cost =  71.45104832918183
# RUN  10 , total integrated cost =  66.08149463536249
# RUN  11 , total integrated cost =  73.07653381954978
# RUN  12 , total integrated cost =  70.29802586174428
# RUN  13 , total integrated cost =  83.37074125357888
# RUN  14 , total integrated cost =  77.56579907380771
# no cost improvement
# RUN  15 , total integrated cost =  85.39882531523926
# RUN  16 , total integrated cost =  82.80831106608248
# RUN  17 , total integrated cost =  84.52439776980819
# RUN  18 , total integrated cost =  78.98708250328751
# RUN  19 , total integrated cost =  74.73879698808494
# RUN  19 , total integrated cost mean =  74.73879698808494
# Improved over  19  iterations in  61.14798664400587  seconds by  -1235.4623200989956  percent.
# cost =  8.862514649826611
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  175.5507844079034
# Gradient descend method:  None
# RUN  1 , total integrated cost =  424.2730570338779
# RUN  2 , total integrated cost =  99.8651059295181
# RUN  3 , total integrated cost =  77.91362140354863
# RUN  3 , total integrated cost mean =  77.91362140354863
# Improved over  3  iterations in  3.4323309409664944  seconds by  55.617617052333195  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  6.460554987924114
# Gradient descend method:  None
# RUN  1 , total integrated cost =  79.26008038492672
# RUN  2 , total integrated cost =  91.32332016096129
# RUN  3 , total integrated cost =  77.0741136349682
# RUN  4 , total integrated cost =  71.29121423766394
# RUN  5 , total integrated cost =  72.17544551127678
# RUN  6 , total integrated cost =  72.91955083825306
# RUN  7 , total integrated cost =  78.41611222973201
# RUN  8 , total integrated cost =  74.26677626465813
# RUN  9 , total integrated cost =  68.3515381690602
# RUN  10 , total integrated cost =  72.42769865993859
# RUN  11 , total integrated cost =  74.83432034359922
# RUN  12 , total integrated cost =  71.1566852169672
# RUN  13 , total integrated cost =  74.0213396219119
# RUN  14 , total integrated cost =  70.04804553986384
# RUN  15 , total integrated cost =  125.40246377422353
# no cost improvement
# RUN  16 , total integrated cost =  83.2015079366755
# RUN  17 , total integrated cost =  78.35680502767507
# RUN  18 , total integrated cost =  209.67533386198974
# RUN  19 , total integrated cost =  82.96057061738556
# RUN  20 , total integrated cost =  94.8337209823355
# RUN  21 , total integrated cost mean =  221.19351491201297
# Improved over  21  iterations in  72.33325563196559  seconds by  -3323.7540787975895  percent.
# rep_ind =  11.273014950814545
# n =  50
# iteration =  6
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  169.02734304770414
# Gradient descend method:  None
# RUN  1 , total integrated cost =  934.9592174191181
# RUN  2 , total integrated cost =  181.98924935722764
# RUN  3 , total integrated cost =  168.53101192751055
# RUN  3 , total integrated cost mean =  168.53101192751055
# Improved over  3  iterations in  5.5375239250133745  seconds by  0.2936395444928195  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  6.8045443676513
# Gradient descend method:  None
# RUN  1 , total integrated cost =  161.9778780732787
# RUN  2 , total integrated cost =  158.75913862501392
# RUN  3 , total integrated cost =  163.0181167581314
# RUN  3 , total integrated cost mean =  163.0181167581314
# Improved over  3  iterations in  15.13263182202354  seconds by  -2295.724209443281  percent.
# cost =  6.563841660805444
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  182.18272351748695
# Gradient descend method:  None
# RUN  1 , total integrated cost =  628.010038534285
# RUN  2 , total integrated cost =  139.58304768365508
# RUN  3 , total integrated cost =  123.09028349979363
# RUN  3 , total integrated cost mean =  123.09028349979363
# Improved over  3  iterations in  5.343843237962574  seconds by  32.43580888284464  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5.461634643512674
# Gradient descend method:  None
# RUN  1 , total integrated cost =  112.831043206316
# RUN  2 , total integrated cost =  121.98212249295777
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  3 , total integrated cost =  4.273019876920123
# Control only changes marginally.
# RUN  3 , total integrated cost mean =  4.273019876920123
# Improved over  3  iterations in  41.211337846994866  seconds by  21.762985702538472  percent.
# rep_ind =  13.821830315916333
# iteration =  12
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  178.08770720003943
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2341.5592676540277
# RUN  2 , total integrated cost =  277.5631373800026
# RUN  3 , total integrated cost =  178.8639976348399
# RUN  3 , total integrated cost mean =  178.8639976348399
# Improved over  3  iterations in  5.229707304970361  seconds by  -0.4359034360122962  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  6.87402415347389
# Gradient descend method:  None
# RUN  1 , total integrated cost =  167.49833974417314
# RUN  2 , total integrated cost =  171.51860504390632
# RUN  3 , total integrated cost =  163.67126124880969
# RUN  4 , total integrated cost =  157.73351631902335
# RUN  5 , total integrated cost =  165.2489942969313
# RUN  6 , total integrated cost =  166.05274996106112
# RUN  7 , total integrated cost =  166.5805433968317
# no cost improvement
# RUN  8 , total integrated cost =  161.80082144268172
# RUN  8 , total integrated cost mean =  161.80082144268172
# Improved over  8  iterations in  40.98143266799161  seconds by  -2253.8005952585036  percent.
# cost =  6.35723441724028
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  171.58805516755035
# Gradient descend method:  None
# RUN  1 , total integrated cost =  823.7925072455425
# RUN  2 , total integrated cost =  208.1362616623872
# RUN  3 , total integrated cost =  166.03018427767518
# RUN  3 , total integrated cost mean =  166.03018427767518
# Improved over  3  iterations in  5.189315474010073  seconds by  3.239077967547388  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  6.492860945121163
# Gradient descend method:  None
# RUN  1 , total integrated cost =  150.4878215095522
# RUN  2 , total integrated cost =  150.34532099349056
# RUN  3 , total integrated cost =  144.54255163419853
# RUN  4 , total integrated cost =  148.35568088923972
# step size too small or too large
# step size too small or too large
# RUN  5 , total integrated cost =  5.39552506487842
# Control only changes marginally.
# RUN  5 , total integrated cost mean =  5.39552506487842
# Improved over  5  iterations in  42.15142341895262  seconds by  16.900652724856187  percent.
# rep_ind =  9.201108581182172
# iteration =  18
# iteration =  24
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  173.14784009796594
# Gradient descend method:  None
# RUN  1 , total integrated cost =  863.9570450031543
# RUN  2 , total integrated cost =  183.40230524580357
# RUN  3 , total integrated cost =  163.37517079597055
# RUN  3 , total integrated cost mean =  163.37517079597055
# Improved over  3  iterations in  5.487958598008845  seconds by  5.644118515406305  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5.85258880032271
# Gradient descend method:  None
# RUN  1 , total integrated cost =  145.36479617603567
# RUN  2 , total integrated cost =  137.53475511627047
# RUN  3 , total integrated cost =  139.0130402564537
# RUN  4 , total integrated cost =  150.52723108122154
# RUN  5 , total integrated cost =  139.01485144105703
# RUN  6 , total integrated cost =  143.60700622033076
# RUN  7 , total integrated cost =  148.04556144507958
# no cost improvement
# RUN  8 , total integrated cost =  129.3660221546116
# RUN  8 , total integrated cost mean =  129.3660221546116
# Improved over  8  iterations in  59.92760513396934  seconds by  -2110.406822831606  percent.
# cost =  6.885917429268018
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  171.71468671016842
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1257.1265576796022
# RUN  2 , total integrated cost =  212.30171306756594
# RUN  3 , total integrated cost =  115.45572800898294
# RUN  3 , total integrated cost mean =  115.45572800898294
# Improved over  3  iterations in  4.750036903016735  seconds by  32.763044197927655  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  4.482242027634971
# Gradient descend method:  None
# RUN  1 , total integrated cost =  118.20437075015057
# RUN  2 , total integrated cost =  120.1495334484339
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  3 , total integrated cost =  4.091587279496985
# Control only changes marginally.
# RUN  3 , total integrated cost mean =  4.091587279496985
# Improved over  3  iterations in  39.343467631959356  seconds by  8.715610306838173  percent.
# rep_ind =  10.014822772536892
