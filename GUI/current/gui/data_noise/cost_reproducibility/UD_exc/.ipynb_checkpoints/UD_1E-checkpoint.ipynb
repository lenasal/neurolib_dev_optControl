# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import sys
import pickle
import matplotlib
import ipyparams

if 'cost_reproducibility' in os.getcwd():
    for i in range(6):
        os.chdir('..')
        
print(os.getcwd())

path = os.getcwd().split(os.sep + 'GUI')[0]
if path not in sys.path:
    print("not here")
    sys.path.append(path)

from neurolib_dev_optControl.neurolib.models.aln import ALNModel
from neurolib_dev_optControl.neurolib.utils import plotFunctions as plotFunc
from neurolib.utils import func_optimize as fo
from neurolib.utils import costFunctions as cost
import neurolib.dashboard.functions as functions
import neurolib.dashboard.data as data
import neurolib.dashboard.layout as layout
    
# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2 

#path = os.path.join(os.getcwd(), "plots")

cmap_ = layout.getcolormap()
darkgrey, midgrey, lightgrey, color_bi_updown, color_LC, color_bi_uposc = layout.getcolors_rgba()
exc_red = cmap_(3)
inh_blue=cmap_(0)
green = cmap_(2)
# Out:
# /home/lena/Promotion/neurolib_dev_optControl
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipykernel_11492/1174555177.py in <module>
#      19
#      20 from neurolib.models.aln import ALNModel
# ---> 21 from neurolib.utils import plotFunctions as plotFunc
#      22 from neurolib.utils import func_optimize as fo
#      23 from neurolib.utils import costFunctions as cost
#
# ImportError: cannot import name 'plotFunctions' from 'neurolib.utils' (/home/lena/Promotion/neurolib/neurolib/utils/__init__.py)

# %%
aln = ALNModel()
N = aln.params.N

aln.params.sigma_ou = 0.
aln.params.mue_ext_mean = 0.
aln.params.mui_ext_mean = 0.
aln.params.ext_exc_current = 0.
aln.params.ext_inh_current = 0.

state_vars = aln.state_vars
init_vars = aln.init_vars

##############################################################
def setinit(init_vars_, model):
    state_vars = model.state_vars
    init_vars = model.init_vars
    for iv in range(len(init_vars)):
        for sv in range(len(state_vars)):
            if state_vars[sv] in init_vars[iv]:
                #print("set init vars ", )
                if model.params[init_vars[iv]].ndim == 2:
                    model.params[init_vars[iv]][0,:] = init_vars_[sv]
                else:
                    model.params[init_vars[iv]][0] = init_vars_[sv]
                    
##############################################################               
def setmaxmincontrol(max_c_c, min_c_c, max_c_r, min_c_r):
    import numpy as np
    
    max_cntrl = np.zeros(( 6 ))
    min_cntrl = np.zeros(( 6 ))
    
    max_cntrl[0] = max_c_c
    min_cntrl[0] = min_c_c
    max_cntrl[1] = max_c_c
    min_cntrl[1] = min_c_c
    max_cntrl[2] = max_c_r
    min_cntrl[2] = min_c_r
    max_cntrl[3] = max_c_r
    min_cntrl[3] = min_c_r
    max_cntrl[4] = max_c_r
    min_cntrl[4] = min_c_r
    max_cntrl[5] = max_c_r
    min_cntrl[5] = min_c_r
            
    return max_cntrl, min_cntrl

def rep_ind(c0, c1):
    abs_diff = np.abs(c0-c1)
    res = 0.
    for n in range(c0.shape[0]):
        for v in range(c0.shape[1]):
            res += sum(abs_diff[n,v,:]) * dt
            
    return res

# %%
points = np.array( [ [0.86, 0.25] ])

# 10 points, two costs, 4 methods, N

# %%
def create_dict(task, point, cost_params, init, init_vars, target, sigma_array, N_max_array, it_array):
    return dict( {'task':task, 'point':point, 'cost_params':cost_params, 'init':init, 'init_vars':init_vars,
            'target':target, 'sigma':sigma_array, 'N_array':N_max_array, 'it_array':it_array,
            'cost':np.zeros(( len(sigma_array), 4, 2, len(N_max_array), len(it_array) )),
            'rep_ind':np.zeros(( len(sigma_array), 4, 2, len(N_max_array), len(it_array) ))     } )

params_list = ['task', 'point', 'cost_params', 'init', 'init_vars', 'target', 'sigma', 'N_array',
               'cost', 'rep_ind']

# %%
dict_list = []
sigma_array = np.arange(0.01, 0.081, 0.02)
N_array = [2,10,30,50]
it_array = np.arange(0,25,6)

for p in points:
    dict_list.append(create_dict('DU', p, [None]*len(sigma_array), [0], None,
                [None]*len(sigma_array), sigma_array, N_array, it_array) )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_9875/2163158536.py in <module>
#       4 it_array = np.arange(0,25,6)
#       5
# ----> 6 for p in points:
#       7     dict_list.append(create_dict('DU', p, [None]*len(sigma_array), [0], None,
#       8                 [None]*len(sigma_array), sigma_array, N_array, it_array) )
#
# NameError: name 'points' is not defined

# %%
for d in dict_list:
    print(d['target'])
# Out:
# [None, None, None, None]

# %%
dict_file = "UD_1E.pickle"

if False:
    file=open(dict_file, "wb")
    pickle.dump(dict_list, file)
    file.close()

if True:
    file = open(dict_file, "rb")
    dict_list = pickle.load(file)
    file.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_683208/484889842.py in <module>
#       7
#       8 if True:
# ----> 9     file = open(dict_file, "rb")
#      10     dict_list = pickle.load(file)
#      11     file.close()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'UD_1E.pickle'

# %%
dur_pre = 10
dur_post = 10
dur = 500.
dur_comp = 2000.
dt = aln.params.dt
T = int(1 + dur / dt)

prec_vars = [0,1]
trans_time = 0.6

n_pre = int(np.around(dur_pre/aln.params.dt,1))
n_post = int(np.around(dur_post/aln.params.dt,1))

tol = 1e-16
start_step = 10.
c_scheme = np.zeros(( 1,1 ))
c_scheme[0,0] = 1.
u_mat = np.identity(1)
u_scheme = np.array([[1.]])

maxC = [5., -5., 0.18, 0.]
n_dur = int(np.around(dur/aln.params.dt + 1.,1))
max_cntrl, min_cntrl = setmaxmincontrol(maxC[0], maxC[1], maxC[2], maxC[3])

noise_realizations_final = 10000
dur_target_compute = 100000
init_it = 3

# %%
# get init vars without noise
aln.params.duration = dur_comp

# initial without noise
control0 = aln.getZeroControl()

for d in dict_list:
    
    print("Point = ", d['point'])
    aln.params.ext_exc_current = d['point'][0] * 5.
    aln.params.ext_inh_current = d['point'][1] * 5.
    aln.params.duration = dur_comp
    aln.params.sigma_ou = 0.
    
    control0[0,0,:500] = 5.

    aln.run(control=control0)

    plt.plot(aln.t, aln.rates_exc[0,:])
    plt.show() 

    init_state_vars = np.zeros(( len(state_vars) ))
    for j in range(len(state_vars)):
        if aln.state[state_vars[j]].size == 1:
            init_state_vars[j] = aln.state[state_vars[j]][0]
        else:
            init_state_vars[j] = aln.state[state_vars[j]][0,-1]

    initVars = init_state_vars.copy()
    d['init_vars'] = initVars
# Out:
# Point =  [0.86 0.25]

# %%
for d in dict_list:
    
    print("Point = ", d['point'])
    aln.params.ext_exc_current = d['point'][0] * 5.
    aln.params.ext_inh_current = d['point'][1] * 5.
        
    aln.params.sigma_ou = 0.15
    aln.params.duration = dur_target_compute

    setinit(d['init_vars'], aln)

    target_rates_e = []
    target_rates_i = []

    aln.run(control=aln.getZeroControl())
    for t in range(len(aln.t)):
        if aln.rates_exc[0,t] > 10.:
            continue
        if aln.rates_inh[0,t] > 30.:
            continue

        target_rates_e.append(aln.rates_exc[0,t])
        target_rates_i.append(aln.rates_inh[0,t])

    plt.plot(aln.t, aln.rates_exc[0,:])
    #plt.plot(aln.t, aln.rates_inh[0,:])
    plt.show()            

    aln.params.duration = dur
    target = aln.getZeroTarget()
    target[:,0,:] = np.mean(target_rates_e)
    target[:,1,:] = np.mean(target_rates_i)
    stddev = np.std(target_rates_e) + np.std(target_rates_i)
        
    for ind_s in range(len(d['sigma'])): 
        
        d['target'][ind_s] = target
        d['cost_params'][ind_s] = [1. / ( stddev * (1. - trans_time) * dur ), 0., 1.]
        
        
    print(d['target'][0][0,:,-1])
    print(d['cost_params'][0][0])
        
    file=open(dict_file, "wb")
    pickle.dump(dict_list, file)
    file.close()
# Out:
# Point =  [0.86 0.25]
# [ 3.0419861 15.191433 ]
# 0.0004517907010954736

# %%
#len(sigma_array), 4, N_max, max_it

##### METHOD 1
method_ind = 0
step_method_ind = 0

for d in dict_list:
        
        
    print("Point = ", d['point'])
    aln.params.ext_exc_current = d['point'][0] * 5.
    aln.params.ext_inh_current = d['point'][1] * 5.
    
    max_it = d['cost'].shape[3]
    
    for s_ind in range(len(d['sigma'])):
        
        print("sigma = ", d['sigma'][s_ind])
        
        s = d['sigma'][s_ind]
        aln.params.sigma_ou = s
        c_p = d['cost_params'][s_ind]
        cost.setParams(c_p[0], c_p[1], c_p[2])
        aln.params.duration = dur
        zero_init = aln.getZeroControl()
        
        target_ = d['target'][s_ind].copy()
        target_[0,0,:int(trans_time * dur / aln.params.dt)] = -1000
        target_[0,1,:int(trans_time * dur / aln.params.dt)] = -1000
        
        if np.amin(d['cost'][s_ind, method_ind, step_method_ind, :, 0]) == 0.:
        
            setinit(d['init_vars'], aln)
            cost_final = 0.

            for n_ in range(noise_realizations_final):
                state_ = fo.updateState(aln, zero_init)
                cost_final += cost.numba_cost_precision_int(1, T, dt, d['cost_params'][s_ind][0],
                                                               state_, target_, list(prec_vars) )

            d['cost'][s_ind, :, :, :, 0] = cost_final/noise_realizations_final
            
        print('cost = ', d['cost'][s_ind, 0, 0, 0])    
        
        for i_it in range(1,len(d['it_array'])):
            
            it = d['it_array'][i_it]
            print("iteration = ", it)
        
            for n_ind in range(len(d['N_array'])):

                if ( d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it] > 0.
                    and d['rep_ind'][s_ind, method_ind, step_method_ind, n_ind, i_it] > 0. ) :
                    continue
                    
                n_max = d['N_array'][n_ind]
                print("n max = ", n_max)

                aln.params.duration = dur
                     
                    
                n_ = 0
                control_sum = aln.getZeroControl()
                
                while n_ < n_max:
                
                    print('--------', n_)

                    aln.params.duration = dur
                    control_init = aln.getZeroControl()               
                    setinit(d['init_vars'], aln)
                    
                    c_vars = d['init']

                    bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                        control_init, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_ = init_it,
                        tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                        t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                        control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                        noise_real=0, init_params = d['init_vars'])
                    
                    if np.isnan(c_).any():
                        continue
                    
                    control_init = bc[:,:,n_pre:-n_post]
                    c_vars = [0,1]
                    aln.params.duration = dur
                    setinit(d['init_vars'], aln)
                    
                    bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                        control_init, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_ = it-init_it,
                        tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                        t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                        control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                        noise_real=0, init_params = d['init_vars'])
                    
                    if np.isnan(c_).any():
                        continue
                    
                    control_sum += bc[:,:,n_pre:-n_post]
                    n_ += 1

                control_init = control_sum / n_max
        
                aln.params.duration = dur
                setinit(d['init_vars'], aln)

                cost_final = 0.

                for j in range(noise_realizations_final):
                    state_ = fo.updateState(aln, control_init)
                    cost_final += cost.numba_cost_precision_int(1, T, dt, d['cost_params'][s_ind][0],
                                                                   state_, target_, list(prec_vars) )
                    cost_final += cost.numba_cost_sparsity_int(1, 6, T, d['cost_params'][s_ind][2],
                                                                   dt, control_init)

                d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it] = cost_final/noise_realizations_final
                print('cost = ', d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it])
                
                ###############################################################
                
                aln.params.duration = dur
                setinit(d['init_vars'], aln)
                     
                    
                n_ = 0
                control_sum = aln.getZeroControl()
                
                while n_ < n_max:
                
                    print('--------', n_)

                    aln.params.duration = dur
                    control_init1 = aln.getZeroControl()               
                    setinit(d['init_vars'], aln)
                    
                    c_vars = d['init']

                    bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                        control_init1, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_ = init_it,
                        tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                        t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                        control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                        noise_real=0, init_params = d['init_vars'])
                    
                    if np.isnan(c_).any():
                        continue
                    
                    control_init1 = bc[:,:,n_pre:-n_post]
                    c_vars = [0,1]
                    aln.params.duration = dur
                    setinit(d['init_vars'], aln)
                    
                    bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                        control_init1, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_ = it-init_it,
                        tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                        t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                        control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                        noise_real=0, init_params = d['init_vars'])
                    
                    if np.isnan(c_).any():
                        continue
                    
                    control_sum += bc[:,:,n_pre:-n_post]
                    n_ += 1

                control_init1 = control_sum / n_max
                
                d['rep_ind'][s_ind, method_ind, step_method_ind, n_ind, i_it] = rep_ind(control_init, control_init1)
                print('rep_ind = ', d['rep_ind'][s_ind, method_ind, step_method_ind, n_ind, i_it])
                
                file=open(dict_file, "wb")
                pickle.dump(dict_list, file)
                file.close()
# Out:
# Point =  [0.86 0.25]
# sigma =  0.01
# set cost params:  0.0004517907010954736 0.0 1.0
# /home/lena/.local/lib/python3.9/site-packages/numba/core/ir_utils.py:2119: NumbaPendingDeprecationWarning:
# Encountered the use of a type that is scheduled for deprecation: type 'reflected list' found for argument 'var_' of function 'numba_cost_precision_int'.
#
# For more information visit https://numba.pydata.org/numba-doc/latest/reference/deprecation.html#deprecation-of-reflection-for-list-and-set-types
#
# File "../../../../../../neurolib/utils/costFunctions.py", line 79:
# @numba.njit
# def numba_cost_precision_int(N, T, dt, i_p, state_, target_state_, var_):
# ^
#
#   warnings.warn(NumbaPendingDeprecationWarning(msg, loc=loc))
# cost =  [62.47333142  0.          0.          0.          0.        ]
# iteration =  6
# n max =  2
# -------- 0
# interpolate adjoint :  True True True
# initial cost =  62.388151849712266
# RUN  0 , total integrated cost =  62.388151849712266
# Gradient descend method:  None
# RUN  1 , total integrated cost =  19.704713781014128
# RUN  2 , total integrated cost =  16.036075466073406
# RUN  3 , total integrated cost =  15.079274453878282
# RUN  3 , total integrated cost =  15.079274453878282
# Improved over  3  iterations in  13.791928558028303  seconds by  75.82990679031018  percent.
# interpolate adjoint :  True True True
# initial cost =  15.087251951907062
# RUN  0 , total integrated cost =  15.087251951907062
# Gradient descend method:  None
# RUN  1 , total integrated cost =  13.93138724545703
# RUN  2 , total integrated cost =  13.99426235576014
# RUN  3 , total integrated cost =  13.777051135517619
# RUN  3 , total integrated cost =  13.777051135517619
# Improved over  3  iterations in  0.4089591249357909  seconds by  8.684158126118064  percent.
# -------- 1
# interpolate adjoint :  True True True
# initial cost =  62.72194383270315
# RUN  0 , total integrated cost =  62.72194383270315
# Gradient descend method:  None
# RUN  1 , total integrated cost =  19.73293645614799
# RUN  2 , total integrated cost =  16.576989494339433
# RUN  3 , total integrated cost =  16.432161199866325
# RUN  3 , total integrated cost =  16.432161199866325
# Improved over  3  iterations in  0.219568200991489  seconds by  73.80157534068863  percent.
# interpolate adjoint :  True True True
# initial cost =  16.45748107852452
# RUN  0 , total integrated cost =  16.45748107852452
# Gradient descend method:  None
# RUN  1 , total integrated cost =  15.642292235399863
# RUN  2 , total integrated cost =  15.56453694204248
# RUN  3 , total integrated cost =  15.713660917169998
# RUN  3 , total integrated cost =  15.713660917169998
# Improved over  3  iterations in  0.3877353009302169  seconds by  4.5196476775849845  percent.
# cost =  15.319514240309738
# -------- 0
# interpolate adjoint :  True True True
# initial cost =  61.59334241507087
# RUN  0 , total integrated cost =  61.59334241507087
# Gradient descend method:  None
# RUN  1 , total integrated cost =  18.825993778388753
# RUN  2 , total integrated cost =  17.008277458458203
# RUN  3 , total integrated cost =  14.685938549716802
# RUN  3 , total integrated cost =  14.685938549716802
# Improved over  3  iterations in  0.28773086704313755  seconds by  76.15661372823405  percent.
# interpolate adjoint :  True True True
# initial cost =  15.736642379125431
# RUN  0 , total integrated cost =  15.736642379125431
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14.262456083673527
# RUN  2 , total integrated cost =  14.355755698727338
# RUN  3 , total integrated cost =  14.246814502726226
# RUN  3 , total integrated cost =  14.246814502726226
# Improved over  3  iterations in  0.4988350060302764  seconds by  9.467253817596145  percent.
# -------- 1
# interpolate adjoint :  True True True
# initial cost =  62.658932171704265
# RUN  0 , total integrated cost =  62.658932171704265
# Gradient descend method:  None
# RUN  1 , total integrated cost =  21.36680574615829
# RUN  2 , total integrated cost =  18.037770464000154
# RUN  3 , total integrated cost =  18.1270128596654
# RUN  3 , total integrated cost =  18.1270128596654
# Improved over  3  iterations in  0.2820511480094865  seconds by  71.07034507068849  percent.
# interpolate adjoint :  True True True
# initial cost =  20.562706223156795
# RUN  0 , total integrated cost =  20.562706223156795
# Gradient descend method:  None
# RUN  1 , total integrated cost =  16.78244999243106
# RUN  2 , total integrated cost =  16.502025197311458
# RUN  3 , total integrated cost =  16.064084368323805
# RUN  3 , total integrated cost =  16.064084368323805
# Improved over  3  iterations in  0.5290989819914103  seconds by  21.877576842326533  percent.
# rep_ind =  9.648907781194493
# n max =  10
# -------- 0
# interpolate adjoint :  True True True
# initial cost =  62.84651294443642
# RUN  0 , total integrated cost =  62.84651294443642
# Gradient descend method:  None
# RUN  1 , total integrated cost =  18.34103495719853
# RUN  2 , total integrated cost =  14.955775915538695
# RUN  3 , total integrated cost =  15.285214306389644
# RUN  3 , total integrated cost =  15.285214306389644
# Improved over  3  iterations in  0.2929423889145255  seconds by  75.67850054003229  percent.
# interpolate adjoint :  True True True
# initial cost =  15.274374984612638
# RUN  0 , total integrated cost =  15.274374984612638
# Gradient descend method:  None
# RUN  1 , total integrated cost =  13.896411174296249
# RUN  2 , total integrated cost =  14.116973155448044
# RUN  3 , total integrated cost =  13.61108905667319
# RUN  3 , total integrated cost =  13.61108905667319
# Improved over  3  iterations in  0.7586045209318399  seconds by  10.889387812038393  percent.
# -------- 1
# interpolate adjoint :  True True True
# initial cost =  62.02465015689157
# RUN  0 , total integrated cost =  62.02465015689157
# Gradient descend method:  None
# RUN  1 , total integrated cost =  18.111165628313476
# RUN  2 , total integrated cost =  16.11392045661521
# RUN  3 , total integrated cost =  15.116258173981418
# RUN  3 , total integrated cost =  15.116258173981418
# Improved over  3  iterations in  0.3754530190490186  seconds by  75.62862807650701  percent.
# interpolate adjoint :  True True True
# initial cost =  16.71336888668145
# RUN  0 , total integrated cost =  16.71336888668145
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14.24200368311698
# RUN  2 , total integrated cost =  12.99970163059233
# RUN  3 , total integrated cost =  13.048742061003486
# RUN  3 , total integrated cost =  13.048742061003486
# Improved over  3  iterations in  0.6029273450840265  seconds by  21.926320483467777  percent.
# -------- 2
# interpolate adjoint :  True True True
# initial cost =  62.78481071194047
# RUN  0 , total integrated cost =  62.78481071194047
# Gradient descend method:  None
# RUN  1 , total integrated cost =  18.773113063672497
# RUN  2 , total integrated cost =  17.526562045398336
# RUN  3 , total integrated cost =  14.899726034850186
# RUN  3 , total integrated cost =  14.899726034850186
# Improved over  3  iterations in  0.34653898992110044  seconds by  76.26858173832713  percent.
# interpolate adjoint :  True True True
# initial cost =  15.089967321568974
# RUN  0 , total integrated cost =  15.089967321568974
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14.828944562504166
# RUN  2 , total integrated cost =  14.59173013550658
# RUN  3 , total integrated cost =  14.695404846841262
# RUN  3 , total integrated cost =  14.695404846841262
# Improved over  3  iterations in  0.7431853599846363  seconds by  2.6147337917938387  percent.
# -------- 3
# interpolate adjoint :  True True True
# initial cost =  62.643733083729074
# RUN  0 , total integrated cost =  62.643733083729074
# Gradient descend method:  None
# RUN  1 , total integrated cost =  18.046500092522997
# RUN  2 , total integrated cost =  16.609960541559836
# RUN  3 , total integrated cost =  15.480226408703954
# RUN  3 , total integrated cost =  15.480226408703954
# Improved over  3  iterations in  0.3474909790093079  seconds by  75.28846758220297  percent.
# interpolate adjoint :  True True True
# initial cost =  15.948269430947546
# RUN  0 , total integrated cost =  15.948269430947546
# Gradient descend method:  None
# RUN  1 , total integrated cost =  15.230051156663457
# RUN  2 , total integrated cost =  15.260786743514446
# RUN  3 , total integrated cost =  15.280732462650592
# RUN  3 , total integrated cost =  15.280732462650592
# Improved over  3  iterations in  0.6872247300343588  seconds by  4.185638894472149  percent.
# -------- 4
# interpolate adjoint :  True True True
# initial cost =  62.545817697623995
# RUN  0 , total integrated cost =  62.545817697623995
# Gradient descend method:  None
# RUN  1 , total integrated cost =  16.499814347085664
# RUN  2 , total integrated cost =  15.753881864164622
# RUN  3 , total integrated cost =  14.838857435892194
# RUN  3 , total integrated cost =  14.838857435892194
# Improved over  3  iterations in  0.32025009801145643  seconds by  76.27522033906371  percent.
# interpolate adjoint :  True True True
# initial cost =  17.49529781390912
# RUN  0 , total integrated cost =  17.49529781390912
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14.309240340273755
# RUN  2 , total integrated cost =  13.010874098898178
# RUN  3 , total integrated cost =  13.692503849305272
# RUN  3 , total integrated cost =  13.692503849305272
# Improved over  3  iterations in  0.8351765980478376  seconds by  21.73609163475085  percent.
# -------- 5
# interpolate adjoint :  True True True
# initial cost =  62.74739307344197
# RUN  0 , total integrated cost =  62.74739307344197
# Gradient descend method:  None
# RUN  1 , total integrated cost =  20.125724944075422
# RUN  2 , total integrated cost =  15.55617035493086
# RUN  3 , total integrated cost =  13.013815731655772
# RUN  3 , total integrated cost =  13.013815731655772
# Improved over  3  iterations in  0.41224820795468986  seconds by  79.2599897872667  percent.
# interpolate adjoint :  True True True
# initial cost =  14.788468868236315
# RUN  0 , total integrated cost =  14.788468868236315
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12.244667646891706
# RUN  2 , total integrated cost =  11.965673351988373
# RUN  3 , total integrated cost =  11.841409608989178
# RUN  3 , total integrated cost =  11.841409608989178
# Improved over  3  iterations in  0.7089063050225377  seconds by  19.928089145029972  percent.
# -------- 6
# interpolate adjoint :  True True True
# initial cost =  61.55146467707431
# RUN  0 , total integrated cost =  61.55146467707431
# Gradient descend method:  None
# RUN  1 , total integrated cost =  19.093500992212327
# RUN  2 , total integrated cost =  16.124301013610857
# RUN  3 , total integrated cost =  16.63662058703273
# RUN  3 , total integrated cost =  16.63662058703273
# Improved over  3  iterations in  0.3174573329742998  seconds by  72.97120275802426  percent.
# interpolate adjoint :  True True True
# initial cost =  14.626180466964772
# RUN  0 , total integrated cost =  14.626180466964772
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12.002940151875123
# RUN  2 , total integrated cost =  12.122902063269256
# RUN  3 , total integrated cost =  11.330776886656128
# RUN  3 , total integrated cost =  11.330776886656128
# Improved over  3  iterations in  0.688703263993375  seconds by  22.530855459849988  percent.
# -------- 7
# interpolate adjoint :  True True True
# initial cost =  62.028500830996215
# RUN  0 , total integrated cost =  62.028500830996215
# Gradient descend method:  None
# RUN  1 , total integrated cost =  19.015476678887502
# RUN  2 , total integrated cost =  18.38323399948323
# RUN  3 , total integrated cost =  16.223860584842775
# RUN  3 , total integrated cost =  16.223860584842775
# Improved over  3  iterations in  0.28379451809450984  seconds by  73.84450636805403  percent.
# interpolate adjoint :  True True True
# initial cost =  17.303929558889948
# RUN  0 , total integrated cost =  17.303929558889948
# Gradient descend method:  None
# RUN  1 , total integrated cost =  15.024904044245531
# RUN  2 , total integrated cost =  13.901722294372824
# RUN  3 , total integrated cost =  13.3631605408066
# RUN  3 , total integrated cost =  13.3631605408066
# Improved over  3  iterations in  0.48255120194517076  seconds by  22.773838766921955  percent.
# -------- 8
# interpolate adjoint :  True True True
# initial cost =  60.83581229250434
# RUN  0 , total integrated cost =  60.83581229250434
# Gradient descend method:  None
# RUN  1 , total integrated cost =  15.771199790664516
# RUN  2 , total integrated cost =  16.30179540703148
# RUN  3 , total integrated cost =  16.583545244505174
# RUN  3 , total integrated cost =  16.583545244505174
# Improved over  3  iterations in  0.2513211569748819  seconds by  72.74048850573422  percent.
# interpolate adjoint :  True True True
# initial cost =  18.632529856897904
# RUN  0 , total integrated cost =  18.632529856897904
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14.76332844362169
# RUN  2 , total integrated cost =  14.510453350051302
# RUN  3 , total integrated cost =  12.700894917128299
# RUN  3 , total integrated cost =  12.700894917128299
# Improved over  3  iterations in  0.4544545850949362  seconds by  31.834833945395076  percent.
# -------- 9
# interpolate adjoint :  True True True
# initial cost =  62.43502374443342
# RUN  0 , total integrated cost =  62.43502374443342
# Gradient descend method:  None
# RUN  1 , total integrated cost =  19.34636695846027
# RUN  2 , total integrated cost =  16.597649113580893
# RUN  3 , total integrated cost =  15.980906590620762
# RUN  3 , total integrated cost =  15.980906590620762
# Improved over  3  iterations in  0.26131801994051784  seconds by  74.40393927607725  percent.
# interpolate adjoint :  True True True
# initial cost =  16.087179827575557
# RUN  0 , total integrated cost =  16.087179827575557
# Gradient descend method:  None
# RUN  1 , total integrated cost =  15.232950073571516
# RUN  2 , total integrated cost =  14.589459460128241
# RUN  3 , total integrated cost =  14.117855897373643
# RUN  3 , total integrated cost =  14.117855897373643
# Improved over  3  iterations in  0.428917519049719  seconds by  12.241573422497794  percent.
# cost =  15.987699643763154
# -------- 0
# interpolate adjoint :  True True True
# initial cost =  63.47846016849088
# RUN  0 , total integrated cost =  63.47846016849088
# Gradient descend method:  None
# RUN  1 , total integrated cost =  18.347942217756707
# RUN  2 , total integrated cost =  16.010927280130943
# RUN  3 , total integrated cost =  15.490624240918926
# RUN  3 , total integrated cost =  15.490624240918926
# Improved over  3  iterations in  0.6195029609370977  seconds by  75.59703842878015  percent.
# interpolate adjoint :  True True True
# initial cost =  15.577680517452931
# RUN  0 , total integrated cost =  15.577680517452931
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14.837555684398117
# RUN  2 , total integrated cost =  14.134743467963188
# RUN  3 , total integrated cost =  14.00564181867824
# RUN  3 , total integrated cost =  14.00564181867824
# Improved over  3  iterations in  1.1938217199640349  seconds by  10.091609575722188  percent.
# -------- 1
# interpolate adjoint :  True True True
# initial cost =  62.355869599389685
# RUN  0 , total integrated cost =  62.355869599389685
# Gradient descend method:  None
# RUN  1 , total integrated cost =  18.804532972264276
# RUN  2 , total integrated cost =  17.032866908581
# RUN  3 , total integrated cost =  16.30987402202789
# RUN  3 , total integrated cost =  16.30987402202789
# Improved over  3  iterations in  0.7285953660029918  seconds by  73.84388329950012  percent.
# interpolate adjoint :  True True True
# initial cost =  16.303797328134248
# RUN  0 , total integrated cost =  16.303797328134248
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14.087532190162278
# RUN  2 , total integrated cost =  13.56653294269908
# RUN  3 , total integrated cost =  12.968686635180946
# RUN  3 , total integrated cost =  12.968686635180946
# Improved over  3  iterations in  1.5559437120100483  seconds by  20.45603625848655  percent.
# -------- 2
# interpolate adjoint :  True True True
# initial cost =  62.091964586756596
# RUN  0 , total integrated cost =  62.091964586756596
# Gradient descend method:  None
# RUN  1 , total integrated cost =  19.132994142545527
# RUN  2 , total integrated cost =  14.792017743997686
# RUN  3 , total integrated cost =  14.606805191149899
# RUN  3 , total integrated cost =  14.606805191149899
# Improved over  3  iterations in  0.781526539940387  seconds by  76.47553062886121  percent.
# interpolate adjoint :  True True True
# initial cost =  15.192442485777832
# RUN  0 , total integrated cost =  15.192442485777832
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14.566043705897483
# RUN  2 , total integrated cost =  14.480354692317718
# RUN  3 , total integrated cost =  14.108662579251524
# RUN  3 , total integrated cost =  14.108662579251524
# Improved over  3  iterations in  1.500329889007844  seconds by  7.133677863456597  percent.
# -------- 3
# interpolate adjoint :  True True True
# initial cost =  62.69602689182764
# RUN  0 , total integrated cost =  62.69602689182764
# Gradient descend method:  None
# RUN  1 , total integrated cost =  21.18820260436923
# RUN  2 , total integrated cost =  18.01813328818093
# RUN  3 , total integrated cost =  14.83167960335184
# RUN  3 , total integrated cost =  14.83167960335184
# Improved over  3  iterations in  0.8555086590349674  seconds by  76.34350956729423  percent.
# interpolate adjoint :  True True True
# initial cost =  16.02021771450004
# RUN  0 , total integrated cost =  16.02021771450004
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14.30764978288538
# RUN  2 , total integrated cost =  12.412029984915835
# RUN  3 , total integrated cost =  12.329203071416256
# RUN  3 , total integrated cost =  12.329203071416256
# Improved over  3  iterations in  1.4358484590193257  seconds by  23.03972835364786  percent.
# -------- 4
# interpolate adjoint :  True True True
# initial cost =  62.65493031339938
# RUN  0 , total integrated cost =  62.65493031339938
# Gradient descend method:  None
# RUN  1 , total integrated cost =  19.21550730878035
# RUN  2 , total integrated cost =  16.07775542360912
# RUN  3 , total integrated cost =  12.655475855658352
# RUN  3 , total integrated cost =  12.655475855658352
# Improved over  3  iterations in  0.5416967900237069  seconds by  79.80130886371467  percent.
# interpolate adjoint :  True True True
# initial cost =  15.885422346107372
# RUN  0 , total integrated cost =  15.885422346107372
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12.134385641417328
# RUN  2 , total integrated cost =  11.242971147858995
# RUN  3 , total integrated cost =  11.621486443989605
# RUN  3 , total integrated cost =  11.621486443989605
# Improved over  3  iterations in  1.2122071069898084  seconds by  26.841816410141718  percent.
# -------- 5
# interpolate adjoint :  True True True
# initial cost =  60.84742299579602
# RUN  0 , total integrated cost =  60.84742299579602
# Gradient descend method:  None
# RUN  1 , total integrated cost =  17.55016577089617
# RUN  2 , total integrated cost =  16.342985986768472
# RUN  3 , total integrated cost =  14.17828807636906
# RUN  3 , total integrated cost =  14.17828807636906
# Improved over  3  iterations in  0.5781315530184656  seconds by  76.69862193284891  percent.
# interpolate adjoint :  True True True
# initial cost =  14.151254717095881
# RUN  0 , total integrated cost =  14.151254717095881
# Gradient descend method:  None
# RUN  1 , total integrated cost =  13.705764182514127
# RUN  2 , total integrated cost =  13.231577940199632
# RUN  3 , total integrated cost =  13.011060656187249
# RUN  3 , total integrated cost =  13.011060656187249
# Improved over  3  iterations in  1.3462288919836283  seconds by  8.057194105418674  percent.
# -------- 6
# interpolate adjoint :  True True True
# initial cost =  61.94649103073719
# RUN  0 , total integrated cost =  61.94649103073719
# Gradient descend method:  None
# RUN  1 , total integrated cost =  17.924560850305305
# RUN  2 , total integrated cost =  15.811696581366492
# RUN  3 , total integrated cost =  14.949194923487818
# RUN  3 , total integrated cost =  14.949194923487818
# Improved over  3  iterations in  1.120875405962579  seconds by  75.86756784000859  percent.
# interpolate adjoint :  True True True
# initial cost =  15.055360204924717
# RUN  0 , total integrated cost =  15.055360204924717
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14.746454308334558
# RUN  2 , total integrated cost =  14.715214309839373
# RUN  3 , total integrated cost =  14.566097633794433
# RUN  3 , total integrated cost =  14.566097633794433
# Improved over  3  iterations in  1.7197919519385323  seconds by  3.2497566612205304  percent.
# -------- 7
# interpolate adjoint :  True True True
# initial cost =  62.6985488655974
# RUN  0 , total integrated cost =  62.6985488655974
# Gradient descend method:  None
# RUN  1 , total integrated cost =  19.006307190846265
# RUN  2 , total integrated cost =  15.989385957507473
# RUN  3 , total integrated cost =  15.058047960187686
# RUN  3 , total integrated cost =  15.058047960187686
# Improved over  3  iterations in  1.5963022590149194  seconds by  75.98341870325166  percent.
# interpolate adjoint :  True True True
# initial cost =  14.65853668325433
# RUN  0 , total integrated cost =  14.65853668325433
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14.097052370241144
# RUN  2 , total integrated cost =  13.897042893449502
# RUN  3 , total integrated cost =  13.902970925728892
# RUN  3 , total integrated cost =  13.902970925728892
# Improved over  3  iterations in  1.5083405169425532  seconds by  5.154441905436457  percent.
# -------- 8
# interpolate adjoint :  True True True
# initial cost =  62.6453876026892
# RUN  0 , total integrated cost =  62.6453876026892
# Gradient descend method:  None
# RUN  1 , total integrated cost =  20.696178434980503
# RUN  2 , total integrated cost =  17.671856209970056
# RUN  3 , total integrated cost =  15.399840557496333
# RUN  3 , total integrated cost =  15.399840557496333
# Improved over  3  iterations in  0.6806833299342543  seconds by  75.41743910155765  percent.
# interpolate adjoint :  True True True
# initial cost =  15.359338163679567
# RUN  0 , total integrated cost =  15.359338163679567
# Gradient descend method:  None
# RUN  1 , total integrated cost =  13.029015997472618
# RUN  2 , total integrated cost =  12.69392517879213
# RUN  3 , total integrated cost =  12.50974751019913
# RUN  3 , total integrated cost =  12.50974751019913
# Improved over  3  iterations in  1.0815786280436441  seconds by  18.55282189319135  percent.
# -------- 9
# interpolate adjoint :  True True True
# initial cost =  61.72753510185608
# RUN  0 , total integrated cost =  61.72753510185608
# Gradient descend method:  None
# RUN  1 , total integrated cost =  18.14044177786038
# RUN  2 , total integrated cost =  17.624878219403385
# RUN  3 , total integrated cost =  16.01260096833216
# RUN  3 , total integrated cost =  16.01260096833216
# Improved over  3  iterations in  0.6297212620265782  seconds by  74.05922504128846  percent.
# interpolate adjoint :  True True True
# initial cost =  16.182954519092124
# RUN  0 , total integrated cost =  16.182954519092124
# Gradient descend method:  None
# RUN  1 , total integrated cost =  15.696955160736382
# RUN  2 , total integrated cost =  15.355891346918789
# RUN  3 , total integrated cost =  15.603009156784317
# RUN  3 , total integrated cost =  15.603009156784317
# Improved over  3  iterations in  1.2313346799928695  seconds by  3.583680357153611  percent.
# rep_ind =  16.16217962821808
# n max =  30
# -------- 0
# interpolate adjoint :  True True True
# initial cost =  62.83929328526437
# RUN  0 , total integrated cost =  62.83929328526437
# Gradient descend method:  None
# RUN  1 , total integrated cost =  18.309471207387045
# RUN  2 , total integrated cost =  14.271855489605924
# RUN  3 , total integrated cost =  14.52516734691281
# RUN  3 , total integrated cost =  14.52516734691281
# Improved over  3  iterations in  1.8792229739483446  seconds by  76.88521530473845  percent.
# interpolate adjoint :  True True True
# initial cost =  16.029011703164628
# RUN  0 , total integrated cost =  16.029011703164628
# Gradient descend method:  None
# RUN  1 , total integrated cost =  13.65783853928017
# RUN  2 , total integrated cost =  12.798896281177537
# RUN  3 , total integrated cost =  13.417098296888366
# RUN  3 , total integrated cost =  13.417098296888366
# Improved over  3  iterations in  2.2762321509653702  seconds by  16.294912341729642  percent.
# -------- 1
# interpolate adjoint :  True True True
# initial cost =  64.03231515611107
# RUN  0 , total integrated cost =  64.03231515611107
# Gradient descend method:  None
# RUN  1 , total integrated cost =  20.89380053437519
# RUN  2 , total integrated cost =  19.518917632298283
# RUN  3 , total integrated cost =  18.8325580524235
# RUN  3 , total integrated cost =  18.8325580524235
# Improved over  3  iterations in  1.2951039290055633  seconds by  70.5889783830092  percent.
# interpolate adjoint :  True True True
# initial cost =  18.857530505831896
# RUN  0 , total integrated cost =  18.857530505831896
# Gradient descend method:  None
# RUN  1 , total integrated cost =  18.721728081086486
# RUN  2 , total integrated cost =  18.3310659228463
# RUN  3 , total integrated cost =  18.036763592492207
# RUN  3 , total integrated cost =  18.036763592492207
# Improved over  3  iterations in  1.7147554889088497  seconds by  4.352462339041992  percent.
# -------- 2
# interpolate adjoint :  True True True
# initial cost =  61.89332341231296
# RUN  0 , total integrated cost =  61.89332341231296
# Gradient descend method:  None
# RUN  1 , total integrated cost =  18.240918703579915
# RUN  2 , total integrated cost =  13.220155867627245
# RUN  3 , total integrated cost =  11.799754619739314
# RUN  3 , total integrated cost =  11.799754619739314
# Improved over  3  iterations in  1.074161738040857  seconds by  80.9353352361882  percent.
# interpolate adjoint :  True True True
# initial cost =  12.515067289694658
# RUN  0 , total integrated cost =  12.515067289694658
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.366269408424769
# RUN  2 , total integrated cost =  11.40208269871985
# RUN  3 , total integrated cost =  11.392982755116142
# RUN  3 , total integrated cost =  11.392982755116142
# Improved over  3  iterations in  1.765267567941919  seconds by  8.965868969018487  percent.
# -------- 3
# interpolate adjoint :  True True True
# initial cost =  63.335506494653984
# RUN  0 , total integrated cost =  63.335506494653984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  18.882105833600257
# RUN  2 , total integrated cost =  14.5744086564398
# RUN  3 , total integrated cost =  14.587267214743118
# RUN  3 , total integrated cost =  14.587267214743118
# Improved over  3  iterations in  0.5147264109691605  seconds by  76.96826310850707  percent.
# interpolate adjoint :  True True True
# initial cost =  16.584887551679152
# RUN  0 , total integrated cost =  16.584887551679152
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14.201816742467155
# RUN  2 , total integrated cost =  13.572051149275994
# RUN  3 , total integrated cost =  13.486827698658615
# RUN  3 , total integrated cost =  13.486827698658615
# Improved over  3  iterations in  1.7558822249993682  seconds by  18.680017234767874  percent.
# -------- 4
# interpolate adjoint :  True True True
# initial cost =  62.73307688997805
# RUN  0 , total integrated cost =  62.73307688997805
# Gradient descend method:  None
# RUN  1 , total integrated cost =  19.023204589387912
# RUN  2 , total integrated cost =  16.6478767947562
# RUN  3 , total integrated cost =  16.56039429715245
# RUN  3 , total integrated cost =  16.56039429715245
# Improved over  3  iterations in  0.9440294730011374  seconds by  73.60181403791775  percent.
# interpolate adjoint :  True True True
# initial cost =  16.807209463557406
# RUN  0 , total integrated cost =  16.807209463557406
# Gradient descend method:  None
# RUN  1 , total integrated cost =  15.853999908259357
# RUN  2 , total integrated cost =  15.684547764760648
# RUN  3 , total integrated cost =  15.634587723780472
# RUN  3 , total integrated cost =  15.634587723780472
# Improved over  3  iterations in  2.0175830429652706  seconds by  6.976897279227089  percent.
# -------- 5
# interpolate adjoint :  True True True
# initial cost =  61.940338021102384
# RUN  0 , total integrated cost =  61.940338021102384
# Gradient descend method:  None
# RUN  1 , total integrated cost =  20.664803549297176
# RUN  2 , total integrated cost =  19.769020381201855
# RUN  3 , total integrated cost =  19.36756264072747
# RUN  3 , total integrated cost =  19.36756264072747
# Improved over  3  iterations in  0.5701170379761606  seconds by  68.73190676788177  percent.
# interpolate adjoint :  True True True
# initial cost =  19.530743545524587
# RUN  0 , total integrated cost =  19.530743545524587
# Gradient descend method:  None
# RUN  1 , total integrated cost =  19.244499720284875
# RUN  2 , total integrated cost =  19.074919814716583
# RUN  3 , total integrated cost =  18.72752072928691
# RUN  3 , total integrated cost =  18.72752072928691
# Improved over  3  iterations in  2.571089214994572  seconds by  4.11260746097777  percent.
# -------- 6
# interpolate adjoint :  True True True
# initial cost =  62.26587679853462
# RUN  0 , total integrated cost =  62.26587679853462
# Gradient descend method:  None
# RUN  1 , total integrated cost =  18.637363184233347
# RUN  2 , total integrated cost =  17.185334746117285
# RUN  3 , total integrated cost =  16.58696299658108
# RUN  3 , total integrated cost =  16.58696299658108
# Improved over  3  iterations in  0.6994031490758061  seconds by  73.36107054229831  percent.
# interpolate adjoint :  True True True
# initial cost =  17.78421996801909
# RUN  0 , total integrated cost =  17.78421996801909
# Gradient descend method:  None
# RUN  1 , total integrated cost =  15.02486000477502
# RUN  2 , total integrated cost =  13.835729118584442
# RUN  3 , total integrated cost =  10.613757435518682
# RUN  3 , total integrated cost =  10.613757435518682
# Improved over  3  iterations in  1.7284316150471568  seconds by  40.319241132840624  percent.
# -------- 7
# interpolate adjoint :  True True True
# initial cost =  62.865616216419085
# RUN  0 , total integrated cost =  62.865616216419085
# Gradient descend method:  None
# RUN  1 , total integrated cost =  18.83110837550442
# RUN  2 , total integrated cost =  13.98821695697874
# RUN  3 , total integrated cost =  13.364077267455645
# RUN  3 , total integrated cost =  13.364077267455645
# Improved over  3  iterations in  0.6463641949230805  seconds by  78.74183365760877  percent.
# interpolate adjoint :  True True True
# initial cost =  14.446991484008421
# RUN  0 , total integrated cost =  14.446991484008421
# Gradient descend method:  None
# RUN  1 , total integrated cost =  13.039546963644565
# RUN  2 , total integrated cost =  13.383822308388023
# RUN  3 , total integrated cost =  13.016241151116242
# RUN  3 , total integrated cost =  13.016241151116242
# Improved over  3  iterations in  1.8660807510605082  seconds by  9.903448302547261  percent.
# -------- 8
# interpolate adjoint :  True True True
# initial cost =  62.585131164215525
# RUN  0 , total integrated cost =  62.585131164215525
# Gradient descend method:  None
# RUN  1 , total integrated cost =  18.334755444119843
# RUN  2 , total integrated cost =  16.38017662814626
# RUN  3 , total integrated cost =  15.618299569804755
# RUN  3 , total integrated cost =  15.618299569804755
# Improved over  3  iterations in  0.49643726402428  seconds by  75.0447122515022  percent.
# interpolate adjoint :  True True True
# initial cost =  16.21560086791081
# RUN  0 , total integrated cost =  16.21560086791081
# Gradient descend method:  None
# RUN  1 , total integrated cost =  15.218907377186163
# RUN  2 , total integrated cost =  15.114516705948176
# RUN  3 , total integrated cost =  15.091412005967575
# RUN  3 , total integrated cost =  15.091412005967575
# Improved over  3  iterations in  1.46447370108217  seconds by  6.9327610558539305  percent.
# -------- 9
# interpolate adjoint :  True True True
# initial cost =  61.177980919823945
# RUN  0 , total integrated cost =  61.177980919823945
# Gradient descend method:  None
# RUN  1 , total integrated cost =  20.213621728280206
# RUN  2 , total integrated cost =  17.26091867728661
# RUN  3 , total integrated cost =  11.850719622581725
# RUN  3 , total integrated cost =  11.850719622581725
# Improved over  3  iterations in  0.9899522309424356  seconds by  80.62910961688563  percent.
# interpolate adjoint :  True True True
# initial cost =  13.734781696344033
# RUN  0 , total integrated cost =  13.734781696344033
# Gradient descend method:  None
# RUN  1 , total integrated cost =  10.990689420091583
# RUN  2 , total integrated cost =  11.301049645771977
# RUN  3 , total integrated cost =  11.141600251085526
# RUN  3 , total integrated cost =  11.141600251085526
# Improved over  3  iterations in  1.4286786689190194  seconds by  18.880397974936642  percent.
# -------- 10
# interpolate adjoint :  True True True
# initial cost =  63.05544674852067
# RUN  0 , total integrated cost =  63.05544674852067
# Gradient descend method:  None
# RUN  1 , total integrated cost =  20.16479365501563
# RUN  2 , total integrated cost =  18.148363928272573
# RUN  3 , total integrated cost =  17.390797123220462
# RUN  3 , total integrated cost =  17.390797123220462
# Improved over  3  iterations in  0.9056019729468971  seconds by  72.41983362265455  percent.
# interpolate adjoint :  True True True
# initial cost =  17.613942607751106
# RUN  0 , total integrated cost =  17.613942607751106
# Gradient descend method:  None
# RUN  1 , total integrated cost =  17.090024720295606
# RUN  2 , total integrated cost =  16.866681241776
# RUN  3 , total integrated cost =  16.758218617961504
# RUN  3 , total integrated cost =  16.758218617961504
# Improved over  3  iterations in  1.3545579579658806  seconds by  4.8582194733224355  percent.
# -------- 11
# interpolate adjoint :  True True True
# initial cost =  60.72466928402733
# RUN  0 , total integrated cost =  60.72466928402733
# Gradient descend method:  None
# RUN  1 , total integrated cost =  17.902499637965008
# RUN  2 , total integrated cost =  15.615073950206586
# RUN  3 , total integrated cost =  15.481438340915481
# RUN  3 , total integrated cost =  15.481438340915481
# Improved over  3  iterations in  0.8083243769360706  seconds by  74.5055205348189  percent.
# interpolate adjoint :  True True True
# initial cost =  15.634990359531434
# RUN  0 , total integrated cost =  15.634990359531434
# Gradient descend method:  None
# RUN  1 , total integrated cost =  15.419480759083354
# RUN  2 , total integrated cost =  15.260055481662176
# RUN  3 , total integrated cost =  15.088541717347383
# RUN  3 , total integrated cost =  15.088541717347383
# Improved over  3  iterations in  1.2670430039288476  seconds by  3.4950366429290796  percent.
# -------- 12
# interpolate adjoint :  True True True
# initial cost =  63.64917685129917
# RUN  0 , total integrated cost =  63.64917685129917
# Gradient descend method:  None
# RUN  1 , total integrated cost =  18.49141477833084
# RUN  2 , total integrated cost =  18.201991492831475
# RUN  3 , total integrated cost =  18.53316414709031
# RUN  3 , total integrated cost =  18.53316414709031
# Improved over  3  iterations in  0.6386058789212257  seconds by  70.88231920046893  percent.
# interpolate adjoint :  True True True
# initial cost =  18.07517674139026
# RUN  0 , total integrated cost =  18.07517674139026
# Gradient descend method:  None
# RUN  1 , total integrated cost =  17.92065118817751
# RUN  2 , total integrated cost =  17.57749975743594
# RUN  3 , total integrated cost =  17.35863663737957
# RUN  3 , total integrated cost =  17.35863663737957
# Improved over  3  iterations in  2.3784457329893485  seconds by  3.964221840054762  percent.
# -------- 13
# interpolate adjoint :  True True True
# initial cost =  61.943856770322405
# RUN  0 , total integrated cost =  61.943856770322405
# Gradient descend method:  None
# RUN  1 , total integrated cost =  19.336658758860395
# RUN  2 , total integrated cost =  18.521158954975967
# RUN  3 , total integrated cost =  18.206929696887578
# RUN  3 , total integrated cost =  18.206929696887578
# Improved over  3  iterations in  0.7292145150713623  seconds by  70.60736827479784  percent.
# interpolate adjoint :  True True True
# initial cost =  18.177879728641667
# RUN  0 , total integrated cost =  18.177879728641667
# Gradient descend method:  None
# RUN  1 , total integrated cost =  17.803144968577286
# RUN  2 , total integrated cost =  17.879434074681157
# RUN  3 , total integrated cost =  17.800334583919863
# RUN  3 , total integrated cost =  17.800334583919863
# Improved over  3  iterations in  1.4783040380571038  seconds by  2.0769481939465777  percent.
# -------- 14
# interpolate adjoint :  True True True
# initial cost =  62.037384022712665
# RUN  0 , total integrated cost =  62.037384022712665
# Gradient descend method:  None
# RUN  1 , total integrated cost =  23.23862472382236
# RUN  2 , total integrated cost =  17.431753737977267
# RUN  3 , total integrated cost =  16.51821449615892
# RUN  3 , total integrated cost =  16.51821449615892
# Improved over  3  iterations in  0.9976990380091593  seconds by  73.3737733201139  percent.
# interpolate adjoint :  True True True
# initial cost =  17.160251164639057
# RUN  0 , total integrated cost =  17.160251164639057
# Gradient descend method:  None
# RUN  1 , total integrated cost =  15.799919424580194
# RUN  2 , total integrated cost =  12.936094383878551
# RUN  3 , total integrated cost =  12.998695230712942
# RUN  3 , total integrated cost =  12.998695230712942
# Improved over  3  iterations in  1.258325748029165  seconds by  24.251136501437372  percent.
# -------- 15
# interpolate adjoint :  True True True
# initial cost =  61.873916135175854
# RUN  0 , total integrated cost =  61.873916135175854
# Gradient descend method:  None
# RUN  1 , total integrated cost =  18.19692665723143
# RUN  2 , total integrated cost =  17.833320758104016
# RUN  3 , total integrated cost =  15.901994645703539
# RUN  3 , total integrated cost =  15.901994645703539
# Improved over  3  iterations in  0.5396503600059077  seconds by  74.29935643484652  percent.
# interpolate adjoint :  True True True
# initial cost =  16.57216038347765
# RUN  0 , total integrated cost =  16.57216038347765
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14.35463241382391
# RUN  2 , total integrated cost =  11.863761795941352
# RUN  3 , total integrated cost =  11.711825069892202
# RUN  3 , total integrated cost =  11.711825069892202
# Improved over  3  iterations in  0.9792786289472133  seconds by  29.328314481141376  percent.
# -------- 16
# interpolate adjoint :  True True True
# initial cost =  61.71819123940306
# RUN  0 , total integrated cost =  61.71819123940306
# Gradient descend method:  None
# RUN  1 , total integrated cost =  19.459725524696616
# RUN  2 , total integrated cost =  17.17022488124129
# RUN  3 , total integrated cost =  16.68879348010298
# RUN  3 , total integrated cost =  16.68879348010298
# Improved over  3  iterations in  0.49453470995649695  seconds by  72.95968474615914  percent.
# interpolate adjoint :  True True True
# initial cost =  18.19422344027434
# RUN  0 , total integrated cost =  18.19422344027434
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14.637813695557668
# RUN  2 , total integrated cost =  14.339826592524126
# RUN  3 , total integrated cost =  13.508243438157372
# RUN  3 , total integrated cost =  13.508243438157372
# Improved over  3  iterations in  0.9425921720685437  seconds by  25.755317436325328  percent.
# -------- 17
# interpolate adjoint :  True True True
# initial cost =  63.72173276976982
# RUN  0 , total integrated cost =  63.72173276976982
# Gradient descend method:  None
# RUN  1 , total integrated cost =  18.803708745053576
# RUN  2 , total integrated cost =  14.432399638293667
# RUN  3 , total integrated cost =  13.263967870452271
# RUN  3 , total integrated cost =  13.263967870452271
# Improved over  3  iterations in  0.6224625059403479  seconds by  79.18454616045089  percent.
# interpolate adjoint :  True True True
# initial cost =  13.784437495386733
# RUN  0 , total integrated cost =  13.784437495386733
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12.463548591677272
# RUN  2 , total integrated cost =  11.692384607937289
# RUN  3 , total integrated cost =  11.818432558614935
# RUN  3 , total integrated cost =  11.818432558614935
# Improved over  3  iterations in  0.951960513019003  seconds by  14.262496655592699  percent.
# -------- 18
# interpolate adjoint :  True True True
# initial cost =  62.87692182073283
# RUN  0 , total integrated cost =  62.87692182073283
# Gradient descend method:  None
# RUN  1 , total integrated cost =  17.432450356775334
# RUN  2 , total integrated cost =  16.734539369507637
# RUN  3 , total integrated cost =  16.2578497654899
# RUN  3 , total integrated cost =  16.2578497654899
# Improved over  3  iterations in  0.577179942978546  seconds by  74.1433751928214  percent.
# interpolate adjoint :  True True True
# initial cost =  16.252361611784437
# RUN  0 , total integrated cost =  16.252361611784437
# Gradient descend method:  None
# RUN  1 , total integrated cost =  15.989792413243197
# RUN  2 , total integrated cost =  15.503410338781862
# RUN  3 , total integrated cost =  15.213155754158599
# RUN  3 , total integrated cost =  15.213155754158599
# Improved over  3  iterations in  0.9015167790930718  seconds by  6.394183703569084  percent.
# -------- 19
# interpolate adjoint :  True True True
# initial cost =  62.414109473472216
# RUN  0 , total integrated cost =  62.414109473472216
# Gradient descend method:  None
# RUN  1 , total integrated cost =  19.16587375196429
# RUN  2 , total integrated cost =  15.9026988768555
# RUN  3 , total integrated cost =  12.880828552194291
# RUN  3 , total integrated cost =  12.880828552194291
# Improved over  3  iterations in  0.7701246740762144  seconds by  79.36231300765573  percent.
# interpolate adjoint :  True True True
# initial cost =  16.072804985283906
# RUN  0 , total integrated cost =  16.072804985283906
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12.676946296447788
# RUN  2 , total integrated cost =  11.789210700240682
# RUN  3 , total integrated cost =  11.880527953581552
# RUN  3 , total integrated cost =  11.880527953581552
# Improved over  3  iterations in  0.9994642670499161  seconds by  26.083045464315404  percent.
# -------- 20
# interpolate adjoint :  True True True
# initial cost =  62.192034603236046
# RUN  0 , total integrated cost =  62.192034603236046
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22.384361560676208
# RUN  2 , total integrated cost =  20.87078220746593
# RUN  3 , total integrated cost =  19.910052942125542
# RUN  3 , total integrated cost =  19.910052942125542
# Improved over  3  iterations in  0.5456779630621895  seconds by  67.98616885724212  percent.
# interpolate adjoint :  True True True
# initial cost =  24.805083454007175
# RUN  0 , total integrated cost =  24.805083454007175
# Gradient descend method:  None
# RUN  1 , total integrated cost =  21.52817123296073
# RUN  2 , total integrated cost =  17.416967097933558
# RUN  3 , total integrated cost =  15.206275473524638
# RUN  3 , total integrated cost =  15.206275473524638
# Improved over  3  iterations in  1.5427477390039712  seconds by  38.69693886852005  percent.
# -------- 21
# interpolate adjoint :  True True True
# initial cost =  62.44089916480188
# RUN  0 , total integrated cost =  62.44089916480188
# Gradient descend method:  None
# RUN  1 , total integrated cost =  18.319510701452156
# RUN  2 , total integrated cost =  12.649503584534617
# RUN  3 , total integrated cost =  14.552560300617435
# RUN  3 , total integrated cost =  14.552560300617435
# Improved over  3  iterations in  0.9624831679975614  seconds by  76.69386492624251  percent.
# interpolate adjoint :  True True True
# initial cost =  16.6456094749058
# RUN  0 , total integrated cost =  16.6456094749058
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12.08197480080569
# RUN  2 , total integrated cost =  11.75473844990702
# RUN  3 , total integrated cost =  11.380741154089115
# RUN  3 , total integrated cost =  11.380741154089115
# Improved over  3  iterations in  1.1678105930332094  seconds by  31.629171216312457  percent.
# -------- 22
# interpolate adjoint :  True True True
# initial cost =  62.4377745880658
# RUN  0 , total integrated cost =  62.4377745880658
# Gradient descend method:  None
# RUN  1 , total integrated cost =  19.334894713738848
# RUN  2 , total integrated cost =  17.628940504835256
# RUN  3 , total integrated cost =  15.462708050199502
# RUN  3 , total integrated cost =  15.462708050199502
# Improved over  3  iterations in  0.6328774420544505  seconds by  75.2350109333413  percent.
# interpolate adjoint :  True True True
# initial cost =  15.717418866010817
# RUN  0 , total integrated cost =  15.717418866010817
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14.893189420967184
# RUN  2 , total integrated cost =  14.82152037768892
# RUN  3 , total integrated cost =  14.800634717910622
# RUN  3 , total integrated cost =  14.800634717910622
# Improved over  3  iterations in  1.0066669100197032  seconds by  5.832917961375685  percent.
# -------- 23
# interpolate adjoint :  True True True
# initial cost =  61.941184218228656
# RUN  0 , total integrated cost =  61.941184218228656
# Gradient descend method:  None
# RUN  1 , total integrated cost =  18.185653952993427
# RUN  2 , total integrated cost =  17.436043911855265
# RUN  3 , total integrated cost =  16.656833480495553
# RUN  3 , total integrated cost =  16.656833480495553
# Improved over  3  iterations in  0.677564809913747  seconds by  73.10862927352038  percent.
# interpolate adjoint :  True True True
# initial cost =  16.65569278527844
# RUN  0 , total integrated cost =  16.65569278527844
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14.275450561909423
# RUN  2 , total integrated cost =  11.795940457172893
# RUN  3 , total integrated cost =  11.988853543385419
# RUN  3 , total integrated cost =  11.988853543385419
# Improved over  3  iterations in  1.0614236990222707  seconds by  28.01948440126084  percent.
# -------- 24
# interpolate adjoint :  True True True
# initial cost =  62.02597192034571
# RUN  0 , total integrated cost =  62.02597192034571
# Gradient descend method:  None
# RUN  1 , total integrated cost =  20.323938071695366
# RUN  2 , total integrated cost =  15.049682466926773
# RUN  3 , total integrated cost =  15.155002242009886
# RUN  3 , total integrated cost =  15.155002242009886
# Improved over  3  iterations in  0.6469730859389529  seconds by  75.5666831606088  percent.
# interpolate adjoint :  True True True
# initial cost =  15.322854256155964
# RUN  0 , total integrated cost =  15.322854256155964
# Gradient descend method:  None
# RUN  1 , total integrated cost =  15.032879231279356
# RUN  2 , total integrated cost =  14.897365231077007
# RUN  3 , total integrated cost =  14.894543931889414
# RUN  3 , total integrated cost =  14.894543931889414
# Improved over  3  iterations in  1.0880653120111674  seconds by  2.795238518270679  percent.
# -------- 25
# interpolate adjoint :  True True True
# initial cost =  64.39231657456105
# RUN  0 , total integrated cost =  64.39231657456105
# Gradient descend method:  None
# RUN  1 , total integrated cost =  18.4402590345219
# RUN  2 , total integrated cost =  16.689298616477323
# RUN  3 , total integrated cost =  16.123627379016675
# RUN  3 , total integrated cost =  16.123627379016675
# Improved over  3  iterations in  0.6491436449578032  seconds by  74.96032409340822  percent.
# interpolate adjoint :  True True True
# initial cost =  18.525287859142324
# RUN  0 , total integrated cost =  18.525287859142324
# Gradient descend method:  None
# RUN  1 , total integrated cost =  13.773444145425412
# RUN  2 , total integrated cost =  12.186442861436122
# RUN  3 , total integrated cost =  12.373833590098906
# RUN  3 , total integrated cost =  12.373833590098906
# Improved over  3  iterations in  1.0568987529259175  seconds by  33.20571488991813  percent.
# -------- 26
# interpolate adjoint :  True True True
# initial cost =  62.58439080040946
# RUN  0 , total integrated cost =  62.58439080040946
# Gradient descend method:  None
# RUN  1 , total integrated cost =  18.844672277889288
# RUN  2 , total integrated cost =  17.005781343204735
# RUN  3 , total integrated cost =  16.415378275443736
# RUN  3 , total integrated cost =  16.415378275443736
# Improved over  3  iterations in  0.6265103800687939  seconds by  73.7708107956268  percent.
# ...
# Improved over  3  iterations in  0.27668211597483605  seconds by  76.84782587907746  percent.
# interpolate adjoint :  True True True
# initial cost =  15.816501142309756
# RUN  0 , total integrated cost =  15.816501142309756
# Gradient descend method:  None
# RUN  1 , total integrated cost =  15.26944990210266
# RUN  2 , total integrated cost =  13.694820081839804
# RUN  3 , total integrated cost =  13.008848674170029
# RUN  4 , total integrated cost =  12.73272549787258
# RUN  5 , total integrated cost =  12.26815140351681
# RUN  6 , total integrated cost =  12.679909385867052
# RUN  7 , total integrated cost =  11.809974375745782
# RUN  8 , total integrated cost =  12.769057576131459
# RUN  9 , total integrated cost =  12.31365958413755
# RUN  10 , total integrated cost =  12.428226020079759
# RUN  11 , total integrated cost =  12.168001742279191
# RUN  12 , total integrated cost =  11.761155678006968
# RUN  13 , total integrated cost =  12.455189603174544
# RUN  14 , total integrated cost =  11.537617830894014
# RUN  15 , total integrated cost =  11.907341030659218
# RUN  15 , total integrated cost =  11.907341030659218
# Improved over  15  iterations in  2.491983358981088  seconds by  24.71570720020614  percent.
# -------- 3
# interpolate adjoint :  True True True
# initial cost =  63.775612025984444
# RUN  0 , total integrated cost =  63.775612025984444
# Gradient descend method:  None
# RUN  1 , total integrated cost =  17.7611482102428
# RUN  2 , total integrated cost =  16.50947439086127
# RUN  3 , total integrated cost =  15.382879214875592
# RUN  3 , total integrated cost =  15.382879214875592
# Improved over  3  iterations in  0.26866277994122356  seconds by  75.8796839007863  percent.
# interpolate adjoint :  True True True
# initial cost =  15.846180800226566
# RUN  0 , total integrated cost =  15.846180800226566
# Gradient descend method:  None
# RUN  1 , total integrated cost =  15.060309141649517
# RUN  2 , total integrated cost =  14.940385273890271
# RUN  3 , total integrated cost =  14.680255128478525
# RUN  4 , total integrated cost =  14.657928859945287
# RUN  5 , total integrated cost =  14.617088836988977
# RUN  6 , total integrated cost =  14.65612689015497
# RUN  7 , total integrated cost =  14.6112145909069
# RUN  8 , total integrated cost =  14.654276618707726
# RUN  9 , total integrated cost =  14.672414640337095
# RUN  10 , total integrated cost =  14.575416049231897
# RUN  11 , total integrated cost =  14.651089267601007
# RUN  12 , total integrated cost =  14.631003756285319
# RUN  13 , total integrated cost =  14.56882838530251
# Control only changes marginally.
# RUN  13 , total integrated cost =  14.56882838530251
# Improved over  13  iterations in  2.189116002060473  seconds by  8.060948130200515  percent.
# -------- 4
# interpolate adjoint :  True True True
# initial cost =  62.365146796900106
# RUN  0 , total integrated cost =  62.365146796900106
# Gradient descend method:  None
# RUN  1 , total integrated cost =  17.394981227281356
# RUN  2 , total integrated cost =  16.03146803927355
# RUN  3 , total integrated cost =  14.77469257971358
# RUN  3 , total integrated cost =  14.77469257971358
# Improved over  3  iterations in  0.2699457100825384  seconds by  76.30937576747921  percent.
# interpolate adjoint :  True True True
# initial cost =  15.714241270116133
# RUN  0 , total integrated cost =  15.714241270116133
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12.87311363006875
# RUN  2 , total integrated cost =  12.147267044220705
# RUN  3 , total integrated cost =  12.302067890044304
# RUN  4 , total integrated cost =  11.26619946048175
# RUN  5 , total integrated cost =  12.349225983097556
# RUN  6 , total integrated cost =  12.829670855896529
# RUN  7 , total integrated cost =  12.007903742103252
# RUN  8 , total integrated cost =  11.102238463586872
# RUN  9 , total integrated cost =  12.120702406719417
# RUN  10 , total integrated cost =  11.567030685701987
# RUN  11 , total integrated cost =  11.500891909401094
# RUN  12 , total integrated cost =  11.67203312036626
# RUN  13 , total integrated cost =  11.602343718391289
# RUN  14 , total integrated cost =  11.670007477486536
# RUN  15 , total integrated cost =  10.879255227780096
# RUN  15 , total integrated cost =  10.879255227780096
# Improved over  15  iterations in  2.297524848021567  seconds by  30.768180017260903  percent.
# -------- 5
# interpolate adjoint :  True True True
# initial cost =  62.26166239663472
# RUN  0 , total integrated cost =  62.26166239663472
# Gradient descend method:  None
# RUN  1 , total integrated cost =  18.793917257064912
# RUN  2 , total integrated cost =  17.312228609592484
# RUN  3 , total integrated cost =  16.73627685660403
# RUN  3 , total integrated cost =  16.73627685660403
# Improved over  3  iterations in  0.2713878690265119  seconds by  73.11945069827009  percent.
# interpolate adjoint :  True True True
# initial cost =  16.944245048509128
# RUN  0 , total integrated cost =  16.944245048509128
# Gradient descend method:  None
# RUN  1 , total integrated cost =  15.955263142453985
# RUN  2 , total integrated cost =  15.578218029398545
# RUN  3 , total integrated cost =  14.03189963301586
# RUN  4 , total integrated cost =  13.477006820186574
# RUN  5 , total integrated cost =  13.44483124508076
# RUN  6 , total integrated cost =  13.412049551093059
# RUN  7 , total integrated cost =  13.420156847815338
# RUN  8 , total integrated cost =  13.47131807362581
# RUN  9 , total integrated cost =  13.440996192266141
# RUN  10 , total integrated cost =  13.413509166880658
# RUN  11 , total integrated cost =  13.403755973933237
# RUN  12 , total integrated cost =  13.27051183278728
# RUN  13 , total integrated cost =  13.29926805893019
# RUN  14 , total integrated cost =  13.286934930449668
# RUN  15 , total integrated cost =  13.280479443322982
# RUN  15 , total integrated cost =  13.280479443322982
# Improved over  15  iterations in  2.612884698086418  seconds by  21.622477689016364  percent.
# -------- 6
# interpolate adjoint :  True True True
# initial cost =  62.51795077629636
# RUN  0 , total integrated cost =  62.51795077629636
# Gradient descend method:  None
# RUN  1 , total integrated cost =  20.925523528556074
# RUN  2 , total integrated cost =  15.900070038979024
# RUN  3 , total integrated cost =  15.365240442021117
# RUN  3 , total integrated cost =  15.365240442021117
# Improved over  3  iterations in  0.25264494004659355  seconds by  75.42267420600287  percent.
# interpolate adjoint :  True True True
# initial cost =  16.214589908990106
# RUN  0 , total integrated cost =  16.214589908990106
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14.81983544616438
# RUN  2 , total integrated cost =  12.341031199716559
# RUN  3 , total integrated cost =  12.082995564670806
# RUN  4 , total integrated cost =  12.216110095355097
# RUN  5 , total integrated cost =  12.291546010725567
# RUN  6 , total integrated cost =  12.212061062134689
# RUN  7 , total integrated cost =  12.123403538668217
# RUN  8 , total integrated cost =  12.206138311456725
# RUN  9 , total integrated cost =  12.402745602160213
# RUN  10 , total integrated cost =  12.231244099078172
# RUN  11 , total integrated cost =  12.065906656838045
# RUN  12 , total integrated cost =  12.054980383514648
# RUN  13 , total integrated cost =  12.312666467413733
# RUN  14 , total integrated cost =  12.148792917903748
# RUN  15 , total integrated cost =  12.085316091342477
# RUN  15 , total integrated cost =  12.085316091342477
# Improved over  15  iterations in  2.2809289370197803  seconds by  25.466409208155  percent.
# -------- 7
# interpolate adjoint :  True True True
# initial cost =  61.695826980986624
# RUN  0 , total integrated cost =  61.695826980986624
# Gradient descend method:  None
# RUN  1 , total integrated cost =  19.216732360857208
# RUN  2 , total integrated cost =  12.926947353317583
# RUN  3 , total integrated cost =  15.576846640737335
# RUN  3 , total integrated cost =  15.576846640737335
# Improved over  3  iterations in  0.2630985779687762  seconds by  74.75218762277424  percent.
# interpolate adjoint :  True True True
# initial cost =  15.663313452320104
# RUN  0 , total integrated cost =  15.663313452320104
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12.946459904305481
# RUN  2 , total integrated cost =  13.18372688757975
# RUN  3 , total integrated cost =  12.995969275845503
# RUN  4 , total integrated cost =  13.35002267388205
# RUN  5 , total integrated cost =  12.417997645921105
# RUN  6 , total integrated cost =  12.742260438521436
# RUN  7 , total integrated cost =  13.281057895584851
# RUN  8 , total integrated cost =  12.61507321153242
# RUN  9 , total integrated cost =  13.73501514696408
# RUN  10 , total integrated cost =  13.5673413163421
# RUN  11 , total integrated cost =  12.498603943924632
# RUN  12 , total integrated cost =  12.726016309923173
# RUN  13 , total integrated cost =  12.37170029551169
# RUN  14 , total integrated cost =  13.262966086746601
# RUN  15 , total integrated cost =  13.3369235423607
# RUN  15 , total integrated cost =  13.3369235423607
# Improved over  15  iterations in  2.5898812679806724  seconds by  14.852476246747202  percent.
# -------- 8
# interpolate adjoint :  True True True
# initial cost =  61.58241961340139
# RUN  0 , total integrated cost =  61.58241961340139
# Gradient descend method:  None
# RUN  1 , total integrated cost =  18.752158437623045
# RUN  2 , total integrated cost =  14.898189393731766
# RUN  3 , total integrated cost =  13.863237906772357
# RUN  3 , total integrated cost =  13.863237906772357
# Improved over  3  iterations in  0.27360569196753204  seconds by  77.48831891666129  percent.
# interpolate adjoint :  True True True
# initial cost =  15.759470383880437
# RUN  0 , total integrated cost =  15.759470383880437
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12.05676428122123
# RUN  2 , total integrated cost =  11.64567328513353
# RUN  3 , total integrated cost =  11.103488416613148
# RUN  4 , total integrated cost =  11.595400655150412
# RUN  5 , total integrated cost =  10.952202617963543
# RUN  6 , total integrated cost =  11.20600630533506
# RUN  7 , total integrated cost =  11.304206931220062
# RUN  8 , total integrated cost =  11.363799356726464
# RUN  9 , total integrated cost =  10.756356795044052
# RUN  10 , total integrated cost =  10.99165027774926
# Control only changes marginally.
# RUN  10 , total integrated cost =  10.99165027774926
# Improved over  10  iterations in  2.10820697597228  seconds by  30.253682325568107  percent.
# -------- 9
# interpolate adjoint :  True True True
# initial cost =  62.90881169934569
# RUN  0 , total integrated cost =  62.90881169934569
# Gradient descend method:  None
# RUN  1 , total integrated cost =  19.066978440993154
# RUN  2 , total integrated cost =  16.137728259556336
# RUN  3 , total integrated cost =  12.406172087745151
# RUN  3 , total integrated cost =  12.406172087745151
# Improved over  3  iterations in  0.25279583502560854  seconds by  80.27911869161218  percent.
# interpolate adjoint :  True True True
# initial cost =  16.196330977129172
# RUN  0 , total integrated cost =  16.196330977129172
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12.246409063819417
# RUN  2 , total integrated cost =  12.204968720686015
# RUN  3 , total integrated cost =  12.200391285656082
# RUN  4 , total integrated cost =  12.434483917970729
# RUN  5 , total integrated cost =  12.226173183182125
# RUN  6 , total integrated cost =  12.141964513454564
# RUN  7 , total integrated cost =  12.184843121466193
# RUN  8 , total integrated cost =  12.59984206239843
# RUN  9 , total integrated cost =  12.411135361486695
# RUN  10 , total integrated cost =  11.88591306381096
# RUN  11 , total integrated cost =  12.135152317117813
# RUN  12 , total integrated cost =  11.94359669186673
# RUN  13 , total integrated cost =  11.890117752622807
# RUN  14 , total integrated cost =  11.876751316324878
# RUN  15 , total integrated cost =  11.673137067143008
# RUN  15 , total integrated cost =  11.673137067143008
# Improved over  15  iterations in  2.4902535709552467  seconds by  27.927275111711182  percent.
# -------- 10
# interpolate adjoint :  True True True
# initial cost =  62.08645659374208
# RUN  0 , total integrated cost =  62.08645659374208
# Gradient descend method:  None
# RUN  1 , total integrated cost =  19.345700731814848
# RUN  2 , total integrated cost =  12.790976866366657
# RUN  3 , total integrated cost =  12.469634848519457
# RUN  3 , total integrated cost =  12.469634848519457
# Improved over  3  iterations in  0.26906189403962344  seconds by  79.91569251549731  percent.
# interpolate adjoint :  True True True
# initial cost =  13.197972683258229
# RUN  0 , total integrated cost =  13.197972683258229
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12.032021298029177
# RUN  2 , total integrated cost =  11.724841590982557
# RUN  3 , total integrated cost =  11.748343711132708
# RUN  4 , total integrated cost =  11.415023426160573
# RUN  5 , total integrated cost =  11.752887985790545
# RUN  6 , total integrated cost =  11.876673322366365
# RUN  7 , total integrated cost =  12.058685448076634
# RUN  8 , total integrated cost =  11.732912183086848
# RUN  9 , total integrated cost =  11.808447116730875
# RUN  10 , total integrated cost =  11.772916082663043
# RUN  11 , total integrated cost =  11.643796390431557
# RUN  12 , total integrated cost =  11.473747167984502
# RUN  13 , total integrated cost =  11.435967074834767
# Control only changes marginally.
# RUN  13 , total integrated cost =  11.435967074834767
# Improved over  13  iterations in  2.3175442739157006  seconds by  13.350577779711458  percent.
# -------- 11
# interpolate adjoint :  True True True
# initial cost =  63.14183307136821
# RUN  0 , total integrated cost =  63.14183307136821
# Gradient descend method:  None
# RUN  1 , total integrated cost =  20.5463437157739
# RUN  2 , total integrated cost =  17.44402999378284
# RUN  3 , total integrated cost =  16.024028066185178
# RUN  3 , total integrated cost =  16.024028066185178
# Improved over  3  iterations in  0.2518272080924362  seconds by  74.62216839971454  percent.
# interpolate adjoint :  True True True
# initial cost =  17.36100165870678
# RUN  0 , total integrated cost =  17.36100165870678
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14.880410977043494
# RUN  2 , total integrated cost =  14.211538407413705
# RUN  3 , total integrated cost =  13.76466079213828
# RUN  4 , total integrated cost =  14.367375801651141
# RUN  5 , total integrated cost =  14.052725502889919
# RUN  6 , total integrated cost =  13.268248611346145
# RUN  7 , total integrated cost =  13.535580150000818
# RUN  8 , total integrated cost =  13.267650216662272
# RUN  9 , total integrated cost =  13.23840563396898
# RUN  10 , total integrated cost =  13.15648713110074
# RUN  11 , total integrated cost =  12.6153805394256
# RUN  12 , total integrated cost =  12.881491508772566
# RUN  13 , total integrated cost =  12.48911497139297
# RUN  14 , total integrated cost =  12.660268172829905
# RUN  15 , total integrated cost =  12.757860728806547
# RUN  15 , total integrated cost =  12.757860728806547
# Improved over  15  iterations in  2.6841230449499562  seconds by  26.514258914270044  percent.
# -------- 12
# interpolate adjoint :  True True True
# initial cost =  61.38905923265764
# RUN  0 , total integrated cost =  61.38905923265764
# Gradient descend method:  None
# RUN  1 , total integrated cost =  18.403682827711165
# RUN  2 , total integrated cost =  18.941603551186695
# RUN  3 , total integrated cost =  18.789556470962403
# RUN  3 , total integrated cost =  18.789556470962403
# Improved over  3  iterations in  0.25683809898328036  seconds by  69.3926626245369  percent.
# interpolate adjoint :  True True True
# initial cost =  18.291676682505226
# RUN  0 , total integrated cost =  18.291676682505226
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14.462107372120993
# RUN  2 , total integrated cost =  13.23087574346767
# RUN  3 , total integrated cost =  13.405766449220891
# RUN  4 , total integrated cost =  12.47584764089641
# RUN  5 , total integrated cost =  12.477632417317857
# RUN  6 , total integrated cost =  12.321048455856896
# RUN  7 , total integrated cost =  12.508644275864828

# %%
#len(sigma_array), 4, N_max, max_it

##### METHOD 2
method_ind = 1
step_method_ind = 0

for d in dict_list:
        
    print("Point = ", d['point'])
    aln.params.ext_exc_current = d['point'][0] * 5.
    aln.params.ext_inh_current = d['point'][1] * 5.
    
    max_it = d['cost'].shape[3]
    
    for s_ind in range(len(d['sigma'])):
        
        print("sigma = ", d['sigma'][s_ind])
        
        s = d['sigma'][s_ind]
        aln.params.sigma_ou = s
        c_p = d['cost_params'][s_ind]
        cost.setParams(c_p[0], c_p[1], c_p[2])
        
        target_ = d['target'][s_ind].copy()
        target_[0,0,:int(trans_time * dur / aln.params.dt)] = -1000
        target_[0,1,:int(trans_time * dur / aln.params.dt)] = -1000
                
        for n_ind in range(len(d['N_array'])):
            
            n_ = d['N_array'][n_ind]
            
            print("n = ", n_)
            aln.params.duration = dur
        
            for i_it in range(1,len(d['it_array'])):
            
                it = d['it_array'][i_it]
                print("iteration = ", it)
                
                if ( d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it] > 0.
                    and d['rep_ind'][s_ind, method_ind, step_method_ind, n_ind, i_it] > 0. ) :
                    continue
                
                c_vars = d['init']
                aln.params.duration = dur
                setinit(d['init_vars'], aln)
                control_init = aln.getZeroControl()
                    
                
                bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                    control_init, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_ = init_it,
                    tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                    t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                    control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                    noise_real=n_, init_params = d['init_vars'], method='M2')
            
                control_init = bc[:,:,100:-100]
                c_vars = [0,1]
                aln.params.duration = dur
                setinit(d['init_vars'], aln)
                
                bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                    control_init, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_=it-init_it,
                    tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                    t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                    control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                    noise_real=n_, init_params = d['init_vars'], method='M2')

                control_init = bc[:,:,100:-100]
                aln.params.duration = dur
                setinit(d['init_vars'], aln)
                cost_final = 0.
                cs = cost.numba_cost_sparsity_int(1, 6, T, d['cost_params'][s_ind][2], dt, control_init)

                for j in range(noise_realizations_final):
                    state_ = fo.updateState(aln, control_init)
                    cost_final += cost.numba_cost_precision_int(1, T, dt, d['cost_params'][s_ind][0],
                                                                   state_, target_, list(prec_vars) )

                d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it] = (
                                cost_final / noise_realizations_final + cs )
                print('cost = ', d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it])
                
                c_vars = d['init']                    
                aln.params.duration = dur
                control_init1 = aln.getZeroControl()
                setinit(d['init_vars'], aln)
                
                bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                    control_init1, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_ = init_it,
                    tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                    t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                    control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                    noise_real=n_, init_params = d['init_vars'], method='M2')
            
                control_init1 = bc[:,:,100:-100]
                c_vars = [0,1]
                aln.params.duration = dur
                setinit(d['init_vars'], aln)
                
                bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                    control_init1, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_=it-init_it,
                    tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                    t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                    control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                    noise_real=n_, init_params = d['init_vars'], method='M2')

                control_init1 = bc[:,:,100:-100]
                d['rep_ind'][s_ind, method_ind, step_method_ind, n_ind, i_it] = rep_ind(control_init, control_init1)
                print('rep_ind = ', d['rep_ind'][s_ind, method_ind, step_method_ind, n_ind, i_it])
                
                file=open(dict_file, "wb")
                pickle.dump(dict_list, file)
                file.close()
                
    break
# Out:
# Point =  [0.74 0.37]
# sigma =  0.01
# set cost params:  0.00029840237860574134 0.0 1.0
# n =  2
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24
# n =  10
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24
# n =  30
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24
# n =  50
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24
# sigma =  0.03
# set cost params:  0.00029840237860574134 0.0 1.0
# n =  2
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24
# n =  10
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24
# n =  30
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24
# n =  50
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24
# sigma =  0.049999999999999996
# set cost params:  0.00029840237860574134 0.0 1.0
# n =  2
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24
# n =  10
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24
# n =  30
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24
# n =  50
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24
# sigma =  0.06999999999999999
# set cost params:  0.00029840237860574134 0.0 1.0
# n =  2
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24
# n =  10
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24
# n =  30
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24
# n =  50
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24

# %%
#len(sigma_array), 4, N_max, max_it

##### METHOD 3
method_ind = 2
step_method_ind = 0

for d in dict_list:
        
    print("Point = ", d['point'])
    aln.params.ext_exc_current = d['point'][0] * 5.
    aln.params.ext_inh_current = d['point'][1] * 5.
    
    max_it = d['cost'].shape[3]
    
    for s_ind in range(len(d['sigma'])):
        
        print("sigma = ", d['sigma'][s_ind])
        
        s = d['sigma'][s_ind]
        aln.params.sigma_ou = s
        c_p = d['cost_params'][s_ind]
        cost.setParams(c_p[0], c_p[1], c_p[2])
        
        target_ = d['target'][s_ind].copy()
        target_[0,0,:int(trans_time * dur / aln.params.dt)] = -1000
        target_[0,1,:int(trans_time * dur / aln.params.dt)] = -1000
                
        for n_ind in range(len(d['N_array'])):
            
            n_ = d['N_array'][n_ind]
            
            print("n = ", n_)
            aln.params.duration = dur
        
            for i_it in range(1,len(d['it_array'])):
                
                print('cost = ', d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it])
            
                it = d['it_array'][i_it]
                print("iteration = ", it)
                
                if d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it] > 0.:
                    continue
                
                c_vars = d['init']
                aln.params.duration = dur
                setinit(d['init_vars'], aln)
                control_init = aln.getZeroControl()
                    
                
                bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                    control_init, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_ = init_it,
                    tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                    t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                    control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                    noise_real=n_, init_params = d['init_vars'], method='M3')
            
                control_init = bc[:,:,100:-100]
                c_vars = [0,1]
                aln.params.duration = dur
                setinit(d['init_vars'], aln)
                
                bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                    control_init, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_=it-init_it,
                    tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                    t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                    control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                    noise_real=n_, init_params = d['init_vars'], method='M3')

                control_init = bc[:,:,100:-100]
                aln.params.duration = dur
                setinit(d['init_vars'], aln)
                cost_final = 0.
                cs = cost.numba_cost_sparsity_int(1, 6, T, d['cost_params'][s_ind][2], dt, control_init)

                for j in range(noise_realizations_final):
                    state_ = fo.updateState(aln, control_init)
                    cost_final += cost.numba_cost_precision_int(1, T, dt, d['cost_params'][s_ind][0],
                                                                   state_, target_, list(prec_vars) )

                d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it] = (
                                cost_final / noise_realizations_final + cs )
                print('cost = ', d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it])
                
                c_vars = d['init']                    
                aln.params.duration = dur
                control_init1 = aln.getZeroControl()
                setinit(d['init_vars'], aln)
                
                bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                    control_init1, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_ = init_it,
                    tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                    t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                    control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                    noise_real=n_, init_params = d['init_vars'], method='M3')
            
                control_init1 = bc[:,:,100:-100]
                c_vars = [0,1]
                aln.params.duration = dur
                setinit(d['init_vars'], aln)
                
                bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                    control_init1, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_=it-init_it,
                    tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                    t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                    control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                    noise_real=n_, init_params = d['init_vars'], method='M3')

                control_init1 = bc[:,:,100:-100]
                d['rep_ind'][s_ind, method_ind, step_method_ind, n_ind, i_it] = rep_ind(control_init, control_init1)
                print('rep_ind = ', d['rep_ind'][s_ind, method_ind, step_method_ind, n_ind, i_it])
                
                file=open(dict_file, "wb")
                pickle.dump(dict_list, file)
                file.close()
                
    break
# Out:
# Point =  [0.74 0.37]
# sigma =  0.01
# set cost params:  0.00029840237860574134 0.0 1.0
# n =  2
# cost =  4.451636574757886
# iteration =  6
# cost =  4.092602556338586
# iteration =  12
# cost =  3.777841584067803
# iteration =  18
# cost =  3.8938370991084956
# iteration =  24
# n =  10
# cost =  4.351254041821601
# iteration =  6
# cost =  3.7960881412512038
# iteration =  12
# cost =  3.778611885812909
# iteration =  18
# cost =  3.7728302899257695
# iteration =  24
# n =  30
# cost =  4.116359151183409
# iteration =  6
# cost =  3.8939746277773413
# iteration =  12
# cost =  3.7811660595532195
# iteration =  18
# cost =  3.7630339604489778
# iteration =  24
# n =  50
# cost =  4.962693085957955
# iteration =  6
# cost =  3.783722340483288
# iteration =  12
# cost =  3.7798722636448634
# iteration =  18
# cost =  3.756070998322329
# iteration =  24
# sigma =  0.03
# set cost params:  0.00029840237860574134 0.0 1.0
# n =  2
# cost =  42.34366603392382
# iteration =  6
# cost =  23.639396272912688
# iteration =  12
# cost =  5.758954178549303
# iteration =  18
# cost =  9.22730654494644
# iteration =  24
# n =  10
# cost =  24.724666600334746
# iteration =  6
# cost =  5.573095696884735
# iteration =  12
# cost =  7.0333680373454595
# iteration =  18
# cost =  7.451133942320042
# iteration =  24
# n =  30
# cost =  11.402200037497852
# iteration =  6
# cost =  12.387753537671585
# iteration =  12
# cost =  54.8873214736335
# iteration =  18
# cost =  5.449419894637215
# iteration =  24
# n =  50
# cost =  14.616568653797167
# iteration =  6
# cost =  5.152422478589676
# iteration =  12
# cost =  5.685293295347801
# iteration =  18
# cost =  5.0956332331477645
# iteration =  24
# sigma =  0.049999999999999996
# set cost params:  0.00029840237860574134 0.0 1.0
# n =  2
# cost =  13.18671753213472
# iteration =  6
# cost =  14.759297577004787
# iteration =  12
# cost =  27.373701673237623
# iteration =  18
# cost =  7.684504381799515
# iteration =  24
# n =  10
# cost =  61.68334620690602
# iteration =  6
# cost =  7.222368273475246
# iteration =  12
# cost =  9.723419958654276
# iteration =  18
# cost =  13.02943457709917
# iteration =  24
# n =  30
# cost =  10.203342684828435
# iteration =  6
# cost =  44.83762907500059
# iteration =  12
# cost =  10.60949761165747
# iteration =  18
# cost =  13.099283023682622
# iteration =  24
# n =  50
# cost =  19.58553892239925
# iteration =  6
# cost =  19.352276087289393
# iteration =  12
# cost =  14.622859056836162
# iteration =  18
# cost =  11.129393600649468
# iteration =  24
# sigma =  0.06999999999999999
# set cost params:  0.00029840237860574134 0.0 1.0
# n =  2
# cost =  38.36899289997595
# iteration =  6
# cost =  15.055249051235892
# iteration =  12
# cost =  12.630226146574433
# iteration =  18
# cost =  16.837580467245175
# iteration =  24
# n =  10
# cost =  32.9733645809119
# iteration =  6
# cost =  9.160409496375133
# iteration =  12
# cost =  9.686500212316004
# iteration =  18
# cost =  9.851002476028848
# iteration =  24
# n =  30
# cost =  11.870930715248077
# iteration =  6
# cost =  9.741359330582283
# iteration =  12
# cost =  45.91134334624863
# iteration =  18
# cost =  10.08020602939881
# iteration =  24
# n =  50
# cost =  32.940566192731
# iteration =  6
# cost =  10.453183277219864
# iteration =  12
# cost =  56.96714174732361
# iteration =  18
# cost =  9.741756838619569
# iteration =  24

# %%
#len(sigma_array), 4, N_max, max_it

##### METHOD 4
method_ind = 3
step_method_ind = 0
step_m = 'S1'

for d in dict_list:
        
    print("Point = ", d['point'])
    aln.params.ext_exc_current = d['point'][0] * 5.
    aln.params.ext_inh_current = d['point'][1] * 5.
    
    max_it = d['cost'].shape[3]
    
    for s_ind in range(len(d['sigma'])):
        
        print("sigma = ", d['sigma'][s_ind])
        
        s = d['sigma'][s_ind]
        aln.params.sigma_ou = s
        c_p = d['cost_params'][s_ind]
        cost.setParams(c_p[0], c_p[1], c_p[2])
        
        target_ = d['target'][s_ind].copy()
        target_[0,0,:int(trans_time * dur / aln.params.dt)] = -1000
        target_[0,1,:int(trans_time * dur / aln.params.dt)] = -1000
                
        for n_ind in range(len(d['N_array'])):
            
            n_ = d['N_array'][n_ind]
            
            print("n = ", n_)
            aln.params.duration = dur
        
            for i_it in range(1,len(d['it_array'])):
            
                it = d['it_array'][i_it]
                print("iteration = ", it)
                
                if ( d['rep_ind'][s_ind, method_ind, step_method_ind, n_ind, i_it] > 0.
                    and d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it] > 0. ):
                    continue
                
                c_vars = d['init']
                aln.params.duration = dur
                setinit(d['init_vars'], aln)
                control_init = aln.getZeroControl()
                    
                bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                    control_init, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_ = init_it,
                    tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                    t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                    control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                    noise_real=n_, init_params = d['init_vars'], method='M4', method_step=step_m)
                            
                control_init = bc[:,:,100:-100]
                c_vars = [0,1]
                aln.params.duration = dur
                setinit(d['init_vars'], aln)

                bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                    control_init, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_=it-init_it,
                    tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                    t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                    control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                    noise_real=n_, init_params = d['init_vars'], method='M4', method_step=step_m)

                
                control_init = bc[:,:,100:-100]
                aln.params.duration = dur
                setinit(d['init_vars'], aln)
                cost_final = 0.
                cs = cost.numba_cost_sparsity_int(1, 6, T, d['cost_params'][s_ind][2], dt, control_init)

                for j in range(noise_realizations_final):
                    state_ = fo.updateState(aln, control_init)
                    cost_final += cost.numba_cost_precision_int(1, T, dt, d['cost_params'][s_ind][0],
                                                                   state_, target_, list(prec_vars) )

                d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it] = (
                                cost_final / noise_realizations_final + cs )
                print('cost = ', d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it])
                
                c_vars = d['init']                    
                aln.params.duration = dur
                control_init1 = aln.getZeroControl()
                setinit(d['init_vars'], aln)
                
                bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                    control_init1, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_ = init_it,
                    tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                    t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                    control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                    noise_real=n_, init_params = d['init_vars'], method='M4', method_step=step_m)
                            
                control_init1 = bc[:,:,100:-100]
                c_vars = [0,1]
                aln.params.duration = dur
                setinit(d['init_vars'], aln)

                bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                    control_init1, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_=it-init_it,
                    tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                    t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                    control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                    noise_real=n_, init_params = d['init_vars'], method='M4', method_step=step_m)
                                

                control_init1 = bc[:,:,100:-100]
                d['rep_ind'][s_ind, method_ind, step_method_ind, n_ind, i_it] = rep_ind(control_init, control_init1)
                print('rep_ind = ', d['rep_ind'][s_ind, method_ind, step_method_ind, n_ind, i_it])
                
                file=open(dict_file, "wb")
                pickle.dump(dict_list, file)
                file.close()
                
    break
# Out:
# Point =  [0.74 0.37]
# sigma =  0.01
# set cost params:  0.00029840237860574134 0.0 1.0
# n =  2
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24
# n =  10
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24
# n =  30
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24
# n =  50
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24
# sigma =  0.03
# set cost params:  0.00029840237860574134 0.0 1.0
# n =  2
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24
# n =  10
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24
# n =  30
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24
# n =  50
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24
# sigma =  0.049999999999999996
# set cost params:  0.00029840237860574134 0.0 1.0
# n =  2
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24
# n =  10
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24
# n =  30
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24
# n =  50
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24
# sigma =  0.06999999999999999
# set cost params:  0.00029840237860574134 0.0 1.0
# n =  2
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24
# n =  10
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24
# n =  30
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24
# n =  50
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24

# %%
for s_ind in range(len(d['sigma'])):
    for n_ind in range(len(d['N_array'])):
        for i_it in range(1,len(d['it_array'])):
            #d['cost'][s_ind, 3, 0, n_ind, i_it] = 0.
# Out:
#   File "/tmp/ipykernel_490995/2703670148.py", line 4
#     #d['cost'][s_ind, 3, 0, n_ind, i_it] = 0.
#                                              ^
# IndentationError: expected an indented block

# %%
#len(sigma_array), 4, N_max, max_it

##### METHOD 3
method_ind = 2
step_method_ind = 1
step_m = 'S1'
if step_method_ind == 1:
    step_m = 'S2'

for d in dict_list:
        
    print("Point = ", d['point'])
    aln.params.ext_exc_current = d['point'][0] * 5.
    aln.params.ext_inh_current = d['point'][1] * 5.
    
    max_it = d['cost'].shape[3]
    
    for s_ind in range(len(d['sigma'])):
        
        print("sigma = ", d['sigma'][s_ind])
        
        s = d['sigma'][s_ind]
        aln.params.sigma_ou = s
        c_p = d['cost_params'][s_ind]
        cost.setParams(c_p[0], c_p[1], c_p[2])
        
        target_ = d['target'][s_ind].copy()
        target_[0,0,:int(trans_time * dur / aln.params.dt)] = -1000
        target_[0,1,:int(trans_time * dur / aln.params.dt)] = -1000
                
        for n_ind in range(len(d['N_array'])):
            
            n_ = d['N_array'][n_ind]
            
            print("n = ", n_)
            aln.params.duration = dur
        
            for i_it in range(1,len(d['it_array'])):
            
                it = d['it_array'][i_it]
                print("iteration = ", it)
                
                if d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it] > 0.:
                    continue
                
                c_vars = d['init']
                aln.params.duration = dur
                setinit(d['init_vars'], aln)
                control_init = aln.getZeroControl()
                    
                
                bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                    control_init, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_ = init_it,
                    tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                    t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                    control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                    noise_real=n_, init_params = d['init_vars'], method='M3', method_step=step_m)
            
                control_init = bc[:,:,100:-100]
                c_vars = [0,1]
                aln.params.duration = dur
                setinit(d['init_vars'], aln)
                
                bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                    control_init, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_=it-init_it,
                    tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                    t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                    control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                    noise_real=n_, init_params = d['init_vars'], method='M3', method_step=step_m)

                control_init = bc[:,:,100:-100]
                aln.params.duration = dur
                setinit(d['init_vars'], aln)
                cost_final = 0.
                cs = cost.numba_cost_sparsity_int(1, 6, T, d['cost_params'][s_ind][2], dt, control_init)

                for j in range(noise_realizations_final):
                    state_ = fo.updateState(aln, control_init)
                    cost_final += cost.numba_cost_precision_int(1, T, dt, d['cost_params'][s_ind][0],
                                                                   state_, target_, list(prec_vars) )

                d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it] = (
                                cost_final / noise_realizations_final + cs )
                print('cost = ', d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it])
                
                c_vars = d['init']                    
                aln.params.duration = dur
                control_init1 = aln.getZeroControl()
                setinit(d['init_vars'], aln)
                
                bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                    control_init1, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_ = init_it,
                    tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                    t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                    control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                    noise_real=n_, init_params = d['init_vars'], method='M3', method_step=step_m)
            
                control_init1 = bc[:,:,100:-100]
                c_vars = [0,1]
                aln.params.duration = dur
                setinit(d['init_vars'], aln)
                
                bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                    control_init1, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_=it-init_it,
                    tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                    t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                    control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                    noise_real=n_, init_params = d['init_vars'], method='M3', method_step=step_m)

                control_init1 = bc[:,:,100:-100]
                d['rep_ind'][s_ind, method_ind, step_method_ind, n_ind, i_it] = rep_ind(control_init, control_init1)
                print('rep_ind = ', d['rep_ind'][s_ind, method_ind, step_method_ind, n_ind, i_it])
                
                file=open(dict_file, "wb")
                pickle.dump(dict_list, file)
                file.close()
                
    break
# Out:
# Point =  [0.74 0.37]
# sigma =  0.01
# set cost params:  0.00029840237860574134 0.0 1.0
# n =  2
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24
# n =  10
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24
# n =  30
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24
# n =  50
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24
# sigma =  0.03
# set cost params:  0.00029840237860574134 0.0 1.0
# n =  2
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24
# n =  10
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24
# n =  30
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24
# n =  50
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24
# sigma =  0.049999999999999996
# set cost params:  0.00029840237860574134 0.0 1.0
# n =  2
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24
# n =  10
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24
# n =  30
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24
# n =  50
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24
# sigma =  0.06999999999999999
# set cost params:  0.00029840237860574134 0.0 1.0
# n =  2
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24
# n =  10
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24
# n =  30
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24
# n =  50
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24

# %%
#len(sigma_array), 4, N_max, max_it

##### METHOD 3
method_ind = 3
step_method_ind = 1
step_m = 'S1'
if step_method_ind == 1:
    step_m = 'S2'

for d in dict_list:
        
    print("Point = ", d['point'])
    aln.params.ext_exc_current = d['point'][0] * 5.
    aln.params.ext_inh_current = d['point'][1] * 5.
    
    max_it = d['cost'].shape[3]
    
    for s_ind in range(len(d['sigma'])):

        print("sigma = ", d['sigma'][s_ind])
        
        s = d['sigma'][s_ind]
        aln.params.sigma_ou = s
        c_p = d['cost_params'][s_ind]
        cost.setParams(c_p[0], c_p[1], c_p[2])
        
        target_ = d['target'][s_ind].copy()
        target_[0,0,:int(trans_time * dur / aln.params.dt)] = -1000
        target_[0,1,:int(trans_time * dur / aln.params.dt)] = -1000
                
        for n_ind in range(len(d['N_array'])):
            
            n_ = d['N_array'][n_ind]
            
            print("n = ", n_)
            aln.params.duration = dur
        
            for i_it in range(1,len(d['it_array'])):
            
                it = d['it_array'][i_it]
                print("iteration = ", it)
                
                if d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it] > 0.:
                    continue
                
                c_vars = d['init']
                aln.params.duration = dur
                setinit(d['init_vars'], aln)
                control_init = aln.getZeroControl()
                    
                
                bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                    control_init, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_ = init_it,
                    tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                    t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                    control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                    noise_real=n_, init_params = d['init_vars'], method='M4', method_step=step_m)
            
                control_init = bc[:,:,100:-100]
                c_vars = [0,1]
                aln.params.duration = dur
                setinit(d['init_vars'], aln)
                
                bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                    control_init, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_=it-init_it,
                    tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                    t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                    control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                    noise_real=n_, init_params = d['init_vars'], method='M4', method_step=step_m)

                control_init = bc[:,:,100:-100]
                aln.params.duration = dur
                setinit(d['init_vars'], aln)
                cost_final = 0.
                cs = cost.numba_cost_sparsity_int(1, 6, T, d['cost_params'][s_ind][2], dt, control_init)

                for j in range(noise_realizations_final):
                    state_ = fo.updateState(aln, control_init)
                    cost_final += cost.numba_cost_precision_int(1, T, dt, d['cost_params'][s_ind][0],
                                                                   state_, target_, list(prec_vars) )

                d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it] = (
                                cost_final / noise_realizations_final + cs )
                print('cost = ', d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it])
                
                c_vars = d['init']                    
                aln.params.duration = dur
                control_init1 = aln.getZeroControl()
                setinit(d['init_vars'], aln)
                
                bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                    control_init1, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_ = init_it,
                    tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                    t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                    control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                    noise_real=n_, init_params = d['init_vars'], method='M4', method_step=step_m)
            
                control_init1 = bc[:,:,100:-100]
                c_vars = [0,1]
                aln.params.duration = dur
                setinit(d['init_vars'], aln)
                
                bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                    control_init1, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_=it-init_it,
                    tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                    t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                    control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                    noise_real=n_, init_params = d['init_vars'], method='M4', method_step=step_m)

                control_init1 = bc[:,:,100:-100]
                d['rep_ind'][s_ind, method_ind, step_method_ind, n_ind, i_it] = rep_ind(control_init, control_init1)
                print('rep_ind = ', d['rep_ind'][s_ind, method_ind, step_method_ind, n_ind, i_it])
                
                file=open(dict_file, "wb")
                pickle.dump(dict_list, file)
                file.close()
                
    break
# Out:
# Point =  [0.74 0.37]
# sigma =  0.01
# set cost params:  0.00029840237860574134 0.0 1.0
# n =  2
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24
# n =  10
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24
# n =  30
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24
# n =  50
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24
# sigma =  0.03
# set cost params:  0.00029840237860574134 0.0 1.0
# n =  2
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24
# n =  10
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24
# n =  30
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24
# n =  50
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24
# sigma =  0.049999999999999996
# set cost params:  0.00029840237860574134 0.0 1.0
# n =  2
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24
# n =  10
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24
# n =  30
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24
# n =  50
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24
# sigma =  0.06999999999999999
# set cost params:  0.00029840237860574134 0.0 1.0
# n =  2
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24
# n =  10
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24
# n =  30
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24
# n =  50
# iteration =  6
# iteration =  12
# iteration =  18
# iteration =  24
