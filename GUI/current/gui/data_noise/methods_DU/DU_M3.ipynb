# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import sys
import pickle
import matplotlib
import ipyparams

path = os.getcwd().split(os.sep + 'GUI')[0]
if path not in sys.path:
    print("not here")
    sys.path.append(path)

from neurolib_dev_optControl.neurolib.models.aln import ALNModel
from neurolib_dev_optControl.neurolib.utils import plotFunctions as plotFunc
from neurolib_dev_optControl.neurolib.utils import func_optimize as fo
from neurolib_dev_optControl.neurolib.utils import costFunctions as cost
import neurolib_dev_optControl.neurolib.dashboard.functions as functions
import neurolib_dev_optControl.neurolib.dashboard.data as data
import neurolib_dev_optControl.neurolib.dashboard.layout as layout
    
# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2 

#path = os.path.join(os.getcwd(), "plots")

cmap_ = layout.getcolormap()
darkgrey, midgrey, lightgrey, color_bi_updown, color_LC, color_bi_uposc = layout.getcolors_rgba()
exc_red = cmap_(3)
inh_blue=cmap_(0)
green = cmap_(2)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
aln = ALNModel()
N = aln.params.N

data.set_parameters(aln)

state_vars = aln.state_vars
init_vars = aln.init_vars

##############################################################
def setinit(init_vars_, model):
    state_vars = model.state_vars
    init_vars = model.init_vars
    for iv in range(len(init_vars)):
        for sv in range(len(state_vars)):
            if state_vars[sv] in init_vars[iv]:
                #print("set init vars ", )
                if model.params[init_vars[iv]].ndim == 2:
                    model.params[init_vars[iv]][0,:] = init_vars_[sv]
                else:
                    model.params[init_vars[iv]][0] = init_vars_[sv]
                    
##############################################################               
def setmaxmincontrol(max_c_c, min_c_c, max_c_r, min_c_r):
    import numpy as np
    
    max_cntrl = np.zeros(( 6 ))
    min_cntrl = np.zeros(( 6 ))
    
    max_cntrl[0] = max_c_c
    min_cntrl[0] = min_c_c
    max_cntrl[1] = max_c_c
    min_cntrl[1] = min_c_c
    max_cntrl[2] = max_c_r
    min_cntrl[2] = min_c_r
    max_cntrl[3] = max_c_r
    min_cntrl[3] = min_c_r
    max_cntrl[4] = max_c_r
    min_cntrl[4] = min_c_r
    max_cntrl[5] = max_c_r
    min_cntrl[5] = min_c_r
            
    return max_cntrl, min_cntrl

# %%
savepath = (os.getcwd().split('neurolib')[0] + 'Talks_Conf_Workshops_Schools' + os.sep + '22' + os.sep + 'FRANCE22' + 
     os.sep + 'ENCODS' + os.sep + 'poster' + os.sep + 'images')

exc = 0.5
inh = 0.5

# %%
dur_pre = 10
dur_post = 10
dur = 200.
dt = aln.params.dt
T = int(1 + dur / dt)

max_it = 10
init_it = 10
prec_vars = [0,1]
trans_time = 0.8
repeat = 20

n_pre = int(np.around(dur_pre/aln.params.dt + 1.,1))
n_post = int(np.around(dur_post/aln.params.dt + 1.,1))

tol = 1e-32
start_step = 10.
c_scheme = np.zeros(( 1,1 ))
c_scheme[0,0] = 1.
u_mat = np.identity(1)
u_scheme = np.array([[1.]])

maxC = [5., -5., 0.18, 0.]
n_dur = int(np.around(dur/aln.params.dt + 1.,1))
max_cntrl, min_cntrl = setmaxmincontrol(maxC[0], maxC[1], maxC[2], maxC[3])

nb = ipyparams.notebook_name
print('nb = ', nb)

case = str(nb[4])
# Out:
# nb =  DU_M3.ipynb

# %%
i = 28
t_range=[1500,3701]

noisefree_file = '..' + os.sep + '..' + os.sep + 'data_final_2' + os.sep + 'control_1.pickle'
file = open(noisefree_file, "rb")
noisefree = pickle.load(file)
file.close()
    
c_noisefree = noisefree[0][i][:,:,t_range[0]:t_range[1]]
plt.plot(c_noisefree[0,0,:])
plt.show()

# %%
sigma_ou_array = [0.01, 0.05]
noise_realizations_array = [0,20,50]
noise_realizations_final = 10000

# %%
n_sig = len(sigma_ou_array)
n_noise = len(noise_realizations_array)

int_t_pen = np.around( (1. - trans_time)*dur/aln.params.dt, 1).astype(int)

cost_final_mean = np.zeros(( n_sig,n_noise ))
target = [None] * n_sig
control_ = [ [None] * n_noise, [None] * n_noise ]
cost_ = control_.copy()
cost_final = control_.copy()

stable_state = np.zeros(( n_noise, 2,2,2, 2))

# %%
cost_final_mean = np.zeros(( n_sig,n_noise ))

# %%
# get init vars without noise
aln = ALNModel()
data.set_parameters(aln)
aln.params.duration = 3000.

# initial without noise
control0 = aln.getZeroControl()
control0[0,0,:500] = -5.

aln.params.ext_exc_current = exc * 5.
aln.params.ext_inh_current = inh * 5.

aln.run(control=control0)

init_state_vars = np.zeros(( len(state_vars) ))
for j in range(len(state_vars)):
    if aln.state[state_vars[j]].size == 1:
        init_state_vars[j] = aln.state[state_vars[j]][0]
    else:
        init_state_vars[j] = aln.state[state_vars[j]][0,-1]

initVars = init_state_vars

# %%
for i_sigma in range(len(sigma_ou_array)):
    
    sigma_ou = sigma_ou_array[i_sigma]
    aln.params.sigma_ou = sigma_ou
    

    aln.params.duration = dur
    control0 = aln.getZeroControl()
    control0[0,0,:500] = 5.

    target_rates_e = []
    target_rates_i = []

    stateswitchcount = 0

    for j in range(noise_realizations_final):
        aln.params.duration = dur
        aln.run(control=control0)
        if np.amin(aln.rates_exc[0,1000:]) < 1.:
            print("fell in down state, repeat")
            j -= 1
            stateswitchcount += 1
            if stateswitchcount > 0.1 * noise_realizations_final:
                break
            continue
        target_rates_e.append(aln.rates_exc[0,1000:])
        target_rates_i.append(aln.rates_inh[0,1000:])

    aln.params.duration = dur
    target[i_sigma] = aln.getZeroTarget()
    target[i_sigma][:,0,:] = np.mean(target_rates_e)
    target[i_sigma][:,1,:] = np.mean(target_rates_i)

    stable_state[i_sigma,1,1,0,0] = target[i_sigma][0,0,-1]
    stable_state[i_sigma,1,1,1,0] = target[i_sigma][0,1,-1]
    stable_state[i_sigma,1,1,0,1] = np.std(target_rates_e)
    stable_state[i_sigma,1,1,1,1] = np.std(target_rates_i)


    aln.params.duration = 300.
    control0 = aln.getZeroControl()
    control0[0,0,:500] = -5.

    target_rates_e = []
    target_rates_i = []

    stateswitchcount = 0

    for j in range(noise_realizations_final):
        aln.params.duration = 300.
        aln.run(control=control0)
        if np.amin(aln.rates_exc[0,1000:]) > 3.:
            print("fell in up state, repeat")
            j -= 1
            stateswitchcount += 1
            if stateswitchcount > 0.1 * noise_realizations_final:
                break
            continue
        target_rates_e.append(aln.rates_exc[0,1000:])
        target_rates_i.append(aln.rates_inh[0,1000:])

    stable_state[i_sigma,1,0,0,0] = np.mean(target_rates_e)
    stable_state[i_sigma,1,0,1,0] = np.mean(target_rates_i)
    stable_state[i_sigma,1,0,0,1] = np.std(target_rates_e)
    stable_state[i_sigma,1,0,1,1] = np.std(target_rates_i)

# %%
w_p = np.zeros((2))
for i_sigma in range(len(sigma_ou_array)):
    w_p[i_sigma] = 1. / ( ( stable_state[i_sigma,1,1,0,1] + stable_state[i_sigma,1,1,1,1] ) * (1. - trans_time) * dur )
w_e = 0.
w_s = 1.

aln.params.duration = dur
zero_init = aln.getZeroControl()

# %%
max_it = 15
init_it = 3
factor = [1.1, 1.5]

for i_sigma in range(len(sigma_ou_array)):
    
    cost.setParams(w_p[i_sigma], w_e, w_s)
    
    for i_noise in range(len(noise_realizations_array)):
        
        if i_sigma in []:
            continue
        if i_noise in []:
            continue

        noise_realizations = noise_realizations_array[i_noise]
        sigma_ou = sigma_ou_array[i_sigma]
        aln.params.sigma_ou = sigma_ou
        
        aln.params.duration = dur
        print(noise_realizations)
        
        if i_noise != 0.:

            setinit(initVars, aln)

            bestControl, bestState, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                zero_init, target[i_sigma], c_scheme, u_mat, u_scheme, max_iteration_ = init_it,
                tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                control_variables_ = [0], prec_variables_ = prec_vars, transition_time_ = trans_time,
                noise_real=noise_realizations, init_params = initVars, method='M3')

            control_init = bestControl[:,:,100:-100].copy()
            setinit(initVars, aln)
            aln.params.duration = dur

            bestControl, bestState, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                control_init, target[i_sigma], c_scheme, u_mat, u_scheme, max_iteration_ = max_it-init_it,
                tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                control_variables_ = [0,1], prec_variables_ = prec_vars, transition_time_ = trans_time,
                noise_real=noise_realizations, init_params = initVars,method='M3')


            control_[i_sigma][i_noise] = bestControl.copy()
        
        else:
            control_[i_sigma][i_noise] = factor[i_sigma] * c_noisefree[:,:,:]
        
        aln.params.duration = dur
        setinit(initVars, aln)

        init_control = aln.getZeroControl()   
        
        init_control[:,:,:] = control_[i_sigma][i_noise][:,:,100:-100]
            
        T = int(1 + dur/aln.params.dt)
        dt = aln.params.dt

        target_ = target[i_sigma].copy()
        target_[0,0,:int(trans_time * dur / aln.params.dt)] = -1000
        target_[0,1,:int(trans_time * dur / aln.params.dt)] = -1000

        cost_final = 0.
        cs = cost.numba_cost_sparsity_int(1, 6, T, w_s, dt, init_control)

        for n_ in range(noise_realizations_final):
            state_ = fo.updateState(aln, init_control)
            cost_final += cost.numba_cost_precision_int(1,T,dt,w_p[i_sigma],state_, target_, list(prec_vars) )

        cost_final_mean[i_sigma, i_noise] = cs + cost_final / noise_realizations_final
        print('mean = ', cost_final_mean[i_sigma, i_noise])
# Out:
# set cost params:  0.02647374912041952 0.0 1.0 0.0
# 0
# mean =  2.824799804687832
# 20
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3683.2978221108087
# Gradient descend method:  None
# RUN  1 , total integrated cost =  145.99283412387518
# RUN  2 , total integrated cost =  33.58664765129121
# RUN  3 , total integrated cost =  9.10959348500569
# RUN  3 , total integrated cost mean =  9.10959348500569
# Improved over  3  iterations in  2.649123014009092  seconds by  99.7526783354221  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  9.290177930161132
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.3004904811791675
# RUN  2 , total integrated cost =  6.925338960904137
# RUN  3 , total integrated cost =  6.8286762827731895
# RUN  4 , total integrated cost =  6.689492036981028
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  5 , total integrated cost =  6.637034324156312
# RUN  6 , total integrated cost =  6.502789196095334
# step size too small or too large
# RUN  7 , total integrated cost =  6.46203060775615
# step size too small or too large
# RUN  8 , total integrated cost =  6.3881291363142125
# RUN  9 , total integrated cost =  6.26097290757607
# step size too small or too large
# RUN  10 , total integrated cost =  6.280805118537584
# RUN  11 , total integrated cost =  6.219471537384395
# step size too small or too large
# step size too small or too large
# RUN  12 , total integrated cost =  6.149270321480139
# RUN  12 , total integrated cost mean =  6.149270321480139
# Improved over  12  iterations in  19.736538037992432  seconds by  33.80890691537613  percent.
# mean =  6.173007055955783
# 50
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3684.5934491272533
# Gradient descend method:  None
# RUN  1 , total integrated cost =  138.88899731412795
# RUN  2 , total integrated cost =  37.00766288501152
# RUN  3 , total integrated cost =  10.325415896317368
# RUN  3 , total integrated cost mean =  10.325415896317368
# Improved over  3  iterations in  6.6140746629971545  seconds by  99.71976783764941  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  10.266658245646289
# Gradient descend method:  None
# step size too small or too large
# step size too small or too large
# RUN  1 , total integrated cost =  8.317394511666699
# step size too small or too large
# RUN  2 , total integrated cost =  7.904574687000987
# step size too small or too large
# RUN  3 , total integrated cost =  7.704357965750493
# RUN  4 , total integrated cost =  7.611212086898604
# RUN  5 , total integrated cost =  7.544008327890806
# step size too small or too large
# RUN  6 , total integrated cost =  7.480682802323219
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  7 , total integrated cost =  7.425204808535426
# step size too small or too large
# step size too small or too large
# RUN  8 , total integrated cost =  7.375187166965904
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  9 , total integrated cost =  7.286458650070184
# step size too small or too large
# RUN  10 , total integrated cost =  7.2165831310676705
# step size too small or too large
# RUN  11 , total integrated cost =  7.167826367638891
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  12 , total integrated cost =  7.119857245555729
# RUN  12 , total integrated cost mean =  7.119857245555729
# Improved over  12  iterations in  40.66377138199459  seconds by  30.650684232379135  percent.
# mean =  7.15127739762179
# set cost params:  0.00529316256045937 0.0 1.0 0.0
# 0
# mean =  4.625388264033342
# 20
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  732.5780412541292
# Gradient descend method:  None
# RUN  1 , total integrated cost =  36.886158644359156
# RUN  2 , total integrated cost =  8.730422159693124
# RUN  3 , total integrated cost =  6.116967714410103
# RUN  3 , total integrated cost mean =  6.116967714410103
# Improved over  3  iterations in  1.7277827789948788  seconds by  99.16500804420261  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5.948312883719442
# Gradient descend method:  None
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  1 , total integrated cost =  5.6281697720268955
# RUN  2 , total integrated cost =  5.384964149996954
# RUN  3 , total integrated cost =  5.1084636715751435
# RUN  4 , total integrated cost =  5.2190967729469815
# step size too small or too large
# step size too small or too large
# RUN  5 , total integrated cost =  5.046001735188112
# step size too small or too large
# RUN  6 , total integrated cost =  4.963452505552007
# step size too small or too large
# RUN  7 , total integrated cost =  5.067182288237584
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  8 , total integrated cost =  4.957584795571806
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  9 , total integrated cost =  5.149774545309828
# RUN  10 , total integrated cost =  5.320038288956463
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  11 , total integrated cost =  5.150590027495467
# step size too small or too large
# RUN  12 , total integrated cost =  5.0988966354644365
# RUN  12 , total integrated cost mean =  5.0988966354644365
# Improved over  12  iterations in  14.197933793999255  seconds by  14.279952397592638  percent.
# mean =  5.3176087283019395
# 50
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  734.4998577281348
# Gradient descend method:  None
# RUN  1 , total integrated cost =  44.145701905633935
# step size too small or too large
# RUN  2 , total integrated cost =  26.73676415063876
# RUN  3 , total integrated cost =  10.995738437039199
# RUN  3 , total integrated cost mean =  10.995738437039199
# Improved over  3  iterations in  4.825317542999983  seconds by  98.50296248238224  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  10.891658423403152
# Gradient descend method:  None
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  1 , total integrated cost =  9.870727165460655
# step size too small or too large
# RUN  2 , total integrated cost =  9.638734077852561
# step size too small or too large
# RUN  3 , total integrated cost =  9.344933203989363
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  4 , total integrated cost =  9.025736219162757
# step size too small or too large
# step size too small or too large
# RUN  5 , total integrated cost =  8.826304081999478
# RUN  6 , total integrated cost =  8.4343810726652
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  7 , total integrated cost =  8.141219702953821
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  8 , total integrated cost =  7.965536881811787
# step size too small or too large
# RUN  9 , total integrated cost =  7.521179665722769
# RUN  10 , total integrated cost =  7.017686732291851
# RUN  11 , total integrated cost =  6.577157320935467
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  12 , total integrated cost =  6.29029409339361
# RUN  12 , total integrated cost mean =  6.29029409339361
# Improved over  12  iterations in  36.65500153100584  seconds by  42.24668228781843  percent.
# mean =  6.250547314623093

# %%
fs_ = 26
fig, ax = plt.subplots(4, 3, figsize=(16,12), constrained_layout=True, facecolor='white',
                       gridspec_kw={'height_ratios': [3,2,3,2]})
#fig.suptitle('Point b', fontsize=fs_)
plot_realizations = 10
i = 50

t_array = np.arange(0,dur+aln.params.dt,aln.params.dt)
ax[0,0].set_title('DOC multiple', fontsize=fs_)

setinit(initVars, aln)
aln.params.duration = dur
target_ = aln.getZeroTarget()

for i_sigma in range(len(sigma_ou_array)):
    
    target_[0,0,:] = target[i_sigma][0,0,-1]
    target_[0,1,:] = target[i_sigma][0,1,-1]
    
    for i_noise in range(3):
        
        noise_realizations = noise_realizations_array[i_noise]
        sigma_ou = sigma_ou_array[i_sigma]
        aln.params.sigma_ou = sigma_ou
        
        if i_noise != 0:
            ax[0,i_noise].set_title(r'$N=$' + '{}'.format(noise_realizations) + ', M3', fontsize=fs_)

        ax[2*i_sigma+1,i_noise].plot( t_array, control_[i_sigma][i_noise][0,0,100:-100]/5., color=exc_red)
        ax[2*i_sigma+1,i_noise].plot( t_array, control_[i_sigma][i_noise][0,1,100:-100]/5., color=inh_blue)
        
        ax[2*i_sigma,i_noise].plot( t_array, target_[0,0,:], linestyle='--', color=exc_red)
        ax[2*i_sigma,i_noise].plot( t_array, target_[0,1,:], linestyle='--', color=inh_blue)

        for indexx in range(plot_realizations):
            aln.run(control=control_[i_sigma][i_noise][:,:,100:-100])
            ax[2*i_sigma,i_noise].plot( t_array, aln.rates_exc[0,:], color=exc_red)
            ax[2*i_sigma,i_noise].plot( t_array, aln.rates_inh[0,:], color=inh_blue)

        ax[2*i_sigma,i_noise].text(0.05, 0.7, r'$F = $' + '{:.2f}'.format(cost_final_mean[i_sigma, i_noise]),
                horizontalalignment='left', verticalalignment='top', transform=ax[2*i_sigma,i_noise].transAxes,
                bbox=dict(boxstyle='round', facecolor=midgrey, alpha=0.3), fontsize=fs_)
        
        ax[2*i_sigma+1,i_noise].text(0.05, 0.9, r'$a = $' + '{:.2f} nA'.format(
            max( np.amax(np.abs(control_[i_sigma][i_noise][0,0,100:-100]/5.)),
               np.amax(np.abs(control_[i_sigma][i_noise][0,1,100:-100]/5.))) ),
            horizontalalignment='left', verticalalignment='top', transform=ax[2*i_sigma+1,i_noise].transAxes,
            bbox=dict(boxstyle='round', facecolor=midgrey, alpha=0.3), fontsize=fs_)

for j in range(4):
    for k in range(3):
        ax[j,k].tick_params(axis='x', labelsize=fs_)
        ax[j,k].tick_params(axis='y', labelsize=fs_)
        ax[j,k].set_xlim(0,dur)
        ax[j,k].grid(False)
        if j != 3:
            ax[j,k].set_xticks([])
        else:
            ax[j,k].set_xlabel('Time [ms]', fontsize=fs_)
        ax[j,k].set_yticks([])
        if j%2 == 0:
            ax[j,k].set_ylim(0,110)
            sigma_ou = sigma_ou_array[int(j/2)]
            ax[j,k].axvspan( dur*trans_time, dur, facecolor=midgrey,
                            alpha=0.5, zorder=-1, hatch='///', edgecolor = midgrey)
        elif j%2 == 1:
            ax[j,k].set_ylim(-0.15,0.3)
            
    if j%2 == 0:
        ax[j,-1].set_yticks(np.arange(0,110,50))
        ax[j,-1].set_ylabel('Activity [Hz]', fontsize=fs_)
        ax[j,-1].yaxis.set_label_position("right")
        ax[j,-1].yaxis.tick_right()
        ax[j,0].text(-0.1,0.3, r'$\sigma=$'+'{:.2f}'.format(sigma_ou_array[int(j/2)]), rotation=90, size=fs_,
                 verticalalignment='bottom', horizontalalignment='center', transform=ax[j,0].transAxes)
    
    elif j%2 == 1:     
        ax[j,-1].set_yticks(np.arange(-0.1,0.31,0.1))
        ax[j,-1].set_ylabel('Control [nA]', fontsize=fs_)
        ax[j,-1].yaxis.set_label_position("right")
        ax[j,-1].yaxis.tick_right()

filename_ = nb[:-6] + '.png'
    
fig.savefig(filename_)
fig.savefig(os.path.join(savepath, filename_))
plt.show()

# %%
n_noise = 3
control_1 = [ [None] * n_noise, [None] * n_noise, [None] * n_noise ]

# %%
for i_sigma in range(len(sigma_ou_array)):    
    cost.setParams(w_p[i_sigma], w_e, w_s)
    
    for i_noise in [1,2]:
        
        if i_sigma in []:
            continue

        noise_realizations = noise_realizations_array[i_noise]
        sigma_ou = sigma_ou_array[i_sigma]
        aln.params.sigma_ou = sigma_ou
        
        aln.params.duration = dur
        zero_init = aln.getZeroControl()
        print(noise_realizations)

        setinit(initVars, aln)

        bestControl, bestState, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
            zero_init, target[i_sigma], c_scheme, u_mat, u_scheme, max_iteration_ = init_it,
            tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
            t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
            control_variables_ = [0], prec_variables_ = prec_vars, transition_time_ = trans_time,
            noise_real=noise_realizations, init_params = initVars, method='M3')

        control_init = bestControl[:,:,100:-100].copy()
        setinit(initVars, aln)
        aln.params.duration = dur

        bestControl, bestState, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
            control_init, target[i_sigma], c_scheme, u_mat, u_scheme, max_iteration_ = max_it-init_it,
            tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
            t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
            control_variables_ = [0,1], prec_variables_ = prec_vars, transition_time_ = trans_time,
            noise_real=noise_realizations, init_params = initVars,method='M3')

        control_1[i_sigma][i_noise] = bestControl.copy()
# Out:
# set cost params:  0.02647374912041952 0.0 1.0 0.0
# 20
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3684.4067264499754
# Gradient descend method:  None
# RUN  1 , total integrated cost =  152.95843560901906
# RUN  2 , total integrated cost =  14.221642846672234
# step size too small or too large
# RUN  3 , total integrated cost =  10.769826692582495
# RUN  3 , total integrated cost mean =  10.769826692582495
# Improved over  3  iterations in  1.4346007620042656  seconds by  99.70769169931032  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  10.709644431520978
# Gradient descend method:  None
# step size too small or too large
# step size too small or too large
# RUN  1 , total integrated cost =  8.783940892177926
# step size too small or too large
# step size too small or too large
# RUN  2 , total integrated cost =  6.9308009486098285
# step size too small or too large
# RUN  3 , total integrated cost =  5.742679020896712
# RUN  4 , total integrated cost =  4.858278106574156
# step size too small or too large
# RUN  5 , total integrated cost =  4.077350179588912
# RUN  6 , total integrated cost =  4.113224831995516
# RUN  7 , total integrated cost =  3.9459035334147643
# RUN  8 , total integrated cost =  3.9345959693852945
# RUN  9 , total integrated cost =  3.832601510679892
# step size too small or too large
# RUN  10 , total integrated cost =  3.8857384028446185
# RUN  11 , total integrated cost =  3.907531542343085
# step size too small or too large
# step size too small or too large
# RUN  12 , total integrated cost =  3.844775235139083
# RUN  12 , total integrated cost mean =  3.844775235139083
# Improved over  12  iterations in  10.804632269995636  seconds by  64.09987969513708  percent.
# 50
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3684.488615045312
# Gradient descend method:  None
# RUN  1 , total integrated cost =  152.06174130602128
# RUN  2 , total integrated cost =  10.126387039663694
# RUN  3 , total integrated cost =  6.924110657798297
# RUN  3 , total integrated cost mean =  6.924110657798297
# Improved over  3  iterations in  4.787079635003465  seconds by  99.81207403845613  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  6.8068024597204975
# Gradient descend method:  None
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  1 , total integrated cost =  5.799828655249205
# step size too small or too large
# RUN  2 , total integrated cost =  4.660245725237071
# RUN  3 , total integrated cost =  4.478294933365084
# step size too small or too large
# step size too small or too large
# RUN  4 , total integrated cost =  4.49279540742456
# step size too small or too large
# RUN  5 , total integrated cost =  4.289954132039804
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  6 , total integrated cost =  4.170161442239642
# RUN  7 , total integrated cost =  4.220756404111044
# RUN  8 , total integrated cost =  4.192603899224297
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  9 , total integrated cost =  4.160977064357609
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  10 , total integrated cost =  4.13326867141958
# step size too small or too large
# RUN  11 , total integrated cost =  4.1643736201426655
# RUN  12 , total integrated cost =  4.0909062986516735
# RUN  12 , total integrated cost mean =  4.0909062986516735
# Improved over  12  iterations in  48.79179036700225  seconds by  39.89973525954718  percent.
# set cost params:  0.00529316256045937 0.0 1.0 0.0
# 20
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  737.5273365781081
# Gradient descend method:  None
# RUN  1 , total integrated cost =  41.389810496615155
# RUN  2 , total integrated cost =  21.048648588127545
# RUN  3 , total integrated cost =  10.617007220330896
# RUN  3 , total integrated cost mean =  10.617007220330896
# Improved over  3  iterations in  2.3677044520009076  seconds by  98.56045915944073  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  10.559150029181756
# Gradient descend method:  None
# RUN  1 , total integrated cost =  9.612693291744275
# RUN  2 , total integrated cost =  9.387332029113269
# RUN  3 , total integrated cost =  9.137679794905399
# step size too small or too large
# RUN  4 , total integrated cost =  8.968120040481002
# step size too small or too large
# RUN  5 , total integrated cost =  8.633600917865959
# RUN  6 , total integrated cost =  8.739992303518783
# RUN  7 , total integrated cost =  7.706661491469693
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  8 , total integrated cost =  7.46704432579074
# step size too small or too large
# step size too small or too large
# RUN  9 , total integrated cost =  7.376355348620858
# RUN  10 , total integrated cost =  7.110322692611431
# step size too small or too large
# RUN  11 , total integrated cost =  7.230289308338743
# step size too small or too large
# RUN  12 , total integrated cost =  6.840291769507353
# RUN  12 , total integrated cost mean =  6.840291769507353
# Improved over  12  iterations in  17.790407145992504  seconds by  35.21929558152688  percent.
# 50
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  736.1632793319759
# Gradient descend method:  None
# RUN  1 , total integrated cost =  37.9148633531366
# RUN  2 , total integrated cost =  16.552389405661117
# RUN  3 , total integrated cost =  9.414851257023738
# RUN  3 , total integrated cost mean =  9.414851257023738
# Improved over  3  iterations in  5.5466127899999265  seconds by  98.72109197492611  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  9.453854510612345
# Gradient descend method:  None
# RUN  1 , total integrated cost =  8.560458971393096
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  2 , total integrated cost =  8.26579734076207
# step size too small or too large
# RUN  3 , total integrated cost =  8.121781022988195
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  4 , total integrated cost =  7.939697703008121
# step size too small or too large
# step size too small or too large
# RUN  5 , total integrated cost =  7.52667709638612
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  6 , total integrated cost =  7.133173092692888
# RUN  7 , total integrated cost =  6.624904730787193
# step size too small or too large
# step size too small or too large
# RUN  8 , total integrated cost =  6.347567112313485
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  9 , total integrated cost =  6.0721053309374975
# step size too small or too large
# step size too small or too large
# RUN  10 , total integrated cost =  6.0367238653264765
# step size too small or too large
# RUN  11 , total integrated cost =  5.700820787564055
# step size too small or too large
# step size too small or too large
# RUN  12 , total integrated cost =  5.369754122896084
# RUN  12 , total integrated cost mean =  5.369754122896084
# Improved over  12  iterations in  51.29937231900112  seconds by  43.2003727488263  percent.

# %%
fig, ax = plt.subplots(4, 3, figsize=(16,12), constrained_layout=True, facecolor='white',
                       gridspec_kw={'height_ratios': [3,2,3,2]})
plot_realizations = 10

t_array = np.arange(0,dur+aln.params.dt,aln.params.dt)
ax[0,0].set_title('DOC multiple', fontsize=fs_)

setinit(initVars, aln)
aln.params.duration = dur
target_ = aln.getZeroTarget()

for i_sigma in range(len(sigma_ou_array)):
    
    target_[0,0,:] = target[i_sigma][0,0,-1]
    target_[0,1,:] = target[i_sigma][0,1,-1]
    
    for i_noise in range(3):
        
        noise_realizations = noise_realizations_array[i_noise]
        sigma_ou = sigma_ou_array[i_sigma]
        aln.params.sigma_ou = sigma_ou
        
        if i_noise != 0:
            ax[0,i_noise].set_title(r'$N=$' + '{}'.format(noise_realizations) + ', M3', fontsize=fs_)
            ax[2*i_sigma+1,i_noise].plot( t_array, control_1[i_sigma][i_noise][0,0,100:-100]/5.,
                                         color=exc_red, linestyle='dotted')
            ax[2*i_sigma+1,i_noise].plot( t_array, control_1[i_sigma][i_noise][0,1,100:-100]/5.,
                                         color=inh_blue, linestyle='dotted')

        ax[2*i_sigma+1,i_noise].plot( t_array, control_[i_sigma][i_noise][0,0,100:-100]/5.,
                                     color=exc_red, linewidth=1)
        ax[2*i_sigma+1,i_noise].plot( t_array, control_[i_sigma][i_noise][0,1,100:-100]/5.,
                                     color=inh_blue, linewidth=1)
        
        ax[2*i_sigma,i_noise].plot( t_array, target_[0,0,:], linestyle='--', color=exc_red)
        ax[2*i_sigma,i_noise].plot( t_array, target_[0,1,:], linestyle='--', color=inh_blue)

        for indexx in range(plot_realizations):
            aln.run(control=control_[i_sigma][i_noise][:,:,100:-100])
            ax[2*i_sigma,i_noise].plot( t_array, aln.rates_exc[0,:], color=exc_red, linewidth=1)
            ax[2*i_sigma,i_noise].plot( t_array, aln.rates_inh[0,:], color=inh_blue, linewidth=1)

        ax[2*i_sigma,i_noise].text(0.05, 0.8, r'$F = $' + '{:.2f}'.format(cost_final_mean[i_sigma, i_noise]),
                horizontalalignment='left', verticalalignment='top', transform=ax[2*i_sigma,i_noise].transAxes,
                bbox=dict(boxstyle='round', facecolor=midgrey, alpha=0.3), fontsize=fs_)
        
        ax[2*i_sigma+1,i_noise].text(0.05, 0.9, r'$a = $' + '{:.2f} nA'.format(
            np.amax(control_[i_sigma][i_noise][0,0,100:-100]/5.)), horizontalalignment='left',
            verticalalignment='top', transform=ax[2*i_sigma+1,i_noise].transAxes,
            bbox=dict(boxstyle='round', facecolor=midgrey, alpha=0.3), fontsize=fs_)

for j in range(4):
    for k in range(3):
        ax[j,k].tick_params(axis='x', labelsize=fs_)
        ax[j,k].tick_params(axis='y', labelsize=fs_)
        ax[j,k].set_xlim(0,dur)
        ax[j,k].grid(False)
        if j != 3:
            ax[j,k].set_xticks([])
        else:
            ax[j,k].set_xlabel('Time [ms]', fontsize=fs_)
        ax[j,k].set_yticks([])
        if j%2 == 0:
            ax[j,k].set_ylim(0,110)
            sigma_ou = sigma_ou_array[int(j/2)]
            ax[j,k].axvspan( dur*trans_time, dur, facecolor=midgrey,
                            alpha=0.5, zorder=-1, hatch='///', edgecolor = midgrey)
        elif j%2 == 1:
            ax[j,k].set_ylim(-0.2,0.4)
            
    if j%2 == 0:
        ax[j,-1].set_yticks(np.arange(0,110,50))
        ax[j,-1].set_ylabel('Activity [Hz]', fontsize=fs_)
        ax[j,-1].yaxis.set_label_position("right")
        ax[j,-1].yaxis.tick_right()
        ax[j,0].text(-0.1,0.3, r'$\sigma=$'+'{:.2f}'.format(sigma_ou_array[int(j/2)]), rotation=90, size=fs_,
                 verticalalignment='bottom', horizontalalignment='center', transform=ax[j,0].transAxes)
    
    elif j%2 == 1:     
        ax[j,-1].set_yticks(np.arange(-0.2,0.41,0.2))
        ax[j,-1].set_ylabel('Control [nA]', fontsize=fs_)
        ax[j,-1].yaxis.set_label_position("right")
        ax[j,-1].yaxis.tick_right()

nb = ipyparams.notebook_name
filename_ = nb[:-6] + '_1.png'
    
fig.savefig(filename_)
fig.savefig(os.path.join(savepath, filename_))
plt.show()
