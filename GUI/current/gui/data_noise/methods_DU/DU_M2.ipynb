# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import sys
import pickle
import matplotlib
import ipyparams

path = os.getcwd().split(os.sep + 'GUI')[0]
if path not in sys.path:
    print("not here")
    sys.path.append(path)

from neurolib_dev_optControl.neurolib.models.aln import ALNModel
from neurolib_dev_optControl.neurolib.utils import plotFunctions as plotFunc
from neurolib_dev_optControl.neurolib.utils import func_optimize as fo
from neurolib_dev_optControl.neurolib.utils import costFunctions as cost
import neurolib_dev_optControl.neurolib.dashboard.functions as functions
import neurolib_dev_optControl.neurolib.dashboard.data as data
import neurolib_dev_optControl.neurolib.dashboard.layout as layout
    
# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2 

#path = os.path.join(os.getcwd(), "plots")

cmap_ = layout.getcolormap()
darkgrey, midgrey, lightgrey, color_bi_updown, color_LC, color_bi_uposc = layout.getcolors_rgba()
exc_red = cmap_(3)
inh_blue=cmap_(0)
green = cmap_(2)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
aln = ALNModel()
N = aln.params.N

data.set_parameters(aln)

state_vars = aln.state_vars
init_vars = aln.init_vars

##############################################################
def setinit(init_vars_, model):
    state_vars = model.state_vars
    init_vars = model.init_vars
    for iv in range(len(init_vars)):
        for sv in range(len(state_vars)):
            if state_vars[sv] in init_vars[iv]:
                #print("set init vars ", )
                if model.params[init_vars[iv]].ndim == 2:
                    model.params[init_vars[iv]][0,:] = init_vars_[sv]
                else:
                    model.params[init_vars[iv]][0] = init_vars_[sv]
                    
##############################################################               
def setmaxmincontrol(max_c_c, min_c_c, max_c_r, min_c_r):
    import numpy as np
    
    max_cntrl = np.zeros(( 6 ))
    min_cntrl = np.zeros(( 6 ))
    
    max_cntrl[0] = max_c_c
    min_cntrl[0] = min_c_c
    max_cntrl[1] = max_c_c
    min_cntrl[1] = min_c_c
    max_cntrl[2] = max_c_r
    min_cntrl[2] = min_c_r
    max_cntrl[3] = max_c_r
    min_cntrl[3] = min_c_r
    max_cntrl[4] = max_c_r
    min_cntrl[4] = min_c_r
    max_cntrl[5] = max_c_r
    min_cntrl[5] = min_c_r
            
    return max_cntrl, min_cntrl

# %%
savepath = (os.getcwd().split('neurolib')[0] + 'Talks_Conf_Workshops_Schools' + os.sep + '22' + os.sep + 'FRANCE22' + 
     os.sep + 'ENCODS' + os.sep + 'poster' + os.sep + 'images')

exc = 0.5
inh = 0.5

# %%
dur_pre = 10
dur_post = 10
dur = 200.
dt = aln.params.dt
T = int(1 + dur / dt)

max_it = 10
init_it = 10
prec_vars = [0,1]
trans_time = 0.8
repeat = 20

n_pre = int(np.around(dur_pre/aln.params.dt + 1.,1))
n_post = int(np.around(dur_post/aln.params.dt + 1.,1))

tol = 1e-32
start_step = 10.
c_scheme = np.zeros(( 1,1 ))
c_scheme[0,0] = 1.
u_mat = np.identity(1)
u_scheme = np.array([[1.]])

maxC = [5., -5., 0.18, 0.]
n_dur = int(np.around(dur/aln.params.dt + 1.,1))
max_cntrl, min_cntrl = setmaxmincontrol(maxC[0], maxC[1], maxC[2], maxC[3])

nb = ipyparams.notebook_name
print('nb = ', nb)

case = str(nb[4])
# Out:
# nb =  DU_M2.ipynb

# %%
i = 28
t_range=[1500,3701]

noisefree_file = '..' + os.sep + '..' + os.sep + 'data_final_2' + os.sep + 'control_1.pickle'
file = open(noisefree_file, "rb")
noisefree = pickle.load(file)
file.close()
    
c_noisefree = noisefree[0][i][:,:,t_range[0]:t_range[1]]
plt.plot(c_noisefree[0,0,:])
plt.show()

# %%
sigma_ou_array = [0.01, 0.05]
noise_realizations_array = [0,20,50]
noise_realizations_final = 10000

# %%
n_sig = len(sigma_ou_array)
n_noise = len(noise_realizations_array)

int_t_pen = np.around( (1. - trans_time)*dur/aln.params.dt, 1).astype(int)

cost_final_mean = np.zeros(( n_sig,n_noise ))
target = [None] * n_sig
control_ = [ [None] * n_noise, [None] * n_noise ]
cost_ = control_.copy()
cost_final = control_.copy()

stable_state = np.zeros(( n_noise, 2,2,2, 2))

# %%
cost_final_mean = np.zeros(( n_sig,n_noise ))

# %%
# get init vars without noise
aln = ALNModel()
data.set_parameters(aln)
aln.params.duration = 3000.

# initial without noise
control0 = aln.getZeroControl()
control0[0,0,:500] = -5.

aln.params.ext_exc_current = exc * 5.
aln.params.ext_inh_current = inh * 5.

aln.run(control=control0)

init_state_vars = np.zeros(( len(state_vars) ))
for j in range(len(state_vars)):
    if aln.state[state_vars[j]].size == 1:
        init_state_vars[j] = aln.state[state_vars[j]][0]
    else:
        init_state_vars[j] = aln.state[state_vars[j]][0,-1]

initVars = init_state_vars

# %%
for i_sigma in range(len(sigma_ou_array)):
    
    sigma_ou = sigma_ou_array[i_sigma]
    aln.params.sigma_ou = sigma_ou
    

    aln.params.duration = dur
    control0 = aln.getZeroControl()
    control0[0,0,:500] = 5.

    target_rates_e = []
    target_rates_i = []

    stateswitchcount = 0

    for j in range(noise_realizations_final):
        aln.params.duration = dur
        aln.run(control=control0)
        if np.amin(aln.rates_exc[0,1000:]) < 1.:
            print("fell in down state, repeat")
            j -= 1
            stateswitchcount += 1
            if stateswitchcount > 0.1 * noise_realizations_final:
                break
            continue
        target_rates_e.append(aln.rates_exc[0,1000:])
        target_rates_i.append(aln.rates_inh[0,1000:])

    aln.params.duration = dur
    target[i_sigma] = aln.getZeroTarget()
    target[i_sigma][:,0,:] = np.mean(target_rates_e)
    target[i_sigma][:,1,:] = np.mean(target_rates_i)

    stable_state[i_sigma,1,1,0,0] = target[i_sigma][0,0,-1]
    stable_state[i_sigma,1,1,1,0] = target[i_sigma][0,1,-1]
    stable_state[i_sigma,1,1,0,1] = np.std(target_rates_e)
    stable_state[i_sigma,1,1,1,1] = np.std(target_rates_i)


    aln.params.duration = 300.
    control0 = aln.getZeroControl()
    control0[0,0,:500] = -5.

    target_rates_e = []
    target_rates_i = []

    stateswitchcount = 0

    for j in range(noise_realizations_final):
        aln.params.duration = 300.
        aln.run(control=control0)
        if np.amin(aln.rates_exc[0,1000:]) > 3.:
            print("fell in up state, repeat")
            j -= 1
            stateswitchcount += 1
            if stateswitchcount > 0.1 * noise_realizations_final:
                break
            continue
        target_rates_e.append(aln.rates_exc[0,1000:])
        target_rates_i.append(aln.rates_inh[0,1000:])

    stable_state[i_sigma,1,0,0,0] = np.mean(target_rates_e)
    stable_state[i_sigma,1,0,1,0] = np.mean(target_rates_i)
    stable_state[i_sigma,1,0,0,1] = np.std(target_rates_e)
    stable_state[i_sigma,1,0,1,1] = np.std(target_rates_i)

# %%
w_p = np.zeros((2))
for i_sigma in range(len(sigma_ou_array)):
    w_p[i_sigma] = 1. / ( ( stable_state[i_sigma,1,1,0,1] + stable_state[i_sigma,1,1,1,1] ) * (1. - trans_time) * dur )
w_e = 0.
w_s = 1.

aln.params.duration = dur
zero_init = aln.getZeroControl()

# %%
max_it = 15
init_it = 3
factor = [1.1, 1.5]

for i_sigma in range(len(sigma_ou_array)):
    
    cost.setParams(w_p[i_sigma], w_e, w_s)
    
    for i_noise in range(len(noise_realizations_array)):
        
        if i_sigma in []:
            continue
        if i_noise in []:
            continue

        noise_realizations = noise_realizations_array[i_noise]
        sigma_ou = sigma_ou_array[i_sigma]
        aln.params.sigma_ou = sigma_ou
        
        aln.params.duration = dur
        print(noise_realizations)
        
        if i_noise != 0.:

            setinit(initVars, aln)

            bestControl, bestState, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                zero_init, target[i_sigma], c_scheme, u_mat, u_scheme, max_iteration_ = init_it,
                tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                control_variables_ = [0], prec_variables_ = prec_vars, transition_time_ = trans_time,
                noise_real=noise_realizations, init_params = initVars, method='M2')

            control_init = bestControl[:,:,100:-100].copy()
            setinit(initVars, aln)
            aln.params.duration = dur

            bestControl, bestState, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                control_init, target[i_sigma], c_scheme, u_mat, u_scheme, max_iteration_ = max_it-init_it,
                tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                control_variables_ = [0,1], prec_variables_ = prec_vars, transition_time_ = trans_time,
                noise_real=noise_realizations, init_params = initVars,method='M2')


            control_[i_sigma][i_noise] = bestControl.copy()
        
        else:
            control_[i_sigma][i_noise] = factor[i_sigma] * c_noisefree[:,:,:]
        
        aln.params.duration = dur
        setinit(initVars, aln)

        init_control = aln.getZeroControl()   
        
        init_control[:,:,:] = control_[i_sigma][i_noise][:,:,100:-100]
            
        T = int(1 + dur/aln.params.dt)
        dt = aln.params.dt

        target_ = target[i_sigma].copy()
        target_[0,0,:int(trans_time * dur / aln.params.dt)] = -1000
        target_[0,1,:int(trans_time * dur / aln.params.dt)] = -1000

        cost_final = 0.
        cs = cost.numba_cost_sparsity_int(1, 6, T, w_s, dt, init_control)

        for n_ in range(noise_realizations_final):
            state_ = fo.updateState(aln, init_control)
            cost_final += cost.numba_cost_precision_int(1,T,dt,w_p[i_sigma],state_, target_, list(prec_vars) )

        cost_final_mean[i_sigma, i_noise] = cs + cost_final / noise_realizations_final
        print('mean = ', cost_final_mean[i_sigma, i_noise])
# Out:
# set cost params:  0.026384345159518752 0.0 1.0 0.0
# 0
# mean =  2.77016840033052
# 20
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3677.0587569485665
# Gradient descend method:  None
# RUN  1 , total integrated cost =  166.64358675353395
# RUN  2 , total integrated cost =  30.82583537542818
# RUN  3 , total integrated cost =  8.99228965125629
# RUN  3 , total integrated cost mean =  8.99228965125629
# Improved over  3  iterations in  4.89726274998975  seconds by  99.75544884524177  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  8.43018817466217
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.94088845619469
# RUN  2 , total integrated cost =  6.537017832980828
# RUN  3 , total integrated cost =  6.38414005251302
# step size too small or too large
# step size too small or too large
# RUN  4 , total integrated cost =  6.317490473374093
# RUN  5 , total integrated cost =  6.252427337899384
# RUN  6 , total integrated cost =  6.227115225646693
# RUN  7 , total integrated cost =  6.186392264031415
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  8 , total integrated cost =  6.202689808508101
# RUN  9 , total integrated cost =  6.160165165029274
# RUN  10 , total integrated cost =  6.119758353532693
# RUN  11 , total integrated cost =  6.095155206771013
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  12 , total integrated cost =  6.106464297533909
# RUN  12 , total integrated cost mean =  6.106464297533909
# Improved over  12  iterations in  21.65790838400426  seconds by  27.5643180079  percent.
# mean =  6.272787494901394
# 50
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3674.3082523696644
# Gradient descend method:  None
# RUN  1 , total integrated cost =  150.04405463031515
# RUN  2 , total integrated cost =  35.135033174446654
# RUN  3 , total integrated cost =  7.92927796882123
# RUN  3 , total integrated cost mean =  7.92927796882123
# Improved over  3  iterations in  6.3821251100016525  seconds by  99.78419671338932  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7.658585376129419
# Gradient descend method:  None
# step size too small or too large
# RUN  1 , total integrated cost =  6.2211886620808965
# RUN  2 , total integrated cost =  5.903732716705393
# step size too small or too large
# RUN  3 , total integrated cost =  5.764506941439699
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  4 , total integrated cost =  5.695874180488342
# RUN  5 , total integrated cost =  5.643586022778454
# step size too small or too large
# RUN  6 , total integrated cost =  5.594820192116893
# step size too small or too large
# RUN  7 , total integrated cost =  5.575891509903419
# step size too small or too large
# step size too small or too large
# RUN  8 , total integrated cost =  5.561717742215634
# step size too small or too large
# step size too small or too large
# RUN  9 , total integrated cost =  5.525434169316599
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  10 , total integrated cost =  5.518988641051161
# RUN  11 , total integrated cost =  5.481338720740731
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  12 , total integrated cost =  5.47567966880561
# RUN  12 , total integrated cost mean =  5.47567966880561
# Improved over  12  iterations in  72.300628899  seconds by  28.502727333008195  percent.
# mean =  5.62672141240348
# set cost params:  0.005277977576769487 0.0 1.0 0.0
# 0
# mean =  4.630496313801136
# 20
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  729.6600012664915
# Gradient descend method:  None
# RUN  1 , total integrated cost =  44.50777270359981
# RUN  2 , total integrated cost =  29.84192745517737
# RUN  3 , total integrated cost =  8.26718934959363
# RUN  3 , total integrated cost mean =  8.26718934959363
# Improved over  3  iterations in  5.670168950004154  seconds by  98.86698060257599  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7.354616021661296
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.841651708527036
# RUN  2 , total integrated cost =  6.81683454025908
# RUN  3 , total integrated cost =  6.457048947481615
# RUN  4 , total integrated cost =  6.264914928937712
# step size too small or too large
# RUN  5 , total integrated cost =  6.254109894987314
# RUN  6 , total integrated cost =  6.323237335339499
# RUN  7 , total integrated cost =  6.281307280578632
# RUN  8 , total integrated cost =  6.292845407323393
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  9 , total integrated cost =  6.211226459208197
# RUN  10 , total integrated cost =  6.073967833731791
# RUN  11 , total integrated cost =  6.101094838362585
# step size too small or too large
# RUN  12 , total integrated cost =  6.051767029867109
# RUN  12 , total integrated cost mean =  6.051767029867109
# Improved over  12  iterations in  24.934605187998386  seconds by  17.714711250144816  percent.
# mean =  6.367645729751268
# 50
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  735.8934780055959
# Gradient descend method:  None
# RUN  1 , total integrated cost =  53.17600743873813
# RUN  2 , total integrated cost =  25.969442091455953
# RUN  3 , total integrated cost =  8.289709684791124
# RUN  3 , total integrated cost mean =  8.289709684791124
# Improved over  3  iterations in  5.889949442993384  seconds by  98.87351771247413  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7.263950475239057
# Gradient descend method:  None
# step size too small or too large
# step size too small or too large
# RUN  1 , total integrated cost =  6.650210202558996
# RUN  2 , total integrated cost =  6.41323026571933
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  3 , total integrated cost =  6.251403153989177
# step size too small or too large
# step size too small or too large
# RUN  4 , total integrated cost =  6.224109198924646
# step size too small or too large
# RUN  5 , total integrated cost =  6.131596062820526
# step size too small or too large
# RUN  6 , total integrated cost =  5.99127062738535
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  7 , total integrated cost =  6.076481082019542
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  8 , total integrated cost =  5.934632962079713
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  9 , total integrated cost =  5.898912424894088
# RUN  10 , total integrated cost =  5.862483182370534
# RUN  11 , total integrated cost =  5.882584501426746
# step size too small or too large
# step size too small or too large
# RUN  12 , total integrated cost =  5.757646968896717
# RUN  12 , total integrated cost mean =  5.757646968896717
# Improved over  12  iterations in  55.45353236400115  seconds by  20.736698460113985  percent.
# mean =  6.094119531586206

# %%
fs_ = 26
fig, ax = plt.subplots(4, 3, figsize=(16,12), constrained_layout=True, facecolor='white',
                       gridspec_kw={'height_ratios': [3,2,3,2]})
#fig.suptitle('Point b', fontsize=fs_)
plot_realizations = 10
i = 50

t_array = np.arange(0,dur+aln.params.dt,aln.params.dt)
ax[0,0].set_title('DOC multiple', fontsize=fs_)

setinit(initVars, aln)
aln.params.duration = dur
target_ = aln.getZeroTarget()

for i_sigma in range(2):
    
    target_[0,0,:] = target[i_sigma][0,0,-1]
    target_[0,1,:] = target[i_sigma][0,1,-1]
    
    for i_noise in range(3):
        
        noise_realizations = noise_realizations_array[i_noise]
        sigma_ou = sigma_ou_array[i_sigma]
        aln.params.sigma_ou = sigma_ou
        
        if i_noise != 0:
            ax[0,i_noise].set_title(r'$N=$' + '{}'.format(noise_realizations) + ', M2', fontsize=fs_)

        ax[2*i_sigma+1,i_noise].plot( t_array, control_[i_sigma][i_noise][0,0,100:-100]/5., color=exc_red)
        ax[2*i_sigma+1,i_noise].plot( t_array, control_[i_sigma][i_noise][0,1,100:-100]/5., color=inh_blue)
        
        ax[2*i_sigma,i_noise].plot( t_array, target_[0,0,:], linestyle='--', color=exc_red)
        ax[2*i_sigma,i_noise].plot( t_array, target_[0,1,:], linestyle='--', color=inh_blue)

        for indexx in range(plot_realizations):
            aln.run(control=control_[i_sigma][i_noise][:,:,100:-100])
            ax[2*i_sigma,i_noise].plot( t_array, aln.rates_exc[0,:], color=exc_red)
            ax[2*i_sigma,i_noise].plot( t_array, aln.rates_inh[0,:], color=inh_blue)

        ax[2*i_sigma,i_noise].text(0.05, 0.7, r'$F = $' + '{:.2f}'.format(cost_final_mean[i_sigma, i_noise]),
                horizontalalignment='left', verticalalignment='top', transform=ax[2*i_sigma,i_noise].transAxes,
                bbox=dict(boxstyle='round', facecolor=midgrey, alpha=0.3), fontsize=fs_)
        
        ax[2*i_sigma+1,i_noise].text(0.05, 0.9, r'$a = $' + '{:.2f} nA'.format(
            max( np.amax(np.abs(control_[i_sigma][i_noise][0,0,100:-100]/5.)),
               np.amax(np.abs(control_[i_sigma][i_noise][0,1,100:-100]/5.))) ),
            horizontalalignment='left', verticalalignment='top', transform=ax[2*i_sigma+1,i_noise].transAxes,
            bbox=dict(boxstyle='round', facecolor=midgrey, alpha=0.3), fontsize=fs_)

for j in range(4):
    for k in range(3):
        ax[j,k].tick_params(axis='x', labelsize=fs_)
        ax[j,k].tick_params(axis='y', labelsize=fs_)
        ax[j,k].set_xlim(0,dur)
        ax[j,k].grid(False)
        if j != 3:
            ax[j,k].set_xticks([])
        else:
            ax[j,k].set_xlabel('Time [ms]', fontsize=fs_)
        ax[j,k].set_yticks([])
        if j%2 == 0:
            ax[j,k].set_ylim(0,110)
            sigma_ou = sigma_ou_array[int(j/2)]
            ax[j,k].axvspan( dur*trans_time, dur, facecolor=midgrey,
                            alpha=0.5, zorder=-1, hatch='///', edgecolor = midgrey)
        elif j%2 == 1:
            ax[j,k].set_ylim(-0.15,0.3)
            
    if j%2 == 0:
        ax[j,-1].set_yticks(np.arange(0,110,50))
        ax[j,-1].set_ylabel('Activity [Hz]', fontsize=fs_)
        ax[j,-1].yaxis.set_label_position("right")
        ax[j,-1].yaxis.tick_right()
        ax[j,0].text(-0.1,0.3, r'$\sigma=$'+'{:.2f}'.format(sigma_ou_array[int(j/2)]), rotation=90, size=fs_,
                 verticalalignment='bottom', horizontalalignment='center', transform=ax[j,0].transAxes)
    
    elif j%2 == 1:     
        ax[j,-1].set_yticks(np.arange(-0.1,0.31,0.1))
        ax[j,-1].set_ylabel('Control [nA]', fontsize=fs_)
        ax[j,-1].yaxis.set_label_position("right")
        ax[j,-1].yaxis.tick_right()

filename_ = nb[:-6] + '.png'
    
fig.savefig(filename_)
fig.savefig(os.path.join(savepath, filename_))
plt.show()

# %%
n_noise = 3
control_1 = [ [None] * n_noise, [None] * n_noise, [None] * n_noise ]

# %%
for i_sigma in range(2):
    
    cost.setParams(w_p[i_sigma], w_e, w_s)
    
    for i_noise in [1,2]:
        
        if i_sigma in []:
            continue

        noise_realizations = noise_realizations_array[i_noise]
        sigma_ou = sigma_ou_array[i_sigma]
        aln.params.sigma_ou = sigma_ou
        
        aln.params.duration = dur
        zero_init = aln.getZeroControl()
        print(noise_realizations)

        setinit(initVars, aln)

        bestControl, bestState, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
            zero_init, target[i_sigma], c_scheme, u_mat, u_scheme, max_iteration_ = init_it,
            tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
            t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
            control_variables_ = [0], prec_variables_ = prec_vars, transition_time_ = trans_time,
            noise_real=noise_realizations, init_params = initVars, method='M2')

        control_init = bestControl[:,:,100:-100].copy()
        setinit(initVars, aln)
        aln.params.duration = dur

        bestControl, bestState, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
            control_init, target[i_sigma], c_scheme, u_mat, u_scheme, max_iteration_ = max_it-init_it,
            tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
            t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
            control_variables_ = [0,1], prec_variables_ = prec_vars, transition_time_ = trans_time,
            noise_real=noise_realizations, init_params = initVars, method='M2')

        control_1[i_sigma][i_noise] = bestControl.copy()
# Out:
# set cost params:  0.026384345159518752 0.0 1.0 0.0
# 20
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3670.923333980292
# Gradient descend method:  None
# RUN  1 , total integrated cost =  152.30034759929794
# RUN  2 , total integrated cost =  28.260920639242137
# RUN  3 , total integrated cost =  8.50715422482245
# RUN  3 , total integrated cost mean =  8.50715422482245
# Improved over  3  iterations in  1.3359620889968937  seconds by  99.76825573702193  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  8.182824355958969
# Gradient descend method:  None
# step size too small or too large
# RUN  1 , total integrated cost =  6.598335485456782
# RUN  2 , total integrated cost =  6.199987130129777
# step size too small or too large
# RUN  3 , total integrated cost =  6.0672248534863
# RUN  4 , total integrated cost =  5.99190473485246
# RUN  5 , total integrated cost =  5.974818049332695
# step size too small or too large
# step size too small or too large
# RUN  6 , total integrated cost =  5.918810841486903
# RUN  7 , total integrated cost =  5.888475962962184
# RUN  8 , total integrated cost =  5.857007970939338
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  9 , total integrated cost =  5.849608493399678
# RUN  10 , total integrated cost =  5.824124711647182
# RUN  11 , total integrated cost =  5.800532439045676
# step size too small or too large
# RUN  12 , total integrated cost =  5.774051644319646
# RUN  12 , total integrated cost mean =  5.774051644319646
# Improved over  12  iterations in  11.144045983994147  seconds by  29.43693530321454  percent.
# 50
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3671.8942240933907
# Gradient descend method:  None
# RUN  1 , total integrated cost =  153.9943675347508
# RUN  2 , total integrated cost =  40.71680386762386
# RUN  3 , total integrated cost =  7.175232874763346
# RUN  3 , total integrated cost mean =  7.175232874763346
# Improved over  3  iterations in  3.4238055820023874  seconds by  99.80459042562603  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  6.9163976795769795
# Gradient descend method:  None
# step size too small or too large
# step size too small or too large
# RUN  1 , total integrated cost =  5.499023787734436
# step size too small or too large
# step size too small or too large
# RUN  2 , total integrated cost =  5.061528225032878
# RUN  3 , total integrated cost =  4.92330001989036
# step size too small or too large
# RUN  4 , total integrated cost =  4.837633807308743
# RUN  5 , total integrated cost =  4.789862997540876
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  6 , total integrated cost =  4.752270115958477
# step size too small or too large
# RUN  7 , total integrated cost =  4.722094578556289
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  8 , total integrated cost =  4.699704653377289
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  9 , total integrated cost =  4.680368886156825
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  10 , total integrated cost =  4.6817132605395635
# step size too small or too large
# RUN  11 , total integrated cost =  4.663208366200975
# step size too small or too large
# step size too small or too large
# RUN  12 , total integrated cost =  4.661779949494856
# RUN  12 , total integrated cost mean =  4.661779949494856
# Improved over  12  iterations in  54.259075602996745  seconds by  32.59815057684797  percent.
# set cost params:  0.005277977576769487 0.0 1.0 0.0
# 20
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  733.1739771437086
# Gradient descend method:  None
# RUN  1 , total integrated cost =  46.35466860773862
# RUN  2 , total integrated cost =  23.106617102824664
# RUN  3 , total integrated cost =  7.43947387242861
# RUN  3 , total integrated cost mean =  7.43947387242861
# Improved over  3  iterations in  2.2480216519907117  seconds by  98.98530579312003  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7.335345926032183
# Gradient descend method:  None
# step size too small or too large
# step size too small or too large
# RUN  1 , total integrated cost =  6.598527254371322
# RUN  2 , total integrated cost =  6.502468357094775
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  3 , total integrated cost =  6.297668734131662
# RUN  4 , total integrated cost =  6.277667930871538
# RUN  5 , total integrated cost =  6.262809092399051
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  6 , total integrated cost =  6.132065730340243
# step size too small or too large
# RUN  7 , total integrated cost =  6.167913845326084
# RUN  8 , total integrated cost =  5.990856554863926
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  9 , total integrated cost =  5.891555609873455
# step size too small or too large
# RUN  10 , total integrated cost =  6.044895797219324
# step size too small or too large
# RUN  11 , total integrated cost =  5.968148085135701
# RUN  12 , total integrated cost =  5.898198136920966
# RUN  12 , total integrated cost mean =  5.898198136920966
# Improved over  12  iterations in  17.131824392999988  seconds by  19.592092910178465  percent.
# 50
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  735.9894542422248
# Gradient descend method:  None
# RUN  1 , total integrated cost =  52.55861140293288
# RUN  2 , total integrated cost =  25.360540043915922
# RUN  3 , total integrated cost =  8.863227508505394
# RUN  3 , total integrated cost mean =  8.863227508505394
# Improved over  3  iterations in  4.315471070993226  seconds by  98.79573987678519  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  8.192750772008173
# Gradient descend method:  None
# step size too small or too large
# step size too small or too large
# RUN  1 , total integrated cost =  7.5420568268427495
# RUN  2 , total integrated cost =  7.388035099532305
# step size too small or too large
# step size too small or too large
# RUN  3 , total integrated cost =  7.141745094479827
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  4 , total integrated cost =  7.116612010509923
# step size too small or too large
# RUN  5 , total integrated cost =  7.034055051503385
# step size too small or too large
# step size too small or too large
# RUN  6 , total integrated cost =  7.003978973832499
# step size too small or too large
# RUN  7 , total integrated cost =  6.974281380410911
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  8 , total integrated cost =  6.902327646315989
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  9 , total integrated cost =  6.822561356004388
# step size too small or too large
# RUN  10 , total integrated cost =  6.861890882652742
# step size too small or too large
# step size too small or too large
# RUN  11 , total integrated cost =  6.7275424006714095
# RUN  12 , total integrated cost =  6.687779547512686
# RUN  12 , total integrated cost mean =  6.687779547512686
# Improved over  12  iterations in  51.308977331995266  seconds by  18.369547254353918  percent.

# %%
fig, ax = plt.subplots(4, 3, figsize=(16,12), constrained_layout=True, facecolor='white',
                       gridspec_kw={'height_ratios': [3,2,3,2]})
plot_realizations = 10
i = 50

t_array = np.arange(0,dur+aln.params.dt,aln.params.dt)
ax[0,0].set_title('DOC multiple', fontsize=fs_)

setinit(initVars, aln)
aln.params.duration = dur
target_ = aln.getZeroTarget()

for i_sigma in range(len(sigma_ou_array)):
    
    target_[0,0,:] = target[i_sigma][0,0,-1]
    target_[0,1,:] = target[i_sigma][0,1,-1]
    
    for i_noise in range(3):
        
        noise_realizations = noise_realizations_array[i_noise]
        sigma_ou = sigma_ou_array[i_sigma]
        aln.params.sigma_ou = sigma_ou
        
        if i_noise != 0:
            ax[0,i_noise].set_title(r'$N=$' + '{}'.format(noise_realizations) + ', M2', fontsize=fs_)
            ax[2*i_sigma+1,i_noise].plot( t_array, control_1[i_sigma][i_noise][0,0,100:-100]/5.,
                                         color=exc_red, linestyle='dotted')
            ax[2*i_sigma+1,i_noise].plot( t_array, control_1[i_sigma][i_noise][0,1,100:-100]/5.,
                                         color=inh_blue, linestyle='dotted')

        ax[2*i_sigma+1,i_noise].plot( t_array, control_[i_sigma][i_noise][0,0,100:-100]/5.,
                                     color=exc_red, linewidth=1)
        ax[2*i_sigma+1,i_noise].plot( t_array, control_[i_sigma][i_noise][0,1,100:-100]/5.,
                                     color=inh_blue, linewidth=1)
        
        ax[2*i_sigma,i_noise].plot( t_array, target_[0,0,:], linestyle='--', color=exc_red)
        ax[2*i_sigma,i_noise].plot( t_array, target_[0,1,:], linestyle='--', color=inh_blue)

        for indexx in range(plot_realizations):
            aln.run(control=control_[i_sigma][i_noise][:,:,100:-100])
            ax[2*i_sigma,i_noise].plot( t_array, aln.rates_exc[0,:], color=exc_red, linewidth=1)
            ax[2*i_sigma,i_noise].plot( t_array, aln.rates_inh[0,:], color=inh_blue, linewidth=1)

        ax[2*i_sigma,i_noise].text(0.05, 0.8, r'$F = $' + '{:.2f}'.format(cost_final_mean[i_sigma, i_noise]),
                horizontalalignment='left', verticalalignment='top', transform=ax[2*i_sigma,i_noise].transAxes,
                bbox=dict(boxstyle='round', facecolor=midgrey, alpha=0.3), fontsize=fs_)
        
        ax[2*i_sigma+1,i_noise].text(0.05, 0.9, r'$a = $' + '{:.2f} nA'.format(
            np.amax(control_[i_sigma][i_noise][0,0,100:-100]/5.)), horizontalalignment='left',
            verticalalignment='top', transform=ax[2*i_sigma+1,i_noise].transAxes,
            bbox=dict(boxstyle='round', facecolor=midgrey, alpha=0.3), fontsize=fs_)

for j in range(4):
    for k in range(3):
        ax[j,k].tick_params(axis='x', labelsize=fs_)
        ax[j,k].tick_params(axis='y', labelsize=fs_)
        ax[j,k].set_xlim(0,dur)
        ax[j,k].grid(False)
        if j != 3:
            ax[j,k].set_xticks([])
        else:
            ax[j,k].set_xlabel('Time [ms]', fontsize=fs_)
        ax[j,k].set_yticks([])
        if j%2 == 0:
            ax[j,k].set_ylim(0,110)
            sigma_ou = sigma_ou_array[int(j/2)]
            ax[j,k].axvspan( dur*trans_time, dur, facecolor=midgrey,
                            alpha=0.5, zorder=-1, hatch='///', edgecolor = midgrey)
        elif j%2 == 1:
            ax[j,k].set_ylim(-0.2,0.4)
            
    if j%2 == 0:
        ax[j,-1].set_yticks(np.arange(0,110,50))
        ax[j,-1].set_ylabel('Activity [Hz]', fontsize=fs_)
        ax[j,-1].yaxis.set_label_position("right")
        ax[j,-1].yaxis.tick_right()
        ax[j,0].text(-0.1,0.3, r'$\sigma=$'+'{:.2f}'.format(sigma_ou_array[int(j/2)]), rotation=90, size=fs_,
                 verticalalignment='bottom', horizontalalignment='center', transform=ax[j,0].transAxes)
    
    elif j%2 == 1:     
        ax[j,-1].set_yticks(np.arange(-0.2,0.41,0.2))
        ax[j,-1].set_ylabel('Control [nA]', fontsize=fs_)
        ax[j,-1].yaxis.set_label_position("right")
        ax[j,-1].yaxis.tick_right()

nb = ipyparams.notebook_name
filename_ = nb[:-6] + '_1.png'
    
fig.savefig(filename_)
fig.savefig(os.path.join(savepath, filename_))
plt.show()
