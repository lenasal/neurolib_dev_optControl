# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import sys
import pickle
import matplotlib
import ipyparams

path = os.getcwd().split(os.sep + 'GUI')[0]
if path not in sys.path:
    print("not here")
    sys.path.append(path)

from neurolib_dev_optControl.neurolib.models.aln import ALNModel
from neurolib_dev_optControl.neurolib.utils import plotFunctions as plotFunc
from neurolib_dev_optControl.neurolib.utils import func_optimize as fo
from neurolib_dev_optControl.neurolib.utils import costFunctions as cost
import neurolib_dev_optControl.neurolib.dashboard.functions as functions
import neurolib_dev_optControl.neurolib.dashboard.data as data
import neurolib_dev_optControl.neurolib.dashboard.layout as layout
    
# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2 

#path = os.path.join(os.getcwd(), "plots")

cmap_ = layout.getcolormap()
darkgrey, midgrey, lightgrey, color_bi_updown, color_LC, color_bi_uposc = layout.getcolors_rgba()
exc_red = cmap_(3)
inh_blue=cmap_(0)
green = cmap_(2)
# Out:
# not here

# %%
aln = ALNModel()
N = aln.params.N

data.set_parameters(aln)

state_vars = aln.state_vars
init_vars = aln.init_vars

##############################################################
def setinit(init_vars_, model):
    state_vars = model.state_vars
    init_vars = model.init_vars
    for iv in range(len(init_vars)):
        for sv in range(len(state_vars)):
            if state_vars[sv] in init_vars[iv]:
                #print("set init vars ", )
                if model.params[init_vars[iv]].ndim == 2:
                    model.params[init_vars[iv]][0,:] = init_vars_[sv]
                else:
                    model.params[init_vars[iv]][0] = init_vars_[sv]
                    
##############################################################               
def setmaxmincontrol(max_c_c, min_c_c, max_c_r, min_c_r):
    import numpy as np
    
    max_cntrl = np.zeros(( 6 ))
    min_cntrl = np.zeros(( 6 ))
    
    max_cntrl[0] = max_c_c
    min_cntrl[0] = min_c_c
    max_cntrl[1] = max_c_c
    min_cntrl[1] = min_c_c
    max_cntrl[2] = max_c_r
    min_cntrl[2] = min_c_r
    max_cntrl[3] = max_c_r
    min_cntrl[3] = min_c_r
    max_cntrl[4] = max_c_r
    min_cntrl[4] = min_c_r
    max_cntrl[5] = max_c_r
    min_cntrl[5] = min_c_r
            
    return max_cntrl, min_cntrl

# %%
savepath = (os.getcwd().split('neurolib')[0] + 'Talks_Conf_Workshops_Schools' + os.sep + '22' + os.sep + 'FRANCE22' + 
     os.sep + 'ENCODS' + os.sep + 'poster' + os.sep + 'images')

exc = 0.5
inh = 0.5

# %%
dur_pre = 10
dur_post = 10
dur = 200.
dt = aln.params.dt
T = int(1 + dur / dt)

max_it = 10
init_it = 10
prec_vars = [0,1]
trans_time = 0.8
repeat = 20

n_pre = int(np.around(dur_pre/aln.params.dt + 1.,1))
n_post = int(np.around(dur_post/aln.params.dt + 1.,1))

tol = 1e-32
start_step = 10.
c_scheme = np.zeros(( 1,1 ))
c_scheme[0,0] = 1.
u_mat = np.identity(1)
u_scheme = np.array([[1.]])

maxC = [5., -5., 0.18, 0.]
n_dur = int(np.around(dur/aln.params.dt + 1.,1))
max_cntrl, min_cntrl = setmaxmincontrol(maxC[0], maxC[1], maxC[2], maxC[3])

nb = ipyparams.notebook_name
print('nb = ', nb)

case = str(nb[4])
# Out:
# nb =  DU_M1.ipynb

# %%
i = 28
t_range=[1500,3701]

noisefree_file = '..' + os.sep + '..' + os.sep + 'data_final_2' + os.sep + 'control_1.pickle'
file = open(noisefree_file, "rb")
noisefree = pickle.load(file)
file.close()
    
c_noisefree = noisefree[0][i][:,:,t_range[0]:t_range[1]]
plt.plot(c_noisefree[0,0,:])
plt.show()

# %%
sigma_ou_array = [0.01, 0.05]
noise_realizations_array = [0,20,50]
noise_realizations_final = 10000

# %%
n_sig = len(sigma_ou_array)
n_noise = len(noise_realizations_array)

int_t_pen = np.around( (1. - trans_time)*dur/aln.params.dt, 1).astype(int)

cost_final_mean = np.zeros(( n_sig,n_noise ))
target = [None] * n_sig
control_ = [ [None] * n_noise, [None] * n_noise ]
cost_ = control_.copy()
cost_final = control_.copy()

stable_state = np.zeros(( n_noise, 2,2,2, 2))

# %%
cost_final_mean = np.zeros(( n_sig,n_noise ))

# %%
# get init vars without noise
aln = ALNModel()
data.set_parameters(aln)
aln.params.duration = 3000.

# initial without noise
control0 = aln.getZeroControl()
control0[0,0,:500] = -5.

aln.params.ext_exc_current = exc * 5.
aln.params.ext_inh_current = inh * 5.

aln.run(control=control0)

init_state_vars = np.zeros(( len(state_vars) ))
for j in range(len(state_vars)):
    if aln.state[state_vars[j]].size == 1:
        init_state_vars[j] = aln.state[state_vars[j]][0]
    else:
        init_state_vars[j] = aln.state[state_vars[j]][0,-1]

initVars = init_state_vars

# %%
for i_sigma in range(len(sigma_ou_array)):
    
    sigma_ou = sigma_ou_array[i_sigma]
    aln.params.sigma_ou = sigma_ou
    

    aln.params.duration = dur
    control0 = aln.getZeroControl()
    control0[0,0,:500] = 5.

    target_rates_e = []
    target_rates_i = []

    stateswitchcount = 0

    for j in range(noise_realizations_final):
        aln.params.duration = dur
        aln.run(control=control0)
        if np.amin(aln.rates_exc[0,1000:]) < 1.:
            print("fell in down state, repeat")
            j -= 1
            stateswitchcount += 1
            if stateswitchcount > 0.1 * noise_realizations_final:
                break
            continue
        target_rates_e.append(aln.rates_exc[0,1000:])
        target_rates_i.append(aln.rates_inh[0,1000:])

    aln.params.duration = dur
    target[i_sigma] = aln.getZeroTarget()
    target[i_sigma][:,0,:] = np.mean(target_rates_e)
    target[i_sigma][:,1,:] = np.mean(target_rates_i)

    stable_state[i_sigma,1,1,0,0] = target[i_sigma][0,0,-1]
    stable_state[i_sigma,1,1,1,0] = target[i_sigma][0,1,-1]
    stable_state[i_sigma,1,1,0,1] = np.std(target_rates_e)
    stable_state[i_sigma,1,1,1,1] = np.std(target_rates_i)


    aln.params.duration = 300.
    control0 = aln.getZeroControl()
    control0[0,0,:500] = -5.

    target_rates_e = []
    target_rates_i = []

    stateswitchcount = 0

    for j in range(noise_realizations_final):
        aln.params.duration = 300.
        aln.run(control=control0)
        if np.amin(aln.rates_exc[0,1000:]) > 3.:
            print("fell in up state, repeat")
            j -= 1
            stateswitchcount += 1
            if stateswitchcount > 0.1 * noise_realizations_final:
                break
            continue
        target_rates_e.append(aln.rates_exc[0,1000:])
        target_rates_i.append(aln.rates_inh[0,1000:])

    stable_state[i_sigma,1,0,0,0] = np.mean(target_rates_e)
    stable_state[i_sigma,1,0,1,0] = np.mean(target_rates_i)
    stable_state[i_sigma,1,0,0,1] = np.std(target_rates_e)
    stable_state[i_sigma,1,0,1,1] = np.std(target_rates_i)

# %%
w_p = np.zeros((2))
for i_sigma in range(len(sigma_ou_array)):
    w_p[i_sigma] = 1. / ( ( stable_state[i_sigma,1,1,0,1] + stable_state[i_sigma,1,1,1,1] ) * (1. - trans_time) * dur )
w_e = 0.
w_s = 1.

aln.params.duration = dur
zero_init = aln.getZeroControl()

# %%
max_it = 15
init_it = 3
factor = [1.1, 1.5]

for i_sigma in range(len(sigma_ou_array)):
    
    cost.setParams(w_p[i_sigma], w_e, w_s)
    
    for i_noise in range(len(noise_realizations_array)):
        
        if i_noise in []:
            continue
            
        if i_sigma in [0]:
            continue

        noise_realizations = noise_realizations_array[i_noise]
        sigma_ou = sigma_ou_array[i_sigma]
        aln.params.sigma_ou = sigma_ou
        
        aln.params.duration = dur
        
        n_ = 0
        control_sum = np.zeros(( c_noisefree[:,:,:].shape ))
        
        print(noise_realizations)
        
        if i_noise != 0.:
            while n_  < noise_realizations:
                
                print('--------', n_)

                setinit(initVars, aln)

                bestControl, bestState, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                    zero_init, target[i_sigma], c_scheme, u_mat, u_scheme, max_iteration_ = init_it,
                    tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                    t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                    control_variables_ = [0], prec_variables_ = prec_vars, transition_time_ = trans_time,
                    noise_real=0, init_params = initVars)
                
                if np.isnan(c_[-1]):
                    continue

                max_jump = 0.
                for v_ in range(bestControl.shape[1]):
                    for t_ in range(1, bestControl.shape[2]):
                        diff = np.abs(bestControl[0,v_,t_] - bestControl[0,v_,t_-1])
                        if  diff > max_jump:
                            max_jump = diff

                if max_jump > 0.5:
                    continue

                control_init = bestControl[:,:,100:-100].copy()
                setinit(initVars, aln)
                aln.params.duration = dur

                bestControl, bestState, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                    control_init, target[i_sigma], c_scheme, u_mat, u_scheme, max_iteration_ = max_it-init_it,
                    tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                    t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                    control_variables_ = [0,1], prec_variables_ = prec_vars, transition_time_ = trans_time,
                    noise_real=0, init_params = initVars)
                
                    
                if np.isnan(c_[-1]):
                    continue

                max_jump = 0.
                for v_ in range(bestControl.shape[1]):
                    for t_ in range(1, bestControl.shape[2]):
                        diff = np.abs(bestControl[0,v_,t_] - bestControl[0,v_,t_-1])
                        if  diff > max_jump:
                            max_jump = diff

                if max_jump > 0.5:
                    continue
                    
                control_sum += bestControl
            
                n_ += 1
    

            control_[i_sigma][i_noise] = control_sum / noise_realizations
        
        else:
            control_[i_sigma][i_noise] = factor[i_sigma] * c_noisefree
        
        aln.params.duration = dur
        setinit(initVars, aln)

        init_control = aln.getZeroControl()           
        init_control[:,:,:] = control_[i_sigma][i_noise][:,:,100:-100]
        T = int(1 + dur/aln.params.dt)
        dt = aln.params.dt

        target_ = target[i_sigma].copy()
        target_[0,0,:int(trans_time * dur / aln.params.dt)] = -1000
        target_[0,1,:int(trans_time * dur / aln.params.dt)] = -1000

        cost_final = 0.
        cs = cost.numba_cost_sparsity_int(1, 6, T, w_s, dt, init_control)

        for n_ in range(noise_realizations_final):
            state_ = fo.updateState(aln, init_control)
            cost_final += cost.numba_cost_precision_int(1,T,dt,w_p[i_sigma],state_, target_, list(prec_vars) )
            

        cost_final_mean[i_sigma, i_noise] = cs + cost_final/noise_realizations_final
        print('mean = ', cost_final_mean[i_sigma, i_noise])
# Out:
# set cost params:  0.026443288126800784 0.0 1.0 0.0
# 0
# /home/lena/.local/lib/python3.9/site-packages/numba/core/ir_utils.py:2119: NumbaPendingDeprecationWarning:
# Encountered the use of a type that is scheduled for deprecation: type 'reflected list' found for argument 'var_' of function 'numba_cost_precision_int'.
#
# For more information visit https://numba.pydata.org/numba-doc/latest/reference/deprecation.html#deprecation-of-reflection-for-list-and-set-types
#
# File "../../../../../neurolib/utils/costFunctions.py", line 89:
# @numba.njit
# def numba_cost_precision_int(N, T, dt, i_p, state_, target_state_, var_):
# ^
#
#   warnings.warn(NumbaPendingDeprecationWarning(msg, loc=loc))
# mean =  2.769992974206046
# 20
# -------- 0
# interpolate adjoint :  True True True
# initial cost =  3685.2101813814616
# RUN  0 , total integrated cost =  3685.2101813814616
# Gradient descend method:  None
# RUN  1 , total integrated cost =  188.66698854918218
# RUN  2 , total integrated cost =  30.44276234602449
# RUN  3 , total integrated cost =  8.155448738939922
# RUN  3 , total integrated cost =  8.155448738939922
# Improved over  3  iterations in  12.49472668299859  seconds by  99.77869786694546  percent.
# interpolate adjoint :  True True True
# initial cost =  8.360055585974914
# RUN  0 , total integrated cost =  8.360055585974914
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.522589573798594
# RUN  2 , total integrated cost =  6.308942363494105
# RUN  3 , total integrated cost =  6.151152924485815
# RUN  4 , total integrated cost =  6.210969295020421
# RUN  5 , total integrated cost =  6.074664206681563
# RUN  6 , total integrated cost =  6.03874105889901
# RUN  7 , total integrated cost =  6.031827421753226
# RUN  8 , total integrated cost =  6.021031888346573
# RUN  9 , total integrated cost =  6.142474048339398
# RUN  10 , total integrated cost =  6.005259327991269
# RUN  11 , total integrated cost =  5.991823250818704
# RUN  12 , total integrated cost =  5.8852888680562
# RUN  12 , total integrated cost =  5.8852888680562
# Improved over  12  iterations in  0.8216305059904698  seconds by  29.602275875658748  percent.
# -------- 1
# interpolate adjoint :  True True True
# initial cost =  3688.6750585192863
# RUN  0 , total integrated cost =  3688.6750585192863
# Gradient descend method:  None
# RUN  1 , total integrated cost =  154.5114837608216
# RUN  2 , total integrated cost =  72.75288267616659
# RUN  3 , total integrated cost =  13.086904528392289
# RUN  3 , total integrated cost =  13.086904528392289
# Improved over  3  iterations in  0.11821459900238551  seconds by  99.6452139502457  percent.
# interpolate adjoint :  True True True
# initial cost =  14.769018254229202
# RUN  0 , total integrated cost =  14.769018254229202
# Gradient descend method:  None
# RUN  1 , total integrated cost =  10.012199919632964
# RUN  2 , total integrated cost =  9.04548103077587
# RUN  3 , total integrated cost =  8.723230412371176
# RUN  4 , total integrated cost =  8.606598731334357
# RUN  5 , total integrated cost =  8.478528002391887
# RUN  6 , total integrated cost =  8.372454919043722
# RUN  7 , total integrated cost =  8.26740169248469
# RUN  8 , total integrated cost =  8.332958876318044
# RUN  9 , total integrated cost =  8.313206780695335
# RUN  10 , total integrated cost =  8.287740155686373
# RUN  11 , total integrated cost =  8.275605068646335
# RUN  12 , total integrated cost =  8.294778431044419
# RUN  12 , total integrated cost =  8.294778431044419
# Improved over  12  iterations in  0.8255561199912336  seconds by  43.836629569679374  percent.
# -------- 2
# interpolate adjoint :  True True True
# initial cost =  3680.355536487594
# RUN  0 , total integrated cost =  3680.355536487594
# Gradient descend method:  None
# RUN  1 , total integrated cost =  137.11975556882055
# RUN  2 , total integrated cost =  28.05486379156495
# RUN  3 , total integrated cost =  8.438202100609187
# RUN  3 , total integrated cost =  8.438202100609187
# Improved over  3  iterations in  0.11570927700086031  seconds by  99.7707231810364  percent.
# interpolate adjoint :  True True True
# initial cost =  8.960958535598234
# RUN  0 , total integrated cost =  8.960958535598234
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.8077316974175295
# RUN  2 , total integrated cost =  5.5147359787307
# RUN  3 , total integrated cost =  5.326830934176828
# RUN  4 , total integrated cost =  5.32296168574344
# RUN  5 , total integrated cost =  5.220967181852353
# RUN  6 , total integrated cost =  5.183189237980582
# RUN  7 , total integrated cost =  5.180382014425842
# RUN  8 , total integrated cost =  5.2042365494773035
# RUN  9 , total integrated cost =  5.1941805293342584
# RUN  10 , total integrated cost =  5.147444409828074
# RUN  11 , total integrated cost =  5.073462012134218
# RUN  12 , total integrated cost =  5.088226658434319
# RUN  12 , total integrated cost =  5.088226658434319
# Improved over  12  iterations in  0.7959573539992562  seconds by  43.21783056778056  percent.
# -------- 3
# interpolate adjoint :  True True True
# initial cost =  3682.0143783559515
# RUN  0 , total integrated cost =  3682.0143783559515
# Gradient descend method:  None
# RUN  1 , total integrated cost =  135.6710458906797
# RUN  2 , total integrated cost =  33.60135827243703
# RUN  3 , total integrated cost =  10.304699330217385
# RUN  3 , total integrated cost =  10.304699330217385
# Improved over  3  iterations in  0.10932196800422389  seconds by  99.72013419092572  percent.
# interpolate adjoint :  True True True
# initial cost =  10.605813805612677
# RUN  0 , total integrated cost =  10.605813805612677
# Gradient descend method:  None
# RUN  1 , total integrated cost =  8.068141166313788
# RUN  2 , total integrated cost =  7.719210748626517
# RUN  3 , total integrated cost =  7.611923539246923
# RUN  4 , total integrated cost =  7.463011203487175
# step size too small or too large
# RUN  5 , total integrated cost =  7.395840085107309
# RUN  6 , total integrated cost =  7.34729144072434
# RUN  7 , total integrated cost =  7.322183113858789
# RUN  8 , total integrated cost =  7.319463706606501
# RUN  9 , total integrated cost =  7.39615301016311
# RUN  10 , total integrated cost =  7.355287681214437
# RUN  11 , total integrated cost =  7.40032067315678
# RUN  12 , total integrated cost =  7.365088256279499
# RUN  12 , total integrated cost =  7.365088256279499
# Improved over  12  iterations in  0.9873328870016849  seconds by  30.5561233558349  percent.
# -------- 4
# interpolate adjoint :  True True True
# initial cost =  3656.72461409571
# RUN  0 , total integrated cost =  3656.72461409571
# Gradient descend method:  None
# RUN  1 , total integrated cost =  158.73683125626007
# RUN  2 , total integrated cost =  38.636421726745155
# RUN  3 , total integrated cost =  12.04452690052397
# RUN  3 , total integrated cost =  12.04452690052397
# Improved over  3  iterations in  0.11233507600263692  seconds by  99.67061979854607  percent.
# interpolate adjoint :  True True True
# initial cost =  12.288965668781845
# RUN  0 , total integrated cost =  12.288965668781845
# Gradient descend method:  None
# RUN  1 , total integrated cost =  9.708317971367135
# RUN  2 , total integrated cost =  8.95956772369522
# RUN  3 , total integrated cost =  8.860994403404916
# RUN  4 , total integrated cost =  8.76054809169821
# RUN  5 , total integrated cost =  8.653675948442602
# RUN  6 , total integrated cost =  8.639712474639106
# RUN  7 , total integrated cost =  8.634810865647909
# RUN  8 , total integrated cost =  8.558520536387602
# RUN  9 , total integrated cost =  8.542549591817286
# RUN  10 , total integrated cost =  8.592245692107703
# RUN  11 , total integrated cost =  8.573627189300492
# RUN  12 , total integrated cost =  8.548213159088231
# RUN  12 , total integrated cost =  8.548213159088231
# Improved over  12  iterations in  0.8156793860107427  seconds by  30.439929693972516  percent.
# -------- 5
# interpolate adjoint :  True True True
# initial cost =  3693.591167993411
# RUN  0 , total integrated cost =  3693.591167993411
# Gradient descend method:  None
# RUN  1 , total integrated cost =  155.92787293494004
# RUN  2 , total integrated cost =  119.0372655683089
# RUN  3 , total integrated cost =  72.03796014556322
# RUN  3 , total integrated cost =  72.03796014556322
# Improved over  3  iterations in  0.11596018700220156  seconds by  98.04964987002883  percent.
# interpolate adjoint :  True True True
# initial cost =  74.69238209564669
# RUN  0 , total integrated cost =  74.69238209564669
# Gradient descend method:  None
# RUN  1 , total integrated cost =  25.596066657263595
# RUN  2 , total integrated cost =  21.85922930168027
# RUN  3 , total integrated cost =  21.044972245720064
# RUN  4 , total integrated cost =  20.752347817717745
# RUN  5 , total integrated cost =  20.52857402989019
# RUN  6 , total integrated cost =  20.42628810189766
# RUN  7 , total integrated cost =  20.348382273316574
# RUN  8 , total integrated cost =  20.259660040487585
# RUN  9 , total integrated cost =  20.19282690648781
# RUN  10 , total integrated cost =  20.140238354020035
# RUN  11 , total integrated cost =  20.184522350840506
# RUN  12 , total integrated cost =  20.166496620141675
# RUN  12 , total integrated cost =  20.166496620141675
# Improved over  12  iterations in  0.7838050029968144  seconds by  73.00059784635381  percent.
# -------- 5
# interpolate adjoint :  True True True
# initial cost =  3676.7684510456384
# RUN  0 , total integrated cost =  3676.7684510456384
# Gradient descend method:  None
# RUN  1 , total integrated cost =  152.49148373031076
# RUN  2 , total integrated cost =  38.382940093212504
# RUN  3 , total integrated cost =  10.050642723566408
# RUN  3 , total integrated cost =  10.050642723566408
# Improved over  3  iterations in  0.15258634800557047  seconds by  99.72664466480863  percent.
# interpolate adjoint :  True True True
# initial cost =  10.206178544935092
# RUN  0 , total integrated cost =  10.206178544935092
# Gradient descend method:  None
# RUN  1 , total integrated cost =  8.63735634413829
# RUN  2 , total integrated cost =  8.18137796075696
# RUN  3 , total integrated cost =  7.896675842948937
# RUN  4 , total integrated cost =  7.74607970645331
# RUN  5 , total integrated cost =  7.593214575419157
# RUN  6 , total integrated cost =  7.641188727485433
# RUN  7 , total integrated cost =  7.562226815868042
# RUN  8 , total integrated cost =  7.5338291796384915
# RUN  9 , total integrated cost =  7.445538753052151
# RUN  10 , total integrated cost =  7.424264922847067
# RUN  11 , total integrated cost =  7.3851274227411885
# RUN  12 , total integrated cost =  7.404683375620797
# RUN  12 , total integrated cost =  7.404683375620797
# Improved over  12  iterations in  0.924036113996408  seconds by  27.449011958590148  percent.
# -------- 6
# interpolate adjoint :  True True True
# initial cost =  3687.966433125152
# RUN  0 , total integrated cost =  3687.966433125152
# Gradient descend method:  None
# RUN  1 , total integrated cost =  161.8026242865674
# RUN  2 , total integrated cost =  96.11563765163474
# RUN  3 , total integrated cost =  48.210338860824635
# RUN  3 , total integrated cost =  48.210338860824635
# Improved over  3  iterations in  0.11963123000168707  seconds by  98.69276633247522  percent.
# interpolate adjoint :  True True True
# initial cost =  47.62435559458031
# RUN  0 , total integrated cost =  47.62435559458031
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12.012692454039367
# RUN  2 , total integrated cost =  9.930971039550409
# RUN  3 , total integrated cost =  9.53427498979216
# RUN  4 , total integrated cost =  9.313226535605715
# RUN  5 , total integrated cost =  9.282232637385505
# RUN  6 , total integrated cost =  9.107692277793763
# RUN  7 , total integrated cost =  9.092921087760358
# RUN  8 , total integrated cost =  9.083098353769712
# RUN  9 , total integrated cost =  8.984761613668436
# RUN  10 , total integrated cost =  8.992295207534038
# RUN  11 , total integrated cost =  8.93200768901272
# RUN  12 , total integrated cost =  8.873926467158828
# RUN  12 , total integrated cost =  8.873926467158828
# Improved over  12  iterations in  0.7821946049953112  seconds by  81.36683141142872  percent.
# -------- 7
# interpolate adjoint :  True True True
# initial cost =  3683.876307111159
# RUN  0 , total integrated cost =  3683.876307111159
# Gradient descend method:  None
# RUN  1 , total integrated cost =  149.7185792270818
# RUN  2 , total integrated cost =  55.06466286434718
# RUN  3 , total integrated cost =  13.673455525223872
# RUN  3 , total integrated cost =  13.673455525223872
# Improved over  3  iterations in  0.11240700200141873  seconds by  99.62882967870476  percent.
# interpolate adjoint :  True True True
# initial cost =  13.368056975940487
# RUN  0 , total integrated cost =  13.368056975940487
# Gradient descend method:  None
# RUN  1 , total integrated cost =  10.660505753659914
# RUN  2 , total integrated cost =  10.060284834266898
# RUN  3 , total integrated cost =  9.957745962558993
# RUN  4 , total integrated cost =  9.918208210248629
# RUN  5 , total integrated cost =  9.922257777280864
# RUN  6 , total integrated cost =  9.818062904568277
# RUN  7 , total integrated cost =  9.791661436678487
# RUN  8 , total integrated cost =  9.787764864768748
# RUN  9 , total integrated cost =  9.744926904750042
# RUN  10 , total integrated cost =  9.658135958564825
# RUN  11 , total integrated cost =  9.736711040313267
# RUN  12 , total integrated cost =  9.706253514894275
# RUN  12 , total integrated cost =  9.706253514894275
# Improved over  12  iterations in  0.8651866400032304  seconds by  27.392189213710267  percent.
# -------- 8
# interpolate adjoint :  True True True
# initial cost =  3684.0514943060793
# RUN  0 , total integrated cost =  3684.0514943060793
# Gradient descend method:  None
# RUN  1 , total integrated cost =  158.88336355368384
# RUN  2 , total integrated cost =  84.18164068789464
# RUN  3 , total integrated cost =  17.496993780004253
# RUN  3 , total integrated cost =  17.496993780004253
# Improved over  3  iterations in  0.1818325779895531  seconds by  99.52506109626734  percent.
# -------- 8
# interpolate adjoint :  True True True
# initial cost =  3667.1224727308063
# RUN  0 , total integrated cost =  3667.1224727308063
# Gradient descend method:  None
# RUN  1 , total integrated cost =  187.79400064837375
# RUN  2 , total integrated cost =  27.872720800278106
# RUN  3 , total integrated cost =  8.160355152866682
# RUN  3 , total integrated cost =  8.160355152866682
# Improved over  3  iterations in  0.21238784800516441  seconds by  99.77747252202379  percent.
# interpolate adjoint :  True True True
# initial cost =  8.685501251837202
# RUN  0 , total integrated cost =  8.685501251837202
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.05710396695578
# RUN  2 , total integrated cost =  5.5123750976999375
# RUN  3 , total integrated cost =  5.34067109362665
# RUN  4 , total integrated cost =  5.29526371197883
# RUN  5 , total integrated cost =  5.198145985970025
# RUN  6 , total integrated cost =  5.179661481451286
# RUN  7 , total integrated cost =  5.254986717763498
# RUN  8 , total integrated cost =  5.17671096863482
# RUN  9 , total integrated cost =  5.1194135911921315
# RUN  10 , total integrated cost =  5.155224714196969
# RUN  11 , total integrated cost =  5.137121926501973
# RUN  12 , total integrated cost =  5.1501455736762445
# RUN  12 , total integrated cost =  5.1501455736762445
# Improved over  12  iterations in  1.6017616339959204  seconds by  40.704106483355126  percent.
# -------- 9
# interpolate adjoint :  True True True
# initial cost =  3704.0514749092035
# RUN  0 , total integrated cost =  3704.0514749092035
# Gradient descend method:  None
# RUN  1 , total integrated cost =  153.96505585125195
# RUN  2 , total integrated cost =  41.57345370251993
# RUN  3 , total integrated cost =  12.304918906857704
# RUN  3 , total integrated cost =  12.304918906857704
# Improved over  3  iterations in  0.18175850498664659  seconds by  99.66779838265721  percent.
# interpolate adjoint :  True True True
# initial cost =  14.689594240920236
# RUN  0 , total integrated cost =  14.689594240920236
# Gradient descend method:  None
# RUN  1 , total integrated cost =  9.729515441753437
# RUN  2 , total integrated cost =  8.963326532515046
# RUN  3 , total integrated cost =  8.813501668622463
# RUN  4 , total integrated cost =  8.77069331063123
# RUN  5 , total integrated cost =  8.748342677203219
# RUN  6 , total integrated cost =  8.69248303419353
# RUN  7 , total integrated cost =  8.54725414837318
# RUN  8 , total integrated cost =  8.485393379709132
# RUN  9 , total integrated cost =  8.54563617028468
# RUN  10 , total integrated cost =  8.465327902094618
# RUN  11 , total integrated cost =  8.449393152698818
# RUN  12 , total integrated cost =  8.41977551500949
# RUN  12 , total integrated cost =  8.41977551500949
# Improved over  12  iterations in  1.651761250992422  seconds by  42.68204160769229  percent.
# -------- 10
# interpolate adjoint :  True True True
# initial cost =  3659.2463952091916
# RUN  0 , total integrated cost =  3659.2463952091916
# Gradient descend method:  None
# RUN  1 , total integrated cost =  147.02220348139474
# RUN  2 , total integrated cost =  25.144621735011416
# RUN  3 , total integrated cost =  9.23244365116491
# RUN  3 , total integrated cost =  9.23244365116491
# Improved over  3  iterations in  0.18964792099723127  seconds by  99.74769549098272  percent.
# interpolate adjoint :  True True True
# initial cost =  8.85533950668064
# RUN  0 , total integrated cost =  8.85533950668064
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.831917585637821
# RUN  2 , total integrated cost =  5.6574417710330485
# RUN  3 , total integrated cost =  5.5671709776743254
# RUN  4 , total integrated cost =  5.475254616753449
# RUN  5 , total integrated cost =  5.448427378179229
# RUN  6 , total integrated cost =  5.422375535111559
# step size too small or too large
# RUN  7 , total integrated cost =  5.352296142474829
# RUN  8 , total integrated cost =  5.379151832232326
# RUN  9 , total integrated cost =  5.362444275798536
# RUN  10 , total integrated cost =  5.363687157088865
# RUN  11 , total integrated cost =  5.342255646166827
# RUN  12 , total integrated cost =  5.284039907291278
# RUN  12 , total integrated cost =  5.284039907291278
# Improved over  12  iterations in  1.2931383730028756  seconds by  40.329335726711605  percent.
# -------- 11
# interpolate adjoint :  True True True
# initial cost =  3688.699166374845
# RUN  0 , total integrated cost =  3688.699166374845
# Gradient descend method:  None
# RUN  1 , total integrated cost =  131.96617760596638
# RUN  2 , total integrated cost =  72.54338050279763
# RUN  3 , total integrated cost =  29.24964193980204
# RUN  3 , total integrated cost =  29.24964193980204
# Improved over  3  iterations in  0.15466851899691392  seconds by  99.20704723750764  percent.
# interpolate adjoint :  True True True
# initial cost =  28.607930287527576
# RUN  0 , total integrated cost =  28.607930287527576
# Gradient descend method:  None
# RUN  1 , total integrated cost =  8.490755708468894
# RUN  2 , total integrated cost =  7.59149227704878
# RUN  3 , total integrated cost =  7.442300449240037
# RUN  4 , total integrated cost =  7.2577109180367865
# RUN  5 , total integrated cost =  7.072400378117895
# RUN  6 , total integrated cost =  7.022503065575086
# RUN  7 , total integrated cost =  6.999948575709783
# RUN  8 , total integrated cost =  6.935002771445688
# RUN  9 , total integrated cost =  6.963332866600697
# RUN  10 , total integrated cost =  6.891794906828684
# RUN  11 , total integrated cost =  6.900756246417027
# RUN  12 , total integrated cost =  6.881040294224316
# RUN  12 , total integrated cost =  6.881040294224316
# Improved over  12  iterations in  1.204611555003794  seconds by  75.94708800998339  percent.
# -------- 12
# interpolate adjoint :  True True True
# initial cost =  3680.2670190017798
# RUN  0 , total integrated cost =  3680.2670190017798
# Gradient descend method:  None
# RUN  1 , total integrated cost =  174.41368065716281
# RUN  2 , total integrated cost =  23.857744332260364
# RUN  3 , total integrated cost =  7.121237341437094
# RUN  3 , total integrated cost =  7.121237341437094
# Improved over  3  iterations in  0.15079036200768314  seconds by  99.80650215583084  percent.
# interpolate adjoint :  True True True
# initial cost =  6.813002292100429
# RUN  0 , total integrated cost =  6.813002292100429
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.864037148534445
# RUN  2 , total integrated cost =  5.522189008526375
# RUN  3 , total integrated cost =  5.349892077835507
# RUN  4 , total integrated cost =  5.296771638287024
# RUN  5 , total integrated cost =  5.261190961371902
# RUN  6 , total integrated cost =  5.204117897621234
# RUN  7 , total integrated cost =  5.208842183150093
# RUN  8 , total integrated cost =  5.185724510181567
# RUN  9 , total integrated cost =  5.151746543081478
# RUN  10 , total integrated cost =  5.182282634973865
# RUN  11 , total integrated cost =  5.153980468415175
# RUN  12 , total integrated cost =  5.138408289166614
# RUN  12 , total integrated cost =  5.138408289166614
# Improved over  12  iterations in  1.1385213929897873  seconds by  24.579384111986585  percent.
# -------- 13
# interpolate adjoint :  True True True
# initial cost =  3672.1039327557014
# RUN  0 , total integrated cost =  3672.1039327557014
# Gradient descend method:  None
# RUN  1 , total integrated cost =  125.7914159786457
# RUN  2 , total integrated cost =  22.128243872551558
# RUN  3 , total integrated cost =  7.3643561859929285
# RUN  3 , total integrated cost =  7.3643561859929285
# Improved over  3  iterations in  0.12131162600417156  seconds by  99.79945131399191  percent.
# interpolate adjoint :  True True True
# initial cost =  7.359270561681239
# RUN  0 , total integrated cost =  7.359270561681239
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.973377286661325
# RUN  2 , total integrated cost =  4.8511341349361485
# RUN  3 , total integrated cost =  4.723604767684599
# RUN  4 , total integrated cost =  4.689619204032869
# RUN  5 , total integrated cost =  4.646911911626428
# RUN  6 , total integrated cost =  4.580802182165834
# RUN  7 , total integrated cost =  4.544729337767193
# RUN  8 , total integrated cost =  4.580604767992973
# RUN  9 , total integrated cost =  4.582461359782396
# RUN  10 , total integrated cost =  4.591583788848378
# RUN  11 , total integrated cost =  4.567095512205493
# RUN  12 , total integrated cost =  4.539401101596493
# RUN  12 , total integrated cost =  4.539401101596493
# Improved over  12  iterations in  0.8377196520013968  seconds by  38.317241314206306  percent.
# -------- 14
# interpolate adjoint :  True True True
# initial cost =  3692.466739161816
# RUN  0 , total integrated cost =  3692.466739161816
# Gradient descend method:  None
# RUN  1 , total integrated cost =  165.99092461918593
# RUN  2 , total integrated cost =  122.60079243437919
# RUN  3 , total integrated cost =  79.2046746648624
# RUN  3 , total integrated cost =  79.2046746648624
# Improved over  3  iterations in  0.11284495299332775  seconds by  97.85496579224863  percent.
# interpolate adjoint :  True True True
# initial cost =  78.65533118312554
# RUN  0 , total integrated cost =  78.65533118312554
# Gradient descend method:  None
# RUN  1 , total integrated cost =  24.49632051036489
# RUN  2 , total integrated cost =  20.016639049291758
# RUN  3 , total integrated cost =  19.551213950812652
# RUN  4 , total integrated cost =  19.32496063381381
# RUN  5 , total integrated cost =  19.17940034219287
# RUN  6 , total integrated cost =  19.061460870765753
# RUN  7 , total integrated cost =  19.001209782745526
# RUN  8 , total integrated cost =  18.974589127535662
# RUN  9 , total integrated cost =  18.86988237705203
# RUN  10 , total integrated cost =  18.8835182502274
# RUN  11 , total integrated cost =  18.78739758055642
# RUN  12 , total integrated cost =  18.79947035467872
# RUN  12 , total integrated cost =  18.79947035467872
# Improved over  12  iterations in  0.906181366997771  seconds by  76.0989241645811  percent.
# -------- 14
# interpolate adjoint :  True True True
# initial cost =  3716.667876135174
# RUN  0 , total integrated cost =  3716.667876135174
# Gradient descend method:  None
# RUN  1 , total integrated cost =  173.14204273554094
# RUN  2 , total integrated cost =  51.153304985365374
# RUN  3 , total integrated cost =  14.077039270988596
# RUN  3 , total integrated cost =  14.077039270988596
# Improved over  3  iterations in  0.11291170900221914  seconds by  99.62124570340606  percent.
# interpolate adjoint :  True True True
# initial cost =  13.765507366524204
# RUN  0 , total integrated cost =  13.765507366524204
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.683376244587034
# RUN  2 , total integrated cost =  10.869273333379326
# RUN  3 , total integrated cost =  10.913550203893326
# RUN  4 , total integrated cost =  10.74437660460691
# RUN  5 , total integrated cost =  10.633158246168296
# RUN  6 , total integrated cost =  10.551799057219725
# RUN  7 , total integrated cost =  10.63261000186877
# RUN  8 , total integrated cost =  10.515564671324352
# RUN  9 , total integrated cost =  10.412574124853645
# RUN  10 , total integrated cost =  10.376720084332298
# RUN  11 , total integrated cost =  10.322783446142203
# RUN  12 , total integrated cost =  10.379848788792374
# RUN  12 , total integrated cost =  10.379848788792374
# Improved over  12  iterations in  0.8696964460104937  seconds by  24.595232762471795  percent.
# -------- 15
# interpolate adjoint :  True True True
# initial cost =  3667.8780839013093
# RUN  0 , total integrated cost =  3667.8780839013093
# Gradient descend method:  None
# RUN  1 , total integrated cost =  121.07019473119696
# RUN  2 , total integrated cost =  26.769579366460178
# RUN  3 , total integrated cost =  10.990061750205186
# RUN  3 , total integrated cost =  10.990061750205186
# Improved over  3  iterations in  0.16202891200373415  seconds by  99.70037003687659  percent.
# interpolate adjoint :  True True True
# initial cost =  10.987718425255057
# RUN  0 , total integrated cost =  10.987718425255057
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.740855659595515
# RUN  2 , total integrated cost =  6.390429475116559
# RUN  3 , total integrated cost =  6.064924359065541
# RUN  4 , total integrated cost =  5.984762777728275
# RUN  5 , total integrated cost =  5.865083359344981
# RUN  6 , total integrated cost =  5.908472779848771
# RUN  7 , total integrated cost =  5.825656185895919
# RUN  8 , total integrated cost =  5.8637767526742595
# RUN  9 , total integrated cost =  5.792844213467137
# RUN  10 , total integrated cost =  5.778475844424073
# RUN  11 , total integrated cost =  5.680171066519747
# RUN  12 , total integrated cost =  5.669161827798507
# RUN  12 , total integrated cost =  5.669161827798507
# Improved over  12  iterations in  0.9149536299955798  seconds by  48.40455854085186  percent.
# -------- 16
# interpolate adjoint :  True True True
# initial cost =  3660.793499501075
# RUN  0 , total integrated cost =  3660.793499501075
# Gradient descend method:  None
# RUN  1 , total integrated cost =  149.08268331664232
# RUN  2 , total integrated cost =  67.96320337473648
# RUN  3 , total integrated cost =  65.73581553083537
# RUN  3 , total integrated cost =  65.73581553083537
# Improved over  3  iterations in  0.11339628898713272  seconds by  98.20432877353518  percent.
# -------- 16
# interpolate adjoint :  True True True
# initial cost =  3693.4492594569115
# RUN  0 , total integrated cost =  3693.4492594569115
# Gradient descend method:  None
# RUN  1 , total integrated cost =  130.8942185596126
# RUN  2 , total integrated cost =  85.0500432877831
# RUN  3 , total integrated cost =  48.62788581509364
# RUN  3 , total integrated cost =  48.62788581509364
# Improved over  3  iterations in  0.12341888700029813  seconds by  98.68340181767533  percent.
# interpolate adjoint :  True True True
# initial cost =  50.37059726811521
# RUN  0 , total integrated cost =  50.37059726811521
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.881514075994039
# RUN  2 , total integrated cost =  8.462339077649311
# RUN  3 , total integrated cost =  8.174104986773212
# RUN  4 , total integrated cost =  7.943745426338562
# step size too small or too large
# RUN  5 , total integrated cost =  7.903080885950571
# RUN  6 , total integrated cost =  7.73622265164587
# RUN  7 , total integrated cost =  7.730381171004941
# RUN  8 , total integrated cost =  7.684616914094299
# RUN  9 , total integrated cost =  7.668705198049338
# RUN  10 , total integrated cost =  7.634588428592331
# RUN  11 , total integrated cost =  7.627885880947575
# RUN  12 , total integrated cost =  7.605606627642005
# RUN  12 , total integrated cost =  7.605606627642005
# Improved over  12  iterations in  1.1802823140023975  seconds by  84.90070191711547  percent.
# -------- 17
# interpolate adjoint :  True True True
# initial cost =  3707.6345068442097
# RUN  0 , total integrated cost =  3707.6345068442097
# Gradient descend method:  None
# RUN  1 , total integrated cost =  154.33354767431345
# RUN  2 , total integrated cost =  24.387069666618512
# RUN  3 , total integrated cost =  8.109434075098445
# RUN  3 , total integrated cost =  8.109434075098445
# Improved over  3  iterations in  0.13536158599890769  seconds by  99.78127741393796  percent.
# interpolate adjoint :  True True True
# initial cost =  9.107378292157744
# RUN  0 , total integrated cost =  9.107378292157744
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.446771980380548
# RUN  2 , total integrated cost =  6.06416131742849
# RUN  3 , total integrated cost =  5.94974500093912
# RUN  4 , total integrated cost =  5.90711642272544
# RUN  5 , total integrated cost =  5.8569532116723835
# RUN  6 , total integrated cost =  5.7567362648660385
# RUN  7 , total integrated cost =  5.694698840306469
# RUN  8 , total integrated cost =  5.687114954748192
# RUN  9 , total integrated cost =  5.646106838164353
# RUN  10 , total integrated cost =  5.630437563023822
# RUN  11 , total integrated cost =  5.59659943129537
# RUN  12 , total integrated cost =  5.6342108405543225
# RUN  12 , total integrated cost =  5.6342108405543225
# Improved over  12  iterations in  1.0168487210030435  seconds by  38.13575477142665  percent.
# -------- 18
# interpolate adjoint :  True True True
# initial cost =  3661.6383229586736
# RUN  0 , total integrated cost =  3661.6383229586736
# Gradient descend method:  None
# RUN  1 , total integrated cost =  115.73783225319346
# RUN  2 , total integrated cost =  27.885744742742837
# RUN  3 , total integrated cost =  8.7054079757959
# RUN  3 , total integrated cost =  8.7054079757959
# Improved over  3  iterations in  0.12413612399541307  seconds by  99.76225374523713  percent.
# interpolate adjoint :  True True True
# initial cost =  8.754054160542443
# RUN  0 , total integrated cost =  8.754054160542443
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.690611634567177
# RUN  2 , total integrated cost =  6.354059500323861
# RUN  3 , total integrated cost =  6.106899881325234
# RUN  4 , total integrated cost =  5.9620970692295785
# RUN  5 , total integrated cost =  5.886363057485503
# RUN  6 , total integrated cost =  5.867190570489892
# RUN  7 , total integrated cost =  5.833940974504326
# RUN  8 , total integrated cost =  5.777079592665782
# RUN  9 , total integrated cost =  5.753594662865381
# RUN  10 , total integrated cost =  5.670076070547219
# RUN  11 , total integrated cost =  5.654013598754956
# RUN  12 , total integrated cost =  5.742810060445674
# RUN  12 , total integrated cost =  5.742810060445674
# Improved over  12  iterations in  1.002012053009821  seconds by  34.39828044095832  percent.
# -------- 19
# interpolate adjoint :  True True True
# initial cost =  3711.8230940220305
# RUN  0 , total integrated cost =  3711.8230940220305
# Gradient descend method:  None
# RUN  1 , total integrated cost =  179.75446913631285
# RUN  2 , total integrated cost =  31.911649285679772
# RUN  3 , total integrated cost =  9.298670846288738
# RUN  3 , total integrated cost =  9.298670846288738
# Improved over  3  iterations in  0.11971363599877805  seconds by  99.74948507483386  percent.
# interpolate adjoint :  True True True
# initial cost =  10.110494729844273
# RUN  0 , total integrated cost =  10.110494729844273
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.369843954034674
# RUN  2 , total integrated cost =  6.826984578173341
# RUN  3 , total integrated cost =  6.835310852469286
# RUN  4 , total integrated cost =  6.54601136528764
# RUN  5 , total integrated cost =  6.57771606656069
# RUN  6 , total integrated cost =  6.422597912282532
# RUN  7 , total integrated cost =  6.404480631844956
# RUN  8 , total integrated cost =  6.386279118790979
# RUN  9 , total integrated cost =  6.32782107741363
# RUN  10 , total integrated cost =  6.319127946915863
# RUN  11 , total integrated cost =  6.278680495208442
# RUN  12 , total integrated cost =  6.2060615539561725
# RUN  12 , total integrated cost =  6.2060615539561725
# Improved over  12  iterations in  0.8344620909920195  seconds by  38.61762732898668  percent.
# mean =  7.094109277531358
# 50
# -------- 0
# interpolate adjoint :  True True True
# initial cost =  3698.633338959469
# RUN  0 , total integrated cost =  3698.633338959469
# Gradient descend method:  None
# RUN  1 , total integrated cost =  159.64659293420775
# RUN  2 , total integrated cost =  50.07172204658201
# RUN  3 , total integrated cost =  14.325841749054995
# RUN  3 , total integrated cost =  14.325841749054995
# Improved over  3  iterations in  0.10791069798870012  seconds by  99.61267202136113  percent.
# interpolate adjoint :  True True True
# initial cost =  14.051950459713545
# RUN  0 , total integrated cost =  14.051950459713545
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.064472231553468
# RUN  2 , total integrated cost =  10.491831046650155
# RUN  3 , total integrated cost =  10.190940423355055
# RUN  4 , total integrated cost =  10.088382278300106
# RUN  5 , total integrated cost =  10.106315746469118
# RUN  6 , total integrated cost =  10.06875748805268
# RUN  7 , total integrated cost =  10.056220404128544
# RUN  8 , total integrated cost =  10.02767459176785
# RUN  9 , total integrated cost =  10.03102949121271
# RUN  10 , total integrated cost =  10.00987766491132
# RUN  11 , total integrated cost =  10.065351308413788
# RUN  12 , total integrated cost =  9.974465622968118
# RUN  12 , total integrated cost =  9.974465622968118
# Improved over  12  iterations in  0.8391790720052086  seconds by  29.017216139748243  percent.
# -------- 1
# interpolate adjoint :  True True True
# initial cost =  3648.0051049279846
# RUN  0 , total integrated cost =  3648.0051049279846
# Gradient descend method:  None
# RUN  1 , total integrated cost =  159.81998826356437
# RUN  2 , total integrated cost =  10.790798702780753
# RUN  3 , total integrated cost =  9.12251973226306
# RUN  3 , total integrated cost =  9.12251973226306
# Improved over  3  iterations in  0.11791782100044657  seconds by  99.74993127833238  percent.
# interpolate adjoint :  True True True
# initial cost =  10.58022644727626
# RUN  0 , total integrated cost =  10.58022644727626
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.972305888065322
# RUN  2 , total integrated cost =  6.758939474147278
# RUN  3 , total integrated cost =  6.524868148308898
# step size too small or too large
# RUN  4 , total integrated cost =  6.046442525482195
# Control only changes marginally.
# RUN  4 , total integrated cost =  6.046442525482195
# Improved over  4  iterations in  0.4391223419952439  seconds by  42.851482852346955  percent.
# -------- 2
# interpolate adjoint :  True True True
# initial cost =  3685.180916403615
# RUN  0 , total integrated cost =  3685.180916403615
# Gradient descend method:  None
# RUN  1 , total integrated cost =  183.84657507884373
# RUN  2 , total integrated cost =  115.85613289832989
# step size too small or too large
# RUN  3 , total integrated cost =  114.67234230107731
# Control only changes marginally.
# RUN  3 , total integrated cost =  114.67234230107731
# Improved over  3  iterations in  0.1918517209996935  seconds by  96.88828459436975  percent.
# interpolate adjoint :  True True True
# initial cost =  118.46297601823014
# RUN  0 , total integrated cost =  118.46297601823014
# Gradient descend method:  None
# RUN  1 , total integrated cost =  70.21523985453585
# RUN  2 , total integrated cost =  64.01620190424927
# RUN  3 , total integrated cost =  62.79101834077358
# RUN  4 , total integrated cost =  62.37621639171716
# RUN  5 , total integrated cost =  62.299806595881684
# RUN  6 , total integrated cost =  62.17928596328177
# RUN  7 , total integrated cost =  62.130873861089896
# RUN  8 , total integrated cost =  62.093652748216485
# RUN  9 , total integrated cost =  62.11590439987015
# RUN  10 , total integrated cost =  62.037623303692996
# RUN  11 , total integrated cost =  62.01696366001351
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  12 , total integrated cost =  62.00255362422531
# Control only changes marginally.
# RUN  12 , total integrated cost =  62.00255362422531
# Improved over  12  iterations in  1.2715264330036007  seconds by  47.66081715296111  percent.
# -------- 2
# interpolate adjoint :  True True True
# initial cost =  3694.4176834738414
# RUN  0 , total integrated cost =  3694.4176834738414
# Gradient descend method:  None
# RUN  1 , total integrated cost =  142.49421459457614
# RUN  2 , total integrated cost =  85.36856964298175
# RUN  3 , total integrated cost =  67.64784297262277
# RUN  3 , total integrated cost =  67.64784297262277
# Improved over  3  iterations in  0.12202211600379087  seconds by  98.16891730257706  percent.
# -------- 2
# interpolate adjoint :  True True True
# initial cost =  3688.1474608858266
# RUN  0 , total integrated cost =  3688.1474608858266
# Gradient descend method:  None
# RUN  1 , total integrated cost =  130.3938024589439
# RUN  2 , total integrated cost =  18.75566094444822
# RUN  3 , total integrated cost =  4.547373139551805
# RUN  3 , total integrated cost =  4.547373139551805
# Improved over  3  iterations in  0.13159706999431364  seconds by  99.87670305518479  percent.
# interpolate adjoint :  True True True
# initial cost =  6.07645889450586
# RUN  0 , total integrated cost =  6.07645889450586
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.317884100047732
# RUN  2 , total integrated cost =  4.221212522750433
# RUN  3 , total integrated cost =  4.272218446354137
# RUN  4 , total integrated cost =  4.0079854500759815
# RUN  5 , total integrated cost =  3.9861654122262156
# RUN  6 , total integrated cost =  4.1791252450953404
# RUN  7 , total integrated cost =  4.00814576794754
# RUN  8 , total integrated cost =  4.056080427146751
# step size too small or too large
# step size too small or too large
# RUN  9 , total integrated cost =  3.779247295017372
# RUN  10 , total integrated cost =  3.8801427977289666
# RUN  11 , total integrated cost =  3.8793979483858028
# RUN  12 , total integrated cost =  3.8454058490061356
# RUN  12 , total integrated cost =  3.8454058490061356
# Improved over  12  iterations in  1.1564265360066202  seconds by  36.716335685525195  percent.
# -------- 3
# interpolate adjoint :  True True True
# initial cost =  3679.089111695894
# RUN  0 , total integrated cost =  3679.089111695894
# Gradient descend method:  None
# RUN  1 , total integrated cost =  145.63103193457502
# RUN  2 , total integrated cost =  17.9258174243256
# RUN  3 , total integrated cost =  5.328780591779395
# RUN  3 , total integrated cost =  5.328780591779395
# Improved over  3  iterations in  0.16102358100761194  seconds by  99.85516032827694  percent.
# interpolate adjoint :  True True True
# initial cost =  5.789180664949308
# RUN  0 , total integrated cost =  5.789180664949308
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.0706099371654565
# RUN  2 , total integrated cost =  3.981565148426897
# RUN  3 , total integrated cost =  3.9082284615411513
# RUN  4 , total integrated cost =  3.8234167500908844
# RUN  5 , total integrated cost =  3.786973891595867
# RUN  6 , total integrated cost =  3.8672187056951817
# RUN  7 , total integrated cost =  3.882429362508743
# RUN  8 , total integrated cost =  3.8151747054247047
# RUN  9 , total integrated cost =  3.8001179024434384
# RUN  10 , total integrated cost =  3.8581609454987236
# RUN  11 , total integrated cost =  3.8131949356814867
# RUN  12 , total integrated cost =  3.7824677127632103
# RUN  12 , total integrated cost =  3.7824677127632103
# Improved over  12  iterations in  0.8738353540102253  seconds by  34.66315992409385  percent.
# -------- 4
# interpolate adjoint :  True True True
# initial cost =  3703.1408337449247
# RUN  0 , total integrated cost =  3703.1408337449247
# Gradient descend method:  None
# RUN  1 , total integrated cost =  212.83532978158422
# RUN  2 , total integrated cost =  125.71347544628087
# RUN  3 , total integrated cost =  35.410997167960275
# RUN  3 , total integrated cost =  35.410997167960275
# Improved over  3  iterations in  0.12179353900137357  seconds by  99.04375775165565  percent.
# interpolate adjoint :  True True True
# initial cost =  33.138572681481705
# RUN  0 , total integrated cost =  33.138572681481705
# Gradient descend method:  None
# RUN  1 , total integrated cost =  8.842810668702985
# RUN  2 , total integrated cost =  7.689950195586495
# RUN  3 , total integrated cost =  7.055372491060056
# RUN  4 , total integrated cost =  6.91762466266174
# RUN  5 , total integrated cost =  6.856298762552222
# RUN  6 , total integrated cost =  6.810458882417077
# RUN  7 , total integrated cost =  6.713225205798703
# RUN  8 , total integrated cost =  6.75409956303615
# RUN  9 , total integrated cost =  6.722718522464383
# RUN  10 , total integrated cost =  6.718261694822078
# RUN  11 , total integrated cost =  6.721728446303425
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  12 , total integrated cost =  6.712033515862236
# Control only changes marginally.
# RUN  12 , total integrated cost =  6.712033515862236
# Improved over  12  iterations in  0.987898999999743  seconds by  79.74555639322084  percent.
# -------- 5
# interpolate adjoint :  True True True
# initial cost =  3680.193677432301
# RUN  0 , total integrated cost =  3680.193677432301
# Gradient descend method:  None
# RUN  1 , total integrated cost =  153.62711030959247
# RUN  2 , total integrated cost =  46.53298069703869
# RUN  3 , total integrated cost =  12.659366715825943
# RUN  3 , total integrated cost =  12.659366715825943
# Improved over  3  iterations in  0.15502951400412712  seconds by  99.65601357359381  percent.
# interpolate adjoint :  True True True
# initial cost =  13.701626284996578
# RUN  0 , total integrated cost =  13.701626284996578
# Gradient descend method:  None
# RUN  1 , total integrated cost =  10.258069185205432
# RUN  2 , total integrated cost =  9.630625959103345
# RUN  3 , total integrated cost =  9.29118098783313
# RUN  4 , total integrated cost =  9.238609485066181
# RUN  5 , total integrated cost =  9.196821768807512
# RUN  6 , total integrated cost =  9.143104237532862
# RUN  7 , total integrated cost =  9.0790264444412
# RUN  8 , total integrated cost =  9.014803462153932
# RUN  9 , total integrated cost =  9.098346014493876
# RUN  10 , total integrated cost =  8.980681402188655
# RUN  11 , total integrated cost =  8.974008872207229
# RUN  12 , total integrated cost =  8.967688103056867
# RUN  12 , total integrated cost =  8.967688103056867
# Improved over  12  iterations in  1.5472991800052114  seconds by  34.55019195147237  percent.
# -------- 6
# interpolate adjoint :  True True True
# initial cost =  3688.585328626535
# RUN  0 , total integrated cost =  3688.585328626535
# Gradient descend method:  None
# RUN  1 , total integrated cost =  181.4167548090395
# RUN  2 , total integrated cost =  42.362127891422
# RUN  3 , total integrated cost =  11.329688504156874
# RUN  3 , total integrated cost =  11.329688504156874
# Improved over  3  iterations in  0.1917874450009549  seconds by  99.69284461399798  percent.
# interpolate adjoint :  True True True
# initial cost =  11.818204172770528
# RUN  0 , total integrated cost =  11.818204172770528
# Gradient descend method:  None
# RUN  1 , total integrated cost =  9.069027440590965
# RUN  2 , total integrated cost =  8.612074578025755
# RUN  3 , total integrated cost =  8.470036944790715
# RUN  4 , total integrated cost =  8.430337520598684
# RUN  5 , total integrated cost =  8.39976220528864
# RUN  6 , total integrated cost =  8.427684261151205
# RUN  7 , total integrated cost =  8.451672202247359
# RUN  8 , total integrated cost =  8.326492454348971
# RUN  9 , total integrated cost =  8.31478470387006
# RUN  10 , total integrated cost =  8.37913247630804
# RUN  11 , total integrated cost =  8.330246946657654
# RUN  12 , total integrated cost =  8.289377002369266
# RUN  12 , total integrated cost =  8.289377002369266
# Improved over  12  iterations in  1.6558083059935598  seconds by  29.859250346442465  percent.
# -------- 7
# interpolate adjoint :  True True True
# initial cost =  3681.162362066698
# RUN  0 , total integrated cost =  3681.162362066698
# Gradient descend method:  None
# RUN  1 , total integrated cost =  120.02815907988031
# RUN  2 , total integrated cost =  63.77856909384664
# RUN  3 , total integrated cost =  48.937971200537135
# RUN  3 , total integrated cost =  48.937971200537135
# Improved over  3  iterations in  0.25632460400811397  seconds by  98.67058373450656  percent.
# interpolate adjoint :  True True True
# initial cost =  51.23387110678579
# RUN  0 , total integrated cost =  51.23387110678579
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.346535371609516
# RUN  2 , total integrated cost =  8.638762186269304
# RUN  3 , total integrated cost =  7.9383210463720815
# RUN  4 , total integrated cost =  7.816920527639436
# RUN  5 , total integrated cost =  7.754612459436192
# RUN  6 , total integrated cost =  7.721183403857972
# RUN  7 , total integrated cost =  7.678204966917362
# RUN  8 , total integrated cost =  7.607752072544181
# RUN  9 , total integrated cost =  7.598239493691891
# RUN  10 , total integrated cost =  7.549927481939727
# RUN  11 , total integrated cost =  7.5355706120377075
# RUN  12 , total integrated cost =  7.540098520858837
# RUN  12 , total integrated cost =  7.540098520858837
# Improved over  12  iterations in  2.175428312009899  seconds by  85.28298104755123  percent.
# -------- 8
# interpolate adjoint :  True True True
# initial cost =  3698.493565208977
# RUN  0 , total integrated cost =  3698.493565208977
# Gradient descend method:  None
# RUN  1 , total integrated cost =  177.93656862220618
# RUN  2 , total integrated cost =  47.9405244891287
# RUN  3 , total integrated cost =  13.64181407768183
# RUN  3 , total integrated cost =  13.64181407768183
# Improved over  3  iterations in  0.29908938200969715  seconds by  99.63115214783642  percent.
# interpolate adjoint :  True True True
# initial cost =  13.548296952889816
# RUN  0 , total integrated cost =  13.548296952889816
# Gradient descend method:  None
# RUN  1 , total integrated cost =  10.603519332249244
# RUN  2 , total integrated cost =  10.439381928676427
# RUN  3 , total integrated cost =  10.067411699534048
# RUN  4 , total integrated cost =  10.053222323321895
# RUN  5 , total integrated cost =  9.976490471518217
# RUN  6 , total integrated cost =  9.90102246071665
# RUN  7 , total integrated cost =  9.805832752414409
# RUN  8 , total integrated cost =  9.868578996270513
# RUN  9 , total integrated cost =  9.832244862498495
# RUN  10 , total integrated cost =  9.772777477591841
# RUN  11 , total integrated cost =  9.83071970437251
# RUN  12 , total integrated cost =  9.785920573512515
# RUN  12 , total integrated cost =  9.785920573512515
# Improved over  12  iterations in  1.6164599559997441  seconds by  27.77010566316821  percent.
# -------- 9
# interpolate adjoint :  True True True
# initial cost =  3683.472525678995
# RUN  0 , total integrated cost =  3683.472525678995
# Gradient descend method:  None
# RUN  1 , total integrated cost =  152.6442833594277
# RUN  2 , total integrated cost =  113.87901184319941
# RUN  3 , total integrated cost =  31.66782753211077
# RUN  3 , total integrated cost =  31.66782753211077
# Improved over  3  iterations in  0.19400712799688336  seconds by  99.14027246541568  percent.
# interpolate adjoint :  True True True
# initial cost =  37.52717173568502
# RUN  0 , total integrated cost =  37.52717173568502
# Gradient descend method:  None
# RUN  1 , total integrated cost =  19.067458310448483
# RUN  2 , total integrated cost =  14.224178236231808
# RUN  3 , total integrated cost =  12.988200038783805
# RUN  4 , total integrated cost =  11.7642586269047
# ...
# RUN  9 , total integrated cost =  5.082219036629027
# RUN  10 , total integrated cost =  5.124957491599035
# RUN  11 , total integrated cost =  5.055151767290216
# RUN  12 , total integrated cost =  5.039355908043424
# RUN  12 , total integrated cost =  5.039355908043424
# Improved over  12  iterations in  0.919065648005926  seconds by  77.92285290655558  percent.
# -------- 40
# interpolate adjoint :  True True True
# initial cost =  3687.3601226284736
# RUN  0 , total integrated cost =  3687.3601226284736
# Gradient descend method:  None
# RUN  1 , total integrated cost =  171.50017309321464
# RUN  2 , total integrated cost =  124.5569485402822
# RUN  3 , total integrated cost =  24.240430582064754
# RUN  3 , total integrated cost =  24.240430582064754
# Improved over  3  iterations in  0.11981255999126006  seconds by  99.34260745422432  percent.
# interpolate adjoint :  True True True
# initial cost =  26.85889523352334
# RUN  0 , total integrated cost =  26.85889523352334
# Gradient descend method:  None
# RUN  1 , total integrated cost =  8.036336411961479
# RUN  2 , total integrated cost =  5.787564181486108
# RUN  3 , total integrated cost =  5.556105987992999
# RUN  4 , total integrated cost =  5.431586914323299
# RUN  5 , total integrated cost =  5.403927290275045
# RUN  6 , total integrated cost =  5.4137545470373105
# RUN  7 , total integrated cost =  5.37761885235361
# RUN  8 , total integrated cost =  5.360110725008147
# RUN  9 , total integrated cost =  5.340518918997617
# RUN  10 , total integrated cost =  5.245004558750682
# RUN  11 , total integrated cost =  5.339227804768786
# RUN  12 , total integrated cost =  5.313258347442255
# RUN  12 , total integrated cost =  5.313258347442255
# Improved over  12  iterations in  0.9218454789952375  seconds by  80.21788200428055  percent.
# -------- 41
# interpolate adjoint :  True True True
# initial cost =  3677.59622704652
# RUN  0 , total integrated cost =  3677.59622704652
# Gradient descend method:  None
# RUN  1 , total integrated cost =  123.12114280830272
# RUN  2 , total integrated cost =  61.71878292396329
# RUN  3 , total integrated cost =  22.92330522007223
# RUN  3 , total integrated cost =  22.92330522007223
# Improved over  3  iterations in  0.14465431799180806  seconds by  99.37667694317595  percent.
# interpolate adjoint :  True True True
# initial cost =  22.653166992511466
# RUN  0 , total integrated cost =  22.653166992511466
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.885165067664399
# RUN  2 , total integrated cost =  5.944683579705313
# RUN  3 , total integrated cost =  5.8757639271270525
# RUN  4 , total integrated cost =  5.619830924565462
# RUN  5 , total integrated cost =  5.552948374896171
# RUN  6 , total integrated cost =  5.493428898230377
# RUN  7 , total integrated cost =  5.462893166739871
# RUN  8 , total integrated cost =  5.467869926731821
# RUN  9 , total integrated cost =  5.403319029655247
# RUN  10 , total integrated cost =  5.398476020416458
# RUN  11 , total integrated cost =  5.353713413215574
# RUN  12 , total integrated cost =  5.343451341563559
# RUN  12 , total integrated cost =  5.343451341563559
# Improved over  12  iterations in  0.834703376996913  seconds by  76.41190150882673  percent.
# -------- 42
# interpolate adjoint :  True True True
# initial cost =  3677.313721001194
# RUN  0 , total integrated cost =  3677.313721001194
# Gradient descend method:  None
# RUN  1 , total integrated cost =  162.1079475365867
# RUN  2 , total integrated cost =  127.54854989686943
# RUN  3 , total integrated cost =  14.814502261935294
# RUN  3 , total integrated cost =  14.814502261935294
# Improved over  3  iterations in  0.13527353698736988  seconds by  99.59713792768538  percent.
# interpolate adjoint :  True True True
# initial cost =  14.771733152660316
# RUN  0 , total integrated cost =  14.771733152660316
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.530473008585719
# RUN  2 , total integrated cost =  6.523952978750236
# RUN  3 , total integrated cost =  5.380616534894749
# RUN  4 , total integrated cost =  4.984153539319053
# RUN  5 , total integrated cost =  4.903282132854479
# RUN  6 , total integrated cost =  4.67818044734988
# RUN  7 , total integrated cost =  4.814328081864346
# RUN  8 , total integrated cost =  4.968777870058593
# RUN  9 , total integrated cost =  4.735327712316356
# step size too small or too large
# step size too small or too large
# RUN  10 , total integrated cost =  4.847897588932631
# RUN  11 , total integrated cost =  4.81069940221813
# RUN  12 , total integrated cost =  4.778547369874238
# RUN  12 , total integrated cost =  4.778547369874238
# Improved over  12  iterations in  1.221117103996221  seconds by  67.65073319095501  percent.
# -------- 43
# interpolate adjoint :  True True True
# initial cost =  3662.6325966988943
# RUN  0 , total integrated cost =  3662.6325966988943
# Gradient descend method:  None
# RUN  1 , total integrated cost =  99.32584019665423
# RUN  2 , total integrated cost =  38.81368473580049
# RUN  3 , total integrated cost =  10.177773704061963
# RUN  3 , total integrated cost =  10.177773704061963
# Improved over  3  iterations in  0.12069206801243126  seconds by  99.72211862819015  percent.
# interpolate adjoint :  True True True
# initial cost =  10.832944286713529
# RUN  0 , total integrated cost =  10.832944286713529
# Gradient descend method:  None
# RUN  1 , total integrated cost =  8.14426847131363
# step size too small or too large
# RUN  2 , total integrated cost =  7.566455689791492
# RUN  3 , total integrated cost =  7.431271490421188
# RUN  4 , total integrated cost =  7.405907505698671
# RUN  5 , total integrated cost =  7.37429100594745
# RUN  6 , total integrated cost =  7.27807233128399
# RUN  7 , total integrated cost =  7.210982346331264
# RUN  8 , total integrated cost =  7.2248926560054745
# RUN  9 , total integrated cost =  7.192502512239032
# step size too small or too large
# RUN  10 , total integrated cost =  7.201937567077149
# RUN  11 , total integrated cost =  7.219069510081801
# RUN  12 , total integrated cost =  7.2574043693605805
# RUN  12 , total integrated cost =  7.2574043693605805
# Improved over  12  iterations in  1.0319275049987482  seconds by  33.00616916989321  percent.
# -------- 44
# interpolate adjoint :  True True True
# initial cost =  3670.7901538431383
# RUN  0 , total integrated cost =  3670.7901538431383
# Gradient descend method:  None
# RUN  1 , total integrated cost =  152.96519894763392
# RUN  2 , total integrated cost =  115.9253011763143
# RUN  3 , total integrated cost =  69.16569030437807
# RUN  3 , total integrated cost =  69.16569030437807
# Improved over  3  iterations in  0.13409633000264876  seconds by  98.11578195958805  percent.
# interpolate adjoint :  True True True
# initial cost =  68.98571821169928
# RUN  0 , total integrated cost =  68.98571821169928
# Gradient descend method:  None
# RUN  1 , total integrated cost =  13.531002685550472
# RUN  2 , total integrated cost =  10.306762368463188
# RUN  3 , total integrated cost =  9.635464851011786
# RUN  4 , total integrated cost =  9.557332956960416
# RUN  5 , total integrated cost =  9.304129561196746
# RUN  6 , total integrated cost =  9.20600836307934
# RUN  7 , total integrated cost =  9.159091088715385
# RUN  8 , total integrated cost =  9.06389130661234
# RUN  9 , total integrated cost =  9.0646073674287
# RUN  10 , total integrated cost =  9.053430171190634
# RUN  11 , total integrated cost =  9.058358525023301
# RUN  12 , total integrated cost =  9.014736173356873
# RUN  12 , total integrated cost =  9.014736173356873
# Improved over  12  iterations in  0.9572955699986778  seconds by  86.93246021489117  percent.
# -------- 45
# interpolate adjoint :  True True True
# initial cost =  3684.9084179826827
# RUN  0 , total integrated cost =  3684.9084179826827
# Gradient descend method:  None
# RUN  1 , total integrated cost =  154.11361177231353
# RUN  2 , total integrated cost =  57.488563962854734
# RUN  3 , total integrated cost =  24.303461238280637
# RUN  3 , total integrated cost =  24.303461238280637
# Improved over  3  iterations in  0.1256803489959566  seconds by  99.34045955878638  percent.
# -------- 45
# interpolate adjoint :  True True True
# initial cost =  3720.078278122412
# RUN  0 , total integrated cost =  3720.078278122412
# Gradient descend method:  None
# RUN  1 , total integrated cost =  154.30743782529734
# RUN  2 , total integrated cost =  53.85763593718314
# RUN  3 , total integrated cost =  25.454700406746028
# RUN  3 , total integrated cost =  25.454700406746028
# Improved over  3  iterations in  0.1201868419884704  seconds by  99.31574825840511  percent.
# -------- 45
# interpolate adjoint :  True True True
# initial cost =  3681.7260734602946
# RUN  0 , total integrated cost =  3681.7260734602946
# Gradient descend method:  None
# RUN  1 , total integrated cost =  149.90912387407792
# RUN  2 , total integrated cost =  134.49237367844455
# RUN  3 , total integrated cost =  25.224369786307996
# RUN  3 , total integrated cost =  25.224369786307996
# Improved over  3  iterations in  0.1357444119930733  seconds by  99.31487652033275  percent.
# interpolate adjoint :  True True True
# initial cost =  23.785120432824826
# RUN  0 , total integrated cost =  23.785120432824826
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.273010636477379
# RUN  2 , total integrated cost =  5.380110387744324
# RUN  3 , total integrated cost =  5.279076072291203
# RUN  4 , total integrated cost =  4.833992839851916
# RUN  5 , total integrated cost =  4.8404696923852475
# RUN  6 , total integrated cost =  4.786177607681658
# RUN  7 , total integrated cost =  4.734284782497156
# RUN  8 , total integrated cost =  4.750068394298723
# step size too small or too large
# RUN  9 , total integrated cost =  4.679162322014371
# RUN  10 , total integrated cost =  4.701515781330357
# RUN  11 , total integrated cost =  4.6699755263263185
# RUN  12 , total integrated cost =  4.607433798585965
# RUN  12 , total integrated cost =  4.607433798585965
# Improved over  12  iterations in  1.0218979659985052  seconds by  80.6289238198372  percent.
# -------- 46
# interpolate adjoint :  True True True
# initial cost =  3678.2759645882566
# RUN  0 , total integrated cost =  3678.2759645882566
# Gradient descend method:  None
# RUN  1 , total integrated cost =  204.4975360452341
# RUN  2 , total integrated cost =  36.208960649757636
# RUN  3 , total integrated cost =  10.456453692098552
# RUN  3 , total integrated cost =  10.456453692098552
# Improved over  3  iterations in  0.11904247901111376  seconds by  99.71572405679275  percent.
# interpolate adjoint :  True True True
# initial cost =  10.493530605328528
# RUN  0 , total integrated cost =  10.493530605328528
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.942006242653516
# RUN  2 , total integrated cost =  7.459795917082608
# RUN  3 , total integrated cost =  7.228256194654669
# RUN  4 , total integrated cost =  7.212349094110317
# RUN  5 , total integrated cost =  7.159092024806752
# RUN  6 , total integrated cost =  7.19899988867151
# RUN  7 , total integrated cost =  7.132788679399682
# RUN  8 , total integrated cost =  7.094417094402465
# RUN  9 , total integrated cost =  7.042992812907319
# RUN  10 , total integrated cost =  6.99743623860159
# RUN  11 , total integrated cost =  7.061818350317447
# RUN  12 , total integrated cost =  7.064445517562039
# RUN  12 , total integrated cost =  7.064445517562039
# Improved over  12  iterations in  0.8883641360007459  seconds by  32.67808725907017  percent.
# -------- 47
# interpolate adjoint :  True True True
# initial cost =  3662.75112968149
# RUN  0 , total integrated cost =  3662.75112968149
# Gradient descend method:  None
# RUN  1 , total integrated cost =  154.21127530467035
# RUN  2 , total integrated cost =  40.651492110448594
# RUN  3 , total integrated cost =  26.889731389244766
# RUN  3 , total integrated cost =  26.889731389244766
# Improved over  3  iterations in  0.13420108299760614  seconds by  99.26585972027034  percent.
# interpolate adjoint :  True True True
# initial cost =  27.755563493729632
# RUN  0 , total integrated cost =  27.755563493729632
# Gradient descend method:  None
# RUN  1 , total integrated cost =  8.489764833370051
# RUN  2 , total integrated cost =  7.210238146754347
# RUN  3 , total integrated cost =  6.819756961257549
# RUN  4 , total integrated cost =  6.75835728160431
# RUN  5 , total integrated cost =  6.667814471800295
# RUN  6 , total integrated cost =  6.567107431457597
# RUN  7 , total integrated cost =  6.572211933805212
# RUN  8 , total integrated cost =  6.611685674571808
# RUN  9 , total integrated cost =  6.638002794706752
# RUN  10 , total integrated cost =  6.531112574871546
# RUN  11 , total integrated cost =  6.514127429404788
# RUN  12 , total integrated cost =  6.463069043348089
# RUN  12 , total integrated cost =  6.463069043348089
# Improved over  12  iterations in  0.8982127099880017  seconds by  76.71432956204191  percent.
# -------- 48
# interpolate adjoint :  True True True
# initial cost =  3710.2864143753995
# RUN  0 , total integrated cost =  3710.2864143753995
# Gradient descend method:  None
# RUN  1 , total integrated cost =  235.31471602685343
# RUN  2 , total integrated cost =  188.26807829346353
# RUN  3 , total integrated cost =  35.097430984837644
# RUN  3 , total integrated cost =  35.097430984837644
# Improved over  3  iterations in  0.11707580299116671  seconds by  99.05405062938392  percent.
# interpolate adjoint :  True True True
# initial cost =  35.42857391609264
# RUN  0 , total integrated cost =  35.42857391609264
# Gradient descend method:  None
# RUN  1 , total integrated cost =  8.938426800242036
# RUN  2 , total integrated cost =  6.878683643014208
# RUN  3 , total integrated cost =  6.827778990755767
# RUN  4 , total integrated cost =  6.671189588943935
# RUN  5 , total integrated cost =  6.5088197739629665
# RUN  6 , total integrated cost =  6.572534968230157
# RUN  7 , total integrated cost =  6.4433580958778744
# RUN  8 , total integrated cost =  6.4573320419343725
# RUN  9 , total integrated cost =  6.410480247841802
# RUN  10 , total integrated cost =  6.429927811970567
# RUN  11 , total integrated cost =  6.4072812731673725
# RUN  12 , total integrated cost =  6.380357337947339
# RUN  12 , total integrated cost =  6.380357337947339
# Improved over  12  iterations in  0.8824717440002132  seconds by  81.99092813315525  percent.
# -------- 49
# interpolate adjoint :  True True True
# initial cost =  3686.9858764773517
# RUN  0 , total integrated cost =  3686.9858764773517
# Gradient descend method:  None
# RUN  1 , total integrated cost =  111.15918027835427
# RUN  2 , total integrated cost =  34.319945581749984
# RUN  3 , total integrated cost =  10.463690946731461
# RUN  3 , total integrated cost =  10.463690946731461
# Improved over  3  iterations in  0.11230728500231635  seconds by  99.71619932114498  percent.
# interpolate adjoint :  True True True
# initial cost =  12.246301530904699
# RUN  0 , total integrated cost =  12.246301530904699
# Gradient descend method:  None
# RUN  1 , total integrated cost =  8.52009160062765
# RUN  2 , total integrated cost =  8.068330338060504
# RUN  3 , total integrated cost =  7.9169207255270795
# RUN  4 , total integrated cost =  7.820944807005297
# RUN  5 , total integrated cost =  7.816878872923297
# RUN  6 , total integrated cost =  7.784927727278401
# RUN  7 , total integrated cost =  7.723604693298103
# RUN  8 , total integrated cost =  7.691317438068763
# RUN  9 , total integrated cost =  7.658310994827779
# RUN  10 , total integrated cost =  7.628286425004629
# RUN  11 , total integrated cost =  7.727506340183924
# RUN  12 , total integrated cost =  7.665867023933526
# RUN  12 , total integrated cost =  7.665867023933526
# Improved over  12  iterations in  0.7987560239998857  seconds by  37.40259453363951  percent.
# mean =  6.986964083843959
# set cost params:  0.005296797491520405 0.0 1.0 0.0
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_95869/735496248.py in <module>
#       5 for i_sigma in range(3):
#       6
# ----> 7     cost.setParams(w_p[i_sigma], w_e, w_s)
#       8
#       9     for i_noise in range(3):
#
# IndexError: index 2 is out of bounds for axis 0 with size 2
