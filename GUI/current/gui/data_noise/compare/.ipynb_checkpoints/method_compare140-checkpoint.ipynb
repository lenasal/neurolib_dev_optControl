# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import sys
import pickle
import matplotlib

path = os.getcwd().split(os.sep + 'GUI')[0]
if path not in sys.path:
    print("not here")
    sys.path.append(path)

from neurolib.models.aln import ALNModel
from neurolib.utils import plotFunctions as plotFunc
from neurolib.utils import costFunctions as cost
from neurolib.utils import func_optimize as fo
import neurolib.dashboard.functions as functions
import neurolib.dashboard.data as data
import neurolib.dashboard.layout as layout

    
# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2 

#path = os.path.join(os.getcwd(), "plots")

cmap_ = layout.getcolormap()
darkgrey, midgrey, lightgrey, color_bi_updown, color_LC, color_bi_uposc = layout.getcolors()
exc_red = cmap_(3)
inh_blue=cmap_(0)
green = cmap_(2)
# Out:
# not here

# %%
aln = ALNModel()
N = aln.params.N

data.set_parameters(aln)

state_vars = aln.state_vars
init_vars = aln.init_vars

##############################################################
def setinit(init_vars_, model):
    state_vars = model.state_vars
    init_vars = model.init_vars
    for iv in range(len(init_vars)):
        for sv in range(len(state_vars)):
            if state_vars[sv] in init_vars[iv]:
                #print("set init vars ", )
                if model.params[init_vars[iv]].ndim == 2:
                    model.params[init_vars[iv]][0,:] = init_vars_[sv]
                else:
                    model.params[init_vars[iv]][0] = init_vars_[sv]
                    
##############################################################               
def setmaxmincontrol(max_c_c, min_c_c, max_c_r, min_c_r):
    import numpy as np
    
    max_cntrl = np.zeros(( 6 ))
    min_cntrl = np.zeros(( 6 ))
    
    max_cntrl[0] = max_c_c
    min_cntrl[0] = min_c_c
    max_cntrl[1] = max_c_c
    min_cntrl[1] = min_c_c
    max_cntrl[2] = max_c_r
    min_cntrl[2] = min_c_r
    max_cntrl[3] = max_c_r
    min_cntrl[3] = min_c_r
    max_cntrl[4] = max_c_r
    min_cntrl[4] = min_c_r
    max_cntrl[5] = max_c_r
    min_cntrl[5] = min_c_r
            
    return max_cntrl, min_cntrl

# %%
##### LOAD BOUNDARIES
data_file = '..' + os.sep + '..' + os.sep + 'bi.pickle'
with open(data_file,'rb') as f:
    load_array= pickle.load(f)
exc = load_array[0]
inh = load_array[1]

# %%
bestControl = [None] * len(exc)
bestState = [None] * len(exc)
cost_ = [None] * len(exc)
runtime = [None] * len(exc)
grad = [None] * len(exc)
phi = [None] * len(exc)
costnode = [None] * len(exc)
weights = [None] * len(exc)

# %%
initVars = [None] * len(exc)
target = [None] * len(exc)
cost_uncontrolled = [None] * len(exc)

cgv_list = [None, "HS", "FR", "PR", "CD", "LS", "DY", "WYL", "HZ", None]

# %%
dur_pre = 10
dur_post = 10

n_pre = int(np.around(dur_pre/aln.params.dt + 1.,1))
n_post = int(np.around(dur_post/aln.params.dt + 1.,1))

tol = 1e-32
start_step = 10.
c_scheme = np.zeros(( 1,1 ))
c_scheme[0,0] = 1.
u_mat = np.identity(1)
u_scheme = np.array([[1.]])

### CURRENTS
cntrl_vars_0 = [0,1]
prec_vars = [0]

dur = 100
trans_time = 0.8
maxC = [5., -5., 0.18, 0.]
n_dur = int(np.around(dur/aln.params.dt + 1.,1))
max_cntrl, min_cntrl = setmaxmincontrol(maxC[0], maxC[1], maxC[2], maxC[3])

case = '1'

if case == '1':
    max_I = [3., -3.]
    factor_ws = 1.
    factor_we = 0.
    read_file = '..' + os.sep + 'data_final_2' + os.sep + 'control_1.pickle'

# %%
if os.path.isfile(read_file) :
    print("file found")
    
    with open(read_file,'rb') as f:
        load_array = pickle.load(f)

    bestControl = load_array[0]
    bestState = load_array[1]
    cost_ = load_array[2]
    costnode = load_array[3]
    weights = load_array[4]

# %%
i_range = [20]
stable_state = np.zeros(( len(exc), 2,2,2, 2))

# %%
# get init vars without noise

data.set_parameters(aln)
aln.params.duration = 3000.

control0 = functions.step_control(aln, maxI_ = max_I[1])

# low state without noise
for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.

    aln.run(control=control0)

    init_state_vars = np.zeros(( len(state_vars) ))
    for j in range(len(state_vars)):
        if aln.state[state_vars[j]].size == 1:
            init_state_vars[j] = aln.state[state_vars[j]][0]
        else:
            init_state_vars[j] = aln.state[state_vars[j]][0,-1]

    initVars[i] = init_state_vars
    
    stable_state[i,0,0,0,0] = aln.rates_exc[0,-1]
    stable_state[i,0,0,1,0] = aln.rates_inh[0,-1]

# high state without noise
control0 = aln.getZeroControl()
control0[0,0,:500] = 5.

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.

    aln.params.duration = 3000.
    aln.run(control=control0)
    stable_state[i,0,1,0,0] = aln.rates_exc[0,-1]
    stable_state[i,0,1,1,0] = aln.rates_inh[0,-1]
    
    aln.params.duration = dur
    target_det = aln.getZeroTarget()
    target_det[:,0,:] = aln.rates_exc[0,-1]
    target_det[:,1,:] = aln.rates_inh[0,-1]
    
    print('exc low, high ', stable_state[i,0,0,0,0], stable_state[i,0,1,0,0])
    print('inh low, high ', stable_state[i,0,0,1,0], stable_state[i,0,1,1,0])
# Out:
# -------  20 0.4500000000000001 0.4750000000000002
# -------  20 0.4500000000000001 0.4750000000000002
# exc low, high  0.00020800079839487667 35.69070596632364
# inh low, high  22.354548572416867 90.39821580372033

# %%
# get initial parameters and target states with noise

sigma_ou = 0.1
noise_realizations_final = 10000

# set target with noise
aln.params.sigma_ou = sigma_ou
aln.params.duration = 300.
control0 = aln.getZeroControl()
control0[0,0,:500] = 5.

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.

    target_rates_e = []
    target_rates_i = []

    for j in range(noise_realizations_final):
        aln.params.duration = 300.
        aln.run(control=control0)
        if np.amin(aln.rates_exc[0,1000:]) < 1.:
            print("fell in down state, repeat")
            j -= 1
            continue
        target_rates_e.append(aln.rates_exc[0,1000:])
        target_rates_i.append(aln.rates_inh[0,1000:])

    aln.params.duration = dur
    target[i] = aln.getZeroTarget()
    target[i][:,0,:] = np.mean(target_rates_e)
    target[i][:,1,:] = np.mean(target_rates_i)
    
    stable_state[i,1,1,0,0] = target[i][0,0,-1]
    stable_state[i,1,1,1,0] = target[i][0,1,-1]
    stable_state[i,1,1,0,1] = np.std(target_rates_e)
    stable_state[i,1,1,1,1] = np.std(target_rates_i)
    
    
aln.params.duration = 300.
control0 = aln.getZeroControl()
control0[0,0,:500] = -5.

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.

    target_rates_e = []
    target_rates_i = []

    for j in range(noise_realizations_final):
        aln.params.duration = 300.
        aln.run(control=control0)
        if np.amin(aln.rates_exc[0,1000:]) > 10.:
            print("fell in up state, repeat")
            j -= 1
            continue
        target_rates_e.append(aln.rates_exc[0,1000:])
        target_rates_i.append(aln.rates_inh[0,1000:])

    stable_state[i,1,0,0,0] = np.mean(target_rates_e)
    stable_state[i,1,0,1,0] = np.mean(target_rates_i)
    stable_state[i,1,0,0,1] = np.std(target_rates_e)
    stable_state[i,1,0,1,1] = np.std(target_rates_i)
    
print('exc low, high with noise ', stable_state[i,1,0,0,0], stable_state[i,1,1,0,0])
print('inh low, high with noise ', stable_state[i,1,0,1,0], stable_state[i,1,1,1,0])
# Out:
# -------  20 0.4500000000000001 0.4750000000000002
# fell in down state, repeat
# fell in down state, repeat
# fell in down state, repeat
# fell in down state, repeat
# -------  20 0.4500000000000001 0.4750000000000002
# exc low, high with noise  0.0008676127008049616 35.25876415393818
# inh low, high with noise  22.478282546227522 90.06140928416514

# %%
diff_low = np.zeros(( 83,2 ))
diff_high = np.zeros(( 83,2 ))

for i in i_range:
    print('------  ', i)
    diff_low[i,:] = [stable_state[i,0,0,0,0] - stable_state[i,1,0,0,0],
                stable_state[i,0,0,1,0] - stable_state[i,1,0,1,0]]
    print("difference in low rate exc/ inh: ", diff_low[i,:])
    print("std dev low rate exc/ inh: ", stable_state[i,1,0,0,1], stable_state[i,1,0,1,1])
    diff_high[i,:] =  [stable_state[i,0,1,0,0] - stable_state[i,1,1,0,0],
                 stable_state[i,0,1,1,0] - stable_state[i,1,1,1,0]]
    print("difference in high rate exc/ inh: ", diff_high[i,:])
    print("std dev high rate exc/ inh: ", stable_state[i,1,1,0,1], stable_state[i,1,1,1,1])
# Out:
# ------   20
# difference in low rate exc/ inh:  [-0.00065961 -0.12373397]
# std dev low rate exc/ inh:  0.005011982452364042 4.1506821503283655
# difference in high rate exc/ inh:  [0.43194181 0.33680652]
# std dev high rate exc/ inh:  5.83709415943879 4.4580822162942555

# %%
print("Max/ min / min abs diff low rate EXC",
      np.amax(diff_low[:,0]), np.amin(diff_low[:,0]), np.amin(np.abs(diff_low[:,0])))
print("Max/ min / min abs diff low rate INH",
      np.amax(diff_low[:,1]), np.amin(diff_low[:,1]), np.amin(np.abs(diff_low[:,1])))
print("Max/ min / min abs diff high rate EXC",
      np.amax(diff_high[:,0]), np.amin(diff_high[:,0]), np.amin(np.abs(diff_high[:,0])))
print("Max/ min / min abs diff high rate INH",
      max(diff_high[:,1]), min(diff_high[:,1]), np.amin(np.abs(diff_high[:,1])))
print('---')
for i in i_range:
    if diff_high[i,0] < 0.:
        print(i, diff_high[i], ' low ', stable_state[i,1,0,:,0], 'high ', stable_state[i,1,1,:,0])
print('---')
for i in i_range:
    if diff_high[i,1] > 0.:
        print(i, diff_high[i], ' low ', stable_state[i,1,0,:,0], 'high ', stable_state[i,1,1,:,0])
# Out:
# Max/ min / min abs diff low rate EXC 0.0 -0.000659611902410085 0.0
# Max/ min / min abs diff low rate INH 0.0 -0.12373397381065487 0.0
# Max/ min / min abs diff high rate EXC 0.43194181238546037 0.0 0.0
# Max/ min / min abs diff high rate INH 0.33680651955519636 0.0 0.0
# ---
# ---
# 20 [0.43194181 0.33680652]  low  [8.67612701e-04 2.24782825e+01] high  [35.25876415 90.06140928]

# %%
init_control_noisefree = bestControl[20]

w_e = 0.
w_s = 1.
w_p = np.zeros(( len(exc) ))

for i in i_range:
    w_p[i] = 1. / ( ( stable_state[i,1,1,0,1] + stable_state[i,1,1,1,1] ) * (1. - trans_time) * dur / aln.params.dt )

# %%
dur = 100.
max_it = 10
noise_realizations = 140
noise_realizations_final = 20000
aln.params.sigma_ou = sigma_ou
prec_vars = [0,1]
i = 20

control_list = [None, None, None, None] # 4 methods
cost_list = [None, None, None, None]
mean_cost = [ None, None, None, None ]

# %%
aln.params.duration = dur
zero_init = aln.getZeroControl()

aln.params.ext_exc_current = exc[i] * 5.
aln.params.ext_inh_current = inh[i] * 5.

print("------- ", i, exc[i], inh[i], noise_realizations)

##### zero control as input for uncontrolled cost
cost.setParams(w_p[i], w_e, w_s)

m1_control_list = []
m1_cost_list = []

control_list[0] = np.zeros(( zero_init.shape[0], zero_init.shape[1], zero_init.shape[2]+200 ))
cost_list[0] = np.zeros(( max_it+1 ))
cost_n = np.zeros(( max_it + 1 ))

min_it = 10
n_ = 0

while n_  < noise_realizations:
    print("---------", n_)
    mean_cost[0] = []
    setinit(initVars[i], aln)

    bestControl[i], bestState[i], cost_[i], runtime[i], grad[i], phi[i], costnode[i], total_cost_mean_std = aln.A1(
        zero_init, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it,
        tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
        t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
        control_variables_ = [0,1], prec_variables_ = prec_vars, transition_time_ = trans_time,
        noise_real=0, init_params = initVars[i])
    
    if cost_[i][min_it] == 0:
        continue
        
    max_jump = 0.
    for v_ in range(bestControl[i].shape[1]):
        for t_ in range(1, bestControl[i].shape[2]):
            diff = np.abs(bestControl[i][0,v_,t_] - bestControl[i][0,v_,t_-1])
            if  diff > max_jump:
                max_jump = diff
                
    if max_jump > 0.5:
        continue
    
    m1_control_list.append(bestControl[i])
    control_list[0] += bestControl[i]
    m1_cost_list.append(cost_[i])
    cost_list[0] += cost_[i]
    
    for c_ in range(len(cost_[i])):
        if cost_[i][c_] != 0.:
            cost_n[c_] += 1
            
    n_ += 1
    
control_list[0] /= noise_realizations
for c_ in range(len(cost_list[0])):
    cost_list[0][c_] /= cost_n[c_]
    
print(cost_list[0])
print('IMPROVEMENT : ', 100. -  100.*cost_list[0][-1]/cost_list[0][0])
# Out:
# -------  20 0.4500000000000001 0.4750000000000002 140
# set cost params:  0.00048566433614343857 0.0 1.0
# --------- 0
# interpolate adjoint :  True True True
# initial cost =  151.46943784519553
# RUN  0 , total integrated cost =  151.46943784519553
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12.161519864016563
# RUN  2 , total integrated cost =  10.813381890955618
# RUN  3 , total integrated cost =  11.554625017064588
# RUN  4 , total integrated cost =  7.4278947162688
# Control only changes marginally.
# RUN  4 , total integrated cost =  7.4278947162688
# Improved over  4  iterations in  13.765681736999795  seconds by  95.09610993350339  percent.
# --------- 0
# interpolate adjoint :  True True True
# initial cost =  149.3809517053003
# RUN  0 , total integrated cost =  149.3809517053003
# Gradient descend method:  None
# RUN  1 , total integrated cost =  41.922112694889165
# RUN  2 , total integrated cost =  40.749473656873924
# RUN  3 , total integrated cost =  39.85567114274941
# RUN  4 , total integrated cost =  40.30884510412569
# RUN  5 , total integrated cost =  40.158617408355724
# RUN  6 , total integrated cost =  40.00344142958419
# RUN  7 , total integrated cost =  39.8946527261495
# RUN  8 , total integrated cost =  39.91523632460972
# RUN  9 , total integrated cost =  39.93581897442883
# RUN  10 , total integrated cost =  39.90288254980142
# RUN  10 , total integrated cost =  39.90288254980142
# Improved over  10  iterations in  0.6454400140000871  seconds by  73.28783750921464  percent.
# --------- 0
# interpolate adjoint :  True True True
# initial cost =  140.5361762868678
# RUN  0 , total integrated cost =  140.5361762868678
# Gradient descend method:  None
# RUN  1 , total integrated cost =  41.79388652486663
# RUN  2 , total integrated cost =  40.81869737043155
# RUN  3 , total integrated cost =  40.23454402287114
# RUN  4 , total integrated cost =  40.26595221484809
# RUN  5 , total integrated cost =  39.74201083200556
# RUN  6 , total integrated cost =  40.31869315210238
# RUN  7 , total integrated cost =  39.8387864084522
# RUN  8 , total integrated cost =  39.822778165988225
# RUN  9 , total integrated cost =  39.653591201924115
# RUN  10 , total integrated cost =  40.30717421545538
# RUN  10 , total integrated cost =  40.30717421545538
# Improved over  10  iterations in  0.6518413849998979  seconds by  71.31900462897265  percent.
# --------- 1
# interpolate adjoint :  True True True
# initial cost =  151.14427074041507
# RUN  0 , total integrated cost =  151.14427074041507
# Gradient descend method:  None
# RUN  1 , total integrated cost =  41.55016004735966
# RUN  2 , total integrated cost =  41.197515316885
# RUN  3 , total integrated cost =  40.16603651965029
# RUN  4 , total integrated cost =  40.14822791803257
# RUN  5 , total integrated cost =  40.051046029922084
# RUN  6 , total integrated cost =  40.18314657113855
# RUN  7 , total integrated cost =  40.04523494223069
# RUN  8 , total integrated cost =  40.22790532519615
# RUN  9 , total integrated cost =  40.0883362209455
# RUN  10 , total integrated cost =  39.427572206057064
# RUN  10 , total integrated cost =  39.427572206057064
# Improved over  10  iterations in  0.6670648789995539  seconds by  73.91394856522712  percent.
# --------- 1
# interpolate adjoint :  True True True
# initial cost =  127.22569500736572
# RUN  0 , total integrated cost =  127.22569500736572
# Gradient descend method:  None
# RUN  1 , total integrated cost =  41.8464834495996
# RUN  2 , total integrated cost =  40.562005989129595
# RUN  3 , total integrated cost =  40.050394063458114
# RUN  4 , total integrated cost =  40.05708560288715
# RUN  5 , total integrated cost =  39.89563460067485
# RUN  6 , total integrated cost =  40.38609144212428
# RUN  7 , total integrated cost =  39.67198745779389
# RUN  8 , total integrated cost =  39.864028074932726
# RUN  9 , total integrated cost =  40.03336698971117
# RUN  10 , total integrated cost =  39.841458812702484
# RUN  10 , total integrated cost =  39.841458812702484
# Improved over  10  iterations in  0.859465306999482  seconds by  68.68442431350375  percent.
# --------- 1
# interpolate adjoint :  True True True
# initial cost =  140.9883095993653
# RUN  0 , total integrated cost =  140.9883095993653
# Gradient descend method:  None
# RUN  1 , total integrated cost =  42.572486198639446
# RUN  2 , total integrated cost =  40.62992207175925
# RUN  3 , total integrated cost =  40.61338050006165
# RUN  4 , total integrated cost =  39.98582248422376
# RUN  5 , total integrated cost =  39.97691965641163
# RUN  6 , total integrated cost =  39.92618640220952
# RUN  7 , total integrated cost =  40.0085639919936
# RUN  8 , total integrated cost =  40.051637064245604
# RUN  9 , total integrated cost =  40.016720783703626
# RUN  10 , total integrated cost =  40.01130774060783
# RUN  10 , total integrated cost =  40.01130774060783
# Improved over  10  iterations in  0.7522867990001032  seconds by  71.62083306459618  percent.
# --------- 1
# interpolate adjoint :  True True True
# initial cost =  138.62132051080522
# RUN  0 , total integrated cost =  138.62132051080522
# Gradient descend method:  None
# RUN  1 , total integrated cost =  19.256161309614047
# RUN  2 , total integrated cost =  11.061583297269785
# RUN  3 , total integrated cost =  10.568206158470684
# RUN  4 , total integrated cost =  10.309436081003136
# RUN  5 , total integrated cost =  9.392768348623367
# RUN  6 , total integrated cost =  7.476229564952501
# RUN  7 , total integrated cost =  8.551557289281577
# RUN  8 , total integrated cost =  6.416284184341121
# RUN  9 , total integrated cost =  6.979569805119658
# RUN  10 , total integrated cost =  8.118980980287484
# RUN  10 , total integrated cost =  8.118980980287484
# Improved over  10  iterations in  0.665997499999321  seconds by  94.14305032561379  percent.
# --------- 2
# interpolate adjoint :  True True True
# initial cost =  154.11651979489395
# RUN  0 , total integrated cost =  154.11651979489395
# Gradient descend method:  None
# RUN  1 , total integrated cost =  10.780021744517931
# RUN  2 , total integrated cost =  11.23778687402978
# RUN  3 , total integrated cost =  13.397557301912531
# RUN  4 , total integrated cost =  12.053924565139145
# RUN  5 , total integrated cost =  10.144013404019857
# RUN  6 , total integrated cost =  13.729880910657862
# RUN  7 , total integrated cost =  6.869021913290203
# RUN  8 , total integrated cost =  5.69174733527337
# RUN  9 , total integrated cost =  5.130064888530048
# RUN  10 , total integrated cost =  5.939794191608296
# RUN  10 , total integrated cost =  5.939794191608296
# Improved over  10  iterations in  0.5849370699997962  seconds by  96.14590687648976  percent.
# --------- 3
# interpolate adjoint :  True True True
# initial cost =  133.7973248442499
# RUN  0 , total integrated cost =  133.7973248442499
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.443114748704883
# RUN  2 , total integrated cost =  8.11588610077366
# RUN  3 , total integrated cost =  7.766873507006954
# RUN  4 , total integrated cost =  7.50412326117623
# RUN  5 , total integrated cost =  7.361575665247996
# RUN  6 , total integrated cost =  7.067106192328228
# RUN  7 , total integrated cost =  6.818317951359138
# Control only changes marginally.
# RUN  7 , total integrated cost =  6.818317951359138
# Improved over  7  iterations in  0.3865976649994991  seconds by  94.90399530835451  percent.
# --------- 3
# interpolate adjoint :  True True True
# initial cost =  142.71986376208108
# RUN  0 , total integrated cost =  142.71986376208108
# Gradient descend method:  None
# RUN  1 , total integrated cost =  17.94986306166355
# RUN  2 , total integrated cost =  13.349808266980249
# RUN  3 , total integrated cost =  9.982505452012228
# RUN  4 , total integrated cost =  11.92290037298621
# RUN  5 , total integrated cost =  8.04656023203529
# RUN  6 , total integrated cost =  6.5246703442372045
# RUN  7 , total integrated cost =  6.088664927050909
# RUN  8 , total integrated cost =  6.379012314586678
# RUN  9 , total integrated cost =  5.840279390746186
# RUN  10 , total integrated cost =  6.181360831446533
# RUN  10 , total integrated cost =  6.181360831446533
# Improved over  10  iterations in  0.6930983119991652  seconds by  95.66888541755402  percent.
# --------- 4
# interpolate adjoint :  True True True
# initial cost =  151.64731536075595
# RUN  0 , total integrated cost =  151.64731536075595
# Gradient descend method:  None
# RUN  1 , total integrated cost =  42.40931394748775
# RUN  2 , total integrated cost =  40.8025030389596
# RUN  3 , total integrated cost =  40.727391320821795
# RUN  4 , total integrated cost =  40.70121132416609
# RUN  5 , total integrated cost =  40.59417737371355
# RUN  6 , total integrated cost =  40.558841752195775
# RUN  7 , total integrated cost =  40.2030147293865
# RUN  8 , total integrated cost =  40.27252932575604
# RUN  9 , total integrated cost =  17.038593416756108
# RUN  10 , total integrated cost =  15.242721843607768
# RUN  10 , total integrated cost =  15.242721843607768
# Improved over  10  iterations in  0.40826256799937255  seconds by  89.94857125736341  percent.
# --------- 4
# interpolate adjoint :  True True True
# initial cost =  151.93426021830604
# RUN  0 , total integrated cost =  151.93426021830604
# Gradient descend method:  None
# RUN  1 , total integrated cost =  43.12141089617597
# RUN  2 , total integrated cost =  40.67573137921253
# RUN  3 , total integrated cost =  39.82240519660591
# RUN  4 , total integrated cost =  40.1612868927717
# RUN  5 , total integrated cost =  40.10116002413901
# RUN  6 , total integrated cost =  40.10117157517992
# RUN  7 , total integrated cost =  40.0614891157704
# RUN  8 , total integrated cost =  39.906622584110224
# RUN  9 , total integrated cost =  39.72678835922747
# RUN  10 , total integrated cost =  39.91048922809261
# RUN  10 , total integrated cost =  39.91048922809261
# Improved over  10  iterations in  0.5118220439999277  seconds by  73.73173820654577  percent.
# --------- 5
# interpolate adjoint :  True True True
# initial cost =  148.331345871942
# RUN  0 , total integrated cost =  148.331345871942
# Gradient descend method:  None
# RUN  1 , total integrated cost =  8.27125310421723
# RUN  2 , total integrated cost =  5.2692535585447065
# RUN  3 , total integrated cost =  5.9988475117422375
# RUN  4 , total integrated cost =  5.708157677649297
# RUN  5 , total integrated cost =  5.404288087608737
# RUN  6 , total integrated cost =  6.522083499906581
# RUN  7 , total integrated cost =  5.997705155607907
# RUN  8 , total integrated cost =  5.906146384808574
# Control only changes marginally.
# RUN  8 , total integrated cost =  5.906146384808574
# Improved over  8  iterations in  0.7049496069994348  seconds by  96.01827493029862  percent.
# --------- 5
# interpolate adjoint :  True True True
# initial cost =  134.7722540497045
# RUN  0 , total integrated cost =  134.7722540497045
# Gradient descend method:  None
# RUN  1 , total integrated cost =  42.488696853239816
# RUN  2 , total integrated cost =  40.447081163396476
# RUN  3 , total integrated cost =  39.754019841031365
# RUN  4 , total integrated cost =  39.89966338826048
# RUN  5 , total integrated cost =  40.07897161031519
# RUN  6 , total integrated cost =  40.00913795691737
# RUN  7 , total integrated cost =  40.00142439795572
# RUN  8 , total integrated cost =  40.210994940189096
# RUN  9 , total integrated cost =  40.329948177740995
# RUN  10 , total integrated cost =  40.24125979778806
# RUN  10 , total integrated cost =  40.24125979778806
# Improved over  10  iterations in  0.38240487100028986  seconds by  70.14128755096213  percent.
# --------- 5
# interpolate adjoint :  True True True
# initial cost =  141.34942036655178
# RUN  0 , total integrated cost =  141.34942036655178
# Gradient descend method:  None
# RUN  1 , total integrated cost =  42.303658839439606
# RUN  2 , total integrated cost =  40.78631421907746
# RUN  3 , total integrated cost =  40.28572568004074
# RUN  4 , total integrated cost =  39.98979246181824
# RUN  5 , total integrated cost =  39.961394991078535
# RUN  6 , total integrated cost =  39.85222128882542
# RUN  7 , total integrated cost =  39.9697903905637
# RUN  8 , total integrated cost =  39.92326581548304
# RUN  9 , total integrated cost =  40.43252011673507
# RUN  10 , total integrated cost =  39.94160948962142
# RUN  10 , total integrated cost =  39.94160948962142
# Improved over  10  iterations in  0.33604061999994883  seconds by  71.74264359482792  percent.
# --------- 6
# interpolate adjoint :  True True True
# initial cost =  137.29525049932096
# RUN  0 , total integrated cost =  137.29525049932096
# Gradient descend method:  None
# RUN  1 , total integrated cost =  13.190139031565987
# RUN  2 , total integrated cost =  7.24409175994574
# RUN  3 , total integrated cost =  6.025300753510157
# RUN  4 , total integrated cost =  5.745098191125655
# RUN  5 , total integrated cost =  5.796212917275264
# RUN  6 , total integrated cost =  5.575866170418725
# RUN  7 , total integrated cost =  5.316358110623711
# RUN  8 , total integrated cost =  5.879964147358161
# RUN  9 , total integrated cost =  5.870107089160749
# RUN  10 , total integrated cost =  6.356123246903625
# RUN  10 , total integrated cost =  6.356123246903625
# Improved over  10  iterations in  0.3906137799995122  seconds by  95.37047113881404  percent.
# --------- 7
# interpolate adjoint :  True True True
# initial cost =  154.54650705201735
# RUN  0 , total integrated cost =  154.54650705201735
# Gradient descend method:  None
# RUN  1 , total integrated cost =  41.89115247282745
# RUN  2 , total integrated cost =  40.75699738097138
# RUN  3 , total integrated cost =  40.632489194616
# RUN  4 , total integrated cost =  40.60822789621104
# RUN  5 , total integrated cost =  40.438845115216694
# RUN  6 , total integrated cost =  39.81504550227876
# RUN  7 , total integrated cost =  39.821489127128714
# RUN  8 , total integrated cost =  39.89860803029598
# RUN  9 , total integrated cost =  39.72982486709762
# RUN  10 , total integrated cost =  39.833534119322664
# RUN  10 , total integrated cost =  39.833534119322664
# Improved over  10  iterations in  0.5508568320001359  seconds by  74.22553580850878  percent.
# --------- 8
# interpolate adjoint :  True True True
# initial cost =  144.13701369129953
# RUN  0 , total integrated cost =  144.13701369129953
# Gradient descend method:  None
# RUN  1 , total integrated cost =  41.31087936285695
# RUN  2 , total integrated cost =  40.26380849966966
# RUN  3 , total integrated cost =  40.39403578238664
# RUN  4 , total integrated cost =  40.573992757369275
# RUN  5 , total integrated cost =  40.57788860292443
# RUN  6 , total integrated cost =  40.413744531642394
# RUN  7 , total integrated cost =  40.138291255905344
# RUN  8 , total integrated cost =  40.39051705789079
# RUN  9 , total integrated cost =  40.099316215214984
# RUN  10 , total integrated cost =  39.73971112762033
# RUN  10 , total integrated cost =  39.73971112762033
# Improved over  10  iterations in  0.3668589400003839  seconds by  72.42921154677765  percent.
# --------- 8
# interpolate adjoint :  True True True
# initial cost =  140.00817748326028
# RUN  0 , total integrated cost =  140.00817748326028
# Gradient descend method:  None
# RUN  1 , total integrated cost =  43.16605952479791
# RUN  2 , total integrated cost =  39.98738569805005
# RUN  3 , total integrated cost =  40.2094072975964
# RUN  4 , total integrated cost =  39.92669740209793
# RUN  5 , total integrated cost =  39.98322091811847
# RUN  6 , total integrated cost =  39.784765486004986
# RUN  7 , total integrated cost =  39.93034074671118
# RUN  8 , total integrated cost =  39.83897214300309
# RUN  9 , total integrated cost =  39.72011877767291
# Control only changes marginally.
# RUN  9 , total integrated cost =  39.72011877767291
# Improved over  9  iterations in  0.591228955000588  seconds by  71.63014368755572  percent.
# --------- 8
# interpolate adjoint :  True True True
# initial cost =  135.98383772261522
# RUN  0 , total integrated cost =  135.98383772261522
# Gradient descend method:  None
# RUN  1 , total integrated cost =  17.1605724952962
# RUN  2 , total integrated cost =  9.305485763251816
# RUN  3 , total integrated cost =  6.518811527412707
# RUN  4 , total integrated cost =  6.326211941246419
# RUN  5 , total integrated cost =  6.246774748872191
# RUN  6 , total integrated cost =  5.838355359698446
# RUN  7 , total integrated cost =  6.564596317864627
# RUN  8 , total integrated cost =  6.405854508938548
# RUN  9 , total integrated cost =  6.083805557609869
# RUN  10 , total integrated cost =  5.272788908532847
# RUN  10 , total integrated cost =  5.272788908532847
# Improved over  10  iterations in  0.6044833880005172  seconds by  96.12248852743186  percent.
# --------- 9
# interpolate adjoint :  True True True
# initial cost =  146.0314870260567
# RUN  0 , total integrated cost =  146.0314870260567
# Gradient descend method:  None
# RUN  1 , total integrated cost =  21.297378526983945
# RUN  2 , total integrated cost =  14.793180203111152
# RUN  3 , total integrated cost =  9.039364751799075
# RUN  4 , total integrated cost =  8.841100188329062
# RUN  5 , total integrated cost =  8.735278276163042
# RUN  6 , total integrated cost =  8.390561931591053
# RUN  7 , total integrated cost =  8.037128474245254
# RUN  8 , total integrated cost =  7.8944297446493525
# RUN  9 , total integrated cost =  7.5366298050437495
# RUN  10 , total integrated cost =  7.157304756848586
# RUN  10 , total integrated cost =  7.157304756848586
# Improved over  10  iterations in  0.4768075179999869  seconds by  95.09879348446853  percent.
# --------- 10
# interpolate adjoint :  True True True
# initial cost =  153.6994749928937
# RUN  0 , total integrated cost =  153.6994749928937
# Gradient descend method:  None
# RUN  1 , total integrated cost =  43.46366400938864
# RUN  2 , total integrated cost =  40.22715635821238
# RUN  3 , total integrated cost =  40.137898869682466
# RUN  4 , total integrated cost =  39.914553900000385
# RUN  5 , total integrated cost =  39.95475067778175
# RUN  6 , total integrated cost =  39.875489277337884
# Control only changes marginally.
# RUN  6 , total integrated cost =  39.875489277337884
# Improved over  6  iterations in  0.3879091260005225  seconds by  74.05619682228483  percent.
# --------- 10
# interpolate adjoint :  True True True
# initial cost =  139.26600626479285
# RUN  0 , total integrated cost =  139.26600626479285
# Gradient descend method:  None
# RUN  1 , total integrated cost =  21.493249704326107
# RUN  2 , total integrated cost =  7.802027590927638
# RUN  3 , total integrated cost =  11.052935124128554
# RUN  4 , total integrated cost =  8.54901848227517
# RUN  5 , total integrated cost =  8.298684046566152
# RUN  6 , total integrated cost =  7.659638646991732
# RUN  7 , total integrated cost =  7.91124452920285
# RUN  8 , total integrated cost =  6.2628038584783745
# RUN  9 , total integrated cost =  5.8054812343554385
# RUN  10 , total integrated cost =  6.458986063844394
# RUN  10 , total integrated cost =  6.458986063844394
# Improved over  10  iterations in  0.39841150999927777  seconds by  95.3621230068423  percent.
# --------- 11
# interpolate adjoint :  True True True
# initial cost =  131.87356789588546
# RUN  0 , total integrated cost =  131.87356789588546
# Gradient descend method:  None
# RUN  1 , total integrated cost =  42.799882313271326
# RUN  2 , total integrated cost =  41.03358910129458
# RUN  3 , total integrated cost =  39.94043561552294
# RUN  4 , total integrated cost =  40.03668219153086
# RUN  5 , total integrated cost =  40.261163133712856
# RUN  6 , total integrated cost =  40.32966129178752
# RUN  7 , total integrated cost =  40.12062943212403
# RUN  8 , total integrated cost =  40.09921348328007
# RUN  9 , total integrated cost =  40.17336786380689
# RUN  10 , total integrated cost =  40.440576529633084
# RUN  10 , total integrated cost =  40.440576529633084
# Improved over  10  iterations in  0.3618347339997854  seconds by  69.3338269564671  percent.
# --------- 11
# interpolate adjoint :  True True True
# initial cost =  149.7238267707881
# RUN  0 , total integrated cost =  149.7238267707881
# Gradient descend method:  None
# RUN  1 , total integrated cost =  42.243355132178856
# RUN  2 , total integrated cost =  40.56918089197965
# RUN  3 , total integrated cost =  40.122443565282765
# RUN  4 , total integrated cost =  39.8333277826555
# RUN  5 , total integrated cost =  39.75398442462721
# RUN  6 , total integrated cost =  39.71392104600238
# RUN  7 , total integrated cost =  40.12273142563666
# RUN  8 , total integrated cost =  39.91813458352501
# RUN  9 , total integrated cost =  39.994616603819196
# RUN  10 , total integrated cost =  40.08616353199392
# RUN  10 , total integrated cost =  40.08616353199392
# Improved over  10  iterations in  0.39026060800006235  seconds by  73.22659699757625  percent.
# --------- 12
# interpolate adjoint :  True True True
# initial cost =  141.4491354339851
# RUN  0 , total integrated cost =  141.4491354339851
# Gradient descend method:  None
# RUN  1 , total integrated cost =  42.17805573143596
# RUN  2 , total integrated cost =  40.58861887074811
# RUN  3 , total integrated cost =  40.169675654155434
# RUN  4 , total integrated cost =  40.32656547091728
# RUN  5 , total integrated cost =  40.18388871053037
# RUN  6 , total integrated cost =  39.994952976985566
# RUN  7 , total integrated cost =  39.91976938138184
# RUN  8 , total integrated cost =  39.97091740730469
# RUN  9 , total integrated cost =  39.930016253464544
# RUN  10 , total integrated cost =  39.95698268447978
# RUN  10 , total integrated cost =  39.95698268447978
# Improved over  10  iterations in  0.7588764869997249  seconds by  71.75169536251576  percent.
# --------- 13
# interpolate adjoint :  True True True
# initial cost =  151.81136884638374
# RUN  0 , total integrated cost =  151.81136884638374
# Gradient descend method:  None
# RUN  1 , total integrated cost =  42.79616086189981
# RUN  2 , total integrated cost =  40.72395834007518
# RUN  3 , total integrated cost =  40.519247316692336
# RUN  4 , total integrated cost =  40.449836893469666
# RUN  5 , total integrated cost =  40.33359864386807
# RUN  6 , total integrated cost =  40.37609878608512
# RUN  7 , total integrated cost =  30.253014667437867
# RUN  8 , total integrated cost =  21.910529398505172
# RUN  9 , total integrated cost =  23.954093398004304
# RUN  10 , total integrated cost =  21.881142588085048
# RUN  10 , total integrated cost =  21.881142588085048
# Improved over  10  iterations in  0.798477023000487  seconds by  85.58662453651522  percent.
# --------- 13
# interpolate adjoint :  True True True
# initial cost =  148.66723353160432
# RUN  0 , total integrated cost =  148.66723353160432
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.623099989949785
# RUN  2 , total integrated cost =  6.51255974583997
# RUN  3 , total integrated cost =  5.864170889557822
# RUN  4 , total integrated cost =  5.630277266781219
# RUN  5 , total integrated cost =  5.191676608717798
# RUN  6 , total integrated cost =  6.546927377323454
# RUN  7 , total integrated cost =  5.674146931100645
# RUN  8 , total integrated cost =  7.078296271539321
# RUN  9 , total integrated cost =  6.761012183082589
# RUN  10 , total integrated cost =  6.120211505898983
# RUN  10 , total integrated cost =  6.120211505898983
# Improved over  10  iterations in  0.4542976799993994  seconds by  95.88328150022518  percent.
# --------- 14
# interpolate adjoint :  True True True
# initial cost =  138.99717889776593
# RUN  0 , total integrated cost =  138.99717889776593
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14.509238033529822
# RUN  2 , total integrated cost =  12.073342018492497
# RUN  3 , total integrated cost =  5.8195334414609
# RUN  4 , total integrated cost =  4.99067397613323
# RUN  5 , total integrated cost =  6.459080966045776
# RUN  6 , total integrated cost =  5.611266672265859
# RUN  7 , total integrated cost =  5.941254674874544
# RUN  8 , total integrated cost =  6.475017402513518
# RUN  9 , total integrated cost =  6.281450632943333
# RUN  10 , total integrated cost =  6.287097157296109
# RUN  10 , total integrated cost =  6.287097157296109
# Improved over  10  iterations in  0.5327503849994173  seconds by  95.47681671876208  percent.
# --------- 15
# interpolate adjoint :  True True True
# initial cost =  135.28416490286995
# RUN  0 , total integrated cost =  135.28416490286995
# Gradient descend method:  None
# RUN  1 , total integrated cost =  42.49827384256435
# RUN  2 , total integrated cost =  41.486410106732336
# RUN  3 , total integrated cost =  40.22274583595235
# RUN  4 , total integrated cost =  40.2769853608164
# RUN  5 , total integrated cost =  40.18162622142609
# RUN  6 , total integrated cost =  40.06316522249937
# RUN  7 , total integrated cost =  40.01572282741058
# RUN  8 , total integrated cost =  40.03883894351367
# RUN  9 , total integrated cost =  40.1124845147072
# RUN  10 , total integrated cost =  40.13201610458916
# RUN  10 , total integrated cost =  40.13201610458916
# Improved over  10  iterations in  0.7026984869999069  seconds by  70.33502322063875  percent.
# --------- 15
# interpolate adjoint :  True True True
# initial cost =  146.0657197216875
# RUN  0 , total integrated cost =  146.0657197216875
# Gradient descend method:  None
# RUN  1 , total integrated cost =  42.03024326348987
# RUN  2 , total integrated cost =  40.77189346930833
# RUN  3 , total integrated cost =  40.381438762483235
# RUN  4 , total integrated cost =  40.253695872759494
# RUN  5 , total integrated cost =  40.01880416082393
# RUN  6 , total integrated cost =  40.17575549608979
# RUN  7 , total integrated cost =  40.09126289275921
# RUN  8 , total integrated cost =  40.015849140941356
# RUN  9 , total integrated cost =  40.02223711350466
# RUN  10 , total integrated cost =  40.105010746187695
# RUN  10 , total integrated cost =  40.105010746187695
# Improved over  10  iterations in  0.7322006240001429  seconds by  72.54317383804805  percent.
# --------- 16
# interpolate adjoint :  True True True
# initial cost =  138.6862599184429
# RUN  0 , total integrated cost =  138.6862599184429
# Gradient descend method:  None
# RUN  1 , total integrated cost =  42.75344078191894
# RUN  2 , total integrated cost =  40.59757166436314
# RUN  3 , total integrated cost =  39.66056245856758
# RUN  4 , total integrated cost =  39.407259284030026
# RUN  5 , total integrated cost =  39.15067398347991
# RUN  6 , total integrated cost =  40.25632597613696
# RUN  7 , total integrated cost =  40.29338624123051
# RUN  8 , total integrated cost =  40.34441665025817
# RUN  9 , total integrated cost =  40.21934563655387
# RUN  10 , total integrated cost =  40.18968936883413
# RUN  10 , total integrated cost =  40.18968936883413
# Improved over  10  iterations in  1.0812267549999888  seconds by  71.0211455752946  percent.
# --------- 16
# interpolate adjoint :  True True True
# initial cost =  129.91841959987715
# RUN  0 , total integrated cost =  129.91841959987715
# Gradient descend method:  None
# RUN  1 , total integrated cost =  17.901245331833092
# RUN  2 , total integrated cost =  7.190509061629903
# RUN  3 , total integrated cost =  7.321864668634828
# RUN  4 , total integrated cost =  6.166677496656811
# RUN  5 , total integrated cost =  5.678610640725781
# RUN  6 , total integrated cost =  5.462761495743096
# RUN  7 , total integrated cost =  5.002844747883589
# RUN  8 , total integrated cost =  4.9563101166282415
# RUN  9 , total integrated cost =  5.572584702489699
# RUN  10 , total integrated cost =  5.434373130598292
# RUN  10 , total integrated cost =  5.434373130598292
# Improved over  10  iterations in  0.7632839030002287  seconds by  95.81708802544314  percent.
# --------- 17
# interpolate adjoint :  True True True
# initial cost =  138.13032937956194
# RUN  0 , total integrated cost =  138.13032937956194
# Gradient descend method:  None
# RUN  1 , total integrated cost =  41.82952311216066
# RUN  2 , total integrated cost =  40.96431549906942
# RUN  3 , total integrated cost =  40.41778284281679
# RUN  4 , total integrated cost =  40.09951160429679
# RUN  5 , total integrated cost =  40.26895734559715
# RUN  6 , total integrated cost =  40.125250246115456
# RUN  7 , total integrated cost =  40.14225725134462
# RUN  8 , total integrated cost =  40.192284086908465
# RUN  9 , total integrated cost =  40.13203967869944
# RUN  10 , total integrated cost =  40.131265179038365
# RUN  10 , total integrated cost =  40.131265179038365
# Improved over  10  iterations in  0.6869810360003612  seconds by  70.9468113488939  percent.
# --------- 17
# interpolate adjoint :  True True True
# initial cost =  134.96498313493618
# RUN  0 , total integrated cost =  134.96498313493618
# Gradient descend method:  None
# RUN  1 , total integrated cost =  42.470536249113884
# RUN  2 , total integrated cost =  40.37830428870684
# RUN  3 , total integrated cost =  40.32286825466124
# RUN  4 , total integrated cost =  40.244656116606826
# RUN  5 , total integrated cost =  40.123188498877596
# RUN  6 , total integrated cost =  39.780919757316596
# RUN  7 , total integrated cost =  39.7949425678948
# RUN  8 , total integrated cost =  39.56202373382427
# RUN  9 , total integrated cost =  39.71125661915716
# RUN  10 , total integrated cost =  39.92962331212268
# RUN  10 , total integrated cost =  39.92962331212268
# Improved over  10  iterations in  0.7364094519998616  seconds by  70.41482732435747  percent.
# --------- 17
# interpolate adjoint :  True True True
# initial cost =  144.4938105958826
# RUN  0 , total integrated cost =  144.4938105958826
# Gradient descend method:  None
# RUN  1 , total integrated cost =  10.99725141343627
# RUN  2 , total integrated cost =  7.293781399898566
# RUN  3 , total integrated cost =  6.207835939785918
# RUN  4 , total integrated cost =  6.221502995246589
# RUN  5 , total integrated cost =  6.4117733410321875
# RUN  6 , total integrated cost =  6.226978323569097
# RUN  7 , total integrated cost =  6.213870719364275
# RUN  8 , total integrated cost =  6.0995291527806295
# RUN  9 , total integrated cost =  5.8027488544715835
# RUN  10 , total integrated cost =  5.88168154532206
# RUN  10 , total integrated cost =  5.88168154532206
# Improved over  10  iterations in  0.5098018019998563  seconds by  95.92945779402841  percent.
# --------- 18
# interpolate adjoint :  True True True
# initial cost =  144.56084434924816
# RUN  0 , total integrated cost =  144.56084434924816
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.382739122430891
# RUN  2 , total integrated cost =  5.309734604297947
# RUN  3 , total integrated cost =  4.870958866309006
# RUN  4 , total integrated cost =  5.1260577616398475
# RUN  5 , total integrated cost =  4.90544704790284
# RUN  6 , total integrated cost =  4.736828114438546
# RUN  7 , total integrated cost =  4.7178811457234175
# RUN  8 , total integrated cost =  5.933691206106923
# RUN  9 , total integrated cost =  5.633797657727571
# RUN  10 , total integrated cost =  5.41161531511974
# RUN  10 , total integrated cost =  5.41161531511974
# Improved over  10  iterations in  0.6801884489996155  seconds by  96.25651376105297  percent.
# --------- 19
# interpolate adjoint :  True True True
# initial cost =  141.68573129839368
# RUN  0 , total integrated cost =  141.68573129839368
# Gradient descend method:  None
# RUN  1 , total integrated cost =  16.112098840687185
# RUN  2 , total integrated cost =  12.446686514814825
# RUN  3 , total integrated cost =  8.194085217499593
# RUN  4 , total integrated cost =  5.449185902852312
# RUN  5 , total integrated cost =  7.623727546671829
# RUN  6 , total integrated cost =  6.924663079085212
# RUN  7 , total integrated cost =  7.444735676830053
# RUN  8 , total integrated cost =  7.353794296647488
# RUN  9 , total integrated cost =  6.210721664937684
# RUN  10 , total integrated cost =  6.576953522685831
# RUN  10 , total integrated cost =  6.576953522685831
# Improved over  10  iterations in  0.5073891920001188  seconds by  95.35806925481113  percent.
# --------- 20
# interpolate adjoint :  True True True
# initial cost =  117.10126370891832
# RUN  0 , total integrated cost =  117.10126370891832
# Gradient descend method:  None
# RUN  1 , total integrated cost =  41.65108142032052
# RUN  2 , total integrated cost =  40.53822929421536
# RUN  3 , total integrated cost =  40.158384423055324
# RUN  4 , total integrated cost =  40.079128411326565
# RUN  5 , total integrated cost =  39.993203496086075
# RUN  6 , total integrated cost =  40.075779933517026
# RUN  7 , total integrated cost =  40.13386325947786
# RUN  8 , total integrated cost =  40.09141435045902
# RUN  9 , total integrated cost =  40.04135691003945
# RUN  10 , total integrated cost =  40.032124680505106
# RUN  10 , total integrated cost =  40.032124680505106
# Improved over  10  iterations in  0.39996597899971675  seconds by  65.81409678036096  percent.
# --------- 20
# interpolate adjoint :  True True True
# initial cost =  136.811648788037
# RUN  0 , total integrated cost =  136.811648788037
# Gradient descend method:  None
# RUN  1 , total integrated cost =  42.12797826885732
# RUN  2 , total integrated cost =  40.247996445115405
# RUN  3 , total integrated cost =  40.571251118230116
# RUN  4 , total integrated cost =  40.353490920977585
# RUN  5 , total integrated cost =  39.696471588114925
# RUN  6 , total integrated cost =  40.34152485937779
# RUN  7 , total integrated cost =  40.162006907297624
# RUN  8 , total integrated cost =  39.94068984566626
# RUN  9 , total integrated cost =  39.85036896219787
# RUN  10 , total integrated cost =  39.86800184770052
# RUN  10 , total integrated cost =  39.86800184770052
# Improved over  10  iterations in  0.6009148559996902  seconds by  70.85920519131508  percent.
# --------- 20
# interpolate adjoint :  True True True
# initial cost =  128.10318401698504
# RUN  0 , total integrated cost =  128.10318401698504
# Gradient descend method:  None
# RUN  1 , total integrated cost =  42.60002466377746
# RUN  2 , total integrated cost =  40.641142064854996
# RUN  3 , total integrated cost =  40.37480927640646
# RUN  4 , total integrated cost =  39.9940628704205
# RUN  5 , total integrated cost =  39.77215054790667
# RUN  6 , total integrated cost =  39.71219185432988
# RUN  7 , total integrated cost =  40.024330492011366
# RUN  8 , total integrated cost =  40.05512596788338
# RUN  9 , total integrated cost =  39.95150341497746
# RUN  10 , total integrated cost =  39.89150294614311
# RUN  10 , total integrated cost =  39.89150294614311
# Improved over  10  iterations in  0.3860254900000655  seconds by  68.8598661678433  percent.
# --------- 20
# interpolate adjoint :  True True True
# initial cost =  130.67649964745087
# RUN  0 , total integrated cost =  130.67649964745087
# Gradient descend method:  None
# RUN  1 , total integrated cost =  41.80658291828915
# RUN  2 , total integrated cost =  41.0994144467097
# RUN  3 , total integrated cost =  40.247899689892435
# RUN  4 , total integrated cost =  39.91314792517493
# RUN  5 , total integrated cost =  39.87088811931066
# RUN  6 , total integrated cost =  39.84310978863972
# RUN  7 , total integrated cost =  39.94993581310331
# RUN  8 , total integrated cost =  39.865861628103175
# RUN  9 , total integrated cost =  40.01266435664195
# RUN  10 , total integrated cost =  39.96786576881365
# RUN  10 , total integrated cost =  39.96786576881365
# Improved over  10  iterations in  0.5619597220002106  seconds by  69.41464924707806  percent.
# --------- 21
# interpolate adjoint :  True True True
# initial cost =  138.74665832400458
# RUN  0 , total integrated cost =  138.74665832400458
# Gradient descend method:  None
# RUN  1 , total integrated cost =  19.775466117532126
# RUN  2 , total integrated cost =  6.534988945353774
# RUN  3 , total integrated cost =  7.398355493705385
# RUN  4 , total integrated cost =  5.711360174205413
# RUN  5 , total integrated cost =  5.326195303725148
# RUN  6 , total integrated cost =  5.876371533926722
# RUN  7 , total integrated cost =  6.333081356695953
# RUN  8 , total integrated cost =  6.01329984353502
# RUN  9 , total integrated cost =  6.110784028506378
# RUN  10 , total integrated cost =  5.9153029584210595
# RUN  10 , total integrated cost =  5.9153029584210595
# Improved over  10  iterations in  0.49688046800019947  seconds by  95.73661590853777  percent.
# --------- 22
# interpolate adjoint :  True True True
# initial cost =  122.48949316137666
# RUN  0 , total integrated cost =  122.48949316137666
# Gradient descend method:  None
# RUN  1 , total integrated cost =  41.09683473392335
# RUN  2 , total integrated cost =  41.076848087336344
# RUN  3 , total integrated cost =  40.30947185823905
# RUN  4 , total integrated cost =  40.00976835166911
# RUN  5 , total integrated cost =  39.94265558850915
# RUN  6 , total integrated cost =  40.050477074174516
# RUN  7 , total integrated cost =  40.13652202474874
# RUN  8 , total integrated cost =  40.18563822278347
# RUN  9 , total integrated cost =  40.07750915970347
# RUN  10 , total integrated cost =  39.99457884147628
# RUN  10 , total integrated cost =  39.99457884147628
# Improved over  10  iterations in  0.4343370939996021  seconds by  67.34856369371659  percent.
# --------- 23
# interpolate adjoint :  True True True
# initial cost =  121.68342502414038
# RUN  0 , total integrated cost =  121.68342502414038
# Gradient descend method:  None
# RUN  1 , total integrated cost =  41.50827327942123
# RUN  2 , total integrated cost =  40.50167978142159
# RUN  3 , total integrated cost =  40.23602961967608
# RUN  4 , total integrated cost =  40.050475498958626
# RUN  5 , total integrated cost =  40.10569877627105
# RUN  6 , total integrated cost =  39.62652799580715
# RUN  7 , total integrated cost =  39.58999034837848
# RUN  8 , total integrated cost =  39.693056594702675
# RUN  9 , total integrated cost =  39.888625946366126
# RUN  10 , total integrated cost =  39.679543530186585
# RUN  10 , total integrated cost =  39.679543530186585
# Improved over  10  iterations in  0.41314649600008124  seconds by  67.39116808857517  percent.
# --------- 23
# interpolate adjoint :  True True True
# initial cost =  143.69682374447632
# RUN  0 , total integrated cost =  143.69682374447632
# Gradient descend method:  None
# RUN  1 , total integrated cost =  40.98130748768013
# RUN  2 , total integrated cost =  40.563159646785934
# RUN  3 , total integrated cost =  40.23359542929429
# RUN  4 , total integrated cost =  40.05910069331054
# RUN  5 , total integrated cost =  39.97858833724378
# RUN  6 , total integrated cost =  40.11043741182557
# RUN  7 , total integrated cost =  39.94075688247787
# RUN  8 , total integrated cost =  40.1141462016933
# RUN  9 , total integrated cost =  40.10294014857941
# RUN  10 , total integrated cost =  40.1811160492755
# RUN  10 , total integrated cost =  40.1811160492755
# Improved over  10  iterations in  0.37968627999998716  seconds by  72.0375753602417  percent.
# --------- 23
# interpolate adjoint :  True True True
# initial cost =  141.36292852564407
# RUN  0 , total integrated cost =  141.36292852564407
# Gradient descend method:  None
# RUN  1 , total integrated cost =  9.817334086128959
# RUN  2 , total integrated cost =  6.886231345030115
# RUN  3 , total integrated cost =  6.25513405874132
# RUN  4 , total integrated cost =  6.606380290113088
# RUN  5 , total integrated cost =  5.695726788649632
# RUN  6 , total integrated cost =  5.593542629746637
# RUN  7 , total integrated cost =  5.963431714629719
# RUN  8 , total integrated cost =  5.665367308173694
# RUN  9 , total integrated cost =  5.250299127840846
# RUN  10 , total integrated cost =  5.545737064222157
# RUN  10 , total integrated cost =  5.545737064222157
# Improved over  10  iterations in  0.5749212900000202  seconds by  96.07695092195537  percent.
# --------- 24
# interpolate adjoint :  True True True
# initial cost =  153.7639735812318
# RUN  0 , total integrated cost =  153.7639735812318
# Gradient descend method:  None
# RUN  1 , total integrated cost =  19.337323983759514
# RUN  2 , total integrated cost =  6.844447379242212
# RUN  3 , total integrated cost =  6.338964126395178
# RUN  4 , total integrated cost =  6.172206973124845
# RUN  5 , total integrated cost =  6.054341321227255
# RUN  6 , total integrated cost =  6.0720747772661525
# RUN  7 , total integrated cost =  6.038256314935363
# RUN  8 , total integrated cost =  6.453420274109609
# RUN  9 , total integrated cost =  5.765343110098392
# RUN  10 , total integrated cost =  6.981428691629354
# RUN  10 , total integrated cost =  6.981428691629354
# Improved over  10  iterations in  0.8037615630000801  seconds by  95.4596460217379  percent.
# --------- 25
# interpolate adjoint :  True True True
# initial cost =  140.32197451366585
# RUN  0 , total integrated cost =  140.32197451366585
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12.258515824305
# RUN  2 , total integrated cost =  7.201204779366009
# RUN  3 , total integrated cost =  7.719781069078623
# RUN  4 , total integrated cost =  6.7587340740611515
# RUN  5 , total integrated cost =  7.5727964194339705
# RUN  6 , total integrated cost =  6.149951063725303
# RUN  7 , total integrated cost =  6.239820653396371
# RUN  8 , total integrated cost =  6.128740441740998
# RUN  9 , total integrated cost =  6.1258618421187
# RUN  10 , total integrated cost =  5.792385706142863
# RUN  10 , total integrated cost =  5.792385706142863
# Improved over  10  iterations in  0.6785532479998437  seconds by  95.87207511423755  percent.
# --------- 26
# interpolate adjoint :  True True True
# initial cost =  143.15101426686044
# RUN  0 , total integrated cost =  143.15101426686044
# Gradient descend method:  None
# RUN  1 , total integrated cost =  25.521102076123803

# %%
aln.params.duration = dur
init_control = aln.getZeroControl()           
init_control[:,:,:] = control_list[0][:,:,100:-100]
T = int(1 + dur/aln.params.dt)
dt = aln.params.dt

target_ = target[i].copy()
target_[0,0,:int(trans_time * dur / aln.params.dt)] = -1000
target_[0,1,:int(trans_time * dur / aln.params.dt)] = -1000

cost_final = np.zeros(( noise_realizations_final ))

for n_ in range(noise_realizations_final):

    setinit(initVars[i], aln)
    state_ = fo.updateState(aln, init_control)
    cost_final[n_] += cost.numba_cost_precision_int(1,T,dt,w_p[i],state_, target_, list(prec_vars) )
    cost_final[n_] += cost.numba_cost_sparsity_int(1, 6, T, w_s, dt, init_control)

mean_cost[0].append(np.mean(cost_final))
print('mean = ', mean_cost[0])

# %%
for k_ in range(19):
    print('-------------------------------------------------------------------', k_)

    aln.params.duration = dur

    n_ = 0
    init_control = aln.getZeroControl()           
    init_control[:,:,:] = control_list[0][:,:,100:-100]

    while n_  < noise_realizations:
        print("---------", n_)
        setinit(initVars[i], aln)

        bestControl[i], bestState[i], cost_[i], runtime[i], grad[i], phi[i], costnode[i], total_cost_mean_std = aln.A1(
            init_control, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it,
            tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
            t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
            control_variables_ = [0,1], prec_variables_ = prec_vars, transition_time_ = trans_time,
            noise_real=0, init_params = initVars[i])

        if cost_[i][min_it] == 0:
            continue

        max_jump = 0.
        for v_ in range(bestControl[i].shape[1]):
            for t_ in range(1, bestControl[i].shape[2]):
                diff = np.abs(bestControl[i][0,v_,t_] - bestControl[i][0,v_,t_-1])
                if  diff > max_jump:
                    max_jump = diff

        if max_jump > 0.5:
            continue

        m1_control_list.append(bestControl[i])
        control_list[0] += bestControl[i]
        m1_cost_list.append(cost_[i])
        cost_list[0] += cost_[i]

        n_ += 1

    control_list[0] /= noise_realizations


    aln.params.duration = dur
    init_control = aln.getZeroControl()           
    init_control[:,:,:] = control_list[0][:,:,100:-100]

    cost_final = np.zeros(( noise_realizations_final ))

    for n_ in range(noise_realizations_final):

        setinit(initVars[i], aln)
        state_ = fo.updateState(aln, init_control)
        cost_final[n_] += cost.numba_cost_precision_int(1,T,dt,w_p[i],state_, target_, list(prec_vars) )
        cost_final[n_] += cost.numba_cost_sparsity_int(1, 6, T, w_s, dt, init_control)

    mean_cost[0].append(np.mean(cost_final))
    
print('mean = ', mean_cost[0])

# %%
aln.params.duration = dur
zero_init = aln.getZeroControl()

mean_cost[1] = []
cost.setParams(w_p[i], w_e, w_s)

##### zero control as input for uncontrolled cost
setinit(initVars[i], aln)

bestControl[i], bestState[i], cost_[i], runtime[i], grad[i], phi[i], costnode[i], total_cost_mean_std = aln.A1(
    zero_init, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it,
    tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
    t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
    control_variables_ = [0,1], prec_variables_ = prec_vars, transition_time_ = trans_time,
    noise_real=noise_realizations, init_params = initVars[i], method='M2')
    
control_list[1] = bestControl[i]
cost_list[1] = cost_[i]

# %%
aln.params.duration = dur
init_control = aln.getZeroControl()           
init_control[:,:,:] = control_list[1][:,:,100:-100]

cost_final = np.zeros(( noise_realizations_final ))

for n_ in range(noise_realizations_final):

    setinit(initVars[i], aln)
    state_ = fo.updateState(aln, init_control)
    cost_final[n_] += cost.numba_cost_precision_int(1,T,dt,w_p[i],state_, target_, list(prec_vars) )
    cost_final[n_] += cost.numba_cost_sparsity_int(1, 6, T, w_s, dt, init_control)

mean_cost[1].append(np.mean(cost_final))
print('mean = ', mean_cost[1])

# %%
for k_ in range(19):
    print('---------------------------------------------------------', k_)
    setinit(initVars[i], aln)
    
    init_control = aln.getZeroControl()           
    init_control[:,:,:] = control_list[1][:,:,100:-100]

    bestControl[i], bestState[i], cost_[i], runtime[i], grad[i], phi[i], costnode[i], total_cost_mean_std = aln.A1(
        init_control, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it,
        tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
        t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
        control_variables_ = [0,1], prec_variables_ = prec_vars, transition_time_ = trans_time,
        noise_real=noise_realizations, init_params = initVars[i], method='M2')

    control_list[1] = bestControl[i]

    aln.params.duration = dur
    init_control = aln.getZeroControl()           
    init_control[:,:,:] = control_list[1][:,:,100:-100]

    cost_final = np.zeros(( noise_realizations_final ))

    for n_ in range(noise_realizations_final):

        setinit(initVars[i], aln)
        state_ = fo.updateState(aln, init_control)
        cost_final[n_] += cost.numba_cost_precision_int(1,T,dt,w_p[i],state_, target_, list(prec_vars) )
        cost_final[n_] += cost.numba_cost_sparsity_int(1, 6, T, w_s, dt, init_control)

    mean_cost[1].append(np.mean(cost_final))

print('mean = ', mean_cost[1])

# %%
aln.params.duration = dur
zero_init = aln.getZeroControl()

##### zero control as input for uncontrolled cost
setinit(initVars[i], aln)
mean_cost[2] = []

bestControl[i], bestState[i], cost_[i], runtime[i], grad[i], phi[i], costnode[i], total_cost_mean_std = aln.A1(
    zero_init, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it,
    tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
    t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
    control_variables_ = [0,1], prec_variables_ = prec_vars, transition_time_ = trans_time,
    noise_real=noise_realizations, init_params = initVars[i], method='M3')
    
control_list[2] = bestControl[i]
cost_list[2] = cost_[i]

# %%
aln.params.duration = dur
init_control = aln.getZeroControl()           
init_control[:,:,:] = control_list[2][:,:,100:-100]

cost_final = np.zeros(( noise_realizations_final ))

for n_ in range(noise_realizations_final):

    setinit(initVars[i], aln)
    state_ = fo.updateState(aln, init_control)
    cost_final[n_] += cost.numba_cost_precision_int(1,T,dt,w_p[i],state_, target_, list(prec_vars) )
    cost_final[n_] += cost.numba_cost_sparsity_int(1, 6, T, w_s, dt, init_control)

mean_cost[2].append(np.mean(cost_final))
print('mean = ', mean_cost[2])

# %%
for k_ in range(19):
    print('---------------------------------------------------------', k_)
    setinit(initVars[i], aln)
    
    init_control = aln.getZeroControl()           
    init_control[:,:,:] = control_list[2][:,:,100:-100]

    bestControl[i], bestState[i], cost_[i], runtime[i], grad[i], phi[i], costnode[i], total_cost_mean_std = aln.A1(
        init_control, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it,
        tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
        t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
        control_variables_ = [0,1], prec_variables_ = prec_vars, transition_time_ = trans_time,
        noise_real=noise_realizations, init_params = initVars[i], method='M3')

    control_list[2] = bestControl[i]

    aln.params.duration = dur
    init_control = aln.getZeroControl()           
    init_control[:,:,:] = control_list[2][:,:,100:-100]

    cost_final = np.zeros(( noise_realizations_final ))

    for n_ in range(noise_realizations_final):

        setinit(initVars[i], aln)
        state_ = fo.updateState(aln, init_control)
        cost_final[n_] += cost.numba_cost_precision_int(1,T,dt,w_p[i],state_, target_, list(prec_vars) )
        cost_final[n_] += cost.numba_cost_sparsity_int(1, 6, T, w_s, dt, init_control)

    mean_cost[2].append(np.mean(cost_final))

print('mean = ', mean_cost[2])

# %%
aln.params.duration = dur
zero_init = aln.getZeroControl()

mean_cost[3] = []

##### zero control as input for uncontrolled cost
setinit(initVars[i], aln)

bestControl[i], bestState[i], cost_[i], runtime[i], grad[i], phi[i], costnode[i], total_cost_mean_std = aln.A1(
    zero_init, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it,
    tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
    t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
    control_variables_ = [0,1], prec_variables_ = prec_vars, transition_time_ = trans_time,
    noise_real=noise_realizations, init_params = initVars[i], method='M4')

control_list[3] = bestControl[i]
cost_list[3] = cost_[i]

# %%
aln.params.duration = dur
init_control = aln.getZeroControl()           
init_control[:,:,:] = control_list[3][:,:,100:-100]

cost_final = np.zeros(( noise_realizations_final ))

for n_ in range(noise_realizations_final):

    setinit(initVars[i], aln)
    state_ = fo.updateState(aln, init_control)
    cost_final[n_] += cost.numba_cost_precision_int(1,T,dt,w_p[i],state_, target_, list(prec_vars) )
    cost_final[n_] += cost.numba_cost_sparsity_int(1, 6, T, w_s, dt, init_control)

mean_cost[3].append(np.mean(cost_final))
print('mean = ', mean_cost[3])

# %%
for k_ in range(19):
    print('---------------------------------------------------------', k_)
    setinit(initVars[i], aln)
    
    init_control = aln.getZeroControl()           
    init_control[:,:,:] = control_list[3][:,:,100:-100]

    bestControl[i], bestState[i], cost_[i], runtime[i], grad[i], phi[i], costnode[i], total_cost_mean_std = aln.A1(
        init_control, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it,
        tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
        t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
        control_variables_ = [0,1], prec_variables_ = prec_vars, transition_time_ = trans_time,
        noise_real=noise_realizations, init_params = initVars[i], method='M4')

    control_list[3] = bestControl[i]

    aln.params.duration = dur
    init_control = aln.getZeroControl()           
    init_control[:,:,:] = control_list[3][:,:,100:-100]

    cost_final = np.zeros(( noise_realizations_final ))

    for n_ in range(noise_realizations_final):

        setinit(initVars[i], aln)
        state_ = fo.updateState(aln, init_control)
        cost_final[n_] += cost.numba_cost_precision_int(1,T,dt,w_p[i],state_, target_, list(prec_vars) )
        cost_final[n_] += cost.numba_cost_sparsity_int(1, 6, T, w_s, dt, init_control)

    mean_cost[3].append(np.mean(cost_final))

print('mean = ', mean_cost[3])

# %%
color = ['red', 'green', 'blue', 'orange']
l_ = ['M1', 'M2', 'M3', 'M4']

for k in range(4):
    x = np.arange(0,len(mean_cost[k]), 1)
    y = mean_cost[k]
    plt.plot( x,y, label=l_[k] + ', corr coeff = {:.2f}'.format(np.corrcoef(x[2:],y[2:])[0,1]),
             linestyle='', marker='x' )
    print('------')
    for k_ in np.arange(0,len(mean_cost[k])-2,1):
        print(np.corrcoef(x[k_:],y[k_:])[0,1])
    
plt.legend()
plt.title('N = {}'.format(noise_realizations))
plt.savefig('method_compare_' + str(noise_realizations) + '.png')
plt.ylim(11,13)
plt.show()
