# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import sys
import pickle
import matplotlib
import ipyparams

path = os.getcwd().split(os.sep + 'GUI')[0]
if path not in sys.path:
    print("not here")
    sys.path.append(path)

from neurolib.models.aln import ALNModel
from neurolib.utils import plotFunctions as plotFunc
from neurolib.utils import func_optimize as fo
from neurolib.utils import costFunctions as cost
import neurolib.dashboard.functions as functions
import neurolib.dashboard.data as data
import neurolib.dashboard.layout as layout
    
# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2 

#path = os.path.join(os.getcwd(), "plots")

cmap_ = layout.getcolormap()
darkgrey, midgrey, lightgrey, color_bi_updown, color_LC, color_bi_uposc = layout.getcolors_rgba()
exc_red = cmap_(3)
inh_blue=cmap_(0)
green = cmap_(2)
# Out:
# not here

# %%
aln = ALNModel()
N = aln.params.N

data.set_parameters(aln)

state_vars = aln.state_vars
init_vars = aln.init_vars

##############################################################
def setinit(init_vars_, model):
    state_vars = model.state_vars
    init_vars = model.init_vars
    for iv in range(len(init_vars)):
        for sv in range(len(state_vars)):
            if state_vars[sv] in init_vars[iv]:
                #print("set init vars ", )
                if model.params[init_vars[iv]].ndim == 2:
                    model.params[init_vars[iv]][0,:] = init_vars_[sv]
                else:
                    model.params[init_vars[iv]][0] = init_vars_[sv]
                    
##############################################################               
def setmaxmincontrol(max_c_c, min_c_c, max_c_r, min_c_r):
    import numpy as np
    
    max_cntrl = np.zeros(( 6 ))
    min_cntrl = np.zeros(( 6 ))
    
    max_cntrl[0] = max_c_c
    min_cntrl[0] = min_c_c
    max_cntrl[1] = max_c_c
    min_cntrl[1] = min_c_c
    max_cntrl[2] = max_c_r
    min_cntrl[2] = min_c_r
    max_cntrl[3] = max_c_r
    min_cntrl[3] = min_c_r
    max_cntrl[4] = max_c_r
    min_cntrl[4] = min_c_r
    max_cntrl[5] = max_c_r
    min_cntrl[5] = min_c_r
            
    return max_cntrl, min_cntrl

# %%
savepath = (os.getcwd().split('neurolib')[0] + 'Talks_Conf_Workshops_Schools' + os.sep + '22' + os.sep + 'FRANCE22' + 
     os.sep + 'FENS' + os.sep + 'poster' + os.sep + 'print' + os.sep + 'images')

exc = 0.4
inh = 0.322

# %%
dur_pre = 10
dur_post = 10
dur = 500.
dt = aln.params.dt
T = int(1 + dur / dt)

max_it = 10
init_it = 10
prec_vars = [0,1]
trans_time = 0.7
repeat = 20

n_pre = int(np.around(dur_pre/aln.params.dt + 1.,1))
n_post = int(np.around(dur_post/aln.params.dt + 1.,1))

tol = 1e-32
start_step = 10.
c_scheme = np.zeros(( 1,1 ))
c_scheme[0,0] = 1.
u_mat = np.identity(1)
u_scheme = np.array([[1.]])

maxC = [5., -5., 0.18, 0.]
n_dur = int(np.around(dur/aln.params.dt + 1.,1))
max_cntrl, min_cntrl = setmaxmincontrol(maxC[0], maxC[1], maxC[2], maxC[3])

nb = ipyparams.notebook_name
print('nb = ', nb)

case = '3'
max_I = [3., -3.]

read_file = '..' + os.sep + 'data_2' + os.sep + 'high_osc' + os.sep  + '3_E.pickle'
# Out:
# nb =

# %%
if os.path.isfile(read_file) :
    print("file found")
    
    with open(read_file,'rb') as f:
        load_array = pickle.load(f)

    bestControl = load_array
    
init_control_noisefree = bestControl[0].copy()
# Out:
# file found

# %%
cost_final_mean = np.zeros(( 3,3 ))
control_ = [ [None] * 3, [None] * 3, [None] * 3 ]
cost_ = [ [None] * 3, [None] * 3, [None] * 3 ]
cost_final = [ [None] * 3, [None] * 3, [None] * 3 ]

stable_state = np.zeros(( 3, 2,2,2, 2))

# %%
# get init vars without noise
aln = ALNModel()
data.set_parameters(aln)
aln.params.duration = 3000.

# initial without noise
control0 = aln.getZeroControl()
control0[0,0,:500] = 5.

aln.params.ext_exc_current = exc * 5.
aln.params.ext_inh_current = inh * 5.

aln.run(control=control0)

init_state_vars = np.zeros(( len(state_vars) ))
for j in range(len(state_vars)):
    if aln.state[state_vars[j]].size == 1:
        init_state_vars[j] = aln.state[state_vars[j]][0]
    else:
        init_state_vars[j] = aln.state[state_vars[j]][0,-1]

initVars = init_state_vars

# final state without noise
control0 = aln.getZeroControl()
control0[0,0,:500] = 5.
if case in ['3', '4']:
    control0[0,0,:500] = - 5.

aln.params.duration = 3000.
aln.run(control=control0)
stable_state[0,0,1,0,0] = aln.rates_exc[0,-1]
stable_state[0,0,1,1,0] = aln.rates_inh[0,-1]

print('exc osc ', stable_state[0,0,1,0,0])
print('inh psc ', stable_state[0,0,1,1,0])

aln.params.duration = dur
target = aln.getZeroTarget()
target[:,0,:] = aln.rates_exc[0,-5001:]
target[:,1,:] = aln.rates_inh[0,-5001:]
# Out:
# exc osc  0.6637229150716093
# inh psc  9.61938307039784

# %%
# get target states with noise
sigma_ou_array = [0.01, 0.02]
noise_realizations_array = [0,20,100]
noise_realizations_final = 10000

i_sigma = 0
i_noise = 1
i = 50

int_t_pen = np.around( (1. - trans_time)*dur/aln.params.dt, 1).astype(int)

noise_realizations = noise_realizations_array[i_noise]

# %%
for i_sigma in range(len(sigma_ou_array)):
    
    sigma_ou = sigma_ou_array[i_sigma]
    aln.params.sigma_ou = sigma_ou
    
    aln.params.duration = dur
    control0 = aln.getZeroControl()
    control0[0,0,:500] = 5.

    target_rates_e = []
    target_rates_i = []

    stateswitchcount = 0

    for j in range(noise_realizations_final):
        aln.params.duration = dur
        setinit(initVars, aln)
        aln.run(control=control0)
        #plt.plot(aln.t, aln.rates_exc[0,:])
        if np.amin(aln.rates_exc[0,1000:]) < 1.:
            #print("fell in down state, repeat")
            j -= 1
            stateswitchcount += 1
            if stateswitchcount > 0.1 * noise_realizations_final:
                break
            continue
        target_rates_e = aln.rates_exc[0,-int_t_pen:]
        target_rates_i = aln.rates_inh[0,-int_t_pen:]
    
    #print(stateswitchcount)
    #plt.show()

    stable_state[i_sigma,1,1,0,0] = np.mean(target_rates_e)
    stable_state[i_sigma,1,1,1,0] = np.mean(target_rates_i)
    stable_state[i_sigma,1,1,0,1] = np.std(target_rates_e)
    stable_state[i_sigma,1,1,1,1] = np.std(target_rates_i)


    aln.params.duration = 300.
    control0 = aln.getZeroControl()
    control0[0,0,:500] = -5.

    target_rates_e = []
    target_rates_i = []

    stateswitchcount = 0

    for j in range(noise_realizations_final):
        aln.params.duration = 300.
        aln.run(control=control0)
        #plt.plot(aln.t, aln.rates_exc[0,:])
        if np.amax(aln.rates_exc[0,1000:]) > 20.:
            #print("fell in up state, repeat")
            j -= 1
            stateswitchcount += 1
            if stateswitchcount > 0.1 * noise_realizations_final:
                break
            continue
        target_rates_e.append(aln.rates_exc[0,1500:])
        target_rates_i.append(aln.rates_inh[0,1500:])
        
    #print(stateswitchcount)
    #plt.show()

    stable_state[i_sigma,1,0,0,0] = np.mean(target_rates_e)
    stable_state[i_sigma,1,0,1,0] = np.mean(target_rates_i)
    stable_state[i_sigma,1,0,0,1] = np.std(target_rates_e)
    stable_state[i_sigma,1,0,1,1] = np.std(target_rates_i)
    
    print(i_sigma, 'st dev osc ', stable_state[i_sigma,1,0,0,1] )

# %%
aln.params.sigma_ou = sigma_ou

w_p = 1. / ( ( stable_state[i_sigma,1,0,0,1] + stable_state[i_sigma,1,0,1,1] ) * (1. - trans_time) * dur )
w_e = 0.
w_s = 1.

aln.params.duration = dur
zero_init = aln.getZeroControl()

# %%
max_it = 15
init_it = 5
min_it = 12
i = 50
    
cost.setParams(w_p, w_e, w_s)

for i_sigma in range(len(sigma_ou_array)):
    for i_noise in range(len(noise_realizations_array)):
        
        if i_noise in [0,2]:
            continue
            
        if i_sigma in []:
            continue

        noise_realizations = noise_realizations_array[i_noise]
        sigma_ou = sigma_ou_array[i_sigma]
        aln.params.sigma_ou = sigma_ou
        
        aln.params.duration = dur
        
        n_ = 0
        control_sum = np.zeros(( init_control_noisefree[:,:,:].shape ))
        
        print(noise_realizations)
        
        if i_noise != 0.:
            while n_  < noise_realizations:
                
                print('--------', n_)

                setinit(initVars, aln)

                bestControl, bestState, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                    zero_init, target, c_scheme, u_mat, u_scheme, max_iteration_ = init_it,
                    tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                    t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                    control_variables_ = [0], prec_variables_ = prec_vars, transition_time_ = trans_time,
                    noise_real=0, init_params = initVars)

                max_jump = 0.
                for v_ in range(bestControl.shape[1]):
                    for t_ in range(1, bestControl.shape[2]):
                        diff = np.abs(bestControl[0,v_,t_] - bestControl[0,v_,t_-1])
                        if  diff > max_jump:
                            max_jump = diff

                if max_jump > 0.5:
                    continue

                control_init = bestControl[:,:,100:-100].copy()
                setinit(initVars, aln)
                aln.params.duration = dur

                bestControl, bestState, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                    control_init, target, c_scheme, u_mat, u_scheme, max_iteration_ = max_it,
                    tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                    t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                    control_variables_ = [0,1], prec_variables_ = prec_vars, transition_time_ = trans_time,
                    noise_real=0, init_params = initVars)
                
                if c_[min_it] == 0:
                    continue

                max_jump = 0.
                for v_ in range(bestControl.shape[1]):
                    for t_ in range(1, bestControl.shape[2]):
                        diff = np.abs(bestControl[0,v_,t_] - bestControl[0,v_,t_-1])
                        if  diff > max_jump:
                            max_jump = diff

                if max_jump > 0.5:
                    continue
                    
                control_sum += bestControl
            
                n_ += 1
    

            control_[i_sigma][i_noise] = control_sum / noise_realizations
        
        else:
            control_[i_sigma][i_noise] = factor[i_sigma] * init_control_noisefree
        
        aln.params.duration = dur

        init_control = aln.getZeroControl()           
        init_control[:,:,:] = control_[i_sigma][i_noise][:,:,100:-100]
        T = int(1 + dur/aln.params.dt)
        dt = aln.params.dt

        target_ = target.copy()
        target_[0,0,:int(trans_time * dur / aln.params.dt)] = -1000
        target_[0,1,:int(trans_time * dur / aln.params.dt)] = -1000

        cost_final = np.zeros(( noise_realizations_final ))

        for n_ in range(noise_realizations_final):
            state_ = fo.updateState(aln, init_control)
            cost_final[n_] += cost.numba_cost_precision_int(1,T,dt,w_p,state_, target_, list(prec_vars) )
            cost_final[n_] += cost.numba_cost_sparsity_int(1, 6, T, w_s, dt, init_control)

        cost_final_mean[i_sigma, i_noise] = np.mean(cost_final)
        print('mean = ', cost_final_mean[i_sigma, i_noise])
# Out:
# set cost params:  0.0008724012800008719 0.0 1.0
# 20
# -------- 0
# interpolate adjoint :  True True True
# initial cost =  217.50520432985414
# RUN  0 , total integrated cost =  217.50520432985414
# Gradient descend method:  None
# RUN  1 , total integrated cost =  15.093822378453819
# RUN  2 , total integrated cost =  8.855927235605428
# RUN  3 , total integrated cost =  6.193813773962585
# RUN  4 , total integrated cost =  5.096714924333799
# RUN  5 , total integrated cost =  4.528129692708653
# RUN  5 , total integrated cost =  4.528129692708653
# Improved over  5  iterations in  0.25789582199649885  seconds by  97.91815110509191  percent.
# interpolate adjoint :  True True True
# initial cost =  4.679806917931823
# RUN  0 , total integrated cost =  4.679806917931823
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.406028320566003
# RUN  2 , total integrated cost =  4.2144332282901145
# RUN  3 , total integrated cost =  4.179847073257078
# RUN  4 , total integrated cost =  4.111444998248992
# RUN  5 , total integrated cost =  4.059689627416424
# RUN  6 , total integrated cost =  3.9406420317732187
# RUN  7 , total integrated cost =  3.9339719379707216
# RUN  8 , total integrated cost =  3.710393726693261
# RUN  9 , total integrated cost =  3.3966878948506105
# RUN  10 , total integrated cost =  3.380532176299429
# RUN  11 , total integrated cost =  3.3009488213095746
# RUN  12 , total integrated cost =  3.276710486484577
# RUN  13 , total integrated cost =  3.2519201262447046
# RUN  14 , total integrated cost =  3.1168845170138626
# RUN  15 , total integrated cost =  2.992764425276103
# RUN  15 , total integrated cost =  2.992764425276103
# Improved over  15  iterations in  1.2753342979995068  seconds by  36.04940379466095  percent.
# -------- 1
# interpolate adjoint :  True True True
# initial cost =  219.24891328058732
# RUN  0 , total integrated cost =  219.24891328058732
# Gradient descend method:  None
# RUN  1 , total integrated cost =  13.631647899048348
# RUN  2 , total integrated cost =  9.788644052490731
# RUN  3 , total integrated cost =  7.774979112789156
# RUN  4 , total integrated cost =  4.1617288436146715
# RUN  5 , total integrated cost =  4.148563329741934
# RUN  5 , total integrated cost =  4.148563329741934
# Improved over  5  iterations in  0.2613053680106532  seconds by  98.10782946758202  percent.
# interpolate adjoint :  True True True
# initial cost =  4.141194031568881
# RUN  0 , total integrated cost =  4.141194031568881
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.04104630250895
# RUN  2 , total integrated cost =  3.6062739649569657
# RUN  3 , total integrated cost =  3.5579327419295925
# RUN  4 , total integrated cost =  3.5266430328866027
# RUN  5 , total integrated cost =  3.4877418430714684
# RUN  6 , total integrated cost =  3.4778643428159164
# RUN  7 , total integrated cost =  3.4937911406459636
# RUN  8 , total integrated cost =  3.5725487475193525
# RUN  9 , total integrated cost =  3.420818618478722
# RUN  10 , total integrated cost =  3.4319645647673
# RUN  11 , total integrated cost =  3.375959290741106
# RUN  12 , total integrated cost =  3.394716848096186
# RUN  13 , total integrated cost =  3.4467945374489712
# RUN  14 , total integrated cost =  3.351074448512254
# RUN  15 , total integrated cost =  3.440408021010091
# RUN  15 , total integrated cost =  3.440408021010091
# Improved over  15  iterations in  1.619380710995756  seconds by  16.922317699112952  percent.
# -------- 2
# interpolate adjoint :  True True True
# initial cost =  218.30906958636368
# RUN  0 , total integrated cost =  218.30906958636368
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14.503336933389921
# RUN  2 , total integrated cost =  9.028934074775906
# RUN  3 , total integrated cost =  4.617028803388125
# RUN  4 , total integrated cost =  4.2757931331632495
# RUN  5 , total integrated cost =  3.8973348237713354
# RUN  5 , total integrated cost =  3.8973348237713354
# Improved over  5  iterations in  0.23533326599863358  seconds by  98.21476275302912  percent.
# interpolate adjoint :  True True True
# initial cost =  4.4109230582920285
# RUN  0 , total integrated cost =  4.4109230582920285
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.052694673875138
# RUN  2 , total integrated cost =  3.7189112188347893
# RUN  3 , total integrated cost =  3.5327540295087405
# RUN  4 , total integrated cost =  3.6548217412046915
# RUN  5 , total integrated cost =  3.576622009555555
# RUN  6 , total integrated cost =  3.63169177349426
# RUN  7 , total integrated cost =  3.5358419561428587
# RUN  8 , total integrated cost =  3.5252467869405164
# RUN  9 , total integrated cost =  3.4827730923288507
# RUN  10 , total integrated cost =  3.5154244562589714
# RUN  11 , total integrated cost =  3.505225194044809
# RUN  12 , total integrated cost =  3.5115166784425
# RUN  13 , total integrated cost =  3.5518570766926283
# RUN  14 , total integrated cost =  3.5199043908210554
# RUN  15 , total integrated cost =  3.443881520699454
# RUN  15 , total integrated cost =  3.443881520699454
# Improved over  15  iterations in  1.2917823629977647  seconds by  21.923790662696945  percent.
# -------- 3
# interpolate adjoint :  True True True
# initial cost =  218.65138323369416
# RUN  0 , total integrated cost =  218.65138323369416
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14.865924761560734
# RUN  2 , total integrated cost =  11.744869417592438
# RUN  3 , total integrated cost =  7.291792374974351
# RUN  4 , total integrated cost =  6.048678594354303
# RUN  5 , total integrated cost =  3.675962560492073
# RUN  5 , total integrated cost =  3.675962560492073
# Improved over  5  iterations in  0.22662985298666172  seconds by  98.31880205552451  percent.
# interpolate adjoint :  True True True
# initial cost =  3.5105617940001728
# RUN  0 , total integrated cost =  3.5105617940001728
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.959780836696728
# RUN  2 , total integrated cost =  2.9354402342983557
# RUN  3 , total integrated cost =  2.8309333950447426
# RUN  4 , total integrated cost =  2.777384967617162
# RUN  5 , total integrated cost =  2.7838971060480584
# RUN  6 , total integrated cost =  2.8171034651178846
# RUN  7 , total integrated cost =  2.742296864566594
# RUN  8 , total integrated cost =  2.827925585211243
# RUN  9 , total integrated cost =  2.772780204059921
# RUN  10 , total integrated cost =  2.7037434787490007
# RUN  11 , total integrated cost =  2.7172341070991552
# RUN  12 , total integrated cost =  2.623864674607795
# RUN  13 , total integrated cost =  2.674850738257363
# RUN  14 , total integrated cost =  2.6634205522747623
# RUN  15 , total integrated cost =  2.5623643782923486
# RUN  15 , total integrated cost =  2.5623643782923486
# Improved over  15  iterations in  1.2052141719905194  seconds by  27.009848319102886  percent.
# -------- 4
# interpolate adjoint :  True True True
# initial cost =  218.67755281337347
# RUN  0 , total integrated cost =  218.67755281337347
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14.38224203176251
# RUN  2 , total integrated cost =  10.75052797551221
# RUN  3 , total integrated cost =  5.854951746095768
# RUN  4 , total integrated cost =  5.305731576458838
# RUN  5 , total integrated cost =  3.9056729510800685
# RUN  5 , total integrated cost =  3.9056729510800685
# Improved over  5  iterations in  0.23333846899913624  seconds by  98.21395799393581  percent.
# interpolate adjoint :  True True True
# initial cost =  4.064284696635788
# RUN  0 , total integrated cost =  4.064284696635788
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.3827776595997405
# RUN  2 , total integrated cost =  3.2010359877780035
# RUN  3 , total integrated cost =  2.8349909259811
# RUN  4 , total integrated cost =  2.669749061043883
# RUN  5 , total integrated cost =  2.635230280067783
# RUN  6 , total integrated cost =  2.621712926211127
# RUN  7 , total integrated cost =  2.6455077085479464
# RUN  8 , total integrated cost =  2.611627188745679
# RUN  9 , total integrated cost =  2.64179714205945
# Control only changes marginally.
# RUN  9 , total integrated cost =  2.64179714205945
# Improved over  9  iterations in  1.0261319860001095  seconds by  34.99970254922846  percent.
# -------- 4
# interpolate adjoint :  True True True
# initial cost =  217.00875589983448
# RUN  0 , total integrated cost =  217.00875589983448
# Gradient descend method:  None
# RUN  1 , total integrated cost =  13.81289968496295
# RUN  2 , total integrated cost =  10.637856111387688
# RUN  3 , total integrated cost =  8.004177520074261
# RUN  4 , total integrated cost =  7.069080881383852
# RUN  5 , total integrated cost =  4.9238886421591825
# RUN  5 , total integrated cost =  4.9238886421591825
# Improved over  5  iterations in  0.22957935399608687  seconds by  97.73101844589537  percent.
# interpolate adjoint :  True True True
# initial cost =  5.108117215030859
# RUN  0 , total integrated cost =  5.108117215030859
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.078923116698246
# RUN  2 , total integrated cost =  3.839158498766041
# RUN  3 , total integrated cost =  3.6208429384967378
# RUN  4 , total integrated cost =  3.5866607151442684
# RUN  5 , total integrated cost =  3.3523904420468633
# RUN  6 , total integrated cost =  3.0786130303224826
# RUN  7 , total integrated cost =  3.0369258684909095
# RUN  8 , total integrated cost =  3.0360554307279504
# RUN  9 , total integrated cost =  2.95289010218157
# RUN  10 , total integrated cost =  2.8532513307818976
# RUN  11 , total integrated cost =  2.764540072756643
# RUN  12 , total integrated cost =  2.639135669578958
# RUN  13 , total integrated cost =  2.537773562426298
# RUN  14 , total integrated cost =  2.582148020014564
# RUN  15 , total integrated cost =  2.5357091666326252
# RUN  15 , total integrated cost =  2.5357091666326252
# Improved over  15  iterations in  1.2904336799983867  seconds by  50.35922121811947  percent.
# -------- 5
# interpolate adjoint :  True True True
# initial cost =  219.27308249619375
# RUN  0 , total integrated cost =  219.27308249619375
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14.830371348553127
# RUN  2 , total integrated cost =  8.933143090969804
# RUN  3 , total integrated cost =  6.244272716018717
# RUN  4 , total integrated cost =  5.490406290214705
# RUN  5 , total integrated cost =  4.542957194939719
# RUN  5 , total integrated cost =  4.542957194939719
# Improved over  5  iterations in  0.23294417900615372  seconds by  97.92817378985924  percent.
# interpolate adjoint :  True True True
# initial cost =  4.554903773454619
# RUN  0 , total integrated cost =  4.554903773454619
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.233647047910964
# RUN  2 , total integrated cost =  4.195637769274536
# RUN  3 , total integrated cost =  4.145012670288875
# RUN  4 , total integrated cost =  3.881159669943311
# RUN  5 , total integrated cost =  3.784285137657349
# RUN  6 , total integrated cost =  3.7454513060823253
# RUN  7 , total integrated cost =  3.47157315097848
# RUN  8 , total integrated cost =  3.440038397403168
# RUN  9 , total integrated cost =  3.3914140629241785
# RUN  10 , total integrated cost =  3.3461953444677737
# RUN  11 , total integrated cost =  3.2945006412930016
# RUN  12 , total integrated cost =  3.1193661347351185
# RUN  13 , total integrated cost =  3.168921858132836
# RUN  14 , total integrated cost =  3.150443375967521
# RUN  15 , total integrated cost =  3.0741585128203965
# RUN  15 , total integrated cost =  3.0741585128203965
# Improved over  15  iterations in  1.3881846349977423  seconds by  32.508815427974824  percent.
# -------- 6
# interpolate adjoint :  True True True
# initial cost =  220.09675533969047
# RUN  0 , total integrated cost =  220.09675533969047
# Gradient descend method:  None
# RUN  1 , total integrated cost =  13.856678174878782
# RUN  2 , total integrated cost =  9.740003789569725
# RUN  3 , total integrated cost =  3.243507885195532
# RUN  4 , total integrated cost =  2.485083090596106
# RUN  5 , total integrated cost =  2.9260224607896177
# RUN  5 , total integrated cost =  2.9260224607896177
# Improved over  5  iterations in  0.23702846700325608  seconds by  98.67057446790903  percent.
# interpolate adjoint :  True True True
# initial cost =  3.351361868022808
# RUN  0 , total integrated cost =  3.351361868022808
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.5069295015125124
# RUN  2 , total integrated cost =  2.4685746175054004
# RUN  3 , total integrated cost =  2.4969474433654937
# RUN  4 , total integrated cost =  2.4503005380952905
# RUN  5 , total integrated cost =  2.488734868922835
# RUN  6 , total integrated cost =  2.4421603364260616
# RUN  7 , total integrated cost =  2.4725496338731077
# RUN  8 , total integrated cost =  2.4658964616168095
# RUN  9 , total integrated cost =  2.3945926506080797
# RUN  10 , total integrated cost =  2.367758239590352
# RUN  11 , total integrated cost =  2.4709524355885715
# RUN  12 , total integrated cost =  2.3977047355296897
# RUN  13 , total integrated cost =  2.4192559219544587
# RUN  14 , total integrated cost =  2.4446268429163545
# RUN  15 , total integrated cost =  2.4351752569488774
# RUN  15 , total integrated cost =  2.4351752569488774
# Improved over  15  iterations in  1.6797036089992616  seconds by  27.337740511276095  percent.
# -------- 7
# interpolate adjoint :  True True True
# initial cost =  214.71090294771605
# RUN  0 , total integrated cost =  214.71090294771605
# Gradient descend method:  None
# RUN  1 , total integrated cost =  15.421526893978175
# RUN  2 , total integrated cost =  13.795771374243639
# RUN  3 , total integrated cost =  9.623808084590538
# RUN  4 , total integrated cost =  8.955356731348207
# RUN  5 , total integrated cost =  6.1700766456081695
# RUN  5 , total integrated cost =  6.1700766456081695
# Improved over  5  iterations in  0.31931030499981716  seconds by  97.12633286856857  percent.
# interpolate adjoint :  True True True
# initial cost =  6.499422474546913
# RUN  0 , total integrated cost =  6.499422474546913
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.234550939054484
# RUN  2 , total integrated cost =  3.7280684663735633
# RUN  3 , total integrated cost =  3.3034840250779443
# RUN  4 , total integrated cost =  3.1753948660291478
# RUN  5 , total integrated cost =  3.258236708596631
# RUN  6 , total integrated cost =  3.134733720788199
# RUN  7 , total integrated cost =  3.183250300877963
# RUN  8 , total integrated cost =  3.109470873961118
# RUN  9 , total integrated cost =  2.995073255201646
# RUN  10 , total integrated cost =  2.8671139036658824
# RUN  11 , total integrated cost =  2.8421733715616257
# RUN  12 , total integrated cost =  2.8746782661166574
# RUN  13 , total integrated cost =  2.8206979021699485
# RUN  14 , total integrated cost =  2.7782947331396626
# RUN  15 , total integrated cost =  2.7903468276581953
# RUN  15 , total integrated cost =  2.7903468276581953
# Improved over  15  iterations in  2.4887784099846613  seconds by  57.067772735411914  percent.
# -------- 8
# interpolate adjoint :  True True True
# initial cost =  217.92809014883767
# RUN  0 , total integrated cost =  217.92809014883767
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14.78317072225908
# RUN  2 , total integrated cost =  8.972234263864355
# RUN  3 , total integrated cost =  6.107004101967804
# RUN  4 , total integrated cost =  4.702963252161303
# RUN  5 , total integrated cost =  4.654064536243435
# RUN  5 , total integrated cost =  4.654064536243435
# Improved over  5  iterations in  0.3273762440076098  seconds by  97.8644035594196  percent.
# interpolate adjoint :  True True True
# initial cost =  4.716510746912046
# RUN  0 , total integrated cost =  4.716510746912046
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.452439976191584
# RUN  2 , total integrated cost =  4.186747060821122
# RUN  3 , total integrated cost =  3.901972997812765
# RUN  4 , total integrated cost =  3.292903722580196
# RUN  5 , total integrated cost =  3.1670119038760562
# RUN  6 , total integrated cost =  3.0797016339953043
# RUN  7 , total integrated cost =  2.917888317053687
# RUN  8 , total integrated cost =  2.7827797858865733
# RUN  9 , total integrated cost =  2.9002963637869277
# RUN  10 , total integrated cost =  2.8055593394373255
# RUN  11 , total integrated cost =  2.7616783202172677
# RUN  12 , total integrated cost =  2.7933454226949586
# RUN  13 , total integrated cost =  2.762539309264963
# RUN  14 , total integrated cost =  2.726472810168194
# RUN  15 , total integrated cost =  2.762332643626592
# RUN  15 , total integrated cost =  2.762332643626592
# Improved over  15  iterations in  1.8505952539853752  seconds by  41.43270752780278  percent.
# -------- 9
# interpolate adjoint :  True True True
# initial cost =  219.57306154820975
# RUN  0 , total integrated cost =  219.57306154820975
# Gradient descend method:  None
# RUN  1 , total integrated cost =  13.845487909479205
# RUN  2 , total integrated cost =  9.637152488497254
# RUN  3 , total integrated cost =  5.486937459581872
# RUN  4 , total integrated cost =  4.587286161116644
# RUN  5 , total integrated cost =  4.405411322138463
# RUN  5 , total integrated cost =  4.405411322138463
# Improved over  5  iterations in  0.32800452900119126  seconds by  97.99364672010496  percent.
# interpolate adjoint :  True True True
# initial cost =  4.320981076930115
# RUN  0 , total integrated cost =  4.320981076930115
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.011006911878541
# RUN  2 , total integrated cost =  3.6932694928765937
# RUN  3 , total integrated cost =  3.650290116150064
# RUN  4 , total integrated cost =  3.4457645779152326
# RUN  5 , total integrated cost =  3.4423429377461465
# RUN  6 , total integrated cost =  3.421855385089923
# RUN  7 , total integrated cost =  3.390408715336684
# RUN  8 , total integrated cost =  3.380487514365668
# RUN  9 , total integrated cost =  3.358508059089903
# RUN  10 , total integrated cost =  3.0388632159772273
# RUN  11 , total integrated cost =  2.994747118660749
# RUN  12 , total integrated cost =  2.949512653773076
# RUN  13 , total integrated cost =  2.691364516703265
# RUN  14 , total integrated cost =  2.4906633382219514
# RUN  15 , total integrated cost =  2.4327093897528167
# RUN  15 , total integrated cost =  2.4327093897528167
# Improved over  15  iterations in  1.987195272988174  seconds by  43.70006842332298  percent.
# -------- 10
# interpolate adjoint :  True True True
# initial cost =  218.1124220607704
# RUN  0 , total integrated cost =  218.1124220607704
# Gradient descend method:  None
# RUN  1 , total integrated cost =  13.931963419434311
# RUN  2 , total integrated cost =  11.615231013011986
# RUN  3 , total integrated cost =  3.2605222320632663
# RUN  4 , total integrated cost =  2.511685312066645
# RUN  5 , total integrated cost =  2.5108087293916075
# RUN  5 , total integrated cost =  2.5108087293916075
# Improved over  5  iterations in  0.37455567900906317  seconds by  98.84884652342632  percent.
# interpolate adjoint :  True True True
# initial cost =  2.440557756188187
# RUN  0 , total integrated cost =  2.440557756188187
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.323390607249255
# RUN  2 , total integrated cost =  2.3605669298547354
# RUN  3 , total integrated cost =  2.3207609796259474
# RUN  4 , total integrated cost =  2.3742636050539536
# RUN  5 , total integrated cost =  2.284898093678802
# RUN  6 , total integrated cost =  2.3321350050540373
# RUN  7 , total integrated cost =  2.3058617780501938
# RUN  8 , total integrated cost =  2.3139336680718676
# RUN  9 , total integrated cost =  2.2784539756556192
# RUN  10 , total integrated cost =  2.321844998958158
# RUN  11 , total integrated cost =  2.2399704139619896
# RUN  12 , total integrated cost =  2.20642041370538
# RUN  13 , total integrated cost =  2.3019534069745284
# RUN  14 , total integrated cost =  2.317120108268397
# RUN  15 , total integrated cost =  2.312075281011987
# RUN  15 , total integrated cost =  2.312075281011987
# Improved over  15  iterations in  1.6883123740262818  seconds by  5.264471813888633  percent.
# -------- 11
# interpolate adjoint :  True True True
# initial cost =  219.66209128494674
# RUN  0 , total integrated cost =  219.66209128494674
# Gradient descend method:  None
# RUN  1 , total integrated cost =  15.13080618321051
# RUN  2 , total integrated cost =  8.85473202440114
# RUN  3 , total integrated cost =  6.089473001070001
# RUN  4 , total integrated cost =  5.3775683165066495
# RUN  5 , total integrated cost =  5.287304699385314
# RUN  5 , total integrated cost =  5.287304699385314
# Improved over  5  iterations in  0.3377173170156311  seconds by  97.59298262688094  percent.
# interpolate adjoint :  True True True
# initial cost =  6.206452955403277
# RUN  0 , total integrated cost =  6.206452955403277
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.042926253710311
# RUN  2 , total integrated cost =  4.907567080922875
# RUN  3 , total integrated cost =  4.851522185555462
# RUN  4 , total integrated cost =  4.70407894997114
# RUN  5 , total integrated cost =  4.497328288730469
# RUN  6 , total integrated cost =  4.477527024511639
# RUN  7 , total integrated cost =  4.399657775419426
# RUN  8 , total integrated cost =  4.373131116900027
# RUN  9 , total integrated cost =  4.344130636170978
# RUN  10 , total integrated cost =  4.208912740092487
# RUN  11 , total integrated cost =  4.00144019242552
# RUN  12 , total integrated cost =  3.8413161845003905
# RUN  13 , total integrated cost =  3.841834679312636
# RUN  14 , total integrated cost =  3.8047787719396524
# RUN  15 , total integrated cost =  3.7465232885629116
# RUN  15 , total integrated cost =  3.7465232885629116
# Improved over  15  iterations in  1.987307753006462  seconds by  39.63503283624787  percent.
# -------- 12
# interpolate adjoint :  True True True
# initial cost =  218.1094623853399
# RUN  0 , total integrated cost =  218.1094623853399
# Gradient descend method:  None
# RUN  1 , total integrated cost =  13.726170952655876
# RUN  2 , total integrated cost =  8.83747896552277
# RUN  3 , total integrated cost =  3.77547209011665
# RUN  4 , total integrated cost =  3.3614121550037037
# RUN  5 , total integrated cost =  3.074964121486624
# RUN  5 , total integrated cost =  3.074964121486624
# Improved over  5  iterations in  0.41615204702247865  seconds by  98.59017390265535  percent.
# interpolate adjoint :  True True True
# initial cost =  3.103847186613331
# RUN  0 , total integrated cost =  3.103847186613331
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.0214817498321507
# RUN  2 , total integrated cost =  3.0392715365585907
# RUN  3 , total integrated cost =  2.9393354094375437
# RUN  4 , total integrated cost =  2.8915126778051126
# RUN  5 , total integrated cost =  2.809434766258834
# RUN  6 , total integrated cost =  2.847694225082446
# RUN  7 , total integrated cost =  2.838715967114929
# RUN  8 , total integrated cost =  2.799529414493562
# RUN  9 , total integrated cost =  2.811009365274587
# RUN  10 , total integrated cost =  2.80294226535136
# RUN  11 , total integrated cost =  2.763591004744658
# RUN  12 , total integrated cost =  2.781836832479804
# RUN  13 , total integrated cost =  2.73882404844791
# RUN  14 , total integrated cost =  2.7606348026397565
# RUN  15 , total integrated cost =  2.7094546960042543
# RUN  15 , total integrated cost =  2.7094546960042543
# Improved over  15  iterations in  2.109149563999381  seconds by  12.706569199349218  percent.
# -------- 13
# interpolate adjoint :  True True True
# initial cost =  218.30231356586904
# RUN  0 , total integrated cost =  218.30231356586904
# Gradient descend method:  None
# RUN  1 , total integrated cost =  15.164092965572792
# RUN  2 , total integrated cost =  10.843318283657101
# RUN  3 , total integrated cost =  3.643219487055898
# RUN  4 , total integrated cost =  3.1440136538098513
# RUN  5 , total integrated cost =  2.9820865175180797
# RUN  5 , total integrated cost =  2.9820865175180797
# Improved over  5  iterations in  0.39752160498755984  seconds by  98.63396476711262  percent.
# interpolate adjoint :  True True True
# initial cost =  3.0314368640390716
# RUN  0 , total integrated cost =  3.0314368640390716
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.839580596449523
# RUN  2 , total integrated cost =  2.5467880359936084
# RUN  3 , total integrated cost =  2.5703208039304553
# RUN  4 , total integrated cost =  2.562263807021073
# RUN  5 , total integrated cost =  2.5276829366723432
# RUN  6 , total integrated cost =  2.5227301040267154
# Control only changes marginally.
# RUN  6 , total integrated cost =  2.5227301040267154
# Improved over  6  iterations in  1.1342659080110025  seconds by  16.781044198775035  percent.
# -------- 13
# interpolate adjoint :  True True True
# initial cost =  218.4282336404021
# RUN  0 , total integrated cost =  218.4282336404021
# Gradient descend method:  None
# RUN  1 , total integrated cost =  13.362079796772855
# RUN  2 , total integrated cost =  9.231975903340885
# RUN  3 , total integrated cost =  4.175432364200901
# RUN  4 , total integrated cost =  3.3172179755895668
# RUN  5 , total integrated cost =  3.3960211877185076
# RUN  5 , total integrated cost =  3.3960211877185076
# Improved over  5  iterations in  0.32484358400688507  seconds by  98.44524623437216  percent.
# interpolate adjoint :  True True True
# initial cost =  3.535794173208544
# RUN  0 , total integrated cost =  3.535794173208544
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.107027463281857
# RUN  2 , total integrated cost =  3.193021347655427
# RUN  3 , total integrated cost =  3.2358391241387308
# RUN  4 , total integrated cost =  3.1624175558910554
# RUN  5 , total integrated cost =  3.108792669222698
# RUN  6 , total integrated cost =  2.981203808621707
# RUN  7 , total integrated cost =  2.9720944183817277
# RUN  8 , total integrated cost =  3.0069375679885506
# RUN  9 , total integrated cost =  2.9607433664923244
# RUN  10 , total integrated cost =  2.90708396937922
# RUN  11 , total integrated cost =  2.8250292139660425
# RUN  12 , total integrated cost =  2.8538764499529456
# RUN  13 , total integrated cost =  2.8381635340806652
# RUN  14 , total integrated cost =  2.766024744821088
# RUN  15 , total integrated cost =  2.71865777901752
# RUN  15 , total integrated cost =  2.71865777901752
# Improved over  15  iterations in  1.8692714759963565  seconds by  23.110406153803808  percent.
# -------- 14
# interpolate adjoint :  True True True
# initial cost =  218.67561498558888
# RUN  0 , total integrated cost =  218.67561498558888
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14.375383450864687
# RUN  2 , total integrated cost =  8.855730263970102
# RUN  3 , total integrated cost =  6.794003654079495
# RUN  4 , total integrated cost =  5.890381357984147
# RUN  5 , total integrated cost =  5.5938514410584155
# RUN  5 , total integrated cost =  5.5938514410584155
# Improved over  5  iterations in  0.33905305198277347  seconds by  97.44194091260378  percent.
# interpolate adjoint :  True True True
# initial cost =  5.575613688016895
# RUN  0 , total integrated cost =  5.575613688016895
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.184409586048846
# RUN  2 , total integrated cost =  5.1544175492760065
# RUN  3 , total integrated cost =  5.088033775107616
# RUN  4 , total integrated cost =  5.099536867147541
# RUN  5 , total integrated cost =  5.032308041838166
# RUN  6 , total integrated cost =  5.064853144799186
# RUN  7 , total integrated cost =  4.822675815069356
# RUN  8 , total integrated cost =  4.767720094609977
# RUN  9 , total integrated cost =  4.672270777780966
# RUN  10 , total integrated cost =  4.4587770988146955
# RUN  11 , total integrated cost =  4.390351031096374
# RUN  12 , total integrated cost =  4.350088629933166
# RUN  13 , total integrated cost =  4.280354901502143
# RUN  14 , total integrated cost =  4.252420144387616
# RUN  15 , total integrated cost =  4.137448343324195
# RUN  15 , total integrated cost =  4.137448343324195
# Improved over  15  iterations in  1.9203890069911722  seconds by  25.79384844727683  percent.
# -------- 15
# interpolate adjoint :  True True True
# initial cost =  221.1130955466621
# RUN  0 , total integrated cost =  221.1130955466621
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14.768288840442676
# RUN  2 , total integrated cost =  10.675106295903612
# RUN  3 , total integrated cost =  5.504047116792639
# RUN  4 , total integrated cost =  4.236916756879385
# RUN  5 , total integrated cost =  3.56552608851013
# RUN  5 , total integrated cost =  3.56552608851013
# Improved over  5  iterations in  0.4020221240061801  seconds by  98.38746498496843  percent.
# interpolate adjoint :  True True True
# initial cost =  3.786812527807877
# RUN  0 , total integrated cost =  3.786812527807877
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.5144071366201133
# RUN  2 , total integrated cost =  3.30508069204466
# RUN  3 , total integrated cost =  3.2476661765236723
# RUN  4 , total integrated cost =  2.9368982375200097
# RUN  5 , total integrated cost =  2.8568888630620495
# RUN  6 , total integrated cost =  2.792150947751665
# RUN  7 , total integrated cost =  2.620939717759666
# RUN  8 , total integrated cost =  2.5523209172479198
# RUN  9 , total integrated cost =  2.548964381923621
# RUN  10 , total integrated cost =  2.5576614569573954
# RUN  11 , total integrated cost =  2.58865463155259
# RUN  12 , total integrated cost =  2.537663340294105
# RUN  13 , total integrated cost =  2.5292113337811872
# RUN  14 , total integrated cost =  2.5071902812666313
# RUN  15 , total integrated cost =  2.44950547301342
# RUN  15 , total integrated cost =  2.44950547301342
# Improved over  15  iterations in  2.006414452014724  seconds by  35.31484711678088  percent.
# -------- 16
# interpolate adjoint :  True True True
# initial cost =  219.41723701043776
# RUN  0 , total integrated cost =  219.41723701043776
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14.514611202161515
# RUN  2 , total integrated cost =  9.276559498847512
# RUN  3 , total integrated cost =  5.727993676320731
# RUN  4 , total integrated cost =  4.795579834175066
# RUN  5 , total integrated cost =  4.412107216797224
# RUN  5 , total integrated cost =  4.412107216797224
# Improved over  5  iterations in  0.34271737199742347  seconds by  97.98917018694054  percent.
# interpolate adjoint :  True True True
# initial cost =  4.376156675409416
# RUN  0 , total integrated cost =  4.376156675409416
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.989192972031603
# RUN  2 , total integrated cost =  3.4540667818611994
# RUN  3 , total integrated cost =  3.4098765959950983
# RUN  4 , total integrated cost =  3.265239692194549
# RUN  5 , total integrated cost =  3.220363738900655
# RUN  6 , total integrated cost =  3.125407498384827
# RUN  7 , total integrated cost =  3.1606741054147323
# RUN  8 , total integrated cost =  3.0823338373450424
# RUN  9 , total integrated cost =  3.0181150341140413
# RUN  10 , total integrated cost =  2.8351879251681065
# RUN  11 , total integrated cost =  2.825640044602934
# RUN  12 , total integrated cost =  2.8828485010094194
# RUN  13 , total integrated cost =  2.8433460812923257
# RUN  14 , total integrated cost =  2.6992025263427624
# RUN  15 , total integrated cost =  2.699807016717559
# RUN  15 , total integrated cost =  2.699807016717559
# Improved over  15  iterations in  1.896315157006029  seconds by  38.30643605864555  percent.
# -------- 17
# interpolate adjoint :  True True True
# initial cost =  220.08336478119654
# RUN  0 , total integrated cost =  220.08336478119654
# Gradient descend method:  None
# RUN  1 , total integrated cost =  13.685502467324678
# RUN  2 , total integrated cost =  9.83643249608942
# RUN  3 , total integrated cost =  7.921010644718962
# RUN  4 , total integrated cost =  4.979633035817253
# RUN  5 , total integrated cost =  4.860508924680589
# RUN  5 , total integrated cost =  4.860508924680589
# Improved over  5  iterations in  0.3170935749949422  seconds by  97.79151462469105  percent.
# interpolate adjoint :  True True True
# initial cost =  4.791232356018119
# RUN  0 , total integrated cost =  4.791232356018119
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.622625794451038
# RUN  2 , total integrated cost =  4.457739988076648
# RUN  3 , total integrated cost =  4.530417235736806
# RUN  4 , total integrated cost =  4.453866060173626
# RUN  5 , total integrated cost =  4.350544486220413
# RUN  6 , total integrated cost =  4.316610631912571
# RUN  7 , total integrated cost =  4.083414363585872
# RUN  8 , total integrated cost =  3.842298063985421
# RUN  9 , total integrated cost =  3.6569454547545366
# RUN  10 , total integrated cost =  3.5383388648854366
# RUN  11 , total integrated cost =  3.4182729949333464
# RUN  12 , total integrated cost =  3.2929791160826776
# RUN  13 , total integrated cost =  3.239677203112594
# RUN  14 , total integrated cost =  3.205737150585391
# RUN  15 , total integrated cost =  3.147453203317057
# RUN  15 , total integrated cost =  3.147453203317057
# Improved over  15  iterations in  1.7455912260047626  seconds by  34.308065870284125  percent.
# -------- 18
# interpolate adjoint :  True True True
# initial cost =  217.8280509746279
# RUN  0 , total integrated cost =  217.8280509746279
# Gradient descend method:  None
# RUN  1 , total integrated cost =  15.494632713966258
# RUN  2 , total integrated cost =  9.207064376095811
# RUN  3 , total integrated cost =  6.329507646463677
# RUN  4 , total integrated cost =  5.373524427763234
# RUN  5 , total integrated cost =  5.305623696273928
# RUN  5 , total integrated cost =  5.305623696273928
# Improved over  5  iterations in  0.3594807969930116  seconds by  97.56430649196236  percent.
# interpolate adjoint :  True True True
# initial cost =  5.308914894186302
# RUN  0 , total integrated cost =  5.308914894186302
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.448373552058205
# RUN  2 , total integrated cost =  4.0934356023512635
# RUN  3 , total integrated cost =  3.83109911177179
# RUN  4 , total integrated cost =  3.7996136923181996
# RUN  5 , total integrated cost =  3.77961109686765
# RUN  6 , total integrated cost =  3.759649885303057
# RUN  7 , total integrated cost =  3.7433491435511748
# RUN  8 , total integrated cost =  3.755881568812164
# RUN  9 , total integrated cost =  3.7371119185558914
# RUN  10 , total integrated cost =  3.702137419183272
# RUN  11 , total integrated cost =  3.6732401814765425
# RUN  12 , total integrated cost =  3.641887045249347
# RUN  13 , total integrated cost =  3.657062346498791
# RUN  14 , total integrated cost =  3.6682461999085882
# RUN  15 , total integrated cost =  3.6346466239274338
# RUN  15 , total integrated cost =  3.6346466239274338
# Improved over  15  iterations in  1.8331290569913108  seconds by  31.536920512557643  percent.
# -------- 19
# interpolate adjoint :  True True True
# initial cost =  219.32535376229114
# RUN  0 , total integrated cost =  219.32535376229114
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14.256819044787347
# RUN  2 , total integrated cost =  10.516737761296332
# RUN  3 , total integrated cost =  3.925965581095472
# RUN  4 , total integrated cost =  3.1716844854618116
# RUN  5 , total integrated cost =  3.0010446975875062
# RUN  5 , total integrated cost =  3.0010446975875062
# Improved over  5  iterations in  0.3344304889906198  seconds by  98.63169275867664  percent.
# interpolate adjoint :  True True True
# initial cost =  3.1698885663830993
# RUN  0 , total integrated cost =  3.1698885663830993
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.9904431009213384
# RUN  2 , total integrated cost =  2.965095306440557
# RUN  3 , total integrated cost =  2.9633134096632374
# RUN  4 , total integrated cost =  2.5200977678611025
# RUN  5 , total integrated cost =  2.382044856805398
# RUN  6 , total integrated cost =  2.3665585109720433
# RUN  7 , total integrated cost =  2.3963098709552906
# RUN  8 , total integrated cost =  2.395738205539682
# RUN  9 , total integrated cost =  2.3750585701932154
# RUN  10 , total integrated cost =  2.409101154700333
# RUN  11 , total integrated cost =  2.3776073351809908
# RUN  12 , total integrated cost =  2.4573645193721863
# RUN  13 , total integrated cost =  2.4104919675163603
# RUN  14 , total integrated cost =  2.37105274538722
# RUN  15 , total integrated cost =  2.327567096522022
# RUN  15 , total integrated cost =  2.327567096522022
# Improved over  15  iterations in  2.20384689597995  seconds by  26.572589295218705  percent.
# mean =  3.3311120000980985
# 20
# -------- 0
# interpolate adjoint :  True True True
# initial cost =  217.6557283958388
# RUN  0 , total integrated cost =  217.6557283958388
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12.923626587975583
# RUN  2 , total integrated cost =  9.326325145833462
# RUN  3 , total integrated cost =  6.473744572245151
# RUN  4 , total integrated cost =  4.923969559723675
# RUN  5 , total integrated cost =  3.562419099698997
# RUN  5 , total integrated cost =  3.562419099698997
# Improved over  5  iterations in  0.3116687660221942  seconds by  98.36327804190836  percent.
# interpolate adjoint :  True True True
# initial cost =  3.987816464045121
# RUN  0 , total integrated cost =  3.987816464045121
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.6065124583813266
# RUN  2 , total integrated cost =  3.350041645754087
# RUN  3 , total integrated cost =  3.3347682835275734
# RUN  4 , total integrated cost =  3.3903803348568484
# RUN  5 , total integrated cost =  3.555584323269576
# RUN  6 , total integrated cost =  3.344482574742549
# RUN  7 , total integrated cost =  3.33419043408953
# RUN  8 , total integrated cost =  3.3727804076399184
# RUN  9 , total integrated cost =  3.2176999160418966
# RUN  10 , total integrated cost =  3.242524982022154
# RUN  11 , total integrated cost =  3.246633815696269
# RUN  12 , total integrated cost =  3.2563126782140053
# RUN  13 , total integrated cost =  3.1963308886126436
# RUN  14 , total integrated cost =  3.2290345195406402
# RUN  15 , total integrated cost =  3.1942615861552244
# RUN  15 , total integrated cost =  3.1942615861552244
# Improved over  15  iterations in  2.0267534109880216  seconds by  19.899483465318227  percent.
# -------- 1
# interpolate adjoint :  True True True
# initial cost =  223.3310894559225
# RUN  0 , total integrated cost =  223.3310894559225
# Gradient descend method:  None
# RUN  1 , total integrated cost =  16.265324294864755
# RUN  2 , total integrated cost =  13.399237233453242
# RUN  3 , total integrated cost =  6.735810803622251
# RUN  4 , total integrated cost =  6.329039268473254
# RUN  5 , total integrated cost =  6.2948660087024795
# RUN  5 , total integrated cost =  6.2948660087024795
# Improved over  5  iterations in  0.31421343801775947  seconds by  97.18137496036132  percent.
# interpolate adjoint :  True True True
# initial cost =  6.283983930362601
# RUN  0 , total integrated cost =  6.283983930362601
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.118413342469887
# RUN  2 , total integrated cost =  4.696126495035066
# RUN  3 , total integrated cost =  3.938283417354088
# RUN  4 , total integrated cost =  3.7268863388289537
# RUN  5 , total integrated cost =  3.6144463211612967
# RUN  6 , total integrated cost =  3.259224955250362
# RUN  7 , total integrated cost =  3.427414717717338
# RUN  8 , total integrated cost =  3.398378716924287
# RUN  9 , total integrated cost =  3.3122486223716914
# RUN  10 , total integrated cost =  3.3807373849678597
# RUN  11 , total integrated cost =  3.3081433401318936
# RUN  12 , total integrated cost =  3.3577463809677552
# RUN  13 , total integrated cost =  3.255624657220423
# RUN  14 , total integrated cost =  3.1472619596718245
# RUN  15 , total integrated cost =  3.158338591212416
# RUN  15 , total integrated cost =  3.158338591212416
# Improved over  15  iterations in  1.6790183300036006  seconds by  49.739868430405544  percent.
# -------- 2
# interpolate adjoint :  True True True
# initial cost =  221.80578592828144
# RUN  0 , total integrated cost =  221.80578592828144
# Gradient descend method:  None
# RUN  1 , total integrated cost =  15.263482889345006
# RUN  2 , total integrated cost =  12.247517850583563
# RUN  3 , total integrated cost =  4.771528211485821
# RUN  4 , total integrated cost =  4.07513047479109
# RUN  5 , total integrated cost =  3.736438839400232
# RUN  5 , total integrated cost =  3.736438839400232
# Improved over  5  iterations in  0.3408690399955958  seconds by  98.31544572935155  percent.
# interpolate adjoint :  True True True
# initial cost =  3.7669364744100293
# RUN  0 , total integrated cost =  3.7669364744100293
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.5939110083470345
# RUN  2 , total integrated cost =  3.5775360059745482
# RUN  3 , total integrated cost =  3.6325896101044
# RUN  4 , total integrated cost =  3.6068498756192557
# RUN  5 , total integrated cost =  3.6588825680469026
# RUN  6 , total integrated cost =  3.607391141264494
# RUN  7 , total integrated cost =  3.503140903130717
# RUN  8 , total integrated cost =  3.5954056429521586
# RUN  9 , total integrated cost =  3.4895700206399956
# RUN  10 , total integrated cost =  3.3683209031480574
# RUN  11 , total integrated cost =  3.3423340033953366
# RUN  12 , total integrated cost =  3.447252225985081
# RUN  13 , total integrated cost =  3.1444513707115735
# RUN  14 , total integrated cost =  3.0938903524825863
# RUN  15 , total integrated cost =  3.0953725814858513
# RUN  15 , total integrated cost =  3.0953725814858513
# Improved over  15  iterations in  1.8097914879908785  seconds by  17.827852884866005  percent.
# -------- 3
# interpolate adjoint :  True True True
# initial cost =  219.3772381684673
# RUN  0 , total integrated cost =  219.3772381684673
# Gradient descend method:  None
# RUN  1 , total integrated cost =  15.729698706950924
# RUN  2 , total integrated cost =  12.353710881096003
# RUN  3 , total integrated cost =  4.276237164877233
# RUN  4 , total integrated cost =  3.925598519020498
# RUN  5 , total integrated cost =  3.55903441645518
# RUN  5 , total integrated cost =  3.55903441645518
# Improved over  5  iterations in  0.3396542609843891  seconds by  98.37766468109054  percent.
# interpolate adjoint :  True True True
# initial cost =  3.507222517545461
# RUN  0 , total integrated cost =  3.507222517545461
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.224882013256627
# RUN  2 , total integrated cost =  3.0992070413830346
# RUN  3 , total integrated cost =  3.1445677950360977
# RUN  4 , total integrated cost =  3.06509118564147
# RUN  5 , total integrated cost =  3.0768619394442704
# RUN  6 , total integrated cost =  2.98782949804488
# RUN  7 , total integrated cost =  2.8627525646720247
# RUN  8 , total integrated cost =  2.9070470715141403
# RUN  9 , total integrated cost =  2.70616372812047
# RUN  10 , total integrated cost =  2.4549849075286145
# RUN  11 , total integrated cost =  2.6002037109896863
# RUN  12 , total integrated cost =  2.5328859787869042
# Control only changes marginally.
# RUN  12 , total integrated cost =  2.5328859787869042
# Improved over  12  iterations in  2.0975798910076264  seconds by  27.780858895729523  percent.
# -------- 4
# interpolate adjoint :  True True True
# initial cost =  220.80045833139496
# RUN  0 , total integrated cost =  220.80045833139496
# Gradient descend method:  None
# RUN  1 , total integrated cost =  15.174668126546969
# RUN  2 , total integrated cost =  11.395465675320482
# RUN  3 , total integrated cost =  6.958826983153933
# RUN  4 , total integrated cost =  5.671780755384299
# RUN  5 , total integrated cost =  5.30472278786587
# RUN  5 , total integrated cost =  5.30472278786587
# Improved over  5  iterations in  0.3339552779798396  seconds by  97.59750372442429  percent.
# interpolate adjoint :  True True True
# initial cost =  6.016709753500204
# RUN  0 , total integrated cost =  6.016709753500204
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.965995909540957
# RUN  2 , total integrated cost =  4.834939104833369
# RUN  3 , total integrated cost =  4.429282878023879
# RUN  4 , total integrated cost =  4.120347599189749
# RUN  5 , total integrated cost =  4.074991479497025
# RUN  6 , total integrated cost =  3.8733416145602013
# RUN  7 , total integrated cost =  3.6942228327056754
# RUN  8 , total integrated cost =  3.6964472016415324
# RUN  9 , total integrated cost =  3.7028041239041762
# RUN  10 , total integrated cost =  3.8058362629061318
# RUN  11 , total integrated cost =  3.677327898186943
# RUN  12 , total integrated cost =  3.479546851427469
# RUN  13 , total integrated cost =  3.6274698986657548
# RUN  14 , total integrated cost =  3.5861485126535255
# RUN  15 , total integrated cost =  3.5039703896315277
# RUN  15 , total integrated cost =  3.5039703896315277
# Improved over  15  iterations in  1.7087551549775526  seconds by  41.76268204406731  percent.
# -------- 5
# interpolate adjoint :  True True True
# initial cost =  220.02467933495123
# RUN  0 , total integrated cost =  220.02467933495123
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14.56236437727644
# RUN  2 , total integrated cost =  8.974781013102115
# RUN  3 , total integrated cost =  8.517295273677009
# RUN  4 , total integrated cost =  4.876096917004436
# RUN  5 , total integrated cost =  4.437505273683212
# RUN  5 , total integrated cost =  4.437505273683212
# Improved over  5  iterations in  0.31333733201608993  seconds by  97.9831783929439  percent.
# interpolate adjoint :  True True True
# initial cost =  4.737036075402309
# RUN  0 , total integrated cost =  4.737036075402309
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.662629372262045
# RUN  2 , total integrated cost =  3.4577802601746006
# RUN  3 , total integrated cost =  3.438291776033611
# RUN  4 , total integrated cost =  3.2126849595898426
# RUN  5 , total integrated cost =  3.054974668296489
# RUN  6 , total integrated cost =  3.134200903711527
# RUN  7 , total integrated cost =  3.0485214178749365
# RUN  8 , total integrated cost =  3.176641045469231
# RUN  9 , total integrated cost =  3.137812625767835
# RUN  10 , total integrated cost =  3.118649522284716
# RUN  11 , total integrated cost =  3.253823754324361
# RUN  12 , total integrated cost =  3.266228416062527
# RUN  13 , total integrated cost =  3.3522666541485795
# RUN  14 , total integrated cost =  3.1529249422546726
# RUN  15 , total integrated cost =  3.1641878173649247
# RUN  15 , total integrated cost =  3.1641878173649247
# Improved over  15  iterations in  1.8111082940013148  seconds by  33.20321468955257  percent.
# -------- 6
# interpolate adjoint :  True True True
# initial cost =  220.25892773026894
# RUN  0 , total integrated cost =  220.25892773026894
# Gradient descend method:  None
# RUN  1 , total integrated cost =  15.870636359040695
# RUN  2 , total integrated cost =  13.630558458845261
# RUN  3 , total integrated cost =  10.490276857911226
# RUN  4 , total integrated cost =  9.129417365286534
# RUN  5 , total integrated cost =  6.735601638772319
# RUN  5 , total integrated cost =  6.735601638772319
# Improved over  5  iterations in  0.3072472679778002  seconds by  96.94196203160455  percent.
# interpolate adjoint :  True True True
# initial cost =  6.776898410711956
# RUN  0 , total integrated cost =  6.776898410711956
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.7623344227746465
# RUN  2 , total integrated cost =  4.8418309473250165
# RUN  3 , total integrated cost =  4.6742762911962625
# RUN  4 , total integrated cost =  4.343351533493358
# RUN  5 , total integrated cost =  4.019114991181711
# RUN  6 , total integrated cost =  4.123624204990776
# RUN  7 , total integrated cost =  4.032076771051031
# RUN  8 , total integrated cost =  4.054736629596838
# RUN  9 , total integrated cost =  3.8224710371935453
# RUN  10 , total integrated cost =  3.783147591830997
# RUN  11 , total integrated cost =  3.7310511629215366
# RUN  12 , total integrated cost =  3.842802868936423
# RUN  13 , total integrated cost =  3.7646573869356894
# RUN  14 , total integrated cost =  3.6815197725449877
# RUN  15 , total integrated cost =  3.6594850511323753
# RUN  15 , total integrated cost =  3.6594850511323753
# Improved over  15  iterations in  1.8281297429930419  seconds by  46.00059157817709  percent.
# -------- 7
# interpolate adjoint :  True True True
# initial cost =  226.91534774084403
# RUN  0 , total integrated cost =  226.91534774084403
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14.6462600018131
# RUN  2 , total integrated cost =  9.14712161871649
# RUN  3 , total integrated cost =  5.971798470850256
# ...
# RUN  13 , total integrated cost =  3.9376534650006105
# RUN  14 , total integrated cost =  3.9931368649225996
# RUN  15 , total integrated cost =  3.916950713017894
# RUN  15 , total integrated cost =  3.916950713017894
# Improved over  15  iterations in  1.919442922982853  seconds by  42.6866905866771  percent.
# -------- 13
# interpolate adjoint :  True True True
# initial cost =  217.59866143807332
# RUN  0 , total integrated cost =  217.59866143807332
# Gradient descend method:  None
# RUN  1 , total integrated cost =  15.375197259145734
# RUN  2 , total integrated cost =  12.380821493974285
# RUN  3 , total integrated cost =  3.78124348620592
# RUN  4 , total integrated cost =  3.0163080614405624
# RUN  5 , total integrated cost =  2.915315517594026
# RUN  5 , total integrated cost =  2.915315517594026
# Improved over  5  iterations in  0.3252953359915409  seconds by  98.660232788967  percent.
# interpolate adjoint :  True True True
# initial cost =  3.8747497273573557
# RUN  0 , total integrated cost =  3.8747497273573557
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.874825177106265
# RUN  2 , total integrated cost =  2.838889432468558
# RUN  3 , total integrated cost =  2.794116453155162
# RUN  4 , total integrated cost =  2.798941984994931
# RUN  5 , total integrated cost =  3.012469688711907
# RUN  6 , total integrated cost =  2.799639553354431
# RUN  7 , total integrated cost =  2.8207250120880634
# RUN  8 , total integrated cost =  2.698540186125623
# RUN  9 , total integrated cost =  2.8647886101066886
# RUN  10 , total integrated cost =  2.7819713462140596
# RUN  11 , total integrated cost =  2.7202321424828737
# RUN  12 , total integrated cost =  2.79457215023785
# RUN  13 , total integrated cost =  2.9224244840668723
# RUN  14 , total integrated cost =  2.7916007576825344
# RUN  15 , total integrated cost =  2.7410349384288164
# RUN  15 , total integrated cost =  2.7410349384288164
# Improved over  15  iterations in  1.7502107380132657  seconds by  29.259045582325953  percent.
# -------- 14
# interpolate adjoint :  True True True
# initial cost =  214.34609191920111
# RUN  0 , total integrated cost =  214.34609191920111
# Gradient descend method:  None
# RUN  1 , total integrated cost =  13.79916711915964
# RUN  2 , total integrated cost =  10.153755361209281
# RUN  3 , total integrated cost =  9.605559151286917
# RUN  4 , total integrated cost =  5.834545430996119
# RUN  5 , total integrated cost =  5.366638349350025
# RUN  5 , total integrated cost =  5.366638349350025
# Improved over  5  iterations in  0.3196672710182611  seconds by  97.49627422581  percent.
# interpolate adjoint :  True True True
# initial cost =  5.417830122385437
# RUN  0 , total integrated cost =  5.417830122385437
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.5563902484649796
# RUN  2 , total integrated cost =  3.2155944579966196
# RUN  3 , total integrated cost =  3.2073911335704546
# RUN  4 , total integrated cost =  3.335816154291551
# RUN  5 , total integrated cost =  3.143399544083988
# RUN  6 , total integrated cost =  2.6001238928398074
# RUN  7 , total integrated cost =  2.8259165161340087
# RUN  8 , total integrated cost =  3.1962637592748506
# RUN  9 , total integrated cost =  2.943743860941643
# RUN  10 , total integrated cost =  2.8581203217091318
# RUN  11 , total integrated cost =  2.707859269177439
# RUN  12 , total integrated cost =  2.8080216699654064
# RUN  13 , total integrated cost =  2.8018250151117488
# RUN  14 , total integrated cost =  2.9291679000340785
# RUN  15 , total integrated cost =  2.9835841481153604
# RUN  15 , total integrated cost =  2.9835841481153604
# Improved over  15  iterations in  1.7237237019871827  seconds by  44.93027502306206  percent.
# -------- 15
# interpolate adjoint :  True True True
# initial cost =  216.29934903059345
# RUN  0 , total integrated cost =  216.29934903059345
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14.557852006805117
# RUN  2 , total integrated cost =  10.667530203148416
# RUN  3 , total integrated cost =  6.990525218536392
# RUN  4 , total integrated cost =  6.807814052187098
# RUN  5 , total integrated cost =  4.084102528706921
# RUN  5 , total integrated cost =  4.084102528706921
# Improved over  5  iterations in  0.326908763992833  seconds by  98.11182856212422  percent.
# interpolate adjoint :  True True True
# initial cost =  4.24812700588574
# RUN  0 , total integrated cost =  4.24812700588574
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.533096323066043
# RUN  2 , total integrated cost =  3.500975162416466
# RUN  3 , total integrated cost =  3.4757715424147335
# RUN  4 , total integrated cost =  3.4950109107882765
# RUN  5 , total integrated cost =  3.449054729439266
# RUN  6 , total integrated cost =  3.5261273624007066
# RUN  7 , total integrated cost =  3.492833731855023
# RUN  8 , total integrated cost =  3.1101709156469908
# RUN  9 , total integrated cost =  3.136923551341754
# RUN  10 , total integrated cost =  3.1517651153312185
# RUN  11 , total integrated cost =  3.020435742591199
# RUN  12 , total integrated cost =  3.1778861857602525
# RUN  13 , total integrated cost =  2.9602563804379685
# RUN  14 , total integrated cost =  2.963976681694083
# RUN  15 , total integrated cost =  3.0117931874297
# RUN  15 , total integrated cost =  3.0117931874297
# Improved over  15  iterations in  1.7993783580022864  seconds by  29.10303333076226  percent.
# -------- 16
# interpolate adjoint :  True True True
# initial cost =  211.57764959996612
# RUN  0 , total integrated cost =  211.57764959996612
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12.564246625953038
# RUN  2 , total integrated cost =  9.327265908469652
# RUN  3 , total integrated cost =  7.881645853543359
# RUN  4 , total integrated cost =  4.451821576936876
# RUN  5 , total integrated cost =  4.389004622129041
# RUN  5 , total integrated cost =  4.389004622129041
# Improved over  5  iterations in  0.3405365869984962  seconds by  97.92558210641464  percent.
# interpolate adjoint :  True True True
# initial cost =  4.7683065331767605
# RUN  0 , total integrated cost =  4.7683065331767605
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.2860418278669
# RUN  2 , total integrated cost =  4.2759029695439015
# RUN  3 , total integrated cost =  4.160656828234719
# RUN  4 , total integrated cost =  3.918838525198094
# RUN  5 , total integrated cost =  3.550696417783577
# RUN  6 , total integrated cost =  3.677569268899803
# RUN  7 , total integrated cost =  3.6545219854482074
# RUN  8 , total integrated cost =  3.495076490278924
# RUN  9 , total integrated cost =  3.5104432647451578
# RUN  10 , total integrated cost =  3.4123152896238436
# RUN  11 , total integrated cost =  3.4997138068625016
# RUN  12 , total integrated cost =  3.4114338670412874
# RUN  13 , total integrated cost =  3.1376889481340777
# RUN  14 , total integrated cost =  3.153768476937105
# RUN  15 , total integrated cost =  3.005219725078051
# RUN  15 , total integrated cost =  3.005219725078051
# Improved over  15  iterations in  2.209261545998743  seconds by  36.97511466243968  percent.
# -------- 17
# interpolate adjoint :  True True True
# initial cost =  212.20379394092805
# RUN  0 , total integrated cost =  212.20379394092805
# Gradient descend method:  None
# RUN  1 , total integrated cost =  13.083139510819302
# RUN  2 , total integrated cost =  9.072321325757315
# RUN  3 , total integrated cost =  6.530486025070928
# RUN  4 , total integrated cost =  4.29823923450766
# RUN  5 , total integrated cost =  3.9915228868633568
# RUN  5 , total integrated cost =  3.9915228868633568
# Improved over  5  iterations in  0.3372239879972767  seconds by  98.11901436221518  percent.
# interpolate adjoint :  True True True
# initial cost =  3.912058977002574
# RUN  0 , total integrated cost =  3.912058977002574
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.6354722134103286
# RUN  2 , total integrated cost =  3.5152760952153517
# RUN  3 , total integrated cost =  3.1207593442203194
# RUN  4 , total integrated cost =  3.1373382705731334
# RUN  5 , total integrated cost =  3.033709730022828
# RUN  6 , total integrated cost =  2.982751020516509
# RUN  7 , total integrated cost =  3.016007931267771
# RUN  8 , total integrated cost =  3.0198939433884
# RUN  9 , total integrated cost =  3.186626222156983
# RUN  10 , total integrated cost =  3.0544187578579116
# RUN  11 , total integrated cost =  3.0385492418119653
# RUN  12 , total integrated cost =  3.0774566206173097
# RUN  13 , total integrated cost =  3.0941404854320744
# RUN  14 , total integrated cost =  3.0082654487211586
# RUN  15 , total integrated cost =  2.970594792727266
# RUN  15 , total integrated cost =  2.970594792727266
# Improved over  15  iterations in  2.126388598990161  seconds by  24.065695067732833  percent.
# -------- 18
# interpolate adjoint :  True True True
# initial cost =  216.69717183180444
# RUN  0 , total integrated cost =  216.69717183180444
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14.179240468231049
# RUN  2 , total integrated cost =  9.33999390597228
# RUN  3 , total integrated cost =  4.055968574682854
# RUN  4 , total integrated cost =  3.600302909421496
# RUN  5 , total integrated cost =  3.9984356972143056
# RUN  5 , total integrated cost =  3.9984356972143056
# Improved over  5  iterations in  0.34154761998797767  seconds by  98.15482792718781  percent.
# interpolate adjoint :  True True True
# initial cost =  5.974017781905161
# RUN  0 , total integrated cost =  5.974017781905161
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.6527382376868656
# RUN  2 , total integrated cost =  3.5016849462565567
# RUN  3 , total integrated cost =  3.450311143239868
# RUN  4 , total integrated cost =  3.3462430459875847
# RUN  5 , total integrated cost =  3.344289656933195
# RUN  6 , total integrated cost =  3.198636024316658
# RUN  7 , total integrated cost =  3.162491425741244
# RUN  8 , total integrated cost =  3.1120497430413856
# RUN  9 , total integrated cost =  3.1054871440983565
# RUN  10 , total integrated cost =  3.134848239344532
# RUN  11 , total integrated cost =  3.291514507506018
# RUN  12 , total integrated cost =  2.946007948590782
# RUN  13 , total integrated cost =  2.9369973061208596
# RUN  14 , total integrated cost =  2.930820595000559
# RUN  15 , total integrated cost =  2.911225080522281
# RUN  15 , total integrated cost =  2.911225080522281
# Improved over  15  iterations in  1.8651921070122626  seconds by  51.26855682719665  percent.
# -------- 19
# interpolate adjoint :  True True True
# initial cost =  218.702683481536
# RUN  0 , total integrated cost =  218.702683481536
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12.790056811266089
# RUN  2 , total integrated cost =  9.167064362616006
# RUN  3 , total integrated cost =  6.656382208463038
# RUN  4 , total integrated cost =  5.651280532631951
# RUN  5 , total integrated cost =  4.900572881234697
# RUN  5 , total integrated cost =  4.900572881234697
# Improved over  5  iterations in  0.34678935501142405  seconds by  97.7592534288001  percent.
# interpolate adjoint :  True True True
# initial cost =  4.678071344875234
# RUN  0 , total integrated cost =  4.678071344875234
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.936598276700451
# RUN  2 , total integrated cost =  3.6731291641262205
# RUN  3 , total integrated cost =  3.7009205724540264
# RUN  4 , total integrated cost =  3.6661484873786447
# RUN  5 , total integrated cost =  3.769314145288002
# RUN  6 , total integrated cost =  3.5958205069279763
# RUN  7 , total integrated cost =  3.612770945776798
# RUN  8 , total integrated cost =  3.5579502536063847
# RUN  9 , total integrated cost =  3.455141251292539
# RUN  10 , total integrated cost =  3.4055130984470585
# RUN  11 , total integrated cost =  3.378165143426867
# Control only changes marginally.
# RUN  11 , total integrated cost =  3.378165143426867
# Improved over  11  iterations in  1.9658134579949547  seconds by  27.78722481161809  percent.
# -------- 19
# interpolate adjoint :  True True True
# initial cost =  216.38721791522457
# RUN  0 , total integrated cost =  216.38721791522457
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14.925847011053579
# RUN  2 , total integrated cost =  10.962527757543343
# RUN  3 , total integrated cost =  7.967551764526067
# RUN  4 , total integrated cost =  6.1576735072596165
# RUN  5 , total integrated cost =  5.536880451841217
# RUN  5 , total integrated cost =  5.536880451841217
# Improved over  5  iterations in  0.3807365730172023  seconds by  97.44121648903936  percent.
# interpolate adjoint :  True True True
# initial cost =  5.872761083792902
# RUN  0 , total integrated cost =  5.872761083792902
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.310229003460147
# RUN  2 , total integrated cost =  5.347519939365535
# RUN  3 , total integrated cost =  5.161823220514479
# RUN  4 , total integrated cost =  5.055577948333553
# RUN  5 , total integrated cost =  4.9189790164666265
# RUN  6 , total integrated cost =  4.028457036666213
# RUN  7 , total integrated cost =  4.059541254349575
# RUN  8 , total integrated cost =  3.9400001637641484
# RUN  9 , total integrated cost =  3.9308289410125927
# RUN  10 , total integrated cost =  3.7486717280892874
# Control only changes marginally.
# RUN  10 , total integrated cost =  3.7486717280892874
# Improved over  10  iterations in  2.0522331400134135  seconds by  36.16849596632626  percent.
# -------- 19
# interpolate adjoint :  True True True
# initial cost =  216.89663091724375
# RUN  0 , total integrated cost =  216.89663091724375
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14.46911518489416
# RUN  2 , total integrated cost =  11.647296413275653
# RUN  3 , total integrated cost =  7.87816175033326
# RUN  4 , total integrated cost =  6.906255569181098
# RUN  5 , total integrated cost =  4.485278365842096
# RUN  5 , total integrated cost =  4.485278365842096
# Improved over  5  iterations in  0.40053846398950554  seconds by  97.93206637333456  percent.
# interpolate adjoint :  True True True
# initial cost =  4.251159736265832
# RUN  0 , total integrated cost =  4.251159736265832
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.1720637745182994
# RUN  2 , total integrated cost =  3.0748065972319676
# Control only changes marginally.
# RUN  2 , total integrated cost =  3.0748065972319676
# Improved over  2  iterations in  0.7981109259999357  seconds by  27.671346456323903  percent.
# -------- 19
# interpolate adjoint :  True True True
# initial cost =  218.87459643372011
# RUN  0 , total integrated cost =  218.87459643372011
# Gradient descend method:  None
# RUN  1 , total integrated cost =  13.666400218069754
# RUN  2 , total integrated cost =  8.666052002287326
# RUN  3 , total integrated cost =  3.8844945857814803
# RUN  4 , total integrated cost =  3.810464363997345
# RUN  5 , total integrated cost =  3.750745806943428
# RUN  5 , total integrated cost =  3.750745806943428
# Improved over  5  iterations in  0.3933914059889503  seconds by  98.2863494128341  percent.
# interpolate adjoint :  True True True
# initial cost =  4.111062348632703
# RUN  0 , total integrated cost =  4.111062348632703
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.5876225296490656
# RUN  2 , total integrated cost =  3.2144598657514902
# RUN  3 , total integrated cost =  3.1052186208122947
# RUN  4 , total integrated cost =  3.1063002096453056
# RUN  5 , total integrated cost =  3.0036747435710316
# RUN  6 , total integrated cost =  2.990228683941886
# RUN  7 , total integrated cost =  2.7781376245648906
# RUN  8 , total integrated cost =  2.7694063252659165
# RUN  9 , total integrated cost =  3.0043439527638074
# RUN  10 , total integrated cost =  2.7922938787182305
# RUN  11 , total integrated cost =  2.8103179850634628
# RUN  12 , total integrated cost =  2.873896635054557
# RUN  13 , total integrated cost =  2.6303322093220105
# RUN  14 , total integrated cost =  2.852946572818725
# RUN  15 , total integrated cost =  2.697486529571803
# RUN  15 , total integrated cost =  2.697486529571803
# Improved over  15  iterations in  2.5307524770032614  seconds by  34.38468452153349  percent.
# mean =  3.3965930433527225

# %%
i_sigma = 0
i_noise = 0
sigma_ou = sigma_ou_array[i_sigma]
aln.params.sigma_ou = sigma_ou

for factor in np.arange(1.6, 1.6, 0.1):

    init_control = aln.getZeroControl()           
    init_control[:,:,:] = factor * init_control_noisefree[:,:,100:-100]
    T = int(1 + dur/aln.params.dt)
    dt = aln.params.dt

    target_ = target.copy()
    target_[0,0,:int(trans_time * dur / aln.params.dt)] = -1000
    target_[0,1,:int(trans_time * dur / aln.params.dt)] = -1000

    cost_final = np.zeros(( noise_realizations_final ))

    for n_ in range(noise_realizations_final):
        state_ = fo.updateState(aln, init_control)
        cost_final[n_] += cost.numba_cost_precision_int(1,T,dt,w_p,state_, target_, list(prec_vars) )
        cost_final[n_] += cost.numba_cost_sparsity_int(1, 6, T, w_s, dt, init_control)

    print('facotr, mean = ', factor, np.mean(cost_final))
    
factor = [1.3, 2.1]
control_[i_sigma][i_noise] = factor[i_sigma] * init_control_noisefree

# %%
fs_ = 20
fig, ax = plt.subplots(4, 3, figsize=(16,18), constrained_layout=True, facecolor='white',
                       gridspec_kw={'height_ratios': [3,2,3,2]})
#fig.suptitle('Point b', fontsize=fs_)
plot_realizations = 10
i = 50

t_array = np.arange(0,dur+aln.params.dt,aln.params.dt)
ax[0,0].set_title('Multiple of noise-free signal', fontsize=fs_)

setinit(initVars, aln)
aln.params.duration = dur

for i_sigma in range(len(sigma_ou_array)):
    for i_noise in range(len(noise_realizations_array)):
        
        if i_noise in [2]:
            continue
            
        if i_sigma in []:
            continue
        
        noise_realizations = noise_realizations_array[i_noise]
        sigma_ou = sigma_ou_array[i_sigma]
        aln.params.sigma_ou = sigma_ou
        
        if i_noise != 0:
            ax[0,i_noise].set_title('{} noise realizations'.format(noise_realizations), fontsize=fs_)

        ax[2*i_sigma+1,i_noise].plot( t_array, control_[i_sigma][i_noise][0,0,100:-100]/5., color=exc_red)
        ax[2*i_sigma+1,i_noise].plot( t_array, control_[i_sigma][i_noise][0,1,100:-100]/5., color=inh_blue)

        for indexx in range(plot_realizations):
            aln.run(control=control_[i_sigma][i_noise][:,:,100:-100])
            ax[2*i_sigma,i_noise].plot( t_array, aln.rates_exc[0,:], color=exc_red)
            ax[2*i_sigma,i_noise].plot( t_array, aln.rates_inh[0,:], color=inh_blue)

        ax[2*i_sigma,i_noise].text(0.05, 0.9, 'Cost = {:.2f}'.format(cost_final_mean[i_sigma, i_noise]),
                horizontalalignment='left', verticalalignment='top', transform=ax[2*i_sigma,i_noise].transAxes,
                bbox=dict(boxstyle='round', facecolor=midgrey, alpha=0.3), fontsize=fs_)
        
        ax[2*i_sigma+1,i_noise].text(0.05, 0.9, 'Amplitude = {:.4f} nA'.format(
            np.amax(np.abs(control_[i_sigma][i_noise][0,:,100:-100]/5.))), horizontalalignment='left',
            verticalalignment='top', transform=ax[2*i_sigma+1,i_noise].transAxes,
            bbox=dict(boxstyle='round', facecolor=midgrey, alpha=0.3), fontsize=fs_)
        
    #ax[2*i_sigma+1,0].text(0.05, 0.9, 'Factor = {:.2f}'.format(factor[i_sigma]),
    #        horizontalalignment='left', verticalalignment='top', transform=ax[2*i_sigma+1,0].transAxes,
    #        bbox=dict(boxstyle='round', facecolor=midgrey, alpha=0.3), fontsize=fs_)

for j in range(4):
    for k in range(3):
        ax[j,k].tick_params(axis='x', labelsize=fs_)
        ax[j,k].tick_params(axis='y', labelsize=fs_)
        ax[j,k].set_xlim(0,dur)
        ax[j,k].grid(False)
        if j != 5:
            ax[j,k].set_xticks([])
        else:
            ax[j,k].set_xlabel('Time [ms]', fontsize=fs_)
        if k != 0:
            ax[j,k].set_yticks([])
        if j%2 == 0:
            ax[j,k].set_ylim(0,80)
            ax[j,0].set_yticks(np.arange(0,90,20))
            sigma_ou = sigma_ou_array[int(j/2)]
            ax[j,0].set_ylabel(r'$\sigma=$' + '{}'.format(sigma_ou) + '\n' + '\n' 
                                + 'Activity [Hz]', fontsize=fs_)
            ax[j,k].axvspan( dur*trans_time, dur, facecolor=midgrey,
                            alpha=0.5, zorder=-1, hatch='///', edgecolor = midgrey)
        elif j%2 == 1:
            ax[j,k].set_ylim(-0.09,0.0)
            ax[j,0].set_yticks(np.arange(-0.08,0.001,0.04))
            ax[j,0].set_ylabel('Control [nA]', fontsize=fs_)


filename_ = nb[:-6] + '.png'
    
fig.savefig(filename_)
fig.savefig(os.path.join(savepath, filename_))
plt.show()
