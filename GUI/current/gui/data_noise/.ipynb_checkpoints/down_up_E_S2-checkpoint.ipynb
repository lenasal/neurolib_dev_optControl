# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import sys
import pickle
import matplotlib
import ipyparams

path = os.getcwd().split(os.sep + 'GUI')[0]
if path not in sys.path:
    print("not here")
    sys.path.append(path)

from neurolib.models.aln import ALNModel
from neurolib.utils import plotFunctions as plotFunc
from neurolib.utils import func_optimize as fo
from neurolib.utils import costFunctions as cost
import neurolib.dashboard.functions as functions
import neurolib.dashboard.data as data
import neurolib.dashboard.layout as layout
    
# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2 

#path = os.path.join(os.getcwd(), "plots")

cmap_ = layout.getcolormap()
darkgrey, midgrey, lightgrey, color_bi_updown, color_LC, color_bi_uposc = layout.getcolors_rgba()
exc_red = cmap_(3)
inh_blue=cmap_(0)
green = cmap_(2)
# Out:
# not here

# %%
aln = ALNModel()
N = aln.params.N

data.set_parameters(aln)

state_vars = aln.state_vars
init_vars = aln.init_vars

##############################################################
def setinit(init_vars_, model):
    state_vars = model.state_vars
    init_vars = model.init_vars
    for iv in range(len(init_vars)):
        for sv in range(len(state_vars)):
            if state_vars[sv] in init_vars[iv]:
                #print("set init vars ", )
                if model.params[init_vars[iv]].ndim == 2:
                    model.params[init_vars[iv]][0,:] = init_vars_[sv]
                else:
                    model.params[init_vars[iv]][0] = init_vars_[sv]
                    
##############################################################               
def setmaxmincontrol(max_c_c, min_c_c, max_c_r, min_c_r):
    import numpy as np
    
    max_cntrl = np.zeros(( 6 ))
    min_cntrl = np.zeros(( 6 ))
    
    max_cntrl[0] = max_c_c
    min_cntrl[0] = min_c_c
    max_cntrl[1] = max_c_c
    min_cntrl[1] = min_c_c
    max_cntrl[2] = max_c_r
    min_cntrl[2] = min_c_r
    max_cntrl[3] = max_c_r
    min_cntrl[3] = min_c_r
    max_cntrl[4] = max_c_r
    min_cntrl[4] = min_c_r
    max_cntrl[5] = max_c_r
    min_cntrl[5] = min_c_r
            
    return max_cntrl, min_cntrl

# %%
points = np.array( [ [0.4, 0.35], [0.4, 0.4], [0.45, 0.4], [0.425, 0.45], [0.475, 0.45], [0.45, 0.5],
                    [0.5, 0.5], [0.45, 0.65], [0.5, 0.65], [0.55, 0.65] ])

# 10 points, two costs, 4 methods, N

# %%
def create_dict(task, point, cost_params, init, init_vars, target, sigma_array, N_max_array, max_it):
    return dict( {'task':task, 'point':point, 'cost_params':cost_params, 'init':init, 'init_vars':init_vars,
            'target':target, 'sigma':sigma_array, 'N_array':N_max_array,
            'cost':np.zeros(( len(sigma_array), 4, 2, len(N_max_array), max_it )) } )

# %%
dict_list = []
sigma_array = np.arange(0.01, 0.081, 0.01)

for p in points:
    dict_list.append(create_dict('DU', p, [None]*len(sigma_array), [1], None,
                [None]*len(sigma_array), np.arange(0.01, 0.081, 0.01), [1,2,10,30], 40) )

# %%
dict_file = "DU_1E.pickle"

if False:
    file=open(dict_file, "wb")
    pickle.dump(dict_list, file)
    file.close()

if True:
    file = open(dict_file, "rb")
    dict_list = pickle.load(file)
    file.close()

# %%
dur_pre = 10
dur_post = 10
dur = 200.
dur_comp = 2000.
dt = aln.params.dt
T = int(1 + dur / dt)

prec_vars = [0,1]
trans_time = 0.8

n_pre = int(np.around(dur_pre/aln.params.dt,1))
n_post = int(np.around(dur_post/aln.params.dt,1))

tol = 1e-16
start_step = 10.
c_scheme = np.zeros(( 1,1 ))
c_scheme[0,0] = 1.
u_mat = np.identity(1)
u_scheme = np.array([[1.]])

maxC = [5., -5., 0.18, 0.]
n_dur = int(np.around(dur/aln.params.dt + 1.,1))
max_cntrl, min_cntrl = setmaxmincontrol(maxC[0], maxC[1], maxC[2], maxC[3])

noise_realizations_final = 10000
noise_realizations_target_compute = 10000
init_it = 5

# %%
# get init vars without noise
aln = ALNModel()
data.set_parameters(aln)
aln.params.duration = dur_comp

# initial without noise
control0 = aln.getZeroControl()

for d in dict_list:
    
    print("Point = ", d['point'])
    aln.params.ext_exc_current = d['point'][0] * 5.
    aln.params.ext_inh_current = d['point'][1] * 5.
    aln.params.duration = dur_comp
    
    if type(d['init_vars']) == type(None):
    
        control0[0,0,:500] = -5.

        aln.run(control=control0)

        init_state_vars = np.zeros(( len(state_vars) ))
        for j in range(len(state_vars)):
            if aln.state[state_vars[j]].size == 1:
                init_state_vars[j] = aln.state[state_vars[j]][0]
            else:
                init_state_vars[j] = aln.state[state_vars[j]][0,-1]

        initVars = init_state_vars.copy()
        d['init_vars'] = initVars
    
    for ind_s in range(len(d['sigma'])):
        
        if type(d['cost_params'][ind_s]) != type(None):
            continue        
        
        s = d['sigma'][ind_s]
        aln.params.sigma_ou = s
        aln.params.duration = dur_comp
        control0[0,0,:500] = 5.
        
        stateswitchcount = 0
        target_rates_e = []
        target_rates_i = []

        for j in range(noise_realizations_target_compute):
            if j % 1000 == 0:
                print(j)
            aln.run(control=control0)
            #plt.plot(aln.t, aln.rates_exc[0,:])
            if np.amin(aln.rates_exc[0,1000:]) < 1.:
                #print("fell in down state, repeat")
                j -= 1
                stateswitchcount += 1
                if stateswitchcount > 0.8 * noise_realizations_target_compute:
                    print("UNSTABLE: point, sigma ", d['point'], s)
                    break
                continue
            target_rates_e.append(aln.rates_exc[0,1000:])
            target_rates_i.append(aln.rates_inh[0,1000:])
        
        #plt.show()            

        aln.params.duration = dur
        target = aln.getZeroTarget()
        target[:,0,:] = np.mean(target_rates_e)
        target[:,1,:] = np.mean(target_rates_i)
        stddev = np.std(target_rates_e) + np.std(target_rates_i)
        
        d['target'][ind_s] = target
        d['cost_params'][ind_s] = [1. / ( stddev * (1. - trans_time) * dur ), 0., 1.]
        
        #print(stddev)
        
    file=open(dict_file, "wb")
    pickle.dump(dict_list, file)
    file.close()
# Out:
# Point =  [0.4  0.35]
# Exception ignored on calling ctypes callback function: <function ExecutionEngine._raw_object_cache_notify at 0x7f847d266040>
# Traceback (most recent call last):
#   File "/home/lena/.local/lib/python3.9/site-packages/llvmlite/binding/executionengine.py", line 171, in _raw_object_cache_notify
#     def _raw_object_cache_notify(self, data):
# KeyboardInterrupt:
# 0
# 1000
# 2000
# 3000
# 4000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_243602/161572449.py in <module>
#      42             if j % 1000 == 0:
#      43                 print(j)
# ---> 44             aln.run(control=control0)
#      45             #plt.plot(aln.t, aln.rates_exc[0,:])
#      46             if np.amin(aln.rates_exc[0,1000:]) < 1.:
#
# ~/Promotion/neurolib_dev_optControl/neurolib/models/model.py in run(self, inputs, chunkwise, chunksize, bold, append, append_outputs, continue_run, control)
#     188         if chunkwise is False:
#     189             if self.name == 'aln':
# --> 190                 self.integrate(append_outputs=append, simulate_bold=bold, control=cntrl)
#     191             else:
#     192                 self.integrate(append_outputs=append, simulate_bold=bold)
#
# ~/Promotion/neurolib_dev_optControl/neurolib/models/model.py in integrate(self, append_outputs, simulate_bold, control)
#     232         #print("before integration")
#     233         if self.name == 'aln':
# --> 234             t, *variables = self.integration(self.params, control=control)
#     235         else:
#     236             t, *variables = self.integration(self.params)
#
# ~/Promotion/neurolib_dev_optControl/neurolib/models/aln/timeIntegration.py in timeIntegration(params, control)
#     279     ext_ei_rate = ap.adjust_shape(params["ext_ei_rate"], rates_exc)
#     280     ext_ie_rate = ap.adjust_shape(params["ext_ie_rate"], rates_exc)
# --> 281     ext_ii_rate = ap.adjust_shape(params["ext_ii_rate"], rates_exc)
#     282
#     283     control_ext = control.copy()
#
# ~/Promotion/neurolib_dev_optControl/neurolib/utils/adjust_params.py in adjust_shape(original, target)
#      36     else:
#      37         rep_x = 1
# ---> 38     original = np.tile(original, (1, rep_x))
#      39
#      40     # cut from end because the beginning can be initial condition
#
# <__array_function__ internals> in tile(*args, **kwargs)
#
# ~/.local/lib/python3.9/site-packages/numpy/lib/shape_base.py in tile(A, reps)
#    1256         for dim_in, nrep in zip(c.shape, tup):
#    1257             if nrep != 1:
# -> 1258                 c = c.reshape(-1, n).repeat(nrep, 0)
#    1259             n //= dim_in
#    1260     return c.reshape(shape_out)
#
# KeyboardInterrupt:

# %%
dict_list[0]['init_vars']
# Out:
# array([ 2.94200403e-001,  1.05247208e+001,  1.05305879e-001,
#         6.33605118e-001,  0.00000000e+000,  5.49219446e-002,
#         6.14592257e-001,  5.15158905e-002,  7.62400120e-001,
#         3.03837318e-003,  7.25371797e-003,  2.68171065e-003,
#         7.42381515e-003,  1.32914953e-176,  9.96862146e-177,
#         1.60924097e+000,  1.53544824e+000, -6.30025667e+001,
#         1.72201118e+001,  5.68735145e+000])

# %%
#len(sigma_array), 4, N_max, max_it

##### METHOD 1
method_ind = 0
step_method_ind = 0

for d in dict_list:
    print("Point = ", d['point'])
    aln.params.ext_exc_current = d['point'][0] * 5.
    aln.params.ext_inh_current = d['point'][1] * 5.
    
    max_it = d['cost'].shape[3]
    
    for s_ind in range(len(d['sigma'])):
        
        print("sigma = ", d['sigma'][s_ind])
        
        s = d['sigma'][s_ind]
        aln.params.sigma_ou = s
        c_p = d['cost_params'][s_ind]
        cost.setParams(c_p[0], c_p[1], c_p[2])
        aln.params.duration = dur
        zero_init = aln.getZeroControl()
        
        target_ = d['target'][s_ind].copy()
        target_[0,0,:int(trans_time * dur / aln.params.dt)] = -1000
        target_[0,1,:int(trans_time * dur / aln.params.dt)] = -1000
        
        if np.amin(d['cost'][s_ind, method_ind, :, 0]) == 0.:
        
            setinit(d['init_vars'], aln)
            cost_final = 0.

            for n_ in range(noise_realizations_final):
                state_ = fo.updateState(aln, zero_init)
                cost_final += cost.numba_cost_precision_int(1, T, dt, d['cost_params'][s_ind][0],
                                                               state_, target_, list(prec_vars) )

            d['cost'][s_ind, :, :, :, 0] = cost_final/noise_realizations_final
            
        print('cost = ', d['cost'][s_ind, 0, 0, 0])    
        
        for i_it in range(1, max_it, 1):
            
            print("iteration = ", i_it)
        
            for n_ind in range(len(d['N_array'])):

                if d['cost'][s_ind, 0, n_ind, -1] > 0.:
                    continue
                    
                n_max = d['N_array'][n_ind]
                print("n max = ", n_max)

                aln.params.duration = dur
                control_init = aln.getZeroControl()

                if i_it <= init_it:
                    c_vars = d['init']
                else:
                    c_vars = [0,1]
                    
                n_ = 0
                control_sum = aln.getZeroControl()
                
                while n_ < n_max:
                
                    print('--------', n_)

                    aln.params.duration = dur
                    setinit(d['init_vars'], aln)

                    bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                        control_init, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_ = i_it,
                        tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                        t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                        control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                        noise_real=0, init_params = d['init_vars'])
                    
                    control_sum += bc[:,:,n_pre:-n_post]
                    n_ += 1

                control_init = control_sum / n_max
        
                aln.params.duration = dur
                setinit(d['init_vars'], aln)

                cost_final = 0.

                for j in range(noise_realizations_final):
                    state_ = fo.updateState(aln, control_init)
                    cost_final += cost.numba_cost_precision_int(1, T, dt, d['cost_params'][s_ind][0],
                                                                   state_, target_, list(prec_vars) )
                    cost_final += cost.numba_cost_sparsity_int(1, 6, T, d['cost_params'][s_ind][2],
                                                                   dt, control_init)

                d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it] = cost_final/noise_realizations_final
                print('cost = ', d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it])
                
                file=open(dict_file, "wb")
                pickle.dump(dict_list, file)
                file.close()
# Out:
# Point =  [0.4  0.35]
# sigma =  0.01
# set cost params:  0.020161370502275046 0.0 1.0
# cost =  1620.1035790293124
# iteration =  1
# iteration =  2
# iteration =  3
# iteration =  4
# iteration =  5
# iteration =  6
# iteration =  7
# iteration =  8
# iteration =  9
# iteration =  10
# iteration =  11
# iteration =  12
# iteration =  13
# iteration =  14
# iteration =  15
# iteration =  16
# iteration =  17
# iteration =  18
# iteration =  19
# iteration =  20
# iteration =  21
# iteration =  22
# iteration =  23
# iteration =  24
# iteration =  25
# iteration =  26
# iteration =  27
# iteration =  28
# iteration =  29
# iteration =  30
# iteration =  31
# iteration =  32
# iteration =  33
# iteration =  34
# iteration =  35
# iteration =  36
# iteration =  37
# iteration =  38
# iteration =  39
# sigma =  0.02
# set cost params:  0.010031022525775904 0.0 1.0
# cost =  802.2909757781794
# iteration =  1
# iteration =  2
# iteration =  3
# iteration =  4
# iteration =  5
# iteration =  6
# iteration =  7
# iteration =  8
# iteration =  9
# iteration =  10
# iteration =  11
# iteration =  12
# iteration =  13
# iteration =  14
# iteration =  15
# iteration =  16
# iteration =  17
# iteration =  18
# iteration =  19
# iteration =  20
# iteration =  21
# iteration =  22
# iteration =  23
# iteration =  24
# iteration =  25
# iteration =  26
# iteration =  27
# iteration =  28
# iteration =  29
# iteration =  30
# iteration =  31
# iteration =  32
# iteration =  33
# iteration =  34
# iteration =  35
# iteration =  36
# iteration =  37
# iteration =  38
# iteration =  39
# sigma =  0.03
# set cost params:  0.006621247555591508 0.0 1.0
# cost =  525.2037107304329
# iteration =  1
# iteration =  2
# iteration =  3
# iteration =  4
# iteration =  5
# iteration =  6
# iteration =  7
# iteration =  8
# iteration =  9
# iteration =  10
# iteration =  11
# iteration =  12
# iteration =  13
# iteration =  14
# iteration =  15
# iteration =  16
# iteration =  17
# iteration =  18
# iteration =  19
# iteration =  20
# iteration =  21
# iteration =  22
# iteration =  23
# iteration =  24
# iteration =  25
# iteration =  26
# iteration =  27
# iteration =  28
# iteration =  29
# iteration =  30
# iteration =  31
# iteration =  32
# iteration =  33
# iteration =  34
# iteration =  35
# iteration =  36
# iteration =  37
# iteration =  38
# iteration =  39
# sigma =  0.04
# set cost params:  0.004883980090759534 0.0 1.0
# cost =  382.05226661394573
# iteration =  1
# iteration =  2
# iteration =  3
# iteration =  4
# iteration =  5
# iteration =  6
# iteration =  7
# iteration =  8
# iteration =  9
# iteration =  10
# iteration =  11
# iteration =  12
# iteration =  13
# iteration =  14
# iteration =  15
# iteration =  16
# iteration =  17
# iteration =  18
# iteration =  19
# iteration =  20
# iteration =  21
# iteration =  22
# iteration =  23
# iteration =  24
# iteration =  25
# iteration =  26
# iteration =  27
# iteration =  28
# iteration =  29
# iteration =  30
# iteration =  31
# iteration =  32
# iteration =  33
# iteration =  34
# iteration =  35
# iteration =  36
# iteration =  37
# iteration =  38
# iteration =  39
# sigma =  0.05
# set cost params:  0.0038007694143633057 0.0 1.0
# cost =  289.63147305608254
# iteration =  1
# iteration =  2
# iteration =  3
# iteration =  4
# iteration =  5
# iteration =  6
# iteration =  7
# iteration =  8
# iteration =  9
# iteration =  10
# iteration =  11
# iteration =  12
# iteration =  13
# iteration =  14
# iteration =  15
# iteration =  16
# iteration =  17
# iteration =  18
# iteration =  19
# iteration =  20
# iteration =  21
# iteration =  22
# iteration =  23
# iteration =  24
# iteration =  25
# iteration =  26
# iteration =  27
# iteration =  28
# iteration =  29
# iteration =  30
# iteration =  31
# iteration =  32
# iteration =  33
# iteration =  34
# iteration =  35
# iteration =  36
# iteration =  37
# iteration =  38
# iteration =  39
# sigma =  0.060000000000000005
# set cost params:  0.0031027349315870777 0.0 1.0
# cost =  223.73248581534745
# iteration =  1
# iteration =  2
# iteration =  3
# iteration =  4
# iteration =  5
# iteration =  6
# iteration =  7
# iteration =  8
# iteration =  9
# iteration =  10
# iteration =  11
# iteration =  12
# iteration =  13
# iteration =  14
# iteration =  15
# iteration =  16
# iteration =  17
# iteration =  18
# iteration =  19
# iteration =  20
# iteration =  21
# iteration =  22
# iteration =  23
# iteration =  24
# iteration =  25
# iteration =  26
# iteration =  27
# iteration =  28
# iteration =  29
# iteration =  30
# iteration =  31
# iteration =  32
# iteration =  33
# iteration =  34
# iteration =  35
# iteration =  36
# iteration =  37
# iteration =  38
# iteration =  39
# sigma =  0.06999999999999999
# set cost params:  0.0026507988833317712 0.0 1.0
# cost =  174.56154512172319
# iteration =  1
# iteration =  2
# iteration =  3
# iteration =  4
# iteration =  5
# iteration =  6
# iteration =  7
# iteration =  8
# iteration =  9
# iteration =  10
# iteration =  11
# iteration =  12
# iteration =  13
# iteration =  14
# iteration =  15
# iteration =  16
# iteration =  17
# iteration =  18
# iteration =  19
# iteration =  20
# iteration =  21
# iteration =  22
# iteration =  23
# iteration =  24
# iteration =  25
# iteration =  26
# iteration =  27
# iteration =  28
# iteration =  29
# iteration =  30
# iteration =  31
# iteration =  32
# iteration =  33
# iteration =  34
# iteration =  35
# iteration =  36
# iteration =  37
# iteration =  38
# iteration =  39
# sigma =  0.08
# set cost params:  0.002341798773127221 0.0 1.0
# cost =  139.07924201005187
# iteration =  1
# iteration =  2
# iteration =  3
# iteration =  4
# iteration =  5
# iteration =  6
# iteration =  7
# iteration =  8
# iteration =  9
# iteration =  10
# iteration =  11
# iteration =  12
# iteration =  13
# iteration =  14
# iteration =  15
# iteration =  16
# iteration =  17
# iteration =  18
# iteration =  19
# iteration =  20
# iteration =  21
# iteration =  22
# iteration =  23
# iteration =  24
# iteration =  25
# iteration =  26
# iteration =  27
# iteration =  28
# iteration =  29
# iteration =  30
# iteration =  31
# iteration =  32
# iteration =  33
# iteration =  34
# iteration =  35
# iteration =  36
# iteration =  37
# iteration =  38
# iteration =  39
# Point =  [0.4 0.4]
# sigma =  0.01
# set cost params:  0.0186528174549039 0.0 1.0
# cost =  1653.973690350716
# iteration =  1
# iteration =  2
# iteration =  3
# iteration =  4
# iteration =  5
# iteration =  6
# iteration =  7
# iteration =  8
# iteration =  9
# iteration =  10
# iteration =  11
# iteration =  12
# iteration =  13
# iteration =  14
# iteration =  15
# iteration =  16
# iteration =  17
# iteration =  18
# iteration =  19
# iteration =  20
# iteration =  21
# iteration =  22
# iteration =  23
# iteration =  24
# iteration =  25
# iteration =  26
# iteration =  27
# iteration =  28
# iteration =  29
# iteration =  30
# iteration =  31
# iteration =  32
# iteration =  33
# iteration =  34
# iteration =  35
# iteration =  36
# iteration =  37
# iteration =  38
# iteration =  39
# sigma =  0.02
# set cost params:  0.009201851130972608 0.0 1.0
# cost =  813.2469635635398
# iteration =  1
# iteration =  2
# iteration =  3
# iteration =  4
# iteration =  5
# iteration =  6
# iteration =  7
# iteration =  8
# iteration =  9
# iteration =  10
# iteration =  11
# iteration =  12
# iteration =  13
# iteration =  14
# iteration =  15
# iteration =  16
# iteration =  17
# iteration =  18
# iteration =  19
# iteration =  20
# iteration =  21
# iteration =  22
# iteration =  23
# iteration =  24
# iteration =  25
# iteration =  26
# iteration =  27
# iteration =  28
# iteration =  29
# iteration =  30
# iteration =  31
# iteration =  32
# iteration =  33
# iteration =  34
# iteration =  35
# iteration =  36
# iteration =  37
# iteration =  38
# iteration =  39
# sigma =  0.03
# set cost params:  0.005940882081947265 0.0 1.0
# cost =  521.3464577162849
# iteration =  1
# iteration =  2
# iteration =  3
# iteration =  4
# iteration =  5
# iteration =  6
# iteration =  7
# iteration =  8
# iteration =  9
# iteration =  10
# iteration =  11
# iteration =  12
# iteration =  13
# iteration =  14
# iteration =  15
# iteration =  16
# iteration =  17
# iteration =  18
# iteration =  19
# iteration =  20
# iteration =  21
# iteration =  22
# iteration =  23
# iteration =  24
# iteration =  25
# iteration =  26
# iteration =  27
# iteration =  28
# iteration =  29
# iteration =  30
# iteration =  31
# iteration =  32
# iteration =  33
# iteration =  34
# iteration =  35
# iteration =  36
# iteration =  37
# iteration =  38
# iteration =  39
# sigma =  0.04
# set cost params:  0.004322503361908931 0.0 1.0
# cost =  375.7984949990708
# iteration =  1
# iteration =  2
# iteration =  3
# iteration =  4
# iteration =  5
# iteration =  6
# iteration =  7
# iteration =  8
# iteration =  9
# iteration =  10
# iteration =  11
# iteration =  12
# iteration =  13
# iteration =  14
# iteration =  15
# iteration =  16
# iteration =  17
# iteration =  18
# iteration =  19
# iteration =  20
# iteration =  21
# iteration =  22
# iteration =  23
# iteration =  24
# iteration =  25
# iteration =  26
# iteration =  27
# iteration =  28
# iteration =  29
# iteration =  30
# iteration =  31
# iteration =  32
# iteration =  33
# iteration =  34
# iteration =  35
# iteration =  36
# iteration =  37
# iteration =  38
# iteration =  39
# sigma =  0.05
# set cost params:  0.0034487750292220656 0.0 1.0
# cost =  297.2439109910928
# iteration =  1
# iteration =  2
# iteration =  3
# iteration =  4
# iteration =  5
# iteration =  6
# iteration =  7
# iteration =  8
# iteration =  9
# iteration =  10
# iteration =  11
# iteration =  12
# iteration =  13
# iteration =  14
# iteration =  15
# iteration =  16
# iteration =  17
# iteration =  18
# iteration =  19
# iteration =  20
# iteration =  21
# iteration =  22
# iteration =  23
# iteration =  24
# iteration =  25
# iteration =  26
# iteration =  27
# iteration =  28
# iteration =  29
# iteration =  30
# iteration =  31
# iteration =  32
# iteration =  33
# iteration =  34
# iteration =  35
# iteration =  36
# iteration =  37
# iteration =  38
# iteration =  39
# sigma =  0.060000000000000005
# set cost params:  0.0029389133316712825 0.0 1.0
# cost =  252.0185197555498
# iteration =  1
# iteration =  2
# iteration =  3
# iteration =  4
# iteration =  5
# iteration =  6
# iteration =  7
# iteration =  8
# iteration =  9
# iteration =  10
# iteration =  11
# iteration =  12
# iteration =  13
# iteration =  14
# iteration =  15
# iteration =  16
# iteration =  17
# iteration =  18
# iteration =  19
# iteration =  20
# iteration =  21
# iteration =  22
# iteration =  23
# iteration =  24
# iteration =  25
# iteration =  26
# iteration =  27
# iteration =  28
# iteration =  29
# iteration =  30
# iteration =  31
# iteration =  32
# iteration =  33
# iteration =  34
# iteration =  35
# iteration =  36
# iteration =  37
# iteration =  38
# iteration =  39
# sigma =  0.06999999999999999
# set cost params:  0.0026006411595522047 0.0 1.0
# cost =  222.46021315883132
# iteration =  1
# iteration =  2
# iteration =  3
# iteration =  4
# iteration =  5
# iteration =  6
# iteration =  7
# iteration =  8
# iteration =  9
# iteration =  10
# iteration =  11
# iteration =  12
# iteration =  13
# iteration =  14
# iteration =  15
# iteration =  16
# iteration =  17
# iteration =  18
# iteration =  19
# iteration =  20
# iteration =  21
# iteration =  22
# iteration =  23
# iteration =  24
# iteration =  25
# iteration =  26
# iteration =  27
# iteration =  28
# iteration =  29
# iteration =  30
# iteration =  31
# iteration =  32
# iteration =  33
# iteration =  34
# iteration =  35
# iteration =  36
# iteration =  37
# iteration =  38
# iteration =  39
# sigma =  0.08
# set cost params:  0.002359447694478544 0.0 1.0
# cost =  200.6514091903836
# iteration =  1
# iteration =  2
# iteration =  3
# iteration =  4
# iteration =  5
# iteration =  6
# iteration =  7
# iteration =  8
# iteration =  9
# iteration =  10
# iteration =  11
# iteration =  12
# iteration =  13
# iteration =  14
# iteration =  15
# iteration =  16
# iteration =  17
# iteration =  18
# iteration =  19
# iteration =  20
# iteration =  21
# iteration =  22
# iteration =  23
# iteration =  24
# iteration =  25
# iteration =  26
# iteration =  27
# iteration =  28
# iteration =  29
# iteration =  30
# iteration =  31
# iteration =  32
# iteration =  33
# iteration =  34
# iteration =  35
# iteration =  36
# iteration =  37
# iteration =  38
# iteration =  39
# Point =  [0.45 0.4 ]
# sigma =  0.01
# set cost params:  0.024618771362587697 0.0 1.0
# cost =  0.2564089247689769
# iteration =  1
# iteration =  2
# iteration =  3
# iteration =  4
# iteration =  5
# iteration =  6
# iteration =  7
# iteration =  8
# iteration =  9
# iteration =  10
# iteration =  11
# iteration =  12
# iteration =  13
# iteration =  14
# iteration =  15
# iteration =  16
# iteration =  17
# iteration =  18
# iteration =  19
# iteration =  20
# iteration =  21
# iteration =  22
# iteration =  23
# iteration =  24
# iteration =  25
# iteration =  26
# iteration =  27
# iteration =  28
# iteration =  29
# iteration =  30
# iteration =  31
# iteration =  32
# iteration =  33
# iteration =  34
# iteration =  35
# iteration =  36
# iteration =  37
# iteration =  38
# iteration =  39
# sigma =  0.02
# set cost params:  0.012309689357182147 0.0 1.0
# cost =  0.5197374343647503
# iteration =  1
# iteration =  2
# iteration =  3
# iteration =  4
# iteration =  5
# iteration =  6
# iteration =  7
# iteration =  8
# iteration =  9
# iteration =  10
# iteration =  11
# iteration =  12
# iteration =  13
# iteration =  14
# iteration =  15
# iteration =  16
# iteration =  17
# iteration =  18
# iteration =  19
# iteration =  20
# iteration =  21
# iteration =  22
# iteration =  23
# iteration =  24
# iteration =  25
# iteration =  26
# iteration =  27
# iteration =  28
# iteration =  29
# iteration =  30
# iteration =  31
# iteration =  32
# iteration =  33
# iteration =  34
# iteration =  35
# iteration =  36
# iteration =  37
# iteration =  38
# iteration =  39
# sigma =  0.03
# set cost params:  0.00819855947523837 0.0 1.0
# cost =  0.7734028531744326
# iteration =  1
# iteration =  2
# iteration =  3
# iteration =  4
# iteration =  5
# iteration =  6
# iteration =  7
# iteration =  8
# iteration =  9
# iteration =  10
# iteration =  11
# iteration =  12
# iteration =  13
# iteration =  14
# iteration =  15
# iteration =  16
# iteration =  17
# iteration =  18
# iteration =  19
# iteration =  20
# iteration =  21
# iteration =  22
# iteration =  23
# iteration =  24
# iteration =  25
# iteration =  26
# iteration =  27
# iteration =  28
# iteration =  29
# iteration =  30
# iteration =  31
# iteration =  32
# iteration =  33
# iteration =  34
# iteration =  35
# iteration =  36
# iteration =  37
# iteration =  38
# iteration =  39
# sigma =  0.04
# set cost params:  0.006144212750369271 0.0 1.0
# cost =  1.0366271982443984
# iteration =  1
# n max =  1
# -------- 0
# interpolate adjoint :  True True True
# initial cost =  0.9621154435602943
# RUN  0 , total integrated cost =  0.9621154435602943
# Gradient descend method:  None
# RUN  1 , total integrated cost =  0.529199673538477
# RUN  1 , total integrated cost =  0.529199673538477
# Improved over  1  iterations in  0.043802577012684196  seconds by  44.99623958012968  percent.
# cost =  1.0364258610838983
# n max =  2
# -------- 0
# interpolate adjoint :  True True True
# initial cost =  1.6470516193854539
# RUN  0 , total integrated cost =  1.6470516193854539
# Gradient descend method:  None
# RUN  1 , total integrated cost =  0.
# Gradient descend method:  None
# RUN  1 , total integrated cost =  0.46012668349597785
# RUN  1 , total integrated cost =  0.46012668349597785
# Improved over  1  iterations in  0.044478220981545746  seconds by  45.078775972916276  percent.
# -------- 4
# interpolate adjoint :  True True True
# initial cost =  0.39583151351526474
# RUN  0 , total integrated cost =  0.39583151351526474
# Gradient descend method:  None
# RUN  1 , total integrated cost =  0.34236631774304843
# RUN  1 , total integrated cost =  0.34236631774304843
# Improved over  1  iterations in  0.0428799630026333  seconds by  13.507058924492256  percent.
# -------- 5
# interpolate adjoint :  True True True
# initial cost =  2.081089387723056
# RUN  0 , total integrated cost =  2.081089387723056
# Gradient descend method:  None
# RUN  1 , total integrated cost =  0.8438417128870062
# RUN  1 , total integrated cost =  0.8438417128870062
# Improved over  1  iterations in  0.038487020996399224  seconds by  59.45192369606655  percent.
# -------- 6
# interpolate adjoint :  True True True
# initial cost =  0.6411979180780232
# RUN  0 , total integrated cost =  0.6411979180780232
# Gradient descend method:  None
# RUN  1 , total integrated cost =  0.5885633390460373
# RUN  1 , total integrated cost =  0.5885633390460373
# Improved over  1  iterations in  0.04778511798940599  seconds by  8.208788199087863  percent.
# -------- 7
# interpolate adjoint :  True True True
# initial cost =  0.7962969418149458
# RUN  0 , total integrated cost =  0.7962969418149458
# Gradient descend method:  None
# RUN  1 , total integrated cost =  0.40620481684086274
# RUN  1 , total integrated cost =  0.40620481684086274
# Improved over  1  iterations in  0.049424749973695725  seconds by  48.988273656429286  percent.
# -------- 8
# interpolate adjoint :  True True True
# initial cost =  0.5191659199654365
# RUN  0 , total integrated cost =  0.5191659199654365
# Gradient descend method:  None
# RUN  1 , total integrated cost =  0.48549069757866337
# RUN  1 , total integrated cost =  0.48549069757866337
# Improved over  1  iterations in  0.08069652295671403  seconds by  6.486408504821554  percent.
# -------- 9
# interpolate adjoint :  True True True
# initial cost =  1.7498051868418734
# RUN  0 , total integrated cost =  1.7498051868418734
# Gradient descend method:  None
# RUN  1 , total integrated cost =  0.5981228083387194
# RUN  1 , total integrated cost =  0.5981228083387194
# Improved over  1  iterations in  0.0431013050256297  seconds by  65.8177485793011  percent.
# -------- 10
# interpolate adjoint :  True True True
# initial cost =  0.6817628440330067
# RUN  0 , total integrated cost =  0.6817628440330067
# Gradient descend method:  None
# RUN  1 , total integrated cost =  0.6368480931874517
# RUN  1 , total integrated cost =  0.6368480931874517
# Improved over  1  iterations in  0.041246020002290606  seconds by  6.588031489052597  percent.
# -------- 11
# interpolate adjoint :  True True True
# initial cost =  0.46850700443223253
# RUN  0 , total integrated cost =  0.46850700443223253
# Gradient descend method:  None
# RUN  1 , total integrated cost =  0.3515434857145288
# RUN  1 , total integrated cost =  0.3515434857145288
# Improved over  1  iterations in  0.04722613003104925  seconds by  24.965159028827713  percent.
# -------- 12
# interpolate adjoint :  True True True
# initial cost =  0.6924112624652962
# RUN  0 , total integrated cost =  0.6924112624652962
# Gradient descend method:  None
# RUN  1 , total integrated cost =  0.507069497424799
# RUN  1 , total integrated cost =  0.507069497424799
# Improved over  1  iterations in  0.04259144503157586  seconds by  26.7675838172529  percent.
# -------- 13
# interpolate adjoint :  True True True
# initial cost =  0.790381018560698
# RUN  0 , total integrated cost =  0.790381018560698
# Gradient descend method:  None
# RUN  1 , total integrated cost =  0.45444530851639986
# RUN  1 , total integrated cost =  0.45444530851639986
# Improved over  1  iterations in  0.04264764202525839  seconds by  42.50300831566588  percent.
# -------- 14
# interpolate adjoint :  True True True
# initial cost =  0.5499522199914554
# RUN  0 , total integrated cost =  0.5499522199914554
# Gradient descend method:  None
# RUN  1 , total integrated cost =  0.48394090182111565
# RUN  1 , total integrated cost =  0.48394090182111565
# Improved over  1  iterations in  0.05245737702352926  seconds by  12.003100591423248  percent.
# -------- 15
# interpolate adjoint :  True True True
# initial cost =  0.993937109174132
# RUN  0 , total integrated cost =  0.993937109174132
# Gradient descend method:  None
# RUN  1 , total integrated cost =  0.5847835035421028
# RUN  1 , total integrated cost =  0.5847835035421028
# Improved over  1  iterations in  0.050808197003789246  seconds by  41.164939094788124  percent.
# -------- 16
# interpolate adjoint :  True True True
# initial cost =  1.7233602125342025
# RUN  0 , total integrated cost =  1.7233602125342025
# Gradient descend method:  None
# RUN  1 , total integrated cost =  0.5948083939326693
# RUN  1 , total integrated cost =  0.5948083939326693
# Improved over  1  iterations in  0.0563353460165672  seconds by  65.48554448416775  percent.
# -------- 17
# interpolate adjoint :  True True True
# initial cost =  0.5445118070666559
# RUN  0 , total integrated cost =  0.5445118070666559
# Gradient descend method:  None
# RUN  1 , total integrated cost =  0.5188913619148088
# RUN  1 , total integrated cost =  0.5188913619148088
# Improved over  1  iterations in  0.03845175099559128  seconds by  4.705213885051876  percent.
# -------- 18
# interpolate adjoint :  True True True
# initial cost =  0.7423552246135214
# RUN  0 , total integrated cost =  0.7423552246135214
# Gradient descend method:  None
# RUN  1 , total integrated cost =  0.5155460050260432
# RUN  1 , total integrated cost =  0.5155460050260432
# Improved over  1  iterations in  0.04202952398918569  seconds by  30.552653509720727  percent.
# -------- 19
# interpolate adjoint :  True True True
# initial cost =  0.8527611296871409
# RUN  0 , total integrated cost =  0.8527611296871409
# Gradient descend method:  None
# RUN  1 , total integrated cost =  0.5006245497767366
# RUN  1 , total integrated cost =  0.5006245497767366
# Improved over  1  iterations in  0.05956944503122941  seconds by  41.29369499282822  percent.
# -------- 20
# interpolate adjoint :  True True True
# initial cost =  1.0839196315472357
# RUN  0 , total integrated cost =  1.0839196315472357
# Gradient descend method:  None
# RUN  1 , total integrated cost =  0.45021967254888734
# RUN  1 , total integrated cost =  0.45021967254888734
# Improved over  1  iterations in  0.048064922040794045  seconds by  58.46374035072845  percent.
# -------- 21
# interpolate adjoint :  True True True
# initial cost =  0.8283959724075712
# RUN  0 , total integrated cost =  0.8283959724075712
# Gradient descend method:  None
# RUN  1 , total integrated cost =  0.4947861501502665
# RUN  1 , total integrated cost =  0.4947861501502665
# Improved over  1  iterations in  0.04662368097342551  seconds by  40.27178225984523  percent.
# -------- 22
# interpolate adjoint :  True True True
# initial cost =  0.7468680844337928
# RUN  0 , total integrated cost =  0.7468680844337928
# Gradient descend method:  None
# RUN  1 , total integrated cost =  0.6755340332957647
# RUN  1 , total integrated cost =  0.6755340332957647
# Improved over  1  iterations in  0.04204671602929011  seconds by  9.551091099589172  percent.
# -------- 23
# interpolate adjoint :  True True True
# initial cost =  1.0402662722475713
# RUN  0 , total integrated cost =  1.0402662722475713
# Gradient descend method:  None
# RUN  1 , total integrated cost =  0.8339208713537382
# RUN  1 , total integrated cost =  0.8339208713537382
# Improved over  1  iterations in  0.0436359359882772  seconds by  19.835825345755836  percent.
# -------- 24
# interpolate adjoint :  True True True
# initial cost =  0.9836863791170553
# RUN  0 , total integrated cost =  0.9836863791170553
# Gradient descend method:  None
# RUN  1 , total integrated cost =  0.5542868110890763
# RUN  1 , total integrated cost =  0.5542868110890763
# Improved over  1  iterations in  0.0429453770047985  seconds by  43.652080291424056  percent.
# -------- 25
# interpolate adjoint :  True True True
# initial cost =  0.6146110845353163
# RUN  0 , total integrated cost =  0.6146110845353163
# Gradient descend method:  None
# RUN  1 , total integrated cost =  0.4785061967029869
# RUN  1 , total integrated cost =  0.4785061967029869
# Improved over  1  iterations in  0.05228375404840335  seconds by  22.14488011312602  percent.
# -------- 26
# interpolate adjoint :  True True True
# initial cost =  1.065500141623688
# RUN  0 , total integrated cost =  1.065500141623688
# Gradient descend method:  None
# RUN  1 , total integrated cost =  0.641657487346368
# RUN  1 , total integrated cost =  0.641657487346368
# Improved over  1  iterations in  0.04092253098497167  seconds by  39.77875156651197  percent.
# -------- 27
# interpolate adjoint :  True True True
# initial cost =  1.614893299013698
# RUN  0 , total integrated cost =  1.614893299013698
# Gradient descend method:  None
# RUN  1 , total integrated cost =  0.6336763129146641
# RUN  1 , total integrated cost =  0.6336763129146641
# Improved over  1  iterations in  0.04639677901286632  seconds by  60.76048409503685  percent.
# -------- 28
# interpolate adjoint :  True True True
# initial cost =  1.4557965078251478
# RUN  0 , total integrated cost =  1.4557965078251478
# Gradient descend method:  None
# RUN  1 , total integrated cost =  0.7548283155755147
# RUN  1 , total integrated cost =  0.7548283155755147
# Improved over  1  iterations in  0.0476677929982543  seconds by  48.15014931563668  percent.
# -------- 29
# interpolate adjoint :  True True True
# initial cost =  0.7297925039976685
# RUN  0 , total integrated cost =  0.7297925039976685
# Gradient descend method:  None
# RUN  1 , total integrated cost =  0.6640547094572308
# RUN  1 , total integrated cost =  0.6640547094572308
# Improved over  1  iterations in  0.04347638599574566  seconds by  9.007737703571664  percent.
# cost =  1.0540174060237466
# iteration =  2
# n max =  1
# -------- 0
# interpolate adjoint :  True True True
# initial cost =  0.5648221877472624
# RUN  0 , total integrated cost =  0.5648221877472624
# Gradient descend method:  None
# RUN  1 , total integrated cost =  0.40020756152798376
# RUN  2 , total integrated cost =  0.5272868250515454
# RUN  2 , total integrated cost =  0.5272868250515454
# Improved over  2  iterations in  0.08660031703766435  seconds by  6.645518449872355  percent.
# cost =  1.0367994206934374
# n max =  2
# -------- 0
# interpolate adjoint :  True True True
# initial cost =  1.4984671296627345
# RUN  0 , total integrated cost =  1.4984671296627345
# Gradient descend method:  None
# RUN  1 , total integrated cost =  0.7791976946282022
# RUN  2 , total integrated cost =  0.5843537888477724
# RUN  2 , total integrated cost =  0.5843537888477724
# Improved over  2  iterations in  0.07431671203812584  seconds by  61.003229414895806  percent.
# -------- 1
# interpolate adjoint :  True True True
# initial cost =
percent.
# -------- 25
# interpolate adjoint :  True True True
# initial cost =  1.0330647955544268
# RUN  0 , total integrated cost =  1.0330647955544268
# Gradient descend method:  None
# RUN  1 , total integrated cost =  0.8310051493980594
# RUN  2 , total integrated cost =  0.8280594013500604
# RUN  2 , total integrated cost =  0.8280594013500604
# Improved over  2  iterations in  0.07409895298769698  seconds by  19.844388763082748  percent.
# -------- 26
# interpolate adjoint :  True True True
# initial cost =  0.840557347859635
# RUN  0 , total integrated cost =  0.840557347859635
# Gradient descend method:  None
# RUN  1 , total integrated cost =  0.6492080530176616
# RUN  2 , total integrated cost =  0.7573048184202369
# RUN  2 , total integrated cost =  0.7573048184202369
# Improved over  2  iterations in  0.06810097396373749  seconds by  9.904443718372022  percent.
# -------- 27
# interpolate adjoint :  True True True
# initial cost =  1.204025601738249
# RUN  0 , total integrated cost =  1.204025601738249
# Gradient descend method:  None
# RUN  1 , total integrated cost =  0.6220859793453162
# RUN  2 , total integrated cost =  0.6338535279488032
# RUN  2 , total integrated cost =  0.6338535279488032
# Improved over  2  iterations in  0.07587008102564141  seconds by  47.355477571763394  percent.
# -------- 28
# interpolate adjoint :  True True True
# initial cost =  0.7774146104052367
# RUN  0 , total integrated cost =  0.7774146104052367
# Gradient descend method:  None
# RUN  1 , total integrated cost =  0.4050203611302289
# RUN  2 , total integrated cost =  0.5305459850529587
# RUN  2 , total integrated cost =  0.5305459850529587
# Improved over  2  iterations in  0.09652097895741463  seconds by  31.755079213599387  percent.
# -------- 29
# interpolate adjoint :  True True True
# initial cost =  0.7816743159803836
# RUN  0 , total integrated cost =  0.7816743159803836
# Gradient descend method:  None
# RUN  1 , total integrated cost =  0.6549239274924027
# RUN  2 , total integrated cost =  0.8178289016196543
# RUN  2 , total integrated cost =  0.8178289016196543
# Improved over  2  iterations in  0.06898241298040375  seconds by  -4.625274861938536  percent.
# cost =  1.0680857189788369
# iteration =  3
# ...
# RUN  12 , total integrated cost =  0.7297696142137992
# RUN  13 , total integrated cost =  0.3474420920411248
# RUN  14 , total integrated cost =  0.39721881409395765
# RUN  15 , total integrated cost =  0.48747361520787413
# RUN  16 , total integrated cost =  0.512372140901133
# RUN  17 , total integrated cost =  0.5638669851919813
# RUN  18 , total integrated cost =  0.45433870330471626
# RUN  19 , total integrated cost =  0.5792529146931701
# RUN  19 , total integrated cost =  0.5792529146931701
# Improved over  19  iterations in  1.628311667998787  seconds by  41.79818018497377  percent.
# -------- 19
# interpolate adjoint :  True True True
# initial cost =  1.5691511191748557
# RUN  0 , total integrated cost =  1.5691511191748557
# Gradient descend method:  None
# RUN  1 , total integrated cost =  0.46599816092999946
# RUN  2 , total integrated cost =  0.5394286054731001
# RUN  3 , total integrated cost =  0.5513712367020094
# RUN  4 , total integrated cost =  0.47706444976804663
# RUN  5 , total integrated cost =  0.5124986458970402
# RUN  6 , total integrated cost =  0.523514491732062
# RUN  7 , total integrated cost =  0.5500547413733852
# RUN  8 , total integrated cost =  0.5471603893185435
# RUN  9 , total integrated cost =  0.5727018250708651
# RUN  10 , total integrated cost =  0.48722936238034087
# RUN  11 , total integrated cost =  0.48148671671837373
# RUN  12 , total integrated cost =  0.5899818996639843
# RUN  13 , total integrated cost =  0.49563221262221985
# Control only changes marginally.
# RUN  13 , total integrated cost =  0.49563221262221985
# Improved over  13  iterations in  1.1050909770419821  seconds by  68.41399107035338  percent.
# -------- 20
# interpolate adjoint :  True True True
# initial cost =  0.5669183580734146
# RUN  0 , total integrated cost =  0.5669183580734146
# Gradient descend method:  None
# RUN  1 , total integrated cost =  0.4583435108937759
# RUN  2 , total integrated cost =  0.517082013979687
# RUN  3 , total integrated cost =  0.5023201466417472
# RUN  4 , total integrated cost =  0.3899891259135259
# RUN  5 , total integrated cost =  0.6074033072155876
# RUN  6 , total integrated cost =  0.41204094088535925
# RUN  7 , total integrated cost =  0.5873418491488878
# RUN  8 , total integrated cost =  0.6018377315560413
# RUN  9 , total integrated cost =  0.5566762148665567
# RUN  10 , total integrated cost =  0.7388758295642135
# RUN  11 , total integrated cost =  0.6069984564535327
# RUN  12 , total integrated cost =  0.6225586477548695
# RUN  13 , total integrated cost =  0.5525361763668515
# RUN  14 , total integrated cost =  0.5754257109329124
# RUN  15 , total integrated cost =  0.4754595945621515
# RUN  16 , total integrated cost =  0.5328284820907081
# RUN  17 , total integrated cost =  0.4258888808792398
# RUN  18 , total integrated cost =  0.5242800558394942
# RUN  19 , total integrated cost =  0.4269939901137537
# RUN  19 , total integrated cost =  0.4269939901137537
# Improved over  19  iterations in  1.2747050049947575  seconds by  24.681572922629016  percent.
# -------- 21
# interpolate adjoint :  True True True
# initial cost =  0.7076846760617094
# RUN  0 , total integrated cost =  0.7076846760617094
# Gradient descend method:  None
# RUN  1 , total integrated cost =  0.328726866457763
# RUN  2 , total integrated cost =  0.37780018185573827
# RUN  3 , total integrated cost =  0.3717895989559179
# RUN  4 , total integrated cost =  0.29129465465296206
# RUN  5 , total integrated cost =  0.4520120513416849
# RUN  6 , total integrated cost =  0.7061337717983619
# RUN  7 , total integrated cost =  0.5209387038731698
# RUN  8 , total integrated cost =  0.44242065551660903
# RUN  9 , total integrated cost =  0.6403974182687351
# RUN  10 , total integrated cost =  0.3681416941423292
# RUN  11 , total integrated cost =  0.47892875760096587
# RUN  12 , total integrated cost =  0.6822064048215835
# RUN  13 , total integrated cost =  0.6072776501556005
# RUN  14 , total integrated cost =  0.7363746059958405
# RUN  15 , total integrated cost =  0.646421185319265
# RUN  16 , total integrated cost =  0.693038123822366
# RUN  17 , total integrated cost =  0.6024995928467518
# RUN  18 , total integrated cost =  0.7734004097201284
# RUN  19 , total integrated cost =  0.6640057656373578
# RUN  19 , total integrated cost =  0.6640057656373578
# Improved over  19  iterations in  1.385840251983609  seconds by  6.172086509973099  percent.
# -------- 22
# interpolate adjoint :  True True True
# initial cost =  0.7301710969222441
# RUN  0 , total integrated cost =  0.7301710969222441
# Gradient descend method:  None
# RUN  1 , total integrated cost =  0.3259605899161528
# RUN  2 , total integrated cost =  0.40640344761841174
# RUN  3 , total integrated cost =  0.3022166266850781
# RUN  4 , total integrated cost =  0.25809469262672474
# RUN  5 , total integrated cost =  0.45464189002550714
# RUN  6 , total integrated cost =  0.44926202833824513
# RUN  7 , total integrated cost =  0.36397001878419166
# RUN  8 , total integrated cost =  0.45711384749232187
# RUN  9 , total integrated cost =  0.3942889427132696
# RUN  10 , total integrated cost =  0.5365867450594055
# RUN  11 , total integrated cost =  0.5341384520500777
# RUN  12 , total integrated cost =  0.824801524883605
# RUN  13 , total integrated cost =  0.6797205942454156
# RUN  14 , total integrated cost =  0.5017160667060376
# RUN  15 , total integrated cost =  0.43180765591169135
# RUN  16 , total integrated cost =  0.5076577142890191
# RUN  17 , total integrated cost =  0.44237441196482963
# RUN  18 , total integrated cost =  0.3827112966219625
# RUN  19 , total integrated cost =  0.46586029622411507
# RUN  19 , total integrated cost =  0.46586029622411507
# Improved over  19  iterations in  1.4817386739887297  seconds by  36.1984748249047  percent.
# -------- 23
# interpolate adjoint :  True True True
# initial cost =  0.5183182675585333
# RUN  0 , total integrated cost =  0.5183182675585333
# Gradient descend method:  None
# RUN  1 , total integrated cost =  0.36660473101803404
# RUN  2 , total integrated cost =  0.348890950260151
# RUN  3 , total integrated cost =  0.5004275030013227
# RUN  4 , total integrated cost =  0.36815749711414325
# RUN  5 , total integrated cost =  0.5132660256308463
# RUN  6 , total integrated cost =  0.5924859468973201
# RUN  7 , total integrated cost =  0.6019873896026873
# RUN  8 , total integrated cost =  0.3876585841375084
# RUN  9 , total integrated cost =  0.5001175831664265
# RUN  10 , total integrated cost =  0.5657820445184175
# RUN  11 , total integrated cost =  0.49516336898707425
# RUN  12 , total integrated cost =  0.7201954877240719
# RUN  13 , total integrated cost =  0.5882269883971425
# RUN  14 , total integrated cost =  0.6330179741024144
# RUN  15 , total integrated cost =  0.5008509295868837
# RUN  16 , total integrated cost =  0.5261691451025605
# RUN  17 , total integrated cost =  0.4884426608881517
# RUN  18 , total integrated cost =  0.6148807973723565
# RUN  19 , total integrated cost =  0.640303164892249
# RUN  19 , total integrated cost =  0.640303164892249
# Improved over  19  iterations in  1.4321320739691146  seconds by  -23.534747850641807  percent.
# -------- 24
# interpolate adjoint :  True True True
# initial cost =  0.9504049665533615
# RUN  0 , total integrated cost =  0.9504049665533615
# Gradient descend method:  None
# RUN  1 , total integrated cost =  0.38305591895053925
# RUN  2 , total integrated cost =  0.45510133287331844
# RUN  3 , total integrated cost =  0.5274900068466521
# RUN  4 , total integrated cost =  0.508631986954904
# RUN  5 , total integrated cost =  0.8110050526331789
# RUN  6 , total integrated cost =  0.4634048065695902
# RUN  7 , total integrated cost =  0.8057692431531995
# RUN  8 , total integrated cost =  0.5321565881272808
# RUN  9 , total integrated cost =  0.7072084829120906
# RUN  10 , total integrated cost =  0.5171294557087055
# RUN  11 , total integrated cost =  0.566558546524693
# RUN  12 , total integrated cost =  0.5519011494646078
# RUN  13 , total integrated cost =  0.5952472739426136
# RUN  14 , total integrated cost =  0.6480475721038474
# RUN  15 , total integrated cost =  0.45273914512764546
# RUN  16 , total integrated cost =  0.5026865587913887
# RUN  17 , total integrated cost =  0.4979897927684428
# RUN  18 , total integrated cost =  0.508550116915902
# RUN  19 , total integrated cost =  0.4786697841795118
# RUN  19 , total integrated cost =  0.4786697841795118
# Improved over  19  iterations in  1.1631050949799828  seconds by  49.635176474781574  percent.
# -------- 25
# interpolate adjoint :  True True True
# initial cost =  0.9246975985041661
# RUN  0 , total integrated cost =  0.9246975985041661
# Gradient descend method:  None
# RUN  1 , total integrated cost =  0.3278515308395998
# RUN  2 , total integrated cost =  0.45183134762983557
# RUN  3 , total integrated cost =  0.4221960838594386
# RUN  4 , total integrated cost =  0.5167380751422509
# RUN  5 , total integrated cost =  0.6977588972397188
# RUN  6 , total integrated cost =  0.5299545424081371
# RUN  7 , total integrated cost =  0.2958958821949116
# RUN  8 , total integrated cost =  0.41064237364452927
# RUN  9 , total integrated cost =  0.6123149635117192
# RUN  10 , total integrated cost =  0.430467974536513
# RUN  11 , total integrated cost =  0.390284033259077
# RUN  12 , total integrated cost =  0.4933029654789617
# RUN  13 , total integrated cost =  0.7158356511540769
# RUN  14 , total integrated cost =  0.6586701745590599
# RUN  15 , total integrated cost =  0.5585889715111789
# RUN  16 , total integrated cost =  0.4123230966502438
# RUN  17 , total integrated cost =  0.6143347311730695
# RUN  18 , total integrated cost =  0.6597323744782209
# RUN  19 , total integrated cost =  0.64071045307351
# RUN  19 , total integrated cost =  0.64071045307351
# Improved over  19  iterations in  1.3470977139659226  seconds by  30.711353191578183  percent.
# -------- 26
# interpolate adjoint :  True True True
# initial cost =  0.5528787070553101
# RUN  0 , total integrated cost =  0.5528787070553101
# Gradient descend method:  None
# RUN  1 , total integrated cost =  0.2952161397110207
# RUN  2 , total integrated cost =  0.3296368744208129
# RUN  3 , total integrated cost =  0.35195105785226277
# RUN  4 , total integrated cost =  0.37692272624715273
# RUN  5 , total integrated cost =  0.4402038862013362
# RUN  6 , total integrated cost =  0.2792756374962459
# RUN  7 , total integrated cost =  0.42269459408292814
# RUN  8 , total integrated cost =  0.559229976412533
# RUN  9 , total integrated cost =  0.6020644639218362
# RUN  10 , total integrated cost =  0.6098589794788177
# RUN  11 , total integrated cost =  0.49817162242001833
# RUN  12 , total integrated cost =  0.44234405167651447
# RUN  13 , total integrated cost =  0.5261187391427619
# RUN  14 , total integrated cost =  0.42754966670122446
# RUN  15 , total integrated cost =  0.6273957371015845
# RUN  16 , total integrated cost =  0.49613348121977896
# RUN  17 , total integrated cost =  0.46733405893206614
# RUN  18 , total integrated cost =  0.4932414504079484
# RUN  19 , total integrated cost =  0.5494177286065739
# RUN  19 , total integrated cost =  0.5494177286065739
# Improved over  19  iterations in  1.354042547987774  seconds by  0.6259923568353116  percent.
# -------- 27
# interpolate adjoint :  True True True
# initial cost =  1.0725809071942598
# RUN  0 , total integrated cost =  1.0725809071942598
# Gradient descend method:  None
# RUN  1 , total integrated cost =  0.5012854630237629
# RUN  2 , total integrated cost =  0.38640086328552603
# RUN  3 , total integrated cost =  0.4157367990790404
# RUN  4 , total integrated cost =  0.3517197845528912
# RUN  5 , total integrated cost =  0.5821361079826721
# RUN  6 , total integrated cost =  0.4457826339889411
# RUN  7 , total integrated cost =  0.6724170783190675
# RUN  8 , total integrated cost =  0.7445291738001754
# RUN  9 , total integrated cost =  0.7179545137366184
# RUN  10 , total integrated cost =  0.8239486165269378
# RUN  11 , total integrated cost =  0.7105019747972972
# RUN  12 , total integrated cost =  0.6571556441015182
# RUN  13 , total integrated cost =  0.6978455561526564
# RUN  14 , total integrated cost =  0.5554628255734021
# RUN  15 , total integrated cost =  0.4626350052868954
# RUN  16 , total integrated cost =  0.31077131640474565
# RUN  17 , total integrated cost =  0.6407304368193132
# RUN  18 , total integrated cost =  0.5029836737522602
# RUN  19 , total integrated cost =  0.343204348471135
# RUN  19 , total integrated cost =  0.343204348471135
# Improved over  19  iterations in  1.5362634779885411  seconds by  68.00200841082324  percent.
# -------- 28
# interpolate adjoint :  True True True
# initial cost =  1.2499381512836565
# RUN  0 , total integrated cost =  1.2499381512836565
# Gradient descend method:  None
# RUN  1 , total integrated cost =  0.39931130348685634
# RUN  2 , total integrated cost =  0.5394622494232774
# RUN  3 , total integrated cost =  0.5216808675038304
# RUN  4 , total integrated cost =  0.6616301012929463
# RUN  5 , total integrated cost =  0.5086472996442891
# RUN  6 , total integrated cost =  0.6528905525811678
# RUN  7 , total integrated cost =  0.4995110525872345
# RUN  8 , total integrated cost =  0.6664855702916195
# RUN  9 , total integrated cost =  0.7479066858238097
# RUN  10 , total integrated cost =  0.7163197306181877
# Control only changes marginally.
# RUN  10 , total integrated cost =  0.7163197306181877
# Improved over  10  iterations in  0.7851567919715308  seconds by  42.69158598907118  percent.
# -------- 29
# interpolate adjoint :  True True True
# initial cost =  0.6848009698573337
# RUN  0 , total integrated cost =  0.6848009698573337
# Gradient descend method:  None
# RUN  1 , total integrated cost =  0.5426302396710827
# RUN  2 , total integrated cost =  0.33481436441903384
# RUN  3 , total integrated cost =  0.4984610877690864
# RUN  4 , total integrated cost =  0.570053284073523
# RUN  5 , total integrated cost =  0.48367885902957536
# RUN  6 , total integrated cost =  0.4064272234202213
# RUN  7 , total integrated cost =  0.501947727179951
# RUN  8 , total integrated cost =  0.5510542457338571
# RUN  9 , total integrated cost =  0.40306854142307363
# RUN  10 , total integrated cost =  0.40858016625367743
# RUN  11 , total integrated cost =  0.6708638515028775
# RUN  12 , total integrated cost =  0.438079362687773
# RUN  13 , total integrated cost =  0.6255301972687457
# RUN  14 , total integrated cost =  0.38786701129495654
# RUN  15 , total integrated cost =  0.33589954701570635
# RUN  16 , total integrated cost =  0.5145876279380439
# RUN  17 , total integrated cost =  0.48112539224182643
# RUN  18 , total integrated cost =  0.5481213044516074
# RUN  19 , total integrated cost =  0.5689462566515456
# RUN  19 , total integrated cost =  0.5689462566515456
# Improved over  19  iterations in  1.489897483959794  seconds by  16.91801243066645  percent.
# cost =  1.0506810400671565
# iteration =  20
# n max =  1
# -------- 0
# interpolate adjoint :  True True True
# initial cost =  0.5043919306107889
# RUN  0 , total integrated cost =  0.5043919306107889
# Gradient descend method:  None
# RUN  1 , total integrated cost =  0.3922872929618419
# RUN  2 , total integrated cost =  0.4853496028280734
# RUN  3 , total integrated cost =  0.4153298090729902
# RUN  4 , total integrated cost =  0.5814717921063378
# RUN  5 , total integrated cost =  0.4936523883393262
# RUN  6 , total integrated cost =  0.4401702253627652
# RUN  7 , total integrated cost =  0.47225511401983344
# RUN  8 , total integrated cost =  0.6355676129393248
# RUN  9 , total integrated cost =  0.3883852104194101
# RUN  10 , total integrated cost =  0.3753518621641967
# RUN  11 , total integrated cost =  0.5884970765747397
# RUN  12 , total integrated cost =  0.4844387573009582
# RUN  13 , total integrated cost =  0.48185817382757806
# RUN  14 , total integrated cost =  0.678567818495363
# RUN  15 , total integrated cost =  0.44065925009274326
# RUN  16 , total integrated cost =  0.30617241038800647
# RUN  17 , total integrated cost =  0.6876120991770706
# RUN  18 , total integrated cost =  0.7616388123975321
# RUN  19 , total integrated cost =  0.32197438778260656
# RUN  20 , total integrated cost =  0.7703723748192269
# RUN  20 , total integrated cost =  0.7703723748192269
# Improved over  20  iterations in  1.3226433480158448  seconds by  -52.73289045016071  percent.

# %%
#len(sigma_array), 4, N_max, max_it

##### METHOD 2
method_ind = 1
step_method_ind = 0

for d in dict_list:
    print("Point = ", d['point'])
    aln.params.ext_exc_current = d['point'][0] * 5.
    aln.params.ext_inh_current = d['point'][1] * 5.
    
    max_it = d['cost'].shape[3]
    
    for s_ind in range(len(d['sigma'])):
        
        print("sigma = ", d['sigma'][s_ind])
        
        s = d['sigma'][s_ind]
        aln.params.sigma_ou = s
        c_p = d['cost_params'][s_ind]
        cost.setParams(c_p[0], c_p[1], c_p[2])
        
        target_ = d['target'][s_ind].copy()
        target_[0,0,:int(trans_time * dur / aln.params.dt)] = -1000
        target_[0,1,:int(trans_time * dur / aln.params.dt)] = -1000
                
        for n_ind in range(len(d['N_array'])):
            
            if d['cost'][s_ind, method_ind, step_method_ind, n_ind, -1] > 0.:
                continue
            
            n_ = d['N_array'][n_ind]
            
            print("n = ", n_)
            aln.params.duration = dur
            control_init = aln.getZeroControl()
        
            for i_it in range(1, max_it, 1):
                
                print("iteration = ", i_it)

                if i_it <= init_it:
                    c_vars = d['init']
                else:
                    c_vars = [0,1]
                    
                aln.params.duration = dur
                setinit(d['init_vars'], aln)
                
                bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                    control_init, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_ = 1,
                    tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                    t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                    control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                    noise_real=n_, init_params = d['init_vars'], method='M2')
    
                control_init = bc[:,:,n_pre:-n_post]
        
                aln.params.duration = dur
                setinit(d['init_vars'], aln)

                cost_final = 0.
                
                for j in range(noise_realizations_final):
                    state_ = fo.updateState(aln, control_init)
                    cost_final += cost.numba_cost_precision_int(1, T, dt, d['cost_params'][s_ind][0],
                                                                   state_, target_, list(prec_vars) )
                    cost_final += cost.numba_cost_sparsity_int(1, 6, T, d['cost_params'][s_ind][2],
                                                                   dt, control_init)
                    
                d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it] = cost_final/noise_realizations_final
                print('cost = ', d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it])
                
                file=open(dict_file, "wb")
                pickle.dump(dict_list, file)
                file.close()

# %%
#len(sigma_array), 4, N_max, max_it

##### METHOD 3
method_ind = 2
step_method_ind = 0

for d in dict_list:
    print("Point = ", d['point'])
    aln.params.ext_exc_current = d['point'][0] * 5.
    aln.params.ext_inh_current = d['point'][1] * 5.
    
    max_it = d['cost'].shape[3]
    
    for s_ind in range(len(d['sigma'])):
        
        print("sigma = ", d['sigma'][s_ind])
        
        s = d['sigma'][s_ind]
        aln.params.sigma_ou = s
        c_p = d['cost_params'][s_ind]
        cost.setParams(c_p[0], c_p[1], c_p[2])
        
        target_ = d['target'][s_ind].copy()
        target_[0,0,:int(trans_time * dur / aln.params.dt)] = -1000
        target_[0,1,:int(trans_time * dur / aln.params.dt)] = -1000
                
        for n_ind in range(len(d['N_array'])):
            
            if d['cost'][s_ind, method_ind, step_method_ind, n_ind, -1] > 0.:
                continue
            
            n_ = d['N_array'][n_ind]
            
            print("n = ", n_)
            aln.params.duration = dur
            control_init = aln.getZeroControl()
        
            for i_it in range(1, max_it, 1):
                
                print("iteration = ", i_it)

                if i_it <= init_it:
                    c_vars = d['init']
                else:
                    c_vars = [0,1]
                    
                aln.params.duration = dur
                setinit(d['init_vars'], aln)

                bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                    control_init, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_ = 1,
                    tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                    t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                    control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                    noise_real=n_, init_params = d['init_vars'], method='M3')
    
                control_init = bc[:,:,n_pre:-n_post]
        
                aln.params.duration = dur
                setinit(d['init_vars'], aln)

                cost_final = 0.
                
                for j in range(noise_realizations_final):
                    state_ = fo.updateState(aln, control_init)
                    cost_final += cost.numba_cost_precision_int(1, T, dt, d['cost_params'][s_ind][0],
                                                                   state_, target_, list(prec_vars) )
                    cost_final += cost.numba_cost_sparsity_int(1, 6, T, d['cost_params'][s_ind][2],
                                                                   dt, control_init)
                    
                d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it] = cost_final/noise_realizations_final
                print('cost = ', d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it])
                
                file=open(dict_file, "wb")
                pickle.dump(dict_list, file)
                file.close()
# Out:
# Point =  [0.4  0.35]
# sigma =  0.01
# set cost params:  0.020161370502275046 0.0 1.0
# n =  1
# iteration =  1
# start
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1614.1776865097024
# Gradient descend method:  None
# RUN  1 , total integrated cost =  266.65677994008666
# RUN  1 , total integrated cost mean =  266.65677994008666
# Improved over  1  iterations in  6.514188711007591  seconds by  83.48033291696206  percent.
# /home/lena/.local/lib/python3.9/site-packages/numba/core/ir_utils.py:2119: NumbaPendingDeprecationWarning:
# Encountered the use of a type that is scheduled for deprecation: type 'reflected list' found for argument 'var_' of function 'numba_cost_precision_int'.
#
# For more information visit https://numba.pydata.org/numba-doc/latest/reference/deprecation.html#deprecation-of-reflection-for-list-and-set-types
#
# File "../../../../neurolib/utils/costFunctions.py", line 79:
# @numba.njit
# def numba_cost_precision_int(N, T, dt, i_p, state_, target_state_, var_):
# ^
#
#   warnings.warn(NumbaPendingDeprecationWarning(msg, loc=loc))
# cost =  259.55719603073453
# iteration =  2
# start
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  256.280815572712
# Gradient descend method:  None
# RUN  1 , total integrated cost =  90.4501805042274

# %%
#len(sigma_array), 4, N_max, max_it

##### METHOD 4
method_ind = 3
step_method_ind = 0

for d in dict_list:
    print("Point = ", d['point'])
    aln.params.ext_exc_current = d['point'][0] * 5.
    aln.params.ext_inh_current = d['point'][1] * 5.
    
    max_it = d['cost'].shape[3]
    
    for s_ind in range(len(d['sigma'])):
        
        print("sigma = ", d['sigma'][s_ind])
        
        s = d['sigma'][s_ind]
        aln.params.sigma_ou = s
        c_p = d['cost_params'][s_ind]
        cost.setParams(c_p[0], c_p[1], c_p[2])
        
        target_ = d['target'][s_ind].copy()
        target_[0,0,:int(trans_time * dur / aln.params.dt)] = -1000
        target_[0,1,:int(trans_time * dur / aln.params.dt)] = -1000
                
        for n_ind in range(len(d['N_array'])):
            
            if d['cost'][s_ind, method_ind, step_method_ind, n_ind, -1] > 0.:
                continue
            
            n_ = d['N_array'][n_ind]
            
            print("n = ", n_)
            aln.params.duration = dur
            control_init = aln.getZeroControl()
        
            for i_it in range(1, max_it, 1):
                
                print("iteration = ", i_it)

                if i_it <= init_it:
                    c_vars = d['init']
                else:
                    c_vars = [0,1]
                    
                aln.params.duration = dur
                setinit(d['init_vars'], aln)

                bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                    control_init, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_ = 1,
                    tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                    t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                    control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                    noise_real=n_, init_params = d['init_vars'], method='M4')
    
                control_init = bc[:,:,n_pre:-n_post]
        
                aln.params.duration = dur
                setinit(d['init_vars'], aln)

                cost_final = 0.
                
                for j in range(noise_realizations_final):
                    state_ = fo.updateState(aln, control_init)
                    cost_final += cost.numba_cost_precision_int(1, T, dt, d['cost_params'][s_ind][0],
                                                                   state_, target_, list(prec_vars) )
                    cost_final += cost.numba_cost_sparsity_int(1, 6, T, d['cost_params'][s_ind][2],
                                                                   dt, control_init)
                    
                d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it] = cost_final/noise_realizations_final
                print('cost = ', d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it])
                
                file=open(dict_file, "wb")
                pickle.dump(dict_list, file)
                file.close()

# %%
p = dict_list[0]

fig, ax = plt.subplots(figsize=(10,8))
for n_ind in range(len(d['N_array'])):
    n_ = d['N_array'][n_ind]
    ax.plot(np.arange(1, p['cost'].shape[3]), p['cost'][0, 0, n_ind, 1:], linestyle='', marker='x',
            label=r'$N=$'+'{}'.format(n_))

ax.set_title("METHOD 1")
ax.legend()
ax.set_yscale('log')
plt.show()
