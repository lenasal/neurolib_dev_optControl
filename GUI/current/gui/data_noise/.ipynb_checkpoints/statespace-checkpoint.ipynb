# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import sys
import pickle
import matplotlib

path = os.getcwd().split(os.sep + 'GUI')[0]
if path not in sys.path:
    sys.path.append(path)

from neurolib.models.aln import ALNModel
import neurolib.dashboard.layout as layout
import neurolib.dashboard.data as data


    
# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2 

#path = os.path.join(os.getcwd(), "plots")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
aln = ALNModel()
N = aln.params.N

data.set_parameters(aln)

##############################################################
def setinit(init_vars_, model):
    state_vars = model.state_vars
    init_vars = model.init_vars
    for iv in range(len(init_vars)):
        for sv in range(len(state_vars)):
            if state_vars[sv] in init_vars[iv]:
                #print("set init vars ", )
                if model.params[init_vars[iv]].ndim == 2:
                    model.params[init_vars[iv]][0,:] = init_vars_[sv]
                else:
                    model.params[init_vars[iv]][0] = init_vars_[sv]

# %%
##### LOAD BOUNDARIES
data_file = '..' + os.sep + 'bi.pickle'
with open(data_file,'rb') as f:
    load_array= pickle.load(f)
exc = load_array[0]
inh = load_array[1]

# %%
bestControl = [None] * len(exc)
bestState = [None] * len(exc)
cost_ = [None] * len(exc)
runtime = [None] * len(exc)
grad = [None] * len(exc)
phi = [None] * len(exc)
costnode = [None] * len(exc)
weights = [None] * len(exc)

conv = [[False]*2] * len(exc)

# %%
initVars = [None] * len(exc)
target = [None] * len(exc)
cost_uncontrolled = [None] * len(exc)

cgv_list = [None, "HS", "FR", "PR", "CD", "LS", "DY", "WYL", "HZ", None]

# %%
dur_pre = 10
dur_post = 10

n_pre = int(np.around(dur_pre/aln.params.dt + 1.,1))
n_post = int(np.around(dur_post/aln.params.dt + 1.,1))

tol = 1e-32
start_step = 10.
c_scheme = np.zeros(( 1,1 ))
c_scheme[0,0] = 1.
u_mat = np.identity(1)
u_scheme = np.array([[1.]])

### CURRENTS
cntrl_vars_0 = [0,1]
prec_vars = [0]

dur = 500
trans_time = 0.95
maxC = [5., -5., 0.18, 0.]
n_dur = int(np.around(dur/aln.params.dt + 1.,1))
max_cntrl, min_cntrl = setmaxmincontrol(maxC[0], maxC[1], maxC[2], maxC[3])

case = '1'

if case == '1':
    max_I = [3., -3.]
    factor_ws = 1.
    factor_we = 0.
    read_file = '..' + os.sep + 'data_final_2' + os.sep + 'control_1.pickle'

# %%
final_file = 'control_' + case + '.pickle'

# %%
if os.path.isfile(read_file) :
    print("file found")
    
    with open(read_file,'rb') as f:
        load_array = pickle.load(f)

    bestControl = load_array[0]
    bestState = load_array[1]
    cost_ = load_array[2]
    costnode = load_array[3]
    weights = load_array[4]
# Out:
# file found

# %%
i_range = range(83)
# without noise/ with noise // low/ high // exc/ inh // value/ std dev
stable_state = np.zeros(( len(exc), 2,2,2, 2))

# %%
# get init vars without noise

data.set_parameters(aln)
aln.params.duration = 3000.

control0 = functions.step_control(aln, maxI_ = max_I[1])

# low state without noise
for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.

    aln.run(control=control0)

    init_state_vars = np.zeros(( len(state_vars) ))
    for j in range(len(state_vars)):
        if aln.state[state_vars[j]].size == 1:
            init_state_vars[j] = aln.state[state_vars[j]][0]
        else:
            init_state_vars[j] = aln.state[state_vars[j]][0,-1]

    initVars[i] = init_state_vars
    
    stable_state[i,0,0,0,0] = aln.rates_exc[0,-1]
    stable_state[i,0,0,1,0] = aln.rates_exc[0,-1]

# high state without noise
control0 = aln.getZeroControl()
control0[0,0,:500] = 5.

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.

    aln.params.duration = 3000.
    aln.run(control=control0)
    stable_state[i][0,1,0,0] = aln.rates_exc[0,-1]
    stable_state[i][0,1,1,0] = aln.rates_exc[0,-1]
    
    aln.params.duration = dur
    target_det = aln.getZeroTarget()
    target_det[:,0,:] = aln.rates_exc[0,-1]
    target_det[:,1,:] = aln.rates_inh[0,-1]
    
    print(stable_state[i,0,0,0,0], stable_state[i,0,1,0,0])
# Out:
# -------  20 0.4500000000000001 0.4750000000000002
# -------  20 0.4500000000000001 0.4750000000000002
# 0.00020800079839487667 35.69070596632364

# %%
# get initial parameters and target states with noise

sigma_ou = 0.1

# set target with noise
aln.params.sigma_ou = sigma_ou
aln.params.duration = 300.
control0 = aln.getZeroControl()
control0[0,0,:500] = 5.

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.

    target_rates_e = []
    target_rates_i = []

    for j in range(100):
        aln.params.duration = 300.
        aln.run(control=control0)
        target_rates_e.append(aln.rates_exc[0,1000:])
        target_rates_i.append(aln.rates_inh[0,1000:])

    aln.params.duration = dur
    target[i] = aln.getZeroTarget()
    target[i][:,0,:] = np.mean(target_rates_e)
    target[i][:,1,:] = np.mean(target_rates_i)
    
    stable_state[i,1,1,0,0] = target[i][0,0,-1]
    stable_state[i,1,1,1,0] = target[i][0,1,-1]
    stable_state[i,1,1,0,1] = np.std(target_rates_e)
    stable_state[i,1,1,1,1] = np.std(target_rates_i)
    
aln.params.duration = 300.
control0 = aln.getZeroControl()
control0[0,0,:500] = -5.

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.

    target_rates_e = []
    target_rates_i = []
    
    found_low = False
    
    while not found_low:

        for j in range(100):
            aln.params.duration = 300.
            aln.run(control=control0)
            target_rates_e.append(aln.rates_exc[0,1000:])
            target_rates_i.append(aln.rates_inh[0,1000:])

        stable_state[i,1,0,0,0] = np.mean(target_rates_e)
        stable_state[i,1,0,1,0] = np.mean(target_rates_i)
        stable_state[i,1,0,0,1] = np.std(target_rates_e)
        stable_state[i,1,0,1,1] = np.std(target_rates_i)
    
        if np.abs(stable_state[i,1,0,0,0] - stable_state[i,1,1,0,0]) > 5.:
            found_low = True
        else:
            print("repeat")
# Out:
# -------  20 0.4500000000000001 0.4750000000000002
# -------  20 0.4500000000000001 0.4750000000000002

# %%
diff_low = np.zeros(( 83,2 ))
diff_high = np.zeros(( 83,2 ))

for i in i_range:
    print('------  ', i)
    diff_low[i,:] = [stable_state[i][0,0,0,0] - stable_state[i,1,0,0,0],
                stable_state[i,0,0,1,0] - stable_state[i,1,0,1,0]]
    print("difference in low rate exc/ inh: ", diff_low[i,:])
    print("std dev low rate exc/ inh: ", stable_state[i,1,0,0,1], stable_state[i,1,0,1,1])
    diff_high[i,:] =  [stable_state[i,0,1,0,0] - stable_state[i,1,1,0,0],
                 stable_state[i,0,1,1,0] - stable_state[i,1,1,1,0]]
    print("difference in high rate exc/ inh: ", diff_high[i,:])
    print("std dev high rate exc/ inh: ", stable_state[i,1,1,0,1], stable_state[i,1,1,1,1])
# Out:
# ------   20
# difference in low rate exc/ inh:  [ 2.82885620e-05 -2.23285804e+01]
# std dev low rate exc/ inh:  0.00014502544368102778 1.2442288453702133
# difference in high rate exc/ inh:  [  0.09800178 -54.6444944 ]
# std dev high rate exc/ inh:  1.6881094210506913 1.3260668577462176

# %%
print("Max/ min / min abs diff low rate EXC",
      np.amax(diff_low[:,0]), np.amin(diff_low[:,0]), np.amin(np.abs(diff_low[:,0])))
print("Max/ min / min abs diff low rate INH",
      np.amax(diff_low[:,1]), np.amin(diff_low[:,1]), np.amin(np.abs(diff_low[:,1])))
print("Max/ min / min abs diff high rate EXC",
      np.amax(diff_high[:,0]), np.amin(diff_high[:,0]), np.amin(np.abs(diff_high[:,0])))
print("Max/ min / min abs diff high rate INH",
      max(diff_high[:,1]), min(diff_high[:,1]), np.amin(np.abs(diff_high[:,1])))
print('---')
for i in i_range:
    if diff_high[i,0] < 0.:
        print(i, diff_high[i], ' low ', stable_state[i,1,0,:,0], 'high ', stable_state[i,1,1,:,0])
print('---')
for i in i_range:
    if diff_high[i,1] > 0.:
        print(i, diff_high[i], ' low ', stable_state[i,1,0,:,0], 'high ', stable_state[i,1,1,:,0])
# Out:
# Max/ min / min abs diff low rate EXC -2.9820396567182916e-10 -20.934897184687046 2.9820396567182916e-10
# Max/ min / min abs diff low rate INH -12.305346254794044 -57.91127478289579 12.305346254794044
# Max/ min / min abs diff high rate EXC 12.862420473862809 -0.13660575936309982 0.0003875944818219068
# Max/ min / min abs diff high rate INH -25.719857004057573 -85.21796014711214 25.719857004057573
# ---
# 7 [ -0.06008432 -43.30098085]  low  [ 4.16553945 23.38504348] high  [37.01772492 80.25862145]
# 8 [ -0.11409915 -38.63208227]  low  [21.46827879 50.24494579] high  [42.54157082 81.05955393]
# 12 [ -0.13660576 -42.52173327]  low  [ 5.92622867 27.9963463 ] high  [42.16423388 84.5493614 ]
# 23 [ -0.09947462 -41.55325001]  low  [13.74517362 43.85933628] high  [51.38377784 92.83755323]
# 57 [-9.17483218e-03 -7.09954599e+01]  low  [2.95490803e-06 4.59687630e+01] high  [ 39.71056327 110.69684832]
# 80 [-3.87594482e-04 -7.19065822e+01]  low  [1.52091160e-04 5.76637581e+01] high  [ 49.41386927 121.32006392]
# ---

# %%
i_range = np.arange(0,90,10)
i_range = [20]

data.set_parameters(aln)
aln.params.duration = 3000.

control0 = aln.getZeroControl()
control0 = functions.step_control(aln, maxI_ = 0.)#max_I[1])

# set init vars without noise
for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    aln.params.sigma_ou = 0.
    setinit(initVars[i], aln)
    aln.run(control=control0)
    
    plt.plot(aln.t, aln.rates_exc[0,:], color='red')
    plt.plot(aln.t, aln.rates_inh[0,:], color='blue')
    plt.plot(aln.t, [target[i][0,0,0]]*len(aln.t), color='black', linestyle='--')
    plt.plot(aln.t, [target[i][0,1,0]]*len(aln.t), color='black', linestyle='--')
    plt.show()

    aln.params.sigma_ou = 0.1
    setinit(initVars[i], aln)
    aln.run(control=control0)
    plt.plot(aln.t, aln.rates_exc[0,:], color='red')
    plt.plot(aln.t, aln.rates_inh[0,:], color='blue')
    plt.plot(aln.t, [target[i][0,0,0]]*len(aln.t), color='black', linestyle='--')
    plt.plot(aln.t, [target[i][0,1,0]]*len(aln.t), color='black', linestyle='--')
    plt.show()
# Out:
# -------  20 0.4500000000000001 0.4750000000000002

# %%
with open(read_file,'rb') as f:
    load_array = pickle.load(f)
load_control = load_array[0].copy()
load_costnode = load_array[3].copy()

array_mult = [0.6, 0.7, 0.8, 0.9, 1., 1.1, 1.2, 1.3, 1.4, 1.5]
cost_pr = np.zeros(( 83, len(array_mult) ))

for i in i_range:

    data.set_parameters(aln)
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    aln.params.sigma_ou = 0.1
    aln.params.duration = 500.

    for j in range(len(array_mult)):
        
        factor_mult = array_mult[j]
        load_control[i] *= factor_mult

        setinit(initVars[i], aln)
        
        control0 = aln.getZeroControl()
        control0 = load_control[i][:,:,n_pre-1:-n_post+1]  
        cost.setParams(1., 0., 1.)
        
        max_it = 0
    
        load_control[i], st, c, r, g, p, costnode_ = aln.A1(
            control0, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it,
            tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
            t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
            control_variables_ = [0,1], prec_variables_ = prec_vars, transition_time_ = trans_time,
            noise_real=1000, init_params = initVars[i])
        
        cost_pr[i][j] = costnode_[0][0][0]
# Out:
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  306070.03508568456
# Gradient descend method:  None
# RUN  0 , total integrated cost mean =  306070.03508568456
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# Problem in initial value trasfer pre:  tau_inh 2.579224009625812 3.559712051928189
# Problem in initial value trasfer post:  tau_inh 2.78558176549395 2.9463864762502157
# Problem in initial value trasfer pre:  tau_inh 3.058822982660894 2.6980389173217687
# Problem in initial value trasfer post:  tau_inh 2.4282766463800027 3.236161412635011
# Problem in initial value trasfer pre:  tau_inh 2.654677333259364 3.7026849766802186
# Problem in initial value trasfer post:  tau_inh 2.4398056557896655 3.704144183056336
# Problem in initial value trasfer pre:  tau_inh 3.021765152644445 3.6805434730017965
# Problem in initial value trasfer post:  tau_inh 2.491974955599391 4.237941068431816
# Problem in initial value trasfer pre:  tau_inh 2.5345168178056334 3.891754072160395
# Problem in initial value trasfer post:  tau_inh 1.7744728378866785 4.653022536495728
# Problem in initial value trasfer pre:  tau_inh 3.056606073312187 2.9790481067531536
# Problem in initial value trasfer post:  tau_inh 2.00497881095942 4.111922138655582
# Problem in initial value trasfer pre:  tau_inh 2.4509781086483646 3.5716231980977753
# Problem in initial value trasfer post:  tau_inh 2.6596778438654485 3.9333066107880823
# Problem in initial value trasfer pre:  tau_inh 2.7510925276689835 3.7048162640236906
# Problem in initial value trasfer post:  tau_inh 4.398739486947845 1.956737572283429
# Problem in initial value trasfer pre:  tau_inh 1.8922401091814154 4.646116772246203
# Problem in initial value trasfer post:  tau_inh 3.921705244704259 3.0026759664955125
# Problem in initial value trasfer pre:  tau_inh 3.359561655640889 3.7793175050008294
# Problem in initial value trasfer post:  tau_inh 2.863080810508904 3.2314548630241746
# Problem in initial value trasfer pre:  tau_inh 2.064190800856986 4.521143625118098
# Problem in initial value trasfer post:  tau_inh 1.927976379746096 3.9060637293457634
# Problem in initial value trasfer pre:  tau_inh 2.543676630404316 3.886235575687268
# Problem in initial value trasfer post:  tau_inh 2.6901708926245798 3.560408910490649
# Problem in initial value trasfer pre:  tau_inh 2.228579891972463 3.616648636017241
# Problem in initial value trasfer post:  tau_inh 4.927071798221335 2.3292701580697392
# Problem in initial value trasfer pre:  tau_inh 2.126948210502842 4.631285674207358
# Problem in initial value trasfer post:  tau_inh 2.347083381895823 3.5500674951971063
# Problem in initial value trasfer pre:  tau_inh 2.5234915864439103 4.1732205886699365
# Problem in initial value trasfer post:  tau_inh 2.3364466649229074 4.775234291216591
# Problem in initial value trasfer pre:  tau_inh 2.821627051381735 3.5020883296544496
# Problem in initial value trasfer post:  tau_inh 2.2173641215070976 3.8425392974225385
# Problem in initial value trasfer pre:  tau_inh 4.055975160246207 2.45243516413972
# Problem in initial value trasfer post:  tau_inh 1.9034946439808085 4.404303467183469
# Problem in initial value trasfer pre:  tau_inh 3.3567520153419053 2.8322763414043655
# Problem in initial value trasfer post:  tau_inh 2.6444178649139136 4.106031286575909
# Problem in initial value trasfer pre:  tau_inh 2.3153756177414646 4.00793240385092
# Problem in initial value trasfer post:  tau_inh 2.4752612263967597 3.15626300617203
# Problem in initial value trasfer pre:  tau_inh 2.7517844754360095 3.5574854016626953
# Problem in initial value trasfer post:  tau_inh 2.7681044715721863 3.8353241493755563
# Problem in initial value trasfer pre:  tau_inh 3.868840593985489 2.673197334113032
# Problem in initial value trasfer post:  tau_inh 3.7286767361022224 2.3271025976104296
# Problem in initial value trasfer pre:  tau_inh 3.316467567749743 2.969385455488894
# Problem in initial value trasfer post:  tau_inh 3.2022099924457885 2.662659609694801
# Problem in initial value trasfer pre:  tau_inh 3.1030668686553358 3.851930824639217
# Problem in initial value trasfer post:  tau_inh 3.873799185108218 2.628594893334491
# Problem in initial value trasfer pre:  tau_inh 2.939373936450034 3.2234009371157017
# Problem in initial value trasfer post:  tau_inh 2.711476412086943 3.660677436992023
# Problem in initial value trasfer pre:  tau_inh 2.3426140467499135 3.8013421215153804
# Problem in initial value trasfer post:  tau_inh 2.938648432839315 3.7195572518132476
# Problem in initial value trasfer pre:  tau_inh 2.8349983086059565 3.243399642677783
# Problem in initial value trasfer post:  tau_inh 3.699819452075382 2.42006214126964
# Problem in initial value trasfer pre:  tau_inh 3.1630125825181734 2.799501787936126
# Problem in initial value trasfer post:  tau_inh 1.8231008796365817 4.905192115890383
# Problem in initial value trasfer pre:  tau_inh 2.8550871973038614 3.121591919524398
# Problem in initial value trasfer post:  tau_inh 2.508206924897277 3.1255635295972874
# Problem in initial value trasfer pre:  tau_inh 4.383911351340878 2.813895426469482
# Problem in initial value trasfer post:  tau_inh 2.529318762169476 3.6761344672396414
# Problem in initial value trasfer pre:  tau_inh 2.7962573908502897 3.4611513113572867
# Problem in initial value trasfer post:  tau_inh 3.2800171913788296 2.901842049312778
# Problem in initial value trasfer pre:  tau_inh 3.152290510531725 3.222570968265426
# Problem in initial value trasfer post:  tau_inh 2.775103328955155 3.5471927934574383
# Problem in initial value trasfer pre:  tau_inh 1.85820845827945 4.442593236804603
# Problem in initial value trasfer post:  tau_inh 1.8327664510756818 4.231254174990253
# Problem in initial value trasfer pre:  tau_inh 2.3521844428376704 3.8960912996771753
# Problem in initial value trasfer post:  tau_inh 3.3538579921396297 3.4825918875224815
# Problem in initial value trasfer pre:  tau_inh 2.8884929620638133 4.050525096091464
# Problem in initial value trasfer post:  tau_inh 2.5154601358476434 3.672711525547844
# Problem in initial value trasfer pre:  tau_inh 3.4325513098655818 2.8833207075300002
# Problem in initial value trasfer post:  tau_inh 1.7683943384723562 4.68316735491105
# Problem in initial value trasfer pre:  tau_inh 2.4794706216735496 3.731752802719208
# Problem in initial value trasfer post:  tau_inh 3.178195004402535 2.5097444031977365
# Problem in initial value trasfer pre:  tau_inh 2.740897994663236 3.543343069200447
# Problem in initial value trasfer post:  tau_inh 4.30867231414516 2.4306971954874452
# Problem in initial value trasfer pre:  tau_inh 3.0415118286236225 3.164944397976847
# Problem in initial value trasfer post:  tau_inh 4.727785640876952 2.348521932096686
# Problem in initial value trasfer pre:  tau_inh 3.0857454128250357 3.0988495646201333
# Problem in initial value trasfer post:  tau_inh 3.756106683754645 2.680046366897533
# Problem in initial value trasfer pre:  tau_inh 2.6564729925003565 4.074140357592106
# Problem in initial value trasfer post:  tau_inh 2.3784320959045187 3.584001957040408
# Problem in initial value trasfer pre:  tau_inh 2.5756620396629137 3.667931474797133
# Problem in initial value trasfer post:  tau_inh 3.1031141433687437 2.9264147142944497
# Problem in initial value trasfer pre:  tau_inh 2.70443131907186 3.048174188777078
# Problem in initial value trasfer post:  tau_inh 3.149051999439357 3.201840979505538
# Problem in initial value trasfer pre:  tau_inh 3.355084806472506 2.9163539354902888
# Problem in initial value trasfer post:  tau_inh 3.8613035304495553 2.536422833142148
# Problem in initial value trasfer pre:  tau_inh 2.278287069848732 3.6848957125838413
# Problem in initial value trasfer post:  tau_inh 3.140079098483028 3.211213765881291
# Problem in initial value trasfer pre:  tau_inh 2.3944688764822284 4.3126934515293645
# Problem in initial value trasfer post:  tau_inh 2.288815055060711 3.5951254270725004
# Problem in initial value trasfer pre:  tau_inh 3.0232496401045026 3.694252899652662
# Problem in initial value trasfer post:  tau_inh 2.9058131014766366 3.6201830978877068
# Problem in initial value trasfer pre:  tau_inh 2.858785484413773 3.4860956151709352
# Problem in initial value trasfer post:  tau_inh 2.8448790257093086 3.3127854356121813
# Problem in initial value trasfer pre:  tau_inh 2.0545889013642853 3.88802285432328
# Problem in initial value trasfer post:  tau_inh 2.0194386099762447 4.6929530859236745
# Problem in initial value trasfer pre:  tau_inh 3.135901397143632 3.216056025913215
# Problem in initial value trasfer post:  tau_inh 4.082894899580272 2.6403410398007994
# Problem in initial value trasfer pre:  tau_inh 3.849825463621725 2.3517200676470384
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# Problem in initial value trasfer post:  tau_inh 3.1750744794227286 2.9734777162048585
# Problem in initial value trasfer pre:  tau_inh 1.8541613298635717 4.265193841064714
# Problem in initial value trasfer post:  tau_inh 3.1203646405896186 2.8436394194800845
# Problem in initial value trasfer pre:  tau_inh 2.6632586380815675 3.628325479939627
# Problem in initial value trasfer post:  tau_inh 3.1448943057894545 2.583585879525585
# Problem in initial value trasfer pre:  tau_inh 4.573965930989623 1.9455147829916206
# Problem in initial value trasfer post:  tau_inh 2.879587739653097 3.1721414074086325
# Problem in initial value trasfer pre:  tau_inh 2.8222326895593794 3.3096835798673685
# Problem in initial value trasfer post:  tau_inh 2.7287862340412663 3.863684243241908
# Problem in initial value trasfer pre:  tau_inh 2.9894831382726417 2.915653260313034
# Problem in initial value trasfer post:  tau_inh 3.681224990629694 2.6412097897427214
# Problem in initial value trasfer pre:  tau_inh 2.7226186337747715 3.5400321895415368
# Problem in initial value trasfer post:  tau_inh 2.118138768224708 3.899526699347511
# Problem in initial value trasfer pre:  tau_inh 2.5506344341941274 3.262516120600673
# Problem in initial value trasfer post:  tau_inh 2.5639815430419537 3.2110010984378716
# Problem in initial value trasfer pre:  tau_inh 2.9069767361236827 2.6980958122472805
# Problem in initial value trasfer post:  tau_inh 2.4359091795516026 3.521618212973338
# Problem in initial value trasfer pre:  tau_inh 2.182500069165452 3.8257415065141624
# Problem in initial value trasfer post:  tau_inh 3.410459968814132 2.9943465467738024
# Problem in initial value trasfer pre:  tau_inh 2.3671262405589424 4.3579673896913285
# Problem in initial value trasfer post:  tau_inh 2.498612676578915 3.619668283278844
# Problem in initial value trasfer pre:  tau_inh 2.5050505937807968 3.524948212380035
# Problem in initial value trasfer post:  tau_inh 3.072475137278747 2.6358915331567476
# Problem in initial value trasfer pre:  tau_inh 1.9704066293276468 4.571927251817095
# Problem in initial value trasfer post:  tau_inh 2.268336603876207 3.7752651406436764
# Problem in initial value trasfer pre:  tau_inh 2.5986437824863704 4.063138339967627
# Problem in initial value trasfer post:  tau_inh 2.52432907817685 3.6946017493222816
# Problem in initial value trasfer pre:  tau_inh 3.0768944636207745 2.892573134961328
# Problem in initial value trasfer post:  tau_inh 3.5991924185684567 2.8842982677073685
# Problem in initial value trasfer pre:  tau_inh 2.1708947904410945 4.331159734891647
# Problem in initial value trasfer post:  tau_inh 2.2955360452210685 3.8403149411630735
# Problem in initial value trasfer pre:  tau_inh 3.5983846873319076 2.4339087459071527
# Problem in initial value trasfer post:  tau_inh 2.32905311301032 3.609162570427226
# Problem in initial value trasfer pre:  tau_inh 2.39170303466206 3.8835420639851037
# Problem in initial value trasfer post:  tau_inh 2.6328344613015746 3.1323111278624016
# Problem in initial value trasfer pre:  tau_inh 2.588835525068193 4.089950310113893
# Problem in initial value trasfer post:  tau_inh 2.545742584689172 3.409006626415261
# Problem in initial value trasfer pre:  tau_inh 3.6751494610931257 2.846271757711737
# Problem in initial value trasfer post:  tau_inh 2.2805545392747564 3.781570219161756
# Problem in initial value trasfer pre:  tau_inh 2.1074584938579717 4.237514114381357
# Problem in initial value trasfer post:  tau_inh 1.964161064291439 4.6147282220406165
# Problem in initial value trasfer pre:  tau_inh 3.2624582575798926 2.48108057860611
# Problem in initial value trasfer post:  tau_inh 2.3946586555772447 4.0265622548992495
# Problem in initial value trasfer pre:  tau_inh 3.434506425047542 3.107044809342241
# Problem in initial value trasfer post:  tau_inh 3.271321378108941 3.1389052927630243
# Problem in initial value trasfer pre:  tau_inh 1.730464044825779 5.458401455934168
# Problem in initial value trasfer post:  tau_inh 3.1137228290426537 3.21611509594001
# Problem in initial value trasfer pre:  tau_inh 2.1565292837632852 3.6481938789311337
# Problem in initial value trasfer post:  tau_inh 2.06061469683666 3.847269133659432
# Problem in initial value trasfer pre:  tau_inh 4.125861637343166 1.9962989981762642
# Problem in initial value trasfer post:  tau_inh 3.010628608808219 3.231179375945973
# Problem in initial value trasfer pre:  tau_inh 2.981358113889207 3.8185554241584683
# Problem in initial value trasfer post:  tau_inh 3.2594674935488666 2.816056552744503
# Problem in initial value trasfer pre:  tau_inh 2.474753670172097 3.6355594729253524
# Problem in initial value trasfer post:  tau_inh 3.5151974098855057 2.9517329078324748
# Problem in initial value trasfer pre:  tau_inh 2.8622779772122797 3.5620532715386606
# Problem in initial value trasfer post:  tau_inh 2.5890592942287993 4.149356712574309
# Problem in initial value trasfer pre:  tau_inh 2.355959421100423 4.0893335526242325
# Problem in initial value trasfer post:  tau_inh 2.6251999439354323 3.97582494019138
# Problem in initial value trasfer pre:  tau_inh 2.9503316152887793 3.260273959768388
# Problem in initial value trasfer post:  tau_inh 3.1679030847659204 2.6740347216055196
# Problem in initial value trasfer pre:  tau_inh 2.794121807689528 3.704206887222722
# Problem in initial value trasfer post:  tau_inh 3.063656572928326 3.3790490946659753
# Problem in initial value trasfer pre:  tau_inh 3.528101932920159 2.8958640233619226
# Problem in initial value trasfer post:  tau_inh 3.239054884211413 3.5453894436493685
# Problem in initial value trasfer pre:  tau_inh 3.627761872629985 2.7835408599475424
# Problem in initial value trasfer post:  tau_inh 3.0073264468509024 2.6327165489018616
# Problem in initial value trasfer pre:  tau_inh 2.513997774530243 3.589067802192193
# Problem in initial value trasfer post:  tau_inh 1.6073583606987452 5.590006754724086
# Problem in initial value trasfer pre:  tau_inh 1.978043629505802 3.985175788363868
# Problem in initial value trasfer post:  tau_inh 2.629139888928509 3.652292141261047
# Problem in initial value trasfer pre:  tau_inh 3.7274453655010014 3.139758498426873
# Problem in initial value trasfer post:  tau_inh 2.7044739188207987 4.068727519988504
# Problem in initial value trasfer pre:  tau_inh 2.535962222452215 2.966833631598116
# Problem in initial value trasfer post:  tau_inh 2.858519446450005 4.237560378876151
# Problem in initial value trasfer pre:  tau_inh 3.8114703029027877 2.574980852512766
# Problem in initial value trasfer post:  tau_inh 2.2040042806452935 3.576440142067799
# Problem in initial value trasfer pre:  tau_inh 2.7650085486669003 3.3425540314758004
# Problem in initial value trasfer post:  tau_inh 2.586132342435408 3.602718731135643
# Problem in initial value trasfer pre:  tau_inh 3.091336542656833 3.8827632841489352
# Problem in initial value trasfer post:  tau_inh 3.1360891532830335 2.8572379967170516
# Problem in initial value trasfer pre:  tau_inh 2.6991974354039385 3.4323945446484427
# Problem in initial value trasfer post:  tau_inh 2.4681511803477574 3.2455774173953054
# Problem in initial value trasfer pre:  tau_inh 2.727458415392224 3.957080773385488
# Problem in initial value trasfer post:  tau_inh 2.423573733045916 3.71819665449439
# Problem in initial value trasfer pre:  tau_inh 2.484319519931448 3.4638522415748576
# Problem in initial value trasfer post:  tau_inh 3.1614254362405325 3.2747449534405124
# Problem in initial value trasfer pre:  tau_inh 2.79068913320027 3.312595390490457
# Problem in initial value trasfer post:  tau_inh 3.3450776744109247 2.714904438533708
# Problem in initial value trasfer pre:  tau_inh 2.2612365830548633 3.3271379115242343
# Problem in initial value trasfer post:  tau_inh 2.777668106990075 3.156790965615954
# Problem in initial value trasfer pre:  tau_inh 2.8692471280407648 3.891990156489515
# Problem in initial value trasfer post:  tau_inh 2.681779864348133 3.0494812888384506
# Problem in initial value trasfer pre:  tau_inh 3.354999546586854 3.310438968802253
# Problem in initial value trasfer post:  tau_inh 4.417152347698824 2.2369473077085518
# Problem in initial value trasfer pre:  tau_inh 3.2934844443047 2.6917367820904228
# Problem in initial value trasfer post:  tau_inh 3.220781556358128 3.417246409741177
# Problem in initial value trasfer pre:  tau_inh 2.596126948258258 3.131016201733024
# Problem in initial value trasfer post:  tau_inh 2.2802511269520673 3.5968910040841733
# Problem in initial value trasfer pre:  tau_inh 2.9492736529733334 2.999577802448536
# Problem in initial value trasfer post:  tau_inh 3.202312329829487 3.3021083898235424
# Problem in initial value trasfer pre:  tau_inh 3.6297031050151096 2.529894872180766
# Problem in initial value trasfer post:  tau_inh 4.248985015584255 2.6274720467274744
# Problem in initial value trasfer pre:  tau_inh 3.082453524209545 3.165985117057899
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# Problem in initial value trasfer post:  tau_inh 2.254926080004605 3.848822479715993
# Problem in initial value trasfer pre:  tau_inh 3.013979947235859 3.578436027907797
# Problem in initial value trasfer post:  tau_inh 3.611512164080763 2.6861915854805245
# Problem in initial value trasfer pre:  tau_inh 1.9637615643353348 4.91498557003507
# Problem in initial value trasfer post:  tau_inh 2.699162710730261 3.232521525404416
# Problem in initial value trasfer pre:  tau_inh 2.4601751997964185 3.98105221513617
# Problem in initial value trasfer post:  tau_inh 3.612533948957886 3.5616747274376794
# Problem in initial value trasfer pre:  tau_inh 3.0152523215682026 2.967971854082455
# Problem in initial value trasfer post:  tau_inh 3.56610349058262 2.510610556120983
# Problem in initial value trasfer pre:  tau_inh 1.9256146111485821 4.211108634637564
# Problem in initial value trasfer post:  tau_inh 4.14565952005009 2.541328199127983
# Problem in initial value trasfer pre:  tau_inh 4.960196515958112 2.094818544408989
# Problem in initial value trasfer post:  tau_inh 2.509596296125697 2.6591874706262693
# Problem in initial value trasfer pre:  tau_inh 2.457938707937391 3.7023467210953362
# Problem in initial value trasfer post:  tau_inh 2.3732097269580184 3.762722791327947
# Problem in initial value trasfer pre:  tau_inh 5.050219508817558 1.8631354534912932
# Problem in initial value trasfer post:  tau_inh 2.5612338642114416 3.948696293680932
# Problem in initial value trasfer pre:  tau_inh 2.6951812854381627 3.1359043081008715
# Problem in initial value trasfer post:  tau_inh 2.6481767720246725 3.914553146639056
# Problem in initial value trasfer pre:  tau_inh 3.5954565418836695 2.4107748631289594
# Problem in initial value trasfer post:  tau_inh 2.8669137279639663 3.531886528659982
# Problem in initial value trasfer pre:  tau_inh 3.362073026251707 3.621219251140186
# Problem in initial value trasfer post:  tau_inh 2.641668924140398 3.3019392339459186
# Problem in initial value trasfer pre:  tau_inh 2.449448083834477 3.5775534951760375
# Problem in initial value trasfer post:  tau_inh 2.57960393779683 3.9173718713435934
# Problem in initial value trasfer pre:  tau_inh 3.4925153267499933 3.654502138211041
# Problem in initial value trasfer post:  tau_inh 2.196341072229515 3.485171630782771
# Problem in initial value trasfer pre:  tau_inh 3.290276401341591 2.8395010753297947
# Problem in initial value trasfer post:  tau_inh 2.3464389968995953 3.6019339155275905
# Problem in initial value trasfer pre:  tau_inh 2.643271259615896 3.6159849545078417
# Problem in initial value trasfer post:  tau_inh 3.5771690338949935 2.503381256422928
# Problem in initial value trasfer pre:  tau_inh 3.0823541175662954 3.059401474012169
# Problem in initial value trasfer post:  tau_inh 2.5658341964424816 3.6230378419135154
# Problem in initial value trasfer pre:  tau_inh 2.770655042441787 3.6856583982417344
# Problem in initial value trasfer post:  tau_inh 2.625867433806918 3.88503869543343
# Problem in initial value trasfer pre:  tau_inh 3.0116303245632445 3.377397543618539
# Problem in initial value trasfer post:  tau_inh 3.4598877509492043 2.805598052362783
# Problem in initial value trasfer pre:  tau_inh 2.0199361321269413 4.046060835717895
# Problem in initial value trasfer post:  tau_inh 2.2609247750013433 3.483826827714044
# Problem in initial value trasfer pre:  tau_inh 3.189924646024255 2.7969288984515335
# Problem in initial value trasfer post:  tau_inh 2.1890384385281916 4.169723103613859
# Problem in initial value trasfer pre:  tau_inh 2.8119827451903436 3.8274439138520813
# Problem in initial value trasfer post:  tau_inh 3.2029127211775013 2.912715092462504
# Problem in initial value trasfer pre:  tau_inh 2.6541211863333256 3.1327061280248865
# Problem in initial value trasfer post:  tau_inh 3.100086186837258 3.266084911630208
# Problem in initial value trasfer pre:  tau_inh 2.6191724905035905 2.9078773371337747
# Problem in initial value trasfer post:  tau_inh 3.2504478446492384 3.1187693657944338
# Problem in initial value trasfer pre:  tau_inh 3.668525916592497 3.0001579744344453
# Problem in initial value trasfer post:  tau_inh 3.1791722873274866 2.7828683700443513
# Problem in initial value trasfer pre:  tau_inh 3.0034160889267874 2.5502241977902207
# Problem in initial value trasfer post:  tau_inh 2.4804843292840024 3.5940933874429275
# Problem in initial value trasfer pre:  tau_inh 2.911352131710834 3.450151430186183
# Problem in initial value trasfer post:  tau_inh 1.9333656851155283 4.6602290165338
# Problem in initial value trasfer pre:  tau_inh 3.441666786832239 2.3285463461762177
# Problem in initial value trasfer post:  tau_inh 2.0322330154784827 3.6495936243142952
# Problem in initial value trasfer pre:  tau_inh 4.511122179190185 2.4736636511276635
# Problem in initial value trasfer post:  tau_inh 3.262321170482483 2.9908525029001836
# Problem in initial value trasfer pre:  tau_inh 3.3148823771501537 2.6167061971034205
# Problem in initial value trasfer post:  tau_inh 2.1260034229801006 4.28739089078027
# Problem in initial value trasfer pre:  tau_inh 2.8268812022617626 3.4841119683615376
# Problem in initial value trasfer post:  tau_inh 4.599855850299013 2.5780031216392594
# Problem in initial value trasfer pre:  tau_inh 1.9650068601689326 4.200966992998796
# Problem in initial value trasfer post:  tau_inh 2.2087705714566366 3.704980445680175
# Problem in initial value trasfer pre:  tau_inh 3.9889422248643314 2.697080765594213
# Problem in initial value trasfer post:  tau_inh 2.673081035713369 3.226283206595542
# Problem in initial value trasfer pre:  tau_inh 3.054921260854115 3.0639058930597165
# Problem in initial value trasfer post:  tau_inh 2.4429725992696154 3.1376419725165174
# Problem in initial value trasfer pre:  tau_inh 3.760373378144587 2.656938238900074
# Problem in initial value trasfer post:  tau_inh 3.007311201384953 2.707121600607977
# Problem in initial value trasfer pre:  tau_inh 2.641171698208222 3.609118903791885
# Problem in initial value trasfer post:  tau_inh 2.445527970653689 3.1370644876690412
# Problem in initial value trasfer pre:  tau_inh 2.42903230025149 3.952705158292983
# Problem in initial value trasfer post:  tau_inh 2.788807140639562 3.545006405386244
# Problem in initial value trasfer pre:  tau_inh 2.9606748694768217 3.0241143127897963
# Problem in initial value trasfer post:  tau_inh 2.8215026400414573 2.803823858263728
# Problem in initial value trasfer pre:  tau_inh 2.580135909904348 4.0685810131826905
# Problem in initial value trasfer post:  tau_inh 1.8894632329786822 5.004578201547939
# Problem in initial value trasfer pre:  tau_inh 2.3386468037158696 3.668319225072331
# Problem in initial value trasfer post:  tau_inh 3.632085259981103 2.549807384787085
# Problem in initial value trasfer pre:  tau_inh 3.0555077310949823 3.5768572728818913
# Problem in initial value trasfer post:  tau_inh 3.450165733363061 2.7808583982382316
# Problem in initial value trasfer pre:  tau_inh 2.493626547326427 3.942997076386839
# Problem in initial value trasfer post:  tau_inh 2.550636930353315 3.6129783065305574
# Problem in initial value trasfer pre:  tau_inh 1.8795150652490242 4.381156752407555
# Problem in initial value trasfer post:  tau_inh 2.236674735790025 4.481305466931918
# Problem in initial value trasfer pre:  tau_inh 1.8832093470523705 4.3796545950504555
# Problem in initial value trasfer post:  tau_inh 2.151431555627108 3.7834820702289775
# Problem in initial value trasfer pre:  tau_inh 2.640464142532732 3.772236313990022
# Problem in initial value trasfer post:  tau_inh 3.5819649020971767 2.4796905871488573
# Problem in initial value trasfer pre:  tau_inh 2.8432376509944364 2.6983182549606926
# Problem in initial value trasfer post:  tau_inh 3.136554169772959 3.180161646092342
# Problem in initial value trasfer pre:  tau_inh 1.671517915003388 4.900784865961607
# Problem in initial value trasfer post:  tau_inh 2.3587380479013222 3.66988789433035
# Problem in initial value trasfer pre:  tau_inh 2.6857223879234877 2.741885012155226
# Problem in initial value trasfer post:  tau_inh 3.75287766778615 2.9349125105319533
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# Problem in initial value trasfer pre:  tau_inh 3.7396128464433853 2.0465361994180675
# Problem in initial value trasfer post:  tau_inh 2.421558213915781 4.568493436516815
# Problem in initial value trasfer pre:  tau_inh 2.084119887419452 4.358666522693126
# Problem in initial value trasfer post:  tau_inh 2.6168367013798752 4.1055445684798295
# Problem in initial value trasfer pre:  tau_inh 2.379919072395824 3.2946772452923874
# Problem in initial value trasfer post:  tau_inh 3.1590250089714096 3.2546115026441034
# Problem in initial value trasfer pre:  tau_inh 2.2723036931613536 3.9982749006018685
# Problem in initial value trasfer post:  tau_inh 3.3729126891643872 2.5575991025992835
# Problem in initial value trasfer pre:  tau_inh 2.29826629105678 4.342682113355829
# Problem in initial value trasfer post:  tau_inh 2.513394208502952 3.537557877161102
# Problem in initial value trasfer pre:  tau_inh 2.435101784377084 3.6573659436982764
# Problem in initial value trasfer post:  tau_inh 2.305681687708703 4.051641357209001
# Problem in initial value trasfer pre:  tau_inh 2.407323801799589 3.476970054661526
# Problem in initial value trasfer post:  tau_inh 3.3237699536850154 2.517403366293036
# Problem in initial value trasfer pre:  tau_inh 1.7012241000227373 4.862057308797785
# Problem in initial value trasfer post:  tau_inh 4.660431500985046 2.342753401968626
# Problem in initial value trasfer pre:  tau_inh 2.8668766541574646 3.6669249995755497
# Problem in initial value trasfer post:  tau_inh 3.06894451520395 2.9173514359008976
# Problem in initial value trasfer pre:  tau_inh 2.956948273398949 3.3992697120972917
# Problem in initial value trasfer post:  tau_inh 2.73832242612102 3.582601451532761
# Problem in initial value trasfer pre:  tau_inh 3.7150297150153655 2.5722806349642835
# Problem in initial value trasfer post:  tau_inh 2.4801761182969897 3.0434835836250396
# Problem in initial value trasfer pre:  tau_inh 2.7186960065867103 3.6153746361556993
# Problem in initial value trasfer post:  tau_inh 4.056378327170289 2.7171778482269384
# Problem in initial value trasfer pre:  tau_inh 2.211640227394195 4.317091489320053
# Problem in initial value trasfer post:  tau_inh 2.7845251772233466 3.595924933105338
# Problem in initial value trasfer pre:  tau_inh 2.2402944303575425 4.1004962983622795
# Problem in initial value trasfer post:  tau_inh 2.523916438421624 3.6570936589263896
# Problem in initial value trasfer pre:  tau_inh 2.332299584982568 4.171366113320626
# Problem in initial value trasfer post:  tau_inh 3.479607304116431 2.5291954217443724
# Problem in initial value trasfer pre:  tau_inh 3.004007299653906 3.294687400646598
# Problem in initial value trasfer post:  tau_inh 2.6731659115061843 2.914793304114032
# Problem in initial value trasfer pre:  tau_inh 2.324119145059492 3.4508372010296835
# Problem in initial value trasfer post:  tau_inh 2.862012766844957 3.384731799280861
# Problem in initial value trasfer pre:  tau_inh 3.451969081514782 3.2273475267519562
# Problem in initial value trasfer post:  tau_inh 3.084365090894597 3.1266455397135116
# Problem in initial value trasfer pre:  tau_inh 2.363910403059626 3.462490166979224
# ...
# Problem in initial value trasfer pre:  tau_inh 3.607762345175951 3.24646093734302
# Problem in initial value trasfer post:  tau_inh 4.0333886135061405 2.3590003221486886
# Problem in initial value trasfer pre:  tau_inh 2.290095955011626 4.086860870863595
# Problem in initial value trasfer post:  tau_inh 1.9668667301894571 4.197400053514363
# Problem in initial value trasfer pre:  tau_inh 3.8559805105611606 2.531096590032267
# Problem in initial value trasfer post:  tau_inh 2.515895582583869 3.833850103315038
# Problem in initial value trasfer pre:  tau_inh 3.636625148966168 2.7335614764155567
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer post
# Problem in initial value trasfer post:  tau_inh 3.2288947785803903 2.6583531424033278
# Problem in initial value trasfer pre:  tau_inh 2.0102316040092703 3.560331292750838
# Problem in initial value trasfer post:  tau_inh 2.6333206153146125 3.8581277470718813
# Problem in initial value trasfer pre:  tau_inh 2.661425500203547 3.760091918633379
# Problem in initial value trasfer post:  tau_inh 2.9441825088342077 4.070072783984535
# Problem in initial value trasfer pre:  tau_inh 2.8099699095560604 3.6150474655121476
# Problem in initial value trasfer post:  tau_inh 4.001261451096118 2.5290920520510776
# Problem in initial value trasfer pre:  tau_inh 2.2691977107176973 3.591009052361915
# Problem in initial value trasfer post:  tau_inh 2.820470501917264 3.753160371548494
# Problem in initial value trasfer pre:  tau_inh 3.7884419725190304 2.4469898042074156
# Problem in initial value trasfer post:  tau_inh 2.348767010659308 3.75384906160593
# Problem in initial value trasfer pre:  tau_inh 4.9019665395097425 2.2438438311028013
# Problem in initial value trasfer post:  tau_inh 2.3866371120665577 3.8500786357915606
# Problem in initial value trasfer pre:  tau_inh 2.704128585221905 3.420347661818751
# Problem in initial value trasfer post:  tau_inh 3.1997282983134987 2.748066207136625
# Problem in initial value trasfer pre:  tau_inh 3.433334779697925 2.876538524342744
# Problem in initial value trasfer post:  tau_inh 1.9832216581993447 4.568827497025415
# Problem in initial value trasfer pre:  tau_inh 2.281057297515676 3.9269011049290343
# Problem in initial value trasfer post:  tau_inh 2.4155865612978387 3.4865980271101766
# Problem in initial value trasfer pre:  tau_inh 2.595508921030456 3.4328430317646235
# Problem in initial value trasfer post:  tau_inh 1.7449846430446474 4.849150358037957
# Problem in initial value trasfer pre:  tau_inh 3.576660143808635 2.650726778126958
# Problem in initial value trasfer post:  tau_inh 2.9007959020791887 3.77319031796401
# Problem in initial value trasfer pre:  tau_inh 3.4869791356157935 3.496878178116055
# Problem in initial value trasfer post:  tau_inh 3.0979683824806403 3.4530687798962503
# Problem in initial value trasfer pre:  tau_inh 2.135762675721092 4.085715270866023
# Problem in initial value trasfer post:  tau_inh 2.5988317286656017 4.025997020560384
# Problem in initial value trasfer pre:  tau_inh 3.306468913626987 2.8923099610472414
# Problem in initial value trasfer post:  tau_inh 1.9393035802844663 3.717280840574094
# Problem in initial value trasfer pre:  tau_inh 3.1033691826553262 2.8089245636133544
# Problem in initial value trasfer post:  tau_inh 3.5634476148643697 2.5030246566995067
# Problem in initial value trasfer pre:  tau_inh 2.1183252600782847 4.3442325028286195
# Problem in initial value trasfer post:  tau_inh 2.9665517171247844 2.846036163581194
# Problem in initial value trasfer pre:  tau_inh 2.6019682223147296 3.9577900191012056
# Problem in initial value trasfer post:  tau_inh 2.515662671661405 3.442538448566505
# Problem in initial value trasfer pre:  tau_inh 2.584918696829891 3.5130839754044207
# Problem in initial value trasfer post:  tau_inh 2.6992479888154137 3.7948401067665425
# Problem in initial value trasfer pre:  tau_inh 2.596810141948667 3.733858218736814
# Problem in initial value trasfer post:  tau_inh 2.1208468338128266 3.866022039733135
# Problem in initial value trasfer pre:  tau_inh 2.0821742105830148 4.6213830300818595
# Problem in initial value trasfer post:  tau_inh 2.44525629435669 3.939105506149074
# Problem in initial value trasfer pre:  tau_inh 3.2026589273064845 2.9706086889951604
# Problem in initial value trasfer post:  tau_inh 2.984026658815413 3.0622482685559222
# Problem in initial value trasfer pre:  tau_inh 1.9296636822420152 4.77318383019845
# Problem in initial value trasfer post:  tau_inh 2.26214768707341 3.931019276780536
# Problem in initial value trasfer pre:  tau_inh 3.007679278582913 3.4240669596132465
# Problem in initial value trasfer post:  tau_inh 2.6836712310891118 3.237681988743316
# Problem in initial value trasfer pre:  tau_inh 2.5890891691807703 3.4937199712433777
# Problem in initial value trasfer post:  tau_inh 2.9289440921773773 3.645690355496723
# Problem in initial value trasfer pre:  tau_inh 2.2895783736891393 4.387478439340326
# Problem in initial value trasfer post:  tau_inh 3.651681222223413 2.566068736183853
# Problem in initial value trasfer pre:  tau_inh 2.607213579989567 3.7097042101161066
# Problem in initial value trasfer post:  tau_inh 2.652381260210984 3.373152583392764
# Problem in initial value trasfer pre:  tau_inh 3.71547008114043 2.8537817215659214
# Problem in initial value trasfer post:  tau_inh 4.455270612272082 2.438362514318874
# Problem in initial value trasfer pre:  tau_inh 2.753845308832537 3.707844116207036
# Problem in initial value trasfer post:  tau_inh 2.598222969261823 3.5256350227448836
# Problem in initial value trasfer pre:  tau_inh 2.625319627497743 4.164884268866399
# Problem in initial value trasfer post:  tau_inh 2.5615210792623793 4.157975222698133
# Problem in initial value trasfer pre:  tau_inh 3.2188915852124715 3.3572190138125597
# Problem in initial value trasfer post:  tau_inh 2.1879635147839123 4.792493963672685
# Problem in initial value trasfer pre:  tau_inh 3.4297836492486575 2.8682266564078702
# Problem in initial value trasfer post:  tau_inh 3.238753945810615 2.7203027011813457
# Problem in initial value trasfer pre:  tau_inh 2.489611409693744 3.9891591009062215
# Problem in initial value trasfer post:  tau_inh 2.859979515889809 3.8920761819985494
# Problem in initial value trasfer pre:  tau_inh 3.3976223932260687 2.8469549585099703
# Problem in initial value trasfer post:  tau_inh 2.9931555198576736 2.763001268919656
# Problem in initial value trasfer pre:  tau_inh 3.3307876992193703 2.5472146117175862
# Problem in initial value trasfer post:  tau_inh 3.0029692529137844 3.227058882257855
# Problem in initial value trasfer pre:  tau_inh 2.6916078476026306 3.3476697548139143
# Problem in initial value trasfer post:  tau_inh 3.211994324511787 3.207391294675598
# Problem in initial value trasfer pre:  tau_inh 3.6938710382658484 2.7616072861243413
# Problem in initial value trasfer post:  tau_inh 2.915380869942663 3.128160984827489
# Problem in initial value trasfer pre:  tau_inh 2.382893787384129 3.958732481520179
# Problem in initial value trasfer post:  tau_inh 2.4784243985104975 4.211916881509423
# Problem in initial value trasfer pre:  tau_inh 3.8693625134057528 2.524190911633754
# Problem in initial value trasfer post:  tau_inh 2.7302014978487694 3.536725669647579
# Problem in initial value trasfer pre:  tau_inh 2.507466031960747 3.7148814700450146
# Problem in initial value trasfer post:  tau_inh 3.8576930734445614 2.1257957294556737
# Problem in initial value trasfer pre:  tau_inh 3.127918598989921 2.908685690991981
# Problem in initial value trasfer post:  tau_inh 2.4066818628271185 3.8579069263744863
# Problem in initial value trasfer pre:  tau_inh 2.562383864928317 3.296565763526022
# Problem in initial value trasfer post:  tau_inh 2.0450661407371284 4.36943705882635
# Problem in initial value trasfer pre:  tau_inh 3.7319358921040453 3.2796876524176795
# Problem in initial value trasfer post:  tau_inh 3.241340141807846 2.4037953952926348
# Problem in initial value trasfer pre:  tau_inh 2.077331657149855 4.243766899906034
# Problem in initial value trasfer post:  tau_inh 3.887436553626748 2.3525896682289553
# Problem in initial value trasfer pre:  tau_inh 2.0092143765544406 4.1329112480122765
# Problem in initial value trasfer post:  tau_inh 2.2923746541734356 4.066304288586287
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_361294/2698971471.py in <module>
#      28         max_it = 0
#      29
# ---> 30         load_control[i], st, c, r, g, p, costnode_ = aln.A1(
#      31             control0, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it,
#      32             tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
#
# ~/Promotion/neurolib/neurolib/models/model.py in A1(self, control_, target_state_, c_scheme_, u_mat_, u_scheme_, max_iteration_, tolerance_, startStep_, max_control_, min_control_, t_sim_, t_sim_pre_, t_sim_post_, CGVar, line_search_, control_variables_, prec_variables_, separate_comp, transition_time_, noise_real, init_params)
#     665                                                 line_search_, control_variables_, prec_variables_, separate_comp, transition_time_)
#     666                 elif noise_real > 0:
# --> 667                     return A1_noise.A1(self, noise_real, init_params, control_, target_state_, c_scheme_, u_mat_, u_scheme_, max_iteration_,
#     668                                                 tolerance_, startStep_, max_control_, min_control_, t_sim_, t_sim_pre_, t_sim_post_, CGVar,
#     669                                                 line_search_, control_variables_, prec_variables_, separate_comp, transition_time_)
#
# ~/Promotion/neurolib/neurolib/utils/A1_aln_noise.py in A1(model, noise_real, init_params, control_, target_state, c_scheme_, u_mat_, u_scheme_, max_iteration_, tolerance_, startStep_, cntrl_max_, cntrl_min_, t_sim_, t_sim_pre_, t_sim_post_, CGVar, line_search_, control_variables_, prec_variables_, separate_comp, transition_time_)
#     163         for noise_ in range(noise_real):
#     164             fo.set_init_1d(init_params, model)
# --> 165             state_pre_[noise_] = fo.updateFullState(model, control_pre_, state_vars)
#     166             if startind_ == 1:
#     167                 fo.update_init(model, init_vars, state_vars)
#
# ~/Promotion/neurolib/neurolib/utils/func_optimize.py in updateFullState(model, control_, state_vars_)
#      16 def updateFullState(model, control_, state_vars_):
#      17     state_ = model.getZeroFullState()
# ---> 18     model.run(control=control_)
#      19     for sv in range(len(state_vars_)):
#      20         state_[:,sv,:] = model.state[state_vars_[sv]][:,:]
#
# ~/Promotion/neurolib/neurolib/models/model.py in run(self, inputs, chunkwise, chunksize, bold, append, append_outputs, continue_run, control)
#     182
#     183         if chunkwise is False:
# --> 184             self.integrate(append_outputs=append, simulate_bold=bold, control=cntrl)
#     185             if continue_run:
#     186                 self.setInitialValuesToLastState()
#
# ~/Promotion/neurolib/neurolib/models/model.py in integrate(self, append_outputs, simulate_bold, control)
#     223         # run integration
#     224         #print("before integration")
# --> 225         t, *variables = self.integration(self.params, control=control)
#     226         #print("after integration")
#     227         self.storeOutputsAndStates(t, variables, append=append_outputs)
#
# ~/Promotion/neurolib/neurolib/models/aln/timeIntegration.py in timeIntegration(params, control)
#     170     sqrt_dt = np.sqrt(dt)
#     171
# --> 172     ndt_de = np.around(de / dt).astype(int)
#     173     ndt_di = np.around(di / dt).astype(int)
#     174
#
# KeyboardInterrupt:

# %%
print("RESULTS")

for i in i_range:
    
    print('----', i)

    for j in range(len(array_mult)):
        
        print("Factor sparsity cost = ", array_mult[j])
        print("factor precision cost = ", cost_pr[i][j] / cost_pr[i][4])
# Out:
# RESULTS
# ---- 0
# Factor sparsity cost =  0.6
# factor precision cost =  0.9135755339744431
# Factor sparsity cost =  0.7
# factor precision cost =  0.9545785448416559
# Factor sparsity cost =  0.8
# factor precision cost =  0.9640827362985152
# Factor sparsity cost =  0.9
# factor precision cost =  0.9870001907872338
# Factor sparsity cost =  1.0
# factor precision cost =  1.0
# Factor sparsity cost =  1.1
# factor precision cost =  0.9970553365576387
# Factor sparsity cost =  1.2
# factor precision cost =  0.9959840674963963
# Factor sparsity cost =  1.3
# factor precision cost =  0.9671568117120932
# Factor sparsity cost =  1.4
# factor precision cost =  0.9364503451339118
# Factor sparsity cost =  1.5
# factor precision cost =  0.9359546043386634
# ---- 10
# Factor sparsity cost =  0.6
# factor precision cost =  0.9388058604847433
# Factor sparsity cost =  0.7
# factor precision cost =  0.9885241877077101
# Factor sparsity cost =  0.8
# factor precision cost =  0.9963460717071407
# Factor sparsity cost =  0.9
# factor precision cost =  0.9962712997450022
# Factor sparsity cost =  1.0
# factor precision cost =  1.0
# Factor sparsity cost =  1.1
# factor precision cost =  1.0000592757837872
# Factor sparsity cost =  1.2
# factor precision cost =  0.9895040363179723
# Factor sparsity cost =  1.3
# factor precision cost =  0.9686585657642169
# Factor sparsity cost =  1.4
# factor precision cost =  0.8742821395638265
# Factor sparsity cost =  1.5
# factor precision cost =  0.39565414310828473
# ---- 20
# Factor sparsity cost =  0.6
# factor precision cost =  0.9814470419552525
# Factor sparsity cost =  0.7
# factor precision cost =  0.9990504939110039
# Factor sparsity cost =  0.8
# factor precision cost =  0.9999916099242651
# Factor sparsity cost =  0.9
# factor precision cost =  0.9999988635853383
# Factor sparsity cost =  1.0
# factor precision cost =  1.0
# Factor sparsity cost =  1.1
# factor precision cost =  0.9999972843154115
# Factor sparsity cost =  1.2
# factor precision cost =  0.9999920435939372
# Factor sparsity cost =  1.3
# factor precision cost =  0.9961288599133342
# Factor sparsity cost =  1.4
# factor precision cost =  0.9230894841774198
# Factor sparsity cost =  1.5
# factor precision cost =  0.3030044285800453
# ---- 30
# Factor sparsity cost =  0.6
# factor precision cost =  1.0000000038831778
# Factor sparsity cost =  0.7
# factor precision cost =  1.000000036162343
# Factor sparsity cost =  0.8
# factor precision cost =  0.9999999699918333
# Factor sparsity cost =  0.9
# factor precision cost =  1.0000000113907257
# Factor sparsity cost =  1.0
# factor precision cost =  1.0
# Factor sparsity cost =  1.1
# factor precision cost =  1.0000000334714088
# Factor sparsity cost =  1.2
# factor precision cost =  0.999999996419216
# Factor sparsity cost =  1.3
# factor precision cost =  1.0000000199774024
# Factor sparsity cost =  1.4
# factor precision cost =  0.9971581878884894
# Factor sparsity cost =  1.5
# factor precision cost =  0.2568947077633192
# ---- 40
# Factor sparsity cost =  0.6
# factor precision cost =  0.9032181434330997
# Factor sparsity cost =  0.7
# factor precision cost =  0.9790260505921339
# Factor sparsity cost =  0.8
# factor precision cost =  0.9939791786937473
# Factor sparsity cost =  0.9
# factor precision cost =  1.0010151724807563
# Factor sparsity cost =  1.0
# factor precision cost =  1.0
# Factor sparsity cost =  1.1
# factor precision cost =  0.9939461135357053
# Factor sparsity cost =  1.2
# factor precision cost =  0.9849469928883599
# Factor sparsity cost =  1.3
# factor precision cost =  0.9550789151933176
# Factor sparsity cost =  1.4
# factor precision cost =  0.7779135672643366
# Factor sparsity cost =  1.5
# factor precision cost =  0.24551700369423285
# ---- 50
# Factor sparsity cost =  0.6
# factor precision cost =  0.9999999944084046
# Factor sparsity cost =  0.7
# factor precision cost =  1.0000000225035839
# Factor sparsity cost =  0.8
# factor precision cost =  0.9999999737675207
# Factor sparsity cost =  0.9
# factor precision cost =  1.000000032663351
# Factor sparsity cost =  1.0
# factor precision cost =  1.0
# Factor sparsity cost =  1.1
# factor precision cost =  1.0000000285150887
# Factor sparsity cost =  1.2
# factor precision cost =  1.0000000186420468
# Factor sparsity cost =  1.3
# factor precision cost =  0.9999999814023144
# Factor sparsity cost =  1.4
# factor precision cost =  0.995076224936783
# Factor sparsity cost =  1.5
# factor precision cost =  0.18085415922151912
# ---- 60
# Factor sparsity cost =  0.6
# factor precision cost =  0.91407188129766
# Factor sparsity cost =  0.7
# factor precision cost =  0.9780519994572805
# Factor sparsity cost =  0.8
# factor precision cost =  1.002057312110548
# Factor sparsity cost =  0.9
# factor precision cost =  1.005791775722791
# Factor sparsity cost =  1.0
# factor precision cost =  1.0
# Factor sparsity cost =  1.1
# factor precision cost =  0.996030578636198
# Factor sparsity cost =  1.2
# factor precision cost =  0.990048355181807
# Factor sparsity cost =  1.3
# factor precision cost =  0.958033920457822
# Factor sparsity cost =  1.4
# factor precision cost =  0.8161750233497502
# Factor sparsity cost =  1.5
# factor precision cost =  0.25641669977697207
# ---- 70
# Factor sparsity cost =  0.6
# factor precision cost =  1.0000000002371725
# Factor sparsity cost =  0.7
# factor precision cost =  0.9999999995741992
# Factor sparsity cost =  0.8
# factor precision cost =  1.0000000004026925
# Factor sparsity cost =  0.9
# factor precision cost =  1.0000000002599236
# Factor sparsity cost =  1.0
# factor precision cost =  1.0
# Factor sparsity cost =  1.1
# factor precision cost =  1.0000000002791516
# Factor sparsity cost =  1.2
# factor precision cost =  1.0000000001217497
# Factor sparsity cost =  1.3
# factor precision cost =  0.9999999995654176
# Factor sparsity cost =  1.4
# factor precision cost =  0.9981056336190907
# Factor sparsity cost =  1.5
# factor precision cost =  0.14043547900924802
# ---- 80
# Factor sparsity cost =  0.6
# factor precision cost =  0.9990087336239686
# Factor sparsity cost =  0.7
# factor precision cost =  1.000000504409714
# Factor sparsity cost =  0.8
# factor precision cost =  1.000000311626541
# Factor sparsity cost =  0.9
# factor precision cost =  1.0000001063103607
# Factor sparsity cost =  1.0
# factor precision cost =  1.0
# Factor sparsity cost =  1.1
# factor precision cost =  1.0000008265741742
# Factor sparsity cost =  1.2
# factor precision cost =  1.0000005225768251
# Factor sparsity cost =  1.3
# factor precision cost =  0.999999957482102
# Factor sparsity cost =  1.4
# factor precision cost =  0.9713547059529617
# Factor sparsity cost =  1.5
# factor precision cost =  0.2355919071477405

# %%
init_control_noisefree = bestControl[20]

# %%
dur = 100.
aln.params.duration = dur
max_it = 0
noise_realizations = 40
zero_init = aln.getZeroControl()
prec_vars = [0,1]
aln.params.sigma_ou = sigma_ou

cost_list = []
control_list = []

for i in i_range:
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.

    print("------- ", i, exc[i], inh[i], noise_realizations)
    
    for max_it in [0,1,2,10,20]:

        ##### zero control as input for uncontrolled cost
        setinit(initVars[i], aln)
        cost.setParams(1., 0., 1.)

        bestControl[i], bestState[i], cost_[i], runtime[i], grad[i], phi[i], costnode[i], total_cost_mean_std = aln.A1(
            zero_init, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it,
            tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
            t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
            control_variables_ = [0,1], prec_variables_ = prec_vars, transition_time_ = 0.75,
            noise_real=noise_realizations, init_params = initVars[i])

        cost_list.append([noise_realizations, cost_[i]])
        control_list.append(bestControl[i])
# Out:
# -------  20 0.4500000000000001 0.4750000000000002 40
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  287131.9199009075
# Gradient descend method:  None
# RUN  0 , total integrated cost mean =  287131.9199009075
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  294167.0409476648
# Gradient descend method:  None
# RUN  1 , total integrated cost =  33315.1615393855
# RUN  1 , total integrated cost mean =  33315.1615393855
# Improved over  1  iterations in  27.55094646901125  seconds by  88.67474703078221  percent.
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  293512.86498064856
# Gradient descend method:  None
# RUN  1 , total integrated cost =  42493.6647268088
# RUN  2 , total integrated cost =  8233.482637745368
# RUN  2 , total integrated cost mean =  8233.482637745368
# Improved over  2  iterations in  60.17790209699888  seconds by  97.19484778349045  percent.
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  294760.2205422244
# Gradient descend method:  None
# RUN  1 , total integrated cost =  29383.526051100827
# RUN  2 , total integrated cost =  11722.86235877463
# RUN  3 , total integrated cost =  3637.170949042434
# RUN  4 , total integrated cost =  2673.092331983478
# RUN  5 , total integrated cost =  2712.8736461400176
# RUN  6 , total integrated cost =  2652.5318547437887
# RUN  7 , total integrated cost =  2504.0408553141287
# RUN  8 , total integrated cost =  2347.8582618891946
# RUN  9 , total integrated cost =  2487.5163403516426
# RUN  10 , total integrated cost =  2505.008751022939
# RUN  10 , total integrated cost mean =  2505.008751022939
# Improved over  10  iterations in  325.0752897829807  seconds by  99.15015372616601  percent.
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  289402.7940657125
# Gradient descend method:  None
# RUN  1 , total integrated cost =  20034.097875139298
# RUN  2 , total integrated cost =  13604.366625663268
# RUN  3 , total integrated cost =  4502.876566959313
# RUN  4 , total integrated cost =  2614.0543972413916
# RUN  5 , total integrated cost =  2434.5153861384324
# RUN  6 , total integrated cost =  2506.168377280426
# RUN  7 , total integrated cost =  2736.881223924879
# RUN  8 , total integrated cost =  2761.0624737266967
# RUN  9 , total integrated cost =  2384.7793109868417
# RUN  10 , total integrated cost =  2390.5266332470846
# RUN  11 , total integrated cost =  2137.862835772944
# RUN  12 , total integrated cost =  2657.4543866067506
# RUN  13 , total integrated cost =  2241.1313333240905
# RUN  14 , total integrated cost =  2343.7494174792964
# RUN  15 , total integrated cost =  2548.744914448712
# RUN  16 , total integrated cost =  2582.124342942352
# RUN  17 , total integrated cost =  2704.388854533651
# RUN  18 , total integrated cost =  2301.785948808053
# RUN  19 , total integrated cost =  2457.6885891964394
# RUN  20 , total integrated cost =  2514.3375615397626
# RUN  20 , total integrated cost mean =  2514.3375615397626
# Improved over  20  iterations in  678.4253571679874  seconds by  99.13119789680785  percent.

# %%
cmap_ = layout.getcolormap()
darkgrey, midgrey, lightgrey, color_bi_updown, color_LC, color_bi_uposc = layout.getcolors()
exc_red = cmap_(3)
inh_blue=cmap_(0)
green = cmap_(2)
savepath = '../../../../../Talks_Conf_Workshops_Schools/2022_03_groupTalk/images'

cmap = matplotlib.cm.get_cmap('viridis')
i = 20
fs_ = 18

fig, ax = plt.subplots(4, 5, figsize=(20,10), constrained_layout=True)
#fig.suptitle('Control after X iterations', fontsize=fs_)

aln.params.duration = dur
aln.params.sigma_ou = sigma_ou
aln.run(control=control_list[0][:,:,100:-100])
pltrange = [0,1,2,3,4]
it_range = [0,1,2,10,20]

for k in range(len(pltrange)):
    max_it = pltrange[k]
    
    # control
    ax[3,k].plot(aln.t, control_list[max_it][0,0,100:-100]/5., color=exc_red, label='E')
    ax[3,k].plot(aln.t, control_list[max_it][0,1,100:-100]/5., color=inh_blue, label='I')
    ax[3,k].plot(aln.t, init_control_noisefree[0,0,1600:2601]/5., color=exc_red, linestyle=':')
    ax[3,k].plot(aln.t, init_control_noisefree[0,1,1600:2601]/5., color=inh_blue, linestyle=':')
    
    ax[3,k].set_ylim(-0.35, 0.5)
    ax[3,k].set_xlim(0,100)
    ax[3,k].set_xlabel('Time [ms]', fontsize=fs_)
    ax[3,k].tick_params(axis='y', labelsize=fs_)
    ax[3,k].tick_params(axis='x', labelsize=fs_)
    ax[3,k].grid(False)
    
    if k == 0:
        ax[3,k].set_ylabel('Control [nA]', fontsize=fs_)
        ax[3,k].tick_params(axis='y', labelsize=fs_)
        ax[3,k].set_yticks(np.arange(-0.25, 0.55, 0.25))
    else:
        ax[3,k].set_yticks([])
    
    # realization 1
    for j in range(3):
        setinit(initVars[i], aln)
        aln.run(control=control_list[max_it][:,:,100:-100])
        ax[j,k].plot(aln.t, aln.rates_exc[0,:], color=exc_red, label='E')
        ax[j,k].plot(aln.t, aln.rates_inh[0,:], color=inh_blue, label='I')
        ax[j,k].plot(aln.t, target[i][0,0,:], color=exc_red, linestyle='--', linewidth=1)
        ax[j,k].plot(aln.t, target[i][0,1,:], color=inh_blue, linestyle='--', linewidth=1)
        ax[j,k].set_xticks([])
        ax[j,k].grid(False)
        
        ax[j,k].set_ylim(0,110)
        ax[j,k].set_xlim(0,100)
        if k == 0:
            ax[j,k].set_ylabel('Activity [Hz]', fontsize=fs_)
            ax[j,k].tick_params(axis='y', labelsize=fs_)
        else:
            ax[j,k].set_yticks([])
        ax[j,k].axvspan( 75, 100, facecolor='grey', alpha=0.2, zorder=-1, hatch='///', edgecolor = 'grey')
        
    ax[0,k].set_title(r'$X = ${}'.format(it_range[k]), fontsize=fs_)
    
ax[0,0].legend(fontsize=fs_, loc='upper left')
ax[3,0].legend(fontsize=fs_, loc='upper left')
    
plt.savefig(os.path.join(savepath, 'Xiterations_3realizations.png'))
plt.show()

# %%
dur = 100.
aln.params.duration = dur
max_it = 20
noise_realizations = 40
init_control = control_list[-1][:,:,100:-100]
prec_vars = [0,1]
aln.params.sigma_ou = sigma_ou

cost_list_ = []
control_list_ = []

for i in i_range:
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.

    print("------- ", i, exc[i], inh[i], noise_realizations)
    
    for w_s in [100, 1000, 10000]:

        ##### zero control as input for uncontrolled cost
        setinit(initVars[i], aln)
        cost.setParams(1., 0., w_s)

        bestControl[i], bestState[i], cost_[i], runtime[i], grad[i], phi[i], costnode[i], total_cost_mean_std = aln.A1(
            init_control, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it,
            tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
            t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
            control_variables_ = [0,1], prec_variables_ = prec_vars, transition_time_ = 0.75,
            noise_real=noise_realizations, init_params = initVars[i])

        cost_list_.append([noise_realizations, cost_[i]])
        control_list_.append(bestControl[i])
# Out:
# -------  20 0.4500000000000001 0.4750000000000002 40
# set cost params:  1.0 0.0 100
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3604.2900700386963
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3366.9223724709846
# RUN  2 , total integrated cost =  3238.2552944827667
# RUN  3 , total integrated cost =  3091.6020947896054
# RUN  4 , total integrated cost =  3167.175597388487
# RUN  5 , total integrated cost =  2896.6159100089953
# RUN  6 , total integrated cost =  3255.467341582659
# RUN  7 , total integrated cost =  3428.331181503011
# RUN  8 , total integrated cost =  2989.4670167573554
# RUN  9 , total integrated cost =  2954.3493798824793
# RUN  10 , total integrated cost =  3078.1503465302
# RUN  11 , total integrated cost =  2949.7005840173097
# RUN  12 , total integrated cost =  3155.7146631330907
# RUN  13 , total integrated cost =  3357.082736978824
# no cost improvement
# RUN  14 , total integrated cost =  3472.0027808689038
# RUN  15 , total integrated cost =  2884.364222563904
# RUN  16 , total integrated cost =  3614.4221724175927
# RUN  17 , total integrated cost =  2804.1020169329163
# RUN  18 , total integrated cost =  3318.8959056242966
# RUN  19 , total integrated cost =  3140.7858391381005
# RUN  20 , total integrated cost =  3051.808332094218
# RUN  20 , total integrated cost mean =  3051.808332094218
# Improved over  20  iterations in  737.0512682609842  seconds by  15.328448243860322  percent.
# set cost params:  1.0 0.0 1000
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  10023.938503398163
# Gradient descend method:  None
# RUN  1 , total integrated cost =  9760.88246260494
# RUN  2 , total integrated cost =  9653.992379779384
# RUN  3 , total integrated cost =  9196.844042452904
# RUN  4 , total integrated cost =  8907.700646054449
# RUN  5 , total integrated cost =  8745.9891336354
# RUN  6 , total integrated cost =  9005.127407338572
# RUN  7 , total integrated cost =  8321.751341889962
# RUN  8 , total integrated cost =  8103.284827760869
# RUN  9 , total integrated cost =  9083.641550606033
# RUN  10 , total integrated cost =  8330.401718762767
# RUN  11 , total integrated cost =  8377.019688697894
# RUN  12 , total integrated cost =  7997.307366484805
# RUN  13 , total integrated cost =  8366.975348436219
# RUN  14 , total integrated cost =  8305.340071455044
# RUN  15 , total integrated cost =  8535.825978893765
# RUN  16 , total integrated cost =  8862.716902838263
# RUN  17 , total integrated cost =  8519.19755225712
# RUN  18 , total integrated cost =  9988.650379987079
# no cost improvement
# RUN  19 , total integrated cost =  8951.668689674272
# RUN  20 , total integrated cost =  8311.870878218706
# RUN  20 , total integrated cost mean =  8311.870878218706
# Improved over  20  iterations in  787.1698602160031  seconds by  17.07978979119892  percent.
# set cost params:  1.0 0.0 10000
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  79587.15982288653
# Gradient descend method:  None
# RUN  1 , total integrated cost =  60644.64645789641
# RUN  2 , total integrated cost =  60309.908872404645
# RUN  3 , total integrated cost =  57877.32785072851
# RUN  4 , total integrated cost =  58117.92422306167
# RUN  5 , total integrated cost =  57102.46141248858
# RUN  6 , total integrated cost =  57092.71959814449
# RUN  7 , total integrated cost =  61026.030947923195
# RUN  8 , total integrated cost =  62258.6409888488
# no cost improvement
# RUN  9 , total integrated cost =  59272.27659761419
# RUN  10 , total integrated cost =  54518.21498086724
# RUN  10 , total integrated cost mean =  54518.21498086724
# Improved over  10  iterations in  392.0037750620104  seconds by  31.49873032007649  percent.

# %%
aln.params.duration = dur
aln.run(control=control_list[0][:,:,100:-100])
pltrange = [1, 100, 1000, 10000]
it_range = [20]

li = []
li.append(control_list[-1])

#li.append(control_list_[-1])
#li.append(control_list_[0])
#li.append(control_list_[1])

for k in range(len(control_list_)):
    li.append(control_list_[k])

fig, ax = plt.subplots(4, len(li), figsize=(16,10), constrained_layout=True)
fig.suptitle('Control after 20 + 20 iterations', fontsize=fs_)

for k in range(len(pltrange)):
    
    # control
    ax[3,k].plot(aln.t, li[k][0,0,100:-100]/5., color=exc_red, label='E')
    ax[3,k].plot(aln.t, li[k][0,1,100:-100]/5., color=inh_blue, label='I')
    ax[3,k].plot(aln.t, init_control_noisefree[0,0,1600:2601]/5., color=exc_red, linestyle=':')
    ax[3,k].plot(aln.t, init_control_noisefree[0,1,1600:2601]/5., color=inh_blue, linestyle=':')
    
    ax[3,k].set_ylim(-0.35, 0.5)
    ax[3,k].set_xlim(0,100)
    ax[3,k].set_xlabel('Time [ms]', fontsize=fs_)
    ax[3,k].tick_params(axis='y', labelsize=fs_)
    ax[3,k].tick_params(axis='x', labelsize=fs_)
    ax[3,k].grid(False)
    
    if k == 0:
        ax[3,k].set_yticks(np.arange(-0.25, 0.55, 0.25))
        ax[3,k].set_ylabel('Control [nA]', fontsize=fs_)
        ax[3,k].tick_params(axis='y', labelsize=fs_)
        
    else:
        ax[3,k].set_yticks([])
    
    # realization 1
    for j in range(3):
        setinit(initVars[i], aln)
        aln.run(control=li[k][:,:,100:-100])
        ax[j,k].plot(aln.t, aln.rates_exc[0,:], color=exc_red, label='E')
        ax[j,k].plot(aln.t, aln.rates_inh[0,:], color=inh_blue, label='I')
        ax[j,k].plot(aln.t, target[i][0,0,:], color=exc_red, linestyle='--', linewidth=1)
        ax[j,k].plot(aln.t, target[i][0,1,:], color=inh_blue, linestyle='--', linewidth=1)
        ax[j,k].set_xticks([])
        ax[j,k].grid(False)
        
        ax[j,k].set_ylim(0,110)
        ax[j,k].set_xlim(0,100)
        if k == 0:
            ax[j,k].set_ylabel('Activity [Hz]', fontsize=fs_)
            ax[j,k].tick_params(axis='y', labelsize=fs_)
        else:
            ax[j,k].set_yticks([])
        ax[j,k].axvspan( 75, 100, facecolor='grey', alpha=0.2, zorder=-1, hatch='///', edgecolor = 'grey')
        
    ax[0,k].set_title(r'$W_1 = ${}'.format(pltrange[k]), fontsize=fs_)
    ax[3,k].set_title(r'$a_E = ${} nA'.format(round(np.amax(li[k])/5., 4)), fontsize=fs_)
    
ax[0,0].legend(fontsize=fs_, loc='upper left')
ax[3,0].legend(fontsize=fs_, loc='upper left')
    
plt.savefig(os.path.join(savepath, 'Xiterations_3realizations_w1-1000-10000-100000.png'))
plt.show()

# %%
aln.params.duration = dur
max_it = 50
noise_realizations = 0
zero_init = aln.getZeroControl()
init_ = 1.1 * init_control_noisefree[:,:,1600:2601]
prec_vars = [0,1]
aln.params.sigma_ou = 0. # sigma_ou

cost_det = []
control_det = []

for i in i_range:
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.

    print("------- ", i, exc[i], inh[i], noise_realizations)
    
    ##### zero control as input for uncontrolled cost
    setinit(initVars[i], aln)
    cost.setParams(1., 0., 1.)

    bestControl[i], bestState[i], cost_[i], runtime[i], grad[i], phi[i], costnode[i], total_cost_mean_std = aln.A1(
        zero_init, target_det, c_scheme, u_mat, u_scheme, max_iteration_ = max_it,
        tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
        t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
        control_variables_ = [0,1], prec_variables_ = prec_vars, transition_time_ = 0.75,
        noise_real=noise_realizations, init_params = initVars[i])

    cost_det.append([noise_realizations, cost_[i]])
    control_det.append(bestControl[i])
        
    plt.plot(aln.t, aln.rates_exc[0,:])
# Out:
# -------  20 0.4500000000000001 0.4750000000000002 0
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  294305.5800601015
# RUN  0 , total integrated cost =  294305.5800601015
# Gradient descend method:  None
# RUN  1 , total integrated cost =  19624.62867219116
# RUN  2 , total integrated cost =  11275.991252484924
# RUN  3 , total integrated cost =  1107.6080743653754
# RUN  4 , total integrated cost =  924.055320085553
# RUN  5 , total integrated cost =  294.75105010042193
# RUN  6 , total integrated cost =  188.33889577956637
# RUN  7 , total integrated cost =  186.24152877995465
# RUN  8 , total integrated cost =  185.04135757231063
# RUN  9 , total integrated cost =  184.55918419468045
# RUN  10 , total integrated cost =  184.2732906994103
# RUN  11 , total integrated cost =  145.21670640378065
# RUN  12 , total integrated cost =  143.65173783186538
# RUN  13 , total integrated cost =  141.35433762098432
# RUN  14 , total integrated cost =  124.04410838178953
# RUN  15 , total integrated cost =  114.7017155806952
# RUN  16 , total integrated cost =  108.17968654932284
# RUN  17 , total integrated cost =  102.97292565595978
# RUN  18 , total integrated cost =  98.89110314521749
# RUN  19 , total integrated cost =  95.90756229919972
# RUN  20 , total integrated cost =  93.40053653018182
# RUN  30 , total integrated cost =  83.44874995315993
# RUN  40 , total integrated cost =  80.56519169664428
# RUN  50 , total integrated cost =  79.25488118357434
# RUN  50 , total integrated cost =  79.25488118357434
# Improved over  50  iterations in  3.2308997830259614  seconds by  99.97307054756917  percent.

# %%
fig, ax = plt.subplots(figsize=(10,4), constrained_layout=True)
ms_ = 10

mean_cost = np.zeros( 21 )
for k in range(len(mean_cost)):
    mean_cost[k] = np.mean(cost_list[-1][1][:,k])

#ax[0].set_title(r'$\sigma^{OU} = 0$')
ax.plot(np.arange(0,51,1), cost_det[0][1], color='green', marker='x', markersize=ms_,
        linestyle='', label=r'$\sigma^{OU}=0$')
ax.plot(np.arange(0,21,1), mean_cost[:], color='red', marker='x', markersize=ms_,
        linestyle='', label=r'$\sigma^{OU}=0.1$')
ax.set_yscale('log')
ax.set_yticks([10,100,1e3,1e4, 1e5])
ax.set_xlim([0,50])
ax.set_xlabel('Iteration', fontsize=fs_)
ax.set_ylabel('Cost', fontsize=fs_)
ax.tick_params(axis='x', labelsize=fs_)
ax.tick_params(axis='y', labelsize=fs_)
ax.legend(fontsize=fs_)
ax.grid(False)


#ax[1].set_title(r'$\sigma^{OU} = 0.1$')

plt.savefig(os.path.join(savepath, 'cost_evolution.png'))
plt.show()
