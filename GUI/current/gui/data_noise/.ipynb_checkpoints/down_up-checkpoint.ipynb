# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import sys
import pickle
import matplotlib
import ipyparams

path = os.getcwd().split(os.sep + 'GUI')[0]
if path not in sys.path:
    print("not here")
    sys.path.append(path)

from neurolib.models.aln import ALNModel
from neurolib.utils import plotFunctions as plotFunc
from neurolib.utils import func_optimize as fo
from neurolib.utils import costFunctions as cost
import neurolib.dashboard.functions as functions
import neurolib.dashboard.data as data
import neurolib.dashboard.layout as layout
    
# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2 

#path = os.path.join(os.getcwd(), "plots")

cmap_ = layout.getcolormap()
darkgrey, midgrey, lightgrey, color_bi_updown, color_LC, color_bi_uposc = layout.getcolors_rgba()
exc_red = cmap_(3)
inh_blue=cmap_(0)
green = cmap_(2)
# Out:
# not here

# %%
aln = ALNModel()
N = aln.params.N

data.set_parameters(aln)

state_vars = aln.state_vars
init_vars = aln.init_vars

##############################################################
def setinit(init_vars_, model):
    state_vars = model.state_vars
    init_vars = model.init_vars
    for iv in range(len(init_vars)):
        for sv in range(len(state_vars)):
            if state_vars[sv] in init_vars[iv]:
                #print("set init vars ", )
                if model.params[init_vars[iv]].ndim == 2:
                    model.params[init_vars[iv]][0,:] = init_vars_[sv]
                else:
                    model.params[init_vars[iv]][0] = init_vars_[sv]
                    
##############################################################               
def setmaxmincontrol(max_c_c, min_c_c, max_c_r, min_c_r):
    import numpy as np
    
    max_cntrl = np.zeros(( 6 ))
    min_cntrl = np.zeros(( 6 ))
    
    max_cntrl[0] = max_c_c
    min_cntrl[0] = min_c_c
    max_cntrl[1] = max_c_c
    min_cntrl[1] = min_c_c
    max_cntrl[2] = max_c_r
    min_cntrl[2] = min_c_r
    max_cntrl[3] = max_c_r
    min_cntrl[3] = min_c_r
    max_cntrl[4] = max_c_r
    min_cntrl[4] = min_c_r
    max_cntrl[5] = max_c_r
    min_cntrl[5] = min_c_r
            
    return max_cntrl, min_cntrl

# %%
points = np.array( [ [0.4, 0.35], [0.4, 0.4], [0.45, 0.4], [0.425, 0.45], [0.475, 0.45], [0.45, 0.5],
                    [0.5, 0.5], [0.45, 0.65], [0.5, 0.65], [0.55, 0.65] ])

# 10 points, two costs, 4 methods, N

# %%
def create_dict(task, point, cost_params, init, init_vars, target, sigma_array, N_max_array, max_it):
    return dict( {'task':task, 'point':point, 'cost_params':cost_params, 'init':init, 'init_vars':init_vars,
            'target':target, 'sigma':sigma_array, 'N_array':N_max_array,
            'cost':np.zeros(( len(sigma_array), 4, len(N_max_array), max_it )) } )

# %%
dict_list = []
for p in points:
    dict_list.append(create_dict('DU', p, None, [0], None, None, np.arange(0.01, 0.081, 0.01),
                                 [1,2,10,30], 40) )

# %%
dict_file = "DU_1E.pickle"

if False:
    file=open(dict_file, "wb")
    pickle.dump(dict_list, file)
    file.close()

if True:
    file = open(dict_file, "rb")
    dict_list = pickle.load(file)
    file.close()

# %%
dur_pre = 10
dur_post = 10
dur = 200.
dur_comp = 2000.
dt = aln.params.dt
T = int(1 + dur / dt)

prec_vars = [0,1]
trans_time = 0.8

n_pre = int(np.around(dur_pre/aln.params.dt,1))
n_post = int(np.around(dur_post/aln.params.dt,1))

tol = 1e-16
start_step = 10.
c_scheme = np.zeros(( 1,1 ))
c_scheme[0,0] = 1.
u_mat = np.identity(1)
u_scheme = np.array([[1.]])

maxC = [5., -5., 0.18, 0.]
n_dur = int(np.around(dur/aln.params.dt + 1.,1))
max_cntrl, min_cntrl = setmaxmincontrol(maxC[0], maxC[1], maxC[2], maxC[3])

noise_realizations_final = 10000
noise_realizations_target_compute = 10000
init_it = 5

# %%
# get init vars without noise
aln = ALNModel()
data.set_parameters(aln)
aln.params.duration = dur_comp

# initial without noise
control0 = aln.getZeroControl()

for d in dict_list:
    print("Point = ", d['point'])
    aln.params.ext_exc_current = d['point'][0] * 5.
    aln.params.ext_inh_current = d['point'][1] * 5.
    
    aln.params.duration = dur_comp
    control0[0,0,:500] = -5.

    aln.run(control=control0)

    init_state_vars = np.zeros(( len(state_vars) ))
    for j in range(len(state_vars)):
        if aln.state[state_vars[j]].size == 1:
            init_state_vars[j] = aln.state[state_vars[j]][0]
        else:
            init_state_vars[j] = aln.state[state_vars[j]][0,-1]

    initVars = init_state_vars.copy()
    d['init_vars'] = initVars
    
    control0[0,0,:500] = 5.
    d['target'] = []
    d['cost_params'] = []
    
    for s in d['sigma']:
        aln.params.sigma_ou = s
        aln.params.duration = dur_comp
        
        stateswitchcount = 0
        target_rates_e = []
        target_rates_i = []

        for j in range(noise_realizations_target_compute):
            if j % 1000 == 0:
                print(j)
            aln.run(control=control0)
            #plt.plot(aln.t, aln.rates_exc[0,:])
            if np.amin(aln.rates_exc[0,1000:]) < 1.:
                #print("fell in down state, repeat")
                j -= 1
                stateswitchcount += 1
                if stateswitchcount > 0.8 * noise_realizations_target_compute:
                    print("UNSTABLE: point, sigma ", d['point'], s)
                    break
                continue
            target_rates_e.append(aln.rates_exc[0,1000:])
            target_rates_i.append(aln.rates_inh[0,1000:])
        
        #plt.show()
            

        aln.params.duration = dur
        target = aln.getZeroTarget()
        target[:,0,:] = np.mean(target_rates_e)
        target[:,1,:] = np.mean(target_rates_i)
        stddev = np.std(target_rates_e) + np.std(target_rates_i)
        
        d['target'].append(target)
        d['cost_params'].append( [1. / ( stddev * (1. - trans_time) * dur ), 0., 1.] )
        
file=open(dict_file, "wb")
pickle.dump(dict_list, file)
file.close()
# Out:
# Point =  [0.4  0.35]
# Exception ignored on calling ctypes callback function: <function ExecutionEngine._raw_object_cache_notify at 0x7f847d266040>
# Traceback (most recent call last):
#   File "/home/lena/.local/lib/python3.9/site-packages/llvmlite/binding/executionengine.py", line 171, in _raw_object_cache_notify
#     def _raw_object_cache_notify(self, data):
# KeyboardInterrupt:
# 0
# 1000
# 2000
# 3000
# 4000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_243602/161572449.py in <module>
#      42             if j % 1000 == 0:
#      43                 print(j)
# ---> 44             aln.run(control=control0)
#      45             #plt.plot(aln.t, aln.rates_exc[0,:])
#      46             if np.amin(aln.rates_exc[0,1000:]) < 1.:
#
# ~/Promotion/neurolib_dev_optControl/neurolib/models/model.py in run(self, inputs, chunkwise, chunksize, bold, append, append_outputs, continue_run, control)
#     188         if chunkwise is False:
#     189             if self.name == 'aln':
# --> 190                 self.integrate(append_outputs=append, simulate_bold=bold, control=cntrl)
#     191             else:
#     192                 self.integrate(append_outputs=append, simulate_bold=bold)
#
# ~/Promotion/neurolib_dev_optControl/neurolib/models/model.py in integrate(self, append_outputs, simulate_bold, control)
#     232         #print("before integration")
#     233         if self.name == 'aln':
# --> 234             t, *variables = self.integration(self.params, control=control)
#     235         else:
#     236             t, *variables = self.integration(self.params)
#
# ~/Promotion/neurolib_dev_optControl/neurolib/models/aln/timeIntegration.py in timeIntegration(params, control)
#     279     ext_ei_rate = ap.adjust_shape(params["ext_ei_rate"], rates_exc)
#     280     ext_ie_rate = ap.adjust_shape(params["ext_ie_rate"], rates_exc)
# --> 281     ext_ii_rate = ap.adjust_shape(params["ext_ii_rate"], rates_exc)
#     282
#     283     control_ext = control.copy()
#
# ~/Promotion/neurolib_dev_optControl/neurolib/utils/adjust_params.py in adjust_shape(original, target)
#      36     else:
#      37         rep_x = 1
# ---> 38     original = np.tile(original, (1, rep_x))
#      39
#      40     # cut from end because the beginning can be initial condition
#
# <__array_function__ internals> in tile(*args, **kwargs)
#
# ~/.local/lib/python3.9/site-packages/numpy/lib/shape_base.py in tile(A, reps)
#    1256         for dim_in, nrep in zip(c.shape, tup):
#    1257             if nrep != 1:
# -> 1258                 c = c.reshape(-1, n).repeat(nrep, 0)
#    1259             n //= dim_in
#    1260     return c.reshape(shape_out)
#
# KeyboardInterrupt:

# %%
print(dict_list[0]['cost_params'])
# Out:
# [[0.020161370502275046, 0.0, 1.0], [0.010031022525775904, 0.0, 1.0], [0.006621247555591508, 0.0, 1.0], [0.004883980090759534, 0.0, 1.0], [0.0038007694143633057, 0.0, 1.0], [0.0031027349315870777, 0.0, 1.0], [0.0026507988833317712, 0.0, 1.0], [0.002341798773127221, 0.0, 1.0]]

# %%
#len(sigma_array), 4, N_max, max_it

##### METHOD 1
method_ind = 0

for d in dict_list:
    print("Point = ", d['point'])
    aln.params.ext_exc_current = d['point'][0] * 5.
    aln.params.ext_inh_current = d['point'][1] * 5.
    
    max_it = d['cost'].shape[3]
    
    for s_ind in range(len(d['sigma'])):
        
        print("sigma = ", d['sigma'][s_ind])
        
        s = d['sigma'][s_ind]
        aln.params.sigma_ou = s
        c_p = d['cost_params'][s_ind]
        cost.setParams(c_p[0], c_p[1], c_p[2])
        aln.params.duration = dur
        zero_init = aln.getZeroControl()
        
        target_ = d['target'][s_ind].copy()
        target_[0,0,:int(trans_time * dur / aln.params.dt)] = -1000
        target_[0,1,:int(trans_time * dur / aln.params.dt)] = -1000
        
        if d['cost'][s_ind, method_ind, n_ind, 0] == 0.:
        
            setinit(d['init_vars'], aln)
            cost_final = 0.

            for n_ in range(noise_realizations_final):
                state_ = fo.updateState(aln, zero_init)
                cost_final += cost.numba_cost_precision_int(1, T, dt, d['cost_params'][s_ind][0],
                                                               state_, target_, list(prec_vars) )

            d['cost'][s_ind, :, :, 0] = cost_final/noise_realizations_final
            
        print('cost = ', d['cost'][s_ind, 0, 0, 0])    
        
        for n_ind in range(len(d['N_array'])):
            
            n_max = d['N_array'][n_ind]
            print("n max = ", n_max)
            
            if d['cost'][s_ind, 0, n_ind, -1] > 0.:
                continue
            
            
            aln.params.duration = dur
            control_init = aln.getZeroControl()
        
            for i_it in range(1, max_it, 1):
                
                print("iteration = ", i_it)

                if i_it <= init_it:
                    c_vars = d['init']
                else:
                    c_vars = [0,1]
                    
                n_ = 0
                control_sum = aln.getZeroControl()
                
                while n_ < n_max:
                
                    print('--------', n_)

                    aln.params.duration = dur
                    setinit(d['init_vars'], aln)

                    bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                        control_init, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_ = 1,
                        tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                        t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                        control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                        noise_real=0, init_params = d['init_vars'])
                    
                    control_sum += bc[:,:,n_pre:-n_post]
                    n_ += 1
    

                control_init = control_sum / n_max
        
                aln.params.duration = dur
                setinit(d['init_vars'], aln)

                cost_final = 0.

                for j in range(noise_realizations_final):
                    state_ = fo.updateState(aln, control_init)
                    cost_final += cost.numba_cost_precision_int(1, T, dt, d['cost_params'][s_ind][0],
                                                                   state_, target_, list(prec_vars) )
                    cost_final += cost.numba_cost_sparsity_int(1, 6, T, d['cost_params'][s_ind][2],
                                                                   dt, control_init)

                d['cost'][s_ind, method_ind, n_ind, i_it] = cost_final/noise_realizations_final
                print('cost = ', d['cost'][s_ind, method_ind, n_ind, i_it])
                
                file=open(dict_file, "wb")
                pickle.dump(dict_list, file)
                file.close()
# Out:
# Point =  [0.4  0.35]
# sigma =  0.01
# set cost params:  0.020161370502275046 0.0 1.0
# cost =  1619.9625034911228
# n max =  10
# n max =  10
# n max =  10
# iteration =  1
# -------- 0
# interpolate adjoint :  True True True
# initial cost =  1625.6283144330826
# RUN  0 , total integrated cost =  1625.6283144330826
# Gradient descend method:  None
# RUN  1 , total integrated cost =  182.72283744152992
# RUN  1 , total integrated cost =  182.72283744152992
# Improved over  1  iterations in  0.03711639501852915  seconds by  88.75986375118889  percent.
# -------- 1
# interpolate adjoint :  True True True
# initial cost =  1613.6326494209623
# RUN  0 , total integrated cost =  1613.6326494209623
# Gradient descend method:  None
# RUN  1 , total integrated cost =  143.72089433957797
# RUN  1 , total integrated cost =  143.72089433957797
# Improved over  1  iterations in  0.023316305014304817  seconds by  91.0933325257672  percent.
# -------- 2
# interpolate adjoint :  True True True
# initial cost =  1622.7993825780864
# RUN  0 , total integrated cost =  1622.7993825780864
# Gradient descend method:  None
# RUN  1 , total integrated cost =  188.91895741329208
# RUN  1 , total integrated cost =  188.91895741329208
# Improved over  1  iterations in  0.021448070008773357  seconds by  88.3584527180949  percent.
# -------- 3
# interpolate adjoint :  True True True
# initial cost =  1604.8922626236158
# RUN  0 , total integrated cost =  1604.8922626236158
# Gradient descend method:  None
# RUN  1 , total integrated cost =  334.61919841885117
# RUN  1 , total integrated cost =  334.61919841885117
# Improved over  1  iterations in  0.0228852599975653  seconds by  79.15005223641438  percent.
# -------- 4
# interpolate adjoint :  True True True
# initial cost =  1612.1600714230638
# RUN  0 , total integrated cost =  1612.1600714230638
# Gradient descend method:  None
# RUN  1 , total integrated cost =  245.90966256633394
# RUN  1 , total integrated cost =  245.90966256633394
# Improved over  1  iterations in  0.02327821496874094  seconds by  84.74657281709824  percent.
# -------- 5
# interpolate adjoint :  True True True
# initial cost =  1617.4995990761292
# RUN  0 , total integrated cost =  1617.4995990761292
# Gradient descend method:  None
# RUN  1 , total integrated cost =  180.79786604223742
# RUN  1 , total integrated cost =  180.79786604223742
# Improved over  1  iterations in  0.02318866300629452  seconds by  88.82238572760673  percent.
# -------- 6
# interpolate adjoint :  True True True
# initial cost =  1606.9055200734927
# RUN  0 , total integrated cost =  1606.9055200734927
# Gradient descend method:  None
# RUN  1 , total integrated cost =  276.62352500827353
# RUN  1 , total integrated cost =  276.62352500827353
# Improved over  1  iterations in  0.023514273983892053  seconds by  82.78532735417934  percent.
# -------- 7
# interpolate adjoint :  True True True
# initial cost =  1619.3514235631965
# RUN  0 , total integrated cost =  1619.3514235631965
# Gradient descend method:  None
# RUN  1 , total integrated cost =  149.91459090201843
# RUN  1 , total integrated cost =  149.91459090201843
# Improved over  1  iterations in  0.02386777801439166  seconds by  90.7423065357766  percent.
# -------- 8
# interpolate adjoint :  True True True
# initial cost =  1615.3177575980421
# RUN  0 , total integrated cost =  1615.3177575980421
# Gradient descend method:  None
# RUN  1 , total integrated cost =  218.86691378815843
# RUN  1 , total integrated cost =  218.86691378815843
# Improved over  1  iterations in  0.023987867985852063  seconds by  86.45053502577655  percent.
# -------- 9
# interpolate adjoint :  True True True
# initial cost =  1630.1376316400376
# RUN  0 , total integrated cost =  1630.1376316400376
# Gradient descend method:  None
# RUN  1 , total integrated cost =  172.45256504326002
# RUN  1 , total integrated cost =  172.45256504326002
# Improved over  1  iterations in  0.022495208017062396  seconds by  89.42098129041042  percent.
# cost =  226.98957378434477
# iteration =  2
# -------- 0
# interpolate adjoint :  True True True
# initial cost =  201.62041454007567
# RUN  0 , total integrated cost =  201.62041454007567
# Gradient descend method:  None
# RUN  1 , total integrated cost =  55.12138614692989
# RUN  1 , total integrated cost =  55.12138614692989
# Improved over  1  iterations in  0.02119975397363305  seconds by  72.66081102319451  percent.
# -------- 1
# interpolate adjoint :  True True True
# initial cost =  242.20212931648499
# RUN  0 , total integrated cost =  242.20212931648499
# Gradient descend method:  None
# RUN  1 , total integrated cost =  75.35887520328171
# RUN  1 , total integrated cost =  75.35887520328171
# Improved over  1  iterations in  0.02340187196386978  seconds by  68.885956776701  percent.
# -------- 2
# interpolate adjoint :  True True True
# initial cost =  258.0744829845158
# RUN  0 , total integrated cost =  258.0744829845158
# Gradient descend method:  None
# RUN  1 , total integrated cost =  97.69695342603436
# RUN  1 , total integrated cost =  97.69695342603436
# Improved over  1  iterations in  0.021172767970710993  seconds by  62.14389260952387  percent.
# -------- 3
# interpolate adjoint :  True True True
# initial cost =  219.2898673800872
# RUN  0 , total integrated cost =  219.2898673800872
# Gradient descend method:  None
# RUN  1 , total integrated cost =  55.23798891669762
# RUN  1 , total integrated cost =  55.23798891669762
# Improved over  1  iterations in  0.023404335021041334  seconds by  74.81051469607777  percent.
# -------- 4
# interpolate adjoint :  True True True
# initial cost =  190.39391605230983
# RUN  0 , total integrated cost =  190.39391605230983
# Gradient descend method:  None
# RUN  1 , total integrated cost =  46.304484378161085
# RUN  1 , total integrated cost =  46.304484378161085
# Improved over  1  iterations in  0.02676219103159383  seconds by  75.67964074784871  percent.
# -------- 5
# interpolate adjoint :  True True True
# initial cost =  234.85759440098627
# RUN  0 , total integrated cost =  234.85759440098627
# Gradient descend method:  None
# RUN  1 , total integrated cost =  74.97644151626702
# RUN  1 , total integrated cost =  74.97644151626702
# Improved over  1  iterations in  0.02445046795764938  seconds by  68.07578579372856  percent.
# -------- 6
# interpolate adjoint :  True True True
# initial cost =  214.29003228840725
# RUN  0 , total integrated cost =  214.29003228840725
# Gradient descend method:  None
# RUN  1 , total integrated cost =  74.79390717880496
# RUN  1 , total integrated cost =  74.79390717880496
# Improved over  1  iterations in  0.0286521099624224  seconds by  65.09687997146698  percent.
# -------- 7
# interpolate adjoint :  True True True
# initial cost =  204.6044924021151
# RUN  0 , total integrated cost =  204.6044924021151
# Gradient descend method:  None
# RUN  1 , total integrated cost =  53.285694938956055
# RUN  1 , total integrated cost =  53.285694938956055
# Improved over  1  iterations in  0.026088011043611914  seconds by  73.95673266340988  percent.
# -------- 8
# interpolate adjoint :  True True True
# initial cost =  235.66258507424837
# RUN  0 , total integrated cost =  235.66258507424837
# Gradient descend method:  None
# RUN  1 , total integrated cost =  81.13450933296663
# RUN  1 , total integrated cost =  81.13450933296663
# Improved over  1  iterations in  0.026226178975775838  seconds by  65.57174771404455  percent.
# -------- 9
# interpolate adjoint :  True True True
# initial cost =  206.38112440507786
# RUN  0 , total integrated cost =  206.38112440507786
# Gradient descend method:  None
# RUN  1 , total integrated cost =  59.53123030370128
# RUN  1 , total integrated cost =  59.53123030370128
# Improved over  1  iterations in  0.027360748033970594  seconds by  71.15471171343393  percent.
# cost =  68.12622962165705
# iteration =  3
# -------- 0
# interpolate adjoint :  True True True
# initial cost =  64.81911952271493
# RUN  0 , total integrated cost =  64.81911952271493
# Gradient descend method:  None
# RUN  1 , total integrated cost =  21.43052853971021
# RUN  1 , total integrated cost =  21.43052853971021
# Improved over  1  iterations in  0.02322372200433165  seconds by  66.93795179954552  percent.
# -------- 1
# interpolate adjoint :  True True True
# initial cost =  68.43729577104685
# RUN  0 , total integrated cost =  68.43729577104685
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22.9020680322267
# RUN  1 , total integrated cost =  22.9020680322267
# Improved over  1  iterations in  0.0247727949754335  seconds by  66.53569114004111  percent.
# -------- 2
# interpolate adjoint :  True True True
# initial cost =  62.42406355946344
# RUN  0 , total integrated cost =  62.42406355946344
# Gradient descend method:  None
# RUN  1 , total integrated cost =  20.325369691250664
# RUN  1 , total integrated cost =  20.325369691250664
# Improved over  1  iterations in  0.025309584045317024  seconds by  67.4398484618207  percent.
# -------- 3
# interpolate adjoint :  True True True
# initial cost =  67.81768157615734
# RUN  0 , total integrated cost =  67.81768157615734
# Gradient descend method:  None
# RUN  1 , total integrated cost =  21.086153746742266
# RUN  1 , total integrated cost =  21.086153746742266
# Improved over  1  iterations in  0.02562634798232466  seconds by  68.90758684656137  percent.
# -------- 4
# interpolate adjoint :  True True True
# initial cost =  69.64420954796513
# RUN  0 , total integrated cost =  69.64420954796513
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22.463549629387696
# RUN  1 , total integrated cost =  22.463549629387696
# Improved over  1  iterations in  0.024526573019102216  seconds by  67.74527304539701  percent.
# -------- 5
# interpolate adjoint :  True True True
# initial cost =  67.49640483837639
# RUN  0 , total integrated cost =  67.49640483837639
# Gradient descend method:  None
# RUN  1 , total integrated cost =  20.806350611257994
# RUN  1 , total integrated cost =  20.806350611257994
# Improved over  1  iterations in  0.025849359983112663  seconds by  69.17413503566617  percent.
# -------- 6
# interpolate adjoint :  True True True
# initial cost =  72.21682807195083
# RUN  0 , total integrated cost =  72.21682807195083
# Gradient descend method:  None
# RUN  1 , total integrated cost =  23.12903620858868
# RUN  1 , total integrated cost =  23.12903620858868
# Improved over  1  iterations in  0.024962341005448252  seconds by  67.97278857838393  percent.
# -------- 7
# interpolate adjoint :  True True True
# initial cost =  66.069049886984
# RUN  0 , total integrated cost =  66.069049886984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  18.195938643955788
# RUN  1 , total integrated cost =  18.195938643955788
# Improved over  1  iterations in  0.02420207898830995  seconds by  72.4592094557417  percent.
# -------- 8
# interpolate adjoint :  True True True
# initial cost =  66.412052439665
# RUN  0 , total integrated cost =  66.412052439665
# Gradient descend method:  None
# RUN  1 , total integrated cost =  18.28049557938956
# RUN  1 , total integrated cost =  18.28049557938956
# Improved over  1  iterations in  0.024267185013741255  seconds by  72.47412945715344  percent.
# -------- 9
# interpolate adjoint :  True True True
# initial cost =  67.47581326515801
# RUN  0 , total integrated cost =  67.47581326515801
# Gradient descend method:  None
# RUN  1 , total integrated cost =  21.944530486078527
# RUN  1 , total integrated cost =  21.944530486078527
# Improved over  1  iterations in  0.022539498982951045  seconds by  67.47793109236986  percent.
# cost =  22.32818100001792
# iteration =  4
# -------- 0
# interpolate adjoint :  True True True
# initial cost =  21.864171812424942
# RUN  0 , total integrated cost =  21.864171812424942
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14.574310923353309
# RUN  1 , total integrated cost =  14.574310923353309
# Improved over  1  iterations in  0.02260970597853884  seconds by  33.341582528769564  percent.
# -------- 1
# interpolate adjoint :  True True True
# initial cost =  22.070896847169568
# RUN  0 , total integrated cost =  22.070896847169568
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12.363873252679358
# RUN  1 , total integrated cost =  12.363873252679358
# Improved over  1  iterations in  0.0213448170106858  seconds by  43.98110172734129  percent.
# -------- 2
# interpolate adjoint :  True True True
# initial cost =  21.693791508403656
# RUN  0 , total integrated cost =  21.693791508403656
# Gradient descend method:  None
# RUN  1 , total integrated cost =  15.698837160116526
# RUN  1 , total integrated cost =  15.698837160116526
# Improved over  1  iterations in  0.02279384498251602  seconds by  27.634424097626408  percent.
# -------- 3
# interpolate adjoint :  True True True
# initial cost =  21.13527801390364
# RUN  0 , total integrated cost =  21.13527801390364
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.798292703870931
# RUN  1 , total integrated cost =  11.798292703870931
# Improved over  1  iterations in  0.021691160975024104  seconds by  44.177253329199  percent.
# -------- 4
# interpolate adjoint :  True True True
# initial cost =  23.218445144312323
# RUN  0 , total integrated cost =  23.218445144312323
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14.41327869997026
# RUN  1 , total integrated cost =  14.41327869997026
# Improved over  1  iterations in  0.023241795948706567  seconds by  37.9231528623656  percent.
# -------- 5
# interpolate adjoint :  True True True
# initial cost =  23.362014199113332
# RUN  0 , total integrated cost =  23.362014199113332
# Gradient descend method:  None
# RUN  1 , total integrated cost =  17.19518808947641
# RUN  1 , total integrated cost =  17.19518808947641
# Improved over  1  iterations in  0.022690616024192423  seconds by  26.396808327729616  percent.
# -------- 6
# interpolate adjoint :  True True True
# initial cost =  22.53238306731509
# RUN  0 , total integrated cost =  22.53238306731509
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14.250133241278286
# RUN  1 , total integrated cost =  14.250133241278286
# Improved over  1  iterations in  0.022000491968356073  seconds by  36.757096669685275  percent.
# -------- 7
# interpolate adjoint :  True True True
# initial cost =  21.347575033969783
# RUN  0 , total integrated cost =  21.347575033969783
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12.205770665944854
# RUN  1 , total integrated cost =  12.205770665944854
# Improved over  1  iterations in  0.028811409953050315  seconds by  42.82361979511883  percent.
# -------- 8
# interpolate adjoint :  True True True
# initial cost =  21.41933127992473
# RUN  0 , total integrated cost =  21.41933127992473
# Gradient descend method:  None
# RUN  1 , total integrated cost =  16.19716804842453
# RUN  1 , total integrated cost =  16.19716804842453
# Improved over  1  iterations in  0.021988264983519912  seconds by  24.3806081677007  percent.
# -------- 9
# interpolate adjoint :  True True True
# initial cost =  20.740610197302704
# RUN  0 , total integrated cost =  20.740610197302704
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12.304456130423677
# RUN  1 , total integrated cost =  12.304456130423677
# Improved over  1  iterations in  0.021047996007837355  seconds by  40.67457025915342  percent.
# cost =  14.448505995753882
# iteration =  5
# -------- 0
# interpolate adjoint :  True True True
# initial cost =  13.899256555302355
# RUN  0 , total integrated cost =  13.899256555302355
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.302556754544751
# RUN  1 , total integrated cost =  11.302556754544751
# Improved over  1  iterations in  0.025178871990647167  seconds by  18.682292757356166  percent.
# -------- 1
# interpolate adjoint :  True True True
# initial cost =  13.839762421776427
# RUN  0 , total integrated cost =  13.839762421776427
# Gradient descend method:  None
# RUN  1 , total integrated cost =  10.821941873575762
# RUN  1 , total integrated cost =  10.821941873575762
# Improved over  1  iterations in  0.025585533992853016  seconds by  21.805436077805936  percent.
# -------- 2
# interpolate adjoint :  True True True
# initial cost =  12.552127864542904
# RUN  0 , total integrated cost =  12.552127864542904
# Gradient descend method:  None
# RUN  1 , total integrated cost =  10.40058544966811
# RUN  1 , total integrated cost =  10.40058544966811
# Improved over  1  iterations in  0.024426079995464534  seconds by  17.140858013026175  percent.
# -------- 3
# interpolate adjoint :  True True True
# initial cost =  12.66257529454036
# RUN  0 , total integrated cost =  12.66257529454036
# Gradient descend method:  None
# RUN  1 , total integrated cost =  10.565506788773504
# RUN  1 , total integrated cost =  10.565506788773504
# Improved over  1  iterations in  0.022991444973740727  seconds by  16.561153296131124  percent.
# -------- 4
# interpolate adjoint :  True True True
# initial cost =  12.892835840091301
# RUN  0 , total integrated cost =  12.892835840091301
# Gradient descend method:  None
# RUN  1 , total integrated cost =  10.812841385572648
# RUN  1 , total integrated cost =  10.812841385572648
# Improved over  1  iterations in  0.022343331016600132  seconds by  16.132947633217697  percent.
# -------- 5
# interpolate adjoint :  True True True
# initial cost =  13.159540953311765
# RUN  0 , total integrated cost =  13.159540953311765
# Gradient descend method:  None
# RUN  1 , total integrated cost =  10.936308868633372
# RUN  1 , total integrated cost =  10.936308868633372
# Improved over  1  iterations in  0.0229122499586083  seconds by  16.89445013747907  percent.
# -------- 6
# interpolate adjoint :  True True True
# initial cost =  13.864384150624126
# RUN  0 , total integrated cost =  13.864384150624126
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.224790322178906
# RUN  1 , total integrated cost =  11.224790322178906
# Improved over  1  iterations in  0.023650074959732592  seconds by  19.038666267238384  percent.
# -------- 7
# interpolate adjoint :  True True True
# initial cost =  13.961231082425343
# RUN  0 , total integrated cost =  13.961231082425343
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.314107981079484
# RUN  1 , total integrated cost =  11.314107981079484
# Improved over  1  iterations in  0.024255946977064013  seconds by  18.960527805302974  percent.
# -------- 8
# interpolate adjoint :  True True True
# initial cost =  13.56255016081385
# RUN  0 , total integrated cost =  13.56255016081385
# Gradient descend method:  None
# RUN  1 , total integrated cost =  10.49493690577586
# RUN  1 , total integrated cost =  10.49493690577586
# Improved over  1  iterations in  0.02356455597328022  seconds by  22.618262927433918  percent.
# -------- 9
# interpolate adjoint :  True True True
# initial cost =  13.355647778939602
# RUN  0 , total integrated cost =  13.355647778939602
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.49128149247955
# RUN  1 , total integrated cost =  11.49128149247955
# Improved over  1  iterations in  0.02304742601700127  seconds by  13.9593849532327  percent.
# cost =  11.77025209563404
# iteration =  6
# -------- 0
# interpolate adjoint :  True True True
# initial cost =  11.845556238636409
# RUN  0 , total integrated cost =  11.845556238636409
# Gradient descend method:  None
# RUN  1 , total integrated cost =  8.290629645333034
# RUN  1 , total integrated cost =  8.290629645333034
# Improved over  1  iterations in  0.046880893991328776  seconds by  30.010634550941077  percent.
# -------- 1
# interpolate adjoint :  True True True
# initial cost =  12.173290319143025
# RUN  0 , total integrated cost =  12.173290319143025
# Gradient descend method:  None
# RUN  1 , total integrated cost =  8.533315555285066
# RUN  1 , total integrated cost =  8.533315555285066
# Improved over  1  iterations in  0.04794983204919845  seconds by  29.90132222620157  percent.
# -------- 2
# interpolate adjoint :  True True True
# initial cost =  11.554357273940848
# RUN  0 , total integrated cost =  11.554357273940848
# Gradient descend method:  None
# RUN  1 , total integrated cost =  8.330724676205115
# RUN  1 , total integrated cost =  8.330724676205115
# Improved over  1  iterations in  0.04695060302037746  seconds by  27.899713686421677  percent.
# -------- 3
# interpolate adjoint :  True True True
# initial cost =  10.471357680272828
# RUN  0 , total integrated cost =  10.471357680272828
# Gradient descend method:  None
# RUN  1 , total integrated cost =  8.303617537904483
# RUN  1 , total integrated cost =  8.303617537904483
# Improved over  1  iterations in  0.052637236018199474  seconds by  20.70161490569832  percent.
# -------- 4
# interpolate adjoint :  True True True
# initial cost =  10.587788267948
# RUN  0 , total integrated cost =  10.587788267948
# Gradient descend method:  None
# RUN  1 , total integrated cost =  8.324374203153257
# RUN  1 , total integrated cost =  8.324374203153257
# Improved over  1  iterations in  0.04722815501736477  seconds by  21.377590933195066  percent.
# -------- 5
# interpolate adjoint :  True True True
# initial cost =  10.702545275943226
# RUN  0 , total integrated cost =  10.702545275943226
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.495181133964428
# RUN  1 , total integrated cost =  7.495181133964428
# Improved over  1  iterations in  0.0435093020205386  seconds by  29.968237080838975  percent.
# -------- 6
# interpolate adjoint :  True True True
# initial cost =  11.730932034131838
# RUN  0 , total integrated cost =  11.730932034131838
# Gradient descend method:  None
# RUN  1 , total integrated cost =  8.050048953463362
# RUN  1 , total integrated cost =  8.050048953463362
# Improved over  1  iterations in  0.04856790998019278  seconds by  31.377584235922  percent.
# -------- 7
# interpolate adjoint :  True True True
# initial cost =  10.939324027210663
# RUN  0 , total integrated cost =  10.939324027210663
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.274781373412324
# RUN  1 , total integrated cost =  7.274781373412324
# Improved over  1  iterations in  0.04322818503715098  seconds by  33.498803442361634  percent.
# -------- 8
# interpolate adjoint :  True True True
# initial cost =  12.194205318710985
# RUN  0 , total integrated cost =  12.194205318710985
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.607247283007407
# RUN  1 , total integrated cost =  7.607247283007407
# Improved over  1  iterations in  0.04225734795909375  seconds by  37.61588324796594  percent.
# -------- 9
# interpolate adjoint :  True True True
# initial cost =  11.695314063413258
# RUN  0 , total integrated cost =  11.695314063413258
# Gradient descend method:  None
# RUN  1 , total integrated cost =  8.180933797620577
# RUN  1 , total integrated cost =  8.180933797620577
# Improved over  1  iterations in  0.042935667966958135  seconds by  30.049473205570465  percent.
# cost =  8.359346810669066
# iteration =  7
# -------- 0
# interpolate adjoint :  True True True
# initial cost =  8.455870077169983
# RUN  0 , total integrated cost =  8.455870077169983
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.500253633442384
# RUN  1 , total integrated cost =  7.500253633442384
# Improved over  1  iterations in  0.04624628403689712  seconds by  11.301219567075307  percent.
# -------- 1
# interpolate adjoint :  True True True
# initial cost =  8.32671679931806
# RUN  0 , total integrated cost =  8.32671679931806
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.469151801198353
# RUN  1 , total integrated cost =  7.469151801198353
# Improved over  1  iterations in  0.04558312700828537  seconds by  10.298957185501251  percent.
# -------- 2
# interpolate adjoint :  True True True
# initial cost =  8.502153659541579
# RUN  0 , total integrated cost =  8.502153659541579
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.503879864961707
# RUN  1 , total integrated cost =  7.503879864961707
# Improved over  1  iterations in  0.04727830697083846  seconds by  11.741422638951647  percent.
# -------- 3
# interpolate adjoint :  True True True
# initial cost =  8.054063187634972
# RUN  0 , total integrated cost =  8.054063187634972
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.112403422477625
# RUN  1 , total integrated cost =  7.112403422477625
# Improved over  1  iterations in  0.04208914301125333  seconds by  11.691735503180965  percent.
# -------- 4
# interpolate adjoint :  True True True
# initial cost =  7.74777294097451
# RUN  0 , total integrated cost =  7.74777294097451
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.175801592310048
# RUN  1 , total integrated cost =  7.175801592310048
# Improved over  1  iterations in  0.04857037798501551  seconds by  7.382396890331691  percent.
# -------- 5
# interpolate adjoint :  True True True
# initial cost =  7.669417045485504
# RUN  0 , total integrated cost =  7.669417045485504
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.501659707700846
# RUN  1 , total integrated cost =  7.501659707700846
# Improved over  1  iterations in  0.06540078297257423  seconds by  2.1873544858719924  percent.
# -------- 6
# interpolate adjoint :  True True True
# initial cost =  7.989243956116616
# RUN  0 , total integrated cost =  7.989243956116616
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.012519781218181
# RUN  1 , total integrated cost =  7.012519781218181
# Improved over  1  iterations in  0.04300424800021574  seconds by  12.22548942382275  percent.
# -------- 7
# interpolate adjoint :  True True True
# initial cost =  7.991826832984655
# RUN  0 , total integrated cost =  7.991826832984655
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.368743248939461
# RUN  1 , total integrated cost =  7.368743248939461
# Improved over  1  iterations in  0.05164857202908024  seconds by  7.796510072935291  percent.
# -------- 8
# interpolate adjoint :  True True True
# initial cost =  7.937417330481234
# RUN  0 , total integrated cost =  7.937417330481234
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.203465169884732
# RUN  1 , total integrated cost =  7.203465169884732
# Improved over  1  iterations in  0.04518490901682526  seconds by  9.246737698646427  percent.
# -------- 9
# interpolate adjoint :  True True True
# initial cost =  8.086754644310721
# RUN  0 , total integrated cost =  8.086754644310721
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.427967436648162
# RUN  1 , total integrated cost =  7.427967436648162
# Improved over  1  iterations in  0.045010639005340636  seconds by  8.146496791837706  percent.
# cost =  7.743926680745122
# iteration =  8
# -------- 0
# interpolate adjoint :  True True True
# initial cost =  7.40149146153821
# RUN  0 , total integrated cost =  7.40149146153821
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.1541620672342745
# RUN  1 , total integrated cost =  7.1541620672342745
# Improved over  1  iterations in  0.057223528041504323  seconds by  3.3416156134095587  percent.
# -------- 1
# interpolate adjoint :  True True True
# initial cost =  7.30488076610583
# RUN  0 , total integrated cost =  7.30488076610583
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.922643567218595
# RUN  1 , total integrated cost =  6.922643567218595
# Improved over  1  iterations in  0.052816409966908395  seconds by  5.232627487375169  percent.
# -------- 2
# interpolate adjoint :  True True True
# initial cost =  7.350132374676039
# RUN  0 , total integrated cost =  7.350132374676039
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.0596270244477095
# RUN  1 , total integrated cost =  7.0596270244477095
# Improved over  1  iterations in  0.04613491898635402  seconds by  3.952382561560782  percent.
# -------- 3
# interpolate adjoint :  True True True
# initial cost =  7.399311935616888
# RUN  0 , total integrated cost =  7.399311935616888
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.585707268031358
# RUN  1 , total integrated cost =  6.585707268031358
# Improved over  1  iterations in  0.046728950983379036  seconds by  10.995680066807438  percent.
# -------- 4
# interpolate adjoint :  True True True
# initial cost =  7.262929443794337
# RUN  0 , total integrated cost =  7.262929443794337
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.11148598006294
# RUN  1 , total integrated cost =  7.11148598006294
# Improved over  1  iterations in  0.06141156703233719  seconds by  2.0851567525662063  percent.
# -------- 5
# interpolate adjoint :  True True True
# initial cost =  7.382127775246646
# RUN  0 , total integrated cost =  7.382127775246646
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.960716919992728
# RUN  1 , total integrated cost =  6.960716919992728
# Improved over  1  iterations in  0.04577120300382376  seconds by  5.708528327929656  percent.
# -------- 6
# interpolate adjoint :  True True True
# initial cost =  7.287435870869737
# RUN  0 , total integrated cost =  7.287435870869737
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.120465414919967
# RUN  1 , total integrated cost =  7.120465414919967
# Improved over  1  iterations in  0.049330531037412584  seconds by  2.2912099524224345  percent.
# -------- 7
# interpolate adjoint :  True True True
# initial cost =  7.905006767209668
# RUN  0 , total integrated cost =  7.905006767209668
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.1691983941177755
# RUN  1 , total integrated cost =  7.1691983941177755
# Improved over  1  iterations in  0.04916857602074742  seconds by  9.308130843657963  percent.
# -------- 8
# interpolate adjoint :  True True True
# initial cost =  7.346098808421988
# RUN  0 , total integrated cost =  7.346098808421988
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.210026983520033
# RUN  1 , total integrated cost =  7.210026983520033
# Improved over  1  iterations in  0.05333632999099791  seconds by  1.8523004992248957  percent.
# -------- 9
# interpolate adjoint :  True True True
# initial cost =  7.7001677279236205
# RUN  0 , total integrated cost =  7.7001677279236205
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.1367980948713345
# RUN  1 , total integrated cost =  7.1367980948713345
# Improved over  1  iterations in  0.05181719298707321  seconds by  7.316329370453872  percent.
# cost =  7.449979852610553
# iteration =  9
# -------- 0
# interpolate adjoint :  True True True
# initial cost =  7.109166118319626
# RUN  0 , total integrated cost =  7.109166118319626
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.902171971818319
# RUN  1 , total integrated cost =  6.902171971818319
# Improved over  1  iterations in  0.04574062902247533  seconds by  2.9116515644205236  percent.
# -------- 1
# interpolate adjoint :  True True True
# initial cost =  7.349627798361154
# RUN  0 , total integrated cost =  7.349627798361154
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.959490689365739
# RUN  1 , total integrated cost =  6.959490689365739
# Improved over  1  iterations in  0.04989370598923415  seconds by  5.308256685901952  percent.
# -------- 2
# interpolate adjoint :  True True True
# initial cost =  7.353642304621016
# RUN  0 , total integrated cost =  7.353642304621016
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.007011301615759
# RUN  1 , total integrated cost =  7.007011301615759
# Improved over  1  iterations in  0.04876456700731069  seconds by  4.713732170348223  percent.
# -------- 3
# interpolate adjoint :  True True True
# initial cost =  7.107767649647464
# RUN  0 , total integrated cost =  7.107767649647464
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.852699754689035
# RUN  1 , total integrated cost =  6.852699754689035
# Improved over  1  iterations in  0.05433592799818143  seconds by  3.588579530608044  percent.
# -------- 4
# interpolate adjoint :  True True True
# initial cost =  7.264377916834391
# RUN  0 , total integrated cost =  7.264377916834391
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.933746476586046
# RUN  1 , total integrated cost =  6.933746476586046
# Improved over  1  iterations in  0.04960765200667083  seconds by  4.551407485039334  percent.
# -------- 5
# interpolate adjoint :  True True True
# initial cost =  7.22499852007147
# RUN  0 , total integrated cost =  7.22499852007147
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.852784763186007
# RUN  1 , total integrated cost =  6.852784763186007
# Improved over  1  iterations in  0.04598479298874736  seconds by  5.1517485554001325  percent.
# -------- 6
# interpolate adjoint :  True True True
# initial cost =  7.1104678191059705
# RUN  0 , total integrated cost =  7.1104678191059705
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.882154274042842
# RUN  1 , total integrated cost =  6.882154274042842
# Improved over  1  iterations in  0.04667222697753459  seconds by  3.210949699394533  percent.
# -------- 7
# interpolate adjoint :  True True True
# initial cost =  7.129894656900832
# RUN  0 , total integrated cost =  7.129894656900832
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.859567123432574
# RUN  1 , total integrated cost =  6.859567123432574
# Improved over  1  iterations in  0.0448413229896687  seconds by  3.7914660240683276  percent.
# -------- 8
# interpolate adjoint :  True True True
# initial cost =  7.346762823396375
# RUN  0 , total integrated cost =  7.346762823396375
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.925425245369211
# RUN  1 , total integrated cost =  6.925425245369211
# Improved over  1  iterations in  0.04834236204624176  seconds by  5.735009937783474  percent.
# -------- 9
# interpolate adjoint :  True True True
# initial cost =  6.950789485048
# RUN  0 , total integrated cost =  6.950789485048
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.691745350758578
# RUN  1 , total integrated cost =  6.691745350758578
# Improved over  1  iterations in  0.05026127299061045  seconds by  3.7268303815941835  percent.
# cost =  7.284681171233816
# iteration =  10
# -------- 0
# interpolate adjoint :  True True True
# initial cost =  7.189241463645919
# RUN  0 , total integrated cost =  7.189241463645919
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.759871832067627
# RUN  1 , total integrated cost =  6.759871832067627
# Improved over  1  iterations in  0.047232981014531106  seconds by  5.97239129815712  percent.
# -------- 1
# interpolate adjoint :  True True True
# initial cost =  6.977768914529886
# RUN  0 , total integrated cost =  6.977768914529886
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.882103023729672
# RUN  1 , total integrated cost =  6.882103023729672
# Improved over  1  iterations in  0.04598168801749125  seconds by  1.37100973064625  percent.
# -------- 2
# interpolate adjoint :  True True True
# initial cost =  6.961311888415361
# RUN  0 , total integrated cost =  6.961311888415361
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.80132533237479
# RUN  1 , total integrated cost =  6.80132533237479
# Improved over  1  iterations in  0.046380577026866376  seconds by  2.2982242227476206  percent.
# -------- 3
# interpolate adjoint :  True True True
# initial cost =  6.829889206810305
# RUN  0 , total integrated cost =  6.829889206810305
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.712644118859746
# RUN  1 , total integrated cost =  6.712644118859746
# Improved over  1  iterations in  0.07528695301152766  seconds by  1.7166469967572908  percent.
# -------- 4
# interpolate adjoint :  True True True
# initial cost =  6.957102460638421
# RUN  0 , total integrated cost =  6.957102460638421
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.777482802157868
# RUN  1 , total integrated cost =  6.777482802157868
# Improved over  1  iterations in  0.044358530023600906  seconds by  2.581817063882511  percent.
# -------- 5
# interpolate adjoint :  True True True
# initial cost =  7.104795800464191
# RUN  0 , total integrated cost =  7.104795800464191
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.818117218734442
# RUN  1 , total integrated cost =  6.818117218734442
# Improved over  1  iterations in  0.04450786701636389  seconds by  4.035001001872828  percent.
# -------- 6
# interpolate adjoint :  True True True
# initial cost =  7.424168488815205
# RUN  0 , total integrated cost =  7.424168488815205
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.759747031363627
# RUN  1 , total integrated cost =  6.759747031363627
# Improved over  1  iterations in  0.04546999401645735  seconds by  8.949439367554149  percent.
# -------- 7
# interpolate adjoint :  True True True
# initial cost =  7.060483310556598
# RUN  0 , total integrated cost =  7.060483310556598
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.741656023544336
# RUN  1 , total integrated cost =  6.741656023544336
# Improved over  1  iterations in  0.044419604004360735  seconds by  4.515658107081165  percent.
# -------- 8
# interpolate adjoint :  True True True
# initial cost =  6.824708374647046
# RUN  0 , total integrated cost =  6.824708374647046
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.702246862885272
# RUN  1 , total integrated cost =  6.702246862885272
# Improved over  1  iterations in  0.044997972960118204  seconds by  1.7943845368793063  percent.
# -------- 9
# interpolate adjoint :  True True True
# initial cost =  7.120455788421288
# RUN  0 , total integrated cost =  7.120455788421288
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.844376738364891
# RUN  1 , total integrated cost =  6.844376738364891
# Improved over  1  iterations in  0.050011607992928475  seconds by  3.8772665438824134  percent.
# cost =  7.147813943590361
# iteration =  11
# -------- 0
# interpolate adjoint :  True True True
# initial cost =  7.1857186457743545
# RUN  0 , total integrated cost =  7.1857186457743545
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.7284837960057
# RUN  1 , total integrated cost =  6.7284837960057
# Improved over  1  iterations in  0.04565763002028689  seconds by  6.363105380385818  percent.
# -------- 1
# interpolate adjoint :  True True True
# initial cost =  6.913263115438389
# RUN  0 , total integrated cost =  6.913263115438389
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.723456725193978
# RUN  1 , total integrated cost =  6.723456725193978
# Improved over  1  iterations in  0.05008107499452308  seconds by  2.7455397990066928  percent.
# -------- 2
# interpolate adjoint :  True True True
# initial cost =  6.873593754653735
# RUN  0 , total integrated cost =  6.873593754653735
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.667927299194192
# RUN  1 , total integrated cost =  6.667927299194192
# Improved over  1  iterations in  0.04460345703409985  seconds by  2.992124102770802  percent.
# -------- 3
# interpolate adjoint :  True True True
# initial cost =  6.789021489150297
# RUN  0 , total integrated cost =  6.789021489150297
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.766678809964533
# RUN  1 , total integrated cost =  6.766678809964533
# Improved over  1  iterations in  0.057313245022669435  seconds by  0.3291001394158144  percent.
# -------- 4
# interpolate adjoint :  True True True
# initial cost =  6.8205209231334205
# RUN  0 , total integrated cost =  6.8205209231334205
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.705617211142884
# RUN  1 , total integrated cost =  6.705617211142884
# Improved over  1  iterations in  0.05404269101563841  seconds by  1.684676482712831  percent.
# -------- 5
# interpolate adjoint :  True True True
# initial cost =  6.82269422117393
# RUN  0 , total integrated cost =  6.82269422117393
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.720646987994162
# RUN  1 , total integrated cost =  6.720646987994162
# Improved over  1  iterations in  0.045021187979727983  seconds by  1.4957028685686709  percent.
# -------- 6
# interpolate adjoint :  True True True
# initial cost =  6.783883348905137
# RUN  0 , total integrated cost =  6.783883348905137
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.624515970900248
# RUN  1 , total integrated cost =  6.624515970900248
# Improved over  1  iterations in  0.04375634802272543  seconds by  2.3492057544092404  percent.
# -------- 7
# interpolate adjoint :  True True True
# initial cost =  6.9601783046703
# RUN  0 , total integrated cost =  6.9601783046703
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.798476573734602
# RUN  1 , total integrated cost =  6.798476573734602
# Improved over  1  iterations in  0.044155723007861525  seconds by  2.3232412139096397  percent.
# -------- 8
# interpolate adjoint :  True True True
# initial cost =  6.925164397360017
# RUN  0 , total integrated cost =  6.925164397360017
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.733321583451833
# RUN  1 , total integrated cost =  6.733321583451833
# Improved over  1  iterations in  0.047407332982402295  seconds by  2.7702275772878124  percent.
# -------- 9
# interpolate adjoint :  True True True
# initial cost =  6.920370619364339
# RUN  0 , total integrated cost =  6.920370619364339
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.678260698159388
# RUN  1 , total integrated cost =  6.678260698159388
# Improved over  1  iterations in  0.04791615897556767  seconds by  3.498510911070099  percent.
# cost =  7.105653065469977
# iteration =  12
# -------- 0
# interpolate adjoint :  True True True
# initial cost =  7.066100308575971
# RUN  0 , total integrated cost =  7.066100308575971
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.6561955792627945
# RUN  1 , total integrated cost =  6.6561955792627945
# Improved over  1  iterations in  0.04576483101118356  seconds by  5.801003543859736  percent.
# -------- 1
# interpolate adjoint :  True True True
# initial cost =  6.791708925580859
# RUN  0 , total integrated cost =  6.791708925580859
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.630100197479394
# RUN  1 , total integrated cost =  6.630100197479394
# Improved over  1  iterations in  0.04167127498658374  seconds by  2.3795002093327042  percent.
# -------- 2
# interpolate adjoint :  True True True
# initial cost =  7.000660451982387
# RUN  0 , total integrated cost =  7.000660451982387
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.649211856020551
# RUN  1 , total integrated cost =  6.649211856020551
# Improved over  1  iterations in  0.0452480330131948  seconds by  5.02022056879386  percent.
# -------- 3
# interpolate adjoint :  True True True
# initial cost =  6.900674480059785
# RUN  0 , total integrated cost =  6.900674480059785
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.74026098473017
# RUN  1 , total integrated cost =  6.74026098473017
# Improved over  1  iterations in  0.04695114400237799  seconds by  2.3246060337021532  percent.
# -------- 4
# interpolate adjoint :  True True True
# initial cost =  6.77548483749617
# RUN  0 , total integrated cost =  6.77548483749617
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.649473319688354
# RUN  1 , total integrated cost =  6.649473319688354
# Improved over  1  iterations in  0.0715914320317097  seconds by  1.8598155088541546  percent.
# -------- 5
# interpolate adjoint :  True True True
# initial cost =  6.841218945270879
# RUN  0 , total integrated cost =  6.841218945270879
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.609070337862327
# RUN  1 , total integrated cost =  6.609070337862327
# Improved over  1  iterations in  0.047869235975667834  seconds by  3.3933807595652183  percent.
# -------- 6
# interpolate adjoint :  True True True
# initial cost =  7.183567131527896
# RUN  0 , total integrated cost =  7.183567131527896
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.677954854601806
# RUN  1 , total integrated cost =  6.677954854601806
# Improved over  1  iterations in  0.048454544972628355  seconds by  7.038456906834114  percent.
# -------- 7
# interpolate adjoint :  True True True
# initial cost =  6.734432005055266
# RUN  0 , total integrated cost =  6.734432005055266
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.43760914895019
# RUN  1 , total integrated cost =  6.43760914895019
# Improved over  1  iterations in  0.06541586900129914  seconds by  4.4075410648182896  percent.
# -------- 8
# interpolate adjoint :  True True True
# initial cost =  6.909082455961982
# RUN  0 , total integrated cost =  6.909082455961982
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.619873402268686
# RUN  1 , total integrated cost =  6.619873402268686
# Improved over  1  iterations in  0.064062176970765  seconds by  4.185925635374801  percent.
# -------- 9
# interpolate adjoint :  True True True
# initial cost =  6.862250341189483
# RUN  0 , total integrated cost =  6.862250341189483
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.649242545260183
# RUN  1 , total integrated cost =  6.649242545260183
# Improved over  1  iterations in  0.045124437019694597  seconds by  3.104051664375433  percent.
# cost =  7.022975703086
# iteration =  13
# -------- 0
# interpolate adjoint :  True True True
# initial cost =  6.620399350142659
# RUN  0 , total integrated cost =  6.620399350142659
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.5123764927837176
# RUN  1 , total integrated cost =  6.5123764927837176
# Improved over  1  iterations in  0.09401991503546014  seconds by  1.6316667869380694  percent.
# -------- 1
# interpolate adjoint :  True True True
# initial cost =  6.81284831903785
# RUN  0 , total integrated cost =  6.81284831903785
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.594172676888563
# RUN  1 , total integrated cost =  6.594172676888563
# Improved over  1  iterations in  0.04894616297679022  seconds by  3.2097535701509514  percent.
# -------- 2
# interpolate adjoint :  True True True
# initial cost =  6.866930987555683
# RUN  0 , total integrated cost =  6.866930987555683
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.651246603298702
# RUN  1 , total integrated cost =  6.651246603298702
# Improved over  1  iterations in  0.04860188503516838  seconds by  3.1409138179464264  percent.
# -------- 3
# interpolate adjoint :  True True True
# initial cost =  6.825630611949843
# RUN  0 , total integrated cost =  6.825630611949843
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.506001321677808
# RUN  1 , total integrated cost =  6.506001321677808
# Improved over  1  iterations in  0.05035002203658223  seconds by  4.682780367757516  percent.
# -------- 4
# interpolate adjoint :  True True True
# initial cost =  6.9291411679214905
# RUN  0 , total integrated cost =  6.9291411679214905
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.597906275923201
# RUN  1 , total integrated cost =  6.597906275923201
# Improved over  1  iterations in  0.04658913495950401  seconds by  4.780316693961211  percent.
# -------- 5
# interpolate adjoint :  True True True
# initial cost =  6.698614243866645
# RUN  0 , total integrated cost =  6.698614243866645
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.558789953766101
# RUN  1 , total integrated cost =  6.558789953766101
# Improved over  1  iterations in  0.05429752799682319  seconds by  2.0873614304416748  percent.
# -------- 6
# interpolate adjoint :  True True True
# initial cost =  6.982558656679135
# RUN  0 , total integrated cost =  6.982558656679135
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.619311640787458
# RUN  1 , total integrated cost =  6.619311640787458
# Improved over  1  iterations in  0.05449487699661404  seconds by  5.202205004668514  percent.
# -------- 7
# interpolate adjoint :  True True True
# initial cost =  6.9149299652068645
# RUN  0 , total integrated cost =  6.9149299652068645
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.581628891148563
# RUN  1 , total integrated cost =  6.581628891148563
# Improved over  1  iterations in  0.05157316802069545  seconds by  4.82002096529304  percent.
# -------- 8
# interpolate adjoint :  True True True
# initial cost =  6.866335712917946
# RUN  0 , total integrated cost =  6.866335712917946
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.671518330254705
# RUN  1 , total integrated cost =  6.671518330254705
# Improved over  1  iterations in  0.048458879988174886  seconds by  2.837283098417714  percent.
# -------- 9
# interpolate adjoint :  True True True
# initial cost =  6.863374712251084
# RUN  0 , total integrated cost =  6.863374712251084
# Gradient descend method:  None
# ...
# -------- 22
# interpolate adjoint :  True True True
# initial cost =  7.072238542199128
# RUN  0 , total integrated cost =  7.072238542199128
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.929610905971563
# RUN  1 , total integrated cost =  6.929610905971563
# Improved over  1  iterations in  0.08908149501075968  seconds by  2.0167254735049482  percent.
# -------- 23
# interpolate adjoint :  True True True
# initial cost =  7.188811031125497
# RUN  0 , total integrated cost =  7.188811031125497
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.019283671467487
# RUN  1 , total integrated cost =  7.019283671467487
# Improved over  1  iterations in  0.06969726801617071  seconds by  2.358211377709125  percent.
# -------- 24
# interpolate adjoint :  True True True
# initial cost =  7.361122395870153
# RUN  0 , total integrated cost =  7.361122395870153
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.047549201863312
# RUN  1 , total integrated cost =  7.047549201863312
# Improved over  1  iterations in  0.0586877369787544  seconds by  4.259855727745617  percent.
# -------- 25
# interpolate adjoint :  True True True
# initial cost =  7.3069445536795214
# RUN  0 , total integrated cost =  7.3069445536795214
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.0640025967361355
# RUN  1 , total integrated cost =  7.0640025967361355
# Improved over  1  iterations in  0.06001861800905317  seconds by  3.3248090930298417  percent.
# -------- 26
# interpolate adjoint :  True True True
# initial cost =  7.3477352899159385
# RUN  0 , total integrated cost =  7.3477352899159385
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.064629067699213
# RUN  1 , total integrated cost =  7.064629067699213
# Improved over  1  iterations in  0.06091207900317386  seconds by  3.8529725288996275  percent.
# -------- 27
# interpolate adjoint :  True True True
# initial cost =  7.5215130497593785
# RUN  0 , total integrated cost =  7.5215130497593785
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.0651060060948785
# RUN  1 , total integrated cost =  7.0651060060948785
# Improved over  1  iterations in  0.05851925996830687  seconds by  6.068021695170785  percent.
# -------- 28
# interpolate adjoint :  True True True
# initial cost =  7.350709933894835
# RUN  0 , total integrated cost =  7.350709933894835
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.009087518606466
# RUN  1 , total integrated cost =  7.009087518606466
# Improved over  1  iterations in  0.059028728981502354  seconds by  4.647475119554301  percent.
# -------- 29
# interpolate adjoint :  True True True
# initial cost =  7.225165281015772
# RUN  0 , total integrated cost =  7.225165281015772
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.059782800968652
# RUN  1 , total integrated cost =  7.059782800968652
# Improved over  1  iterations in  0.0634693139581941  seconds by  2.288978502424925  percent.
# cost =  7.444233118291022
# iteration =  11
# -------- 0
# interpolate adjoint :  True True True
# initial cost =  7.100456017271243
# RUN  0 , total integrated cost =  7.100456017271243
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.989328036681343
# RUN  1 , total integrated cost =  6.989328036681343
# Improved over  1  iterations in  0.08089918200857937  seconds by  1.5650823034406613  percent.
# -------- 1
# interpolate adjoint :  True True True
# initial cost =  7.1160467460551615
# RUN  0 , total integrated cost =  7.1160467460551615
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.9741596906929795
# RUN  1 , total integrated cost =  6.9741596906929795
# Improved over  1  iterations in  0.07311769999796525  seconds by  1.993902800608197  percent.
# -------- 2
# interpolate adjoint :  True True True
# initial cost =  7.193271442425875
# RUN  0 , total integrated cost =  7.193271442425875
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.949495540920144
# RUN  1 , total integrated cost =  6.949495540920144
# Improved over  1  iterations in  0.06210248899878934  seconds by  3.3889434516253942  percent.
# -------- 3
# interpolate adjoint :  True True True
# initial cost =  7.199194875225213
# RUN  0 , total integrated cost =  7.199194875225213
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.992171654403748
# RUN  1 , total integrated cost =  6.992171654403748
# Improved over  1  iterations in  0.061819681024644524  seconds by  2.8756440742269547  percent.
# -------- 4
# interpolate adjoint :  True True True
# initial cost =  7.049176740973982
# RUN  0 , total integrated cost =  7.049176740973982
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.009453544670403
# RUN  1 , total integrated cost =  7.009453544670403
# Improved over  1  iterations in  0.10433220199774951  seconds by  0.5635153970914786  percent.
# -------- 5
# interpolate adjoint :  True True True
# initial cost =  7.745037163106526
# RUN  0 , total integrated cost =  7.745037163106526
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.0289893143350515
# RUN  1 , total integrated cost =  7.0289893143350515
# Improved over  1  iterations in  0.06710400700103492  seconds by  9.24524742350323  percent.
# -------- 6
# interpolate adjoint :  True True True
# initial cost =  7.284292765131389
# RUN  0 , total integrated cost =  7.284292765131389
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.005826219881119
# RUN  1 , total integrated cost =  7.005826219881119
# Improved over  1  iterations in  0.06811627402203158  seconds by  3.8228357127989057  percent.
# -------- 7
# interpolate adjoint :  True True True
# initial cost =  7.1427740638728
# RUN  0 , total integrated cost =  7.1427740638728
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.976378176148995
# RUN  1 , total integrated cost =  6.976378176148995
# Improved over  1  iterations in  0.061251468025147915  seconds by  2.3295695234910596  percent.
# -------- 8
# interpolate adjoint :  True True True
# initial cost =  7.107817946629221
# RUN  0 , total integrated cost =  7.107817946629221
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.985728230306528
# RUN  1 , total integrated cost =  6.985728230306528
# Improved over  1  iterations in  0.06866713997442275  seconds by  1.7176820965229211  percent.
# -------- 9
# interpolate adjoint :  True True True
# initial cost =  7.141229616662953
# RUN  0 , total integrated cost =  7.141229616662953
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.952334567318184
# RUN  1 , total integrated cost =  6.952334567318184
# Improved over  1  iterations in  0.06344997801352292  seconds by  2.645133394170813  percent.
# -------- 10
# interpolate adjoint :  True True True
# initial cost =  7.1492902508218865
# RUN  0 , total integrated cost =  7.1492902508218865
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.981291673162705
# RUN  1 , total integrated cost =  6.981291673162705
# Improved over  1  iterations in  0.06970596802420914  seconds by  2.349863717448997  percent.
# -------- 11
# interpolate adjoint :  True True True
# initial cost =  7.576694226122102
# RUN  0 , total integrated cost =  7.576694226122102
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.073116939850515
# RUN  1 , total integrated cost =  7.073116939850515
# Improved over  1  iterations in  0.06794829404680058  seconds by  6.646398432385041  percent.
# -------- 12
# interpolate adjoint :  True True True
# initial cost =  7.111656738774857
# RUN  0 , total integrated cost =  7.111656738774857
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.940818399843826
# RUN  1 , total integrated cost =  6.940818399843826
# Improved over  1  iterations in  0.06888808700023219  seconds by  2.4022298207894437  percent.
# -------- 13
# interpolate adjoint :  True True True
# initial cost =  7.29000278490609
# RUN  0 , total integrated cost =  7.29000278490609
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.991209710537856
# RUN  1 , total integrated cost =  6.991209710537856
# Improved over  1  iterations in  0.06885729799978435  seconds by  4.098668864528875  percent.
# -------- 14
# interpolate adjoint :  True True True
# initial cost =  7.153560814780778
# RUN  0 , total integrated cost =  7.153560814780778
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.892534453815306
# RUN  1 , total integrated cost =  6.892534453815306
# Improved over  1  iterations in  0.06240371702006087  seconds by  3.6489011238450075  percent.
# -------- 15
# interpolate adjoint :  True True True
# initial cost =  7.271737046345072
# RUN  0 , total integrated cost =  7.271737046345072
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.953757928632153
# RUN  1 , total integrated cost =  6.953757928632153
# Improved over  1  iterations in  0.061469926964491606  seconds by  4.372808253190925  percent.
# -------- 16
# interpolate adjoint :  True True True
# initial cost =  7.402447825418254
# RUN  0 , total integrated cost =  7.402447825418254
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.055227730583698
# RUN  1 , total integrated cost =  7.055227730583698
# Improved over  1  iterations in  0.07287863298552111  seconds by  4.69061184926268  percent.
# -------- 17
# interpolate adjoint :  True True True
# initial cost =  7.077226170557422
# RUN  0 , total integrated cost =  7.077226170557422
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.942646566305171
# RUN  1 , total integrated cost =  6.942646566305171
# Improved over  1  iterations in  0.06847370200557634  seconds by  1.9015868789403356  percent.
# -------- 18
# interpolate adjoint :  True True True
# initial cost =  7.063222319765634
# RUN  0 , total integrated cost =  7.063222319765634
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.978559149730772
# RUN  1 , total integrated cost =  6.978559149730772
# Improved over  1  iterations in  0.0698615699657239  seconds by  1.1986479570088164  percent.
# -------- 19
# interpolate adjoint :  True True True
# initial cost =  7.135748109579531
# RUN  0 , total integrated cost =  7.135748109579531
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.027196904864796
# RUN  1 , total integrated cost =  7.027196904864796
# Improved over  1  iterations in  0.07341915997676551  seconds by  1.52123089335241  percent.
# -------- 20
# interpolate adjoint :  True True True
# initial cost =  7.062281855702836
# RUN  0 , total integrated cost =  7.062281855702836
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.02006028975223
# RUN  1 , total integrated cost =  7.02006028975223
# Improved over  1  iterations in  0.09502862999215722  seconds by  0.5978459485656487  percent.
# -------- 21
# interpolate adjoint :  True True True
# initial cost =  7.115805231154002
# RUN  0 , total integrated cost =  7.115805231154002
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.941271226920797
# RUN  1 , total integrated cost =  6.941271226920797
# Improved over  1  iterations in  0.0811278639594093  seconds by  2.4527653380543626  percent.
# -------- 22
# interpolate adjoint :  True True True
# initial cost =  7.07307072247856
# RUN  0 , total integrated cost =  7.07307072247856
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.990677655771426
# RUN  1 , total integrated cost =  6.990677655771426
# Improved over  1  iterations in  0.08808897697599605  seconds by  1.1648839653940541  percent.
# -------- 23
# interpolate adjoint :  True True True
# initial cost =  7.052087983934489
# RUN  0 , total integrated cost =  7.052087983934489
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.962554858672494
# RUN  1 , total integrated cost =  6.962554858672494
# Improved over  1  iterations in  0.08402746001956984  seconds by  1.2695973939344185  percent.
# -------- 24
# interpolate adjoint :  True True True
# initial cost =  7.163215633218287
# RUN  0 , total integrated cost =  7.163215633218287
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.94745985850549
# RUN  1 , total integrated cost =  6.94745985850549
# Improved over  1  iterations in  0.06305248301941901  seconds by  3.0119960889110047  percent.
# -------- 25
# interpolate adjoint :  True True True
# initial cost =  7.2194946515826155
# RUN  0 , total integrated cost =  7.2194946515826155
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.9115111301021965
# RUN  1 , total integrated cost =  6.9115111301021965
# Improved over  1  iterations in  0.06644278997555375  seconds by  4.26599833290139  percent.
# -------- 26
# interpolate adjoint :  True True True
# initial cost =  7.378349987196346
# RUN  0 , total integrated cost =  7.378349987196346
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.029428467085057
# RUN  1 , total integrated cost =  7.029428467085057
# Improved over  1  iterations in  0.06574964500032365  seconds by  4.728991179827105  percent.
# -------- 27
# interpolate adjoint :  True True True
# initial cost =  7.313904049070046
# RUN  0 , total integrated cost =  7.313904049070046
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.935987264696384
# RUN  1 , total integrated cost =  6.935987264696384
# Improved over  1  iterations in  0.06389230099739507  seconds by  5.167100659759313  percent.
# -------- 28
# interpolate adjoint :  True True True
# initial cost =  7.282649056227571
# RUN  0 , total integrated cost =  7.282649056227571
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.03401792838443
# RUN  1 , total integrated cost =  7.03401792838443
# Improved over  1  iterations in  0.06564563297433779  seconds by  3.414020446729211  percent.
# -------- 29
# interpolate adjoint :  True True True
# initial cost =  7.128955823753051
# RUN  0 , total integrated cost =  7.128955823753051
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.974098443365475
# RUN  1 , total integrated cost =  6.974098443365475
# Improved over  1  iterations in  0.06218327395617962  seconds by  2.172230887889711  percent.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_227101/62168783.py in <module>
#      89
#      90                 for n_ in range(noise_realizations_final):
# ---> 91                     state_ = fo.updateState(aln, control_init)
#      92                     cost_final += cost.numba_cost_precision_int(1, T, dt, d['cost_params'][s_ind][0],
#      93                                                                    state_, target_, list(prec_vars) )
#
# ~/Promotion/neurolib_dev_optControl/neurolib/utils/func_optimize.py in updateState(model, control_)
#       8     state_ = model.getZeroState()
#       9     output_vars = model.output_vars
# ---> 10     model.run(control = control_)
#      11     for i in range(len(output_vars)):
#      12         state_[:,i,:] = model[output_vars[i]][:,:]
#
# ~/Promotion/neurolib_dev_optControl/neurolib/models/model.py in run(self, inputs, chunkwise, chunksize, bold, append, append_outputs, continue_run, control)
#     188         if chunkwise is False:
#     189             if self.name == 'aln':
# --> 190                 self.integrate(append_outputs=append, simulate_bold=bold, control=cntrl)
#     191             else:
#     192                 self.integrate(append_outputs=append, simulate_bold=bold)
#
# ~/Promotion/neurolib_dev_optControl/neurolib/models/model.py in integrate(self, append_outputs, simulate_bold, control)
#     232         #print("before integration")
#     233         if self.name == 'aln':
# --> 234             t, *variables = self.integration(self.params, control=control)
#     235         else:
#     236             t, *variables = self.integration(self.params)
#
# ~/Promotion/neurolib_dev_optControl/neurolib/models/aln/timeIntegration.py in timeIntegration(params, control)
#     286     # ------------------------------------------------------------------------
#     287
# --> 288     return timeIntegration_njit_elementwise(
#     289         dt,
#     290         duration,
#
# KeyboardInterrupt:

# %%
#len(sigma_array), 4, N_max, max_it

##### METHOD 2
method_ind = 1

for d in dict_list:
    print("Point = ", d['point'])
    aln.params.ext_exc_current = d['point'][0] * 5.
    aln.params.ext_inh_current = d['point'][1] * 5.
    
    max_it = d['cost'].shape[3]
    
    for s_ind in range(len(d['sigma'])):
        
        print("sigma = ", d['sigma'][s_ind])
        
        s = d['sigma'][s_ind]
        aln.params.sigma_ou = s
        c_p = d['cost_params'][s_ind]
        cost.setParams(c_p[0], c_p[1], c_p[2])
        
        target_ = d['target'][s_ind].copy()
        target_[0,0,:int(trans_time * dur / aln.params.dt)] = -1000
        target_[0,1,:int(trans_time * dur / aln.params.dt)] = -1000
                
        for n_ind in range(len(d['N_array'])):
            
            if d['cost'][s_ind, method_ind, n_ind, -1] > 0.:
                continue
            
            n_ = d['N_array'][n_ind]
            
            print("n = ", n_)
            aln.params.duration = dur
            control_init = aln.getZeroControl()
        
            for i_it in range(1, max_it, 1):
                
                print("iteration = ", i_it)

                if i_it <= init_it:
                    c_vars = d['init']
                else:
                    c_vars = [0,1]
                    
                aln.params.duration = dur
                setinit(d['init_vars'], aln)
                
                bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                    control_init, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_ = 1,
                    tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                    t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                    control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                    noise_real=n_, init_params = d['init_vars'], method='M2')
    
                control_init = bc[:,:,n_pre:-n_post]
        
                aln.params.duration = dur
                setinit(d['init_vars'], aln)

                cost_final = 0.
                
                for j in range(noise_realizations_final):
                    state_ = fo.updateState(aln, control_init)
                    cost_final += cost.numba_cost_precision_int(1, T, dt, d['cost_params'][s_ind][0],
                                                                   state_, target_, list(prec_vars) )
                    cost_final += cost.numba_cost_sparsity_int(1, 6, T, d['cost_params'][s_ind][2],
                                                                   dt, control_init)
                    
                d['cost'][s_ind, method_ind, n_ind, i_it] = cost_final/noise_realizations_final
                print('cost = ', d['cost'][s_ind, method_ind, n_ind, i_it])
                
                file=open(dict_file, "wb")
                pickle.dump(dict_list, file)
                file.close()
# Out:
# Point =  [0.4  0.35]
# sigma =  0.01
# set cost params:  0.020161370502275046 0.0 1.0
# n =  2
# iteration =  1
# n =  2
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1624.048295796249
# Gradient descend method:  None
# RUN  1 , total integrated cost =  245.311081309991
# RUN  1 , total integrated cost mean =  245.311081309991
# Improved over  1  iterations in  0.05129125795792788  seconds by  84.89508705221613  percent.
# cost =  258.27613574534354
# iteration =  2
# n =  2
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  267.53094402493423
# Gradient descend method:  None
# RUN  1 , total integrated cost =  77.51848227869729
# RUN  1 , total integrated cost mean =  77.51848227869729
# Improved over  1  iterations in  0.046636177983600646  seconds by  71.02447996764349  percent.

# %%
#len(sigma_array), 4, N_max, max_it

##### METHOD 3
method_ind = 2

for d in dict_list:
    print("Point = ", d['point'])
    aln.params.ext_exc_current = d['point'][0] * 5.
    aln.params.ext_inh_current = d['point'][1] * 5.
    
    max_it = d['cost'].shape[3]
    
    for s_ind in range(len(d['sigma'])):
        
        print("sigma = ", d['sigma'][s_ind])
        
        s = d['sigma'][s_ind]
        aln.params.sigma_ou = s
        c_p = d['cost_params'][s_ind]
        cost.setParams(c_p[0], c_p[1], c_p[2])
        
        target_ = d['target'][s_ind].copy()
        target_[0,0,:int(trans_time * dur / aln.params.dt)] = -1000
        target_[0,1,:int(trans_time * dur / aln.params.dt)] = -1000
                
        for n_ind in range(len(d['N_array'])):
            
            if d['cost'][s_ind, method_ind, n_ind, -1] > 0.:
                continue
            
            n_ = d['N_array'][n_ind]
            
            print("n = ", n_)
            aln.params.duration = dur
            control_init = aln.getZeroControl()
        
            for i_it in range(1, max_it, 1):
                
                print("iteration = ", i_it)

                if i_it <= init_it:
                    c_vars = d['init']
                else:
                    c_vars = [0,1]
                    
                aln.params.duration = dur
                setinit(d['init_vars'], aln)

                bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                    control_init, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_ = 1,
                    tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                    t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                    control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                    noise_real=n_, init_params = d['init_vars'], method='M3')
    
                control_init = bc[:,:,n_pre:-n_post]
        
                aln.params.duration = dur
                setinit(d['init_vars'], aln)

                cost_final = 0.
                
                for j in range(noise_realizations_final):
                    state_ = fo.updateState(aln, control_init)
                    cost_final += cost.numba_cost_precision_int(1, T, dt, d['cost_params'][s_ind][0],
                                                                   state_, target_, list(prec_vars) )
                    cost_final += cost.numba_cost_sparsity_int(1, 6, T, d['cost_params'][s_ind][2],
                                                                   dt, control_init)
                    
                d['cost'][s_ind, method_ind, n_ind, i_it] = cost_final/noise_realizations_final
                print('cost = ', d['cost'][s_ind, method_ind, n_ind, i_it])
                
                file=open(dict_file, "wb")
                pickle.dump(dict_list, file)
                file.close() 
                
            break
        break
    break
# Out:
# Point =  [0.4  0.35]
# sigma =  0.01
# set cost params:  0.020161370502275046 0.0 1.0
# n =  1
# iteration =  1
# start
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1614.1776865097024
# Gradient descend method:  None
# RUN  1 , total integrated cost =  266.65677994008666
# RUN  1 , total integrated cost mean =  266.65677994008666
# Improved over  1  iterations in  6.514188711007591  seconds by  83.48033291696206  percent.
# /home/lena/.local/lib/python3.9/site-packages/numba/core/ir_utils.py:2119: NumbaPendingDeprecationWarning:
# Encountered the use of a type that is scheduled for deprecation: type 'reflected list' found for argument 'var_' of function 'numba_cost_precision_int'.
#
# For more information visit https://numba.pydata.org/numba-doc/latest/reference/deprecation.html#deprecation-of-reflection-for-list-and-set-types
#
# File "../../../../neurolib/utils/costFunctions.py", line 79:
# @numba.njit
# def numba_cost_precision_int(N, T, dt, i_p, state_, target_state_, var_):
# ^
#
#   warnings.warn(NumbaPendingDeprecationWarning(msg, loc=loc))
# cost =  259.55719603073453
# iteration =  2
# start
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  256.280815572712
# Gradient descend method:  None
# RUN  1 , total integrated cost =  90.4501805042274

# %%
p = dict_list[0]

fig, ax = plt.subplots(figsize=(10,8))
for n_ind in range(len(d['N_array'])):
    n_ = d['N_array'][n_ind]
    ax.plot(np.arange(1, p['cost'].shape[3]), p['cost'][0, 0, n_ind, 1:], linestyle='', marker='x',
            label=r'$N=$'+'{}'.format(n_))

ax.set_title("METHOD 1")
ax.legend()
ax.set_yscale('log')
plt.show()
