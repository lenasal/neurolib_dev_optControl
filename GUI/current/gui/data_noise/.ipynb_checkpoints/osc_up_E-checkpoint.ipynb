# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import sys
import pickle
import matplotlib
import ipyparams

path = os.getcwd().split(os.sep + 'GUI')[0]
if path not in sys.path:
    print("not here")
    sys.path.append(path)

from neurolib.models.aln import ALNModel
from neurolib.utils import plotFunctions as plotFunc
from neurolib.utils import func_optimize as fo
from neurolib.utils import costFunctions as cost
import neurolib.dashboard.functions as functions
import neurolib.dashboard.data as data
import neurolib.dashboard.layout as layout
    
# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2 

#path = os.path.join(os.getcwd(), "plots")

cmap_ = layout.getcolormap()
darkgrey, midgrey, lightgrey, color_bi_updown, color_LC, color_bi_uposc = layout.getcolors_rgba()
exc_red = cmap_(3)
inh_blue=cmap_(0)
green = cmap_(2)
# Out:
# not here

# %%
aln = ALNModel()
N = aln.params.N

data.set_parameters(aln)

state_vars = aln.state_vars
init_vars = aln.init_vars

##############################################################
def setinit(init_vars_, model):
    state_vars = model.state_vars
    init_vars = model.init_vars
    for iv in range(len(init_vars)):
        for sv in range(len(state_vars)):
            if state_vars[sv] in init_vars[iv]:
                #print("set init vars ", )
                if model.params[init_vars[iv]].ndim == 2:
                    model.params[init_vars[iv]][0,:] = init_vars_[sv]
                else:
                    model.params[init_vars[iv]][0] = init_vars_[sv]
                    
##############################################################               
def setmaxmincontrol(max_c_c, min_c_c, max_c_r, min_c_r):
    import numpy as np
    
    max_cntrl = np.zeros(( 6 ))
    min_cntrl = np.zeros(( 6 ))
    
    max_cntrl[0] = max_c_c
    min_cntrl[0] = min_c_c
    max_cntrl[1] = max_c_c
    min_cntrl[1] = min_c_c
    max_cntrl[2] = max_c_r
    min_cntrl[2] = min_c_r
    max_cntrl[3] = max_c_r
    min_cntrl[3] = min_c_r
    max_cntrl[4] = max_c_r
    min_cntrl[4] = min_c_r
    max_cntrl[5] = max_c_r
    min_cntrl[5] = min_c_r
            
    return max_cntrl, min_cntrl

# %%
points = np.array( [ [0.4, 0.322] ])

# 10 points, two costs, 4 methods, N

# %%
def create_dict(task, point, cost_params, init, init_vars, target, sigma_array, N_max_array, max_it):
    return dict( {'task':task, 'point':point, 'cost_params':cost_params, 'init':init, 'init_vars':init_vars,
            'target':target, 'sigma':sigma_array, 'N_array':N_max_array,
            'cost':np.zeros(( len(sigma_array), 4, 2, len(N_max_array), max_it )) } )

params_list = ['task', 'point', 'cost_params', 'init', 'init_vars', 'target', 'sigma', 'N_array', 'cost']

# %%
dict_list = []
sigma_array = np.arange(0.01, 0.031, 0.01)
N_array = [1,2,10,30]
maxit = 30

for p in points:
    dict_list.append(create_dict('DU', p, [None]*len(sigma_array), [0], None,
                [None]*len(sigma_array), sigma_array, N_array, maxit) )

# %%
for d in dict_list:
    print(d['target'])
# Out:
# [None, None, None]

# %%
dict_file = "OU_1E.pickle"

if False:
    file=open(dict_file, "wb")
    pickle.dump(dict_list, file)
    file.close()

if True:
    file = open(dict_file, "rb")
    dict_list = pickle.load(file)
    file.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_32687/3426067400.py in <module>
#       7
#       8 if True:
# ----> 9     file = open(dict_file, "rb")
#      10     dict_list = pickle.load(file)
#      11     file.close()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'OU_1E.pickle'

# %%
dur_pre = 10
dur_post = 10
dur = 500.
dur_comp = 2000.
dt = aln.params.dt
T = int(1 + dur / dt)

prec_vars = [0,1]
trans_time = 0.8

n_pre = int(np.around(dur_pre/aln.params.dt,1))
n_post = int(np.around(dur_post/aln.params.dt,1))

tol = 1e-16
start_step = 10.
c_scheme = np.zeros(( 1,1 ))
c_scheme[0,0] = 1.
u_mat = np.identity(1)
u_scheme = np.array([[1.]])

maxC = [5., -5., 0.18, 0.]
n_dur = int(np.around(dur/aln.params.dt + 1.,1))
max_cntrl, min_cntrl = setmaxmincontrol(maxC[0], maxC[1], maxC[2], maxC[3])

noise_realizations_final = 10000
noise_realizations_target_compute = 1000
init_it = 5

# %%
# get init vars without noise
aln = ALNModel()
data.set_parameters(aln)
aln.params.duration = dur_comp

# initial without noise
control0 = aln.getZeroControl()

for d in dict_list:
    
    print("Point = ", d['point'])
    aln.params.ext_exc_current = d['point'][0] * 5.
    aln.params.ext_inh_current = d['point'][1] * 5.
    aln.params.duration = dur_comp
    
    if type(d['init_vars']) == type(None):
    
        control0[0,0,:500] = -5.

        aln.run(control=control0)

        init_state_vars = np.zeros(( len(state_vars) ))
        for j in range(len(state_vars)):
            if aln.state[state_vars[j]].size == 1:
                init_state_vars[j] = aln.state[state_vars[j]][0]
            else:
                init_state_vars[j] = aln.state[state_vars[j]][0,-1]

        initVars = init_state_vars.copy()
        d['init_vars'] = initVars
    
    for ind_s in range(len(d['sigma'])):
        
        #if type(d['target'][ind_s]) != type(None):
        #    continue        
        
        s = d['sigma'][ind_s]
        aln.params.sigma_ou = s
        aln.params.duration = dur_comp
        control0[0,0,:500] = 5.
        
        stateswitchcount = 0
        target_rates_e = []
        target_rates_i = []

        for j in range(noise_realizations_target_compute):
            if j % 100 == 0:
                print(j)
            aln.run(control=control0)
            #plt.plot(aln.t, aln.rates_exc[0,:])
            if np.amin(aln.rates_exc[0,1000:]) < 3.:
                #print("fell in down state, repeat")
                j -= 1
                stateswitchcount += 1
                if stateswitchcount > 0.8 * noise_realizations_target_compute:
                    print("UNSTABLE: point, sigma ", d['point'], s)
                    break
                continue
            target_rates_e.append(aln.rates_exc[0,1000:])
            target_rates_i.append(aln.rates_inh[0,1000:])
        
        #plt.show()            

        aln.params.duration = dur
        target = aln.getZeroTarget()
        target[:,0,:] = np.mean(target_rates_e)
        target[:,1,:] = np.mean(target_rates_i)
        stddev = np.std(target_rates_e) + np.std(target_rates_i)
        
        d['target'][ind_s] = target
        d['cost_params'][ind_s] = [1. / ( stddev * (1. - trans_time) * dur ), 0., 1.]
        
        #print(stddev)
        
    file=open(dict_file, "wb")
    pickle.dump(dict_list, file)
    file.close()
# Out:
# Point =  [0.4   0.322]
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900

# %%
dict_list[0]['init_vars']
# Out:
# array([ 1.38476963e+000,  1.28885088e+001,  2.55697567e-001,
#         6.95281166e-001,  0.00000000e+000,  1.71538706e-001,
#         6.33656436e-001,  1.62003917e-001,  7.80243181e-001,
#         7.77006827e-003,  7.06669419e-003,  7.00884310e-003,
#         6.74044730e-003,  1.32914953e-176,  9.96862146e-177,
#         1.62432140e+000,  1.55922871e+000, -6.04482159e+001,
#         1.37576571e+001,  4.77763399e+000])

# %%
#len(sigma_array), 4, N_max, max_it

##### METHOD 1
method_ind = 0
step_method_ind = 0

for d in dict_list:
    print("Point = ", d['point'])
    aln.params.ext_exc_current = d['point'][0] * 5.
    aln.params.ext_inh_current = d['point'][1] * 5.
    
    max_it = d['cost'].shape[3]
    
    for s_ind in range(len(d['sigma'])):
        
        print("sigma = ", d['sigma'][s_ind])
        
        s = d['sigma'][s_ind]
        aln.params.sigma_ou = s
        c_p = d['cost_params'][s_ind]
        cost.setParams(c_p[0], c_p[1], c_p[2])
        aln.params.duration = dur
        zero_init = aln.getZeroControl()
        
        target_ = d['target'][s_ind].copy()
        target_[0,0,:int(trans_time * dur / aln.params.dt)] = -1000
        target_[0,1,:int(trans_time * dur / aln.params.dt)] = -1000
        
        if np.amin(d['cost'][s_ind, method_ind, step_method_ind, :, 0]) == 0.:
        
            setinit(d['init_vars'], aln)
            cost_final = 0.

            for n_ in range(noise_realizations_final):
                state_ = fo.updateState(aln, zero_init)
                cost_final += cost.numba_cost_precision_int(1, T, dt, d['cost_params'][s_ind][0],
                                                               state_, target_, list(prec_vars) )

            d['cost'][s_ind, :, :, :, 0] = cost_final/noise_realizations_final
            
        print('cost = ', d['cost'][s_ind, 0, 0, 0])    
        
        for i_it in range(1, d['cost'].shape[4], 1):
            
            print("iteration = ", i_it)
        
            for n_ind in range(len(d['N_array'])):

                if d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it] > 0.:
                    continue
                    
                n_max = d['N_array'][n_ind]
                print("n max = ", n_max)

                aln.params.duration = dur
                control_init = aln.getZeroControl()

                if i_it <= init_it:
                    c_vars = d['init']
                else:
                    c_vars = [0,1]
                    
                n_ = 0
                control_sum = aln.getZeroControl()
                
                while n_ < n_max:
                
                    print('--------', n_)

                    aln.params.duration = dur
                    setinit(d['init_vars'], aln)

                    bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                        control_init, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_ = i_it,
                        tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                        t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                        control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                        noise_real=0, init_params = d['init_vars'])
                    
                    control_sum += bc[:,:,n_pre:-n_post]
                    n_ += 1

                control_init = control_sum / n_max
        
                aln.params.duration = dur
                setinit(d['init_vars'], aln)

                cost_final = 0.
                cs = cost.numba_cost_sparsity_int(1, 6, T, d['cost_params'][s_ind][2], dt, control_init)

                for j in range(noise_realizations_final):
                    state_ = fo.updateState(aln, control_init)
                    cost_final += cost.numba_cost_precision_int(1, T, dt, d['cost_params'][s_ind][0],
                                                                   state_, target_, list(prec_vars) )

                d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it] = (
                                cost_final / noise_realizations_final + cs )
                print('cost = ', d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it])
                
                file=open(dict_file, "wb")
                pickle.dump(dict_list, file)
                file.close()
# Out:
# Point =  [0.4   0.322]
# sigma =  0.01
# set cost params:  0.00829916864127671 0.0 1.0
# cost =  [1388.82380225  414.27654183   99.46427622    7.48648856    5.52684603
#     3.59214672   16.63464692    1.85939696  111.26753212    2.30148686
#    22.25034319  322.75506667   78.49919284  206.36012691  282.54034183
#    19.65537234  173.2725337   638.53175073   36.42171746  173.19519795
#    54.11163022  265.11579046    1.79745259  560.20190655   23.9462663
#   259.95202647    4.62328446   15.10001       8.89744843  536.16492379]
# iteration =  1
# iteration =  2
# iteration =  3
# n max =  10
# -------- 0
# interpolate adjoint :  True True True
# initial cost =  1378.0137043610528
# RUN  0 , total integrated cost =  1378.0137043610528
# Gradient descend method:  None
# RUN  1 , total integrated cost =  28.070556025130866
# RUN  2 , total integrated cost =  5.183848411514954
# RUN  3 , total integrated cost =  2.6750972146281287
# RUN  3 , total integrated cost =  2.6750972146281287
# Improved over  3  iterations in  0.3298001579969423  seconds by  99.8058729600321  percent.
# -------- 1
# interpolate adjoint :  True True True
# initial cost =  1405.485779637363
# RUN  0 , total integrated cost =  1405.485779637363
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.557025685313451
# RUN  2 , total integrated cost =  2.515533405603647
# RUN  3 , total integrated cost =  2.505713518077789
# RUN  3 , total integrated cost =  2.505713518077789
# Improved over  3  iterations in  0.3179163829991012  seconds by  99.82171904160252  percent.
# -------- 2
# interpolate adjoint :  True True True
# initial cost =  1356.3972505959332
# RUN  0 , total integrated cost =  1356.3972505959332
# Gradient descend method:  None
# RUN  1 , total integrated cost =  95.99955715295886
# RUN  2 , total integrated cost =  83.03659415657346
# RUN  3 , total integrated cost =  7.578659776311609
# RUN  3 , total integrated cost =  7.578659776311609
# Improved over  3  iterations in  0.35519842299981974  seconds by  99.44126547197129  percent.
# -------- 3
# interpolate adjoint :  True True True
# initial cost =  1393.956173713445
# RUN  0 , total integrated cost =  1393.956173713445
# Gradient descend method:  None
# RUN  1 , total integrated cost =  143.1176995335352
# RUN  2 , total integrated cost =  73.10985878525274
# RUN  3 , total integrated cost =  9.906269297307889
# RUN  3 , total integrated cost =  9.906269297307889
# Improved over  3  iterations in  0.3606659810029669  seconds by  99.28934140942768  percent.
# -------- 4
# interpolate adjoint :  True True True
# initial cost =  1320.5550562578483
# RUN  0 , total integrated cost =  1320.5550562578483
# Gradient descend method:  None
# RUN  1 , total integrated cost =  122.65601613203644
# RUN  2 , total integrated cost =  73.42223531095918
# RUN  3 , total integrated cost =  15.990259763574725
# RUN  3 , total integrated cost =  15.990259763574725
# Improved over  3  iterations in  0.4849542299998575  seconds by  98.78912585372339  percent.
# -------- 5
# interpolate adjoint :  True True True
# initial cost =  1381.805423961629
# RUN  0 , total integrated cost =  1381.805423961629
# Gradient descend method:  None
# RUN  1 , total integrated cost =  29.695070833713817
# RUN  2 , total integrated cost =  28.0003626364262
# RUN  3 , total integrated cost =  323.74071578354517
# RUN  3 , total integrated cost =  323.74071578354517
# Improved over  3  iterations in  0.4325445549984579  seconds by  76.57117925797525  percent.
# -------- 6
# interpolate adjoint :  True True True
# initial cost =  1403.9877400115981
# RUN  0 , total integrated cost =  1403.9877400115981
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12.957806270308676
# RUN  2 , total integrated cost =  13.423058851421594
# RUN  3 , total integrated cost =  10.751618329177386
# RUN  3 , total integrated cost =  10.751618329177386
# Improved over  3  iterations in  0.32984960499743465  seconds by  99.23420853168642  percent.
# -------- 7
# interpolate adjoint :  True True True
# initial cost =  1362.9438058816
# RUN  0 , total integrated cost =  1362.9438058816
# Gradient descend method:  None
# RUN  1 , total integrated cost =  54.44870903233532
# RUN  2 , total integrated cost =  289.43508269201925
# RUN  3 , total integrated cost =  191.3435578408824
# RUN  3 , total integrated cost =  191.3435578408824
# Improved over  3  iterations in  0.3430625049950322  seconds by  85.96100902948712  percent.
# -------- 8
# interpolate adjoint :  True True True
# initial cost =  1370.4788724377263
# RUN  0 , total integrated cost =  1370.4788724377263
# Gradient descend method:  None
# RUN  1 , total integrated cost =  10.037855491245566
# RUN  2 , total integrated cost =  10.25950596170355
# RUN  3 , total integrated cost =  2.82398916967332
# RUN  3 , total integrated cost =  2.82398916967332
# Improved over  3  iterations in  0.3459242489989265  seconds by  99.79394142978285  percent.
# -------- 9
# interpolate adjoint :  True True True
# initial cost =  1420.9837333879539
# RUN  0 , total integrated cost =  1420.9837333879539
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12.379737889125602
# RUN  2 , total integrated cost =  2.5886499246374095
# RUN  3 , total integrated cost =  1.6985343680789866
# RUN  3 , total integrated cost =  1.6985343680789866
# Improved over  3  iterations in  0.3014519080024911  seconds by  99.88046771203852  percent.
# cost =  14.970814747133922
# n max =  30
# -------- 0
# interpolate adjoint :  True True True
# initial cost =  1352.685549510511
# RUN  0 , total integrated cost =  1352.685549510511
# Gradient descend method:  None
# RUN  1 , total integrated cost =  51.98637249294586
# RUN  2 , total integrated cost =  48.975364518277885
# RUN  3 , total integrated cost =  4.809057626408043
# RUN  3 , total integrated cost =  4.809057626408043
# Improved over  3  iterations in  0.43160396500024945  seconds by  99.64448074216892  percent.
# -------- 1
# interpolate adjoint :  True True True
# initial cost =  1353.5079101703673
# RUN  0 , total integrated cost =  1353.5079101703673
# Gradient descend method:  None
# RUN  1 , total integrated cost =  347.67344528693695
# RUN  2 , total integrated cost =  183.37343511653157
# RUN  3 , total integrated cost =  35.73328042716142
# RUN  3 , total integrated cost =  35.73328042716142
# Improved over  3  iterations in  0.38915580000320915  seconds by  97.35995038088373  percent.
# -------- 2
# interpolate adjoint :  True True True
# initial cost =  1413.0702386717403
# RUN  0 , total integrated cost =  1413.0702386717403
# Gradient descend method:  None
# RUN  1 , total integrated cost =  65.82013031835265
# RUN  2 , total integrated cost =  60.7742027542185
# RUN  3 , total integrated cost =  7.699102023668039
# RUN  3 , total integrated cost =  7.699102023668039
# Improved over  3  iterations in  0.3498642589984229  seconds by  99.45515079060011  percent.
# -------- 3
# interpolate adjoint :  True True True
# initial cost =  1394.7590983330151
# RUN  0 , total integrated cost =  1394.7590983330151
# Gradient descend method:  None
# RUN  1 , total integrated cost =  13.194572620249382
# RUN  2 , total integrated cost =  2.6987777559717663
# RUN  3 , total integrated cost =  2.0372021426639066
# RUN  3 , total integrated cost =  2.0372021426639066
# Improved over  3  iterations in  0.30729852199874585  seconds by  99.85393878089064  percent.
# -------- 4
# interpolate adjoint :  True True True
# initial cost =  1414.3067920147691
# RUN  0 , total integrated cost =  1414.3067920147691
# Gradient descend method:  None
# RUN  1 , total integrated cost =  25.64886087804068
# RUN  2 , total integrated cost =  11.148258724477696
# RUN  3 , total integrated cost =  5.572298116733096
# RUN  3 , total integrated cost =  5.572298116733096
# Improved over  3  iterations in  0.34099345299910055  seconds by  99.60600499494208  percent.
# -------- 5
# interpolate adjoint :  True True True
# initial cost =  1322.6749796333097
# RUN  0 , total integrated cost =  1322.6749796333097
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14.51509091675942
# RUN  2 , total integrated cost =  81.49533460215072
# RUN  3 , total integrated cost =  45.69117535337334
# RUN  3 , total integrated cost =  45.69117535337334
# Improved over  3  iterations in  0.3149485329995514  seconds by  96.54554776820224  percent.
# -------- 6
# interpolate adjoint :  True True True
# initial cost =  1279.265622610135
# RUN  0 , total integrated cost =  1279.265622610135
# Gradient descend method:  None
# RUN  1 , total integrated cost =  192.93978622250765
# RUN  2 , total integrated cost =  90.59478792190404
# RUN  3 , total integrated cost =  21.081832058820936
# RUN  3 , total integrated cost =  21.081832058820936
# Improved over  3  iterations in  0.31597239799884846  seconds by  98.35203638038777  percent.
# -------- 7
# interpolate adjoint :  True True True
# initial cost =  1286.307006796858
# RUN  0 , total integrated cost =  1286.307006796858
# Gradient descend method:  None
# RUN  1 , total integrated cost =  21.381930854557396
# RUN  2 , total integrated cost =  3.248531650506423
# RUN  3 , total integrated cost =  2.2707412453819966
# RUN  3 , total integrated cost =  2.2707412453819966
# Improved over  3  iterations in  0.3282918900004006  seconds by  99.8234681741308  percent.
# -------- 8
# interpolate adjoint :  True True True
# initial cost =  1379.3346036298833
# RUN  0 , total integrated cost =  1379.3346036298833
# Gradient descend method:  None
# RUN  1 , total integrated cost =  25.610812466779024
# RUN  2 , total integrated cost =  23.865867702683893
# RUN  3 , total integrated cost =  4.795144344772674
# RUN  3 , total integrated cost =  4.795144344772674
# Improved over  3  iterations in  0.347710038004152  seconds by  99.65235814920081  percent.
# -------- 9
# interpolate adjoint :  True True True
# initial cost =  1360.2865362927616
# RUN  0 , total integrated cost =  1360.2865362927616
# Gradient descend method:  None
# RUN  1 , total integrated cost =  57.37949310895976
# RUN  2 , total integrated cost =  52.06017371335863
# RUN  3 , total integrated cost =  4.973935612770386
# RUN  3 , total integrated cost =  4.973935612770386
# Improved over  3  iterations in  0.335898580000503  seconds by  99.6343464792112  percent.
# -------- 10
# interpolate adjoint :  True True True
# initial cost =  1320.2201806976914
# RUN  0 , total integrated cost =  1320.2201806976914
# Gradient descend method:  None
# RUN  1 , total integrated cost =  429.5639872994202
# RUN  2 , total integrated cost =  271.64685220855125
# RUN  3 , total integrated cost =  94.7789608512449
# RUN  3 , total integrated cost =  94.7789608512449
# Improved over  3  iterations in  0.30639401500229724  seconds by  92.82097318031016  percent.
# -------- 11
# interpolate adjoint :  True True True
# initial cost =  1357.0029205519756
# RUN  0 , total integrated cost =  1357.0029205519756
# Gradient descend method:  None
# RUN  1 , total integrated cost =  157.0331569471337
# RUN  2 , total integrated cost =  57.86394748140331
# RUN  3 , total integrated cost =  8.545617075343431
# RUN  3 , total integrated cost =  8.545617075343431
# Improved over  3  iterations in  0.3225161310037947  seconds by  99.37025801890924  percent.
# -------- 12
# interpolate adjoint :  True True True
# initial cost =  1389.738253932803
# RUN  0 , total integrated cost =  1389.738253932803
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.173462633221697
# RUN  2 , total integrated cost =  12.588840381143289
# RUN  3 , total integrated cost =  2.0614333911934546
# RUN  3 , total integrated cost =  2.0614333911934546
# Improved over  3  iterations in  0.38429968500713585  seconds by  99.85166750750655  percent.
# -------- 13
# interpolate adjoint :  True True True
# initial cost =  1397.7848913530813
# RUN  0 , total integrated cost =  1397.7848913530813
# Gradient descend method:  None
# RUN  1 , total integrated cost =  56.50945528182534
# RUN  2 , total integrated cost =  33.7216583715393
# RUN  3 , total integrated cost =  21.242123052376016
# RUN  3 , total integrated cost =  21.242123052376016
# Improved over  3  iterations in  0.3037147110007936  seconds by  98.48030099740073  percent.
# -------- 14
# interpolate adjoint :  True True True
# initial cost =  1383.7220147178239
# RUN  0 , total integrated cost =  1383.7220147178239
# Gradient descend method:  None
# RUN  1 , total integrated cost =  137.5525043721151
# RUN  2 , total integrated cost =  16.209595629161484
# RUN  3 , total integrated cost =  6.184980444939997
# RUN  3 , total integrated cost =  6.184980444939997
# Improved over  3  iterations in  0.26847275999898557  seconds by  99.55301857026527  percent.
# -------- 15
# interpolate adjoint :  True True True
# initial cost =  1417.61918908013
# RUN  0 , total integrated cost =  1417.61918908013
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12.771936468145267
# RUN  2 , total integrated cost =  13.254046783673378
# RUN  3 , total integrated cost =  11.946885921164167
# Control only changes marginally.
# RUN  3 , total integrated cost =  11.946885921164167
# Improved over  3  iterations in  0.3842877139977645  seconds by  99.15725703960622  percent.
# -------- 16
# interpolate adjoint :  True True True
# initial cost =  1408.8844014019282
# RUN  0 , total integrated cost =  1408.8844014019282
# Gradient descend method:  None
# RUN  1 , total integrated cost =  19.33069133895262
# RUN  2 , total integrated cost =  6.662692961028607
# RUN  3 , total integrated cost =  2.9030567020214715
# RUN  3 , total integrated cost =  2.9030567020214715
# Improved over  3  iterations in  0.250819369997771  seconds by  99.79394642320315  percent.
# -------- 17
# interpolate adjoint :  True True True
# initial cost =  1311.708378814298
# RUN  0 , total integrated cost =  1311.708378814298
# Gradient descend method:  None
# RUN  1 , total integrated cost =  19.544151279191986
# RUN  2 , total integrated cost =  13.390770486727785
# RUN  3 , total integrated cost =  6.277145583923435
# RUN  3 , total integrated cost =  6.277145583923435
# Improved over  3  iterations in  0.3273320349981077  seconds by  99.52145265782342  percent.
# -------- 18
# interpolate adjoint :  True True True
# initial cost =  1424.938324126749
# RUN  0 , total integrated cost =  1424.938324126749
# Gradient descend method:  None
# RUN  1 , total integrated cost =  8.71281820263744
# RUN  2 , total integrated cost =  9.764445198042798
# RUN  3 , total integrated cost =  2.4553458932305823
# RUN  3 , total integrated cost =  2.4553458932305823
# Improved over  3  iterations in  0.34379316499689594  seconds by  99.82768756712784  percent.
# -------- 19
# interpolate adjoint :  True True True
# initial cost =  1365.809580857898
# RUN  0 , total integrated cost =  1365.809580857898
# Gradient descend method:  None
# RUN  1 , total integrated cost =  61.25867785055372
# RUN  2 , total integrated cost =  38.92689686546013
# step size too small or too large
# RUN  3 , total integrated cost =  40.21173850447714
# Control only changes marginally.
# RUN  3 , total integrated cost =  40.21173850447714
# Improved over  3  iterations in  0.6890519580047112  seconds by  97.05583127633216  percent.
# -------- 20
# interpolate adjoint :  True True True
# initial cost =  1337.572390288045
# RUN  0 , total integrated cost =  1337.572390288045
# Gradient descend method:  None
# RUN  1 , total integrated cost =  63.307988567727215
# RUN  2 , total integrated cost =  57.41713146176825
# RUN  3 , total integrated cost =  55.41878898415109
# RUN  3 , total integrated cost =  55.41878898415109
# Improved over  3  iterations in  0.32513231899793027  seconds by  95.85676338816947  percent.
# -------- 21
# interpolate adjoint :  True True True
# initial cost =  1417.8388056039437
# RUN  0 , total integrated cost =  1417.8388056039437
# Gradient descend method:  None
# RUN  1 , total integrated cost =  40.35645613685627
# RUN  2 , total integrated cost =  143.5107879924088
# RUN  3 , total integrated cost =  31.50530627083106
# RUN  3 , total integrated cost =  31.50530627083106
# Improved over  3  iterations in  0.3385014079976827  seconds by  97.77793454754463  percent.
# -------- 22
# interpolate adjoint :  True True True
# initial cost =  1367.3377648964981
# RUN  0 , total integrated cost =  1367.3377648964981
# Gradient descend method:  None
# RUN  1 , total integrated cost =  49.03512056438425
# RUN  2 , total integrated cost =  29.118082795129475
# RUN  3 , total integrated cost =  9.340199748840984
# RUN  3 , total integrated cost =  9.340199748840984
# Improved over  3  iterations in  0.30075669899815693  seconds by  99.31690618158652  percent.
# -------- 23
# interpolate adjoint :  True True True
# initial cost =  1418.6090253250356
# RUN  0 , total integrated cost =  1418.6090253250356
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14.821311888344075
# RUN  2 , total integrated cost =  9.49096479099699
# RUN  3 , total integrated cost =  8.579683020528027
# RUN  3 , total integrated cost =  8.579683020528027
# Improved over  3  iterations in  0.42462548299954506  seconds by  99.3952045371654  percent.
# -------- 24
# interpolate adjoint :  True True True
# initial cost =  1413.7886534165264
# RUN  0 , total integrated cost =  1413.7886534165264
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22.85711710851207
# RUN  2 , total integrated cost =  3.540506610250075
# RUN  3 , total integrated cost =  3.4060008255213745
# RUN  3 , total integrated cost =  3.4060008255213745
# Improved over  3  iterations in  0.41888629200548166  seconds by  99.7590869881937  percent.
# -------- 25
# interpolate adjoint :  True True True
# initial cost =  1321.2296441434698
# RUN  0 , total integrated cost =  1321.2296441434698
# Gradient descend method:  None
# RUN  1 , total integrated cost =  17.569552995168152
# RUN  2 , total integrated cost =  15.294645576042477
# RUN  3 , total integrated cost =  16.252849103520084
# RUN  3 , total integrated cost =  16.252849103520084
# Improved over  3  iterations in  0.34916334100125823  seconds by  98.76986947912022  percent.
# -------- 26
# interpolate adjoint :  True True True
# initial cost =  1380.9083513839296
# RUN  0 , total integrated cost =  1380.9083513839296
# Gradient descend method:  None
# RUN  1 , total integrated cost =  78.6622226212833
# RUN  2 , total integrated cost =  13.48378562041012
# RUN  3 , total integrated cost =  4.461331840645885
# RUN  3 , total integrated cost =  4.461331840645885
# Improved over  3  iterations in  0.3374976310005877  seconds by  99.67692773845747  percent.
# -------- 27
# interpolate adjoint :  True True True
# initial cost =  1420.9286329020613
# RUN  0 , total integrated cost =  1420.9286329020613
# Gradient descend method:  None
# RUN  1 , total integrated cost =  71.96854374983249
# RUN  2 , total integrated cost =  21.07995613682305
# RUN  3 , total integrated cost =  3.8084079720928328
# RUN  3 , total integrated cost =  3.8084079720928328
# Improved over  3  iterations in  0.32137682100437814  seconds by  99.73197753328999  percent.
# -------- 28
# interpolate adjoint :  True True True
# initial cost =  1352.573182846473
# RUN  0 , total integrated cost =  1352.573182846473
# Gradient descend method:  None
# RUN  1 , total integrated cost =  36.866024985452704
# RUN  2 , total integrated cost =  13.687355716177777
# RUN  3 , total integrated cost =  3.6664946832687653
# RUN  3 , total integrated cost =  3.6664946832687653
# Improved over  3  iterations in  0.3348201839980902  seconds by  99.7289244878009  percent.
# -------- 29
# interpolate adjoint :  True True True
# initial cost =  1380.9998152144028
# RUN  0 , total integrated cost =  1380.9998152144028
# Gradient descend method:  None
# RUN  1 , total integrated cost =  235.74808679512805
# RUN  2 , total integrated cost =  145.9769222096247
# RUN  3 , total integrated cost =  8.573227526283716
# RUN  3 , total integrated cost =  8.573227526283716
# Improved over  3  iterations in  0.3483745039993664  seconds by  99.37920139946198  percent.
# cost =  6.931996239360671
# iteration =  4
# n max =  30
# -------- 0
# interpolate adjoint :  True True True
# initial cost =  1369.8263220334577
# RUN  0 , total integrated cost =  1369.8263220334577
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14.061941384258102
# RUN  2 , total integrated cost =  5.305395311946956
# RUN  3 , total integrated cost =  2.534065500404729
# RUN  4 , total integrated cost =  2.4184572890416685
# RUN  4 , total integrated cost =  2.4184572890416685
# Improved over  4  iterations in  0.4274860380028258  seconds by  99.82344788896657  percent.
# -------- 1
# interpolate adjoint :  True True True
# initial cost =  1411.1578121534128
# RUN  0 , total integrated cost =  1411.1578121534128
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.045205071858863
# RUN  2 , total integrated cost =  2.286757842399166
# RUN  3 , total integrated cost =  1.688763845177386
# RUN  4 , total integrated cost =  1.5754922921360177
# RUN  4 , total integrated cost =  1.5754922921360177
# Improved over  4  iterations in  0.5329565850042854  seconds by  99.88835463485606  percent.
# -------- 2
# interpolate adjoint :  True True True
# initial cost =  1347.1382165369982
# RUN  0 , total integrated cost =  1347.1382165369982
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14.578013992519473
# RUN  2 , total integrated cost =  2.7824334243027646
# RUN  3 , total integrated cost =  2.547714929213244
# RUN  4 , total integrated cost =  2.3970050064834796
# RUN  4 , total integrated cost =  2.3970050064834796
# Improved over  4  iterations in  0.4755190229989239  seconds by  99.82206688392782  percent.
# -------- 3
# interpolate adjoint :  True True True
# initial cost =  1432.469262001953
# RUN  0 , total integrated cost =  1432.469262001953
# Gradient descend method:  None
# RUN  1 , total integrated cost =  46.534636448880185
# RUN  2 , total integrated cost =  42.37326631110991
# RUN  3 , total integrated cost =  44.308402752579596
# RUN  4 , total integrated cost =  46.1908457701147
# RUN  4 , total integrated cost =  46.1908457701147
# Improved over  4  iterations in  0.5012063039976056  seconds by  96.77543895737347  percent.
# -------- 4
# interpolate adjoint :  True True True
# initial cost =  1380.076545625097
# RUN  0 , total integrated cost =  1380.076545625097
# Gradient descend method:  None
# RUN  1 , total integrated cost =  10.094167536845486
# RUN  2 , total integrated cost =  2.3705109642728495
# RUN  3 , total integrated cost =  1.7164922365481072
# RUN  4 , total integrated cost =  1.6386379828665354
# RUN  4 , total integrated cost =  1.6386379828665354
# Improved over  4  iterations in  0.4823960099965916  seconds by  99.88126470317454  percent.
# -------- 5
# interpolate adjoint :  True True True
# initial cost =  1364.229295720533
# RUN  0 , total integrated cost =  1364.229295720533
# Gradient descend method:  None
# RUN  1 , total integrated cost =  365.642535052731
# RUN  2 , total integrated cost =  159.76994039262806
# RUN  3 , total integrated cost =  40.087469969130005
# RUN  4 , total integrated cost =  15.81964424770976
# RUN  4 , total integrated cost =  15.81964424770976
# Improved over  4  iterations in  0.41608720400108723  seconds by  98.84039697011825  percent.
# -------- 6
# interpolate adjoint :  True True True
# initial cost =  1422.3620749178365
# RUN  0 , total integrated cost =  1422.3620749178365
# Gradient descend method:  None
# RUN  1 , total integrated cost =  13.79909344736147
# RUN  2 , total integrated cost =  2.362412510402047
# RUN  3 , total integrated cost =  1.989731311763335
# RUN  4 , total integrated cost =  2.292144030649969
# RUN  4 , total integrated cost =  2.292144030649969
# Improved over  4  iterations in  0.5484672199963825  seconds by  99.83884946940937  percent.
# -------- 7
# interpolate adjoint :  True True True
# initial cost =  1403.4975414170744
# RUN  0 , total integrated cost =  1403.4975414170744
# Gradient descend method:  None
# RUN  1 , total integrated cost =  85.90866049595442
# RUN  2 , total integrated cost =  13.764232553726824
# RUN  3 , total integrated cost =  2.221202333791152
# RUN  4 , total integrated cost =  2.27508966724756
# RUN  4 , total integrated cost =  2.27508966724756
# Improved over  4  iterations in  0.47060216899990337  seconds by  99.83789856411501  percent.
# -------- 8
# interpolate adjoint :  True True True
# initial cost =  1329.3734088229542
# RUN  0 , total integrated cost =  1329.3734088229542
# Gradient descend method:  None
# RUN  1 , total integrated cost =  43.731990862506926
# RUN  2 , total integrated cost =  45.75653806004031
# RUN  3 , total integrated cost =  5.877960995187605
# RUN  4 , total integrated cost =  2.230418031379146
# RUN  4 , total integrated cost =  2.230418031379146
# Improved over  4  iterations in  0.4121457810033462  seconds by  99.83222035159001  percent.
# -------- 9
# interpolate adjoint :  True True True
# initial cost =  1301.4465783922053
# RUN  0 , total integrated cost =  1301.4465783922053
# Gradient descend method:  None
# RUN  1 , total integrated cost =  54.32863650583627
# RUN  2 , total integrated cost =  50.60403510725335
# RUN  3 , total integrated cost =  7.112714274273007
# RUN  4 , total integrated cost =  4.854535276827123
# RUN  4 , total integrated cost =  4.854535276827123
# Improved over  4  iterations in  0.4868782299963641  seconds by  99.62698927812893  percent.
# -------- 10
# interpolate adjoint :  True True True
# initial cost =  1411.5414457955494
# RUN  0 , total integrated cost =  1411.5414457955494
# Gradient descend method:  None
# RUN  1 , total integrated cost =  51.168300491711186
# RUN  2 , total integrated cost =  37.1139965310772
# RUN  3 , total integrated cost =  48.0368575526677
# RUN  4 , total integrated cost =  15.593379719647164
# RUN  4 , total integrated cost =  15.593379719647164
# Improved over  4  iterations in  0.44951589300035266  seconds by  98.89529423552571  percent.
# -------- 11
# interpolate adjoint :  True True True
# initial cost =  1407.0161378793453
# RUN  0 , total integrated cost =  1407.0161378793453
# Gradient descend method:  None
# RUN  1 , total integrated cost =  9.894060977255942
# RUN  2 , total integrated cost =  3.2913569660658055
# RUN  3 , total integrated cost =  2.6607249715749894
# RUN  4 , total integrated cost =  2.8123840242521707
# RUN  4 , total integrated cost =  2.8123840242521707
# Improved over  4  iterations in  0.7937417849971098  seconds by  99.80011714517426  percent.
# -------- 12
# interpolate adjoint :  True True True
# initial cost =  1395.2154619783782
# RUN  0 , total integrated cost =  1395.2154619783782
# Gradient descend method:  None
# RUN  1 , total integrated cost =  26.435426215564256
# RUN  2 , total integrated cost =  2.866615295658728
# RUN  3 , total integrated cost =  1.9981724268038166
# RUN  4 , total integrated cost =  2.8465565271683864
# RUN  4 , total integrated cost =  2.8465565271683864
# Improved over  4  iterations in  0.7773784490054823  seconds by  99.79597728058918  percent.
# -------- 13
# interpolate adjoint :  True True True
# initial cost =  1359.730846320921
# RUN  0 , total integrated cost =  1359.730846320921
# Gradient descend method:  None
# RUN  1 , total integrated cost =  67.42111785795296
# RUN  2 , total integrated cost =  30.405750890097345
# RUN  3 , total integrated cost =  29.584918419078427
# RUN  4 , total integrated cost =  30.193440192863136
# RUN  4 , total integrated cost =  30.193440192863136
# Improved over  4  iterations in  0.882055419999233  seconds by  97.779454641736  percent.
# -------- 14
# interpolate adjoint :  True True True
# initial cost =  1416.298275116999
# RUN  0 , total integrated cost =  1416.298275116999
# Gradient descend method:  None
# RUN  1 , total integrated cost =  86.30651814967756
# RUN  2 , total integrated cost =  70.80132891023688
# RUN  3 , total integrated cost =  9.159343596256559
# RUN  4 , total integrated cost =  6.892057233131616
# RUN  4 , total integrated cost =  6.892057233131616
# Improved over  4  iterations in  0.622303907002788  seconds by  99.51337529994787  percent.
# -------- 15
# interpolate adjoint :  True True True
# initial cost =  1405.3000138047794
# RUN  0 , total integrated cost =  1405.3000138047794
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22.307527234983766
# RUN  2 , total integrated cost =  4.211285596140106
# RUN  3 , total integrated cost =  2.196551590519263
# RUN  4 , total integrated cost =  2.014715731157571
# RUN  4 , total integrated cost =  2.014715731157571
# Improved over  4  iterations in  0.5196188420013641  seconds by  99.8566344758154  percent.
# -------- 16
# interpolate adjoint :  True True True
# initial cost =  1348.5003611603124
# RUN  0 , total integrated cost =  1348.5003611603124
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.017004875576042
# RUN  2 , total integrated cost =  216.3132128716381
# RUN  3 , total integrated cost =  124.1757323929491
# RUN  4 , total integrated cost =  63.478976334399164
# RUN  4 , total integrated cost =  63.478976334399164
# Improved over  4  iterations in  0.5883386049972614  seconds by  95.29262444692422  percent.
# -------- 17
# interpolate adjoint :  True True True
# initial cost =  1385.1504803606956
# RUN  0 , total integrated cost =  1385.1504803606956
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22.880273493725777
# RUN  2 , total integrated cost =  24.321610469890018
# RUN  3 , total integrated cost =  25.042449720425676
# RUN  4 , total integrated cost =  7.681334174591942
# RUN  4 , total integrated cost =  7.681334174591942
# Improved over  4  iterations in  0.409401949000312  seconds by  99.44545128608758  percent.
# -------- 18
# interpolate adjoint :  True True True
# initial cost =  1421.420352213678
# RUN  0 , total integrated cost =  1421.420352213678
# Gradient descend method:  None
# RUN  1 , total integrated cost =  17.72419972198531
# RUN  2 , total integrated cost =  3.314544627785959
# RUN  3 , total integrated cost =  2.40486797882906
# RUN  4 , total integrated cost =  2.7489400026655955
# RUN  4 , total integrated cost =  2.7489400026655955
# Improved over  4  iterations in  0.40589855100552086  seconds by  99.8066061177199  percent.
# -------- 19
# interpolate adjoint :  True True True
# initial cost =  1405.0075910587793
# RUN  0 , total integrated cost =  1405.0075910587793
# Gradient descend method:  None
# RUN  1 , total integrated cost =  113.31195831304663
# RUN  2 , total integrated cost =  81.36530630683951
# RUN  3 , total integrated cost =  6.29559893218563
# RUN  4 , total integrated cost =  4.580936867144345
# RUN  4 , total integrated cost =  4.580936867144345
# Improved over  4  iterations in  0.4287059690032038  seconds by  99.67395643295477  percent.
# -------- 20
# interpolate adjoint :  True True True
# initial cost =  1413.6472627060007
# RUN  0 , total integrated cost =  1413.6472627060007
# Gradient descend method:  None
# RUN  1 , total integrated cost =  8.812299374033955
# RUN  2 , total integrated cost =  2.327972347406841
# RUN  3 , total integrated cost =  2.3225786299145312
# RUN  4 , total integrated cost =  2.1036638743363847
# RUN  4 , total integrated cost =  2.1036638743363847
# Improved over  4  iterations in  0.4382751060038572  seconds by  99.85118891184287  percent.
# -------- 21
# interpolate adjoint :  True True True
# initial cost =  1331.9271114079918
# RUN  0 , total integrated cost =  1331.9271114079918
# Gradient descend method:  None
# RUN  1 , total integrated cost =  36.15932473680569
# RUN  2 , total integrated cost =  15.42757808931973
# RUN  3 , total integrated cost =  15.408229345359377
# RUN  4 , total integrated cost =  14.982429395752908
# RUN  4 , total integrated cost =  14.982429395752908
# Improved over  4  iterations in  0.40852528699906543  seconds by  98.87513143418825  percent.
# -------- 22
# interpolate adjoint :  True True True
# initial cost =  1364.1305312744498
# RUN  0 , total integrated cost =  1364.1305312744498
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.9834437687210125
# RUN  2 , total integrated cost =  6.852599054893742
# RUN  3 , total integrated cost =  5.890435738421939
# Control only changes marginally.
# RUN  3 , total integrated cost =  5.890435738421939
# Improved over  3  iterations in  0.4117139199952362  seconds by  99.5681911955362  percent.
# -------- 23
# interpolate adjoint :  True True True
# initial cost =  1383.7624839395214
# RUN  0 , total integrated cost =  1383.7624839395214
# Gradient descend method:  None
# RUN  1 , total integrated cost =  56.70568655982221
# RUN  2 , total integrated cost =  9.511442274342404
# RUN  3 , total integrated cost =  11.074615377932666
# RUN  4 , total integrated cost =  9.589791205430696
# RUN  4 , total integrated cost =  9.589791205430696
# Improved over  4  iterations in  0.4017947699976503  seconds by  99.30697707758857  percent.
# -------- 24
# interpolate adjoint :  True True True
# initial cost =  1370.0656044330028
# RUN  0 , total integrated cost =  1370.0656044330028
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14.662046361223746
# RUN  2 , total integrated cost =  7.013781091658217
# RUN  3 , total integrated cost =  5.197988484344771
# RUN  4 , total integrated cost =  4.609317641256408
# RUN  4 , total integrated cost =  4.609317641256408
# Improved over  4  iterations in  0.39127925699722255  seconds by  99.66356956730084  percent.
# -------- 25
# interpolate adjoint :  True True True
# initial cost =  1397.0623269373605
# RUN  0 , total integrated cost =  1397.0623269373605
# Gradient descend method:  None
# RUN  1 , total integrated cost =  25.144514379645628
# RUN  2 , total integrated cost =  1.9770109423746893
# RUN  3 , total integrated cost =  1.6433502022161082
# RUN  4 , total integrated cost =  2.1049210255553255
# RUN  4 , total integrated cost =  2.1049210255553255
# Improved over  4  iterations in  0.45484888899954967  seconds by  99.84933234652675  percent.
# -------- 26
# interpolate adjoint :  True True True
# initial cost =  1349.7620679348822
# RUN  0 , total integrated cost =  1349.7620679348822
# Gradient descend method:  None
# RUN  1 , total integrated cost =  44.692106998212196
# RUN  2 , total integrated cost =  44.16554210634245
# RUN  3 , total integrated cost =  6.242872734604154
# RUN  4 , total integrated cost =  2.7346981432265407
# RUN  4 , total integrated cost =  2.7346981432265407
# Improved over  4  iterations in  0.41726858200127026  seconds by  99.7973940586869  percent.
# -------- 27
# interpolate adjoint :  True True True
# initial cost =  1372.3923327565287
# RUN  0 , total integrated cost =  1372.3923327565287
# Gradient descend method:  None
# RUN  1 , total integrated cost =  102.33583181528249
# RUN  2 , total integrated cost =  30.09563862891066
# RUN  3 , total integrated cost =  3.6694748212391692
# RUN  4 , total integrated cost =  2.739444676211604
# RUN  4 , total integrated cost =  2.739444676211604
# Improved over  4  iterations in  0.46187900599761633  seconds by  99.80038910078218  percent.
# -------- 28
# interpolate adjoint :  True True True
# initial cost =  1417.4075549464985
# RUN  0 , total integrated cost =  1417.4075549464985
# Gradient descend method:  None
# RUN  1 , total integrated cost =  21.36220528113242
# RUN  2 , total integrated cost =  4.75216387567332
# RUN  3 , total integrated cost =  1.6635001144066468
# RUN  4 , total integrated cost =  2.023733106571396
# RUN  4 , total integrated cost =  2.023733106571396
# Improved over  4  iterations in  0.47549008899659384  seconds by  99.85722292085231  percent.
# -------- 29
# interpolate adjoint :  True True True
# initial cost =  1313.557412452344
# RUN  0 , total integrated cost =  1313.557412452344
# Gradient descend method:  None
# RUN  1 , total integrated cost =  68.18115287304626
# RUN  2 , total integrated cost =  35.86549282548184
# RUN  3 , total integrated cost =  4.327681762940124
# RUN  4 , total integrated cost =  3.482477960206782
# RUN  4 , total integrated cost =  3.482477960206782
# Improved over  4  iterations in  0.44940876699547516  seconds by  99.73488193761511  percent.
# cost =  13.310739587245404
# iteration =  5
# iteration =  6
# iteration =  7
# iteration =  8
# iteration =  9
# iteration =  10
# iteration =  11
# iteration =  12
# iteration =  13
# iteration =  14
# iteration =  15
# iteration =  16
# iteration =  17
# iteration =  18
# iteration =  19
# iteration =  20
# iteration =  21
# iteration =  22
# n max =  30
# -------- 0
# interpolate adjoint :  True True True
# initial cost =  1320.8671522600255
# RUN  0 , total integrated cost =  1320.8671522600255
# Gradient descend method:  None
# RUN  1 , total integrated cost =  8.581506273530884
# RUN  2 , total integrated cost =  2.0460423806067727
# RUN  3 , total integrated cost =  1.610564711845981
# RUN  4 , total integrated cost =  1.4559345350645554
# RUN  5 , total integrated cost =  1.3624832437602572
# RUN  6 , total integrated cost =  1.196131689133522
# RUN  7 , total integrated cost =  1.2146728315643756
# RUN  8 , total integrated cost =  1.0548072731440297
# RUN  9 , total integrated cost =  1.1697091561947237
# RUN  10 , total integrated cost =  1.1497448181964178
# RUN  11 , total integrated cost =  1.134299699036702
# RUN  12 , total integrated cost =  1.1153738520736236
# RUN  13 , total integrated cost =  1.139857516561057
# RUN  14 , total integrated cost =  1.1263302153063424
# RUN  15 , total integrated cost =  1.150972420794889
# RUN  16 , total integrated cost =  1.1169184955296898
# RUN  17 , total integrated cost =  1.023420434518826
# RUN  18 , total integrated cost =  0.9912827361700602
# RUN  19 , total integrated cost =  1.0029885494826216
# RUN  20 , total integrated cost =  0.997603573562696
# RUN  22 , total integrated cost =  0.945599304294843
# Improved over  22  iterations in  4.124911881001026  seconds by  99.92841071846803  percent.
# -------- 1
# interpolate adjoint :  True True True
# initial cost =  1339.0436847740716
# RUN  0 , total integrated cost =  1339.0436847740716
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.404096442118253
# RUN  2 , total integrated cost =  2.6627601480408565
# RUN  3 , total integrated cost =  2.230177185730531
# RUN  4 , total integrated cost =  1.6261722537160594
# RUN  5 , total integrated cost =  1.6822177503300964
# RUN  6 , total integrated cost =  1.8234971082147151
# RUN  7 , total integrated cost =  1.5615152489270028
# RUN  8 , total integrated cost =  1.3280653068479507
# RUN  9 , total integrated cost =  1.347193849099843
# RUN  10 , total integrated cost =  1.0633903790128176
# RUN  11 , total integrated cost =  0.9641037167091915
# RUN  12 , total integrated cost =  1.0230307377132104
# RUN  13 , total integrated cost =  1.0604684792331942
# RUN  14 , total integrated cost =  0.9676462433941087
# RUN  15 , total integrated cost =  0.9919796411259872
# RUN  16 , total integrated cost =  1.1071083328660525
# RUN  17 , total integrated cost =  1.1078628786839007
# RUN  18 , total integrated cost =  1.0537430452078433
# RUN  19 , total integrated cost =  1.0872784773438886
# RUN  20 , total integrated cost =  1.0313153615545325
# RUN  22 , total integrated cost =  0.9462518885054099
# Improved over  22  iterations in  4.253768166003283  seconds by  99.92933375518177  percent.
# -------- 2
# interpolate adjoint :  True True True
# initial cost =  1437.7073083596877
# RUN  0 , total integrated cost =  1437.7073083596877
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.7500043997854746
# RUN  2 , total integrated cost =  2.355212679914672
# RUN  3 , total integrated cost =  2.119956185300077
# RUN  4 , total integrated cost =  1.4373890937585214
# RUN  5 , total integrated cost =  1.2249195298143196
# RUN  6 , total integrated cost =  1.1956781487226826
# RUN  7 , total integrated cost =  1.2901648713099354
# RUN  8 , total integrated cost =  1.3440322739697657
# RUN  9 , total integrated cost =  1.2710163560061387
# RUN  10 , total integrated cost =  1.2950955301516975
# RUN  11 , total integrated cost =  1.176931359378978
# RUN  12 , total integrated cost =  1.1640146277946217
# RUN  13 , total integrated cost =  1.1767731549523073
# RUN  14 , total integrated cost =  1.1411381304521409
# RUN  15 , total integrated cost =  1.1265820769006512
# RUN  16 , total integrated cost =  1.1597013194851191
# RUN  17 , total integrated cost =  1.08135451142264
# RUN  18 , total integrated cost =  1.1114409779960894
# RUN  19 , total integrated cost =  1.075574585493261
# RUN  20 , total integrated cost =  1.039469767023486
# RUN  22 , total integrated cost =  1.0409226747606086
# Improved over  22  iterations in  4.471122282004217  seconds by  99.92759842919988  percent.
# -------- 3
# interpolate adjoint :  True True True
# initial cost =  1392.2488930588697
# RUN  0 , total integrated cost =  1392.2488930588697
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.5555290239146404
# RUN  2 , total integrated cost =  1.5527835445872866
# RUN  3 , total integrated cost =  1.3397777709714414
# RUN  4 , total integrated cost =  1.4257367536660526
# RUN  5 , total integrated cost =  1.4659604118607235
# RUN  6 , total integrated cost =  1.5589503811933285
# RUN  7 , total integrated cost =  1.472613565310951
# RUN  8 , total integrated cost =  1.4710986850662313
# RUN  9 , total integrated cost =  1.4918225080975334
# RUN  10 , total integrated cost =  1.4926211244868426
# RUN  11 , total integrated cost =  1.4192835500405585
# RUN  12 , total integrated cost =  1.3843802193627701
# RUN  13 , total integrated cost =  1.3812094528246464
# RUN  14 , total integrated cost =  1.4314512481421733
# RUN  15 , total integrated cost =  1.2084060951078888
# RUN  16 , total integrated cost =  1.5292520686807958
# RUN  17 , total integrated cost =  1.3965148270237695
# RUN  18 , total integrated cost =  1.3709898288287108
# RUN  19 , total integrated cost =  1.634275798877705
# RUN  20 , total integrated cost =  1.9277107010785524
# RUN  22 , total integrated cost =  1.5742921668527832
# Improved over  22  iterations in  4.675148349000665  seconds by  99.88692451653569  percent.
# -------- 4
# interpolate adjoint :  True True True
# initial cost =  1407.3299743975522
# RUN  0 , total integrated cost =  1407.3299743975522
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.1728736942112485
# RUN  2 , total integrated cost =  5.288428788731303
# RUN  3 , total integrated cost =  8.193129021969586
# RUN  4 , total integrated cost =  4.878084225150394
# RUN  5 , total integrated cost =  1.763472887540643
# RUN  6 , total integrated cost =  1.8453683903489235
# RUN  7 , total integrated cost =  1.665292578854811
# RUN  8 , total integrated cost =  1.5333186395190546
# RUN  9 , total integrated cost =  1.4753379402202111
# RUN  10 , total integrated cost =  1.437503377630065
# RUN  11 , total integrated cost =  1.6841613927957604
# RUN  12 , total integrated cost =  1.601958530426292
# RUN  13 , total integrated cost =  1.502997462231357
# RUN  14 , total integrated cost =  1.494792155558371
# RUN  15 , total integrated cost =  1.4084219100883857
# RUN  16 , total integrated cost =  1.396056678499833
# RUN  17 , total integrated cost =  1.3433964237044447
# RUN  18 , total integrated cost =  1.231698535691972
# RUN  19 , total integrated cost =  3.3929930444790717
# RUN  20 , total integrated cost =  3.0151734204204264
# RUN  22 , total integrated cost =  2.7749281203989367
# Improved over  22  iterations in  4.619115452005644  seconds by  99.8028232062927  percent.
# -------- 5
# interpolate adjoint :  True True True
# initial cost =  1386.1181437188052
# RUN  0 , total integrated cost =  1386.1181437188052
# Gradient descend method:  None
# RUN  1 , total integrated cost =  9.083167234442781
# RUN  2 , total integrated cost =  6.712280563066185
# RUN  3 , total integrated cost =  1.6866084301814195
# RUN  4 , total integrated cost =  1.366112763529828
# RUN  5 , total integrated cost =  1.3124546093960214
# RUN  6 , total integrated cost =  1.3555033918409658
# RUN  7 , total integrated cost =  1.3590247025831013
# RUN  8 , total integrated cost =  1.3790460144834702
# RUN  9 , total integrated cost =  1.337869216369579
# RUN  10 , total integrated cost =  1.3300374588588735
# RUN  11 , total integrated cost =  1.358833889505963
# RUN  12 , total integrated cost =  1.384904624502363
# RUN  13 , total integrated cost =  1.347989765832328
# RUN  14 , total integrated cost =  1.310187413060651
# RUN  15 , total integrated cost =  1.360261905562102
# RUN  16 , total integrated cost =  1.315430026228825
# RUN  17 , total integrated cost =  1.2923701703397792
# Control only changes marginally.
# RUN  17 , total integrated cost =  1.2923701703397792
# Improved over  17  iterations in  6.383261401002528  seconds by  99.9067633465303  percent.
# -------- 6
# interpolate adjoint :  True True True
# initial cost =  1398.2046700431808
# RUN  0 , total integrated cost =  1398.2046700431808
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.8096253080001814
# RUN  2 , total integrated cost =  2.088941289431969
# RUN  3 , total integrated cost =  2.2688549125348247
# RUN  4 , total integrated cost =  1.7899852410624675
# RUN  5 , total integrated cost =  1.6987775438569668
# RUN  6 , total integrated cost =  2.330622649616455
# RUN  7 , total integrated cost =  2.269403115663717
# RUN  8 , total integrated cost =  1.9336358014356498
# RUN  9 , total integrated cost =  1.7460864000765985
# RUN  10 , total integrated cost =  1.7520406858774027
# RUN  11 , total integrated cost =  1.7171130647792718
# RUN  12 , total integrated cost =  1.6876073658659891
# RUN  13 , total integrated cost =  1.5306343719342914
# RUN  14 , total integrated cost =  1.8900611367929168
# RUN  15 , total integrated cost =  1.9369830250467217
# RUN  16 , total integrated cost =  2.0588709440050783
# RUN  17 , total integrated cost =  1.945499032819828
# RUN  18 , total integrated cost =  1.6896251413667998
# RUN  19 , total integrated cost =  1.7938995128924051
# RUN  20 , total integrated cost =  1.5796823968077918
# RUN  22 , total integrated cost =  1.646310640250024
# Improved over  22  iterations in  9.166985718999058  seconds by  99.88225538967774  percent.
# -------- 7
# interpolate adjoint :  True True True
# initial cost =  1375.8614569055844
# RUN  0 , total integrated cost =  1375.8614569055844
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.2519306162654322
# RUN  2 , total integrated cost =  4.806348486508702
# RUN  3 , total integrated cost =  3.131334595056284
# RUN  4 , total integrated cost =  1.3275631656686673
# RUN  5 , total integrated cost =  1.3864167489291996
# RUN  6 , total integrated cost =  1.3152849118426908
# RUN  7 , total integrated cost =  1.2070413012752323
# RUN  8 , total integrated cost =  1.3095510233611567
# RUN  9 , total integrated cost =  1.2339435235559513
# RUN  10 , total integrated cost =  1.2155236564768541
# RUN  11 , total integrated cost =  1.2436774633403327
# RUN  12 , total integrated cost =  1.324108091285142
# RUN  13 , total integrated cost =  1.3132511374543558
# RUN  14 , total integrated cost =  1.3274910582271395
# RUN  15 , total integrated cost =  1.1872300142624757
# RUN  16 , total integrated cost =  1.267946949304088
# RUN  17 , total integrated cost =  1.4242567210988846
# RUN  18 , total integrated cost =  1.2831911717748419
# RUN  19 , total integrated cost =  1.257414338508967
# RUN  20 , total integrated cost =  1.352678553692252
# RUN  22 , total integrated cost =  1.154230161351586
# Improved over  22  iterations in  7.267950606998056  seconds by  99.91610854744434  percent.
# -------- 8
# interpolate adjoint :  True True True
# initial cost =  1356.6807724451733
# RUN  0 , total integrated cost =  1356.6807724451733
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.6316707838059816
# RUN  2 , total integrated cost =  2.1231847528006718
# RUN  3 , total integrated cost =  2.126280291828701
# RUN  4 , total integrated cost =  2.0764497290766286
# RUN  5 , total integrated cost =  1.9233549875687743
# RUN  6 , total integrated cost =  2.023688166119256
# RUN  7 , total integrated cost =  2.166963119303964
# RUN  8 , total integrated cost =  2.0082747351025647
# RUN  9 , total integrated cost =  2.103302124855297
# RUN  10 , total integrated cost =  2.031959163150021
# RUN  11 , total integrated cost =  1.8391199268628924
# RUN  12 , total integrated cost =  1.9033057797928508
# RUN  13 , total integrated cost =  1.7879792770794807
# RUN  14 , total integrated cost =  1.81409191738354
# RUN  15 , total integrated cost =  1.677935339866478
# RUN  16 , total integrated cost =  1.5338008701931736
# RUN  17 , total integrated cost =  1.4031177069581124
# RUN  18 , total integrated cost =  1.2063223632240676
# RUN  19 , total integrated cost =  1.2937772736905688
# RUN  20 , total integrated cost =  1.3198452209676597
# RUN  22 , total integrated cost =  1.2348284415230575
# Improved over  22  iterations in  4.55927507999877  seconds by  99.90898165090837  percent.
# -------- 9
# interpolate adjoint :  True True True
# initial cost =  1378.9356125953304
# RUN  0 , total integrated cost =  1378.9356125953304
# ...
# RUN  8 , total integrated cost =  1.7321529621181795
# RUN  9 , total integrated cost =  1.64979828004756
# RUN  10 , total integrated cost =  1.7422153638122155
# RUN  11 , total integrated cost =  1.532067453452112
# Control only changes marginally.
# RUN  11 , total integrated cost =  1.532067453452112
# Improved over  11  iterations in  2.272676908003632  seconds by  99.66714799219936  percent.
# -------- 17
# interpolate adjoint :  True True True
# initial cost =  366.81911125430736
# RUN  0 , total integrated cost =  366.81911125430736
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.401967902866349
# RUN  2 , total integrated cost =  1.3112564271557736
# RUN  3 , total integrated cost =  1.399071786783769
# RUN  4 , total integrated cost =  1.3666240734896657
# RUN  5 , total integrated cost =  1.2454335183038672
# RUN  6 , total integrated cost =  1.3685822861371912
# RUN  7 , total integrated cost =  1.2407798561781367
# RUN  8 , total integrated cost =  1.644869760707296
# RUN  9 , total integrated cost =  1.3913793746916405
# RUN  10 , total integrated cost =  1.666061278093711
# RUN  11 , total integrated cost =  1.6307976616260613
# RUN  12 , total integrated cost =  1.4356868881122704
# RUN  13 , total integrated cost =  1.3230980118940385
# RUN  14 , total integrated cost =  1.5186490901635772
# RUN  15 , total integrated cost =  1.246740481322132
# RUN  16 , total integrated cost =  1.3525415028946313
# RUN  17 , total integrated cost =  1.6412935663582582
# RUN  18 , total integrated cost =  1.33672518827386
# RUN  19 , total integrated cost =  1.7004941703752015
# RUN  20 , total integrated cost =  1.5790672292120953
# RUN  29 , total integrated cost =  1.6234212765727078
# Improved over  29  iterations in  5.531297155001084  seconds by  99.55743274361537  percent.
# -------- 18
# interpolate adjoint :  True True True
# initial cost =  1.2596426751542815
# RUN  0 , total integrated cost =  1.2596426751542815
# Gradient descend method:  None
# RUN  1 , total integrated cost =  0.6087063273029021
# RUN  2 , total integrated cost =  1.0922546502060737
# RUN  3 , total integrated cost =  1.2894003201642592
# RUN  4 , total integrated cost =  2.2055854526199465
# RUN  5 , total integrated cost =  1.9709147150738604
# RUN  6 , total integrated cost =  1.8835198858922235
# Control only changes marginally.
# RUN  6 , total integrated cost =  1.8835198858922235
# Improved over  6  iterations in  1.4433463960012887  seconds by  -49.528110077846435  percent.
# -------- 19
# interpolate adjoint :  True True True
# initial cost =  342.57327806714346
# RUN  0 , total integrated cost =  342.57327806714346
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.667266957687013
# RUN  2 , total integrated cost =  1.3823650942414487
# RUN  3 , total integrated cost =  1.2769290515847462
# RUN  4 , total integrated cost =  2.588200746754832
# RUN  5 , total integrated cost =  1.6672642935239679
# RUN  6 , total integrated cost =  2.0612546980084385
# RUN  7 , total integrated cost =  2.0850494220545253
# RUN  8 , total integrated cost =  2.091290345967533
# RUN  9 , total integrated cost =  1.8884819629953062
# RUN  10 , total integrated cost =  1.812381956965031
# RUN  11 , total integrated cost =  1.8728436401425332
# RUN  12 , total integrated cost =  1.7697655574126108
# RUN  13 , total integrated cost =  2.2711263519737726
# RUN  14 , total integrated cost =  1.7092074288286188
# RUN  15 , total integrated cost =  1.500674354099802
# RUN  16 , total integrated cost =  1.613099514547228
# RUN  17 , total integrated cost =  1.6516598977513235
# RUN  18 , total integrated cost =  1.5209386352756855
# RUN  19 , total integrated cost =  1.689585571980611
# RUN  20 , total integrated cost =  1.710568218448219
# RUN  29 , total integrated cost =  3.8790520739178236
# Improved over  29  iterations in  5.962735924986191  seconds by  98.8676723135546  percent.
# -------- 20
# interpolate adjoint :  True True True
# initial cost =  0.6836065279905016
# RUN  0 , total integrated cost =  0.6836065279905016
# Gradient descend method:  None
# RUN  1 , total integrated cost =  0.515406479741448
# RUN  2 , total integrated cost =  0.33657440355280765
# Control only changes marginally.
# RUN  2 , total integrated cost =  0.33657440355280765
# Improved over  2  iterations in  0.7459511229972122  seconds by  50.7648932870512  percent.
# -------- 21
# interpolate adjoint :  True True True
# initial cost =  426.744813829802
# RUN  0 , total integrated cost =  426.744813829802
# Gradient descend method:  None
# RUN  1 , total integrated cost =  0.8240046994223988
# RUN  2 , total integrated cost =  1.026387757246931
# RUN  3 , total integrated cost =  1.1301449237409615
# RUN  4 , total integrated cost =  1.6907365586939451
# RUN  5 , total integrated cost =  1.2964634317158064
# RUN  6 , total integrated cost =  1.1877154049260419
# RUN  7 , total integrated cost =  1.2345279893606342
# RUN  8 , total integrated cost =  1.0573061621049769
# RUN  9 , total integrated cost =  1.2251651986792318
# RUN  10 , total integrated cost =  1.2801507014616353
# RUN  11 , total integrated cost =  2.0450583626499856
# RUN  12 , total integrated cost =  1.1304509311630189
# RUN  13 , total integrated cost =  1.5108218218916893
# RUN  14 , total integrated cost =  2.6221499991067034
# RUN  15 , total integrated cost =  2.0832469040448336
# RUN  16 , total integrated cost =  2.4255596557640753
# RUN  17 , total integrated cost =  1.7620357333541115
# Control only changes marginally.
# RUN  17 , total integrated cost =  1.7620357333541115
# Improved over  17  iterations in  3.2264290460007032  seconds by  99.58709850096577  percent.
# -------- 22
# interpolate adjoint :  True True True
# initial cost =  270.3552766714658
# RUN  0 , total integrated cost =  270.3552766714658
# Gradient descend method:  None
# RUN  1 , total integrated cost =  9.20035423947776
# RUN  2 , total integrated cost =  6.806938933504267
# RUN  3 , total integrated cost =  3.4896042224736705
# RUN  4 , total integrated cost =  2.9633846797616865
# RUN  5 , total integrated cost =  2.8830182488708602
# RUN  6 , total integrated cost =  2.7350129768282416
# RUN  7 , total integrated cost =  2.588247846933786
# RUN  8 , total integrated cost =  2.3223777671280863
# RUN  9 , total integrated cost =  1.8961231850844764
# RUN  10 , total integrated cost =  1.6945276973730952
# RUN  11 , total integrated cost =  1.8756003722989418
# RUN  12 , total integrated cost =  1.6787735126734602
# RUN  13 , total integrated cost =  1.8216928910679435
# RUN  14 , total integrated cost =  1.8439145741448018
# RUN  15 , total integrated cost =  1.5776879734722764
# RUN  16 , total integrated cost =  1.8878395546858662
# RUN  17 , total integrated cost =  1.629188997516585
# RUN  18 , total integrated cost =  1.6659265282163755
# RUN  19 , total integrated cost =  2.0170684224468545
# RUN  20 , total integrated cost =  1.7128268520701755
# RUN  29 , total integrated cost =  1.5791429679330062
# Improved over  29  iterations in  5.313103369990131  seconds by  99.41590081489255  percent.
# -------- 23
# interpolate adjoint :  True True True
# initial cost =  1.1572486886546058
# RUN  0 , total integrated cost =  1.1572486886546058
# Gradient descend method:  None
# RUN  1 , total integrated cost =  0.5456349290850094
# RUN  2 , total integrated cost =  1.1212373391625634
# RUN  3 , total integrated cost =  0.6648235529933204
# RUN  4 , total integrated cost =  0.7433424380946582
# RUN  5 , total integrated cost =  1.038378013791239
# RUN  6 , total integrated cost =  1.1132984844572615
# RUN  7 , total integrated cost =  2.8010064583799275
# RUN  8 , total integrated cost =  2.269257975080916
# RUN  9 , total integrated cost =  1.368477474869743
# RUN  10 , total integrated cost =  1.7273901984275248
# RUN  11 , total integrated cost =  1.7308030705509956
# RUN  12 , total integrated cost =  1.6701050295390811
# RUN  13 , total integrated cost =  1.7327065866822364
# RUN  14 , total integrated cost =  1.8678894249283844
# RUN  15 , total integrated cost =  1.7459404279745154
# RUN  16 , total integrated cost =  1.6069777545622679
# RUN  17 , total integrated cost =  1.612871390973316
# RUN  18 , total integrated cost =  1.792958866744709
# RUN  19 , total integrated cost =  1.9404999456729302
# RUN  20 , total integrated cost =  1.4781231731479079
# RUN  29 , total integrated cost =  2.059361653975573
# Improved over  29  iterations in  5.147918012997252  seconds by  -77.95325016697538  percent.
# -------- 24
# interpolate adjoint :  True True True
# initial cost =  418.34331276123214
# RUN  0 , total integrated cost =  418.34331276123214
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.429981323650783
# RUN  2 , total integrated cost =  3.3578678544044367
# RUN  3 , total integrated cost =  1.8307528384382803
# RUN  4 , total integrated cost =  1.8122836364875026
# RUN  5 , total integrated cost =  1.4285795192658672
# RUN  6 , total integrated cost =  1.4445417223261712
# RUN  7 , total integrated cost =  1.2873279484483393
# RUN  8 , total integrated cost =  1.2720739754134351
# RUN  9 , total integrated cost =  1.3166934444009457
# RUN  10 , total integrated cost =  1.3642497131018274
# RUN  11 , total integrated cost =  1.5781233492744424
# RUN  12 , total integrated cost =  1.2532338912061713
# RUN  13 , total integrated cost =  1.6173590167088592
# RUN  14 , total integrated cost =  1.4655058599386308
# RUN  15 , total integrated cost =  1.720432745702102
# RUN  16 , total integrated cost =  1.5768529744839512
# RUN  17 , total integrated cost =  1.9648401288674926
# RUN  18 , total integrated cost =  1.4992651092186136
# RUN  19 , total integrated cost =  1.6958925947958687
# RUN  20 , total integrated cost =  1.9419678584053182
# Control only changes marginally.
# RUN  21 , total integrated cost =  1.305104353226932
# Improved over  21  iterations in  4.1965989300078945  seconds by  99.68803030587182  percent.
# -------- 25
# interpolate adjoint :  True True True
# initial cost =  435.26447313796325
# RUN  0 , total integrated cost =  435.26447313796325
# Gradient descend method:  None
# RUN  1 , total integrated cost =  0.9820532500094151
# RUN  2 , total integrated cost =  1.2810544986513206
# RUN  3 , total integrated cost =  2.0595838920785097
# RUN  4 , total integrated cost =  1.640739836199688
# RUN  5 , total integrated cost =  1.5551129277390041
# RUN  6 , total integrated cost =  1.301572929305623
# Control only changes marginally.
# RUN  6 , total integrated cost =  1.301572929305623
# Improved over  6  iterations in  1.3359293739922578  seconds by  99.70096963808643  percent.
# -------- 26
# interpolate adjoint :  True True True
# initial cost =  0.6689286379052461
# RUN  0 , total integrated cost =  0.6689286379052461
# Gradient descend method:  None
# RUN  1 , total integrated cost =  0.46532538105185706
# RUN  2 , total integrated cost =  1.9962960037918833
# RUN  3 , total integrated cost =  1.7799069538908454
# RUN  4 , total integrated cost =  1.3515443829978555
# RUN  5 , total integrated cost =  1.4631078511467315
# RUN  6 , total integrated cost =  1.2512316975171307
# RUN  7 , total integrated cost =  1.411948280464102
# RUN  8 , total integrated cost =  1.359068103440067
# RUN  9 , total integrated cost =  1.4339802217106512
# RUN  10 , total integrated cost =  1.125750606981586
# RUN  11 , total integrated cost =  1.4171977433267489
# RUN  12 , total integrated cost =  1.2340506110858898
# RUN  13 , total integrated cost =  1.566640404131383
# RUN  14 , total integrated cost =  1.1638173575822388
# RUN  15 , total integrated cost =  1.3169717328573194
# RUN  16 , total integrated cost =  1.2421271482381449
# RUN  17 , total integrated cost =  1.2119043300497523
# RUN  18 , total integrated cost =  1.0830961440579199
# RUN  19 , total integrated cost =  1.6262525021454386
# RUN  20 , total integrated cost =  2.024697332734323
# Control only changes marginally.
# RUN  23 , total integrated cost =  1.8308488356868375
# Improved over  23  iterations in  5.353564449003898  seconds by  -173.6986775480492  percent.
# -------- 27
# interpolate adjoint :  True True True
# initial cost =  1.1097341913927796
# RUN  0 , total integrated cost =  1.1097341913927796
# Gradient descend method:  None
# RUN  1 , total integrated cost =  0.4908898950195835
# RUN  2 , total integrated cost =  0.4843600834107807
# RUN  3 , total integrated cost =  0.5233404433102669
# RUN  4 , total integrated cost =  0.9660365891885068
# RUN  5 , total integrated cost =  0.9962434182254839
# RUN  6 , total integrated cost =  1.4768427164710074
# RUN  7 , total integrated cost =  1.6136543177444937
# RUN  8 , total integrated cost =  1.5884449933891864
# RUN  9 , total integrated cost =  1.595762787640597
# RUN  10 , total integrated cost =  1.551458449774005
# RUN  11 , total integrated cost =  1.4624326547177204
# RUN  12 , total integrated cost =  1.529306781813981
# RUN  13 , total integrated cost =  1.4522576366497468
# RUN  14 , total integrated cost =  1.3640064487854042
# RUN  15 , total integrated cost =  1.3809080389417805
# RUN  16 , total integrated cost =  1.3585536639046634
# RUN  17 , total integrated cost =  1.4184296636116942
# RUN  18 , total integrated cost =  1.5587059918545725
# RUN  19 , total integrated cost =  1.558330404504272
# RUN  20 , total integrated cost =  1.3239149116845663
# RUN  29 , total integrated cost =  1.557971439362189
# Improved over  29  iterations in  5.669568614001037  seconds by  -40.39140646886318  percent.
# -------- 28
# interpolate adjoint :  True True True
# initial cost =  416.5451701211996
# RUN  0 , total integrated cost =  416.5451701211996
# Gradient descend method:  None
# RUN  1 , total integrated cost =  0.8391873053475201
# RUN  2 , total integrated cost =  1.0061777021444822
# RUN  3 , total integrated cost =  0.8441502051440115
# RUN  4 , total integrated cost =  3.4195503392278943
# RUN  5 , total integrated cost =  2.433463728609536
# RUN  6 , total integrated cost =  1.8733214378362755
# RUN  7 , total integrated cost =  1.3479635659135736
# RUN  8 , total integrated cost =  1.3053535907295473
# RUN  9 , total integrated cost =  1.1976921601318826
# RUN  10 , total integrated cost =  1.399147319277374
# RUN  11 , total integrated cost =  1.4137254432903923
# RUN  12 , total integrated cost =  1.8365200186123078
# RUN  13 , total integrated cost =  1.3767823243465278
# RUN  14 , total integrated cost =  1.4088645782999654
# RUN  15 , total integrated cost =  1.393536887809149
# RUN  16 , total integrated cost =  1.198967063262983
# RUN  17 , total integrated cost =  1.0499050170342257
# RUN  18 , total integrated cost =  1.0408211606004243
# RUN  19 , total integrated cost =  1.176393633653222
# RUN  20 , total integrated cost =  1.0257136253277073
# Control only changes marginally.
# RUN  25 , total integrated cost =  1.0666935004746694
# Improved over  25  iterations in  5.040551427999162  seconds by  99.74391888875718  percent.
# -------- 29
# interpolate adjoint :  True True True
# initial cost =  463.52530250145
# RUN  0 , total integrated cost =  463.52530250145
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.364258396295897
# RUN  2 , total integrated cost =  3.7862291607697576
# RUN  3 , total integrated cost =  2.2889417919988952
# RUN  4 , total integrated cost =  2.3464268691580665
# RUN  5 , total integrated cost =  1.8087195320252873
# RUN  6 , total integrated cost =  1.5738110443065918
# RUN  7 , total integrated cost =  1.390692793436548
# RUN  8 , total integrated cost =  1.5037163526844082
# RUN  9 , total integrated cost =  1.2427065421183028
# RUN  10 , total integrated cost =  1.3840791790278755
# RUN  11 , total integrated cost =  1.0918474743185524
# RUN  12 , total integrated cost =  1.0522985124418796
# RUN  13 , total integrated cost =  1.1259515457932205
# RUN  14 , total integrated cost =  1.0708031295304117
# RUN  15 , total integrated cost =  0.976540197559916
# RUN  16 , total integrated cost =  0.9671207135588852
# RUN  17 , total integrated cost =  0.9939669383785966
# RUN  18 , total integrated cost =  1.3323189800447528
# RUN  19 , total integrated cost =  0.9987368771518157
# RUN  20 , total integrated cost =  0.9202911183338702
# RUN  29 , total integrated cost =  1.5328044096373699
# Improved over  29  iterations in  5.030988938000519  seconds by  99.66931591406866  percent.
# cost =  201.71123794669265

# %%
#len(sigma_array), 4, N_max, max_it

##### METHOD 2
method_ind = 1
step_method_ind = 0

for d in dict_list:
    print("Point = ", d['point'])
    aln.params.ext_exc_current = d['point'][0] * 5.
    aln.params.ext_inh_current = d['point'][1] * 5.
    
    max_it = d['cost'].shape[3]
    
    for s_ind in range(len(d['sigma'])):
        
        print("sigma = ", d['sigma'][s_ind])
        
        s = d['sigma'][s_ind]
        aln.params.sigma_ou = s
        c_p = d['cost_params'][s_ind]
        cost.setParams(c_p[0], c_p[1], c_p[2])
        
        target_ = d['target'][s_ind].copy()
        target_[0,0,:int(trans_time * dur / aln.params.dt)] = -1000
        target_[0,1,:int(trans_time * dur / aln.params.dt)] = -1000
                
        for n_ind in range(len(d['N_array'])):
            
            n_ = d['N_array'][n_ind]
            
            print("n = ", n_)
            aln.params.duration = dur
            control_init = aln.getZeroControl()
        
            for i_it in range(1, d['cost'].shape[4], 1):
                
                if d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it] > 0.:
                    continue
                
                print("iteration = ", i_it)

                if i_it <= init_it:
                    c_vars = d['init']
                else:
                    c_vars = [0,1]
                    
                aln.params.duration = dur
                setinit(d['init_vars'], aln)
                
                bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                    control_init, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_ = i_it,
                    tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                    t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                    control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                    noise_real=n_, init_params = d['init_vars'], method='M2')
            
                aln.params.duration = dur
                setinit(d['init_vars'], aln)

                cost_final = 0.
                cs = cost.numba_cost_sparsity_int(1, 6, T, d['cost_params'][s_ind][2], dt, control_init)

                for j in range(noise_realizations_final):
                    state_ = fo.updateState(aln, control_init)
                    cost_final += cost.numba_cost_precision_int(1, T, dt, d['cost_params'][s_ind][0],
                                                                   state_, target_, list(prec_vars) )

                d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it] = (
                                cost_final / noise_realizations_final + cs )
                print('cost = ', d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it])
                
                file=open(dict_file, "wb")
                pickle.dump(dict_list, file)
                file.close()
# Out:
# Point =  [0.4   0.322]
# sigma =  0.01
# set cost params:  0.00829916864127671 0.0 1.0
# n =  1
# iteration =  5
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1377.216681037566
# Gradient descend method:  None
# RUN  1 , total integrated cost =  427.68930387400445
# RUN  2 , total integrated cost =  3.7614080987982836
# RUN  3 , total integrated cost =  2.6009633502340153
# RUN  4 , total integrated cost =  3.20432255910222
# RUN  5 , total integrated cost =  2.398911759818412
# RUN  5 , total integrated cost mean =  2.398911759818412
# Improved over  5  iterations in  0.9135115319804754  seconds by  99.82581450015468  percent.
# cost =  1385.5922500832728
# iteration =  6
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1369.6182213906866
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.241644830069581
# RUN  2 , total integrated cost =  3.0188902572195566
# RUN  3 , total integrated cost =  3.3500762717699106
# RUN  4 , total integrated cost =  1.880414845153231
# RUN  5 , total integrated cost =  1.5977369744713958
# RUN  6 , total integrated cost =  1.4275405170126694
# RUN  6 , total integrated cost mean =  1.4275405170126694
# Improved over  6  iterations in  2.3986470520030707  seconds by  99.89577091668924  percent.

# %%
#len(sigma_array), 4, N_max, max_it

##### METHOD 3
method_ind = 2
step_method_ind = 0

for d in dict_list:
    print("Point = ", d['point'])
    aln.params.ext_exc_current = d['point'][0] * 5.
    aln.params.ext_inh_current = d['point'][1] * 5.
    
    max_it = d['cost'].shape[3]
    
    for s_ind in range(len(d['sigma'])):
        
        print("sigma = ", d['sigma'][s_ind])
        
        s = d['sigma'][s_ind]
        aln.params.sigma_ou = s
        c_p = d['cost_params'][s_ind]
        cost.setParams(c_p[0], c_p[1], c_p[2])
        
        target_ = d['target'][s_ind].copy()
        target_[0,0,:int(trans_time * dur / aln.params.dt)] = -1000
        target_[0,1,:int(trans_time * dur / aln.params.dt)] = -1000
                
        for n_ind in range(len(d['N_array'])):
            
            n_ = d['N_array'][n_ind]
            
            print("n = ", n_)
            aln.params.duration = dur
            control_init = aln.getZeroControl()
        
            for i_it in range(1, d['cost'].shape[4], 1):
                
                if d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it] > 0.:
                    continue
                
                print("iteration = ", i_it)

                if i_it <= init_it:
                    c_vars = d['init']
                else:
                    c_vars = [0,1]
                    
                aln.params.duration = dur
                setinit(d['init_vars'], aln)

                bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                    control_init, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_ = i_it,
                    tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                    t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                    control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                    noise_real=n_, init_params = d['init_vars'], method='M3')
            
                aln.params.duration = dur
                setinit(d['init_vars'], aln)

                cost_final = 0.
                cs = cost.numba_cost_sparsity_int(1, 6, T, d['cost_params'][s_ind][2], dt, control_init)

                for j in range(noise_realizations_final):
                    state_ = fo.updateState(aln, control_init)
                    cost_final += cost.numba_cost_precision_int(1, T, dt, d['cost_params'][s_ind][0],
                                                                   state_, target_, list(prec_vars) )

                d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it] = (
                                cost_final / noise_realizations_final + cs )
                print('cost = ', d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it])
                
                file=open(dict_file, "wb")
                pickle.dump(dict_list, file)
                file.close()
# Out:
# Point =  [0.4   0.322]
# sigma =  0.01
# set cost params:  0.00829916864127671 0.0 1.0
# n =  1
# iteration =  1
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1372.1940012128796
# Gradient descend method:  None
# RUN  1 , total integrated cost =  39.50508239459211
# RUN  1 , total integrated cost mean =  39.50508239459211
# Improved over  1  iterations in  15.449098230004893  seconds by  97.12102790424142  percent.
# cost =  151.29191762265515
# iteration =  2
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  93.96729964178978
# Gradient descend method:  None
# RUN  1 , total integrated cost =  18.4260953790973
# RUN  1 , total integrated cost mean =  18.4260953790973
# Improved over  1  iterations in  0.16240363799443003  seconds by  80.39094935223325  percent.
# cost =  17.91942183195109
# iteration =  3
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  17.418849343323917
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.8609010088866684
# RUN  1 , total integrated cost mean =  3.8609010088866684
# Improved over  1  iterations in  0.17763271900184918  seconds by  77.83492507002808  percent.
# cost =  3.4785832448799656
# iteration =  4
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.086205036996666
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.9118477701182837
# RUN  1 , total integrated cost mean =  1.9118477701182837
# Improved over  1  iterations in  0.13809067700640298  seconds by  38.05182263655449  percent.
# cost =  2.119842725717519
# iteration =  5
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.0409949518191155
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.7512403865828174
# RUN  1 , total integrated cost mean =  1.7512403865828174
# Improved over  1  iterations in  0.13165594800375402  seconds by  14.19673110793552  percent.
# cost =  1.8980078222021612
# iteration =  6
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1.9574966439908132
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.8421454813359417
# RUN  1 , total integrated cost mean =  1.8421454813359417
# Improved over  1  iterations in  0.24839033601165283  seconds by  5.892789804211432  percent.
# cost =  1.885963931630451
# iteration =  7
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1.9941812408334911
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.7007002153717488
# RUN  1 , total integrated cost mean =  1.7007002153717488
# Improved over  1  iterations in  0.24781065399292856  seconds by  14.716868229042134  percent.
# cost =  1.8691784190335348
# iteration =  8
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1.8018577710488501
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.702390348718004
# RUN  1 , total integrated cost mean =  1.702390348718004
# Improved over  1  iterations in  0.2060738720028894  seconds by  5.520270463575301  percent.
# cost =  1.7968840561192836
# iteration =  9
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.019387145269486
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.7338094156731167
# RUN  1 , total integrated cost mean =  1.7338094156731167
# Improved over  1  iterations in  0.2542604879999999  seconds by  14.141801895953876  percent.
# cost =  1.8089597089049603
# iteration =  10
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.206175637450172
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.739823040824103
# RUN  1 , total integrated cost mean =  1.739823040824103
# Improved over  1  iterations in  0.3685840649995953  seconds by  21.138507229871536  percent.
# cost =  1.9600188722229468
# iteration =  11
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1.5756169997398237
# Gradient descend method:  None
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  1 , total integrated cost =  1.8648101817224085
# Control only changes marginally.
# RUN  1 , total integrated cost mean =  1.8648101817224085
# Improved over  1  iterations in  1.1932098990073428  seconds by  -18.354281657937065  percent.
# cost =  1.9603764380507336
# iteration =  12
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1.7804179561407514
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.6290168244817826
# RUN  1 , total integrated cost mean =  1.6290168244817826
# Improved over  1  iterations in  0.2702593800058821  seconds by  8.503684830675766  percent.
# cost =  1.833652389428906
# iteration =  13
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.045796203687527
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.7612635280599431
# RUN  1 , total integrated cost mean =  1.7612635280599431
# Improved over  1  iterations in  0.2258867630007444  seconds by  13.908163242981715  percent.
# cost =  1.8475026211711396
# iteration =  14
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1.7623204031025992
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.5634010720880822
# RUN  1 , total integrated cost mean =  1.5634010720880822
# Improved over  1  iterations in  0.2704106749879429  seconds by  11.287353347570374  percent.
# cost =  2.084411700433657
# iteration =  15
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1.8428334517022207
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.594780405925481
# RUN  1 , total integrated cost mean =  1.594780405925481
# Improved over  1  iterations in  0.38256032900244463  seconds by  13.46041583668962  percent.
# cost =  1.7507196196517543
# iteration =  16
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1.6381985124794511
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.541027661677267
# RUN  1 , total integrated cost mean =  1.541027661677267
# Improved over  1  iterations in  0.27398204400378745  seconds by  5.931567515289345  percent.
# cost =  1.7484361450060402
# iteration =  17
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1.7589658574995732
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.6067257671103725
# RUN  1 , total integrated cost mean =  1.6067257671103725
# Improved over  1  iterations in  0.24171518899674993  seconds by  8.655090702307035  percent.
# cost =  1.7468127399828453
# iteration =  18
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1.7446919521579705
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.6483387994188954
# RUN  1 , total integrated cost mean =  1.6483387994188954
# Improved over  1  iterations in  0.20819118000508752  seconds by  5.522645566164158  percent.
# cost =  1.7118553388844802
# iteration =  19
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1.613834012758811
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.6534032861963464
# RUN  1 , total integrated cost mean =  1.6534032861963464
# Improved over  1  iterations in  0.40513083898986224  seconds by  -2.4518800028196637  percent.
# cost =  1.7290652857635367
# iteration =  20
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1.5011373046308782
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.5563583985558844
# RUN  1 , total integrated cost mean =  1.5563583985558844
# Improved over  1  iterations in  0.5157139410002856  seconds by  -3.6786171228077507  percent.
# cost =  1.731875628527172
# iteration =  21
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1.9308247898628412
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.6462610902758825
# RUN  1 , total integrated cost mean =  1.6462610902758825
# Improved over  1  iterations in  0.49895762201049365  seconds by  14.737934849447072  percent.
# cost =  1.8590872341364284
# iteration =  22
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1.76404561012378
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.5910606515430217
# RUN  1 , total integrated cost mean =  1.5910606515430217
# Improved over  1  iterations in  0.3936085860041203  seconds by  9.806149999070627  percent.
# cost =  1.700226506901645
# iteration =  23
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1.5630568944868983
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.6924636158172877
# RUN  1 , total integrated cost mean =  1.6924636158172877
# Improved over  1  iterations in  0.4336411219992442  seconds by  -8.279079397993968  percent.
# cost =  1.8596462564343972
# iteration =  24
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1.8489513470439716
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.5821320112607125
# RUN  1 , total integrated cost mean =  1.5821320112607125
# Improved over  1  iterations in  0.4170010029920377  seconds by  14.43084677213595  percent.
# cost =  1.7561110111097926
# iteration =  25
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1.7179869245135588
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.5270994024828735
# RUN  1 , total integrated cost mean =  1.5270994024828735
# Improved over  1  iterations in  0.43356362599297427  seconds by  11.111116115434612  percent.
# cost =  1.748445987408076
# iteration =  26
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1.6149716934372427
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.5502288848420624
# RUN  1 , total integrated cost mean =  1.5502288848420624
# Improved over  1  iterations in  0.5415582739951788  seconds by  4.008912902825202  percent.
# cost =  1.6909713397788209
# iteration =  27
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1.6248123072779332
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.5232203166022702
# RUN  1 , total integrated cost mean =  1.5232203166022702
# Improved over  1  iterations in  0.30103035100910347  seconds by  6.252536998926445  percent.
# cost =  1.7857626551368786
# iteration =  28
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1.5174217634282494
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.5887001577403992
# RUN  1 , total integrated cost mean =  1.5887001577403992
# Improved over  1  iterations in  0.6461425019952003  seconds by  -4.697335706528506  percent.
# cost =  1.9101468986574444
# iteration =  29
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1.717145289199551
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.7045524548577982
# RUN  1 , total integrated cost mean =  1.7045524548577982
# Improved over  1  iterations in  0.28502173798915464  seconds by  0.7333586983558575  percent.
# cost =  1.76623028673638
# n =  2
# iteration =  1
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1391.6258397084703
# Gradient descend method:  None
# RUN  1 , total integrated cost =  184.38041865128537
# RUN  1 , total integrated cost mean =  184.38041865128537
# Improved over  1  iterations in  0.37749434099532664  seconds by  86.75071895115781  percent.
# cost =  143.3439486574297
# iteration =  2
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  235.7315381638884
# Gradient descend method:  None
# RUN  1 , total integrated cost =  87.99539107673237
# RUN  1 , total integrated cost mean =  87.99539107673237
# Improved over  1  iterations in  0.47366680500272196  seconds by  62.67135413355041  percent.
# cost =  88.47471662414766
# iteration =  3
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  86.84932186763771
# Gradient descend method:  None
# RUN  1 , total integrated cost =  43.68466214889503
# RUN  1 , total integrated cost mean =  43.68466214889503
# Improved over  1  iterations in  0.39454338401264977  seconds by  49.70062953920075  percent.
# cost =  47.24537258073494
# iteration =  4
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  43.96098393257297
# Gradient descend method:  None
# RUN  1 , total integrated cost =  13.839543565350994
# RUN  1 , total integrated cost mean =  13.839543565350994
# Improved over  1  iterations in  0.3062004800012801  seconds by  68.51857641180648  percent.
# cost =  14.795521255016045
# iteration =  5
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  14.601512806581827
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14.274983594305644
# RUN  1 , total integrated cost mean =  14.274983594305644
# Improved over  1  iterations in  0.3084085910086287  seconds by  2.2362697386327994  percent.
# cost =  14.014664685039385
# iteration =  6
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  14.394925121355573
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12.65366176195256
# RUN  1 , total integrated cost mean =  12.65366176195256
# Improved over  1  iterations in  0.4994576000026427  seconds by  12.096369690869494  percent.
# cost =  12.760072838540765
# iteration =  7
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12.526277142500268
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12.582507111537284
# RUN  1 , total integrated cost mean =  12.582507111537284
# Improved over  1  iterations in  0.8333214890008094  seconds by  -0.4488960957620378  percent.
# cost =  12.685816023081504
# iteration =  8
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12.770280515571006
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12.465623972974605
# RUN  1 , total integrated cost mean =  12.465623972974605
# Improved over  1  iterations in  0.8447045259963488  seconds by  2.3856683666809744  percent.
# cost =  12.63982954988016
# iteration =  9
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12.44055245236369
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12.363490356428882
# RUN  1 , total integrated cost mean =  12.363490356428882
# Improved over  1  iterations in  1.3677934970037313  seconds by  0.6194427155054996  percent.
# cost =  12.562742425889445
# iteration =  10
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12.663733603629913
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12.45592433490383
# RUN  1 , total integrated cost mean =  12.45592433490383
# Improved over  1  iterations in  0.5889445790089667  seconds by  1.6409794712241563  percent.
# cost =  12.581863971061066
# iteration =  11
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12.541769969488922
# Gradient descend method:  None
# step size too small or too large
# RUN  1 , total integrated cost =  12.43924789894686
# RUN  1 , total integrated cost mean =  12.43924789894686
# Improved over  1  iterations in  1.2229651430097874  seconds by  0.8174449921460365  percent.
# cost =  12.5814966034639
# iteration =  12
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12.884242552670525
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12.445932494022319
# RUN  1 , total integrated cost mean =  12.445932494022319
# Improved over  1  iterations in  0.5142423510114895  seconds by  3.401907848726097  percent.
# cost =  12.619219715873346
# iteration =  13
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12.63403927862798
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12.405840108885034
# RUN  1 , total integrated cost mean =  12.405840108885034
# Improved over  1  iterations in  0.8422042460006196  seconds by  1.806224950788092  percent.
# cost =  12.5084227631784
# iteration =  14
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12.481551062592887
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12.40710299904498
# RUN  1 , total integrated cost mean =  12.40710299904498
# Improved over  1  iterations in  0.5631225589895621  seconds by  0.5964648397828256  percent.
# cost =  12.499571519649846
# iteration =  15
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12.463408744248767
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12.335833249497362
# RUN  1 , total integrated cost mean =  12.335833249497362
# Improved over  1  iterations in  0.9455729680048535  seconds by  1.023600343768507  percent.
# cost =  12.469044038358673
# iteration =  16
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12.354287222302183
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12.369009743389809
# RUN  1 , total integrated cost mean =  12.369009743389809
# Improved over  1  iterations in  0.7793353980086977  seconds by  -0.11916932820736292  percent.
# cost =  12.461774328002077
# iteration =  17
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12.39134485785045
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12.375937154503845
# RUN  1 , total integrated cost mean =  12.375937154503845
# Improved over  1  iterations in  0.43415497000387404  seconds by  0.12434246260883697  percent.
# cost =  12.430970300852405
# iteration =  18
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12.311754572513266
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12.297606873549114
# RUN  1 , total integrated cost mean =  12.297606873549114
# Improved over  1  iterations in  0.6341531639918685  seconds by  0.114912126300311  percent.
# cost =  12.426157443477315
# iteration =  19
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12.404075075826878
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12.477862455276414
# RUN  1 , total integrated cost mean =  12.477862455276414
# Improved over  1  iterations in  0.5217847660096595  seconds by  -0.5948640184654721  percent.
# cost =  12.452771416700484
# iteration =  20
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12.394606051648577
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12.286834482605133
# RUN  1 , total integrated cost mean =  12.286834482605133
# Improved over  1  iterations in  0.45764803599740844  seconds by  0.8695037873277869  percent.
# cost =  12.44589885613734
# iteration =  21
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12.376168272800355
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12.324634710038307
# RUN  1 , total integrated cost mean =  12.324634710038307
# Improved over  1  iterations in  0.6189602759986883  seconds by  0.41639352040247957  percent.
# cost =  12.500226883626375
# iteration =  22
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12.406857902294279
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12.3877791443777
# RUN  1 , total integrated cost mean =  12.3877791443777
# Improved over  1  iterations in  0.5346342529956019  seconds by  0.15377590415580755  percent.
# cost =  12.492009879649608
# iteration =  23
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12.42235639254302
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12.566492489727592
# RUN  1 , total integrated cost mean =  12.566492489727592
# Improved over  1  iterations in  0.4850714380008867  seconds by  -1.160295942492013  percent.
# cost =  12.479259190704859
# iteration =  24
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12.70483728471317
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12.39637800185255
# RUN  1 , total integrated cost mean =  12.39637800185255
# Improved over  1  iterations in  0.6375173260021256  seconds by  2.427888495917742  percent.
# cost =  12.40450545595826
# iteration =  25
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12.494736900496413
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12.369802719683214
# RUN  1 , total integrated cost mean =  12.369802719683214
# Improved over  1  iterations in  0.4417263250070391  seconds by  0.9998944500242715  percent.
# cost =  12.371168755343083
# iteration =  26
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12.444027020434463
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12.182669495261116
# RUN  1 , total integrated cost mean =  12.182669495261116
# Improved over  1  iterations in  0.4625416250055423  seconds by  2.100264847899865  percent.
# cost =  12.352175504431155
# iteration =  27
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12.24599412762451
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12.170801084349197
# RUN  1 , total integrated cost mean =  12.170801084349197
# Improved over  1  iterations in  1.0130578980024438  seconds by  0.6140215526127974  percent.
# cost =  12.337864988974939
# iteration =  28
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12.35308827990906
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12.235981114823037
# RUN  1 , total integrated cost mean =  12.235981114823037
# Improved over  1  iterations in  0.5024753009929555  seconds by  0.9479990949023289  percent.
# cost =  12.331947588027427
# iteration =  29
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12.388663488634101
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12.167242728077778
# RUN  1 , total integrated cost mean =  12.167242728077778
# Improved over  1  iterations in  0.45771393399627414  seconds by  1.7872852931994316  percent.
# cost =  12.274682178087376
# n =  10
# iteration =  1
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1405.9893355790487
# Gradient descend method:  None
# RUN  1 , total integrated cost =  325.1909041075249
# RUN  1 , total integrated cost mean =  325.1909041075249
# Improved over  1  iterations in  1.6647838979988592  seconds by  76.87102626752166  percent.
# cost =  322.79113491418065
# iteration =  2
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  300.3738985185925
# Gradient descend method:  None
# step size too small or too large
# RUN  1 , total integrated cost =  96.7118969719756
# RUN  1 , total integrated cost mean =  96.7118969719756
# Improved over  1  iterations in  1.9665155770053389  seconds by  67.80282925748645  percent.
# cost =  86.62314903747549
# iteration =  3
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  81.51453303955512
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.789069900216857
# RUN  1 , total integrated cost mean =  4.789069900216857
# Improved over  1  iterations in  1.4580104490014492  seconds by  94.12488826024072  percent.
# cost =  80.80030493225628
# iteration =  4
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5.411785597037985
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.418615614275216
# RUN  1 , total integrated cost mean =  4.418615614275216
# Improved over  1  iterations in  3.620672838995233  seconds by  18.35198318474326  percent.
# cost =  267.5033455693806
# iteration =  5
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  129.0597515505139
# Gradient descend method:  None
# RUN  1 , total integrated cost =  20.11056881755163
# RUN  1 , total integrated cost mean =  20.11056881755163
# Improved over  1  iterations in  1.740503274006187  seconds by  84.4176293724846  percent.
# cost =  20.25346541641987
# iteration =  6
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  20.239246687979342
# Gradient descend method:  None
# step size too small or too large
# RUN  1 , total integrated cost =  16.326718035669227
# RUN  1 , total integrated cost mean =  16.326718035669227
# Improved over  1  iterations in  2.9228904579940718  seconds by  19.33139465429747  percent.
# cost =  16.504862954565937
# iteration =  7
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  16.511527838316663
# Gradient descend method:  None
# RUN  1 , total integrated cost =  16.162442362560665
# RUN  1 , total integrated cost mean =  16.162442362560665
# Improved over  1  iterations in  2.302081330999499  seconds by  2.114192454958115  percent.
# cost =  16.239213179284583
# iteration =  8
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  16.252679749562567
# Gradient descend method:  None
# RUN  1 , total integrated cost =  16.16776015834668
# RUN  1 , total integrated cost mean =  16.16776015834668
# Improved over  1  iterations in  2.405828090995783  seconds by  0.5224959362050612  percent.
# cost =  16.19507358442976
# iteration =  9
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  16.187227457209858
# Gradient descend method:  None
# RUN  1 , total integrated cost =  16.105584351263627
# RUN  1 , total integrated cost mean =  16.105584351263627
# Improved over  1  iterations in  2.326917844999116  seconds by  0.5043674474955679  percent.
# cost =  16.157043197772193
# iteration =  10
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  16.19251218718595
# Gradient descend method:  None
# step size too small or too large
# RUN  1 , total integrated cost =  16.05843906817685
# RUN  1 , total integrated cost mean =  16.05843906817685
# Improved over  1  iterations in  2.853307447003317  seconds by  0.8279945536505551  percent.
# cost =  16.057203663032986
# iteration =  11
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  16.08818814508992
# Gradient descend method:  None
# RUN  1 , total integrated cost =  16.001216978093904
# RUN  1 , total integrated cost mean =  16.001216978093904
# Improved over  1  iterations in  3.213887613004772  seconds by  0.5405901908386141  percent.
# cost =  16.03376619829276
# iteration =  12
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  16.084918171219016
# Gradient descend method:  None
# RUN  1 , total integrated cost =  15.97454626701506
# RUN  1 , total integrated cost mean =  15.97454626701506
# Improved over  1  iterations in  3.4136293829942588  seconds by  0.686182565736928  percent.
# cost =  16.003533204143057
# iteration =  13
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  16.063783817863722
# Gradient descend method:  None
# RUN  1 , total integrated cost =  15.998509519331105
# RUN  1 , total integrated cost mean =  15.998509519331105
# Improved over  1  iterations in  2.5954873230075464  seconds by  0.40634447819218167  percent.
# cost =  16.013368835013576
# iteration =  14
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  15.97470518727108
# Gradient descend method:  None
# RUN  1 , total integrated cost =  15.950615434881456
# RUN  1 , total integrated cost mean =  15.950615434881456
# Improved over  1  iterations in  2.713488829002017  seconds by  0.1507993550254696  percent.
# cost =  15.97149807122356
# iteration =  15
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  15.945989094149983
# Gradient descend method:  None
# RUN  1 , total integrated cost =  15.911827900769461
# RUN  1 , total integrated cost mean =  15.911827900769461
# Improved over  1  iterations in  3.0765001749969088  seconds by  0.21423063303770107  percent.
# cost =  15.936618501138518
# iteration =  16
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  15.957271813417208
# Gradient descend method:  None
# RUN  1 , total integrated cost =  15.887662748966804
# RUN  1 , total integrated cost mean =  15.887662748966804
# Improved over  1  iterations in  2.663515770997037  seconds by  0.43622158765181496  percent.
# cost =  15.919444647037928
# iteration =  17
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  15.876139546173505
# Gradient descend method:  None
# RUN  1 , total integrated cost =  15.838209094433637
# RUN  1 , total integrated cost mean =  15.838209094433637
# Improved over  1  iterations in  2.5176041460072156  seconds by  0.23891482957523635  percent.
# cost =  15.852428609386406
# iteration =  18
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  15.903128537956695
# Gradient descend method:  None
# RUN  1 , total integrated cost =  15.822169731203157
# RUN  1 , total integrated cost mean =  15.822169731203157
# Improved over  1  iterations in  2.290329818002647  seconds by  0.5090747179733199  percent.
# cost =  15.817129235309237
# iteration =  19
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  15.841236921012745
# Gradient descend method:  None
# RUN  1 , total integrated cost =  15.756429187158156
# RUN  1 , total integrated cost mean =  15.756429187158156
# Improved over  1  iterations in  2.1997327610006323  seconds by  0.5353605547183946  percent.
# cost =  15.798804690749789
# iteration =  20
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  15.725655250703301
# Gradient descend method:  None
# step size too small or too large
# RUN  1 , total integrated cost =  15.736166515443552
# RUN  1 , total integrated cost mean =  15.736166515443552
# Improved over  1  iterations in  3.1936778809904354  seconds by  -0.06684150563316393  percent.
# cost =  15.755255130961887
# iteration =  21
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  15.727730326424872
# Gradient descend method:  None
# step size too small or too large
# RUN  1 , total integrated cost =  15.71588352895742
# RUN  1 , total integrated cost mean =  15.71588352895742
# Improved over  1  iterations in  2.9222235820052447  seconds by  0.07532426625822097  percent.
# cost =  15.752770142097306
# iteration =  22
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  15.711395434932754
# Gradient descend method:  None
# step size too small or too large
# RUN  1 , total integrated cost =  15.753573584517875
# RUN  1 , total integrated cost mean =  15.753573584517875
# Improved over  1  iterations in  3.347474174006493  seconds by  -0.2684557826820395  percent.
# cost =  15.726027878581062
# iteration =  23
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  15.68708247750657
# Gradient descend method:  None
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  1 , total integrated cost =  15.625592884234583
# RUN  1 , total integrated cost mean =  15.625592884234583
# Improved over  1  iterations in  3.46322515400243  seconds by  0.39197596723390404  percent.
# cost =  15.676898250299546
# iteration =  24
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  15.657025214594384
# Gradient descend method:  None
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  1 , total integrated cost =  15.661337941345646
# RUN  1 , total integrated cost mean =  15.661337941345646
# Improved over  1  iterations in  3.106701188997249  seconds by  -0.02754499460881732  percent.
# cost =  15.669569028679073
# iteration =  25
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  15.606742222247174
# Gradient descend method:  None
# step size too small or too large
# RUN  1 , total integrated cost =  15.594776016623076
# RUN  1 , total integrated cost mean =  15.594776016623076
# Improved over  1  iterations in  2.6412335819914006  seconds by  0.0766733085848017  percent.
# cost =  15.61346208056932
# iteration =  26
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  15.623200935537692
# Gradient descend method:  None
# RUN  1 , total integrated cost =  15.533597819321617
# RUN  1 , total integrated cost mean =  15.533597819321617
# Improved over  1  iterations in  2.4548740180034656  seconds by  0.5735259796362016  percent.
# cost =  15.510296423219895
# iteration =  27
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  15.528823874491977
# Gradient descend method:  None
# RUN  1 , total integrated cost =  15.477726645276581
# RUN  1 , total integrated cost mean =  15.477726645276581
# Improved over  1  iterations in  2.3415200199960964  seconds by  0.32904764474358217  percent.
# cost =  15.459813849322858
# iteration =  28
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  15.501018159605351
# Gradient descend method:  None
# RUN  1 , total integrated cost =  15.337245047565451
# RUN  1 , total integrated cost mean =  15.337245047565451
# Improved over  1  iterations in  2.4472625579946907  seconds by  1.0565313217081496  percent.
# cost =  15.398048053986548
# iteration =  29
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  15.370026665956294
# Gradient descend method:  None
# RUN  1 , total integrated cost =  15.304570428094667
# RUN  1 , total integrated cost mean =  15.304570428094667
# Improved over  1  iterations in  2.6337263460009126  seconds by  0.42586938386131123  percent.
# cost =  15.362324902296217
# n =  30
# iteration =  1
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1371.429396530469
# Gradient descend method:  None
# RUN  1 , total integrated cost =  221.1645692604543
# RUN  1 , total integrated cost mean =  221.1645692604543
# Improved over  1  iterations in  4.380317638002452  seconds by  83.8734265270986  percent.
# cost =  198.9249275673846
# iteration =  2
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  216.48817605613746
# Gradient descend method:  None
# step size too small or too large
# RUN  1 , total integrated cost =  80.57783140482196
# RUN  1 , total integrated cost mean =  80.57783140482196
# Improved over  1  iterations in  5.337215669002035  seconds by  62.779569363674  percent.
# cost =  80.1377729932175
# iteration =  3
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  80.26382711497182
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.441856926634982
# RUN  1 , total integrated cost mean =  11.441856926634982
# Improved over  1  iterations in  4.458464505994925  seconds by  85.74469055625096  percent.
# cost =  11.760099251400852
# iteration =  4
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11.718758563606665
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.149206578258494
# RUN  1 , total integrated cost mean =  6.149206578258494
# Improved over  1  iterations in  4.10983965700143  seconds by  47.52680887756115  percent.
# cost =  6.109449188456982
# iteration =  5
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5.893774774000493
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.7292964367256918
# RUN  1 , total integrated cost mean =  3.7292964367256918
# Improved over  1  iterations in  3.7156457730015973  seconds by  36.724822720119434  percent.
# cost =  3.7203144814001243
# iteration =  6
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.7150978523323603
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.611565642413948
# RUN  1 , total integrated cost mean =  3.611565642413948
# Improved over  1  iterations in  6.622359362008865  seconds by  2.786796311526871  percent.
# cost =  3.6586128832475815
# iteration =  7
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.6293993410304792
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.6047557827061545
# RUN  1 , total integrated cost mean =  3.6047557827061545
# Improved over  1  iterations in  6.60143550200155  seconds by  0.6789982586299743  percent.
# cost =  3.603061371930166
# iteration =  8
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.5662359379361996
# Gradient descend method:  None
# step size too small or too large
# step size too small or too large
# RUN  1 , total integrated cost =  3.4891056716952944
# RUN  1 , total integrated cost mean =  3.4891056716952944
# Improved over  1  iterations in  7.725369687992497  seconds by  2.1627920189021665  percent.
# cost =  3.484452375953432
# iteration =  9
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.4918638232160544
# Gradient descend method:  None
# step size too small or too large
# RUN  1 , total integrated cost =  3.3264037676214135
# RUN  1 , total integrated cost mean =  3.3264037676214135
# Improved over  1  iterations in  7.9697906599903945  seconds by  4.738445253636783  percent.
# cost =  3.3563274628261306
# iteration =  10
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.3611655995039302
# Gradient descend method:  None
# step size too small or too large
# RUN  1 , total integrated cost =  3.2776017656086607
# RUN  1 , total integrated cost mean =  3.2776017656086607
# Improved over  1  iterations in  7.06666002899874  seconds by  2.486156406801342  percent.
# cost =  3.3236550832955705
# iteration =  11
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.3224894658476436
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.258866860250018
# RUN  1 , total integrated cost mean =  3.258866860250018
# Improved over  1  iterations in  6.981476736997138  seconds by  1.9149076694331626  percent.
# cost =  3.2655153036553184
# iteration =  12
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.259372685684056
# Gradient descend method:  None
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  1 , total integrated cost =  3.210068856285713
# RUN  1 , total integrated cost mean =  3.210068856285713
# Improved over  1  iterations in  8.885244577992125  seconds by  1.5126784861055285  percent.
# cost =  3.2243589609043393
# iteration =  13
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.228206019701909
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.1861375545965798
# RUN  1 , total integrated cost mean =  3.1861375545965798
# Improved over  1  iterations in  6.85358499600261  seconds by  1.303153046880638  percent.
# cost =  3.2097121457889823
# iteration =  14
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.206730140013447
# Gradient descend method:  None
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  1 , total integrated cost =  3.107916012326944
# RUN  1 , total integrated cost mean =  3.107916012326944
# Improved over  1  iterations in  8.443414307999774  seconds by  3.0814606584291084  percent.
# cost =  3.119785731003628
# iteration =  15
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.0772801290212057
# Gradient descend method:  None
# step size too small or too large
# step size too small or too large
# RUN  1 , total integrated cost =  3.0353962262261214
# RUN  1 , total integrated cost mean =  3.0353962262261214
# Improved over  1  iterations in  7.415330068994081  seconds by  1.361068899775674  percent.
# cost =  3.0559829717696974
# iteration =  16
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.013468280354879
# Gradient descend method:  None
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  1 , total integrated cost =  2.9362893493073945
# RUN  1 , total integrated cost mean =  2.9362893493073945
# Improved over  1  iterations in  8.555447024991736  seconds by  2.5611330157553738  percent.
# cost =  2.961742971129662
# iteration =  17
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.9758490426579747
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.890703841422252
# RUN  1 , total integrated cost mean =  2.890703841422252
# Improved over  1  iterations in  7.895603552999091  seconds by  2.861207003957176  percent.
# cost =  2.92639933426829
# iteration =  18
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.9341242565879666
# Gradient descend method:  None
# step size too small or too large
# RUN  1 , total integrated cost =  2.881220579888985
# RUN  1 , total integrated cost mean =  2.881220579888985
# Improved over  1  iterations in  7.416683610994369  seconds by  1.8030482717354914  percent.
# cost =  2.879500877390219
# iteration =  19
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.892706625991473
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.807782035046394
# RUN  1 , total integrated cost mean =  2.807782035046394
# Improved over  1  iterations in  7.453204886012827  seconds by  2.935817624297499  percent.
# cost =  2.8034053006776465
# iteration =  20
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.783516325728513
# Gradient descend method:  None
# step size too small or too large
# RUN  1 , total integrated cost =  2.7309294070432184
# RUN  1 , total integrated cost mean =  2.7309294070432184
# Improved over  1  iterations in  7.255807530993479  seconds by  1.88922616329657  percent.
# cost =  2.741302544985564
# iteration =  21
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.7731864773219175
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.67985740007511
# RUN  1 , total integrated cost mean =  2.67985740007511
# Improved over  1  iterations in  6.840226428990718  seconds by  3.365409358873549  percent.
# cost =  2.70614908957144
# iteration =  22
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.7214852080885135
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.4627834241681414
# RUN  1 , total integrated cost mean =  2.4627834241681414
# Improved over  1  iterations in  7.448315350993653  seconds by  9.505904465381093  percent.
# cost =  2.511450388945417
# iteration =  23
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.491491291152393
# Gradient descend method:  None
# step size too small or too large
# step size too small or too large
# RUN  1 , total integrated cost =  2.4793366045649865
# RUN  1 , total integrated cost mean =  2.4793366045649865
# Improved over  1  iterations in  8.000352393995854  seconds by  0.48784784560835703  percent.
# cost =  2.4965018522081137
# iteration =  24
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.4602710600889424
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.420364168205773
# RUN  1 , total integrated cost mean =  2.420364168205773
# Improved over  1  iterations in  7.393861810996896  seconds by  1.6220526482040043  percent.
# cost =  2.473684384864811
# iteration =  25
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.4812016355246347
# Gradient descend method:  None
# step size too small or too large
# RUN  1 , total integrated cost =  2.4581199857483838
# RUN  1 , total integrated cost mean =  2.4581199857483838
# Improved over  1  iterations in  7.2479411069944035  seconds by  0.9302609447688184  percent.
# cost =  2.4557263473516757
# iteration =  26
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.5082684446155072
# Gradient descend method:  None
# step size too small or too large
# RUN  1 , total integrated cost =  2.4213578682901327
# RUN  1 , total integrated cost mean =  2.4213578682901327
# Improved over  1  iterations in  7.569813360998523  seconds by  3.464963110784467  percent.
# cost =  2.4191821461728487
# iteration =  27
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.4312053223397996
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.2952169939250044
# RUN  1 , total integrated cost mean =  2.2952169939250044
# Improved over  1  iterations in  6.678672835987527  seconds by  5.593453056606492  percent.
# cost =  2.3082193000525435
# iteration =  28
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.288862982327623
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.252194869240183
# RUN  1 , total integrated cost mean =  2.252194869240183
# Improved over  1  iterations in  6.662470441995538  seconds by  1.6020230730522371  percent.
# cost =  2.2808241762132995
# iteration =  29
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.2570239500155513
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.198665373718306
# RUN  1 , total integrated cost mean =  2.198665373718306
# Improved over  1  iterations in  6.78959106100956  seconds by  2.585642757439203  percent.
# cost =  2.2196857943460215
# sigma =  0.02
# set cost params:  0.004152796306112395 0.0 1.0
# n =  1
# iteration =  1
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  0.8033566243926941
# Gradient descend method:  None
# step size too small or too large
# RUN  1 , total integrated cost =  0.5181416703235586
# RUN  1 , total integrated cost mean =  0.5181416703235586
# Improved over  1  iterations in  0.7715861420001602  seconds by  35.50290685469193  percent.
# cost =  643.6385159251598
# iteration =  2
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  666.6405487565719
# Gradient descend method:  None
# RUN  1 , total integrated cost =  229.07571208642293
# RUN  1 , total integrated cost mean =  229.07571208642293
# Improved over  1  iterations in  0.1333453530096449  seconds by  65.6372969640538  percent.
# cost =  167.28162770717196
# iteration =  3
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  194.79067254356056
# Gradient descend method:  None
# RUN  1 , total integrated cost =  103.2976842859286
# RUN  1 , total integrated cost mean =  103.2976842859286
# Improved over  1  iterations in  0.13275460999284405  seconds by  46.969902132850635  percent.
# cost =  93.21607084332076
# iteration =  4
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  120.36478907443201
# Gradient descend method:  None
# RUN  1 , total integrated cost =  35.096651860092805
# RUN  1 , total integrated cost mean =  35.096651860092805
# Improved over  1  iterations in  0.21331944399571512  seconds by  70.84142951607758  percent.
# cost =  34.892414163186515
# iteration =  5
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  32.047265402660614
# Gradient descend method:  None
# RUN  1 , total integrated cost =  16.261689200235946
# RUN  1 , total integrated cost mean =  16.261689200235946
# Improved over  1  iterations in  0.10992424399591982  seconds by  49.25717063245628  percent.
# cost =  16.280909963652608
# iteration =  6
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  16.319205225963273
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.689313224013908
# RUN  1 , total integrated cost mean =  11.689313224013908
# Improved over  1  iterations in  0.18463892799627502  seconds by  28.370817927967295  percent.
# cost =  12.55626396878171
# iteration =  7
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  13.743929868583866
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.37742708897308
# RUN  1 , total integrated cost mean =  11.37742708897308
# Improved over  1  iterations in  0.2094726570066996  seconds by  17.21853066945708  percent.
# cost =  11.331223612211474
# iteration =  8
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11.249959222771476
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.07670985561096
# RUN  1 , total integrated cost mean =  11.07670985561096
# Improved over  1  iterations in  0.20023033100005705  seconds by  1.5399999567094795  percent.
# cost =  11.317646008539619
# iteration =  9
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11.133639756244278
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.015410330984846
# RUN  1 , total integrated cost mean =  11.015410330984846
# Improved over  1  iterations in  0.23426989899598993  seconds by  1.061911718430835  percent.
# cost =  11.358373656705801
# iteration =  10
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11.211908766531504
# Gradient descend method:  None
# RUN  1 , total integrated cost =  10.518378641876847
# RUN  1 , total integrated cost mean =  10.518378641876847
# Improved over  1  iterations in  0.24169789599545766  seconds by  6.18565615450693  percent.
# ...
# step size too small or too large
# RUN  1 , total integrated cost =  7.373496395079663
# RUN  1 , total integrated cost mean =  7.373496395079663
# Improved over  1  iterations in  3.679030697006965  seconds by  6.375690174929446  percent.
# cost =  7.559755448748114
# iteration =  18
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7.657051689690294
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.305630490672198
# RUN  1 , total integrated cost mean =  7.305630490672198
# Improved over  1  iterations in  2.0316950600099517  seconds by  4.5895106009439814  percent.
# cost =  7.459954539904544
# iteration =  19
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7.435141424805677
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.309453901642257
# RUN  1 , total integrated cost mean =  7.309453901642257
# Improved over  1  iterations in  2.471884394995868  seconds by  1.690452352985389  percent.
# cost =  7.311423549597292
# iteration =  20
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7.423387492004565
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.004670390952242
# RUN  1 , total integrated cost mean =  7.004670390952242
# Improved over  1  iterations in  2.6224934780038893  seconds by  5.640512522124254  percent.
# cost =  7.198273554417602
# iteration =  21
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7.203354661654333
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.978083975370208
# RUN  1 , total integrated cost mean =  6.978083975370208
# Improved over  1  iterations in  2.223849877002067  seconds by  3.1273024426148197  percent.
# cost =  7.107955125298672
# iteration =  22
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7.158303530169746
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.996880911711612
# RUN  1 , total integrated cost mean =  6.996880911711612
# Improved over  1  iterations in  2.0084627009928226  seconds by  2.2550401471213775  percent.
# cost =  7.16155711937046
# iteration =  23
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7.017953176406263
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.096321448570838
# RUN  1 , total integrated cost mean =  7.096321448570838
# Improved over  1  iterations in  2.81269768900529  seconds by  -1.1166827448783891  percent.
# cost =  7.094678767343272
# iteration =  24
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7.5212982552606515
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.221108615371696
# RUN  1 , total integrated cost mean =  7.221108615371696
# Improved over  1  iterations in  2.391925287010963  seconds by  3.991194468042707  percent.
# cost =  7.156142431375524
# iteration =  25
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7.082758713908227
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.983200983336344
# RUN  1 , total integrated cost mean =  6.983200983336344
# Improved over  1  iterations in  2.752968911008793  seconds by  1.405634931151667  percent.
# cost =  7.119152342832023
# iteration =  26
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  6.861182632923935
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.894525073463451
# RUN  1 , total integrated cost mean =  6.894525073463451
# Improved over  1  iterations in  3.167609245996573  seconds by  -0.48595763038750306  percent.
# cost =  6.891026540345429
# iteration =  27
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  6.883181563033491
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.581423345252555
# RUN  1 , total integrated cost mean =  6.581423345252555
# Improved over  1  iterations in  4.041198321006959  seconds by  4.383993288823675  percent.
# cost =  6.899385903669995
# iteration =  28
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  6.854183314115177
# Gradient descend method:  None
# step size too small or too large
# step size too small or too large
# RUN  1 , total integrated cost =  6.741301465433355
# RUN  1 , total integrated cost mean =  6.741301465433355
# Improved over  1  iterations in  3.4197348480083747  seconds by  1.646904430603115  percent.
# cost =  6.916221564608694
# iteration =  29
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  6.798188225730006
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.3473220116993465
# RUN  1 , total integrated cost mean =  6.3473220116993465
# Improved over  1  iterations in  3.013964979996672  seconds by  6.632152553884964  percent.
# cost =  6.4982322234976335
# n =  30
# iteration =  1
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  269.30162705395895
# Gradient descend method:  None
# RUN  1 , total integrated cost =  179.84291355102212
# RUN  1 , total integrated cost mean =  179.84291355102212
# Improved over  1  iterations in  5.228778404998593  seconds by  33.218779433891925  percent.
# cost =  153.35835743029804
# iteration =  2
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  187.9356293407085
# Gradient descend method:  None
# step size too small or too large
# RUN  1 , total integrated cost =  77.28264780898256
# RUN  1 , total integrated cost mean =  77.28264780898256
# Improved over  1  iterations in  5.195698641007766  seconds by  58.87812860174754  percent.
# cost =  71.4574523097009
# iteration =  3
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  100.82616873591681
# Gradient descend method:  None
# RUN  1 , total integrated cost =  24.41143013619539
# RUN  1 , total integrated cost mean =  24.41143013619539
# Improved over  1  iterations in  4.916882338002324  seconds by  75.78859690668835  percent.
# cost =  27.639108903888282
# iteration =  4
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  36.55029564949005
# Gradient descend method:  None
# step size too small or too large
# RUN  1 , total integrated cost =  71.4538593322869
# RUN  1 , total integrated cost mean =  71.4538593322869
# Improved over  1  iterations in  5.060752692996175  seconds by  -95.49461382615058  percent.
# cost =  62.276488205727105
# iteration =  5
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  43.752878812108555
# Gradient descend method:  None
# RUN  1 , total integrated cost =  13.400868343758862
# RUN  1 , total integrated cost mean =  13.400868343758862
# Improved over  1  iterations in  4.820062699000118  seconds by  69.37145918716053  percent.
# cost =  13.617968129351864
# iteration =  6
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  14.21688936650969
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.01823627173672
# RUN  1 , total integrated cost mean =  11.01823627173672
# Improved over  1  iterations in  7.626627193996683  seconds by  22.498965929269616  percent.
# cost =  11.166175205935204
# iteration =  7
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  10.803154095625088
# Gradient descend method:  None
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  1 , total integrated cost =  10.228312623145701
# RUN  1 , total integrated cost mean =  10.228312623145701
# Improved over  1  iterations in  11.1216982719925  seconds by  5.321052235218772  percent.
# cost =  10.967487870973608
# iteration =  8
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  10.529537314794993
# Gradient descend method:  None
# RUN  1 , total integrated cost =  10.310811488942422
# RUN  1 , total integrated cost mean =  10.310811488942422
# Improved over  1  iterations in  9.093157045004773  seconds by  2.077259610878073  percent.
# cost =  10.30446079486185
# iteration =  9
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  10.337416311188257
# Gradient descend method:  None
# RUN  1 , total integrated cost =  10.0750539864389
# RUN  1 , total integrated cost mean =  10.0750539864389
# Improved over  1  iterations in  9.88304471700394  seconds by  2.5379874124388238  percent.
# cost =  10.273231437595552
# iteration =  10
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  10.246170921900092
# Gradient descend method:  None
# RUN  1 , total integrated cost =  9.898374860166756
# RUN  1 , total integrated cost mean =  9.898374860166756
# Improved over  1  iterations in  9.01882436699816  seconds by  3.3944003509638776  percent.
# cost =  9.96613581394063
# iteration =  11
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  9.939848565697218
# Gradient descend method:  None
# step size too small or too large
# RUN  1 , total integrated cost =  9.750339157433277
# RUN  1 , total integrated cost mean =  9.750339157433277
# Improved over  1  iterations in  8.137227788989549  seconds by  1.9065623285041227  percent.
# cost =  10.02597998036044
# iteration =  12
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  9.935797495349249
# Gradient descend method:  None
# RUN  1 , total integrated cost =  9.80122682196539
# RUN  1 , total integrated cost mean =  9.80122682196539
# Improved over  1  iterations in  8.403267453002627  seconds by  1.354402336066613  percent.
# cost =  9.786887533320643
# iteration =  13
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  9.863346930953384
# Gradient descend method:  None
# RUN  1 , total integrated cost =  9.5554619134367
# RUN  1 , total integrated cost mean =  9.5554619134367
# Improved over  1  iterations in  7.683903344994178  seconds by  3.12150651976431  percent.
# cost =  9.638998182026144
# iteration =  14
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  9.634268260445525
# Gradient descend method:  None
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  1 , total integrated cost =  9.520737915742547
# RUN  1 , total integrated cost mean =  9.520737915742547
# Improved over  1  iterations in  10.44119897800556  seconds by  1.1784013236281652  percent.
# cost =  9.592899253143486
# iteration =  15
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  9.561069934700761
# Gradient descend method:  None
# step size too small or too large
# RUN  1 , total integrated cost =  9.517100006807848
# RUN  1 , total integrated cost mean =  9.517100006807848
# Improved over  1  iterations in  9.75899771200784  seconds by  0.4598850148907445  percent.
# cost =  9.64488070415168
# iteration =  16
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  9.73652133134218
# Gradient descend method:  None
# step size too small or too large
# RUN  1 , total integrated cost =  9.421699173429431
# RUN  1 , total integrated cost mean =  9.421699173429431
# Improved over  1  iterations in  10.832514679001179  seconds by  3.2334151715903516  percent.
# cost =  9.43403497960358
# iteration =  17
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  9.44287143693192
# Gradient descend method:  None
# RUN  1 , total integrated cost =  9.20815222350654
# RUN  1 , total integrated cost mean =  9.20815222350654
# Improved over  1  iterations in  8.591000829997938  seconds by  2.4856762584670236  percent.
# cost =  9.360122983976662
# iteration =  18
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  9.222150313592017
# Gradient descend method:  None
# step size too small or too large
# step size too small or too large
# RUN  1 , total integrated cost =  9.110291735950222
# RUN  1 , total integrated cost mean =  9.110291735950222
# Improved over  1  iterations in  12.08844022800622  seconds by  1.2129337935094497  percent.
# cost =  9.275842843613953
# iteration =  19
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  9.205252389462022
# Gradient descend method:  None
# RUN  1 , total integrated cost =  9.026422036644085
# RUN  1 , total integrated cost mean =  9.026422036644085
# Improved over  1  iterations in  13.33975004698732  seconds by  1.9426990727886846  percent.
# cost =  9.050918073834719
# iteration =  20
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  8.941489138507148
# Gradient descend method:  None
# RUN  1 , total integrated cost =  8.818667282689985
# RUN  1 , total integrated cost mean =  8.818667282689985
# Improved over  1  iterations in  11.312712897997699  seconds by  1.3736174580610054  percent.
# cost =  9.039648338058507
# iteration =  21
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  8.725339588968465
# Gradient descend method:  None
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  1 , total integrated cost =  8.71295989481197
# RUN  1 , total integrated cost mean =  8.71295989481197
# Improved over  1  iterations in  14.362305946997367  seconds by  0.1418820898632589  percent.
# cost =  8.85754434250373
# iteration =  22
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  8.777423561084316
# Gradient descend method:  None
# RUN  1 , total integrated cost =  8.605867175097694
# RUN  1 , total integrated cost mean =  8.605867175097694
# Improved over  1  iterations in  12.08641785501095  seconds by  1.9545187126121562  percent.
# cost =  8.652011156299155
# iteration =  23
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  8.583353212499718
# Gradient descend method:  None
# RUN  1 , total integrated cost =  8.325972864464324
# RUN  1 , total integrated cost mean =  8.325972864464324
# Improved over  1  iterations in  11.558178678998956  seconds by  2.998599051715331  percent.
# cost =  8.642605693764693
# iteration =  24
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  8.565453973482295
# Gradient descend method:  None
# RUN  1 , total integrated cost =  8.356956206949599
# RUN  1 , total integrated cost mean =  8.356956206949599
# Improved over  1  iterations in  12.784325800996157  seconds by  2.4341706484931507  percent.
# cost =  8.427338068419349
# iteration =  25
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  8.419216584467515
# Gradient descend method:  None
# step size too small or too large
# RUN  1 , total integrated cost =  8.248878047075426
# RUN  1 , total integrated cost mean =  8.248878047075426
# Improved over  1  iterations in  8.568113736997475  seconds by  2.02321125348341  percent.
# cost =  8.310751818247686
# iteration =  26
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  8.243208482788392
# Gradient descend method:  None
# RUN  1 , total integrated cost =  8.039442698060395
# RUN  1 , total integrated cost mean =  8.039442698060395
# Improved over  1  iterations in  8.281212171001243  seconds by  2.4719232220494547  percent.
# cost =  8.18075496391305
# iteration =  27
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  8.16290651005904
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.966845026996898
# RUN  1 , total integrated cost mean =  7.966845026996898
# Improved over  1  iterations in  7.268408678995911  seconds by  2.4018587352499736  percent.
# cost =  8.058064340407311
# iteration =  28
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7.956695359007749
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.696413494223618
# RUN  1 , total integrated cost mean =  7.696413494223618
# Improved over  1  iterations in  6.802063051000005  seconds by  3.271230743922686  percent.
# cost =  7.922423147933167
# iteration =  29
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7.941286198446418
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.77669280879834
# RUN  1 , total integrated cost mean =  7.77669280879834
# Improved over  1  iterations in  5.842948450008407  seconds by  2.0726288605525554  percent.
# cost =  7.890518180521791

# %%
#len(sigma_array), 4, N_max, max_it

##### METHOD 4
method_ind = 3
step_method_ind = 0

for d in dict_list:
    print("Point = ", d['point'])
    aln.params.ext_exc_current = d['point'][0] * 5.
    aln.params.ext_inh_current = d['point'][1] * 5.
    
    max_it = d['cost'].shape[3]
    
    for s_ind in range(len(d['sigma'])):
        
        print("sigma = ", d['sigma'][s_ind])
        
        s = d['sigma'][s_ind]
        aln.params.sigma_ou = s
        c_p = d['cost_params'][s_ind]
        cost.setParams(c_p[0], c_p[1], c_p[2])
        
        target_ = d['target'][s_ind].copy()
        target_[0,0,:int(trans_time * dur / aln.params.dt)] = -1000
        target_[0,1,:int(trans_time * dur / aln.params.dt)] = -1000
                
        for n_ind in range(len(d['N_array'])):
            
            n_ = d['N_array'][n_ind]
            
            print("n = ", n_)
            aln.params.duration = dur
            control_init = aln.getZeroControl()
        
            for i_it in range(1, d['cost'].shape[4], 1):
                
                if d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it] > 0.:
                    continue
                
                print("iteration = ", i_it)

                if i_it <= init_it:
                    c_vars = d['init']
                else:
                    c_vars = [0,1]
                    
                aln.params.duration = dur
                setinit(d['init_vars'], aln)

                bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                    control_init, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_ = i_it,
                    tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                    t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                    control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                    noise_real=n_, init_params = d['init_vars'], method='M3')
            
                aln.params.duration = dur
                setinit(d['init_vars'], aln)

                cost_final = 0.
                cs = cost.numba_cost_sparsity_int(1, 6, T, d['cost_params'][s_ind][2], dt, control_init)

                for j in range(noise_realizations_final):
                    state_ = fo.updateState(aln, control_init)
                    cost_final += cost.numba_cost_precision_int(1, T, dt, d['cost_params'][s_ind][0],
                                                                   state_, target_, list(prec_vars) )

                d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it] = (
                                cost_final / noise_realizations_final + cs )
                print('cost = ', d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it])
                
                file=open(dict_file, "wb")
                pickle.dump(dict_list, file)
                file.close()
# Out:
# Point =  [0.4   0.322]
# sigma =  0.01
# set cost params:  0.00829916864127671 0.0 1.0
# n =  1
# iteration =  1
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1398.9877222677244
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12.199352349408246
# RUN  1 , total integrated cost mean =  12.199352349408246
# Improved over  1  iterations in  13.385787571998662  seconds by  99.12798717563915  percent.
# cost =  319.2852142125449
# iteration =  2
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  324.329689513803
# Gradient descend method:  None
# RUN  1 , total integrated cost =  327.17682053923414
# RUN  1 , total integrated cost mean =  327.17682053923414
# Improved over  1  iterations in  0.2421968019916676  seconds by  -0.8778508775127136  percent.
# cost =  82.89767498718183
# iteration =  3
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  13.737786282297547
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.426546051609516
# RUN  1 , total integrated cost mean =  2.426546051609516
# Improved over  1  iterations in  0.18233924299420323  seconds by  82.33670256803782  percent.
# cost =  228.43596067077132
# iteration =  4
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.4819038160157074
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.7904049141354341
# RUN  1 , total integrated cost mean =  1.7904049141354341
# Improved over  1  iterations in  0.13928278400271665  seconds by  27.861631760990733  percent.
# cost =  263.9505294801458
# iteration =  5
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.021647043766407
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.482673656087014
# RUN  1 , total integrated cost mean =  4.482673656087014
# Improved over  1  iterations in  0.17524391000915784  seconds by  -121.73374278705046  percent.
# cost =  331.03779078192673
# iteration =  6
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1419.1365593124972
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.382740607755305
# RUN  1 , total integrated cost mean =  3.382740607755305
# Improved over  1  iterations in  0.3285344489995623  seconds by  99.76163389030059  percent.
# cost =  81.15809863641545
# iteration =  7
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  4.59252536006027
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.258800194920552
# RUN  1 , total integrated cost mean =  3.258800194920552
# Improved over  1  iterations in  0.244267039000988  seconds by  29.041215030377415  percent.
# cost =  6.0208686541388685
# iteration =  8
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.2849323278948264
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.739460673840848
# RUN  1 , total integrated cost mean =  2.739460673840848
# Improved over  1  iterations in  0.24425247200997546  seconds by  16.605263049773328  percent.
# cost =  6.2571611374385965
# iteration =  9
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.4555600329524427
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.372647009754168
# RUN  1 , total integrated cost mean =  2.372647009754168
# Improved over  1  iterations in  0.36799968700506724  seconds by  3.376542299337899  percent.
# cost =  12.675684032995447
# iteration =  10
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.981982241077644
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.450555879128003
# RUN  1 , total integrated cost mean =  2.450555879128003
# Improved over  1  iterations in  0.45099702099105343  seconds by  38.45889482257437  percent.
# cost =  6.366264501309416
# iteration =  11
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.516974234356097
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.259146536620112
# RUN  1 , total integrated cost mean =  2.259146536620112
# Improved over  1  iterations in  0.3311523370066425  seconds by  10.2435572925896  percent.
# cost =  4.531835491369637
# iteration =  12
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.2910176090599683
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.229728796472047
# RUN  1 , total integrated cost mean =  2.229728796472047
# Improved over  1  iterations in  0.25953874200058635  seconds by  2.6751785907515853  percent.
# cost =  6.587751005090326
# iteration =  13
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.5953274329677374
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.1994849070690856
# RUN  1 , total integrated cost mean =  2.1994849070690856
# Improved over  1  iterations in  0.24991157800832298  seconds by  15.252122752234342  percent.
# cost =  8.993716866922098
# iteration =  14
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.2549915547576744
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.174940116701676
# RUN  1 , total integrated cost mean =  2.174940116701676
# Improved over  1  iterations in  0.39315718300349545  seconds by  3.5499662021838816  percent.
# cost =  8.379581878360076
# iteration =  15
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.1099488901280834
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.106931470983076
# RUN  1 , total integrated cost mean =  2.106931470983076
# Improved over  1  iterations in  0.4298580739996396  seconds by  0.14300911074791145  percent.
# cost =  5.467150844388089
# iteration =  16
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.6669456368755924
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.0521780806181313
# RUN  1 , total integrated cost mean =  2.0521780806181313
# Improved over  1  iterations in  0.48307595400547143  seconds by  23.05137186739509  percent.
# cost =  2.6706357616596152
# iteration =  17
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.1730726292429376
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.0059383819165415
# RUN  1 , total integrated cost mean =  2.0059383819165415
# Improved over  1  iterations in  0.286489085003268  seconds by  7.6911487024077445  percent.
# cost =  2.8524550044532893
# iteration =  18
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1.9266239528970939
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.9901706321825638
# RUN  1 , total integrated cost mean =  1.9901706321825638
# Improved over  1  iterations in  0.4435916179936612  seconds by  -3.2983436746913526  percent.
# cost =  3.0185908051895707
# iteration =  19
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.15136816447423
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.9534435310948923
# RUN  1 , total integrated cost mean =  1.9534435310948923
# Improved over  1  iterations in  0.23360038200917188  seconds by  9.199942466737582  percent.
# cost =  2.8547715676034002
# iteration =  20
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1.8120366058884232
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.1634042959765445
# RUN  1 , total integrated cost mean =  2.1634042959765445
# Improved over  1  iterations in  0.5323627070029033  seconds by  -19.390761143914602  percent.
# cost =  2.5826111394306386
# iteration =  21
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1.9431073923242757
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.9064685544254898
# RUN  1 , total integrated cost mean =  1.9064685544254898
# Improved over  1  iterations in  0.4376046030083671  seconds by  1.8855796670589484  percent.
# cost =  2.8379190916685872
# iteration =  22
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.052280921688599
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.8593505674735384
# RUN  1 , total integrated cost mean =  1.8593505674735384
# Improved over  1  iterations in  0.2763709119899431  seconds by  9.400777065954443  percent.
# cost =  2.7142440247397484
# iteration =  23
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1.857777397547719
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.884945739167392
# RUN  1 , total integrated cost mean =  1.884945739167392
# Improved over  1  iterations in  0.3626022819953505  seconds by  -1.462411032426985  percent.
# cost =  2.7536271428568044
# iteration =  24
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.174032887311431
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.9484535387076725
# RUN  1 , total integrated cost mean =  1.9484535387076725
# Improved over  1  iterations in  0.37803320300008636  seconds by  10.376078021649732  percent.
# cost =  3.1564136937877154
# iteration =  25
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1.7715612622418289
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.7643570380561626
# RUN  1 , total integrated cost mean =  1.7643570380561626
# Improved over  1  iterations in  0.2993388809991302  seconds by  0.406659613709877  percent.
# cost =  3.71237563695308
# iteration =  26
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.2500432427685233
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.8612413665838554
# RUN  1 , total integrated cost mean =  1.8612413665838554
# Improved over  1  iterations in  0.26045218801300507  seconds by  17.27975128630301  percent.
# cost =  3.1865038803160126
# iteration =  27
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1.8863222564046676
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.6486872735564924
# RUN  1 , total integrated cost mean =  1.6486872735564924
# Improved over  1  iterations in  0.2125968059990555  seconds by  12.597793512817248  percent.
# cost =  3.6547500889320252
# iteration =  28
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1.944514298051239
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.8925495754743167
# RUN  1 , total integrated cost mean =  1.8925495754743167
# Improved over  1  iterations in  0.2529183459992055  seconds by  2.6723754424948396  percent.
# cost =  2.595500337636266
# iteration =  29
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1.7141627374222401
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.6587199248537248
# RUN  1 , total integrated cost mean =  1.6587199248537248
# Improved over  1  iterations in  0.32274392299586907  seconds by  3.2343960907638376  percent.
# cost =  2.850739448132386
# n =  2
# iteration =  1
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1374.2043745498568
# Gradient descend method:  None
# RUN  1 , total integrated cost =  197.2673531207792
# RUN  1 , total integrated cost mean =  197.2673531207792
# Improved over  1  iterations in  0.19700995300081559  seconds by  85.64497706642817  percent.
# cost =  151.44880691374934
# iteration =  2
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  165.51361454314664
# Gradient descend method:  None
# RUN  1 , total integrated cost =  13.1350723219692
# RUN  1 , total integrated cost mean =  13.1350723219692
# Improved over  1  iterations in  0.20975518100021873  seconds by  92.06405324527239  percent.
# cost =  13.515325951827739
# iteration =  3
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  13.503645392829425
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.613955384692256
# RUN  1 , total integrated cost mean =  4.613955384692256
# Improved over  1  iterations in  0.1679931510007009  seconds by  65.83177911986408  percent.
# cost =  4.0132617118313485
# iteration =  4
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.711119570725887
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.3820770665538635
# RUN  1 , total integrated cost mean =  3.3820770665538635
# Improved over  1  iterations in  0.22898818700923584  seconds by  8.866394571804747  percent.
# cost =  3.1758429339175853
# iteration =  5
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.1110178677716296
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.066253726315784
# RUN  1 , total integrated cost mean =  3.066253726315784
# Improved over  1  iterations in  0.16770469999755733  seconds by  1.4388905290315535  percent.
# cost =  3.1856162245933244
# iteration =  6
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.3830097066976457
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.025398296744978
# RUN  1 , total integrated cost mean =  3.025398296744978
# Improved over  1  iterations in  0.30739360200823285  seconds by  10.570806499451436  percent.
# cost =  3.7328549113077343
# iteration =  7
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.8838018613252023
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.8545492529305094
# RUN  1 , total integrated cost mean =  2.8545492529305094
# Improved over  1  iterations in  0.30091278000327293  seconds by  1.0143765002374465  percent.
# cost =  3.5002524062846145
# iteration =  8
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.981625855495816
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.8081826035869955
# RUN  1 , total integrated cost mean =  2.8081826035869955
# Improved over  1  iterations in  0.30482853000285104  seconds by  5.817069622908093  percent.
# cost =  4.330097867655804
# iteration =  9
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.7526870997405766
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.6093215070691347
# RUN  1 , total integrated cost mean =  2.6093215070691347
# Improved over  1  iterations in  0.34596117500041146  seconds by  5.208205200109859  percent.
# cost =  4.776275723037224
# iteration =  10
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.8944852854099983
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.705482759056051
# RUN  1 , total integrated cost mean =  2.705482759056051
# Improved over  1  iterations in  0.3053957610100042  seconds by  6.52974562719794  percent.
# cost =  3.9071807308108073
# iteration =  11
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.780693479548421
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.6661903349572063
# RUN  1 , total integrated cost mean =  2.6661903349572063
# Improved over  1  iterations in  0.30700511700706556  seconds by  4.117790955147257  percent.
# cost =  3.412511479143372
# iteration =  12
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.817108635648355
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.554910872277105
# RUN  1 , total integrated cost mean =  2.554910872277105
# Improved over  1  iterations in  0.34558063800795935  seconds by  9.307335899416088  percent.
# cost =  4.5183829476610615
# iteration =  13
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  9.035786081864343
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.941228498905338
# RUN  1 , total integrated cost mean =  2.941228498905338
# Improved over  1  iterations in  0.3332257430010941  seconds by  67.44911320102348  percent.
# cost =  2.8482657880556603
# iteration =  14
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.8893224378173326
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.72679486712251
# RUN  1 , total integrated cost mean =  2.72679486712251
# Improved over  1  iterations in  0.2925642960035475  seconds by  5.625110183881034  percent.
# cost =  2.8111519545416352
# iteration =  15
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.7544886693039725
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.7407652833119505
# RUN  1 , total integrated cost mean =  2.7407652833119505
# Improved over  1  iterations in  0.2828647220012499  seconds by  0.4982190032202851  percent.
# cost =  3.863273430490136
# iteration =  16
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.8741139646159377
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.7085761612210733
# RUN  1 , total integrated cost mean =  2.7085761612210733
# Improved over  1  iterations in  0.2996171279955888  seconds by  5.7596116727745965  percent.
# cost =  3.6835411540271203
# iteration =  17
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.789843156894017
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.624191858236613
# RUN  1 , total integrated cost mean =  2.624191858236613
# Improved over  1  iterations in  0.2933438489999389  seconds by  5.9376563248031005  percent.
# cost =  6.5050046248959665
# iteration =  18
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.8239478478834474
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.700766477381845
# RUN  1 , total integrated cost mean =  2.700766477381845
# Improved over  1  iterations in  0.3163839310000185  seconds by  4.362027103082909  percent.
# cost =  5.10698448899615
# iteration =  19
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.767864400293326
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.7057256604253666
# RUN  1 , total integrated cost mean =  2.7057256604253666
# Improved over  1  iterations in  0.2975563349900767  seconds by  2.2450066506644646  percent.
# cost =  6.0851579663390964
# iteration =  20
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.730286934304016
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.593810893873341
# RUN  1 , total integrated cost mean =  2.593810893873341
# Improved over  1  iterations in  0.2923233969922876  seconds by  4.998596986857137  percent.
# cost =  4.746161142941719
# iteration =  21
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.541560709974803
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.526191685003832
# RUN  1 , total integrated cost mean =  2.526191685003832
# Improved over  1  iterations in  0.4080795439949725  seconds by  0.6047081586779512  percent.
# cost =  4.324106888098558
# iteration =  22
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.687106212055274
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.580862292873852
# RUN  1 , total integrated cost mean =  2.580862292873852
# Improved over  1  iterations in  0.32546731499314774  seconds by  3.953841448647438  percent.
# cost =  5.47861241542224
# iteration =  23
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.6080902051720267
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.6115075355014836
# RUN  1 , total integrated cost mean =  2.6115075355014836
# Improved over  1  iterations in  0.3124700059997849  seconds by  -0.13102807267479477  percent.
# cost =  4.5017852906555635
# iteration =  24
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.574749190493567
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.50943078138407
# RUN  1 , total integrated cost mean =  2.50943078138407
# Improved over  1  iterations in  0.3033696710044751  seconds by  2.536884343945573  percent.
# cost =  3.9497602650962995
# iteration =  25
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.606026704195326
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.482311410356468
# RUN  1 , total integrated cost mean =  2.482311410356468
# Improved over  1  iterations in  0.2875932940078201  seconds by  4.747276520217312  percent.
# cost =  3.718313099018742
# iteration =  26
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.669134825559687
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.400025415500088
# RUN  1 , total integrated cost mean =  2.400025415500088
# Improved over  1  iterations in  0.2867155699932482  seconds by  10.08227113454899  percent.
# cost =  3.837634703161967
# iteration =  27
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.593003266901313
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.4063792665065384
# RUN  1 , total integrated cost mean =  2.4063792665065384
# Improved over  1  iterations in  0.3046102369989967  seconds by  7.197214240990661  percent.
# cost =  3.4048725103392368
# iteration =  28
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.3973319759851397
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.3947396900189757
# RUN  1 , total integrated cost mean =  2.3947396900189757
# Improved over  1  iterations in  0.438764976002858  seconds by  0.10813212321579613  percent.
# cost =  2.8900039128570474
# iteration =  29
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.5978348391407318
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.3658398563237233
# RUN  1 , total integrated cost mean =  2.3658398563237233
# Improved over  1  iterations in  0.2878495839977404  seconds by  8.930320716375633  percent.
# cost =  3.155368655341748
# n =  10
# iteration =  1
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1384.853443964757
# Gradient descend method:  None
# RUN  1 , total integrated cost =  153.44595786517615
# RUN  1 , total integrated cost mean =  153.44595786517615
# Improved over  1  iterations in  0.5587198230059585  seconds by  88.91969698787265  percent.
# cost =  162.65875268730903
# iteration =  2
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  258.82441941883854
# Gradient descend method:  None
# RUN  1 , total integrated cost =  32.517976694051974
# RUN  1 , total integrated cost mean =  32.517976694051974
# Improved over  1  iterations in  1.293953414002317  seconds by  87.43627947970772  percent.
# cost =  31.673251428085763
# iteration =  3
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  31.313891214316754
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.450047655963385
# RUN  1 , total integrated cost mean =  4.450047655963385
# Improved over  1  iterations in  0.5537531550071435  seconds by  85.78890235804097  percent.
# cost =  4.189097491628748
# iteration =  4
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  4.392622858922194
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.6926854525274937
# RUN  1 , total integrated cost mean =  2.6926854525274937
# Improved over  1  iterations in  0.5057516030065017  seconds by  38.6998260718383  percent.
# cost =  2.690499846256601
# iteration =  5
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.7230055777727755
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.3471268267382097
# RUN  1 , total integrated cost mean =  2.3471268267382097
# Improved over  1  iterations in  0.6263034370058449  seconds by  13.80381862243587  percent.
# cost =  2.384184601161383
# iteration =  6
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.502312675856825
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.3941495724607824
# RUN  1 , total integrated cost mean =  2.3941495724607824
# Improved over  1  iterations in  1.5176365950028412  seconds by  4.322525495699935  percent.
# cost =  2.3609494680889336
# iteration =  7
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.299850589601742
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.24809769890091
# RUN  1 , total integrated cost mean =  2.24809769890091
# Improved over  1  iterations in  1.5169858099980047  seconds by  2.2502718626514593  percent.
# cost =  2.2806696833366065
# iteration =  8
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.324084059712546
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.2412862351518825
# RUN  1 , total integrated cost mean =  2.2412862351518825
# Improved over  1  iterations in  1.4462202920112759  seconds by  3.562600251683861  percent.
# cost =  2.261250985880949
# iteration =  9
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.21950040995777
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.233056189793432
# RUN  1 , total integrated cost mean =  2.233056189793432
# Improved over  1  iterations in  1.4317110940028215  seconds by  -0.6107581586759068  percent.
# cost =  2.2550755156380617
# iteration =  10
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.210823008771519
# Gradient descend method:  None
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  1 , total integrated cost =  2.1661480729025118
# RUN  1 , total integrated cost mean =  2.1661480729025118
# Improved over  1  iterations in  2.0614224610035308  seconds by  2.0207377837012643  percent.
# cost =  2.182065795943875
# iteration =  11
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.1968353323063434
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.1272998916484074
# RUN  1 , total integrated cost mean =  2.1272998916484074
# Improved over  1  iterations in  1.2246115790039767  seconds by  3.1652550209548167  percent.
# cost =  2.1766288745335727
# iteration =  12
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.111948580525864
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.088793310858768
# RUN  1 , total integrated cost mean =  2.088793310858768
# Improved over  1  iterations in  1.7043511569936527  seconds by  1.0963936281692384  percent.
# cost =  2.1337319392957195
# iteration =  13
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.118470861382717
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.0812486740915497
# RUN  1 , total integrated cost mean =  2.0812486740915497
# Improved over  1  iterations in  1.4047075089911232  seconds by  1.7570308834397963  percent.
# cost =  2.102669471011122
# iteration =  14
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.134848389383006
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.0319800640537298
# RUN  1 , total integrated cost mean =  2.0319800640537298
# Improved over  1  iterations in  1.196405553011573  seconds by  4.81853071350919  percent.
# cost =  2.0445109562208295
# iteration =  15
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.050548925228909
# Gradient descend method:  None
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  1 , total integrated cost =  1.9520517561954804
# RUN  1 , total integrated cost mean =  1.9520517561954804
# Improved over  1  iterations in  1.9531225410028128  seconds by  4.803453739706939  percent.
# cost =  2.0110356922581474
# iteration =  16
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1.969840154792913
# Gradient descend method:  None
# step size too small or too large
# RUN  1 , total integrated cost =  1.9248420339843744
# RUN  1 , total integrated cost mean =  1.9248420339843744
# Improved over  1  iterations in  1.80461538900272  seconds by  2.2843539207509593  percent.
# cost =  1.9335286962674294
# iteration =  17
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1.9712599506079234
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.880533305581385
# RUN  1 , total integrated cost mean =  1.880533305581385
# Improved over  1  iterations in  1.752537221997045  seconds by  4.602469856832371  percent.
# cost =  2.0753512238936938
# iteration =  18
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1.861755301247894
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.8223257232204577
# RUN  1 , total integrated cost mean =  1.8223257232204577
# Improved over  1  iterations in  1.639388636991498  seconds by  2.1178711295199406  percent.
# cost =  2.213604102708809
# iteration =  19
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1.8502070297453224
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.733606571558375
# RUN  1 , total integrated cost mean =  1.733606571558375
# Improved over  1  iterations in  1.963931014004629  seconds by  6.302022223048041  percent.
# cost =  2.205000739626698
# iteration =  20
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1.7950648554643656
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.8151518736087193
# RUN  1 , total integrated cost mean =  1.8151518736087193
# Improved over  1  iterations in  1.4546630769909825  seconds by  -1.1190135043425755  percent.
# cost =  2.1896234404444805
# iteration =  21
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1.8384616929022737
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.720316422671744
# RUN  1 , total integrated cost mean =  1.720316422671744
# Improved over  1  iterations in  1.566195630992297  seconds by  6.426311230016466  percent.
# cost =  2.8055922051405306
# iteration =  22
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1.8482560434547062
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.7378273459826743
# RUN  1 , total integrated cost mean =  1.7378273459826743
# Improved over  1  iterations in  1.4623334440111648  seconds by  5.974751055899247  percent.
# cost =  2.526380760985758
# iteration =  23
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1.7298209946132694
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.6636168841328647
# RUN  1 , total integrated cost mean =  1.6636168841328647
# Improved over  1  iterations in  1.1873275740072131  seconds by  3.8272232032428093  percent.
# cost =  2.8760903326065046
# iteration =  24
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1.7242603132810381
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.6677600090654607
# RUN  1 , total integrated cost mean =  1.6677600090654607
# Improved over  1  iterations in  1.4897652360086795  seconds by  3.276785052720072  percent.
# cost =  3.6498882178399508
# iteration =  25
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1.7019440781908028
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.6133122076869202
# RUN  1 , total integrated cost mean =  1.6133122076869202
# Improved over  1  iterations in  1.6537667279917514  seconds by  5.207684061987507  percent.
# cost =  2.63774009944966
# iteration =  26
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1.6294137324681504
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.5921608111142684
# RUN  1 , total integrated cost mean =  1.5921608111142684
# Improved over  1  iterations in  1.669993631003308  seconds by  2.286277610871309  percent.
# cost =  2.710337127422036
# iteration =  27
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1.5365389552593642
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.4643234255736872
# RUN  1 , total integrated cost mean =  1.4643234255736872
# Improved over  1  iterations in  1.2958118819951778  seconds by  4.699882774757711  percent.
# cost =  2.721148799974096
# iteration =  28
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1.4858665164779432
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.4585921182906412
# RUN  1 , total integrated cost mean =  1.4585921182906412
# Improved over  1  iterations in  1.491577006992884  seconds by  1.8355887211155846  percent.
# cost =  2.8108641568228028
# iteration =  29
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1.4617740028814974
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.3990831513429356
# RUN  1 , total integrated cost mean =  1.3990831513429356
# Improved over  1  iterations in  1.7738849519955693  seconds by  4.288682889077492  percent.
# cost =  2.764659117222242
# n =  30
# iteration =  1
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1375.2951491589324
# Gradient descend method:  None
# RUN  1 , total integrated cost =  108.41176324372572
# RUN  1 , total integrated cost mean =  108.41176324372572
# Improved over  1  iterations in  2.1658690470067086  seconds by  92.11720020171485  percent.
# cost =  123.03878264496417
# iteration =  2
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  141.68049368204836
# Gradient descend method:  None
# RUN  1 , total integrated cost =  42.23665398905135
# RUN  1 , total integrated cost mean =  42.23665398905135
# Improved over  1  iterations in  2.647511550996569  seconds by  70.18880094825437  percent.
# cost =  40.20917171124576
# iteration =  3
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  54.07720478818283
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.800872914631902
# RUN  1 , total integrated cost mean =  4.800872914631902
# Improved over  1  iterations in  1.8127740019990597  seconds by  91.12218737370648  percent.
# cost =  15.028696125754182
# iteration =  4
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  4.86117129838517
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.374106421234507
# RUN  1 , total integrated cost mean =  3.374106421234507
# Improved over  1  iterations in  2.5860725789971184  seconds by  30.590670146609526  percent.
# cost =  15.823350070828129
# iteration =  5
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  49.13430773436584
# Gradient descend method:  None
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  1 , total integrated cost =  47.474210206318126
# RUN  1 , total integrated cost mean =  47.474210206318126
# Improved over  1  iterations in  2.590527648004354  seconds by  3.37869322800411  percent.
# cost =  16.108297283653368
# iteration =  6
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  47.65073202294711
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.17777203279968
# RUN  1 , total integrated cost mean =  3.17777203279968
# Improved over  1  iterations in  6.567344638009672  seconds by  93.33111602300387  percent.
# cost =  15.04551876075934
# iteration =  7
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.159746429052984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.985455998685035
# RUN  1 , total integrated cost mean =  2.985455998685035
# Improved over  1  iterations in  10.697326024004724  seconds by  5.515962571091066  percent.
# cost =  20.429346112426817
# iteration =  8
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.008587288321138
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.9908759897747412
# RUN  1 , total integrated cost mean =  2.9908759897747412
# Improved over  1  iterations in  6.873272071999963  seconds by  0.5886915302457396  percent.
# cost =  20.258448022313118
# iteration =  9
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.935156758113865
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.874785552591482
# RUN  1 , total integrated cost mean =  2.874785552591482
# Improved over  1  iterations in  5.284508419994381  seconds by  2.056830707780591  percent.
# cost =  21.74207187311616
# iteration =  10
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.89051169560377
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.843803915520764
# RUN  1 , total integrated cost mean =  2.843803915520764
# Improved over  1  iterations in  10.662997179999365  seconds by  1.6159000551371179  percent.
# cost =  25.6514656160957
# iteration =  11
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  96.0221937102111
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.823462666056209
# RUN  1 , total integrated cost mean =  2.823462666056209
# Improved over  1  iterations in  6.5554886129975785  seconds by  97.05957283732005  percent.
# cost =  25.728083365990408
# iteration =  12
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  44.689745306552105
# Gradient descend method:  None
# RUN  1 , total integrated cost =  48.054864692728756
# RUN  1 , total integrated cost mean =  48.054864692728756
# Improved over  1  iterations in  6.139927155003534  seconds by  -7.5299587480157015  percent.
# cost =  27.88105293266462
# iteration =  13
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.9102764945906885
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.7896163672307237
# RUN  1 , total integrated cost mean =  2.7896163672307237
# Improved over  1  iterations in  4.609052334999433  seconds by  4.146002195469563  percent.
# cost =  24.802418217550404
# iteration =  14
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  90.64881533154961
# Gradient descend method:  None
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  1 , total integrated cost =  2.7837129724130936
# RUN  1 , total integrated cost mean =  2.7837129724130936
# Improved over  1  iterations in  7.634576147000189  seconds by  96.92912371526134  percent.
# cost =  23.965268268244593
# iteration =  15
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  50.41308848339937
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.868241038196791
# RUN  1 , total integrated cost mean =  2.868241038196791
# Improved over  1  iterations in  5.568171284001437  seconds by  94.31052307152085  percent.
# cost =  22.8913969677257
# iteration =  16
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  87.26024680743606
# Gradient descend method:  None
# step size too small or too large
# RUN  1 , total integrated cost =  2.9144967170962626
# RUN  1 , total integrated cost mean =  2.9144967170962626
# Improved over  1  iterations in  8.298204172999249  seconds by  96.65999487312028  percent.
# cost =  26.166907513858167
# iteration =  17
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  39.34690086063416
# Gradient descend method:  None
# step size too small or too large
# RUN  1 , total integrated cost =  3.014546003125876
# RUN  1 , total integrated cost mean =  3.014546003125876
# Improved over  1  iterations in  7.046458522003377  seconds by  92.33854271317752  percent.
# cost =  27.546034909364796
# iteration =  18
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  47.79425018616339
# Gradient descend method:  None
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  1 , total integrated cost =  2.9984020931540334
# RUN  1 , total integrated cost mean =  2.9984020931540334
# Improved over  1  iterations in  12.212934317998588  seconds by  93.7264376332405  percent.
# cost =  25.09019363580704
# iteration =  19
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  88.19206897331762
# Gradient descend method:  None
# RUN  1 , total integrated cost =  46.071690931433686
# RUN  1 , total integrated cost mean =  46.071690931433686
# Improved over  1  iterations in  9.269918669000617  seconds by  47.759825267992504  percent.
# cost =  26.022861132227657
# iteration =  20
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.153831707987137
# Gradient descend method:  None
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  1 , total integrated cost =  2.7893255951921407
# RUN  1 , total integrated cost mean =  2.7893255951921407
# Improved over  1  iterations in  13.97102257500228  seconds by  11.557563831699653  percent.
# cost =  22.657871298692378
# iteration =  21
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  45.55986504411486
# Gradient descend method:  None
# step size too small or too large
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  1 , total integrated cost =  2.7992601031604663
# RUN  1 , total integrated cost mean =  2.7992601031604663
# Improved over  1  iterations in  11.888688777005882  seconds by  93.85586392661614  percent.
# cost =  20.705799605299905
# iteration =  22
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  49.576455927812795
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.8137750710003426
# RUN  1 , total integrated cost mean =  2.8137750710003426
# Improved over  1  iterations in  7.45621257199673  seconds by  94.32437228853668  percent.
# cost =  22.055816933393686
# iteration =  23
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.877555051940547
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.7000121047607926
# RUN  1 , total integrated cost mean =  2.7000121047607926
# Improved over  1  iterations in  6.09944330000144  seconds by  6.16992356271426  percent.
# cost =  21.230234900883243
# iteration =  24
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.7250788190864186
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.63058062652969
# RUN  1 , total integrated cost mean =  2.63058062652969
# Improved over  1  iterations in  6.3716255689942045  seconds by  3.467723278125547  percent.
# cost =  14.093209212829537
# iteration =  25
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  48.45315009617749
# Gradient descend method:  None
# step size too small or too large
# RUN  1 , total integrated cost =  2.6857299048993837
# RUN  1 , total integrated cost mean =  2.6857299048993837
# Improved over  1  iterations in  7.442869934995542  seconds by  94.45705821072868  percent.
# cost =  12.903404491712436
# iteration =  26
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.7351997695162322
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.5968453377832263
# RUN  1 , total integrated cost mean =  2.5968453377832263
# Improved over  1  iterations in  6.042553355000564  seconds by  5.058293484628223  percent.
# cost =  12.00395590192991
# iteration =  27
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.5914509472711145
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.5664690605299185
# RUN  1 , total integrated cost mean =  2.5664690605299185
# Improved over  1  iterations in  4.110953288996825  seconds by  0.9640115614575961  percent.
# cost =  6.076655895738986
# iteration =  28
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.604385812100429
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.4917996856290645
# RUN  1 , total integrated cost mean =  2.4917996856290645
# Improved over  1  iterations in  5.4110677580029005  seconds by  4.322943472824562  percent.
# cost =  4.625695703966573
# iteration =  29
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.5235398895898924
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.44903783743115
# RUN  1 , total integrated cost mean =  2.44903783743115
# Improved over  1  iterations in  5.895949682992068  seconds by  2.95228351515577  percent.
# cost =  3.871106466344169
# sigma =  0.02
# set cost params:  0.004152796306112395 0.0 1.0
# n =  1
# iteration =  1
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  629.6788076867957
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.501770148842911
# RUN  1 , total integrated cost mean =  3.501770148842911
# Improved over  1  iterations in  0.2685863789956784  seconds by  99.44387994226658  percent.
# cost =  104.18390774360846
# iteration =  2
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.25997768201937
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.6624667289862072
# RUN  1 , total integrated cost mean =  1.6624667289862072
# Improved over  1  iterations in  0.12062832299852744  seconds by  26.438798833591378  percent.
# cost =  182.20588116354975
# iteration =  3
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1.9637832427889588
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.7683709824255716
# RUN  1 , total integrated cost mean =  1.7683709824255716
# Improved over  1  iterations in  0.12815409600443672  seconds by  9.95080598029054  percent.
# cost =  207.9612630038604
# iteration =  4
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1.5751535346533707
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.486473154824468
# RUN  1 , total integrated cost mean =  1.486473154824468
# Improved over  1  iterations in  0.2650082750042202  seconds by  5.629951485866911  percent.
# cost =  233.8826211952344
# iteration =  5
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  459.1764022579526
# Gradient descend method:  None
# RUN  1 , total integrated cost =  327.93107817513226
# RUN  1 , total integrated cost mean =  327.93107817513226
# Improved over  1  iterations in  0.1407943650119705  seconds by  28.582767632969592  percent.
# cost =  190.28006896510192
# iteration =  6
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  6.859164736734303
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.7823419498498474
# RUN  1 , total integrated cost mean =  2.7823419498498474
# Improved over  1  iterations in  0.40399396599968895  seconds by  59.43614045382237  percent.
# cost =  262.4662564760822
# iteration =  7
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  4.675094199571612
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.3888063684769567
# RUN  1 , total integrated cost mean =  3.3888063684769567
# Improved over  1  iterations in  0.23093542899005115  seconds by  27.513623815591146  percent.
# cost =  5.316876250305757
# iteration =  8
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.463865205492235
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.649945041946852
# RUN  1 , total integrated cost mean =  2.649945041946852
# Improved over  1  iterations in  0.2288135420094477  seconds by  23.497454873672552  percent.
# cost =  5.910447118442646
# iteration =  9
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.2452230329432536
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.736046907532034
# RUN  1 , total integrated cost mean =  2.736046907532034
# Improved over  1  iterations in  0.21372360701207072  seconds by  15.690019460678556  percent.
# cost =  5.867025761759352
# iteration =  10
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.834644046700852
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.292042324446821
# RUN  1 , total integrated cost mean =  2.292042324446821
# Improved over  1  iterations in  0.20923350300290622  seconds by  19.141793936545483  percent.
# cost =  5.869568190737062
# iteration =  11
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.5205354831854234
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.5886316768781628
# RUN  1 , total integrated cost mean =  2.5886316768781628
# Improved over  1  iterations in  0.19281067000702024  seconds by  -2.7016558246059788  percent.
# cost =  5.7947246300374875
# iteration =  12
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.6225247150331055
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.258325191760181
# RUN  1 , total integrated cost mean =  2.258325191760181
# ...
# Improved over  1  iterations in  6.7687374189990805  seconds by  7.030043782671626  percent.
# cost =  33.68198793495491
# iteration =  17
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  44.301708973037904
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.874299271897461
# RUN  1 , total integrated cost mean =  7.874299271897461
# Improved over  1  iterations in  1.8326257709995843  seconds by  82.22574375925367  percent.
# cost =  21.17591291600129
# iteration =  18
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  46.14993732317835
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.315999027113383
# RUN  1 , total integrated cost mean =  6.315999027113383
# Improved over  1  iterations in  2.3704397230030736  seconds by  86.31417637063348  percent.
# cost =  22.357621231823238
# iteration =  19
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  8.681513050932
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.697503600531079
# RUN  1 , total integrated cost mean =  4.697503600531079
# Improved over  1  iterations in  1.5955208800005494  seconds by  45.8907269623147  percent.
# cost =  9.49789819157971
# iteration =  20
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  33.14012934317044
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.896166228378226
# RUN  1 , total integrated cost mean =  4.896166228378226
# Improved over  1  iterations in  3.086411730997497  seconds by  85.22586868120588  percent.
# cost =  9.778556663231267
# iteration =  21
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  4.667378670269089
# Gradient descend method:  None
# step size too small or too large
# RUN  1 , total integrated cost =  4.23836741994091
# RUN  1 , total integrated cost mean =  4.23836741994091
# Improved over  1  iterations in  3.3436812840081984  seconds by  9.19169582405975  percent.
# cost =  29.55750754778733
# iteration =  22
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  4.979584702853286
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.13505440695648
# RUN  1 , total integrated cost mean =  4.13505440695648
# Improved over  1  iterations in  1.7609732739947503  seconds by  16.95985400977098  percent.
# cost =  37.238890385112555
# iteration =  23
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  9.404772674012046
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.318654773705115
# RUN  1 , total integrated cost mean =  4.318654773705115
# Improved over  1  iterations in  2.9143355569976848  seconds by  54.08017903889653  percent.
# cost =  22.31531957203773
# iteration =  24
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  4.550247505424172
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.118048128455688
# RUN  1 , total integrated cost mean =  4.118048128455688
# Improved over  1  iterations in  3.5665583619993413  seconds by  9.498370724961134  percent.
# cost =  30.359095798430342
# iteration =  25
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  4.180867886974649
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.8655125708637925
# RUN  1 , total integrated cost mean =  3.8655125708637925
# Improved over  1  iterations in  6.343262227004743  seconds by  7.542819448883691  percent.
# cost =  30.10505790136854
# iteration =  26
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5.103496904648109
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.8053837314460077
# RUN  1 , total integrated cost mean =  3.8053837314460077
# Improved over  1  iterations in  3.4792720890109194  seconds by  25.43575899928183  percent.
# cost =  33.554327459803865
# iteration =  27
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  45.17112814345232
# Gradient descend method:  None
# RUN  1 , total integrated cost =  37.26084656131191
# RUN  1 , total integrated cost mean =  37.26084656131191
# Improved over  1  iterations in  2.213380404005875  seconds by  17.5118087753295  percent.
# cost =  26.231401182986556
# iteration =  28
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  10.481362771236434
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.539891839036256
# RUN  1 , total integrated cost mean =  4.539891839036256
# Improved over  1  iterations in  3.4763449010060867  seconds by  56.686053730580795  percent.
# cost =  28.483569614554796
# iteration =  29
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  4.1260346450932355
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.061758641542632
# RUN  1 , total integrated cost mean =  4.061758641542632
# Improved over  1  iterations in  3.8662339739967138  seconds by  1.5578154106641477  percent.
# cost =  38.48245208484866
# n =  30
# iteration =  1
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  280.83915329095635
# Gradient descend method:  None
# RUN  1 , total integrated cost =  175.74840573854127
# RUN  1 , total integrated cost mean =  175.74840573854127
# Improved over  1  iterations in  2.7997444270004053  seconds by  37.42026221092415  percent.
# cost =  129.8952036916806
# iteration =  2
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  145.37479720948042
# Gradient descend method:  None
# RUN  1 , total integrated cost =  33.212961498041984
# RUN  1 , total integrated cost mean =  33.212961498041984
# Improved over  1  iterations in  3.013813254001434  seconds by  77.15356297269108  percent.
# cost =  53.36103147135588
# iteration =  3
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  56.410314664241206
# Gradient descend method:  None
# RUN  1 , total integrated cost =  52.86232856176688
# RUN  1 , total integrated cost mean =  52.86232856176688
# Improved over  1  iterations in  2.997202776998165  seconds by  6.289605231937159  percent.
# cost =  44.246599757382384
# iteration =  4
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  56.37489527131503
# Gradient descend method:  None
# RUN  1 , total integrated cost =  37.494408324971715
# RUN  1 , total integrated cost mean =  37.494408324971715
# Improved over  1  iterations in  2.622964800990303  seconds by  33.490948152501815  percent.
# cost =  39.554900831192256
# iteration =  5
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  17.809839650034696
# Gradient descend method:  None
# RUN  1 , total integrated cost =  75.63617582300981
# RUN  1 , total integrated cost mean =  75.63617582300981
# Improved over  1  iterations in  4.939774026002851  seconds by  -324.6875733261442  percent.
# cost =  84.8793578321491
# iteration =  6
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  90.31698734366606
# Gradient descend method:  None
# step size too small or too large
# RUN  1 , total integrated cost =  16.21372192631573
# RUN  1 , total integrated cost mean =  16.21372192631573
# Improved over  1  iterations in  11.063923936992069  seconds by  82.04798188781393  percent.
# cost =  60.057329576672416
# iteration =  7
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  84.67247762667378
# Gradient descend method:  None
# step size too small or too large
# RUN  1 , total integrated cost =  2.5860010252773242
# RUN  1 , total integrated cost mean =  2.5860010252773242
# Improved over  1  iterations in  8.818961848999606  seconds by  96.94587769513588  percent.
# cost =  51.97821304181776
# iteration =  8
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  67.76238809951876
# Gradient descend method:  None
# step size too small or too large
# RUN  1 , total integrated cost =  29.368451348133796
# RUN  1 , total integrated cost mean =  29.368451348133796
# Improved over  1  iterations in  8.1610126660089  seconds by  56.65965711686249  percent.
# cost =  45.29573715538764
# iteration =  9
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  29.03965847295155
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.683873492479895
# RUN  1 , total integrated cost mean =  3.683873492479895
# Improved over  1  iterations in  7.357067660996108  seconds by  87.31433602805222  percent.
# cost =  43.77373890150598
# iteration =  10
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  40.16324336530925
# Gradient descend method:  None
# step size too small or too large
# RUN  1 , total integrated cost =  27.804436754741783
# RUN  1 , total integrated cost mean =  27.804436754741783
# Improved over  1  iterations in  9.794790628002374  seconds by  30.771435708407722  percent.
# cost =  41.156767298042546
# iteration =  11
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  32.5376444047816
# Gradient descend method:  None
# RUN  1 , total integrated cost =  28.64169325694855
# RUN  1 , total integrated cost mean =  28.64169325694855
# Improved over  1  iterations in  5.980565888006822  seconds by  11.973673015064719  percent.
# cost =  36.71429308021416
# iteration =  12
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  44.618588413843575
# Gradient descend method:  None
# RUN  1 , total integrated cost =  18.670860631210285
# RUN  1 , total integrated cost mean =  18.670860631210285
# Improved over  1  iterations in  8.535572795008193  seconds by  58.154524168188665  percent.
# cost =  37.31079611041924
# iteration =  13
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  32.08931672623341
# Gradient descend method:  None
# step size too small or too large
# step size too small or too large
# RUN  1 , total integrated cost =  18.120454406792547
# RUN  1 , total integrated cost mean =  18.120454406792547
# Improved over  1  iterations in  6.364872655991348  seconds by  43.53119275992919  percent.
# cost =  32.02498353053075
# iteration =  14
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  51.07160545983209
# Gradient descend method:  None
# RUN  1 , total integrated cost =  16.78002148117683
# RUN  1 , total integrated cost mean =  16.78002148117683
# Improved over  1  iterations in  9.77723719200003  seconds by  67.14412768093936  percent.
# cost =  32.117576424595484
# iteration =  15
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  29.84339432523632
# Gradient descend method:  None
# RUN  1 , total integrated cost =  19.48836832217055
# RUN  1 , total integrated cost mean =  19.48836832217055
# Improved over  1  iterations in  4.76198426100018  seconds by  34.697882855467626  percent.
# cost =  41.02546798843334
# iteration =  16
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  10.849317343516468
# Gradient descend method:  None
# RUN  1 , total integrated cost =  16.55005937635673
# RUN  1 , total integrated cost mean =  16.55005937635673
# Improved over  1  iterations in  16.097775614995044  seconds by  -52.544707213740196  percent.
# cost =  41.11625878512873
# iteration =  17
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  36.077392009849376
# Gradient descend method:  None
# step size too small or too large
# RUN  1 , total integrated cost =  32.43327170178236
# RUN  1 , total integrated cost mean =  32.43327170178236
# Improved over  1  iterations in  5.957093970006099  seconds by  10.100841843202375  percent.
# cost =  34.67811281250044
# iteration =  18
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  29.65796296540436
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14.686217224764468
# RUN  1 , total integrated cost mean =  14.686217224764468
# Improved over  1  iterations in  34.98855974999606  seconds by  50.481369061335215  percent.
# cost =  42.141442921660506
# iteration =  19
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  48.93391633793843
# Gradient descend method:  None
# RUN  1 , total integrated cost =  20.108959434081374
# RUN  1 , total integrated cost mean =  20.108959434081374
# Improved over  1  iterations in  6.236968888988486  seconds by  58.90588585796287  percent.
# cost =  40.86198726980255
# iteration =  20
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  45.734006031762824
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.382921880436681
# RUN  1 , total integrated cost mean =  6.382921880436681
# Improved over  1  iterations in  6.4691245010035345  seconds by  86.04337902084575  percent.
# cost =  11.10984819946388
# iteration =  21
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  17.914369125129003
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.6749532770213156
# RUN  1 , total integrated cost mean =  2.6749532770213156
# Improved over  1  iterations in  6.678220121000777  seconds by  85.06811343264619  percent.
# cost =  16.778554823062073
# iteration =  22
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  16.08308442879081
# Gradient descend method:  None
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  1 , total integrated cost =  2.6626122534705905
# RUN  1 , total integrated cost mean =  2.6626122534705905
# Improved over  1  iterations in  5.351129132002825  seconds by  83.44464169631436  percent.
# cost =  22.941713208383355
# iteration =  23
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  18.463372464711085
# Gradient descend method:  None
# RUN  1 , total integrated cost =  29.922665422127785
# RUN  1 , total integrated cost mean =  29.922665422127785
# Improved over  1  iterations in  8.239089358990896  seconds by  -62.0650045343491  percent.
# cost =  48.58113404630519
# iteration =  24
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  66.90675617606468
# Gradient descend method:  None
# RUN  1 , total integrated cost =  31.181720014873257
# RUN  1 , total integrated cost mean =  31.181720014873257
# Improved over  1  iterations in  8.756000042994856  seconds by  53.39525961650454  percent.
# cost =  54.4076318002115
# iteration =  25
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  55.418368694096316
# Gradient descend method:  None
# step size too small or too large
# step size too small or too large
# step size too small or too large
# RUN  1 , total integrated cost =  18.194555326013873
# RUN  1 , total integrated cost mean =  18.194555326013873
# Improved over  1  iterations in  9.30585117499868  seconds by  67.16872806840284  percent.
# cost =  49.483949755716466
# iteration =  26
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  48.60752736152451
# Gradient descend method:  None
# RUN  1 , total integrated cost =  13.813839456337238
# RUN  1 , total integrated cost mean =  13.813839456337238
# Improved over  1  iterations in  6.934840139001608  seconds by  71.58086369299328  percent.
# cost =  12.308376618695194
# iteration =  27
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.9708570889182817
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.4881873712745644
# RUN  1 , total integrated cost mean =  2.4881873712745644
# Improved over  1  iterations in  11.317909677003627  seconds by  37.338783150405895  percent.
# cost =  22.556266715556156
# iteration =  28
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.6116140580466918
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.534836192992829
# RUN  1 , total integrated cost mean =  5.534836192992829
# Improved over  1  iterations in  30.207303078001132  seconds by  -111.93162810329284  percent.
# cost =  26.6070595388465
# iteration =  29
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  16.688436267438796
# Gradient descend method:  None
# step size too small or too large
# RUN  1 , total integrated cost =  17.86727602774946
# RUN  1 , total integrated cost mean =  17.86727602774946
# Improved over  1  iterations in  13.331906186998822  seconds by  -7.063811979860148  percent.
# cost =  37.734754461732045

# %%
#len(sigma_array), 4, N_max, max_it

##### METHOD 1
method_ind = 0
step_method_ind = 1
step_m = 'S2'

for d in dict_list:
    print("Point = ", d['point'])
    aln.params.ext_exc_current = d['point'][0] * 5.
    aln.params.ext_inh_current = d['point'][1] * 5.
    
    max_it = d['cost'].shape[3]
    
    for s_ind in range(len(d['sigma'])):
        
        print("sigma = ", d['sigma'][s_ind])
        
        s = d['sigma'][s_ind]
        aln.params.sigma_ou = s
        c_p = d['cost_params'][s_ind]
        cost.setParams(c_p[0], c_p[1], c_p[2])
        aln.params.duration = dur
        zero_init = aln.getZeroControl()
        
        target_ = d['target'][s_ind].copy()
        target_[0,0,:int(trans_time * dur / aln.params.dt)] = -1000
        target_[0,1,:int(trans_time * dur / aln.params.dt)] = -1000
        
        if np.amin(d['cost'][s_ind, method_ind, step_method_ind, :, 0]) == 0.:
        
            setinit(d['init_vars'], aln)
            cost_final = 0.

            for n_ in range(noise_realizations_final):
                state_ = fo.updateState(aln, zero_init)
                cost_final += cost.numba_cost_precision_int(1, T, dt, d['cost_params'][s_ind][0],
                                                               state_, target_, list(prec_vars) )

            d['cost'][s_ind, :, :, :, 0] = cost_final/noise_realizations_final
            
        print('cost = ', d['cost'][s_ind, method_ind, step_method_ind, :, :])    
        
        for i_it in range(1, d['cost'].shape[4], 1):
            
            print("iteration = ", i_it)
        
            for n_ind in range(len(d['N_array'])):

                if d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it] > 0.:
                    continue
                    
                n_max = d['N_array'][n_ind]
                print("n max = ", n_max)

                aln.params.duration = dur
                control_init = aln.getZeroControl()

                if i_it <= init_it:
                    c_vars = d['init']
                else:
                    c_vars = [0,1]
                    
                n_ = 0
                control_sum = aln.getZeroControl()
                
                while n_ < n_max:
                
                    print('--------', n_)

                    aln.params.duration = dur
                    setinit(d['init_vars'], aln)

                    bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                        control_init, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_ = i_it,
                        tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                        t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                        control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                        noise_real=0, init_params = d['init_vars'], method_step=step_m)
                    
                    control_sum += bc[:,:,n_pre:-n_post]
                    n_ += 1

                control_init = control_sum / n_max
        
                aln.params.duration = dur
                setinit(d['init_vars'], aln)

                cost_final = 0.
                cs = cost.numba_cost_sparsity_int(1, 6, T, d['cost_params'][s_ind][2], dt, control_init)

                for j in range(noise_realizations_final):
                    state_ = fo.updateState(aln, control_init)
                    cost_final += cost.numba_cost_precision_int(1, T, dt, d['cost_params'][s_ind][0],
                                                                   state_, target_, list(prec_vars) )

                d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it] = (
                                cost_final / noise_realizations_final + cs )

                d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it] = cost_final/noise_realizations_final
                print('cost = ', d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it])
                
                file=open(dict_file, "wb")
                pickle.dump(dict_list, file)
                file.close()
# Out:
# Point =  [0.4   0.322]
# sigma =  0.01
# set cost params:  0.00829916864127671 0.0 1.0
# cost =  [[1388.82380225  125.24892512   79.81614237   78.50759025   89.63167552
#      3.96964058  145.30936948    1.83369018  412.4616809   304.82328726
#    119.5039298    35.71146291    2.62670492  412.5802109   485.96356996
#     91.09266056  575.00751118    9.55305002   14.02740648  254.009791
#      4.08363826   39.63091768  113.68325469   75.53081453   43.13376099
#      4.12351679  126.01968885  355.66220137  457.44259932  110.50818519]
#  [1388.82380225  371.67277597 1344.94471606    4.31892386    4.65043941
#     24.27145304  897.48575697  690.74388083  478.98381523  702.03499665
#    335.22783378    2.03925669 1254.61389204 1215.70644471    9.93545487
#    795.29345367  914.22821641 1260.8351424   951.98179038 1210.25173692
#     20.8800613  1208.45263154 1088.99847675  690.83559    1237.40751273
#   1222.1105764     2.58217631  952.70453978  956.50458853   81.08718726]
#  [1388.82380225  449.65426311   18.74245539    8.2901613   861.99939863
#      3.2670583   132.02993257 1260.48302209 1315.745233    182.89500599
#   1340.80287026 1235.91446474 1314.49465055  990.72531091 1215.44928616
#   1328.98004197    8.79428513 1205.13779505    7.79824538 1275.27070005
#    121.00828437 1295.01262893 1054.49345054 1107.71252995 1286.82693124
#   1276.73037417 1124.63830823 1320.3656908  1358.15548636 1370.92477313]
#  [1388.82380225  389.02279776   19.12291427  340.18489654  124.91361928
#     52.66204247    2.8618861  1349.18355393    3.49986217  868.17767149
#    121.62465444 1303.34220368 1232.84039993 1356.10576211 1303.96246526
#   1343.62519442 1357.5379671  1326.026263   1307.19889184  349.0242571
#   1351.48245597 1270.74815501 1335.41280822 1336.36756829 1357.84142194
#   1331.20850576 1355.12502852 1334.82267714    6.37163268 1357.36170516]]
# iteration =  1
# iteration =  2
# iteration =  3
# iteration =  4
# iteration =  5
# iteration =  6
# iteration =  7
# iteration =  8
# iteration =  9
# iteration =  10
# iteration =  11
# iteration =  12
# iteration =  13
# iteration =  14
# iteration =  15
# iteration =  16
# iteration =  17
# iteration =  18
# iteration =  19
# iteration =  20
# iteration =  21
# iteration =  22
# iteration =  23
# iteration =  24
# iteration =  25
# iteration =  26
# iteration =  27
# iteration =  28
# iteration =  29
# sigma =  0.02
# set cost params:  0.004152796306112395 0.0 1.0
# cost =  [[641.70641414  87.63407224  54.92269105  48.89754742   5.92184341
#    12.77934875 103.92911804  43.81409345 137.79142208 293.16097493
#    46.86088351  14.22636948  98.32488737  32.32008123   2.84575033
#    18.2268896  250.13175008 192.17764011  36.36119137 188.18469111
#   130.2576408   14.15300703 298.66136267  22.60530835  48.7142147
#    32.00071047  10.4526736  225.61843758   5.6940483  115.79869159]
#  [641.70641414 221.6369258  100.1594535  109.14167934 186.11219586
#     7.94042409  18.99461402 136.49335115 225.72660724 202.53351073
#   143.67692947  85.75606611  44.30290583 272.31960114 365.67903165
#   255.3261124  188.3794467  201.8396924   65.49019604  15.49313286
#   267.06779843 332.94897904  67.3599019  316.79696482 506.602993
#   487.92833988  51.79003096 102.57602006 281.34723404 432.88416478]
#  [641.70641414 149.07929224  12.23372829 232.4425599   74.4702609
#    11.66291136 417.24581027 523.83827414 324.02817259 518.23082834
#   406.76625413 485.86596206 490.28219027 589.09267662 218.97974687
#     3.4939234  484.3245401  587.71784503 605.88500823 617.1019575
#   368.76220142 180.47740421 101.200521   647.79519711 574.89338612
#   486.14048271 591.75285608 339.49545203 540.89050622 590.63831024]
#  [641.70641414 202.17793363 180.2056835   14.55394302   3.71940554
#            nan 153.07825944 596.25222489 577.10053271 473.65150812
#   481.40857637 581.10525982   6.93406205   3.08817648 563.70838813
#   606.60667059          nan 508.18837894 602.5814896    3.29919135
#   527.69269282 601.31853811 492.35726682 545.37220203 422.23673633
#   573.40877031 540.09044316  57.36606087  14.78922986 487.61778714]]
# iteration =  1
# iteration =  2
# iteration =  3
# iteration =  4
# iteration =  5
# n max =  30
# -------- 0
# interpolate adjoint :  True True True
# initial cost =  684.9538477828177
# RUN  0 , total integrated cost =  684.9538477828177
# Gradient descend method:  None
# RUN  1 , total integrated cost =  20.627849831168184
# RUN  2 , total integrated cost =  9.329418718976386
# RUN  3 , total integrated cost =  2.3262248152263894
# RUN  4 , total integrated cost =  2.285598018449366
# RUN  5 , total integrated cost =  1.7572594819827603
# RUN  5 , total integrated cost =  1.7572594819827603
# Improved over  5  iterations in  0.6767669119872153  seconds by  99.74344848376705  percent.
# -------- 1
# interpolate adjoint :  True True True
# initial cost =  681.2077241810217
# RUN  0 , total integrated cost =  681.2077241810217
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.5136188010985547
# RUN  2 , total integrated cost =  94.20901077821645
# RUN  3 , total integrated cost =  87.33693162228356
# RUN  4 , total integrated cost =  78.70303872661258
# RUN  5 , total integrated cost =  78.96092719754398
# RUN  5 , total integrated cost =  78.96092719754398
# Improved over  5  iterations in  0.9793041609809734  seconds by  88.40868586854702  percent.
# -------- 2
# interpolate adjoint :  True True True
# initial cost =  680.6628618087703
# RUN  0 , total integrated cost =  680.6628618087703
# Gradient descend method:  None
# RUN  1 , total integrated cost =  10.767785088369479
# RUN  2 , total integrated cost =  4.471695678968249
# RUN  3 , total integrated cost =  4.113985814572221
# RUN  4 , total integrated cost =  1.4186508832264346
# RUN  5 , total integrated cost =  113.3135431184321
# RUN  5 , total integrated cost =  113.3135431184321
# Improved over  5  iterations in  0.8483896089892369  seconds by  83.35247161607782  percent.
# -------- 3
# interpolate adjoint :  True True True
# initial cost =  641.7711147616819
# RUN  0 , total integrated cost =  641.7711147616819
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.0808102983983314
# RUN  2 , total integrated cost =  12.880867630973773
# RUN  3 , total integrated cost =  3.5187306945154058
# RUN  4 , total integrated cost =  2.7734784634489333
# RUN  5 , total integrated cost =  2.5934934749504985
# RUN  5 , total integrated cost =  2.5934934749504985
# Improved over  5  iterations in  1.1176446410245262  seconds by  99.59588497903749  percent.
# -------- 4
# interpolate adjoint :  True True True
# initial cost =  652.3905530059722
# RUN  0 , total integrated cost =  652.3905530059722
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.1654460434920952
# RUN  2 , total integrated cost =  0.9541335484521547
# RUN  3 , total integrated cost =  0.8841471801158709
# RUN  4 , total integrated cost =  19.846737967782385
# RUN  5 , total integrated cost =  14.752269489323119
# RUN  5 , total integrated cost =  14.752269489323119
# Improved over  5  iterations in  0.8749178739963099  seconds by  97.73873649436673  percent.
# -------- 5
# interpolate adjoint :  True True True
# initial cost =  639.4110940536099
# RUN  0 , total integrated cost =  639.4110940536099
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.004231903639996
# RUN  2 , total integrated cost =  12.487776069536594
# RUN  3 , total integrated cost =  5.589403709310225
# RUN  4 , total integrated cost =  4.334706844342257
# RUN  5 , total integrated cost =  4.399710549895881
# RUN  5 , total integrated cost =  4.399710549895881
# Improved over  5  iterations in  1.0072042749961838  seconds by  99.31191207177788  percent.
# -------- 6
# interpolate adjoint :  True True True
# initial cost =  632.0541533924694
# RUN  0 , total integrated cost =  632.0541533924694
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.628374454087767
# RUN  2 , total integrated cost =  12.50218947977946
# RUN  3 , total integrated cost =  5.504877902502636
# RUN  4 , total integrated cost =  5.530859573231382
# RUN  5 , total integrated cost =  4.86686303938054
# RUN  5 , total integrated cost =  4.86686303938054
# Improved over  5  iterations in  0.8129018459876534  seconds by  99.22999271292527  percent.
# -------- 7
# interpolate adjoint :  True True True
# initial cost =  712.5494083577196
# RUN  0 , total integrated cost =  712.5494083577196
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.9020142908124633
# RUN  2 , total integrated cost =  1.8379875551462201
# RUN  3 , total integrated cost =  1.7342709034835004
# RUN  4 , total integrated cost =  1.8762096539899005
# RUN  5 , total integrated cost =  1.8585492829926142
# RUN  5 , total integrated cost =  1.8585492829926142
# Improved over  5  iterations in  0.7299196050153114  seconds by  99.73916906516332  percent.
# -------- 8
# interpolate adjoint :  True True True
# initial cost =  666.070898289391
# RUN  0 , total integrated cost =  666.070898289391
# Gradient descend method:  None
# RUN  1 , total integrated cost =  65.60403913148673
# RUN  2 , total integrated cost =  51.56567473242331
# RUN  3 , total integrated cost =  52.922316759868124
# RUN  4 , total integrated cost =  5.91828209613856
# RUN  5 , total integrated cost =  4.797158228875752
# RUN  5 , total integrated cost =  4.797158228875752
# Improved over  5  iterations in  0.9169948540220503  seconds by  99.27978264157827  percent.
# -------- 9
# interpolate adjoint :  True True True
# initial cost =  580.294441853897
# RUN  0 , total integrated cost =  580.294441853897
# Gradient descend method:  None
# RUN  1 , total integrated cost =  42.877484936646184
# RUN  2 , total integrated cost =  25.11177269733577
# RUN  3 , total integrated cost =  11.937829484576788
# RUN  4 , total integrated cost =  8.407956465356131
# RUN  5 , total integrated cost =  8.15601971812517
# RUN  5 , total integrated cost =  8.15601971812517
# Improved over  5  iterations in  0.7129313460027333  seconds by  98.59450321597623  percent.
# -------- 10
# interpolate adjoint :  True True True
# initial cost =  704.3066281361638
# RUN  0 , total integrated cost =  704.3066281361638
# Gradient descend method:  None
# RUN  1 , total integrated cost =  8.459247056434217
# RUN  2 , total integrated cost =  2.959676783122263
# RUN  3 , total integrated cost =  3.8487324899834947
# RUN  4 , total integrated cost =  2.4529659408429656
# RUN  5 , total integrated cost =  2.31349184499706
# RUN  5 , total integrated cost =  2.31349184499706
# Improved over  5  iterations in  0.691475798987085  seconds by  99.67152206829014  percent.
# -------- 11
# interpolate adjoint :  True True True
# initial cost =  645.71127198865
# RUN  0 , total integrated cost =  645.71127198865
# Gradient descend method:  None
# RUN  1 , total integrated cost =  10.452109096982687
# RUN  2 , total integrated cost =  8.118188238772323
# RUN  3 , total integrated cost =  8.918324333852567
# RUN  4 , total integrated cost =  7.48150652113673
# RUN  5 , total integrated cost =  8.133526958158166
# RUN  5 , total integrated cost =  8.133526958158166
# Improved over  5  iterations in  0.7622490610228851  seconds by  98.74037711420019  percent.
# -------- 12
# interpolate adjoint :  True True True
# initial cost =  685.6350601021702
# RUN  0 , total integrated cost =  685.6350601021702
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.519244125286608
# RUN  2 , total integrated cost =  3.1029186044117796
# RUN  3 , total integrated cost =  2.0212018859290426
# RUN  4 , total integrated cost =  1.6884077635796118
# RUN  5 , total integrated cost =  1.6160847020810922
# RUN  5 , total integrated cost =  1.6160847020810922
# Improved over  5  iterations in  0.9055549450276885  seconds by  99.76429374807054  percent.
# -------- 13
# interpolate adjoint :  True True True
# initial cost =  639.979893180106
# RUN  0 , total integrated cost =  639.979893180106
# Gradient descend method:  None
# RUN  1 , total integrated cost =  8.395116574354068
# RUN  2 , total integrated cost =  2.3719253698981273
# RUN  3 , total integrated cost =  1.6356597336570922
# RUN  4 , total integrated cost =  1.6396421411274877
# RUN  5 , total integrated cost =  1.5252913989912789
# RUN  5 , total integrated cost =  1.5252913989912789
# Improved over  5  iterations in  0.9410565390135162  seconds by  99.76166573118228  percent.
# -------- 14
# interpolate adjoint :  True True True
# initial cost =  397.09421993185225
# RUN  0 , total integrated cost =  397.09421993185225
# Gradient descend method:  None
# RUN  1 , total integrated cost =  343.5377133675973
# RUN  2 , total integrated cost =  253.851994295886
# RUN  3 , total integrated cost =  42.264322821294414
# RUN  4 , total integrated cost =  3.754604938813668
# RUN  5 , total integrated cost =  2.53274347601735
# RUN  5 , total integrated cost =  2.53274347601735
# Improved over  5  iterations in  0.7122485940053593  seconds by  99.36218072465219  percent.
# -------- 15
# interpolate adjoint :  True True True
# initial cost =  674.2856069245925
# RUN  0 , total integrated cost =  674.2856069245925
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.454718774471763
# RUN  2 , total integrated cost =  3.1120860593147346
# RUN  3 , total integrated cost =  2.5112530436653024
# RUN  4 , total integrated cost =  2.2837742055548365
# RUN  5 , total integrated cost =  2.082684791813418
# Control only changes marginally.
# RUN  5 , total integrated cost =  2.082684791813418
# Improved over  5  iterations in  0.8673460150021128  seconds by  99.69112720627206  percent.
# -------- 16
# interpolate adjoint :  True True True
# initial cost =  653.6391811529527
# RUN  0 , total integrated cost =  653.6391811529527
# Gradient descend method:  None
# RUN  1 , total integrated cost =  9.110241319507022
# RUN  2 , total integrated cost =  7.9413391664747355
# RUN  3 , total integrated cost =  7.298789303383819
# RUN  4 , total integrated cost =  7.715619933438148
# RUN  5 , total integrated cost =  7.190556674378509
# RUN  5 , total integrated cost =  7.190556674378509
# Improved over  5  iterations in  0.6426077090145554  seconds by  98.89991957616508  percent.
# -------- 17
# interpolate adjoint :  True True True
# initial cost =  645.8527843413528
# RUN  0 , total integrated cost =  645.8527843413528
# Gradient descend method:  None
# RUN  1 , total integrated cost =  32.20550608379905
# RUN  2 , total integrated cost =  4.100107153274781
# RUN  3 , total integrated cost =  2.5960126336856693
# RUN  4 , total integrated cost =  1.9584305068658554
# RUN  5 , total integrated cost =  1.7649614518137782
# RUN  5 , total integrated cost =  1.7649614518137782
# Improved over  5  iterations in  0.720625925983768  seconds by  99.72672387661629  percent.
# -------- 18
# interpolate adjoint :  True True True
# initial cost =  673.629965916774
# RUN  0 , total integrated cost =  673.629965916774
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.137407771778788
# RUN  2 , total integrated cost =  2.696825864965549
# RUN  3 , total integrated cost =  2.965155892832284
# RUN  4 , total integrated cost =  3.3433245635210826
# RUN  5 , total integrated cost =  1.7011867654778259
# RUN  5 , total integrated cost =  1.7011867654778259
# Improved over  5  iterations in  0.7507557290082332  seconds by  99.74745975512496  percent.
# -------- 19
# interpolate adjoint :  True True True
# initial cost =  688.8959348508179
# RUN  0 , total integrated cost =  688.8959348508179
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.598601309479463
# RUN  2 , total integrated cost =  5.5594213218516355
# RUN  3 , total integrated cost =  6.687645161000869
# RUN  4 , total integrated cost =  3.1755173282652884
# RUN  5 , total integrated cost =  2.87882098753054
# RUN  5 , total integrated cost =  2.87882098753054
# Improved over  5  iterations in  0.9007928640057798  seconds by  99.58211090501587  percent.
# -------- 20
# interpolate adjoint :  True True True
# initial cost =  18.71783917481299
# RUN  0 , total integrated cost =  18.71783917481299
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.605980899588882
# RUN  2 , total integrated cost =  1.5710545321728495
# RUN  3 , total integrated cost =  1.4140541186280509
# RUN  4 , total integrated cost =  1.2608445863038649
# RUN  5 , total integrated cost =  1.4464748655761834
# RUN  5 , total integrated cost =  1.4464748655761834
# Improved over  5  iterations in  0.7815373099874705  seconds by  92.27221234210313  percent.
# -------- 21
# interpolate adjoint :  True True True
# initial cost =  661.9444090006772
# RUN  0 , total integrated cost =  661.9444090006772
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14.013279189977947
# RUN  2 , total integrated cost =  6.335271407988445
# RUN  3 , total integrated cost =  3.3899548914493893
# RUN  4 , total integrated cost =  2.468432447784782
# RUN  5 , total integrated cost =  2.5198651655756015
# RUN  5 , total integrated cost =  2.5198651655756015
# Improved over  5  iterations in  0.6898869200085755  seconds by  99.61932374814076  percent.
# -------- 22
# interpolate adjoint :  True True True
# initial cost =  0.8241081291792741
# RUN  0 , total integrated cost =  0.8241081291792741
# Gradient descend method:  None
# RUN  1 , total integrated cost =  0.8241081291792741
# Control only changes marginally.
# RUN  1 , total integrated cost =  0.8241081291792741
# Improved over  1  iterations in  0.257635471993126  seconds by  0.0  percent.
# -------- 23
# interpolate adjoint :  True True True
# initial cost =  651.8897628001356
# RUN  0 , total integrated cost =  651.8897628001356
# Gradient descend method:  None
# RUN  1 , total integrated cost =  9.981354949174523
# RUN  2 , total integrated cost =  1.8142650428997915
# RUN  3 , total integrated cost =  1.9280963833744629
# RUN  4 , total integrated cost =  1.4168083908467644
# RUN  5 , total integrated cost =  1.5594362696461845
# RUN  5 , total integrated cost =  1.5594362696461845
# Improved over  5  iterations in  0.6795312649919651  seconds by  99.76078221217223  percent.
# -------- 24
# interpolate adjoint :  True True True
# initial cost =  696.0452852525717
# RUN  0 , total integrated cost =  696.0452852525717
# Gradient descend method:  None
# RUN  1 , total integrated cost =  50.41039730833932
# RUN  2 , total integrated cost =  38.35286454271874
# RUN  3 , total integrated cost =  12.705575608135627
# RUN  4 , total integrated cost =  8.387881242674958
# RUN  5 , total integrated cost =  7.843952096268906
# RUN  5 , total integrated cost =  7.843952096268906
# Improved over  5  iterations in  0.7534830500080716  seconds by  98.8730687122717  percent.
# -------- 25
# interpolate adjoint :  True True True
# initial cost =  725.7018307184679
# RUN  0 , total integrated cost =  725.7018307184679
# Gradient descend method:  None
# RUN  1 , total integrated cost =  81.01043017658684
# RUN  2 , total integrated cost =  20.02972338400651
# RUN  3 , total integrated cost =  9.20016564267211
# RUN  4 , total integrated cost =  8.686958662863427
# RUN  5 , total integrated cost =  9.076345071828992
# RUN  5 , total integrated cost =  9.076345071828992
# Improved over  5  iterations in  0.8429163830005564  seconds by  98.74930106448221  percent.
# -------- 26
# interpolate adjoint :  True True True
# initial cost =  680.367927721115
# RUN  0 , total integrated cost =  680.367927721115
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.9563988411238071
# RUN  2 , total integrated cost =  29.98149215436431
# RUN  3 , total integrated cost =  4.0454806356832425
# RUN  4 , total integrated cost =  19.69774402892383
# RUN  5 , total integrated cost =  10.682397773880382
# RUN  5 , total integrated cost =  10.682397773880382
# Improved over  5  iterations in  0.801113022986101  seconds by  98.42990868048985  percent.
# -------- 27
# interpolate adjoint :  True True True
# initial cost =  672.7743271415994
# RUN  0 , total integrated cost =  672.7743271415994
# Gradient descend method:  None
# RUN  1 , total integrated cost =  20.414198208034723
# RUN  2 , total integrated cost =  16.15611839984609
# RUN  3 , total integrated cost =  14.973249199487508
# RUN  4 , total integrated cost =  5.182507217046742
# RUN  5 , total integrated cost =  5.0632479789783895
# RUN  5 , total integrated cost =  5.0632479789783895
# Improved over  5  iterations in  0.9826279359986074  seconds by  99.24740767078754  percent.
# -------- 28
# interpolate adjoint :  True True True
# initial cost =  677.3200110487412
# RUN  0 , total integrated cost =  677.3200110487412
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.905786275122948
# RUN  2 , total integrated cost =  2.5205721688937466
# RUN  3 , total integrated cost =  1.750037332854692
# RUN  4 , total integrated cost =  2.4946010302260997
# RUN  5 , total integrated cost =  2.071290787167711
# RUN  5 , total integrated cost =  2.071290787167711
# Improved over  5  iterations in  0.6266030900005717  seconds by  99.69419317997698  percent.
# -------- 29
# interpolate adjoint :  True True True
# initial cost =  687.4362770071648
# RUN  0 , total integrated cost =  687.4362770071648
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.507027478045384
# RUN  2 , total integrated cost =  5.325175755651008
# RUN  3 , total integrated cost =  6.465155563167054
# RUN  4 , total integrated cost =  3.96004282014948
# RUN  5 , total integrated cost =  3.322100559726678
# RUN  5 , total integrated cost =  3.322100559726678
# Improved over  5  iterations in  0.6370459120080341  seconds by  99.51674058078666  percent.
# cost =  4.2463182971824205
# iteration =  6
# iteration =  7
# iteration =  8
# iteration =  9
# iteration =  10
# iteration =  11
# iteration =  12
# iteration =  13
# iteration =  14
# iteration =  15
# iteration =  16
# n max =  30
# -------- 0
# interpolate adjoint :  True True True
# initial cost =  704.0962264923462
# RUN  0 , total integrated cost =  704.0962264923462
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.333242061799039
# RUN  2 , total integrated cost =  1.187891960472288
# RUN  3 , total integrated cost =  1.17342889638798
# RUN  4 , total integrated cost =  1.2834639469899307
# RUN  5 , total integrated cost =  1.7641714163350113
# RUN  6 , total integrated cost =  1.131825602785429
# RUN  7 , total integrated cost =  1.376114026594829
# RUN  8 , total integrated cost =  1.6734783416035923
# RUN  9 , total integrated cost =  2.0548404198032113
# RUN  10 , total integrated cost =  1.91087469047223
# RUN  11 , total integrated cost =  1.901117686886196
# RUN  12 , total integrated cost =  1.7543291695780392
# RUN  13 , total integrated cost =  1.7246744323027534
# RUN  14 , total integrated cost =  1.5608094136157709
# RUN  15 , total integrated cost =  1.7236086927729966
# RUN  16 , total integrated cost =  1.7229074278019887
# RUN  16 , total integrated cost =  1.7229074278019887
# Improved over  16  iterations in  4.643367846001638  seconds by  99.75530227787398  percent.
# -------- 1
# interpolate adjoint :  True True True
# initial cost =  674.6615895424751
# RUN  0 , total integrated cost =  674.6615895424751
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.4465199343954505
# RUN  2 , total integrated cost =  1.1299729646045165
# RUN  3 , total integrated cost =  1.3025279159191283
# RUN  4 , total integrated cost =  1.3542900751928109
# RUN  5 , total integrated cost =  1.1969237547091998
# RUN  6 , total integrated cost =  1.1484200143469345
# RUN  7 , total integrated cost =  1.0418928651279662
# RUN  8 , total integrated cost =  1.0532714411979949
# RUN  9 , total integrated cost =  1.0787452300225084
# RUN  10 , total integrated cost =  1.1624435014866448
# RUN  11 , total integrated cost =  1.1295176822972055
# RUN  12 , total integrated cost =  1.0780194106818035
# RUN  13 , total integrated cost =  0.9902771666345587
# RUN  14 , total integrated cost =  1.1306938533383977
# RUN  15 , total integrated cost =  1.473700960310763
# RUN  16 , total integrated cost =  1.1449705073582694
# RUN  16 , total integrated cost =  1.1449705073582694
# Improved over  16  iterations in  5.236649994010804  seconds by  99.83028965556869  percent.
# -------- 2
# interpolate adjoint :  True True True
# initial cost =  676.8367046680575
# RUN  0 , total integrated cost =  676.8367046680575
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.360229555386768
# RUN  2 , total integrated cost =  1.21461441398401
# RUN  3 , total integrated cost =  1.422356509670547
# RUN  4 , total integrated cost =  1.5206590418705048
# RUN  5 , total integrated cost =  1.8181624352051307
# RUN  6 , total integrated cost =  1.520496881135705
# RUN  7 , total integrated cost =  1.6432220012897694
# RUN  8 , total integrated cost =  1.634957312388054
# RUN  9 , total integrated cost =  1.6356577598820738
# RUN  10 , total integrated cost =  2.0118185257896206
# RUN  11 , total integrated cost =  2.0501605348467744
# RUN  12 , total integrated cost =  1.85414396032362
# RUN  13 , total integrated cost =  1.8408331817254293
# RUN  14 , total integrated cost =  1.7705336749119642
# RUN  15 , total integrated cost =  2.1009627154382615
# RUN  16 , total integrated cost =  1.9477948382292545
# RUN  16 , total integrated cost =  1.9477948382292545
# Improved over  16  iterations in  4.537096703017596  seconds by  99.71222086142853  percent.
# -------- 3
# interpolate adjoint :  True True True
# initial cost =  612.5224690670469
# RUN  0 , total integrated cost =  612.5224690670469
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.2490169247216265
# RUN  2 , total integrated cost =  1.2013692009090344
# RUN  3 , total integrated cost =  1.1769308651687869
# RUN  4 , total integrated cost =  1.1028142558380631
# RUN  5 , total integrated cost =  1.0415847722432847
# RUN  6 , total integrated cost =  1.0852410936269408
# RUN  7 , total integrated cost =  1.2607286385840712
# RUN  8 , total integrated cost =  1.0993109012465463
# RUN  9 , total integrated cost =  0.937837997966118
# RUN  10 , total integrated cost =  1.2379479523317647
# RUN  11 , total integrated cost =  1.215859369910028
# RUN  12 , total integrated cost =  1.2682255148412833
# RUN  13 , total integrated cost =  1.1627788155394772
# RUN  14 , total integrated cost =  1.197159898770323
# RUN  15 , total integrated cost =  1.547477354612773
# RUN  16 , total integrated cost =  1.482227090214495
# RUN  16 , total integrated cost =  1.482227090214495
# Improved over  16  iterations in  4.368410360009875  seconds by  99.75801261748452  percent.
# -------- 4
# interpolate adjoint :  True True True
# initial cost =  694.7053587231849
# RUN  0 , total integrated cost =  694.7053587231849
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.5128056098503917
# RUN  2 , total integrated cost =  1.1973963099870968
# RUN  3 , total integrated cost =  1.2238005304484607
# RUN  4 , total integrated cost =  1.1763995569909895
# RUN  5 , total integrated cost =  1.053115747764967
# RUN  6 , total integrated cost =  1.5104597092114915
# RUN  7 , total integrated cost =  1.430553393239487
# RUN  8 , total integrated cost =  1.3681008122719236
# RUN  9 , total integrated cost =  1.98613653327548
# RUN  10 , total integrated cost =  1.9657819225168391
# RUN  11 , total integrated cost =  2.0265021863904407
# RUN  12 , total integrated cost =  1.9068447853088517
# RUN  13 , total integrated cost =  1.8525505068062094
# RUN  14 , total integrated cost =  1.7615698948376919
# RUN  15 , total integrated cost =  1.7089849358052023
# RUN  16 , total integrated cost =  1.6965547278585533
# RUN  16 , total integrated cost =  1.6965547278585533
# Improved over  16  iterations in  4.3700041490083095  seconds by  99.75578787372869  percent.
# -------- 5
# interpolate adjoint :  True True True
# initial cost =  674.2806687783302
# RUN  0 , total integrated cost =  674.2806687783302
# Gradient descend method:  None
# RUN  1 , total integrated cost =  0.982615927411783
# RUN  2 , total integrated cost =  1.2957780235242446
# RUN  3 , total integrated cost =  1.8593031977886734
# RUN  4 , total integrated cost =  1.8468130337009647
# RUN  5 , total integrated cost =  1.2709720923248027
# RUN  6 , total integrated cost =  1.184846717433351
# RUN  7 , total integrated cost =  4.638866787412236
# RUN  8 , total integrated cost =  2.2881572128691863
# RUN  9 , total integrated cost =  2.162413383893009
# RUN  10 , total integrated cost =  1.9206336646813573
# RUN  11 , total integrated cost =  1.9015437586145383
# RUN  12 , total integrated cost =  1.9158676485517705
# RUN  13 , total integrated cost =  1.7987932077268618
# RUN  14 , total integrated cost =  1.7596090053257658
# RUN  15 , total integrated cost =  1.5853511915815335
# RUN  16 , total integrated cost =  1.5683428008508817
# RUN  16 , total integrated cost =  1.5683428008508817
# Improved over  16  iterations in  4.363465931004612  seconds by  99.76740504756091  percent.
# -------- 6
# interpolate adjoint :  True True True
# initial cost =  538.3560183099459
# RUN  0 , total integrated cost =  538.3560183099459
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.297552364522263
# RUN  2 , total integrated cost =  3.8883743859846325
# RUN  3 , total integrated cost =  2.1220959216642443
# RUN  4 , total integrated cost =  2.737066794861273
# RUN  5 , total integrated cost =  2.4152683489420026
# RUN  6 , total integrated cost =  2.214452010089964
# RUN  7 , total integrated cost =  1.7379912295154791
# RUN  8 , total integrated cost =  1.6404921890245698
# RUN  9 , total integrated cost =  1.5326817911417103
# RUN  10 , total integrated cost =  1.2247649677989783
# RUN  11 , total integrated cost =  1.4578300225300262
# RUN  12 , total integrated cost =  1.2618427871626337
# RUN  13 , total integrated cost =  1.5046500722356742
# RUN  14 , total integrated cost =  1.2609398382777048
# RUN  15 , total integrated cost =  1.1042315731618007
# RUN  16 , total integrated cost =  1.1012756206776564
# RUN  16 , total integrated cost =  1.1012756206776564
# Improved over  16  iterations in  4.295108274993254  seconds by  99.79543729739757  percent.
# -------- 7
# interpolate adjoint :  True True True
# initial cost =  692.2986307066521
# RUN  0 , total integrated cost =  692.2986307066521
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.0809107496634354
# RUN  2 , total integrated cost =  1.1078643039500773
# RUN  3 , total integrated cost =  0.9259552965752968
# RUN  4 , total integrated cost =  0.8306442614035798
# RUN  5 , total integrated cost =  1.1872463543793128
# RUN  6 , total integrated cost =  1.0280327082976843
# RUN  7 , total integrated cost =  0.8652751890017291
# RUN  8 , total integrated cost =  0.991504768535612
# RUN  9 , total integrated cost =  0.8899139493755489
# RUN  10 , total integrated cost =  0.9026988269978775
# RUN  11 , total integrated cost =  0.9070254152143221
# RUN  12 , total integrated cost =  1.022258664559101
# RUN  13 , total integrated cost =  0.9474087263663505
# Control only changes marginally.
# RUN  13 , total integrated cost =  0.9474087263663505
# Improved over  13  iterations in  3.6103837529954035  seconds by  99.86315028163507  percent.
# -------- 8
# interpolate adjoint :  True True True
# initial cost =  699.8739571118942
# RUN  0 , total integrated cost =  699.8739571118942
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.8099425921170034
# RUN  2 , total integrated cost =  1.4272785293372103
# RUN  3 , total integrated cost =  1.6715944179322544
# Control only changes marginally.
# RUN  3 , total integrated cost =  1.6715944179322544
# Improved over  3  iterations in  0.887117992999265  seconds by  99.76115779120711  percent.
# -------- 9
# interpolate adjoint :  True True True
# initial cost =  630.662114098487
# RUN  0 , total integrated cost =  630.662114098487
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.336835488227956
# RUN  2 , total integrated cost =  2.8636587066126937
# RUN  3 , total integrated cost =  2.3573771960247014
# RUN  4 , total integrated cost =  2.699509557374102
# RUN  5 , total integrated cost =  2.136961974799424
# RUN  6 , total integrated cost =  3.1379814727600444
# RUN  7 , total integrated cost =  2.2033954001338842
# RUN  8 , total integrated cost =  2.177703427315617
# RUN  9 , total integrated cost =  1.9504024977261643
# RUN  10 , total integrated cost =  1.984530833276542
# RUN  11 , total integrated cost =  1.8765615906599868
# RUN  12 , total integrated cost =  1.897891615026002
# RUN  13 , total integrated cost =  1.776717846838114
# RUN  14 , total integrated cost =  1.7745414645172968
# RUN  15 , total integrated cost =  1.9854118911947456
# RUN  16 , total integrated cost =  1.8257039772484163
# RUN  16 , total integrated cost =  1.8257039772484163
# Improved over  16  iterations in  4.159085043997038  seconds by  99.71050996461739  percent.
# -------- 10
# interpolate adjoint :  True True True
# initial cost =  683.8558626188442
# RUN  0 , total integrated cost =  683.8558626188442
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.224482604557246
# RUN  2 , total integrated cost =  1.0894493318166725
# RUN  3 , total integrated cost =  1.3047573930793455
# RUN  4 , total integrated cost =  1.5434986127131807
# RUN  5 , total integrated cost =  1.2536532553849928
# RUN  6 , total integrated cost =  2.7955485918694714
# RUN  7 , total integrated cost =  2.026931217192072
# RUN  8 , total integrated cost =  2.110950036595917
# RUN  9 , total integrated cost =  1.7476580978699823
# RUN  10 , total integrated cost =  1.7242923914348012
# RUN  11 , total integrated cost =  1.7288505346002394
# RUN  12 , total integrated cost =  1.6860828222321207
# RUN  13 , total integrated cost =  1.5144473439740216
# RUN  14 , total integrated cost =  1.563723246125332
# RUN  15 , total integrated cost =  1.5557708167954458
# RUN  16 , total integrated cost =  1.476748631862898
# RUN  16 , total integrated cost =  1.476748631862898
# Improved over  16  iterations in  4.554545737017179  seconds by  99.78405557185579  percent.
# -------- 11
# interpolate adjoint :  True True True
# initial cost =  679.3537018190987
# RUN  0 , total integrated cost =  679.3537018190987
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.777840891182851
# RUN  2 , total integrated cost =  5.255490439864995
# RUN  3 , total integrated cost =  3.6618964820225584
# RUN  4 , total integrated cost =  3.228854666523824
# RUN  5 , total integrated cost =  3.237060053324071
# RUN  6 , total integrated cost =  3.0131085359029113
# RUN  7 , total integrated cost =  3.079221156114585
# RUN  8 , total integrated cost =  3.076138885083002
# RUN  9 , total integrated cost =  3.140424893139826
# RUN  10 , total integrated cost =  3.210339765578989
# RUN  11 , total integrated cost =  3.127323455869046
# RUN  12 , total integrated cost =  3.0830207782467514
# RUN  13 , total integrated cost =  3.0753000769045356
# RUN  14 , total integrated cost =  3.0407059464482833
# RUN  15 , total integrated cost =  3.0652101603449267
# RUN  16 , total integrated cost =  3.0283670904953968
# RUN  16 , total integrated cost =  3.0283670904953968
# Improved over  16  iterations in  3.731456114008324  seconds by  99.55422821979384  percent.
# -------- 12
# interpolate adjoint :  True True True
# initial cost =  701.3404245117349
# RUN  0 , total integrated cost =  701.3404245117349
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.3066277601009197
# RUN  2 , total integrated cost =  2.062031190180271
# RUN  3 , total integrated cost =  1.9659862464142677
# RUN  4 , total integrated cost =  1.8588910807407564
# RUN  5 , total integrated cost =  1.7859215630486545
# RUN  6 , total integrated cost =  1.815168584805006
# RUN  7 , total integrated cost =  1.6679746907110558
# RUN  8 , total integrated cost =  1.4980187916662953
# RUN  9 , total integrated cost =  1.5408368620029838
# RUN  10 , total integrated cost =  1.523470757771672
# RUN  11 , total integrated cost =  1.9132917489249157
# RUN  12 , total integrated cost =  1.6167329731786997
# RUN  13 , total integrated cost =  1.8731253434086677
# RUN  14 , total integrated cost =  1.614221569192477
# RUN  15 , total integrated cost =  1.6091886027165467
# RUN  16 , total integrated cost =  1.8235624342973058
# RUN  16 , total integrated cost =  1.8235624342973058
# Improved over  16  iterations in  4.37377625098452  seconds by  99.73998897388998  percent.
# -------- 13
# interpolate adjoint :  True True True
# initial cost =  651.9295714515342
# RUN  0 , total integrated cost =  651.9295714515342
# Gradient descend method:  None
# RUN  1 , total integrated cost =  0.9741134073639094
# RUN  2 , total integrated cost =  2.791020874562481
# RUN  3 , total integrated cost =  2.3371550308137055
# RUN  4 , total integrated cost =  2.2931184102498374
# RUN  5 , total integrated cost =  2.5390913492300715
# RUN  6 , total integrated cost =  2.5571723409471616
# RUN  7 , total integrated cost =  2.4839878251078513
# RUN  8 , total integrated cost =  2.5311925438211027
# RUN  9 , total integrated cost =  2.2341278802317537
# RUN  10 , total integrated cost =  1.9583673855177348
# RUN  11 , total integrated cost =  1.9974349672403418
# RUN  12 , total integrated cost =  3.5783642331292556
# RUN  13 , total integrated cost =  3.0340285284717767
# RUN  14 , total integrated cost =  2.9203794221048702
# RUN  15 , total integrated cost =  2.954650580036059
# RUN  16 , total integrated cost =  2.893840018515375
# RUN  16 , total integrated cost =  2.893840018515375
# Improved over  16  iterations in  4.887072557001375  seconds by  99.5561115578678  percent.
# -------- 14
# interpolate adjoint :  True True True
# initial cost =  684.078676352592
# RUN  0 , total integrated cost =  684.078676352592
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.2175688474925566
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_32687/484839595.py in <module>
#      72                     setinit(d['init_vars'], aln)
#      73
# ---> 74                     bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
#      75                         control_init, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_ = i_it,
#      76                         tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
#
# ~/Promotion/neurolib_dev_optControl/neurolib/models/model.py in A1(self, control_, target_state_, c_scheme_, u_mat_, u_scheme_, max_iteration_, tolerance_, startStep_, max_control_, min_control_, t_sim_, t_sim_pre_, t_sim_post_, CGVar, line_search_, control_variables_, prec_variables_, separate_comp, transition_time_, noise_real, init_params, method, method_step, numerical)
#     673                 if self.params.N == 1:
#     674                     if noise_real == 0:
# --> 675                         return opti1_rate_control.A1(self, control_, target_state_, c_scheme_, u_mat_, u_scheme_, max_iteration_,
#     676                                                     tolerance_, startStep_, max_control_, min_control_, t_sim_, t_sim_pre_, t_sim_post_, CGVar,
#     677                                                     line_search_, control_variables_, prec_variables_, separate_comp, transition_time_)
#
# ~/Promotion/neurolib_dev_optControl/neurolib/utils/A1_aln_rate_control.py in A1(model, control_, target_state, c_scheme_, u_mat_, u_scheme_, max_iteration_, tolerance_, startStep_, cntrl_max_, cntrl_min_, t_sim_, t_sim_pre_, t_sim_post_, CGVar, line_search_, control_variables_, prec_variables_, separate_comp, transition_time_)
#     407                 d_inh[:,2:,:] = 0.
#     408
# --> 409                 s_inh, tc_inh, startstep_inh_ = line_search_func(model, N, n_control_vars, T, dt, state1_[:,:2,:], target_state_,
#     410                              best_control_, d_inh, ip_, ie_, is_, start_step_ = startstep_inh_, max_it_ = 500,
#     411                              max_control_ = cntrl_max_, min_control_ = cntrl_min_, tolerance_ = tolerance_step, variables_ = prec_variables, grad_ = grad1_)
#
# ~/Promotion/neurolib_dev_optControl/neurolib/utils/func_optimize.py in step_size(model, N, V, T, dt, state_, target_, control_, dir_, ip_, ie_, is_, start_step_, max_it_, bisec_factor_, max_control_, min_control_, tolerance_, substep_, variables_, alg, control_parameter, grad_, noise_real, init_vars, startind_)
#     235                 #print(init_vars)
#     236                 set_init(model, init_vars, model.init_vars, model.state_vars, startind_)
# --> 237             state1_ = updateState(model, test_control_)
#     238             cost1_int_ = cost.f_int(N, V, T, dt, state1_, target_, test_control_, ip_, ie_, is_, v_ = variables_)
#     239         else:
#
# ~/Promotion/neurolib_dev_optControl/neurolib/utils/func_optimize.py in updateState(model, control_)
#       8     state_ = model.getZeroState()
#       9     output_vars = model.output_vars
# ---> 10     model.run(control = control_)
#      11     for i in range(len(output_vars)):
#      12         state_[:,i,:] = model[output_vars[i]][:,:]
#
# ~/Promotion/neurolib_dev_optControl/neurolib/models/model.py in run(self, inputs, chunkwise, chunksize, bold, append, append_outputs, continue_run, control)
#     188         if chunkwise is False:
#     189             if self.name == 'aln':
# --> 190                 self.integrate(append_outputs=append, simulate_bold=bold, control=cntrl)
#     191             else:
#     192                 self.integrate(append_outputs=append, simulate_bold=bold)
#
# ~/Promotion/neurolib_dev_optControl/neurolib/models/model.py in integrate(self, append_outputs, simulate_bold, control)
#     232         #print("before integration")
#     233         if self.name == 'aln':
# --> 234             t, *variables = self.integration(self.params, control=control)
#     235         else:
#     236             t, *variables = self.integration(self.params)
#
# ~/Promotion/neurolib_dev_optControl/neurolib/models/aln/timeIntegration.py in timeIntegration(params, control)
#     262
#     263     # Save the noise in the rates array to save memory
# --> 264     rates_exc[:, startind:] = np.random.standard_normal((N, len(t)))
#     265     rates_inh[:, startind:] = np.random.standard_normal((N, len(t)))
#     266
#
# KeyboardInterrupt:

# %%
#len(sigma_array), 4, N_max, max_it

##### METHOD 2
method_ind = 1
step_method_ind = 1

for d in dict_list:
    print("Point = ", d['point'])
    aln.params.ext_exc_current = d['point'][0] * 5.
    aln.params.ext_inh_current = d['point'][1] * 5.
    
    max_it = d['cost'].shape[3]
    
    for s_ind in range(len(d['sigma'])):
        
        print("sigma = ", d['sigma'][s_ind])
        
        s = d['sigma'][s_ind]
        aln.params.sigma_ou = s
        c_p = d['cost_params'][s_ind]
        cost.setParams(c_p[0], c_p[1], c_p[2])
        
        target_ = d['target'][s_ind].copy()
        target_[0,0,:int(trans_time * dur / aln.params.dt)] = -1000
        target_[0,1,:int(trans_time * dur / aln.params.dt)] = -1000
                
        for n_ind in range(len(d['N_array'])):
            
            n_ = d['N_array'][n_ind]
            
            print("n = ", n_)
            aln.params.duration = dur
            control_init = aln.getZeroControl()
        
            for i_it in range(1, d['cost'].shape[4], 1):
                
                if d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it] > 0.:
                    continue
                
                print("iteration = ", i_it)

                if i_it <= init_it:
                    c_vars = d['init']
                else:
                    c_vars = [0,1]
                    
                aln.params.duration = dur
                setinit(d['init_vars'], aln)
                
                bc, bs, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                    control_init, d['target'][s_ind], c_scheme, u_mat, u_scheme, max_iteration_ = i_it,
                    tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                    t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                    control_variables_ = c_vars, prec_variables_ = prec_vars, transition_time_ = trans_time,
                    noise_real=n_, init_params = d['init_vars'], method='M2', method_step=step_m)
            
                aln.params.duration = dur
                setinit(d['init_vars'], aln)

                cost_final = 0.
                cs = cost.numba_cost_sparsity_int(1, 6, T, d['cost_params'][s_ind][2], dt, control_init)

                for j in range(noise_realizations_final):
                    state_ = fo.updateState(aln, control_init)
                    cost_final += cost.numba_cost_precision_int(1, T, dt, d['cost_params'][s_ind][0],
                                                                   state_, target_, list(prec_vars) )

                d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it] = (
                                cost_final / noise_realizations_final + cs )
                print('cost = ', d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it])
                
                file=open(dict_file, "wb")
                pickle.dump(dict_list, file)
                file.close()
# Out:
# Point =  [0.4   0.322]
# sigma =  0.01
# set cost params:  0.00829916864127671 0.0 1.0
# n =  1
# iteration =  1
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1343.4665832013984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  41.18131534624246
# RUN  1 , total integrated cost mean =  41.18131534624246
# Improved over  1  iterations in  19.4022758359788  seconds by  96.93469745647786  percent.
# cost =  43.463981424568374
# iteration =  2
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  23.464434587404057
# Gradient descend method:  None
# RUN  1 , total integrated cost =  27.0131625386667
# RUN  1 , total integrated cost mean =  27.0131625386667
# Improved over  1  iterations in  0.17564478699932806  seconds by  -15.12385878314592  percent.
# cost =  34.83264747469119
# iteration =  3
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  14.526199780970117
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.139967022804454
# RUN  1 , total integrated cost mean =  7.139967022804454
# Improved over  1  iterations in  0.20064925399492495  seconds by  50.84766056874636  percent.
# cost =  122.82826743914154
# iteration =  4
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1251.1812460777728
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.4651972614768045
# RUN  1 , total integrated cost mean =  3.4651972614768045
# Improved over  1  iterations in  0.15600167200318538  seconds by  99.72304593979972  percent.
# cost =  4.483931132946809
# iteration =  5
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  4.876855988128428
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.892940369016123
# RUN  1 , total integrated cost mean =  3.892940369016123
# Improved over  1  iterations in  0.134021842997754  seconds by  20.17520348165742  percent.
# cost =  3.252556643220326
# iteration =  6
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.314898623559455
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.9822068261367574
# RUN  1 , total integrated cost mean =  2.9822068261367574
# Improved over  1  iterations in  0.18026676299632527  seconds by  10.036258576905183  percent.
# cost =  3.332357418319598
# iteration =  7
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.057297286489063
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.9077919052048142
# RUN  1 , total integrated cost mean =  2.9077919052048142
# Improved over  1  iterations in  0.3107522409991361  seconds by  4.890115918558166  percent.
# cost =  3.0037498098142543
# iteration =  8
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.1750230701395292
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.0354682464304994
# RUN  1 , total integrated cost mean =  3.0354682464304994
# Improved over  1  iterations in  0.2490675610024482  seconds by  4.395395580634215  percent.
# cost =  2.991321854334304
# iteration =  9
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.9634482208490995
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.106853939609048
# RUN  1 , total integrated cost mean =  3.106853939609048
# Improved over  1  iterations in  0.2395267119864002  seconds by  -4.839150478521233  percent.
# cost =  2.9360507601604793
# iteration =  10
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.9070107334623705
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.7490324564912156
# RUN  1 , total integrated cost mean =  2.7490324564912156
# Improved over  1  iterations in  0.3461607680073939  seconds by  5.434389187238949  percent.
# cost =  2.93070060089158
# iteration =  11
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.0842597056070042
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.7728026057803565
# RUN  1 , total integrated cost mean =  2.7728026057803565
# Improved over  1  iterations in  0.3317848390142899  seconds by  10.09827736816186  percent.
# cost =  2.986801311119176
# iteration =  12
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.6902946390005096
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.9745564825856583
# RUN  1 , total integrated cost mean =  2.9745564825856583
# Improved over  1  iterations in  0.24582395600737073  seconds by  -10.566197451545946  percent.
# cost =  3.082045347441547
# iteration =  13
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.092349944075028
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.7356310389961647
# RUN  1 , total integrated cost mean =  2.7356310389961647
# Improved over  1  iterations in  0.188836703018751  seconds by  11.535528369366475  percent.
# cost =  2.9769305998544953
# iteration =  14
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.1777812856120975
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.73837427608054
# RUN  1 , total integrated cost mean =  2.73837427608054
# Improved over  1  iterations in  0.19705794600304216  seconds by  13.827478043282639  percent.
# cost =  2.7485864712156802
# iteration =  15
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.6309176890925365
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.8034737986400753
# RUN  1 , total integrated cost mean =  2.8034737986400753
# Improved over  1  iterations in  0.25317436299519613  seconds by  -6.558780240937807  percent.
# cost =  2.8801852644028307
# iteration =  16
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.757098592142499
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.7207911164454672
# RUN  1 , total integrated cost mean =  2.7207911164454672
# Improved over  1  iterations in  0.3431241220096126  seconds by  1.316872592097539  percent.
# cost =  2.8751272620039328
# iteration =  17
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.9334177424784857
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.7125049846308897
# RUN  1 , total integrated cost mean =  2.7125049846308897
# Improved over  1  iterations in  0.25902913900790736  seconds by  7.5309000367927155  percent.
# cost =  2.731576024836025
# iteration =  18
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.8607061823664415
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.7609796136992024
# RUN  1 , total integrated cost mean =  2.7609796136992024
# Improved over  1  iterations in  0.30449005399714224  seconds by  3.48608218774649  percent.
# cost =  3.096266476765027
# iteration =  19
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.23674865765673
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.5913414679223186
# RUN  1 , total integrated cost mean =  2.5913414679223186
# Improved over  1  iterations in  0.21923707000678405  seconds by  19.93998478095172  percent.
# cost =  3.113253066639765
# iteration =  20
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.5927485324598423
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.61899302484871
# RUN  1 , total integrated cost mean =  2.61899302484871
# Improved over  1  iterations in  0.21399919301620685  seconds by  -1.0122266799228896  percent.
# cost =  3.0960835529470216
# iteration =  21
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.5759199769696424
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.686451217947822
# RUN  1 , total integrated cost mean =  2.686451217947822
# Improved over  1  iterations in  0.3375948850007262  seconds by  -4.290942341625481  percent.
# cost =  3.091567356833635
# iteration =  22
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.480934269714763
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.5946716387417252
# RUN  1 , total integrated cost mean =  2.5946716387417252
# Improved over  1  iterations in  0.1920520119892899  seconds by  -4.584457170646388  percent.
# cost =  3.032800640557375
# iteration =  23
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.6972925606732234
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.723253794011254
# RUN  1 , total integrated cost mean =  2.723253794011254
# Improved over  1  iterations in  0.2042557419918012  seconds by  -0.9624923049337468  percent.
# cost =  3.733642826400463
# iteration =  24
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.8672837114591974
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.591348390999487
# RUN  1 , total integrated cost mean =  2.591348390999487
# Improved over  1  iterations in  0.20857152799726464  seconds by  9.623579255757832  percent.
# cost =  4.022006892043827
# iteration =  25
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.4080948752236413
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.4724997683661867
# RUN  1 , total integrated cost mean =  2.4724997683661867
# Improved over  1  iterations in  0.24525359200197272  seconds by  -2.6745164322715453  percent.
# cost =  4.835042407900071
# iteration =  26
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.4407031326820734
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.367369504405463
# RUN  1 , total integrated cost mean =  2.367369504405463
# Improved over  1  iterations in  0.23269927100045606  seconds by  3.004610732646725  percent.
# cost =  4.406346169672503
# iteration =  27
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.4866418302470046
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.427264122533372
# RUN  1 , total integrated cost mean =  2.427264122533372
# Improved over  1  iterations in  0.25261130201397464  seconds by  2.3878673233665637  percent.
# cost =  4.639198325746068
# iteration =  28
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.6964196265342006
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.4456637367702303
# RUN  1 , total integrated cost mean =  2.4456637367702303
# Improved over  1  iterations in  0.1922535549965687  seconds by  9.299587026307009  percent.
# cost =  4.836035005762276
# iteration =  29
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.5600956682839606
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.5112976613270757
# RUN  1 , total integrated cost mean =  2.5112976613270757
# Improved over  1  iterations in  0.2151642879762221  seconds by  1.9061009149550472  percent.
# cost =  5.736864980154503
# n =  2
# iteration =  1
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1377.7536433604942
# Gradient descend method:  None
# RUN  1 , total integrated cost =  209.31980693437112
# RUN  1 , total integrated cost mean =  209.31980693437112
# Improved over  1  iterations in  0.28665148600703105  seconds by  84.80716723609477  percent.
# cost =  227.53023507808078
# iteration =  2
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  401.91725781687586
# Gradient descend method:  None
# RUN  1 , total integrated cost =  34.2040841684354
# RUN  1 , total integrated cost mean =  34.2040841684354
# Improved over  1  iterations in  0.2737620339903515  seconds by  91.48976972170234  percent.
# cost =  35.76713961352472
# iteration =  3
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  34.40739506875025
# Gradient descend method:  None
# RUN  1 , total integrated cost =  8.69993948907518
# RUN  1 , total integrated cost mean =  8.69993948907518
# Improved over  1  iterations in  0.3725986139907036  seconds by  74.71491383845938  percent.
# cost =  10.23622892122518
# iteration =  4
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  4.18516566690956
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.584798642659072
# RUN  1 , total integrated cost mean =  4.584798642659072
# Improved over  1  iterations in  0.26878593099536374  seconds by  -9.54879705023987  percent.
# cost =  11.665022016987498
# iteration =  5
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.3327847731348483
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.0603446183227074
# RUN  1 , total integrated cost mean =  3.0603446183227074
# Improved over  1  iterations in  0.2565998589852825  seconds by  -31.188468544834848  percent.
# cost =  12.558510849325558
# iteration =  6
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.1035378973278744
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.117381856308075
# RUN  1 , total integrated cost mean =  3.117381856308075
# Improved over  1  iterations in  0.5994266650232021  seconds by  -48.19708550381182  percent.
# cost =  11.594543574646353
# iteration =  7
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.0558575711565332
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.11986938472535
# RUN  1 , total integrated cost mean =  2.11986938472535
# Improved over  1  iterations in  0.4533698599843774  seconds by  -3.1136307527766434  percent.
# cost =  11.470289901964518
# iteration =  8
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.3259033521239294
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.2643475551420353
# RUN  1 , total integrated cost mean =  2.2643475551420353
# Improved over  1  iterations in  0.43147848098305985  seconds by  2.6465328804691524  percent.
# cost =  13.53061713384379
# iteration =  9
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1.9641483766045882
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.0159633623785655
# RUN  1 , total integrated cost mean =  2.0159633623785655
# Improved over  1  iterations in  0.44310284801758826  seconds by  -2.638038265904825  percent.
# cost =  11.337821841815474
# iteration =  10
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1.9463929168417282
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.1453235156743498
# RUN  1 , total integrated cost mean =  2.1453235156743498
# Improved over  1  iterations in  0.46091256602085195  seconds by  -10.220474864623526  percent.
# cost =  14.987599598790455
# iteration =  11
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1.9629213534712693
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.0174231722679172
# RUN  1 , total integrated cost mean =  2.0174231722679172
# Improved over  1  iterations in  0.5055417719995603  seconds by  -2.776566605700509  percent.
# cost =  13.035809282366788
# iteration =  12
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.0708207967004895
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.9310111685071463
# RUN  1 , total integrated cost mean =  1.9310111685071463
# Improved over  1  iterations in  0.4527559200068936  seconds by  6.751411247950898  percent.
# cost =  13.918291023062515
# iteration =  13
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1.9293367217208957
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.236376425361861
# RUN  1 , total integrated cost mean =  2.236376425361861
# Improved over  1  iterations in  0.5870961250038818  seconds by  -15.914262149486149  percent.
# cost =  15.649838803205263
# iteration =  14
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.0740470264177606
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.0378043363475156
# RUN  1 , total integrated cost mean =  2.0378043363475156
# Improved over  1  iterations in  0.4822251019941177  seconds by  1.747438202153134  percent.
# cost =  14.501045048684054
# iteration =  15
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.203320386468395
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.9679057260672586
# RUN  1 , total integrated cost mean =  1.9679057260672586
# Improved over  1  iterations in  0.4038761779956985  seconds by  10.68454056191402  percent.
# cost =  14.304008925962059
# iteration =  16
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.1167098184459525
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.0114191963839168
# RUN  1 , total integrated cost mean =  2.0114191963839168
# Improved over  1  iterations in  0.4520830270193983  seconds by  4.974258688861667  percent.
# cost =  17.880238230442114
# iteration =  17
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.408859355757662
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.000971001923305
# RUN  1 , total integrated cost mean =  2.000971001923305
# Improved over  1  iterations in  0.4549859589897096  seconds by  16.932842212619065  percent.
# cost =  14.538950631124262
# iteration =  18
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1.9818193341392933
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.9968007593825587
# RUN  1 , total integrated cost mean =  1.9968007593825587
# Improved over  1  iterations in  0.4152063750079833  seconds by  -0.7559430360372374  percent.
# cost =  17.790690177160023
# iteration =  19
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1.962421122712196
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.9578526829620895
# RUN  1 , total integrated cost mean =  1.9578526829620895
# Improved over  1  iterations in  0.4718904590117745  seconds by  0.23279609545745927  percent.
# cost =  16.785398254383008
# iteration =  20
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.0924045807556677
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.9031195107420658
# RUN  1 , total integrated cost mean =  2.9031195107420658
# Improved over  1  iterations in  0.4171121819817927  seconds by  -38.74561054983019  percent.
# cost =  17.190581052961583
# iteration =  21
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.090759912588961
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.0614612539677486
# RUN  1 , total integrated cost mean =  2.0614612539677486
# Improved over  1  iterations in  0.4625694580026902  seconds by  1.4013401751582393  percent.
# cost =  18.424844402097797
# iteration =  22
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.2127955256618943
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.8876688876859546
# RUN  1 , total integrated cost mean =  1.8876688876859546
# Improved over  1  iterations in  0.3959664510039147  seconds by  14.693026725941493  percent.
# cost =  19.698804462309987
# iteration =  23
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1.8348759570992763
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.8765393636208094
# RUN  1 , total integrated cost mean =  1.8765393636208094
# Improved over  1  iterations in  0.5040495450084563  seconds by  -2.2706388603727703  percent.
# cost =  19.765592333376397
# iteration =  24
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1.9481293394641783
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.962700812336578
# RUN  1 , total integrated cost mean =  1.962700812336578
# Improved over  1  iterations in  0.38610606401925907  seconds by  -0.7479725589681436  percent.
# cost =  22.06621828941325
# iteration =  25
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1.9359226830738139
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.932602513563002
# RUN  1 , total integrated cost mean =  1.932602513563002
# Improved over  1  iterations in  0.29990632997942157  seconds by  0.17150320825520282  percent.
# cost =  19.99034927083402
# iteration =  26
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1.8865123820741405
# Gradient descend method:  None
# step size too small or too large
# step size too small or too large
# RUN  1 , total integrated cost =  1.8426615996908011
# RUN  1 , total integrated cost mean =  1.8426615996908011
# Improved over  1  iterations in  0.8538396449876018  seconds by  2.3244364998615765  percent.
# cost =  22.387904222337497
# iteration =  27
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1.850371709260843
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.9328373980033497
# RUN  1 , total integrated cost mean =  1.9328373980033497
# Improved over  1  iterations in  0.5124526180152316  seconds by  -4.456709337360593  percent.
# cost =  19.398848744090685
# iteration =  28
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1.9833192554086463
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.706023412581063
# RUN  1 , total integrated cost mean =  2.706023412581063
# Improved over  1  iterations in  0.3007876350020524  seconds by  -36.439123716545055  percent.
# cost =  21.81180972055277
# iteration =  29
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1.7946743899848658
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.843255171062479
# RUN  1 , total integrated cost mean =  1.843255171062479
# Improved over  1  iterations in  0.3120445880049374  seconds by  -2.7069412339484558  percent.
# cost =  24.38111327602918
# n =  10
# iteration =  1
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1391.504170672727
# Gradient descend method:  None
# RUN  1 , total integrated cost =  397.3958786591437
# RUN  1 , total integrated cost mean =  397.3958786591437
# Improved over  1  iterations in  0.8804744220105931  seconds by  71.44127290204085  percent.
# cost =  199.34774364066865
# iteration =  2
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  213.2545783040423
# Gradient descend method:  None
# RUN  1 , total integrated cost =  151.08803916230812
# RUN  1 , total integrated cost mean =  151.08803916230812
# Improved over  1  iterations in  1.1274738179927226  seconds by  29.151326848937245  percent.
# cost =  36.48076813610171
# iteration =  3
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  35.58558785710786
# Gradient descend method:  None
# RUN  1 , total integrated cost =  15.153989249828706
# RUN  1 , total integrated cost mean =  15.153989249828706
# Improved over  1  iterations in  1.4300181309808977  seconds by  57.41537469978355  percent.
# cost =  7.737939563536535
# iteration =  4
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7.720539830816567
# Gradient descend method:  None
# RUN  1 , total integrated cost =  9.870866266924578
# RUN  1 , total integrated cost mean =  9.870866266924578
# Improved over  1  iterations in  1.409555566002382  seconds by  -27.852021791597707  percent.
# cost =  6.389224363279409
# iteration =  5
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  6.3388339706843615
# Gradient descend method:  None
# RUN  1 , total integrated cost =  8.101577329432356
# RUN  1 , total integrated cost mean =  8.101577329432356
# Improved over  1  iterations in  1.604479220986832  seconds by  -27.80863747023939  percent.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_32687/205458463.py in <module>
#      63
#      64                 for j in range(noise_realizations_final):
# ---> 65                     state_ = fo.updateState(aln, control_init)
#      66                     cost_final += cost.numba_cost_precision_int(1, T, dt, d['cost_params'][s_ind][0],
#      67                                                                    state_, target_, list(prec_vars) )
#
# ~/Promotion/neurolib_dev_optControl/neurolib/utils/func_optimize.py in updateState(model, control_)
#       8     state_ = model.getZeroState()
#       9     output_vars = model.output_vars
# ---> 10     model.run(control = control_)
#      11     for i in range(len(output_vars)):
#      12         state_[:,i,:] = model[output_vars[i]][:,:]
#
# ~/Promotion/neurolib_dev_optControl/neurolib/models/model.py in run(self, inputs, chunkwise, chunksize, bold, append, append_outputs, continue_run, control)
#     188         if chunkwise is False:
#     189             if self.name == 'aln':
# --> 190                 self.integrate(append_outputs=append, simulate_bold=bold, control=cntrl)
#     191             else:
#     192                 self.integrate(append_outputs=append, simulate_bold=bold)
#
# ~/Promotion/neurolib_dev_optControl/neurolib/models/model.py in integrate(self, append_outputs, simulate_bold, control)
#     232         #print("before integration")
#     233         if self.name == 'aln':
# --> 234             t, *variables = self.integration(self.params, control=control)
#     235         else:
#     236             t, *variables = self.integration(self.params)
#
# ~/Promotion/neurolib_dev_optControl/neurolib/models/aln/timeIntegration.py in timeIntegration(params, control)
#     286     # ------------------------------------------------------------------------
#     287
# --> 288     return timeIntegration_njit_elementwise(
#     289         dt,
#     290         duration,
#
# KeyboardInterrupt:

# %%
for step_method_ind in [0,1]:
    for method_ind in [1,2,3]:
        for d in dict_list:
            for s_ind in range(len(d['sigma'])):
                for n_ind in range(len(d['N_array'])):
                    for i_it in range(1, d['cost'].shape[4], 1):

                        d['cost'][s_ind, method_ind, step_method_ind, n_ind, i_it] = 0.
