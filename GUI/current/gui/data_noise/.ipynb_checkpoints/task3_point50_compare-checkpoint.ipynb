# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import sys
import pickle
import matplotlib
import ipyparams

path = os.getcwd().split(os.sep + 'GUI')[0]
if path not in sys.path:
    print("not here")
    sys.path.append(path)

from neurolib.models.aln import ALNModel
from neurolib.utils import plotFunctions as plotFunc
from neurolib.utils import func_optimize as fo
from neurolib.utils import costFunctions as cost
import neurolib.dashboard.functions as functions
import neurolib.dashboard.data as data
import neurolib.dashboard.layout as layout
    
# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2 

#path = os.path.join(os.getcwd(), "plots")

cmap_ = layout.getcolormap()
darkgrey, midgrey, lightgrey, color_bi_updown, color_LC, color_bi_uposc = layout.getcolors_rgba()
exc_red = cmap_(3)
inh_blue=cmap_(0)
green = cmap_(2)
# Out:
# not here

# %%
aln = ALNModel()
N = aln.params.N

data.set_parameters(aln)

state_vars = aln.state_vars
init_vars = aln.init_vars

##############################################################
def setinit(init_vars_, model):
    state_vars = model.state_vars
    init_vars = model.init_vars
    for iv in range(len(init_vars)):
        for sv in range(len(state_vars)):
            if state_vars[sv] in init_vars[iv]:
                #print("set init vars ", )
                if model.params[init_vars[iv]].ndim == 2:
                    model.params[init_vars[iv]][0,:] = init_vars_[sv]
                else:
                    model.params[init_vars[iv]][0] = init_vars_[sv]
                    
##############################################################               
def setmaxmincontrol(max_c_c, min_c_c, max_c_r, min_c_r):
    import numpy as np
    
    max_cntrl = np.zeros(( 6 ))
    min_cntrl = np.zeros(( 6 ))
    
    max_cntrl[0] = max_c_c
    min_cntrl[0] = min_c_c
    max_cntrl[1] = max_c_c
    min_cntrl[1] = min_c_c
    max_cntrl[2] = max_c_r
    min_cntrl[2] = min_c_r
    max_cntrl[3] = max_c_r
    min_cntrl[3] = min_c_r
    max_cntrl[4] = max_c_r
    min_cntrl[4] = min_c_r
    max_cntrl[5] = max_c_r
    min_cntrl[5] = min_c_r
            
    return max_cntrl, min_cntrl

# %%
##### LOAD POINTS
data_file = '..' + os.sep + 'bi.pickle'
with open(data_file,'rb') as f:
    load_array= pickle.load(f)
exc = load_array[0]
inh = load_array[1]

savepath = (os.getcwd().split('neurolib')[0] + 'Talks_Conf_Workshops_Schools' + os.sep + '22' + os.sep + 'FRANCE22' + 
     os.sep + 'FENS' + os.sep + 'poster' + os.sep + 'print' + os.sep + 'images')

# %%
bestControl = [None] * len(exc)

# %%
initVars = [None] * len(exc)
cost_uncontrolled = [None] * len(exc)

# %%
dur_pre = 10
dur_post = 10
dur = 200.
dt = aln.params.dt
T = int(1 + dur / dt)

max_it = 10
init_it = 10
prec_vars = [0,1]
trans_time = 0.9

n_pre = int(np.around(dur_pre/aln.params.dt + 1.,1))
n_post = int(np.around(dur_post/aln.params.dt + 1.,1))

tol = 1e-32
start_step = 10.
c_scheme = np.zeros(( 1,1 ))
c_scheme[0,0] = 1.
u_mat = np.identity(1)
u_scheme = np.array([[1.]])

maxC = [5., -5., 0.18, 0.]
n_dur = int(np.around(dur/aln.params.dt + 1.,1))
max_cntrl, min_cntrl = setmaxmincontrol(maxC[0], maxC[1], maxC[2], maxC[3])

nb = ipyparams.notebook_name
print('nb = ', nb)

case = str(nb[4])

read_file = '..' + os.sep + 'data_final_2' + os.sep + 'control_' + case + '.pickle'
    
i_range = [50]
i = 50
# Out:
# nb =  task3_point50_compare.ipynb

# %%
if os.path.isfile(read_file) :
    print("file found")
    
    with open(read_file,'rb') as f:
        load_array = pickle.load(f)

    bestControl = load_array[0]
    
init_control_noisefree = [None] * len(exc)
for i in i_range:
    init_control_noisefree[i] = bestControl[i].copy()
# Out:
# file found

# %%
sigma_ou_array = [0.01, 0.03, 0.1]
noise_realizations_array = [0,10,50]
noise_realizations_final = 10000

# %%
cost_final_mean = np.zeros(( 3,3 ))
target = [None] * 3
control_ = [ [None] * 3, [None] * 3, [None] * 3 ]
cost_ = [ [None] * 3, [None] * 3, [None] * 3 ]
cost_final = [ [None] * 3, [None] * 3, [None] * 3 ]

stable_state = np.zeros(( 3, 2,2,2, 2))

# %%
# get init vars without noise
aln = ALNModel()
data.set_parameters(aln)
aln.params.duration = 3000.

# initial without noise
control0 = aln.getZeroControl()
control0[0,0,:500] = 5.
aln.params.ext_exc_current = exc[i] * 5.
aln.params.ext_inh_current = inh[i] * 5.

aln.run(control=control0)

init_state_vars = np.zeros(( len(state_vars) ))
for j in range(len(state_vars)):
    if aln.state[state_vars[j]].size == 1:
        init_state_vars[j] = aln.state[state_vars[j]][0]
    else:
        init_state_vars[j] = aln.state[state_vars[j]][0,-1]

initVars[i] = init_state_vars

stable_state[0,0,0,0,0] = aln.rates_exc[0,-1]
stable_state[0,0,0,1,0] = aln.rates_inh[0,-1]

control0 = aln.getZeroControl()
control0[0,0,:500] = -5.

aln.params.duration = 3000.
aln.run(control=control0)
stable_state[0,0,1,0,0] = aln.rates_exc[0,-1]
stable_state[0,0,1,1,0] = aln.rates_inh[0,-1]

aln.params.duration = dur
target_det = aln.getZeroTarget()
target_det[:,0,:] = aln.rates_exc[0,-1]
target_det[:,1,:] = aln.rates_inh[0,-1]

print('exc initial , final ', stable_state[0,0,0,0,0], stable_state[0,0,1,0,0])
print('inh initial , final ', stable_state[0,0,0,1,0], stable_state[0,0,1,1,0])
# Out:
# exc initial , final  39.92863296490006 2.339651407613867e-06
# inh initial , final  107.75907077321249 41.918142394968584

# %%
# get target states with noise

i = 50

print("------- ", i, exc[i], inh[i])
aln.params.ext_exc_current = exc[i] * 5.
aln.params.ext_inh_current = inh[i] * 5.
# Out:
# -------  50 0.47500000000000014 0.6000000000000003

# %%
for i_sigma in range(len(sigma_ou_array)):
    
    sigma_ou = sigma_ou_array[i_sigma]
    aln.params.sigma_ou = sigma_ou
    

    aln.params.duration = dur
    control0 = aln.getZeroControl()
    control0[0,0,:500] = 5.

    target_rates_e = []
    target_rates_i = []

    stateswitchcount = 0

    for j in range(noise_realizations_final):
        aln.params.duration = dur
        aln.run(control=control0)
        if np.amin(aln.rates_exc[0,1000:]) < 1.:
            print("fell in down state, repeat")
            j -= 1
            stateswitchcount += 1
            if stateswitchcount > 0.1 * noise_realizations_final:
                break
            continue
        target_rates_e.append(aln.rates_exc[0,1000:])
        target_rates_i.append(aln.rates_inh[0,1000:])

    stable_state[i_sigma,1,1,0,0] = np.mean(target_rates_e)
    stable_state[i_sigma,1,1,1,0] = np.mean(target_rates_i)
    stable_state[i_sigma,1,1,0,1] = np.std(target_rates_e)
    stable_state[i_sigma,1,1,1,1] = np.std(target_rates_i)


    aln.params.duration = 300.
    control0 = aln.getZeroControl()
    control0[0,0,:500] = -5.

    target_rates_e = []
    target_rates_i = []

    stateswitchcount = 0

    for j in range(noise_realizations_final):
        aln.params.duration = 300.
        aln.run(control=control0)
        if np.amin(aln.rates_exc[0,1000:]) > 3.:
            print("fell in up state, repeat")
            j -= 1
            stateswitchcount += 1
            if stateswitchcount > 0.1 * noise_realizations_final:
                break
            continue
        target_rates_e.append(aln.rates_exc[0,1000:])
        target_rates_i.append(aln.rates_inh[0,1000:])

    aln.params.duration = dur
    target[i_sigma] = aln.getZeroTarget()
    target[i_sigma][:,0,:] = np.mean(target_rates_e)
    target[i_sigma][:,1,:] = np.mean(target_rates_i)

    stable_state[i_sigma,1,0,0,0] = np.mean(target_rates_e)
    stable_state[i_sigma,1,0,1,0] = np.mean(target_rates_i)
    stable_state[i_sigma,1,0,0,1] = np.std(target_rates_e)
    stable_state[i_sigma,1,0,1,1] = np.std(target_rates_i)

# %%
w_p = np.zeros((3))
for i_sigma in range(len(sigma_ou_array)):
    w_p[i_sigma] = 1. / ( ( stable_state[i_sigma,1,1,0,1] + stable_state[i_sigma,1,1,1,1] ) * (1. - trans_time) * dur )
w_e = 0.
w_s = 1.

aln.params.duration = dur
zero_init = aln.getZeroControl()

# %%
max_it = 10
init_it = 5
min_it = 8
i = 50
factor = [1.09, 1.21, 2.0]


for i_sigma in range(3):
    cost.setParams(w_p[i_sigma], w_e, w_s)
    for i_noise in range(3):
        
        if i_noise in []:
            continue
            
        if i_sigma in []:
            continue

        noise_realizations = noise_realizations_array[i_noise]
        sigma_ou = sigma_ou_array[i_sigma]
        aln.params.sigma_ou = sigma_ou
        
        aln.params.duration = dur
        
        n_ = 0
        control_sum = np.zeros(( init_control_noisefree[i][:,:,:2201].shape ))
        
        print(noise_realizations)
        
        if i_noise != 0.:
            while n_  < noise_realizations:
            #while n_  < 30:
                
                print('--------', n_)

                setinit(initVars[i], aln)

                bestControl, bestState, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                    zero_init, target[i_sigma], c_scheme, u_mat, u_scheme, max_iteration_ = init_it,
                    tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                    t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                    control_variables_ = [0], prec_variables_ = [0], transition_time_ = trans_time,
                    noise_real=0, init_params = initVars[i])
                
                if np.isnan(c_[-1]):
                    continue

                max_jump = 0.
                for v_ in range(bestControl.shape[1]):
                    for t_ in range(1, bestControl.shape[2]):
                        diff = np.abs(bestControl[0,v_,t_] - bestControl[0,v_,t_-1])
                        if  diff > max_jump:
                            max_jump = diff

                if max_jump > 0.5:
                    continue

                control_init = bestControl[:,:,100:-100].copy()
                setinit(initVars[i], aln)
                aln.params.duration = dur

                bestControl, bestState, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                    control_init, target[i_sigma], c_scheme, u_mat, u_scheme, max_iteration_ = max_it,
                    tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                    t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                    control_variables_ = [0,1], prec_variables_ = [0], transition_time_ = trans_time,
                    noise_real=0, init_params = initVars[i])
                
                if c_[min_it] == 0:
                    continue

                max_jump = 0.
                for v_ in range(bestControl.shape[1]):
                    for t_ in range(1, bestControl.shape[2]):
                        diff = np.abs(bestControl[0,v_,t_] - bestControl[0,v_,t_-1])
                        if  diff > max_jump:
                            max_jump = diff

                if max_jump > 0.5:
                    continue

                control_init = bestControl[:,:,100:-100].copy()
                setinit(initVars[i], aln)
                aln.params.duration = dur

                bestControl, bestState, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                    control_init, target[i_sigma], c_scheme, u_mat, u_scheme, max_iteration_ = max_it,
                    tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                    t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                    control_variables_ = [0,1], prec_variables_ = [0,1], transition_time_ = trans_time,
                    noise_real=0, init_params = initVars[i])
                
                if c_[min_it] == 0:
                    continue
                    
                if np.isnan(c_[-1]):
                    continue

                max_jump = 0.
                for v_ in range(bestControl.shape[1]):
                    for t_ in range(1, bestControl.shape[2]):
                        diff = np.abs(bestControl[0,v_,t_] - bestControl[0,v_,t_-1])
                        if  diff > max_jump:
                            max_jump = diff

                if max_jump > 0.5:
                    continue
                    
                control_sum += bestControl
                            
                n_ += 1
    

            control_[i_sigma][i_noise] = control_sum / noise_realizations
            
        else:
            control_[i_sigma][i_noise] = factor[i_sigma] * init_control_noisefree[i][:,:,1400:3601]
        
        aln.params.duration = dur
        setinit(initVars[i], aln)

        init_control = aln.getZeroControl()           
        init_control[:,:,:] = control_[i_sigma][i_noise][:,:,100:-100]
        T = int(1 + dur/aln.params.dt)
        dt = aln.params.dt

        target_ = target[i_sigma].copy()
        target_[0,0,:int(trans_time * dur / aln.params.dt)] = -1000
        target_[0,1,:int(trans_time * dur / aln.params.dt)] = -1000

        cost_final = np.zeros(( noise_realizations_final ))

        for n_ in range(noise_realizations_final):
            state_ = fo.updateState(aln, init_control)
            cost_final[n_] += cost.numba_cost_precision_int(1,T,dt,w_p[i_sigma],state_, target_, list(prec_vars) )
            cost_final[n_] += cost.numba_cost_sparsity_int(1, 6, T, w_s, dt, init_control)

        cost_final_mean[i_sigma, i_noise] = np.mean(cost_final)
        print('mean = ', cost_final_mean[i_sigma, i_noise])
# Out:
# set cost params:  0.05214890598130851 0.0 1.0
# 0
# mean =  3.0100167316298188
# 20
# -------- 0
# interpolate adjoint :  True True True
# initial cost =  818.4501320192044
# RUN  0 , total integrated cost =  818.4501320192044
# Gradient descend method:  None
# RUN  1 , total integrated cost =  9.643455572654767
# RUN  2 , total integrated cost =  9.211930219586028
# RUN  3 , total integrated cost =  8.204584714973441
# RUN  4 , total integrated cost =  6.165567406066667
# RUN  5 , total integrated cost =  5.648098362042176
# RUN  5 , total integrated cost =  5.648098362042176
# Improved over  5  iterations in  0.171050027012825  seconds by  99.30990317661654  percent.
# interpolate adjoint :  True True True
# initial cost =  5.660183989518804
# RUN  0 , total integrated cost =  5.660183989518804
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.9968843217564483
# RUN  2 , total integrated cost =  3.931852940257117
# RUN  3 , total integrated cost =  3.901354030906611
# RUN  4 , total integrated cost =  3.767676765386736
# RUN  5 , total integrated cost =  3.5099087314635793
# RUN  6 , total integrated cost =  3.418922617432558
# RUN  7 , total integrated cost =  3.3446311593963727
# RUN  8 , total integrated cost =  3.3194979661943878
# RUN  9 , total integrated cost =  3.25682421274194
# RUN  10 , total integrated cost =  3.298073280124002
# RUN  10 , total integrated cost =  3.298073280124002
# Improved over  10  iterations in  0.7230383019777946  seconds by  41.73204817668154  percent.
# interpolate adjoint :  True True True
# initial cost =  183.91267827070808
# RUN  0 , total integrated cost =  183.91267827070808
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.916821792672107
# RUN  2 , total integrated cost =  5.676829067868544
# RUN  3 , total integrated cost =  5.289377934352393
# RUN  4 , total integrated cost =  4.862418843430043
# RUN  5 , total integrated cost =  4.89298305102909
# RUN  6 , total integrated cost =  4.895856317469255
# RUN  7 , total integrated cost =  4.665220971187677
# RUN  8 , total integrated cost =  4.016172013717479
# RUN  9 , total integrated cost =  4.01145357533487
# RUN  10 , total integrated cost =  4.056253630677839
# RUN  10 , total integrated cost =  4.056253630677839
# Improved over  10  iterations in  0.728132187970914  seconds by  97.79446764148186  percent.
# -------- 1
# interpolate adjoint :  True True True
# initial cost =  820.3152574048567
# RUN  0 , total integrated cost =  820.3152574048567
# Gradient descend method:  None
# RUN  1 , total integrated cost =  9.513432354027021
# RUN  2 , total integrated cost =  8.302219160635127
# RUN  3 , total integrated cost =  6.255678083862292
# RUN  4 , total integrated cost =  5.8309174821763206
# RUN  5 , total integrated cost =  5.113848230088038
# RUN  5 , total integrated cost =  5.113848230088038
# Improved over  5  iterations in  0.18148471595486626  seconds by  99.37659964459687  percent.
# interpolate adjoint :  True True True
# initial cost =  4.984679118839683
# RUN  0 , total integrated cost =  4.984679118839683
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.667084664567735
# RUN  2 , total integrated cost =  4.341508097770737
# RUN  3 , total integrated cost =  3.6746011922468265
# RUN  4 , total integrated cost =  3.656528811143765
# RUN  5 , total integrated cost =  3.612184575989442
# RUN  6 , total integrated cost =  3.533391538196481
# RUN  7 , total integrated cost =  3.478841957244872
# RUN  8 , total integrated cost =  3.472471730611556
# RUN  9 , total integrated cost =  3.368671106259368
# RUN  10 , total integrated cost =  3.260186291427972
# RUN  10 , total integrated cost =  3.260186291427972
# Improved over  10  iterations in  0.8292670380324125  seconds by  34.59586437357541  percent.
# interpolate adjoint :  True True True
# initial cost =  195.14797155237062
# RUN  0 , total integrated cost =  195.14797155237062
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.960191375377104
# RUN  2 , total integrated cost =  5.84113621672714
# RUN  3 , total integrated cost =  5.391688011937846
# RUN  4 , total integrated cost =  5.233963888509152
# RUN  5 , total integrated cost =  5.089409776456125
# RUN  6 , total integrated cost =  5.05105190356483
# RUN  7 , total integrated cost =  5.0455113135431935
# RUN  8 , total integrated cost =  4.92845947620531
# RUN  9 , total integrated cost =  4.728932381759867
# RUN  10 , total integrated cost =  4.736020103094431
# RUN  10 , total integrated cost =  4.736020103094431
# Improved over  10  iterations in  0.8801762930233963  seconds by  97.57311333270843  percent.
# -------- 2
# interpolate adjoint :  True True True
# initial cost =  835.8979502450516
# RUN  0 , total integrated cost =  835.8979502450516
# Gradient descend method:  None
# RUN  1 , total integrated cost =  9.765972004338948
# RUN  2 , total integrated cost =  7.8306177657002225
# RUN  3 , total integrated cost =  4.3401650999904255
# RUN  4 , total integrated cost =  4.237627347214826
# RUN  5 , total integrated cost =  4.092878191163729
# RUN  5 , total integrated cost =  4.092878191163729
# Improved over  5  iterations in  0.192957661987748  seconds by  99.51036149927586  percent.
# interpolate adjoint :  True True True
# initial cost =  4.081156390986434
# RUN  0 , total integrated cost =  4.081156390986434
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.988058695912958
# RUN  2 , total integrated cost =  3.967531685439597
# RUN  3 , total integrated cost =  3.9608578257401255
# RUN  4 , total integrated cost =  3.6887051641081494
# RUN  5 , total integrated cost =  3.5603019688399375
# RUN  6 , total integrated cost =  3.5342378814638007
# RUN  7 , total integrated cost =  3.524336562937675
# RUN  8 , total integrated cost =  3.5135585573498225
# RUN  9 , total integrated cost =  3.495470017474936
# RUN  10 , total integrated cost =  3.4998898590648007
# RUN  10 , total integrated cost =  3.4998898590648007
# Improved over  10  iterations in  0.8179857710492797  seconds by  14.242691929312187  percent.
# interpolate adjoint :  True True True
# initial cost =  253.9125196665135
# RUN  0 , total integrated cost =  253.9125196665135
# Gradient descend method:  None
# RUN  1 , total integrated cost =  8.096748799967555
# RUN  2 , total integrated cost =  7.1817447863633195
# RUN  3 , total integrated cost =  5.7059102267418496
# RUN  4 , total integrated cost =  5.244464305462834
# RUN  5 , total integrated cost =  4.597486455686623
# RUN  6 , total integrated cost =  4.4853218368497085
# RUN  7 , total integrated cost =  3.9228991993103697
# RUN  8 , total integrated cost =  3.9254678685518805
# RUN  9 , total integrated cost =  3.937762155330752
# RUN  10 , total integrated cost =  3.8990303266410518
# RUN  10 , total integrated cost =  3.8990303266410518
# Improved over  10  iterations in  0.7669326220056973  seconds by  98.46441981995925  percent.
# -------- 3
# interpolate adjoint :  True True True
# initial cost =  889.7129405270797
# RUN  0 , total integrated cost =  889.7129405270797
# Gradient descend method:  None
# RUN  1 , total integrated cost =  9.818238686967456
# RUN  2 , total integrated cost =  8.454471132338874
# RUN  3 , total integrated cost =  6.106983840876776
# RUN  4 , total integrated cost =  5.521782009255535
# RUN  5 , total integrated cost =  4.674706903081325
# RUN  5 , total integrated cost =  4.674706903081325
# Improved over  5  iterations in  0.17106915399199352  seconds by  99.47458256588783  percent.
# interpolate adjoint :  True True True
# initial cost =  4.803182881009602
# RUN  0 , total integrated cost =  4.803182881009602
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.371659870113658
# RUN  2 , total integrated cost =  4.225827602184743
# RUN  3 , total integrated cost =  4.112666493587279
# RUN  4 , total integrated cost =  4.0160200340950984
# RUN  5 , total integrated cost =  3.913079787942876
# RUN  6 , total integrated cost =  3.882159372817455
# RUN  7 , total integrated cost =  3.6651025631107013
# RUN  8 , total integrated cost =  3.6563315509966463
# RUN  9 , total integrated cost =  3.5213599349296696
# RUN  10 , total integrated cost =  3.508311722807955
# RUN  10 , total integrated cost =  3.508311722807955
# Improved over  10  iterations in  0.7246872130199336  seconds by  26.958606205089424  percent.
# interpolate adjoint :  True True True
# initial cost =  176.87195376032304
# RUN  0 , total integrated cost =  176.87195376032304
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.294949720687036
# RUN  2 , total integrated cost =  7.066420325913518
# RUN  3 , total integrated cost =  7.12323167142542
# RUN  4 , total integrated cost =  7.051599195519706
# RUN  5 , total integrated cost =  7.04676384710261
# RUN  6 , total integrated cost =  7.084545114570026
# RUN  7 , total integrated cost =  7.047111318380389
# RUN  8 , total integrated cost =  7.042637508776361
# RUN  9 , total integrated cost =  7.001960182444567
# RUN  10 , total integrated cost =  6.9195250616913295
# RUN  10 , total integrated cost =  6.9195250616913295
# Improved over  10  iterations in  0.8016371169942431  seconds by  96.08783364768622  percent.
# -------- 4
# interpolate adjoint :  True True True
# initial cost =  829.1710972657088
# RUN  0 , total integrated cost =  829.1710972657088
# Gradient descend method:  None
# RUN  1 , total integrated cost =  9.720169230012385
# RUN  2 , total integrated cost =  8.283136388690775
# RUN  3 , total integrated cost =  6.312589545974421
# RUN  4 , total integrated cost =  5.880480115547724
# RUN  5 , total integrated cost =  5.181893231723262
# RUN  5 , total integrated cost =  5.181893231723262
# Improved over  5  iterations in  0.1719007520005107  seconds by  99.37505139182839  percent.
# interpolate adjoint :  True True True
# initial cost =  5.144760519546862
# RUN  0 , total integrated cost =  5.144760519546862
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.6373799891928424
# RUN  2 , total integrated cost =  4.207394463443548
# RUN  3 , total integrated cost =  4.052120994823644
# RUN  4 , total integrated cost =  3.9989369934119416
# RUN  5 , total integrated cost =  3.909358846693187
# RUN  6 , total integrated cost =  3.846738447624979
# RUN  7 , total integrated cost =  3.7459989873939126
# RUN  8 , total integrated cost =  3.7963954611885242
# RUN  9 , total integrated cost =  3.7719976323597786
# RUN  10 , total integrated cost =  3.773003782338278
# RUN  10 , total integrated cost =  3.773003782338278
# Improved over  10  iterations in  0.825818823010195  seconds by  26.66317959789906  percent.
# interpolate adjoint :  True True True
# initial cost =  206.38974787994533
# RUN  0 , total integrated cost =  206.38974787994533
# Gradient descend method:  None
# RUN  1 , total integrated cost =  8.513748930978743
# RUN  2 , total integrated cost =  7.742066234470835
# RUN  3 , total integrated cost =  6.610698528151966
# RUN  4 , total integrated cost =  6.183088169548206
# RUN  5 , total integrated cost =  4.7502308830927475
# RUN  6 , total integrated cost =  4.44625973898482
# RUN  7 , total integrated cost =  4.398298513546866
# RUN  8 , total integrated cost =  4.369592604699693
# RUN  9 , total integrated cost =  4.332793817104474
# RUN  10 , total integrated cost =  4.352027266278299
# RUN  10 , total integrated cost =  4.352027266278299
# Improved over  10  iterations in  0.8174947940278798  seconds by  97.89135491903899  percent.
# -------- 5
# interpolate adjoint :  True True True
# initial cost =  852.3237453770312
# RUN  0 , total integrated cost =  852.3237453770312
# Gradient descend method:  None
# RUN  1 , total integrated cost =  9.635534128724963
# RUN  2 , total integrated cost =  8.355062134260079
# RUN  3 , total integrated cost =  6.350978439061459
# RUN  4 , total integrated cost =  5.857829231057565
# RUN  5 , total integrated cost =  5.060037066691302
# RUN  5 , total integrated cost =  5.060037066691302
# Improved over  5  iterations in  0.21157302503706887  seconds by  99.40632452232656  percent.
# interpolate adjoint :  True True True
# initial cost =  5.0401158427849095
# RUN  0 , total integrated cost =  5.0401158427849095
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.737118082978575
# step size too small or too large
# RUN  2 , total integrated cost =  4.495763321906626
# step size too small or too large
# step size too small or too large
# RUN  3 , total integrated cost =  3.734647998953419
# RUN  4 , total integrated cost =  3.602484154495206
# RUN  5 , total integrated cost =  3.3856284008457647
# RUN  6 , total integrated cost =  3.412230973181672
# RUN  7 , total integrated cost =  3.3686862431481543
# RUN  8 , total integrated cost =  3.3559156351026456
# RUN  9 , total integrated cost =  3.3589143488842073
# RUN  10 , total integrated cost =  3.288520593556769
# RUN  10 , total integrated cost =  3.288520593556769
# Improved over  10  iterations in  1.1955589129938744  seconds by  34.75307520432503  percent.
# interpolate adjoint :  True True True
# initial cost =  213.2381520101218
# RUN  0 , total integrated cost =  213.2381520101218
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.3909348260051715
# RUN  2 , total integrated cost =  5.910939704715727
# RUN  3 , total integrated cost =  5.903046520238067
# RUN  4 , total integrated cost =  5.8934752913811055
# RUN  5 , total integrated cost =  5.931512737796562
# RUN  6 , total integrated cost =  5.8845957350888956
# RUN  7 , total integrated cost =  5.874242627995969
# RUN  8 , total integrated cost =  5.812065660746448
# RUN  9 , total integrated cost =  5.816317609914092
# RUN  10 , total integrated cost =  5.853118266055821
# RUN  10 , total integrated cost =  5.853118266055821
# Improved over  10  iterations in  0.672355433984194  seconds by  97.25512615313886  percent.
# -------- 6
# interpolate adjoint :  True True True
# initial cost =  821.0964983116182
# RUN  0 , total integrated cost =  821.0964983116182
# Gradient descend method:  None
# RUN  1 , total integrated cost =  9.528542985212152
# RUN  2 , total integrated cost =  8.218817259355772
# RUN  3 , total integrated cost =  6.128004600671718
# RUN  4 , total integrated cost =  5.610117033657151
# RUN  5 , total integrated cost =  4.636810640940707
# RUN  5 , total integrated cost =  4.636810640940707
# Improved over  5  iterations in  0.16907033004099503  seconds by  99.4352904134319  percent.
# interpolate adjoint :  True True True
# initial cost =  4.72956940056392
# RUN  0 , total integrated cost =  4.72956940056392
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.457967224919019
# RUN  2 , total integrated cost =  4.158237646698342
# RUN  3 , total integrated cost =  4.048728718355189
# RUN  4 , total integrated cost =  3.685513154091103
# RUN  5 , total integrated cost =  3.6490414560112083
# RUN  6 , total integrated cost =  3.6528843759328407
# RUN  7 , total integrated cost =  3.6455019132324633
# RUN  8 , total integrated cost =  3.613264011272874
# RUN  9 , total integrated cost =  3.5581937472647294
# RUN  10 , total integrated cost =  3.581215098549065
# RUN  10 , total integrated cost =  3.581215098549065
# Improved over  10  iterations in  0.6516616870067082  seconds by  24.28031401501231  percent.
# interpolate adjoint :  True True True
# initial cost =  247.41471204602544
# RUN  0 , total integrated cost =  247.41471204602544
# Gradient descend method:  None
# RUN  1 , total integrated cost =  8.257856068019429
# RUN  2 , total integrated cost =  7.235999425221912
# RUN  3 , total integrated cost =  5.28254496344094
# RUN  4 , total integrated cost =  4.619186185428712
# RUN  5 , total integrated cost =  4.590410621443628
# RUN  6 , total integrated cost =  4.505135431539214
# RUN  7 , total integrated cost =  4.494761274574637
# RUN  8 , total integrated cost =  4.465560552739974
# RUN  9 , total integrated cost =  4.475233758837012
# RUN  10 , total integrated cost =  4.468014452033654
# RUN  10 , total integrated cost =  4.468014452033654
# Improved over  10  iterations in  0.7143594319932163  seconds by  98.19411933304819  percent.
# -------- 7
# interpolate adjoint :  True True True
# initial cost =  832.871345886102
# RUN  0 , total integrated cost =  832.871345886102
# Gradient descend method:  None
# RUN  1 , total integrated cost =  9.706271089931057
# RUN  2 , total integrated cost =  8.589461084376158
# RUN  3 , total integrated cost =  6.2788571396563855
# RUN  4 , total integrated cost =  5.817515745780085
# RUN  5 , total integrated cost =  5.062004763900559
# RUN  5 , total integrated cost =  5.062004763900559
# Improved over  5  iterations in  0.18275646900292486  seconds by  99.39222248563311  percent.
# interpolate adjoint :  True True True
# initial cost =  5.183944861373666
# RUN  0 , total integrated cost =  5.183944861373666
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.88493890910854
# RUN  2 , total integrated cost =  3.759187729530224
# RUN  3 , total integrated cost =  3.7650042305567606
# RUN  4 , total integrated cost =  3.7879951201812934
# RUN  5 , total integrated cost =  3.7585397735507073
# RUN  6 , total integrated cost =  3.7062219908537206
# RUN  7 , total integrated cost =  3.7641227220811544
# RUN  8 , total integrated cost =  3.673081467922378
# RUN  9 , total integrated cost =  3.5311095096499354
# RUN  10 , total integrated cost =  3.5382948067322917
# RUN  10 , total integrated cost =  3.5382948067322917
# Improved over  10  iterations in  0.7941168050165288  seconds by  31.74513037172433  percent.
# interpolate adjoint :  True True True
# initial cost =  215.59011675387916
# RUN  0 , total integrated cost =  215.59011675387916
# Gradient descend method:  None
# RUN  1 , total integrated cost =  8.033721455791564
# RUN  2 , total integrated cost =  7.222408168858303
# RUN  3 , total integrated cost =  6.285178863595633
# RUN  4 , total integrated cost =  5.477234528329843
# RUN  5 , total integrated cost =  5.414303070871718
# RUN  6 , total integrated cost =  5.208300539901376
# RUN  7 , total integrated cost =  5.1883283256793105
# RUN  8 , total integrated cost =  5.2423199021754145
# RUN  9 , total integrated cost =  5.090369987986996
# RUN  10 , total integrated cost =  5.035617918781315
# RUN  10 , total integrated cost =  5.035617918781315
# Improved over  10  iterations in  0.8222894789651036  seconds by  97.66426309582175  percent.
# -------- 8
# interpolate adjoint :  True True True
# initial cost =  813.8135266173284
# RUN  0 , total integrated cost =  813.8135266173284
# Gradient descend method:  None
# RUN  1 , total integrated cost =  9.563135333302794
# RUN  2 , total integrated cost =  8.269878825145126
# RUN  3 , total integrated cost =  6.448829448720394
# RUN  4 , total integrated cost =  5.567458124648011
# RUN  5 , total integrated cost =  4.663436493036536
# RUN  5 , total integrated cost =  4.663436493036536
# Improved over  5  iterations in  0.18261552200419828  seconds by  99.42696498147181  percent.
# interpolate adjoint :  True True True
# initial cost =  4.7046546388341195
# RUN  0 , total integrated cost =  4.7046546388341195
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.798812013936799
# RUN  2 , total integrated cost =  3.6761612966281914
# RUN  3 , total integrated cost =  3.6203834145659206
# RUN  4 , total integrated cost =  3.67527536940119
# RUN  5 , total integrated cost =  3.727947864595197
# RUN  6 , total integrated cost =  3.6575382780460264
# RUN  7 , total integrated cost =  3.6753520359158287
# RUN  8 , total integrated cost =  3.662036881407261
# RUN  9 , total integrated cost =  3.6761952904031783
# RUN  10 , total integrated cost =  3.4375364540873194
# RUN  10 , total integrated cost =  3.4375364540873194
# Improved over  10  iterations in  0.878684998024255  seconds by  26.933288031123354  percent.
# interpolate adjoint :  True True True
# initial cost =  147.86516230963363
# RUN  0 , total integrated cost =  147.86516230963363
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.5096913038274185
# RUN  2 , total integrated cost =  5.110502802204621
# RUN  3 , total integrated cost =  4.866105178667286
# RUN  4 , total integrated cost =  4.502077081470963
# RUN  5 , total integrated cost =  4.520471666856263
# RUN  6 , total integrated cost =  4.404091248754169
# RUN  7 , total integrated cost =  4.353887384302918
# RUN  8 , total integrated cost =  4.360257682975869
# RUN  9 , total integrated cost =  4.360208368992538
# RUN  10 , total integrated cost =  4.374447992614589
# RUN  10 , total integrated cost =  4.374447992614589
# Improved over  10  iterations in  0.7968715410097502  seconds by  97.04159659767973  percent.
# -------- 9
# interpolate adjoint :  True True True
# initial cost =  850.7507787393153
# RUN  0 , total integrated cost =  850.7507787393153
# Gradient descend method:  None
# RUN  1 , total integrated cost =  9.669968753128522
# RUN  2 , total integrated cost =  8.302385552398105
# RUN  3 , total integrated cost =  6.113155331852083
# RUN  4 , total integrated cost =  5.730429652238602
# RUN  5 , total integrated cost =  5.033440666043795
# RUN  5 , total integrated cost =  5.033440666043795
# Improved over  5  iterations in  0.16739881603280082  seconds by  99.40835309331099  percent.
# interpolate adjoint :  True True True
# initial cost =  5.293376189735666
# RUN  0 , total integrated cost =  5.293376189735666
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.497989474152628
# RUN  2 , total integrated cost =  4.338945587098373
# RUN  3 , total integrated cost =  3.9741992338142236
# RUN  4 , total integrated cost =  3.932884278962068
# RUN  5 , total integrated cost =  3.844550630562074
# RUN  6 , total integrated cost =  3.8520520687280886
# RUN  7 , total integrated cost =  3.696413618134682
# RUN  8 , total integrated cost =  3.530741932625048
# RUN  9 , total integrated cost =  3.531636952487609
# RUN  10 , total integrated cost =  3.5340214395530523
# RUN  10 , total integrated cost =  3.5340214395530523
# Improved over  10  iterations in  0.8078461970435455  seconds by  33.23691132313931  percent.
# interpolate adjoint :  True True True
# initial cost =  212.10679381424703
# RUN  0 , total integrated cost =  212.10679381424703
# Gradient descend method:  None
# RUN  1 , total integrated cost =  8.287380844108695
# RUN  2 , total integrated cost =  7.120714256074069
# RUN  3 , total integrated cost =  6.974821088682623
# RUN  4 , total integrated cost =  6.0676758391983245
# RUN  5 , total integrated cost =  5.960111971711057
# RUN  6 , total integrated cost =  5.661425757439712
# RUN  7 , total integrated cost =  4.777506513751555
# RUN  8 , total integrated cost =  4.388207639402461
# RUN  9 , total integrated cost =  4.423078570979243
# RUN  10 , total integrated cost =  4.367964785303336
# RUN  10 , total integrated cost =  4.367964785303336
# Improved over  10  iterations in  0.759618560958188  seconds by  97.94067662484748  percent.
# -------- 10
# interpolate adjoint :  True True True
# initial cost =  829.1280645695751
# RUN  0 , total integrated cost =  829.1280645695751
# Gradient descend method:  None
# RUN  1 , total integrated cost =  9.58089606070893
# RUN  2 , total integrated cost =  7.854014419484275
# RUN  3 , total integrated cost =  5.195607685302924
# RUN  4 , total integrated cost =  4.726238870157437
# RUN  5 , total integrated cost =  4.495582568259605
# RUN  5 , total integrated cost =  4.495582568259605
# Improved over  5  iterations in  0.1681470790063031  seconds by  99.45779394518586  percent.
# interpolate adjoint :  True True True
# initial cost =  4.661641341782568
# RUN  0 , total integrated cost =  4.661641341782568
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.451354348067845
# RUN  2 , total integrated cost =  4.147410539359832
# RUN  3 , total integrated cost =  3.998978039787229
# RUN  4 , total integrated cost =  3.8618906181796335
# RUN  5 , total integrated cost =  3.576054876460995
# RUN  6 , total integrated cost =  3.455370611273549
# RUN  7 , total integrated cost =  3.476500283429421
# step size too small or too large
# step size too small or too large
# RUN  8 , total integrated cost =  3.393741609033011
# Control only changes marginally.
# RUN  8 , total integrated cost =  3.393741609033011
# Improved over  8  iterations in  0.8401211460004561  seconds by  27.19856891145392  percent.
# interpolate adjoint :  True True True
# initial cost =  229.3206119065057
# RUN  0 , total integrated cost =  229.3206119065057
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.9928527125840825
# RUN  2 , total integrated cost =  7.949600939696025
# RUN  3 , total integrated cost =  7.931590271218669
# RUN  4 , total integrated cost =  6.247194716330727
# RUN  5 , total integrated cost =  5.697742696901009
# RUN  6 , total integrated cost =  4.9482010206304174
# RUN  7 , total integrated cost =  4.29801826861215
# RUN  8 , total integrated cost =  4.2242434250365735
# RUN  9 , total integrated cost =  4.221234160078454
# RUN  10 , total integrated cost =  4.189776144524467
# RUN  10 , total integrated cost =  4.189776144524467
# Improved over  10  iterations in  0.69538414204726  seconds by  98.17296137940158  percent.
# -------- 11
# interpolate adjoint :  True True True
# initial cost =  845.6715237935431
# RUN  0 , total integrated cost =  845.6715237935431
# Gradient descend method:  None
# RUN  1 , total integrated cost =  9.647786070744983
# RUN  2 , total integrated cost =  8.34206860773091
# RUN  3 , total integrated cost =  6.324848412793394
# RUN  4 , total integrated cost =  5.863333696352448
# RUN  5 , total integrated cost =  4.9390716204481375
# RUN  5 , total integrated cost =  4.9390716204481375
# Improved over  5  iterations in  0.1731587500544265  seconds by  99.41595862205548  percent.
# interpolate adjoint :  True True True
# initial cost =  5.03769331135724
# RUN  0 , total integrated cost =  5.03769331135724
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.725560451783564
# RUN  2 , total integrated cost =  4.326003070014252
# RUN  3 , total integrated cost =  4.287312055942454
# RUN  4 , total integrated cost =  4.028462407878807
# RUN  5 , total integrated cost =  3.7119388314567656
# RUN  6 , total integrated cost =  3.7165981094999596
# RUN  7 , total integrated cost =  3.6766592589314855
# RUN  8 , total integrated cost =  3.6603081982622294
# RUN  9 , total integrated cost =  3.5979007098187212
# RUN  10 , total integrated cost =  3.4086444131712077
# RUN  10 , total integrated cost =  3.4086444131712077
# Improved over  10  iterations in  0.6704988130368292  seconds by  32.33719874358805  percent.
# interpolate adjoint :  True True True
# initial cost =  230.24641287657366
# RUN  0 , total integrated cost =  230.24641287657366
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.288021066887614
# RUN  2 , total integrated cost =  6.866426325988821
# RUN  3 , total integrated cost =  6.6648134879312435
# RUN  4 , total integrated cost =  6.141311923107461
# RUN  5 , total integrated cost =  6.017811889592651
# RUN  6 , total integrated cost =  5.871902662507084
# RUN  7 , total integrated cost =  5.636012693730891
# RUN  8 , total integrated cost =  5.420373562680942
# RUN  9 , total integrated cost =  5.386761700156237
# RUN  10 , total integrated cost =  5.333961708558841
# RUN  10 , total integrated cost =  5.333961708558841
# Improved over  10  iterations in  0.8874682169989683  seconds by  97.68336816112824  percent.
# -------- 12
# interpolate adjoint :  True True True
# initial cost =  836.2440231310754
# RUN  0 , total integrated cost =  836.2440231310754
# Gradient descend method:  None
# RUN  1 , total integrated cost =  9.597702395417855
# RUN  2 , total integrated cost =  8.276034383029263
# RUN  3 , total integrated cost =  6.085273539770143
# RUN  4 , total integrated cost =  5.538029444796517
# RUN  5 , total integrated cost =  3.9086320750303045
# RUN  5 , total integrated cost =  3.9086320750303045
# Improved over  5  iterations in  0.17342376901069656  seconds by  99.5325967101809  percent.
# interpolate adjoint :  True True True
# initial cost =  4.085460440469164
# RUN  0 , total integrated cost =  4.085460440469164
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.832446677388753
# RUN  2 , total integrated cost =  3.8528194372314775
# RUN  3 , total integrated cost =  3.6183578835029264
# RUN  4 , total integrated cost =  3.511850113517304
# RUN  5 , total integrated cost =  3.534031246314401
# RUN  6 , total integrated cost =  3.498691090077085
# RUN  7 , total integrated cost =  3.5287262544359153
# RUN  8 , total integrated cost =  3.5648341216355157
# RUN  9 , total integrated cost =  3.553676872017363
# RUN  10 , total integrated cost =  3.541894910634295
# RUN  10 , total integrated cost =  3.541894910634295
# Improved over  10  iterations in  0.7065994680160657  seconds by  13.30487806100129  percent.
# interpolate adjoint :  True True True
# initial cost =  214.5188050003986
# RUN  0 , total integrated cost =  214.5188050003986
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.873671754057696
# RUN  2 , total integrated cost =  7.03258297267959
# RUN  3 , total integrated cost =  7.041215801104275
# RUN  4 , total integrated cost =  6.8558325378195715
# RUN  5 , total integrated cost =  6.115044738422423
# RUN  6 , total integrated cost =  5.624737494200104
# RUN  7 , total integrated cost =  5.378125712646358
# RUN  8 , total integrated cost =  5.394166293017785
# RUN  9 , total integrated cost =  5.418044774598661
# RUN  10 , total integrated cost =  4.828031828675087
# RUN  10 , total integrated cost =  4.828031828675087
# Improved over  10  iterations in  0.7676755519933067  seconds by  97.7493666214176  percent.
# -------- 13
# interpolate adjoint :  True True True
# initial cost =  865.5078996955924
# RUN  0 , total integrated cost =  865.5078996955924
# Gradient descend method:  None
# RUN  1 , total integrated cost =  9.77628096095328
# RUN  2 , total integrated cost =  7.878456989196046
# RUN  3 , total integrated cost =  4.259897867143233
# RUN  4 , total integrated cost =  4.109269316877179
# RUN  5 , total integrated cost =  3.9710692373475567
# RUN  5 , total integrated cost =  3.9710692373475567
# Improved over  5  iterations in  0.2542801949894056  seconds by  99.54118625159352  percent.
# interpolate adjoint :  True True True
# initial cost =  4.049305842963949
# RUN  0 , total integrated cost =  4.049305842963949
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.9172208975698295
# RUN  2 , total integrated cost =  3.8154218665416897
# RUN  3 , total integrated cost =  3.7648655765531025
# RUN  4 , total integrated cost =  3.5675326270323056
# RUN  5 , total integrated cost =  3.5740453497820854
# RUN  6 , total integrated cost =  3.588992754768317
# RUN  7 , total integrated cost =  3.5517645039230796
# RUN  8 , total integrated cost =  3.565000635278759
# RUN  9 , total integrated cost =  3.546717265821543
# RUN  10 , total integrated cost =  3.5375656473335435
# RUN  10 , total integrated cost =  3.5375656473335435
# Improved over  10  iterations in  0.7490966590121388  seconds by  12.637726451796723  percent.
# interpolate adjoint :  True True True
# initial cost =  297.01599511529844
# RUN  0 , total integrated cost =  297.01599511529844
# Gradient descend method:  None
# RUN  1 , total integrated cost =  8.604156131941897
# RUN  2 , total integrated cost =  7.052472717186074
# RUN  3 , total integrated cost =  5.146914718011311
# RUN  4 , total integrated cost =  4.754357364406844
# RUN  5 , total integrated cost =  4.7195531983640695
# RUN  6 , total integrated cost =  4.744195970173521
# RUN  7 , total integrated cost =  4.725380886808205
# RUN  8 , total integrated cost =  4.647639579434267
# RUN  9 , total integrated cost =  4.475886317129717
# RUN  10 , total integrated cost =  4.384658363383153
# RUN  10 , total integrated cost =  4.384658363383153
# Improved over  10  iterations in  0.7414744889829308  seconds by  98.52376355634279  percent.
# -------- 14
# interpolate adjoint :  True True True
# initial cost =  835.3423698541357
# RUN  0 , total integrated cost =  835.3423698541357
# Gradient descend method:  None
# RUN  1 , total integrated cost =  9.705502518420829
# RUN  2 , total integrated cost =  8.313958547849333
# RUN  3 , total integrated cost =  6.478413000518454
# RUN  4 , total integrated cost =  5.803326283803396
# RUN  5 , total integrated cost =  4.958886897224495
# RUN  5 , total integrated cost =  4.958886897224495
# Improved over  5  iterations in  0.17806012695655227  seconds by  99.40636473424777  percent.
# interpolate adjoint :  True True True
# initial cost =  4.957492883275934
# RUN  0 , total integrated cost =  4.957492883275934
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.431377801518218
# RUN  2 , total integrated cost =  4.047610494712756
# RUN  3 , total integrated cost =  3.5964698226835172
# RUN  4 , total integrated cost =  3.597220429502854
# RUN  5 , total integrated cost =  3.5936314062093757
# RUN  6 , total integrated cost =  3.5764749609819693
# RUN  7 , total integrated cost =  3.385515123102852
# RUN  8 , total integrated cost =  3.331635793474703
# RUN  9 , total integrated cost =  3.356571592037982
# RUN  10 , total integrated cost =  3.337623226337414
# RUN  10 , total integrated cost =  3.337623226337414
# Improved over  10  iterations in  0.7054938490036875  seconds by  32.675178665473  percent.
# interpolate adjoint :  True True True
# initial cost =  174.57085532884088
# RUN  0 , total integrated cost =  174.57085532884088
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.545903097188868
# RUN  2 , total integrated cost =  5.651039333486733
# RUN  3 , total integrated cost =  5.523022377321446
# RUN  4 , total integrated cost =  5.6261515243155396
# RUN  5 , total integrated cost =  5.497458688852922
# RUN  6 , total integrated cost =  5.312984518258544
# RUN  7 , total integrated cost =  5.220513511759507
# RUN  8 , total integrated cost =  5.03248778592842
# RUN  9 , total integrated cost =  5.021604482610422
# RUN  10 , total integrated cost =  5.048052483072403
# RUN  10 , total integrated cost =  5.048052483072403
# Improved over  10  iterations in  0.8765260609798133  seconds by  97.10830741273317  percent.
# -------- 15
# interpolate adjoint :  True True True
# initial cost =  831.1600708697467
# RUN  0 , total integrated cost =  831.1600708697467
# Gradient descend method:  None
# RUN  1 , total integrated cost =  9.57525276024206
# RUN  2 , total integrated cost =  7.819146289454641
# RUN  3 , total integrated cost =  6.145195613158584
# RUN  4 , total integrated cost =  5.659933521226916
# RUN  5 , total integrated cost =  5.070396084582357
# RUN  5 , total integrated cost =  5.070396084582357
# Improved over  5  iterations in  0.18709489598404616  seconds by  99.3899615414301  percent.
# interpolate adjoint :  True True True
# initial cost =  5.026126488701274
# RUN  0 , total integrated cost =  5.026126488701274
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.684601357917712
# RUN  2 , total integrated cost =  4.316404721995771
# RUN  3 , total integrated cost =  4.236319039441841
# RUN  4 , total integrated cost =  4.1016340126770015
# RUN  5 , total integrated cost =  3.8875439109522936
# RUN  6 , total integrated cost =  3.862787417478876
# RUN  7 , total integrated cost =  3.7555704072013656
# RUN  8 , total integrated cost =  3.673550976431537
# RUN  9 , total integrated cost =  3.6055633177436746
# RUN  10 , total integrated cost =  3.5913157578001313
# RUN  10 , total integrated cost =  3.5913157578001313
# Improved over  10  iterations in  0.715285355981905  seconds by  28.547047793695498  percent.
# interpolate adjoint :  True True True
# initial cost =  231.31908897168677
# RUN  0 , total integrated cost =  231.31908897168677
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.816208931342994
# RUN  2 , total integrated cost =  7.1958398930416205
# RUN  3 , total integrated cost =  7.219171381846753
# RUN  4 , total integrated cost =  7.141207061678002
# RUN  5 , total integrated cost =  7.132597636751546
# RUN  6 , total integrated cost =  7.174131188720572
# RUN  7 , total integrated cost =  6.342707540598237
# RUN  8 , total integrated cost =  5.915742243597836
# RUN  9 , total integrated cost =  5.031729471105603
# RUN  10 , total integrated cost =  4.72957653439437
# RUN  10 , total integrated cost =  4.72957653439437
# Improved over  10  iterations in  0.7581633040099405  seconds by  97.95538856934834  percent.
# -------- 16
# interpolate adjoint :  True True True
# initial cost =  820.5217106491692
# RUN  0 , total integrated cost =  820.5217106491692
# Gradient descend method:  None
# RUN  1 , total integrated cost =  9.464991713399098
# RUN  2 , total integrated cost =  8.301341042283603
# RUN  3 , total integrated cost =  5.985612655619156
# RUN  4 , total integrated cost =  5.5330308745620105
# RUN  5 , total integrated cost =  4.83477150793559
# RUN  5 , total integrated cost =  4.83477150793559
# Improved over  5  iterations in  0.18133930099429563  seconds by  99.41076860670627  percent.
# interpolate adjoint :  True True True
# initial cost =  4.740901668951702
# RUN  0 , total integrated cost =  4.740901668951702
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.464643915726695
# RUN  2 , total integrated cost =  4.136139416826485
# RUN  3 , total integrated cost =  4.064026907280168
# RUN  4 , total integrated cost =  3.9566089762169416
# RUN  5 , total integrated cost =  3.9147488938244623
# RUN  6 , total integrated cost =  3.6763817925461733
# RUN  7 , total integrated cost =  3.559930731791718
# RUN  8 , total integrated cost =  3.575731557138134
# RUN  9 , total integrated cost =  3.536684147064828
# RUN  10 , total integrated cost =  3.4419644135713794
# RUN  10 , total integrated cost =  3.4419644135713794
# Improved over  10  iterations in  0.6995056809973903  seconds by  27.398527665888935  percent.
# interpolate adjoint :  True True True
# initial cost =  197.69176572686703
# RUN  0 , total integrated cost =  197.69176572686703
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.209113836820896
# RUN  2 , total integrated cost =  7.119809557014831
# RUN  3 , total integrated cost =  7.10061734080372
# RUN  4 , total integrated cost =  5.471843716667938
# RUN  5 , total integrated cost =  5.187419701273827
# RUN  6 , total integrated cost =  4.575544460452529
# RUN  7 , total integrated cost =  4.4189869246575775
# RUN  8 , total integrated cost =  4.357300059129971
# RUN  9 , total integrated cost =  4.277338367548187
# RUN  10 , total integrated cost =  4.280208847156377
# RUN  10 , total integrated cost =  4.280208847156377
# Improved over  10  iterations in  0.7714284439571202  seconds by  97.83490787721024  percent.
# -------- 17
# interpolate adjoint :  True True True
# initial cost =  815.5529152774773
# RUN  0 , total integrated cost =  815.5529152774773
# Gradient descend method:  None
# RUN  1 , total integrated cost =  9.60505203523738
# RUN  2 , total integrated cost =  8.228900697406292
# RUN  3 , total integrated cost =  6.391770249163663
# RUN  4 , total integrated cost =  5.363604228861486
# RUN  5 , total integrated cost =  4.455787859270997
# RUN  5 , total integrated cost =  4.455787859270997
# Improved over  5  iterations in  0.17091376997996122  seconds by  99.45364822124938  percent.
# interpolate adjoint :  True True True
# initial cost =  4.45035171142769
# RUN  0 , total integrated cost =  4.45035171142769
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.142943599538963
# RUN  2 , total integrated cost =  4.111807260474996
# RUN  3 , total integrated cost =  3.971301165931366
# RUN  4 , total integrated cost =  3.7947852230631125
# RUN  5 , total integrated cost =  3.807785148226282
# RUN  6 , total integrated cost =  3.753535569875101
# RUN  7 , total integrated cost =  3.7156895764183084
# RUN  8 , total integrated cost =  3.6957238664985574
# RUN  9 , total integrated cost =  3.7054641221354903
# RUN  10 , total integrated cost =  3.689076854814363
# RUN  10 , total integrated cost =  3.689076854814363
# Improved over  10  iterations in  0.7119702069903724  seconds by  17.105948158176176  percent.
# interpolate adjoint :  True True True
# initial cost =  241.26807077900264
# RUN  0 , total integrated cost =  241.26807077900264
# Gradient descend method:  None
# RUN  1 , total integrated cost =  9.47461700606641
# RUN  2 , total integrated cost =  8.932803544773323
# RUN  3 , total integrated cost =  7.347942104194654
# RUN  4 , total integrated cost =  6.8825159045692725
# RUN  5 , total integrated cost =  5.3527177065229345
# RUN  6 , total integrated cost =  4.602068326298611
# RUN  7 , total integrated cost =  4.589441231867211
# RUN  8 , total integrated cost =  4.521876787245991
# RUN  9 , total integrated cost =  4.566784230641943
# RUN  10 , total integrated cost =  4.182268614243438
# RUN  10 , total integrated cost =  4.182268614243438
# Improved over  10  iterations in  0.738525279040914  seconds by  98.2665469986394  percent.
# -------- 18
# interpolate adjoint :  True True True
# initial cost =  829.2522571529948
# RUN  0 , total integrated cost =  829.2522571529948
# Gradient descend method:  None
# RUN  1 , total integrated cost =  9.413512123337377
# RUN  2 , total integrated cost =  7.798746992140717
# RUN  3 , total integrated cost =  5.918892903102179
# RUN  4 , total integrated cost =  5.539129479695977
# RUN  5 , total integrated cost =  4.8025232775740285
# RUN  5 , total integrated cost =  4.8025232775740285
# Improved over  5  iterations in  0.17551169299986213  seconds by  99.42086099420915  percent.
# interpolate adjoint :  True True True
# initial cost =  4.850981276642152
# RUN  0 , total integrated cost =  4.850981276642152
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.620054360723539
# RUN  2 , total integrated cost =  4.218307350415906
# RUN  3 , total integrated cost =  4.199437267073658
# RUN  4 , total integrated cost =  3.9869779498066062
# RUN  5 , total integrated cost =  4.005168656373151
# RUN  6 , total integrated cost =  3.8600567085729653
# RUN  7 , total integrated cost =  3.7580920380621157
# RUN  8 , total integrated cost =  3.7914227159398126
# RUN  9 , total integrated cost =  3.7437095949773744
# RUN  10 , total integrated cost =  3.739409337656204
# RUN  10 , total integrated cost =  3.739409337656204
# Improved over  10  iterations in  0.7521523949690163  seconds by  22.914372898907118  percent.
# interpolate adjoint :  True True True
# initial cost =  260.2344783939116
# RUN  0 , total integrated cost =  260.2344783939116
# Gradient descend method:  None
# RUN  1 , total integrated cost =  8.862715418016073
# RUN  2 , total integrated cost =  8.510697327019562
# RUN  3 , total integrated cost =  7.850995514169158
# RUN  4 , total integrated cost =  7.494531554828132
# RUN  5 , total integrated cost =  6.587969349767377
# RUN  6 , total integrated cost =  6.268958068982193
# RUN  7 , total integrated cost =  6.231068362113976
# RUN  8 , total integrated cost =  5.906631588825896
# RUN  9 , total integrated cost =  5.755453205305366
# RUN  10 , total integrated cost =  5.576566006518105
# RUN  10 , total integrated cost =  5.576566006518105
# Improved over  10  iterations in  0.9026871760142967  seconds by  97.8570994739302  percent.
# -------- 19
# interpolate adjoint :  True True True
# initial cost =  806.9229558018236
# RUN  0 , total integrated cost =  806.9229558018236
# Gradient descend method:  None
# RUN  1 , total integrated cost =  9.410044148319953
# RUN  2 , total integrated cost =  8.224074081963407
# RUN  3 , total integrated cost =  6.233932811893765
# RUN  4 , total integrated cost =  5.707963150571585
# RUN  5 , total integrated cost =  4.838543816153267
# RUN  5 , total integrated cost =  4.838543816153267
# Improved over  5  iterations in  0.16777040396118537  seconds by  99.40037102905998  percent.
# interpolate adjoint :  True True True
# initial cost =  5.165235716783212
# RUN  0 , total integrated cost =  5.165235716783212
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.573519372570943
# RUN  2 , total integrated cost =  3.7223132418615683
# RUN  3 , total integrated cost =  3.654614827963864
# RUN  4 , total integrated cost =  3.6327032584546175
# RUN  5 , total integrated cost =  3.6104917418658773
# RUN  6 , total integrated cost =  3.5102673805767286
# RUN  7 , total integrated cost =  3.4920593399591073
# RUN  8 , total integrated cost =  3.49140563765651
# RUN  9 , total integrated cost =  3.485556482887689
# RUN  10 , total integrated cost =  3.489799375054615
# RUN  10 , total integrated cost =  3.489799375054615
# Improved over  10  iterations in  0.6148553629755042  seconds by  32.43678379061508  percent.
# interpolate adjoint :  True True True
# initial cost =  179.76010734073793
# RUN  0 , total integrated cost =  179.76010734073793
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.607430632897926
# RUN  2 , total integrated cost =  6.863088745642411
# RUN  3 , total integrated cost =  4.529819558408884
# RUN  4 , total integrated cost =  4.481734107522991
# RUN  5 , total integrated cost =  4.446667323407248
# RUN  6 , total integrated cost =  4.445541850092264
# step size too small or too large
# RUN  7 , total integrated cost =  4.421215346944109
# Control only changes marginally.
# RUN  7 , total integrated cost =  4.421215346944109
# Improved over  7  iterations in  0.7640368850552477  seconds by  97.54049137355952  percent.
# -------- 19
# interpolate adjoint :  True True True
# initial cost =  821.5782456524666
# RUN  0 , total integrated cost =  821.5782456524666
# Gradient descend method:  None
# RUN  1 , total integrated cost =  9.740773742513017
# RUN  2 , total integrated cost =  8.573606928556057
# RUN  3 , total integrated cost =  6.291140041007918
# RUN  4 , total integrated cost =  5.737754795369842
# RUN  5 , total integrated cost =  4.82540802099486
# RUN  5 , total integrated cost =  4.82540802099486
# Improved over  5  iterations in  0.17176243802532554  seconds by  99.412666042884  percent.
# interpolate adjoint :  True True True
# initial cost =  4.802936570422093
# RUN  0 , total integrated cost =  4.802936570422093
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.501213351351909
# RUN  2 , total integrated cost =  4.199866106318006
# RUN  3 , total integrated cost =  4.11101196919377
# RUN  4 , total integrated cost =  4.1321721117402825
# RUN  5 , total integrated cost =  3.9596811712643145
# RUN  6 , total integrated cost =  3.954334526407798
# RUN  7 , total integrated cost =  3.50270172590954
# RUN  8 , total integrated cost =  3.503165449370034
# RUN  9 , total integrated cost =  3.492441226468093
# RUN  10 , total integrated cost =  3.411268957958651
# RUN  10 , total integrated cost =  3.411268957958651
# Improved over  10  iterations in  0.816321144986432  seconds by  28.975348561414364  percent.
# interpolate adjoint :  True True True
# initial cost =  268.4842103286929
# RUN  0 , total integrated cost =  268.4842103286929
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.031487447911983
# RUN  2 , total integrated cost =  6.5089668985035285
# RUN  3 , total integrated cost =  5.9942959699109934
# RUN  4 , total integrated cost =  4.798732047658614
# RUN  5 , total integrated cost =  4.354691413534555
# RUN  6 , total integrated cost =  4.307767582825299
# RUN  7 , total integrated cost =  4.351202287092219
# step size too small or too large
# RUN  8 , total integrated cost =  4.240401687276612
# Control only changes marginally.
# RUN  8 , total integrated cost =  4.240401687276612
# Improved over  8  iterations in  0.7833225509966724  seconds by  98.42061412770408  percent.
# mean =  4.730806768059732
# 100
# -------- 0
# interpolate adjoint :  True True True
# initial cost =  851.980721126921
# RUN  0 , total integrated cost =  851.980721126921
# Gradient descend method:  None
# RUN  1 , total integrated cost =  9.606683374231116
# RUN  2 , total integrated cost =  8.368492454158135
# RUN  3 , total integrated cost =  6.369155611872247
# RUN  4 , total integrated cost =  5.738403240982214
# RUN  5 , total integrated cost =  4.84489548330455
# RUN  5 , total integrated cost =  4.84489548330455
# Improved over  5  iterations in  0.1785011279862374  seconds by  99.4313374278122  percent.
# interpolate adjoint :  True True True
# initial cost =  4.863694210403541
# RUN  0 , total integrated cost =  4.863694210403541
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.226246255174652
# RUN  2 , total integrated cost =  3.896079063791957
# RUN  3 , total integrated cost =  3.851029654888414
# RUN  4 , total integrated cost =  3.865262530502558
# RUN  5 , total integrated cost =  3.8821529633391934
# RUN  6 , total integrated cost =  3.7266737151200595
# RUN  7 , total integrated cost =  3.7329127478048463
# RUN  8 , total integrated cost =  3.4391256766508875
# RUN  9 , total integrated cost =  3.4193602418914044
# ...
# RUN  3 , total integrated cost =  5.503652731698535
# RUN  4 , total integrated cost =  5.6289671746963
# RUN  5 , total integrated cost =  5.373865883703605
# RUN  6 , total integrated cost =  5.32522529480241
# RUN  7 , total integrated cost =  5.0171626565350875
# RUN  8 , total integrated cost =  4.965627938416731
# RUN  9 , total integrated cost =  4.719167549550569
# RUN  10 , total integrated cost =  3.9975887458449915
# RUN  10 , total integrated cost =  3.9975887458449915
# Improved over  10  iterations in  0.5720397150143981  seconds by  90.32078470182762  percent.
# -------- 95
# interpolate adjoint :  True True True
# initial cost =  74.04354468744836
# RUN  0 , total integrated cost =  74.04354468744836
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.22713534496755
# RUN  2 , total integrated cost =  4.7716515429765725
# RUN  3 , total integrated cost =  3.8563058666331465
# RUN  4 , total integrated cost =  3.8381863445304694
# RUN  5 , total integrated cost =  3.020100835035513
# RUN  5 , total integrated cost =  3.020100835035513
# Improved over  5  iterations in  0.13575365499127656  seconds by  95.9211828015745  percent.
# interpolate adjoint :  True True True
# initial cost =  7.39575860823847
# RUN  0 , total integrated cost =  7.39575860823847
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.26815815972218
# RUN  2 , total integrated cost =  3.2366755340664626
# RUN  3 , total integrated cost =  3.1644881200512414
# RUN  4 , total integrated cost =  3.2655578975708535
# RUN  5 , total integrated cost =  3.184897540632052
# RUN  6 , total integrated cost =  3.215924511755059
# RUN  7 , total integrated cost =  3.176161287295763
# RUN  8 , total integrated cost =  3.1914379302082407
# RUN  9 , total integrated cost =  3.310064462863312
# RUN  10 , total integrated cost =  3.2364618430120986
# RUN  10 , total integrated cost =  3.2364618430120986
# Improved over  10  iterations in  0.6643680479610339  seconds by  56.23894701745866  percent.
# interpolate adjoint :  True True True
# initial cost =  71.60488641948442
# RUN  0 , total integrated cost =  71.60488641948442
# Gradient descend method:  None
# RUN  1 , total integrated cost =  10.754058438606961
# RUN  2 , total integrated cost =  10.242881752617732
# RUN  3 , total integrated cost =  9.401852339793669
# RUN  4 , total integrated cost =  8.775331803509166
# RUN  5 , total integrated cost =  5.620892691436495
# RUN  6 , total integrated cost =  5.283869154167553
# RUN  7 , total integrated cost =  5.56212722116954
# RUN  8 , total integrated cost =  5.535624585161583
# RUN  9 , total integrated cost =  5.298879525852707
# RUN  10 , total integrated cost =  5.46636163181
# RUN  10 , total integrated cost =  5.46636163181
# Improved over  10  iterations in  0.6017292590113357  seconds by  92.36593771019159  percent.
# -------- 96
# interpolate adjoint :  True True True
# initial cost =  90.83457156371033
# RUN  0 , total integrated cost =  90.83457156371033
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.301178404121053
# RUN  2 , total integrated cost =  4.403075254652602
# RUN  3 , total integrated cost =  3.7324333359605375
# RUN  4 , total integrated cost =  3.5553042647705073
# RUN  5 , total integrated cost =  3.8292772439856853
# RUN  5 , total integrated cost =  3.8292772439856853
# Improved over  5  iterations in  0.14675861300202087  seconds by  95.78433940066544  percent.
# interpolate adjoint :  True True True
# initial cost =  4.5731493098202725
# RUN  0 , total integrated cost =  4.5731493098202725
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.8246204459871938
# RUN  2 , total integrated cost =  3.832792928290635
# RUN  3 , total integrated cost =  2.9081043148540755
# RUN  4 , total integrated cost =  3.0677616487648414
# RUN  5 , total integrated cost =  3.5267881648200046
# RUN  6 , total integrated cost =  3.4954547759314405
# RUN  7 , total integrated cost =  3.325960645281014
# RUN  8 , total integrated cost =  3.245649185148052
# RUN  9 , total integrated cost =  2.9027895519924
# RUN  10 , total integrated cost =  2.67230798169423
# RUN  10 , total integrated cost =  2.67230798169423
# Improved over  10  iterations in  0.6383845090167597  seconds by  41.56525841052732  percent.
# interpolate adjoint :  True True True
# initial cost =  243.8265433185501
# RUN  0 , total integrated cost =  243.8265433185501
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12.338106711280464
# RUN  2 , total integrated cost =  9.238006402643146
# RUN  3 , total integrated cost =  8.143692999720146
# RUN  4 , total integrated cost =  8.021569461954037
# RUN  5 , total integrated cost =  7.960896026346862
# RUN  6 , total integrated cost =  5.2936322148334884
# RUN  7 , total integrated cost =  4.3883241963281145
# RUN  8 , total integrated cost =  5.024520738356136
# RUN  9 , total integrated cost =  4.924547648807344
# RUN  10 , total integrated cost =  4.9724215239926925
# RUN  10 , total integrated cost =  4.9724215239926925
# Improved over  10  iterations in  0.5667757439659908  seconds by  97.96067259277166  percent.
# -------- 97
# interpolate adjoint :  True True True
# initial cost =  92.2689167774212
# RUN  0 , total integrated cost =  92.2689167774212
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.655278894780667
# RUN  2 , total integrated cost =  3.989277644364188
# RUN  3 , total integrated cost =  2.8707883013364843
# RUN  4 , total integrated cost =  2.889057767138123
# RUN  5 , total integrated cost =  3.6599120719907985
# RUN  5 , total integrated cost =  3.6599120719907985
# Improved over  5  iterations in  0.13104638195363805  seconds by  96.03342902483666  percent.
# interpolate adjoint :  True True True
# initial cost =  4.033122691515784
# RUN  0 , total integrated cost =  4.033122691515784
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.6007906810057717
# RUN  2 , total integrated cost =  3.6866746203995793
# RUN  3 , total integrated cost =  3.6478496463435097
# RUN  4 , total integrated cost =  3.1425705017569827
# RUN  5 , total integrated cost =  3.1130218197288184
# RUN  6 , total integrated cost =  2.563500260196179
# RUN  7 , total integrated cost =  3.083832287124754
# RUN  8 , total integrated cost =  2.7850631931276766
# RUN  9 , total integrated cost =  2.7157660146747973
# RUN  10 , total integrated cost =  2.911334826565775
# RUN  10 , total integrated cost =  2.911334826565775
# Improved over  10  iterations in  0.5672748519573361  seconds by  27.814374884003414  percent.
# interpolate adjoint :  True True True
# initial cost =  219.1669068109587
# RUN  0 , total integrated cost =  219.1669068109587
# Gradient descend method:  None
# RUN  1 , total integrated cost =  13.547352710627004
# RUN  2 , total integrated cost =  11.059564468003513
# RUN  3 , total integrated cost =  6.159259312846027
# RUN  4 , total integrated cost =  5.248831946444677
# RUN  5 , total integrated cost =  5.308132738114621
# Control only changes marginally.
# RUN  5 , total integrated cost =  5.308132738114621
# Improved over  5  iterations in  0.5136475319741294  seconds by  97.5780409481742  percent.
# -------- 97
# interpolate adjoint :  True True True
# initial cost =  108.62635732718553
# RUN  0 , total integrated cost =  108.62635732718553
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.200503937476965
# RUN  2 , total integrated cost =  4.144274339112352
# RUN  3 , total integrated cost =  3.645022346944474
# RUN  4 , total integrated cost =  3.881317257023637
# RUN  5 , total integrated cost =  3.9265047613764312
# RUN  5 , total integrated cost =  3.9265047613764312
# Improved over  5  iterations in  0.14871558197773993  seconds by  96.38531120992147  percent.
# interpolate adjoint :  True True True
# initial cost =  3.9150248595019095
# RUN  0 , total integrated cost =  3.9150248595019095
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.3825959904045995
# RUN  2 , total integrated cost =  3.4350812960443196
# RUN  3 , total integrated cost =  3.5998620245341932
# RUN  4 , total integrated cost =  3.5079165288316405
# RUN  5 , total integrated cost =  3.5096074030038418
# RUN  6 , total integrated cost =  3.5890832914619892
# RUN  7 , total integrated cost =  3.5721152186692318
# RUN  8 , total integrated cost =  3.5580846392753585
# RUN  9 , total integrated cost =  2.5779470447362653
# RUN  10 , total integrated cost =  2.4589482512541703
# RUN  10 , total integrated cost =  2.4589482512541703
# Improved over  10  iterations in  0.6319599529961124  seconds by  37.192014367770554  percent.
# interpolate adjoint :  True True True
# initial cost =  154.20770956230248
# RUN  0 , total integrated cost =  154.20770956230248
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.943087902433067
# RUN  2 , total integrated cost =  9.074305902460402
# RUN  3 , total integrated cost =  8.809875385925107
# RUN  4 , total integrated cost =  8.810058142896802
# RUN  5 , total integrated cost =  6.462480024653546
# RUN  6 , total integrated cost =  5.343281405209876
# RUN  7 , total integrated cost =  5.0220862865112705
# RUN  8 , total integrated cost =  5.4130090276603
# RUN  9 , total integrated cost =  5.509791811346104
# RUN  10 , total integrated cost =  5.713048105466204
# RUN  10 , total integrated cost =  5.713048105466204
# Improved over  10  iterations in  0.613330882973969  seconds by  96.29522536734258  percent.
# -------- 98
# interpolate adjoint :  True True True
# initial cost =  106.23676634920018
# RUN  0 , total integrated cost =  106.23676634920018
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.389859999273387
# RUN  2 , total integrated cost =  4.376945470292513
# RUN  3 , total integrated cost =  3.458725876022009
# RUN  4 , total integrated cost =  3.1449067260354013
# RUN  5 , total integrated cost =  3.6969199422681185
# RUN  5 , total integrated cost =  3.6969199422681185
# Improved over  5  iterations in  0.1320834970101714  seconds by  96.52011250971594  percent.
# interpolate adjoint :  True True True
# initial cost =  3.7271031936712777
# RUN  0 , total integrated cost =  3.7271031936712777
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.9873896137711453
# RUN  2 , total integrated cost =  3.0313070470126924
# RUN  3 , total integrated cost =  2.9648337308661827
# RUN  4 , total integrated cost =  3.228473511536878
# RUN  5 , total integrated cost =  2.933579555970573
# RUN  6 , total integrated cost =  2.965671756830914
# RUN  7 , total integrated cost =  3.060673306152609
# RUN  8 , total integrated cost =  2.9374981567357823
# RUN  9 , total integrated cost =  2.9475169244754627
# RUN  10 , total integrated cost =  2.9438185875339205
# RUN  10 , total integrated cost =  2.9438185875339205
# Improved over  10  iterations in  0.5414948490215465  seconds by  21.015908748311446  percent.
# interpolate adjoint :  True True True
# initial cost =  68.18582570536223
# RUN  0 , total integrated cost =  68.18582570536223
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.1262945847565
# RUN  2 , total integrated cost =  9.438956691899772
# RUN  3 , total integrated cost =  6.543149083385522
# RUN  4 , total integrated cost =  5.898031497064726
# RUN  5 , total integrated cost =  4.45558499386724
# RUN  6 , total integrated cost =  4.6579550765482045
# RUN  7 , total integrated cost =  4.83252804137771
# RUN  8 , total integrated cost =  4.905463172455249
# RUN  9 , total integrated cost =  4.753027010022152
# RUN  10 , total integrated cost =  4.551465682299128
# RUN  10 , total integrated cost =  4.551465682299128
# Improved over  10  iterations in  0.6025190170039423  seconds by  93.32490934117823  percent.
# -------- 99
# interpolate adjoint :  True True True
# initial cost =  56.21551065113546
# RUN  0 , total integrated cost =  56.21551065113546
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.174985764973348
# RUN  2 , total integrated cost =  4.2530465609629315
# RUN  3 , total integrated cost =  3.8262598215595913
# RUN  4 , total integrated cost =  3.8082756172416805
# RUN  5 , total integrated cost =  3.781523477896399
# RUN  5 , total integrated cost =  3.781523477896399
# Improved over  5  iterations in  0.14334974199300632  seconds by  93.27316707774135  percent.
# interpolate adjoint :  True True True
# initial cost =  3.788377013523127
# RUN  0 , total integrated cost =  3.788377013523127
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.8133269844364768
# RUN  2 , total integrated cost =  3.301644432590118
# RUN  3 , total integrated cost =  3.0574639784053215
# RUN  4 , total integrated cost =  3.125187058787948
# step size too small or too large
# RUN  5 , total integrated cost =  2.913651623849616
# RUN  6 , total integrated cost =  2.80022338807913
# RUN  7 , total integrated cost =  2.8463390205915404
# RUN  8 , total integrated cost =  2.849978500134154
# RUN  9 , total integrated cost =  3.3212255749985573
# RUN  10 , total integrated cost =  3.3046510972618526
# RUN  10 , total integrated cost =  3.3046510972618526
# Improved over  10  iterations in  0.6885479739867151  seconds by  12.768684704150331  percent.
# interpolate adjoint :  True True True
# initial cost =  111.33130708612396
# RUN  0 , total integrated cost =  111.33130708612396
# Gradient descend method:  None
# RUN  1 , total integrated cost =  10.901891525699547
# RUN  2 , total integrated cost =  14.62715117332251
# RUN  3 , total integrated cost =  12.323673461182034
# RUN  4 , total integrated cost =  10.487566172200808
# RUN  5 , total integrated cost =  9.534884030746497
# RUN  6 , total integrated cost =  8.867260901246164
# RUN  7 , total integrated cost =  9.624599397133368
# RUN  8 , total integrated cost =  9.674673158274219
# RUN  9 , total integrated cost =  10.028141367942386
# RUN  10 , total integrated cost =  9.86716397852938
# RUN  10 , total integrated cost =  9.86716397852938
# Improved over  10  iterations in  0.6820970720145851  seconds by  91.1371165606667  percent.
# -------- 99
# interpolate adjoint :  True True True
# initial cost =  98.86536445081033
# RUN  0 , total integrated cost =  98.86536445081033
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.189368566260923
# RUN  2 , total integrated cost =  3.7495682986270444
# RUN  3 , total integrated cost =  3.693966352484342
# RUN  4 , total integrated cost =  3.784735240884553
# RUN  5 , total integrated cost =  2.763188806208574
# RUN  5 , total integrated cost =  2.763188806208574
# Improved over  5  iterations in  0.1428161800140515  seconds by  97.20509925638986  percent.
# interpolate adjoint :  True True True
# initial cost =  6.276119342999893
# RUN  0 , total integrated cost =  6.276119342999893
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.2159671765435096
# RUN  2 , total integrated cost =  3.052990161308453
# RUN  3 , total integrated cost =  3.092266706062841
# RUN  4 , total integrated cost =  3.085714968686698
# RUN  5 , total integrated cost =  3.102518461397894
# RUN  6 , total integrated cost =  3.0028455050523357
# RUN  7 , total integrated cost =  2.9870180018143704
# RUN  8 , total integrated cost =  3.304446278471349
# RUN  9 , total integrated cost =  3.2119157104478364
# RUN  10 , total integrated cost =  3.1807237711294736
# RUN  10 , total integrated cost =  3.1807237711294736
# Improved over  10  iterations in  0.5177117619896308  seconds by  49.320215290725585  percent.
# interpolate adjoint :  True True True
# initial cost =  28.403403876298547
# RUN  0 , total integrated cost =  28.403403876298547
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.927090049986891
# RUN  2 , total integrated cost =  5.5993902889020575
# RUN  3 , total integrated cost =  4.8303900396846995
# RUN  4 , total integrated cost =  4.76948529123818
# RUN  5 , total integrated cost =  4.872082416400368
# RUN  6 , total integrated cost =  4.700831044172696
# RUN  7 , total integrated cost =  5.2238281996043945
# RUN  8 , total integrated cost =  4.893000757188049
# RUN  9 , total integrated cost =  4.628822246466594
# RUN  10 , total integrated cost =  4.56186693920892
# RUN  10 , total integrated cost =  4.56186693920892
# Improved over  10  iterations in  0.6475774709833786  seconds by  83.93901322856728  percent.
# mean =  7.981242726951506

# %%
max_it = 15
init_it = 3
min_it = 12
i = 50
factor = [1.09, 1.21, 2.0]

for i_sigma in range(3):
    
    cost.setParams(w_p[i_sigma], w_e, w_s)
    
    for i_noise in range(3):
        
        if i_sigma in []:
            continue
        if i_noise in []:
            continue

        noise_realizations = noise_realizations_array[i_noise]
        sigma_ou = sigma_ou_array[i_sigma]
        aln.params.sigma_ou = sigma_ou
        
        aln.params.duration = dur
        print(noise_realizations)
        
        if i_noise != 0.:

            setinit(initVars[i], aln)

            bestControl, bestState, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                zero_init, target[i_sigma], c_scheme, u_mat, u_scheme, max_iteration_ = init_it,
                tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                control_variables_ = [0], prec_variables_ = prec_vars, transition_time_ = trans_time,
                noise_real=noise_realizations, init_params = initVars[i], method='M2')

            control_init = bestControl[:,:,100:-100].copy()
            setinit(initVars[i], aln)
            aln.params.duration = dur

            bestControl, bestState, c_, runtime, grad, phi, costnode, total_cost_mean_std = aln.A1(
                control_init, target[i_sigma], c_scheme, u_mat, u_scheme, max_iteration_ = max_it-init_it,
                tolerance_ = tol, startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl,
                t_sim_ = dur, t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = None,
                control_variables_ = [0,1], prec_variables_ = prec_vars, transition_time_ = trans_time,
                noise_real=noise_realizations, init_params = initVars[i],method='M2')


            control_[i_sigma][i_noise] = bestControl.copy()
        
        else:
            control_[i_sigma][i_noise] = factor[i_sigma] * init_control_noisefree[i][:,:,1400:3601]
        
        aln.params.duration = dur
        setinit(initVars[i], aln)

        init_control = aln.getZeroControl()   
        
        init_control[:,:,:] = control_[i_sigma][i_noise][:,:,100:-100]
            
        T = int(1 + dur/aln.params.dt)
        dt = aln.params.dt

        target_ = target[i_sigma].copy()
        target_[0,0,:int(trans_time * dur / aln.params.dt)] = -1000
        target_[0,1,:int(trans_time * dur / aln.params.dt)] = -1000

        cost_final = 0.
        cs = cost.numba_cost_sparsity_int(1, 6, T, w_s, dt, init_control)

        for n_ in range(noise_realizations_final):
            state_ = fo.updateState(aln, init_control)
            cost_final += cost.numba_cost_precision_int(1,T,dt,w_p[i_sigma],state_, target_, list(prec_vars) )

        cost_final_mean[i_sigma, i_noise] = cs + cost_final / noise_realizations_final
        print('mean = ', cost_final_mean[i_sigma, i_noise])
# Out:
# set cost params:  0.052145270361592284 0.0 1.0
# 0
# mean =  3.0094647223917814
# 10
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3080.1734397181235
# Gradient descend method:  None
# RUN  1 , total integrated cost =  27.52169054292503
# RUN  2 , total integrated cost =  6.984034682875768
# RUN  3 , total integrated cost =  5.460753388841783
# RUN  3 , total integrated cost mean =  5.460753388841783
# Improved over  3  iterations in  17.39701439498458  seconds by  99.82271279537618  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5.424366176251992
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.130982175097975
# RUN  2 , total integrated cost =  4.8320223596127345
# RUN  3 , total integrated cost =  4.526618219175755
# step size too small or too large
# RUN  4 , total integrated cost =  4.4837235754885185
# RUN  5 , total integrated cost =  4.353605486834682

# %%
i_sigma = 2
i_noise = 0
sigma_ou = sigma_ou_array[i_sigma]
aln.params.sigma_ou = sigma_ou
aln.params.duration = dur
setinit(initVars[i], aln)

for factor in np.arange(1.9, 1.9, 0.1):

    
    init_control = aln.getZeroControl()           
    init_control[:,:,:] = factor * init_control_noisefree[i][:,:,1500:3501]
    T = int(1 + dur/aln.params.dt)
    dt = aln.params.dt

    target_ = target[i_sigma].copy()
    target_[0,0,:int(trans_time * dur / aln.params.dt)] = -1000
    target_[0,1,:int(trans_time * dur / aln.params.dt)] = -1000

    cost_final = np.zeros(( noise_realizations_final ))

    for n_ in range(noise_realizations_final):
        state_ = fo.updateState(aln, init_control)
        cost_final[n_] += cost.numba_cost_precision_int(1,T,dt,w_p,state_, target_, list(prec_vars) )
        cost_final[n_] += cost.numba_cost_sparsity_int(1, 6, T, w_s, dt, init_control)

    print('facotr, mean = ', factor, np.mean(cost_final))
    
factor = [1.09, 1.21, 2.0]
# 1.01, 1.1, 1.5

for i_sigma in range(3):
    control_[i_sigma][i_noise] = factor[i_sigma] * init_control_noisefree[i][:,:,1400:3601]

# %%
fs_ = 26
fig, ax = plt.subplots(6, 3, figsize=(16,18), constrained_layout=True, facecolor='white',
                       gridspec_kw={'height_ratios': [3,2,3,2,3,2]})
#fig.suptitle('Point b', fontsize=fs_)
plot_realizations = 10
i = 50

t_array = np.arange(0,dur+aln.params.dt,aln.params.dt)
ax[0,0].set_title('Multiple of deterministic OC', fontsize=fs_)

setinit(initVars[i], aln)
aln.params.duration = dur
target_ = aln.getZeroTarget()

for i_sigma in range(3):
    
    target_[0,0,:] = target[i_sigma][0,0,-1]
    target_[0,1,:] = target[i_sigma][0,1,-1]
    
    for i_noise in range(3):
        
        noise_realizations = noise_realizations_array[i_noise]
        sigma_ou = sigma_ou_array[i_sigma]
        aln.params.sigma_ou = sigma_ou
        
        if i_noise != 0:
            ax[0,i_noise].set_title(r'$N=$' + '{}'.format(noise_realizations), fontsize=fs_)

        ax[2*i_sigma+1,i_noise].plot( t_array, control_[i_sigma][i_noise][0,0,100:-100]/5., color=exc_red)
        ax[2*i_sigma+1,i_noise].plot( t_array, control_[i_sigma][i_noise][0,1,100:-100]/5., color=inh_blue)
        
        ax[2*i_sigma,i_noise].plot( t_array, target_[0,0,:], linestyle='--', color=exc_red)
        ax[2*i_sigma,i_noise].plot( t_array, target_[0,1,:], linestyle='--', color=inh_blue)

        for indexx in range(plot_realizations):
            aln.run(control=control_[i_sigma][i_noise][:,:,100:-100])
            ax[2*i_sigma,i_noise].plot( t_array, aln.rates_exc[0,:], color=exc_red)
            ax[2*i_sigma,i_noise].plot( t_array, aln.rates_inh[0,:], color=inh_blue)

        ax[2*i_sigma,i_noise].text(0.05, 0.7, r'$F = $' + '{:.2f}'.format(cost_final_mean[i_sigma, i_noise]),
                horizontalalignment='left', verticalalignment='top', transform=ax[2*i_sigma,i_noise].transAxes,
                bbox=dict(boxstyle='round', facecolor=midgrey, alpha=0.3), fontsize=fs_)
        
        ax[2*i_sigma+1,i_noise].text(0.05, 0.9, r'$a = $' + '{:.2f} nA'.format(
            np.amax(np.abs(control_[i_sigma][i_noise][0,0,100:-100]/5.))), horizontalalignment='left',
            verticalalignment='top', transform=ax[2*i_sigma+1,i_noise].transAxes,
            bbox=dict(boxstyle='round', facecolor=midgrey, alpha=0.3), fontsize=fs_)

for j in range(6):
    for k in range(3):
        ax[j,k].tick_params(axis='x', labelsize=fs_)
        ax[j,k].tick_params(axis='y', labelsize=fs_)
        ax[j,k].set_xlim(0,dur)
        ax[j,k].grid(False)
        if j != 5:
            ax[j,k].set_xticks([])
        else:
            ax[j,k].set_xlabel('Time [ms]', fontsize=fs_)
        ax[j,k].set_yticks([])
        if j%2 == 0:
            ax[j,k].set_ylim(0,130)
            sigma_ou = sigma_ou_array[int(j/2)]
            ax[j,k].axvspan( dur*trans_time, dur, facecolor=midgrey,
                            alpha=0.5, zorder=-1, hatch='///', edgecolor = midgrey)
        elif j%2 == 1:
            ax[j,k].set_ylim(-0.15,0.5)
            
    if j%2 == 0:
        ax[j,-1].set_yticks(np.arange(0,140,50))
        ax[j,-1].set_ylabel('Activity [Hz]', fontsize=fs_)
        ax[j,-1].yaxis.set_label_position("right")
        ax[j,-1].yaxis.tick_right()
        ax[j,0].text(-0.1,0.3, r'$\sigma=$'+'{:.2f}'.format(sigma_ou_array[i_sigma]), rotation=90, size=fs_,
                 verticalalignment='bottom', horizontalalignment='center', transform=ax[j,0].transAxes)
    
    elif j%2 == 1:     
        ax[j,-1].set_yticks(np.arange(0.,0.41,0.2))
        ax[j,-1].set_ylabel('Control [nA]', fontsize=fs_)
        ax[j,-1].yaxis.set_label_position("right")
        ax[j,-1].yaxis.tick_right()


filename_ = nb[:-6] + '.png'
    
fig.savefig(filename_)
fig.savefig(os.path.join(savepath, filename_))
plt.show()
