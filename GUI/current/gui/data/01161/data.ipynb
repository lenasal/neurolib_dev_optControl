# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import sys
import pickle

path = os.getcwd().split(os.sep + 'GUI')[0]
if path not in sys.path:
    print("not here")
    sys.path.append(path)

from neurolib.models.aln import ALNModel
from neurolib.utils import plotFunctions as plotFunc
from neurolib.utils import costFunctions as cost
import neurolib.dashboard.functions as functions
import neurolib.dashboard.data as data
    
# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2 

#path = os.path.join(os.getcwd(), "plots")
# Out:
# not here

# %%
# read case
print(os.getcwd())
case = os.getcwd().split(os.sep)[-1]
print(case)
# Out:
# /home/lena/Promotion/neurolib/GUI/current/gui/data/01161
# 01161

# %% [markdown]
# ### Bistability

# %%
aln = ALNModel()
N = aln.params.N

data.set_parameters(aln)

state_vars = aln.state_vars
init_vars = aln.init_vars

##############################################################
def setinit(init_vars_, model):
    state_vars = model.state_vars
    init_vars = model.init_vars
    for iv in range(len(init_vars)):
        for sv in range(len(state_vars)):
            if state_vars[sv] in init_vars[iv]:
                #print("set init vars ", )
                if model.params[init_vars[iv]].ndim == 2:
                    model.params[init_vars[iv]][0,:] = init_vars_[sv]
                else:
                    model.params[init_vars[iv]][0] = init_vars_[sv]
                    
##############################################################               
def setmaxmincontrol(max_c_c, min_c_c, max_c_r, min_c_r):
    import numpy as np
    
    max_cntrl = np.zeros(( 6 ))
    min_cntrl = np.zeros(( 6 ))
    
    max_cntrl[0] = max_c_c
    min_cntrl[0] = min_c_c
    max_cntrl[1] = max_c_c
    min_cntrl[1] = min_c_c
    max_cntrl[2] = max_c_r
    min_cntrl[2] = min_c_r
    max_cntrl[3] = max_c_r
    min_cntrl[3] = min_c_r
    max_cntrl[4] = max_c_r
    min_cntrl[4] = min_c_r
    max_cntrl[5] = max_c_r
    min_cntrl[5] = min_c_r
            
    return max_cntrl, min_cntrl

#####################################################
def getclosest(k_, found_solution, exc, inh, already_tried_):
    import numpy as np
    if len(found_solution) == 0:
        print("no solutions found")
        return -1
    
    start_ind = -1
    for j_ in found_solution:
        if j_ not in already_tried_ and j_ != k_:
            start_ind = j_
            break
            
    if start_ind == -1:
        return -1
        
    min_dist = np.sqrt((exc[k_] - exc[start_ind])**2 + (inh[k_] - inh[start_ind])**2)
    min_i = start_ind
        
    print(found_solution, already_tried_)
        
    if len(found_solution) == len(already_tried_):
        print("already tried all options")
        min_i = -1
        return min_i
    
    for i_ in found_solution:
        if i_ not in already_tried_:
            if i_ != k_ and i_ != min_i:
                dist_ = np.sqrt((exc[k_] - exc[i_])**2 + (inh[k_] - inh[i_])**2)
                if dist_ < min_dist:
                    min_dist = dist_
                    min_i = i_
                    
    if min_i == 0 and 0 in already_tried_:
        return -1
    
    return min_i

# %%
##### LOAD BOUNDARIES
data_file = 'bi.pickle'
with open(data_file,'rb') as f:
    load_array= pickle.load(f)
exc = load_array[0]
inh = load_array[1]
print(len(exc))
#plt.scatter(exc, inh)
# Out:
# 147

# %%
bestControl_init = [None] * len(exc)
bestState_init = [None] * len(exc)
cost_init = [None] * len(exc)
runtime_init = [None] * len(exc)
grad_init = [None] * len(exc)
phi_init = [None] * len(exc)
costnode_init = [None] * len(exc)
weights_init = [None] * len(exc)

conv_init = [[False]*2] * len(exc)

# %%
bestControl_0 = [None] * len(exc)
bestState_0 = [None] * len(exc)
cost_0 = [None] * len(exc)
runtime_0 = [None] * len(exc)
grad_0 = [None] * len(exc)
phi_0 = [None] * len(exc)
costnode_0 = [None] * len(exc)
weights_0 = [None] * len(exc)

conv_0 = [[False]*2] * len(exc)

# %%
bestControl_1 = [None] * len(exc)
bestState_1 = [None] * len(exc)
cost_1 = [None] * len(exc)
runtime_1 = [None] * len(exc)
grad_1 = [None] * len(exc)
phi_1 = [None] * len(exc)
costnode_1 = [None] * len(exc)
weights_1 = [None] * len(exc)

conv_1 = [[False]*2] * len(exc)

# %%
initVars = [None] * len(exc)
target = [None] * len(exc)
cost_uncontrolled = [None] * len(exc)

cgv_list = [None, "HS", "FR", "PR", "CD", "LS", "DY", "WYL", "HZ", None]

# %%
dur_pre = 10
dur_post = 10

n_pre = int(np.around(dur_pre/aln.params.dt + 1.,1))
n_post = int(np.around(dur_post/aln.params.dt + 1.,1))

tol = 1e-32
start_step = 10.
c_scheme = np.zeros(( 1,1 ))
c_scheme[0,0] = 1.
u_mat = np.identity(1)
u_scheme = np.array([[1.]])

c_var = [ [0], [1], [0,1]]
p_var = [ [0], [0], [0]]

### CURRENTS
cntrl_vars_0 = [0,1]
prec_vars = [0]

if case[0] == '0':    # low to high
    max_I = [3., -3.]
elif case[0] == '1':
    max_I = [-3., 3.]
    
if case[1] == '0':    # sparsity
    factor_ws = 1.
    factor_we = 0.
elif case[1] == '1':  # energy
    factor_ws = 0.
    factor_we = 1.
    
if case[3] == '0':
    cntrl_vars_init = [0]
elif case[3] == '1':
    cntrl_vars_init = [1]
elif case[3] == '2':
    cntrl_vars_init = [0,1]
elif case[3] == '3':
    cntrl_vars_init = [0]
    conv_init = [[True]*2] * len(exc)
    case_read = case[0] + case[1] + case[2] + str(int(case[3])-3) + '0'
    read_file = os.path.join( os.getcwd()[:-5], case_read, 'control_init_' + case_read + '.pickle')
elif case[3] == '4':
    cntrl_vars_init = [1]
    conv_init = [[True]*2] * len(exc)
    case_read = case[0] + case[1] + case[2] + str(int(case[3])-3) + '0'
    read_file = os.path.join( os.getcwd()[:-5], case_read, 'control_init_' + case_read + '.pickle')
elif case[3] == '5':
    cntrl_vars_init = [0,1]
    conv_init = [[True]*2] * len(exc)
    case_read = case[0] + case[1] + case[2] + str(int(case[3])-3) + '0'
    read_file = os.path.join( os.getcwd()[:-5], case_read, 'control_init_' + case_read + '.pickle')
elif case[3] == '6':
    cntrl_vars_init = [0]
    conv_init = [[True]*2] * len(exc)
    case_read = case[0] + case[1] + case[2] + str(int(case[3])-6) + '0'
    read_file = os.path.join( os.getcwd()[:-5], case_read, 'control_init_' + case_read + '.pickle')
elif case[3] == '7':
    cntrl_vars_init = [1]
    conv_init = [[True]*2] * len(exc)
    case_read = case[0] + case[1] + case[2] + str(int(case[3])-6) + '0'
    read_file = os.path.join( os.getcwd()[:-5], case_read, 'control_init_' + case_read + '.pickle')
elif case[3] == '8':
    cntrl_vars_init = [0,1]
    conv_init = [[True]*2] * len(exc)
    case_read = case[0] + case[1] + case[2] + str(int(case[3])-6) + '0'
    read_file = os.path.join( os.getcwd()[:-5], case_read, 'control_init_' + case_read + '.pickle')
    
if case[4] == '0':
    dur = 100
    trans_time = 0.8
elif case[4] == '1':
    dur = 400
    trans_time = 0.95
    
maxC = [5., -5., 0.18, 0.]

n_dur = int(np.around(dur/aln.params.dt + 1.,1))
max_cntrl, min_cntrl = setmaxmincontrol(maxC[0], maxC[1], maxC[2], maxC[3])

# %%
init_file = 'control_init_' + case + '.pickle'
final_file = 'control_' + case + '.pickle'
case_1 = case[0] + case[1] + '0' + case[3] + case[4]
final_file_1 = 'control_' + case_1 + '.pickle'

# %%
if os.path.isfile(init_file) :
    print("file found")
    
    with open(init_file,'rb') as f:
        load_array = pickle.load(f)

    bestControl_init = load_array[0]
    bestState_init = load_array[1]
    cost_init = load_array[2]
    runtime_init = load_array[3]
    grad_init = load_array[4]
    phi_init = load_array[5]
    costnode_init = load_array[6]
    weights_init = load_array[7]
# Out:
# file found

# %%
# get initial parameters and target states

i_stepsize = 1
limit = 65
start_index = 60
i_range = range(start_index, limit,i_stepsize)
i_range_0 = range(start_index, limit,i_stepsize)
i_range_1 = range(start_index, limit,i_stepsize)


i_range = [50, 62, 70]
i_range_0 = i_range
i_range_1 = i_range

data.set_parameters(aln)

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    aln.params.duration = 3000.
    
    control0 = aln.getZeroControl()
    control0 = functions.step_control(aln, maxI_ = max_I[0])

    aln.run(control=control0)
    
    target_rates = np.zeros((2))
    target_rates[0] = aln.rates_exc[0,-1] 
    target_rates[1] = aln.rates_inh[0,-1]

    control0 = functions.step_control(aln, maxI_ = max_I[1])
    aln.run(control=control0)

    init_state_vars = np.zeros(( len(state_vars) ))
    for j in range(len(state_vars)):
        if aln.state[state_vars[j]].size == 1:
            init_state_vars[j] = aln.state[state_vars[j]][0]
        else:
            init_state_vars[j] = aln.state[state_vars[j]][0,-1]

    initVars[i] = init_state_vars
    
    aln.params.duration = dur

    target[i] = aln.getZeroTarget()
    target[i][:,0,:] = target_rates[0]
    target[i][:,1,:] = target_rates[1]
# Out:
# -------  50 0.47500000000000014 0.6000000000000003
# -------  62 0.4250000000000001 0.6500000000000004
# -------  70 0.4500000000000001 0.6750000000000004

# %%
# get uncontrolled cost

data.set_parameters(aln)

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    aln.params.duration = dur
        
    cost.setParams(1.0, 0.0, 0.0)

##### zero control as input for uncontrolled cost
    setinit(initVars[i], aln)
    control0 = aln.getZeroControl()

    # "HS", "FR", "PR", "HZ"
    cgv = None
    max_it = 0

    bestControl_init_, bestState_init_, cost_init_, runtime_init_, grad_init_, phi_init_, costnode_init_ = aln.A1(
        control0, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cntrl_vars_init,
        prec_variables_ = prec_vars, transition_time_ = trans_time)
    
    cost_uncontrolled[i] = cost_init_[0]
# Out:
# -------  60 0.5500000000000003 0.6250000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  593096.2936384227
# Gradient descend method:  None
# RUN  0 , total integrated cost =  593096.2936384227
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  61 0.5750000000000002 0.6250000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  693403.3444460082
# Gradient descend method:  None
# RUN  0 , total integrated cost =  693403.3444460082
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  62 0.4250000000000001 0.6500000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  137868.6710720623
# Gradient descend method:  None
# RUN  0 , total integrated cost =  137868.6710720623
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  63 0.4500000000000001 0.6500000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  224297.9659900913
# Gradient descend method:  None
# RUN  0 , total integrated cost =  224297.9659900913
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  64 0.47500000000000014 0.6500000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  310383.3404885133
# Gradient descend method:  None
# RUN  0 , total integrated cost =  310383.3404885133
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.

# %%
factor_iteration = 20.
aln.params.duration = dur

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
        
    ##### zero control as input for uncontrolled cost
    setinit(initVars[i], aln)
    
    if conv_init[i] == [True, True]:
    
        with open(read_file,'rb') as f:
            load_array = pickle.load(f)

        bestControl_read = load_array[0]

        bestControl_init[i] = np.zeros(( 1, 6, n_dur + n_pre + n_post -2 ))
        bestControl_init[i][:,:,n_pre-1+1000:n_pre-1+2000] = bestControl_read[i][:,:,n_pre-1:n_pre-1+1000].copy()
        weights_init = load_array[7]
        
        control0 = bestControl_init[i][:,:,n_pre-1:-n_post+1]   
        cost.setParams(weights_init[i][0], weights_init[i][1], weights_init[i][2])

        
        bestControl_init[i], bestState_init[i], cost_init[i], runtime_init[i], grad_init[i], phi_init[i], costnode_init[i] = aln.A1(
        control0, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = 0, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cntrl_vars_init,
        prec_variables_ = prec_vars, transition_time_ = trans_time)
        
        continue
    
    
    
    if not type(bestControl_init[i]) == type(None):
        continue
        
    control0 = aln.getZeroControl()

    ##### initial guess
    weight_ = 10
    cost.setParams(1.0, weight_ * factor_we, weight_ * factor_ws)

    setinit(initVars[i], aln)

    # "HS", "FR", "PR", "HZ"
    cgv = None
    max_it = int(100 * factor_iteration)

    weights_init[i] = cost.getParams()

    bestControl_init[i], bestState_init[i], cost_init[i], runtime_init[i], grad_init[i], phi_init[i], costnode_init[i] = aln.A1(
        control0, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cntrl_vars_init,
        prec_variables_ = prec_vars, transition_time_ = trans_time)
    
    j = 1
    while cost_init[i][-j] == 0.:
        j += 1
    
    weight_ = 10 * cost_uncontrolled[i] / cost_init[i][-j]
    print("weight = ", weight_)
    cost.setParams(1.0, weight_ * factor_we, weight_ * factor_ws)

    setinit(initVars[i], aln)
    control0 = bestControl_init[i][:,:,n_pre-1:-n_post+1]

    # "HS", "FR", "PR", "HZ"
    cgv = None
    max_it = int(500 * factor_iteration)

    weights_init[i] = cost.getParams()
    
    bestControl_init[i], bestState_init[i], cost_init[i], runtime_init[i], grad_init[i], phi_init[i], costnode_init[i] = aln.A1(
        control0, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cntrl_vars_init,
        prec_variables_ = prec_vars, transition_time_ = trans_time)
        
    with open(init_file,'wb') as f:
        pickle.dump([bestControl_init, bestState_init, cost_init, runtime_init, grad_init, phi_init,
                 costnode_init, weights_init], f)

with open(init_file,'wb') as f:
        pickle.dump([bestControl_init, bestState_init, cost_init, runtime_init, grad_init, phi_init,
                 costnode_init, weights_init], f)
# Out:
# -------  60 0.5500000000000003 0.6250000000000003
# set cost params:  1.0 59092.273940340936 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  146551.7065435314
# Gradient descend method:  None
# RUN  0 , total integrated cost =  146551.7065435314
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  61 0.5750000000000002 0.6250000000000003
# set cost params:  1.0 304932.05737392674 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  167929.53974072498
# Gradient descend method:  None
# RUN  0 , total integrated cost =  167929.53974072498
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  62 0.4250000000000001 0.6500000000000004
# set cost params:  1.0 1158.1953031943615 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  34391.481991423825
# Gradient descend method:  None
# RUN  0 , total integrated cost =  34391.481991423825
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  63 0.4500000000000001 0.6500000000000004
# set cost params:  1.0 2516.2654928443562 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  55991.851651222074
# Gradient descend method:  None
# RUN  0 , total integrated cost =  55991.851651222074
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  64 0.47500000000000014 0.6500000000000004
# set cost params:  1.0 4791.758280162424 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  77335.8138199754
# Gradient descend method:  None
# RUN  0 , total integrated cost =  77335.8138199754
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.

# %%
#plot initial guesses
for i in i_range:
    print("---------", i)
        
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.

    plotFunc.plot_control_current(aln, [bestControl_init[i]],
        [costnode_init[i]], [weights_init[i]], dur,
        dur_pre, dur_post, initVars[i], target[i], '', filename_ = '', transition_time_ = trans_time,
        labels_ = ["init", "sparse control" + str(i)], print_cost_ = False)
    plt.show()
# Out:
# --------- 60
# --------- 61
# --------- 62
# --------- 63
# --------- 64

# %%
found_solution = []
no_solution = []
factor_iteration = 20.

for i in i_range:
    print("------- ", i, exc[i], inh[i])    

    if np.abs(np.mean(bestState_init[i][0,0,-300:]) - target[i][0,0,-1]) < 0.1 * np.abs(
        np.mean(bestState_init[i][0,0,-100:]) - bestState_init[i][0,0,0]) and np.abs(
        np.mean(bestState_init[i][0,1,-300:]) - target[i][0,1,-1]) < 0.1 * np.abs(
        np.mean(bestState_init[i][0,1,-100:]) - bestState_init[i][0,1,0]) and np.amax(
        bestState_init[i][0,0,:]) < target[i][0,0,-1] + 5. and np.amax(
        bestState_init[i][0,1,:]) < target[i][0,1,-1] + 5.:
        # and np.amin(bestState_init[i][0,0,:]) > bestState_init[i][0,0,0] - 1.
        #and np.amin(bestState_init[i][0,1,:]) > bestState_init[i][0,1,0] - 1.:
        if i not in found_solution:
            print("found solution for ", i)
            found_solution.append(i)
        if i in no_solution:
            no_solution.pop(no_solution.index(i))
# Out:
# -------  60 0.5500000000000003 0.6250000000000003
# found solution for  60
# -------  61 0.5750000000000002 0.6250000000000003
# found solution for  61
# -------  62 0.4250000000000001 0.6500000000000004
# found solution for  62
# -------  63 0.4500000000000001 0.6500000000000004
# found solution for  63
# -------  64 0.47500000000000014 0.6500000000000004
# found solution for  64

# %%
if os.path.isfile(final_file) :
    print("file found")
    
    with open(final_file,'rb') as f:
        load_array = pickle.load(f)

    bestControl_0 = load_array[0]
    bestState_0 = load_array[1]
    cost_0 = load_array[2]
    runtime_0 = load_array[3]
    grad_0 = load_array[4]
    phi_0 = load_array[5]
    costnode_0 = load_array[6]
    weights_0 = load_array[7]
# Out:
# file found

# %%
factor_iteration = 6
conv_0 = [[False]*2] * len(exc)
full_converge = False

for i in range(len(conv_0)):
    if i not in i_range_0:
        conv_0[i] = [True, True]

counter = 0

while full_converge == False:
    print('---------------', counter)
    
    if counter > 6:
        break
    
    print(conv_0[start_index:limit:i_stepsize])
    full_converge = True
    
    for conv in conv_0[start_index:limit:i_stepsize]:
        if not conv[0]:
            full_converge = False
            break
        if not conv[1]:
            full_converge = False
            break
    
    if full_converge:
        print("full convergence")
        break
        
    counter += 1
    
    for i in i_range_0:
        print("------- ", i, exc[i], inh[i])
        
        if conv_0[i] == [True, True]:
            continue
            
        aln.params.ext_exc_current = exc[i] * 5.
        aln.params.ext_inh_current = inh[i] * 5.

    # exc and inh control current 

        setinit(initVars[i], aln)
        aln.params.duration = dur

        if not type(bestControl_0[i]) == type(None):
            control0 = bestControl_0[i][:,:,n_pre-1:-n_post+1]
        else:
            control0 = bestControl_init[i][:,:,n_pre-1:-n_post+1].copy()
            weights_0[i] = weights_init[i]
            cost_0[i] = cost_init[i]

        cgv = None
        max_it = 500 * factor_iteration

        j = 1
        while cost_0[i][-j] == 0.:
            j += 1

        weight_ = (factor_we * weights_0[i][1] * cost_uncontrolled[i] / cost_0[i][-j]
                           + factor_ws * weights_0[i][2] * cost_uncontrolled[i] / cost_0[i][-j]) - 1
        print("weight = ", weight_)
        cost.setParams(1.0, weight_ * factor_we, weight_ * factor_ws)

        weights_0[i] = cost.getParams()

        bestControl_0[i], bestState_0[i], cost_0[i], runtime_0[i], grad_0[i], phi_0[i], costnode_0[i] = aln.A1(
            control0, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cntrl_vars_0,
            prec_variables_ = prec_vars, transition_time_ = trans_time)

        with open(final_file,'wb') as f:
            pickle.dump([bestControl_0, bestState_0, cost_0, runtime_0, grad_0, phi_0,
                     costnode_0, weights_0], f)
            
        if j == cost_0[i].shape[0]-1:
            print("converged for ", i)
            if conv_0[i][0]:
                conv_0[i] = [True, True]
            else:
                conv_0[i] = [True, False]
            continue
    
        print("no convergence")
# Out:
# --------------- 0
# [[False, False], [False, False], [False, False], [False, False], [False, False]]
# -------  60 0.5500000000000003 0.6250000000000003
# weight =  292492.74846346176
# set cost params:  1.0 292492.74846346176 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  593094.2659149453
# Gradient descend method:  None
# RUN  1 , total integrated cost =  593094.2659149448
# RUN  2 , total integrated cost =  593094.2659149448
# Control only changes marginally.
# RUN  2 , total integrated cost =  593094.2659149448
# Improved over  2  iterations in  0.8258792069973424  seconds by  7.105427357601002e-14  percent.
# no convergence
# -------  61 0.5750000000000002 0.6250000000000003
# weight =  1259103.9123241648
# set cost params:  1.0 1259103.9123241648 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  693402.7937346782
# Gradient descend method:  None
# RUN  1 , total integrated cost =  489873.35894042155
# RUN  2 , total integrated cost =  481864.1899629585
# RUN  3 , total integrated cost =  481747.08433827077
# RUN  4 , total integrated cost =  481742.25151419314
# RUN  5 , total integrated cost =  481728.74141494266
# RUN  6 , total integrated cost =  481726.8114051021
# RUN  7 , total integrated cost =  481714.804291092
# RUN  8 , total integrated cost =  481687.92007925775
# RUN  9 , total integrated cost =  480135.8551353755
# RUN  10 , total integrated cost =  480022.2847124987
# RUN  11 , total integrated cost =  480021.97740991635
# RUN  12 , total integrated cost =  480020.65106548945
# RUN  13 , total integrated cost =  480016.73542791064
# RUN  14 , total integrated cost =  480015.33227132336
# RUN  15 , total integrated cost =  480011.49971547973
# RUN  16 , total integrated cost =  480010.01375542005
# RUN  17 , total integrated cost =  480006.00879088545
# RUN  18 , total integrated cost =  480004.6834084482
# RUN  19 , total integrated cost =  480000.24240972
# RUN  20 , total integrated cost =  479998.8305539355
# RUN  30 , total integrated cost =  479797.19092450535
# RUN  40 , total integrated cost =  479228.09444776154
# RUN  50 , total integrated cost =  479207.83740606514
# RUN  60 , total integrated cost =  479186.2987379565
# RUN  70 , total integrated cost =  479159.0193847641
# RUN  80 , total integrated cost =  479134.091038539
# RUN  90 , total integrated cost =  479110.63272958196
# RUN  100 , total integrated cost =  479089.8628186947
# RUN  110 , total integrated cost =  479067.3036036228
# RUN  120 , total integrated cost =  479047.42353091703
# RUN  130 , total integrated cost =  479028.86397892656
# RUN  140 , total integrated cost =  479006.4425186705
# RUN  150 , total integrated cost =  478991.63060210354
# RUN  160 , total integrated cost =  478975.01538599055
# RUN  170 , total integrated cost =  478956.4534435054
# RUN  180 , total integrated cost =  478932.9759641201
# RUN  190 , total integrated cost =  478919.2813174127
# RUN  200 , total integrated cost =  478901.23177926557
# Control only changes marginally.
# RUN  207 , total integrated cost =  478901.21494186646
# Improved over  207  iterations in  57.26100213394966  seconds by  30.93462857821828  percent.
# no convergence
# -------  62 0.4250000000000001 0.6500000000000004
# weight =  4641.976633956335
# set cost params:  1.0 4641.976633956335 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  137838.9770455915
# Gradient descend method:  None
# RUN  1 , total integrated cost =  135900.8131615771
# RUN  2 , total integrated cost =  135879.66319425343
# RUN  3 , total integrated cost =  130124.79696944435
# RUN  4 , total integrated cost =  127667.42684523783
# RUN  5 , total integrated cost =  127623.26563235206
# RUN  6 , total integrated cost =  127623.20610369301
# RUN  7 , total integrated cost =  127623.20585791726
# RUN  8 , total integrated cost =  127623.20585791708
# RUN  9 , total integrated cost =  127623.20585791708
# Control only changes marginally.
# RUN  9 , total integrated cost =  127623.20585791708
# Improved over  9  iterations in  3.230011377017945  seconds by  7.411380588159375  percent.
# no convergence
# -------  63 0.4500000000000001 0.6500000000000004
# weight =  10078.917261027485
# set cost params:  1.0 10078.917261027485 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  224275.714025102
# Gradient descend method:  None
# RUN  1 , total integrated cost =  220519.03495821636
# RUN  2 , total integrated cost =  220465.21951237277
# RUN  3 , total integrated cost =  220462.90256579654
# RUN  4 , total integrated cost =  220462.8913918054
# RUN  5 , total integrated cost =  220462.86932460492
# RUN  6 , total integrated cost =  220457.03369003008
# RUN  7 , total integrated cost =  219993.73866327916
# RUN  8 , total integrated cost =  219987.02739840967
# RUN  9 , total integrated cost =  219986.86607398256
# RUN  10 , total integrated cost =  219986.85900178034
# RUN  11 , total integrated cost =  219986.8585767433
# RUN  12 , total integrated cost =  219986.85721753255
# RUN  13 , total integrated cost =  219986.85685639596
# RUN  14 , total integrated cost =  219986.85542226586
# RUN  15 , total integrated cost =  219986.85501301443
# RUN  16 , total integrated cost =  219986.853551445
# RUN  17 , total integrated cost =  219986.85316951948
# RUN  18 , total integrated cost =  219986.85172977
# RUN  19 , total integrated cost =  219986.85132610478
# RUN  20 , total integrated cost =  219986.84990846273
# RUN  30 , total integrated cost =  219891.60691729953
# RUN  40 , total integrated cost =  219891.59646273922
# RUN  50 , total integrated cost =  219744.1909277702
# RUN  60 , total integrated cost =  219744.18102986494
# RUN  70 , total integrated cost =  219744.17327560895
# RUN  80 , total integrated cost =  219744.16368428592
# RUN  90 , total integrated cost =  219239.50039011252
# Control only changes marginally.
# RUN  95 , total integrated cost =  219239.50038752108
# Improved over  95  iterations in  33.016281118034385  seconds by  2.245545693376883  percent.
# no convergence
# -------  64 0.47500000000000014 0.6500000000000004
# weight =  19230.477220533885
# set cost params:  1.0 19230.477220533885 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  310367.2011489859
# Gradient descend method:  None
# RUN  1 , total integrated cost =  303996.71470758214
# RUN  2 , total integrated cost =  303757.20330675424
# RUN  3 , total integrated cost =  303743.6028991376
# RUN  4 , total integrated cost =  303743.51258716447
# RUN  5 , total integrated cost =  303347.1642833533
# RUN  6 , total integrated cost =  299534.4726651247
# RUN  7 , total integrated cost =  299416.46318358247
# RUN  8 , total integrated cost =  299413.7819484586
# RUN  9 , total integrated cost =  299413.64579291013
# RUN  10 , total integrated cost =  299413.6422177021
# RUN  11 , total integrated cost =  299413.6421442724
# RUN  12 , total integrated cost =  299413.6421442722
# RUN  13 , total integrated cost =  299413.6421442722
# Control only changes marginally.
# RUN  13 , total integrated cost =  299413.6421442722
# Improved over  13  iterations in  4.729655114002526  seconds by  3.5292256927160253  percent.
# no convergence
# --------------- 1
# [[False, False], [False, False], [False, False], [False, False], [False, False]]
# -------  60 0.5500000000000003 0.6250000000000003
# weight =  292492.7484637101
# set cost params:  1.0 292492.7484637101 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  593094.265915448
# Gradient descend method:  None
# RUN  1 , total integrated cost =  593094.2659154478
# RUN  2 , total integrated cost =  593094.2659154478
# Control only changes marginally.
# RUN  2 , total integrated cost =  593094.2659154478
# Improved over  2  iterations in  1.794610129960347  seconds by  2.842170943040401e-14  percent.
# no convergence
# -------  61 0.5750000000000002 0.6250000000000003
# weight =  1823061.5368461646
# set cost params:  1.0 1823061.5368461646 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  693402.2689198619
# Gradient descend method:  None
# RUN  1 , total integrated cost =  693402.1412678229
# RUN  2 , total integrated cost =  693402.1412032403
# RUN  3 , total integrated cost =  693402.1412032392
# RUN  4 , total integrated cost =  693402.141203239
# RUN  5 , total integrated cost =  693402.141203239
# Control only changes marginally.
# RUN  5 , total integrated cost =  693402.141203239
# Improved over  5  iterations in  3.4266682909801602  seconds by  1.8418835452393978e-05  percent.
# no convergence
# -------  62 0.4250000000000001 0.6500000000000004
# weight =  5013.629944209505
# set cost params:  1.0 5013.629944209505 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  137841.17713631628
# Gradient descend method:  None
# RUN  1 , total integrated cost =  137841.17712092196
# RUN  2 , total integrated cost =  137841.1771209013
# RUN  3 , total integrated cost =  137841.17712090106
# RUN  4 , total integrated cost =  137841.17712090106
# Control only changes marginally.
# RUN  4 , total integrated cost =  137841.17712090106
# Improved over  4  iterations in  2.754210832004901  seconds by  1.1183317383256508e-08  percent.
# no convergence
# -------  63 0.4500000000000001 0.6500000000000004
# weight =  10310.465940375601
# set cost params:  1.0 10310.465940375601 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  224276.21369362774
# Gradient descend method:  None
# RUN  1 , total integrated cost =  224276.21369353443
# RUN  2 , total integrated cost =  224276.2136935339
# RUN  3 , total integrated cost =  224276.2136935338
# RUN  4 , total integrated cost =  224276.2136935338
# Control only changes marginally.
# RUN  4 , total integrated cost =  224276.2136935338
# Improved over  4  iterations in  2.62862806400517  seconds by  4.189359970041551e-11  percent.
# no convergence
# -------  64 0.47500000000000014 0.6500000000000004
# weight =  19934.02939996801
# set cost params:  1.0 19934.02939996801 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  310367.77073945646
# Gradient descend method:  None
# RUN  1 , total integrated cost =  310367.7707394562
# RUN  2 , total integrated cost =  310367.7707394562
# Control only changes marginally.
# RUN  2 , total integrated cost =  310367.7707394562
# Improved over  2  iterations in  1.838830863009207  seconds by  8.526512829121202e-14  percent.
# no convergence
# --------------- 2
# [[False, False], [False, False], [False, False], [False, False], [False, False]]
# -------  60 0.5500000000000003 0.6250000000000003
# weight =  292492.74846371025
# set cost params:  1.0 292492.74846371025 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  593094.2659154483
# Gradient descend method:  None
# RUN  1 , total integrated cost =  593094.2659154482
# RUN  2 , total integrated cost =  593094.2659154482
# Control only changes marginally.
# RUN  2 , total integrated cost =  593094.2659154482
# Improved over  2  iterations in  1.6626387040014379  seconds by  2.842170943040401e-14  percent.
# no convergence
# -------  61 0.5750000000000002 0.6250000000000003
# weight =  1823063.7003576132
# set cost params:  1.0 1823063.7003576132 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  693402.9640930175
# Gradient descend method:  None
# RUN  1 , total integrated cost =  693402.9640930175
# Control only changes marginally.
# RUN  1 , total integrated cost =  693402.9640930175
# Improved over  1  iterations in  0.8089168779551983  seconds by  0.0  percent.
# no convergence
# -------  62 0.4250000000000001 0.6500000000000004
# weight =  5013.629968293061
# set cost params:  1.0 5013.629968293061 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  137841.17778303794
# Gradient descend method:  None
# RUN  1 , total integrated cost =  137841.17778303762
# RUN  2 , total integrated cost =  137841.17778303756
# RUN  3 , total integrated cost =  137841.17778303756
# Control only changes marginally.
# RUN  3 , total integrated cost =  137841.17778303756
# Improved over  3  iterations in  2.4401229880168103  seconds by  2.8421709430404007e-13  percent.
# no convergence
# -------  63 0.4500000000000001 0.6500000000000004
# weight =  10310.465940817412
# set cost params:  1.0 10310.465940817412 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  224276.21370314423
# Gradient descend method:  None
# RUN  1 , total integrated cost =  224276.21370314396
# RUN  2 , total integrated cost =  224276.21370314385
# RUN  3 , total integrated cost =  224276.21370314385
# Control only changes marginally.
# RUN  3 , total integrated cost =  224276.21370314385
# Improved over  3  iterations in  2.413390204019379  seconds by  1.7053025658242404e-13  percent.
# no convergence
# -------  64 0.47500000000000014 0.6500000000000004
# weight =  19934.029400176525
# set cost params:  1.0 19934.029400176525 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  310367.7707427026
# Gradient descend method:  None
# RUN  1 , total integrated cost =  310367.7707427021
# RUN  2 , total integrated cost =  310367.77074270195
# RUN  3 , total integrated cost =  310367.7707427019
# RUN  4 , total integrated cost =  310367.7707427019
# Control only changes marginally.
# RUN  4 , total integrated cost =  310367.7707427019
# Improved over  4  iterations in  2.992686641984619  seconds by  2.2737367544323206e-13  percent.
# no convergence
# --------------- 3
# [[False, False], [False, False], [False, False], [False, False], [False, False]]
# -------  60 0.5500000000000003 0.6250000000000003
# weight =  292492.7484637103
# set cost params:  1.0 292492.7484637103 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  593094.2659154483
# Gradient descend method:  None
# RUN  1 , total integrated cost =  593094.2659154483
# Control only changes marginally.
# RUN  1 , total integrated cost =  593094.2659154483
# Improved over  1  iterations in  0.6449098630109802  seconds by  0.0  percent.
# no convergence
# -------  61 0.5750000000000002 0.6250000000000003
# weight =  1823063.7003644872
# set cost params:  1.0 1823063.7003644872 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  693402.964095632
# Gradient descend method:  None
# RUN  1 , total integrated cost =  693402.9640956316
# RUN  2 , total integrated cost =  693402.9640956316
# Control only changes marginally.
# RUN  2 , total integrated cost =  693402.9640956316
# Improved over  2  iterations in  1.3115689540281892  seconds by  5.684341886080802e-14  percent.
# converged for  61
# -------  62 0.4250000000000001 0.6500000000000004
# weight =  5013.629968293049
# set cost params:  1.0 5013.629968293049 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  137841.1777830373
# Gradient descend method:  None
# RUN  1 , total integrated cost =  137841.17778303724
# RUN  2 , total integrated cost =  137841.17778303724
# Control only changes marginally.
# RUN  2 , total integrated cost =  137841.17778303724
# Improved over  2  iterations in  1.3392663929844275  seconds by  4.263256414560601e-14  percent.
# no convergence
# -------  63 0.4500000000000001 0.6500000000000004
# weight =  10310.465940817428
# set cost params:  1.0 10310.465940817428 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  224276.21370314425
# Gradient descend method:  None
# RUN  1 , total integrated cost =  224276.21370314425
# Control only changes marginally.
# RUN  1 , total integrated cost =  224276.21370314425
# Improved over  1  iterations in  0.7452503620297648  seconds by  0.0  percent.
# no convergence
# -------  64 0.47500000000000014 0.6500000000000004
# weight =  19934.029400176572
# set cost params:  1.0 19934.029400176572 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  310367.77074270276
# Gradient descend method:  None
# RUN  1 , total integrated cost =  310367.77074270276
# Control only changes marginally.
# RUN  1 , total integrated cost =  310367.77074270276
# Improved over  1  iterations in  0.9027429989655502  seconds by  0.0  percent.
# no convergence
# --------------- 4
# [[False, False], [True, False], [False, False], [False, False], [False, False]]
# -------  60 0.5500000000000003 0.6250000000000003
# weight =  292492.7484637103
# set cost params:  1.0 292492.7484637103 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  593094.2659154483
# Gradient descend method:  None
# RUN  1 , total integrated cost =  593094.2659154483
# Control only changes marginally.
# RUN  1 , total integrated cost =  593094.2659154483
# Improved over  1  iterations in  0.787454295961652  seconds by  0.0  percent.
# converged for  60
# -------  61 0.5750000000000002 0.6250000000000003
# weight =  1823063.7003644884
# set cost params:  1.0 1823063.7003644884 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  693402.9640956323
# Gradient descend method:  None
# RUN  1 , total integrated cost =  693402.9640956313
# RUN  2 , total integrated cost =  693402.9640956309
# RUN  3 , total integrated cost =  693402.9640956309
# Control only changes marginally.
# RUN  3 , total integrated cost =  693402.9640956309
# Improved over  3  iterations in  1.8191487650037743  seconds by  1.9895196601282805e-13  percent.
# no convergence
# -------  62 0.4250000000000001 0.6500000000000004
# weight =  5013.629968293049
# set cost params:  1.0 5013.629968293049 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  137841.17778303724
# Gradient descend method:  None
# RUN  1 , total integrated cost =  137841.17778303724
# Control only changes marginally.
# RUN  1 , total integrated cost =  137841.17778303724
# Improved over  1  iterations in  0.8325729419593699  seconds by  0.0  percent.
# no convergence
# -------  63 0.4500000000000001 0.6500000000000004
# weight =  10310.465940817425
# set cost params:  1.0 10310.465940817425 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  224276.2137031442
# Gradient descend method:  None
# RUN  1 , total integrated cost =  224276.2137031442
# Control only changes marginally.
# RUN  1 , total integrated cost =  224276.2137031442
# Improved over  1  iterations in  0.7989687719964422  seconds by  0.0  percent.
# converged for  63
# -------  64 0.47500000000000014 0.6500000000000004
# weight =  19934.029400176565
# set cost params:  1.0 19934.029400176565 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  310367.77074270265
# Gradient descend method:  None
# RUN  1 , total integrated cost =  310367.77074270265
# Control only changes marginally.
# RUN  1 , total integrated cost =  310367.77074270265
# Improved over  1  iterations in  0.7097653929959051  seconds by  0.0  percent.
# converged for  64
# --------------- 5
# [[True, False], [True, False], [False, False], [True, False], [True, False]]
# -------  60 0.5500000000000003 0.6250000000000003
# weight =  292492.7484637103
# set cost params:  1.0 292492.7484637103 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  593094.2659154483
# Gradient descend method:  None
# RUN  1 , total integrated cost =  593094.2659154483
# Control only changes marginally.
# RUN  1 , total integrated cost =  593094.2659154483
# Improved over  1  iterations in  0.683299783966504  seconds by  0.0  percent.
# converged for  60
# -------  61 0.5750000000000002 0.6250000000000003
# weight =  1823063.7003644914
# set cost params:  1.0 1823063.7003644914 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  693402.9640956327
# Gradient descend method:  None
# RUN  1 , total integrated cost =  693402.9640956327
# Control only changes marginally.
# RUN  1 , total integrated cost =  693402.9640956327
# Improved over  1  iterations in  0.6671673569944687  seconds by  0.0  percent.
# no convergence
# -------  62 0.4250000000000001 0.6500000000000004
# weight =  5013.629968293049
# set cost params:  1.0 5013.629968293049 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  137841.17778303724
# Gradient descend method:  None
# RUN  1 , total integrated cost =  137841.17778303724
# Control only changes marginally.
# RUN  1 , total integrated cost =  137841.17778303724
# Improved over  1  iterations in  0.6492496699793264  seconds by  0.0  percent.
# converged for  62
# -------  63 0.4500000000000001 0.6500000000000004
# weight =  10310.465940817425
# set cost params:  1.0 10310.465940817425 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  224276.2137031442
# Gradient descend method:  None
# RUN  1 , total integrated cost =  224276.2137031442
# Control only changes marginally.
# RUN  1 , total integrated cost =  224276.2137031442
# Improved over  1  iterations in  0.7503611360443756  seconds by  0.0  percent.
# converged for  63
# -------  64 0.47500000000000014 0.6500000000000004
# weight =  19934.029400176565
# set cost params:  1.0 19934.029400176565 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  310367.77074270265
# Gradient descend method:  None
# RUN  1 , total integrated cost =  310367.77074270265
# Control only changes marginally.
# RUN  1 , total integrated cost =  310367.77074270265
# Improved over  1  iterations in  0.6534870339673944  seconds by  0.0  percent.
# converged for  64
# --------------- 6
# [[True, True], [True, False], [True, False], [True, True], [True, True]]
# -------  60 0.5500000000000003 0.6250000000000003
# -------  61 0.5750000000000002 0.6250000000000003
# weight =  1823063.70036449
# set cost params:  1.0 1823063.70036449 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  693402.964095632
# Gradient descend method:  None
# RUN  1 , total integrated cost =  693402.964095632
# Control only changes marginally.
# RUN  1 , total integrated cost =  693402.964095632
# Improved over  1  iterations in  0.6831363199744374  seconds by  0.0  percent.
# converged for  61
# -------  62 0.4250000000000001 0.6500000000000004
# weight =  5013.629968293049
# set cost params:  1.0 5013.629968293049 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  137841.17778303724
# Gradient descend method:  None
# RUN  1 , total integrated cost =  137841.17778303724
# Control only changes marginally.
# RUN  1 , total integrated cost =  137841.17778303724
# Improved over  1  iterations in  0.6857249890454113  seconds by  0.0  percent.
# converged for  62
# -------  63 0.4500000000000001 0.6500000000000004
# -------  64 0.47500000000000014 0.6500000000000004
# --------------- 7

# %%
"""
for i in i_range_0:
    
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.

    plotFunc.plot_control_current(aln, [bestControl_init[i], bestControl_0[i]],
        [costnode_init[i], costnode_0[i]], [weights_init[i], weights_0[i]], dur,
        dur_pre, dur_post, initVars[i], target[i], '', filename_ = '', transition_time_ = trans_time,
        labels_ = ["init", "sparse control" + str(i)], print_cost_ = False)
"""
# Out:
# '\nfor i in i_range_0:\n    \n    aln.params.ext_exc_current = exc[i] * 5.\n    aln.params.ext_inh_current = inh[i] * 5.\n\n    plotFunc.plot_control_current(aln, [bestControl_init[i], bestControl_0[i]],\n        [costnode_init[i], costnode_0[i]], [weights_init[i], weights_0[i]], dur,\n        dur_pre, dur_post, initVars[i], target[i], \'\', filename_ = \'\', transition_time_ = trans_time,\n        labels_ = ["init", "sparse control" + str(i)], print_cost_ = False)\n'

# %%
if os.path.isfile(final_file_1) :
    print("file found")
    
    with open(final_file_1,'rb') as f:
        load_array = pickle.load(f)

    bestControl_1 = load_array[0]
    bestState_1 = load_array[1]
    cost_1 = load_array[2]
    runtime_1 = load_array[3]
    grad_1 = load_array[4]
    phi_1 = load_array[5]
    costnode_1 = load_array[6]
    weights_1 = load_array[7]
# Out:
# file found

# %%
bestControl_1[50] = 1.2 * bestControl_1[52]

# %%
factor_iteration = 4
conv_1 = [[False]*2] * len(exc)
full_converge = False

for i in range(len(conv_1)):
    if i not in i_range_1:
        conv_1[i] = [True, True]
        
counter = 0

while full_converge == False:
    
    print('---------------', counter)
    if counter > 4:
        break
    
    print(conv_1[start_index:limit:i_stepsize])
    full_converge = True
    
    for conv in conv_1[start_index:limit:i_stepsize]:
        if not conv[0]:
            full_converge = False
            break
        if not conv[1]:
            full_converge = False
            break
    
    if full_converge:
        print("full convergence")
        break

    for i in i_range_1:        

        print("------- ", i, exc[i], inh[i])
        
        if conv_1[i] == [True, True]:
            continue
            
        aln.params.ext_exc_current = exc[i] * 5.
        aln.params.ext_inh_current = inh[i] * 5.
        
        if not type(bestControl_1[i]) == type(None):
            control0 = bestControl_1[i][:,:,n_pre-1:-n_post+1].copy()
        else:
            control0 = bestControl_0[i][:,:,n_pre-1:-n_post+1].copy()
            cost_1[i] = cost_0[i]
        
        cost.setParams(1.0, 1. * factor_we, 1. * factor_ws)

        setinit(initVars[i], aln)

        # "HS", "FR", "PR", "HZ"
        cgv = None
        max_it = int( 500 * factor_iteration )

        weights_1[i] = cost.getParams()

        bestControl_1[i], bestState_1[i], cost_1[i], runtime_1[i], grad_1[i], phi_1[i], costnode_1[i] = aln.A1(
            control0, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cntrl_vars_init,
            prec_variables_ = prec_vars, transition_time_ = trans_time)
        
        with open(final_file_1,'wb') as f:
            pickle.dump([bestControl_1, bestState_1, cost_1, runtime_1, grad_1, phi_1,
                 costnode_1, weights_1], f)
            
        j = 1
        while cost_1[i][-j] == 0.:
            j += 1
            
        if j == cost_1[i].shape[0]-1:
            print("converged for ", i)
            if conv_1[i][0]:
                conv_1[i] = [True, True]
            else:
                conv_1[i] = [True, False]
            continue
    
        print("no convergence")
        
    counter += 1
# Out:
# --------------- 0
# [[True, True], [True, True], [False, False], [True, True], [True, True]]
# -------  50 0.47500000000000014 0.6000000000000003
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11.11079439300552
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.11079439300552
# Control only changes marginally.
# RUN  1 , total integrated cost =  11.11079439300552
# Improved over  1  iterations in  0.10104572400086909  seconds by  0.0  percent.
# converged for  50
# -------  62 0.4250000000000001 0.6500000000000004
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  26.466051038750905
# Gradient descend method:  None
# RUN  1 , total integrated cost =  26.466051038750905
# Control only changes marginally.
# RUN  1 , total integrated cost =  26.466051038750905
# Improved over  1  iterations in  0.10045918800096842  seconds by  0.0  percent.
# converged for  62
# -------  70 0.4500000000000001 0.6750000000000004
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  21.516788451033822
# Gradient descend method:  None
# RUN  1 , total integrated cost =  21.516788451033822
# Control only changes marginally.
# RUN  1 , total integrated cost =  21.516788451033822
# Improved over  1  iterations in  0.09779502400124329  seconds by  0.0  percent.
# converged for  70
# --------------- 1
# [[True, True], [True, True], [True, False], [True, True], [True, True]]
# -------  50 0.47500000000000014 0.6000000000000003
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11.11079439300552
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.11079439300552
# Control only changes marginally.
# RUN  1 , total integrated cost =  11.11079439300552
# Improved over  1  iterations in  0.09466837999934796  seconds by  0.0  percent.
# converged for  50
# -------  62 0.4250000000000001 0.6500000000000004
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  26.466051038750905
# Gradient descend method:  None
# RUN  1 , total integrated cost =  26.466051038750905
# Control only changes marginally.
# RUN  1 , total integrated cost =  26.466051038750905
# Improved over  1  iterations in  0.10858000599910156  seconds by  0.0  percent.
# converged for  62
# -------  70 0.4500000000000001 0.6750000000000004
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  21.516788451033822
# Gradient descend method:  None
# RUN  1 , total integrated cost =  21.516788451033822
# Control only changes marginally.
# RUN  1 , total integrated cost =  21.516788451033822
# Improved over  1  iterations in  0.09937211500073317  seconds by  0.0  percent.
# converged for  70
# --------------- 2
# [[True, True], [True, True], [True, True], [True, True], [True, True]]
# full convergence

# %%
for i in i_range_1:
    print("---------", i)
        
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.

    plotFunc.plot_control_current(aln, [bestControl_1[i]],
        [costnode_1[i]], [weights_1[i]], dur,
        dur_pre, dur_post, initVars[i], target[i], '', filename_ = '', transition_time_ = trans_time,
        labels_ = ["init", "sparse control" + str(i)], print_cost_ = False)
    plt.show()
    break
# Out:
# --------- 50

# %%
bestControl_1[50] = 1. * bestControl_1[55]
