# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import sys
import pickle

path = os.getcwd().split(os.sep + 'GUI')[0]
if path not in sys.path:
    print("not here")
    sys.path.append(path)

from neurolib.models.aln import ALNModel
from neurolib.utils import plotFunctions as plotFunc
from neurolib.utils import costFunctions as cost
import neurolib.dashboard.functions as functions
import neurolib.dashboard.data as data
    
# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2 

#path = os.path.join(os.getcwd(), "plots")
# Out:
# not here

# %%
# read case
print(os.getcwd())
case = os.getcwd().split(os.sep)[-1]
print(case)
# Out:
# /home/lena/Promotion/neurolib/GUI/current/gui/data/01181
# 01181

# %% [markdown]
# ### Bistability

# %%
aln = ALNModel()
N = aln.params.N

data.set_parameters(aln)

state_vars = aln.state_vars
init_vars = aln.init_vars

##############################################################
def setinit(init_vars_, model):
    state_vars = model.state_vars
    init_vars = model.init_vars
    for iv in range(len(init_vars)):
        for sv in range(len(state_vars)):
            if state_vars[sv] in init_vars[iv]:
                #print("set init vars ", )
                if model.params[init_vars[iv]].ndim == 2:
                    model.params[init_vars[iv]][0,:] = init_vars_[sv]
                else:
                    model.params[init_vars[iv]][0] = init_vars_[sv]
                    
##############################################################               
def setmaxmincontrol(max_c_c, min_c_c, max_c_r, min_c_r):
    import numpy as np
    
    max_cntrl = np.zeros(( 6 ))
    min_cntrl = np.zeros(( 6 ))
    
    max_cntrl[0] = max_c_c
    min_cntrl[0] = min_c_c
    max_cntrl[1] = max_c_c
    min_cntrl[1] = min_c_c
    max_cntrl[2] = max_c_r
    min_cntrl[2] = min_c_r
    max_cntrl[3] = max_c_r
    min_cntrl[3] = min_c_r
    max_cntrl[4] = max_c_r
    min_cntrl[4] = min_c_r
    max_cntrl[5] = max_c_r
    min_cntrl[5] = min_c_r
            
    return max_cntrl, min_cntrl

#####################################################
def getclosest(k_, found_solution, exc, inh, already_tried_):
    import numpy as np
    if len(found_solution) == 0:
        print("no solutions found")
        return -1
    
    start_ind = -1
    for j_ in found_solution:
        if j_ not in already_tried_ and j_ != k_:
            start_ind = j_
            break
            
    if start_ind == -1:
        return -1
        
    min_dist = np.sqrt((exc[k_] - exc[start_ind])**2 + (inh[k_] - inh[start_ind])**2)
    min_i = start_ind
        
    print(found_solution, already_tried_)
        
    if len(found_solution) == len(already_tried_):
        print("already tried all options")
        min_i = -1
        return min_i
    
    for i_ in found_solution:
        if i_ not in already_tried_:
            if i_ != k_ and i_ != min_i:
                dist_ = np.sqrt((exc[k_] - exc[i_])**2 + (inh[k_] - inh[i_])**2)
                if dist_ < min_dist:
                    min_dist = dist_
                    min_i = i_
                    
    if min_i == 0 and 0 in already_tried_:
        return -1
    
    return min_i

# %%
##### LOAD BOUNDARIES
data_file = 'bi.pickle'
with open(data_file,'rb') as f:
    load_array= pickle.load(f)
exc = load_array[0]
inh = load_array[1]
print(len(exc))
#plt.scatter(exc, inh)
# Out:
# 147

# %%
bestControl_init = [None] * len(exc)
bestState_init = [None] * len(exc)
cost_init = [None] * len(exc)
runtime_init = [None] * len(exc)
grad_init = [None] * len(exc)
phi_init = [None] * len(exc)
costnode_init = [None] * len(exc)
weights_init = [None] * len(exc)

conv_init = [[False]*2] * len(exc)

# %%
bestControl_0 = [None] * len(exc)
bestState_0 = [None] * len(exc)
cost_0 = [None] * len(exc)
runtime_0 = [None] * len(exc)
grad_0 = [None] * len(exc)
phi_0 = [None] * len(exc)
costnode_0 = [None] * len(exc)
weights_0 = [None] * len(exc)

conv_0 = [[False]*2] * len(exc)

# %%
bestControl_1 = [None] * len(exc)
bestState_1 = [None] * len(exc)
cost_1 = [None] * len(exc)
runtime_1 = [None] * len(exc)
grad_1 = [None] * len(exc)
phi_1 = [None] * len(exc)
costnode_1 = [None] * len(exc)
weights_1 = [None] * len(exc)

conv_1 = [[False]*2] * len(exc)

# %%
initVars = [None] * len(exc)
target = [None] * len(exc)
cost_uncontrolled = [None] * len(exc)

cgv_list = [None, "HS", "FR", "PR", "CD", "LS", "DY", "WYL", "HZ", None]

# %%
dur_pre = 10
dur_post = 10

n_pre = int(np.around(dur_pre/aln.params.dt + 1.,1))
n_post = int(np.around(dur_post/aln.params.dt + 1.,1))

tol = 1e-32
start_step = 10.
c_scheme = np.zeros(( 1,1 ))
c_scheme[0,0] = 1.
u_mat = np.identity(1)
u_scheme = np.array([[1.]])

c_var = [ [0], [1], [0,1]]
p_var = [ [0], [0], [0]]

### CURRENTS
cntrl_vars_0 = [0,1]
prec_vars = [0]

if case[0] == '0':    # low to high
    max_I = [3., -3.]
elif case[0] == '1':
    max_I = [-3., 3.]
    
if case[1] == '0':    # sparsity
    factor_ws = 1.
    factor_we = 0.
elif case[1] == '1':  # energy
    factor_ws = 0.
    factor_we = 1.
    
if case[3] == '0':
    cntrl_vars_init = [0]
elif case[3] == '1':
    cntrl_vars_init = [1]
elif case[3] == '2':
    cntrl_vars_init = [0,1]
elif case[3] == '3':
    cntrl_vars_init = [0]
    conv_init = [[True]*2] * len(exc)
    case_read = case[0] + case[1] + case[2] + str(int(case[3])-3) + '0'
    read_file = os.path.join( os.getcwd()[:-5], case_read, 'control_init_' + case_read + '.pickle')
elif case[3] == '4':
    cntrl_vars_init = [1]
    conv_init = [[True]*2] * len(exc)
    case_read = case[0] + case[1] + case[2] + str(int(case[3])-3) + '0'
    read_file = os.path.join( os.getcwd()[:-5], case_read, 'control_init_' + case_read + '.pickle')
elif case[3] == '5':
    cntrl_vars_init = [0,1]
    conv_init = [[True]*2] * len(exc)
    case_read = case[0] + case[1] + case[2] + str(int(case[3])-3) + '0'
    read_file = os.path.join( os.getcwd()[:-5], case_read, 'control_init_' + case_read + '.pickle')
elif case[3] == '6':
    cntrl_vars_init = [0]
    conv_init = [[True]*2] * len(exc)
    case_read = case[0] + case[1] + case[2] + str(int(case[3])-6) + '0'
    read_file = os.path.join( os.getcwd()[:-5], case_read, 'control_init_' + case_read + '.pickle')
elif case[3] == '7':
    cntrl_vars_init = [1]
    conv_init = [[True]*2] * len(exc)
    case_read = case[0] + case[1] + case[2] + str(int(case[3])-6) + '0'
    read_file = os.path.join( os.getcwd()[:-5], case_read, 'control_init_' + case_read + '.pickle')
elif case[3] == '8':
    cntrl_vars_init = [0,1]
    conv_init = [[True]*2] * len(exc)
    case_read = case[0] + case[1] + case[2] + str(int(case[3])-6) + '0'
    read_file = os.path.join( os.getcwd()[:-5], case_read, 'control_init_' + case_read + '.pickle')
    
if case[4] == '0':
    dur = 100
    trans_time = 0.8
elif case[4] == '1':
    dur = 400
    trans_time = 0.95
    
maxC = [5., -5., 0.18, 0.]

n_dur = int(np.around(dur/aln.params.dt + 1.,1))
max_cntrl, min_cntrl = setmaxmincontrol(maxC[0], maxC[1], maxC[2], maxC[3])

# %%
init_file = 'control_init_' + case + '.pickle'
final_file = 'control_' + case + '.pickle'
case_1 = case[0] + case[1] + '0' + case[3] + case[4]
final_file_1 = 'control_' + case_1 + '.pickle'

# %%
if os.path.isfile(init_file) :
    print("file found")
    
    with open(init_file,'rb') as f:
        load_array = pickle.load(f)

    bestControl_init = load_array[0]
    bestState_init = load_array[1]
    cost_init = load_array[2]
    runtime_init = load_array[3]
    grad_init = load_array[4]
    phi_init = load_array[5]
    costnode_init = load_array[6]
    weights_init = load_array[7]
# Out:
# file found

# %%
# get initial parameters and target states

i_stepsize = 1
limit = 57
start_index = 54
i_range = range(start_index, limit,i_stepsize)
i_range_0 = range(start_index, limit,i_stepsize)
i_range_1 = range(start_index, limit,i_stepsize)

i_range = [38, 50, 56, 57, 58, 62, 63, 64, 70, 115]
i_range_0 = i_range
i_range_1 = i_range

data.set_parameters(aln)

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    aln.params.duration = 3000.
    
    control0 = aln.getZeroControl()
    control0 = functions.step_control(aln, maxI_ = max_I[0])

    aln.run(control=control0)
    
    target_rates = np.zeros((2))
    target_rates[0] = aln.rates_exc[0,-1] 
    target_rates[1] = aln.rates_inh[0,-1]

    control0 = functions.step_control(aln, maxI_ = max_I[1])
    aln.run(control=control0)

    init_state_vars = np.zeros(( len(state_vars) ))
    for j in range(len(state_vars)):
        if aln.state[state_vars[j]].size == 1:
            init_state_vars[j] = aln.state[state_vars[j]][0]
        else:
            init_state_vars[j] = aln.state[state_vars[j]][0,-1]

    initVars[i] = init_state_vars
    
    aln.params.duration = dur

    target[i] = aln.getZeroTarget()
    target[i][:,0,:] = target_rates[0]
    target[i][:,1,:] = target_rates[1]
# Out:
# -------  38 0.47500000000000014 0.5500000000000003
# -------  50 0.47500000000000014 0.6000000000000003
# -------  56 0.4500000000000001 0.6250000000000003
# -------  57 0.47500000000000014 0.6250000000000003
# -------  58 0.5000000000000002 0.6250000000000003
# -------  62 0.4250000000000001 0.6500000000000004
# -------  63 0.4500000000000001 0.6500000000000004
# -------  64 0.47500000000000014 0.6500000000000004
# -------  70 0.4500000000000001 0.6750000000000004
# -------  115 0.4250000000000001 0.8250000000000005

# %%
# get uncontrolled cost

data.set_parameters(aln)

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    aln.params.duration = dur
        
    cost.setParams(1.0, 0.0, 0.0)

##### zero control as input for uncontrolled cost
    setinit(initVars[i], aln)
    control0 = aln.getZeroControl()

    # "HS", "FR", "PR", "HZ"
    cgv = None
    max_it = 0

    bestControl_init_, bestState_init_, cost_init_, runtime_init_, grad_init_, phi_init_, costnode_init_ = aln.A1(
        control0, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cntrl_vars_init,
        prec_variables_ = prec_vars, transition_time_ = trans_time)
    
    cost_uncontrolled[i] = cost_init_[0]
# Out:
# -------  38 0.47500000000000014 0.5500000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  325347.54927894264
# Gradient descend method:  None
# RUN  0 , total integrated cost =  325347.54927894264
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  44 0.47500000000000014 0.5750000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  321214.9998952403
# Gradient descend method:  None
# RUN  0 , total integrated cost =  321214.9998952403
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  50 0.47500000000000014 0.6000000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  317352.0631827761
# Gradient descend method:  None
# RUN  0 , total integrated cost =  317352.0631827761
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  51 0.5000000000000002 0.6000000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  406662.24025548215
# Gradient descend method:  None
# RUN  0 , total integrated cost =  406662.24025548215
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  52 0.5250000000000001 0.6000000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  499845.69242991135
# Gradient descend method:  None
# RUN  0 , total integrated cost =  499845.69242991135
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  62 0.4250000000000001 0.6500000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  137868.6710720623
# Gradient descend method:  None
# RUN  0 , total integrated cost =  137868.6710720623
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  63 0.4500000000000001 0.6500000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  224297.9659900913
# Gradient descend method:  None
# RUN  0 , total integrated cost =  224297.9659900913
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  64 0.47500000000000014 0.6500000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  310383.3404885133
# Gradient descend method:  None
# RUN  0 , total integrated cost =  310383.3404885133
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  70 0.4500000000000001 0.6750000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  221130.87200836552
# Gradient descend method:  None
# RUN  0 , total integrated cost =  221130.87200836552
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  115 0.4250000000000001 0.8250000000000005
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  116353.19804002078
# Gradient descend method:  None
# RUN  0 , total integrated cost =  116353.19804002078
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.

# %%
factor_iteration = 20.
aln.params.duration = dur

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
        
    ##### zero control as input for uncontrolled cost
    setinit(initVars[i], aln)
    
    if conv_init[i] == [True, True]:
    
        with open(read_file,'rb') as f:
            load_array = pickle.load(f)

        bestControl_read = load_array[0]

        bestControl_init[i] = np.zeros(( 1, 6, n_dur + n_pre + n_post -2 ))
        bestControl_init[i][:,:,n_pre-1+1000:n_pre-1+2000] = bestControl_read[i][:,:,n_pre-1:n_pre-1+1000].copy()
        weights_init = load_array[7]
        
        control0 = bestControl_init[i][:,:,n_pre-1:-n_post+1]   
        cost.setParams(weights_init[i][0], weights_init[i][1], weights_init[i][2])

        
        bestControl_init[i], bestState_init[i], cost_init[i], runtime_init[i], grad_init[i], phi_init[i], costnode_init[i] = aln.A1(
        control0, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = 0, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cntrl_vars_init,
        prec_variables_ = prec_vars, transition_time_ = trans_time)
        
        continue
    
    
    
    if not type(bestControl_init[i]) == type(None):
        continue
        
    control0 = aln.getZeroControl()

    ##### initial guess
    weight_ = 10
    cost.setParams(1.0, weight_ * factor_we, weight_ * factor_ws)

    setinit(initVars[i], aln)

    # "HS", "FR", "PR", "HZ"
    cgv = None
    max_it = int(100 * factor_iteration)

    weights_init[i] = cost.getParams()

    bestControl_init[i], bestState_init[i], cost_init[i], runtime_init[i], grad_init[i], phi_init[i], costnode_init[i] = aln.A1(
        control0, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cntrl_vars_init,
        prec_variables_ = prec_vars, transition_time_ = trans_time)
    
    j = 1
    while cost_init[i][-j] == 0.:
        j += 1
    
    weight_ = 10 * cost_uncontrolled[i] / cost_init[i][-j]
    print("weight = ", weight_)
    cost.setParams(1.0, weight_ * factor_we, weight_ * factor_ws)

    setinit(initVars[i], aln)
    control0 = bestControl_init[i][:,:,n_pre-1:-n_post+1]

    # "HS", "FR", "PR", "HZ"
    cgv = None
    max_it = int(500 * factor_iteration)

    weights_init[i] = cost.getParams()
    
    bestControl_init[i], bestState_init[i], cost_init[i], runtime_init[i], grad_init[i], phi_init[i], costnode_init[i] = aln.A1(
        control0, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cntrl_vars_init,
        prec_variables_ = prec_vars, transition_time_ = trans_time)
        
    with open(init_file,'wb') as f:
        pickle.dump([bestControl_init, bestState_init, cost_init, runtime_init, grad_init, phi_init,
                 costnode_init, weights_init], f)

with open(init_file,'wb') as f:
        pickle.dump([bestControl_init, bestState_init, cost_init, runtime_init, grad_init, phi_init,
                 costnode_init, weights_init], f)
# Out:
# -------  54 0.5750000000000002 0.6000000000000003
# set cost params:  1.0 730469.9567062266 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  159298.4932289608
# Gradient descend method:  None
# RUN  0 , total integrated cost =  159298.4932289608
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  55 0.4250000000000001 0.6250000000000003
# set cost params:  1.0 1599.125067405626 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  35344.15732328158
# Gradient descend method:  None
# RUN  0 , total integrated cost =  35344.15732328158
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  56 0.4500000000000001 0.6250000000000003
# set cost params:  1.0 3132.992529412117 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  56750.5538754956
# Gradient descend method:  None
# RUN  0 , total integrated cost =  56750.5538754956
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.

# %%
#plot initial guesses
for i in i_range:
    print("---------", i)
        
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.

    plotFunc.plot_control_current(aln, [bestControl_init[i]],
        [costnode_init[i]], [weights_init[i]], dur,
        dur_pre, dur_post, initVars[i], target[i], '', filename_ = '', transition_time_ = trans_time,
        labels_ = ["init", "sparse control" + str(i)], print_cost_ = False)
    plt.show()
# Out:
# --------- 54
# --------- 55
# --------- 56

# %%
bestControl_init[61][:,:,-1000:] = 0.

# %%
delete = [55]
for i in delete:
    bestControl_init[i] = None

# %%
found_solution = []
no_solution = []
factor_iteration = 1.
already_tried = [ [] for _ in range(len(exc)) ]

for i in i_range:
    print("------- ", i, exc[i], inh[i])   

    if type(bestControl_init[i]) != type(None):
        if np.abs(np.mean(bestState_init[i][0,0,-300:]) - target[i][0,0,-1]) < 0.1 * np.abs(
            np.mean(bestState_init[i][0,0,-100:]) - bestState_init[i][0,0,0]) and np.abs(
            np.mean(bestState_init[i][0,1,-300:]) - target[i][0,1,-1]) < 0.1 * np.abs(
            np.mean(bestState_init[i][0,1,-100:]) - bestState_init[i][0,1,0]) and np.amax(
            bestState_init[i][0,0,:]) < target[i][0,0,-1] + 5. and np.amax(
            bestState_init[i][0,1,:]) < target[i][0,1,-1] + 5.:
            # and np.amin(bestState_init[i][0,0,:]) > bestState_init[i][0,0,0] - 1.
            #and np.amin(bestState_init[i][0,1,:]) > bestState_init[i][0,1,0] - 1.:
            if i not in found_solution:
                print("found solution for ", i)
                found_solution.append(i)
            if i in no_solution:
                no_solution.pop(no_solution.index(i))
            continue
        
    if len(found_solution) == 0:
        continue

    closest_ = getclosest(i, found_solution, exc, inh, already_tried[i])
    print("closest index ", closest_)

    weight_ = 10
    cost.setParams(1.0, weight_ * factor_we, weight_ * factor_ws)

    setinit(initVars[i], aln)
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.

    if i != 0 and closest_ != -1:
        control0 = 1.5 * bestControl_init[closest_][:,:,n_pre-1:-n_post+1]
        control0 = 1.5 * bestControl_1[62][:,:,n_pre-1:-n_post+1]
        if closest_ not in already_tried[i]:
            already_tried[i].append(closest_)

    if closest_ == -1:
        print("all options tried already")
        if i not in no_solution:
            no_solution.append(i)
            continue

    # "HS", "FR", "PR", "HZ"
    cgv = None
    max_it = int(100 * factor_iteration)

    weights_init[i] = cost.getParams()

    print("precision vars = ", prec_vars)

    bestControl_init[i], bestState_init[i], cost_init[i], runtime_init[i], grad_init[i], phi_init[i], costnode_init[i] = aln.A1(
        control0, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cntrl_vars_init,
        prec_variables_ = prec_vars, transition_time_ = trans_time)

    j = 1
    while cost_init[i][-j] == 0.:
        j += 1

    weight_ = 10 * cost_uncontrolled[i] / cost_init[i][-j]
    print("weight = ", weight_)
    cost.setParams(1.0, weight_ * factor_we, weight_ * factor_ws)

    setinit(initVars[i], aln)
    control0 = bestControl_init[i][:,:,n_pre-1:-n_post+1]

    # "HS", "FR", "PR", "HZ"
    cgv = None
    max_it = int(500 * factor_iteration)

    weights_init[i] = cost.getParams()

    bestControl_init[i], bestState_init[i], cost_init[i], runtime_init[i], grad_init[i], phi_init[i], costnode_init[i] = aln.A1(
        control0, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cntrl_vars_init,
        prec_variables_ = prec_vars, transition_time_ = trans_time)

    with open(init_file,'wb') as f:
        pickle.dump([bestControl_init, bestState_init, cost_init, runtime_init, grad_init, phi_init,
                     costnode_init, weights_init], f)
# Out:
# -------  54 0.5750000000000002 0.6000000000000003
# found solution for  54
# -------  55 0.4250000000000001 0.6250000000000003
# [54] []
# closest index  54
# set cost params:  1.0 10.0 0.0
# precision vars =  [0]
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  616.5889608726516
# Gradient descend method:  None
# RUN  1 , total integrated cost =  256.2885199511742
# RUN  2 , total integrated cost =  250.2436987001862
# RUN  3 , total integrated cost =  250.1229462361409
# RUN  4 , total integrated cost =  250.10976550125702
# RUN  5 , total integrated cost =  250.0239092508403
# RUN  6 , total integrated cost =  250.01687837262114
# RUN  7 , total integrated cost =  250.01687788150375
# RUN  8 , total integrated cost =  250.01687788149945
# RUN  9 , total integrated cost =  250.01687788149928
# RUN  10 , total integrated cost =  250.0168778814992
# RUN  11 , total integrated cost =  250.01687788149917
# RUN  12 , total integrated cost =  250.01687788149917
# Control only changes marginally.
# RUN  12 , total integrated cost =  250.01687788149917
# Improved over  12  iterations in  1.527326353942044  seconds by  59.45161302796387  percent.
# weight =  5663.053767188998
# set cost params:  1.0 5663.053767188998 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  140990.5747512085
# Gradient descend method:  None
# RUN  1 , total integrated cost =  140990.5744933485
# RUN  2 , total integrated cost =  140990.57449334834
# RUN  3 , total integrated cost =  140990.57449334825
# RUN  4 , total integrated cost =  140990.57449334825
# Control only changes marginally.
# RUN  4 , total integrated cost =  140990.57449334825
# Improved over  4  iterations in  1.2498609889298677  seconds by  1.828918527735368e-07  percent.
# -------  56 0.4500000000000001 0.6250000000000003
# found solution for  56

# %%
if os.path.isfile(final_file) :
    print("file found")
    
    with open(final_file,'rb') as f:
        load_array = pickle.load(f)

    bestControl_0 = load_array[0]
    bestState_0 = load_array[1]
    cost_0 = load_array[2]
    runtime_0 = load_array[3]
    grad_0 = load_array[4]
    phi_0 = load_array[5]
    costnode_0 = load_array[6]
    weights_0 = load_array[7]
# Out:
# file found

# %%
delete = [55]
for i in delete:
    bestControl_0[i] = None

# %%
factor_iteration = 0.1
conv_0 = [[False]*2] * len(exc)
full_converge = False

for i in range(len(conv_0)):
    if i not in i_range_0:
        conv_0[i] = [True, True]

counter = 0

while full_converge == False:
    print('---------------', counter)
    
    if counter > 6:
        break
    
    print(conv_0[start_index:limit:i_stepsize])
    full_converge = True
    
    for conv in conv_0[start_index:limit:i_stepsize]:
        if not conv[0]:
            full_converge = False
            break
        if not conv[1]:
            full_converge = False
            break
    
    if full_converge:
        print("full convergence")
        break
        
    counter += 1
    
    for i in i_range_0:
        print("------- ", i, exc[i], inh[i])
        
        if conv_0[i] == [True, True]:
            continue
            
        aln.params.ext_exc_current = exc[i] * 5.
        aln.params.ext_inh_current = inh[i] * 5.

    # exc and inh control current 

        setinit(initVars[i], aln)
        aln.params.duration = dur

        if not type(bestControl_0[i]) == type(None):
            control0 = bestControl_0[i][:,:,n_pre-1:-n_post+1]
        else:
            control0 = bestControl_init[i][:,:,n_pre-1:-n_post+1].copy()
            weights_0[i] = weights_init[i]
            cost_0[i] = cost_init[i]

        cgv = None
        max_it = 500 * factor_iteration

        j = 1
        while cost_0[i][-j] == 0.:
            j += 1

        weight_ = (factor_we * weights_0[i][1] * cost_uncontrolled[i] / cost_0[i][-j]
                           + factor_ws * weights_0[i][2] * cost_uncontrolled[i] / cost_0[i][-j]) - 1
        print("weight = ", weight_)
        cost.setParams(1.0, weight_ * factor_we, weight_ * factor_ws)

        weights_0[i] = cost.getParams()

        bestControl_0[i], bestState_0[i], cost_0[i], runtime_0[i], grad_0[i], phi_0[i], costnode_0[i] = aln.A1(
            control0, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cntrl_vars_0,
            prec_variables_ = prec_vars, transition_time_ = trans_time)

        with open(final_file,'wb') as f:
            pickle.dump([bestControl_0, bestState_0, cost_0, runtime_0, grad_0, phi_0,
                     costnode_0, weights_0], f)
            
        if j == cost_0[i].shape[0]-1:
            print("converged for ", i)
            if conv_0[i][0]:
                conv_0[i] = [True, True]
            else:
                conv_0[i] = [True, False]
            continue
    
        print("no convergence")
# Out:
# --------------- 0
# [[False, False], [False, False], [False, False]]
# -------  54 0.5750000000000002 0.6000000000000003
# weight =  6268110.588492569
# set cost params:  1.0 6268110.588492569 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  696453.3189562352
# Gradient descend method:  None
# RUN  1 , total integrated cost =  696453.3189562352
# Control only changes marginally.
# RUN  1 , total integrated cost =  696453.3189562352
# Improved over  1  iterations in  0.4228553099092096  seconds by  0.0  percent.
# converged for  54
# -------  55 0.4250000000000001 0.6250000000000003
# weight =  5685.965811718211
# set cost params:  1.0 5685.965811718211 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  141561.00139010366
# Gradient descend method:  None
# RUN  1 , total integrated cost =  141561.00139010334
# RUN  2 , total integrated cost =  141561.00139010328
# RUN  3 , total integrated cost =  141561.00139010325
# RUN  4 , total integrated cost =  141561.00139010322
# RUN  5 , total integrated cost =  141561.00139010322
# Control only changes marginally.
# RUN  5 , total integrated cost =  141561.00139010322
# Improved over  5  iterations in  1.793311693938449  seconds by  3.126388037344441e-13  percent.
# no convergence
# -------  56 0.4500000000000001 0.6250000000000003
# weight =  12290.914002991422
# set cost params:  1.0 12290.914002991422 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  227643.74295733302
# Gradient descend method:  None
# RUN  1 , total integrated cost =  227643.74295733302
# Control only changes marginally.
# RUN  1 , total integrated cost =  227643.74295733302
# Improved over  1  iterations in  0.4123534730169922  seconds by  0.0  percent.
# converged for  56
# --------------- 1
# [[True, False], [False, False], [True, False]]
# -------  54 0.5750000000000002 0.6000000000000003
# weight =  6268110.5884925695
# set cost params:  1.0 6268110.5884925695 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  696453.3189562353
# Gradient descend method:  None
# RUN  1 , total integrated cost =  696453.3189562353
# Control only changes marginally.
# RUN  1 , total integrated cost =  696453.3189562353
# Improved over  1  iterations in  0.41321164299733937  seconds by  0.0  percent.
# converged for  54
# -------  55 0.4250000000000001 0.6250000000000003
# weight =  5685.96598292584
# set cost params:  1.0 5685.96598292584 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  141561.005652553
# Gradient descend method:  None
# RUN  1 , total integrated cost =  141561.00565255273
# RUN  2 , total integrated cost =  141561.00565255265
# RUN  3 , total integrated cost =  141561.00565255262
# RUN  4 , total integrated cost =  141561.00565255262
# Control only changes marginally.
# RUN  4 , total integrated cost =  141561.00565255262
# Improved over  4  iterations in  1.4264959859428927  seconds by  2.7000623958883807e-13  percent.
# no convergence
# -------  56 0.4500000000000001 0.6250000000000003
# weight =  12290.914002991422
# set cost params:  1.0 12290.914002991422 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  227643.74295733302
# Gradient descend method:  None
# RUN  1 , total integrated cost =  227643.74295733302
# Control only changes marginally.
# RUN  1 , total integrated cost =  227643.74295733302
# Improved over  1  iterations in  0.41141415503807366  seconds by  0.0  percent.
# converged for  56
# --------------- 2
# [[True, True], [False, False], [True, True]]
# -------  54 0.5750000000000002 0.6000000000000003
# -------  55 0.4250000000000001 0.6250000000000003
# weight =  5685.965982927125
# set cost params:  1.0 5685.965982927125 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  141561.0056525852
# Gradient descend method:  None
# RUN  1 , total integrated cost =  141561.00565258475
# RUN  2 , total integrated cost =  141561.00565258466
# RUN  3 , total integrated cost =  141561.00565258466
# Control only changes marginally.
# RUN  3 , total integrated cost =  141561.00565258466
# Improved over  3  iterations in  1.032016746001318  seconds by  3.836930773104541e-13  percent.
# no convergence
# -------  56 0.4500000000000001 0.6250000000000003
# --------------- 3
# [[True, True], [False, False], [True, True]]
# -------  54 0.5750000000000002 0.6000000000000003
# -------  55 0.4250000000000001 0.6250000000000003
# weight =  5685.965982927124
# set cost params:  1.0 5685.965982927124 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  141561.00565258466
# Gradient descend method:  None
# RUN  1 , total integrated cost =  141561.00565258466
# Control only changes marginally.
# RUN  1 , total integrated cost =  141561.00565258466
# Improved over  1  iterations in  0.3831978690577671  seconds by  0.0  percent.
# no convergence
# -------  56 0.4500000000000001 0.6250000000000003
# --------------- 4
# [[True, True], [False, False], [True, True]]
# -------  54 0.5750000000000002 0.6000000000000003
# -------  55 0.4250000000000001 0.6250000000000003
# weight =  5685.965982927123
# set cost params:  1.0 5685.965982927123 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  141561.00565258463
# Gradient descend method:  None
# RUN  1 , total integrated cost =  141561.00565258463
# Control only changes marginally.
# RUN  1 , total integrated cost =  141561.00565258463
# Improved over  1  iterations in  0.39850026997737586  seconds by  0.0  percent.
# converged for  55
# -------  56 0.4500000000000001 0.6250000000000003
# --------------- 5
# [[True, True], [True, False], [True, True]]
# -------  54 0.5750000000000002 0.6000000000000003
# -------  55 0.4250000000000001 0.6250000000000003
# weight =  5685.965982927123
# set cost params:  1.0 5685.965982927123 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  141561.00565258463
# Gradient descend method:  None
# RUN  1 , total integrated cost =  141561.00565258463
# Control only changes marginally.
# RUN  1 , total integrated cost =  141561.00565258463
# Improved over  1  iterations in  0.4026939480099827  seconds by  0.0  percent.
# converged for  55
# -------  56 0.4500000000000001 0.6250000000000003
# --------------- 6
# [[True, True], [True, True], [True, True]]
# full convergence

# %%
for i in i_range_0:
    
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.

    plotFunc.plot_control_current(aln, [bestControl_init[i], bestControl_0[i]],
        [costnode_init[i], costnode_0[i]], [weights_init[i], weights_0[i]], dur,
        dur_pre, dur_post, initVars[i], target[i], '', filename_ = '', transition_time_ = trans_time,
        labels_ = ["init", "sparse control" + str(i)], print_cost_ = False)

# %%
if os.path.isfile(final_file_1) :
    print("file found")
    
    with open(final_file_1,'rb') as f:
        load_array = pickle.load(f)

    bestControl_1 = load_array[0]
    bestState_1 = load_array[1]
    cost_1 = load_array[2]
    runtime_1 = load_array[3]
    grad_1 = load_array[4]
    phi_1 = load_array[5]
    costnode_1 = load_array[6]
    weights_1 = load_array[7]
# Out:
# file found

# %%
bestControl_1[38] = bestControl_1[31]
bestControl_1[50] = bestControl_1[49]
bestControl_1[56] = 1.2 * bestControl_1[49]
bestControl_1[57] = bestControl_1[49]
bestControl_1[58] = 1.2 * bestControl_1[51]
bestControl_1[62] = 1.8 * bestControl_1[65]
bestControl_1[63] = 1.6 * bestControl_1[65]
bestControl_1[64] = 1.4 * bestControl_1[65]
bestControl_1[70] = 1.2 * bestControl_1[85]
bestControl_1[115] = 1.4 * bestControl_1[125]

# %%
factor_iteration = 0.1
full_converge = False
conv_1 = [[False]*2] * len(exc)

for i in range(len(conv_1)):
    if i not in i_range_1:
        conv_1[i] = [True, True]
        
counter = 0

while full_converge == False:
    
    print('---------------', counter)
    if counter > 4:
        break
    
    """
    print(conv_1[start_index:limit:i_stepsize])
    full_converge = True
    
    for conv in conv_1[start_index:limit:i_stepsize]:
        if not conv[0]:
            full_converge = False
            break
        if not conv[1]:
            full_converge = False
            break
    
    if full_converge:
        print("full convergence")
        break
    """

    for i in i_range_1:        

        print("------- ", i, exc[i], inh[i])
        
        #if conv_1[i] == [True, True]:
        #    continue
            
        aln.params.ext_exc_current = exc[i] * 5.
        aln.params.ext_inh_current = inh[i] * 5.
        
        if not type(bestControl_1[i]) == type(None):
            control0 = bestControl_1[i][:,:,n_pre-1:-n_post+1].copy()
        else:
            control0 = bestControl_0[i][:,:,n_pre-1:-n_post+1].copy()
            cost_1[i] = cost_0[i]
        
        cost.setParams(1.0, 1. * factor_we, 1. * factor_ws)

        setinit(initVars[i], aln)

        # "HS", "FR", "PR", "HZ"
        cgv = None
        max_it = int( 500 * factor_iteration )

        weights_1[i] = cost.getParams()

        bestControl_1[i], bestState_1[i], cost_1[i], runtime_1[i], grad_1[i], phi_1[i], costnode_1[i] = aln.A1(
            control0, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cntrl_vars_init,
            prec_variables_ = prec_vars, transition_time_ = trans_time)
        
        with open(final_file_1,'wb') as f:
            pickle.dump([bestControl_1, bestState_1, cost_1, runtime_1, grad_1, phi_1,
                 costnode_1, weights_1], f)
            
        j = 1
        while cost_1[i][-j] == 0.:
            j += 1
            
        if j == cost_1[i].shape[0]-1:
            print("converged for ", i)
            if conv_1[i][0]:
                conv_1[i] = [True, True]
            else:
                conv_1[i] = [True, False]
            continue
    
        print("no convergence")
        
    counter += 1
# Out:
# --------------- 0
# -------  38 0.47500000000000014 0.5500000000000003
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7.084872050729091
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.084872050729091
# Control only changes marginally.
# RUN  1 , total integrated cost =  7.084872050729091
# Improved over  1  iterations in  0.35430962600003113  seconds by  0.0  percent.
# converged for  38
# -------  50 0.47500000000000014 0.6000000000000003
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11.569419867240136
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.569419867240136
# Control only changes marginally.
# RUN  1 , total integrated cost =  11.569419867240136
# Improved over  1  iterations in  0.3284002340005827  seconds by  0.0  percent.
# converged for  50
# -------  56 0.4500000000000001 0.6250000000000003
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  18.04918404753998
# Gradient descend method:  None
# RUN  1 , total integrated cost =  18.04918404753998
# Control only changes marginally.
# RUN  1 , total integrated cost =  18.04918404753998
# Improved over  1  iterations in  0.33435196099890163  seconds by  0.0  percent.
# converged for  56
# -------  57 0.47500000000000014 0.6250000000000003
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12.742897127659312
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12.742897127659312
# Control only changes marginally.
# RUN  1 , total integrated cost =  12.742897127659312
# Improved over  1  iterations in  0.33155971899759606  seconds by  0.0  percent.
# converged for  57
# -------  58 0.5000000000000002 0.6250000000000003
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  8.39895410240161
# Gradient descend method:  None
# RUN  1 , total integrated cost =  8.39895410240161
# Control only changes marginally.
# RUN  1 , total integrated cost =  8.39895410240161
# Improved over  1  iterations in  0.32831645799888065  seconds by  0.0  percent.
# converged for  58
# -------  62 0.4250000000000001 0.6500000000000004
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  27.63756363444539
# Gradient descend method:  None
# RUN  1 , total integrated cost =  27.63756363444539
# Control only changes marginally.
# RUN  1 , total integrated cost =  27.63756363444539
# Improved over  1  iterations in  0.324211445000401  seconds by  0.0  percent.
# converged for  62
# -------  63 0.4500000000000001 0.6500000000000004
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  20.67571449407937
# Gradient descend method:  None
# RUN  1 , total integrated cost =  20.67571449407937
# Control only changes marginally.
# RUN  1 , total integrated cost =  20.67571449407937
# Improved over  1  iterations in  0.344953929001349  seconds by  0.0  percent.
# converged for  63
# -------  64 0.47500000000000014 0.6500000000000004
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  14.733744217717781
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14.733744217717781
# Control only changes marginally.
# RUN  1 , total integrated cost =  14.733744217717781
# Improved over  1  iterations in  0.32497601300201495  seconds by  0.0  percent.
# converged for  64
# -------  70 0.4500000000000001 0.6750000000000004
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22.332743975419685
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22.332743975419685
# Control only changes marginally.
# RUN  1 , total integrated cost =  22.332743975419685
# Improved over  1  iterations in  0.3259770609984116  seconds by  0.0  percent.
# converged for  70
# -------  115 0.4250000000000001 0.8250000000000005
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  35.677751130652275
# Gradient descend method:  None
# RUN  1 , total integrated cost =  35.677751130652275
# Control only changes marginally.
# RUN  1 , total integrated cost =  35.677751130652275
# Improved over  1  iterations in  0.3225760369969066  seconds by  0.0  percent.
# converged for  115
# --------------- 1
# -------  38 0.47500000000000014 0.5500000000000003
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7.084872050729091
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.084872050729091
# Control only changes marginally.
# RUN  1 , total integrated cost =  7.084872050729091
# Improved over  1  iterations in  0.32730377099869656  seconds by  0.0  percent.
# converged for  38
# -------  50 0.47500000000000014 0.6000000000000003
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11.569419867240136
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.569419867240136
# Control only changes marginally.
# RUN  1 , total integrated cost =  11.569419867240136
# Improved over  1  iterations in  0.33111815699885483  seconds by  0.0  percent.
# converged for  50
# -------  56 0.4500000000000001 0.6250000000000003
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  18.04918404753998
# Gradient descend method:  None
# RUN  1 , total integrated cost =  18.04918404753998
# Control only changes marginally.
# RUN  1 , total integrated cost =  18.04918404753998
# Improved over  1  iterations in  0.3467195000011998  seconds by  0.0  percent.
# converged for  56
# -------  57 0.47500000000000014 0.6250000000000003
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12.742897127659312
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12.742897127659312
# Control only changes marginally.
# RUN  1 , total integrated cost =  12.742897127659312
# Improved over  1  iterations in  0.33531124200089835  seconds by  0.0  percent.
# converged for  57
# -------  58 0.5000000000000002 0.6250000000000003
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  8.39895410240161
# Gradient descend method:  None
# RUN  1 , total integrated cost =  8.39895410240161
# Control only changes marginally.
# RUN  1 , total integrated cost =  8.39895410240161
# Improved over  1  iterations in  0.327747774997988  seconds by  0.0  percent.
# converged for  58
# -------  62 0.4250000000000001 0.6500000000000004
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  27.63756363444539
# Gradient descend method:  None
# RUN  1 , total integrated cost =  27.63756363444539
# Control only changes marginally.
# RUN  1 , total integrated cost =  27.63756363444539
# Improved over  1  iterations in  0.3293479709973326  seconds by  0.0  percent.
# converged for  62
# -------  63 0.4500000000000001 0.6500000000000004
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  20.67571449407937
# Gradient descend method:  None
# RUN  1 , total integrated cost =  20.67571449407937
# Control only changes marginally.
# RUN  1 , total integrated cost =  20.67571449407937
# Improved over  1  iterations in  0.3938403579995793  seconds by  0.0  percent.
# converged for  63
# -------  64 0.47500000000000014 0.6500000000000004
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  14.733744217717781
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14.733744217717781
# Control only changes marginally.
# RUN  1 , total integrated cost =  14.733744217717781
# Improved over  1  iterations in  0.3367684309996548  seconds by  0.0  percent.
# converged for  64
# -------  70 0.4500000000000001 0.6750000000000004
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22.332743975419685
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22.332743975419685
# Control only changes marginally.
# RUN  1 , total integrated cost =  22.332743975419685
# Improved over  1  iterations in  0.31341484600125114  seconds by  0.0  percent.
# converged for  70
# -------  115 0.4250000000000001 0.8250000000000005
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  35.677751130652275
# Gradient descend method:  None
# RUN  1 , total integrated cost =  35.677751130652275
# Control only changes marginally.
# RUN  1 , total integrated cost =  35.677751130652275
# Improved over  1  iterations in  0.3158030209997378  seconds by  0.0  percent.
# converged for  115
# --------------- 2
# -------  38 0.47500000000000014 0.5500000000000003
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7.084872050729091
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.084872050729091
# Control only changes marginally.
# RUN  1 , total integrated cost =  7.084872050729091
# Improved over  1  iterations in  0.32200396599728265  seconds by  0.0  percent.
# converged for  38
# -------  50 0.47500000000000014 0.6000000000000003
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11.569419867240136
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.569419867240136
# Control only changes marginally.
# RUN  1 , total integrated cost =  11.569419867240136
# Improved over  1  iterations in  0.321855770998809  seconds by  0.0  percent.
# converged for  50
# -------  56 0.4500000000000001 0.6250000000000003
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  18.04918404753998
# Gradient descend method:  None
# RUN  1 , total integrated cost =  18.04918404753998
# Control only changes marginally.
# RUN  1 , total integrated cost =  18.04918404753998
# Improved over  1  iterations in  0.32648450400301954  seconds by  0.0  percent.
# converged for  56
# -------  57 0.47500000000000014 0.6250000000000003
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12.742897127659312
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12.742897127659312
# Control only changes marginally.
# RUN  1 , total integrated cost =  12.742897127659312
# Improved over  1  iterations in  0.36234087500270107  seconds by  0.0  percent.
# converged for  57
# -------  58 0.5000000000000002 0.6250000000000003
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  8.39895410240161
# Gradient descend method:  None
# RUN  1 , total integrated cost =  8.39895410240161
# Control only changes marginally.
# RUN  1 , total integrated cost =  8.39895410240161
# Improved over  1  iterations in  0.32540167800107156  seconds by  0.0  percent.
# converged for  58
# -------  62 0.4250000000000001 0.6500000000000004
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  27.63756363444539
# Gradient descend method:  None
# RUN  1 , total integrated cost =  27.63756363444539
# Control only changes marginally.
# RUN  1 , total integrated cost =  27.63756363444539
# Improved over  1  iterations in  0.3231217339998693  seconds by  0.0  percent.
# converged for  62
# -------  63 0.4500000000000001 0.6500000000000004
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  20.67571449407937
# Gradient descend method:  None
# RUN  1 , total integrated cost =  20.67571449407937
# Control only changes marginally.
# RUN  1 , total integrated cost =  20.67571449407937
# Improved over  1  iterations in  0.32120986800146056  seconds by  0.0  percent.
# converged for  63
# -------  64 0.47500000000000014 0.6500000000000004
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  14.733744217717781
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14.733744217717781
# Control only changes marginally.
# RUN  1 , total integrated cost =  14.733744217717781
# Improved over  1  iterations in  0.31936784599747625  seconds by  0.0  percent.
# converged for  64
# -------  70 0.4500000000000001 0.6750000000000004
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22.332743975419685
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22.332743975419685
# Control only changes marginally.
# RUN  1 , total integrated cost =  22.332743975419685
# Improved over  1  iterations in  0.3263022089995502  seconds by  0.0  percent.
# converged for  70
# -------  115 0.4250000000000001 0.8250000000000005
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  35.677751130652275
# Gradient descend method:  None
# RUN  1 , total integrated cost =  35.677751130652275
# Control only changes marginally.
# RUN  1 , total integrated cost =  35.677751130652275
# Improved over  1  iterations in  0.317982872002176  seconds by  0.0  percent.
# converged for  115
# --------------- 3
# -------  38 0.47500000000000014 0.5500000000000003
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7.084872050729091
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.084872050729091
# Control only changes marginally.
# RUN  1 , total integrated cost =  7.084872050729091
# Improved over  1  iterations in  0.322858619998442  seconds by  0.0  percent.
# converged for  38
# -------  50 0.47500000000000014 0.6000000000000003
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11.569419867240136
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.569419867240136
# Control only changes marginally.
# RUN  1 , total integrated cost =  11.569419867240136
# Improved over  1  iterations in  0.32460438900307054  seconds by  0.0  percent.
# converged for  50
# -------  56 0.4500000000000001 0.6250000000000003
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  18.04918404753998
# Gradient descend method:  None
# RUN  1 , total integrated cost =  18.04918404753998
# Control only changes marginally.
# RUN  1 , total integrated cost =  18.04918404753998
# Improved over  1  iterations in  0.3268099419983628  seconds by  0.0  percent.
# converged for  56
# -------  57 0.47500000000000014 0.6250000000000003
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12.742897127659312
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12.742897127659312
# Control only changes marginally.
# RUN  1 , total integrated cost =  12.742897127659312
# Improved over  1  iterations in  0.324065808999876  seconds by  0.0  percent.
# converged for  57
# -------  58 0.5000000000000002 0.6250000000000003
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  8.39895410240161
# Gradient descend method:  None
# RUN  1 , total integrated cost =  8.39895410240161
# Control only changes marginally.
# RUN  1 , total integrated cost =  8.39895410240161
# Improved over  1  iterations in  0.3238251490001858  seconds by  0.0  percent.
# converged for  58
# -------  62 0.4250000000000001 0.6500000000000004
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  27.63756363444539
# Gradient descend method:  None
# RUN  1 , total integrated cost =  27.63756363444539
# Control only changes marginally.
# RUN  1 , total integrated cost =  27.63756363444539
# Improved over  1  iterations in  0.32297839500097325  seconds by  0.0  percent.
# converged for  62
# -------  63 0.4500000000000001 0.6500000000000004
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  20.67571449407937
# Gradient descend method:  None
# RUN  1 , total integrated cost =  20.67571449407937
# Control only changes marginally.
# RUN  1 , total integrated cost =  20.67571449407937
# Improved over  1  iterations in  0.3188906200011843  seconds by  0.0  percent.
# converged for  63
# -------  64 0.47500000000000014 0.6500000000000004
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  14.733744217717781
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14.733744217717781
# Control only changes marginally.
# RUN  1 , total integrated cost =  14.733744217717781
# Improved over  1  iterations in  0.32044187000064994  seconds by  0.0  percent.
# converged for  64
# -------  70 0.4500000000000001 0.6750000000000004
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22.332743975419685
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22.332743975419685
# Control only changes marginally.
# RUN  1 , total integrated cost =  22.332743975419685
# Improved over  1  iterations in  0.3132035509988782  seconds by  0.0  percent.
# converged for  70
# -------  115 0.4250000000000001 0.8250000000000005
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  35.677751130652275
# Gradient descend method:  None
# RUN  1 , total integrated cost =  35.677751130652275
# Control only changes marginally.
# RUN  1 , total integrated cost =  35.677751130652275
# Improved over  1  iterations in  0.3191646060004132  seconds by  0.0  percent.
# converged for  115
# --------------- 4
# -------  38 0.47500000000000014 0.5500000000000003
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7.084872050729091
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.084872050729091
# Control only changes marginally.
# RUN  1 , total integrated cost =  7.084872050729091
# Improved over  1  iterations in  0.3239617729996098  seconds by  0.0  percent.
# converged for  38
# -------  50 0.47500000000000014 0.6000000000000003
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11.569419867240136
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.569419867240136
# Control only changes marginally.
# RUN  1 , total integrated cost =  11.569419867240136
# Improved over  1  iterations in  0.32375850900280057  seconds by  0.0  percent.
# converged for  50
# -------  56 0.4500000000000001 0.6250000000000003
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  18.04918404753998
# Gradient descend method:  None
# RUN  1 , total integrated cost =  18.04918404753998
# Control only changes marginally.
# RUN  1 , total integrated cost =  18.04918404753998
# Improved over  1  iterations in  0.3256813950029027  seconds by  0.0  percent.
# converged for  56
# -------  57 0.47500000000000014 0.6250000000000003
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12.742897127659312
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12.742897127659312
# Control only changes marginally.
# RUN  1 , total integrated cost =  12.742897127659312
# Improved over  1  iterations in  0.32406922899826895  seconds by  0.0  percent.
# converged for  57
# -------  58 0.5000000000000002 0.6250000000000003
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  8.39895410240161
# Gradient descend method:  None
# RUN  1 , total integrated cost =  8.39895410240161
# Control only changes marginally.
# RUN  1 , total integrated cost =  8.39895410240161
# Improved over  1  iterations in  0.323409136999544  seconds by  0.0  percent.
# converged for  58
# -------  62 0.4250000000000001 0.6500000000000004
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  27.63756363444539
# Gradient descend method:  None
# RUN  1 , total integrated cost =  27.63756363444539
# Control only changes marginally.
# RUN  1 , total integrated cost =  27.63756363444539
# Improved over  1  iterations in  0.3196900539987837  seconds by  0.0  percent.
# converged for  62
# -------  63 0.4500000000000001 0.6500000000000004
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  20.67571449407937
# Gradient descend method:  None
# RUN  1 , total integrated cost =  20.67571449407937
# Control only changes marginally.
# RUN  1 , total integrated cost =  20.67571449407937
# Improved over  1  iterations in  0.3181527750020905  seconds by  0.0  percent.
# converged for  63
# -------  64 0.47500000000000014 0.6500000000000004
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  14.733744217717781
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14.733744217717781
# Control only changes marginally.
# RUN  1 , total integrated cost =  14.733744217717781
# Improved over  1  iterations in  0.31571823700141977  seconds by  0.0  percent.
# converged for  64
# -------  70 0.4500000000000001 0.6750000000000004
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22.332743975419685
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22.332743975419685
# Control only changes marginally.
# RUN  1 , total integrated cost =  22.332743975419685
# Improved over  1  iterations in  0.31534589500006405  seconds by  0.0  percent.
# converged for  70
# -------  115 0.4250000000000001 0.8250000000000005
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  35.677751130652275
# Gradient descend method:  None
# RUN  1 , total integrated cost =  35.677751130652275
# Control only changes marginally.
# RUN  1 , total integrated cost =  35.677751130652275
# Improved over  1  iterations in  0.3178246869974828  seconds by  0.0  percent.
# converged for  115
# --------------- 5

# %%
for i in i_range_1:
    print("---------", i)
        
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.

    plotFunc.plot_control_current(aln, [bestControl_1[i]],
        [costnode_1[i]], [weights_1[i]], dur,
        dur_pre, dur_post, initVars[i], target[i], '', filename_ = '', transition_time_ = trans_time,
        labels_ = ["init", "sparse control" + str(i)], print_cost_ = False)
    plt.show()
# Out:
# --------- 38
# --------- 50
# --------- 56
# --------- 57
# --------- 58
# --------- 62
# --------- 63
# --------- 64
# --------- 70
# --------- 115

# %%
bestControl_1[63][:,:,-1000:] = 0.
