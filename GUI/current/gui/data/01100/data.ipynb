# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import sys
import pickle

path = os.getcwd().split(os.sep + 'GUI')[0]
if path not in sys.path:
    print("not here")
    sys.path.append(path)

from neurolib.models.aln import ALNModel
from neurolib.utils import plotFunctions as plotFunc
from neurolib.utils import costFunctions as cost
import neurolib.dashboard.functions as functions
import neurolib.dashboard.data as data
    
# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2 

#path = os.path.join(os.getcwd(), "plots")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# read case
print(os.getcwd())
case = os.getcwd().split(os.sep)[-1]
print(case)
# Out:
# /home/lena/Promotion/neurolib/GUI/current/gui/data/01100
# 01100

# %% [markdown]
# ### Bistability

# %%
aln = ALNModel()
N = aln.params.N

data.set_parameters(aln)

state_vars = aln.state_vars
init_vars = aln.init_vars

##############################################################
def setinit(init_vars_, model):
    state_vars = model.state_vars
    init_vars = model.init_vars
    for iv in range(len(init_vars)):
        for sv in range(len(state_vars)):
            if state_vars[sv] in init_vars[iv]:
                #print("set init vars ", )
                if model.params[init_vars[iv]].ndim == 2:
                    model.params[init_vars[iv]][0,:] = init_vars_[sv]
                else:
                    model.params[init_vars[iv]][0] = init_vars_[sv]
                    
##############################################################               
def setmaxmincontrol(max_c_c, min_c_c, max_c_r, min_c_r):
    import numpy as np
    
    max_cntrl = np.zeros(( 6 ))
    min_cntrl = np.zeros(( 6 ))
    
    max_cntrl[0] = max_c_c
    min_cntrl[0] = min_c_c
    max_cntrl[1] = max_c_c
    min_cntrl[1] = min_c_c
    max_cntrl[2] = max_c_r
    min_cntrl[2] = min_c_r
    max_cntrl[3] = max_c_r
    min_cntrl[3] = min_c_r
    max_cntrl[4] = max_c_r
    min_cntrl[4] = min_c_r
    max_cntrl[5] = max_c_r
    min_cntrl[5] = min_c_r
            
    return max_cntrl, min_cntrl

#####################################################
def getclosest(k_, found_solution, exc, inh, already_tried_):
    import numpy as np
    if len(found_solution) == 0:
        print("no solutions found")
        return -1
    
    start_ind = -1
    for j_ in found_solution:
        if j_ not in already_tried_ and j_ != k_:
            start_ind = j_
            break
            
    if start_ind == -1:
        return -1
        
    min_dist = np.sqrt((exc[k_] - exc[start_ind])**2 + (inh[k_] - inh[start_ind])**2)
    min_i = start_ind
        
    print(found_solution, already_tried_)
        
    if len(found_solution) == len(already_tried_):
        print("already tried all options")
        min_i = -1
        return min_i
    
    for i_ in found_solution:
        if i_ not in already_tried_:
            if i_ != k_ and i_ != min_i:
                dist_ = np.sqrt((exc[k_] - exc[i_])**2 + (inh[k_] - inh[i_])**2)
                if dist_ < min_dist:
                    min_dist = dist_
                    min_i = i_
                    
    if min_i == 0 and 0 in already_tried_:
        return -1
    
    return min_i

# %%
##### LOAD BOUNDARIES
data_file = 'bi.pickle'
with open(data_file,'rb') as f:
    load_array= pickle.load(f)
exc = load_array[0]
inh = load_array[1]
print(len(exc))
#plt.scatter(exc, inh)
# Out:
# 147

# %%
bestControl_init = [None] * len(exc)
bestState_init = [None] * len(exc)
cost_init = [None] * len(exc)
runtime_init = [None] * len(exc)
grad_init = [None] * len(exc)
phi_init = [None] * len(exc)
costnode_init = [None] * len(exc)
weights_init = [None] * len(exc)

conv_init = [[False]*2] * len(exc)

# %%
bestControl_0 = [None] * len(exc)
bestState_0 = [None] * len(exc)
cost_0 = [None] * len(exc)
runtime_0 = [None] * len(exc)
grad_0 = [None] * len(exc)
phi_0 = [None] * len(exc)
costnode_0 = [None] * len(exc)
weights_0 = [None] * len(exc)

conv_0 = [[False]*2] * len(exc)

# %%
bestControl_1 = [None] * len(exc)
bestState_1 = [None] * len(exc)
cost_1 = [None] * len(exc)
runtime_1 = [None] * len(exc)
grad_1 = [None] * len(exc)
phi_1 = [None] * len(exc)
costnode_1 = [None] * len(exc)
weights_1 = [None] * len(exc)

conv_1 = [[False]*2] * len(exc)

# %%
initVars = [None] * len(exc)
target = [None] * len(exc)
cost_uncontrolled = [None] * len(exc)

cgv_list = [None, "HS", "FR", "PR", "CD", "LS", "DY", "WYL", "HZ", None]

# %%
dur_pre = 10
dur_post = 10

n_pre = int(np.around(dur_pre/aln.params.dt + 1.,1))
n_post = int(np.around(dur_post/aln.params.dt + 1.,1))

tol = 1e-32
start_step = 10.
c_scheme = np.zeros(( 1,1 ))
c_scheme[0,0] = 1.
u_mat = np.identity(1)
u_scheme = np.array([[1.]])

c_var = [ [0], [1], [0,1]]
p_var = [ [0], [0], [0]]

### CURRENTS
cntrl_vars_0 = [0,1]
prec_vars = [0]

if case[0] == '0':    # low to high
    max_I = [3., -3.]
elif case[0] == '1':
    max_I = [-3., 3.]
    
if case[1] == '0':    # sparsity
    factor_ws = 1.
    factor_we = 0.
elif case[1] == '1':  # energy
    factor_ws = 0.
    factor_we = 1.
    
if case[3] == '0':
    cntrl_vars_init = [0]
elif case[3] == '1':
    cntrl_vars_init = [1]
elif case[3] == '2':
    cntrl_vars_init = [0,1]

if case[4] == '0':
    dur = 100
    trans_time = 0.8
elif case[4] == '1':
    dur = 400
    trans_time = 0.95
    
maxC = [5., -5., 0.18, 0.]

n_dur = int(np.around(dur/aln.params.dt + 1.,1))
max_cntrl, min_cntrl = setmaxmincontrol(maxC[0], maxC[1], maxC[2], maxC[3])

# %%
init_file = 'control_init_' + case + '.pickle'
final_file = 'control_' + case + '.pickle'
case_1 = case[0] + case[1] + '0' + case[3] + case[4]
final_file_1 = 'control_' + case_1 + '.pickle'

# %%
if os.path.isfile(init_file) :
    print("file found")
    
    with open(init_file,'rb') as f:
        load_array = pickle.load(f)

    bestControl_init = load_array[0]
    bestState_init = load_array[1]
    cost_init = load_array[2]
    runtime_init = load_array[3]
    grad_init = load_array[4]
    phi_init = load_array[5]
    costnode_init = load_array[6]
    weights_init = load_array[7]
# Out:
# file found

# %%
# get initial parameters and target states

i_stepsize = 1
limit = 65
start_index = 60
i_range = range(start_index, limit,i_stepsize)
i_range_0 = range(start_index, limit,i_stepsize)
i_range_1 = range(start_index, limit,i_stepsize)
data.set_parameters(aln)

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    aln.params.duration = 3000.
    
    control0 = aln.getZeroControl()
    control0 = functions.step_control(aln, maxI_ = max_I[0])

    aln.run(control=control0)
    
    target_rates = np.zeros((2))
    target_rates[0] = aln.rates_exc[0,-1] 
    target_rates[1] = aln.rates_inh[0,-1]

    control0 = functions.step_control(aln, maxI_ = max_I[1])
    aln.run(control=control0)

    init_state_vars = np.zeros(( len(state_vars) ))
    for j in range(len(state_vars)):
        if aln.state[state_vars[j]].size == 1:
            init_state_vars[j] = aln.state[state_vars[j]][0]
        else:
            init_state_vars[j] = aln.state[state_vars[j]][0,-1]

    initVars[i] = init_state_vars
    
    aln.params.duration = dur

    target[i] = aln.getZeroTarget()
    target[i][:,0,:] = target_rates[0]
    target[i][:,1,:] = target_rates[1]
# Out:
# -------  60 0.5500000000000003 0.6250000000000003
# -------  61 0.5750000000000002 0.6250000000000003
# -------  62 0.4250000000000001 0.6500000000000004
# -------  63 0.4500000000000001 0.6500000000000004
# -------  64 0.47500000000000014 0.6500000000000004

# %%
# get uncontrolled cost

data.set_parameters(aln)

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    aln.params.duration = dur
        
    cost.setParams(1.0, 0.0, 0.0)

##### zero control as input for uncontrolled cost
    setinit(initVars[i], aln)
    control0 = aln.getZeroControl()

    # "HS", "FR", "PR", "HZ"
    cgv = None
    max_it = 0

    bestControl_init_, bestState_init_, cost_init_, runtime_init_, grad_init_, phi_init_, costnode_init_ = aln.A1(
        control0, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cntrl_vars_init,
        prec_variables_ = prec_vars, transition_time_ = trans_time)
    
    cost_uncontrolled[i] = cost_init_[0]
# Out:
# -------  60 0.5500000000000003 0.6250000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  148385.25117022273
# Gradient descend method:  None
# RUN  0 , total integrated cost =  148385.25117022273
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  61 0.5750000000000002 0.6250000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  173480.81674342768
# Gradient descend method:  None
# RUN  0 , total integrated cost =  173480.81674342768
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  62 0.4250000000000001 0.6500000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  34493.011682862874
# Gradient descend method:  None
# RUN  0 , total integrated cost =  34493.011682862874
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  63 0.4500000000000001 0.6500000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  56116.53685480664
# Gradient descend method:  None
# RUN  0 , total integrated cost =  56116.53685480664
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  64 0.47500000000000014 0.6500000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  77654.01745288723
# Gradient descend method:  None
# RUN  0 , total integrated cost =  77654.01745288723
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.

# %%
factor_iteration = 20.

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    aln.params.duration = dur
        
##### zero control as input for uncontrolled cost
    setinit(initVars[i], aln)
    
    if not type(bestControl_init[i]) == type(None):
        continue
        
    control0 = aln.getZeroControl()

    ##### initial guess
    weight_ = 10
    cost.setParams(1.0, weight_ * factor_we, weight_ * factor_ws)

    setinit(initVars[i], aln)

    # "HS", "FR", "PR", "HZ"
    cgv = None
    max_it = int(100 * factor_iteration)

    weights_init[i] = cost.getParams()

    bestControl_init[i], bestState_init[i], cost_init[i], runtime_init[i], grad_init[i], phi_init[i], costnode_init[i] = aln.A1(
        control0, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cntrl_vars_init,
        prec_variables_ = prec_vars, transition_time_ = trans_time)
    
    j = 1
    while cost_init[i][-j] == 0.:
        j += 1
    
    weight_ = 10 * cost_uncontrolled[i] / cost_init[i][-j]
    print("weight = ", weight_)
    cost.setParams(1.0, weight_ * factor_we, weight_ * factor_ws)

    setinit(initVars[i], aln)
    control0 = bestControl_init[i][:,:,n_pre-1:-n_post+1]

    # "HS", "FR", "PR", "HZ"
    cgv = None
    max_it = int(500 * factor_iteration)

    weights_init[i] = cost.getParams()
    
    bestControl_init[i], bestState_init[i], cost_init[i], runtime_init[i], grad_init[i], phi_init[i], costnode_init[i] = aln.A1(
        control0, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cntrl_vars_init,
        prec_variables_ = prec_vars, transition_time_ = trans_time)
        
    with open(init_file,'wb') as f:
        pickle.dump([bestControl_init, bestState_init, cost_init, runtime_init, grad_init, phi_init,
                 costnode_init, weights_init], f)
# Out:
# -------  60 0.5500000000000003 0.6250000000000003
# -------  61 0.5750000000000002 0.6250000000000003
# set cost params:  1.0 10.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  173480.81674342768
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5218.09784164886
# RUN  2 , total integrated cost =  5197.007366823041
# RUN  3 , total integrated cost =  417.7409359350122
# RUN  4 , total integrated cost =  212.843625651394
# RUN  5 , total integrated cost =  179.49588958989267
# RUN  6 , total integrated cost =  165.40967943411246
# RUN  7 , total integrated cost =  156.46688511365105
# RUN  8 , total integrated cost =  149.53554607118798
# RUN  9 , total integrated cost =  143.49658881172553
# RUN  10 , total integrated cost =  138.095715526362
# RUN  11 , total integrated cost =  133.01923831988768
# RUN  12 , total integrated cost =  128.27011803934408
# RUN  13 , total integrated cost =  123.7005690524392
# RUN  14 , total integrated cost =  119.41274589385327
# RUN  15 , total integrated cost =  115.27893898085779
# RUN  16 , total integrated cost =  111.33466235138397
# RUN  17 , total integrated cost =  107.50629102322503
# RUN  18 , total integrated cost =  103.72843876609417
# RUN  19 , total integrated cost =  100.15364086825247
# RUN  20 , total integrated cost =  96.68269518179993
# RUN  30 , total integrated cost =  67.4308333572395
# RUN  40 , total integrated cost =  44.97872187663141
# RUN  50 , total integrated cost =  30.81382714320713
# RUN  60 , total integrated cost =  20.732958346482793
# RUN  70 , total integrated cost =  14.152445038235713
# RUN  80 , total integrated cost =  10.206355623144171
# RUN  90 , total integrated cost =  9.521067130114124
# RUN  100 , total integrated cost =  9.521063392569557
# State only changes marginally.
# State only changes marginally.
# State only changes marginally.
# Control only changes marginally.
# RUN  107 , total integrated cost =  9.521063392569515
# Improved over  107  iterations in  1.2561341270338744  seconds by  99.99451174857757  percent.
# weight =  182207.39594992783
# set cost params:  1.0 182207.39594992783 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  171814.99938632792
# Gradient descend method:  None
# RUN  1 , total integrated cost =  138256.18209007458
# RUN  2 , total integrated cost =  138234.55917620286
# RUN  3 , total integrated cost =  138234.42230586932
# RUN  4 , total integrated cost =  138234.42120317265
# RUN  5 , total integrated cost =  138234.42120317247
# RUN  6 , total integrated cost =  138234.42120317245
# RUN  7 , total integrated cost =  138234.42120317242
# RUN  8 , total integrated cost =  138234.42120317242
# Control only changes marginally.
# RUN  8 , total integrated cost =  138234.42120317242
# Improved over  8  iterations in  0.15684530301950872  seconds by  19.54461385973015  percent.
# -------  62 0.4250000000000001 0.6500000000000004
# set cost params:  1.0 10.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  34493.011682862874
# Gradient descend method:  None
# RUN  1 , total integrated cost =  34493.011682862874
# Control only changes marginally.
# RUN  1 , total integrated cost =  34493.011682862874
# Improved over  1  iterations in  0.025911195029038936  seconds by  0.0  percent.
# weight =  10.0
# set cost params:  1.0 10.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  34493.011682862874
# Gradient descend method:  None
# RUN  1 , total integrated cost =  34493.011682862874
# Control only changes marginally.
# RUN  1 , total integrated cost =  34493.011682862874
# Improved over  1  iterations in  0.0241122129955329  seconds by  0.0  percent.
# -------  63 0.4500000000000001 0.6500000000000004
# set cost params:  1.0 10.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  56116.53685480664
# Gradient descend method:  None
# RUN  1 , total integrated cost =  56116.5368548053
# RUN  2 , total integrated cost =  56116.53685480491
# RUN  3 , total integrated cost =  56116.53685480491
# Control only changes marginally.
# RUN  3 , total integrated cost =  56116.53685480491
# Improved over  3  iterations in  0.04787033301545307  seconds by  3.083755473198835e-12  percent.
# weight =  10.000000000000307
# set cost params:  1.0 10.000000000000307 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  56116.53685480491
# Gradient descend method:  None
# RUN  1 , total integrated cost =  56116.53685480491
# Control only changes marginally.
# RUN  1 , total integrated cost =  56116.53685480491
# Improved over  1  iterations in  0.02664219297003001  seconds by  0.0  percent.
# -------  64 0.47500000000000014 0.6500000000000004
# set cost params:  1.0 10.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  77654.01745288723
# Gradient descend method:  None
# RUN  1 , total integrated cost =  77654.01745020793
# RUN  2 , total integrated cost =  77654.01745020793
# Control only changes marginally.
# RUN  2 , total integrated cost =  77654.01745020793
# Improved over  2  iterations in  0.04332325200084597  seconds by  3.4503102597227553e-09  percent.
# weight =  10.00000000034503
# set cost params:  1.0 10.00000000034503 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  77654.01745020793
# Gradient descend method:  None
# RUN  1 , total integrated cost =  77654.01745020793
# Control only changes marginally.
# RUN  1 , total integrated cost =  77654.01745020793
# Improved over  1  iterations in  0.03078818297944963  seconds by  0.0  percent.

# %%
#plot initial guesses
for i in i_range:
    print("---------", i)
        
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.

    plotFunc.plot_control_current(aln, [bestControl_init[i]],
        [costnode_init[i]], [weights_init[i]], dur,
        dur_pre, dur_post, initVars[i], target[i], '', filename_ = '', transition_time_ = trans_time,
        labels_ = ["init", "sparse control" + str(i)], print_cost_ = False)
    plt.show()
# Out:
# --------- 60
# --------- 61
# --------- 62
# --------- 63
# --------- 64

# %%
found_solution = []
no_solution = []
factor_iteration = 1.
already_tried = [ [] for _ in range(len(exc)) ]

for k in range(len(i_range)**2):
    print('------------------------------------------------------------')
    print('--------------------', k)
    print('------------------------------------------------------------')
        
    print("found solution: ", found_solution)
    print("no solution: ", no_solution)
    
    if len(i_range) == len(found_solution) + len(no_solution):
        print("found solution for all parameters")
        break


    for i in i_range:
        print("------- ", i, exc[i], inh[i])     

        if np.abs(np.mean(bestState_init[i][0,0,-300:]) - target[i][0,0,-1]) < 0.1 * np.abs(
            np.mean(bestState_init[i][0,0,-100:]) - bestState_init[i][0,0,0]) and np.abs(
            np.mean(bestState_init[i][0,1,-300:]) - target[i][0,1,-1]) < 0.1 * np.abs(
            np.mean(bestState_init[i][0,1,-100:]) - bestState_init[i][0,1,0]) and np.amax(
            bestState_init[i][0,0,:]) < target[i][0,0,-1] + 1. and np.amax(
            bestState_init[i][0,1,:]) < target[i][0,1,-1] + 1.:
            # and np.amin(bestState_init[i][0,0,:]) > bestState_init[i][0,0,0] - 1.
            #and np.amin(bestState_init[i][0,1,:]) > bestState_init[i][0,1,0] - 1.:
            if i not in found_solution:
                print("found solution for ", i)
                found_solution.append(i)
            if i in no_solution:
                no_solution.pop(no_solution.index(i))
            continue

        if len(found_solution) == 0:
            continue
            
        closest_ = getclosest(i, found_solution, exc, inh, already_tried[i])
        print("closest index ", closest_)

        weight_ = 10
        cost.setParams(1.0, weight_ * factor_we, weight_ * factor_ws)

        setinit(initVars[i], aln)
        aln.params.ext_exc_current = exc[i] * 5.
        aln.params.ext_inh_current = inh[i] * 5.
            
        if i != 0 and closest_ != -1:
            control0 = 2. * bestControl_init[closest_][:,:,n_pre-1:-n_post+1]
            if closest_ not in already_tried[i]:
                already_tried[i].append(closest_)
                        
        if closest_ == -1:
            print("all options tried already")
            if i not in no_solution:
                no_solution.append(i)
                continue

        # "HS", "FR", "PR", "HZ"
        cgv = None
        max_it = int(100 * factor_iteration)

        weights_init[i] = cost.getParams()
        
        print("precision vars = ", prec_vars)

        bestControl_init[i], bestState_init[i], cost_init[i], runtime_init[i], grad_init[i], phi_init[i], costnode_init[i] = aln.A1(
            control0, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cntrl_vars_init,
            prec_variables_ = prec_vars, transition_time_ = trans_time)

        j = 1
        while cost_init[i][-j] == 0.:
            j += 1

        weight_ = 10 * cost_uncontrolled[i] / cost_init[i][-j]
        print("weight = ", weight_)
        cost.setParams(1.0, weight_ * factor_we, weight_ * factor_ws)

        setinit(initVars[i], aln)
        control0 = bestControl_init[i][:,:,n_pre-1:-n_post+1]

        # "HS", "FR", "PR", "HZ"
        cgv = None
        max_it = int(500 * factor_iteration)

        weights_init[i] = cost.getParams()

        bestControl_init[i], bestState_init[i], cost_init[i], runtime_init[i], grad_init[i], phi_init[i], costnode_init[i] = aln.A1(
            control0, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cntrl_vars_init,
            prec_variables_ = prec_vars, transition_time_ = trans_time)
        
        with open(init_file,'wb') as f:
            pickle.dump([bestControl_init, bestState_init, cost_init, runtime_init, grad_init, phi_init,
                         costnode_init, weights_init], f)
# Out:
# ------------------------------------------------------------
# -------------------- 0
# ------------------------------------------------------------
# found solution:  []
# no solution:  []
# -------  60 0.5500000000000003 0.6250000000000003
# found solution for  60
# -------  61 0.5750000000000002 0.6250000000000003
# [60] []
# closest index  60
# set cost params:  1.0 10.0 0.0
# precision vars =  [0]
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  386.05592829086606
# Gradient descend method:  None
# RUN  1 , total integrated cost =  122.33035402013482
# RUN  2 , total integrated cost =  101.8541778912403
# RUN  3 , total integrated cost =  94.69192131728344
# RUN  4 , total integrated cost =  90.19741760658687
# RUN  5 , total integrated cost =  86.55319825650892
# RUN  6 , total integrated cost =  83.33070836137502
# RUN  7 , total integrated cost =  80.3371631080759
# RUN  8 , total integrated cost =  77.51788179196656
# RUN  9 , total integrated cost =  74.8162132403298
# RUN  10 , total integrated cost =  72.1685572795602
# RUN  11 , total integrated cost =  69.51258069610809
# RUN  12 , total integrated cost =  67.02727341818895
# RUN  13 , total integrated cost =  64.6307972983706
# RUN  14 , total integrated cost =  62.286051699367036
# RUN  15 , total integrated cost =  60.112167596858754
# RUN  16 , total integrated cost =  58.07380172279876
# RUN  17 , total integrated cost =  56.06723389403153
# RUN  18 , total integrated cost =  54.15499596052541
# RUN  19 , total integrated cost =  52.300726497691045
# RUN  20 , total integrated cost =  50.50624110537819
# RUN  30 , total integrated cost =  35.775761543863176
# RUN  40 , total integrated cost =  25.0121103680112
# RUN  50 , total integrated cost =  17.144931392579245
# RUN  60 , total integrated cost =  11.821938568167646
# RUN  70 , total integrated cost =  8.378650206031125
# RUN  80 , total integrated cost =  6.677163063252008
# RUN  90 , total integrated cost =  6.558530694595262
# Control only changes marginally.
# RUN  90 , total integrated cost =  6.558530694595262
# Improved over  90  iterations in  2.7812807689770125  seconds by  98.30114493419879  percent.
# weight =  264511.709743753
# set cost params:  1.0 264511.709743753 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  172024.57913771764
# Gradient descend method:  None
# RUN  1 , total integrated cost =  151182.97133092614
# RUN  2 , total integrated cost =  151182.97133092562
# RUN  3 , total integrated cost =  151182.97133092562
# Control only changes marginally.
# RUN  3 , total integrated cost =  151182.97133092562
# Improved over  3  iterations in  0.19600728602381423  seconds by  12.115482514918327  percent.
# -------  62 0.4250000000000001 0.6500000000000004
# [60] []
# closest index  60
# set cost params:  1.0 10.0 0.0
# precision vars =  [0]
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  34592.212952609945
# Gradient descend method:  None
# RUN  1 , total integrated cost =  34493.03588847842
# RUN  2 , total integrated cost =  34493.01168877109
# RUN  3 , total integrated cost =  34493.01168286432
# RUN  4 , total integrated cost =  34493.011682862874
# RUN  5 , total integrated cost =  34493.011682862874
# Control only changes marginally.
# RUN  5 , total integrated cost =  34493.011682862874
# Improved over  5  iterations in  0.1733333829906769  seconds by  0.2867734130885822  percent.
# weight =  10.0
# set cost params:  1.0 10.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  34493.011682862874
# Gradient descend method:  None
# RUN  1 , total integrated cost =  34493.011682862874
# Control only changes marginally.
# RUN  1 , total integrated cost =  34493.011682862874
# Improved over  1  iterations in  0.057976034993771464  seconds by  0.0  percent.
# -------  63 0.4500000000000001 0.6500000000000004
# [60] []
# closest index  60
# set cost params:  1.0 10.0 0.0
# precision vars =  [0]
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  56215.7204058884
# Gradient descend method:  None
# RUN  1 , total integrated cost =  56116.56073448474
# RUN  2 , total integrated cost =  1107.058369460752
# RUN  3 , total integrated cost =  298.81185918891487
# RUN  4 , total integrated cost =  290.3979881845536
# RUN  5 , total integrated cost =  283.0153635229936
# RUN  6 , total integrated cost =  279.04557561606896
# RUN  7 , total integrated cost =  273.1568147017073
# RUN  8 , total integrated cost =  269.31489960504655
# RUN  9 , total integrated cost =  260.80892825401537
# RUN  10 , total integrated cost =  254.6874527701287
# RUN  11 , total integrated cost =  230.14053785552315
# RUN  12 , total integrated cost =  230.07721789083357
# RUN  13 , total integrated cost =  230.02433595762048
# RUN  14 , total integrated cost =  229.35839294693332
# RUN  15 , total integrated cost =  229.08133898832327
# RUN  16 , total integrated cost =  229.0644055374764
# RUN  17 , total integrated cost =  228.98032338906194
# RUN  18 , total integrated cost =  228.58246084570013
# RUN  19 , total integrated cost =  228.52511668676595
# RUN  20 , total integrated cost =  228.51496821039996
# RUN  30 , total integrated cost =  227.44031515689838
# RUN  40 , total integrated cost =  226.20629788955395
# RUN  50 , total integrated cost =  226.20629788822322
# Control only changes marginally.
# RUN  50 , total integrated cost =  226.20629788822322
# Improved over  50  iterations in  1.3690341949695721  seconds by  99.59761024806768  percent.
# weight =  2480.768103217704
# set cost params:  1.0 2480.768103217704 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  55449.950473207515
# Gradient descend method:  None
# RUN  1 , total integrated cost =  55304.3575263483
# RUN  2 , total integrated cost =  55304.35752634827
# RUN  3 , total integrated cost =  55304.35752634826
# RUN  4 , total integrated cost =  55304.35752634826
# Control only changes marginally.
# RUN  4 , total integrated cost =  55304.35752634826
# Improved over  4  iterations in  0.33869967598002404  seconds by  0.26256641460771846  percent.
# -------  64 0.47500000000000014 0.6500000000000004
# [60] []
# closest index  60
# set cost params:  1.0 10.0 0.0
# precision vars =  [0]
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  77752.8229366172
# Gradient descend method:  None
# RUN  1 , total integrated cost =  77654.03644286525
# RUN  2 , total integrated cost =  6304.085223418747
# RUN  3 , total integrated cost =  272.64333400073394
# RUN  4 , total integrated cost =  182.98105360510255
# RUN  5 , total integrated cost =  175.84435493222958
# RUN  6 , total integrated cost =  172.26236361080836
# RUN  7 , total integrated cost =  168.53819535450904
# RUN  8 , total integrated cost =  168.23845358681913
# RUN  9 , total integrated cost =  168.11153732264506
# RUN  10 , total integrated cost =  167.8767956825192
# RUN  11 , total integrated cost =  165.778061226087
# RUN  12 , total integrated cost =  164.76746996603663
# RUN  13 , total integrated cost =  164.70853835973048
# RUN  14 , total integrated cost =  164.7082589346577
# RUN  15 , total integrated cost =  164.708258803904
# RUN  16 , total integrated cost =  164.7082588039028
# RUN  17 , total integrated cost =  164.70825880390268
# RUN  18 , total integrated cost =  164.70825880390237
# RUN  19 , total integrated cost =  164.70825880390223
# RUN  20 , total integrated cost =  164.7082588039022
# Control only changes marginally.
# RUN  21 , total integrated cost =  164.7082588039022
# Improved over  21  iterations in  0.7707887039869092  seconds by  99.78816427161986  percent.
# weight =  4714.640177535985
# set cost params:  1.0 4714.640177535985 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  77344.57678105625
# Gradient descend method:  None
# RUN  1 , total integrated cost =  76395.03749521321
# RUN  2 , total integrated cost =  76393.1389910791
# RUN  3 , total integrated cost =  76393.13731792018
# RUN  4 , total integrated cost =  76393.13731792006
# RUN  5 , total integrated cost =  76393.13731792005
# RUN  6 , total integrated cost =  76393.13731792005
# Control only changes marginally.
# RUN  6 , total integrated cost =  76393.13731792005
# Improved over  6  iterations in  0.3169225539895706  seconds by  1.2301308026152924  percent.
# ------------------------------------------------------------
# -------------------- 1
# ------------------------------------------------------------
# found solution:  [60]
# no solution:  []
# -------  60 0.5500000000000003 0.6250000000000003
# -------  61 0.5750000000000002 0.6250000000000003
# found solution for  61
# -------  62 0.4250000000000001 0.6500000000000004
# [60, 61] [60]
# closest index  61
# set cost params:  1.0 10.0 0.0
# precision vars =  [0]
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  34515.085872091564
# Gradient descend method:  None
# RUN  1 , total integrated cost =  34493.01707196708
# RUN  2 , total integrated cost =  34493.011684177975
# RUN  3 , total integrated cost =  34493.011682863194
# RUN  4 , total integrated cost =  34493.011682862874
# RUN  5 , total integrated cost =  34493.011682862874
# Control only changes marginally.
# RUN  5 , total integrated cost =  34493.011682862874
# Improved over  5  iterations in  0.19482031895313412  seconds by  0.06395519139222472  percent.
# weight =  10.0
# set cost params:  1.0 10.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  34493.011682862874
# Gradient descend method:  None
# RUN  1 , total integrated cost =  34493.011682862874
# Control only changes marginally.
# RUN  1 , total integrated cost =  34493.011682862874
# Improved over  1  iterations in  0.06994944397592917  seconds by  0.0  percent.
# -------  63 0.4500000000000001 0.6500000000000004
# found solution for  63
# -------  64 0.47500000000000014 0.6500000000000004
# found solution for  64
# ------------------------------------------------------------
# -------------------- 2
# ------------------------------------------------------------
# found solution:  [60, 61, 63, 64]
# no solution:  []
# -------  60 0.5500000000000003 0.6250000000000003
# -------  61 0.5750000000000002 0.6250000000000003
# -------  62 0.4250000000000001 0.6500000000000004
# [60, 61, 63, 64] [60, 61]
# closest index  63
# set cost params:  1.0 10.0 0.0
# precision vars =  [0]
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2393.3717527433187
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1213.965793676232
# RUN  2 , total integrated cost =  999.6508406957777
# RUN  3 , total integrated cost =  928.1168689482049
# RUN  4 , total integrated cost =  889.7662019623132
# RUN  5 , total integrated cost =  864.3273052184142
# RUN  6 , total integrated cost =  845.125336749153
# RUN  7 , total integrated cost =  828.5336447692794
# RUN  8 , total integrated cost =  813.9233831769642
# RUN  9 , total integrated cost =  800.1339161845476
# RUN  10 , total integrated cost =  787.2555368094831
# RUN  11 , total integrated cost =  774.6143655332905
# RUN  12 , total integrated cost =  762.2287577885606
# RUN  13 , total integrated cost =  749.9354628103183
# RUN  14 , total integrated cost =  738.7101003350051
# RUN  15 , total integrated cost =  727.5283181996591
# RUN  16 , total integrated cost =  716.9396377369793
# RUN  17 , total integrated cost =  706.3105593492107
# RUN  18 , total integrated cost =  696.0717933577032
# RUN  19 , total integrated cost =  685.6827244735848
# RUN  20 , total integrated cost =  675.4317707842484
# RUN  30 , total integrated cost =  576.1989894707675
# RUN  40 , total integrated cost =  492.45600449927224
# RUN  50 , total integrated cost =  417.18474728571624
# RUN  60 , total integrated cost =  355.6252050052075
# RUN  70 , total integrated cost =  306.8886772600593
# RUN  80 , total integrated cost =  301.79868924861694
# Control only changes marginally.
# RUN  84 , total integrated cost =  301.79868924861614
# Improved over  84  iterations in  2.4417401970131323  seconds by  87.39022933220926  percent.
# weight =  1142.9145623110435
# set cost params:  1.0 1142.9145623110435 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  34107.69746575218
# Gradient descend method:  None
# RUN  1 , total integrated cost =  34009.508957662176
# RUN  2 , total integrated cost =  34009.50895766215
# RUN  3 , total integrated cost =  34009.50895766214
# RUN  4 , total integrated cost =  34009.50895766214
# Control only changes marginally.
# RUN  4 , total integrated cost =  34009.50895766214
# Improved over  4  iterations in  0.23503139900276437  seconds by  0.2878778556911783  percent.
# -------  63 0.4500000000000001 0.6500000000000004
# -------  64 0.47500000000000014 0.6500000000000004
# ------------------------------------------------------------
# -------------------- 3
# ------------------------------------------------------------
# found solution:  [60, 61, 63, 64]
# no solution:  []
# -------  60 0.5500000000000003 0.6250000000000003
# -------  61 0.5750000000000002 0.6250000000000003
# -------  62 0.4250000000000001 0.6500000000000004
# found solution for  62
# -------  63 0.4500000000000001 0.6500000000000004
# -------  64 0.47500000000000014 0.6500000000000004
# ------------------------------------------------------------
# -------------------- 4
# ------------------------------------------------------------
# found solution:  [60, 61, 63, 64, 62]
# no solution:  []
# found solution for all parameters

# %%
factor_iteration = 20
full_converge = False
conv_init = [[False]*2] * len(exc)

for i in range(len(conv_init)):
    if i not in i_range:
        conv_init[i] = [True, True]
        
counter = 0

while full_converge == False:
    
    print("------------------------------------------------")
    print('-------------------------', counter)
    
    if counter > 20:
        break
        
    print(conv_init[::i_stepsize])
    full_converge = True
    
    for conv in conv_init[::i_stepsize]:
        if not conv[0]:
            full_converge = False
            break
        if not conv[1]:
            full_converge = False
            break
    
    if full_converge:
        print("full convergence")
        break

    for i in i_range:        

        print("------- ", i, exc[i], inh[i])
        
        if conv_init[i] == [True, True]:
            continue
        aln.params.ext_exc_current = exc[i] * 5.
        aln.params.ext_inh_current = inh[i] * 5.
        
        j = 1
        while cost_init[i][-j] == 0.:
            j += 1
                       
        weight_ = (factor_we * weights_init[i][1] * cost_uncontrolled[i] / cost_init[i][-j]
                   + factor_ws * weights_init[i][2] * cost_uncontrolled[i] / cost_init[i][-j]) - 1
        print("weight = ", weight_)
        cost.setParams(1.0, weight_ * factor_we, weight_ * factor_ws)

        setinit(initVars[i], aln)
        control0 = bestControl_init[i][:,:,n_pre-1:-n_post+1]

        # "HS", "FR", "PR", "HZ"
        cgv = None
        max_it = int( 500 * factor_iteration )

        weights_init[i] = cost.getParams()

        bestControl_init[i], bestState_init[i], cost_init[i], runtime_init[i], grad_init[i], phi_init[i], costnode_init[i] = aln.A1(
            control0, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cntrl_vars_init,
            prec_variables_ = prec_vars, transition_time_ = trans_time)
        
        with open(init_file,'wb') as f:
            pickle.dump([bestControl_init, bestState_init, cost_init, runtime_init, grad_init, phi_init,
                         costnode_init, weights_init], f)
            
        if j == cost_init[i].shape[0]-1:
            print("converged for ", i)
            if conv_init[i][0]:
                conv_init[i] = [True, True]
            else:
                conv_init[i] = [True, False]
            continue
    
        print("no convergence")
            
    counter += 1
# Out:
# ------------------------------------------------
# ------------------------- 0
# [[True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [False, False], [False, False], [False, False], [False, False], [False, False], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# -------  60 0.5500000000000003 0.6250000000000003
# weight =  59092.27394024865
# set cost params:  1.0 59092.27394024865 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  148382.74013546412
# Gradient descend method:  None
# RUN  1 , total integrated cost =  148382.74013546412
# Control only changes marginally.
# RUN  1 , total integrated cost =  148382.74013546412
# Improved over  1  iterations in  0.12645291804801673  seconds by  0.0  percent.
# converged for  60
# -------  61 0.5750000000000002 0.6250000000000003
# weight =  303523.3125636338
# set cost params:  1.0 303523.3125636338 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  172711.72506535967
# Gradient descend method:  None
# RUN  1 , total integrated cost =  172704.39253310434
# RUN  2 , total integrated cost =  172704.37663971045
# RUN  3 , total integrated cost =  172704.37663605757
# RUN  4 , total integrated cost =  172704.37663605728
# RUN  5 , total integrated cost =  172704.37663605725
# RUN  6 , total integrated cost =  172704.37663605722
# RUN  7 , total integrated cost =  172704.37663605722
# Control only changes marginally.
# RUN  7 , total integrated cost =  172704.37663605722
# Improved over  7  iterations in  0.4966888870112598  seconds by  0.0042547367873737585  percent.
# no convergence
# -------  62 0.4250000000000001 0.6500000000000004
# weight =  1158.1630270047538
# set cost params:  1.0 1158.1630270047538 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  34462.297271916534
# Gradient descend method:  None
# RUN  1 , total integrated cost =  34462.297271916534
# Control only changes marginally.
# RUN  1 , total integrated cost =  34462.297271916534
# Improved over  1  iterations in  0.11776843102416024  seconds by  0.0  percent.
# no convergence
# -------  63 0.4500000000000001 0.6500000000000004
# weight =  2516.199745537613
# set cost params:  1.0 2516.199745537613 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  56092.78119077371
# Gradient descend method:  None
# RUN  1 , total integrated cost =  56092.78119077371
# Control only changes marginally.
# RUN  1 , total integrated cost =  56092.78119077371
# Improved over  1  iterations in  0.07650525902863592  seconds by  0.0  percent.
# no convergence
# -------  64 0.47500000000000014 0.6500000000000004
# weight =  4791.456017441003
# set cost params:  1.0 4791.456017441003 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  77632.97391364678
# Gradient descend method:  None
# RUN  1 , total integrated cost =  77632.93676752475
# RUN  2 , total integrated cost =  77632.93676752459
# RUN  3 , total integrated cost =  77632.93676752457
# RUN  4 , total integrated cost =  77632.93676752457
# Control only changes marginally.
# RUN  4 , total integrated cost =  77632.93676752457
# Improved over  4  iterations in  0.25045908201718703  seconds by  4.784838237981148e-05  percent.
# no convergence
# ------------------------------------------------
# ------------------------- 1
# [[True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, False], [False, False], [False, False], [False, False], [False, False], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# -------  60 0.5500000000000003 0.6250000000000003
# weight =  59092.273940340936
# set cost params:  1.0 59092.273940340936 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  148382.740135693
# Gradient descend method:  None
# RUN  1 , total integrated cost =  148382.740135693
# Control only changes marginally.
# RUN  1 , total integrated cost =  148382.740135693
# Improved over  1  iterations in  0.09380088199395686  seconds by  0.0  percent.
# converged for  60
# -------  61 0.5750000000000002 0.6250000000000003
# weight =  304886.88523971004
# set cost params:  1.0 304886.88523971004 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  173455.41515170442
# Gradient descend method:  None
# RUN  1 , total integrated cost =  173455.37089540623
# RUN  2 , total integrated cost =  173455.37089532235
# RUN  3 , total integrated cost =  173455.3708953223
# RUN  4 , total integrated cost =  173455.37089532212
# RUN  5 , total integrated cost =  173455.37089532206
# RUN  6 , total integrated cost =  173455.37089532198
# RUN  7 , total integrated cost =  173455.37089532192
# RUN  8 , total integrated cost =  173455.37089532177
# RUN  9 , total integrated cost =  173455.37089532177
# Control only changes marginally.
# RUN  9 , total integrated cost =  173455.37089532177
# Improved over  9  iterations in  0.41973668202990666  seconds by  2.5514558089412276e-05  percent.
# no convergence
# -------  62 0.4250000000000001 0.6500000000000004
# weight =  1158.1952360555204
# set cost params:  1.0 1158.1952360555204 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  34463.2536883225
# Gradient descend method:  None
# RUN  1 , total integrated cost =  34463.2536883225
# Control only changes marginally.
# RUN  1 , total integrated cost =  34463.2536883225
# Improved over  1  iterations in  0.09495655598584563  seconds by  0.0  percent.
# converged for  62
# -------  63 0.4500000000000001 0.6500000000000004
# weight =  2516.265372781009
# set cost params:  1.0 2516.265372781009 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  56094.241525896156
# Gradient descend method:  None
# RUN  1 , total integrated cost =  56094.241525896134
# RUN  2 , total integrated cost =  56094.24152589612
# RUN  3 , total integrated cost =  56094.24152589612
# Control only changes marginally.
# RUN  3 , total integrated cost =  56094.24152589612
# Improved over  3  iterations in  0.21786919701844454  seconds by  7.105427357601002e-14  percent.
# converged for  63
# -------  64 0.47500000000000014 0.6500000000000004
# weight =  4791.757104079463
# set cost params:  1.0 4791.757104079463 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  77637.79610701026
# Gradient descend method:  None
# RUN  1 , total integrated cost =  77637.79610701012
# RUN  2 , total integrated cost =  77637.79610701009
# RUN  3 , total integrated cost =  77637.79610701006
# RUN  4 , total integrated cost =  77637.79610701006
# Control only changes marginally.
# RUN  4 , total integrated cost =  77637.79610701006
# Improved over  4  iterations in  0.43318055901909247  seconds by  2.7000623958883807e-13  percent.
# no convergence
# ------------------------------------------------
# ------------------------- 2
# [[True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [False, False], [True, False], [True, False], [False, False], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# -------  60 0.5500000000000003 0.6250000000000003
# -------  61 0.5750000000000002 0.6250000000000003
# weight =  304930.6120494436
# set cost params:  1.0 304930.6120494436 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  173479.4519912272
# Gradient descend method:  None
# RUN  1 , total integrated cost =  173479.45187230155
# RUN  2 , total integrated cost =  173479.45187226436
# RUN  3 , total integrated cost =  173479.45187226406
# RUN  4 , total integrated cost =  173479.45187226404
# RUN  5 , total integrated cost =  173479.45187226404
# Control only changes marginally.
# RUN  5 , total integrated cost =  173479.45187226404
# Improved over  5  iterations in  0.39659458899404854  seconds by  6.857477785615629e-08  percent.
# no convergence
# -------  62 0.4250000000000001 0.6500000000000004
# weight =  1158.1953031943615
# set cost params:  1.0 1158.1953031943615 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  34463.25568194509
# Gradient descend method:  None
# RUN  1 , total integrated cost =  34463.255681945084
# RUN  2 , total integrated cost =  34463.255681945084
# Control only changes marginally.
# RUN  2 , total integrated cost =  34463.255681945084
# Improved over  2  iterations in  0.1559541600290686  seconds by  2.842170943040401e-14  percent.
# converged for  62
# -------  63 0.4500000000000001 0.6500000000000004
# weight =  2516.2654926255104
# set cost params:  1.0 2516.2654926255104 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  56094.2441926718
# Gradient descend method:  None
# RUN  1 , total integrated cost =  56094.2441926718
# Control only changes marginally.
# RUN  1 , total integrated cost =  56094.2441926718
# Improved over  1  iterations in  0.09484041802352294  seconds by  0.0  percent.
# no convergence
# -------  64 0.47500000000000014 0.6500000000000004
# weight =  4791.75827558667
# set cost params:  1.0 4791.75827558667 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  77637.81501436295
# Gradient descend method:  None
# RUN  1 , total integrated cost =  77637.81501436271
# RUN  2 , total integrated cost =  77637.8150143627
# RUN  3 , total integrated cost =  77637.8150143627
# Control only changes marginally.
# RUN  3 , total integrated cost =  77637.8150143627
# Improved over  3  iterations in  0.2062185849645175  seconds by  3.268496584496461e-13  percent.
# no convergence
# ------------------------------------------------
# ------------------------- 3
# [[True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [False, False], [True, True], [True, False], [False, False], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# -------  60 0.5500000000000003 0.6250000000000003
# -------  61 0.5750000000000002 0.6250000000000003
# weight =  304932.01112895884
# set cost params:  1.0 304932.01112895884 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  173480.22236145238
# Gradient descend method:  None
# RUN  1 , total integrated cost =  173480.2223613422
# RUN  2 , total integrated cost =  173480.22236134217
# RUN  3 , total integrated cost =  173480.22236134214
# RUN  4 , total integrated cost =  173480.22236134202
# RUN  5 , total integrated cost =  173480.222361342
# RUN  6 , total integrated cost =  173480.22236134193
# RUN  7 , total integrated cost =  173480.22236134193
# Control only changes marginally.
# RUN  7 , total integrated cost =  173480.22236134193
# Improved over  7  iterations in  0.5307173330220394  seconds by  6.366462912410498e-11  percent.
# no convergence
# -------  62 0.4250000000000001 0.6500000000000004
# -------  63 0.4500000000000001 0.6500000000000004
# weight =  2516.2654928443562
# set cost params:  1.0 2516.2654928443562 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  56094.24419754159
# Gradient descend method:  None
# RUN  1 , total integrated cost =  56094.24419754151
# RUN  2 , total integrated cost =  56094.24419754151
# Control only changes marginally.
# RUN  2 , total integrated cost =  56094.24419754151
# Improved over  2  iterations in  0.21370693400967866  seconds by  1.4210854715202004e-13  percent.
# converged for  63
# -------  64 0.47500000000000014 0.6500000000000004
# weight =  4791.7582801446315
# set cost params:  1.0 4791.7582801446315 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  77637.81508792532
# Gradient descend method:  None
# RUN  1 , total integrated cost =  77637.81508792518
# RUN  2 , total integrated cost =  77637.81508792509
# RUN  3 , total integrated cost =  77637.81508792508
# RUN  4 , total integrated cost =  77637.81508792506
# RUN  5 , total integrated cost =  77637.81508792506
# Control only changes marginally.
# RUN  5 , total integrated cost =  77637.81508792506
# Improved over  5  iterations in  0.43952919397270307  seconds by  3.268496584496461e-13  percent.
# no convergence
# ------------------------------------------------
# ------------------------- 4
# [[True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [False, False], [True, True], [True, True], [False, False], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# -------  60 0.5500000000000003 0.6250000000000003
# -------  61 0.5750000000000002 0.6250000000000003
# weight =  304932.0558943063
# set cost params:  1.0 304932.0558943063 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  173480.24701412642
# Gradient descend method:  None
# RUN  1 , total integrated cost =  173480.24701412642
# Control only changes marginally.
# RUN  1 , total integrated cost =  173480.24701412642
# Improved over  1  iterations in  0.09063884901115671  seconds by  0.0  percent.
# no convergence
# -------  62 0.4250000000000001 0.6500000000000004
# -------  63 0.4500000000000001 0.6500000000000004
# -------  64 0.47500000000000014 0.6500000000000004
# weight =  4791.758280162374
# set cost params:  1.0 4791.758280162374 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  77637.81508821173
# Gradient descend method:  None
# RUN  1 , total integrated cost =  77637.81508821172
# RUN  2 , total integrated cost =  77637.81508821165
# RUN  3 , total integrated cost =  77637.81508821165
# Control only changes marginally.
# RUN  3 , total integrated cost =  77637.81508821165
# Improved over  3  iterations in  0.1898017930216156  seconds by  1.1368683772161603e-13  percent.
# no convergence
# ------------------------------------------------
# ------------------------- 5
# [[True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [False, False], [True, True], [True, True], [False, False], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# -------  60 0.5500000000000003 0.6250000000000003
# -------  61 0.5750000000000002 0.6250000000000003
# weight =  304932.05732663145
# set cost params:  1.0 304932.05732663145 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  173480.2478029242
# Gradient descend method:  None
# RUN  1 , total integrated cost =  173480.24780292393
# RUN  2 , total integrated cost =  173480.2478029239
# RUN  3 , total integrated cost =  173480.2478029239
# Control only changes marginally.
# RUN  3 , total integrated cost =  173480.2478029239
# Improved over  3  iterations in  0.2444573289831169  seconds by  1.7053025658242404e-13  percent.
# converged for  61
# -------  62 0.4250000000000001 0.6500000000000004
# -------  63 0.4500000000000001 0.6500000000000004
# -------  64 0.47500000000000014 0.6500000000000004
# weight =  4791.7582801624285
# set cost params:  1.0 4791.7582801624285 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  77637.81508821266
# Gradient descend method:  None
# RUN  1 , total integrated cost =  77637.81508821262
# RUN  2 , total integrated cost =  77637.8150882126
# RUN  3 , total integrated cost =  77637.8150882126
# Control only changes marginally.
# RUN  3 , total integrated cost =  77637.8150882126
# Improved over  3  iterations in  0.234498028003145  seconds by  7.105427357601002e-14  percent.
# no convergence
# ------------------------------------------------
# ------------------------- 6
# [[True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, False], [True, True], [True, True], [False, False], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# -------  60 0.5500000000000003 0.6250000000000003
# -------  61 0.5750000000000002 0.6250000000000003
# weight =  304932.05737246096
# set cost params:  1.0 304932.05737246096 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  173480.24782816306
# Gradient descend method:  None
# RUN  1 , total integrated cost =  173480.24782816306
# Control only changes marginally.
# RUN  1 , total integrated cost =  173480.24782816306
# Improved over  1  iterations in  0.10401935002300888  seconds by  0.0  percent.
# no convergence
# -------  62 0.4250000000000001 0.6500000000000004
# -------  63 0.4500000000000001 0.6500000000000004
# -------  64 0.47500000000000014 0.6500000000000004
# weight =  4791.758280162424
# set cost params:  1.0 4791.758280162424 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  77637.81508821253
# Gradient descend method:  None
# RUN  1 , total integrated cost =  77637.81508821253
# Control only changes marginally.
# RUN  1 , total integrated cost =  77637.81508821253
# Improved over  1  iterations in  0.12488532200222835  seconds by  0.0  percent.
# no convergence
# ------------------------------------------------
# ------------------------- 7
# [[True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, False], [True, True], [True, True], [False, False], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# -------  60 0.5500000000000003 0.6250000000000003
# -------  61 0.5750000000000002 0.6250000000000003
# weight =  304932.05737392674
# set cost params:  1.0 304932.05737392674 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  173480.24782897023
# Gradient descend method:  None
# RUN  1 , total integrated cost =  173480.24782897002
# RUN  2 , total integrated cost =  173480.2478289698
# RUN  3 , total integrated cost =  173480.24782896976
# RUN  4 , total integrated cost =  173480.24782896976
# Control only changes marginally.
# RUN  4 , total integrated cost =  173480.24782896976
# Improved over  4  iterations in  0.2795963889802806  seconds by  2.7000623958883807e-13  percent.
# converged for  61
# -------  62 0.4250000000000001 0.6500000000000004
# -------  63 0.4500000000000001 0.6500000000000004
# -------  64 0.47500000000000014 0.6500000000000004
# weight =  4791.758280162423
# set cost params:  1.0 4791.758280162423 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  77637.81508821252
# Gradient descend method:  None
# RUN  1 , total integrated cost =  77637.81508821252
# Control only changes marginally.
# RUN  1 , total integrated cost =  77637.81508821252
# Improved over  1  iterations in  0.08383264002623037  seconds by  0.0  percent.
# converged for  64
# ------------------------------------------------
# ------------------------- 8
# [[True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, False], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# -------  60 0.5500000000000003 0.6250000000000003
# -------  61 0.5750000000000002 0.6250000000000003
# -------  62 0.4250000000000001 0.6500000000000004
# -------  63 0.4500000000000001 0.6500000000000004
# -------  64 0.47500000000000014 0.6500000000000004
# weight =  4791.758280162424
# set cost params:  1.0 4791.758280162424 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  77637.81508821253
# Gradient descend method:  None
# RUN  1 , total integrated cost =  77637.81508821253
# Control only changes marginally.
# RUN  1 , total integrated cost =  77637.81508821253
# Improved over  1  iterations in  0.1398177109658718  seconds by  0.0  percent.
# converged for  64
# ------------------------------------------------
# ------------------------- 9
# [[True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# full convergence

# %%
if os.path.isfile(final_file) :
    print("file found")
    
    with open(final_file,'rb') as f:
        load_array = pickle.load(f)

    bestControl_0 = load_array[0]
    bestState_0 = load_array[1]
    cost_0 = load_array[2]
    runtime_0 = load_array[3]
    grad_0 = load_array[4]
    phi_0 = load_array[5]
    costnode_0 = load_array[6]
    weights_0 = load_array[7]
# Out:
# file found

# %%
delete = [61, 62, 63, 64]
for i in delete:
    bestControl_0[i] = None

# %%
factor_iteration = 20
conv_0 = [[False]*2] * len(exc)
full_converge = False

for i in range(len(conv_0)):
    if i not in i_range_0:
        conv_0[i] = [True, True]

counter = 0

while full_converge == False:
    print('---------------', counter)
    
    if counter > 20:
        break
    
    print(conv_0[::i_stepsize])
    full_converge = True
    
    for conv in conv_0[::i_stepsize]:
        if not conv[0]:
            full_converge = False
            break
        if not conv[1]:
            full_converge = False
            break
    
    if full_converge:
        print("full convergence")
        break
        
    counter += 1
    
    for i in i_range_0:
        print("------- ", i, exc[i], inh[i])
        
        if conv_0[i] == [True, True]:
            continue
            
        aln.params.ext_exc_current = exc[i] * 5.
        aln.params.ext_inh_current = inh[i] * 5.

    # exc and inh control current 

        setinit(initVars[i], aln)
        aln.params.duration = dur

        if not type(bestControl_0[i]) == type(None):
            control0 = bestControl_0[i][:,:,n_pre-1:-n_post+1]
        else:
            control0 = bestControl_init[i][:,:,n_pre-1:-n_post+1].copy()
            weights_0[i] = weights_init[i]
            cost_0[i] = cost_init[i]

        cgv = None
        max_it = 500 * factor_iteration

        j = 1
        while cost_0[i][-j] == 0.:
            j += 1

        weight_ = (factor_we * weights_0[i][1] * cost_uncontrolled[i] / cost_0[i][-j]
                           + factor_ws * weights_0[i][2] * cost_uncontrolled[i] / cost_0[i][-j]) - 1
        print("weight = ", weight_)
        cost.setParams(1.0, weight_ * factor_we, weight_ * factor_ws)

        weights_0[i] = cost.getParams()

        bestControl_0[i], bestState_0[i], cost_0[i], runtime_0[i], grad_0[i], phi_0[i], costnode_0[i] = aln.A1(
            control0, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cntrl_vars_0,
            prec_variables_ = prec_vars, transition_time_ = trans_time)

        with open(final_file,'wb') as f:
            pickle.dump([bestControl_0, bestState_0, cost_0, runtime_0, grad_0, phi_0,
                     costnode_0, weights_0], f)
            
        if j == cost_0[i].shape[0]-1:
            print("converged for ", i)
            if conv_0[i][0]:
                conv_0[i] = [True, True]
            else:
                conv_0[i] = [True, False]
            continue
    
        print("no convergence")
# Out:
# --------------- 0
# [[True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [False, False], [False, False], [False, False], [False, False], [False, False], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# -------  60 0.5500000000000003 0.6250000000000003
# weight =  62843.167270479855
# set cost params:  1.0 62843.167270479855 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  148382.8900083582
# Gradient descend method:  None
# RUN  1 , total integrated cost =  148382.8900083582
# Control only changes marginally.
# RUN  1 , total integrated cost =  148382.8900083582
# Improved over  1  iterations in  0.25857055402593687  seconds by  0.0  percent.
# no convergence
# -------  61 0.5750000000000002 0.6250000000000003
# weight =  304932.05737397453
# set cost params:  1.0 304932.05737397453 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  173480.24782899648
# Gradient descend method:  None
# RUN  1 , total integrated cost =  170490.55055318953
# RUN  2 , total integrated cost =  168075.552397616
# RUN  3 , total integrated cost =  168075.30339132188
# RUN  4 , total integrated cost =  168075.30273022738
# RUN  5 , total integrated cost =  168075.30268987865
# RUN  6 , total integrated cost =  168075.30268882436
# RUN  7 , total integrated cost =  168075.3026887867
# RUN  8 , total integrated cost =  168075.30268878632
# RUN  9 , total integrated cost =  168075.3026887863
# RUN  10 , total integrated cost =  168075.3026887863
# Control only changes marginally.
# RUN  10 , total integrated cost =  168075.3026887863
# Improved over  10  iterations in  1.4381176910246722  seconds by  3.115596852004714  percent.
# no convergence
# -------  62 0.4250000000000001 0.6500000000000004
# weight =  1158.1953033343043
# set cost params:  1.0 1158.1953033343043 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  34463.25568610056
# Gradient descend method:  None
# RUN  1 , total integrated cost =  34399.17517774959
# RUN  2 , total integrated cost =  34314.691613688825
# RUN  3 , total integrated cost =  34259.73583304412
# RUN  4 , total integrated cost =  34180.4397215259
# RUN  5 , total integrated cost =  34133.35699087558
# RUN  6 , total integrated cost =  34058.94829349471
# RUN  7 , total integrated cost =  34015.05925247791
# RUN  8 , total integrated cost =  33959.92593772095
# RUN  9 , total integrated cost =  33918.65509321565
# RUN  10 , total integrated cost =  33868.24135280064
# RUN  11 , total integrated cost =  33833.086866106474
# RUN  12 , total integrated cost =  33785.862803305616
# RUN  13 , total integrated cost =  33785.862803305594
# RUN  14 , total integrated cost =  33785.862803305594
# Control only changes marginally.
# RUN  14 , total integrated cost =  33785.862803305594
# Improved over  14  iterations in  1.6010385999688879  seconds by  1.9655510464966426  percent.
# no convergence
# -------  63 0.4500000000000001 0.6500000000000004
# weight =  2516.2654928447573
# set cost params:  1.0 2516.2654928447573 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  56094.24419755051
# Gradient descend method:  None
# RUN  1 , total integrated cost =  56000.35717858006
# RUN  2 , total integrated cost =  55879.25228929362
# RUN  3 , total integrated cost =  55798.44230842315
# RUN  4 , total integrated cost =  55689.869591501396
# RUN  5 , total integrated cost =  55616.42348215182
# RUN  6 , total integrated cost =  55507.6175546409
# RUN  7 , total integrated cost =  55441.559122953484
# RUN  8 , total integrated cost =  55352.485342310785
# RUN  9 , total integrated cost =  55291.96858921597
# RUN  10 , total integrated cost =  55210.18015980055
# RUN  11 , total integrated cost =  55150.745057129076
# RUN  12 , total integrated cost =  55081.9890981015
# RUN  13 , total integrated cost =  55081.98909810148
# RUN  14 , total integrated cost =  55081.98909810148
# Control only changes marginally.
# RUN  14 , total integrated cost =  55081.98909810148
# Improved over  14  iterations in  1.7265945349936374  seconds by  1.8045614375052565  percent.
# no convergence
# -------  64 0.47500000000000014 0.6500000000000004
# weight =  4791.758280162423
# set cost params:  1.0 4791.758280162423 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  77637.81508821252
# Gradient descend method:  None
# RUN  1 , total integrated cost =  77391.98059328823
# RUN  2 , total integrated cost =  76988.91058536535
# RUN  3 , total integrated cost =  76792.50190536371
# RUN  4 , total integrated cost =  76501.31202105929
# RUN  5 , total integrated cost =  76350.71901050508
# RUN  6 , total integrated cost =  76136.73917435629
# RUN  7 , total integrated cost =  76136.73917435622
# RUN  8 , total integrated cost =  76136.73917435615
# RUN  9 , total integrated cost =  76136.73917435615
# Control only changes marginally.
# RUN  9 , total integrated cost =  76136.73917435615
# Improved over  9  iterations in  1.217010239022784  seconds by  1.9334340001078658  percent.
# converged for  64
# --------------- 1
# [[True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [False, False], [False, False], [False, False], [False, False], [True, False], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# -------  60 0.5500000000000003 0.6250000000000003
# weight =  62843.16727047984
# set cost params:  1.0 62843.16727047984 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  148382.89000835814
# Gradient descend method:  None
# RUN  1 , total integrated cost =  148382.89000835814
# Control only changes marginally.
# RUN  1 , total integrated cost =  148382.89000835814
# Improved over  1  iterations in  0.2288818479864858  seconds by  0.0  percent.
# converged for  60
# -------  61 0.5750000000000002 0.6250000000000003
# weight =  314738.0575428084
# set cost params:  1.0 314738.0575428084 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  173306.68971978317
# Gradient descend method:  None
# RUN  1 , total integrated cost =  173303.2729023798
# RUN  2 , total integrated cost =  173303.26807899642
# RUN  3 , total integrated cost =  173303.2680267709
# RUN  4 , total integrated cost =  173303.26802677065
# RUN  5 , total integrated cost =  173303.26802677038
# RUN  6 , total integrated cost =  173303.26802677038
# Control only changes marginally.
# RUN  6 , total integrated cost =  173303.26802677038
# Improved over  6  iterations in  1.2012595520354807  seconds by  0.001974357145897443  percent.
# no convergence
# -------  62 0.4250000000000001 0.6500000000000004
# weight =  1181.4367002709316
# set cost params:  1.0 1181.4367002709316 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  34462.45328668071
# Gradient descend method:  None
# RUN  1 , total integrated cost =  34462.453286680706
# RUN  2 , total integrated cost =  34462.453286680706
# Control only changes marginally.
# RUN  2 , total integrated cost =  34462.453286680706
# Improved over  2  iterations in  0.41044798999791965  seconds by  2.842170943040401e-14  percent.
# no convergence
# -------  63 0.4500000000000001 0.6500000000000004
# weight =  2562.525892542031
# set cost params:  1.0 2562.525892542031 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  56092.79340144396
# Gradient descend method:  None
# RUN  1 , total integrated cost =  56092.79340144385
# RUN  2 , total integrated cost =  56092.79340144384
# RUN  3 , total integrated cost =  56092.79340144384
# Control only changes marginally.
# RUN  3 , total integrated cost =  56092.79340144384
# Improved over  3  iterations in  0.5848852740018629  seconds by  2.1316282072803006e-13  percent.
# no convergence
# -------  64 0.47500000000000014 0.6500000000000004
# weight =  4886.250033989867
# set cost params:  1.0 4886.250033989867 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  77632.20434013294
# Gradient descend method:  None
# RUN  1 , total integrated cost =  77632.18543379994
# RUN  2 , total integrated cost =  77632.18543379978
# RUN  3 , total integrated cost =  77632.18543379974
# RUN  4 , total integrated cost =  77632.18543379974
# Control only changes marginally.
# RUN  4 , total integrated cost =  77632.18543379974
# Improved over  4  iterations in  0.7324365850072354  seconds by  2.4353724541015254e-05  percent.
# no convergence
# --------------- 2
# [[True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, False], [False, False], [False, False], [False, False], [True, False], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# -------  60 0.5500000000000003 0.6250000000000003
# weight =  62843.16727047985
# set cost params:  1.0 62843.16727047985 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  148382.8900083582
# Gradient descend method:  None
# RUN  1 , total integrated cost =  148382.8900083582
# Control only changes marginally.
# RUN  1 , total integrated cost =  148382.8900083582
# Improved over  1  iterations in  0.23695572197902948  seconds by  0.0  percent.
# converged for  60
# -------  61 0.5750000000000002 0.6250000000000003
# weight =  315059.5058084193
# set cost params:  1.0 315059.5058084193 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  173474.50750447367
# Gradient descend method:  None
# RUN  1 , total integrated cost =  173474.50562774637
# RUN  2 , total integrated cost =  173474.5056233603
# RUN  3 , total integrated cost =  173474.50562334893
# RUN  4 , total integrated cost =  173474.50562334873
# RUN  5 , total integrated cost =  173474.50562334873
# Control only changes marginally.
# RUN  5 , total integrated cost =  173474.50562334873
# Improved over  5  iterations in  1.4745314550236799  seconds by  1.0843811963923145e-06  percent.
# no convergence
# -------  62 0.4250000000000001 0.6500000000000004
# weight =  1181.484298665936
# set cost params:  1.0 1181.484298665936 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  34463.83894440056
# Gradient descend method:  None
# RUN  1 , total integrated cost =  34463.83894440051
# RUN  2 , total integrated cost =  34463.83894440051
# Control only changes marginally.
# RUN  2 , total integrated cost =  34463.83894440051
# Improved over  2  iterations in  0.7231961420038715  seconds by  1.4210854715202004e-13  percent.
# no convergence
# -------  63 0.4500000000000001 0.6500000000000004
# weight =  2562.610581150514
# set cost params:  1.0 2562.610581150514 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  56094.64387421234
# Gradient descend method:  None
# RUN  1 , total integrated cost =  56094.64387421226
# RUN  2 , total integrated cost =  56094.64387421226
# Control only changes marginally.
# RUN  2 , total integrated cost =  56094.64387421226
# Improved over  2  iterations in  0.5007023899815977  seconds by  1.4210854715202004e-13  percent.
# no convergence
# -------  64 0.47500000000000014 0.6500000000000004
# weight =  4886.6241638486645
# set cost params:  1.0 4886.6241638486645 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  77638.10626527898
# Gradient descend method:  None
# RUN  1 , total integrated cost =  77638.10626527898
# Control only changes marginally.
# RUN  1 , total integrated cost =  77638.10626527898
# Improved over  1  iterations in  0.22707708703819662  seconds by  0.0  percent.
# no convergence
# --------------- 3
# [[True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [False, False], [False, False], [False, False], [True, False], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# -------  60 0.5500000000000003 0.6250000000000003
# -------  61 0.5750000000000002 0.6250000000000003
# weight =  315069.96788675775
# set cost params:  1.0 315069.96788675775 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  173480.07868946381
# Gradient descend method:  None
# RUN  1 , total integrated cost =  173480.0786832295
# RUN  2 , total integrated cost =  173480.0786832292
# RUN  3 , total integrated cost =  173480.07868322896
# RUN  4 , total integrated cost =  173480.07868322896
# Control only changes marginally.
# RUN  4 , total integrated cost =  173480.07868322896
# Improved over  4  iterations in  0.7582990560331382  seconds by  3.5939962117481628e-09  percent.
# no convergence
# -------  62 0.4250000000000001 0.6500000000000004
# weight =  1181.4843942298103
# set cost params:  1.0 1181.4843942298103 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  34463.84172640245
# Gradient descend method:  None
# RUN  1 , total integrated cost =  34463.84172640243
# RUN  2 , total integrated cost =  34463.84172640243
# Control only changes marginally.
# RUN  2 , total integrated cost =  34463.84172640243
# Improved over  2  iterations in  0.41230349900433794  seconds by  4.263256414560601e-14  percent.
# no convergence
# -------  63 0.4500000000000001 0.6500000000000004
# weight =  2562.6107333905366
# set cost params:  1.0 2562.6107333905366 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  56094.64720070489
# Gradient descend method:  None
# RUN  1 , total integrated cost =  56094.64720070478
# RUN  2 , total integrated cost =  56094.64720070474
# RUN  3 , total integrated cost =  56094.64720070474
# Control only changes marginally.
# RUN  3 , total integrated cost =  56094.64720070474
# Improved over  3  iterations in  0.6930673780152574  seconds by  2.5579538487363607e-13  percent.
# no convergence
# -------  64 0.47500000000000014 0.6500000000000004
# weight =  4886.625630751738
# set cost params:  1.0 4886.625630751738 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  77638.12947990824
# Gradient descend method:  None
# RUN  1 , total integrated cost =  77638.12947990814
# RUN  2 , total integrated cost =  77638.12947990814
# Control only changes marginally.
# RUN  2 , total integrated cost =  77638.12947990814
# Improved over  2  iterations in  0.5045296340249479  seconds by  1.2789769243681803e-13  percent.
# converged for  64
# --------------- 4
# [[True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [False, False], [False, False], [False, False], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# -------  60 0.5500000000000003 0.6250000000000003
# -------  61 0.5750000000000002 0.6250000000000003
# weight =  315070.3083323286
# set cost params:  1.0 315070.3083323286 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  173480.26003547251
# Gradient descend method:  None
# RUN  1 , total integrated cost =  173480.26003546498
# RUN  2 , total integrated cost =  173480.26003546474
# RUN  3 , total integrated cost =  173480.2600354645
# RUN  4 , total integrated cost =  173480.26003546445
# State only changes marginally.
# RUN  5 , total integrated cost =  173480.26003546445
# Control only changes marginally.
# RUN  5 , total integrated cost =  173480.26003546445
# Improved over  5  iterations in  1.4000963969738223  seconds by  4.646949491871055e-12  percent.
# no convergence
# -------  62 0.4250000000000001 0.6500000000000004
# weight =  1181.4843944216627
# set cost params:  1.0 1181.4843944216627 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  34463.84173198752
# Gradient descend method:  None
# RUN  1 , total integrated cost =  34463.84173198751
# RUN  2 , total integrated cost =  34463.84173198751
# Control only changes marginally.
# RUN  2 , total integrated cost =  34463.84173198751
# Improved over  2  iterations in  0.4751324460376054  seconds by  4.263256414560601e-14  percent.
# no convergence
# -------  63 0.4500000000000001 0.6500000000000004
# weight =  2562.6107336642
# set cost params:  1.0 2562.6107336642 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  56094.64720668443
# Gradient descend method:  None
# RUN  1 , total integrated cost =  56094.64720668443
# Control only changes marginally.
# RUN  1 , total integrated cost =  56094.64720668443
# Improved over  1  iterations in  0.20359607599675655  seconds by  0.0  percent.
# no convergence
# -------  64 0.47500000000000014 0.6500000000000004
# --------------- 5
# [[True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [False, False], [False, False], [False, False], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# -------  60 0.5500000000000003 0.6250000000000003
# -------  61 0.5750000000000002 0.6250000000000003
# weight =  315070.3194107625
# set cost params:  1.0 315070.3194107625 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  173480.26593684472
# Gradient descend method:  None
# RUN  1 , total integrated cost =  173480.2659368447
# RUN  2 , total integrated cost =  173480.26593684466
# RUN  3 , total integrated cost =  173480.26593684466
# Control only changes marginally.
# RUN  3 , total integrated cost =  173480.26593684466
# Improved over  3  iterations in  0.7264110430260189  seconds by  2.842170943040401e-14  percent.
# no convergence
# -------  62 0.4250000000000001 0.6500000000000004
# weight =  1181.4843944220488
# set cost params:  1.0 1181.4843944220488 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  34463.841731998764
# Gradient descend method:  None
# RUN  1 , total integrated cost =  34463.84173199876
# RUN  2 , total integrated cost =  34463.84173199876
# Control only changes marginally.
# RUN  2 , total integrated cost =  34463.84173199876
# Improved over  2  iterations in  0.5426805680035613  seconds by  2.842170943040401e-14  percent.
# no convergence
# -------  63 0.4500000000000001 0.6500000000000004
# weight =  2562.6107336646887
# set cost params:  1.0 2562.6107336646887 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  56094.64720669515
# Gradient descend method:  None
# RUN  1 , total integrated cost =  56094.64720669509
# RUN  2 , total integrated cost =  56094.64720669509
# Control only changes marginally.
# RUN  2 , total integrated cost =  56094.64720669509
# Improved over  2  iterations in  0.5295334969996475  seconds by  9.947598300641403e-14  percent.
# converged for  63
# -------  64 0.47500000000000014 0.6500000000000004
# --------------- 6
# [[True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [False, False], [False, False], [True, False], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# -------  60 0.5500000000000003 0.6250000000000003
# -------  61 0.5750000000000002 0.6250000000000003
# weight =  315070.31977126526
# set cost params:  1.0 315070.31977126526 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  173480.2661288813
# Gradient descend method:  None
# RUN  1 , total integrated cost =  173480.2661288813
# Control only changes marginally.
# RUN  1 , total integrated cost =  173480.2661288813
# Improved over  1  iterations in  0.28157094796188176  seconds by  0.0  percent.
# no convergence
# -------  62 0.4250000000000001 0.6500000000000004
# weight =  1181.484394422049
# set cost params:  1.0 1181.484394422049 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  34463.841731998764
# Gradient descend method:  None
# RUN  1 , total integrated cost =  34463.841731998764
# Control only changes marginally.
# RUN  1 , total integrated cost =  34463.841731998764
# Improved over  1  iterations in  0.2789134579943493  seconds by  0.0  percent.
# no convergence
# -------  63 0.4500000000000001 0.6500000000000004
# weight =  2562.610733664691
# set cost params:  1.0 2562.610733664691 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  56094.64720669515
# Gradient descend method:  None
# RUN  1 , total integrated cost =  56094.64720669514
# RUN  2 , total integrated cost =  56094.64720669514
# Control only changes marginally.
# RUN  2 , total integrated cost =  56094.64720669514
# Improved over  2  iterations in  0.4466269099502824  seconds by  1.4210854715202004e-14  percent.
# no convergence
# -------  64 0.47500000000000014 0.6500000000000004
# --------------- 7
# [[True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [False, False], [False, False], [True, False], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# -------  60 0.5500000000000003 0.6250000000000003
# -------  61 0.5750000000000002 0.6250000000000003
# weight =  315070.3197829961
# set cost params:  1.0 315070.3197829961 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  173480.26613513
# Gradient descend method:  None
# RUN  1 , total integrated cost =  173480.26613513
# Control only changes marginally.
# RUN  1 , total integrated cost =  173480.26613513
# Improved over  1  iterations in  0.23694229195825756  seconds by  0.0  percent.
# converged for  61
# -------  62 0.4250000000000001 0.6500000000000004
# weight =  1181.484394422049
# set cost params:  1.0 1181.484394422049 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  34463.841731998764
# Gradient descend method:  None
# RUN  1 , total integrated cost =  34463.841731998764
# Control only changes marginally.
# RUN  1 , total integrated cost =  34463.841731998764
# Improved over  1  iterations in  0.22084298799745739  seconds by  0.0  percent.
# converged for  62
# -------  63 0.4500000000000001 0.6500000000000004
# weight =  2562.6107336646905
# set cost params:  1.0 2562.6107336646905 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  56094.64720669514
# Gradient descend method:  None
# RUN  1 , total integrated cost =  56094.64720669514
# Control only changes marginally.
# RUN  1 , total integrated cost =  56094.64720669514
# Improved over  1  iterations in  0.22651089302962646  seconds by  0.0  percent.
# no convergence
# -------  64 0.47500000000000014 0.6500000000000004
# --------------- 8
# [[True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, False], [True, False], [True, False], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# -------  60 0.5500000000000003 0.6250000000000003
# -------  61 0.5750000000000002 0.6250000000000003
# weight =  315070.3197833782
# set cost params:  1.0 315070.3197833782 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  173480.26613533363
# Gradient descend method:  None
# RUN  1 , total integrated cost =  173480.26613533363
# Control only changes marginally.
# RUN  1 , total integrated cost =  173480.26613533363
# Improved over  1  iterations in  0.28099479398224503  seconds by  0.0  percent.
# converged for  61
# -------  62 0.4250000000000001 0.6500000000000004
# weight =  1181.484394422049
# set cost params:  1.0 1181.484394422049 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  34463.841731998764
# Gradient descend method:  None
# RUN  1 , total integrated cost =  34463.841731998764
# Control only changes marginally.
# RUN  1 , total integrated cost =  34463.841731998764
# Improved over  1  iterations in  0.20904885203344747  seconds by  0.0  percent.
# converged for  62
# -------  63 0.4500000000000001 0.6500000000000004
# weight =  2562.61073366469
# set cost params:  1.0 2562.61073366469 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  56094.64720669513
# Gradient descend method:  None
# RUN  1 , total integrated cost =  56094.64720669513
# Control only changes marginally.
# RUN  1 , total integrated cost =  56094.64720669513
# Improved over  1  iterations in  0.2509692049934529  seconds by  0.0  percent.
# converged for  63
# -------  64 0.47500000000000014 0.6500000000000004
# --------------- 9
# [[True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# full convergence

# %%
"""
for i in i_range_0:
    
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.

    plotFunc.plot_control_current(aln, [bestControl_init[i], bestControl_0[i]],
        [costnode_init[i], costnode_0[i]], [weights_init[i], weights_0[i]], dur,
        dur_pre, dur_post, initVars[i], target[i], '', filename_ = '', transition_time_ = trans_time,
        labels_ = ["init", "sparse control" + str(i)], print_cost_ = False)
"""

# %%
if os.path.isfile(final_file_1) :
    print("file found")
    
    with open(final_file_1,'rb') as f:
        load_array = pickle.load(f)

    bestControl_1 = load_array[0]
    bestState_1 = load_array[1]
    cost_1 = load_array[2]
    runtime_1 = load_array[3]
    grad_1 = load_array[4]
    phi_1 = load_array[5]
    costnode_1 = load_array[6]
    weights_1 = load_array[7]
# Out:
# file found

# %%
factor_iteration = 20
conv_1 = [[False]*2] * len(exc)
full_converge = False

for i in range(len(conv_1)):
    if i not in i_range_1:
        conv_1[i] = [True, True]
        
counter = 0

while full_converge == False:
    
    print('---------------', counter)
    if counter > 20:
        break
    
    print(conv_1[::i_stepsize])
    full_converge = True
    
    for conv in conv_1[::i_stepsize]:
        if not conv[0]:
            full_converge = False
            break
        if not conv[1]:
            full_converge = False
            break
    
    if full_converge:
        print("full convergence")
        break

    for i in i_range_1:        

        print("------- ", i, exc[i], inh[i])
        
        if conv_1[i] == [True, True]:
            continue
            
        aln.params.ext_exc_current = exc[i] * 5.
        aln.params.ext_inh_current = inh[i] * 5.
        
        if not type(bestControl_1[i]) == type(None):
            control0 = bestControl_1[i][:,:,n_pre-1:-n_post+1].copy()
        else:
            control0 = bestControl_0[i][:,:,n_pre-1:-n_post+1].copy()
            cost_1[i] = cost_0[i]
        
        cost.setParams(1.0, 1. * factor_we, 1. * factor_ws)

        setinit(initVars[i], aln)

        # "HS", "FR", "PR", "HZ"
        cgv = None
        max_it = int( 500 * factor_iteration )

        weights_1[i] = cost.getParams()

        bestControl_1[i], bestState_1[i], cost_1[i], runtime_1[i], grad_1[i], phi_1[i], costnode_1[i] = aln.A1(
            control0, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cntrl_vars_init,
            prec_variables_ = prec_vars, transition_time_ = trans_time)
        
        with open(final_file_1,'wb') as f:
            pickle.dump([bestControl_1, bestState_1, cost_1, runtime_1, grad_1, phi_1,
                 costnode_1, weights_1], f)
            
        j = 1
        while cost_1[i][-j] == 0.:
            j += 1
            
        if j == cost_1[i].shape[0]-1:
            print("converged for ", i)
            if conv_1[i][0]:
                conv_1[i] = [True, True]
            else:
                conv_1[i] = [True, False]
            continue
    
        print("no convergence")
        
    counter += 1
# Out:
# --------------- 0
# [[True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [False, False], [False, False], [False, False], [False, False], [False, False], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# -------  60 0.5500000000000003 0.6250000000000003
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.4228345093979766
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.42264385184191
# RUN  2 , total integrated cost =  2.4226429250451877
# RUN  3 , total integrated cost =  2.4226429240285094
# RUN  4 , total integrated cost =  2.4226429240283114
# RUN  5 , total integrated cost =  2.422642924028309
# RUN  6 , total integrated cost =  2.4226429240283074
# RUN  7 , total integrated cost =  2.4226429240283074
# Control only changes marginally.
# RUN  7 , total integrated cost =  2.4226429240283074
# Improved over  7  iterations in  0.3209481089725159  seconds by  0.007907488890637637  percent.
# no convergence
# -------  61 0.5750000000000002 0.6250000000000003
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5645.733412041239
# Gradient descend method:  None
# RUN  1 , total integrated cost =  0.7467018858028653
# RUN  2 , total integrated cost =  0.6796399648259835
# RUN  3 , total integrated cost =  0.6738334729804445
# RUN  4 , total integrated cost =  0.6659395176888744
# RUN  5 , total integrated cost =  0.6634741170821759
# RUN  6 , total integrated cost =  0.6464401141701891
# RUN  7 , total integrated cost =  0.6439488128829486
# RUN  8 , total integrated cost =  0.6415428393746764
# RUN  9 , total integrated cost =  0.6413331934668539
# RUN  10 , total integrated cost =  0.6412861309742814
# RUN  11 , total integrated cost =  0.6411136010963074
# RUN  12 , total integrated cost =  0.6392856724755727
# RUN  13 , total integrated cost =  0.6389213726940824
# RUN  14 , total integrated cost =  0.6389087513595911
# RUN  15 , total integrated cost =  0.6389037072329263
# RUN  16 , total integrated cost =  0.6388978154929493
# RUN  17 , total integrated cost =  0.6388762643620619
# RUN  18 , total integrated cost =  0.6369911988866157
# RUN  19 , total integrated cost =  0.6342210946535869
# RUN  20 , total integrated cost =  0.6341905641371737
# RUN  30 , total integrated cost =  0.6341897024579211
# Control only changes marginally.
# RUN  32 , total integrated cost =  0.6341897024579205
# Improved over  32  iterations in  1.0397518789977767  seconds by  99.98876692085557  percent.
# no convergence
# -------  62 0.4250000000000001 0.6500000000000004
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  98.24360479678224
# Gradient descend method:  None
# RUN  1 , total integrated cost =  32.69565620604842
# RUN  2 , total integrated cost =  32.53590535682931
# RUN  3 , total integrated cost =  32.182512941361466
# RUN  4 , total integrated cost =  31.89480964368154
# RUN  5 , total integrated cost =  29.991399726447124
# RUN  6 , total integrated cost =  29.786669382989768
# RUN  7 , total integrated cost =  29.76136408011049
# RUN  8 , total integrated cost =  29.722380831453584
# RUN  9 , total integrated cost =  29.71992985947048
# RUN  10 , total integrated cost =  29.687875277957243
# RUN  11 , total integrated cost =  29.6431469749482
# RUN  12 , total integrated cost =  29.64197675738211
# RUN  13 , total integrated cost =  29.638598712833673
# RUN  14 , total integrated cost =  29.62207340803317
# RUN  15 , total integrated cost =  29.61927813752173
# RUN  16 , total integrated cost =  29.618372420351648
# RUN  17 , total integrated cost =  29.416181598856973
# RUN  18 , total integrated cost =  29.391991977019263
# RUN  19 , total integrated cost =  29.39192440442253
# RUN  20 , total integrated cost =  29.391915729689472
# RUN  30 , total integrated cost =  29.391913248992427
# RUN  40 , total integrated cost =  29.39191324891155
# Control only changes marginally.
# RUN  41 , total integrated cost =  29.39191324891155
# Improved over  41  iterations in  1.4410788230015896  seconds by  70.08261931175166  percent.
# no convergence
# -------  63 0.4500000000000001 0.6500000000000004
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  122.64588333222942
# Gradient descend method:  None
# RUN  1 , total integrated cost =  24.509645146886566
# RUN  2 , total integrated cost =  24.410374762351804
# RUN  3 , total integrated cost =  24.339737850995125
# RUN  4 , total integrated cost =  24.1678110682983
# RUN  5 , total integrated cost =  24.039703631265418
# RUN  6 , total integrated cost =  23.048574864984353
# RUN  7 , total integrated cost =  22.796728228643676
# RUN  8 , total integrated cost =  22.786100050098394
# RUN  9 , total integrated cost =  22.76841063486367
# RUN  10 , total integrated cost =  22.762454450529326
# RUN  11 , total integrated cost =  22.730475017113882
# RUN  12 , total integrated cost =  22.709035563092804
# RUN  13 , total integrated cost =  22.693191698440437
# RUN  14 , total integrated cost =  22.67201536475548
# RUN  15 , total integrated cost =  22.667920216589962
# RUN  16 , total integrated cost =  22.645793654727353
# RUN  17 , total integrated cost =  22.631583496844364
# RUN  18 , total integrated cost =  22.614818492916587
# RUN  19 , total integrated cost =  22.59042457972948
# RUN  20 , total integrated cost =  22.587414340708563
# RUN  30 , total integrated cost =  22.401631945436936
# RUN  40 , total integrated cost =  22.196253079872683
# RUN  50 , total integrated cost =  22.030998770605628
# Control only changes marginally.
# RUN  56 , total integrated cost =  22.030998770560057
# Improved over  56  iterations in  1.375903278007172  seconds by  82.03690317849367  percent.
# no convergence
# -------  64 0.47500000000000014 0.6500000000000004
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  320.14656725814854
# Gradient descend method:  None
# RUN  1 , total integrated cost =  16.909929537628543
# RUN  2 , total integrated cost =  16.686004572632534
# RUN  3 , total integrated cost =  16.36672314376381
# RUN  4 , total integrated cost =  16.29584526681457
# RUN  5 , total integrated cost =  16.294228203006764
# RUN  6 , total integrated cost =  16.28911521596149
# RUN  7 , total integrated cost =  16.267182692154055
# RUN  8 , total integrated cost =  16.26406144040693
# RUN  9 , total integrated cost =  16.263889743999844
# RUN  10 , total integrated cost =  16.263814564771366
# RUN  11 , total integrated cost =  16.263722450420357
# RUN  12 , total integrated cost =  16.26336747858991
# RUN  13 , total integrated cost =  16.22617370812722
# RUN  14 , total integrated cost =  16.191285824456294
# RUN  15 , total integrated cost =  16.190859119500875
# RUN  16 , total integrated cost =  16.190849175147516
# RUN  17 , total integrated cost =  16.190848874827598
# RUN  18 , total integrated cost =  16.190848863618665
# RUN  19 , total integrated cost =  16.19084886332189
# RUN  20 , total integrated cost =  16.190848863308812
# Control only changes marginally.
# RUN  25 , total integrated cost =  16.190848863308275
# Improved over  25  iterations in  0.7249496639706194  seconds by  94.94267609927147  percent.
# no convergence
# --------------- 1
# [[True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [False, False], [False, False], [False, False], [False, False], [False, False], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# -------  60 0.5500000000000003 0.6250000000000003
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.4226429240283074
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.4226429240283074
# Control only changes marginally.
# RUN  1 , total integrated cost =  2.4226429240283074
# Improved over  1  iterations in  0.08382392604835331  seconds by  0.0  percent.
# converged for  60
# -------  61 0.5750000000000002 0.6250000000000003
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  0.6341897024579205
# Gradient descend method:  None
# RUN  1 , total integrated cost =  0.6341897024579205
# Control only changes marginally.
# RUN  1 , total integrated cost =  0.6341897024579205
# Improved over  1  iterations in  0.07685590197797865  seconds by  0.0  percent.
# converged for  61
# -------  62 0.4250000000000001 0.6500000000000004
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  29.39191324891155
# Gradient descend method:  None
# RUN  1 , total integrated cost =  29.39191324891155
# Control only changes marginally.
# RUN  1 , total integrated cost =  29.39191324891155
# Improved over  1  iterations in  0.08248147700214759  seconds by  0.0  percent.
# converged for  62
# -------  63 0.4500000000000001 0.6500000000000004
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22.030998770560057
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22.030998770560057
# Control only changes marginally.
# RUN  1 , total integrated cost =  22.030998770560057
# Improved over  1  iterations in  0.07754319097148255  seconds by  0.0  percent.
# converged for  63
# -------  64 0.47500000000000014 0.6500000000000004
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  16.190848863308275
# Gradient descend method:  None
# RUN  1 , total integrated cost =  16.190848863308275
# Control only changes marginally.
# RUN  1 , total integrated cost =  16.190848863308275
# Improved over  1  iterations in  0.07893152598990127  seconds by  0.0  percent.
# converged for  64
# --------------- 2
# [[True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# -------  60 0.5500000000000003 0.6250000000000003
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2.4226429240283074
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.4226429240283074
# Control only changes marginally.
# RUN  1 , total integrated cost =  2.4226429240283074
# Improved over  1  iterations in  0.0736935639870353  seconds by  0.0  percent.
# converged for  60
# -------  61 0.5750000000000002 0.6250000000000003
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  0.6341897024579205
# Gradient descend method:  None
# RUN  1 , total integrated cost =  0.6341897024579205
# Control only changes marginally.
# RUN  1 , total integrated cost =  0.6341897024579205
# Improved over  1  iterations in  0.07355367299169302  seconds by  0.0  percent.
# converged for  61
# -------  62 0.4250000000000001 0.6500000000000004
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  29.39191324891155
# Gradient descend method:  None
# RUN  1 , total integrated cost =  29.39191324891155
# Control only changes marginally.
# RUN  1 , total integrated cost =  29.39191324891155
# Improved over  1  iterations in  0.07856526499381289  seconds by  0.0  percent.
# converged for  62
# -------  63 0.4500000000000001 0.6500000000000004
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22.030998770560057
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22.030998770560057
# Control only changes marginally.
# RUN  1 , total integrated cost =  22.030998770560057
# Improved over  1  iterations in  0.07084397203288972  seconds by  0.0  percent.
# converged for  63
# -------  64 0.47500000000000014 0.6500000000000004
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  16.190848863308275
# Gradient descend method:  None
# RUN  1 , total integrated cost =  16.190848863308275
# Control only changes marginally.
# RUN  1 , total integrated cost =  16.190848863308275
# Improved over  1  iterations in  0.07953713199822232  seconds by  0.0  percent.
# converged for  64
# --------------- 3
# [[True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# full convergence
