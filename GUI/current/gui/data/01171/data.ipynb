# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import sys
import pickle

path = os.getcwd().split(os.sep + 'GUI')[0]
if path not in sys.path:
    print("not here")
    sys.path.append(path)

from neurolib.models.aln import ALNModel
from neurolib.utils import plotFunctions as plotFunc
from neurolib.utils import costFunctions as cost
import neurolib.dashboard.functions as functions
import neurolib.dashboard.data as data
    
# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2 

#path = os.path.join(os.getcwd(), "plots")
# Out:
# not here

# %%
# read case
print(os.getcwd())
case = os.getcwd().split(os.sep)[-1]
print(case)
# Out:
# /home/lena/Promotion/neurolib/GUI/current/gui/data/01171
# 01171

# %% [markdown]
# ### Bistability

# %%
aln = ALNModel()
N = aln.params.N

data.set_parameters(aln)

state_vars = aln.state_vars
init_vars = aln.init_vars

##############################################################
def setinit(init_vars_, model):
    state_vars = model.state_vars
    init_vars = model.init_vars
    for iv in range(len(init_vars)):
        for sv in range(len(state_vars)):
            if state_vars[sv] in init_vars[iv]:
                #print("set init vars ", )
                if model.params[init_vars[iv]].ndim == 2:
                    model.params[init_vars[iv]][0,:] = init_vars_[sv]
                else:
                    model.params[init_vars[iv]][0] = init_vars_[sv]
                    
##############################################################               
def setmaxmincontrol(max_c_c, min_c_c, max_c_r, min_c_r):
    import numpy as np
    
    max_cntrl = np.zeros(( 6 ))
    min_cntrl = np.zeros(( 6 ))
    
    max_cntrl[0] = max_c_c
    min_cntrl[0] = min_c_c
    max_cntrl[1] = max_c_c
    min_cntrl[1] = min_c_c
    max_cntrl[2] = max_c_r
    min_cntrl[2] = min_c_r
    max_cntrl[3] = max_c_r
    min_cntrl[3] = min_c_r
    max_cntrl[4] = max_c_r
    min_cntrl[4] = min_c_r
    max_cntrl[5] = max_c_r
    min_cntrl[5] = min_c_r
            
    return max_cntrl, min_cntrl

#####################################################
def getclosest(k_, found_solution, exc, inh, already_tried_):
    import numpy as np
    if len(found_solution) == 0:
        print("no solutions found")
        return -1
    
    start_ind = -1
    for j_ in found_solution:
        if j_ not in already_tried_ and j_ != k_:
            start_ind = j_
            break
            
    if start_ind == -1:
        return -1
        
    min_dist = np.sqrt((exc[k_] - exc[start_ind])**2 + (inh[k_] - inh[start_ind])**2)
    min_i = start_ind
        
    print(found_solution, already_tried_)
        
    if len(found_solution) == len(already_tried_):
        print("already tried all options")
        min_i = -1
        return min_i
    
    for i_ in found_solution:
        if i_ not in already_tried_:
            if i_ != k_ and i_ != min_i:
                dist_ = np.sqrt((exc[k_] - exc[i_])**2 + (inh[k_] - inh[i_])**2)
                if dist_ < min_dist:
                    min_dist = dist_
                    min_i = i_
                    
    if min_i == 0 and 0 in already_tried_:
        return -1
    
    return min_i

# %%
##### LOAD BOUNDARIES
data_file = 'bi.pickle'
with open(data_file,'rb') as f:
    load_array= pickle.load(f)
exc = load_array[0]
inh = load_array[1]
print(len(exc))
#plt.scatter(exc, inh)
# Out:
# 147

# %%
bestControl_init = [None] * len(exc)
bestState_init = [None] * len(exc)
cost_init = [None] * len(exc)
runtime_init = [None] * len(exc)
grad_init = [None] * len(exc)
phi_init = [None] * len(exc)
costnode_init = [None] * len(exc)
weights_init = [None] * len(exc)

conv_init = [[False]*2] * len(exc)

# %%
bestControl_0 = [None] * len(exc)
bestState_0 = [None] * len(exc)
cost_0 = [None] * len(exc)
runtime_0 = [None] * len(exc)
grad_0 = [None] * len(exc)
phi_0 = [None] * len(exc)
costnode_0 = [None] * len(exc)
weights_0 = [None] * len(exc)

conv_0 = [[False]*2] * len(exc)

# %%
bestControl_1 = [None] * len(exc)
bestState_1 = [None] * len(exc)
cost_1 = [None] * len(exc)
runtime_1 = [None] * len(exc)
grad_1 = [None] * len(exc)
phi_1 = [None] * len(exc)
costnode_1 = [None] * len(exc)
weights_1 = [None] * len(exc)

conv_1 = [[False]*2] * len(exc)

# %%
initVars = [None] * len(exc)
target = [None] * len(exc)
cost_uncontrolled = [None] * len(exc)

cgv_list = [None, "HS", "FR", "PR", "CD", "LS", "DY", "WYL", "HZ", None]

# %%
dur_pre = 10
dur_post = 10

n_pre = int(np.around(dur_pre/aln.params.dt + 1.,1))
n_post = int(np.around(dur_post/aln.params.dt + 1.,1))

tol = 1e-32
start_step = 10.
c_scheme = np.zeros(( 1,1 ))
c_scheme[0,0] = 1.
u_mat = np.identity(1)
u_scheme = np.array([[1.]])

c_var = [ [0], [1], [0,1]]
p_var = [ [0], [0], [0]]

### CURRENTS
cntrl_vars_0 = [0,1]
prec_vars = [0]

if case[0] == '0':    # low to high
    max_I = [3., -3.]
elif case[0] == '1':
    max_I = [-3., 3.]
    
if case[1] == '0':    # sparsity
    factor_ws = 1.
    factor_we = 0.
elif case[1] == '1':  # energy
    factor_ws = 0.
    factor_we = 1.
    
if case[3] == '0':
    cntrl_vars_init = [0]
elif case[3] == '1':
    cntrl_vars_init = [1]
elif case[3] == '2':
    cntrl_vars_init = [0,1]
elif case[3] == '3':
    cntrl_vars_init = [0]
    conv_init = [[True]*2] * len(exc)
    case_read = case[0] + case[1] + case[2] + str(int(case[3])-3) + '0'
    read_file = os.path.join( os.getcwd()[:-5], case_read, 'control_init_' + case_read + '.pickle')
elif case[3] == '4':
    cntrl_vars_init = [1]
    conv_init = [[True]*2] * len(exc)
    case_read = case[0] + case[1] + case[2] + str(int(case[3])-3) + '0'
    read_file = os.path.join( os.getcwd()[:-5], case_read, 'control_init_' + case_read + '.pickle')
elif case[3] == '5':
    cntrl_vars_init = [0,1]
    conv_init = [[True]*2] * len(exc)
    case_read = case[0] + case[1] + case[2] + str(int(case[3])-3) + '0'
    read_file = os.path.join( os.getcwd()[:-5], case_read, 'control_init_' + case_read + '.pickle')
elif case[3] == '6':
    cntrl_vars_init = [0]
    conv_init = [[True]*2] * len(exc)
    case_read = case[0] + case[1] + case[2] + str(int(case[3])-6) + '0'
    read_file = os.path.join( os.getcwd()[:-5], case_read, 'control_init_' + case_read + '.pickle')
elif case[3] == '7':
    cntrl_vars_init = [1]
    conv_init = [[True]*2] * len(exc)
    case_read = case[0] + case[1] + case[2] + str(int(case[3])-6) + '0'
    read_file = os.path.join( os.getcwd()[:-5], case_read, 'control_init_' + case_read + '.pickle')
elif case[3] == '8':
    cntrl_vars_init = [0,1]
    conv_init = [[True]*2] * len(exc)
    case_read = case[0] + case[1] + case[2] + str(int(case[3])-6) + '0'
    read_file = os.path.join( os.getcwd()[:-5], case_read, 'control_init_' + case_read + '.pickle')
    
if case[4] == '0':
    dur = 100
    trans_time = 0.8
elif case[4] == '1':
    dur = 400
    trans_time = 0.95
    
maxC = [5., -5., 0.18, 0.]

n_dur = int(np.around(dur/aln.params.dt + 1.,1))
max_cntrl, min_cntrl = setmaxmincontrol(maxC[0], maxC[1], maxC[2], maxC[3])

# %%
init_file = 'control_init_' + case + '.pickle'
final_file = 'control_' + case + '.pickle'
case_1 = case[0] + case[1] + '0' + case[3] + case[4]
final_file_1 = 'control_' + case_1 + '.pickle'

# %%
if os.path.isfile(init_file) :
    print("file found")
    
    with open(init_file,'rb') as f:
        load_array = pickle.load(f)

    bestControl_init = load_array[0]
    bestState_init = load_array[1]
    cost_init = load_array[2]
    runtime_init = load_array[3]
    grad_init = load_array[4]
    phi_init = load_array[5]
    costnode_init = load_array[6]
    weights_init = load_array[7]
# Out:
# file found

# %%
# get initial parameters and target states

i_stepsize = 1
limit = 57
start_index = 54
i_range = range(start_index, limit,i_stepsize)
i_range_0 = range(start_index, limit,i_stepsize)
i_range_1 = range(start_index, limit,i_stepsize)

i_range = [38]
i_range_0 = i_range
i_range_1 = i_range

data.set_parameters(aln)

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    aln.params.duration = 3000.
    
    control0 = aln.getZeroControl()
    control0 = functions.step_control(aln, maxI_ = max_I[0])

    aln.run(control=control0)
    
    target_rates = np.zeros((2))
    target_rates[0] = aln.rates_exc[0,-1] 
    target_rates[1] = aln.rates_inh[0,-1]

    control0 = functions.step_control(aln, maxI_ = max_I[1])
    aln.run(control=control0)

    init_state_vars = np.zeros(( len(state_vars) ))
    for j in range(len(state_vars)):
        if aln.state[state_vars[j]].size == 1:
            init_state_vars[j] = aln.state[state_vars[j]][0]
        else:
            init_state_vars[j] = aln.state[state_vars[j]][0,-1]

    initVars[i] = init_state_vars
    
    aln.params.duration = dur

    target[i] = aln.getZeroTarget()
    target[i][:,0,:] = target_rates[0]
    target[i][:,1,:] = target_rates[1]
# Out:
# -------  38 0.47500000000000014 0.5500000000000003

# %%
# get uncontrolled cost

data.set_parameters(aln)

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    aln.params.duration = dur
        
    cost.setParams(1.0, 0.0, 0.0)

##### zero control as input for uncontrolled cost
    setinit(initVars[i], aln)
    control0 = aln.getZeroControl()

    # "HS", "FR", "PR", "HZ"
    cgv = None
    max_it = 0

    bestControl_init_, bestState_init_, cost_init_, runtime_init_, grad_init_, phi_init_, costnode_init_ = aln.A1(
        control0, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cntrl_vars_init,
        prec_variables_ = prec_vars, transition_time_ = trans_time)
    
    cost_uncontrolled[i] = cost_init_[0]
# Out:
# -------  38 0.47500000000000014 0.5500000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  325347.54927894264
# Gradient descend method:  None
# RUN  0 , total integrated cost =  325347.54927894264
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.

# %%
factor_iteration = 20.
aln.params.duration = dur

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
        
    ##### zero control as input for uncontrolled cost
    setinit(initVars[i], aln)
    
    if conv_init[i] == [True, True]:
    
        with open(read_file,'rb') as f:
            load_array = pickle.load(f)

        bestControl_read = load_array[0]

        bestControl_init[i] = np.zeros(( 1, 6, n_dur + n_pre + n_post -2 ))
        bestControl_init[i][:,:,n_pre-1+1000:n_pre-1+2000] = bestControl_read[i][:,:,n_pre-1:n_pre-1+1000].copy()
        weights_init = load_array[7]
        
        control0 = bestControl_init[i][:,:,n_pre-1:-n_post+1]   
        cost.setParams(weights_init[i][0], weights_init[i][1], weights_init[i][2])

        
        bestControl_init[i], bestState_init[i], cost_init[i], runtime_init[i], grad_init[i], phi_init[i], costnode_init[i] = aln.A1(
        control0, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = 0, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cntrl_vars_init,
        prec_variables_ = prec_vars, transition_time_ = trans_time)
        
        continue
    
    
    
    if not type(bestControl_init[i]) == type(None):
        continue
        
    control0 = aln.getZeroControl()

    ##### initial guess
    weight_ = 10
    cost.setParams(1.0, weight_ * factor_we, weight_ * factor_ws)

    setinit(initVars[i], aln)

    # "HS", "FR", "PR", "HZ"
    cgv = None
    max_it = int(100 * factor_iteration)

    weights_init[i] = cost.getParams()

    bestControl_init[i], bestState_init[i], cost_init[i], runtime_init[i], grad_init[i], phi_init[i], costnode_init[i] = aln.A1(
        control0, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cntrl_vars_init,
        prec_variables_ = prec_vars, transition_time_ = trans_time)
    
    j = 1
    while cost_init[i][-j] == 0.:
        j += 1
    
    weight_ = 10 * cost_uncontrolled[i] / cost_init[i][-j]
    print("weight = ", weight_)
    cost.setParams(1.0, weight_ * factor_we, weight_ * factor_ws)

    setinit(initVars[i], aln)
    control0 = bestControl_init[i][:,:,n_pre-1:-n_post+1]

    # "HS", "FR", "PR", "HZ"
    cgv = None
    max_it = int(500 * factor_iteration)

    weights_init[i] = cost.getParams()
    
    bestControl_init[i], bestState_init[i], cost_init[i], runtime_init[i], grad_init[i], phi_init[i], costnode_init[i] = aln.A1(
        control0, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cntrl_vars_init,
        prec_variables_ = prec_vars, transition_time_ = trans_time)
        
    with open(init_file,'wb') as f:
        pickle.dump([bestControl_init, bestState_init, cost_init, runtime_init, grad_init, phi_init,
                 costnode_init, weights_init], f)

with open(init_file,'wb') as f:
        pickle.dump([bestControl_init, bestState_init, cost_init, runtime_init, grad_init, phi_init,
                 costnode_init, weights_init], f)
# Out:
# -------  60 0.5500000000000003 0.6250000000000003
# set cost params:  1.0 12804.012033409164 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  142856.55108127513
# Gradient descend method:  None
# RUN  0 , total integrated cost =  142856.55108127513
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  61 0.5750000000000002 0.6250000000000003
# set cost params:  1.0 17410.59705860458 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  153075.7576347865
# Gradient descend method:  None
# RUN  0 , total integrated cost =  153075.7576347865
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  62 0.4250000000000001 0.6500000000000004
# set cost params:  1.0 698.6321632513159 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  33941.66574782833
# Gradient descend method:  None
# RUN  0 , total integrated cost =  33941.66574782833
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  63 0.4500000000000001 0.6500000000000004
# set cost params:  1.0 1147.5663777139189 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  53686.93778000558
# Gradient descend method:  None
# RUN  0 , total integrated cost =  53686.93778000558
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  64 0.47500000000000014 0.6500000000000004
# set cost params:  1.0 2067.5918177159547 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  74532.33769550553
# Gradient descend method:  None
# RUN  0 , total integrated cost =  74532.33769550553
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.

# %%
#plot initial guesses
for i in i_range:
    print("---------", i)
        
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.

    plotFunc.plot_control_current(aln, [bestControl_init[i]],
        [costnode_init[i]], [weights_init[i]], dur,
        dur_pre, dur_post, initVars[i], target[i], '', filename_ = '', transition_time_ = trans_time,
        labels_ = ["init", "sparse control" + str(i)], print_cost_ = False)
    plt.show()
# Out:
# --------- 60
# --------- 61
# --------- 62
# --------- 63
# --------- 64

# %%
found_solution = []
no_solution = []
factor_iteration = 20.

for i in i_range:
    print("------- ", i, exc[i], inh[i])    


    if np.abs(np.mean(bestState_init[i][0,0,-300:]) - target[i][0,0,-1]) < 0.1 * np.abs(
        np.mean(bestState_init[i][0,0,-100:]) - bestState_init[i][0,0,0]) and np.abs(
        np.mean(bestState_init[i][0,1,-300:]) - target[i][0,1,-1]) < 0.1 * np.abs(
        np.mean(bestState_init[i][0,1,-100:]) - bestState_init[i][0,1,0]) and np.amax(
        bestState_init[i][0,0,:]) < target[i][0,0,-1] + 5. and np.amax(
        bestState_init[i][0,1,:]) < target[i][0,1,-1] + 5.:
        # and np.amin(bestState_init[i][0,0,:]) > bestState_init[i][0,0,0] - 1.
        #and np.amin(bestState_init[i][0,1,:]) > bestState_init[i][0,1,0] - 1.:
        if i not in found_solution:
            print("found solution for ", i)
            found_solution.append(i)
        if i in no_solution:
            no_solution.pop(no_solution.index(i))
# Out:
# -------  60 0.5500000000000003 0.6250000000000003
# found solution for  60
# -------  61 0.5750000000000002 0.6250000000000003
# found solution for  61
# -------  62 0.4250000000000001 0.6500000000000004
# found solution for  62
# -------  63 0.4500000000000001 0.6500000000000004
# found solution for  63
# -------  64 0.47500000000000014 0.6500000000000004
# found solution for  64

# %%
if os.path.isfile(final_file) :
    print("file found")
    
    with open(final_file,'rb') as f:
        load_array = pickle.load(f)

    bestControl_0 = load_array[0]
    bestState_0 = load_array[1]
    cost_0 = load_array[2]
    runtime_0 = load_array[3]
    grad_0 = load_array[4]
    phi_0 = load_array[5]
    costnode_0 = load_array[6]
    weights_0 = load_array[7]
# Out:
# file found

# %%
factor_iteration = 6
conv_0 = [[False]*2] * len(exc)
full_converge = False

for i in range(len(conv_0)):
    if i not in i_range_0:
        conv_0[i] = [True, True]

counter = 0

while full_converge == False:
    print('---------------', counter)
    
    if counter > 6:
        break
    
    print(conv_0[start_index:limit:i_stepsize])
    full_converge = True
    
    for conv in conv_0[start_index:limit:i_stepsize]:
        if not conv[0]:
            full_converge = False
            break
        if not conv[1]:
            full_converge = False
            break
    
    if full_converge:
        print("full convergence")
        break
        
    counter += 1
    
    for i in i_range_0:
        print("------- ", i, exc[i], inh[i])
            
        aln.params.ext_exc_current = exc[i] * 5.
        aln.params.ext_inh_current = inh[i] * 5.

    # exc and inh control current 

        setinit(initVars[i], aln)
        aln.params.duration = dur

        if not type(bestControl_0[i]) == type(None):
            control0 = bestControl_0[i][:,:,n_pre-1:-n_post+1]
        else:
            control0 = bestControl_init[i][:,:,n_pre-1:-n_post+1].copy()
            weights_0[i] = weights_init[i]
            cost_0[i] = cost_init[i]

        cgv = None
        max_it = 500 * factor_iteration

        j = 1
        while cost_0[i][-j] == 0.:
            j += 1

        weight_ = (factor_we * weights_0[i][1] * cost_uncontrolled[i] / cost_0[i][-j]
                           + factor_ws * weights_0[i][2] * cost_uncontrolled[i] / cost_0[i][-j]) - 1
        print("weight = ", weight_)
        cost.setParams(1.0, weight_ * factor_we, weight_ * factor_ws)

        weights_0[i] = cost.getParams()

        bestControl_0[i], bestState_0[i], cost_0[i], runtime_0[i], grad_0[i], phi_0[i], costnode_0[i] = aln.A1(
            control0, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cntrl_vars_0,
            prec_variables_ = prec_vars, transition_time_ = trans_time)

        with open(final_file,'wb') as f:
            pickle.dump([bestControl_0, bestState_0, cost_0, runtime_0, grad_0, phi_0,
                     costnode_0, weights_0], f)
            
        if j == cost_0[i].shape[0]-1:
            print("converged for ", i)
            if conv_0[i][0]:
                conv_0[i] = [True, True]
            else:
                conv_0[i] = [True, False]
            continue
    
        print("no convergence")
# Out:
# --------------- 0
# [[False, False], [False, False], [False, False], [False, False], [False, False]]
# -------  60 0.5500000000000003 0.6250000000000003
# weight =  292884.1219361554
# set cost params:  1.0 292884.1219361554 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  593094.2686231141
# Gradient descend method:  None
# RUN  1 , total integrated cost =  593094.2686231133
# RUN  2 , total integrated cost =  593094.2686231128
# RUN  3 , total integrated cost =  593094.2686231127
# RUN  4 , total integrated cost =  593094.2686231127
# Control only changes marginally.
# RUN  4 , total integrated cost =  593094.2686231127
# Improved over  4  iterations in  2.9691794420359656  seconds by  2.2737367544323206e-13  percent.
# converged for  60
# -------  61 0.5750000000000002 0.6250000000000003
# weight =  78865.61098905941
# set cost params:  1.0 78865.61098905941 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  693394.5523432953
# Gradient descend method:  None
# RUN  1 , total integrated cost =  338940.213766951
# RUN  2 , total integrated cost =  332202.61316054175
# RUN  3 , total integrated cost =  331934.3969263541
# RUN  4 , total integrated cost =  231932.78132544435
# RUN  5 , total integrated cost =  44344.596256487246
# RUN  6 , total integrated cost =  31941.70309617258
# RUN  7 , total integrated cost =  31914.320106980496
# RUN  8 , total integrated cost =  31914.16739049206
# RUN  9 , total integrated cost =  31914.167087493024
# RUN  10 , total integrated cost =  31914.167087492886
# RUN  11 , total integrated cost =  31914.16708749284
# RUN  12 , total integrated cost =  31914.16708749283
# RUN  13 , total integrated cost =  31914.167087492824
# RUN  14 , total integrated cost =  31914.167087492824
# Control only changes marginally.
# RUN  14 , total integrated cost =  31914.167087492824
# Improved over  14  iterations in  4.379923515953124  seconds by  95.39740152563351  percent.
# no convergence
# -------  62 0.4250000000000001 0.6500000000000004
# weight =  2836.794957715703
# set cost params:  1.0 2836.794957715703 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  137820.0880443506
# Gradient descend method:  None
# RUN  1 , total integrated cost =  130826.87005870267
# RUN  2 , total integrated cost =  130760.51544897437
# RUN  3 , total integrated cost =  130757.57667387476
# RUN  4 , total integrated cost =  130757.39549056142
# RUN  5 , total integrated cost =  130755.06205636193
# RUN  6 , total integrated cost =  130754.97733724413
# RUN  7 , total integrated cost =  130752.89511099974
# RUN  8 , total integrated cost =  130752.7751496341
# RUN  9 , total integrated cost =  130750.88345513123
# RUN  10 , total integrated cost =  130750.75652817592
# RUN  11 , total integrated cost =  130748.88169696588
# RUN  12 , total integrated cost =  130536.0175226957
# RUN  13 , total integrated cost =  121529.85886553023
# RUN  14 , total integrated cost =  121222.34174701583
# RUN  15 , total integrated cost =  121215.25114813106
# RUN  16 , total integrated cost =  121214.90118517556
# RUN  17 , total integrated cost =  121214.88219290052
# RUN  18 , total integrated cost =  121214.87256307273
# RUN  19 , total integrated cost =  121214.8654748929
# RUN  20 , total integrated cost =  121214.85668828664
# RUN  30 , total integrated cost =  121214.7770341043
# RUN  40 , total integrated cost =  121214.69791188206
# RUN  50 , total integrated cost =  121214.61533629755
# RUN  60 , total integrated cost =  121214.53710313534
# RUN  70 , total integrated cost =  121214.45936837509
# RUN  80 , total integrated cost =  121214.3790706123
# RUN  90 , total integrated cost =  121214.29896153371
# RUN  100 , total integrated cost =  121214.22132326422
# RUN  110 , total integrated cost =  121214.1440829727
# RUN  120 , total integrated cost =  121214.0645568799
# RUN  130 , total integrated cost =  121213.98770372201
# RUN  140 , total integrated cost =  121213.9084384192
# RUN  150 , total integrated cost =  121213.82930150253
# RUN  160 , total integrated cost =  121213.75224569245
# RUN  170 , total integrated cost =  121213.67532128317
# RUN  180 , total integrated cost =  121213.59582604576
# RUN  190 , total integrated cost =  121213.51687171882
# RUN  200 , total integrated cost =  121213.43707956439
# RUN  300 , total integrated cost =  121212.64199992636
# RUN  400 , total integrated cost =  121211.85800192718
# RUN  500 , total integrated cost =  121211.06437802229
# RUN  600 , total integrated cost =  121210.27023809224
# RUN  700 , total integrated cost =  121209.48079222014
# RUN  800 , total integrated cost =  121208.69579807414
# RUN  900 , total integrated cost =  121207.89100435194
# RUN  1000 , total integrated cost =  121207.08893893928
# RUN  1100 , total integrated cost =  121206.28670298713
# RUN  1200 , total integrated cost =  121205.48437280332
# RUN  1300 , total integrated cost =  121204.67591646039
# RUN  1400 , total integrated cost =  121203.87750224244
# RUN  1500 , total integrated cost =  121203.073566617
# RUN  1600 , total integrated cost =  121202.27306999208
# RUN  1700 , total integrated cost =  121201.46449122817
# RUN  1800 , total integrated cost =  121200.65467704732
# RUN  1900 , total integrated cost =  121199.85103983778
# RUN  2000 , total integrated cost =  121199.03578504984
# RUN  3000 , total integrated cost =  121190.8562488493
# RUN  3000 , total integrated cost =  121190.8562488493
# Improved over  3000  iterations in  673.4867184729665  seconds by  12.065898398025979  percent.
# no convergence
# -------  63 0.4500000000000001 0.6500000000000004
# weight =  4793.402791505649
# set cost params:  1.0 4793.402791505649 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  224251.18269387222
# Gradient descend method:  None
# RUN  1 , total integrated cost =  202265.36528902332
# RUN  2 , total integrated cost =  201861.04420021077
# RUN  3 , total integrated cost =  201846.6260752337
# RUN  4 , total integrated cost =  114796.27806616481
# RUN  5 , total integrated cost =  101438.59075286772
# RUN  6 , total integrated cost =  100793.94920888933
# RUN  7 , total integrated cost =  100783.21100728653
# RUN  8 , total integrated cost =  98138.94870128823
# RUN  9 , total integrated cost =  98044.16128626051
# RUN  10 , total integrated cost =  98044.10215211519
# RUN  11 , total integrated cost =  98044.10215116227
# RUN  12 , total integrated cost =  98044.10215116203
# RUN  13 , total integrated cost =  98044.10215116203
# Control only changes marginally.
# RUN  13 , total integrated cost =  98044.10215116203
# Improved over  13  iterations in  2.98430993699003  seconds by  56.27933776161924  percent.
# no convergence
# -------  64 0.47500000000000014 0.6500000000000004
# weight =  8609.303594275883
# set cost params:  1.0 8609.303594275883 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  310347.2925911206
# Gradient descend method:  None
# RUN  1 , total integrated cost =  278105.93868430675
# RUN  2 , total integrated cost =  277348.30156208004
# RUN  3 , total integrated cost =  277336.48780648597
# RUN  4 , total integrated cost =  277336.20984475926
# RUN  5 , total integrated cost =  218079.06408893407
# RUN  6 , total integrated cost =  141395.14072128947
# RUN  7 , total integrated cost =  137868.39678221778
# RUN  8 , total integrated cost =  137854.3187036819
# RUN  9 , total integrated cost =  137853.9648265836
# RUN  10 , total integrated cost =  137772.39393409752
# RUN  11 , total integrated cost =  137727.537260886
# RUN  12 , total integrated cost =  137727.51739370517
# RUN  13 , total integrated cost =  137727.51739370517
# Control only changes marginally.
# RUN  13 , total integrated cost =  137727.51739370517
# Improved over  13  iterations in  2.847252090985421  seconds by  55.62148577362981  percent.
# no convergence
# --------------- 1
# [[True, False], [False, False], [False, False], [False, False], [False, False]]
# -------  60 0.5500000000000003 0.6250000000000003
# weight =  292884.1219371036
# set cost params:  1.0 292884.1219371036 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  593094.2686250317
# Gradient descend method:  None
# RUN  1 , total integrated cost =  593094.2686250317
# Control only changes marginally.
# RUN  1 , total integrated cost =  593094.2686250317
# Improved over  1  iterations in  0.5366185250459239  seconds by  0.0  percent.
# no convergence
# -------  61 0.5750000000000002 0.6250000000000003
# weight =  1713522.5982086149
# set cost params:  1.0 1713522.5982086149 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  693383.2512949909
# Gradient descend method:  None
# RUN  1 , total integrated cost =  693339.9858760752
# RUN  2 , total integrated cost =  693339.9858760744
# RUN  3 , total integrated cost =  693339.9858760743
# RUN  4 , total integrated cost =  693339.9858760743
# Control only changes marginally.
# RUN  4 , total integrated cost =  693339.9858760743
# Improved over  4  iterations in  2.0458204220049083  seconds by  0.006239755407392522  percent.
# no convergence
# -------  62 0.4250000000000001 0.6500000000000004
# weight =  3226.18365914594
# set cost params:  1.0 3226.18365914594 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  137825.94628743335
# Gradient descend method:  None
# RUN  1 , total integrated cost =  137825.94608281195
# RUN  2 , total integrated cost =  137825.93770071174
# RUN  3 , total integrated cost =  137825.92629322794
# RUN  4 , total integrated cost =  137825.91768059664
# RUN  5 , total integrated cost =  137825.90628110836
# RUN  6 , total integrated cost =  137825.89766080663
# RUN  7 , total integrated cost =  137825.88618856395
# RUN  8 , total integrated cost =  137825.87764418428
# RUN  9 , total integrated cost =  137825.86684664688
# RUN  10 , total integrated cost =  137825.85853130172
# RUN  11 , total integrated cost =  137825.84672093517
# RUN  12 , total integrated cost =  137825.83841704522
# RUN  13 , total integrated cost =  137825.82682471516
# RUN  14 , total integrated cost =  137825.81839538622
# RUN  15 , total integrated cost =  137825.80643973654
# RUN  16 , total integrated cost =  137825.79812532986
# RUN  17 , total integrated cost =  137825.78659305107
# RUN  18 , total integrated cost =  137825.7781214117
# RUN  19 , total integrated cost =  137825.7655508453
# RUN  20 , total integrated cost =  137825.75712724333
# RUN  30 , total integrated cost =  137825.65501053524
# RUN  40 , total integrated cost =  137825.55637859824
# RUN  50 , total integrated cost =  137825.45398641407
# RUN  60 , total integrated cost =  137825.3519295184
# RUN  70 , total integrated cost =  137825.25079555457
# RUN  80 , total integrated cost =  137825.1464163044
# RUN  90 , total integrated cost =  137825.04580478815
# RUN  100 , total integrated cost =  137824.94319071266
# RUN  110 , total integrated cost =  137824.84127208902
# RUN  120 , total integrated cost =  137824.73755192448
# RUN  130 , total integrated cost =  137824.6342505149
# RUN  140 , total integrated cost =  137824.5317731635
# RUN  150 , total integrated cost =  137824.4303170974
# RUN  160 , total integrated cost =  137824.32783358
# RUN  170 , total integrated cost =  137824.22841301814
# RUN  180 , total integrated cost =  137824.12603805336
# RUN  190 , total integrated cost =  137824.02632809448
# RUN  200 , total integrated cost =  137823.92531213845
# RUN  300 , total integrated cost =  137822.8998764912
# RUN  400 , total integrated cost =  137821.87632926714
# RUN  500 , total integrated cost =  137820.85695625015
# RUN  600 , total integrated cost =  137819.83139469518
# RUN  700 , total integrated cost =  137818.8067893039
# RUN  800 , total integrated cost =  137817.78366103605
# RUN  900 , total integrated cost =  137816.7597880217
# RUN  1000 , total integrated cost =  137815.72846483972
# RUN  1100 , total integrated cost =  137814.70336749178
# RUN  1200 , total integrated cost =  137813.6664825538
# RUN  1300 , total integrated cost =  137812.62978396218
# RUN  1400 , total integrated cost =  137811.59520123742
# RUN  1500 , total integrated cost =  137810.5508674076
# RUN  1600 , total integrated cost =  137809.5059367412
# RUN  1700 , total integrated cost =  137808.46165588475
# RUN  1800 , total integrated cost =  137807.4102693996
# RUN  1900 , total integrated cost =  137806.37370660173
# RUN  2000 , total integrated cost =  137805.33454219496
# RUN  3000 , total integrated cost =  137794.76525294996
# RUN  3000 , total integrated cost =  137794.76525294996
# Improved over  3000  iterations in  618.6385777200339  seconds by  0.02262348659544955  percent.
# no convergence
# -------  63 0.4500000000000001 0.6500000000000004
# weight =  10964.98849615963
# set cost params:  1.0 10964.98849615963 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  223627.97359344395
# Gradient descend method:  None
# RUN  1 , total integrated cost =  223627.97359344395
# Control only changes marginally.
# RUN  1 , total integrated cost =  223627.97359344395
# Improved over  1  iterations in  0.5280912410235032  seconds by  0.0  percent.
# no convergence
# -------  64 0.47500000000000014 0.6500000000000004
# weight =  19400.96454156985
# set cost params:  1.0 19400.96454156985 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  310341.66678903846
# Gradient descend method:  None
# RUN  1 , total integrated cost =  310341.66678903846
# Control only changes marginally.
# RUN  1 , total integrated cost =  310341.66678903846
# Improved over  1  iterations in  0.49502226198092103  seconds by  0.0  percent.
# no convergence
# --------------- 2
# [[True, False], [False, False], [False, False], [False, False], [False, False]]
# -------  60 0.5500000000000003 0.6250000000000003
# weight =  292884.1219371042
# set cost params:  1.0 292884.1219371042 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  593094.2686250329
# Gradient descend method:  None
# RUN  1 , total integrated cost =  593094.2686250329
# Control only changes marginally.
# RUN  1 , total integrated cost =  593094.2686250329
# Improved over  1  iterations in  0.5037383619928733  seconds by  0.0  percent.
# converged for  60
# -------  61 0.5750000000000002 0.6250000000000003
# weight =  1713678.1827754702
# set cost params:  1.0 1713678.1827754702 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  693402.9378537505
# Gradient descend method:  None
# RUN  1 , total integrated cost =  693402.9378537505
# Control only changes marginally.
# RUN  1 , total integrated cost =  693402.9378537505
# Improved over  1  iterations in  0.5242153389845043  seconds by  0.0  percent.
# no convergence
# -------  62 0.4250000000000001 0.6500000000000004
# weight =  3226.914013310689
# set cost params:  1.0 3226.914013310689 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  137825.95968497638
# Gradient descend method:  None
# RUN  1 , total integrated cost =  137825.945815764
# RUN  2 , total integrated cost =  137825.93650613845
# RUN  3 , total integrated cost =  137825.9256225252
# RUN  4 , total integrated cost =  137825.91649856413
# RUN  5 , total integrated cost =  137825.90459993295
# RUN  6 , total integrated cost =  137825.8958614592
# RUN  7 , total integrated cost =  137825.88337014188
# RUN  8 , total integrated cost =  137825.87428828198
# RUN  9 , total integrated cost =  137825.8627384214
# RUN  10 , total integrated cost =  137825.85406891463
# RUN  11 , total integrated cost =  137825.8406605794
# RUN  12 , total integrated cost =  137825.83198452918
# RUN  13 , total integrated cost =  137825.82006760896
# RUN  14 , total integrated cost =  137825.81136961718
# RUN  15 , total integrated cost =  137825.79889545633
# RUN  16 , total integrated cost =  137825.78979559764
# RUN  17 , total integrated cost =  137825.7781128634
# RUN  18 , total integrated cost =  137825.76943817778
# RUN  19 , total integrated cost =  137825.7571149868
# RUN  20 , total integrated cost =  137825.74788037647
# RUN  30 , total integrated cost =  137825.6405047091
# RUN  40 , total integrated cost =  137825.53246072028
# RUN  50 , total integrated cost =  137825.4257203107
# RUN  60 , total integrated cost =  137825.31893562299
# RUN  70 , total integrated cost =  137825.21216339385
# RUN  80 , total integrated cost =  137825.10464422626
# RUN  90 , total integrated cost =  137824.99843326723
# RUN  100 , total integrated cost =  137824.89532887965
# RUN  110 , total integrated cost =  137824.78639859287
# RUN  120 , total integrated cost =  137824.67597743744
# RUN  130 , total integrated cost =  137824.57213613155
# RUN  140 , total integrated cost =  137824.45958193904
# RUN  150 , total integrated cost =  137824.3562364173
# RUN  160 , total integrated cost =  137824.2478633075
# RUN  170 , total integrated cost =  137824.14459587028
# RUN  180 , total integrated cost =  137824.03949329272
# RUN  190 , total integrated cost =  137823.92902241566
# RUN  200 , total integrated cost =  137823.82152315287
# RUN  300 , total integrated cost =  137822.74961001443
# RUN  400 , total integrated cost =  137821.6773278213
# RUN  500 , total integrated cost =  137820.60780135603
# RUN  600 , total integrated cost =  137819.52176097763
# RUN  700 , total integrated cost =  137818.43638182164
# RUN  800 , total integrated cost =  137817.35421289998
# RUN  900 , total integrated cost =  137816.26907375085
# RUN  1000 , total integrated cost =  137815.1814315378
# RUN  1100 , total integrated cost =  137814.0809388229
# RUN  1200 , total integrated cost =  137813.01050814387
# RUN  1300 , total integrated cost =  137811.9143809149
# RUN  1400 , total integrated cost =  137810.8317520535
# RUN  1500 , total integrated cost =  137809.7469315689
# RUN  1600 , total integrated cost =  137808.65932777335
# RUN  1700 , total integrated cost =  137807.5645797888
# RUN  1800 , total integrated cost =  137806.4620027707
# RUN  1900 , total integrated cost =  137805.3570906648
# RUN  2000 , total integrated cost =  137804.26692971922
# RUN  3000 , total integrated cost =  137793.14520732322
# RUN  3000 , total integrated cost =  137793.14520732322
# Improved over  3000  iterations in  574.0805418199743  seconds by  0.023808633531857026  percent.
# no convergence
# -------  63 0.4500000000000001 0.6500000000000004
# weight =  10996.839748190865
# set cost params:  1.0 10996.839748190865 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  224276.1058129072
# Gradient descend method:  None
# RUN  1 , total integrated cost =  224276.1058129072
# Control only changes marginally.
# RUN  1 , total integrated cost =  224276.1058129072
# Improved over  1  iterations in  0.5057761479984038  seconds by  0.0  percent.
# converged for  63
# -------  64 0.47500000000000014 0.6500000000000004
# weight =  19402.569766882305
# set cost params:  1.0 19402.569766882305 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  310367.3425958703
# Gradient descend method:  None
# RUN  1 , total integrated cost =  310367.34259587026
# State only changes marginally.
# RUN  2 , total integrated cost =  310367.3425958702
# RUN  3 , total integrated cost =  310367.3425958702
# Control only changes marginally.
# RUN  3 , total integrated cost =  310367.3425958702
# Improved over  3  iterations in  1.4323680140078068  seconds by  2.842170943040401e-14  percent.
# converged for  64
# --------------- 3
# [[True, True], [False, False], [False, False], [True, False], [True, False]]
# -------  60 0.5500000000000003 0.6250000000000003
# weight =  292884.12193710415
# set cost params:  1.0 292884.12193710415 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  593094.2686250327
# Gradient descend method:  None
# RUN  1 , total integrated cost =  593094.2686250327
# Control only changes marginally.
# RUN  1 , total integrated cost =  593094.2686250327
# Improved over  1  iterations in  0.5248476979904808  seconds by  0.0  percent.
# converged for  60
# -------  61 0.5750000000000002 0.6250000000000003
# weight =  1713678.1876288436
# set cost params:  1.0 1713678.1876288436 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  693402.9398175027
# Gradient descend method:  None
# RUN  1 , total integrated cost =  693402.9398175027
# Control only changes marginally.
# RUN  1 , total integrated cost =  693402.9398175027
# Improved over  1  iterations in  0.5150050580268726  seconds by  0.0  percent.
# converged for  61
# -------  62 0.4250000000000001 0.6500000000000004
# weight =  3227.6827186474256
# set cost params:  1.0 3227.6827186474256 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  137825.96985405544
# Gradient descend method:  None
# RUN  1 , total integrated cost =  137825.95521424612
# RUN  2 , total integrated cost =  137825.9451133427
# RUN  3 , total integrated cost =  137825.93244872332
# RUN  4 , total integrated cost =  137825.92339446794
# RUN  5 , total integrated cost =  137825.91103686285
# RUN  6 , total integrated cost =  137825.90184357896
# RUN  7 , total integrated cost =  137825.88952437168
# RUN  8 , total integrated cost =  137825.88029081165
# RUN  9 , total integrated cost =  137825.8675521458
# RUN  10 , total integrated cost =  137825.8584763881
# RUN  11 , total integrated cost =  137825.84552410772
# RUN  12 , total integrated cost =  137825.83639758913
# RUN  13 , total integrated cost =  137825.82288216578
# RUN  14 , total integrated cost =  137825.81328243855
# RUN  15 , total integrated cost =  137825.80159737688
# RUN  16 , total integrated cost =  137825.79250584776
# RUN  17 , total integrated cost =  137825.77742660177
# RUN  18 , total integrated cost =  137825.7677359976
# RUN  19 , total integrated cost =  137825.75537952414
# RUN  20 , total integrated cost =  137825.7461854462
# RUN  30 , total integrated cost =  137825.63759945784
# RUN  40 , total integrated cost =  137825.52330887725
# RUN  50 , total integrated cost =  137825.41236346564
# RUN  60 , total integrated cost =  137825.30282056073
# RUN  70 , total integrated cost =  137825.1930059227
# RUN  80 , total integrated cost =  137825.0824823532
# RUN  90 , total integrated cost =  137824.9708941905
# RUN  100 , total integrated cost =  137824.86266778392
# RUN  110 , total integrated cost =  137824.74773506747
# RUN  120 , total integrated cost =  137824.6369514007
# RUN  130 , total integrated cost =  137824.5267877503
# RUN  140 , total integrated cost =  137824.41701646885
# RUN  150 , total integrated cost =  137824.3032161586
# RUN  160 , total integrated cost =  137824.1922529123
# RUN  170 , total integrated cost =  137824.0840005151
# RUN  180 , total integrated cost =  137823.96856251894
# RUN  190 , total integrated cost =  137823.85608918712
# RUN  200 , total integrated cost =  137823.74448149954
# RUN  300 , total integrated cost =  137822.6239391166
# RUN  400 , total integrated cost =  137821.5085675792
# RUN  500 , total integrated cost =  137820.37806428922
# RUN  600 , total integrated cost =  137819.24524714585
# RUN  700 , total integrated cost =  137818.11972937232
# RUN  800 , total integrated cost =  137816.9870207938
# RUN  900 , total integrated cost =  137815.85244721794
# RUN  1000 , total integrated cost =  137814.72750758956
# RUN  1100 , total integrated cost =  137813.59854815932
# RUN  1200 , total integrated cost =  137812.45783733815
# RUN  1300 , total integrated cost =  137811.31777436915
# RUN  1400 , total integrated cost =  137810.17995818626
# RUN  1500 , total integrated cost =  137809.0394746596
# RUN  1600 , total integrated cost =  137807.89860297221
# RUN  1700 , total integrated cost =  137806.74715076145
# RUN  1800 , total integrated cost =  137805.58520175936
# RUN  1900 , total integrated cost =  137804.43545866656
# RUN  2000 , total integrated cost =  137803.2802809788
# RUN  3000 , total integrated cost =  137791.62856558492
# RUN  3000 , total integrated cost =  137791.62856558492
# Improved over  3000  iterations in  589.9982484349748  seconds by  0.024916413435633444  percent.
# no convergence
# -------  63 0.4500000000000001 0.6500000000000004
# weight =  10996.911609433013
# set cost params:  1.0 10996.911609433013 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  224277.5680972249
# Gradient descend method:  None
# RUN  1 , total integrated cost =  224277.5680972249
# Control only changes marginally.
# RUN  1 , total integrated cost =  224277.5680972249
# Improved over  1  iterations in  0.5025189699954353  seconds by  0.0  percent.
# converged for  63
# -------  64 0.47500000000000014 0.6500000000000004
# weight =  19402.569872839118
# set cost params:  1.0 19402.569872839118 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  310367.3442906663
# Gradient descend method:  None
# RUN  1 , total integrated cost =  310367.3442906663
# Control only changes marginally.
# RUN  1 , total integrated cost =  310367.3442906663
# Improved over  1  iterations in  0.49459035199834034  seconds by  0.0  percent.
# no convergence
# --------------- 4
# [[True, True], [True, False], [False, False], [True, True], [True, False]]
# -------  60 0.5500000000000003 0.6250000000000003
# weight =  292884.1219371042
# set cost params:  1.0 292884.1219371042 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  593094.2686250329
# Gradient descend method:  None
# RUN  1 , total integrated cost =  593094.2686250329
# Control only changes marginally.
# RUN  1 , total integrated cost =  593094.2686250329
# Improved over  1  iterations in  0.5310442649642937  seconds by  0.0  percent.
# converged for  60
# -------  61 0.5750000000000002 0.6250000000000003
# weight =  1713678.1876289938
# set cost params:  1.0 1713678.1876289938 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  693402.9398175634
# Gradient descend method:  None
# RUN  1 , total integrated cost =  693402.9398175634
# Control only changes marginally.
# RUN  1 , total integrated cost =  693402.9398175634
# Improved over  1  iterations in  0.560972495994065  seconds by  0.0  percent.
# converged for  61
# -------  62 0.4250000000000001 0.6500000000000004
# weight =  3228.4873911761347
# set cost params:  1.0 3228.4873911761347 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  137825.98049377056
# Gradient descend method:  None
# RUN  1 , total integrated cost =  137825.96515393083
# RUN  2 , total integrated cost =  137825.95569660707
# RUN  3 , total integrated cost =  137825.94308947856
# RUN  4 , total integrated cost =  137825.93359540286
# RUN  5 , total integrated cost =  137825.9196160807
# RUN  6 , total integrated cost =  137825.9101315077
# RUN  7 , total integrated cost =  137825.89538171195
# RUN  8 , total integrated cost =  137825.8854478179
# RUN  9 , total integrated cost =  137825.87295978132
# RUN  10 , total integrated cost =  137825.86348296967
# RUN  11 , total integrated cost =  137825.84983242193
# RUN  12 , total integrated cost =  137825.84036715058
# RUN  13 , total integrated cost =  137825.82685053648
# RUN  14 , total integrated cost =  137825.81726403726
# RUN  15 , total integrated cost =  137825.80411467035
# RUN  16 , total integrated cost =  137825.79418166645
# RUN  17 , total integrated cost =  137825.78170957553
# RUN  18 , total integrated cost =  137825.7722187346
# RUN  19 , total integrated cost =  137825.7583003689
# RUN  20 , total integrated cost =  137825.74882814844
# RUN  30 , total integrated cost =  137825.63284367177
# RUN  40 , total integrated cost =  137825.5137112597
# RUN  50 , total integrated cost =  137825.3935037391
# RUN  60 , total integrated cost =  137825.27494307788
# RUN  70 , total integrated cost =  137825.15765621804
# RUN  80 , total integrated cost =  137825.04272832017
# RUN  90 , total integrated cost =  137824.92378556842
# RUN  100 , total integrated cost =  137824.80760651102
# RUN  110 , total integrated cost =  137824.6902456912
# RUN  120 , total integrated cost =  137824.57159336034
# RUN  130 , total integrated cost =  137824.4542847057
# RUN  140 , total integrated cost =  137824.33540391893
# RUN  150 , total integrated cost =  137824.2166696389
# RUN  160 , total integrated cost =  137824.10010733161
# RUN  170 , total integrated cost =  137823.97619002033
# RUN  180 , total integrated cost =  137823.8589345173
# RUN  190 , total integrated cost =  137823.74402210957
# RUN  200 , total integrated cost =  137823.62653826637
# RUN  300 , total integrated cost =  137822.45246997537
# RUN  400 , total integrated cost =  137821.26906212737
# RUN  500 , total integrated cost =  137820.08342455808
# RUN  600 , total integrated cost =  137818.897002236
# RUN  700 , total integrated cost =  137817.70458754484
# RUN  800 , total integrated cost =  137816.51238725573
# RUN  900 , total integrated cost =  137815.30016244226
# RUN  1000 , total integrated cost =  137814.1103594084
# RUN  1100 , total integrated cost =  137812.90429821008
# RUN  1200 , total integrated cost =  137811.71259644986
# RUN  1300 , total integrated cost =  137810.51154091288
# RUN  1400 , total integrated cost =  137809.29750966473
# RUN  1500 , total integrated cost =  137808.1034177359
# RUN  1600 , total integrated cost =  137806.91846039027
# RUN  1700 , total integrated cost =  137805.70278390616
# RUN  1800 , total integrated cost =  137804.50024681905
# RUN  1900 , total integrated cost =  137803.29207472966
# RUN  2000 , total integrated cost =  137802.08581929753
# RUN  3000 , total integrated cost =  137789.70579550136
# RUN  3000 , total integrated cost =  137789.70579550136
# Improved over  3000  iterations in  595.4612905129907  seconds by  0.026319202039587708  percent.
# no convergence
# -------  63 0.4500000000000001 0.6500000000000004
# weight =  10996.911771093286
# set cost params:  1.0 10996.911771093286 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  224277.5713868059
# Gradient descend method:  None
# RUN  1 , total integrated cost =  224277.5713868059
# Control only changes marginally.
# RUN  1 , total integrated cost =  224277.5713868059
# Improved over  1  iterations in  0.5074792510131374  seconds by  0.0  percent.
# converged for  63
# -------  64 0.47500000000000014 0.6500000000000004
# weight =  19402.569872845997
# set cost params:  1.0 19402.569872845997 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  310367.3442907754
# Gradient descend method:  None
# RUN  1 , total integrated cost =  310367.3442907754
# Control only changes marginally.
# RUN  1 , total integrated cost =  310367.3442907754
# Improved over  1  iterations in  0.4964995330083184  seconds by  0.0  percent.
# converged for  64
# --------------- 5
# [[True, True], [True, True], [False, False], [True, True], [True, True]]
# -------  60 0.5500000000000003 0.6250000000000003
# weight =  292884.12193710415
# set cost params:  1.0 292884.12193710415 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  593094.2686250327
# Gradient descend method:  None
# RUN  1 , total integrated cost =  593094.2686250327
# Control only changes marginally.
# RUN  1 , total integrated cost =  593094.2686250327
# Improved over  1  iterations in  0.5278945259633474  seconds by  0.0  percent.
# converged for  60
# -------  61 0.5750000000000002 0.6250000000000003
# weight =  1713678.1876289938
# set cost params:  1.0 1713678.1876289938 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  693402.9398175634
# Gradient descend method:  None
# RUN  1 , total integrated cost =  693402.9398175634
# Control only changes marginally.
# RUN  1 , total integrated cost =  693402.9398175634
# Improved over  1  iterations in  0.5400092760100961  seconds by  0.0  percent.
# converged for  61
# -------  62 0.4250000000000001 0.6500000000000004
# weight =  3229.3375903491856
# set cost params:  1.0 3229.3375903491856 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  137825.991729667
# Gradient descend method:  None
# RUN  1 , total integrated cost =  137825.97826010548
# RUN  2 , total integrated cost =  137825.96831758894
# RUN  3 , total integrated cost =  137825.95436985497
# RUN  4 , total integrated cost =  137825.9436887322
# RUN  5 , total integrated cost =  137825.9300473185
# RUN  6 , total integrated cost =  137825.9200637097
# RUN  7 , total integrated cost =  137825.90381441012
# RUN  8 , total integrated cost =  137825.8935197447
# RUN  9 , total integrated cost =  137825.8763650031
# RUN  10 , total integrated cost =  137825.86564582709
# RUN  11 , total integrated cost =  137825.85175814482
# RUN  12 , total integrated cost =  137825.8410125375
# RUN  13 , total integrated cost =  137825.8268928734
# RUN  14 , total integrated cost =  137825.8163743421
# RUN  15 , total integrated cost =  137825.8018232099
# RUN  16 , total integrated cost =  137825.7917249574
# RUN  17 , total integrated cost =  137825.77744322928
# RUN  18 , total integrated cost =  137825.76709069306
# RUN  19 , total integrated cost =  137825.7518347472
# RUN  20 , total integrated cost =  137825.74180417854
# RUN  30 , total integrated cost =  137825.6095262383
# RUN  40 , total integrated cost =  137825.48868686878
# RUN  50 , total integrated cost =  137825.36465773653
# RUN  60 , total integrated cost =  137825.2413234541
# RUN  70 , total integrated cost =  137825.11345354616
# RUN  80 , total integrated cost =  137824.99101700983
# RUN  90 , total integrated cost =  137824.86479300013
# RUN  100 , total integrated cost =  137824.73641572296
# RUN  110 , total integrated cost =  137824.60659393205
# RUN  120 , total integrated cost =  137824.47816338527
# RUN  130 , total integrated cost =  137824.3519947154
# RUN  140 , total integrated cost =  137824.22450174336
# RUN  150 , total integrated cost =  137824.0921418592
# RUN  160 , total integrated cost =  137823.96689976443
# RUN  170 , total integrated cost =  137823.83943276107
# RUN  180 , total integrated cost =  137823.71230612422
# RUN  190 , total integrated cost =  137823.5887676461
# RUN  200 , total integrated cost =  137823.46033392276
# RUN  300 , total integrated cost =  137822.1833201402
# RUN  400 , total integrated cost =  137820.87830296342
# RUN  500 , total integrated cost =  137819.5566239341
# RUN  600 , total integrated cost =  137818.25808278777
# RUN  700 , total integrated cost =  137816.93817043118
# RUN  800 , total integrated cost =  137815.6175176424
# RUN  900 , total integrated cost =  137814.30792933586
# RUN  1000 , total integrated cost =  137812.98000442988
# RUN  1100 , total integrated cost =  137811.65483553684
# RUN  1200 , total integrated cost =  137810.290634569
# RUN  1300 , total integrated cost =  137808.9386628105
# RUN  1400 , total integrated cost =  137807.59408434216
# RUN  1500 , total integrated cost =  137806.23490131533
# RUN  1600 , total integrated cost =  137804.85941733266
# RUN  1700 , total integrated cost =  137803.47906346092
# RUN  1800 , total integrated cost =  137802.10945137337
# RUN  1900 , total integrated cost =  137800.72731141056
# RUN  2000 , total integrated cost =  137799.34978370625
# RUN  3000 , total integrated cost =  137785.1767289631
# RUN  3000 , total integrated cost =  137785.1767289631
# Improved over  3000  iterations in  561.571093676961  seconds by  0.029613427911300505  percent.
# no convergence
# -------  63 0.4500000000000001 0.6500000000000004
# weight =  10996.911771456895
# set cost params:  1.0 10996.911771456895 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  224277.57139420416
# Gradient descend method:  None
# RUN  1 , total integrated cost =  224277.57139420416
# Control only changes marginally.
# RUN  1 , total integrated cost =  224277.57139420416
# Improved over  1  iterations in  0.49958588497247547  seconds by  0.0  percent.
# converged for  63
# -------  64 0.47500000000000014 0.6500000000000004
# weight =  19402.569872846056
# set cost params:  1.0 19402.569872846056 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  310367.34429077664
# Gradient descend method:  None
# RUN  1 , total integrated cost =  310367.34429077664
# Control only changes marginally.
# RUN  1 , total integrated cost =  310367.34429077664
# Improved over  1  iterations in  0.49802936700871214  seconds by  0.0  percent.
# converged for  64
# --------------- 6
# [[True, True], [True, True], [False, False], [True, True], [True, True]]
# -------  60 0.5500000000000003 0.6250000000000003
# weight =  292884.1219371042
# set cost params:  1.0 292884.1219371042 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  593094.2686250329
# Gradient descend method:  None
# RUN  1 , total integrated cost =  593094.2686250329
# Control only changes marginally.
# RUN  1 , total integrated cost =  593094.2686250329
# Improved over  1  iterations in  0.506149668013677  seconds by  0.0  percent.
# converged for  60
# -------  61 0.5750000000000002 0.6250000000000003
# weight =  1713678.1876289938
# set cost params:  1.0 1713678.1876289938 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  693402.9398175634
# Gradient descend method:  None
# RUN  1 , total integrated cost =  693402.9398175634
# Control only changes marginally.
# RUN  1 , total integrated cost =  693402.9398175634
# Improved over  1  iterations in  0.5139805339858867  seconds by  0.0  percent.
# converged for  61
# -------  62 0.4250000000000001 0.6500000000000004
# weight =  3230.2944875071594
# set cost params:  1.0 3230.2944875071594 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  137826.00436867977
# Gradient descend method:  None
# RUN  1 , total integrated cost =  137825.98852476696
# RUN  2 , total integrated cost =  137825.97666515433
# RUN  3 , total integrated cost =  137825.96134079402
# RUN  4 , total integrated cost =  137825.9502959901
# RUN  5 , total integrated cost =  137825.93220612334
# RUN  6 , total integrated cost =  137825.92100775137
# RUN  7 , total integrated cost =  137825.90162930204
# RUN  8 , total integrated cost =  137825.89005943417
# RUN  9 , total integrated cost =  137825.87276815216
# RUN  10 , total integrated cost =  137825.86175241752
# RUN  11 , total integrated cost =  137825.8456096424
# RUN  12 , total integrated cost =  137825.8340384425
# RUN  13 , total integrated cost =  137825.81674241478
# RUN  14 , total integrated cost =  137825.80573211098
# RUN  15 , total integrated cost =  137825.7897156373
# RUN  16 , total integrated cost =  137825.77801461477
# RUN  17 , total integrated cost =  137825.76183846715
# RUN  18 , total integrated cost =  137825.75029529634
# RUN  19 , total integrated cost =  137825.7333920014
# RUN  20 , total integrated cost =  137825.7224042802
# RUN  30 , total integrated cost =  137825.5726315908
# RUN  40 , total integrated cost =  137825.43123453634
# RUN  50 , total integrated cost =  137825.28894490728
# RUN  60 , total integrated cost =  137825.1452872808
# RUN  70 , total integrated cost =  137825.00556247798
# RUN  80 , total integrated cost =  137824.86101578095
# RUN  90 , total integrated cost =  137824.7138517744
# RUN  100 , total integrated cost =  137824.5705446476
# RUN  110 , total integrated cost =  137824.42816885834
# RUN  120 , total integrated cost =  137824.2807010783
# RUN  130 , total integrated cost =  137824.1355462585
# RUN  140 , total integrated cost =  137823.98908666737
# RUN  150 , total integrated cost =  137823.85048958412
# RUN  160 , total integrated cost =  137823.71160632788
# RUN  170 , total integrated cost =  137823.5703431237
# RUN  180 , total integrated cost =  137823.42397373437
# RUN  190 , total integrated cost =  137823.28455783805
# RUN  200 , total integrated cost =  137823.1398026204
# RUN  300 , total integrated cost =  137821.69589192563
# RUN  400 , total integrated cost =  137820.26507303776
# RUN  500 , total integrated cost =  137818.79892656137
# RUN  600 , total integrated cost =  137817.35130496044
# RUN  700 , total integrated cost =  137815.87910927142
# RUN  800 , total integrated cost =  137814.42170428115
# RUN  900 , total integrated cost =  137812.95077719915
# RUN  1000 , total integrated cost =  137811.46086654352
# RUN  1100 , total integrated cost =  137809.97002303798
# RUN  1200 , total integrated cost =  137808.4837809777
# RUN  1300 , total integrated cost =  137806.96304305585
# RUN  1400 , total integrated cost =  137805.45546062014
# RUN  1500 , total integrated cost =  137803.9287917255
# RUN  1600 , total integrated cost =  137802.4066515185
# RUN  1700 , total integrated cost =  137800.88014982306
# RUN  1800 , total integrated cost =  137799.3313749531
# RUN  1900 , total integrated cost =  137797.81323711766
# RUN  2000 , total integrated cost =  137796.26399691805
# RUN  3000 , total integrated cost =  137780.50120941616
# RUN  3000 , total integrated cost =  137780.50120941616
# Improved over  3000  iterations in  558.2239519509603  seconds by  0.03301493028985192  percent.
# no convergence
# -------  63 0.4500000000000001 0.6500000000000004
# weight =  10996.911771457746
# set cost params:  1.0 10996.911771457746 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  224277.5713942215
# Gradient descend method:  None
# RUN  1 , total integrated cost =  224277.5713942215
# Control only changes marginally.
# RUN  1 , total integrated cost =  224277.5713942215
# Improved over  1  iterations in  0.5115976170054637  seconds by  0.0  percent.
# converged for  63
# -------  64 0.47500000000000014 0.6500000000000004
# weight =  19402.569872846037
# set cost params:  1.0 19402.569872846037 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  310367.3442907762
# Gradient descend method:  None
# RUN  1 , total integrated cost =  310367.3442907762
# Control only changes marginally.
# RUN  1 , total integrated cost =  310367.3442907762
# Improved over  1  iterations in  0.5148710549692623  seconds by  0.0  percent.
# converged for  64
# --------------- 7

# %%
"""
for i in i_range_0:
    
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.

    plotFunc.plot_control_current(aln, [bestControl_init[i], bestControl_0[i]],
        [costnode_init[i], costnode_0[i]], [weights_init[i], weights_0[i]], dur,
        dur_pre, dur_post, initVars[i], target[i], '', filename_ = '', transition_time_ = trans_time,
        labels_ = ["init", "sparse control" + str(i)], print_cost_ = False)
"""
# Out:
# '\nfor i in i_range_0:\n    \n    aln.params.ext_exc_current = exc[i] * 5.\n    aln.params.ext_inh_current = inh[i] * 5.\n\n    plotFunc.plot_control_current(aln, [bestControl_init[i], bestControl_0[i]],\n        [costnode_init[i], costnode_0[i]], [weights_init[i], weights_0[i]], dur,\n        dur_pre, dur_post, initVars[i], target[i], \'\', filename_ = \'\', transition_time_ = trans_time,\n        labels_ = ["init", "sparse control" + str(i)], print_cost_ = False)\n'

# %%
if os.path.isfile(final_file_1) :
    print("file found")
    
    with open(final_file_1,'rb') as f:
        load_array = pickle.load(f)

    bestControl_1 = load_array[0]
    bestState_1 = load_array[1]
    cost_1 = load_array[2]
    runtime_1 = load_array[3]
    grad_1 = load_array[4]
    phi_1 = load_array[5]
    costnode_1 = load_array[6]
    weights_1 = load_array[7]
# Out:
# file found

# %%
factor_iteration = 20
conv_1 = [[False]*2] * len(exc)
full_converge = False

for i in range(len(conv_1)):
    if i not in i_range_1:
        conv_1[i] = [True, True]
        
counter = 0

while full_converge == False:
    
    
    print('---------------', counter)
    if counter > 20:
        break
    
    """
    print(conv_1[start_index:limit:i_stepsize])
    full_converge = True
    
    for conv in conv_1[start_index:limit:i_stepsize]:
        if not conv[0]:
            full_converge = False
            break
        if not conv[1]:
            full_converge = False
            break
    
    if full_converge:
        print("full convergence")
        break
    """

    for i in i_range_1:        

        print("------- ", i, exc[i], inh[i])
        
        #if conv_1[i] == [True, True]:
        #    continue
            
        aln.params.ext_exc_current = exc[i] * 5.
        aln.params.ext_inh_current = inh[i] * 5.
        
        if not type(bestControl_1[i]) == type(None):
            control0 = bestControl_1[i][:,:,n_pre-1:-n_post+1].copy()
        else:
            control0 = bestControl_0[i][:,:,n_pre-1:-n_post+1].copy()
            cost_1[i] = cost_0[i]
        
        cost.setParams(1.0, 1. * factor_we, 1. * factor_ws)

        setinit(initVars[i], aln)

        # "HS", "FR", "PR", "HZ"
        cgv = None
        max_it = int( 500 * factor_iteration )

        weights_1[i] = cost.getParams()

        bestControl_1[i], bestState_1[i], cost_1[i], runtime_1[i], grad_1[i], phi_1[i], costnode_1[i] = aln.A1(
            control0, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cntrl_vars_init,
            prec_variables_ = prec_vars, transition_time_ = trans_time)
        
        with open(final_file_1,'wb') as f:
            pickle.dump([bestControl_1, bestState_1, cost_1, runtime_1, grad_1, phi_1,
                 costnode_1, weights_1], f)
            
        j = 1
        while cost_1[i][-j] == 0.:
            j += 1
            
        if j == cost_1[i].shape[0]-1:
            print("converged for ", i)
            if conv_1[i][0]:
                conv_1[i] = [True, True]
            else:
                conv_1[i] = [True, False]
            continue
    
        print("no convergence")
        
    counter += 1
# Out:
# --------------- 0
# -------  38 0.47500000000000014 0.5500000000000003
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7.357141885082921
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.357141885082921
# Control only changes marginally.
# RUN  1 , total integrated cost =  7.357141885082921
# Improved over  1  iterations in  0.09596614700058126  seconds by  0.0  percent.
# converged for  38
# --------------- 1
# -------  38 0.47500000000000014 0.5500000000000003
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7.357141885082921
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.357141885082921
# Control only changes marginally.
# RUN  1 , total integrated cost =  7.357141885082921
# Improved over  1  iterations in  0.0932876849983586  seconds by  0.0  percent.
# converged for  38
# --------------- 2
# -------  38 0.47500000000000014 0.5500000000000003
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7.357141885082921
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.357141885082921
# Control only changes marginally.
# RUN  1 , total integrated cost =  7.357141885082921
# Improved over  1  iterations in  0.0928304869994463  seconds by  0.0  percent.
# converged for  38
# --------------- 3
# -------  38 0.47500000000000014 0.5500000000000003
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7.357141885082921
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.357141885082921
# Control only changes marginally.
# RUN  1 , total integrated cost =  7.357141885082921
# Improved over  1  iterations in  0.09290778799913824  seconds by  0.0  percent.
# converged for  38
# --------------- 4
# -------  38 0.47500000000000014 0.5500000000000003
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7.357141885082921
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.357141885082921
# Control only changes marginally.
# RUN  1 , total integrated cost =  7.357141885082921
# Improved over  1  iterations in  0.09247276400128612  seconds by  0.0  percent.
# converged for  38
# --------------- 5
# -------  38 0.47500000000000014 0.5500000000000003
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7.357141885082921
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.357141885082921
# Control only changes marginally.
# RUN  1 , total integrated cost =  7.357141885082921
# Improved over  1  iterations in  0.0947259229978954  seconds by  0.0  percent.
# converged for  38
# --------------- 6
# -------  38 0.47500000000000014 0.5500000000000003
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7.357141885082921
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.357141885082921
# Control only changes marginally.
# RUN  1 , total integrated cost =  7.357141885082921
# Improved over  1  iterations in  0.0942272510001203  seconds by  0.0  percent.
# converged for  38
# --------------- 7
# -------  38 0.47500000000000014 0.5500000000000003
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7.357141885082921
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.357141885082921
# Control only changes marginally.
# RUN  1 , total integrated cost =  7.357141885082921
# Improved over  1  iterations in  0.09744883999883314  seconds by  0.0  percent.
# converged for  38
# --------------- 8
# -------  38 0.47500000000000014 0.5500000000000003
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7.357141885082921
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.357141885082921
# Control only changes marginally.
# RUN  1 , total integrated cost =  7.357141885082921
# Improved over  1  iterations in  0.09705081399806659  seconds by  0.0  percent.
# converged for  38
# --------------- 9
# -------  38 0.47500000000000014 0.5500000000000003
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7.357141885082921
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.357141885082921
# Control only changes marginally.
# RUN  1 , total integrated cost =  7.357141885082921
# Improved over  1  iterations in  0.09216611000010744  seconds by  0.0  percent.
# converged for  38
# --------------- 10
# -------  38 0.47500000000000014 0.5500000000000003
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7.357141885082921
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.357141885082921
# Control only changes marginally.
# RUN  1 , total integrated cost =  7.357141885082921
# Improved over  1  iterations in  0.09492426100041484  seconds by  0.0  percent.
# converged for  38
# --------------- 11
# -------  38 0.47500000000000014 0.5500000000000003
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7.357141885082921
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.357141885082921
# Control only changes marginally.
# RUN  1 , total integrated cost =  7.357141885082921
# Improved over  1  iterations in  0.09227458799796295  seconds by  0.0  percent.
# converged for  38
# --------------- 12
# -------  38 0.47500000000000014 0.5500000000000003
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7.357141885082921
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.357141885082921
# Control only changes marginally.
# RUN  1 , total integrated cost =  7.357141885082921
# Improved over  1  iterations in  0.09824693600239698  seconds by  0.0  percent.
# converged for  38
# --------------- 13
# -------  38 0.47500000000000014 0.5500000000000003
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7.357141885082921
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.357141885082921
# Control only changes marginally.
# RUN  1 , total integrated cost =  7.357141885082921
# Improved over  1  iterations in  0.11280625599829364  seconds by  0.0  percent.
# converged for  38
# --------------- 14
# -------  38 0.47500000000000014 0.5500000000000003
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7.357141885082921
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.357141885082921
# Control only changes marginally.
# RUN  1 , total integrated cost =  7.357141885082921
# Improved over  1  iterations in  0.09582792499713833  seconds by  0.0  percent.
# converged for  38
# --------------- 15
# -------  38 0.47500000000000014 0.5500000000000003
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7.357141885082921
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.357141885082921
# Control only changes marginally.
# RUN  1 , total integrated cost =  7.357141885082921
# Improved over  1  iterations in  0.10157345100014936  seconds by  0.0  percent.
# converged for  38
# --------------- 16
# -------  38 0.47500000000000014 0.5500000000000003
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7.357141885082921
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.357141885082921
# Control only changes marginally.
# RUN  1 , total integrated cost =  7.357141885082921
# Improved over  1  iterations in  0.09308591400258592  seconds by  0.0  percent.
# converged for  38
# --------------- 17
# -------  38 0.47500000000000014 0.5500000000000003
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7.357141885082921
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.357141885082921
# Control only changes marginally.
# RUN  1 , total integrated cost =  7.357141885082921
# Improved over  1  iterations in  0.09760845699929632  seconds by  0.0  percent.
# converged for  38
# --------------- 18
# -------  38 0.47500000000000014 0.5500000000000003
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7.357141885082921
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.357141885082921
# Control only changes marginally.
# RUN  1 , total integrated cost =  7.357141885082921
# Improved over  1  iterations in  0.09523521099981735  seconds by  0.0  percent.
# converged for  38
# --------------- 19
# -------  38 0.47500000000000014 0.5500000000000003
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7.357141885082921
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.357141885082921
# Control only changes marginally.
# RUN  1 , total integrated cost =  7.357141885082921
# Improved over  1  iterations in  0.09606288700160803  seconds by  0.0  percent.
# converged for  38
# --------------- 20
# -------  38 0.47500000000000014 0.5500000000000003
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7.357141885082921
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.357141885082921
# Control only changes marginally.
# RUN  1 , total integrated cost =  7.357141885082921
# Improved over  1  iterations in  0.09600792199853458  seconds by  0.0  percent.
# converged for  38
# --------------- 21

# %%
for i in i_range_1:
    print("---------", i)
        
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.

    plotFunc.plot_control_current(aln, [bestControl_1[i]],
        [costnode_1[i]], [weights_1[i]], dur,
        dur_pre, dur_post, initVars[i], target[i], '', filename_ = '', transition_time_ = trans_time,
        labels_ = ["init", "sparse control" + str(i)], print_cost_ = False)
    plt.show()
# Out:
# --------- 38
