# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import sys
import pickle

path = os.getcwd().split(os.sep + 'GUI')[0]
if path not in sys.path:
    print("not here")
    sys.path.append(path)

from neurolib.models.aln import ALNModel
from neurolib.utils import plotFunctions as plotFunc
from neurolib.utils import costFunctions as cost
import neurolib.dashboard.functions as functions
import neurolib.dashboard.data as data
    
# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2 

#path = os.path.join(os.getcwd(), "plots")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# read case
print(os.getcwd())
case = os.getcwd().split(os.sep)[-1]
print(case)
# Out:
# /home/lena/Promotion/neurolib/GUI/current/gui/data/01110
# 01110

# %% [markdown]
# ### Bistability

# %%
aln = ALNModel()
N = aln.params.N

data.set_parameters(aln)

state_vars = aln.state_vars
init_vars = aln.init_vars

##############################################################
def setinit(init_vars_, model):
    state_vars = model.state_vars
    init_vars = model.init_vars
    for iv in range(len(init_vars)):
        for sv in range(len(state_vars)):
            if state_vars[sv] in init_vars[iv]:
                #print("set init vars ", )
                if model.params[init_vars[iv]].ndim == 2:
                    model.params[init_vars[iv]][0,:] = init_vars_[sv]
                else:
                    model.params[init_vars[iv]][0] = init_vars_[sv]
                    
##############################################################               
def setmaxmincontrol(max_c_c, min_c_c, max_c_r, min_c_r):
    import numpy as np
    
    max_cntrl = np.zeros(( 6 ))
    min_cntrl = np.zeros(( 6 ))
    
    max_cntrl[0] = max_c_c
    min_cntrl[0] = min_c_c
    max_cntrl[1] = max_c_c
    min_cntrl[1] = min_c_c
    max_cntrl[2] = max_c_r
    min_cntrl[2] = min_c_r
    max_cntrl[3] = max_c_r
    min_cntrl[3] = min_c_r
    max_cntrl[4] = max_c_r
    min_cntrl[4] = min_c_r
    max_cntrl[5] = max_c_r
    min_cntrl[5] = min_c_r
            
    return max_cntrl, min_cntrl

#####################################################
def getclosest(k_, found_solution, exc, inh, already_tried_):
    import numpy as np
    if len(found_solution) == 0:
        print("no solutions found")
        return -1
    
    start_ind = -1
    for j_ in found_solution:
        if j_ not in already_tried_ and j_ != k_:
            start_ind = j_
            break
            
    if start_ind == -1:
        return -1
        
    min_dist = np.sqrt((exc[k_] - exc[start_ind])**2 + (inh[k_] - inh[start_ind])**2)
    min_i = start_ind
        
    print(found_solution, already_tried_)
        
    if len(found_solution) == len(already_tried_):
        print("already tried all options")
        min_i = -1
        return min_i
    
    for i_ in found_solution:
        if i_ not in already_tried_:
            if i_ != k_ and i_ != min_i:
                dist_ = np.sqrt((exc[k_] - exc[i_])**2 + (inh[k_] - inh[i_])**2)
                if dist_ < min_dist:
                    min_dist = dist_
                    min_i = i_
                    
    if min_i == 0 and 0 in already_tried_:
        return -1
    
    return min_i

# %%
##### LOAD BOUNDARIES
data_file = 'bi.pickle'
with open(data_file,'rb') as f:
    load_array= pickle.load(f)
exc = load_array[0]
inh = load_array[1]
print(len(exc))
#plt.scatter(exc, inh)
# Out:
# 147

# %%
bestControl_init = [None] * len(exc)
bestState_init = [None] * len(exc)
cost_init = [None] * len(exc)
runtime_init = [None] * len(exc)
grad_init = [None] * len(exc)
phi_init = [None] * len(exc)
costnode_init = [None] * len(exc)
weights_init = [None] * len(exc)

conv_init = [[False]*2] * len(exc)

# %%
bestControl_0 = [None] * len(exc)
bestState_0 = [None] * len(exc)
cost_0 = [None] * len(exc)
runtime_0 = [None] * len(exc)
grad_0 = [None] * len(exc)
phi_0 = [None] * len(exc)
costnode_0 = [None] * len(exc)
weights_0 = [None] * len(exc)

conv_0 = [[False]*2] * len(exc)

# %%
bestControl_1 = [None] * len(exc)
bestState_1 = [None] * len(exc)
cost_1 = [None] * len(exc)
runtime_1 = [None] * len(exc)
grad_1 = [None] * len(exc)
phi_1 = [None] * len(exc)
costnode_1 = [None] * len(exc)
weights_1 = [None] * len(exc)

conv_1 = [[False]*2] * len(exc)

# %%
initVars = [None] * len(exc)
target = [None] * len(exc)
cost_uncontrolled = [None] * len(exc)

cgv_list = [None, "HS", "FR", "PR", "CD", "LS", "DY", "WYL", "HZ", None]

# %%
dur_pre = 10
dur_post = 10

n_pre = int(np.around(dur_pre/aln.params.dt + 1.,1))
n_post = int(np.around(dur_post/aln.params.dt + 1.,1))

tol = 1e-32
start_step = 10.
c_scheme = np.zeros(( 1,1 ))
c_scheme[0,0] = 1.
u_mat = np.identity(1)
u_scheme = np.array([[1.]])

c_var = [ [0], [1], [0,1]]
p_var = [ [0], [0], [0]]

### CURRENTS
cntrl_vars_0 = [0,1]
prec_vars = [0]

if case[0] == '0':    # low to high
    max_I = [3., -3.]
elif case[0] == '1':
    max_I = [-3., 3.]
    
if case[1] == '0':    # sparsity
    factor_ws = 1.
    factor_we = 0.
elif case[1] == '1':  # energy
    factor_ws = 0.
    factor_we = 1.
    
if case[3] == '0':
    cntrl_vars_init = [0]
elif case[3] == '1':
    cntrl_vars_init = [1]
elif case[3] == '2':
    cntrl_vars_init = [0,1]

if case[4] == '0':
    dur = 100
    trans_time = 0.8
elif case[4] == '1':
    dur = 400
    trans_time = 0.95
    
maxC = [5., -5., 0.18, 0.]

n_dur = int(np.around(dur/aln.params.dt + 1.,1))
max_cntrl, min_cntrl = setmaxmincontrol(maxC[0], maxC[1], maxC[2], maxC[3])

# %%
init_file = 'control_init_' + case + '.pickle'
final_file = 'control_' + case + '.pickle'
case_1 = case[0] + case[1] + '0' + case[3] + case[4]
final_file_1 = 'control_' + case_1 + '.pickle'

# %%
if os.path.isfile(init_file) :
    print("file found")
    
    with open(init_file,'rb') as f:
        load_array = pickle.load(f)

    bestControl_init = load_array[0]
    bestState_init = load_array[1]
    cost_init = load_array[2]
    runtime_init = load_array[3]
    grad_init = load_array[4]
    phi_init = load_array[5]
    costnode_init = load_array[6]
    weights_init = load_array[7]
# Out:
# file found

# %%
# get initial parameters and target states

i_stepsize = 1
limit = 65
start_index = 60
i_range = range(start_index, limit,i_stepsize)
i_range_0 = range(start_index, limit,i_stepsize)
i_range_1 = range(start_index, limit,i_stepsize)

data.set_parameters(aln)

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    aln.params.duration = 3000.
    
    control0 = aln.getZeroControl()
    control0 = functions.step_control(aln, maxI_ = max_I[0])

    aln.run(control=control0)
    
    target_rates = np.zeros((2))
    target_rates[0] = aln.rates_exc[0,-1] 
    target_rates[1] = aln.rates_inh[0,-1]

    control0 = functions.step_control(aln, maxI_ = max_I[1])
    aln.run(control=control0)

    init_state_vars = np.zeros(( len(state_vars) ))
    for j in range(len(state_vars)):
        if aln.state[state_vars[j]].size == 1:
            init_state_vars[j] = aln.state[state_vars[j]][0]
        else:
            init_state_vars[j] = aln.state[state_vars[j]][0,-1]

    initVars[i] = init_state_vars
    
    aln.params.duration = dur

    target[i] = aln.getZeroTarget()
    target[i][:,0,:] = target_rates[0]
    target[i][:,1,:] = target_rates[1]
# Out:
# -------  60 0.5500000000000003 0.6250000000000003
# -------  61 0.5750000000000002 0.6250000000000003
# -------  62 0.4250000000000001 0.6500000000000004
# -------  63 0.4500000000000001 0.6500000000000004
# -------  64 0.47500000000000014 0.6500000000000004

# %%
# get uncontrolled cost

data.set_parameters(aln)

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    aln.params.duration = dur
        
    cost.setParams(1.0, 0.0, 0.0)

##### zero control as input for uncontrolled cost
    setinit(initVars[i], aln)
    control0 = aln.getZeroControl()

    # "HS", "FR", "PR", "HZ"
    cgv = None
    max_it = 0

    bestControl_init_, bestState_init_, cost_init_, runtime_init_, grad_init_, phi_init_, costnode_init_ = aln.A1(
        control0, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cntrl_vars_init,
        prec_variables_ = prec_vars, transition_time_ = trans_time)
    
    cost_uncontrolled[i] = cost_init_[0]
# Out:
# -------  60 0.5500000000000003 0.6250000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  148385.25117022273
# Gradient descend method:  None
# RUN  0 , total integrated cost =  148385.25117022273
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  61 0.5750000000000002 0.6250000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  173480.81674342768
# Gradient descend method:  None
# RUN  0 , total integrated cost =  173480.81674342768
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  62 0.4250000000000001 0.6500000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  34493.011682862874
# Gradient descend method:  None
# RUN  0 , total integrated cost =  34493.011682862874
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  63 0.4500000000000001 0.6500000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  56116.53685480664
# Gradient descend method:  None
# RUN  0 , total integrated cost =  56116.53685480664
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  64 0.47500000000000014 0.6500000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  77654.01745288723
# Gradient descend method:  None
# RUN  0 , total integrated cost =  77654.01745288723
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.

# %%
factor_iteration = 20.

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    aln.params.duration = dur
        
##### zero control as input for uncontrolled cost
    setinit(initVars[i], aln)
    
    if not type(bestControl_init[i]) == type(None):
        continue
        
    control0 = aln.getZeroControl()

    ##### initial guess
    weight_ = 10
    cost.setParams(1.0, weight_ * factor_we, weight_ * factor_ws)

    setinit(initVars[i], aln)

    # "HS", "FR", "PR", "HZ"
    cgv = None
    max_it = int(100 * factor_iteration)

    weights_init[i] = cost.getParams()

    bestControl_init[i], bestState_init[i], cost_init[i], runtime_init[i], grad_init[i], phi_init[i], costnode_init[i] = aln.A1(
        control0, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cntrl_vars_init,
        prec_variables_ = prec_vars, transition_time_ = trans_time)
    
    j = 1
    while cost_init[i][-j] == 0.:
        j += 1
    
    weight_ = 10 * cost_uncontrolled[i] / cost_init[i][-j]
    print("weight = ", weight_)
    cost.setParams(1.0, weight_ * factor_we, weight_ * factor_ws)

    setinit(initVars[i], aln)
    control0 = bestControl_init[i][:,:,n_pre-1:-n_post+1]

    # "HS", "FR", "PR", "HZ"
    cgv = None
    max_it = int(500 * factor_iteration)

    weights_init[i] = cost.getParams()
    
    bestControl_init[i], bestState_init[i], cost_init[i], runtime_init[i], grad_init[i], phi_init[i], costnode_init[i] = aln.A1(
        control0, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cntrl_vars_init,
        prec_variables_ = prec_vars, transition_time_ = trans_time)
        
    with open(init_file,'wb') as f:
        pickle.dump([bestControl_init, bestState_init, cost_init, runtime_init, grad_init, phi_init,
                 costnode_init, weights_init], f)
# Out:
# -------  60 0.5500000000000003 0.6250000000000003
# -------  61 0.5750000000000002 0.6250000000000003
# set cost params:  1.0 10.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  173480.81674342768
# Gradient descend method:  None
# RUN  1 , total integrated cost =  594.5096121606321
# RUN  2 , total integrated cost =  422.2310040346942
# RUN  3 , total integrated cost =  151.5472393663112
# RUN  4 , total integrated cost =  149.87054575682868
# RUN  5 , total integrated cost =  149.86156675765142
# RUN  6 , total integrated cost =  149.86152156297413
# RUN  7 , total integrated cost =  149.8615208626995
# RUN  8 , total integrated cost =  149.8615208304193
# RUN  9 , total integrated cost =  149.8615208285558
# RUN  10 , total integrated cost =  149.86152082847494
# RUN  11 , total integrated cost =  149.86152082847346
# RUN  12 , total integrated cost =  149.8615208284734
# RUN  13 , total integrated cost =  149.86152082847335
# RUN  14 , total integrated cost =  149.86152082847332
# RUN  15 , total integrated cost =  149.8615208284733
# RUN  16 , total integrated cost =  149.8615208284733
# Control only changes marginally.
# RUN  16 , total integrated cost =  149.8615208284733
# Improved over  16  iterations in  0.2274503749795258  seconds by  99.9136149323933  percent.
# weight =  11576.074751168999
# set cost params:  1.0 11576.074751168999 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  166049.71075846461
# Gradient descend method:  None
# RUN  1 , total integrated cost =  120715.81720474293
# RUN  2 , total integrated cost =  120319.73841392258
# RUN  3 , total integrated cost =  120318.88054589293
# RUN  4 , total integrated cost =  120318.87953104818
# RUN  5 , total integrated cost =  120318.87938905224
# RUN  6 , total integrated cost =  120318.8793873794
# RUN  7 , total integrated cost =  120318.87938737091
# RUN  8 , total integrated cost =  120318.87938737066
# RUN  9 , total integrated cost =  120318.8793873706
# RUN  10 , total integrated cost =  120318.87938737057
# RUN  11 , total integrated cost =  120318.87938737056
# RUN  12 , total integrated cost =  120318.87938737056
# Control only changes marginally.
# RUN  12 , total integrated cost =  120318.87938737056
# Improved over  12  iterations in  0.25609119702130556  seconds by  27.540446268897128  percent.
# -------  62 0.4250000000000001 0.6500000000000004
# set cost params:  1.0 10.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  34493.011682862874
# Gradient descend method:  None
# RUN  1 , total integrated cost =  34493.011682862874
# Control only changes marginally.
# RUN  1 , total integrated cost =  34493.011682862874
# Improved over  1  iterations in  0.04698605398880318  seconds by  0.0  percent.
# weight =  10.0
# set cost params:  1.0 10.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  34493.011682862874
# Gradient descend method:  None
# RUN  1 , total integrated cost =  34493.011682862874
# Control only changes marginally.
# RUN  1 , total integrated cost =  34493.011682862874
# Improved over  1  iterations in  0.04141059500398114  seconds by  0.0  percent.
# -------  63 0.4500000000000001 0.6500000000000004
# set cost params:  1.0 10.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  56116.53685480664
# Gradient descend method:  None
# RUN  1 , total integrated cost =  56116.53685480627
# RUN  2 , total integrated cost =  56116.53685480626
# RUN  3 , total integrated cost =  56116.53685480626
# Control only changes marginally.
# RUN  3 , total integrated cost =  56116.53685480626
# Improved over  3  iterations in  0.139414077042602  seconds by  6.821210263296962e-13  percent.
# weight =  10.000000000000068
# set cost params:  1.0 10.000000000000068 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  56116.53685480626
# Gradient descend method:  None
# RUN  1 , total integrated cost =  56116.53685480626
# Control only changes marginally.
# RUN  1 , total integrated cost =  56116.53685480626
# Improved over  1  iterations in  0.06800985801964998  seconds by  0.0  percent.
# -------  64 0.47500000000000014 0.6500000000000004
# set cost params:  1.0 10.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  77654.01745288723
# Gradient descend method:  None
# RUN  1 , total integrated cost =  77654.01745275361
# RUN  2 , total integrated cost =  77654.01745275361
# Control only changes marginally.
# RUN  2 , total integrated cost =  77654.01745275361
# Improved over  2  iterations in  0.09994018101133406  seconds by  1.7206502889166586e-10  percent.
# weight =  10.000000000017208
# set cost params:  1.0 10.000000000017208 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  77654.01745275361
# Gradient descend method:  None
# RUN  1 , total integrated cost =  77654.01745275361
# Control only changes marginally.
# RUN  1 , total integrated cost =  77654.01745275361
# Improved over  1  iterations in  0.0809508350212127  seconds by  0.0  percent.

# %%
#plot initial guesses
for i in i_range:
    print("---------", i)
        
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.

    plotFunc.plot_control_current(aln, [bestControl_init[i]],
        [costnode_init[i]], [weights_init[i]], dur,
        dur_pre, dur_post, initVars[i], target[i], '', filename_ = '', transition_time_ = trans_time,
        labels_ = ["init", "sparse control" + str(i)], print_cost_ = False)
    plt.show()
# Out:
# --------- 60
# --------- 61
# --------- 62
# --------- 63
# --------- 64

# %%
found_solution = []
no_solution = []
factor_iteration = 1.
already_tried = [ [] for _ in range(len(exc)) ]

for k in range(len(i_range)**2):
    print('------------------------------------------------------------')
    print('--------------------', k)
    print('------------------------------------------------------------')
        
    print("found solution: ", found_solution)
    print("no solution: ", no_solution)
    
    if len(i_range) == len(found_solution) + len(no_solution):
        print("found solution for all parameters")
        break


    for i in i_range:
        print("------- ", i, exc[i], inh[i])     

        if np.abs(np.mean(bestState_init[i][0,0,-10:]) - target[i][0,0,-1]) < 0.2 * np.abs(
            np.mean(bestState_init[i][0,0,-10:]) - bestState_init[i][0,0,0]) and np.abs(
            np.mean(bestState_init[i][0,1,-10:]) - target[i][0,1,-1]) < 0.2 * np.abs(
            np.mean(bestState_init[i][0,1,-10:]) - bestState_init[i][0,1,0]) and np.amax(
            bestState_init[i][0,0,:]) < target[i][0,0,-1] + 1. and np.amax(
            bestState_init[i][0,1,:]) < target[i][0,1,-1] + 1.:
            # and np.amin(bestState_init[i][0,0,:]) > bestState_init[i][0,0,0] - 1.
            #and np.amin(bestState_init[i][0,1,:]) > bestState_init[i][0,1,0] - 1.:
            if i not in found_solution:
                print("found solution for ", i)
                found_solution.append(i)
            if i in no_solution:
                no_solution.pop(no_solution.index(i))
            continue

        if len(found_solution) == 0:
            continue
            
        closest_ = getclosest(i, found_solution, exc, inh, already_tried[i])
        print("closest index ", closest_)

        weight_ = 10
        cost.setParams(1.0, weight_ * factor_we, weight_ * factor_ws)

        setinit(initVars[i], aln)
        aln.params.ext_exc_current = exc[i] * 5.
        aln.params.ext_inh_current = inh[i] * 5.
            
        if i != 0 and closest_ != -1:
            control0 = 2. * bestControl_init[closest_][:,:,n_pre-1:-n_post+1]
            if closest_ not in already_tried[i]:
                already_tried[i].append(closest_)
                        
        if closest_ == -1:
            print("all options tried already")
            if i not in no_solution:
                no_solution.append(i)
                continue

        # "HS", "FR", "PR", "HZ"
        cgv = None
        max_it = int(100 * factor_iteration)

        weights_init[i] = cost.getParams()
        
        print("precision vars = ", prec_vars)

        bestControl_init[i], bestState_init[i], cost_init[i], runtime_init[i], grad_init[i], phi_init[i], costnode_init[i] = aln.A1(
            control0, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cntrl_vars_init,
            prec_variables_ = prec_vars, transition_time_ = trans_time)

        j = 1
        while cost_init[i][-j] == 0.:
            j += 1

        weight_ = 10 * cost_uncontrolled[i] / cost_init[i][-j]
        print("weight = ", weight_)
        cost.setParams(1.0, weight_ * factor_we, weight_ * factor_ws)

        setinit(initVars[i], aln)
        control0 = bestControl_init[i][:,:,n_pre-1:-n_post+1]

        # "HS", "FR", "PR", "HZ"
        cgv = None
        max_it = int(500 * factor_iteration)

        weights_init[i] = cost.getParams()

        bestControl_init[i], bestState_init[i], cost_init[i], runtime_init[i], grad_init[i], phi_init[i], costnode_init[i] = aln.A1(
            control0, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cntrl_vars_init,
            prec_variables_ = prec_vars, transition_time_ = trans_time)
        
        with open(init_file,'wb') as f:
            pickle.dump([bestControl_init, bestState_init, cost_init, runtime_init, grad_init, phi_init,
                         costnode_init, weights_init], f)
# Out:
# ------------------------------------------------------------
# -------------------- 0
# ------------------------------------------------------------
# found solution:  []
# no solution:  []
# -------  60 0.5500000000000003 0.6250000000000003
# found solution for  60
# -------  61 0.5750000000000002 0.6250000000000003
# found solution for  61
# -------  62 0.4250000000000001 0.6500000000000004
# [60, 61] []
# closest index  60
# set cost params:  1.0 10.0 0.0
# precision vars =  [0]
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  34931.080318478096
# Gradient descend method:  None
# RUN  1 , total integrated cost =  34493.738825526736
# RUN  2 , total integrated cost =  34493.01186038811
# RUN  3 , total integrated cost =  34493.01168290622
# RUN  4 , total integrated cost =  34493.01168286288
# RUN  5 , total integrated cost =  34493.011682862874
# RUN  6 , total integrated cost =  34493.011682862874
# Control only changes marginally.
# RUN  6 , total integrated cost =  34493.011682862874
# Improved over  6  iterations in  0.14116866001859307  seconds by  1.2540941523170943  percent.
# weight =  10.0
# set cost params:  1.0 10.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  34493.011682862874
# Gradient descend method:  None
# RUN  1 , total integrated cost =  34493.011682862874
# Control only changes marginally.
# RUN  1 , total integrated cost =  34493.011682862874
# Improved over  1  iterations in  0.040509485988877714  seconds by  0.0  percent.
# -------  63 0.4500000000000001 0.6500000000000004
# [60, 61] []
# closest index  60
# set cost params:  1.0 10.0 0.0
# precision vars =  [0]
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  40199.53807981598
# Gradient descend method:  None
# RUN  1 , total integrated cost =  570.998425426173
# RUN  2 , total integrated cost =  569.8060787536743
# RUN  3 , total integrated cost =  569.7788880650821
# RUN  4 , total integrated cost =  569.7782370220032
# RUN  5 , total integrated cost =  569.7782082006373
# RUN  6 , total integrated cost =  569.7782071365779
# RUN  7 , total integrated cost =  569.778207081946
# RUN  8 , total integrated cost =  569.778207079198
# RUN  9 , total integrated cost =  569.7782070790626
# RUN  10 , total integrated cost =  569.7782070790562
# RUN  11 , total integrated cost =  569.7782070790553
# RUN  12 , total integrated cost =  569.7782070790539
# RUN  13 , total integrated cost =  569.7782070790537
# RUN  14 , total integrated cost =  569.7782070790533
# RUN  15 , total integrated cost =  569.7782070790533
# Control only changes marginally.
# RUN  15 , total integrated cost =  569.7782070790533
# Improved over  15  iterations in  0.32191890402464196  seconds by  98.58262498950171  percent.
# weight =  984.88387512197
# set cost params:  1.0 984.88387512197 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  54877.79476876646
# Gradient descend method:  None
# RUN  1 , total integrated cost =  48441.29561428678
# RUN  2 , total integrated cost =  48441.29561428678
# Control only changes marginally.
# RUN  2 , total integrated cost =  48441.29561428678
# Improved over  2  iterations in  0.09449926199158654  seconds by  11.728786081147334  percent.
# -------  64 0.47500000000000014 0.6500000000000004
# [60, 61] []
# closest index  60
# set cost params:  1.0 10.0 0.0
# precision vars =  [0]
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  460.85211167716807
# Gradient descend method:  None
# RUN  1 , total integrated cost =  460.7594340427225
# RUN  2 , total integrated cost =  460.75691575794514
# RUN  3 , total integrated cost =  460.75685500281287
# RUN  4 , total integrated cost =  460.7568501265849
# RUN  5 , total integrated cost =  460.7568499548179
# RUN  6 , total integrated cost =  460.7568499525562
# RUN  7 , total integrated cost =  460.75684995247707
# RUN  8 , total integrated cost =  460.7568499524742
# RUN  9 , total integrated cost =  460.7568499524736
# RUN  10 , total integrated cost =  460.7568499524735
# RUN  11 , total integrated cost =  460.7568499524734
# RUN  12 , total integrated cost =  460.7568499524733
# State only changes marginally.
# RUN  13 , total integrated cost =  460.75684995247326
# RUN  14 , total integrated cost =  460.75684995247326
# Control only changes marginally.
# RUN  14 , total integrated cost =  460.75684995247326
# Improved over  14  iterations in  0.3490940000046976  seconds by  0.020670779688543917  percent.
# weight =  1685.3578511290107
# set cost params:  1.0 1685.3578511290107 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  74839.06712925411
# Gradient descend method:  None
# RUN  1 , total integrated cost =  63786.2876114169
# RUN  2 , total integrated cost =  63786.28761141685
# RUN  3 , total integrated cost =  63786.28761141685
# Control only changes marginally.
# RUN  3 , total integrated cost =  63786.28761141685
# Improved over  3  iterations in  0.18100214301375672  seconds by  14.768729677974306  percent.
# ------------------------------------------------------------
# -------------------- 1
# ------------------------------------------------------------
# found solution:  [60, 61]
# no solution:  []
# -------  60 0.5500000000000003 0.6250000000000003
# -------  61 0.5750000000000002 0.6250000000000003
# -------  62 0.4250000000000001 0.6500000000000004
# [60, 61] [60]
# closest index  61
# set cost params:  1.0 10.0 0.0
# precision vars =  [0]
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  34836.95774362883
# Gradient descend method:  None
# RUN  1 , total integrated cost =  34493.62701019142
# RUN  2 , total integrated cost =  755.1270657074991
# RUN  3 , total integrated cost =  674.8237784523955
# RUN  4 , total integrated cost =  674.8237470781536
# RUN  5 , total integrated cost =  674.8237460780283
# RUN  6 , total integrated cost =  674.8237460526958
# RUN  7 , total integrated cost =  674.8237460514775
# RUN  8 , total integrated cost =  674.8237460514395
# RUN  9 , total integrated cost =  674.8237460514373
# RUN  10 , total integrated cost =  674.8237460514371
# RUN  11 , total integrated cost =  674.823746051437
# RUN  12 , total integrated cost =  674.8237460514364
# RUN  13 , total integrated cost =  674.8237460514364
# Control only changes marginally.
# RUN  13 , total integrated cost =  674.8237460514364
# Improved over  13  iterations in  0.3039171440177597  seconds by  98.06290850361395  percent.
# weight =  511.14104808389106
# set cost params:  1.0 511.14104808389106 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  33696.29179176714
# Gradient descend method:  None
# RUN  1 , total integrated cost =  32731.731222250673
# RUN  2 , total integrated cost =  32731.731222250663
# RUN  3 , total integrated cost =  32731.73122225065
# RUN  4 , total integrated cost =  32731.731222250644
# RUN  5 , total integrated cost =  32731.731222250644
# Control only changes marginally.
# RUN  5 , total integrated cost =  32731.731222250644
# Improved over  5  iterations in  0.2361204299959354  seconds by  2.8625125146623986  percent.
# -------  63 0.4500000000000001 0.6500000000000004
# found solution for  63
# -------  64 0.47500000000000014 0.6500000000000004
# found solution for  64
# ------------------------------------------------------------
# -------------------- 2
# ------------------------------------------------------------
# found solution:  [60, 61, 63, 64]
# no solution:  []
# -------  60 0.5500000000000003 0.6250000000000003
# -------  61 0.5750000000000002 0.6250000000000003
# -------  62 0.4250000000000001 0.6500000000000004
# [60, 61, 63, 64] [60, 61]
# closest index  63
# set cost params:  1.0 10.0 0.0
# precision vars =  [0]
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  2374.2522589249065
# Gradient descend method:  None
# RUN  1 , total integrated cost =  676.2778406252445
# RUN  2 , total integrated cost =  744.7182302694378
# RUN  3 , total integrated cost =  744.4661084058695
# RUN  4 , total integrated cost =  744.3832428899073
# RUN  5 , total integrated cost =  744.3336067541148
# RUN  6 , total integrated cost =  744.3026348968252
# RUN  7 , total integrated cost =  744.261607934819
# RUN  8 , total integrated cost =  744.2210957956357
# RUN  9 , total integrated cost =  744.1352213881352
# RUN  10 , total integrated cost =  743.8776813767344
# RUN  11 , total integrated cost =  741.2478691445717
# RUN  12 , total integrated cost =  511.1083408440013
# RUN  13 , total integrated cost =  511.1083408440013
# Control only changes marginally.
# RUN  13 , total integrated cost =  511.1083408440013
# Improved over  13  iterations in  0.2987817300017923  seconds by  78.47287124092543  percent.
# weight =  674.866929894042
# set cost params:  1.0 674.866929894042 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  34361.20067041861
# Gradient descend method:  None
# RUN  1 , total integrated cost =  33288.9864746117
# RUN  2 , total integrated cost =  33288.98647461165
# RUN  3 , total integrated cost =  33288.98647461165
# Control only changes marginally.
# RUN  3 , total integrated cost =  33288.98647461165
# Improved over  3  iterations in  0.149216634046752  seconds by  3.120421216043326  percent.
# -------  63 0.4500000000000001 0.6500000000000004
# -------  64 0.47500000000000014 0.6500000000000004
# ------------------------------------------------------------
# -------------------- 3
# ------------------------------------------------------------
# found solution:  [60, 61, 63, 64]
# no solution:  []
# -------  60 0.5500000000000003 0.6250000000000003
# -------  61 0.5750000000000002 0.6250000000000003
# -------  62 0.4250000000000001 0.6500000000000004
# found solution for  62
# -------  63 0.4500000000000001 0.6500000000000004
# -------  64 0.47500000000000014 0.6500000000000004
# ------------------------------------------------------------
# -------------------- 4
# ------------------------------------------------------------
# found solution:  [60, 61, 63, 64, 62]
# no solution:  []
# found solution for all parameters

# %%
factor_iteration = 20
full_converge = False
conv_init = [[False]*2] * len(exc)

for i in range(len(conv_init)):
    if i not in i_range:
        conv_init[i] = [True, True]
        
counter = 0

while full_converge == False:
    
    print("------------------------------------------------")
    print('-------------------------', counter)
    
    if counter > 20:
        break
        
    print(conv_init[::i_stepsize])
    full_converge = True
    
    for conv in conv_init[::i_stepsize]:
        if not conv[0]:
            full_converge = False
            break
        if not conv[1]:
            full_converge = False
            break
    
    if full_converge:
        print("full convergence")
        break

    for i in i_range:        

        print("------- ", i, exc[i], inh[i])
        
        if conv_init[i] == [True, True]:
            continue
        aln.params.ext_exc_current = exc[i] * 5.
        aln.params.ext_inh_current = inh[i] * 5.
        
        j = 1
        while cost_init[i][-j] == 0.:
            j += 1
                       
        weight_ = (factor_we * weights_init[i][1] * cost_uncontrolled[i] / cost_init[i][-j]
                   + factor_ws * weights_init[i][2] * cost_uncontrolled[i] / cost_init[i][-j]) - 1
        print("weight = ", weight_)
        cost.setParams(1.0, weight_ * factor_we, weight_ * factor_ws)

        setinit(initVars[i], aln)
        control0 = bestControl_init[i][:,:,n_pre-1:-n_post+1]

        # "HS", "FR", "PR", "HZ"
        cgv = None
        max_it = int( 500 * factor_iteration )

        weights_init[i] = cost.getParams()

        bestControl_init[i], bestState_init[i], cost_init[i], runtime_init[i], grad_init[i], phi_init[i], costnode_init[i] = aln.A1(
            control0, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cntrl_vars_init,
            prec_variables_ = prec_vars, transition_time_ = trans_time)
        
        with open(init_file,'wb') as f:
            pickle.dump([bestControl_init, bestState_init, cost_init, runtime_init, grad_init, phi_init,
                         costnode_init, weights_init], f)
            
        if j == cost_init[i].shape[0]-1:
            print("converged for ", i)
            if conv_init[i][0]:
                conv_init[i] = [True, True]
            else:
                conv_init[i] = [True, False]
            continue
    
        print("no convergence")
            
    counter += 1
# Out:
# ------------------------------------------------
# ------------------------- 0
# [[True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [False, False], [False, False], [False, False], [False, False], [False, False], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# -------  60 0.5500000000000003 0.6250000000000003
# weight =  12804.0120257955
# set cost params:  1.0 12804.0120257955 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  148373.66302172755
# Gradient descend method:  None
# RUN  1 , total integrated cost =  148373.66302172755
# Control only changes marginally.
# RUN  1 , total integrated cost =  148373.66302172755
# Improved over  1  iterations in  0.0579980059992522  seconds by  0.0  percent.
# converged for  60
# -------  61 0.5750000000000002 0.6250000000000003
# weight =  17410.597032544985
# set cost params:  1.0 17410.597032544985 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  173470.85298987883
# Gradient descend method:  None
# RUN  1 , total integrated cost =  173470.85298987883
# Control only changes marginally.
# RUN  1 , total integrated cost =  173470.85298987883
# Improved over  1  iterations in  0.05799702898366377  seconds by  0.0  percent.
# no convergence
# -------  62 0.4250000000000001 0.6500000000000004
# weight =  698.2761078792968
# set cost params:  1.0 698.2761078792968 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  34426.427114473016
# Gradient descend method:  None
# RUN  1 , total integrated cost =  34426.41171712159
# RUN  2 , total integrated cost =  34426.41171696741
# RUN  3 , total integrated cost =  34426.411716967166
# RUN  4 , total integrated cost =  34426.41171696713
# RUN  5 , total integrated cost =  34426.41171696713
# Control only changes marginally.
# RUN  5 , total integrated cost =  34426.41171696713
# Improved over  5  iterations in  0.1672025690204464  seconds by  4.472583179904177e-05  percent.
# no convergence
# -------  63 0.4500000000000001 0.6500000000000004
# weight =  1139.9329906462401
# set cost params:  1.0 1139.9329906462401 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  55712.93053045163
# Gradient descend method:  None
# RUN  1 , total integrated cost =  55710.55476055394
# RUN  2 , total integrated cost =  55710.51428494085
# RUN  3 , total integrated cost =  55710.51356144497
# RUN  4 , total integrated cost =  55710.51355084982
# RUN  5 , total integrated cost =  55710.513550662894
# RUN  6 , total integrated cost =  55710.513550660886
# RUN  7 , total integrated cost =  55710.51355066084
# RUN  8 , total integrated cost =  55710.513550660806
# RUN  9 , total integrated cost =  55710.513550660784
# RUN  10 , total integrated cost =  55710.51355066076
# RUN  11 , total integrated cost =  55710.513550660755
# RUN  12 , total integrated cost =  55710.513550660755
# Control only changes marginally.
# RUN  12 , total integrated cost =  55710.513550660755
# Improved over  12  iterations in  0.29789971600985155  seconds by  0.004338274378795859  percent.
# no convergence
# -------  64 0.47500000000000014 0.6500000000000004
# weight =  2050.7702610820693
# set cost params:  1.0 2050.7702610820693 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  77034.7129131803
# Gradient descend method:  None
# RUN  1 , total integrated cost =  77010.03129171481
# RUN  2 , total integrated cost =  77009.97848328945
# RUN  3 , total integrated cost =  77009.97813629387
# RUN  4 , total integrated cost =  77009.97813500074
# RUN  5 , total integrated cost =  77009.97813498786
# RUN  6 , total integrated cost =  77009.9781349878
# RUN  7 , total integrated cost =  77009.97813498777
# RUN  8 , total integrated cost =  77009.97813498777
# Control only changes marginally.
# RUN  8 , total integrated cost =  77009.97813498777
# Improved over  8  iterations in  0.2252026839996688  seconds by  0.032108613451171664  percent.
# no convergence
# ------------------------------------------------
# ------------------------- 1
# [[True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, False], [False, False], [False, False], [False, False], [False, False], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# -------  60 0.5500000000000003 0.6250000000000003
# weight =  12804.012033409164
# set cost params:  1.0 12804.012033409164 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  148373.66310667433
# Gradient descend method:  None
# RUN  1 , total integrated cost =  148373.66310667433
# Control only changes marginally.
# RUN  1 , total integrated cost =  148373.66310667433
# Improved over  1  iterations in  0.07519479905022308  seconds by  0.0  percent.
# converged for  60
# -------  61 0.5750000000000002 0.6250000000000003
# weight =  17410.597055862912
# set cost params:  1.0 17410.597055862912 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  173470.8531948924
# Gradient descend method:  None
# RUN  1 , total integrated cost =  173470.8531948924
# Control only changes marginally.
# RUN  1 , total integrated cost =  173470.8531948924
# Improved over  1  iterations in  0.08212739496957511  seconds by  0.0  percent.
# converged for  61
# -------  62 0.4250000000000001 0.6500000000000004
# weight =  698.6269650453852
# set cost params:  1.0 698.6269650453852 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  34443.45757042899
# Gradient descend method:  None
# RUN  1 , total integrated cost =  34443.45750035162
# RUN  2 , total integrated cost =  34443.45750020914
# RUN  3 , total integrated cost =  34443.45750020906
# RUN  4 , total integrated cost =  34443.45750020904
# RUN  5 , total integrated cost =  34443.45750020903
# RUN  6 , total integrated cost =  34443.45750020903
# Control only changes marginally.
# RUN  6 , total integrated cost =  34443.45750020903
# Improved over  6  iterations in  0.25437533599324524  seconds by  2.0387024335377646e-07  percent.
# no convergence
# -------  63 0.4500000000000001 0.6500000000000004
# weight =  1147.2409262560277
# set cost params:  1.0 1147.2409262560277 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  56052.481822855974
# Gradient descend method:  None
# RUN  1 , total integrated cost =  56052.45333151683
# RUN  2 , total integrated cost =  56052.45316038552
# RUN  3 , total integrated cost =  56052.453157898184
# RUN  4 , total integrated cost =  56052.45315788431
# RUN  5 , total integrated cost =  56052.45315788395
# RUN  6 , total integrated cost =  56052.45315788388
# RUN  7 , total integrated cost =  56052.45315788388
# Control only changes marginally.
# RUN  7 , total integrated cost =  56052.45315788388
# Improved over  7  iterations in  0.3610168199520558  seconds by  5.11395234639167e-05  percent.
# no convergence
# -------  64 0.47500000000000014 0.6500000000000004
# weight =  2066.9209824834
# set cost params:  1.0 2066.9209824834 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  77592.36557320408
# Gradient descend method:  None
# RUN  1 , total integrated cost =  77592.29585477612
# RUN  2 , total integrated cost =  77592.295565835
# RUN  3 , total integrated cost =  77592.29556478458
# RUN  4 , total integrated cost =  77592.29556478094
# RUN  5 , total integrated cost =  77592.29556478093
# RUN  6 , total integrated cost =  77592.29556478091
# RUN  7 , total integrated cost =  77592.29556478084
# RUN  8 , total integrated cost =  77592.29556478083
# RUN  9 , total integrated cost =  77592.29556478081
# RUN  10 , total integrated cost =  77592.29556478078
# RUN  11 , total integrated cost =  77592.29556478078
# Control only changes marginally.
# RUN  11 , total integrated cost =  77592.29556478078
# Improved over  11  iterations in  0.34525394695810974  seconds by  9.02259169208719e-05  percent.
# no convergence
# ------------------------------------------------
# ------------------------- 2
# [[True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, False], [False, False], [False, False], [False, False], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# -------  60 0.5500000000000003 0.6250000000000003
# -------  61 0.5750000000000002 0.6250000000000003
# weight =  17410.59705860458
# set cost params:  1.0 17410.59705860458 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  173470.8532189975
# Gradient descend method:  None
# RUN  1 , total integrated cost =  173470.8532189975
# Control only changes marginally.
# RUN  1 , total integrated cost =  173470.8532189975
# Improved over  1  iterations in  0.07434867799747735  seconds by  0.0  percent.
# converged for  61
# -------  62 0.4250000000000001 0.6500000000000004
# weight =  698.6320873747144
# set cost params:  1.0 698.6320873747144 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  34443.70635850948
# Gradient descend method:  None
# RUN  1 , total integrated cost =  34443.70635849495
# RUN  2 , total integrated cost =  34443.70635849491
# RUN  3 , total integrated cost =  34443.7063584949
# RUN  4 , total integrated cost =  34443.70635849484
# RUN  5 , total integrated cost =  34443.70635849481
# RUN  6 , total integrated cost =  34443.70635849481
# Control only changes marginally.
# RUN  6 , total integrated cost =  34443.70635849481
# Improved over  6  iterations in  0.2378665340365842  seconds by  4.2589931581460405e-11  percent.
# no convergence
# -------  63 0.4500000000000001 0.6500000000000004
# weight =  1147.5525448502842
# set cost params:  1.0 1147.5525448502842 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  56067.03187608038
# Gradient descend method:  None
# RUN  1 , total integrated cost =  56067.03181238284
# RUN  2 , total integrated cost =  56067.03181145869
# RUN  3 , total integrated cost =  56067.03181145151
# RUN  4 , total integrated cost =  56067.03181145137
# RUN  5 , total integrated cost =  56067.03181145131
# RUN  6 , total integrated cost =  56067.03181145124
# RUN  7 , total integrated cost =  56067.03181145123
# RUN  8 , total integrated cost =  56067.03181145123
# Control only changes marginally.
# RUN  8 , total integrated cost =  56067.03181145123
# Improved over  8  iterations in  0.2919543180032633  seconds by  1.1527122012466862e-07  percent.
# no convergence
# -------  64 0.47500000000000014 0.6500000000000004
# weight =  2067.5651439903786
# set cost params:  1.0 2067.5651439903786 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  77615.5164682659
# Gradient descend method:  None
# RUN  1 , total integrated cost =  77615.51636577919
# RUN  2 , total integrated cost =  77615.51636561629
# RUN  3 , total integrated cost =  77615.51636561443
# RUN  4 , total integrated cost =  77615.51636561406
# RUN  5 , total integrated cost =  77615.51636561398
# RUN  6 , total integrated cost =  77615.51636561385
# RUN  7 , total integrated cost =  77615.51636561382
# RUN  8 , total integrated cost =  77615.51636561377
# RUN  9 , total integrated cost =  77615.51636561377
# Control only changes marginally.
# RUN  9 , total integrated cost =  77615.51636561377
# Improved over  9  iterations in  0.29630545899271965  seconds by  1.322572131812194e-07  percent.
# no convergence
# ------------------------------------------------
# ------------------------- 3
# [[True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [False, False], [False, False], [False, False], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# -------  60 0.5500000000000003 0.6250000000000003
# -------  61 0.5750000000000002 0.6250000000000003
# -------  62 0.4250000000000001 0.6500000000000004
# weight =  698.6321621437717
# set cost params:  1.0 698.6321621437717 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  34443.70999100204
# Gradient descend method:  None
# RUN  1 , total integrated cost =  34443.70999100203
# RUN  2 , total integrated cost =  34443.70999100201
# RUN  3 , total integrated cost =  34443.70999100201
# Control only changes marginally.
# RUN  3 , total integrated cost =  34443.70999100201
# Improved over  3  iterations in  0.15224710199981928  seconds by  8.526512829121202e-14  percent.
# no convergence
# -------  63 0.4500000000000001 0.6500000000000004
# weight =  1147.5657898295526
# set cost params:  1.0 1147.5657898295526 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  56067.65145556352
# Gradient descend method:  None
# RUN  1 , total integrated cost =  56067.651455445746
# RUN  2 , total integrated cost =  56067.65145544302
# RUN  3 , total integrated cost =  56067.651455443
# RUN  4 , total integrated cost =  56067.651455443
# Control only changes marginally.
# RUN  4 , total integrated cost =  56067.651455443
# Improved over  4  iterations in  0.1792281610541977  seconds by  2.149533884221455e-10  percent.
# no convergence
# -------  64 0.47500000000000014 0.6500000000000004
# weight =  2067.590757292716
# set cost params:  1.0 2067.590757292716 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  77616.43967130857
# Gradient descend method:  None
# RUN  1 , total integrated cost =  77616.43967130846
# RUN  2 , total integrated cost =  77616.43967130846
# Control only changes marginally.
# RUN  2 , total integrated cost =  77616.43967130846
# Improved over  2  iterations in  0.11910300597082824  seconds by  1.5631940186722204e-13  percent.
# no convergence
# ------------------------------------------------
# ------------------------- 4
# [[True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [False, False], [False, False], [False, False], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# -------  60 0.5500000000000003 0.6250000000000003
# -------  61 0.5750000000000002 0.6250000000000003
# -------  62 0.4250000000000001 0.6500000000000004
# weight =  698.6321632351494
# set cost params:  1.0 698.6321632351494 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  34443.710044024505
# Gradient descend method:  None
# RUN  1 , total integrated cost =  34443.71004402445
# RUN  2 , total integrated cost =  34443.710044024425
# RUN  3 , total integrated cost =  34443.710044024425
# Control only changes marginally.
# RUN  3 , total integrated cost =  34443.710044024425
# Improved over  3  iterations in  0.17122975399252027  seconds by  2.2737367544323206e-13  percent.
# no convergence
# -------  63 0.4500000000000001 0.6500000000000004
# weight =  1147.566352729471
# set cost params:  1.0 1147.566352729471 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  56067.67778975754
# Gradient descend method:  None
# RUN  1 , total integrated cost =  56067.67778975733
# RUN  2 , total integrated cost =  56067.677789757305
# RUN  3 , total integrated cost =  56067.6777897573
# RUN  4 , total integrated cost =  56067.6777897573
# Control only changes marginally.
# RUN  4 , total integrated cost =  56067.6777897573
# Improved over  4  iterations in  0.1875095730065368  seconds by  4.263256414560601e-13  percent.
# no convergence
# -------  64 0.47500000000000014 0.6500000000000004
# weight =  2067.5917755589603
# set cost params:  1.0 2067.5917755589603 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  77616.47637766562
# Gradient descend method:  None
# RUN  1 , total integrated cost =  77616.47637766557
# RUN  2 , total integrated cost =  77616.47637766556
# RUN  3 , total integrated cost =  77616.47637766552
# RUN  4 , total integrated cost =  77616.4763776655
# RUN  5 , total integrated cost =  77616.4763776655
# Control only changes marginally.
# RUN  5 , total integrated cost =  77616.4763776655
# Improved over  5  iterations in  0.25429794599767774  seconds by  1.5631940186722204e-13  percent.
# no convergence
# ------------------------------------------------
# ------------------------- 5
# [[True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [False, False], [False, False], [False, False], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# -------  60 0.5500000000000003 0.6250000000000003
# -------  61 0.5750000000000002 0.6250000000000003
# -------  62 0.4250000000000001 0.6500000000000004
# weight =  698.6321632510802
# set cost params:  1.0 698.6321632510802 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  34443.71004479844
# Gradient descend method:  None
# RUN  1 , total integrated cost =  34443.710044798434
# RUN  2 , total integrated cost =  34443.71004479842
# RUN  3 , total integrated cost =  34443.7100447984
# RUN  4 , total integrated cost =  34443.71004479838
# RUN  5 , total integrated cost =  34443.71004479838
# Control only changes marginally.
# RUN  5 , total integrated cost =  34443.71004479838
# Improved over  5  iterations in  0.2356631529983133  seconds by  1.7053025658242404e-13  percent.
# no convergence
# -------  63 0.4500000000000001 0.6500000000000004
# weight =  1147.5663766521077
# set cost params:  1.0 1147.5663766521077 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  56067.678908937174
# Gradient descend method:  None
# RUN  1 , total integrated cost =  56067.67890893715
# RUN  2 , total integrated cost =  56067.6789089371
# RUN  3 , total integrated cost =  56067.67890893706
# RUN  4 , total integrated cost =  56067.67890893706
# Control only changes marginally.
# RUN  4 , total integrated cost =  56067.67890893706
# Improved over  4  iterations in  0.18979173101251945  seconds by  2.1316282072803006e-13  percent.
# no convergence
# -------  64 0.47500000000000014 0.6500000000000004
# weight =  2067.5918160400097
# set cost params:  1.0 2067.5918160400097 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  77616.47783692229
# Gradient descend method:  None
# RUN  1 , total integrated cost =  77616.47783692223
# RUN  2 , total integrated cost =  77616.47783692219
# RUN  3 , total integrated cost =  77616.47783692219
# Control only changes marginally.
# RUN  3 , total integrated cost =  77616.47783692219
# Improved over  3  iterations in  0.1709409230388701  seconds by  1.2789769243681803e-13  percent.
# no convergence
# ------------------------------------------------
# ------------------------- 6
# [[True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [False, False], [False, False], [False, False], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# -------  60 0.5500000000000003 0.6250000000000003
# -------  61 0.5750000000000002 0.6250000000000003
# -------  62 0.4250000000000001 0.6500000000000004
# weight =  698.632163251313
# set cost params:  1.0 698.632163251313 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  34443.71004480975
# Gradient descend method:  None
# RUN  1 , total integrated cost =  34443.710044809726
# RUN  2 , total integrated cost =  34443.71004480972
# RUN  3 , total integrated cost =  34443.71004480972
# Control only changes marginally.
# RUN  3 , total integrated cost =  34443.71004480972
# Improved over  3  iterations in  0.18923587299650535  seconds by  8.526512829121202e-14  percent.
# no convergence
# -------  63 0.4500000000000001 0.6500000000000004
# weight =  1147.5663776687948
# set cost params:  1.0 1147.5663776687948 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  56067.67895650129
# Gradient descend method:  None
# RUN  1 , total integrated cost =  56067.67895650116
# RUN  2 , total integrated cost =  56067.678956501135
# RUN  3 , total integrated cost =  56067.67895650112
# RUN  4 , total integrated cost =  56067.678956501106
# RUN  5 , total integrated cost =  56067.678956501106
# Control only changes marginally.
# RUN  5 , total integrated cost =  56067.678956501106
# Improved over  5  iterations in  0.2266627789940685  seconds by  3.268496584496461e-13  percent.
# no convergence
# -------  64 0.47500000000000014 0.6500000000000004
# weight =  2067.591817649329
# set cost params:  1.0 2067.591817649329 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  77616.47789493481
# Gradient descend method:  None
# RUN  1 , total integrated cost =  77616.47789493478
# RUN  2 , total integrated cost =  77616.47789493478
# Control only changes marginally.
# RUN  2 , total integrated cost =  77616.47789493478
# Improved over  2  iterations in  0.20731215400155634  seconds by  2.842170943040401e-14  percent.
# no convergence
# ------------------------------------------------
# ------------------------- 7
# [[True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [False, False], [False, False], [False, False], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# -------  60 0.5500000000000003 0.6250000000000003
# -------  61 0.5750000000000002 0.6250000000000003
# -------  62 0.4250000000000001 0.6500000000000004
# weight =  698.6321632513159
# set cost params:  1.0 698.6321632513159 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  34443.710044809864
# Gradient descend method:  None
# RUN  1 , total integrated cost =  34443.71004480986
# RUN  2 , total integrated cost =  34443.71004480986
# Control only changes marginally.
# RUN  2 , total integrated cost =  34443.71004480986
# Improved over  2  iterations in  0.11745945498114452  seconds by  2.842170943040401e-14  percent.
# no convergence
# -------  63 0.4500000000000001 0.6500000000000004
# weight =  1147.5663777120012
# set cost params:  1.0 1147.5663777120012 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  56067.678958522534
# Gradient descend method:  None
# RUN  1 , total integrated cost =  56067.67895852252
# RUN  2 , total integrated cost =  56067.67895852249
# RUN  3 , total integrated cost =  56067.67895852249
# Control only changes marginally.
# RUN  3 , total integrated cost =  56067.67895852249
# Improved over  3  iterations in  0.16643238300457597  seconds by  7.105427357601002e-14  percent.
# no convergence
# -------  64 0.47500000000000014 0.6500000000000004
# weight =  2067.5918177133067
# set cost params:  1.0 2067.5918177133067 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  77616.4778972411
# Gradient descend method:  None
# RUN  1 , total integrated cost =  77616.47789724107
# RUN  2 , total integrated cost =  77616.47789724107
# Control only changes marginally.
# RUN  2 , total integrated cost =  77616.47789724107
# Improved over  2  iterations in  0.12189889000728726  seconds by  2.842170943040401e-14  percent.
# no convergence
# ------------------------------------------------
# ------------------------- 8
# [[True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [False, False], [False, False], [False, False], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# -------  60 0.5500000000000003 0.6250000000000003
# -------  61 0.5750000000000002 0.6250000000000003
# -------  62 0.4250000000000001 0.6500000000000004
# weight =  698.6321632513159
# set cost params:  1.0 698.6321632513159 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  34443.71004480986
# Gradient descend method:  None
# RUN  1 , total integrated cost =  34443.71004480986
# Control only changes marginally.
# RUN  1 , total integrated cost =  34443.71004480986
# Improved over  1  iterations in  0.07951516500907019  seconds by  0.0  percent.
# no convergence
# -------  63 0.4500000000000001 0.6500000000000004
# weight =  1147.5663777138366
# set cost params:  1.0 1147.5663777138366 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  56067.678958608354
# Gradient descend method:  None
# RUN  1 , total integrated cost =  56067.67895860835
# RUN  2 , total integrated cost =  56067.67895860829
# RUN  3 , total integrated cost =  56067.67895860828
# RUN  4 , total integrated cost =  56067.67895860828
# Control only changes marginally.
# RUN  4 , total integrated cost =  56067.67895860828
# Improved over  4  iterations in  0.23281527700601146  seconds by  1.2789769243681803e-13  percent.
# no convergence
# -------  64 0.47500000000000014 0.6500000000000004
# weight =  2067.591817715849
# set cost params:  1.0 2067.591817715849 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  77616.47789733275
# Gradient descend method:  None
# RUN  1 , total integrated cost =  77616.47789733272
# RUN  2 , total integrated cost =  77616.47789733272
# Control only changes marginally.
# RUN  2 , total integrated cost =  77616.47789733272
# Improved over  2  iterations in  0.13221123401308432  seconds by  2.842170943040401e-14  percent.
# no convergence
# ------------------------------------------------
# ------------------------- 9
# [[True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [False, False], [False, False], [False, False], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# -------  60 0.5500000000000003 0.6250000000000003
# -------  61 0.5750000000000002 0.6250000000000003
# -------  62 0.4250000000000001 0.6500000000000004
# weight =  698.6321632513159
# set cost params:  1.0 698.6321632513159 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  34443.71004480986
# Gradient descend method:  None
# RUN  1 , total integrated cost =  34443.71004480986
# Control only changes marginally.
# RUN  1 , total integrated cost =  34443.71004480986
# Improved over  1  iterations in  0.08427690499229357  seconds by  0.0  percent.
# converged for  62
# -------  63 0.4500000000000001 0.6500000000000004
# weight =  1147.5663777139162
# set cost params:  1.0 1147.5663777139162 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  56067.678958612065
# Gradient descend method:  None
# RUN  1 , total integrated cost =  56067.67895861206
# RUN  2 , total integrated cost =  56067.678958612036
# RUN  3 , total integrated cost =  56067.67895861201
# RUN  4 , total integrated cost =  56067.67895861201
# Control only changes marginally.
# RUN  4 , total integrated cost =  56067.67895861201
# Improved over  4  iterations in  0.23624382901471108  seconds by  9.947598300641403e-14  percent.
# no convergence
# -------  64 0.47500000000000014 0.6500000000000004
# weight =  2067.5918177159506
# set cost params:  1.0 2067.5918177159506 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  77616.47789733646
# Gradient descend method:  None
# RUN  1 , total integrated cost =  77616.47789733642
# RUN  2 , total integrated cost =  77616.47789733637
# RUN  3 , total integrated cost =  77616.47789733637
# Control only changes marginally.
# RUN  3 , total integrated cost =  77616.47789733637
# Improved over  3  iterations in  0.18729253800120205  seconds by  1.1368683772161603e-13  percent.
# no convergence
# ------------------------------------------------
# ------------------------- 10
# [[True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, False], [False, False], [False, False], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# -------  60 0.5500000000000003 0.6250000000000003
# -------  61 0.5750000000000002 0.6250000000000003
# -------  62 0.4250000000000001 0.6500000000000004
# weight =  698.6321632513159
# set cost params:  1.0 698.6321632513159 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  34443.71004480986
# Gradient descend method:  None
# RUN  1 , total integrated cost =  34443.71004480986
# Control only changes marginally.
# RUN  1 , total integrated cost =  34443.71004480986
# Improved over  1  iterations in  0.07286456698784605  seconds by  0.0  percent.
# converged for  62
# -------  63 0.4500000000000001 0.6500000000000004
# weight =  1147.5663777139193
# set cost params:  1.0 1147.5663777139193 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  56067.678958612196
# Gradient descend method:  None
# RUN  1 , total integrated cost =  56067.67895861219
# RUN  2 , total integrated cost =  56067.67895861219
# Control only changes marginally.
# RUN  2 , total integrated cost =  56067.67895861219
# Improved over  2  iterations in  0.1264089619508013  seconds by  1.4210854715202004e-14  percent.
# no convergence
# -------  64 0.47500000000000014 0.6500000000000004
# weight =  2067.5918177159547
# set cost params:  1.0 2067.5918177159547 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  77616.47789733653
# Gradient descend method:  None
# RUN  1 , total integrated cost =  77616.47789733653
# Control only changes marginally.
# RUN  1 , total integrated cost =  77616.47789733653
# Improved over  1  iterations in  0.08676722802920267  seconds by  0.0  percent.
# no convergence
# ------------------------------------------------
# ------------------------- 11
# [[True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [False, False], [False, False], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# -------  60 0.5500000000000003 0.6250000000000003
# -------  61 0.5750000000000002 0.6250000000000003
# -------  62 0.4250000000000001 0.6500000000000004
# -------  63 0.4500000000000001 0.6500000000000004
# weight =  1147.5663777139189
# set cost params:  1.0 1147.5663777139189 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  56067.67895861216
# Gradient descend method:  None
# RUN  1 , total integrated cost =  56067.67895861216
# Control only changes marginally.
# RUN  1 , total integrated cost =  56067.67895861216
# Improved over  1  iterations in  0.07113350502913818  seconds by  0.0  percent.
# no convergence
# -------  64 0.47500000000000014 0.6500000000000004
# weight =  2067.5918177159547
# set cost params:  1.0 2067.5918177159547 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  77616.47789733653
# Gradient descend method:  None
# RUN  1 , total integrated cost =  77616.47789733653
# Control only changes marginally.
# RUN  1 , total integrated cost =  77616.47789733653
# Improved over  1  iterations in  0.07139517203904688  seconds by  0.0  percent.
# converged for  64
# ------------------------------------------------
# ------------------------- 12
# [[True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [False, False], [True, False], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# -------  60 0.5500000000000003 0.6250000000000003
# -------  61 0.5750000000000002 0.6250000000000003
# -------  62 0.4250000000000001 0.6500000000000004
# -------  63 0.4500000000000001 0.6500000000000004
# weight =  1147.566377713919
# set cost params:  1.0 1147.566377713919 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  56067.67895861218
# Gradient descend method:  None
# RUN  1 , total integrated cost =  56067.67895861218
# Control only changes marginally.
# RUN  1 , total integrated cost =  56067.67895861218
# Improved over  1  iterations in  0.07510386302601546  seconds by  0.0  percent.
# converged for  63
# -------  64 0.47500000000000014 0.6500000000000004
# weight =  2067.5918177159547
# set cost params:  1.0 2067.5918177159547 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  77616.47789733653
# Gradient descend method:  None
# RUN  1 , total integrated cost =  77616.47789733653
# Control only changes marginally.
# RUN  1 , total integrated cost =  77616.47789733653
# Improved over  1  iterations in  0.07323645701399073  seconds by  0.0  percent.
# converged for  64
# ------------------------------------------------
# ------------------------- 13
# [[True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, False], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# -------  60 0.5500000000000003 0.6250000000000003
# -------  61 0.5750000000000002 0.6250000000000003
# -------  62 0.4250000000000001 0.6500000000000004
# -------  63 0.4500000000000001 0.6500000000000004
# weight =  1147.5663777139189
# set cost params:  1.0 1147.5663777139189 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  56067.67895861216
# Gradient descend method:  None
# RUN  1 , total integrated cost =  56067.67895861216
# Control only changes marginally.
# RUN  1 , total integrated cost =  56067.67895861216
# Improved over  1  iterations in  0.06876620196271688  seconds by  0.0  percent.
# converged for  63
# -------  64 0.47500000000000014 0.6500000000000004
# ------------------------------------------------
# ------------------------- 14
# [[True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# full convergence

# %%
if os.path.isfile(final_file) :
    print("file found")
    
    with open(final_file,'rb') as f:
        load_array = pickle.load(f)

    bestControl_0 = load_array[0]
    bestState_0 = load_array[1]
    cost_0 = load_array[2]
    runtime_0 = load_array[3]
    grad_0 = load_array[4]
    phi_0 = load_array[5]
    costnode_0 = load_array[6]
    weights_0 = load_array[7]
# Out:
# file found

# %%
delete = [61, 62, 63, 64]
for i in delete:
    bestControl_0[i] = None

# %%
factor_iteration = 20
conv_0 = [[False]*2] * len(exc)
full_converge = False

for i in range(len(conv_0)):
    if i not in i_range_0:
        conv_0[i] = [True, True]

counter = 0

while full_converge == False:
    print('---------------', counter)
    
    if counter > 20:
        break
    
    print(conv_0[::i_stepsize])
    full_converge = True
    
    for conv in conv_0[::i_stepsize]:
        if not conv[0]:
            full_converge = False
            break
        if not conv[1]:
            full_converge = False
            break
    
    if full_converge:
        print("full convergence")
        break
        
    counter += 1
    
    for i in i_range_0:
        print("------- ", i, exc[i], inh[i])
        
        if conv_0[i] == [True, True]:
            continue
            
        aln.params.ext_exc_current = exc[i] * 5.
        aln.params.ext_inh_current = inh[i] * 5.

    # exc and inh control current 

        setinit(initVars[i], aln)
        aln.params.duration = dur

        if not type(bestControl_0[i]) == type(None):
            control0 = bestControl_0[i][:,:,n_pre-1:-n_post+1]
        else:
            control0 = bestControl_init[i][:,:,n_pre-1:-n_post+1].copy()
            weights_0[i] = weights_init[i]
            cost_0[i] = cost_init[i]

        cgv = None
        max_it = 500 * factor_iteration

        j = 1
        while cost_0[i][-j] == 0.:
            j += 1

        weight_ = (factor_we * weights_0[i][1] * cost_uncontrolled[i] / cost_0[i][-j]
                           + factor_ws * weights_0[i][2] * cost_uncontrolled[i] / cost_0[i][-j]) - 1
        print("weight = ", weight_)
        cost.setParams(1.0, weight_ * factor_we, weight_ * factor_ws)

        weights_0[i] = cost.getParams()

        bestControl_0[i], bestState_0[i], cost_0[i], runtime_0[i], grad_0[i], phi_0[i], costnode_0[i] = aln.A1(
            control0, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cntrl_vars_0,
            prec_variables_ = prec_vars, transition_time_ = trans_time)

        with open(final_file,'wb') as f:
            pickle.dump([bestControl_0, bestState_0, cost_0, runtime_0, grad_0, phi_0,
                     costnode_0, weights_0], f)
            
        if j == cost_0[i].shape[0]-1:
            print("converged for ", i)
            if conv_0[i][0]:
                conv_0[i] = [True, True]
            else:
                conv_0[i] = [True, False]
            continue
    
        print("no convergence")
# Out:
# --------------- 0
# [[True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [False, False], [False, False], [False, False], [False, False], [False, False], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# -------  60 0.5500000000000003 0.6250000000000003
# weight =  62358.82497610793
# set cost params:  1.0 62358.82497610793 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  148382.8716694588
# Gradient descend method:  None
# RUN  1 , total integrated cost =  148382.87166945878
# RUN  2 , total integrated cost =  148382.87166945878
# Control only changes marginally.
# RUN  2 , total integrated cost =  148382.87166945878
# Improved over  2  iterations in  0.32921399298356846  seconds by  2.842170943040401e-14  percent.
# no convergence
# -------  61 0.5750000000000002 0.6250000000000003
# weight =  17410.59705892693
# set cost params:  1.0 17410.59705892693 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  173470.85322183184
# Gradient descend method:  None
# RUN  1 , total integrated cost =  31250.098876848147
# RUN  2 , total integrated cost =  17992.412054774246
# RUN  3 , total integrated cost =  17857.59364260968
# RUN  4 , total integrated cost =  17838.161202982512
# RUN  5 , total integrated cost =  17834.471008387696
# RUN  6 , total integrated cost =  17833.499480824736
# RUN  7 , total integrated cost =  17833.077841633687
# RUN  8 , total integrated cost =  17833.011054013907
# RUN  9 , total integrated cost =  17832.9396267774
# RUN  10 , total integrated cost =  17832.92427780012
# RUN  11 , total integrated cost =  17832.87529568526
# RUN  12 , total integrated cost =  17832.830932810964
# RUN  13 , total integrated cost =  17832.80535350505
# RUN  14 , total integrated cost =  17832.800191407077
# RUN  15 , total integrated cost =  17832.79876718903
# RUN  16 , total integrated cost =  17832.79839237543
# RUN  17 , total integrated cost =  17832.79828582354
# RUN  18 , total integrated cost =  17832.798252682038
# RUN  19 , total integrated cost =  17832.798241964927
# RUN  20 , total integrated cost =  17832.79823863083
# RUN  30 , total integrated cost =  17832.798237123712
# Control only changes marginally.
# RUN  33 , total integrated cost =  17832.7982371237
# Improved over  33  iterations in  2.7709074589656666  seconds by  89.7200031556198  percent.
# converged for  61
# -------  62 0.4250000000000001 0.6500000000000004
# weight =  698.6321632513159
# set cost params:  1.0 698.6321632513159 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  34443.71004480986
# Gradient descend method:  None
# RUN  1 , total integrated cost =  33958.93722172608
# RUN  2 , total integrated cost =  33201.75637018378
# RUN  3 , total integrated cost =  32825.07593708923
# RUN  4 , total integrated cost =  32320.53812160484
# RUN  5 , total integrated cost =  32029.279512677615
# RUN  6 , total integrated cost =  31548.987262451996
# RUN  7 , total integrated cost =  31300.55031274464
# RUN  8 , total integrated cost =  30982.77175436462
# RUN  9 , total integrated cost =  30777.12582807942
# RUN  10 , total integrated cost =  30452.31331073072
# RUN  11 , total integrated cost =  30270.740091217227
# RUN  12 , total integrated cost =  30014.8761698514
# RUN  13 , total integrated cost =  29852.043546921715
# RUN  14 , total integrated cost =  29603.87761845921
# RUN  15 , total integrated cost =  29455.825611471977
# RUN  16 , total integrated cost =  29279.8139512204
# RUN  17 , total integrated cost =  29143.030746723998
# RUN  18 , total integrated cost =  28964.966282694437
# RUN  19 , total integrated cost =  28836.583593174753
# RUN  20 , total integrated cost =  28676.032477053403
# RUN  30 , total integrated cost =  27464.589222696955
# RUN  40 , total integrated cost =  26513.110341923068
# RUN  50 , total integrated cost =  25820.7219481227
# RUN  60 , total integrated cost =  25652.83518522992
# Control only changes marginally.
# RUN  60 , total integrated cost =  25652.83518522992
# Improved over  60  iterations in  4.263109432009514  seconds by  25.522438924678454  percent.
# converged for  62
# -------  63 0.4500000000000001 0.6500000000000004
# weight =  1147.566377713919
# set cost params:  1.0 1147.566377713919 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  56067.67895861218
# Gradient descend method:  None
# RUN  1 , total integrated cost =  50275.48838989524
# RUN  2 , total integrated cost =  44282.576065512956
# RUN  3 , total integrated cost =  41339.918136979024
# RUN  4 , total integrated cost =  40667.19450866991
# RUN  5 , total integrated cost =  39679.54230063332
# RUN  6 , total integrated cost =  39125.27381495681
# RUN  7 , total integrated cost =  38328.586752257164
# RUN  8 , total integrated cost =  37822.97237718773
# RUN  9 , total integrated cost =  37185.26124910649
# RUN  10 , total integrated cost =  36796.418373837965
# RUN  11 , total integrated cost =  36317.552527692846
# RUN  12 , total integrated cost =  35958.5720124475
# RUN  13 , total integrated cost =  35517.916972301566
# RUN  14 , total integrated cost =  35214.771895652615
# RUN  15 , total integrated cost =  34835.36759503821
# RUN  16 , total integrated cost =  34563.564229820426
# RUN  17 , total integrated cost =  34208.00473359015
# RUN  18 , total integrated cost =  34206.71384568713
# RUN  19 , total integrated cost =  33962.198778338985
# RUN  20 , total integrated cost =  33647.36997968895
# Control only changes marginally.
# RUN  24 , total integrated cost =  33188.95904944935
# Improved over  24  iterations in  2.4067553819622844  seconds by  40.805541328099835  percent.
# converged for  63
# -------  64 0.47500000000000014 0.6500000000000004
# weight =  2067.5918177159547
# set cost params:  1.0 2067.5918177159547 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  77616.47789733653
# Gradient descend method:  None
# RUN  1 , total integrated cost =  74715.60284948812
# RUN  2 , total integrated cost =  68266.08257483995
# RUN  3 , total integrated cost =  66421.69102473951
# RUN  4 , total integrated cost =  62908.525435391
# RUN  5 , total integrated cost =  61544.6827604463
# RUN  6 , total integrated cost =  58812.302720842235
# RUN  7 , total integrated cost =  57717.846341180135
# RUN  8 , total integrated cost =  56237.741716743745
# RUN  9 , total integrated cost =  55396.224800449025
# RUN  10 , total integrated cost =  54027.62129275071
# RUN  11 , total integrated cost =  53271.348162010814
# RUN  12 , total integrated cost =  52322.40224284595
# RUN  13 , total integrated cost =  51714.40782386422
# RUN  14 , total integrated cost =  50782.63919741473
# RUN  15 , total integrated cost =  50272.756156512616
# RUN  16 , total integrated cost =  49459.51447260779
# RUN  17 , total integrated cost =  49068.172787827665
# RUN  18 , total integrated cost =  48733.41002270068
# RUN  19 , total integrated cost =  48733.41002270066
# RUN  20 , total integrated cost =  48733.41002270066
# Control only changes marginally.
# RUN  20 , total integrated cost =  48733.41002270066
# Improved over  20  iterations in  1.5997040329966694  seconds by  37.21254642968928  percent.
# converged for  64
# --------------- 1
# [[True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [False, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# -------  60 0.5500000000000003 0.6250000000000003
# weight =  62358.82497610793
# set cost params:  1.0 62358.82497610793 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  148382.87166945878
# Gradient descend method:  None
# RUN  1 , total integrated cost =  148382.87166945878
# Control only changes marginally.
# RUN  1 , total integrated cost =  148382.87166945878
# Improved over  1  iterations in  0.20168395596556365  seconds by  0.0  percent.
# no convergence
# -------  61 0.5750000000000002 0.6250000000000003
# weight =  169372.5642388187
# set cost params:  1.0 169372.5642388187 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  164211.99181464312
# Gradient descend method:  None
# RUN  1 , total integrated cost =  150285.18087337815
# RUN  2 , total integrated cost =  150261.69844554822
# RUN  3 , total integrated cost =  150261.62600960137
# RUN  4 , total integrated cost =  150261.62600960117
# RUN  5 , total integrated cost =  150261.62600960105
# RUN  6 , total integrated cost =  150261.62600960105
# Control only changes marginally.
# RUN  6 , total integrated cost =  150261.62600960105
# Improved over  6  iterations in  0.900194700981956  seconds by  8.495339256824039  percent.
# no convergence
# -------  62 0.4250000000000001 0.6500000000000004
# weight =  938.3865120579816
# set cost params:  1.0 938.3865120579816 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  34411.40327322249
# Gradient descend method:  None
# RUN  1 , total integrated cost =  34403.193608129215
# RUN  2 , total integrated cost =  34403.168040644705
# RUN  3 , total integrated cost =  34403.168040644654
# RUN  4 , total integrated cost =  34403.168040644654
# Control only changes marginally.
# RUN  4 , total integrated cost =  34403.168040644654
# Improved over  4  iterations in  0.5549193450133316  seconds by  0.02393169645668536  percent.
# no convergence
# -------  63 0.4500000000000001 0.6500000000000004
# weight =  1939.327529777965
# set cost params:  1.0 1939.327529777965 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  55787.59886651319
# Gradient descend method:  None
# RUN  1 , total integrated cost =  55689.181520614744
# RUN  2 , total integrated cost =  55689.178648565176
# RUN  3 , total integrated cost =  55689.17864856511
# RUN  4 , total integrated cost =  55689.17864856505
# RUN  5 , total integrated cost =  55689.17864856505
# Control only changes marginally.
# RUN  5 , total integrated cost =  55689.17864856505
# Improved over  5  iterations in  0.696271829016041  seconds by  0.17641952682645012  percent.
# no convergence
# -------  64 0.47500000000000014 0.6500000000000004
# weight =  3293.5942223942902
# set cost params:  1.0 3293.5942223942902 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  77113.11620133018
# Gradient descend method:  None
# RUN  1 , total integrated cost =  76990.61234791209
# RUN  2 , total integrated cost =  76990.61234791199
# RUN  3 , total integrated cost =  76990.61234791199
# Control only changes marginally.
# RUN  3 , total integrated cost =  76990.61234791199
# Improved over  3  iterations in  0.43183597602183  seconds by  0.15886253785718907  percent.
# no convergence
# --------------- 2
# [[True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [False, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# -------  60 0.5500000000000003 0.6250000000000003
# weight =  62358.82497610793
# set cost params:  1.0 62358.82497610793 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  148382.87166945878
# Gradient descend method:  None
# RUN  1 , total integrated cost =  148382.87166945878
# Control only changes marginally.
# RUN  1 , total integrated cost =  148382.87166945878
# Improved over  1  iterations in  0.1844756979844533  seconds by  0.0  percent.
# converged for  60
# -------  61 0.5750000000000002 0.6250000000000003
# weight =  195543.87435269405
# set cost params:  1.0 195543.87435269405 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  171079.27687958584
# Gradient descend method:  None
# RUN  1 , total integrated cost =  170855.11119371527
# RUN  2 , total integrated cost =  170854.19801751612
# RUN  3 , total integrated cost =  170854.18635751493
# RUN  4 , total integrated cost =  170854.18616355406
# RUN  5 , total integrated cost =  170854.18615600068
# RUN  6 , total integrated cost =  170854.18615588397
# RUN  7 , total integrated cost =  170854.18615588365
# RUN  8 , total integrated cost =  170854.18615588357
# RUN  9 , total integrated cost =  170854.18615588357
# Control only changes marginally.
# RUN  9 , total integrated cost =  170854.18615588357
# Improved over  9  iterations in  1.0691317939781584  seconds by  0.13157100486267836  percent.
# no convergence
# -------  62 0.4250000000000001 0.6500000000000004
# weight =  939.8371021301557
# set cost params:  1.0 939.8371021301557 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  34456.05730782238
# Gradient descend method:  None
# RUN  1 , total integrated cost =  34456.05710412404
# RUN  2 , total integrated cost =  34456.05710407807
# RUN  3 , total integrated cost =  34456.05710407806
# RUN  4 , total integrated cost =  34456.05710407806
# Control only changes marginally.
# RUN  4 , total integrated cost =  34456.05710407806
# Improved over  4  iterations in  1.0203293160302565  seconds by  5.913164073945154e-07  percent.
# no convergence
# -------  63 0.4500000000000001 0.6500000000000004
# weight =  1953.2099100635683
# set cost params:  1.0 1953.2099100635683 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  56082.049533065394
# Gradient descend method:  None
# RUN  1 , total integrated cost =  56082.031642304595
# RUN  2 , total integrated cost =  56082.03159029503
# RUN  3 , total integrated cost =  56082.031590294966
# RUN  4 , total integrated cost =  56082.03159029492
# RUN  5 , total integrated cost =  56082.03159029492
# Control only changes marginally.
# RUN  5 , total integrated cost =  56082.03159029492
# Improved over  5  iterations in  0.8262822240358219  seconds by  3.199378521401286e-05  percent.
# no convergence
# -------  64 0.47500000000000014 0.6500000000000004
# weight =  3320.9741398182437
# set cost params:  1.0 3320.9741398182437 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  77618.70389272369
# Gradient descend method:  None
# RUN  1 , total integrated cost =  77618.70389272363
# RUN  2 , total integrated cost =  77618.70389272363
# Control only changes marginally.
# RUN  2 , total integrated cost =  77618.70389272363
# Improved over  2  iterations in  0.457552918989677  seconds by  7.105427357601002e-14  percent.
# no convergence
# --------------- 3
# [[True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# -------  60 0.5500000000000003 0.6250000000000003
# weight =  62358.82497610793
# set cost params:  1.0 62358.82497610793 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  148382.87166945878
# Gradient descend method:  None
# RUN  1 , total integrated cost =  148382.87166945878
# Control only changes marginally.
# RUN  1 , total integrated cost =  148382.87166945878
# Improved over  1  iterations in  0.2895035310066305  seconds by  0.0  percent.
# converged for  60
# -------  61 0.5750000000000002 0.6250000000000003
# weight =  198549.07240459928
# set cost params:  1.0 198549.07240459928 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  173185.3529436109
# Gradient descend method:  None
# RUN  1 , total integrated cost =  173182.78576265817
# RUN  2 , total integrated cost =  173182.74357205562
# RUN  3 , total integrated cost =  173182.74223032832
# RUN  4 , total integrated cost =  173182.7422303282
# RUN  5 , total integrated cost =  173182.74223032818
# RUN  6 , total integrated cost =  173182.74223032815
# RUN  7 , total integrated cost =  173182.74223032815
# Control only changes marginally.
# RUN  7 , total integrated cost =  173182.74223032815
# Improved over  7  iterations in  1.0427646900061518  seconds by  0.0015074677150153093  percent.
# no convergence
# -------  62 0.4250000000000001 0.6500000000000004
# weight =  939.8450899022519
# set cost params:  1.0 939.8450899022519 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  34456.34833921258
# Gradient descend method:  None
# RUN  1 , total integrated cost =  34456.34833920446
# RUN  2 , total integrated cost =  34456.34833920436
# RUN  3 , total integrated cost =  34456.348339204334
# RUN  4 , total integrated cost =  34456.34833920433
# RUN  5 , total integrated cost =  34456.34833920431
# RUN  6 , total integrated cost =  34456.348339204305
# RUN  7 , total integrated cost =  34456.348339204305
# Control only changes marginally.
# RUN  7 , total integrated cost =  34456.348339204305
# Improved over  7  iterations in  1.1037163839791901  seconds by  2.4016344468691386e-11  percent.
# no convergence
# -------  63 0.4500000000000001 0.6500000000000004
# weight =  1953.4116501340068
# set cost params:  1.0 1953.4116501340068 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  56087.74024667964
# Gradient descend method:  None
# RUN  1 , total integrated cost =  56087.740245668996
# RUN  2 , total integrated cost =  56087.740245668305
# RUN  3 , total integrated cost =  56087.74024566828
# RUN  4 , total integrated cost =  56087.74024566825
# RUN  5 , total integrated cost =  56087.74024566825
# Control only changes marginally.
# RUN  5 , total integrated cost =  56087.74024566825
# Improved over  5  iterations in  0.763593445008155  seconds by  1.8032295656666975e-09  percent.
# no convergence
# -------  64 0.47500000000000014 0.6500000000000004
# weight =  3321.4850568293077
# set cost params:  1.0 3321.4850568293077 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  77630.4242587785
# Gradient descend method:  None
# RUN  1 , total integrated cost =  77630.42425877848
# RUN  2 , total integrated cost =  77630.42425877848
# Control only changes marginally.
# RUN  2 , total integrated cost =  77630.42425877848
# Improved over  2  iterations in  0.34740780299762264  seconds by  2.842170943040401e-14  percent.
# no convergence
# --------------- 4
# [[True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, False], [True, False], [True, False], [True, False], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# -------  60 0.5500000000000003 0.6250000000000003
# -------  61 0.5750000000000002 0.6250000000000003
# weight =  198889.80632866808
# set cost params:  1.0 198889.80632866808 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  173446.16332694303
# Gradient descend method:  None
# RUN  1 , total integrated cost =  173446.15141011434
# RUN  2 , total integrated cost =  173446.15124738618
# RUN  3 , total integrated cost =  173446.1512473861
# RUN  4 , total integrated cost =  173446.1512473861
# Control only changes marginally.
# RUN  4 , total integrated cost =  173446.1512473861
# Improved over  4  iterations in  0.6448181779705919  seconds by  6.964441709556013e-06  percent.
# no convergence
# -------  62 0.4250000000000001 0.6500000000000004
# weight =  939.8451338760847
# set cost params:  1.0 939.8451338760847 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  34456.34994249551
# Gradient descend method:  None
# RUN  1 , total integrated cost =  34456.349942495464
# RUN  2 , total integrated cost =  34456.34994249544
# RUN  3 , total integrated cost =  34456.34994249543
# RUN  4 , total integrated cost =  34456.34994249543
# Control only changes marginally.
# RUN  4 , total integrated cost =  34456.34994249543
# Improved over  4  iterations in  0.6130518200225197  seconds by  2.2737367544323206e-13  percent.
# no convergence
# -------  63 0.4500000000000001 0.6500000000000004
# weight =  1953.4145721902155
# set cost params:  1.0 1953.4145721902155 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  56087.82293127509
# Gradient descend method:  None
# RUN  1 , total integrated cost =  56087.82293127399
# RUN  2 , total integrated cost =  56087.82293127389
# RUN  3 , total integrated cost =  56087.82293127389
# Control only changes marginally.
# RUN  3 , total integrated cost =  56087.82293127389
# Improved over  3  iterations in  0.6043478819774464  seconds by  2.1458390619955026e-12  percent.
# no convergence
# -------  64 0.47500000000000014 0.6500000000000004
# weight =  3321.4945121095448
# set cost params:  1.0 3321.4945121095448 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  77630.64116160816
# Gradient descend method:  None
# RUN  1 , total integrated cost =  77630.64116160815
# RUN  2 , total integrated cost =  77630.64116160815
# Control only changes marginally.
# RUN  2 , total integrated cost =  77630.64116160815
# Improved over  2  iterations in  0.3850344740203582  seconds by  2.842170943040401e-14  percent.
# no convergence
# --------------- 5
# [[True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, False], [True, False], [True, False], [True, False], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# -------  60 0.5500000000000003 0.6250000000000003
# -------  61 0.5750000000000002 0.6250000000000003
# weight =  198928.55707404015
# set cost params:  1.0 198928.55707404015 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  173476.10585643532
# Gradient descend method:  None
# RUN  1 , total integrated cost =  173476.10585643517
# RUN  2 , total integrated cost =  173476.10585643517
# Control only changes marginally.
# RUN  2 , total integrated cost =  173476.10585643517
# Improved over  2  iterations in  0.3556098460103385  seconds by  8.526512829121202e-14  percent.
# no convergence
# -------  62 0.4250000000000001 0.6500000000000004
# weight =  939.845134118167
# set cost params:  1.0 939.845134118167 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  34456.349951321805
# Gradient descend method:  None
# RUN  1 , total integrated cost =  34456.349951321776
# RUN  2 , total integrated cost =  34456.34995132177
# RUN  3 , total integrated cost =  34456.34995132177
# Control only changes marginally.
# RUN  3 , total integrated cost =  34456.34995132177
# Improved over  3  iterations in  0.49849456996889785  seconds by  1.1368683772161603e-13  percent.
# no convergence
# -------  63 0.4500000000000001 0.6500000000000004
# weight =  1953.4146145117431
# set cost params:  1.0 1953.4146145117431 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  56087.824128848755
# Gradient descend method:  None
# RUN  1 , total integrated cost =  56087.824128848755
# Control only changes marginally.
# RUN  1 , total integrated cost =  56087.824128848755
# Improved over  1  iterations in  0.20569422299740836  seconds by  0.0  percent.
# no convergence
# -------  64 0.47500000000000014 0.6500000000000004
# weight =  3321.49468706669
# set cost params:  1.0 3321.49468706669 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  77630.64517510093
# Gradient descend method:  None
# RUN  1 , total integrated cost =  77630.64517510093
# Control only changes marginally.
# RUN  1 , total integrated cost =  77630.64517510093
# Improved over  1  iterations in  0.1808890299871564  seconds by  0.0  percent.
# no convergence
# --------------- 6
# [[True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, False], [True, False], [True, False], [True, False], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# -------  60 0.5500000000000003 0.6250000000000003
# -------  61 0.5750000000000002 0.6250000000000003
# weight =  198932.95914337604
# set cost params:  1.0 198932.95914337604 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  173479.5086881665
# Gradient descend method:  None
# RUN  1 , total integrated cost =  173479.5086881665
# Control only changes marginally.
# RUN  1 , total integrated cost =  173479.5086881665
# Improved over  1  iterations in  0.1932625619811006  seconds by  0.0  percent.
# no convergence
# -------  62 0.4250000000000001 0.6500000000000004
# weight =  939.8451341195001
# set cost params:  1.0 939.8451341195001 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  34456.34995137046
# Gradient descend method:  None
# RUN  1 , total integrated cost =  34456.34995137039
# RUN  2 , total integrated cost =  34456.34995137035
# RUN  3 , total integrated cost =  34456.34995137035
# Control only changes marginally.
# RUN  3 , total integrated cost =  34456.34995137035
# Improved over  3  iterations in  0.5642472199979238  seconds by  3.268496584496461e-13  percent.
# no convergence
# -------  63 0.4500000000000001 0.6500000000000004
# weight =  1953.414615124706
# set cost params:  1.0 1953.414615124706 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  56087.824146193954
# Gradient descend method:  None
# RUN  1 , total integrated cost =  56087.82414619384
# RUN  2 , total integrated cost =  56087.82414619378
# RUN  3 , total integrated cost =  56087.824146193765
# RUN  4 , total integrated cost =  56087.824146193765
# Control only changes marginally.
# RUN  4 , total integrated cost =  56087.824146193765
# Improved over  4  iterations in  0.623371222987771  seconds by  3.268496584496461e-13  percent.
# converged for  63
# -------  64 0.47500000000000014 0.6500000000000004
# weight =  3321.494690304029
# set cost params:  1.0 3321.494690304029 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  77630.64524936485
# Gradient descend method:  None
# RUN  1 , total integrated cost =  77630.64524936485
# Control only changes marginally.
# RUN  1 , total integrated cost =  77630.64524936485
# Improved over  1  iterations in  0.17361030500615016  seconds by  0.0  percent.
# converged for  64
# --------------- 7
# [[True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, False], [True, False], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# -------  60 0.5500000000000003 0.6250000000000003
# -------  61 0.5750000000000002 0.6250000000000003
# weight =  198933.45912055374
# set cost params:  1.0 198933.45912055374 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  173479.89517417474
# Gradient descend method:  None
# RUN  1 , total integrated cost =  173479.8951741747
# RUN  2 , total integrated cost =  173479.8951741747
# Control only changes marginally.
# RUN  2 , total integrated cost =  173479.8951741747
# Improved over  2  iterations in  0.30137524800375104  seconds by  2.842170943040401e-14  percent.
# converged for  61
# -------  62 0.4250000000000001 0.6500000000000004
# weight =  939.8451341195081
# set cost params:  1.0 939.8451341195081 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  34456.34995137066
# Gradient descend method:  None
# RUN  1 , total integrated cost =  34456.34995137066
# Control only changes marginally.
# RUN  1 , total integrated cost =  34456.34995137066
# Improved over  1  iterations in  0.14248806796967983  seconds by  0.0  percent.
# no convergence
# -------  63 0.4500000000000001 0.6500000000000004
# -------  64 0.47500000000000014 0.6500000000000004
# --------------- 8
# [[True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, False], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# -------  60 0.5500000000000003 0.6250000000000003
# -------  61 0.5750000000000002 0.6250000000000003
# -------  62 0.4250000000000001 0.6500000000000004
# weight =  939.8451341195075
# set cost params:  1.0 939.8451341195075 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  34456.34995137064
# Gradient descend method:  None
# RUN  1 , total integrated cost =  34456.34995137064
# Control only changes marginally.
# RUN  1 , total integrated cost =  34456.34995137064
# Improved over  1  iterations in  0.13981025200337172  seconds by  0.0  percent.
# converged for  62
# -------  63 0.4500000000000001 0.6500000000000004
# -------  64 0.47500000000000014 0.6500000000000004
# --------------- 9
# [[True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# full convergence

# %%
"""
for i in i_range_0:
    
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.

    plotFunc.plot_control_current(aln, [bestControl_init[i], bestControl_0[i]],
        [costnode_init[i], costnode_0[i]], [weights_init[i], weights_0[i]], dur,
        dur_pre, dur_post, initVars[i], target[i], '', filename_ = '', transition_time_ = trans_time,
        labels_ = ["init", "sparse control" + str(i)], print_cost_ = False)
"""

# %%
if os.path.isfile(final_file_1) :
    print("file found")
    
    with open(final_file_1,'rb') as f:
        load_array = pickle.load(f)

    bestControl_1 = load_array[0]
    bestState_1 = load_array[1]
    cost_1 = load_array[2]
    runtime_1 = load_array[3]
    grad_1 = load_array[4]
    phi_1 = load_array[5]
    costnode_1 = load_array[6]
    weights_1 = load_array[7]
# Out:
# file found

# %%
factor_iteration = 20
full_converge = False
conv_1 = [[False]*2] * len(exc)

for i in range(len(conv_1)):
    if i not in i_range_1:
        conv_1[i] = [True, True]
        
counter = 0

while full_converge == False:
    
    print('---------------', counter)
    if counter > 20:
        break
    
    print(conv_1[::i_stepsize])
    full_converge = True
    
    for conv in conv_1[::i_stepsize]:
        if not conv[0]:
            full_converge = False
            break
        if not conv[1]:
            full_converge = False
            break
    
    if full_converge:
        print("full convergence")
        break

    for i in i_range_1:        

        print("------- ", i, exc[i], inh[i])
        
        if conv_1[i] == [True, True]:
            continue
            
        aln.params.ext_exc_current = exc[i] * 5.
        aln.params.ext_inh_current = inh[i] * 5.
        
        if not type(bestControl_1[i]) == type(None):
            control0 = bestControl_1[i][:,:,n_pre-1:-n_post+1].copy()
        else:
            control0 = bestControl_0[i][:,:,n_pre-1:-n_post+1].copy()
            cost_1[i] = cost_0[i]
        
        cost.setParams(1.0, 1. * factor_we, 1. * factor_ws)

        setinit(initVars[i], aln)

        # "HS", "FR", "PR", "HZ"
        cgv = None
        max_it = int( 500 * factor_iteration )

        weights_1[i] = cost.getParams()

        bestControl_1[i], bestState_1[i], cost_1[i], runtime_1[i], grad_1[i], phi_1[i], costnode_1[i] = aln.A1(
            control0, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cntrl_vars_init,
            prec_variables_ = prec_vars, transition_time_ = trans_time)
        
        with open(final_file_1,'wb') as f:
            pickle.dump([bestControl_1, bestState_1, cost_1, runtime_1, grad_1, phi_1,
                 costnode_1, weights_1], f)
            
        j = 1
        while cost_1[i][-j] == 0.:
            j += 1
            
        if j == cost_1[i].shape[0]-1:
            print("converged for ", i)
            if conv_1[i][0]:
                conv_1[i] = [True, True]
            else:
                conv_1[i] = [True, False]
            continue
    
        print("no convergence")
        
    counter += 1
# Out:
# --------------- 0
# [[True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [False, False], [False, False], [False, False], [False, False], [False, False], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# -------  60 0.5500000000000003 0.6250000000000003
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.9161555049378194
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.9127227759517016
# RUN  2 , total integrated cost =  3.9120698853716513
# RUN  3 , total integrated cost =  3.912069853790318
# RUN  4 , total integrated cost =  3.9120698537794096
# RUN  5 , total integrated cost =  3.912069853779401
# RUN  6 , total integrated cost =  3.9120698537793954
# RUN  7 , total integrated cost =  3.91206985377939
# RUN  8 , total integrated cost =  3.9120698537793865
# RUN  9 , total integrated cost =  3.912069853779374
# RUN  10 , total integrated cost =  3.912069853779373
# RUN  11 , total integrated cost =  3.912069853779373
# Control only changes marginally.
# RUN  11 , total integrated cost =  3.912069853779373
# Improved over  11  iterations in  0.1545840899925679  seconds by  0.10432811345960147  percent.
# no convergence
# -------  61 0.5750000000000002 0.6250000000000003
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  19703.65208606026
# Gradient descend method:  None
# RUN  1 , total integrated cost =  16.903148786797072
# RUN  2 , total integrated cost =  14.265844123410547
# RUN  3 , total integrated cost =  11.697219503741925
# RUN  4 , total integrated cost =  9.638850450732141
# RUN  5 , total integrated cost =  9.589809353828715
# RUN  6 , total integrated cost =  9.492865720813883
# RUN  7 , total integrated cost =  9.449246284972222
# RUN  8 , total integrated cost =  9.185102017259437
# RUN  9 , total integrated cost =  8.96354636922161
# RUN  10 , total integrated cost =  8.863408738014998
# RUN  11 , total integrated cost =  8.71541895974308
# RUN  12 , total integrated cost =  8.688894589433874
# RUN  13 , total integrated cost =  8.562736400885168
# RUN  14 , total integrated cost =  8.479103287512764
# RUN  15 , total integrated cost =  7.583352692377654
# RUN  16 , total integrated cost =  6.876189146306171
# RUN  17 , total integrated cost =  6.869481133442245
# RUN  18 , total integrated cost =  6.770805331497028
# RUN  19 , total integrated cost =  6.711059084339118
# RUN  20 , total integrated cost =  6.700898479603339
# RUN  30 , total integrated cost =  6.332725401317072
# RUN  40 , total integrated cost =  6.086384771709167
# RUN  50 , total integrated cost =  4.0053019687923666
# Control only changes marginally.
# RUN  50 , total integrated cost =  4.0053019687923666
# Improved over  50  iterations in  0.5978481430211104  seconds by  99.97967228637971  percent.
# no convergence
# -------  62 0.4250000000000001 0.6500000000000004
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  225.94523815020887
# Gradient descend method:  None
# RUN  1 , total integrated cost =  68.60295819234705
# RUN  2 , total integrated cost =  68.60119756507045
# RUN  3 , total integrated cost =  68.58916500281673
# RUN  4 , total integrated cost =  68.55359337419614
# RUN  5 , total integrated cost =  68.54895108047893
# RUN  6 , total integrated cost =  68.54699149700082
# RUN  7 , total integrated cost =  65.46830262873469
# RUN  8 , total integrated cost =  62.197824310616596
# RUN  9 , total integrated cost =  62.19529181057344
# RUN  10 , total integrated cost =  62.165500605974785
# RUN  11 , total integrated cost =  62.15815412229736
# RUN  12 , total integrated cost =  62.157625951383565
# RUN  13 , total integrated cost =  62.156848833193834
# RUN  14 , total integrated cost =  61.64049530257087
# RUN  15 , total integrated cost =  61.094868832557566
# RUN  16 , total integrated cost =  61.09408166235255
# RUN  17 , total integrated cost =  61.093766325460805
# RUN  18 , total integrated cost =  61.09280745103338
# RUN  19 , total integrated cost =  60.93780924574474
# RUN  20 , total integrated cost =  60.83734681586712
# RUN  30 , total integrated cost =  59.86870148283532
# RUN  40 , total integrated cost =  59.755411161888105
# RUN  50 , total integrated cost =  59.54901929684283
# RUN  60 , total integrated cost =  59.32567076665401
# RUN  70 , total integrated cost =  59.20906413984012
# RUN  80 , total integrated cost =  58.63127371294931
# RUN  90 , total integrated cost =  58.571964799565656
# RUN  100 , total integrated cost =  58.482262892177204
# RUN  110 , total integrated cost =  42.8494432001966
# Control only changes marginally.
# RUN  110 , total integrated cost =  42.8494432001966
# Improved over  110  iterations in  1.4036434959853068  seconds by  81.0354741038135  percent.
# no convergence
# -------  63 0.4500000000000001 0.6500000000000004
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  840.2278159336206
# Gradient descend method:  None
# RUN  1 , total integrated cost =  77.50777339241675
# RUN  2 , total integrated cost =  77.33784277606827
# RUN  3 , total integrated cost =  77.31011347834314
# RUN  4 , total integrated cost =  77.16734862607183
# RUN  5 , total integrated cost =  76.90717139265108
# RUN  6 , total integrated cost =  76.88299931352581
# RUN  7 , total integrated cost =  76.71344014353936
# RUN  8 , total integrated cost =  76.41738524137389
# RUN  9 , total integrated cost =  76.39995257644273
# RUN  10 , total integrated cost =  74.43945391258656
# RUN  11 , total integrated cost =  72.47057879697493
# RUN  12 , total integrated cost =  72.45446296931684
# RUN  13 , total integrated cost =  72.39146236021502
# RUN  14 , total integrated cost =  72.24818187543235
# RUN  15 , total integrated cost =  72.22998123651853
# RUN  16 , total integrated cost =  72.179937031972
# RUN  17 , total integrated cost =  72.04394813707982
# RUN  18 , total integrated cost =  72.02201135848259
# RUN  19 , total integrated cost =  71.98298974592525
# RUN  20 , total integrated cost =  71.86066406993604
# RUN  30 , total integrated cost =  71.30437456977788
# RUN  40 , total integrated cost =  70.78174463324088
# RUN  50 , total integrated cost =  69.03401385453212
# RUN  60 , total integrated cost =  66.91956517276623
# RUN  70 , total integrated cost =  66.19706426838493
# RUN  80 , total integrated cost =  56.188538951473845
# RUN  90 , total integrated cost =  55.428232782608454
# RUN  100 , total integrated cost =  55.324750037834136
# RUN  110 , total integrated cost =  55.07733666780929
# RUN  120 , total integrated cost =  54.850738488680484
# RUN  130 , total integrated cost =  53.1095852690259
# RUN  140 , total integrated cost =  51.85514985506506
# RUN  150 , total integrated cost =  51.85514290004744
# RUN  160 , total integrated cost =  51.85514289821363
# Control only changes marginally.
# RUN  161 , total integrated cost =  51.85514289821363
# Improved over  161  iterations in  1.9359226030064747  seconds by  93.82844248728011  percent.
# no convergence
# -------  64 0.47500000000000014 0.6500000000000004
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1458.9531555360154
# Gradient descend method:  None
# RUN  1 , total integrated cost =  138.60666014644067
# RUN  2 , total integrated cost =  138.426515425736
# RUN  3 , total integrated cost =  137.0262454823585
# RUN  4 , total integrated cost =  135.29257013911678
# RUN  5 , total integrated cost =  135.2227375642236
# RUN  6 , total integrated cost =  134.91462189664833
# RUN  7 , total integrated cost =  134.75372509332246
# RUN  8 , total integrated cost =  133.24114549657045
# RUN  9 , total integrated cost =  131.48078967427594
# RUN  10 , total integrated cost =  131.41979438332962
# RUN  11 , total integrated cost =  131.03276511373195
# RUN  12 , total integrated cost =  130.78086005935097
# RUN  13 , total integrated cost =  130.6414769056187
# RUN  14 , total integrated cost =  130.37213566343172
# RUN  15 , total integrated cost =  130.31267605110116
# RUN  16 , total integrated cost =  129.78172992848562
# RUN  17 , total integrated cost =  129.40683047414655
# RUN  18 , total integrated cost =  129.06252551412572
# RUN  19 , total integrated cost =  128.60237091437574
# RUN  20 , total integrated cost =  128.54716255216485
# RUN  30 , total integrated cost =  123.20113506317827
# RUN  40 , total integrated cost =  113.60022552904263
# RUN  50 , total integrated cost =  109.8683888980745
# RUN  60 , total integrated cost =  107.2166454236633
# RUN  70 , total integrated cost =  96.37023277883938
# RUN  80 , total integrated cost =  87.58877133304435
# RUN  90 , total integrated cost =  85.68664847483223
# RUN  100 , total integrated cost =  84.5993108227489
# RUN  110 , total integrated cost =  79.98565968184592
# RUN  120 , total integrated cost =  79.67396702266622
# RUN  130 , total integrated cost =  69.88942760653245
# Control only changes marginally.
# RUN  137 , total integrated cost =  69.88942760646547
# Improved over  137  iterations in  1.7822322539868765  seconds by  95.20961811959012  percent.
# no convergence
# --------------- 1
# [[True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [False, False], [False, False], [False, False], [False, False], [False, False], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# -------  60 0.5500000000000003 0.6250000000000003
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.912069853779373
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.912069853779373
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.912069853779373
# Improved over  1  iterations in  0.03611338802147657  seconds by  0.0  percent.
# converged for  60
# -------  61 0.5750000000000002 0.6250000000000003
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  4.0053019687923666
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.0053019687923666
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.0053019687923666
# Improved over  1  iterations in  0.03753056499408558  seconds by  0.0  percent.
# converged for  61
# -------  62 0.4250000000000001 0.6500000000000004
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  42.8494432001966
# Gradient descend method:  None
# RUN  1 , total integrated cost =  42.8494432001966
# Control only changes marginally.
# RUN  1 , total integrated cost =  42.8494432001966
# Improved over  1  iterations in  0.035856342990882695  seconds by  0.0  percent.
# converged for  62
# -------  63 0.4500000000000001 0.6500000000000004
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  51.85514289821363
# Gradient descend method:  None
# RUN  1 , total integrated cost =  51.85514289821363
# Control only changes marginally.
# RUN  1 , total integrated cost =  51.85514289821363
# Improved over  1  iterations in  0.036783627001568675  seconds by  0.0  percent.
# converged for  63
# -------  64 0.47500000000000014 0.6500000000000004
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  69.88942760646547
# Gradient descend method:  None
# RUN  1 , total integrated cost =  69.88942760646547
# Control only changes marginally.
# RUN  1 , total integrated cost =  69.88942760646547
# Improved over  1  iterations in  0.036457729001995176  seconds by  0.0  percent.
# converged for  64
# --------------- 2
# [[True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# -------  60 0.5500000000000003 0.6250000000000003
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.912069853779373
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.912069853779373
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.912069853779373
# Improved over  1  iterations in  0.039400034002028406  seconds by  0.0  percent.
# converged for  60
# -------  61 0.5750000000000002 0.6250000000000003
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  4.0053019687923666
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.0053019687923666
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.0053019687923666
# Improved over  1  iterations in  0.03388833598000929  seconds by  0.0  percent.
# converged for  61
# -------  62 0.4250000000000001 0.6500000000000004
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  42.8494432001966
# Gradient descend method:  None
# RUN  1 , total integrated cost =  42.8494432001966
# Control only changes marginally.
# RUN  1 , total integrated cost =  42.8494432001966
# Improved over  1  iterations in  0.036780945956707  seconds by  0.0  percent.
# converged for  62
# -------  63 0.4500000000000001 0.6500000000000004
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  51.85514289821363
# Gradient descend method:  None
# RUN  1 , total integrated cost =  51.85514289821363
# Control only changes marginally.
# RUN  1 , total integrated cost =  51.85514289821363
# Improved over  1  iterations in  0.034982692974153906  seconds by  0.0  percent.
# converged for  63
# -------  64 0.47500000000000014 0.6500000000000004
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  69.88942760646547
# Gradient descend method:  None
# RUN  1 , total integrated cost =  69.88942760646547
# Control only changes marginally.
# RUN  1 , total integrated cost =  69.88942760646547
# Improved over  1  iterations in  0.03475186903961003  seconds by  0.0  percent.
# converged for  64
# --------------- 3
# [[True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# full convergence
