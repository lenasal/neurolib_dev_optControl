# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import sys
import pickle

path = os.getcwd().split(os.sep + 'GUI')[0]
if path not in sys.path:
    print("not here")
    sys.path.append(path)

from neurolib.models.aln import ALNModel
from neurolib.utils import plotFunctions as plotFunc
from neurolib.utils import costFunctions as cost
import neurolib.dashboard.functions as functions
import neurolib.dashboard.data as data
    
# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2 

#path = os.path.join(os.getcwd(), "plots")
# Out:
# not here

# %%
# read case
print(os.getcwd())
case = os.getcwd().split(os.sep)[-2]
print(case)
# Out:
# /home/lena/Promotion/neurolib/GUI/current/gui/data/00181/dt
# 00181

# %% [markdown]
# ### Bistability

# %%
aln = ALNModel()
N = aln.params.N

data.set_parameters(aln)

state_vars = aln.state_vars
init_vars = aln.init_vars

##############################################################
def setinit(init_vars_, model):
    state_vars = model.state_vars
    init_vars = model.init_vars
    for iv in range(len(init_vars)):
        for sv in range(len(state_vars)):
            if state_vars[sv] in init_vars[iv]:
                #print("set init vars ", )
                if model.params[init_vars[iv]].ndim == 2:
                    model.params[init_vars[iv]][0,:] = init_vars_[sv]
                else:
                    model.params[init_vars[iv]][0] = init_vars_[sv]
                    
##############################################################               
def setmaxmincontrol(max_c_c, min_c_c, max_c_r, min_c_r):
    import numpy as np
    
    max_cntrl = np.zeros(( 6 ))
    min_cntrl = np.zeros(( 6 ))
    
    max_cntrl[0] = max_c_c
    min_cntrl[0] = min_c_c
    max_cntrl[1] = max_c_c
    min_cntrl[1] = min_c_c
    max_cntrl[2] = max_c_r
    min_cntrl[2] = min_c_r
    max_cntrl[3] = max_c_r
    min_cntrl[3] = min_c_r
    max_cntrl[4] = max_c_r
    min_cntrl[4] = min_c_r
    max_cntrl[5] = max_c_r
    min_cntrl[5] = min_c_r
            
    return max_cntrl, min_cntrl

#####################################################
def getclosest(k_, found_solution, exc, inh, already_tried_):
    import numpy as np
    if len(found_solution) == 0:
        print("no solutions found")
        return -1
    
    start_ind = -1
    for j_ in found_solution:
        if j_ not in already_tried_ and j_ != k_:
            start_ind = j_
            break
            
    if start_ind == -1:
        return -1
        
    min_dist = np.sqrt((exc[k_] - exc[start_ind])**2 + (inh[k_] - inh[start_ind])**2)
    min_i = start_ind
        
    print(found_solution, already_tried_)
        
    if len(found_solution) == len(already_tried_):
        print("already tried all options")
        min_i = -1
        return min_i
    
    for i_ in found_solution:
        if i_ not in already_tried_:
            if i_ != k_ and i_ != min_i:
                dist_ = np.sqrt((exc[k_] - exc[i_])**2 + (inh[k_] - inh[i_])**2)
                if dist_ < min_dist:
                    min_dist = dist_
                    min_i = i_
                    
    if min_i == 0 and 0 in already_tried_:
        return -1
    
    return min_i

# %%
##### LOAD BOUNDARIES
data_file = 'bi.pickle'
with open(data_file,'rb') as f:
    load_array= pickle.load(f)
exc = load_array[0]
inh = load_array[1]
print(len(exc))
#plt.scatter(exc, inh)
# Out:
# 147

# %%
bestControl_init = [None] * len(exc)
bestState_init = [None] * len(exc)
cost_init = [None] * len(exc)
runtime_init = [None] * len(exc)
grad_init = [None] * len(exc)
phi_init = [None] * len(exc)
costnode_init = [None] * len(exc)
weights_init = [None] * len(exc)

conv_init = [[False]*2] * len(exc)

# %%
bestControl_0 = [None] * len(exc)
bestState_0 = [None] * len(exc)
cost_0 = [None] * len(exc)
runtime_0 = [None] * len(exc)
grad_0 = [None] * len(exc)
phi_0 = [None] * len(exc)
costnode_0 = [None] * len(exc)
weights_0 = [None] * len(exc)

conv_0 = [[False]*2] * len(exc)

# %%
bestControl_1 = [None] * len(exc)
bestState_1 = [None] * len(exc)
cost_1 = [None] * len(exc)
runtime_1 = [None] * len(exc)
grad_1 = [None] * len(exc)
phi_1 = [None] * len(exc)
costnode_1 = [None] * len(exc)
weights_1 = [None] * len(exc)

conv_1 = [[False]*2] * len(exc)

# %%
initVars = [None] * len(exc)
target = [None] * len(exc)
cost_uncontrolled = [None] * len(exc)

cgv_list = [None, "HS", "FR", "PR", "CD", "LS", "DY", "WYL", "HZ", None]

# %%
dur_pre = 10
dur_post = 10

aln.params.dt = 0.01

n_pre = int(np.around(dur_pre/aln.params.dt + 1.,1))
n_post = int(np.around(dur_post/aln.params.dt + 1.,1))

tol = 1e-32
start_step = 10.
c_scheme = np.zeros(( 1,1 ))
c_scheme[0,0] = 1.
u_mat = np.identity(1)
u_scheme = np.array([[1.]])

c_var = [ [0], [1], [0,1]]
p_var = [ [0], [0], [0]]

### CURRENTS
cntrl_vars_0 = [0,1]
prec_vars = [0]

if case[0] == '0':    # low to high
    max_I = [3., -3.]
elif case[0] == '1':
    max_I = [-3., 3.]
    
if case[1] == '0':    # sparsity
    factor_ws = 1.
    factor_we = 0.
elif case[1] == '1':  # energy
    factor_ws = 0.
    factor_we = 1.
    
if case[3] == '0':
    cntrl_vars_init = [0]
elif case[3] == '1':
    cntrl_vars_init = [1]
elif case[3] == '2':
    cntrl_vars_init = [0,1]
elif case[3] == '3':
    cntrl_vars_init = [0]
    conv_init = [[True]*2] * len(exc)
    case_read = case[0] + case[1] + case[2] + str(int(case[3])-3) + '0'
    read_file = os.path.join( os.getcwd()[:-9], case_read, 'control_init_' + case_read + '.pickle')
elif case[3] == '4':
    cntrl_vars_init = [1]
    conv_init = [[True]*2] * len(exc)
    case_read = case[0] + case[1] + case[2] + str(int(case[3])-3) + '0'
    read_file = os.path.join( os.getcwd()[:-9], case_read, 'control_init_' + case_read + '.pickle')
elif case[3] == '5':
    cntrl_vars_init = [0,1]
    conv_init = [[True]*2] * len(exc)
    case_read = case[0] + case[1] + case[2] + str(int(case[3])-3) + '0'
    read_file = os.path.join( os.getcwd()[:-9], case_read, 'control_init_' + case_read + '.pickle')
elif case[3] == '6':
    cntrl_vars_init = [0]
    conv_init = [[True]*2] * len(exc)
    case_read = case[0] + case[1] + case[2] + str(int(case[3])-6) + '0'
    read_file = os.path.join( os.getcwd()[:-9], case_read, 'control_init_' + case_read + '.pickle')
elif case[3] == '7':
    cntrl_vars_init = [1]
    conv_init = [[True]*2] * len(exc)
    case_read = case[0] + case[1] + case[2] + str(int(case[3])-6) + '0'
    read_file = os.path.join( os.getcwd()[:-9], case_read, 'control_init_' + case_read + '.pickle')
elif case[3] == '8':
    cntrl_vars_init = [0,1]
    conv_init = [[True]*2] * len(exc)
    case_read = case[0] + case[1] + case[2] + str(int(case[3])-6) + '0'
    read_file = os.path.join( os.getcwd()[:-9], case_read, 'control_init_' + case_read + '.pickle')
    
if case[4] == '0':
    dur = 100
    trans_time = 0.8
elif case[4] == '1':
    dur = 400
    trans_time = 0.95
    
maxC = [5., -5., 0.18, 0.]

n_dur = int(np.around(dur/aln.params.dt + 1.,1))
max_cntrl, min_cntrl = setmaxmincontrol(maxC[0], maxC[1], maxC[2], maxC[3])
# Out:
# /home/lena/Promotion/neurolib/GUI/current/gui/data/00120/control_init_00120.pickle

# %%
init_file = 'control_init_' + case + '.pickle'
final_file = 'control_' + case + '.pickle'
case_1 = case[0] + case[1] + '0' + case[3] + case[4]
final_file_1 = 'control_' + case_1 + '.pickle'

# %%
if os.path.isfile(init_file) :
    print("file found")
    
    with open(init_file,'rb') as f:
        load_array = pickle.load(f)

    bestControl_init = load_array[0]
    bestState_init = load_array[1]
    cost_init = load_array[2]
    runtime_init = load_array[3]
    grad_init = load_array[4]
    phi_init = load_array[5]
    costnode_init = load_array[6]
    weights_init = load_array[7]

# %%
# get initial parameters and target states

i_stepsize = 2
i_range = [20]
i_range_0 = [20]
i_range_1 = [20]
data.set_parameters(aln)
data.set_parameters(aln)

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    aln.params.duration = 3000.
    
    control0 = aln.getZeroControl()
    control0 = functions.step_control(aln, maxI_ = max_I[0])

    aln.run(control=control0)
    
    target_rates = np.zeros((2))
    target_rates[0] = aln.rates_exc[0,-1] 
    target_rates[1] = aln.rates_inh[0,-1]

    control0 = functions.step_control(aln, maxI_ = max_I[1])
    aln.run(control=control0)

    init_state_vars = np.zeros(( len(state_vars) ))
    for j in range(len(state_vars)):
        if aln.state[state_vars[j]].size == 1:
            init_state_vars[j] = aln.state[state_vars[j]][0]
        else:
            init_state_vars[j] = aln.state[state_vars[j]][0,-1]

    initVars[i] = init_state_vars
    
    aln.params.duration = dur

    target[i] = aln.getZeroTarget()
    target[i][:,0,:] = target_rates[0]
    target[i][:,1,:] = target_rates[1]
# Out:
# -------  20 0.4500000000000001 0.4750000000000002

# %%
print(aln.params.dt)
# Out:
# 0.01

# %%
# get uncontrolled cost

data.set_parameters(aln)

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    aln.params.duration = dur
        
    cost.setParams(1.0, 0.0, 0.0)

##### zero control as input for uncontrolled cost
    setinit(initVars[i], aln)
    control0 = aln.getZeroControl()

    # "HS", "FR", "PR", "HZ"
    cgv = None
    max_it = 0

    bestControl_init_, bestState_init_, cost_init_, runtime_init_, grad_init_, phi_init_, costnode_init_ = aln.A1(
        control0, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cntrl_vars_init,
        prec_variables_ = prec_vars, transition_time_ = trans_time)
    
    cost_uncontrolled[i] = cost_init_[0]
# Out:
# -------  20 0.4500000000000001 0.4750000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12738.116450268566
# Gradient descend method:  None
# RUN  0 , total integrated cost =  12738.116450268566
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.

# %%
factor_iteration = 2.
aln.params.duration = dur

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
        
    ##### zero control as input for uncontrolled cost
    setinit(initVars[i], aln)
    
    if conv_init[i] == [True, True]:
    
        with open(read_file,'rb') as f:
            load_array = pickle.load(f)

        bestControl_read = load_array[0]

        bestControl_init[i] = np.zeros(( 1, 6, n_dur + n_pre + n_post -2 ))
        count = 0
        for j in range((n_pre-1)+10000,(n_pre-1)+20000,10):
            for k in range(10):
                bestControl_init[i][:,:,j+k] = bestControl_read[i][:,:,100+count]
            count += 1
        #bestControl_init[i][:,:,(n_pre-1)+10000:(n_pre-1)+20000:10] = bestControl_read[i][:,:,n_pre-1:n_pre-1+1000].copy()
        weights_init = load_array[7]
        
        control0 = bestControl_init[i][:,:,n_pre-1:-n_post+1]   
        cost.setParams(weights_init[i][0], weights_init[i][1], weights_init[i][2])

        
        bestControl_init[i], bestState_init[i], cost_init[i], runtime_init[i], grad_init[i], phi_init[i], costnode_init[i] = aln.A1(
        control0, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = 0, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cntrl_vars_init,
        prec_variables_ = prec_vars, transition_time_ = trans_time)
        
        continue
    
    
    
    if not type(bestControl_init[i]) == type(None):
        continue
        
    control0 = aln.getZeroControl()

    ##### initial guess
    weight_ = 10
    cost.setParams(1.0, weight_ * factor_we, weight_ * factor_ws)

    setinit(initVars[i], aln)

    # "HS", "FR", "PR", "HZ"
    cgv = None
    max_it = int(100 * factor_iteration)

    weights_init[i] = cost.getParams()

    bestControl_init[i], bestState_init[i], cost_init[i], runtime_init[i], grad_init[i], phi_init[i], costnode_init[i] = aln.A1(
        control0, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cntrl_vars_init,
        prec_variables_ = prec_vars, transition_time_ = trans_time)
    
    j = 1
    while cost_init[i][-j] == 0.:
        j += 1
    
    weight_ = 10 * cost_uncontrolled[i] / cost_init[i][-j]
    print("weight = ", weight_)
    cost.setParams(1.0, weight_ * factor_we, weight_ * factor_ws)

    setinit(initVars[i], aln)
    control0 = bestControl_init[i][:,:,n_pre-1:-n_post+1]

    # "HS", "FR", "PR", "HZ"
    cgv = None
    max_it = int(500 * factor_iteration)

    weights_init[i] = cost.getParams()
    
    bestControl_init[i], bestState_init[i], cost_init[i], runtime_init[i], grad_init[i], phi_init[i], costnode_init[i] = aln.A1(
        control0, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cntrl_vars_init,
        prec_variables_ = prec_vars, transition_time_ = trans_time)
        
    with open(init_file,'wb') as f:
        pickle.dump([bestControl_init, bestState_init, cost_init, runtime_init, grad_init, phi_init,
                 costnode_init, weights_init], f)

with open(init_file,'wb') as f:
        pickle.dump([bestControl_init, bestState_init, cost_init, runtime_init, grad_init, phi_init,
                 costnode_init, weights_init], f)
# Out:
# -------  20 0.4500000000000001 0.4750000000000002
# set cost params:  1.0 0.0 3462.4946137997285
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12489.544720780916
# Gradient descend method:  None
# RUN  0 , total integrated cost =  12489.544720780916
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.

# %%
#plot initial guesses
for i in i_range:
    print("---------", i)
        
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.

    plotFunc.plot_control_current(aln, [bestControl_init[i]],
        [costnode_init[i]], [weights_init[i]], dur,
        dur_pre, dur_post, initVars[i], target[i], '', filename_ = '', transition_time_ = trans_time,
        labels_ = ["init", "sparse control" + str(i)], print_cost_ = False)
    plt.show()
# Out:
# --------- 20

# %%
found_solution = []
no_solution = []
factor_iteration = 20.

for i in i_range:
    print("------- ", i, exc[i], inh[i])    

    if np.abs(np.mean(bestState_init[i][0,0,-300:]) - target[i][0,0,-1]) < 0.1 * np.abs(
        np.mean(bestState_init[i][0,0,-100:]) - bestState_init[i][0,0,0]) and np.abs(
        np.mean(bestState_init[i][0,1,-300:]) - target[i][0,1,-1]) < 0.1 * np.abs(
        np.mean(bestState_init[i][0,1,-100:]) - bestState_init[i][0,1,0]) and np.amax(
        bestState_init[i][0,0,:]) < target[i][0,0,-1] + 5. and np.amax(
        bestState_init[i][0,1,:]) < target[i][0,1,-1] + 5.:
        # and np.amin(bestState_init[i][0,0,:]) > bestState_init[i][0,0,0] - 1.
        #and np.amin(bestState_init[i][0,1,:]) > bestState_init[i][0,1,0] - 1.:
        if i not in found_solution:
            print("found solution for ", i)
            found_solution.append(i)
        if i in no_solution:
            no_solution.pop(no_solution.index(i))
# Out:
# -------  20 0.4500000000000001 0.4750000000000002
# found solution for  20

# %%
if os.path.isfile(final_file) :
    print("file found")
    
    with open(final_file,'rb') as f:
        load_array = pickle.load(f)

    bestControl_0 = load_array[0]
    bestState_0 = load_array[1]
    cost_0 = load_array[2]
    runtime_0 = load_array[3]
    grad_0 = load_array[4]
    phi_0 = load_array[5]
    costnode_0 = load_array[6]
    weights_0 = load_array[7]

# %%
print(aln.params.dt)
# Out:
# 0.01

# %%
factor_iteration = 4
conv_0 = [[False]*2] * len(exc)
full_converge = False

for i in range(len(conv_0)):
    if i not in i_range_0:
        conv_0[i] = [True, True]

counter = 0

while full_converge == False:
    print('---------------', counter)
    
    if counter > 4:
        break
        
    counter += 1
    
    for i in i_range_0:
        print("------- ", i, exc[i], inh[i])
        
        if conv_0[i] == [True, True]:
            continue
            
        aln.params.ext_exc_current = exc[i] * 5.
        aln.params.ext_inh_current = inh[i] * 5.

    # exc and inh control current 

        setinit(initVars[i], aln)
        aln.params.duration = dur

        if not type(bestControl_0[i]) == type(None):
            control0 = bestControl_0[i][:,:,n_pre-1:-n_post+1]
        else:
            control0 = bestControl_init[i][:,:,n_pre-1:-n_post+1].copy()
            weights_0[i] = weights_init[i]
            cost_0[i] = cost_init[i]

        cgv = None
        max_it = 500 * factor_iteration

        j = 1
        while cost_0[i][-j] == 0.:
            j += 1

        weight_ = (factor_we * weights_0[i][1] * cost_uncontrolled[i] / cost_0[i][-j]
                           + factor_ws * weights_0[i][2] * cost_uncontrolled[i] / cost_0[i][-j]) - 1
        print("weight = ", weight_)
        cost.setParams(1.0, weight_ * factor_we, weight_ * factor_ws)

        weights_0[i] = cost.getParams()

        bestControl_0[i], bestState_0[i], cost_0[i], runtime_0[i], grad_0[i], phi_0[i], costnode_0[i] = aln.A1(
            control0, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cntrl_vars_0,
            prec_variables_ = prec_vars, transition_time_ = trans_time)

        with open(final_file,'wb') as f:
            pickle.dump([bestControl_0, bestState_0, cost_0, runtime_0, grad_0, phi_0,
                     costnode_0, weights_0], f)
            
        if j == cost_0[i].shape[0]-1:
            print("converged for ", i)
            if conv_0[i][0]:
                conv_0[i] = [True, True]
            else:
                conv_0[i] = [True, False]
            continue
    
        print("no convergence")
# Out:
# --------------- 0
# -------  20 0.4500000000000001 0.4750000000000002
# weight =  3530.406515212902
# set cost params:  1.0 0.0 3530.406515212902
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12734.509355929415
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11831.144666710852
# RUN  2 , total integrated cost =  11811.829303290182
# RUN  3 , total integrated cost =  11811.335972193083
# RUN  4 , total integrated cost =  11811.32146283331
# RUN  5 , total integrated cost =  11811.321094089704
# RUN  6 , total integrated cost =  11811.321092280772
# RUN  7 , total integrated cost =  11811.321092206372
# RUN  8 , total integrated cost =  11811.321089200308
# RUN  9 , total integrated cost =  11811.32108638005
# RUN  10 , total integrated cost =  11811.321086167925
# RUN  11 , total integrated cost =  11811.32108565348
# RUN  12 , total integrated cost =  11811.321085558335
# RUN  13 , total integrated cost =  11811.32108392037
# RUN  14 , total integrated cost =  11811.32108188751
# RUN  15 , total integrated cost =  11811.321081811204
# RUN  16 , total integrated cost =  11810.35692169276
# RUN  17 , total integrated cost =  11804.785182244475
# RUN  18 , total integrated cost =  11804.464517034008
# RUN  19 , total integrated cost =  11804.46312168515
# RUN  20 , total integrated cost =  11804.46312134066
# RUN  30 , total integrated cost =  11804.463118814361
# RUN  40 , total integrated cost =  11804.463005146425
# RUN  50 , total integrated cost =  11804.463002594282
# RUN  60 , total integrated cost =  11804.46299912766
# RUN  70 , total integrated cost =  11804.462993617819
# RUN  80 , total integrated cost =  11804.46298665813
# RUN  90 , total integrated cost =  11804.462983551712
# RUN  100 , total integrated cost =  11804.46286788965
# RUN  110 , total integrated cost =  11804.462864483196
# RUN  120 , total integrated cost =  11804.46274856658
# RUN  130 , total integrated cost =  11804.462633167792
# RUN  140 , total integrated cost =  11804.46250080949
# RUN  150 , total integrated cost =  11804.462365103376
# RUN  160 , total integrated cost =  11804.462249858934
# RUN  170 , total integrated cost =  11804.462247326528
# RUN  180 , total integrated cost =  11804.462240880961
# RUN  190 , total integrated cost =  11804.462204648828
# RUN  200 , total integrated cost =  11804.462122571953
# RUN  300 , total integrated cost =  11804.461315616585
# RUN  400 , total integrated cost =  11804.460056911865
# RUN  500 , total integrated cost =  11804.459131867854
# RUN  600 , total integrated cost =  11804.45860655027
# RUN  700 , total integrated cost =  11804.4575366133
# RUN  800 , total integrated cost =  11804.456677817949
# RUN  900 , total integrated cost =  11804.455976025452
# RUN  1000 , total integrated cost =  11804.455366879973
# RUN  1100 , total integrated cost =  11804.454644729172
# RUN  1200 , total integrated cost =  11800.744922789861
# RUN  1300 , total integrated cost =  11800.744462010933
# RUN  1400 , total integrated cost =  11800.744370400385
# RUN  1500 , total integrated cost =  11800.743977757153
# RUN  1600 , total integrated cost =  11800.743507935143
# RUN  1700 , total integrated cost =  11800.742816394055
# RUN  1800 , total integrated cost =  11800.742725256048
# RUN  1900 , total integrated cost =  11800.742635228382
# RUN  2000 , total integrated cost =  11800.74196680963
# RUN  2000 , total integrated cost =  11800.74196680963
# Improved over  2000  iterations in  5856.482579182004  seconds by  7.332574526595366  percent.
# no convergence
# --------------- 1
# -------  20 0.4500000000000001 0.4750000000000002
# weight =  3809.839134865583
# set cost params:  1.0 0.0 3809.839134865583
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12734.77384468695
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12734.773844606136
# RUN  2 , total integrated cost =  12734.77384460192
# RUN  3 , total integrated cost =  12734.773844598501
# RUN  4 , total integrated cost =  12734.7738445786
# RUN  5 , total integrated cost =  12734.77384431838
# RUN  6 , total integrated cost =  12734.773844253428
# RUN  7 , total integrated cost =  12734.77384424979
# RUN  8 , total integrated cost =  12734.773844245907
# RUN  9 , total integrated cost =  12734.773844194964
# RUN  10 , total integrated cost =  12734.773843956082
# RUN  11 , total integrated cost =  12734.773843931303
# RUN  12 , total integrated cost =  12734.773843928118
# RUN  13 , total integrated cost =  12734.773843922609
# RUN  14 , total integrated cost =  12734.773843406228
# RUN  15 , total integrated cost =  12734.773842556651
# RUN  16 , total integrated cost =  12734.77384253815
# RUN  17 , total integrated cost =  12734.773842534785
# RUN  18 , total integrated cost =  12734.773842529748
# RUN  19 , total integrated cost =  12734.773842050194
# RUN  20 , total integrated cost =  12734.77384124287
# RUN  30 , total integrated cost =  12734.773836527926
# RUN  40 , total integrated cost =  12734.773835668608
# RUN  50 , total integrated cost =  12734.773821008404
# RUN  60 , total integrated cost =  12730.225510983215
# Control only changes marginally.
# RUN  65 , total integrated cost =  12730.204122040232
# Improved over  65  iterations in  319.9024171600031  seconds by  0.03588381468293278  percent.
# no convergence
# --------------- 2
# -------  20 0.4500000000000001 0.4750000000000002
# weight =  3811.2071014310227
# set cost params:  1.0 0.0 3811.2071014310227
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12734.775048244479
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12734.775048244479
# Control only changes marginally.
# RUN  1 , total integrated cost =  12734.775048244479
# Improved over  1  iterations in  8.299512388999574  seconds by  0.0  percent.
# no convergence
# --------------- 3
# -------  20 0.4500000000000001 0.4750000000000002
# weight =  3811.2071014368876
# set cost params:  1.0 0.0 3811.2071014368876
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12734.775048264075
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12734.775048264075
# Control only changes marginally.
# RUN  1 , total integrated cost =  12734.775048264075
# Improved over  1  iterations in  8.810654007997073  seconds by  0.0  percent.
# converged for  20
# --------------- 4
# -------  20 0.4500000000000001 0.4750000000000002
# weight =  3811.207101436888
# set cost params:  1.0 0.0 3811.207101436888
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12734.775048264077
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12734.775048264077
# Control only changes marginally.
# RUN  1 , total integrated cost =  12734.775048264077
# Improved over  1  iterations in  8.578955120996397  seconds by  0.0  percent.
# converged for  20
# --------------- 5

# %%
for i in i_range_0:
    print(i)
    
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.

    plotFunc.plot_control_current(aln, [bestControl_init[i], bestControl_0[i]],
        [costnode_init[i], costnode_0[i]], [weights_init[i], weights_0[i]], dur,
        dur_pre, dur_post, initVars[i], target[i], '', filename_ = '', transition_time_ = trans_time,
        labels_ = ["init", "sparse control" + str(i)], print_cost_ = False)
    plt.show()
# Out:
# 20

# %%
print(aln.params.dt)
# Out:
# 0.01

# %%
if os.path.isfile(final_file_1) :
    print("file found")
    
    with open(final_file_1,'rb') as f:
        load_array = pickle.load(f)

    bestControl_1 = load_array[0]
    bestState_1 = load_array[1]
    cost_1 = load_array[2]
    runtime_1 = load_array[3]
    grad_1 = load_array[4]
    phi_1 = load_array[5]
    costnode_1 = load_array[6]
    weights_1 = load_array[7]

# %%
factor_iteration = 2
full_converge = False

for i in range(len(conv_1)):
    if i not in i_range_1:
        conv_1[i] = [True, True]
        
counter = 0

while full_converge == False:
    
    print('---------------', counter)
    if counter > 2:
        break
    
    if full_converge:
        print("full convergence")
        break

    for i in i_range_1:        

        print("------- ", i, exc[i], inh[i])
        
        if conv_1[i] == [True, True]:
            continue
            
        aln.params.ext_exc_current = exc[i] * 5.
        aln.params.ext_inh_current = inh[i] * 5.
        
        if not type(bestControl_1[i]) == type(None):
            control0 = bestControl_1[i][:,:,n_pre-1:-n_post+1].copy()
        else:
            control0 = bestControl_0[i][:,:,n_pre-1:-n_post+1].copy()
            cost_1[i] = cost_0[i]
        
        cost.setParams(1.0, 1. * factor_we, 1. * factor_ws)

        setinit(initVars[i], aln)

        # "HS", "FR", "PR", "HZ"
        cgv = None
        max_it = int( 500 * factor_iteration )

        weights_1[i] = cost.getParams()

        bestControl_1[i], bestState_1[i], cost_1[i], runtime_1[i], grad_1[i], phi_1[i], costnode_1[i] = aln.A1(
            control0, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cntrl_vars_init,
            prec_variables_ = prec_vars, transition_time_ = trans_time)
        
        with open(final_file_1,'wb') as f:
            pickle.dump([bestControl_1, bestState_1, cost_1, runtime_1, grad_1, phi_1,
                 costnode_1, weights_1], f)
            
        j = 1
        while cost_1[i][-j] == 0.:
            j += 1
            
        if j == cost_1[i].shape[0]-1:
            print("converged for ", i)
            if conv_1[i][0]:
                conv_1[i] = [True, True]
            else:
                conv_1[i] = [True, False]
            continue
    
        print("no convergence")
        
    counter += 1
# Out:
# --------------- 0
# -------  20 0.4500000000000001 0.4750000000000002
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.3414021794160838
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.34140217940952
# RUN  2 , total integrated cost =  3.341402179332042
# RUN  3 , total integrated cost =  3.3414021792588313
# RUN  4 , total integrated cost =  3.3414021792191946
# RUN  5 , total integrated cost =  3.3414021791717956
# RUN  6 , total integrated cost =  3.34140217916824
# RUN  7 , total integrated cost =  3.3414021791628232
# RUN  8 , total integrated cost =  3.341402179159989
# RUN  9 , total integrated cost =  3.3414021791544437
# RUN  10 , total integrated cost =  3.3414021791505077
# RUN  11 , total integrated cost =  3.341402179126986
# RUN  12 , total integrated cost =  3.3414021791059647
# RUN  13 , total integrated cost =  3.3414021790673303
# RUN  14 , total integrated cost =  3.341402179024209
# RUN  15 , total integrated cost =  3.3414021790204993
# RUN  16 , total integrated cost =  3.341402179015189
# RUN  17 , total integrated cost =  3.3414021790123205
# RUN  18 , total integrated cost =  3.341402179006406
# RUN  19 , total integrated cost =  3.3414021790022983
# RUN  20 , total integrated cost =  3.3414021789800605
# RUN  30 , total integrated cost =  3.3414021788325705
# RUN  40 , total integrated cost =  3.3414021786197394
# RUN  50 , total integrated cost =  3.3414021782615904
# RUN  60 , total integrated cost =  3.341402177941224
# RUN  70 , total integrated cost =  3.3414021776527654
# RUN  80 , total integrated cost =  3.3414021448351887
# RUN  90 , total integrated cost =  3.3414021445025766
# RUN  100 , total integrated cost =  3.3414021441923367
# RUN  110 , total integrated cost =  3.3414021438720987
# RUN  120 , total integrated cost =  3.34140214368773
# RUN  130 , total integrated cost =  3.3414021434848022
# RUN  140 , total integrated cost =  3.3414021432779175
# RUN  150 , total integrated cost =  3.3414021431184024
# RUN  160 , total integrated cost =  3.3414021429571505
# RUN  170 , total integrated cost =  3.3414021427982386
# RUN  180 , total integrated cost =  3.34140214263442
# RUN  190 , total integrated cost =  3.341402142314035
# RUN  200 , total integrated cost =  3.3414021419264746
# RUN  300 , total integrated cost =  3.341402139378108
# RUN  400 , total integrated cost =  3.341402088390264
# RUN  500 , total integrated cost =  3.3414019110031083
# RUN  600 , total integrated cost =  3.341401882636655
# RUN  700 , total integrated cost =  3.341401860864543
# RUN  800 , total integrated cost =  3.341401777169299
# Control only changes marginally.
# RUN  826 , total integrated cost =  3.341340383975279
# Improved over  826  iterations in  2887.4890811280056  seconds by  0.0018493864996429465  percent.
# no convergence
# --------------- 1
# -------  20 0.4500000000000001 0.4750000000000002
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.341340383975279
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.341340383975279
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.341340383975279
# Improved over  1  iterations in  6.805635336000705  seconds by  0.0  percent.
# converged for  20
# --------------- 2
# -------  20 0.4500000000000001 0.4750000000000002
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.341340383975279
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.341340383975279
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.341340383975279
# Improved over  1  iterations in  5.735634402997675  seconds by  0.0  percent.
# converged for  20
# --------------- 3

# %%
for i in i_range_1:
    print(i)
    
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.

    plotFunc.plot_control_current(aln, [bestControl_init[i], bestControl_1[i]],
        [costnode_init[i], costnode_1[i]], [weights_init[i], weights_1[i]], dur,
        dur_pre, dur_post, initVars[i], target[i], '', filename_ = '', transition_time_ = trans_time,
        labels_ = ["init", "sparse control" + str(i)], print_cost_ = False)
    plt.show()
# Out:
# 20
