# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import sys
import pickle

path = os.getcwd().split(os.sep + 'GUI')[0]
if path not in sys.path:
    print("not here")
    sys.path.append(path)

from neurolib.models.aln import ALNModel
from neurolib.utils import plotFunctions as plotFunc
from neurolib.utils import costFunctions as cost
import neurolib.dashboard.functions as functions
import neurolib.dashboard.data as data
    
# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2 

#path = os.path.join(os.getcwd(), "plots")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# read case
print(os.getcwd())
case = '00131'
# Out:
# D:\Promotion\neurolib\GUI\current\gui\data\shift_init\2

# %% [markdown]
# ### Bistability

# %%
aln = ALNModel()
N = aln.params.N

data.set_parameters(aln)

state_vars = aln.state_vars
init_vars = aln.init_vars

##############################################################
def setinit(init_vars_, model):
    state_vars = model.state_vars
    init_vars = model.init_vars
    for iv in range(len(init_vars)):
        for sv in range(len(state_vars)):
            if state_vars[sv] in init_vars[iv]:
                #print("set init vars ", )
                if model.params[init_vars[iv]].ndim == 2:
                    model.params[init_vars[iv]][0,:] = init_vars_[sv]
                else:
                    model.params[init_vars[iv]][0] = init_vars_[sv]
                    
##############################################################               
def setmaxmincontrol(max_c_c, min_c_c, max_c_r, min_c_r):
    import numpy as np
    
    max_cntrl = np.zeros(( 6 ))
    min_cntrl = np.zeros(( 6 ))
    
    max_cntrl[0] = max_c_c
    min_cntrl[0] = min_c_c
    max_cntrl[1] = max_c_c
    min_cntrl[1] = min_c_c
    max_cntrl[2] = max_c_r
    min_cntrl[2] = min_c_r
    max_cntrl[3] = max_c_r
    min_cntrl[3] = min_c_r
    max_cntrl[4] = max_c_r
    min_cntrl[4] = min_c_r
    max_cntrl[5] = max_c_r
    min_cntrl[5] = min_c_r
            
    return max_cntrl, min_cntrl

#####################################################
def getclosest(k_, found_solution, exc, inh, already_tried_):
    import numpy as np
    if len(found_solution) == 0:
        print("no solutions found")
        return -1
    
    start_ind = -1
    for j_ in found_solution:
        if j_ not in already_tried_ and j_ != k_:
            start_ind = j_
            break
            
    if start_ind == -1:
        return -1
        
    min_dist = np.sqrt((exc[k_] - exc[start_ind])**2 + (inh[k_] - inh[start_ind])**2)
    min_i = start_ind
        
    print(found_solution, already_tried_)
        
    if len(found_solution) == len(already_tried_):
        print("already tried all options")
        min_i = -1
        return min_i
    
    for i_ in found_solution:
        if i_ not in already_tried_:
            if i_ != k_ and i_ != min_i:
                dist_ = np.sqrt((exc[k_] - exc[i_])**2 + (inh[k_] - inh[i_])**2)
                if dist_ < min_dist:
                    min_dist = dist_
                    min_i = i_
                    
    if min_i == 0 and 0 in already_tried_:
        return -1
    
    return min_i

# %%
##### LOAD BOUNDARIES
data_file = 'bi.pickle'
with open(data_file,'rb') as f:
    load_array= pickle.load(f)
exc = load_array[0]
inh = load_array[1]
print(len(exc))
#plt.scatter(exc, inh)
# Out:
# 147

# %%
bestControl_init = [None] * len(exc)
bestState_init = [None] * len(exc)
cost_init = [None] * len(exc)
runtime_init = [None] * len(exc)
grad_init = [None] * len(exc)
phi_init = [None] * len(exc)
costnode_init = [None] * len(exc)
weights_init = [None] * len(exc)

conv_init = [[False]*2] * len(exc)

# %%
bestControl_0 = [None] * len(exc)
bestState_0 = [None] * len(exc)
cost_0 = [None] * len(exc)
runtime_0 = [None] * len(exc)
grad_0 = [None] * len(exc)
phi_0 = [None] * len(exc)
costnode_0 = [None] * len(exc)
weights_0 = [None] * len(exc)

conv_0 = [[False]*2] * len(exc)

# %%
bestControl_1 = [None] * len(exc)
bestState_1 = [None] * len(exc)
cost_1 = [None] * len(exc)
runtime_1 = [None] * len(exc)
grad_1 = [None] * len(exc)
phi_1 = [None] * len(exc)
costnode_1 = [None] * len(exc)
weights_1 = [None] * len(exc)

conv_1 = [[False]*2] * len(exc)

# %%
initVars = [None] * len(exc)
target = [None] * len(exc)
cost_uncontrolled = [None] * len(exc)

cgv_list = [None, "HS", "FR", "PR", "CD", "LS", "DY", "WYL", "HZ", None]

# %%
dur_pre = 10
dur_post = 10

n_pre = int(np.around(dur_pre/aln.params.dt + 1.,1))
n_post = int(np.around(dur_post/aln.params.dt + 1.,1))

tol = 1e-32
start_step = 10.
c_scheme = np.zeros(( 1,1 ))
c_scheme[0,0] = 1.
u_mat = np.identity(1)
u_scheme = np.array([[1.]])

c_var = [ [0], [1], [0,1]]
p_var = [ [0], [0], [0]]

### CURRENTS
cntrl_vars_0 = [0,1]
prec_vars = [0]

if case[0] == '0':    # low to high
    max_I = [3., -3.]
elif case[0] == '1':
    max_I = [-3., 3.]
    
if case[1] == '0':    # sparsity
    factor_ws = 1.
    factor_we = 0.
elif case[1] == '1':  # energy
    factor_ws = 0.
    factor_we = 1.
    
if case[3] == '0':
    cntrl_vars_init = [0]
elif case[3] == '1':
    cntrl_vars_init = [1]
elif case[3] == '2':
    cntrl_vars_init = [0,1]
elif case[3] == '3':
    cntrl_vars_init = [0]
    conv_init = [[True]*2] * len(exc)
    case_read = case[0] + case[1] + case[2] + str(int(case[3])-3) + '0'
    read_file = os.path.join( os.getcwd()[:-12], case_read, 'control_init_' + case_read + '.pickle')
    print(read_file)
elif case[3] == '4':
    cntrl_vars_init = [1]
    conv_init = [[True]*2] * len(exc)
    case_read = case[0] + case[1] + case[2] + str(int(case[3])-3) + '0'
    read_file = os.path.join( os.getcwd()[:-12], case_read, 'control_init_' + case_read + '.pickle')
    print(read_file)
elif case[3] == '5':
    cntrl_vars_init = [0,1]
    conv_init = [[True]*2] * len(exc)
    case_read = case[0] + case[1] + case[2] + str(int(case[3])-3) + '0'
    read_file = os.path.join( os.getcwd()[:-12], case_read, 'control_init_' + case_read + '.pickle')
    print(read_file)

if case[4] == '0':
    dur = 100
    trans_time = 0.8
elif case[4] == '1':
    dur = 400
    trans_time = 0.95
    
maxC = [5., -5., 0.18, 0.]

n_dur = int(np.around(dur/aln.params.dt + 1.,1))
max_cntrl, min_cntrl = setmaxmincontrol(maxC[0], maxC[1], maxC[2], maxC[3])
# Out:
# D:\Promotion\neurolib\GUI\current\gui\data\00100\control_init_00100.pickle

# %%
init_file = 'control_init_' + case + '.pickle'
final_file = 'control_' + case + '.pickle'
case_1 = case[0] + case[1] + '0' + case[3] + case[4]
final_file_1 = 'control_' + case_1 + '.pickle'

# %%
if os.path.isfile(init_file) :
    print("file found")
    
    with open(init_file,'rb') as f:
        load_array = pickle.load(f)

    bestControl_init = load_array[0]
    bestState_init = load_array[1]
    cost_init = load_array[2]
    runtime_init = load_array[3]
    grad_init = load_array[4]
    phi_init = load_array[5]
    costnode_init = load_array[6]
    weights_init = load_array[7]
# Out:
# file found

# %%
# get initial parameters and target states

i_range = [20, 35, 50, 65, 80]
i_range_0 = i_range
i_range_1 = i_range
data.set_parameters(aln)

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    aln.params.duration = 3000.
    
    control0 = aln.getZeroControl()
    control0 = functions.step_control(aln, maxI_ = max_I[0])

    aln.run(control=control0)
    
    target_rates = np.zeros((2))
    target_rates[0] = aln.rates_exc[0,-1] 
    target_rates[1] = aln.rates_inh[0,-1]

    control0 = functions.step_control(aln, maxI_ = max_I[1])
    aln.run(control=control0)

    init_state_vars = np.zeros(( len(state_vars) ))
    for j in range(len(state_vars)):
        if aln.state[state_vars[j]].size == 1:
            init_state_vars[j] = aln.state[state_vars[j]][0]
        else:
            init_state_vars[j] = aln.state[state_vars[j]][0,-1]

    initVars[i] = init_state_vars
    
    aln.params.duration = dur

    target[i] = aln.getZeroTarget()
    target[i][:,0,:] = target_rates[0]
    target[i][:,1,:] = target_rates[1]
# Out:
# -------  20 0.4500000000000001 0.4750000000000002
# -------  35 0.5500000000000003 0.5250000000000002
# -------  50 0.47500000000000014 0.6000000000000003
# -------  65 0.5000000000000002 0.6500000000000004
# -------  80 0.5250000000000001 0.7000000000000004

# %%
# get uncontrolled cost

data.set_parameters(aln)

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    aln.params.duration = dur
        
    cost.setParams(1.0, 0.0, 0.0)

##### zero control as input for uncontrolled cost
    setinit(initVars[i], aln)
    control0 = aln.getZeroControl()

    # "HS", "FR", "PR", "HZ"
    cgv = None
    max_it = 0

    bestControl_init_, bestState_init_, cost_init_, runtime_init_, grad_init_, phi_init_, costnode_init_ = aln.A1(
        control0, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cntrl_vars_init,
        prec_variables_ = prec_vars, transition_time_ = trans_time)
    
    cost_uncontrolled[i] = cost_init_[0]
# Out:
# -------  20 0.4500000000000001 0.4750000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12738.116450271265
# Gradient descend method:  None
# RUN  0 , total integrated cost =  12738.116450271265
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  35 0.5500000000000003 0.5250000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  30546.428984237715
# Gradient descend method:  None
# RUN  0 , total integrated cost =  30546.428984237715
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  50 0.47500000000000014 0.6000000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  15942.955436075114
# Gradient descend method:  None
# RUN  0 , total integrated cost =  15942.955436075114
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  65 0.5000000000000002 0.6500000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  20071.115113665277
# Gradient descend method:  None
# RUN  0 , total integrated cost =  20071.115113665277
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  80 0.5250000000000001 0.7000000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  24416.866252081658
# Gradient descend method:  None
# RUN  0 , total integrated cost =  24416.866252081658
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.

# %%
factor_iteration = 20.
aln.params.duration = dur
shift = 1000

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
        
    ##### zero control as input for uncontrolled cost
    setinit(initVars[i], aln)
    
    if conv_init[i] == [True, True]:
    
        with open(read_file,'rb') as f:
            load_array = pickle.load(f)

        bestControl_read = load_array[0]

        bestControl_init[i] = np.zeros(( 1, 6, n_dur + n_pre + n_post -2 ))
        bestControl_init[i][:,:,n_pre-1+shift:n_pre-1+shift+1000] = bestControl_read[i][:,:,n_pre-1:n_pre-1+1000].copy()
        weights_init = load_array[7]
        
        control0 = bestControl_init[i][:,:,n_pre-1:-n_post+1]       
        cost.setParams(weights_init[i][0], weights_init[i][1], weights_init[i][2])
        
        bestControl_init[i], bestState_init[i], cost_init[i], runtime_init[i], grad_init[i], phi_init[i], costnode_init[i] = aln.A1(
        control0, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = 0, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cntrl_vars_init,
        prec_variables_ = prec_vars, transition_time_ = trans_time)
        
        continue
    
    
    
    if not type(bestControl_init[i]) == type(None):
        continue
        
    control0 = aln.getZeroControl()

    ##### initial guess
    weight_ = 10
    cost.setParams(1.0, weight_ * factor_we, weight_ * factor_ws)

    setinit(initVars[i], aln)

    # "HS", "FR", "PR", "HZ"
    cgv = None
    max_it = int(100 * factor_iteration)

    weights_init[i] = cost.getParams()

    bestControl_init[i], bestState_init[i], cost_init[i], runtime_init[i], grad_init[i], phi_init[i], costnode_init[i] = aln.A1(
        control0, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cntrl_vars_init,
        prec_variables_ = prec_vars, transition_time_ = trans_time)
    
    j = 1
    while cost_init[i][-j] == 0.:
        j += 1
    
    weight_ = 10 * cost_uncontrolled[i] / cost_init[i][-j]
    print("weight = ", weight_)
    cost.setParams(1.0, weight_ * factor_we, weight_ * factor_ws)

    setinit(initVars[i], aln)
    control0 = bestControl_init[i][:,:,n_pre-1:-n_post+1]

    # "HS", "FR", "PR", "HZ"
    cgv = None
    max_it = int(500 * factor_iteration)

    weights_init[i] = cost.getParams()
    
    bestControl_init[i], bestState_init[i], cost_init[i], runtime_init[i], grad_init[i], phi_init[i], costnode_init[i] = aln.A1(
        control0, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cntrl_vars_init,
        prec_variables_ = prec_vars, transition_time_ = trans_time)
        
    with open(init_file,'wb') as f:
        pickle.dump([bestControl_init, bestState_init, cost_init, runtime_init, grad_init, phi_init,
                 costnode_init, weights_init], f)

with open(init_file,'wb') as f:
        pickle.dump([bestControl_init, bestState_init, cost_init, runtime_init, grad_init, phi_init,
                 costnode_init, weights_init], f)
# Out:
# -------  20 0.4500000000000001 0.4750000000000002
# set cost params:  1.0 0.0 3245.121619207406
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12685.052643014476
# Gradient descend method:  None
# RUN  0 , total integrated cost =  12685.052643014476
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  35 0.5500000000000003 0.5250000000000002
# set cost params:  1.0 0.0 48505.630336750546
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  30102.859260773505
# Gradient descend method:  None
# RUN  0 , total integrated cost =  30102.859260773505
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  50 0.47500000000000014 0.6000000000000003
# set cost params:  1.0 0.0 3098.974168043461
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  15915.058572293297
# Gradient descend method:  None
# RUN  0 , total integrated cost =  15915.058572293297
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  65 0.5000000000000002 0.6500000000000004
# set cost params:  1.0 0.0 4351.906456573152
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  20034.249169041283
# Gradient descend method:  None
# RUN  0 , total integrated cost =  20034.249169041283
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  80 0.5250000000000001 0.7000000000000004
# set cost params:  1.0 0.0 6202.258871598218
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  24347.79193825767
# Gradient descend method:  None
# RUN  0 , total integrated cost =  24347.79193825767
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.

# %%
#plot initial guesses
for i in i_range:
    print("---------", i)
        
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.

    plotFunc.plot_control_current(aln, [bestControl_init[i]],
        [costnode_init[i]], [weights_init[i]], dur,
        dur_pre, dur_post, initVars[i], target[i], '', filename_ = '', transition_time_ = trans_time,
        labels_ = ["init", "sparse control" + str(i)], print_cost_ = False)
    plt.show()
# Out:
# --------- 20
# --------- 35
# --------- 50
# --------- 65
# --------- 80

# %%
found_solution = []
no_solution = []
factor_iteration = 20.

for i in i_range:
    print("------- ", i, exc[i], inh[i])    

    if np.abs(np.mean(bestState_init[i][0,0,-300:]) - target[i][0,0,-1]) < 0.1 * np.abs(
        np.mean(bestState_init[i][0,0,-100:]) - bestState_init[i][0,0,0]) and np.abs(
        np.mean(bestState_init[i][0,1,-300:]) - target[i][0,1,-1]) < 0.1 * np.abs(
        np.mean(bestState_init[i][0,1,-100:]) - bestState_init[i][0,1,0]) and np.amax(
        bestState_init[i][0,0,:]) < target[i][0,0,-1] + 5. and np.amax(
        bestState_init[i][0,1,:]) < target[i][0,1,-1] + 5.:
        # and np.amin(bestState_init[i][0,0,:]) > bestState_init[i][0,0,0] - 1.
        #and np.amin(bestState_init[i][0,1,:]) > bestState_init[i][0,1,0] - 1.:
        if i not in found_solution:
            print("found solution for ", i)
            found_solution.append(i)
        if i in no_solution:
            no_solution.pop(no_solution.index(i))
# Out:
# -------  20 0.4500000000000001 0.4750000000000002
# found solution for  20
# -------  35 0.5500000000000003 0.5250000000000002
# found solution for  35
# -------  50 0.47500000000000014 0.6000000000000003
# found solution for  50
# -------  65 0.5000000000000002 0.6500000000000004
# found solution for  65
# -------  80 0.5250000000000001 0.7000000000000004
# found solution for  80

# %%
if os.path.isfile(final_file) :
    print("file found")
    
    with open(final_file,'rb') as f:
        load_array = pickle.load(f)

    bestControl_0 = load_array[0]
    bestState_0 = load_array[1]
    cost_0 = load_array[2]
    runtime_0 = load_array[3]
    grad_0 = load_array[4]
    phi_0 = load_array[5]
    costnode_0 = load_array[6]
    weights_0 = load_array[7]
# Out:
# file found

# %%
factor_iteration = 20
conv_0 = [[False]*2] * len(exc)
full_converge = False
i_stepsize = 5

for i in range(len(conv_0)):
    if i not in i_range_0:
        conv_0[i] = [True, True]

counter = 0

while full_converge == False:
    print('---------------', counter)
    
    if counter > 20:
        break
    
    print(conv_0[::i_stepsize])
    full_converge = True
    
    for conv in conv_0[::i_stepsize]:
        if not conv[0]:
            full_converge = False
            break
        if not conv[1]:
            full_converge = False
            break
    
    if full_converge:
        print("full convergence")
        break
        
    counter += 1
    
    for i in i_range_0:
        print("------- ", i, exc[i], inh[i])
        
        if conv_0[i] == [True, True]:
            continue
            
        aln.params.ext_exc_current = exc[i] * 5.
        aln.params.ext_inh_current = inh[i] * 5.

    # exc and inh control current 

        setinit(initVars[i], aln)
        aln.params.duration = dur

        if not type(bestControl_0[i]) == type(None):
            control0 = bestControl_0[i][:,:,n_pre-1:-n_post+1]
        else:
            control0 = bestControl_init[i][:,:,n_pre-1:-n_post+1].copy()
            weights_0[i] = weights_init[i]
            cost_0[i] = cost_init[i]

        cgv = None
        max_it = 500 * factor_iteration

        j = 1
        while cost_0[i][-j] == 0.:
            j += 1

        weight_ = (factor_we * weights_0[i][1] * cost_uncontrolled[i] / cost_0[i][-j]
                           + factor_ws * weights_0[i][2] * cost_uncontrolled[i] / cost_0[i][-j]) - 1
        print("weight = ", weight_)
        cost.setParams(1.0, weight_ * factor_we, weight_ * factor_ws)

        weights_0[i] = cost.getParams()

        bestControl_0[i], bestState_0[i], cost_0[i], runtime_0[i], grad_0[i], phi_0[i], costnode_0[i] = aln.A1(
            control0, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cntrl_vars_0,
            prec_variables_ = prec_vars, transition_time_ = trans_time)

        with open(final_file,'wb') as f:
            pickle.dump([bestControl_0, bestState_0, cost_0, runtime_0, grad_0, phi_0,
                     costnode_0, weights_0], f)
            
        if j == cost_0[i].shape[0]-1:
            print("converged for ", i)
            if conv_0[i][0]:
                conv_0[i] = [True, True]
            else:
                conv_0[i] = [True, False]
            continue
    
        print("no convergence")
# Out:
# --------------- 0
# [[True, True], [True, True], [True, True], [True, True], [False, False], [True, True], [True, True], [False, False], [True, True], [True, True], [False, False], [True, True], [True, True], [False, False], [True, True], [True, True], [False, False], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# -------  20 0.4500000000000001 0.4750000000000002
# weight =  3410.7564192910354
# set cost params:  1.0 0.0 3410.7564192910354
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12734.38285534689
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12734.38285534689
# Control only changes marginally.
# RUN  1 , total integrated cost =  12734.38285534689
# Improved over  1  iterations in  11.1955225  seconds by  0.0  percent.
# converged for  20
# -------  35 0.5500000000000003 0.5250000000000002
# weight =  74075.79652354539
# set cost params:  1.0 0.0 74075.79652354539
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  30546.016622601983
# Gradient descend method:  None
# RUN  1 , total integrated cost =  30546.016622601983
# Control only changes marginally.
# RUN  1 , total integrated cost =  30546.016622601983
# Improved over  1  iterations in  0.45412410000000136  seconds by  0.0  percent.
# converged for  35
# -------  50 0.47500000000000014 0.6000000000000003
# weight =  3174.0450361554776
# set cost params:  1.0 0.0 3174.0450361554776
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  15937.934104013826
# Gradient descend method:  None
# RUN  1 , total integrated cost =  15937.934103595631
# RUN  2 , total integrated cost =  15937.934103285834
# RUN  3 , total integrated cost =  15937.934103106954
# RUN  4 , total integrated cost =  15937.934102832092
# RUN  5 , total integrated cost =  15937.934102769139
# RUN  6 , total integrated cost =  15937.934102012041
# RUN  7 , total integrated cost =  15937.934101289147
# RUN  8 , total integrated cost =  15937.934101152616
# RUN  9 , total integrated cost =  15937.934100911352
# RUN  10 , total integrated cost =  15937.934100846966
# RUN  11 , total integrated cost =  15937.93410010977
# RUN  12 , total integrated cost =  15937.934099474913
# RUN  13 , total integrated cost =  15937.93409927788
# RUN  14 , total integrated cost =  15937.934098971584
# RUN  15 , total integrated cost =  15937.934098910497
# RUN  16 , total integrated cost =  15937.934098513651
# RUN  17 , total integrated cost =  15937.934098235884
# RUN  18 , total integrated cost =  15937.934098030608
# RUN  19 , total integrated cost =  15937.934097731451
# RUN  20 , total integrated cost =  15937.934097670872
# RUN  30 , total integrated cost =  15937.934094930995
# RUN  40 , total integrated cost =  15937.93409242047
# RUN  50 , total integrated cost =  15937.93408856113
# RUN  60 , total integrated cost =  15937.934085394321
# RUN  70 , total integrated cost =  15937.93408221254
# RUN  80 , total integrated cost =  15937.934078353164
# RUN  90 , total integrated cost =  15937.934075186367
# RUN  100 , total integrated cost =  15937.934071347741
# RUN  110 , total integrated cost =  15937.934068863362
# RUN  120 , total integrated cost =  15937.934065024729
# RUN  130 , total integrated cost =  15937.934062544518
# RUN  140 , total integrated cost =  15937.934059820916
# RUN  150 , total integrated cost =  15937.934055982261
# RUN  160 , total integrated cost =  15937.934052841423
# RUN  170 , total integrated cost =  15937.934048982797
# RUN  180 , total integrated cost =  15937.93404650264
# RUN  190 , total integrated cost =  15937.934043758707
# RUN  200 , total integrated cost =  15937.934039899437
# RUN  300 , total integrated cost =  15937.934009135099
# RUN  400 , total integrated cost =  15937.933981438839
# RUN  500 , total integrated cost =  15937.933952757516
# RUN  600 , total integrated cost =  15937.933923112054
# RUN  700 , total integrated cost =  15937.933892247758
# RUN  800 , total integrated cost =  15937.933861697282
# RUN  900 , total integrated cost =  15937.933828475441
# RUN  1000 , total integrated cost =  15937.933796639234
# RUN  1100 , total integrated cost =  15937.933769378524
# RUN  1200 , total integrated cost =  15937.933739075834
# RUN  1300 , total integrated cost =  15937.933710810636
# RUN  1400 , total integrated cost =  15937.933680708487
# RUN  1500 , total integrated cost =  15937.933651089452
# RUN  1600 , total integrated cost =  15937.933619622148
# RUN  1700 , total integrated cost =  15937.933586976389
# RUN  1800 , total integrated cost =  15937.933555721447
# RUN  1900 , total integrated cost =  15937.933523244328
# RUN  2000 , total integrated cost =  15937.933492454085
# RUN  3000 , total integrated cost =  15937.93319616714
# RUN  4000 , total integrated cost =  15937.932892495459
# RUN  5000 , total integrated cost =  15937.932540803959
# RUN  6000 , total integrated cost =  15937.932243554618
# RUN  7000 , total integrated cost =  15937.931908528677
# RUN  8000 , total integrated cost =  15937.931570273522
# RUN  9000 , total integrated cost =  15937.931277700936
# RUN  10000 , total integrated cost =  15937.930970970438
# RUN  10000 , total integrated cost =  15937.930970970438
# Improved over  10000  iterations in  3028.5332623000004  seconds by  1.9657776022086182e-05  percent.
# no convergence
# -------  65 0.5000000000000002 0.6500000000000004
# weight =  4498.272682704817
# set cost params:  1.0 0.0 4498.272682704817
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  20066.654144853404
# Gradient descend method:  None
# RUN  1 , total integrated cost =  20066.654144853404
# Control only changes marginally.
# RUN  1 , total integrated cost =  20066.654144853404
# Improved over  1  iterations in  0.44210590000011507  seconds by  0.0  percent.
# converged for  65
# -------  80 0.5250000000000001 0.7000000000000004
# weight =  6453.216552546937
# set cost params:  1.0 0.0 6453.216552546937
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  24413.08316453675
# Gradient descend method:  None
# RUN  1 , total integrated cost =  24413.08316453675
# Control only changes marginally.
# RUN  1 , total integrated cost =  24413.08316453675
# Improved over  1  iterations in  0.4678054000000884  seconds by  0.0  percent.
# converged for  80
# --------------- 1
# [[True, True], [True, True], [True, True], [True, True], [True, False], [True, True], [True, True], [True, False], [True, True], [True, True], [False, False], [True, True], [True, True], [True, False], [True, True], [True, True], [True, False], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# -------  20 0.4500000000000001 0.4750000000000002
# weight =  3410.7564192910354
# set cost params:  1.0 0.0 3410.7564192910354
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12734.38285534689
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12734.38285534689
# Control only changes marginally.
# RUN  1 , total integrated cost =  12734.38285534689
# Improved over  1  iterations in  0.46616599999970276  seconds by  0.0  percent.
# converged for  20
# -------  35 0.5500000000000003 0.5250000000000002
# weight =  74075.79652354539
# set cost params:  1.0 0.0 74075.79652354539
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  30546.016622601983
# Gradient descend method:  None
# RUN  1 , total integrated cost =  30546.016622601983
# Control only changes marginally.
# RUN  1 , total integrated cost =  30546.016622601983
# Improved over  1  iterations in  0.48899710000023333  seconds by  0.0  percent.
# converged for  35
# -------  50 0.47500000000000014 0.6000000000000003
# weight =  3174.0456602988424
# set cost params:  1.0 0.0 3174.0456602988424
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  15937.934105000908
# Gradient descend method:  None
# RUN  1 , total integrated cost =  15937.934104939808
# RUN  2 , total integrated cost =  15937.934104544105
# RUN  3 , total integrated cost =  15937.93410426518
# RUN  4 , total integrated cost =  15937.934104061182
# RUN  5 , total integrated cost =  15937.93410376094
# RUN  6 , total integrated cost =  15937.93410370031
# RUN  7 , total integrated cost =  15937.934103290114
# RUN  8 , total integrated cost =  15937.934102971996
# RUN  9 , total integrated cost =  15937.934102799858
# RUN  10 , total integrated cost =  15937.934102519164
# RUN  11 , total integrated cost =  15937.934102459878
# RUN  12 , total integrated cost =  15937.93410215709
# RUN  13 , total integrated cost =  15937.93410194308
# RUN  14 , total integrated cost =  15937.934101550916
# RUN  15 , total integrated cost =  15937.934101021026
# RUN  16 , total integrated cost =  15937.934100960743
# RUN  17 , total integrated cost =  15937.93410054325
# RUN  18 , total integrated cost =  15937.934100232766
# RUN  19 , total integrated cost =  15937.93410005443
# RUN  20 , total integrated cost =  15937.934099779146
# RUN  30 , total integrated cost =  15937.934095963295
# RUN  40 , total integrated cost =  15937.9340928452
# RUN  50 , total integrated cost =  15937.934089662544
# RUN  60 , total integrated cost =  15937.934087204374
# RUN  70 , total integrated cost =  15937.93408446457
# RUN  80 , total integrated cost =  15937.93408132493
# RUN  90 , total integrated cost =  15937.93407814313
# RUN  100 , total integrated cost =  15937.934075004445
# RUN  110 , total integrated cost =  15937.934071144344
# RUN  120 , total integrated cost =  15937.934068686192
# RUN  130 , total integrated cost =  15937.934066204463
# RUN  140 , total integrated cost =  15937.9340634643
# RUN  150 , total integrated cost =  15937.934059604153
# RUN  160 , total integrated cost =  15937.934057122367
# RUN  170 , total integrated cost =  15937.934054382124
# RUN  180 , total integrated cost =  15937.934050521326
# RUN  190 , total integrated cost =  15937.934047781651
# RUN  200 , total integrated cost =  15937.934044642228
# RUN  300 , total integrated cost =  15937.9340146467
# RUN  400 , total integrated cost =  15937.93395575976
# RUN  500 , total integrated cost =  15937.933926356402
# RUN  600 , total integrated cost =  15937.933889738904
# RUN  700 , total integrated cost =  15937.933858935383
# RUN  800 , total integrated cost =  15937.93383201824
# RUN  900 , total integrated cost =  15937.933804252421
# RUN  1000 , total integrated cost =  15937.933775899392
# RUN  1100 , total integrated cost =  15937.933749557238
# RUN  1200 , total integrated cost =  15937.933720241746
# RUN  1300 , total integrated cost =  15937.933690893547
# RUN  1400 , total integrated cost =  15937.93366286364
# RUN  1500 , total integrated cost =  15937.933634110255
# RUN  1600 , total integrated cost =  15937.93360654402
# RUN  1700 , total integrated cost =  15937.933578704158
# RUN  1800 , total integrated cost =  15937.933547036071
# RUN  1900 , total integrated cost =  15937.933517769736
# RUN  2000 , total integrated cost =  15937.933488599365
# RUN  3000 , total integrated cost =  15937.933202446073
# RUN  4000 , total integrated cost =  15937.932911553906
# RUN  5000 , total integrated cost =  15937.932618437939
# RUN  6000 , total integrated cost =  15937.932335225114
# RUN  7000 , total integrated cost =  15937.932041433165
# RUN  8000 , total integrated cost =  15937.93175523698
# RUN  9000 , total integrated cost =  15937.931470082609
# RUN  10000 , total integrated cost =  15937.931179566129
# RUN  10000 , total integrated cost =  15937.931179566129
# Improved over  10000  iterations in  3059.2810945  seconds by  1.8355169245865e-05  percent.
# no convergence
# -------  65 0.5000000000000002 0.6500000000000004
# weight =  4498.272682704817
# set cost params:  1.0 0.0 4498.272682704817
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  20066.654144853404
# Gradient descend method:  None
# RUN  1 , total integrated cost =  20066.654144853404
# Control only changes marginally.
# RUN  1 , total integrated cost =  20066.654144853404
# Improved over  1  iterations in  0.4631360000003042  seconds by  0.0  percent.
# converged for  65
# -------  80 0.5250000000000001 0.7000000000000004
# weight =  6453.216552546937
# set cost params:  1.0 0.0 6453.216552546937
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  24413.08316453675
# Gradient descend method:  None
# RUN  1 , total integrated cost =  24413.08316453675
# Control only changes marginally.
# RUN  1 , total integrated cost =  24413.08316453675
# Improved over  1  iterations in  0.4747966000004453  seconds by  0.0  percent.
# converged for  80
# --------------- 2
# [[True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [False, False], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# -------  20 0.4500000000000001 0.4750000000000002
# -------  35 0.5500000000000003 0.5250000000000002
# -------  50 0.47500000000000014 0.6000000000000003
# weight =  3174.0462430839543
# set cost params:  1.0 0.0 3174.0462430839543
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  15937.93410592258
# Gradient descend method:  None
# RUN  1 , total integrated cost =  15937.934105648244
# RUN  2 , total integrated cost =  15937.93410558538
# RUN  3 , total integrated cost =  15937.93410482855
# RUN  4 , total integrated cost =  15937.934104105554
# RUN  5 , total integrated cost =  15937.934103968933
# RUN  6 , total integrated cost =  15937.934103727817
# RUN  7 , total integrated cost =  15937.934103663447
# RUN  8 , total integrated cost =  15937.934102927748
# RUN  9 , total integrated cost =  15937.934102291558
# RUN  10 , total integrated cost =  15937.934102096284
# RUN  11 , total integrated cost =  15937.93410178855
# RUN  12 , total integrated cost =  15937.934101727387
# RUN  13 , total integrated cost =  15937.934101334731
# RUN  14 , total integrated cost =  15937.934101052664
# RUN  15 , total integrated cost =  15937.934100850245
# RUN  16 , total integrated cost =  15937.934100548695
# RUN  17 , total integrated cost =  15937.934100487939
# RUN  18 , total integrated cost =  15937.934100080676
# RUN  19 , total integrated cost =  15937.934099759566
# RUN  20 , total integrated cost =  15937.934099588858
# RUN  30 , total integrated cost =  15937.934097130552
# RUN  40 , total integrated cost =  15937.934094672153
# RUN  50 , total integrated cost =  15937.934092212943
# RUN  60 , total integrated cost =  15937.934089467086
# RUN  70 , total integrated cost =  15937.934085640189
# RUN  80 , total integrated cost =  15937.934083133367
# RUN  90 , total integrated cost =  15937.934080674995
# RUN  100 , total integrated cost =  15937.934078215836
# RUN  110 , total integrated cost =  15937.93407547005
# RUN  120 , total integrated cost =  15937.934071643354
# RUN  130 , total integrated cost =  15937.934069136385
# RUN  140 , total integrated cost =  15937.934066678154
# RUN  150 , total integrated cost =  15937.93406421952
# RUN  160 , total integrated cost =  15937.93406147517
# RUN  170 , total integrated cost =  15937.93405766992
# RUN  180 , total integrated cost =  15937.934054908286
# RUN  190 , total integrated cost =  15937.934050935131
# RUN  200 , total integrated cost =  15937.934047780054
# RUN  300 , total integrated cost =  15937.933956925062
# RUN  400 , total integrated cost =  15937.933921779319
# RUN  500 , total integrated cost =  15937.933893805173
# RUN  600 , total integrated cost =  15937.933865872066
# RUN  700 , total integrated cost =  15937.933838205689
# RUN  800 , total integrated cost =  15937.933810211433
# RUN  900 , total integrated cost =  15937.933781842006
# RUN  1000 , total integrated cost =  15937.933753914074
# RUN  1100 , total integrated cost =  15937.933724159418
# RUN  1200 , total integrated cost =  15937.933697892897
# RUN  1300 , total integrated cost =  15937.933669898946
# RUN  1400 , total integrated cost =  15937.933642687774
# RUN  1500 , total integrated cost =  15937.933616140064
# RUN  1600 , total integrated cost =  15937.93358769828
# RUN  1700 , total integrated cost =  15937.93356001179
# RUN  1800 , total integrated cost =  15937.933528661806
# RUN  1900 , total integrated cost =  15937.933500347606
# RUN  2000 , total integrated cost =  15937.933472640545
# RUN  3000 , total integrated cost =  15937.933195567435
# Control only changes marginally.
# RUN  3783 , total integrated cost =  15891.637030827402
# Improved over  3783  iterations in  1082.8614191000006  seconds by  0.29048353938152616  percent.
# no convergence
# -------  65 0.5000000000000002 0.6500000000000004
# -------  80 0.5250000000000001 0.7000000000000004
# --------------- 3
# [[True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [False, False], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# -------  20 0.4500000000000001 0.4750000000000002
# -------  35 0.5500000000000003 0.5250000000000002
# -------  50 0.47500000000000014 0.6000000000000003
# weight =  3183.2960990969996
# set cost params:  1.0 0.0 3183.2960990969996
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  15937.948692043896
# Gradient descend method:  None
# RUN  1 , total integrated cost =  15937.948692043887
# RUN  2 , total integrated cost =  15937.948692043881
# RUN  3 , total integrated cost =  15937.948692043881
# Control only changes marginally.
# RUN  3 , total integrated cost =  15937.948692043881
# Improved over  3  iterations in  1.1936507000000347  seconds by  8.526512829121202e-14  percent.
# no convergence
# -------  65 0.5000000000000002 0.6500000000000004
# -------  80 0.5250000000000001 0.7000000000000004
# --------------- 4
# [[True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [False, False], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# -------  20 0.4500000000000001 0.4750000000000002
# -------  35 0.5500000000000003 0.5250000000000002
# -------  50 0.47500000000000014 0.6000000000000003
# weight =  3183.296099100247
# set cost params:  1.0 0.0 3183.296099100247
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  15937.948692060141
# Gradient descend method:  None
# RUN  1 , total integrated cost =  15937.948692060141
# Control only changes marginally.
# RUN  1 , total integrated cost =  15937.948692060141
# Improved over  1  iterations in  0.4441796000000977  seconds by  0.0  percent.
# no convergence
# -------  65 0.5000000000000002 0.6500000000000004
# -------  80 0.5250000000000001 0.7000000000000004
# --------------- 5
# [[True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [False, False], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# -------  20 0.4500000000000001 0.4750000000000002
# -------  35 0.5500000000000003 0.5250000000000002
# -------  50 0.47500000000000014 0.6000000000000003
# weight =  3183.2960991002465
# set cost params:  1.0 0.0 3183.2960991002465
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  15937.948692060138
# Gradient descend method:  None
# RUN  1 , total integrated cost =  15937.948692060138
# Control only changes marginally.
# RUN  1 , total integrated cost =  15937.948692060138
# Improved over  1  iterations in  0.4229568000000654  seconds by  0.0  percent.
# converged for  50
# -------  65 0.5000000000000002 0.6500000000000004
# -------  80 0.5250000000000001 0.7000000000000004
# --------------- 6
# [[True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, False], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# -------  20 0.4500000000000001 0.4750000000000002
# -------  35 0.5500000000000003 0.5250000000000002
# -------  50 0.47500000000000014 0.6000000000000003
# weight =  3183.296099100247
# set cost params:  1.0 0.0 3183.296099100247
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  15937.948692060141
# Gradient descend method:  None
# RUN  1 , total integrated cost =  15937.948692060141
# Control only changes marginally.
# RUN  1 , total integrated cost =  15937.948692060141
# Improved over  1  iterations in  0.4334934999997131  seconds by  0.0  percent.
# converged for  50
# -------  65 0.5000000000000002 0.6500000000000004
# -------  80 0.5250000000000001 0.7000000000000004
# --------------- 7
# [[True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# full convergence

# %%
"""
for i in i_range_0:
    
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.

    plotFunc.plot_control_current(aln, [bestControl_init[i], bestControl_0[i]],
        [costnode_init[i], costnode_0[i]], [weights_init[i], weights_0[i]], dur,
        dur_pre, dur_post, initVars[i], target[i], '', filename_ = '', transition_time_ = trans_time,
        labels_ = ["init", "sparse control" + str(i)], print_cost_ = False)
"""
# Out:
# '\nfor i in i_range_0:\n    \n    aln.params.ext_exc_current = exc[i] * 5.\n    aln.params.ext_inh_current = inh[i] * 5.\n\n    plotFunc.plot_control_current(aln, [bestControl_init[i], bestControl_0[i]],\n        [costnode_init[i], costnode_0[i]], [weights_init[i], weights_0[i]], dur,\n        dur_pre, dur_post, initVars[i], target[i], \'\', filename_ = \'\', transition_time_ = trans_time,\n        labels_ = ["init", "sparse control" + str(i)], print_cost_ = False)\n'

# %%
if os.path.isfile(final_file_1) :
    print("file found")
    
    with open(final_file_1,'rb') as f:
        load_array = pickle.load(f)

    bestControl_1 = load_array[0]
    bestState_1 = load_array[1]
    cost_1 = load_array[2]
    runtime_1 = load_array[3]
    grad_1 = load_array[4]
    phi_1 = load_array[5]
    costnode_1 = load_array[6]
    weights_1 = load_array[7]
# Out:
# file found

# %%
factor_iteration = 20
full_converge = False

for i in range(len(conv_1)):
    if i not in i_range_1:
        conv_1[i] = [True, True]
        
counter = 0

while full_converge == False:
    
    print('---------------', counter)
    if counter > 20:
        break
    
    print(conv_1[::i_stepsize])
    full_converge = True
    
    for conv in conv_1[::i_stepsize]:
        if not conv[0]:
            full_converge = False
            break
        if not conv[1]:
            full_converge = False
            break
    
    if full_converge:
        print("full convergence")
        break

    for i in i_range_1:        

        print("------- ", i, exc[i], inh[i])
        
        if conv_1[i] == [True, True]:
            continue
            
        aln.params.ext_exc_current = exc[i] * 5.
        aln.params.ext_inh_current = inh[i] * 5.
        
        if not type(bestControl_1[i]) == type(None):
            control0 = bestControl_1[i][:,:,n_pre-1:-n_post+1].copy()
        else:
            control0 = bestControl_0[i][:,:,n_pre-1:-n_post+1].copy()
            cost_1[i] = cost_0[i]
        
        cost.setParams(1.0, 1. * factor_we, 1. * factor_ws)

        setinit(initVars[i], aln)

        # "HS", "FR", "PR", "HZ"
        cgv = None
        max_it = int( 500 * factor_iteration )

        weights_1[i] = cost.getParams()

        bestControl_1[i], bestState_1[i], cost_1[i], runtime_1[i], grad_1[i], phi_1[i], costnode_1[i] = aln.A1(
            control0, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cntrl_vars_init,
            prec_variables_ = prec_vars, transition_time_ = trans_time)
        
        with open(final_file_1,'wb') as f:
            pickle.dump([bestControl_1, bestState_1, cost_1, runtime_1, grad_1, phi_1,
                 costnode_1, weights_1], f)
            
        j = 1
        while cost_1[i][-j] == 0.:
            j += 1
            
        if j == cost_1[i].shape[0]-1:
            print("converged for ", i)
            if conv_1[i][0]:
                conv_1[i] = [True, True]
            else:
                conv_1[i] = [True, False]
            continue
    
        print("no convergence")
        
    counter += 1
# Out:
# --------------- 0
# [[True, True], [True, True], [True, True], [True, True], [False, False], [True, True], [True, True], [False, False], [True, True], [True, True], [False, False], [True, True], [True, True], [False, False], [True, True], [True, True], [False, False], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# -------  20 0.4500000000000001 0.4750000000000002
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.733598397842583
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.733598397842583
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.733598397842583
# Improved over  1  iterations in  0.19030670000029204  seconds by  0.0  percent.
# converged for  20
# -------  35 0.5500000000000003 0.5250000000000002
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  0.4124271649725494
# Gradient descend method:  None
# RUN  1 , total integrated cost =  0.4124271649725494
# Control only changes marginally.
# RUN  1 , total integrated cost =  0.4124271649725494
# Improved over  1  iterations in  0.15701760000047216  seconds by  0.0  percent.
# converged for  35
# -------  50 0.47500000000000014 0.6000000000000003
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5.021355708794575
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.021355708794575
# Control only changes marginally.
# RUN  1 , total integrated cost =  5.021355708794575
# Improved over  1  iterations in  0.1526294000004782  seconds by  0.0  percent.
# converged for  50
# -------  65 0.5000000000000002 0.6500000000000004
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  4.460968869891001
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.460968869891001
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.460968869891001
# Improved over  1  iterations in  0.15648609999971086  seconds by  0.0  percent.
# converged for  65
# -------  80 0.5250000000000001 0.7000000000000004
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.7830878127383505
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.7830878127383505
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.7830878127383505
# Improved over  1  iterations in  0.16569319999962318  seconds by  0.0  percent.
# converged for  80
# --------------- 1
# [[True, True], [True, True], [True, True], [True, True], [True, False], [True, True], [True, True], [True, False], [True, True], [True, True], [True, False], [True, True], [True, True], [True, False], [True, True], [True, True], [True, False], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# -------  20 0.4500000000000001 0.4750000000000002
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.733598397842583
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.733598397842583
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.733598397842583
# Improved over  1  iterations in  0.17986280000059196  seconds by  0.0  percent.
# converged for  20
# -------  35 0.5500000000000003 0.5250000000000002
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  0.4124271649725494
# Gradient descend method:  None
# RUN  1 , total integrated cost =  0.4124271649725494
# Control only changes marginally.
# RUN  1 , total integrated cost =  0.4124271649725494
# Improved over  1  iterations in  0.16621399999985442  seconds by  0.0  percent.
# converged for  35
# -------  50 0.47500000000000014 0.6000000000000003
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5.021355708794575
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.021355708794575
# Control only changes marginally.
# RUN  1 , total integrated cost =  5.021355708794575
# Improved over  1  iterations in  0.16517320000002655  seconds by  0.0  percent.
# converged for  50
# -------  65 0.5000000000000002 0.6500000000000004
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  4.460968869891001
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.460968869891001
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.460968869891001
# Improved over  1  iterations in  0.16446279999945546  seconds by  0.0  percent.
# converged for  65
# -------  80 0.5250000000000001 0.7000000000000004
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.7830878127383505
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.7830878127383505
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.7830878127383505
# Improved over  1  iterations in  0.16011209999942366  seconds by  0.0  percent.
# converged for  80
# --------------- 2
# [[True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# full convergence
