# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import sys
import pickle

path = os.getcwd().split(os.sep + 'GUI')[0]
if path not in sys.path:
    print("not here")
    sys.path.append(path)

from neurolib.models.aln import ALNModel
from neurolib.utils import plotFunctions as plotFunc
from neurolib.utils import costFunctions as cost
import neurolib.dashboard.functions as functions
import neurolib.dashboard.data as data
    
# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2 

#path = os.path.join(os.getcwd(), "plots")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### Bistability

# %%
aln = ALNModel()
N = aln.params.N

data.set_parameters(aln)

state_vars = aln.state_vars
init_vars = aln.init_vars

##############################################################
def setinit(init_vars_, model):
    state_vars = model.state_vars
    init_vars = model.init_vars
    for iv in range(len(init_vars)):
        for sv in range(len(state_vars)):
            if state_vars[sv] in init_vars[iv]:
                #print("set init vars ", )
                if model.params[init_vars[iv]].ndim == 2:
                    model.params[init_vars[iv]][0,:] = init_vars_[sv]
                else:
                    model.params[init_vars[iv]][0] = init_vars_[sv]
                    
##############################################################               
def setmaxmincontrol(max_c_c, min_c_c, max_c_r, min_c_r):
    import numpy as np
    
    max_cntrl = np.zeros(( 6 ))
    min_cntrl = np.zeros(( 6 ))
    
    max_cntrl[0] = max_c_c
    min_cntrl[0] = min_c_c
    max_cntrl[1] = max_c_c
    min_cntrl[1] = min_c_c
    max_cntrl[2] = max_c_r
    min_cntrl[2] = min_c_r
    max_cntrl[3] = max_c_r
    min_cntrl[3] = min_c_r
    max_cntrl[4] = max_c_r
    min_cntrl[4] = min_c_r
    max_cntrl[5] = max_c_r
    min_cntrl[5] = min_c_r
            
    return max_cntrl, min_cntrl

# %%
##### LOAD BOUNDARIES
data_file = 'bi.pickle'
with open(data_file,'rb') as f:
    load_array= pickle.load(f)
exc = load_array[0]
inh = load_array[1]
print(len(exc))
#plt.scatter(exc, inh)
# Out:
# 147

# %%
bestControl_init = [None] * len(exc)
bestState_init = [None] * len(exc)
cost_init = [None] * len(exc)
runtime_init = [None] * len(exc)
grad_init = [None] * len(exc)
phi_init = [None] * len(exc)
costnode_init = [None] * len(exc)
weights_init = [None] * len(exc)

conv_init = [[False]*2] * len(exc)

# %%
initVars = [None] * len(exc)
target = [None] * len(exc)
cost_uncontrolled = [None] * len(exc)

cgv_list = [None, "HS", "FR", "PR", "CD", "LS", "DY", "WYL", "HZ", None]

# %%
case = '01161'

dur_pre = 10
dur_post = 10

n_pre = int(np.around(dur_pre/aln.params.dt + 1.,1))
n_post = int(np.around(dur_post/aln.params.dt + 1.,1))

tol = 1e-32
start_step = 10.
c_scheme = np.zeros(( 1,1 ))
c_scheme[0,0] = 1.
u_mat = np.identity(1)
u_scheme = np.array([[1.]])

c_var = [ [0], [1], [0,1]]
p_var = [ [0], [0], [0]]

### CURRENTS
cntrl_vars_0 = [0,1]
prec_vars = [0]

if case[0] == '0':    # low to high
    max_I = [3., -3.]
elif case[0] == '1':
    max_I = [-3., 3.]
    
if case[1] == '0':    # sparsity
    factor_ws = 1.
    factor_we = 0.
elif case[1] == '1':  # energy
    factor_ws = 0.
    factor_we = 1.
    
if case[3] == '0':
    cntrl_vars_init = [0]
elif case[3] == '1':
    cntrl_vars_init = [1]
elif case[3] == '2':
    cntrl_vars_init = [0,1]
elif case[3] == '3':
    cntrl_vars_init = [0]
    conv_init = [[True]*2] * len(exc)
    case_read = case[0] + case[1] + case[2] + str(int(case[3])-3) + '0'
    read_file = os.path.join( os.getcwd()[:-10], case_read, 'control_init_' + case_read + '.pickle')
    print(read_file)
elif case[3] == '4':
    cntrl_vars_init = [1]
    conv_init = [[True]*2] * len(exc)
    case_read = case[0] + case[1] + case[2] + str(int(case[3])-3) + '0'
    read_file = os.path.join( os.getcwd()[:-10], case_read, 'control_init_' + case_read + '.pickle')
    print(read_file)
elif case[3] == '5':
    cntrl_vars_init = [0,1]
    conv_init = [[True]*2] * len(exc)
    case_read = case[0] + case[1] + case[2] + str(int(case[3])-3) + '0'
    read_file = os.path.join( os.getcwd()[:-10], case_read, 'control_init_' + case_read + '.pickle')
    print(read_file)
elif case[3] == '5':
    cntrl_vars_init = [0,1]
    conv_init = [[True]*2] * len(exc)
    case_read = case[0] + case[1] + case[2] + str(int(case[3])-3) + '0'
    read_file = os.path.join( os.getcwd()[:-10], case_read, 'control_init_' + case_read + '.pickle')
    print(read_file)

if case[4] == '0':
    dur = 100
    trans_time = 0.8
elif case[4] == '1':
    dur = 400
    trans_time = 0.95
    
maxC = [5., -5., 0.18, 0.]

n_dur = int(np.around(dur/aln.params.dt + 1.,1))
max_cntrl, min_cntrl = setmaxmincontrol(maxC[0], maxC[1], maxC[2], maxC[3])

# %%
# get initial parameters and target states

i_range = [20, 50]
i_range_0 = i_range
i_range_1 = i_range
data.set_parameters(aln)

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    aln.params.duration = 3000.
    
    control0 = aln.getZeroControl()
    control0 = functions.step_control(aln, maxI_ = max_I[0])

    aln.run(control=control0)
    
    target_rates = np.zeros((2))
    target_rates[0] = aln.rates_exc[0,-1] 
    target_rates[1] = aln.rates_inh[0,-1]

    control0 = functions.step_control(aln, maxI_ = max_I[1])
    aln.run(control=control0)

    init_state_vars = np.zeros(( len(state_vars) ))
    for j in range(len(state_vars)):
        if aln.state[state_vars[j]].size == 1:
            init_state_vars[j] = aln.state[state_vars[j]][0]
        else:
            init_state_vars[j] = aln.state[state_vars[j]][0,-1]

    initVars[i] = init_state_vars
    
    aln.params.duration = dur

    target[i] = aln.getZeroTarget()
    target[i][:,0,:] = target_rates[0]
    target[i][:,1,:] = target_rates[1]
# Out:
# -------  20 0.4500000000000001 0.4750000000000002
# -------  50 0.47500000000000014 0.6000000000000003

# %%
aln.params.duration = dur
case = os.getcwd().split('task')[1][0]
read_file = os.getcwd().split('data_shift')[0] + os.sep + 'data_final' + os.sep + 'control_' + case + '.pickle'
print(read_file)

init_file = 'control_init.pickle'
final_file = 'control.pickle'
cntrl_vars_init = [0,1]
# Out:
# D:\Promotion\neurolib\GUI\current\gui\\data_final\control_2.pickle

# %%
# get uncontrolled cost

data.set_parameters(aln)

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    aln.params.duration = dur
        
    cost.setParams(1.0, 0.0, 0.0)

##### zero control as input for uncontrolled cost
    setinit(initVars[i], aln)
    control0 = aln.getZeroControl()

    # "HS", "FR", "PR", "HZ"
    cgv = None
    max_it = 0

    bestControl_init_, bestState_init_, cost_init_, runtime_init_, grad_init_, phi_init_, costnode_init_ = aln.A1(
        control0, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cntrl_vars_init,
        prec_variables_ = prec_vars, transition_time_ = trans_time)
    
    cost_uncontrolled[i] = cost_init_[0]
# Out:
# -------  20 0.4500000000000001 0.4750000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12738.116450271265
# Gradient descend method:  None
# RUN  0 , total integrated cost =  12738.116450271265
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  50 0.47500000000000014 0.6000000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  15942.955436075114
# Gradient descend method:  None
# RUN  0 , total integrated cost =  15942.955436075114
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.

# %%
for i in i_range:
    print("------- ", i, exc[i], inh[i])
    
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    with open(read_file,'rb') as f:
        load_array = pickle.load(f)

    bestControl_read = load_array[0]

    bestControl_init[i] = np.zeros(( 1, 6, n_dur + n_pre + n_post -2 ))
    bestControl_init[i][:,:,n_pre-1+1000:n_pre-1+4000] = 1.01 * bestControl_read[i][:,:,n_pre-1:n_pre-1+3000].copy()

    weight_ = 1.
    cost.setParams(1.0, weight_ * factor_we, weight_ * factor_ws)

    setinit(initVars[i], aln)

    # "HS", "FR", "PR", "HZ"
    cgv = None
    max_it = 0
    weights_init[i] = cost.getParams()
    
    control0 = bestControl_init[i][:,:,n_pre-1:-n_post+1].copy()


    bestControl_init[i], bestState_init[i], cost_init[i], runtime_init[i], grad_init[i], phi_init[i], costnode_init[i] = aln.A1(
        control0, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cntrl_vars_init,
        prec_variables_ = prec_vars, transition_time_ = trans_time)

    with open(init_file,'wb') as f:
            pickle.dump([bestControl_init, bestState_init, cost_init, runtime_init, grad_init, phi_init,
                     costnode_init, weights_init], f)
# Out:
# -------  20 0.4500000000000001 0.4750000000000002
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# ERROR:root:Problem in initial value trasfer
# RUN  0 , total integrated cost =  3.6234530950119224
# Gradient descend method:  None
# RUN  0 , total integrated cost =  3.6234530950119224
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# Problem in initial value trasfer:  Vmean_exc -56.669066686503264 -56.66906667034625
# -------  50 0.47500000000000014 0.6000000000000003
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11.240903582903206
# Gradient descend method:  None
# RUN  0 , total integrated cost =  11.240903582903206
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.

# %%
#plot initial guesses
for i in i_range:
    print("---------", i)
        
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.

    plotFunc.plot_control_current(aln, [bestControl_init[i]],
        [costnode_init[i]], [weights_init[i]], dur,
        dur_pre, dur_post, initVars[i], target[i], '', filename_ = '', transition_time_ = trans_time,
        labels_ = ["init", "sparse control" + str(i)], print_cost_ = False)
    plt.show()
# Out:
# --------- 20
# --------- 50

# %%
bestControl_1 = [None] * len(exc)
bestState_1 = [None] * len(exc)
cost_1 = [None] * len(exc)
runtime_1 = [None] * len(exc)
grad_1 = [None] * len(exc)
phi_1 = [None] * len(exc)
costnode_1 = [None] * len(exc)
weights_1 = [None] * len(exc)

conv_1 = [[False]*2] * len(exc)

# %%
if os.path.isfile(final_file) :
    print("file found")
    
    with open(final_file,'rb') as f:
        load_array = pickle.load(f)

    bestControl_1 = load_array[0]
    bestState_1 = load_array[1]
    cost_1 = load_array[2]
    runtime_1 = load_array[3]
    grad_1 = load_array[4]
    phi_1 = load_array[5]
    costnode_1 = load_array[6]
    weights_1 = load_array[7]
# Out:
# file found

# %%
factor_iteration = 5
full_converge = False
i_stepsize = 5

for i in range(len(conv_1)):
    if i not in i_range_1:
        conv_1[i] = [True, True]
        
counter = 0

while full_converge == False:
    
    print('---------------', counter)
    if counter > 5:
        break
    
    print(conv_1[::i_stepsize])
    full_converge = True
    
    for conv in conv_1[::i_stepsize]:
        if not conv[0]:
            full_converge = False
            break
        if not conv[1]:
            full_converge = False
            break
    
    if full_converge:
        print("full convergence")
        break

    for i in i_range_1:        

        print("------- ", i, exc[i], inh[i])
        
        if conv_1[i] == [True, True]:
            continue
            
        aln.params.ext_exc_current = exc[i] * 5.
        aln.params.ext_inh_current = inh[i] * 5.
        
        if not type(bestControl_1[i]) == type(None):
            control0 = bestControl_1[i][:,:,n_pre-1:-n_post+1].copy()
        else:
            control0 = bestControl_init[i][:,:,n_pre-1:-n_post+1].copy()
            cost_1[i] = cost_init[i]
        
        cost.setParams(1.0, 1. * factor_we, 1. * factor_ws)

        setinit(initVars[i], aln)

        # "HS", "FR", "PR", "HZ"
        cgv = None
        max_it = int( 500 * factor_iteration )

        weights_1[i] = cost.getParams()

        bestControl_1[i], bestState_1[i], cost_1[i], runtime_1[i], grad_1[i], phi_1[i], costnode_1[i] = aln.A1(
            control0, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cntrl_vars_init,
            prec_variables_ = prec_vars, transition_time_ = trans_time)
        
        with open(final_file,'wb') as f:
            pickle.dump([bestControl_1, bestState_1, cost_1, runtime_1, grad_1, phi_1,
                 costnode_1, weights_1], f)
            
        j = 1
        while cost_1[i][-j] == 0.:
            j += 1
            
        if j == cost_1[i].shape[0]-1:
            print("converged for ", i)
            if conv_1[i][0]:
                conv_1[i] = [True, True]
            else:
                conv_1[i] = [True, False]
            continue
    
        print("no convergence")
        
    counter += 1
# Out:
# --------------- 0
# [[True, True], [True, True], [True, True], [True, True], [False, False], [True, True], [True, True], [True, True], [True, True], [True, True], [False, False], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# -------  20 0.4500000000000001 0.4750000000000002
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5.550630865252526
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.546102949615538
# RUN  2 , total integrated cost =  5.5348828376613906
# RUN  3 , total integrated cost =  5.534731468944311
# RUN  4 , total integrated cost =  5.53472078591738
# RUN  5 , total integrated cost =  5.5347024771739175
# RUN  6 , total integrated cost =  5.534687933746699
# RUN  7 , total integrated cost =  5.5346783997307
# RUN  8 , total integrated cost =  5.5346668187260795
# RUN  9 , total integrated cost =  5.534653952081882
# RUN  10 , total integrated cost =  5.534641143053883
# RUN  11 , total integrated cost =  5.534627528432282
# RUN  12 , total integrated cost =  5.534614382062911
# RUN  13 , total integrated cost =  5.534598644104829
# RUN  14 , total integrated cost =  5.5345886441354555
# RUN  15 , total integrated cost =  5.534578590274057
# RUN  16 , total integrated cost =  5.534566908108959
# RUN  17 , total integrated cost =  5.534554254884594
# RUN  18 , total integrated cost =  5.534541616290122
# RUN  19 , total integrated cost =  5.534527794347126
# RUN  20 , total integrated cost =  5.534514643563502
# RUN  30 , total integrated cost =  5.534389446626005
# RUN  40 , total integrated cost =  5.534268185979152
# RUN  50 , total integrated cost =  5.534143537543979
# RUN  60 , total integrated cost =  5.533994113219265
# RUN  70 , total integrated cost =  5.53389663824073
# RUN  80 , total integrated cost =  5.533799114179191
# RUN  90 , total integrated cost =  5.533701540071393
# RUN  100 , total integrated cost =  5.533603910322759
# RUN  110 , total integrated cost =  5.533506224443176
# RUN  120 , total integrated cost =  5.533408489236164
# RUN  130 , total integrated cost =  5.533310705684574
# RUN  140 , total integrated cost =  5.533199648360305
# RUN  150 , total integrated cost =  5.533088203889219
# RUN  160 , total integrated cost =  5.532978592407728
# RUN  170 , total integrated cost =  5.532866022347025
# RUN  180 , total integrated cost =  5.532755520044645
# RUN  190 , total integrated cost =  5.532642891916589
# RUN  200 , total integrated cost =  5.532530199031469
# RUN  300 , total integrated cost =  5.531395345082828
# RUN  400 , total integrated cost =  5.52984017606796
# RUN  500 , total integrated cost =  5.528160447041229
# RUN  600 , total integrated cost =  5.527394770241389
# RUN  700 , total integrated cost =  5.526557954416983
# RUN  800 , total integrated cost =  5.525732317893013
# RUN  900 , total integrated cost =  5.524962820460758
# RUN  1000 , total integrated cost =  5.524186639952473
# RUN  1100 , total integrated cost =  5.52339655326885
# RUN  1200 , total integrated cost =  5.522609957836873
# RUN  1300 , total integrated cost =  5.521820003431853
# RUN  1400 , total integrated cost =  5.520974574357832
# RUN  1500 , total integrated cost =  5.520159177177985
# RUN  1600 , total integrated cost =  5.51908027065739
# RUN  1700 , total integrated cost =  5.518192724152378
# RUN  1800 , total integrated cost =  5.517369012065423
# RUN  1900 , total integrated cost =  5.516447295160531
# RUN  2000 , total integrated cost =  5.515574758097533
# ERROR:root:Problem in initial value trasfer
# RUN  2500 , total integrated cost =  5.511542648304035
# Improved over  2500  iterations in  580.4477287999999  seconds by  0.7042121498870841  percent.
# Problem in initial value trasfer:  Vmean_exc -56.66906639936946 -56.66906642458086
# no convergence
# -------  50 0.47500000000000014 0.6000000000000003
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12.5322219440653
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12.532217772025424
# RUN  2 , total integrated cost =  12.532212772969475
# RUN  3 , total integrated cost =  12.53220945019444
# RUN  4 , total integrated cost =  12.532204222021537
# RUN  5 , total integrated cost =  12.53219872150197
# RUN  6 , total integrated cost =  12.532175835398977
# RUN  7 , total integrated cost =  12.532144913876982
# RUN  8 , total integrated cost =  12.532141146379777
# RUN  9 , total integrated cost =  12.499972377810314
# RUN  10 , total integrated cost =  12.452388246445587
# RUN  11 , total integrated cost =  12.420389406876383
# RUN  12 , total integrated cost =  12.38910103551004
# RUN  13 , total integrated cost =  12.358000079168363
# RUN  14 , total integrated cost =  12.356016590299031
# RUN  15 , total integrated cost =  12.356014694116867
# RUN  16 , total integrated cost =  12.356014089400267
# RUN  17 , total integrated cost =  12.3490329755032
# RUN  18 , total integrated cost =  12.34786595367826
# RUN  19 , total integrated cost =  12.347862279717086
# RUN  20 , total integrated cost =  12.347861380607036
# RUN  30 , total integrated cost =  12.347805094392745
# RUN  40 , total integrated cost =  12.347688847526307
# RUN  50 , total integrated cost =  12.318935636283591
# RUN  60 , total integrated cost =  12.318929986743877
# RUN  70 , total integrated cost =  12.31892433651491
# RUN  80 , total integrated cost =  12.318918685584752
# RUN  90 , total integrated cost =  12.318913033953066
# RUN  100 , total integrated cost =  12.318907381619821
# RUN  110 , total integrated cost =  12.31890172858477
# RUN  120 , total integrated cost =  12.318896074847158
# RUN  130 , total integrated cost =  12.318890420329428
# RUN  140 , total integrated cost =  12.318884765093046
# RUN  150 , total integrated cost =  12.318879109143879
# RUN  160 , total integrated cost =  12.31887345247835
# RUN  170 , total integrated cost =  12.318867795005676
# RUN  180 , total integrated cost =  12.318862136648063
# RUN  190 , total integrated cost =  12.318856477402973
# RUN  200 , total integrated cost =  12.318850817261755
# RUN  300 , total integrated cost =  12.318794166165192
# RUN  400 , total integrated cost =  12.318737422738351
# RUN  500 , total integrated cost =  12.318680601197897
# RUN  600 , total integrated cost =  12.31862370597023
# RUN  700 , total integrated cost =  12.31856672075312
# RUN  800 , total integrated cost =  12.318509640778375
# RUN  900 , total integrated cost =  12.318452481941511
# RUN  1000 , total integrated cost =  12.318395253340933
# RUN  1100 , total integrated cost =  12.318337958043593
# RUN  1200 , total integrated cost =  12.318280588202926
# RUN  1300 , total integrated cost =  12.318223133737426
# RUN  1400 , total integrated cost =  12.3181655974289
# RUN  1500 , total integrated cost =  12.318107990930214
# RUN  1600 , total integrated cost =  12.318050325659158
# RUN  1700 , total integrated cost =  12.317992603376739
# RUN  1800 , total integrated cost =  12.317934823982412
# RUN  1900 , total integrated cost =  12.317876985764727
# RUN  2000 , total integrated cost =  12.317819370626435
# RUN  2500 , total integrated cost =  12.317547139426123
# Improved over  2500  iterations in  583.5494135  seconds by  1.712982786271482  percent.
# no convergence
# --------------- 1
# [[True, True], [True, True], [True, True], [True, True], [False, False], [True, True], [True, True], [True, True], [True, True], [True, True], [False, False], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# -------  20 0.4500000000000001 0.4750000000000002
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5.511542648304035
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.511534623978804
# RUN  2 , total integrated cost =  5.511526603455598
# RUN  3 , total integrated cost =  5.511518878632973
# RUN  4 , total integrated cost =  5.511510591579503
# RUN  5 , total integrated cost =  5.511502546455801
# RUN  6 , total integrated cost =  5.511494547767346
# RUN  7 , total integrated cost =  5.511486844807439
# RUN  8 , total integrated cost =  5.511478538386879
# RUN  9 , total integrated cost =  5.511470475866321
# RUN  10 , total integrated cost =  5.511462492370875
# RUN  11 , total integrated cost =  5.511454777892217
# RUN  12 , total integrated cost =  5.511446485207377
# RUN  13 , total integrated cost =  5.511438475977291
# RUN  14 , total integrated cost =  5.511430444345885
# RUN  15 , total integrated cost =  5.5114227197315175
# RUN  16 , total integrated cost =  5.511414433281004
# RUN  17 , total integrated cost =  5.5114064256751085
# RUN  18 , total integrated cost =  5.511398392726309
# RUN  19 , total integrated cost =  5.511390672155956
# RUN  20 , total integrated cost =  5.511382381389981
# RUN  30 , total integrated cost =  5.511302230877831
# RUN  40 , total integrated cost =  5.51122211893155
# RUN  50 , total integrated cost =  5.511141977562403
# RUN  60 , total integrated cost =  5.511061853909221
# RUN  70 , total integrated cost =  5.5109817169694635
# RUN  80 , total integrated cost =  5.510901611042474
# RUN  90 , total integrated cost =  5.5108214788949095
# RUN  100 , total integrated cost =  5.510741376733195
# RUN  110 , total integrated cost =  5.510661242702988
# RUN  120 , total integrated cost =  5.510572334760791
# RUN  130 , total integrated cost =  5.510482618547218
# RUN  140 , total integrated cost =  5.51039860156323
# RUN  150 , total integrated cost =  5.510313616759569
# RUN  160 , total integrated cost =  5.510224210166419
# RUN  170 , total integrated cost =  5.5101312989541364
# RUN  180 , total integrated cost =  5.510038470646847
# RUN  190 , total integrated cost =  5.509945483652626
# RUN  200 , total integrated cost =  5.509852329114717
# RUN  300 , total integrated cost =  5.508978386363404
# RUN  400 , total integrated cost =  5.508170264992796
# RUN  500 , total integrated cost =  5.39231713284438
# RUN  600 , total integrated cost =  5.389005752147852
# RUN  700 , total integrated cost =  5.386156708992511
# RUN  800 , total integrated cost =  5.383677197442202
# RUN  900 , total integrated cost =  5.3816367233152524
# RUN  1000 , total integrated cost =  5.379571619576642
# RUN  1100 , total integrated cost =  5.377614048648359
# RUN  1200 , total integrated cost =  5.37572654462757
# RUN  1300 , total integrated cost =  5.374116298069607
# RUN  1400 , total integrated cost =  5.3723747427845865
# RUN  1500 , total integrated cost =  5.370894177591702
# RUN  1600 , total integrated cost =  5.369230099448186
# RUN  1700 , total integrated cost =  5.367900400903167
# RUN  1800 , total integrated cost =  5.366579913619754
# RUN  1900 , total integrated cost =  5.365104274476091
# RUN  2000 , total integrated cost =  5.363824773312062
# ERROR:root:Problem in initial value trasfer
# RUN  2500 , total integrated cost =  5.357851154534452
# Improved over  2500  iterations in  698.2498995000001  seconds by  2.7885385921285604  percent.
# Problem in initial value trasfer:  Vmean_exc -56.66906647909792 -56.669066498556994
# no convergence
# -------  50 0.47500000000000014 0.6000000000000003
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12.317547139426123
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12.317546558618647
# RUN  2 , total integrated cost =  12.31754604653779
# RUN  3 , total integrated cost =  12.317545515434748
# RUN  4 , total integrated cost =  12.317544959128467
# RUN  5 , total integrated cost =  12.317544378315533
# RUN  6 , total integrated cost =  12.31754386617931
# RUN  7 , total integrated cost =  12.317543335105215
# RUN  8 , total integrated cost =  12.317542778735477
# RUN  9 , total integrated cost =  12.31754219791716
# RUN  10 , total integrated cost =  12.317541685725542
# RUN  11 , total integrated cost =  12.317541154680274
# RUN  12 , total integrated cost =  12.317540598247213
# RUN  13 , total integrated cost =  12.317540017423363
# RUN  14 , total integrated cost =  12.317539505176354
# RUN  15 , total integrated cost =  12.31753897415997
# RUN  16 , total integrated cost =  12.317538417663622
# RUN  17 , total integrated cost =  12.317537836834173
# RUN  18 , total integrated cost =  12.317537324531665
# RUN  19 , total integrated cost =  12.317536793544075
# RUN  20 , total integrated cost =  12.31753623698421
# RUN  30 , total integrated cost =  12.317530782020226
# RUN  40 , total integrated cost =  12.317525332147742
# RUN  50 , total integrated cost =  12.31751987596776
# RUN  60 , total integrated cost =  12.317514424999231
# RUN  70 , total integrated cost =  12.317508993117265
# RUN  80 , total integrated cost =  12.317503574369336
# RUN  90 , total integrated cost =  12.31749815519121
# RUN  100 , total integrated cost =  12.317492735679464
# RUN  110 , total integrated cost =  12.317487318039968
# RUN  120 , total integrated cost =  12.317481898793185
# RUN  130 , total integrated cost =  12.317476479716216
# RUN  140 , total integrated cost =  12.31747105958732
# RUN  150 , total integrated cost =  12.317465639619185
# RUN  160 , total integrated cost =  12.317460219246009
# RUN  170 , total integrated cost =  12.317454799598186
# RUN  180 , total integrated cost =  12.317449379506122
# RUN  190 , total integrated cost =  12.317443958969271
# RUN  200 , total integrated cost =  12.31743853797996
# RUN  300 , total integrated cost =  12.317384298395993
# RUN  400 , total integrated cost =  12.317329994240367
# RUN  500 , total integrated cost =  12.317275627326381
# RUN  600 , total integrated cost =  12.317221224222445
# RUN  700 , total integrated cost =  12.317166757732815
# RUN  800 , total integrated cost =  12.317112227738386
# RUN  900 , total integrated cost =  12.317057634800543
# RUN  1000 , total integrated cost =  12.317002979675651
# RUN  1100 , total integrated cost =  12.31694826640749
# RUN  1200 , total integrated cost =  12.316893505274766
# RUN  1300 , total integrated cost =  12.3168387100368
# RUN  1400 , total integrated cost =  12.31678386072766
# RUN  1500 , total integrated cost =  12.316731620518187
# RUN  1600 , total integrated cost =  12.316679991629961
# RUN  1700 , total integrated cost =  12.31662831295074
# RUN  1800 , total integrated cost =  12.316576580649373
# RUN  1900 , total integrated cost =  12.316524792219484
# RUN  2000 , total integrated cost =  12.31647295027943
# RUN  2500 , total integrated cost =  12.316212863305918
# Improved over  2500  iterations in  743.2874652  seconds by  0.01083231998305223  percent.
# no convergence
# --------------- 2
# [[True, True], [True, True], [True, True], [True, True], [False, False], [True, True], [True, True], [True, True], [True, True], [True, True], [False, False], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# -------  20 0.4500000000000001 0.4750000000000002
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5.357851154534452
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.357841562047574
# RUN  2 , total integrated cost =  5.357831779994475
# RUN  3 , total integrated cost =  5.357822183152164
# RUN  4 , total integrated cost =  5.357812397033129
# RUN  5 , total integrated cost =  5.357802796769345
# RUN  6 , total integrated cost =  5.357793005684416
# RUN  7 , total integrated cost =  5.357783403158856
# RUN  8 , total integrated cost =  5.357773605989482
# RUN  9 , total integrated cost =  5.3577639988207615
# RUN  10 , total integrated cost =  5.3577541976054
# RUN  11 , total integrated cost =  5.357744585956114
# RUN  12 , total integrated cost =  5.3577347806822075
# RUN  13 , total integrated cost =  5.357725164556353
# RUN  14 , total integrated cost =  5.357715355214586
# RUN  15 , total integrated cost =  5.357705734537302
# RUN  16 , total integrated cost =  5.357695921090722
# RUN  17 , total integrated cost =  5.357686295760445
# RUN  18 , total integrated cost =  5.35767647820362
# RUN  19 , total integrated cost =  5.357666848760456
# RUN  20 , total integrated cost =  5.357657027041784
# RUN  30 , total integrated cost =  5.357559644991847
# RUN  40 , total integrated cost =  5.357462034493786
# RUN  50 , total integrated cost =  5.357364193634802
# RUN  60 , total integrated cost =  5.357263980437455
# RUN  70 , total integrated cost =  5.357160802112487
# RUN  80 , total integrated cost =  5.357056472926017
# RUN  90 , total integrated cost =  5.356956244048768
# RUN  100 , total integrated cost =  5.356858361544113
# RUN  110 , total integrated cost =  5.356760320479231
# RUN  120 , total integrated cost =  5.356658522594304
# RUN  130 , total integrated cost =  5.356553025304652
# RUN  140 , total integrated cost =  5.356446822728845
# RUN  150 , total integrated cost =  5.3563436757197955
# RUN  160 , total integrated cost =  5.356244556605785
# RUN  170 , total integrated cost =  5.356145246798698
# RUN  180 , total integrated cost =  5.356045755715565
# RUN  190 , total integrated cost =  5.355946095115653
# RUN  200 , total integrated cost =  5.355846276161676
# RUN  300 , total integrated cost =  5.354855713912168
# RUN  400 , total integrated cost =  5.353798026405287
# RUN  500 , total integrated cost =  5.352676002673131
# RUN  600 , total integrated cost =  5.351729593565413
# RUN  700 , total integrated cost =  5.350804384876139
# RUN  800 , total integrated cost =  5.349851161895642
# RUN  900 , total integrated cost =  5.348804484741465
# RUN  1000 , total integrated cost =  5.3478840151573594
# RUN  1100 , total integrated cost =  5.3469460664780675
# RUN  1200 , total integrated cost =  5.346029088839205
# RUN  1300 , total integrated cost =  5.3450572213778855
# RUN  1400 , total integrated cost =  5.344066881743002
# RUN  1500 , total integrated cost =  5.343243001720759
# RUN  1600 , total integrated cost =  5.342488858499626
# RUN  1700 , total integrated cost =  5.341680546397211
# RUN  1800 , total integrated cost =  5.340900307720624
# RUN  1900 , total integrated cost =  5.34015089029377
# RUN  2000 , total integrated cost =  5.339379955231946
# ERROR:root:Problem in initial value trasfer
# RUN  2500 , total integrated cost =  5.3354079100691765
# Improved over  2500  iterations in  618.4989059  seconds by  0.41888518023277754  percent.
# Problem in initial value trasfer:  Vmean_exc -56.66906644328865 -56.6690664611408
# no convergence
# -------  50 0.47500000000000014 0.6000000000000003
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12.316212863305918
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12.316212365767795
# RUN  2 , total integrated cost =  12.316211820350471
# RUN  3 , total integrated cost =  12.31621132281955
# RUN  4 , total integrated cost =  12.316210777372799
# RUN  5 , total integrated cost =  12.316210279849022
# RUN  6 , total integrated cost =  12.316209734372924
# RUN  7 , total integrated cost =  12.316209236856256
# RUN  8 , total integrated cost =  12.316208691350802
# RUN  9 , total integrated cost =  12.316208193841215
# RUN  10 , total integrated cost =  12.316207648306387
# RUN  11 , total integrated cost =  12.316207150804011
# RUN  12 , total integrated cost =  12.316206605239843
# RUN  13 , total integrated cost =  12.316206107744586
# RUN  14 , total integrated cost =  12.316205562150977
# RUN  15 , total integrated cost =  12.316205064662801
# RUN  16 , total integrated cost =  12.31620451903986
# RUN  17 , total integrated cost =  12.3162040215589
# RUN  18 , total integrated cost =  12.316203475906551
# RUN  19 , total integrated cost =  12.316202978432615
# RUN  20 , total integrated cost =  12.316202432751028
# RUN  30 , total integrated cost =  12.31619721663958
# RUN  40 , total integrated cost =  12.316191999971918
# RUN  50 , total integrated cost =  12.316186782747993
# RUN  60 , total integrated cost =  12.316181564967561
# RUN  70 , total integrated cost =  12.316176346630156
# RUN  80 , total integrated cost =  12.316171127732861
# RUN  90 , total integrated cost =  12.316165908274543
# RUN  100 , total integrated cost =  12.31616068825499
# RUN  110 , total integrated cost =  12.316155467674267
# RUN  120 , total integrated cost =  12.316150246531963
# RUN  130 , total integrated cost =  12.316145024823344
# RUN  140 , total integrated cost =  12.316139802541576
# RUN  150 , total integrated cost =  12.316134579686343
# RUN  160 , total integrated cost =  12.316129356256017
# RUN  170 , total integrated cost =  12.316124132228326
# RUN  180 , total integrated cost =  12.31611890757764
# RUN  190 , total integrated cost =  12.31611368233588
# RUN  200 , total integrated cost =  12.316108456597355
# RUN  300 , total integrated cost =  12.316056170231247
# RUN  400 , total integrated cost =  12.316003829108661
# RUN  500 , total integrated cost =  12.315951435855833
# RUN  600 , total integrated cost =  12.315898979760732
# RUN  700 , total integrated cost =  12.315846451872098
# RUN  800 , total integrated cost =  12.315793860157706
# RUN  900 , total integrated cost =  12.315746735442573
# RUN  1000 , total integrated cost =  12.31569955732019
# RUN  1100 , total integrated cost =  12.315652331600594
# RUN  1200 , total integrated cost =  12.315605057322012
# RUN  1300 , total integrated cost =  12.315557748322794
# RUN  1400 , total integrated cost =  12.315510402077097
# RUN  1500 , total integrated cost =  12.315463015715247
# RUN  1600 , total integrated cost =  12.31541558272137
# RUN  1700 , total integrated cost =  12.315368101766635
# RUN  1800 , total integrated cost =  12.315320578597866
# RUN  1900 , total integrated cost =  12.31527301843002
# RUN  2000 , total integrated cost =  12.315225426892857
# RUN  2500 , total integrated cost =  12.314986913721478
# Improved over  2500  iterations in  703.7998470000002  seconds by  0.009953949302811793  percent.
# no convergence
# --------------- 3
# [[True, True], [True, True], [True, True], [True, True], [False, False], [True, True], [True, True], [True, True], [True, True], [True, True], [False, False], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# -------  20 0.4500000000000001 0.4750000000000002
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5.3354079100691765
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.335401224514272
# RUN  2 , total integrated cost =  5.335394566172449
# RUN  3 , total integrated cost =  5.335388058459706
# RUN  4 , total integrated cost =  5.335381162796112
# RUN  5 , total integrated cost =  5.335374450968727
# RUN  6 , total integrated cost =  5.335367797913809
# RUN  7 , total integrated cost =  5.335361301356523
# RUN  8 , total integrated cost =  5.33535443638876
# RUN  9 , total integrated cost =  5.335347666297044
# RUN  10 , total integrated cost =  5.335341016766408
# RUN  11 , total integrated cost =  5.335334528368544
# RUN  12 , total integrated cost =  5.335327686165735
# RUN  13 , total integrated cost =  5.335320873731329
# RUN  14 , total integrated cost =  5.335314228662361
# RUN  15 , total integrated cost =  5.335307750090252
# RUN  16 , total integrated cost =  5.33530093501033
# RUN  17 , total integrated cost =  5.335294071617636
# RUN  18 , total integrated cost =  5.3352874305614195
# RUN  19 , total integrated cost =  5.3352809610851875
# RUN  20 , total integrated cost =  5.335274171247558
# RUN  30 , total integrated cost =  5.335206326699216
# RUN  40 , total integrated cost =  5.335139092272421
# RUN  50 , total integrated cost =  5.335072199415206
# RUN  60 , total integrated cost =  5.335005494023433
# RUN  70 , total integrated cost =  5.334938766115236
# RUN  80 , total integrated cost =  5.334872651996649
# RUN  90 , total integrated cost =  5.334795603419617
# RUN  100 , total integrated cost =  5.334721679263038
# RUN  110 , total integrated cost =  5.334653299781794
# RUN  120 , total integrated cost =  5.3345879953964515
# RUN  130 , total integrated cost =  5.33452257910337
# RUN  140 , total integrated cost =  5.334457111633448
# RUN  150 , total integrated cost =  5.334391593509022
# RUN  160 , total integrated cost =  5.334326034942388
# RUN  170 , total integrated cost =  5.334260429411151
# RUN  180 , total integrated cost =  5.334194781884976
# RUN  190 , total integrated cost =  5.334129088226797
# RUN  200 , total integrated cost =  5.334063351854661
# RUN  300 , total integrated cost =  5.333404123778437
# RUN  400 , total integrated cost =  5.332647068140375
# RUN  500 , total integrated cost =  5.331768584179599
# RUN  600 , total integrated cost =  5.3309276868126965
# RUN  700 , total integrated cost =  5.33019335662104
# RUN  800 , total integrated cost =  5.329520145295451
# RUN  900 , total integrated cost =  5.328890956709667
# RUN  1000 , total integrated cost =  5.328264577974377
# RUN  1100 , total integrated cost =  5.327636811123045
# RUN  1200 , total integrated cost =  5.32696785344864
# RUN  1300 , total integrated cost =  5.326375304080547
# RUN  1400 , total integrated cost =  5.325786039442173
# RUN  1500 , total integrated cost =  5.325194985368314
# RUN  1600 , total integrated cost =  5.324532291987983
# RUN  1700 , total integrated cost =  5.323798869848971
# RUN  1800 , total integrated cost =  5.322948831084301
# RUN  1900 , total integrated cost =  5.322236384801672
# RUN  2000 , total integrated cost =  5.321589321743289
# ERROR:root:Problem in initial value trasfer
# RUN  2500 , total integrated cost =  5.318734346973922
# Improved over  2500  iterations in  696.6074030999998  seconds by  0.31250774779164203  percent.
# Problem in initial value trasfer:  Vmean_exc -56.669066422750255 -56.66906644121253
# no convergence
# -------  50 0.47500000000000014 0.6000000000000003
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12.314986913721478
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12.314986435621776
# RUN  2 , total integrated cost =  12.314985957534962
# RUN  3 , total integrated cost =  12.314985479435911
# RUN  4 , total integrated cost =  12.314985001332108
# RUN  5 , total integrated cost =  12.314984523233896
# RUN  6 , total integrated cost =  12.31498404511305
# RUN  7 , total integrated cost =  12.314983567015545
# RUN  8 , total integrated cost =  12.314983088877765
# RUN  9 , total integrated cost =  12.31498261078098
# RUN  10 , total integrated cost =  12.314982132626142
# RUN  11 , total integrated cost =  12.314981654530138
# RUN  12 , total integrated cost =  12.31498117635829
# RUN  13 , total integrated cost =  12.314980698262952
# RUN  14 , total integrated cost =  12.314980220074112
# RUN  15 , total integrated cost =  12.314979741979508
# RUN  16 , total integrated cost =  12.314979263773681
# RUN  17 , total integrated cost =  12.314978785679905
# RUN  18 , total integrated cost =  12.314978307457073
# RUN  19 , total integrated cost =  12.31497782936393
# RUN  20 , total integrated cost =  12.314977351124076
# RUN  30 , total integrated cost =  12.314972569215314
# RUN  40 , total integrated cost =  12.314967786899254
# RUN  50 , total integrated cost =  12.314963004174132
# RUN  60 , total integrated cost =  12.314958221033798
# RUN  70 , total integrated cost =  12.314953437472147
# RUN  80 , total integrated cost =  12.31494865349698
# RUN  90 , total integrated cost =  12.314943869175034
# RUN  100 , total integrated cost =  12.314939084531028
# RUN  110 , total integrated cost =  12.31493429957033
# RUN  120 , total integrated cost =  12.314929514293167
# RUN  130 , total integrated cost =  12.314924728699394
# RUN  140 , total integrated cost =  12.314919942788748
# RUN  150 , total integrated cost =  12.31491515656168
# RUN  160 , total integrated cost =  12.314910370018138
# RUN  170 , total integrated cost =  12.314905583158149
# RUN  180 , total integrated cost =  12.314900795981687
# RUN  190 , total integrated cost =  12.3148960084887
# RUN  200 , total integrated cost =  12.314891220679193
# RUN  300 , total integrated cost =  12.31484332520739
# RUN  400 , total integrated cost =  12.314795398315482
# RUN  500 , total integrated cost =  12.314747439683867
# RUN  600 , total integrated cost =  12.31469945000325
# RUN  700 , total integrated cost =  12.314651429471938
# RUN  800 , total integrated cost =  12.314603375964309
# RUN  900 , total integrated cost =  12.3145552872015
# RUN  1000 , total integrated cost =  12.314507162918236
# RUN  1100 , total integrated cost =  12.314459003780565
# RUN  1200 , total integrated cost =  12.314410808127366
# RUN  1300 , total integrated cost =  12.314362575679393
# RUN  1400 , total integrated cost =  12.314314304148336
# RUN  1500 , total integrated cost =  12.314265995387462
# RUN  1600 , total integrated cost =  12.314217651476493
# RUN  1700 , total integrated cost =  12.314169273659266
# RUN  1800 , total integrated cost =  12.314120861692622
# RUN  1900 , total integrated cost =  12.314074138660706
# RUN  2000 , total integrated cost =  12.314028974866003
# RUN  2500 , total integrated cost =  12.313802719741876
# Improved over  2500  iterations in  768.8265023000004  seconds by  0.009615876881554186  percent.
# no convergence
# --------------- 4
# [[True, True], [True, True], [True, True], [True, True], [False, False], [True, True], [True, True], [True, True], [True, True], [True, True], [False, False], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# -------  20 0.4500000000000001 0.4750000000000002
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5.318734346973922
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.318728170031081
# RUN  2 , total integrated cost =  5.318722749053895
# RUN  3 , total integrated cost =  5.318717576545906
# RUN  4 , total integrated cost =  5.318711782399004
# RUN  5 , total integrated cost =  5.318705582006018
# RUN  6 , total integrated cost =  5.318700160330695
# RUN  7 , total integrated cost =  5.31869499077151
# RUN  8 , total integrated cost =  5.318689210890922
# RUN  9 , total integrated cost =  5.318682987040839
# RUN  10 , total integrated cost =  5.318677564668591
# RUN  11 , total integrated cost =  5.318672397937357
# RUN  12 , total integrated cost =  5.318666631762313
# RUN  13 , total integrated cost =  5.318660385489119
# RUN  14 , total integrated cost =  5.318654962360226
# RUN  15 , total integrated cost =  5.318649798391853
# RUN  16 , total integrated cost =  5.318644045648768
# RUN  17 , total integrated cost =  5.318637777471525
# RUN  18 , total integrated cost =  5.318632353549859
# RUN  19 , total integrated cost =  5.318627192334061
# RUN  20 , total integrated cost =  5.318621453012676
# RUN  30 , total integrated cost =  5.318564488064044
# RUN  40 , total integrated cost =  5.318503894679324
# RUN  50 , total integrated cost =  5.318444414476973
# RUN  60 , total integrated cost =  5.318381210241368
# RUN  70 , total integrated cost =  5.318320855487255
# RUN  80 , total integrated cost =  5.318259334011689
# RUN  90 , total integrated cost =  5.318195956771915
# RUN  100 , total integrated cost =  5.318135492123493
# RUN  110 , total integrated cost =  5.318074012707712
# RUN  120 , total integrated cost =  5.3180103779425165
# RUN  130 , total integrated cost =  5.317949825628899
# RUN  140 , total integrated cost =  5.3178882845250595
# RUN  150 , total integrated cost =  5.317824434842364
# RUN  160 , total integrated cost =  5.317763772837297
# RUN  170 , total integrated cost =  5.317702221437737
# RUN  180 , total integrated cost =  5.3176381573382
# RUN  190 , total integrated cost =  5.317581136387521
# RUN  200 , total integrated cost =  5.3175207807019875
# RUN  300 , total integrated cost =  5.316952655682841
# RUN  400 , total integrated cost =  5.3164346625125365
# RUN  500 , total integrated cost =  5.31591450501602
# RUN  600 , total integrated cost =  5.315392802788249
# RUN  700 , total integrated cost =  5.314870293481614
# RUN  800 , total integrated cost =  5.3141972678354055
# RUN  900 , total integrated cost =  5.313483792671007
# RUN  1000 , total integrated cost =  5.312829274675326
# RUN  1100 , total integrated cost =  5.31222558868944
# RUN  1200 , total integrated cost =  5.311655299931645
# RUN  1300 , total integrated cost =  5.311114681870033
# RUN  1400 , total integrated cost =  5.310597080006201
# RUN  1500 , total integrated cost =  5.310107525490803
# RUN  1600 , total integrated cost =  5.3096153079449095
# RUN  1700 , total integrated cost =  5.30912402169125
# RUN  1800 , total integrated cost =  5.308655902452191
# RUN  1900 , total integrated cost =  5.308185175166781
# RUN  2000 , total integrated cost =  5.307706227156336
# ERROR:root:Problem in initial value trasfer
# RUN  2500 , total integrated cost =  5.305184711390577
# Improved over  2500  iterations in  668.1071574999996  seconds by  0.25475300512147214  percent.
# Problem in initial value trasfer:  Vmean_exc -56.669066426312895 -56.669066444455474
# no convergence
# -------  50 0.47500000000000014 0.6000000000000003
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12.313802719741876
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12.313802241175836
# RUN  2 , total integrated cost =  12.313801813023082
# RUN  3 , total integrated cost =  12.313801334457322
# RUN  4 , total integrated cost =  12.313800906292126
# RUN  5 , total integrated cost =  12.313800427726669
# RUN  6 , total integrated cost =  12.313799999549053
# RUN  7 , total integrated cost =  12.313799520983935
# RUN  8 , total integrated cost =  12.313799092793857
# RUN  9 , total integrated cost =  12.313798614228977
# RUN  10 , total integrated cost =  12.313798186026505
# RUN  11 , total integrated cost =  12.313797707461916
# RUN  12 , total integrated cost =  12.313797279247021
# RUN  13 , total integrated cost =  12.313796800682807
# RUN  14 , total integrated cost =  12.313796372455453
# RUN  15 , total integrated cost =  12.313795893891427
# RUN  16 , total integrated cost =  12.313795465651697
# RUN  17 , total integrated cost =  12.31379498708797
# RUN  18 , total integrated cost =  12.313794558835756
# RUN  19 , total integrated cost =  12.313794080272267
# RUN  20 , total integrated cost =  12.31379365200765
# RUN  30 , total integrated cost =  12.313789117684045
# RUN  40 , total integrated cost =  12.313784583055826
# RUN  50 , total integrated cost =  12.31378004812286
# RUN  60 , total integrated cost =  12.313775512885114
# RUN  70 , total integrated cost =  12.313770977342681
# RUN  80 , total integrated cost =  12.313766441495488
# RUN  90 , total integrated cost =  12.313761905343585
# RUN  100 , total integrated cost =  12.313757368883934
# RUN  110 , total integrated cost =  12.313752832113007
# RUN  120 , total integrated cost =  12.313748295030853
# RUN  130 , total integrated cost =  12.313743757637468
# RUN  140 , total integrated cost =  12.313739219932765
# RUN  150 , total integrated cost =  12.313734681916698
# RUN  160 , total integrated cost =  12.313730143589293
# RUN  170 , total integrated cost =  12.31372560495024
# RUN  180 , total integrated cost =  12.313721065998092
# RUN  190 , total integrated cost =  12.313716526732373
# RUN  200 , total integrated cost =  12.313711987153608
# RUN  300 , total integrated cost =  12.31366657426075
# RUN  400 , total integrated cost =  12.313621131125698
# RUN  500 , total integrated cost =  12.313575658543243
# RUN  600 , total integrated cost =  12.313530156526692
# RUN  700 , total integrated cost =  12.313484625616482
# RUN  800 , total integrated cost =  12.313439066597661
# RUN  900 , total integrated cost =  12.313393480045788
# RUN  1000 , total integrated cost =  12.313347866267025
# RUN  1100 , total integrated cost =  12.31330222414277
# RUN  1200 , total integrated cost =  12.313256553264091
# RUN  1300 , total integrated cost =  12.31321085342534
# RUN  1400 , total integrated cost =  12.313165124320205
# RUN  1500 , total integrated cost =  12.313119365680153
# RUN  1600 , total integrated cost =  12.313073578653482
# RUN  1700 , total integrated cost =  12.313027763310043
# RUN  1800 , total integrated cost =  12.312981914914532
# RUN  1900 , total integrated cost =  12.312936031951399
# RUN  2000 , total integrated cost =  12.312890112225897
# RUN  2500 , total integrated cost =  12.312659906727022
# Improved over  2500  iterations in  663.7870211999998  seconds by  0.00928074812357238  percent.
# no convergence
# --------------- 5
# [[True, True], [True, True], [True, True], [True, True], [False, False], [True, True], [True, True], [True, True], [True, True], [True, True], [False, False], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True], [True, True]]
# -------  20 0.4500000000000001 0.4750000000000002
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5.305184711390577
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.305179736119947
# RUN  2 , total integrated cost =  5.305175006914652
# RUN  3 , total integrated cost =  5.30517002922862
# RUN  4 , total integrated cost =  5.305165301584961
# RUN  5 , total integrated cost =  5.30516032147487
# RUN  6 , total integrated cost =  5.3051555954146234
# RUN  7 , total integrated cost =  5.305150612847509
# RUN  8 , total integrated cost =  5.305145888368885
# RUN  9 , total integrated cost =  5.305140903348761
# RUN  10 , total integrated cost =  5.305136180449302
# RUN  11 , total integrated cost =  5.305131192980246
# RUN  12 , total integrated cost =  5.305126471661612
# RUN  13 , total integrated cost =  5.305121481741222
# RUN  14 , total integrated cost =  5.3051167620050705
# RUN  15 , total integrated cost =  5.305111769631429
# RUN  16 , total integrated cost =  5.30510705148864
# RUN  17 , total integrated cost =  5.305102056642064
# RUN  18 , total integrated cost =  5.305097340093967
# RUN  19 , total integrated cost =  5.305092342772813
# RUN  20 , total integrated cost =  5.3050876278210115
# RUN  30 , total integrated cost =  5.305039053516009
# RUN  40 , total integrated cost =  5.304990455813803
# RUN  50 , total integrated cost =  5.30494183310686
# RUN  60 , total integrated cost =  5.30489318520095
# RUN  70 , total integrated cost =  5.304844511885027
# RUN  80 , total integrated cost =  5.3047958133282425
# RUN  90 , total integrated cost =  5.304747089553463
# RUN  100 , total integrated cost =  5.304698340489669
# RUN  110 , total integrated cost =  5.304649565845109
# RUN  120 , total integrated cost =  5.304600532061399
# RUN  130 , total integrated cost =  5.304549713977621
# RUN  140 , total integrated cost =  5.30449962464032
# RUN  150 , total integrated cost =  5.304449201732238
# RUN  160 , total integrated cost =  5.304398319591021
# RUN  170 , total integrated cost =  5.3043481692337044
# RUN  180 , total integrated cost =  5.304297663750333
# RUN  190 , total integrated cost =  5.304247432372197
# RUN  200 , total integrated cost =  5.304196290972911
# RUN  300 , total integrated cost =  5.303681085987311
# RUN  400 , total integrated cost =  5.3031669293446
# RUN  500 , total integrated cost =  5.302611230628513
# RUN  600 , total integrated cost =  5.302041147076923
# RUN  700 , total integrated cost =  5.301477884254382
# RUN  800 , total integrated cost =  5.30095447861632
# RUN  900 , total integrated cost =  5.300440568123222
# RUN  1000 , total integrated cost =  5.2999660426482835
# RUN  1100 , total integrated cost =  5.299489319348325
# RUN  1200 , total integrated cost =  5.299014215974801
# RUN  1300 , total integrated cost =  5.298573713244545
# RUN  1400 , total integrated cost =  5.298147905509806
# RUN  1500 , total integrated cost =  5.297679868044794
# RUN  1600 , total integrated cost =  5.29719302902442
# RUN  1700 , total integrated cost =  5.29675062214746
# RUN  1800 , total integrated cost =  5.296269273782512
# RUN  1900 , total integrated cost =  5.295850550715282
# RUN  2000 , total integrated cost =  5.29543159654422
# ERROR:root:Problem in initial value trasfer
# RUN  2500 , total integrated cost =  5.293303219743381
# Improved over  2500  iterations in  594.1653512000003  seconds by  0.22395999938864009  percent.
# Problem in initial value trasfer:  Vmean_exc -56.66906635522667 -56.66906637488637
# no convergence
# -------  50 0.47500000000000014 0.6000000000000003
# set cost params:  1.0 1.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12.312659906727022
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12.31265942756016
# RUN  2 , total integrated cost =  12.312658984137439
# RUN  3 , total integrated cost =  12.312658504970162
# RUN  4 , total integrated cost =  12.312658061535066
# RUN  5 , total integrated cost =  12.31265758236735
# RUN  6 , total integrated cost =  12.312657138919864
# RUN  7 , total integrated cost =  12.31265665975169
# RUN  8 , total integrated cost =  12.312656216291913
# RUN  9 , total integrated cost =  12.312655737123285
# RUN  10 , total integrated cost =  12.312655293651114
# RUN  11 , total integrated cost =  12.31265481448198
# RUN  12 , total integrated cost =  12.312654370997944
# RUN  13 , total integrated cost =  12.31265389182824
# RUN  14 , total integrated cost =  12.312653448332778
# RUN  15 , total integrated cost =  12.312652969162489
# RUN  16 , total integrated cost =  12.312652525655425
# RUN  17 , total integrated cost =  12.312652046484544
# RUN  18 , total integrated cost =  12.31265160296608
# RUN  19 , total integrated cost =  12.31265112379459
# RUN  20 , total integrated cost =  12.312650680264538
# RUN  30 , total integrated cost =  12.312646066539518
# RUN  40 , total integrated cost =  12.312641452409869
# RUN  50 , total integrated cost =  12.31263683787417
# RUN  60 , total integrated cost =  12.31263222293224
# RUN  70 , total integrated cost =  12.312627607584101
# RUN  80 , total integrated cost =  12.312622991829734
# RUN  90 , total integrated cost =  12.312618375669086
# RUN  100 , total integrated cost =  12.31261375910219
# RUN  110 , total integrated cost =  12.312609142128924
# RUN  120 , total integrated cost =  12.312604524749373
# RUN  130 , total integrated cost =  12.312599906963912
# RUN  140 , total integrated cost =  12.312595288771828
# RUN  150 , total integrated cost =  12.312590670174774
# RUN  160 , total integrated cost =  12.312586051195828
# RUN  170 , total integrated cost =  12.312581431863334
# RUN  180 , total integrated cost =  12.312576812177161
# RUN  190 , total integrated cost =  12.312572192137337
# RUN  200 , total integrated cost =  12.312567571743834
# RUN  300 , total integrated cost =  12.312521348388769
# RUN  400 , total integrated cost =  12.312475089476322
# RUN  500 , total integrated cost =  12.312428798402442
# RUN  600 , total integrated cost =  12.312382476377149
# RUN  700 , total integrated cost =  12.312336118263866
# RUN  800 , total integrated cost =  12.312289723467181
# RUN  900 , total integrated cost =  12.312243291841803
# RUN  1000 , total integrated cost =  12.312196825829488
# RUN  1100 , total integrated cost =  12.312150327405192
# RUN  1200 , total integrated cost =  12.312103794904589
# RUN  1300 , total integrated cost =  12.312057227742388
# RUN  1400 , total integrated cost =  12.312010623068623
# RUN  1500 , total integrated cost =  12.311963976522982
# RUN  1600 , total integrated cost =  12.31191728832548
# RUN  1700 , total integrated cost =  12.31187055765589
# RUN  1800 , total integrated cost =  12.311823787683707
# RUN  1900 , total integrated cost =  12.311776985264052
# RUN  2000 , total integrated cost =  12.311730151159368
# RUN  2500 , total integrated cost =  12.311495434706577
# Improved over  2500  iterations in  613.5372057000004  seconds by  0.009457517947112137  percent.
# no convergence
# --------------- 6
