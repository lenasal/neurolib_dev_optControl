# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import sys
import pickle

path = os.getcwd().split(os.sep + 'GUI')[0]
if path not in sys.path:
    print("not here")
    sys.path.append(path)

from neurolib.models.aln import ALNModel
from neurolib.utils import plotFunctions as plotFunc
from neurolib.utils import costFunctions as cost
import neurolib.dashboard.functions as functions
import neurolib.dashboard.data as data
    
# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2 

#path = os.path.join(os.getcwd(), "plots")
# Out:
# not here

# %%
grid_data_file = os.path.join(os.getcwd().split('data')[0], 'bi.pickle')
with open(grid_data_file,'rb') as f:
    load_array= pickle.load(f)
exc = [load_array[0][20], load_array[0][50]]
inh = [load_array[1][20], load_array[1][50]]

folder = str(os.getcwd().split('data_2')[1])
print(folder)
case = str(folder[1])

file_ = 'up.pickle'

c_var = [0,1]
if len(folder) == 4:
    if folder[3] == 'e':
        p_var = [0]
    elif folder[3] == 'i':
        p_var = [1]
else:
    p_var = [0,1]
    
print(p_var)

step1 = 1
step2 = 10
step3 = 100
# Out:
# /2_e
# [0]

# %%
aln = ALNModel()
N = aln.params.N

data.set_parameters(aln)

state_vars = aln.state_vars
init_vars = aln.init_vars

##############################################################
def setinit(init_vars_, model):
    state_vars = model.state_vars
    init_vars = model.init_vars
    for iv in range(len(init_vars)):
        for sv in range(len(state_vars)):
            if state_vars[sv] in init_vars[iv]:
                #print("set init vars ", )
                if model.params[init_vars[iv]].ndim == 2:
                    model.params[init_vars[iv]][0,:] = init_vars_[sv]
                else:
                    model.params[init_vars[iv]][0] = init_vars_[sv]
                    
##############################################################               
def setmaxmincontrol(max_c_c, min_c_c, max_c_r, min_c_r):
    import numpy as np
    
    max_cntrl = np.zeros(( 6 ))
    min_cntrl = np.zeros(( 6 ))
    
    max_cntrl[0] = max_c_c
    min_cntrl[0] = min_c_c
    max_cntrl[1] = max_c_c
    min_cntrl[1] = min_c_c
    max_cntrl[2] = max_c_r
    min_cntrl[2] = min_c_r
    max_cntrl[3] = max_c_r
    min_cntrl[3] = min_c_r
    max_cntrl[4] = max_c_r
    min_cntrl[4] = min_c_r
    max_cntrl[5] = max_c_r
    min_cntrl[5] = min_c_r
            
    return max_cntrl, min_cntrl

# %%
d_array = np.arange(20., 300, 0.1)
t0_array = d_array - 20.
t_pen = np.zeros(( t0_array.shape ))
for i in range(len(t_pen)):
    t_pen[i] = t0_array[i] / d_array[i]

# %%
dur_pre = 10
dur_post = 10

n_pre = int(np.around(dur_pre/aln.params.dt + 1.,1))
n_post = int(np.around(dur_post/aln.params.dt + 1.,1))

tol = 1e-12
start_step = 10.
c_scheme = np.zeros(( 1,1 ))
c_scheme[0,0] = 1.
u_mat = np.identity(1)
u_scheme = np.array([[1.]])

if case in ['1', '2']:    # low to high
    max_I = [3., -3.]
else:
    max_I = [-3., 3.]
    
if case in ['1', '3']:    # sparsity
    factor_ws = 1.
    factor_we = 0.
    cost_index = 2
else:
    factor_ws = 0.
    factor_we = 1.
    cost_index = 1
    
maxC = [1000., -1000., 0.18, 0.]
max_cntrl, min_cntrl = setmaxmincontrol(maxC[0], maxC[1], maxC[2], maxC[3])

# %%
bestControl_ = np.array( [[None] * len(t_pen)] * len(exc) )
bestState_ = np.array( [[None] * len(t_pen)] * len(exc) )
cost_ = np.array( [[None] * len(t_pen)] * len(exc) )
costnode_ = np.array( [[None] * len(t_pen)] * len(exc) )
weights_ = np.array( [[None] * len(t_pen)] * len(exc) )
convergence_ = np.array( [[None] * len(t_pen)] * len(exc) )

initVars = [None] * len(exc)
target = [None] * len(exc)
cost_uncontrolled = [None] * len(exc)

print(bestControl_.shape)
# Out:
# (2, 2800)

# %%
if os.path.isfile(file_) :
    print("file found")
    
    with open(file_,'rb') as f:
        load_array = pickle.load(f)

    bestControl_ = load_array[0]
    bestState_ = load_array[1]
    cost_ = load_array[2]
    costnode_ = load_array[3]
    weights_ = load_array[4]
# Out:
# file found

# %%
# get initial parameters and target states
# -------  20 0.4500000000000001 0.4750000000000002
#-------  50 0.47500000000000014 0.6000000000000003

i_range = range(len(exc))
data.set_parameters(aln)

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    aln.params.duration = 3000.
    
    control0 = aln.getZeroControl()
    control0 = functions.step_control(aln, maxI_ = max_I[0])

    aln.run(control=control0)
    
    target_rates = np.zeros((2))
    target_rates[0] = aln.rates_exc[0,-1] 
    target_rates[1] = aln.rates_inh[0,-1]

    control0 = functions.step_control(aln, maxI_ = max_I[1])
    aln.run(control=control0)

    init_state_vars = np.zeros(( len(state_vars) ))
    for j in range(len(state_vars)):
        if aln.state[state_vars[j]].size == 1:
            init_state_vars[j] = aln.state[state_vars[j]][0]
        else:
            init_state_vars[j] = aln.state[state_vars[j]][0,-1]

    initVars[i] = init_state_vars
    target[i] = [target_rates[0], target_rates[1]]
# Out:
# -------  0 0.4500000000000001 0.4750000000000002
# -------  1 0.47500000000000014 0.6000000000000003

# %%
# get uncontrolled cost

data.set_parameters(aln)

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    dur = d_array[0]
    aln.params.duration = dur
    
    target_ = aln.getZeroTarget()
    target_[:,0,:] = target[i][0]
    target_[:,1,:] = target[i][1]
            
    cost.setParams(1.0, 0.0, 0.0)

    setinit(initVars[i], aln)
    control0 = aln.getZeroControl()

    # "HS", "FR", "PR", "HZ"
    cgv = None
    max_it = 0

    bestControl_init_, bestState_init_, cost_init_, runtime_init_, grad_init_, phi_init_, phi1_, costnode_init_ = aln.A1(
        control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
        prec_variables_ = p_var, transition_time_ = t_pen[0])
    
    cost_uncontrolled[i] = cost_init_[0]
# Out:
# -------  0 0.4500000000000001 0.4750000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  12801.807032522984
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  0 , total integrated cost =  12801.807032522984
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  1 0.47500000000000014 0.6000000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  16022.670213255857
# RUN  0 , total integrated cost =  16022.670213255857
# Gradient descend method:  None
# RUN  0 , total integrated cost =  16022.670213255857
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.

# %%
for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.

    cgv = None
    j = 0
    max_it = 1000

    while not convergence_[i][j]:

        dur = d_array[0]
        aln.params.duration = dur
        cost.setParams(1.0, factor_we, factor_ws)
        weights_[i][j] = [1.0, factor_we, factor_ws]
        
        setinit(initVars[i], aln)

        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        if type(bestControl_[i][j]) == type(None) or np.amax(np.abs(bestControl_[i][j])) < 1e-6:
            control0 = aln.getZeroControl()
        else:
            control0 = bestControl_[i][j][:,:,n_pre-1:-n_post+1]

        bestControl_[i][j], bestState_[i][j], cost_[i][j], runtime_, grad_, phi_, phi1_, costnode_[i][j] = aln.A1(
            control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
            prec_variables_ = p_var, transition_time_ = t_pen[j])

        if max_it > 1:
            if cost_[i][j][2] == 0.:
                convergence_[i][j] = True
                continue

        print('cost splitting : ', costnode_[i][j][0][0][:2], costnode_[i][j][cost_index][0][:2])

        with open(file_,'wb') as f:
            pickle.dump([bestControl_, bestState_, cost_, costnode_, weights_], f)
# Out:
# -------  0 0.4500000000000001 0.4750000000000002
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  219.0663994845803
# RUN  0 , total integrated cost =  219.0663994845803
# Gradient descend method:  None
# The history saving thread hit an unexpected error (OperationalError('database is locked')).History will not be written to the database.
# RUN  1 , total integrated cost =  219.0663994845803
# Control only changes marginally.
# RUN  1 , total integrated cost =  219.0663994845803
# Improved over  1  iterations in  9.904776327311993  seconds by  0.0  percent.
# -------  1 0.47500000000000014 0.6000000000000003
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  16022.670213255857
# RUN  0 , total integrated cost =  16022.670213255857
# Gradient descend method:  None
# RUN  1 , total integrated cost =  16022.670213255857
# Control only changes marginally.
# RUN  1 , total integrated cost =  16022.670213255857
# Improved over  1  iterations in  0.05236832331866026  seconds by  0.0  percent.

# %%
for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    j = 0
    step = step1

    while j < 2001:
        
        if convergence_[i][j]:
            j += step
            continue

        print('-----', j)

        dur = round(d_array[j],1)
        aln.params.duration = dur
        max_it = int(1000)  

        setinit(initVars[i], aln)
        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        if type(bestControl_[i][j]) == type(None):
            control0 = aln.getZeroControl()
            control0[:,:,:-step] = bestControl_[i][j-step][:,:,n_pre-1:-n_post+1]

        else:
            control0 = bestControl_[i][j][:,:,n_pre-1:-n_post+1]
            
        weights_[i][j] = cost.getParams()

        bestControl_[i][j], bestState_[i][j], cost_[i][j], runtime_, grad_, phi_, phi1_, costnode_[i][j] = aln.A1(
            control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
            prec_variables_ = p_var, transition_time_ = t_pen[j])

        if cost_[i][j][-1] == 0.:
            convergence_[i][j] = True
            if j >= 10:
                step = step2
            if j >=1000:
                step = step3

        print('cost splitting : ', costnode_[i][j][0][0][:2], costnode_[i][j][cost_index][0][:2])

        with open(file_,'wb') as f:
            pickle.dump([bestControl_, bestState_, cost_, costnode_, weights_], f)
# Out:
# -------  0 0.4500000000000001 0.4750000000000002
# ----- 1
# interpolate adjoint :  True True True
# initial cost =  91.75600786373941
# RUN  0 , total integrated cost =  91.75600786373941
# Gradient descend method:  None
# RUN  1 , total integrated cost =  91.75600786373941
# Control only changes marginally.
# RUN  1 , total integrated cost =  91.75600786373941
# Improved over  1  iterations in  0.05588242691010237  seconds by  0.0  percent.
# cost splitting :  [14.15966637  0.        ] [3.00513223e+03 1.21391536e-24]
# ----- 2
# interpolate adjoint :  True True True
# initial cost =  55.22021413435351
# RUN  0 , total integrated cost =  55.22021413435351
# Gradient descend method:  None
# RUN  1 , total integrated cost =  55.22021413435351
# Control only changes marginally.
# RUN  1 , total integrated cost =  55.22021413435351
# Improved over  1  iterations in  0.05852322839200497  seconds by  0.0  percent.
# cost splitting :  [1.33364552 0.        ] [1.45116615e+03 1.21391536e-24]
# ----- 3
# interpolate adjoint :  True True True
# initial cost =  40.843844675641186
# RUN  0 , total integrated cost =  40.843844675641186
# Gradient descend method:  None
# RUN  1 , total integrated cost =  40.843844675641186
# Control only changes marginally.
# RUN  1 , total integrated cost =  40.843844675641186
# Improved over  1  iterations in  0.05973790120333433  seconds by  0.0  percent.
# cost splitting :  [0.44197435 0.        ] [8.15889068e+02 1.21391536e-24]
# ----- 4
# interpolate adjoint :  True True True
# initial cost =  33.381224513964625
# RUN  0 , total integrated cost =  33.381224513964625
# Gradient descend method:  None
# RUN  1 , total integrated cost =  33.381224513964625
# Control only changes marginally.
# RUN  1 , total integrated cost =  33.381224513964625
# Improved over  1  iterations in  0.0694943917915225  seconds by  0.0  percent.
# cost splitting :  [0.21227759 0.        ] [5.49949409e+02 1.21391536e-24]
# ----- 5
# interpolate adjoint :  True True True
# initial cost =  28.794103408335584
# RUN  0 , total integrated cost =  28.794103408335584
# Gradient descend method:  None
# RUN  1 , total integrated cost =  28.794103408335584
# Control only changes marginally.
# RUN  1 , total integrated cost =  28.794103408335584
# Improved over  1  iterations in  0.09749818220734596  seconds by  0.0  percent.
# cost splitting :  [0.11648886 0.        ] [4.11119692e+02 1.21391536e-24]
# ----- 6
# interpolate adjoint :  True True True
# initial cost =  25.65853745542159
# RUN  0 , total integrated cost =  25.65853745542159
# Gradient descend method:  None
# RUN  1 , total integrated cost =  25.65853745542159
# Control only changes marginally.
# RUN  1 , total integrated cost =  25.65853745542159
# Improved over  1  iterations in  0.058681052178144455  seconds by  0.0  percent.
# cost splitting :  [0.07393262 0.        ] [3.27229541e+02 1.21391536e-24]
# ----- 7
# interpolate adjoint :  True True True
# initial cost =  23.356665156430694
# RUN  0 , total integrated cost =  23.356665156430694
# Gradient descend method:  None
# RUN  1 , total integrated cost =  23.356665156430694
# Control only changes marginally.
# RUN  1 , total integrated cost =  23.356665156430694
# Improved over  1  iterations in  0.0622857790440321  seconds by  0.0  percent.
# cost splitting :  [0.05171466 0.        ] [2.71518388e+02 1.21391536e-24]
# ----- 8
# interpolate adjoint :  True True True
# initial cost =  21.589852244060342
# RUN  0 , total integrated cost =  21.589852244060342
# Gradient descend method:  None
# RUN  1 , total integrated cost =  21.589852244060342
# Control only changes marginally.
# RUN  1 , total integrated cost =  21.589852244060342
# Improved over  1  iterations in  0.0617156932130456  seconds by  0.0  percent.
# cost splitting :  [0.04218264 0.        ] [2.32114857e+02 1.21391536e-24]
# ----- 9
# interpolate adjoint :  True True True
# initial cost =  20.179831652732293
# RUN  0 , total integrated cost =  20.179831652732293
# Gradient descend method:  None
# RUN  1 , total integrated cost =  20.179831652732293
# Control only changes marginally.
# RUN  1 , total integrated cost =  20.179831652732293
# Improved over  1  iterations in  0.06022522319108248  seconds by  0.0  percent.
# cost splitting :  [0.03169657 0.        ] [2.02945080e+02 1.21391536e-24]
# ----- 10
# interpolate adjoint :  True True True
# initial cost =  19.026376774831594
# RUN  0 , total integrated cost =  19.026376774831594
# Gradient descend method:  None
# RUN  1 , total integrated cost =  19.026376774831594
# Control only changes marginally.
# RUN  1 , total integrated cost =  19.026376774831594
# Improved over  1  iterations in  0.06088370643556118  seconds by  0.0  percent.
# cost splitting :  [0.02653765 0.        ] [1.80471859e+02 1.21391536e-24]
# ----- 20
# interpolate adjoint :  True True True
# initial cost =  13.346933783236338
# RUN  0 , total integrated cost =  13.346933783236338
# Gradient descend method:  None
# RUN  1 , total integrated cost =  13.346933783236338
# Control only changes marginally.
# RUN  1 , total integrated cost =  13.346933783236338
# Improved over  1  iterations in  0.06378061696887016  seconds by  0.0  percent.
# cost splitting :  [0.00693634 0.        ] [8.89685591e+01 1.21391536e-24]
# ----- 30
# interpolate adjoint :  True True True
# initial cost =  11.127644199099393
# RUN  0 , total integrated cost =  11.127644199099393
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.127644199099393
# Control only changes marginally.
# RUN  1 , total integrated cost =  11.127644199099393
# Improved over  1  iterations in  0.08173116203397512  seconds by  0.0  percent.
# cost splitting :  [0.00339321 0.        ] [6.18688464e+01 1.21391536e-24]
# ----- 40
# interpolate adjoint :  True True True
# initial cost =  9.888052370191009
# RUN  0 , total integrated cost =  9.888052370191009
# Gradient descend method:  None
# RUN  1 , total integrated cost =  9.888052370191009
# Control only changes marginally.
# RUN  1 , total integrated cost =  9.888052370191009
# Improved over  1  iterations in  0.06348155252635479  seconds by  0.0  percent.
# cost splitting :  [0.00195943 0.        ] [4.88635619e+01 1.21391536e-24]
# ----- 50
# interpolate adjoint :  True True True
# initial cost =  9.075645237292346
# RUN  0 , total integrated cost =  9.075645237292346
# Gradient descend method:  None
# RUN  1 , total integrated cost =  9.075645237292346
# Control only changes marginally.
# RUN  1 , total integrated cost =  9.075645237292346
# Improved over  1  iterations in  0.06507464125752449  seconds by  0.0  percent.
# cost splitting :  [0.00127592 0.        ] [4.11692092e+01 1.21391536e-24]
# ----- 60
# interpolate adjoint :  True True True
# initial cost =  8.490339848740291
# RUN  0 , total integrated cost =  8.490339848740291
# Gradient descend method:  None
# RUN  1 , total integrated cost =  8.490339848740291
# Control only changes marginally.
# RUN  1 , total integrated cost =  8.490339848740291
# Improved over  1  iterations in  0.0998618621379137  seconds by  0.0  percent.
# cost splitting :  [0.00098929 0.        ] [3.60320295e+01 1.21391536e-24]
# ----- 70
# interpolate adjoint :  True True True
# initial cost =  8.039697247542268
# RUN  0 , total integrated cost =  8.039697247542268
# Gradient descend method:  None
# RUN  1 , total integrated cost =  8.039697247542268
# Control only changes marginally.
# RUN  1 , total integrated cost =  8.039697247542268
# Improved over  1  iterations in  0.08320058323442936  seconds by  0.0  percent.
# cost splitting :  [0.00073862 0.        ] [3.23103601e+01 1.21391536e-24]
# ----- 80
# interpolate adjoint :  True True True
# initial cost =  7.67463169047838
# RUN  0 , total integrated cost =  7.67463169047838
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.67463169047838
# Control only changes marginally.
# RUN  1 , total integrated cost =  7.67463169047838
# Improved over  1  iterations in  0.06561222765594721  seconds by  0.0  percent.
# cost splitting :  [0.00061162 0.        ] [2.94434240e+01 1.21391536e-24]
# ----- 90
# interpolate adjoint :  True True True
# initial cost =  7.365671262311984
# RUN  0 , total integrated cost =  7.365671262311984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.365671262311984
# Control only changes marginally.
# RUN  1 , total integrated cost =  7.365671262311984
# Improved over  1  iterations in  0.08712679240852594  seconds by  0.0  percent.
# cost splitting :  [0.00047715 0.        ] [2.71214686e+01 1.21391536e-24]
# ----- 100
# interpolate adjoint :  True True True
# initial cost =  7.093353104910751
# RUN  0 , total integrated cost =  7.093353104910751
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.093353104910751
# Control only changes marginally.
# RUN  1 , total integrated cost =  7.093353104910751
# Improved over  1  iterations in  0.10410705953836441  seconds by  0.0  percent.
# cost splitting :  [0.00041693 0.        ] [2.51534006e+01 1.21391536e-24]
# ----- 110
# interpolate adjoint :  True True True
# initial cost =  6.844460694241969
# RUN  0 , total integrated cost =  6.844460694241969
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.844460694241969
# Control only changes marginally.
# RUN  1 , total integrated cost =  6.844460694241969
# Improved over  1  iterations in  0.067620730958879  seconds by  0.0  percent.
# cost splitting :  [0.0003682 0.       ] [2.34194219e+01 1.21391536e-24]
# ----- 120
# interpolate adjoint :  True True True
# initial cost =  6.611290084002062
# RUN  0 , total integrated cost =  6.611290084002062
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.611290084002062
# Control only changes marginally.
# RUN  1 , total integrated cost =  6.611290084002062
# Improved over  1  iterations in  0.06959019415080547  seconds by  0.0  percent.
# cost splitting :  [0.00031721 0.        ] [2.18512292e+01 1.21391536e-24]
# ----- 130
# interpolate adjoint :  True True True
# initial cost =  6.393577198115948
# RUN  0 , total integrated cost =  6.393577198115948
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.393577198115948
# Control only changes marginally.
# RUN  1 , total integrated cost =  6.393577198115948
# Improved over  1  iterations in  0.08894569333642721  seconds by  0.0  percent.
# cost splitting :  [0.00028364 0.        ] [2.04359284e+01 1.21391536e-24]
# ----- 140
# interpolate adjoint :  True True True
# initial cost =  6.194924335387375
# RUN  0 , total integrated cost =  6.194924335387375
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.194924335387375
# Control only changes marginally.
# RUN  1 , total integrated cost =  6.194924335387375
# Improved over  1  iterations in  0.08058472909033298  seconds by  0.0  percent.
# cost splitting :  [0.00024073 0.        ] [1.91860139e+01 1.21391536e-24]
# ----- 150
# interpolate adjoint :  True True True
# initial cost =  6.017314681831221
# RUN  0 , total integrated cost =  6.017314681831221
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.017314681831221
# Control only changes marginally.
# RUN  1 , total integrated cost =  6.017314681831221
# Improved over  1  iterations in  0.07601387705653906  seconds by  0.0  percent.
# cost splitting :  [0.00021128 0.        ] [1.81018180e+01 1.21391536e-24]
# ----- 160
# interpolate adjoint :  True True True
# initial cost =  5.859648836649335
# RUN  0 , total integrated cost =  5.859648836649335
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.859648836649335
# Control only changes marginally.
# RUN  1 , total integrated cost =  5.859648836649335
# Improved over  1  iterations in  0.07368614431470633  seconds by  0.0  percent.
# cost splitting :  [0.00017957 0.        ] [1.71658525e+01 1.21391536e-24]
# ----- 170
# interpolate adjoint :  True True True
# initial cost =  5.719944579168942
# RUN  0 , total integrated cost =  5.719944579168942
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.719944579168942
# Control only changes marginally.
# RUN  1 , total integrated cost =  5.719944579168942
# Improved over  1  iterations in  0.0680701732635498  seconds by  0.0  percent.
# cost splitting :  [0.00015288 0.        ] [1.63572690e+01 1.21391536e-24]
# ----- 180
# interpolate adjoint :  True True True
# initial cost =  5.595537336616552
# RUN  0 , total integrated cost =  5.595537336616552
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.595537336616552
# Control only changes marginally.
# RUN  1 , total integrated cost =  5.595537336616552
# Improved over  1  iterations in  0.0699448324739933  seconds by  0.0  percent.
# cost splitting :  [0.0001277 0.       ] [1.56536646e+01 1.21391536e-24]
# ----- 190
# interpolate adjoint :  True True True
# initial cost =  5.484072573864063
# RUN  0 , total integrated cost =  5.484072573864063
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.484072573864063
# Control only changes marginally.
# RUN  1 , total integrated cost =  5.484072573864063
# Improved over  1  iterations in  0.07101006247103214  seconds by  0.0  percent.
# cost splitting :  [0.00011074 0.        ] [1.50363446e+01 1.21391536e-24]
# ----- 200
# interpolate adjoint :  True True True
# initial cost =  5.383469214010293
# RUN  0 , total integrated cost =  5.383469214010293
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.383469214010293
# Control only changes marginally.
# RUN  1 , total integrated cost =  5.383469214010293
# Improved over  1  iterations in  0.08779213204979897  seconds by  0.0  percent.
# cost splitting :  [9.75602242e-05 0.00000000e+00] [1.44898226e+01 1.21391536e-24]
# ----- 210
# interpolate adjoint :  True True True
# initial cost =  5.2918838648392015
# RUN  0 , total integrated cost =  5.2918838648392015
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.2918838648392015
# Control only changes marginally.
# RUN  1 , total integrated cost =  5.2918838648392015
# Improved over  1  iterations in  0.07103183306753635  seconds by  0.0  percent.
# cost splitting :  [8.53993636e-05 0.00000000e+00] [1.40010934e+01 1.21391536e-24]
# ----- 220
# interpolate adjoint :  True True True
# initial cost =  5.207913854426286
# RUN  0 , total integrated cost =  5.207913854426286
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.207913854426286
# Control only changes marginally.
# RUN  1 , total integrated cost =  5.207913854426286
# Improved over  1  iterations in  0.06999656464904547  seconds by  0.0  percent.
# cost splitting :  [7.69412894e-05 0.00000000e+00] [1.35603441e+01 1.21391536e-24]
# ----- 230
# interpolate adjoint :  True True True
# initial cost =  5.130256304590215
# RUN  0 , total integrated cost =  5.130256304590215
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.130256304590215
# Control only changes marginally.
# RUN  1 , total integrated cost =  5.130256304590215
# Improved over  1  iterations in  0.06961409468203783  seconds by  0.0  percent.
# cost splitting :  [6.91359495e-05 0.00000000e+00] [1.31590043e+01 1.21391536e-24]
# ----- 240
# interpolate adjoint :  True True True
# initial cost =  5.057962146857684
# RUN  0 , total integrated cost =  5.057962146857684
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.057962146857684
# Control only changes marginally.
# RUN  1 , total integrated cost =  5.057962146857684
# Improved over  1  iterations in  0.07166330981999636  seconds by  0.0  percent.
# cost splitting :  [6.13588949e-05 0.00000000e+00] [1.27908096e+01 1.21391536e-24]
# ----- 250
# interpolate adjoint :  True True True
# initial cost =  4.990236101691893
# RUN  0 , total integrated cost =  4.990236101691893
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.990236101691893
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.990236101691893
# Improved over  1  iterations in  0.07224534545093775  seconds by  0.0  percent.
# cost splitting :  [5.57904422e-05 0.00000000e+00] [1.24506035e+01 1.21391536e-24]
# ----- 260
# interpolate adjoint :  True True True
# initial cost =  4.92672553712115
# RUN  0 , total integrated cost =  4.92672553712115
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.92672553712115
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.92672553712115
# Improved over  1  iterations in  0.08554189931601286  seconds by  0.0  percent.
# cost splitting :  [5.00199726e-05 0.00000000e+00] [1.21357471e+01 1.21391536e-24]
# ----- 270
# interpolate adjoint :  True True True
# initial cost =  4.866930236396223
# RUN  0 , total integrated cost =  4.866930236396223
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.866930236396223
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.866930236396223
# Improved over  1  iterations in  0.07044110726565123  seconds by  0.0  percent.
# cost splitting :  [4.64948902e-05 0.00000000e+00] [1.18429747e+01 1.21391536e-24]
# ----- 280
# interpolate adjoint :  True True True
# initial cost =  4.81077415492486
# RUN  0 , total integrated cost =  4.81077415492486
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.81077415492486
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.81077415492486
# Improved over  1  iterations in  0.08725395705550909  seconds by  0.0  percent.
# cost splitting :  [4.1848368e-05 0.0000000e+00] [1.15712922e+01 1.21391536e-24]
# ----- 290
# interpolate adjoint :  True True True
# initial cost =  4.757960476637921
# RUN  0 , total integrated cost =  4.757960476637921
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.757960476637921
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.757960476637921
# Improved over  1  iterations in  0.08797682728618383  seconds by  0.0  percent.
# cost splitting :  [3.85711333e-05 0.00000000e+00] [1.13186457e+01 1.21391536e-24]
# ----- 300
# interpolate adjoint :  True True True
# initial cost =  4.708369859675466
# RUN  0 , total integrated cost =  4.708369859675466
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.708369859675466
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.708369859675466
# Improved over  1  iterations in  0.07376677263528109  seconds by  0.0  percent.
# cost splitting :  [3.47654686e-05 0.00000000e+00] [1.10839654e+01 1.21391536e-24]
# ----- 310
# interpolate adjoint :  True True True
# initial cost =  4.661754407609072
# RUN  0 , total integrated cost =  4.661754407609072
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.661754407609072
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.661754407609072
# Improved over  1  iterations in  0.07733883894979954  seconds by  0.0  percent.
# cost splitting :  [3.18705558e-05 0.00000000e+00] [1.08655994e+01 1.21391536e-24]
# ----- 320
# interpolate adjoint :  True True True
# initial cost =  4.617893265183589
# RUN  0 , total integrated cost =  4.617893265183589
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.617893265183589
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.617893265183589
# Improved over  1  iterations in  0.07379991468042135  seconds by  0.0  percent.
# cost splitting :  [2.86110409e-05 0.00000000e+00] [1.06621266e+01 1.21391536e-24]
# ----- 330
# interpolate adjoint :  True True True
# initial cost =  4.576525059046421
# RUN  0 , total integrated cost =  4.576525059046421
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.576525059046421
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.576525059046421
# Improved over  1  iterations in  0.07908723503351212  seconds by  0.0  percent.
# cost splitting :  [2.61742575e-05 0.00000000e+00] [1.04719744e+01 1.21391536e-24]
# ----- 340
# interpolate adjoint :  True True True
# initial cost =  4.53751394663576
# RUN  0 , total integrated cost =  4.53751394663576
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.53751394663576
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.53751394663576
# Improved over  1  iterations in  0.09285358525812626  seconds by  0.0  percent.
# cost splitting :  [2.39107522e-05 0.00000000e+00] [1.02942244e+01 1.21391536e-24]
# ----- 350
# interpolate adjoint :  True True True
# initial cost =  4.500661735137882
# RUN  0 , total integrated cost =  4.500661735137882
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.500661735137882
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.500661735137882
# Improved over  1  iterations in  0.07614483591169119  seconds by  0.0  percent.
# cost splitting :  [2.21342134e-05 0.00000000e+00] [1.01277049e+01 1.21391536e-24]
# ----- 360
# interpolate adjoint :  True True True
# initial cost =  4.465805418244312
# RUN  0 , total integrated cost =  4.465805418244312
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.465805418244312
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.465805418244312
# Improved over  1  iterations in  0.08296521939337254  seconds by  0.0  percent.
# cost splitting :  [2.02714702e-05 0.00000000e+00] [9.97145635e+00 1.21391536e-24]
# ----- 370
# interpolate adjoint :  True True True
# initial cost =  4.432697207471275
# RUN  0 , total integrated cost =  4.432697207471275
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.432697207471275
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.432697207471275
# Improved over  1  iterations in  0.07645449414849281  seconds by  0.0  percent.
# cost splitting :  [1.87387612e-05 0.00000000e+00] [9.82416630e+00 1.21391536e-24]
# ----- 380
# interpolate adjoint :  True True True
# initial cost =  4.401378874776104
# RUN  0 , total integrated cost =  4.401378874776104
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.401378874776104
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.401378874776104
# Improved over  1  iterations in  0.07763260696083307  seconds by  0.0  percent.
# cost splitting :  [1.72472513e-05 0.00000000e+00] [9.68584857e+00 1.21391536e-24]
# ----- 390
# interpolate adjoint :  True True True
# initial cost =  4.371634646683186
# RUN  0 , total integrated cost =  4.371634646683186
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.371634646683186
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.371634646683186
# Improved over  1  iterations in  0.077439920976758  seconds by  0.0  percent.
# cost splitting :  [1.56552709e-05 0.00000000e+00] [9.55539351e+00 1.21391536e-24]
# ----- 400
# interpolate adjoint :  True True True
# initial cost =  4.343370023181723
# RUN  0 , total integrated cost =  4.343370023181723
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.343370023181723
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.343370023181723
# Improved over  1  iterations in  0.07872628513723612  seconds by  0.0  percent.
# cost splitting :  [1.45253499e-05 0.00000000e+00] [9.43224294e+00 1.21391536e-24]
# ----- 410
# interpolate adjoint :  True True True
# initial cost =  4.316489917580824
# RUN  0 , total integrated cost =  4.316489917580824
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.316489917580824
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.316489917580824
# Improved over  1  iterations in  0.07993190828710794  seconds by  0.0  percent.
# cost splitting :  [1.3457268e-05 0.0000000e+00] [9.31586603e+00 1.21391536e-24]
# ----- 420
# interpolate adjoint :  True True True
# initial cost =  4.291005121205016
# RUN  0 , total integrated cost =  4.291005121205016
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.291005121205016
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.291005121205016
# Improved over  1  iterations in  0.1222012247890234  seconds by  0.0  percent.
# cost splitting :  [1.24998603e-05 0.00000000e+00] [9.20619676e+00 1.21391536e-24]
# ----- 430
# interpolate adjoint :  True True True
# initial cost =  4.266720481461364
# RUN  0 , total integrated cost =  4.266720481461364
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.266720481461364
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.266720481461364
# Improved over  1  iterations in  0.07717412430793047  seconds by  0.0  percent.
# cost splitting :  [1.15534327e-05 0.00000000e+00] [9.10229708e+00 1.21391536e-24]
# ----- 440
# interpolate adjoint :  True True True
# initial cost =  4.2436589749273885
# RUN  0 , total integrated cost =  4.2436589749273885
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.2436589749273885
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.2436589749273885
# Improved over  1  iterations in  0.07860267255455256  seconds by  0.0  percent.
# cost splitting :  [1.05680524e-05 0.00000000e+00] [9.00417773e+00 1.21391536e-24]
# ----- 450
# interpolate adjoint :  True True True
# initial cost =  4.221630850617317
# RUN  0 , total integrated cost =  4.221630850617317
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.221630850617317
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.221630850617317
# Improved over  1  iterations in  0.07800438441336155  seconds by  0.0  percent.
# cost splitting :  [9.79888218e-06 0.00000000e+00] [8.91094954e+00 1.21391536e-24]
# ----- 460
# interpolate adjoint :  True True True
# initial cost =  4.2007633929175645
# RUN  0 , total integrated cost =  4.2007633929175645
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.2007633929175645
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.2007633929175645
# Improved over  1  iterations in  0.12037801556289196  seconds by  0.0  percent.
# cost splitting :  [9.09535692e-06 0.00000000e+00] [8.82308089e+00 1.21391536e-24]
# ----- 470
# interpolate adjoint :  True True True
# initial cost =  4.180746284633654
# RUN  0 , total integrated cost =  4.180746284633654
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.180746284633654
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.180746284633654
# Improved over  1  iterations in  0.0922341775149107  seconds by  0.0  percent.
# cost splitting :  [8.40550797e-06 0.00000000e+00] [8.73920244e+00 1.21391536e-24]
# ----- 480
# interpolate adjoint :  True True True
# initial cost =  4.161753867358187
# RUN  0 , total integrated cost =  4.161753867358187
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.161753867358187
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.161753867358187
# Improved over  1  iterations in  0.08109137881547213  seconds by  0.0  percent.
# cost splitting :  [8.3131212e-06 0.0000000e+00] [8.65998041e+00 1.21391536e-24]
# ----- 490
# interpolate adjoint :  True True True
# initial cost =  4.143618711432055
# RUN  0 , total integrated cost =  4.143618711432055
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.143618711432055
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.143618711432055
# Improved over  1  iterations in  0.11547202244400978  seconds by  0.0  percent.
# cost splitting :  [7.26373086e-06 0.00000000e+00] [8.58468454e+00 1.21391536e-24]
# ----- 500
# interpolate adjoint :  True True True
# initial cost =  4.126340034983154
# RUN  0 , total integrated cost =  4.126340034983154
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.126340034983154
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.126340034983154
# Improved over  1  iterations in  0.08242653589695692  seconds by  0.0  percent.
# cost splitting :  [6.74038584e-06 0.00000000e+00] [8.51324404e+00 1.21391536e-24]
# ----- 510
# interpolate adjoint :  True True True
# initial cost =  4.109766507482416
# RUN  0 , total integrated cost =  4.109766507482416
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.109766507482416
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.109766507482416
# Improved over  1  iterations in  0.08127208333462477  seconds by  0.0  percent.
# cost splitting :  [6.2619889e-06 0.0000000e+00] [8.44499934e+00 1.21391536e-24]
# ----- 520
# interpolate adjoint :  True True True
# initial cost =  4.0939500708626735
# RUN  0 , total integrated cost =  4.0939500708626735
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.0939500708626735
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.0939500708626735
# Improved over  1  iterations in  0.08210082538425922  seconds by  0.0  percent.
# cost splitting :  [5.93277639e-06 0.00000000e+00] [8.38012647e+00 1.21391536e-24]
# ----- 530
# interpolate adjoint :  True True True
# initial cost =  4.078938552673629
# RUN  0 , total integrated cost =  4.078938552673629
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.078938552673629
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.078938552673629
# Improved over  1  iterations in  0.0833420492708683  seconds by  0.0  percent.
# cost splitting :  [5.46185749e-06 0.00000000e+00] [8.31878884e+00 1.21391536e-24]
# ----- 540
# interpolate adjoint :  True True True
# initial cost =  4.064549105819588
# RUN  0 , total integrated cost =  4.064549105819588
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.064549105819588
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.064549105819588
# Improved over  1  iterations in  0.12504102010279894  seconds by  0.0  percent.
# cost splitting :  [5.07703761e-06 0.00000000e+00] [8.26020364e+00 1.21391536e-24]
# ----- 550
# interpolate adjoint :  True True True
# initial cost =  4.050740744785428
# RUN  0 , total integrated cost =  4.050740744785428
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.050740744785428
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.050740744785428
# Improved over  1  iterations in  0.08483904879540205  seconds by  0.0  percent.
# cost splitting :  [4.76644558e-06 0.00000000e+00] [8.20417815e+00 1.21391536e-24]
# ----- 560
# interpolate adjoint :  True True True
# initial cost =  4.037628477713008
# RUN  0 , total integrated cost =  4.037628477713008
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.037628477713008
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.037628477713008
# Improved over  1  iterations in  0.09070271626114845  seconds by  0.0  percent.
# cost splitting :  [4.40848944e-06 0.00000000e+00] [8.15115447e+00 1.21391536e-24]
# ----- 570
# interpolate adjoint :  True True True
# initial cost =  4.025055430656691
# RUN  0 , total integrated cost =  4.025055430656691
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.025055430656691
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.025055430656691
# Improved over  1  iterations in  0.09427645243704319  seconds by  0.0  percent.
# cost splitting :  [4.09543812e-06 0.00000000e+00] [8.10047238e+00 1.21391536e-24]
# ----- 580
# interpolate adjoint :  True True True
# initial cost =  4.01298795482607
# RUN  0 , total integrated cost =  4.01298795482607
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.01298795482607
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.01298795482607
# Improved over  1  iterations in  0.08480981830507517  seconds by  0.0  percent.
# cost splitting :  [3.84183059e-06 0.00000000e+00] [8.05197626e+00 1.21391536e-24]
# ----- 590
# interpolate adjoint :  True True True
# initial cost =  4.002502884748796
# RUN  0 , total integrated cost =  4.002502884748796
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.002502880614898
# RUN  2 , total integrated cost =  4.002502877398693
# RUN  3 , total integrated cost =  4.002502872955298
# RUN  4 , total integrated cost =  4.002502869330892
# RUN  5 , total integrated cost =  4.00250286433298
# RUN  6 , total integrated cost =  4.002502859828926
# RUN  7 , total integrated cost =  4.002502850318403
# RUN  8 , total integrated cost =  4.002502841986814
# RUN  9 , total integrated cost =  4.0025028220572665
# RUN  10 , total integrated cost =  4.002502801577987
# RUN  11 , total integrated cost =  4.002502771666407
# RUN  12 , total integrated cost =  4.00250274363393
# RUN  13 , total integrated cost =  4.002502737417183
# RUN  14 , total integrated cost =  4.002502730075876
# RUN  15 , total integrated cost =  4.002502724394597
# RUN  16 , total integrated cost =  4.002502718170781
# RUN  17 , total integrated cost =  4.002502714268429
# RUN  18 , total integrated cost =  4.002502709761006
# RUN  19 , total integrated cost =  4.002502706569891
# RUN  20 , total integrated cost =  4.0025027023581305
# RUN  30 , total integrated cost =  4.0025025908084055
# RUN  40 , total integrated cost =  4.002502519445695
# RUN  50 , total integrated cost =  4.002502427600643
# RUN  60 , total integrated cost =  4.002502291762014
# RUN  70 , total integrated cost =  4.002502164610813
# RUN  80 , total integrated cost =  4.002502027097517
# RUN  90 , total integrated cost =  4.002501901741201
# RUN  100 , total integrated cost =  4.002501764269945
# RUN  110 , total integrated cost =  4.002501637239133
# RUN  120 , total integrated cost =  4.002501503314802
# RUN  130 , total integrated cost =  4.0025013745790545
# RUN  140 , total integrated cost =  4.002501240717311
# RUN  150 , total integrated cost =  4.0025011137633415
# RUN  160 , total integrated cost =  4.002500979936529
# RUN  170 , total integrated cost =  4.0025008428126005
# RUN  180 , total integrated cost =  4.002500797551623
# RUN  190 , total integrated cost =  4.002500656245299
# RUN  200 , total integrated cost =  4.002500591773588
# RUN  300 , total integrated cost =  4.002499293363174
# RUN  400 , total integrated cost =  4.002497964497913
# RUN  500 , total integrated cost =  4.00249694067318
# RUN  600 , total integrated cost =  4.00249593906661
# RUN  700 , total integrated cost =  4.002494837526165
# RUN  800 , total integrated cost =  4.002493777789015
# RUN  900 , total integrated cost =  4.002492574021045
# RUN  1000 , total integrated cost =  4.00249146034162
# RUN  1000 , total integrated cost =  4.00249146034162
# Improved over  1000  iterations in  65.00113167800009  seconds by  0.00028543157880278613  percent.
# cost splitting :  [3.80418257e-06 0.00000000e+00] [8.00990903e+00 1.21391536e-24]
# ----- 590
# interpolate adjoint :  True True True
# initial cost =  4.00249146034162
# RUN  0 , total integrated cost =  4.00249146034162
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.002491457255881
# RUN  2 , total integrated cost =  4.002491451446277
# RUN  3 , total integrated cost =  4.002491446340831
# RUN  4 , total integrated cost =  4.002491413776775
# RUN  5 , total integrated cost =  4.002491382518743
# RUN  6 , total integrated cost =  4.002491363384994
# RUN  7 , total integrated cost =  4.00249134273421
# RUN  8 , total integrated cost =  4.00249133522738
# RUN  9 , total integrated cost =  4.002491326870175
# RUN  10 , total integrated cost =  4.002491322147422
# RUN  11 , total integrated cost =  4.002491316732361
# RUN  12 , total integrated cost =  4.002491313517804
# RUN  13 , total integrated cost =  4.002491309090702
# RUN  14 , total integrated cost =  4.002491306095811
# RUN  15 , total integrated cost =  4.002491301044076
# RUN  16 , total integrated cost =  4.002491296721559
# RUN  17 , total integrated cost =  4.00249128746313
# RUN  18 , total integrated cost =  4.002491279172338
# RUN  19 , total integrated cost =  4.002491260579608
# RUN  20 , total integrated cost =  4.002491242858747
# RUN  30 , total integrated cost =  4.002491108192299
# RUN  40 , total integrated cost =  4.0024910004172805
# RUN  50 , total integrated cost =  4.002490866878178
# RUN  60 , total integrated cost =  4.002490816490717
# RUN  70 , total integrated cost =  4.002490676358216
# RUN  80 , total integrated cost =  4.002490537044778
# RUN  90 , total integrated cost =  4.002490422665769
# RUN  100 , total integrated cost =  4.002490357975967
# RUN  110 , total integrated cost =  4.002490219485964
# RUN  120 , total integrated cost =  4.002490155872362
# RUN  130 , total integrated cost =  4.002490033360219
# RUN  140 , total integrated cost =  4.002489892297838
# RUN  150 , total integrated cost =  4.002489760002582
# RUN  160 , total integrated cost =  4.002489656377641
# RUN  170 , total integrated cost =  4.002489574078324
# RUN  180 , total integrated cost =  4.002489432772609
# RUN  190 , total integrated cost =  4.002489302547834
# RUN  200 , total integrated cost =  4.00248924667758
# RUN  300 , total integrated cost =  4.002488039168712
# RUN  400 , total integrated cost =  4.002486899280169
# RUN  500 , total integrated cost =  4.002485743204316
# RUN  600 , total integrated cost =  4.00248469638003
# RUN  700 , total integrated cost =  4.002483572859503
# RUN  800 , total integrated cost =  4.002482518151507
# RUN  900 , total integrated cost =  4.002481327328141
# RUN  1000 , total integrated cost =  4.002480274519741
# RUN  1000 , total integrated cost =  4.002480274519741
# Improved over  1000  iterations in  65.2141561191529  seconds by  0.0002794714739451365  percent.
# cost splitting :  [3.76817586e-06 0.00000000e+00] [8.00986482e+00 1.21391536e-24]
# ----- 590
# interpolate adjoint :  True True True
# initial cost =  4.002480274519741
# RUN  0 , total integrated cost =  4.002480274519741
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.002480258141669
# RUN  2 , total integrated cost =  4.0024802420715435
# RUN  3 , total integrated cost =  4.002480204795901
# RUN  4 , total integrated cost =  4.0024801655268725
# RUN  5 , total integrated cost =  4.00248016118221
# RUN  6 , total integrated cost =  4.002480155554999
# RUN  7 , total integrated cost =  4.002480152480286
# RUN  8 , total integrated cost =  4.0024801482257
# RUN  9 , total integrated cost =  4.002480145322268
# RUN  10 , total integrated cost =  4.002480140992116
# RUN  11 , total integrated cost =  4.002480137747919
# RUN  12 , total integrated cost =  4.002480132569372
# RUN  13 , total integrated cost =  4.0024801285275045
# RUN  14 , total integrated cost =  4.002480118815608
# RUN  15 , total integrated cost =  4.002480109546804
# RUN  16 , total integrated cost =  4.002480093568167
# RUN  17 , total integrated cost =  4.002480080500169
# RUN  18 , total integrated cost =  4.002480034073423
# RUN  19 , total integrated cost =  4.002479983642891
# RUN  20 , total integrated cost =  4.002479979892791
# RUN  30 , total integrated cost =  4.002479888604777
# RUN  40 , total integrated cost =  4.002479805789125
# RUN  50 , total integrated cost =  4.0024796611344335
# RUN  60 , total integrated cost =  4.00247956266086
# RUN  70 , total integrated cost =  4.00247948335423
# RUN  80 , total integrated cost =  4.0024793412441015
# RUN  90 , total integrated cost =  4.002479289825424
# RUN  100 , total integrated cost =  4.002479156434133
# RUN  110 , total integrated cost =  4.002479011897018
# RUN  120 , total integrated cost =  4.0024789135089405
# RUN  130 , total integrated cost =  4.002478834278274
# RUN  140 , total integrated cost =  4.002478692300719
# RUN  150 , total integrated cost =  4.002478640900593
# RUN  160 , total integrated cost =  4.002478507632362
# RUN  170 , total integrated cost =  4.002478346853723
# RUN  180 , total integrated cost =  4.002478255771012
# RUN  190 , total integrated cost =  4.002478173126907
# RUN  200 , total integrated cost =  4.002478028770466
# RUN  300 , total integrated cost =  4.00247692887255
# RUN  400 , total integrated cost =  4.002475853404326
# RUN  500 , total integrated cost =  4.002474715912551
# RUN  600 , total integrated cost =  4.002473447864732
# RUN  700 , total integrated cost =  4.002472259473234
# RUN  800 , total integrated cost =  4.002470991610976
# RUN  900 , total integrated cost =  4.002469743389714
# RUN  1000 , total integrated cost =  4.0024685257125485
# RUN  1000 , total integrated cost =  4.0024685257125485
# Improved over  1000  iterations in  65.26939930394292  seconds by  0.0002935381660194025  percent.
# cost splitting :  [3.88608634e-06 0.00000000e+00] [8.00981594e+00 1.21391536e-24]
# ----- 590
# interpolate adjoint :  True True True
# initial cost =  4.0024685257125485
# RUN  0 , total integrated cost =  4.0024685257125485
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.002468502455333
# RUN  2 , total integrated cost =  4.002468478965947
# RUN  3 , total integrated cost =  4.002468453467974
# RUN  4 , total integrated cost =  4.002468447615898
# RUN  5 , total integrated cost =  4.002468440384167
# RUN  6 , total integrated cost =  4.002468437279979
# RUN  7 , total integrated cost =  4.002468432823758
# RUN  8 , total integrated cost =  4.002468430082696
# RUN  9 , total integrated cost =  4.002468425368329
# RUN  10 , total integrated cost =  4.002468421947566
# RUN  11 , total integrated cost =  4.002468410293349
# RUN  12 , total integrated cost =  4.00246839981111
# RUN  13 , total integrated cost =  4.002468345731339
# RUN  14 , total integrated cost =  4.00246829035876
# RUN  15 , total integrated cost =  4.002468286953982
# RUN  16 , total integrated cost =  4.002468282226911
# RUN  17 , total integrated cost =  4.002468279486945
# RUN  18 , total integrated cost =  4.0024682750397025
# RUN  19 , total integrated cost =  4.002468271921596
# RUN  20 , total integrated cost =  4.002468264745294
# RUN  30 , total integrated cost =  4.002468137550154
# RUN  40 , total integrated cost =  4.002467997617895
# RUN  50 , total integrated cost =  4.002467864298043
# RUN  60 , total integrated cost =  4.002467736268215
# RUN  70 , total integrated cost =  4.002467626769307
# RUN  80 , total integrated cost =  4.002467469567666
# RUN  90 , total integrated cost =  4.00246739276538
# RUN  100 , total integrated cost =  4.002467244959824
# RUN  110 , total integrated cost =  4.002467113505905
# RUN  120 , total integrated cost =  4.00246696029344
# RUN  130 , total integrated cost =  4.002466834498935
# RUN  140 , total integrated cost =  4.002466727083986
# RUN  150 , total integrated cost =  4.0024665914001725
# RUN  160 , total integrated cost =  4.002466500255533
# RUN  170 , total integrated cost =  4.00246636963627
# RUN  180 , total integrated cost =  4.0024662290542015
# RUN  190 , total integrated cost =  4.0024661000878545
# RUN  200 , total integrated cost =  4.002465998723778
# RUN  300 , total integrated cost =  4.00246472007128
# RUN  400 , total integrated cost =  4.002463567437763
# RUN  500 , total integrated cost =  4.0024622549887
# RUN  600 , total integrated cost =  4.002461028502179
# RUN  700 , total integrated cost =  4.002459792263153
# RUN  800 , total integrated cost =  4.002458664397657
# RUN  900 , total integrated cost =  4.002457515807307
# RUN  1000 , total integrated cost =  4.002456372166196
# RUN  1000 , total integrated cost =  4.002456372166196
# Improved over  1000  iterations in  65.01408028043807  seconds by  0.00030365126607989623  percent.
# cost splitting :  [3.71848906e-06 0.00000000e+00] [8.00976994e+00 1.21391536e-24]
# ----- 590
# interpolate adjoint :  True True True
# initial cost =  4.002456372166196
# RUN  0 , total integrated cost =  4.002456372166196
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.002456363945884
# RUN  2 , total integrated cost =  4.002456359555663
# RUN  3 , total integrated cost =  4.002456354164223
# RUN  4 , total integrated cost =  4.002456351211873
# RUN  5 , total integrated cost =  4.002456346917513
# RUN  6 , total integrated cost =  4.002456344099332
# RUN  7 , total integrated cost =  4.002456338260746
# RUN  8 , total integrated cost =  4.002456333565806
# RUN  9 , total integrated cost =  4.0024563016845445
# RUN  10 , total integrated cost =  4.002456272088931
# RUN  11 , total integrated cost =  4.002456253670265
# RUN  12 , total integrated cost =  4.00245623377316
# RUN  13 , total integrated cost =  4.0024562267113355
# RUN  14 , total integrated cost =  4.002456218488837
# RUN  15 , total integrated cost =  4.002456214101364
# RUN  16 , total integrated cost =  4.002456208709146
# RUN  17 , total integrated cost =  4.00245620575797
# RUN  18 , total integrated cost =  4.002456201464398
# RUN  19 , total integrated cost =  4.002456198646103
# RUN  20 , total integrated cost =  4.002456192811353
# RUN  30 , total integrated cost =  4.002456060330824
# RUN  40 , total integrated cost =  4.002455927654262
# RUN  50 , total integrated cost =  4.00245581748991
# RUN  60 , total integrated cost =  4.002455751918505
# RUN  70 , total integrated cost =  4.002455619919273
# RUN  80 , total integrated cost =  4.002455487237154
# RUN  90 , total integrated cost =  4.002455361569914
# RUN  100 , total integrated cost =  4.002455284489374
# RUN  110 , total integrated cost =  4.002455181217142
# RUN  120 , total integrated cost =  4.002455046024276
# RUN  130 , total integrated cost =  4.002454918871929
# RUN  140 , total integrated cost =  4.002454818875455
# RUN  150 , total integrated cost =  4.002454739818825
# RUN  160 , total integrated cost =  4.002454607530595
# RUN  170 , total integrated cost =  4.002454475070499
# RUN  180 , total integrated cost =  4.002454365556415
# RUN  190 , total integrated cost =  4.002454299652976
# RUN  200 , total integrated cost =  4.002454167926563
# RUN  300 , total integrated cost =  4.002452994431391
# RUN  400 , total integrated cost =  4.002451766182835
# RUN  500 , total integrated cost =  4.002450381609459
# RUN  600 , total integrated cost =  4.002448987816257
# RUN  700 , total integrated cost =  4.002447776272279
# RUN  800 , total integrated cost =  4.002446407735785
# RUN  900 , total integrated cost =  4.002445071061205
# RUN  1000 , total integrated cost =  4.002443677360032
# RUN  1000 , total integrated cost =  4.002443677360032
# Improved over  1000  iterations in  65.29270364064723  seconds by  0.0003171753789104059  percent.
# cost splitting :  [3.77111979e-06 0.00000000e+00] [8.00971830e+00 1.21391536e-24]
# ----- 590
# interpolate adjoint :  True True True
# initial cost =  4.002443677360032
# RUN  0 , total integrated cost =  4.002443677360032
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.002443661757376
# RUN  2 , total integrated cost =  4.002443642593797
# RUN  3 , total integrated cost =  4.002443635371479
# RUN  4 , total integrated cost =  4.002443625782912
# RUN  5 , total integrated cost =  4.002443622061322
# RUN  6 , total integrated cost =  4.002443616779111
# RUN  7 , total integrated cost =  4.002443614206447
# RUN  8 , total integrated cost =  4.002443609621822
# RUN  9 , total integrated cost =  4.002443606479076
# RUN  10 , total integrated cost =  4.0024435944522
# RUN  11 , total integrated cost =  4.002443584802195
# RUN  12 , total integrated cost =  4.00244353093584
# RUN  13 , total integrated cost =  4.002443477711044
# RUN  14 , total integrated cost =  4.002443474472971
# RUN  15 , total integrated cost =  4.002443469713393
# RUN  16 , total integrated cost =  4.00244346717002
# RUN  17 , total integrated cost =  4.002443461685835
# RUN  18 , total integrated cost =  4.002443457416951
# RUN  19 , total integrated cost =  4.002443422666798
# RUN  20 , total integrated cost =  4.002443389785713
# RUN  30 , total integrated cost =  4.0024433134290325
# RUN  40 , total integrated cost =  4.002443192007458
# RUN  50 , total integrated cost =  4.002443055769512
# RUN  60 , total integrated cost =  4.002442931296065
# RUN  70 , total integrated cost =  4.002442807135841
# RUN  80 , total integrated cost =  4.002442694654335
# RUN  90 , total integrated cost =  4.002442617263283
# RUN  100 , total integrated cost =  4.002442397736118
# RUN  110 , total integrated cost =  4.002442262876155
# RUN  120 , total integrated cost =  4.002442157275509
# RUN  130 , total integrated cost =  4.002441982658247
# RUN  140 , total integrated cost =  4.002441853062936
# RUN  150 , total integrated cost =  4.002441729027623
# RUN  160 , total integrated cost =  4.00244162121832
# RUN  170 , total integrated cost =  4.002441434930552
# RUN  180 , total integrated cost =  4.0024413090850395
# RUN  190 , total integrated cost =  4.002441180777569
# RUN  200 , total integrated cost =  4.002441032593835
# RUN  300 , total integrated cost =  4.002439633407711
# RUN  400 , total integrated cost =  4.002438305182595
# RUN  500 , total integrated cost =  4.002436941069885
# RUN  600 , total integrated cost =  4.002435567697595
# RUN  700 , total integrated cost =  4.002434157910241
# RUN  800 , total integrated cost =  4.002432997887848
# RUN  900 , total integrated cost =  4.002431633145483
# RUN  1000 , total integrated cost =  4.002430378310052
# RUN  1000 , total integrated cost =  4.002430378310052
# Improved over  1000  iterations in  65.34410923346877  seconds by  0.0003322732573280973  percent.
# cost splitting :  [3.76841943e-06 0.00000000e+00] [8.00966511e+00 1.21391536e-24]
# ----- 590
# ...
# RUN  9 , total integrated cost =  3.9905018327663018
# RUN  10 , total integrated cost =  3.99050183276324
# RUN  11 , total integrated cost =  3.990501832760892
# RUN  12 , total integrated cost =  3.990501832753421
# RUN  13 , total integrated cost =  3.9905018302716453
# RUN  14 , total integrated cost =  3.9905018267005454
# RUN  15 , total integrated cost =  3.9905018266897425
# RUN  16 , total integrated cost =  3.990501826687234
# RUN  17 , total integrated cost =  3.990501826684489
# RUN  18 , total integrated cost =  3.990501826668686
# RUN  19 , total integrated cost =  3.99050182558258
# RUN  20 , total integrated cost =  3.9905018250487294
# RUN  30 , total integrated cost =  3.990501823723592
# RUN  40 , total integrated cost =  3.9905018011658244
# RUN  50 , total integrated cost =  3.990501794626417
# RUN  60 , total integrated cost =  3.9905017913132093
# RUN  70 , total integrated cost =  3.9905017901524724
# RUN  80 , total integrated cost =  3.990501789347067
# RUN  90 , total integrated cost =  3.9905017881617626
# RUN  100 , total integrated cost =  3.9905017648966767
# RUN  110 , total integrated cost =  3.990501758263303
# RUN  120 , total integrated cost =  3.9905017565831105
# RUN  130 , total integrated cost =  3.990501754818543
# RUN  140 , total integrated cost =  3.9905017323024996
# RUN  150 , total integrated cost =  3.990501724600521
# RUN  160 , total integrated cost =  3.9905017228594346
# RUN  170 , total integrated cost =  3.990501716748109
# RUN  180 , total integrated cost =  3.990501713928913
# RUN  190 , total integrated cost =  3.990501691424252
# RUN  200 , total integrated cost =  3.9905016852502926
# RUN  300 , total integrated cost =  3.9905016223078213
# RUN  400 , total integrated cost =  3.99050156494133
# RUN  500 , total integrated cost =  3.9905012837140164
# RUN  600 , total integrated cost =  3.9905010626719344
# RUN  700 , total integrated cost =  3.9905010108148136
# RUN  800 , total integrated cost =  3.990500847089859
# RUN  900 , total integrated cost =  3.990500752930321
# RUN  1000 , total integrated cost =  3.9905007306127622
# RUN  1000 , total integrated cost =  3.9905007306127622
# Improved over  1000  iterations in  62.94910024572164  seconds by  2.7663768307206738e-05  percent.
# cost splitting :  [3.36395942e-06 0.00000000e+00] [7.96199455e+00 1.21391536e-24]
# ----- 600
# interpolate adjoint :  True True True
# initial cost =  3.9905007306127622
# RUN  0 , total integrated cost =  3.9905007306127622
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.990500730220341
# RUN  2 , total integrated cost =  3.990500729368339
# RUN  3 , total integrated cost =  3.9905007293441854
# RUN  4 , total integrated cost =  3.990500729340512
# RUN  5 , total integrated cost =  3.9905007293373957
# RUN  6 , total integrated cost =  3.9905007293228274
# RUN  7 , total integrated cost =  3.9905007283327025
# RUN  8 , total integrated cost =  3.990500727857356
# RUN  9 , total integrated cost =  3.9905007278495734
# RUN  10 , total integrated cost =  3.990500727846708
# RUN  11 , total integrated cost =  3.990500727842302
# RUN  12 , total integrated cost =  3.9905007277833935
# RUN  13 , total integrated cost =  3.9905007274245725
# RUN  14 , total integrated cost =  3.9905007273869977
# RUN  15 , total integrated cost =  3.9905007273832904
# RUN  16 , total integrated cost =  3.990500727380196
# RUN  17 , total integrated cost =  3.990500727365821
# RUN  18 , total integrated cost =  3.990500726380118
# RUN  19 , total integrated cost =  3.990500725900313
# RUN  20 , total integrated cost =  3.990500725892435
# RUN  30 , total integrated cost =  3.9905007228375133
# RUN  40 , total integrated cost =  3.9905007214742887
# RUN  50 , total integrated cost =  3.990500719952028
# RUN  60 , total integrated cost =  3.9905007178972296
# RUN  70 , total integrated cost =  3.9905007145138613
# RUN  80 , total integrated cost =  3.9905007123453107
# RUN  90 , total integrated cost =  3.9905007104267485
# RUN  100 , total integrated cost =  3.9905007088297855
# RUN  110 , total integrated cost =  3.990500705824587
# RUN  120 , total integrated cost =  3.990500704253293
# RUN  130 , total integrated cost =  3.9905007013720453
# RUN  140 , total integrated cost =  3.9905006983192766
# RUN  150 , total integrated cost =  3.990500696867361
# RUN  160 , total integrated cost =  3.990500695332053
# RUN  170 , total integrated cost =  3.990500693390854
# RUN  180 , total integrated cost =  3.990500690009526
# RUN  190 , total integrated cost =  3.9905006879464224
# RUN  200 , total integrated cost =  3.9905006859170826
# RUN  300 , total integrated cost =  3.9905006644267207
# RUN  400 , total integrated cost =  3.9905005847428767
# RUN  500 , total integrated cost =  3.9905005611821323
# RUN  600 , total integrated cost =  3.990500481094015
# RUN  700 , total integrated cost =  3.990500458688291
# RUN  800 , total integrated cost =  3.990500437756054
# RUN  900 , total integrated cost =  3.9905004140663807
# RUN  1000 , total integrated cost =  3.990500392939958
# RUN  1000 , total integrated cost =  3.990500392939958
# Improved over  1000  iterations in  62.49354815389961  seconds by  8.461915612656412e-06  percent.
# cost splitting :  [3.36781923e-06 0.00000000e+00] [7.96199314e+00 1.21391536e-24]
# ----- 600
# interpolate adjoint :  True True True
# initial cost =  3.990500392939958
# RUN  0 , total integrated cost =  3.990500392939958
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.9905003929361658
# RUN  2 , total integrated cost =  3.9905003929327525
# RUN  3 , total integrated cost =  3.9905003929134937
# RUN  4 , total integrated cost =  3.9905003922959943
# RUN  5 , total integrated cost =  3.990500392058647
# RUN  6 , total integrated cost =  3.9905003920516204
# RUN  7 , total integrated cost =  3.990500392048593
# RUN  8 , total integrated cost =  3.990500392042478
# RUN  9 , total integrated cost =  3.990500391664364
# RUN  10 , total integrated cost =  3.9905003908099834
# RUN  11 , total integrated cost =  3.9905003907996948
# RUN  12 , total integrated cost =  3.9905003907965657
# RUN  13 , total integrated cost =  3.9905003907914733
# RUN  14 , total integrated cost =  3.9905003906864076
# RUN  15 , total integrated cost =  3.9905003902747898
# RUN  16 , total integrated cost =  3.990500390241195
# RUN  17 , total integrated cost =  3.9905003902375555
# RUN  18 , total integrated cost =  3.9905003902336684
# RUN  19 , total integrated cost =  3.990500390196334
# RUN  20 , total integrated cost =  3.9905003898336333
# RUN  30 , total integrated cost =  3.9905003332662767
# RUN  40 , total integrated cost =  3.990500330187961
# RUN  50 , total integrated cost =  3.9905003285276823
# RUN  60 , total integrated cost =  3.990500326719494
# RUN  70 , total integrated cost =  3.9905003238978294
# RUN  80 , total integrated cost =  3.9905003220904502
# RUN  90 , total integrated cost =  3.990500319272446
# RUN  100 , total integrated cost =  3.990500317491529
# RUN  110 , total integrated cost =  3.9905003077304966
# RUN  120 , total integrated cost =  3.990500275251826
# RUN  130 , total integrated cost =  3.9905002738463966
# RUN  140 , total integrated cost =  3.9904994743622764
# RUN  150 , total integrated cost =  3.990499472335827
# RUN  160 , total integrated cost =  3.9904994621616896
# RUN  170 , total integrated cost =  3.9904994587455116
# RUN  180 , total integrated cost =  3.9904994575559374
# RUN  190 , total integrated cost =  3.9904994561411242
# RUN  200 , total integrated cost =  3.9904994547304886
# RUN  300 , total integrated cost =  3.990499341624919
# RUN  400 , total integrated cost =  3.9904992454683224
# RUN  500 , total integrated cost =  3.9904985048644384
# RUN  600 , total integrated cost =  3.9904984503983605
# RUN  700 , total integrated cost =  3.9904984395638152
# RUN  800 , total integrated cost =  3.9904984287469567
# RUN  900 , total integrated cost =  3.9904984175129656
# RUN  1000 , total integrated cost =  3.990498406531684
# RUN  1000 , total integrated cost =  3.990498406531684
# Improved over  1000  iterations in  63.80809376575053  seconds by  4.977842571918245e-05  percent.
# cost splitting :  [3.36614307e-06 0.00000000e+00] [7.96198524e+00 1.21391536e-24]
# ----- 600
# interpolate adjoint :  True True True
# initial cost =  3.990498406531684
# RUN  0 , total integrated cost =  3.990498406531684
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.990498406430576
# RUN  2 , total integrated cost =  3.9904984060897846
# RUN  3 , total integrated cost =  3.990498406065025
# RUN  4 , total integrated cost =  3.990498406056273
# RUN  5 , total integrated cost =  3.990498405940639
# RUN  6 , total integrated cost =  3.990498405589669
# RUN  7 , total integrated cost =  3.9904984055616466
# RUN  8 , total integrated cost =  3.9904984055531556
# RUN  9 , total integrated cost =  3.990498405451003
# RUN  10 , total integrated cost =  3.9904984051110395
# RUN  11 , total integrated cost =  3.990498405086527
# RUN  12 , total integrated cost =  3.990498405077748
# RUN  13 , total integrated cost =  3.990498404960933
# RUN  14 , total integrated cost =  3.9904984045904173
# RUN  15 , total integrated cost =  3.9904984045552103
# RUN  16 , total integrated cost =  3.990498404546829
# RUN  17 , total integrated cost =  3.990498404497468
# RUN  18 , total integrated cost =  3.9904984042080165
# RUN  19 , total integrated cost =  3.9904984041577882
# RUN  20 , total integrated cost =  3.990498404149399
# RUN  30 , total integrated cost =  3.990498402990998
# RUN  40 , total integrated cost =  3.9904984020300884
# RUN  50 , total integrated cost =  3.9904984007557665
# RUN  60 , total integrated cost =  3.99049839971304
# RUN  70 , total integrated cost =  3.9904983985625395
# RUN  80 , total integrated cost =  3.9904983976077744
# RUN  90 , total integrated cost =  3.9904983964351297
# RUN  100 , total integrated cost =  3.990498395410649
# RUN  110 , total integrated cost =  3.9904983941390944
# RUN  120 , total integrated cost =  3.990498393277822
# RUN  130 , total integrated cost =  3.99049839200732
# RUN  140 , total integrated cost =  3.9904983910532414
# RUN  150 , total integrated cost =  3.9904983897086677
# RUN  160 , total integrated cost =  3.990498388841902
# RUN  170 , total integrated cost =  3.99049838758465
# RUN  180 , total integrated cost =  3.9904983867240222
# RUN  190 , total integrated cost =  3.9904983852589653
# RUN  200 , total integrated cost =  3.9904983844211133
# RUN  300 , total integrated cost =  3.9904983733706123
# RUN  400 , total integrated cost =  3.990498362153447
# RUN  500 , total integrated cost =  3.990498351293795
# RUN  600 , total integrated cost =  3.9904983401611345
# RUN  700 , total integrated cost =  3.990498329109426
# RUN  800 , total integrated cost =  3.990498318259158
# RUN  900 , total integrated cost =  3.9904983071361184
# RUN  1000 , total integrated cost =  3.9904982957952804
# RUN  1000 , total integrated cost =  3.9904982957952804
# Improved over  1000  iterations in  63.70987027045339  seconds by  2.7750018318783987e-06  percent.
# cost splitting :  [3.36643916e-06 0.00000000e+00] [7.96198479e+00 1.21391536e-24]
# ----- 600
# interpolate adjoint :  True True True
# initial cost =  3.9904982957952804
# RUN  0 , total integrated cost =  3.9904982957952804
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.990498295738254
# RUN  2 , total integrated cost =  3.9904982954465833
# RUN  3 , total integrated cost =  3.990498295408596
# RUN  4 , total integrated cost =  3.9904982953997834
# RUN  5 , total integrated cost =  3.9904982952852985
# RUN  6 , total integrated cost =  3.9904982949351218
# RUN  7 , total integrated cost =  3.99049829490668
# RUN  8 , total integrated cost =  3.9904982948981202
# RUN  9 , total integrated cost =  3.990498294797011
# RUN  10 , total integrated cost =  3.990498294457808
# RUN  11 , total integrated cost =  3.9904982944329217
# RUN  12 , total integrated cost =  3.990498294424091
# RUN  13 , total integrated cost =  3.990498294308494
# RUN  14 , total integrated cost =  3.9904982939591727
# RUN  15 , total integrated cost =  3.9904982939310183
# RUN  16 , total integrated cost =  3.990498293922439
# RUN  17 , total integrated cost =  3.9904982938202944
# RUN  18 , total integrated cost =  3.9904982934819153
# RUN  19 , total integrated cost =  3.990498293457273
# RUN  20 , total integrated cost =  3.990498293448419
# RUN  30 , total integrated cost =  3.9904982921806234
# RUN  40 , total integrated cost =  3.9904982913212725
# RUN  50 , total integrated cost =  3.9904982898808634
# RUN  60 , total integrated cost =  3.9904982888408163
# RUN  70 , total integrated cost =  3.990498287694109
# RUN  80 , total integrated cost =  3.9904982867416345
# RUN  90 , total integrated cost =  3.9904982853258146
# RUN  100 , total integrated cost =  3.990498284366812
# RUN  110 , total integrated cost =  3.9904982832125326
# RUN  120 , total integrated cost =  3.9904982821901664
# RUN  130 , total integrated cost =  3.9904982807296054
# RUN  140 , total integrated cost =  3.990498279893554
# RUN  150 , total integrated cost =  3.990498278624075
# RUN  160 , total integrated cost =  3.99049827761163
# RUN  170 , total integrated cost =  3.9904982762717647
# RUN  180 , total integrated cost =  3.990498275406852
# RUN  190 , total integrated cost =  3.990498274070315
# RUN  200 , total integrated cost =  3.9904982730612484
# RUN  300 , total integrated cost =  3.9904982618090092
# RUN  400 , total integrated cost =  3.990498250390141
# RUN  500 , total integrated cost =  3.9904982390054458
# RUN  600 , total integrated cost =  3.990498227763261
# RUN  700 , total integrated cost =  3.9904982163435383
# RUN  800 , total integrated cost =  3.9904981577218637
# RUN  900 , total integrated cost =  3.9904979570650227
# RUN  1000 , total integrated cost =  3.99049790256178
# RUN  1000 , total integrated cost =  3.99049790256178
# Improved over  1000  iterations in  63.79860349372029  seconds by  9.854245547558094e-06  percent.
# cost splitting :  [3.36639504e-06 0.00000000e+00] [7.96198322e+00 1.21391536e-24]
# ----- 600
# interpolate adjoint :  True True True
# initial cost =  3.99049790256178
# RUN  0 , total integrated cost =  3.99049790256178
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.9904979024606133
# RUN  2 , total integrated cost =  3.990497902122283
# RUN  3 , total integrated cost =  3.9904979020973723
# RUN  4 , total integrated cost =  3.9904979020885065
# RUN  5 , total integrated cost =  3.9904979019728626
# RUN  6 , total integrated cost =  3.9904979016244413
# RUN  7 , total integrated cost =  3.9904979015962665
# RUN  8 , total integrated cost =  3.99049790158765
# RUN  9 , total integrated cost =  3.9904979014854476
# RUN  10 , total integrated cost =  3.990497901147938
# RUN  11 , total integrated cost =  3.9904979011232755
# RUN  12 , total integrated cost =  3.990497901114376
# RUN  13 , total integrated cost =  3.990497900997524
# RUN  14 , total integrated cost =  3.9904979006297303
# RUN  15 , total integrated cost =  3.9904979005943835
# RUN  16 , total integrated cost =  3.9904979005858743
# RUN  17 , total integrated cost =  3.9904979005363717
# RUN  18 , total integrated cost =  3.9904979002491183
# RUN  19 , total integrated cost =  3.9904979001987386
# RUN  20 , total integrated cost =  3.990497900190227
# RUN  30 , total integrated cost =  3.990497899037517
# RUN  40 , total integrated cost =  3.9904978980165513
# RUN  50 , total integrated cost =  3.990497896557982
# RUN  60 , total integrated cost =  3.9904978957230766
# RUN  70 , total integrated cost =  3.9904978944553284
# RUN  80 , total integrated cost =  3.9904978934442275
# RUN  90 , total integrated cost =  3.9904978921061343
# RUN  100 , total integrated cost =  3.9904978912424327
# RUN  110 , total integrated cost =  3.99049788990771
# RUN  120 , total integrated cost =  3.9904978888999643
# RUN  130 , total integrated cost =  3.9904978876349166
# RUN  140 , total integrated cost =  3.990497886776791
# RUN  150 , total integrated cost =  3.990497885339339
# RUN  160 , total integrated cost =  3.990497884300468
# RUN  170 , total integrated cost =  3.9904978830289375
# RUN  180 , total integrated cost =  3.9904978820085897
# RUN  190 , total integrated cost =  3.990497880743742
# RUN  200 , total integrated cost =  3.990497879885757

# %%
bestControl_maxW = np.array( [[None] * len(t_pen)] * len(exc) )
bestState_maxW = np.array( [[None] * len(t_pen)] * len(exc) )
cost_maxW = np.array( [[None] * len(t_pen)] * len(exc) )
costnode_maxW = np.array( [[None] * len(t_pen)] * len(exc) )
weights_maxW = np.array( [[None] * len(t_pen)] * len(exc) )
convergence_maxW = np.array( [[None] * len(t_pen)] * len(exc) )

file_maxW = 'up_Wmax.pickle'

# %%
for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    j = 0

    while not convergence_maxW[i][j]:

        dur = d_array[0]
        aln.params.duration = dur        
        setinit(initVars[i], aln)

        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        control0 = aln.getZeroControl()
        if type(bestControl_maxW[i][j]) == type(None):
            max_it = 10
            control0 = bestControl_[i][0][:,:,n_pre-1:-n_post+1]
            weight_ = ( cost_uncontrolled[i] - sum(costnode_[i][j][0][0][:]) ) / sum( costnode_[i][j][cost_index][0][:] )
            cost.setParams(1., weight_ * factor_we, weight_ * factor_ws)
            weights_maxW[i][j] = cost.getParams()
        else:
            control0 = bestControl_maxW[i][j][:,:,n_pre-1:-n_post+1]
            weight_ = ( cost_uncontrolled[i] - sum(costnode_maxW[i][j][0][0][:]) ) / sum( costnode_maxW[i][j][cost_index][0][:] )
            cost.setParams(1., weight_ * factor_we, weight_ * factor_ws)
            weights_maxW[i][j] = cost.getParams()
            max_it = int(100)

        bestControl_maxW[i][j], bestState_maxW[i][j], cost_maxW[i][j], runtime_, grad_, phi_, phi1_, costnode_maxW[i][j] = aln.A1(
            control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
            prec_variables_ = p_var, transition_time_ = t_pen[j])

        if cost_maxW[i][j][2] == 0.:
            convergence_maxW[i][j] = True

        print('cost splitting : ', costnode_[i][j][0][0][:2], costnode_[i][j][cost_index][0][:2])

        with open(file_maxW,'wb') as f:
            pickle.dump([bestControl_maxW, bestState_maxW, cost_maxW, costnode_maxW, weights_maxW], f)

# %%
for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    j = 0
    step = step1

    while j < 2001:
        
        if j >= 1000:
            step = step2
        
        if convergence_maxW[i][j]:
            j += step
            continue

        print('-----', j)

        dur = round(d_array[j],1)
        aln.params.duration = dur
        max_it = int(1000)  

        setinit(initVars[i], aln)
        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        if type(bestControl_maxW[i][j]) == type(None):
            control0 = aln.getZeroControl()
            control0[:,:,:-step] = bestControl_maxW[i][j-step][:,:,n_pre-1:-n_post+1]
            weight_ = ( cost_uncontrolled[i] * (1. - t_pen[0]) / (1. - t_pen[j])
                          - sum(costnode_maxW[i][j-step][0][0][:]) ) / sum( costnode_maxW[i][j-step][cost_index][0][:] )
            cost.setParams(1., weight_ * factor_we, weight_ * factor_ws)
            weights_maxW[i][j] = cost.getParams()

        else:
            control0 = bestControl_maxW[i][j][:,:,n_pre-1:-n_post+1]
            weight_ = ( cost_uncontrolled[i] * (1. - t_pen[0]) / (1. - t_pen[j])
                           - sum(costnode_maxW[i][j][0][0][:]) ) / sum( costnode_maxW[i][j][cost_index][0][:] )
            cost.setParams(1., weight_ * factor_we, weight_ * factor_ws)
            weights_maxW[i][j] = cost.getParams()

        bestControl_maxW[i][j], bestState_maxW[i][j], cost_maxW[i][j], runtime_, grad_, phi_, phi1_, costnode_maxW[i][j] = aln.A1(
            control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
            prec_variables_ = p_var, transition_time_ = t_pen[j])

        if cost_maxW[i][j][2] == 0.:
            convergence_maxW[i][j] = True

        print('cost splitting : ', costnode_maxW[i][j][0][0][:2], costnode_maxW[i][j][cost_index][0][:2])

    with open(file_maxW,'wb') as f:
            pickle.dump([bestControl_maxW, bestState_maxW, cost_maxW, costnode_maxW, weights_maxW], f)
