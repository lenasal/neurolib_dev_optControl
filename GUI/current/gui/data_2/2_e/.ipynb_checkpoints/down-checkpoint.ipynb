# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import sys
import pickle

path = os.getcwd().split(os.sep + 'GUI')[0]
if path not in sys.path:
    print("not here")
    sys.path.append(path)

from neurolib.models.aln import ALNModel
from neurolib.utils import plotFunctions as plotFunc
from neurolib.utils import costFunctions as cost
import neurolib.dashboard.functions as functions
import neurolib.dashboard.data as data
    
# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2 

#path = os.path.join(os.getcwd(), "plots")
# Out:
# not here

# %%
grid_data_file = os.path.join(os.getcwd().split('data')[0], 'bi.pickle')
with open(grid_data_file,'rb') as f:
    load_array= pickle.load(f)
exc = [load_array[0][20], load_array[0][50]]
inh = [load_array[1][20], load_array[1][50]]

folder = str(os.getcwd().split('data_2')[1])
print(folder)
case = str(folder[1])

file_ = 'down.pickle'

c_var = [0,1]
if len(folder) == 4:
    if folder[3] == 'e':
        p_var = [0]
    elif folder[3] == 'i':
        p_var = [1]
else:
    p_var = [0,1]
    
print(p_var)

step1 = 100
step2 = 10
step3 = 1

if case in ['1', '3']:
    index_cost = 2
else:
    index_cost = 1
# Out:
# /2_e
# [0]

# %%
aln = ALNModel()
N = aln.params.N

data.set_parameters(aln)

state_vars = aln.state_vars
init_vars = aln.init_vars

##############################################################
def setinit(init_vars_, model):
    state_vars = model.state_vars
    init_vars = model.init_vars
    for iv in range(len(init_vars)):
        for sv in range(len(state_vars)):
            if state_vars[sv] in init_vars[iv]:
                #print("set init vars ", )
                if model.params[init_vars[iv]].ndim == 2:
                    model.params[init_vars[iv]][0,:] = init_vars_[sv]
                else:
                    model.params[init_vars[iv]][0] = init_vars_[sv]
                    
##############################################################               
def setmaxmincontrol(max_c_c, min_c_c, max_c_r, min_c_r):
    import numpy as np
    
    max_cntrl = np.zeros(( 6 ))
    min_cntrl = np.zeros(( 6 ))
    
    max_cntrl[0] = max_c_c
    min_cntrl[0] = min_c_c
    max_cntrl[1] = max_c_c
    min_cntrl[1] = min_c_c
    max_cntrl[2] = max_c_r
    min_cntrl[2] = min_c_r
    max_cntrl[3] = max_c_r
    min_cntrl[3] = min_c_r
    max_cntrl[4] = max_c_r
    min_cntrl[4] = min_c_r
    max_cntrl[5] = max_c_r
    min_cntrl[5] = min_c_r
            
    return max_cntrl, min_cntrl

# %%
d_array = np.arange(500., 20, -0.1)
t0_array = d_array - 20.
t_pen = np.zeros(( t0_array.shape ))
for i in range(len(t_pen)):
    t_pen[i] = t0_array[i] / d_array[i]

# %%
dur_pre = 10
dur_post = 10

n_pre = int(np.around(dur_pre/aln.params.dt + 1.,1))
n_post = int(np.around(dur_post/aln.params.dt + 1.,1))

tol = 1e-12
start_step = 10.
c_scheme = np.zeros(( 1,1 ))
c_scheme[0,0] = 1.
u_mat = np.identity(1)
u_scheme = np.array([[1.]])

if case in ['1', '2']:    # low to high
    max_I = [3., -3.]
else:
    max_I = [-3., 3.]
    
if case in ['1', '3']:    # sparsity
    factor_ws = 1.
    factor_we = 0.
    cost_index = 2
else:
    factor_ws = 0.
    factor_we = 1.
    cost_index = 1
    
maxC = [1000., -1000., 0.18, 0.]
max_cntrl, min_cntrl = setmaxmincontrol(maxC[0], maxC[1], maxC[2], maxC[3])

# %%
bestControl_ = np.array( [[None] * len(t_pen)] * len(exc) )
bestState_ = np.array( [[None] * len(t_pen)] * len(exc) )
cost_ = np.array( [[None] * len(t_pen)] * len(exc) )
costnode_ = np.array( [[None] * len(t_pen)] * len(exc) )
weights_ = np.array( [[None] * len(t_pen)] * len(exc) )
convergence_ = np.array( [[None] * len(t_pen)] * len(exc) )

initVars = [None] * len(exc)
target = [None] * len(exc)
cost_uncontrolled = [None] * len(exc)

print(bestControl_.shape)
# Out:
# (2, 4800)

# %%
i_range = range(len(exc))

if os.path.isfile(file_) :
    print("file found")
    
    with open(file_,'rb') as f:
        load_array = pickle.load(f)
    
    bestControl_ = load_array[0]
    bestState_ = load_array[1]
    cost_ = load_array[2]
    costnode_ = load_array[3]
    weights_ = load_array[4]
# Out:
# file found

# %%
# get initial parameters and target states

i_range = range(len(exc))
data.set_parameters(aln)
max_percent = []

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    aln.params.duration = 3000.
    
    control0 = aln.getZeroControl()
    control0 = functions.step_control(aln, maxI_ = max_I[0])

    aln.run(control=control0)
    
    target_rates = np.zeros((2))
    target_rates[0] = aln.rates_exc[0,-1] 
    target_rates[1] = aln.rates_inh[0,-1]

    control0 = functions.step_control(aln, maxI_ = max_I[1])
    aln.run(control=control0)

    init_state_vars = np.zeros(( len(state_vars) ))
    for j in range(len(state_vars)):
        if aln.state[state_vars[j]].size == 1:
            init_state_vars[j] = aln.state[state_vars[j]][0]
        else:
            init_state_vars[j] = aln.state[state_vars[j]][0,-1]

    initVars[i] = init_state_vars
    target[i] = [target_rates[0], target_rates[1]]
    
    max_percent.append( (np.argmax(np.abs(bestControl_[i][0]), axis=2)[0,1] -100) / 4800 )
# Out:
# -------  0 0.4500000000000001 0.4750000000000002
# -------  1 0.47500000000000014 0.6000000000000003

# %%
# get uncontrolled cost

data.set_parameters(aln)

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    dur = d_array[0]
    aln.params.duration = dur
    
    target_ = aln.getZeroTarget()
    target_[:,0,:] = target[i][0]
    target_[:,1,:] = target[i][1]
            
    cost.setParams(1.0, 0.0, 0.0)

    setinit(initVars[i], aln)
    control0 = aln.getZeroControl()

    # "HS", "FR", "PR", "HZ"
    cgv = None
    max_it = 0

    bestControl_init_, bestState_init_, cost_init_, runtime_init_, grad_init_, phi_init_, phi1_, costnode_init_ = aln.A1(
        control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
        prec_variables_ = p_var, transition_time_ = t_pen[0])
    
    cost_uncontrolled[i] = cost_init_[0]
# Out:
# -------  0 0.4500000000000001 0.4750000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  316931.9421284
# RUN  0 , total integrated cost =  316931.9421284
# Gradient descend method:  None
# RUN  0 , total integrated cost =  316931.9421284
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  1 0.47500000000000014 0.6000000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  396670.24943190784
# RUN  0 , total integrated cost =  396670.24943190784
# Gradient descend method:  None
# RUN  0 , total integrated cost =  396670.24943190784
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.

# %%
for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    j = 0
    step = step1

    while j < 4799:

        if j == 0:
            j += step
            continue
            
        if not convergence_[i][j-step]:
            if j - step > 0:
                j -= step
                print('go back to -----', j)

        print('-----', j)

        if convergence_[i][j]:
            j += step
            continue

        dur = d_array[j]
        T = 5001 - j
        aln.params.duration = dur

        cost.setParams(1., factor_we, factor_ws)
        weights_[i][j] = cost.getParams()

        setinit(initVars[i], aln)

        max_it = 1000

        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        if type(bestControl_[i][j]) == type(None):
            max_percent_prev = (np.argmax(np.abs(bestControl_[i][j-step]), axis=2)[0,1] - 100) / (T-200)
            shift_ind = 0
            if j < 3000:
                while max_percent_prev > max_percent[i]:
                    shift_ind += 1
                    max_percent_prev = (np.argmax(np.abs(bestControl_[i][j-step]), axis=2)[0,1] - 100 - shift_ind) / (T-200)

            control0 = np.zeros(( bestControl_[i][j-step][:,:,100:-(100+step)].shape ))
            print('shift ind = ', shift_ind)
            if shift_ind != 0:
                control0[:,:,:-shift_ind] = 1. * bestControl_[i][j-step][:,:,100+shift_ind:-(100+step)]
            else:
                control0[:,:,:] = 1. * bestControl_[i][j-step][:,:,100:-(100+step)]
                #control0[0,0,:] = 0.
        else:
            if bestControl_[i][j].shape[2] == T+200:
                control0 = bestControl_[i][j][:,:,100:-100]
                #control0[0,1,:] = 0.
            else:
                control0 = bestControl_[i][j][:,:,100:-(100+j)]

        bestControl_[i][j], bestState_[i][j], cost_[i][j], runtime_, grad_, phi_, phi1_, costnode_[i][j] = aln.A1(
            control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
            prec_variables_ = p_var, transition_time_ = t_pen[j])
        
        time_ = np.arange(-dur_pre,round(dur+dur_post+aln.params.dt,1),aln.params.dt)
        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        print(costnode_[i][j][0][0][0], costnode_[i][j][index_cost][0][:2])

        if cost_[i][j][-1] == 0.:
            convergence_[i][j] = True
            if j >= 4400:
                step = step2
            if j >=4790:
                step = step3

        with open(file_,'wb') as f:
            pickle.dump([bestControl_, bestState_, cost_, costnode_, weights_], f)

        j += step
# Out:
# -------  0 0.4500000000000001 0.4750000000000002
# ----- 100
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.3311692431255353
# RUN  0 , total integrated cost =  3.3311692431255353
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.3311692431255353
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.3311692431255353
# Improved over  1  iterations in  10.228906512260437  seconds by  0.0  percent.
# 3.503634850379466e-10 [7.53690786e-36 5.54834423e+00]
# ----- 200
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.3311692706298626
# RUN  0 , total integrated cost =  3.3311692706298626
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.3311692706298626
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.3311692706298626
# Improved over  1  iterations in  0.25186891946941614  seconds by  0.0  percent.
# 5.40288831369283e-10 [7.53689509e-36 5.54834431e+00]
# ----- 300
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.331169311777218
# RUN  0 , total integrated cost =  3.331169311777218
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.331169311777218
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.331169311777218
# Improved over  1  iterations in  0.2515021786093712  seconds by  0.0  percent.
# 8.390173095377646e-10 [7.53672721e-36 5.54834443e+00]
# ----- 400
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.33116926001615
# RUN  0 , total integrated cost =  3.33116926001615
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.33116926001615
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.33116926001615
# Improved over  1  iterations in  0.2474526185542345  seconds by  0.0  percent.
# 6.216992453080934e-10 [7.53528298e-36 5.54834427e+00]
# ----- 500
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.3311693104428395
# RUN  0 , total integrated cost =  3.3311693104428395
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.3311693104428395
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.3311693104428395
# Improved over  1  iterations in  0.23571899440139532  seconds by  0.0  percent.
# 1.4138222813754984e-09 [7.52796738e-36 5.54834438e+00]
# ----- 600
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.331169264705968
# RUN  0 , total integrated cost =  3.331169264705968
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.331169264705968
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.331169264705968
# Improved over  1  iterations in  0.2387007661163807  seconds by  0.0  percent.
# 1.0715994287257891e-09 [7.52705564e-36 5.54834426e+00]
# ----- 700
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.331168802088103
# RUN  0 , total integrated cost =  3.331168802088103
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.331168802088103
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.331168802088103
# Improved over  1  iterations in  0.22883973084390163  seconds by  0.0  percent.
# 1.337243992201884e-09 [7.52697379e-36 5.54834270e+00]
# ----- 800
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.331168866100297
# RUN  0 , total integrated cost =  3.331168866100297
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.331168866100297
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.331168866100297
# Improved over  1  iterations in  0.24493606202304363  seconds by  0.0  percent.
# 2.2793457991232935e-09 [7.52696724e-36 5.54834285e+00]
# ----- 900
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.3311688471160634
# RUN  0 , total integrated cost =  3.3311688471160634
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.3311688471160634
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.3311688471160634
# Improved over  1  iterations in  0.2188457539305091  seconds by  0.0  percent.
# 2.661234872761525e-09 [7.52696667e-36 5.54834276e+00]
# ----- 1000
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.3311687701524924
# RUN  0 , total integrated cost =  3.3311687701524924
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.3311687701524924
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.3311687701524924
# Improved over  1  iterations in  0.21502976771444082  seconds by  0.0  percent.
# 2.799367209181432e-09 [7.52696656e-36 5.54834250e+00]
# ----- 1100
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.331168194132988
# RUN  0 , total integrated cost =  3.331168194132988
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.331168194132988
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.331168194132988
# Improved over  1  iterations in  0.21140237245708704  seconds by  0.0  percent.
# 4.369444644113792e-09 [7.52696646e-36 5.54834049e+00]
# ----- 1200
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.331168543073865
# RUN  0 , total integrated cost =  3.331168543073865
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.331168543073865
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.331168543073865
# Improved over  1  iterations in  0.2224743291735649  seconds by  0.0  percent.
# 5.596544081635108e-09 [7.52696631e-36 5.54834158e+00]
# ----- 1300
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.331169061577973
# RUN  0 , total integrated cost =  3.331169061577973
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.331169061577973
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.331169061577973
# Improved over  1  iterations in  0.2281156899407506  seconds by  0.0  percent.
# 7.261713475679724e-09 [7.52696609e-36 5.54834321e+00]
# ----- 1400
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.331168162938732
# RUN  0 , total integrated cost =  3.331168162938732
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.331168162938732
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.331168162938732
# Improved over  1  iterations in  0.19982239324599504  seconds by  0.0  percent.
# 1.0380155295355813e-08 [7.52696573e-36 5.54834005e+00]
# ----- 1500
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.3311693439693544
# RUN  0 , total integrated cost =  3.3311693439693544
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.3311693439693544
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.3311693439693544
# Improved over  1  iterations in  0.19855892099440098  seconds by  0.0  percent.
# 1.1842726517606228e-08 [1.92716914e-24 5.54834391e+00]
# ----- 1600
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.331173985996874
# RUN  0 , total integrated cost =  3.331173985996874
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.331173985996874
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.331173985996874
# Improved over  1  iterations in  0.2113678753376007  seconds by  0.0  percent.
# 2.418633838465135e-08 [7.80276897e-24 5.54835870e+00]
# ----- 1700
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.331179779061203
# RUN  0 , total integrated cost =  3.331179779061203
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.331179779061203
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.331179779061203
# Improved over  1  iterations in  0.19199280254542828  seconds by  0.0  percent.
# 3.310454565942349e-08 [4.10632925e-24 5.54837755e+00]
# ----- 1800
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.3311884413437647
# RUN  0 , total integrated cost =  3.3311884413437647
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.3311884413437647
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.3311884413437647
# Improved over  1  iterations in  0.19412611983716488  seconds by  0.0  percent.
# 4.33441695578272e-08 [7.76718888e-24 5.54840592e+00]
# ----- 1900
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.331198229299501
# RUN  0 , total integrated cost =  3.331198229299501
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.331198229299501
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.331198229299501
# Improved over  1  iterations in  0.17860705498605967  seconds by  0.0  percent.
# 4.46811720278052e-08 [1.35798877e-23 5.54843853e+00]
# ----- 2000
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.3312208091354862
# RUN  0 , total integrated cost =  3.3312208091354862
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.3312208091354862
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.3312208091354862
# Improved over  1  iterations in  0.17748026549816132  seconds by  0.0  percent.
# 8.061728267345683e-08 [8.99780202e-24 5.54851203e+00]
# ----- 2100
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.3312517387607605
# RUN  0 , total integrated cost =  3.3312517387607605
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.3312517387607605
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.3312517387607605
# Improved over  1  iterations in  0.173530088737607  seconds by  0.0  percent.
# 1.2519795747911612e-07 [9.70422888e-24 5.54861305e+00]
# ----- 2200
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.3312955899711056
# RUN  0 , total integrated cost =  3.3312955899711056
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.3312955899711056
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.3312955899711056
# Improved over  1  iterations in  0.17131763882935047  seconds by  0.0  percent.
# 1.6252709033676388e-07 [4.64174831e-24 5.54875761e+00]
# ----- 2300
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.3313662195137197
# RUN  0 , total integrated cost =  3.3313662195137197
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.3313662195137197
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.3313662195137197
# Improved over  1  iterations in  0.16472932323813438  seconds by  0.0  percent.
# 2.2077746364961363e-07 [1.75474933e-23 5.54899056e+00]
# ----- 2400
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.3314689916864597
# RUN  0 , total integrated cost =  3.3314689916864597
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.3314689916864597
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.3314689916864597
# Improved over  1  iterations in  0.16197533812373877  seconds by  0.0  percent.
# 3.5929838546777893e-07 [2.83426630e-24 5.54932733e+00]
# ----- 2500
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.331634595672253
# RUN  0 , total integrated cost =  3.331634595672253
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.331634595672253
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.331634595672253
# Improved over  1  iterations in  0.15837047155946493  seconds by  0.0  percent.
# 4.850648640524351e-07 [9.56855169e-24 5.54987443e+00]
# ----- 2600
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.3318767462245757
# RUN  0 , total integrated cost =  3.3318767462245757
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.3318767462245757
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.3318767462245757
# Improved over  1  iterations in  0.15487169846892357  seconds by  0.0  percent.
# 7.556897823460238e-07 [1.54938769e-24 5.55067125e+00]
# ----- 2700
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.3322486128830344
# RUN  0 , total integrated cost =  3.3322486128830344
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.3322486128830344
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.3322486128830344
# Improved over  1  iterations in  0.14740551821887493  seconds by  0.0  percent.
# 1.1462623552266252e-06 [6.25801912e-24 5.55189668e+00]
# ----- 2800
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.332796893547122
# RUN  0 , total integrated cost =  3.332796893547122
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.332796893547122
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.332796893547122
# Improved over  1  iterations in  0.17336522415280342  seconds by  0.0  percent.
# 1.6016651278960809e-06 [5.33683056e-24 5.55370911e+00]
# ----- 2900
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.333651862018432
# RUN  0 , total integrated cost =  3.333651862018432
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.333651862018432
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.333651862018432
# Improved over  1  iterations in  0.14010166190564632  seconds by  0.0  percent.
# 2.681405789485004e-06 [1.15934341e-23 5.55652393e+00]
# ----- 3000
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.336371342349519
# RUN  0 , total integrated cost =  3.336371342349519
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.336371342349519
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.336371342349519
# Improved over  1  iterations in  0.15846577379852533  seconds by  0.0  percent.
# 4.888779180791028e-06 [2.19722193e-24 5.56552449e+00]
# ----- 3100
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.3421010980858887
# RUN  0 , total integrated cost =  3.3421010980858887
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.3421010980858887
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.3421010980858887
# Improved over  1  iterations in  0.14751252625137568  seconds by  0.0  percent.
# 1.0936511764516927e-05 [2.39442188e-23 5.58447419e+00]
# ----- 3200
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.3472633812443258
# RUN  0 , total integrated cost =  3.3472633812443258
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.3472633812443258
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.3472633812443258
# Improved over  1  iterations in  0.12879165168851614  seconds by  0.0  percent.
# 1.607317571382761e-05 [4.20220716e-23 5.60160401e+00]
# ----- 3300
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.3476691664149674
# RUN  0 , total integrated cost =  3.3476691664149674
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.3476691664149674
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.3476691664149674
# Improved over  1  iterations in  0.11871644109487534  seconds by  0.0  percent.
# 1.760726412620614e-05 [1.03952186e-22 5.60294562e+00]
# ----- 3400
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.348361951054167
# RUN  0 , total integrated cost =  3.348361951054167
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.348361951054167
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.348361951054167
# Improved over  1  iterations in  0.11802991200238466  seconds by  0.0  percent.
# 1.9389369376691604e-05 [1.19986090e-23 5.60524677e+00]
# ----- 3500
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.351118612815391
# RUN  0 , total integrated cost =  3.351118612815391
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.351118612815391
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.351118612815391
# Improved over  1  iterations in  0.11970186699181795  seconds by  0.0  percent.
# 2.352050645295712e-05 [2.47277347e-21 5.61440939e+00]
# ----- 3600
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.355671344541031
# RUN  0 , total integrated cost =  3.355671344541031
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.355671344541031
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.355671344541031
# Improved over  1  iterations in  0.10172541346400976  seconds by  0.0  percent.
# 2.6183655312086865e-05 [7.17846834e-07 5.62563284e+00]
# ----- 3700
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.3637017880327793
# RUN  0 , total integrated cost =  3.3637017880327793
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.3637017880327793
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.3637017880327793
# Improved over  1  iterations in  0.09563978109508753  seconds by  0.0  percent.
# 2.8995537426208194e-05 [5.48236056e-06 5.64548146e+00]
# ----- 3800
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.3791298702837698
# RUN  0 , total integrated cost =  3.3791298702837698
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.3791298702837698
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.3791298702837698
# Improved over  1  iterations in  0.08870537579059601  seconds by  0.0  percent.
# 3.3638076236713494e-05 [3.71136795e-05 5.67950603e+00]
# ----- 3900
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.4034309892878887
# RUN  0 , total integrated cost =  3.4034309892878887
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.4034309892878887
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.4034309892878887
# Improved over  1  iterations in  0.08226691093295813  seconds by  0.0  percent.
# 4.060679006419994e-05 [1.57898487e-04 5.73059483e+00]
# ----- 4000
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.440935019695512
# RUN  0 , total integrated cost =  3.440935019695512
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.440935019695512
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.440935019695512
# Improved over  1  iterations in  0.09869806189090014  seconds by  0.0  percent.
# 5.099362763436942e-05 [5.17170758e-04 5.80900391e+00]
# ----- 4100
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.4992439339341255
# RUN  0 , total integrated cost =  3.4992439339341255
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.4992439339341255
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.4992439339341255
# Improved over  1  iterations in  0.07606331445276737  seconds by  0.0  percent.
# 6.539802390541019e-05 [1.66417040e-03 5.92113178e+00]
# ----- 4200
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.590750512639121
# RUN  0 , total integrated cost =  3.590750512639121
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.590750512639121
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.590750512639121
# Improved over  1  iterations in  0.0992182157933712  seconds by  0.0  percent.
# 8.55776995289466e-05 [5.35817396e-03 6.07919984e+00]
# ----- 4300
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.7339649632406773
# RUN  0 , total integrated cost =  3.7339649632406773
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.7339649632406773
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.7339649632406773
# Improved over  1  iterations in  0.06956511922180653  seconds by  0.0  percent.
# 0.00011254760559534677 [0.01612892 6.31534345]
# ----- 4400
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.9553995131618476
# RUN  0 , total integrated cost =  3.9553995131618476
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.9553995131618476
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.9553995131618476
# Improved over  1  iterations in  0.06568808481097221  seconds by  0.0  percent.
# 0.0001542702677080431 [0.04324424 6.70090773]
# ----- 4410
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.9827166203634725
# RUN  0 , total integrated cost =  3.9827166203634725
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.9827166203634725
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.9827166203634725
# Improved over  1  iterations in  0.06375801283866167  seconds by  0.0  percent.
# 0.0001582494916259113 [0.0479027  6.74446124]
# ----- 4420
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  4.011193073661135
# RUN  0 , total integrated cost =  4.011193073661135
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.011193073661135
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.011193073661135
# Improved over  1  iterations in  0.09696358442306519  seconds by  0.0  percent.
# 0.00016621665322251046 [0.05103843 6.81254488]
# ----- 4430
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  4.040972195414365
# RUN  0 , total integrated cost =  4.040972195414365
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.040972195414365
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.040972195414365
# Improved over  1  iterations in  0.06407793145626783  seconds by  0.0  percent.
# 0.00017483030572504752 [0.05455936 6.8825854 ]
# ----- 4440
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  4.071853342944232
# RUN  0 , total integrated cost =  4.071853342944232
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.071853342944232
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.071853342944232
# Improved over  1  iterations in  0.07525429222732782  seconds by  0.0  percent.
# 0.00018311223959588136 [0.05651731 6.97562062]
# ----- 4450
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  4.103082107785326
# RUN  0 , total integrated cost =  4.103082107785326
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.103082107785326
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.103082107785326
# Improved over  1  iterations in  0.09775340743362904  seconds by  0.0  percent.
# 0.0001877185222073413 [0.05708745 7.08636913]
# ----- 4460
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  4.132578221454463
# RUN  0 , total integrated cost =  4.132578221454463
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.132578221454463
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.132578221454463
# Improved over  1  iterations in  0.06553360167890787  seconds by  0.0  percent.
# 0.00019032918557338659 [0.04816197 7.3027144 ]
# ----- 4470
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  4.1597119054428875
# RUN  0 , total integrated cost =  4.1597119054428875
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.1597119054428875
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.1597119054428875
# Improved over  1  iterations in  0.06343241408467293  seconds by  0.0  percent.
# 0.0002111565950793999 [0.03380642 7.60160495]
# ----- 4480
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  4.187602019400898
# RUN  0 , total integrated cost =  4.187602019400898
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.187602019400898
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.187602019400898
# Improved over  1  iterations in  0.06017988547682762  seconds by  0.0  percent.
# 0.00025519889054263767 [0.02417529 7.86875436]
# ----- 4490
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  4.179570606150261
# RUN  0 , total integrated cost =  4.179570606150261
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.179570606150261
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.179570606150261
# Improved over  1  iterations in  0.06665987987071276  seconds by  0.0  percent.
# 0.00040164738003015094 [1.86770709e-04 8.64956500e+00]
# ----- 4500
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  4.194865524543614
# RUN  0 , total integrated cost =  4.194865524543614
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.194865524543614
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.194865524543614
# Improved over  1  iterations in  0.06392047554254532  seconds by  0.0  percent.
# 0.000493593933110471 [2.87177808e-04 8.69307189e+00]
# ----- 4510
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  4.214001400054082
# RUN  0 , total integrated cost =  4.214001400054082
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.214001400054082
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.214001400054082
# Improved over  1  iterations in  0.07615681551396847  seconds by  0.0  percent.
# 0.0005949153901476851 [4.11590667e-04 8.75232975e+00]
# ----- 4520
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  4.238044968342985
# RUN  0 , total integrated cost =  4.238044968342985
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.238044968342985
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.238044968342985
# Improved over  1  iterations in  0.06575959548354149  seconds by  0.0  percent.
# 0.0007099462590850114 [5.84297754e-04 8.82907986e+00]
# ----- 4530
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  4.268608623483524
# RUN  0 , total integrated cost =  4.268608623483524
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.268608623483524
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.268608623483524
# Improved over  1  iterations in  0.07974782213568687  seconds by  0.0  percent.
# 0.0008279317496321935 [8.94282713e-04 8.92268098e+00]
# ----- 4540
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  4.307625752202729
# RUN  0 , total integrated cost =  4.307625752202729
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.307625752202729
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.307625752202729
# Improved over  1  iterations in  0.0639785872772336  seconds by  0.0  percent.
# 0.0009774895030791612 [1.42282229e-03 9.03991896e+00]
# ----- 4550
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  4.358146937628658
# RUN  0 , total integrated cost =  4.358146937628658
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.358146937628658
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.358146937628658
# Improved over  1  iterations in  0.0615709638223052  seconds by  0.0  percent.
# 0.0011480114669871633 [2.58660747e-03 9.17481147e+00]
# ----- 4560
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  4.423734178054993
# RUN  0 , total integrated cost =  4.423734178054993
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.423734178054993
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.423734178054993
# Improved over  1  iterations in  0.06784456130117178  seconds by  0.0  percent.
# 0.0012875151542136422 [4.8042999e-03 9.3436711e+00]
# ----- 4570
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  4.508450307623401
# RUN  0 , total integrated cost =  4.508450307623401
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.508450307623401
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.508450307623401
# Improved over  1  iterations in  0.060963766649365425  seconds by  0.0  percent.
# 0.0013886736490873806 [0.01066209 9.5023786 ]
# ----- 4580
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  4.616778752062834
# RUN  0 , total integrated cost =  4.616778752062834
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.616778752062834
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.616778752062834
# Improved over  1  iterations in  0.06215240899473429  seconds by  0.0  percent.
# 0.0013753283836755146 [0.02593544 9.61913963]
# ----- 4590
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  4.750119343034946
# RUN  0 , total integrated cost =  4.750119343034946
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.750119343034946
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.750119343034946
# Improved over  1  iterations in  0.059827376157045364  seconds by  0.0  percent.
# 0.0012433289509446884 [0.06974579 9.56633737]
# ----- 4600
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  4.906331715770445
# RUN  0 , total integrated cost =  4.906331715770445
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.906331715770445
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.906331715770445
# Improved over  1  iterations in  0.060817343182861805  seconds by  0.0  percent.
# 0.0010538672002936976 [0.18653078 9.21682025]
# ----- 4610
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  5.080651790427346
# RUN  0 , total integrated cost =  5.080651790427346
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.080651790427346
# Control only changes marginally.
# RUN  1 , total integrated cost =  5.080651790427346
# Improved over  1  iterations in  0.06265228241682053  seconds by  0.0  percent.
# 0.0009122854008924827 [0.40192579 8.74581429]
# ----- 4620
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  5.269316413034957
# RUN  0 , total integrated cost =  5.269316413034957
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.269316413034957
# Control only changes marginally.
# RUN  1 , total integrated cost =  5.269316413034957
# Improved over  1  iterations in  0.07654992584139109  seconds by  0.0  percent.
# 0.0007901318021203132 [0.7442974  8.19209498]
# ----- 4630
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  5.470772178030742
# RUN  0 , total integrated cost =  5.470772178030742
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.470772178030742
# Control only changes marginally.
# RUN  1 , total integrated cost =  5.470772178030742
# Improved over  1  iterations in  0.05967842321842909  seconds by  0.0  percent.
# 0.0007248991801961664 [1.24934821 7.56102352]
# ----- 4640
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  5.685287130707663
# RUN  0 , total integrated cost =  5.685287130707663
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.685287130707663
# Control only changes marginally.
# RUN  1 , total integrated cost =  5.685287130707663
# Improved over  1  iterations in  0.06516920030117035  seconds by  0.0  percent.
# 0.0007220093113341062 [1.93262125 6.91164447]
# ----- 4650
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  5.915080096511851
# RUN  0 , total integrated cost =  5.915080096511851
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.915080096511851
# Control only changes marginally.
# RUN  1 , total integrated cost =  5.915080096511851
# Improved over  1  iterations in  0.06377471331506968  seconds by  0.0  percent.
# 0.0006989256585378238 [2.84373177 6.22698835]
# ----- 4660
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  6.162351761026579
# RUN  0 , total integrated cost =  6.162351761026579
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.162351761026579
# Control only changes marginally.
# RUN  1 , total integrated cost =  6.162351761026579
# Improved over  1  iterations in  0.10506261046975851  seconds by  0.0  percent.
# 0.0006461252481082905 [4.2377804  5.28116536]
# ----- 4670
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  6.431306033294671
# RUN  0 , total integrated cost =  6.431306033294671
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.431306033294671
# Control only changes marginally.
# RUN  1 , total integrated cost =  6.431306033294671
# Improved over  1  iterations in  0.08713020011782646  seconds by  0.0  percent.
# 0.0006712525974120428 [5.94154902 4.44918526]
# ----- 4680
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  6.723958513731437
# RUN  0 , total integrated cost =  6.723958513731437
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.723958513731437
# Control only changes marginally.
# RUN  1 , total integrated cost =  6.723958513731437
# Improved over  1  iterations in  0.05407435167580843  seconds by  0.0  percent.
# 0.0006328822415865112 [8.27154274 3.5261816 ]
# ----- 4690
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  7.040348318236412
# RUN  0 , total integrated cost =  7.040348318236412
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.040348318236412
# Control only changes marginally.
# RUN  1 , total integrated cost =  7.040348318236412
# Improved over  1  iterations in  0.05432348884642124  seconds by  0.0  percent.
# 0.0006990110947427579 [11.3257027   2.59901191]
# ----- 4700
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  7.0933566585486565
# RUN  0 , total integrated cost =  7.0933566585486565
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.0933566585486565
# Control only changes marginally.
# RUN  1 , total integrated cost =  7.0933566585486565
# Improved over  1  iterations in  0.0629203887656331  seconds by  0.0  percent.
# 0.00041781923021218644 [2.51534163e+01 1.11376536e-24]
# ----- 4710
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  7.365595512527608
# RUN  0 , total integrated cost =  7.365595512527608
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.365595512527608
# Control only changes marginally.
# RUN  1 , total integrated cost =  7.365595512527608
# Improved over  1  iterations in  0.06323156785219908  seconds by  0.0  percent.
# 0.0004926351988882149 [2.71207456e+01 1.11376536e-24]
# ----- 4720
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  7.674630766578835
# RUN  0 , total integrated cost =  7.674630766578835
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.674630766578835
# Control only changes marginally.
# RUN  1 , total integrated cost =  7.674630766578835
# Improved over  1  iterations in  0.06774573866277933  seconds by  0.0  percent.
# 0.0006077682964501896 [2.94434582e+01 1.11376536e-24]
# ----- 4730
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  8.039697147275621
# RUN  0 , total integrated cost =  8.039697147275621
# Gradient descend method:  None
# RUN  1 , total integrated cost =  8.039697147275621
# Control only changes marginally.
# RUN  1 , total integrated cost =  8.039697147275621
# Improved over  1  iterations in  0.07864910177886486  seconds by  0.0  percent.
# 0.0007437634191564055 [3.23103035e+01 1.11376448e-24]
# ----- 4740
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  8.49033800080579
# RUN  0 , total integrated cost =  8.49033800080579
# Gradient descend method:  None
# RUN  1 , total integrated cost =  8.49033800080579
# Control only changes marginally.
# RUN  1 , total integrated cost =  8.49033800080579
# Improved over  1  iterations in  0.06274284422397614  seconds by  0.0  percent.
# 0.0009793492445645548 [3.60321234e+01 1.11371145e-24]
# ----- 4750
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  9.075632797055041
# RUN  0 , total integrated cost =  9.075632797055041
# Gradient descend method:  None
# RUN  1 , total integrated cost =  9.075632797055041
# Control only changes marginally.
# RUN  1 , total integrated cost =  9.075632797055041
# Improved over  1  iterations in  0.06292890943586826  seconds by  0.0  percent.
# 0.0012751842567497132 [4.11691046e+01 1.11347148e-24]
# ----- 4760
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  9.887988820909303
# RUN  0 , total integrated cost =  9.887988820909303
# Gradient descend method:  None
# RUN  1 , total integrated cost =  9.887988820909303
# Control only changes marginally.
# RUN  1 , total integrated cost =  9.887988820909303
# Improved over  1  iterations in  0.07267320062965155  seconds by  0.0  percent.
# 0.001963386569116912 [4.88628868e+01 1.11301499e-24]
# ----- 4770
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  11.127637642542739
# RUN  0 , total integrated cost =  11.127637642542739
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.127637642542739
# Control only changes marginally.
# RUN  1 , total integrated cost =  11.127637642542739
# Improved over  1  iterations in  0.06467012595385313  seconds by  0.0  percent.
# 0.003378176136721039 [6.18689656e+01 1.11244438e-24]
# ----- 4780
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  13.347045153863595
# RUN  0 , total integrated cost =  13.347045153863595
# Gradient descend method:  None
# RUN  1 , total integrated cost =  13.347045153863595
# Control only changes marginally.
# RUN  1 , total integrated cost =  13.347045153863595
# Improved over  1  iterations in  0.06451511103659868  seconds by  0.0  percent.
# 0.006826246279913745 [8.89716594e+01 1.11189219e-24]
# ----- 4790
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  19.048082659220142
# RUN  0 , total integrated cost =  19.048082659220142
# Gradient descend method:  None
# RUN  1 , total integrated cost =  19.04807912949459
# RUN  2 , total integrated cost =  19.04807559673746
# RUN  3 , total integrated cost =  19.048072094517572
# RUN  4 , total integrated cost =  19.048068639198014
# RUN  5 , total integrated cost =  19.04806517383962
# RUN  6 , total integrated cost =  19.04806170006693
# RUN  7 , total integrated cost =  19.04805825755923
# RUN  8 , total integrated cost =  19.0480547772446
# RUN  9 , total integrated cost =  19.048051315132952
# RUN  10 , total integrated cost =  19.04804786889915
# RUN  11 , total integrated cost =  19.048044361592748
# RUN  12 , total integrated cost =  19.048040846959072
# RUN  13 , total integrated cost =  19.04803740540901
# RUN  14 , total integrated cost =  19.048033929236336
# RUN  15 , total integrated cost =  19.048030468241794
# RUN  16 , total integrated cost =  19.048027025885467
# RUN  17 , total integrated cost =  19.04802351715962
# RUN  18 , total integrated cost =  19.04802000694366
# RUN  19 , total integrated cost =  19.048016566362772
# RUN  20 , total integrated cost =  19.048013094309116
# RUN  30 , total integrated cost =  19.047978447537655
# RUN  40 , total integrated cost =  19.04794371685124
# RUN  50 , total integrated cost =  19.047909043966374
# RUN  60 , total integrated cost =  19.047874365309816
# RUN  70 , total integrated cost =  19.047839749404655
# RUN  80 , total integrated cost =  19.047805173621928
# RUN  90 , total integrated cost =  19.0477706103758
# RUN  100 , total integrated cost =  19.047736143563377
# RUN  110 , total integrated cost =  19.04770172145604
# RUN  120 , total integrated cost =  19.04766735773309
# RUN  130 , total integrated cost =  19.047632989357105
# RUN  140 , total integrated cost =  19.047598607683895
# RUN  150 , total integrated cost =  19.04756427322206
# RUN  160 , total integrated cost =  19.04752999701583
# RUN  170 , total integrated cost =  19.047495713768342
# RUN  180 , total integrated cost =  19.047461622915268
# RUN  190 , total integrated cost =  19.047427419076527
# RUN  200 , total integrated cost =  19.047393263823647
# RUN  300 , total integrated cost =  19.04705378845468
# RUN  400 , total integrated cost =  19.046717952698156
# RUN  500 , total integrated cost =  19.046385714165787
# RUN  600 , total integrated cost =  19.046056768803748
# RUN  700 , total integrated cost =  19.045731368823734
# RUN  800 , total integrated cost =  19.045409270150724
# RUN  900 , total integrated cost =  19.045090532089517
# RUN  1000 , total integrated cost =  19.0447751835715
# RUN  1000 , total integrated cost =  19.0447751835715
# Improved over  1000  iterations in  47.678791884332895  seconds by  0.017363824526668736  percent.
# 0.024862935821332286 [1.80855005e+02 2.10313250e-25]
# -------  1 0.47500000000000014 0.6000000000000003
# ----- 100
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  5.00629374738296
# RUN  0 , total integrated cost =  5.00629374738296
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.00629374738296
# Control only changes marginally.
# RUN  1 , total integrated cost =  5.00629374738296
# Improved over  1  iterations in  0.2898163599893451  seconds by  0.0  percent.
# 1.6258575772393106e-08 [1.25314866e+01 9.97425085e-21]
# ----- 200
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  5.006408507604399
# RUN  0 , total integrated cost =  5.006408507604399
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.006408507604399
# Control only changes marginally.
# RUN  1 , total integrated cost =  5.006408507604399
# Improved over  1  iterations in  0.2928923424333334  seconds by  0.0  percent.
# 4.8206063341939845e-06 [1.25314866e+01 5.99092729e-17]
# ----- 300
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  5.006293497899016
# RUN  0 , total integrated cost =  5.006293497899016
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.006293497899016
# Control only changes marginally.
# RUN  1 , total integrated cost =  5.006293497899016
# Improved over  1  iterations in  0.25833734311163425  seconds by  0.0  percent.
# 2.790635597137083e-10 [1.25314873e+01 8.97706957e-24]
# ----- 400
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  5.006293434599554
# RUN  0 , total integrated cost =  5.006293434599554
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.006293434599554
# Control only changes marginally.
# RUN  1 , total integrated cost =  5.006293434599554
# Improved over  1  iterations in  0.2551107071340084  seconds by  0.0  percent.
# 1.1827173673346246e-10 [1.25314870e+01 8.42084164e-24]
# ----- 500
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  5.006293436789977
# RUN  0 , total integrated cost =  5.006293436789977
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.006293436789977
# Control only changes marginally.
# RUN  1 , total integrated cost =  5.006293436789977
# Improved over  1  iterations in  0.24746310338377953  seconds by  0.0  percent.
# 9.676970452236725e-11 [1.25314870e+01 8.42084164e-24]
# ----- 600
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  5.006293444333743
# RUN  0 , total integrated cost =  5.006293444333743
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.006293444333743
# Control only changes marginally.
# RUN  1 , total integrated cost =  5.006293444333743
# Improved over  1  iterations in  0.24264353327453136  seconds by  0.0  percent.
# 9.812003181804187e-11 [1.25314870e+01 8.42084164e-24]
# ----- 700
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  5.006293463850648
# RUN  0 , total integrated cost =  5.006293463850648
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.006293463850648
# Control only changes marginally.
# RUN  1 , total integrated cost =  5.006293463850648
# Improved over  1  iterations in  0.2514162678271532  seconds by  0.0  percent.
# 9.93205115108076e-11 [1.25314871e+01 8.42084164e-24]
# ----- 800
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  5.006293513178056
# RUN  0 , total integrated cost =  5.006293513178056
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.006293513178056
# Control only changes marginally.
# RUN  1 , total integrated cost =  5.006293513178056
# Improved over  1  iterations in  0.2359284833073616  seconds by  0.0  percent.
# 1.008510347119256e-10 [1.25314874e+01 8.42084164e-24]
# ----- 900
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  5.006293638201294
# RUN  0 , total integrated cost =  5.006293638201294
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.006293638201294
# Control only changes marginally.
# RUN  1 , total integrated cost =  5.006293638201294
# Improved over  1  iterations in  0.24217189941555262  seconds by  0.0  percent.
# 9.182062090361672e-11 [1.25314880e+01 4.55805317e-24]
# ----- 1000
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  5.006293839992579
# RUN  0 , total integrated cost =  5.006293839992579
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.006293839992579
# Control only changes marginally.
# RUN  1 , total integrated cost =  5.006293839992579
# Improved over  1  iterations in  0.22843710146844387  seconds by  0.0  percent.
# 1.5732724250177703e-10 [1.25314890e+01 4.55697012e-24]
# ----- 1100
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  5.006294413866856
# RUN  0 , total integrated cost =  5.006294413866856
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.006294413866856
# Control only changes marginally.
# RUN  1 , total integrated cost =  5.006294413866856
# Improved over  1  iterations in  0.23012892715632915  seconds by  0.0  percent.
# 1.5887287536385158e-10 [1.25314919e+01 4.54931837e-24]
# ----- 1200
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  5.006295862327239
# RUN  0 , total integrated cost =  5.006295862327239
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.006295862327239
# Control only changes marginally.
# RUN  1 , total integrated cost =  5.006295862327239
# Improved over  1  iterations in  0.21957248263061047  seconds by  0.0  percent.
# 1.6069292928149212e-10 [1.25314991e+01 4.54931699e-24]
# ----- 1300
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  5.006299573855994
# RUN  0 , total integrated cost =  5.006299573855994
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.006299573855994
# Control only changes marginally.
# RUN  1 , total integrated cost =  5.006299573855994
# Improved over  1  iterations in  0.22593438439071178  seconds by  0.0  percent.
# 1.422423308949453e-10 [1.25315177e+01 4.54931348e-24]
# ----- 1400
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  5.006308886079068
# RUN  0 , total integrated cost =  5.006308886079068
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.006308886079068
# Control only changes marginally.
# RUN  1 , total integrated cost =  5.006308886079068
# Improved over  1  iterations in  0.2224670611321926  seconds by  0.0  percent.
# 1.357990782549839e-10 [1.25315643e+01 4.54930466e-24]
# ----- 1500
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  5.006332390640372
# RUN  0 , total integrated cost =  5.006332390640372
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.006332390640372
# Control only changes marginally.
# ...
# interpolate adjoint :  True True True
# initial cost =  5622.551565118095
# RUN  0 , total integrated cost =  5622.551565118095
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5622.551239670297
# RUN  2 , total integrated cost =  5622.550917094585
# RUN  3 , total integrated cost =  5622.5506057949415
# RUN  4 , total integrated cost =  5622.5502691017
# RUN  5 , total integrated cost =  5622.549969826559
# RUN  6 , total integrated cost =  5622.54967997161
# RUN  7 , total integrated cost =  5622.549331365049
# RUN  8 , total integrated cost =  5622.548972886112
# RUN  9 , total integrated cost =  5622.548690973997
# RUN  10 , total integrated cost =  5622.548383603621
# RUN  11 , total integrated cost =  5622.548056076645
# RUN  12 , total integrated cost =  5622.547735575477
# RUN  13 , total integrated cost =  5622.5474220589595
# RUN  14 , total integrated cost =  5622.547087577711
# RUN  15 , total integrated cost =  5622.546786538892
# RUN  16 , total integrated cost =  5622.546498463085
# RUN  17 , total integrated cost =  5622.546147411376
# RUN  18 , total integrated cost =  5622.545791354614
# RUN  19 , total integrated cost =  5622.545507511962
# RUN  20 , total integrated cost =  5622.545202089035
# RUN  30 , total integrated cost =  5622.542020574353
# RUN  40 , total integrated cost =  5622.538839059815
# RUN  50 , total integrated cost =  5622.535657545698
# RUN  60 , total integrated cost =  5622.532476032142
# RUN  70 , total integrated cost =  5622.5292357574945
# RUN  80 , total integrated cost =  5622.526054224575
# RUN  90 , total integrated cost =  5622.522872690894
# RUN  100 , total integrated cost =  5622.51969115709
# RUN  110 , total integrated cost =  5622.516509623593
# RUN  120 , total integrated cost =  5622.513328090666
# RUN  130 , total integrated cost =  5622.510205684882
# RUN  140 , total integrated cost =  5622.50702417348
# RUN  150 , total integrated cost =  5622.503842661368
# RUN  160 , total integrated cost =  5622.500661149061
# RUN  170 , total integrated cost =  5622.497479636935
# RUN  180 , total integrated cost =  5622.494298125215
# RUN  190 , total integrated cost =  5622.491057669579
# RUN  200 , total integrated cost =  5622.487876139736
# RUN  300 , total integrated cost =  5622.456060850556
# RUN  400 , total integrated cost =  5622.424186797014
# RUN  500 , total integrated cost =  5622.392371664578
# RUN  600 , total integrated cost =  5622.360526463423
# RUN  700 , total integrated cost =  5622.3287110727315
# RUN  800 , total integrated cost =  5622.296807002975
# RUN  900 , total integrated cost =  5622.264991613443
# RUN  1000 , total integrated cost =  5622.2331163357185
# RUN  1000 , total integrated cost =  5622.2331163357185
# Improved over  1000  iterations in  48.379329848103225  seconds by  0.005663777000322057  percent.
# 1.4087982833595852e-06 [1.52151275e+07 5.60429540e+03]
# go back to ----- 3800
# ----- 3800
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  5622.2331163357185
# RUN  0 , total integrated cost =  5622.2331163357185
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5622.232815669654
# RUN  2 , total integrated cost =  5622.232527208576
# RUN  3 , total integrated cost =  5622.2321763349655
# RUN  4 , total integrated cost =  5622.231820090337
# RUN  5 , total integrated cost =  5622.231536119115
# RUN  6 , total integrated cost =  5622.231230815836
# RUN  7 , total integrated cost =  5622.230900785299
# RUN  8 , total integrated cost =  5622.230582772099
# RUN  9 , total integrated cost =  5622.230266283266
# RUN  10 , total integrated cost =  5622.229934757047
# RUN  11 , total integrated cost =  5622.229631108197
# RUN  12 , total integrated cost =  5622.229345656095
# RUN  13 , total integrated cost =  5622.22899064782
# RUN  14 , total integrated cost =  5622.228638499057
# RUN  15 , total integrated cost =  5622.228351264521
# RUN  16 , total integrated cost =  5622.228049253247
# RUN  17 , total integrated cost =  5622.2277157132485
# RUN  18 , total integrated cost =  5622.227401202007
# RUN  19 , total integrated cost =  5622.227080979984
# RUN  20 , total integrated cost =  5622.226753178987
# RUN  30 , total integrated cost =  5622.223571602051
# RUN  40 , total integrated cost =  5622.220390028977
# RUN  50 , total integrated cost =  5622.21720845566
# RUN  60 , total integrated cost =  5622.214026882909
# RUN  70 , total integrated cost =  5622.210786370824
# RUN  80 , total integrated cost =  5622.207633915563
# RUN  90 , total integrated cost =  5622.204452337178
# RUN  100 , total integrated cost =  5622.201270758598
# RUN  110 , total integrated cost =  5622.1980891806825
# RUN  120 , total integrated cost =  5622.194907603979
# RUN  130 , total integrated cost =  5622.19172603161
# RUN  140 , total integrated cost =  5622.1885444590625
# RUN  150 , total integrated cost =  5622.185362887185
# RUN  160 , total integrated cost =  5622.182122561578
# RUN  170 , total integrated cost =  5622.178940953671
# RUN  180 , total integrated cost =  5622.17575934641
# RUN  190 , total integrated cost =  5622.172577740591
# RUN  200 , total integrated cost =  5622.169425147709
# RUN  300 , total integrated cost =  5622.137579748368
# RUN  400 , total integrated cost =  5622.1057349563
# RUN  500 , total integrated cost =  5622.073861567254
# RUN  600 , total integrated cost =  5622.042077142238
# RUN  700 , total integrated cost =  5622.010321797821
# RUN  800 , total integrated cost =  5621.978478039413
# RUN  900 , total integrated cost =  5621.946634387916
# RUN  1000 , total integrated cost =  5621.914849564541
# RUN  1000 , total integrated cost =  5621.914849564541
# Improved over  1000  iterations in  48.08760156016797  seconds by  0.005660860455108718  percent.
# 1.3795612098529983e-06 [1.52133719e+07 5.60429540e+03]
# go back to ----- 3800
# ----- 3800
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  5621.914849564541
# RUN  0 , total integrated cost =  5621.914849564541
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5621.91454512338
# RUN  2 , total integrated cost =  5621.914260499664
# RUN  3 , total integrated cost =  5621.913905464028
# RUN  4 , total integrated cost =  5621.913553378298
# RUN  5 , total integrated cost =  5621.913266966813
# RUN  6 , total integrated cost =  5621.912964156995
# RUN  7 , total integrated cost =  5621.912632412685
# RUN  8 , total integrated cost =  5621.912316141623
# RUN  9 , total integrated cost =  5621.911998797287
# RUN  10 , total integrated cost =  5621.911668158775
# RUN  11 , total integrated cost =  5621.911364602606
# RUN  12 , total integrated cost =  5621.911079086033
# RUN  13 , total integrated cost =  5621.910725273837
# RUN  14 , total integrated cost =  5621.910371976037
# RUN  15 , total integrated cost =  5621.9100865275905
# RUN  16 , total integrated cost =  5621.909782746169
# RUN  17 , total integrated cost =  5621.90945203491
# RUN  18 , total integrated cost =  5621.909134732913
# RUN  19 , total integrated cost =  5621.908818484789
# RUN  20 , total integrated cost =  5621.908486752311
# RUN  30 , total integrated cost =  5621.905305345061
# RUN  40 , total integrated cost =  5621.902123936963
# RUN  50 , total integrated cost =  5621.898942527953
# RUN  60 , total integrated cost =  5621.895761118003
# RUN  70 , total integrated cost =  5621.892579707057
# RUN  80 , total integrated cost =  5621.8893982950885
# RUN  90 , total integrated cost =  5621.886216882069
# RUN  100 , total integrated cost =  5621.883064488896
# RUN  110 , total integrated cost =  5621.879824338906
# RUN  120 , total integrated cost =  5621.876672070065
# RUN  130 , total integrated cost =  5621.873490649336
# RUN  140 , total integrated cost =  5621.87030922834
# RUN  150 , total integrated cost =  5621.867127806865
# RUN  160 , total integrated cost =  5621.863946384782
# RUN  170 , total integrated cost =  5621.860764961981
# RUN  180 , total integrated cost =  5621.857583538369
# RUN  190 , total integrated cost =  5621.854402113876
# RUN  200 , total integrated cost =  5621.851220688472
# RUN  300 , total integrated cost =  5621.819406377511
# RUN  400 , total integrated cost =  5621.7875919564
# RUN  500 , total integrated cost =  5621.755777425575
# RUN  600 , total integrated cost =  5621.723962791425
# RUN  700 , total integrated cost =  5621.69214730009
# RUN  800 , total integrated cost =  5621.660272294305
# RUN  900 , total integrated cost =  5621.628457404731
# RUN  1000 , total integrated cost =  5621.596583588907
# RUN  1000 , total integrated cost =  5621.596583588907
# Improved over  1000  iterations in  48.25833386555314  seconds by  0.005661166775922766  percent.
# 1.485796210047401e-06 [1.52116163e+07 5.60429540e+03]
# go back to ----- 3800
# ----- 3800
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  5621.596583588907
# RUN  0 , total integrated cost =  5621.596583588907
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5621.596293249331
# RUN  2 , total integrated cost =  5621.59599438309
# RUN  3 , total integrated cost =  5621.595657868294
# RUN  4 , total integrated cost =  5621.595346338214
# RUN  5 , total integrated cost =  5621.595023335897
# RUN  6 , total integrated cost =  5621.594698322678
# RUN  7 , total integrated cost =  5621.594389707695
# RUN  8 , total integrated cost =  5621.594050338357
# RUN  9 , total integrated cost =  5621.593753259813
# RUN  10 , total integrated cost =  5621.593461191458
# RUN  11 , total integrated cost =  5621.593115723585
# RUN  12 , total integrated cost =  5621.592754138155
# RUN  13 , total integrated cost =  5621.592474767405
# RUN  14 , total integrated cost =  5621.592164835964
# RUN  15 , total integrated cost =  5621.591840118824
# RUN  16 , total integrated cost =  5621.591516816354
# RUN  17 , total integrated cost =  5621.591206366023
# RUN  18 , total integrated cost =  5621.590868827722
# RUN  19 , total integrated cost =  5621.590570282505
# RUN  20 , total integrated cost =  5621.590279693401
# RUN  30 , total integrated cost =  5621.5870981942335
# RUN  40 , total integrated cost =  5621.583916694216
# RUN  50 , total integrated cost =  5621.580735193534
# RUN  60 , total integrated cost =  5621.577553692334
# RUN  70 , total integrated cost =  5621.57437219071
# RUN  80 , total integrated cost =  5621.571190688759
# RUN  90 , total integrated cost =  5621.567950238885
# RUN  100 , total integrated cost =  5621.56476872073
# RUN  110 , total integrated cost =  5621.561587201319
# RUN  120 , total integrated cost =  5621.558405680987
# RUN  130 , total integrated cost =  5621.555224159962
# RUN  140 , total integrated cost =  5621.552042638426
# RUN  150 , total integrated cost =  5621.548861116519
# RUN  160 , total integrated cost =  5621.545679594351
# RUN  170 , total integrated cost =  5621.542498074795
# RUN  180 , total integrated cost =  5621.539316554089
# RUN  190 , total integrated cost =  5621.536135032562
# RUN  200 , total integrated cost =  5621.532953510457
# RUN  300 , total integrated cost =  5621.501079502869
# RUN  400 , total integrated cost =  5621.469264334711
# RUN  500 , total integrated cost =  5621.437448870999
# RUN  600 , total integrated cost =  5621.40557369072
# RUN  700 , total integrated cost =  5621.373699286891
# RUN  800 , total integrated cost =  5621.341823949322
# RUN  900 , total integrated cost =  5621.309978532917
# RUN  1000 , total integrated cost =  5621.278132759778
# RUN  1000 , total integrated cost =  5621.278132759778
# Improved over  1000  iterations in  48.279574401676655  seconds by  0.005664775556098789  percent.
# 1.2990463597650991e-06 [1.52098599e+07 5.60429540e+03]
# go back to ----- 3800
# ----- 3800
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  5621.278132759778
# RUN  0 , total integrated cost =  5621.278132759778
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5621.2778150310405
# RUN  2 , total integrated cost =  5621.277484736358
# RUN  3 , total integrated cost =  5621.2771799742295
# RUN  4 , total integrated cost =  5621.276895640908
# RUN  5 , total integrated cost =  5621.276538931413
# RUN  6 , total integrated cost =  5621.276188461572
# RUN  7 , total integrated cost =  5621.2758997379615
# RUN  8 , total integrated cost =  5621.275599223981
# RUN  9 , total integrated cost =  5621.275263943354
# RUN  10 , total integrated cost =  5621.274951163897
# RUN  11 , total integrated cost =  5621.27462893607
# RUN  12 , total integrated cost =  5621.274303130971
# RUN  13 , total integrated cost =  5621.2739947653545
# RUN  14 , total integrated cost =  5621.273655126879
# RUN  15 , total integrated cost =  5621.273357787367
# RUN  16 , total integrated cost =  5621.273065965456
# RUN  17 , total integrated cost =  5621.272719516084
# RUN  18 , total integrated cost =  5621.272358881407
# RUN  19 , total integrated cost =  5621.272078232383
# RUN  20 , total integrated cost =  5621.271769572025
# RUN  30 , total integrated cost =  5621.26858798086
# RUN  40 , total integrated cost =  5621.265406390842
# RUN  50 , total integrated cost =  5621.262166044095
# RUN  60 , total integrated cost =  5621.258984413428
# RUN  70 , total integrated cost =  5621.2558027843015
# RUN  80 , total integrated cost =  5621.252680285339
# RUN  90 , total integrated cost =  5621.249498701269
# RUN  100 , total integrated cost =  5621.246317118325
# RUN  110 , total integrated cost =  5621.243076585894
# RUN  120 , total integrated cost =  5621.239894964818
# RUN  130 , total integrated cost =  5621.236713345246
# RUN  140 , total integrated cost =  5621.233531727588
# RUN  150 , total integrated cost =  5621.230350114538
# RUN  160 , total integrated cost =  5621.227168502916
# RUN  170 , total integrated cost =  5621.223927950037
# RUN  180 , total integrated cost =  5621.220775455972
# RUN  190 , total integrated cost =  5621.217593838276
# RUN  200 , total integrated cost =  5621.214412222156
# RUN  300 , total integrated cost =  5621.182507398992
# RUN  400 , total integrated cost =  5621.150691303843
# RUN  500 , total integrated cost =  5621.118785410844
# RUN  600 , total integrated cost =  5621.086850453666
# RUN  700 , total integrated cost =  5621.05497529759
# RUN  800 , total integrated cost =  5621.023158750272
# RUN  900 , total integrated cost =  5620.991282637532
# RUN  1000 , total integrated cost =  5620.95919656681
# RUN  1000 , total integrated cost =  5620.95919656681
# Improved over  1000  iterations in  48.077170110307634  seconds by  0.005673730874647731  percent.
# 1.6012688808970166e-06 [1.52081009e+07 5.60429540e+03]
# go back to ----- 3800
# ----- 3800
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  5620.95919656681
# RUN  0 , total integrated cost =  5620.95919656681
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5620.958919649934
# RUN  2 , total integrated cost =  5620.958636597525
# RUN  3 , total integrated cost =  5620.958277454801
# RUN  4 , total integrated cost =  5620.957929373399
# RUN  5 , total integrated cost =  5620.957638214619
# RUN  6 , total integrated cost =  5620.957340138184
# RUN  7 , total integrated cost =  5620.9570015405425
# RUN  8 , total integrated cost =  5620.95663310356
# RUN  9 , total integrated cost =  5620.956356253108
# RUN  10 , total integrated cost =  5620.956073133015
# RUN  11 , total integrated cost =  5620.955714077431
# RUN  12 , total integrated cost =  5620.95536590951
# RUN  13 , total integrated cost =  5620.955074815031
# RUN  14 , total integrated cost =  5620.9547766735695
# RUN  15 , total integrated cost =  5620.954438159023
# RUN  16 , total integrated cost =  5620.954069639523
# RUN  17 , total integrated cost =  5620.953792840631
# RUN  18 , total integrated cost =  5620.953509667976
# RUN  19 , total integrated cost =  5620.953150678937
# RUN  20 , total integrated cost =  5620.952802444903
# RUN  30 , total integrated cost =  5620.949649742612
# RUN  40 , total integrated cost =  5620.946379242736
# RUN  50 , total integrated cost =  5620.943255802492
# RUN  60 , total integrated cost =  5620.9399851111475
# RUN  70 , total integrated cost =  5620.936832405275
# RUN  80 , total integrated cost =  5620.93356189947
# RUN  90 , total integrated cost =  5620.93043845893
# RUN  100 , total integrated cost =  5620.92716775988

# %%
bestControl_maxW = np.array( [[None] * len(t_pen)] * len(exc) )
bestState_maxW = np.array( [[None] * len(t_pen)] * len(exc) )
cost_maxW = np.array( [[None] * len(t_pen)] * len(exc) )
costnode_maxW = np.array( [[None] * len(t_pen)] * len(exc) )
weights_maxW = np.array( [[None] * len(t_pen)] * len(exc) )
convergence_maxW = np.array( [[None] * len(t_pen)] * len(exc) )

file_maxW = 'down_Wmax.pickle'

# %%
if os.path.isfile(file_maxW) :
    print("file found")
    
    with open(file_maxW,'rb') as f:
        load_array = pickle.load(f)

    bestControl_maxW = load_array[0]
    bestState_maxW = load_array[1]
    cost_maxW = load_array[2]
    costnode_maxW = load_array[3]
    weights_maxW = load_array[4]

# %%
for i in i_range:
    print('------------', i)
    j = 0

    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.

    aln.params.duration = dur

    while not convergence_maxW[i][j]:
        dur = d_array[j]
        aln.params.duration = dur

        setinit(initVars[i], aln)

        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        control0 = aln.getZeroControl()
        if type(bestControl_maxW[i][j]) == type(None):
            max_it = 10
            control0 = bestControl_[i][0][:,:,n_pre-1:-n_post+1]
            weight_ = ( cost_uncontrolled[i] * (1. - t_pen[0]) / (1. - t_pen[j]) 
                       - sum(costnode_[i][j][0][0][:]) ) / sum( costnode_[i][j][index_cost][0][:] )
            cost.setParams(1., weight_ * factor_we, weight_ * factor_ws)
            weights_maxW[i][j] = cost.getParams()
        else:
            control0 = bestControl_maxW[i][j][:,:,n_pre-1:-n_post+1]
            weight_ = ( cost_uncontrolled[i] * (1. - t_pen[0]) / (1. - t_pen[j])
                       - sum(costnode_maxW[i][j][0][0][:]) ) / sum( costnode_maxW[i][j][index_cost][0][:] )
            cost.setParams(1., weight_ * factor_we, weight_ * factor_ws)
            weights_maxW[i][j] = cost.getParams()
            max_it = int(100)

        bestControl_maxW[i][j], bestState_maxW[i][j], cost_maxW[i][j], runtime_, grad_, phi_, phi1_, costnode_maxW[i][j] = aln.A1(
            control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
            prec_variables_ = p_var, transition_time_ = t_pen[j])

        if cost_maxW[i][j][2] == 0.:
            convergence_maxW[i][j] = True

        print('cost splitting : ', costnode_maxW[i][j][0][0][0], costnode_maxW[i][j][index_cost][0][:2])

        with open(file_maxW,'wb') as f:
            pickle.dump([bestControl_maxW, bestState_maxW, cost_maxW, costnode_maxW, weights_maxW], f)

# %%
for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    j = 0
    step = step1

    while j < 4800:

        if j == 0:
            j += step
            continue
            
        if not convergence_maxW[i][j-step]:
            if j - step > 0:
                j -= step
                print('go back to -----', j)

        print('-----', j)

        if convergence_maxW[i][j]:
            j += step
            continue

        dur = d_array[j]
        T = 5001 - j
        aln.params.duration = dur
        setinit(initVars[i], aln)

        max_it = 1000

        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        if type(bestControl_maxW[i][j]) == type(None):
            max_percent_prev = (np.argmax(np.abs(bestControl_maxW[i][j-step]), axis=2)[0,1] - 100) / (T-200)
            shift_ind = 0
            if j < 4000:
                while max_percent_prev > max_percent[i]:
                    shift_ind += 1
                    max_percent_prev = (np.argmax(np.abs(bestControl_maxW[i][j-step]), axis=2)[0,1] - 100 - shift_ind) / (T-200)

            control0 = np.zeros(( bestControl_maxW[i][j-step][:,:,100:-(100+step)].shape ))
            print('shift ind = ', shift_ind)
            if shift_ind != 0:
                control0[:,:,:-shift_ind] = 1. * bestControl_maxW[i][j-step][:,:,100+shift_ind:-(100+step)]
            else:
                control0[:,:,:] = 1. * bestControl_maxW[i][j-step][:,:,100:-(100+step)]
                
            weight_ = ( cost_uncontrolled[i] * (1. - t_pen[0]) / (1. - t_pen[j])
                          - sum(costnode_maxW[i][j-step][0][0][:]) ) / sum( costnode_maxW[i][j-step][cost_index][0][:] )
            cost.setParams(1., weight_ * factor_we, weight_ * factor_ws)
            weights_maxW[i][j] = cost.getParams()
        
        else:
            if bestControl_maxW[i][j].shape[2] == T+200:
                control0 = bestControl_maxW[i][j][:,:,100:-100]
                #control0[0,1,:] = 0.
            else:
                control0 = bestControl_maxW[i][j][:,:,100:-(100+j)]
                
                weight_ = ( cost_uncontrolled[i] * (1. - t_pen[0]) / (1. - t_pen[j])
                           - sum(costnode_maxW[i][j][0][0][:]) ) / sum( costnode_maxW[i][j][2][0][:] )
                cost.setParams(1., weight_ * factor_we, weight_ * factor_ws)
                weights_maxW[i][j] = cost.getParams()

        bestControl_maxW[i][j], bestState_maxW[i][j], cost_maxW[i][j], runtime_, grad_, phi_, phi1_, costnode_maxW[i][j] = aln.A1(
            control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
            prec_variables_ = p_var, transition_time_ = t_pen[j])

        print(costnode_maxW[i][j][0][0][:2], costnode_maxW[i][j][cost_index][0][:2])

        if cost_maxW[i][j][2] == 0.:
            convergence_maxW[i][j] = True
            if j >= 4400:
                step = step2
            if j >=4790:
                step = step3

        with open(file_maxW,'wb') as f:
            pickle.dump([bestControl_maxW, bestState_maxW, cost_maxW, costnode_maxW, weights_maxW], f)

        j += step
