# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import sys
import pickle

path = os.getcwd().split(os.sep + 'GUI')[0]
if path not in sys.path:
    print("not here")
    sys.path.append(path)

from neurolib.models.aln import ALNModel
from neurolib.utils import plotFunctions as plotFunc
from neurolib.utils import costFunctions as cost
import neurolib.dashboard.functions as functions
import neurolib.dashboard.data as data
    
# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2 

#path = os.path.join(os.getcwd(), "plots")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
grid_data_file = os.path.join(os.getcwd().split('data')[0], 'bi.pickle')
with open(grid_data_file,'rb') as f:
    load_array= pickle.load(f)
exc = [load_array[0][20], load_array[0][50]]
inh = [load_array[1][20], load_array[1][50]]

folder = str(os.getcwd().split('data_2')[1])
print(folder)
case = str(folder[1])

file_ = 'up.pickle'

c_var = [0,1]
if len(folder) == 4:
    if folder[3] == 'e':
        p_var = [0]
    elif folder[3] == 'i':
        p_var = [1]
else:
    p_var = [0,1]
    
print(p_var)

step1 = 1
step2 = 10
step3 = 100
# Out:
# /1_ei
# [0, 1]

# %%
aln = ALNModel()
N = aln.params.N

data.set_parameters(aln)

state_vars = aln.state_vars
init_vars = aln.init_vars

##############################################################
def setinit(init_vars_, model):
    state_vars = model.state_vars
    init_vars = model.init_vars
    for iv in range(len(init_vars)):
        for sv in range(len(state_vars)):
            if state_vars[sv] in init_vars[iv]:
                #print("set init vars ", )
                if model.params[init_vars[iv]].ndim == 2:
                    model.params[init_vars[iv]][0,:] = init_vars_[sv]
                else:
                    model.params[init_vars[iv]][0] = init_vars_[sv]
                    
##############################################################               
def setmaxmincontrol(max_c_c, min_c_c, max_c_r, min_c_r):
    import numpy as np
    
    max_cntrl = np.zeros(( 6 ))
    min_cntrl = np.zeros(( 6 ))
    
    max_cntrl[0] = max_c_c
    min_cntrl[0] = min_c_c
    max_cntrl[1] = max_c_c
    min_cntrl[1] = min_c_c
    max_cntrl[2] = max_c_r
    min_cntrl[2] = min_c_r
    max_cntrl[3] = max_c_r
    min_cntrl[3] = min_c_r
    max_cntrl[4] = max_c_r
    min_cntrl[4] = min_c_r
    max_cntrl[5] = max_c_r
    min_cntrl[5] = min_c_r
            
    return max_cntrl, min_cntrl

# %%
d_array = np.arange(20., 300, 0.1)
t0_array = d_array - 20.
t_pen = np.zeros(( t0_array.shape ))
for i in range(len(t_pen)):
    t_pen[i] = t0_array[i] / d_array[i]

# %%
dur_pre = 10
dur_post = 10

n_pre = int(np.around(dur_pre/aln.params.dt + 1.,1))
n_post = int(np.around(dur_post/aln.params.dt + 1.,1))

tol = 1e-12
start_step = 10.
c_scheme = np.zeros(( 1,1 ))
c_scheme[0,0] = 1.
u_mat = np.identity(1)
u_scheme = np.array([[1.]])

if case in ['1', '2']:    # low to high
    max_I = [3., -3.]
else:
    max_I = [-3., 3.]
    
if case in ['1', '3']:    # sparsity
    factor_ws = 1.
    factor_we = 0.
else:
    factor_ws = 0.
    factor_we = 1.
    
maxC = [1000., -1000., 0.18, 0.]
max_cntrl, min_cntrl = setmaxmincontrol(maxC[0], maxC[1], maxC[2], maxC[3])

# %%
bestControl_ = np.array( [[None] * len(t_pen)] * len(exc) )
bestState_ = np.array( [[None] * len(t_pen)] * len(exc) )
cost_ = np.array( [[None] * len(t_pen)] * len(exc) )
costnode_ = np.array( [[None] * len(t_pen)] * len(exc) )
weights_ = np.array( [[None] * len(t_pen)] * len(exc) )
convergence_ = np.array( [[None] * len(t_pen)] * len(exc) )

initVars = [None] * len(exc)
target = [None] * len(exc)
cost_uncontrolled = [None] * len(exc)

print(bestControl_.shape)
# Out:
# (2, 2800)

# %%
if os.path.isfile(file_) :
    print("file found")
    
    with open(file_,'rb') as f:
        load_array = pickle.load(f)

    bestControl_ = load_array[0]
    bestState_ = load_array[1]
    cost_ = load_array[2]
    costnode_ = load_array[3]
    weights_ = load_array[4]
# Out:
# file found

# %%
# get initial parameters and target states
# -------  20 0.4500000000000001 0.4750000000000002
#-------  50 0.47500000000000014 0.6000000000000003

i_range = range(len(exc))
data.set_parameters(aln)

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    aln.params.duration = 3000.
    
    control0 = aln.getZeroControl()
    control0 = functions.step_control(aln, maxI_ = max_I[0])

    aln.run(control=control0)
    
    target_rates = np.zeros((2))
    target_rates[0] = aln.rates_exc[0,-1] 
    target_rates[1] = aln.rates_inh[0,-1]

    control0 = functions.step_control(aln, maxI_ = max_I[1])
    aln.run(control=control0)

    init_state_vars = np.zeros(( len(state_vars) ))
    for j in range(len(state_vars)):
        if aln.state[state_vars[j]].size == 1:
            init_state_vars[j] = aln.state[state_vars[j]][0]
        else:
            init_state_vars[j] = aln.state[state_vars[j]][0,-1]

    initVars[i] = init_state_vars
    target[i] = [target_rates[0], target_rates[1]]
# Out:
# -------  0 0.4500000000000001 0.4750000000000002
# -------  1 0.47500000000000014 0.6000000000000003

# %%
# get uncontrolled cost

data.set_parameters(aln)

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    dur = d_array[0]
    aln.params.duration = dur
    
    target_ = aln.getZeroTarget()
    target_[:,0,:] = target[i][0]
    target_[:,1,:] = target[i][1]
            
    cost.setParams(1.0, 0.0, 0.0)

    setinit(initVars[i], aln)
    control0 = aln.getZeroControl()

    # "HS", "FR", "PR", "HZ"
    cgv = None
    max_it = 0

    bestControl_init_, bestState_init_, cost_init_, runtime_init_, grad_init_, phi_init_, phi1_, costnode_init_ = aln.A1(
        control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
        prec_variables_ = p_var, transition_time_ = t_pen[0])
    
    cost_uncontrolled[i] = cost_init_[0]
# Out:
# -------  0 0.4500000000000001 0.4750000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  59332.71056788095
# RUN  0 , total integrated cost =  59332.71056788095
# Gradient descend method:  None
# RUN  0 , total integrated cost =  59332.71056788095
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  1 0.47500000000000014 0.6000000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  59589.700102831725
# RUN  0 , total integrated cost =  59589.700102831725
# Gradient descend method:  None
# RUN  0 , total integrated cost =  59589.700102831725
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.

# %%
bestControl_[1][0] = None

# %%
for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.

    cgv = None
    j = 0
    max_it = 10000

    while not convergence_[i][j]:

        dur = d_array[0]
        aln.params.duration = dur
        cost.setParams(1.0, 0., 1.)
        weights_[i][j] = [1., 0., 1.]
        
        setinit(initVars[i], aln)

        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        if type(bestControl_[i][j]) == type(None) or np.amax(np.abs(bestControl_[i][j])) < 1e-6:
            control0 = aln.getZeroControl()
            if i == 1:
                control0[0,0,1:-1] = 2.
            
        else:
            control0 = bestControl_[i][j][:,:,n_pre-1:-n_post+1]

        bestControl_[i][j], bestState_[i][j], cost_[i][j], runtime_, grad_, phi_, phi1_, costnode_[i][j] = aln.A1(
            control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
            prec_variables_ = p_var, transition_time_ = t_pen[j])

        if max_it > 1:
            if cost_[i][j][2] == 0.:
                convergence_[i][j] = True
                continue

        print('cost splitting : ', costnode_[i][j][0][0][:2], costnode_[i][j][2][0][:2])

        with open(file_,'wb') as f:
            pickle.dump([bestControl_, bestState_, cost_, costnode_, weights_], f)
# Out:
# -------  0 0.4500000000000001 0.4750000000000002
# -------  1 0.47500000000000014 0.6000000000000003
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  48927.08626201098
# RUN  0 , total integrated cost =  48927.08626201098
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11848.645180789043
# RUN  2 , total integrated cost =  10382.281189083087
# RUN  3 , total integrated cost =  8956.334636192269
# RUN  4 , total integrated cost =  8153.01478799906
# RUN  5 , total integrated cost =  7347.693784510963
# RUN  6 , total integrated cost =  7021.408819846043
# RUN  7 , total integrated cost =  6618.655474789852
# RUN  8 , total integrated cost =  6379.403306265014
# RUN  9 , total integrated cost =  5994.5273411073795
# RUN  10 , total integrated cost =  5798.5521398352985
# RUN  11 , total integrated cost =  5702.52169331045
# RUN  12 , total integrated cost =  5606.908466320512
# RUN  13 , total integrated cost =  5518.230116156362
# RUN  14 , total integrated cost =  5420.125884606733
# RUN  15 , total integrated cost =  5327.885194774669
# RUN  16 , total integrated cost =  5250.504945114745
# RUN  17 , total integrated cost =  5179.490747867628
# RUN  18 , total integrated cost =  5101.64308974296
# RUN  19 , total integrated cost =  5035.470230521464
# RUN  20 , total integrated cost =  4971.084687459318
# RUN  30 , total integrated cost =  4320.935036660346
# RUN  40 , total integrated cost =  3726.7933109060873
# RUN  50 , total integrated cost =  3360.989550703316
# RUN  60 , total integrated cost =  3054.530246422436
# RUN  70 , total integrated cost =  2681.4161433724325
# RUN  80 , total integrated cost =  2497.4340763221526
# RUN  90 , total integrated cost =  2333.4495632824865
# RUN  100 , total integrated cost =  2191.6172523864043
# RUN  110 , total integrated cost =  2135.7425399957724
# RUN  120 , total integrated cost =  2086.588104173005
# RUN  130 , total integrated cost =  2042.0600391717057
# RUN  140 , total integrated cost =  2002.2749104215497
# RUN  150 , total integrated cost =  1964.1798888769063
# RUN  160 , total integrated cost =  1929.9282895141234
# RUN  170 , total integrated cost =  1897.7628556266452
# RUN  180 , total integrated cost =  1867.9195627370202
# RUN  190 , total integrated cost =  1840.5256465878417
# RUN  200 , total integrated cost =  1814.9170769436546
# RUN  300 , total integrated cost =  1620.6887951008935
# RUN  400 , total integrated cost =  1469.1158739801358
# RUN  500 , total integrated cost =  1368.61210504645
# RUN  600 , total integrated cost =  1297.243481967314
# RUN  700 , total integrated cost =  1255.2884264533009
# RUN  800 , total integrated cost =  1220.6167219685417

# %%
for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    j = 0
    step = step1

    while j < 2001:
        
        if convergence_[i][j]:
            j += step
            continue

        print('-----', j)

        dur = round(d_array[j],1)
        aln.params.duration = dur
        max_it = int(10000)  

        setinit(initVars[i], aln)
        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        if type(bestControl_[i][j]) == type(None):
            control0 = aln.getZeroControl()
            control0[:,:,:-step] = bestControl_[i][j-step][:,:,n_pre-1:-n_post+1]

        else:
            control0 = bestControl_[i][j][:,:,n_pre-1:-n_post+1]
            
        weights_[i][j] = cost.getParams()

        bestControl_[i][j], bestState_[i][j], cost_[i][j], runtime_, grad_, phi_, phi1_, costnode_[i][j] = aln.A1(
            control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
            prec_variables_ = p_var, transition_time_ = t_pen[j])

        if cost_[i][j][-1] == 0.:
            convergence_[i][j] = True
            if j >= 10:
                step = step2
            if j >=1000:
                step = step3

        print('cost splitting : ', costnode_[i][j][0][0][:2], costnode_[i][j][2][0][:2])

        with open(file_,'wb') as f:
            pickle.dump([bestControl_, bestState_, cost_, costnode_, weights_], f)
# Out:
# -------  0 0.4500000000000001 0.4750000000000002
# ----- 1
# interpolate adjoint :  True True True
# initial cost =  110.356643579998
# RUN  0 , total integrated cost =  110.356643579998
# Gradient descend method:  None
# RUN  1 , total integrated cost =  110.356643579998
# Control only changes marginally.
# RUN  1 , total integrated cost =  110.356643579998
# Improved over  1  iterations in  0.043268890120089054  seconds by  0.0  percent.
# cost splitting :  [14.14625377  0.44793334] [77.55868302 18.13116556]
# ----- 2
# interpolate adjoint :  True True True
# initial cost =  64.37405381491025
# RUN  0 , total integrated cost =  64.37405381491025
# Gradient descend method:  None
# RUN  1 , total integrated cost =  64.37405381491025
# Control only changes marginally.
# RUN  1 , total integrated cost =  64.37405381491025
# Improved over  1  iterations in  0.04217633977532387  seconds by  0.0  percent.
# cost splitting :  [1.32704435 0.02850953] [53.90767737  9.09733446]
# ----- 3
# interpolate adjoint :  True True True
# initial cost =  48.122565226769446
# RUN  0 , total integrated cost =  48.122565226769446
# Gradient descend method:  None
# RUN  1 , total integrated cost =  48.122565226769446
# Control only changes marginally.
# RUN  1 , total integrated cost =  48.122565226769446
# Improved over  1  iterations in  0.05093708448112011  seconds by  0.0  percent.
# cost splitting :  [0.43725851 0.00815783] [40.43756294  7.23293794]
# ----- 4
# interpolate adjoint :  True True True
# initial cost =  39.9148907683608
# RUN  0 , total integrated cost =  39.9148907683608
# Gradient descend method:  None
# RUN  1 , total integrated cost =  39.9148907683608
# Control only changes marginally.
# RUN  1 , total integrated cost =  39.9148907683608
# Improved over  1  iterations in  0.054444149136543274  seconds by  0.0  percent.
# cost splitting :  [0.20901747 0.00474963] [33.21421971  6.48264987]
# ----- 5
# interpolate adjoint :  True True True
# initial cost =  34.94196331835916
# RUN  0 , total integrated cost =  34.94196331835916
# Gradient descend method:  None
# RUN  1 , total integrated cost =  34.94196331835916
# Control only changes marginally.
# RUN  1 , total integrated cost =  34.94196331835916
# Improved over  1  iterations in  0.054381257854402065  seconds by  0.0  percent.
# cost splitting :  [0.11322631 0.00268796] [28.73272306  6.09044255]
# ----- 6
# interpolate adjoint :  True True True
# initial cost =  31.571505951064402
# RUN  0 , total integrated cost =  31.571505951064402
# Gradient descend method:  None
# RUN  1 , total integrated cost =  31.571505951064402
# Control only changes marginally.
# RUN  1 , total integrated cost =  31.571505951064402
# Improved over  1  iterations in  0.11654287297278643  seconds by  0.0  percent.
# cost splitting :  [0.07212468 0.00182885] [25.64662512  5.84871972]
# ----- 7
# interpolate adjoint :  True True True
# initial cost =  29.11577965404765
# RUN  0 , total integrated cost =  29.11577965404765
# Gradient descend method:  None
# RUN  1 , total integrated cost =  29.11577965404765
# Control only changes marginally.
# RUN  1 , total integrated cost =  29.11577965404765
# Improved over  1  iterations in  0.08939867652952671  seconds by  0.0  percent.
# cost splitting :  [0.04958952 0.00134406] [23.37518599  5.68788627]
# ----- 8
# interpolate adjoint :  True True True
# initial cost =  27.237645599308472
# RUN  0 , total integrated cost =  27.237645599308472
# Gradient descend method:  None
# RUN  1 , total integrated cost =  27.237645599308472
# Control only changes marginally.
# RUN  1 , total integrated cost =  27.237645599308472
# Improved over  1  iterations in  0.05826149042695761  seconds by  0.0  percent.
# cost splitting :  [0.0394831  0.00133781] [21.62539964  5.56980033]
# ----- 9
# interpolate adjoint :  True True True
# initial cost =  25.75291654177141
# RUN  0 , total integrated cost =  25.75291654177141
# Gradient descend method:  None
# RUN  1 , total integrated cost =  25.75291654177141
# Control only changes marginally.
# RUN  1 , total integrated cost =  25.75291654177141
# Improved over  1  iterations in  0.05565171130001545  seconds by  0.0  percent.
# cost splitting :  [0.02890029 0.0010777 ] [20.23360368  5.48799257]
# ----- 10
# interpolate adjoint :  True True True
# initial cost =  24.536590191768543
# RUN  0 , total integrated cost =  24.536590191768543
# Gradient descend method:  None
# RUN  1 , total integrated cost =  24.536590191768543
# Control only changes marginally.
# RUN  1 , total integrated cost =  24.536590191768543
# Improved over  1  iterations in  0.05406053923070431  seconds by  0.0  percent.
# cost splitting :  [0.0228466 0.0010236] [19.09316684  5.41836558]
# ----- 20
# interpolate adjoint :  True True True
# initial cost =  18.610659060103636
# RUN  0 , total integrated cost =  18.610659060103636
# Gradient descend method:  None
# RUN  1 , total integrated cost =  18.610659060103636
# Control only changes marginally.
# RUN  1 , total integrated cost =  18.610659060103636
# Improved over  1  iterations in  0.06512153428047895  seconds by  0.0  percent.
# cost splitting :  [0.00545936 0.00078799] [13.48518408  5.118606  ]
# ----- 30
# interpolate adjoint :  True True True
# initial cost =  16.271615264289135
# RUN  0 , total integrated cost =  16.271615264289135
# Gradient descend method:  None
# RUN  1 , total integrated cost =  16.271615264289135
# Control only changes marginally.
# RUN  1 , total integrated cost =  16.271615264289135
# Improved over  1  iterations in  0.08259489294141531  seconds by  0.0  percent.
# cost splitting :  [0.00202529 0.00071523] [11.30590555  4.96256016]
# ----- 40
# interpolate adjoint :  True True True
# initial cost =  14.849229007967455
# RUN  0 , total integrated cost =  14.849229007967455
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14.849229007967455
# Control only changes marginally.
# RUN  1 , total integrated cost =  14.849229007967455
# Improved over  1  iterations in  0.059854354709386826  seconds by  0.0  percent.
# cost splitting :  [0.00102729 0.00066774] [10.02395916  4.8232375 ]
# ----- 50
# interpolate adjoint :  True True True
# initial cost =  13.734748114506257
# RUN  0 , total integrated cost =  13.734748114506257
# Gradient descend method:  None
# RUN  1 , total integrated cost =  13.734748114506257
# Control only changes marginally.
# RUN  1 , total integrated cost =  13.734748114506257
# Improved over  1  iterations in  0.05957407131791115  seconds by  0.0  percent.
# cost splitting :  [0.00058586 0.00060703] [9.05288569 4.6803728 ]
# ----- 60
# interpolate adjoint :  True True True
# initial cost =  12.731373288974687
# RUN  0 , total integrated cost =  12.731373288974687
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12.731373288974687
# Control only changes marginally.
# RUN  1 , total integrated cost =  12.731373288974687
# Improved over  1  iterations in  0.05902777053415775  seconds by  0.0  percent.
# cost splitting :  [0.00033207 0.00058123] [8.21627845 4.51390891]
# ----- 70
# interpolate adjoint :  True True True
# initial cost =  11.787657936146855
# RUN  0 , total integrated cost =  11.787657936146855
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.787657936146855
# Control only changes marginally.
# RUN  1 , total integrated cost =  11.787657936146855
# Improved over  1  iterations in  0.06326233129948378  seconds by  0.0  percent.
# cost splitting :  [0.00022113 0.00052485] [7.48165097 4.30500119]
# ----- 80
# interpolate adjoint :  True True True
# initial cost =  10.908755788064047
# RUN  0 , total integrated cost =  10.908755788064047
# Gradient descend method:  None
# RUN  1 , total integrated cost =  10.908755788064047
# Control only changes marginally.
# RUN  1 , total integrated cost =  10.908755788064047
# Improved over  1  iterations in  0.06720123998820782  seconds by  0.0  percent.
# cost splitting :  [0.00014137 0.00049965] [6.92579108 3.98206857]
# ----- 90
# interpolate adjoint :  True True True
# initial cost =  10.098183018822677
# RUN  0 , total integrated cost =  10.098183018822677
# Gradient descend method:  None
# RUN  1 , total integrated cost =  10.098183018822677
# Control only changes marginally.
# RUN  1 , total integrated cost =  10.098183018822677
# Improved over  1  iterations in  0.06215899530798197  seconds by  0.0  percent.
# cost splitting :  [0.00011217 0.00040995] [6.57416422 3.52326288]
# ----- 100
# interpolate adjoint :  True True True
# initial cost =  9.025160161109968
# RUN  0 , total integrated cost =  9.025160161109968
# Gradient descend method:  None
# RUN  1 , total integrated cost =  9.025160161109968
# Control only changes marginally.
# RUN  1 , total integrated cost =  9.025160161109968
# Improved over  1  iterations in  0.07600863557308912  seconds by  0.0  percent.
# cost splitting :  [4.45393521e-05 9.14050499e-04] [8.0164736  1.00725106]
# ----- 110
# interpolate adjoint :  True True True
# initial cost =  8.333120785129061
# RUN  0 , total integrated cost =  8.333120785129061
# Gradient descend method:  None
# RUN  1 , total integrated cost =  8.333120785129061
# Control only changes marginally.
# RUN  1 , total integrated cost =  8.333120785129061
# Improved over  1  iterations in  0.06766147166490555  seconds by  0.0  percent.
# cost splitting :  [2.01102237e-05 8.25461301e-04] [7.70025414 0.63155832]
# ----- 120
# interpolate adjoint :  True True True
# initial cost =  7.815774956993469
# RUN  0 , total integrated cost =  7.815774956993469
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.815774956993469
# Control only changes marginally.
# RUN  1 , total integrated cost =  7.815774956993469
# Improved over  1  iterations in  0.07727822102606297  seconds by  0.0  percent.
# cost splitting :  [1.63582789e-05 7.56704830e-04] [7.2146753  0.59986507]
# ----- 130
# interpolate adjoint :  True True True
# initial cost =  7.403543239693909
# RUN  0 , total integrated cost =  7.403543239693909
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.403543239693909
# Control only changes marginally.
# RUN  1 , total integrated cost =  7.403543239693909
# Improved over  1  iterations in  0.0751398429274559  seconds by  0.0  percent.
# cost splitting :  [1.58893852e-05 4.69018715e-04] [6.72787362 0.67487109]
# ----- 140
# interpolate adjoint :  True True True
# initial cost =  7.062493899039516
# RUN  0 , total integrated cost =  7.062493899039516
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.062493899039516
# Control only changes marginally.
# RUN  1 , total integrated cost =  7.062493899039516
# Improved over  1  iterations in  0.06930331885814667  seconds by  0.0  percent.
# cost splitting :  [2.49266571e-05 3.48218390e-04] [6.15336259 0.90849826]
# ----- 150
# interpolate adjoint :  True True True
# initial cost =  6.62995744580741
# RUN  0 , total integrated cost =  6.62995744580741
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.62995744580741
# Control only changes marginally.
# RUN  1 , total integrated cost =  6.62995744580741
# Improved over  1  iterations in  0.06781056616455317  seconds by  0.0  percent.
# cost splitting :  [9.39587455e-05 1.13726837e-04] [3.9751996  2.65439517]
# ----- 160
# interpolate adjoint :  True True True
# initial cost =  6.265605317905457
# RUN  0 , total integrated cost =  6.265605317905457
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.265605317905457
# Control only changes marginally.
# RUN  1 , total integrated cost =  6.265605317905457
# Improved over  1  iterations in  0.06684958003461361  seconds by  0.0  percent.
# cost splitting :  [1.19976768e-04 9.46608729e-05] [3.07849927 3.18672055]
# ----- 170
# interpolate adjoint :  True True True
# initial cost =  5.941396732803659
# RUN  0 , total integrated cost =  5.941396732803659
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.941396732803659
# Control only changes marginally.
# RUN  1 , total integrated cost =  5.941396732803659
# Improved over  1  iterations in  0.06415752321481705  seconds by  0.0  percent.
# cost splitting :  [1.31322930e-04 6.63672842e-05] [2.54696864 3.3940632 ]
# ----- 180
# interpolate adjoint :  True True True
# initial cost =  5.646090511436991
# RUN  0 , total integrated cost =  5.646090511436991
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.646090511436991
# Control only changes marginally.
# RUN  1 , total integrated cost =  5.646090511436991
# Improved over  1  iterations in  0.06303682923316956  seconds by  0.0  percent.
# cost splitting :  [1.59419822e-04 5.13234802e-05] [1.87631998 3.76937106]
# ----- 190
# interpolate adjoint :  True True True
# initial cost =  5.382178963328854
# RUN  0 , total integrated cost =  5.382178963328854
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.382178963328854
# Control only changes marginally.
# RUN  1 , total integrated cost =  5.382178963328854
# Improved over  1  iterations in  0.06445403583347797  seconds by  0.0  percent.
# cost splitting :  [2.00410031e-04 4.06683502e-05] [1.30897663 4.07273337]
# ----- 200
# interpolate adjoint :  True True True
# initial cost =  5.148372704041608
# RUN  0 , total integrated cost =  5.148372704041608
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.148372704041608
# Control only changes marginally.
# RUN  1 , total integrated cost =  5.148372704041608
# Improved over  1  iterations in  0.06297915708273649  seconds by  0.0  percent.
# cost splitting :  [2.40895526e-04 3.11993093e-05] [0.87627752 4.27155235]
# ----- 210
# interpolate adjoint :  True True True
# initial cost =  4.945549950376011
# RUN  0 , total integrated cost =  4.945549950376011
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.945549950376011
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.945549950376011
# Improved over  1  iterations in  0.06227085832506418  seconds by  0.0  percent.
# cost splitting :  [2.94101950e-04 2.68421338e-05] [0.52131386 4.42357983]
# ----- 220
# interpolate adjoint :  True True True
# initial cost =  4.777781274347183
# RUN  0 , total integrated cost =  4.777781274347183
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.777781274347183
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.777781274347183
# Improved over  1  iterations in  0.06622643396258354  seconds by  0.0  percent.
# cost splitting :  [2.63280194e-04 1.98622709e-05] [0.36028212 4.41690611]
# ----- 230
# interpolate adjoint :  True True True
# initial cost =  4.640695922364675
# RUN  0 , total integrated cost =  4.640695922364675
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.640695922364675
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.640695922364675
# Improved over  1  iterations in  0.06327488459646702  seconds by  0.0  percent.
# cost splitting :  [2.27067996e-04 1.52888092e-05] [0.20824795 4.43192829]
# ----- 240
# interpolate adjoint :  True True True
# initial cost =  4.5328364635568885
# RUN  0 , total integrated cost =  4.5328364635568885
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.5328364635568885
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.5328364635568885
# Improved over  1  iterations in  0.06660192273557186  seconds by  0.0  percent.
# cost splitting :  [1.58765536e-04 1.33239597e-05] [0.13953033 4.39292856]
# ----- 250
# interpolate adjoint :  True True True
# initial cost =  4.447534033943053
# RUN  0 , total integrated cost =  4.447534033943053
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.447534033943053
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.447534033943053
# Improved over  1  iterations in  0.0890905074775219  seconds by  0.0  percent.
# cost splitting :  [1.00968736e-04 1.05827145e-05] [0.10002106 4.34726268]
# ----- 260
# interpolate adjoint :  True True True
# initial cost =  4.380151341661283
# RUN  0 , total integrated cost =  4.380151341661283
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.380151341661283
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.380151341661283
# Improved over  1  iterations in  0.07036894373595715  seconds by  0.0  percent.
# cost splitting :  [7.21718509e-05 8.00510159e-06] [0.06662042 4.31334703]
# ----- 270
# interpolate adjoint :  True True True
# initial cost =  4.326420361051024
# RUN  0 , total integrated cost =  4.326420361051024
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.326420361051024
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.326420361051024
# Improved over  1  iterations in  0.06877432204782963  seconds by  0.0  percent.
# cost splitting :  [7.33929808e-05 5.98783334e-06] [0.03942339 4.28681096]
# ----- 280
# interpolate adjoint :  True True True
# initial cost =  4.284146909988343
# RUN  0 , total integrated cost =  4.284146909988343
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.284146909988343
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.284146909988343
# Improved over  1  iterations in  0.07371751219034195  seconds by  0.0  percent.
# cost splitting :  [9.55856871e-05 4.57056542e-06] [0.02296008 4.26094716]
# ----- 290
# interpolate adjoint :  True True True
# initial cost =  4.250658925352011
# RUN  0 , total integrated cost =  4.250658925352011
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.250658925352011
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.250658925352011
# Improved over  1  iterations in  0.06624543014913797  seconds by  0.0  percent.
# cost splitting :  [1.21080894e-04 4.27107834e-06] [0.01376101 4.2365917 ]
# ----- 300
# interpolate adjoint :  True True True
# initial cost =  4.224207006916414
# RUN  0 , total integrated cost =  4.224207006916414
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.224207006916414
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.224207006916414
# Improved over  1  iterations in  0.08728576637804508  seconds by  0.0  percent.
# cost splitting :  [1.41064433e-04 2.57589813e-06] [0.00792164 4.21592734]
# ----- 310
# interpolate adjoint :  True True True
# initial cost =  4.203038814115892
# RUN  0 , total integrated cost =  4.203038814115892
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.203038814115892
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.203038814115892
# Improved over  1  iterations in  0.0662360405549407  seconds by  0.0  percent.
# cost splitting :  [1.47570610e-04 2.18096529e-06] [0.00555651 4.19710159]
# ----- 320
# interpolate adjoint :  True True True
# initial cost =  4.186198199463527
# RUN  0 , total integrated cost =  4.186198199463527
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.186198199463527
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.186198199463527
# Improved over  1  iterations in  0.06918903905898333  seconds by  0.0  percent.
# cost splitting :  [1.40821980e-04 1.53434134e-06] [3.68469878e-03 4.18214451e+00]
# ----- 330
# interpolate adjoint :  True True True
# initial cost =  4.172449031726635
# RUN  0 , total integrated cost =  4.172449031726635
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.172449031726635
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.172449031726635
# Improved over  1  iterations in  0.06846862938255072  seconds by  0.0  percent.
# cost splitting :  [1.3393639e-04 1.2761421e-06] [3.06383073e-03 4.16902800e+00]
# ----- 340
# interpolate adjoint :  True True True
# initial cost =  4.136110055199308
# RUN  0 , total integrated cost =  4.136110055199308
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.136110055199308
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.136110055199308
# Improved over  1  iterations in  0.06750144343823195  seconds by  0.0  percent.
# cost splitting :  [1.84153227e-04 3.30432959e-07] [0.26539833 3.87021518]
# ----- 350
# interpolate adjoint :  True True True
# initial cost =  4.1067336981768205
# RUN  0 , total integrated cost =  4.1067336981768205
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.1067336981768205
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.1067336981768205
# Improved over  1  iterations in  0.06875653844326735  seconds by  0.0  percent.
# cost splitting :  [1.81635967e-04 3.55611351e-07] [0.31060852 3.79562628]
# ----- 360
# interpolate adjoint :  True True True
# initial cost =  4.075424135202979
# RUN  0 , total integrated cost =  4.075424135202979
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.075424135202979
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.075424135202979
# Improved over  1  iterations in  0.06713483482599258  seconds by  0.0  percent.
# cost splitting :  [1.78228408e-04 3.37075186e-07] [0.31565826 3.75926749]
# ----- 370
# interpolate adjoint :  True True True
# initial cost =  4.044332155338689
# RUN  0 , total integrated cost =  4.044332155338689
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.044332155338689
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.044332155338689
# Improved over  1  iterations in  0.07117700297385454  seconds by  0.0  percent.
# cost splitting :  [1.69315710e-04 3.11211311e-07] [0.31157277 3.73227751]
# ----- 380
# interpolate adjoint :  True True True
# initial cost =  4.014439615747166
# RUN  0 , total integrated cost =  4.014439615747166
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.014439615747166
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.014439615747166
# Improved over  1  iterations in  0.07061685808002949  seconds by  0.0  percent.
# cost splitting :  [1.59411961e-04 2.90736143e-07] [0.30533391 3.70864407]
# ----- 390
# interpolate adjoint :  True True True
# initial cost =  3.9858247862532266
# RUN  0 , total integrated cost =  3.9858247862532266
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.9858247862532266
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.9858247862532266
# Improved over  1  iterations in  0.07912778574973345  seconds by  0.0  percent.
# cost splitting :  [1.51900291e-04 2.73386515e-07] [0.29746191 3.68791544]
# ----- 400
# interpolate adjoint :  True True True
# initial cost =  3.958335819743278
# RUN  0 , total integrated cost =  3.958335819743278
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.958335819743278
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.958335819743278
# Improved over  1  iterations in  0.07328319828957319  seconds by  0.0  percent.
# cost splitting :  [1.45218295e-04 2.50439858e-07] [0.28847281 3.66942805]
# ----- 410
# interpolate adjoint :  True True True
# initial cost =  3.9318183596792537
# RUN  0 , total integrated cost =  3.9318183596792537
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.9318183596792537
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.9318183596792537
# Improved over  1  iterations in  0.073179985396564  seconds by  0.0  percent.
# cost splitting :  [1.40886248e-04 2.33117394e-07] [0.27769369 3.6536957 ]
# ----- 420
# interpolate adjoint :  True True True
# initial cost =  3.906205304495883
# RUN  0 , total integrated cost =  3.906205304495883
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.906205304495883
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.906205304495883
# Improved over  1  iterations in  0.07188815157860518  seconds by  0.0  percent.
# cost splitting :  [1.36020728e-04 2.07081123e-07] [0.26563689 3.64014753]
# ----- 430
# interpolate adjoint :  True True True
# initial cost =  3.8815153717018807
# RUN  0 , total integrated cost =  3.8815153717018807
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.8815153717018807
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.8815153717018807
# Improved over  1  iterations in  0.07915951684117317  seconds by  0.0  percent.
# cost splitting :  [1.31603335e-04 1.90889287e-07] [0.25341634 3.62768529]
# ----- 440
# interpolate adjoint :  True True True
# initial cost =  3.8577724701277165
# RUN  0 , total integrated cost =  3.8577724701277165
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.8577724701277165
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.8577724701277165
# Improved over  1  iterations in  0.07410668022930622  seconds by  0.0  percent.
# cost splitting :  [1.27724197e-04 1.74710881e-07] [0.24178831 3.61557628]
# ----- 450
# interpolate adjoint :  True True True
# initial cost =  3.835093081120682
# RUN  0 , total integrated cost =  3.835093081120682
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.835093081120682
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.835093081120682
# Improved over  1  iterations in  0.07072365935891867  seconds by  0.0  percent.
# cost splitting :  [1.23519116e-04 1.58278910e-07] [0.22919331 3.60549921]
# ----- 460
# interpolate adjoint :  True True True
# initial cost =  3.813378669431831
# RUN  0 , total integrated cost =  3.813378669431831
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.813378669431831
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.813378669431831
# Improved over  1  iterations in  0.07559428084641695  seconds by  0.0  percent.
# cost splitting :  [1.20168074e-04 1.42816952e-07] [0.21689286 3.59609016]
# ----- 470
# interpolate adjoint :  True True True
# initial cost =  3.7926356141490736
# RUN  0 , total integrated cost =  3.7926356141490736
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.7926356141490736
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.7926356141490736
# Improved over  1  iterations in  0.07188791129738092  seconds by  0.0  percent.
# cost splitting :  [1.16093654e-04 1.29831489e-07] [0.20581846 3.58642917]
# ----- 480
# interpolate adjoint :  True True True
# initial cost =  3.772745763663547
# RUN  0 , total integrated cost =  3.772745763663547
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.772745763663547
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.772745763663547
# Improved over  1  iterations in  0.07545782625675201  seconds by  0.0  percent.
# cost splitting :  [1.13230404e-04 1.17780709e-07] [0.19464753 3.5777142 ]
# ----- 490
# interpolate adjoint :  True True True
# initial cost =  3.753674326236727
# RUN  0 , total integrated cost =  3.753674326236727
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.753674326236727
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.753674326236727
# Improved over  1  iterations in  0.07418379280716181  seconds by  0.0  percent.
# cost splitting :  [1.10119951e-04 1.06317647e-07] [0.18421177 3.56908362]
# ----- 500
# interpolate adjoint :  True True True
# initial cost =  3.7353882143981147
# RUN  0 , total integrated cost =  3.7353882143981147
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.7353882143981147
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.7353882143981147
# Improved over  1  iterations in  0.07337968051433563  seconds by  0.0  percent.
# cost splitting :  [1.07635795e-04 9.79583608e-08] [0.17433384 3.56067864]
# ----- 510
# interpolate adjoint :  True True True
# initial cost =  3.7179007549608203
# RUN  0 , total integrated cost =  3.7179007549608203
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.7179007549608203
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.7179007549608203
# Improved over  1  iterations in  0.08941436186432838  seconds by  0.0  percent.
# cost splitting :  [1.04517296e-04 8.93460841e-08] [0.16512932 3.55240141]
# ----- 520
# interpolate adjoint :  True True True
# initial cost =  3.7011759388169647
# RUN  0 , total integrated cost =  3.7011759388169647
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.7011759388169647
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.7011759388169647
# Improved over  1  iterations in  0.07256032899022102  seconds by  0.0  percent.
# cost splitting :  [1.01651027e-04 8.19584018e-08] [0.15614517 3.54466585]
# ----- 530
# interpolate adjoint :  True True True
# initial cost =  3.685197053573964
# RUN  0 , total integrated cost =  3.685197053573964
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.685197053573964
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.685197053573964
# Improved over  1  iterations in  0.07575916592031717  seconds by  0.0  percent.
# cost splitting :  [9.86397989e-05 7.59531514e-08] [0.14741989 3.53741815]
# ----- 540
# interpolate adjoint :  True True True
# initial cost =  3.669923365529182
# RUN  0 , total integrated cost =  3.669923365529182
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.669923365529182
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.669923365529182
# Improved over  1  iterations in  0.07524614222347736  seconds by  0.0  percent.
# cost splitting :  [9.61218021e-05 6.97084737e-08] [0.13910713 3.53046162]
# ----- 550
# interpolate adjoint :  True True True
# initial cost =  3.655333236710597
# RUN  0 , total integrated cost =  3.655333236710597
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.655333236710597
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.655333236710597
# Improved over  1  iterations in  0.08241322357207537  seconds by  0.0  percent.
# cost splitting :  [9.34049414e-05 6.37908844e-08] [0.13123071 3.5237533 ]
# ----- 560
# interpolate adjoint :  True True True
# initial cost =  3.641333537502168
# RUN  0 , total integrated cost =  3.641333537502168
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.641333537502168
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.641333537502168
# Improved over  1  iterations in  0.08172336500138044  seconds by  0.0  percent.
# cost splitting :  [9.11206867e-05 5.79013606e-08] [0.12374033 3.517248  ]
# ----- 570
# interpolate adjoint :  True True True
# initial cost =  3.6279853180540282
# RUN  0 , total integrated cost =  3.6279853180540282
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.6279853180540282
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.6279853180540282
# Improved over  1  iterations in  0.07778902910649776  seconds by  0.0  percent.
# cost splitting :  [8.86557942e-05 5.22325921e-08] [0.11655544 3.51108961]
# ----- 580
# interpolate adjoint :  True True True
# initial cost =  3.6151708623969916
# RUN  0 , total integrated cost =  3.6151708623969916
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.6151708623969916
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.6151708623969916
# Improved over  1  iterations in  0.10302133671939373  seconds by  0.0  percent.
# cost splitting :  [8.65559434e-05 5.02110710e-08] [0.1101764  3.50465795]
# ----- 590
# interpolate adjoint :  True True True
# initial cost =  3.6030424358706656
# RUN  0 , total integrated cost =  3.6030424358706656
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.6030424358706656
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.6030424358706656
# Improved over  1  iterations in  0.08256985805928707  seconds by  0.0  percent.
# cost splitting :  [8.3190158e-05 4.5314535e-08] [0.10383329 3.49888159]
# ----- 600
# interpolate adjoint :  True True True
# initial cost =  3.591408070924512
# RUN  0 , total integrated cost =  3.591408070924512
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.591408070924512
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.591408070924512
# Improved over  1  iterations in  0.0899807270616293  seconds by  0.0  percent.
# cost splitting :  [8.10775301e-05 4.17313985e-08] [0.09754168 3.49354312]
# ----- 610
# interpolate adjoint :  True True True
# initial cost =  3.5802127484428405
# RUN  0 , total integrated cost =  3.5802127484428405
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.5802127484428405
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.5802127484428405
# Improved over  1  iterations in  0.07586524821817875  seconds by  0.0  percent.
# cost splitting :  [7.93161947e-05 4.00292359e-08] [0.09177621 3.48811635]
# ----- 620
# interpolate adjoint :  True True True
# initial cost =  3.5696043161678657
# RUN  0 , total integrated cost =  3.5696043161678657
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.5696043161678657
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.5696043161678657
# Improved over  1  iterations in  0.07930683996528387  seconds by  0.0  percent.
# cost splitting :  [7.67922039e-05 3.61696862e-08] [0.08662992 3.48266058]
# ----- 630
# interpolate adjoint :  True True True
# initial cost =  3.5593697584636494
# RUN  0 , total integrated cost =  3.5593697584636494
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.5593697584636494
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.5593697584636494
# Improved over  1  iterations in  0.08277357276529074  seconds by  0.0  percent.
# cost splitting :  [7.52250210e-05 3.50776494e-08] [0.08148959 3.47756901]
# ----- 640
# interpolate adjoint :  True True True
# initial cost =  3.549661564763872
# RUN  0 , total integrated cost =  3.549661564763872
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.549661564763872
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.549661564763872
# Improved over  1  iterations in  0.07927778828889132  seconds by  0.0  percent.
# cost splitting :  [7.31062161e-05 3.18711312e-08] [0.07675674 3.47259881]
# ----- 650
# interpolate adjoint :  True True True
# initial cost =  3.540360934650774
# RUN  0 , total integrated cost =  3.540360934650774
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.540360934650774
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.540360934650774
# Improved over  1  iterations in  0.08298259787261486  seconds by  0.0  percent.
# cost splitting :  [7.12822782e-05 2.94717405e-08] [0.07224921 3.46780981]
# ----- 660
# interpolate adjoint :  True True True
# initial cost =  3.531508133820613
# RUN  0 , total integrated cost =  3.531508133820613
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.531508133820613
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.531508133820613
# Improved over  1  iterations in  0.08600835967808962  seconds by  0.0  percent.
# cost splitting :  [6.90021776e-05 2.78286563e-08] [0.0678759  3.46333654]
# ----- 670
# interpolate adjoint :  True True True
# initial cost =  3.522967078927225
# RUN  0 , total integrated cost =  3.522967078927225
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.522967078927225
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.522967078927225
# Improved over  1  iterations in  0.08218576665967703  seconds by  0.0  percent.
# cost splitting :  [6.74228069e-05 2.66402167e-08] [0.06394918 3.45872562]
# ----- 680
# interpolate adjoint :  True True True
# initial cost =  3.5148861890496033
# RUN  0 , total integrated cost =  3.5148861890496033
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.5148861890496033
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.5148861890496033
# Improved over  1  iterations in  0.09832037147134542  seconds by  0.0  percent.
# cost splitting :  [6.54086551e-05 2.45000310e-08] [0.06016922 3.45443017]
# ----- 690
# interpolate adjoint :  True True True
# initial cost =  3.5070799793748226
# RUN  0 , total integrated cost =  3.5070799793748226
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.5070799793748226
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.5070799793748226
# Improved over  1  iterations in  0.08261647913604975  seconds by  0.0  percent.
# cost splitting :  [6.39095737e-05 2.38313845e-08] [0.0565816  3.45021497]
# ----- 700
# interpolate adjoint :  True True True
# initial cost =  3.4995983431016726
# RUN  0 , total integrated cost =  3.4995983431016726
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.4995983431016726
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.4995983431016726
# Improved over  1  iterations in  0.08777112700045109  seconds by  0.0  percent.
# cost splitting :  [6.25287266e-05 2.15550404e-08] [0.0533984  3.44591956]
# ----- 710
# interpolate adjoint :  True True True
# initial cost =  3.4925790977622566
# RUN  0 , total integrated cost =  3.4925790977622566
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.4925790977622566
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.4925790977622566
# Improved over  1  iterations in  0.08254202641546726  seconds by  0.0  percent.
# cost splitting :  [6.02481625e-05 2.07464825e-08] [0.05015134 3.4421546 ]
# ----- 720
# interpolate adjoint :  True True True
# initial cost =  3.485846647947468
# RUN  0 , total integrated cost =  3.485846647947468
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.485846647947468
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.485846647947468
# Improved over  1  iterations in  0.08162958081811666  seconds by  0.0  percent.
# cost splitting :  [5.85564782e-05 2.19041702e-08] [0.0467529  3.43882534]
# ----- 730
# interpolate adjoint :  True True True
# initial cost =  3.4794383814441328
# RUN  0 , total integrated cost =  3.4794383814441328
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.4794383814441328
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.4794383814441328
# Improved over  1  iterations in  0.08231916092336178  seconds by  0.0  percent.
# cost splitting :  [5.66298544e-05 1.85771874e-08] [0.04368807 3.43548792]
# ----- 740
# interpolate adjoint :  True True True
# initial cost =  3.4731560181240364
# RUN  0 , total integrated cost =  3.4731560181240364
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.4731560181240364
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.4731560181240364
# Improved over  1  iterations in  0.08913116343319416  seconds by  0.0  percent.
# cost splitting :  [5.55748988e-05 1.79242271e-08] [0.04108189 3.43181387]
# ----- 750
# interpolate adjoint :  True True True
# initial cost =  3.4673217668995315
# RUN  0 , total integrated cost =  3.4673217668995315
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.4673217668995315
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.4673217668995315
# Improved over  1  iterations in  0.09007405955344439  seconds by  0.0  percent.
# cost splitting :  [5.35579884e-05 1.59968084e-08] [0.03835367 3.42871462]
# ----- 760
# interpolate adjoint :  True True True
# initial cost =  3.461719547716994
# RUN  0 , total integrated cost =  3.461719547716994
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.461719547716994
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.461719547716994
# Improved over  1  iterations in  0.11779968347400427  seconds by  0.0  percent.
# cost splitting :  [5.21247614e-05 1.65609342e-08] [0.03564358 3.42582668]
# ----- 770
# interpolate adjoint :  True True True
# initial cost =  3.4561687652368147
# RUN  0 , total integrated cost =  3.4561687652368147
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.4561687652368147
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.4561687652368147
# Improved over  1  iterations in  0.09362048376351595  seconds by  0.0  percent.
# cost splitting :  [5.11143348e-05 1.58825336e-08] [0.03352538 3.42239638]
# ----- 780
# interpolate adjoint :  True True True
# initial cost =  3.4510366976038602
# RUN  0 , total integrated cost =  3.4510366976038602
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.4510366976038602
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.4510366976038602
# Improved over  1  iterations in  0.1273937402293086  seconds by  0.0  percent.
# cost splitting :  [4.96280790e-05 1.57676193e-08] [0.03127335 3.41952106]
# ----- 790
# interpolate adjoint :  True True True
# initial cost =  3.446023329304584
# RUN  0 , total integrated cost =  3.446023329304584
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.446023329304584
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.446023329304584
# Improved over  1  iterations in  0.08634871896356344  seconds by  0.0  percent.
# cost splitting :  [4.84952098e-05 1.48175557e-08] [0.02921059 3.41657357]
# ----- 800
# interpolate adjoint :  True True True
# initial cost =  3.441269166949482
# RUN  0 , total integrated cost =  3.441269166949482
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.441269166949482
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.441269166949482
# Improved over  1  iterations in  0.08413893915712833  seconds by  0.0  percent.
# cost splitting :  [4.72045797e-05 1.42700892e-08] [0.02724875 3.41378526]
# ----- 810
# interpolate adjoint :  True True True
# initial cost =  3.4367924565729613
# RUN  0 , total integrated cost =  3.4367924565729613
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.4367924565729613
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.4367924565729613
# Improved over  1  iterations in  0.08827624935656786  seconds by  0.0  percent.
# cost splitting :  [4.57206018e-05 1.34325312e-08] [0.02532993 3.41123249]
# ----- 820
# interpolate adjoint :  True True True
# initial cost =  3.432579944534396
# RUN  0 , total integrated cost =  3.432579944534396
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.432579944534396
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.432579944534396
# Improved over  1  iterations in  0.10871864017099142  seconds by  0.0  percent.
# cost splitting :  [4.40398665e-05 1.27524174e-08] [0.02334809 3.40900809]
# ----- 830
# interpolate adjoint :  True True True
# initial cost =  3.428432531511494
# RUN  0 , total integrated cost =  3.428432531511494
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.428432531511494
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.428432531511494
# Improved over  1  iterations in  0.0966030927374959  seconds by  0.0  percent.
# cost splitting :  [4.31538860e-05 1.28323955e-08] [0.02143575 3.40677537]
# ----- 840
# interpolate adjoint :  True True True
# initial cost =  3.424313837583047
# RUN  0 , total integrated cost =  3.424313837583047
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.424313837583047
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.424313837583047
# Improved over  1  iterations in  0.08792382013052702  seconds by  0.0  percent.
# cost splitting :  [4.22101267e-05 1.27073230e-08] [0.02008494 3.40401022]
# ----- 850
# interpolate adjoint :  True True True
# initial cost =  3.420631023951782
# RUN  0 , total integrated cost =  3.420631023951782
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.420631023951782
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.420631023951782
# Improved over  1  iterations in  0.11973986402153969  seconds by  0.0  percent.
# cost splitting :  [4.04784038e-05 1.26716494e-08] [0.01856327 3.40185603]
# ----- 860
# interpolate adjoint :  True True True
# initial cost =  3.4168457362201234
# RUN  0 , total integrated cost =  3.4168457362201234
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.4168457362201234
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.4168457362201234
# Improved over  1  iterations in  0.08853419683873653  seconds by  0.0  percent.
# cost splitting :  [3.98752475e-05 1.23333129e-08] [0.01718537 3.39944981]
# ----- 870
# interpolate adjoint :  True True True
# initial cost =  3.4132158965491968
# RUN  0 , total integrated cost =  3.4132158965491968
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.4132158965491968
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.4132158965491968
# Improved over  1  iterations in  0.08906351029872894  seconds by  0.0  percent.
# cost splitting :  [3.89711506e-05 1.21127320e-08] [0.01609547 3.39691271]
# ----- 880
# interpolate adjoint :  True True True
# initial cost =  3.4100009528741735
# RUN  0 , total integrated cost =  3.4100009528741735
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.4100009528741735
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.4100009528741735
# Improved over  1  iterations in  0.09539922047406435  seconds by  0.0  percent.
# cost splitting :  [3.73311025e-05 1.13494134e-08] [0.01475745 3.39504267]
# ----- 890
# interpolate adjoint :  True True True
# initial cost =  3.406719066949776
# RUN  0 , total integrated cost =  3.406719066949776
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.406719066949776
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.406719066949776
# Improved over  1  iterations in  0.09082895796746016  seconds by  0.0  percent.
# cost splitting :  [3.68167380e-05 1.19418917e-08] [0.01350721 3.39301196]
# ----- 900
# interpolate adjoint :  True True True
# initial cost =  3.4036677905358275
# RUN  0 , total integrated cost =  3.4036677905358275
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.4036677905358275
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.4036677905358275
# Improved over  1  iterations in  0.09378841705620289  seconds by  0.0  percent.
# cost splitting :  [3.56663788e-05 1.19787998e-08] [0.01234647 3.39112589]
# ----- 910
# interpolate adjoint :  True True True
# initial cost =  3.4005387778972445
# RUN  0 , total integrated cost =  3.4005387778972445
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.4005387778972445
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.4005387778972445
# Improved over  1  iterations in  0.12547939829528332  seconds by  0.0  percent.
# cost splitting :  [3.48714391e-05 1.21300914e-08] [0.01150603 3.38883994]
# ----- 920
# interpolate adjoint :  True True True
# initial cost =  3.3976054551780748
# RUN  0 , total integrated cost =  3.3976054551780748
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.3976054551780748
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.3976054551780748
# Improved over  1  iterations in  0.08909072075039148  seconds by  0.0  percent.
# cost splitting :  [3.39857048e-05 1.18571003e-08] [0.01070401 3.38671184]
# ----- 930
# interpolate adjoint :  True True True
# initial cost =  3.395023039296953
# RUN  0 , total integrated cost =  3.395023039296953
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.395023039296953
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.395023039296953
# Improved over  1  iterations in  0.09911921061575413  seconds by  0.0  percent.
# cost splitting :  [3.26834936e-05 1.22133379e-08] [0.009686   3.38515307]
# ----- 940
# interpolate adjoint :  True True True
# initial cost =  3.392562091870271
# RUN  0 , total integrated cost =  3.392562091870271
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.392562091870271
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.392562091870271
# Improved over  1  iterations in  0.1093855956569314  seconds by  0.0  percent.
# cost splitting :  [3.16057943e-05 1.19627178e-08] [0.00859801 3.3837846 ]
# ----- 950
# interpolate adjoint :  True True True
# initial cost =  3.3901757064041402
# RUN  0 , total integrated cost =  3.3901757064041402
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.3901757064041402
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.3901757064041402
# Improved over  1  iterations in  0.09007152821868658  seconds by  0.0  percent.
# cost splitting :  [3.06603844e-05 1.23572020e-08] [0.00763008 3.38236998]
# ----- 960
# interpolate adjoint :  True True True
# initial cost =  3.387773647805571
# RUN  0 , total integrated cost =  3.387773647805571
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.387773647805571
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.387773647805571
# Improved over  1  iterations in  0.09215554408729076  seconds by  0.0  percent.
# cost splitting :  [3.00367127e-05 1.36124909e-08] [0.00681558 3.38078449]
# ----- 970
# ...
# RUN  1900 , total integrated cost =  3.3440024358000087
# RUN  2000 , total integrated cost =  3.344002430997822
# RUN  3000 , total integrated cost =  3.344002383111066
# RUN  4000 , total integrated cost =  3.3440023352476724
# RUN  5000 , total integrated cost =  3.344002287456328
# RUN  6000 , total integrated cost =  3.344002239680354
# RUN  7000 , total integrated cost =  3.3440021919762883
# RUN  8000 , total integrated cost =  3.3440021442875643
# RUN  9000 , total integrated cost =  3.3440020966581927
# RUN  10000 , total integrated cost =  3.344002049068939
# RUN  10000 , total integrated cost =  3.344002049068939
# Improved over  10000  iterations in  1054.421124582179  seconds by  1.429026158916713e-05  percent.
# cost splitting :  [1.05714372e-06 3.56182741e-09] [6.49895361e-13 3.34399254e+00]
# ----- 1600
# interpolate adjoint :  True True True
# initial cost =  3.344002049068939
# RUN  0 , total integrated cost =  3.344002049068939
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.3440020490474702
# RUN  2 , total integrated cost =  3.3440020490435063
# RUN  3 , total integrated cost =  3.344002049022391
# RUN  4 , total integrated cost =  3.344002048880195
# RUN  5 , total integrated cost =  3.3440020488587576
# RUN  6 , total integrated cost =  3.3440020488547924
# RUN  7 , total integrated cost =  3.344002048833642
# RUN  8 , total integrated cost =  3.3440020486914537
# RUN  9 , total integrated cost =  3.3440020486700472
# RUN  10 , total integrated cost =  3.3440020486660815
# RUN  11 , total integrated cost =  3.3440020486449034
# RUN  12 , total integrated cost =  3.3440020485027153
# RUN  13 , total integrated cost =  3.3440020484715527
# RUN  14 , total integrated cost =  3.344002048467578
# RUN  15 , total integrated cost =  3.3440020484477575
# RUN  16 , total integrated cost =  3.344002048301556
# RUN  17 , total integrated cost =  3.3440020482736963
# RUN  18 , total integrated cost =  3.344002048269731
# RUN  19 , total integrated cost =  3.344002048247564
# RUN  20 , total integrated cost =  3.3440020481049735
# RUN  30 , total integrated cost =  3.344002047693818
# RUN  40 , total integrated cost =  3.344002047153378
# RUN  50 , total integrated cost =  3.3440020467502825
# RUN  60 , total integrated cost =  3.3440020462097046
# RUN  70 , total integrated cost =  3.3440020458067794
# RUN  80 , total integrated cost =  3.344002045266061
# RUN  90 , total integrated cost =  3.344002044853504
# RUN  100 , total integrated cost =  3.3440020442942524
# RUN  110 , total integrated cost =  3.3440020438911002
# RUN  120 , total integrated cost =  3.344002043350638
# RUN  130 , total integrated cost =  3.3440020429476407
# RUN  140 , total integrated cost =  3.344002042407042
# RUN  150 , total integrated cost =  3.3440020420042007
# RUN  160 , total integrated cost =  3.34400204145104
# RUN  170 , total integrated cost =  3.3440020410320686
# RUN  180 , total integrated cost =  3.3440020404917234
# RUN  190 , total integrated cost =  3.344002040088661
# RUN  200 , total integrated cost =  3.3440020395481778
# RUN  300 , total integrated cost =  3.3440020348025286
# RUN  400 , total integrated cost =  3.3440020300291544
# RUN  500 , total integrated cost =  3.34400202528437
# RUN  600 , total integrated cost =  3.344002020511878
# RUN  700 , total integrated cost =  3.34400201576796
# RUN  800 , total integrated cost =  3.344002011024473
# RUN  900 , total integrated cost =  3.344002006253275
# RUN  1000 , total integrated cost =  3.3440020015106637
# RUN  1100 , total integrated cost =  3.34400199674033
# RUN  1200 , total integrated cost =  3.344001991998583
# RUN  1300 , total integrated cost =  3.3440019872572644
# RUN  1400 , total integrated cost =  3.344001982488243
# RUN  1500 , total integrated cost =  3.344001977747796
# RUN  1600 , total integrated cost =  3.3440019729796435
# RUN  1700 , total integrated cost =  3.3440019682400597
# RUN  1800 , total integrated cost =  3.3440019634884908
# RUN  1900 , total integrated cost =  3.344001958734047
# RUN  2000 , total integrated cost =  3.344001953995764
# RUN  3000 , total integrated cost =  3.344001906496094
# RUN  4000 , total integrated cost =  3.3440018590678386
# RUN  5000 , total integrated cost =  3.3440018116547967
# RUN  6000 , total integrated cost =  3.344001764296194
# RUN  7000 , total integrated cost =  3.3440017170201193
# RUN  8000 , total integrated cost =  3.3440016698278088
# RUN  9000 , total integrated cost =  3.3440016226912257
# RUN  10000 , total integrated cost =  3.3440015751891075
# RUN  10000 , total integrated cost =  3.3440015751891075
# Improved over  10000  iterations in  1053.9713370492682  seconds by  1.4171038912991207e-05  percent.
# cost splitting :  [1.05714241e-06 3.56136121e-09] [6.49895361e-13 3.34399207e+00]
# ----- 1600
# interpolate adjoint :  True True True
# initial cost =  3.3440015751891075
# RUN  0 , total integrated cost =  3.3440015751891075
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.344001575167794
# RUN  2 , total integrated cost =  3.344001575163962
# RUN  3 , total integrated cost =  3.344001575143589
# RUN  4 , total integrated cost =  3.344001575002853
# RUN  5 , total integrated cost =  3.3440015749815593
# RUN  6 , total integrated cost =  3.344001574977739
# RUN  7 , total integrated cost =  3.3440015749573266
# RUN  8 , total integrated cost =  3.3440015748165925
# RUN  9 , total integrated cost =  3.344001574795338
# RUN  10 , total integrated cost =  3.344001574791507
# RUN  11 , total integrated cost =  3.34400157477107
# RUN  12 , total integrated cost =  3.3440015746303318
# RUN  13 , total integrated cost =  3.3440015746091056
# RUN  14 , total integrated cost =  3.3440015746052807
# RUN  15 , total integrated cost =  3.3440015745848126
# RUN  16 , total integrated cost =  3.3440015744440736
# RUN  17 , total integrated cost =  3.3440015744228835
# RUN  18 , total integrated cost =  3.344001574419055
# RUN  19 , total integrated cost =  3.3440015743985567
# RUN  20 , total integrated cost =  3.344001574257819
# RUN  30 , total integrated cost =  3.3440015738507336
# RUN  40 , total integrated cost =  3.3440015731967194
# RUN  50 , total integrated cost =  3.344001572760831
# RUN  60 , total integrated cost =  3.344001572227124
# RUN  70 , total integrated cost =  3.3440015718111145
# RUN  80 , total integrated cost =  3.344001571268128
# RUN  90 , total integrated cost =  3.3440015708704514
# RUN  100 , total integrated cost =  3.344001570336971
# RUN  110 , total integrated cost =  3.3440015699394774
# RUN  120 , total integrated cost =  3.3440015694058465
# RUN  130 , total integrated cost =  3.3440015689687304
# RUN  140 , total integrated cost =  3.3440015682370148
# RUN  150 , total integrated cost =  3.3440015333779205
# RUN  160 , total integrated cost =  3.3440015326506467
# RUN  170 , total integrated cost =  3.344001531970405
# RUN  180 , total integrated cost =  3.3440015315541918
# RUN  190 , total integrated cost =  3.344001530853574
# RUN  200 , total integrated cost =  3.3440015303564725
# RUN  300 , total integrated cost =  3.3440015252773683
# RUN  400 , total integrated cost =  3.344001520424135
# RUN  500 , total integrated cost =  3.344001513690639
# RUN  600 , total integrated cost =  3.344001506710682
# RUN  700 , total integrated cost =  3.3440014997068643
# RUN  800 , total integrated cost =  3.34400149152541
# RUN  900 , total integrated cost =  3.3440014844692487
# RUN  1000 , total integrated cost =  3.344001477571409
# RUN  1100 , total integrated cost =  3.3440014721790545
# RUN  1200 , total integrated cost =  3.3440014640552183
# RUN  1300 , total integrated cost =  3.344001457144681
# RUN  1400 , total integrated cost =  3.344001448902126
# RUN  1500 , total integrated cost =  3.34400144373888
# RUN  1600 , total integrated cost =  3.3440014367471433
# RUN  1700 , total integrated cost =  3.344001428585193
# RUN  1800 , total integrated cost =  3.344001421555558
# RUN  1900 , total integrated cost =  3.3440014133658336
# RUN  2000 , total integrated cost =  3.344001406412433
# RUN  3000 , total integrated cost =  3.3440013174256147
# RUN  4000 , total integrated cost =  3.344001128252441
# RUN  5000 , total integrated cost =  3.3440006917613125
# RUN  6000 , total integrated cost =  3.344000586086528
# RUN  7000 , total integrated cost =  3.3440004077409524
# RUN  8000 , total integrated cost =  3.3439999948401686
# RUN  9000 , total integrated cost =  3.343999889240807
# RUN  10000 , total integrated cost =  3.3439997837557702
# RUN  10000 , total integrated cost =  3.3439997837557702
# Improved over  10000  iterations in  1024.1597841484472  seconds by  5.3571545848285496e-05  percent.
# cost splitting :  [1.05722714e-06 3.57244927e-09] [6.49895361e-13 3.34399028e+00]
# ----- 1600
# interpolate adjoint :  True True True
# initial cost =  3.3439997837557702
# RUN  0 , total integrated cost =  3.3439997837557702
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.343999783731332
# RUN  2 , total integrated cost =  3.343999783728015
# RUN  3 , total integrated cost =  3.3439997837189543
# RUN  4 , total integrated cost =  3.3439997834373925
# RUN  5 , total integrated cost =  3.343999783300424
# RUN  6 , total integrated cost =  3.343999783295616
# RUN  7 , total integrated cost =  3.3439997832915433
# RUN  8 , total integrated cost =  3.343999783022722
# RUN  9 , total integrated cost =  3.343999782577589
# RUN  10 , total integrated cost =  3.3439997825684227
# RUN  11 , total integrated cost =  3.3439997825651018
# RUN  12 , total integrated cost =  3.343999782540759
# RUN  13 , total integrated cost =  3.3439997823986762
# RUN  14 , total integrated cost =  3.343999782374379
# RUN  15 , total integrated cost =  3.3439997823710597
# RUN  16 , total integrated cost =  3.3439997823619505
# RUN  17 , total integrated cost =  3.3439997820797167
# RUN  18 , total integrated cost =  3.3439997819434653
# RUN  19 , total integrated cost =  3.343999781938668
# RUN  20 , total integrated cost =  3.3439997819345875
# RUN  30 , total integrated cost =  3.3439997807220805
# RUN  40 , total integrated cost =  3.343999779660542
# RUN  50 , total integrated cost =  3.3439997784270554
# RUN  60 , total integrated cost =  3.343999777529249
# RUN  70 , total integrated cost =  3.3439997764486358
# RUN  80 , total integrated cost =  3.343999775519363
# RUN  90 , total integrated cost =  3.343999774332132
# RUN  100 , total integrated cost =  3.343999773012219
# RUN  110 , total integrated cost =  3.343999772373474
# RUN  120 , total integrated cost =  3.3439997714398104
# RUN  130 , total integrated cost =  3.3439997700528377
# RUN  140 , total integrated cost =  3.343999768865653
# RUN  150 , total integrated cost =  3.343999768231942
# RUN  160 , total integrated cost =  3.3439997670199935
# RUN  170 , total integrated cost =  3.3439997659583574
# RUN  180 , total integrated cost =  3.3439997647924207
# RUN  190 , total integrated cost =  3.343999763888717
# RUN  200 , total integrated cost =  3.343999762747085
# RUN  300 , total integrated cost =  3.343999752258879
# RUN  400 , total integrated cost =  3.343999741468247
# RUN  500 , total integrated cost =  3.343999731279342
# RUN  600 , total integrated cost =  3.3439997196229827
# RUN  700 , total integrated cost =  3.343999648182131
# RUN  800 , total integrated cost =  3.3439996373756506
# RUN  900 , total integrated cost =  3.3439996271763204
# RUN  1000 , total integrated cost =  3.343999616622112
# RUN  1100 , total integrated cost =  3.3439996058326362
# RUN  1200 , total integrated cost =  3.343999595644791
# RUN  1300 , total integrated cost =  3.3439995850965674
# RUN  1400 , total integrated cost =  3.3439995743117796
# RUN  1500 , total integrated cost =  3.343999564127522
# RUN  1600 , total integrated cost =  3.3439995535787874
# RUN  1700 , total integrated cost =  3.3439995427834064
# RUN  1800 , total integrated cost =  3.3439995322917553
# RUN  1900 , total integrated cost =  3.3439995217357974
# RUN  2000 , total integrated cost =  3.343999511084253
# RUN  3000 , total integrated cost =  3.3439994057486198
# RUN  4000 , total integrated cost =  3.343999225394877
# RUN  5000 , total integrated cost =  3.34399835304759
# RUN  6000 , total integrated cost =  3.3439979863657006
# RUN  7000 , total integrated cost =  3.343997772130409
# RUN  8000 , total integrated cost =  3.3439973967763397
# RUN  9000 , total integrated cost =  3.3439972043781516
# RUN  10000 , total integrated cost =  3.34399647035865
# RUN  10000 , total integrated cost =  3.34399647035865
# Improved over  10000  iterations in  1019.225067269057  seconds by  9.908484851450794e-05  percent.
# cost splitting :  [1.05567189e-06 3.62288763e-09] [6.49895361e-13 3.34398698e+00]
# ----- 1600
# interpolate adjoint :  True True True
# initial cost =  3.34399647035865
# RUN  0 , total integrated cost =  3.34399647035865
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.3439964703557803
# RUN  2 , total integrated cost =  3.343996470347144
# RUN  3 , total integrated cost =  3.3439964700764393
# RUN  4 , total integrated cost =  3.3439964699559277
# RUN  5 , total integrated cost =  3.343996469952038
# RUN  6 , total integrated cost =  3.343996469948349
# RUN  7 , total integrated cost =  3.343996469685798
# RUN  8 , total integrated cost =  3.3439964692240016
# RUN  9 , total integrated cost =  3.3439964692142996
# RUN  10 , total integrated cost =  3.343996469211593
# RUN  11 , total integrated cost =  3.3439964692018567
# RUN  12 , total integrated cost =  3.3439964689880006
# RUN  13 , total integrated cost =  3.3439964689043995
# RUN  14 , total integrated cost =  3.343996468901394
# RUN  15 , total integrated cost =  3.343996468896614
# RUN  16 , total integrated cost =  3.343996452335443
# RUN  17 , total integrated cost =  3.3439964353080818
# RUN  18 , total integrated cost =  3.343996435287756
# RUN  19 , total integrated cost =  3.343996435245105
# RUN  20 , total integrated cost =  3.343996435080355
# RUN  30 , total integrated cost =  3.343996432684748
# RUN  40 , total integrated cost =  3.343996430524166
# RUN  50 , total integrated cost =  3.343996429862526
# RUN  60 , total integrated cost =  3.3439964286860775
# RUN  70 , total integrated cost =  3.343996398217303
# RUN  80 , total integrated cost =  3.343996396435877
# RUN  90 , total integrated cost =  3.3439963956480327
# RUN  100 , total integrated cost =  3.3439963901559135
# RUN  110 , total integrated cost =  3.343996351716993
# RUN  120 , total integrated cost =  3.3439963385318783
# RUN  130 , total integrated cost =  3.3439963372510197
# RUN  140 , total integrated cost =  3.3439963339650993
# RUN  150 , total integrated cost =  3.3439963307745657
# RUN  160 , total integrated cost =  3.3439963274778024
# RUN  170 , total integrated cost =  3.3439962867233817
# RUN  180 , total integrated cost =  3.343996285736328
# RUN  190 , total integrated cost =  3.3439962562861734
# RUN  200 , total integrated cost =  3.343996246571037
# RUN  300 , total integrated cost =  3.343996128551485
# RUN  400 , total integrated cost =  3.3439960271602964
# RUN  500 , total integrated cost =  3.3439958741897864
# RUN  600 , total integrated cost =  3.3439957550460555
# RUN  700 , total integrated cost =  3.343995696105839
# RUN  800 , total integrated cost =  3.3439956019005095
# RUN  900 , total integrated cost =  3.3439955454958827
# RUN  1000 , total integrated cost =  3.34399544701052
# RUN  1100 , total integrated cost =  3.3439953374878253
# RUN  1200 , total integrated cost =  3.3439952752186177
# RUN  1300 , total integrated cost =  3.343995209765736
# RUN  1400 , total integrated cost =  3.3439951550784253
# RUN  1500 , total integrated cost =  3.343995111060186
# RUN  1600 , total integrated cost =  3.3439950485861223
# RUN  1700 , total integrated cost =  3.3439949947615717
# RUN  1800 , total integrated cost =  3.3439949555597233
# RUN  1900 , total integrated cost =  3.3439949316494344
# RUN  2000 , total integrated cost =  3.343994912994316
# RUN  3000 , total integrated cost =  3.3439941990297553
# RUN  4000 , total integrated cost =  3.3439937701322306
# RUN  5000 , total integrated cost =  3.3439933196877516
# RUN  6000 , total integrated cost =  3.343992829360101
# RUN  7000 , total integrated cost =  3.3439927893933095
# RUN  8000 , total integrated cost =  3.3439927494405923

# %%
bestControl_maxW = np.array( [[None] * len(t_pen)] * len(exc) )
bestState_maxW = np.array( [[None] * len(t_pen)] * len(exc) )
cost_maxW = np.array( [[None] * len(t_pen)] * len(exc) )
costnode_maxW = np.array( [[None] * len(t_pen)] * len(exc) )
weights_maxW = np.array( [[None] * len(t_pen)] * len(exc) )
convergence_maxW = np.array( [[None] * len(t_pen)] * len(exc) )

file_maxW = 'up_Wmax.pickle'

# %%
if os.path.isfile(file_maxW) :
    print("file found")
    
    with open(file_maxW,'rb') as f:
        load_array = pickle.load(f)

    bestControl_maxW = load_array[0]
    bestState_maxW = load_array[1]
    cost_maxW = load_array[2]
    costnode_maxW = load_array[3]
    weights_maxW = load_array[4]
# Out:
# file found

# %%
tol = 1e-8

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    j = 0

    while not convergence_maxW[i][j]:

        dur = d_array[0]
        aln.params.duration = dur        
        setinit(initVars[i], aln)

        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        control0 = aln.getZeroControl()
        if type(bestControl_maxW[i][j]) == type(None):
            max_it = 10
            control0 = bestControl_[i][0][:,:,n_pre-1:-n_post+1]
            weight_ = ( cost_uncontrolled[i] - sum(costnode_[i][j][0][0][:]) ) / sum( costnode_[i][j][2][0][:] )
            cost.setParams(1., weight_ * factor_we, weight_ * factor_ws)
            weights_maxW[i][j] = cost.getParams()
        else:
            control0 = bestControl_maxW[i][j][:,:,n_pre-1:-n_post+1]
            weight_ = ( cost_uncontrolled[i] - sum(costnode_maxW[i][j][0][0][:]) ) / sum( costnode_maxW[i][j][2][0][:] )
            cost.setParams(1., weight_ * factor_we, weight_ * factor_ws)
            weights_maxW[i][j] = cost.getParams()
            max_it = int(100)

        bestControl_maxW[i][j], bestState_maxW[i][j], cost_maxW[i][j], runtime_, grad_, phi_, phi1_, costnode_maxW[i][j] = aln.A1(
            control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
            prec_variables_ = p_var, transition_time_ = t_pen[j])

        if cost_maxW[i][j][2] == 0.:
            convergence_maxW[i][j] = True

        print('cost splitting : ', costnode_[i][j][0][0][:2], costnode_[i][j][2][0][:2])

        with open(file_maxW,'wb') as f:
            pickle.dump([bestControl_maxW, bestState_maxW, cost_maxW, costnode_maxW, weights_maxW], f)
# Out:
# -------  0 0.4500000000000001 0.4750000000000002
# set cost params:  1.0 0.0 4271.010735426549
# interpolate adjoint :  True True True
# initial cost =  59332.71056788092
# RUN  0 , total integrated cost =  59332.71056788092
# Gradient descend method:  None
# RUN  1 , total integrated cost =  59332.71056788092
# Control only changes marginally.
# RUN  1 , total integrated cost =  59332.71056788092
# Improved over  1  iterations in  0.06357321102404967  seconds by  0.0  percent.
# cost splitting :  [141.66003002 463.44432709] [77.42571324 18.12886434]
# -------  1 0.47500000000000014 0.6000000000000003
# set cost params:  1.0 0.0 9023.532227728007
# interpolate adjoint :  True True True
# initial cost =  59589.70010283168
# RUN  0 , total integrated cost =  59589.70010283168
# Gradient descend method:  None
# RUN  1 , total integrated cost =  59589.70010283168
# Control only changes marginally.
# RUN  1 , total integrated cost =  59589.70010283168
# Improved over  1  iterations in  0.06353268801467493  seconds by  0.0  percent.
# cost splitting :  [16022.6715674    433.55724978] [ 0.         13.56960159]

# %%
for j in np.arange(2000, 2001, 1):
    bestControl_maxW[1][j] = None
    convergence_maxW[1][j] = None

# %%
for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    j = 0
    step = step1
    
    if i == 0:
        continue

    while j < 2001:
        
        if j >= 10:
            step = step2
        if j >= 500:
            step = step3
        
        if convergence_maxW[i][j]:
            j += step
            continue

        print('-----', j)

        dur = round(d_array[j],1)
        aln.params.duration = dur
        max_it = int(10000)  

        setinit(initVars[i], aln)
        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        if type(bestControl_maxW[i][j]) == type(None):
            control0 = aln.getZeroControl()
            control0[:,:,:-step] = bestControl_maxW[i][j-step][:,:,n_pre-1:-n_post+1]
            weight_ = ( cost_uncontrolled[i] * (1. - t_pen[0]) / (1. - t_pen[j])
                          - sum(costnode_maxW[i][j-step][0][0][:]) ) / sum( costnode_maxW[i][j-step][2][0][:] )
        else:
            control0 = bestControl_maxW[i][j][:,:,n_pre-1:-n_post+1]
            weight_ = ( cost_uncontrolled[i] * (1. - t_pen[0]) / (1. - t_pen[j])
                           - sum(costnode_maxW[i][j][0][0][:]) ) / sum( costnode_maxW[i][j][2][0][:] )
            
        if j <= 200:
            weight_ *= 0.8
        elif j <= 400:
            weight_ *= 0.85
        elif j <= 600:
            weight_ *= 0.8
        elif j <= 2000:
            weight_ *= 0.8
        
        cost.setParams(1., weight_ * factor_we, weight_ * factor_ws)
        weights_maxW[i][j] = cost.getParams()
        
        if j <= 30:
            cost.setParams(1., weights_maxW[i][j-step][1] * factor_we, weights_maxW[i][j-step][2] * factor_ws)
            weights_maxW[i][j] = cost.getParams()

        bestControl_maxW[i][j], bestState_maxW[i][j], cost_maxW[i][j], runtime_, grad_, phi_, phi1_, costnode_maxW[i][j] = aln.A1(
            control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
            prec_variables_ = p_var, transition_time_ = t_pen[j])

        if cost_maxW[i][j][2] == 0.:
            convergence_maxW[i][j] = True

        print('cost splitting : ', costnode_maxW[i][j][0][0][:2], costnode_maxW[i][j][2][0][:2])

        if np.amax(costnode_maxW[i][j][2][0][:2]) > 1e-2:
            with open(file_maxW,'wb') as f:
                    pickle.dump([bestControl_maxW, bestState_maxW, cost_maxW, costnode_maxW, weights_maxW], f)  
        else:
            print("converged to zero, repeat")
            break
# Out:
# -------  0 0.4500000000000001 0.4750000000000002
# -------  1 0.47500000000000014 0.6000000000000003
# ----- 2000
# set cost params:  1.0 0.0 104519.54914779642
# interpolate adjoint :  True True True
# initial cost =  524388.9936475958
# RUN  0 , total integrated cost =  524388.9936475958
# Gradient descend method:  None
# RUN  1 , total integrated cost =  524387.6772318347
# RUN  2 , total integrated cost =  524387.6708293832
# RUN  3 , total integrated cost =  524387.6708293832
# Control only changes marginally.
# RUN  3 , total integrated cost =  524387.6708293832
# Improved over  3  iterations in  1.378332621010486  seconds by  0.00025225895825542466  percent.
# cost splitting :  [0.15366806 0.06065628] [5.01712321e+00 2.58034143e-09]
# ----- 2000
# set cost params:  1.0 0.0 104519.89455298895
# interpolate adjoint :  True True True
# initial cost =  524389.4037697935
# RUN  0 , total integrated cost =  524389.4037697935
# Gradient descend method:  None
# RUN  1 , total integrated cost =  524389.4037697935
# Control only changes marginally.
# RUN  1 , total integrated cost =  524389.4037697935
# Improved over  1  iterations in  0.38048618903849274  seconds by  0.0  percent.
# cost splitting :  [0.15366806 0.06065628] [5.01712321e+00 2.58034143e-09]

# %%
if os.path.isfile(file_maxW) :
    print("file found")
    
    with open(file_maxW,'rb') as f:
        load_array = pickle.load(f)

    bestControl_maxW = load_array[0]
    bestState_maxW = load_array[1]
    cost_maxW = load_array[2]
    costnode_maxW = load_array[3]
    weights_maxW = load_array[4]
# Out:
# file found
