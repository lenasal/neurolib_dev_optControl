# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import sys
import pickle

path = os.getcwd().split(os.sep + 'GUI')[0]
if path not in sys.path:
    print("not here")
    sys.path.append(path)

from neurolib.models.aln import ALNModel
from neurolib.utils import plotFunctions as plotFunc
from neurolib.utils import costFunctions as cost
import neurolib.dashboard.functions as functions
import neurolib.dashboard.data as data
    
# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2 

#path = os.path.join(os.getcwd(), "plots")
# Out:
# not here

# %%
grid_data_file = os.path.join(os.getcwd().split('data')[0], 'bi.pickle')
with open(grid_data_file,'rb') as f:
    load_array= pickle.load(f)
exc = [load_array[0][20], load_array[0][50]]
inh = [load_array[1][20], load_array[1][50]]

folder = str(os.getcwd().split('data_2')[1])
print(folder)
case = str(folder[1])

file_ = 'down.pickle'

c_var = [0,1]
if len(folder) == 4:
    if folder[3] == 'e':
        p_var = [0]
    elif folder[3] == 'i':
        p_var = [1]
else:
    p_var = [0,1]
    
print(p_var)

step1 = 100
step2 = 10
step3 = 1
# Out:
# /1_ei
# [0, 1]

# %%
aln = ALNModel()
N = aln.params.N

data.set_parameters(aln)

state_vars = aln.state_vars
init_vars = aln.init_vars

##############################################################
def setinit(init_vars_, model):
    state_vars = model.state_vars
    init_vars = model.init_vars
    for iv in range(len(init_vars)):
        for sv in range(len(state_vars)):
            if state_vars[sv] in init_vars[iv]:
                #print("set init vars ", )
                if model.params[init_vars[iv]].ndim == 2:
                    model.params[init_vars[iv]][0,:] = init_vars_[sv]
                else:
                    model.params[init_vars[iv]][0] = init_vars_[sv]
                    
##############################################################               
def setmaxmincontrol(max_c_c, min_c_c, max_c_r, min_c_r):
    import numpy as np
    
    max_cntrl = np.zeros(( 6 ))
    min_cntrl = np.zeros(( 6 ))
    
    max_cntrl[0] = max_c_c
    min_cntrl[0] = min_c_c
    max_cntrl[1] = max_c_c
    min_cntrl[1] = min_c_c
    max_cntrl[2] = max_c_r
    min_cntrl[2] = min_c_r
    max_cntrl[3] = max_c_r
    min_cntrl[3] = min_c_r
    max_cntrl[4] = max_c_r
    min_cntrl[4] = min_c_r
    max_cntrl[5] = max_c_r
    min_cntrl[5] = min_c_r
            
    return max_cntrl, min_cntrl

# %%
d_array = np.arange(500., 20, -0.1)
t0_array = d_array - 20.
t_pen = np.zeros(( t0_array.shape ))
for i in range(len(t_pen)):
    t_pen[i] = t0_array[i] / d_array[i]

# %%
dur_pre = 10
dur_post = 10

n_pre = int(np.around(dur_pre/aln.params.dt + 1.,1))
n_post = int(np.around(dur_post/aln.params.dt + 1.,1))

tol = 1e-12
start_step = 10.
c_scheme = np.zeros(( 1,1 ))
c_scheme[0,0] = 1.
u_mat = np.identity(1)
u_scheme = np.array([[1.]])

if case in ['1', '2']:    # low to high
    max_I = [3., -3.]
else:
    max_I = [-3., 3.]
    
if case in ['1', '3']:    # sparsity
    factor_ws = 1.
    factor_we = 0.
else:
    factor_ws = 0.
    factor_we = 1.
    
maxC = [1000., -1000., 0.18, 0.]
max_cntrl, min_cntrl = setmaxmincontrol(maxC[0], maxC[1], maxC[2], maxC[3])

# %%
bestControl_ = np.array( [[None] * len(t_pen)] * len(exc) )
bestState_ = np.array( [[None] * len(t_pen)] * len(exc) )
cost_ = np.array( [[None] * len(t_pen)] * len(exc) )
costnode_ = np.array( [[None] * len(t_pen)] * len(exc) )
weights_ = np.array( [[None] * len(t_pen)] * len(exc) )
convergence_ = np.array( [[None] * len(t_pen)] * len(exc) )

initVars = [None] * len(exc)
target = [None] * len(exc)
cost_uncontrolled = [None] * len(exc)

print(bestControl_.shape)
# Out:
# (2, 4800)

# %%
if os.path.isfile(file_) :
    print("file found")
    
    with open(file_,'rb') as f:
        load_array = pickle.load(f)

    bestControl_ = load_array[0]
    bestState_ = load_array[1]
    cost_ = load_array[2]
    costnode_ = load_array[3]
    weights_ = load_array[4]
# Out:
# file found

# %%
# get initial parameters and target states

i_range = range(len(exc))
data.set_parameters(aln)
max_percent = []

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    aln.params.duration = 3000.
    
    control0 = aln.getZeroControl()
    control0 = functions.step_control(aln, maxI_ = max_I[0])

    aln.run(control=control0)
    
    target_rates = np.zeros((2))
    target_rates[0] = aln.rates_exc[0,-1] 
    target_rates[1] = aln.rates_inh[0,-1]

    control0 = functions.step_control(aln, maxI_ = max_I[1])
    aln.run(control=control0)

    init_state_vars = np.zeros(( len(state_vars) ))
    for j in range(len(state_vars)):
        if aln.state[state_vars[j]].size == 1:
            init_state_vars[j] = aln.state[state_vars[j]][0]
        else:
            init_state_vars[j] = aln.state[state_vars[j]][0,-1]

    initVars[i] = init_state_vars
    target[i] = [target_rates[0], target_rates[1]]
    
    max_percent.append( (np.argmax(np.abs(bestControl_[i][0]), axis=2)[0,1] -100) / 4800 )
# Out:
# -------  0 0.4500000000000001 0.4750000000000002
# -------  1 0.47500000000000014 0.6000000000000003

# %%
# get uncontrolled cost

data.set_parameters(aln)

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    dur = d_array[0]
    aln.params.duration = dur
    
    target_ = aln.getZeroTarget()
    target_[:,0,:] = target[i][0]
    target_[:,1,:] = target[i][1]
            
    cost.setParams(1.0, 0.0, 0.0)

    setinit(initVars[i], aln)
    control0 = aln.getZeroControl()

    # "HS", "FR", "PR", "HZ"
    cgv = None
    max_it = 0

    bestControl_init_, bestState_init_, cost_init_, runtime_init_, grad_init_, phi_init_, phi1_, costnode_init_ = aln.A1(
        control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
        prec_variables_ = p_var, transition_time_ = t_pen[0])
    
    cost_uncontrolled[i] = cost_init_[0]
# Out:
# -------  0 0.4500000000000001 0.4750000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1468888.8173558703
# RUN  0 , total integrated cost =  1468888.8173558703
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1468888.8173558703
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  1 0.47500000000000014 0.6000000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1475251.059202799
# RUN  0 , total integrated cost =  1475251.059202799
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1475251.059202799
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.

# %%
for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    j = 0
    step = step1

    while j < 4799:

        if j == 0:
            j += step
            continue
            
        if not convergence_[i][j-step]:
            if j - step > 0:
                j -= step
                print('go back to -----', j)

        print('-----', j)

        if convergence_[i][j]:
            j += step
            continue

        dur = d_array[j]
        T = 5001 - j
        aln.params.duration = dur

        cost.setParams(1., 0., 1.)
        weights_[i][j] = cost.getParams()

        setinit(initVars[i], aln)

        max_it = 10000

        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        if type(bestControl_[i][j]) == type(None):
            max_percent_prev = (np.argmax(np.abs(bestControl_[i][j-step]), axis=2)[0,1] - 100) / (T-200)
            shift_ind = 0
            if j < 3000:
                while max_percent_prev > max_percent[i]:
                    shift_ind += 1
                    max_percent_prev = (np.argmax(np.abs(bestControl_[i][j-step]), axis=2)[0,1] - 100 - shift_ind) / (T-200)

            control0 = np.zeros(( bestControl_[i][j-step][:,:,100:-(100+step)].shape ))
            print('shift ind = ', shift_ind)
            if shift_ind != 0:
                control0[:,:,:-shift_ind] = 1. * bestControl_[i][j-step][:,:,100+shift_ind:-(100+step)]
            else:
                control0[:,:,:] = 1. * bestControl_[i][j-step][:,:,100:-(100+step)]
                #control0[0,0,:] = 0.
        else:
            if bestControl_[i][j].shape[2] == T+200:
                control0 = bestControl_[i][j][:,:,100:-100]
                #control0[0,1,:] = 0.
            else:
                control0 = bestControl_[i][j][:,:,100:-(100+j)]

        bestControl_[i][j], bestState_[i][j], cost_[i][j], runtime_, grad_, phi_, phi1_, costnode_[i][j] = aln.A1(
            control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
            prec_variables_ = p_var, transition_time_ = t_pen[j])
        
        time_ = np.arange(-dur_pre,round(dur+dur_post+aln.params.dt,1),aln.params.dt)
        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        print(costnode_[i][j][0][0][0], costnode_[i][j][2][0][:2])

        if cost_[i][j][-1] == 0.:
            convergence_[i][j] = True
            if j >= 4400:
                step = step2
            if j >=4790:
                step = step3

        with open(file_,'wb') as f:
            pickle.dump([bestControl_, bestState_, cost_, costnode_, weights_], f)

        j += step
# Out:
# -------  0 0.4500000000000001 0.4750000000000002
# ----- 100
# ----- 200
# ----- 300
# ----- 400
# ----- 500
# ----- 600
# ----- 700
# ----- 800
# set cost params:  1.0 0.0 1.0
# shift ind =  47
# interpolate adjoint :  True True True
# initial cost =  3.331321067746838
# RUN  0 , total integrated cost =  3.331321067746838
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.3312765267221867
# RUN  2 , total integrated cost =  3.3311823396030062
# RUN  3 , total integrated cost =  3.3311772921012563
# RUN  4 , total integrated cost =  3.331176550223975
# RUN  5 , total integrated cost =  3.3311761608781385
# RUN  6 , total integrated cost =  3.331175710062887
# RUN  7 , total integrated cost =  3.331175430180699
# RUN  8 , total integrated cost =  3.331174852938796
# RUN  9 , total integrated cost =  3.331174538710195
# RUN  10 , total integrated cost =  3.3311740305410495
# RUN  11 , total integrated cost =  3.3311737499637983
# RUN  12 , total integrated cost =  3.3311718930926513
# RUN  13 , total integrated cost =  3.3311713701985877
# RUN  14 , total integrated cost =  3.3311707153967025
# RUN  15 , total integrated cost =  3.3311703394264773
# RUN  16 , total integrated cost =  3.331170332997402
# RUN  17 , total integrated cost =  3.3311703277782847
# RUN  18 , total integrated cost =  3.331170322386869
# RUN  19 , total integrated cost =  3.3311703181385255
# RUN  20 , total integrated cost =  3.3311703118678406
# RUN  30 , total integrated cost =  3.3311701361246415
# RUN  40 , total integrated cost =  3.3311701212720553
# RUN  50 , total integrated cost =  3.331170103428137
# RUN  60 , total integrated cost =  3.331170015163445
# RUN  70 , total integrated cost =  3.331169976077068
# RUN  80 , total integrated cost =  3.3311699704525073
# RUN  90 , total integrated cost =  3.33116995698248
# RUN  100 , total integrated cost =  3.3311699134728547
# RUN  110 , total integrated cost =  3.331169906935798
# RUN  120 , total integrated cost =  3.331169894123069
# RUN  130 , total integrated cost =  3.331169892292986
# RUN  140 , total integrated cost =  3.33116988270204
# RUN  150 , total integrated cost =  3.3311698800542766
# RUN  160 , total integrated cost =  3.331169876497154
# RUN  170 , total integrated cost =  3.3311698754618764
# RUN  180 , total integrated cost =  3.3311698726144363
# RUN  190 , total integrated cost =  3.3311698710666526
# RUN  200 , total integrated cost =  3.3311698696920393
# RUN  300 , total integrated cost =  3.331169820569034
# RUN  400 , total integrated cost =  3.3311698126469573
# RUN  500 , total integrated cost =  3.331169810226888
# RUN  600 , total integrated cost =  3.3311698089495447
# RUN  700 , total integrated cost =  3.3311698051671086
# RUN  800 , total integrated cost =  3.3311698028574632
# RUN  900 , total integrated cost =  3.331169801592408
# RUN  1000 , total integrated cost =  3.331169797944559
# RUN  1100 , total integrated cost =  3.3311695253519518
# RUN  1200 , total integrated cost =  3.3311694967352703
# RUN  1300 , total integrated cost =  3.3311694960941387
# RUN  1400 , total integrated cost =  3.3311694954884303
# RUN  1500 , total integrated cost =  3.331169494895994
# RUN  1600 , total integrated cost =  3.3311694943042287
# RUN  1700 , total integrated cost =  3.3311694810624966
# RUN  1800 , total integrated cost =  3.331169474381197
# RUN  1900 , total integrated cost =  3.331169471298526
# RUN  2000 , total integrated cost =  3.33116946946212
# Control only changes marginally.
# RUN  2840 , total integrated cost =  3.33116917735727
# Improved over  2840  iterations in  994.4898859170207  seconds by  0.004559464142886327  percent.
# 2.7927589186588783e-09 [3.87993987e-18 3.33116912e+00]
# ----- 900
# set cost params:  1.0 0.0 1.0
# shift ind =  48
# interpolate adjoint :  True True True
# initial cost =  3.3314229862611837
# RUN  0 , total integrated cost =  3.3314229862611837
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.331350949423149
# RUN  2 , total integrated cost =  3.3312701204672157
# RUN  3 , total integrated cost =  3.3312565662116707
# RUN  4 , total integrated cost =  3.3311853961739843
# RUN  5 , total integrated cost =  3.3311806670287774
# RUN  6 , total integrated cost =  3.331173937314403
# RUN  7 , total integrated cost =  3.3311715399796067
# RUN  8 , total integrated cost =  3.3311715210802064
# RUN  9 , total integrated cost =  3.3311715063333374
# RUN  10 , total integrated cost =  3.331171489271752
# RUN  11 , total integrated cost =  3.3311714749381927
# RUN  12 , total integrated cost =  3.3311714586266303
# RUN  13 , total integrated cost =  3.331171444974665
# RUN  14 , total integrated cost =  3.3311714291731955
# RUN  15 , total integrated cost =  3.331171416578045
# RUN  16 , total integrated cost =  3.3311714016864187
# RUN  17 , total integrated cost =  3.331171389642382
# RUN  18 , total integrated cost =  3.331171375830341
# RUN  19 , total integrated cost =  3.331171364938574
# RUN  20 , total integrated cost =  3.3311713521906072
# RUN  30 , total integrated cost =  3.3311712396062307
# RUN  40 , total integrated cost =  3.3311711247553326
# RUN  50 , total integrated cost =  3.3311709870910975
# RUN  60 , total integrated cost =  3.331170674282409
# RUN  70 , total integrated cost =  3.3311706553823175
# RUN  80 , total integrated cost =  3.3311706205867515
# RUN  90 , total integrated cost =  3.331170499894351
# RUN  100 , total integrated cost =  3.3311704849705532
# RUN  110 , total integrated cost =  3.3311703853413817
# RUN  120 , total integrated cost =  3.331170331258721
# RUN  130 , total integrated cost =  3.3311703232649896
# RUN  140 , total integrated cost =  3.3311703218220297
# RUN  150 , total integrated cost =  3.331170319643233
# RUN  160 , total integrated cost =  3.331170318460561
# RUN  170 , total integrated cost =  3.3311703121137612
# RUN  180 , total integrated cost =  3.3311703106593153
# RUN  190 , total integrated cost =  3.331170308800613
# RUN  200 , total integrated cost =  3.331170278847223
# RUN  300 , total integrated cost =  3.3311702018236193
# RUN  400 , total integrated cost =  3.331170161733085
# RUN  500 , total integrated cost =  3.3311701600548838
# RUN  600 , total integrated cost =  3.3311701576184665
# RUN  700 , total integrated cost =  3.3311701500177247
# RUN  800 , total integrated cost =  3.331170131343112
# RUN  900 , total integrated cost =  3.3311698986998906
# RUN  1000 , total integrated cost =  3.3311697249720176
# RUN  1100 , total integrated cost =  3.331169716164654
# RUN  1200 , total integrated cost =  3.3311697157315963
# RUN  1300 , total integrated cost =  3.3311697149549304
# RUN  1400 , total integrated cost =  3.331169714387401
# RUN  1500 , total integrated cost =  3.331169583139146
# RUN  1600 , total integrated cost =  3.331169582758454
# RUN  1700 , total integrated cost =  3.3311694923908326
# RUN  1800 , total integrated cost =  3.331169474580647
# RUN  1900 , total integrated cost =  3.3311694720241203
# RUN  2000 , total integrated cost =  3.3311694667267293
# Control only changes marginally.
# RUN  2756 , total integrated cost =  3.3311693326840466
# Improved over  2756  iterations in  811.0633646869974  seconds by  0.007613970912217383  percent.
# 3.913573609665467e-09 [3.87993987e-18 3.33116925e+00]
# ----- 1000
# set cost params:  1.0 0.0 1.0
# shift ind =  47
# interpolate adjoint :  True True True
# initial cost =  3.3316305456884314
# RUN  0 , total integrated cost =  3.3316305456884314
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.3314991138922077
# RUN  2 , total integrated cost =  3.3312804558456435
# RUN  3 , total integrated cost =  3.3312555393729704
# RUN  4 , total integrated cost =  3.331172712885252
# RUN  5 , total integrated cost =  3.3311725966461014
# RUN  6 , total integrated cost =  3.3311725781576444
# RUN  7 , total integrated cost =  3.331172557060103
# RUN  8 , total integrated cost =  3.3311725376466654
# RUN  9 , total integrated cost =  3.331172515199409
# RUN  10 , total integrated cost =  3.331172498517879
# RUN  11 , total integrated cost =  3.3311724803589295
# RUN  12 , total integrated cost =  3.3311724632723894
# RUN  13 , total integrated cost =  3.33117244329232
# RUN  14 , total integrated cost =  3.331172429152764
# RUN  15 , total integrated cost =  3.3311724125071596
# RUN  16 , total integrated cost =  3.3311723978821863
# RUN  17 , total integrated cost =  3.3311723811559797
# RUN  18 , total integrated cost =  3.331172367809465
# RUN  19 , total integrated cost =  3.3311723523618393
# RUN  20 , total integrated cost =  3.3311723394342043
# RUN  30 , total integrated cost =  3.331172228877457
# RUN  40 , total integrated cost =  3.3311721311866367
# RUN  50 , total integrated cost =  3.3311720074481634
# RUN  60 , total integrated cost =  3.331171417440398
# RUN  70 , total integrated cost =  3.3311712579734456
# RUN  80 , total integrated cost =  3.331171136979922
# RUN  90 , total integrated cost =  3.331171096722287
# RUN  100 , total integrated cost =  3.331171074351179
# RUN  110 , total integrated cost =  3.3311710710276206
# RUN  120 , total integrated cost =  3.3311710405379333
# RUN  130 , total integrated cost =  3.3311710392694756
# RUN  140 , total integrated cost =  3.331171038033398
# RUN  150 , total integrated cost =  3.331171036776216
# RUN  160 , total integrated cost =  3.3311710331143094
# RUN  170 , total integrated cost =  3.331170960795615
# RUN  180 , total integrated cost =  3.3311709600924546
# RUN  190 , total integrated cost =  3.3311709553406126
# RUN  200 , total integrated cost =  3.3311709342023663
# RUN  300 , total integrated cost =  3.3311707641675126
# RUN  400 , total integrated cost =  3.331170758817955
# RUN  500 , total integrated cost =  3.331170619836654
# RUN  600 , total integrated cost =  3.3311706179292724
# RUN  700 , total integrated cost =  3.331170615785363
# RUN  800 , total integrated cost =  3.331170608579122
# RUN  900 , total integrated cost =  3.3311706006115305
# RUN  1000 , total integrated cost =  3.3311699624912494
# RUN  1100 , total integrated cost =  3.3311699455138104
# RUN  1200 , total integrated cost =  3.331169930897346
# RUN  1300 , total integrated cost =  3.3311699256031178
# RUN  1400 , total integrated cost =  3.3311699248150224
# RUN  1500 , total integrated cost =  3.331169924099481
# RUN  1600 , total integrated cost =  3.3311699178475283
# RUN  1700 , total integrated cost =  3.331169915155154
# RUN  1800 , total integrated cost =  3.3311698887191326
# RUN  1900 , total integrated cost =  3.3311698791099484
# RUN  2000 , total integrated cost =  3.3311698649922925
# RUN  3000 , total integrated cost =  3.3311698162073506
# Control only changes marginally.
# RUN  3934 , total integrated cost =  3.3311695384082194
# Improved over  3934  iterations in  1355.916840216989  seconds by  0.013837286994757392  percent.
# 5.939642345912699e-09 [3.87993986e-18 3.33116942e+00]
# ----- 1100
# set cost params:  1.0 0.0 1.0
# shift ind =  48
# interpolate adjoint :  True True True
# initial cost =  3.3321797448196397
# RUN  0 , total integrated cost =  3.3321797448196397
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.331903609116319
# RUN  2 , total integrated cost =  3.3311938667144347
# RUN  3 , total integrated cost =  3.3311835620402834
# RUN  4 , total integrated cost =  3.3311809147449187
# RUN  5 , total integrated cost =  3.331177633141952
# RUN  6 , total integrated cost =  3.331175115588463
# RUN  7 , total integrated cost =  3.331173887336605
# RUN  8 , total integrated cost =  3.33117384377228
# RUN  9 , total integrated cost =  3.331173809069286
# RUN  10 , total integrated cost =  3.331173685032568
# RUN  11 , total integrated cost =  3.3311735905042728
# RUN  12 , total integrated cost =  3.3311726222483857
# RUN  13 , total integrated cost =  3.3311725142117967
# RUN  14 , total integrated cost =  3.3311725116518427
# RUN  15 , total integrated cost =  3.331172508687475
# RUN  16 , total integrated cost =  3.3311725065751783
# RUN  17 , total integrated cost =  3.3311725041088542
# RUN  18 , total integrated cost =  3.331172502348687
# RUN  19 , total integrated cost =  3.331172500082678
# RUN  20 , total integrated cost =  3.3311724983151016
# RUN  30 , total integrated cost =  3.3311724624942016
# RUN  40 , total integrated cost =  3.3311723140856047
# RUN  50 , total integrated cost =  3.3311721863273767
# RUN  60 , total integrated cost =  3.3311721327656847
# RUN  70 , total integrated cost =  3.3311720994378495
# RUN  80 , total integrated cost =  3.331172093884356
# RUN  90 , total integrated cost =  3.33117201284127
# RUN  100 , total integrated cost =  3.3311719823654817
# RUN  110 , total integrated cost =  3.331171980230763
# RUN  120 , total integrated cost =  3.331171976683453
# RUN  130 , total integrated cost =  3.3311719735348237
# RUN  140 , total integrated cost =  3.3311719716481276
# RUN  150 , total integrated cost =  3.33117196945531
# RUN  160 , total integrated cost =  3.3311719666182076
# RUN  170 , total integrated cost =  3.3311719645048394
# RUN  180 , total integrated cost =  3.3311719627640435
# RUN  190 , total integrated cost =  3.3311719599606295
# RUN  200 , total integrated cost =  3.3311719579405197
# RUN  300 , total integrated cost =  3.331171697221569
# RUN  400 , total integrated cost =  3.3311715657043752
# RUN  500 , total integrated cost =  3.331171551658201
# RUN  600 , total integrated cost =  3.3311715000471014
# RUN  700 , total integrated cost =  3.3311714444740357
# RUN  800 , total integrated cost =  3.331171414229269
# RUN  900 , total integrated cost =  3.331171412036633
# RUN  1000 , total integrated cost =  3.3311714065360136
# RUN  1100 , total integrated cost =  3.3311713642502228
# RUN  1200 , total integrated cost =  3.3311713466166766
# RUN  1300 , total integrated cost =  3.331171339385029
# RUN  1400 , total integrated cost =  3.3311713353285026
# RUN  1500 , total integrated cost =  3.3311711819807255
# RUN  1600 , total integrated cost =  3.3311711662281245
# RUN  1700 , total integrated cost =  3.331171158492397
# RUN  1800 , total integrated cost =  3.331171085786266
# RUN  1900 , total integrated cost =  3.331171078534175
# RUN  2000 , total integrated cost =  3.3311710521480844
# RUN  3000 , total integrated cost =  3.331170384235618
# RUN  4000 , total integrated cost =  3.3311702851945673
# Control only changes marginally.
# RUN  4567 , total integrated cost =  3.3311701601116077
# Improved over  4567  iterations in  1422.2937438400113  seconds by  0.030298026677627377  percent.
# 8.452605770523688e-09 [3.87993985e-18 3.33117000e+00]
# ----- 1200
# set cost params:  1.0 0.0 1.0
# shift ind =  48
# interpolate adjoint :  True True True
# initial cost =  3.332662856956437
# RUN  0 , total integrated cost =  3.332662856956437
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.3322527437881555
# RUN  2 , total integrated cost =  3.3311875342462263
# RUN  3 , total integrated cost =  3.331184844945903
# RUN  4 , total integrated cost =  3.331183524226526
# RUN  5 , total integrated cost =  3.331181616816014
# RUN  6 , total integrated cost =  3.331180295066866
# RUN  7 , total integrated cost =  3.3311787024359125
# RUN  8 , total integrated cost =  3.331175456891859
# RUN  9 , total integrated cost =  3.3311751787256383
# RUN  10 , total integrated cost =  3.331175160066567
# RUN  11 , total integrated cost =  3.331175139867172
# RUN  12 , total integrated cost =  3.331175124747518
# RUN  13 , total integrated cost =  3.331175107260941
# RUN  14 , total integrated cost =  3.3311750915475593
# RUN  15 , total integrated cost =  3.3311750742392188
# RUN  16 , total integrated cost =  3.3311750595291807
# RUN  17 , total integrated cost =  3.331175042842129
# RUN  18 , total integrated cost =  3.3311750287413435
# RUN  19 , total integrated cost =  3.3311750129611593
# RUN  20 , total integrated cost =  3.3311749986029784
# RUN  30 , total integrated cost =  3.3311748598150217
# RUN  40 , total integrated cost =  3.331174743701956
# RUN  50 , total integrated cost =  3.331174667904726
# RUN  60 , total integrated cost =  3.331174614969217
# RUN  70 , total integrated cost =  3.3311740919471675
# RUN  80 , total integrated cost =  3.3311740668193806
# RUN  90 , total integrated cost =  3.3311740049444487
# RUN  100 , total integrated cost =  3.3311739509104044
# RUN  110 , total integrated cost =  3.3311739355053667
# RUN  120 , total integrated cost =  3.3311739188544975
# RUN  130 , total integrated cost =  3.331173904653811
# RUN  140 , total integrated cost =  3.3311738934592516
# RUN  150 , total integrated cost =  3.331173881996908
# RUN  160 , total integrated cost =  3.3311738709531125
# RUN  170 , total integrated cost =  3.3311738605328505
# RUN  180 , total integrated cost =  3.3311738409470406
# RUN  190 , total integrated cost =  3.3311738219331923
# RUN  200 , total integrated cost =  3.3311738052925772
# RUN  300 , total integrated cost =  3.3311735030002256
# RUN  400 , total integrated cost =  3.3311729336641918
# RUN  500 , total integrated cost =  3.331172838374885
# RUN  600 , total integrated cost =  3.3311728078634384
# RUN  700 , total integrated cost =  3.3311721189886683
# RUN  800 , total integrated cost =  3.331172102164244
# RUN  900 , total integrated cost =  3.331171724417433
# RUN  1000 , total integrated cost =  3.33117169855597
# RUN  1100 , total integrated cost =  3.3311716673462626
# RUN  1200 , total integrated cost =  3.331171645287475
# RUN  1300 , total integrated cost =  3.3311716253986967
# RUN  1400 , total integrated cost =  3.33117161191634
# RUN  1500 , total integrated cost =  3.331171609066557
# RUN  1600 , total integrated cost =  3.33117160806454
# RUN  1700 , total integrated cost =  3.3311716070587103
# RUN  1800 , total integrated cost =  3.3311716060643684
# RUN  1900 , total integrated cost =  3.3311716050711175
# RUN  2000 , total integrated cost =  3.331171603104455
# RUN  3000 , total integrated cost =  3.3311715640773185
# RUN  4000 , total integrated cost =  3.331171404736557
# RUN  5000 , total integrated cost =  3.3311711675157354
# RUN  6000 , total integrated cost =  3.331170915228479
# Control only changes marginally.
# RUN  6856 , total integrated cost =  3.331170863040312
# Improved over  6856  iterations in  1937.8064494160062  seconds by  0.044768822415107934  percent.
# 1.2206958954393567e-08 [3.87993983e-18 3.33117063e+00]
# ----- 1300
# set cost params:  1.0 0.0 1.0
# shift ind =  47
# interpolate adjoint :  True True True
# initial cost =  3.33429084867489
# RUN  0 , total integrated cost =  3.33429084867489
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.3334330553852873
# RUN  2 , total integrated cost =  3.3311971880980757
# RUN  3 , total integrated cost =  3.3311917405114215
# RUN  4 , total integrated cost =  3.33118656805495
# RUN  5 , total integrated cost =  3.33118442331065
# RUN  6 , total integrated cost =  3.3311824780377135
# RUN  7 , total integrated cost =  3.3311814170294296
# RUN  8 , total integrated cost =  3.3311812006652364
# RUN  9 , total integrated cost =  3.3311809380022126
# RUN  10 , total integrated cost =  3.3311802161171884
# RUN  11 , total integrated cost =  3.331179421785091
# RUN  12 , total integrated cost =  3.331179386465527
# RUN  13 , total integrated cost =  3.331179347993917
# RUN  14 , total integrated cost =  3.3311793166184085
# RUN  15 , total integrated cost =  3.331179280141878
# RUN  16 , total integrated cost =  3.331179249697832
# RUN  17 , total integrated cost =  3.3311792145063084
# RUN  18 , total integrated cost =  3.331179185225565
# RUN  19 , total integrated cost =  3.3311791509921127
# RUN  20 , total integrated cost =  3.3311791230101466
# RUN  30 , total integrated cost =  3.3311788628226537
# RUN  40 , total integrated cost =  3.3311781976748613
# RUN  50 , total integrated cost =  3.3311771565385535
# RUN  60 , total integrated cost =  3.331177046153857
# RUN  70 , total integrated cost =  3.3311769666004656
# RUN  80 , total integrated cost =  3.3311768101258385
# RUN  90 , total integrated cost =  3.331176638812919
# RUN  100 , total integrated cost =  3.3311765962555384
# RUN  110 , total integrated cost =  3.331176554885677
# RUN  120 , total integrated cost =  3.3311764067912537
# RUN  130 , total integrated cost =  3.331176356367357
# RUN  140 , total integrated cost =  3.331176324263548
# RUN  150 , total integrated cost =  3.331176261078084
# RUN  160 , total integrated cost =  3.3311759542496415
# RUN  170 , total integrated cost =  3.3311757715060493
# RUN  180 , total integrated cost =  3.331175747931351
# RUN  190 , total integrated cost =  3.3311757111323037
# RUN  200 , total integrated cost =  3.331175706457635
# RUN  300 , total integrated cost =  3.331175027085204
# RUN  400 , total integrated cost =  3.331174867707657
# RUN  500 , total integrated cost =  3.331174753492211
# RUN  600 , total integrated cost =  3.331174419012032
# RUN  700 , total integrated cost =  3.331174395665157
# RUN  800 , total integrated cost =  3.3311743928106434
# RUN  900 , total integrated cost =  3.331174383563021
# RUN  1000 , total integrated cost =  3.331174370892039
# RUN  1100 , total integrated cost =  3.331174367513398
# RUN  1200 , total integrated cost =  3.331172813653225
# RUN  1300 , total integrated cost =  3.3311728047252624
# RUN  1400 , total integrated cost =  3.331172801329275
# RUN  1500 , total integrated cost =  3.3311727964707534
# RUN  1600 , total integrated cost =  3.3311727939730567
# RUN  1700 , total integrated cost =  3.331172793136985
# RUN  1800 , total integrated cost =  3.3311727888506977
# RUN  1900 , total integrated cost =  3.3311727872682297
# RUN  2000 , total integrated cost =  3.331172784765274
# Control only changes marginally.
# RUN  2751 , total integrated cost =  3.3311706333410376
# Improved over  2751  iterations in  1171.4459159449907  seconds by  0.09357957885085  percent.
# 1.9169947790952354e-08 [3.87993980e-18 3.33117028e+00]
# ----- 1400
# set cost params:  1.0 0.0 1.0
# shift ind =  48
# interpolate adjoint :  True True True
# initial cost =  3.3435374932991087
# RUN  0 , total integrated cost =  3.3435374932991087
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.3403823417144354
# RUN  2 , total integrated cost =  3.3312774131028062
# RUN  3 , total integrated cost =  3.3312523454179948
# RUN  4 , total integrated cost =  3.3312505784353514
# RUN  5 , total integrated cost =  3.331247835258141
# RUN  6 , total integrated cost =  3.331246229833585
# RUN  7 , total integrated cost =  3.3312437845867464
# RUN  8 , total integrated cost =  3.3312423227839028
# RUN  9 , total integrated cost =  3.3312401477541216
# RUN  10 , total integrated cost =  3.3312388064278005
# RUN  11 , total integrated cost =  3.3312368059708386
# RUN  12 , total integrated cost =  3.3312355635189697
# RUN  13 , total integrated cost =  3.331233776291519
# RUN  14 , total integrated cost =  3.331232645985478
# RUN  15 , total integrated cost =  3.3312310464469403
# RUN  16 , total integrated cost =  3.3312300044494108
# RUN  17 , total integrated cost =  3.3312285351081674
# RUN  18 , total integrated cost =  3.331227546581989
# RUN  19 , total integrated cost =  3.331226203439839
# RUN  20 , total integrated cost =  3.331225266872825
# RUN  30 , total integrated cost =  3.3312156420403816
# RUN  40 , total integrated cost =  3.3312078896514703
# RUN  50 , total integrated cost =  3.3311937753995027
# RUN  60 , total integrated cost =  3.3311863685633765
# RUN  70 , total integrated cost =  3.331182982685554
# RUN  80 , total integrated cost =  3.3311796591155716
# RUN  90 , total integrated cost =  3.331179607309955
# RUN  100 , total integrated cost =  3.331178821470144
# RUN  110 , total integrated cost =  3.3311785397083065
# RUN  120 , total integrated cost =  3.3311784679108944
# RUN  130 , total integrated cost =  3.3311783942947213
# RUN  140 , total integrated cost =  3.331178282529321
# RUN  150 , total integrated cost =  3.331178244258088
# RUN  160 , total integrated cost =  3.3311781725901795
# RUN  170 , total integrated cost =  3.3311781527355224
# RUN  180 , total integrated cost =  3.3311781203110247
# RUN  190 , total integrated cost =  3.3311781048180604
# RUN  200 , total integrated cost =  3.331177987636073
# RUN  300 , total integrated cost =  3.331177794411444
# RUN  400 , total integrated cost =  3.331177166501276
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_73554/634243386.py in <module>
#      66                 control0 = bestControl_[i][j][:,:,100:-(100+j)]
#      67
# ---> 68         bestControl_[i][j], bestState_[i][j], cost_[i][j], runtime_, grad_, phi_, phi1_, costnode_[i][j] = aln.A1(
#      69             control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
#      70             startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
#
# ~/Promotion/neurolib/neurolib/models/model.py in A1(self, control_, target_state_, c_scheme_, u_mat_, u_scheme_, max_iteration_, tolerance_, startStep_, max_control_, min_control_, t_sim_, t_sim_pre_, t_sim_post_, CGVar, line_search_, control_variables_, prec_variables_, separate_comp, transition_time_, noise_real, init_params)
#     661             if self.params.N == 1:
#     662                 if noise_real == 0:
# --> 663                     return opti1_rate_control.A1(self, control_, target_state_, c_scheme_, u_mat_, u_scheme_, max_iteration_,
#     664                                                 tolerance_, startStep_, max_control_, min_control_, t_sim_, t_sim_pre_, t_sim_post_, CGVar,
#     665                                                 line_search_, control_variables_, prec_variables_, separate_comp, transition_time_)
#
# ~/Promotion/neurolib/neurolib/utils/A1_aln_rate_control.py in A1(model, control_, target_state, c_scheme_, u_mat_, u_scheme_, max_iteration_, tolerance_, startStep_, cntrl_max_, cntrl_min_, t_sim_, t_sim_pre_, t_sim_post_, CGVar, line_search_, control_variables_, prec_variables_, separate_comp, transition_time_)
#     483
#     484
# --> 485         step_, total_cost_[i], startStep_ = line_search_func(model, N, n_control_vars, T, dt, state1_[:,:2,:], target_state_,
#     486                      best_control_, dir0_, ip_, ie_, is_, start_step_ = startStep_, max_it_ = 500, max_control_ = cntrl_max_,
#     487                          min_control_ = cntrl_min_, tolerance_ = tolerance_step, variables_ = prec_variables, grad_ = grad1_)
#
# ~/Promotion/neurolib/neurolib/utils/func_optimize.py in step_size(model, N, V, T, dt, state_, target_, control_, dir_, ip_, ie_, is_, start_step_, max_it_, bisec_factor_, max_control_, min_control_, tolerance_, substep_, variables_, alg, control_parameter, grad_, noise_real, init_vars, startind_)
#     233                 #print(init_vars)
#     234                 set_init(model, init_vars, model.init_vars, model.state_vars, startind_)
# --> 235             state1_ = updateState(model, test_control_)
#     236             cost1_int_ = cost.f_int(N, V, T, dt, state1_, target_, test_control_, ip_, ie_, is_, v_ = variables_)
#     237         else:
#
# ~/Promotion/neurolib/neurolib/utils/func_optimize.py in updateState(model, control_)
#       8     state_ = model.getZeroState()
#       9     output_vars = model.output_vars
# ---> 10     model.run(control = control_)
#      11     for i in range(len(output_vars)):
#      12         state_[:,i,:] = model[output_vars[i]][:,:]
#
# ~/Promotion/neurolib/neurolib/models/model.py in run(self, inputs, chunkwise, chunksize, bold, append, append_outputs, continue_run, control)
#     182
#     183         if chunkwise is False:
# --> 184             self.integrate(append_outputs=append, simulate_bold=bold, control=cntrl)
#     185             if continue_run:
#     186                 self.setInitialValuesToLastState()
#
# ~/Promotion/neurolib/neurolib/models/model.py in integrate(self, append_outputs, simulate_bold, control)
#     223         # run integration
#     224         #print("before integration")
# --> 225         t, *variables = self.integration(self.params, control=control)
#     226         #print("after integration")
#     227         self.storeOutputsAndStates(t, variables, append=append_outputs)
#
# ~/Promotion/neurolib/neurolib/models/aln/timeIntegration.py in timeIntegration(params, control)
#     271     # tile external inputs to appropriate shape
#     272     ext_exc_current = adjust_shape(params["ext_exc_current"], rates_exc)
# --> 273     ext_inh_current = adjust_shape(params["ext_inh_current"], rates_exc)
#     274     ext_ee_rate = adjust_shape(params["ext_ee_rate"], rates_exc)
#     275     ext_ei_rate = adjust_shape(params["ext_ei_rate"], rates_exc)
#
# ~/Promotion/neurolib/neurolib/models/aln/timeIntegration.py in adjust_shape(original, target)
#     925     else:
#     926         rep_x = 1
# --> 927     original = np.tile(original, (1, rep_x))
#     928
#     929     # cut from end because the beginning can be initial condition
#
# <__array_function__ internals> in tile(*args, **kwargs)
#
# ~/.local/lib/python3.9/site-packages/numpy/lib/shape_base.py in tile(A, reps)
#    1256         for dim_in, nrep in zip(c.shape, tup):
#    1257             if nrep != 1:
# -> 1258                 c = c.reshape(-1, n).repeat(nrep, 0)
#    1259             n //= dim_in
#    1260     return c.reshape(shape_out)
#
# KeyboardInterrupt:

# %%
bestControl_maxW = np.array( [[None] * len(t_pen)] * len(exc) )
bestState_maxW = np.array( [[None] * len(t_pen)] * len(exc) )
cost_maxW = np.array( [[None] * len(t_pen)] * len(exc) )
costnode_maxW = np.array( [[None] * len(t_pen)] * len(exc) )
weights_maxW = np.array( [[None] * len(t_pen)] * len(exc) )
convergence_maxW = np.array( [[None] * len(t_pen)] * len(exc) )

file_maxW = 'down_Wmax.pickle'

# %%
if os.path.isfile(file_maxW) :
    print("file found")
    
    with open(file_maxW,'rb') as f:
        load_array = pickle.load(f)

    bestControl_maxW = load_array[0]
    bestState_maxW = load_array[1]
    cost_maxW = load_array[2]
    costnode_maxW = load_array[3]
    weights_maxW = load_array[4]

# %%
for i in i_range:
    print('------------', i)
    j = 0

    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.

    aln.params.duration = dur

    while not convergence_maxW[i][j]:
        dur = d_array[j]
        aln.params.duration = dur

        setinit(initVars[i], aln)

        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        control0 = aln.getZeroControl()
        if type(bestControl_maxW[i][j]) == type(None):
            max_it = 10
            control0 = bestControl_[i][0][:,:,n_pre-1:-n_post+1]
            weight_ = ( cost_uncontrolled[i] * (1. - t_pen[0]) / (1. - t_pen[j]) 
                       - sum(costnode_[i][j][0][0][:]) ) / sum( costnode_[i][j][2][0][:] )
            cost.setParams(1., weight_ * factor_we, weight_ * factor_ws)
            weights_maxW[i][j] = cost.getParams()
        else:
            control0 = bestControl_maxW[i][j][:,:,n_pre-1:-n_post+1]
            weight_ = ( cost_uncontrolled[i] * (1. - t_pen[0]) / (1. - t_pen[j])
                       - sum(costnode_maxW[i][j][0][0][:]) ) / sum( costnode_maxW[i][j][2][0][:] )
            cost.setParams(1., weight_ * factor_we, weight_ * factor_ws)
            weights_maxW[i][j] = cost.getParams()
            max_it = int(100)

        bestControl_maxW[i][j], bestState_maxW[i][j], cost_maxW[i][j], runtime_, grad_, phi_, phi1_, costnode_maxW[i][j] = aln.A1(
            control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
            prec_variables_ = p_var, transition_time_ = t_pen[j])

        if cost_maxW[i][j][2] == 0.:
            convergence_maxW[i][j] = True

        print('cost splitting : ', costnode_maxW[i][j][0][0][0], costnode_maxW[i][j][2][0][:2])

        with open(file_maxW,'wb') as f:
            pickle.dump([bestControl_maxW, bestState_maxW, cost_maxW, costnode_maxW, weights_maxW], f)
# Out:
# ------------ 0
# set cost params:  1.0 0.0 440952.9224536757
# interpolate adjoint :  True True True
# initial cost =  1468888.81735589
# RUN  0 , total integrated cost =  1468888.81735589
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1468888.7940168614
# RUN  2 , total integrated cost =  1468888.793694043
# RUN  3 , total integrated cost =  1468888.793693076
# RUN  4 , total integrated cost =  1468888.793693076
# Control only changes marginally.
# RUN  4 , total integrated cost =  1468888.793693076
# Improved over  4  iterations in  1.5178786350006703  seconds by  1.61093296924264e-06  percent.
# cost splitting :  1.885135683576661e-05 [3.88250122e-18 3.33116920e+00]
# set cost params:  1.0 0.0 440952.9297581056
# interpolate adjoint :  True True True
# initial cost =  1468888.8180253676
# RUN  0 , total integrated cost =  1468888.8180253676
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1468888.8180253676
# Control only changes marginally.
# RUN  1 , total integrated cost =  1468888.8180253676
# Improved over  1  iterations in  0.4240929090010468  seconds by  0.0  percent.
# cost splitting :  1.885135683576661e-05 [3.88250122e-18 3.33116920e+00]
# ------------ 1
# set cost params:  1.0 0.0 294679.3073488042
# interpolate adjoint :  True True True
# initial cost =  1475251.0595766376
# RUN  0 , total integrated cost =  1475251.0595766376
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1475251.0589242058
# RUN  2 , total integrated cost =  1475251.0588844754
# RUN  3 , total integrated cost =  1475251.0588843778
# RUN  4 , total integrated cost =  1475251.0588843778
# Control only changes marginally.
# RUN  4 , total integrated cost =  1475251.0588843778
# Improved over  4  iterations in  1.462294454977382  seconds by  4.69248817580592e-08  percent.
# cost splitting :  8.982382641942008e-06 [5.00629335e+00 2.56353618e-12]
# set cost params:  1.0 0.0 294679.30754479213
# interpolate adjoint :  True True True
# initial cost =  1475251.0598655508
# RUN  0 , total integrated cost =  1475251.0598655508
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1475251.0598655508
# Control only changes marginally.
# RUN  1 , total integrated cost =  1475251.0598655508
# Improved over  1  iterations in  0.4069266229926143  seconds by  0.0  percent.
# cost splitting :  8.982382641942008e-06 [5.00629335e+00 2.56353618e-12]

# %%
for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    j = 0
    step = step1

    while j < 4800:

        if j == 0:
            j += step
            continue
            
        if not convergence_maxW[i][j-step]:
            if j - step > 0:
                j -= step
                print('go back to -----', j)

        print('-----', j)

        if convergence_maxW[i][j]:
            j += step
            continue

        dur = d_array[j]
        T = 5001 - j
        aln.params.duration = dur
        setinit(initVars[i], aln)

        max_it = 1000

        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        if type(bestControl_maxW[i][j]) == type(None):
            max_percent_prev = (np.argmax(np.abs(bestControl_maxW[i][j-step]), axis=2)[0,1] - 100) / (T-200)
            shift_ind = 0
            if j < 4000:
                while max_percent_prev > max_percent[i]:
                    shift_ind += 1
                    max_percent_prev = (np.argmax(np.abs(bestControl_maxW[i][j-step]), axis=2)[0,1] - 100 - shift_ind) / (T-200)

            control0 = np.zeros(( bestControl_maxW[i][j-step][:,:,100:-(100+step)].shape ))
            print('shift ind = ', shift_ind)
            if shift_ind != 0:
                control0[:,:,:-shift_ind] = 1. * bestControl_maxW[i][j-step][:,:,100+shift_ind:-(100+step)]
            else:
                control0[:,:,:] = 1. * bestControl_maxW[i][j-step][:,:,100:-(100+step)]
                
            weight_ = ( cost_uncontrolled[i] * (1. - t_pen[0]) / (1. - t_pen[j])
                          - sum(costnode_maxW[i][j-step][0][0][:]) ) / sum( costnode_maxW[i][j-step][2][0][:] )
            cost.setParams(1., weight_ * factor_we, weight_ * factor_ws)
            weights_maxW[i][j] = cost.getParams()
        
        else:
            if bestControl_maxW[i][j].shape[2] == T+200:
                control0 = bestControl_maxW[i][j][:,:,100:-100]
                #control0[0,1,:] = 0.
            else:
                control0 = bestControl_maxW[i][j][:,:,100:-(100+j)]
                
                weight_ = ( cost_uncontrolled[i] * (1. - t_pen[0]) / (1. - t_pen[j])
                           - sum(costnode_maxW[i][j][0][0][:]) ) / sum( costnode_maxW[i][j][2][0][:] )
                cost.setParams(1., weight_ * factor_we, weight_ * factor_ws)
                weights_maxW[i][j] = cost.getParams()

        bestControl_maxW[i][j], bestState_maxW[i][j], cost_maxW[i][j], runtime_, grad_, phi_, phi1_, costnode_maxW[i][j] = aln.A1(
            control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
            prec_variables_ = p_var, transition_time_ = t_pen[j])

        print(costnode_maxW[i][j][0][0][:2], costnode_maxW[i][j][2][0][:2])

        if cost_maxW[i][j][2] == 0.:
            convergence_maxW[i][j] = True
            if j >= 4400:
                step = step2
            if j >=4790:
                step = step3

        with open(file_maxW,'wb') as f:
            pickle.dump([bestControl_maxW, bestState_maxW, cost_maxW, costnode_maxW, weights_maxW], f)

        j += step
# Out:
# -------  0 0.4500000000000001 0.4750000000000002
# ----- 100
# ----- 200
# ----- 300
# ----- 400
# ----- 500
# ----- 600
# ----- 700
# ----- 800
# ----- 900
# ----- 1000
# ----- 1100
# ----- 1200
# ----- 1300
# ----- 1400
# ----- 1500
# ----- 1600
# ----- 1700
# ----- 1800
# ----- 1900
# ----- 2000
# ----- 2100
# ----- 2200
# ----- 2300
# ----- 2400
# ----- 2500
# ----- 2600
# ----- 2700
# ----- 2800
# ----- 2900
# ----- 3000
# ----- 3100
# ----- 3200
# ----- 3300
# ----- 3400
# ----- 3500
# ----- 3600
# ----- 3700
# ----- 3800
# ----- 3900
# ----- 4000
# ----- 4100
# ----- 4200
# ----- 4300
# ----- 4400
# ----- 4500
# ----- 4600
# ----- 4700
# -------  1 0.47500000000000014 0.6000000000000003
# ----- 100
# shift ind =  53
# set cost params:  1.0 0.0 288785.72139378457
# interpolate adjoint :  True True True
# initial cost =  1445746.0608597691
# RUN  0 , total integrated cost =  1445746.0608597691
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1445746.0425533094
# RUN  2 , total integrated cost =  1445746.0425526241
# RUN  3 , total integrated cost =  1445746.042552622
# RUN  4 , total integrated cost =  1445746.042552622
# Control only changes marginally.
# RUN  4 , total integrated cost =  1445746.042552622
# Improved over  4  iterations in  4.10789944298449  seconds by  1.2662768114068967e-06  percent.
# [5.13272114e-05 2.18037638e-05] [5.00629336e+00 2.56348845e-12]
# go back to ----- 100
# ----- 100
# interpolate adjoint :  True True True
# initial cost =  1445746.042552622
# RUN  0 , total integrated cost =  1445746.042552622
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1445746.042552622
# Control only changes marginally.
# RUN  1 , total integrated cost =  1445746.042552622
# Improved over  1  iterations in  1.0979340969934128  seconds by  0.0  percent.
# [5.13272114e-05 2.18037638e-05] [5.00629336e+00 2.56348845e-12]
# ----- 200
# shift ind =  53
# set cost params:  1.0 0.0 282892.13469004165
# interpolate adjoint :  True True True
# initial cost =  1416241.0415731403
# RUN  0 , total integrated cost =  1416241.0415731403
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1416241.0233632885
# RUN  2 , total integrated cost =  1416241.0233583164
# RUN  3 , total integrated cost =  1416241.0233583164
# Control only changes marginally.
# RUN  3 , total integrated cost =  1416241.0233583164
# Improved over  3  iterations in  3.0835787119867746  seconds by  1.2861386835538724e-06  percent.
# [8.51557991e-05 2.75120332e-05] [5.00629338e+00 2.56323447e-12]
# go back to ----- 200
# ----- 200
# interpolate adjoint :  True True True
# initial cost =  1416241.0233583164
# RUN  0 , total integrated cost =  1416241.0233583164
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1416241.0233583164
# Control only changes marginally.
# RUN  1 , total integrated cost =  1416241.0233583164
# Improved over  1  iterations in  1.1283392870100215  seconds by  0.0  percent.
# [8.51557991e-05 2.75120332e-05] [5.00629338e+00 2.56323447e-12]
# ----- 300
# shift ind =  52
# set cost params:  1.0 0.0 276998.54777857027
# interpolate adjoint :  True True True
# initial cost =  1386736.0265029294
# RUN  0 , total integrated cost =  1386736.0265029294
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1386736.0037972943
# RUN  2 , total integrated cost =  1386736.003796036
# RUN  3 , total integrated cost =  1386736.0037960329
# RUN  4 , total integrated cost =  1386736.0037960329
# Control only changes marginally.
# RUN  4 , total integrated cost =  1386736.0037960329
# Improved over  4  iterations in  3.8797843529901  seconds by  1.6374346785141825e-06  percent.
# [1.01940254e-04 3.78508792e-05] [5.00629340e+00 2.56267316e-12]
# go back to ----- 300
# ----- 300
# interpolate adjoint :  True True True
# initial cost =  1386736.0037960329
# RUN  0 , total integrated cost =  1386736.0037960329
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1386736.0037960329
# Control only changes marginally.
# RUN  1 , total integrated cost =  1386736.0037960329
# Improved over  1  iterations in  1.1019070989859756  seconds by  0.0  percent.
# [1.01940254e-04 3.78508792e-05] [5.00629340e+00 2.56267316e-12]
# ----- 400
# shift ind =  53
# set cost params:  1.0 0.0 271104.9606744507
# interpolate adjoint :  True True True
# initial cost =  1357231.0144878784
# RUN  0 , total integrated cost =  1357231.0144878784
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1357230.985962104
# RUN  2 , total integrated cost =  1357230.9859409148
# RUN  3 , total integrated cost =  1357230.9859409116
# RUN  4 , total integrated cost =  1357230.9859409116
# Control only changes marginally.
# RUN  4 , total integrated cost =  1357230.9859409116
# Improved over  4  iterations in  3.7711432549986057  seconds by  2.10332407846181e-06  percent.
# [1.37230649e-04 5.48118231e-05] [5.00629342e+00 2.56247557e-12]
# go back to ----- 400
# ----- 400
# interpolate adjoint :  True True True
# initial cost =  1357230.9859409116
# RUN  0 , total integrated cost =  1357230.9859409116
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1357230.9859409116
# Control only changes marginally.
# RUN  1 , total integrated cost =  1357230.9859409116
# Improved over  1  iterations in  1.0900261409988161  seconds by  0.0  percent.
# [1.37230649e-04 5.48118231e-05] [5.00629342e+00 2.56247557e-12]
# ----- 500
# shift ind =  53
# set cost params:  1.0 0.0 265211.3731513059
# interpolate adjoint :  True True True
# initial cost =  1327726.0115603667
# RUN  0 , total integrated cost =  1327726.0115603667
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1327725.971032703
# RUN  2 , total integrated cost =  1327725.9710134475
# RUN  3 , total integrated cost =  1327725.9710134412
# RUN  4 , total integrated cost =  1327725.9710134412
# Control only changes marginally.
# RUN  4 , total integrated cost =  1327725.9710134412
# Improved over  4  iterations in  3.755256926000584  seconds by  3.0538624002929282e-06  percent.
# [2.04451193e-04 8.10079798e-05] [5.00629347e+00 2.56247356e-12]
# go back to ----- 500
# ----- 500
# interpolate adjoint :  True True True
# initial cost =  1327725.9710134412
# RUN  0 , total integrated cost =  1327725.9710134412
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1327725.9710134412
# Control only changes marginally.
# RUN  1 , total integrated cost =  1327725.9710134412
# Improved over  1  iterations in  1.0811614480044227  seconds by  0.0  percent.
# [2.04451193e-04 8.10079798e-05] [5.00629347e+00 2.56247356e-12]
# ----- 600
# shift ind =  53
# set cost params:  1.0 0.0 259317.78480970536
# interpolate adjoint :  True True True
# initial cost =  1298221.0166351479
# RUN  0 , total integrated cost =  1298221.0166351479
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1298220.9578619218
# RUN  2 , total integrated cost =  1298220.9578611776
# RUN  3 , total integrated cost =  1298220.9578611776
# Control only changes marginally.
# RUN  3 , total integrated cost =  1298220.9578611776
# Improved over  3  iterations in  2.6658360279980116  seconds by  4.527269965137748e-06  percent.
# [0.00030315 0.00011977] [5.00629353e+00 2.56247349e-12]
# go back to ----- 600
# ----- 600
# interpolate adjoint :  True True True
# initial cost =  1298220.9578611776
# RUN  0 , total integrated cost =  1298220.9578611776
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1298220.9578611776
# Control only changes marginally.
# RUN  1 , total integrated cost =  1298220.9578611776
# Improved over  1  iterations in  0.978847983002197  seconds by  0.0  percent.
# [0.00030315 0.00011977] [5.00629353e+00 2.56247349e-12]
# ----- 700
# shift ind =  53
# set cost params:  1.0 0.0 253424.1954853687
# interpolate adjoint :  True True True
# initial cost =  1268716.0335001482
# RUN  0 , total integrated cost =  1268716.0335001482
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1268715.9482943146
# RUN  2 , total integrated cost =  1268715.9482324347
# RUN  3 , total integrated cost =  1268715.9482324268
# RUN  4 , total integrated cost =  1268715.9482324268
# Control only changes marginally.
# RUN  4 , total integrated cost =  1268715.9482324268
# Improved over  4  iterations in  3.4109607709979173  seconds by  6.720788519487542e-06  percent.
# [0.00044944 0.00017744] [5.00629363e+00 2.56247349e-12]
# go back to ----- 700
# ----- 700
# interpolate adjoint :  True True True
# initial cost =  1268715.9482324268
# RUN  0 , total integrated cost =  1268715.9482324268
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1268715.9482324268
# Control only changes marginally.
# RUN  1 , total integrated cost =  1268715.9482324268
# Improved over  1  iterations in  0.6085689119936433  seconds by  0.0  percent.
# [0.00044944 0.00017744] [5.00629363e+00 2.56247349e-12]
# ----- 800
# shift ind =  52
# set cost params:  1.0 0.0 247530.6047548864
# interpolate adjoint :  True True True
# initial cost =  1239211.077631146
# RUN  0 , total integrated cost =  1239211.077631146
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1239210.944854558
# RUN  2 , total integrated cost =  1239210.9448324312
# RUN  3 , total integrated cost =  1239210.9448324312
# Control only changes marginally.
# RUN  3 , total integrated cost =  1239210.9448324312
# Improved over  3  iterations in  1.6640544630063232  seconds by  1.0716391841469886e-05  percent.
# [0.00067199 0.00026525] [5.00629377e+00 2.56247348e-12]
# go back to ----- 800
# ----- 800
# interpolate adjoint :  True True True
# initial cost =  1239210.9448324312
# RUN  0 , total integrated cost =  1239210.9448324312
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1239210.9448324312
# Control only changes marginally.
# RUN  1 , total integrated cost =  1239210.9448324312
# Improved over  1  iterations in  0.5523697410244495  seconds by  0.0  percent.
# [0.00067199 0.00026525] [5.00629377e+00 2.56247348e-12]
# ----- 900
# shift ind =  53
# set cost params:  1.0 0.0 241637.01181533132
# interpolate adjoint :  True True True
# initial cost =  1209706.1293082999
# RUN  0 , total integrated cost =  1209706.1293082999
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1209705.9474834632
# RUN  2 , total integrated cost =  1209705.947430271
# RUN  3 , total integrated cost =  1209705.947430271
# Control only changes marginally.
# RUN  3 , total integrated cost =  1209705.947430271
# Improved over  3  iterations in  1.6472172040084843  seconds by  1.5034893550591732e-05  percent.
# [0.00099783 0.00039382] [5.00629399e+00 2.56247348e-12]
# go back to ----- 900
# ----- 900
# interpolate adjoint :  True True True
# initial cost =  1209705.947430271
# RUN  0 , total integrated cost =  1209705.947430271
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1209705.947430271
# Control only changes marginally.
# RUN  1 , total integrated cost =  1209705.947430271
# Improved over  1  iterations in  0.9489703779981937  seconds by  0.0  percent.
# [0.00099783 0.00039382] [5.00629399e+00 2.56247348e-12]
# ----- 1000
# shift ind =  53
# set cost params:  1.0 0.0 235743.41604396084
# interpolate adjoint :  True True True
# initial cost =  1180201.226826268
# RUN  0 , total integrated cost =  1180201.226826268
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1180200.961711606
# RUN  2 , total integrated cost =  1180200.9615352768
# RUN  3 , total integrated cost =  1180200.9615352768
# Control only changes marginally.
# RUN  3 , total integrated cost =  1180200.9615352768
# Improved over  3  iterations in  2.59402780799428  seconds by  2.2478454113183943e-05  percent.
# [0.00147312 0.00058138] [5.00629430e+00 2.56247348e-12]
# go back to ----- 1000
# ----- 1000
# interpolate adjoint :  True True True
# initial cost =  1180200.9615352768
# RUN  0 , total integrated cost =  1180200.9615352768
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1180200.9615352768
# Control only changes marginally.
# RUN  1 , total integrated cost =  1180200.9615352768
# Improved over  1  iterations in  0.9365766129922122  seconds by  0.0  percent.
# [0.00147312 0.00058138] [5.00629430e+00 2.56247348e-12]
# ----- 1100
# shift ind =  53
# set cost params:  1.0 0.0 229849.81596137723
# interpolate adjoint :  True True True
# initial cost =  1150696.3750696196
# RUN  0 , total integrated cost =  1150696.3750696196
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1150695.9911284817
# RUN  2 , total integrated cost =  1150695.991112845
# RUN  3 , total integrated cost =  1150695.9911128366
# RUN  4 , total integrated cost =  1150695.9911128366
# Control only changes marginally.
# RUN  4 , total integrated cost =  1150695.9911128366
# Improved over  4  iterations in  3.250302308006212  seconds by  3.336734096137661e-05  percent.
# [0.00218926 0.00086407] [5.00629477e+00 2.56247348e-12]
# go back to ----- 1100
# ----- 1100
# interpolate adjoint :  True True True
# initial cost =  1150695.9911128366
# RUN  0 , total integrated cost =  1150695.9911128366
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1150695.9911128366
# Control only changes marginally.
# RUN  1 , total integrated cost =  1150695.9911128366
# Improved over  1  iterations in  0.9414555870171171  seconds by  0.0  percent.
# [0.00218926 0.00086407] [5.00629477e+00 2.56247348e-12]
# ----- 1200
# shift ind =  53
# set cost params:  1.0 0.0 223956.2097594895
# interpolate adjoint :  True True True
# initial cost =  1121191.6042202543
# RUN  0 , total integrated cost =  1121191.6042202543
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1121191.0439034766
# RUN  2 , total integrated cost =  1121191.043476364
# RUN  3 , total integrated cost =  1121191.04347636
# RUN  4 , total integrated cost =  1121191.04347636
# Control only changes marginally.
# RUN  4 , total integrated cost =  1121191.04347636
# Improved over  4  iterations in  3.147294757014606  seconds by  5.001320847952684e-05  percent.
# [0.00324978 0.00128285] [5.00629547e+00 2.56247347e-12]
# go back to ----- 1200
# ----- 1200
# interpolate adjoint :  True True True
# initial cost =  1121191.04347636
# RUN  0 , total integrated cost =  1121191.04347636
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1121191.04347636
# Control only changes marginally.
# RUN  1 , total integrated cost =  1121191.04347636
# Improved over  1  iterations in  0.9379502390220296  seconds by  0.0  percent.
# [0.00324978 0.00128285] [5.00629547e+00 2.56247347e-12]
# ----- 1300
# shift ind =  53
# set cost params:  1.0 0.0 218062.59467455363
# interpolate adjoint :  True True True
# initial cost =  1091686.9460481629
# RUN  0 , total integrated cost =  1091686.9460481629
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1091686.1284227448
# RUN  2 , total integrated cost =  1091686.1283138064
# RUN  3 , total integrated cost =  1091686.1283138064
# Control only changes marginally.
# RUN  3 , total integrated cost =  1091686.1283138064
# Improved over  3  iterations in  2.397526964021381  seconds by  7.490557246114804e-05  percent.
# [0.0048195 0.0019029] [5.00629650e+00 2.56247346e-12]
# go back to ----- 1300
# ----- 1300
# interpolate adjoint :  True True True
# initial cost =  1091686.1283138064
# RUN  0 , total integrated cost =  1091686.1283138064
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1091686.1283138064
# Control only changes marginally.
# RUN  1 , total integrated cost =  1091686.1283138064
# Improved over  1  iterations in  0.8778481339977589  seconds by  0.0  percent.
# [0.0048195 0.0019029] [5.00629650e+00 2.56247346e-12]
# ----- 1400
# shift ind =  52
# set cost params:  1.0 0.0 212168.96679408546
# interpolate adjoint :  True True True
# initial cost =  1062182.5420378398
# RUN  0 , total integrated cost =  1062182.5420378398
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1062181.2699610083
# RUN  2 , total integrated cost =  1062181.269479887
# RUN  3 , total integrated cost =  1062181.269479887
# Control only changes marginally.
# RUN  3 , total integrated cost =  1062181.269479887
# Improved over  3  iterations in  2.268520243000239  seconds by  0.0001198059563591869  percent.
# [0.00719314 0.0028406 ] [5.00629807e+00 2.56247344e-12]
# go back to ----- 1400
# ----- 1400
# interpolate adjoint :  True True True
# initial cost =  1062181.269479887
# RUN  0 , total integrated cost =  1062181.269479887
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1062181.269479887
# Control only changes marginally.
# RUN  1 , total integrated cost =  1062181.269479887
# Improved over  1  iterations in  0.863062381016789  seconds by  0.0  percent.
# [0.00719314 0.0028406 ] [5.00629807e+00 2.56247344e-12]
# ----- 1500
# shift ind =  53
# set cost params:  1.0 0.0 206275.31885704564
# interpolate adjoint :  True True True
# initial cost =  1032678.2042391825
# RUN  0 , total integrated cost =  1032678.2042391825
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1032676.4657286153
# RUN  2 , total integrated cost =  1032676.4640832533
# RUN  3 , total integrated cost =  1032676.4640832533
# Control only changes marginally.
# RUN  3 , total integrated cost =  1032676.4640832533
# Improved over  3  iterations in  2.136355282011209  seconds by  0.0001685090207246276  percent.
# [0.01066349 0.00421144] [5.00630037e+00 2.56247341e-12]
# go back to ----- 1500
# ----- 1500
# interpolate adjoint :  True True True
# initial cost =  1032676.4640832533
# RUN  0 , total integrated cost =  1032676.4640832533
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1032676.4640832533
# Control only changes marginally.
# RUN  1 , total integrated cost =  1032676.4640832533
# Improved over  1  iterations in  0.8273505110119004  seconds by  0.0  percent.
# [0.01066349 0.00421144] [5.00630037e+00 2.56247341e-12]
# ----- 1600
# shift ind =  53
# set cost params:  1.0 0.0 200381.64539900457
# interpolate adjoint :  True True True
# initial cost =  1003174.2926747405
# RUN  0 , total integrated cost =  1003174.2926747405
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1003171.761856295
# RUN  2 , total integrated cost =  1003171.7615770685
# RUN  3 , total integrated cost =  1003171.7615770685
# Control only changes marginally.
# RUN  3 , total integrated cost =  1003171.7615770685
# Improved over  3  iterations in  2.1143894880078733  seconds by  0.0002523088650292493  percent.
# [0.01583374 0.00625336] [5.00630378e+00 2.56247336e-12]
# go back to ----- 1600
# ----- 1600
# interpolate adjoint :  True True True
# initial cost =  1003171.7615770685
# RUN  0 , total integrated cost =  1003171.7615770685
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1003171.7615770685
# Control only changes marginally.
# RUN  1 , total integrated cost =  1003171.7615770685
# Improved over  1  iterations in  0.8324390210036654  seconds by  0.0  percent.
# [0.01583374 0.00625336] [5.00630378e+00 2.56247336e-12]
# ----- 1700
# shift ind =  53
# set cost params:  1.0 0.0 194487.93375214955
# interpolate adjoint :  True True True
# initial cost =  973670.8868442172
# RUN  0 , total integrated cost =  973670.8868442172
# Gradient descend method:  None
# RUN  1 , total integrated cost =  973667.2020117816
# RUN  2 , total integrated cost =  973667.198772018
# RUN  3 , total integrated cost =  973667.1987719759
# RUN  4 , total integrated cost =  973667.1987719759
# Control only changes marginally.
# RUN  4 , total integrated cost =  973667.1987719759
# Improved over  4  iterations in  2.6786068880173843  seconds by  0.0003787801700809723  percent.
# [0.02347204 0.00926986] [5.00630884e+00 2.56247328e-12]
# go back to ----- 1700
# ----- 1700
# interpolate adjoint :  True True True
# initial cost =  973667.1987719759
# RUN  0 , total integrated cost =  973667.1987719759
# Gradient descend method:  None
# RUN  1 , total integrated cost =  973667.1987719759
# Control only changes marginally.
# RUN  1 , total integrated cost =  973667.1987719759
# Improved over  1  iterations in  0.7967200209968723  seconds by  0.0  percent.
# [0.02347204 0.00926986] [5.00630884e+00 2.56247328e-12]
# ----- 1800
# shift ind =  53
# set cost params:  1.0 0.0 188594.16713090194
# interpolate adjoint :  True True True
# initial cost =  944168.1958403959
# RUN  0 , total integrated cost =  944168.1958403959
# Gradient descend method:  None
# RUN  1 , total integrated cost =  944162.8339318621
# RUN  2 , total integrated cost =  944162.8338827189
# RUN  3 , total integrated cost =  944162.8338827189
# Control only changes marginally.
# RUN  3 , total integrated cost =  944162.8338827189
# Improved over  3  iterations in  1.9558288659900427  seconds by  0.0005679028059404345  percent.
# [0.03476246 0.01373189] [5.00631635e+00 2.56247314e-12]
# go back to ----- 1800
# ----- 1800
# interpolate adjoint :  True True True
# initial cost =  944162.8338827189
# RUN  0 , total integrated cost =  944162.8338827189
# Gradient descend method:  None
# RUN  1 , total integrated cost =  944162.8338827189
# Control only changes marginally.
# RUN  1 , total integrated cost =  944162.8338827189
# Improved over  1  iterations in  0.7495823150093202  seconds by  0.0  percent.
# [0.03476246 0.01373189] [5.00631635e+00 2.56247314e-12]
# ----- 1900
# shift ind =  52
# set cost params:  1.0 0.0 182700.32196733807
# interpolate adjoint :  True True True
# initial cost =  914667.1036479938
# RUN  0 , total integrated cost =  914667.1036479938
# Gradient descend method:  None
# RUN  1 , total integrated cost =  914658.8182062146
# RUN  2 , total integrated cost =  914658.8134731828
# RUN  3 , total integrated cost =  914658.8134702476
# RUN  4 , total integrated cost =  914658.8134702462
# RUN  5 , total integrated cost =  914658.8134702462
# Control only changes marginally.
# RUN  5 , total integrated cost =  914658.8134702462
# Improved over  5  iterations in  3.2774699419969693  seconds by  0.0009063601079049022  percent.
# [0.0519772  0.02054329] [5.00632777e+00 2.56247293e-12]
# go back to ----- 1900
# ----- 1900
# interpolate adjoint :  True True True
# initial cost =  914658.8134702462
# RUN  0 , total integrated cost =  914658.8134702462
# Gradient descend method:  None
# RUN  1 , total integrated cost =  914658.8134702462
# Control only changes marginally.
# RUN  1 , total integrated cost =  914658.8134702462
# Improved over  1  iterations in  0.7493455309886485  seconds by  0.0  percent.
# [0.0519772  0.02054329] [5.00632777e+00 2.56247293e-12]
# ----- 2000
# shift ind =  53
# set cost params:  1.0 0.0 176806.35476917538
# interpolate adjoint :  True True True
# initial cost =  885166.4737426245
# RUN  0 , total integrated cost =  885166.4737426245
# Gradient descend method:  None
# RUN  1 , total integrated cost =  885155.1294049422
# RUN  2 , total integrated cost =  885155.1196027314
# RUN  3 , total integrated cost =  885155.1195900965
# RUN  4 , total integrated cost =  885155.1195900958
# RUN  5 , total integrated cost =  885155.1195900958
# Control only changes marginally.
# RUN  5 , total integrated cost =  885155.1195900958
# Improved over  5  iterations in  2.8597368479822762  seconds by  0.00128271380191336  percent.
# [0.07706971 0.03048336] [5.00634445e+00 2.56247258e-12]
# go back to ----- 2000
# ----- 2000
# interpolate adjoint :  True True True
# initial cost =  885155.1195900958
# RUN  0 , total integrated cost =  885155.1195900958
# Gradient descend method:  None
# RUN  1 , total integrated cost =  885155.1195900958
# Control only changes marginally.
# RUN  1 , total integrated cost =  885155.1195900958
# Improved over  1  iterations in  0.6946034299908206  seconds by  0.0  percent.
# [0.07706971 0.03048336] [5.00634445e+00 2.56247258e-12]
# ----- 2100
# shift ind =  53
# set cost params:  1.0 0.0 170912.23236769752
# interpolate adjoint :  True True True
# initial cost =  855668.5220788479
# RUN  0 , total integrated cost =  855668.5220788479
# Gradient descend method:  None
# RUN  1 , total integrated cost =  855652.0500848884
# RUN  2 , total integrated cost =  855652.0443643773
# RUN  3 , total integrated cost =  855652.0443511343
# RUN  4 , total integrated cost =  855652.0443511256
# RUN  5 , total integrated cost =  855652.0443511256
# Control only changes marginally.
# RUN  5 , total integrated cost =  855652.0443511256
# Improved over  5  iterations in  3.05699195197667  seconds by  0.0019257139063881823  percent.
# [0.11431608 0.04525385] [5.00636923e+00 2.56247201e-12]
# go back to ----- 2100
# ----- 2100
# interpolate adjoint :  True True True
# initial cost =  855652.0443511256
# RUN  0 , total integrated cost =  855652.0443511256
# Gradient descend method:  None
# RUN  1 , total integrated cost =  855652.0443511256
# Control only changes marginally.
# RUN  1 , total integrated cost =  855652.0443511256
# Improved over  1  iterations in  0.7123635860043578  seconds by  0.0  percent.
# [0.11431608 0.04525385] [5.00636923e+00 2.56247201e-12]
# ----- 2200
# shift ind =  53
# set cost params:  1.0 0.0 165017.879322582
# interpolate adjoint :  True True True
# initial cost =  826173.6976661513
# RUN  0 , total integrated cost =  826173.6976661513
# Gradient descend method:  None
# RUN  1 , total integrated cost =  826149.8071699307
# RUN  2 , total integrated cost =  826149.8054790657
# RUN  3 , total integrated cost =  826149.8054745133
# RUN  4 , total integrated cost =  826149.8054744831
# RUN  5 , total integrated cost =  826149.8054744821
# RUN  6 , total integrated cost =  826149.8054744821
# Control only changes marginally.
# RUN  6 , total integrated cost =  826149.8054744821
# Improved over  6  iterations in  3.272835616982775  seconds by  0.002891909018245542  percent.
# [0.16921432 0.06704654] [5.00640607e+00 2.56247107e-12]
# go back to ----- 2200
# ----- 2200
# interpolate adjoint :  True True True
# initial cost =  826149.8054744821
# RUN  0 , total integrated cost =  826149.8054744821
# Gradient descend method:  None
# RUN  1 , total integrated cost =  826149.8054744821
# Control only changes marginally.
# RUN  1 , total integrated cost =  826149.8054744821
# Improved over  1  iterations in  0.7243682559928857  seconds by  0.0  percent.
# [0.16921432 0.06704654] [5.00640607e+00 2.56247107e-12]
# ----- 2300
# shift ind =  53
# set cost params:  1.0 0.0 159123.19619713328
# interpolate adjoint :  True True True
# initial cost =  796683.2586514212
# RUN  0 , total integrated cost =  796683.2586514212
# Gradient descend method:  None
# RUN  1 , total integrated cost =  796648.7543078834
# RUN  2 , total integrated cost =  796648.745534752
# RUN  3 , total integrated cost =  796648.7455320631
# RUN  4 , total integrated cost =  796648.7455320482
# RUN  5 , total integrated cost =  796648.7455320472
# RUN  6 , total integrated cost =  796648.7455320472
# Control only changes marginally.
# RUN  6 , total integrated cost =  796648.7455320472
# Improved over  6  iterations in  3.299100347998319  seconds by  0.004332100492774771  percent.
# [0.25146577 0.09973808] [5.00646069e+00 2.56246954e-12]
# go back to ----- 2300
# ----- 2300
# interpolate adjoint :  True True True
# initial cost =  796648.7455320472
# RUN  0 , total integrated cost =  796648.7455320472
# Gradient descend method:  None
# RUN  1 , total integrated cost =  796648.7455320472
# Control only changes marginally.
# RUN  1 , total integrated cost =  796648.7455320472
# Improved over  1  iterations in  0.6908547490020283  seconds by  0.0  percent.
# [0.25146577 0.09973808] [5.00646069e+00 2.56246954e-12]
# ----- 2400
# shift ind =  52
# set cost params:  1.0 0.0 153228.04823014786
# interpolate adjoint :  True True True
# initial cost =  767202.7103595003
# RUN  0 , total integrated cost =  767202.7103595003
# Gradient descend method:  None
# RUN  1 , total integrated cost =  767149.7502364231
# RUN  2 , total integrated cost =  767149.7437674375
# RUN  3 , total integrated cost =  767149.7437674375
# Control only changes marginally.
# RUN  3 , total integrated cost =  767149.7437674375
# Improved over  3  iterations in  1.658442991989432  seconds by  0.006903858829943488  percent.
# [0.37510781 0.14890394] [5.00654398e+00 2.56246711e-12]
# go back to ----- 2400
# ----- 2400
# interpolate adjoint :  True True True
# initial cost =  767149.7437674375
# RUN  0 , total integrated cost =  767149.7437674375
# Gradient descend method:  None
# RUN  1 , total integrated cost =  767149.7437674375
# Control only changes marginally.
# RUN  1 , total integrated cost =  767149.7437674375
# Improved over  1  iterations in  0.6363068569917232  seconds by  0.0  percent.
# [0.37510781 0.14890394] [5.00654398e+00 2.56246711e-12]
# ----- 2500
# shift ind =  53
# set cost params:  1.0 0.0 147332.17326939534
# interpolate adjoint :  True True True
# initial cost =  737724.5695316365
# RUN  0 , total integrated cost =  737724.5695316365
# Gradient descend method:  None
# RUN  1 , total integrated cost =  737652.594355393
# RUN  2 , total integrated cost =  737652.5812507014
# RUN  3 , total integrated cost =  737652.581232148
# RUN  4 , total integrated cost =  737652.581230961
# RUN  5 , total integrated cost =  737652.5812309234
# RUN  6 , total integrated cost =  737652.5812309213
# RUN  7 , total integrated cost =  737652.58123092
# RUN  8 , total integrated cost =  737652.58123092
# Control only changes marginally.
# RUN  8 , total integrated cost =  737652.58123092
# Improved over  8  iterations in  3.9480668010073714  seconds by  0.009758154152592624  percent.
# [0.55514155 0.22050255] [5.00666564e+00 2.56246306e-12]
# go back to ----- 2500
# ----- 2500
# interpolate adjoint :  True True True
# initial cost =  737652.58123092
# RUN  0 , total integrated cost =  737652.58123092
# Gradient descend method:  None
# RUN  1 , total integrated cost =  737652.58123092
# Control only changes marginally.
# RUN  1 , total integrated cost =  737652.58123092
# Improved over  1  iterations in  0.6772412130085286  seconds by  0.0  percent.
# [0.55514155 0.22050255] [5.00666564e+00 2.56246306e-12]
# ----- 2600
# shift ind =  53
# set cost params:  1.0 0.0 141435.39497665595
# interpolate adjoint :  True True True
# initial cost =  708262.1187652877
# RUN  0 , total integrated cost =  708262.1187652877
# Gradient descend method:  None
# RUN  1 , total integrated cost =  708159.0072048496
# RUN  2 , total integrated cost =  708158.9938443013
# RUN  3 , total integrated cost =  708158.9938243021
# RUN  4 , total integrated cost =  708158.993814344
# RUN  5 , total integrated cost =  708158.9937811411
# RUN  6 , total integrated cost =  708158.8435988532
# RUN  7 , total integrated cost =  708158.6726820451
# RUN  8 , total integrated cost =  708158.6723036788
# RUN  9 , total integrated cost =  708158.6722924385
# RUN  10 , total integrated cost =  708158.6722889786
# RUN  11 , total integrated cost =  708158.6722854414
# RUN  12 , total integrated cost =  708158.6722689644
# RUN  13 , total integrated cost =  708158.658897879
# RUN  14 , total integrated cost =  708158.6426791708
# RUN  15 , total integrated cost =  708158.642649419
# RUN  16 , total integrated cost =  708158.6426420488
# RUN  17 , total integrated cost =  708158.6426382803
# RUN  18 , total integrated cost =  708158.642628402
# RUN  19 , total integrated cost =  708158.5430498206
# RUN  20 , total integrated cost =  708158.4622164941
# Control only changes marginally.
# RUN  24 , total integrated cost =  708158.4622164879
# Improved over  24  iterations in  10.282523076981306  seconds by  0.014635337123564796  percent.
# [0.79528643 0.32923771] [5.00684450e+00 2.56245646e-12]
# go back to ----- 2600
# ----- 2600
# interpolate adjoint :  True True True
# initial cost =  708158.4622164879
# RUN  0 , total integrated cost =  708158.4622164879
# Gradient descend method:  None
# RUN  1 , total integrated cost =  708158.4622164879
# Control only changes marginally.
# RUN  1 , total integrated cost =  708158.4622164879
# Improved over  1  iterations in  0.6284493170096539  seconds by  0.0  percent.
# [0.79528643 0.32923771] [5.00684450e+00 2.56245646e-12]
# ----- 2700
# shift ind =  53
# set cost params:  1.0 0.0 135537.33547870856
# interpolate adjoint :  True True True
# initial cost =  678819.7296018508
# RUN  0 , total integrated cost =  678819.7296018508
# Gradient descend method:  None
# RUN  1 , total integrated cost =  678670.014863336
# RUN  2 , total integrated cost =  678669.9902850823
# RUN  3 , total integrated cost =  678669.9902320711
# RUN  4 , total integrated cost =  678669.9901995392
# RUN  5 , total integrated cost =  678669.9899267054
# RUN  6 , total integrated cost =  678669.9874108293
# RUN  7 , total integrated cost =  678669.9867687176
# RUN  8 , total integrated cost =  678669.986726512
# RUN  9 , total integrated cost =  678669.9866886713
# RUN  10 , total integrated cost =  678669.9856318382
# RUN  11 , total integrated cost =  678669.9826135389
# RUN  12 , total integrated cost =  678669.9823804906
# RUN  13 , total integrated cost =  678669.9823468798
# RUN  14 , total integrated cost =  678669.9822958821
# RUN  15 , total integrated cost =  678669.9693772795
# RUN  16 , total integrated cost =  678669.9506119242
# RUN  17 , total integrated cost =  678669.9505599111
# RUN  18 , total integrated cost =  678669.9505257658
# RUN  19 , total integrated cost =  678669.9501273573
# RUN  20 , total integrated cost =  678669.9477608136
# RUN  30 , total integrated cost =  678669.612721966
# RUN  40 , total integrated cost =  678669.5860168982
# RUN  50 , total integrated cost =  678669.5764166132
# RUN  60 , total integrated cost =  678669.5383130213
# RUN  70 , total integrated cost =  678669.5320794748
# RUN  80 , total integrated cost =  678669.5251210266
# RUN  90 , total integrated cost =  678668.3308186512
# RUN  100 , total integrated cost =  678668.3072594859
# RUN  110 , total integrated cost =  678668.0681006304
# RUN  120 , total integrated cost =  678668.0680991552
# Control only changes marginally.
# RUN  123 , total integrated cost =  678668.0680991445
# Improved over  123  iterations in  49.5121508059965  seconds by  0.022341940885439726  percent.
# [1.08536204 0.49721235] [5.00710707e+00 2.56244568e-12]
# go back to ----- 2700
# ----- 2700
# interpolate adjoint :  True True True
# initial cost =  678668.0680991445
# RUN  0 , total integrated cost =  678668.0680991445
# Gradient descend method:  None
# RUN  1 , total integrated cost =  678668.0680991445
# Control only changes marginally.
# RUN  1 , total integrated cost =  678668.0680991445
# Improved over  1  iterations in  0.6318318490230013  seconds by  0.0  percent.
# [1.08536204 0.49721235] [5.00710707e+00 2.56244568e-12]
# ----- 2800
# shift ind =  53
# set cost params:  1.0 0.0 129637.5080417111
# interpolate adjoint :  True True True
# initial cost =  649408.4579223669
# RUN  0 , total integrated cost =  649408.4579223669
# Gradient descend method:  None
# RUN  1 , total integrated cost =  649187.5135453059
# RUN  2 , total integrated cost =  649187.3383478893
# RUN  3 , total integrated cost =  649187.3379277634
# RUN  4 , total integrated cost =  649187.337894446
# RUN  5 , total integrated cost =  649187.337877459
# RUN  6 , total integrated cost =  649187.3378630835
# RUN  7 , total integrated cost =  649187.3378188954
# RUN  8 , total integrated cost =  649187.336032998
# RUN  9 , total integrated cost =  649187.330029288
# RUN  10 , total integrated cost =  649187.329804625
# RUN  11 , total integrated cost =  649187.329780562
# RUN  12 , total integrated cost =  649187.3297647093
# RUN  13 , total integrated cost =  649187.3297492831
# RUN  14 , total integrated cost =  649187.3296914287
# RUN  15 , total integrated cost =  649187.3259969287
# RUN  16 , total integrated cost =  649187.3177215959
# RUN  17 , total integrated cost =  649187.3174936033
# RUN  18 , total integrated cost =  649187.3174705395
# RUN  19 , total integrated cost =  649187.3174553603
# RUN  20 , total integrated cost =  649187.3174384637
# RUN  30 , total integrated cost =  649187.2434236553
# RUN  40 , total integrated cost =  649187.2327551193
# RUN  50 , total integrated cost =  649186.2708854593
# RUN  60 , total integrated cost =  649186.2647458505
# RUN  70 , total integrated cost =  649186.2532106385
# RUN  80 , total integrated cost =  649186.0070859713
# RUN  90 , total integrated cost =  649186.0003904934
# RUN  100 , total integrated cost =  649185.8359285723
# RUN  110 , total integrated cost =  649185.8357285475
# RUN  120 , total integrated cost =  649185.8309485915
# RUN  130 , total integrated cost =  649185.8264459567
# RUN  140 , total integrated cost =  649185.8220810979
# RUN  150 , total integrated cost =  649185.8171403287
# RUN  160 , total integrated cost =  649185.668566772
# RUN  170 , total integrated cost =  649185.5811937319
# RUN  180 , total integrated cost =  649185.572078116
# RUN  190 , total integrated cost =  649185.5665808027
# RUN  200 , total integrated cost =  649185.3980101093
# Control only changes marginally.
# RUN  213 , total integrated cost =  649185.1123717419
# Improved over  213  iterations in  72.41246577198035  seconds by  0.0343921530279232  percent.
# [1.56789697 0.74445762] [5.00749977e+00 2.56242806e-12]
# go back to ----- 2800
# ----- 2800
# interpolate adjoint :  True True True
# initial cost =  649185.1123717419
# RUN  0 , total integrated cost =  649185.1123717419
# Gradient descend method:  None
# RUN  1 , total integrated cost =  649185.1123717419
# Control only changes marginally.
# RUN  1 , total integrated cost =  649185.1123717419
# Improved over  1  iterations in  0.5718861710047349  seconds by  0.0  percent.
# [1.56789697 0.74445762] [5.00749977e+00 2.56242806e-12]
# ----- 2900
# shift ind =  53
# set cost params:  1.0 0.0 123735.02968533595
# interpolate adjoint :  True True True
# initial cost =  620032.099978959
# RUN  0 , total integrated cost =  620032.099978959
# Gradient descend method:  None
# RUN  1 , total integrated cost =  619714.1082070293
# RUN  2 , total integrated cost =  619713.9552724796
# RUN  3 , total integrated cost =  619713.954611999
# RUN  4 , total integrated cost =  619713.9537030086
# RUN  5 , total integrated cost =  619713.9475738709
# RUN  6 , total integrated cost =  619713.945993724
# RUN  7 , total integrated cost =  619713.9455501451
# RUN  8 , total integrated cost =  619713.8438754424
# RUN  9 , total integrated cost =  619713.7571889944
# RUN  10 , total integrated cost =  619713.7567894469
# RUN  11 , total integrated cost =  619713.754714512
# RUN  12 , total integrated cost =  619713.7484900819
# RUN  13 , total integrated cost =  619713.7477978102
# RUN  14 , total integrated cost =  619713.7453445249
# RUN  15 , total integrated cost =  619713.7386551494
# RUN  16 , total integrated cost =  619713.7378986255
# RUN  17 , total integrated cost =  619713.7341364295
# RUN  18 , total integrated cost =  619713.726317488
# RUN  19 , total integrated cost =  619713.725463428
# RUN  20 , total integrated cost =  619713.7220110989
# RUN  30 , total integrated cost =  619713.6576864611
# RUN  40 , total integrated cost =  619713.631163334
# RUN  50 , total integrated cost =  619713.5860940451
# RUN  60 , total integrated cost =  619713.5105822551
# RUN  70 , total integrated cost =  619713.4595416886
# RUN  80 , total integrated cost =  619713.4059598265
# RUN  90 , total integrated cost =  619713.3376420384
# RUN  100 , total integrated cost =  619711.9203365255
# RUN  110 , total integrated cost =  619707.6823591634
# RUN  120 , total integrated cost =  619707.6737179611
# RUN  130 , total integrated cost =  619707.6160388695
# RUN  140 , total integrated cost =  619707.5978890522
# RUN  150 , total integrated cost =  619707.5765052247
# RUN  160 , total integrated cost =  619706.7315236129
# Control only changes marginally.
# RUN  162 , total integrated cost =  619706.7315236123
# Improved over  162  iterations in  48.50197041998035  seconds by  0.052476066216200934  percent.
# [1.97793847 1.14378581] [5.00807332e+00 2.56239928e-12]
# go back to ----- 2900
# ----- 2900
# interpolate adjoint :  True True True
# initial cost =  619706.7315236123
# RUN  0 , total integrated cost =  619706.7315236123
# Gradient descend method:  None
# RUN  1 , total integrated cost =  619706.7315236123
# Control only changes marginally.
# RUN  1 , total integrated cost =  619706.7315236123
# Improved over  1  iterations in  0.35318418699898757  seconds by  0.0  percent.
# [1.97793847 1.14378581] [5.00807332e+00 2.56239928e-12]
# ----- 3000
# shift ind =  52
# set cost params:  1.0 0.0 117829.2058057458
# interpolate adjoint :  True True True
# initial cost =  590757.7026085032
# RUN  0 , total integrated cost =  590757.7026085032
# Gradient descend method:  None
# RUN  1 , total integrated cost =  590255.0134938526
# RUN  2 , total integrated cost =  590254.7697620278
# RUN  3 , total integrated cost =  590254.7689246493
# RUN  4 , total integrated cost =  590254.7681709094
# RUN  5 , total integrated cost =  590254.7428184557
# RUN  6 , total integrated cost =  590254.728072697
# RUN  7 , total integrated cost =  590254.7274760146
# RUN  8 , total integrated cost =  590254.7257857327
# RUN  9 , total integrated cost =  590254.715547254
# RUN  10 , total integrated cost =  590254.7132494771
# RUN  11 , total integrated cost =  590254.712687664
# RUN  12 , total integrated cost =  590254.6837920422
# RUN  13 , total integrated cost =  590254.6364137934
# RUN  14 , total integrated cost =  590254.6358237856
# RUN  15 , total integrated cost =  590254.6342025972
# RUN  16 , total integrated cost =  590254.6240657922
# RUN  17 , total integrated cost =  590254.6216994777
# RUN  18 , total integrated cost =  590254.6210569859
# RUN  19 , total integrated cost =  590254.0430995061
# RUN  20 , total integrated cost =  590253.5673097242
# RUN  30 , total integrated cost =  590252.3060711104
# RUN  40 , total integrated cost =  590252.2472171792
# RUN  50 , total integrated cost =  590252.2202600357
# RUN  60 , total integrated cost =  590251.8460850567
# RUN  70 , total integrated cost =  590251.8189148462
# RUN  80 , total integrated cost =  590251.7397423236
# RUN  90 , total integrated cost =  590251.4990058966
# RUN  100 , total integrated cost =  590251.4507505961
# RUN  110 , total integrated cost =  590251.4044231204
# RUN  120 , total integrated cost =  590251.3758909497
# RUN  130 , total integrated cost =  590251.3434673796
# RUN  140 , total integrated cost =  590251.3160688777
# RUN  150 , total integrated cost =  590251.1940286912
# RUN  160 , total integrated cost =  590250.9310461857
# RUN  170 , total integrated cost =  590250.5743185407
# Control only changes marginally.
# RUN  179 , total integrated cost =  590244.7742055493
# Improved over  179  iterations in  59.12180280999746  seconds by  0.08682551250521442  percent.
# [2.59048941 1.75587122] [5.00895768e+00 2.56235339e-12]
# go back to ----- 3000
# ----- 3000
# interpolate adjoint :  True True True
# initial cost =  590244.7742055493
# RUN  0 , total integrated cost =  590244.7742055493
# Gradient descend method:  None
# RUN  1 , total integrated cost =  590244.7742055493
# Control only changes marginally.
# RUN  1 , total integrated cost =  590244.7742055493
# Improved over  1  iterations in  0.31797132702195086  seconds by  0.0  percent.
# [2.59048941 1.75587122] [5.00895768e+00 2.56235339e-12]
# ----- 3100
# shift ind =  53
# set cost params:  1.0 0.0 111917.70665268214
# interpolate adjoint :  True True True
# initial cost =  561512.7204784184
# RUN  0 , total integrated cost =  561512.7204784184
# Gradient descend method:  None
# RUN  1 , total integrated cost =  560808.1209937627
# RUN  2 , total integrated cost =  560808.1158009862
# RUN  3 , total integrated cost =  560808.1056234767
# RUN  4 , total integrated cost =  560808.0833977346
# RUN  5 , total integrated cost =  560808.0802640913
# RUN  6 , total integrated cost =  560808.0310801723
# RUN  7 , total integrated cost =  560807.9638071425
# RUN  8 , total integrated cost =  560807.9611874579
# RUN  9 , total integrated cost =  560807.8706711347
# RUN  10 , total integrated cost =  560807.809316702
# RUN  11 , total integrated cost =  560807.8062614793
# RUN  12 , total integrated cost =  560807.7779425749
# RUN  13 , total integrated cost =  560807.7629689416
# RUN  14 , total integrated cost =  560807.7571740092
# RUN  15 , total integrated cost =  560807.7398941725
# RUN  16 , total integrated cost =  560807.7359294031
# RUN  17 , total integrated cost =  560807.7212201052
# RUN  18 , total integrated cost =  560807.6931188123
# RUN  19 , total integrated cost =  560807.689916516
# RUN  20 , total integrated cost =  560807.6381828078
# RUN  30 , total integrated cost =  560792.8744794015
# Control only changes marginally.
# RUN  30 , total integrated cost =  560792.8744794015
# Improved over  30  iterations in  10.26025433500763  seconds by  0.12819762986021033  percent.
# [3.60556744 2.6087537 ] [5.01023581e+00 2.56227730e-12]
# go back to ----- 3100
# ----- 3100
# interpolate adjoint :  True True True
# initial cost =  560792.8744794015
# RUN  0 , total integrated cost =  560792.8744794015
# Gradient descend method:  None
# RUN  1 , total integrated cost =  560792.8744794015
# Control only changes marginally.
# RUN  1 , total integrated cost =  560792.8744794015
# Improved over  1  iterations in  0.49413597499369644  seconds by  0.0  percent.
# [3.60556744 2.6087537 ] [5.01023581e+00 2.56227730e-12]
# ----- 3200
# shift ind =  53
# set cost params:  1.0 0.0 105999.8346446043
# interpolate adjoint :  True True True
# initial cost =  532375.6342533394
# RUN  0 , total integrated cost =  532375.6342533394
# Gradient descend method:  None
# RUN  1 , total integrated cost =  531385.9757843956
# RUN  2 , total integrated cost =  531385.59386482
# RUN  3 , total integrated cost =  531385.5531174026
# RUN  4 , total integrated cost =  531385.4929756101
# RUN  5 , total integrated cost =  531385.4851231856
# RUN  6 , total integrated cost =  531385.4213626302
# RUN  7 , total integrated cost =  531385.3770137215
# RUN  8 , total integrated cost =  531385.3536343124
# RUN  9 , total integrated cost =  531385.316314927
# RUN  10 , total integrated cost =  531385.3078389715
# RUN  11 , total integrated cost =  531385.2440016196
# RUN  12 , total integrated cost =  531385.2006538868
# RUN  13 , total integrated cost =  531385.1753630235
# RUN  14 , total integrated cost =  531385.1366512772
# RUN  15 , total integrated cost =  531385.1282962195
# RUN  16 , total integrated cost =  531385.069419831
# RUN  17 , total integrated cost =  531385.0298806984
# RUN  18 , total integrated cost =  531385.0020676752
# RUN  19 , total integrated cost =  531384.9588067721
# RUN  20 , total integrated cost =  531384.9508879841
# RUN  30 , total integrated cost =  531384.4820824992
# RUN  40 , total integrated cost =  531384.0014008385
# RUN  50 , total integrated cost =  531383.6707364457
# RUN  60 , total integrated cost =  531383.2995116685
# RUN  70 , total integrated cost =  531382.9526660865
# RUN  80 , total integrated cost =  531382.635578262
# RUN  90 , total integrated cost =  531382.117974576
# RUN  100 , total integrated cost =  531381.797123207
# RUN  110 , total integrated cost =  531380.5455291157
# RUN  120 , total integrated cost =  531373.6223437646
# RUN  130 , total integrated cost =  531372.5011659462
# RUN  140 , total integrated cost =  531371.3571444524
# RUN  150 , total integrated cost =  531371.1390860751
# Control only changes marginally.
# RUN  157 , total integrated cost =  531363.313258737
# Improved over  157  iterations in  54.50372205500025  seconds by  0.1901516390813356  percent.
# [5.14203169 3.83926956] [5.01211007e+00 2.56215299e-12]
# go back to ----- 3200
# ----- 3200
# interpolate adjoint :  True True True
# initial cost =  531363.313258737
# RUN  0 , total integrated cost =  531363.313258737
# Gradient descend method:  None
# RUN  1 , total integrated cost =  531363.313258737
# Control only changes marginally.
# RUN  1 , total integrated cost =  531363.313258737
# Improved over  1  iterations in  0.49510193002060987  seconds by  0.0  percent.
# [5.14203169 3.83926956] [5.01211007e+00 2.56215299e-12]
# ----- 3300
# shift ind =  53
# set cost params:  1.0 0.0 100072.89773598785
# interpolate adjoint :  True True True
# initial cost =  503355.5975341875
# RUN  0 , total integrated cost =  503355.5975341875
# Gradient descend method:  None
# RUN  1 , total integrated cost =  501992.3656731629
# RUN  2 , total integrated cost =  501991.53365458397
# RUN  3 , total integrated cost =  501965.9639286602
# RUN  4 , total integrated cost =  501963.20884389145
# RUN  5 , total integrated cost =  501963.20861999533
# RUN  6 , total integrated cost =  501963.20847360394
# RUN  7 , total integrated cost =  501963.2058373096
# RUN  8 , total integrated cost =  501963.1960873859
# RUN  9 , total integrated cost =  501963.1953840675
# RUN  10 , total integrated cost =  501963.19524198945
# RUN  11 , total integrated cost =  501963.19500504783
# RUN  12 , total integrated cost =  501962.3940251473
# RUN  13 , total integrated cost =  501961.546176007
# RUN  14 , total integrated cost =  501961.5460272166
# RUN  15 , total integrated cost =  501960.8165237785
# RUN  16 , total integrated cost =  501960.412499331
# RUN  17 , total integrated cost =  501960.4114397062
# RUN  18 , total integrated cost =  501960.4114352508
# RUN  19 , total integrated cost =  501960.41143519914
# RUN  20 , total integrated cost =  501960.41143519734
# Control only changes marginally.
# ...
# initial cost =  92420.13896608131
# RUN  0 , total integrated cost =  92420.13896608131
# Gradient descend method:  None
# RUN  1 , total integrated cost =  92420.13896608131
# Control only changes marginally.
# RUN  1 , total integrated cost =  92420.13896608131
# Improved over  1  iterations in  0.22762589197373018  seconds by  0.0  percent.
# [1592.09255507 7164.65372705] [8.20631209e+00 8.44895863e-13]
# ----- 4720
# shift ind =  0
# set cost params:  1.0 0.0 9000.06143830559
# interpolate adjoint :  True True True
# initial cost =  89814.25055358172
# RUN  0 , total integrated cost =  89814.25055358172
# Gradient descend method:  None
# RUN  1 , total integrated cost =  89785.16033904768
# RUN  2 , total integrated cost =  89770.81547024152
# RUN  3 , total integrated cost =  89763.5439443834
# RUN  4 , total integrated cost =  89760.04598410394
# RUN  5 , total integrated cost =  89758.43645933094
# RUN  6 , total integrated cost =  89756.50057461893
# RUN  7 , total integrated cost =  89754.8306305985
# RUN  8 , total integrated cost =  89753.06660749017
# RUN  9 , total integrated cost =  89752.20864185508
# RUN  10 , total integrated cost =  89751.69880176257
# RUN  11 , total integrated cost =  89751.12896388948
# RUN  12 , total integrated cost =  89750.902862427
# RUN  13 , total integrated cost =  89750.6508027903
# RUN  14 , total integrated cost =  89750.46922370236
# RUN  15 , total integrated cost =  89750.18862618529
# RUN  16 , total integrated cost =  89750.13694717959
# RUN  17 , total integrated cost =  89750.12728542979
# RUN  18 , total integrated cost =  89750.07494263559
# RUN  19 , total integrated cost =  89750.07217815789
# RUN  20 , total integrated cost =  89750.07217815789
# Control only changes marginally.
# RUN  20 , total integrated cost =  89750.07217815789
# Improved over  20  iterations in  3.26102760998765  seconds by  0.07145678445041881  percent.
# [1816.11380706 8726.11017516] [8.33460290e+00 8.03310661e-13]
# go back to ----- 4720
# ----- 4720
# interpolate adjoint :  True True True
# initial cost =  89750.07217815789
# RUN  0 , total integrated cost =  89750.07217815789
# Gradient descend method:  None
# RUN  1 , total integrated cost =  89750.07217815789
# Control only changes marginally.
# RUN  1 , total integrated cost =  89750.07217815789
# Improved over  1  iterations in  0.2245099589927122  seconds by  0.0  percent.
# [1816.11380706 8726.11017516] [8.33460290e+00 8.03310661e-13]
# ----- 4730
# shift ind =  0
# set cost params:  1.0 0.0 8293.296519765705
# interpolate adjoint :  True True True
# initial cost =  87014.44662493124
# RUN  0 , total integrated cost =  87014.44662493124
# Gradient descend method:  None
# RUN  1 , total integrated cost =  86985.68484755373
# RUN  2 , total integrated cost =  86965.91485710524
# RUN  3 , total integrated cost =  86957.02260303719
# RUN  4 , total integrated cost =  86948.702373502
# RUN  5 , total integrated cost =  86945.567449041
# RUN  6 , total integrated cost =  86939.2812653184
# RUN  7 , total integrated cost =  86937.82962187991
# RUN  8 , total integrated cost =  86935.05930044738
# RUN  9 , total integrated cost =  86934.58236891392
# RUN  10 , total integrated cost =  86934.52966067908
# RUN  11 , total integrated cost =  86934.48771899984
# RUN  12 , total integrated cost =  86934.45975031942
# RUN  13 , total integrated cost =  86934.4547298977
# RUN  14 , total integrated cost =  86934.45449323757
# RUN  15 , total integrated cost =  86934.4544916953
# RUN  16 , total integrated cost =  86934.45449168519
# RUN  17 , total integrated cost =  86934.45449168514
# RUN  18 , total integrated cost =  86934.45449168509
# RUN  19 , total integrated cost =  86934.45449168509
# Control only changes marginally.
# RUN  19 , total integrated cost =  86934.45449168509
# Improved over  19  iterations in  2.9309443669917528  seconds by  0.09192971552293727  percent.
# [ 2052.42602104 10170.16159431] [8.49544498e+00 7.63518956e-13]
# go back to ----- 4730
# ----- 4730
# interpolate adjoint :  True True True
# initial cost =  86934.45449168509
# RUN  0 , total integrated cost =  86934.45449168509
# Gradient descend method:  None
# RUN  1 , total integrated cost =  86934.45449168509
# Control only changes marginally.
# RUN  1 , total integrated cost =  86934.45449168509
# Improved over  1  iterations in  0.20987801300361753  seconds by  0.0  percent.
# [ 2052.42602104 10170.16159431] [8.49544498e+00 7.63518956e-13]
# ----- 4740
# shift ind =  0
# set cost params:  1.0 0.0 7591.181813386155
# interpolate adjoint :  True True True
# initial cost =  84018.94352118064
# RUN  0 , total integrated cost =  84018.94352118064
# Gradient descend method:  None
# RUN  1 , total integrated cost =  83994.89531766331
# RUN  2 , total integrated cost =  83980.29671930846
# RUN  3 , total integrated cost =  83970.35927936315
# RUN  4 , total integrated cost =  83962.75103636389
# RUN  5 , total integrated cost =  83957.08358133538
# RUN  6 , total integrated cost =  83950.49101843833
# RUN  7 , total integrated cost =  83946.44091335838
# RUN  8 , total integrated cost =  83943.94400341895
# RUN  9 , total integrated cost =  83942.53096486491
# RUN  10 , total integrated cost =  83939.7886401938
# RUN  11 , total integrated cost =  83938.80679774478
# RUN  12 , total integrated cost =  83938.5125606027
# RUN  13 , total integrated cost =  83938.45669594432
# RUN  14 , total integrated cost =  83938.44414383093
# RUN  15 , total integrated cost =  83938.41146149713
# RUN  16 , total integrated cost =  83938.4043317144
# RUN  17 , total integrated cost =  83938.40423213618
# RUN  18 , total integrated cost =  83938.40422997298
# RUN  19 , total integrated cost =  83938.40422990048
# RUN  20 , total integrated cost =  83938.40422990046
# Control only changes marginally.
# RUN  21 , total integrated cost =  83938.40422990046
# Improved over  21  iterations in  3.409466576995328  seconds by  0.09585849084126608  percent.
# [ 2323.98346486 11546.15865334] [8.68480334e+00 7.25426393e-13]
# go back to ----- 4740
# ----- 4740
# interpolate adjoint :  True True True
# initial cost =  83938.40422990046
# RUN  0 , total integrated cost =  83938.40422990046
# Gradient descend method:  None
# RUN  1 , total integrated cost =  83938.40422990046
# Control only changes marginally.
# RUN  1 , total integrated cost =  83938.40422990046
# Improved over  1  iterations in  0.20674619800411165  seconds by  0.0  percent.
# [ 2323.98346486 11546.15865334] [8.68480334e+00 7.25426393e-13]
# ----- 4750
# shift ind =  0
# set cost params:  1.0 0.0 6896.231092942723
# interpolate adjoint :  True True True
# initial cost =  80827.2587515063
# RUN  0 , total integrated cost =  80827.2587515063
# Gradient descend method:  None
# RUN  1 , total integrated cost =  80811.72968615717
# RUN  2 , total integrated cost =  80799.81428767115
# RUN  3 , total integrated cost =  80792.4995964611
# RUN  4 , total integrated cost =  80779.41633829814
# RUN  5 , total integrated cost =  80774.84942349422
# RUN  6 , total integrated cost =  80773.91449885325
# RUN  7 , total integrated cost =  80773.80743224492
# RUN  8 , total integrated cost =  80773.45548793046
# RUN  9 , total integrated cost =  80772.62539274414
# RUN  10 , total integrated cost =  80772.32683032527
# RUN  11 , total integrated cost =  80772.17207939985
# RUN  12 , total integrated cost =  80772.09134919892
# RUN  13 , total integrated cost =  80772.03559849404
# RUN  14 , total integrated cost =  80771.65344338903
# RUN  15 , total integrated cost =  80771.31335045618
# RUN  16 , total integrated cost =  80770.8255417957
# RUN  17 , total integrated cost =  80770.81774646477
# RUN  18 , total integrated cost =  80770.69592047235
# RUN  19 , total integrated cost =  80770.64484256718
# RUN  20 , total integrated cost =  80770.60593991875
# RUN  30 , total integrated cost =  80770.56198591483
# Control only changes marginally.
# RUN  32 , total integrated cost =  80770.5619859148
# Improved over  32  iterations in  4.89439923199825  seconds by  0.07014559997118397  percent.
# [ 2686.68088337 13004.12947117] [8.87101435e+00 6.88941403e-13]
# go back to ----- 4750
# ----- 4750
# interpolate adjoint :  True True True
# initial cost =  80770.5619859148
# RUN  0 , total integrated cost =  80770.5619859148
# Gradient descend method:  None
# RUN  1 , total integrated cost =  80770.5619859148
# Control only changes marginally.
# RUN  1 , total integrated cost =  80770.5619859148
# Improved over  1  iterations in  0.20174427097663283  seconds by  0.0  percent.
# [ 2686.68088337 13004.12947117] [8.87101435e+00 6.88941403e-13]
# ----- 4760
# shift ind =  0
# set cost params:  1.0 0.0 6213.634464049895
# interpolate adjoint :  True True True
# initial cost =  77463.05914498858
# RUN  0 , total integrated cost =  77463.05914498858
# Gradient descend method:  None
# RUN  1 , total integrated cost =  77451.64973582845
# RUN  2 , total integrated cost =  77442.4321402146
# RUN  3 , total integrated cost =  77438.93828779299
# RUN  4 , total integrated cost =  77438.14140643545
# RUN  5 , total integrated cost =  77436.9561447932
# RUN  6 , total integrated cost =  77435.51343748278
# RUN  7 , total integrated cost =  77434.30794311003
# RUN  8 , total integrated cost =  77432.19621775011
# RUN  9 , total integrated cost =  77429.91545420837
# RUN  10 , total integrated cost =  77428.80910681289
# RUN  11 , total integrated cost =  77428.33541837671
# RUN  12 , total integrated cost =  77427.94134636172
# RUN  13 , total integrated cost =  77427.42421274602
# RUN  14 , total integrated cost =  77426.93765588068
# RUN  15 , total integrated cost =  77426.89018194014
# RUN  16 , total integrated cost =  77426.83555420801
# RUN  17 , total integrated cost =  77426.81560056431
# RUN  18 , total integrated cost =  77426.80005018448
# RUN  19 , total integrated cost =  77426.79824215881
# RUN  20 , total integrated cost =  77426.79817753025
# Control only changes marginally.
# RUN  24 , total integrated cost =  77426.79786955431
# Improved over  24  iterations in  3.6892984280129895  seconds by  0.04681105527527052  percent.
# [ 3181.34771359 14696.3572025 ] [9.01104515e+00 6.53976112e-13]
# go back to ----- 4760
# ----- 4760
# interpolate adjoint :  True True True
# initial cost =  77426.79786955431
# RUN  0 , total integrated cost =  77426.79786955431
# Gradient descend method:  None
# RUN  1 , total integrated cost =  77426.79786955431
# Control only changes marginally.
# RUN  1 , total integrated cost =  77426.79786955431
# Improved over  1  iterations in  0.2006333449971862  seconds by  0.0  percent.
# [ 3181.34771359 14696.3572025 ] [9.01104515e+00 6.53976112e-13]
# ----- 4770
# shift ind =  0
# set cost params:  1.0 0.0 5546.9529835784515
# interpolate adjoint :  True True True
# initial cost =  73932.71870512917
# RUN  0 , total integrated cost =  73932.71870512917
# Gradient descend method:  None
# RUN  1 , total integrated cost =  73918.05309313709
# RUN  2 , total integrated cost =  73909.56288405444
# RUN  3 , total integrated cost =  73904.87443847761
# RUN  4 , total integrated cost =  73901.80825263116
# RUN  5 , total integrated cost =  73899.42835610695
# RUN  6 , total integrated cost =  73896.45565015264
# RUN  7 , total integrated cost =  73894.27192132917
# RUN  8 , total integrated cost =  73893.13540526656
# RUN  9 , total integrated cost =  73891.3624717072
# RUN  10 , total integrated cost =  73889.99561238734
# RUN  11 , total integrated cost =  73889.2635213616
# RUN  12 , total integrated cost =  73887.87652190973
# RUN  13 , total integrated cost =  73887.31107604473
# RUN  14 , total integrated cost =  73886.20587723196
# RUN  15 , total integrated cost =  73886.05094798518
# RUN  16 , total integrated cost =  73885.88609832975
# RUN  17 , total integrated cost =  73885.70630372046
# RUN  18 , total integrated cost =  73885.48232830092
# RUN  19 , total integrated cost =  73885.4261160521
# RUN  20 , total integrated cost =  73885.32019852161
# RUN  30 , total integrated cost =  73884.85091312467
# Control only changes marginally.
# RUN  30 , total integrated cost =  73884.85091312467
# Improved over  30  iterations in  4.439444599003764  seconds by  0.06474507206398528  percent.
# [ 3599.67023809 16191.72231136] [9.21938933e+00 6.20446055e-13]
# go back to ----- 4770
# ----- 4770
# interpolate adjoint :  True True True
# initial cost =  73884.85091312467
# RUN  0 , total integrated cost =  73884.85091312467
# Gradient descend method:  None
# RUN  1 , total integrated cost =  73884.85091312467
# Control only changes marginally.
# RUN  1 , total integrated cost =  73884.85091312467
# Improved over  1  iterations in  0.1986142590176314  seconds by  0.0  percent.
# [ 3599.67023809 16191.72231136] [9.21938933e+00 6.20446055e-13]
# ----- 4780
# shift ind =  0
# set cost params:  1.0 0.0 4893.995948849079
# interpolate adjoint :  True True True
# initial cost =  70139.48046670019
# RUN  0 , total integrated cost =  70139.48046670019
# Gradient descend method:  None
# RUN  1 , total integrated cost =  70004.11356430274
# RUN  2 , total integrated cost =  69656.1686688032
# RUN  3 , total integrated cost =  69577.06462623086
# RUN  4 , total integrated cost =  69548.98851792903
# RUN  5 , total integrated cost =  69544.27516501225
# RUN  6 , total integrated cost =  69542.45835472023
# RUN  7 , total integrated cost =  69541.20535439177
# RUN  8 , total integrated cost =  69540.71805476682
# RUN  9 , total integrated cost =  69540.35669701986
# RUN  10 , total integrated cost =  69540.16600217707
# RUN  11 , total integrated cost =  69539.67833142186
# RUN  12 , total integrated cost =  69539.4563072856
# RUN  13 , total integrated cost =  69539.33237154875
# RUN  14 , total integrated cost =  69539.2499518203
# RUN  15 , total integrated cost =  69539.19471705765
# RUN  16 , total integrated cost =  69539.14031217514
# RUN  17 , total integrated cost =  69539.12576164084
# RUN  18 , total integrated cost =  69539.08675955384
# RUN  19 , total integrated cost =  69539.07665983471
# RUN  20 , total integrated cost =  69539.04383065262
# RUN  30 , total integrated cost =  69538.84580242774
# RUN  40 , total integrated cost =  69538.82880926403
# RUN  50 , total integrated cost =  69538.8234054303
# Control only changes marginally.
# RUN  53 , total integrated cost =  69538.82340543027
# Improved over  53  iterations in  3.796647857001517  seconds by  0.856375121790478  percent.
# [ 4392.69234549 12637.01274279] [9.31759006 1.06546314]
# go back to ----- 4780
# ----- 4780
# interpolate adjoint :  True True True
# initial cost =  69538.82340543027
# RUN  0 , total integrated cost =  69538.82340543027
# Gradient descend method:  None
# RUN  1 , total integrated cost =  69538.82340543027
# Control only changes marginally.
# RUN  1 , total integrated cost =  69538.82340543027
# Improved over  1  iterations in  0.1755648120015394  seconds by  0.0  percent.
# [ 4392.69234549 12637.01274279] [9.31759006 1.06546314]
# ----- 4790
# shift ind =  0
# set cost params:  1.0 0.0 4327.324394051322
# interpolate adjoint :  True True True
# initial cost =  65815.1792853117
# RUN  0 , total integrated cost =  65815.1792853117
# Gradient descend method:  None
# RUN  1 , total integrated cost =  65550.06713458034
# RUN  2 , total integrated cost =  65477.72947004708
# RUN  3 , total integrated cost =  65453.273241878094
# RUN  4 , total integrated cost =  65446.25470489394
# RUN  5 , total integrated cost =  65443.88774316541
# RUN  6 , total integrated cost =  65442.79834233405
# RUN  7 , total integrated cost =  65442.46583037567
# RUN  8 , total integrated cost =  65442.35506172976
# RUN  9 , total integrated cost =  65442.27708171815
# RUN  10 , total integrated cost =  65442.20766088937
# RUN  11 , total integrated cost =  65442.17322536011
# RUN  12 , total integrated cost =  65442.14109197994
# RUN  13 , total integrated cost =  65442.12495494244
# RUN  14 , total integrated cost =  65442.09010449222
# RUN  15 , total integrated cost =  65442.08483478965
# RUN  16 , total integrated cost =  65442.0508718016
# RUN  17 , total integrated cost =  65442.03923698458
# RUN  18 , total integrated cost =  65442.033463684114
# RUN  19 , total integrated cost =  65442.0334636841
# RUN  20 , total integrated cost =  65442.0334636841
# Control only changes marginally.
# RUN  20 , total integrated cost =  65442.0334636841
# Improved over  20  iterations in  1.5985615639947355  seconds by  0.5669601233022377  percent.
# [ 5061.0427705  11346.93681107] [9.46595688 1.67666431]
