# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import sys
import pickle
import random

path = os.getcwd().split(os.sep + 'GUI')[0]
if path not in sys.path:
    print("not here")
    sys.path.append(path)

from neurolib.models.aln import ALNModel
from neurolib.utils import plotFunctions as plotFunc
from neurolib.utils import costFunctions as cost
import neurolib.dashboard.functions as functions
import neurolib.dashboard.data as data
    
# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2 

#path = os.path.join(os.getcwd(), "plots")
# Out:
# not here

# %%
exc = 0.4
inh = 0.316

# %%
aln = ALNModel()
N = aln.params.N

data.set_parameters(aln)

state_vars = aln.state_vars
init_vars = aln.init_vars

##############################################################
def setinit(init_vars_, model):
    state_vars = model.state_vars
    init_vars = model.init_vars
    for iv in range(len(init_vars)):
        for sv in range(len(state_vars)):
            if state_vars[sv] in init_vars[iv]:
                #print("set init vars ", )
                if model.params[init_vars[iv]].ndim == 2:
                    model.params[init_vars[iv]][0,:] = init_vars_[sv]
                else:
                    model.params[init_vars[iv]][0] = init_vars_[sv]
                    
##############################################################               
def setmaxmincontrol(max_c_c, min_c_c, max_c_r, min_c_r):
    import numpy as np
    
    max_cntrl = np.zeros(( 6 ))
    min_cntrl = np.zeros(( 6 ))
    
    max_cntrl[0] = max_c_c
    min_cntrl[0] = min_c_c
    max_cntrl[1] = max_c_c
    min_cntrl[1] = min_c_c
    max_cntrl[2] = max_c_r
    min_cntrl[2] = min_c_r
    max_cntrl[3] = max_c_r
    min_cntrl[3] = min_c_r
    max_cntrl[4] = max_c_r
    min_cntrl[4] = min_c_r
    max_cntrl[5] = max_c_r
    min_cntrl[5] = min_c_r
            
    return max_cntrl, min_cntrl

# %%
dur = 500.
t_pen = 0.96

# %%
file_ = '1_I.pickle'
folder = str(os.getcwd().split('data_2')[1])
print(folder)
case = '1'
# Out:
# /high_osc

# %%
dur_pre = 10
dur_post = 10

n_pre = int(np.around(dur_pre/aln.params.dt + 1.,1))
n_post = int(np.around(dur_post/aln.params.dt + 1.,1))

tol = 1e-10
start_step = 10.
c_scheme = np.zeros(( 1,1 ))
c_scheme[0,0] = 1.
u_mat = np.identity(1)
u_scheme = np.array([[1.]])

p_var = [0]
c_var = [0]
wp = 1. / (dur - t_pen * dur)

if case in ['1', '2']:    # osc to high
    max_I = [3., -3.]
else:
    max_I = [-3., 3.]
    
if case in ['1', '3']:    # sparsity
    factor_ws = 1.
    factor_we = 0.
else:
    factor_ws = 0.
    factor_we = 1.
    
maxC = [5., -5., 0.18, 0.]
max_cntrl, min_cntrl = setmaxmincontrol(maxC[0], maxC[1], maxC[2], maxC[3])

# %%
bestControl_ = None

if os.path.isfile(file_) :
    print("file found")
    
    with open(file_,'rb') as f:
        load_array = pickle.load(f)

    bestControl_ = load_array[0]

# %%
# get initial parameters and target states
data.set_parameters(aln)

aln.params.ext_exc_current = exc * 5.
aln.params.ext_inh_current = inh * 5.

aln.params.duration = 3000.

control0 = aln.getZeroControl()
control0 = functions.step_control(aln, maxI_ = max_I[0])

aln.run(control=control0)
plt.plot(aln.t, aln.rates_exc[0,:])
plt.show()

target_rates = np.zeros((2))
target_rates[0] = aln.rates_exc[0,-1] 
target_rates[1] = aln.rates_inh[0,-1]

control0 = functions.step_control(aln, maxI_ = max_I[1])
aln.run(control=control0)
plt.plot(aln.t, aln.rates_exc[0,:])
plt.show()

init_state_vars = np.zeros(( len(state_vars) ))
for j in range(len(state_vars)):
    if aln.state[state_vars[j]].size == 1:
        init_state_vars[j] = aln.state[state_vars[j]][0]
    else:
        init_state_vars[j] = aln.state[state_vars[j]][0,-1]

initVars = init_state_vars
target = [target_rates[0], target_rates[1]]

print(initVars[0])
print(target[0])
# Out:
# 2.664662481344133
# 25.98168358603569

# %%
# get uncontrolled cost
data.set_parameters(aln)
    
aln.params.duration = dur

target_ = aln.getZeroTarget()
target_[:,0,:] = target[0]
target_[:,1,:] = target[1]

cost.setParams(wp, 0.0, 0.0)

setinit(initVars, aln)
control0 = aln.getZeroControl()

cgv = None
max_it = 0

bestControl_init_, bestState_init_, cost_init_, runtime_init_, grad_init_, phi_init_, phi1_, costnode_init_ = aln.A1(
    control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
    startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
    t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
    prec_variables_ = p_var, transition_time_ = t_pen)

cost_uncontrolled = cost_init_[0]
# Out:
# set cost params:  0.05 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  336.5181300805788
# RUN  0 , total integrated cost =  336.5181300805788
# Gradient descend method:  None
# RUN  0 , total integrated cost =  336.5181300805788
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.

# %%
cgv = None
j = 0

aln.params.duration = dur
setinit(initVars, aln)

target_ = aln.getZeroTarget()
target_[:,0,:] = target[0]
target_[:,1,:] = target[1]

control0 = aln.getZeroControl()
cost.setParams(wp, 0., 10.)
max_it = int(0)

aln.run(control=control0)
plt.plot(aln.t, aln.rates_exc[0,:])
plt.show

#control0[0,1,2200:2800] = -5.

bestControl_, bestState_, cost_, runtime_, grad_, phi_, phi1_, costnode_ = aln.A1(
    control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
    startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
    t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
    prec_variables_ = p_var, transition_time_ = t_pen)

if True:
    plot_time_array = np.arange(0.,round(dur+aln.params.dt,1),aln.params.dt)
    target_ = aln.getZeroTarget()
    target_[:,0,:] = target[0]
    target_[:,1,:] = target[1]

    fig, ax = plt.subplots(2,1, constrained_layout=True, figsize = (4,6) )
    ax[1].plot(plot_time_array, bestControl_[0,0,n_pre-1:-n_post+1], color = 'red')
    ax[0].plot(plot_time_array, bestState_[0,0,n_pre-1:-n_post+1], color= 'red')
    ax[1].plot(plot_time_array, bestControl_[0,1,n_pre-1:-n_post+1], color = 'blue')
    ax[0].plot(plot_time_array, bestState_[0,1,n_pre-1:-n_post+1], color= 'blue')
    ax[0].plot(plot_time_array, target_[0,0,n_pre-1:-n_post+1], linestyle = '--', color='red')
    ax[0].plot(plot_time_array, target_[0,1,n_pre-1:-n_post+1], linestyle = '--', color='blue')

    for k in range(2):
        ax[k].set_xlim(0.,dur)
        ax[k].axvspan(dur*t_pen, dur, alpha=0.2, color='gray')
    plt.show()

print('uncontrolled cost : ', cost_uncontrolled)
print('cost splitting : ', costnode_[0][0][0], costnode_[2][0][:2])
# Out:
# set cost params:  0.05 0.0 10.0
# interpolate adjoint :  True True True
# initial cost =  336.5181300805788
# RUN  0 , total integrated cost =  336.5181300805788
# Gradient descend method:  None
# RUN  0 , total integrated cost =  336.5181300805788
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  336.5181300805788
# cost splitting :  6730.362601611578 [0. 0.]

# %%
c_var = [0,1]
max_it = int(30)
conv = False

tol = 1e-6
    
while not conv:

    weight_ = random.random() * ( cost_uncontrolled -
                                 costnode_[0][0][0] ) / sum( costnode_[2][0][:] )

    aln.params.duration = dur
    cost.setParams(wp, weight_ * factor_we, weight_ * factor_ws)
    weights_ = cost.getParams()

    setinit(initVars, aln)

    target_ = aln.getZeroTarget()
    target_[:,0,:] = target[0]
    target_[:,1,:] = target[1]

    control0 = aln.getZeroControl()
    control0 = bestControl_[:,:,n_pre-1:-n_post+1]

    bestControl_, bestState_, cost_, runtime_, grad_, phi_, phi1_, costnode_ = aln.A1(
        control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
        prec_variables_ = p_var, transition_time_ = t_pen)

    if cost_[2] == 0.:
        conv = True

    #print('uncontrolled cost : ', cost_uncontrolled[i])
    print('cost splitting : ', costnode_[0][0][0], costnode_[2][0][:2])

    if conv and True:
        time_ = np.arange(-dur_pre,round(dur+dur_post+aln.params.dt,1),aln.params.dt)
        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[0]
        target_[:,1,:] = target[1]

        fig, ax = plt.subplots(2,1, constrained_layout=True, figsize = (4,4) )
        ax[1].plot(time_, bestControl_[0,0,:], color = 'red')
        ax[0].plot(time_, bestState_[0,0,:], color= 'red')
        ax[1].plot(time_, bestControl_[0,1,:], color = 'blue')
        ax[0].plot(time_, bestState_[0,1,:], color= 'blue')
        ax[0].plot(time_, target_[0,0,:], linestyle = '--', color='red')
        ax[0].plot(time_, target_[0,1,:], linestyle = '--', color='blue')
        ax[0].set_xlim(-dur_pre,dur+dur_post)
        ax[1].set_xlim(-dur_pre,dur+dur_post)
        ax[0].axvspan(dur*t_pen, dur, alpha=0.2, color='gray')
        plt.show()

    with open(file_,'wb') as f:
        pickle.dump([bestControl_, bestState_, cost_, costnode_, weights_], f)
# Out:
# set cost params:  0.05 0.0 479.76134278446347
# interpolate adjoint :  True True True
# initial cost =  185.76963215507746
# RUN  0 , total integrated cost =  185.76963215507746
# Gradient descend method:  None
# RUN  1 , total integrated cost =  185.76963215507746
# Control only changes marginally.
# RUN  1 , total integrated cost =  185.76963215507746
# Improved over  1  iterations in  0.2613756890059449  seconds by  0.0  percent.
# cost splitting :  0.49564043193657786 [0.38716094 0.        ]

# %%
c_var = [0,1]
max_it = int(30)
conv = False

tol = 1e-8
    
while not conv:

    weight_ = random.random() * ( cost_uncontrolled -
                                 costnode_[0][0][0] ) / sum( costnode_[2][0][:] )

    aln.params.duration = dur
    cost.setParams(wp, weight_ * factor_we, weight_ * factor_ws)
    weights_ = cost.getParams()

    setinit(initVars, aln)

    target_ = aln.getZeroTarget()
    target_[:,0,:] = target[0]
    target_[:,1,:] = target[1]

    control0 = aln.getZeroControl()
    control0 = bestControl_[:,:,n_pre-1:-n_post+1]

    bestControl_, bestState_, cost_, runtime_, grad_, phi_, phi1_, costnode_ = aln.A1(
        control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
        prec_variables_ = p_var, transition_time_ = t_pen)

    if cost_[2] == 0.:
        conv = True

    #print('uncontrolled cost : ', cost_uncontrolled[i])
    print('cost splitting : ', costnode_[0][0][0], costnode_[2][0][:2])

    if conv and True:
        time_ = np.arange(-dur_pre,round(dur+dur_post+aln.params.dt,1),aln.params.dt)
        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[0]
        target_[:,1,:] = target[1]

        fig, ax = plt.subplots(2,1, constrained_layout=True, figsize = (4,4) )
        ax[1].plot(time_, bestControl_[0,0,:], color = 'red')
        ax[0].plot(time_, bestState_[0,0,:], color= 'red')
        ax[1].plot(time_, bestControl_[0,1,:], color = 'blue')
        ax[0].plot(time_, bestState_[0,1,:], color= 'blue')
        ax[0].plot(time_, target_[0,0,:], linestyle = '--', color='red')
        ax[0].plot(time_, target_[0,1,:], linestyle = '--', color='blue')
        ax[0].set_xlim(-dur_pre,dur+dur_post)
        ax[1].set_xlim(-dur_pre,dur+dur_post)
        ax[0].axvspan(dur*t_pen, dur, alpha=0.2, color='gray')
        plt.show()

    with open(file_,'wb') as f:
        pickle.dump([bestControl_, bestState_, cost_, costnode_, weights_], f)
# Out:
# set cost params:  0.05 0.0 42.02679723245852
# interpolate adjoint :  True True True
# initial cost =  16.29591614054607
# RUN  0 , total integrated cost =  16.29591614054607
# Gradient descend method:  None
# RUN  1 , total integrated cost =  16.27115941693109
# RUN  2 , total integrated cost =  15.374039974173343
# RUN  3 , total integrated cost =  15.050629549167027
# RUN  4 , total integrated cost =  15.043499573003789
# RUN  5 , total integrated cost =  14.922884099175839
# RUN  6 , total integrated cost =  11.904387495492992
# RUN  7 , total integrated cost =  11.898491589008144
# RUN  8 , total integrated cost =  11.89843405752011
# RUN  9 , total integrated cost =  11.898414008394132
# RUN  10 , total integrated cost =  11.89835449756151
# RUN  11 , total integrated cost =  11.898334455577244
# RUN  12 , total integrated cost =  11.89827145444777
# RUN  13 , total integrated cost =  11.89760917608411
# RUN  14 , total integrated cost =  11.776330177412003
# RUN  15 , total integrated cost =  11.771278895886422
# RUN  16 , total integrated cost =  11.771225360326042
# RUN  17 , total integrated cost =  11.771204153787973
# RUN  18 , total integrated cost =  11.77115460865603
# RUN  19 , total integrated cost =  11.771133651410889
# RUN  20 , total integrated cost =  11.771083254303788
# RUN  30 , total integrated cost =  11.770721494914001
# RUN  30 , total integrated cost =  11.770721494914001
# Improved over  30  iterations in  4.134266758017475  seconds by  27.768887656293685  percent.
# cost splitting :  0.000816973568591967 [0.24288947 0.03718614]
# set cost params:  0.05 0.0 982.2483209708281
# interpolate adjoint :  True True True
# initial cost =  275.1038332575668
# RUN  0 , total integrated cost =  275.1038332575668
# Gradient descend method:  None
# RUN  1 , total integrated cost =  275.1031511135127
# RUN  2 , total integrated cost =  275.1028954666591
# RUN  3 , total integrated cost =  275.1022197792676
# RUN  4 , total integrated cost =  275.1019645149722
# RUN  5 , total integrated cost =  275.10126707651705
# RUN  6 , total integrated cost =  275.1010124432756
# RUN  7 , total integrated cost =  275.10031910788973
# RUN  8 , total integrated cost =  275.1000641535583
# RUN  9 , total integrated cost =  275.0993690118835
# RUN  10 , total integrated cost =  275.09911422084593
# RUN  11 , total integrated cost =  275.0984200431024
# RUN  12 , total integrated cost =  275.0981651757226
# RUN  13 , total integrated cost =  275.0974705865593
# RUN  14 , total integrated cost =  275.0972157662092
# RUN  15 , total integrated cost =  275.0965215613442
# RUN  16 , total integrated cost =  275.0962667145367
# RUN  17 , total integrated cost =  275.09557244201176
# RUN  18 , total integrated cost =  275.0953176064826
# RUN  19 , total integrated cost =  275.09462338873305
# RUN  20 , total integrated cost =  275.0943685618437
# RUN  30 , total integrated cost =  275.0896232564701
# RUN  30 , total integrated cost =  275.0896232564701
# Improved over  30  iterations in  3.7485861540189944  seconds by  0.005165322826826468  percent.
# cost splitting :  0.0007422028713035989 [0.24288947 0.03717167]
# set cost params:  0.05 0.0 198.99391242414583
# interpolate adjoint :  True True True
# initial cost =  55.73049940331595
# RUN  0 , total integrated cost =  55.73049940331595
# Gradient descend method:  None
# RUN  1 , total integrated cost =  52.63602780418725
# RUN  2 , total integrated cost =  52.595902855347404
# RUN  3 , total integrated cost =  52.59463437013324
# RUN  4 , total integrated cost =  52.59458870988502
# RUN  5 , total integrated cost =  52.594458992894964
# RUN  6 , total integrated cost =  52.59442418984298
# RUN  7 , total integrated cost =  52.594353144495706
# RUN  8 , total integrated cost =  52.594314995008205
# RUN  9 , total integrated cost =  52.59423139673947
# RUN  10 , total integrated cost =  52.5942004374471
# RUN  11 , total integrated cost =  52.5941432402872
# RUN  12 , total integrated cost =  52.59411269718542
# RUN  13 , total integrated cost =  52.59405815645228
# RUN  14 , total integrated cost =  52.59402774783946
# RUN  15 , total integrated cost =  52.59397284426215
# RUN  16 , total integrated cost =  52.59394243597088
# RUN  17 , total integrated cost =  52.59388753609237
# RUN  18 , total integrated cost =  52.59385712926539
# RUN  19 , total integrated cost =  52.59380222992946
# RUN  20 , total integrated cost =  52.59377182436385
# RUN  30 , total integrated cost =  52.59334532302679
# RUN  30 , total integrated cost =  52.59334532302679
# Improved over  30  iterations in  3.345988460991066  seconds by  5.629151207825899  percent.
# cost splitting :  0.0003661274383503831 [0.23403604 0.03026012]
# set cost params:  0.05 0.0 849.8755470077052
# interpolate adjoint :  True True True
# initial cost =  224.6188622836868
# RUN  0 , total integrated cost =  224.6188622836868
# Gradient descend method:  None
# RUN  1 , total integrated cost =  224.61842026665374
# RUN  2 , total integrated cost =  224.61825152901187
# RUN  3 , total integrated cost =  224.6176469913992
# RUN  4 , total integrated cost =  224.61752033413
# RUN  5 , total integrated cost =  224.61725128923945
# RUN  6 , total integrated cost =  224.6171464266132
# RUN  7 , total integrated cost =  224.61694006800968
# RUN  8 , total integrated cost =  224.61683808291585
# RUN  9 , total integrated cost =  224.61664349984488
# RUN  10 , total integrated cost =  224.61654295573837
# RUN  11 , total integrated cost =  224.61636053662312
# RUN  12 , total integrated cost =  224.6162604598389
# RUN  13 , total integrated cost =  224.61608329175584
# RUN  14 , total integrated cost =  224.61598298090593
# RUN  15 , total integrated cost =  224.61579984852435
# RUN  16 , total integrated cost =  224.6156997766814
# RUN  17 , total integrated cost =  224.61552261744868
# RUN  18 , total integrated cost =  224.61542231427822
# RUN  19 , total integrated cost =  224.61523918191
# RUN  20 , total integrated cost =  224.61513911572627
# RUN  30 , total integrated cost =  224.61374042452078
# RUN  30 , total integrated cost =  224.61374042452078
# Improved over  30  iterations in  3.902127487002872  seconds by  0.0022802444611897954  percent.
# cost splitting :  0.001353185353204402 [0.23402995 0.03026012]
# set cost params:  0.05 0.0 15.513693046939611
# interpolate adjoint :  True True True
# initial cost =  4.100182771056239
# RUN  0 , total integrated cost =  4.100182771056239
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.100128590415511
# RUN  2 , total integrated cost =  4.023248221707722
# RUN  3 , total integrated cost =  4.023211290504783
# RUN  4 , total integrated cost =  3.740321416247894
# RUN  5 , total integrated cost =  3.5787336777046574
# RUN  6 , total integrated cost =  3.569552544377696
# RUN  7 , total integrated cost =  3.569147166891884
# RUN  8 , total integrated cost =  3.5691451036567376
# RUN  9 , total integrated cost =  3.5691442184137157
# RUN  10 , total integrated cost =  3.5691430220338183
# RUN  11 , total integrated cost =  3.569142144023404
# RUN  12 , total integrated cost =  3.5691409390177875
# RUN  13 , total integrated cost =  3.56914005890589
# RUN  14 , total integrated cost =  3.569138856530043
# RUN  15 , total integrated cost =  3.5691379771490737
# RUN  16 , total integrated cost =  3.5691367739742335
# RUN  17 , total integrated cost =  3.5691358944011995
# RUN  18 , total integrated cost =  3.5691346915454245
# RUN  19 , total integrated cost =  3.569133812084932
# RUN  20 , total integrated cost =  3.5691326091793054
# RUN  30 , total integrated cost =  3.5691221984978148
# RUN  30 , total integrated cost =  3.5691221984978148
# Improved over  30  iterations in  3.3654321579961106  seconds by  12.952119508116922  percent.
# cost splitting :  5.634924916300397e-05 [0.20046348 0.02959905]
# set cost params:  0.05 0.0 108.54408570288743
# interpolate adjoint :  True True True
# initial cost =  24.97192915420032
# RUN  0 , total integrated cost =  24.97192915420032
# Gradient descend method:  None
# RUN  1 , total integrated cost =  24.97190849946987
# RUN  2 , total integrated cost =  24.97189573781803
# RUN  3 , total integrated cost =  24.971867433669093
# RUN  4 , total integrated cost =  24.82994416253432
# RUN  5 , total integrated cost =  24.537807379366576
# RUN  6 , total integrated cost =  24.536492796467392
# RUN  7 , total integrated cost =  24.536471715613338
# RUN  8 , total integrated cost =  24.534755492481143
# RUN  9 , total integrated cost =  24.53425659847327
# RUN  10 , total integrated cost =  24.53425659847327
# Control only changes marginally.
# RUN  10 , total integrated cost =  24.53425659847327
# Improved over  10  iterations in  1.6141851259744726  seconds by  1.752658166793779  percent.
# cost splitting :  0.0003736595451296782 [0.19643055 0.02959962]
# set cost params:  0.05 0.0 189.10570362583695
# interpolate adjoint :  True True True
# initial cost =  42.743612623537224
# RUN  0 , total integrated cost =  42.743612623537224
# Gradient descend method:  None
# RUN  1 , total integrated cost =  42.7436009020566
# RUN  2 , total integrated cost =  42.74359621787608
# RUN  3 , total integrated cost =  42.74359621787608
# Control only changes marginally.
# RUN  3 , total integrated cost =  42.74359621787608
# Improved over  3  iterations in  0.6112133080023341  seconds by  3.83815502118523e-05  percent.
# cost splitting :  0.000480823436729156 [0.19643044 0.02959962]
# set cost params:  0.05 0.0 1059.8590448125979
# interpolate adjoint :  True True True
# initial cost =  239.56001990842816
# RUN  0 , total integrated cost =  239.56001990842816
# Gradient descend method:  None
# RUN  1 , total integrated cost =  239.55974260771666
# RUN  2 , total integrated cost =  239.55970423244645
# RUN  3 , total integrated cost =  239.55965283224967
# RUN  4 , total integrated cost =  239.55959810643273
# RUN  5 , total integrated cost =  239.55950804627233
# RUN  6 , total integrated cost =  238.40128876698313
# RUN  7 , total integrated cost =  238.39461022134034
# RUN  8 , total integrated cost =  238.39459153968784
# RUN  9 , total integrated cost =  238.39459153968784
# Control only changes marginally.
# RUN  9 , total integrated cost =  238.39459153968784
# Improved over  9  iterations in  1.583402363001369  seconds by  0.48648700613141216  percent.
# cost splitting :  0.003809172798694389 [0.19533075 0.02959953]
# set cost params:  0.05 0.0 524.3662492312174
# interpolate adjoint :  True True True
# initial cost =  117.94604235698823
# RUN  0 , total integrated cost =  117.94604235698823
# Gradient descend method:  None
# RUN  1 , total integrated cost =  117.9459914384774
# RUN  2 , total integrated cost =  117.92706101815075
# RUN  3 , total integrated cost =  117.92413312400473
# RUN  4 , total integrated cost =  117.92410900898085
# RUN  5 , total integrated cost =  117.92410900898085
# Control only changes marginally.
# RUN  5 , total integrated cost =  117.92410900898085
# Improved over  5  iterations in  0.9563964339904487  seconds by  0.018596086455360705  percent.
# cost splitting :  0.0027119415052263636 [0.19533075 0.02955781]
# set cost params:  0.05 0.0 261.01158529886163
# interpolate adjoint :  True True True
# initial cost =  58.69865650704743
# RUN  0 , total integrated cost =  58.69865650704743
# Gradient descend method:  None
# RUN  1 , total integrated cost =  58.69860716259906
# RUN  2 , total integrated cost =  58.69354778224924
# RUN  3 , total integrated cost =  58.62857594412279
# RUN  4 , total integrated cost =  58.62773481165699
# RUN  5 , total integrated cost =  58.62772516188683
# RUN  6 , total integrated cost =  58.6277070676508
# RUN  7 , total integrated cost =  58.62770128624139
# RUN  8 , total integrated cost =  58.627693521976866
# RUN  9 , total integrated cost =  58.627314498677976
# RUN  10 , total integrated cost =  58.62713891434851
# RUN  11 , total integrated cost =  58.62713891434851
# Control only changes marginally.
# RUN  11 , total integrated cost =  58.62713891434851
# Improved over  11  iterations in  1.5437950199993793  seconds by  0.12183855126282594  percent.
# cost splitting :  0.0008152830105643577 [0.19507567 0.02953925]
# set cost params:  0.05 0.0 335.9179219239406
# interpolate adjoint :  True True True
# initial cost =  75.45222023923262
# RUN  0 , total integrated cost =  75.45222023923262
# Gradient descend method:  None
# RUN  1 , total integrated cost =  75.45222023923262
# Control only changes marginally.
# RUN  1 , total integrated cost =  75.45222023923262
# Improved over  1  iterations in  0.2235964889987372  seconds by  0.0  percent.
# cost splitting :  0.0008152830105643577 [0.19507567 0.02953925]

# %%
c_var = [0,1]
max_it = int(30)
conv = False

tol = 1e-10
    
while not conv:

    weight_ = random.random() * ( cost_uncontrolled -
                                 costnode_[0][0][0] ) / sum( costnode_[2][0][:] )

    aln.params.duration = dur
    cost.setParams(wp, weight_ * factor_we, weight_ * factor_ws)
    weights_ = cost.getParams()

    setinit(initVars, aln)

    target_ = aln.getZeroTarget()
    target_[:,0,:] = target[0]
    target_[:,1,:] = target[1]

    control0 = aln.getZeroControl()
    control0 = bestControl_[:,:,n_pre-1:-n_post+1]

    bestControl_, bestState_, cost_, runtime_, grad_, phi_, phi1_, costnode_ = aln.A1(
        control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
        prec_variables_ = p_var, transition_time_ = t_pen)

    if cost_[2] == 0.:
        conv = True

    #print('uncontrolled cost : ', cost_uncontrolled[i])
    print('cost splitting : ', costnode_[0][0][0], costnode_[2][0][:2])

    if conv and True:
        time_ = np.arange(-dur_pre,round(dur+dur_post+aln.params.dt,1),aln.params.dt)
        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[0]
        target_[:,1,:] = target[1]

        fig, ax = plt.subplots(2,1, constrained_layout=True, figsize = (4,4) )
        ax[1].plot(time_, bestControl_[0,0,:], color = 'red')
        ax[0].plot(time_, bestState_[0,0,:], color= 'red')
        ax[1].plot(time_, bestControl_[0,1,:], color = 'blue')
        ax[0].plot(time_, bestState_[0,1,:], color= 'blue')
        ax[0].plot(time_, target_[0,0,:], linestyle = '--', color='red')
        ax[0].plot(time_, target_[0,1,:], linestyle = '--', color='blue')
        ax[0].set_xlim(-dur_pre,dur+dur_post)
        ax[1].set_xlim(-dur_pre,dur+dur_post)
        ax[0].axvspan(dur*t_pen, dur, alpha=0.2, color='gray')
        plt.show()

    with open(file_,'wb') as f:
        pickle.dump([bestControl_, bestState_, cost_, costnode_, weights_], f)
# Out:
# set cost params:  0.05 0.0 1303.8104409510497
# interpolate adjoint :  True True True
# initial cost =  292.855327641041
# RUN  0 , total integrated cost =  292.855327641041
# Gradient descend method:  None
# RUN  1 , total integrated cost =  292.8551021340495
# RUN  2 , total integrated cost =  292.8122624038625
# RUN  3 , total integrated cost =  292.05233747837906
# RUN  4 , total integrated cost =  292.0474599120273
# RUN  5 , total integrated cost =  292.0474345652244
# RUN  6 , total integrated cost =  292.04736300661114
# RUN  7 , total integrated cost =  292.0473088206974
# RUN  8 , total integrated cost =  292.0472961136501
# RUN  9 , total integrated cost =  292.0472851749643
# RUN  10 , total integrated cost =  292.04727473407206
# RUN  11 , total integrated cost =  292.0472654249118
# RUN  12 , total integrated cost =  292.0472512375231
# RUN  13 , total integrated cost =  292.0472397777759
# RUN  14 , total integrated cost =  292.0472183249767
# RUN  15 , total integrated cost =  292.0472000343892
# RUN  16 , total integrated cost =  292.0471780806707
# RUN  17 , total integrated cost =  292.0471602845709
# RUN  18 , total integrated cost =  292.04713624023447
# RUN  19 , total integrated cost =  292.04711649077444
# RUN  20 , total integrated cost =  292.04709959108686
# RUN  30 , total integrated cost =  292.0468219117301
# RUN  30 , total integrated cost =  292.0468219117301
# Improved over  30  iterations in  3.719788123999024  seconds by  0.2760768382885459  percent.
# cost splitting :  0.007848223118039338 [0.19360916 0.03038539]
# set cost params:  0.05 0.0 1021.5890474462989
# interpolate adjoint :  True True True
# initial cost =  228.83076863206975
# RUN  0 , total integrated cost =  228.83076863206975
# Gradient descend method:  None
# RUN  1 , total integrated cost =  228.83064698643832
# RUN  2 , total integrated cost =  228.8305477104593
# RUN  3 , total integrated cost =  228.83020908259357
# RUN  4 , total integrated cost =  228.8301993965507
# RUN  5 , total integrated cost =  228.83016423176315
# RUN  6 , total integrated cost =  228.83013689861812
# RUN  7 , total integrated cost =  228.82662122706515
# RUN  8 , total integrated cost =  228.82561990095718
# RUN  9 , total integrated cost =  228.82489954362921
# RUN  10 , total integrated cost =  228.77828082858153
# RUN  11 , total integrated cost =  228.77811545110222
# RUN  12 , total integrated cost =  228.77810379860946
# RUN  13 , total integrated cost =  228.77808897091117
# RUN  14 , total integrated cost =  228.7780714127651
# RUN  15 , total integrated cost =  228.7780480479893
# RUN  16 , total integrated cost =  228.7780379635938
# RUN  17 , total integrated cost =  228.77802637039363
# RUN  18 , total integrated cost =  228.77801621811372
# RUN  19 , total integrated cost =  228.77800469477395
# RUN  20 , total integrated cost =  228.7779946298664
# RUN  30 , total integrated cost =  228.77781737241546
# RUN  30 , total integrated cost =  228.77781737241546
# Improved over  30  iterations in  3.9638728449936025  seconds by  0.023139921248713335  percent.
# cost splitting :  0.0020622882519586213 [0.19351403 0.03042897]
# set cost params:  0.05 0.0 887.4946968277251
# interpolate adjoint :  True True True
# initial cost =  198.74832644735622
# RUN  0 , total integrated cost =  198.74832644735622
# Gradient descend method:  None
# RUN  1 , total integrated cost =  198.74831266737277
# RUN  2 , total integrated cost =  198.7483062009512
# RUN  3 , total integrated cost =  198.74829833732852
# RUN  4 , total integrated cost =  198.7482922177911
# RUN  5 , total integrated cost =  198.74828505205284
# RUN  6 , total integrated cost =  198.74827892726125
# RUN  7 , total integrated cost =  198.7482717588083
# RUN  8 , total integrated cost =  198.7482656340354
# RUN  9 , total integrated cost =  198.74825846559145
# RUN  10 , total integrated cost =  198.74825234083647
# RUN  11 , total integrated cost =  198.74824517239927
# RUN  12 , total integrated cost =  198.74823904766453
# RUN  13 , total integrated cost =  198.74823187923644
# RUN  14 , total integrated cost =  198.74822575452148
# RUN  15 , total integrated cost =  198.7482185861032
# RUN  16 , total integrated cost =  198.74821246140897
# RUN  17 , total integrated cost =  198.7482052929935
# RUN  18 , total integrated cost =  198.74819916831976
# RUN  19 , total integrated cost =  198.74819199991654
# RUN  20 , total integrated cost =  198.748185875263
# RUN  30 , total integrated cost =  198.74811941038658
# RUN  30 , total integrated cost =  198.74811941038658
# Improved over  30  iterations in  3.847069569019368  seconds by  0.00010417042163624046  percent.
# cost splitting :  0.002357460006578279 [0.19351324 0.0304295 ]
# set cost params:  0.05 0.0 1181.259554802128
# interpolate adjoint :  True True True
# initial cost =  264.5346290684381
# RUN  0 , total integrated cost =  264.5346290684381
# Gradient descend method:  None
# RUN  1 , total integrated cost =  264.53460244453044

# %%
c_var = [0,1]
max_it = int(30)
conv = False

tol = 1e-12
    
while not conv:

    weight_ = random.random() * ( cost_uncontrolled -
                                 costnode_[0][0][0] ) / sum( costnode_[2][0][:] )

    aln.params.duration = dur
    cost.setParams(wp, weight_ * factor_we, weight_ * factor_ws)
    weights_ = cost.getParams()

    setinit(initVars, aln)

    target_ = aln.getZeroTarget()
    target_[:,0,:] = target[0]
    target_[:,1,:] = target[1]

    control0 = aln.getZeroControl()
    control0 = bestControl_[:,:,n_pre-1:-n_post+1]

    bestControl_, bestState_, cost_, runtime_, grad_, phi_, phi1_, costnode_ = aln.A1(
        control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
        prec_variables_ = p_var, transition_time_ = t_pen)

    if cost_[2] == 0.:
        conv = True

    #print('uncontrolled cost : ', cost_uncontrolled[i])
    print('cost splitting : ', costnode_[0][0][0], costnode_[2][0][:2])

    if conv and True:
        time_ = np.arange(-dur_pre,round(dur+dur_post+aln.params.dt,1),aln.params.dt)
        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[0]
        target_[:,1,:] = target[1]

        fig, ax = plt.subplots(2,1, constrained_layout=True, figsize = (4,4) )
        ax[1].plot(time_, bestControl_[0,0,:], color = 'red')
        ax[0].plot(time_, bestState_[0,0,:], color= 'red')
        ax[1].plot(time_, bestControl_[0,1,:], color = 'blue')
        ax[0].plot(time_, bestState_[0,1,:], color= 'blue')
        ax[0].plot(time_, target_[0,0,:], linestyle = '--', color='red')
        ax[0].plot(time_, target_[0,1,:], linestyle = '--', color='blue')
        ax[0].set_xlim(-dur_pre,dur+dur_post)
        ax[1].set_xlim(-dur_pre,dur+dur_post)
        ax[0].axvspan(dur*t_pen, dur, alpha=0.2, color='gray')
        plt.show()

    with open(file_,'wb') as f:
        pickle.dump([bestControl_, bestState_, cost_, costnode_, weights_], f)
# Out:
# -------  0 0.4000000000000001 0.3500000000000001
# -------  1 0.4250000000000001 0.3500000000000001
# -------  2 0.4000000000000001 0.3750000000000001
# -------  3 0.4250000000000001 0.3750000000000001
# -------  4 0.4500000000000001 0.3750000000000001
# -------  5 0.4000000000000001 0.40000000000000013
# -------  6 0.4250000000000001 0.40000000000000013
# -------  7 0.4500000000000001 0.40000000000000013
# -------  8 0.47500000000000014 0.40000000000000013
# -------  9 0.4000000000000001 0.42500000000000016
# -------  10 0.4250000000000001 0.42500000000000016
# -------  11 0.4500000000000001 0.42500000000000016
# -------  12 0.47500000000000014 0.42500000000000016
# -------  13 0.4000000000000001 0.4500000000000002
# -------  14 0.4250000000000001 0.4500000000000002
# -------  15 0.4500000000000001 0.4500000000000002
# -------  16 0.47500000000000014 0.4500000000000002
# -------  17 0.5000000000000002 0.4500000000000002
# -------  18 0.4000000000000001 0.4750000000000002
# -------  19 0.4250000000000001 0.4750000000000002
# -------  20 0.4500000000000001 0.4750000000000002
# -------  21 0.47500000000000014 0.4750000000000002
# -------  22 0.5000000000000002 0.4750000000000002
# -------  23 0.5250000000000001 0.4750000000000002
# -------  24 0.4000000000000001 0.5000000000000002
# -------  25 0.4250000000000001 0.5000000000000002
# -------  26 0.4500000000000001 0.5000000000000002
# -------  27 0.47500000000000014 0.5000000000000002
# -------  28 0.5000000000000002 0.5000000000000002
# -------  29 0.5250000000000001 0.5000000000000002
# -------  30 0.4250000000000001 0.5250000000000002
# -------  31 0.4500000000000001 0.5250000000000002
# -------  32 0.47500000000000014 0.5250000000000002
# -------  33 0.5000000000000002 0.5250000000000002
# -------  34 0.5250000000000001 0.5250000000000002
# -------  35 0.5500000000000003 0.5250000000000002
# -------  36 0.4250000000000001 0.5500000000000003
# -------  37 0.4500000000000001 0.5500000000000003
# -------  38 0.47500000000000014 0.5500000000000003
# -------  39 0.5000000000000002 0.5500000000000003
# -------  40 0.5250000000000001 0.5500000000000003
# -------  41 0.5500000000000003 0.5500000000000003
# -------  42 0.4250000000000001 0.5750000000000003
# -------  43 0.4500000000000001 0.5750000000000003
# -------  44 0.47500000000000014 0.5750000000000003
# -------  45 0.5000000000000002 0.5750000000000003
# -------  46 0.5250000000000001 0.5750000000000003
# -------  47 0.5500000000000003 0.5750000000000003
# -------  48 0.4250000000000001 0.6000000000000003
# -------  49 0.4500000000000001 0.6000000000000003
# -------  50 0.47500000000000014 0.6000000000000003
# -------  51 0.5000000000000002 0.6000000000000003
# -------  52 0.5250000000000001 0.6000000000000003
# -------  53 0.5500000000000003 0.6000000000000003
# -------  54 0.5750000000000002 0.6000000000000003
# -------  55 0.4250000000000001 0.6250000000000003
# -------  56 0.4500000000000001 0.6250000000000003
# -------  57 0.47500000000000014 0.6250000000000003
# -------  58 0.5000000000000002 0.6250000000000003
# -------  59 0.5250000000000001 0.6250000000000003
# -------  60 0.5500000000000003 0.6250000000000003
# -------  61 0.5750000000000002 0.6250000000000003
# -------  62 0.4250000000000001 0.6500000000000004
# -------  63 0.4500000000000001 0.6500000000000004
# -------  64 0.47500000000000014 0.6500000000000004
# -------  65 0.5000000000000002 0.6500000000000004
# -------  66 0.5250000000000001 0.6500000000000004
# -------  67 0.5500000000000003 0.6500000000000004
# -------  68 0.5750000000000002 0.6500000000000004
# -------  69 0.4250000000000001 0.6750000000000004
# -------  70 0.4500000000000001 0.6750000000000004
# -------  71 0.47500000000000014 0.6750000000000004
# -------  72 0.5000000000000002 0.6750000000000004
# -------  73 0.5250000000000001 0.6750000000000004
# -------  74 0.5500000000000003 0.6750000000000004
# -------  75 0.5750000000000002 0.6750000000000004
# -------  76 0.4250000000000001 0.7000000000000004
# set cost params:  0.05 0.0 36.384757717265224
# interpolate adjoint :  True True True
# initial cost =  286.4889477320213
# RUN  0 , total integrated cost =  286.4889477320213
# Gradient descend method:  None
# RUN  1 , total integrated cost =  286.4889477240068
# RUN  2 , total integrated cost =  286.4889477222877
# RUN  3 , total integrated cost =  286.4889477211053
# RUN  4 , total integrated cost =  286.48894771419685
# RUN  5 , total integrated cost =  286.48894770762513
# RUN  6 , total integrated cost =  286.4889477064232
# RUN  7 , total integrated cost =  286.4889477053017
# RUN  8 , total integrated cost =  286.4889476979761
# RUN  9 , total integrated cost =  286.488947690489
# RUN  10 , total integrated cost =  286.48894768942154
# RUN  11 , total integrated cost =  286.4889476884975
# RUN  12 , total integrated cost =  286.4889476793832
# RUN  13 , total integrated cost =  286.4889476710172
# RUN  14 , total integrated cost =  286.4889476706232
# RUN  15 , total integrated cost =  286.4889476701653
# RUN  16 , total integrated cost =  286.48894766992174
# RUN  17 , total integrated cost =  286.4889476695793
# RUN  18 , total integrated cost =  286.48894766934376
# RUN  19 , total integrated cost =  286.48894766898144
# RUN  20 , total integrated cost =  286.48894766870546
# RUN  30 , total integrated cost =  286.4889476382694
# RUN  40 , total integrated cost =  286.48894761424174
# RUN  50 , total integrated cost =  286.48894759284786
# RUN  60 , total integrated cost =  286.4889475888477
# RUN  70 , total integrated cost =  286.4889475499321
# RUN  80 , total integrated cost =  286.4889475451668
# RUN  90 , total integrated cost =  286.48894750060043
# RUN  100 , total integrated cost =  286.4889474765727
# RUN  100 , total integrated cost =  286.4889474765727
# Improved over  100  iterations in  40.21464749192819  seconds by  8.916525473523507e-08  percent.
# cost splitting :  0.021484051841555555 [7.87384309e+00 4.81515288e-13]
# total cost =  7.895327145704924
# set cost params:  0.05 0.0 39.22562177458735
# interpolate adjoint :  True True True
# initial cost =  308.8574653149232
# RUN  0 , total integrated cost =  308.8574653149232
# Gradient descend method:  None
# RUN  1 , total integrated cost =  308.85746531223793
# RUN  2 , total integrated cost =  308.8574653118771
# RUN  3 , total integrated cost =  308.8574653114044
# RUN  4 , total integrated cost =  308.8574653111403
# RUN  5 , total integrated cost =  308.8574653107729
# RUN  6 , total integrated cost =  308.8574653105166
# RUN  7 , total integrated cost =  308.85746531011046
# RUN  8 , total integrated cost =  308.8574653097976
# RUN  9 , total integrated cost =  308.85746530925786
# RUN  10 , total integrated cost =  308.85746530879817
# RUN  11 , total integrated cost =  308.85746530803095
# RUN  12 , total integrated cost =  308.85746530736634
# RUN  13 , total integrated cost =  308.8574652954034
# RUN  14 , total integrated cost =  308.8574652842566
# RUN  15 , total integrated cost =  308.85746528384834
# RUN  16 , total integrated cost =  308.8574652833422
# RUN  17 , total integrated cost =  308.85746528300854
# RUN  18 , total integrated cost =  308.857465282586
# RUN  19 , total integrated cost =  308.85746528233335
# RUN  20 , total integrated cost =  308.8574652819578
# RUN  30 , total integrated cost =  308.8574652665365
# RUN  40 , total integrated cost =  308.8574652620119
# RUN  50 , total integrated cost =  308.85746523569946
# RUN  60 , total integrated cost =  308.85746521924335
# RUN  70 , total integrated cost =  308.85746520368565
# RUN  80 , total integrated cost =  308.85746519906905
# RUN  90 , total integrated cost =  308.85746517741103
# RUN  100 , total integrated cost =  308.85746515822314
# RUN  100 , total integrated cost =  308.85746515822314
# Improved over  100  iterations in  44.42144343000837  seconds by  5.0735408763102896e-08  percent.
# cost splitting :  0.021483687034199762 [7.87384309e+00 4.81515288e-13]
# total cost =  7.895326777367739
# set cost params:  0.05 0.0 25.699036986941515
# interpolate adjoint :  True True True
# initial cost =  202.3512589922072
# RUN  0 , total integrated cost =  202.3512589922072
# Gradient descend method:  None
# RUN  1 , total integrated cost =  202.35125895377587
# RUN  2 , total integrated cost =  202.3512589534017
# RUN  3 , total integrated cost =  202.35125895306436
# RUN  4 , total integrated cost =  202.35125895240452
# RUN  5 , total integrated cost =  202.35125895179576
# RUN  6 , total integrated cost =  202.35125895082342
# RUN  7 , total integrated cost =  202.35125894989463
# RUN  8 , total integrated cost =  202.35125892427428
# RUN  9 , total integrated cost =  202.35125890091226
# RUN  10 , total integrated cost =  202.3512589003169
# RUN  11 , total integrated cost =  202.35125889976874
# RUN  12 , total integrated cost =  202.3512588986879
# RUN  13 , total integrated cost =  202.35125889761403
# RUN  14 , total integrated cost =  202.35125887604127
# RUN  15 , total integrated cost =  202.351258856777
# RUN  16 , total integrated cost =  202.35125885604558
# RUN  17 , total integrated cost =  202.3512588553826
# RUN  18 , total integrated cost =  202.35125881664354
# RUN  19 , total integrated cost =  202.3512587819692
# RUN  20 , total integrated cost =  202.35125878155952
# RUN  30 , total integrated cost =  202.35125873069407
# RUN  40 , total integrated cost =  202.3512586357538
# RUN  50 , total integrated cost =  202.35125853561766
# RUN  60 , total integrated cost =  202.35125846226723
# RUN  70 , total integrated cost =  202.3512584049275
# RUN  80 , total integrated cost =  202.35125827794405
# RUN  90 , total integrated cost =  202.35125820783801
# RUN  100 , total integrated cost =  202.3512581090268
# RUN  100 , total integrated cost =  202.3512581090268
# Improved over  100  iterations in  51.21499594300985  seconds by  4.364590608929575e-07  percent.
# cost splitting :  0.02146874656724349 [7.87384309e+00 4.81515288e-13]
# total cost =  7.895311831602644
# set cost params:  0.05 0.0 6.6069292094374
# interpolate adjoint :  True True True
# initial cost =  52.022997306375444
# RUN  0 , total integrated cost =  52.022997306375444
# Gradient descend method:  None
# RUN  1 , total integrated cost =  52.022997220596174
# RUN  2 , total integrated cost =  52.02299721320398
# RUN  3 , total integrated cost =  52.02299720634889
# RUN  4 , total integrated cost =  52.02299720560755
# RUN  5 , total integrated cost =  52.0229972048483
# RUN  6 , total integrated cost =  52.02299720405241
# RUN  7 , total integrated cost =  52.02299720334776
# RUN  8 , total integrated cost =  52.02299720248723
# RUN  9 , total integrated cost =  52.02299720167064
# RUN  10 , total integrated cost =  52.022997200928735
# RUN  11 , total integrated cost =  52.02299720017011
# RUN  12 , total integrated cost =  52.02299719937361
# RUN  13 , total integrated cost =  52.0229971986695
# RUN  14 , total integrated cost =  52.02299719780831
# RUN  15 , total integrated cost =  52.022997196992556
# RUN  16 , total integrated cost =  52.02299719624979
# RUN  17 , total integrated cost =  52.02299719549193
# RUN  18 , total integrated cost =  52.02299719469459
# RUN  19 , total integrated cost =  52.02299719399136
# RUN  20 , total integrated cost =  52.02299719312901
# RUN  30 , total integrated cost =  52.02299718533585
# RUN  40 , total integrated cost =  52.0229971775249
# RUN  50 , total integrated cost =  52.022997169729926
# RUN  60 , total integrated cost =  52.02299716192788
# RUN  70 , total integrated cost =  52.0229971541281
# RUN  80 , total integrated cost =  52.02299714633217
# RUN  90 , total integrated cost =  52.02299713852705
# RUN  100 , total integrated cost =  52.02299713072372
# RUN  100 , total integrated cost =  52.02299713072372
# Improved over  100  iterations in  45.26048008201178  seconds by  3.3764246154532884e-07  percent.
# cost splitting :  0.02146429186775704 [7.87384309e+00 4.81515288e-13]
# total cost =  7.895307384029501
# set cost params:  0.05 0.0 17.558632113510747
# interpolate adjoint :  True True True
# initial cost =  138.25498738936935
# RUN  0 , total integrated cost =  138.25498738936935
# Gradient descend method:  None
# RUN  1 , total integrated cost =  138.25498737231734
# RUN  2 , total integrated cost =  138.25498736935617
# RUN  3 , total integrated cost =  138.2549873663001
# RUN  4 , total integrated cost =  138.25498717049135
# RUN  5 , total integrated cost =  138.25498698725525
# RUN  6 , total integrated cost =  138.2549869870433
# RUN  7 , total integrated cost =  138.25498698687798
# RUN  8 , total integrated cost =  138.25498698666837
# RUN  9 , total integrated cost =  138.25498698648585
# RUN  10 , total integrated cost =  138.2549869862179
# RUN  11 , total integrated cost =  138.25498698599154
# RUN  12 , total integrated cost =  138.25498698567608
# RUN  13 , total integrated cost =  138.25498698540045
# RUN  14 , total integrated cost =  138.25498698473555
# RUN  15 , total integrated cost =  138.25498698413648
# RUN  16 , total integrated cost =  138.254986983227
# RUN  17 , total integrated cost =  138.2549869823468
# RUN  18 , total integrated cost =  138.25498005723443
# RUN  19 , total integrated cost =  138.2549731642662
# RUN  20 , total integrated cost =  138.25497315440177
# RUN  30 , total integrated cost =  138.25497303939267
# RUN  40 , total integrated cost =  138.25497283633482
# RUN  50 , total integrated cost =  138.2549726577234
# RUN  60 , total integrated cost =  138.2549724658801
# RUN  70 , total integrated cost =  138.25497246270965
# RUN  80 , total integrated cost =  138.25497228521763
# RUN  90 , total integrated cost =  138.2549721199723
# RUN  100 , total integrated cost =  138.2549721168037
# RUN  100 , total integrated cost =  138.2549721168037
# Improved over  100  iterations in  44.698845784994774  seconds by  1.1046665235880937e-05  percent.
# cost splitting :  0.021215545324496612 [7.87384293e+00 4.81515288e-13]
# total cost =  7.895058476013613
# set cost params:  0.05 0.0 10.408615913800375
# interpolate adjoint :  True True True
# initial cost =  81.95686760840155
# RUN  0 , total integrated cost =  81.95686760840155
# Gradient descend method:  None
# RUN  1 , total integrated cost =  81.9568675982294
# RUN  2 , total integrated cost =  81.95686759699431
# RUN  3 , total integrated cost =  81.95686759575248
# RUN  4 , total integrated cost =  81.95686759514992
# RUN  5 , total integrated cost =  81.95686759455998
# RUN  6 , total integrated cost =  81.95686759425865
# RUN  7 , total integrated cost =  81.95686759395598
# RUN  8 , total integrated cost =  81.9568675937516
# RUN  9 , total integrated cost =  81.956867593524
# RUN  10 , total integrated cost =  81.9568675933485
# RUN  11 , total integrated cost =  81.95686759314972
# RUN  12 , total integrated cost =  81.95686759298788
# RUN  13 , total integrated cost =  81.95686759280703
# RUN  14 , total integrated cost =  81.95686759264919
# RUN  15 , total integrated cost =  81.9568675924646
# RUN  16 , total integrated cost =  81.95686759230884
# RUN  17 , total integrated cost =  81.95686759213262
# RUN  18 , total integrated cost =  81.95686759198014
# RUN  19 , total integrated cost =  81.95686759180114
# RUN  20 , total integrated cost =  81.95686759163661
# RUN  30 , total integrated cost =  81.95686758850074
# RUN  40 , total integrated cost =  81.95686758408841
# RUN  50 , total integrated cost =  81.95686757994729
# RUN  60 , total integrated cost =  81.95686757580762
# RUN  70 , total integrated cost =  81.95686757166794
# RUN  80 , total integrated cost =  81.95686756752829
# RUN  90 , total integrated cost =  81.95686756338864
# RUN  100 , total integrated cost =  81.95686755924905
# RUN  100 , total integrated cost =  81.95686755924905
# Improved over  100  iterations in  44.97585731896106  seconds by  5.997362961807085e-08  percent.
# cost splitting :  0.02121400436359326 [7.87384293e+00 4.81515288e-13]
# total cost =  7.895056937732753
# set cost params:  0.05 0.0 24.84808298943268
# interpolate adjoint :  True True True
# initial cost =  195.6509633543331
# RUN  0 , total integrated cost =  195.6509633543331
# Gradient descend method:  None
# RUN  1 , total integrated cost =  195.65096331001152
# RUN  2 , total integrated cost =  195.6509633084824
# RUN  3 , total integrated cost =  195.65096330693288
# RUN  4 , total integrated cost =  195.6509632183745
# RUN  5 , total integrated cost =  195.65096313287134
# RUN  6 , total integrated cost =  195.65096313257783
# RUN  7 , total integrated cost =  195.65096313232021
# RUN  8 , total integrated cost =  195.65096313195363
# RUN  9 , total integrated cost =  195.65096313162863
# RUN  10 , total integrated cost =  195.65096313091107
# RUN  11 , total integrated cost =  195.65096313027402
# RUN  12 , total integrated cost =  195.65096312922017
# RUN  13 , total integrated cost =  195.6509631281821
# RUN  14 , total integrated cost =  195.65096296899668
# RUN  15 , total integrated cost =  195.6509628118553
# RUN  16 , total integrated cost =  195.65096281160424
# RUN  17 , total integrated cost =  195.6509628114187
# RUN  18 , total integrated cost =  195.65096281116328
# RUN  19 , total integrated cost =  195.65096281096203
# RUN  20 , total integrated cost =  195.65096281063595
# RUN  30 , total integrated cost =  195.6509623951834
# RUN  40 , total integrated cost =  195.65096239084352
# RUN  50 , total integrated cost =  195.650961945638
# RUN  60 , total integrated cost =  195.6509614355312
# RUN  70 , total integrated cost =  195.65096143121107
# RUN  80 , total integrated cost =  195.65096101763763
# RUN  90 , total integrated cost =  195.65096057062505
# RUN  100 , total integrated cost =  195.6509605664348
# RUN  100 , total integrated cost =  195.6509605664348
# Improved over  100  iterations in  44.84188293397892  seconds by  1.4249346094175053e-06  percent.
# cost splitting :  0.02117819568883062 [7.87384289e+00 4.81515288e-13]
# total cost =  7.895021088915474
# set cost params:  0.05 0.0 21.532915286414582
# interpolate adjoint :  True True True
# initial cost =  169.54785090817126
# RUN  0 , total integrated cost =  169.54785090817126
# Gradient descend method:  None
# RUN  1 , total integrated cost =  169.54785090219812
# RUN  2 , total integrated cost =  169.54785047649776
# RUN  3 , total integrated cost =  169.5478500846692
# RUN  4 , total integrated cost =  169.5478500842595
# RUN  5 , total integrated cost =  169.54785008404667
# RUN  6 , total integrated cost =  169.54785008379685
# RUN  7 , total integrated cost =  169.5478500836105
# RUN  8 , total integrated cost =  169.5478500833749
# RUN  9 , total integrated cost =  169.5478500832004
# RUN  10 , total integrated cost =  169.54785008297003
# RUN  11 , total integrated cost =  169.54785008277526
# RUN  12 , total integrated cost =  169.54785008248174
# RUN  13 , total integrated cost =  169.54785008224178
# RUN  14 , total integrated cost =  169.54785008189174
# RUN  15 , total integrated cost =  169.54785008160368
# RUN  16 , total integrated cost =  169.54785008083942
# RUN  17 , total integrated cost =  169.54785008012706
# RUN  18 , total integrated cost =  169.547850079182
# RUN  19 , total integrated cost =  169.54785007819598
# RUN  20 , total integrated cost =  169.54784912208436
# RUN  30 , total integrated cost =  169.54784820629214
# RUN  40 , total integrated cost =  169.5478472680684
# RUN  50 , total integrated cost =  169.54784586419936
# RUN  60 , total integrated cost =  169.54784586191556
# RUN  70 , total integrated cost =  169.54784585662554
# RUN  80 , total integrated cost =  169.54784533070043
# RUN  90 , total integrated cost =  169.54784486001583
# RUN  100 , total integrated cost =  169.54784485751998
# RUN  100 , total integrated cost =  169.54784485751998
# Improved over  100  iterations in  48.5326567030279  seconds by  3.568698303979545e-06  percent.
# cost splitting :  0.02108617505725401 [7.87384283e+00 4.81515288e-13]
# total cost =  7.894929000962791
# set cost params:  0.05 0.0 16.503418589322724
# interpolate adjoint :  True True True
# initial cost =  129.94637837120766
# RUN  0 , total integrated cost =  129.94637837120766
# Gradient descend method:  None
# RUN  1 , total integrated cost =  129.9463783663138
# RUN  2 , total integrated cost =  129.9463783605268
# RUN  3 , total integrated cost =  129.9463783548115
# RUN  4 , total integrated cost =  129.94637835302223
# RUN  5 , total integrated cost =  129.94637835145718
# RUN  6 , total integrated cost =  129.94637833806445
# RUN  7 , total integrated cost =  129.94637832528034
# RUN  8 , total integrated cost =  129.94637832456522
# RUN  9 , total integrated cost =  129.9463783238582
# RUN  10 , total integrated cost =  129.9463783228551
# RUN  11 , total integrated cost =  129.94637832192902
# RUN  12 , total integrated cost =  129.9463783211585
# RUN  13 , total integrated cost =  129.94637832040573
# RUN  14 , total integrated cost =  129.94637831946613
# RUN  15 , total integrated cost =  129.94637831847658
# RUN  16 , total integrated cost =  129.9463782984197
# RUN  17 , total integrated cost =  129.94637827925692
# RUN  18 , total integrated cost =  129.94637827879166
# RUN  19 , total integrated cost =  129.9463782783404
# RUN  20 , total integrated cost =  129.94637827790538
# RUN  30 , total integrated cost =  129.946378273425
# RUN  40 , total integrated cost =  129.94637826896985
# RUN  50 , total integrated cost =  129.94637826453283
# RUN  60 , total integrated cost =  129.94637826004805
# RUN  70 , total integrated cost =  129.94637825560045
# RUN  80 , total integrated cost =  129.94637825113202
# RUN  90 , total integrated cost =  129.9463782466614
# RUN  100 , total integrated cost =  129.94637824223108
# RUN  100 , total integrated cost =  129.94637824223108
# Improved over  100  iterations in  46.86531060002744  seconds by  9.925369681695884e-08  percent.
# cost splitting :  0.021083514345468526 [7.87384283e+00 4.81515288e-13]
# total cost =  7.894926340496953
# set cost params:  0.05 0.0 30.103122867525673
# interpolate adjoint :  True True True
# initial cost =  237.02831221094104
# RUN  0 , total integrated cost =  237.02831221094104
# Gradient descend method:  None
# RUN  1 , total integrated cost =  237.02831217916255
# RUN  2 , total integrated cost =  237.02831214357033
# RUN  3 , total integrated cost =  237.0283121072314
# RUN  4 , total integrated cost =  237.02831210660497
# RUN  5 , total integrated cost =  237.02831210603927
# RUN  6 , total integrated cost =  237.02831210463887
# RUN  7 , total integrated cost =  237.02831210338474
# RUN  8 , total integrated cost =  237.02831205528472
# RUN  9 , total integrated cost =  237.02831200453116
# RUN  10 , total integrated cost =  237.02831200408488
# RUN  11 , total integrated cost =  237.02831200367942
# RUN  12 , total integrated cost =  237.0283120029862
# RUN  13 , total integrated cost =  237.0283120024191
# RUN  14 , total integrated cost =  237.02831200102125
# RUN  15 , total integrated cost =  237.0283119997648
# RUN  16 , total integrated cost =  237.02831195133078
# RUN  17 , total integrated cost =  237.02831190091499
# RUN  18 , total integrated cost =  237.02831190046487
# RUN  19 , total integrated cost =  237.02831190006356
# RUN  20 , total integrated cost =  237.02831189936313
# RUN  30 , total integrated cost =  237.02831179387303
# RUN  40 , total integrated cost =  237.0283115026328
# RUN  50 , total integrated cost =  237.02831135442304
# RUN  60 , total integrated cost =  237.028311187852
# RUN  70 , total integrated cost =  237.02831090547517
# RUN  80 , total integrated cost =  237.02831080112128
# RUN  90 , total integrated cost =  237.0283106785754
# RUN  100 , total integrated cost =  237.02831051198123
# RUN  100 , total integrated cost =  237.02831051198123
# Improved over  100  iterations in  46.35340943397023  seconds by  7.167750482039992e-07  percent.
# cost splitting :  0.021065998751455303 [7.87384280e+00 4.81515288e-13]
# total cost =  7.894908797557601
# set cost params:  0.05 0.0 9.348909515007243
# interpolate adjoint :  True True True
# initial cost =  73.61289716136761
# RUN  0 , total integrated cost =  73.61289716136761
# Gradient descend method:  None
# RUN  1 , total integrated cost =  73.61289705202958
# RUN  2 , total integrated cost =  73.61289705158808
# RUN  3 , total integrated cost =  73.6128970511304
# RUN  4 , total integrated cost =  73.61289705073186
# RUN  5 , total integrated cost =  73.6128970503201
# RUN  6 , total integrated cost =  73.61289704987513
# RUN  7 , total integrated cost =  73.61289704942081
# RUN  8 , total integrated cost =  73.61289704901938
# RUN  9 , total integrated cost =  73.61289704861063
# RUN  10 , total integrated cost =  73.6128970481623
# RUN  11 , total integrated cost =  73.61289704771131
# RUN  12 , total integrated cost =  73.61289704730702
# RUN  13 , total integrated cost =  73.61289704690111
# RUN  14 , total integrated cost =  73.6128970464495
# RUN  15 , total integrated cost =  73.61289704600183
# RUN  16 , total integrated cost =  73.61289704559465
# RUN  17 , total integrated cost =  73.61289704519157
# RUN  18 , total integrated cost =  73.6128970447369
# RUN  19 , total integrated cost =  73.61289704429237
# RUN  20 , total integrated cost =  73.61289704388246
# RUN  30 , total integrated cost =  73.61289703959848
# RUN  40 , total integrated cost =  73.61289703526013
# RUN  50 , total integrated cost =  73.61289703092476
# RUN  60 , total integrated cost =  73.61289702660824
# RUN  70 , total integrated cost =  73.61289702228231
# RUN  80 , total integrated cost =  73.61289701796335
# RUN  90 , total integrated cost =  73.61289701364623
# RUN  100 , total integrated cost =  73.61289700932033
# RUN  100 , total integrated cost =  73.61289700932033
# Improved over  100  iterations in  42.44724825699814  seconds by  2.0654977106460137e-07  percent.
# cost splitting :  0.021061124559829395 [7.87384281e+00 4.81515288e-13]
# total cost =  7.894903933170574
# set cost params:  0.05 0.0 24.837937268944533
# interpolate adjoint :  True True True
# initial cost =  195.5710668020317
# RUN  0 , total integrated cost =  195.5710668020317
# Gradient descend method:  None
# RUN  1 , total integrated cost =  195.57106674242507
# RUN  2 , total integrated cost =  195.57106674193892
# RUN  3 , total integrated cost =  195.57106674150157
# RUN  4 , total integrated cost =  195.5710667409499
# RUN  5 , total integrated cost =  195.5710667404586
# RUN  6 , total integrated cost =  195.57106673996122
# RUN  7 , total integrated cost =  195.57106673953507
# RUN  8 , total integrated cost =  195.57106673897044
# RUN  9 , total integrated cost =  195.5710667384294
# RUN  10 , total integrated cost =  195.5710667370469
# RUN  11 , total integrated cost =  195.57106673585824
# RUN  12 , total integrated cost =  195.57103818799925
# RUN  13 , total integrated cost =  195.57101476421877
# RUN  14 , total integrated cost =  195.57101472772865
# RUN  15 , total integrated cost =  195.57101472754442
# RUN  16 , total integrated cost =  195.5710147272765
# RUN  17 , total integrated cost =  195.57101472705472
# RUN  18 , total integrated cost =  195.57101472656382
# RUN  19 , total integrated cost =  195.57101472615156
# RUN  20 , total integrated cost =  195.57101472542098
# RUN  30 , total integrated cost =  195.5710147083466
# RUN  40 , total integrated cost =  195.57101470165904
# RUN  50 , total integrated cost =  195.5710146880194
# RUN  60 , total integrated cost =  195.57101467083135
# RUN  70 , total integrated cost =  195.57101466832512
# RUN  80 , total integrated cost =  195.57101464912938
# RUN  90 , total integrated cost =  195.57101463753523
# RUN  100 , total integrated cost =  195.57101463008854
# RUN  100 , total integrated cost =  195.57101463008854
# Improved over  100  iterations in  43.54661718092393  seconds by  2.6676718619000894e-05  percent.
# cost splitting :  0.020337912482153376 [7.87384216e+00 4.81515288e-13]
# total cost =  7.894180076460492
# set cost params:  0.05 0.0 1.646170402482464
# interpolate adjoint :  True True True
# initial cost =  12.962702819783724
# RUN  0 , total integrated cost =  12.962702819783724
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12.96270271070519
# RUN  2 , total integrated cost =  12.962702710492055
# RUN  3 , total integrated cost =  12.962702710317718
# RUN  4 , total integrated cost =  12.962702710142732
# RUN  5 , total integrated cost =  12.962702709981388
# RUN  6 , total integrated cost =  12.962702709809028
# RUN  7 , total integrated cost =  12.962702709645194
# RUN  8 , total integrated cost =  12.962702709475332
# RUN  9 , total integrated cost =  12.962702709309148
# RUN  10 , total integrated cost =  12.962702709141704
# RUN  11 , total integrated cost =  12.962702708973243
# RUN  12 , total integrated cost =  12.9627027088081
# RUN  13 , total integrated cost =  12.962702708636762
# RUN  14 , total integrated cost =  12.96270270845894
# RUN  15 , total integrated cost =  12.962702708299398
# RUN  16 , total integrated cost =  12.962702708139457
# RUN  17 , total integrated cost =  12.96270270798589
# RUN  18 , total integrated cost =  12.962702707831916
# RUN  19 , total integrated cost =  12.962702707683322
# RUN  20 , total integrated cost =  12.96270270753257
# RUN  30 , total integrated cost =  12.96270270603846
# RUN  40 , total integrated cost =  12.962702704539902
# RUN  50 , total integrated cost =  12.962702702881458
# RUN  60 , total integrated cost =  12.962702701101461
# RUN  70 , total integrated cost =  12.962702699371448
# RUN  80 , total integrated cost =  12.962702697642502
# RUN  90 , total integrated cost =  12.962702693284037
# RUN  100 , total integrated cost =  12.962702690526946
# RUN  100 , total integrated cost =  12.962702690526946
# Improved over  100  iterations in  42.02089528099168  seconds by  9.971437293643248e-07  percent.
# cost splitting :  0.020335019943565066 [7.87384217e+00 4.81515288e-13]
# total cost =  7.894177193258817
# set cost params:  0.05 0.0 27.721527096251037
# interpolate adjoint :  True True True
# initial cost =  218.2759459101601
# RUN  0 , total integrated cost =  218.2759459101601
# Gradient descend method:  None
# RUN  1 , total integrated cost =  218.27594577224423
# RUN  2 , total integrated cost =  218.27594577196695
# RUN  3 , total integrated cost =  218.27594577154503
# RUN  4 , total integrated cost =  218.27594577118185
# RUN  5 , total integrated cost =  218.27594577026605
# RUN  6 , total integrated cost =  218.2759457693835
# RUN  7 , total integrated cost =  218.27594576793769
# RUN  8 , total integrated cost =  218.27594576668736
# RUN  9 , total integrated cost =  218.27594575309152
# RUN  10 , total integrated cost =  218.2759457397953
# RUN  11 , total integrated cost =  218.27594573958208
# RUN  12 , total integrated cost =  218.27594573931103
# RUN  13 , total integrated cost =  218.2759457391156
# RUN  14 , total integrated cost =  218.27594573882894
# RUN  15 , total integrated cost =  218.27594573858786
# RUN  16 , total integrated cost =  218.27594573808818
# RUN  17 , total integrated cost =  218.27594573761652
# RUN  18 , total integrated cost =  218.27594573692355
# RUN  19 , total integrated cost =  218.27594573632896
# RUN  20 , total integrated cost =  218.27594573413535
# RUN  30 , total integrated cost =  218.2759457115629
# RUN  40 , total integrated cost =  218.27594567283467
# RUN  50 , total integrated cost =  218.2759456671026
# RUN  60 , total integrated cost =  218.27594566137066
# RUN  70 , total integrated cost =  218.27594565557573
# RUN  80 , total integrated cost =  218.27594564984375
# RUN  90 , total integrated cost =  218.2759456440492
# RUN  100 , total integrated cost =  218.27594563831704
# RUN  100 , total integrated cost =  218.27594563831704
# Improved over  100  iterations in  46.82241175498348  seconds by  1.2454100328795903e-07  percent.
# cost splitting :  0.020336438277433564 [7.87384216e+00 4.81515288e-13]
# total cost =  7.894178599228296
# set cost params:  0.05 0.0 11.873255343875316
# interpolate adjoint :  True True True
# initial cost =  93.48915533625446
# RUN  0 , total integrated cost =  93.48915533625446
# Gradient descend method:  None
# RUN  1 , total integrated cost =  93.48915528551282
# RUN  2 , total integrated cost =  93.48915528536098
# RUN  3 , total integrated cost =  93.48915528518107
# RUN  4 , total integrated cost =  93.48915528503018
# RUN  5 , total integrated cost =  93.48915528485138
# RUN  6 , total integrated cost =  93.48915528469789
# RUN  7 , total integrated cost =  93.48915528450424
# RUN  8 , total integrated cost =  93.48915528432532
# RUN  9 , total integrated cost =  93.48915528408689
# RUN  10 , total integrated cost =  93.48915528385646
# RUN  11 , total integrated cost =  93.48915528355707
# RUN  12 , total integrated cost =  93.48915528326006
# RUN  13 , total integrated cost =  93.48915528243428
# RUN  14 , total integrated cost =  93.48915528172738
# RUN  15 , total integrated cost =  93.48915528137339
# RUN  16 , total integrated cost =  93.4891552810435
# RUN  17 , total integrated cost =  93.48915528031202
# RUN  18 , total integrated cost =  93.48915527960074
# RUN  19 , total integrated cost =  93.48915527924852
# RUN  20 , total integrated cost =  93.48915527891688
# RUN  30 , total integrated cost =  93.48915527322102
# RUN  40 , total integrated cost =  93.48915526837413
# RUN  50 , total integrated cost =  93.48915526312767
# RUN  60 , total integrated cost =  93.48915525832886
# RUN  70 , total integrated cost =  93.48915525290269
# RUN  80 , total integrated cost =  93.48915524819378
# RUN  90 , total integrated cost =  93.4891552427681
# RUN  100 , total integrated cost =  93.48915523796875
# RUN  100 , total integrated cost =  93.48915523796875
# Improved over  100  iterations in  47.38413368805777  seconds by  1.0513060999528534e-07  percent.
# cost splitting :  0.020332999248646 [7.87384217e+00 4.81515288e-13]
# total cost =  7.8941751664038495
# set cost params:  0.05 0.0 31.075567131534616
# interpolate adjoint :  True True True
# initial cost =  244.68512749850194
# RUN  0 , total integrated cost =  244.68512749850194
# Gradient descend method:  None
# RUN  1 , total integrated cost =  244.68512741953086
# RUN  2 , total integrated cost =  244.68512741923072
# RUN  3 , total integrated cost =  244.68512741900577
# RUN  4 , total integrated cost =  244.6851274185996
# RUN  5 , total integrated cost =  244.6851274182825
# RUN  6 , total integrated cost =  244.68512741706456
# RUN  7 , total integrated cost =  244.68512741590197
# RUN  8 , total integrated cost =  244.68512737948282
# RUN  9 , total integrated cost =  244.6851273438718
# RUN  10 , total integrated cost =  244.6851273433962
# RUN  11 , total integrated cost =  244.6851273430165
# RUN  12 , total integrated cost =  244.68512734204583
# RUN  13 , total integrated cost =  244.68512734119543
# RUN  14 , total integrated cost =  244.68512733966156
# RUN  15 , total integrated cost =  244.68512733825403
# RUN  16 , total integrated cost =  244.6851273077056
# RUN  17 , total integrated cost =  244.68512727521528
# RUN  18 , total integrated cost =  244.68512727469965
# RUN  19 , total integrated cost =  244.68512727422444
# RUN  20 , total integrated cost =  244.68512727346283
# RUN  30 , total integrated cost =  244.6851271938246
# RUN  40 , total integrated cost =  244.68512711637018
# RUN  50 , total integrated cost =  244.68512703888254
# RUN  60 , total integrated cost =  244.6851269579792
# RUN  70 , total integrated cost =  244.68512685559813
# RUN  80 , total integrated cost =  244.6851267765571
# RUN  90 , total integrated cost =  244.68512669737297
# RUN  100 , total integrated cost =  244.6851266189245
# RUN  100 , total integrated cost =  244.6851266189245
# Improved over  100  iterations in  45.162890605046414  seconds by  3.594731907696769e-07  percent.
# cost splitting :  0.020324582434782097 [7.87384215e+00 4.81515288e-13]
# total cost =  7.894166734828009
# set cost params:  0.05 0.0 41.01195936900453
# interpolate adjoint :  True True True
# initial cost =  322.9227106610279
# RUN  0 , total integrated cost =  322.9227106610279
# Gradient descend method:  None
# RUN  1 , total integrated cost =  322.92271057975915
# RUN  2 , total integrated cost =  322.9227105788993
# RUN  3 , total integrated cost =  322.922710578116
# RUN  4 , total integrated cost =  322.92271057619206
# RUN  5 , total integrated cost =  322.9227105742962
# RUN  6 , total integrated cost =  322.9227102805823
# RUN  7 , total integrated cost =  322.9227100137188
# RUN  8 , total integrated cost =  322.9227100132814
# RUN  9 , total integrated cost =  322.9227100130132
# RUN  10 , total integrated cost =  322.92271001262606
# RUN  11 , total integrated cost =  322.92271001236657
# RUN  12 , total integrated cost =  322.9227100119559
# RUN  13 , total integrated cost =  322.9227100116598
# RUN  14 , total integrated cost =  322.922710010923
# RUN  15 , total integrated cost =  322.92271001028564
# RUN  16 , total integrated cost =  322.92271000787105
# RUN  17 , total integrated cost =  322.9227100057375
# RUN  18 , total integrated cost =  322.92270974238187
# RUN  19 , total integrated cost =  322.9227094919242
# RUN  20 , total integrated cost =  322.9227094915037
# RUN  30 , total integrated cost =  322.92270780561046
# RUN  40 , total integrated cost =  322.9226998683423
# RUN  50 , total integrated cost =  322.91850556363016
# RUN  60 , total integrated cost =  322.9185052240912
# RUN  70 , total integrated cost =  322.9185047498681
# RUN  80 , total integrated cost =  322.9185045940303
# RUN  90 , total integrated cost =  322.9185044748793
# RUN  100 , total integrated cost =  322.9185041128983
# RUN  100 , total integrated cost =  322.9185041128983
# Improved over  100  iterations in  46.837251623976044  seconds by  0.00130264858763951  percent.
# cost splitting :  0.017588237048023404 [7.87374292e+00 4.81515288e-13]
# total cost =  7.891331156658353
# set cost params:  0.05 0.0 36.592280600017325
# interpolate adjoint :  True True True
# initial cost =  288.1190896986332
# RUN  0 , total integrated cost =  288.1190896986332
# Gradient descend method:  None
# RUN  1 , total integrated cost =  288.1190896058768
# RUN  2 , total integrated cost =  288.11908778512145
# RUN  3 , total integrated cost =  288.11908606724495
# RUN  4 , total integrated cost =  288.11908606294344
# RUN  5 , total integrated cost =  288.11908605420064
# RUN  6 , total integrated cost =  288.1190860475635
# RUN  7 , total integrated cost =  288.11908593883794
# RUN  8 , total integrated cost =  288.11908584283753
# RUN  9 , total integrated cost =  288.11908539219877
# RUN  10 , total integrated cost =  288.1190849572329
# RUN  11 , total integrated cost =  288.11908495231785
# RUN  12 , total integrated cost =  288.1190849460178
# RUN  13 , total integrated cost =  288.11908494240555
# RUN  14 , total integrated cost =  288.1190849369086
# RUN  15 , total integrated cost =  288.11908493285347
# RUN  16 , total integrated cost =  288.11908492335425
# RUN  17 , total integrated cost =  288.1190849152384
# RUN  18 , total integrated cost =  288.1190848339499
# RUN  19 , total integrated cost =  288.11908476577895
# RUN  20 , total integrated cost =  288.11907673289295
# RUN  30 , total integrated cost =  288.119050801732
# RUN  40 , total integrated cost =  288.11903651145093
# RUN  50 , total integrated cost =  288.1190363103679
# RUN  60 , total integrated cost =  288.11903610478146
# RUN  70 , total integrated cost =  288.1190359037288
# RUN  80 , total integrated cost =  288.119035698174
# RUN  90 , total integrated cost =  288.11903558666853
# RUN  100 , total integrated cost =  288.11903497513237
# RUN  100 , total integrated cost =  288.11903497513237
# Improved over  100  iterations in  50.38967106200289  seconds by  1.8993361706520773e-05  percent.
# cost splitting :  0.016977316227686702 [7.87374226e+00 4.81515288e-13]
# total cost =  7.890719575112326
# set cost params:  0.05 0.0 8.337364384754071
# interpolate adjoint :  True True True
# initial cost =  65.64710714976924
# RUN  0 , total integrated cost =  65.64710714976924
# Gradient descend method:  None
# RUN  1 , total integrated cost =  65.64710408907797
# RUN  2 , total integrated cost =  65.64710407984236
# RUN  3 , total integrated cost =  65.64710406958814
# RUN  4 , total integrated cost =  65.64710406495604
# RUN  5 , total integrated cost =  65.6471040598407
# RUN  6 , total integrated cost =  65.64710405626074
# RUN  7 , total integrated cost =  65.64710405217346
# RUN  8 , total integrated cost =  65.64710404857153
# RUN  9 , total integrated cost =  65.64710404450632
# RUN  10 , total integrated cost =  65.64710404088342
# RUN  11 , total integrated cost =  65.64710403683948
# RUN  12 , total integrated cost =  65.64710403319599
# RUN  13 , total integrated cost =  65.6471040291728
# RUN  14 , total integrated cost =  65.64710402550949
# RUN  15 , total integrated cost =  65.64710402150627
# RUN  16 , total integrated cost =  65.64710401782388
# RUN  17 , total integrated cost =  65.64710401384005
# RUN  18 , total integrated cost =  65.64710401013893
# RUN  19 , total integrated cost =  65.64710400617346
# RUN  20 , total integrated cost =  65.64710400311063
# RUN  30 , total integrated cost =  65.64710396806396
# RUN  40 , total integrated cost =  65.64710392619362
# RUN  50 , total integrated cost =  65.64710085090097
# RUN  60 , total integrated cost =  65.64710081196436
# RUN  70 , total integrated cost =  65.64710077664382
# RUN  80 , total integrated cost =  65.64709972734741
# RUN  90 , total integrated cost =  65.64709968860132
# RUN  100 , total integrated cost =  65.64709965378067
# RUN  100 , total integrated cost =  65.64709965378067
# Improved over  100  iterations in  48.404127996996976  seconds by  1.1418612174907139e-05  percent.
# cost splitting :  0.016794876316998462 [7.87374245e+00 4.81515288e-13]
# total cost =  7.890537330228133
# set cost params:  0.05 0.0 37.162062192109374
# interpolate adjoint :  True True True
# initial cost =  292.6053465007133
# RUN  0 , total integrated cost =  292.6053465007133
# Gradient descend method:  None
# RUN  1 , total integrated cost =  292.6053429691873
# RUN  2 , total integrated cost =  292.60534296485355
# RUN  3 , total integrated cost =  292.6053429591253
# RUN  4 , total integrated cost =  292.60534295582545
# RUN  5 , total integrated cost =  292.6053429502262
# RUN  6 , total integrated cost =  292.6053429462409
# RUN  7 , total integrated cost =  292.6053429328303
# RUN  8 , total integrated cost =  292.60534292101323
# RUN  9 , total integrated cost =  292.60534275005307
# RUN  10 , total integrated cost =  292.60534258987036
# RUN  11 , total integrated cost =  292.605342556153
# RUN  12 , total integrated cost =  292.60534251905517
# RUN  13 , total integrated cost =  292.60534251026036
# RUN  14 , total integrated cost =  292.6053424994291
# RUN  15 , total integrated cost =  292.6053424944597
# RUN  16 , total integrated cost =  292.6053424879478
# RUN  17 , total integrated cost =  292.6053424844372
# RUN  18 , total integrated cost =  292.60534247909266
# RUN  19 , total integrated cost =  292.6053424757268
# RUN  20 , total integrated cost =  292.6053424687619
# RUN  30 , total integrated cost =  292.6053421837794
# RUN  40 , total integrated cost =  292.60534208652314
# RUN  50 , total integrated cost =  292.60534184901195
# RUN  60 , total integrated cost =  292.60534167246936
# RUN  70 , total integrated cost =  292.6053412725523
# RUN  80 , total integrated cost =  292.6053411833832
# RUN  90 , total integrated cost =  292.60534104356776
# RUN  100 , total integrated cost =  292.60534087446086
# RUN  100 , total integrated cost =  292.60534087446086
# Improved over  100  iterations in  46.48407175100874  seconds by  1.9228126006964885e-06  percent.
# cost splitting :  0.016880224405007065 [7.87374219e+00 4.81515288e-13]
# total cost =  7.890622412086114
# set cost params:  0.05 0.0 24.652591279337898
# interpolate adjoint :  True True True
# initial cost =  194.1089920030024
# RUN  0 , total integrated cost =  194.1089920030024
# Gradient descend method:  None
# RUN  1 , total integrated cost =  194.10899138138623
# RUN  2 , total integrated cost =  194.1089913614047
# RUN  3 , total integrated cost =  194.1089913431323
# RUN  4 , total integrated cost =  194.10899132752465
# RUN  5 , total integrated cost =  194.10899131474156
# RUN  6 , total integrated cost =  194.1089912908425
# RUN  7 , total integrated cost =  194.10899126990543
# RUN  8 , total integrated cost =  194.1089912565198
# RUN  9 , total integrated cost =  194.10899124479678
# RUN  10 , total integrated cost =  194.1089912181929
# RUN  11 , total integrated cost =  194.10899119337262
# RUN  12 , total integrated cost =  194.1089911820053
# RUN  13 , total integrated cost =  194.1089911698602
# RUN  14 , total integrated cost =  194.10899116491825
# RUN  15 , total integrated cost =  194.10899115924758
# RUN  16 , total integrated cost =  194.10899115583018
# RUN  17 , total integrated cost =  194.10899115141908
# RUN  18 , total integrated cost =  194.10899114846066
# RUN  19 , total integrated cost =  194.1089911440067
# RUN  20 , total integrated cost =  194.10899114067053
# RUN  30 , total integrated cost =  194.10899100956286
# RUN  40 , total integrated cost =  194.1089909607737
# RUN  50 , total integrated cost =  194.10899083997137
# RUN  60 , total integrated cost =  194.10899071184517
# RUN  70 , total integrated cost =  194.10899066100635
# RUN  80 , total integrated cost =  194.10899054050495
# RUN  90 , total integrated cost =  194.10899041713384
# RUN  100 , total integrated cost =  194.10899031360503
# RUN  100 , total integrated cost =  194.10899031360503
# Improved over  100  iterations in  48.05988819897175  seconds by  8.703344320792894e-07  percent.
# cost splitting :  0.016820541569397874 [7.87374224e+00 4.81515288e-13]
# total cost =  7.890562781770111
# set cost params:  0.05 0.0 38.870509229693745
# interpolate adjoint :  True True True
# initial cost =  306.0572114470298
# RUN  0 , total integrated cost =  306.0572114470298
# Gradient descend method:  None
# RUN  1 , total integrated cost =  306.05721105584854
# RUN  2 , total integrated cost =  306.0572110523002
# RUN  3 , total integrated cost =  306.0572110469463
# RUN  4 , total integrated cost =  306.0572110434784
# RUN  5 , total integrated cost =  306.05721103703394
# RUN  6 , total integrated cost =  306.0572110321544
# RUN  7 , total integrated cost =  306.05721100346545
# RUN  8 , total integrated cost =  306.0572109774063
# RUN  9 , total integrated cost =  306.057210823275
# RUN  10 , total integrated cost =  306.05721067002423
# RUN  11 , total integrated cost =  306.05721066643343
# RUN  12 , total integrated cost =  306.05721066096373
# RUN  13 , total integrated cost =  306.0572106575826
# RUN  14 , total integrated cost =  306.0572106517557
# RUN  15 , total integrated cost =  306.05721064774644
# RUN  16 , total integrated cost =  306.05721063659865
# RUN  17 , total integrated cost =  306.0572106261793
# RUN  18 , total integrated cost =  306.05721057170615
# RUN  19 , total integrated cost =  306.05721051903186
# RUN  20 , total integrated cost =  306.05721031194844
# RUN  30 , total integrated cost =  306.0572100262933
# RUN  40 , total integrated cost =  306.0572092980628
# RUN  50 , total integrated cost =  306.0572085957234
# RUN  60 , total integrated cost =  306.0572081081882
# RUN  70 , total integrated cost =  306.05720758076825
# RUN  80 , total integrated cost =  306.05720711918497
# RUN  90 , total integrated cost =  306.0572065899504
# RUN  100 , total integrated cost =  306.0572061248693
# RUN  100 , total integrated cost =  306.0572061248693
# Improved over  100  iterations in  48.18132173002232  seconds by  1.7389429984859817e-06  percent.
# cost splitting :  0.01681964481533898 [7.87374210e+00 4.81515288e-13]
# total cost =  7.8905617492493
# set cost params:  0.05 0.0 37.354443164071164
# interpolate adjoint :  True True True
# initial cost =  294.12009291087327
# RUN  0 , total integrated cost =  294.12009291087327
# Gradient descend method:  None
# RUN  1 , total integrated cost =  294.1200929036523
# RUN  2 , total integrated cost =  294.1200928820188
# RUN  3 , total integrated cost =  294.12009286478514
# RUN  4 , total integrated cost =  294.12009279946807
# RUN  5 , total integrated cost =  294.1200927251999
# RUN  6 , total integrated cost =  294.1200927199075
# RUN  7 , total integrated cost =  294.12009271320267
# RUN  8 , total integrated cost =  294.12009270978723
# RUN  9 , total integrated cost =  294.12009270455644
# RUN  10 , total integrated cost =  294.1200927011961
# RUN  11 , total integrated cost =  294.1200926944355
# RUN  12 , total integrated cost =  294.12009268924254
# RUN  13 , total integrated cost =  294.12009265582265
# RUN  14 , total integrated cost =  294.1200926275324
# RUN  15 , total integrated cost =  294.12009257945095
# RUN  16 , total integrated cost =  294.1200925245679
# RUN  17 , total integrated cost =  294.1200925185688
# RUN  18 , total integrated cost =  294.12009251046436
# RUN  19 , total integrated cost =  294.1200925067794
# RUN  20 , total integrated cost =  294.1200925013133
# RUN  30 , total integrated cost =  294.12009218907167
# ...
# interpolate adjoint :  True True True
# initial cost =  183.81745321707
# RUN  0 , total integrated cost =  183.81745321707
# Gradient descend method:  None
# RUN  1 , total integrated cost =  183.81745249351104
# RUN  2 , total integrated cost =  183.81745249207813
# RUN  3 , total integrated cost =  183.81745249207793
# RUN  4 , total integrated cost =  183.81745249207793
# Control only changes marginally.
# RUN  4 , total integrated cost =  183.81745249207793
# Improved over  4  iterations in  2.1648215539753437  seconds by  3.94408729675888e-07  percent.
# cost splitting :  6.251727292395935e-05 [7.87327917e+00 4.81515288e-13]
# total cost =  7.873341689644903
# set cost params:  0.05 0.0 40.95095509933144
# interpolate adjoint :  True True True
# initial cost =  322.41830499816996
# RUN  0 , total integrated cost =  322.41830499816996
# Gradient descend method:  None
# RUN  1 , total integrated cost =  322.4183042850983
# RUN  2 , total integrated cost =  322.4183042841878
# RUN  3 , total integrated cost =  322.4183042841874
# RUN  4 , total integrated cost =  322.41830428418723
# RUN  5 , total integrated cost =  322.41830428418723
# Control only changes marginally.
# RUN  5 , total integrated cost =  322.41830428418723
# Improved over  5  iterations in  3.4151720489608124  seconds by  2.2144610056784586e-07  percent.
# cost splitting :  0.00011288076554221927 [7.87327909e+00 4.81515288e-13]
# total cost =  7.8733919742100005
# set cost params:  0.05 0.0 8.876821695400404
# interpolate adjoint :  True True True
# initial cost =  69.88970031466847
# RUN  0 , total integrated cost =  69.88970031466847
# Gradient descend method:  None
# RUN  1 , total integrated cost =  69.88969796935702
# RUN  2 , total integrated cost =  69.8896979676577
# RUN  3 , total integrated cost =  69.88969796764924
# RUN  4 , total integrated cost =  69.88969796764623
# RUN  5 , total integrated cost =  69.88969796764616
# RUN  6 , total integrated cost =  69.88969796764509
# RUN  7 , total integrated cost =  69.88969796763926
# RUN  8 , total integrated cost =  69.88969796763836
# RUN  9 , total integrated cost =  69.88969796763817
# RUN  10 , total integrated cost =  69.88969796763749
# RUN  11 , total integrated cost =  69.8896979676302
# RUN  12 , total integrated cost =  69.88969796762787
# RUN  13 , total integrated cost =  69.88969796762777
# RUN  14 , total integrated cost =  69.88969796762736
# RUN  15 , total integrated cost =  69.8896979676131
# RUN  16 , total integrated cost =  69.88969796760452
# RUN  17 , total integrated cost =  69.88969796760433
# RUN  18 , total integrated cost =  69.88969796760412
# RUN  19 , total integrated cost =  69.88969796758087
# RUN  20 , total integrated cost =  69.88969796754532
# RUN  30 , total integrated cost =  69.88969796745094
# RUN  40 , total integrated cost =  69.88969796740633
# RUN  50 , total integrated cost =  69.88969796733522
# RUN  60 , total integrated cost =  69.88969796698656
# RUN  70 , total integrated cost =  69.88969796692798
# RUN  80 , total integrated cost =  69.8896979669097
# RUN  90 , total integrated cost =  69.88969796562205
# RUN  100 , total integrated cost =  69.88969796558433
# RUN  100 , total integrated cost =  69.88969796558433
# Improved over  100  iterations in  48.22943108098116  seconds by  3.361130652024258e-06  percent.
# cost splitting :  3.861622669886928e-05 [7.87327925e+00 4.81515288e-13]
# total cost =  7.873317863345846
# set cost params:  0.05 0.0 8.631619841208273
# interpolate adjoint :  True True True
# initial cost =  67.95915529561829
# RUN  0 , total integrated cost =  67.95915529561829
# Gradient descend method:  None
# RUN  1 , total integrated cost =  67.95915529539593
# RUN  2 , total integrated cost =  67.95915529539552
# RUN  3 , total integrated cost =  67.95915529539542
# RUN  4 , total integrated cost =  67.95915529539499
# RUN  5 , total integrated cost =  67.95915529538709
# RUN  6 , total integrated cost =  67.95915529538381
# RUN  7 , total integrated cost =  67.9591552953836
# RUN  8 , total integrated cost =  67.95915529538338
# RUN  9 , total integrated cost =  67.9591552953751
# RUN  10 , total integrated cost =  67.95915529536114
# RUN  11 , total integrated cost =  67.95915529536065
# RUN  12 , total integrated cost =  67.95915529536053
# RUN  13 , total integrated cost =  67.95915529536025
# RUN  14 , total integrated cost =  67.95915529535112
# RUN  15 , total integrated cost =  67.9591552953479
# RUN  16 , total integrated cost =  67.95915529534768
# RUN  17 , total integrated cost =  67.95915529534746
# RUN  18 , total integrated cost =  67.95915529521804
# RUN  19 , total integrated cost =  67.95915529506226
# RUN  20 , total integrated cost =  67.95915529506208
# RUN  30 , total integrated cost =  67.95915529499814
# RUN  40 , total integrated cost =  67.95915529453306
# RUN  50 , total integrated cost =  67.95915529438055
# RUN  60 , total integrated cost =  67.95915529430152
# RUN  70 , total integrated cost =  67.95915453300977
# Control only changes marginally.
# RUN  74 , total integrated cost =  67.95915453300374
# Improved over  74  iterations in  34.893987866002135  seconds by  1.1221660116689236e-06  percent.
# cost splitting :  2.9393674631581073e-05 [7.87327921e+00 4.81515288e-13]
# total cost =  7.873308605865576
# set cost params:  0.05 0.0 23.190385292809967
# interpolate adjoint :  True True True
# initial cost =  182.58437991826307
# RUN  0 , total integrated cost =  182.58437991826307
# Gradient descend method:  None
# RUN  1 , total integrated cost =  182.5843793461725
# RUN  2 , total integrated cost =  182.58437934563898
# RUN  3 , total integrated cost =  182.58437934563761
# RUN  4 , total integrated cost =  182.58437934563727
# RUN  5 , total integrated cost =  182.58437934563727
# Control only changes marginally.
# RUN  5 , total integrated cost =  182.58437934563727
# Improved over  5  iterations in  3.824133795918897  seconds by  3.1362255015210394e-07  percent.
# cost splitting :  5.35049645103111e-05 [7.87327914e+00 4.81515288e-13]
# total cost =  7.873332640477545
# set cost params:  0.05 0.0 11.751034062899329
# interpolate adjoint :  True True True
# initial cost =  92.51917398337648
# RUN  0 , total integrated cost =  92.51917398337648
# Gradient descend method:  None
# RUN  1 , total integrated cost =  92.51917365148887
# RUN  2 , total integrated cost =  92.51917365146574
# RUN  3 , total integrated cost =  92.51917365146554
# RUN  4 , total integrated cost =  92.51917365146554
# Control only changes marginally.
# RUN  4 , total integrated cost =  92.51917365146554
# Improved over  4  iterations in  2.750969015993178  seconds by  3.587482808597997e-07  percent.
# cost splitting :  3.293695681925038e-05 [7.87327919e+00 4.81515288e-13]
# total cost =  7.873312131740335
# set cost params:  0.05 0.0 17.30155001669285
# interpolate adjoint :  True True True
# initial cost =  136.21993543078204
# RUN  0 , total integrated cost =  136.21993543078204
# Gradient descend method:  None
# RUN  1 , total integrated cost =  136.21993534777263
# RUN  2 , total integrated cost =  136.2199353476248
# RUN  3 , total integrated cost =  136.2199353476248
# Control only changes marginally.
# RUN  3 , total integrated cost =  136.2199353476248
# Improved over  3  iterations in  2.2284381879726425  seconds by  6.104630756453844e-08  percent.
# cost splitting :  4.1519456034360665e-05 [7.87327917e+00 4.81515288e-13]
# total cost =  7.873320684630515
# set cost params:  0.05 0.0 38.521601687903654
# interpolate adjoint :  True True True
# initial cost =  303.29132605449473
# RUN  0 , total integrated cost =  303.29132605449473
# Gradient descend method:  None
# RUN  1 , total integrated cost =  303.2913249585755
# RUN  2 , total integrated cost =  303.29132495832516
# RUN  3 , total integrated cost =  303.2913249583221
# RUN  4 , total integrated cost =  303.2913249583214
# RUN  5 , total integrated cost =  303.2913249583214
# Control only changes marginally.
# RUN  5 , total integrated cost =  303.2913249583214
# Improved over  5  iterations in  3.5459201809717342  seconds by  3.6142586168352864e-07  percent.
# cost splitting :  9.667180882622446e-05 [7.87327907e+00 4.81515288e-13]
# total cost =  7.873375736940973
# set cost params:  0.05 0.0 11.587451776394714
# interpolate adjoint :  True True True
# initial cost =  91.23124632290725
# RUN  0 , total integrated cost =  91.23124632290725
# Gradient descend method:  None
# RUN  1 , total integrated cost =  91.23124464050252
# RUN  2 , total integrated cost =  91.2312446384173
# RUN  3 , total integrated cost =  91.23124463841425
# RUN  4 , total integrated cost =  91.2312446384142
# RUN  5 , total integrated cost =  91.2312446384142
# Control only changes marginally.
# RUN  5 , total integrated cost =  91.2312446384142
# Improved over  5  iterations in  3.7475729279685766  seconds by  1.846399257487974e-06  percent.
# cost splitting :  3.27258460009397e-05 [7.87327920e+00 4.81515288e-13]
# total cost =  7.873311921533607
# set cost params:  0.05 0.0 28.921491690524853
# interpolate adjoint :  True True True
# initial cost =  227.70698047155358
# RUN  0 , total integrated cost =  227.70698047155358
# Gradient descend method:  None
# RUN  1 , total integrated cost =  227.7069796904559
# RUN  2 , total integrated cost =  227.70697969033853
# RUN  3 , total integrated cost =  227.70697969033768
# RUN  4 , total integrated cost =  227.70697969033753
# RUN  5 , total integrated cost =  227.70697969033753
# Control only changes marginally.
# RUN  5 , total integrated cost =  227.70697969033753
# Improved over  5  iterations in  3.0680305029964074  seconds by  3.4307953455936513e-07  percent.
# cost splitting :  6.774709773321794e-05 [7.87327911e+00 4.81515288e-13]
# total cost =  7.873346855228353
# set cost params:  0.05 0.0 36.232486988377744
# interpolate adjoint :  True True True
# initial cost =  285.26848622856386
# RUN  0 , total integrated cost =  285.26848622856386
# Gradient descend method:  None
# RUN  1 , total integrated cost =  285.2684861057346
# RUN  2 , total integrated cost =  285.26848610566446
# RUN  3 , total integrated cost =  285.26848610566356
# RUN  4 , total integrated cost =  285.26848610566356
# Control only changes marginally.
# RUN  4 , total integrated cost =  285.26848610566356
# Improved over  4  iterations in  2.332804854027927  seconds by  4.308232348648744e-08  percent.
# cost splitting :  8.922153841411652e-05 [7.87327908e+00 4.81515288e-13]
# total cost =  7.8733682966428065
# set cost params:  0.05 0.0 27.464374555669927
# interpolate adjoint :  True True True
# initial cost =  216.23468996106243
# RUN  0 , total integrated cost =  216.23468996106243
# Gradient descend method:  None
# RUN  1 , total integrated cost =  216.23468978979125
# RUN  2 , total integrated cost =  216.2346897895955
# RUN  3 , total integrated cost =  216.23468978959474
# RUN  4 , total integrated cost =  216.2346897895946
# RUN  5 , total integrated cost =  216.2346897895946
# Control only changes marginally.
# RUN  5 , total integrated cost =  216.2346897895946
# Improved over  5  iterations in  2.9186738739954308  seconds by  7.929710932330636e-08  percent.
# cost splitting :  6.392103293361882e-05 [7.87327911e+00 4.81515288e-13]
# total cost =  7.873343035954632
# set cost params:  0.05 0.0 4.043050694762798
# interpolate adjoint :  True True True
# initial cost =  31.832069791697254
# RUN  0 , total integrated cost =  31.832069791697254
# Gradient descend method:  None
# RUN  1 , total integrated cost =  31.832068399157087
# RUN  2 , total integrated cost =  31.83206839797918
# RUN  3 , total integrated cost =  31.832068397976848
# RUN  4 , total integrated cost =  31.832068397976446
# RUN  5 , total integrated cost =  31.832068397975537
# RUN  6 , total integrated cost =  31.832068397973156
# RUN  7 , total integrated cost =  31.832068397972822
# RUN  8 , total integrated cost =  31.832068397971632
# RUN  9 , total integrated cost =  31.83206839796878
# RUN  10 , total integrated cost =  31.832068397968378
# RUN  11 , total integrated cost =  31.832068397967497
# RUN  12 , total integrated cost =  31.832068397965113
# RUN  13 , total integrated cost =  31.8320683979647
# RUN  14 , total integrated cost =  31.832068397964278
# RUN  15 , total integrated cost =  31.832068397962008
# RUN  16 , total integrated cost =  31.8320683979611
# RUN  17 , total integrated cost =  31.832068397960686
# RUN  18 , total integrated cost =  31.832068397958054
# RUN  19 , total integrated cost =  31.83206839795692
# RUN  20 , total integrated cost =  31.832068397956537
# RUN  30 , total integrated cost =  31.83206839794019
# RUN  40 , total integrated cost =  31.83206839701632
# RUN  50 , total integrated cost =  31.832068396390508
# RUN  60 , total integrated cost =  31.83206839637168
# RUN  70 , total integrated cost =  31.832068396340762
# RUN  80 , total integrated cost =  31.832068396328545
# RUN  90 , total integrated cost =  31.832068396108777
# RUN  100 , total integrated cost =  31.83206839609178
# RUN  100 , total integrated cost =  31.83206839609178
# Improved over  100  iterations in  45.39637270302046  seconds by  4.384274987501158e-06  percent.
# cost splitting :  2.599415295762135e-05 [7.87327924e+00 4.81515288e-13]
# total cost =  7.873305232926313
# set cost params:  0.05 0.0 14.036571835562693
# interpolate adjoint :  True True True
# initial cost =  110.51385091619423
# RUN  0 , total integrated cost =  110.51385091619423
# Gradient descend method:  None
# RUN  1 , total integrated cost =  110.51385062924527
# RUN  2 , total integrated cost =  110.51385062919691
# RUN  3 , total integrated cost =  110.5138506291961
# RUN  4 , total integrated cost =  110.5138506291961
# Control only changes marginally.
# RUN  4 , total integrated cost =  110.5138506291961
# Improved over  4  iterations in  2.49870875896886  seconds by  2.5969426076244417e-07  percent.
# cost splitting :  3.609257332252962e-05 [7.87327918e+00 4.81515288e-13]
# total cost =  7.873315274928406
# set cost params:  0.05 0.0 17.307057438337264
# interpolate adjoint :  True True True
# initial cost =  136.26329684171313
# RUN  0 , total integrated cost =  136.26329684171313
# Gradient descend method:  None
# RUN  1 , total integrated cost =  136.2632968132189
# RUN  2 , total integrated cost =  136.26329681317154
# RUN  3 , total integrated cost =  136.26329681317137
# RUN  4 , total integrated cost =  136.26329681317125
# RUN  5 , total integrated cost =  136.26329681317125
# Control only changes marginally.
# RUN  5 , total integrated cost =  136.26329681317125
# Improved over  5  iterations in  2.7740279720164835  seconds by  2.0946117729181424e-08  percent.
# cost splitting :  4.149727742709351e-05 [7.87327917e+00 4.81515288e-13]
# total cost =  7.873320662369202
# set cost params:  0.05 0.0 18.64097224791481
# interpolate adjoint :  True True True
# initial cost =  146.76558049142554
# RUN  0 , total integrated cost =  146.76558049142554
# Gradient descend method:  None
# RUN  1 , total integrated cost =  146.7655804867733
# RUN  2 , total integrated cost =  146.76558048673922
# RUN  3 , total integrated cost =  146.76558048672652
# RUN  4 , total integrated cost =  146.76558048672624
# RUN  5 , total integrated cost =  146.76558048672624
# Control only changes marginally.
# RUN  5 , total integrated cost =  146.76558048672624
# Improved over  5  iterations in  2.399820599006489  seconds by  3.2019045193010243e-09  percent.
# cost splitting :  4.396558085469456e-05 [7.87327916e+00 4.81515288e-13]
# total cost =  7.873323123799894
# set cost params:  0.05 0.0 16.692750312015793
# interpolate adjoint :  True True True
# initial cost =  131.42668532322736
# RUN  0 , total integrated cost =  131.42668532322736
# Gradient descend method:  None
# RUN  1 , total integrated cost =  131.42668531355022
# RUN  2 , total integrated cost =  131.42668531355022
# Control only changes marginally.
# RUN  2 , total integrated cost =  131.42668531355022
# Improved over  2  iterations in  1.7268848420353606  seconds by  7.36314120786119e-09  percent.
# cost splitting :  4.0389409388139426e-05 [7.87327917e+00 4.81515288e-13]
# total cost =  7.873319557760459
# -------  77 0.4500000000000001 0.7000000000000004
# -------  78 0.47500000000000014 0.7000000000000004
# -------  79 0.5000000000000002 0.7000000000000004
# -------  80 0.5250000000000001 0.7000000000000004
# -------  81 0.5500000000000003 0.7000000000000004
# -------  82 0.5750000000000002 0.7000000000000004
