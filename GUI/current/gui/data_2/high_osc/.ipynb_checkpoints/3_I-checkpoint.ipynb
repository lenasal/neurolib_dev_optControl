# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import sys
import pickle
import random

path = os.getcwd().split(os.sep + 'GUI')[0]
if path not in sys.path:
    print("not here")
    sys.path.append(path)

from neurolib.models.aln import ALNModel
from neurolib.utils import plotFunctions as plotFunc
from neurolib.utils import costFunctions as cost
import neurolib.dashboard.functions as functions
import neurolib.dashboard.data as data
    
# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2 

#path = os.path.join(os.getcwd(), "plots")
# Out:
# not here

# %%
exc = 0.4
inh = 0.316

# %%
aln = ALNModel()
N = aln.params.N

data.set_parameters(aln)

state_vars = aln.state_vars
init_vars = aln.init_vars

##############################################################
def setinit(init_vars_, model):
    state_vars = model.state_vars
    init_vars = model.init_vars
    for iv in range(len(init_vars)):
        for sv in range(len(state_vars)):
            if state_vars[sv] in init_vars[iv]:
                #print("set init vars ", )
                if model.params[init_vars[iv]].ndim == 2:
                    model.params[init_vars[iv]][0,:] = init_vars_[sv]
                else:
                    model.params[init_vars[iv]][0] = init_vars_[sv]
                    
##############################################################               
def setmaxmincontrol(max_c_c, min_c_c, max_c_r, min_c_r):
    import numpy as np
    
    max_cntrl = np.zeros(( 6 ))
    min_cntrl = np.zeros(( 6 ))
    
    max_cntrl[0] = max_c_c
    min_cntrl[0] = min_c_c
    max_cntrl[1] = max_c_c
    min_cntrl[1] = min_c_c
    max_cntrl[2] = max_c_r
    min_cntrl[2] = min_c_r
    max_cntrl[3] = max_c_r
    min_cntrl[3] = min_c_r
    max_cntrl[4] = max_c_r
    min_cntrl[4] = min_c_r
    max_cntrl[5] = max_c_r
    min_cntrl[5] = min_c_r
            
    return max_cntrl, min_cntrl

# %%
dur = 500.
t_pen = 0.7
int_t_pen = int((1.-t_pen)*dur/aln.params.dt)

# %%
file_ = '3_I.pickle'
folder = str(os.getcwd().split('data_2')[1])
print(folder)
case = '3'
# Out:
# /high_osc

# %%
dur_pre = 10
dur_post = 10

n_pre = int(np.around(dur_pre/aln.params.dt + 1.,1))
n_post = int(np.around(dur_post/aln.params.dt + 1.,1))

tol = 1e-10
start_step = 10.
c_scheme = np.zeros(( 1,1 ))
c_scheme[0,0] = 1.
u_mat = np.identity(1)
u_scheme = np.array([[1.]])

p_var = [0]
c_var = [1]
wp = 1. / (dur - t_pen * dur)

if case in ['1', '2']:    # osc to high
    max_I = [3., -3.]
else:
    max_I = [-3., 3.]
    
if case in ['1', '3']:    # sparsity
    factor_ws = 1.
    factor_we = 0.
else:
    factor_ws = 0.
    factor_we = 1.
    
maxC = [5., -5., 0.18, 0.]
max_cntrl, min_cntrl = setmaxmincontrol(maxC[0], maxC[1], maxC[2], maxC[3])

# %%
bestControl_ = None

if os.path.isfile(file_) :
    print("file found")
    
    with open(file_,'rb') as f:
        load_array = pickle.load(f)

    bestControl_ = load_array[0]
# Out:
# file found

# %%
# get initial parameters and target states
data.set_parameters(aln)

aln.params.ext_exc_current = exc * 5.
aln.params.ext_inh_current = inh * 5.

aln.params.duration = 3000.

control0 = aln.getZeroControl()
control0 = functions.step_control(aln, maxI_ = max_I[0])

aln.run(control=control0)
plt.plot(aln.t, aln.rates_exc[0,:])
plt.show()

target_rates = np.zeros((2, int_t_pen))
target_rates[0,:] = aln.rates_exc[0,-int_t_pen:] 
target_rates[1,:] = aln.rates_inh[0,-int_t_pen:]

control0 = functions.step_control(aln, maxI_ = max_I[1])
aln.run(control=control0)
plt.plot(aln.t, aln.rates_exc[0,:])
plt.show()

init_state_vars = np.zeros(( len(state_vars) ))
for j in range(len(state_vars)):
    if aln.state[state_vars[j]].size == 1:
        init_state_vars[j] = aln.state[state_vars[j]][0]
    else:
        init_state_vars[j] = aln.state[state_vars[j]][0,-1]

initVars = init_state_vars
target = [target_rates[0,:], target_rates[1,:]]

print(initVars[0])
print(target[0][::100])
# Out:
# 25.98168358603569
# [0.67581631 0.45793241 1.00459912 2.30159581 2.57499306 1.43003446
#  0.56826009 0.50399557 1.23231814 2.5250781  2.39702322 1.1874474
#  0.49520273 0.58207539 1.49398809]

# %%
# get uncontrolled cost
    
aln.params.duration = dur

target_ = aln.getZeroTarget()
target_[:,0,-int_t_pen:] = target[0]
target_[:,1,-int_t_pen:] = target[1]

cost.setParams(wp, 0.0, 0.0)

setinit(initVars, aln)
control0 = aln.getZeroControl()

cgv = None
max_it = 0

bestControl_init_, bestState_init_, cost_init_, runtime_init_, grad_init_, phi_init_, phi1_, costnode_init_ = aln.A1(
    control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
    startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
    t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
    prec_variables_ = p_var, transition_time_ = t_pen)

cost_uncontrolled = cost_init_[0]
# Out:
# set cost params:  0.006666666666666667 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  303.5628677925299
# RUN  0 , total integrated cost =  303.5628677925299
# Gradient descend method:  None
# RUN  0 , total integrated cost =  303.5628677925299
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.

# %%
cgv = None
j = 0

aln.params.duration = dur
setinit(initVars, aln)

target_ = aln.getZeroTarget()
target_[:,0,-int_t_pen:] = target[0]
target_[:,1,-int_t_pen:] = target[1]

control0 = aln.getZeroControl()
cost.setParams(wp, 0., 10.)
max_it = int(10)

control0[0,1,1200:1800] = 2.

bestControl_, bestState_, cost_, runtime_, grad_, phi_, phi1_, costnode_ = aln.A1(
    control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
    startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
    t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
    prec_variables_ = p_var, transition_time_ = t_pen)

if True:
    plot_time_array = np.arange(0.,round(dur+aln.params.dt,1),aln.params.dt)
    target_ = aln.getZeroTarget()
    target_[:,0,-int_t_pen:] = target[0]
    target_[:,1,-int_t_pen:] = target[1]

    fig, ax = plt.subplots(2,1, constrained_layout=True, figsize = (4,6) )
    ax[1].plot(plot_time_array, bestControl_[0,0,n_pre-1:-n_post+1], color = 'red')
    ax[0].plot(plot_time_array, bestState_[0,0,n_pre-1:-n_post+1], color= 'red')
    ax[1].plot(plot_time_array, bestControl_[0,1,n_pre-1:-n_post+1], color = 'blue')
    ax[0].plot(plot_time_array, bestState_[0,1,n_pre-1:-n_post+1], color= 'blue')
    ax[0].plot(plot_time_array, target_[0,0,n_pre-1:-n_post+1], linestyle = '--', color='red')
    ax[0].plot(plot_time_array, target_[0,1,n_pre-1:-n_post+1], linestyle = '--', color='blue')

    for k in range(2):
        ax[k].set_xlim(0.,dur)
        ax[k].axvspan(dur*t_pen, dur, alpha=0.2, color='gray')
    plt.show()

print('uncontrolled cost : ', cost_uncontrolled)
print('cost splitting : ', costnode_[0][0][0], costnode_[2][0][:2])
# Out:
# set cost params:  0.006666666666666667 0.0 10.0
# interpolate adjoint :  True True True
# initial cost =  156.21070236213242
# RUN  0 , total integrated cost =  156.21070236213242
# Gradient descend method:  None
# RUN  1 , total integrated cost =  148.9865678073263
# RUN  2 , total integrated cost =  144.8843842520503
# RUN  3 , total integrated cost =  141.06333959349908
# RUN  4 , total integrated cost =  138.17263736166936
# RUN  5 , total integrated cost =  135.76355865064775
# RUN  6 , total integrated cost =  135.60050690729958
# RUN  7 , total integrated cost =  135.42775639215873
# RUN  8 , total integrated cost =  135.4121536569607
# RUN  9 , total integrated cost =  135.4121450853554
# RUN  10 , total integrated cost =  135.41213563770984
# RUN  10 , total integrated cost =  135.41213563770984
# Improved over  10  iterations in  0.9357191439776216  seconds by  13.314431348120266  percent.
# uncontrolled cost :  303.5628677925299
# cost splitting :  41.37542353937162 [ 0.         13.51362995]

# %%
c_var = [0,1]
max_it = int(30)
conv = False

tol = 1e-6
    
while not conv:

    weight_ = random.random() * ( cost_uncontrolled -
                                 costnode_[0][0][0] ) / sum( costnode_[2][0][:] )

    aln.params.duration = dur
    cost.setParams(wp, weight_ * factor_we, weight_ * factor_ws)
    weights_ = cost.getParams()

    setinit(initVars, aln)

    target_ = aln.getZeroTarget()
    target_[:,0,-int_t_pen:] = target[0]
    target_[:,1,-int_t_pen:] = target[1]

    control0 = aln.getZeroControl()
    control0 = bestControl_[:,:,n_pre-1:-n_post+1]

    bestControl_, bestState_, cost_, runtime_, grad_, phi_, phi1_, costnode_ = aln.A1(
        control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
        prec_variables_ = p_var, transition_time_ = t_pen)

    if cost_[2] == 0.:
        conv = True

    #print('uncontrolled cost : ', cost_uncontrolled[i])
    print('cost splitting : ', costnode_[0][0][0], costnode_[2][0][:2])

    if conv and True:
        time_ = np.arange(-dur_pre,round(dur+dur_post+aln.params.dt,1),aln.params.dt)
        target_ = aln.getZeroTarget()
        target_[:,0,-int_t_pen:] = target[0]
        target_[:,1,-int_t_pen:] = target[1]

        fig, ax = plt.subplots(2,1, constrained_layout=True, figsize = (4,4) )
        ax[1].plot(time_, bestControl_[0,0,:], color = 'red')
        ax[0].plot(time_, bestState_[0,0,:], color= 'red')
        ax[1].plot(time_, bestControl_[0,1,:], color = 'blue')
        ax[0].plot(time_, bestState_[0,1,:], color= 'blue')
        ax[0].plot(time_, target_[0,0,:], linestyle = '--', color='red')
        ax[0].plot(time_, target_[0,1,:], linestyle = '--', color='blue')
        ax[0].set_xlim(-dur_pre,dur+dur_post)
        ax[1].set_xlim(-dur_pre,dur+dur_post)
        ax[0].axvspan(dur*t_pen, dur, alpha=0.2, color='gray')
        plt.show()

    with open(file_,'wb') as f:
        pickle.dump([bestControl_, bestState_, cost_, costnode_, weights_], f)
# Out:
# set cost params:  0.006666666666666667 0.0 18.22930230011255
# interpolate adjoint :  True True True
# initial cost =  246.61988165229855
# RUN  0 , total integrated cost =  246.61988165229855
# Gradient descend method:  None
# RUN  1 , total integrated cost =  246.61988165229855
# Control only changes marginally.
# RUN  1 , total integrated cost =  246.61988165229855
# Improved over  1  iterations in  0.2793064809811767  seconds by  0.0  percent.
# cost splitting :  41.37542353937162 [ 0.         13.51362995]

# %%
c_var = [0,1]
max_it = int(30)
conv = False

tol = 1e-8
    
while not conv:

    weight_ = random.random() * ( cost_uncontrolled -
                                 costnode_[0][0][0] ) / sum( costnode_[2][0][:] )

    aln.params.duration = dur
    cost.setParams(wp, weight_ * factor_we, weight_ * factor_ws)
    weights_ = cost.getParams()

    setinit(initVars, aln)

    target_ = aln.getZeroTarget()
    target_[:,0,-int_t_pen:] = target[0]
    target_[:,1,-int_t_pen:] = target[1]

    control0 = aln.getZeroControl()
    control0 = bestControl_[:,:,n_pre-1:-n_post+1]

    bestControl_, bestState_, cost_, runtime_, grad_, phi_, phi1_, costnode_ = aln.A1(
        control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
        prec_variables_ = p_var, transition_time_ = t_pen)

    if cost_[2] == 0.:
        conv = True

    #print('uncontrolled cost : ', cost_uncontrolled[i])
    print('cost splitting : ', costnode_[0][0][0], costnode_[2][0][:2])

    if conv and True:
        time_ = np.arange(-dur_pre,round(dur+dur_post+aln.params.dt,1),aln.params.dt)
        target_ = aln.getZeroTarget()
        target_[:,0,-int_t_pen:] = target[0]
        target_[:,1,-int_t_pen:] = target[1]

        fig, ax = plt.subplots(2,1, constrained_layout=True, figsize = (4,4) )
        ax[1].plot(time_, bestControl_[0,0,:], color = 'red')
        ax[0].plot(time_, bestState_[0,0,:], color= 'red')
        ax[1].plot(time_, bestControl_[0,1,:], color = 'blue')
        ax[0].plot(time_, bestState_[0,1,:], color= 'blue')
        ax[0].plot(time_, target_[0,0,:], linestyle = '--', color='red')
        ax[0].plot(time_, target_[0,1,:], linestyle = '--', color='blue')
        ax[0].set_xlim(-dur_pre,dur+dur_post)
        ax[1].set_xlim(-dur_pre,dur+dur_post)
        ax[0].axvspan(dur*t_pen, dur, alpha=0.2, color='gray')
        plt.show()

    with open(file_,'wb') as f:
        pickle.dump([bestControl_, bestState_, cost_, costnode_, weights_], f)
# Out:
# set cost params:  0.006666666666666667 0.0 2.11435941548662
# interpolate adjoint :  True True True
# initial cost =  28.84850687504998
# RUN  0 , total integrated cost =  28.84850687504998
# Gradient descend method:  None
# RUN  1 , total integrated cost =  28.84847929356845
# RUN  2 , total integrated cost =  28.848477018824052
# RUN  3 , total integrated cost =  28.848474406102678
# RUN  4 , total integrated cost =  28.84847168293157
# RUN  5 , total integrated cost =  28.848390601650557
# RUN  6 , total integrated cost =  28.848333280824114
# RUN  7 , total integrated cost =  28.84819810038726
# RUN  8 , total integrated cost =  28.84808191591502
# RUN  9 , total integrated cost =  28.847979979416458
# RUN  10 , total integrated cost =  28.847877746492024
# RUN  11 , total integrated cost =  28.846434224814082
# RUN  12 , total integrated cost =  28.845339397813255
# RUN  13 , total integrated cost =  28.84533341785256
# RUN  14 , total integrated cost =  28.845332652543554
# RUN  15 , total integrated cost =  28.843691072683015
# RUN  16 , total integrated cost =  28.84228457632748
# RUN  17 , total integrated cost =  28.842277626429226
# RUN  18 , total integrated cost =  28.842267221384745
# RUN  19 , total integrated cost =  28.84225917372436
# RUN  20 , total integrated cost =  28.84224770199091
# RUN  30 , total integrated cost =  28.842152318425406
# RUN  30 , total integrated cost =  28.842152318425406
# Improved over  30  iterations in  7.881587753014173  seconds by  0.0220273328255729  percent.
# cost splitting :  40.49439564313008 [1.26752316e-06 1.35134012e+01]
# set cost params:  0.006666666666666667 0.0 11.676721941130694
# interpolate adjoint :  True True True
# initial cost =  158.06220538893828
# RUN  0 , total integrated cost =  158.06220538893828
# Gradient descend method:  None
# RUN  1 , total integrated cost =  158.06182869485966
# RUN  2 , total integrated cost =  158.0613871366665
# RUN  3 , total integrated cost =  158.0613616882448
# RUN  4 , total integrated cost =  158.06135484915498
# RUN  5 , total integrated cost =  158.0613031441007
# RUN  6 , total integrated cost =  158.06124121493187
# RUN  7 , total integrated cost =  158.06121569354215
# RUN  8 , total integrated cost =  158.06120882359372
# RUN  9 , total integrated cost =  158.06115753775262
# RUN  10 , total integrated cost =  158.06109516919804
# RUN  11 , total integrated cost =  158.06106931570693
# RUN  12 , total integrated cost =  158.06106246317313
# RUN  13 , total integrated cost =  158.06099416735833
# RUN  14 , total integrated cost =  158.06092181982436
# RUN  15 , total integrated cost =  158.06089794149491
# RUN  16 , total integrated cost =  158.06088612288883
# RUN  17 , total integrated cost =  158.06085996718528
# RUN  18 , total integrated cost =  158.06085312850578
# RUN  19 , total integrated cost =  158.06078872607756
# RUN  20 , total integrated cost =  158.06071131666715
# RUN  30 , total integrated cost =  158.060363504041
# RUN  30 , total integrated cost =  158.060363504041
# Improved over  30  iterations in  7.4274664130061865  seconds by  0.0011652911540522837  percent.
# cost splitting :  40.42069197560086 [3.44336366e-06 1.35132833e+01]
# set cost params:  0.006666666666666667 0.0 18.134737157209
# interpolate adjoint :  True True True
# initial cost =  245.32937513932228
# RUN  0 , total integrated cost =  245.32937513932228
# Gradient descend method:  None
# RUN  1 , total integrated cost =  245.32933480496956
# RUN  2 , total integrated cost =  245.32928028158952
# RUN  3 , total integrated cost =  245.32923936028908
# RUN  4 , total integrated cost =  245.32918511450455
# RUN  5 , total integrated cost =  245.32914452688073
# RUN  6 , total integrated cost =  245.32909002864673
# RUN  7 , total integrated cost =  245.32904910424426
# RUN  8 , total integrated cost =  245.32899474787675
# RUN  9 , total integrated cost =  245.32895427476802
# RUN  10 , total integrated cost =  245.32890093658588
# RUN  11 , total integrated cost =  245.32886138562674
# RUN  12 , total integrated cost =  245.32880723137177
# RUN  13 , total integrated cost =  245.32876699814142
# RUN  14 , total integrated cost =  245.32871338216938
# RUN  15 , total integrated cost =  245.32867372384425
# RUN  16 , total integrated cost =  245.32861952303756
# RUN  17 , total integrated cost =  245.32857921586339
# RUN  18 , total integrated cost =  245.32852552851702
# RUN  19 , total integrated cost =  245.3284859339709
# RUN  20 , total integrated cost =  245.32843153053264
# RUN  30 , total integrated cost =  245.32796009237532
# RUN  30 , total integrated cost =  245.32796009237532
# Improved over  30  iterations in  6.6740580780024175  seconds by  0.0005767947463084511  percent.
# cost splitting :  40.40131780185117 [5.96008600e-06 1.35132099e+01]
# set cost params:  0.006666666666666667 0.0 4.785088816223005
# interpolate adjoint :  True True True
# initial cost =  64.93128025539207
# RUN  0 , total integrated cost =  64.93128025539207
# Gradient descend method:  None
# RUN  1 , total integrated cost =  64.83100831028628
# RUN  2 , total integrated cost =  64.74607792471177
# RUN  3 , total integrated cost =  64.74593746836406
# RUN  4 , total integrated cost =  63.73991212709148
# RUN  5 , total integrated cost =  63.66090359181628
# RUN  6 , total integrated cost =  63.219915457229234
# RUN  7 , total integrated cost =  63.19251756445214
# RUN  8 , total integrated cost =  63.180708676275614
# RUN  9 , total integrated cost =  63.17453361242061
# RUN  10 , total integrated cost =  63.163126366145804
# RUN  11 , total integrated cost =  63.154335837794726
# RUN  12 , total integrated cost =  63.14429185994479
# RUN  13 , total integrated cost =  63.13715950291575
# RUN  14 , total integrated cost =  63.128220127517736
# RUN  15 , total integrated cost =  63.1230251746376
# RUN  16 , total integrated cost =  63.11596572299155
# RUN  17 , total integrated cost =  63.11174146060521
# RUN  18 , total integrated cost =  63.105590687474056
# RUN  19 , total integrated cost =  63.10123538558878
# RUN  20 , total integrated cost =  63.09520129119893
# RUN  30 , total integrated cost =  63.01149598882149
# RUN  30 , total integrated cost =  63.01149598882149
# Improved over  30  iterations in  6.813431782997213  seconds by  2.9566400955280017  percent.
# cost splitting :  12.213472571745747 [1.27969539e-03 1.31500066e+01]
# set cost params:  0.006666666666666667 0.0 20.253526175909276
# interpolate adjoint :  True True True
# initial cost =  266.4413438194746
# RUN  0 , total integrated cost =  266.4413438194746
# Gradient descend method:  None
# RUN  1 , total integrated cost =  258.81344663724957
# RUN  2 , total integrated cost =  246.5451792994378
# RUN  3 , total integrated cost =  246.01033241920254
# RUN  4 , total integrated cost =  245.99058021176788
# RUN  5 , total integrated cost =  245.96264337755213
# RUN  6 , total integrated cost =  245.95815329159137
# RUN  7 , total integrated cost =  245.8891220915926
# RUN  8 , total integrated cost =  245.87970622295282
# RUN  9 , total integrated cost =  245.73144306705973
# RUN  10 , total integrated cost =  245.54546521997042
# RUN  11 , total integrated cost =  245.42123062197828
# RUN  12 , total integrated cost =  245.4212276966301
# RUN  13 , total integrated cost =  245.4212276966301
# Control only changes marginally.
# RUN  13 , total integrated cost =  245.4212276966301
# Improved over  13  iterations in  3.1718183560005855  seconds by  7.8892096179662445  percent.
# cost splitting :  46.31015437818517 [2.02035760e-03 1.21001929e+01]
# set cost params:  0.006666666666666667 0.0 5.576326206811906
# interpolate adjoint :  True True True
# initial cost =  67.79462340350136
# RUN  0 , total integrated cost =  67.79462340350136
# Gradient descend method:  None
# RUN  1 , total integrated cost =  67.79462189303277
# RUN  2 , total integrated cost =  67.79462189303277
# Control only changes marginally.
# RUN  2 , total integrated cost =  67.79462189303277
# Improved over  2  iterations in  0.8092348699865397  seconds by  2.2280064655433307e-06  percent.
# cost splitting :  46.30979235577151 [2.02035760e-03 1.21001931e+01]
# set cost params:  0.006666666666666667 0.0 2.269202681545219
# interpolate adjoint :  True True True
# initial cost =  27.77110713080353
# RUN  0 , total integrated cost =  27.77110713080353
# Gradient descend method:  None
# RUN  1 , total integrated cost =  27.77110713080353
# Control only changes marginally.
# RUN  1 , total integrated cost =  27.77110713080353
# Improved over  1  iterations in  0.3668367920035962  seconds by  0.0  percent.
# cost splitting :  46.30979235577151 [2.02035760e-03 1.21001931e+01]

# %%
c_var = [0,1]
max_it = int(30)
conv = False

tol = 1e-10
    
while not conv:

    weight_ = random.random() * ( cost_uncontrolled -
                                 costnode_[0][0][0] ) / sum( costnode_[2][0][:] )

    aln.params.duration = dur
    cost.setParams(wp, weight_ * factor_we, weight_ * factor_ws)
    weights_ = cost.getParams()

    setinit(initVars, aln)

    target_ = aln.getZeroTarget()
    target_[:,0,-int_t_pen:] = target[0]
    target_[:,1,-int_t_pen:] = target[1]

    control0 = aln.getZeroControl()
    control0 = bestControl_[:,:,n_pre-1:-n_post+1]

    bestControl_, bestState_, cost_, runtime_, grad_, phi_, phi1_, costnode_ = aln.A1(
        control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
        prec_variables_ = p_var, transition_time_ = t_pen)

    if cost_[2] == 0.:
        conv = True

    #print('uncontrolled cost : ', cost_uncontrolled[i])
    print('cost splitting : ', costnode_[0][0][0], costnode_[2][0][:2])

    if conv and True:
        time_ = np.arange(-dur_pre,round(dur+dur_post+aln.params.dt,1),aln.params.dt)
        target_ = aln.getZeroTarget()
        target_[:,0,-int_t_pen:] = target[0]
        target_[:,1,-int_t_pen:] = target[1]

        fig, ax = plt.subplots(2,1, constrained_layout=True, figsize = (4,4) )
        ax[1].plot(time_, bestControl_[0,0,:], color = 'red')
        ax[0].plot(time_, bestState_[0,0,:], color= 'red')
        ax[1].plot(time_, bestControl_[0,1,:], color = 'blue')
        ax[0].plot(time_, bestState_[0,1,:], color= 'blue')
        ax[0].plot(time_, target_[0,0,:], linestyle = '--', color='red')
        ax[0].plot(time_, target_[0,1,:], linestyle = '--', color='blue')
        ax[0].set_xlim(-dur_pre,dur+dur_post)
        ax[1].set_xlim(-dur_pre,dur+dur_post)
        ax[0].axvspan(dur*t_pen, dur, alpha=0.2, color='gray')
        plt.show()

    with open(file_,'wb') as f:
        pickle.dump([bestControl_, bestState_, cost_, costnode_, weights_], f)
# Out:
# set cost params:  0.006666666666666667 0.0 10.98971755803165
# interpolate adjoint :  True True True
# initial cost =  133.3086394384753
# RUN  0 , total integrated cost =  133.3086394384753
# Gradient descend method:  None
# RUN  1 , total integrated cost =  133.30863935006337
# RUN  2 , total integrated cost =  133.30863894130087
# RUN  3 , total integrated cost =  133.3086385420784
# RUN  4 , total integrated cost =  133.30863789157326
# RUN  5 , total integrated cost =  133.30863726583354
# RUN  6 , total integrated cost =  133.30863726133467
# RUN  7 , total integrated cost =  133.30863673476887
# RUN  8 , total integrated cost =  133.30863617166776
# RUN  9 , total integrated cost =  133.3086353971067
# RUN  10 , total integrated cost =  133.30863249672726
# RUN  11 , total integrated cost =  133.30863225077823
# RUN  12 , total integrated cost =  133.30863178953547
# RUN  13 , total integrated cost =  133.30863131800007
# RUN  14 , total integrated cost =  133.3086313128975
# RUN  15 , total integrated cost =  133.3086308072417
# RUN  16 , total integrated cost =  133.308630258548
# RUN  17 , total integrated cost =  133.3086294675723
# RUN  18 , total integrated cost =  133.30862879123995
# RUN  19 , total integrated cost =  133.3086283294282
# RUN  20 , total integrated cost =  133.30862786695528
# RUN  30 , total integrated cost =  133.30862403506725
# RUN  30 , total integrated cost =  133.30862403506725
# Improved over  30  iterations in  7.403054591995897  seconds by  1.1554696015991794e-05  percent.
# cost splitting :  46.30980789973417 [2.02043015e-03 1.21001916e+01]
# set cost params:  0.006666666666666667 0.0 0.10290276306445804
# interpolate adjoint :  True True True
# initial cost =  1.5540831092315326
# RUN  0 , total integrated cost =  1.5540831092315326
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.533774131449178
# RUN  2 , total integrated cost =  1.3683206051747066
# RUN  3 , total integrated cost =  1.3524291356036828
# RUN  4 , total integrated cost =  1.3283387037296615
# RUN  5 , total integrated cost =  1.3159203927706478
# RUN  6 , total integrated cost =  1.3101331427665703
# RUN  7 , total integrated cost =  1.3064357075844155
# RUN  8 , total integrated cost =  1.2982682744062102
# RUN  9 , total integrated cost =  1.293821462733577
# RUN  10 , total integrated cost =  1.292370145498349
# RUN  11 , total integrated cost =  1.2912594247292366
# RUN  12 , total integrated cost =  1.2886545137544532
# RUN  13 , total integrated cost =  1.2867374881299645
# RUN  14 , total integrated cost =  1.2851211199041064
# RUN  15 , total integrated cost =  1.284100539370406
# RUN  16 , total integrated cost =  1.2808480590742686
# RUN  17 , total integrated cost =  1.2798504340172367
# RUN  18 , total integrated cost =  1.2795063881736413
# RUN  19 , total integrated cost =  1.2792490613779082
# RUN  20 , total integrated cost =  1.279032692376591
# RUN  30 , total integrated cost =  1.2777083898525272
# RUN  30 , total integrated cost =  1.2777083898525272
# Improved over  30  iterations in  6.17572763498174  seconds by  17.78377988521271  percent.
# cost splitting :  1.0736270165094717 [ 0.27424505 12.0728566 ]
# set cost params:  0.006666666666666667 0.0 4.092764291537541
# interpolate adjoint :  True True True
# initial cost =  50.5409342818253
# RUN  0 , total integrated cost =  50.5409342818253
# Gradient descend method:  None
# RUN  1 , total integrated cost =  41.1989986464567
# RUN  2 , total integrated cost =  40.73370901410255
# RUN  3 , total integrated cost =  39.559584763273186
# RUN  4 , total integrated cost =  39.12347507217674
# RUN  5 , total integrated cost =  39.05237520901379
# RUN  6 , total integrated cost =  39.052209558035884
# RUN  7 , total integrated cost =  39.0521654295487
# RUN  8 , total integrated cost =  39.05210861739171
# RUN  9 , total integrated cost =  38.72915817950203
# RUN  10 , total integrated cost =  38.728686817591225
# RUN  11 , total integrated cost =  38.72868586509812
# RUN  12 , total integrated cost =  38.72868584931986
# RUN  13 , total integrated cost =  38.72868584931986
# Control only changes marginally.
# RUN  13 , total integrated cost =  38.72868584931986
# Improved over  13  iterations in  3.159546417009551  seconds by  23.371646370124907  percent.
# cost splitting :  8.871420715498745 [0.28638501 9.16188523]
# set cost params:  0.006666666666666667 0.0 21.995180692091942
# interpolate adjoint :  True True True
# initial cost =  207.8755539047543
# RUN  0 , total integrated cost =  207.8755539047543
# Gradient descend method:  None
# RUN  1 , total integrated cost =  207.87555339592654
# RUN  2 , total integrated cost =  207.87553986706982
# RUN  3 , total integrated cost =  207.8755230422411
# RUN  4 , total integrated cost =  207.8755221396628
# RUN  5 , total integrated cost =  207.8755198894101
# RUN  6 , total integrated cost =  207.87551815736612
# RUN  7 , total integrated cost =  207.8755174383946
# RUN  8 , total integrated cost =  207.8755168777211
# RUN  9 , total integrated cost =  207.87547848706228
# RUN  10 , total integrated cost =  207.87543341899715
# RUN  11 , total integrated cost =  207.8754327224797
# RUN  12 , total integrated cost =  207.8754319979655
# RUN  13 , total integrated cost =  207.87543133993952
# RUN  14 , total integrated cost =  207.87542960082317
# RUN  15 , total integrated cost =  207.87542792781488
# RUN  16 , total integrated cost =  207.87542722112295
# RUN  17 , total integrated cost =  207.87542665838413
# RUN  18 , total integrated cost =  207.87499730615335
# RUN  19 , total integrated cost =  207.87452114277588
# RUN  20 , total integrated cost =  207.87452036688305
# RUN  30 , total integrated cost =  207.87451353144726
# RUN  30 , total integrated cost =  207.87451353144726
# Improved over  30  iterations in  8.033337978995405  seconds by  0.0005004789103395524  percent.
# cost splitting :  8.854997892811797 [0.28638512 9.16184279]
# set cost params:  0.006666666666666667 0.0 18.401538126424114
# interpolate adjoint :  True True True
# initial cost =  173.9209595256995
# RUN  0 , total integrated cost =  173.9209595256995
# Gradient descend method:  None
# RUN  1 , total integrated cost =  173.92095903134083
# RUN  2 , total integrated cost =  173.92095852972813
# RUN  3 , total integrated cost =  173.92095805800747
# RUN  4 , total integrated cost =  173.92095756057174

# %%
c_var = [0,1]
max_it = int(30)
conv = False

tol = 1e-12
    
while not conv:

    weight_ = random.random() * ( cost_uncontrolled -
                                 costnode_[0][0][0] ) / sum( costnode_[2][0][:] )

    aln.params.duration = dur
    cost.setParams(wp, weight_ * factor_we, weight_ * factor_ws)
    weights_ = cost.getParams()

    setinit(initVars, aln)

    target_ = aln.getZeroTarget()
    target_[:,0,-int_t_pen:] = target[0]
    target_[:,1,-int_t_pen:] = target[1]

    control0 = aln.getZeroControl()
    control0 = bestControl_[:,:,n_pre-1:-n_post+1]

    bestControl_, bestState_, cost_, runtime_, grad_, phi_, phi1_, costnode_ = aln.A1(
        control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
        prec_variables_ = p_var, transition_time_ = t_pen)

    if cost_[2] == 0.:
        conv = True

    #print('uncontrolled cost : ', cost_uncontrolled[i])
    print('cost splitting : ', costnode_[0][0][0], costnode_[2][0][:2])

    if conv and True:
        time_ = np.arange(-dur_pre,round(dur+dur_post+aln.params.dt,1),aln.params.dt)
        target_ = aln.getZeroTarget()
        target_[:,0,-int_t_pen:] = target[0]
        target_[:,1,-int_t_pen:] = target[1]

        fig, ax = plt.subplots(2,1, constrained_layout=True, figsize = (4,4) )
        ax[1].plot(time_, bestControl_[0,0,:], color = 'red')
        ax[0].plot(time_, bestState_[0,0,:], color= 'red')
        ax[1].plot(time_, bestControl_[0,1,:], color = 'blue')
        ax[0].plot(time_, bestState_[0,1,:], color= 'blue')
        ax[0].plot(time_, target_[0,0,:], linestyle = '--', color='red')
        ax[0].plot(time_, target_[0,1,:], linestyle = '--', color='blue')
        ax[0].set_xlim(-dur_pre,dur+dur_post)
        ax[1].set_xlim(-dur_pre,dur+dur_post)
        ax[0].axvspan(dur*t_pen, dur, alpha=0.2, color='gray')
        plt.show()

    with open(file_,'wb') as f:
        pickle.dump([bestControl_, bestState_, cost_, costnode_, weights_], f)
# Out:
# set cost params:  0.05 0.0 60.31063265389809
# interpolate adjoint :  True True True
# initial cost =  20.10890223860148
# RUN  0 , total integrated cost =  20.10890223860148
# Gradient descend method:  None
# RUN  1 , total integrated cost =  18.440290874311913
# RUN  2 , total integrated cost =  13.556123816428824
# RUN  3 , total integrated cost =  13.465933231561031
# RUN  4 , total integrated cost =  13.464320749649941
# RUN  5 , total integrated cost =  13.46432037904216
# RUN  6 , total integrated cost =  13.464320365733347
# RUN  7 , total integrated cost =  13.464320365733347
# Control only changes marginally.
# RUN  7 , total integrated cost =  13.464320365733347
# Improved over  7  iterations in  2.6768725309812  seconds by  33.042986603779156  percent.
# cost splitting :  3.6014070574718697e-09 [1.80713516e-12 2.23249530e-01]
# set cost params:  0.05 0.0 977.7792327202665
# interpolate adjoint :  True True True
# initial cost =  218.2887536877876
# RUN  0 , total integrated cost =  218.2887536877876
# Gradient descend method:  None
# RUN  1 , total integrated cost =  218.288753670052
# RUN  2 , total integrated cost =  218.28874918010297
# RUN  3 , total integrated cost =  218.26203738943087
# RUN  4 , total integrated cost =  218.26125829553632
# RUN  5 , total integrated cost =  218.2612435136006
# RUN  6 , total integrated cost =  218.26124299759383
# RUN  7 , total integrated cost =  218.26124299185594
# RUN  8 , total integrated cost =  218.26124298802944
# RUN  9 , total integrated cost =  218.26124298011422
# RUN  10 , total integrated cost =  218.26124297613376
# RUN  11 , total integrated cost =  218.2612429671136
# RUN  12 , total integrated cost =  218.26124296416876
# RUN  13 , total integrated cost =  218.26124295937635
# RUN  14 , total integrated cost =  218.26124295623333
# RUN  15 , total integrated cost =  218.2612429505807
# RUN  16 , total integrated cost =  218.26124294687094
# RUN  17 , total integrated cost =  218.26124293945952
# RUN  18 , total integrated cost =  218.2612429362158
# RUN  19 , total integrated cost =  218.26124293009752
# RUN  20 , total integrated cost =  218.2612429254494
# RUN  30 , total integrated cost =  182.17085456304696
# RUN  30 , total integrated cost =  182.17085456304696
# Improved over  30  iterations in  10.53881071700016  seconds by  16.54592759112046  percent.
# cost splitting :  5.472042034010148e-11 [1.80713516e-12 1.86310824e-01]
# set cost params:  0.05 0.0 440.7054863027264
# interpolate adjoint :  True True True
# initial cost =  82.10820230558195
# RUN  0 , total integrated cost =  82.10820230558195
# Gradient descend method:  None
# RUN  1 , total integrated cost =  82.1081457797365
# RUN  2 , total integrated cost =  82.10814277679867
# RUN  3 , total integrated cost =  82.10814270602081
# RUN  4 , total integrated cost =  82.10814270602081
# Control only changes marginally.
# RUN  4 , total integrated cost =  82.10814270602081
# Improved over  4  iterations in  2.300738238991471  seconds by  7.258661068476613e-05  percent.
# cost splitting :  1.0932921419877885e-07 [1.80713516e-12 1.86310689e-01]
# set cost params:  0.05 0.0 680.7305370961164
# interpolate adjoint :  True True True
# initial cost =  126.82737524290326
# RUN  0 , total integrated cost =  126.82737524290326
# Gradient descend method:  None
# RUN  1 , total integrated cost =  126.69197549648736
# RUN  2 , total integrated cost =  126.5538733035688
# RUN  3 , total integrated cost =  126.54826290198126
# RUN  4 , total integrated cost =  126.54796619805201
# RUN  5 , total integrated cost =  126.5479660737679
# RUN  6 , total integrated cost =  126.5479660737679
# Control only changes marginally.
# RUN  6 , total integrated cost =  126.5479660737679
# Improved over  6  iterations in  2.783632945996942  seconds by  0.2203066716473785  percent.
# cost splitting :  1.4829870986822238e-07 [1.80713516e-12 1.85900234e-01]
# set cost params:  0.05 0.0 704.187549290634
# interpolate adjoint :  True True True
# initial cost =  130.90863012723122
# RUN  0 , total integrated cost =  130.90863012723122
# Gradient descend method:  None
# RUN  1 , total integrated cost =  130.90863012723122
# Control only changes marginally.
# RUN  1 , total integrated cost =  130.90863012723122
# Improved over  1  iterations in  0.5952080079878215  seconds by  0.0  percent.
# cost splitting :  1.4829870986822238e-07 [1.80713516e-12 1.85900234e-01]
