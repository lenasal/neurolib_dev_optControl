# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import sys
import pickle

path = os.getcwd().split(os.sep + 'GUI')[0]
if path not in sys.path:
    print("not here")
    sys.path.append(path)

from neurolib.models.aln import ALNModel
from neurolib.utils import plotFunctions as plotFunc
from neurolib.utils import costFunctions as cost
import neurolib.dashboard.functions as functions
import neurolib.dashboard.data as data
    
# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2 

#path = os.path.join(os.getcwd(), "plots")
# Out:
# not here

# %%
grid_data_file = os.path.join(os.getcwd().split('data')[0], 'bi.pickle')
with open(grid_data_file,'rb') as f:
    load_array= pickle.load(f)
exc = [load_array[0][20], load_array[0][50]]
inh = [load_array[1][20], load_array[1][50]]

folder = str(os.getcwd().split('data_2')[1])
print(folder)
case = str(folder[1])

file_ = 'down.pickle'

c_var = [0,1]
if len(folder) == 4:
    if folder[3] == 'e':
        p_var = [0]
    elif folder[3] == 'i':
        p_var = [1]
else:
    p_var = [0,1]
    
print(p_var)

step1 = 100
step2 = 10
step3 = 1
# Out:
# /1_e
# [0]

# %%
aln = ALNModel()
N = aln.params.N

data.set_parameters(aln)

state_vars = aln.state_vars
init_vars = aln.init_vars

##############################################################
def setinit(init_vars_, model):
    state_vars = model.state_vars
    init_vars = model.init_vars
    for iv in range(len(init_vars)):
        for sv in range(len(state_vars)):
            if state_vars[sv] in init_vars[iv]:
                #print("set init vars ", )
                if model.params[init_vars[iv]].ndim == 2:
                    model.params[init_vars[iv]][0,:] = init_vars_[sv]
                else:
                    model.params[init_vars[iv]][0] = init_vars_[sv]
                    
##############################################################               
def setmaxmincontrol(max_c_c, min_c_c, max_c_r, min_c_r):
    import numpy as np
    
    max_cntrl = np.zeros(( 6 ))
    min_cntrl = np.zeros(( 6 ))
    
    max_cntrl[0] = max_c_c
    min_cntrl[0] = min_c_c
    max_cntrl[1] = max_c_c
    min_cntrl[1] = min_c_c
    max_cntrl[2] = max_c_r
    min_cntrl[2] = min_c_r
    max_cntrl[3] = max_c_r
    min_cntrl[3] = min_c_r
    max_cntrl[4] = max_c_r
    min_cntrl[4] = min_c_r
    max_cntrl[5] = max_c_r
    min_cntrl[5] = min_c_r
            
    return max_cntrl, min_cntrl

# %%
d_array = np.arange(500., 20, -0.1)
t0_array = d_array - 20.
t_pen = np.zeros(( t0_array.shape ))
for i in range(len(t_pen)):
    t_pen[i] = t0_array[i] / d_array[i]

# %%
dur_pre = 10
dur_post = 10

n_pre = int(np.around(dur_pre/aln.params.dt + 1.,1))
n_post = int(np.around(dur_post/aln.params.dt + 1.,1))

tol = 1e-12
start_step = 10.
c_scheme = np.zeros(( 1,1 ))
c_scheme[0,0] = 1.
u_mat = np.identity(1)
u_scheme = np.array([[1.]])

if case in ['1', '2']:    # low to high
    max_I = [3., -3.]
else:
    max_I = [-3., 3.]
    
if case in ['1', '3']:    # sparsity
    factor_ws = 1.
    factor_we = 0.
else:
    factor_ws = 0.
    factor_we = 1.
    
maxC = [1000., -1000., 0.18, 0.]
max_cntrl, min_cntrl = setmaxmincontrol(maxC[0], maxC[1], maxC[2], maxC[3])

# %%
bestControl_ = np.array( [[None] * len(t_pen)] * len(exc) )
bestState_ = np.array( [[None] * len(t_pen)] * len(exc) )
cost_ = np.array( [[None] * len(t_pen)] * len(exc) )
costnode_ = np.array( [[None] * len(t_pen)] * len(exc) )
weights_ = np.array( [[None] * len(t_pen)] * len(exc) )
convergence_ = np.array( [[None] * len(t_pen)] * len(exc) )

initVars = [None] * len(exc)
target = [None] * len(exc)
cost_uncontrolled = [None] * len(exc)

print(bestControl_.shape)
# Out:
# (2, 4800)

# %%
if os.path.isfile(file_) :
    print("file found")
    
    with open(file_,'rb') as f:
        load_array = pickle.load(f)

    bestControl_ = load_array[0]
    bestState_ = load_array[1]
    cost_ = load_array[2]
    costnode_ = load_array[3]
    weights_ = load_array[4]
# Out:
# file found

# %%
# get initial parameters and target states

i_range = range(len(exc))
data.set_parameters(aln)
max_percent = []

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    aln.params.duration = 3000.
    
    control0 = aln.getZeroControl()
    control0 = functions.step_control(aln, maxI_ = max_I[0])

    aln.run(control=control0)
    
    target_rates = np.zeros((2))
    target_rates[0] = aln.rates_exc[0,-1] 
    target_rates[1] = aln.rates_inh[0,-1]

    control0 = functions.step_control(aln, maxI_ = max_I[1])
    aln.run(control=control0)

    init_state_vars = np.zeros(( len(state_vars) ))
    for j in range(len(state_vars)):
        if aln.state[state_vars[j]].size == 1:
            init_state_vars[j] = aln.state[state_vars[j]][0]
        else:
            init_state_vars[j] = aln.state[state_vars[j]][0,-1]

    initVars[i] = init_state_vars
    target[i] = [target_rates[0], target_rates[1]]
    
    max_percent.append( (np.argmax(np.abs(bestControl_[i][0]), axis=2)[0,1] -100) / 4800 )
# Out:
# -------  0 0.4500000000000001 0.4750000000000002
# -------  1 0.47500000000000014 0.6000000000000003

# %%
# get uncontrolled cost

data.set_parameters(aln)

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    dur = d_array[0]
    aln.params.duration = dur
    
    target_ = aln.getZeroTarget()
    target_[:,0,:] = target[i][0]
    target_[:,1,:] = target[i][1]
            
    cost.setParams(1.0, 0.0, 0.0)

    setinit(initVars[i], aln)
    control0 = aln.getZeroControl()

    # "HS", "FR", "PR", "HZ"
    cgv = None
    max_it = 0

    bestControl_init_, bestState_init_, cost_init_, runtime_init_, grad_init_, phi_init_, phi1_, costnode_init_ = aln.A1(
        control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
        prec_variables_ = p_var, transition_time_ = t_pen[0])
    
    cost_uncontrolled[i] = cost_init_[0]
# Out:
# -------  0 0.4500000000000001 0.4750000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  316931.9421284
# RUN  0 , total integrated cost =  316931.9421284
# Gradient descend method:  None
# RUN  0 , total integrated cost =  316931.9421284
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  1 0.47500000000000014 0.6000000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  396670.24943190784
# RUN  0 , total integrated cost =  396670.24943190784
# Gradient descend method:  None
# RUN  0 , total integrated cost =  396670.24943190784
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.

# %%
for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    j = 0
    step = step1

    while j < 4799:

        if j == 0:
            j += step
            continue
            
        if not convergence_[i][j-step]:
            if j - step > 0:
                j -= step
                print('go back to -----', j)

        print('-----', j)

        if convergence_[i][j]:
            j += step
            continue

        dur = d_array[j]
        T = 5001 - j
        aln.params.duration = dur

        cost.setParams(1., 0., 1.)
        weights_[i][j] = cost.getParams()

        setinit(initVars[i], aln)

        max_it = 10000

        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        if type(bestControl_[i][j]) == type(None):
            max_percent_prev = (np.argmax(np.abs(bestControl_[i][j-step]), axis=2)[0,1] - 100) / (T-200)
            shift_ind = 0
            if j < 3000:
                while max_percent_prev > max_percent[i]:
                    shift_ind += 1
                    max_percent_prev = (np.argmax(np.abs(bestControl_[i][j-step]), axis=2)[0,1] - 100 - shift_ind) / (T-200)

            control0 = np.zeros(( bestControl_[i][j-step][:,:,100:-(100+step)].shape ))
            print('shift ind = ', shift_ind)
            if shift_ind != 0:
                control0[:,:,:-shift_ind] = 1. * bestControl_[i][j-step][:,:,100+shift_ind:-(100+step)]
            else:
                control0[:,:,:] = 1. * bestControl_[i][j-step][:,:,100:-(100+step)]
                #control0[0,0,:] = 0.
        else:
            if bestControl_[i][j].shape[2] == T+200:
                control0 = bestControl_[i][j][:,:,100:-100]
                #control0[0,1,:] = 0.
            else:
                control0 = bestControl_[i][j][:,:,100:-(100+j)]

        bestControl_[i][j], bestState_[i][j], cost_[i][j], runtime_, grad_, phi_, phi1_, costnode_[i][j] = aln.A1(
            control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
            prec_variables_ = p_var, transition_time_ = t_pen[j])
        
        time_ = np.arange(-dur_pre,round(dur+dur_post+aln.params.dt,1),aln.params.dt)
        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        print(costnode_[i][j][0][0][0], costnode_[i][j][2][0][:2])

        if cost_[i][j][-1] == 0.:
            convergence_[i][j] = True
            if j >= 4400:
                step = step2
            if j >=4790:
                step = step3

        with open(file_,'wb') as f:
            pickle.dump([bestControl_, bestState_, cost_, costnode_, weights_], f)

        j += step
# Out:
# -------  0 0.4500000000000001 0.4750000000000002
# ----- 100
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.3311692710671506
# RUN  0 , total integrated cost =  3.3311692710671506
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.3311692710671506
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.3311692710671506
# Improved over  1  iterations in  19.615538701415062  seconds by  0.0  percent.
# 5.92898019966308e-10 [2.21282060e-16 3.33116926e+00]
# ----- 200
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.331169171684079
# RUN  0 , total integrated cost =  3.331169171684079
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.331169171684079
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.331169171684079
# Improved over  1  iterations in  1.9196668341755867  seconds by  0.0  percent.
# 1.394730645088842e-09 [1.30984179e-16 3.33116914e+00]
# ----- 300
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.331169090994605
# RUN  0 , total integrated cost =  3.331169090994605
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.331169090994605
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.331169090994605
# Improved over  1  iterations in  1.2285032868385315  seconds by  0.0  percent.
# 1.7852406253929399e-09 [1.18650842e-16 3.33116905e+00]
# ----- 400
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.3311688029644237
# RUN  0 , total integrated cost =  3.3311688029644237
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.3311688029644237
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.3311688029644237
# Improved over  1  iterations in  0.7626339197158813  seconds by  0.0  percent.
# 1.935602677606225e-09 [5.65090790e-17 3.33116876e+00]
# ----- 500
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.3311676686383205
# RUN  0 , total integrated cost =  3.3311676686383205
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.3311676686383205
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.3311676686383205
# Improved over  1  iterations in  1.9368497505784035  seconds by  0.0  percent.
# 2.5044267514112276e-09 [1.48613034e-16 3.33116761e+00]
# ----- 600
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.3311665508482693
# RUN  0 , total integrated cost =  3.3311665508482693
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.3311665508482693
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.3311665508482693
# Improved over  1  iterations in  1.7431037053465843  seconds by  0.0  percent.
# 1.2759030445289266e-09 [2.16625006e-16 3.33116652e+00]
# ----- 700
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.3311655224069456
# RUN  0 , total integrated cost =  3.3311655224069456
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.3311655224069456
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.3311655224069456
# Improved over  1  iterations in  1.5359304174780846  seconds by  0.0  percent.
# 2.649573706581059e-09 [1.53582162e-16 3.33116547e+00]
# ----- 800
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.3311649159194334
# RUN  0 , total integrated cost =  3.3311649159194334
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.3311649159194334
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.3311649159194334
# Improved over  1  iterations in  2.3087650313973427  seconds by  0.0  percent.
# 9.638315530146258e-09 [1.49484956e-16 3.33116471e+00]
# ----- 900
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.3311638766833127
# RUN  0 , total integrated cost =  3.3311638766833127
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.3311638766833127
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.3311638766833127
# Improved over  1  iterations in  2.0746131613850594  seconds by  0.0  percent.
# 9.072831513051743e-09 [5.57450184e-17 3.33116369e+00]
# ----- 1000
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.3311637208839935
# RUN  0 , total integrated cost =  3.3311637208839935
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.3311637208839935
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.3311637208839935
# Improved over  1  iterations in  7.498582057654858  seconds by  0.0  percent.
# 1.5744420338292902e-08 [1.01738332e-16 3.33116341e+00]
# ----- 1100
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.3311622930698435
# RUN  0 , total integrated cost =  3.3311622930698435
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.3311622930698435
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.3311622930698435
# Improved over  1  iterations in  1.7327155843377113  seconds by  0.0  percent.
# 6.648065409658648e-09 [3.14633256e-17 3.33116216e+00]
# ----- 1200
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.3311614877379454
# RUN  0 , total integrated cost =  3.3311614877379454
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.3311614877379454
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.3311614877379454
# Improved over  1  iterations in  1.377528965473175  seconds by  0.0  percent.
# 7.761689078233237e-09 [1.56318909e-16 3.33116134e+00]
# ----- 1300
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.331161467618942
# RUN  0 , total integrated cost =  3.331161467618942
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.331161467618942
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.331161467618942
# Improved over  1  iterations in  0.833663210272789  seconds by  0.0  percent.
# 2.4662787545703022e-09 [1.56318896e-16 3.33116142e+00]
# ----- 1400
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.3311621293522524
# RUN  0 , total integrated cost =  3.3311621293522524
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.3311621293522524
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.3311621293522524
# Improved over  1  iterations in  1.099748618900776  seconds by  0.0  percent.
# 1.6668293906902773e-08 [1.56263012e-16 3.33116183e+00]
# ----- 1500
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.3311625989994305
# RUN  0 , total integrated cost =  3.3311625989994305
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.3311625989994305
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.3311625989994305
# Improved over  1  iterations in  1.6936180219054222  seconds by  0.0  percent.
# 1.747594150286802e-08 [1.53235929e-16 3.33116229e+00]
# ----- 1600
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.3311632649645055
# RUN  0 , total integrated cost =  3.3311632649645055
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.3311632649645055
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.3311632649645055
# Improved over  1  iterations in  0.9742441773414612  seconds by  0.0  percent.
# 5.676116750130074e-09 [1.15698638e-16 3.33116317e+00]
# ----- 1700
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.331165248907694
# RUN  0 , total integrated cost =  3.331165248907694
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.331165248907694
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.331165248907694
# Improved over  1  iterations in  1.3696414455771446  seconds by  0.0  percent.
# 2.8944749472542964e-08 [1.85101320e-16 3.33116477e+00]
# ----- 1800
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.3311680929457594
# RUN  0 , total integrated cost =  3.3311680929457594
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.3311680929457594
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.3311680929457594
# Improved over  1  iterations in  1.1414667442440987  seconds by  0.0  percent.
# 4.454469805107902e-08 [5.78509591e-17 3.33116738e+00]
# ----- 1900
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.331172414936819
# RUN  0 , total integrated cost =  3.331172414936819
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.331172414936819
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.331172414936819
# Improved over  1  iterations in  1.4034588113427162  seconds by  0.0  percent.
# 4.5821586079235835e-08 [1.67146928e-16 3.33117171e+00]
# ----- 2000
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.3311799857041766
# RUN  0 , total integrated cost =  3.3311799857041766
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.3311799857041766
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.3311799857041766
# Improved over  1  iterations in  0.7331044003367424  seconds by  0.0  percent.
# 7.354928005694767e-08 [1.22936354e-16 3.33117889e+00]
# ----- 2100
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.331190957406648
# RUN  0 , total integrated cost =  3.331190957406648
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.331190957406648
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.331190957406648
# Improved over  1  iterations in  0.7334132045507431  seconds by  0.0  percent.
# 4.7312223083840296e-08 [5.19535884e-17 3.33119027e+00]
# ----- 2200
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.3312100587232045
# RUN  0 , total integrated cost =  3.3312100587232045
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.3312100587232045
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.3312100587232045
# Improved over  1  iterations in  1.014821045100689  seconds by  0.0  percent.
# 1.4396101905887987e-07 [2.01626479e-16 3.33120805e+00]
# ----- 2300
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.331237709286417
# RUN  0 , total integrated cost =  3.331237709286417
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.331237709286417
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.331237709286417
# Improved over  1  iterations in  1.1928429380059242  seconds by  0.0  percent.
# 7.118725693532984e-08 [4.16035127e-18 3.33123675e+00]
# ----- 2400
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.3312839011051505
# RUN  0 , total integrated cost =  3.3312839011051505
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.3312839011051505
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.3312839011051505
# Improved over  1  iterations in  1.0835596024990082  seconds by  0.0  percent.
# 1.4087398806306444e-07 [4.14005458e-18 3.33128208e+00]
# ----- 2500
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.331350347782861
# RUN  0 , total integrated cost =  3.331350347782861
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.331350347782861
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.331350347782861
# Improved over  1  iterations in  0.8715159893035889  seconds by  0.0  percent.
# 1.9190037955314781e-07 [4.05609183e-18 3.33134796e+00]
# ----- 2600
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.331454986993271
# RUN  0 , total integrated cost =  3.331454986993271
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.331454986993271
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.331454986993271
# Improved over  1  iterations in  0.961079016327858  seconds by  0.0  percent.
# 3.036680528757721e-07 [4.01572035e-18 3.33145136e+00]
# ----- 2700
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.3316128328224512
# RUN  0 , total integrated cost =  3.3316128328224512
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.3316128328224512
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.3316128328224512
# Improved over  1  iterations in  0.9702757745981216  seconds by  0.0  percent.
# 6.311489755165987e-07 [4.01207950e-18 3.33160561e+00]
# ----- 2800
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.331817908119564
# RUN  0 , total integrated cost =  3.331817908119564
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.331817908119564
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.331817908119564
# Improved over  1  iterations in  0.9067220911383629  seconds by  0.0  percent.
# 1.0880349575081168e-07 [4.01132330e-18 3.33181672e+00]
# ----- 2900
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.332351226269193
# RUN  0 , total integrated cost =  3.332351226269193
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.332351226269193
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.332351226269193
# Improved over  1  iterations in  0.9171384125947952  seconds by  0.0  percent.
# 1.9687213856895345e-07 [4.01007547e-18 3.33234917e+00]
# ----- 3000
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.332874245406478
# RUN  0 , total integrated cost =  3.332874245406478
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.332874245406478
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.332874245406478
# Improved over  1  iterations in  0.905010536313057  seconds by  0.0  percent.
# 5.634219375029044e-07 [4.00934550e-18 3.33286864e+00]
# ----- 3100
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.333670328535447
# RUN  0 , total integrated cost =  3.333670328535447
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.333670328535447
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.333670328535447
# Improved over  1  iterations in  1.0102722495794296  seconds by  0.0  percent.
# 1.3941021255863148e-06 [4.00834306e-18 3.33365714e+00]
# ----- 3200
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.3348549454850556
# RUN  0 , total integrated cost =  3.3348549454850556
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.3348549454850556
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.3348549454850556
# Improved over  1  iterations in  0.6880061775445938  seconds by  0.0  percent.
# 1.7216975523145372e-06 [4.00705255e-18 3.33483952e+00]
# ----- 3300
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.336686258579255
# RUN  0 , total integrated cost =  3.336686258579255
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.336686258579255
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.336686258579255
# Improved over  1  iterations in  0.9316535592079163  seconds by  0.0  percent.
# 3.5592238598840114e-06 [4.00525733e-18 3.33665614e+00]
# ----- 3400
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.3395057741722614
# RUN  0 , total integrated cost =  3.3395057741722614
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.3395057741722614
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.3395057741722614
# Improved over  1  iterations in  0.610531821846962  seconds by  0.0  percent.
# 6.196603753566153e-06 [4.00282519e-18 3.33945642e+00]
# ----- 3500
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.3438890529274916
# RUN  0 , total integrated cost =  3.3438890529274916
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.3438890529274916
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.3438890529274916
# Improved over  1  iterations in  0.7289155125617981  seconds by  0.0  percent.
# 8.706986821745034e-06 [3.99964771e-18 3.34382403e+00]
# ----- 3600
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.3508078809773703
# RUN  0 , total integrated cost =  3.3508078809773703
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.3508078809773703
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.3508078809773703
# Improved over  1  iterations in  0.36915553361177444  seconds by  0.0  percent.
# 1.826993316681276e-05 [3.99522006e-18 3.35068054e+00]
# ----- 3700
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.3615109481587053
# RUN  0 , total integrated cost =  3.3615109481587053
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.3615109481587053
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.3615109481587053
# Improved over  1  iterations in  0.955662339925766  seconds by  0.0  percent.
# 2.6489661349466812e-05 [3.98134763e-18 3.36133949e+00]
# ----- 3800
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.3779706375703986
# RUN  0 , total integrated cost =  3.3779706375703986
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.3779706375703986
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.3779706375703986
# Improved over  1  iterations in  0.6637916639447212  seconds by  0.0  percent.
# 4.916923682190932e-05 [3.97153949e-18 3.37767685e+00]
# ----- 3900
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.4043468384577382
# RUN  0 , total integrated cost =  3.4043468384577382
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.4043468384577382
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.4043468384577382
# Improved over  1  iterations in  0.7513148933649063  seconds by  0.0  percent.
# 8.944501674327987e-05 [3.95856396e-18 3.40385689e+00]
# ----- 4000
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.4405876057644154
# RUN  0 , total integrated cost =  3.4405876057644154
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.4405876057644154
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.4405876057644154
# Improved over  1  iterations in  0.5078853741288185  seconds by  0.0  percent.
# 5.14049236031653e-05 [0.02841607 3.41191554]
# ----- 4100
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.4991032885775972
# RUN  0 , total integrated cost =  3.4991032885775972
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.4991032885775972
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.4991032885775972
# Improved over  1  iterations in  0.5219050347805023  seconds by  0.0  percent.
# 6.618423614704474e-05 [0.05365342 3.44515319]
# ----- 4200
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.590521619122479
# RUN  0 , total integrated cost =  3.590521619122479
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.590521619122479
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.590521619122479
# Improved over  1  iterations in  0.6465465798974037  seconds by  0.0  percent.
# 8.641341626735506e-05 [0.09850825 3.49166901]
# ----- 4300
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.733934706668014
# RUN  0 , total integrated cost =  3.733934706668014
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.733934706668014
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.733934706668014
# Improved over  1  iterations in  0.6028153225779533  seconds by  0.0  percent.
# 0.00011404668364560825 [0.17553379 3.55800317]
# ----- 4400
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.955399544505863
# RUN  0 , total integrated cost =  3.955399544505863
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.955399544505863
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.955399544505863
# Improved over  1  iterations in  0.3641381859779358  seconds by  0.0  percent.
# 0.00015428229744577702 [0.29407236 3.66086588]
# ----- 4410
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.9827161674608513
# RUN  0 , total integrated cost =  3.9827161674608513
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.9827161674608513
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.9827161674608513
# Improved over  1  iterations in  0.5231286287307739  seconds by  0.0  percent.
# 0.0001582304379286098 [0.30949416 3.67275677]
# ----- 4420
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  4.011180939047528
# RUN  0 , total integrated cost =  4.011180939047528
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.011180939047528
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.011180939047528
# Improved over  1  iterations in  0.4223014712333679  seconds by  0.0  percent.
# 0.00016647951539638798 [0.31830424 3.69239549]
# ----- 4430
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  4.040966938421719
# RUN  0 , total integrated cost =  4.040966938421719
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.040966938421719
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.040966938421719
# Improved over  1  iterations in  0.4817051514983177  seconds by  0.0  percent.
# 0.00017509048660728648 [0.32944951 3.71102003]
# ----- 4440
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  4.07185363119981
# RUN  0 , total integrated cost =  4.07185363119981
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.07185363119981
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.07185363119981
# Improved over  1  iterations in  0.2547430247068405  seconds by  0.0  percent.
# 0.00018308094557284847 [0.33628779 3.73505485]
# ----- 4450
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  4.1030810931222845
# RUN  0 , total integrated cost =  4.1030810931222845
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.1030810931222845
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.1030810931222845
# Improved over  1  iterations in  0.42000918835401535  seconds by  0.0  percent.
# 0.00018767687218713714 [0.33770397 3.76486264]
# ----- 4460
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  4.1326568114807465
# RUN  0 , total integrated cost =  4.1326568114807465
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.1326568114807465
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.1326568114807465
# Improved over  1  iterations in  0.2620721906423569  seconds by  0.0  percent.
# 0.00019016061920023873 [0.31363709 3.8185079 ]
# ----- 4470
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  4.15971158648232
# RUN  0 , total integrated cost =  4.15971158648232
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.15971158648232
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.15971158648232
# Improved over  1  iterations in  0.3901914581656456  seconds by  0.0  percent.
# 0.0002111796505134952 [0.26000475 3.89914895]
# ----- 4480
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  4.187602083885821
# RUN  0 , total integrated cost =  4.187602083885821
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.187602083885821
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.187602083885821
# Improved over  1  iterations in  0.3939395323395729  seconds by  0.0  percent.
# 0.0002551689483893904 [0.21989526 3.96704542]
# ----- 4490
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  4.179571489449609
# RUN  0 , total integrated cost =  4.179571489449609
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.179571489449609
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.179571489449609
# Improved over  1  iterations in  0.41013894230127335  seconds by  0.0  percent.
# 0.0004011229544292889 [0.01938969 4.15916203]
# ----- 4500
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  4.194863297421144
# RUN  0 , total integrated cost =  4.194863297421144
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.194863297421144
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.194863297421144
# Improved over  1  iterations in  0.360754132270813  seconds by  0.0  percent.
# 0.0004862500601587363 [0.02324562 4.17040568]
# ----- 4510
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  4.21400143763394
# RUN  0 , total integrated cost =  4.21400143763394
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.21400143763394
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.21400143763394
# Improved over  1  iterations in  0.4496149569749832  seconds by  0.0  percent.
# 0.0005951214157408628 [0.02870487 4.18384281]
# ----- 4520
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  4.2380448070100245
# RUN  0 , total integrated cost =  4.2380448070100245
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.2380448070100245
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.2380448070100245
# Improved over  1  iterations in  0.4634077697992325  seconds by  0.0  percent.
# 0.0007098966490448323 [0.03414659 4.20219941]
# ----- 4530
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  4.268606195736969
# RUN  0 , total integrated cost =  4.268606195736969
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.268606195736969
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.268606195736969
# Improved over  1  iterations in  0.36939282715320587  seconds by  0.0  percent.
# 0.0008304720488459521 [0.0419668  4.22469336]
# ----- 4540
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  4.307625145057846
# RUN  0 , total integrated cost =  4.307625145057846
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.307625145057846
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.307625145057846
# Improved over  1  iterations in  0.3000102639198303  seconds by  0.0  percent.
# 0.000980067203650305 [0.05327543 4.2521019 ]
# ----- 4550
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  4.358146685579033
# RUN  0 , total integrated cost =  4.358146685579033
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.358146685579033
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.358146685579033
# Improved over  1  iterations in  0.4685142934322357  seconds by  0.0  percent.
# 0.0011488139539099047 [0.07184345 4.28372555]
# ----- 4560
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  4.423734121593376
# RUN  0 , total integrated cost =  4.423734121593376
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.423734121593376
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.423734121593376
# Improved over  1  iterations in  0.37348581850528717  seconds by  0.0  percent.
# 0.0012873421389149049 [0.09802206 4.32288759]
# ----- 4570
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  4.508447735765488
# RUN  0 , total integrated cost =  4.508447735765488
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.508447735765488
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.508447735765488
# Improved over  1  iterations in  0.36147111654281616  seconds by  0.0  percent.
# 0.001393853537220673 [0.14472273 4.36073619]
# ----- 4580
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  4.6167777487462445
# RUN  0 , total integrated cost =  4.6167777487462445
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.6167777487462445
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.6167777487462445
# Improved over  1  iterations in  0.3648228272795677  seconds by  0.0  percent.
# 0.0013739391225718342 [0.22750248 4.38639751]
# ----- 4590
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  4.750122503588894
# RUN  0 , total integrated cost =  4.750122503588894
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.750122503588894
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.750122503588894
# Improved over  1  iterations in  0.4972958341240883  seconds by  0.0  percent.
# 0.0012372758387852773 [0.37482451 4.37276805]
# ----- 4600
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  4.906324073012787
# RUN  0 , total integrated cost =  4.906324073012787
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.906324073012787
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.906324073012787
# Improved over  1  iterations in  0.47078076004981995  seconds by  0.0  percent.
# 0.0010763261735815756 [0.59775569 4.30642109]
# ----- 4610
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  5.080654062254101
# RUN  0 , total integrated cost =  5.080654062254101
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.080654062254101
# Control only changes marginally.
# RUN  1 , total integrated cost =  5.080654062254101
# Improved over  1  iterations in  0.1736471951007843  seconds by  0.0  percent.
# 0.0009233802946134189 [0.88587974 4.1929781 ]
# ----- 4620
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  5.269343912900085
# RUN  0 , total integrated cost =  5.269343912900085
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.269343912900085
# Control only changes marginally.
# RUN  1 , total integrated cost =  5.269343912900085
# Improved over  1  iterations in  0.23705728352069855  seconds by  0.0  percent.
# 0.0008001351478730374 [1.20875471 4.05907253]
# ----- 4630
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  5.470777912386597
# RUN  0 , total integrated cost =  5.470777912386597
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.470777912386597
# Control only changes marginally.
# RUN  1 , total integrated cost =  5.470777912386597
# Improved over  1  iterations in  0.3948766440153122  seconds by  0.0  percent.
# 0.0007287620582067324 [1.57712361 3.89230918]
# ----- 4640
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  5.685289016907955
# RUN  0 , total integrated cost =  5.685289016907955
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.685289016907955
# Control only changes marginally.
# RUN  1 , total integrated cost =  5.685289016907955
# Improved over  1  iterations in  0.6445358842611313  seconds by  0.0  percent.
# 0.0007229521828119521 [1.9652576  3.71873298]
# ----- 4650
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  5.915095667620385
# RUN  0 , total integrated cost =  5.915095667620385
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.915095667620385
# Control only changes marginally.
# RUN  1 , total integrated cost =  5.915095667620385
# Improved over  1  iterations in  0.31941863149404526  seconds by  0.0  percent.
# 0.0007000262567876955 [2.381395   3.53247823]
# ----- 4660
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  6.162353296952546
# RUN  0 , total integrated cost =  6.162353296952546
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.162353296952546
# Control only changes marginally.
# RUN  1 , total integrated cost =  6.162353296952546
# Improved over  1  iterations in  0.46325376629829407  seconds by  0.0  percent.
# 0.0006466414385675269 [2.91025311 3.25100315]
# ----- 4670
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  6.431306001128606
# RUN  0 , total integrated cost =  6.431306001128606
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.431306001128606
# Control only changes marginally.
# RUN  1 , total integrated cost =  6.431306001128606
# Improved over  1  iterations in  0.21781177073717117  seconds by  0.0  percent.
# 0.0006712053054712979 [3.44724593 2.98295475]
# ----- 4680
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  6.611290059525897
# RUN  0 , total integrated cost =  6.611290059525897
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.611290059525897
# Control only changes marginally.
# RUN  1 , total integrated cost =  6.611290059525897
# Improved over  1  iterations in  0.4675608277320862  seconds by  0.0  percent.
# 0.00031721467662973734 [6.61078346e+00 5.16956303e-13]
# ----- 4690
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  6.8444607613142985
# RUN  0 , total integrated cost =  6.8444607613142985
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.8444607613142985
# Control only changes marginally.
# RUN  1 , total integrated cost =  6.8444607613142985
# Improved over  1  iterations in  0.3597942367196083  seconds by  0.0  percent.
# 0.00036801942825473536 [6.84389134e+00 4.02320819e-12]
# ----- 4700
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  7.093356922838442
# RUN  0 , total integrated cost =  7.093356922838442
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.093356922838442
# Control only changes marginally.
# RUN  1 , total integrated cost =  7.093356922838442
# Improved over  1  iterations in  0.3891473487019539  seconds by  0.0  percent.
# 0.0004189463525307951 [7.09272955e+00 3.79208714e-12]
# ----- 4710
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  7.365593835661671
# RUN  0 , total integrated cost =  7.365593835661671
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.365593835661671
# Control only changes marginally.
# RUN  1 , total integrated cost =  7.365593835661671
# Improved over  1  iterations in  0.45409614592790604  seconds by  0.0  percent.
# 0.0004929971712658405 [7.36488009e+00 4.27449840e-12]
# ----- 4720
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  7.67462800761407
# RUN  0 , total integrated cost =  7.67462800761407
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.67462800761407
# Control only changes marginally.
# RUN  1 , total integrated cost =  7.67462800761407
# Improved over  1  iterations in  0.36158496141433716  seconds by  0.0  percent.
# 0.0006083172539904554 [7.67377757e+00 3.09455330e-12]
# ----- 4730
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  8.039696533803316
# RUN  0 , total integrated cost =  8.039696533803316
# Gradient descend method:  None
# RUN  1 , total integrated cost =  8.039696533803316
# Control only changes marginally.
# RUN  1 , total integrated cost =  8.039696533803316
# Improved over  1  iterations in  0.4671925902366638  seconds by  0.0  percent.
# 0.0007444378575486891 [8.03869284e+00 1.14833737e-13]
# ----- 4740
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  8.490343979576641
# RUN  0 , total integrated cost =  8.490343979576641
# Gradient descend method:  None
# RUN  1 , total integrated cost =  8.490343979576641
# Control only changes marginally.
# RUN  1 , total integrated cost =  8.490343979576641
# Improved over  1  iterations in  0.297010637819767  seconds by  0.0  percent.
# 0.0009792141308025025 [8.48907246e+00 1.14833737e-13]
# ----- 4750
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  9.075632684002885
# RUN  0 , total integrated cost =  9.075632684002885
# Gradient descend method:  None
# RUN  1 , total integrated cost =  9.075632684002885
# Control only changes marginally.
# RUN  1 , total integrated cost =  9.075632684002885
# Improved over  1  iterations in  0.5213891789317131  seconds by  0.0  percent.
# 0.001275692275766677 [9.07403966e+00 1.49084516e-12]
# ----- 4760
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  9.887983382666116
# RUN  0 , total integrated cost =  9.887983382666116
# Gradient descend method:  None
# RUN  1 , total integrated cost =  9.887983382666116
# Control only changes marginally.
# RUN  1 , total integrated cost =  9.887983382666116
# Improved over  1  iterations in  0.21824270486831665  seconds by  0.0  percent.
# 0.002010110824237288 [9.88557325e+00 3.00612573e-12]
# ----- 4770
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  11.127656272145705
# RUN  0 , total integrated cost =  11.127656272145705
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.127656272145705
# Control only changes marginally.
# RUN  1 , total integrated cost =  11.127656272145705
# Improved over  1  iterations in  0.4910329729318619  seconds by  0.0  percent.
# 0.003386580330591005 [1.11237642e+01 2.58032069e-12]
# ----- 4780
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  13.346995113183798
# RUN  0 , total integrated cost =  13.346995113183798
# Gradient descend method:  None
# RUN  1 , total integrated cost =  13.346995113183798
# Control only changes marginally.
# RUN  1 , total integrated cost =  13.346995113183798
# Improved over  1  iterations in  0.3775148093700409  seconds by  0.0  percent.
# 0.006785699113842684 [1.33395342e+01 2.72871382e-12]
# ----- 4790
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  19.0270290170802
# RUN  0 , total integrated cost =  19.0270290170802
# Gradient descend method:  None
# RUN  1 , total integrated cost =  19.027028948858124
# RUN  2 , total integrated cost =  19.027028879960223
# RUN  3 , total integrated cost =  19.02702881038413
# RUN  4 , total integrated cost =  19.027028742771602
# RUN  5 , total integrated cost =  19.027028674022798
# RUN  6 , total integrated cost =  19.0270286060008
# RUN  7 , total integrated cost =  19.027028537843716
# RUN  8 , total integrated cost =  19.02702846959759
# RUN  9 , total integrated cost =  19.027028401063312
# RUN  10 , total integrated cost =  19.027028333518277
# RUN  11 , total integrated cost =  19.02702826404881
# RUN  12 , total integrated cost =  19.027028195230386
# RUN  13 , total integrated cost =  19.02702812703
# RUN  14 , total integrated cost =  19.02702805899217
# RUN  15 , total integrated cost =  19.027027990427083
# RUN  16 , total integrated cost =  19.027027923015677
# RUN  17 , total integrated cost =  19.02702785418993
# RUN  18 , total integrated cost =  19.027027786356335
# RUN  19 , total integrated cost =  19.02702771827499
# RUN  20 , total integrated cost =  19.02702764953306
# RUN  30 , total integrated cost =  19.027026965948963
# RUN  40 , total integrated cost =  19.027026277690023
# RUN  50 , total integrated cost =  19.02702559892026
# RUN  60 , total integrated cost =  19.027024912068672
# RUN  70 , total integrated cost =  19.027024232015723
# RUN  80 , total integrated cost =  19.027023552869174
# RUN  90 , total integrated cost =  19.027022875730193
# RUN  100 , total integrated cost =  19.02702219895677
# RUN  110 , total integrated cost =  19.027021523026473
# RUN  120 , total integrated cost =  19.027020848390215
# RUN  130 , total integrated cost =  19.02702017384616
# RUN  140 , total integrated cost =  19.027019500400954
# RUN  150 , total integrated cost =  19.02701882813748
# RUN  160 , total integrated cost =  19.02701815534265
# RUN  170 , total integrated cost =  19.02701748336931
# RUN  180 , total integrated cost =  19.02701681342563
# RUN  190 , total integrated cost =  19.027016143802776
# RUN  200 , total integrated cost =  19.0270154750524
# RUN  300 , total integrated cost =  19.027008830809883
# RUN  400 , total integrated cost =  19.027002250291307
# RUN  500 , total integrated cost =  19.02699576147781
# RUN  600 , total integrated cost =  19.026989336505427
# RUN  700 , total integrated cost =  19.02698299943682
# RUN  800 , total integrated cost =  19.026976723119837
# RUN  900 , total integrated cost =  19.026970534149743
# RUN  1000 , total integrated cost =  19.026964404315592
# RUN  1100 , total integrated cost =  19.02695835312917
# RUN  1200 , total integrated cost =  19.02695237428385
# RUN  1300 , total integrated cost =  19.026946458081614
# RUN  1400 , total integrated cost =  19.02694062320496
# RUN  1500 , total integrated cost =  19.026934845518863
# RUN  1600 , total integrated cost =  19.026929135493386
# RUN  1700 , total integrated cost =  19.026923491194427
# RUN  1800 , total integrated cost =  19.02691791904952
# RUN  1900 , total integrated cost =  19.026912413278584
# RUN  2000 , total integrated cost =  19.026906964939574
# RUN  3000 , total integrated cost =  19.026855862585798
# RUN  4000 , total integrated cost =  19.026810163690882
# RUN  5000 , total integrated cost =  19.026747371238596
# RUN  6000 , total integrated cost =  19.026693558575623
# RUN  7000 , total integrated cost =  19.02664755735952
# RUN  8000 , total integrated cost =  19.026612505894256
# RUN  9000 , total integrated cost =  19.026581821433325
# RUN  10000 , total integrated cost =  19.026556038798912
# RUN  10000 , total integrated cost =  19.026556038798912
# Improved over  10000  iterations in  1727.5127407312393  seconds by  0.0024858230933659797  percent.
# 0.027128147806644517 [1.89980782e+01 5.62806241e-13]
# -------  1 0.47500000000000014 0.6000000000000003
# ----- 100
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  5.007376898479997
# RUN  0 , total integrated cost =  5.007376898479997
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.007376898479997
# Control only changes marginally.
# RUN  1 , total integrated cost =  5.007376898479997
# Improved over  1  iterations in  2.29295152425766  seconds by  0.0  percent.
# 1.1933314003403408e-07 [5.00737399 0.        ]
# ----- 200
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  5.007346262513779
# RUN  0 , total integrated cost =  5.007346262513779
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.007346262512205
# RUN  2 , total integrated cost =  5.007346262511834
# RUN  3 , total integrated cost =  5.007346262511317
# RUN  4 , total integrated cost =  5.0073462625112155
# RUN  5 , total integrated cost =  5.007346262510987
# RUN  6 , total integrated cost =  5.007346262510889
# RUN  7 , total integrated cost =  5.007346262510267
# RUN  8 , total integrated cost =  5.007346262509809
# RUN  9 , total integrated cost =  5.0073462625085625
# RUN  10 , total integrated cost =  5.007346262507151
# RUN  11 , total integrated cost =  5.007346262507013
# RUN  12 , total integrated cost =  5.007346262506771
# RUN  13 , total integrated cost =  5.007346262506674
# RUN  14 , total integrated cost =  5.007346262506414
# RUN  15 , total integrated cost =  5.007346262506265
# RUN  16 , total integrated cost =  5.007346262505765
# RUN  17 , total integrated cost =  5.00734626250538
# RUN  18 , total integrated cost =  5.007346262503849
# RUN  19 , total integrated cost =  5.007346262502129
# RUN  20 , total integrated cost =  5.007346262502015
# RUN  30 , total integrated cost =  5.007346262484396
# RUN  40 , total integrated cost =  5.0073462624796115
# RUN  50 , total integrated cost =  5.0073462624053295
# RUN  60 , total integrated cost =  5.00734626240011
# RUN  70 , total integrated cost =  5.007346262357776
# RUN  80 , total integrated cost =  5.007346262024325
# RUN  90 , total integrated cost =  5.0073462619964255
# RUN  100 , total integrated cost =  5.0073462619903575
# RUN  110 , total integrated cost =  5.0073462619818985
# RUN  120 , total integrated cost =  5.007346261961096
# RUN  130 , total integrated cost =  5.007346261933874
# RUN  140 , total integrated cost =  5.007346261913222
# RUN  150 , total integrated cost =  5.007346261905968
# RUN  160 , total integrated cost =  5.007346261884627
# RUN  170 , total integrated cost =  5.007346261853271
# RUN  180 , total integrated cost =  5.00734626184301
# RUN  190 , total integrated cost =  5.007346261838606
# RUN  200 , total integrated cost =  5.007346261815673
# RUN  300 , total integrated cost =  5.007346261317402
# RUN  400 , total integrated cost =  5.007346261085397
# RUN  500 , total integrated cost =  5.007346260335166
# RUN  600 , total integrated cost =  5.007346260230342
# RUN  700 , total integrated cost =  5.0073462594987035
# RUN  800 , total integrated cost =  5.007346258692866
# RUN  900 , total integrated cost =  5.007346258487255
# RUN  1000 , total integrated cost =  5.007346258333952
# RUN  1100 , total integrated cost =  5.007346258112384
# RUN  1200 , total integrated cost =  5.007346256806987
# RUN  1300 , total integrated cost =  5.007346256593528
# RUN  1400 , total integrated cost =  5.007346256420852
# RUN  1500 , total integrated cost =  5.007346255484029
# RUN  1600 , total integrated cost =  5.007346255253283
# RUN  1700 , total integrated cost =  5.00734625509962
# RUN  1800 , total integrated cost =  5.0073462549930055
# RUN  1900 , total integrated cost =  5.007346254728508
# RUN  2000 , total integrated cost =  5.007346254316969
# RUN  3000 , total integrated cost =  5.007346249166793
# RUN  4000 , total integrated cost =  5.00734624473613
# RUN  5000 , total integrated cost =  5.007346240616157
# RUN  6000 , total integrated cost =  5.007346238254699
# RUN  7000 , total integrated cost =  5.007346234654046
# RUN  8000 , total integrated cost =  5.007346232270913
# RUN  9000 , total integrated cost =  5.007346223480206
# RUN  10000 , total integrated cost =  5.007346220022536
# RUN  10000 , total integrated cost =  5.007346220022536
# Improved over  10000  iterations in  13227.326431594789  seconds by  8.48578068257666e-07  percent.
# 2.915712423086968e-11 [5.00734622 0.        ]
# go back to ----- 200
# ----- 200
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  5.007346220022536
# RUN  0 , total integrated cost =  5.007346220022536
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.007346220022286
# RUN  2 , total integrated cost =  5.007346220022188
# RUN  3 , total integrated cost =  5.00734622002166
# RUN  4 , total integrated cost =  5.007346220021297
# RUN  5 , total integrated cost =  5.007346220006008
# RUN  6 , total integrated cost =  5.007346219989556
# RUN  7 , total integrated cost =  5.007346219989437
# RUN  8 , total integrated cost =  5.0073462199892065
# RUN  9 , total integrated cost =  5.007346219989113
# RUN  10 , total integrated cost =  5.007346219986686
# RUN  11 , total integrated cost =  5.007346219984676
# RUN  12 , total integrated cost =  5.007346219984361
# RUN  13 , total integrated cost =  5.007346219983935
# RUN  14 , total integrated cost =  5.007346219983814
# RUN  15 , total integrated cost =  5.007346219983589
# RUN  16 , total integrated cost =  5.007346219983481
# RUN  17 , total integrated cost =  5.007346219981608
# RUN  18 , total integrated cost =  5.007346219979837
# RUN  19 , total integrated cost =  5.007346219979483
# RUN  20 , total integrated cost =  5.0073462199790075
# RUN  30 , total integrated cost =  5.007346219974041
# RUN  40 , total integrated cost =  5.007346219933736
# RUN  50 , total integrated cost =  5.007346219925204
# RUN  60 , total integrated cost =  5.007346219919621
# RUN  70 , total integrated cost =  5.0073462199126615
# RUN  80 , total integrated cost =  5.007346219907848
# RUN  90 , total integrated cost =  5.007346219898761
# RUN  100 , total integrated cost =  5.007346219883824
# RUN  110 , total integrated cost =  5.0073462198631296
# RUN  120 , total integrated cost =  5.007346219842365
# RUN  130 , total integrated cost =  5.0073462198383
# RUN  140 , total integrated cost =  5.0073462198308185
# RUN  150 , total integrated cost =  5.007346219818874
# RUN  160 , total integrated cost =  5.007346219808783
# RUN  170 , total integrated cost =  5.007346219785011
# RUN  180 , total integrated cost =  5.007346219780307
# RUN  190 , total integrated cost =  5.007346219770547
# RUN  200 , total integrated cost =  5.007346219765439
# RUN  300 , total integrated cost =  5.007346218713068
# RUN  400 , total integrated cost =  5.007346218481165
# RUN  500 , total integrated cost =  5.007346218285425
# RUN  600 , total integrated cost =  5.007346216324114
# RUN  700 , total integrated cost =  5.007346213986386
# RUN  800 , total integrated cost =  5.007346213825527
# RUN  900 , total integrated cost =  5.007346212974939
# RUN  1000 , total integrated cost =  5.007346212427598
# RUN  1100 , total integrated cost =  5.007346212205677
# RUN  1200 , total integrated cost =  5.00734621125072
# RUN  1300 , total integrated cost =  5.007346210845468
# RUN  1400 , total integrated cost =  5.007346209870473
# RUN  1500 , total integrated cost =  5.007346209050301
# RUN  1600 , total integrated cost =  5.007346208903759
# RUN  1700 , total integrated cost =  5.007346208760743
# RUN  1800 , total integrated cost =  5.007346208617677
# RUN  1900 , total integrated cost =  5.007346208467392
# RUN  2000 , total integrated cost =  5.007346207467683
# RUN  3000 , total integrated cost =  5.007346201628905
# RUN  4000 , total integrated cost =  5.007346195888249
# RUN  5000 , total integrated cost =  5.00734618919901
# RUN  6000 , total integrated cost =  5.007346177313502
# RUN  7000 , total integrated cost =  5.007346169236794
# RUN  8000 , total integrated cost =  5.007346156680438
# RUN  9000 , total integrated cost =  5.007346150360606
# RUN  10000 , total integrated cost =  5.007346135856923
# RUN  10000 , total integrated cost =  5.007346135856923
# Improved over  10000  iterations in  12658.551252424717  seconds by  1.6808427005798876e-06  percent.
# 2.87439254898277e-11 [5.00734614 0.        ]
# go back to ----- 200
# ----- 200
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  5.007346135856923
# RUN  0 , total integrated cost =  5.007346135856923
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.007346135856261
# RUN  2 , total integrated cost =  5.007346135856159
# RUN  3 , total integrated cost =  5.007346135855909
# RUN  4 , total integrated cost =  5.007346135855769
# RUN  5 , total integrated cost =  5.007346135846619
# RUN  6 , total integrated cost =  5.007346135838276
# RUN  7 , total integrated cost =  5.007346135838149
# RUN  8 , total integrated cost =  5.007346135837913
# RUN  9 , total integrated cost =  5.007346135837814
# RUN  10 , total integrated cost =  5.007346135837315
# RUN  11 , total integrated cost =  5.007346135836928
# RUN  12 , total integrated cost =  5.007346135835062
# RUN  13 , total integrated cost =  5.007346135832889
# RUN  14 , total integrated cost =  5.007346135832354
# RUN  15 , total integrated cost =  5.007346135831709
# RUN  16 , total integrated cost =  5.007346135831612
# RUN  17 , total integrated cost =  5.007346135831196
# RUN  18 , total integrated cost =  5.007346135830875
# RUN  19 , total integrated cost =  5.007346135828592
# RUN  20 , total integrated cost =  5.007346135826044
# RUN  30 , total integrated cost =  5.007346135814228
# RUN  40 , total integrated cost =  5.007346135795362
# RUN  50 , total integrated cost =  5.007346135787968
# RUN  60 , total integrated cost =  5.007346135764365
# RUN  70 , total integrated cost =  5.00734613575759
# RUN  80 , total integrated cost =  5.007346135681317
# RUN  90 , total integrated cost =  5.007346135603617
# RUN  100 , total integrated cost =  5.007346135580191
# RUN  110 , total integrated cost =  5.007346135572685
# RUN  120 , total integrated cost =  5.007346135562473
# RUN  130 , total integrated cost =  5.007346135539766
# RUN  140 , total integrated cost =  5.007346135532521
# RUN  150 , total integrated cost =  5.007346135526334
# RUN  160 , total integrated cost =  5.007346135498071
# RUN  170 , total integrated cost =  5.0073461354869275
# RUN  180 , total integrated cost =  5.007346135468365
# RUN  190 , total integrated cost =  5.007346135463418
# RUN  200 , total integrated cost =  5.007346135457741
# RUN  300 , total integrated cost =  5.007346132070292
# RUN  400 , total integrated cost =  5.007346131930172
# RUN  500 , total integrated cost =  5.007346128970868
# RUN  600 , total integrated cost =  5.007346128765984
# RUN  700 , total integrated cost =  5.007346128360866
# RUN  800 , total integrated cost =  5.007346128253979
# RUN  900 , total integrated cost =  5.007346128035931
# RUN  1000 , total integrated cost =  5.00734612584383
# RUN  1100 , total integrated cost =  5.00734612573492
# RUN  1200 , total integrated cost =  5.007346123388415
# RUN  1300 , total integrated cost =  5.007346123028215
# RUN  1400 , total integrated cost =  5.00734612271609
# RUN  1500 , total integrated cost =  5.007346122445476
# RUN  1600 , total integrated cost =  5.007346115315456
# RUN  1700 , total integrated cost =  5.007346115186488
# RUN  1800 , total integrated cost =  5.007346114817573
# RUN  1900 , total integrated cost =  5.007346114690343
# RUN  2000 , total integrated cost =  5.007346109173105
# RUN  3000 , total integrated cost =  5.007346072302825
# RUN  4000 , total integrated cost =  5.0073459595255505
# RUN  5000 , total integrated cost =  5.007345948782675
# RUN  6000 , total integrated cost =  5.0073459416748936
# RUN  7000 , total integrated cost =  5.007345936247593
# RUN  8000 , total integrated cost =  5.007345924710032
# RUN  9000 , total integrated cost =  5.007345902791585
# RUN  10000 , total integrated cost =  5.007345739013571
# RUN  10000 , total integrated cost =  5.007345739013571
# Improved over  10000  iterations in  6117.12437427789  seconds by  7.925223087568156e-06  percent.
# 2.8540505986262886e-11 [5.00734574 0.        ]
# go back to ----- 200
# ----- 200
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  5.007345739013571
# RUN  0 , total integrated cost =  5.007345739013571
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.007345739013349
# RUN  2 , total integrated cost =  5.007345739013232
# RUN  3 , total integrated cost =  5.00734573900729
# RUN  4 , total integrated cost =  5.007345739002079
# RUN  5 , total integrated cost =  5.007345739001704
# RUN  6 , total integrated cost =  5.007345739001193
# RUN  7 , total integrated cost =  5.007345739001092
# RUN  8 , total integrated cost =  5.007345739000844
# RUN  9 , total integrated cost =  5.007345739000708
# RUN  10 , total integrated cost =  5.007345738999822
# RUN  11 , total integrated cost =  5.0073457389990415
# RUN  12 , total integrated cost =  5.007345738998881
# RUN  13 , total integrated cost =  5.00734573899862
# RUN  14 , total integrated cost =  5.007345738998518
# RUN  15 , total integrated cost =  5.007345738998228
# RUN  16 , total integrated cost =  5.007345738998024
# RUN  17 , total integrated cost =  5.007345738997461
# RUN  18 , total integrated cost =  5.0073457389967535
# RUN  19 , total integrated cost =  5.007345738996584
# RUN  20 , total integrated cost =  5.00734573899634
# RUN  30 , total integrated cost =  5.00734573898685
# RUN  40 , total integrated cost =  5.007345738974442
# RUN  50 , total integrated cost =  5.007345737543033
# RUN  60 , total integrated cost =  5.007345737533307
# RUN  70 , total integrated cost =  5.007345737529322
# RUN  80 , total integrated cost =  5.00734573590423
# RUN  90 , total integrated cost =  5.007345735892228
# RUN  100 , total integrated cost =  5.007345735884604
# RUN  110 , total integrated cost =  5.007345735858822
# RUN  120 , total integrated cost =  5.007345735850434
# RUN  130 , total integrated cost =  5.007345735841639
# RUN  140 , total integrated cost =  5.00734573583041
# RUN  150 , total integrated cost =  5.007345735812074
# RUN  160 , total integrated cost =  5.007345735797668
# RUN  170 , total integrated cost =  5.007345735785786
# RUN  180 , total integrated cost =  5.007345735765048
# RUN  190 , total integrated cost =  5.007345735753351
# RUN  200 , total integrated cost =  5.0073457357352105
# RUN  300 , total integrated cost =  5.007345734506976
# RUN  400 , total integrated cost =  5.007345733536662
# RUN  500 , total integrated cost =  5.007345730328254
# RUN  600 , total integrated cost =  5.0073457297671435
# RUN  700 , total integrated cost =  5.007345729529429
# RUN  800 , total integrated cost =  5.007345728420838
# RUN  900 , total integrated cost =  5.007345727249898
# RUN  1000 , total integrated cost =  5.0073457270716295
# RUN  1100 , total integrated cost =  5.007345725323834
# RUN  1200 , total integrated cost =  5.007345724425365
# RUN  1300 , total integrated cost =  5.007345724241411
# RUN  1400 , total integrated cost =  5.007345722805557
# RUN  1500 , total integrated cost =  5.007345722143155
# RUN  1600 , total integrated cost =  5.0073457213095285
# RUN  1700 , total integrated cost =  5.007345720801008
# RUN  1800 , total integrated cost =  5.007345720471716
# RUN  1900 , total integrated cost =  5.007345716514901
# RUN  2000 , total integrated cost =  5.0073457145809375
# RUN  3000 , total integrated cost =  5.007345706760375
# RUN  4000 , total integrated cost =  5.007345699861718
# RUN  5000 , total integrated cost =  5.0073456940322245
# RUN  6000 , total integrated cost =  5.007345687275402
# RUN  7000 , total integrated cost =  5.007345679667632
# RUN  8000 , total integrated cost =  5.007345674950296
# RUN  9000 , total integrated cost =  5.00734567011806
# go back to ----- 200
# ----- 200
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  5.007345664364991
# RUN  0 , total integrated cost =  5.007345664364991
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.0073456643648795
# RUN  2 , total integrated cost =  5.0073456643643555
# RUN  3 , total integrated cost =  5.007345664364006
# RUN  4 , total integrated cost =  5.007345664356507
# RUN  5 , total integrated cost =  5.007345664348115
# RUN  6 , total integrated cost =  5.007345664348009
# RUN  7 , total integrated cost =  5.007345664347787
# RUN  8 , total integrated cost =  5.00734566434764
# RUN  9 , total integrated cost =  5.007345664347143
# RUN  10 , total integrated cost =  5.007345664346757
# RUN  11 , total integrated cost =  5.0073456643401615
# RUN  12 , total integrated cost =  5.0073456643324405
# RUN  13 , total integrated cost =  5.007345664332343
# RUN  14 , total integrated cost =  5.007345664332112
# RUN  15 , total integrated cost =  5.0073456643319725
# RUN  16 , total integrated cost =  5.007345664331566
# RUN  17 , total integrated cost =  5.007345664331235
# RUN  18 , total integrated cost =  5.007345664323468
# RUN  19 , total integrated cost =  5.007345664315339
# RUN  20 , total integrated cost =  5.007345664315241
# RUN  30 , total integrated cost =  5.007345664196364
# RUN  40 , total integrated cost =  5.007345664152565
# RUN  50 , total integrated cost =  5.007345664144177
# RUN  60 , total integrated cost =  5.007345664134436
# RUN  70 , total integrated cost =  5.007345664091821
# RUN  80 , total integrated cost =  5.007345664082571
# RUN  90 , total integrated cost =  5.007345664074383
# RUN  100 , total integrated cost =  5.007345664066125
# RUN  110 , total integrated cost =  5.0073456640329175
# RUN  120 , total integrated cost =  5.0073456639618446
# RUN  130 , total integrated cost =  5.0073456639447995
# RUN  140 , total integrated cost =  5.007345663932483
# RUN  150 , total integrated cost =  5.0073456639154825
# RUN  160 , total integrated cost =  5.007345663798321
# RUN  170 , total integrated cost =  5.007345663785273
# RUN  180 , total integrated cost =  5.007345663769348
# RUN  190 , total integrated cost =  5.007345663754181
# RUN  200 , total integrated cost =  5.0073456637335445
# RUN  300 , total integrated cost =  5.007345663403505
# RUN  400 , total integrated cost =  5.007345662786138
# RUN  500 , total integrated cost =  5.007345662106856
# RUN  600 , total integrated cost =  5.007345661088273
# RUN  700 , total integrated cost =  5.007345660674996
# RUN  800 , total integrated cost =  5.007345660218693
# RUN  900 , total integrated cost =  5.007345659540205
# RUN  1000 , total integrated cost =  5.007345658929223
# RUN  1100 , total integrated cost =  5.007345658664785
# RUN  1200 , total integrated cost =  5.007345658059037
# RUN  1300 , total integrated cost =  5.007345657243493
# RUN  1400 , total integrated cost =  5.007345657003682
# RUN  1500 , total integrated cost =  5.007345656296792
# RUN  1600 , total integrated cost =  5.007345655610498
# RUN  1700 , total integrated cost =  5.00734565518083
# RUN  1800 , total integrated cost =  5.00734565463171
# RUN  1900 , total integrated cost =  5.0073456541825365
# RUN  2000 , total integrated cost =  5.007345653917546
# RUN  3000 , total integrated cost =  5.007345647791015
# RUN  4000 , total integrated cost =  5.007345643757805
# RUN  5000 , total integrated cost =  5.007345639510343
# RUN  6000 , total integrated cost =  5.0073456149894655
# RUN  7000 , total integrated cost =  5.007345611167048
# RUN  8000 , total integrated cost =  5.00734560699422
# RUN  9000 , total integrated cost =  5.007345603103723
# RUN  10000 , total integrated cost =  5.00734559860296
# RUN  10000 , total integrated cost =  5.00734559860296
# Improved over  10000  iterations in  6495.503886476159  seconds by  1.3133112020113913e-06  percent.
# 2.8568598735828905e-11 [5.0073456 0.       ]

# %%
bestControl_maxW = np.array( [[None] * len(t_pen)] * len(exc) )
bestState_maxW = np.array( [[None] * len(t_pen)] * len(exc) )
cost_maxW = np.array( [[None] * len(t_pen)] * len(exc) )
costnode_maxW = np.array( [[None] * len(t_pen)] * len(exc) )
weights_maxW = np.array( [[None] * len(t_pen)] * len(exc) )
convergence_maxW = np.array( [[None] * len(t_pen)] * len(exc) )

file_maxW = 'down_Wmax.pickle'

# %%
if os.path.isfile(file_maxW) :
    print("file found")
    
    with open(file_maxW,'rb') as f:
        load_array = pickle.load(f)

    bestControl_maxW = load_array[0]
    bestState_maxW = load_array[1]
    cost_maxW = load_array[2]
    costnode_maxW = load_array[3]
    weights_maxW = load_array[4]

# %%
for i in i_range:
    print('------------', i)
    j = 0

    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.

    aln.params.duration = dur

    while not convergence_maxW[i][j]:
        dur = d_array[j]
        aln.params.duration = dur

        setinit(initVars[i], aln)

        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        control0 = aln.getZeroControl()
        if type(bestControl_maxW[i][j]) == type(None):
            max_it = 10
            control0 = bestControl_[i][0][:,:,n_pre-1:-n_post+1]
            weight_ = ( cost_uncontrolled[i] * (1. - t_pen[0]) / (1. - t_pen[j]) 
                       - sum(costnode_[i][j][0][0][:]) ) / sum( costnode_[i][j][2][0][:] )
            cost.setParams(1., weight_ * factor_we, weight_ * factor_ws)
            weights_maxW[i][j] = cost.getParams()
        else:
            control0 = bestControl_maxW[i][j][:,:,n_pre-1:-n_post+1]
            weight_ = ( cost_uncontrolled[i] * (1. - t_pen[0]) / (1. - t_pen[j])
                       - sum(costnode_maxW[i][j][0][0][:]) ) / sum( costnode_maxW[i][j][2][0][:] )
            cost.setParams(1., weight_ * factor_we, weight_ * factor_ws)
            weights_maxW[i][j] = cost.getParams()
            max_it = int(100)

        bestControl_maxW[i][j], bestState_maxW[i][j], cost_maxW[i][j], runtime_, grad_, phi_, phi1_, costnode_maxW[i][j] = aln.A1(
            control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
            prec_variables_ = p_var, transition_time_ = t_pen[j])

        if cost_maxW[i][j][2] == 0.:
            convergence_maxW[i][j] = True

        print('cost splitting : ', costnode_maxW[i][j][0][0][0], costnode_maxW[i][j][2][0][:2])

        with open(file_maxW,'wb') as f:
            pickle.dump([bestControl_maxW, bestState_maxW, cost_maxW, costnode_maxW, weights_maxW], f)

# %%
for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    j = 0
    step = step1

    while j < 4800:

        if j == 0:
            j += step
            continue
            
        if not convergence_maxW[i][j-step]:
            if j - step > 0:
                j -= step
                print('go back to -----', j)

        print('-----', j)

        if convergence_maxW[i][j]:
            j += step
            continue

        dur = d_array[j]
        T = 5001 - j
        aln.params.duration = dur
        setinit(initVars[i], aln)

        max_it = 1000

        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        if type(bestControl_maxW[i][j]) == type(None):
            max_percent_prev = (np.argmax(np.abs(bestControl_maxW[i][j-step]), axis=2)[0,1] - 100) / (T-200)
            shift_ind = 0
            if j < 4000:
                while max_percent_prev > max_percent[i]:
                    shift_ind += 1
                    max_percent_prev = (np.argmax(np.abs(bestControl_maxW[i][j-step]), axis=2)[0,1] - 100 - shift_ind) / (T-200)

            control0 = np.zeros(( bestControl_maxW[i][j-step][:,:,100:-(100+step)].shape ))
            print('shift ind = ', shift_ind)
            if shift_ind != 0:
                control0[:,:,:-shift_ind] = 1. * bestControl_maxW[i][j-step][:,:,100+shift_ind:-(100+step)]
            else:
                control0[:,:,:] = 1. * bestControl_maxW[i][j-step][:,:,100:-(100+step)]
                
            weight_ = ( cost_uncontrolled[i] * (1. - t_pen[0]) / (1. - t_pen[j])
                          - sum(costnode_maxW[i][j-step][0][0][:]) ) / sum( costnode_maxW[i][j-step][2][0][:] )
            cost.setParams(1., weight_ * factor_we, weight_ * factor_ws)
            weights_maxW[i][j] = cost.getParams()
        
        else:
            if bestControl_maxW[i][j].shape[2] == T+200:
                control0 = bestControl_maxW[i][j][:,:,100:-100]
                #control0[0,1,:] = 0.
            else:
                control0 = bestControl_maxW[i][j][:,:,100:-(100+j)]
                
                weight_ = ( cost_uncontrolled[i] * (1. - t_pen[0]) / (1. - t_pen[j])
                           - sum(costnode_maxW[i][j][0][0][:]) ) / sum( costnode_maxW[i][j][2][0][:] )
                cost.setParams(1., weight_ * factor_we, weight_ * factor_ws)
                weights_maxW[i][j] = cost.getParams()

        bestControl_maxW[i][j], bestState_maxW[i][j], cost_maxW[i][j], runtime_, grad_, phi_, phi1_, costnode_maxW[i][j] = aln.A1(
            control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
            prec_variables_ = p_var, transition_time_ = t_pen[j])

        print(costnode_maxW[i][j][0][0][:2], costnode_maxW[i][j][2][0][:2])

        if cost_maxW[i][j][2] == 0.:
            convergence_maxW[i][j] = True
            if j >= 4400:
                step = step2
            if j >=4790:
                step = step3

        with open(file_maxW,'wb') as f:
            pickle.dump([bestControl_maxW, bestState_maxW, cost_maxW, costnode_maxW, weights_maxW], f)

        j += step
