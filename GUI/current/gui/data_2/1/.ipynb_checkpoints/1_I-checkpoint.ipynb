# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import sys
import pickle
import random

path = os.getcwd().split(os.sep + 'GUI')[0]
if path not in sys.path:
    print("not here")
    sys.path.append(path)

from neurolib.models.aln import ALNModel
from neurolib.utils import plotFunctions as plotFunc
from neurolib.utils import costFunctions as cost
import neurolib.dashboard.functions as functions
import neurolib.dashboard.data as data
    
# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2 

#path = os.path.join(os.getcwd(), "plots")
# Out:
# not here

# %%
grid_data_file = os.path.join(os.getcwd().split('data')[0], 'bi.pickle')
print(grid_data_file)
with open(grid_data_file,'rb') as f:
    load_array= pickle.load(f)
exc = load_array[0]
inh = load_array[1]
print(len(exc))
# Out:
# /home/lena/Promotion/neurolib/GUI/current/gui/bi.pickle
# 147

# %%
aln = ALNModel()
N = aln.params.N

data.set_parameters(aln)

state_vars = aln.state_vars
init_vars = aln.init_vars

##############################################################
def setinit(init_vars_, model):
    state_vars = model.state_vars
    init_vars = model.init_vars
    for iv in range(len(init_vars)):
        for sv in range(len(state_vars)):
            if state_vars[sv] in init_vars[iv]:
                #print("set init vars ", )
                if model.params[init_vars[iv]].ndim == 2:
                    model.params[init_vars[iv]][0,:] = init_vars_[sv]
                else:
                    model.params[init_vars[iv]][0] = init_vars_[sv]
                    
##############################################################               
def setmaxmincontrol(max_c_c, min_c_c, max_c_r, min_c_r):
    import numpy as np
    
    max_cntrl = np.zeros(( 6 ))
    min_cntrl = np.zeros(( 6 ))
    
    max_cntrl[0] = max_c_c
    min_cntrl[0] = min_c_c
    max_cntrl[1] = max_c_c
    min_cntrl[1] = min_c_c
    max_cntrl[2] = max_c_r
    min_cntrl[2] = min_c_r
    max_cntrl[3] = max_c_r
    min_cntrl[3] = min_c_r
    max_cntrl[4] = max_c_r
    min_cntrl[4] = min_c_r
    max_cntrl[5] = max_c_r
    min_cntrl[5] = min_c_r
            
    return max_cntrl, min_cntrl

# %%
dur = 500.
t_pen = 0.96

# %%
file_ = '1_I.pickle'
c_var = [1]

folder = str(os.getcwd().split('data_2')[1])
print(folder)
case = str(folder[1])
# Out:
# /1

# %%
dur_pre = 10
dur_post = 10

n_pre = int(np.around(dur_pre/aln.params.dt + 1.,1))
n_post = int(np.around(dur_post/aln.params.dt + 1.,1))

tol = 1e-10
start_step = 10.
c_scheme = np.zeros(( 1,1 ))
c_scheme[0,0] = 1.
u_mat = np.identity(1)
u_scheme = np.array([[1.]])

p_var = [0]
wp = 1. / (dur - t_pen * dur)

if case in ['1', '2']:    # low to high
    max_I = [3., -3.]
else:
    max_I = [-3., 3.]
    
if case in ['1', '3']:    # sparsity
    factor_ws = 1.
    factor_we = 0.
else:
    factor_ws = 0.
    factor_we = 1.
    
maxC = [5., -5., 0.18, 0.]
max_cntrl, min_cntrl = setmaxmincontrol(maxC[0], maxC[1], maxC[2], maxC[3])

# %%
bestControl_ = [None] * len(exc) 
bestState_ = [None] * len(exc) 
cost_ = [None] * len(exc) 
costnode_ = [None] * len(exc) 
weights_ = [None] * len(exc) 

if os.path.isfile(file_) :
    print("file found")
    
    with open(file_,'rb') as f:
        load_array = pickle.load(f)

    bestControl_ = load_array[0]
    bestState_ = load_array[1]
    cost_ = load_array[2]
    costnode_ = load_array[3]
    weights_ = load_array[4]
# Out:
# file found

# %%
initVars = [None] * len(exc)
target = [None] * len(exc)
cost_uncontrolled = [None] * len(exc)

# %%
# get initial parameters and target states

i_range = range(0,83,1)

data.set_parameters(aln)

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    aln.params.duration = 3000.
    
    control0 = aln.getZeroControl()
    control0 = functions.step_control(aln, maxI_ = max_I[0])

    aln.run(control=control0)
    
    target_rates = np.zeros((2))
    target_rates[0] = aln.rates_exc[0,-1] 
    target_rates[1] = aln.rates_inh[0,-1]

    control0 = functions.step_control(aln, maxI_ = max_I[1])
    aln.run(control=control0)

    init_state_vars = np.zeros(( len(state_vars) ))
    for j in range(len(state_vars)):
        if aln.state[state_vars[j]].size == 1:
            init_state_vars[j] = aln.state[state_vars[j]][0]
        else:
            init_state_vars[j] = aln.state[state_vars[j]][0,-1]

    initVars[i] = init_state_vars
    target[i] = [target_rates[0], target_rates[1]]
# Out:
# -------  0 0.4000000000000001 0.3500000000000001
# -------  1 0.4250000000000001 0.3500000000000001
# -------  2 0.4000000000000001 0.3750000000000001
# -------  3 0.4250000000000001 0.3750000000000001
# -------  4 0.4500000000000001 0.3750000000000001
# -------  5 0.4000000000000001 0.40000000000000013
# -------  6 0.4250000000000001 0.40000000000000013
# -------  7 0.4500000000000001 0.40000000000000013
# -------  8 0.47500000000000014 0.40000000000000013
# -------  9 0.4000000000000001 0.42500000000000016
# -------  10 0.4250000000000001 0.42500000000000016
# -------  11 0.4500000000000001 0.42500000000000016
# -------  12 0.47500000000000014 0.42500000000000016
# -------  13 0.4000000000000001 0.4500000000000002
# -------  14 0.4250000000000001 0.4500000000000002
# -------  15 0.4500000000000001 0.4500000000000002
# -------  16 0.47500000000000014 0.4500000000000002
# -------  17 0.5000000000000002 0.4500000000000002
# -------  18 0.4000000000000001 0.4750000000000002
# -------  19 0.4250000000000001 0.4750000000000002
# -------  20 0.4500000000000001 0.4750000000000002
# -------  21 0.47500000000000014 0.4750000000000002
# -------  22 0.5000000000000002 0.4750000000000002
# -------  23 0.5250000000000001 0.4750000000000002
# -------  24 0.4000000000000001 0.5000000000000002
# -------  25 0.4250000000000001 0.5000000000000002
# -------  26 0.4500000000000001 0.5000000000000002
# -------  27 0.47500000000000014 0.5000000000000002
# -------  28 0.5000000000000002 0.5000000000000002
# -------  29 0.5250000000000001 0.5000000000000002
# -------  30 0.4250000000000001 0.5250000000000002
# -------  31 0.4500000000000001 0.5250000000000002
# -------  32 0.47500000000000014 0.5250000000000002
# -------  33 0.5000000000000002 0.5250000000000002
# -------  34 0.5250000000000001 0.5250000000000002
# -------  35 0.5500000000000003 0.5250000000000002
# -------  36 0.4250000000000001 0.5500000000000003
# -------  37 0.4500000000000001 0.5500000000000003
# -------  38 0.47500000000000014 0.5500000000000003
# -------  39 0.5000000000000002 0.5500000000000003
# -------  40 0.5250000000000001 0.5500000000000003
# -------  41 0.5500000000000003 0.5500000000000003
# -------  42 0.4250000000000001 0.5750000000000003
# -------  43 0.4500000000000001 0.5750000000000003
# -------  44 0.47500000000000014 0.5750000000000003
# -------  45 0.5000000000000002 0.5750000000000003
# -------  46 0.5250000000000001 0.5750000000000003
# -------  47 0.5500000000000003 0.5750000000000003
# -------  48 0.4250000000000001 0.6000000000000003
# -------  49 0.4500000000000001 0.6000000000000003
# -------  50 0.47500000000000014 0.6000000000000003
# -------  51 0.5000000000000002 0.6000000000000003
# -------  52 0.5250000000000001 0.6000000000000003
# -------  53 0.5500000000000003 0.6000000000000003
# -------  54 0.5750000000000002 0.6000000000000003
# -------  55 0.4250000000000001 0.6250000000000003
# -------  56 0.4500000000000001 0.6250000000000003
# -------  57 0.47500000000000014 0.6250000000000003
# -------  58 0.5000000000000002 0.6250000000000003
# -------  59 0.5250000000000001 0.6250000000000003
# -------  60 0.5500000000000003 0.6250000000000003
# -------  61 0.5750000000000002 0.6250000000000003
# -------  62 0.4250000000000001 0.6500000000000004
# -------  63 0.4500000000000001 0.6500000000000004
# -------  64 0.47500000000000014 0.6500000000000004
# -------  65 0.5000000000000002 0.6500000000000004
# -------  66 0.5250000000000001 0.6500000000000004
# -------  67 0.5500000000000003 0.6500000000000004
# -------  68 0.5750000000000002 0.6500000000000004
# -------  69 0.4250000000000001 0.6750000000000004
# -------  70 0.4500000000000001 0.6750000000000004
# -------  71 0.47500000000000014 0.6750000000000004
# -------  72 0.5000000000000002 0.6750000000000004
# -------  73 0.5250000000000001 0.6750000000000004
# -------  74 0.5500000000000003 0.6750000000000004
# -------  75 0.5750000000000002 0.6750000000000004
# -------  76 0.4250000000000001 0.7000000000000004
# -------  77 0.4500000000000001 0.7000000000000004
# -------  78 0.47500000000000014 0.7000000000000004
# -------  79 0.5000000000000002 0.7000000000000004
# -------  80 0.5250000000000001 0.7000000000000004
# -------  81 0.5500000000000003 0.7000000000000004
# -------  82 0.5750000000000002 0.7000000000000004

# %%
# get uncontrolled cost
data.set_parameters(aln)

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    aln.params.duration = dur
    
    target_ = aln.getZeroTarget()
    target_[:,0,:] = target[i][0]
    target_[:,1,:] = target[i][1]
            
    cost.setParams(wp, 0.0, 0.0)

    setinit(initVars[i], aln)
    control0 = aln.getZeroControl()

    cgv = None
    max_it = 0

    bestControl_init_, bestState_init_, cost_init_, runtime_init_, grad_init_, phi_init_, phi1_, costnode_init_ = aln.A1(
        control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
        prec_variables_ = p_var, transition_time_ = t_pen)
    
    cost_uncontrolled[i] = cost_init_[0]
# Out:
# -------  0 0.4000000000000001 0.3500000000000001
# set cost params:  0.05 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  295.1203239619291
# RUN  0 , total integrated cost =  295.1203239619291
# Gradient descend method:  None
# RUN  0 , total integrated cost =  295.1203239619291
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  1 0.4250000000000001 0.3500000000000001
# set cost params:  0.05 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  490.81359439844215
# RUN  0 , total integrated cost =  490.81359439844215
# Gradient descend method:  None
# RUN  0 , total integrated cost =  490.81359439844215
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  2 0.4000000000000001 0.3750000000000001
# set cost params:  0.05 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  276.9353881083755
# RUN  0 , total integrated cost =  276.9353881083755
# Gradient descend method:  None
# RUN  0 , total integrated cost =  276.9353881083755
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  3 0.4250000000000001 0.3750000000000001
# set cost params:  0.05 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  485.2784447710771
# RUN  0 , total integrated cost =  485.2784447710771
# Gradient descend method:  None
# RUN  0 , total integrated cost =  485.2784447710771
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  4 0.4500000000000001 0.3750000000000001
# set cost params:  0.05 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  680.1133312665802
# RUN  0 , total integrated cost =  680.1133312665802
# Gradient descend method:  None
# RUN  0 , total integrated cost =  680.1133312665802
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  5 0.4000000000000001 0.40000000000000013
# set cost params:  0.05 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  254.86449140999528
# RUN  0 , total integrated cost =  254.86449140999528
# Gradient descend method:  None
# RUN  0 , total integrated cost =  254.86449140999528
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  6 0.4250000000000001 0.40000000000000013
# set cost params:  0.05 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  471.9538368446909
# RUN  0 , total integrated cost =  471.9538368446909
# Gradient descend method:  None
# RUN  0 , total integrated cost =  471.9538368446909
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  7 0.4500000000000001 0.40000000000000013
# set cost params:  0.05 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  677.860255446574
# RUN  0 , total integrated cost =  677.860255446574
# Gradient descend method:  None
# RUN  0 , total integrated cost =  677.860255446574
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  8 0.47500000000000014 0.40000000000000013
# set cost params:  0.05 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  877.5573911507829
# RUN  0 , total integrated cost =  877.5573911507829
# Gradient descend method:  None
# RUN  0 , total integrated cost =  877.5573911507829
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  9 0.4000000000000001 0.42500000000000016
# set cost params:  0.05 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  232.11379765972552
# RUN  0 , total integrated cost =  232.11379765972552
# Gradient descend method:  None
# RUN  0 , total integrated cost =  232.11379765972552
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  10 0.4250000000000001 0.42500000000000016
# set cost params:  0.05 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  455.57282451055954
# RUN  0 , total integrated cost =  455.57282451055954
# Gradient descend method:  None
# RUN  0 , total integrated cost =  455.57282451055954
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  11 0.4500000000000001 0.42500000000000016
# set cost params:  0.05 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  665.571788546768
# RUN  0 , total integrated cost =  665.571788546768
# Gradient descend method:  None
# RUN  0 , total integrated cost =  665.571788546768
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  12 0.47500000000000014 0.42500000000000016
# set cost params:  0.05 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  878.560008314686
# RUN  0 , total integrated cost =  878.560008314686
# Gradient descend method:  None
# RUN  0 , total integrated cost =  878.560008314686
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  13 0.4000000000000001 0.4500000000000002
# set cost params:  0.05 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  208.86235665930843
# RUN  0 , total integrated cost =  208.86235665930843
# Gradient descend method:  None
# RUN  0 , total integrated cost =  208.86235665930843
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  14 0.4250000000000001 0.4500000000000002
# set cost params:  0.05 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  439.80877803490125
# RUN  0 , total integrated cost =  439.80877803490125
# Gradient descend method:  None
# RUN  0 , total integrated cost =  439.80877803490125
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  15 0.4500000000000001 0.4500000000000002
# set cost params:  0.05 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  650.9037320173404
# RUN  0 , total integrated cost =  650.9037320173404
# Gradient descend method:  None
# RUN  0 , total integrated cost =  650.9037320173404
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  16 0.47500000000000014 0.4500000000000002
# set cost params:  0.05 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  867.0448977562043
# RUN  0 , total integrated cost =  867.0448977562043
# Gradient descend method:  None
# RUN  0 , total integrated cost =  867.0448977562043
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  17 0.5000000000000002 0.4500000000000002
# set cost params:  0.05 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1088.3381695519752
# RUN  0 , total integrated cost =  1088.3381695519752
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1088.3381695519752
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  18 0.4000000000000001 0.4750000000000002
# set cost params:  0.05 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  183.55796221510641
# RUN  0 , total integrated cost =  183.55796221510641
# Gradient descend method:  None
# RUN  0 , total integrated cost =  183.55796221510641
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  19 0.4250000000000001 0.4750000000000002
# set cost params:  0.05 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  425.17584252715665
# RUN  0 , total integrated cost =  425.17584252715665
# Gradient descend method:  None
# RUN  0 , total integrated cost =  425.17584252715665
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  20 0.4500000000000001 0.4750000000000002
# set cost params:  0.05 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  636.9058225135838
# RUN  0 , total integrated cost =  636.9058225135838
# Gradient descend method:  None
# RUN  0 , total integrated cost =  636.9058225135838
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  21 0.47500000000000014 0.4750000000000002
# set cost params:  0.05 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  853.444341989734
# RUN  0 , total integrated cost =  853.444341989734
# Gradient descend method:  None
# RUN  0 , total integrated cost =  853.444341989734
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  22 0.5000000000000002 0.4750000000000002
# set cost params:  0.05 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1078.2588794154944
# RUN  0 , total integrated cost =  1078.2588794154944
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1078.2588794154944
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  23 0.5250000000000001 0.4750000000000002
# set cost params:  0.05 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1305.596837765156
# RUN  0 , total integrated cost =  1305.596837765156
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1305.596837765156
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  24 0.4000000000000001 0.5000000000000002
# set cost params:  0.05 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  149.04908161970724
# RUN  0 , total integrated cost =  149.04908161970724
# Gradient descend method:  None
# RUN  0 , total integrated cost =  149.04908161970724
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  25 0.4250000000000001 0.5000000000000002
# set cost params:  0.05 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  411.59536107342876
# RUN  0 , total integrated cost =  411.59536107342876
# Gradient descend method:  None
# RUN  0 , total integrated cost =  411.59536107342876
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  26 0.4500000000000001 0.5000000000000002
# set cost params:  0.05 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  623.98423067335
# RUN  0 , total integrated cost =  623.98423067335
# Gradient descend method:  None
# RUN  0 , total integrated cost =  623.98423067335
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  27 0.47500000000000014 0.5000000000000002
# set cost params:  0.05 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  840.486503578103
# RUN  0 , total integrated cost =  840.486503578103
# Gradient descend method:  None
# RUN  0 , total integrated cost =  840.486503578103
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  28 0.5000000000000002 0.5000000000000002
# set cost params:  0.05 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1065.654639098131
# RUN  0 , total integrated cost =  1065.654639098131
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1065.654639098131
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  29 0.5250000000000001 0.5000000000000002
# set cost params:  0.05 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1299.2487134596593
# RUN  0 , total integrated cost =  1299.2487134596593
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1299.2487134596593
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  30 0.4250000000000001 0.5250000000000002
# set cost params:  0.05 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  398.9158590893028
# RUN  0 , total integrated cost =  398.9158590893028
# Gradient descend method:  None
# RUN  0 , total integrated cost =  398.9158590893028
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  31 0.4500000000000001 0.5250000000000002
# set cost params:  0.05 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  611.9840098576404
# RUN  0 , total integrated cost =  611.9840098576404
# Gradient descend method:  None
# RUN  0 , total integrated cost =  611.9840098576404
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  32 0.47500000000000014 0.5250000000000002
# set cost params:  0.05 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  828.4109189821265
# RUN  0 , total integrated cost =  828.4109189821265
# Gradient descend method:  None
# RUN  0 , total integrated cost =  828.4109189821265
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  33 0.5000000000000002 0.5250000000000002
# set cost params:  0.05 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1053.4566176891283
# RUN  0 , total integrated cost =  1053.4566176891283
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1053.4566176891283
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  34 0.5250000000000001 0.5250000000000002
# set cost params:  0.05 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1287.9845155276914
# RUN  0 , total integrated cost =  1287.9845155276914
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1287.9845155276914
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  35 0.5500000000000003 0.5250000000000002
# set cost params:  0.05 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1527.32144921191
# RUN  0 , total integrated cost =  1527.32144921191
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1527.32144921191
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  36 0.4250000000000001 0.5500000000000003
# set cost params:  0.05 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  387.0833866640474
# RUN  0 , total integrated cost =  387.0833866640474
# Gradient descend method:  None
# RUN  0 , total integrated cost =  387.0833866640474
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  37 0.4500000000000001 0.5500000000000003
# set cost params:  0.05 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  600.8741453799756
# RUN  0 , total integrated cost =  600.8741453799756
# Gradient descend method:  None
# RUN  0 , total integrated cost =  600.8741453799756
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  38 0.47500000000000014 0.5500000000000003
# set cost params:  0.05 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  817.2314097109169
# RUN  0 , total integrated cost =  817.2314097109169
# Gradient descend method:  None
# RUN  0 , total integrated cost =  817.2314097109169
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  39 0.5000000000000002 0.5500000000000003
# set cost params:  0.05 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1042.0431472829491
# RUN  0 , total integrated cost =  1042.0431472829491
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1042.0431472829491
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  40 0.5250000000000001 0.5500000000000003
# set cost params:  0.05 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1276.5738852746529
# RUN  0 , total integrated cost =  1276.5738852746529
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1276.5738852746529
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  41 0.5500000000000003 0.5500000000000003
# set cost params:  0.05 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1519.6476109133644
# RUN  0 , total integrated cost =  1519.6476109133644
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1519.6476109133644
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  42 0.4250000000000001 0.5750000000000003
# set cost params:  0.05 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  375.9591752519903
# RUN  0 , total integrated cost =  375.9591752519903
# Gradient descend method:  None
# RUN  0 , total integrated cost =  375.9591752519903
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  43 0.4500000000000001 0.5750000000000003
# set cost params:  0.05 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  590.5339574936078
# RUN  0 , total integrated cost =  590.5339574936078
# Gradient descend method:  None
# RUN  0 , total integrated cost =  590.5339574936078
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  44 0.47500000000000014 0.5750000000000003
# set cost params:  0.05 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  806.8509744931607
# RUN  0 , total integrated cost =  806.8509744931607
# Gradient descend method:  None
# RUN  0 , total integrated cost =  806.8509744931607
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  45 0.5000000000000002 0.5750000000000003
# set cost params:  0.05 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1031.3953947060102
# RUN  0 , total integrated cost =  1031.3953947060102
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1031.3953947060102
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  46 0.5250000000000001 0.5750000000000003
# set cost params:  0.05 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1265.7355655437036
# RUN  0 , total integrated cost =  1265.7355655437036
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1265.7355655437036
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  47 0.5500000000000003 0.5750000000000003
# set cost params:  0.05 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1509.5617137521951
# RUN  0 , total integrated cost =  1509.5617137521951
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1509.5617137521951
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  48 0.4250000000000001 0.6000000000000003
# set cost params:  0.05 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  365.51076705497655
# RUN  0 , total integrated cost =  365.51076705497655
# Gradient descend method:  None
# RUN  0 , total integrated cost =  365.51076705497655
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  49 0.4500000000000001 0.6000000000000003
# set cost params:  0.05 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  580.8726224508954
# RUN  0 , total integrated cost =  580.8726224508954
# Gradient descend method:  None
# RUN  0 , total integrated cost =  580.8726224508954
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  50 0.47500000000000014 0.6000000000000003
# set cost params:  0.05 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  797.1477718037709
# RUN  0 , total integrated cost =  797.1477718037709
# Gradient descend method:  None
# RUN  0 , total integrated cost =  797.1477718037709
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  51 0.5000000000000002 0.6000000000000003
# set cost params:  0.05 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1021.4835077649523
# RUN  0 , total integrated cost =  1021.4835077649523
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1021.4835077649523
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  52 0.5250000000000001 0.6000000000000003
# set cost params:  0.05 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1255.5484151263772
# RUN  0 , total integrated cost =  1255.5484151263772
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1255.5484151263772
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  53 0.5500000000000003 0.6000000000000003
# set cost params:  0.05 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1499.45071686005
# RUN  0 , total integrated cost =  1499.45071686005
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1499.45071686005
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  54 0.5750000000000002 0.6000000000000003
# set cost params:  0.05 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1749.4018925696892
# RUN  0 , total integrated cost =  1749.4018925696892
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1749.4018925696892
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  55 0.4250000000000001 0.6250000000000003
# set cost params:  0.05 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  355.64566789762387
# RUN  0 , total integrated cost =  355.64566789762387
# Gradient descend method:  None
# RUN  0 , total integrated cost =  355.64566789762387
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  56 0.4500000000000001 0.6250000000000003
# set cost params:  0.05 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  571.8584743356153
# RUN  0 , total integrated cost =  571.8584743356153
# Gradient descend method:  None
# RUN  0 , total integrated cost =  571.8584743356153
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  57 0.47500000000000014 0.6250000000000003
# set cost params:  0.05 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  788.100083052238
# RUN  0 , total integrated cost =  788.100083052238
# Gradient descend method:  None
# RUN  0 , total integrated cost =  788.100083052238
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  58 0.5000000000000002 0.6250000000000003
# set cost params:  0.05 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1012.236377049588
# RUN  0 , total integrated cost =  1012.236377049588
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1012.236377049588
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  59 0.5250000000000001 0.6250000000000003
# set cost params:  0.05 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1246.0201531879043
# RUN  0 , total integrated cost =  1246.0201531879043
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1246.0201531879043
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  60 0.5500000000000003 0.6250000000000003
# set cost params:  0.05 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1489.7819922684603
# RUN  0 , total integrated cost =  1489.7819922684603
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1489.7819922684603
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  61 0.5750000000000002 0.6250000000000003
# set cost params:  0.05 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1741.7404678036398
# RUN  0 , total integrated cost =  1741.7404678036398
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1741.7404678036398
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  62 0.4250000000000001 0.6500000000000004
# set cost params:  0.05 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  346.3084589538196
# RUN  0 , total integrated cost =  346.3084589538196
# Gradient descend method:  None
# RUN  0 , total integrated cost =  346.3084589538196
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  63 0.4500000000000001 0.6500000000000004
# set cost params:  0.05 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  563.4077876032045
# RUN  0 , total integrated cost =  563.4077876032045
# Gradient descend method:  None
# RUN  0 , total integrated cost =  563.4077876032045
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  64 0.47500000000000014 0.6500000000000004
# set cost params:  0.05 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  779.6432321693527
# RUN  0 , total integrated cost =  779.6432321693527
# Gradient descend method:  None
# RUN  0 , total integrated cost =  779.6432321693527
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  65 0.5000000000000002 0.6500000000000004
# set cost params:  0.05 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1003.5557556832827
# RUN  0 , total integrated cost =  1003.5557556832827
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1003.5557556832827
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  66 0.5250000000000001 0.6500000000000004
# set cost params:  0.05 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1237.1014764099714
# RUN  0 , total integrated cost =  1237.1014764099714
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1237.1014764099714
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  67 0.5500000000000003 0.6500000000000004
# set cost params:  0.05 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1480.6481391436553
# RUN  0 , total integrated cost =  1480.6481391436553
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1480.6481391436553
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  68 0.5750000000000002 0.6500000000000004
# set cost params:  0.05 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1733.2138872070445
# RUN  0 , total integrated cost =  1733.2138872070445
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1733.2138872070445
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  69 0.4250000000000001 0.6750000000000004
# set cost params:  0.05 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  337.479567507888
# RUN  0 , total integrated cost =  337.479567507888
# Gradient descend method:  None
# RUN  0 , total integrated cost =  337.479567507888
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  70 0.4500000000000001 0.6750000000000004
# set cost params:  0.05 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  555.4524528078139
# RUN  0 , total integrated cost =  555.4524528078139
# Gradient descend method:  None
# RUN  0 , total integrated cost =  555.4524528078139
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  71 0.47500000000000014 0.6750000000000004
# set cost params:  0.05 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  771.6969104453199
# RUN  0 , total integrated cost =  771.6969104453199
# Gradient descend method:  None
# RUN  0 , total integrated cost =  771.6969104453199
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  72 0.5000000000000002 0.6750000000000004
# set cost params:  0.05 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  995.4164939619873
# RUN  0 , total integrated cost =  995.4164939619873
# Gradient descend method:  None
# RUN  0 , total integrated cost =  995.4164939619873
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  73 0.5250000000000001 0.6750000000000004
# set cost params:  0.05 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1228.7327114182663
# RUN  0 , total integrated cost =  1228.7327114182663
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1228.7327114182663
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  74 0.5500000000000003 0.6750000000000004
# set cost params:  0.05 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1472.0503179189525
# RUN  0 , total integrated cost =  1472.0503179189525
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1472.0503179189525
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  75 0.5750000000000002 0.6750000000000004
# set cost params:  0.05 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1724.7914491906026
# RUN  0 , total integrated cost =  1724.7914491906026
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1724.7914491906026
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  76 0.4250000000000001 0.7000000000000004
# set cost params:  0.05 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  329.04521873539363
# RUN  0 , total integrated cost =  329.04521873539363
# Gradient descend method:  None
# RUN  0 , total integrated cost =  329.04521873539363
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  77 0.4500000000000001 0.7000000000000004
# set cost params:  0.05 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  547.9805088984016
# RUN  0 , total integrated cost =  547.9805088984016
# Gradient descend method:  None
# RUN  0 , total integrated cost =  547.9805088984016
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  78 0.47500000000000014 0.7000000000000004
# set cost params:  0.05 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  764.21978919591
# RUN  0 , total integrated cost =  764.21978919591
# Gradient descend method:  None
# RUN  0 , total integrated cost =  764.21978919591
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  79 0.5000000000000002 0.7000000000000004
# set cost params:  0.05 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  987.7747943519569
# RUN  0 , total integrated cost =  987.7747943519569
# Gradient descend method:  None
# RUN  0 , total integrated cost =  987.7747943519569
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  80 0.5250000000000001 0.7000000000000004
# set cost params:  0.05 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1220.8433126041011
# RUN  0 , total integrated cost =  1220.8433126041011
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1220.8433126041011
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  81 0.5500000000000003 0.7000000000000004
# set cost params:  0.05 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1463.94854782607
# RUN  0 , total integrated cost =  1463.94854782607
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1463.94854782607
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  82 0.5750000000000002 0.7000000000000004
# set cost params:  0.05 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1716.6770456793977
# RUN  0 , total integrated cost =  1716.6770456793977
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1716.6770456793977
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.

# %%
cgv = None
j = 0

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    if type(bestControl_[i]) != type(None):
        continue
    
    aln.params.duration = dur
    setinit(initVars[i], aln)

    target_ = aln.getZeroTarget()
    target_[:,0,:] = target[i][0]
    target_[:,1,:] = target[i][1]

    control0 = aln.getZeroControl()
    cost.setParams(wp, 0., 10.)
    max_it = int(10)

    control0[0,1,2200:2800] = -2.

    bestControl_[i], bestState_[i], cost_[i], runtime_, grad_, phi_, phi1_, costnode_[i] = aln.A1(
        control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
        prec_variables_ = p_var, transition_time_ = t_pen)

    if True:
        plot_time_array = np.arange(0.,round(dur+aln.params.dt,1),aln.params.dt)
        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        fig, ax = plt.subplots(2,1, constrained_layout=True, figsize = (4,8) )
        ax[1].plot(plot_time_array, bestControl_[i][0,0,n_pre-1:-n_post+1], color = 'red')
        ax[0].plot(plot_time_array, bestState_[i][0,0,n_pre-1:-n_post+1], color= 'red')
        ax[1].plot(plot_time_array, bestControl_[i][0,1,n_pre-1:-n_post+1], color = 'blue')
        ax[0].plot(plot_time_array, bestState_[i][0,1,n_pre-1:-n_post+1], color= 'blue')
        ax[0].plot(plot_time_array, target_[0,0,n_pre-1:-n_post+1], linestyle = '--', color='red')
        ax[0].plot(plot_time_array, target_[0,1,n_pre-1:-n_post+1], linestyle = '--', color='blue')
        plt.show()

    print('uncontrolled cost : ', cost_uncontrolled[i])
    print('cost splitting : ', costnode_[i][0][0][0], costnode_[i][2][0][:2])

# %%
c_var = [0,1]
conv = [None] * len(exc)
max_it = int(30)

tol = 1e-6

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
        
    while not conv[i]:

        weight_ = random.random() * ( cost_uncontrolled[i] -
                                     costnode_[i][0][0][0] ) / sum( costnode_[i][2][0][:] )
            
        aln.params.duration = dur
        cost.setParams(wp, weight_ * factor_we, weight_ * factor_ws)
        weights_[i] = cost.getParams()

        setinit(initVars[i], aln)

        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        control0 = aln.getZeroControl()
        control0 = bestControl_[i][:,:,n_pre-1:-n_post+1]

        bestControl_[i], bestState_[i], cost_[i], runtime_, grad_, phi_, phi1_, costnode_[i] = aln.A1(
            control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
            prec_variables_ = p_var, transition_time_ = t_pen)
        
        if cost_[i][2] == 0.:
            conv[i] = True

        #print('uncontrolled cost : ', cost_uncontrolled[i])
        print('cost splitting : ', costnode_[i][0][0][0], costnode_[i][2][0][:2])

        if conv[i] and False:
            time_ = np.arange(-dur_pre,round(dur+dur_post+aln.params.dt,1),aln.params.dt)
            target_ = aln.getZeroTarget()
            target_[:,0,:] = target[i][0]
            target_[:,1,:] = target[i][1]
        
            fig, ax = plt.subplots(2,1, constrained_layout=True, figsize = (4,4) )
            ax[1].plot(time_, bestControl_[i][0,0,:], color = 'red')
            ax[0].plot(time_, bestState_[i][0,0,:], color= 'red')
            ax[1].plot(time_, bestControl_[i][0,1,:], color = 'blue')
            ax[0].plot(time_, bestState_[i][0,1,:], color= 'blue')
            ax[0].plot(time_, target_[0,0,:], linestyle = '--', color='red')
            ax[0].plot(time_, target_[0,1,:], linestyle = '--', color='blue')
            ax[0].set_xlim(-dur_pre,dur+dur_post)
            ax[1].set_xlim(-dur_pre,dur+dur_post)
            ax[0].axvspan(dur*t_pen, dur, alpha=0.2, color='gray')
            plt.show()

        with open(file_,'wb') as f:
            pickle.dump([bestControl_, bestState_, cost_, costnode_, weights_], f)
# Out:
# -------  0 0.4000000000000001 0.3500000000000001
# set cost params:  0.05 0.0 8.238000778025667
# interpolate adjoint :  True True True
# initial cost =  12.368060568679283
# RUN  0 , total integrated cost =  12.368060568679283
# Gradient descend method:  None
# RUN  1 , total integrated cost =  9.592879079786252
# RUN  2 , total integrated cost =  9.025821866176628
# RUN  3 , total integrated cost =  9.00709749974879
# RUN  4 , total integrated cost =  9.006795605022301
# RUN  5 , total integrated cost =  9.006795605022301
# Control only changes marginally.
# RUN  5 , total integrated cost =  9.006795605022301
# Improved over  5  iterations in  2.716120663972106  seconds by  27.17697689942598  percent.
# cost splitting :  0.017446070613105127 [0.36684204 0.72637506]
# set cost params:  0.05 0.0 249.04113043349727
# interpolate adjoint :  True True True
# initial cost =  272.25689412662854
# RUN  0 , total integrated cost =  272.25689412662854
# Gradient descend method:  None
# RUN  1 , total integrated cost =  272.25476713546885
# RUN  2 , total integrated cost =  269.9546442819971
# RUN  3 , total integrated cost =  266.8789224497683
# RUN  4 , total integrated cost =  266.74585010601083
# RUN  5 , total integrated cost =  266.74208737353496
# RUN  6 , total integrated cost =  266.74208737353496
# Control only changes marginally.
# RUN  6 , total integrated cost =  266.74208737353496
# Improved over  6  iterations in  2.4137973039760254  seconds by  2.0255893871060664  percent.
# cost splitting :  0.008972711236988158 [0.34469958 0.72637506]
# set cost params:  0.05 0.0 223.36223153152673
# interpolate adjoint :  True True True
# initial cost =  239.23807001633998
# RUN  0 , total integrated cost =  239.23807001633998
# Gradient descend method:  None
# RUN  1 , total integrated cost =  239.23807001633998
# Control only changes marginally.
# RUN  1 , total integrated cost =  239.23807001633998
# Improved over  1  iterations in  0.6950078150257468  seconds by  0.0  percent.
# cost splitting :  0.008972711236988158 [0.34469958 0.72637506]
# -------  1 0.4250000000000001 0.3500000000000001
# set cost params:  0.05 0.0 471.41149330992477
# interpolate adjoint :  True True True
# initial cost =  385.5270909715933
# RUN  0 , total integrated cost =  385.5270909715933
# Gradient descend method:  None
# RUN  1 , total integrated cost =  385.5270909715933
# Control only changes marginally.
# RUN  1 , total integrated cost =  385.5270909715933
# Improved over  1  iterations in  0.6950794380391017  seconds by  0.0  percent.
# cost splitting :  6.593440811138558e-06 [0.         0.81781436]
# -------  2 0.4000000000000001 0.3750000000000001
# set cost params:  0.05 0.0 118.04731716608448
# interpolate adjoint :  True True True
# initial cost =  274.50590297873805
# RUN  0 , total integrated cost =  274.50590297873805
# Gradient descend method:  None
# RUN  1 , total integrated cost =  274.504803683758
# RUN  2 , total integrated cost =  274.504803683758
# Control only changes marginally.
# RUN  2 , total integrated cost =  274.504803683758
# Improved over  2  iterations in  1.4482594089931808  seconds by  0.0004004631478267129  percent.
# cost splitting :  0.013105835206382591 [2.94076881e-06 2.32537094e+00]
# set cost params:  0.05 0.0 69.83960016779965
# interpolate adjoint :  True True True
# initial cost =  162.4038375777822
# RUN  0 , total integrated cost =  162.4038375777822
# Gradient descend method:  None
# RUN  1 , total integrated cost =  162.4038375777822
# Control only changes marginally.
# RUN  1 , total integrated cost =  162.4038375777822
# Improved over  1  iterations in  0.7442968349787407  seconds by  0.0  percent.
# cost splitting :  0.013105835206382591 [2.94076881e-06 2.32537094e+00]
# -------  3 0.4250000000000001 0.3750000000000001
# set cost params:  0.05 0.0 31.576340205662014
# interpolate adjoint :  True True True
# initial cost =  46.78096390592856
# RUN  0 , total integrated cost =  46.78096390592856
# Gradient descend method:  None
# RUN  1 , total integrated cost =  46.78096390592856
# Control only changes marginally.
# RUN  1 , total integrated cost =  46.78096390592856
# Improved over  1  iterations in  0.7416111280326732  seconds by  0.0  percent.
# cost splitting :  7.061735153770385e-05 [0.         1.48151939]
# -------  4 0.4500000000000001 0.3750000000000001
# set cost params:  0.05 0.0 307.39687202202475
# interpolate adjoint :  True True True
# initial cost =  211.7930324849401
# RUN  0 , total integrated cost =  211.7930324849401
# Gradient descend method:  None
# RUN  1 , total integrated cost =  211.7930324849401
# Control only changes marginally.
# RUN  1 , total integrated cost =  211.7930324849401
# Improved over  1  iterations in  0.7312128440244123  seconds by  0.0  percent.
# cost splitting :  3.9574153267427407e-05 [0.         0.68898889]
# -------  5 0.4000000000000001 0.40000000000000013
# set cost params:  0.05 0.0 29.784091683070816
# interpolate adjoint :  True True True
# initial cost =  98.99057888394717
# RUN  0 , total integrated cost =  98.99057888394717
# Gradient descend method:  None
# RUN  1 , total integrated cost =  98.9888311224296
# RUN  2 , total integrated cost =  98.98837251683707
# RUN  3 , total integrated cost =  98.98718904627398
# RUN  4 , total integrated cost =  98.98674311600959
# RUN  5 , total integrated cost =  98.98566453949577
# RUN  6 , total integrated cost =  98.9852101289288
# RUN  7 , total integrated cost =  98.98400571723732
# RUN  8 , total integrated cost =  98.98355953158668
# RUN  9 , total integrated cost =  98.98245321741102
# RUN  10 , total integrated cost =  98.98199336122515
# RUN  11 , total integrated cost =  98.980696301705
# RUN  12 , total integrated cost =  98.9802225300636
# RUN  13 , total integrated cost =  98.97885901225135
# RUN  14 , total integrated cost =  98.978290630527
# RUN  15 , total integrated cost =  98.97560364973016
# RUN  16 , total integrated cost =  98.97497135372632
# RUN  17 , total integrated cost =  98.96942403414687
# RUN  18 , total integrated cost =  98.96897588551829
# RUN  19 , total integrated cost =  98.96784179695089
# RUN  20 , total integrated cost =  98.96737128504319
# RUN  30 , total integrated cost =  98.95363990859722
# RUN  30 , total integrated cost =  98.95363990859722
# Improved over  30  iterations in  14.729791025980376  seconds by  0.03731564737412896  percent.
# cost splitting :  0.0026370013066291933 [5.86188369e-06 3.32235525e+00]
# set cost params:  0.05 0.0 21.754093046995926
# interpolate adjoint :  True True True
# initial cost =  72.2750846852233
# RUN  0 , total integrated cost =  72.2750846852233
# Gradient descend method:  None
# RUN  1 , total integrated cost =  72.2742415834208
# RUN  2 , total integrated cost =  72.27388686282305
# RUN  3 , total integrated cost =  72.27301571398905
# RUN  4 , total integrated cost =  72.27265781891231
# RUN  5 , total integrated cost =  72.27175184881564
# RUN  6 , total integrated cost =  72.27138380880646
# RUN  7 , total integrated cost =  72.2703367907576
# RUN  8 , total integrated cost =  72.26996398810772
# RUN  9 , total integrated cost =  72.26893535596557
# RUN  10 , total integrated cost =  72.26857238997253
# RUN  11 , total integrated cost =  72.26757022206262
# RUN  12 , total integrated cost =  72.26721508431883
# RUN  13 , total integrated cost =  72.26629461725865
# RUN  14 , total integrated cost =  72.26591964693486
# RUN  15 , total integrated cost =  72.26476636043571
# RUN  16 , total integrated cost =  72.264402933678
# RUN  17 , total integrated cost =  72.26340302568009
# RUN  18 , total integrated cost =  72.26304847382856
# RUN  19 , total integrated cost =  72.26217803159861
# RUN  20 , total integrated cost =  72.26182048507346
# RUN  30 , total integrated cost =  72.25515161683165
# RUN  30 , total integrated cost =  72.25515161683165
# Improved over  30  iterations in  15.432194848021027  seconds by  0.02757944660800149  percent.
# cost splitting :  0.0022234313655877863 [5.86188369e-06 3.32143991e+00]
# set cost params:  0.05 0.0 40.52581534599664
# interpolate adjoint :  True True True
# initial cost =  134.60440934094765
# RUN  0 , total integrated cost =  134.60440934094765
# Gradient descend method:  None
# RUN  1 , total integrated cost =  134.60248689004786
# RUN  2 , total integrated cost =  134.60189615711363
# RUN  3 , total integrated cost =  134.60023085952065
# RUN  4 , total integrated cost =  134.59966067916096
# RUN  5 , total integrated cost =  134.5982276476484
# RUN  6 , total integrated cost =  134.59765702744502
# RUN  7 , total integrated cost =  134.59612709138955
# RUN  8 , total integrated cost =  134.59550603157646
# RUN  9 , total integrated cost =  134.59359231370408
# RUN  10 , total integrated cost =  134.59300704468427
# RUN  11 , total integrated cost =  134.59143611181887
# RUN  12 , total integrated cost =  134.59075960286597
# RUN  13 , total integrated cost =  134.58803564222288
# RUN  14 , total integrated cost =  133.42716459251469
# RUN  15 , total integrated cost =  118.99252056401278
# RUN  16 , total integrated cost =  118.29083633420069
# RUN  17 , total integrated cost =  118.25279111934702
# RUN  18 , total integrated cost =  118.2515311106828
# RUN  19 , total integrated cost =  118.25107238529009
# RUN  20 , total integrated cost =  118.24987684922166
# RUN  30 , total integrated cost =  98.574712662112
# RUN  30 , total integrated cost =  98.574712662112
# Improved over  30  iterations in  18.223004190949723  seconds by  26.767099870832496  percent.
# cost splitting :  0.011433111814605358 [5.86188369e-06 2.43237311e+00]
# set cost params:  0.05 0.0 102.34162416443755
# interpolate adjoint :  True True True
# initial cost =  248.93418607127805
# RUN  0 , total integrated cost =  248.93418607127805
# Gradient descend method:  None
# RUN  1 , total integrated cost =  248.93363581084847
# RUN  2 , total integrated cost =  248.93325454632023
# RUN  3 , total integrated cost =  248.93262003135206
# RUN  4 , total integrated cost =  248.93236324813697
# RUN  5 , total integrated cost =  248.93236324813697
# Control only changes marginally.
# RUN  5 , total integrated cost =  248.93236324813697
# Improved over  5  iterations in  3.3875817379448563  seconds by  0.0007322510298166662  percent.
# cost splitting :  0.01388078286111075 [5.86188369e-06 2.43235410e+00]
# set cost params:  0.05 0.0 44.6171694130536
# interpolate adjoint :  True True True
# initial cost =  108.52571060059915
# RUN  0 , total integrated cost =  108.52571060059915
# Gradient descend method:  None
# RUN  1 , total integrated cost =  108.52540651336194
# RUN  2 , total integrated cost =  108.52475671174103
# RUN  3 , total integrated cost =  108.52448750163187
# RUN  4 , total integrated cost =  108.52396690758866
# RUN  5 , total integrated cost =  108.52375164537892
# RUN  6 , total integrated cost =  108.52339469157387
# RUN  7 , total integrated cost =  108.52300995318217
# RUN  8 , total integrated cost =  108.52211488530254
# RUN  9 , total integrated cost =  108.52180014673746
# RUN  10 , total integrated cost =  108.52116317845493
# RUN  11 , total integrated cost =  108.52095681827527
# RUN  12 , total integrated cost =  108.52059010115634
# RUN  13 , total integrated cost =  108.52045000802948
# RUN  14 , total integrated cost =  108.52025578632711
# RUN  15 , total integrated cost =  108.52013997123342
# RUN  16 , total integrated cost =  108.51998095186924
# RUN  17 , total integrated cost =  108.51986880202877
# RUN  18 , total integrated cost =  108.5197171907237
# RUN  19 , total integrated cost =  108.51960437145019
# RUN  20 , total integrated cost =  108.51945365253175
# RUN  30 , total integrated cost =  108.51813639807821
# RUN  30 , total integrated cost =  108.51813639807821
# Improved over  30  iterations in  15.854844328016043  seconds by  0.006979178002168851  percent.
# cost splitting :  0.01518283195758904 [5.86188369e-06 2.43218288e+00]
# set cost params:  0.05 0.0 85.44768667606715
# interpolate adjoint :  True True True
# initial cost =  207.82566091601308
# RUN  0 , total integrated cost =  207.82566091601308
# Gradient descend method:  None
# RUN  1 , total integrated cost =  207.82543885138296
# RUN  2 , total integrated cost =  207.82527583735958
# RUN  3 , total integrated cost =  207.82505015934044
# RUN  4 , total integrated cost =  207.82505015934044
# Control only changes marginally.
# RUN  4 , total integrated cost =  207.82505015934044
# Improved over  4  iterations in  2.7273834199877456  seconds by  0.0002938793361408898  percent.
# cost splitting :  0.026458571146098918 [5.86188369e-06 2.43216914e+00]
# set cost params:  0.05 0.0 78.14228763581274
# interpolate adjoint :  True True True
# initial cost =  190.0570412580638
# RUN  0 , total integrated cost =  190.0570412580638
# Gradient descend method:  None
# RUN  1 , total integrated cost =  190.0570412580638
# Control only changes marginally.
# RUN  1 , total integrated cost =  190.0570412580638
# Improved over  1  iterations in  0.8150569800054654  seconds by  0.0  percent.
# cost splitting :  0.026458571146098918 [5.86188369e-06 2.43216914e+00]
# -------  6 0.4250000000000001 0.40000000000000013
# set cost params:  0.05 0.0 196.96916042634186
# interpolate adjoint :  True True True
# initial cost =  328.9560391078349
# RUN  0 , total integrated cost =  328.9560391078349
# Gradient descend method:  None
# RUN  1 , total integrated cost =  328.94505486079925
# RUN  2 , total integrated cost =  328.94505486079925
# Control only changes marginally.
# RUN  2 , total integrated cost =  328.94505486079925
# Improved over  2  iterations in  1.4419706470216624  seconds by  0.0033391230832648944  percent.
# cost splitting :  1.130156252323818e-07 [0.         1.67003329]
# set cost params:  0.05 0.0 13.300306422873621
# interpolate adjoint :  True True True
# initial cost =  22.21195448823354
# RUN  0 , total integrated cost =  22.21195448823354
# Gradient descend method:  None
# RUN  1 , total integrated cost =  22.21195448823354
# Control only changes marginally.
# RUN  1 , total integrated cost =  22.21195448823354
# Improved over  1  iterations in  0.4298291529994458  seconds by  0.0  percent.
# cost splitting :  1.130156252323818e-07 [0.         1.67003329]
# -------  7 0.4500000000000001 0.40000000000000013
# set cost params:  0.05 0.0 384.7262177062176
# interpolate adjoint :  True True True
# initial cost =  566.0255820822654
# RUN  0 , total integrated cost =  566.0255820822654
# Gradient descend method:  None
# RUN  1 , total integrated cost =  566.0255820822654
# Control only changes marginally.
# RUN  1 , total integrated cost =  566.0255820822654
# Improved over  1  iterations in  0.5215949869598262  seconds by  0.0  percent.
# cost splitting :  1.2267166098450698e-06 [0.         1.47124255]
# -------  8 0.47500000000000014 0.40000000000000013
# set cost params:  0.05 0.0 413.99029790445053
# interpolate adjoint :  True True True
# initial cost =  199.69602321478624
# RUN  0 , total integrated cost =  199.69602321478624
# Gradient descend method:  None
# RUN  1 , total integrated cost =  199.69602321478624
# Control only changes marginally.
# RUN  1 , total integrated cost =  199.69602321478624
# Improved over  1  iterations in  0.5324495279928669  seconds by  0.0  percent.
# cost splitting :  8.191072410275832e-05 [0.         0.48236884]
# -------  9 0.4000000000000001 0.42500000000000016
# set cost params:  0.05 0.0 15.234100428512704
# interpolate adjoint :  True True True
# initial cost =  65.82958413286842
# RUN  0 , total integrated cost =  65.82958413286842
# Gradient descend method:  None
# RUN  1 , total integrated cost =  56.62359652711031
# RUN  2 , total integrated cost =  50.73095650177466
# RUN  3 , total integrated cost =  50.44761779375625
# RUN  4 , total integrated cost =  50.43572077263725
# RUN  5 , total integrated cost =  50.43552607508766
# RUN  6 , total integrated cost =  50.43538290211574
# RUN  7 , total integrated cost =  50.43519198644982
# RUN  8 , total integrated cost =  50.43504931756677
# RUN  9 , total integrated cost =  50.43485779551864
# RUN  10 , total integrated cost =  50.43471466352316
# RUN  11 , total integrated cost =  50.43452398393923
# RUN  12 , total integrated cost =  50.43438100072485
# RUN  13 , total integrated cost =  50.43418999482752
# RUN  14 , total integrated cost =  50.43404738919587
# RUN  15 , total integrated cost =  50.43385615519514
# RUN  16 , total integrated cost =  50.43370861987475
# RUN  17 , total integrated cost =  50.43351725003827
# RUN  18 , total integrated cost =  50.43336986008326
# RUN  19 , total integrated cost =  50.43317833018758
# RUN  20 , total integrated cost =  50.43303110550418
# RUN  30 , total integrated cost =  50.43133741702863
# RUN  30 , total integrated cost =  50.43133741702863
# Improved over  30  iterations in  16.561299710010644  seconds by  23.391073965711882  percent.
# cost splitting :  0.011897814577447749 [0.         3.31038533]
# set cost params:  0.05 0.0 25.917657937300582
# interpolate adjoint :  True True True
# initial cost =  85.79802943267256
# RUN  0 , total integrated cost =  85.79802943267256
# Gradient descend method:  None
# RUN  1 , total integrated cost =  85.79751245548458
# RUN  2 , total integrated cost =  85.79723742858476
# RUN  3 , total integrated cost =  85.79683325278744
# RUN  4 , total integrated cost =  85.79649053197262
# RUN  5 , total integrated cost =  85.7959305864305
# RUN  6 , total integrated cost =  85.79562447082718
# RUN  7 , total integrated cost =  85.79518100170954
# RUN  8 , total integrated cost =  85.79479480888442
# RUN  9 , total integrated cost =  85.79420575518039
# RUN  10 , total integrated cost =  85.79386792363483
# RUN  11 , total integrated cost =  85.7933838464758
# RUN  12 , total integrated cost =  85.79312469093541
# RUN  13 , total integrated cost =  85.79277549161513
# RUN  14 , total integrated cost =  85.79253776189722
# RUN  15 , total integrated cost =  85.792195621267
# RUN  16 , total integrated cost =  85.79195728229574
# RUN  17 , total integrated cost =  85.79161605387954
# RUN  18 , total integrated cost =  85.79137766502822
# RUN  19 , total integrated cost =  85.79103658888266
# RUN  20 , total integrated cost =  85.79079823336575
# RUN  30 , total integrated cost =  85.7879021994779
# RUN  30 , total integrated cost =  85.7879021994779
# Improved over  30  iterations in  16.988996430009138  seconds by  0.01180357318418146  percent.
# cost splitting :  0.015284823568497452 [0.         3.30998805]
# set cost params:  0.05 0.0 64.90364070134896
# interpolate adjoint :  True True True
# initial cost =  214.83103911833965
# RUN  0 , total integrated cost =  214.83103911833965
# Gradient descend method:  None
# RUN  1 , total integrated cost =  214.82874506297637
# RUN  2 , total integrated cost =  214.8275959352113
# RUN  3 , total integrated cost =  214.8254114478672
# RUN  4 , total integrated cost =  214.8246573312217
# RUN  5 , total integrated cost =  214.82341808951116
# RUN  6 , total integrated cost =  214.8224868836152
# RUN  7 , total integrated cost =  214.82081848808505
# RUN  8 , total integrated cost =  214.82007763693355
# RUN  9 , total integrated cost =  214.81895011898553
# RUN  10 , total integrated cost =  214.81824612316387
# RUN  11 , total integrated cost =  214.81720153399513
# RUN  12 , total integrated cost =  214.81658553164118
# RUN  13 , total integrated cost =  214.8156850812586
# RUN  14 , total integrated cost =  214.81514928959982
# RUN  15 , total integrated cost =  214.81438996129359
# RUN  16 , total integrated cost =  214.81388394206277
# RUN  17 , total integrated cost =  214.8131994446703
# RUN  18 , total integrated cost =  214.8126920196584
# RUN  19 , total integrated cost =  214.8119537593392
# RUN  20 , total integrated cost =  214.8114488370121
# RUN  30 , total integrated cost =  214.80538527150975
# RUN  30 , total integrated cost =  214.80538527150975
# Improved over  30  iterations in  16.25756208098028  seconds by  0.011941406109272634  percent.
# cost splitting :  0.0316254085256547 [0.        3.3095802]
# set cost params:  0.05 0.0 61.73328842451389
# interpolate adjoint :  True True True
# initial cost =  204.31285015747392
# RUN  0 , total integrated cost =  204.31285015747392
# Gradient descend method:  None
# RUN  1 , total integrated cost =  204.31218682487417
# RUN  2 , total integrated cost =  204.31174376627365
# RUN  3 , total integrated cost =  204.31115014703144
# RUN  4 , total integrated cost =  204.31068903722192
# RUN  5 , total integrated cost =  204.31003455099608
# RUN  6 , total integrated cost =  204.30959072707
# RUN  7 , total integrated cost =  204.30899855716973
# RUN  8 , total integrated cost =  204.30853671654552
# RUN  9 , total integrated cost =  204.30788346598652
# RUN  10 , total integrated cost =  204.30743964100694
# RUN  11 , total integrated cost =  204.3068477293467
# RUN  12 , total integrated cost =  204.3063859103946
# RUN  13 , total integrated cost =  204.30573289190718
# RUN  14 , total integrated cost =  204.3052891650232
# RUN  15 , total integrated cost =  204.3046973589861
# RUN  16 , total integrated cost =  204.30423566169657
# RUN  17 , total integrated cost =  204.30358274477555
# RUN  18 , total integrated cost =  204.30313913467046
# RUN  19 , total integrated cost =  204.3025474053795
# RUN  20 , total integrated cost =  204.3020858500008
# RUN  30 , total integrated cost =  204.2966914818794
# RUN  30 , total integrated cost =  204.2966914818794
# Improved over  30  iterations in  16.155922011006624  seconds by  0.007908790652209063  percent.
# cost splitting :  0.03439696463050858 [0.        3.3093162]
# set cost params:  0.05 0.0 24.522838145383993
# interpolate adjoint :  True True True
# initial cost =  81.1555454607088
# RUN  0 , total integrated cost =  81.1555454607088
# Gradient descend method:  None
# RUN  1 , total integrated cost =  81.1553081952013
# RUN  2 , total integrated cost =  81.1549943235307
# RUN  3 , total integrated cost =  81.15475862884767
# RUN  4 , total integrated cost =  81.15444189215061
# RUN  5 , total integrated cost =  81.1542087799744
# RUN  6 , total integrated cost =  81.15388746453753
# RUN  7 , total integrated cost =  81.15365844296329
# RUN  8 , total integrated cost =  81.15332726825044
# RUN  9 , total integrated cost =  81.15308387532208
# RUN  10 , total integrated cost =  81.15278083386414
# RUN  11 , total integrated cost =  81.15255794638543
# RUN  12 , total integrated cost =  81.15226977382149
# RUN  13 , total integrated cost =  81.15205306901233
# RUN  14 , total integrated cost =  81.15175479101228
# RUN  15 , total integrated cost =  81.15152819009491
# RUN  16 , total integrated cost =  81.15119169790202
# RUN  17 , total integrated cost =  81.15095280996672
# RUN  18 , total integrated cost =  81.15064316577524
# RUN  19 , total integrated cost =  81.1504045020545
# RUN  20 , total integrated cost =  81.1500945046079
# RUN  30 , total integrated cost =  81.14734020200929
# RUN  30 , total integrated cost =  81.14734020200929
# Improved over  30  iterations in  14.265125352016184  seconds by  0.010110533609164918  percent.
# cost splitting :  0.0353578456048076 [0.         3.30897965]
# set cost params:  0.05 0.0 51.809694728759276
# interpolate adjoint :  True True True
# initial cost =  171.43899326698178
# RUN  0 , total integrated cost =  171.43899326698178
# Gradient descend method:  None
# RUN  1 , total integrated cost =  171.438413544594
# RUN  2 , total integrated cost =  171.4379797806983
# RUN  3 , total integrated cost =  171.43735446432055
# RUN  4 , total integrated cost =  171.4369060395701
# RUN  5 , total integrated cost =  171.4363146070519
# RUN  6 , total integrated cost =  171.4358911438938
# RUN  7 , total integrated cost =  171.43534333696968
# RUN  8 , total integrated cost =  171.4349327378275
# RUN  9 , total integrated cost =  171.43436091986575
# RUN  10 , total integrated cost =  171.43392045488557
# RUN  11 , total integrated cost =  171.43331230182443
# RUN  12 , total integrated cost =  171.43284964469407
# RUN  13 , total integrated cost =  171.43212083827996
# RUN  14 , total integrated cost =  171.4315881994058
# RUN  15 , total integrated cost =  171.43078098763596
# RUN  16 , total integrated cost =  171.43025770508854
# RUN  17 , total integrated cost =  171.42941108089903
# RUN  18 , total integrated cost =  171.42879779863594
# RUN  19 , total integrated cost =  171.42773050578012
# RUN  20 , total integrated cost =  171.42692895449912
# RUN  30 , total integrated cost =  171.41506929532653
# RUN  30 , total integrated cost =  171.41506929532653
# Improved over  30  iterations in  14.6230208039633  seconds by  0.013954801763205182  percent.
# cost splitting :  0.03854729239988204 [0.        3.3085148]
# set cost params:  0.05 0.0 4.785976218046398
# interpolate adjoint :  True True True
# initial cost =  15.83640052714155
# RUN  0 , total integrated cost =  15.83640052714155
# Gradient descend method:  None
# RUN  1 , total integrated cost =  15.835212879136298
# RUN  2 , total integrated cost =  15.7928579417281
# RUN  3 , total integrated cost =  15.785794307859101
# RUN  4 , total integrated cost =  15.78542265523838
# RUN  5 , total integrated cost =  15.785188314818503
# RUN  6 , total integrated cost =  15.784806138029037
# RUN  7 , total integrated cost =  15.784582560843715
# RUN  8 , total integrated cost =  15.783854694785276
# RUN  9 , total integrated cost =  15.783464564019274
# RUN  10 , total integrated cost =  15.527234587055851
# RUN  11 , total integrated cost =  15.510736204072286
# RUN  12 , total integrated cost =  15.510687544283751
# RUN  13 , total integrated cost =  15.510649606177138
# RUN  14 , total integrated cost =  15.510598008138341
# RUN  15 , total integrated cost =  15.5105579585857
# RUN  16 , total integrated cost =  15.510510493764517
# RUN  17 , total integrated cost =  15.510471482856268
# RUN  18 , total integrated cost =  15.510422244098509
# RUN  19 , total integrated cost =  15.510384848446568
# RUN  20 , total integrated cost =  15.510340659509822
# RUN  30 , total integrated cost =  15.509939554335597
# RUN  30 , total integrated cost =  15.509939554335597
# Improved over  30  iterations in  14.11867490701843  seconds by  2.0614594348408986  percent.
# cost splitting :  0.006829075403054017 [0.         3.24063418]
# set cost params:  0.05 0.0 36.73334672254665
# interpolate adjoint :  True True True
# initial cost =  119.03968026351814
# RUN  0 , total integrated cost =  119.03968026351814
# Gradient descend method:  None
# RUN  1 , total integrated cost =  119.03798959873303
# RUN  2 , total integrated cost =  118.64191942298129
# RUN  3 , total integrated cost =  116.89179704054244
# RUN  4 , total integrated cost =  116.84780624974495
# RUN  5 , total integrated cost =  116.84761751029755
# RUN  6 , total integrated cost =  116.84743610473134
# RUN  7 , total integrated cost =  116.84728795090103
# RUN  8 , total integrated cost =  116.84710882391627
# RUN  9 , total integrated cost =  116.84695854814844
# RUN  10 , total integrated cost =  116.84678493141233
# RUN  11 , total integrated cost =  116.8466475508698
# RUN  12 , total integrated cost =  116.84643330165932
# RUN  13 , total integrated cost =  116.84626261415725
# RUN  14 , total integrated cost =  116.84612783092929
# RUN  15 , total integrated cost =  116.8460066688842
# RUN  16 , total integrated cost =  116.84588127043686
# RUN  17 , total integrated cost =  116.84576824846354
# RUN  18 , total integrated cost =  116.84562782639352
# RUN  19 , total integrated cost =  116.84551198475293
# RUN  20 , total integrated cost =  116.84537769546513
# RUN  30 , total integrated cost =  116.84400730787934
# RUN  30 , total integrated cost =  116.84400730787934
# Improved over  30  iterations in  17.60007515497273  seconds by  1.8444882838883956  percent.
# cost splitting :  0.04857654598839822 [0.         3.18080406]
# set cost params:  0.05 0.0 4.008692374168321
# interpolate adjoint :  True True True
# initial cost =  12.753293815961094
# RUN  0 , total integrated cost =  12.753293815961094
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12.751589950649608
# RUN  2 , total integrated cost =  12.751568961854282
# RUN  3 , total integrated cost =  12.751542477602573
# RUN  4 , total integrated cost =  12.751525936563606
# RUN  5 , total integrated cost =  12.751505497946255
# RUN  6 , total integrated cost =  12.751488179634439
# RUN  7 , total integrated cost =  12.751466836173373
# RUN  8 , total integrated cost =  12.751449779346657
# RUN  9 , total integrated cost =  12.751429925937375
# RUN  10 , total integrated cost =  12.751412423660142
# RUN  11 , total integrated cost =  12.751391297132784
# RUN  12 , total integrated cost =  12.751374206571516
# RUN  13 , total integrated cost =  12.751354406372371
# RUN  14 , total integrated cost =  12.751336952853746
# RUN  15 , total integrated cost =  12.751317557213632
# RUN  16 , total integrated cost =  12.751299937700688
# RUN  17 , total integrated cost =  12.751277184147519
# RUN  18 , total integrated cost =  12.751260441658294
# RUN  19 , total integrated cost =  12.751240283844401
# RUN  20 , total integrated cost =  12.751222946948051
# RUN  30 , total integrated cost =  12.751033854492912
# RUN  30 , total integrated cost =  12.751033854492912
# Improved over  30  iterations in  15.308859827986453  seconds by  0.017720610069787313  percent.
# cost splitting :  0.003700648014276836 [0.         3.18080003]
# set cost params:  0.05 0.0 62.326280985343466
# interpolate adjoint :  True True True
# initial cost =  198.24762143046863
# RUN  0 , total integrated cost =  198.24762143046863
# Gradient descend method:  None
# RUN  1 , total integrated cost =  198.24103936953261
# RUN  2 , total integrated cost =  198.2406334081138
# RUN  3 , total integrated cost =  198.24032191454555
# RUN  4 , total integrated cost =  198.23997869293956
# RUN  5 , total integrated cost =  198.23971301279232
# RUN  6 , total integrated cost =  198.23945008706858
# RUN  7 , total integrated cost =  198.23921200531225
# RUN  8 , total integrated cost =  198.23886205069718
# RUN  9 , total integrated cost =  198.2386029929016
# RUN  10 , total integrated cost =  198.23832274232464
# RUN  11 , total integrated cost =  198.2381017798335
# RUN  12 , total integrated cost =  198.2376648958203
# RUN  13 , total integrated cost =  198.2373309238712
# RUN  14 , total integrated cost =  198.23641395998027
# RUN  15 , total integrated cost =  198.2357379673475
# RUN  16 , total integrated cost =  198.23518584557877
# RUN  17 , total integrated cost =  198.23480339992327
# RUN  18 , total integrated cost =  198.2343461317159
# RUN  19 , total integrated cost =  198.2339789037321
# RUN  20 , total integrated cost =  198.23343003167778
# RUN  30 , total integrated cost =  198.22977934571622
# RUN  30 , total integrated cost =  198.22977934571622
# Improved over  30  iterations in  15.290524256997742  seconds by  0.008999898522702665  percent.
# cost splitting :  0.08293634450039324 [0.        3.1804502]
# set cost params:  0.05 0.0 25.736116120957625
# interpolate adjoint :  True True True
# initial cost =  81.85658235887395
# RUN  0 , total integrated cost =  81.85658235887395
# Gradient descend method:  None
# RUN  1 , total integrated cost =  81.854967822189
# RUN  2 , total integrated cost =  81.85435639637237
# RUN  3 , total integrated cost =  81.853893283955
# RUN  4 , total integrated cost =  81.85338318595889
# RUN  5 , total integrated cost =  81.85304416615504
# RUN  6 , total integrated cost =  81.85284349781638
# RUN  7 , total integrated cost =  81.85267988187023
# RUN  8 , total integrated cost =  81.85251887568126
# RUN  9 , total integrated cost =  81.85238911406293
# RUN  10 , total integrated cost =  81.85226792208263
# RUN  11 , total integrated cost =  81.85217042120726
# RUN  12 , total integrated cost =  81.85205048946543
# RUN  13 , total integrated cost =  81.85195182786833
# RUN  14 , total integrated cost =  81.85183472227102
# RUN  15 , total integrated cost =  81.85173341400969
# RUN  16 , total integrated cost =  81.85162197998476
# RUN  17 , total integrated cost =  81.85153252412815
# RUN  18 , total integrated cost =  81.85143984843286
# RUN  19 , total integrated cost =  81.85135758997794
# RUN  20 , total integrated cost =  81.85125158782853
# RUN  30 , total integrated cost =  81.84850364870546
# RUN  30 , total integrated cost =  81.84850364870546
# Improved over  30  iterations in  13.83674790902296  seconds by  0.009869347016064012  percent.
# cost splitting :  0.054225545397233316 [0.         3.18019207]
# set cost params:  0.05 0.0 12.292359085109217
# interpolate adjoint :  True True True
# initial cost =  39.09477414745959
# RUN  0 , total integrated cost =  39.09477414745959
# Gradient descend method:  None
# RUN  1 , total integrated cost =  39.09353824728235
# RUN  2 , total integrated cost =  39.09340844668572
# RUN  3 , total integrated cost =  39.09323623675564
# RUN  4 , total integrated cost =  39.092713183059814
# RUN  5 , total integrated cost =  39.09125977905659
# RUN  6 , total integrated cost =  39.091168848592034
# RUN  7 , total integrated cost =  39.09109162502448
# RUN  8 , total integrated cost =  39.09109162502448
# Control only changes marginally.
# RUN  8 , total integrated cost =  39.09109162502448
# Improved over  8  iterations in  4.456414685992058  seconds by  0.009419474892510493  percent.
# cost splitting :  0.012608676696284791 [0.         3.18006177]
# set cost params:  0.05 0.0 23.194119108866456
# interpolate adjoint :  True True True
# initial cost =  73.75936190363869
# RUN  0 , total integrated cost =  73.75936190363869
# Gradient descend method:  None
# RUN  1 , total integrated cost =  73.75911675291569
# RUN  2 , total integrated cost =  73.7588181256089
# RUN  3 , total integrated cost =  73.75833577396732
# RUN  4 , total integrated cost =  73.75763013688355
# RUN  5 , total integrated cost =  73.75607239487736
# RUN  6 , total integrated cost =  73.7556346153586
# RUN  7 , total integrated cost =  73.75532817990918
# RUN  8 , total integrated cost =  73.75495157283743
# RUN  9 , total integrated cost =  73.75464481767263
# RUN  10 , total integrated cost =  73.75427249295167
# RUN  11 , total integrated cost =  73.7540216255283
# RUN  12 , total integrated cost =  73.75388348372705
# RUN  13 , total integrated cost =  73.75377009678759
# RUN  14 , total integrated cost =  73.75356233003214
# RUN  15 , total integrated cost =  73.75338615475808
# RUN  16 , total integrated cost =  73.75324043991989
# RUN  17 , total integrated cost =  73.75312011920907
# RUN  18 , total integrated cost =  73.75294859077846
# RUN  19 , total integrated cost =  73.75279557801953
# RUN  20 , total integrated cost =  73.75254319977223
# Control only changes marginally.
# RUN  27 , total integrated cost =  72.78484169825376
# Improved over  27  iterations in  13.727348158019595  seconds by  1.3212156128168147  percent.
# cost splitting :  0.021563779002511774 [0.         3.13802663]
# set cost params:  0.05 0.0 26.962199329235684
# interpolate adjoint :  True True True
# initial cost =  84.60917778776701
# RUN  0 , total integrated cost =  84.60917778776701
# Gradient descend method:  None
# RUN  1 , total integrated cost =  84.6091318834969
# RUN  2 , total integrated cost =  84.60911910379232
# RUN  3 , total integrated cost =  84.60910565044061
# RUN  4 , total integrated cost =  84.60910565044061
# Control only changes marginally.
# RUN  4 , total integrated cost =  84.60910565044061
# Improved over  4  iterations in  1.9385809329687618  seconds by  8.52594579896504e-05  percent.
# cost splitting :  0.027704955564340984 [0.         3.13801257]
# set cost params:  0.05 0.0 25.182920479604963
# interpolate adjoint :  True True True
# initial cost =  79.02570625524764
# RUN  0 , total integrated cost =  79.02570625524764
# Gradient descend method:  None
# RUN  1 , total integrated cost =  79.02570625524764
# Control only changes marginally.
# RUN  1 , total integrated cost =  79.02570625524764
# Improved over  1  iterations in  0.7022240640362725  seconds by  0.0  percent.
# cost splitting :  0.027704955564340984 [0.         3.13801257]
# -------  10 0.4250000000000001 0.42500000000000016
# set cost params:  0.05 0.0 97.01824198496317
# interpolate adjoint :  True True True
# initial cost =  249.68043593678985
# RUN  0 , total integrated cost =  249.68043593678985
# Gradient descend method:  None
# RUN  1 , total integrated cost =  249.68043593678985
# Control only changes marginally.
# RUN  1 , total integrated cost =  249.68043593678985
# Improved over  1  iterations in  0.7215682769892737  seconds by  0.0  percent.
# cost splitting :  2.6687495670093112e-05 [0.         2.57354111]
# -------  11 0.4500000000000001 0.42500000000000016
# set cost params:  0.05 0.0 191.7907669823601
# interpolate adjoint :  True True True
# initial cost =  466.13517821977797
# RUN  0 , total integrated cost =  466.13517821977797
# Gradient descend method:  None
# RUN  1 , total integrated cost =  411.56848515229615
# RUN  2 , total integrated cost =  353.19591704975943
# RUN  3 , total integrated cost =  351.2577653744809
# RUN  4 , total integrated cost =  351.2506398169352
# RUN  5 , total integrated cost =  351.2506398169352
# Control only changes marginally.
# RUN  5 , total integrated cost =  351.2506398169352
# Improved over  5  iterations in  2.8328938839840703  seconds by  24.646185006160565  percent.
# cost splitting :  2.065494593010774e-09 [0.         1.83142622]
# set cost params:  0.05 0.0 261.4540179700752
# interpolate adjoint :  True True True
# initial cost =  478.83374439571827
# RUN  0 , total integrated cost =  478.83374439571827
# Gradient descend method:  None
# RUN  1 , total integrated cost =  478.83374439571827
# Control only changes marginally.
# RUN  1 , total integrated cost =  478.83374439571827
# Improved over  1  iterations in  0.6875102409976535  seconds by  0.0  percent.
# cost splitting :  2.065494593010774e-09 [0.         1.83142622]
# -------  12 0.47500000000000014 0.42500000000000016
# set cost params:  0.05 0.0 400.52289300889123
# interpolate adjoint :  True True True
# initial cost =  560.6664095478051
# RUN  0 , total integrated cost =  560.6664095478051
# Gradient descend method:  None
# RUN  1 , total integrated cost =  560.6664095478051
# Control only changes marginally.
# RUN  1 , total integrated cost =  560.6664095478051
# Improved over  1  iterations in  0.7432407810119912  seconds by  0.0  percent.
# cost splitting :  1.6235249369724336e-05 [0.         1.39983611]
# -------  13 0.4000000000000001 0.4500000000000002
# set cost params:  0.05 0.0 22.04618112256755
# interpolate adjoint :  True True True
# initial cost =  92.04944891500593
# RUN  0 , total integrated cost =  92.04944891500593
# Gradient descend method:  None
# RUN  1 , total integrated cost =  92.04786476720254
# RUN  2 , total integrated cost =  92.04697588653693
# RUN  3 , total integrated cost =  92.04564489810235
# RUN  4 , total integrated cost =  92.0441360723482
# RUN  5 , total integrated cost =  92.04164710330402
# RUN  6 , total integrated cost =  92.04082646999892
# RUN  7 , total integrated cost =  92.03958727444348
# RUN  8 , total integrated cost =  92.0384244584456
# RUN  9 , total integrated cost =  92.03656663461588
# RUN  10 , total integrated cost =  92.03445107998317
# RUN  11 , total integrated cost =  92.03030671468889
# RUN  12 , total integrated cost =  91.98391856381883
# RUN  13 , total integrated cost =  91.96643243995729
# RUN  14 , total integrated cost =  90.51414780159745
# RUN  15 , total integrated cost =  88.73396688682342
# RUN  16 , total integrated cost =  88.72058328978322
# RUN  17 , total integrated cost =  88.72047872398788
# RUN  18 , total integrated cost =  88.72038637142681
# RUN  19 , total integrated cost =  88.72028822356798
# RUN  20 , total integrated cost =  88.7201982190541
# RUN  30 , total integrated cost =  88.71924069627897
# RUN  30 , total integrated cost =  88.71924069627897
# Improved over  30  iterations in  16.31008186697727  seconds by  3.6178469920030807  percent.
# cost splitting :  0.07401491813225962 [0.         4.02407743]
# set cost params:  0.05 0.0 36.304757476025046
# interpolate adjoint :  True True True
# initial cost =  146.09685603418984
# RUN  0 , total integrated cost =  146.09685603418984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  146.09601470132628
# RUN  2 , total integrated cost =  146.09574681834945
# RUN  3 , total integrated cost =  146.09542134247846
# RUN  4 , total integrated cost =  146.0951641192478
# RUN  5 , total integrated cost =  146.09483597547282
# RUN  6 , total integrated cost =  146.09457768577542
# RUN  7 , total integrated cost =  146.0942510090483
# RUN  8 , total integrated cost =  146.09399369827958
# RUN  9 , total integrated cost =  146.09366637062607
# RUN  10 , total integrated cost =  146.09340895629117
# RUN  11 , total integrated cost =  146.09308210346737
# RUN  12 , total integrated cost =  146.09282537318055
# RUN  13 , total integrated cost =  146.09249817718387
# RUN  14 , total integrated cost =  146.0922417160667
# RUN  15 , total integrated cost =  146.0919146049623
# RUN  16 , total integrated cost =  146.09165784687443
# RUN  17 , total integrated cost =  146.09135520223091
# RUN  18 , total integrated cost =  146.09110760868083
# RUN  19 , total integrated cost =  146.09082735839047
# RUN  20 , total integrated cost =  146.09058513633522
# RUN  30 , total integrated cost =  146.08794891995205
# RUN  30 , total integrated cost =  146.08794891995205
# Improved over  30  iterations in  17.33730090694735  seconds by  0.006096718628697317  percent.
# cost splitting :  0.09422534971430004 [0.         4.02380426]
# set cost params:  0.05 0.0 35.71155335675959
# interpolate adjoint :  True True True
# initial cost =  143.70101166005426
# RUN  0 , total integrated cost =  143.70101166005426
# Gradient descend method:  None
# RUN  1 , total integrated cost =  143.70075343901271
# RUN  2 , total integrated cost =  143.70045304981068
# RUN  3 , total integrated cost =  143.70012235451776
# RUN  4 , total integrated cost =  143.69977178215188
# RUN  5 , total integrated cost =  143.69937000517544
# RUN  6 , total integrated cost =  143.69889800451398
# RUN  7 , total integrated cost =  143.6983138471665
# RUN  8 , total integrated cost =  143.6929112272192
# RUN  9 , total integrated cost =  143.6729620460775
# RUN  10 , total integrated cost =  143.6728387681611
# RUN  11 , total integrated cost =  143.67269879659983
# RUN  12 , total integrated cost =  143.67257937381532
# RUN  13 , total integrated cost =  143.6724456570232
# RUN  14 , total integrated cost =  143.6723313015559
# RUN  15 , total integrated cost =  143.6722008221936
# RUN  16 , total integrated cost =  143.6720883489458
# RUN  17 , total integrated cost =  143.67196054713065
# RUN  18 , total integrated cost =  143.67184703157514
# RUN  19 , total integrated cost =  143.67171523763707
# RUN  20 , total integrated cost =  143.67159981807094
# RUN  30 , total integrated cost =  143.67038579124502
# RUN  30 , total integrated cost =  143.67038579124502
# Improved over  30  iterations in  16.557547012984287  seconds by  0.021312215171931825  percent.
# cost splitting :  0.10690436816937789 [0.         4.02292891]
# set cost params:  0.05 0.0 35.78938131620422
# interpolate adjoint :  True True True
# initial cost =  143.98348213963442
# RUN  0 , total integrated cost =  143.98348213963442
# Gradient descend method:  None
# RUN  1 , total integrated cost =  143.98335239640588
# RUN  2 , total integrated cost =  143.98323978999062
# RUN  3 , total integrated cost =  143.9831122510518
# RUN  4 , total integrated cost =  143.98299870935134
# RUN  5 , total integrated cost =  143.98287182235512
# RUN  6 , total integrated cost =  143.98275868219446
# RUN  7 , total integrated cost =  143.98263126115447
# RUN  8 , total integrated cost =  143.98251902141283
# RUN  9 , total integrated cost =  143.98239146993302
# RUN  10 , total integrated cost =  143.9822780630349
# RUN  11 , total integrated cost =  143.98215132487138
# RUN  12 , total integrated cost =  143.98203818980133
# RUN  13 , total integrated cost =  143.98191091841912
# RUN  14 , total integrated cost =  143.98179849147468
# RUN  15 , total integrated cost =  143.98167175935822
# RUN  16 , total integrated cost =  143.98155880207713
# RUN  17 , total integrated cost =  143.9814315350227
# RUN  18 , total integrated cost =  143.98131956709761
# RUN  19 , total integrated cost =  143.98119158844472
# RUN  20 , total integrated cost =  143.98107858400056
# RUN  30 , total integrated cost =  143.97988160816104
# RUN  30 , total integrated cost =  143.97988160816104
# Improved over  30  iterations in  17.2567501940066  seconds by  0.002500655922389683  percent.
# cost splitting :  0.10928264005473713 [0.         4.02282499]
# set cost params:  0.05 0.0 46.98299482423711
# interpolate adjoint :  True True True
# initial cost =  189.00982973812822
# RUN  0 , total integrated cost =  189.00982973812822
# Gradient descend method:  None
# RUN  1 , total integrated cost =  189.00933443433496
# RUN  2 , total integrated cost =  189.00894576001662
# RUN  3 , total integrated cost =  189.0084732773816
# RUN  4 , total integrated cost =  189.008108969433
# RUN  5 , total integrated cost =  189.00766342466605
# RUN  6 , total integrated cost =  189.00732242680817
# RUN  7 , total integrated cost =  189.00690470784485
# RUN  8 , total integrated cost =  189.00658256868874
# RUN  9 , total integrated cost =  189.0061970495874
# RUN  10 , total integrated cost =  189.0058915043649
# RUN  11 , total integrated cost =  189.0055402927333
# RUN  12 , total integrated cost =  189.0052476106398
# RUN  13 , total integrated cost =  189.00488348652695
# RUN  14 , total integrated cost =  189.00458675031717
# RUN  15 , total integrated cost =  189.00422719729178
# RUN  16 , total integrated cost =  189.00393218151282
# RUN  17 , total integrated cost =  189.0035712202763
# RUN  18 , total integrated cost =  189.00327592499232
# RUN  19 , total integrated cost =  189.00291562535062
# RUN  20 , total integrated cost =  189.00262077957922
# RUN  30 , total integrated cost =  188.999349526914
# RUN  30 , total integrated cost =  188.999349526914
# Improved over  30  iterations in  17.103374613972846  seconds by  0.005544796918101724  percent.
# cost splitting :  0.11590630302190962 [0.         4.02259488]
# set cost params:  0.05 0.0 15.70094337326871
# interpolate adjoint :  True True True
# initial cost =  63.16432966768878
# RUN  0 , total integrated cost =  63.16432966768878
# Gradient descend method:  None
# RUN  1 , total integrated cost =  63.16336455296989
# RUN  2 , total integrated cost =  63.16225458928926
# RUN  3 , total integrated cost =  63.16043676602505
# RUN  4 , total integrated cost =  63.160198821819854
# RUN  5 , total integrated cost =  63.16000939855899
# RUN  6 , total integrated cost =  63.15987866587543
# RUN  7 , total integrated cost =  63.15975673515025
# RUN  8 , total integrated cost =  63.159638928801414
# RUN  9 , total integrated cost =  63.15952557558935
# RUN  10 , total integrated cost =  63.159390895234125
# RUN  11 , total integrated cost =  63.15927308690128
# RUN  12 , total integrated cost =  63.15914792522673
# RUN  13 , total integrated cost =  63.15904206674231
# RUN  14 , total integrated cost =  63.158888611819194
# RUN  15 , total integrated cost =  63.15874700652654
# RUN  16 , total integrated cost =  63.158462286554325
# RUN  17 , total integrated cost =  63.15823372901666
# RUN  18 , total integrated cost =  63.15751896617115
# RUN  19 , total integrated cost =  63.15697367004376
# RUN  20 , total integrated cost =  63.15680754365232
# RUN  30 , total integrated cost =  63.15536398288046
# RUN  30 , total integrated cost =  63.15536398288046
# Improved over  30  iterations in  13.125215900014155  seconds by  0.014194221414982167  percent.
# cost splitting :  0.07534008454032591 [0.         4.02215303]
# set cost params:  0.05 0.0 34.430256601351054
# interpolate adjoint :  True True True
# initial cost =  138.4875279521197
# RUN  0 , total integrated cost =  138.4875279521197
# Gradient descend method:  None
# RUN  1 , total integrated cost =  138.48688655400096
# RUN  2 , total integrated cost =  138.4862087323546
# RUN  3 , total integrated cost =  138.4853252632356
# RUN  4 , total integrated cost =  138.4851024591086
# RUN  5 , total integrated cost =  138.48482670793365
# RUN  6 , total integrated cost =  138.48465942179877
# RUN  7 , total integrated cost =  138.48445743133465
# RUN  8 , total integrated cost =  138.48428518380993
# RUN  9 , total integrated cost =  138.484088543639
# RUN  10 , total integrated cost =  138.48391497185693
# RUN  11 , total integrated cost =  138.48371988078665
# RUN  12 , total integrated cost =  138.48354601114963
# RUN  13 , total integrated cost =  138.48335139828993
# RUN  14 , total integrated cost =  138.48317755229664
# RUN  15 , total integrated cost =  138.48298310302016
# RUN  16 , total integrated cost =  138.4828093776368
# RUN  17 , total integrated cost =  138.48261495601838
# RUN  18 , total integrated cost =  138.48244135560336
# RUN  19 , total integrated cost =  138.48224696154676
# RUN  20 , total integrated cost =  138.4820734735921
# ...
# RUN  0 , total integrated cost =  141.7575650257649
# Gradient descend method:  None
# RUN  1 , total integrated cost =  141.7575650257649
# Control only changes marginally.
# RUN  1 , total integrated cost =  141.7575650257649
# Improved over  1  iterations in  0.5046356549719349  seconds by  0.0  percent.
# cost splitting :  5.294707740142009e-06 [ 0.        11.3900446]
# -------  72 0.5000000000000002 0.6750000000000004
# set cost params:  0.05 0.0 39.001425542440884
# interpolate adjoint :  True True True
# initial cost =  404.39038204475776
# RUN  0 , total integrated cost =  404.39038204475776
# Gradient descend method:  None
# RUN  1 , total integrated cost =  296.46255032904804
# RUN  2 , total integrated cost =  268.23880740255873
# RUN  3 , total integrated cost =  267.35681543670694
# RUN  4 , total integrated cost =  267.35409547790954
# RUN  5 , total integrated cost =  267.35409547790954
# Control only changes marginally.
# RUN  5 , total integrated cost =  267.35409547790954
# Improved over  5  iterations in  2.3271724049700424  seconds by  33.88712804541457  percent.
# cost splitting :  0.0003866661910776629 [3.95600159 2.89898057]
# set cost params:  0.05 0.0 91.29936137348
# interpolate adjoint :  True True True
# initial cost =  625.8555123853997
# RUN  0 , total integrated cost =  625.8555123853997
# Gradient descend method:  None
# RUN  1 , total integrated cost =  625.8555123853997
# Control only changes marginally.
# RUN  1 , total integrated cost =  625.8555123853997
# Improved over  1  iterations in  0.7007688130252063  seconds by  0.0  percent.
# cost splitting :  0.0003866661910776629 [3.95600159 2.89898057]
# -------  73 0.5250000000000001 0.6750000000000004
# set cost params:  0.05 0.0 90.19895284348064
# interpolate adjoint :  True True True
# initial cost =  827.9509330739701
# RUN  0 , total integrated cost =  827.9509330739701
# Gradient descend method:  None
# RUN  1 , total integrated cost =  827.9509330739701
# Control only changes marginally.
# RUN  1 , total integrated cost =  827.9509330739701
# Improved over  1  iterations in  0.6087335519259796  seconds by  0.0  percent.
# cost splitting :  2.965085442300826e-05 [0.         9.17916345]
# -------  74 0.5500000000000003 0.6750000000000004
# set cost params:  0.05 0.0 138.08042271127687
# interpolate adjoint :  True True True
# initial cost =  1056.3289561995066
# RUN  0 , total integrated cost =  1056.3289561995066
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1056.3289561995066
# Control only changes marginally.
# RUN  1 , total integrated cost =  1056.3289561995066
# Improved over  1  iterations in  0.5263332189060748  seconds by  0.0  percent.
# cost splitting :  7.01283520840961e-06 [0.         7.65009938]
# -------  75 0.5750000000000002 0.6750000000000004
# set cost params:  0.05 0.0 214.51465465644938
# interpolate adjoint :  True True True
# initial cost =  1140.9199965337943
# RUN  0 , total integrated cost =  1140.9199965337943
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1140.9199965337943
# Control only changes marginally.
# RUN  1 , total integrated cost =  1140.9199965337943
# Improved over  1  iterations in  0.6995059320470318  seconds by  0.0  percent.
# cost splitting :  0.00026058585110192995 [0.         5.31861091]
# -------  76 0.4250000000000001 0.7000000000000004
# set cost params:  0.05 0.0 16.532760820085805
# interpolate adjoint :  True True True
# initial cost =  235.05158670835382
# RUN  0 , total integrated cost =  235.05158670835382
# Gradient descend method:  None
# RUN  1 , total integrated cost =  235.0513861112937
# RUN  2 , total integrated cost =  235.05130748762699
# RUN  3 , total integrated cost =  235.0511024249756
# RUN  4 , total integrated cost =  235.0510273639449
# RUN  5 , total integrated cost =  235.0508540257232
# RUN  6 , total integrated cost =  235.05077513371262
# RUN  7 , total integrated cost =  235.05057090520245
# RUN  8 , total integrated cost =  235.0504961430015
# RUN  9 , total integrated cost =  235.05032169445562
# RUN  10 , total integrated cost =  235.05024209700582
# RUN  11 , total integrated cost =  235.0500247247438
# RUN  12 , total integrated cost =  235.0499389422465
# RUN  13 , total integrated cost =  235.0496761217656
# RUN  14 , total integrated cost =  234.99387142958017
# RUN  15 , total integrated cost =  230.45613015435669
# RUN  16 , total integrated cost =  230.2392551989463
# RUN  17 , total integrated cost =  230.23847810423067
# RUN  18 , total integrated cost =  230.23841394085113
# RUN  19 , total integrated cost =  230.23827194010636
# RUN  20 , total integrated cost =  230.23820692705038
# RUN  30 , total integrated cost =  230.2371611142142
# RUN  30 , total integrated cost =  230.2371611142142
# Improved over  30  iterations in  13.981298662023619  seconds by  2.048242116362843  percent.
# cost splitting :  0.0007445164124069054 [3.66224676e-06 1.39261111e+01]
# set cost params:  0.05 0.0 10.55135146432055
# interpolate adjoint :  True True True
# initial cost =  146.9393682133807
# RUN  0 , total integrated cost =  146.9393682133807
# Gradient descend method:  None
# RUN  1 , total integrated cost =  146.93928049773953
# RUN  2 , total integrated cost =  146.9392332907396
# RUN  3 , total integrated cost =  146.9391413294889
# RUN  4 , total integrated cost =  146.9391413294889
# Control only changes marginally.
# RUN  4 , total integrated cost =  146.9391413294889
# Improved over  4  iterations in  1.857710056938231  seconds by  0.00015440647020170672  percent.
# cost splitting :  0.0026183612446191587 [3.66224676e-06 1.39260807e+01]
# set cost params:  0.05 0.0 4.749277232721413
# interpolate adjoint :  True True True
# initial cost =  66.13896622322675
# RUN  0 , total integrated cost =  66.13896622322675
# Gradient descend method:  None
# RUN  1 , total integrated cost =  66.13889583918598
# RUN  2 , total integrated cost =  66.13871141164478
# RUN  3 , total integrated cost =  66.13863812251962
# RUN  4 , total integrated cost =  66.13851448994969
# RUN  5 , total integrated cost =  66.1384627594686
# RUN  6 , total integrated cost =  66.13831703499874
# RUN  7 , total integrated cost =  66.13825853877869
# RUN  8 , total integrated cost =  66.13805095527563
# RUN  9 , total integrated cost =  66.13796509883417
# RUN  10 , total integrated cost =  66.13779669517126
# RUN  11 , total integrated cost =  66.13772534445656
# RUN  12 , total integrated cost =  66.13756674562954
# RUN  13 , total integrated cost =  66.13750331540228
# RUN  14 , total integrated cost =  66.13740033413143
# RUN  15 , total integrated cost =  66.13735238989291
# RUN  16 , total integrated cost =  66.13725725855545
# RUN  17 , total integrated cost =  66.13721039033442
# RUN  18 , total integrated cost =  66.13710324974102
# RUN  19 , total integrated cost =  66.13705919242585
# RUN  20 , total integrated cost =  66.13698086605375
# RUN  30 , total integrated cost =  66.1362715565642
# RUN  30 , total integrated cost =  66.1362715565642
# Improved over  30  iterations in  12.4572963550454  seconds by  0.004074249744775216  percent.
# cost splitting :  0.002021407671602851 [3.66224676e-06 1.39255196e+01]
# set cost params:  0.05 0.0 6.959614661826088
# interpolate adjoint :  True True True
# initial cost =  96.91637679785953
# RUN  0 , total integrated cost =  96.91637679785953
# Gradient descend method:  None
# RUN  1 , total integrated cost =  96.91633645227606
# RUN  2 , total integrated cost =  96.91626449293896
# RUN  3 , total integrated cost =  96.91622556394118
# RUN  4 , total integrated cost =  96.9161481316402
# RUN  5 , total integrated cost =  96.91610621115973
# RUN  6 , total integrated cost =  96.91602060945115
# RUN  7 , total integrated cost =  96.91597775951234
# RUN  8 , total integrated cost =  96.91589706166182
# RUN  9 , total integrated cost =  96.91585786184639
# RUN  10 , total integrated cost =  96.91578165973289
# RUN  11 , total integrated cost =  96.91574391170124
# RUN  12 , total integrated cost =  96.91567545623114
# RUN  13 , total integrated cost =  96.91567545623114
# Control only changes marginally.
# RUN  13 , total integrated cost =  96.91567545623114
# Improved over  13  iterations in  6.215094469953328  seconds by  0.0007236564671018186  percent.
# cost splitting :  0.0017976652634098084 [3.66224676e-06 1.39254204e+01]
# set cost params:  0.05 0.0 4.786847056448393
# interpolate adjoint :  True True True
# initial cost =  66.65896513228581
# RUN  0 , total integrated cost =  66.65896513228581
# Gradient descend method:  None
# RUN  1 , total integrated cost =  66.65892617181574
# RUN  2 , total integrated cost =  66.65884723132777
# RUN  3 , total integrated cost =  66.65880843966757
# RUN  4 , total integrated cost =  66.65872825192183
# RUN  5 , total integrated cost =  66.65869059216158
# RUN  6 , total integrated cost =  66.65859986720425
# RUN  7 , total integrated cost =  66.65855535628626
# RUN  8 , total integrated cost =  66.65848195169934
# RUN  9 , total integrated cost =  66.65848195169934
# Control only changes marginally.
# RUN  9 , total integrated cost =  66.65848195169934
# Improved over  9  iterations in  4.837406735052355  seconds by  0.0007248546170899317  percent.
# cost splitting :  0.0016988669442781958 [3.66224676e-06 1.39253205e+01]
# set cost params:  0.05 0.0 21.49195709876364
# interpolate adjoint :  True True True
# initial cost =  299.2825545693544
# RUN  0 , total integrated cost =  299.2825545693544
# Gradient descend method:  None
# RUN  1 , total integrated cost =  299.28203148173566
# RUN  2 , total integrated cost =  299.2818003003386
# RUN  3 , total integrated cost =  299.2792306774224
# RUN  4 , total integrated cost =  299.2785733676936
# RUN  5 , total integrated cost =  299.2784800343188
# RUN  6 , total integrated cost =  299.2782746362165
# RUN  7 , total integrated cost =  299.26593849890753
# RUN  8 , total integrated cost =  299.2634554382463
# RUN  9 , total integrated cost =  299.26125775494523
# RUN  10 , total integrated cost =  299.26067074067544
# RUN  11 , total integrated cost =  299.2589359598857
# RUN  12 , total integrated cost =  299.25844091480394
# RUN  13 , total integrated cost =  294.88172218548044
# RUN  14 , total integrated cost =  294.87047794248457
# RUN  15 , total integrated cost =  294.87047794248457
# Control only changes marginally.
# RUN  15 , total integrated cost =  294.87047794248457
# Improved over  15  iterations in  7.986999173997901  seconds by  1.474217778319371  percent.
# cost splitting :  0.004178368854673178 [5.33672893e-07 1.37200282e+01]
# set cost params:  0.05 0.0 14.533938224540458
# interpolate adjoint :  True True True
# initial cost =  199.4062590308165
# RUN  0 , total integrated cost =  199.4062590308165
# Gradient descend method:  None
# RUN  1 , total integrated cost =  199.4062590308165
# Control only changes marginally.
# RUN  1 , total integrated cost =  199.4062590308165
# Improved over  1  iterations in  0.7037616419838741  seconds by  0.0  percent.
# cost splitting :  0.004178368854673178 [5.33672893e-07 1.37200282e+01]
# -------  77 0.4500000000000001 0.7000000000000004
# set cost params:  0.05 0.0 23.707391651292895
# interpolate adjoint :  True True True
# initial cost =  315.4706952964536
# RUN  0 , total integrated cost =  315.4706952964536
# Gradient descend method:  None
# RUN  1 , total integrated cost =  315.4706952964536
# Control only changes marginally.
# RUN  1 , total integrated cost =  315.4706952964536
# Improved over  1  iterations in  0.4721802369458601  seconds by  0.0  percent.
# cost splitting :  4.300275660459489e-06 [ 0.        13.3068496]
# -------  78 0.47500000000000014 0.7000000000000004
# set cost params:  0.05 0.0 29.230767517977085
# interpolate adjoint :  True True True
# initial cost =  361.6724674491692
# RUN  0 , total integrated cost =  361.6724674491692
# Gradient descend method:  None
# RUN  1 , total integrated cost =  361.6724674491692
# Control only changes marginally.
# RUN  1 , total integrated cost =  361.6724674491692
# Improved over  1  iterations in  0.4734356920234859  seconds by  0.0  percent.
# cost splitting :  1.3564470485779192e-06 [ 0.         12.37300619]
# -------  79 0.5000000000000002 0.7000000000000004
# set cost params:  0.05 0.0 33.36131138267902
# interpolate adjoint :  True True True
# initial cost =  378.89156853082574
# RUN  0 , total integrated cost =  378.89156853082574
# Gradient descend method:  None
# RUN  1 , total integrated cost =  361.8090226778051
# RUN  2 , total integrated cost =  279.2052536222518
# RUN  3 , total integrated cost =  279.17341109207774
# RUN  4 , total integrated cost =  279.17341109207774
# Control only changes marginally.
# RUN  4 , total integrated cost =  279.17341109207774
# Improved over  4  iterations in  2.2201423320220783  seconds by  26.318389143736027  percent.
# cost splitting :  0.0002974569658250036 [3.70032451 4.66785361]
# set cost params:  0.05 0.0 98.90997753178358
# interpolate adjoint :  True True True
# initial cost =  827.6963254517008
# RUN  0 , total integrated cost =  827.6963254517008
# Gradient descend method:  None
# RUN  1 , total integrated cost =  827.6945719399221
# RUN  2 , total integrated cost =  827.6945719399221
# Control only changes marginally.
# RUN  2 , total integrated cost =  827.6945719399221
# Improved over  2  iterations in  1.471250168979168  seconds by  0.00021185448392202488  percent.
# cost splitting :  0.00021461259202876123 [3.70032451 4.66783593]
# set cost params:  0.05 0.0 74.68338319244423
# interpolate adjoint :  True True True
# initial cost =  624.9625435674409
# RUN  0 , total integrated cost =  624.9625435674409
# Gradient descend method:  None
# RUN  1 , total integrated cost =  624.9625435674409
# Control only changes marginally.
# RUN  1 , total integrated cost =  624.9625435674409
# Improved over  1  iterations in  0.5561333219520748  seconds by  0.0  percent.
# cost splitting :  0.00021461259202876123 [3.70032451 4.66783593]
# -------  80 0.5250000000000001 0.7000000000000004
# set cost params:  0.05 0.0 67.67688347182406
# interpolate adjoint :  True True True
# initial cost =  688.7944561792527
# RUN  0 , total integrated cost =  688.7944561792527
# Gradient descend method:  None
# RUN  1 , total integrated cost =  688.7944561792527
# Control only changes marginally.
# RUN  1 , total integrated cost =  688.7944561792527
# Improved over  1  iterations in  0.5860048069152981  seconds by  0.0  percent.
# cost splitting :  1.0868591557279247e-06 [ 0.         10.17769171]
# -------  81 0.5500000000000003 0.7000000000000004
# set cost params:  0.05 0.0 142.77712893917857
# interpolate adjoint :  True True True
# initial cost =  1237.7455474782655
# RUN  0 , total integrated cost =  1237.7455474782655
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1237.7455474782655
# Control only changes marginally.
# RUN  1 , total integrated cost =  1237.7455474782655
# Improved over  1  iterations in  0.71845680300612  seconds by  0.0  percent.
# cost splitting :  2.9036135280485506e-06 [0.         8.66907436]
# -------  82 0.5750000000000002 0.7000000000000004
# set cost params:  0.05 0.0 97.29105701904312
# interpolate adjoint :  True True True
# initial cost =  623.2602235210921
# RUN  0 , total integrated cost =  623.2602235210921
# Gradient descend method:  None
# RUN  1 , total integrated cost =  286.519544597779
# RUN  2 , total integrated cost =  156.5299488253562
# RUN  3 , total integrated cost =  151.9080983558276
# RUN  4 , total integrated cost =  151.23106942552417
# RUN  5 , total integrated cost =  151.19651274106536
# RUN  6 , total integrated cost =  151.19524331167244
# RUN  7 , total integrated cost =  151.19524331167244
# Control only changes marginally.
# RUN  7 , total integrated cost =  151.19524331167244
# Improved over  7  iterations in  3.558494948898442  seconds by  75.74123333950321  percent.
# cost splitting :  6.290411701785373e-05 [1.55405014e+00 6.13857129e-07]
# set cost params:  0.05 0.0 633.9622295387538
# interpolate adjoint :  True True True
# initial cost =  985.2094816774313
# RUN  0 , total integrated cost =  985.2094816774313
# Gradient descend method:  None
# RUN  1 , total integrated cost =  985.2094816774313
# Control only changes marginally.
# RUN  1 , total integrated cost =  985.2094816774313
# Improved over  1  iterations in  0.5802889360347763  seconds by  0.0  percent.
# cost splitting :  6.290411701785373e-05 [1.55405014e+00 6.13857129e-07]

# %%
bad = [24]

# %%
c_var = [0,1]
conv = [None] * len(exc)
max_it = int(30)

tol = 1e-8

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    if i in bad:
        continue
        
    while not conv[i]:

        weight_ = random.random() * ( cost_uncontrolled[i] -
                                     costnode_[i][0][0][0] ) / sum( costnode_[i][2][0][:] )
            
        aln.params.duration = dur
        cost.setParams(wp, weight_ * factor_we, weight_ * factor_ws)
        weights_[i] = cost.getParams()

        setinit(initVars[i], aln)

        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        control0 = aln.getZeroControl()
        control0 = bestControl_[i][:,:,n_pre-1:-n_post+1]

        bestControl_[i], bestState_[i], cost_[i], runtime_, grad_, phi_, phi1_, costnode_[i] = aln.A1(
            control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
            prec_variables_ = p_var, transition_time_ = t_pen)
        
        if cost_[i][3] == 0.:
            conv[i] = True

        #print('uncontrolled cost : ', cost_uncontrolled[i])
        print('cost splitting : ', costnode_[i][0][0][0], costnode_[i][2][0][:2])

        if conv[i] and False:
            time_ = np.arange(-dur_pre,round(dur+dur_post+aln.params.dt,1),aln.params.dt)
            target_ = aln.getZeroTarget()
            target_[:,0,:] = target[i][0]
            target_[:,1,:] = target[i][1]
        
            fig, ax = plt.subplots(2,1, constrained_layout=True, figsize = (4,4) )
            ax[1].plot(time_, bestControl_[i][0,0,:], color = 'red')
            ax[0].plot(time_, bestState_[i][0,0,:], color= 'red')
            ax[1].plot(time_, bestControl_[i][0,1,:], color = 'blue')
            ax[0].plot(time_, bestState_[i][0,1,:], color= 'blue')
            ax[0].plot(time_, target_[0,0,:], linestyle = '--', color='red')
            ax[0].plot(time_, target_[0,1,:], linestyle = '--', color='blue')
            ax[0].set_xlim(-dur_pre,dur+dur_post)
            ax[1].set_xlim(-dur_pre,dur+dur_post)
            ax[0].axvspan(dur*t_pen, dur, alpha=0.2, color='gray')
            plt.show()

        with open(file_,'wb') as f:
            pickle.dump([bestControl_, bestState_, cost_, costnode_, weights_], f)
# Out:
# -------  0 0.4000000000000001 0.3500000000000001
# set cost params:  0.05 0.0 219.39929231902784
# interpolate adjoint :  True True True
# initial cost =  205.60710077856046
# RUN  0 , total integrated cost =  205.60710077856046
# Gradient descend method:  None
# RUN  1 , total integrated cost =  205.60709592269023
# RUN  2 , total integrated cost =  205.60709202341113
# RUN  3 , total integrated cost =  205.60708820355626
# RUN  4 , total integrated cost =  205.60708819741131
# RUN  5 , total integrated cost =  205.60708819357603
# RUN  6 , total integrated cost =  205.60708818530503
# RUN  7 , total integrated cost =  205.60708817917333
# RUN  8 , total integrated cost =  205.60708816511107
# RUN  9 , total integrated cost =  205.6070881538456
# RUN  10 , total integrated cost =  205.60708803446892
# RUN  11 , total integrated cost =  205.60708793142055
# RUN  12 , total integrated cost =  205.60708791572137
# RUN  13 , total integrated cost =  205.60708790113307
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_7960/314225781.py in <module>
#      31         control0 = bestControl_[i][:,:,n_pre-1:-n_post+1]
#      32
# ---> 33         bestControl_[i], bestState_[i], cost_[i], runtime_, grad_, phi_, phi1_, costnode_[i] = aln.A1(
#      34             control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
#      35             startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
#
# ~/Promotion/neurolib/neurolib/models/model.py in A1(self, control_, target_state_, c_scheme_, u_mat_, u_scheme_, max_iteration_, tolerance_, startStep_, max_control_, min_control_, t_sim_, t_sim_pre_, t_sim_post_, CGVar, line_search_, control_variables_, prec_variables_, separate_comp, transition_time_, noise_real, init_params, method)
#     664             if self.params.N == 1:
#     665                 if noise_real == 0:
# --> 666                     return opti1_rate_control.A1(self, control_, target_state_, c_scheme_, u_mat_, u_scheme_, max_iteration_,
#     667                                                 tolerance_, startStep_, max_control_, min_control_, t_sim_, t_sim_pre_, t_sim_post_, CGVar,
#     668                                                 line_search_, control_variables_, prec_variables_, separate_comp, transition_time_)
#
# ~/Promotion/neurolib/neurolib/utils/A1_aln_rate_control.py in A1(model, control_, target_state, c_scheme_, u_mat_, u_scheme_, max_iteration_, tolerance_, startStep_, cntrl_max_, cntrl_min_, t_sim_, t_sim_pre_, t_sim_post_, CGVar, line_search_, control_variables_, prec_variables_, separate_comp, transition_time_)
#     483
#     484
# --> 485         step_, total_cost_[i], startStep_ = line_search_func(model, N, n_control_vars, T, dt, state1_[:,:2,:], target_state_,
#     486                      best_control_, dir0_, ip_, ie_, is_, start_step_ = startStep_, max_it_ = 500, max_control_ = cntrl_max_,
#     487                          min_control_ = cntrl_min_, tolerance_ = tolerance_step, variables_ = prec_variables, grad_ = grad1_)
#
# ~/Promotion/neurolib/neurolib/utils/func_optimize.py in step_size(model, N, V, T, dt, state_, target_, control_, dir_, ip_, ie_, is_, start_step_, max_it_, bisec_factor_, max_control_, min_control_, tolerance_, substep_, variables_, alg, control_parameter, grad_, noise_real, init_vars, startind_)
#     234                 #print(init_vars)
#     235                 set_init(model, init_vars, model.init_vars, model.state_vars, startind_)
# --> 236             state1_ = updateState(model, test_control_)
#     237             cost1_int_ = cost.f_int(N, V, T, dt, state1_, target_, test_control_, ip_, ie_, is_, v_ = variables_)
#     238         else:
#
# ~/Promotion/neurolib/neurolib/utils/func_optimize.py in updateState(model, control_)
#       8     state_ = model.getZeroState()
#       9     output_vars = model.output_vars
# ---> 10     model.run(control = control_)
#      11     for i in range(len(output_vars)):
#      12         state_[:,i,:] = model[output_vars[i]][:,:]
#
# ~/Promotion/neurolib/neurolib/models/model.py in run(self, inputs, chunkwise, chunksize, bold, append, append_outputs, continue_run, control)
#     185
#     186         if chunkwise is False:
# --> 187             self.integrate(append_outputs=append, simulate_bold=bold, control=cntrl)
#     188             if continue_run:
#     189                 self.setInitialValuesToLastState()
#
# ~/Promotion/neurolib/neurolib/models/model.py in integrate(self, append_outputs, simulate_bold, control)
#     226         # run integration
#     227         #print("before integration")
# --> 228         t, *variables = self.integration(self.params, control=control)
#     229         #print("after integration")
#     230         self.storeOutputsAndStates(t, variables, append=append_outputs)
#
# ~/Promotion/neurolib/neurolib/models/aln/timeIntegration.py in timeIntegration(params, control)
#     281     # ------------------------------------------------------------------------
#     282
# --> 283     return timeIntegration_njit_elementwise(
#     284         dt,
#     285         duration,
#
# KeyboardInterrupt:

# %%
c_var = [0,1]
#conv = [None] * len(exc)
max_it = int(60)

tol = 1e-10

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    if i in bad:
        continue
    
    while not conv[i]:

        weight_ = random.random() * ( cost_uncontrolled[i] -
                                     costnode_[i][0][0][0] ) / sum( costnode_[i][2][0][:] )
            
        aln.params.duration = dur
        cost.setParams(wp, weight_ * factor_we, weight_ * factor_ws)
        weights_[i] = cost.getParams()

        setinit(initVars[i], aln)

        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        control0 = aln.getZeroControl()
        control0 = bestControl_[i][:,:,n_pre-1:-n_post+1]

        bestControl_[i], bestState_[i], cost_[i], runtime_, grad_, phi_, phi1_, costnode_[i] = aln.A1(
            control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
            prec_variables_ = p_var, transition_time_ = t_pen)
        
        if cost_[i][3] == 0.:
            conv[i] = True

        #print('uncontrolled cost : ', cost_uncontrolled[i])
        print('cost splitting : ', costnode_[i][0][0][0], costnode_[i][2][0][:2])

        if conv[i]:
            time_ = np.arange(-dur_pre,round(dur+dur_post+aln.params.dt,1),aln.params.dt)
            target_ = aln.getZeroTarget()
            target_[:,0,:] = target[i][0]
            target_[:,1,:] = target[i][1]
        
            fig, ax = plt.subplots(2,1, constrained_layout=True, figsize = (4,4) )
            ax[1].plot(time_, bestControl_[i][0,0,:], color = 'red')
            ax[0].plot(time_, bestState_[i][0,0,:], color= 'red')
            ax[1].plot(time_, bestControl_[i][0,1,:], color = 'blue')
            ax[0].plot(time_, bestState_[i][0,1,:], color= 'blue')
            ax[0].plot(time_, target_[0,0,:], linestyle = '--', color='red')
            ax[0].plot(time_, target_[0,1,:], linestyle = '--', color='blue')
            ax[0].set_xlim(-dur_pre,dur+dur_post)
            ax[1].set_xlim(-dur_pre,dur+dur_post)
            ax[0].axvspan(dur*t_pen, dur, alpha=0.2, color='gray')
            plt.show()

        with open(file_,'wb') as f:
            pickle.dump([bestControl_, bestState_, cost_, costnode_, weights_], f)
# Out:
# -------  0 0.4000000000000001 0.3500000000000001
# set cost params:  0.05 0.0 158.5912239511063
# interpolate adjoint :  True True True
# initial cost =  148.62082025732835
# RUN  0 , total integrated cost =  148.62082025732835
# Gradient descend method:  None
# RUN  1 , total integrated cost =  148.62067054784498
# RUN  2 , total integrated cost =  148.62067026476987
# RUN  3 , total integrated cost =  148.6206702647516
# RUN  4 , total integrated cost =  148.62067026441616
# RUN  5 , total integrated cost =  148.62067026428923
# RUN  6 , total integrated cost =  148.62067026428923
# Control only changes marginally.
# RUN  6 , total integrated cost =  148.62067026428923
# Improved over  6  iterations in  2.5181105639931047  seconds by  0.0001009233019004796  percent.
# cost splitting :  0.0034340047942970496 [2.22079097e-11 9.37129400e-01]
# set cost params:  0.05 0.0 88.78813250693119
# interpolate adjoint :  True True True
# initial cost =  83.20614105336895
# RUN  0 , total integrated cost =  83.20614105336895
# Gradient descend method:  None
# RUN  1 , total integrated cost =  83.20612486924821
# RUN  2 , total integrated cost =  83.2061248683152
# RUN  3 , total integrated cost =  83.2061248683152
# Control only changes marginally.
# RUN  3 , total integrated cost =  83.2061248683152
# Improved over  3  iterations in  1.745722081992426  seconds by  1.9451753857424592e-05  percent.
# cost splitting :  0.002177195587870136 [2.22079097e-11 9.37129926e-01]
# set cost params:  0.05 0.0 233.25618334152097
# interpolate adjoint :  True True True
# initial cost =  218.59145859550517
# RUN  0 , total integrated cost =  218.59145859550517
# Gradient descend method:  None
# RUN  1 , total integrated cost =  218.5913863787389
# RUN  2 , total integrated cost =  218.59138622375423
# RUN  3 , total integrated cost =  218.59138622375423
# Control only changes marginally.
# RUN  3 , total integrated cost =  218.59138622375423
# Improved over  3  iterations in  1.4893257950025145  seconds by  3.31082245423886e-05  percent.
# cost splitting :  0.00464665423936112 [2.22079097e-11 9.37129086e-01]
# set cost params:  0.05 0.0 194.17220049183143
# interpolate adjoint :  True True True
# initial cost =  181.96464909986608
# RUN  0 , total integrated cost =  181.96464909986608
# Gradient descend method:  None
# RUN  1 , total integrated cost =  181.96464635080986
# RUN  2 , total integrated cost =  181.96464635080986
# Control only changes marginally.
# RUN  2 , total integrated cost =  181.96464635080986
# Improved over  2  iterations in  1.0295753329992294  seconds by  1.510763894430056e-06  percent.
# cost splitting :  0.004024308758130797 [2.22079097e-11 9.37129232e-01]
# set cost params:  0.05 0.0 5.332682767499309
# interpolate adjoint :  True True True
# initial cost =  4.997614122193284
# RUN  0 , total integrated cost =  4.997614122193284
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.997448129100309
# RUN  2 , total integrated cost =  4.997448096453495
# RUN  3 , total integrated cost =  4.99744809643169
# RUN  4 , total integrated cost =  4.997448096399243
# RUN  5 , total integrated cost =  4.9974480963455
# RUN  6 , total integrated cost =  4.997448096339298
# RUN  7 , total integrated cost =  4.997448096202307
# RUN  8 , total integrated cost =  4.997448096100529
# RUN  9 , total integrated cost =  4.997448096091945
# RUN  10 , total integrated cost =  4.997448096060148
# RUN  11 , total integrated cost =  4.997448096048625
# RUN  12 , total integrated cost =  4.997448095982579
# RUN  13 , total integrated cost =  4.997448095889141

# %%
c_var = [0,1]
conv = [None] * len(exc)
max_it = int(80)

tol = 1e-12

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.

    
    while not conv[i]:

        weight_ = random.random() * ( cost_uncontrolled[i] -
                                     costnode_[i][0][0][0] ) / sum( costnode_[i][2][0][:] )
            
        aln.params.duration = dur
        cost.setParams(wp, weight_ * factor_we, weight_ * factor_ws)
        weights_[i] = cost.getParams()

        setinit(initVars[i], aln)

        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        control0 = aln.getZeroControl()
        control0 = bestControl_[i][:,:,n_pre-1:-n_post+1]

        bestControl_[i], bestState_[i], cost_[i], runtime_, grad_, phi_, phi1_, costnode_[i] = aln.A1(
            control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
            prec_variables_ = p_var, transition_time_ = t_pen)
        
        if cost_[i][2] == 0.:
            conv[i] = True

        #print('uncontrolled cost : ', cost_uncontrolled[i])
        print('cost splitting : ', costnode_[i][0][0][0], costnode_[i][2][0][:2])
        print("total cost = ", costnode_[i][0][0][0] + sum(costnode_[i][2][0][:2]))

        if conv[i]:
            time_ = np.arange(-dur_pre,round(dur+dur_post+aln.params.dt,1),aln.params.dt)
            target_ = aln.getZeroTarget()
            target_[:,0,:] = target[i][0]
            target_[:,1,:] = target[i][1]
        
            fig, ax = plt.subplots(2,1, constrained_layout=True, figsize = (4,4) )
            ax[1].plot(time_, bestControl_[i][0,0,:], color = 'red')
            ax[0].plot(time_, bestState_[i][0,0,:], color= 'red')
            ax[1].plot(time_, bestControl_[i][0,1,:], color = 'blue')
            ax[0].plot(time_, bestState_[i][0,1,:], color= 'blue')
            ax[0].plot(time_, target_[0,0,:], linestyle = '--', color='red')
            ax[0].plot(time_, target_[0,1,:], linestyle = '--', color='blue')
            ax[0].set_xlim(-dur_pre,dur+dur_post)
            ax[1].set_xlim(-dur_pre,dur+dur_post)
            ax[0].axvspan(dur*t_pen, dur, alpha=0.2, color='gray')
            plt.show()

        with open(file_,'wb') as f:
            pickle.dump([bestControl_, bestState_, cost_, costnode_, weights_], f)
# Out:
# -------  0 0.4000000000000001 0.3500000000000001
# -------  1 0.4250000000000001 0.3500000000000001
# -------  2 0.4000000000000001 0.3750000000000001
# -------  3 0.4250000000000001 0.3750000000000001
# -------  4 0.4500000000000001 0.3750000000000001
# -------  5 0.4000000000000001 0.40000000000000013
# -------  6 0.4250000000000001 0.40000000000000013
# -------  7 0.4500000000000001 0.40000000000000013
# -------  8 0.47500000000000014 0.40000000000000013
# -------  9 0.4000000000000001 0.42500000000000016
# -------  10 0.4250000000000001 0.42500000000000016
# -------  11 0.4500000000000001 0.42500000000000016
# -------  12 0.47500000000000014 0.42500000000000016
# -------  13 0.4000000000000001 0.4500000000000002
# -------  14 0.4250000000000001 0.4500000000000002
# -------  15 0.4500000000000001 0.4500000000000002
# -------  16 0.47500000000000014 0.4500000000000002
# -------  17 0.5000000000000002 0.4500000000000002
# -------  18 0.4000000000000001 0.4750000000000002
# -------  19 0.4250000000000001 0.4750000000000002
# -------  20 0.4500000000000001 0.4750000000000002
# -------  21 0.47500000000000014 0.4750000000000002
# -------  22 0.5000000000000002 0.4750000000000002
# -------  23 0.5250000000000001 0.4750000000000002
# -------  24 0.4000000000000001 0.5000000000000002
# -------  25 0.4250000000000001 0.5000000000000002
# -------  26 0.4500000000000001 0.5000000000000002
# -------  27 0.47500000000000014 0.5000000000000002
# -------  28 0.5000000000000002 0.5000000000000002
# -------  29 0.5250000000000001 0.5000000000000002
# -------  30 0.4250000000000001 0.5250000000000002
# -------  31 0.4500000000000001 0.5250000000000002
# -------  32 0.47500000000000014 0.5250000000000002
# -------  33 0.5000000000000002 0.5250000000000002
# -------  34 0.5250000000000001 0.5250000000000002
# -------  35 0.5500000000000003 0.5250000000000002
# -------  36 0.4250000000000001 0.5500000000000003
# -------  37 0.4500000000000001 0.5500000000000003
# -------  38 0.47500000000000014 0.5500000000000003
# -------  39 0.5000000000000002 0.5500000000000003
# -------  40 0.5250000000000001 0.5500000000000003
# -------  41 0.5500000000000003 0.5500000000000003
# -------  42 0.4250000000000001 0.5750000000000003
# -------  43 0.4500000000000001 0.5750000000000003
# -------  44 0.47500000000000014 0.5750000000000003
# -------  45 0.5000000000000002 0.5750000000000003
# -------  46 0.5250000000000001 0.5750000000000003
# -------  47 0.5500000000000003 0.5750000000000003
# -------  48 0.4250000000000001 0.6000000000000003
# -------  49 0.4500000000000001 0.6000000000000003
# -------  50 0.47500000000000014 0.6000000000000003
# set cost params:  0.05 0.0 31.43985430775056
# interpolate adjoint :  True True True
# initial cost =  197.88946514159537
# RUN  0 , total integrated cost =  197.88946514159537
# Gradient descend method:  None
# RUN  1 , total integrated cost =  197.88946508069537
# RUN  2 , total integrated cost =  197.8894650806826
# RUN  3 , total integrated cost =  197.8894650806826
# Control only changes marginally.
# RUN  3 , total integrated cost =  197.8894650806826
# Improved over  3  iterations in  1.1662146080007005  seconds by  3.078119448218786e-08  percent.
# cost splitting :  3.84193490434487e-06 [4.52045174e-12 6.29422334e+00]
# total cost =  6.294227185069231
# set cost params:  0.05 0.0 73.85414454271938
# interpolate adjoint :  True True True
# initial cost =  464.8544807600977
# RUN  0 , total integrated cost =  464.8544807600977
# Gradient descend method:  None
# RUN  1 , total integrated cost =  464.85448065688905
# RUN  2 , total integrated cost =  464.85448065676627
# RUN  3 , total integrated cost =  464.85448065676627
# Control only changes marginally.
# RUN  3 , total integrated cost =  464.85448065676627
# Improved over  3  iterations in  1.292764721999447  seconds by  2.222877526492084e-08  percent.
# cost splitting :  7.97629395689088e-06 [4.52045174e-12 6.29422334e+00]
# total cost =  6.294231315230153
# set cost params:  0.05 0.0 22.455791483591334
# interpolate adjoint :  True True True
# initial cost =  141.34176724911995
# RUN  0 , total integrated cost =  141.34176724911995
# Gradient descend method:  None
# RUN  1 , total integrated cost =  141.3417671290601
# RUN  2 , total integrated cost =  141.34176712905975
# RUN  3 , total integrated cost =  141.34176712905975
# Control only changes marginally.
# RUN  3 , total integrated cost =  141.34176712905975
# Improved over  3  iterations in  1.2575803190002262  seconds by  8.494318137763912e-08  percent.
# cost splitting :  2.8803402510723216e-06 [4.52045174e-12 6.29422334e+00]
# total cost =  6.294226225276569
# set cost params:  0.05 0.0 59.11525397074146
# interpolate adjoint :  True True True
# initial cost =  372.0846117284973
# RUN  0 , total integrated cost =  372.0846117284973
# Gradient descend method:  None
# RUN  1 , total integrated cost =  372.08461162136916
# RUN  2 , total integrated cost =  372.08461162121625
# RUN  3 , total integrated cost =  372.08461162121625
# Control only changes marginally.
# RUN  3 , total integrated cost =  372.08461162121625
# Improved over  3  iterations in  1.3012214829996083  seconds by  2.8832431553382776e-08  percent.
# cost splitting :  6.598019348659886e-06 [4.52045174e-12 6.29422334e+00]
# total cost =  6.294229937996457
# set cost params:  0.05 0.0 41.74419413354471
# interpolate adjoint :  True True True
# initial cost =  262.74728135379354
# RUN  0 , total integrated cost =  262.74728135379354
# Gradient descend method:  None
# RUN  1 , total integrated cost =  262.74728133992596
# RUN  2 , total integrated cost =  262.74728133991454
# RUN  3 , total integrated cost =  262.74728133991454
# Control only changes marginally.
# RUN  3 , total integrated cost =  262.74728133991454
# Improved over  3  iterations in  1.2376710749995254  seconds by  5.282259962768876e-09  percent.
# cost splitting :  4.891726468947534e-06 [4.52045174e-12 6.29422334e+00]
# total cost =  6.294228233414849
# set cost params:  0.05 0.0 96.2333855731156
# interpolate adjoint :  True True True
# initial cost =  605.7144219685882
# RUN  0 , total integrated cost =  605.7144219685882
# Gradient descend method:  None
# RUN  1 , total integrated cost =  605.7144218439313
# RUN  2 , total integrated cost =  605.7144218439282
# RUN  3 , total integrated cost =  605.7144218439282
# Control only changes marginally.
# RUN  3 , total integrated cost =  605.7144218439282
# Improved over  3  iterations in  1.2483655609994457  seconds by  2.0580657178470574e-08  percent.
# cost splitting :  9.989722738156793e-06 [4.52045174e-12 6.29422334e+00]
# total cost =  6.294233327466958
# set cost params:  0.05 0.0 24.59164039752208
# interpolate adjoint :  True True True
# initial cost =  154.78527740298316
# RUN  0 , total integrated cost =  154.78527740298316
# Gradient descend method:  None
# RUN  1 , total integrated cost =  154.78527722386727
# RUN  2 , total integrated cost =  154.78527722385115
# RUN  3 , total integrated cost =  154.78527722385115
# Control only changes marginally.
# RUN  3 , total integrated cost =  154.78527722385115
# Improved over  3  iterations in  1.1796484229998896  seconds by  1.1572936386983201e-07  percent.
# cost splitting :  3.110668787147759e-06 [4.52045174e-12 6.29422334e+00]
# total cost =  6.2942264551153135
# set cost params:  0.05 0.0 103.40769088903794
# interpolate adjoint :  True True True
# initial cost =  650.8711021446264
# RUN  0 , total integrated cost =  650.8711021446264
# Gradient descend method:  None
# RUN  1 , total integrated cost =  650.8711017945834
# RUN  2 , total integrated cost =  650.8711017943336
# RUN  3 , total integrated cost =  650.8711017943336
# Control only changes marginally.
# RUN  3 , total integrated cost =  650.8711017943336
# Improved over  3  iterations in  1.2811344989995632  seconds by  5.3819064760318724e-08  percent.
# cost splitting :  1.0617934381330736e-05 [4.52045174e-12 6.29422334e+00]
# total cost =  6.29423395536348
# set cost params:  0.05 0.0 41.66965561195318
# interpolate adjoint :  True True True
# initial cost =  262.27811934628585
# RUN  0 , total integrated cost =  262.27811934628585
# Gradient descend method:  None
# RUN  1 , total integrated cost =  262.2781192376533
# RUN  2 , total integrated cost =  262.27811923745617
# RUN  3 , total integrated cost =  262.27811923745617
# Control only changes marginally.
# RUN  3 , total integrated cost =  262.27811923745617
# Improved over  3  iterations in  1.2261303139994197  seconds by  4.1493990465824027e-08  percent.
# cost splitting :  4.887098012592822e-06 [4.52045174e-12 6.29422334e+00]
# total cost =  6.294228228791897
# set cost params:  0.05 0.0 29.009899508108084
# interpolate adjoint :  True True True
# initial cost =  182.59478686848274
# RUN  0 , total integrated cost =  182.59478686848274
# Gradient descend method:  None
# RUN  1 , total integrated cost =  182.5947868574989
# RUN  2 , total integrated cost =  182.59478685749798
# RUN  3 , total integrated cost =  182.59478685749798
# Control only changes marginally.
# RUN  3 , total integrated cost =  182.59478685749798
# Improved over  3  iterations in  1.418545642999561  seconds by  6.01592375915061e-09  percent.
# cost splitting :  3.5824058493898517e-06 [4.52045174e-12 6.29422334e+00]
# total cost =  6.29422692596978
# set cost params:  0.05 0.0 32.44291465499243
# interpolate adjoint :  True True True
# initial cost =  204.20295093382597
# RUN  0 , total integrated cost =  204.20295093382597
# Gradient descend method:  None
# RUN  1 , total integrated cost =  204.20295093278213
# RUN  2 , total integrated cost =  204.20295093278162
# RUN  3 , total integrated cost =  204.20295093278162
# Control only changes marginally.
# RUN  3 , total integrated cost =  204.20295093278162
# Improved over  3  iterations in  1.2418568149996645  seconds by  5.114344503454049e-10  percent.
# cost splitting :  3.9403074480053364e-06 [4.52045174e-12 6.29422334e+00]
# total cost =  6.2942272832876025
# set cost params:  0.05 0.0 60.38813599838626
# interpolate adjoint :  True True True
# initial cost =  380.0964154371183
# RUN  0 , total integrated cost =  380.0964154371183
# Gradient descend method:  None
# RUN  1 , total integrated cost =  380.0964153887295
# RUN  2 , total integrated cost =  380.0964153885876
# RUN  3 , total integrated cost =  380.0964153885876
# Control only changes marginally.
# RUN  3 , total integrated cost =  380.0964153885876
# Improved over  3  iterations in  1.2462282689994026  seconds by  1.2767998214258114e-08  percent.
# cost splitting :  6.7266848555048224e-06 [4.52045174e-12 6.29422334e+00]
# total cost =  6.294230066554306
# set cost params:  0.05 0.0 91.72673011671297
# interpolate adjoint :  True True True
# initial cost =  577.348525926855
# RUN  0 , total integrated cost =  577.348525926855
# Gradient descend method:  None
# RUN  1 , total integrated cost =  577.3485258946997
# RUN  2 , total integrated cost =  577.3485258946022
# RUN  3 , total integrated cost =  577.3485258946022
# Control only changes marginally.
# RUN  3 , total integrated cost =  577.3485258946022
# Improved over  3  iterations in  1.2963281739994272  seconds by  5.586372253674199e-09  percent.
# cost splitting :  9.583443963056215e-06 [4.52045174e-12 6.29422334e+00]
# total cost =  6.294232921404583
# set cost params:  0.05 0.0 74.94309313341783
# interpolate adjoint :  True True True
# initial cost =  471.70856629848697
# RUN  0 , total integrated cost =  471.70856629848697
# Gradient descend method:  None
# RUN  1 , total integrated cost =  471.708566291201
# RUN  2 , total integrated cost =  471.708566291199
# RUN  3 , total integrated cost =  471.708566291199
# Control only changes marginally.
# RUN  3 , total integrated cost =  471.708566291199
# Improved over  3  iterations in  1.2410483860003296  seconds by  1.5450041246367618e-09  percent.
# cost splitting :  8.073977311429513e-06 [4.52045174e-12 6.29422334e+00]
# total cost =  6.294231412847759
# set cost params:  0.05 0.0 98.34291547178015
# interpolate adjoint :  True True True
# initial cost =  618.992274178741
# RUN  0 , total integrated cost =  618.992274178741
# Gradient descend method:  None
# RUN  1 , total integrated cost =  618.992274163677
# RUN  2 , total integrated cost =  618.9922741636616
# RUN  3 , total integrated cost =  618.9922741636616
# Control only changes marginally.
# RUN  3 , total integrated cost =  618.9922741636616
# Improved over  3  iterations in  1.226726478999808  seconds by  2.436124191262934e-09  percent.
# cost splitting :  1.0176944518324154e-05 [4.52045174e-12 6.29422334e+00]
# total cost =  6.294233514592428
# set cost params:  0.05 0.0 52.97666705979543
# interpolate adjoint :  True True True
# initial cost =  333.4469746674149
# RUN  0 , total integrated cost =  333.4469746674149
# Gradient descend method:  None
# RUN  1 , total integrated cost =  333.44697461033087
# RUN  2 , total integrated cost =  333.4469746102428
# RUN  3 , total integrated cost =  333.4469746102428
# Control only changes marginally.
# RUN  3 , total integrated cost =  333.4469746102428
# Improved over  3  iterations in  1.2334218870000768  seconds by  1.7145779906968528e-08  percent.
# cost splitting :  6.008391169564938e-06 [4.52045174e-12 6.29422334e+00]
# total cost =  6.294229348894215
# set cost params:  0.05 0.0 119.55621940702194
# interpolate adjoint :  True True True
# initial cost =  752.5135469944003
# RUN  0 , total integrated cost =  752.5135469944003
# Gradient descend method:  None
# RUN  1 , total integrated cost =  752.5135468524287
# RUN  2 , total integrated cost =  752.5135468520635
# RUN  3 , total integrated cost =  752.5135468520635
# Control only changes marginally.
# RUN  3 , total integrated cost =  752.5135468520635
# Improved over  3  iterations in  1.2913400879997425  seconds by  1.8914832367045165e-08  percent.
# cost splitting :  1.2005321290992322e-05 [4.52045174e-12 6.29422334e+00]
# total cost =  6.294235342125799
# set cost params:  0.05 0.0 88.58087963694109
# interpolate adjoint :  True True True
# initial cost =  557.5478404057719
# RUN  0 , total integrated cost =  557.5478404057719
# Gradient descend method:  None
# RUN  1 , total integrated cost =  557.5478403868866
# RUN  2 , total integrated cost =  557.5478403868589
# RUN  3 , total integrated cost =  557.5478403868589
# Control only changes marginally.
# RUN  3 , total integrated cost =  557.5478403868589
# Improved over  3  iterations in  1.3041406640004425  seconds by  3.392187863937579e-09  percent.
# cost splitting :  9.321102893716028e-06 [4.52045174e-12 6.29422334e+00]
# total cost =  6.2942326592090145
# set cost params:  0.05 0.0 33.35700890932854
# interpolate adjoint :  True True True
# initial cost =  209.95646443256462
# RUN  0 , total integrated cost =  209.95646443256462
# Gradient descend method:  None
# RUN  1 , total integrated cost =  209.95646432607526
# RUN  2 , total integrated cost =  209.9564643260331
# RUN  3 , total integrated cost =  209.9564643260331
# Control only changes marginally.
# RUN  3 , total integrated cost =  209.9564643260331
# Improved over  3  iterations in  1.1426219860004494  seconds by  5.0739799917209893e-08  percent.
# cost splitting :  4.042753864094861e-06 [4.52045174e-12 6.29422334e+00]
# total cost =  6.294227385578211
# set cost params:  0.05 0.0 82.86751479856595
# interpolate adjoint :  True True True
# initial cost =  521.5866462091135
# RUN  0 , total integrated cost =  521.5866462091135
# Gradient descend method:  None
# RUN  1 , total integrated cost =  521.5866460812538
# RUN  2 , total integrated cost =  521.586646081169
# RUN  3 , total integrated cost =  521.586646081169
# Control only changes marginally.
# RUN  3 , total integrated cost =  521.586646081169
# Improved over  3  iterations in  1.2681438099998559  seconds by  2.4529867914679926e-08  percent.
# cost splitting :  8.7991074134089e-06 [4.52045174e-12 6.29422334e+00]
# total cost =  6.294232137517942
# set cost params:  0.05 0.0 63.81683124272841
# interpolate adjoint :  True True True
# initial cost =  401.6773890313427
# RUN  0 , total integrated cost =  401.6773890313427
# Gradient descend method:  None
# RUN  1 , total integrated cost =  401.67738902042095
# RUN  2 , total integrated cost =  401.6773890204046
# RUN  3 , total integrated cost =  401.6773890204046
# Control only changes marginally.
# RUN  3 , total integrated cost =  401.6773890204046
# Improved over  3  iterations in  1.2861414250000962  seconds by  2.7231266130911536e-09  percent.
# cost splitting :  7.0358751113639725e-06 [4.52045174e-12 6.29422334e+00]
# total cost =  6.2942303754957205
# set cost params:  0.05 0.0 65.83949442593094
# interpolate adjoint :  True True True
# initial cost =  414.40848283630925
# RUN  0 , total integrated cost =  414.40848283630925
# Gradient descend method:  None
# RUN  1 , total integrated cost =  414.4084828361517
# RUN  2 , total integrated cost =  414.4084828361517
# Control only changes marginally.
# RUN  2 , total integrated cost =  414.4084828361517
# Improved over  2  iterations in  0.8770324969991634  seconds by  3.802824721788056e-11  percent.
# cost splitting :  7.221798474461722e-06 [4.52045174e-12 6.29422334e+00]
# total cost =  6.294230561275496
# set cost params:  0.05 0.0 59.3609527503388
# interpolate adjoint :  True True True
# initial cost =  373.63109461586504
# RUN  0 , total integrated cost =  373.63109461586504
# Gradient descend method:  None
# RUN  1 , total integrated cost =  373.6310946143496
# RUN  2 , total integrated cost =  373.6310946143489
# RUN  3 , total integrated cost =  373.6310946143489
# Control only changes marginally.
# RUN  3 , total integrated cost =  373.6310946143489
# Improved over  3  iterations in  1.3450253080000039  seconds by  4.057909563925932e-10  percent.
# cost splitting :  6.61586949202904e-06 [4.52045174e-12 6.29422334e+00]
# total cost =  6.29422995583135
# set cost params:  0.05 0.0 36.005509936785046
# interpolate adjoint :  True True True
# initial cost =  226.6267213421345
# RUN  0 , total integrated cost =  226.6267213421345
# Gradient descend method:  None
# RUN  1 , total integrated cost =  226.62672131604532
# RUN  2 , total integrated cost =  226.62672131602073
# RUN  3 , total integrated cost =  226.62672131602073
# Control only changes marginally.
# RUN  3 , total integrated cost =  226.62672131602073
# Improved over  3  iterations in  1.3132888589998402  seconds by  1.1522800491547969e-08  percent.
# cost splitting :  4.3181105551574554e-06 [4.52045174e-12 6.29422334e+00]
# total cost =  6.294227660537985
# set cost params:  0.05 0.0 52.29249493735097
# interpolate adjoint :  True True True
# initial cost =  329.14064248434823
# RUN  0 , total integrated cost =  329.14064248434823
# Gradient descend method:  None
# RUN  1 , total integrated cost =  329.1406424682101
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_7960/2254336237.py in <module>
#      32         control0 = bestControl_[i][:,:,n_pre-1:-n_post+1]
#      33
# ---> 34         bestControl_[i], bestState_[i], cost_[i], runtime_, grad_, phi_, phi1_, costnode_[i] = aln.A1(
#      35             control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
#      36             startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
#
# ~/Promotion/neurolib/neurolib/models/model.py in A1(self, control_, target_state_, c_scheme_, u_mat_, u_scheme_, max_iteration_, tolerance_, startStep_, max_control_, min_control_, t_sim_, t_sim_pre_, t_sim_post_, CGVar, line_search_, control_variables_, prec_variables_, separate_comp, transition_time_, noise_real, init_params, method)
#     664             if self.params.N == 1:
#     665                 if noise_real == 0:
# --> 666                     return opti1_rate_control.A1(self, control_, target_state_, c_scheme_, u_mat_, u_scheme_, max_iteration_,
#     667                                                 tolerance_, startStep_, max_control_, min_control_, t_sim_, t_sim_pre_, t_sim_post_, CGVar,
#     668                                                 line_search_, control_variables_, prec_variables_, separate_comp, transition_time_)
#
# ~/Promotion/neurolib/neurolib/utils/A1_aln_rate_control.py in A1(model, control_, target_state, c_scheme_, u_mat_, u_scheme_, max_iteration_, tolerance_, startStep_, cntrl_max_, cntrl_min_, t_sim_, t_sim_pre_, t_sim_post_, CGVar, line_search_, control_variables_, prec_variables_, separate_comp, transition_time_)
#     483
#     484
# --> 485         step_, total_cost_[i], startStep_ = line_search_func(model, N, n_control_vars, T, dt, state1_[:,:2,:], target_state_,
#     486                      best_control_, dir0_, ip_, ie_, is_, start_step_ = startStep_, max_it_ = 500, max_control_ = cntrl_max_,
#     487                          min_control_ = cntrl_min_, tolerance_ = tolerance_step, variables_ = prec_variables, grad_ = grad1_)
#
# ~/Promotion/neurolib/neurolib/utils/func_optimize.py in step_size(model, N, V, T, dt, state_, target_, control_, dir_, ip_, ie_, is_, start_step_, max_it_, bisec_factor_, max_control_, min_control_, tolerance_, substep_, variables_, alg, control_parameter, grad_, noise_real, init_vars, startind_)
#     234                 #print(init_vars)
#     235                 set_init(model, init_vars, model.init_vars, model.state_vars, startind_)
# --> 236             state1_ = updateState(model, test_control_)
#     237             cost1_int_ = cost.f_int(N, V, T, dt, state1_, target_, test_control_, ip_, ie_, is_, v_ = variables_)
#     238         else:
#
# ~/Promotion/neurolib/neurolib/utils/func_optimize.py in updateState(model, control_)
#       8     state_ = model.getZeroState()
#       9     output_vars = model.output_vars
# ---> 10     model.run(control = control_)
#      11     for i in range(len(output_vars)):
#      12         state_[:,i,:] = model[output_vars[i]][:,:]
#
# ~/Promotion/neurolib/neurolib/models/model.py in run(self, inputs, chunkwise, chunksize, bold, append, append_outputs, continue_run, control)
#     185
#     186         if chunkwise is False:
# --> 187             self.integrate(append_outputs=append, simulate_bold=bold, control=cntrl)
#     188             if continue_run:
#     189                 self.setInitialValuesToLastState()
#
# ~/Promotion/neurolib/neurolib/models/model.py in integrate(self, append_outputs, simulate_bold, control)
#     226         # run integration
#     227         #print("before integration")
# --> 228         t, *variables = self.integration(self.params, control=control)
#     229         #print("after integration")
#     230         self.storeOutputsAndStates(t, variables, append=append_outputs)
#
# ~/Promotion/neurolib/neurolib/models/aln/timeIntegration.py in timeIntegration(params, control)
#     281     # ------------------------------------------------------------------------
#     282
# --> 283     return timeIntegration_njit_elementwise(
#     284         dt,
#     285         duration,
#
# KeyboardInterrupt:

# %%
c_var = [0,1]
conv = [None] * len(exc)

tol = 1e-12

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    while not conv[i]:
        max_it = int(100)

        weight_ = random.random() * ( cost_uncontrolled[i] -
                                     costnode_[i][0][0][0] ) / sum( costnode_[i][2][0][:] )
            
        aln.params.duration = dur
        cost.setParams(wp, weight_ * factor_we, weight_ * factor_ws)
        weights_[i] = cost.getParams()

        setinit(initVars[i], aln)

        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        control0 = aln.getZeroControl()
        control0 = bestControl_[i][:,:,n_pre-1:-n_post+1]

        bestControl_[i], bestState_[i], cost_[i], runtime_, grad_, phi_, phi1_, costnode_[i] = aln.A1(
            control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
            prec_variables_ = p_var, transition_time_ = t_pen)
        
        if cost_[i][2] == 0.:
            conv[i] = True

        #print('uncontrolled cost : ', cost_uncontrolled[i])
        print('cost splitting : ', costnode_[i][0][0][0], costnode_[i][2][0][:2])

        if conv[i]:
            time_ = np.arange(-dur_pre,round(dur+dur_post+aln.params.dt,1),aln.params.dt)
            target_ = aln.getZeroTarget()
            target_[:,0,:] = target[i][0]
            target_[:,1,:] = target[i][1]
        
            fig, ax = plt.subplots(2,1, constrained_layout=True, figsize = (4,4) )
            ax[1].plot(time_, bestControl_[i][0,0,:], color = 'red')
            ax[0].plot(time_, bestState_[i][0,0,:], color= 'red')
            ax[1].plot(time_, bestControl_[i][0,1,:], color = 'blue')
            ax[0].plot(time_, bestState_[i][0,1,:], color= 'blue')
            ax[0].plot(time_, target_[0,0,:], linestyle = '--', color='red')
            ax[0].plot(time_, target_[0,1,:], linestyle = '--', color='blue')
            ax[0].set_xlim(-dur_pre,dur+dur_post)
            ax[1].set_xlim(-dur_pre,dur+dur_post)
            ax[0].axvspan(dur*t_pen, dur, alpha=0.2, color='gray')
            plt.show()

        with open(file_,'wb') as f:
            pickle.dump([bestControl_, bestState_, cost_, costnode_, weights_], f)
# Out:
# -------  20 0.4500000000000001 0.4750000000000002
# set cost params:  0.05 0.0 1.4483990221903713
# interpolate adjoint :  True True True
# initial cost =  4.82498840633447
# RUN  0 , total integrated cost =  4.82498840633447
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.824987609642855
# RUN  2 , total integrated cost =  4.824987609465598
# RUN  3 , total integrated cost =  4.824987609414683
# RUN  4 , total integrated cost =  4.824987609374701
# RUN  5 , total integrated cost =  4.824987609346649
# RUN  6 , total integrated cost =  4.824987609288059
# RUN  7 , total integrated cost =  4.8249876092334745
# RUN  8 , total integrated cost =  4.824987609226406
# RUN  9 , total integrated cost =  4.824987609221292
# RUN  10 , total integrated cost =  4.82498760921887
# RUN  11 , total integrated cost =  4.824987609211991
# RUN  12 , total integrated cost =  4.82498760920676
# RUN  13 , total integrated cost =  4.8249876091839
# RUN  14 , total integrated cost =  4.824987609165418
# RUN  15 , total integrated cost =  4.824987609092217
# RUN  16 , total integrated cost =  4.824987609031796
# RUN  17 , total integrated cost =  4.824987608960736
# RUN  18 , total integrated cost =  4.824987608898167
# RUN  19 , total integrated cost =  4.8249876088393
# RUN  20 , total integrated cost =  4.824987608790931
# RUN  30 , total integrated cost =  4.824987608188761
# RUN  40 , total integrated cost =  4.824987607586595
# RUN  50 , total integrated cost =  4.824987606984427
# RUN  60 , total integrated cost =  4.8249876063822645
# RUN  70 , total integrated cost =  4.824987605780114
# RUN  80 , total integrated cost =  4.8249876051779585
# RUN  90 , total integrated cost =  4.824987604575804
# RUN  100 , total integrated cost =  4.824987603973649
# RUN  100 , total integrated cost =  4.824987603973649
# Improved over  100  iterations in  29.490586470987182  seconds by  1.6629279770086214e-05  percent.
# cost splitting :  7.203750718267627e-07 [1.35856431e-11 3.33125575e+00]
# set cost params:  0.05 0.0 22.781211198052276
# interpolate adjoint :  True True True
# initial cost =  75.89004078413366
# RUN  0 , total integrated cost =  75.89004078413366
# Gradient descend method:  None
# RUN  1 , total integrated cost =  75.8900400025601
# RUN  2 , total integrated cost =  75.89004000250686
# RUN  3 , total integrated cost =  75.8900400024813
# RUN  4 , total integrated cost =  75.89004000229714
# RUN  5 , total integrated cost =  75.89004000213036
# RUN  6 , total integrated cost =  75.89004000191241
# RUN  7 , total integrated cost =  75.89004000165068
# RUN  8 , total integrated cost =  75.89004000162495
# RUN  9 , total integrated cost =  75.89004000157348
# RUN  10 , total integrated cost =  75.89004000155087
# RUN  11 , total integrated cost =  75.89004000146217
# RUN  12 , total integrated cost =  75.89004000138982
# RUN  13 , total integrated cost =  75.89004000030745
# RUN  14 , total integrated cost =  75.8900399991252
# RUN  15 , total integrated cost =  75.89003999906573
# RUN  16 , total integrated cost =  75.89003999897494
# RUN  17 , total integrated cost =  75.89003999895247
# RUN  18 , total integrated cost =  75.8900399989004
# RUN  19 , total integrated cost =  75.89003999887278
# RUN  20 , total integrated cost =  75.8900399982852
# RUN  30 , total integrated cost =  75.89003999636391
# RUN  40 , total integrated cost =  75.8900399950079
# RUN  50 , total integrated cost =  75.89003999326849
# RUN  60 , total integrated cost =  75.89003999189183
# RUN  70 , total integrated cost =  75.89003997776959
# RUN  80 , total integrated cost =  75.89003997636067
# RUN  90 , total integrated cost =  75.89003997495143
# RUN  100 , total integrated cost =  75.89003997333103
# RUN  100 , total integrated cost =  75.89003997333103
# Improved over  100  iterations in  43.45980825001607  seconds by  1.0683913558295899e-06  percent.
# cost splitting :  7.804856111126813e-06 [1.5740411e-13 3.3312557e+00]
# set cost params:  0.05 0.0 182.9624795512403
# interpolate adjoint :  True True True
# initial cost =  609.4948026925332
# RUN  0 , total integrated cost =  609.4948026925332
# Gradient descend method:  None
# RUN  1 , total integrated cost =  609.4947998623963
# RUN  2 , total integrated cost =  609.4947998621149
# RUN  3 , total integrated cost =  609.4947998619947
# RUN  4 , total integrated cost =  609.4947998615627
# RUN  5 , total integrated cost =  609.4947998612543
# RUN  6 , total integrated cost =  609.4947998049578
# RUN  7 , total integrated cost =  609.4947997559173
# RUN  8 , total integrated cost =  609.4947997555637
# RUN  9 , total integrated cost =  609.4947997553209
# RUN  10 , total integrated cost =  609.4947997374569
# RUN  11 , total integrated cost =  609.494799722318
# RUN  12 , total integrated cost =  609.4947997221227
# RUN  13 , total integrated cost =  609.4947997217847
# RUN  14 , total integrated cost =  609.4947997216686
# RUN  15 , total integrated cost =  609.4947997212915
# RUN  16 , total integrated cost =  609.4947997210236
# RUN  17 , total integrated cost =  609.4947997176317
# RUN  18 , total integrated cost =  609.4947997143356
# RUN  19 , total integrated cost =  609.4947997142162
# RUN  20 , total integrated cost =  609.4947997139071
# RUN  30 , total integrated cost =  609.4947996955666
# RUN  40 , total integrated cost =  609.4947996900796
# RUN  50 , total integrated cost =  609.4947996584998
# RUN  60 , total integrated cost =  609.4947996472454
# RUN  70 , total integrated cost =  609.4947996175123
# RUN  80 , total integrated cost =  609.4947996125497
# RUN  90 , total integrated cost =  609.4947995975185
# RUN  100 , total integrated cost =  609.4947995785528
# RUN  100 , total integrated cost =  609.4947995785528
# Improved over  100  iterations in  48.85627742501674  seconds by  5.109117182655609e-07  percent.
# cost splitting :  4.561983195930995e-05 [1.57404110e-13 3.33125567e+00]
# set cost params:  0.05 0.0 162.71984832186416
# interpolate adjoint :  True True True
# initial cost =  542.0614195315658
# RUN  0 , total integrated cost =  542.0614195315658
# Gradient descend method:  None
# RUN  1 , total integrated cost =  542.061419517521
# RUN  2 , total integrated cost =  542.0614195173291
# RUN  3 , total integrated cost =  542.0614195170198
# RUN  4 , total integrated cost =  542.0614195169074
# RUN  5 , total integrated cost =  542.0614195165838
# RUN  6 , total integrated cost =  542.0614195163786
# RUN  7 , total integrated cost =  542.0614195011716
# RUN  8 , total integrated cost =  542.0614194850418
# RUN  9 , total integrated cost =  542.0614194847846
# RUN  10 , total integrated cost =  542.0614194843896
# RUN  11 , total integrated cost =  542.0614194842758
# RUN  12 , total integrated cost =  542.0614194839826
# RUN  13 , total integrated cost =  542.0614194838154
# RUN  14 , total integrated cost =  542.0614194811129
# RUN  15 , total integrated cost =  542.0614194785176
# RUN  16 , total integrated cost =  542.0614194783635
# RUN  17 , total integrated cost =  542.0614194780837
# RUN  18 , total integrated cost =  542.0614194779721
# RUN  19 , total integrated cost =  542.0614194776431
# RUN  20 , total integrated cost =  542.0614194774442
# RUN  30 , total integrated cost =  542.0614194399301
# RUN  40 , total integrated cost =  542.0614194288137
# RUN  50 , total integrated cost =  542.061419418367
# RUN  60 , total integrated cost =  542.0614194116433
# RUN  70 , total integrated cost =  542.0614193988413
# RUN  80 , total integrated cost =  542.0614193851932
# RUN  90 , total integrated cost =  542.0614193747583
# RUN  100 , total integrated cost =  542.0614193629997
# RUN  100 , total integrated cost =  542.0614193629997
# Improved over  100  iterations in  46.83621839398984  seconds by  3.1097229680199234e-08  percent.
# cost splitting :  4.064606428263319e-05 [1.57404110e-13 3.33125567e+00]
# set cost params:  0.05 0.0 177.40409510914432
# interpolate adjoint :  True True True
# initial cost =  590.9783997316281
# RUN  0 , total integrated cost =  590.9783997316281
# Gradient descend method:  None
# RUN  1 , total integrated cost =  590.9783997227618
# RUN  2 , total integrated cost =  590.9783997226037
# RUN  3 , total integrated cost =  590.978399722324
# RUN  4 , total integrated cost =  590.9783997221679
# RUN  5 , total integrated cost =  590.9783997217006
# RUN  6 , total integrated cost =  590.9783997213682
# RUN  7 , total integrated cost =  590.9783997178131
# RUN  8 , total integrated cost =  590.9783997135257
# RUN  9 , total integrated cost =  590.97839971333
# RUN  10 , total integrated cost =  590.9783997130274
# RUN  11 , total integrated cost =  590.978399712884
# RUN  12 , total integrated cost =  590.9783997123272
# RUN  13 , total integrated cost =  590.9783997118952
# RUN  14 , total integrated cost =  590.9783997090001
# RUN  15 , total integrated cost =  590.9783997055995
# RUN  16 , total integrated cost =  590.9783997053942
# RUN  17 , total integrated cost =  590.9783997050633
# RUN  18 , total integrated cost =  590.9783997049246
# RUN  19 , total integrated cost =  590.9783997046093
# RUN  20 , total integrated cost =  590.9783997043876
# RUN  30 , total integrated cost =  590.9783996640838
# RUN  40 , total integrated cost =  590.9783996396168
# RUN  50 , total integrated cost =  590.9783996268392
# RUN  60 , total integrated cost =  590.9783995701365
# RUN  70 , total integrated cost =  590.9783995018131
# RUN  80 , total integrated cost =  590.9783994648787
# RUN  90 , total integrated cost =  590.9783994539285
# RUN  100 , total integrated cost =  590.9783994207229
# RUN  100 , total integrated cost =  590.9783994207229
# Improved over  100  iterations in  53.25201625499176  seconds by  5.260855573396839e-08  percent.
# cost splitting :  4.656389255132188e-05 [1.57404110e-13 3.33125567e+00]
# set cost params:  0.05 0.0 23.57161902191313
# interpolate adjoint :  True True True
# initial cost =  78.52309176350681
# RUN  0 , total integrated cost =  78.52309176350681
# Gradient descend method:  None
# RUN  1 , total integrated cost =  78.52309044023025
# RUN  2 , total integrated cost =  78.5230904395134
# RUN  3 , total integrated cost =  78.52309043948564
# RUN  4 , total integrated cost =  78.52309043943453
# RUN  5 , total integrated cost =  78.52309043940417
# RUN  6 , total integrated cost =  78.52309043929392
# RUN  7 , total integrated cost =  78.52309043920458
# RUN  8 , total integrated cost =  78.5230904378053
# RUN  9 , total integrated cost =  78.52309043656524
# RUN  10 , total integrated cost =  78.52309043486156
# RUN  11 , total integrated cost =  78.523090433053
# RUN  12 , total integrated cost =  78.52309043234634
# RUN  13 , total integrated cost =  78.52309043172357
# RUN  14 , total integrated cost =  78.52309043134005
# RUN  15 , total integrated cost =  78.52309043088512
# RUN  16 , total integrated cost =  78.5230904308567
# RUN  17 , total integrated cost =  78.52309043080612
# RUN  18 , total integrated cost =  78.52309043077865
# RUN  19 , total integrated cost =  78.52309043070778
# RUN  20 , total integrated cost =  78.52309043065823
# RUN  30 , total integrated cost =  78.5230904169714
# RUN  40 , total integrated cost =  78.52309041606875
# RUN  50 , total integrated cost =  78.52309040002793
# RUN  60 , total integrated cost =  78.52309038398737
# RUN  70 , total integrated cost =  78.52309036794679
# RUN  80 , total integrated cost =  78.52309035190622
# RUN  90 , total integrated cost =  78.52309033586614
# RUN  100 , total integrated cost =  78.52309031982604
# RUN  100 , total integrated cost =  78.52309031982604
# Improved over  100  iterations in  54.65678581199609  seconds by  1.8385429569889311e-06  percent.
# cost splitting :  7.960301726853587e-06 [1.57404110e-13 3.33125569e+00]
# set cost params:  0.05 0.0 154.34023958606903
# interpolate adjoint :  True True True
# initial cost =  514.1468012734314
# RUN  0 , total integrated cost =  514.1468012734314
# Gradient descend method:  None
# RUN  1 , total integrated cost =  514.1467992022831
# RUN  2 , total integrated cost =  514.1467991984181
# RUN  3 , total integrated cost =  514.1467991983129
# RUN  4 , total integrated cost =  514.1467991980238
# RUN  5 , total integrated cost =  514.1467991978659
# RUN  6 , total integrated cost =  514.146799191471
# RUN  7 , total integrated cost =  514.1467991860749
# RUN  8 , total integrated cost =  514.1467985834256
# RUN  9 , total integrated cost =  514.1467981375998
# RUN  10 , total integrated cost =  514.1467981371264
# RUN  11 , total integrated cost =  514.1467981370167
# RUN  12 , total integrated cost =  514.1467981367608
# RUN  13 , total integrated cost =  514.146798136627
# RUN  14 , total integrated cost =  514.1467981358356
# RUN  15 , total integrated cost =  514.1467981352137
# RUN  16 , total integrated cost =  514.1467980728139
# RUN  17 , total integrated cost =  514.1467980041169
# RUN  18 , total integrated cost =  514.1467980038619
# RUN  19 , total integrated cost =  514.146798003755
# RUN  20 , total integrated cost =  514.1467980033174
# RUN  30 , total integrated cost =  514.1467943425466
# RUN  40 , total integrated cost =  514.1467925945227
# RUN  50 , total integrated cost =  514.1467901846316
# RUN  60 , total integrated cost =  514.1467889725247
# RUN  70 , total integrated cost =  514.1467880602378
# RUN  80 , total integrated cost =  514.1467880199272
# RUN  90 , total integrated cost =  514.1327709325808
# RUN  100 , total integrated cost =  514.132770932042
# RUN  100 , total integrated cost =  514.132770932042
# Improved over  100  iterations in  54.688800988020375  seconds by  0.002728859025197039  percent.
# cost splitting :  3.950516060991371e-05 [1.57404110e-13 3.33116477e+00]
# set cost params:  0.05 0.0 162.3607619665754
# interpolate adjoint :  True True True
# initial cost =  540.850452536197
# RUN  0 , total integrated cost =  540.850452536197
# Gradient descend method:  None
# RUN  1 , total integrated cost =  540.8504525340085
# RUN  2 , total integrated cost =  540.8504525339973
# RUN  3 , total integrated cost =  540.8504525339176
# RUN  4 , total integrated cost =  540.8504525338118
# RUN  5 , total integrated cost =  540.8504525338054
# RUN  6 , total integrated cost =  540.8504525336668
# RUN  7 , total integrated cost =  540.8504525335701
# RUN  8 , total integrated cost =  540.8504525329214
# RUN  9 , total integrated cost =  540.8504525322518
# RUN  10 , total integrated cost =  540.8504525322444
# RUN  11 , total integrated cost =  540.8504525322187
# RUN  12 , total integrated cost =  540.8504525322072
# RUN  13 , total integrated cost =  540.8504525321116
# RUN  14 , total integrated cost =  540.8504525320343
# RUN  15 , total integrated cost =  540.8504525320194
# RUN  16 , total integrated cost =  540.8504525319897
# RUN  17 , total integrated cost =  540.8504525319842
# RUN  18 , total integrated cost =  540.8504525318127
# RUN  19 , total integrated cost =  540.8504525316736
# RUN  20 , total integrated cost =  540.8504525316666
# RUN  30 , total integrated cost =  540.8504525313699
# RUN  40 , total integrated cost =  540.8504519119364
# RUN  50 , total integrated cost =  540.850451910671
# RUN  60 , total integrated cost =  540.850451337989
# RUN  70 , total integrated cost =  540.8504512891349
# RUN  80 , total integrated cost =  540.8504511384546
# RUN  90 , total integrated cost =  540.850450996518
# RUN  100 , total integrated cost =  540.850450996165
# RUN  100 , total integrated cost =  540.850450996165
# Improved over  100  iterations in  66.70040818100097  seconds by  2.847426685548271e-07  percent.
# cost splitting :  4.119457610111744e-05 [1.57404110e-13 3.33116476e+00]
# set cost params:  0.05 0.0 103.07170247485021
# interpolate adjoint :  True True True
# initial cost =  343.3488252664209
# RUN  0 , total integrated cost =  343.3488252664209
# Gradient descend method:  None
# RUN  1 , total integrated cost =  343.3488251310695
# RUN  2 , total integrated cost =  343.3488251309401
# RUN  3 , total integrated cost =  343.3488251309354
# RUN  4 , total integrated cost =  343.34882513088775
# RUN  5 , total integrated cost =  343.34882513086245
# RUN  6 , total integrated cost =  343.34882513085734
# RUN  7 , total integrated cost =  343.3488251308339
# RUN  8 , total integrated cost =  343.34882513082306
# RUN  9 , total integrated cost =  343.34882513081607
# RUN  10 , total integrated cost =  343.34882513079657
# RUN  11 , total integrated cost =  343.34882513079066
# RUN  12 , total integrated cost =  343.34882513075155
# RUN  13 , total integrated cost =  343.34882513069255
# RUN  14 , total integrated cost =  343.3488251306882
# RUN  15 , total integrated cost =  343.3488251305926
# RUN  16 , total integrated cost =  343.34882513051934
# RUN  17 , total integrated cost =  343.34882513051394
# RUN  18 , total integrated cost =  343.34882513049416
# RUN  19 , total integrated cost =  343.3488251304873
# RUN  20 , total integrated cost =  343.3488251304599
# RUN  30 , total integrated cost =  343.34882513017493
# Control only changes marginally.
# RUN  35 , total integrated cost =  343.3480235480348
# Improved over  35  iterations in  25.294786248006858  seconds by  0.00023349967352714884  percent.
# cost splitting :  2.8127419329355148e-05 [1.57404110e-13 3.33115699e+00]
# set cost params:  0.05 0.0 168.02572292795648
# interpolate adjoint :  True True True
# initial cost =  559.7200627909583
# RUN  0 , total integrated cost =  559.7200627909583
# Gradient descend method:  None
# RUN  1 , total integrated cost =  559.7200625996719
# RUN  2 , total integrated cost =  559.720062599362
# RUN  3 , total integrated cost =  559.720062599362
# Control only changes marginally.
# RUN  3 , total integrated cost =  559.720062599362
# Improved over  3  iterations in  3.235275225015357  seconds by  3.423073735575599e-08  percent.
# cost splitting :  4.2388696577497264e-05 [1.57404110e-13 3.33115698e+00]
# set cost params:  0.05 0.0 84.21027664554585
# interpolate adjoint :  True True True
# initial cost =  280.5176533202917
# RUN  0 , total integrated cost =  280.5176533202917
# Gradient descend method:  None
# RUN  1 , total integrated cost =  280.5176530394533
# RUN  2 , total integrated cost =  280.51765303929113
# RUN  3 , total integrated cost =  280.51765303929113
# Control only changes marginally.
# RUN  3 , total integrated cost =  280.51765303929113
# Improved over  3  iterations in  2.424786994000897  seconds by  1.0017214435720234e-07  percent.
# cost splitting :  2.375799001097279e-05 [1.57404110e-13 3.33115699e+00]
# set cost params:  0.05 0.0 46.646245410348236
# interpolate adjoint :  True True True
# initial cost =  155.38596774007985
# RUN  0 , total integrated cost =  155.38596774007985
# Gradient descend method:  None
# RUN  1 , total integrated cost =  155.38596761743375
# RUN  2 , total integrated cost =  155.38596761734814
# RUN  3 , total integrated cost =  155.38596761734814
# Control only changes marginally.
# RUN  3 , total integrated cost =  155.38596761734814
# Improved over  3  iterations in  2.155016614997294  seconds by  7.898506737546995e-08  percent.
# cost splitting :  1.4438549008640788e-05 [1.5740411e-13 3.3311570e+00]
# set cost params:  0.05 0.0 115.93373408745812
# interpolate adjoint :  True True True
# initial cost =  386.19347049644983
# RUN  0 , total integrated cost =  386.19347049644983
# Gradient descend method:  None
# RUN  1 , total integrated cost =  386.193470047605
# RUN  2 , total integrated cost =  386.19347004759516
# RUN  3 , total integrated cost =  386.19347004759516
# Control only changes marginally.
# RUN  3 , total integrated cost =  386.19347004759516
# Improved over  3  iterations in  2.3087770440033637  seconds by  1.1622533691024728e-07  percent.
# cost splitting :  3.104310393822333e-05 [1.57404110e-13 3.33115699e+00]
# set cost params:  0.05 0.0 112.24298448065613
# interpolate adjoint :  True True True
# initial cost =  373.89900370250365
# RUN  0 , total integrated cost =  373.89900370250365
# Gradient descend method:  None
# RUN  1 , total integrated cost =  373.899003701837
# RUN  2 , total integrated cost =  373.899003701837
# Control only changes marginally.
# RUN  2 , total integrated cost =  373.899003701837
# Improved over  2  iterations in  1.3523770840256475  seconds by  1.7830359411163954e-10  percent.
# cost splitting :  3.0229396992027544e-05 [1.57404110e-13 3.33115699e+00]
# set cost params:  0.05 0.0 186.45387634795105
# interpolate adjoint :  True True True
# initial cost =  621.1071347865976
# RUN  0 , total integrated cost =  621.1071347865976
# Gradient descend method:  None
# RUN  1 , total integrated cost =  621.1071345625809
# RUN  2 , total integrated cost =  621.1071345624401
# RUN  3 , total integrated cost =  621.1071345624401
# Control only changes marginally.
# RUN  3 , total integrated cost =  621.1071345624401
# Improved over  3  iterations in  3.0127895859768614  seconds by  3.6089986110710015e-08  percent.
# cost splitting :  4.6250924441636237e-05 [1.57404110e-13 3.33115698e+00]
# set cost params:  0.05 0.0 181.17533578885138
# interpolate adjoint :  True True True
# initial cost =  603.5234873176444
# RUN  0 , total integrated cost =  603.5234873176444
# Gradient descend method:  None
# RUN  1 , total integrated cost =  603.5234873169123
# RUN  2 , total integrated cost =  603.5234873169111
# RUN  3 , total integrated cost =  603.5234873169073
# RUN  4 , total integrated cost =  603.5234873169073
# Control only changes marginally.
# RUN  4 , total integrated cost =  603.5234873169073
# Improved over  4  iterations in  4.081194730009884  seconds by  1.2212808542244602e-10  percent.
# cost splitting :  4.518157453775522e-05 [1.57404110e-13 3.33115698e+00]
# set cost params:  0.05 0.0 147.44897399519883
# interpolate adjoint :  True True True
# initial cost =  491.1756816986609
# RUN  0 , total integrated cost =  491.1756816986609
# Gradient descend method:  None
# RUN  1 , total integrated cost =  491.1756816631221
# RUN  2 , total integrated cost =  491.1756816631111
# RUN  3 , total integrated cost =  491.1756816631111
# Control only changes marginally.
# RUN  3 , total integrated cost =  491.1756816631111
# Improved over  3  iterations in  2.865193272999022  seconds by  7.237701993290102e-09  percent.
# cost splitting :  3.801979109456046e-05 [1.57404110e-13 3.33115699e+00]
# set cost params:  0.05 0.0 9.046417982073963
# interpolate adjoint :  True True True
# initial cost =  30.135040357765405
# RUN  0 , total integrated cost =  30.135040357765405
# Gradient descend method:  None
# RUN  1 , total integrated cost =  30.13503898352535
# RUN  2 , total integrated cost =  30.13503898260222
# RUN  3 , total integrated cost =  30.13503898260222
# Control only changes marginally.
# RUN  3 , total integrated cost =  30.13503898260222
# Improved over  3  iterations in  2.7941840040148236  seconds by  4.563336133855955e-06  percent.
# cost splitting :  3.6124645318094165e-06 [1.57404110e-13 3.33115702e+00]
# set cost params:  0.05 0.0 81.32408992684647
# interpolate adjoint :  True True True
# initial cost =  270.90331355143695
# RUN  0 , total integrated cost =  270.90331355143695
# Gradient descend method:  None
# RUN  1 , total integrated cost =  270.90331197035255
# RUN  2 , total integrated cost =  270.9033119702632
# RUN  3 , total integrated cost =  270.9033119702632
# Control only changes marginally.
# RUN  3 , total integrated cost =  270.9033119702632
# Improved over  3  iterations in  2.7166051130043343  seconds by  5.836671874703825e-07  percent.
# cost splitting :  2.30249696599356e-05 [1.57404110e-13 3.33115699e+00]
# set cost params:  0.05 0.0 138.5476380435958
# interpolate adjoint :  True True True
# initial cost =  461.5239344153858
# RUN  0 , total integrated cost =  461.5239344153858
# Gradient descend method:  None
# RUN  1 , total integrated cost =  461.5239342227417
# RUN  2 , total integrated cost =  461.52393422261866
# RUN  3 , total integrated cost =  461.52393422261866
# Control only changes marginally.
# RUN  3 , total integrated cost =  461.52393422261866
# Improved over  3  iterations in  3.1276151399943046  seconds by  4.1767520997382235e-08  percent.
# cost splitting :  3.6122397219673783e-05 [1.57404110e-13 3.33115699e+00]
# set cost params:  0.05 0.0 58.743331820182995
# interpolate adjoint :  True True True
# initial cost =  195.68326200263886
# RUN  0 , total integrated cost =  195.68326200263886
# Gradient descend method:  None
# RUN  1 , total integrated cost =  195.68326166581156
# RUN  2 , total integrated cost =  195.68326166541084
# RUN  3 , total integrated cost =  195.68326166541019
# RUN  4 , total integrated cost =  195.68326166541019
# Control only changes marginally.
# RUN  4 , total integrated cost =  195.68326166541019
# Improved over  4  iterations in  3.2605213709757663  seconds by  1.7233394089544163e-07  percent.
# cost splitting :  1.7525483201416656e-05 [1.5740411e-13 3.3311570e+00]
# set cost params:  0.05 0.0 41.0913548373186
# interpolate adjoint :  True True True
# initial cost =  136.88175503730147
# RUN  0 , total integrated cost =  136.88175503730147
# Gradient descend method:  None
# RUN  1 , total integrated cost =  136.88175499946513
# RUN  2 , total integrated cost =  136.88175499946513
# Control only changes marginally.
# RUN  2 , total integrated cost =  136.88175499946513
# Improved over  2  iterations in  1.9157884350279346  seconds by  2.764161877166771e-08  percent.
# cost splitting :  1.295807702670396e-05 [1.5740411e-13 3.3311570e+00]
# set cost params:  0.05 0.0 85.51491031069361
# interpolate adjoint :  True True True
# initial cost =  284.8635928289396
# RUN  0 , total integrated cost =  284.8635928289396
# Gradient descend method:  None
# RUN  1 , total integrated cost =  284.8635925950249
# RUN  2 , total integrated cost =  284.86359259492366
# RUN  3 , total integrated cost =  284.86359259492366
# Control only changes marginally.
# RUN  3 , total integrated cost =  284.86359259492366
# Improved over  3  iterations in  2.952224693959579  seconds by  8.215017999191332e-08  percent.
# cost splitting :  2.4035532515478856e-05 [1.57404110e-13 3.33115699e+00]
# set cost params:  0.05 0.0 149.22235772552355
# interpolate adjoint :  True True True
# initial cost =  497.08310148692004
# RUN  0 , total integrated cost =  497.08310148692004
# Gradient descend method:  None
# RUN  1 , total integrated cost =  497.08310126488215
# RUN  2 , total integrated cost =  497.08310126464914
# RUN  3 , total integrated cost =  497.08310126464914
# Control only changes marginally.
# RUN  3 , total integrated cost =  497.08310126464914
# Improved over  3  iterations in  3.4893836170085706  seconds by  4.471503700642643e-08  percent.
# cost splitting :  3.8389833117730126e-05 [1.57404110e-13 3.33115699e+00]
# set cost params:  0.05 0.0 50.851241242048644
# interpolate adjoint :  True True True
# initial cost =  169.39346940939927
# RUN  0 , total integrated cost =  169.39346940939927
# Gradient descend method:  None
# RUN  1 , total integrated cost =  169.39346891235363
# RUN  2 , total integrated cost =  169.3934689122505
# RUN  3 , total integrated cost =  169.3934689122505
# Control only changes marginally.
# RUN  3 , total integrated cost =  169.3934689122505
# Improved over  3  iterations in  3.3458831959869713  seconds by  2.934875595883568e-07  percent.
# cost splitting :  1.5545757799322236e-05 [1.5740411e-13 3.3311570e+00]
# set cost params:  0.05 0.0 113.03998136065799
# interpolate adjoint :  True True True
# initial cost =  376.55392577292406
# RUN  0 , total integrated cost =  376.55392577292406
# Gradient descend method:  None
# RUN  1 , total integrated cost =  376.5539254291557
# RUN  2 , total integrated cost =  376.5539254286297
# RUN  3 , total integrated cost =  376.5539254286297
# Control only changes marginally.
# RUN  3 , total integrated cost =  376.5539254286297
# Improved over  3  iterations in  3.4543097090208903  seconds by  9.143293766555871e-08  percent.
# cost splitting :  3.039916167129283e-05 [1.57404110e-13 3.33115699e+00]
# set cost params:  0.05 0.0 118.8505648707304
# interpolate adjoint :  True True True
# initial cost =  395.9098912964575
# RUN  0 , total integrated cost =  395.9098912964575
# Gradient descend method:  None
# RUN  1 , total integrated cost =  395.9098912948
# RUN  2 , total integrated cost =  395.9098912947984
# RUN  3 , total integrated cost =  395.9098912947984
# Control only changes marginally.
# RUN  3 , total integrated cost =  395.9098912947984
# Improved over  3  iterations in  3.098840518970974  seconds by  4.190496838418767e-10  percent.
# cost splitting :  3.1691170761627805e-05 [1.57404110e-13 3.33115699e+00]
# set cost params:  0.05 0.0 108.78568288724222
# interpolate adjoint :  True True True
# initial cost =  362.3821893409751
# RUN  0 , total integrated cost =  362.3821893409751
# Gradient descend method:  None
# RUN  1 , total integrated cost =  362.3821893361155
# RUN  2 , total integrated cost =  362.38218933611205
# RUN  3 , total integrated cost =  362.38218933611205
# Control only changes marginally.
# RUN  3 , total integrated cost =  362.38218933611205
# Improved over  3  iterations in  2.812647937971633  seconds by  1.3419736433206708e-09  percent.
# cost splitting :  2.942905306120369e-05 [1.57404110e-13 3.33115699e+00]
# set cost params:  0.05 0.0 76.21097576182405
# interpolate adjoint :  True True True
# initial cost =  253.87072602714835
# RUN  0 , total integrated cost =  253.87072602714835
# Gradient descend method:  None
# RUN  1 , total integrated cost =  253.87072596411988
# RUN  2 , total integrated cost =  253.87072596407634
# RUN  3 , total integrated cost =  253.87072596407634
# Control only changes marginally.
# RUN  3 , total integrated cost =  253.87072596407634
# Improved over  3  iterations in  3.0654931819881313  seconds by  2.4844155177561333e-08  percent.
# cost splitting :  2.1822118087282352e-05 [1.57404110e-13 3.33115699e+00]
# set cost params:  0.05 0.0 156.36450071487604
# interpolate adjoint :  True True True
# initial cost =  520.8747011467187
# RUN  0 , total integrated cost =  520.8747011467187
# Gradient descend method:  None
# RUN  1 , total integrated cost =  520.8747007739806
# RUN  2 , total integrated cost =  520.8747007739744
# RUN  3 , total integrated cost =  520.8747007739744
# Control only changes marginally.
# RUN  3 , total integrated cost =  520.8747007739744
# Improved over  3  iterations in  2.7989715519943275  seconds by  7.156123160712013e-08  percent.
# cost splitting :  3.9932995493510355e-05 [1.57404110e-13 3.33115699e+00]
# set cost params:  0.05 0.0 134.68787384946154
# interpolate adjoint :  True True True
# initial cost =  448.66645377794083
# RUN  0 , total integrated cost =  448.66645377794083
# Gradient descend method:  None
# RUN  1 , total integrated cost =  448.66645376084557
# RUN  2 , total integrated cost =  448.66645376083795
# RUN  3 , total integrated cost =  448.66645376083795
# Control only changes marginally.
# RUN  3 , total integrated cost =  448.66645376083795
# Improved over  3  iterations in  2.51356258202577  seconds by  3.811933879660501e-09  percent.
# cost splitting :  3.520303477095746e-05 [1.57404110e-13 3.33115699e+00]
# set cost params:  0.05 0.0 139.8993275589032
# interpolate adjoint :  True True True
# initial cost =  466.02662419603524
# RUN  0 , total integrated cost =  466.02662419603524
# Gradient descend method:  None
# RUN  1 , total integrated cost =  466.0266241949034
# RUN  2 , total integrated cost =  466.02662419489934
# RUN  3 , total integrated cost =  466.02662419489934
# Control only changes marginally.
# RUN  3 , total integrated cost =  466.02662419489934
# Improved over  3  iterations in  2.5809087199741043  seconds by  2.4374458007514477e-10  percent.
# cost splitting :  3.637233679571553e-05 [1.57404110e-13 3.33115699e+00]
# set cost params:  0.05 0.0 169.4654254418418
# interpolate adjoint :  True True True
# initial cost =  564.5159377152314
# RUN  0 , total integrated cost =  564.5159377152314
# Gradient descend method:  None
# RUN  1 , total integrated cost =  564.5159376838242
# RUN  2 , total integrated cost =  564.515937683774
# RUN  3 , total integrated cost =  564.515937683774
# Control only changes marginally.
# RUN  3 , total integrated cost =  564.515937683774
# Improved over  3  iterations in  2.860037898994051  seconds by  5.572459826908016e-09  percent.
# cost splitting :  4.26899695628111e-05 [1.57404110e-13 3.33115698e+00]
# set cost params:  0.05 0.0 94.69623604444536
# interpolate adjoint :  True True True
# initial cost =  315.4480302160199
# RUN  0 , total integrated cost =  315.4480302160199
# Gradient descend method:  None
# RUN  1 , total integrated cost =  315.44803000220605
# RUN  2 , total integrated cost =  315.44803000216694
# RUN  3 , total integrated cost =  315.44803000216694
# Control only changes marginally.
# RUN  3 , total integrated cost =  315.44803000216694
# Improved over  3  iterations in  2.723284460953437  seconds by  6.779340822049562e-08  percent.
# cost splitting :  2.6185399776372e-05 [1.57404110e-13 3.33115699e+00]
# set cost params:  0.05 0.0 5.700635011786701
# interpolate adjoint :  True True True
# initial cost =  18.989711480240462
# RUN  0 , total integrated cost =  18.989711480240462
# Gradient descend method:  None
# RUN  1 , total integrated cost =  18.989710528466023
# RUN  2 , total integrated cost =  18.98971052845759
# RUN  3 , total integrated cost =  18.98971052845759
# Control only changes marginally.
# RUN  3 , total integrated cost =  18.98971052845759
# Improved over  3  iterations in  2.463500190002378  seconds by  5.012097588519282e-06  percent.
# cost splitting :  2.4464663982372146e-06 [1.57404110e-13 3.33115703e+00]
# set cost params:  0.05 0.0 35.64513467493846
# interpolate adjoint :  True True True
# initial cost =  118.73954114980337
# RUN  0 , total integrated cost =  118.73954114980337
# Gradient descend method:  None
# RUN  1 , total integrated cost =  118.73954057249388
# RUN  2 , total integrated cost =  118.73954057102134
# RUN  3 , total integrated cost =  118.73954057102134
# Control only changes marginally.
# RUN  3 , total integrated cost =  118.73954057102134
# Improved over  3  iterations in  2.7745060669840313  seconds by  4.874383279229733e-07  percent.
# cost splitting :  1.1510635088540136e-05 [1.5740411e-13 3.3311570e+00]
# set cost params:  0.05 0.0 0.45036794435413574
# interpolate adjoint :  True True True
# initial cost =  1.500246907296151
# RUN  0 , total integrated cost =  1.500246907296151
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.5002463842018887
# RUN  2 , total integrated cost =  1.5002463840939297
# RUN  3 , total integrated cost =  1.500246384093883
# RUN  4 , total integrated cost =  1.500246384093883
# Control only changes marginally.
# RUN  4 , total integrated cost =  1.500246384093883
# Improved over  4  iterations in  3.2908359059947543  seconds by  3.487441071570174e-05  percent.
# cost splitting :  2.762591994838669e-07 [1.57404110e-13 3.33115709e+00]
# set cost params:  0.05 0.0 64.30484232293392
# interpolate adjoint :  True True True
# initial cost =  214.20953134450963
# RUN  0 , total integrated cost =  214.20953134450963
# Gradient descend method:  None
# RUN  1 , total integrated cost =  214.20952630048896
# RUN  2 , total integrated cost =  214.20952628438653
# RUN  3 , total integrated cost =  214.20952628438653
# Control only changes marginally.
# RUN  3 , total integrated cost =  214.20952628438653
# Improved over  3  iterations in  3.1994119189912453  seconds by  2.3622306031256812e-06  percent.
# cost splitting :  1.8924909404810666e-05 [1.5740411e-13 3.3311570e+00]
# set cost params:  0.05 0.0 186.3906035019203
# interpolate adjoint :  True True True
# initial cost =  620.8963636669174
# RUN  0 , total integrated cost =  620.8963636669174
# Gradient descend method:  None
# RUN  1 , total integrated cost =  620.896362780476
# RUN  2 , total integrated cost =  620.8963627795071
# RUN  3 , total integrated cost =  620.8963627795071
# Control only changes marginally.
# RUN  3 , total integrated cost =  620.8963627795071
# Improved over  3  iterations in  2.949295020021964  seconds by  1.4292407968241605e-07  percent.
# cost splitting :  4.6230314385667865e-05 [1.57404110e-13 3.33115698e+00]
# set cost params:  0.05 0.0 149.87628518905552
# interpolate adjoint :  True True True
# initial cost =  499.2614363429183
# RUN  0 , total integrated cost =  499.2614363429183
# Gradient descend method:  None
# RUN  1 , total integrated cost =  499.2614363029106
# RUN  2 , total integrated cost =  499.26143630284287
# RUN  3 , total integrated cost =  499.26143630284287
# Control only changes marginally.
# RUN  3 , total integrated cost =  499.26143630284287
# Improved over  3  iterations in  2.9030976670328528  seconds by  8.026930231608276e-09  percent.
# cost splitting :  3.8511128355088966e-05 [1.57404110e-13 3.33115699e+00]
# set cost params:  0.05 0.0 152.1061464302704
# interpolate adjoint :  True True True
# initial cost =  506.689454153345
# RUN  0 , total integrated cost =  506.689454153345
# Gradient descend method:  None
# RUN  1 , total integrated cost =  506.6894541531628
# RUN  2 , total integrated cost =  506.6894541531628
# Control only changes marginally.
# RUN  2 , total integrated cost =  506.6894541531628
# Improved over  2  iterations in  1.8707485609920695  seconds by  3.596767328417627e-11  percent.
# cost splitting :  3.900207871754098e-05 [1.57404110e-13 3.33115699e+00]
# set cost params:  0.05 0.0 108.48156848396744
# interpolate adjoint :  True True True
# initial cost =  361.3691365923269
# RUN  0 , total integrated cost =  361.3691365923269
# Gradient descend method:  None
# RUN  1 , total integrated cost =  361.3691365161728
# RUN  2 , total integrated cost =  361.3691365161412
# RUN  3 , total integrated cost =  361.3691365161412
# Control only changes marginally.
# RUN  3 , total integrated cost =  361.3691365161412
# Improved over  3  iterations in  3.0325237429933622  seconds by  2.1082513512737933e-08  percent.
# cost splitting :  2.9356456235279616e-05 [1.57404110e-13 3.33115699e+00]
# set cost params:  0.05 0.0 164.71174213663377
# interpolate adjoint :  True True True
# initial cost =  548.6806724798184
# RUN  0 , total integrated cost =  548.6806724798184
# Gradient descend method:  None
# RUN  1 , total integrated cost =  548.6806723401212
# RUN  2 , total integrated cost =  548.680672340019
# RUN  3 , total integrated cost =  548.680672340019
# Control only changes marginally.
# RUN  3 , total integrated cost =  548.680672340019
# Improved over  3  iterations in  3.1224368260009214  seconds by  2.5479195642219565e-08  percent.
# cost splitting :  4.174465005376663e-05 [1.57404110e-13 3.33115698e+00]
# set cost params:  0.05 0.0 46.97073133043539
# interpolate adjoint :  True True True
# initial cost =  156.46688182716136
# RUN  0 , total integrated cost =  156.46688182716136
# Gradient descend method:  None
# RUN  1 , total integrated cost =  156.4668811620315
# RUN  2 , total integrated cost =  156.4668811612373
# RUN  3 , total integrated cost =  156.4668811612373
# Control only changes marginally.
# RUN  3 , total integrated cost =  156.4668811612373
# Improved over  3  iterations in  2.4425156569923274  seconds by  4.2560064628105465e-07  percent.
# cost splitting :  1.4523913233705938e-05 [1.5740411e-13 3.3311570e+00]
# set cost params:  0.05 0.0 109.49286560969846
# interpolate adjoint :  True True True
# initial cost =  364.73792637867166
# RUN  0 , total integrated cost =  364.73792637867166
# Gradient descend method:  None
# RUN  1 , total integrated cost =  364.737926004984
# RUN  2 , total integrated cost =  364.737926004561
# RUN  3 , total integrated cost =  364.737926004561
# Control only changes marginally.
# RUN  3 , total integrated cost =  364.737926004561
# Improved over  3  iterations in  2.7403826199588366  seconds by  1.0256971449962293e-07  percent.
# cost splitting :  2.961069012627972e-05 [1.57404110e-13 3.33115699e+00]
# set cost params:  0.05 0.0 38.37159348154765
# interpolate adjoint :  True True True
# initial cost =  127.82180328658461
# RUN  0 , total integrated cost =  127.82180328658461
# Gradient descend method:  None
# RUN  1 , total integrated cost =  127.82180291702969
# RUN  2 , total integrated cost =  127.82180291666663
# RUN  3 , total integrated cost =  127.82180291666663
# Control only changes marginally.
# RUN  3 , total integrated cost =  127.82180291666663
# Improved over  3  iterations in  2.901083891047165  seconds by  2.8940131358012877e-07  percent.
# cost splitting :  1.2253607449463874e-05 [1.5740411e-13 3.3311570e+00]
# set cost params:  0.05 0.0 135.80321464852116
# interpolate adjoint :  True True True
# initial cost =  452.3818299833212
# RUN  0 , total integrated cost =  452.3818299833212
# Gradient descend method:  None
# RUN  1 , total integrated cost =  452.3818290564245
# RUN  2 , total integrated cost =  452.3818290561387
# RUN  3 , total integrated cost =  452.3818290561387
# Control only changes marginally.
# RUN  3 , total integrated cost =  452.3818290561387
# Improved over  3  iterations in  3.4653732429724187  seconds by  2.0495572528034245e-07  percent.
# cost splitting :  3.54374893848998e-05 [1.57404110e-13 3.33115699e+00]
# set cost params:  0.05 0.0 141.51223314705896
# interpolate adjoint :  True True True
# initial cost =  471.3994659143861
# RUN  0 , total integrated cost =  471.3994659143861
# Gradient descend method:  None
# RUN  1 , total integrated cost =  471.3994659130252
# RUN  2 , total integrated cost =  471.3994659130252
# Control only changes marginally.
# RUN  2 , total integrated cost =  471.3994659130252
# Improved over  2  iterations in  1.9179559819749556  seconds by  2.886935135393287e-10  percent.
# cost splitting :  3.66883757760953e-05 [1.57404110e-13 3.33115699e+00]
# set cost params:  0.05 0.0 90.35752678859642
# interpolate adjoint :  True True True
# initial cost =  300.9951084507397
# RUN  0 , total integrated cost =  300.9951084507397
# Gradient descend method:  None
# RUN  1 , total integrated cost =  300.995108332859
# RUN  2 , total integrated cost =  300.99510833275576
# RUN  3 , total integrated cost =  300.9951083327552
# RUN  4 , total integrated cost =  300.9951083327552
# Control only changes marginally.
# RUN  4 , total integrated cost =  300.9951083327552
# Improved over  4  iterations in  3.7848016100469977  seconds by  3.919814162145485e-08  percent.
# cost splitting :  2.518160028858701e-05 [1.57404110e-13 3.33115699e+00]
# set cost params:  0.05 0.0 146.03395227490643
# interpolate adjoint :  True True True
# initial cost =  486.4620223391528
# RUN  0 , total integrated cost =  486.4620223391528
# Gradient descend method:  None
# RUN  1 , total integrated cost =  486.46202217468885
# RUN  2 , total integrated cost =  486.4620221745141
# RUN  3 , total integrated cost =  486.4620221745141
# Control only changes marginally.
# RUN  3 , total integrated cost =  486.4620221745141
# Improved over  3  iterations in  4.001291506981943  seconds by  3.3844088420664775e-08  percent.
# cost splitting :  3.7724133536828507e-05 [1.57404110e-13 3.33115699e+00]
# set cost params:  0.05 0.0 90.580813459417
# interpolate adjoint :  True True True
# initial cost =  301.73891142332815
# RUN  0 , total integrated cost =  301.73891142332815
# Gradient descend method:  None
# RUN  1 , total integrated cost =  301.7389112873716
# RUN  2 , total integrated cost =  301.7389112873082
# RUN  3 , total integrated cost =  301.7389112873082
# Control only changes marginally.
# RUN  3 , total integrated cost =  301.7389112873082
# Improved over  3  iterations in  3.3400631159893237  seconds by  4.507867856773373e-08  percent.
# cost splitting :  2.5225967958198007e-05 [1.57404110e-13 3.33115699e+00]
# set cost params:  0.05 0.0 179.60734591775633
# interpolate adjoint :  True True True
# initial cost =  598.300267290253
# RUN  0 , total integrated cost =  598.300267290253
# Gradient descend method:  None
# RUN  1 , total integrated cost =  598.300266907834
# RUN  2 , total integrated cost =  598.3002669075861
# RUN  3 , total integrated cost =  598.3002669075861
# Control only changes marginally.
# RUN  3 , total integrated cost =  598.3002669075861
# Improved over  3  iterations in  2.9140355809940957  seconds by  6.39590211903851e-08  percent.
# cost splitting :  4.4811798070195414e-05 [1.57404110e-13 3.33115698e+00]
# set cost params:  0.05 0.0 10.020494256296935
# interpolate adjoint :  True True True
# initial cost =  33.37984166197889
# RUN  0 , total integrated cost =  33.37984166197889
# Gradient descend method:  None
# RUN  1 , total integrated cost =  33.37984000469453
# RUN  2 , total integrated cost =  33.37984000440037
# RUN  3 , total integrated cost =  33.379840004399156
# RUN  4 , total integrated cost =  33.379840004399156
# Control only changes marginally.
# RUN  4 , total integrated cost =  33.379840004399156
# Improved over  4  iterations in  3.1409540740423836  seconds by  4.965810646240243e-06  percent.
# cost splitting :  3.945569879435344e-06 [1.57404110e-13 3.33115702e+00]
# set cost params:  0.05 0.0 165.69086285386683
# interpolate adjoint :  True True True
# initial cost =  551.9422814964399
# RUN  0 , total integrated cost =  551.9422814964399
# Gradient descend method:  None
# RUN  1 , total integrated cost =  551.9422771707158
# RUN  2 , total integrated cost =  551.9422771559348
# RUN  3 , total integrated cost =  551.9422771558986
# RUN  4 , total integrated cost =  551.9422771558986
# Control only changes marginally.
# RUN  4 , total integrated cost =  551.9422771558986
# Improved over  4  iterations in  3.729917330958415  seconds by  7.864121727152451e-07  percent.
# cost splitting :  4.189638677749579e-05 [1.57404110e-13 3.33115698e+00]
# set cost params:  0.05 0.0 83.27227811718882
# interpolate adjoint :  True True True
# initial cost =  277.39303295890784
# RUN  0 , total integrated cost =  277.39303295890784
# Gradient descend method:  None
# RUN  1 , total integrated cost =  277.3930326829516
# RUN  2 , total integrated cost =  277.3930326829248
# RUN  3 , total integrated cost =  277.3930326829248
# Control only changes marginally.
# RUN  3 , total integrated cost =  277.3930326829248
# Improved over  3  iterations in  2.10619859903818  seconds by  9.949170021172904e-08  percent.
# cost splitting :  2.3524722454798846e-05 [1.57404110e-13 3.33115699e+00]
# set cost params:  0.05 0.0 24.984040952399685
# interpolate adjoint :  True True True
# initial cost =  83.22576388829111
# RUN  0 , total integrated cost =  83.22576388829111
# Gradient descend method:  None
# RUN  1 , total integrated cost =  83.22576353302799
# RUN  2 , total integrated cost =  83.22576353283218
# RUN  3 , total integrated cost =  83.2257635328164
# RUN  4 , total integrated cost =  83.22576353279503
# RUN  5 , total integrated cost =  83.22576353279503
# Control only changes marginally.
# RUN  5 , total integrated cost =  83.22576353279503
# Improved over  5  iterations in  2.687173762009479  seconds by  4.271466735872309e-07  percent.
# cost splitting :  8.529725518385252e-06 [1.57404110e-13 3.33115701e+00]
# set cost params:  0.05 0.0 159.85361277403115
# interpolate adjoint :  True True True
# initial cost =  532.4974828700259
# RUN  0 , total integrated cost =  532.4974828700259
# Gradient descend method:  None
# RUN  1 , total integrated cost =  532.4974807823232
# RUN  2 , total integrated cost =  532.4974807809682
# RUN  3 , total integrated cost =  532.4974807809638
# RUN  4 , total integrated cost =  532.4974807809638
# Control only changes marginally.
# RUN  4 , total integrated cost =  532.4974807809638
# Improved over  4  iterations in  3.7962160899769515  seconds by  3.923139928474484e-07  percent.
# cost splitting :  4.06599866013739e-05 [1.57404110e-13 3.33115698e+00]
# set cost params:  0.05 0.0 181.23859083961386
# interpolate adjoint :  True True True
# initial cost =  603.7341998352939
# RUN  0 , total integrated cost =  603.7341998352939
# Gradient descend method:  None
# RUN  1 , total integrated cost =  603.7341998207202
# RUN  2 , total integrated cost =  603.734199820694
# RUN  3 , total integrated cost =  603.734199820694
# Control only changes marginally.
# RUN  3 , total integrated cost =  603.734199820694
# Improved over  3  iterations in  3.1768690830213018  seconds by  2.418261146885925e-09  percent.
# cost splitting :  4.516901605564703e-05 [1.57404110e-13 3.33115698e+00]
# set cost params:  0.05 0.0 35.9535604552909
# interpolate adjoint :  True True True
# initial cost =  119.76695625220378
# RUN  0 , total integrated cost =  119.76695625220378
# Gradient descend method:  None
# RUN  1 , total integrated cost =  119.76695526919343
# RUN  2 , total integrated cost =  119.76695526907318
# RUN  3 , total integrated cost =  119.76695526907318
# Control only changes marginally.
# RUN  3 , total integrated cost =  119.76695526907318
# Improved over  3  iterations in  2.226952989003621  seconds by  8.208696584688369e-07  percent.
# cost splitting :  1.1592537904840218e-05 [1.5740411e-13 3.3311570e+00]
# set cost params:  0.05 0.0 5.906648670941673
# interpolate adjoint :  True True True
# initial cost =  19.67597466344106
# RUN  0 , total integrated cost =  19.67597466344106
# Gradient descend method:  None
# RUN  1 , total integrated cost =  19.67597437778776
# RUN  2 , total integrated cost =  19.675974377758127
# ...
# initial cost =  678.5906586005937
# RUN  0 , total integrated cost =  678.5906586005937
# Gradient descend method:  None
# RUN  1 , total integrated cost =  678.5906585990389
# RUN  2 , total integrated cost =  678.5906585990357
# RUN  3 , total integrated cost =  678.5906585989642
# RUN  4 , total integrated cost =  678.5906585988727
# RUN  5 , total integrated cost =  678.5906585988727
# Control only changes marginally.
# RUN  5 , total integrated cost =  678.5906585988727
# Improved over  5  iterations in  3.080228655016981  seconds by  2.5360691324749496e-10  percent.
# cost splitting :  1.104631845303334e-05 [4.52045174e-12 6.29422762e+00]
# set cost params:  0.05 0.0 4.264492346623007
# interpolate adjoint :  True True True
# initial cost =  26.841686058340954
# RUN  0 , total integrated cost =  26.841686058340954
# Gradient descend method:  None
# RUN  1 , total integrated cost =  26.841685617924533
# RUN  2 , total integrated cost =  26.841685617924437
# RUN  3 , total integrated cost =  26.8416856179244
# RUN  4 , total integrated cost =  26.841685617924227
# RUN  5 , total integrated cost =  26.84168561792416
# RUN  6 , total integrated cost =  26.84168561792311
# RUN  7 , total integrated cost =  26.841685617922096
# RUN  8 , total integrated cost =  26.841685617922053
# RUN  9 , total integrated cost =  26.841685617917605
# RUN  10 , total integrated cost =  26.841685617913914
# RUN  11 , total integrated cost =  26.84168561791386
# RUN  12 , total integrated cost =  26.84168561785438
# RUN  13 , total integrated cost =  26.84168561778415
# RUN  14 , total integrated cost =  26.8416856177841
# RUN  15 , total integrated cost =  26.841685617731095
# RUN  16 , total integrated cost =  26.841685617667483
# RUN  17 , total integrated cost =  26.84168561766726
# RUN  18 , total integrated cost =  26.84168561766726
# Control only changes marginally.
# RUN  18 , total integrated cost =  26.84168561766726
# Improved over  18  iterations in  9.444773972034454  seconds by  1.6417511687905062e-06  percent.
# cost splitting :  6.936779459622147e-07 [4.52045174e-12 6.29422764e+00]
# set cost params:  0.05 0.0 9.985360387494701
# interpolate adjoint :  True True True
# initial cost =  62.850131344253285
# RUN  0 , total integrated cost =  62.850131344253285
# Gradient descend method:  None
# RUN  1 , total integrated cost =  62.850131325615564
# RUN  2 , total integrated cost =  62.85013132553711
# RUN  3 , total integrated cost =  62.85013132553692
# RUN  4 , total integrated cost =  62.85013132553692
# Control only changes marginally.
# RUN  4 , total integrated cost =  62.85013132553692
# Improved over  4  iterations in  3.1863256759825163  seconds by  2.9779357646475546e-08  percent.
# cost splitting :  1.4448322172799037e-06 [4.52045174e-12 6.29422763e+00]
# set cost params:  0.05 0.0 73.73133217834136
# interpolate adjoint :  True True True
# initial cost =  464.08178831621444
# RUN  0 , total integrated cost =  464.08178831621444
# Gradient descend method:  None
# RUN  1 , total integrated cost =  464.0817878507071
# RUN  2 , total integrated cost =  464.08178784984835
# RUN  3 , total integrated cost =  464.081787849839
# RUN  4 , total integrated cost =  464.08178784983465
# RUN  5 , total integrated cost =  464.08178784983437
# RUN  6 , total integrated cost =  464.08178784982425
# RUN  7 , total integrated cost =  464.0817878498187
# RUN  8 , total integrated cost =  464.0817878498187
# Control only changes marginally.
# RUN  8 , total integrated cost =  464.0817878498187
# Improved over  8  iterations in  5.055990830005612  seconds by  1.0049861032257468e-07  percent.
# cost splitting :  8.003019155027172e-06 [4.52045174e-12 6.29422762e+00]
# set cost params:  0.05 0.0 93.66797894898622
# interpolate adjoint :  True True True
# initial cost =  589.567580601999
# RUN  0 , total integrated cost =  589.567580601999
# Gradient descend method:  None
# RUN  1 , total integrated cost =  589.5675805908187
# RUN  2 , total integrated cost =  589.5675805908181
# RUN  3 , total integrated cost =  589.5675805908181
# Control only changes marginally.
# RUN  3 , total integrated cost =  589.5675805908181
# Improved over  3  iterations in  2.0760602399823256  seconds by  1.8964527725984226e-09  percent.
# cost splitting :  9.792999637931324e-06 [4.52045174e-12 6.29422762e+00]
# set cost params:  0.05 0.0 101.86665202762138
# interpolate adjoint :  True True True
# initial cost =  641.1718951201628
# RUN  0 , total integrated cost =  641.1718951201628
# Gradient descend method:  None
# RUN  1 , total integrated cost =  641.1718951185744
# RUN  2 , total integrated cost =  641.1718951185744
# Control only changes marginally.
# RUN  2 , total integrated cost =  641.1718951185744
# Improved over  2  iterations in  1.2765066270367242  seconds by  2.4773783025011653e-10  percent.
# cost splitting :  1.0545411601194486e-05 [4.52045174e-12 6.29422762e+00]
# set cost params:  0.05 0.0 125.5297906626852
# interpolate adjoint :  True True True
# initial cost =  790.1130758546076
# RUN  0 , total integrated cost =  790.1130758546076
# Gradient descend method:  None
# RUN  1 , total integrated cost =  790.1130758437108
# RUN  2 , total integrated cost =  790.1130758436827
# RUN  3 , total integrated cost =  790.1130758436817
# RUN  4 , total integrated cost =  790.1130758436789
# RUN  5 , total integrated cost =  790.1130758436786
# RUN  6 , total integrated cost =  790.1130758436628
# RUN  7 , total integrated cost =  790.1130758436501
# RUN  8 , total integrated cost =  790.113075843649
# RUN  9 , total integrated cost =  790.1130758436462
# RUN  10 , total integrated cost =  790.1130758436462
# Control only changes marginally.
# RUN  10 , total integrated cost =  790.1130758436462
# Improved over  10  iterations in  6.620769079017919  seconds by  1.3873062698621652e-09  percent.
# cost splitting :  1.2582123497116146e-05 [4.52045174e-12 6.29422762e+00]
# set cost params:  0.05 0.0 88.70297812522793
# interpolate adjoint :  True True True
# initial cost =  558.3167353039884
# RUN  0 , total integrated cost =  558.3167353039884
# Gradient descend method:  None
# RUN  1 , total integrated cost =  558.3167352777838
# RUN  2 , total integrated cost =  558.3167352777717
# RUN  3 , total integrated cost =  558.3167352777717
# Control only changes marginally.
# RUN  3 , total integrated cost =  558.3167352777717
# Improved over  3  iterations in  2.8034121959935874  seconds by  4.6956500909800525e-09  percent.
# cost splitting :  9.359563123042662e-06 [4.52045174e-12 6.29422762e+00]
# set cost params:  0.05 0.0 40.04587878151579
# interpolate adjoint :  True True True
# initial cost =  252.0578767246243
# RUN  0 , total integrated cost =  252.0578767246243
# Gradient descend method:  None
# RUN  1 , total integrated cost =  252.05787664617282
# RUN  2 , total integrated cost =  252.0578766461321
# RUN  3 , total integrated cost =  252.05787664613194
# RUN  4 , total integrated cost =  252.05787664613194
# Control only changes marginally.
# RUN  4 , total integrated cost =  252.05787664613194
# Improved over  4  iterations in  3.4255018680123612  seconds by  3.114060120879003e-08  percent.
# cost splitting :  4.741965723096241e-06 [4.52045174e-12 6.29422762e+00]
# set cost params:  0.05 0.0 50.56631620245122
# interpolate adjoint :  True True True
# initial cost =  318.2759044657413
# RUN  0 , total integrated cost =  318.2759044657413
# Gradient descend method:  None
# RUN  1 , total integrated cost =  318.2759044592867
# RUN  2 , total integrated cost =  318.27590445927217
# RUN  3 , total integrated cost =  318.27590445927217
# Control only changes marginally.
# RUN  3 , total integrated cost =  318.27590445927217
# Improved over  3  iterations in  2.407651216024533  seconds by  2.032550128205912e-09  percent.
# cost splitting :  5.793609569340375e-06 [4.52045174e-12 6.29422762e+00]
# set cost params:  0.05 0.0 76.46704448771052
# interpolate adjoint :  True True True
# initial cost =  481.3009838547575
# RUN  0 , total integrated cost =  481.3009838547575
# Gradient descend method:  None
# RUN  1 , total integrated cost =  481.30098382738873
# RUN  2 , total integrated cost =  481.30098382733973
# RUN  3 , total integrated cost =  481.30098382733973
# Control only changes marginally.
# RUN  3 , total integrated cost =  481.30098382733973
# Improved over  3  iterations in  2.2213070500292815  seconds by  5.696591642845306e-09  percent.
# cost splitting :  8.242378038912876e-06 [4.52045174e-12 6.29422762e+00]
# set cost params:  0.05 0.0 97.36638116436977
# interpolate adjoint :  True True True
# initial cost =  612.8461659720284
# RUN  0 , total integrated cost =  612.8461659720284
# Gradient descend method:  None
# RUN  1 , total integrated cost =  612.8461659600789
# RUN  2 , total integrated cost =  612.8461659600641
# RUN  3 , total integrated cost =  612.8461659600636
# RUN  4 , total integrated cost =  612.8461656564356
# RUN  5 , total integrated cost =  612.8461654193713
# RUN  6 , total integrated cost =  612.846165419361
# RUN  7 , total integrated cost =  612.8461654193603
# RUN  8 , total integrated cost =  612.8461654193123
# RUN  9 , total integrated cost =  612.8461654192671
# RUN  10 , total integrated cost =  612.8461654192664
# RUN  11 , total integrated cost =  612.8461652936755
# RUN  12 , total integrated cost =  612.8461652032393
# RUN  13 , total integrated cost =  612.8461652031315
# RUN  14 , total integrated cost =  612.8461652031315
# Control only changes marginally.
# RUN  14 , total integrated cost =  612.8461652031315
# Improved over  14  iterations in  7.917856525979005  seconds by  1.2546328775897564e-07  percent.
# cost splitting :  1.0131734126087896e-05 [4.52045174e-12 6.29422761e+00]
# set cost params:  0.05 0.0 32.25428765923694
# interpolate adjoint :  True True True
# initial cost =  203.01582846072196
# RUN  0 , total integrated cost =  203.01582846072196
# Gradient descend method:  None
# RUN  1 , total integrated cost =  203.01582832330362
# RUN  2 , total integrated cost =  203.0158283232697
# RUN  3 , total integrated cost =  203.01582832326935
# RUN  4 , total integrated cost =  203.01582832326832
# RUN  5 , total integrated cost =  203.01582832326795
# RUN  6 , total integrated cost =  203.01582832326315
# RUN  7 , total integrated cost =  203.0158283232563
# RUN  8 , total integrated cost =  203.0158283232563
# Control only changes marginally.
# RUN  8 , total integrated cost =  203.0158283232563
# Improved over  8  iterations in  5.112832606013399  seconds by  6.771179528186622e-08  percent.
# cost splitting :  3.946922711815002e-06 [4.52045174e-12 6.29422762e+00]
# set cost params:  0.05 0.0 113.03094650725082
# interpolate adjoint :  True True True
# initial cost =  711.442505189498
# RUN  0 , total integrated cost =  711.442505189498
# Gradient descend method:  None
# RUN  1 , total integrated cost =  711.4425048916193
# RUN  2 , total integrated cost =  711.4425048914867
# RUN  3 , total integrated cost =  711.4425048914867
# Control only changes marginally.
# RUN  3 , total integrated cost =  711.4425048914867
# Improved over  3  iterations in  3.148465784965083  seconds by  4.188831326246145e-08  percent.
# cost splitting :  1.1494543337628526e-05 [4.52045174e-12 6.29422761e+00]
# set cost params:  0.05 0.0 32.04883972862214
# interpolate adjoint :  True True True
# initial cost =  201.72269247056772
# RUN  0 , total integrated cost =  201.72269247056772
# Gradient descend method:  None
# RUN  1 , total integrated cost =  201.72269228471689
# RUN  2 , total integrated cost =  201.7226922846829
# RUN  3 , total integrated cost =  201.72269228468193
# RUN  4 , total integrated cost =  201.72269228468096
# RUN  5 , total integrated cost =  201.72269228468096
# Control only changes marginally.
# RUN  5 , total integrated cost =  201.72269228468096
# Improved over  5  iterations in  4.388860230974387  seconds by  9.214964791226521e-08  percent.
# cost splitting :  3.928074962664464e-06 [4.52045174e-12 6.29422762e+00]
# set cost params:  0.05 0.0 93.58461728545903
# interpolate adjoint :  True True True
# initial cost =  589.0428827695987
# RUN  0 , total integrated cost =  589.0428827695987
# Gradient descend method:  None
# RUN  1 , total integrated cost =  589.0428825786504
# RUN  2 , total integrated cost =  589.0428825782745
# RUN  3 , total integrated cost =  589.0428825782745
# Control only changes marginally.
# RUN  3 , total integrated cost =  589.0428825782745
# Improved over  3  iterations in  2.966585293994285  seconds by  3.248050006732228e-08  percent.
# cost splitting :  9.79713105600183e-06 [4.52045174e-12 6.29422761e+00]
# set cost params:  0.05 0.0 110.39674417546101
# interpolate adjoint :  True True True
# initial cost =  694.8622358499331
# RUN  0 , total integrated cost =  694.8622358499331
# Gradient descend method:  None
# RUN  1 , total integrated cost =  694.862235843647
# RUN  2 , total integrated cost =  694.862235843647
# Control only changes marginally.
# RUN  2 , total integrated cost =  694.862235843647
# Improved over  2  iterations in  1.64673356997082  seconds by  9.046488003150444e-10  percent.
# cost splitting :  1.1274126008651766e-05 [4.52045174e-12 6.29422761e+00]
# set cost params:  0.05 0.0 4.855119561874431
# interpolate adjoint :  True True True
# initial cost =  30.559228161519155
# RUN  0 , total integrated cost =  30.559228161519155
# Gradient descend method:  None
# RUN  1 , total integrated cost =  30.5592277206921
# RUN  2 , total integrated cost =  30.559227720639704
# RUN  3 , total integrated cost =  30.55922772063962
# RUN  4 , total integrated cost =  30.559227720639406
# RUN  5 , total integrated cost =  30.559227720639125
# RUN  6 , total integrated cost =  30.55922772063883
# RUN  7 , total integrated cost =  30.55922772063883
# Control only changes marginally.
# RUN  7 , total integrated cost =  30.55922772063883
# Improved over  7  iterations in  3.2636047279811464  seconds by  1.4427076564516028e-06  percent.
# cost splitting :  7.765601262588377e-07 [4.52045174e-12 6.29422763e+00]
# set cost params:  0.05 0.0 107.58572067479528
# interpolate adjoint :  True True True
# initial cost =  677.1690154489171
# RUN  0 , total integrated cost =  677.1690154489171
# Gradient descend method:  None
# RUN  1 , total integrated cost =  677.1690141187111
# RUN  2 , total integrated cost =  677.1690141122979
# RUN  3 , total integrated cost =  677.1690141122889
# RUN  4 , total integrated cost =  677.1690141122889
# Control only changes marginally.
# RUN  4 , total integrated cost =  677.1690141122889
# Improved over  4  iterations in  3.552405998983886  seconds by  1.9738473611141671e-07  percent.
# cost splitting :  1.1032800876388103e-05 [4.52045174e-12 6.29422761e+00]
# set cost params:  0.05 0.0 117.28534056625344
# interpolate adjoint :  True True True
# initial cost =  738.220629443902
# RUN  0 , total integrated cost =  738.220629443902
# Gradient descend method:  None
# RUN  1 , total integrated cost =  738.2206294420694
# RUN  2 , total integrated cost =  738.2206294420671
# RUN  3 , total integrated cost =  738.2206294420671
# Control only changes marginally.
# RUN  3 , total integrated cost =  738.2206294420671
# Improved over  3  iterations in  1.9605384559836239  seconds by  2.4856205982359825e-10  percent.
# cost splitting :  1.1872468473527841e-05 [4.52045174e-12 6.29422761e+00]
# set cost params:  0.05 0.0 77.7937426821349
# interpolate adjoint :  True True True
# initial cost =  489.6515236741106
# RUN  0 , total integrated cost =  489.6515236741106
# Gradient descend method:  None
# RUN  1 , total integrated cost =  489.65152364088925
# RUN  2 , total integrated cost =  489.6515236408659
# RUN  3 , total integrated cost =  489.6515236408659
# Control only changes marginally.
# RUN  3 , total integrated cost =  489.6515236408659
# Improved over  3  iterations in  1.8823826300213113  seconds by  6.7894632138632005e-09  percent.
# cost splitting :  8.369531332210477e-06 [4.52045174e-12 6.29422761e+00]
# set cost params:  0.05 0.0 77.76761844470637
# interpolate adjoint :  True True True
# initial cost =  489.48709174430354
# RUN  0 , total integrated cost =  489.48709174430354
# Gradient descend method:  None
# RUN  1 , total integrated cost =  489.48709174430354
# Control only changes marginally.
# RUN  1 , total integrated cost =  489.48709174430354
# Improved over  1  iterations in  0.9434646140434779  seconds by  0.0  percent.
# cost splitting :  8.369531332210477e-06 [4.52045174e-12 6.29422761e+00]

# %%
for i in i_range:
    print("------- ", i, exc[i], inh[i])
    
    aln.params.duration = dur + dur_pre + dur_post

    time_ = np.arange(-dur_pre,round(dur+dur_post+aln.params.dt,1),aln.params.dt)
    target_ = aln.getZeroTarget()
    target_[:,0,:] = target[i][0]
    target_[:,1,:] = target[i][1]

    fig, ax = plt.subplots(2,1, constrained_layout=True, figsize = (4,4) )
    ax[1].plot(time_, bestControl_[i][0,0,:], color = 'red')
    ax[0].plot(time_, bestState_[i][0,0,:], color= 'red')
    ax[1].plot(time_, bestControl_[i][0,1,:], color = 'blue')
    ax[0].plot(time_, bestState_[i][0,1,:], color= 'blue')
    ax[0].plot(time_, target_[0,0,:], linestyle = '--', color='red')
    ax[0].plot(time_, target_[0,1,:], linestyle = '--', color='blue')
    ax[0].set_xlim(-dur_pre,dur+dur_post)
    ax[1].set_xlim(-dur_pre,dur+dur_post)
    ax[0].axvspan(dur*t_pen, dur, alpha=0.2, color='gray')
    plt.show()
# Out:
# -------  0 0.4000000000000001 0.3500000000000001
# -------  1 0.4250000000000001 0.3500000000000001
# -------  2 0.4000000000000001 0.3750000000000001
# -------  3 0.4250000000000001 0.3750000000000001
# -------  4 0.4500000000000001 0.3750000000000001
# -------  5 0.4000000000000001 0.40000000000000013
# -------  6 0.4250000000000001 0.40000000000000013
# -------  7 0.4500000000000001 0.40000000000000013
# -------  8 0.47500000000000014 0.40000000000000013
# -------  9 0.4000000000000001 0.42500000000000016
# -------  10 0.4250000000000001 0.42500000000000016
# -------  11 0.4500000000000001 0.42500000000000016
# -------  12 0.47500000000000014 0.42500000000000016
# -------  13 0.4000000000000001 0.4500000000000002
# -------  14 0.4250000000000001 0.4500000000000002
# -------  15 0.4500000000000001 0.4500000000000002
# -------  16 0.47500000000000014 0.4500000000000002
# -------  17 0.5000000000000002 0.4500000000000002
# -------  18 0.4000000000000001 0.4750000000000002
# -------  19 0.4250000000000001 0.4750000000000002
# -------  20 0.4500000000000001 0.4750000000000002
# -------  21 0.47500000000000014 0.4750000000000002
# -------  22 0.5000000000000002 0.4750000000000002
# -------  23 0.5250000000000001 0.4750000000000002
# -------  24 0.4000000000000001 0.5000000000000002
# -------  25 0.4250000000000001 0.5000000000000002
# -------  26 0.4500000000000001 0.5000000000000002
# -------  27 0.47500000000000014 0.5000000000000002
# -------  28 0.5000000000000002 0.5000000000000002
# -------  29 0.5250000000000001 0.5000000000000002
# -------  30 0.4250000000000001 0.5250000000000002
# -------  31 0.4500000000000001 0.5250000000000002
# -------  32 0.47500000000000014 0.5250000000000002
# -------  33 0.5000000000000002 0.5250000000000002
# -------  34 0.5250000000000001 0.5250000000000002
# -------  35 0.5500000000000003 0.5250000000000002
# -------  36 0.4250000000000001 0.5500000000000003
# -------  37 0.4500000000000001 0.5500000000000003
# -------  38 0.47500000000000014 0.5500000000000003
# -------  39 0.5000000000000002 0.5500000000000003
# -------  40 0.5250000000000001 0.5500000000000003
# -------  41 0.5500000000000003 0.5500000000000003
# -------  42 0.4250000000000001 0.5750000000000003
# -------  43 0.4500000000000001 0.5750000000000003
# -------  44 0.47500000000000014 0.5750000000000003
# -------  45 0.5000000000000002 0.5750000000000003
# -------  46 0.5250000000000001 0.5750000000000003
# -------  47 0.5500000000000003 0.5750000000000003
# -------  48 0.4250000000000001 0.6000000000000003
# -------  49 0.4500000000000001 0.6000000000000003
# -------  50 0.47500000000000014 0.6000000000000003
# -------  51 0.5000000000000002 0.6000000000000003
# -------  52 0.5250000000000001 0.6000000000000003
# -------  53 0.5500000000000003 0.6000000000000003
# -------  54 0.5750000000000002 0.6000000000000003
# -------  55 0.4250000000000001 0.6250000000000003
# -------  56 0.4500000000000001 0.6250000000000003
# -------  57 0.47500000000000014 0.6250000000000003
# -------  58 0.5000000000000002 0.6250000000000003
# -------  59 0.5250000000000001 0.6250000000000003
# -------  60 0.5500000000000003 0.6250000000000003
# -------  61 0.5750000000000002 0.6250000000000003
# -------  62 0.4250000000000001 0.6500000000000004
# -------  63 0.4500000000000001 0.6500000000000004
# -------  64 0.47500000000000014 0.6500000000000004
# -------  65 0.5000000000000002 0.6500000000000004
# -------  66 0.5250000000000001 0.6500000000000004
# -------  67 0.5500000000000003 0.6500000000000004
# -------  68 0.5750000000000002 0.6500000000000004
# -------  69 0.4250000000000001 0.6750000000000004
# -------  70 0.4500000000000001 0.6750000000000004
# -------  71 0.47500000000000014 0.6750000000000004
# -------  72 0.5000000000000002 0.6750000000000004
# -------  73 0.5250000000000001 0.6750000000000004
# -------  74 0.5500000000000003 0.6750000000000004
# -------  75 0.5750000000000002 0.6750000000000004
# -------  76 0.4250000000000001 0.7000000000000004
# -------  77 0.4500000000000001 0.7000000000000004
# -------  78 0.47500000000000014 0.7000000000000004
# -------  79 0.5000000000000002 0.7000000000000004
# -------  80 0.5250000000000001 0.7000000000000004
# -------  81 0.5500000000000003 0.7000000000000004
# -------  82 0.5750000000000002 0.7000000000000004
