# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import sys
import pickle

path = os.getcwd().split(os.sep + 'GUI')[0]
if path not in sys.path:
    print("not here")
    sys.path.append(path)

from neurolib.models.aln import ALNModel
from neurolib.utils import plotFunctions as plotFunc
from neurolib.utils import costFunctions as cost
import neurolib.dashboard.functions as functions
import neurolib.dashboard.data as data
    
# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2 

#path = os.path.join(os.getcwd(), "plots")
# Out:
# not here

# %%
grid_data_file = os.path.join(os.getcwd().split('data')[0], 'bi.pickle')
print(grid_data_file)
with open(grid_data_file,'rb') as f:
    load_array= pickle.load(f)
exc = load_array[0]
inh = load_array[1]
print(len(exc))
# Out:
# /home/lena/Promotion/neurolib/GUI/current/gui/bi.pickle
# 147

# %%
aln = ALNModel()
N = aln.params.N

data.set_parameters(aln)

state_vars = aln.state_vars
init_vars = aln.init_vars

##############################################################
def setinit(init_vars_, model):
    state_vars = model.state_vars
    init_vars = model.init_vars
    for iv in range(len(init_vars)):
        for sv in range(len(state_vars)):
            if state_vars[sv] in init_vars[iv]:
                #print("set init vars ", )
                if model.params[init_vars[iv]].ndim == 2:
                    model.params[init_vars[iv]][0,:] = init_vars_[sv]
                else:
                    model.params[init_vars[iv]][0] = init_vars_[sv]
                    
##############################################################               
def setmaxmincontrol(max_c_c, min_c_c, max_c_r, min_c_r):
    import numpy as np
    
    max_cntrl = np.zeros(( 6 ))
    min_cntrl = np.zeros(( 6 ))
    
    max_cntrl[0] = max_c_c
    min_cntrl[0] = min_c_c
    max_cntrl[1] = max_c_c
    min_cntrl[1] = min_c_c
    max_cntrl[2] = max_c_r
    min_cntrl[2] = min_c_r
    max_cntrl[3] = max_c_r
    min_cntrl[3] = min_c_r
    max_cntrl[4] = max_c_r
    min_cntrl[4] = min_c_r
    max_cntrl[5] = max_c_r
    min_cntrl[5] = min_c_r
            
    return max_cntrl, min_cntrl

# %%
d_array = np.arange(500., 20, -0.1)
t0_array = d_array - 20.
t_pen = np.zeros(( t0_array.shape ))
for i in range(len(t_pen)):
    t_pen[i] = t0_array[i] / d_array[i]

# %%
bestControl_ = [None] * len(exc) 
bestState_ = [None] * len(exc) 
cost_ = [None] * len(exc) 
costnode_ = [None] * len(exc) 
weights_ = [None] * len(exc) 
convergence_ = [None] * len(exc) 

initVars = [None] * len(exc)
target = [None] * len(exc)
cost_uncontrolled = [None] * len(exc)
ws = [None] * len(exc)
conv = [None] * len(exc)
conv_shift = [None] * len(exc)

# %%
file_ = '1_rect.pickle'
folder = str(os.getcwd().split('data_2')[1])
print(folder)
case = str(folder[1])
# Out:
# /1

# %%
dur_pre = 10
dur_post = 10
dur = d_array[0]

n_pre = int(np.around(dur_pre/aln.params.dt + 1.,1))
n_post = int(np.around(dur_post/aln.params.dt + 1.,1))

tol = 1e-10
start_step = 10.
c_scheme = np.zeros(( 1,1 ))
c_scheme[0,0] = 1.
u_mat = np.identity(1)
u_scheme = np.array([[1.]])

p_var = [0]
c_var = [0]
wp = 1. / (dur - t_pen[0] * dur)

if case in ['1', '2']:    # low to high
    max_I = [3., -3.]
else:
    max_I = [-3., 3.]
    
if case in ['1', '3']:    # sparsity
    factor_ws = 1.
    factor_we = 0.
else:
    factor_ws = 0.
    factor_we = 1.
    
maxC = [5., -5., 0.18, 0.]
max_cntrl, min_cntrl = setmaxmincontrol(maxC[0], maxC[1], maxC[2], maxC[3])

# %%
if os.path.isfile(file_) :
    print("file found")
    
    with open(file_,'rb') as f:
        load_array = pickle.load(f)

    bestControl_ = load_array[0]
    bestState_ = load_array[1]
    cost_ = load_array[2]
    costnode_ = load_array[3]
    weights_ = load_array[4]

# %%
# get initial parameters and target states

i_range = [20,50]

data.set_parameters(aln)

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    aln.params.duration = 3000.
    
    control0 = aln.getZeroControl()
    control0 = functions.step_control(aln, maxI_ = max_I[0])

    aln.run(control=control0)
    
    target_rates = np.zeros((2))
    target_rates[0] = aln.rates_exc[0,-1] 
    target_rates[1] = aln.rates_inh[0,-1]

    control0 = functions.step_control(aln, maxI_ = max_I[1])
    aln.run(control=control0)

    init_state_vars = np.zeros(( len(state_vars) ))
    for j in range(len(state_vars)):
        if aln.state[state_vars[j]].size == 1:
            init_state_vars[j] = aln.state[state_vars[j]][0]
        else:
            init_state_vars[j] = aln.state[state_vars[j]][0,-1]

    initVars[i] = init_state_vars
    target[i] = [target_rates[0], target_rates[1]]
# Out:
# -------  20 0.4500000000000001 0.4750000000000002
# -------  50 0.47500000000000014 0.6000000000000003

# %%
# get uncontrolled cost
data.set_parameters(aln)

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    dur = d_array[0]
    aln.params.duration = dur
    
    target_ = aln.getZeroTarget()
    target_[:,0,:] = target[i][0]
    target_[:,1,:] = target[i][1]
            
    cost.setParams(wp, 0.0, 0.0)

    setinit(initVars[i], aln)
    control0 = aln.getZeroControl()

    # "HS", "FR", "PR", "HZ"
    cgv = None
    max_it = 0

    bestControl_init_, bestState_init_, cost_init_, runtime_init_, grad_init_, phi_init_, phi1_, costnode_init_ = aln.A1(
        control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
        prec_variables_ = p_var, transition_time_ = t_pen[0])
    
    cost_uncontrolled[i] = cost_init_[0]
# Out:
# -------  20 0.4500000000000001 0.4750000000000002
# set cost params:  0.05 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  636.9058225135838
# RUN  0 , total integrated cost =  636.9058225135838
# Gradient descend method:  None
# RUN  0 , total integrated cost =  636.9058225135838
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  50 0.47500000000000014 0.6000000000000003
# set cost params:  0.05 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  797.1477718037709
# RUN  0 , total integrated cost =  797.1477718037709
# Gradient descend method:  None
# RUN  0 , total integrated cost =  797.1477718037709
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.

# %%
bad = []

# %%
cgv = None
j = 0

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    while not found_digit_1:
    
        dur = d_array[0]
        aln.params.duration = dur
        setinit(initVars[i], aln)

        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        control0 = aln.getZeroControl()
        cost.setParams(wp, 0., 100.)
        max_it = int(10)
            
        control0[0,0,2300:5000] = 3.

        bestControl_[i], bestState_[i], cost_[i], runtime_, grad_, phi_, phi1_, costnode_[i] = aln.A1(
            control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
            prec_variables_ = p_var, transition_time_ = t_pen[0])
        
        if found_exponent == False and cost_[i][-1] == 0.:
            exponent -= 1
            continue
        elif found_exponent == False and found_digit_0 == False:
            found_exponent = True
            sig_digit[0] = 9.
        elif found_exponent == True and found_digit_0 == False and cost_[i][-1] == 0.:
            sig_digit[0] -= 1.
        elif found_exponent == True and found_digit_0 == False:
            found_digit_0 = True
            sig_digit[1] = 9.
        elif found_exponent == True and found_digit_0 == True and found_digit_1 == False and cost_[i][-1] == 0.:
            sig_digit[1] -= 1.
        elif found_exponent == True and found_digit_0 == True and found_digit_1 == False:
            print("sparsity weight = ", ws[i])
            
            if True:
                plot_time_array = np.arange(0.,round(dur+aln.params.dt,1),aln.params.dt)
                target_ = aln.getZeroTarget()
                target_[:,0,:] = target[i][0]
                target_[:,1,:] = target[i][1]

                fig, ax = plt.subplots(3,1, constrained_layout=True, figsize = (4,8) )
                ax[1].plot(plot_time_array, bestControl_[i][0,0,n_pre-1:-n_post+1], color = 'red')
                ax[0].plot(plot_time_array, bestState_[i][0,0,n_pre-1:-n_post+1], color= 'red')
                ax[1].plot(plot_time_array, bestControl_[i][0,1,n_pre-1:-n_post+1], color = 'blue')
                ax[0].plot(plot_time_array, bestState_[i][0,1,n_pre-1:-n_post+1], color= 'blue')
                ax[0].plot(plot_time_array, target_[0,0,n_pre-1:-n_post+1], linestyle = '--', color='red')
                ax[0].plot(plot_time_array, target_[0,1,n_pre-1:-n_post+1], linestyle = '--', color='blue')


                ax[2].plot(plot_time_array, phi_[0,0,:], color = 'red')
                ax[2].plot(plot_time_array, phi_[0,1,:], color = 'blue')
                for k in range(3):
                    ax[k].set_xlim(0.,dur)
                    ax[k].axvspan(dur*t_pen[0], dur, alpha=0.2, color='gray')
                plt.show()

            break            

        print('uncontrolled cost : ', cost_uncontrolled[i])
        print('cost splitting : ', costnode_[i][0][0][0], costnode_[i][2][0][:2])
# Out:
# -------  6 0.4250000000000001 0.40000000000000013
# set cost params:  0.05 0.0 100000.0
# interpolate adjoint :  True True True
# initial cost =  471.9538368446909
# RUN  0 , total integrated cost =  471.9538368446909
# Gradient descend method:  None
# RUN  1 , total integrated cost =  471.9538368446909
# Control only changes marginally.
# RUN  1 , total integrated cost =  471.9538368446909
# Improved over  1  iterations in  0.2099147679982707  seconds by  0.0  percent.
# set cost params:  0.05 0.0 10000.0
# interpolate adjoint :  True True True
# initial cost =  471.9538368446909
# RUN  0 , total integrated cost =  471.9538368446909
# Gradient descend method:  None
# RUN  1 , total integrated cost =  471.9538368446909
# Control only changes marginally.
# RUN  1 , total integrated cost =  471.9538368446909
# Improved over  1  iterations in  0.20577848301036283  seconds by  0.0  percent.
# set cost params:  0.05 0.0 1000.0
# interpolate adjoint :  True True True
# initial cost =  471.9538368446909
# RUN  0 , total integrated cost =  471.9538368446909
# Gradient descend method:  None
# RUN  1 , total integrated cost =  471.9538368446909
# Control only changes marginally.
# RUN  1 , total integrated cost =  471.9538368446909
# Improved over  1  iterations in  0.2525124939857051  seconds by  0.0  percent.
# set cost params:  0.05 0.0 100.0
# interpolate adjoint :  True True True
# initial cost =  471.9538368446909
# RUN  0 , total integrated cost =  471.9538368446909
# Gradient descend method:  None
# RUN  1 , total integrated cost =  296.03117780426237
# RUN  2 , total integrated cost =  272.551649150796
# RUN  3 , total integrated cost =  258.7234348193123
# RUN  4 , total integrated cost =  250.7332390438866
# RUN  5 , total integrated cost =  243.866444656386
# RUN  6 , total integrated cost =  239.22322208883958
# RUN  7 , total integrated cost =  235.01077771937102
# RUN  8 , total integrated cost =  232.01846298594452
# RUN  9 , total integrated cost =  229.3300821442497
# RUN  10 , total integrated cost =  227.30465449350996
# RUN  10 , total integrated cost =  227.30465449350996
# Improved over  10  iterations in  1.6559909780044109  seconds by  51.837523768598864  percent.
# uncontrolled cost :  471.9538368446909
# cost splitting :  73.5919880926869 [0.         2.23625055]
# set cost params:  0.05 0.0 900.0
# interpolate adjoint :  True True True
# initial cost =  471.9538368446909
# RUN  0 , total integrated cost =  471.9538368446909
# Gradient descend method:  None
# RUN  1 , total integrated cost =  471.9538368446909
# Control only changes marginally.
# RUN  1 , total integrated cost =  471.9538368446909
# Improved over  1  iterations in  0.2105206639971584  seconds by  0.0  percent.
# uncontrolled cost :  471.9538368446909
# cost splitting :  9439.076736893785 [0. 0.]
# set cost params:  0.05 0.0 800.0
# interpolate adjoint :  True True True
# initial cost =  471.9538368446909
# RUN  0 , total integrated cost =  471.9538368446909
# Gradient descend method:  None
# RUN  1 , total integrated cost =  471.9538368446909
# Control only changes marginally.
# RUN  1 , total integrated cost =  471.9538368446909
# Improved over  1  iterations in  0.2298788369516842  seconds by  0.0  percent.
# uncontrolled cost :  471.9538368446909
# cost splitting :  9439.076736893785 [0. 0.]
# set cost params:  0.05 0.0 700.0
# interpolate adjoint :  True True True
# initial cost =  471.9538368446909
# RUN  0 , total integrated cost =  471.9538368446909
# Gradient descend method:  None
# RUN  1 , total integrated cost =  471.9538368446909
# Control only changes marginally.
# RUN  1 , total integrated cost =  471.9538368446909
# Improved over  1  iterations in  0.22261664998950437  seconds by  0.0  percent.
# uncontrolled cost :  471.9538368446909
# cost splitting :  9439.076736893785 [0. 0.]
# set cost params:  0.05 0.0 600.0
# interpolate adjoint :  True True True
# initial cost =  471.9538368446909
# RUN  0 , total integrated cost =  471.9538368446909
# Gradient descend method:  None
# RUN  1 , total integrated cost =  471.9538368446909
# Control only changes marginally.
# RUN  1 , total integrated cost =  471.9538368446909
# Improved over  1  iterations in  0.22147552197566256  seconds by  0.0  percent.
# uncontrolled cost :  471.9538368446909
# cost splitting :  9439.076736893785 [0. 0.]
# set cost params:  0.05 0.0 500.0
# interpolate adjoint :  True True True
# initial cost =  471.9538368446909
# RUN  0 , total integrated cost =  471.9538368446909
# Gradient descend method:  None
# RUN  1 , total integrated cost =  471.9538368446909
# Control only changes marginally.
# RUN  1 , total integrated cost =  471.9538368446909
# Improved over  1  iterations in  0.20785020402399823  seconds by  0.0  percent.
# uncontrolled cost :  471.9538368446909
# cost splitting :  9439.076736893785 [0. 0.]
# set cost params:  0.05 0.0 400.0
# interpolate adjoint :  True True True
# initial cost =  471.9538368446909
# RUN  0 , total integrated cost =  471.9538368446909
# Gradient descend method:  None
# RUN  1 , total integrated cost =  471.9538368446909
# Control only changes marginally.
# RUN  1 , total integrated cost =  471.9538368446909
# Improved over  1  iterations in  0.20820957905380055  seconds by  0.0  percent.
# uncontrolled cost :  471.9538368446909
# cost splitting :  9439.076736893785 [0. 0.]
# set cost params:  0.05 0.0 300.0
# interpolate adjoint :  True True True
# initial cost =  471.9538368446909
# RUN  0 , total integrated cost =  471.9538368446909
# Gradient descend method:  None
# RUN  1 , total integrated cost =  471.9538368446909
# Control only changes marginally.
# RUN  1 , total integrated cost =  471.9538368446909
# Improved over  1  iterations in  0.20771723199868575  seconds by  0.0  percent.
# uncontrolled cost :  471.9538368446909
# cost splitting :  9439.076736893785 [0. 0.]
# set cost params:  0.05 0.0 200.0
# interpolate adjoint :  True True True
# initial cost =  471.9538368446909
# RUN  0 , total integrated cost =  471.9538368446909
# Gradient descend method:  None
# RUN  1 , total integrated cost =  471.9538368446909
# Control only changes marginally.
# RUN  1 , total integrated cost =  471.9538368446909
# Improved over  1  iterations in  0.225336084025912  seconds by  0.0  percent.
# uncontrolled cost :  471.9538368446909
# cost splitting :  9439.076736893785 [0. 0.]
# set cost params:  0.05 0.0 100.0
# interpolate adjoint :  True True True
# initial cost =  471.9538368446909
# RUN  0 , total integrated cost =  471.9538368446909
# Gradient descend method:  None
# RUN  1 , total integrated cost =  296.03117780426237
# RUN  2 , total integrated cost =  272.551649150796
# RUN  3 , total integrated cost =  258.7234348193123
# RUN  4 , total integrated cost =  250.7332390438866
# RUN  5 , total integrated cost =  243.866444656386
# RUN  6 , total integrated cost =  239.22322208883958
# RUN  7 , total integrated cost =  235.01077771937102
# RUN  8 , total integrated cost =  232.01846298594452
# RUN  9 , total integrated cost =  229.3300821442497
# RUN  10 , total integrated cost =  227.30465449350996
# RUN  10 , total integrated cost =  227.30465449350996
# Improved over  10  iterations in  1.651017299038358  seconds by  51.837523768598864  percent.
# uncontrolled cost :  471.9538368446909
# cost splitting :  73.5919880926869 [0.         2.23625055]
# set cost params:  0.05 0.0 190.0
# interpolate adjoint :  True True True
# initial cost =  471.9538368446909
# RUN  0 , total integrated cost =  471.9538368446909
# Gradient descend method:  None
# RUN  1 , total integrated cost =  471.9538368446909
# Control only changes marginally.
# RUN  1 , total integrated cost =  471.9538368446909
# Improved over  1  iterations in  0.21054647699929774  seconds by  0.0  percent.
# uncontrolled cost :  471.9538368446909
# cost splitting :  9439.076736893785 [0. 0.]
# set cost params:  0.05 0.0 180.0
# interpolate adjoint :  True True True
# initial cost =  471.9538368446909
# RUN  0 , total integrated cost =  471.9538368446909
# Gradient descend method:  None
# RUN  1 , total integrated cost =  471.9538368446909
# Control only changes marginally.
# RUN  1 , total integrated cost =  471.9538368446909
# Improved over  1  iterations in  0.23320807004347444  seconds by  0.0  percent.
# uncontrolled cost :  471.9538368446909
# cost splitting :  9439.076736893785 [0. 0.]
# set cost params:  0.05 0.0 170.0
# interpolate adjoint :  True True True
# initial cost =  471.9538368446909
# RUN  0 , total integrated cost =  471.9538368446909
# Gradient descend method:  None
# RUN  1 , total integrated cost =  471.9538368446909
# Control only changes marginally.
# RUN  1 , total integrated cost =  471.9538368446909
# Improved over  1  iterations in  0.21173498302232474  seconds by  0.0  percent.
# uncontrolled cost :  471.9538368446909
# cost splitting :  9439.076736893785 [0. 0.]
# set cost params:  0.05 0.0 160.0
# interpolate adjoint :  True True True
# initial cost =  471.9538368446909
# RUN  0 , total integrated cost =  471.9538368446909
# Gradient descend method:  None
# RUN  1 , total integrated cost =  471.9538368446909
# Control only changes marginally.
# RUN  1 , total integrated cost =  471.9538368446909
# Improved over  1  iterations in  0.21091824199538678  seconds by  0.0  percent.
# uncontrolled cost :  471.9538368446909
# cost splitting :  9439.076736893785 [0. 0.]
# set cost params:  0.05 0.0 150.0
# interpolate adjoint :  True True True
# initial cost =  471.9538368446909
# RUN  0 , total integrated cost =  471.9538368446909
# Gradient descend method:  None
# RUN  1 , total integrated cost =  427.30202484179244
# RUN  2 , total integrated cost =  360.7530509768001
# RUN  3 , total integrated cost =  339.3286412108038
# RUN  4 , total integrated cost =  331.2137855045684
# RUN  5 , total integrated cost =  326.62491033570177
# RUN  6 , total integrated cost =  323.1592013440925
# RUN  7 , total integrated cost =  320.8400889885919
# RUN  8 , total integrated cost =  318.28002966030783
# RUN  9 , total integrated cost =  316.6538716073176
# RUN  10 , total integrated cost =  315.8899331506328
# RUN  11 , total integrated cost =  315.08882365740385
# RUN  12 , total integrated cost =  314.4187490025203
# RUN  13 , total integrated cost =  313.68536694802486
# RUN  14 , total integrated cost =  313.09316825759214
# RUN  15 , total integrated cost =  312.49921069737076
# RUN  16 , total integrated cost =  311.92523386365326
# RUN  17 , total integrated cost =  311.3217959108697
# RUN  18 , total integrated cost =  310.8105107990786
# RUN  19 , total integrated cost =  310.28231970110755
# RUN  20 , total integrated cost =  309.78468163017294
# RUN  30 , total integrated cost =  305.5082074418125
# RUN  40 , total integrated cost =  302.172675005197
# RUN  50 , total integrated cost =  299.3861672646511
# RUN  50 , total integrated cost =  299.3861672646511
# Improved over  50  iterations in  9.84304438403342  seconds by  36.564523075765955  percent.
# sparsity weight =  150.0
# -------  7 0.4500000000000001 0.40000000000000013
# set cost params:  0.05 0.0 100000.0
# interpolate adjoint :  True True True
# initial cost =  677.860255446574
# RUN  0 , total integrated cost =  677.860255446574
# Gradient descend method:  None
# RUN  1 , total integrated cost =  677.860255446574
# Control only changes marginally.
# RUN  1 , total integrated cost =  677.860255446574
# Improved over  1  iterations in  0.21783867402700707  seconds by  0.0  percent.
# set cost params:  0.05 0.0 10000.0
# interpolate adjoint :  True True True
# initial cost =  677.860255446574
# RUN  0 , total integrated cost =  677.860255446574
# Gradient descend method:  None
# RUN  1 , total integrated cost =  677.860255446574
# Control only changes marginally.
# RUN  1 , total integrated cost =  677.860255446574
# Improved over  1  iterations in  0.2181123520131223  seconds by  0.0  percent.
# set cost params:  0.05 0.0 1000.0
# interpolate adjoint :  True True True
# initial cost =  677.860255446574
# RUN  0 , total integrated cost =  677.860255446574
# Gradient descend method:  None
# RUN  1 , total integrated cost =  677.860255446574
# Control only changes marginally.
# RUN  1 , total integrated cost =  677.860255446574
# Improved over  1  iterations in  0.2191135140019469  seconds by  0.0  percent.
# set cost params:  0.05 0.0 100.0
# interpolate adjoint :  True True True
# initial cost =  677.860255446574
# RUN  0 , total integrated cost =  677.860255446574
# Gradient descend method:  None
# RUN  1 , total integrated cost =  262.0905722561684
# RUN  2 , total integrated cost =  239.68238608685658
# RUN  3 , total integrated cost =  224.4302384816147
# RUN  4 , total integrated cost =  215.24164844312574
# RUN  5 , total integrated cost =  199.878455271055
# RUN  6 , total integrated cost =  195.71390326994705
# RUN  7 , total integrated cost =  193.0899276805582
# RUN  8 , total integrated cost =  190.74521126389928
# RUN  9 , total integrated cost =  188.2378923262701
# RUN  10 , total integrated cost =  186.25041856116616
# RUN  10 , total integrated cost =  186.25041856116616
# Improved over  10  iterations in  1.2080566200311296  seconds by  72.52377358538826  percent.
# uncontrolled cost :  677.860255446574
# cost splitting :  100.51822662122866 [0.54747546 1.26476961]
# set cost params:  0.05 0.0 900.0
# interpolate adjoint :  True True True
# initial cost =  677.860255446574
# RUN  0 , total integrated cost =  677.860255446574
# Gradient descend method:  None
# RUN  1 , total integrated cost =  677.860255446574
# Control only changes marginally.
# RUN  1 , total integrated cost =  677.860255446574
# Improved over  1  iterations in  0.21780696895439178  seconds by  0.0  percent.
# uncontrolled cost :  677.860255446574
# cost splitting :  13557.2051089315 [0. 0.]
# set cost params:  0.05 0.0 800.0
# interpolate adjoint :  True True True
# initial cost =  677.860255446574
# RUN  0 , total integrated cost =  677.860255446574
# Gradient descend method:  None
# RUN  1 , total integrated cost =  677.860255446574
# Control only changes marginally.
# RUN  1 , total integrated cost =  677.860255446574
# Improved over  1  iterations in  0.2176260880078189  seconds by  0.0  percent.
# uncontrolled cost :  677.860255446574
# cost splitting :  13557.2051089315 [0. 0.]
# set cost params:  0.05 0.0 700.0
# interpolate adjoint :  True True True
# initial cost =  677.860255446574
# RUN  0 , total integrated cost =  677.860255446574
# Gradient descend method:  None
# RUN  1 , total integrated cost =  677.860255446574
# Control only changes marginally.
# RUN  1 , total integrated cost =  677.860255446574
# Improved over  1  iterations in  0.2169721649843268  seconds by  0.0  percent.
# uncontrolled cost :  677.860255446574
# cost splitting :  13557.2051089315 [0. 0.]
# set cost params:  0.05 0.0 600.0
# interpolate adjoint :  True True True
# initial cost =  677.860255446574
# RUN  0 , total integrated cost =  677.860255446574
# Gradient descend method:  None
# RUN  1 , total integrated cost =  677.860255446574
# Control only changes marginally.
# RUN  1 , total integrated cost =  677.860255446574
# Improved over  1  iterations in  0.21862199599854648  seconds by  0.0  percent.
# uncontrolled cost :  677.860255446574
# cost splitting :  13557.2051089315 [0. 0.]
# set cost params:  0.05 0.0 500.0
# interpolate adjoint :  True True True
# initial cost =  677.860255446574
# RUN  0 , total integrated cost =  677.860255446574
# Gradient descend method:  None
# RUN  1 , total integrated cost =  677.860255446574
# Control only changes marginally.
# RUN  1 , total integrated cost =  677.860255446574
# Improved over  1  iterations in  0.21804492198862135  seconds by  0.0  percent.
# uncontrolled cost :  677.860255446574
# cost splitting :  13557.2051089315 [0. 0.]
# set cost params:  0.05 0.0 400.0
# interpolate adjoint :  True True True
# initial cost =  677.860255446574
# RUN  0 , total integrated cost =  677.860255446574
# Gradient descend method:  None
# RUN  1 , total integrated cost =  677.860255446574
# Control only changes marginally.
# RUN  1 , total integrated cost =  677.860255446574
# Improved over  1  iterations in  0.21755967498756945  seconds by  0.0  percent.
# uncontrolled cost :  677.860255446574
# cost splitting :  13557.2051089315 [0. 0.]
# set cost params:  0.05 0.0 300.0
# interpolate adjoint :  True True True
# initial cost =  677.860255446574
# RUN  0 , total integrated cost =  677.860255446574
# Gradient descend method:  None
# RUN  1 , total integrated cost =  677.860255446574
# Control only changes marginally.
# RUN  1 , total integrated cost =  677.860255446574
# Improved over  1  iterations in  0.21881512395339087  seconds by  0.0  percent.
# uncontrolled cost :  677.860255446574
# cost splitting :  13557.2051089315 [0. 0.]
# set cost params:  0.05 0.0 200.0
# interpolate adjoint :  True True True
# initial cost =  677.860255446574
# RUN  0 , total integrated cost =  677.860255446574
# Gradient descend method:  None
# RUN  1 , total integrated cost =  482.3724278685749
# RUN  2 , total integrated cost =  432.40399224568915
# RUN  3 , total integrated cost =  402.7150824338135
# RUN  4 , total integrated cost =  386.52392970362814
# RUN  5 , total integrated cost =  373.47728771562777
# RUN  6 , total integrated cost =  365.02859931976104
# RUN  7 , total integrated cost =  357.75154279204844
# RUN  8 , total integrated cost =  352.7023700574302
# RUN  9 , total integrated cost =  347.85298950788115
# RUN  10 , total integrated cost =  344.2384908524344
# RUN  10 , total integrated cost =  344.2384908524344
# Improved over  10  iterations in  1.7162707019597292  seconds by  49.216894177451046  percent.
# uncontrolled cost :  677.860255446574
# cost splitting :  291.920640701538 [0.         1.64821229]
# set cost params:  0.05 0.0 290.0
# interpolate adjoint :  True True True
# initial cost =  677.860255446574
# RUN  0 , total integrated cost =  677.860255446574
# Gradient descend method:  None
# RUN  1 , total integrated cost =  661.7601101110383
# RUN  2 , total integrated cost =  593.3386015750206
# RUN  3 , total integrated cost =  554.1732671519181
# RUN  4 , total integrated cost =  534.6640980144783
# RUN  5 , total integrated cost =  518.2097360069952
# RUN  6 , total integrated cost =  507.5226463474892
# RUN  7 , total integrated cost =  495.14590645919
# RUN  8 , total integrated cost =  485.7084373757936
# RUN  9 , total integrated cost =  475.95037189110127
# RUN  10 , total integrated cost =  467.8723190209618
# RUN  11 , total integrated cost =  442.5900048646822
# RUN  12 , total integrated cost =  431.95040684831804
# RUN  13 , total integrated cost =  419.85340673848316
# RUN  14 , total integrated cost =  413.67644284573373
# RUN  15 , total integrated cost =  410.10106649096195
# RUN  16 , total integrated cost =  407.32757985995687
# RUN  17 , total integrated cost =  385.58950121015977
# RUN  18 , total integrated cost =  384.17300024097796
# RUN  19 , total integrated cost =  382.7341029271509
# RUN  20 , total integrated cost =  381.6280326426404
# RUN  30 , total integrated cost =  373.9563990886805
# RUN  40 , total integrated cost =  369.2170474798484
# RUN  50 , total integrated cost =  365.2547271267323
# RUN  50 , total integrated cost =  365.2547271267323
# Improved over  50  iterations in  8.016963889996987  seconds by  46.116515285867784  percent.
# sparsity weight =  290.0
# -------  8 0.47500000000000014 0.40000000000000013
# set cost params:  0.05 0.0 100000.0
# interpolate adjoint :  True True True
# initial cost =  877.5573911507829
# RUN  0 , total integrated cost =  877.5573911507829
# Gradient descend method:  None
# RUN  1 , total integrated cost =  877.5573911507829
# Control only changes marginally.
# RUN  1 , total integrated cost =  877.5573911507829
# Improved over  1  iterations in  0.23596694401931018  seconds by  0.0  percent.
# set cost params:  0.05 0.0 10000.0
# interpolate adjoint :  True True True
# initial cost =  877.5573911507829
# RUN  0 , total integrated cost =  877.5573911507829
# Gradient descend method:  None
# RUN  1 , total integrated cost =  877.5573911507829
# Control only changes marginally.
# RUN  1 , total integrated cost =  877.5573911507829
# Improved over  1  iterations in  0.25310960999922827  seconds by  0.0  percent.
# set cost params:  0.05 0.0 1000.0
# interpolate adjoint :  True True True
# initial cost =  877.5573911507829
# RUN  0 , total integrated cost =  877.5573911507829
# Gradient descend method:  None
# RUN  1 , total integrated cost =  877.5573911507829
# Control only changes marginally.
# RUN  1 , total integrated cost =  877.5573911507829
# Improved over  1  iterations in  0.23615306004649028  seconds by  0.0  percent.
# set cost params:  0.05 0.0 100.0
# interpolate adjoint :  True True True
# initial cost =  877.5573911507829
# RUN  0 , total integrated cost =  877.5573911507829
# Gradient descend method:  None
# RUN  1 , total integrated cost =  194.83246778879325
# RUN  2 , total integrated cost =  181.8943573221798
# RUN  3 , total integrated cost =  155.54290268664337
# RUN  4 , total integrated cost =  144.5278154906761
# RUN  5 , total integrated cost =  140.02318391545603
# RUN  6 , total integrated cost =  134.35740653553395
# RUN  7 , total integrated cost =  130.79348849750778
# RUN  8 , total integrated cost =  126.32100493653401
# RUN  9 , total integrated cost =  122.7217902178182
# RUN  10 , total integrated cost =  99.09121897548978
# RUN  10 , total integrated cost =  99.09121897548978
# Improved over  10  iterations in  1.168447442993056  seconds by  88.70829190492638  percent.
# uncontrolled cost :  877.5573911507829
# cost splitting :  255.18664574465873 [0.29572708 0.56759179]
# set cost params:  0.05 0.0 900.0
# interpolate adjoint :  True True True
# initial cost =  877.5573911507829
# RUN  0 , total integrated cost =  877.5573911507829
# Gradient descend method:  None
# RUN  1 , total integrated cost =  877.5573911507829
# Control only changes marginally.
# RUN  1 , total integrated cost =  877.5573911507829
# Improved over  1  iterations in  0.23698305297875777  seconds by  0.0  percent.
# uncontrolled cost :  877.5573911507829
# cost splitting :  17551.147823015737 [0. 0.]
# set cost params:  0.05 0.0 800.0
# interpolate adjoint :  True True True
# initial cost =  877.5573911507829
# RUN  0 , total integrated cost =  877.5573911507829
# Gradient descend method:  None
# RUN  1 , total integrated cost =  877.5573911507829
# Control only changes marginally.
# RUN  1 , total integrated cost =  877.5573911507829
# Improved over  1  iterations in  0.23367103596683592  seconds by  0.0  percent.
# uncontrolled cost :  877.5573911507829
# cost splitting :  17551.147823015737 [0. 0.]
# set cost params:  0.05 0.0 700.0
# interpolate adjoint :  True True True
# initial cost =  877.5573911507829
# RUN  0 , total integrated cost =  877.5573911507829
# Gradient descend method:  None
# RUN  1 , total integrated cost =  877.5573911507829
# Control only changes marginally.
# RUN  1 , total integrated cost =  877.5573911507829
# Improved over  1  iterations in  0.2345326020149514  seconds by  0.0  percent.
# uncontrolled cost :  877.5573911507829
# cost splitting :  17551.147823015737 [0. 0.]
# set cost params:  0.05 0.0 600.0
# interpolate adjoint :  True True True
# initial cost =  877.5573911507829
# RUN  0 , total integrated cost =  877.5573911507829
# Gradient descend method:  None
# RUN  1 , total integrated cost =  877.5573911507829
# Control only changes marginally.
# RUN  1 , total integrated cost =  877.5573911507829
# Improved over  1  iterations in  0.2352444669813849  seconds by  0.0  percent.
# uncontrolled cost :  877.5573911507829
# cost splitting :  17551.147823015737 [0. 0.]
# set cost params:  0.05 0.0 500.0
# interpolate adjoint :  True True True
# initial cost =  877.5573911507829
# RUN  0 , total integrated cost =  877.5573911507829
# Gradient descend method:  None
# RUN  1 , total integrated cost =  784.2039818073939
# RUN  2 , total integrated cost =  657.616626174753
# RUN  3 , total integrated cost =  534.3763278952489
# RUN  4 , total integrated cost =  438.65004146743104
# RUN  5 , total integrated cost =  424.794362442353
# RUN  6 , total integrated cost =  410.33035635668034
# RUN  7 , total integrated cost =  400.49266657355304
# RUN  8 , total integrated cost =  389.43532303563853
# RUN  9 , total integrated cost =  381.7164221692287
# RUN  10 , total integrated cost =  371.86700722321785
# RUN  10 , total integrated cost =  371.86700722321785
# Improved over  10  iterations in  1.1094871269888245  seconds by  57.624764947216626  percent.
# uncontrolled cost :  877.5573911507829
# cost splitting :  689.4271915141403 [0.33623412 0.33855717]
# set cost params:  0.05 0.0 590.0
# interpolate adjoint :  True True True
# initial cost =  877.5573911507829
# RUN  0 , total integrated cost =  877.5573911507829
# Gradient descend method:  None
# RUN  1 , total integrated cost =  877.5573911507829
# Control only changes marginally.
# RUN  1 , total integrated cost =  877.5573911507829
# Improved over  1  iterations in  0.22986787999980152  seconds by  0.0  percent.
# uncontrolled cost :  877.5573911507829
# cost splitting :  17551.147823015737 [0. 0.]
# set cost params:  0.05 0.0 580.0
# interpolate adjoint :  True True True
# initial cost =  877.5573911507829
# RUN  0 , total integrated cost =  877.5573911507829
# Gradient descend method:  None
# RUN  1 , total integrated cost =  877.5573911507829
# Control only changes marginally.
# RUN  1 , total integrated cost =  877.5573911507829
# Improved over  1  iterations in  0.2272346299723722  seconds by  0.0  percent.
# uncontrolled cost :  877.5573911507829
# cost splitting :  17551.147823015737 [0. 0.]
# set cost params:  0.05 0.0 570.0
# interpolate adjoint :  True True True
# initial cost =  877.5573911507829
# RUN  0 , total integrated cost =  877.5573911507829
# Gradient descend method:  None
# RUN  1 , total integrated cost =  867.2689641518876
# RUN  2 , total integrated cost =  725.2163016946354
# RUN  3 , total integrated cost =  524.221424011195
# RUN  4 , total integrated cost =  436.01557953258157
# RUN  5 , total integrated cost =  352.15900817778896
# RUN  6 , total integrated cost =  336.4492621694781
# RUN  7 , total integrated cost =  329.01756909339304
# RUN  8 , total integrated cost =  321.34196301511435
# RUN  9 , total integrated cost =  316.60516148796876
# RUN  10 , total integrated cost =  311.15094187461034
# RUN  11 , total integrated cost =  307.35245155943403
# RUN  12 , total integrated cost =  303.3694630419463
# RUN  13 , total integrated cost =  300.7682783119021
# RUN  14 , total integrated cost =  297.9521980678489
# RUN  15 , total integrated cost =  295.9420170390022
# RUN  16 , total integrated cost =  293.6965879290781
# RUN  17 , total integrated cost =  292.19057659128157
# RUN  18 , total integrated cost =  290.5154776774059
# RUN  19 , total integrated cost =  289.22252120616724
# RUN  20 , total integrated cost =  287.732291648401
# RUN  30 , total integrated cost =  275.75098121476924
# RUN  40 , total integrated cost =  264.7660125456298
# RUN  50 , total integrated cost =  237.58171883312625
# RUN  50 , total integrated cost =  237.58171883312625
# Improved over  50  iterations in  6.127187714970205  seconds by  72.92693090743911  percent.
# sparsity weight =  570.0
# -------  9 0.4000000000000001 0.42500000000000016
# set cost params:  0.05 0.0 100000.0
# interpolate adjoint :  True True True
# initial cost =  232.11379765972552
# RUN  0 , total integrated cost =  232.11379765972552
# Gradient descend method:  None
# RUN  1 , total integrated cost =  232.11379765972552
# Control only changes marginally.
# RUN  1 , total integrated cost =  232.11379765972552
# Improved over  1  iterations in  0.17158008000114933  seconds by  0.0  percent.
# set cost params:  0.05 0.0 10000.0
# interpolate adjoint :  True True True
# initial cost =  232.11379765972552
# RUN  0 , total integrated cost =  232.11379765972552
# Gradient descend method:  None
# RUN  1 , total integrated cost =  232.11379765972552
# Control only changes marginally.
# RUN  1 , total integrated cost =  232.11379765972552
# Improved over  1  iterations in  0.1652965940302238  seconds by  0.0  percent.
# set cost params:  0.05 0.0 1000.0
# interpolate adjoint :  True True True
# initial cost =  232.11379765972552
# RUN  0 , total integrated cost =  232.11379765972552
# Gradient descend method:  None
# RUN  1 , total integrated cost =  232.11379765972552
# Control only changes marginally.
# RUN  1 , total integrated cost =  232.11379765972552
# Improved over  1  iterations in  0.16429472499294207  seconds by  0.0  percent.
# set cost params:  0.05 0.0 100.0
# interpolate adjoint :  True True True
# initial cost =  232.11379765972552
# RUN  0 , total integrated cost =  232.11379765972552
# Gradient descend method:  None
# RUN  1 , total integrated cost =  232.11379765972552
# Control only changes marginally.
# RUN  1 , total integrated cost =  232.11379765972552
# Improved over  1  iterations in  0.1665884520043619  seconds by  0.0  percent.
# set cost params:  0.05 0.0 10.0
# interpolate adjoint :  True True True
# initial cost =  232.11379765972552
# RUN  0 , total integrated cost =  232.11379765972552
# Gradient descend method:  None
# RUN  1 , total integrated cost =  232.11379765972552
# Control only changes marginally.
# RUN  1 , total integrated cost =  232.11379765972552
# Improved over  1  iterations in  0.16643687203759328  seconds by  0.0  percent.
# set cost params:  0.05 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  232.11379765972552
# RUN  0 , total integrated cost =  232.11379765972552
# Gradient descend method:  None
# RUN  1 , total integrated cost =  232.11379765972552
# Control only changes marginally.
# RUN  1 , total integrated cost =  232.11379765972552
# Improved over  1  iterations in  0.17004892497789115  seconds by  0.0  percent.
# set cost params:  0.05 0.0 0.1
# interpolate adjoint :  True True True
# initial cost =  232.11379765972552
# RUN  0 , total integrated cost =  232.11379765972552
# Gradient descend method:  None
# RUN  1 , total integrated cost =  232.11379765972552
# Control only changes marginally.
# RUN  1 , total integrated cost =  232.11379765972552
# Improved over  1  iterations in  0.16507394396467134  seconds by  0.0  percent.
# set cost params:  0.05 0.0 0.01
# interpolate adjoint :  True True True
# initial cost =  232.11379765972552
# RUN  0 , total integrated cost =  232.11379765972552
# Gradient descend method:  None
# RUN  1 , total integrated cost =  51.46395134932605
# RUN  2 , total integrated cost =  2.0527152887069082
# RUN  3 , total integrated cost =  0.7477333827326895
# RUN  4 , total integrated cost =  0.33918669778058363
# RUN  5 , total integrated cost =  0.2010895463888837
# RUN  6 , total integrated cost =  0.14200527080248015
# RUN  7 , total integrated cost =  0.12750490375765827
# RUN  8 , total integrated cost =  0.11787596437218334
# RUN  9 , total integrated cost =  0.11490115867817047
# RUN  10 , total integrated cost =  0.11361880408132771
# RUN  10 , total integrated cost =  0.11361880408132771
# Improved over  10  iterations in  1.0453145090141334  seconds by  99.95105038768618  percent.
# uncontrolled cost :  232.11379765972552
# cost splitting :  0.18025130510050633 [ 0.3171243  10.14349959]
# set cost params:  0.05 0.0 0.09
# interpolate adjoint :  True True True
# initial cost =  232.11379765972552
# RUN  0 , total integrated cost =  232.11379765972552
# Gradient descend method:  None
# RUN  1 , total integrated cost =  232.11379765972552
# Control only changes marginally.
# RUN  1 , total integrated cost =  232.11379765972552
# Improved over  1  iterations in  0.1715861629927531  seconds by  0.0  percent.
# uncontrolled cost :  232.11379765972552
# cost splitting :  4642.275953194519 [0. 0.]
# set cost params:  0.05 0.0 0.08
# interpolate adjoint :  True True True
# initial cost =  232.11379765972552
# RUN  0 , total integrated cost =  232.11379765972552
# Gradient descend method:  None
# RUN  1 , total integrated cost =  232.11379765972552
# Control only changes marginally.
# RUN  1 , total integrated cost =  232.11379765972552
# Improved over  1  iterations in  0.16696275101276115  seconds by  0.0  percent.
# uncontrolled cost :  232.11379765972552
# cost splitting :  4642.275953194519 [0. 0.]
# set cost params:  0.05 0.0 0.07
# interpolate adjoint :  True True True
# initial cost =  232.11379765972552
# RUN  0 , total integrated cost =  232.11379765972552
# Gradient descend method:  None
# RUN  1 , total integrated cost =  232.11379765972552
# Control only changes marginally.
# RUN  1 , total integrated cost =  232.11379765972552
# Improved over  1  iterations in  0.16582782397745177  seconds by  0.0  percent.
# uncontrolled cost :  232.11379765972552
# cost splitting :  4642.275953194519 [0. 0.]
# set cost params:  0.05 0.0 0.06
# interpolate adjoint :  True True True
# initial cost =  232.11379765972552
# RUN  0 , total integrated cost =  232.11379765972552
# Gradient descend method:  None
# RUN  1 , total integrated cost =  232.11379765972552
# Control only changes marginally.
# RUN  1 , total integrated cost =  232.11379765972552
# Improved over  1  iterations in  0.16484022204531357  seconds by  0.0  percent.
# uncontrolled cost :  232.11379765972552
# cost splitting :  4642.275953194519 [0. 0.]
# set cost params:  0.05 0.0 0.05
# interpolate adjoint :  True True True
# initial cost =  232.11379765972552
# RUN  0 , total integrated cost =  232.11379765972552
# Gradient descend method:  None
# RUN  1 , total integrated cost =  232.11379765972552
# Control only changes marginally.
# RUN  1 , total integrated cost =  232.11379765972552
# Improved over  1  iterations in  0.16578525496879593  seconds by  0.0  percent.
# uncontrolled cost :  232.11379765972552
# cost splitting :  4642.275953194519 [0. 0.]
# set cost params:  0.05 0.0 0.04
# interpolate adjoint :  True True True
# initial cost =  232.11379765972552
# RUN  0 , total integrated cost =  232.11379765972552
# Gradient descend method:  None
# RUN  1 , total integrated cost =  232.11379765972552
# Control only changes marginally.
# RUN  1 , total integrated cost =  232.11379765972552
# Improved over  1  iterations in  0.165018305007834  seconds by  0.0  percent.
# uncontrolled cost :  232.11379765972552
# cost splitting :  4642.275953194519 [0. 0.]
# set cost params:  0.05 0.0 0.03
# interpolate adjoint :  True True True
# initial cost =  232.11379765972552
# RUN  0 , total integrated cost =  232.11379765972552
# Gradient descend method:  None
# RUN  1 , total integrated cost =  232.11379765972552
# Control only changes marginally.
# RUN  1 , total integrated cost =  232.11379765972552
# Improved over  1  iterations in  0.16643442801432684  seconds by  0.0  percent.
# uncontrolled cost :  232.11379765972552
# cost splitting :  4642.275953194519 [0. 0.]
# set cost params:  0.05 0.0 0.02
# interpolate adjoint :  True True True
# initial cost =  232.11379765972552
# RUN  0 , total integrated cost =  232.11379765972552
# Gradient descend method:  None
# RUN  1 , total integrated cost =  232.11379765972552
# Control only changes marginally.
# RUN  1 , total integrated cost =  232.11379765972552
# Improved over  1  iterations in  0.16453435202129185  seconds by  0.0  percent.
# uncontrolled cost :  232.11379765972552
# cost splitting :  4642.275953194519 [0. 0.]
# set cost params:  0.05 0.0 0.01
# interpolate adjoint :  True True True
# initial cost =  232.11379765972552
# RUN  0 , total integrated cost =  232.11379765972552
# Gradient descend method:  None
# RUN  1 , total integrated cost =  51.46395134932605
# RUN  2 , total integrated cost =  2.0527152887069082
# RUN  3 , total integrated cost =  0.7477333827326895
# RUN  4 , total integrated cost =  0.33918669778058363
# RUN  5 , total integrated cost =  0.2010895463888837
# RUN  6 , total integrated cost =  0.14200527080248015
# RUN  7 , total integrated cost =  0.12750490375765827
# RUN  8 , total integrated cost =  0.11787596437218334
# RUN  9 , total integrated cost =  0.11490115867817047
# RUN  10 , total integrated cost =  0.11361880408132771
# RUN  10 , total integrated cost =  0.11361880408132771
# Improved over  10  iterations in  1.0740926580037922  seconds by  99.95105038768618  percent.
# uncontrolled cost :  232.11379765972552
# cost splitting :  0.18025130510050633 [ 0.3171243  10.14349959]
# set cost params:  0.05 0.0 0.019000000000000003
# interpolate adjoint :  True True True
# initial cost =  232.11379765972552
# RUN  0 , total integrated cost =  232.11379765972552
# Gradient descend method:  None
# RUN  1 , total integrated cost =  232.11379765972552
# Control only changes marginally.
# RUN  1 , total integrated cost =  232.11379765972552
# Improved over  1  iterations in  0.17003856698283926  seconds by  0.0  percent.
# uncontrolled cost :  232.11379765972552
# cost splitting :  4642.275953194519 [0. 0.]
# set cost params:  0.05 0.0 0.018000000000000002
# interpolate adjoint :  True True True
# initial cost =  232.11379765972552
# RUN  0 , total integrated cost =  232.11379765972552
# Gradient descend method:  None
# RUN  1 , total integrated cost =  232.11379765972552
# Control only changes marginally.
# RUN  1 , total integrated cost =  232.11379765972552
# Improved over  1  iterations in  0.16936589102260768  seconds by  0.0  percent.
# uncontrolled cost :  232.11379765972552
# cost splitting :  4642.275953194519 [0. 0.]
# set cost params:  0.05 0.0 0.017
# interpolate adjoint :  True True True
# initial cost =  232.11379765972552
# RUN  0 , total integrated cost =  232.11379765972552
# Gradient descend method:  None
# RUN  1 , total integrated cost =  232.11379765972552
# Control only changes marginally.
# RUN  1 , total integrated cost =  232.11379765972552
# Improved over  1  iterations in  0.17258284700801596  seconds by  0.0  percent.
# uncontrolled cost :  232.11379765972552
# cost splitting :  4642.275953194519 [0. 0.]
# set cost params:  0.05 0.0 0.016
# interpolate adjoint :  True True True
# initial cost =  232.11379765972552
# RUN  0 , total integrated cost =  232.11379765972552
# Gradient descend method:  None
# RUN  1 , total integrated cost =  51.48633237848877
# RUN  2 , total integrated cost =  2.1132655530278357
# RUN  3 , total integrated cost =  0.8082969585745245
# RUN  4 , total integrated cost =  0.4028263417951928
# RUN  5 , total integrated cost =  0.2633086277321818
# RUN  6 , total integrated cost =  0.20483629765221076
# RUN  7 , total integrated cost =  0.19009232485025718
# RUN  8 , total integrated cost =  0.1806247803706751
# RUN  9 , total integrated cost =  0.1774346952498425
# RUN  10 , total integrated cost =  0.17513986272934667
# RUN  11 , total integrated cost =  0.17395831060259168
# RUN  12 , total integrated cost =  0.1730763324897092
# RUN  13 , total integrated cost =  0.17221615473928406
# RUN  14 , total integrated cost =  0.17130254688923072
# RUN  15 , total integrated cost =  0.17037696197475302
# RUN  16 , total integrated cost =  0.1693756649640503
# RUN  17 , total integrated cost =  0.1683618842117524
# RUN  18 , total integrated cost =  0.1675303915363407
# RUN  19 , total integrated cost =  0.16671222650606818
# RUN  20 , total integrated cost =  0.16577118681733563
# RUN  30 , total integrated cost =  0.15783686573742203
# RUN  40 , total integrated cost =  0.1512923583418941
# RUN  50 , total integrated cost =  0.1412624832676739
# RUN  50 , total integrated cost =  0.1412624832676739
# Improved over  50  iterations in  5.3742103049880825  seconds by  99.93914085043977  percent.
# sparsity weight =  0.016
# -------  10 0.4250000000000001 0.42500000000000016
# set cost params:  0.05 0.0 100000.0
# interpolate adjoint :  True True True
# initial cost =  455.57282451055954
# RUN  0 , total integrated cost =  455.57282451055954
# Gradient descend method:  None
# RUN  1 , total integrated cost =  455.57282451055954
# Control only changes marginally.
# RUN  1 , total integrated cost =  455.57282451055954
# Improved over  1  iterations in  0.1851065589580685  seconds by  0.0  percent.
# set cost params:  0.05 0.0 10000.0
# interpolate adjoint :  True True True
# initial cost =  455.57282451055954
# RUN  0 , total integrated cost =  455.57282451055954
# Gradient descend method:  None
# RUN  1 , total integrated cost =  455.57282451055954
# Control only changes marginally.
# RUN  1 , total integrated cost =  455.57282451055954
# Improved over  1  iterations in  0.18391718802740797  seconds by  0.0  percent.
# set cost params:  0.05 0.0 1000.0
# interpolate adjoint :  True True True
# initial cost =  455.57282451055954
# RUN  0 , total integrated cost =  455.57282451055954
# Gradient descend method:  None
# RUN  1 , total integrated cost =  455.57282451055954
# Control only changes marginally.
# RUN  1 , total integrated cost =  455.57282451055954
# Improved over  1  iterations in  0.18481462297495455  seconds by  0.0  percent.
# set cost params:  0.05 0.0 100.0
# interpolate adjoint :  True True True
# initial cost =  455.57282451055954
# RUN  0 , total integrated cost =  455.57282451055954
# Gradient descend method:  None
# RUN  1 , total integrated cost =  451.9447119248756
# RUN  2 , total integrated cost =  334.37844749007314
# RUN  3 , total integrated cost =  328.0190753011506
# RUN  4 , total integrated cost =  325.2606377322863
# RUN  5 , total integrated cost =  323.95429710533455
# RUN  6 , total integrated cost =  323.0050890097465
# RUN  7 , total integrated cost =  322.0973779795126
# RUN  8 , total integrated cost =  321.2345146663566
# RUN  9 , total integrated cost =  318.56171124234976
# RUN  10 , total integrated cost =  316.5806484417977
# RUN  10 , total integrated cost =  316.5806484417977
# Improved over  10  iterations in  1.207566642027814  seconds by  30.50932114269257  percent.
# uncontrolled cost :  455.57282451055954
# cost splitting :  94.62024451506217 [1.2289221  1.88957426]
# set cost params:  0.05 0.0 900.0
# interpolate adjoint :  True True True
# initial cost =  455.57282451055954
# RUN  0 , total integrated cost =  455.57282451055954
# Gradient descend method:  None
# RUN  1 , total integrated cost =  455.57282451055954
# Control only changes marginally.
# RUN  1 , total integrated cost =  455.57282451055954
# Improved over  1  iterations in  0.19616971199866384  seconds by  0.0  percent.
# uncontrolled cost :  455.57282451055954
# cost splitting :  9111.456490211245 [0. 0.]
# set cost params:  0.05 0.0 800.0
# interpolate adjoint :  True True True
# initial cost =  455.57282451055954
# RUN  0 , total integrated cost =  455.57282451055954
# Gradient descend method:  None
# RUN  1 , total integrated cost =  455.57282451055954
# Control only changes marginally.
# RUN  1 , total integrated cost =  455.57282451055954
# Improved over  1  iterations in  0.18753688602009788  seconds by  0.0  percent.
# uncontrolled cost :  455.57282451055954
# cost splitting :  9111.456490211245 [0. 0.]
# set cost params:  0.05 0.0 700.0
# interpolate adjoint :  True True True
# initial cost =  455.57282451055954
# RUN  0 , total integrated cost =  455.57282451055954
# Gradient descend method:  None
# RUN  1 , total integrated cost =  455.57282451055954
# Control only changes marginally.
# RUN  1 , total integrated cost =  455.57282451055954
# Improved over  1  iterations in  0.1863759359694086  seconds by  0.0  percent.
# uncontrolled cost :  455.57282451055954
# cost splitting :  9111.456490211245 [0. 0.]
# set cost params:  0.05 0.0 600.0
# interpolate adjoint :  True True True
# initial cost =  455.57282451055954
# RUN  0 , total integrated cost =  455.57282451055954
# Gradient descend method:  None
# RUN  1 , total integrated cost =  455.57282451055954
# Control only changes marginally.
# RUN  1 , total integrated cost =  455.57282451055954
# Improved over  1  iterations in  0.18746523599838838  seconds by  0.0  percent.
# uncontrolled cost :  455.57282451055954
# cost splitting :  9111.456490211245 [0. 0.]
# set cost params:  0.05 0.0 500.0
# interpolate adjoint :  True True True
# initial cost =  455.57282451055954
# RUN  0 , total integrated cost =  455.57282451055954
# Gradient descend method:  None
# RUN  1 , total integrated cost =  455.57282451055954
# Control only changes marginally.
# RUN  1 , total integrated cost =  455.57282451055954
# Improved over  1  iterations in  0.19045014400035143  seconds by  0.0  percent.
# uncontrolled cost :  455.57282451055954
# cost splitting :  9111.456490211245 [0. 0.]
# set cost params:  0.05 0.0 400.0
# interpolate adjoint :  True True True
# initial cost =  455.57282451055954
# RUN  0 , total integrated cost =  455.57282451055954
# Gradient descend method:  None
# RUN  1 , total integrated cost =  455.57282451055954
# Control only changes marginally.
# RUN  1 , total integrated cost =  455.57282451055954
# Improved over  1  iterations in  0.19716633297502995  seconds by  0.0  percent.
# uncontrolled cost :  455.57282451055954
# cost splitting :  9111.456490211245 [0. 0.]
# set cost params:  0.05 0.0 300.0
# interpolate adjoint :  True True True
# initial cost =  455.57282451055954
# RUN  0 , total integrated cost =  455.57282451055954
# Gradient descend method:  None
# RUN  1 , total integrated cost =  455.57282451055954
# Control only changes marginally.
# RUN  1 , total integrated cost =  455.57282451055954
# Improved over  1  iterations in  0.19483679597033188  seconds by  0.0  percent.
# uncontrolled cost :  455.57282451055954
# cost splitting :  9111.456490211245 [0. 0.]
# set cost params:  0.05 0.0 200.0
# interpolate adjoint :  True True True
# initial cost =  455.57282451055954
# RUN  0 , total integrated cost =  455.57282451055954
# Gradient descend method:  None
# RUN  1 , total integrated cost =  455.57282451055954
# Control only changes marginally.
# RUN  1 , total integrated cost =  455.57282451055954
# Improved over  1  iterations in  0.1976679340004921  seconds by  0.0  percent.
# uncontrolled cost :  455.57282451055954
# cost splitting :  9111.456490211245 [0. 0.]
# set cost params:  0.05 0.0 100.0
# interpolate adjoint :  True True True
# initial cost =  455.57282451055954
# RUN  0 , total integrated cost =  455.57282451055954
# Gradient descend method:  None
# RUN  1 , total integrated cost =  451.9447119248756
# RUN  2 , total integrated cost =  334.37844749007314
# RUN  3 , total integrated cost =  328.0190753011506
# RUN  4 , total integrated cost =  325.2606377322863
# RUN  5 , total integrated cost =  323.95429710533455
# RUN  6 , total integrated cost =  323.0050890097465
# RUN  7 , total integrated cost =  322.0973779795126
# RUN  8 , total integrated cost =  321.2345146663566
# RUN  9 , total integrated cost =  318.56171124234976
# RUN  10 , total integrated cost =  316.5806484417977
# RUN  10 , total integrated cost =  316.5806484417977
# Improved over  10  iterations in  1.2268579070223495  seconds by  30.50932114269257  percent.
# uncontrolled cost :  455.57282451055954
# cost splitting :  94.62024451506217 [1.2289221  1.88957426]
# set cost params:  0.05 0.0 190.0
# interpolate adjoint :  True True True
# initial cost =  455.57282451055954
# RUN  0 , total integrated cost =  455.57282451055954
# Gradient descend method:  None
# RUN  1 , total integrated cost =  455.57282451055954
# Control only changes marginally.
# RUN  1 , total integrated cost =  455.57282451055954
# Improved over  1  iterations in  0.19584286102326587  seconds by  0.0  percent.
# uncontrolled cost :  455.57282451055954
# cost splitting :  9111.456490211245 [0. 0.]
# set cost params:  0.05 0.0 180.0
# interpolate adjoint :  True True True
# initial cost =  455.57282451055954
# RUN  0 , total integrated cost =  455.57282451055954
# Gradient descend method:  None
# RUN  1 , total integrated cost =  455.57282451055954
# Control only changes marginally.
# RUN  1 , total integrated cost =  455.57282451055954
# Improved over  1  iterations in  0.18439376895548776  seconds by  0.0  percent.
# uncontrolled cost :  455.57282451055954
# cost splitting :  9111.456490211245 [0. 0.]
# set cost params:  0.05 0.0 170.0
# interpolate adjoint :  True True True
# initial cost =  455.57282451055954
# RUN  0 , total integrated cost =  455.57282451055954
# Gradient descend method:  None
# RUN  1 , total integrated cost =  455.57282451055954
# Control only changes marginally.
# RUN  1 , total integrated cost =  455.57282451055954
# Improved over  1  iterations in  0.18796031700912863  seconds by  0.0  percent.
# uncontrolled cost :  455.57282451055954
# cost splitting :  9111.456490211245 [0. 0.]
# set cost params:  0.05 0.0 160.0
# interpolate adjoint :  True True True
# initial cost =  455.57282451055954
# RUN  0 , total integrated cost =  455.57282451055954
# Gradient descend method:  None
# RUN  1 , total integrated cost =  455.57282451055954
# Control only changes marginally.
# RUN  1 , total integrated cost =  455.57282451055954
# Improved over  1  iterations in  0.19439649797277525  seconds by  0.0  percent.
# uncontrolled cost :  455.57282451055954
# cost splitting :  9111.456490211245 [0. 0.]
# set cost params:  0.05 0.0 150.0
# interpolate adjoint :  True True True
# initial cost =  455.57282451055954
# RUN  0 , total integrated cost =  455.57282451055954
# Gradient descend method:  None
# RUN  1 , total integrated cost =  455.57282451055954
# Control only changes marginally.
# RUN  1 , total integrated cost =  455.57282451055954
# Improved over  1  iterations in  0.20264394796686247  seconds by  0.0  percent.
# uncontrolled cost :  455.57282451055954
# cost splitting :  9111.456490211245 [0. 0.]
# set cost params:  0.05 0.0 140.0
# ...
# RUN  5 , total integrated cost =  45.74917240358735
# RUN  6 , total integrated cost =  41.980333645195486
# RUN  7 , total integrated cost =  38.79506995174244
# RUN  8 , total integrated cost =  35.43386671739306
# RUN  9 , total integrated cost =  32.62858471349584
# RUN  10 , total integrated cost =  29.615915126625993
# RUN  10 , total integrated cost =  29.615915126625993
# Improved over  10  iterations in  1.5359592059976421  seconds by  83.86563308437695  percent.
# uncontrolled cost :  183.55796221510641
# cost splitting :  592.3148731958207 [0.45462721 5.26093396]
# set cost params:  0.05 0.0 3.9000000000000006e-05
# interpolate adjoint :  True True True
# initial cost =  183.55796221510641
# RUN  0 , total integrated cost =  183.55796221510641
# Gradient descend method:  None
# RUN  1 , total integrated cost =  183.55796221510641
# Control only changes marginally.
# RUN  1 , total integrated cost =  183.55796221510641
# Improved over  1  iterations in  0.12997396104037762  seconds by  0.0  percent.
# uncontrolled cost :  183.55796221510641
# cost splitting :  3671.159244302156 [0. 0.]
# set cost params:  0.05 0.0 3.8e-05
# interpolate adjoint :  True True True
# initial cost =  183.55796221510641
# RUN  0 , total integrated cost =  183.55796221510641
# Gradient descend method:  None
# RUN  1 , total integrated cost =  88.78494104684962
# RUN  2 , total integrated cost =  70.53762475979704
# RUN  3 , total integrated cost =  68.01621605084775
# RUN  4 , total integrated cost =  65.50140264207229
# RUN  5 , total integrated cost =  64.13265728884592
# RUN  6 , total integrated cost =  62.67334059436783
# RUN  7 , total integrated cost =  60.33418412208582
# RUN  8 , total integrated cost =  57.76549711561263
# RUN  9 , total integrated cost =  56.42890119292992
# RUN  10 , total integrated cost =  55.05758261024732
# RUN  11 , total integrated cost =  53.88178552022199
# RUN  12 , total integrated cost =  52.76132887362312
# RUN  13 , total integrated cost =  51.33171691597162
# RUN  14 , total integrated cost =  49.95463876612142
# RUN  15 , total integrated cost =  48.850279976409425
# RUN  16 , total integrated cost =  47.797489382868584
# RUN  17 , total integrated cost =  46.821515349546964
# RUN  18 , total integrated cost =  45.8959625430413
# RUN  19 , total integrated cost =  45.01302564238546
# RUN  20 , total integrated cost =  44.128221970308154
# RUN  30 , total integrated cost =  36.01216501124234
# RUN  40 , total integrated cost =  28.309701649242154
# RUN  50 , total integrated cost =  22.62521932096091
# RUN  50 , total integrated cost =  22.62521932096091
# Improved over  50  iterations in  5.860125167993829  seconds by  87.6740736016414  percent.
# sparsity weight =  3.8e-05
# -------  19 0.4250000000000001 0.4750000000000002
# set cost params:  0.05 0.0 100000.0
# interpolate adjoint :  True True True
# initial cost =  425.17584252715665
# RUN  0 , total integrated cost =  425.17584252715665
# Gradient descend method:  None
# RUN  1 , total integrated cost =  425.17584252715665
# Control only changes marginally.
# RUN  1 , total integrated cost =  425.17584252715665
# Improved over  1  iterations in  0.1580287119722925  seconds by  0.0  percent.
# set cost params:  0.05 0.0 10000.0
# interpolate adjoint :  True True True
# initial cost =  425.17584252715665
# RUN  0 , total integrated cost =  425.17584252715665
# Gradient descend method:  None
# RUN  1 , total integrated cost =  425.17584252715665
# Control only changes marginally.
# RUN  1 , total integrated cost =  425.17584252715665
# Improved over  1  iterations in  0.16004982497543097  seconds by  0.0  percent.
# set cost params:  0.05 0.0 1000.0
# interpolate adjoint :  True True True
# initial cost =  425.17584252715665
# RUN  0 , total integrated cost =  425.17584252715665
# Gradient descend method:  None
# RUN  1 , total integrated cost =  425.17584252715665
# Control only changes marginally.
# RUN  1 , total integrated cost =  425.17584252715665
# Improved over  1  iterations in  0.16000278398860246  seconds by  0.0  percent.
# set cost params:  0.05 0.0 100.0
# interpolate adjoint :  True True True
# initial cost =  425.17584252715665
# RUN  0 , total integrated cost =  425.17584252715665
# Gradient descend method:  None
# RUN  1 , total integrated cost =  425.17584252715665
# Control only changes marginally.
# RUN  1 , total integrated cost =  425.17584252715665
# Improved over  1  iterations in  0.1563864320050925  seconds by  0.0  percent.
# set cost params:  0.05 0.0 10.0
# interpolate adjoint :  True True True
# initial cost =  425.17584252715665
# RUN  0 , total integrated cost =  425.17584252715665
# Gradient descend method:  None
# RUN  1 , total integrated cost =  425.17584252715665
# Control only changes marginally.
# RUN  1 , total integrated cost =  425.17584252715665
# Improved over  1  iterations in  0.1576476779882796  seconds by  0.0  percent.
# set cost params:  0.05 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  425.17584252715665
# RUN  0 , total integrated cost =  425.17584252715665
# Gradient descend method:  None
# RUN  1 , total integrated cost =  425.17584252715665
# Control only changes marginally.
# RUN  1 , total integrated cost =  425.17584252715665
# Improved over  1  iterations in  0.15868804999627173  seconds by  0.0  percent.
# set cost params:  0.05 0.0 0.1
# interpolate adjoint :  True True True
# initial cost =  425.17584252715665
# RUN  0 , total integrated cost =  425.17584252715665
# Gradient descend method:  None
# RUN  1 , total integrated cost =  425.17584252715665
# Control only changes marginally.
# RUN  1 , total integrated cost =  425.17584252715665
# Improved over  1  iterations in  0.18532759899972007  seconds by  0.0  percent.
# set cost params:  0.05 0.0 0.01
# interpolate adjoint :  True True True
# initial cost =  425.17584252715665
# RUN  0 , total integrated cost =  425.17584252715665
# Gradient descend method:  None
# RUN  1 , total integrated cost =  425.17584252715665
# Control only changes marginally.
# RUN  1 , total integrated cost =  425.17584252715665
# Improved over  1  iterations in  0.17230500699952245  seconds by  0.0  percent.
# set cost params:  0.05 0.0 0.001
# interpolate adjoint :  True True True
# initial cost =  425.17584252715665
# RUN  0 , total integrated cost =  425.17584252715665
# Gradient descend method:  None
# RUN  1 , total integrated cost =  106.01733217886216
# RUN  2 , total integrated cost =  0.43846364026735446
# RUN  3 , total integrated cost =  0.1388174175550648
# RUN  4 , total integrated cost =  0.08063803110433312
# RUN  5 , total integrated cost =  0.05756105352716163
# RUN  6 , total integrated cost =  0.0442542731467119
# RUN  7 , total integrated cost =  0.0365715579199589
# RUN  8 , total integrated cost =  0.03161869700101561
# RUN  9 , total integrated cost =  0.028390856630231304
# RUN  10 , total integrated cost =  0.026050893330500376
# RUN  10 , total integrated cost =  0.026050893330500376
# Improved over  10  iterations in  1.3190523909870535  seconds by  99.99387291310445  percent.
# uncontrolled cost :  425.17584252715665
# cost splitting :  0.2404991151480802 [ 0.52798605 13.49795152]
# set cost params:  0.05 0.0 0.009000000000000001
# interpolate adjoint :  True True True
# initial cost =  425.17584252715665
# RUN  0 , total integrated cost =  425.17584252715665
# Gradient descend method:  None
# RUN  1 , total integrated cost =  425.17584252715665
# Control only changes marginally.
# RUN  1 , total integrated cost =  425.17584252715665
# Improved over  1  iterations in  0.18452624301426113  seconds by  0.0  percent.
# uncontrolled cost :  425.17584252715665
# cost splitting :  8503.516850543185 [0. 0.]
# set cost params:  0.05 0.0 0.008
# interpolate adjoint :  True True True
# initial cost =  425.17584252715665
# RUN  0 , total integrated cost =  425.17584252715665
# Gradient descend method:  None
# RUN  1 , total integrated cost =  425.17584252715665
# Control only changes marginally.
# RUN  1 , total integrated cost =  425.17584252715665
# Improved over  1  iterations in  0.1754823209485039  seconds by  0.0  percent.
# uncontrolled cost :  425.17584252715665
# cost splitting :  8503.516850543185 [0. 0.]
# set cost params:  0.05 0.0 0.007
# interpolate adjoint :  True True True
# initial cost =  425.17584252715665
# RUN  0 , total integrated cost =  425.17584252715665
# Gradient descend method:  None
# RUN  1 , total integrated cost =  425.17584252715665
# Control only changes marginally.
# RUN  1 , total integrated cost =  425.17584252715665
# Improved over  1  iterations in  0.17715608997968957  seconds by  0.0  percent.
# uncontrolled cost :  425.17584252715665
# cost splitting :  8503.516850543185 [0. 0.]
# set cost params:  0.05 0.0 0.006
# interpolate adjoint :  True True True
# initial cost =  425.17584252715665
# RUN  0 , total integrated cost =  425.17584252715665
# Gradient descend method:  None
# RUN  1 , total integrated cost =  425.17584252715665
# Control only changes marginally.
# RUN  1 , total integrated cost =  425.17584252715665
# Improved over  1  iterations in  0.17070339299971238  seconds by  0.0  percent.
# uncontrolled cost :  425.17584252715665
# cost splitting :  8503.516850543185 [0. 0.]
# set cost params:  0.05 0.0 0.005
# interpolate adjoint :  True True True
# initial cost =  425.17584252715665
# RUN  0 , total integrated cost =  425.17584252715665
# Gradient descend method:  None
# RUN  1 , total integrated cost =  425.17584252715665
# Control only changes marginally.
# RUN  1 , total integrated cost =  425.17584252715665
# Improved over  1  iterations in  0.17125766701065004  seconds by  0.0  percent.
# uncontrolled cost :  425.17584252715665
# cost splitting :  8503.516850543185 [0. 0.]
# set cost params:  0.05 0.0 0.004
# interpolate adjoint :  True True True
# initial cost =  425.17584252715665
# RUN  0 , total integrated cost =  425.17584252715665
# Gradient descend method:  None
# RUN  1 , total integrated cost =  425.17584252715665
# Control only changes marginally.
# RUN  1 , total integrated cost =  425.17584252715665
# Improved over  1  iterations in  0.1651184359798208  seconds by  0.0  percent.
# uncontrolled cost :  425.17584252715665
# cost splitting :  8503.516850543185 [0. 0.]
# set cost params:  0.05 0.0 0.003
# interpolate adjoint :  True True True
# initial cost =  425.17584252715665
# RUN  0 , total integrated cost =  425.17584252715665
# Gradient descend method:  None
# RUN  1 , total integrated cost =  425.17584252715665
# Control only changes marginally.
# RUN  1 , total integrated cost =  425.17584252715665
# Improved over  1  iterations in  0.17312979901907966  seconds by  0.0  percent.
# uncontrolled cost :  425.17584252715665
# cost splitting :  8503.516850543185 [0. 0.]
# set cost params:  0.05 0.0 0.002
# interpolate adjoint :  True True True
# initial cost =  425.17584252715665
# RUN  0 , total integrated cost =  425.17584252715665
# Gradient descend method:  None
# RUN  1 , total integrated cost =  425.17584252715665
# Control only changes marginally.
# RUN  1 , total integrated cost =  425.17584252715665
# Improved over  1  iterations in  0.20533248002175242  seconds by  0.0  percent.
# uncontrolled cost :  425.17584252715665
# cost splitting :  8503.516850543185 [0. 0.]
# set cost params:  0.05 0.0 0.001
# interpolate adjoint :  True True True
# initial cost =  425.17584252715665
# RUN  0 , total integrated cost =  425.17584252715665
# Gradient descend method:  None
# RUN  1 , total integrated cost =  106.01733217886216
# RUN  2 , total integrated cost =  0.43846364026735446
# RUN  3 , total integrated cost =  0.1388174175550648
# RUN  4 , total integrated cost =  0.08063803110433312
# RUN  5 , total integrated cost =  0.05756105352716163
# RUN  6 , total integrated cost =  0.0442542731467119
# RUN  7 , total integrated cost =  0.0365715579199589
# RUN  8 , total integrated cost =  0.03161869700101561
# RUN  9 , total integrated cost =  0.028390856630231304
# RUN  10 , total integrated cost =  0.026050893330500376
# RUN  10 , total integrated cost =  0.026050893330500376
# Improved over  10  iterations in  1.3931018939474598  seconds by  99.99387291310445  percent.
# uncontrolled cost :  425.17584252715665
# cost splitting :  0.2404991151480802 [ 0.52798605 13.49795152]
# set cost params:  0.05 0.0 0.0019000000000000002
# interpolate adjoint :  True True True
# initial cost =  425.17584252715665
# RUN  0 , total integrated cost =  425.17584252715665
# Gradient descend method:  None
# RUN  1 , total integrated cost =  425.17584252715665
# Control only changes marginally.
# RUN  1 , total integrated cost =  425.17584252715665
# Improved over  1  iterations in  0.19289747497532517  seconds by  0.0  percent.
# uncontrolled cost :  425.17584252715665
# cost splitting :  8503.516850543185 [0. 0.]
# set cost params:  0.05 0.0 0.0018
# interpolate adjoint :  True True True
# initial cost =  425.17584252715665
# RUN  0 , total integrated cost =  425.17584252715665
# Gradient descend method:  None
# RUN  1 , total integrated cost =  425.17584252715665
# Control only changes marginally.
# RUN  1 , total integrated cost =  425.17584252715665
# Improved over  1  iterations in  0.16978799499338493  seconds by  0.0  percent.
# uncontrolled cost :  425.17584252715665
# cost splitting :  8503.516850543185 [0. 0.]
# set cost params:  0.05 0.0 0.0017000000000000001
# interpolate adjoint :  True True True
# initial cost =  425.17584252715665
# RUN  0 , total integrated cost =  425.17584252715665
# Gradient descend method:  None
# RUN  1 , total integrated cost =  425.17584252715665
# Control only changes marginally.
# RUN  1 , total integrated cost =  425.17584252715665
# Improved over  1  iterations in  0.15819968603318557  seconds by  0.0  percent.
# uncontrolled cost :  425.17584252715665
# cost splitting :  8503.516850543185 [0. 0.]
# set cost params:  0.05 0.0 0.0016
# interpolate adjoint :  True True True
# initial cost =  425.17584252715665
# RUN  0 , total integrated cost =  425.17584252715665
# Gradient descend method:  None
# RUN  1 , total integrated cost =  425.17584252715665
# Control only changes marginally.
# RUN  1 , total integrated cost =  425.17584252715665
# Improved over  1  iterations in  0.16331019304925576  seconds by  0.0  percent.
# uncontrolled cost :  425.17584252715665
# cost splitting :  8503.516850543185 [0. 0.]
# set cost params:  0.05 0.0 0.0015
# interpolate adjoint :  True True True
# initial cost =  425.17584252715665
# RUN  0 , total integrated cost =  425.17584252715665
# Gradient descend method:  None
# RUN  1 , total integrated cost =  425.17584252715665
# Control only changes marginally.
# RUN  1 , total integrated cost =  425.17584252715665
# Improved over  1  iterations in  0.16209765302482992  seconds by  0.0  percent.
# uncontrolled cost :  425.17584252715665
# cost splitting :  8503.516850543185 [0. 0.]
# set cost params:  0.05 0.0 0.0014
# interpolate adjoint :  True True True
# initial cost =  425.17584252715665
# RUN  0 , total integrated cost =  425.17584252715665
# Gradient descend method:  None
# RUN  1 , total integrated cost =  155.27029728444157
# RUN  2 , total integrated cost =  142.47545132362276
# RUN  3 , total integrated cost =  126.74231018313019
# RUN  4 , total integrated cost =  114.93128406651095
# RUN  5 , total integrated cost =  102.03224821035712
# RUN  6 , total integrated cost =  92.29793709063264
# RUN  7 , total integrated cost =  82.23806664707672
# RUN  8 , total integrated cost =  74.57278178217662
# RUN  9 , total integrated cost =  66.8782980083479
# RUN  10 , total integrated cost =  60.88696676161504
# RUN  11 , total integrated cost =  55.01159552583028
# RUN  12 , total integrated cost =  50.276955862509425
# RUN  13 , total integrated cost =  45.6749432069894
# RUN  14 , total integrated cost =  41.800548998864166
# RUN  15 , total integrated cost =  38.1375548566888
# RUN  16 , total integrated cost =  34.99008360313244
# RUN  17 , total integrated cost =  31.795149971854453
# RUN  18 , total integrated cost =  29.014851822566726
# RUN  19 , total integrated cost =  26.34651188730744
# RUN  20 , total integrated cost =  24.17791655526177
# RUN  30 , total integrated cost =  10.250226798459375
# RUN  40 , total integrated cost =  4.461660004147886
# RUN  50 , total integrated cost =  2.6873084240296965
# RUN  50 , total integrated cost =  2.6873084240296965
# Improved over  50  iterations in  5.821983711968642  seconds by  99.3679536428841  percent.
# sparsity weight =  0.0014

# %%
c_var = [0,1]
conv = [None] * len(exc)

tol = 1e-6

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    k = 0
    
    while not conv[i]:
        max_it = int(100 + 100*k)

        weight_ = ( cost_uncontrolled[i] - costnode_[i][0][0][0] ) / sum( costnode_[i][2][0][:] )
            
        dur = d_array[0]
        aln.params.duration = dur
        cost.setParams(wp, weight_ * factor_we, weight_ * factor_ws)
        weights_[i] = cost.getParams()

        setinit(initVars[i], aln)

        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        control0 = aln.getZeroControl()
        control0 = bestControl_[i][:,:,n_pre-1:-n_post+1]

        bestControl_[i], bestState_[i], cost_[i], runtime_, grad_, phi_, phi1_, costnode_[i] = aln.A1(
            control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
            prec_variables_ = p_var, transition_time_ = t_pen[0])
        
        if cost_[i][2] == 0.:
            conv[i] = True

        #print('uncontrolled cost : ', cost_uncontrolled[i])
        print('cost splitting : ', costnode_[i][0][0][0], costnode_[i][2][0][:2])

        if conv[i]:
            time_ = np.arange(-dur_pre,round(dur+dur_post+aln.params.dt,1),aln.params.dt)
            target_ = aln.getZeroTarget()
            target_[:,0,:] = target[i][0]
            target_[:,1,:] = target[i][1]
        
            fig, ax = plt.subplots(2,1, constrained_layout=True, figsize = (4,4) )
            ax[1].plot(time_, bestControl_[i][0,0,:], color = 'red')
            ax[0].plot(time_, bestState_[i][0,0,:], color= 'red')
            ax[1].plot(time_, bestControl_[i][0,1,:], color = 'blue')
            ax[0].plot(time_, bestState_[i][0,1,:], color= 'blue')
            ax[0].plot(time_, target_[0,0,:], linestyle = '--', color='red')
            ax[0].plot(time_, target_[0,1,:], linestyle = '--', color='blue')
            ax[0].set_xlim(-dur_pre,dur+dur_post)
            ax[1].set_xlim(-dur_pre,dur+dur_post)
            ax[0].axvspan(dur*t_pen[0], dur, alpha=0.2, color='gray')
            plt.show()

        with open(file_,'wb') as f:
            pickle.dump([bestControl_, bestState_, cost_, costnode_, weights_], f)
        
        k += 1
# Out:
# -------  6 0.4250000000000001 0.40000000000000013
# set cost params:  0.05 0.0 286.3952370172736
# interpolate adjoint :  True True True
# initial cost =  467.73147375813545
# RUN  0 , total integrated cost =  467.73147375813545
# Gradient descend method:  None
# RUN  1 , total integrated cost =  467.73147375813545
# Control only changes marginally.
# RUN  1 , total integrated cost =  467.73147375813545
# Improved over  1  iterations in  0.2976223719888367  seconds by  0.0  percent.
# cost splitting :  4.444592722689936 [0.         1.63239183]
# -------  7 0.4500000000000001 0.40000000000000013
# set cost params:  0.05 0.0 647.2242187610499
# interpolate adjoint :  True True True
# initial cost =  672.2271588209883
# RUN  0 , total integrated cost =  672.2271588209883
# Gradient descend method:  None
# RUN  1 , total integrated cost =  672.2271588209883
# Control only changes marginally.
# RUN  1 , total integrated cost =  672.2271588209883
# Improved over  1  iterations in  0.38047730701509863  seconds by  0.0  percent.
# cost splitting :  5.929575395353376 [0.         1.03817296]
# -------  8 0.47500000000000014 0.40000000000000013
# set cost params:  0.05 0.0 2411.2780002746954
# interpolate adjoint :  True True True
# initial cost =  873.3794466731003
# RUN  0 , total integrated cost =  873.3794466731003
# Gradient descend method:  None
# RUN  1 , total integrated cost =  873.3794466731003
# Control only changes marginally.
# RUN  1 , total integrated cost =  873.3794466731003
# Improved over  1  iterations in  0.40511900797719136  seconds by  0.0  percent.
# cost splitting :  4.397836292297215 [3.62114843e-01 5.20016894e-10]
# -------  9 0.4000000000000001 0.42500000000000016
# set cost params:  0.05 0.0 71.35293614643949
# interpolate adjoint :  True True True
# initial cost =  225.11777716969203
# RUN  0 , total integrated cost =  225.11777716969203
# Gradient descend method:  None
# RUN  1 , total integrated cost =  225.11774933540943
# RUN  2 , total integrated cost =  225.1177405484211
# RUN  3 , total integrated cost =  225.11773110385502
# RUN  4 , total integrated cost =  225.11771240244084
# RUN  5 , total integrated cost =  225.11769211854968
# RUN  6 , total integrated cost =  225.1176800886352
# RUN  7 , total integrated cost =  225.11766851248527
# RUN  8 , total integrated cost =  225.11765449975996
# RUN  9 , total integrated cost =  225.11763911237006
# RUN  10 , total integrated cost =  225.1176298233243
# RUN  11 , total integrated cost =  225.1176201351567
# RUN  12 , total integrated cost =  225.11761906038186
# RUN  13 , total integrated cost =  225.11761683792722
# RUN  14 , total integrated cost =  225.11761565374385
# RUN  15 , total integrated cost =  225.11760814950023
# RUN  16 , total integrated cost =  225.11760251388762
# RUN  17 , total integrated cost =  225.11760037450495
# RUN  18 , total integrated cost =  225.1175970592051
# RUN  19 , total integrated cost =  225.11759631330423
# RUN  20 , total integrated cost =  225.11759104235796
# RUN  30 , total integrated cost =  225.11748662366153
# RUN  40 , total integrated cost =  225.11747338882986
# RUN  50 , total integrated cost =  225.11737175279808
# RUN  60 , total integrated cost =  225.11734041608838
# RUN  70 , total integrated cost =  225.11720708712542
# RUN  80 , total integrated cost =  225.1171172637452
# RUN  90 , total integrated cost =  225.11698254210177
# RUN  100 , total integrated cost =  225.11668554879108
# RUN  100 , total integrated cost =  225.11668554879108
# Improved over  100  iterations in  27.254462650977075  seconds by  0.0004849110162155057  percent.
# cost splitting :  7.493669020920355 [2.67244480e-09 3.14972325e+00]
# set cost params:  0.05 0.0 71.31424276001188
# interpolate adjoint :  True True True
# initial cost =  224.9948120898512
# RUN  0 , total integrated cost =  224.9948120898512
# Gradient descend method:  None
# RUN  1 , total integrated cost =  224.99479002207764
# RUN  2 , total integrated cost =  224.9947517307736
# RUN  3 , total integrated cost =  224.99471638537912
# RUN  4 , total integrated cost =  224.99467920801465
# RUN  5 , total integrated cost =  224.99464449742197
# RUN  6 , total integrated cost =  224.9945948729222
# RUN  7 , total integrated cost =  224.994548215986
# RUN  8 , total integrated cost =  224.9945124518205
# RUN  9 , total integrated cost =  224.99447995281
# RUN  10 , total integrated cost =  224.99442419573745
# RUN  11 , total integrated cost =  224.9943713960515
# RUN  12 , total integrated cost =  224.99434080348868
# RUN  13 , total integrated cost =  224.99431447383523
# RUN  14 , total integrated cost =  224.99425320415665
# RUN  15 , total integrated cost =  224.99418907650846
# RUN  16 , total integrated cost =  224.99320204698375
# RUN  17 , total integrated cost =  224.99238799082582
# RUN  18 , total integrated cost =  224.97892802415865
# RUN  19 , total integrated cost =  224.97817598631423
# RUN  20 , total integrated cost =  224.97765073901252
# RUN  30 , total integrated cost =  224.97512044447726
# RUN  40 , total integrated cost =  224.97379094926146
# RUN  50 , total integrated cost =  224.97298871547716
# RUN  60 , total integrated cost =  224.97254641147683
# RUN  70 , total integrated cost =  224.97222945782553
# RUN  80 , total integrated cost =  224.9720030452238
# RUN  90 , total integrated cost =  224.97177965898007
# RUN  100 , total integrated cost =  224.96951748093605
# RUN  110 , total integrated cost =  224.9628401436055
# RUN  120 , total integrated cost =  224.9627979762676
# RUN  130 , total integrated cost =  224.96275070696905
# RUN  140 , total integrated cost =  224.96269577133413
# RUN  150 , total integrated cost =  224.96235614658985
# RUN  160 , total integrated cost =  224.96233751612053
# RUN  170 , total integrated cost =  224.96231867971423
# RUN  180 , total integrated cost =  224.96230115902176
# RUN  190 , total integrated cost =  224.96228324423845
# RUN  200 , total integrated cost =  224.96226629573948
# RUN  200 , total integrated cost =  224.96226629573948
# Improved over  200  iterations in  56.78923139098333  seconds by  0.014465130910977564  percent.
# cost splitting :  7.283798139283171 [2.67244480e-09 3.14941402e+00]
# set cost params:  0.05 0.0 71.38788284980826
# interpolate adjoint :  True True True
# initial cost =  225.19418942740654
# RUN  0 , total integrated cost =  225.19418942740654
# Gradient descend method:  None
# RUN  1 , total integrated cost =  225.1941882648033
# RUN  2 , total integrated cost =  225.1941869214782
# RUN  3 , total integrated cost =  225.19418576940654
# RUN  4 , total integrated cost =  225.19418431743705
# RUN  5 , total integrated cost =  225.19418309297748
# RUN  6 , total integrated cost =  225.19418153487925
# RUN  7 , total integrated cost =  225.1941801837245
# RUN  8 , total integrated cost =  225.19417833159804
# RUN  9 , total integrated cost =  225.1941765999212
# RUN  10 , total integrated cost =  225.19417403328058
# RUN  11 , total integrated cost =  225.19417188293832
# RUN  12 , total integrated cost =  225.1941606220147
# RUN  13 , total integrated cost =  225.1941500475935
# RUN  14 , total integrated cost =  225.1941486063916
# RUN  15 , total integrated cost =  225.19414653383018
# RUN  16 , total integrated cost =  225.1941458684545
# RUN  17 , total integrated cost =  225.194144244871
# RUN  18 , total integrated cost =  225.19414326139506
# RUN  19 , total integrated cost =  225.19412567627884
# RUN  20 , total integrated cost =  225.194109996074
# Control only changes marginally.
# RUN  23 , total integrated cost =  225.19410783096487
# Improved over  23  iterations in  6.520982666988857  seconds by  3.623381307704676e-05  percent.
# cost splitting :  7.281917015576703 [2.6724448e-09 3.1494142e+00]
# set cost params:  0.05 0.0 71.3884761868049
# interpolate adjoint :  True True True
# initial cost =  225.1959764949276
# RUN  0 , total integrated cost =  225.1959764949276
# Gradient descend method:  None
# RUN  1 , total integrated cost =  225.1959764949276
# Control only changes marginally.
# RUN  1 , total integrated cost =  225.1959764949276
# Improved over  1  iterations in  0.3366933150100522  seconds by  0.0  percent.
# cost splitting :  7.281917015576703 [2.6724448e-09 3.1494142e+00]
# -------  10 0.4250000000000001 0.42500000000000016
# set cost params:  0.05 0.0 142.184706654021
# interpolate adjoint :  True True True
# initial cost =  393.8764491346629
# RUN  0 , total integrated cost =  393.8764491346629
# Gradient descend method:  None
# RUN  1 , total integrated cost =  392.39627963374676
# RUN  2 , total integrated cost =  391.8829626138445
# RUN  3 , total integrated cost =  391.31507201790487
# RUN  4 , total integrated cost =  390.90510367869666
# RUN  5 , total integrated cost =  390.3692161491218
# RUN  6 , total integrated cost =  389.9716934375856
# RUN  7 , total integrated cost =  389.43814072725786
# RUN  8 , total integrated cost =  389.037044636053
# RUN  9 , total integrated cost =  388.53319049482064
# RUN  10 , total integrated cost =  388.13570543595284
# RUN  11 , total integrated cost =  387.64729519629424
# RUN  12 , total integrated cost =  387.2589883574694
# RUN  13 , total integrated cost =  386.7887260597876
# RUN  14 , total integrated cost =  386.3895557897747
# RUN  15 , total integrated cost =  385.99383176981956
# RUN  16 , total integrated cost =  385.6293579211797
# RUN  17 , total integrated cost =  385.2473690087957
# RUN  18 , total integrated cost =  384.8647130507268
# RUN  19 , total integrated cost =  384.4886251558051
# RUN  20 , total integrated cost =  384.11339809005597
# RUN  30 , total integrated cost =  380.3489422760975
# RUN  40 , total integrated cost =  376.98902595708984
# RUN  50 , total integrated cost =  371.37119437842296
# RUN  60 , total integrated cost =  370.91169618581574
# RUN  70 , total integrated cost =  370.4399047246738
# RUN  80 , total integrated cost =  369.9625431013221
# RUN  90 , total integrated cost =  369.489968505537
# RUN  100 , total integrated cost =  369.095961907833
# RUN  100 , total integrated cost =  369.095961907833
# Improved over  100  iterations in  25.450364738993812  seconds by  6.291436637369927  percent.
# cost splitting :  115.38700362102081 [1.09072803e-05 2.55530338e+00]
# set cost params:  0.05 0.0 133.1287596059976
# interpolate adjoint :  True True True
# initial cost =  345.9551710705897
# RUN  0 , total integrated cost =  345.9551710705897
# Gradient descend method:  None
# RUN  1 , total integrated cost =  345.92541009575217
# RUN  2 , total integrated cost =  345.8967915442084
# RUN  3 , total integrated cost =  345.8701022309998
# RUN  4 , total integrated cost =  345.84166720470176
# RUN  5 , total integrated cost =  345.8145535063665
# RUN  6 , total integrated cost =  345.78417604682704
# RUN  7 , total integrated cost =  345.75646175308805
# RUN  8 , total integrated cost =  345.7280010766191
# RUN  9 , total integrated cost =  345.70109488878876
# RUN  10 , total integrated cost =  345.67387504561196
# RUN  11 , total integrated cost =  345.64686464340923
# RUN  12 , total integrated cost =  345.61811912777796
# RUN  13 , total integrated cost =  345.59179725529816
# RUN  14 , total integrated cost =  345.56411187140696
# RUN  15 , total integrated cost =  345.5375462835572
# RUN  16 , total integrated cost =  345.51083760372705
# RUN  17 , total integrated cost =  345.4848821981642
# RUN  18 , total integrated cost =  345.45813055198204
# RUN  19 , total integrated cost =  345.4316221669622
# RUN  20 , total integrated cost =  345.4032210211131
# RUN  30 , total integrated cost =  345.15043962050004
# RUN  40 , total integrated cost =  344.90459535557306
# RUN  50 , total integrated cost =  344.6650248133639
# RUN  60 , total integrated cost =  344.4292614767939
# RUN  70 , total integrated cost =  344.17549622505635
# RUN  80 , total integrated cost =  343.87247708758275
# RUN  90 , total integrated cost =  343.52710605442707
# RUN  100 , total integrated cost =  343.2274267821125
# RUN  110 , total integrated cost =  340.2030488658039
# RUN  120 , total integrated cost =  339.88204896852903
# RUN  130 , total integrated cost =  339.63024283564863
# RUN  140 , total integrated cost =  339.4181852640674
# RUN  150 , total integrated cost =  339.22085062150205
# RUN  160 , total integrated cost =  339.04159990177385
# RUN  170 , total integrated cost =  338.8684363922435
# RUN  180 , total integrated cost =  338.71349715463975
# RUN  190 , total integrated cost =  338.59856116374215
# RUN  200 , total integrated cost =  338.48930697890574
# RUN  200 , total integrated cost =  338.48930697890574
# Improved over  200  iterations in  52.25858267903095  seconds by  2.1580437917953788  percent.
# cost splitting :  76.05832184351682 [6.82383292e-06 2.51399835e+00]
# set cost params:  0.05 0.0 150.96011181897663
# interpolate adjoint :  True True True
# initial cost =  383.3174187592185
# RUN  0 , total integrated cost =  383.3174187592185
# Gradient descend method:  None
# RUN  1 , total integrated cost =  383.2550322187971
# RUN  2 , total integrated cost =  383.10454949568424
# RUN  3 , total integrated cost =  382.9502758148089
# RUN  4 , total integrated cost =  380.7104861140952
# RUN  5 , total integrated cost =  380.6808058207596
# RUN  6 , total integrated cost =  380.64935230341143
# RUN  7 , total integrated cost =  380.6189927151987
# RUN  8 , total integrated cost =  380.5928440451035
# RUN  9 , total integrated cost =  380.5680329128996
# RUN  10 , total integrated cost =  380.54880134494084
# RUN  11 , total integrated cost =  380.5284295465781
# RUN  12 , total integrated cost =  380.50676796608417
# RUN  13 , total integrated cost =  380.4841882515559
# RUN  14 , total integrated cost =  380.46022237993554
# RUN  15 , total integrated cost =  380.4379172957731
# RUN  16 , total integrated cost =  380.4232962533332
# RUN  17 , total integrated cost =  380.40806628377265
# RUN  18 , total integrated cost =  380.3894090054714
# RUN  19 , total integrated cost =  380.3665920309781
# RUN  20 , total integrated cost =  380.35174076630614
# RUN  30 , total integrated cost =  380.2306159529459
# RUN  40 , total integrated cost =  380.14130263289724
# RUN  50 , total integrated cost =  380.0561164594722
# RUN  60 , total integrated cost =  379.9664438595407
# RUN  70 , total integrated cost =  379.88561026544915
# RUN  80 , total integrated cost =  379.816784294546
# RUN  90 , total integrated cost =  379.75092673221036
# RUN  100 , total integrated cost =  379.6852981689287
# RUN  110 , total integrated cost =  379.62039561300764
# RUN  120 , total integrated cost =  379.55494592785715
# RUN  130 , total integrated cost =  379.4836789045447
# RUN  140 , total integrated cost =  379.4161193500353
# RUN  150 , total integrated cost =  379.3371196286828
# RUN  160 , total integrated cost =  379.2620390561367
# RUN  170 , total integrated cost =  379.19595801182396
# RUN  180 , total integrated cost =  379.1250871019343
# RUN  190 , total integrated cost =  379.0404962512643
# RUN  200 , total integrated cost =  378.41908979229873
# RUN  300 , total integrated cost =  377.5693212077962
# RUN  300 , total integrated cost =  377.5693212077962
# Improved over  300  iterations in  86.63918791996548  seconds by  1.499565965467653  percent.
# cost splitting :  62.35077721502139 [6.82383292e-06 2.48046155e+00]
# set cost params:  0.05 0.0 158.52733790543215
# interpolate adjoint :  True True True
# initial cost =  396.3395861562892
# RUN  0 , total integrated cost =  396.3395861562892
# Gradient descend method:  None
# RUN  1 , total integrated cost =  396.33179267734846
# RUN  2 , total integrated cost =  396.321433269316
# RUN  3 , total integrated cost =  396.3092598555694
# RUN  4 , total integrated cost =  396.29825416017223
# RUN  5 , total integrated cost =  396.28799540630126
# RUN  6 , total integrated cost =  396.2793040062658
# RUN  7 , total integrated cost =  396.2698519905883
# RUN  8 , total integrated cost =  396.2595172788748
# RUN  9 , total integrated cost =  396.24921488558493
# RUN  10 , total integrated cost =  396.24130915788993
# RUN  11 , total integrated cost =  396.23335236444785
# RUN  12 , total integrated cost =  396.2240288876544
# RUN  13 , total integrated cost =  396.2132822850305
# RUN  14 , total integrated cost =  396.2041166661396
# RUN  15 , total integrated cost =  396.1945616512682
# RUN  16 , total integrated cost =  396.1866649001849
# RUN  17 , total integrated cost =  396.17793311920866
# RUN  18 , total integrated cost =  396.1688736915873
# RUN  19 , total integrated cost =  396.1596429619692
# RUN  20 , total integrated cost =  396.1517086980853
# RUN  30 , total integrated cost =  396.0701268142568
# RUN  40 , total integrated cost =  395.9872169702372
# RUN  50 , total integrated cost =  395.90724865799297
# RUN  60 , total integrated cost =  395.832093049399
# RUN  70 , total integrated cost =  395.7623762357444
# RUN  80 , total integrated cost =  395.7165117686278
# RUN  90 , total integrated cost =  395.6785418461051
# RUN  100 , total integrated cost =  395.63937777726284
# RUN  110 , total integrated cost =  395.59467409678234
# RUN  120 , total integrated cost =  395.5464538920725
# RUN  130 , total integrated cost =  395.5038887787369
# RUN  140 , total integrated cost =  395.4340164251741
# RUN  150 , total integrated cost =  395.3641532747329
# RUN  160 , total integrated cost =  395.2892105562904
# RUN  170 , total integrated cost =  395.2006443369359
# RUN  180 , total integrated cost =  395.1522760148253
# RUN  190 , total integrated cost =  395.1113647922773
# RUN  200 , total integrated cost =  395.0523656826993
# RUN  300 , total integrated cost =  394.5770064663563
# RUN  400 , total integrated cost =  392.9926838806965
# RUN  400 , total integrated cost =  392.9926838806965
# Improved over  400  iterations in  109.0808011579793  seconds by  0.8444531892589993  percent.
# cost splitting :  51.08112878145981 [6.82383292e-06 2.46290357e+00]
# set cost params:  0.05 0.0 164.23321675152542
# interpolate adjoint :  True True True
# initial cost =  407.0457521681727
# RUN  0 , total integrated cost =  407.0457521681727
# Gradient descend method:  None
# RUN  1 , total integrated cost =  407.0434497948348
# RUN  2 , total integrated cost =  407.0412127765821
# RUN  3 , total integrated cost =  407.03888806896356
# RUN  4 , total integrated cost =  407.03670303637523
# RUN  5 , total integrated cost =  407.0344145151318
# RUN  6 , total integrated cost =  407.0322635326013
# RUN  7 , total integrated cost =  407.02998059492677
# RUN  8 , total integrated cost =  407.02785458180796
# RUN  9 , total integrated cost =  407.0256122981885
# RUN  10 , total integrated cost =  407.0234417196135
# RUN  11 , total integrated cost =  407.02107777548196
# RUN  12 , total integrated cost =  407.0188069428238
# RUN  13 , total integrated cost =  407.01623287992516
# RUN  14 , total integrated cost =  407.01359252264444
# RUN  15 , total integrated cost =  407.0101866931663
# RUN  16 , total integrated cost =  407.00707727115787
# RUN  17 , total integrated cost =  407.0031991862257
# RUN  18 , total integrated cost =  406.99978602905213
# RUN  19 , total integrated cost =  406.9961617514682
# RUN  20 , total integrated cost =  406.9923513669731
# RUN  30 , total integrated cost =  406.7321982626711
# RUN  40 , total integrated cost =  406.64797219150427
# RUN  50 , total integrated cost =  405.46011180654165
# RUN  60 , total integrated cost =  405.44505709012003
# RUN  70 , total integrated cost =  405.4291365891186
# RUN  80 , total integrated cost =  405.414674033611
# RUN  90 , total integrated cost =  405.40050533068165
# RUN  100 , total integrated cost =  405.3859339359926
# RUN  110 , total integrated cost =  405.33275488906867
# RUN  120 , total integrated cost =  405.27817590493214
# RUN  130 , total integrated cost =  404.6535275346725
# RUN  140 , total integrated cost =  404.580747324442
# RUN  150 , total integrated cost =  404.54824069466963
# RUN  160 , total integrated cost =  404.52519083766106
# RUN  170 , total integrated cost =  404.5057972525551
# RUN  180 , total integrated cost =  404.4931242000472
# RUN  190 , total integrated cost =  404.479889269611
# RUN  200 , total integrated cost =  404.46585434417494
# RUN  300 , total integrated cost =  404.23506054290516
# RUN  400 , total integrated cost =  402.6019662931084
# RUN  500 , total integrated cost =  402.4395678473213
# RUN  500 , total integrated cost =  402.4395678473213
# Improved over  500  iterations in  134.6918945159996  seconds by  1.131613411100858  percent.
# cost splitting :  31.925636898417295 [6.82383292e-06 2.44068875e+00]
# set cost params:  0.05 0.0 173.57641457131066
# interpolate adjoint :  True True True
# initial cost =  425.2434694570631
# RUN  0 , total integrated cost =  425.2434694570631
# Gradient descend method:  None
# RUN  1 , total integrated cost =  425.24234445293985
# RUN  2 , total integrated cost =  425.24136531123526
# RUN  3 , total integrated cost =  425.2402559517594
# RUN  4 , total integrated cost =  425.23932314780296
# RUN  5 , total integrated cost =  425.23839832442354
# RUN  6 , total integrated cost =  425.23735408260177
# RUN  7 , total integrated cost =  425.2362447933111
# RUN  8 , total integrated cost =  425.2353403171719
# RUN  9 , total integrated cost =  425.2344067780041
# RUN  10 , total integrated cost =  425.2337071398658
# RUN  11 , total integrated cost =  425.23291959238804
# RUN  12 , total integrated cost =  425.2322057108674
# RUN  13 , total integrated cost =  425.23146172660387
# RUN  14 , total integrated cost =  425.23073375340465
# RUN  15 , total integrated cost =  425.2299998456017
# RUN  16 , total integrated cost =  425.22926199149344
# RUN  17 , total integrated cost =  425.228566063621
# RUN  18 , total integrated cost =  425.22783061409973
# RUN  19 , total integrated cost =  425.2271129832628
# RUN  20 , total integrated cost =  425.2263534542174
# RUN  30 , total integrated cost =  425.21952592882405
# RUN  40 , total integrated cost =  425.21349875854185
# RUN  50 , total integrated cost =  425.2061510306436
# RUN  60 , total integrated cost =  425.18382597947686
# RUN  70 , total integrated cost =  425.1608993706713
# RUN  80 , total integrated cost =  425.15407384062735
# RUN  90 , total integrated cost =  425.1486293808833
# RUN  100 , total integrated cost =  425.1420268753916
# RUN  110 , total integrated cost =  425.11405355104233
# RUN  120 , total integrated cost =  425.05986607743955
# RUN  130 , total integrated cost =  425.04592002526107
# RUN  140 , total integrated cost =  425.0410921930107
# RUN  150 , total integrated cost =  425.0358826846659
# RUN  160 , total integrated cost =  425.0305074006163
# RUN  170 , total integrated cost =  425.0199815230424
# RUN  180 , total integrated cost =  424.9993832056468
# RUN  190 , total integrated cost =  424.9876095814566
# RUN  200 , total integrated cost =  424.97512612466863
# RUN  300 , total integrated cost =  424.2037436398783
# RUN  400 , total integrated cost =  423.7019687157661
# RUN  500 , total integrated cost =  423.0850710062136
# RUN  600 , total integrated cost =  422.99614021404557
# RUN  600 , total integrated cost =  422.99614021404557
# Improved over  600  iterations in  159.22330267104553  seconds by  0.5284806009806147  percent.
# cost splitting :  23.098013415122164 [6.82383292e-06 2.43028441e+00]
# set cost params:  0.05 0.0 177.9518455417573
# interpolate adjoint :  True True True
# initial cost =  433.6297117661934
# RUN  0 , total integrated cost =  433.6297117661934
# Gradient descend method:  None
# RUN  1 , total integrated cost =  433.6295049760854
# RUN  2 , total integrated cost =  433.6293180334704
# RUN  3 , total integrated cost =  433.62909913039897
# RUN  4 , total integrated cost =  433.6289435188844
# RUN  5 , total integrated cost =  433.62873962629726
# RUN  6 , total integrated cost =  433.62859545263103
# RUN  7 , total integrated cost =  433.62836741346445
# RUN  8 , total integrated cost =  433.62819815555264
# RUN  9 , total integrated cost =  433.6278097246405
# RUN  10 , total integrated cost =  433.6274715312298
# RUN  11 , total integrated cost =  433.6268141010315
# RUN  12 , total integrated cost =  433.6262262804823
# RUN  13 , total integrated cost =  433.5692246145604
# RUN  14 , total integrated cost =  433.53118372530366
# RUN  15 , total integrated cost =  433.5309753578223
# RUN  16 , total integrated cost =  433.53080971695425
# RUN  17 , total integrated cost =  433.530633130177
# RUN  18 , total integrated cost =  433.53047302565864
# RUN  19 , total integrated cost =  433.530301450672
# RUN  20 , total integrated cost =  433.53013596152914
# RUN  30 , total integrated cost =  433.5283334996655
# RUN  40 , total integrated cost =  433.52602263802015
# RUN  50 , total integrated cost =  433.52377721082945
# RUN  60 , total integrated cost =  433.519778892897
# RUN  70 , total integrated cost =  433.51584533077687
# RUN  80 , total integrated cost =  433.5122112712154
# RUN  90 , total integrated cost =  433.50884314985
# RUN  100 , total integrated cost =  433.5059351485604
# RUN  110 , total integrated cost =  433.49195829812305
# RUN  120 , total integrated cost =  433.47845919600474
# RUN  130 , total integrated cost =  433.45903614599126
# RUN  140 , total integrated cost =  433.45246176900383
# RUN  150 , total integrated cost =  433.42461034251403
# RUN  160 , total integrated cost =  433.4217535242107
# RUN  170 , total integrated cost =  433.4195080260112
# RUN  180 , total integrated cost =  433.41660412590363
# RUN  190 , total integrated cost =  433.404620675715
# RUN  200 , total integrated cost =  433.3964646308991
# RUN  300 , total integrated cost =  433.35805894127753
# RUN  400 , total integrated cost =  433.29403859607424
# RUN  500 , total integrated cost =  433.239056156499
# RUN  600 , total integrated cost =  433.18433341850897
# RUN  700 , total integrated cost =  433.13449195028136
# RUN  700 , total integrated cost =  433.13449195028136
# Improved over  700  iterations in  193.75197039701743  seconds by  0.1142033865472456  percent.
# cost splitting :  20.640751494092928 [6.82383292e-06 2.42819196e+00]
# set cost params:  0.05 0.0 179.11716143900986
# interpolate adjoint :  True True True
# initial cost =  435.9641105911712
# RUN  0 , total integrated cost =  435.9641105911712
# Gradient descend method:  None
# RUN  1 , total integrated cost =  435.96345436262186
# RUN  2 , total integrated cost =  435.96300017835944
# RUN  3 , total integrated cost =  435.96255966302243
# RUN  4 , total integrated cost =  435.9620933016695
# RUN  5 , total integrated cost =  435.9615270610327
# RUN  6 , total integrated cost =  435.96100976836715
# RUN  7 , total integrated cost =  435.9605155307181
# RUN  8 , total integrated cost =  435.9600592654272
# RUN  9 , total integrated cost =  435.95965742001255
# RUN  10 , total integrated cost =  435.9591593854969
# RUN  11 , total integrated cost =  435.95867511588176
# RUN  12 , total integrated cost =  435.9582462519629
# RUN  13 , total integrated cost =  435.95784716490397
# RUN  14 , total integrated cost =  435.95743275452236
# RUN  15 , total integrated cost =  435.9570250858904
# RUN  16 , total integrated cost =  435.95663867158083
# RUN  17 , total integrated cost =  435.9562413218879
# RUN  18 , total integrated cost =  435.955800075197
# RUN  19 , total integrated cost =  435.9553965698619
# RUN  20 , total integrated cost =  435.95492812294896
# RUN  30 , total integrated cost =  435.9504812739516
# RUN  40 , total integrated cost =  435.9446692875915
# RUN  50 , total integrated cost =  435.93974837580976
# RUN  60 , total integrated cost =  435.9349454062856
# RUN  70 , total integrated cost =  435.9308060002768
# RUN  80 , total integrated cost =  435.9267276075673
# RUN  90 , total integrated cost =  435.9229281308491
# RUN  100 , total integrated cost =  435.91944789765165
# RUN  110 , total integrated cost =  435.9162738702418
# RUN  120 , total integrated cost =  435.9147884613509
# RUN  130 , total integrated cost =  435.9093079157964
# RUN  140 , total integrated cost =  435.90445437384227
# RUN  150 , total integrated cost =  435.89900454403244
# RUN  160 , total integrated cost =  435.89498117663896
# RUN  170 , total integrated cost =  435.8261176094177
# RUN  180 , total integrated cost =  435.4687160442718
# RUN  190 , total integrated cost =  435.4136353304944
# RUN  200 , total integrated cost =  435.40661017349623
# RUN  300 , total integrated cost =  435.37612446695044
# RUN  400 , total integrated cost =  434.942206471604
# RUN  500 , total integrated cost =  434.5691445022158
# RUN  600 , total integrated cost =  434.52297343408276
# RUN  700 , total integrated cost =  434.2431605979215
# RUN  800 , total integrated cost =  434.2310695543165
# RUN  800 , total integrated cost =  434.2310695543165
# Improved over  800  iterations in  222.56955443497282  seconds by  0.3975191981983812  percent.
# cost splitting :  13.72335767242623 [6.82383292e-06 2.42044747e+00]
# set cost params:  0.05 0.0 182.5481558620665
# interpolate adjoint :  True True True
# initial cost =  442.5356347217546
# RUN  0 , total integrated cost =  442.5356347217546
# Gradient descend method:  None
# RUN  1 , total integrated cost =  442.53547185534984
# RUN  2 , total integrated cost =  442.5354282526031
# RUN  3 , total integrated cost =  442.5353733383371
# RUN  4 , total integrated cost =  442.53534076145263
# RUN  5 , total integrated cost =  442.5352915377267
# RUN  6 , total integrated cost =  442.53526018347264
# RUN  7 , total integrated cost =  442.53520885221087
# RUN  8 , total integrated cost =  442.53517404184913
# RUN  9 , total integrated cost =  442.5350780125769
# RUN  10 , total integrated cost =  442.5350011763038
# RUN  11 , total integrated cost =  442.3851224885487
# RUN  12 , total integrated cost =  442.38169198879706
# RUN  13 , total integrated cost =  442.3806559315565
# RUN  14 , total integrated cost =  442.3796925719315
# RUN  15 , total integrated cost =  442.3793972080731
# RUN  16 , total integrated cost =  442.37911574123865
# RUN  17 , total integrated cost =  442.3788397942186
# RUN  18 , total integrated cost =  442.3785830576535
# RUN  19 , total integrated cost =  442.3782925289479
# RUN  20 , total integrated cost =  442.37799112834597
# RUN  30 , total integrated cost =  442.3740966027584
# RUN  40 , total integrated cost =  442.3690363589084
# RUN  50 , total integrated cost =  442.3678706496366
# RUN  60 , total integrated cost =  442.36647938592273
# RUN  70 , total integrated cost =  442.36175908420375
# RUN  80 , total integrated cost =  442.35775877894275
# RUN  90 , total integrated cost =  442.33734605832285
# RUN  100 , total integrated cost =  442.3344457098904
# RUN  110 , total integrated cost =  442.33229153317376
# RUN  120 , total integrated cost =  442.33052030595064
# RUN  130 , total integrated cost =  442.33021788712693
# RUN  140 , total integrated cost =  442.3293942061928
# RUN  150 , total integrated cost =  442.3286852956483
# RUN  160 , total integrated cost =  442.3252599245844
# RUN  170 , total integrated cost =  442.32447120264743
# RUN  180 , total integrated cost =  442.3223722313085
# RUN  190 , total integrated cost =  442.3194489235768
# RUN  200 , total integrated cost =  442.3160153909671
# RUN  300 , total integrated cost =  442.30211080022303
# RUN  400 , total integrated cost =  442.28939015999356
# RUN  500 , total integrated cost =  442.2728564893909
# RUN  600 , total integrated cost =  442.2269585266985
# RUN  700 , total integrated cost =  442.1716066818279
# RUN  800 , total integrated cost =  442.14591387668264
# RUN  900 , total integrated cost =  442.09201438650547
# RUN  900 , total integrated cost =  442.09201438650547
# Improved over  900  iterations in  248.8686039170134  seconds by  0.10024511032383998  percent.
# cost splitting :  12.048996139759462 [6.82383292e-06 2.41847592e+00]
# set cost params:  0.05 0.0 183.38928809582447
# interpolate adjoint :  True True True
# initial cost =  444.126278177788
# RUN  0 , total integrated cost =  444.126278177788
# Gradient descend method:  None
# RUN  1 , total integrated cost =  444.1262456276781
# RUN  2 , total integrated cost =  444.1262250793766
# RUN  3 , total integrated cost =  444.1261907386104
# RUN  4 , total integrated cost =  444.12616508062644
# RUN  5 , total integrated cost =  444.12607781867274
# RUN  6 , total integrated cost =  444.12600205729746
# RUN  7 , total integrated cost =  444.12502078425604
# RUN  8 , total integrated cost =  444.1241405318531
# RUN  9 , total integrated cost =  444.12410286245006
# RUN  10 , total integrated cost =  444.12407218995503
# RUN  11 , total integrated cost =  444.1240107857167
# RUN  12 , total integrated cost =  444.1239523178956
# RUN  13 , total integrated cost =  444.12355044683716
# RUN  14 , total integrated cost =  444.12313128493236
# RUN  15 , total integrated cost =  444.1230687175187
# RUN  16 , total integrated cost =  444.1230036471248
# RUN  17 , total integrated cost =  444.1229591704004
# RUN  18 , total integrated cost =  444.1229155367594
# RUN  19 , total integrated cost =  444.1228585337069
# RUN  20 , total integrated cost =  444.1227986575703
# RUN  30 , total integrated cost =  444.12231788155157
# RUN  40 , total integrated cost =  444.12058323666
# RUN  50 , total integrated cost =  444.11841542711767
# RUN  60 , total integrated cost =  444.1163007368132
# RUN  70 , total integrated cost =  444.1146023548209
# RUN  80 , total integrated cost =  444.11317235963105
# RUN  90 , total integrated cost =  444.1118428695702
# RUN  100 , total integrated cost =  444.11083949998607
# RUN  110 , total integrated cost =  444.1101748882826
# RUN  120 , total integrated cost =  444.1095447649853
# RUN  130 , total integrated cost =  444.1087857374927
# RUN  140 , total integrated cost =  444.05154873096814
# RUN  150 , total integrated cost =  443.9122283931026
# RUN  160 , total integrated cost =  443.9110453356849
# RUN  170 , total integrated cost =  443.9100954653108
# RUN  180 , total integrated cost =  443.9091637850005
# RUN  190 , total integrated cost =  443.9079575913654
# RUN  200 , total integrated cost =  443.9045963029159
# RUN  300 , total integrated cost =  443.8780455358795
# RUN  400 , total integrated cost =  443.8728176488729
# RUN  500 , total integrated cost =  443.8463880556742
# RUN  600 , total integrated cost =  443.8232262242273
# RUN  700 , total integrated cost =  443.67344828197344
# RUN  800 , total integrated cost =  443.56558896851374
# RUN  900 , total integrated cost =  443.5166759185434
# RUN  1000 , total integrated cost =  443.42606965172064
# RUN  1000 , total integrated cost =  443.42606965172064
# Improved over  1000  iterations in  288.72978683403926  seconds by  0.15765978292034788  percent.
# cost splitting :  9.078247978566262 [6.82383292e-06 2.41546772e+00]
# set cost params:  0.05 0.0 184.8475602544943
# interpolate adjoint :  True True True
# initial cost =  446.9484889309216
# RUN  0 , total integrated cost =  446.9484889309216
# Gradient descend method:  None
# RUN  1 , total integrated cost =  446.94843010836934
# RUN  2 , total integrated cost =  446.9484136660287
# RUN  3 , total integrated cost =  446.9483913720476
# RUN  4 , total integrated cost =  446.94838051780624
# RUN  5 , total integrated cost =  446.9483624024583
# RUN  6 , total integrated cost =  446.9483514290975
# RUN  7 , total integrated cost =  446.9483258851145
# RUN  8 , total integrated cost =  446.9483055736613
# RUN  9 , total integrated cost =  446.947372117933
# RUN  10 , total integrated cost =  446.946497494573
# RUN  11 , total integrated cost =  446.94647299495716
# RUN  12 , total integrated cost =  446.94644271820925
# RUN  13 , total integrated cost =  446.94642891209276
# RUN  14 , total integrated cost =  446.94640739455866
# RUN  15 , total integrated cost =  446.9463934592583
# RUN  16 , total integrated cost =  446.9463634104104
# RUN  17 , total integrated cost =  446.9463393623321
# RUN  18 , total integrated cost =  446.9459239272291
# RUN  19 , total integrated cost =  446.9455138943064
# RUN  20 , total integrated cost =  446.94546547336535
# RUN  30 , total integrated cost =  446.9452357427974
# RUN  40 , total integrated cost =  446.9444435922215
# RUN  50 , total integrated cost =  446.9440781914146
# RUN  60 , total integrated cost =  446.9434009532569
# RUN  70 , total integrated cost =  446.9424611133086
# RUN  80 , total integrated cost =  446.93977981561653
# RUN  90 , total integrated cost =  446.9231011660313
# RUN  100 , total integrated cost =  446.88684721464614
# RUN  110 , total integrated cost =  446.8826330472407
# RUN  120 , total integrated cost =  446.8814408160183
# RUN  130 , total integrated cost =  446.87569573827886
# RUN  140 , total integrated cost =  446.8650023217232
# RUN  150 , total integrated cost =  446.8571296901326
# RUN  160 , total integrated cost =  446.8551526441918
# RUN  170 , total integrated cost =  446.85396949953775
# RUN  180 , total integrated cost =  446.85277803277535
# RUN  190 , total integrated cost =  446.8523510190767
# RUN  200 , total integrated cost =  446.79732797850676
# RUN  300 , total integrated cost =  446.7934337136719
# RUN  400 , total integrated cost =  446.78912329623233
# RUN  500 , total integrated cost =  446.72105825825173
# RUN  600 , total integrated cost =  446.7150741019322
# RUN  700 , total integrated cost =  446.70703910854127
# RUN  800 , total integrated cost =  446.70058954144446
# RUN  900 , total integrated cost =  446.69749403731817
# RUN  1000 , total integrated cost =  446.69377414944563
# RUN  1100 , total integrated cost =  446.6817423628903
# RUN  1100 , total integrated cost =  446.6817423628903
# Improved over  1100  iterations in  335.29582582903095  seconds by  0.059681724994604224  percent.
# cost splitting :  8.060789990570862 [6.82383292e-06 2.41429987e+00]
# set cost params:  0.05 0.0 185.35840324621537
# interpolate adjoint :  True True True
# initial cost =  447.9150740195172
# RUN  0 , total integrated cost =  447.9150740195172
# Gradient descend method:  None
# RUN  1 , total integrated cost =  447.9150646420885
# RUN  2 , total integrated cost =  447.91505727540067
# RUN  3 , total integrated cost =  447.91504801161835
# RUN  4 , total integrated cost =  447.91504050224535
# RUN  5 , total integrated cost =  447.91503097220493
# RUN  6 , total integrated cost =  447.91502274021303
# RUN  7 , total integrated cost =  447.9150086926321
# RUN  8 , total integrated cost =  447.9149969254704
# RUN  9 , total integrated cost =  447.91496090596274
# RUN  10 , total integrated cost =  447.9149246904812
# RUN  11 , total integrated cost =  447.9139272317938
# RUN  12 , total integrated cost =  447.913096687983
# RUN  13 , total integrated cost =  447.91308546915576
# RUN  14 , total integrated cost =  447.91307584088986
# RUN  15 , total integrated cost =  447.91305640796884
# RUN  16 , total integrated cost =  447.913039309666
# RUN  17 , total integrated cost =  447.9128521989086
# RUN  18 , total integrated cost =  447.9126103810959
# RUN  19 , total integrated cost =  447.9106532194607
# RUN  20 , total integrated cost =  447.90914541761384
# RUN  30 , total integrated cost =  447.90816599858925
# RUN  40 , total integrated cost =  447.9072241167434
# RUN  50 , total integrated cost =  447.9051354342469
# RUN  60 , total integrated cost =  447.90237746853865
# RUN  70 , total integrated cost =  447.90147124704333
# RUN  80 , total integrated cost =  447.9007400846017
# RUN  90 , total integrated cost =  447.900193104215
# RUN  100 , total integrated cost =  447.8999797674836
# RUN  110 , total integrated cost =  447.89812149213384
# RUN  120 , total integrated cost =  447.89661497940136
# RUN  130 , total integrated cost =  447.89632664460555
# RUN  140 , total integrated cost =  447.8748882728833
# RUN  150 , total integrated cost =  447.87439555353313
# RUN  160 , total integrated cost =  447.86891996210585
# RUN  170 , total integrated cost =  447.8671407128736
# RUN  180 , total integrated cost =  447.8636467697258
# RUN  190 , total integrated cost =  447.81432794977746
# RUN  200 , total integrated cost =  447.81205605504204
# RUN  300 , total integrated cost =  447.8070539983429
# RUN  400 , total integrated cost =  447.8048525383909
# RUN  500 , total integrated cost =  447.801236686033
# RUN  600 , total integrated cost =  447.7640717088588
# RUN  700 , total integrated cost =  447.76059665623853
# RUN  800 , total integrated cost =  447.7568276928431
# RUN  900 , total integrated cost =  447.75408163244504
# Control only changes marginally.
# RUN  939 , total integrated cost =  447.75323980726483
# Improved over  939  iterations in  268.7534118859912  seconds by  0.03613055725053016  percent.
# cost splitting :  7.419007374598818 [6.82383292e-06 2.41359991e+00]
# set cost params:  0.05 0.0 185.67806083086083
# interpolate adjoint :  True True True
# initial cost =  448.52476750469066
# RUN  0 , total integrated cost =  448.52476750469066
# Gradient descend method:  None
# RUN  1 , total integrated cost =  448.5247569480218
# RUN  2 , total integrated cost =  448.5247429720267
# RUN  3 , total integrated cost =  448.5247402068035
# RUN  4 , total integrated cost =  448.5247278396326
# RUN  5 , total integrated cost =  448.52472024171294
# RUN  6 , total integrated cost =  448.5246515156714
# RUN  7 , total integrated cost =  448.52456204166697
# RUN  8 , total integrated cost =  448.5245561085614
# RUN  9 , total integrated cost =  448.5245477824684
# RUN  10 , total integrated cost =  448.5245432794442
# RUN  11 , total integrated cost =  448.52453512888394
# RUN  12 , total integrated cost =  448.52452904697924
# RUN  13 , total integrated cost =  448.5245090355875
# RUN  14 , total integrated cost =  448.52449351873787
# RUN  15 , total integrated cost =  448.52445638893636
# RUN  16 , total integrated cost =  448.5244266685154
# RUN  17 , total integrated cost =  448.52440583016494
# RUN  18 , total integrated cost =  448.52437976036396
# RUN  19 , total integrated cost =  448.5243715660108
# RUN  20 , total integrated cost =  448.5243606274638
# RUN  30 , total integrated cost =  448.5241893596583
# RUN  40 , total integrated cost =  448.52378956594646
# RUN  50 , total integrated cost =  448.5235600350809
# RUN  60 , total integrated cost =  448.52330041987784
# RUN  70 , total integrated cost =  448.52305447513686
# RUN  80 , total integrated cost =  448.5228477487718
# RUN  90 , total integrated cost =  448.52261534116064
# RUN  100 , total integrated cost =  448.52246485500376
# RUN  110 , total integrated cost =  448.5222140919498
# RUN  120 , total integrated cost =  448.52203383740164
# RUN  130 , total integrated cost =  448.5207655914982
# RUN  140 , total integrated cost =  448.52070977041393
# RUN  150 , total integrated cost =  448.5206557046521
# RUN  160 , total integrated cost =  448.52060312907287
# RUN  170 , total integrated cost =  448.5205522430378
# RUN  180 , total integrated cost =  448.5205006095133
# RUN  190 , total integrated cost =  448.5202138444908
# RUN  200 , total integrated cost =  448.5200147820244
# RUN  300 , total integrated cost =  448.51779456152633
# RUN  400 , total integrated cost =  448.51588734474547
# RUN  500 , total integrated cost =  448.50564313470437
# RUN  600 , total integrated cost =  448.4502981449012
# RUN  700 , total integrated cost =  448.44222622358166
# RUN  800 , total integrated cost =  448.39938659677875
# RUN  900 , total integrated cost =  448.3869734957989
# Control only changes marginally.
# RUN  928 , total integrated cost =  448.3865142996465
# Improved over  928  iterations in  267.0957345649949  seconds by  0.030823984551247463  percent.
# cost splitting :  6.8498586369181345 [6.82383292e-06 2.41300858e+00]
# set cost params:  0.05 0.0 185.9594284939566
# interpolate adjoint :  True True True
# initial cost =  449.0654588054873
# RUN  0 , total integrated cost =  449.0654588054873
# Gradient descend method:  None
# RUN  1 , total integrated cost =  449.065452181154
# RUN  2 , total integrated cost =  449.0654433241428
# RUN  3 , total integrated cost =  449.06543981963983
# RUN  4 , total integrated cost =  449.06543328836057
# RUN  5 , total integrated cost =  449.06542892780607
# RUN  6 , total integrated cost =  449.0654191481451
# RUN  7 , total integrated cost =  449.065411886289
# RUN  8 , total integrated cost =  449.06529630589245
# RUN  9 , total integrated cost =  449.06518933217365
# RUN  10 , total integrated cost =  449.06518075171965
# RUN  11 , total integrated cost =  449.0651700365657
# RUN  12 , total integrated cost =  449.065165244291
# RUN  13 , total integrated cost =  449.0651585953896
# RUN  14 , total integrated cost =  449.0651549671592
# RUN  15 , total integrated cost =  449.065149519992
# RUN  16 , total integrated cost =  449.0651451153193
# RUN  17 , total integrated cost =  449.06513637413536
# RUN  18 , total integrated cost =  449.0651291574553
# RUN  19 , total integrated cost =  449.0651184963347
# RUN  20 , total integrated cost =  449.06511042909125
# RUN  30 , total integrated cost =  449.0347333859012
# RUN  40 , total integrated cost =  449.03436288324957
# RUN  50 , total integrated cost =  449.03402851607655
# RUN  60 , total integrated cost =  449.0338483979992
# RUN  70 , total integrated cost =  449.0336707056115
# RUN  80 , total integrated cost =  449.0329534682652
# RUN  90 , total integrated cost =  449.03286553837415
# RUN  100 , total integrated cost =  449.0326301170423
# RUN  110 , total integrated cost =  449.0323709568935
# RUN  120 , total integrated cost =  449.0321258429644
# RUN  130 , total integrated cost =  449.03189856405857
# RUN  140 , total integrated cost =  449.031687994608
# RUN  150 , total integrated cost =  449.0300617770186
# RUN  160 , total integrated cost =  449.02895063604944
# RUN  170 , total integrated cost =  449.02858621668673
# RUN  180 , total integrated cost =  449.02850473857717
# RUN  190 , total integrated cost =  449.0218217731086
# RUN  200 , total integrated cost =  449.01688107615115
# Control only changes marginally.
# RUN  224 , total integrated cost =  449.01257645416786
# Improved over  224  iterations in  63.70852141000796  seconds by  0.01177608971755717  percent.
# cost splitting :  6.635102190348824 [6.82383292e-06 2.41278195e+00]
# set cost params:  0.05 0.0 186.06590320007743
# interpolate adjoint :  True True True
# initial cost =  449.2694774297281
# RUN  0 , total integrated cost =  449.2694774297281
# Gradient descend method:  None
# RUN  1 , total integrated cost =  449.2694774297281
# Control only changes marginally.
# RUN  1 , total integrated cost =  449.2694774297281
# Improved over  1  iterations in  0.3182837720378302  seconds by  0.0  percent.
# cost splitting :  6.635102190348824 [6.82383292e-06 2.41278195e+00]
# -------  11 0.4500000000000001 0.42500000000000016
# set cost params:  0.05 0.0 219.76067168288228
# interpolate adjoint :  True True True
# initial cost =  466.74966165090086
# RUN  0 , total integrated cost =  466.74966165090086
# Gradient descend method:  None
# RUN  1 , total integrated cost =  465.19649006937397
# RUN  2 , total integrated cost =  464.2981491455966
# RUN  3 , total integrated cost =  463.3497000153263
# RUN  4 , total integrated cost =  462.6657092069335
# RUN  5 , total integrated cost =  461.91053181736703
# RUN  6 , total integrated cost =  461.2749727813044
# RUN  7 , total integrated cost =  460.5889068549143
# RUN  8 , total integrated cost =  460.00383498590986
# RUN  9 , total integrated cost =  459.38330415169946
# RUN  10 , total integrated cost =  458.8476116700213
# RUN  11 , total integrated cost =  458.283832090452
# RUN  12 , total integrated cost =  457.77711225435337
# RUN  13 , total integrated cost =  457.21218808698825
# RUN  14 , total integrated cost =  456.74492514464896
# RUN  15 , total integrated cost =  456.235538245082
# RUN  16 , total integrated cost =  455.77942293199436
# RUN  17 , total integrated cost =  455.28544353530367
# RUN  18 , total integrated cost =  454.8630965822896
# RUN  19 , total integrated cost =  454.4191940130266
# RUN  20 , total integrated cost =  454.0047510695477
# RUN  30 , total integrated cost =  450.2515769938546
# RUN  40 , total integrated cost =  447.1565892673902
# RUN  50 , total integrated cost =  444.4018086836706
# RUN  60 , total integrated cost =  441.86592003358464
# RUN  70 , total integrated cost =  439.635066493464
# RUN  80 , total integrated cost =  437.2893507826423
# RUN  90 , total integrated cost =  435.39056378443416
# RUN  100 , total integrated cost =  433.6519899823342
# RUN  100 , total integrated cost =  433.6519899823342
# Improved over  100  iterations in  29.298614425992128  seconds by  7.091097088640552  percent.
# cost splitting :  182.3456485500856 [0.         1.93180474]
# set cost params:  0.05 0.0 250.14233043992553
# interpolate adjoint :  True True True
# initial cost =  492.34342242418666
# RUN  0 , total integrated cost =  492.34342242418666
# Gradient descend method:  None
# RUN  1 , total integrated cost =  492.0348689034889
# RUN  2 , total integrated cost =  491.8270292163754
# RUN  3 , total integrated cost =  491.6025782478357
# RUN  4 , total integrated cost =  491.3752200219248
# ...
# RUN  170 , total integrated cost =  200.73593055621433
# RUN  180 , total integrated cost =  200.73584095138222
# RUN  190 , total integrated cost =  200.7351924062982
# RUN  200 , total integrated cost =  200.73497819963993
# RUN  300 , total integrated cost =  200.73343267583638
# RUN  400 , total integrated cost =  200.73081297484467
# RUN  500 , total integrated cost =  200.72894042268456
# RUN  600 , total integrated cost =  200.707027975789
# RUN  700 , total integrated cost =  200.68472668509332
# RUN  800 , total integrated cost =  200.6829246366038
# RUN  900 , total integrated cost =  200.6752516579694
# RUN  1000 , total integrated cost =  200.67364689763886
# RUN  1100 , total integrated cost =  200.671489645504
# RUN  1200 , total integrated cost =  200.66963913801814
# RUN  1300 , total integrated cost =  200.66599897958375
# RUN  1400 , total integrated cost =  200.66490606394467
# RUN  1400 , total integrated cost =  200.66490606394467
# Improved over  1400  iterations in  385.91570723603945  seconds by  0.03680025956674626  percent.
# cost splitting :  8.177721430865843 [8.29660871e-06 4.02173627e+00]
# set cost params:  0.05 0.0 49.89989587885009
# interpolate adjoint :  True True True
# initial cost =  201.09352129998592
# RUN  0 , total integrated cost =  201.09352129998592
# Gradient descend method:  None
# RUN  1 , total integrated cost =  201.09351587170727
# RUN  2 , total integrated cost =  201.0935102767308
# RUN  3 , total integrated cost =  201.09350516183432
# RUN  4 , total integrated cost =  201.0935004282406
# RUN  5 , total integrated cost =  201.09349584006958
# RUN  6 , total integrated cost =  201.09349101326862
# RUN  7 , total integrated cost =  201.09348653084868
# RUN  8 , total integrated cost =  201.09348181226733
# RUN  9 , total integrated cost =  201.0934772179877
# RUN  10 , total integrated cost =  201.09347278083993
# RUN  11 , total integrated cost =  201.0934682831591
# RUN  12 , total integrated cost =  201.09346408599208
# RUN  13 , total integrated cost =  201.09345957457253
# RUN  14 , total integrated cost =  201.0934556033715
# RUN  15 , total integrated cost =  201.09345114599913
# RUN  16 , total integrated cost =  201.09344730218695
# RUN  17 , total integrated cost =  201.09344273006914
# RUN  18 , total integrated cost =  201.09343877296462
# RUN  19 , total integrated cost =  201.09343365662494
# RUN  20 , total integrated cost =  201.09342910005793
# RUN  30 , total integrated cost =  201.09314669490445
# RUN  40 , total integrated cost =  201.09301472745463
# RUN  50 , total integrated cost =  201.09180970485215
# RUN  60 , total integrated cost =  201.09168140100758
# RUN  70 , total integrated cost =  201.0915603920207
# RUN  80 , total integrated cost =  201.09146058258162
# RUN  90 , total integrated cost =  201.09125452925957
# RUN  100 , total integrated cost =  201.09105162746363
# RUN  110 , total integrated cost =  201.09094244368762
# RUN  120 , total integrated cost =  201.09085266257006
# RUN  130 , total integrated cost =  201.09010056971545
# RUN  140 , total integrated cost =  201.08720893316456
# RUN  150 , total integrated cost =  201.08710138551183
# RUN  160 , total integrated cost =  201.0870054124358
# RUN  170 , total integrated cost =  201.0868926627398
# RUN  180 , total integrated cost =  201.0851528233231
# RUN  190 , total integrated cost =  201.08339372554929
# RUN  200 , total integrated cost =  201.0832147547233
# RUN  300 , total integrated cost =  201.07780237586704
# RUN  400 , total integrated cost =  201.07364118867983
# RUN  500 , total integrated cost =  201.06614177537014
# RUN  600 , total integrated cost =  201.0465788949581
# RUN  700 , total integrated cost =  201.0395587930786
# RUN  800 , total integrated cost =  201.0116259417045
# RUN  900 , total integrated cost =  200.99576646379106
# RUN  1000 , total integrated cost =  200.96717053522966
# RUN  1100 , total integrated cost =  200.96441407057188
# RUN  1200 , total integrated cost =  200.96348077104798
# RUN  1300 , total integrated cost =  200.96149885346173
# RUN  1400 , total integrated cost =  200.95993884088512
# RUN  1500 , total integrated cost =  200.9589665571546
# RUN  1500 , total integrated cost =  200.9589665571546
# Improved over  1500  iterations in  377.16911016899394  seconds by  0.06691152552377844  percent.
# cost splitting :  7.5677913550643545 [8.29660871e-06 4.01965093e+00]
# set cost params:  0.05 0.0 50.077519969398246
# interpolate adjoint :  True True True
# initial cost =  201.67295487199732
# RUN  0 , total integrated cost =  201.67295487199732
# Gradient descend method:  None
# RUN  1 , total integrated cost =  201.67294968901575
# RUN  2 , total integrated cost =  201.6729459206089
# RUN  3 , total integrated cost =  201.672941291409
# RUN  4 , total integrated cost =  201.6729363217448
# RUN  5 , total integrated cost =  201.67293133291201
# RUN  6 , total integrated cost =  201.6729270385047
# RUN  7 , total integrated cost =  201.67292228589787
# RUN  8 , total integrated cost =  201.67291808245895
# RUN  9 , total integrated cost =  201.67291350033963
# RUN  10 , total integrated cost =  201.6729094435891
# RUN  11 , total integrated cost =  201.6729050218077
# RUN  12 , total integrated cost =  201.67290104295955
# RUN  13 , total integrated cost =  201.6728968092071
# RUN  14 , total integrated cost =  201.67289453248168
# RUN  15 , total integrated cost =  201.672891808023
# RUN  16 , total integrated cost =  201.67288993589878
# RUN  17 , total integrated cost =  201.67288745961596
# RUN  18 , total integrated cost =  201.67288560493395
# RUN  19 , total integrated cost =  201.67288262888601
# RUN  20 , total integrated cost =  201.67288016891752
# RUN  30 , total integrated cost =  201.67280385899696
# RUN  40 , total integrated cost =  201.6727390655588
# RUN  50 , total integrated cost =  201.672630761695
# RUN  60 , total integrated cost =  201.6725568238361
# RUN  70 , total integrated cost =  201.67235445279687
# RUN  80 , total integrated cost =  201.6711243572646
# RUN  90 , total integrated cost =  201.67070499757114
# RUN  100 , total integrated cost =  201.67044499062575
# RUN  110 , total integrated cost =  201.6703422517626
# RUN  120 , total integrated cost =  201.67026210036227
# RUN  130 , total integrated cost =  201.67003363968936
# RUN  140 , total integrated cost =  201.66998868185496
# RUN  150 , total integrated cost =  201.66989339986392
# RUN  160 , total integrated cost =  201.6697702476655
# RUN  170 , total integrated cost =  201.66971605931033
# RUN  180 , total integrated cost =  201.66965618004278
# RUN  190 , total integrated cost =  201.66960053991733
# RUN  200 , total integrated cost =  201.66932601034213
# RUN  300 , total integrated cost =  201.66649404861852
# RUN  400 , total integrated cost =  201.66556620574212
# RUN  500 , total integrated cost =  201.6647189821009
# RUN  600 , total integrated cost =  201.66187132490484
# RUN  700 , total integrated cost =  201.66099927496387
# RUN  800 , total integrated cost =  201.6596528817469
# RUN  900 , total integrated cost =  201.65755580747788
# RUN  1000 , total integrated cost =  201.65634253385832
# RUN  1100 , total integrated cost =  201.6538960918793
# RUN  1200 , total integrated cost =  201.65291336264966
# RUN  1300 , total integrated cost =  201.64999852533575
# RUN  1400 , total integrated cost =  201.64943403699792
# RUN  1500 , total integrated cost =  201.64860510929222
# RUN  1600 , total integrated cost =  201.64578660229535
# RUN  1600 , total integrated cost =  201.64578660229535
# Improved over  1600  iterations in  407.22991906799143  seconds by  0.013471449217973941  percent.
# cost splitting :  7.473934724107832 [8.29660871e-06 4.01920212e+00]
# set cost params:  0.05 0.0 50.1064639800549
# interpolate adjoint :  True True True
# initial cost =  201.762118671406
# RUN  0 , total integrated cost =  201.762118671406
# Gradient descend method:  None
# RUN  1 , total integrated cost =  201.76211327830399
# RUN  2 , total integrated cost =  201.7621087156209
# RUN  3 , total integrated cost =  201.7621036999299
# RUN  4 , total integrated cost =  201.76209936853178
# RUN  5 , total integrated cost =  201.76209454075874
# RUN  6 , total integrated cost =  201.7620901961579
# RUN  7 , total integrated cost =  201.7620855047621
# RUN  8 , total integrated cost =  201.76208084926847
# RUN  9 , total integrated cost =  201.7620765917873
# RUN  10 , total integrated cost =  201.76207195421927
# RUN  11 , total integrated cost =  201.76206786672336
# RUN  12 , total integrated cost =  201.76206334461
# RUN  13 , total integrated cost =  201.76205933940156
# RUN  14 , total integrated cost =  201.76205483370646
# RUN  15 , total integrated cost =  201.76205096409973
# RUN  16 , total integrated cost =  201.76204684674565
# RUN  17 , total integrated cost =  201.76204279873417
# RUN  18 , total integrated cost =  201.76203878638952
# RUN  19 , total integrated cost =  201.76203483512595
# RUN  20 , total integrated cost =  201.76203077604598
# RUN  30 , total integrated cost =  201.76199278684618
# RUN  40 , total integrated cost =  201.7619582220687
# RUN  50 , total integrated cost =  201.76192985694533
# RUN  60 , total integrated cost =  201.7618949087227
# RUN  70 , total integrated cost =  201.76143160004966
# RUN  80 , total integrated cost =  201.7612604053096
# RUN  90 , total integrated cost =  201.76123411215585
# RUN  100 , total integrated cost =  201.76103495965108
# RUN  110 , total integrated cost =  201.7609670664106
# RUN  120 , total integrated cost =  201.75945081334837
# RUN  130 , total integrated cost =  201.758345263856
# RUN  140 , total integrated cost =  201.75828754466008
# RUN  150 , total integrated cost =  201.75819469154538
# RUN  160 , total integrated cost =  201.75814112439582
# RUN  170 , total integrated cost =  201.75810275424584
# RUN  180 , total integrated cost =  201.75806505404765
# RUN  190 , total integrated cost =  201.758032526849
# RUN  200 , total integrated cost =  201.75797313884314
# RUN  300 , total integrated cost =  201.7540495184663
# RUN  400 , total integrated cost =  201.750267191178
# RUN  500 , total integrated cost =  201.7429234139642
# RUN  600 , total integrated cost =  201.73824370566885
# RUN  700 , total integrated cost =  201.7317339218787
# RUN  800 , total integrated cost =  201.70821436939966
# RUN  900 , total integrated cost =  201.70198060015662
# RUN  1000 , total integrated cost =  201.6780288051313
# RUN  1100 , total integrated cost =  201.6753022350226
# RUN  1200 , total integrated cost =  201.64532401176797
# RUN  1300 , total integrated cost =  201.6426876631753
# RUN  1400 , total integrated cost =  201.63868756474022
# RUN  1500 , total integrated cost =  201.63226129078078
# RUN  1600 , total integrated cost =  201.63110754697283
# RUN  1700 , total integrated cost =  201.6258488889568
# RUN  1700 , total integrated cost =  201.6258488889568
# Improved over  1700  iterations in  446.6949157930212  seconds by  0.06753982528857705  percent.
# cost splitting :  6.782492825777439 [8.29660871e-06 4.01717249e+00]
# set cost params:  0.05 0.0 50.303900846488794
# interpolate adjoint :  True True True
# initial cost =  202.41898847481988
# RUN  0 , total integrated cost =  202.41898847481988
# Gradient descend method:  None
# RUN  1 , total integrated cost =  202.41897970288542
# RUN  2 , total integrated cost =  202.41897436804945
# RUN  3 , total integrated cost =  202.41896308591186
# RUN  4 , total integrated cost =  202.41895341791601
# RUN  5 , total integrated cost =  202.41889208002786
# RUN  6 , total integrated cost =  202.41883531397193
# RUN  7 , total integrated cost =  202.4186973344246
# RUN  8 , total integrated cost =  202.4185655706727
# RUN  9 , total integrated cost =  202.41855375234144
# RUN  10 , total integrated cost =  202.41853321438023
# RUN  11 , total integrated cost =  202.418525042551
# RUN  12 , total integrated cost =  202.41851412734195
# RUN  13 , total integrated cost =  202.41850562777887
# RUN  14 , total integrated cost =  202.41849613249866
# RUN  15 , total integrated cost =  202.4184889176222
# RUN  16 , total integrated cost =  202.41848061496697
# RUN  17 , total integrated cost =  202.4184734500943
# RUN  18 , total integrated cost =  202.41846575418455
# RUN  19 , total integrated cost =  202.41845885430817
# RUN  20 , total integrated cost =  202.41845139655337
# RUN  30 , total integrated cost =  202.41836913931664
# RUN  40 , total integrated cost =  202.4180049313682
# RUN  50 , total integrated cost =  202.41793752671077
# RUN  60 , total integrated cost =  202.4174638296488
# RUN  70 , total integrated cost =  202.41742855732116
# RUN  80 , total integrated cost =  202.4172928440913
# RUN  90 , total integrated cost =  202.41720354661257
# RUN  100 , total integrated cost =  202.4054201620665
# RUN  110 , total integrated cost =  202.4033087550998
# RUN  120 , total integrated cost =  202.4012875155486
# RUN  130 , total integrated cost =  202.3997558193933
# RUN  140 , total integrated cost =  202.3983342736955
# RUN  150 , total integrated cost =  202.39738389621616
# RUN  160 , total integrated cost =  202.39676946530776
# RUN  170 , total integrated cost =  202.39621331234636
# RUN  180 , total integrated cost =  202.3957286390553
# RUN  190 , total integrated cost =  202.3951766072012
# RUN  200 , total integrated cost =  202.39487174110937
# RUN  300 , total integrated cost =  202.3912575405449
# RUN  400 , total integrated cost =  202.38913882268162
# RUN  500 , total integrated cost =  202.38801719355695
# RUN  600 , total integrated cost =  202.38726001537677
# RUN  700 , total integrated cost =  202.38497580759122
# Control only changes marginally.
# RUN  775 , total integrated cost =  202.38457656764334
# Improved over  775  iterations in  166.60947776399553  seconds by  0.017000335509948172  percent.
# cost splitting :  6.659269656085264 [8.29660871e-06 4.01661089e+00]
# set cost params:  0.05 0.0 50.341612641286616
# interpolate adjoint :  True True True
# initial cost =  202.53605048602748
# RUN  0 , total integrated cost =  202.53605048602748
# Gradient descend method:  None
# RUN  1 , total integrated cost =  202.53605017646746
# RUN  2 , total integrated cost =  202.53604832725378
# RUN  3 , total integrated cost =  202.53604760772103
# RUN  4 , total integrated cost =  202.5360464150655
# RUN  5 , total integrated cost =  202.5360440706414
# RUN  6 , total integrated cost =  202.53604356638436
# RUN  7 , total integrated cost =  202.53597263909631
# RUN  8 , total integrated cost =  202.53590253170677
# RUN  9 , total integrated cost =  202.53589428994468
# RUN  10 , total integrated cost =  202.53588251768866
# RUN  11 , total integrated cost =  202.5358795539655
# RUN  12 , total integrated cost =  202.53587634748797
# RUN  13 , total integrated cost =  202.53587444343364
# RUN  14 , total integrated cost =  202.53587198424668
# RUN  15 , total integrated cost =  202.53587036149878
# RUN  16 , total integrated cost =  202.53586781137324
# RUN  17 , total integrated cost =  202.53586590541084
# RUN  18 , total integrated cost =  202.53586053403356
# RUN  19 , total integrated cost =  202.53585521345747
# RUN  20 , total integrated cost =  202.5358467483108
# RUN  30 , total integrated cost =  202.53568268691185
# RUN  40 , total integrated cost =  202.53565098701327
# RUN  50 , total integrated cost =  202.5356279756286
# RUN  60 , total integrated cost =  202.53560388946985
# RUN  70 , total integrated cost =  202.53540163085984
# RUN  80 , total integrated cost =  202.5353469077883
# RUN  90 , total integrated cost =  202.53530475505272
# RUN  100 , total integrated cost =  202.5352905975426
# RUN  110 , total integrated cost =  202.53524735315875
# RUN  120 , total integrated cost =  202.53520638361087
# RUN  130 , total integrated cost =  202.53509444063707
# RUN  140 , total integrated cost =  202.53474954834294
# RUN  150 , total integrated cost =  202.53446474536145
# RUN  160 , total integrated cost =  202.53428048481092
# RUN  170 , total integrated cost =  202.53421401112413
# RUN  180 , total integrated cost =  202.53359525035341
# RUN  190 , total integrated cost =  202.5335347820987
# RUN  200 , total integrated cost =  202.5334469600233
# RUN  300 , total integrated cost =  202.53239135964495
# RUN  400 , total integrated cost =  202.52906544934234
# RUN  500 , total integrated cost =  202.5282046610668

# %%
#for i in i_range:
for i in i_range:
        
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    if i in bad:
        continue
    
    aln.params.duration = dur
    max_it = int(0)
    
    int_array = np.zeros(( bestControl_[i].shape[2] ))
    int_array[0] = ( np.abs(bestControl_[i][0,0,0]) + np.abs(bestControl_[i][0,1,0]) ) * aln.params.dt
    for t_ in range(1,bestControl_[i].shape[2]):
        int_array[t_] = int_array[t_-1] + ( np.abs(bestControl_[i][0,0,t_])
                        + np.abs(bestControl_[i][0,1,t_]) ) * aln.params.dt
    
    ind_mid = np.where(int_array >= int_array[-1]/2.)
    
    if ind_mid[0][0] <= 2500:
        print("integral mid before intervall mid")
        break
    
    init_ind = ind_mid[0][0] - 2500
    
    print("shift by ", init_ind, )
    

    weight_ = 1.
    cost.setParams(wp, weight_ * factor_we, weight_ * factor_ws)
    weights_[i] = cost.getParams()

    setinit(initVars[i], aln)

    target_ = aln.getZeroTarget()
    target_[:,0,:] = target[i][0]
    target_[:,1,:] = target[i][1]

    control0 = aln.getZeroControl()
    if init_ind != 0:
        control0[:,:,:-init_ind] = bestControl_[i][:,:,n_pre-1+init_ind:-n_post+1]
    else:
        control0 = bestControl_[i][:,:,n_pre-1:-n_post+1]

    bestControl_[i], bestState_[i], cost_[i], runtime_, grad_, phi_, phi1_, costnode_[i] = aln.A1(
        control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
        prec_variables_ = p_var, transition_time_ = t_pen[0])

    print('uncontrolled cost : ', cost_uncontrolled[i])
    print('cost splitting : ', costnode_[i][0][0][0], costnode_[i][2][0][:2])

    time_ = np.arange(-dur_pre,round(dur+dur_post+aln.params.dt,1),aln.params.dt)
    target_ = aln.getZeroTarget()
    target_[:,0,:] = target[i][0]
    target_[:,1,:] = target[i][1]

    fig, ax = plt.subplots(2,1, constrained_layout=True, figsize = (4,4) )
    ax[1].plot(time_, bestControl_[i][0,0,:], color = 'red')
    ax[0].plot(time_, bestState_[i][0,0,:], color= 'red')
    ax[1].plot(time_, bestControl_[i][0,1,:], color = 'blue')
    ax[0].plot(time_, bestState_[i][0,1,:], color= 'blue')
    ax[0].plot(time_, target_[0,0,:], linestyle = '--', color='red')
    ax[0].plot(time_, target_[0,1,:], linestyle = '--', color='blue')
    ax[0].set_xlim(-dur_pre,dur+dur_post)
    ax[1].set_xlim(-dur_pre,dur+dur_post)
    ax[0].axvspan(dur*t_pen[0], dur, alpha=0.2, color='gray')
    plt.show()
# Out:
# -------  6 0.4250000000000001 0.40000000000000013
# shift by  2223
# set cost params:  0.05 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  2.8584899295331505
# RUN  0 , total integrated cost =  2.8584899295331505
# Gradient descend method:  None
# RUN  0 , total integrated cost =  2.8584899295331505
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  471.9538368446909
# cost splitting :  0.0 [0.22611934 2.63237059]
# -------  7 0.4500000000000001 0.40000000000000013
# shift by  2327
# set cost params:  0.05 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  2.6323190158752476
# RUN  0 , total integrated cost =  2.6323190158752476
# Gradient descend method:  None
# RUN  0 , total integrated cost =  2.6323190158752476
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  677.860255446574
# cost splitting :  0.0 [0.02615936 2.60615966]
# -------  8 0.47500000000000014 0.40000000000000013
# shift by  2308
# set cost params:  0.05 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  2.2752910129804884
# RUN  0 , total integrated cost =  2.2752910129804884
# Gradient descend method:  None
# RUN  0 , total integrated cost =  2.2752910129804884
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  877.5573911507829
# cost splitting :  0.0 [0.15814189 2.11714912]
# -------  9 0.4000000000000001 0.42500000000000016
# shift by  2238
# set cost params:  0.05 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  10.506855347330225
# RUN  0 , total integrated cost =  10.506855347330225
# Gradient descend method:  None
# RUN  0 , total integrated cost =  10.506855347330225
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  232.11379765972552
# cost splitting :  4.5348026026500284e-17 [ 0.34092097 10.16593438]
# -------  10 0.4250000000000001 0.42500000000000016
# shift by  2279
# set cost params:  0.05 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.9321024280844425
# RUN  0 , total integrated cost =  3.9321024280844425
# Gradient descend method:  None
# RUN  0 , total integrated cost =  3.9321024280844425
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  455.57282451055954
# cost splitting :  0.0 [0.29631082 3.63579161]
# -------  11 0.4500000000000001 0.42500000000000016
# shift by  2295
# set cost params:  0.05 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.5395324563907584
# RUN  0 , total integrated cost =  3.5395324563907584
# Gradient descend method:  None
# RUN  0 , total integrated cost =  3.5395324563907584
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  665.571788546768
# cost splitting :  0.0 [0.06154069 3.47799177]
# -------  12 0.47500000000000014 0.42500000000000016
# shift by  2137
# set cost params:  0.05 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  2.497099657135434
# RUN  0 , total integrated cost =  2.497099657135434
# Gradient descend method:  None
# RUN  0 , total integrated cost =  2.497099657135434
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  878.560008314686
# cost splitting :  0.0 [0.09309149 2.40400817]
# -------  13 0.4000000000000001 0.4500000000000002
# shift by  2269
# set cost params:  0.05 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  5.8543421076552224
# RUN  0 , total integrated cost =  5.8543421076552224
# Gradient descend method:  None
# RUN  0 , total integrated cost =  5.8543421076552224
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  208.86235665930843
# cost splitting :  2.1788196473178934e-10 [3.35350665 2.50083546]
# -------  14 0.4250000000000001 0.4500000000000002
# shift by  2264
# set cost params:  0.05 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  5.217733437109176
# RUN  0 , total integrated cost =  5.217733437109176
# Gradient descend method:  None
# RUN  0 , total integrated cost =  5.217733437109176
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  439.80877803490125
# cost splitting :  4.1008145297009206e-25 [2.87860672 2.33912672]
# -------  15 0.4500000000000001 0.4500000000000002
# shift by  2155
# set cost params:  0.05 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  5.07988891068972
# RUN  0 , total integrated cost =  5.07988891068972
# Gradient descend method:  None
# RUN  0 , total integrated cost =  5.07988891068972
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  650.9037320173404
# cost splitting :  1.8225842354226319e-25 [0.22933624 4.85055268]
# -------  16 0.47500000000000014 0.4500000000000002
# shift by  2165
# set cost params:  0.05 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  4.020838817622436
# RUN  0 , total integrated cost =  4.020838817622436
# Gradient descend method:  None
# RUN  0 , total integrated cost =  4.020838817622436
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  867.0448977562043
# cost splitting :  0.0 [0.20134174 3.81949707]
# -------  17 0.5000000000000002 0.4500000000000002
# shift by  2307
# set cost params:  0.05 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  2.0718520428165643
# RUN  0 , total integrated cost =  2.0718520428165643
# Gradient descend method:  None
# RUN  0 , total integrated cost =  2.0718520428165643
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  1088.3381695519752
# cost splitting :  0.0 [2.07185204 0.        ]
# -------  18 0.4000000000000001 0.4750000000000002
# shift by  2270
# set cost params:  0.05 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  6.856066480056395
# RUN  0 , total integrated cost =  6.856066480056395
# Gradient descend method:  None
# RUN  0 , total integrated cost =  6.856066480056395
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  183.55796221510641
# cost splitting :  2.688626677468768e-10 [6.26705715 0.58900933]
# -------  19 0.4250000000000001 0.4750000000000002
# shift by  2268
# set cost params:  0.05 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  5.654534611013142
# RUN  0 , total integrated cost =  5.654534611013142
# Gradient descend method:  None
# RUN  0 , total integrated cost =  5.654534611013142
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  425.17584252715665
# cost splitting :  6.543127892265141e-25 [5.65453461 0.        ]

# %%
conv = [None] * len(exc)

tol = 1e-10

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
        
    while not conv[i]:
        max_it = int(1000)

        weight_ = ( cost_uncontrolled[i] - costnode_[i][0][0][0] ) / sum( costnode_[i][2][0][:] )
            
        dur = d_array[0]
        aln.params.duration = dur
        cost.setParams(wp, weight_ * factor_we, weight_ * factor_ws)
        weights_[i] = cost.getParams()

        setinit(initVars[i], aln)

        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        control0 = aln.getZeroControl()
        control0 = bestControl_[i][:,:,n_pre-1:-n_post+1]

        bestControl_[i], bestState_[i], cost_[i], runtime_, grad_, phi_, phi1_, costnode_[i] = aln.A1(
            control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
            prec_variables_ = p_var, transition_time_ = t_pen[0])
        
        if cost_[i][2] == 0.:
            conv[i] = True

        #print('uncontrolled cost : ', cost_uncontrolled[i])
        print('cost splitting : ', costnode_[i][0][0][0], costnode_[i][2][0][:2])

        if conv[i]:
            time_ = np.arange(-dur_pre,round(dur+dur_post+aln.params.dt,1),aln.params.dt)
            target_ = aln.getZeroTarget()
            target_[:,0,:] = target[i][0]
            target_[:,1,:] = target[i][1]
        
            fig, ax = plt.subplots(2,1, constrained_layout=True, figsize = (4,4) )
            ax[1].plot(time_, bestControl_[i][0,0,:], color = 'red')
            ax[0].plot(time_, bestState_[i][0,0,:], color= 'red')
            ax[1].plot(time_, bestControl_[i][0,1,:], color = 'blue')
            ax[0].plot(time_, bestState_[i][0,1,:], color= 'blue')
            ax[0].plot(time_, target_[0,0,:], linestyle = '--', color='red')
            ax[0].plot(time_, target_[0,1,:], linestyle = '--', color='blue')
            ax[0].set_xlim(-dur_pre,dur+dur_post)
            ax[1].set_xlim(-dur_pre,dur+dur_post)
            ax[0].axvspan(dur*t_pen[0], dur, alpha=0.2, color='gray')
            plt.show()

        with open(file_,'wb') as f:
            pickle.dump([bestControl_, bestState_, cost_, costnode_, weights_], f)

# %%
c_var = [0,1]
tol = 1. * 1e-8     # 5.7
conv_shift = [None] * len(exc)

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    
    if i in bad:
        continue
        
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    aln.params.duration = dur
    max_it = int(1000)
    k = 0
    
    while not conv_shift[i]:
            
        weight_ = 1.
        cost.setParams(wp, weight_ * factor_we, weight_ * factor_ws)
        weights_[i] = cost.getParams()

        setinit(initVars[i], aln)

        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        control0 = aln.getZeroControl()
        control0 = bestControl_[i][:,:,n_pre-1:-n_post+1]

        bestControl_[i], bestState_[i], cost_[i], runtime_, grad_, phi_, phi1_, costnode_[i]= aln.A1(
            control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
            prec_variables_ = p_var, transition_time_ = t_pen[0])
                
        if cost_[i][-1] == 0.:
            conv_shift[i] = True

        print('uncontrolled cost : ', cost_uncontrolled[i])
        print('cost splitting : ', costnode_[i][0][0][0], costnode_[i][2][0][:2])

        if conv_shift[i] and False:
            plot_time_array = np.arange(0.,round(dur+aln.params.dt,1),aln.params.dt)

            fig, ax = plt.subplots(2,1, constrained_layout=True, figsize = (4,8) )

            ax[0].plot(plot_time_array, bestState_[i][0,0,n_pre-1:-n_post+1], color= 'red')
            ax[0].plot(plot_time_array, bestState_[i][0,1,n_pre-1:-n_post+1], color= 'blue')

            ax[1].plot(plot_time_array, bestControl_[i][0,0,n_pre-1:-n_post+1], color = 'blue')
            ax[1].plot(plot_time_array, bestControl_[i][0,1,n_pre-1:-n_post+1], color = 'red')
            
            plt.show()

        with open(file_,'wb') as f:
            pickle.dump([bestControl_, bestState_, cost_, costnode_, weights_], f)
        
        k += 1
# Out:
# -------  6 0.4250000000000001 0.40000000000000013
# set cost params:  0.05 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  2.8584899295331505
# RUN  0 , total integrated cost =  2.8584899295331505
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.8584899295331505
# Control only changes marginally.
# RUN  1 , total integrated cost =  2.8584899295331505
# Improved over  1  iterations in  0.03843921102816239  seconds by  0.0  percent.
# uncontrolled cost :  471.9538368446909
# cost splitting :  0.0 [0.22611934 2.63237059]
# -------  7 0.4500000000000001 0.40000000000000013
# set cost params:  0.05 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  2.6323190158752476
# RUN  0 , total integrated cost =  2.6323190158752476
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.6323190158752476
# Control only changes marginally.
# RUN  1 , total integrated cost =  2.6323190158752476
# Improved over  1  iterations in  0.03704002604354173  seconds by  0.0  percent.
# uncontrolled cost :  677.860255446574
# cost splitting :  0.0 [0.02615936 2.60615966]
# -------  8 0.47500000000000014 0.40000000000000013
# set cost params:  0.05 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  2.2752910129804884
# RUN  0 , total integrated cost =  2.2752910129804884
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.2752910129804884
# Control only changes marginally.
# RUN  1 , total integrated cost =  2.2752910129804884
# Improved over  1  iterations in  0.036751963023561984  seconds by  0.0  percent.
# uncontrolled cost :  877.5573911507829
# cost splitting :  0.0 [0.15814189 2.11714912]
# -------  9 0.4000000000000001 0.42500000000000016
# set cost params:  0.05 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  10.506855347330225
# RUN  0 , total integrated cost =  10.506855347330225
# Gradient descend method:  None
# RUN  1 , total integrated cost =  10.506855347330225
# Control only changes marginally.
# RUN  1 , total integrated cost =  10.506855347330225
# Improved over  1  iterations in  0.0531361160101369  seconds by  0.0  percent.
# uncontrolled cost :  232.11379765972552
# cost splitting :  4.5348026026500284e-17 [ 0.34092097 10.16593438]
# -------  10 0.4250000000000001 0.42500000000000016
# set cost params:  0.05 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.9321024280844425
# RUN  0 , total integrated cost =  3.9321024280844425
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.9321024280844425
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.9321024280844425
# Improved over  1  iterations in  0.036669361987151206  seconds by  0.0  percent.
# uncontrolled cost :  455.57282451055954
# cost splitting :  0.0 [0.29631082 3.63579161]
# -------  11 0.4500000000000001 0.42500000000000016
# set cost params:  0.05 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.5395324563907584
# RUN  0 , total integrated cost =  3.5395324563907584
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.5395324563907584
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.5395324563907584
# Improved over  1  iterations in  0.03679933300008997  seconds by  0.0  percent.
# uncontrolled cost :  665.571788546768
# cost splitting :  0.0 [0.06154069 3.47799177]
# -------  12 0.47500000000000014 0.42500000000000016
# set cost params:  0.05 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  2.497099657135434
# RUN  0 , total integrated cost =  2.497099657135434
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.497099657135434
# Control only changes marginally.
# RUN  1 , total integrated cost =  2.497099657135434
# Improved over  1  iterations in  0.03659336600685492  seconds by  0.0  percent.
# uncontrolled cost :  878.560008314686
# cost splitting :  0.0 [0.09309149 2.40400817]
# -------  13 0.4000000000000001 0.4500000000000002
# set cost params:  0.05 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  5.8543421076552224
# RUN  0 , total integrated cost =  5.8543421076552224
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.854342107646885
# RUN  2 , total integrated cost =  5.854342107646885
# Control only changes marginally.
# RUN  2 , total integrated cost =  5.854342107646885
# Improved over  2  iterations in  0.21589137398405  seconds by  1.4240697510103928e-10  percent.
# uncontrolled cost :  208.86235665930843
# cost splitting :  1.5602931491449417e-11 [3.35350665 2.50083546]
# -------  14 0.4250000000000001 0.4500000000000002
# set cost params:  0.05 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  5.217733437109176
# RUN  0 , total integrated cost =  5.217733437109176
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.217733437109176
# Control only changes marginally.
# RUN  1 , total integrated cost =  5.217733437109176
# Improved over  1  iterations in  0.03748132899636403  seconds by  0.0  percent.
# uncontrolled cost :  439.80877803490125
# cost splitting :  4.1008145297009206e-25 [2.87860672 2.33912672]
# -------  15 0.4500000000000001 0.4500000000000002
# set cost params:  0.05 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  5.07988891068972
# RUN  0 , total integrated cost =  5.07988891068972
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.07988891068972
# Control only changes marginally.
# RUN  1 , total integrated cost =  5.07988891068972
# Improved over  1  iterations in  0.03886621800484136  seconds by  0.0  percent.
# uncontrolled cost :  650.9037320173404
# cost splitting :  1.8225842354226319e-25 [0.22933624 4.85055268]
# -------  16 0.47500000000000014 0.4500000000000002
# set cost params:  0.05 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  4.020838817622436
# RUN  0 , total integrated cost =  4.020838817622436
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.020838817622436
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.020838817622436
# Improved over  1  iterations in  0.03847798699280247  seconds by  0.0  percent.
# uncontrolled cost :  867.0448977562043
# cost splitting :  0.0 [0.20134174 3.81949707]
# -------  17 0.5000000000000002 0.4500000000000002
# set cost params:  0.05 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  2.0718520428165643
# RUN  0 , total integrated cost =  2.0718520428165643
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.0718520428165643
# Control only changes marginally.
# RUN  1 , total integrated cost =  2.0718520428165643
# Improved over  1  iterations in  0.039344238000921905  seconds by  0.0  percent.
# uncontrolled cost :  1088.3381695519752
# cost splitting :  0.0 [2.07185204 0.        ]
# -------  18 0.4000000000000001 0.4750000000000002
# set cost params:  0.05 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  6.856066480056395
# RUN  0 , total integrated cost =  6.856066480056395
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.856066480056395
# Control only changes marginally.
# RUN  1 , total integrated cost =  6.856066480056395
# Improved over  1  iterations in  0.1116921259672381  seconds by  0.0  percent.
# uncontrolled cost :  183.55796221510641
# cost splitting :  2.688626677468768e-10 [6.26705715 0.58900933]
# -------  19 0.4250000000000001 0.4750000000000002
# set cost params:  0.05 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  5.654534611013142
# RUN  0 , total integrated cost =  5.654534611013142
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.654534611013142
# Control only changes marginally.
# RUN  1 , total integrated cost =  5.654534611013142
# Improved over  1  iterations in  0.035924386989790946  seconds by  0.0  percent.
# uncontrolled cost :  425.17584252715665
# cost splitting :  6.543127892265141e-25 [5.65453461 0.        ]

# %%
c_var = [0,1]
tol = 1. * 1e-9     # 5.7
conv_shift = [None] * len(exc)

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    
    if i in bad:
        continue
        
    if i == 1:
        continue
        
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    aln.params.duration = dur
    max_it = int(1000)
    k = 0
    
    while not conv_shift[i]:
            
        weight_ = 1.
        cost.setParams(wp, weight_ * factor_we, weight_ * factor_ws)
        weights_[i] = cost.getParams()

        setinit(initVars[i], aln)

        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        control0 = aln.getZeroControl()
        control0 = bestControl_[i][:,:,n_pre-1:-n_post+1]

        bestControl_[i], bestState_[i], cost_[i], runtime_, grad_, phi_, phi1_, costnode_[i]= aln.A1(
            control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
            prec_variables_ = p_var, transition_time_ = t_pen[0])
                
        if cost_[i][-1] == 0.:
            conv_shift[i] = True

        print('uncontrolled cost : ', cost_uncontrolled[i])
        print('cost splitting : ', costnode_[i][0][0][0], costnode_[i][2][0][:2])

        if conv_shift[i] and False:
            plot_time_array = np.arange(0.,round(dur+aln.params.dt,1),aln.params.dt)

            fig, ax = plt.subplots(2,1, constrained_layout=True, figsize = (4,8) )

            ax[0].plot(plot_time_array, bestState_[i][0,0,n_pre-1:-n_post+1], color= 'red')
            ax[0].plot(plot_time_array, bestState_[i][0,1,n_pre-1:-n_post+1], color= 'blue')

            ax[1].plot(plot_time_array, bestControl_[i][0,0,n_pre-1:-n_post+1], color = 'blue')
            ax[1].plot(plot_time_array, bestControl_[i][0,1,n_pre-1:-n_post+1], color = 'red')
            
            plt.show()

        with open(file_,'wb') as f:
            pickle.dump([bestControl_, bestState_, cost_, costnode_, weights_], f)
        
        k += 1
# Out:
# -------  6 0.4250000000000001 0.40000000000000013
# set cost params:  0.05 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  2.8584899295331505
# RUN  0 , total integrated cost =  2.8584899295331505
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.8584899295331505
# Control only changes marginally.
# RUN  1 , total integrated cost =  2.8584899295331505
# Improved over  1  iterations in  0.03707122302148491  seconds by  0.0  percent.
# uncontrolled cost :  471.9538368446909
# cost splitting :  0.0 [0.22611934 2.63237059]
# -------  7 0.4500000000000001 0.40000000000000013
# set cost params:  0.05 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  2.6323190158752476
# RUN  0 , total integrated cost =  2.6323190158752476
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.6323190158752476
# Control only changes marginally.
# RUN  1 , total integrated cost =  2.6323190158752476
# Improved over  1  iterations in  0.040889034047722816  seconds by  0.0  percent.
# uncontrolled cost :  677.860255446574
# cost splitting :  0.0 [0.02615936 2.60615966]
# -------  8 0.47500000000000014 0.40000000000000013
# set cost params:  0.05 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  2.2752910129804884
# RUN  0 , total integrated cost =  2.2752910129804884
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.2752910129804884
# Control only changes marginally.
# RUN  1 , total integrated cost =  2.2752910129804884
# Improved over  1  iterations in  0.03802296501817182  seconds by  0.0  percent.
# uncontrolled cost :  877.5573911507829
# cost splitting :  0.0 [0.15814189 2.11714912]
# -------  9 0.4000000000000001 0.42500000000000016
# set cost params:  0.05 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  10.506855347330225
# RUN  0 , total integrated cost =  10.506855347330225
# Gradient descend method:  None
# RUN  1 , total integrated cost =  10.506855347330225
# Control only changes marginally.
# RUN  1 , total integrated cost =  10.506855347330225
# Improved over  1  iterations in  0.06682042597094551  seconds by  0.0  percent.
# uncontrolled cost :  232.11379765972552
# cost splitting :  4.5348026026500284e-17 [ 0.34092097 10.16593438]
# -------  10 0.4250000000000001 0.42500000000000016
# set cost params:  0.05 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.9321024280844425
# RUN  0 , total integrated cost =  3.9321024280844425
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.9321024280844425
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.9321024280844425
# Improved over  1  iterations in  0.036030183953698725  seconds by  0.0  percent.
# uncontrolled cost :  455.57282451055954
# cost splitting :  0.0 [0.29631082 3.63579161]
# -------  11 0.4500000000000001 0.42500000000000016
# set cost params:  0.05 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.5395324563907584
# RUN  0 , total integrated cost =  3.5395324563907584
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.5395324563907584
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.5395324563907584
# Improved over  1  iterations in  0.03540913201868534  seconds by  0.0  percent.
# uncontrolled cost :  665.571788546768
# cost splitting :  0.0 [0.06154069 3.47799177]
# -------  12 0.47500000000000014 0.42500000000000016
# set cost params:  0.05 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  2.497099657135434
# RUN  0 , total integrated cost =  2.497099657135434
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.497099657135434
# Control only changes marginally.
# RUN  1 , total integrated cost =  2.497099657135434
# Improved over  1  iterations in  0.03632914897752926  seconds by  0.0  percent.
# uncontrolled cost :  878.560008314686
# cost splitting :  0.0 [0.09309149 2.40400817]
# -------  13 0.4000000000000001 0.4500000000000002
# set cost params:  0.05 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  5.854342107646885
# RUN  0 , total integrated cost =  5.854342107646885
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.854342107646858
# RUN  2 , total integrated cost =  5.854342107646852
# RUN  3 , total integrated cost =  5.854342107646847
# RUN  4 , total integrated cost =  5.854342107646847
# Control only changes marginally.
# RUN  4 , total integrated cost =  5.854342107646847
# Improved over  4  iterations in  0.4415461419848725  seconds by  6.536993168992922e-13  percent.
# uncontrolled cost :  208.86235665930843
# cost splitting :  7.415688997047881e-12 [3.35350665 2.50083546]
# -------  14 0.4250000000000001 0.4500000000000002
# set cost params:  0.05 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  5.217733437109176
# RUN  0 , total integrated cost =  5.217733437109176
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.217733437109176
# Control only changes marginally.
# RUN  1 , total integrated cost =  5.217733437109176
# Improved over  1  iterations in  0.03607500100042671  seconds by  0.0  percent.
# uncontrolled cost :  439.80877803490125
# cost splitting :  4.1008145297009206e-25 [2.87860672 2.33912672]
# -------  15 0.4500000000000001 0.4500000000000002
# set cost params:  0.05 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  5.07988891068972
# RUN  0 , total integrated cost =  5.07988891068972
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.07988891068972
# Control only changes marginally.
# RUN  1 , total integrated cost =  5.07988891068972
# Improved over  1  iterations in  0.036278824030887336  seconds by  0.0  percent.
# uncontrolled cost :  650.9037320173404
# cost splitting :  1.8225842354226319e-25 [0.22933624 4.85055268]
# -------  16 0.47500000000000014 0.4500000000000002
# set cost params:  0.05 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  4.020838817622436
# RUN  0 , total integrated cost =  4.020838817622436
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.020838817622436
# Control only changes marginally.
# RUN  1 , total integrated cost =  4.020838817622436
# Improved over  1  iterations in  0.03804788104025647  seconds by  0.0  percent.
# uncontrolled cost :  867.0448977562043
# cost splitting :  0.0 [0.20134174 3.81949707]
# -------  17 0.5000000000000002 0.4500000000000002
# set cost params:  0.05 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  2.0718520428165643
# RUN  0 , total integrated cost =  2.0718520428165643
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2.0718520428165643
# Control only changes marginally.
# RUN  1 , total integrated cost =  2.0718520428165643
# Improved over  1  iterations in  0.03706920600961894  seconds by  0.0  percent.
# uncontrolled cost :  1088.3381695519752
# cost splitting :  0.0 [2.07185204 0.        ]
# -------  18 0.4000000000000001 0.4750000000000002
# set cost params:  0.05 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  6.856066480056395
# RUN  0 , total integrated cost =  6.856066480056395
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.856066480056395
# Control only changes marginally.
# RUN  1 , total integrated cost =  6.856066480056395
# Improved over  1  iterations in  0.13349906401708722  seconds by  0.0  percent.
# uncontrolled cost :  183.55796221510641
# cost splitting :  2.688626677468768e-10 [6.26705715 0.58900933]
# -------  19 0.4250000000000001 0.4750000000000002
# set cost params:  0.05 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  5.654534611013142
# RUN  0 , total integrated cost =  5.654534611013142
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.654534611013142
# Control only changes marginally.
# RUN  1 , total integrated cost =  5.654534611013142
# Improved over  1  iterations in  0.03689139796188101  seconds by  0.0  percent.
# uncontrolled cost :  425.17584252715665
# cost splitting :  6.543127892265141e-25 [5.65453461 0.        ]

# %%
for i in i_range:
    print("------- ", i, exc[i], inh[i])
    plot_time_array = np.arange(0.,round(dur+aln.params.dt,1),aln.params.dt)
    
    if i in bad:
        print("bad")
        continue
    
    if type(bestControl_[i]) == type(None):
        bad.append(i)
        print("No solution")
        continue
        
    if np.amax(np.abs(bestControl_[i])) < 1e-6:
        bad.append(i)
        print("zero solution")
        continue

    fig, ax = plt.subplots(3,1, constrained_layout=True, figsize = (4,8) )

    ax[0].plot(plot_time_array, bestState_[i][0,0,n_pre-1:-n_post+1], color= 'red')
    ax[0].plot(plot_time_array, bestState_[i][0,1,n_pre-1:-n_post+1], color= 'blue')

    ax[1].plot(plot_time_array, bestControl_[i][0,0,n_pre-1:-n_post+1], color = 'red')
    ax[1].plot(plot_time_array, bestControl_[i][0,1,n_pre-1:-n_post+1], color = 'blue')

    for k in range(3):
        ax[k].set_xlim(0.,dur)
    plt.show()
# Out:
# -------  0 0.4000000000000001 0.3500000000000001
# -------  1 0.4250000000000001 0.3500000000000001
# -------  2 0.4000000000000001 0.3750000000000001
# -------  3 0.4250000000000001 0.3750000000000001
# -------  4 0.4500000000000001 0.3750000000000001
# -------  5 0.4000000000000001 0.40000000000000013
# -------  20 0.4500000000000001 0.4750000000000002
# -------  50 0.47500000000000014 0.6000000000000003
