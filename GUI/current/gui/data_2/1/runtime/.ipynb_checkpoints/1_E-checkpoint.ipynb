# %%
import datetime
print(datetime.datetime.now())
# Out:
# 2022-01-07 16:33:57.699229

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import sys
import pickle

path = os.getcwd().split(os.sep + 'GUI')[0]
if path not in sys.path:
    print("not here")
    sys.path.append(path)

from neurolib.models.aln import ALNModel
from neurolib.utils import plotFunctions as plotFunc
from neurolib.utils import costFunctions as cost
import neurolib.dashboard.functions as functions
import neurolib.dashboard.data as data
    
# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2 

#path = os.path.join(os.getcwd(), "plots")
# Out:
# not here

# %%
grid_data_file = os.path.join(os.getcwd().split('data')[0], 'bi.pickle')
print(grid_data_file)
with open(grid_data_file,'rb') as f:
    load_array= pickle.load(f)
exc = load_array[0]
inh = load_array[1]
print(len(exc))
# Out:
# /home/lena/Promotion/neurolib/GUI/current/gui/bi.pickle
# 147

# %%
aln = ALNModel()
N = aln.params.N

data.set_parameters(aln)

state_vars = aln.state_vars
init_vars = aln.init_vars

##############################################################
def setinit(init_vars_, model):
    state_vars = model.state_vars
    init_vars = model.init_vars
    for iv in range(len(init_vars)):
        for sv in range(len(state_vars)):
            if state_vars[sv] in init_vars[iv]:
                #print("set init vars ", )
                if model.params[init_vars[iv]].ndim == 2:
                    model.params[init_vars[iv]][0,:] = init_vars_[sv]
                else:
                    model.params[init_vars[iv]][0] = init_vars_[sv]
                    
##############################################################               
def setmaxmincontrol(max_c_c, min_c_c, max_c_r, min_c_r):
    import numpy as np
    
    max_cntrl = np.zeros(( 6 ))
    min_cntrl = np.zeros(( 6 ))
    
    max_cntrl[0] = max_c_c
    min_cntrl[0] = min_c_c
    max_cntrl[1] = max_c_c
    min_cntrl[1] = min_c_c
    max_cntrl[2] = max_c_r
    min_cntrl[2] = min_c_r
    max_cntrl[3] = max_c_r
    min_cntrl[3] = min_c_r
    max_cntrl[4] = max_c_r
    min_cntrl[4] = min_c_r
    max_cntrl[5] = max_c_r
    min_cntrl[5] = min_c_r
            
    return max_cntrl, min_cntrl

# %%
d_array = np.arange(500., 20, -0.1)
t0_array = d_array - 20.
t_pen = np.zeros(( t0_array.shape ))
for i in range(len(t_pen)):
    t_pen[i] = t0_array[i] / d_array[i]

# %%
bestControl_ = [None] * len(exc) 
bestState_ = [None] * len(exc) 
cost_ = [None] * len(exc) 
costnode_ = [None] * len(exc) 
weights_ = [None] * len(exc) 
convergence_ = [None] * len(exc) 

initVars = [None] * len(exc)
target = [None] * len(exc)
cost_uncontrolled = [None] * len(exc)
ws = [None] * len(exc)
conv = [None] * len(exc)
conv_shift = [None] * len(exc)

# %%
file_ = '1_E.pickle'
folder = str(os.getcwd().split('data_2')[1])
print(folder)
case = str(folder[1])
# Out:
# /1/runtime

# %%
dur_pre = 10
dur_post = 10

n_pre = int(np.around(dur_pre/aln.params.dt + 1.,1))
n_post = int(np.around(dur_post/aln.params.dt + 1.,1))

tol = 1e-10
start_step = 10.
c_scheme = np.zeros(( 1,1 ))
c_scheme[0,0] = 1.
u_mat = np.identity(1)
u_scheme = np.array([[1.]])

c_var = [1]
p_var = [0]

if case in ['1', '2']:    # low to high
    max_I = [3., -3.]
else:
    max_I = [-3., 3.]
    
if case in ['1', '3']:    # sparsity
    factor_ws = 1.
    factor_we = 0.
else:
    factor_ws = 0.
    factor_we = 1.
    
maxC = [5., -5., 0.18, 0.]
max_cntrl, min_cntrl = setmaxmincontrol(maxC[0], maxC[1], maxC[2], maxC[3])

# %%
if os.path.isfile(file_) :
    print("file found")
    
    with open(file_,'rb') as f:
        load_array = pickle.load(f)

    bestControl_ = load_array[0]
    bestState_ = load_array[1]
    cost_ = load_array[2]
    costnode_ = load_array[3]
    weights_ = load_array[4]

# %%
# get initial parameters and target states

i_range = [20]

data.set_parameters(aln)

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    aln.params.duration = 3000.
    
    control0 = aln.getZeroControl()
    control0 = functions.step_control(aln, maxI_ = max_I[0])

    aln.run(control=control0)
    
    target_rates = np.zeros((2))
    target_rates[0] = aln.rates_exc[0,-1] 
    target_rates[1] = aln.rates_inh[0,-1]

    control0 = functions.step_control(aln, maxI_ = max_I[1])
    aln.run(control=control0)

    init_state_vars = np.zeros(( len(state_vars) ))
    for j in range(len(state_vars)):
        if aln.state[state_vars[j]].size == 1:
            init_state_vars[j] = aln.state[state_vars[j]][0]
        else:
            init_state_vars[j] = aln.state[state_vars[j]][0,-1]

    initVars[i] = init_state_vars
    target[i] = [target_rates[0], target_rates[1]]
# Out:
# -------  20 0.4500000000000001 0.4750000000000002

# %%
# get uncontrolled cost

data.set_parameters(aln)

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    dur = d_array[0]
    aln.params.duration = dur
    
    target_ = aln.getZeroTarget()
    target_[:,0,:] = target[i][0]
    target_[:,1,:] = target[i][1]
            
    cost.setParams(1.0, 0.0, 0.0)

    setinit(initVars[i], aln)
    control0 = aln.getZeroControl()

    # "HS", "FR", "PR", "HZ"
    cgv = None
    max_it = 0

    bestControl_init_, bestState_init_, cost_init_, runtime_init_, grad_init_, phi_init_, phi1_, costnode_init_ = aln.A1(
        control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
        prec_variables_ = p_var, transition_time_ = t_pen[0])
    
    cost_uncontrolled[i] = cost_init_[0]
# Out:
# -------  20 0.4500000000000001 0.4750000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  316931.9421284
# RUN  0 , total integrated cost =  316931.9421284
# Gradient descend method:  None
# RUN  0 , total integrated cost =  316931.9421284
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.

# %%
cgv = None
j = 0

wp = 1.

for i in i_range:

    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
        
    found_exponent = False
    found_digit_0 = False
    found_digit_1 = False
    exponent = 5
    sig_digit = [1., 0.]
    
    while not found_digit_1:
        
        ws[i] = sig_digit[0] * 10**exponent + sig_digit[1] * 10**(exponent-1.)
    
        dur = d_array[0]
        aln.params.duration = dur
        setinit(initVars[i], aln)

        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        control0 = aln.getZeroControl()
        cost.setParams(wp, 0., ws[i])
        max_it = int(10)
        if found_digit_0:
            max_it = int(50)

        bestControl_[i], bestState_[i], cost_[i], runtime_, grad_, phi_, phi1_, costnode_[i] = aln.A1(
            control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
            prec_variables_ = p_var, transition_time_ = t_pen[0])
        
        if found_exponent == False and cost_[i][-1] == 0.:
            exponent -= 1
            continue
        elif found_exponent == False and found_digit_0 == False:
            found_exponent = True
            sig_digit[0] = 9.
        elif found_exponent == True and found_digit_0 == False and cost_[i][-1] == 0.:
            sig_digit[0] -= 1.
        elif found_exponent == True and found_digit_0 == False:
            found_digit_0 = True
            sig_digit[1] = 9.
        elif found_exponent == True and found_digit_0 == True and found_digit_1 == False and cost_[i][-1] == 0.:
            sig_digit[1] -= 1.
        elif found_exponent == True and found_digit_0 == True and found_digit_1 == False:
            print("sparsity weight = ", ws[i])

            break
# Out:
# -------  20 0.4500000000000001 0.4750000000000002
# set cost params:  1.0 0.0 100000.0
# interpolate adjoint :  True True True
# initial cost =  316931.9421284
# RUN  0 , total integrated cost =  316931.9421284
# Gradient descend method:  None
# RUN  1 , total integrated cost =  316931.9421284
# Control only changes marginally.
# RUN  1 , total integrated cost =  316931.9421284
# Improved over  1  iterations in  8.3987630920019  seconds by  0.0  percent.
# set cost params:  1.0 0.0 10000.0
# interpolate adjoint :  True True True
# initial cost =  316931.9421284
# RUN  0 , total integrated cost =  316931.9421284
# Gradient descend method:  None
# RUN  1 , total integrated cost =  142217.12614158593
# RUN  2 , total integrated cost =  119867.45438783456
# RUN  3 , total integrated cost =  100731.49075476563
# RUN  4 , total integrated cost =  89386.6485051245
# RUN  5 , total integrated cost =  80225.53523707463
# RUN  6 , total integrated cost =  74107.38816338005
# RUN  7 , total integrated cost =  69153.83545104953
# RUN  8 , total integrated cost =  65631.3547825495
# RUN  9 , total integrated cost =  62691.666833234136
# RUN  10 , total integrated cost =  60499.13235980919
# RUN  10 , total integrated cost =  60499.13235980919
# Improved over  10  iterations in  0.7445936069707386  seconds by  80.91100191620984  percent.
# set cost params:  1.0 0.0 90000.0
# interpolate adjoint :  True True True
# initial cost =  316931.9421284
# RUN  0 , total integrated cost =  316931.9421284
# Gradient descend method:  None
# RUN  1 , total integrated cost =  316931.9421284
# Control only changes marginally.
# RUN  1 , total integrated cost =  316931.9421284
# Improved over  1  iterations in  0.12595574598526582  seconds by  0.0  percent.
# set cost params:  1.0 0.0 80000.0
# interpolate adjoint :  True True True
# initial cost =  316931.9421284
# RUN  0 , total integrated cost =  316931.9421284
# Gradient descend method:  None
# RUN  1 , total integrated cost =  316931.9421284
# Control only changes marginally.
# RUN  1 , total integrated cost =  316931.9421284
# Improved over  1  iterations in  0.11960279097547755  seconds by  0.0  percent.
# set cost params:  1.0 0.0 70000.0
# interpolate adjoint :  True True True
# initial cost =  316931.9421284
# RUN  0 , total integrated cost =  316931.9421284
# Gradient descend method:  None
# RUN  1 , total integrated cost =  316931.9421284
# Control only changes marginally.
# RUN  1 , total integrated cost =  316931.9421284
# Improved over  1  iterations in  0.1203762239892967  seconds by  0.0  percent.
# set cost params:  1.0 0.0 60000.0
# interpolate adjoint :  True True True
# initial cost =  316931.9421284
# RUN  0 , total integrated cost =  316931.9421284
# Gradient descend method:  None
# RUN  1 , total integrated cost =  316931.9421284
# Control only changes marginally.
# RUN  1 , total integrated cost =  316931.9421284
# Improved over  1  iterations in  0.11720392399001867  seconds by  0.0  percent.
# set cost params:  1.0 0.0 50000.0
# interpolate adjoint :  True True True
# initial cost =  316931.9421284
# RUN  0 , total integrated cost =  316931.9421284
# Gradient descend method:  None
# RUN  1 , total integrated cost =  316931.9421284
# Control only changes marginally.
# RUN  1 , total integrated cost =  316931.9421284
# Improved over  1  iterations in  0.12085052998736501  seconds by  0.0  percent.
# set cost params:  1.0 0.0 40000.0
# interpolate adjoint :  True True True
# initial cost =  316931.9421284
# RUN  0 , total integrated cost =  316931.9421284
# Gradient descend method:  None
# RUN  1 , total integrated cost =  316931.9421284
# Control only changes marginally.
# RUN  1 , total integrated cost =  316931.9421284
# Improved over  1  iterations in  0.12191592797171324  seconds by  0.0  percent.
# set cost params:  1.0 0.0 30000.0
# interpolate adjoint :  True True True
# initial cost =  316931.9421284
# RUN  0 , total integrated cost =  316931.9421284
# Gradient descend method:  None
# RUN  1 , total integrated cost =  316931.9421284
# Control only changes marginally.
# RUN  1 , total integrated cost =  316931.9421284
# Improved over  1  iterations in  0.12071638001361862  seconds by  0.0  percent.
# set cost params:  1.0 0.0 20000.0
# interpolate adjoint :  True True True
# initial cost =  316931.9421284
# RUN  0 , total integrated cost =  316931.9421284
# Gradient descend method:  None
# RUN  1 , total integrated cost =  189242.07505525992
# RUN  2 , total integrated cost =  163635.73690168757
# RUN  3 , total integrated cost =  145455.9709626386
# RUN  4 , total integrated cost =  134736.30960960683
# RUN  5 , total integrated cost =  126102.81149938825
# RUN  6 , total integrated cost =  120270.47949801855
# RUN  7 , total integrated cost =  115252.72872138502
# RUN  8 , total integrated cost =  111605.28940776839
# RUN  9 , total integrated cost =  108256.64830034491
# RUN  10 , total integrated cost =  105600.99272504433
# RUN  10 , total integrated cost =  105600.99272504433
# Improved over  10  iterations in  0.7795970549923368  seconds by  66.68023045709235  percent.
# set cost params:  1.0 0.0 29000.0
# interpolate adjoint :  True True True
# initial cost =  316931.9421284
# RUN  0 , total integrated cost =  316931.9421284
# Gradient descend method:  None
# RUN  1 , total integrated cost =  316931.9421284
# Control only changes marginally.
# RUN  1 , total integrated cost =  316931.9421284
# Improved over  1  iterations in  0.12848046503495425  seconds by  0.0  percent.
# set cost params:  1.0 0.0 28000.0
# interpolate adjoint :  True True True
# initial cost =  316931.9421284
# RUN  0 , total integrated cost =  316931.9421284
# Gradient descend method:  None
# RUN  1 , total integrated cost =  226862.03418619913
# RUN  2 , total integrated cost =  195833.83542160812
# RUN  3 , total integrated cost =  179129.70957956376
# RUN  4 , total integrated cost =  169127.63022334146
# RUN  5 , total integrated cost =  161002.52333223278
# RUN  6 , total integrated cost =  155441.86407651988
# RUN  7 , total integrated cost =  150867.26440192395
# RUN  8 , total integrated cost =  147570.4296085127
# RUN  9 , total integrated cost =  144744.2366377953
# RUN  10 , total integrated cost =  142538.1356675909
# RUN  11 , total integrated cost =  140633.2132563471
# RUN  12 , total integrated cost =  139105.9507233395
# RUN  13 , total integrated cost =  137732.95923703158
# RUN  14 , total integrated cost =  136589.1136888283
# RUN  15 , total integrated cost =  135526.22141556276
# RUN  16 , total integrated cost =  134598.8272625918
# RUN  17 , total integrated cost =  133740.05203469913
# RUN  18 , total integrated cost =  133024.06350754303
# RUN  19 , total integrated cost =  132308.27175178603
# RUN  20 , total integrated cost =  131686.42809450201
# RUN  30 , total integrated cost =  127607.62241582967
# RUN  40 , total integrated cost =  124535.89723452441
# RUN  50 , total integrated cost =  121328.370460204
# RUN  50 , total integrated cost =  121328.370460204
# Improved over  50  iterations in  3.6710293130017817  seconds by  61.71784716762639  percent.
# sparsity weight =  28000.0

# %%
c_var = [0,1]

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    k = 0
    
    while not conv[i]:
        max_it = int(100 + 100*k)

        weight_ = ( cost_uncontrolled[i] - costnode_[i][0][0][0] ) / sum( costnode_[i][2][0][:] )
            
        dur = d_array[0]
        aln.params.duration = dur
        cost.setParams(1., weight_ * factor_we, weight_ * factor_ws)
        weights_[i] = cost.getParams()

        setinit(initVars[i], aln)

        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        control0 = aln.getZeroControl()
        control0 = bestControl_[i][:,:,n_pre-1:-n_post+1]

        bestControl_[i], bestState_[i], cost_[i], runtime_, grad_, phi_, phi1_, costnode_[i] = aln.A1(
            control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
            prec_variables_ = p_var, transition_time_ = t_pen[0])
        
        if cost_[i][2] == 0.:
            conv[i] = True

        with open(file_,'wb') as f:
            pickle.dump([bestControl_, bestState_, cost_, costnode_, weights_], f)
        
        k += 1
# Out:
# -------  20 0.4500000000000001 0.4750000000000002
# set cost params:  1.0 0.0 73393.55464467472
# interpolate adjoint :  True True True
# initial cost =  316931.9421284
# RUN  0 , total integrated cost =  316931.9421284
# Gradient descend method:  None
# RUN  1 , total integrated cost =  315476.72101449233
# RUN  2 , total integrated cost =  314856.9138581915
# RUN  3 , total integrated cost =  314249.4286491881
# RUN  4 , total integrated cost =  313806.04555383313
# RUN  5 , total integrated cost =  313343.16270926
# RUN  6 , total integrated cost =  312958.87321439956
# RUN  7 , total integrated cost =  312563.836495235
# RUN  8 , total integrated cost =  312222.9580005848
# RUN  9 , total integrated cost =  311861.47728825547
# RUN  10 , total integrated cost =  311543.42341583077
# RUN  11 , total integrated cost =  311201.39476459636
# RUN  12 , total integrated cost =  310891.60216654715
# RUN  13 , total integrated cost =  310562.64887363475
# RUN  14 , total integrated cost =  310275.2814349125
# RUN  15 , total integrated cost =  309954.3436843289
# RUN  16 , total integrated cost =  309669.1694326353
# RUN  17 , total integrated cost =  309354.92830745055
# RUN  18 , total integrated cost =  309056.7323798504
# RUN  19 , total integrated cost =  308717.11905862094
# RUN  20 , total integrated cost =  308407.1265247045
# RUN  30 , total integrated cost =  303808.00341345946
# RUN  40 , total integrated cost =  299795.6977396728
# RUN  50 , total integrated cost =  296924.9997855475
# RUN  60 , total integrated cost =  290834.647676914
# RUN  70 , total integrated cost =  288631.3581558353
# RUN  80 , total integrated cost =  287731.212427931
# RUN  90 , total integrated cost =  286351.98495183856
# RUN  100 , total integrated cost =  286098.1925536274
# RUN  100 , total integrated cost =  286098.1925536274
# Improved over  100  iterations in  7.378691177000292  seconds by  9.728823597805984  percent.
# set cost params:  1.0 0.0 81332.84797761908
# interpolate adjoint :  True True True
# initial cost =  316931.9421284
# RUN  0 , total integrated cost =  316931.9421284
# Gradient descend method:  None
# RUN  1 , total integrated cost =  316918.59146488894
# RUN  2 , total integrated cost =  316907.67093633173
# RUN  3 , total integrated cost =  316891.90358126507
# RUN  4 , total integrated cost =  316879.17794757674
# RUN  5 , total integrated cost =  316860.13184448244
# RUN  6 , total integrated cost =  316842.5975238047
# RUN  7 , total integrated cost =  316817.2181623181
# RUN  8 , total integrated cost =  316794.5103334355
# RUN  9 , total integrated cost =  316737.35103407013
# RUN  10 , total integrated cost =  316683.25903459726
# RUN  11 , total integrated cost =  315706.9276929023
# RUN  12 , total integrated cost =  315345.7630467027
# RUN  13 , total integrated cost =  315339.00190606253
# RUN  14 , total integrated cost =  315330.52068815986
# RUN  15 , total integrated cost =  315323.9435223863
# RUN  16 , total integrated cost =  315315.61739713285
# RUN  17 , total integrated cost =  315309.01304174407
# RUN  18 , total integrated cost =  315299.76067194674
# RUN  19 , total integrated cost =  315291.294844509
# RUN  20 , total integrated cost =  315275.0143419877
# RUN  30 , total integrated cost =  312898.41333058197
# RUN  40 , total integrated cost =  312309.7773668457
# RUN  50 , total integrated cost =  311994.92242504214
# RUN  60 , total integrated cost =  311721.03715200734
# RUN  70 , total integrated cost =  310870.21771389345
# RUN  80 , total integrated cost =  310829.9574531073
# RUN  90 , total integrated cost =  310421.4327165193
# RUN  100 , total integrated cost =  309379.4096477598
# RUN  110 , total integrated cost =  309316.14894409134
# RUN  120 , total integrated cost =  309256.4198191209
# RUN  130 , total integrated cost =  308830.14992865117
# RUN  140 , total integrated cost =  308797.8441477515
# RUN  150 , total integrated cost =  308575.4620364773
# RUN  160 , total integrated cost =  308407.04219995136
# RUN  170 , total integrated cost =  308225.1338559755
# RUN  180 , total integrated cost =  307566.7093828937
# RUN  190 , total integrated cost =  307529.4630320268
# RUN  200 , total integrated cost =  307515.61066973844
# RUN  200 , total integrated cost =  307515.61066973844
# Improved over  200  iterations in  12.91462070500711  seconds by  2.971089438137696  percent.
# set cost params:  1.0 0.0 83825.84638066121
# interpolate adjoint :  True True True
# initial cost =  316931.9421284
# RUN  0 , total integrated cost =  316931.9421284
# Gradient descend method:  None
# RUN  1 , total integrated cost =  316931.29994658503
# RUN  2 , total integrated cost =  316930.9645285821
# RUN  3 , total integrated cost =  316929.90216553386
# RUN  4 , total integrated cost =  316928.98593664565
# RUN  5 , total integrated cost =  316926.1860078567
# RUN  6 , total integrated cost =  316923.9176755845
# RUN  7 , total integrated cost =  316908.9089249912
# RUN  8 , total integrated cost =  316894.61651486665
# RUN  9 , total integrated cost =  316894.206980311
# RUN  10 , total integrated cost =  316893.6501617764
# RUN  11 , total integrated cost =  316893.362506782
# RUN  12 , total integrated cost =  316892.8424169248
# RUN  13 , total integrated cost =  316892.5268654845
# RUN  14 , total integrated cost =  316891.5257811079
# RUN  15 , total integrated cost =  316890.7029823507
# RUN  16 , total integrated cost =  316881.74234082474
# RUN  17 , total integrated cost =  316874.7961506406
# RUN  18 , total integrated cost =  316873.77689442027
# RUN  19 , total integrated cost =  316872.56863560196
# RUN  20 , total integrated cost =  316872.21102229314
# RUN  30 , total integrated cost =  316844.69366402685
# RUN  40 , total integrated cost =  316807.8304181284
# RUN  50 , total integrated cost =  316753.62271556107
# RUN  60 , total integrated cost =  316125.1311949253
# RUN  70 , total integrated cost =  316111.3434096273
# RUN  80 , total integrated cost =  316105.7276692046
# RUN  90 , total integrated cost =  316080.85932852945
# RUN  100 , total integrated cost =  316069.6469113315
# RUN  110 , total integrated cost =  316040.06680737995
# RUN  120 , total integrated cost =  316032.882184878
# RUN  130 , total integrated cost =  316025.8345852084
# RUN  140 , total integrated cost =  315773.54251445015
# RUN  150 , total integrated cost =  315740.3479053449
# RUN  160 , total integrated cost =  315564.61733788345
# RUN  170 , total integrated cost =  315554.76311475696
# RUN  180 , total integrated cost =  315551.94166851445
# RUN  190 , total integrated cost =  315548.80056377995
# RUN  200 , total integrated cost =  315542.93014312914
# RUN  300 , total integrated cost =  314795.46473275364
# RUN  300 , total integrated cost =  314795.46473275364
# Improved over  300  iterations in  19.82443360600155  seconds by  0.6741123603063102  percent.
# set cost params:  1.0 0.0 84395.03222412255
# interpolate adjoint :  True True True
# initial cost =  316931.9421284
# RUN  0 , total integrated cost =  316931.9421284
# Gradient descend method:  None
# RUN  1 , total integrated cost =  316931.8611459769
# RUN  2 , total integrated cost =  316931.8085190864
# RUN  3 , total integrated cost =  316931.6132201226
# RUN  4 , total integrated cost =  316931.351912269
# RUN  5 , total integrated cost =  316931.3312007137
# RUN  6 , total integrated cost =  316931.2799644452
# RUN  7 , total integrated cost =  316931.26076470746
# RUN  8 , total integrated cost =  316930.495800952
# RUN  9 , total integrated cost =  316929.8476198876
# RUN  10 , total integrated cost =  316929.8315893483
# RUN  11 , total integrated cost =  316929.77108077216
# RUN  12 , total integrated cost =  316929.74528013775
# RUN  13 , total integrated cost =  316929.53787352244
# RUN  14 , total integrated cost =  316929.27479168156
# RUN  15 , total integrated cost =  316929.25320546376
# RUN  16 , total integrated cost =  316929.19932321087
# RUN  17 , total integrated cost =  316929.18163644965
# RUN  18 , total integrated cost =  316909.50427151145
# RUN  19 , total integrated cost =  316897.8715272654
# RUN  20 , total integrated cost =  316897.8595698435
# RUN  30 , total integrated cost =  316896.1042615862
# RUN  40 , total integrated cost =  316893.4004736992
# RUN  50 , total integrated cost =  316890.09463140153
# RUN  60 , total integrated cost =  316776.4278207809
# RUN  70 , total integrated cost =  316775.3907894935
# RUN  80 , total integrated cost =  316718.88496531814
# RUN  90 , total integrated cost =  316704.2435082577
# RUN  100 , total integrated cost =  316703.4173947209
# RUN  110 , total integrated cost =  316700.4814103042
# RUN  120 , total integrated cost =  316700.03102196817
# RUN  130 , total integrated cost =  316699.025967727
# RUN  140 , total integrated cost =  316697.963327069
# RUN  150 , total integrated cost =  316696.7975520345
# RUN  160 , total integrated cost =  316695.68732517166
# RUN  170 , total integrated cost =  316695.42781139683
# RUN  180 , total integrated cost =  316690.3701248851
# RUN  190 , total integrated cost =  316667.37605235504
# RUN  200 , total integrated cost =  316464.20134900644
# RUN  300 , total integrated cost =  316434.7196639276
# RUN  400 , total integrated cost =  316355.2331911485
# RUN  400 , total integrated cost =  316355.2331911485
# Improved over  400  iterations in  27.26607034599874  seconds by  0.18196617651680924  percent.
# set cost params:  1.0 0.0 84548.93254968285
# interpolate adjoint :  True True True
# initial cost =  316931.9421284
# RUN  0 , total integrated cost =  316931.9421284
# Gradient descend method:  None
# RUN  1 , total integrated cost =  316930.3330158816
# RUN  2 , total integrated cost =  316929.0807150316
# RUN  3 , total integrated cost =  316929.0736916567
# RUN  4 , total integrated cost =  316928.3503690382
# RUN  5 , total integrated cost =  316927.4617168917
# RUN  6 , total integrated cost =  316927.45214680594
# RUN  7 , total integrated cost =  316927.416575201
# RUN  8 , total integrated cost =  316927.40470003296
# RUN  9 , total integrated cost =  316927.3787805119
# RUN  10 , total integrated cost =  316927.3259655442
# RUN  11 , total integrated cost =  316927.3187351735
# RUN  12 , total integrated cost =  316926.04636827955
# RUN  13 , total integrated cost =  316924.81579236296
# RUN  14 , total integrated cost =  316924.8064331421
# RUN  15 , total integrated cost =  316924.77757046645
# RUN  16 , total integrated cost =  316924.7687947318
# RUN  17 , total integrated cost =  316924.1126982285
# RUN  18 , total integrated cost =  316923.39158446656
# RUN  19 , total integrated cost =  316923.38580593374
# RUN  20 , total integrated cost =  316923.3556756354
# RUN  30 , total integrated cost =  316919.05684742116
# RUN  40 , total integrated cost =  316894.23616639286
# RUN  50 , total integrated cost =  316893.0127956293
# RUN  60 , total integrated cost =  316890.60930715717
# RUN  70 , total integrated cost =  316890.48903645494
# RUN  80 , total integrated cost =  316890.398008587
# RUN  90 , total integrated cost =  316888.8953406027
# RUN  100 , total integrated cost =  316771.44109766354
# RUN  110 , total integrated cost =  316763.02495837084
# RUN  120 , total integrated cost =  316762.2462049843
# RUN  130 , total integrated cost =  316760.62215005973
# RUN  140 , total integrated cost =  316744.73644060537
# RUN  150 , total integrated cost =  316744.67013672437
# RUN  160 , total integrated cost =  316744.60883725865
# RUN  170 , total integrated cost =  316744.51706387906
# RUN  180 , total integrated cost =  316744.42588784936
# RUN  190 , total integrated cost =  316743.76563537715
# RUN  200 , total integrated cost =  316740.9828279631
# RUN  300 , total integrated cost =  316728.21337688976
# RUN  400 , total integrated cost =  316709.66856824746
# RUN  500 , total integrated cost =  316612.9555829584
# RUN  500 , total integrated cost =  316612.9555829584
# Improved over  500  iterations in  33.38251268299064  seconds by  0.10064827902780848  percent.
# set cost params:  1.0 0.0 84634.13623506356
# interpolate adjoint :  True True True
# initial cost =  316931.9421284
# RUN  0 , total integrated cost =  316931.9421284
# Gradient descend method:  None
# RUN  1 , total integrated cost =  316931.94111930154
# RUN  2 , total integrated cost =  316931.93523811223
# RUN  3 , total integrated cost =  316931.9176215504
# RUN  4 , total integrated cost =  316931.9158856046
# RUN  5 , total integrated cost =  316931.91404530307
# RUN  6 , total integrated cost =  316931.897876615
# RUN  7 , total integrated cost =  316931.89194428915
# RUN  8 , total integrated cost =  316931.89104266104
# RUN  9 , total integrated cost =  316931.86095933255
# RUN  10 , total integrated cost =  316931.81628102687
# RUN  11 , total integrated cost =  316931.814883166
# RUN  12 , total integrated cost =  316931.81041424256
# RUN  13 , total integrated cost =  316931.7963578619
# RUN  14 , total integrated cost =  316931.7937921678
# RUN  15 , total integrated cost =  316931.79203312035
# RUN  16 , total integrated cost =  316931.7741616096
# RUN  17 , total integrated cost =  316931.7644582107
# RUN  18 , total integrated cost =  316931.7626415602
# RUN  19 , total integrated cost =  316931.74205364974
# RUN  20 , total integrated cost =  316931.73179949936
# RUN  30 , total integrated cost =  316931.3985093745
# RUN  40 , total integrated cost =  316931.3155469297
# RUN  50 , total integrated cost =  316931.188876587
# RUN  60 , total integrated cost =  316931.05769075797
# RUN  70 , total integrated cost =  316923.691845529
# RUN  80 , total integrated cost =  316923.6067527972
# RUN  90 , total integrated cost =  316923.5684501233
# RUN  100 , total integrated cost =  316923.37725017255
# RUN  110 , total integrated cost =  316923.34218823985
# RUN  120 , total integrated cost =  316923.27965451695
# RUN  130 , total integrated cost =  316923.24491041864
# RUN  140 , total integrated cost =  316923.0894301106
# RUN  150 , total integrated cost =  316897.4395057224
# RUN  160 , total integrated cost =  316897.2799860197
# RUN  170 , total integrated cost =  316896.5112314895
# RUN  180 , total integrated cost =  316896.39563417813
# RUN  190 , total integrated cost =  316887.5058304569
# RUN  200 , total integrated cost =  316886.7985347593
# RUN  300 , total integrated cost =  316825.65377688175
# RUN  400 , total integrated cost =  316824.2735431192
# RUN  500 , total integrated cost =  316814.8238133744
# RUN  600 , total integrated cost =  316788.892833778
# RUN  600 , total integrated cost =  316788.892833778
# Improved over  600  iterations in  39.55099262698786  seconds by  0.04513565078400461  percent.
# set cost params:  1.0 0.0 84672.36157680083
# interpolate adjoint :  True True True
# initial cost =  316931.9421284
# RUN  0 , total integrated cost =  316931.9421284
# Gradient descend method:  None
# RUN  1 , total integrated cost =  316931.9415284998
# RUN  2 , total integrated cost =  316931.92395920673
# RUN  3 , total integrated cost =  316931.917405227
# RUN  4 , total integrated cost =  316931.91728277196
# RUN  5 , total integrated cost =  316931.91723839525
# RUN  6 , total integrated cost =  316931.9171985084
# RUN  7 , total integrated cost =  316931.91710341553
# RUN  8 , total integrated cost =  316931.91483465495
# RUN  9 , total integrated cost =  316931.90313456784
# RUN  10 , total integrated cost =  316931.9023013867
# RUN  11 , total integrated cost =  316931.90222997364
# RUN  12 , total integrated cost =  316931.90218876774
# RUN  13 , total integrated cost =  316931.90175739053
# RUN  14 , total integrated cost =  316931.84193540824
# RUN  15 , total integrated cost =  316931.80271322746
# RUN  16 , total integrated cost =  316931.80224701785
# RUN  17 , total integrated cost =  316931.80212398054
# RUN  18 , total integrated cost =  316931.80187922594
# RUN  19 , total integrated cost =  316931.7480497502
# RUN  20 , total integrated cost =  316931.67379930906
# RUN  30 , total integrated cost =  316930.8351007975
# RUN  40 , total integrated cost =  316930.8102637595
# RUN  50 , total integrated cost =  316930.7626635136
# RUN  60 , total integrated cost =  316915.8638550166
# RUN  70 , total integrated cost =  316915.7029734014
# RUN  80 , total integrated cost =  316914.72591664986
# RUN  90 , total integrated cost =  316912.68552879815
# RUN  100 , total integrated cost =  316912.3791334634
# RUN  110 , total integrated cost =  316912.3422606667
# RUN  120 , total integrated cost =  316912.2680291177
# RUN  130 , total integrated cost =  316912.14098159416
# RUN  140 , total integrated cost =  316912.0814498736
# RUN  150 , total integrated cost =  316911.7030273899
# RUN  160 , total integrated cost =  316911.676028295
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_168524/3922556324.py in <module>
#      25         control0 = bestControl_[i][:,:,n_pre-1:-n_post+1]
#      26
# ---> 27         bestControl_[i], bestState_[i], cost_[i], runtime_, grad_, phi_, phi1_, costnode_[i] = aln.A1(
#      28             control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
#      29             startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
#
# ~/Promotion/neurolib/neurolib/models/model.py in A1(self, control_, target_state_, c_scheme_, u_mat_, u_scheme_, max_iteration_, tolerance_, startStep_, max_control_, min_control_, t_sim_, t_sim_pre_, t_sim_post_, CGVar, line_search_, control_variables_, prec_variables_, separate_comp, transition_time_, noise_real, init_params)
#     661             if self.params.N == 1:
#     662                 if noise_real == 0:
# --> 663                     return opti1_rate_control.A1(self, control_, target_state_, c_scheme_, u_mat_, u_scheme_, max_iteration_,
#     664                                                 tolerance_, startStep_, max_control_, min_control_, t_sim_, t_sim_pre_, t_sim_post_, CGVar,
#     665                                                 line_search_, control_variables_, prec_variables_, separate_comp, transition_time_)
#
# ~/Promotion/neurolib/neurolib/utils/A1_aln_rate_control.py in A1(model, control_, target_state, c_scheme_, u_mat_, u_scheme_, max_iteration_, tolerance_, startStep_, cntrl_max_, cntrl_min_, t_sim_, t_sim_pre_, t_sim_post_, CGVar, line_search_, control_variables_, prec_variables_, separate_comp, transition_time_)
#     258
#     259         for ind_time in range(T):
# --> 260             f_p_grad_t_ = cost.cost_precision_gradient_t(N, V_target, state0_[:,:2,ind_time], target_state_[:,:,ind_time], ip_, transition_time_)
#     261             for v in prec_variables:
#     262                 full_cost_grad[0,v,ind_time] = f_p_grad_t_[0,v]
#
# ~/Promotion/neurolib/neurolib/utils/costFunctions.py in cost_precision_gradient_t(N, V_target, state_t_, target_state_t_, i_p, trans_time)
#      55 # time interval for transition can be set by defining respective target state to -1.
#      56 def cost_precision_gradient_t(N, V_target, state_t_, target_state_t_, i_p, trans_time):
# ---> 57     cost_gradient_ = numba_precision_gradient_t(N, V_target, i_p, state_t_, target_state_t_, trans_time)
#      58     return cost_gradient_
#      59
#
# KeyboardInterrupt:

# %%
#for i in i_range:
for i in i_range:
        
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    aln.params.duration = dur
    max_it = int(0)
    
    for l in range( bestControl_[i].shape[2] ):
        if np.abs(bestControl_[i][0,0,l]) > 5. * 1e-6 or np.abs(bestControl_[i][0,1,l]) > 5. * 1e-6:
            init_ind = l - n_pre
            break
            
    if init_ind == -1:
        init_ind = 0
            
    print("init ind = ", init_ind)

    weight_ = 1.
    cost.setParams(1., weight_ * factor_we, weight_ * factor_ws)
    weights_[i] = cost.getParams()

    setinit(initVars[i], aln)

    target_ = aln.getZeroTarget()
    target_[:,0,:] = target[i][0]
    target_[:,1,:] = target[i][1]

    control0 = aln.getZeroControl()
    if init_ind != 0:
        control0[:,:,:-init_ind] = bestControl_[i][:,:,n_pre-1+init_ind:-n_post+1]
    else:
        control0 = bestControl_[i][:,:,n_pre-1:-n_post+1]

    bestControl_[i], bestState_[i], cost_[i], runtime_, grad_, phi_, phi1_, costnode_[i] = aln.A1(
        control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
        prec_variables_ = p_var, transition_time_ = t_pen[0])

# %%
conv_shift = [None] * len(exc)

for i in i_range:
    print("------- ", i, exc[i], inh[i])
        
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    aln.params.duration = dur
    max_it = int(1000)
    k = 0
    
    while not conv_shift[i]:
            
        weight_ = 1.
        cost.setParams(1., weight_ * factor_we, weight_ * factor_ws)
        weights_[i] = cost.getParams()

        setinit(initVars[i], aln)

        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        control0 = aln.getZeroControl()
        control0 = bestControl_[i][:,:,n_pre-1:-n_post+1]

        bestControl_[i], bestState_[i], cost_[i], runtime_, grad_, phi_, phi1_, costnode_[i]= aln.A1(
            control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
            prec_variables_ = p_var, transition_time_ = t_pen[0])
                
        if cost_[i][-1] == 0.:
            conv_shift[i] = True

        with open(file_,'wb') as f:
            pickle.dump([bestControl_, bestState_, cost_, costnode_, weights_], f)
        
        k += 1

# %%
print(datetime.datetime.now())
