# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import sys
import pickle

path = os.getcwd().split(os.sep + 'GUI')[0]
if path not in sys.path:
    print("not here")
    sys.path.append(path)

from neurolib.models.aln import ALNModel
from neurolib.utils import plotFunctions as plotFunc
from neurolib.utils import costFunctions as cost
import neurolib.dashboard.functions as functions
import neurolib.dashboard.data as data
    
# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2 

#path = os.path.join(os.getcwd(), "plots")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
grid_data_file = os.path.join(os.getcwd().split('data')[0], 'bi.pickle')
with open(grid_data_file,'rb') as f:
    load_array= pickle.load(f)
exc = load_array[0]
inh = load_array[1]

folder = str(os.getcwd().split('data_2')[1])
print(folder)
case = str(folder[1])

file_ = '1_down.pickle'

c_var = [0,1]
if len(folder) == 4:
    if folder[3] == 'e':
        p_var = [0]
    elif folder[3] == 'i':
        p_var = [1]
else:
    p_var = [0,1]
    
print(p_var)
# Out:
# /1_i
# [1]

# %% [markdown]
# ### Bistability

# %%
aln = ALNModel()
N = aln.params.N

data.set_parameters(aln)

state_vars = aln.state_vars
init_vars = aln.init_vars

##############################################################
def setinit(init_vars_, model):
    state_vars = model.state_vars
    init_vars = model.init_vars
    for iv in range(len(init_vars)):
        for sv in range(len(state_vars)):
            if state_vars[sv] in init_vars[iv]:
                #print("set init vars ", )
                if model.params[init_vars[iv]].ndim == 2:
                    model.params[init_vars[iv]][0,:] = init_vars_[sv]
                else:
                    model.params[init_vars[iv]][0] = init_vars_[sv]
                    
##############################################################               
def setmaxmincontrol(max_c_c, min_c_c, max_c_r, min_c_r):
    import numpy as np
    
    max_cntrl = np.zeros(( 6 ))
    min_cntrl = np.zeros(( 6 ))
    
    max_cntrl[0] = max_c_c
    min_cntrl[0] = min_c_c
    max_cntrl[1] = max_c_c
    min_cntrl[1] = min_c_c
    max_cntrl[2] = max_c_r
    min_cntrl[2] = min_c_r
    max_cntrl[3] = max_c_r
    min_cntrl[3] = min_c_r
    max_cntrl[4] = max_c_r
    min_cntrl[4] = min_c_r
    max_cntrl[5] = max_c_r
    min_cntrl[5] = min_c_r
            
    return max_cntrl, min_cntrl

# %%
d_array = np.arange(500., 20, -0.1)
t0_array = d_array - 20.
t_pen = np.zeros(( t0_array.shape ))
for i in range(len(t_pen)):
    t_pen[i] = t0_array[i] / d_array[i]

# %%
dur_pre = 10
dur_post = 10

n_pre = int(np.around(dur_pre/aln.params.dt + 1.,1))
n_post = int(np.around(dur_post/aln.params.dt + 1.,1))

tol = 1e-12
start_step = 10.
c_scheme = np.zeros(( 1,1 ))
c_scheme[0,0] = 1.
u_mat = np.identity(1)
u_scheme = np.array([[1.]])

if case in ['1', '2']:    # low to high
    max_I = [3., -3.]
else:
    max_I = [-3., 3.]
    
if case in ['1', '3']:    # sparsity
    factor_ws = 1.
    factor_we = 0.
else:
    factor_ws = 0.
    factor_we = 1.
    
maxC = [1000., -1000., 0.18, 0.]
max_cntrl, min_cntrl = setmaxmincontrol(maxC[0], maxC[1], maxC[2], maxC[3])

# %%
bestControl_ = np.array( [[None] * len(t_pen)] * len(exc) )
bestState_ = np.array( [[None] * len(t_pen)] * len(exc) )
cost_ = np.array( [[None] * len(t_pen)] * len(exc) )
costnode_ = np.array( [[None] * len(t_pen)] * len(exc) )
weights_ = np.array( [[None] * len(t_pen)] * len(exc) )
convergence_ = np.array( [[None] * len(t_pen)] * len(exc) )

initVars = [None] * len(exc)
target = [None] * len(exc)
cost_uncontrolled = [None] * len(exc)

print(bestControl_.shape)
# Out:
# (147, 4800)

# %%
if os.path.isfile(file_) :
    print("file found")
    
    with open(file_,'rb') as f:
        load_array = pickle.load(f)

    bestControl_ = load_array[0]
    bestState_ = load_array[1]
    cost_ = load_array[2]
    costnode_ = load_array[3]
    weights_ = load_array[4]

# %%
# get initial parameters and target states

i_range = [20,50]
data.set_parameters(aln)

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    aln.params.duration = 3000.
    
    control0 = aln.getZeroControl()
    control0 = functions.step_control(aln, maxI_ = max_I[0])

    aln.run(control=control0)
    
    target_rates = np.zeros((2))
    target_rates[0] = aln.rates_exc[0,-1] 
    target_rates[1] = aln.rates_inh[0,-1]

    control0 = functions.step_control(aln, maxI_ = max_I[1])
    aln.run(control=control0)

    init_state_vars = np.zeros(( len(state_vars) ))
    for j in range(len(state_vars)):
        if aln.state[state_vars[j]].size == 1:
            init_state_vars[j] = aln.state[state_vars[j]][0]
        else:
            init_state_vars[j] = aln.state[state_vars[j]][0,-1]

    initVars[i] = init_state_vars
    target[i] = [target_rates[0], target_rates[1]]

# %%
# get uncontrolled cost

data.set_parameters(aln)

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    dur = d_array[0]
    aln.params.duration = dur
    
    target_ = aln.getZeroTarget()
    target_[:,0,:] = target[i][0]
    target_[:,1,:] = target[i][1]
            
    cost.setParams(1.0, 0.0, 0.0)

    setinit(initVars[i], aln)
    control0 = aln.getZeroControl()

    # "HS", "FR", "PR", "HZ"
    cgv = None
    max_it = 0

    bestControl_init_, bestState_init_, cost_init_, runtime_init_, grad_init_, phi_init_, phi1_, costnode_init_ = aln.A1(
        control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
        prec_variables_ = p_var, transition_time_ = t_pen[0])
    
    cost_uncontrolled[i] = cost_init_[0]
# Out:
# -------  20 0.4500000000000001 0.4750000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1151956.8752274683
# RUN  0 , total integrated cost =  1151956.8752274683
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1151956.8752274683
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  50 0.47500000000000014 0.6000000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1078580.8097708924
# RUN  0 , total integrated cost =  1078580.8097708924
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1078580.8097708924
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.

# %%
for i in i_range:
    if i == 20:
        readfile_ = os.path.join(os.getcwd().split(folder)[0], '1', '1_I.pickle')
    elif i == 50:
        readfile_ = os.path.join(os.getcwd().split(folder)[0], '1', '1_E.pickle')
    else:
        continue
    print(readfile_)
        
    if os.path.isfile(readfile_) :
        print("file found")

        with open(readfile_,'rb') as f:
            load_array = pickle.load(f)

        bestControl_[i] = load_array[0][i]
        bestState_[i] = load_array[1][i]
        cost_[i] = load_array[2][i]
        costnode_[i] = load_array[3][i]
        weights_[i] = load_array[4][i]
        
print(bestControl_[20][0].shape)
print(bestControl_[20][0][0,1,::200])
# Out:
# /home/lena/Promotion/neurolib/GUI/current/gui/data_2/1/1_I.pickle
# file found
# /home/lena/Promotion/neurolib/GUI/current/gui/data_2/1/1_E.pickle
# file found
# (1, 6, 5201)
# [ 0.00000000e+00 -1.28307270e-05 -3.29760263e-05 -8.47555755e-05
#  -2.17869833e-04 -5.60244185e-04 -1.44194189e-03 -3.71986536e-03
#  -9.65478956e-03 -2.54961550e-02 -7.08394617e-02 -2.37530209e-01
#  -8.32520073e-01 -1.67527975e-02 -2.51885128e-03 -2.05495971e-03
#  -7.18241612e-05 -5.71215230e-10 -9.24131005e-11 -1.50087058e-11
#  -2.31719987e-12 -4.05963963e-13 -2.05316895e-12 -1.93948604e-10
#  -2.07915779e-08 -7.83764837e-09  0.00000000e+00]

# %%
for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    j = 0
    step = 10

    while j < 4799:

        if j == 0:
            j += step
            continue
            
        if not convergence_[i][j-step]:
            if j - step > 0:
                j -= step
                print('go back to -----', j)

        print('-----', j)

        if convergence_[i][j]:
            j += step
            continue

        dur = d_array[j]
        T = 5001 - j
        aln.params.duration = dur

        cost.setParams(1., 0., 1.)
        weights_[i][j] = cost.getParams()

        setinit(initVars[i], aln)

        max_it = 10000

        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        if type(bestControl_[i][j]) == type(None):
            max_percent_prev = (np.argmax(np.abs(bestControl_[i][j-step]), axis=2)[0,1] - 100) / (T-200)
            shift_ind = 0
            if j < 3000:
                while max_percent_prev > max_percent:
                    shift_ind += 1
                    max_percent_prev = (np.argmax(np.abs(bestControl_[i][j-step]), axis=2)[0,1] - 100 - shift_ind) / (T-200)

            control0 = np.zeros(( bestControl_[i][j-step][:,:,100:-(100+step)].shape ))
            print('shift ind = ', shift_ind)
            if shift_ind != 0:
                control0[:,:,:-shift_ind] = 1. * bestControl_[i][j-step][:,:,100+shift_ind:-(100+step)]
            else:
                control0[:,:,:] = 1. * bestControl_[i][j-step][:,:,100:-(100+step)]
                #control0[0,0,:] = 0.
        else:
            if bestControl_[i][j].shape[2] == T+200:
                control0 = bestControl_[i][j][:,:,100:-100]
                #control0[0,1,:] = 0.
            else:
                control0 = bestControl_[i][j][:,:,100:-(100+j)]

        bestControl_[i][j], bestState_[i][j], cost_[i][j], runtime_, grad_, phi_, phi1_, costnode_[i][j] = aln.A1(
            control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
            prec_variables_ = p_var, transition_time_ = t_pen[j])
        
        time_ = np.arange(-dur_pre,round(dur+dur_post+aln.params.dt,1),aln.params.dt)
        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        print(costnode_[i][j][0][0][0], costnode_[i][j][2][0][:2])
        print(costnode_[i][0][0][0][0], costnode_[i][0][2][0][:2])

        if cost_[i][j][-1] == 0.:
            convergence_[i][j] = True

        with open(file_,'wb') as f:
            pickle.dump([bestControl_, bestState_, cost_, costnode_, weights_], f)

        j += step
# Out:
# -------  20 0.4500000000000001 0.4750000000000002
# ----- 10
# set cost params:  1.0 0.0 1.0
# 1
# interpolate adjoint :  True True True
# initial cost =  3.3311692645563546
# RUN  0 , total integrated cost =  3.3311692645563546
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.331169263305466
# RUN  2 , total integrated cost =  3.331169263296465
# RUN  3 , total integrated cost =  3.331169263260024
# RUN  4 , total integrated cost =  3.331169263227607
# RUN  5 , total integrated cost =  3.3311692631142233
# RUN  6 , total integrated cost =  3.331169263011767
# RUN  7 , total integrated cost =  3.331169262865751
# RUN  8 , total integrated cost =  3.331169262700098
# RUN  9 , total integrated cost =  3.33116926268942
# RUN  10 , total integrated cost =  3.3311692626743894
# RUN  11 , total integrated cost =  3.3311692626674256
# RUN  12 , total integrated cost =  3.3311692626547287
# RUN  13 , total integrated cost =  3.3311692626461116
# RUN  14 , total integrated cost =  3.331169262611019
# RUN  15 , total integrated cost =  3.33116926257933
# RUN  16 , total integrated cost =  3.331169262383555
# RUN  17 , total integrated cost =  3.331169262220799
# RUN  18 , total integrated cost =  3.3311692619694178
# RUN  19 , total integrated cost =  3.331169261735105
# RUN  20 , total integrated cost =  3.3311692617254316
# RUN  30 , total integrated cost =  3.331169260529552
# RUN  40 , total integrated cost =  3.3311692580662484
# RUN  50 , total integrated cost =  3.3311692570363105
# RUN  60 , total integrated cost =  3.3311692537500224
# RUN  70 , total integrated cost =  3.331169250812951
# RUN  80 , total integrated cost =  3.3311692501400105
# RUN  90 , total integrated cost =  3.331169249957469
# RUN  100 , total integrated cost =  3.331169249273555
# RUN  110 , total integrated cost =  3.3311692492078886
# RUN  120 , total integrated cost =  3.3311692490582017
# RUN  130 , total integrated cost =  3.3311692485466615
# RUN  140 , total integrated cost =  3.3311692484541333
# RUN  150 , total integrated cost =  3.331169248223858
# RUN  160 , total integrated cost =  3.3311692455410813
# RUN  170 , total integrated cost =  3.3311692439153653
# RUN  180 , total integrated cost =  3.331169243882457
# RUN  190 , total integrated cost =  3.3311692313132277
# RUN  200 , total integrated cost =  3.331169231310564
# RUN  300 , total integrated cost =  3.3311692310253607
# RUN  400 , total integrated cost =  3.3311692290487223
# RUN  500 , total integrated cost =  3.3311692289719845
# RUN  600 , total integrated cost =  3.331169228643222
# Control only changes marginally.
# RUN  681 , total integrated cost =  3.3311692080349045
# Improved over  681  iterations in  183.1188637120067  seconds by  1.69674507333184e-06  percent.
# 0.0 [1.62407450e-16 3.33116921e+00]
# 0.0 [3.88250122e-18 3.33116925e+00]
# ----- 20
# set cost params:  1.0 0.0 1.0
# 1
# interpolate adjoint :  True True True
# initial cost =  3.3311692693405797
# RUN  0 , total integrated cost =  3.3311692693405797
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.331169268685324
# RUN  2 , total integrated cost =  3.331169268671226
# RUN  3 , total integrated cost =  3.3311692686515326
# RUN  4 , total integrated cost =  3.3311692686413963
# RUN  5 , total integrated cost =  3.3311692686218004
# RUN  6 , total integrated cost =  3.3311692686061236
# RUN  7 , total integrated cost =  3.331169268547731
# RUN  8 , total integrated cost =  3.3311692684958647
# RUN  9 , total integrated cost =  3.3311692671967945
# RUN  10 , total integrated cost =  3.331169266229925
# RUN  11 , total integrated cost =  3.331169266218536
# RUN  12 , total integrated cost =  3.331169266202931
# RUN  13 , total integrated cost =  3.3311692661939576
# RUN  14 , total integrated cost =  3.331169266176077
# RUN  15 , total integrated cost =  3.331169266164185
# RUN  16 , total integrated cost =  3.3311692661276675
# RUN  17 , total integrated cost =  3.331169266095448
# RUN  18 , total integrated cost =  3.33116926591452
# RUN  19 , total integrated cost =  3.3311692657495544
# RUN  20 , total integrated cost =  3.331169265734109
# RUN  30 , total integrated cost =  3.331169264022143
# RUN  40 , total integrated cost =  3.331169263676252
# RUN  50 , total integrated cost =  3.331169263327627
# RUN  60 , total integrated cost =  3.3311692427907755
# RUN  70 , total integrated cost =  3.3311692427526096
# RUN  80 , total integrated cost =  3.331169242670476
# RUN  90 , total integrated cost =  3.331169242646578
# RUN  100 , total integrated cost =  3.3311692419286376
# RUN  110 , total integrated cost =  3.3311692418927987
# RUN  120 , total integrated cost =  3.331169241696855
# RUN  130 , total integrated cost =  3.3311692416658834
# RUN  140 , total integrated cost =  3.331169241599092
# RUN  150 , total integrated cost =  3.3311692388283194
# RUN  160 , total integrated cost =  3.33116923881305
# RUN  170 , total integrated cost =  3.3311692383257947
# RUN  180 , total integrated cost =  3.3311692382712907
# RUN  190 , total integrated cost =  3.331169238197996
# RUN  200 , total integrated cost =  3.3311692381753746
# Control only changes marginally.
# RUN  222 , total integrated cost =  3.3311692242416675
# Improved over  222  iterations in  64.73448355699657  seconds by  1.353846315055307e-06  percent.
# 0.0 [4.25374652e-16 3.33116922e+00]
# 0.0 [3.88250122e-18 3.33116925e+00]
# ----- 30
# set cost params:  1.0 0.0 1.0
# 1
# interpolate adjoint :  True True True
# initial cost =  3.3311692756039104
# RUN  0 , total integrated cost =  3.3311692756039104
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.331169275292114
# RUN  2 , total integrated cost =  3.3311692635188654
# RUN  3 , total integrated cost =  3.3311692559733985
# RUN  4 , total integrated cost =  3.3311692559614237
# RUN  5 , total integrated cost =  3.3311692530958896
# RUN  6 , total integrated cost =  3.3311692513188658
# RUN  7 , total integrated cost =  3.3311692502973
# RUN  8 , total integrated cost =  3.3311692493108866
# RUN  9 , total integrated cost =  3.3311692493070684
# RUN  10 , total integrated cost =  3.331169249305137
# RUN  11 , total integrated cost =  3.3311692492884335
# RUN  12 , total integrated cost =  3.331169249275488
# RUN  13 , total integrated cost =  3.331169249262038
# RUN  14 , total integrated cost =  3.3311692492458076
# RUN  15 , total integrated cost =  3.331169249242725
# RUN  16 , total integrated cost =  3.331169249237665
# RUN  17 , total integrated cost =  3.331169249236114
# RUN  18 , total integrated cost =  3.331169249231827
# RUN  19 , total integrated cost =  3.331169249229406
# RUN  20 , total integrated cost =  3.3311692490624707
# RUN  30 , total integrated cost =  3.331169248856675
# RUN  40 , total integrated cost =  3.331169244884906
# RUN  50 , total integrated cost =  3.331169244761807
# RUN  60 , total integrated cost =  3.3311692447341947
# RUN  70 , total integrated cost =  3.3311692446772914
# RUN  80 , total integrated cost =  3.331169242806878
# RUN  90 , total integrated cost =  3.3311692424733765
# RUN  100 , total integrated cost =  3.331169242413639
# RUN  110 , total integrated cost =  3.3311692419378947
# RUN  120 , total integrated cost =  3.331169241880695
# RUN  130 , total integrated cost =  3.3311692418412564
# RUN  140 , total integrated cost =  3.3311692418068084
# RUN  150 , total integrated cost =  3.3311692417868692
# RUN  160 , total integrated cost =  3.331169241769167
# RUN  170 , total integrated cost =  3.331169241750813
# RUN  180 , total integrated cost =  3.3311692401663167
# RUN  190 , total integrated cost =  3.3311692398086437
# RUN  200 , total integrated cost =  3.33116923979294
# Control only changes marginally.
# RUN  223 , total integrated cost =  3.3311692171133602
# Improved over  223  iterations in  47.19562732899794  seconds by  1.7558564309183566e-06  percent.
# 0.0 [1.85816688e-16 3.33116922e+00]
# 0.0 [3.88250122e-18 3.33116925e+00]
# ----- 40
# set cost params:  1.0 0.0 1.0
# 1
# interpolate adjoint :  True True True
# initial cost =  3.331169281399771
# RUN  0 , total integrated cost =  3.331169281399771
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.3311692812544673
# RUN  2 , total integrated cost =  3.331169281222612
# RUN  3 , total integrated cost =  3.3311692811813836
# RUN  4 , total integrated cost =  3.3311692811573796
# RUN  5 , total integrated cost =  3.331169281124248
# RUN  6 , total integrated cost =  3.3311692811060816
# RUN  7 , total integrated cost =  3.331169281079114
# RUN  8 , total integrated cost =  3.3311692810601463
# RUN  9 , total integrated cost =  3.3311692810215536
# RUN  10 , total integrated cost =  3.331169280988227
# RUN  11 , total integrated cost =  3.331169280831808
# RUN  12 , total integrated cost =  3.3311692806980813
# RUN  13 , total integrated cost =  3.331169280152497
# RUN  14 , total integrated cost =  3.3311692796788464
# RUN  15 , total integrated cost =  3.3311692796426375
# RUN  16 , total integrated cost =  3.3311692795988073
# RUN  17 , total integrated cost =  3.331169279580914
# RUN  18 , total integrated cost =  3.3311692795538312
# RUN  19 , total integrated cost =  3.3311692795375056
# RUN  20 , total integrated cost =  3.331169279508851
# RUN  30 , total integrated cost =  3.331169254736023
# RUN  40 , total integrated cost =  3.331169254088145
# RUN  50 , total integrated cost =  3.3311692522261724
# RUN  60 , total integrated cost =  3.3311692519889737
# RUN  70 , total integrated cost =  3.331169251562796
# RUN  80 , total integrated cost =  3.3311692513968367
# RUN  90 , total integrated cost =  3.3311692512798254
# RUN  100 , total integrated cost =  3.331169251058979
# RUN  110 , total integrated cost =  3.331169246868652
# RUN  120 , total integrated cost =  3.3311692467594245
# RUN  130 , total integrated cost =  3.331169246692215
# RUN  140 , total integrated cost =  3.3311692466173435
# RUN  150 , total integrated cost =  3.3311692464926086
# RUN  160 , total integrated cost =  3.3311692464386797
# RUN  170 , total integrated cost =  3.3311692464014486
# RUN  180 , total integrated cost =  3.3311692449142503
# RUN  190 , total integrated cost =  3.331169243826056
# RUN  200 , total integrated cost =  3.3311692437969014
# RUN  300 , total integrated cost =  3.3311692389133536
# RUN  400 , total integrated cost =  3.3311692308448126
# RUN  500 , total integrated cost =  3.3311692296560143
# RUN  600 , total integrated cost =  3.3311692290965644
# Control only changes marginally.
# RUN  668 , total integrated cost =  3.331169222327756
# Improved over  668  iterations in  146.9435248719965  seconds by  1.7733117232410223e-06  percent.
# 0.0 [1.22595848e-16 3.33116922e+00]
# 0.0 [3.88250122e-18 3.33116925e+00]
# ----- 50
# set cost params:  1.0 0.0 1.0
# 1
# interpolate adjoint :  True True True
# initial cost =  3.3311692896738596
# RUN  0 , total integrated cost =  3.3311692896738596
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.3311692873081187
# RUN  2 , total integrated cost =  3.3311692856230257
# RUN  3 , total integrated cost =  3.3311692851798576
# RUN  4 , total integrated cost =  3.3311692847903034
# RUN  5 , total integrated cost =  3.331169284488702
# RUN  6 , total integrated cost =  3.3311692842260894
# RUN  7 , total integrated cost =  3.3311692591083686
# RUN  8 , total integrated cost =  3.33116924946768
# RUN  9 , total integrated cost =  3.3311692494624436
# RUN  10 , total integrated cost =  3.331169249461288
# RUN  11 , total integrated cost =  3.33116924945804
# RUN  12 , total integrated cost =  3.3311692494563787
# RUN  13 , total integrated cost =  3.331169249411941
# RUN  14 , total integrated cost =  3.331169249377267
# RUN  15 , total integrated cost =  3.331169249367421
# RUN  16 , total integrated cost =  3.331169249354287
# RUN  17 , total integrated cost =  3.3311692493532234
# RUN  18 , total integrated cost =  3.331169249349607
# RUN  19 , total integrated cost =  3.3311692493472727
# RUN  20 , total integrated cost =  3.3311692492646796
# RUN  30 , total integrated cost =  3.3311692490342373
# RUN  40 , total integrated cost =  3.331169248983
# RUN  50 , total integrated cost =  3.3311692488840148
# RUN  60 , total integrated cost =  3.3311692480435764
# RUN  70 , total integrated cost =  3.331169247933722
# RUN  80 , total integrated cost =  3.3311692463742406
# RUN  90 , total integrated cost =  3.331169246341561
# RUN  100 , total integrated cost =  3.3311692442668837
# RUN  110 , total integrated cost =  3.331169244167066
# RUN  120 , total integrated cost =  3.331169244122773
# RUN  130 , total integrated cost =  3.331169244070257
# RUN  140 , total integrated cost =  3.331169243860982
# RUN  150 , total integrated cost =  3.331169243793952
# RUN  160 , total integrated cost =  3.3311692437204456
# RUN  170 , total integrated cost =  3.3311692436489184
# RUN  180 , total integrated cost =  3.33116924362841
# RUN  190 , total integrated cost =  3.3311692436084797
# RUN  200 , total integrated cost =  3.33116924346002
# RUN  300 , total integrated cost =  3.3311692396239967
# RUN  400 , total integrated cost =  3.3311692322553004
# RUN  500 , total integrated cost =  3.3311692318284565
# RUN  600 , total integrated cost =  3.3311692317282415
# RUN  700 , total integrated cost =  3.331169231465816
# RUN  800 , total integrated cost =  3.3311692314234693
# RUN  900 , total integrated cost =  3.3311692307707212
# RUN  1000 , total integrated cost =  3.3311692293239044
# RUN  1100 , total integrated cost =  3.331169229267232
# RUN  1200 , total integrated cost =  3.331169228936908
# RUN  1300 , total integrated cost =  3.331169227163255
# RUN  1400 , total integrated cost =  3.3311692271060123
# RUN  1500 , total integrated cost =  3.33116922699939
# Control only changes marginally.
# RUN  1570 , total integrated cost =  3.331169221949932
# Improved over  1570  iterations in  337.78019685999607  seconds by  2.0330377026311908e-06  percent.
# 0.0 [4.90459838e-16 3.33116922e+00]
# 0.0 [3.88250122e-18 3.33116925e+00]
# ----- 60
# set cost params:  1.0 0.0 1.0
# 1
# interpolate adjoint :  True True True
# initial cost =  3.331169353569593
# RUN  0 , total integrated cost =  3.331169353569593
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.331169346400827
# RUN  2 , total integrated cost =  3.3311693459754874
# RUN  3 , total integrated cost =  3.3311693454743976
# RUN  4 , total integrated cost =  3.3311693453453617
# RUN  5 , total integrated cost =  3.3311693451857
# RUN  6 , total integrated cost =  3.3311693450722677
# RUN  7 , total integrated cost =  3.3311693449270883
# RUN  8 , total integrated cost =  3.3311693448161046
# RUN  9 , total integrated cost =  3.3311693446739494
# RUN  10 , total integrated cost =  3.3311693445610007
# RUN  11 , total integrated cost =  3.331169344398904
# RUN  12 , total integrated cost =  3.331169344265715
# RUN  13 , total integrated cost =  3.3311693440953625
# RUN  14 , total integrated cost =  3.331169343954501
# RUN  15 , total integrated cost =  3.3311693437578773
# RUN  16 , total integrated cost =  3.331169343590012
# RUN  17 , total integrated cost =  3.3311693432243064
# RUN  18 , total integrated cost =  3.3311693429091846
# RUN  19 , total integrated cost =  3.331169342527474
# RUN  20 , total integrated cost =  3.331169342192931
# RUN  30 , total integrated cost =  3.331169323463658
# RUN  40 , total integrated cost =  3.3311693223913297
# RUN  50 , total integrated cost =  3.331169253273469
# RUN  60 , total integrated cost =  3.3311692390639775
# RUN  70 , total integrated cost =  3.3311692378295032
# RUN  80 , total integrated cost =  3.331169237572065
# RUN  90 , total integrated cost =  3.331169237501839
# RUN  100 , total integrated cost =  3.3311692374122828
# RUN  110 , total integrated cost =  3.331169237202726
# Control only changes marginally.
# RUN  114 , total integrated cost =  3.331169202039315
# Improved over  114  iterations in  24.22648467599356  seconds by  4.548861426201256e-06  percent.
# 0.0 [2.21282162e-16 3.33116920e+00]
# 0.0 [3.88250122e-18 3.33116925e+00]
# ----- 70
# set cost params:  1.0 0.0 1.0
# 1
# interpolate adjoint :  True True True
# initial cost =  3.3311693822214212
# RUN  0 , total integrated cost =  3.3311693822214212
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.3311693727196694
# RUN  2 , total integrated cost =  3.3311693725409492
# RUN  3 , total integrated cost =  3.3311693723199505
# RUN  4 , total integrated cost =  3.331169372162072
# RUN  5 , total integrated cost =  3.3311693719613658
# RUN  6 , total integrated cost =  3.331169371811755
# RUN  7 , total integrated cost =  3.331169371619105
# RUN  8 , total integrated cost =  3.3311693714696906
# RUN  9 , total integrated cost =  3.3311693712670465
# RUN  10 , total integrated cost =  3.3311693711029142
# RUN  11 , total integrated cost =  3.3311693708611823
# RUN  12 , total integrated cost =  3.3311693706582384
# RUN  13 , total integrated cost =  3.3311693703947483
# RUN  14 , total integrated cost =  3.331169370168528
# RUN  15 , total integrated cost =  3.3311693698202505
# RUN  16 , total integrated cost =  3.3311693695107802
# RUN  17 , total integrated cost =  3.3311693686057944
# RUN  18 , total integrated cost =  3.3311693678017855
# RUN  19 , total integrated cost =  3.331169322056059
# RUN  20 , total integrated cost =  3.3311692874039602
# RUN  30 , total integrated cost =  3.3311692867216216
# RUN  40 , total integrated cost =  3.331169285145649
# RUN  50 , total integrated cost =  3.3311692792696275
# RUN  60 , total integrated cost =  3.331169246009264
# RUN  70 , total integrated cost =  3.3311692261126953
# RUN  80 , total integrated cost =  3.3311692261041013
# RUN  90 , total integrated cost =  3.3311692260462413
# RUN  100 , total integrated cost =  3.3311692260369408
# RUN  110 , total integrated cost =  3.331169225968213
# RUN  120 , total integrated cost =  3.3311692259597154
# RUN  130 , total integrated cost =  3.3311692259495174
# RUN  140 , total integrated cost =  3.3311692259393055
# RUN  150 , total integrated cost =  3.3311692258413097
# RUN  160 , total integrated cost =  3.33116922582548
# RUN  170 , total integrated cost =  3.331169225815835
# RUN  180 , total integrated cost =  3.3311692258091834
# RUN  190 , total integrated cost =  3.331169225803109
# RUN  200 , total integrated cost =  3.331169225788741
# RUN  300 , total integrated cost =  3.3311692219556615
# RUN  400 , total integrated cost =  3.3311692218092377
# RUN  500 , total integrated cost =  3.3311692210260557
# RUN  600 , total integrated cost =  3.331169220782383
# RUN  700 , total integrated cost =  3.331169220611486
# RUN  800 , total integrated cost =  3.3311692205702936
# RUN  900 , total integrated cost =  3.3311692204660477
# RUN  1000 , total integrated cost =  3.3311692202816627
# RUN  1100 , total integrated cost =  3.331169219976646
# RUN  1200 , total integrated cost =  3.331169215034562
# RUN  1300 , total integrated cost =  3.331169214971851
# Control only changes marginally.
# RUN  1361 , total integrated cost =  3.331169214784284
# Improved over  1361  iterations in  278.46686554201005  seconds by  5.026377152717032e-06  percent.
# 0.0 [2.21282145e-16 3.33116921e+00]
# 0.0 [3.88250122e-18 3.33116925e+00]
# ----- 80
# set cost params:  1.0 0.0 1.0
# 1
# interpolate adjoint :  True True True
# initial cost =  3.3311694088445636
# RUN  0 , total integrated cost =  3.3311694088445636
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.3311693971971303
# RUN  2 , total integrated cost =  3.3311693968837326
# RUN  3 , total integrated cost =  3.3311693966230322
# RUN  4 , total integrated cost =  3.331169396130857
# RUN  5 , total integrated cost =  3.3311693957024238
# RUN  6 , total integrated cost =  3.3311693948360395
# RUN  7 , total integrated cost =  3.3311693941247316
# RUN  8 , total integrated cost =  3.3311693931302777
# RUN  9 , total integrated cost =  3.331169392326332
# RUN  10 , total integrated cost =  3.331169375317427
# RUN  11 , total integrated cost =  3.331169364984203
# RUN  12 , total integrated cost =  3.331169364639025
# RUN  13 , total integrated cost =  3.331169364329521
# RUN  14 , total integrated cost =  3.3311693633699777
# RUN  15 , total integrated cost =  3.33116936256113
# RUN  16 , total integrated cost =  3.331169322029186
# RUN  17 , total integrated cost =  3.331169287948491
# RUN  18 , total integrated cost =  3.331169287898721
# RUN  19 , total integrated cost =  3.3311692878614534
# RUN  20 , total integrated cost =  3.331169287798983
# RUN  30 , total integrated cost =  3.3311692859469297
# RUN  40 , total integrated cost =  3.3311692854575647
# RUN  50 , total integrated cost =  3.3311692827338897
# RUN  60 , total integrated cost =  3.331169280595646
# RUN  70 , total integrated cost =  3.3311692801862454
# RUN  80 , total integrated cost =  3.331169240718507
# RUN  90 , total integrated cost =  3.331169240088296
# RUN  100 , total integrated cost =  3.3311692398939625
# RUN  110 , total integrated cost =  3.331169239691751
# RUN  120 , total integrated cost =  3.331169239574358
# RUN  130 , total integrated cost =  3.331169239459736
# RUN  140 , total integrated cost =  3.3311692386848306
# RUN  150 , total integrated cost =  3.3311692386424476
# RUN  160 , total integrated cost =  3.3311692385757863
# RUN  170 , total integrated cost =  3.3311692384960803
# RUN  180 , total integrated cost =  3.3311692382214684
# RUN  190 , total integrated cost =  3.3311692381801827
# RUN  200 , total integrated cost =  3.3311692381448217
# RUN  300 , total integrated cost =  3.331169235483721
# RUN  400 , total integrated cost =  3.3311692328683558
# RUN  500 , total integrated cost =  3.3311692321684787
# RUN  600 , total integrated cost =  3.3311692283846446
# Control only changes marginally.
# RUN  638 , total integrated cost =  3.3311691983657954
# Improved over  638  iterations in  117.01471287399181  seconds by  6.318464855326056e-06  percent.
# 0.0 [2.21282124e-16 3.33116919e+00]
# 0.0 [3.88250122e-18 3.33116925e+00]
# ----- 90
# set cost params:  1.0 0.0 1.0
# 1
# interpolate adjoint :  True True True
# initial cost =  3.331169446021601
# RUN  0 , total integrated cost =  3.331169446021601
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.331169430506725
# RUN  2 , total integrated cost =  3.331169429950527
# RUN  3 , total integrated cost =  3.3311694294994316
# RUN  4 , total integrated cost =  3.331169428736185
# RUN  5 , total integrated cost =  3.3311694281308855
# RUN  6 , total integrated cost =  3.33116942717347
# RUN  7 , total integrated cost =  3.331169426329356
# RUN  8 , total integrated cost =  3.3311694251117263
# RUN  9 , total integrated cost =  3.3311694241056875
# RUN  10 , total integrated cost =  3.3311694174214113
# RUN  11 , total integrated cost =  3.3311694123831983
# RUN  12 , total integrated cost =  3.331169355231508
# RUN  13 , total integrated cost =  3.3311693353810674
# RUN  14 , total integrated cost =  3.331169335110523
# RUN  15 , total integrated cost =  3.331169334884386
# RUN  16 , total integrated cost =  3.331169333877092
# RUN  17 , total integrated cost =  3.3311693330930936
# RUN  18 , total integrated cost =  3.331169332736041
# RUN  19 , total integrated cost =  3.3311693324495364
# RUN  20 , total integrated cost =  3.3311693319393365
# RUN  30 , total integrated cost =  3.331169319288575
# RUN  40 , total integrated cost =  3.3311693181436097
# RUN  50 , total integrated cost =  3.3311693145583168
# RUN  60 , total integrated cost =  3.3311693136692044
# RUN  70 , total integrated cost =  3.3311692498717544
# RUN  80 , total integrated cost =  3.3311692492370586
# RUN  90 , total integrated cost =  3.3311692244817204
# RUN  100 , total integrated cost =  3.331169224470602
# RUN  110 , total integrated cost =  3.331169224341473
# RUN  120 , total integrated cost =  3.331169224333471
# RUN  130 , total integrated cost =  3.331169224096707
# RUN  140 , total integrated cost =  3.331169224082092
# RUN  150 , total integrated cost =  3.3311692240215858
# RUN  160 , total integrated cost =  3.33116922378798
# RUN  170 , total integrated cost =  3.3311692235890473
# RUN  180 , total integrated cost =  3.3311692234391503
# RUN  190 , total integrated cost =  3.331169223377744
# RUN  200 , total integrated cost =  3.3311692233755683
# RUN  300 , total integrated cost =  3.3311692222127665
# RUN  400 , total integrated cost =  3.3311692215554207
# RUN  500 , total integrated cost =  3.3311692215022823
# RUN  600 , total integrated cost =  3.3311692208379826
# RUN  700 , total integrated cost =  3.3311692208039214
# RUN  800 , total integrated cost =  3.3311692193335234
# RUN  900 , total integrated cost =  3.3311692192194293
# Control only changes marginally.
# RUN  970 , total integrated cost =  3.3311692116003866
# Improved over  970  iterations in  165.39715900999727  seconds by  7.037204753146398e-06  percent.
# 0.0 [2.21282093e-16 3.33116921e+00]
# 0.0 [3.88250122e-18 3.33116925e+00]
# ----- 100
# set cost params:  1.0 0.0 1.0
# 1
# interpolate adjoint :  True True True
# initial cost =  3.3311694857873886
# RUN  0 , total integrated cost =  3.3311694857873886
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.331169466262028
# RUN  2 , total integrated cost =  3.331169464643656
# RUN  3 , total integrated cost =  3.3311694633094198
# RUN  4 , total integrated cost =  3.3311694588208614
# RUN  5 , total integrated cost =  3.3311694551838666
# RUN  6 , total integrated cost =  3.331169452197397
# RUN  7 , total integrated cost =  3.3311694498100066
# RUN  8 , total integrated cost =  3.331169448489294
# RUN  9 , total integrated cost =  3.3311694474419817
# RUN  10 , total integrated cost =  3.3311694417524205
# RUN  11 , total integrated cost =  3.331169437358523
# RUN  12 , total integrated cost =  3.3311692670761306
# RUN  13 , total integrated cost =  3.3311692479213244
# RUN  14 , total integrated cost =  3.3311692479066766
# RUN  15 , total integrated cost =  3.331169247888139
# RUN  16 , total integrated cost =  3.3311692478837323
# RUN  17 , total integrated cost =  3.3311692478771717
# RUN  18 , total integrated cost =  3.331169247874917
# RUN  19 , total integrated cost =  3.3311692478686488
# RUN  20 , total integrated cost =  3.3311692478646617
# RUN  30 , total integrated cost =  3.3311692361940417
# RUN  40 , total integrated cost =  3.3311692361700658
# RUN  50 , total integrated cost =  3.3311692361421654
# RUN  60 , total integrated cost =  3.331169236111671
# RUN  70 , total integrated cost =  3.3311692360814016
# RUN  80 , total integrated cost =  3.331169236035747
# RUN  90 , total integrated cost =  3.3311692359840506
# RUN  100 , total integrated cost =  3.3311692359321636
# RUN  110 , total integrated cost =  3.3311692345001265
# RUN  120 , total integrated cost =  3.3311692344775254
# RUN  130 , total integrated cost =  3.331169234446973
# RUN  140 , total integrated cost =  3.33116923436787
# RUN  150 , total integrated cost =  3.3311692343333066
# RUN  160 , total integrated cost =  3.331169230482853
# RUN  170 , total integrated cost =  3.3311692304514557
# RUN  180 , total integrated cost =  3.3311692304375287
# RUN  190 , total integrated cost =  3.3311692304061427
# RUN  200 , total integrated cost =  3.331169230014514
# RUN  300 , total integrated cost =  3.33116922921996
# RUN  400 , total integrated cost =  3.331169228001432
# RUN  500 , total integrated cost =  3.331169227130254
# RUN  600 , total integrated cost =  3.3311692256892638
# RUN  700 , total integrated cost =  3.331169224167236
# Control only changes marginally.
# RUN  719 , total integrated cost =  3.3311691966985353
# Improved over  719  iterations in  121.38418002300023  seconds by  8.678299153075386e-06  percent.
# 0.0 [2.21282060e-16 3.33116919e+00]
# 0.0 [3.88250122e-18 3.33116925e+00]
# ----- 110
# set cost params:  1.0 0.0 1.0
# 1
# interpolate adjoint :  True True True
# initial cost =  3.331169535218776
# RUN  0 , total integrated cost =  3.331169535218776
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.3311695107525647
# RUN  2 , total integrated cost =  3.3311692722618553
# RUN  3 , total integrated cost =  3.331169255026599
# RUN  4 , total integrated cost =  3.3311692549895175
# RUN  5 , total integrated cost =  3.3311692549778766
# RUN  6 , total integrated cost =  3.331169254961927
# RUN  7 , total integrated cost =  3.331169254956775
# RUN  8 , total integrated cost =  3.331169254947902
# RUN  9 , total integrated cost =  3.3311692549430982
# RUN  10 , total integrated cost =  3.3311692549285756
# RUN  11 , total integrated cost =  3.331169254918085
# RUN  12 , total integrated cost =  3.3311692540532047
# RUN  13 , total integrated cost =  3.3311692531381776
# RUN  14 , total integrated cost =  3.331169253134669
# RUN  15 , total integrated cost =  3.331169253124029
# RUN  16 , total integrated cost =  3.3311692531169914
# RUN  17 , total integrated cost =  3.3311692528814576
# RUN  18 , total integrated cost =  3.331169252664595
# RUN  19 , total integrated cost =  3.331169244092002
# RUN  20 , total integrated cost =  3.3311692384415807
# RUN  30 , total integrated cost =  3.3311692382854314
# RUN  40 , total integrated cost =  3.331169238132423
# RUN  50 , total integrated cost =  3.3311692380056446
# RUN  60 , total integrated cost =  3.331169237900721
# RUN  70 , total integrated cost =  3.3311692375268542
# RUN  80 , total integrated cost =  3.3311692374697794
# RUN  90 , total integrated cost =  3.3311692374152027
# RUN  100 , total integrated cost =  3.331169237379511
# RUN  110 , total integrated cost =  3.331169235802885
# RUN  120 , total integrated cost =  3.331169235220873
# RUN  130 , total integrated cost =  3.3311692347135597
# RUN  140 , total integrated cost =  3.331169234632888
# RUN  150 , total integrated cost =  3.3311692340848715
# RUN  160 , total integrated cost =  3.331169233735761
# RUN  170 , total integrated cost =  3.331169233187252
# RUN  180 , total integrated cost =  3.3311692329876292
# RUN  190 , total integrated cost =  3.3311692329594162
# RUN  200 , total integrated cost =  3.3311692329210145
# RUN  300 , total integrated cost =  3.331169215216979
# RUN  400 , total integrated cost =  3.3311692151500396
# Control only changes marginally.
# RUN  495 , total integrated cost =  3.331169214983449
# Improved over  495  iterations in  108.25261473099818  seconds by  9.61330019322304e-06  percent.
# 0.0 [5.38816710e-17 3.33116921e+00]
# 0.0 [3.88250122e-18 3.33116925e+00]
# ----- 120
# set cost params:  1.0 0.0 1.0
# 1
# interpolate adjoint :  True True True
# initial cost =  3.331169565852415
# RUN  0 , total integrated cost =  3.331169565852415
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.3311695393183225
# RUN  2 , total integrated cost =  3.33116953795491
# RUN  3 , total integrated cost =  3.331169536387161
# RUN  4 , total integrated cost =  3.3311695346330343
# RUN  5 , total integrated cost =  3.331169532485751
# RUN  6 , total integrated cost =  3.3311695296414072
# RUN  7 , total integrated cost =  3.331169526170968
# RUN  8 , total integrated cost =  3.3311695251676716
# RUN  9 , total integrated cost =  3.3311695238669934
# RUN  10 , total integrated cost =  3.331169522525513
# RUN  11 , total integrated cost =  3.3311695208724013
# RUN  12 , total integrated cost =  3.3311695195088693
# RUN  13 , total integrated cost =  3.331169517917707
# RUN  14 , total integrated cost =  3.3311695167109687
# RUN  15 , total integrated cost =  3.33116951523022
# RUN  16 , total integrated cost =  3.331169514031114
# RUN  17 , total integrated cost =  3.3311695125731036
# RUN  18 , total integrated cost =  3.3311695114426034
# RUN  19 , total integrated cost =  3.3311695101736114
# RUN  20 , total integrated cost =  3.3311695091392837
# RUN  30 , total integrated cost =  3.3311694994403545
# RUN  40 , total integrated cost =  3.3311694908814653
# RUN  50 , total integrated cost =  3.3311694831459175
# RUN  60 , total integrated cost =  3.331169478335612
# RUN  70 , total integrated cost =  3.3311694738561575
# RUN  80 , total integrated cost =  3.3311693934188273
# RUN  90 , total integrated cost =  3.331169391083223
# RUN  100 , total integrated cost =  3.3311693866889094
# RUN  110 , total integrated cost =  3.3311693532752074
# RUN  120 , total integrated cost =  3.33116927338796
# RUN  130 , total integrated cost =  3.3311692713170618
# RUN  140 , total integrated cost =  3.3311692280371394
# RUN  150 , total integrated cost =  3.331169228028888
# RUN  160 , total integrated cost =  3.3311692199806675
# RUN  170 , total integrated cost =  3.3311692199585523
# RUN  180 , total integrated cost =  3.331169215760264
# RUN  190 , total integrated cost =  3.3311692157574186
# RUN  200 , total integrated cost =  3.3311692157555983
# RUN  300 , total integrated cost =  3.331169214493925
# RUN  400 , total integrated cost =  3.3311692144667746
# RUN  500 , total integrated cost =  3.331169214443674
# Control only changes marginally.
# RUN  597 , total integrated cost =  3.331169214181456
# Improved over  597  iterations in  103.28371904199594  seconds by  1.0556981621334671e-05  percent.
# 0.0 [5.38812685e-17 3.33116921e+00]
# 0.0 [3.88250122e-18 3.33116925e+00]
# ----- 130
# set cost params:  1.0 0.0 1.0
# 1
# interpolate adjoint :  True True True
# initial cost =  3.3311707218970343
# RUN  0 , total integrated cost =  3.3311707218970343
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.33117044198424
# RUN  2 , total integrated cost =  3.3311704290919306
# RUN  3 , total integrated cost =  3.331170410223853
# RUN  4 , total integrated cost =  3.3311703867693807
# RUN  5 , total integrated cost =  3.3311703465888054
# RUN  6 , total integrated cost =  3.3311702974028545
# RUN  7 , total integrated cost =  3.331170171711841
# RUN  8 , total integrated cost =  3.3311701691811937
# RUN  9 , total integrated cost =  3.331170166010549
# RUN  10 , total integrated cost =  3.3311701635569633
# RUN  11 , total integrated cost =  3.3311701605189348
# RUN  12 , total integrated cost =  3.331170158084193
# RUN  13 , total integrated cost =  3.3311701550619013
# RUN  14 , total integrated cost =  3.331170152638146
# RUN  15 , total integrated cost =  3.331170149618529
# RUN  16 , total integrated cost =  3.3311701471372777
# RUN  17 , total integrated cost =  3.3311701441234667
# RUN  18 , total integrated cost =  3.331170141567928
# RUN  19 , total integrated cost =  3.3311701383624923
# RUN  20 , total integrated cost =  3.33117013575869
# RUN  30 , total integrated cost =  3.331170103067431
# RUN  40 , total integrated cost =  3.331170031448249
# RUN  50 , total integrated cost =  3.3311697139177032
# RUN  60 , total integrated cost =  3.3311696949635383
# RUN  70 , total integrated cost =  3.331169677606203
# RUN  80 , total integrated cost =  3.331169661724074
# RUN  90 , total integrated cost =  3.331169646587974
# RUN  100 , total integrated cost =  3.331169634634344
# RUN  110 , total integrated cost =  3.331169613777081
# RUN  120 , total integrated cost =  3.331169292769604
# RUN  130 , total integrated cost =  3.331169273450087
# RUN  140 , total integrated cost =  3.3311692545778255
# RUN  150 , total integrated cost =  3.3311692526820202
# RUN  160 , total integrated cost =  3.3311691917431996
# RUN  170 , total integrated cost =  3.3311691255798763
# RUN  180 , total integrated cost =  3.331169125500773
# RUN  190 , total integrated cost =  3.3311691254174782
# RUN  200 , total integrated cost =  3.3311691252635085
# RUN  300 , total integrated cost =  3.3311691228586398
# RUN  400 , total integrated cost =  3.3311691224114344
# RUN  500 , total integrated cost =  3.3311691112598414
# RUN  600 , total integrated cost =  3.3311691101209715
# RUN  700 , total integrated cost =  3.331169109203944
# RUN  800 , total integrated cost =  3.3311691089759234
# RUN  900 , total integrated cost =  3.331169108703692
# Control only changes marginally.
# RUN  988 , total integrated cost =  3.3311690976002803
# Improved over  988  iterations in  172.9988596559997  seconds by  4.8760537652015046e-05  percent.
# 0.0 [5.38807508e-17 3.33116910e+00]
# 0.0 [3.88250122e-18 3.33116925e+00]
# ----- 140
# set cost params:  1.0 0.0 1.0
# 1
# interpolate adjoint :  True True True
# initial cost =  3.331171257357029
# RUN  0 , total integrated cost =  3.331171257357029
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.3311709165023426
# RUN  2 , total integrated cost =  3.331170886058537
# RUN  3 , total integrated cost =  3.3311708253812284
# RUN  4 , total integrated cost =  3.3311708172263734
# RUN  5 , total integrated cost =  3.3311708055689113
# RUN  6 , total integrated cost =  3.331170794970625
# RUN  7 , total integrated cost =  3.3311707798709373
# RUN  8 , total integrated cost =  3.331170773748527
# RUN  9 , total integrated cost =  3.3311707658759904
# RUN  10 , total integrated cost =  3.331170758929982
# RUN  11 , total integrated cost =  3.331170749855884
# RUN  12 , total integrated cost =  3.3311707427905914
# RUN  13 , total integrated cost =  3.3311707340295036
# RUN  14 , total integrated cost =  3.3311707271859485
# RUN  15 , total integrated cost =  3.3311707183649704
# RUN  16 , total integrated cost =  3.331170711717816
# RUN  17 , total integrated cost =  3.331170702867038
# RUN  18 , total integrated cost =  3.3311706964965833
# RUN  19 , total integrated cost =  3.331170687531339
# RUN  20 , total integrated cost =  3.331170681293504
# RUN  30 , total integrated cost =  3.3311706156330643
# RUN  40 , total integrated cost =  3.331170558251535
# RUN  50 , total integrated cost =  3.3311705061110892
# RUN  60 , total integrated cost =  3.3311704573148564
# RUN  70 , total integrated cost =  3.3311704120663945
# RUN  80 , total integrated cost =  3.331170369533121
# RUN  90 , total integrated cost =  3.331170329125362
# RUN  100 , total integrated cost =  3.3311702912639913
# RUN  110 , total integrated cost =  3.3311702562964265
# RUN  120 , total integrated cost =  3.3311702250665673
# RUN  130 , total integrated cost =  3.3311701819454087
# RUN  140 , total integrated cost =  3.331170102806858
# RUN  150 , total integrated cost =  3.331170034048855
# RUN  160 , total integrated cost =  3.3311696256216625
# RUN  170 , total integrated cost =  3.3311695391253915
# RUN  180 , total integrated cost =  3.331169530906056
# RUN  190 , total integrated cost =  3.3311695153218874
# RUN  200 , total integrated cost =  3.331169496393731
# RUN  300 , total integrated cost =  3.3311692221537843
# RUN  400 , total integrated cost =  3.331169172175804
# RUN  500 , total integrated cost =  3.3311691262348377
# RUN  600 , total integrated cost =  3.3311691217538657
# RUN  700 , total integrated cost =  3.3311691130472685
# RUN  800 , total integrated cost =  3.3311691100969716
# RUN  900 , total integrated cost =  3.3311691099368312
# RUN  1000 , total integrated cost =  3.331169109370746
# RUN  1100 , total integrated cost =  3.331169107575625
# RUN  1200 , total integrated cost =  3.3311690985455367
# Control only changes marginally.
# RUN  1230 , total integrated cost =  3.3311690915550773
# Improved over  1230  iterations in  222.48935640600394  seconds by  6.501622955568109e-05  percent.
# 0.0 [5.38802759e-17 3.33116909e+00]
# 0.0 [3.88250122e-18 3.33116925e+00]
# ----- 150
# set cost params:  1.0 0.0 1.0
# 1
# interpolate adjoint :  True True True
# initial cost =  3.331172117113265
# RUN  0 , total integrated cost =  3.331172117113265
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.3311716975885712
# RUN  2 , total integrated cost =  3.3311716530318103
# RUN  3 , total integrated cost =  3.3311716240868976
# RUN  4 , total integrated cost =  3.3311707872808016
# RUN  5 , total integrated cost =  3.331170588675932
# RUN  6 , total integrated cost =  3.3311705661290953
# RUN  7 , total integrated cost =  3.3311705278270183
# RUN  8 , total integrated cost =  3.3311705194391856
# RUN  9 , total integrated cost =  3.3311705084923204
# RUN  10 , total integrated cost =  3.3311705008546557
# RUN  11 , total integrated cost =  3.331170490681513
# RUN  12 , total integrated cost =  3.331170484304397
# RUN  13 , total integrated cost =  3.3311704755236082
# RUN  14 , total integrated cost =  3.3311704701479514
# RUN  15 , total integrated cost =  3.3311704628919117
# RUN  16 , total integrated cost =  3.331170458123881
# RUN  17 , total integrated cost =  3.3311704520980463
# RUN  18 , total integrated cost =  3.3311704474274086
# RUN  19 , total integrated cost =  3.3311704413953986
# RUN  20 , total integrated cost =  3.3311704367929282
# RUN  30 , total integrated cost =  3.331170386798436
# RUN  40 , total integrated cost =  3.3311703412927507
# RUN  50 , total integrated cost =  3.3311702984022693
# RUN  60 , total integrated cost =  3.3311702589301713
# RUN  70 , total integrated cost =  3.331170221907969
# RUN  80 , total integrated cost =  3.3311701902326565
# RUN  90 , total integrated cost =  3.331170161111784
# RUN  100 , total integrated cost =  3.331170133098676
# RUN  110 , total integrated cost =  3.3311701038751
# RUN  120 , total integrated cost =  3.331170069993098
# RUN  130 , total integrated cost =  3.3311700146366703
# RUN  140 , total integrated cost =  3.331169964414122
# RUN  150 , total integrated cost =  3.3311692578849685
# RUN  160 , total integrated cost =  3.3311692560997055
# RUN  170 , total integrated cost =  3.3311692502068286
# RUN  180 , total integrated cost =  3.331169245211384
# RUN  190 , total integrated cost =  3.3311692392095327
# RUN  200 , total integrated cost =  3.3311692378032864
# RUN  300 , total integrated cost =  3.331169168264408
# RUN  400 , total integrated cost =  3.331169120571824
# RUN  500 , total integrated cost =  3.331169111684255
# RUN  600 , total integrated cost =  3.331169111600793
# RUN  700 , total integrated cost =  3.3311691115619335
# RUN  800 , total integrated cost =  3.3311691114366857
# RUN  900 , total integrated cost =  3.3311691112283297
# RUN  1000 , total integrated cost =  3.3311691110369206
# RUN  1100 , total integrated cost =  3.331169110828577
# RUN  1200 , total integrated cost =  3.331169110709797
# RUN  1300 , total integrated cost =  3.3311691104653343
# RUN  1400 , total integrated cost =  3.3311691088566038
# RUN  1500 , total integrated cost =  3.331169108698207
# RUN  1600 , total integrated cost =  3.3311691082644517
# RUN  1700 , total integrated cost =  3.331169108067905
# RUN  1800 , total integrated cost =  3.3311691076565317
# RUN  1900 , total integrated cost =  3.3311691070057594
# RUN  2000 , total integrated cost =  3.331169106748393
# Control only changes marginally.
# RUN  2610 , total integrated cost =  3.3311691021274386
# Improved over  2610  iterations in  457.9392651990056  seconds by  9.050825717338284e-05  percent.
# 0.0 [5.38797514e-17 3.33116910e+00]
# 0.0 [3.88250122e-18 3.33116925e+00]
# ----- 160
# set cost params:  1.0 0.0 1.0
# 1
# interpolate adjoint :  True True True
# initial cost =  3.3311729707203503
# RUN  0 , total integrated cost =  3.3311729707203503
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.3311724879015134
# RUN  2 , total integrated cost =  3.3311716366338886
# RUN  3 , total integrated cost =  3.3311713931875153
# RUN  4 , total integrated cost =  3.331171306065431
# RUN  5 , total integrated cost =  3.3311712614248608
# RUN  6 , total integrated cost =  3.331171151039688
# RUN  7 , total integrated cost =  3.3311710934471557
# RUN  8 , total integrated cost =  3.3311694632666202
# RUN  9 , total integrated cost =  3.331169253697166
# RUN  10 , total integrated cost =  3.3311692536051134
# RUN  11 , total integrated cost =  3.331169253537007
# RUN  12 , total integrated cost =  3.331169253429627
# RUN  13 , total integrated cost =  3.3311692533466237
# RUN  14 , total integrated cost =  3.331169253209732
# RUN  15 , total integrated cost =  3.3311692530979125
# RUN  16 , total integrated cost =  3.3311692526944605
# RUN  17 , total integrated cost =  3.331169252346767
# RUN  18 , total integrated cost =  3.3311692509604476
# RUN  19 , total integrated cost =  3.331169249272706
# RUN  20 , total integrated cost =  3.3311692491506086
# RUN  30 , total integrated cost =  3.3311692483085835
# RUN  40 , total integrated cost =  3.331169245789948
# RUN  50 , total integrated cost =  3.3311692433270284
# RUN  60 , total integrated cost =  3.3311692418332863
# RUN  70 , total integrated cost =  3.3311692405679016
# RUN  80 , total integrated cost =  3.3311691600427107
# RUN  90 , total integrated cost =  3.3311691598348094
# RUN  100 , total integrated cost =  3.33116915953966
# RUN  110 , total integrated cost =  3.33116915706173
# RUN  120 , total integrated cost =  3.33116915693067
# RUN  130 , total integrated cost =  3.3311691544906625
# RUN  140 , total integrated cost =  3.3311691533269876
# RUN  150 , total integrated cost =  3.331169152979876
# RUN  160 , total integrated cost =  3.3311691524352773
# RUN  170 , total integrated cost =  3.3311691521479623
# RUN  180 , total integrated cost =  3.3311691519537994
# RUN  190 , total integrated cost =  3.3311691517393816
# RUN  200 , total integrated cost =  3.3311691452393988
# RUN  300 , total integrated cost =  3.3311691127161174
# RUN  400 , total integrated cost =  3.3311691125202127
# RUN  500 , total integrated cost =  3.3311691099128558
# RUN  600 , total integrated cost =  3.3311691094709213
# RUN  700 , total integrated cost =  3.331169109334429
# RUN  800 , total integrated cost =  3.3311691029908603
# RUN  900 , total integrated cost =  3.3311691028968187
# Control only changes marginally.
# RUN  954 , total integrated cost =  3.3311691028847235
# Improved over  954  iterations in  170.31117340098717  seconds by  0.00011611032093128415  percent.
# 0.0 [5.38791701e-17 3.33116910e+00]
# 0.0 [3.88250122e-18 3.33116925e+00]
# ----- 170
# set cost params:  1.0 0.0 1.0
# 1
# interpolate adjoint :  True True True
# initial cost =  3.3311740375628918
# RUN  0 , total integrated cost =  3.3311740375628918
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.3311734861862283
# RUN  2 , total integrated cost =  3.3311715337234715
# RUN  3 , total integrated cost =  3.33116986720599
# RUN  4 , total integrated cost =  3.331169841547835
# RUN  5 , total integrated cost =  3.331169789851977
# RUN  6 , total integrated cost =  3.331169761630981
# RUN  7 , total integrated cost =  3.331169670394941
# RUN  8 , total integrated cost =  3.331169498908703
# RUN  9 , total integrated cost =  3.3311694978987183
# RUN  10 , total integrated cost =  3.3311694958774374
# RUN  11 , total integrated cost =  3.3311694941894228
# RUN  12 , total integrated cost =  3.3311694921559876
# RUN  13 , total integrated cost =  3.3311694905285747
# RUN  14 , total integrated cost =  3.3311694885032277
# RUN  15 , total integrated cost =  3.3311694869152135
# RUN  16 , total integrated cost =  3.3311694848846494
# RUN  17 , total integrated cost =  3.331169483123028
# RUN  18 , total integrated cost =  3.3311694815932555
# RUN  19 , total integrated cost =  3.331169480279784
# RUN  20 , total integrated cost =  3.3311694774296963
# RUN  30 , total integrated cost =  3.3311691934362986
# RUN  40 , total integrated cost =  3.3311691922024727
# RUN  50 , total integrated cost =  3.331169188999794
# RUN  60 , total integrated cost =  3.3311691862678576
# RUN  70 , total integrated cost =  3.3311691831214416
# RUN  80 , total integrated cost =  3.331169180428774
# RUN  90 , total integrated cost =  3.3311691794780796
# RUN  100 , total integrated cost =  3.3311691790222477
# RUN  110 , total integrated cost =  3.3311691736757143
# RUN  120 , total integrated cost =  3.331169168995932
# RUN  130 , total integrated cost =  3.331169167443252
# RUN  140 , total integrated cost =  3.3311691484089776
# RUN  150 , total integrated cost =  3.331169145843442
# RUN  160 , total integrated cost =  3.3311691356095667
# RUN  170 , total integrated cost =  3.331169124965164
# Control only changes marginally.
# RUN  176 , total integrated cost =  3.3311691030068067
# Improved over  176  iterations in  34.17027502199926  seconds by  0.00014813264121471548  percent.
# 0.0 [5.38785269e-17 3.33116910e+00]
# 0.0 [3.88250122e-18 3.33116925e+00]
# ----- 180
# set cost params:  1.0 0.0 1.0
# 1
# interpolate adjoint :  True True True
# initial cost =  3.3311740858225036
# RUN  0 , total integrated cost =  3.3311740858225036
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.3311735474070328
# RUN  2 , total integrated cost =  3.3311734345774746
# RUN  3 , total integrated cost =  3.331173375251462
# RUN  4 , total integrated cost =  3.3311726432425592
# RUN  5 , total integrated cost =  3.3311723990037385
# RUN  6 , total integrated cost =  3.331171503983959
# RUN  7 , total integrated cost =  3.331169996822159
# RUN  8 , total integrated cost =  3.331169994529813
# RUN  9 , total integrated cost =  3.331169991602979
# RUN  10 , total integrated cost =  3.331169989367404
# RUN  11 , total integrated cost =  3.33116998660568
# RUN  12 , total integrated cost =  3.3311699843991667
# RUN  13 , total integrated cost =  3.3311699817043015
# RUN  14 , total integrated cost =  3.3311699795289345
# RUN  15 , total integrated cost =  3.331169976796696
# ...
# RUN  3000 , total integrated cost =  3.3311646502625756
# RUN  4000 , total integrated cost =  3.3311646458215094
# RUN  5000 , total integrated cost =  3.3311646416505907
# RUN  6000 , total integrated cost =  3.331164637789478
# RUN  7000 , total integrated cost =  3.3311646341264693
# RUN  8000 , total integrated cost =  3.3311646305544285
# RUN  9000 , total integrated cost =  3.331164627126436
# RUN  10000 , total integrated cost =  3.3311646239752744
# RUN  10000 , total integrated cost =  3.3311646239752744
# Improved over  10000  iterations in  1191.320498342  seconds by  0.0004809936150138583  percent.
# 0.0 [9.15536726e-17 3.33116457e+00]
# 0.0 [3.88250122e-18 3.33116925e+00]
# go back to ----- 760
# ----- 760
# set cost params:  1.0 0.0 1.0
# 1
# interpolate adjoint :  True True True
# initial cost =  3.3311646239752744
# RUN  0 , total integrated cost =  3.3311646239752744
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.33116462397457
# RUN  2 , total integrated cost =  3.3311646239728026
# RUN  3 , total integrated cost =  3.3311646239715524
# RUN  4 , total integrated cost =  3.3311646239598076
# RUN  5 , total integrated cost =  3.3311646239482124
# RUN  6 , total integrated cost =  3.331164623946217
# RUN  7 , total integrated cost =  3.331164623943712
# RUN  8 , total integrated cost =  3.331164623942994
# RUN  9 , total integrated cost =  3.3311646239417825
# RUN  10 , total integrated cost =  3.3311646239409747
# RUN  11 , total integrated cost =  3.331164623938976
# RUN  12 , total integrated cost =  3.331164623937328
# RUN  13 , total integrated cost =  3.3311646239289048
# RUN  14 , total integrated cost =  3.33116462392102
# RUN  15 , total integrated cost =  3.3311646239182076
# RUN  16 , total integrated cost =  3.3311646239147885
# RUN  17 , total integrated cost =  3.331164623913895
# RUN  18 , total integrated cost =  3.3311646239126325
# RUN  19 , total integrated cost =  3.3311646239119352
# RUN  20 , total integrated cost =  3.3311646239104844
# RUN  30 , total integrated cost =  3.33116462388072
# RUN  40 , total integrated cost =  3.3311646238492094
# RUN  50 , total integrated cost =  3.331164623819248
# RUN  60 , total integrated cost =  3.331164623788004
# RUN  70 , total integrated cost =  3.3311646237592103
# RUN  80 , total integrated cost =  3.331164623726695
# RUN  90 , total integrated cost =  3.3311646236980033
# RUN  100 , total integrated cost =  3.3311646236653862
# RUN  110 , total integrated cost =  3.331164623636735
# RUN  120 , total integrated cost =  3.331164623604394
# RUN  130 , total integrated cost =  3.3311646235753574
# RUN  140 , total integrated cost =  3.3311646235387182
# RUN  150 , total integrated cost =  3.331164623507992
# RUN  160 , total integrated cost =  3.3311646234787577
# RUN  170 , total integrated cost =  3.331164623450237
# RUN  180 , total integrated cost =  3.3311646234147374
# RUN  190 , total integrated cost =  3.331164623386182
# RUN  200 , total integrated cost =  3.3311646233539234
# RUN  300 , total integrated cost =  3.33116462303398
# RUN  400 , total integrated cost =  3.3311646227009777
# RUN  500 , total integrated cost =  3.3311646223976763
# RUN  600 , total integrated cost =  3.3311646220927034
# RUN  700 , total integrated cost =  3.331164621778131
# RUN  800 , total integrated cost =  3.331164621473586
# RUN  900 , total integrated cost =  3.3311646211761348
# RUN  1000 , total integrated cost =  3.3311646208493304
# RUN  1100 , total integrated cost =  3.331164620545522
# RUN  1200 , total integrated cost =  3.3311646202290803
# RUN  1300 , total integrated cost =  3.3311646199257963
# RUN  1400 , total integrated cost =  3.331164619630933
# RUN  1500 , total integrated cost =  3.331164619322058
# RUN  1600 , total integrated cost =  3.3311646190315094
# RUN  1700 , total integrated cost =  3.331164618739309
# RUN  1800 , total integrated cost =  3.331164618450355
# RUN  1900 , total integrated cost =  3.33116461815737
# RUN  2000 , total integrated cost =  3.331164617868398
# RUN  3000 , total integrated cost =  3.3311646149209237
# RUN  4000 , total integrated cost =  3.3311646110303035
# RUN  5000 , total integrated cost =  3.331164607728343
# RUN  6000 , total integrated cost =  3.331164604489546
# RUN  7000 , total integrated cost =  3.3311646012893794
# RUN  8000 , total integrated cost =  3.3311645985461764
# RUN  9000 , total integrated cost =  3.33116459554664
# RUN  10000 , total integrated cost =  3.33116459144718
# RUN  10000 , total integrated cost =  3.33116459144718
# Improved over  10000  iterations in  3202.938616995001  seconds by  9.764781481180762e-07  percent.
# 0.0 [9.15536726e-17 3.33116457e+00]
# 0.0 [3.88250122e-18 3.33116925e+00]
# go back to ----- 760
# ----- 760
# set cost params:  1.0 0.0 1.0
# 1
# interpolate adjoint :  True True True
# initial cost =  3.33116459144718
# RUN  0 , total integrated cost =  3.33116459144718
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.3311645914464605
# RUN  2 , total integrated cost =  3.3311645914462513
# RUN  3 , total integrated cost =  3.3311645914452312
# RUN  4 , total integrated cost =  3.3311645914443972
# RUN  5 , total integrated cost =  3.3311645914357375
# RUN  6 , total integrated cost =  3.3311645914257992
# RUN  7 , total integrated cost =  3.3311645914256003
# RUN  8 , total integrated cost =  3.331164591425061
# RUN  9 , total integrated cost =  3.331164591424786
# RUN  10 , total integrated cost =  3.331164591420391
# RUN  11 , total integrated cost =  3.331164591416711
# RUN  12 , total integrated cost =  3.3311645914148293
# RUN  13 , total integrated cost =  3.3311645914125787
# RUN  14 , total integrated cost =  3.331164591412375
# RUN  15 , total integrated cost =  3.3311645914118007
# RUN  16 , total integrated cost =  3.3311645914114627
# RUN  17 , total integrated cost =  3.331164591385668
# RUN  18 , total integrated cost =  3.3311645913588404
# RUN  19 , total integrated cost =  3.3311645913581542
# RUN  20 , total integrated cost =  3.331164591357705
# RUN  30 , total integrated cost =  3.331164591294242
# RUN  40 , total integrated cost =  3.3311645912301002
# RUN  50 , total integrated cost =  3.3311645911967593
# RUN  60 , total integrated cost =  3.3311645911571306
# RUN  70 , total integrated cost =  3.331164591095847
# RUN  80 , total integrated cost =  3.331164591024159
# RUN  90 , total integrated cost =  3.331164590932947
# RUN  100 , total integrated cost =  3.331164590918388
# RUN  110 , total integrated cost =  3.3311645908611442
# RUN  120 , total integrated cost =  3.3311645907928615
# RUN  130 , total integrated cost =  3.331164590703512
# RUN  140 , total integrated cost =  3.331164590640286
# RUN  150 , total integrated cost =  3.331164590596788
# RUN  160 , total integrated cost =  3.331164590563329
# RUN  170 , total integrated cost =  3.3311645905156198
# RUN  180 , total integrated cost =  3.331164590499485
# RUN  190 , total integrated cost =  3.331164590477136
# RUN  200 , total integrated cost =  3.3311645904350775
# RUN  300 , total integrated cost =  3.3311645899914146
# RUN  400 , total integrated cost =  3.331164589645721
# RUN  500 , total integrated cost =  3.3311645892552364
# RUN  600 , total integrated cost =  3.331164588585547
# RUN  700 , total integrated cost =  3.3311645881546936
# RUN  800 , total integrated cost =  3.3311645877250897
# RUN  900 , total integrated cost =  3.3311645871111866
# RUN  1000 , total integrated cost =  3.331164586537744
# RUN  1100 , total integrated cost =  3.33116458573484
# RUN  1200 , total integrated cost =  3.331164585250316
# RUN  1300 , total integrated cost =  3.331164584864346
# RUN  1400 , total integrated cost =  3.331164584525673
# RUN  1500 , total integrated cost =  3.3311645841559705
# RUN  1600 , total integrated cost =  3.3311645832304784
# RUN  1700 , total integrated cost =  3.331164582590049
# RUN  1800 , total integrated cost =  3.3311645818012043
# RUN  1900 , total integrated cost =  3.3311645807648107
# RUN  2000 , total integrated cost =  3.3311645802143994
# Control only changes marginally.
# RUN  2190 , total integrated cost =  3.3311645637076146
# Improved over  2190  iterations in  922.6728824159945  seconds by  8.327287588372201e-07  percent.
# 0.0 [9.15536726e-17 3.33116456e+00]
# 0.0 [3.88250122e-18 3.33116925e+00]
# ----- 770
# set cost params:  1.0 0.0 1.0
# 1
# interpolate adjoint :  True True True
# initial cost =  3.331180515509348
# RUN  0 , total integrated cost =  3.331180515509348
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.331175336705634
# RUN  2 , total integrated cost =  3.3311735773623674
# RUN  3 , total integrated cost =  3.331172856826134
# RUN  4 , total integrated cost =  3.3311718242180115
# RUN  5 , total integrated cost =  3.331171348749385
# RUN  6 , total integrated cost =  3.3311670022381734
# RUN  7 , total integrated cost =  3.3311665252663576
# RUN  8 , total integrated cost =  3.331166502893776
# RUN  9 , total integrated cost =  3.331166483462966
# RUN  10 , total integrated cost =  3.3311664674460637
# RUN  11 , total integrated cost =  3.331166455520549
# RUN  12 , total integrated cost =  3.3311664414477793
# RUN  13 , total integrated cost =  3.3311664298508057
# RUN  14 , total integrated cost =  3.331166417095222
# RUN  15 , total integrated cost =  3.3311664062868553
# RUN  16 , total integrated cost =  3.3311663945234256
# RUN  17 , total integrated cost =  3.33116638470153
# RUN  18 , total integrated cost =  3.331166373130104
# RUN  19 , total integrated cost =  3.3311663636218065
# RUN  20 , total integrated cost =  3.3311663532718185
# RUN  30 , total integrated cost =  3.3311662502213086
# RUN  40 , total integrated cost =  3.3311660779824823
# RUN  50 , total integrated cost =  3.331166034598319
# RUN  60 , total integrated cost =  3.33116600296716
# RUN  70 , total integrated cost =  3.3311659730279377
# RUN  80 , total integrated cost =  3.3311658685972008
# RUN  90 , total integrated cost =  3.3311655148345842
# RUN  100 , total integrated cost =  3.331165364545099
# RUN  110 , total integrated cost =  3.3311653009989395
# RUN  120 , total integrated cost =  3.331165292247812
# RUN  130 , total integrated cost =  3.3311652872114106
# RUN  140 , total integrated cost =  3.3311651564250635
# RUN  150 , total integrated cost =  3.3311651545621617
# RUN  160 , total integrated cost =  3.331165116894928
# RUN  170 , total integrated cost =  3.3311648780356804
# RUN  180 , total integrated cost =  3.3311648775529017
# RUN  190 , total integrated cost =  3.331164876833206
# RUN  200 , total integrated cost =  3.3311648762185735
# RUN  300 , total integrated cost =  3.331164857209917
# RUN  400 , total integrated cost =  3.3311648534186116
# RUN  500 , total integrated cost =  3.3311647795027812
# RUN  600 , total integrated cost =  3.3311647770031922
# RUN  700 , total integrated cost =  3.3311647685573336
# RUN  800 , total integrated cost =  3.3311647662416446
# RUN  900 , total integrated cost =  3.3311647645842375
# RUN  1000 , total integrated cost =  3.331164760966504
# RUN  1100 , total integrated cost =  3.33116475195458
# RUN  1200 , total integrated cost =  3.3311647503835253
# RUN  1300 , total integrated cost =  3.3311647492289107
# RUN  1400 , total integrated cost =  3.331164747977533
# RUN  1500 , total integrated cost =  3.331164738410401
# RUN  1600 , total integrated cost =  3.331164734671603
# RUN  1700 , total integrated cost =  3.331164730590476
# RUN  1800 , total integrated cost =  3.331164729760356
# RUN  1900 , total integrated cost =  3.3311647270645226
# RUN  2000 , total integrated cost =  3.33116471869024
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_32337/904553173.py in <module>
#      62                 control0 = bestControl_[i][j][:,:,100:-(100+j)]
#      63
# ---> 64         bestControl_[i][j], bestState_[i][j], cost_[i][j], runtime_, grad_, phi_, phi1_, costnode_[i][j] = aln.A1(
#      65             control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
#      66             startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
#
# ~/Promotion/neurolib/neurolib/models/model.py in A1(self, control_, target_state_, c_scheme_, u_mat_, u_scheme_, max_iteration_, tolerance_, startStep_, max_control_, min_control_, t_sim_, t_sim_pre_, t_sim_post_, CGVar, line_search_, control_variables_, prec_variables_, separate_comp, transition_time_, noise_real, init_params)
#     661             if self.params.N == 1:
#     662                 if noise_real == 0:
# --> 663                     return opti1_rate_control.A1(self, control_, target_state_, c_scheme_, u_mat_, u_scheme_, max_iteration_,
#     664                                                 tolerance_, startStep_, max_control_, min_control_, t_sim_, t_sim_pre_, t_sim_post_, CGVar,
#     665                                                 line_search_, control_variables_, prec_variables_, separate_comp, transition_time_)
#
# ~/Promotion/neurolib/neurolib/utils/A1_aln_rate_control.py in A1(model, control_, target_state, c_scheme_, u_mat_, u_scheme_, max_iteration_, tolerance_, startStep_, cntrl_max_, cntrl_min_, t_sim_, t_sim_pre_, t_sim_post_, CGVar, line_search_, control_variables_, prec_variables_, separate_comp, transition_time_)
#     384                 d_exc[:,1:,:] = 0.
#     385
# --> 386                 s_exc, tc_exc, startstep_exc_ = line_search_func(model, N, n_control_vars, T, dt, state1_[:,:2,:], target_state_,
#     387                              best_control_, d_exc, ip_, ie_, is_, start_step_ = startstep_exc_, max_it_ = 500,
#     388                              max_control_ = cntrl_max_, min_control_ = cntrl_min_, tolerance_ = tolerance_step, variables_ = prec_variables, grad_ = grad1_)
#
# ~/Promotion/neurolib/neurolib/utils/func_optimize.py in step_size(model, N, V, T, dt, state_, target_, control_, dir_, ip_, ie_, is_, start_step_, max_it_, bisec_factor_, max_control_, min_control_, tolerance_, substep_, variables_, alg, control_parameter, grad_, noise_real, init_vars, startind_)
#     233                 #print(init_vars)
#     234                 set_init(model, init_vars, model.init_vars, model.state_vars, startind_)
# --> 235             state1_ = updateState(model, test_control_)
#     236             cost1_int_ = cost.f_int(N, V, T, dt, state1_, target_, test_control_, ip_, ie_, is_, v_ = variables_)
#     237         else:
#
# ~/Promotion/neurolib/neurolib/utils/func_optimize.py in updateState(model, control_)
#       8     state_ = model.getZeroState()
#       9     output_vars = model.output_vars
# ---> 10     model.run(control = control_)
#      11     for i in range(len(output_vars)):
#      12         state_[:,i,:] = model[output_vars[i]][:,:]
#
# ~/Promotion/neurolib/neurolib/models/model.py in run(self, inputs, chunkwise, chunksize, bold, append, append_outputs, continue_run, control)
#     182
#     183         if chunkwise is False:
# --> 184             self.integrate(append_outputs=append, simulate_bold=bold, control=cntrl)
#     185             if continue_run:
#     186                 self.setInitialValuesToLastState()
#
# ~/Promotion/neurolib/neurolib/models/model.py in integrate(self, append_outputs, simulate_bold, control)
#     225         t, *variables = self.integration(self.params, control=control)
#     226         #print("after integration")
# --> 227         self.storeOutputsAndStates(t, variables, append=append_outputs)
#     228
#     229         # force bold if params['bold'] == True
#
# ~/Promotion/neurolib/neurolib/models/model.py in storeOutputsAndStates(self, t, variables, append)
#     292             if svn in self.output_vars:
#     293                 self.setOutput(svn, sv, append=append, removeICs=False)
# --> 294             self.setStateVariables(svn, sv, removeICs=False)
#     295
#     296     def setInitialValuesToLastState(self):
#
# ~/Promotion/neurolib/neurolib/models/model.py in setStateVariables(self, name, data, removeICs)
#     408                 self.state[name] = data[:, self.startindt:].copy()
#     409             else:
# --> 410                 self.state[name] = data[:, self.startindt-1:].copy()
#     411         else:
#     412             # no time dimension
#
# KeyboardInterrupt:

# %%
bestControl_maxW = np.array( [[None] * len(t_pen)] * len(exc) )
bestState_maxW = np.array( [[None] * len(t_pen)] * len(exc) )
cost_maxW = np.array( [[None] * len(t_pen)] * len(exc) )
costnode_maxW = np.array( [[None] * len(t_pen)] * len(exc) )
weights_maxW = np.array( [[None] * len(t_pen)] * len(exc) )
convergence_maxW = np.array( [[None] * len(t_pen)] * len(exc) )

file_maxW = '1_down_Wmax.pickle'

# %%
if os.path.isfile(file_maxW) :
    print("file found")
    
    with open(file_maxW,'rb') as f:
        load_array = pickle.load(f)

    bestControl_maxW = load_array[0]
    bestState_maxW = load_array[1]
    cost_maxW = load_array[2]
    costnode_maxW = load_array[3]
    weights_maxW = load_array[4]

# %%
for i in i_range_:
    j = 0

    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.

    aln.params.duration = dur
    max_it = int(160)

    while not convergence_maxW[i][j]:
        weight_ = ( cost_uncontrolled[i] - costnode_[i][j][0][0][0] ) / sum( costnode_[i][j][2][0][:] )

        cost.setParams(1., weight_ * factor_we, weight_ * factor_ws)
        weights_maxW[i][j] = cost.getParams()

        setinit(initVars[i], aln)

        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        control0 = aln.getZeroControl()
        control0 = bestControl_[i][0][:,:,n_pre-1:-n_post+1]

        bestControl_maxW[i][j], bestState_maxW[i][j], cost_maxW[i][j], runtime_, grad_, phi_, phi1_, costnode_maxW[i][j] = aln.A1(
            control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
            prec_variables_ = p_var, transition_time_ = t_pen[j])

        if cost_maxW[i][j][2] == 0.:
            convergence_maxW[i][j] = True

        print('cost splitting : ', costnode_[i][j][0][0][0], costnode_[i][j][2][0][:2])

        with open(file_maxW,'wb') as f:
            pickle.dump([bestControl_maxW, bestState_maxW, cost_maxW, costnode_maxW, weights_maxW], f)

# %%
for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    j = 0
    step = 10

    while j < 4799:

        if j == 0:
            j += step
            continue
            
        if not convergence_maxW[i][j-step]:
            if j - step > 0:
                j -= step
                print('go back to -----', j)

        print('-----', j)

        if convergence_maxW[i][j]:
            j += step
            continue

        dur = d_array[j]
        T = 5001 - j
        aln.params.duration = dur

        cost.setParams(1., 0., 1.)
        weights_[i][j] = cost.getParams()

        setinit(initVars[i], aln)

        max_it = 10000

        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        if type(bestControl_maxW[i][j]) == type(None):
            max_percent_prev = (np.argmax(np.abs(bestControl_maxW[i][j-step]), axis=2)[0,1] - 100) / (T-200)
            shift_ind = 0
            if j < 3000:
                while max_percent_prev > max_percent:
                    shift_ind += 1
                    max_percent_prev = (np.argmax(np.abs(bestControl_maxW[i][j-step]), axis=2)[0,1] - 100 - shift_ind) / (T-200)

            control0 = np.zeros(( bestControl_maxW[i][j-step][:,:,100:-(100+step)].shape ))
            print('shift ind = ', shift_ind)
            if shift_ind != 0:
                control0[:,:,:-shift_ind] = 1. * bestControl_maxW[i][j-step][:,:,100+shift_ind:-(100+step)]
            else:
                control0[:,:,:] = 1. * bestControl_maxW[i][j-step][:,:,100:-(100+step)]
                #control0[0,0,:] = 0.
        else:
            if bestControl_[i][j].shape[2] == T+200:
                control0 = bestControl_maxW[i][j][:,:,100:-100]
                #control0[0,1,:] = 0.
            else:
                control0 = bestControl_maxW[i][j][:,:,100:-(100+j)]

        bestControl_maxW[i][j], bestState_maxW[i][j], cost_maxW[i][j], runtime_, grad_, phi_, phi1_, costnode_maxW[i][j] = aln.A1(
            control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
            prec_variables_ = p_var, transition_time_ = t_pen[j])

        print(costnode_[i][j][0][0][0], costnode_[i][j][2][0][:2])
        print(costnode_[i][0][0][0][0], costnode_[i][0][2][0][:2])

        if cost_maxW[i][j][2] == 0.:
            convergence_maxW[i][j] = True

        with open(file_maxW,'wb') as f:
            pickle.dump([bestControl_maxW, bestState_maxW, cost_maxW, costnode_maxW, weights_maxW], f)

        j += step
