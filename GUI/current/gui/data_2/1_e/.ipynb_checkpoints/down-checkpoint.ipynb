# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import sys
import pickle

path = os.getcwd().split(os.sep + 'GUI')[0]
if path not in sys.path:
    print("not here")
    sys.path.append(path)

from neurolib.models.aln import ALNModel
from neurolib.utils import plotFunctions as plotFunc
from neurolib.utils import costFunctions as cost
import neurolib.dashboard.functions as functions
import neurolib.dashboard.data as data
    
# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2 

#path = os.path.join(os.getcwd(), "plots")
# Out:
# not here

# %%
grid_data_file = os.path.join(os.getcwd().split('data')[0], 'bi.pickle')
with open(grid_data_file,'rb') as f:
    load_array= pickle.load(f)
exc = [load_array[0][20], load_array[0][50]]
inh = [load_array[1][20], load_array[1][50]]

folder = str(os.getcwd().split('data_2')[1])
print(folder)
case = str(folder[1])

file_ = 'down.pickle'

c_var = [0,1]
if len(folder) == 4:
    if folder[3] == 'e':
        p_var = [0]
    elif folder[3] == 'i':
        p_var = [1]
else:
    p_var = [0,1]
    
print(p_var)

step1 = 100
step2 = 10
step3 = 1
# Out:
# /1_e
# [0]

# %%
aln = ALNModel()
N = aln.params.N

data.set_parameters(aln)

state_vars = aln.state_vars
init_vars = aln.init_vars

##############################################################
def setinit(init_vars_, model):
    state_vars = model.state_vars
    init_vars = model.init_vars
    for iv in range(len(init_vars)):
        for sv in range(len(state_vars)):
            if state_vars[sv] in init_vars[iv]:
                #print("set init vars ", )
                if model.params[init_vars[iv]].ndim == 2:
                    model.params[init_vars[iv]][0,:] = init_vars_[sv]
                else:
                    model.params[init_vars[iv]][0] = init_vars_[sv]
                    
##############################################################               
def setmaxmincontrol(max_c_c, min_c_c, max_c_r, min_c_r):
    import numpy as np
    
    max_cntrl = np.zeros(( 6 ))
    min_cntrl = np.zeros(( 6 ))
    
    max_cntrl[0] = max_c_c
    min_cntrl[0] = min_c_c
    max_cntrl[1] = max_c_c
    min_cntrl[1] = min_c_c
    max_cntrl[2] = max_c_r
    min_cntrl[2] = min_c_r
    max_cntrl[3] = max_c_r
    min_cntrl[3] = min_c_r
    max_cntrl[4] = max_c_r
    min_cntrl[4] = min_c_r
    max_cntrl[5] = max_c_r
    min_cntrl[5] = min_c_r
            
    return max_cntrl, min_cntrl

# %%
d_array = np.arange(500., 20, -0.1)
t0_array = d_array - 20.
t_pen = np.zeros(( t0_array.shape ))
for i in range(len(t_pen)):
    t_pen[i] = t0_array[i] / d_array[i]

# %%
dur_pre = 10
dur_post = 10

n_pre = int(np.around(dur_pre/aln.params.dt + 1.,1))
n_post = int(np.around(dur_post/aln.params.dt + 1.,1))

tol = 1e-8
start_step = 10.
c_scheme = np.zeros(( 1,1 ))
c_scheme[0,0] = 1.
u_mat = np.identity(1)
u_scheme = np.array([[1.]])

if case in ['1', '2']:    # low to high
    max_I = [3., -3.]
else:
    max_I = [-3., 3.]
    
if case in ['1', '3']:    # sparsity
    factor_ws = 1.
    factor_we = 0.
else:
    factor_ws = 0.
    factor_we = 1.
    
maxC = [1000., -1000., 0.18, 0.]
max_cntrl, min_cntrl = setmaxmincontrol(maxC[0], maxC[1], maxC[2], maxC[3])

# %%
bestControl_ = np.array( [[None] * len(t_pen)] * len(exc) )
bestState_ = np.array( [[None] * len(t_pen)] * len(exc) )
cost_ = np.array( [[None] * len(t_pen)] * len(exc) )
costnode_ = np.array( [[None] * len(t_pen)] * len(exc) )
weights_ = np.array( [[None] * len(t_pen)] * len(exc) )
convergence_ = np.array( [[None] * len(t_pen)] * len(exc) )

initVars = [None] * len(exc)
target = [None] * len(exc)
cost_uncontrolled = [None] * len(exc)

print(bestControl_.shape)
# Out:
# (2, 4800)

# %%
if os.path.isfile(file_) :
    print("file found")
    
    with open(file_,'rb') as f:
        load_array = pickle.load(f)

    bestControl_ = load_array[0]
    bestState_ = load_array[1]
    cost_ = load_array[2]
    costnode_ = load_array[3]
    weights_ = load_array[4]
# Out:
# file found

# %%
# get initial parameters and target states

i_range = range(len(exc))
data.set_parameters(aln)
max_percent = []

i_range = [0]

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    aln.params.duration = 3000.
    
    control0 = aln.getZeroControl()
    control0 = functions.step_control(aln, maxI_ = max_I[0])

    aln.run(control=control0)
    
    target_rates = np.zeros((2))
    target_rates[0] = aln.rates_exc[0,-1] 
    target_rates[1] = aln.rates_inh[0,-1]

    control0 = functions.step_control(aln, maxI_ = max_I[1])
    aln.run(control=control0)

    init_state_vars = np.zeros(( len(state_vars) ))
    for j in range(len(state_vars)):
        if aln.state[state_vars[j]].size == 1:
            init_state_vars[j] = aln.state[state_vars[j]][0]
        else:
            init_state_vars[j] = aln.state[state_vars[j]][0,-1]

    initVars[i] = init_state_vars
    target[i] = [target_rates[0], target_rates[1]]
    
    max_percent_ind = 1
    if i == 1:
        max_percent_ind = 0
    
    max_percent.append( (np.argmax(np.abs(bestControl_[i][0]), axis=2)[0,max_percent_ind] -100) / 4800 )
    
print(max_percent)
# Out:
# -------  0 0.4500000000000001 0.4750000000000002
# [0.5277083333333333]

# %%
# get uncontrolled cost

data.set_parameters(aln)

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    dur = d_array[0]
    aln.params.duration = dur
    wp = 1. / (dur - t_pen[j] * dur)
    
    target_ = aln.getZeroTarget()
    target_[:,0,:] = target[i][0]
    target_[:,1,:] = target[i][1]
            
    cost.setParams(wp, 0.0, 0.0)

    setinit(initVars[i], aln)
    control0 = aln.getZeroControl()

    # "HS", "FR", "PR", "HZ"
    cgv = None
    max_it = 0

    bestControl_init_, bestState_init_, cost_init_, runtime_init_, grad_init_, phi_init_, phi1_, costnode_init_ = aln.A1(
        control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
        prec_variables_ = p_var, transition_time_ = t_pen[0])
    
    cost_uncontrolled[i] = cost_init_[0]
# Out:
# -------  0 0.4500000000000001 0.4750000000000002
# set cost params:  0.04980999999999999 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  634.4855803880291
# RUN  0 , total integrated cost =  634.4855803880291
# Gradient descend method:  None
# RUN  0 , total integrated cost =  634.4855803880291
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.

# %%
i = 0

for j in range(3000,4800,1):
    convergence_[i][j] = None
    #bestControl_[i][j] = None

# %%
tol = 1e-6

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    j = 0
    step = step1

    while j < 4800:

        if j == 0:
            j += step
            continue
            
        if not convergence_[i][j-step]:
            if j - step > 0:
                j -= step
                print('go back to -----', j)

        print('-----', j)
        
        if j >= 3301:
            step = step2
        if j >=4790:
            step = step3

        if convergence_[i][j]:
            j += step
            continue

        dur = d_array[j]
        T = 5001 - j
        aln.params.duration = dur
        
        wp = 1. / (dur - t_pen[j] * dur)

        cost.setParams(wp, 0., 1.)
        weights_[i][j] = cost.getParams()

        setinit(initVars[i], aln)

        max_it = 1000

        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]
        
        max_percent_ind = 1
        if i == 1:
            max_percent_ind = 0

        if type(bestControl_[i][j]) == type(None):
            max_percent_prev = (np.argmax(np.abs(bestControl_[i][j-step]), axis=2)[0,max_percent_ind] - 100) / (T-200)
            shift_ind = 0
            print(max_percent_prev, max_percent[i])
            if j < 4600:
                while max_percent_prev > max_percent[i]:
                    shift_ind += 1
                    max_percent_prev = (np.argmax(np.abs(bestControl_[i][j-step]), axis=2)[0,max_percent_ind] - 100 - shift_ind) / (T-200)

            control0 = np.zeros(( bestControl_[i][j-step][:,:,100:-(100+step)].shape ))
            print('shift ind = ', shift_ind)
            if shift_ind != 0:
                control0[:,:,:-shift_ind] = 1. * bestControl_[i][j-step][:,:,100+shift_ind:-(100+step)]
            else:
                control0[:,:,:] = 1. * bestControl_[i][j-step][:,:,100:-(100+step)]
                #control0[0,0,:] = 0.
        else:
            if bestControl_[i][j].shape[2] == T+200:
                control0 = bestControl_[i][j][:,:,100:-100]
                #control0[0,1,:] = 0.
            else:
                control0 = bestControl_[i][j][:,:,100:-(100+j)]

        bestControl_[i][j], bestState_[i][j], cost_[i][j], runtime_, grad_, phi_, phi1_, costnode_[i][j] = aln.A1(
            control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
            prec_variables_ = p_var, transition_time_ = t_pen[j])
        
        time_ = np.arange(-dur_pre,round(dur+dur_post+aln.params.dt,1),aln.params.dt)
        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        print(costnode_[i][j][0][0][0], costnode_[i][j][2][0][:2])

        if cost_[i][j][-1] == 0.:
            convergence_[i][j] = True
            if j >= 3300:
                step = step2
            if j >=4790:
                step = step3

        with open(file_,'wb') as f:
            pickle.dump([bestControl_, bestState_, cost_, costnode_, weights_], f)

        j += step
# Out:
# -------  0 0.4500000000000001 0.4750000000000002
# ----- 100
# ----- 200
# ----- 300
# ----- 400
# ----- 500
# ----- 600
# ----- 700
# ----- 800
# ----- 900
# ----- 1000
# ----- 1100
# ----- 1200
# ----- 1300
# ----- 1400
# ----- 1500
# ----- 1600
# ----- 1700
# ----- 1800
# ----- 1900
# ----- 2000
# ----- 2100
# ----- 2200
# ----- 2300
# ----- 2400
# ----- 2500
# ----- 2600
# ----- 2700
# ----- 2800
# ----- 2900
# ----- 3000
# set cost params:  0.05 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.3387793848001346
# RUN  0 , total integrated cost =  3.3387793848001346
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.3387793848001346
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.3387793848001346
# Improved over  1  iterations in  0.1553316750068916  seconds by  0.0  percent.
# 0.014827267673976598 [5.01289424e-09 3.33803802e+00]
# ----- 3100
# set cost params:  0.05 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.3390047264483798
# RUN  0 , total integrated cost =  3.3390047264483798
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.3390047264483798
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.3390047264483798
# Improved over  1  iterations in  0.21089317300356925  seconds by  0.0  percent.
# 0.01517195123000609 [5.01278415e-09 3.33824612e+00]
# ----- 3200
# set cost params:  0.05 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.340643926557231
# RUN  0 , total integrated cost =  3.340643926557231
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.340643926557231
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.340643926557231
# Improved over  1  iterations in  0.20539390300109517  seconds by  0.0  percent.
# 0.018122173736182846 [5.01278098e-09 3.33973781e+00]
# ----- 3300
# set cost params:  0.05 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.340853176697873
# RUN  0 , total integrated cost =  3.340853176697873
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.340853176697873
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.340853176697873
# Improved over  1  iterations in  0.20002019200182986  seconds by  0.0  percent.
# 0.017980061491771372 [5.01278009e-09 3.33995417e+00]
# ----- 3310
# set cost params:  0.05 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.3408986825563534
# RUN  0 , total integrated cost =  3.3408986825563534
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.3408986825563534
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.3408986825563534
# Improved over  1  iterations in  0.24735180100833531  seconds by  0.0  percent.
# 0.017982876570701946 [5.01277990e-09 3.33999953e+00]
# ----- 3320
# set cost params:  0.05 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.3409485038859077
# RUN  0 , total integrated cost =  3.3409485038859077
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.3409485038859077
# Control only changes marginally.
# RUN  1 , total integrated cost =  3.3409485038859077
# Improved over  1  iterations in  0.19698368599347305  seconds by  0.0  percent.
# 0.017983786210646065 [5.01277967e-09 3.34004931e+00]
# ----- 3330
# set cost params:  0.05 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.3412063896113495
# RUN  0 , total integrated cost =  3.3412063896113495
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.3412063852803944
# RUN  2 , total integrated cost =  3.3412063707781074
# RUN  3 , total integrated cost =  3.3412063707781074
# Control only changes marginally.
# RUN  3 , total integrated cost =  3.3412063707781074
# Improved over  3  iterations in  0.47874653700273484  seconds by  5.636659210495054e-07  percent.
# 0.01842717611917016 [5.01277941e-09 3.34028501e+00]
# ----- 3340
# set cost params:  0.05 0.0 1.0
# 0.4394250513347023 0.5277083333333333
# shift ind =  0
# interpolate adjoint :  True True True
# initial cost =  3.342284400510211
# RUN  0 , total integrated cost =  3.342284400510211
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.3420313841424694
# RUN  2 , total integrated cost =  3.3420312135607575
# RUN  3 , total integrated cost =  3.3420310851101878
# RUN  4 , total integrated cost =  3.3420309282772616
# RUN  5 , total integrated cost =  3.3420308101270373
# RUN  6 , total integrated cost =  3.3420306636251342
# RUN  7 , total integrated cost =  3.3420305500415997
# RUN  8 , total integrated cost =  3.3420304067913085
# RUN  9 , total integrated cost =  3.34203029128221
# RUN  10 , total integrated cost =  3.3420301408054662
# RUN  11 , total integrated cost =  3.342030004793207
# RUN  12 , total integrated cost =  3.342029834810472
# RUN  13 , total integrated cost =  3.3420296689171995
# RUN  14 , total integrated cost =  3.342029469785543
# RUN  15 , total integrated cost =  3.342029278474826
# RUN  16 , total integrated cost =  3.342028937753771
# RUN  17 , total integrated cost =  3.3420285936535152
# RUN  18 , total integrated cost =  3.3420275111822058
# RUN  19 , total integrated cost =  3.3420263543971376
# RUN  20 , total integrated cost =  3.342025384492495
# RUN  30 , total integrated cost =  3.342014023442149
# RUN  40 , total integrated cost =  3.342004150508131
# RUN  50 , total integrated cost =  3.3419942546688164
# RUN  60 , total integrated cost =  3.3419829760470368
# RUN  70 , total integrated cost =  3.3419686636349857
# RUN  80 , total integrated cost =  3.341920545013272
# RUN  90 , total integrated cost =  3.341896189997739
# Control only changes marginally.
# RUN  98 , total integrated cost =  3.341888247343956
# Improved over  98  iterations in  14.667423360995599  seconds by  0.011852766514863333  percent.
# 0.019740317563103505 [5.01277910e-09 3.34090123e+00]
# ----- 3350
# set cost params:  0.05 0.0 1.0
# 0.44176430048242593 0.5277083333333333
# shift ind =  0
# interpolate adjoint :  True True True
# initial cost =  3.3430536387134393
# RUN  0 , total integrated cost =  3.3430536387134393
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.342778939295636
# RUN  2 , total integrated cost =  3.3427785547510034
# RUN  3 , total integrated cost =  3.3427783665638775
# RUN  4 , total integrated cost =  3.342778129118919
# RUN  5 , total integrated cost =  3.3427779656539967
# RUN  6 , total integrated cost =  3.3427777408696295
# RUN  7 , total integrated cost =  3.342777577210851
# RUN  8 , total integrated cost =  3.342777343729766
# RUN  9 , total integrated cost =  3.3427771564344693
# RUN  10 , total integrated cost =  3.3427768613751176
# RUN  11 , total integrated cost =  3.3427766080404653
# RUN  12 , total integrated cost =  3.3427761493800827
# RUN  13 , total integrated cost =  3.3427757298464233
# RUN  14 , total integrated cost =  3.342774994243596
# RUN  15 , total integrated cost =  3.34277440713337
# RUN  16 , total integrated cost =  3.342694488162429
# RUN  17 , total integrated cost =  3.3426792473595155
# RUN  18 , total integrated cost =  3.3426792039179127
# RUN  19 , total integrated cost =  3.3426792039179127
# Control only changes marginally.
# RUN  19 , total integrated cost =  3.3426792039179127
# Improved over  19  iterations in  2.7774739710002905  seconds by  0.01120038252425104  percent.
# 0.021986067103956886 [5.01277873e-09 3.34157990e+00]
# ----- 3360
# set cost params:  0.05 0.0 1.0
# 0.4448299791811242 0.5277083333333333
# shift ind =  0
# interpolate adjoint :  True True True
# initial cost =  3.3439600904287703
# RUN  0 , total integrated cost =  3.3439600904287703
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.343663167106889
# RUN  2 , total integrated cost =  3.3436620317926997
# RUN  3 , total integrated cost =  3.343661531240358
# RUN  4 , total integrated cost =  3.3436609516941647
# RUN  5 , total integrated cost =  3.343660508846577
# RUN  6 , total integrated cost =  3.3436599773563
# RUN  7 , total integrated cost =  3.343659693390701
# RUN  8 , total integrated cost =  3.34365932771803
# RUN  9 , total integrated cost =  3.3436590611313246
# RUN  10 , total integrated cost =  3.343658719752677
# RUN  11 , total integrated cost =  3.3436584872282307
# RUN  12 , total integrated cost =  3.343658183008963
# RUN  13 , total integrated cost =  3.3436579468776575
# RUN  14 , total integrated cost =  3.3436576350158798
# RUN  15 , total integrated cost =  3.343657384282561
# RUN  16 , total integrated cost =  3.343657036180753
# RUN  17 , total integrated cost =  3.3436567498044054
# RUN  18 , total integrated cost =  3.3436563086660973
# RUN  19 , total integrated cost =  3.3436559451871752
# RUN  20 , total integrated cost =  3.343655107033075
# RUN  30 , total integrated cost =  3.343606455185251
# RUN  40 , total integrated cost =  3.3436043840123
# RUN  50 , total integrated cost =  3.3435855844349134
# RUN  60 , total integrated cost =  3.343562913306451
# RUN  70 , total integrated cost =  3.343561600810151
# RUN  80 , total integrated cost =  3.343539401603219
# RUN  90 , total integrated cost =  3.3435367891887893
# RUN  100 , total integrated cost =  3.3435355075255653
# RUN  110 , total integrated cost =  3.343534161348254
# RUN  120 , total integrated cost =  3.343532784504276
# RUN  130 , total integrated cost =  3.343531385719588
# RUN  140 , total integrated cost =  3.343528668719146
# RUN  150 , total integrated cost =  3.3435275524205674
# RUN  160 , total integrated cost =  3.3435238428981644
# RUN  170 , total integrated cost =  3.343522422217375
# RUN  180 , total integrated cost =  3.3435207841280157
# RUN  190 , total integrated cost =  3.3435185790317745
# RUN  200 , total integrated cost =  3.343516809275116
# RUN  300 , total integrated cost =  3.3434840798222836
# Control only changes marginally.
# RUN  366 , total integrated cost =  3.3434706765535367
# Improved over  366  iterations in  52.41342500499741  seconds by  0.014635757066429278  percent.
# 0.023248468414363583 [5.01277829e-09 3.34230825e+00]
# ----- 3370
# set cost params:  0.05 0.0 1.0
# 0.4472396925227114 0.5277083333333333
# shift ind =  0
# interpolate adjoint :  True True True
# initial cost =  3.3448292703060623
# RUN  0 , total integrated cost =  3.3448292703060623
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.3445117749037547
# RUN  2 , total integrated cost =  3.344511144481679
# RUN  3 , total integrated cost =  3.344510603048252
# RUN  4 , total integrated cost =  3.344509939208172
# RUN  5 , total integrated cost =  3.3445093449771974
# RUN  6 , total integrated cost =  3.3445076068520323
# RUN  7 , total integrated cost =  3.3445060565141116
# RUN  8 , total integrated cost =  3.344503969239067
# RUN  9 , total integrated cost =  3.3445020876417058
# RUN  10 , total integrated cost =  3.344500154933394
# RUN  11 , total integrated cost =  3.344498239090242
# RUN  12 , total integrated cost =  3.3444964160567334
# RUN  13 , total integrated cost =  3.344494870386439
# RUN  14 , total integrated cost =  3.3444929931094918
# RUN  15 , total integrated cost =  3.344491239584331
# RUN  16 , total integrated cost =  3.344489493373121
# RUN  17 , total integrated cost =  3.3444880523906573
# RUN  18 , total integrated cost =  3.3444864540315553
# RUN  19 , total integrated cost =  3.34448494839127
# RUN  20 , total integrated cost =  3.3444833736660553
# RUN  30 , total integrated cost =  3.3444696627132173
# RUN  40 , total integrated cost =  3.344458381451323
# RUN  50 , total integrated cost =  3.3444518769419935
# RUN  60 , total integrated cost =  3.3444497788344423
# RUN  70 , total integrated cost =  3.3444464136124066
# RUN  80 , total integrated cost =  3.344439302593216
# RUN  90 , total integrated cost =  3.3444292305046583
# RUN  100 , total integrated cost =  3.3444110736758277
# RUN  110 , total integrated cost =  3.3443970567388606
# RUN  120 , total integrated cost =  3.3443942859990745
# RUN  130 , total integrated cost =  3.3443877129255357
# RUN  140 , total integrated cost =  3.344386160495616
# RUN  150 , total integrated cost =  3.3443823924534577
# RUN  160 , total integrated cost =  3.3443780067304
# RUN  170 , total integrated cost =  3.344375842091261
# RUN  180 , total integrated cost =  3.3443506165555035
# RUN  190 , total integrated cost =  3.344349246202743
# RUN  200 , total integrated cost =  3.3443473603368945
# RUN  300 , total integrated cost =  3.3443189406121516
# RUN  400 , total integrated cost =  3.3442929786628137
# Control only changes marginally.
# RUN  402 , total integrated cost =  3.344292950621546
# Improved over  402  iterations in  55.14084944300703  seconds by  0.016034291773195264  percent.
# 0.024512752339967147 [5.01277778e-09 3.34306731e+00]
# ----- 3380
# set cost params:  0.05 0.0 1.0
# 0.44968332160450386 0.5277083333333333
# shift ind =  0
# interpolate adjoint :  True True True
# initial cost =  3.3457297027085886
# RUN  0 , total integrated cost =  3.3457297027085886
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.345394694424317
# RUN  2 , total integrated cost =  3.345393824113103
# RUN  3 , total integrated cost =  3.3453926910513956
# RUN  4 , total integrated cost =  3.3453916389583647
# RUN  5 , total integrated cost =  3.3452907114030634
# RUN  6 , total integrated cost =  3.3452653159849883
# RUN  7 , total integrated cost =  3.345265252255778
# RUN  8 , total integrated cost =  3.345265224328266
# RUN  9 , total integrated cost =  3.345265161661167
# RUN  10 , total integrated cost =  3.345265124061448
# RUN  11 , total integrated cost =  3.3452648580071442
# RUN  12 , total integrated cost =  3.3452646649556104
# RUN  13 , total integrated cost =  3.345264077796239
# RUN  14 , total integrated cost =  3.3452634198489757
# RUN  15 , total integrated cost =  3.345263322933752
# RUN  16 , total integrated cost =  3.3452631983099685
# RUN  17 , total integrated cost =  3.345263165312652
# RUN  18 , total integrated cost =  3.3452631072399948
# RUN  19 , total integrated cost =  3.3452630713716194
# RUN  20 , total integrated cost =  3.3452629620107466
# RUN  30 , total integrated cost =  3.3452585981296035
# RUN  40 , total integrated cost =  3.345255165832632
# RUN  50 , total integrated cost =  3.345253823749545
# RUN  60 , total integrated cost =  3.3451990093223287
# RUN  70 , total integrated cost =  3.3451983358209625
# RUN  80 , total integrated cost =  3.3451959643775204
# RUN  90 , total integrated cost =  3.345193007303113
# RUN  100 , total integrated cost =  3.3451915146299833
# RUN  110 , total integrated cost =  3.3451868935704745
# RUN  120 , total integrated cost =  3.3451810866543963
# RUN  130 , total integrated cost =  3.3451800373903864
# RUN  140 , total integrated cost =  3.345178315997852
# Control only changes marginally.
# RUN  141 , total integrated cost =  3.345178315997852
# Improved over  141  iterations in  20.207202955003595  seconds by  0.016480312509699502  percent.
# 0.026038200450174163 [5.01277716e-09 3.34387640e+00]
# ----- 3390
# set cost params:  0.05 0.0 1.0
# 0.45216158752657687 0.5277083333333333
# shift ind =  0
# interpolate adjoint :  True True True
# initial cost =  3.3467102347556765
# RUN  0 , total integrated cost =  3.3467102347556765
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.3463503709192683
# RUN  2 , total integrated cost =  3.3463473124448186
# RUN  3 , total integrated cost =  3.3463442112828137
# RUN  4 , total integrated cost =  3.346262876596103
# RUN  5 , total integrated cost =  3.3462338323095575
# RUN  6 , total integrated cost =  3.346233775306667
# RUN  7 , total integrated cost =  3.3462336764825094
# RUN  8 , total integrated cost =  3.3462335891815846
# RUN  9 , total integrated cost =  3.346233456509463
# RUN  10 , total integrated cost =  3.346233349147287
# RUN  11 , total integrated cost =  3.346233062265542
# RUN  12 , total integrated cost =  3.3462327921152677
# RUN  13 , total integrated cost =  3.3462321106183484
# RUN  14 , total integrated cost =  3.3462314240461426
# RUN  15 , total integrated cost =  3.3462215053895736
# RUN  16 , total integrated cost =  3.346212937689055
# RUN  17 , total integrated cost =  3.3462128108028932
# RUN  18 , total integrated cost =  3.3462126928433205
# RUN  19 , total integrated cost =  3.3462095924118747
# RUN  20 , total integrated cost =  3.346206539645685
# RUN  30 , total integrated cost =  3.346203517883669
# RUN  40 , total integrated cost =  3.3462025505010975
# RUN  50 , total integrated cost =  3.3462016114840942
# RUN  60 , total integrated cost =  3.346200773452195
# RUN  70 , total integrated cost =  3.346200170423583
# RUN  80 , total integrated cost =  3.3461308522310884
# RUN  90 , total integrated cost =  3.346107248976746
# RUN  100 , total integrated cost =  3.3461068336496944
# RUN  110 , total integrated cost =  3.3461064616072935
# RUN  120 , total integrated cost =  3.346104502763493
# RUN  130 , total integrated cost =  3.346099406922971
# RUN  140 , total integrated cost =  3.346098914604589
# RUN  150 , total integrated cost =  3.3460972831375235
# RUN  160 , total integrated cost =  3.34609639526565
# RUN  170 , total integrated cost =  3.346095942377076
# RUN  180 , total integrated cost =  3.346095495843653
# RUN  190 , total integrated cost =  3.3460950578814277
# RUN  200 , total integrated cost =  3.346094627053862
# RUN  300 , total integrated cost =  3.34593333310698
# Control only changes marginally.
# RUN  388 , total integrated cost =  3.345919632530377
# Improved over  388  iterations in  53.11305003899906  seconds by  0.02362326493310718  percent.
# 0.02764358810679332 [5.01277644e-09 3.34453745e+00]
# ----- 3400
# set cost params:  0.05 0.0 1.0
# 0.4532476802284083 0.5277083333333333
# shift ind =  0
# interpolate adjoint :  True True True
# initial cost =  3.347540573770116
# RUN  0 , total integrated cost =  3.347540573770116
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.3471602700212237
# RUN  2 , total integrated cost =  3.3471593533634914
# RUN  3 , total integrated cost =  3.3471585558964256
# RUN  4 , total integrated cost =  3.3471577439718465
# RUN  5 , total integrated cost =  3.34715732538999
# RUN  6 , total integrated cost =  3.347156872016175
# RUN  7 , total integrated cost =  3.3471565060746045
# RUN  8 , total integrated cost =  3.3471560932230764
# RUN  9 , total integrated cost =  3.3471557018264533
# RUN  10 , total integrated cost =  3.347155276096469
# RUN  11 , total integrated cost =  3.3471549002310783
# RUN  12 , total integrated cost =  3.3471545074047913
# RUN  13 , total integrated cost =  3.347154108054105
# RUN  14 , total integrated cost =  3.3471537002854888
# RUN  15 , total integrated cost =  3.347153319786698
# RUN  16 , total integrated cost =  3.3471528980265783
# RUN  17 , total integrated cost =  3.3471525328887783
# RUN  18 , total integrated cost =  3.3471521431864732
# RUN  19 , total integrated cost =  3.3471517563540027
# RUN  20 , total integrated cost =  3.347151350726251
# RUN  30 , total integrated cost =  3.3471475410027915
# RUN  40 , total integrated cost =  3.3471438421421227
# RUN  50 , total integrated cost =  3.3471402886441077
# RUN  60 , total integrated cost =  3.3471367965681913
# RUN  70 , total integrated cost =  3.3471334372979222
# RUN  80 , total integrated cost =  3.3471301710238857
# RUN  90 , total integrated cost =  3.3471269938427914
# RUN  100 , total integrated cost =  3.3471243663659442
# RUN  110 , total integrated cost =  3.3471219825873897
# RUN  120 , total integrated cost =  3.347118223233241
# RUN  130 , total integrated cost =  3.3471111753659484
# RUN  140 , total integrated cost =  3.3470898599897034
# RUN  150 , total integrated cost =  3.3470871535392837
# RUN  160 , total integrated cost =  3.347084479057576
# RUN  170 , total integrated cost =  3.347081828137321
# RUN  180 , total integrated cost =  3.34707922674538
# RUN  190 , total integrated cost =  3.3470765406366256
# RUN  200 , total integrated cost =  3.346963871510061
# Control only changes marginally.
# RUN  242 , total integrated cost =  3.3469256210942318
# Improved over  242  iterations in  33.5911080789956  seconds by  0.01837028296841936  percent.
# 0.029337001896082175 [5.01277558e-09 3.34545877e+00]
# ----- 3410
# set cost params:  0.05 0.0 1.0
# 0.45578720345075485 0.5277083333333333
# shift ind =  0
# interpolate adjoint :  True True True
# initial cost =  3.348638015129809
# RUN  0 , total integrated cost =  3.348638015129809
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.3482355505689583
# RUN  2 , total integrated cost =  3.3482352504830963
# RUN  3 , total integrated cost =  3.348234788893088
# RUN  4 , total integrated cost =  3.348234401913744
# RUN  5 , total integrated cost =  3.348233716134449
# RUN  6 , total integrated cost =  3.348233173834221
# RUN  7 , total integrated cost =  3.3482321439133576
# RUN  8 , total integrated cost =  3.348231324996146
# RUN  9 , total integrated cost =  3.3482125454743414
# RUN  10 , total integrated cost =  3.348198355134017
# RUN  11 , total integrated cost =  3.348197325438151
# RUN  12 , total integrated cost =  3.3481961333982575
# RUN  13 , total integrated cost =  3.348195359854731
# RUN  14 , total integrated cost =  3.3481944983489846
# RUN  15 , total integrated cost =  3.3481942791303902
# RUN  16 , total integrated cost =  3.348193990688307
# RUN  17 , total integrated cost =  3.3481937968384026
# RUN  18 , total integrated cost =  3.3481934830868303
# RUN  19 , total integrated cost =  3.348193249185267
# RUN  20 , total integrated cost =  3.348192677859413
# RUN  30 , total integrated cost =  3.348182905336809
# RUN  40 , total integrated cost =  3.3481729842044485
# RUN  50 , total integrated cost =  3.3481609087165096
# RUN  60 , total integrated cost =  3.3481355771512593
# RUN  70 , total integrated cost =  3.3481337451778184
# RUN  80 , total integrated cost =  3.348002841724335
# RUN  90 , total integrated cost =  3.3480011303488233
# RUN  100 , total integrated cost =  3.3479995845682833
# RUN  110 , total integrated cost =  3.347998076328119
# RUN  120 , total integrated cost =  3.347996604571397
# RUN  130 , total integrated cost =  3.3479951671993167
# RUN  140 , total integrated cost =  3.3479937506846977
# RUN  150 , total integrated cost =  3.347992349921217
# RUN  160 , total integrated cost =  3.3479909492763937
# RUN  170 , total integrated cost =  3.347989540267278
# RUN  180 , total integrated cost =  3.3479881555776934
# RUN  190 , total integrated cost =  3.3479867536363335
# RUN  200 , total integrated cost =  3.347985392083698
# RUN  300 , total integrated cost =  3.3476437659564713
# RUN  400 , total integrated cost =  3.3473301381101193
# RUN  500 , total integrated cost =  3.3472204200448825
# RUN  600 , total integrated cost =  3.347201282855179
# RUN  700 , total integrated cost =  3.3471610603916853
# RUN  800 , total integrated cost =  3.34688718397653
# RUN  900 , total integrated cost =  3.3462643731995434
# RUN  1000 , total integrated cost =  3.3461578084789836
# RUN  1000 , total integrated cost =  3.3461578084789836
# Improved over  1000  iterations in  139.09348702999705  seconds by  0.07406613195034595  percent.
# 0.02769228831593438 [5.01277456e-09 3.34477319e+00]
# go back to ----- 3410
# ----- 3410
# set cost params:  0.05 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.3461578084789836
# RUN  0 , total integrated cost =  3.3461578084789836
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.34615763482549
# RUN  2 , total integrated cost =  3.34615747665473
# RUN  3 , total integrated cost =  3.346157306856632
# RUN  4 , total integrated cost =  3.346157152023037
# RUN  5 , total integrated cost =  3.3461569884083344
# RUN  6 , total integrated cost =  3.346156835025969
# RUN  7 , total integrated cost =  3.3461566392462423
# RUN  8 , total integrated cost =  3.3461564142063054
# RUN  9 , total integrated cost =  3.3461563812021238
# RUN  10 , total integrated cost =  3.346156342394832
# RUN  11 , total integrated cost =  3.346156313722595
# RUN  12 , total integrated cost =  3.346156278975116
# RUN  13 , total integrated cost =  3.346156256021972
# RUN  14 , total integrated cost =  3.346156226522165
# RUN  15 , total integrated cost =  3.346156204260077
# RUN  16 , total integrated cost =  3.346156170396492
# RUN  17 , total integrated cost =  3.346156145634469
# RUN  18 , total integrated cost =  3.3461561090652783
# RUN  19 , total integrated cost =  3.3461561090652783
# Control only changes marginally.
# RUN  19 , total integrated cost =  3.3461561090652783
# Improved over  19  iterations in  2.824830313998973  seconds by  5.0787016121489614e-05  percent.
# 0.027854150781065293 [5.01277456e-09 3.34476340e+00]
# ----- 3420
# set cost params:  0.05 0.0 1.0
# 0.44605358435916004 0.5277083333333333
# shift ind =  0
# interpolate adjoint :  True True True
# initial cost =  3.347790273413878
# RUN  0 , total integrated cost =  3.347790273413878
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.347406800834
# RUN  2 , total integrated cost =  3.3474061095024337
# RUN  3 , total integrated cost =  3.347405651067037
# RUN  4 , total integrated cost =  3.347405209359267
# RUN  5 , total integrated cost =  3.347404822570647
# RUN  6 , total integrated cost =  3.3474044453193024
# RUN  7 , total integrated cost =  3.3474040945384296
# RUN  8 , total integrated cost =  3.3474037235768725
# RUN  9 , total integrated cost =  3.3474033692083998
# RUN  10 , total integrated cost =  3.3474030034442577
# RUN  11 , total integrated cost =  3.347402648780679
# RUN  12 , total integrated cost =  3.347402285946298
# RUN  13 , total integrated cost =  3.347401932743486
# RUN  14 , total integrated cost =  3.347401572300384
# RUN  15 , total integrated cost =  3.347401220872351
# RUN  16 , total integrated cost =  3.3474008624435214
# RUN  17 , total integrated cost =  3.347400513005949
# RUN  18 , total integrated cost =  3.3474001563258797
# RUN  19 , total integrated cost =  3.3473998090261525
# RUN  20 , total integrated cost =  3.3473994539067338
# RUN  30 , total integrated cost =  3.347395994723111
# RUN  40 , total integrated cost =  3.347392621352757
# RUN  50 , total integrated cost =  3.3473893318323378
# RUN  60 , total integrated cost =  3.347386327765991
# RUN  70 , total integrated cost =  3.3473832958471763
# RUN  80 , total integrated cost =  3.347379676825585
# RUN  90 , total integrated cost =  3.347376136341799
# RUN  100 , total integrated cost =  3.347372688416415
# RUN  110 , total integrated cost =  3.3473693230171366
# RUN  120 , total integrated cost =  3.3473656547397472
# RUN  130 , total integrated cost =  3.3473356743717875
# RUN  140 , total integrated cost =  3.3472691676571698
# RUN  150 , total integrated cost =  3.347257116455741
# RUN  160 , total integrated cost =  3.34725484140454
# RUN  170 , total integrated cost =  3.347252490627725
# RUN  180 , total integrated cost =  3.3471715367162513
# RUN  190 , total integrated cost =  3.347170920663024
# RUN  200 , total integrated cost =  3.3471664942423343
# RUN  300 , total integrated cost =  3.346548970385717
# RUN  400 , total integrated cost =  3.3464669339608335
# RUN  500 , total integrated cost =  3.346275463328046
# RUN  600 , total integrated cost =  3.3462506720911933
# Control only changes marginally.
# RUN  629 , total integrated cost =  3.3462461478290852
# Improved over  629  iterations in  83.72261956600414  seconds by  0.04612372516447749  percent.
# 0.027865827046556203 [5.01277334e-09 3.34485285e+00]
# ----- 3430
# set cost params:  0.05 0.0 1.0
# 0.4420131291028446 0.5277083333333333
# shift ind =  0
# interpolate adjoint :  True True True
# initial cost =  3.3478744352352514
# RUN  0 , total integrated cost =  3.3478744352352514
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.347492704460364
# RUN  2 , total integrated cost =  3.347492125877808
# RUN  3 , total integrated cost =  3.347491615154899
# RUN  4 , total integrated cost =  3.3474910721278124
# RUN  5 , total integrated cost =  3.347490548455152
# RUN  6 , total integrated cost =  3.347490026601794
# RUN  7 , total integrated cost =  3.3474894968830813
# RUN  8 , total integrated cost =  3.3474889890124913
# RUN  9 , total integrated cost =  3.3474884565344154
# RUN  10 , total integrated cost =  3.347487860446619
# RUN  11 , total integrated cost =  3.347487382075192
# RUN  12 , total integrated cost =  3.3474868862171685
# RUN  13 , total integrated cost =  3.3474863588818735
# RUN  14 , total integrated cost =  3.3474857745812447
# RUN  15 , total integrated cost =  3.3474853028396745
# RUN  16 , total integrated cost =  3.347484814889718
# RUN  17 , total integrated cost =  3.3474842969164214
# RUN  18 , total integrated cost =  3.34748371948172
# RUN  19 , total integrated cost =  3.3474832555952316
# RUN  20 , total integrated cost =  3.3474827738822994
# RUN  30 , total integrated cost =  3.347477873527278
# RUN  40 , total integrated cost =  3.3474732065917654
# RUN  50 , total integrated cost =  3.3474687129281904
# RUN  60 , total integrated cost =  3.347464375620837
# RUN  70 , total integrated cost =  3.347460912178226
# RUN  80 , total integrated cost =  3.3474580958350106
# RUN  90 , total integrated cost =  3.3474552416231838
# RUN  100 , total integrated cost =  3.3474523571156944
# RUN  110 , total integrated cost =  3.3474495599589504
# RUN  120 , total integrated cost =  3.347446477573412
# RUN  130 , total integrated cost =  3.347443484219177
# RUN  140 , total integrated cost =  3.3474405609136353
# RUN  150 , total integrated cost =  3.347437699136153
# RUN  160 , total integrated cost =  3.3474348948635373
# RUN  170 , total integrated cost =  3.3474321621070717
# RUN  180 , total integrated cost =  3.3474294914802307
# RUN  190 , total integrated cost =  3.347426894900514
# RUN  200 , total integrated cost =  3.3474243596687643
# RUN  300 , total integrated cost =  3.3471341092553946
# RUN  400 , total integrated cost =  3.347120821934383
# RUN  500 , total integrated cost =  3.3465349701484057
# RUN  600 , total integrated cost =  3.3463943338974875
# RUN  700 , total integrated cost =  3.346332479129914
# RUN  800 , total integrated cost =  3.346297592214318
# RUN  900 , total integrated cost =  3.34627743273236
# RUN  1000 , total integrated cost =  3.346264070292315
# RUN  1000 , total integrated cost =  3.346264070292315
# Improved over  1000  iterations in  133.952948835009  seconds by  0.04810111532223971  percent.
# 0.02744083878832668 [5.01277189e-09 3.34489202e+00]
# go back to ----- 3430
# ----- 3430
# set cost params:  0.05 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.346264070292315
# RUN  0 , total integrated cost =  3.346264070292315
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.3462640083793413
# RUN  2 , total integrated cost =  3.3462639478848364
# RUN  3 , total integrated cost =  3.3462638869876047
# RUN  4 , total integrated cost =  3.3462638267430704
# RUN  5 , total integrated cost =  3.346263765789979
# RUN  6 , total integrated cost =  3.3462637057607063
# RUN  7 , total integrated cost =  3.3462636452515353
# RUN  8 , total integrated cost =  3.346263585437769
# RUN  9 , total integrated cost =  3.346263525310976
# RUN  10 , total integrated cost =  3.346263465713617
# RUN  11 , total integrated cost =  3.346263405924838
# RUN  12 , total integrated cost =  3.346263346544848
# RUN  13 , total integrated cost =  3.346263287061742
# RUN  14 , total integrated cost =  3.3462632279048043
# RUN  15 , total integrated cost =  3.3462631686914706
# RUN  16 , total integrated cost =  3.34626310973309
# RUN  17 , total integrated cost =  3.3462630489967267
# RUN  18 , total integrated cost =  3.3462629894247584
# RUN  19 , total integrated cost =  3.346262927477887
# RUN  20 , total integrated cost =  3.346262868678141
# RUN  30 , total integrated cost =  3.3462622827463226
# RUN  40 , total integrated cost =  3.3462617035967566
# RUN  50 , total integrated cost =  3.3462611247471727
# RUN  60 , total integrated cost =  3.3462605381709554
# RUN  70 , total integrated cost =  3.346259964108481
# RUN  80 , total integrated cost =  3.346259399069837
# RUN  90 , total integrated cost =  3.346258837252654
# RUN  100 , total integrated cost =  3.346258281552537
# RUN  110 , total integrated cost =  3.3462576857566395
# RUN  120 , total integrated cost =  3.346256753295388
# RUN  130 , total integrated cost =  3.346254466247229
# RUN  140 , total integrated cost =  3.3462384608375757
# RUN  150 , total integrated cost =  3.346238043802402
# RUN  160 , total integrated cost =  3.346237626694617
# RUN  170 , total integrated cost =  3.3462372154729287
# RUN  180 , total integrated cost =  3.3462368112674428
# RUN  190 , total integrated cost =  3.3462364024979245
# RUN  200 , total integrated cost =  3.346235853282213
# Control only changes marginally.
# RUN  244 , total integrated cost =  3.346229174288032
# Improved over  244  iterations in  35.81355981298839  seconds by  0.0010428347419662032  percent.
# 0.027639656797389545 [5.01277189e-09 3.34484719e+00]
# ----- 3440
# set cost params:  0.05 0.0 1.0
# 0.4371785451873622 0.5277083333333333
# shift ind =  0
# interpolate adjoint :  True True True
# initial cost =  3.3478509491102617
# RUN  0 , total integrated cost =  3.3478509491102617
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.3474702284791547
# RUN  2 , total integrated cost =  3.347469408884943
# RUN  3 , total integrated cost =  3.3474686154970037
# RUN  4 , total integrated cost =  3.347467805477553
# RUN  5 , total integrated cost =  3.347467030043556
# RUN  6 , total integrated cost =  3.3474662198502436
# RUN  7 , total integrated cost =  3.3474654622968227
# RUN  8 , total integrated cost =  3.3474646517936644
# RUN  9 , total integrated cost =  3.3474639119242244
# RUN  10 , total integrated cost =  3.3474631011015132
# RUN  11 , total integrated cost =  3.347462378145972
# RUN  12 , total integrated cost =  3.347461671373574
# RUN  13 , total integrated cost =  3.3474612458550794
# RUN  14 , total integrated cost =  3.3474607899838085
# RUN  15 , total integrated cost =  3.347460121482877
# RUN  16 , total integrated cost =  3.3474593813090054
# RUN  17 , total integrated cost =  3.3474586536354263
# RUN  18 , total integrated cost =  3.347457888765095
# RUN  19 , total integrated cost =  3.3474571956042003
# RUN  20 , total integrated cost =  3.3474565119829265
# RUN  30 , total integrated cost =  3.3474514161750077
# RUN  40 , total integrated cost =  3.347446272742625
# RUN  50 , total integrated cost =  3.3474415479674735
# RUN  60 , total integrated cost =  3.347437000666778
# RUN  70 , total integrated cost =  3.347432705101416
# RUN  80 , total integrated cost =  3.34742864907166
# RUN  90 , total integrated cost =  3.3474247428332227
# RUN  100 , total integrated cost =  3.347421083691635
# RUN  110 , total integrated cost =  3.347417590314182
# RUN  120 , total integrated cost =  3.347414317866401
# RUN  130 , total integrated cost =  3.3474111578601593
# RUN  140 , total integrated cost =  3.347408203122976
# RUN  150 , total integrated cost =  3.3474053204551586
# RUN  160 , total integrated cost =  3.347402616497566
# RUN  170 , total integrated cost =  3.347399974083247
# RUN  180 , total integrated cost =  3.3473974928305075
# RUN  190 , total integrated cost =  3.34739498463029
# RUN  200 , total integrated cost =  3.3473926407501486
# RUN  300 , total integrated cost =  3.347351169725242
# RUN  400 , total integrated cost =  3.3471955174788235
# RUN  500 , total integrated cost =  3.346519521437106
# RUN  600 , total integrated cost =  3.346430921685337
# RUN  700 , total integrated cost =  3.34640442440479
# Control only changes marginally.
# RUN  704 , total integrated cost =  3.3464043450342182
# Improved over  704  iterations in  93.70461144798901  seconds by  0.04320993072968804  percent.
# 0.027854868525641483 [5.01277016e-09 3.34501160e+00]
# ----- 3450
# set cost params:  0.05 0.0 1.0
# 0.43375277572168763 0.5277083333333333
# shift ind =  0
# interpolate adjoint :  True True True
# initial cost =  3.348037727594207
# RUN  0 , total integrated cost =  3.348037727594207
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.3476545397816313
# RUN  2 , total integrated cost =  3.3476538452498006
# RUN  3 , total integrated cost =  3.3476534117200796
# RUN  4 , total integrated cost =  3.347652974454844
# RUN  5 , total integrated cost =  3.347652605191328
# RUN  6 , total integrated cost =  3.3476522356146066
# RUN  7 , total integrated cost =  3.347651899862842
# RUN  8 , total integrated cost =  3.347651566926081
# RUN  9 , total integrated cost =  3.347651249201929
# RUN  10 , total integrated cost =  3.3476509226796143
# RUN  11 , total integrated cost =  3.3476506082429167
# RUN  12 , total integrated cost =  3.3476502819989697
# RUN  13 , total integrated cost =  3.347649970169984
# RUN  14 , total integrated cost =  3.3476496450115736
# RUN  15 , total integrated cost =  3.3476493349676057
# RUN  16 , total integrated cost =  3.3476490108865726
# RUN  17 , total integrated cost =  3.347648702620897
# RUN  18 , total integrated cost =  3.347648379609172
# RUN  19 , total integrated cost =  3.347648072948728
# RUN  20 , total integrated cost =  3.347647742873426
# RUN  30 , total integrated cost =  3.347643902802126
# RUN  40 , total integrated cost =  3.3476400725960462
# RUN  50 , total integrated cost =  3.3476359025234186
# RUN  60 , total integrated cost =  3.347627179468501
# RUN  70 , total integrated cost =  3.3476189954034608
# RUN  80 , total integrated cost =  3.3476112430034175
# RUN  90 , total integrated cost =  3.3475872557855966
# RUN  100 , total integrated cost =  3.3475600561460137
# RUN  110 , total integrated cost =  3.347555812893346
# RUN  120 , total integrated cost =  3.347524339240084
# RUN  130 , total integrated cost =  3.347515043708764
# RUN  140 , total integrated cost =  3.3474826697783886
# RUN  150 , total integrated cost =  3.3474787228633915
# RUN  160 , total integrated cost =  3.3474223775325496
# RUN  170 , total integrated cost =  3.3473217149334134
# RUN  180 , total integrated cost =  3.3471827445445874
# RUN  190 , total integrated cost =  3.3471783816153082
# RUN  200 , total integrated cost =  3.3470380921746283
# Control only changes marginally.
# RUN  283 , total integrated cost =  3.3468225748584395
# Improved over  283  iterations in  38.59573777299374  seconds by  0.03629447558944321  percent.
# 0.02871005945816673 [5.01276810e-09 3.34538707e+00]
# ----- 3460
# set cost params:  0.05 0.0 1.0
# 0.4317673378076063 0.5277083333333333
# shift ind =  0
# interpolate adjoint :  True True True
# initial cost =  3.3485032039942224
# RUN  0 , total integrated cost =  3.3485032039942224
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.3481081346942325
# RUN  2 , total integrated cost =  3.3481074960739585
# RUN  3 , total integrated cost =  3.3481069331515174
# RUN  4 , total integrated cost =  3.348106359988978
# RUN  5 , total integrated cost =  3.3481058450073524
# RUN  6 , total integrated cost =  3.348105231411066
# RUN  7 , total integrated cost =  3.348104661221437
# RUN  8 , total integrated cost =  3.348104110639319
# RUN  9 , total integrated cost =  3.34810358842369
# RUN  10 , total integrated cost =  3.3481030026164404
# RUN  11 , total integrated cost =  3.3481024215289676
# RUN  12 , total integrated cost =  3.348101300208767
# RUN  13 , total integrated cost =  3.3481001697598924
# RUN  14 , total integrated cost =  3.348096239065915
# RUN  15 , total integrated cost =  3.348092008372928
# RUN  16 , total integrated cost =  3.3480802839085815
# RUN  17 , total integrated cost =  3.3480690224626657
# RUN  18 , total integrated cost =  3.348068281276754
# RUN  19 , total integrated cost =  3.348067417131945
# RUN  20 , total integrated cost =  3.348066548238993
# RUN  30 , total integrated cost =  3.3480581785098655
# RUN  40 , total integrated cost =  3.3480505099220403
# RUN  50 , total integrated cost =  3.3480430256539364
# RUN  60 , total integrated cost =  3.348038601287988
# RUN  70 , total integrated cost =  3.3480351013169747
# RUN  80 , total integrated cost =  3.3480318965865785
# RUN  90 , total integrated cost =  3.348029577812128
# RUN  100 , total integrated cost =  3.348024994710603
# RUN  110 , total integrated cost =  3.348020140169299
# RUN  120 , total integrated cost =  3.3479779687477147
# RUN  130 , total integrated cost =  3.347976326204045
# RUN  140 , total integrated cost =  3.3479475687032503
# RUN  150 , total integrated cost =  3.347832993048435
# RUN  160 , total integrated cost =  3.3478269329394887
# RUN  170 , total integrated cost =  3.3478155298879924
# RUN  180 , total integrated cost =  3.34778787845816
# RUN  190 , total integrated cost =  3.347783948551742
# RUN  200 , total integrated cost =  3.347779463766395
# RUN  300 , total integrated cost =  3.3475328475097714
# RUN  400 , total integrated cost =  3.3471658276683742
# Control only changes marginally.
# RUN  489 , total integrated cost =  3.34700884266934
# Improved over  489  iterations in  73.18693762899784  seconds by  0.0446277406305029  percent.
# 0.028626994091224597 [5.01276565e-09 3.34557749e+00]
# ----- 3470
# set cost params:  0.05 0.0 1.0
# 0.42824943651389935 0.5277083333333333
# shift ind =  0
# interpolate adjoint :  True True True
# initial cost =  3.3486895192434334
# RUN  0 , total integrated cost =  3.3486895192434334
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.3482967992833452
# RUN  2 , total integrated cost =  3.348296282530932
# RUN  3 , total integrated cost =  3.348295861097316
# RUN  4 , total integrated cost =  3.3482951230624134
# RUN  5 , total integrated cost =  3.3482944455090253
# RUN  6 , total integrated cost =  3.348293588605619
# RUN  7 , total integrated cost =  3.348292746835263
# RUN  8 , total integrated cost =  3.3482903070718892
# RUN  9 , total integrated cost =  3.348287825322929
# RUN  10 , total integrated cost =  3.348286098525271
# RUN  11 , total integrated cost =  3.348284572077809
# RUN  12 , total integrated cost =  3.3482828266501987
# RUN  13 , total integrated cost =  3.3482809963058253
# RUN  14 , total integrated cost =  3.348279146979606
# RUN  15 , total integrated cost =  3.348277149215979
# RUN  16 , total integrated cost =  3.3482754245254527
# RUN  17 , total integrated cost =  3.3482737705718315
# RUN  18 , total integrated cost =  3.3482722798309923
# RUN  19 , total integrated cost =  3.348270829814338
# RUN  20 , total integrated cost =  3.3482694889909976
# RUN  30 , total integrated cost =  3.3482245586612343
# RUN  40 , total integrated cost =  3.3481847169317605
# RUN  50 , total integrated cost =  3.34810402541615
# RUN  60 , total integrated cost =  3.34810245258059
# RUN  70 , total integrated cost =  3.348089170542219
# RUN  80 , total integrated cost =  3.3480763537482185
# RUN  90 , total integrated cost =  3.3480716389792327
# RUN  100 , total integrated cost =  3.348070980589049
# RUN  110 , total integrated cost =  3.3480703439179984
# RUN  120 , total integrated cost =  3.348069724332244
# RUN  130 , total integrated cost =  3.3480691227820274
# RUN  140 , total integrated cost =  3.3480685375291928
# RUN  150 , total integrated cost =  3.3480678451590746
# RUN  160 , total integrated cost =  3.348066906899995
# RUN  170 , total integrated cost =  3.3480660906830564
# RUN  180 , total integrated cost =  3.3480652120940353
# RUN  190 , total integrated cost =  3.348062426506407
# RUN  200 , total integrated cost =  3.3480614200351106
# RUN  300 , total integrated cost =  3.348046372014085
# Control only changes marginally.
# RUN  371 , total integrated cost =  3.3479525602327653
# Improved over  371  iterations in  64.14035102300113  seconds by  0.022007385469251517  percent.
# 0.030459657819766253 [5.01276272e-09 3.34642957e+00]
# ----- 3480
# set cost params:  0.05 0.0 1.0
# 0.4299772899318698 0.5277083333333333
# shift ind =  0
# interpolate adjoint :  True True True
# initial cost =  3.349740437492262
# RUN  0 , total integrated cost =  3.349740437492262
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.3493225356264476
# RUN  2 , total integrated cost =  3.3493216318847323
# RUN  3 , total integrated cost =  3.349321184109411
# RUN  4 , total integrated cost =  3.349320699844267
# RUN  5 , total integrated cost =  3.3493203143405785
# RUN  6 , total integrated cost =  3.3493198883838717
# RUN  7 , total integrated cost =  3.3493195240354314
# RUN  8 , total integrated cost =  3.3493191061246375
# RUN  9 , total integrated cost =  3.3493187367519845
# RUN  10 , total integrated cost =  3.3493183157768844
# RUN  11 , total integrated cost =  3.349317922362073
# RUN  12 , total integrated cost =  3.349317486679049
# RUN  13 , total integrated cost =  3.3493170751644095
# RUN  14 , total integrated cost =  3.3493165755150227
# RUN  15 , total integrated cost =  3.349316105516808
# RUN  16 , total integrated cost =  3.34931548917239
# RUN  17 , total integrated cost =  3.3493149044899053
# RUN  18 , total integrated cost =  3.349313895604057
# RUN  19 , total integrated cost =  3.349313013254907
# RUN  20 , total integrated cost =  3.3493095009305
# RUN  30 , total integrated cost =  3.3492727318938917
# RUN  40 , total integrated cost =  3.3492613340627537
# RUN  50 , total integrated cost =  3.349247423239549
# RUN  60 , total integrated cost =  3.349244223938104
# RUN  70 , total integrated cost =  3.3492368420828056
# RUN  80 , total integrated cost =  3.349234637849888
# RUN  90 , total integrated cost =  3.349211868137395
# RUN  100 , total integrated cost =  3.3491262131712176
# RUN  110 , total integrated cost =  3.349125162826001
# RUN  120 , total integrated cost =  3.34911708483974
# RUN  130 , total integrated cost =  3.349115723330851
# RUN  140 , total integrated cost =  3.3491095196811558
# RUN  150 , total integrated cost =  3.349107614180751
# RUN  160 , total integrated cost =  3.3491029681576023
# RUN  170 , total integrated cost =  3.3490984892811455
# RUN  180 , total integrated cost =  3.3490954573353187
# RUN  190 , total integrated cost =  3.3490906858871403
# RUN  200 , total integrated cost =  3.3490838534641023
# RUN  300 , total integrated cost =  3.349054984759384
# RUN  400 , total integrated cost =  3.3487921726341146
# Control only changes marginally.
# RUN  487 , total integrated cost =  3.348716465925996
# Improved over  487  iterations in  70.07044122400112  seconds by  0.03056868391368539  percent.
# 0.03189272339989502 [5.01275923e-09 3.34712182e+00]
# ----- 3490
# set cost params:  0.05 0.0 1.0
# 0.4302059496567506 0.5277083333333333
# shift ind =  0
# interpolate adjoint :  True True True
# initial cost =  3.3505886908672524
# RUN  0 , total integrated cost =  3.3505886908672524
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.350149669385514
# RUN  2 , total integrated cost =  3.350147878095033
# RUN  3 , total integrated cost =  3.350145729307165
# RUN  4 , total integrated cost =  3.350145313060585
# RUN  5 , total integrated cost =  3.3501447673519285
# RUN  6 , total integrated cost =  3.350144418562286
# RUN  7 , total integrated cost =  3.3501438665092693
# RUN  8 , total integrated cost =  3.3501434562054753
# RUN  9 , total integrated cost =  3.350142348091151
# RUN  10 , total integrated cost =  3.350141392652986
# RUN  11 , total integrated cost =  3.3501403197071915
# RUN  12 , total integrated cost =  3.3501393420951415
# RUN  13 , total integrated cost =  3.3501383366727544
# RUN  14 , total integrated cost =  3.350137425097745
# RUN  15 , total integrated cost =  3.350136388937095
# RUN  16 , total integrated cost =  3.3501354233088962
# RUN  17 , total integrated cost =  3.350134461530501
# RUN  18 , total integrated cost =  3.3501335513207846
# RUN  19 , total integrated cost =  3.3501325687017665
# RUN  20 , total integrated cost =  3.3501315960955513
# RUN  30 , total integrated cost =  3.3500685471483793
# RUN  40 , total integrated cost =  3.350053037331669
# RUN  50 , total integrated cost =  3.3500390450022333
# RUN  60 , total integrated cost =  3.350028029272463
# RUN  70 , total integrated cost =  3.3500233768431347
# RUN  80 , total integrated cost =  3.3499676210560794
# RUN  90 , total integrated cost =  3.3499647659059093
# RUN  100 , total integrated cost =  3.34990603427681
# RUN  110 , total integrated cost =  3.349902063047377
# RUN  120 , total integrated cost =  3.349901204467173
# RUN  130 , total integrated cost =  3.349717685908965
# RUN  140 , total integrated cost =  3.349704996158271
# RUN  150 , total integrated cost =  3.3496144316132677
# RUN  160 , total integrated cost =  3.3496093540803598
# RUN  170 , total integrated cost =  3.3496042309425684
# RUN  180 , total integrated cost =  3.3495993211684025
# RUN  190 , total integrated cost =  3.349594783189048
# RUN  200 , total integrated cost =  3.3495900870341075
# RUN  300 , total integrated cost =  3.349533857461006
# RUN  400 , total integrated cost =  3.3494695760990605
# RUN  500 , total integrated cost =  3.349395992270379
# RUN  600 , total integrated cost =  3.348988348048046
# RUN  700 , total integrated cost =  3.348811050569664
# Control only changes marginally.
# ...
# RUN  8 , total integrated cost =  5.446514380773243
# RUN  9 , total integrated cost =  5.446512504954353
# RUN  10 , total integrated cost =  5.446510692468848
# RUN  11 , total integrated cost =  5.446508809525785
# RUN  12 , total integrated cost =  5.446506998622665
# RUN  13 , total integrated cost =  5.446505129567721
# RUN  14 , total integrated cost =  5.4465033247280425
# RUN  15 , total integrated cost =  5.446501464516063
# RUN  16 , total integrated cost =  5.446499676473192
# RUN  17 , total integrated cost =  5.446497811713157
# RUN  18 , total integrated cost =  5.446496022306187
# RUN  19 , total integrated cost =  5.446494144115999
# RUN  20 , total integrated cost =  5.446492254877069
# RUN  30 , total integrated cost =  5.446471899805907
# RUN  40 , total integrated cost =  5.446454990449744
# RUN  50 , total integrated cost =  5.446438341401184
# RUN  60 , total integrated cost =  5.446422114663013
# RUN  70 , total integrated cost =  5.4464063919083445
# RUN  80 , total integrated cost =  5.446390837277175
# RUN  90 , total integrated cost =  5.446375569571698
# RUN  100 , total integrated cost =  5.44636055573747
# RUN  110 , total integrated cost =  5.446345755678911
# RUN  120 , total integrated cost =  5.446331163353857
# RUN  130 , total integrated cost =  5.4463169897908905
# RUN  140 , total integrated cost =  5.446303223078714
# RUN  150 , total integrated cost =  5.446289685004395
# RUN  160 , total integrated cost =  5.446276361331919
# RUN  170 , total integrated cost =  5.446263312167127
# RUN  180 , total integrated cost =  5.446250689734158
# RUN  190 , total integrated cost =  5.446238296424532
# RUN  200 , total integrated cost =  5.446226051764317
# RUN  300 , total integrated cost =  5.4461146779504634
# RUN  400 , total integrated cost =  5.446012258436021
# RUN  500 , total integrated cost =  5.445852674764798
# RUN  600 , total integrated cost =  5.445749971212191
# RUN  700 , total integrated cost =  5.445665602192526
# RUN  800 , total integrated cost =  5.445593955992411
# RUN  900 , total integrated cost =  5.445525924264349
# RUN  1000 , total integrated cost =  5.445457424084919
# RUN  1000 , total integrated cost =  5.445457424084919
# Improved over  1000  iterations in  49.00202028499916  seconds by  0.01970223210226152  percent.
# 0.38199177972084614 [1.43324546 3.99311237]
# go back to ----- 4630
# ----- 4630
# set cost params:  0.05 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  5.445457424084919
# RUN  0 , total integrated cost =  5.445457424084919
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.445456754225415
# RUN  2 , total integrated cost =  5.445456116022915
# RUN  3 , total integrated cost =  5.4454554468276255
# RUN  4 , total integrated cost =  5.445454809290056
# RUN  5 , total integrated cost =  5.445454140756307
# RUN  6 , total integrated cost =  5.445453503877888
# RUN  7 , total integrated cost =  5.445452836003023
# RUN  8 , total integrated cost =  5.44545219977852
# RUN  9 , total integrated cost =  5.445451532557655
# RUN  10 , total integrated cost =  5.445450896981403
# RUN  11 , total integrated cost =  5.445450230410972
# RUN  12 , total integrated cost =  5.445449595477424
# RUN  13 , total integrated cost =  5.445448929555008
# RUN  14 , total integrated cost =  5.445448295258988
# RUN  15 , total integrated cost =  5.445447629981936
# RUN  16 , total integrated cost =  5.44544699631831
# RUN  17 , total integrated cost =  5.445446331684049
# RUN  18 , total integrated cost =  5.445445698647838
# RUN  19 , total integrated cost =  5.445445034653806
# RUN  20 , total integrated cost =  5.445444402240138
# RUN  30 , total integrated cost =  5.445437938891608
# RUN  40 , total integrated cost =  5.44543150606686
# RUN  50 , total integrated cost =  5.445425102895252
# RUN  60 , total integrated cost =  5.445418728443069
# RUN  70 , total integrated cost =  5.445412382023775
# RUN  80 , total integrated cost =  5.445406063006329
# RUN  90 , total integrated cost =  5.445399808752469
# RUN  100 , total integrated cost =  5.445393624607838
# RUN  110 , total integrated cost =  5.445387479903532
# RUN  120 , total integrated cost =  5.44538137832991
# RUN  130 , total integrated cost =  5.445375295300017
# RUN  140 , total integrated cost =  5.4453692773023405
# RUN  150 , total integrated cost =  5.445363282629445
# RUN  160 , total integrated cost =  5.445357347464067
# RUN  170 , total integrated cost =  5.445351052972727
# RUN  180 , total integrated cost =  5.44534470334364
# RUN  190 , total integrated cost =  5.44534064479955
# RUN  200 , total integrated cost =  5.445336701895368
# RUN  300 , total integrated cost =  5.445300169455891
# RUN  400 , total integrated cost =  5.4452534330650355
# RUN  500 , total integrated cost =  5.445222056035247
# RUN  600 , total integrated cost =  5.445205447998312
# RUN  700 , total integrated cost =  5.445191188787015
# RUN  800 , total integrated cost =  5.4451776676883545
# RUN  900 , total integrated cost =  5.445164823467292
# RUN  1000 , total integrated cost =  5.445151003547625
# RUN  1000 , total integrated cost =  5.445151003547625
# Improved over  1000  iterations in  42.955601626992575  seconds by  0.00562708535629497  percent.
# 0.3745150620762331 [1.46043558 3.96598967]
# go back to ----- 4630
# ----- 4630
# set cost params:  0.05 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  5.445151003547625
# RUN  0 , total integrated cost =  5.445151003547625
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.445150870559452
# RUN  2 , total integrated cost =  5.445150768423884
# RUN  3 , total integrated cost =  5.445150630805301
# RUN  4 , total integrated cost =  5.445150486615189
# RUN  5 , total integrated cost =  5.445150353419201
# RUN  6 , total integrated cost =  5.445150251699987
# RUN  7 , total integrated cost =  5.445150113830213
# RUN  8 , total integrated cost =  5.445149969508523
# RUN  9 , total integrated cost =  5.445149829574726
# RUN  10 , total integrated cost =  5.445149694137721
# RUN  11 , total integrated cost =  5.445149551430209
# RUN  12 , total integrated cost =  5.445149403953673
# RUN  13 , total integrated cost =  5.4451492683739655
# RUN  14 , total integrated cost =  5.445149140025177
# RUN  15 , total integrated cost =  5.445149000019994
# RUN  16 , total integrated cost =  5.445148860574071
# RUN  17 , total integrated cost =  5.445148720726366
# RUN  18 , total integrated cost =  5.445148585656428
# RUN  19 , total integrated cost =  5.445148442642119
# RUN  20 , total integrated cost =  5.445148295658272
# RUN  30 , total integrated cost =  5.445146850613252
# RUN  40 , total integrated cost =  5.4451454106830015
# RUN  50 , total integrated cost =  5.44514398177623
# RUN  60 , total integrated cost =  5.4451425658035415
# RUN  70 , total integrated cost =  5.445141161556115
# RUN  80 , total integrated cost =  5.445139759962321
# RUN  90 , total integrated cost =  5.445138154003354
# RUN  100 , total integrated cost =  5.445136361314149
# RUN  110 , total integrated cost =  5.445134558792545
# RUN  120 , total integrated cost =  5.445132565462771
# RUN  130 , total integrated cost =  5.445130304078933
# RUN  140 , total integrated cost =  5.44512905671353
# RUN  150 , total integrated cost =  5.445127825290951
# RUN  160 , total integrated cost =  5.445126685250398
# RUN  170 , total integrated cost =  5.445125662349611
# RUN  180 , total integrated cost =  5.4451246646830205
# RUN  190 , total integrated cost =  5.445123579861853
# RUN  200 , total integrated cost =  5.4451225004630155
# RUN  300 , total integrated cost =  5.445112425356618
# RUN  400 , total integrated cost =  5.445101345179528
# RUN  500 , total integrated cost =  5.4450902165108435
# RUN  600 , total integrated cost =  5.445083409675555
# RUN  700 , total integrated cost =  5.445077750292596
# RUN  800 , total integrated cost =  5.445073707310151
# RUN  900 , total integrated cost =  5.445069848328083
# RUN  1000 , total integrated cost =  5.4450667436128874
# RUN  1000 , total integrated cost =  5.4450667436128874
# Improved over  1000  iterations in  48.539760542000295  seconds by  0.0015474306347584843  percent.
# 0.3710381819052986 [1.47436402 3.95215082]
# go back to ----- 4630
# ----- 4630
# set cost params:  0.05 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  5.4450667436128874
# RUN  0 , total integrated cost =  5.4450667436128874
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.445066715599088
# RUN  2 , total integrated cost =  5.445066689565541
# RUN  3 , total integrated cost =  5.44506666131114
# RUN  4 , total integrated cost =  5.4450666346702485
# RUN  5 , total integrated cost =  5.445066614436422
# RUN  6 , total integrated cost =  5.445066593450637
# RUN  7 , total integrated cost =  5.445066573153815
# RUN  8 , total integrated cost =  5.445066551518655
# RUN  9 , total integrated cost =  5.4450665316166775
# RUN  10 , total integrated cost =  5.445066510633841
# RUN  11 , total integrated cost =  5.445066490492017
# RUN  12 , total integrated cost =  5.445066468811449
# RUN  13 , total integrated cost =  5.445066448938385
# RUN  14 , total integrated cost =  5.445066427999523
# RUN  15 , total integrated cost =  5.445066407873336
# RUN  16 , total integrated cost =  5.445066386246245
# RUN  17 , total integrated cost =  5.445066366366432
# RUN  18 , total integrated cost =  5.445066345451675
# RUN  19 , total integrated cost =  5.445066325364375
# RUN  20 , total integrated cost =  5.445066303756204
# RUN  30 , total integrated cost =  5.445066098445823
# RUN  40 , total integrated cost =  5.445065892843017
# RUN  50 , total integrated cost =  5.445065688755586
# RUN  60 , total integrated cost =  5.445065484383416
# RUN  70 , total integrated cost =  5.44506528150093
# RUN  80 , total integrated cost =  5.445065078330165
# RUN  90 , total integrated cost =  5.445064876629567
# RUN  100 , total integrated cost =  5.445064674634637
# RUN  110 , total integrated cost =  5.4450644740937495
# RUN  120 , total integrated cost =  5.445064273250928
# RUN  130 , total integrated cost =  5.445064073848304
# RUN  140 , total integrated cost =  5.445063874154056
# RUN  150 , total integrated cost =  5.445063676162777
# RUN  160 , total integrated cost =  5.445063478207531
# RUN  170 , total integrated cost =  5.445063282007719
# RUN  180 , total integrated cost =  5.4450630858336035
# RUN  190 , total integrated cost =  5.445062891386812
# RUN  200 , total integrated cost =  5.4450626969563745
# RUN  300 , total integrated cost =  5.445060760769317
# RUN  400 , total integrated cost =  5.445058889150112
# RUN  500 , total integrated cost =  5.445057074153463
# RUN  600 , total integrated cost =  5.445054488917724
# RUN  700 , total integrated cost =  5.445052584843172
# RUN  800 , total integrated cost =  5.445050361943992
# RUN  900 , total integrated cost =  5.445048641087426
# RUN  1000 , total integrated cost =  5.445047273683141
# RUN  1000 , total integrated cost =  5.445047273683141
# Improved over  1000  iterations in  39.53527803799079  seconds by  0.0003575700843185814  percent.
# 0.3703565223267375 [1.4803751  3.94615435]
# go back to ----- 4630
# ----- 4630
# set cost params:  0.05 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  5.445047273683141
# RUN  0 , total integrated cost =  5.445047273683141
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.445047260318573
# RUN  2 , total integrated cost =  5.445047247584291
# RUN  3 , total integrated cost =  5.445047234264057
# RUN  4 , total integrated cost =  5.445047221568005
# RUN  5 , total integrated cost =  5.44504720829149
# RUN  6 , total integrated cost =  5.4450471956337845
# RUN  7 , total integrated cost =  5.445047182400401
# RUN  8 , total integrated cost =  5.445047169781142
# RUN  9 , total integrated cost =  5.445047156590355
# RUN  10 , total integrated cost =  5.4450471440096075
# RUN  11 , total integrated cost =  5.445047130857934
# RUN  12 , total integrated cost =  5.445047115628158
# RUN  13 , total integrated cost =  5.445047102192774
# RUN  14 , total integrated cost =  5.445047089619129
# RUN  15 , total integrated cost =  5.445047076575894
# RUN  16 , total integrated cost =  5.445047061435656
# RUN  17 , total integrated cost =  5.445047048110792
# RUN  18 , total integrated cost =  5.445047032911195
# RUN  19 , total integrated cost =  5.4450470196461085
# RUN  20 , total integrated cost =  5.4450470044856605
# RUN  30 , total integrated cost =  5.445046863953701
# RUN  40 , total integrated cost =  5.445046725924973
# RUN  50 , total integrated cost =  5.445046590289303
# RUN  60 , total integrated cost =  5.445046456975274
# RUN  70 , total integrated cost =  5.445046318820139
# RUN  80 , total integrated cost =  5.445046175590047
# RUN  90 , total integrated cost =  5.4450460313606515
# RUN  100 , total integrated cost =  5.445045889909654
# RUN  110 , total integrated cost =  5.445045751163612
# RUN  120 , total integrated cost =  5.445045615052631
# RUN  130 , total integrated cost =  5.445045481510211
# RUN  140 , total integrated cost =  5.445045350476562
# RUN  150 , total integrated cost =  5.445045221890329
# RUN  160 , total integrated cost =  5.445045095692097
# RUN  170 , total integrated cost =  5.445044965726709
# RUN  180 , total integrated cost =  5.4450448297773395
# RUN  190 , total integrated cost =  5.445044695917849
# RUN  200 , total integrated cost =  5.445044565279386
# RUN  300 , total integrated cost =  5.445043705648412
# Control only changes marginally.
# RUN  365 , total integrated cost =  5.445043042697005
# Improved over  365  iterations in  12.982260435004719  seconds by  7.770338663704024e-05  percent.
# 0.37025742496227676 [1.48216357 3.9443666 ]
# ----- 4640
# set cost params:  0.05 0.0 1.0
# 0.006211180124223602 0.5277083333333333
# shift ind =  0
# interpolate adjoint :  True True True
# initial cost =  8.07878660015404
# RUN  0 , total integrated cost =  8.07878660015404
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7.651135492430682
# RUN  2 , total integrated cost =  7.3368375522659175
# RUN  3 , total integrated cost =  7.0946564434767465
# RUN  4 , total integrated cost =  6.894422474730081
# RUN  5 , total integrated cost =  6.73102319506539
# RUN  6 , total integrated cost =  6.59007511933057
# RUN  7 , total integrated cost =  6.472958321048133
# RUN  8 , total integrated cost =  6.368899676360862
# RUN  9 , total integrated cost =  6.285716408415632
# RUN  10 , total integrated cost =  6.20878002963864
# RUN  11 , total integrated cost =  6.146851617751608
# RUN  12 , total integrated cost =  6.090211746910581
# RUN  13 , total integrated cost =  6.043238432069961
# RUN  14 , total integrated cost =  6.000436052915381
# RUN  15 , total integrated cost =  5.964730515885883
# RUN  16 , total integrated cost =  5.935860250291165
# RUN  17 , total integrated cost =  5.912220409504165
# RUN  18 , total integrated cost =  5.887171547256449
# RUN  19 , total integrated cost =  5.866314031500243
# RUN  20 , total integrated cost =  5.8457654553062985
# RUN  30 , total integrated cost =  5.760469371295216
# RUN  40 , total integrated cost =  5.73729068785661
# RUN  50 , total integrated cost =  5.728615158390252
# RUN  60 , total integrated cost =  5.7234558996375355
# RUN  70 , total integrated cost =  5.719361586348586
# RUN  80 , total integrated cost =  5.715807467714587
# RUN  90 , total integrated cost =  5.712617360117479
# RUN  100 , total integrated cost =  5.709965110537493
# RUN  110 , total integrated cost =  5.707533525533903
# RUN  120 , total integrated cost =  5.705160376858909
# RUN  130 , total integrated cost =  5.7030189920658625
# RUN  140 , total integrated cost =  5.700887844959721
# RUN  150 , total integrated cost =  5.698983950217469
# RUN  160 , total integrated cost =  5.696868130283821
# RUN  170 , total integrated cost =  5.695206588309717
# RUN  180 , total integrated cost =  5.693665790416424
# RUN  190 , total integrated cost =  5.6922223007173605
# RUN  200 , total integrated cost =  5.690880415563083
# RUN  300 , total integrated cost =  5.681018854734523
# RUN  400 , total integrated cost =  5.674277155395466
# RUN  500 , total integrated cost =  5.668768409532083
# RUN  600 , total integrated cost =  5.666871818478006
# RUN  700 , total integrated cost =  5.665576271454707

# %%
bestControl_maxW = np.array( [[None] * len(t_pen)] * len(exc) )
bestState_maxW = np.array( [[None] * len(t_pen)] * len(exc) )
cost_maxW = np.array( [[None] * len(t_pen)] * len(exc) )
costnode_maxW = np.array( [[None] * len(t_pen)] * len(exc) )
weights_maxW = np.array( [[None] * len(t_pen)] * len(exc) )
convergence_maxW = np.array( [[None] * len(t_pen)] * len(exc) )

file_maxW = 'down_Wmax.pickle'

# %%
if os.path.isfile(file_maxW) :
    print("file found")
    
    with open(file_maxW,'rb') as f:
        load_array = pickle.load(f)

    bestControl_maxW = load_array[0]
    bestState_maxW = load_array[1]
    cost_maxW = load_array[2]
    costnode_maxW = load_array[3]
    weights_maxW = load_array[4]
# Out:
# file found

# %%
tol = 1e-8

for i in i_range:
    print('------------', i)
    j = 0

    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.

    aln.params.duration = dur

    while not convergence_maxW[i][j]:
        dur = d_array[j]
        aln.params.duration = dur
        wp = 1. / (dur - t_pen[j] * dur)

        setinit(initVars[i], aln)

        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        control0 = aln.getZeroControl()
        if type(bestControl_maxW[i][j]) == type(None):
            max_it = 10
            control0 = bestControl_[i][0][:,:,n_pre-1:-n_post+1]
            weight_ = ( cost_uncontrolled[i] * (1. - t_pen[0]) / (1. - t_pen[j]) 
                       - wp * sum(costnode_[i][j][0][0][:]) ) / sum( costnode_[i][j][2][0][:] )
            cost.setParams(wp, weight_ * factor_we, weight_ * factor_ws)
            weights_maxW[i][j] = cost.getParams()
        else:
            control0 = bestControl_maxW[i][j][:,:,n_pre-1:-n_post+1]
            weight_ = ( cost_uncontrolled[i] * (1. - t_pen[0]) / (1. - t_pen[j])
                       - wp * sum(costnode_maxW[i][j][0][0][:]) ) / sum( costnode_maxW[i][j][2][0][:] )
            cost.setParams(wp, weight_ * factor_we, weight_ * factor_ws)
            weights_maxW[i][j] = cost.getParams()
            max_it = int(100)

        bestControl_maxW[i][j], bestState_maxW[i][j], cost_maxW[i][j], runtime_, grad_, phi_, phi1_, costnode_maxW[i][j] = aln.A1(
            control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
            prec_variables_ = p_var, transition_time_ = t_pen[j])

        if cost_maxW[i][j][2] == 0.:
            convergence_maxW[i][j] = True

        print('cost splitting : ', costnode_maxW[i][j][0][0][0], costnode_maxW[i][j][2][0][:2])

        with open(file_maxW,'wb') as f:
            pickle.dump([bestControl_maxW, bestState_maxW, cost_maxW, costnode_maxW, weights_maxW], f)
# Out:
# ------------ 0
# set cost params:  0.05 0.0 191.19657269555836
# interpolate adjoint :  True True True
# initial cost =  636.9058012469633
# RUN  0 , total integrated cost =  636.9058012469633
# Gradient descend method:  None
# RUN  1 , total integrated cost =  636.9058012469633
# Control only changes marginally.
# RUN  1 , total integrated cost =  636.9058012469633
# Improved over  1  iterations in  0.48827666499710176  seconds by  0.0  percent.
# cost splitting :  2.2385916167652766e-05 [1.25115182e-15 3.33115699e+00]

# %%
i=0
for j in range(0,4800,1):
    convergence_maxW[i][j] = None
    bestControl_maxW[i][j] = None

# %%
tol = 1e-8

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    j = 0
    step = step1

    k = 0
    
    ind_max_c = 1
    if i == 1:
        ind_max_c = 0

    while j < 4800:

        if j == 0:
            j += step
            continue
            
        if not convergence_maxW[i][j-step]:
            if j - step > 0:
                j -= step
                print('go back to -----', j)

        print('-----', j)
        
        if j >= 3000:
            step = step2
        if j >=4790:
            step = step3

        if convergence_maxW[i][j]:
            j += step
            continue

        dur = d_array[j]
        T = 5001 - j
        aln.params.duration = dur
        setinit(initVars[i], aln)
        wp = 1. / (dur - t_pen[j] * dur)

        max_it = 1000

        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        if type(bestControl_maxW[i][j]) == type(None):
            max_percent_prev = (np.argmax(np.abs(bestControl_maxW[i][j-step]), axis=2)[0,ind_max_c] - 100) / (T-200)
            shift_ind = 0
            print(max_percent_prev, max_percent[i])
            if j < 4000:
                while max_percent_prev > max_percent[i]:
                    shift_ind += 1
                    max_percent_prev = (np.argmax(np.abs(bestControl_maxW[i][j-step]), axis=2)[0,ind_max_c] - 100 - shift_ind) / (T-200)

            control0 = np.zeros(( bestControl_maxW[i][j-step][:,:,100:-(100+step)].shape ))
            print('shift ind = ', shift_ind)
            if shift_ind != 0:
                control0[:,:,:-shift_ind] = 1. * bestControl_maxW[i][j-step][:,:,100+shift_ind:-(100+step)]
            else:
                control0[:,:,:] = 1. * bestControl_maxW[i][j-step][:,:,100:-(100+step)]
                
            weight_ = ( cost_uncontrolled[i] * (1. - t_pen[0]) / (1. - t_pen[j])
                          - wp * sum(costnode_maxW[i][j-step][0][0][:]) ) / sum( costnode_maxW[i][j-step][2][0][:] )
        
        else:
            if bestControl_maxW[i][j].shape[2] == T+200:
                control0 = bestControl_maxW[i][j][:,:,100:-100]
                weight_ = ( cost_uncontrolled[i] * (1. - t_pen[0]) / (1. - t_pen[j])
                           - wp * sum(costnode_maxW[i][j][0][0][:]) ) / sum( costnode_maxW[i][j][2][0][:] )
            else:
                control0 = bestControl_maxW[i][j][:,:,100:-(100+j)]
                
                weight_ = ( cost_uncontrolled[i] * (1. - t_pen[0]) / (1. - t_pen[j])
                           - wp * sum(costnode_maxW[i][j][0][0][:]) ) / sum( costnode_maxW[i][j][2][0][:] )
             
        """
        if j >= 3800:
            if k == 0:
                weight_ *= 0.6
                max_it = 100
            elif k < 3:
                weight_ *= 0.8
                max_it = 100
            elif k < 5:
                weight_ *= 0.9
                max_it = 100
        """
            
            
        cost.setParams(wp, weight_ * factor_we, weight_ * factor_ws)
        weights_maxW[i][j] = cost.getParams()

        bestControl_maxW[i][j], bestState_maxW[i][j], cost_maxW[i][j], runtime_, grad_, phi_, phi1_, costnode_maxW[i][j] = aln.A1(
            control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
            prec_variables_ = p_var, transition_time_ = t_pen[j])
        
        k +=1

        print(costnode_maxW[i][j][0][0][:2], costnode_maxW[i][j][2][0][:2])

        if cost_maxW[i][j][2] == 0.:
            convergence_maxW[i][j] = True
            if j >= 3000:
                step = step2
            if j >=4790:
                step = step3

        with open(file_maxW,'wb') as f:
            pickle.dump([bestControl_maxW, bestState_maxW, cost_maxW, costnode_maxW, weights_maxW], f)

        j += step
# Out:
# -------  0 0.4500000000000001 0.4750000000000002
# ----- 100
# 0.5388215273346096 0.5277083333333333
# shift ind =  53
# set cost params:  0.05 0.0 187.3726411072434
# interpolate adjoint :  True True True
# initial cost =  624.1676938422187
# RUN  0 , total integrated cost =  624.1676938422187
# Gradient descend method:  None
# RUN  1 , total integrated cost =  624.1676938422187
# Control only changes marginally.
# RUN  1 , total integrated cost =  624.1676938422187
# Improved over  1  iterations in  0.48991678400489036  seconds by  0.0  percent.
# [0.00020332 0.        ] [1.25115182e-15 3.33115699e+00]
# ----- 200
# 0.5390132579873941 0.5277083333333333
# shift ind =  53
# set cost params:  0.05 0.0 183.54865520332118
# interpolate adjoint :  True True True
# initial cost =  611.4294775971925
# RUN  0 , total integrated cost =  611.4294775971925
# Gradient descend method:  None
# RUN  1 , total integrated cost =  611.4294052495654
# RUN  2 , total integrated cost =  611.4294052495654
# Control only changes marginally.
# RUN  2 , total integrated cost =  611.4294052495654
# Improved over  2  iterations in  0.9479176989989355  seconds by  1.1832538305611706e-05  percent.
# [0.00012107 0.        ] [7.03154802e-08 3.33115699e+00]
# go back to ----- 200
# ----- 200
# set cost params:  0.05 0.0 183.54867602185112
# interpolate adjoint :  True True True
# initial cost =  611.4294745993584
# RUN  0 , total integrated cost =  611.4294745993584
# Gradient descend method:  None
# RUN  1 , total integrated cost =  611.4294745993584
# Control only changes marginally.
# RUN  1 , total integrated cost =  611.4294745993584
# Improved over  1  iterations in  0.4457273979933234  seconds by  0.0  percent.
# [0.00012107 0.        ] [7.03154802e-08 3.33115699e+00]
# ----- 300
# 0.539213508109309 0.5277083333333333
# shift ind =  52
# set cost params:  0.05 0.0 179.72474451423176
# interpolate adjoint :  True True True
# initial cost =  598.6914090070956
# RUN  0 , total integrated cost =  598.6914090070956
# Gradient descend method:  None
# RUN  1 , total integrated cost =  598.6914090070956
# Control only changes marginally.
# RUN  1 , total integrated cost =  598.6914090070956
# Improved over  1  iterations in  0.5764979679952376  seconds by  0.0  percent.
# [0.00113833 0.        ] [7.03154802e-08 3.33115699e+00]
# ----- 400
# 0.5396500795273801 0.5277083333333333
# shift ind =  53
# set cost params:  0.05 0.0 175.90050762870288
# interpolate adjoint :  True True True
# initial cost =  585.9527274570755
# RUN  0 , total integrated cost =  585.9527274570755
# Gradient descend method:  None
# RUN  1 , total integrated cost =  585.95225376556
# RUN  2 , total integrated cost =  585.95225376556
# Control only changes marginally.
# RUN  2 , total integrated cost =  585.95225376556
# Improved over  2  iterations in  0.923218840995105  seconds by  8.084125106222473e-05  percent.
# [0.00017952 0.        ] [7.03154802e-08 3.33115714e+00]
# go back to ----- 400
# ----- 400
# set cost params:  0.05 0.0 175.90078753204622
# interpolate adjoint :  True True True
# initial cost =  585.9531861676012
# RUN  0 , total integrated cost =  585.9531861676012
# Gradient descend method:  None
# RUN  1 , total integrated cost =  585.9531861676012
# Control only changes marginally.
# RUN  1 , total integrated cost =  585.9531861676012
# Improved over  1  iterations in  0.46495889700599946  seconds by  0.0  percent.
# [0.00017952 0.        ] [7.03154802e-08 3.33115714e+00]
# ----- 500
# 0.5398744478028366 0.5277083333333333
# shift ind =  53
# set cost params:  0.05 0.0 172.07685619675144
# interpolate adjoint :  True True True
# initial cost =  573.2151411414308
# RUN  0 , total integrated cost =  573.2151411414308
# Gradient descend method:  None
# RUN  1 , total integrated cost =  573.2150939936604
# RUN  2 , total integrated cost =  573.2150939936604
# Control only changes marginally.
# RUN  2 , total integrated cost =  573.2150939936604
# Improved over  2  iterations in  0.9600809429975925  seconds by  8.225143929507794e-06  percent.
# [0.00026733 0.        ] [7.03154802e-08 3.33115726e+00]
# go back to ----- 500
# ----- 500
# set cost params:  0.05 0.0 172.07682386674986
# interpolate adjoint :  True True True
# initial cost =  573.2149862973387
# RUN  0 , total integrated cost =  573.2149862973387
# Gradient descend method:  None
# RUN  1 , total integrated cost =  573.2149862973387
# Control only changes marginally.
# RUN  1 , total integrated cost =  573.2149862973387
# Improved over  1  iterations in  0.5912362579983892  seconds by  0.0  percent.
# [0.00026733 0.        ] [7.03154802e-08 3.33115726e+00]
# ----- 600
# 0.5401094977386337 0.5277083333333333
# shift ind =  53
# set cost params:  0.05 0.0 168.25289266411417
# interpolate adjoint :  True True True
# initial cost =  560.4769761867262
# RUN  0 , total integrated cost =  560.4769761867262
# Gradient descend method:  None
# RUN  1 , total integrated cost =  560.4769040150944
# RUN  2 , total integrated cost =  560.4769040150944
# Control only changes marginally.
# RUN  2 , total integrated cost =  560.4769040150944
# Improved over  2  iterations in  0.8087069989996962  seconds by  1.2876823646479352e-05  percent.
# [0.00040231 0.        ] [7.03154802e-08 3.33115742e+00]
# go back to ----- 600
# ----- 600
# set cost params:  0.05 0.0 168.25284391230707
# interpolate adjoint :  True True True
# initial cost =  560.476741615147
# RUN  0 , total integrated cost =  560.476741615147
# Gradient descend method:  None
# RUN  1 , total integrated cost =  560.476741615147
# Control only changes marginally.
# RUN  1 , total integrated cost =  560.476741615147
# Improved over  1  iterations in  0.40102143699186854  seconds by  0.0  percent.
# [0.00040231 0.        ] [7.03154802e-08 3.33115742e+00]
# ----- 700
# 0.5403560107290905 0.5277083333333333
# shift ind =  52
# set cost params:  0.05 0.0 164.42891289674088
# interpolate adjoint :  True True True
# initial cost =  547.7387937624599
# RUN  0 , total integrated cost =  547.7387937624599
# Gradient descend method:  None
# RUN  1 , total integrated cost =  547.7386741699484
# RUN  2 , total integrated cost =  547.7386741699484
# Control only changes marginally.
# RUN  2 , total integrated cost =  547.7386741699484
# Improved over  2  iterations in  0.8568178529967554  seconds by  2.1833858198760936e-05  percent.
# [0.00055049 0.        ] [7.03154802e-08 3.33115767e+00]
# go back to ----- 700
# ----- 700
# set cost params:  0.05 0.0 164.42885592742664
# interpolate adjoint :  True True True
# initial cost =  547.738484396176
# RUN  0 , total integrated cost =  547.738484396176
# Gradient descend method:  None
# RUN  1 , total integrated cost =  547.738484396176
# Control only changes marginally.
# RUN  1 , total integrated cost =  547.738484396176
# Improved over  1  iterations in  0.3809224419965176  seconds by  0.0  percent.
# [0.00055049 0.        ] [7.03154802e-08 3.33115767e+00]
# ----- 800
# 0.540864783804049 0.5277083333333333
# shift ind =  53
# set cost params:  0.05 0.0 160.60492520225642
# interpolate adjoint :  True True True
# initial cost =  535.0005868828417
# RUN  0 , total integrated cost =  535.0005868828417
# Gradient descend method:  None
# RUN  1 , total integrated cost =  535.0004355571226
# RUN  2 , total integrated cost =  535.0004355571226
# Control only changes marginally.
# RUN  2 , total integrated cost =  535.0004355571226
# Improved over  2  iterations in  0.8569722899992485  seconds by  2.8285150108331436e-05  percent.
# [0.00072213 0.        ] [7.03154802e-08 3.33115804e+00]
# go back to ----- 800
# ----- 800
# set cost params:  0.05 0.0 160.6048559576121
# interpolate adjoint :  True True True
# initial cost =  535.0002048922639
# RUN  0 , total integrated cost =  535.0002048922639
# Gradient descend method:  None
# RUN  1 , total integrated cost =  535.0002048922639
# Control only changes marginally.
# RUN  1 , total integrated cost =  535.0002048922639
# Improved over  1  iterations in  0.5248192849976476  seconds by  0.0  percent.
# [0.00072213 0.        ] [7.03154802e-08 3.33115804e+00]
# ----- 900
# 0.5411432965906178 0.5277083333333333
# shift ind =  53
# set cost params:  0.05 0.0 156.78092565435628
# interpolate adjoint :  True True True
# initial cost =  522.2623756224469
# RUN  0 , total integrated cost =  522.2623756224469
# Gradient descend method:  None
# RUN  1 , total integrated cost =  522.2621833658253
# RUN  2 , total integrated cost =  522.2621833658253
# Control only changes marginally.
# RUN  2 , total integrated cost =  522.2621833658253
# Improved over  2  iterations in  0.8036872619995847  seconds by  3.681226728247111e-05  percent.
# [0.00102276 0.        ] [7.03154802e-08 3.33115855e+00]
# go back to ----- 900
# ----- 900
# set cost params:  0.05 0.0 156.78081142068095
# interpolate adjoint :  True True True
# initial cost =  522.2618028353329
# RUN  0 , total integrated cost =  522.2618028353329
# Gradient descend method:  None
# RUN  1 , total integrated cost =  522.2618028353329
# Control only changes marginally.
# RUN  1 , total integrated cost =  522.2618028353329
# Improved over  1  iterations in  0.520438136998564  seconds by  0.0  percent.
# [0.00102276 0.        ] [7.03154802e-08 3.33115855e+00]
# ----- 1000
# 0.5414364640883977 0.5277083333333333
# shift ind =  53
# set cost params:  0.05 0.0 152.95688170238293
# interpolate adjoint :  True True True
# initial cost =  509.5240930513305
# RUN  0 , total integrated cost =  509.5240930513305
# Gradient descend method:  None
# RUN  1 , total integrated cost =  509.5238194714672
# RUN  2 , total integrated cost =  509.5238194714672
# Control only changes marginally.
# RUN  2 , total integrated cost =  509.5238194714672
# Improved over  2  iterations in  0.8210110369982431  seconds by  5.369321431203389e-05  percent.
# [0.00148068 0.        ] [7.03154802e-08 3.33115927e+00]
# go back to ----- 1000
# ----- 1000
# set cost params:  0.05 0.0 152.9567111600892
# interpolate adjoint :  True True True
# initial cost =  509.5232513679123
# RUN  0 , total integrated cost =  509.5232513679123
# Gradient descend method:  None
# RUN  1 , total integrated cost =  509.5232513679123
# Control only changes marginally.
# RUN  1 , total integrated cost =  509.5232513679123
# Improved over  1  iterations in  0.4669518769951537  seconds by  0.0  percent.
# [0.00148068 0.        ] [7.03154802e-08 3.33115927e+00]
# ----- 1100
# 0.5417454741961631 0.5277083333333333
# shift ind =  52
# set cost params:  0.05 0.0 149.13278226876275
# interpolate adjoint :  True True True
# initial cost =  496.78575495348923
# RUN  0 , total integrated cost =  496.78575495348923
# Gradient descend method:  None
# RUN  1 , total integrated cost =  496.78532602123624
# RUN  2 , total integrated cost =  496.78532602123624
# Control only changes marginally.
# RUN  2 , total integrated cost =  496.78532602123624
# Improved over  2  iterations in  0.7953503320022719  seconds by  8.634149605768471e-05  percent.
# [0.00207812 0.        ] [7.03154801e-08 3.33116035e+00]
# go back to ----- 1100
# ----- 1100
# set cost params:  0.05 0.0 149.13255451867047
# interpolate adjoint :  True True True
# initial cost =  496.7845673491425
# RUN  0 , total integrated cost =  496.7845673491425
# Gradient descend method:  None
# RUN  1 , total integrated cost =  496.7845673491425
# Control only changes marginally.
# RUN  1 , total integrated cost =  496.7845673491425
# Improved over  1  iterations in  0.3569243450037902  seconds by  0.0  percent.
# [0.00207812 0.        ] [7.03154801e-08 3.33116035e+00]
# ----- 1200
# 0.542349347403499 0.5277083333333333
# shift ind =  53
# set cost params:  0.05 0.0 145.30862686839933
# interpolate adjoint :  True True True
# initial cost =  484.0472766316294
# RUN  0 , total integrated cost =  484.0472766316294
# Gradient descend method:  None
# RUN  1 , total integrated cost =  484.04671389877336
# RUN  2 , total integrated cost =  484.04671389877336
# Control only changes marginally.
# RUN  2 , total integrated cost =  484.04671389877336
# Improved over  2  iterations in  0.8266439430008177  seconds by  0.00011625576327389808  percent.
# [0.00280914 0.        ] [7.03154801e-08 3.33116191e+00]
# go back to ----- 1200
# ----- 1200
# set cost params:  0.05 0.0 145.30833944108602
# interpolate adjoint :  True True True
# initial cost =  484.0457564318348
# RUN  0 , total integrated cost =  484.0457564318348
# Gradient descend method:  None
# RUN  1 , total integrated cost =  484.0457564318348
# Control only changes marginally.
# RUN  1 , total integrated cost =  484.0457564318348
# Improved over  1  iterations in  0.36793547800334636  seconds by  0.0  percent.
# [0.00280914 0.        ] [7.03154801e-08 3.33116191e+00]
# ----- 1300
# 0.5427020851185376 0.5277083333333333
# shift ind =  53
# set cost params:  0.05 0.0 141.48441357974355
# interpolate adjoint :  True True True
# initial cost =  471.3087559423269
# RUN  0 , total integrated cost =  471.3087559423269
# Gradient descend method:  None
# RUN  1 , total integrated cost =  471.3080084817143
# RUN  2 , total integrated cost =  471.30800815257777
# RUN  3 , total integrated cost =  471.30800815257777
# Control only changes marginally.
# RUN  3 , total integrated cost =  471.30800815257777
# Improved over  3  iterations in  0.9466729639971163  seconds by  0.00015866239269257676  percent.
# [0.00398715 0.        ] [7.03154799e-08 3.33116410e+00]
# go back to ----- 1300
# ----- 1300
# set cost params:  0.05 0.0 141.4839671025538
# interpolate adjoint :  True True True
# initial cost =  471.3065208637616
# RUN  0 , total integrated cost =  471.3065208637616
# Gradient descend method:  None
# RUN  1 , total integrated cost =  471.3065208637616
# Control only changes marginally.
# RUN  1 , total integrated cost =  471.3065208637616
# Improved over  1  iterations in  0.3188464609993389  seconds by  0.0  percent.
# [0.00398715 0.        ] [7.03154799e-08 3.33116410e+00]
# ----- 1400
# 0.5430755660099971 0.5277083333333333
# shift ind =  53
# set cost params:  0.05 0.0 137.66004375045435
# interpolate adjoint :  True True True
# initial cost =  458.5699878838418
# RUN  0 , total integrated cost =  458.5699878838418
# Gradient descend method:  None
# RUN  1 , total integrated cost =  458.56891931835133
# RUN  2 , total integrated cost =  458.56891931835133
# Control only changes marginally.
# RUN  2 , total integrated cost =  458.56891931835133
# Improved over  2  iterations in  0.6889029090089025  seconds by  0.00023302124402846403  percent.
# [0.00566479 0.        ] [7.03154798e-08 3.33116723e+00]
# go back to ----- 1400
# ----- 1400
# set cost params:  0.05 0.0 137.65941074208718
# interpolate adjoint :  True True True
# initial cost =  458.56681066157876
# RUN  0 , total integrated cost =  458.56681066157876
# Gradient descend method:  None
# RUN  1 , total integrated cost =  458.56681066157876
# Control only changes marginally.
# RUN  1 , total integrated cost =  458.56681066157876
# Improved over  1  iterations in  0.32501668800250627  seconds by  0.0  percent.
# [0.00566479 0.        ] [7.03154798e-08 3.33116723e+00]
# ----- 1500
# 0.5434716752499242 0.5277083333333333
# shift ind =  53
# set cost params:  0.05 0.0 133.83549098421435
# interpolate adjoint :  True True True
# initial cost =  445.8309430725515
# RUN  0 , total integrated cost =  445.8309430725515
# Gradient descend method:  None
# RUN  1 , total integrated cost =  445.82941395128984
# RUN  2 , total integrated cost =  445.82941370380956
# RUN  3 , total integrated cost =  445.82941370380956
# Control only changes marginally.
# RUN  3 , total integrated cost =  445.82941370380956
# Improved over  3  iterations in  0.9088926490076119  seconds by  0.0003430378186379812  percent.
# [0.0078351 0.       ] [7.03154795e-08 3.33117179e+00]
# go back to ----- 1500
# ----- 1500
# set cost params:  0.05 0.0 133.8346560548363
# interpolate adjoint :  True True True
# initial cost =  445.8266324105572
# RUN  0 , total integrated cost =  445.8266324105572
# Gradient descend method:  None
# RUN  1 , total integrated cost =  445.8266324105572
# Control only changes marginally.
# RUN  1 , total integrated cost =  445.8266324105572
# Improved over  1  iterations in  0.4491194709989941  seconds by  0.0  percent.
# [0.0078351 0.       ] [7.03154795e-08 3.33117179e+00]
# ----- 1600
# 0.5438925335832552 0.5277083333333333
# shift ind =  52
# set cost params:  0.05 0.0 130.01074153737096
# interpolate adjoint :  True True True
# initial cost =  433.0917902149819
# RUN  0 , total integrated cost =  433.0917902149819
# Gradient descend method:  None
# RUN  1 , total integrated cost =  433.0895466346892
# RUN  2 , total integrated cost =  433.0895465047945
# RUN  3 , total integrated cost =  433.0895465047945
# Control only changes marginally.
# RUN  3 , total integrated cost =  433.0895465047945
# Improved over  3  iterations in  1.0975995780027006  seconds by  0.0005180680488763301  percent.
# [0.01101995 0.        ] [7.0315479e-08 3.3311785e+00]
# go back to ----- 1600
# ----- 1600
# set cost params:  0.05 0.0 130.00952390612005
# interpolate adjoint :  True True True
# initial cost =  433.0854903576707
# RUN  0 , total integrated cost =  433.0854903576707
# Gradient descend method:  None
# RUN  1 , total integrated cost =  433.0854903576707
# Control only changes marginally.
# RUN  1 , total integrated cost =  433.0854903576707
# Improved over  1  iterations in  0.3641025010001613  seconds by  0.0  percent.
# [0.01101995 0.        ] [7.0315479e-08 3.3311785e+00]
# ----- 1700
# 0.5446630119316349 0.5277083333333333
# shift ind =  53
# set cost params:  0.05 0.0 126.18561708172831
# interpolate adjoint :  True True True
# initial cost =  420.3517424815966
# RUN  0 , total integrated cost =  420.3517424815966
# Gradient descend method:  None
# RUN  1 , total integrated cost =  420.3487876034013
# RUN  2 , total integrated cost =  420.3487874240487
# RUN  3 , total integrated cost =  420.3487874240487
# Control only changes marginally.
# RUN  3 , total integrated cost =  420.3487874240487
# Improved over  3  iterations in  0.8447403729951475  seconds by  0.0007029963835663011  percent.
# [0.01537274 0.        ] [7.03154782e-08 3.33118797e+00]
# go back to ----- 1700
# ----- 1700
# set cost params:  0.05 0.0 126.18395141065255
# interpolate adjoint :  True True True
# initial cost =  420.343238760478
# RUN  0 , total integrated cost =  420.343238760478
# Gradient descend method:  None
# RUN  1 , total integrated cost =  420.343238760478
# Control only changes marginally.
# RUN  1 , total integrated cost =  420.343238760478
# Improved over  1  iterations in  0.3481388040090678  seconds by  0.0  percent.
# [0.01537274 0.        ] [7.03154782e-08 3.33118797e+00]
# ----- 1800
# 0.5451516161279574 0.5277083333333333
# shift ind =  53
# set cost params:  0.05 0.0 122.36005546515926
# interpolate adjoint :  True True True
# initial cost =  407.6112098069792
# RUN  0 , total integrated cost =  407.6112098069792
# Gradient descend method:  None
# RUN  1 , total integrated cost =  407.6070972282567
# RUN  2 , total integrated cost =  407.60709372731895
# RUN  3 , total integrated cost =  407.60709372731895
# Control only changes marginally.
# RUN  3 , total integrated cost =  407.60709372731895
# Improved over  3  iterations in  0.8789389980083797  seconds by  0.0010098053147800101  percent.
# [0.02143745 0.        ] [7.03154768e-08 3.33120161e+00]
# go back to ----- 1800
# ----- 1800
# set cost params:  0.05 0.0 122.3577341131923
# interpolate adjoint :  True True True
# initial cost =  407.5993608357557
# RUN  0 , total integrated cost =  407.5993608357557
# Gradient descend method:  None
# RUN  1 , total integrated cost =  407.5993608357557
# Control only changes marginally.
# RUN  1 , total integrated cost =  407.5993608357557
# Improved over  1  iterations in  0.291126604002784  seconds by  0.0  percent.
# [0.02143745 0.        ] [7.03154768e-08 3.33120161e+00]
# ----- 1900
# 0.5456739055498104 0.5277083333333333
# shift ind =  53
# set cost params:  0.05 0.0 118.53385381749969
# interpolate adjoint :  True True True
# initial cost =  394.86972180067926
# RUN  0 , total integrated cost =  394.86972180067926
# Gradient descend method:  None
# RUN  1 , total integrated cost =  394.8639917491553
# RUN  2 , total integrated cost =  394.8639916278521
# RUN  3 , total integrated cost =  394.8639916278521
# Control only changes marginally.
# RUN  3 , total integrated cost =  394.8639916278521
# Improved over  3  iterations in  0.9991516040026909  seconds by  0.001451155282566674  percent.
# [0.02990724 0.        ] [7.03154746e-08 3.33122121e+00]
# go back to ----- 1900
# ----- 1900
# set cost params:  0.05 0.0 118.53061369960471
# interpolate adjoint :  True True True
# initial cost =  394.85319807816984
# RUN  0 , total integrated cost =  394.85319807816984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  394.85319807816984
# Control only changes marginally.
# RUN  1 , total integrated cost =  394.85319807816984
# Improved over  1  iterations in  0.28188468000735156  seconds by  0.0  percent.
# [0.02990724 0.        ] [7.03154746e-08 3.33122121e+00]
# ----- 2000
# 0.5462334880399857 0.5277083333333333
# shift ind =  52
# set cost params:  0.05 0.0 114.70675590731892
# interpolate adjoint :  True True True
# initial cost =  382.1275146640842
# RUN  0 , total integrated cost =  382.1275146640842
# Gradient descend method:  None
# RUN  1 , total integrated cost =  382.11900365762165
# RUN  2 , total integrated cost =  382.1190031597582
# RUN  3 , total integrated cost =  382.1190031597582
# Control only changes marginally.
# RUN  3 , total integrated cost =  382.1190031597582
# Improved over  3  iterations in  0.8815419849997852  seconds by  0.002227398970063632  percent.
# [0.04190257 0.        ] [7.03154711e-08 3.33125017e+00]
# go back to ----- 2000
# ----- 2000
# set cost params:  0.05 0.0 114.70215790663367
# interpolate adjoint :  True True True
# initial cost =  382.1036860688765
# RUN  0 , total integrated cost =  382.1036860688765
# Gradient descend method:  None
# RUN  1 , total integrated cost =  382.1036860688765
# Control only changes marginally.
# RUN  1 , total integrated cost =  382.1036860688765
# Improved over  1  iterations in  0.3121048610046273  seconds by  0.0  percent.
# [0.04190257 0.        ] [7.03154711e-08 3.33125017e+00]
# ----- 2100
# 0.5472047389855609 0.5277083333333333
# shift ind =  53
# set cost params:  0.05 0.0 110.87833335537704
# interpolate adjoint :  True True True
# initial cost =  369.38208574007547
# RUN  0 , total integrated cost =  369.38208574007547
# Gradient descend method:  None
# RUN  1 , total integrated cost =  369.37093134522365
# RUN  2 , total integrated cost =  369.37092994637106
# RUN  3 , total integrated cost =  369.37092994637106
# Control only changes marginally.
# RUN  3 , total integrated cost =  369.37092994637106
# Improved over  3  iterations in  0.7268961560039315  seconds by  0.0030201231015496433  percent.
# [0.05835554 0.        ] [7.03154652e-08 3.33129109e+00]
# go back to ----- 2100
# ----- 2100
# set cost params:  0.05 0.0 110.87203229908985
# interpolate adjoint :  True True True
# initial cost =  369.3499392932386
# RUN  0 , total integrated cost =  369.3499392932386
# Gradient descend method:  None
# RUN  1 , total integrated cost =  369.3499392932386
# Control only changes marginally.
# RUN  1 , total integrated cost =  369.3499392932386
# Improved over  1  iterations in  0.3193172949977452  seconds by  0.0  percent.
# [0.05835554 0.        ] [7.03154652e-08 3.33129109e+00]
# ----- 2200
# 0.5478662053056517 0.5277083333333333
# shift ind =  53
# set cost params:  0.05 0.0 107.04825472344578
# interpolate adjoint :  True True True
# initial cost =  356.63478089970005
# RUN  0 , total integrated cost =  356.63478089970005
# Gradient descend method:  None
# RUN  1 , total integrated cost =  356.6192714490973
# RUN  2 , total integrated cost =  356.6192702244217
# RUN  3 , total integrated cost =  356.6192702244217
# Control only changes marginally.
# RUN  3 , total integrated cost =  356.6192702244217
# Improved over  3  iterations in  0.737911065996741  seconds by  0.004349176274729416  percent.
# [0.08108736 0.        ] [7.03154554e-08 3.33135005e+00]
# go back to ----- 2200
# ----- 2200
# set cost params:  0.05 0.0 107.03953675274073
# interpolate adjoint :  True True True
# initial cost =  356.5902276116968
# RUN  0 , total integrated cost =  356.5902276116968
# Gradient descend method:  None
# RUN  1 , total integrated cost =  356.5902276116968
# Control only changes marginally.
# RUN  1 , total integrated cost =  356.5902276116968
# Improved over  1  iterations in  0.3334717219986487  seconds by  0.0  percent.
# [0.08108736 0.        ] [7.03154554e-08 3.33135005e+00]
# ----- 2300
# 0.5485805677728909 0.5277083333333333
# shift ind =  53
# set cost params:  0.05 0.0 103.21582684403151
# interpolate adjoint :  True True True
# initial cost =  343.8839413018614
# RUN  0 , total integrated cost =  343.8839413018614
# Gradient descend method:  None
# RUN  1 , total integrated cost =  343.8624507719967
# RUN  2 , total integrated cost =  343.86244654432556
# RUN  3 , total integrated cost =  343.86244654432556
# Control only changes marginally.
# RUN  3 , total integrated cost =  343.86244654432556
# Improved over  3  iterations in  0.8922577550110873  seconds by  0.006250584849780694  percent.
# [0.11284837 0.        ] [7.03154393e-08 3.33143479e+00]
# go back to ----- 2300
# ----- 2300
# set cost params:  0.05 0.0 103.20366741857613
# interpolate adjoint :  True True True
# initial cost =  343.8219382104301
# RUN  0 , total integrated cost =  343.8219382104301
# Gradient descend method:  None
# RUN  1 , total integrated cost =  343.8219382104301
# Control only changes marginally.
# RUN  1 , total integrated cost =  343.8219382104301
# Improved over  1  iterations in  0.363095455992152  seconds by  0.0  percent.
# [0.11284837 0.        ] [7.03154393e-08 3.33143479e+00]
# ----- 2400
# 0.5493544356518117 0.5277083333333333
# shift ind =  52
# set cost params:  0.05 0.0 99.3800547807741
# interpolate adjoint :  True True True
# initial cost =  331.1302889751468
# RUN  0 , total integrated cost =  331.1302889751468
# Gradient descend method:  None
# RUN  1 , total integrated cost =  331.0985068325238
# RUN  2 , total integrated cost =  331.0985068325238
# Control only changes marginally.
# RUN  2 , total integrated cost =  331.0985068325238
# Improved over  2  iterations in  0.42919345099653583  seconds by  0.009598077760074375  percent.
# [0.15774498 0.        ] [7.03154134e-08 3.33155997e+00]
# go back to ----- 2400
# ----- 2400
# set cost params:  0.05 0.0 99.3628445680533
# interpolate adjoint :  True True True
# initial cost =  331.0411699754909
# RUN  0 , total integrated cost =  331.0411699754909
# Gradient descend method:  None
# RUN  1 , total integrated cost =  331.0411699754909
# Control only changes marginally.
# RUN  1 , total integrated cost =  331.0411699754909
# Improved over  1  iterations in  0.2598990449914709  seconds by  0.0  percent.
# [0.15774498 0.        ] [7.03154134e-08 3.33155997e+00]
# ----- 2500
# 0.5506301607996523 0.5277083333333333
# shift ind =  53
# set cost params:  0.05 0.0 95.53937559685552
# interpolate adjoint :  True True True
# initial cost =  318.3645654534614
# RUN  0 , total integrated cost =  318.3645654534614
# Gradient descend method:  None
# RUN  1 , total integrated cost =  318.3230314241638
# RUN  2 , total integrated cost =  318.3230195139405
# RUN  3 , total integrated cost =  318.3230195139405
# Control only changes marginally.
# RUN  3 , total integrated cost =  318.3230195139405
# Improved over  3  iterations in  0.6260648720053723  seconds by  0.013049800143974721  percent.
# [0.21845835 0.        ] [7.03153700e-08 3.33173718e+00]
# go back to ----- 2500
# ----- 2500
# set cost params:  0.05 0.0 95.51607133071366
# interpolate adjoint :  True True True
# initial cost =  318.2453758223326
# RUN  0 , total integrated cost =  318.2453758223326
# Gradient descend method:  None
# RUN  1 , total integrated cost =  318.2453758223326
# Control only changes marginally.
# RUN  1 , total integrated cost =  318.2453758223326
# Improved over  1  iterations in  0.38447321399871726  seconds by  0.0  percent.
# [0.21845835 0.        ] [7.03153700e-08 3.33173718e+00]
# ----- 2600
# 0.5515674693321218 0.5277083333333333
# shift ind =  53
# set cost params:  0.05 0.0 91.69280572141892
# interpolate adjoint :  True True True
# initial cost =  305.5920739451476
# RUN  0 , total integrated cost =  305.5920739451476
# Gradient descend method:  None
# RUN  1 , total integrated cost =  305.5348476908437
# RUN  2 , total integrated cost =  305.53483860914463
# RUN  3 , total integrated cost =  305.5348385994344
# RUN  4 , total integrated cost =  305.53483859686503
# RUN  5 , total integrated cost =  305.53483855569084
# RUN  6 , total integrated cost =  305.53483844366207
# RUN  7 , total integrated cost =  305.5348384375475
# RUN  8 , total integrated cost =  305.5348384344827
# RUN  9 , total integrated cost =  305.5348381429886
# RUN  10 , total integrated cost =  305.5348376665657
# RUN  11 , total integrated cost =  305.53483766172053
# RUN  12 , total integrated cost =  305.5348376583012
# RUN  13 , total integrated cost =  305.5348363487224
# RUN  14 , total integrated cost =  305.53483469822345
# RUN  15 , total integrated cost =  305.53483469586877
# RUN  16 , total integrated cost =  305.53483468228654
# RUN  17 , total integrated cost =  305.5348346049094
# RUN  18 , total integrated cost =  305.5348345873303
# RUN  19 , total integrated cost =  305.5348345849731
# RUN  20 , total integrated cost =  305.5348345719065
# RUN  30 , total integrated cost =  305.53483425154405
# RUN  40 , total integrated cost =  305.5348290145
# RUN  50 , total integrated cost =  305.5348237914143
# RUN  60 , total integrated cost =  305.5348227286013
# RUN  70 , total integrated cost =  305.5348222382149
# RUN  80 , total integrated cost =  305.53482095580074
# RUN  90 , total integrated cost =  305.5348205314677
# RUN  100 , total integrated cost =  305.5348200751221
# RUN  110 , total integrated cost =  305.5348165920194
# RUN  120 , total integrated cost =  305.534807033311
# RUN  130 , total integrated cost =  305.53480619736763
# RUN  140 , total integrated cost =  305.5348049585557
# RUN  150 , total integrated cost =  305.5348045863926
# RUN  160 , total integrated cost =  305.5347272326349
# Control only changes marginally.
# RUN  163 , total integrated cost =  305.5347271832369
# Improved over  163  iterations in  28.623862698004814  seconds by  0.01876578838265175  percent.
# [0.30080015 0.        ] [7.03152985e-08 3.33199184e+00]
# go back to ----- 2600
# ----- 2600
# set cost params:  0.05 0.0 91.66108519920297
# interpolate adjoint :  True True True
# initial cost =  305.42903465972637
# RUN  0 , total integrated cost =  305.42903465972637
# Gradient descend method:  None
# RUN  1 , total integrated cost =  305.42903465972637
# Control only changes marginally.
# RUN  1 , total integrated cost =  305.42903465972637
# Improved over  1  iterations in  0.2705038330022944  seconds by  0.0  percent.
# [0.30080015 0.        ] [7.03152985e-08 3.33199184e+00]
# ----- 2700
# 0.552594002855783 0.5277083333333333
# shift ind =  53
# set cost params:  0.05 0.0 87.83811180023885
# interpolate adjoint :  True True True
# initial cost =  292.8077912684112
# RUN  0 , total integrated cost =  292.8077912684112
# Gradient descend method:  None
# RUN  1 , total integrated cost =  292.72900761651465
# RUN  2 , total integrated cost =  292.72900409008986
# RUN  3 , total integrated cost =  292.7290040874888
# RUN  4 , total integrated cost =  292.7290040874888
# Control only changes marginally.
# RUN  4 , total integrated cost =  292.7290040874888
# Improved over  4  iterations in  0.8119383529992774  seconds by  0.026907474210673854  percent.
# [0.41629509 0.        ] [7.03151804e-08 3.33235969e+00]
# go back to ----- 2700
# ----- 2700
# set cost params:  0.05 0.0 87.79375702681133
# interpolate adjoint :  True True True
# initial cost =  292.58119802526636
# RUN  0 , total integrated cost =  292.58119802526636
# Gradient descend method:  None
# RUN  1 , total integrated cost =  292.58119802526636
# Control only changes marginally.
# RUN  1 , total integrated cost =  292.58119802526636
# Improved over  1  iterations in  0.33032566400652286  seconds by  0.0  percent.
# [0.41629509 0.        ] [7.03151804e-08 3.33235969e+00]
# ----- 2800
# 0.5537231384307846 0.5277083333333333
# shift ind =  53
# set cost params:  0.05 0.0 83.97120563379278
# interpolate adjoint :  True True True
# initial cost =  280.00339575506837
# RUN  0 , total integrated cost =  280.00339575506837
# Gradient descend method:  None
# RUN  1 , total integrated cost =  279.8955615744199
# RUN  2 , total integrated cost =  279.89552001822534
# RUN  3 , total integrated cost =  279.89552000042005
# RUN  4 , total integrated cost =  279.89552000042005
# Control only changes marginally.
# RUN  4 , total integrated cost =  279.89552000042005
# Improved over  4  iterations in  0.8431152129924158  seconds by  0.038526587992777195  percent.
# [0.57493788 0.        ] [7.03149858e-08 3.33288971e+00]
# go back to ----- 2800
# ----- 2800
# set cost params:  0.05 0.0 83.91025279765206
# interpolate adjoint :  True True True
# initial cost =  279.69237091575917
# RUN  0 , total integrated cost =  279.69237091575917
# Gradient descend method:  None
# RUN  1 , total integrated cost =  279.69237091005454
# RUN  2 , total integrated cost =  279.69237091005454
# Control only changes marginally.
# RUN  2 , total integrated cost =  279.69237091005454
# Improved over  2  iterations in  0.5523267660028068  seconds by  2.0396129229993676e-09  percent.
# [0.57462743 0.        ] [7.03149858e-08 3.33288990e+00]
# go back to ----- 2800
# ----- 2800
# set cost params:  0.05 0.0 83.91034129048984
# interpolate adjoint :  True True True
# initial cost =  279.6926658469456
# RUN  0 , total integrated cost =  279.6926658469456
# Gradient descend method:  None
# RUN  1 , total integrated cost =  279.6926658469456
# Control only changes marginally.
# RUN  1 , total integrated cost =  279.6926658469456
# Improved over  1  iterations in  0.351662294997368  seconds by  0.0  percent.
# [0.57462743 0.        ] [7.03149858e-08 3.33288990e+00]
# ----- 2900
# 0.5549710678590216 0.5277083333333333
# shift ind =  52
# set cost params:  0.05 0.0 80.08839799721025
# interpolate adjoint :  True True True
# initial cost =  267.18460255330234
# RUN  0 , total integrated cost =  267.18460255330234
# Gradient descend method:  None
# RUN  1 , total integrated cost =  267.02820927801304
# RUN  2 , total integrated cost =  267.0282006152688
# RUN  3 , total integrated cost =  267.02819803480156
# RUN  4 , total integrated cost =  267.02819577380393
# RUN  5 , total integrated cost =  267.0281953895576
# RUN  6 , total integrated cost =  267.02819477450635
# RUN  7 , total integrated cost =  267.0281946065858
# RUN  8 , total integrated cost =  267.0281941463704
# RUN  9 , total integrated cost =  267.0281938332564
# RUN  10 , total integrated cost =  267.0281881649258
# RUN  11 , total integrated cost =  267.0281835145622
# RUN  12 , total integrated cost =  267.0281832798224
# RUN  13 , total integrated cost =  267.02818287815285
# RUN  14 , total integrated cost =  267.0281826744666
# RUN  15 , total integrated cost =  267.02818150167843
# RUN  16 , total integrated cost =  267.0281804495599
# RUN  17 , total integrated cost =  267.02817926085453
# RUN  18 , total integrated cost =  267.0281775563052
# RUN  19 , total integrated cost =  267.0281773823812
# RUN  20 , total integrated cost =  267.0281769802148
# RUN  30 , total integrated cost =  267.0281603842803
# RUN  40 , total integrated cost =  267.02813184367375
# RUN  50 , total integrated cost =  267.028103671163
# RUN  60 , total integrated cost =  267.0280668910531
# RUN  70 , total integrated cost =  267.0280534071048
# RUN  80 , total integrated cost =  267.0279941192319
# RUN  90 , total integrated cost =  267.02798164205626
# RUN  100 , total integrated cost =  267.02797156265666
# RUN  110 , total integrated cost =  267.0279620094444
# RUN  120 , total integrated cost =  267.02795500179747
# RUN  130 , total integrated cost =  267.0279186299052
# RUN  140 , total integrated cost =  267.0278333711387
# RUN  150 , total integrated cost =  267.0278195696635
# RUN  160 , total integrated cost =  267.0278128364624
# RUN  170 , total integrated cost =  267.02780591626544
# RUN  180 , total integrated cost =  267.02770721126063
# RUN  190 , total integrated cost =  267.02769774286884
# RUN  200 , total integrated cost =  267.0276840752802
# Control only changes marginally.
# RUN  255 , total integrated cost =  267.02747599714775
# Improved over  255  iterations in  42.09666233600001  seconds by  0.05880823769523147  percent.
# [0.7889907 0.       ] [7.03146723e-08 3.33366664e+00]
# go back to ----- 2900
# ----- 2900
# set cost params:  0.05 0.0 80.00543478260408
# interpolate adjoint :  True True True
# initial cost =  266.75090429025175
# RUN  0 , total integrated cost =  266.75090429025175
# Gradient descend method:  None
# RUN  1 , total integrated cost =  266.7509042732854
# RUN  2 , total integrated cost =  266.7509042732854
# Control only changes marginally.
# RUN  2 , total integrated cost =  266.7509042732854
# Improved over  2  iterations in  0.3829681450006319  seconds by  6.360366455737676e-09  percent.
# [0.78830346 0.        ] [7.03146723e-08 3.33366707e+00]
# go back to ----- 2900
# ----- 2900
# set cost params:  0.05 0.0 80.0056306302839
# interpolate adjoint :  True True True
# initial cost =  266.75155716426036
# RUN  0 , total integrated cost =  266.75155716426036
# Gradient descend method:  None
# RUN  1 , total integrated cost =  266.75155716426036
# Control only changes marginally.
# RUN  1 , total integrated cost =  266.75155716426036
# Improved over  1  iterations in  0.20544818000053056  seconds by  0.0  percent.
# [0.78830346 0.        ] [7.03146723e-08 3.33366707e+00]
# ----- 3000
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_5634/3643991053.py in <module>
#      49
#      50         if type(bestControl_maxW[i][j]) == type(None):
# ---> 51             max_percent_prev = (np.argmax(np.abs(bestControl_maxW[i][j-step]), axis=2)[0,ind_max_c] - 100) / (T-200)
#      52             shift_ind = 0
#      53             print(max_percent_prev, max_percent[i])
#
# TypeError: bad operand type for abs(): 'NoneType'
