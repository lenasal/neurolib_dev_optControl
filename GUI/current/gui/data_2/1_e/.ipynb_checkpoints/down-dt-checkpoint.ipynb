# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import sys
import pickle

path = os.getcwd().split(os.sep + 'GUI')[0]
if path not in sys.path:
    print("not here")
    sys.path.append(path)

from neurolib.models.aln import ALNModel
from neurolib.utils import plotFunctions as plotFunc
from neurolib.utils import costFunctions as cost
import neurolib.dashboard.functions as functions
import neurolib.dashboard.data as data
    
# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2 

#path = os.path.join(os.getcwd(), "plots")
# Out:
# not here

# %%
grid_data_file = os.path.join(os.getcwd().split('data')[0], 'bi.pickle')
with open(grid_data_file,'rb') as f:
    load_array= pickle.load(f)
exc = [load_array[0][20], load_array[0][50]]
inh = [load_array[1][20], load_array[1][50]]

folder = str(os.getcwd().split('data_2')[1])
print(folder)
case = str(folder[1])

file_ = 'down.pickle'

c_var = [0,1]
if len(folder) == 4:
    if folder[3] == 'e':
        p_var = [0]
    elif folder[3] == 'i':
        p_var = [1]
else:
    p_var = [0,1]
    
print(p_var)

step1 = 100
step2 = 10
step3 = 1
# Out:
# /1_e
# [0]

# %%
aln = ALNModel()
N = aln.params.N

data.set_parameters(aln)

state_vars = aln.state_vars
init_vars = aln.init_vars

##############################################################
def setinit(init_vars_, model):
    state_vars = model.state_vars
    init_vars = model.init_vars
    for iv in range(len(init_vars)):
        for sv in range(len(state_vars)):
            if state_vars[sv] in init_vars[iv]:
                #print("set init vars ", )
                if model.params[init_vars[iv]].ndim == 2:
                    model.params[init_vars[iv]][0,:] = init_vars_[sv]
                else:
                    model.params[init_vars[iv]][0] = init_vars_[sv]
                    
##############################################################               
def setmaxmincontrol(max_c_c, min_c_c, max_c_r, min_c_r):
    import numpy as np
    
    max_cntrl = np.zeros(( 6 ))
    min_cntrl = np.zeros(( 6 ))
    
    max_cntrl[0] = max_c_c
    min_cntrl[0] = min_c_c
    max_cntrl[1] = max_c_c
    min_cntrl[1] = min_c_c
    max_cntrl[2] = max_c_r
    min_cntrl[2] = min_c_r
    max_cntrl[3] = max_c_r
    min_cntrl[3] = min_c_r
    max_cntrl[4] = max_c_r
    min_cntrl[4] = min_c_r
    max_cntrl[5] = max_c_r
    min_cntrl[5] = min_c_r
            
    return max_cntrl, min_cntrl

# %%
d_array = np.arange(500., 20, -0.1)
t0_array = d_array - 20.
t_pen = np.zeros(( t0_array.shape ))
for i in range(len(t_pen)):
    t_pen[i] = t0_array[i] / d_array[i]

# %%
dur_pre = 10
dur_post = 10

n_pre = int(np.around(dur_pre/aln.params.dt + 1.,1))
n_post = int(np.around(dur_post/aln.params.dt + 1.,1))

tol = 1e-8
start_step = 10.
c_scheme = np.zeros(( 1,1 ))
c_scheme[0,0] = 1.
u_mat = np.identity(1)
u_scheme = np.array([[1.]])

if case in ['1', '2']:    # low to high
    max_I = [3., -3.]
else:
    max_I = [-3., 3.]
    
if case in ['1', '3']:    # sparsity
    factor_ws = 1.
    factor_we = 0.
else:
    factor_ws = 0.
    factor_we = 1.
    
maxC = [1000., -1000., 0.18, 0.]
max_cntrl, min_cntrl = setmaxmincontrol(maxC[0], maxC[1], maxC[2], maxC[3])

# %%
bestControl_ = np.array( [[None] * len(t_pen)] * len(exc) )
bestState_ = np.array( [[None] * len(t_pen)] * len(exc) )
cost_ = np.array( [[None] * len(t_pen)] * len(exc) )
costnode_ = np.array( [[None] * len(t_pen)] * len(exc) )
weights_ = np.array( [[None] * len(t_pen)] * len(exc) )
convergence_ = np.array( [[None] * len(t_pen)] * len(exc) )

initVars = [None] * len(exc)
target = [None] * len(exc)
cost_uncontrolled = [None] * len(exc)

print(bestControl_.shape)
# Out:
# (2, 4800)

# %%
if os.path.isfile(file_) :
    print("file found")
    
    with open(file_,'rb') as f:
        load_array = pickle.load(f)

    bestControl_ = load_array[0]
    bestState_ = load_array[1]
    cost_ = load_array[2]
    costnode_ = load_array[3]
    weights_ = load_array[4]
# Out:
# file found

# %%
# get initial parameters and target states

i_range = range(len(exc))
data.set_parameters(aln)
max_percent = []

i_range = [0]

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    aln.params.duration = 3000.
    
    control0 = aln.getZeroControl()
    control0 = functions.step_control(aln, maxI_ = max_I[0])

    aln.run(control=control0)
    
    target_rates = np.zeros((2))
    target_rates[0] = aln.rates_exc[0,-1] 
    target_rates[1] = aln.rates_inh[0,-1]

    control0 = functions.step_control(aln, maxI_ = max_I[1])
    aln.run(control=control0)

    init_state_vars = np.zeros(( len(state_vars) ))
    for j in range(len(state_vars)):
        if aln.state[state_vars[j]].size == 1:
            init_state_vars[j] = aln.state[state_vars[j]][0]
        else:
            init_state_vars[j] = aln.state[state_vars[j]][0,-1]

    initVars[i] = init_state_vars
    target[i] = [target_rates[0], target_rates[1]]
    
    max_percent_ind = 1
    if i == 1:
        max_percent_ind = 0
    
    max_percent.append( (np.argmax(np.abs(bestControl_[i][0]), axis=2)[0,max_percent_ind] -100) / 4800 )
    
print(max_percent)
# Out:
# -------  0 0.4500000000000001 0.4750000000000002
# [0.5277083333333333]

# %%
# get uncontrolled cost

data.set_parameters(aln)
j = 0

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    dur = d_array[0]
    aln.params.duration = dur
    wp = 1. / (dur - t_pen[j] * dur)
    
    print(wp)
    
    target_ = aln.getZeroTarget()
    target_[:,0,:] = target[i][0]
    target_[:,1,:] = target[i][1]
            
    cost.setParams(wp, 0.0, 0.0)

    setinit(initVars[i], aln)
    control0 = aln.getZeroControl()

    # "HS", "FR", "PR", "HZ"
    cgv = None
    max_it = 0
    
    print(t_pen[0], dur, dur_pre, dur_post)

    bestControl_init_, bestState_init_, cost_init_, runtime_init_, grad_init_, phi_init_, phi1_, costnode_init_ = aln.A1(
        control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
        prec_variables_ = p_var, transition_time_ = t_pen[0])
    
    cost_uncontrolled[i] = cost_init_[0]
# Out:
# -------  0 0.4500000000000001 0.4750000000000002
# 0.05
# set cost params:  0.05 0.0 0.0
# 0.96 500.0 10 10
# interpolate adjoint :  True True True
# initial cost =  636.9058225135838
# RUN  0 , total integrated cost =  636.9058225135838
# Gradient descend method:  None
# RUN  0 , total integrated cost =  636.9058225135838
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.

# %%
i = 0

for j in range(4460,4800,1):
    convergence_[i][j] = None
    #bestControl_[i][j] = None

# %%
tol = 1e-6

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    j = 0
    step = step1

    while j < 4800:

        if j == 0:
            j += step
            continue
            
        if not convergence_[i][j-step]:
            if j - step > 0:
                j -= step
                print('go back to -----', j)

        print('-----', j)
        
        if j >= 3301:
            step = step2
        if j >=4791:
            step = step3

        if convergence_[i][j]:
            j += step
            continue

        dur = d_array[j]
        T = 5001 - j
        aln.params.duration = dur
        
        wp = 1. / (dur - t_pen[j] * dur)

        cost.setParams(wp, 0., 1.)
        weights_[i][j] = cost.getParams()

        setinit(initVars[i], aln)

        max_it = 1000

        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]
        
        max_percent_ind = 1
        if i == 1:
            max_percent_ind = 0

        if type(bestControl_[i][j]) == type(None):
            max_percent_prev = (np.argmax(np.abs(bestControl_[i][j-step]), axis=2)[0,max_percent_ind] - 100) / (T-200)
            shift_ind = 0
            print(max_percent_prev, max_percent[i])
            if j < 4600:
                while max_percent_prev > max_percent[i]:
                    shift_ind += 1
                    max_percent_prev = (np.argmax(np.abs(bestControl_[i][j-step]), axis=2)[0,max_percent_ind] - 100 - shift_ind) / (T-200)

            control0 = np.zeros(( bestControl_[i][j-step][:,:,100:-(100+step)].shape ))
            print('shift ind = ', shift_ind)
            if shift_ind != 0:
                control0[:,:,:-shift_ind] = 1. * bestControl_[i][j-step][:,:,100+shift_ind:-(100+step)]
            else:
                control0[:,:,:] = 1. * bestControl_[i][j-step][:,:,100:-(100+step)]
                #control0[0,0,:] = 0.
        else:
            if bestControl_[i][j].shape[2] == T+200:
                control0 = bestControl_[i][j][:,:,100:-100]
                #control0[0,1,:] = 0.
            else:
                control0 = bestControl_[i][j][:,:,100:-(100+j)]

        bestControl_[i][j], bestState_[i][j], cost_[i][j], runtime_, grad_, phi_, phi1_, costnode_[i][j] = aln.A1(
            control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
            prec_variables_ = p_var, transition_time_ = t_pen[j])
        
        time_ = np.arange(-dur_pre,round(dur+dur_post+aln.params.dt,1),aln.params.dt)
        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        print(costnode_[i][j][0][0][0], costnode_[i][j][2][0][:2])

        if cost_[i][j][-1] == 0.:
            convergence_[i][j] = True
            if j >= 3300:
                step = step2
            if j >=4790:
                step = step3

        with open(file_,'wb') as f:
            pickle.dump([bestControl_, bestState_, cost_, costnode_, weights_], f)

        j += step
# Out:
# -------  0 0.4500000000000001 0.4750000000000002
# ----- 100
# ----- 200
# ----- 300
# ----- 400
# ----- 500
# ----- 600
# ----- 700
# ----- 800
# ----- 900
# ----- 1000
# ----- 1100
# ----- 1200
# ----- 1300
# ----- 1400
# ----- 1500
# ----- 1600
# ----- 1700
# ----- 1800
# ----- 1900
# ----- 2000
# ----- 2100
# ----- 2200
# ----- 2300
# ----- 2400
# ----- 2500
# ----- 2600
# ----- 2700
# ----- 2800
# ----- 2900
# ----- 3000
# ----- 3100
# ----- 3200
# ----- 3300
# ----- 3400
# ----- 3410
# ----- 3420
# ----- 3430
# ----- 3440
# ----- 3450
# ----- 3460
# ----- 3470
# ----- 3480
# ----- 3490
# ----- 3500
# ----- 3510
# ----- 3520
# ----- 3530
# ----- 3540
# ----- 3550
# ----- 3560
# ----- 3570
# ----- 3580
# ----- 3590
# ----- 3600
# ----- 3610
# ----- 3620
# ----- 3630
# ----- 3640
# ----- 3650
# ----- 3660
# ----- 3670
# ----- 3680
# ----- 3690
# ----- 3700
# ----- 3710
# ----- 3720
# ----- 3730
# ----- 3740
# ----- 3750
# ----- 3760
# ----- 3770
# ----- 3780
# ----- 3790
# ----- 3800
# ----- 3810
# ----- 3820
# ----- 3830
# ----- 3840
# ----- 3850
# ----- 3860
# ----- 3870
# ----- 3880
# ----- 3890
# ----- 3900
# ----- 3910
# ----- 3920
# ----- 3930
# ----- 3940
# ----- 3950
# ----- 3960
# ----- 3970
# ----- 3980
# ----- 3990
# ----- 4000
# ----- 4010
# ----- 4020
# ----- 4030
# ----- 4040
# ----- 4050
# ----- 4060
# ----- 4070
# ----- 4080
# ----- 4090
# ----- 4100
# ----- 4110
# ----- 4120
# ----- 4130
# ----- 4140
# ----- 4150
# ----- 4160
# ----- 4170
# ----- 4180
# ----- 4190
# ----- 4200
# ----- 4210
# ----- 4220
# ----- 4230
# ----- 4240
# ----- 4250
# ----- 4260
# ----- 4270
# ----- 4280
# ----- 4290
# ----- 4300
# ----- 4310
# ----- 4320
# ----- 4330
# ----- 4340
# ----- 4350
# ----- 4360
# ----- 4370
# ----- 4380
# ----- 4390
# ----- 4400
# ----- 4410
# ----- 4420
# ----- 4430
# ----- 4440
# ----- 4450
# ----- 4460
# ----- 4470
# ----- 4480
# ----- 4490
# ----- 4500
# ----- 4510
# ----- 4520
# ----- 4530
# ----- 4540
# ----- 4550
# ----- 4560
# ----- 4570
# ----- 4580
# ----- 4590
# ----- 4600
# ----- 4610
# ----- 4620
# ----- 4630
# ----- 4640
# ----- 4650
# ----- 4660
# ----- 4670
# ----- 4680
# ----- 4690
# ----- 4700
# ----- 4710
# ----- 4720
# ----- 4730
# ----- 4740
# ----- 4750
# ----- 4760
# ----- 4770
# ----- 4780
# ----- 4790
# set cost params:  0.05 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  18.51910293570357
# RUN  0 , total integrated cost =  18.51910293570357
# Gradient descend method:  None
# RUN  1 , total integrated cost =  18.51892408475534
# RUN  2 , total integrated cost =  18.518744832093777
# RUN  3 , total integrated cost =  18.518566222434536
# RUN  4 , total integrated cost =  18.51838845409931
# RUN  5 , total integrated cost =  18.518211116075395
# RUN  6 , total integrated cost =  18.518033052308237
# RUN  7 , total integrated cost =  18.51785195929471
# RUN  8 , total integrated cost =  18.517674197382647
# RUN  9 , total integrated cost =  18.517494629630807
# RUN  10 , total integrated cost =  18.517317149093845
# RUN  11 , total integrated cost =  18.517139116572878
# RUN  12 , total integrated cost =  18.51696189643759
# RUN  13 , total integrated cost =  18.51678540980122
# RUN  14 , total integrated cost =  18.51660842857594
# RUN  15 , total integrated cost =  18.516433499184682
# RUN  16 , total integrated cost =  18.51625673917263
# RUN  17 , total integrated cost =  18.516083290988867
# RUN  18 , total integrated cost =  18.51591149225535
# RUN  19 , total integrated cost =  18.51574048271761
# RUN  20 , total integrated cost =  18.515567962414814
# RUN  30 , total integrated cost =  18.513856600567312
# RUN  40 , total integrated cost =  18.512197611983606
# RUN  50 , total integrated cost =  18.51057269159486
# RUN  60 , total integrated cost =  18.509011043530005
# RUN  70 , total integrated cost =  18.507720661190106
# RUN  80 , total integrated cost =  18.506710162610872
# RUN  90 , total integrated cost =  18.505758519402605
# RUN  100 , total integrated cost =  18.504819293283397
# RUN  110 , total integrated cost =  18.503910819074537
# RUN  120 , total integrated cost =  18.50302807669964
# RUN  130 , total integrated cost =  18.50218567473292
# RUN  140 , total integrated cost =  18.501367913758195
# RUN  150 , total integrated cost =  18.500579920123258
# RUN  160 , total integrated cost =  18.49980850618341
# RUN  170 , total integrated cost =  18.499054645252006
# RUN  180 , total integrated cost =  18.49831945447717
# RUN  190 , total integrated cost =  18.497596185612817
# RUN  200 , total integrated cost =  18.496911959977794
# RUN  300 , total integrated cost =  18.491835539737604
# RUN  400 , total integrated cost =  18.488532604440607
# RUN  500 , total integrated cost =  18.485120092390588
# RUN  600 , total integrated cost =  18.48440609226852
# RUN  700 , total integrated cost =  18.48395990397905
# RUN  800 , total integrated cost =  18.483650651706427
# RUN  900 , total integrated cost =  18.483415530418995
# RUN  1000 , total integrated cost =  18.48322848972486
# RUN  1000 , total integrated cost =  18.48322848972486
# Improved over  1000  iterations in  43.50871990300948  seconds by  0.19371589489655605  percent.
# 11.221903949414978 [1.79221324e+01 8.79855294e-07]
# go back to ----- 4790
# ----- 4790
# set cost params:  0.05 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  18.48322848972486
# RUN  0 , total integrated cost =  18.48322848972486
# Gradient descend method:  None
# RUN  1 , total integrated cost =  18.483226776496927
# RUN  2 , total integrated cost =  18.483224986325684
# RUN  3 , total integrated cost =  18.48322319894469
# RUN  4 , total integrated cost =  18.483221498640493
# RUN  5 , total integrated cost =  18.48321982248727
# RUN  6 , total integrated cost =  18.483218193898683
# RUN  7 , total integrated cost =  18.483216573787242
# RUN  8 , total integrated cost =  18.483214961183695
# RUN  9 , total integrated cost =  18.48321334746995
# RUN  10 , total integrated cost =  18.483211735973033
# RUN  11 , total integrated cost =  18.483210132070283
# RUN  12 , total integrated cost =  18.48320853332468
# RUN  13 , total integrated cost =  18.483206924302298
# RUN  14 , total integrated cost =  18.483205291241397
# RUN  15 , total integrated cost =  18.483203684843332
# RUN  16 , total integrated cost =  18.4832020635929
# RUN  17 , total integrated cost =  18.483200459717157
# RUN  18 , total integrated cost =  18.483198850306337
# RUN  19 , total integrated cost =  18.48319724884982
# RUN  20 , total integrated cost =  18.48319565130951
# RUN  30 , total integrated cost =  18.48317991500445
# RUN  40 , total integrated cost =  18.48316446701221
# RUN  50 , total integrated cost =  18.48314947759254
# RUN  60 , total integrated cost =  18.483134448674154
# RUN  70 , total integrated cost =  18.483119703879243
# RUN  80 , total integrated cost =  18.483105274152987
# RUN  90 , total integrated cost =  18.483091489889496
# RUN  100 , total integrated cost =  18.483077957985557
# RUN  110 , total integrated cost =  18.483064663433847
# RUN  120 , total integrated cost =  18.483051686068514
# RUN  130 , total integrated cost =  18.48303897659865
# RUN  140 , total integrated cost =  18.48302629415846
# RUN  150 , total integrated cost =  18.4830138878971
# RUN  160 , total integrated cost =  18.483001799727038
# RUN  170 , total integrated cost =  18.482989956453522
# RUN  180 , total integrated cost =  18.482978329382817
# RUN  190 , total integrated cost =  18.48296741451543
# RUN  200 , total integrated cost =  18.48294956526812
# Control only changes marginally.
# RUN  290 , total integrated cost =  18.48273375704741
# Improved over  290  iterations in  12.339463475975208  seconds by  0.002676657261062587  percent.
# 11.125547759044188 [1.79264555e+01 8.79855294e-07]
# ----- 4791
# set cost params:  0.05 0.0 1.0
# 3.2 0.5277083333333333
# shift ind =  0
# interpolate adjoint :  True True True
# initial cost =  19.96454902628736
# RUN  0 , total integrated cost =  19.96454902628736
# Gradient descend method:  None
# RUN  1 , total integrated cost =  19.94526351675307
# RUN  2 , total integrated cost =  19.93582773024008
# RUN  3 , total integrated cost =  19.931779733597196
# RUN  4 , total integrated cost =  19.928409711356966
# RUN  5 , total integrated cost =  19.925257716182713
# RUN  6 , total integrated cost =  19.922246830709682
# RUN  7 , total integrated cost =  19.919327855418018
# RUN  8 , total integrated cost =  19.91646988341555
# RUN  9 , total integrated cost =  19.91366891981818
# RUN  10 , total integrated cost =  19.910863902470993
# RUN  11 , total integrated cost =  19.908177015775642
# RUN  12 , total integrated cost =  19.905511127223892
# RUN  13 , total integrated cost =  19.902944110315087
# RUN  14 , total integrated cost =  19.900442138982335
# RUN  15 , total integrated cost =  19.897942869596417
# RUN  16 , total integrated cost =  19.895513027395765
# RUN  17 , total integrated cost =  19.89307438941505
# RUN  18 , total integrated cost =  19.890716631165336
# RUN  19 , total integrated cost =  19.88840309832404
# RUN  20 , total integrated cost =  19.88612229581576
# RUN  30 , total integrated cost =  19.86444742192853
# RUN  40 , total integrated cost =  19.844776073546047
# RUN  50 , total integrated cost =  19.826500190939065
# RUN  60 , total integrated cost =  19.810385793292173
# RUN  70 , total integrated cost =  19.795817259521737
# RUN  80 , total integrated cost =  19.7828098617729
# RUN  90 , total integrated cost =  19.76984346714274
# RUN  100 , total integrated cost =  19.756279926464945
# RUN  110 , total integrated cost =  19.742813291523458
# RUN  120 , total integrated cost =  19.730671860076818
# RUN  130 , total integrated cost =  19.719315419251288
# RUN  140 , total integrated cost =  19.707916965025184
# RUN  150 , total integrated cost =  19.69742255123098
# RUN  160 , total integrated cost =  19.687645711830097
# RUN  170 , total integrated cost =  19.68034856165789
# RUN  180 , total integrated cost =  19.67340881846405
# RUN  190 , total integrated cost =  19.66588493170754
# RUN  200 , total integrated cost =  19.658492954627807
# RUN  300 , total integrated cost =  19.59947905934021
# RUN  400 , total integrated cost =  19.564696899962026
# RUN  500 , total integrated cost =  19.538340784890433
# RUN  600 , total integrated cost =  19.524334881259136
# RUN  700 , total integrated cost =  19.5157999707313
# RUN  800 , total integrated cost =  19.509387878222878
# RUN  900 , total integrated cost =  19.50453354310962
# RUN  1000 , total integrated cost =  19.502065284402935
# RUN  1000 , total integrated cost =  19.502065284402935
# Improved over  1000  iterations in  42.388712876010686  seconds by  2.316524862522428  percent.
# 15.234835612602474 [1.87403226e+01 8.79855294e-07]
# go back to ----- 4791
# ----- 4791
# set cost params:  0.05 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  19.502065284402935
# RUN  0 , total integrated cost =  19.502065284402935
# Gradient descend method:  None
# RUN  1 , total integrated cost =  19.50204881475436
# RUN  2 , total integrated cost =  19.502032580623727
# RUN  3 , total integrated cost =  19.50201857542403
# RUN  4 , total integrated cost =  19.50200373242251
# RUN  5 , total integrated cost =  19.50198870749815
# RUN  6 , total integrated cost =  19.501973273529728
# RUN  7 , total integrated cost =  19.501958950602706
# RUN  8 , total integrated cost =  19.501944779868445
# RUN  9 , total integrated cost =  19.501929360976963
# RUN  10 , total integrated cost =  19.50191465829594
# RUN  11 , total integrated cost =  19.501900025282087
# RUN  12 , total integrated cost =  19.50188472811483
# RUN  13 , total integrated cost =  19.50187075297719
# RUN  14 , total integrated cost =  19.501856719445612
# RUN  15 , total integrated cost =  19.50184168459827
# RUN  16 , total integrated cost =  19.501827115741026
# RUN  17 , total integrated cost =  19.501812863204428
# RUN  18 , total integrated cost =  19.50179944240207
# RUN  19 , total integrated cost =  19.501783953432543
# RUN  20 , total integrated cost =  19.501768406053525
# RUN  30 , total integrated cost =  19.50163096076529
# RUN  40 , total integrated cost =  19.501494260681046
# RUN  50 , total integrated cost =  19.501362467122526
# RUN  60 , total integrated cost =  19.501232901433387
# RUN  70 , total integrated cost =  19.501108067777615
# RUN  80 , total integrated cost =  19.500991925121625
# RUN  90 , total integrated cost =  19.50088451533926
# RUN  100 , total integrated cost =  19.50074601382797
# RUN  110 , total integrated cost =  19.500597556071895
# RUN  120 , total integrated cost =  19.50045565757996
# RUN  130 , total integrated cost =  19.50031661478573
# RUN  140 , total integrated cost =  19.500193704729075
# RUN  150 , total integrated cost =  19.500067850689188
# RUN  160 , total integrated cost =  19.49992566224278
# RUN  170 , total integrated cost =  19.49979040741649
# RUN  180 , total integrated cost =  19.499657418836716
# RUN  190 , total integrated cost =  19.499526994446068
# RUN  200 , total integrated cost =  19.49939903114816
# RUN  300 , total integrated cost =  19.498193627749966
# RUN  400 , total integrated cost =  19.497203132830382
# RUN  500 , total integrated cost =  19.496821145166017
# RUN  600 , total integrated cost =  19.49655720001455
# RUN  700 , total integrated cost =  19.496485208167986
# RUN  800 , total integrated cost =  19.496432880968804
# RUN  900 , total integrated cost =  19.496392174564647
# RUN  1000 , total integrated cost =  19.496358664819663
# RUN  1000 , total integrated cost =  19.496358664819663
# Improved over  1000  iterations in  44.00012050900841  seconds by  0.029261616654707723  percent.
# 13.863931373784983 [1.88031612e+01 8.79855294e-07]
# go back to ----- 4791
# ----- 4791
# set cost params:  0.05 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  19.496358664819663
# RUN  0 , total integrated cost =  19.496358664819663
# Gradient descend method:  None
# RUN  1 , total integrated cost =  19.496358373762035
# RUN  2 , total integrated cost =  19.496358066051943
# RUN  3 , total integrated cost =  19.49635770951514
# RUN  4 , total integrated cost =  19.49635735255001
# RUN  5 , total integrated cost =  19.496357048002345
# RUN  6 , total integrated cost =  19.496356757687987
# RUN  7 , total integrated cost =  19.49635646836918
# RUN  8 , total integrated cost =  19.49635616602002
# RUN  9 , total integrated cost =  19.496355887117087
# RUN  10 , total integrated cost =  19.496355606141922
# RUN  11 , total integrated cost =  19.496355309564823
# RUN  12 , total integrated cost =  19.496355017899198
# RUN  13 , total integrated cost =  19.496354735027733
# RUN  14 , total integrated cost =  19.496354447474385
# RUN  15 , total integrated cost =  19.496354163834887
# RUN  16 , total integrated cost =  19.49635386379783
# RUN  17 , total integrated cost =  19.49635351638463
# RUN  18 , total integrated cost =  19.496353168285232
# RUN  19 , total integrated cost =  19.496352871469536
# RUN  20 , total integrated cost =  19.496352588403298
# RUN  30 , total integrated cost =  19.496349767153667
# RUN  40 , total integrated cost =  19.496346697904993
# RUN  50 , total integrated cost =  19.496343659778287
# RUN  60 , total integrated cost =  19.496340744368613
# RUN  70 , total integrated cost =  19.496337783587833
# RUN  80 , total integrated cost =  19.496334880712187
# RUN  90 , total integrated cost =  19.496332223394845
# RUN  100 , total integrated cost =  19.49632965248472
# RUN  110 , total integrated cost =  19.496327221963405
# RUN  120 , total integrated cost =  19.496324725533842
# RUN  130 , total integrated cost =  19.49632226035709
# RUN  140 , total integrated cost =  19.49631995379816
# RUN  150 , total integrated cost =  19.49631758316715
# RUN  160 , total integrated cost =  19.49631524264656
# RUN  170 , total integrated cost =  19.496312764231917
# RUN  180 , total integrated cost =  19.496310332493287
# RUN  190 , total integrated cost =  19.496308024788547
# RUN  200 , total integrated cost =  19.496305708401213
# RUN  300 , total integrated cost =  19.496285680729546
# RUN  400 , total integrated cost =  19.496268527310566
# RUN  500 , total integrated cost =  19.496254006435166
# RUN  600 , total integrated cost =  19.496241475806677
# RUN  700 , total integrated cost =  19.496230744233994
# RUN  800 , total integrated cost =  19.49622168969339
# RUN  900 , total integrated cost =  19.49621394538956
# RUN  1000 , total integrated cost =  19.49620519742714
# RUN  1000 , total integrated cost =  19.49620519742714
# Improved over  1000  iterations in  43.103791161993286  seconds by  0.0007871592596444543  percent.
# 13.541775845926 [1.88191155e+01 8.79855294e-07]
# go back to ----- 4791
# ----- 4791
# set cost params:  0.05 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  19.49620519742714
# RUN  0 , total integrated cost =  19.49620519742714
# Gradient descend method:  None
# RUN  1 , total integrated cost =  19.496205091292158
# RUN  2 , total integrated cost =  19.49620499416764
# RUN  3 , total integrated cost =  19.496204848567682
# RUN  4 , total integrated cost =  19.49620469917879
# RUN  5 , total integrated cost =  19.496204291356996
# RUN  6 , total integrated cost =  19.496203921203254
# RUN  7 , total integrated cost =  19.496203760453575
# RUN  8 , total integrated cost =  19.496203595934468
# RUN  9 , total integrated cost =  19.496203246296893
# RUN  10 , total integrated cost =  19.496202908418457
# RUN  11 , total integrated cost =  19.496202741374155
# RUN  12 , total integrated cost =  19.496202590187483
# RUN  13 , total integrated cost =  19.496202224378063
# RUN  14 , total integrated cost =  19.496201846501346
# RUN  15 , total integrated cost =  19.49620170162713
# RUN  16 , total integrated cost =  19.49620155336064
# RUN  17 , total integrated cost =  19.49620120062271
# RUN  18 , total integrated cost =  19.496200827354546
# RUN  19 , total integrated cost =  19.496200699416708
# RUN  20 , total integrated cost =  19.496200576815696
# RUN  30 , total integrated cost =  19.496199639406743
# RUN  40 , total integrated cost =  19.496198608410953
# RUN  50 , total integrated cost =  19.496197605189916
# RUN  60 , total integrated cost =  19.49619663459215
# RUN  70 , total integrated cost =  19.49619604704244
# RUN  80 , total integrated cost =  19.496195137247174
# RUN  90 , total integrated cost =  19.496194188993023
# RUN  100 , total integrated cost =  19.49619185980479
# RUN  110 , total integrated cost =  19.49619105870384
# RUN  120 , total integrated cost =  19.49619026007382
# RUN  130 , total integrated cost =  19.49618947232133
# RUN  140 , total integrated cost =  19.496188665688884
# RUN  150 , total integrated cost =  19.49618794673847
# RUN  160 , total integrated cost =  19.496187236329025
# RUN  170 , total integrated cost =  19.496186471746217
# RUN  180 , total integrated cost =  19.496185790161185
# RUN  190 , total integrated cost =  19.496185116571628
# RUN  200 , total integrated cost =  19.496184391503515
# RUN  300 , total integrated cost =  19.496178187046358
# RUN  400 , total integrated cost =  19.49617296065445
# RUN  500 , total integrated cost =  19.496168265078246
# RUN  600 , total integrated cost =  19.49616448258827
# RUN  700 , total integrated cost =  19.49616125545722
# RUN  800 , total integrated cost =  19.496158545162768
# RUN  900 , total integrated cost =  19.496156230886626
# RUN  1000 , total integrated cost =  19.496154222016763
# RUN  1000 , total integrated cost =  19.496154222016763
# Improved over  1000  iterations in  46.821996941027464  seconds by  0.00026146324303510937  percent.
# 13.343468980066067 [1.88289799e+01 8.79855294e-07]
# go back to ----- 4791
# ----- 4791
# set cost params:  0.05 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  19.496154222016763
# RUN  0 , total integrated cost =  19.496154222016763
# Gradient descend method:  None
# RUN  1 , total integrated cost =  19.496154204400902
# RUN  2 , total integrated cost =  19.496154187037295
# RUN  3 , total integrated cost =  19.496154170237666
# RUN  4 , total integrated cost =  19.4961541530969
# RUN  5 , total integrated cost =  19.496154136184856
# RUN  6 , total integrated cost =  19.49615411925939
# RUN  7 , total integrated cost =  19.496154102267955
# RUN  8 , total integrated cost =  19.496154084624962
# RUN  9 , total integrated cost =  19.496154068268947
# RUN  10 , total integrated cost =  19.496154051842492
# RUN  11 , total integrated cost =  19.496154034441066
# RUN  12 , total integrated cost =  19.496154017371875
# RUN  13 , total integrated cost =  19.49615400078046
# RUN  14 , total integrated cost =  19.496153983929176
# RUN  15 , total integrated cost =  19.496153967295932
# RUN  16 , total integrated cost =  19.49615394968861
# RUN  17 , total integrated cost =  19.496153929334703
# RUN  18 , total integrated cost =  19.496153908864326
# RUN  19 , total integrated cost =  19.496153891465635
# RUN  20 , total integrated cost =  19.49615387480733
# RUN  30 , total integrated cost =  19.49615369310032
# RUN  40 , total integrated cost =  19.496153529746287
# RUN  50 , total integrated cost =  19.496153369686052
# RUN  60 , total integrated cost =  19.496153196088287
# RUN  70 , total integrated cost =  19.49615303140766
# RUN  80 , total integrated cost =  19.496152878600643
# RUN  90 , total integrated cost =  19.496152721217573
# RUN  100 , total integrated cost =  19.496152563862577
# RUN  110 , total integrated cost =  19.496152417842755
# RUN  120 , total integrated cost =  19.496152267439967
# RUN  130 , total integrated cost =  19.496152117057825
# RUN  140 , total integrated cost =  19.49615197043195
# RUN  150 , total integrated cost =  19.496151832999956
# RUN  160 , total integrated cost =  19.49615169002474
# RUN  170 , total integrated cost =  19.49615154317692
# RUN  180 , total integrated cost =  19.49615141190761
# RUN  190 , total integrated cost =  19.496151281837555
# RUN  200 , total integrated cost =  19.49615114146367
# RUN  300 , total integrated cost =  19.49614991833065
# RUN  400 , total integrated cost =  19.496148859418977
# RUN  500 , total integrated cost =  19.49614794796428
# RUN  600 , total integrated cost =  19.496147166144198
# RUN  700 , total integrated cost =  19.49614648512402
# RUN  800 , total integrated cost =  19.496145893376962
# RUN  900 , total integrated cost =  19.496145385385994
# RUN  1000 , total integrated cost =  19.496144952713966
# RUN  1000 , total integrated cost =  19.496144952713966
# Improved over  1000  iterations in  42.25123904499924  seconds by  4.754426279873769e-05  percent.
# 13.268248191608265 [1.88327317e+01 8.79855294e-07]
# go back to ----- 4791
# ----- 4791
# set cost params:  0.05 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  19.496144952713966
# RUN  0 , total integrated cost =  19.496144952713966
# Gradient descend method:  None
# RUN  1 , total integrated cost =  19.496144948745975
# RUN  2 , total integrated cost =  19.49614494484469
# RUN  3 , total integrated cost =  19.496144941060745
# RUN  4 , total integrated cost =  19.49614493720823
# RUN  5 , total integrated cost =  19.49614493339889
# RUN  6 , total integrated cost =  19.496144929593505
# RUN  7 , total integrated cost =  19.49614492576522
# RUN  8 , total integrated cost =  19.49614492179775
# RUN  9 , total integrated cost =  19.496144918113636
# RUN  10 , total integrated cost =  19.49614491441806
# RUN  11 , total integrated cost =  19.4961449104975
# RUN  12 , total integrated cost =  19.496144906656475
# RUN  13 , total integrated cost =  19.496144902918356
# RUN  14 , total integrated cost =  19.496144899125174
# RUN  15 , total integrated cost =  19.4961448953771
# RUN  16 , total integrated cost =  19.49614489141291
# RUN  17 , total integrated cost =  19.496144886826073
# RUN  18 , total integrated cost =  19.496144882215706
# RUN  19 , total integrated cost =  19.49614487829499
# RUN  20 , total integrated cost =  19.496144874541592
# RUN  30 , total integrated cost =  19.496144833573734
# RUN  40 , total integrated cost =  19.49614479671024
# RUN  50 , total integrated cost =  19.496144760558547
# RUN  60 , total integrated cost =  19.496144724903516
# RUN  70 , total integrated cost =  19.496144686198075
# RUN  80 , total integrated cost =  19.49614464944826
# RUN  90 , total integrated cost =  19.496144610625407
# RUN  100 , total integrated cost =  19.496144573235085
# RUN  110 , total integrated cost =  19.496144538129453
# RUN  120 , total integrated cost =  19.496144501834316
# RUN  130 , total integrated cost =  19.496144465326807
# RUN  140 , total integrated cost =  19.496144431790515
# RUN  150 , total integrated cost =  19.496144397501443
# RUN  160 , total integrated cost =  19.496144363407
# RUN  170 , total integrated cost =  19.496144330205006
# RUN  180 , total integrated cost =  19.496144297448936
# RUN  190 , total integrated cost =  19.496144265194985
# RUN  200 , total integrated cost =  19.496144233157104
# RUN  300 , total integrated cost =  19.496143951356387
# RUN  400 , total integrated cost =  19.496143704375463
# RUN  500 , total integrated cost =  19.496143496934213
# RUN  600 , total integrated cost =  19.49614331629886
# RUN  700 , total integrated cost =  19.496143160498487
# RUN  800 , total integrated cost =  19.49614302478404
# RUN  900 , total integrated cost =  19.496142906576722
# RUN  1000 , total integrated cost =  19.496142803780486
# RUN  1000 , total integrated cost =  19.496142803780486
# Improved over  1000  iterations in  42.64919570600614  seconds by  1.102235074768032e-05  percent.
# 13.231369616455215 [1.88345734e+01 8.79855294e-07]
# go back to ----- 4791
# ----- 4791
# set cost params:  0.05 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  19.496142803780486
# RUN  0 , total integrated cost =  19.496142803780486
# Gradient descend method:  None
# RUN  1 , total integrated cost =  19.49614280288523
# RUN  2 , total integrated cost =  19.496142801938728
# RUN  3 , total integrated cost =  19.496142800843117
# RUN  4 , total integrated cost =  19.496142799742206
# RUN  5 , total integrated cost =  19.49614279880577
# RUN  6 , total integrated cost =  19.496142797909368
# RUN  7 , total integrated cost =  19.496142797020514
# RUN  8 , total integrated cost =  19.496142796084197
# RUN  9 , total integrated cost =  19.49614279499551
# RUN  10 , total integrated cost =  19.496142793906966
# RUN  11 , total integrated cost =  19.49614279297756
# RUN  12 , total integrated cost =  19.49614279209027
# RUN  13 , total integrated cost =  19.49614279120779
# RUN  14 , total integrated cost =  19.496142790281542
# RUN  15 , total integrated cost =  19.49614278919976
# RUN  16 , total integrated cost =  19.49614278812343
# RUN  17 , total integrated cost =  19.496142787200988
# RUN  18 , total integrated cost =  19.49614278632272
# RUN  19 , total integrated cost =  19.496142785446576
# RUN  20 , total integrated cost =  19.49614278453029
# RUN  30 , total integrated cost =  19.49614277537838
# RUN  40 , total integrated cost =  19.496142766792428
# RUN  50 , total integrated cost =  19.496142757851526
# RUN  60 , total integrated cost =  19.49614274866001
# RUN  70 , total integrated cost =  19.496142739607798
# RUN  80 , total integrated cost =  19.496142731460473
# RUN  90 , total integrated cost =  19.496142723468843
# RUN  100 , total integrated cost =  19.496142714791493
# RUN  110 , total integrated cost =  19.496142706550618
# RUN  120 , total integrated cost =  19.496142698122835
# RUN  130 , total integrated cost =  19.496142690582186
# RUN  140 , total integrated cost =  19.496142683143535
# RUN  150 , total integrated cost =  19.49614267576634
# RUN  160 , total integrated cost =  19.496142667797418
# RUN  170 , total integrated cost =  19.496142659949136
# RUN  180 , total integrated cost =  19.496142652885354
# RUN  190 , total integrated cost =  19.496142645956482
# RUN  200 , total integrated cost =  19.49614263912128
# RUN  300 , total integrated cost =  19.496142573153193
# RUN  400 , total integrated cost =  19.496142515332828
# RUN  500 , total integrated cost =  19.49614246501362
# RUN  600 , total integrated cost =  19.496142419871784
# RUN  700 , total integrated cost =  19.49614238302624
# RUN  800 , total integrated cost =  19.496142350749057
# RUN  900 , total integrated cost =  19.496142322738194
# RUN  1000 , total integrated cost =  19.496142298676023
# RUN  1000 , total integrated cost =  19.496142298676023
# Improved over  1000  iterations in  44.33014680098859  seconds by  2.590791766010625e-06  percent.
# 13.213507691680412 [1.88354660e+01 8.79855294e-07]
# go back to ----- 4791
# ----- 4791
# set cost params:  0.05 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  19.496142298676023
# RUN  0 , total integrated cost =  19.496142298676023
# Gradient descend method:  None
# RUN  1 , total integrated cost =  19.496142298453645
# RUN  2 , total integrated cost =  19.49614229823507
# RUN  3 , total integrated cost =  19.496142298023013
# RUN  4 , total integrated cost =  19.496142297807147
# RUN  5 , total integrated cost =  19.496142297593668
# RUN  6 , total integrated cost =  19.496142297380427
# RUN  7 , total integrated cost =  19.496142297165907
# RUN  8 , total integrated cost =  19.496142296943532
# RUN  9 , total integrated cost =  19.496142296737077
# RUN  10 , total integrated cost =  19.496142296529936
# RUN  11 , total integrated cost =  19.49614229631026
# RUN  12 , total integrated cost =  19.496142296094916
# RUN  13 , total integrated cost =  19.49614229588546
# RUN  14 , total integrated cost =  19.496142295672765
# RUN  15 , total integrated cost =  19.49614229546278
# RUN  16 , total integrated cost =  19.49614229524045
# RUN  17 , total integrated cost =  19.49614229498356
# RUN  18 , total integrated cost =  19.49614229472487
# RUN  19 , total integrated cost =  19.49614229450521
# RUN  20 , total integrated cost =  19.49614229429467
# RUN  30 , total integrated cost =  19.496142291997522
# RUN  40 , total integrated cost =  19.496142289815822
# RUN  50 , total integrated cost =  19.496142287789176
# RUN  60 , total integrated cost =  19.496142285789833
# RUN  70 , total integrated cost =  19.49614228372832
# RUN  80 , total integrated cost =  19.49614228166485
# RUN  90 , total integrated cost =  19.496142279554572
# RUN  100 , total integrated cost =  19.49614227757086
# RUN  110 , total integrated cost =  19.49614227570933
# RUN  120 , total integrated cost =  19.496142273872895
# RUN  130 , total integrated cost =  19.496142271960135
# RUN  140 , total integrated cost =  19.496142269994394
# RUN  150 , total integrated cost =  19.496142268127493
# RUN  160 , total integrated cost =  19.496142266305213
# RUN  170 , total integrated cost =  19.496142264595534
# RUN  180 , total integrated cost =  19.4961422629089
# RUN  190 , total integrated cost =  19.496142261152464
# RUN  200 , total integrated cost =  19.496142259346644
# RUN  300 , total integrated cost =  19.496142243599138
# RUN  400 , total integrated cost =  19.496142229801848
# RUN  500 , total integrated cost =  19.496142217772437
# RUN  600 , total integrated cost =  19.49614220734471
# RUN  700 , total integrated cost =  19.496142198426405
# Control only changes marginally.
# RUN  752 , total integrated cost =  19.496142194403525
# Improved over  752  iterations in  31.989385561988456  seconds by  5.348365590407411e-07  percent.
# 13.206441142918658 [1.88358193e+01 8.79855294e-07]
# ----- 4792
# set cost params:  0.05 0.0 1.0
# 3.5555555555555554 0.5277083333333333
# shift ind =  0
# interpolate adjoint :  True True True
# initial cost =  21.119258096003467
# RUN  0 , total integrated cost =  21.119258096003467
# Gradient descend method:  None
# RUN  1 , total integrated cost =  21.10344249568679
# RUN  2 , total integrated cost =  21.095657809285477
# RUN  3 , total integrated cost =  21.09254405840612
# RUN  4 , total integrated cost =  21.089905198661135
# RUN  5 , total integrated cost =  21.087422322466526
# RUN  6 , total integrated cost =  21.08502493123171
# RUN  7 , total integrated cost =  21.082635279127913
# RUN  8 , total integrated cost =  21.08024983124843
# RUN  9 , total integrated cost =  21.07782745636477
# RUN  10 , total integrated cost =  21.075423057446486
# RUN  11 , total integrated cost =  21.073195372289344
# RUN  12 , total integrated cost =  21.071020610765586
# RUN  13 , total integrated cost =  21.068724010949634
# RUN  14 , total integrated cost =  21.066523127446896
# RUN  15 , total integrated cost =  21.06439852709721
# RUN  16 , total integrated cost =  21.062275898103817
# RUN  17 , total integrated cost =  21.06020104968866
# RUN  18 , total integrated cost =  21.05803062835259
# RUN  19 , total integrated cost =  21.055557126177604
# RUN  20 , total integrated cost =  21.05308828920674
# RUN  30 , total integrated cost =  21.033574878700442
# RUN  40 , total integrated cost =  21.019032408700816
# RUN  50 , total integrated cost =  21.006310870090253
# RUN  60 , total integrated cost =  20.991895480380823
# RUN  70 , total integrated cost =  20.980249932889713
# RUN  80 , total integrated cost =  20.968846678364972
# RUN  90 , total integrated cost =  20.95678459945146
# RUN  100 , total integrated cost =  20.945721153192903
# RUN  110 , total integrated cost =  20.936123584048033
# RUN  120 , total integrated cost =  20.92633270228575
# RUN  130 , total integrated cost =  20.915606048242168
# RUN  140 , total integrated cost =  20.90616705516516
# RUN  150 , total integrated cost =  20.897849996248762
# RUN  160 , total integrated cost =  20.890416761881998
# RUN  170 , total integrated cost =  20.88403826484273
# RUN  180 , total integrated cost =  20.87769382127306
# RUN  190 , total integrated cost =  20.87129982364278
# RUN  200 , total integrated cost =  20.865057963572998
# RUN  300 , total integrated cost =  20.81232788612586
# RUN  400 , total integrated cost =  20.77626657951471
# RUN  500 , total integrated cost =  20.748060186982084
# RUN  600 , total integrated cost =  20.731105012273304
# RUN  700 , total integrated cost =  20.720474485730143
# RUN  800 , total integrated cost =  20.712939584191492
# RUN  900 , total integrated cost =  20.70714566682454
# RUN  1000 , total integrated cost =  20.702744448121887
# RUN  1000 , total integrated cost =  20.702744448121887
# Improved over  1000  iterations in  43.64884695102228  seconds by  1.9721982940319265  percent.
# 19.769168619691072 [1.97142851e+01 8.79855294e-07]
# go back to ----- 4792
# ----- 4792
# set cost params:  0.05 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  20.702744448121887
# RUN  0 , total integrated cost =  20.702744448121887
# Gradient descend method:  None
# RUN  1 , total integrated cost =  20.702722843890538
# RUN  2 , total integrated cost =  20.702701854306223
# RUN  3 , total integrated cost =  20.702681295325135
# RUN  4 , total integrated cost =  20.70266076789474
# RUN  5 , total integrated cost =  20.702640118587325
# RUN  6 , total integrated cost =  20.70261892295127
# RUN  7 , total integrated cost =  20.70259911809945
# RUN  8 , total integrated cost =  20.70257952327219
# RUN  9 , total integrated cost =  20.702560523946584
# RUN  10 , total integrated cost =  20.702541674563342
# RUN  11 , total integrated cost =  20.702522925793772
# RUN  12 , total integrated cost =  20.702504105144893
# RUN  13 , total integrated cost =  20.702484893240506
# RUN  14 , total integrated cost =  20.70246551619529
# RUN  15 , total integrated cost =  20.702445094226164
# RUN  16 , total integrated cost =  20.70242511906988
# RUN  17 , total integrated cost =  20.702405639461563
# RUN  18 , total integrated cost =  20.70238608388334
# RUN  19 , total integrated cost =  20.702366494372278
# RUN  20 , total integrated cost =  20.70234627588468
# RUN  30 , total integrated cost =  20.702161251943856
# RUN  40 , total integrated cost =  20.70198065756527
# RUN  50 , total integrated cost =  20.701800757826007
# RUN  60 , total integrated cost =  20.701629509385345
# RUN  70 , total integrated cost =  20.70146328923819
# RUN  80 , total integrated cost =  20.701297245847016
# RUN  90 , total integrated cost =  20.701127648993914
# RUN  100 , total integrated cost =  20.70094765130605
# RUN  110 , total integrated cost =  20.700775900773262
# RUN  120 , total integrated cost =  20.700628184158642
# RUN  130 , total integrated cost =  20.70048273298365
# RUN  140 , total integrated cost =  20.700336804155874
# RUN  150 , total integrated cost =  20.700196340020145
# RUN  160 , total integrated cost =  20.700034278842132
# RUN  170 , total integrated cost =  20.699881303637284
# RUN  180 , total integrated cost =  20.699751022166115
# RUN  190 , total integrated cost =  20.699620301942346
# RUN  200 , total integrated cost =  20.699492047779234
# RUN  300 , total integrated cost =  20.698343371520437
# RUN  400 , total integrated cost =  20.697339667806766
# RUN  500 , total integrated cost =  20.696564574535117
# RUN  600 , total integrated cost =  20.69591587721462
# RUN  700 , total integrated cost =  20.695357180665354
# RUN  800 , total integrated cost =  20.69487402079029
# RUN  900 , total integrated cost =  20.694850967918278
# RUN  1000 , total integrated cost =  20.694834116920752
# RUN  1000 , total integrated cost =  20.694834116920752
# Improved over  1000  iterations in  40.96702565200394  seconds by  0.03820909455244248  percent.
# 18.035904086217446 [1.97930380e+01 8.79855294e-07]
# go back to ----- 4792
# ----- 4792
# set cost params:  0.05 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  20.694834116920752
# RUN  0 , total integrated cost =  20.694834116920752
# Gradient descend method:  None
# RUN  1 , total integrated cost =  20.694833969510096
# RUN  2 , total integrated cost =  20.69483383370921
# RUN  3 , total integrated cost =  20.69483369765502
# RUN  4 , total integrated cost =  20.69483355262001
# RUN  5 , total integrated cost =  20.69483341232478
# RUN  6 , total integrated cost =  20.69483327409542
# RUN  7 , total integrated cost =  20.694833128844728
# RUN  8 , total integrated cost =  20.694832995089065
# RUN  9 , total integrated cost =  20.694832861031777
# RUN  10 , total integrated cost =  20.694832718185282
# RUN  11 , total integrated cost =  20.694832579942524
# RUN  12 , total integrated cost =  20.694832443799676
# RUN  13 , total integrated cost =  20.694832300667095
# RUN  14 , total integrated cost =  20.69483216891115
# RUN  15 , total integrated cost =  20.694832036811462
# RUN  16 , total integrated cost =  20.694831896103917
# RUN  17 , total integrated cost =  20.694831759873693
# RUN  18 , total integrated cost =  20.6948316257696
# RUN  19 , total integrated cost =  20.694831484713337
# RUN  20 , total integrated cost =  20.694831318918585
# RUN  30 , total integrated cost =  20.69482982087603
# RUN  40 , total integrated cost =  20.694828395034943
# RUN  50 , total integrated cost =  20.694827177389502
# RUN  60 , total integrated cost =  20.69482594668634
# RUN  70 , total integrated cost =  20.694824745146406
# RUN  80 , total integrated cost =  20.694823569889373
# RUN  90 , total integrated cost =  20.694822422462806
# RUN  100 , total integrated cost =  20.69482130148016
# RUN  110 , total integrated cost =  20.694820204325232
# RUN  120 , total integrated cost =  20.694819132485616
# RUN  130 , total integrated cost =  20.694818084674214
# RUN  140 , total integrated cost =  20.694817058564126
# RUN  150 , total integrated cost =  20.694816055551186
# RUN  160 , total integrated cost =  20.694815074412723
# RUN  170 , total integrated cost =  20.69481412280366
# RUN  180 , total integrated cost =  20.694813205323683
# RUN  190 , total integrated cost =  20.694812330190473
# RUN  200 , total integrated cost =  20.694811487667558
# RUN  300 , total integrated cost =  20.69480336966708
# RUN  400 , total integrated cost =  20.69479699446045
# RUN  500 , total integrated cost =  20.694791637529583
# RUN  600 , total integrated cost =  20.69478712636863
# RUN  700 , total integrated cost =  20.694783261617893
# RUN  800 , total integrated cost =  20.69477983467403
# RUN  900 , total integrated cost =  20.694776530182104
# RUN  1000 , total integrated cost =  20.694773752161908
# RUN  1000 , total integrated cost =  20.694773752161908
# Improved over  1000  iterations in  42.821580336021725  seconds by  0.00029168998651130096  percent.
# 17.889095092817033 [1.98003181e+01 8.79855294e-07]
# go back to ----- 4792
# ----- 4792
# set cost params:  0.05 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  20.694773752161908
# RUN  0 , total integrated cost =  20.694773752161908
# Gradient descend method:  None
# RUN  1 , total integrated cost =  20.694773727235045
# RUN  2 , total integrated cost =  20.6947737035609
# RUN  3 , total integrated cost =  20.694773676152273
# RUN  4 , total integrated cost =  20.69477364891872
# RUN  5 , total integrated cost =  20.69477362530558
# RUN  6 , total integrated cost =  20.694773600588356
# RUN  7 , total integrated cost =  20.694773574925012
# RUN  8 , total integrated cost =  20.694773549420376
# RUN  9 , total integrated cost =  20.694773524781233
# RUN  10 , total integrated cost =  20.69477350146984
# RUN  11 , total integrated cost =  20.69477347435641
# RUN  12 , total integrated cost =  20.694773447552112
# RUN  13 , total integrated cost =  20.694773424203095
# RUN  14 , total integrated cost =  20.694773399868332
# RUN  15 , total integrated cost =  20.694773374488268
# RUN  16 , total integrated cost =  20.69477334938089
# RUN  17 , total integrated cost =  20.69477332502588
# RUN  18 , total integrated cost =  20.694773302071027
# RUN  19 , total integrated cost =  20.694773275249492
# RUN  20 , total integrated cost =  20.694773248866905
# RUN  30 , total integrated cost =  20.694773006481228
# RUN  40 , total integrated cost =  20.694772765155584
# RUN  50 , total integrated cost =  20.69477253066646
# RUN  60 , total integrated cost =  20.694772294370498
# RUN  70 , total integrated cost =  20.694772067514805
# RUN  80 , total integrated cost =  20.69477184169666
# RUN  90 , total integrated cost =  20.694771622323522
# RUN  100 , total integrated cost =  20.694771401165386
# RUN  110 , total integrated cost =  20.694771188803337
# RUN  120 , total integrated cost =  20.694770977393837
# RUN  130 , total integrated cost =  20.69477077192965
# RUN  140 , total integrated cost =  20.694770567298782
# RUN  150 , total integrated cost =  20.694770366000963
# RUN  160 , total integrated cost =  20.69477016798234
# RUN  170 , total integrated cost =  20.69476997550591
# RUN  180 , total integrated cost =  20.6947697814753
# RUN  190 , total integrated cost =  20.69476959513489
# RUN  200 , total integrated cost =  20.69476940964715
# RUN  300 , total integrated cost =  20.694767713928208
# RUN  400 , total integrated cost =  20.694766270519622
# RUN  500 , total integrated cost =  20.6947650366431
# RUN  600 , total integrated cost =  20.694763982853434
# RUN  700 , total integrated cost =  20.694763079670363
# RUN  800 , total integrated cost =  20.694762306648705
# RUN  900 , total integrated cost =  20.694761642866403
# RUN  1000 , total integrated cost =  20.694761073924628
# RUN  1000 , total integrated cost =  20.694761073924628
# Improved over  1000  iterations in  40.643475604010746  seconds by  6.12629905134554e-05  percent.
# 17.786373039188025 [1.98054415e+01 8.79855294e-07]
# go back to ----- 4792
# ----- 4792
# set cost params:  0.05 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  20.694761073924628
# RUN  0 , total integrated cost =  20.694761073924628
# Gradient descend method:  None
# RUN  1 , total integrated cost =  20.694761068801718
# RUN  2 , total integrated cost =  20.69476106388208
# RUN  3 , total integrated cost =  20.694761058260426
# RUN  4 , total integrated cost =  20.694761052591762
# RUN  5 , total integrated cost =  20.694761047741228
# RUN  6 , total integrated cost =  20.694761042598618
# RUN  7 , total integrated cost =  20.694761037327975
# RUN  8 , total integrated cost =  20.694761032017873
# RUN  9 , total integrated cost =  20.694761026948687
# RUN  10 , total integrated cost =  20.69476102209743
# RUN  11 , total integrated cost =  20.694761016530776
# RUN  12 , total integrated cost =  20.694761010943107
# RUN  13 , total integrated cost =  20.69476100614191
# RUN  14 , total integrated cost =  20.6947610010715
# RUN  15 , total integrated cost =  20.69476099585376
# RUN  16 , total integrated cost =  20.694760990618718
# RUN  17 , total integrated cost =  20.69476098560272
# RUN  18 , total integrated cost =  20.694760980818852
# RUN  19 , total integrated cost =  20.694760975306753
# RUN  20 , total integrated cost =  20.694760969798878
# RUN  30 , total integrated cost =  20.694760919519773
# RUN  40 , total integrated cost =  20.694760869404547
# RUN  50 , total integrated cost =  20.694760820051055
# RUN  60 , total integrated cost =  20.694760771447694
# RUN  70 , total integrated cost =  20.694760724135644
# RUN  80 , total integrated cost =  20.694760676978937
# RUN  90 , total integrated cost =  20.694760631091995
# RUN  100 , total integrated cost =  20.694760584784284
# RUN  110 , total integrated cost =  20.69476054026485
# RUN  120 , total integrated cost =  20.694760495903417
# RUN  130 , total integrated cost =  20.694760455046403
# RUN  140 , total integrated cost =  20.694760419524915
# RUN  150 , total integrated cost =  20.694760384206358
# RUN  160 , total integrated cost =  20.694760347653478
# RUN  170 , total integrated cost =  20.694760313483517
# RUN  180 , total integrated cost =  20.694760278880036
# RUN  190 , total integrated cost =  20.69476024431012
# RUN  200 , total integrated cost =  20.694760211437526
# RUN  300 , total integrated cost =  20.69475989693258
# RUN  400 , total integrated cost =  20.694759621832784
# RUN  500 , total integrated cost =  20.694759378157688
# RUN  600 , total integrated cost =  20.694759164425104
# RUN  700 , total integrated cost =  20.694758975982293
# RUN  800 , total integrated cost =  20.694758809755506
# RUN  900 , total integrated cost =  20.694758664038513
# RUN  1000 , total integrated cost =  20.69475853497023
# RUN  1000 , total integrated cost =  20.69475853497023
# Improved over  1000  iterations in  41.722840945003554  seconds by  1.2268585209085359e-05  percent.
# 17.741319663591888 [1.98076917e+01 8.79855294e-07]
# go back to ----- 4792
# ----- 4792
# set cost params:  0.05 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  20.69475853497023
# RUN  0 , total integrated cost =  20.69475853497023
# Gradient descend method:  None
# RUN  1 , total integrated cost =  20.69475853379198
# RUN  2 , total integrated cost =  20.69475853261121
# RUN  3 , total integrated cost =  20.694758531436314
# RUN  4 , total integrated cost =  20.69475853026127
# RUN  5 , total integrated cost =  20.694758529085547
# RUN  6 , total integrated cost =  20.694758527915567
# RUN  7 , total integrated cost =  20.694758526743776
# RUN  8 , total integrated cost =  20.694758525573018
# RUN  9 , total integrated cost =  20.694758524407966
# RUN  10 , total integrated cost =  20.69475852323941
# RUN  11 , total integrated cost =  20.69475852207364
# RUN  12 , total integrated cost =  20.69475852091345
# RUN  13 , total integrated cost =  20.694758519748174
# RUN  14 , total integrated cost =  20.694758518587342
# RUN  15 , total integrated cost =  20.694758517431833
# RUN  16 , total integrated cost =  20.69475851626646
# RUN  17 , total integrated cost =  20.694758515078505
# RUN  18 , total integrated cost =  20.694758513873307
# RUN  19 , total integrated cost =  20.69475851260396
# RUN  20 , total integrated cost =  20.694758511357747
# RUN  30 , total integrated cost =  20.694758499487005
# RUN  40 , total integrated cost =  20.69475848819717
# RUN  50 , total integrated cost =  20.694758476618407
# RUN  60 , total integrated cost =  20.69475846532911
# RUN  70 , total integrated cost =  20.694758454455087
# RUN  80 , total integrated cost =  20.694758443382117
# RUN  90 , total integrated cost =  20.69475843055028
# RUN  100 , total integrated cost =  20.694758417913295
# RUN  110 , total integrated cost =  20.69475840546848
# RUN  120 , total integrated cost =  20.69475839320981
# RUN  130 , total integrated cost =  20.694758381116003
# RUN  140 , total integrated cost =  20.694758369204212
# RUN  150 , total integrated cost =  20.694758357483906
# RUN  160 , total integrated cost =  20.694758345941946
# RUN  170 , total integrated cost =  20.69475833457585
# RUN  180 , total integrated cost =  20.694758323355416
# RUN  190 , total integrated cost =  20.694758312318733
# RUN  200 , total integrated cost =  20.694758301447152
# RUN  300 , total integrated cost =  20.69475820118319
# RUN  400 , total integrated cost =  20.694758114910144
# RUN  500 , total integrated cost =  20.694758049630565
# RUN  600 , total integrated cost =  20.694757993842785
# RUN  700 , total integrated cost =  20.6947579449077
# RUN  800 , total integrated cost =  20.694757899700875
# RUN  900 , total integrated cost =  20.694757856672773
# RUN  1000 , total integrated cost =  20.69475782162835
# RUN  1000 , total integrated cost =  20.69475782162835
# Improved over  1000  iterations in  44.181372638995526  seconds by  3.446968847242715e-06  percent.
# 17.71657641932403 [1.98089281e+01 8.79855294e-07]
# go back to ----- 4792
# ----- 4792
# set cost params:  0.05 0.0 1.0
# interpolate adjoint :  True True True
# ...
# RUN  11 , total integrated cost =  34.84855352492605
# RUN  12 , total integrated cost =  34.8485534258016
# RUN  13 , total integrated cost =  34.84855332518141
# RUN  14 , total integrated cost =  34.84855322494046
# RUN  15 , total integrated cost =  34.84855312620797
# RUN  16 , total integrated cost =  34.84855302477993
# RUN  17 , total integrated cost =  34.8485529275707
# RUN  18 , total integrated cost =  34.84855283055923
# RUN  19 , total integrated cost =  34.84855272968838
# RUN  20 , total integrated cost =  34.84855263162986
# RUN  30 , total integrated cost =  34.8485516521524
# RUN  40 , total integrated cost =  34.848550688645595
# RUN  50 , total integrated cost =  34.84854974570943
# RUN  60 , total integrated cost =  34.848548813057825
# RUN  70 , total integrated cost =  34.84854789554757
# RUN  80 , total integrated cost =  34.84854699761028
# RUN  90 , total integrated cost =  34.84854610935821
# RUN  100 , total integrated cost =  34.848545235464854
# RUN  110 , total integrated cost =  34.8485443756802
# RUN  120 , total integrated cost =  34.848543534056276
# RUN  130 , total integrated cost =  34.8485427015334
# RUN  140 , total integrated cost =  34.84854188239432
# RUN  150 , total integrated cost =  34.848541080546326
# RUN  160 , total integrated cost =  34.84854028727278
# RUN  170 , total integrated cost =  34.84853950669843
# RUN  180 , total integrated cost =  34.848538742590556
# RUN  190 , total integrated cost =  34.848537986563
# RUN  200 , total integrated cost =  34.84853724258792
# RUN  300 , total integrated cost =  34.84853042981209
# RUN  400 , total integrated cost =  34.848524610359995
# RUN  500 , total integrated cost =  34.84851962916973
# RUN  600 , total integrated cost =  34.848515357154255
# RUN  700 , total integrated cost =  34.848511686557785
# RUN  800 , total integrated cost =  34.848508527189765
# RUN  900 , total integrated cost =  34.84850580336261
# RUN  1000 , total integrated cost =  34.84850345139499
# RUN  1000 , total integrated cost =  34.84850345139499
# Improved over  1000  iterations in  47.32367748901015  seconds by  0.00014687168950899832  percent.
# 193.53739655825288 [2.51716327e+01 8.79855294e-07]
# go back to ----- 4798
# ----- 4798
# set cost params:  0.05 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  34.84850345139499
# RUN  0 , total integrated cost =  34.84850345139499
# Gradient descend method:  None
# RUN  1 , total integrated cost =  34.84850343006907
# RUN  2 , total integrated cost =  34.8485034086242
# RUN  3 , total integrated cost =  34.84850338649654
# RUN  4 , total integrated cost =  34.84850336480932
# RUN  5 , total integrated cost =  34.84850334307516
# RUN  6 , total integrated cost =  34.84850332113053
# RUN  7 , total integrated cost =  34.84850329980567
# RUN  8 , total integrated cost =  34.84850327758781
# RUN  9 , total integrated cost =  34.8485032565505
# RUN  10 , total integrated cost =  34.84850323530758
# RUN  11 , total integrated cost =  34.84850321348496
# RUN  12 , total integrated cost =  34.848503192000116
# RUN  13 , total integrated cost =  34.84850317056897
# RUN  14 , total integrated cost =  34.84850314882712
# RUN  15 , total integrated cost =  34.84850312780317
# RUN  16 , total integrated cost =  34.84850310578858
# RUN  17 , total integrated cost =  34.84850308503621
# RUN  18 , total integrated cost =  34.848503063992894
# RUN  19 , total integrated cost =  34.84850304247146
# RUN  20 , total integrated cost =  34.8485030211866
# RUN  30 , total integrated cost =  34.848502810164206
# RUN  40 , total integrated cost =  34.84850260328356
# RUN  50 , total integrated cost =  34.84850239826578
# RUN  60 , total integrated cost =  34.84850219620641
# RUN  70 , total integrated cost =  34.848501997060545
# RUN  80 , total integrated cost =  34.84850180179013
# RUN  90 , total integrated cost =  34.84850160828962
# RUN  100 , total integrated cost =  34.84850141757139
# RUN  110 , total integrated cost =  34.84850123056801
# RUN  120 , total integrated cost =  34.84850104524182
# RUN  130 , total integrated cost =  34.84850086257307
# RUN  140 , total integrated cost =  34.84850068346555
# RUN  150 , total integrated cost =  34.84850050594772
# RUN  160 , total integrated cost =  34.848500330968506
# RUN  170 , total integrated cost =  34.848500158489884
# RUN  180 , total integrated cost =  34.84849998934578
# RUN  190 , total integrated cost =  34.848499821713474
# RUN  200 , total integrated cost =  34.84849965647045
# RUN  300 , total integrated cost =  34.84849812959172
# RUN  400 , total integrated cost =  34.848496804225114
# RUN  500 , total integrated cost =  34.84849565251752
# RUN  600 , total integrated cost =  34.84849465070033
# RUN  700 , total integrated cost =  34.848493778448415
# RUN  800 , total integrated cost =  34.84849301834639
# RUN  900 , total integrated cost =  34.84849235544552
# RUN  1000 , total integrated cost =  34.84849177689011
# RUN  1000 , total integrated cost =  34.84849177689011
# Improved over  1000  iterations in  46.33036818099208  seconds by  3.3500735270308724e-05  percent.
# 193.39051067004968 [2.51789654e+01 8.79855294e-07]
# go back to ----- 4798
# ----- 4798
# set cost params:  0.05 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  34.84849177689011
# RUN  0 , total integrated cost =  34.84849177689011
# Gradient descend method:  None
# RUN  1 , total integrated cost =  34.84849177160585
# RUN  2 , total integrated cost =  34.84849176631403
# RUN  3 , total integrated cost =  34.84849176082853
# RUN  4 , total integrated cost =  34.84849175547641
# RUN  5 , total integrated cost =  34.84849175008638
# RUN  6 , total integrated cost =  34.848491744670284
# RUN  7 , total integrated cost =  34.84849173937967
# RUN  8 , total integrated cost =  34.848491733895635
# RUN  9 , total integrated cost =  34.84849172867835
# RUN  10 , total integrated cost =  34.84849172343265
# RUN  11 , total integrated cost =  34.84849171801799
# RUN  12 , total integrated cost =  34.84849171271206
# RUN  13 , total integrated cost =  34.848491707392505
# RUN  14 , total integrated cost =  34.848491702022635
# RUN  15 , total integrated cost =  34.848491696802
# RUN  16 , total integrated cost =  34.84849169136436
# RUN  17 , total integrated cost =  34.84849168621327
# RUN  18 , total integrated cost =  34.848491681013215
# RUN  19 , total integrated cost =  34.84849167566857
# RUN  20 , total integrated cost =  34.848491670408364
# RUN  30 , total integrated cost =  34.84849161810026
# RUN  40 , total integrated cost =  34.84849156649845
# RUN  50 , total integrated cost =  34.848491515852764
# RUN  60 , total integrated cost =  34.84849146562182
# RUN  70 , total integrated cost =  34.84849141606814
# RUN  80 , total integrated cost =  34.84849136743468
# RUN  90 , total integrated cost =  34.848491319195716
# RUN  100 , total integrated cost =  34.84849127160625
# RUN  110 , total integrated cost =  34.84849122490248
# RUN  120 , total integrated cost =  34.84849117857401
# RUN  130 , total integrated cost =  34.84849113286849
# RUN  140 , total integrated cost =  34.848491087777354
# RUN  150 , total integrated cost =  34.848491043519374
# RUN  160 , total integrated cost =  34.848490999620886
# RUN  170 , total integrated cost =  34.848490956311764
# RUN  180 , total integrated cost =  34.848490913804696
# RUN  190 , total integrated cost =  34.848490871639655
# RUN  200 , total integrated cost =  34.848490830039964
# RUN  300 , total integrated cost =  34.84849044393561
# RUN  400 , total integrated cost =  34.84849010614992
# RUN  500 , total integrated cost =  34.848489810494016
# RUN  600 , total integrated cost =  34.848489551599414
# RUN  700 , total integrated cost =  34.84848932480381
# RUN  800 , total integrated cost =  34.848489126054254
# RUN  900 , total integrated cost =  34.848488951823796
# RUN  1000 , total integrated cost =  34.84848879904055
# RUN  1000 , total integrated cost =  34.84848879904055
# Improved over  1000  iterations in  59.13166115398053  seconds by  8.545131805703932e-06  percent.
# 193.31357570478391 [2.51828091e+01 8.79855294e-07]
# go back to ----- 4798
# ----- 4798
# set cost params:  0.05 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  34.84848879904055
# RUN  0 , total integrated cost =  34.84848879904055
# Gradient descend method:  None
# RUN  1 , total integrated cost =  34.848488797637344
# RUN  2 , total integrated cost =  34.84848879616561
# RUN  3 , total integrated cost =  34.84848879477986
# RUN  4 , total integrated cost =  34.848488793372795
# RUN  5 , total integrated cost =  34.848488791935374
# RUN  6 , total integrated cost =  34.848488790511745
# RUN  7 , total integrated cost =  34.84848878909999
# RUN  8 , total integrated cost =  34.84848878765878
# RUN  9 , total integrated cost =  34.848488786273734
# RUN  10 , total integrated cost =  34.84848878481391
# RUN  11 , total integrated cost =  34.84848878344534
# RUN  12 , total integrated cost =  34.84848878205001
# RUN  13 , total integrated cost =  34.848488780630746
# RUN  14 , total integrated cost =  34.84848877921888
# RUN  15 , total integrated cost =  34.848488777825175
# RUN  16 , total integrated cost =  34.84848877639576
# RUN  17 , total integrated cost =  34.84848877502867
# RUN  18 , total integrated cost =  34.84848877358064
# RUN  19 , total integrated cost =  34.848488772229054
# RUN  20 , total integrated cost =  34.84848877084534
# RUN  30 , total integrated cost =  34.848488756985326
# RUN  40 , total integrated cost =  34.848488743306675
# RUN  50 , total integrated cost =  34.84848872987685
# RUN  60 , total integrated cost =  34.84848871655052
# RUN  70 , total integrated cost =  34.84848870339845
# RUN  80 , total integrated cost =  34.8484886904863
# RUN  90 , total integrated cost =  34.84848867767281
# RUN  100 , total integrated cost =  34.84848866502679
# RUN  110 , total integrated cost =  34.848488652546
# RUN  120 , total integrated cost =  34.84848864029139
# RUN  130 , total integrated cost =  34.848488628131655
# RUN  140 , total integrated cost =  34.84848861613073
# RUN  150 , total integrated cost =  34.84848860434791
# RUN  160 , total integrated cost =  34.84848859265548
# RUN  170 , total integrated cost =  34.84848858111573
# RUN  180 , total integrated cost =  34.84848856978624
# RUN  190 , total integrated cost =  34.84848855854301
# RUN  200 , total integrated cost =  34.848488547446415
# RUN  300 , total integrated cost =  34.848488444260205
# RUN  400 , total integrated cost =  34.84848835368657
# RUN  500 , total integrated cost =  34.848488274168425
# RUN  600 , total integrated cost =  34.8484882043439
# RUN  700 , total integrated cost =  34.84848814302134
# RUN  800 , total integrated cost =  34.848488089158536
# RUN  900 , total integrated cost =  34.84848804184174
# RUN  1000 , total integrated cost =  34.84848800026954
# RUN  1000 , total integrated cost =  34.84848800026954
# Improved over  1000  iterations in  53.88534632200026  seconds by  2.292125259373279e-06  percent.
# 193.2731604247776 [2.51848291e+01 8.79855294e-07]
# go back to ----- 4798
# ----- 4798
# set cost params:  0.05 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  34.84848800026954
# RUN  0 , total integrated cost =  34.84848800026954
# Gradient descend method:  None
# RUN  1 , total integrated cost =  34.84848799988444
# RUN  2 , total integrated cost =  34.84848799948646
# RUN  3 , total integrated cost =  34.848487999106815
# RUN  4 , total integrated cost =  34.848487998725986
# RUN  5 , total integrated cost =  34.84848799833187
# RUN  6 , total integrated cost =  34.848487997946656
# RUN  7 , total integrated cost =  34.84848799755938
# RUN  8 , total integrated cost =  34.84848799716947
# RUN  9 , total integrated cost =  34.84848799678934
# RUN  10 , total integrated cost =  34.84848799639449
# RUN  11 , total integrated cost =  34.848487996019465
# RUN  12 , total integrated cost =  34.84848799564177
# RUN  13 , total integrated cost =  34.84848799525258
# RUN  14 , total integrated cost =  34.84848799487047
# RUN  15 , total integrated cost =  34.84848799448808
# RUN  16 , total integrated cost =  34.84848799410135
# RUN  17 , total integrated cost =  34.84848799372606
# RUN  18 , total integrated cost =  34.84848799333435
# RUN  19 , total integrated cost =  34.848487992963896
# RUN  20 , total integrated cost =  34.848487992589305
# RUN  30 , total integrated cost =  34.84848798881282
# RUN  40 , total integrated cost =  34.84848798508511
# RUN  50 , total integrated cost =  34.848487981424825
# RUN  60 , total integrated cost =  34.8484879777919
# RUN  70 , total integrated cost =  34.84848797423666
# RUN  80 , total integrated cost =  34.848487970931814
# RUN  90 , total integrated cost =  34.848487967979956
# RUN  100 , total integrated cost =  34.84848796492056
# RUN  110 , total integrated cost =  34.8484879617962
# RUN  120 , total integrated cost =  34.84848795892828
# RUN  130 , total integrated cost =  34.84848795625856
# RUN  140 , total integrated cost =  34.84848795377075
# RUN  150 , total integrated cost =  34.84848795166162
# Control only changes marginally.
# RUN  150 , total integrated cost =  34.84848795166162
# Improved over  150  iterations in  6.270253341994248  seconds by  1.394835891233015e-07  percent.
# 193.26978469421283 [2.51849978e+01 8.79855294e-07]
# ----- 4799
# set cost params:  0.05 0.0 1.0
# 16.0 0.5277083333333333
# shift ind =  0
# interpolate adjoint :  True True True
# initial cost =  38.031818851379825
# RUN  0 , total integrated cost =  38.031818851379825
# Gradient descend method:  None
# RUN  1 , total integrated cost =  38.03181884672451
# RUN  2 , total integrated cost =  38.031818841832944
# RUN  3 , total integrated cost =  38.031818838272486
# RUN  4 , total integrated cost =  38.03181883473248
# RUN  5 , total integrated cost =  38.03181883158325
# RUN  6 , total integrated cost =  38.031818828535314
# RUN  7 , total integrated cost =  38.03181882577485
# RUN  8 , total integrated cost =  38.031818822801505
# RUN  9 , total integrated cost =  38.03181882005692
# RUN  10 , total integrated cost =  38.03181881715503
# RUN  11 , total integrated cost =  38.0318188144235
# RUN  12 , total integrated cost =  38.03181881158945
# RUN  13 , total integrated cost =  38.0318188088685
# RUN  14 , total integrated cost =  38.03181880609934
# RUN  15 , total integrated cost =  38.03181880338732
# RUN  16 , total integrated cost =  38.03181880068037
# RUN  17 , total integrated cost =  38.031818797976044
# RUN  18 , total integrated cost =  38.03181879532881
# RUN  19 , total integrated cost =  38.03181879262868
# RUN  20 , total integrated cost =  38.03181878972083
# RUN  30 , total integrated cost =  38.03181876416851
# RUN  40 , total integrated cost =  38.03181873991922
# RUN  50 , total integrated cost =  38.03181872054927
# RUN  60 , total integrated cost =  38.031818700221024
# RUN  70 , total integrated cost =  38.0318186754189
# RUN  80 , total integrated cost =  38.03181864753702
# RUN  90 , total integrated cost =  38.031818621138676
# RUN  100 , total integrated cost =  38.03181859608783
# RUN  110 , total integrated cost =  38.03181854232575
# RUN  120 , total integrated cost =  38.031818455503625
# RUN  130 , total integrated cost =  38.031818402222655
# RUN  140 , total integrated cost =  38.03181839082656
# RUN  150 , total integrated cost =  38.03181833554607
# RUN  160 , total integrated cost =  38.03181828654084
# RUN  170 , total integrated cost =  38.03181826468035
# RUN  180 , total integrated cost =  38.03181825098132
# RUN  190 , total integrated cost =  38.03181822212143
# RUN  200 , total integrated cost =  38.0318181993765
# RUN  300 , total integrated cost =  38.03181808430752
# Control only changes marginally.
# RUN  321 , total integrated cost =  38.03181806777596
# Improved over  321  iterations in  14.874679622997064  seconds by  2.060390187352823e-06  percent.
# 256.93008939196943 [2.51853127e+01 8.79855294e-07]
# ----- 4800
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_5634/485845009.py in <module>
#      27             step = step3
#      28
# ---> 29         if convergence_[i][j]:
#      30             j += step
#      31             continue
#
# IndexError: index 4800 is out of bounds for axis 0 with size 4800

# %%
bestControl_maxW = np.array( [[None] * len(t_pen)] * len(exc) )
bestState_maxW = np.array( [[None] * len(t_pen)] * len(exc) )
cost_maxW = np.array( [[None] * len(t_pen)] * len(exc) )
costnode_maxW = np.array( [[None] * len(t_pen)] * len(exc) )
weights_maxW = np.array( [[None] * len(t_pen)] * len(exc) )
convergence_maxW = np.array( [[None] * len(t_pen)] * len(exc) )

file_maxW = 'down_Wmax.pickle'

# %%
if os.path.isfile(file_maxW) :
    print("file found")
    
    with open(file_maxW,'rb') as f:
        load_array = pickle.load(f)

    bestControl_maxW = load_array[0]
    bestState_maxW = load_array[1]
    cost_maxW = load_array[2]
    costnode_maxW = load_array[3]
    weights_maxW = load_array[4]
# Out:
# file found

# %%
tol = 1e-8

for i in i_range:
    print('------------', i)
    j = 0

    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.

    aln.params.duration = dur

    while not convergence_maxW[i][j]:
        dur = d_array[j]
        aln.params.duration = dur
        wp = 1. / (dur - t_pen[j] * dur)

        setinit(initVars[i], aln)

        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        control0 = aln.getZeroControl()
        if type(bestControl_maxW[i][j]) == type(None):
            max_it = 10
            control0 = bestControl_[i][0][:,:,n_pre-1:-n_post+1]
            weight_ = ( cost_uncontrolled[i]
                       - wp * sum(costnode_[i][j][0][0][:]) ) / sum( costnode_[i][j][2][0][:] )
            cost.setParams(wp, weight_ * factor_we, weight_ * factor_ws)
            weights_maxW[i][j] = cost.getParams()
        else:
            control0 = bestControl_maxW[i][j][:,:,n_pre-1:-n_post+1]
            weight_ = ( cost_uncontrolled[i]
                       - wp * sum(costnode_maxW[i][j][0][0][:]) ) / sum( costnode_maxW[i][j][2][0][:] )
            cost.setParams(wp, weight_ * factor_we, weight_ * factor_ws)
            weights_maxW[i][j] = cost.getParams()
            max_it = int(100)

        bestControl_maxW[i][j], bestState_maxW[i][j], cost_maxW[i][j], runtime_, grad_, phi_, phi1_, costnode_maxW[i][j] = aln.A1(
            control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
            prec_variables_ = p_var, transition_time_ = t_pen[j])

        if cost_maxW[i][j][2] == 0.:
            convergence_maxW[i][j] = True

        print('cost splitting : ', costnode_maxW[i][j][0][0][0], costnode_maxW[i][j][2][0][:2])

        with open(file_maxW,'wb') as f:
            pickle.dump([bestControl_maxW, bestState_maxW, cost_maxW, costnode_maxW, weights_maxW], f)
# Out:
# ------------ 0
# set cost params:  0.05 0.0 190.47003207793207
# interpolate adjoint :  True True True
# initial cost =  634.4855803880291
# RUN  0 , total integrated cost =  634.4855803880291
# Gradient descend method:  None
# RUN  1 , total integrated cost =  634.4855803880291
# Control only changes marginally.
# RUN  1 , total integrated cost =  634.4855803880291
# Improved over  1  iterations in  0.5308340739866253  seconds by  0.0  percent.
# cost splitting :  2.2385916167652766e-05 [1.25115182e-15 3.33115699e+00]

# %%
i=0
for j in range(1,4800,1):
    convergence_maxW[i][j] = None
    bestControl_maxW[i][j] = None

# %%
tol = 1e-5

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    j = 0
    step = step1

    k = 0
    
    ind_max_c = 1
    if i == 1:
        ind_max_c = 0

    while j < 4800:

        if j == 0:
            j += step
            continue
            
        if not convergence_maxW[i][j-step]:
            if j - step > 0:
                j -= step
                print('go back to -----', j)

        print('-----', j)
        
        if j >= 3001:
            step = step2
        if j >=4791:
            step = step3

        if convergence_maxW[i][j]:
            j += step
            continue

        dur = d_array[j]
        T = 5001 - j
        aln.params.duration = dur
        setinit(initVars[i], aln)
        wp = 1. / (dur - t_pen[j] * dur)

        max_it = 1000

        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        if type(bestControl_maxW[i][j]) == type(None):
            max_percent_prev = (np.argmax(np.abs(bestControl_maxW[i][j-step]), axis=2)[0,ind_max_c] - 100) / (T-200)
            shift_ind = 0
            print(max_percent_prev, max_percent[i])
            if j < 4000:
                while max_percent_prev > max_percent[i]:
                    shift_ind += 1
                    max_percent_prev = (np.argmax(np.abs(bestControl_maxW[i][j-step]), axis=2)[0,ind_max_c] - 100 - shift_ind) / (T-200)

            control0 = np.zeros(( bestControl_maxW[i][j-step][:,:,100:-(100+step)].shape ))
            print('shift ind = ', shift_ind)
            if shift_ind != 0:
                control0[:,:,:-shift_ind] = 1. * bestControl_maxW[i][j-step][:,:,100+shift_ind:-(100+step)]
            else:
                control0[:,:,:] = 1. * bestControl_maxW[i][j-step][:,:,100:-(100+step)]
                
            weight_ = ( cost_uncontrolled[i] * (1. - t_pen[0]) / (1. - t_pen[j])
                          - wp * sum(costnode_maxW[i][j-step][0][0][:]) ) / sum( costnode_maxW[i][j-step][2][0][:] )
        
        else:
            if bestControl_maxW[i][j].shape[2] == T+200:
                control0 = bestControl_maxW[i][j][:,:,100:-100]
                weight_ = ( cost_uncontrolled[i]
                           - wp * sum(costnode_maxW[i][j][0][0][:]) ) / sum( costnode_maxW[i][j][2][0][:] )
            else:
                control0 = bestControl_maxW[i][j][:,:,100:-(100+j)]
                
                weight_ = ( cost_uncontrolled[i]
                           - wp * sum(costnode_maxW[i][j][0][0][:]) ) / sum( costnode_maxW[i][j][2][0][:] )
             
        """
        if j >= 3800:
            if k == 0:
                weight_ *= 0.6
                max_it = 100
            elif k < 3:
                weight_ *= 0.8
                max_it = 100
            elif k < 5:
                weight_ *= 0.9
                max_it = 100
        """
            
            
        cost.setParams(wp, weight_ * factor_we, weight_ * factor_ws)
        weights_maxW[i][j] = cost.getParams()

        bestControl_maxW[i][j], bestState_maxW[i][j], cost_maxW[i][j], runtime_, grad_, phi_, phi1_, costnode_maxW[i][j] = aln.A1(
            control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
            prec_variables_ = p_var, transition_time_ = t_pen[j])
        
        k +=1

        print(costnode_maxW[i][j][0][0][:2], costnode_maxW[i][j][2][0][:2])

        if cost_maxW[i][j][2] == 0.:
            convergence_maxW[i][j] = True
            if j >= 3000:
                step = step2
            if j >=4790:
                step = step3

        with open(file_maxW,'wb') as f:
            pickle.dump([bestControl_maxW, bestState_maxW, cost_maxW, costnode_maxW, weights_maxW], f)

        j += step
# Out:
# -------  0 0.4500000000000001 0.4750000000000002
# ----- 100
# 0.5388215273346096 0.5277083333333333
# shift ind =  53
# set cost params:  0.05 0.0 186.6606314296527
# interpolate adjoint :  True True True
# initial cost =  621.7958778258002
# RUN  0 , total integrated cost =  621.7958778258002
# Gradient descend method:  None
# RUN  1 , total integrated cost =  621.7958778258002
# Control only changes marginally.
# RUN  1 , total integrated cost =  621.7958778258002
# Improved over  1  iterations in  0.5158967129827943  seconds by  0.0  percent.
# [0.00020332 0.        ] [1.25115182e-15 3.33115699e+00]
# ----- 200
# 0.5390132579873941 0.5277083333333333
# shift ind =  53
# set cost params:  0.05 0.0 182.85122806593242
# interpolate adjoint :  True True True
# initial cost =  609.1062383115482
# RUN  0 , total integrated cost =  609.1062383115482
# Gradient descend method:  None
# RUN  1 , total integrated cost =  609.1062383115482
# Control only changes marginally.
# RUN  1 , total integrated cost =  609.1062383115482
# Improved over  1  iterations in  0.6450163710105699  seconds by  0.0  percent.
# [0.00182615 0.        ] [1.25115181e-15 3.33115699e+00]
# ----- 300
# 0.539213508109309 0.5277083333333333
# shift ind =  52
# set cost params:  0.05 0.0 179.04180306001473
# interpolate adjoint :  True True True
# initial cost =  596.4172091399703
# RUN  0 , total integrated cost =  596.4172091399703
# Gradient descend method:  None
# RUN  1 , total integrated cost =  596.4172091399703
# Control only changes marginally.
# RUN  1 , total integrated cost =  596.4172091399703
# Improved over  1  iterations in  0.7051767490047496  seconds by  0.0  percent.
# [0.01709776 0.        ] [1.25115172e-15 3.33115699e+00]
# ----- 400
# 0.5396500795273801 0.5277083333333333
# shift ind =  53
# set cost params:  0.05 0.0 175.23217318945086
# interpolate adjoint :  True True True
# initial cost =  583.7334563289744
# RUN  0 , total integrated cost =  583.7334563289744
# Gradient descend method:  None
# RUN  1 , total integrated cost =  583.7334563289744
# Control only changes marginally.
# RUN  1 , total integrated cost =  583.7334563289744
# Improved over  1  iterations in  0.8335783779912163  seconds by  0.0  percent.
# [0.15154558 0.        ] [1.25115162e-15 3.33115699e+00]
# ----- 500
# 0.5398744478028366 0.5277083333333333
# shift ind =  53
# set cost params:  0.05 0.0 171.4207545118151
# interpolate adjoint :  True True True
# initial cost =  571.0950214868648
# RUN  0 , total integrated cost =  571.0950214868648
# Gradient descend method:  None
# RUN  1 , total integrated cost =  571.0950214868648
# Control only changes marginally.
# RUN  1 , total integrated cost =  571.0950214868648
# Improved over  1  iterations in  0.7772175489808433  seconds by  0.0  percent.
# [1.31152855 0.        ] [1.25115161e-15 3.33115699e+00]
# ----- 600
# 0.5401094977386337 0.5277083333333333
# shift ind =  53
# set cost params:  0.05 0.0 167.5939427542366
# interpolate adjoint :  True True True
# initial cost =  558.8092645452094
# RUN  0 , total integrated cost =  558.8092645452094
# Gradient descend method:  None
# RUN  1 , total integrated cost =  558.8092645452094
# Control only changes marginally.
# RUN  1 , total integrated cost =  558.8092645452094
# Improved over  1  iterations in  0.7914660800015554  seconds by  0.0  percent.
# [10.55060489  0.        ] [1.25115161e-15 3.33115699e+00]
# ----- 700
# 0.5403560107290905 0.5277083333333333
# shift ind =  52
# set cost params:  0.05 0.0 163.64586542216585
# interpolate adjoint :  True True True
# initial cost =  548.8156764808364
# RUN  0 , total integrated cost =  548.8156764808364
# Gradient descend method:  None
# RUN  1 , total integrated cost =  548.8156764808364
# Control only changes marginally.
# RUN  1 , total integrated cost =  548.8156764808364
# Improved over  1  iterations in  0.6215735909936484  seconds by  0.0  percent.
# [73.71215225  0.        ] [1.25115161e-15 3.33115699e+00]
# ----- 800
# 0.540864783804049 0.5277083333333333
# shift ind =  53
# set cost params:  0.05 0.0 158.8884225903338
# interpolate adjoint :  True True True
# initial cost =  546.829021160448
# RUN  0 , total integrated cost =  546.829021160448
# Gradient descend method:  None
# RUN  1 , total integrated cost =  546.829021160448
# Control only changes marginally.
# RUN  1 , total integrated cost =  546.829021160448
# Improved over  1  iterations in  0.5888862650026567  seconds by  0.0  percent.
# [350.93482561   0.        ] [1.25115161e-15 3.33115699e+00]
# ----- 900
# 0.5411432965906178 0.5277083333333333
# shift ind =  53
# set cost params:  0.05 0.0 150.91796508712184
# interpolate adjoint :  True True True
# initial cost =  557.2573836956923
# RUN  0 , total integrated cost =  557.2573836956923
# Gradient descend method:  None
# RUN  1 , total integrated cost =  557.2573836956923
# Control only changes marginally.
# RUN  1 , total integrated cost =  557.2573836956923
# Improved over  1  iterations in  0.9400457479932811  seconds by  0.0  percent.
# [1090.51898221    0.        ] [1.25115161e-15 3.33115699e+00]
# ----- 1000
# 0.5414364640883977 0.5277083333333333
# shift ind =  53
# set cost params:  0.05 0.0 136.0075542275174
# interpolate adjoint :  True True True
# initial cost =  571.6139156583776
# RUN  0 , total integrated cost =  571.6139156583776
# Gradient descend method:  None
# RUN  1 , total integrated cost =  571.6139156583776
# Control only changes marginally.
# RUN  1 , total integrated cost =  571.6139156583776
# Improved over  1  iterations in  0.8236469330149703  seconds by  0.0  percent.
# [2371.02801073    0.        ] [1.25115161e-15 3.33115699e+00]
# ----- 1100
# 0.5417454741961631 0.5277083333333333
# shift ind =  52
# set cost params:  0.05 0.0 112.97796926402178
# interpolate adjoint :  True True True
# initial cost =  580.7661499358611
# RUN  0 , total integrated cost =  580.7661499358611
# Gradient descend method:  None
# RUN  1 , total integrated cost =  580.7661499358611
# Control only changes marginally.
# RUN  1 , total integrated cost =  580.7661499358611
# Improved over  1  iterations in  0.8307881479850039  seconds by  0.0  percent.
# [4088.37595748    0.        ] [1.25115161e-15 3.33115699e+00]
# ----- 1200
# 0.542349347403499 0.5277083333333333
# shift ind =  53
# set cost params:  0.05 0.0 83.39151953244932
# interpolate adjoint :  True True True
# initial cost =  572.234652151468
# RUN  0 , total integrated cost =  572.234652151468
# Gradient descend method:  None
# RUN  1 , total integrated cost =  572.234652151468
# Control only changes marginally.
# RUN  1 , total integrated cost =  572.234652151468
# Improved over  1  iterations in  0.8060486729955301  seconds by  0.0  percent.
# [5888.88818119    0.        ] [1.25115161e-15 3.33115699e+00]
# ----- 1300
# 0.5427020851185376 0.5277083333333333
# shift ind =  53
# set cost params:  0.05 0.0 52.556790634457585
# interpolate adjoint :  True True True
# initial cost =  544.9176712465184
# RUN  0 , total integrated cost =  544.9176712465184
# Gradient descend method:  None
# RUN  1 , total integrated cost =  544.9176712465184
# Control only changes marginally.
# RUN  1 , total integrated cost =  544.9176712465184
# Improved over  1  iterations in  0.8008982870087493  seconds by  0.0  percent.
# [7396.85501906    0.        ] [1.25115161e-15 3.33115699e+00]
# ----- 1400
# 0.5430755660099971 0.5277083333333333
# shift ind =  53
# set cost params:  0.05 0.0 26.113109435272897
# interpolate adjoint :  True True True
# initial cost =  507.60935177723513
# RUN  0 , total integrated cost =  507.60935177723513
# Gradient descend method:  None
# RUN  1 , total integrated cost =  507.60935177723513
# Control only changes marginally.
# RUN  1 , total integrated cost =  507.60935177723513
# Improved over  1  iterations in  0.6996638829878066  seconds by  0.0  percent.
# [8412.44969921    0.        ] [1.25115161e-15 3.33115698e+00]
# ----- 1500
# 0.5434716752499242 0.5277083333333333
# shift ind =  53
# set cost params:  0.05 0.0 7.059835798228278
# interpolate adjoint :  True True True
# initial cost =  475.2085647088692
# RUN  0 , total integrated cost =  475.2085647088692
# Gradient descend method:  None
# ERROR:root:Cost parameter I_s smaller 0 not allowed, use default instead
# RUN  1 , total integrated cost =  475.2085647088692
# Control only changes marginally.
# RUN  1 , total integrated cost =  475.2085647088692
# Improved over  1  iterations in  0.6933014329988509  seconds by  0.0  percent.
# [9033.82286894    0.        ] [1.25115160e-15 3.33115698e+00]
# ----- 1600
# 0.5438925335832552 0.5277083333333333
# shift ind =  52
# set cost params:  0.05 -0.0 -6.0762518652615745
# interpolate adjoint :  True True True
# initial cost =  473.79055888553745
# RUN  0 , total integrated cost =  473.79055888553745
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.3312317776675426
# RUN  2 , total integrated cost =  3.3312317776675426
# Control only changes marginally.
# RUN  2 , total integrated cost =  3.3312317776675426
# Improved over  2  iterations in  0.972947183996439  seconds by  99.2968978137717  percent.
# [0.00030311 0.        ] [5.96583811e-05 3.33115696e+00]
# go back to ----- 1600
# ----- 1600
# set cost params:  0.05 0.0 190.4666184097924
# interpolate adjoint :  True True True
# initial cost =  634.4855803880292
# RUN  0 , total integrated cost =  634.4855803880292
# Gradient descend method:  None
# RUN  1 , total integrated cost =  634.4855803880292
# Control only changes marginally.
# RUN  1 , total integrated cost =  634.4855803880292
# Improved over  1  iterations in  0.34025033301441  seconds by  0.0  percent.
# [0.00030311 0.        ] [5.96583811e-05 3.33115696e+00]
# ----- 1700
# 0.5446630119316349 0.5277083333333333
# shift ind =  53
# set cost params:  0.05 0.0 125.70796660361476
# interpolate adjoint :  True True True
# initial cost =  418.760601596751
# RUN  0 , total integrated cost =  418.760601596751
# Gradient descend method:  None
# RUN  1 , total integrated cost =  418.760601596751
# Control only changes marginally.
# RUN  1 , total integrated cost =  418.760601596751
# Improved over  1  iterations in  0.329701632988872  seconds by  0.0  percent.
# [0.00272091 0.        ] [5.96583805e-05 3.33115695e+00]
# ----- 1800
# 0.5451516161279574 0.5277083333333333
# shift ind =  53
# set cost params:  0.05 0.0 121.89859853824748
# interpolate adjoint :  True True True
# initial cost =  406.0718516175712
# RUN  0 , total integrated cost =  406.0718516175712
# Gradient descend method:  None
# RUN  1 , total integrated cost =  406.0718516175712
# Control only changes marginally.
# RUN  1 , total integrated cost =  406.0718516175712
# Improved over  1  iterations in  0.3777233430009801  seconds by  0.0  percent.
# [0.02439946 0.        ] [5.96583793e-05 3.33115691e+00]
# ----- 1900
# 0.5456739055498104 0.5277083333333333
# shift ind =  53
# set cost params:  0.05 0.0 118.088941765737
# interpolate adjoint :  True True True
# initial cost =  393.3907010441161
# RUN  0 , total integrated cost =  393.3907010441161
# Gradient descend method:  None
# RUN  1 , total integrated cost =  393.3907010441161
# Control only changes marginally.
# RUN  1 , total integrated cost =  393.3907010441161
# Improved over  1  iterations in  0.45775365800363943  seconds by  0.0  percent.
# [0.21734363 0.        ] [5.96583774e-05 3.33115686e+00]
# ----- 2000
# 0.5462334880399857 0.5277083333333333
# shift ind =  52
# set cost params:  0.05 0.0 114.276714992755
# interpolate adjoint :  True True True
# initial cost =  380.77926824453954
# RUN  0 , total integrated cost =  380.77926824453954
# Gradient descend method:  None
# RUN  1 , total integrated cost =  380.77926824453954
# Control only changes marginally.
# RUN  1 , total integrated cost =  380.77926824453954
# Improved over  1  iterations in  0.4158306279859971  seconds by  0.0  percent.
# [1.975931 0.      ] [5.96583744e-05 3.33115678e+00]
# ----- 2100
# 0.5472047389855609 0.5277083333333333
# shift ind =  53
# set cost params:  0.05 0.0 110.44098956042804
# interpolate adjoint :  True True True
# initial cost =  368.69360802859467
# RUN  0 , total integrated cost =  368.69360802859467
# Gradient descend method:  None
# RUN  1 , total integrated cost =  367.91579458746475
# RUN  2 , total integrated cost =  367.91579458746475
# Control only changes marginally.
# RUN  2 , total integrated cost =  367.91579458746475
# Improved over  2  iterations in  0.6698513260053005  seconds by  0.210964720893557  percent.
# [0.06387198 0.        ] [5.96583694e-05 3.33124516e+00]
# go back to ----- 2100
# ----- 2100
# set cost params:  0.05 0.0 190.46062153722966
# interpolate adjoint :  True True True
# initial cost =  634.4855803880291
# RUN  0 , total integrated cost =  634.4855803880291
# Gradient descend method:  None
# RUN  1 , total integrated cost =  634.4855803880291
# Control only changes marginally.
# RUN  1 , total integrated cost =  634.4855803880291
# Improved over  1  iterations in  0.32559875698643737  seconds by  0.0  percent.
# [0.06387198 0.        ] [5.96583694e-05 3.33124516e+00]
# ----- 2200
# 0.5478662053056517 0.5277083333333333
# shift ind =  53
# set cost params:  0.05 0.0 106.65752624906803
# interpolate adjoint :  True True True
# initial cost =  355.33703244043323
# RUN  0 , total integrated cost =  355.33703244043323
# Gradient descend method:  None
# RUN  1 , total integrated cost =  355.33703244043323
# Control only changes marginally.
# RUN  1 , total integrated cost =  355.33703244043323
# Improved over  1  iterations in  0.3724107510061003  seconds by  0.0  percent.
# [0.56650287 0.        ] [5.96583610e-05 3.33124494e+00]
# ----- 2300
# 0.5485805677728909 0.5277083333333333
# shift ind =  53
# set cost params:  0.05 0.0 102.84075757243285
# interpolate adjoint :  True True True
# initial cost =  342.83496853051633
# RUN  0 , total integrated cost =  342.83496853051633
# Gradient descend method:  None
# RUN  1 , total integrated cost =  342.61457621319767
# RUN  2 , total integrated cost =  342.61457621319767
# Control only changes marginally.
# RUN  2 , total integrated cost =  342.61457621319767
# Improved over  2  iterations in  0.6554079380002804  seconds by  0.06428525020750442  percent.
# [0.11006027 0.        ] [5.96583473e-05 3.33139259e+00]
# go back to ----- 2300
# ----- 2300
# set cost params:  0.05 0.0 190.451499758706
# interpolate adjoint :  True True True
# initial cost =  634.4855803880291
# RUN  0 , total integrated cost =  634.4855803880291
# Gradient descend method:  None
# RUN  1 , total integrated cost =  634.4855803880291
# Control only changes marginally.
# RUN  1 , total integrated cost =  634.4855803880291
# Improved over  1  iterations in  0.33844613801920786  seconds by  0.0  percent.
# [0.11006027 0.        ] [5.96583473e-05 3.33139259e+00]
# ----- 2400
# 0.5493544356518117 0.5277083333333333
# shift ind =  52
# set cost params:  0.05 0.0 99.03398699310262
# interpolate adjoint :  True True True
# initial cost =  329.97783750518215
# RUN  0 , total integrated cost =  329.97783750518215
# Gradient descend method:  None
# RUN  1 , total integrated cost =  329.9471531935129
# RUN  2 , total integrated cost =  329.9471531935129
# Control only changes marginally.
# RUN  2 , total integrated cost =  329.9471531935129
# Improved over  2  iterations in  0.5304773829993792  seconds by  0.009298900768982321  percent.
# [0.16298121 0.        ] [5.96583251e-05 3.33151382e+00]
# go back to ----- 2400
# ----- 2400
# set cost params:  0.05 0.0 190.44377565060867
# interpolate adjoint :  True True True
# initial cost =  634.4855803880291
# RUN  0 , total integrated cost =  634.4855803880291
# Gradient descend method:  None
# RUN  1 , total integrated cost =  634.4855803880291
# Control only changes marginally.
# RUN  1 , total integrated cost =  634.4855803880291
# Improved over  1  iterations in  0.22931641599279828  seconds by  0.0  percent.
# [0.16298121 0.        ] [5.96583251e-05 3.33151382e+00]
# ----- 2500
# 0.5506301607996523 0.5277083333333333
# shift ind =  53
# set cost params:  0.05 0.0 95.22066482053754
# interpolate adjoint :  True True True
# initial cost =  317.3063102234539
# RUN  0 , total integrated cost =  317.3063102234539
# Gradient descend method:  None
# RUN  1 , total integrated cost =  317.26273218484755
# RUN  2 , total integrated cost =  317.26273218484755
# Control only changes marginally.
# RUN  2 , total integrated cost =  317.26273218484755
# Improved over  2  iterations in  0.4882350270054303  seconds by  0.0137337447136332  percent.
# [0.19939107 0.        ] [5.96582881e-05 3.33170413e+00]
# go back to ----- 2500
# ----- 2500
# set cost params:  0.05 0.0 190.43235108495057
# interpolate adjoint :  True True True
# initial cost =  634.4855803880291
# RUN  0 , total integrated cost =  634.4855803880291
# Gradient descend method:  None
# RUN  1 , total integrated cost =  634.4855803880291
# Control only changes marginally.
# RUN  1 , total integrated cost =  634.4855803880291
# Improved over  1  iterations in  0.31004954199306667  seconds by  0.0  percent.
# [0.19939107 0.        ] [5.96582881e-05 3.33170413e+00]
# ----- 2600
# 0.5515674693321218 0.5277083333333333
# shift ind =  53
# set cost params:  0.05 0.0 91.40597253774611
# interpolate adjoint :  True True True
# initial cost =  304.63062791117534
# RUN  0 , total integrated cost =  304.63062791117534
# Gradient descend method:  None
# RUN  1 , total integrated cost =  304.5805847806859
# RUN  2 , total integrated cost =  304.5805847806859
# Control only changes marginally.
# RUN  2 , total integrated cost =  304.5805847806859
# Improved over  2  iterations in  0.7794908939977176  seconds by  0.016427478363738146  percent.
# [0.29200404 0.        ] [5.96582269e-05 3.33195439e+00]
# go back to ----- 2600
# ----- 2600
# set cost params:  0.05 0.0 190.41665821977463
# interpolate adjoint :  True True True
# initial cost =  634.4855803880291
# RUN  0 , total integrated cost =  634.4855803880291
# Gradient descend method:  None
# RUN  1 , total integrated cost =  634.4796684986367
# RUN  2 , total integrated cost =  634.4796684986367
# Control only changes marginally.
# RUN  2 , total integrated cost =  634.4796684986367
# Improved over  2  iterations in  0.6283461530110799  seconds by  0.0009317610321204484  percent.
# [0.54470751 0.        ] [5.96582269e-05 3.33185699e+00]
# go back to ----- 2600
# ----- 2600
# set cost params:  0.05 0.0 190.41843254068996
# interpolate adjoint :  True True True
# initial cost =  634.4855803880292
# RUN  0 , total integrated cost =  634.4855803880292
# Gradient descend method:  None
# RUN  1 , total integrated cost =  634.4855803880292
# Control only changes marginally.
# RUN  1 , total integrated cost =  634.4855803880292
# Improved over  1  iterations in  0.24541331001091748  seconds by  0.0  percent.
# [0.54470751 0.        ] [5.96582269e-05 3.33185699e+00]
# ----- 2700
# 0.552594002855783 0.5277083333333333
# shift ind =  53
# set cost params:  0.05 0.0 87.58806496185856
# interpolate adjoint :  True True True
# initial cost =  292.0700963803266
# RUN  0 , total integrated cost =  292.0700963803266
# Gradient descend method:  None
# RUN  1 , total integrated cost =  291.89728556621134
# RUN  2 , total integrated cost =  291.89728556621134
# Control only changes marginally.
# RUN  2 , total integrated cost =  291.89728556621134
# Improved over  2  iterations in  0.6553731389867608  seconds by  0.05916758211708384  percent.
# [0.39261424 0.        ] [5.96581261e-05 3.33233106e+00]
# go back to ----- 2700
# ----- 2700
# set cost params:  0.05 0.0 190.39362517856037
# interpolate adjoint :  True True True
# initial cost =  634.4855803880291
# RUN  0 , total integrated cost =  634.4855803880291
# Gradient descend method:  None
# RUN  1 , total integrated cost =  634.4754970331318
# RUN  2 , total integrated cost =  634.4754970331318
# Control only changes marginally.
# RUN  2 , total integrated cost =  634.4754970331318
# Improved over  2  iterations in  0.631744112004526  seconds by  0.0015892173453693204  percent.
# [0.78222301 0.        ] [5.96581261e-05 3.33217578e+00]
# go back to ----- 2700
# ----- 2700
# set cost params:  0.05 0.0 190.39665118169574
# interpolate adjoint :  True True True
# initial cost =  634.485580388029
# RUN  0 , total integrated cost =  634.485580388029
# Gradient descend method:  None
# RUN  1 , total integrated cost =  634.485580388029
# Control only changes marginally.
# RUN  1 , total integrated cost =  634.485580388029
# Improved over  1  iterations in  0.20639894501073286  seconds by  0.0  percent.
# [0.78222301 0.        ] [5.96581261e-05 3.33217578e+00]
# ----- 2800
# 0.5537231384307846 0.5277083333333333
# shift ind =  53
# set cost params:  0.05 0.0 83.76795368176457
# interpolate adjoint :  True True True
# initial cost =  279.4672795119329
# RUN  0 , total integrated cost =  279.4672795119329
# Gradient descend method:  None
# RUN  1 , total integrated cost =  279.2195073536007
# RUN  2 , total integrated cost =  279.2195073536007
# Control only changes marginally.
# RUN  2 , total integrated cost =  279.2195073536007
# Improved over  2  iterations in  0.3893636270076968  seconds by  0.08865873628029419  percent.
# [0.55785584 0.        ] [5.96579599e-05 3.33285708e+00]
# go back to ----- 2800
# ----- 2800
# set cost params:  0.05 0.0 190.3610975961323
# interpolate adjoint :  True True True
# initial cost =  634.4855803880292
# RUN  0 , total integrated cost =  634.4855803880292
# Gradient descend method:  None
# RUN  1 , total integrated cost =  634.4707760305369
# RUN  2 , total integrated cost =  634.4707760305369
# Control only changes marginally.
# RUN  2 , total integrated cost =  634.4707760305369
# Improved over  2  iterations in  0.45540996702038683  seconds by  0.0023332850973929453  percent.
# [1.15341984 0.        ] [5.96579599e-05 3.33262288e+00]
# go back to ----- 2800
# ----- 2800
# set cost params:  0.05 0.0 190.3655397706698
# interpolate adjoint :  True True True
# initial cost =  634.4855803880292
# RUN  0 , total integrated cost =  634.4855803880292
# Gradient descend method:  None
# RUN  1 , total integrated cost =  634.4855803880292
# Control only changes marginally.
# RUN  1 , total integrated cost =  634.4855803880292
# Improved over  1  iterations in  0.2557308289979119  seconds by  0.0  percent.
# [1.15341984 0.        ] [5.96579599e-05 3.33262288e+00]
# ----- 2900
# 0.5549710678590216 0.5277083333333333
# shift ind =  52
# set cost params:  0.05 0.0 79.94348999146372
# interpolate adjoint :  True True True
# initial cost =  266.93145821311776
# RUN  0 , total integrated cost =  266.93145821311776
# Gradient descend method:  None
# RUN  1 , total integrated cost =  266.5464700458021
# RUN  2 , total integrated cost =  266.5464700458021
# Control only changes marginally.
# RUN  2 , total integrated cost =  266.5464700458021
# Improved over  2  iterations in  0.4266856239992194  seconds by  0.14422734955739713  percent.
# [0.81503561 0.        ] [5.96576921e-05 3.33361665e+00]
# go back to ----- 2900
# ----- 2900
# set cost params:  0.05 0.0 190.3138669447163
# interpolate adjoint :  True True True
# initial cost =  634.4855803880291
# RUN  0 , total integrated cost =  634.4855803880291
# Gradient descend method:  None
# RUN  1 , total integrated cost =  634.4650217662669
# RUN  2 , total integrated cost =  634.4650217662669
# Control only changes marginally.
# RUN  2 , total integrated cost =  634.4650217662669
# Improved over  2  iterations in  0.6550955399870872  seconds by  0.0032402031500282646  percent.
# [1.67663018 0.        ] [5.96576921e-05 3.33328226e+00]
# go back to ----- 2900
# ----- 2900
# set cost params:  0.05 0.0 190.32003451536107
# interpolate adjoint :  True True True
# initial cost =  634.4855803880291
# RUN  0 , total integrated cost =  634.4855803880291
# Gradient descend method:  None
# RUN  1 , total integrated cost =  634.4855803880291
# Control only changes marginally.
# RUN  1 , total integrated cost =  634.4855803880291
# Improved over  1  iterations in  0.3507320240023546  seconds by  0.0  percent.
# [1.67663018 0.        ] [5.96576921e-05 3.33328226e+00]
# ----- 3000
# 0.5569128262076624 0.5277083333333333
# shift ind =  53
# set cost params:  0.05 0.0 76.11292417333665
# interpolate adjoint :  True True True
# initial cost =  254.4043119312263
# RUN  0 , total integrated cost =  254.4043119312263
# Gradient descend method:  None
# RUN  1 , total integrated cost =  253.87602462833078
# RUN  2 , total integrated cost =  253.8755843770008
# RUN  3 , total integrated cost =  253.8755843770008
# Control only changes marginally.
# RUN  3 , total integrated cost =  253.8755843770008
# Improved over  3  iterations in  0.7737080620136112  seconds by  0.20782963551671685  percent.
# [1.08997628 0.        ] [5.96572439e-05 3.33473648e+00]
# go back to ----- 3000
# ----- 3000
# set cost params:  0.05 0.0 190.24583673950693
# interpolate adjoint :  True True True
# initial cost =  634.4855803880291
# RUN  0 , total integrated cost =  634.4855803880291
# Gradient descend method:  None
# RUN  1 , total integrated cost =  634.4506073476489
# RUN  2 , total integrated cost =  634.4506073476489
# Control only changes marginally.
# RUN  2 , total integrated cost =  634.4506073476489
# Improved over  2  iterations in  0.516283328004647  seconds by  0.005512030763384246  percent.
# [2.33426031 0.        ] [5.96572439e-05 3.33422563e+00]
# go back to ----- 3000
# ----- 3000
# set cost params:  0.05 0.0 190.25632565613256
# interpolate adjoint :  True True True
# initial cost =  634.4855803880291
# RUN  0 , total integrated cost =  634.4855803880291
# Gradient descend method:  None
# RUN  1 , total integrated cost =  634.4855803880291
# Control only changes marginally.
# RUN  1 , total integrated cost =  634.4855803880291
# Improved over  1  iterations in  0.2457618500047829  seconds by  0.0  percent.
# [2.33426031 0.        ] [5.96572439e-05 3.33422563e+00]
# ----- 3010
# 0.5304299274148521 0.5277083333333333
# shift ind =  5
# set cost params:  0.05 0.0 75.7009452585198
# interpolate adjoint :  True True True
# initial cost =  252.55504296038563
# RUN  0 , total integrated cost =  252.55504296038563
# Gradient descend method:  None
# RUN  1 , total integrated cost =  252.5144388958625
# RUN  2 , total integrated cost =  252.5144388958625
# Control only changes marginally.
# RUN  2 , total integrated cost =  252.5144388958625
# Improved over  2  iterations in  0.4138801050139591  seconds by  0.01607731290857828  percent.
# [1.09223306 0.        ] [5.96571889e-05 3.33490302e+00]
# go back to ----- 3010
# ----- 3010
# set cost params:  0.05 0.0 190.23630238127444
# interpolate adjoint :  True True True
# initial cost =  634.4855803880291
# RUN  0 , total integrated cost =  634.4855803880291
# Gradient descend method:  None
# RUN  1 , total integrated cost =  634.44612990655
# RUN  2 , total integrated cost =  634.44612990655
# Control only changes marginally.
# RUN  2 , total integrated cost =  634.44612990655
# Improved over  2  iterations in  0.5548131900141016  seconds by  0.006217711276420346  percent.
# [2.43260409 0.        ] [5.96571889e-05 3.33434336e+00]
# go back to ----- 3010
# ----- 3010
# set cost params:  0.05 0.0 190.24813372899513
# interpolate adjoint :  True True True
# initial cost =  634.485580388029
# RUN  0 , total integrated cost =  634.485580388029
# Gradient descend method:  None
# RUN  1 , total integrated cost =  634.485580388029
# Control only changes marginally.
# RUN  1 , total integrated cost =  634.485580388029
# Improved over  1  iterations in  0.21180900698527694  seconds by  0.0  percent.
# [2.43260409 0.        ] [5.96571889e-05 3.33434336e+00]
# ----- 3020
# 0.5306007860752386 0.5277083333333333
# shift ind =  6
# set cost params:  0.05 0.0 75.31622863386258
# interpolate adjoint :  True True True
# initial cost =  251.28077557092192
# RUN  0 , total integrated cost =  251.28077557092192
# Gradient descend method:  None
# RUN  1 , total integrated cost =  251.24190513777907
# RUN  2 , total integrated cost =  251.24190513777907
# Control only changes marginally.
# RUN  2 , total integrated cost =  251.24190513777907
# Improved over  2  iterations in  0.375582199980272  seconds by  0.015468924375355186  percent.
# [1.18058753 0.        ] [5.96571194e-05 3.33498354e+00]
# go back to ----- 3020
# ----- 3020
# set cost params:  0.05 0.0 190.2303850234365
# interpolate adjoint :  True True True
# initial cost =  634.4855803880292
# RUN  0 , total integrated cost =  634.4855803880292
# Gradient descend method:  None
# RUN  1 , total integrated cost =  634.449138085703
# RUN  2 , total integrated cost =  634.449138085703
# Control only changes marginally.
# RUN  2 , total integrated cost =  634.449138085703
# Improved over  2  iterations in  0.46552857701317407  seconds by  0.005743598192410104  percent.
# [2.5046947 0.       ] [5.96571194e-05 3.33444394e+00]
# go back to ----- 3020
# ----- 3020
# set cost params:  0.05 0.0 190.2413138772382
# interpolate adjoint :  True True True
# initial cost =  634.4855803880291
# RUN  0 , total integrated cost =  634.4855803880291
# Gradient descend method:  None
# RUN  1 , total integrated cost =  634.4855803880291
# Control only changes marginally.
# RUN  1 , total integrated cost =  634.4855803880291
# Improved over  1  iterations in  0.3209985909925308  seconds by  0.0  percent.
# [2.5046947 0.       ] [5.96571194e-05 3.33444394e+00]
# ----- 3030
# 0.5302089215132694 0.5277083333333333
# shift ind =  5
# set cost params:  0.05 0.0 74.93231798328424
# interpolate adjoint :  True True True
# initial cost =  250.0192440759322
# RUN  0 , total integrated cost =  250.0192440759322
# Gradient descend method:  None
# RUN  1 , total integrated cost =  249.97501239292978
# RUN  2 , total integrated cost =  249.97501239292978
# Control only changes marginally.
# RUN  2 , total integrated cost =  249.97501239292978
# Improved over  2  iterations in  0.6446769700269215  seconds by  0.017691311389199882  percent.
# [1.23602245 0.        ] [5.96570583e-05 3.33512625e+00]
# go back to ----- 3030
# ----- 3030
# set cost params:  0.05 0.0 190.22141375575623
# interpolate adjoint :  True True True
# initial cost =  634.4855803880291
# RUN  0 , total integrated cost =  634.4855803880291
# Gradient descend method:  None
# RUN  1 , total integrated cost =  634.4485529622219
# RUN  2 , total integrated cost =  634.4485529622219
# Control only changes marginally.
# RUN  2 , total integrated cost =  634.4485529622219
# Improved over  2  iterations in  0.6227265280031133  seconds by  0.005835818330908182  percent.
# [2.73906066 0.        ] [5.96570583e-05 3.33453652e+00]
# go back to ----- 3030
# ----- 3030
# set cost params:  0.05 0.0 190.232517776691
# interpolate adjoint :  True True True
# initial cost =  634.4855803880291
# RUN  0 , total integrated cost =  634.4855803880291
# Gradient descend method:  None
# RUN  1 , total integrated cost =  634.4855803880291
# Control only changes marginally.
# RUN  1 , total integrated cost =  634.4855803880291
# Improved over  1  iterations in  0.20190948800882325  seconds by  0.0  percent.
# [2.73906066 0.        ] [5.96570583e-05 3.33453652e+00]
# ----- 3040
# 0.5303804656445201 0.5277083333333333
# shift ind =  5
# set cost params:  0.05 0.0 74.54617619553603
# interpolate adjoint :  True True True
# initial cost =  248.75320072826528
# RUN  0 , total integrated cost =  248.75320072826528
# Gradient descend method:  None
# RUN  1 , total integrated cost =  248.70106006667928
# RUN  2 , total integrated cost =  248.70106006667928
# Control only changes marginally.
# RUN  2 , total integrated cost =  248.70106006667928
# Improved over  2  iterations in  0.3751081099908333  seconds by  0.020960800276483837  percent.
# [1.2814512 0.       ] [5.96569944e-05 3.33528228e+00]
# go back to ----- 3040
# ----- 3040
# set cost params:  0.05 0.0 190.21183444613777
# interpolate adjoint :  True True True
# initial cost =  634.4855803880291
# RUN  0 , total integrated cost =  634.4855803880291
# Gradient descend method:  None
# RUN  1 , total integrated cost =  634.4468580749603
# RUN  2 , total integrated cost =  634.4468580749603
# Control only changes marginally.
# RUN  2 , total integrated cost =  634.4468580749603
# Improved over  2  iterations in  0.4153438039938919  seconds by  0.006102946113458074  percent.
# [2.75341258 0.        ] [5.96569944e-05 3.33469178e+00]
# go back to ----- 3040
# ----- 3040
# set cost params:  0.05 0.0 190.22344620007195
# interpolate adjoint :  True True True
# initial cost =  634.4855803880292
# RUN  0 , total integrated cost =  634.4855803880292
# Gradient descend method:  None
# RUN  1 , total integrated cost =  634.4855803880292
# Control only changes marginally.
# RUN  1 , total integrated cost =  634.4855803880292
# Improved over  1  iterations in  0.19886098898132332  seconds by  0.0  percent.
# [2.75341258 0.        ] [5.96569944e-05 3.33469178e+00]
# ----- 3050
# 0.5305539691604797 0.5277083333333333
# shift ind =  5
# set cost params:  0.05 0.0 74.16196100650852
# interpolate adjoint :  True True True
# initial cost =  247.4844066087084
# RUN  0 , total integrated cost =  247.4844066087084
# Gradient descend method:  None
# RUN  1 , total integrated cost =  247.4338923787924
# RUN  2 , total integrated cost =  247.4338923787924
# Control only changes marginally.
# RUN  2 , total integrated cost =  247.4338923787924
# Improved over  2  iterations in  0.377601986983791  seconds by  0.020411075836335613  percent.
# [1.2791942 0.       ] [5.96569273e-05 3.33547691e+00]
# go back to ----- 3050
# ----- 3050
# set cost params:  0.05 0.0 190.20076929652922
# interpolate adjoint :  True True True
# initial cost =  634.4855803880291
# RUN  0 , total integrated cost =  634.4855803880291
# Gradient descend method:  None
# RUN  1 , total integrated cost =  634.44150882993
# RUN  2 , total integrated cost =  634.44150882993
# Control only changes marginally.
# RUN  2 , total integrated cost =  634.44150882993
# Improved over  2  iterations in  0.43693876700126566  seconds by  0.006946029895942729  percent.
# [2.92581769 0.        ] [5.96569273e-05 3.33481233e+00]
# go back to ----- 3050
# ----- 3050
# set cost params:  0.05 0.0 190.21398466378628
# interpolate adjoint :  True True True
# initial cost =  634.4855803880291
# RUN  0 , total integrated cost =  634.4855803880291
# Gradient descend method:  None
# RUN  1 , total integrated cost =  634.4855803880291
# Control only changes marginally.
# RUN  1 , total integrated cost =  634.4855803880291
# Improved over  1  iterations in  0.3149012599897105  seconds by  0.0  percent.
# [2.92581769 0.        ] [5.96569273e-05 3.33481233e+00]
# ----- 3060
# 0.530729465824239 0.5277083333333333
# shift ind =  6
# set cost params:  0.05 0.0 73.7761794354373
# interpolate adjoint :  True True True
# initial cost =  246.2097867608521
# RUN  0 , total integrated cost =  246.2097867608521
# Gradient descend method:  None
# RUN  1 , total integrated cost =  246.15905032988186
# RUN  2 , total integrated cost =  246.15905032988186
# Control only changes marginally.
# RUN  2 , total integrated cost =  246.15905032988186
# Improved over  2  iterations in  0.4369546349917073  seconds by  0.020606991963120436  percent.
# [1.36261413 0.        ] [5.96568425e-05 3.33558230e+00]
# go back to ----- 3060
# ----- 3060
# set cost params:  0.05 0.0 190.19350927828563
# interpolate adjoint :  True True True
# initial cost =  634.4855803880291
# RUN  0 , total integrated cost =  634.4855803880291
# Gradient descend method:  None
# RUN  1 , total integrated cost =  634.44346951963
# RUN  2 , total integrated cost =  634.44346951963
# Control only changes marginally.
# RUN  2 , total integrated cost =  634.44346951963
# Improved over  2  iterations in  0.42420392998610623  seconds by  0.006637009524069981  percent.
# [2.98570913 0.        ] [5.96568425e-05 3.33493419e+00]
# go back to ----- 3060
# ----- 3060
# set cost params:  0.05 0.0 190.2061362486108
# interpolate adjoint :  True True True
# initial cost =  634.485580388029
# RUN  0 , total integrated cost =  634.485580388029
# Gradient descend method:  None
# RUN  1 , total integrated cost =  634.485580388029
# Control only changes marginally.
# RUN  1 , total integrated cost =  634.485580388029
# Improved over  1  iterations in  0.19938813598128036  seconds by  0.0  percent.
# [2.98570913 0.        ] [5.96568425e-05 3.33493419e+00]
# ----- 3070
# 0.5303292894280762 0.5277083333333333
# shift ind =  5
# set cost params:  0.05 0.0 73.39208390252315
# interpolate adjoint :  True True True
# initial cost =  244.94937099300142
# RUN  0 , total integrated cost =  244.94937099300142
# Gradient descend method:  None
# RUN  1 , total integrated cost =  244.89308213766944
# RUN  2 , total integrated cost =  244.89308213766944
# Control only changes marginally.
# RUN  2 , total integrated cost =  244.89308213766944
# Improved over  2  iterations in  0.45623770100064576  seconds by  0.02297979174382192  percent.
# [1.31721374 0.        ] [5.96567681e-05 3.33582084e+00]
# go back to ----- 3070
# ----- 3070
# set cost params:  0.05 0.0 190.18058948596158
# interpolate adjoint :  True True True
# initial cost =  634.4855803880291
# RUN  0 , total integrated cost =  634.4855803880291
# Gradient descend method:  None
# RUN  1 , total integrated cost =  634.434064557805
# RUN  2 , total integrated cost =  634.434064557805
# Control only changes marginally.
# RUN  2 , total integrated cost =  634.434064557805
# Improved over  2  iterations in  0.4151240380015224  seconds by  0.008119306697665252  percent.
# [3.10311424 0.        ] [5.96567681e-05 3.33508044e+00]
# go back to ----- 3070
# ----- 3070
# set cost params:  0.05 0.0 190.19603586266317
# interpolate adjoint :  True True True
# initial cost =  634.4855803880291
# RUN  0 , total integrated cost =  634.4855803880291
# Gradient descend method:  None
# RUN  1 , total integrated cost =  634.4855803880291
# Control only changes marginally.
# RUN  1 , total integrated cost =  634.4855803880291
# Improved over  1  iterations in  0.21777726302389055  seconds by  0.0  percent.
# [3.10311424 0.        ] [5.96567681e-05 3.33508044e+00]
# ----- 3080
# 0.5305055200464845 0.5277083333333333
# shift ind =  5
# set cost params:  0.05 0.0 73.00662052868802
# interpolate adjoint :  True True True
# initial cost =  243.68185984857584
# RUN  0 , total integrated cost =  243.68185984857584
# Gradient descend method:  None
# RUN  1 , total integrated cost =  243.6229584097138
# RUN  2 , total integrated cost =  243.6229584097138
# Control only changes marginally.
# RUN  2 , total integrated cost =  243.6229584097138
# Improved over  2  iterations in  0.43774990999372676  seconds by  0.024171449979348836  percent.
# [1.4137208 0.       ] [5.96566901e-05 3.33597029e+00]
# go back to ----- 3080
# ----- 3080
# set cost params:  0.05 0.0 190.17062332771846
# interpolate adjoint :  True True True
# initial cost =  634.4855803880291
# RUN  0 , total integrated cost =  634.4855803880291
# Gradient descend method:  None
# RUN  1 , total integrated cost =  634.4357537558726
# RUN  2 , total integrated cost =  634.4357537558726
# Control only changes marginally.
# RUN  2 , total integrated cost =  634.4357537558726
# Improved over  2  iterations in  0.48474728598375805  seconds by  0.007853075577543223  percent.
# [3.16932222 0.        ] [5.96566901e-05 3.33524669e+00]
# go back to ----- 3080
# ----- 3080
# set cost params:  0.05 0.0 190.18556247480774
# interpolate adjoint :  True True True
# initial cost =  634.4855803880291
# RUN  0 , total integrated cost =  634.4855803880291
# Gradient descend method:  None
# RUN  1 , total integrated cost =  634.4855803880291
# Control only changes marginally.
# RUN  1 , total integrated cost =  634.4855803880291
# Improved over  1  iterations in  0.23257187401759438  seconds by  0.0  percent.
# [3.16932222 0.        ] [5.96566901e-05 3.33524669e+00]
# ----- 3090
# 0.5306838106370544 0.5277083333333333
# shift ind =  6
# set cost params:  0.05 0.0 72.62152262804518
# interpolate adjoint :  True True True
# initial cost =  242.40528743530447
# RUN  0 , total integrated cost =  242.40528743530447
# Gradient descend method:  None
# RUN  1 , total integrated cost =  242.35131122993002
# RUN  2 , total integrated cost =  242.35131122993002
# Control only changes marginally.
# RUN  2 , total integrated cost =  242.35131122993002
# Improved over  2  iterations in  0.42114425598992966  seconds by  0.022266925752958855  percent.
# [1.43695492 0.        ] [5.96565915e-05 3.33613400e+00]
# go back to ----- 3090
# ----- 3090
# set cost params:  0.05 0.0 190.16094297931693
# interpolate adjoint :  True True True
# initial cost =  634.4855803880291
# RUN  0 , total integrated cost =  634.4855803880291
# Gradient descend method:  None
# RUN  1 , total integrated cost =  634.4326676766414
# RUN  2 , total integrated cost =  634.4326676766414
# Control only changes marginally.
# RUN  2 , total integrated cost =  634.4326676766414
# Improved over  2  iterations in  0.4278893349983264  seconds by  0.008339466336721557  percent.
# [3.37263003 0.        ] [5.96565915e-05 3.33534680e+00]
# go back to ----- 3090
# ----- 3090
# set cost params:  0.05 0.0 190.17680692637876
# interpolate adjoint :  True True True
# initial cost =  634.4855803880291
# RUN  0 , total integrated cost =  634.4855803880291
# Gradient descend method:  None
# RUN  1 , total integrated cost =  634.4855803880291
# Control only changes marginally.
# RUN  1 , total integrated cost =  634.4855803880291
# Improved over  1  iterations in  0.18847796999034472  seconds by  0.0  percent.
# [3.37263003 0.        ] [5.96565915e-05 3.33534680e+00]
# ----- 3100
# 0.5302763080540859 0.5277083333333333
# shift ind =  5
# set cost params:  0.05 0.0 72.23584066789871
# interpolate adjoint :  True True True
# initial cost =  241.14727677979337
# RUN  0 , total integrated cost =  241.14727677979337
# Gradient descend method:  None
# RUN  1 , total integrated cost =  241.08134543522854
# RUN  2 , total integrated cost =  241.08134543522854
# Control only changes marginally.
# RUN  2 , total integrated cost =  241.08134543522854
# Improved over  2  iterations in  0.39462298798025586  seconds by  0.027340696293677524  percent.
# [1.4671795 0.       ] [5.96565050e-05 3.33634488e+00]
# go back to ----- 3100
# ----- 3100
# set cost params:  0.05 0.0 190.14847108113545
# interpolate adjoint :  True True True
# initial cost =  634.4855803880291
# RUN  0 , total integrated cost =  634.4855803880291
# Gradient descend method:  None
# RUN  1 , total integrated cost =  634.4283618172603
# RUN  2 , total integrated cost =  634.4283618172603
# Control only changes marginally.
# RUN  2 , total integrated cost =  634.4283618172603
# Improved over  2  iterations in  0.4123031320050359  seconds by  0.009018104199270738  percent.
# [3.35650448 0.        ] [5.96565050e-05 3.33554716e+00]
# go back to ----- 3100
# ----- 3100
# set cost params:  0.05 0.0 190.16562495264634
# interpolate adjoint :  True True True
# initial cost =  634.4855803880291
# RUN  0 , total integrated cost =  634.4855803880291
# Gradient descend method:  None
# RUN  1 , total integrated cost =  634.4855803880291
# Control only changes marginally.
# RUN  1 , total integrated cost =  634.4855803880291
# Improved over  1  iterations in  0.1859577849972993  seconds by  0.0  percent.
# [3.35650448 0.        ] [5.96565050e-05 3.33554716e+00]
# ----- 3110
# 0.5304553518628031 0.5277083333333333
# shift ind =  5
# set cost params:  0.05 0.0 71.8513113897525
# interpolate adjoint :  True True True
# initial cost =  239.87810271461575
# RUN  0 , total integrated cost =  239.87810271461575
# Gradient descend method:  None
# RUN  1 , total integrated cost =  239.81571987270405
# RUN  2 , total integrated cost =  239.81571987270405
# Control only changes marginally.
# RUN  2 , total integrated cost =  239.81571987270405
# Improved over  2  iterations in  0.5201566930045374  seconds by  0.026006059413390403  percent.
# [1.51123849 0.        ] [5.96564142e-05 3.33655527e+00]
# go back to ----- 3110
# ----- 3110
# set cost params:  0.05 0.0 190.13582111369186
# interpolate adjoint :  True True True
# initial cost =  634.4855803880291
# RUN  0 , total integrated cost =  634.4855803880291
# Gradient descend method:  None
# RUN  1 , total integrated cost =  634.4249919292325
# RUN  2 , total integrated cost =  634.4249919292325
# Control only changes marginally.
# RUN  2 , total integrated cost =  634.4249919292325
# Improved over  2  iterations in  0.5636557909892872  seconds by  0.009549225493756808  percent.
# [3.56888368 0.        ] [5.96564142e-05 3.33569551e+00]
# go back to ----- 3110
# ----- 3110
# set cost params:  0.05 0.0 190.15398445475265
# interpolate adjoint :  True True True
# initial cost =  634.4855803880291
# RUN  0 , total integrated cost =  634.4855803880291
# Gradient descend method:  None
# RUN  1 , total integrated cost =  634.4855803880291
# Control only changes marginally.
# RUN  1 , total integrated cost =  634.4855803880291
# Improved over  1  iterations in  0.22188183400430717  seconds by  0.0  percent.
# [3.56888368 0.        ] [5.96564142e-05 3.33569551e+00]
# ----- 3120
# 0.5306365258774539 0.5277083333333333
# shift ind =  5
# set cost params:  0.05 0.0 71.46451765627596
# interpolate adjoint :  True True True
# initial cost =  238.61175793044706
# RUN  0 , total integrated cost =  238.61175793044706
# Gradient descend method:  None
# RUN  1 , total integrated cost =  238.543019219131
# RUN  2 , total integrated cost =  238.543019219131
# Control only changes marginally.
# RUN  2 , total integrated cost =  238.543019219131
# Improved over  2  iterations in  0.4359957770211622  seconds by  0.02880776367109661  percent.
# [1.59880086 0.        ] [5.96563190e-05 3.33674421e+00]
# go back to ----- 3120
# ----- 3120
# set cost params:  0.05 0.0 190.12374260322315
# interpolate adjoint :  True True True
# initial cost =  634.485580388029
# RUN  0 , total integrated cost =  634.485580388029
# Gradient descend method:  None
# RUN  1 , total integrated cost =  634.4250032627407
# RUN  2 , total integrated cost =  634.4250032627407
# Control only changes marginally.
# RUN  2 , total integrated cost =  634.4250032627407
# Improved over  2  iterations in  0.6257047850231174  seconds by  0.00954743924224033  percent.
# [3.61684549 0.        ] [5.96563190e-05 3.33589488e+00]
# go back to ----- 3120
# ----- 3120
# set cost params:  0.05 0.0 190.1419014614112
# interpolate adjoint :  True True True
# initial cost =  634.4855803880291
# RUN  0 , total integrated cost =  634.4855803880291
# Gradient descend method:  None
# RUN  1 , total integrated cost =  634.4855803880291
# Control only changes marginally.
# RUN  1 , total integrated cost =  634.4855803880291
# Improved over  1  iterations in  0.19572978498763405  seconds by  0.0  percent.
# [3.61684549 0.        ] [5.96563190e-05 3.33589488e+00]
# ----- 3130
# 0.53081986834231 0.5277083333333333
# shift ind =  6
# set cost params:  0.05 0.0 71.07913565285878
# interpolate adjoint :  True True True
# initial cost =  237.33382100587127
# RUN  0 , total integrated cost =  237.33382100587127
# Gradient descend method:  None
# RUN  1 , total integrated cost =  237.27190947172468
# RUN  2 , total integrated cost =  237.27190947172468
# Control only changes marginally.
# RUN  2 , total integrated cost =  237.27190947172468
# Improved over  2  iterations in  0.5194032219878864  seconds by  0.026086266965322125  percent.
# [1.65203512 0.        ] [5.96561988e-05 3.33691547e+00]
# go back to ----- 3130
# ----- 3130
# set cost params:  0.05 0.0 190.1131876939713
# interpolate adjoint :  True True True
# initial cost =  634.4855803880291
# RUN  0 , total integrated cost =  634.4855803880291
# Gradient descend method:  None
# RUN  1 , total integrated cost =  634.4233768571497
# RUN  2 , total integrated cost =  634.4233768571497
# Control only changes marginally.
# RUN  2 , total integrated cost =  634.4233768571497
# Improved over  2  iterations in  0.6106154120061547  seconds by  0.009803773766037693  percent.
# [3.84598436 0.        ] [5.96561988e-05 3.33601127e+00]
# go back to ----- 3130
# ----- 3130
# set cost params:  0.05 0.0 190.13183343991193
# interpolate adjoint :  True True True
# initial cost =  634.4855803880291
# RUN  0 , total integrated cost =  634.4855803880291
# Gradient descend method:  None
# RUN  1 , total integrated cost =  634.4855803880291
# Control only changes marginally.
# RUN  1 , total integrated cost =  634.4855803880291
# Improved over  1  iterations in  0.2292305119917728  seconds by  0.0  percent.
# [3.84598436 0.        ] [5.96561988e-05 3.33601127e+00]
# ----- 3140
# 0.5304033714629741 0.5277083333333333
# shift ind =  5
# set cost params:  0.05 0.0 70.69284259674765
# interpolate adjoint :  True True True
# initial cost =  236.07725892966917
# RUN  0 , total integrated cost =  236.07725892966917
# Gradient descend method:  None
# RUN  1 , total integrated cost =  236.00185967045005
# RUN  2 , total integrated cost =  236.00185967045005
# Control only changes marginally.
# RUN  2 , total integrated cost =  236.00185967045005
# Improved over  2  iterations in  0.5026441980153322  seconds by  0.031938383036546725  percent.
# [1.69040386 0.        ] [5.96560932e-05 3.33715711e+00]
# go back to ----- 3140
# ----- 3140
# set cost params:  0.05 0.0 190.09884729498808
# interpolate adjoint :  True True True
# initial cost =  634.4855803880291
# RUN  0 , total integrated cost =  634.4855803880291
# Gradient descend method:  None
# RUN  1 , total integrated cost =  634.4186688337638
# RUN  2 , total integrated cost =  634.4186688337638
# Control only changes marginally.
# RUN  2 , total integrated cost =  634.4186688337638
# ...
# interpolate adjoint :  True True True
# initial cost =  634.485580388029
# RUN  0 , total integrated cost =  634.485580388029
# Gradient descend method:  None
# RUN  1 , total integrated cost =  634.485580388029
# Control only changes marginally.
# RUN  1 , total integrated cost =  634.485580388029
# Improved over  1  iterations in  0.10497358400607482  seconds by  0.0  percent.
# [747.90586799   0.        ] [1.33935948e-04 4.43937051e+00]
# ----- 4630
# 0.631578947368421 0.5277083333333333
# shift ind =  0
# set cost params:  0.05 0.0 2.152636552072829
# interpolate adjoint :  True True True
# initial cost =  67.09184924028412
# RUN  0 , total integrated cost =  67.09184924028412
# Gradient descend method:  None
# RUN  1 , total integrated cost =  37.53557878544769
# RUN  2 , total integrated cost =  12.685848516335371
# RUN  3 , total integrated cost =  12.463497324845571
# RUN  4 , total integrated cost =  12.398848939643921
# RUN  5 , total integrated cost =  12.358145878772719
# RUN  6 , total integrated cost =  12.328067179253395
# RUN  7 , total integrated cost =  12.288405681994151
# RUN  8 , total integrated cost =  12.260407634088077
# RUN  9 , total integrated cost =  12.234052695055857
# RUN  10 , total integrated cost =  12.213265515267995
# RUN  11 , total integrated cost =  12.185386537773327
# RUN  12 , total integrated cost =  12.163616558107421
# RUN  13 , total integrated cost =  12.077447221600439
# RUN  14 , total integrated cost =  12.049859642231723
# RUN  15 , total integrated cost =  12.041196618843541
# RUN  16 , total integrated cost =  12.035084006945509
# RUN  17 , total integrated cost =  12.031276376808126
# RUN  18 , total integrated cost =  12.027858378943538
# RUN  19 , total integrated cost =  12.025217606363574
# RUN  20 , total integrated cost =  12.02262874906343
# RUN  30 , total integrated cost =  12.0024478933617
# RUN  40 , total integrated cost =  11.986191536664993
# RUN  50 , total integrated cost =  11.971908061112877
# RUN  60 , total integrated cost =  11.958780607198364
# RUN  70 , total integrated cost =  11.94605099440805
# RUN  80 , total integrated cost =  11.93443537878966
# RUN  90 , total integrated cost =  11.923731734752517
# RUN  100 , total integrated cost =  11.913542343763742
# RUN  110 , total integrated cost =  11.903902354744696
# RUN  120 , total integrated cost =  11.894783781592574
# RUN  130 , total integrated cost =  11.88636856476871
# RUN  140 , total integrated cost =  11.878026438576645
# RUN  150 , total integrated cost =  11.87064160195845
# RUN  160 , total integrated cost =  11.862982027004946
# RUN  170 , total integrated cost =  11.85591082231896
# RUN  180 , total integrated cost =  11.845657217972931
# RUN  190 , total integrated cost =  11.832012691940456
# RUN  200 , total integrated cost =  11.82643160317858
# RUN  300 , total integrated cost =  11.776807937875112
# RUN  400 , total integrated cost =  11.749940329681406
# RUN  500 , total integrated cost =  11.734351536950827
# RUN  600 , total integrated cost =  11.717099431624526
# RUN  700 , total integrated cost =  11.707627581793387
# RUN  800 , total integrated cost =  11.701432677355882
# RUN  900 , total integrated cost =  11.69671393084391
# RUN  1000 , total integrated cost =  11.693188797250997
# RUN  1000 , total integrated cost =  11.693188797250997
# Improved over  1000  iterations in  48.3728205160005  seconds by  82.57137203749926  percent.
# [1.39931227 0.        ] [1.22262739 4.17690147]
# go back to ----- 4630
# ----- 4630
# set cost params:  0.05 0.0 117.4946243369346
# interpolate adjoint :  True True True
# initial cost =  634.4855803880291
# RUN  0 , total integrated cost =  634.4855803880291
# Gradient descend method:  None
# RUN  1 , total integrated cost =  606.2814731284659
# RUN  2 , total integrated cost =  597.3768174754209
# RUN  3 , total integrated cost =  591.7206102155684
# RUN  4 , total integrated cost =  588.0402157984141
# RUN  5 , total integrated cost =  585.4275625660202
# RUN  6 , total integrated cost =  583.7641941183576
# RUN  7 , total integrated cost =  582.4892765141437
# RUN  8 , total integrated cost =  581.4021419481751
# RUN  9 , total integrated cost =  580.4619539946277
# RUN  10 , total integrated cost =  579.8664469092479
# RUN  11 , total integrated cost =  579.3017419629475
# RUN  12 , total integrated cost =  578.9570018480309
# RUN  13 , total integrated cost =  578.6193902881981
# RUN  14 , total integrated cost =  578.3707463701586
# RUN  15 , total integrated cost =  578.1421595311739
# RUN  16 , total integrated cost =  577.9434395968146
# RUN  17 , total integrated cost =  577.7639594967751
# RUN  18 , total integrated cost =  577.6286473189059
# RUN  19 , total integrated cost =  577.5017436217253
# RUN  20 , total integrated cost =  577.3955610497642
# RUN  30 , total integrated cost =  576.8386570916135
# RUN  40 , total integrated cost =  576.6478630100365
# RUN  50 , total integrated cost =  576.5814611201829
# RUN  60 , total integrated cost =  576.5666818757958
# RUN  70 , total integrated cost =  576.5647762355924
# Control only changes marginally.
# RUN  71 , total integrated cost =  576.5647762355924
# Improved over  71  iterations in  3.7281132120115217  seconds by  9.12878179469648  percent.
# [819.14132001   0.        ] [5.95365959e-04 4.55797668e+00]
# go back to ----- 4630
# ----- 4630
# set cost params:  0.05 0.0 130.2005338956237
# interpolate adjoint :  True True True
# initial cost =  634.485580388029
# RUN  0 , total integrated cost =  634.485580388029
# Gradient descend method:  None
# RUN  1 , total integrated cost =  634.2955029754623
# RUN  2 , total integrated cost =  634.2636221118966
# RUN  3 , total integrated cost =  634.2434509624229
# RUN  4 , total integrated cost =  634.2332700094325
# RUN  5 , total integrated cost =  634.2281291999764
# RUN  6 , total integrated cost =  634.2248943709222
# RUN  7 , total integrated cost =  634.2213701054261
# RUN  8 , total integrated cost =  634.2188485590517
# RUN  9 , total integrated cost =  634.2163123658293
# RUN  10 , total integrated cost =  634.2146743420146
# RUN  11 , total integrated cost =  634.213173981791
# RUN  12 , total integrated cost =  634.2123115225303
# RUN  13 , total integrated cost =  634.2115163113025
# RUN  14 , total integrated cost =  634.2110790949207
# RUN  15 , total integrated cost =  634.2105738518217
# RUN  16 , total integrated cost =  634.2103485305046
# RUN  17 , total integrated cost =  634.2096216481456
# RUN  18 , total integrated cost =  634.2095488422466
# RUN  19 , total integrated cost =  634.2095487463463
# RUN  20 , total integrated cost =  634.2095487463463
# Control only changes marginally.
# RUN  20 , total integrated cost =  634.2095487463463
# Improved over  20  iterations in  1.211508848995436  seconds by  0.04350479352326886  percent.
# [923.57887737   0.        ] [1.22115598e-04 4.51622346e+00]
# go back to ----- 4630
# ----- 4630
# set cost params:  0.05 0.0 130.2616522571869
# interpolate adjoint :  True True True
# initial cost =  634.485580388029
# RUN  0 , total integrated cost =  634.485580388029
# Gradient descend method:  None
# RUN  1 , total integrated cost =  634.485580388029
# Control only changes marginally.
# RUN  1 , total integrated cost =  634.485580388029
# Improved over  1  iterations in  0.06922325698542409  seconds by  0.0  percent.
# [923.57887737   0.        ] [1.22115598e-04 4.51622346e+00]
# ERROR:root:Cost parameter I_s smaller 0 not allowed, use default instead
# ----- 4640
# 0.006211180124223602 0.5277083333333333
# shift ind =  0
# set cost params:  0.05 -0.0 -0.10981933787786022
# interpolate adjoint :  True True True
# initial cost =  73.18626989080126
# RUN  0 , total integrated cost =  73.18626989080126
# Gradient descend method:  None
# RUN  1 , total integrated cost =  41.53438678328095
# RUN  2 , total integrated cost =  26.301689234759273
# RUN  3 , total integrated cost =  18.034215561593136
# RUN  4 , total integrated cost =  13.110146516407465
# RUN  5 , total integrated cost =  10.543967187436873
# RUN  6 , total integrated cost =  8.436082027534173
# RUN  7 , total integrated cost =  7.660982839129403
# RUN  8 , total integrated cost =  7.431127309766117
# RUN  9 , total integrated cost =  7.268290741416724
# RUN  10 , total integrated cost =  7.134928726397822
# RUN  11 , total integrated cost =  7.02578330366353
# RUN  12 , total integrated cost =  6.924864690175728
# RUN  13 , total integrated cost =  6.839296093924049
# RUN  14 , total integrated cost =  6.780710933003654
# RUN  15 , total integrated cost =  6.7313462386321135
# RUN  16 , total integrated cost =  6.680379148086445
# RUN  17 , total integrated cost =  6.6374319464779825
# RUN  18 , total integrated cost =  6.604535645983141
# RUN  19 , total integrated cost =  6.576225857442465
# RUN  20 , total integrated cost =  6.550161924205817
# RUN  30 , total integrated cost =  6.409817534170772
# RUN  40 , total integrated cost =  6.3565214295840855
# RUN  50 , total integrated cost =  6.313644982964826
# RUN  60 , total integrated cost =  6.278763856718489
# RUN  70 , total integrated cost =  6.247059419181996
# RUN  80 , total integrated cost =  6.217916334192533
# RUN  90 , total integrated cost =  6.190698703458945
# RUN  100 , total integrated cost =  6.161375846911579
# RUN  110 , total integrated cost =  6.138040634442831
# RUN  120 , total integrated cost =  6.116422719629659
# RUN  130 , total integrated cost =  6.096987978261468
# RUN  140 , total integrated cost =  6.07818735095578
# RUN  150 , total integrated cost =  6.059572422077182
# RUN  160 , total integrated cost =  6.042307313831344
# RUN  170 , total integrated cost =  6.026249627975698
# RUN  180 , total integrated cost =  6.008893540978805
# RUN  190 , total integrated cost =  5.99516751602293
# RUN  200 , total integrated cost =  5.981890906384526
# RUN  300 , total integrated cost =  5.877866425083199
# RUN  400 , total integrated cost =  5.8029399550443
# RUN  500 , total integrated cost =  5.754721353563717
# RUN  600 , total integrated cost =  5.726019488166848
# RUN  700 , total integrated cost =  5.70764554260632
# RUN  800 , total integrated cost =  5.691165492993721
# RUN  900 , total integrated cost =  5.683002485972533
# RUN  1000 , total integrated cost =  5.677413022534862
# RUN  1000 , total integrated cost =  5.677413022534862
# Improved over  1000  iterations in  44.59362062299624  seconds by  92.24251621102437  percent.
# [0.43317015 0.        ] [1.68552261 3.9702319 ]
# go back to ----- 4640
# ----- 4640
# set cost params:  0.05 0.0 112.18024406870278
# interpolate adjoint :  True True True
# initial cost =  634.4855803880291
# RUN  0 , total integrated cost =  634.4855803880291
# Gradient descend method:  None
# RUN  1 , total integrated cost =  604.1186375929293
# RUN  2 , total integrated cost =  592.7077053201092
# RUN  3 , total integrated cost =  586.3635132316373
# RUN  4 , total integrated cost =  583.3861898241232
# RUN  5 , total integrated cost =  580.7911271164019
# RUN  6 , total integrated cost =  579.5325727984134
# RUN  7 , total integrated cost =  578.4687423681128
# RUN  8 , total integrated cost =  577.7337437269476
# RUN  9 , total integrated cost =  577.0981746215328
# RUN  10 , total integrated cost =  576.5868271716834
# RUN  11 , total integrated cost =  576.185548014138
# RUN  12 , total integrated cost =  575.864034831407
# RUN  13 , total integrated cost =  575.5907318956632
# RUN  14 , total integrated cost =  575.3565473516758
# RUN  15 , total integrated cost =  575.1687709957343
# RUN  16 , total integrated cost =  575.0006694057868
# RUN  17 , total integrated cost =  574.8483167635708
# RUN  18 , total integrated cost =  574.7190496947024
# RUN  19 , total integrated cost =  574.6019148819738
# RUN  20 , total integrated cost =  574.4977310881573
# RUN  30 , total integrated cost =  573.7730201899628
# RUN  40 , total integrated cost =  573.3233483552826
# RUN  50 , total integrated cost =  573.0589308573459
# RUN  60 , total integrated cost =  572.9052042591679
# RUN  70 , total integrated cost =  572.8104375116807
# RUN  80 , total integrated cost =  572.7694983536337
# RUN  90 , total integrated cost =  572.7305794591633
# RUN  100 , total integrated cost =  572.7116945509181
# RUN  110 , total integrated cost =  572.7017019316248
# RUN  120 , total integrated cost =  572.694310304287
# RUN  130 , total integrated cost =  572.6906547807376
# RUN  140 , total integrated cost =  572.6885471574701
# RUN  150 , total integrated cost =  572.6872794875767
# RUN  160 , total integrated cost =  572.6856936535175
# RUN  170 , total integrated cost =  572.6852899573662
# RUN  180 , total integrated cost =  572.6849686487411
# RUN  190 , total integrated cost =  572.6848993862237
# Control only changes marginally.
# RUN  198 , total integrated cost =  572.6848768032366
# Improved over  198  iterations in  10.093227930017747  seconds by  9.740284963922647  percent.
# [940.25856907   0.        ] [0.17113895 4.51481937]
# go back to ----- 4640
# ----- 4640
# set cost params:  0.05 0.0 125.36873174342364
# interpolate adjoint :  True True True
# initial cost =  634.4855803880291
# RUN  0 , total integrated cost =  634.4855803880291
# Gradient descend method:  None
# RUN  1 , total integrated cost =  634.2063525337101
# RUN  2 , total integrated cost =  634.1249011767794
# RUN  3 , total integrated cost =  634.079830897676
# RUN  4 , total integrated cost =  634.0499999362332
# RUN  5 , total integrated cost =  634.0241112571471
# RUN  6 , total integrated cost =  633.9883902543586
# RUN  7 , total integrated cost =  633.9663389042032
# RUN  8 , total integrated cost =  633.9586702893172
# RUN  9 , total integrated cost =  633.953545388746
# RUN  10 , total integrated cost =  633.9492555376638
# RUN  11 , total integrated cost =  633.9447807152471
# RUN  12 , total integrated cost =  633.939985269277
# RUN  13 , total integrated cost =  633.9356632992324
# RUN  14 , total integrated cost =  633.9315322088149
# RUN  15 , total integrated cost =  633.9279393847656
# RUN  16 , total integrated cost =  633.9251641427932
# RUN  17 , total integrated cost =  633.9222329514323
# RUN  18 , total integrated cost =  633.9193274082464
# RUN  19 , total integrated cost =  633.9167564405561
# RUN  20 , total integrated cost =  633.9140594584492
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_5634/2745927097.py in <module>
#      96         weights_maxW[i][j] = cost.getParams()
#      97
# ---> 98         bestControl_maxW[i][j], bestState_maxW[i][j], cost_maxW[i][j], runtime_, grad_, phi_, phi1_, costnode_maxW[i][j] = aln.A1(
#      99             control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
#     100             startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
#
# ~/Promotion/neurolib/neurolib/models/model.py in A1(self, control_, target_state_, c_scheme_, u_mat_, u_scheme_, max_iteration_, tolerance_, startStep_, max_control_, min_control_, t_sim_, t_sim_pre_, t_sim_post_, CGVar, line_search_, control_variables_, prec_variables_, separate_comp, transition_time_, noise_real, init_params, method)
#     664             if self.params.N == 1:
#     665                 if noise_real == 0:
# --> 666                     return opti1_rate_control.A1(self, control_, target_state_, c_scheme_, u_mat_, u_scheme_, max_iteration_,
#     667                                                 tolerance_, startStep_, max_control_, min_control_, t_sim_, t_sim_pre_, t_sim_post_, CGVar,
#     668                                                 line_search_, control_variables_, prec_variables_, separate_comp, transition_time_)
#
# ~/Promotion/neurolib/neurolib/utils/A1_aln_rate_control.py in A1(model, control_, target_state, c_scheme_, u_mat_, u_scheme_, max_iteration_, tolerance_, startStep_, cntrl_max_, cntrl_min_, t_sim_, t_sim_pre_, t_sim_post_, CGVar, line_search_, control_variables_, prec_variables_, separate_comp, transition_time_)
#     258
#     259         for ind_time in range(T):
# --> 260             f_p_grad_t_ = cost.cost_precision_gradient_t(N, V_target, state0_[:,:2,ind_time], target_state_[:,:,ind_time], ip_)
#     261             for v in prec_variables:
#     262                 full_cost_grad[0,v,ind_time] = f_p_grad_t_[0,v]
#
# KeyboardInterrupt:
