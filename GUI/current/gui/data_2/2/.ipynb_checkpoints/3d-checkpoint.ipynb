# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import sys
import pickle
import smoothfit

path = os.getcwd().split(os.sep + 'GUI')[0]
if path not in sys.path:
    print("not here")
    sys.path.append(path)

from neurolib.models.aln import ALNModel
from neurolib.utils import plotFunctions as plotFunc
from neurolib.utils import costFunctions as cost
import neurolib.dashboard.functions as functions
import neurolib.dashboard.data as data
    
# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2 

#path = os.path.join(os.getcwd(), "plots")
# Out:
# not here

# %%
grid_data_file = os.path.join(os.getcwd().split('data')[0], 'bi.pickle')
print(grid_data_file)
with open(grid_data_file,'rb') as f:
    load_array= pickle.load(f)
exc = load_array[0]
inh = load_array[1]
print(len(exc))
# Out:
# /home/lena/Promotion/neurolib/GUI/current/gui/bi.pickle
# 147

# %% [markdown]
# ### Bistability

# %%
aln = ALNModel()
N = aln.params.N

data.set_parameters(aln)

state_vars = aln.state_vars
init_vars = aln.init_vars

##############################################################
def setinit(init_vars_, model):
    state_vars = model.state_vars
    init_vars = model.init_vars
    for iv in range(len(init_vars)):
        for sv in range(len(state_vars)):
            if state_vars[sv] in init_vars[iv]:
                #print("set init vars ", )
                if model.params[init_vars[iv]].ndim == 2:
                    model.params[init_vars[iv]][0,:] = init_vars_[sv]
                else:
                    model.params[init_vars[iv]][0] = init_vars_[sv]
                    
##############################################################               
def setmaxmincontrol(max_c_c, min_c_c, max_c_r, min_c_r):
    import numpy as np
    
    max_cntrl = np.zeros(( 6 ))
    min_cntrl = np.zeros(( 6 ))
    
    max_cntrl[0] = max_c_c
    min_cntrl[0] = min_c_c
    max_cntrl[1] = max_c_c
    min_cntrl[1] = min_c_c
    max_cntrl[2] = max_c_r
    min_cntrl[2] = min_c_r
    max_cntrl[3] = max_c_r
    min_cntrl[3] = min_c_r
    max_cntrl[4] = max_c_r
    min_cntrl[4] = min_c_r
    max_cntrl[5] = max_c_r
    min_cntrl[5] = min_c_r
            
    return max_cntrl, min_cntrl

# %%
d_array = np.arange(20., 300, 0.1)
t0_array = d_array - 20.
t_pen = np.zeros(( t0_array.shape ))
for i in range(len(t_pen)):
    t_pen[i] = t0_array[i] / d_array[i]

bestControl_ = np.array( [[None] * len(t_pen)] * len(exc) )
bestState_ = np.array( [[None] * len(t_pen)] * len(exc) )
cost_ = np.array( [[None] * len(t_pen)] * len(exc) )
costnode_ = np.array( [[None] * len(t_pen)] * len(exc) )
weights_ = np.array( [[None] * len(t_pen)] * len(exc) )
convergence_ = np.array( [[None] * len(t_pen)] * len(exc) )

initVars = [None] * len(exc)
target = [None] * len(exc)
cost_uncontrolled = [None] * len(exc)

print(bestControl_.shape)
# Out:
# (147, 2800)

# %%
file_ = '3d.pickle'
case = '1'

# %%
dur_pre = 10
dur_post = 10

n_pre = int(np.around(dur_pre/aln.params.dt + 1.,1))
n_post = int(np.around(dur_post/aln.params.dt + 1.,1))

tol = 1e-32
start_step = 10.
c_scheme = np.zeros(( 1,1 ))
c_scheme[0,0] = 1.
u_mat = np.identity(1)
u_scheme = np.array([[1.]])

c_var = [0,1]
p_var = [0]

if case in ['1', '2']:    # low to high
    max_I = [3., -3.]
else:
    max_I = [-3., 3.]
    
if case in ['1', '3']:    # sparsity
    factor_ws = 1.
    factor_we = 0.
else:
    factor_ws = 0.
    factor_we = 1.
    
maxC = [5., -5., 0.18, 0.]
max_cntrl, min_cntrl = setmaxmincontrol(maxC[0], maxC[1], maxC[2], maxC[3])

# %%
if os.path.isfile(file_) :
    print("file found")
    
    with open(file_,'rb') as f:
        load_array = pickle.load(f)

    bestControl_ = load_array[0]
    bestState_ = load_array[1]
    cost_ = load_array[2]
    costnode_ = load_array[3]
    weights_ = load_array[4]

# %%
# get initial parameters and target states

#i_stepsize = 20
#limit = 150
#start_index = 0
#i_range = range(start_index, limit,i_stepsize)
i_range = [20]

data.set_parameters(aln)

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    aln.params.duration = 3000.
    
    control0 = aln.getZeroControl()
    control0 = functions.step_control(aln, maxI_ = max_I[0])

    aln.run(control=control0)
    
    target_rates = np.zeros((2))
    target_rates[0] = aln.rates_exc[0,-1] 
    target_rates[1] = aln.rates_inh[0,-1]

    control0 = functions.step_control(aln, maxI_ = max_I[1])
    aln.run(control=control0)

    init_state_vars = np.zeros(( len(state_vars) ))
    for j in range(len(state_vars)):
        if aln.state[state_vars[j]].size == 1:
            init_state_vars[j] = aln.state[state_vars[j]][0]
        else:
            init_state_vars[j] = aln.state[state_vars[j]][0,-1]

    initVars[i] = init_state_vars
    target[i] = [target_rates[0], target_rates[1]]
# Out:
# -------  20 0.4500000000000001 0.4750000000000002

# %%
# get uncontrolled cost

data.set_parameters(aln)

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    dur = d_array[0]
    aln.params.duration = dur
    
    target_ = aln.getZeroTarget()
    target_[:,0,:] = target[i][0]
    target_[:,1,:] = target[i][1]
        
    cost.setParams(1.0, 0.0, 0.0)

    setinit(initVars[i], aln)
    control0 = aln.getZeroControl()

    # "HS", "FR", "PR", "HZ"
    cgv = None
    max_it = 0

    bestControl_init_, bestState_init_, cost_init_, runtime_init_, grad_init_, phi_init_, costnode_init_ = aln.A1(
        control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
        prec_variables_ = p_var, transition_time_ = 0.)
    
    cost_uncontrolled[i] = cost_init_[0]
# Out:
# -------  20 0.4500000000000001 0.4750000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  0 , total integrated cost =  12801.807032522984
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.

# %%
cgv = None
j = 0
k = 0

while k < 10:
    print('-------------------------------------------- k = ', k)

    for i in i_range:
        print("------- ", i, exc[i], inh[i])
        aln.params.ext_exc_current = exc[i] * 5.
        aln.params.ext_inh_current = inh[i] * 5.

        if convergence_[i][j] == True:
            print('converged')
            continue

        dur = d_array[0]
        aln.params.duration = dur
        
        setinit(initVars[i], aln)

        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        max_it = int(100)

        if type(bestControl_[i][j]) == type(None) or np.amax(np.abs(bestControl_[i][j])) < 1e-6:
            print('no solution found')
            control0 = aln.getZeroControl()
            #control0[0,0,:50] = 5.
            cost.setParams(1.0, 0., 1.)
            max_it = int(1)
            weights_[i][j] = [1., 0., 1.]
        else:
            control0 = bestControl_[i][j][:,:,n_pre-1:-n_post+1]
            l = 1
            while cost_[i][j][-l] == 0.:
                l += 1

            weight_ = ( cost_uncontrolled[i] - costnode_[i][j][0][0][0] ) / sum( costnode_[i][j][2][0][:] )
                
            print("weight = ", weight_)
            cost.setParams(1.0, weight_ * factor_we, weight_ * factor_ws)
            weights_[i][j] = cost.getParams()

        bestControl_[i][j], bestState_[i][j], cost_[i][j], runtime_, grad_, phi_, costnode_[i][j] = aln.A1(
            control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = [1],
            prec_variables_ = p_var, transition_time_ = t_pen[j])

        #if cost_[i][j][2] == 0.:
        #    print('converged')
        #    convergence_[i][j] = True

        print('uncontrolled cost : ', cost_uncontrolled[i])
        print('cost splitting : ', costnode_[i][j][0][0][0], costnode_[i][j][2][0][:2])

        time_ = np.arange(-dur_pre,dur+dur_post+aln.params.dt,aln.params.dt)
        dur += dur_pre + dur_post
        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        if True:
            fig, ax = plt.subplots(2,1, constrained_layout=True, figsize = (4,4) )
            ax[1].plot(time_, bestControl_[i][j][0,0,:], color = 'red')
            ax[0].plot(time_, bestState_[i][j][0,0,:], color= 'red')
            ax[1].plot(time_, bestControl_[i][j][0,1,:], color = 'blue')
            ax[0].plot(time_, bestState_[i][j][0,1,:], color= 'blue')
            ax[0].plot(time_, target_[0,0,:], linestyle = '--', color='red')
            ax[0].plot(time_, target_[0,1,:], linestyle = '--', color='blue')
            ax[0].set_xlim(-dur_pre,dur-dur_post)
            ax[1].set_xlim(-dur_pre,dur-dur_post)
            ax[0].axvspan(t0_array[0], dur, alpha=0.2, color='gray')
            plt.show()

        with open(file_,'wb') as f:
            pickle.dump([bestControl_, bestState_, cost_, costnode_, weights_], f)
    
    k += 1
# Out:
# -------------------------------------------- k =  0
# -------  20 0.4500000000000001 0.4750000000000002
# no solution found
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  9444.199144044613
# RUN  1 , total integrated cost =  9444.199144044613
# Improved over  1  iterations in  26.938155794050545  seconds by  26.227608961362805  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  9438.294876277036 [0.         5.90426777]
# -------------------------------------------- k =  1
# -------  20 0.4500000000000001 0.4750000000000002
# weight =  569.6747316773378
# set cost params:  1.0 0.0 569.6747316773378
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12772.358064437001
# RUN  2 , total integrated cost =  12749.621242966616
# RUN  3 , total integrated cost =  12732.171609177196
# RUN  4 , total integrated cost =  12719.270884094178
# RUN  5 , total integrated cost =  12709.454637556424
# RUN  6 , total integrated cost =  12701.815254663874
# RUN  7 , total integrated cost =  12695.813125710483
# RUN  8 , total integrated cost =  12691.2970356773
# RUN  9 , total integrated cost =  12687.593093545522
# RUN  10 , total integrated cost =  12684.520484537754
# RUN  11 , total integrated cost =  12681.890836830436
# RUN  12 , total integrated cost =  12679.81879166343
# RUN  13 , total integrated cost =  12678.027251238937
# RUN  14 , total integrated cost =  12676.767103842818
# RUN  15 , total integrated cost =  12675.6045212568
# RUN  16 , total integrated cost =  12674.688012431805
# RUN  17 , total integrated cost =  12673.827156404384
# RUN  18 , total integrated cost =  12673.139336157492
# RUN  19 , total integrated cost =  12672.53599253744
# RUN  20 , total integrated cost =  12672.03426805036
# RUN  30 , total integrated cost =  12669.931611202326
# RUN  40 , total integrated cost =  12669.577455779488
# RUN  50 , total integrated cost =  12669.307427533315
# RUN  60 , total integrated cost =  12669.295640525826
# Control only changes marginally.
# RUN  63 , total integrated cost =  12669.295636811981
# Improved over  63  iterations in  1.559399125049822  seconds by  1.0350991494744335  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  9339.746496766073 [0.         5.84464951]
# -------------------------------------------- k =  2
# -------  20 0.4500000000000001 0.4750000000000002
# weight =  592.3469886769187
# set cost params:  1.0 0.0 592.3469886769187
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.701855619574
# RUN  2 , total integrated cost =  12801.671802968496
# RUN  3 , total integrated cost =  12801.645871799024
# RUN  4 , total integrated cost =  12801.623668586682
# RUN  5 , total integrated cost =  12801.60645765147
# RUN  6 , total integrated cost =  12801.591388995577
# RUN  7 , total integrated cost =  12801.581351156483
# RUN  8 , total integrated cost =  12801.571089647163
# RUN  9 , total integrated cost =  12801.55958766985
# RUN  10 , total integrated cost =  12801.551476043673
# RUN  11 , total integrated cost =  12801.543800542895
# RUN  12 , total integrated cost =  12801.538986823452
# RUN  13 , total integrated cost =  12801.533734025423
# RUN  14 , total integrated cost =  12801.531193998246
# RUN  15 , total integrated cost =  12801.528260580655
# RUN  16 , total integrated cost =  12801.526379469859
# RUN  17 , total integrated cost =  12801.521544555118
# RUN  18 , total integrated cost =  12801.517850467022
# RUN  19 , total integrated cost =  12801.509300395624
# RUN  20 , total integrated cost =  12801.508315533945
# Control only changes marginally.
# RUN  29 , total integrated cost =  12801.50322642536
# Improved over  29  iterations in  0.8653742959722877  seconds by  0.002373150109605149  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  9356.479817553367 [0.         5.81588744]
# -------------------------------------------- k =  3
# -------  20 0.4500000000000001 0.4750000000000002
# weight =  592.399225949561
# set cost params:  1.0 0.0 592.399225949561
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522982
# RUN  2 , total integrated cost =  12801.807032522982
# Control only changes marginally.
# RUN  2 , total integrated cost =  12801.807032522982
# Improved over  2  iterations in  0.2062219560611993  seconds by  1.4210854715202004e-14  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  9356.47981754994 [0.         5.81588744]
# -------------------------------------------- k =  4
# -------  20 0.4500000000000001 0.4750000000000002
# weight =  592.3992259495612
# set cost params:  1.0 0.0 592.3992259495612
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.14086003205738962  seconds by  0.0  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  9356.47981754994 [0.         5.81588744]
# -------------------------------------------- k =  5
# -------  20 0.4500000000000001 0.4750000000000002
# weight =  592.3992259495612
# set cost params:  1.0 0.0 592.3992259495612
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.1391978560714051  seconds by  0.0  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  9356.47981754994 [0.         5.81588744]
# -------------------------------------------- k =  6
# -------  20 0.4500000000000001 0.4750000000000002
# weight =  592.3992259495612
# set cost params:  1.0 0.0 592.3992259495612
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.12276997801382095  seconds by  0.0  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  9356.47981754994 [0.         5.81588744]
# -------------------------------------------- k =  7
# -------  20 0.4500000000000001 0.4750000000000002
# weight =  592.3992259495612
# set cost params:  1.0 0.0 592.3992259495612
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.13361785106826574  seconds by  0.0  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  9356.47981754994 [0.         5.81588744]
# -------------------------------------------- k =  8
# -------  20 0.4500000000000001 0.4750000000000002
# weight =  592.3992259495612
# set cost params:  1.0 0.0 592.3992259495612
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.13889612595085055  seconds by  0.0  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  9356.47981754994 [0.         5.81588744]
# -------------------------------------------- k =  9
# -------  20 0.4500000000000001 0.4750000000000002
# weight =  592.3992259495612
# set cost params:  1.0 0.0 592.3992259495612
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.13801528699696064  seconds by  0.0  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  9356.47981754994 [0.         5.81588744]

# %%
for i in range(bestControl_.shape[0]):
    for j in range(1,bestControl_.shape[1]):
        bestControl_[i][j] = None
        convergence_[i][j] = None

# %%
cost.setParams(1.0, factor_we, factor_ws)

j_start = 1

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.

    for j in range(j_start,j_start+600):
        print(i,j, '-----------------')
            
        k = 0
        while convergence_[i][j] != True:
            print('---------------------', k)

            dur = round(d_array[j],1)
            print('simulation duration : ', dur)
            aln.params.duration = dur
            max_it = int(100)  
            
            setinit(initVars[i], aln)
            target_ = aln.getZeroTarget()
            target_[:,0,:] = target[i][0]
            target_[:,1,:] = target[i][1]

            if type(bestControl_[i][j]) == type(None):
                print('no solution computed yet')
                control0 = aln.getZeroControl()
                control1 = aln.getZeroControl()
                if j%2 == 0:
                    control0[:,:,1:] = bestControl_[i][j-1][:,:,n_pre-1:-n_post+1]
                else:
                    control0[:,:,:-1] = bestControl_[i][j-1][:,:,n_pre-1:-n_post+1]

                time_ = np.arange(0.,round(dur+aln.params.dt,1),aln.params.dt)
                basis, coeffs = smoothfit.fit1d(time_[1:], control0[0,0,1:],
                                aln.params.dt, round(dur+aln.params.dt,1), int(len(time_)-2), degree=1, lmbda=1.)
                control1[0,0,1:] = coeffs[basis.nodal_dofs[0]]
                basis, coeffs = smoothfit.fit1d(time_[1:], control0[0,1,1:],
                                aln.params.dt, round(dur+aln.params.dt,1), int(len(time_)-2), degree=1, lmbda=1.)
                control1[0,1,1:] = coeffs[basis.nodal_dofs[0]]                            
                                        
                l = 1
                while cost_[i][j-1][-l] == 0.:
                    l += 1
                    
                weight_ = ( cost_uncontrolled[i] - costnode_[i][j-1][0][0][0] ) / sum( costnode_[i][j-1][2][0][:] )
            else:
                control1 = bestControl_[i][j][:,:,n_pre-1:-n_post+1]
                l = 1
                while cost_[i][j][-l] == 0.:
                    l += 1
                
                weight_ = ( cost_uncontrolled[i] - costnode_[i][j][0][0][0] ) / sum( costnode_[i][j][2][0][:] )
                
            print("weight = ", weight_)
            cost.setParams(1.0, weight_ * factor_we, weight_ * factor_ws)
            weights_[i][j] = cost.getParams()

            bestControl_[i][j], bestState_[i][j], cost_[i][j], runtime_, grad_, phi_, costnode_[i][j] = aln.A1(
                control1, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
                startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
                t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = [1],
                prec_variables_ = p_var, transition_time_ = t_pen[j])

            if cost_[i][j][2] == 0.:
                print('converged')
                convergence_[i][j] = True

            print('uncontrolled cost : ', cost_uncontrolled[i])
            print('cost splitting : ', costnode_[i][j][0][0][0], costnode_[i][j][2][0][:2])
                
            time_ = np.arange(-dur_pre,round(dur+dur_post+aln.params.dt,1),aln.params.dt)
            dur += dur_pre + dur_post
            target_ = aln.getZeroTarget()
            target_[:,0,:] = target[i][0]
            target_[:,1,:] = target[i][1]

            if False:
                fig, ax = plt.subplots(2,1, constrained_layout=True, figsize = (4,4) )
                ax[1].plot(time_, bestControl_[i][j][0,0,:], color = 'red')
                ax[0].plot(time_, bestState_[i][j][0,0,:], color= 'red')
                ax[1].plot(time_, bestControl_[i][j][0,1,:], color = 'blue')
                ax[0].plot(time_, bestState_[i][j][0,1,:], color= 'blue')
                ax[0].plot(time_, target_[0,0,:], linestyle = '--', color='red')
                ax[0].plot(time_, target_[0,1,:], linestyle = '--', color='blue')
                ax[0].set_xlim(-dur_pre,dur-dur_post)
                ax[1].set_xlim(-dur_pre,dur-dur_post)
                ax[0].axvspan(t0_array[j], t0_array[j]+20, alpha=0.2, color='gray')
                plt.show()

            with open(file_,'wb') as f:
                pickle.dump([bestControl_, bestState_, cost_, costnode_, weights_], f)
                
            k += 1
# Out:
# set cost params:  1.0 0.0 1.0
# -------  20 0.4500000000000001 0.4750000000000002
# 20 1 -----------------
# 20 2 -----------------
# 20 3 -----------------
# 20 4 -----------------
# 20 5 -----------------
# 20 6 -----------------
# 20 7 -----------------
# 20 8 -----------------
# 20 9 -----------------
# 20 10 -----------------
# 20 11 -----------------
# 20 12 -----------------
# 20 13 -----------------
# 20 14 -----------------
# 20 15 -----------------
# 20 16 -----------------
# 20 17 -----------------
# 20 18 -----------------
# 20 19 -----------------
# 20 20 -----------------
# 20 21 -----------------
# 20 22 -----------------
# 20 23 -----------------
# 20 24 -----------------
# 20 25 -----------------
# 20 26 -----------------
# 20 27 -----------------
# 20 28 -----------------
# 20 29 -----------------
# 20 30 -----------------
# 20 31 -----------------
# 20 32 -----------------
# 20 33 -----------------
# 20 34 -----------------
# 20 35 -----------------
# 20 36 -----------------
# 20 37 -----------------
# 20 38 -----------------
# 20 39 -----------------
# 20 40 -----------------
# 20 41 -----------------
# 20 42 -----------------
# 20 43 -----------------
# 20 44 -----------------
# 20 45 -----------------
# 20 46 -----------------
# 20 47 -----------------
# 20 48 -----------------
# 20 49 -----------------
# 20 50 -----------------
# 20 51 -----------------
# 20 52 -----------------
# 20 53 -----------------
# 20 54 -----------------
# 20 55 -----------------
# 20 56 -----------------
# 20 57 -----------------
# 20 58 -----------------
# 20 59 -----------------
# 20 60 -----------------
# 20 61 -----------------
# 20 62 -----------------
# 20 63 -----------------
# 20 64 -----------------
# 20 65 -----------------
# 20 66 -----------------
# 20 67 -----------------
# 20 68 -----------------
# 20 69 -----------------
# 20 70 -----------------
# 20 71 -----------------
# 20 72 -----------------
# 20 73 -----------------
# 20 74 -----------------
# 20 75 -----------------
# 20 76 -----------------
# 20 77 -----------------
# 20 78 -----------------
# 20 79 -----------------
# 20 80 -----------------
# 20 81 -----------------
# 20 82 -----------------
# 20 83 -----------------
# 20 84 -----------------
# 20 85 -----------------
# 20 86 -----------------
# 20 87 -----------------
# 20 88 -----------------
# 20 89 -----------------
# 20 90 -----------------
# 20 91 -----------------
# 20 92 -----------------
# 20 93 -----------------
# 20 94 -----------------
# 20 95 -----------------
# 20 96 -----------------
# 20 97 -----------------
# 20 98 -----------------
# 20 99 -----------------
# 20 100 -----------------
# 20 101 -----------------
# --------------------- 0
# simulation duration :  30.1
# no solution computed yet
# weight =  1444.2772775250387
# set cost params:  1.0 0.0 1444.2772775250387
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12727.106864123652
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12727.106864123647
# RUN  2 , total integrated cost =  12727.106864123647
# Control only changes marginally.
# RUN  2 , total integrated cost =  12727.106864123647
# Improved over  2  iterations in  0.2864759999793023  seconds by  4.263256414560601e-14  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  5367.41360700225 [0.         5.09576199]
# --------------------- 1
# simulation duration :  30.1
# weight =  1458.9365509590316
# set cost params:  1.0 0.0 1458.9365509590316
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.13564416905865073  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  5367.41360700225 [0.         5.09576199]
# 20 102 -----------------
# --------------------- 0
# simulation duration :  30.2
# no solution computed yet
# weight =  1458.9365509590316
# set cost params:  1.0 0.0 1458.9365509590316
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12790.01377731443
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12702.729512340746
# RUN  2 , total integrated cost =  12702.694646644508
# RUN  3 , total integrated cost =  12702.694641717848
# RUN  4 , total integrated cost =  12702.694641650436
# RUN  5 , total integrated cost =  12702.694641649301
# RUN  6 , total integrated cost =  12702.694641649286
# RUN  7 , total integrated cost =  12702.694641649286
# Control only changes marginally.
# RUN  7 , total integrated cost =  12702.694641649286
# Improved over  7  iterations in  0.42575857299380004  seconds by  0.6827133823735352  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  5219.869982404959 [0.         5.12895825]
# --------------------- 1
# simulation duration :  30.2
# weight =  1478.2606292694777
# set cost params:  1.0 0.0 1478.2606292694777
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.80215709897
# RUN  2 , total integrated cost =  12801.802152470938
# RUN  3 , total integrated cost =  12801.802152297401
# RUN  4 , total integrated cost =  12801.802152287815
# RUN  5 , total integrated cost =  12801.802152287812
# RUN  6 , total integrated cost =  12801.802152287812
# Control only changes marginally.
# RUN  6 , total integrated cost =  12801.802152287812
# Improved over  6  iterations in  0.39180786500219256  seconds by  3.8121455503414836e-05  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  5221.35536681972 [0.         5.12795013]
# --------------------- 2
# simulation duration :  30.2
# weight =  1478.2615809626589
# set cost params:  1.0 0.0 1478.2615809626589
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522982
# RUN  2 , total integrated cost =  12801.807032522982
# Control only changes marginally.
# RUN  2 , total integrated cost =  12801.807032522982
# Improved over  2  iterations in  0.268428758950904  seconds by  1.4210854715202004e-14  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  5221.355366819721 [0.         5.12795013]
# --------------------- 3
# simulation duration :  30.2
# weight =  1478.261580962659
# set cost params:  1.0 0.0 1478.261580962659
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.12370221398305148  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  5221.355366819721 [0.         5.12795013]
# 20 103 -----------------
# --------------------- 0
# simulation duration :  30.3
# no solution computed yet
# weight =  1478.261580962659
# set cost params:  1.0 0.0 1478.261580962659
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12720.890864134642
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12720.890864134642
# Control only changes marginally.
# RUN  1 , total integrated cost =  12720.890864134642
# Improved over  1  iterations in  0.28669504600111395  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  5156.898800399972 [0.        5.1168157]
# 20 104 -----------------
# --------------------- 0
# simulation duration :  30.4
# no solution computed yet
# weight =  1494.0753552235656
# set cost params:  1.0 0.0 1494.0753552235656
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12770.310552219975
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12770.310552219973
# RUN  2 , total integrated cost =  12770.310552219973
# Control only changes marginally.
# RUN  2 , total integrated cost =  12770.310552219973
# Improved over  2  iterations in  0.27906750701367855  seconds by  1.4210854715202004e-14  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  5193.872950212079 [0.        5.0709876]
# --------------------- 1
# simulation duration :  30.4
# weight =  1500.2864688720883
# set cost params:  1.0 0.0 1500.2864688720883
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522982
# RUN  2 , total integrated cost =  12801.807032522982
# Control only changes marginally.
# RUN  2 , total integrated cost =  12801.807032522982
# Improved over  2  iterations in  0.21478542604018003  seconds by  1.4210854715202004e-14  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  5193.87295021208 [0.        5.0709876]
# --------------------- 2
# simulation duration :  30.4
# weight =  1500.2864688720886
# set cost params:  1.0 0.0 1500.2864688720886
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522986
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522986
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522986
# Improved over  1  iterations in  0.11883140192367136  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  5193.87295021208 [0.        5.0709876]
# 20 105 -----------------
# --------------------- 0
# simulation duration :  30.5
# no solution computed yet
# weight =  1500.2864688720886
# set cost params:  1.0 0.0 1500.2864688720886
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12721.255596392242
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12721.255596392239
# RUN  2 , total integrated cost =  12721.255596392235
# RUN  3 , total integrated cost =  12721.255596392235
# Control only changes marginally.
# RUN  3 , total integrated cost =  12721.255596392235
# Improved over  3  iterations in  0.5226878980174661  seconds by  5.684341886080802e-14  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  5129.600450620265 [0.         5.06013705]
# --------------------- 1
# simulation duration :  30.5
# weight =  1516.205293865408
# set cost params:  1.0 0.0 1516.205293865408
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.1358095200266689  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  5129.600450620265 [0.         5.06013705]
# 20 106 -----------------
# --------------------- 0
# simulation duration :  30.6
# no solution computed yet
# weight =  1516.205293865408
# set cost params:  1.0 0.0 1516.205293865408
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12782.602418083614
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12782.60241808361
# RUN  2 , total integrated cost =  12782.602418083607
# RUN  3 , total integrated cost =  12782.602418083607
# Control only changes marginally.
# RUN  3 , total integrated cost =  12782.602418083607
# Improved over  3  iterations in  0.47460802795831114  seconds by  5.684341886080802e-14  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  5168.80334181306 [0.         5.02161489]
# --------------------- 1
# simulation duration :  30.6
# weight =  1520.029684000732
# set cost params:  1.0 0.0 1520.029684000732
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.1343805460492149  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  5168.80334181306 [0.         5.02161489]
# 20 107 -----------------
# --------------------- 0
# simulation duration :  30.7
# no solution computed yet
# weight =  1520.029684000732
# set cost params:  1.0 0.0 1520.029684000732
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12722.589365537022
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12720.22775873051
# RUN  2 , total integrated cost =  12608.230300088682
# RUN  3 , total integrated cost =  12599.427452712833
# RUN  4 , total integrated cost =  12599.403949318457
# RUN  5 , total integrated cost =  12599.403949318446
# RUN  6 , total integrated cost =  12599.403949318446
# Control only changes marginally.
# RUN  6 , total integrated cost =  12599.403949318446
# Improved over  6  iterations in  0.4602330159395933  seconds by  0.968241705200839  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  4775.580263160529 [0.         5.14715191]
# --------------------- 1
# simulation duration :  30.7
# weight =  1559.3530004436222
# set cost params:  1.0 0.0 1559.3530004436222
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.768063443902
# RUN  2 , total integrated cost =  12801.76803712501
# RUN  3 , total integrated cost =  12801.768037124837
# RUN  4 , total integrated cost =  12801.76803712483
# RUN  5 , total integrated cost =  12801.76803712483
# Control only changes marginally.
# RUN  5 , total integrated cost =  12801.76803712483
# Improved over  5  iterations in  0.31739995104726404  seconds by  0.00030460854515013125  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  4779.8762124020195 [0.         5.14437194]
# --------------------- 2
# simulation duration :  30.7
# weight =  1559.3605806494445
# set cost params:  1.0 0.0 1559.3605806494445
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.8070325209
# RUN  2 , total integrated cost =  12801.80703252088
# RUN  3 , total integrated cost =  12801.807032520876
# RUN  4 , total integrated cost =  12801.807032520876
# Control only changes marginally.
# RUN  4 , total integrated cost =  12801.807032520876
# Improved over  4  iterations in  0.3036669900175184  seconds by  1.6470380614919122e-11  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  4779.8774915836975 [0.         5.14437112]
# --------------------- 3
# simulation duration :  30.7
# weight =  1559.3605806498545
# set cost params:  1.0 0.0 1559.3605806498545
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.1306905320379883  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  4779.8774915836975 [0.         5.14437112]
# 20 108 -----------------
# --------------------- 0
# simulation duration :  30.8
# no solution computed yet
# weight =  1559.3605806498545
# set cost params:  1.0 0.0 1559.3605806498545
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12762.11411833543
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12762.11411833543
# Control only changes marginally.
# RUN  1 , total integrated cost =  12762.11411833543
# Improved over  1  iterations in  0.3707468539942056  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  4816.02706424213 [0.         5.09573421]
# 20 109 -----------------
# --------------------- 0
# simulation duration :  30.9
# no solution computed yet
# weight =  1567.1500203191947
# set cost params:  1.0 0.0 1567.1500203191947
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12718.284347300225
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12718.284347300221
# RUN  2 , total integrated cost =  12718.284347300221
# Control only changes marginally.
# RUN  2 , total integrated cost =  12718.284347300221
# Improved over  2  iterations in  0.4165549089666456  seconds by  2.842170943040401e-14  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  4749.087024351466 [0.         5.08515281]
# --------------------- 1
# simulation duration :  30.9
# weight =  1583.574833576991
# set cost params:  1.0 0.0 1583.574833576991
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522982
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522982
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522982
# Improved over  1  iterations in  0.1376224869163707  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  4749.087024351466 [0.         5.08515281]
# 20 110 -----------------
# --------------------- 0
# simulation duration :  31.0
# no solution computed yet
# weight =  1583.574833576991
# set cost params:  1.0 0.0 1583.574833576991
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12776.33707414637
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12776.33707414637
# Control only changes marginally.
# RUN  1 , total integrated cost =  12776.33707414637
# Improved over  1  iterations in  0.32465765392407775  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  4786.298098501058 [0.         5.04557082]
# 20 111 -----------------
# --------------------- 0
# simulation duration :  31.1
# no solution computed yet
# weight =  1588.6228171000255
# set cost params:  1.0 0.0 1588.6228171000255
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12719.132659183097
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12719.132659183097
# Control only changes marginally.
# RUN  1 , total integrated cost =  12719.132659183097
# Improved over  1  iterations in  0.31426816096063703  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  4720.657245809844 [0.         5.03484863]
# 20 112 -----------------
# --------------------- 0
# simulation duration :  31.2
# no solution computed yet
# weight =  1605.0432458804398
# set cost params:  1.0 0.0 1605.0432458804398
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12787.106544171093
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12787.106544171089
# RUN  2 , total integrated cost =  12787.106544171089
# Control only changes marginally.
# RUN  2 , total integrated cost =  12787.106544171089
# Improved over  2  iterations in  0.5462591840187088  seconds by  2.842170943040401e-14  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  4760.594767663502 [0.         5.00080717]
# --------------------- 1
# simulation duration :  31.2
# weight =  1607.982868994108
# set cost params:  1.0 0.0 1607.982868994108
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522982
# RUN  2 , total integrated cost =  12801.807032522982
# Control only changes marginally.
# RUN  2 , total integrated cost =  12801.807032522982
# Improved over  2  iterations in  0.29341705003753304  seconds by  1.4210854715202004e-14  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  4760.594767663504 [0.         5.00080717]
# --------------------- 2
# simulation duration :  31.2
# weight =  1607.9828689941082
# set cost params:  1.0 0.0 1607.9828689941082
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522982
# RUN  2 , total integrated cost =  12801.807032522982
# Control only changes marginally.
# RUN  2 , total integrated cost =  12801.807032522982
# Improved over  2  iterations in  0.27104188699740916  seconds by  1.4210854715202004e-14  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  4760.594767663504 [0.         5.00080717]
# --------------------- 3
# simulation duration :  31.2
# weight =  1607.9828689941085
# set cost params:  1.0 0.0 1607.9828689941085
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.1496396060101688  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  4760.594767663504 [0.         5.00080717]
# 20 113 -----------------
# --------------------- 0
# simulation duration :  31.3
# no solution computed yet
# weight =  1607.9828689941085
# set cost params:  1.0 0.0 1607.9828689941085
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12720.937409640454
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12716.617322409344
# RUN  2 , total integrated cost =  12607.286473233624
# RUN  3 , total integrated cost =  12604.863169704167
# RUN  4 , total integrated cost =  12604.863169704167
# Control only changes marginally.
# RUN  4 , total integrated cost =  12604.863169704167
# Improved over  4  iterations in  0.4080791970482096  seconds by  0.9124660879812296  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  4422.998800749003 [0.         5.08827832]
# --------------------- 1
# simulation duration :  31.3
# weight =  1646.6882719787616
# set cost params:  1.0 0.0 1646.6882719787616
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.785412478903
# RUN  2 , total integrated cost =  12801.785406869
# RUN  3 , total integrated cost =  12801.785406868992
# RUN  4 , total integrated cost =  12801.78540686899
# RUN  5 , total integrated cost =  12801.785406868989
# RUN  6 , total integrated cost =  12801.785406868985
# RUN  7 , total integrated cost =  12801.785406868985
# Control only changes marginally.
# RUN  7 , total integrated cost =  12801.785406868985
# Improved over  7  iterations in  0.36848165304400027  seconds by  0.00016892657374967257  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  4426.488186566755 [0.         5.08614615]
# --------------------- 2
# simulation duration :  31.3
# weight =  1646.6925238530387
# set cost params:  1.0 0.0 1646.6925238530387
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522986
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522986
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522986
# Improved over  1  iterations in  0.14100719499401748  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  4426.488186566755 [0.         5.08614615]
# 20 114 -----------------
# --------------------- 0
# simulation duration :  31.4
# no solution computed yet
# weight =  1646.6925238530387
# set cost params:  1.0 0.0 1646.6925238530387
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12759.374046963809
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12759.374046963803
# RUN  2 , total integrated cost =  12759.374046963803
# Control only changes marginally.
# RUN  2 , total integrated cost =  12759.374046963803
# Improved over  2  iterations in  0.4464852720266208  seconds by  4.263256414560601e-14  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  4459.992755368906 [0.         5.04003095]
# --------------------- 1
# simulation duration :  31.4
# weight =  1655.1117153120247
# set cost params:  1.0 0.0 1655.1117153120247
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522982
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522982
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522982
# Improved over  1  iterations in  0.14398007898125798  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  4459.992755368906 [0.         5.04003095]
# 20 115 -----------------
# --------------------- 0
# simulation duration :  31.5
# no solution computed yet
# weight =  1655.1117153120247
# set cost params:  1.0 0.0 1655.1117153120247
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12714.335201583037
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12714.335201583037
# Control only changes marginally.
# RUN  1 , total integrated cost =  12714.335201583037
# Improved over  1  iterations in  0.3210697330068797  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  4389.649948567301 [0.         5.02968179]
# 20 116 -----------------
# --------------------- 0
# simulation duration :  31.6
# no solution computed yet
# weight =  1672.5028415526297
# set cost params:  1.0 0.0 1672.5028415526297
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12773.706121383802
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12773.706121383802
# Control only changes marginally.
# RUN  1 , total integrated cost =  12773.706121383802
# Improved over  1  iterations in  0.3352379980497062  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  4425.037322654463 [0.         4.99172174]
# 20 117 -----------------
# --------------------- 0
# simulation duration :  31.7
# no solution computed yet
# weight =  1678.132344274986
# set cost params:  1.0 0.0 1678.132344274986
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12715.669908793514
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12715.669908793514
# Control only changes marginally.
# RUN  1 , total integrated cost =  12715.669908793514
# Improved over  1  iterations in  0.3516238590236753  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  4356.530122848282 [0.         4.98121606]
# 20 118 -----------------
# --------------------- 0
# simulation duration :  31.8
# no solution computed yet
# weight =  1695.4247328550023
# set cost params:  1.0 0.0 1695.4247328550023
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12784.307677993755
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12784.307677993753
# RUN  2 , total integrated cost =  12784.307677993753
# Control only changes marginally.
# RUN  2 , total integrated cost =  12784.307677993753
# Improved over  2  iterations in  0.4917108539957553  seconds by  1.4210854715202004e-14  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  4394.583945693399 [0.         4.94844954]
# --------------------- 1
# simulation duration :  31.8
# weight =  1698.96106365975
# set cost params:  1.0 0.0 1698.96106365975
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522982
# RUN  2 , total integrated cost =  12801.80703252298
# RUN  3 , total integrated cost =  12801.80703252298
# Control only changes marginally.
# RUN  3 , total integrated cost =  12801.80703252298
# Improved over  3  iterations in  0.32469034602399915  seconds by  2.842170943040401e-14  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  4394.583945693439 [0.         4.94844954]
# --------------------- 2
# simulation duration :  31.8
# weight =  1698.9610636597504
# set cost params:  1.0 0.0 1698.9610636597504
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.1496276940451935  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  4394.583945693439 [0.         4.94844954]
# 20 119 -----------------
# --------------------- 0
# simulation duration :  31.9
# no solution computed yet
# weight =  1698.9610636597504
# set cost params:  1.0 0.0 1698.9610636597504
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12717.651176345342
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12717.651176345338
# RUN  2 , total integrated cost =  12717.651176345338
# Control only changes marginally.
# RUN  2 , total integrated cost =  12717.651176345338
# Improved over  2  iterations in  0.4224400989478454  seconds by  2.842170943040401e-14  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  4328.539233105819 [0.         4.93778941]
# --------------------- 1
# simulation duration :  31.9
# weight =  1716.004288722445
# set cost params:  1.0 0.0 1716.004288722445
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.14901759393978864  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  4328.539233105819 [0.         4.93778941]
# 20 120 -----------------
# --------------------- 0
# simulation duration :  32.0
# no solution computed yet
# weight =  1716.004288722445
# set cost params:  1.0 0.0 1716.004288722445
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12793.435841689829
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12704.263578301661
# RUN  2 , total integrated cost =  12587.251620274623
# RUN  3 , total integrated cost =  12584.886371643262
# RUN  4 , total integrated cost =  12584.883942595163
# RUN  5 , total integrated cost =  12584.883933116147
# RUN  6 , total integrated cost =  12584.88393309907
# RUN  7 , total integrated cost =  12584.883933099009
# RUN  8 , total integrated cost =  12584.883933099
# RUN  9 , total integrated cost =  12584.883933098994
# RUN  10 , total integrated cost =  12584.88393309899
# RUN  11 , total integrated cost =  12584.883933098985
# RUN  12 , total integrated cost =  12584.883933098983
# RUN  13 , total integrated cost =  12584.883933098981
# RUN  14 , total integrated cost =  12584.883933098981
# Control only changes marginally.
# RUN  14 , total integrated cost =  12584.883933098981
# Improved over  14  iterations in  0.7930336560821161  seconds by  1.630147766178979  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  3907.7644759504255 [0.         5.05658378]
# --------------------- 1
# simulation duration :  32.0
# weight =  1758.9034294767982
# set cost params:  1.0 0.0 1758.9034294767982
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.751751815951
# RUN  2 , total integrated cost =  12801.751751815946
# RUN  3 , total integrated cost =  12801.751751815944
# RUN  4 , total integrated cost =  12801.751751815942
# RUN  5 , total integrated cost =  12801.751751815942
# Control only changes marginally.
# RUN  5 , total integrated cost =  12801.751751815942
# Improved over  5  iterations in  0.38224943808745593  seconds by  0.0004318195618822074  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  3914.072256850563 [0.         5.05296615]
# --------------------- 2
# simulation duration :  32.0
# weight =  1758.9143697256286
# set cost params:  1.0 0.0 1758.9143697256286
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.11765220097731799  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  3914.072256850563 [0.         5.05296615]
# 20 121 -----------------
# --------------------- 0
# simulation duration :  32.1
# no solution computed yet
# weight =  1758.9143697256286
# set cost params:  1.0 0.0 1758.9143697256286
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12712.566697723762
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12712.566697723754
# RUN  2 , total integrated cost =  12712.566697723754
# Control only changes marginally.
# RUN  2 , total integrated cost =  12712.566697723754
# Improved over  2  iterations in  0.33507525408640504  seconds by  5.684341886080802e-14  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  3842.404709664497 [0.         5.04297545]
# --------------------- 1
# simulation duration :  32.1
# weight =  1776.6103382376798
# set cost params:  1.0 0.0 1776.6103382376798
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.11915931105613708  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  3842.404709664497 [0.         5.04297545]
# 20 122 -----------------
# --------------------- 0
# simulation duration :  32.2
# no solution computed yet
# weight =  1776.6103382376798
# set cost params:  1.0 0.0 1776.6103382376798
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12764.821111198238
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12764.821111198238
# Control only changes marginally.
# RUN  1 , total integrated cost =  12764.821111198238
# Improved over  1  iterations in  0.2859295279486105  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  3876.2792659308334 [0.         5.00309024]
# 20 123 -----------------
# --------------------- 0
# simulation duration :  32.3
# no solution computed yet
# weight =  1784.0029535100905
# set cost params:  1.0 0.0 1784.0029535100905
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12713.206759810368
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12713.206759810364
# RUN  2 , total integrated cost =  12713.206759810364
# Control only changes marginally.
# RUN  2 , total integrated cost =  12713.206759810364
# Improved over  2  iterations in  0.43629263003822416  seconds by  2.842170943040401e-14  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  3805.2121286137776 [0.         4.99326227]
# --------------------- 1
# simulation duration :  32.3
# weight =  1801.7469188743669
# set cost params:  1.0 0.0 1801.7469188743669
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522982
# RUN  2 , total integrated cost =  12801.807032522982
# Control only changes marginally.
# RUN  2 , total integrated cost =  12801.807032522982
# Improved over  2  iterations in  0.21925073396414518  seconds by  1.4210854715202004e-14  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  3805.21212861378 [0.         4.99326227]
# --------------------- 2
# simulation duration :  32.3
# weight =  1801.746918874367
# set cost params:  1.0 0.0 1801.746918874367
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522986
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522982
# RUN  2 , total integrated cost =  12801.807032522982
# Control only changes marginally.
# RUN  2 , total integrated cost =  12801.807032522982
# Improved over  2  iterations in  0.22133231605403125  seconds by  2.842170943040401e-14  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  3805.2121286137835 [0.         4.99326227]
# --------------------- 3
# simulation duration :  32.3
# weight =  1801.7469188743673
# set cost params:  1.0 0.0 1801.7469188743673
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522986
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522986
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522986
# Improved over  1  iterations in  0.13917655090335757  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  3805.2121286137835 [0.         4.99326227]
# 20 124 -----------------
# --------------------- 0
# simulation duration :  32.4
# no solution computed yet
# weight =  1801.7469188743673
# set cost params:  1.0 0.0 1801.7469188743673
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12777.17373158257
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12777.173731582563
# RUN  2 , total integrated cost =  12777.173731582563
# Control only changes marginally.
# RUN  2 , total integrated cost =  12777.173731582563
# Improved over  2  iterations in  0.4508992519695312  seconds by  5.684341886080802e-14  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  3841.114472923631 [0.         4.95966396]
# --------------------- 1
# simulation duration :  32.4
# weight =  1806.7136466887673
# set cost params:  1.0 0.0 1806.7136466887673
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.13946569501422346  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  3841.114472923631 [0.         4.95966396]
# 20 125 -----------------
# --------------------- 0
# simulation duration :  32.5
# no solution computed yet
# weight =  1806.7136466887673
# set cost params:  1.0 0.0 1806.7136466887673
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12714.844019394488
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12714.844019394484
# RUN  2 , total integrated cost =  12714.844019394484
# Control only changes marginally.
# RUN  2 , total integrated cost =  12714.844019394484
# Improved over  2  iterations in  0.3286309069953859  seconds by  2.842170943040401e-14  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  3772.336538669392 [0.         4.94959868]
# --------------------- 1
# simulation duration :  32.5
# weight =  1824.2833566291933
# set cost params:  1.0 0.0 1824.2833566291933
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522982
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522982
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522982
# Improved over  1  iterations in  0.1417442780220881  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  3772.336538669392 [0.         4.94959868]
# 20 126 -----------------
# --------------------- 0
# simulation duration :  32.6
# no solution computed yet
# weight =  1824.2833566291933
# set cost params:  1.0 0.0 1824.2833566291933
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12786.792253340725
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12786.792253340722
# RUN  2 , total integrated cost =  12786.792253340722
# Control only changes marginally.
# RUN  2 , total integrated cost =  12786.792253340722
# Improved over  2  iterations in  0.4270311490399763  seconds by  2.842170943040401e-14  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  3810.7507223501816 [0.         4.92031104]
# --------------------- 1
# simulation duration :  32.6
# weight =  1827.3349480986726
# set cost params:  1.0 0.0 1827.3349480986726
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.15289530297741294  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  3810.7507223501816 [0.         4.92031104]
# 20 127 -----------------
# --------------------- 0
# simulation duration :  32.7
# no solution computed yet
# weight =  1827.3349480986726
# set cost params:  1.0 0.0 1827.3349480986726
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12716.912127375621
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12716.912127375617
# RUN  2 , total integrated cost =  12716.912127375615
# RUN  3 , total integrated cost =  12716.912127375614
# RUN  4 , total integrated cost =  12716.912127375614
# Control only changes marginally.
# RUN  4 , total integrated cost =  12716.912127375614
# Improved over  4  iterations in  0.4387085409834981  seconds by  5.684341886080802e-14  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  3744.5311348267155 [0.         4.91009106]
# --------------------- 1
# simulation duration :  32.7
# weight =  1844.6248321573344
# set cost params:  1.0 0.0 1844.6248321573344
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.13827295997180045  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  3744.5311348267155 [0.         4.91009106]
# 20 128 -----------------
# --------------------- 0
# simulation duration :  32.8
# no solution computed yet
# weight =  1844.6248321573344
# set cost params:  1.0 0.0 1844.6248321573344
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12795.337702089115
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12758.706267065278
# RUN  2 , total integrated cost =  12617.475896204802
# RUN  3 , total integrated cost =  12612.841821685095
# RUN  4 , total integrated cost =  12612.841821685091
# RUN  5 , total integrated cost =  12612.841821685086
# RUN  6 , total integrated cost =  12612.841821685086
# Control only changes marginally.
# RUN  6 , total integrated cost =  12612.841821685086
# Improved over  6  iterations in  0.5637836229288951  seconds by  1.4262685726085351  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  3409.2928925066262 [0.         4.98938796]
# --------------------- 1
# simulation duration :  32.8
# weight =  1882.4982571814946
# set cost params:  1.0 0.0 1882.4982571814946
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.769550882878
# RUN  2 , total integrated cost =  12801.769534327392
# RUN  3 , total integrated cost =  12801.769534327386
# RUN  4 , total integrated cost =  12801.769534327386
# Control only changes marginally.
# RUN  4 , total integrated cost =  12801.769534327386
# Improved over  4  iterations in  0.2736556710442528  seconds by  0.0002929133012372631  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  3414.561635970291 [0.         4.98656924]
# --------------------- 2
# simulation duration :  32.8
# weight =  1882.5057770200476
# set cost params:  1.0 0.0 1882.5057770200476
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522982
# RUN  2 , total integrated cost =  12801.807032522982
# Control only changes marginally.
# RUN  2 , total integrated cost =  12801.807032522982
# Improved over  2  iterations in  0.23276618402451277  seconds by  1.4210854715202004e-14  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  3414.5616359702944 [0.         4.98656924]
# --------------------- 3
# simulation duration :  32.8
# weight =  1882.5057770200478
# set cost params:  1.0 0.0 1882.5057770200478
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.12593996000941843  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  3414.5616359702944 [0.         4.98656924]
# 20 129 -----------------
# --------------------- 0
# simulation duration :  32.9
# no solution computed yet
# weight =  1882.5057770200478
# set cost params:  1.0 0.0 1882.5057770200478
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12709.881419202764
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12709.881419202764
# Control only changes marginally.
# RUN  1 , total integrated cost =  12709.881419202764
# Improved over  1  iterations in  0.27867639996111393  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  3339.9138858091005 [0.         4.97739112]
# 20 130 -----------------
# --------------------- 0
# simulation duration :  33.0
# no solution computed yet
# weight =  1900.9744107175168
# set cost params:  1.0 0.0 1900.9744107175168
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12769.83041932759
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12769.830419327587
# RUN  2 , total integrated cost =  12769.830419327587
# Control only changes marginally.
# RUN  2 , total integrated cost =  12769.830419327587
# Improved over  2  iterations in  0.34135501692071557  seconds by  2.842170943040401e-14  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  3371.2555060576187 [0.         4.94408281]
# --------------------- 1
# simulation duration :  33.0
# weight =  1907.4420639507784
# set cost params:  1.0 0.0 1907.4420639507784
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522986
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522986
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522986
# Improved over  1  iterations in  0.14193414500914514  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  3371.2555060576187 [0.         4.94408281]
# 20 131 -----------------
# --------------------- 0
# simulation duration :  33.1
# no solution computed yet
# weight =  1907.4420639507784
# set cost params:  1.0 0.0 1907.4420639507784
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12711.12392527958
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12711.123925279579
# RUN  2 , total integrated cost =  12711.123925279579
# Control only changes marginally.
# RUN  2 , total integrated cost =  12711.123925279579
# Improved over  2  iterations in  0.5303599870530888  seconds by  1.4210854715202004e-14  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  3298.664541398537 [0.         4.93459779]
# --------------------- 1
# simulation duration :  33.1
# weight =  1925.8190647102238
# set cost params:  1.0 0.0 1925.8190647102238
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.13497551705222577  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  3298.664541398537 [0.         4.93459779]
# 20 132 -----------------
# --------------------- 0
# simulation duration :  33.2
# no solution computed yet
# weight =  1925.8190647102238
# set cost params:  1.0 0.0 1925.8190647102238
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12780.135594458387
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12780.13559445838
# RUN  2 , total integrated cost =  12780.13559445838
# Control only changes marginally.
# RUN  2 , total integrated cost =  12780.13559445838
# ...
# set cost params:  1.0 0.0 3596.774387206047
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12808.21356999762
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12808.213569997615
# RUN  2 , total integrated cost =  12808.213569997615
# Control only changes marginally.
# RUN  2 , total integrated cost =  12808.213569997615
# Improved over  2  iterations in  0.5451968440320343  seconds by  4.263256414560601e-14  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  226.22456743115885 [0.         3.49813128]
# --------------------- 1
# simulation duration :  78.5
# weight =  3594.942970099043
# set cost params:  1.0 0.0 3594.942970099043
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.22115699003916234  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  226.22456743115885 [0.         3.49813128]
# 20 586 -----------------
# --------------------- 0
# simulation duration :  78.6
# no solution computed yet
# weight =  3594.942970099043
# set cost params:  1.0 0.0 3594.942970099043
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12819.31324737129
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12819.31324737129
# Control only changes marginally.
# RUN  1 , total integrated cost =  12819.31324737129
# Improved over  1  iterations in  0.2520365889649838  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  252.83249445670026 [0.         3.49559947]
# 20 587 -----------------
# --------------------- 0
# simulation duration :  78.7
# no solution computed yet
# weight =  3589.934897812188
# set cost params:  1.0 0.0 3589.934897812188
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12812.667268135743
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12812.66726813574
# RUN  2 , total integrated cost =  12812.66726813574
# Control only changes marginally.
# RUN  2 , total integrated cost =  12812.66726813574
# Improved over  2  iterations in  0.45226013904903084  seconds by  2.842170943040401e-14  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  272.75771504276037 [0.         3.49307436]
# --------------------- 1
# simulation duration :  78.7
# weight =  3586.825821254688
# set cost params:  1.0 0.0 3586.825821254688
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.17522885906510055  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  272.75771504276037 [0.         3.49307436]
# 20 588 -----------------
# --------------------- 0
# simulation duration :  78.8
# no solution computed yet
# weight =  3586.825821254688
# set cost params:  1.0 0.0 3586.825821254688
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12826.111614897422
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12826.111614897422
# Control only changes marginally.
# RUN  1 , total integrated cost =  12826.111614897422
# Improved over  1  iterations in  0.31183332996442914  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  306.1011768346018 [0.         3.49055434]
# 20 589 -----------------
# --------------------- 0
# simulation duration :  78.9
# no solution computed yet
# weight =  3579.862863510626
# set cost params:  1.0 0.0 3579.862863510626
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12818.433666209032
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12678.114391881578
# RUN  2 , total integrated cost =  12677.554360512868
# RUN  3 , total integrated cost =  12677.553541790807
# RUN  4 , total integrated cost =  12677.553540658035
# RUN  5 , total integrated cost =  12677.553540658022
# RUN  6 , total integrated cost =  12677.553540658022
# Control only changes marginally.
# RUN  6 , total integrated cost =  12677.553540658022
# Improved over  6  iterations in  0.4108450959902257  seconds by  1.0990432155715553  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  92.08870157779165 [0.         3.51562764]
# --------------------- 1
# simulation duration :  78.9
# weight =  3615.206052409591
# set cost params:  1.0 0.0 3615.206052409591
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.80337708596
# RUN  2 , total integrated cost =  12801.803372459342
# RUN  3 , total integrated cost =  12801.803372459332
# RUN  4 , total integrated cost =  12801.803372459326
# RUN  5 , total integrated cost =  12801.803372459326
# Control only changes marginally.
# RUN  5 , total integrated cost =  12801.803372459326
# Improved over  5  iterations in  0.4124757740646601  seconds by  2.8590211115897546e-05  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  92.91513656826959 [0.         3.51539803]
# --------------------- 2
# simulation duration :  78.9
# weight =  3615.2070935615816
# set cost params:  1.0 0.0 3615.2070935615816
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.17041404894553125  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  92.91513656826959 [0.         3.51539803]
# 20 590 -----------------
# --------------------- 0
# simulation duration :  79.0
# no solution computed yet
# weight =  3615.2070935615816
# set cost params:  1.0 0.0 3615.2070935615816
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12802.513814864615
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12802.513814864611
# RUN  2 , total integrated cost =  12802.513814864611
# Control only changes marginally.
# RUN  2 , total integrated cost =  12802.513814864611
# Improved over  2  iterations in  0.4117509030038491  seconds by  2.842170943040401e-14  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  102.79408632507726 [0.         3.51286092]
# --------------------- 1
# simulation duration :  79.0
# weight =  3615.0058950635303
# set cost params:  1.0 0.0 3615.0058950635303
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.15360398800112307  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  102.79408632507726 [0.         3.51286092]
# 20 591 -----------------
# --------------------- 0
# simulation duration :  79.1
# no solution computed yet
# weight =  3615.0058950635303
# set cost params:  1.0 0.0 3615.0058950635303
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12799.268188907567
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12799.268188907567
# Control only changes marginally.
# RUN  1 , total integrated cost =  12799.268188907567
# Improved over  1  iterations in  0.2588560660369694  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  109.38299189134193 [0.         3.51033596]
# 20 592 -----------------
# --------------------- 0
# simulation duration :  79.2
# no solution computed yet
# weight =  3615.729143106668
# set cost params:  1.0 0.0 3615.729143106668
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12804.70419747132
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12804.70419747132
# Control only changes marginally.
# RUN  1 , total integrated cost =  12804.70419747132
# Improved over  1  iterations in  0.30074157495982945  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  121.40212720110053 [0.        3.5078131]
# 20 593 -----------------
# --------------------- 0
# simulation duration :  79.3
# no solution computed yet
# weight =  3614.903225401795
# set cost params:  1.0 0.0 3614.903225401795
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12800.963668489167
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12800.963668489167
# Control only changes marginally.
# RUN  1 , total integrated cost =  12800.963668489167
# Improved over  1  iterations in  0.21812249801587313  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  129.64977130619357 [0.         3.50529824]
# 20 594 -----------------
# --------------------- 0
# simulation duration :  79.4
# no solution computed yet
# weight =  3615.1438223431046
# set cost params:  1.0 0.0 3615.1438223431046
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12807.500710998569
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12807.500710998569
# Control only changes marginally.
# RUN  1 , total integrated cost =  12807.500710998569
# Improved over  1  iterations in  0.28570393193513155  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  144.4196723105963 [0.         3.50278762]
# 20 595 -----------------
# --------------------- 0
# simulation duration :  79.5
# no solution computed yet
# weight =  3613.518351693068
# set cost params:  1.0 0.0 3613.518351693068
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12803.270598912071
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12803.270598912068
# RUN  2 , total integrated cost =  12803.270598912068
# Control only changes marginally.
# RUN  2 , total integrated cost =  12803.270598912068
# Improved over  2  iterations in  0.31306967802811414  seconds by  2.842170943040401e-14  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  154.93439046902697 [0.         3.50028282]
# --------------------- 1
# simulation duration :  79.5
# weight =  3613.1002236548247
# set cost params:  1.0 0.0 3613.1002236548247
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.1904707410139963  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  154.93439046902697 [0.         3.50028282]
# 20 596 -----------------
# --------------------- 0
# simulation duration :  79.6
# no solution computed yet
# weight =  3613.1002236548247
# set cost params:  1.0 0.0 3613.1002236548247
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12811.110300589164
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12811.110300589164
# Control only changes marginally.
# RUN  1 , total integrated cost =  12811.110300589164
# Improved over  1  iterations in  0.31485068204347044  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  173.26960954110564 [0.         3.49778304]
# 20 597 -----------------
# --------------------- 0
# simulation duration :  79.7
# no solution computed yet
# weight =  3610.440462327524
# set cost params:  1.0 0.0 3610.440462327524
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12806.268350229051
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12806.268350229051
# Control only changes marginally.
# RUN  1 , total integrated cost =  12806.268350229051
# Improved over  1  iterations in  0.20003571303095669  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  186.73842099245877 [0.        3.4952882]
# 20 598 -----------------
# --------------------- 0
# simulation duration :  79.8
# no solution computed yet
# weight =  3609.1640818243195
# set cost params:  1.0 0.0 3609.1640818243195
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12815.806505778526
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12815.806505778524
# RUN  2 , total integrated cost =  12815.806505778524
# Control only changes marginally.
# RUN  2 , total integrated cost =  12815.806505778524
# Improved over  2  iterations in  0.2207828030223027  seconds by  1.4210854715202004e-14  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  209.72487922934985 [0.         3.49279815]
# --------------------- 1
# simulation duration :  79.8
# weight =  3605.1559849758946
# set cost params:  1.0 0.0 3605.1559849758946
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.09020021394826472  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  209.72487922934985 [0.         3.49279815]
# 20 599 -----------------
# --------------------- 0
# simulation duration :  79.9
# no solution computed yet
# weight =  3605.1559849758946
# set cost params:  1.0 0.0 3605.1559849758946
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12810.33299393495
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12810.332993934946
# RUN  2 , total integrated cost =  12810.332993934946
# Control only changes marginally.
# RUN  2 , total integrated cost =  12810.332993934946
# Improved over  2  iterations in  0.2315157559933141  seconds by  2.842170943040401e-14  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  227.2098135555797 [0.         3.49031311]
# --------------------- 1
# simulation duration :  79.9
# weight =  3602.7132352410804
# set cost params:  1.0 0.0 3602.7132352410804
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.08645747089758515  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  227.2098135555797 [0.         3.49031311]
# 20 600 -----------------
# --------------------- 0
# simulation duration :  80.0
# no solution computed yet
# weight =  3602.7132352410804
# set cost params:  1.0 0.0 3602.7132352410804
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12821.926841398017
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12821.926841398015
# RUN  2 , total integrated cost =  12821.926841398015
# Control only changes marginally.
# RUN  2 , total integrated cost =  12821.926841398015
# Improved over  2  iterations in  0.28310682193841785  seconds by  1.4210854715202004e-14  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  256.2686510282227 [0.         3.48783191]
# --------------------- 1
# simulation duration :  80.0
# weight =  3596.944663422045
# set cost params:  1.0 0.0 3596.944663422045
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.17374462890438735  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  256.2686510282227 [0.         3.48783191]

# %%
i = 20
for j in [0,60,600]:
    print("simulation duration = ", round(d_array[j],1))
    aln.params.duration = round(d_array[j],1)
    time_ = np.arange(-dur_pre,round(d_array[j]+dur_post+aln.params.dt,1),aln.params.dt)
    dur += dur_pre + dur_post
    target_e = [target[i][0]] * len(time_)
    target_i = [target[i][1]] * len(time_)

    fig, ax = plt.subplots(2,1, constrained_layout=True, figsize = (4,4) )
    ax[1].plot(time_, bestControl_[i][j][0,0,:], color = 'red')
    ax[0].plot(time_, bestState_[i][j][0,0,:], color= 'red')
    ax[1].plot(time_, bestControl_[i][j][0,1,:], color = 'blue')
    ax[0].plot(time_, bestState_[i][j][0,1,:], color= 'blue')
    ax[0].plot(time_, target_e, linestyle = '--', color='red')
    ax[0].plot(time_, target_i, linestyle = '--', color='blue')
    ax[0].set_xlim(-dur_pre,round(d_array[j]+dur_pre,1))
    ax[1].set_xlim(-dur_pre,round(d_array[j]+dur_pre,1))
    ax[0].axvspan(t0_array[j], t0_array[j]+20, alpha=0.2, color='gray')
    plt.show()
# Out:
# simulation duration =  20.0
# simulation duration =  26.0
# simulation duration =  80.0
