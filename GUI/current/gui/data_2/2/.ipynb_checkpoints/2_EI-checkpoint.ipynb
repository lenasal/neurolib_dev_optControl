# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import sys
import pickle
import random

path = os.getcwd().split(os.sep + 'GUI')[0]
if path not in sys.path:
    print("not here")
    sys.path.append(path)

from neurolib.models.aln import ALNModel
from neurolib.utils import plotFunctions as plotFunc
from neurolib.utils import costFunctions as cost
import neurolib.dashboard.functions as functions
import neurolib.dashboard.data as data
    
# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2 

#path = os.path.join(os.getcwd(), "plots")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
grid_data_file = os.path.join(os.getcwd().split('data')[0], 'bi.pickle')
print(grid_data_file)
with open(grid_data_file,'rb') as f:
    load_array= pickle.load(f)
exc = load_array[0]
inh = load_array[1]
print(len(exc))
# Out:
# /home/lena/Promotion/neurolib/GUI/current/gui/bi.pickle
# 147

# %%
aln = ALNModel()
N = aln.params.N

data.set_parameters(aln)

state_vars = aln.state_vars
init_vars = aln.init_vars

##############################################################
def setinit(init_vars_, model):
    state_vars = model.state_vars
    init_vars = model.init_vars
    for iv in range(len(init_vars)):
        for sv in range(len(state_vars)):
            if state_vars[sv] in init_vars[iv]:
                #print("set init vars ", )
                if model.params[init_vars[iv]].ndim == 2:
                    model.params[init_vars[iv]][0,:] = init_vars_[sv]
                else:
                    model.params[init_vars[iv]][0] = init_vars_[sv]
                    
##############################################################               
def setmaxmincontrol(max_c_c, min_c_c, max_c_r, min_c_r):
    import numpy as np
    
    max_cntrl = np.zeros(( 6 ))
    min_cntrl = np.zeros(( 6 ))
    
    max_cntrl[0] = max_c_c
    min_cntrl[0] = min_c_c
    max_cntrl[1] = max_c_c
    min_cntrl[1] = min_c_c
    max_cntrl[2] = max_c_r
    min_cntrl[2] = min_c_r
    max_cntrl[3] = max_c_r
    min_cntrl[3] = min_c_r
    max_cntrl[4] = max_c_r
    min_cntrl[4] = min_c_r
    max_cntrl[5] = max_c_r
    min_cntrl[5] = min_c_r
            
    return max_cntrl, min_cntrl

# %%
dur = 500.
t_pen = 0.96

# %%
file_ = '2_EI.pickle'
c_var = [0,1]
folder = str(os.getcwd().split('data_2')[1])
print(folder)
case = str(folder[1])
# Out:
# /2

# %%
dur_pre = 10
dur_post = 10

n_pre = int(np.around(dur_pre/aln.params.dt + 1.,1))
n_post = int(np.around(dur_post/aln.params.dt + 1.,1))

tol = 1e-10
start_step = 10.
c_scheme = np.zeros(( 1,1 ))
c_scheme[0,0] = 1.
u_mat = np.identity(1)
u_scheme = np.array([[1.]])

p_var = [0]

wp = 1. / (dur - t_pen * dur)

if case in ['1', '2']:    # low to high
    max_I = [3., -3.]
else:
    max_I = [-3., 3.]
    
if case in ['1', '3']:    # sparsity
    factor_ws = 1.
    factor_we = 0.
else:
    factor_ws = 0.
    factor_we = 1.
    
ind_cost = 2
if case in ['2', '4']:
    ind_cost = 1
    
maxC = [5., -5., 0.18, 0.]
max_cntrl, min_cntrl = setmaxmincontrol(maxC[0], maxC[1], maxC[2], maxC[3])

# %%
bestControl_ = [None] * len(exc) 
bestState_ = [None] * len(exc) 
cost_ = [None] * len(exc) 
costnode_ = [None] * len(exc) 
weights_ = [None] * len(exc) 

if os.path.isfile(file_) :
    print("file found")
    
    with open(file_,'rb') as f:
        load_array = pickle.load(f)

    bestControl_ = load_array[0]
    bestState_ = load_array[1]
    cost_ = load_array[2]
    costnode_ = load_array[3]
    weights_ = load_array[4]

# %%
initVars = [None] * len(exc)
target = [None] * len(exc)
cost_uncontrolled = [None] * len(exc)

# %%
# get initial parameters and target states

i_range = range(0,83,1)
i_range = [20,50]

data.set_parameters(aln)

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    aln.params.duration = 3000.
    
    control0 = aln.getZeroControl()
    control0 = functions.step_control(aln, maxI_ = max_I[0])

    aln.run(control=control0)
    
    target_rates = np.zeros((2))
    target_rates[0] = aln.rates_exc[0,-1] 
    target_rates[1] = aln.rates_inh[0,-1]

    control0 = functions.step_control(aln, maxI_ = max_I[1])
    aln.run(control=control0)

    init_state_vars = np.zeros(( len(state_vars) ))
    for j in range(len(state_vars)):
        if aln.state[state_vars[j]].size == 1:
            init_state_vars[j] = aln.state[state_vars[j]][0]
        else:
            init_state_vars[j] = aln.state[state_vars[j]][0,-1]

    initVars[i] = init_state_vars
    target[i] = [target_rates[0], target_rates[1]]
# Out:
# -------  20 0.4500000000000001 0.4750000000000002
# -------  50 0.47500000000000014 0.6000000000000003

# %%
# get uncontrolled cost
data.set_parameters(aln)

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    aln.params.duration = dur
    
    target_ = aln.getZeroTarget()
    target_[:,0,:] = target[i][0]
    target_[:,1,:] = target[i][1]
            
    cost.setParams(wp, 0.0, 0.0)

    setinit(initVars[i], aln)
    control0 = aln.getZeroControl()

    cgv = None
    max_it = 0

    bestControl_init_, bestState_init_, cost_init_, runtime_init_, grad_init_, phi_init_, phi1_, costnode_init_ = aln.A1(
        control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
        prec_variables_ = p_var, transition_time_ = t_pen)
    
    cost_uncontrolled[i] = cost_init_[0]
# Out:
# -------  20 0.4500000000000001 0.4750000000000002
# set cost params:  0.05 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  636.9058225135838
# RUN  0 , total integrated cost =  636.9058225135838
# Gradient descend method:  None
# RUN  0 , total integrated cost =  636.9058225135838
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  50 0.47500000000000014 0.6000000000000003
# set cost params:  0.05 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  797.1477718037709
# RUN  0 , total integrated cost =  797.1477718037709
# Gradient descend method:  None
# RUN  0 , total integrated cost =  797.1477718037709
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.

# %%
cgv = None
j = 0

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    aln.params.duration = dur
    setinit(initVars[i], aln)

    target_ = aln.getZeroTarget()
    target_[:,0,:] = target[i][0]
    target_[:,1,:] = target[i][1]

    control0 = aln.getZeroControl()
    cost.setParams(wp, 0., 10.)
    max_it = int(10)

    control0[0,0,2200:2800] = 2.
    control0[0,1,2200:2800] = -2.

    bestControl_[i], bestState_[i], cost_[i], runtime_, grad_, phi_, phi1_, costnode_[i] = aln.A1(
        control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
        prec_variables_ = p_var, transition_time_ = t_pen)

    if True:
        plot_time_array = np.arange(0.,round(dur+aln.params.dt,1),aln.params.dt)
        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        fig, ax = plt.subplots(3,1, constrained_layout=True, figsize = (4,8) )
        ax[1].plot(plot_time_array, bestControl_[i][0,0,n_pre-1:-n_post+1], color = 'red')
        ax[0].plot(plot_time_array, bestState_[i][0,0,n_pre-1:-n_post+1], color= 'red')
        ax[1].plot(plot_time_array, bestControl_[i][0,1,n_pre-1:-n_post+1], color = 'blue')
        ax[0].plot(plot_time_array, bestState_[i][0,1,n_pre-1:-n_post+1], color= 'blue')
        ax[0].plot(plot_time_array, target_[0,0,n_pre-1:-n_post+1], linestyle = '--', color='red')
        ax[0].plot(plot_time_array, target_[0,1,n_pre-1:-n_post+1], linestyle = '--', color='blue')


        ax[2].plot(plot_time_array, phi_[0,0,:], color = 'red')
        ax[2].plot(plot_time_array, phi_[0,1,:], color = 'blue')
        for k in range(3):
            ax[k].set_xlim(0.,dur)
            ax[k].axvspan(dur*t_pen, dur, alpha=0.2, color='gray')
        plt.show()

    print('uncontrolled cost : ', cost_uncontrolled[i])
    print('cost splitting : ', costnode_[i][0][0][0], costnode_[i][ind_cost][0][:2])
# Out:
# -------  20 0.4500000000000001 0.4750000000000002
# set cost params:  0.05 0.0 10.0
# interpolate adjoint :  True True True
# initial cost =  309.8386676965948
# RUN  0 , total integrated cost =  309.8386676965948
# Gradient descend method:  None
# RUN  1 , total integrated cost =  47.33866769659453
# RUN  2 , total integrated cost =  45.48319894659454
# RUN  3 , total integrated cost =  45.4465778528445
# RUN  4 , total integrated cost =  45.44576722967928
# RUN  5 , total integrated cost =  45.445750151043185
# RUN  6 , total integrated cost =  45.44574987849145
# RUN  7 , total integrated cost =  45.445749483177316
# RUN  8 , total integrated cost =  45.44574922938298
# RUN  9 , total integrated cost =  45.445748721338305
# RUN  10 , total integrated cost =  45.4457484379082
# RUN  10 , total integrated cost =  45.4457484379082
# Improved over  10  iterations in  2.2797659959760495  seconds by  85.33244776200422  percent.
# uncontrolled cost :  636.9058225135838
# cost splitting :  5.088895264943734e-06 [2.36327128 2.18130354]
# -------  50 0.47500000000000014 0.6000000000000003
# set cost params:  0.05 0.0 10.0
# interpolate adjoint :  True True True
# initial cost =  309.8386676965948
# RUN  0 , total integrated cost =  309.8386676965948
# Gradient descend method:  None
# RUN  1 , total integrated cost =  84.83866769659465
# RUN  2 , total integrated cost =  76.24491769659461
# RUN  3 , total integrated cost =  76.19303781378193
# RUN  4 , total integrated cost =  76.19122583258087
# RUN  5 , total integrated cost =  76.19115430703647
# RUN  6 , total integrated cost =  76.19115128390419
# RUN  7 , total integrated cost =  75.5974860761004
# RUN  8 , total integrated cost =  73.74201732609342
# RUN  9 , total integrated cost =  73.65046459171808
# RUN  10 , total integrated cost =  73.64664989445241
# RUN  10 , total integrated cost =  73.64664989445241
# Improved over  10  iterations in  2.779334876977373  seconds by  76.23064595456825  percent.
# uncontrolled cost :  797.1477718037709
# cost splitting :  5.473113149778203e-10 [4.24193338 3.1227316 ]

# %%
c_var = [0,1]
conv = [None] * len(exc)

tol = 1e-6

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    k = 0
    
    while not conv[i]:
        max_it = int(30)

        weight_ = random.random() * ( cost_uncontrolled[i] -
                                     costnode_[i][0][0][0] ) / sum( costnode_[i][ind_cost][0][:] )
            
        aln.params.duration = dur
        cost.setParams(wp, weight_ * factor_we, weight_ * factor_ws)
        weights_[i] = cost.getParams()

        setinit(initVars[i], aln)

        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        control0 = aln.getZeroControl()
        control0 = bestControl_[i][:,:,n_pre-1:-n_post+1]

        bestControl_[i], bestState_[i], cost_[i], runtime_, grad_, phi_, phi1_, costnode_[i] = aln.A1(
            control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
            prec_variables_ = p_var, transition_time_ = t_pen)
        
        if cost_[i][2] == 0.:
            conv[i] = True

        #print('uncontrolled cost : ', cost_uncontrolled[i])
        print('cost splitting : ', costnode_[i][0][0][0], costnode_[i][ind_cost][0][:2])

        if conv[i]:
            time_ = np.arange(-dur_pre,round(dur+dur_post+aln.params.dt,1),aln.params.dt)
            target_ = aln.getZeroTarget()
            target_[:,0,:] = target[i][0]
            target_[:,1,:] = target[i][1]
        
            fig, ax = plt.subplots(2,1, constrained_layout=True, figsize = (4,4) )
            ax[1].plot(time_, bestControl_[i][0,0,:], color = 'red')
            ax[0].plot(time_, bestState_[i][0,0,:], color= 'red')
            ax[1].plot(time_, bestControl_[i][0,1,:], color = 'blue')
            ax[0].plot(time_, bestState_[i][0,1,:], color= 'blue')
            ax[0].plot(time_, target_[0,0,:], linestyle = '--', color='red')
            ax[0].plot(time_, target_[0,1,:], linestyle = '--', color='blue')
            ax[0].set_xlim(-dur_pre,dur+dur_post)
            ax[1].set_xlim(-dur_pre,dur+dur_post)
            ax[0].axvspan(dur*t_pen, dur, alpha=0.2, color='gray')
            plt.show()

        with open(file_,'wb') as f:
            pickle.dump([bestControl_, bestState_, cost_, costnode_, weights_], f)
        
        k += 1
# Out:
# -------  20 0.4500000000000001 0.4750000000000002
# set cost params:  0.05 55.35092400854575 0.0
# interpolate adjoint :  True True True
# initial cost =  286.2510750340051
# RUN  0 , total integrated cost =  286.2510750340051
# Gradient descend method:  None
# RUN  1 , total integrated cost =  286.2510750340051
# Control only changes marginally.
# RUN  1 , total integrated cost =  286.2510750340051
# Improved over  1  iterations in  0.2961183069855906  seconds by  0.0  percent.
# cost splitting :  5.088895264943734e-06 [2.79252556 2.37904257]
# -------  50 0.47500000000000014 0.6000000000000003
# set cost params:  0.05 51.688351832029355 0.0
# interpolate adjoint :  True True True
# initial cost =  717.0583298431004
# RUN  0 , total integrated cost =  717.0583298431004
# Gradient descend method:  None
# RUN  1 , total integrated cost =  717.0583298431004
# Control only changes marginally.
# RUN  1 , total integrated cost =  717.0583298431004
# Improved over  1  iterations in  0.363287471991498  seconds by  0.0  percent.
# cost splitting :  5.473113149778203e-10 [8.99699942 4.87572634]

# %%
c_var = [0,1]
conv = [None] * len(exc)

tol = 1e-8

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    k = 0
    
    while not conv[i]:
        max_it = int(30)

        weight_ = random.random() * ( cost_uncontrolled[i] -
                                     costnode_[i][0][0][0] ) / sum( costnode_[i][ind_cost][0][:] )
            
        aln.params.duration = dur
        cost.setParams(wp, weight_ * factor_we, weight_ * factor_ws)
        weights_[i] = cost.getParams()

        setinit(initVars[i], aln)

        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        control0 = aln.getZeroControl()
        control0 = bestControl_[i][:,:,n_pre-1:-n_post+1]

        bestControl_[i], bestState_[i], cost_[i], runtime_, grad_, phi_, phi1_, costnode_[i] = aln.A1(
            control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
            prec_variables_ = p_var, transition_time_ = t_pen)
        
        if cost_[i][2] == 0.:
            conv[i] = True

        #print('uncontrolled cost : ', cost_uncontrolled[i])
        print('cost splitting : ', costnode_[i][0][0][0], costnode_[i][ind_cost][0][:2])

        if conv[i]:
            time_ = np.arange(-dur_pre,round(dur+dur_post+aln.params.dt,1),aln.params.dt)
            target_ = aln.getZeroTarget()
            target_[:,0,:] = target[i][0]
            target_[:,1,:] = target[i][1]
        
            fig, ax = plt.subplots(2,1, constrained_layout=True, figsize = (4,4) )
            ax[1].plot(time_, bestControl_[i][0,0,:], color = 'red')
            ax[0].plot(time_, bestState_[i][0,0,:], color= 'red')
            ax[1].plot(time_, bestControl_[i][0,1,:], color = 'blue')
            ax[0].plot(time_, bestState_[i][0,1,:], color= 'blue')
            ax[0].plot(time_, target_[0,0,:], linestyle = '--', color='red')
            ax[0].plot(time_, target_[0,1,:], linestyle = '--', color='blue')
            ax[0].set_xlim(-dur_pre,dur+dur_post)
            ax[1].set_xlim(-dur_pre,dur+dur_post)
            ax[0].axvspan(dur*t_pen, dur, alpha=0.2, color='gray')
            plt.show()

        with open(file_,'wb') as f:
            pickle.dump([bestControl_, bestState_, cost_, costnode_, weights_], f)
        
        k += 1
# Out:
# -------  20 0.4500000000000001 0.4750000000000002
# set cost params:  0.05 86.11955705077528 0.0
# interpolate adjoint :  True True True
# initial cost =  445.37315719610353
# RUN  0 , total integrated cost =  445.37315719610353
# Gradient descend method:  None
# RUN  1 , total integrated cost =  445.37315719610353
# Control only changes marginally.
# RUN  1 , total integrated cost =  445.37315719610353
# Improved over  1  iterations in  0.3619047029642388  seconds by  0.0  percent.
# cost splitting :  5.088895264943734e-06 [2.79252556 2.37904257]
# -------  50 0.47500000000000014 0.6000000000000003
# set cost params:  0.05 34.78074485587516 0.0
# interpolate adjoint :  True True True
# initial cost =  482.50373504072775
# RUN  0 , total integrated cost =  482.50373504072775
# Gradient descend method:  None
# RUN  1 , total integrated cost =  482.50268036888957
# RUN  2 , total integrated cost =  482.5026686874076
# RUN  3 , total integrated cost =  428.9001430610299
# RUN  4 , total integrated cost =  422.12924058878866
# RUN  5 , total integrated cost =  421.913299931078
# RUN  6 , total integrated cost =  421.907569764564
# RUN  7 , total integrated cost =  421.90746422163903
# RUN  8 , total integrated cost =  421.90746422163903
# Control only changes marginally.
# RUN  8 , total integrated cost =  421.90746422163903
# Improved over  8  iterations in  2.9572577069629915  seconds by  12.558715387762504  percent.
# cost splitting :  3.504627668618795e-05 [7.45584419 4.67464537]
# set cost params:  0.05 29.684446410642074 0.0
# interpolate adjoint :  True True True
# initial cost =  360.08686912154747
# RUN  0 , total integrated cost =  360.08686912154747
# Gradient descend method:  None
# RUN  1 , total integrated cost =  360.08686912154747
# Control only changes marginally.
# RUN  1 , total integrated cost =  360.08686912154747
# Improved over  1  iterations in  0.5738103709882125  seconds by  0.0  percent.
# cost splitting :  3.504627668618795e-05 [7.45584419 4.67464537]

# %%
c_var = [0,1]
conv = [None] * len(exc)

tol = 1e-10

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    k = 0
    
    while not conv[i]:
        max_it = int(80)

        weight_ = random.random() * ( cost_uncontrolled[i] -
                                     costnode_[i][0][0][0] ) / sum( costnode_[i][ind_cost][0][:] )
            
        aln.params.duration = dur
        cost.setParams(wp, weight_ * factor_we, weight_ * factor_ws)
        weights_[i] = cost.getParams()

        setinit(initVars[i], aln)

        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        control0 = aln.getZeroControl()
        control0 = bestControl_[i][:,:,n_pre-1:-n_post+1]

        bestControl_[i], bestState_[i], cost_[i], runtime_, grad_, phi_, phi1_, costnode_[i] = aln.A1(
            control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
            prec_variables_ = p_var, transition_time_ = t_pen)
        
        if cost_[i][2] == 0.:
            conv[i] = True

        #print('uncontrolled cost : ', cost_uncontrolled[i])
        print('cost splitting : ', costnode_[i][0][0][0], costnode_[i][ind_cost][0][:2])

        if conv[i] and False:
            time_ = np.arange(-dur_pre,round(dur+dur_post+aln.params.dt,1),aln.params.dt)
            target_ = aln.getZeroTarget()
            target_[:,0,:] = target[i][0]
            target_[:,1,:] = target[i][1]
        
            fig, ax = plt.subplots(2,1, constrained_layout=True, figsize = (4,4) )
            ax[1].plot(time_, bestControl_[i][0,0,:], color = 'red')
            ax[0].plot(time_, bestState_[i][0,0,:], color= 'red')
            ax[1].plot(time_, bestControl_[i][0,1,:], color = 'blue')
            ax[0].plot(time_, bestState_[i][0,1,:], color= 'blue')
            ax[0].plot(time_, target_[0,0,:], linestyle = '--', color='red')
            ax[0].plot(time_, target_[0,1,:], linestyle = '--', color='blue')
            ax[0].set_xlim(-dur_pre,dur+dur_post)
            ax[1].set_xlim(-dur_pre,dur+dur_post)
            ax[0].axvspan(dur*t_pen, dur, alpha=0.2, color='gray')
            plt.show()

        with open(file_,'wb') as f:
            pickle.dump([bestControl_, bestState_, cost_, costnode_, weights_], f)
        
        k += 1
# Out:
# -------  20 0.4500000000000001 0.4750000000000002
# set cost params:  0.05 39.1517881535773 0.0
# interpolate adjoint :  True True True
# initial cost =  202.47614025118557
# RUN  0 , total integrated cost =  202.47614025118557
# Gradient descend method:  None
# RUN  1 , total integrated cost =  202.47613524066264
# RUN  2 , total integrated cost =  202.47613416960624
# RUN  3 , total integrated cost =  202.47613231905967
# RUN  4 , total integrated cost =  202.47613124721698
# RUN  5 , total integrated cost =  202.47612925782215
# RUN  6 , total integrated cost =  202.4761279926832
# RUN  7 , total integrated cost =  202.47612560140493
# RUN  8 , total integrated cost =  202.4761244917882
# RUN  9 , total integrated cost =  202.47612241727288
# RUN  10 , total integrated cost =  202.47612093344642
# RUN  11 , total integrated cost =  202.47611742922285
# RUN  12 , total integrated cost =  202.47611623312815
# RUN  13 , total integrated cost =  202.47611403151058
# RUN  14 , total integrated cost =  202.47611305966916
# RUN  15 , total integrated cost =  202.4761114403126
# RUN  16 , total integrated cost =  202.47611045552526
# RUN  17 , total integrated cost =  202.47610873074802
# RUN  18 , total integrated cost =  202.4761077190906
# RUN  19 , total integrated cost =  202.47610590674702
# RUN  20 , total integrated cost =  202.47610485540363
# RUN  30 , total integrated cost =  202.4760871307521
# RUN  40 , total integrated cost =  202.47607008378182
# RUN  50 , total integrated cost =  202.47605347385218
# RUN  60 , total integrated cost =  202.47603677254943
# RUN  70 , total integrated cost =  202.47602025435677
# RUN  80 , total integrated cost =  202.4760036462162
# RUN  80 , total integrated cost =  202.4760036462162
# Improved over  80  iterations in  17.160629332996905  seconds by  6.746719350303465e-05  percent.
# cost splitting :  1.4351698285084081e-05 [2.79252383 2.3790408 ]
# set cost params:  0.05 14.989779210084548 0.0
# interpolate adjoint :  True True True
# initial cost =  77.52061273497758
# RUN  0 , total integrated cost =  77.52061273497758
# Gradient descend method:  None
# RUN  1 , total integrated cost =  77.52061148702415
# RUN  2 , total integrated cost =  77.52061074535308
# RUN  3 , total integrated cost =  77.52060965122551
# RUN  4 , total integrated cost =  77.52060900476164
# RUN  5 , total integrated cost =  77.52060806951381
# RUN  6 , total integrated cost =  77.52060750838965
# RUN  7 , total integrated cost =  77.52060662055723
# RUN  8 , total integrated cost =  77.52060601749007
# RUN  9 , total integrated cost =  77.5206048875893
# RUN  10 , total integrated cost =  77.5206041562378
# RUN  11 , total integrated cost =  77.52060301998867
# RUN  12 , total integrated cost =  77.5206022944334
# RUN  13 , total integrated cost =  77.52060112647716
# RUN  14 , total integrated cost =  77.52060043008758
# RUN  15 , total integrated cost =  77.52059905081893
# RUN  16 , total integrated cost =  77.52059818926976
# RUN  17 , total integrated cost =  77.52059672758713
# RUN  18 , total integrated cost =  77.52059594431341
# RUN  19 , total integrated cost =  77.52059342740418
# RUN  20 , total integrated cost =  77.52059215230734
# RUN  30 , total integrated cost =  77.52057187020445
# RUN  40 , total integrated cost =  77.52053903517036
# RUN  50 , total integrated cost =  77.52052626030722
# RUN  60 , total integrated cost =  77.52051867134126
# RUN  70 , total integrated cost =  77.52051250841443
# RUN  80 , total integrated cost =  77.52050543280932
# RUN  80 , total integrated cost =  77.52050543280932
# Improved over  80  iterations in  18.28106873302022  seconds by  0.00013841759562183142  percent.
# cost splitting :  1.3116971789161038e-05 [2.79252383 2.37903365]
# set cost params:  0.05 40.28815296290793 0.0
# interpolate adjoint :  True True True
# initial cost =  208.3524994114597
# RUN  0 , total integrated cost =  208.3524994114597
# Gradient descend method:  None
# RUN  1 , total integrated cost =  208.35249706610733
# RUN  2 , total integrated cost =  208.35249468654217
# RUN  3 , total integrated cost =  208.35248123379458
# RUN  4 , total integrated cost =  200.70093492562376
# RUN  5 , total integrated cost =  175.405046816947
# RUN  6 , total integrated cost =  175.2163951071373
# RUN  7 , total integrated cost =  175.21008203882235
# RUN  8 , total integrated cost =  175.20984635617907
# RUN  9 , total integrated cost =  175.2098438853169
# RUN  10 , total integrated cost =  175.20960624850397
# RUN  11 , total integrated cost =  175.20954666785133
# RUN  12 , total integrated cost =  170.92328316557976
# RUN  13 , total integrated cost =  168.14900731851253
# RUN  14 , total integrated cost =  168.13036970513213
# RUN  15 , total integrated cost =  168.1302364795111
# RUN  16 , total integrated cost =  168.13023608001737
# RUN  17 , total integrated cost =  168.13023577823762
# RUN  18 , total integrated cost =  168.13023539110094
# RUN  19 , total integrated cost =  168.13023509871658
# RUN  20 , total integrated cost =  168.1302346962771
# RUN  30 , total integrated cost =  168.13023128390526
# RUN  40 , total integrated cost =  168.13022789292816
# RUN  50 , total integrated cost =  168.13022451318957
# RUN  60 , total integrated cost =  168.13022124885143
# RUN  70 , total integrated cost =  168.13021798329567
# RUN  80 , total integrated cost =  168.13021471927595
# RUN  80 , total integrated cost =  168.13021471927595
# Improved over  80  iterations in  18.770877787959762  seconds by  19.304920654084285  percent.
# cost splitting :  2.0227187451696734e-05 [2.18878562 1.98440678]
# set cost params:  0.05 16.745762179829317 0.0
# interpolate adjoint :  True True True
# initial cost =  69.88328845292403
# RUN  0 , total integrated cost =  69.88328845292403
# Gradient descend method:  None
# RUN  1 , total integrated cost =  69.88328798755026
# RUN  2 , total integrated cost =  69.88328716855744
# RUN  3 , total integrated cost =  69.88328665282737
# RUN  4 , total integrated cost =  69.88328629316159
# RUN  5 , total integrated cost =  69.88328601260548
# RUN  6 , total integrated cost =  69.88328558256892
# RUN  7 , total integrated cost =  69.88328527376817
# RUN  8 , total integrated cost =  69.88328499355026
# RUN  9 , total integrated cost =  69.88328478009046
# RUN  10 , total integrated cost =  69.88328435472773
# RUN  11 , total integrated cost =  69.88328404145447
# RUN  12 , total integrated cost =  69.8832837753439
# RUN  13 , total integrated cost =  69.88328359533817
# RUN  14 , total integrated cost =  69.8832832725518
# RUN  15 , total integrated cost =  69.88328305230316
# RUN  16 , total integrated cost =  69.88328267398495
# RUN  17 , total integrated cost =  69.88328241161841
# RUN  18 , total integrated cost =  69.88328178408068
# RUN  19 , total integrated cost =  69.88328137564699
# RUN  20 , total integrated cost =  69.88328110878965
# RUN  30 , total integrated cost =  69.88327808440826
# RUN  40 , total integrated cost =  61.88712347933019
# RUN  50 , total integrated cost =  61.88712328666134
# RUN  60 , total integrated cost =  61.88712312859716
# RUN  70 , total integrated cost =  61.88712297053292
# RUN  80 , total integrated cost =  61.887122812468746
# RUN  80 , total integrated cost =  61.887122812468746
# Improved over  80  iterations in  24.956459697976243  seconds by  11.44217139386879  percent.
# cost splitting :  5.106678196709359e-06 [2.06762337 1.62806524]
# set cost params:  0.05 140.0043525054573 0.0
# interpolate adjoint :  True True True
# initial cost =  517.4124911883541
# RUN  0 , total integrated cost =  517.4124911883541
# Gradient descend method:  None
# RUN  1 , total integrated cost =  517.4124878102953
# RUN  2 , total integrated cost =  508.6413083418711
# RUN  3 , total integrated cost =  503.73269279267976
# RUN  4 , total integrated cost =  503.55780942003395
# RUN  5 , total integrated cost =  503.5503611642787
# RUN  6 , total integrated cost =  503.5500506240882
# RUN  7 , total integrated cost =  503.5500448781688
# RUN  8 , total integrated cost =  503.55004438451556
# RUN  9 , total integrated cost =  503.5500434080723
# RUN  10 , total integrated cost =  503.5500432309547
# RUN  11 , total integrated cost =  503.5500429495297
# RUN  12 , total integrated cost =  503.5500428920853
# RUN  13 , total integrated cost =  503.5500427946345
# RUN  14 , total integrated cost =  503.55004271101177
# RUN  15 , total integrated cost =  503.55004253804884
# RUN  16 , total integrated cost =  503.55004240229385
# RUN  17 , total integrated cost =  503.5500385560191
# RUN  18 , total integrated cost =  503.5500361700305
# RUN  19 , total integrated cost =  503.5500356798958
# RUN  20 , total integrated cost =  503.55003472431093
# RUN  30 , total integrated cost =  503.5500339126715
# RUN  40 , total integrated cost =  503.55003295348575
# RUN  50 , total integrated cost =  503.5500277149632
# RUN  60 , total integrated cost =  503.5500251650581
# RUN  70 , total integrated cost =  503.5500204812617
# RUN  80 , total integrated cost =  503.5500176631905
# RUN  80 , total integrated cost =  503.5500176631905
# Improved over  80  iterations in  23.361911084037274  seconds by  2.6791918945221767  percent.
# cost splitting :  6.137688781797684e-05 [1.7000011 1.8966729]
# set cost params:  0.05 176.6797660891375 0.0
# interpolate adjoint :  True True True
# initial cost =  635.4595241522534
# RUN  0 , total integrated cost =  635.4595241522534
# Gradient descend method:  None
# RUN  1 , total integrated cost =  635.4595240672937
# RUN  2 , total integrated cost =  635.4595240039533
# RUN  3 , total integrated cost =  635.4595238992197
# RUN  4 , total integrated cost =  635.4595238118828
# RUN  5 , total integrated cost =  635.459523735457
# RUN  6 , total integrated cost =  635.4595236689294
# RUN  7 , total integrated cost =  635.4595235719164
# RUN  8 , total integrated cost =  635.4595234893621
# RUN  9 , total integrated cost =  635.459523415499
# RUN  10 , total integrated cost =  635.4595233463831
# RUN  11 , total integrated cost =  635.4595232546563
# RUN  12 , total integrated cost =  635.4595231668812
# RUN  13 , total integrated cost =  635.4595230909458
# RUN  14 , total integrated cost =  635.4595230239289
# RUN  15 , total integrated cost =  635.4595229279015
# RUN  16 , total integrated cost =  635.4595228444331
# RUN  17 , total integrated cost =  635.4595227719
# RUN  18 , total integrated cost =  635.4595227014584
# RUN  19 , total integrated cost =  635.4595226122908
# RUN  20 , total integrated cost =  635.4595225341849
# RUN  30 , total integrated cost =  635.4595215848753
# RUN  40 , total integrated cost =  635.4595191054764
# RUN  50 , total integrated cost =  635.4594996213341
# RUN  60 , total integrated cost =  635.4594839212706
# RUN  70 , total integrated cost =  635.4594831089862
# RUN  80 , total integrated cost =  635.4594823091759
# RUN  80 , total integrated cost =  635.4594823091759
# Improved over  80  iterations in  22.82397804799257  seconds by  6.584695938727236e-06  percent.
# cost splitting :  6.285820068446843e-05 [1.7000011  1.89667267]
# set cost params:  0.05 154.8211487846294 0.0
# interpolate adjoint :  True True True
# initial cost =  556.8411669520541
# RUN  0 , total integrated cost =  556.8411669520541
# Gradient descend method:  None
# RUN  1 , total integrated cost =  556.8411666940194
# RUN  2 , total integrated cost =  556.8411662784903
# RUN  3 , total integrated cost =  556.8411641181942
# RUN  4 , total integrated cost =  556.8411620413028
# RUN  5 , total integrated cost =  554.9107098763086
# RUN  6 , total integrated cost =  554.1728757394924
# RUN  7 , total integrated cost =  554.1413909361191
# RUN  8 , total integrated cost =  554.1395746433931
# RUN  9 , total integrated cost =  554.139473226611
# RUN  10 , total integrated cost =  554.1394730956113
# RUN  11 , total integrated cost =  554.1394728610982
# RUN  12 , total integrated cost =  554.1394258241414
# RUN  13 , total integrated cost =  554.1394088443908
# RUN  14 , total integrated cost =  554.1394087975658
# RUN  15 , total integrated cost =  554.1394087538381
# RUN  16 , total integrated cost =  554.1394087038373
# RUN  17 , total integrated cost =  554.139408657162
# RUN  18 , total integrated cost =  554.1394086101158
# RUN  19 , total integrated cost =  554.1394085666523
# RUN  20 , total integrated cost =  554.1394085163865
# RUN  30 , total integrated cost =  554.1394080365608
# RUN  40 , total integrated cost =  554.1394009284112
# RUN  50 , total integrated cost =  554.1394002002808
# RUN  60 , total integrated cost =  554.1393969315577
# RUN  70 , total integrated cost =  554.1393956321641
# RUN  80 , total integrated cost =  553.0573226998333
# RUN  80 , total integrated cost =  553.0573226998333
# Improved over  80  iterations in  25.541724841983523  seconds by  0.67951948900118  percent.
# cost splitting :  5.817900349066292e-05 [1.64922906 1.9230046 ]
# set cost params:  0.05 99.26837673105508 0.0
# interpolate adjoint :  True True True
# initial cost =  354.609840168596
# RUN  0 , total integrated cost =  354.609840168596
# Gradient descend method:  None
# RUN  1 , total integrated cost =  354.60983983414536
# RUN  2 , total integrated cost =  354.60983981545013
# RUN  3 , total integrated cost =  354.6098397986818
# RUN  4 , total integrated cost =  354.60983977921796
# RUN  5 , total integrated cost =  354.6098397624322
# RUN  6 , total integrated cost =  354.60983974296465
# RUN  7 , total integrated cost =  354.6098397261796
# RUN  8 , total integrated cost =  354.6098397067111
# RUN  9 , total integrated cost =  354.6098396899256
# RUN  10 , total integrated cost =  354.6098396704574
# RUN  11 , total integrated cost =  354.60983965367126
# RUN  12 , total integrated cost =  354.6098396342035
# RUN  13 , total integrated cost =  354.60983961741795
# RUN  14 , total integrated cost =  354.60983959794885
# RUN  15 , total integrated cost =  354.60983958116344
# RUN  16 , total integrated cost =  354.6098395616945
# RUN  17 , total integrated cost =  354.60983954490837
# RUN  18 , total integrated cost =  354.60983952544063
# RUN  19 , total integrated cost =  354.6098395086537
# RUN  20 , total integrated cost =  354.60983948918596
# RUN  30 , total integrated cost =  354.60983930791565
# RUN  40 , total integrated cost =  354.6098391266454
# RUN  50 , total integrated cost =  354.6098389453746
# RUN  60 , total integrated cost =  354.6098387641024
# RUN  70 , total integrated cost =  354.6098385828344
# RUN  80 , total integrated cost =  354.60983840156325
# RUN  80 , total integrated cost =  354.60983840156325
# Improved over  80  iterations in  23.990583688020706  seconds by  4.983033647931734e-07  percent.
# cost splitting :  3.723367716993121e-05 [1.64922895 1.92300471]
# set cost params:  0.05 123.93901707593297 0.0
# interpolate adjoint :  True True True
# initial cost =  442.7391302074848
# RUN  0 , total integrated cost =  442.7391302074848
# Gradient descend method:  None
# RUN  1 , total integrated cost =  442.73913015317095
# RUN  2 , total integrated cost =  442.73913013108853
# RUN  3 , total integrated cost =  442.65956582315596
# RUN  4 , total integrated cost =  442.5689758199215
# RUN  5 , total integrated cost =  442.56840931738725
# RUN  6 , total integrated cost =  442.56840334833663
# RUN  7 , total integrated cost =  442.56840332262414
# RUN  8 , total integrated cost =  442.5684032939727
# RUN  9 , total integrated cost =  442.56840327136644
# RUN  10 , total integrated cost =  442.5684032143528
# RUN  11 , total integrated cost =  442.5684031458709
# RUN  12 , total integrated cost =  442.5684031250963
# RUN  13 , total integrated cost =  442.5684031027993
# RUN  14 , total integrated cost =  442.5684030701723
# RUN  15 , total integrated cost =  442.5684030315052
# RUN  16 , total integrated cost =  442.55865416603154
# RUN  17 , total integrated cost =  442.5073427103288
# RUN  18 , total integrated cost =  442.50583343354845
# RUN  19 , total integrated cost =  442.5058185251208
# RUN  20 , total integrated cost =  442.5058184487311
# RUN  30 , total integrated cost =  442.5058182448089
# RUN  40 , total integrated cost =  442.50581804176284
# RUN  50 , total integrated cost =  442.5058178387212
# RUN  60 , total integrated cost =  442.5058176356748
# RUN  70 , total integrated cost =  442.50581743262904
# RUN  80 , total integrated cost =  442.50581722958617
# RUN  80 , total integrated cost =  442.50581722958617
# Improved over  80  iterations in  24.098531432042364  seconds by  0.05269761852521526  percent.
# cost splitting :  4.620984990148366e-05 [1.64798834 1.92236283]
# set cost params:  0.05 58.761597867254174 0.0
# interpolate adjoint :  True True True
# initial cost =  209.7995421460119
# RUN  0 , total integrated cost =  209.7995421460119
# Gradient descend method:  None
# RUN  1 , total integrated cost =  209.79954162518555
# RUN  2 , total integrated cost =  209.79954161246494
# RUN  3 , total integrated cost =  209.79954160199804
# RUN  4 , total integrated cost =  209.79954159079364
# RUN  5 , total integrated cost =  209.7995415799886
# RUN  6 , total integrated cost =  209.799541568801
# RUN  7 , total integrated cost =  209.79954155795846
# RUN  8 , total integrated cost =  209.7995415467697
# RUN  9 , total integrated cost =  209.7995415359292
# RUN  10 , total integrated cost =  209.7995415247416
# RUN  11 , total integrated cost =  209.79954151390058
# RUN  12 , total integrated cost =  209.79954150271226
# RUN  13 , total integrated cost =  209.79954149187154
# RUN  14 , total integrated cost =  209.79954148068367
# RUN  15 , total integrated cost =  209.79954146984252
# RUN  16 , total integrated cost =  209.79954145865466
# RUN  17 , total integrated cost =  209.79954144781362
# RUN  18 , total integrated cost =  209.7995414366253
# RUN  19 , total integrated cost =  209.79954142578438
# RUN  20 , total integrated cost =  209.7995414145967
# RUN  30 , total integrated cost =  209.7995413044515
# RUN  40 , total integrated cost =  209.79954119430616
# RUN  50 , total integrated cost =  209.7995410841608
# RUN  60 , total integrated cost =  209.7995409740165
# RUN  70 , total integrated cost =  209.79954086387121
# RUN  80 , total integrated cost =  209.7995407537263
# RUN  80 , total integrated cost =  209.7995407537263
# Improved over  80  iterations in  18.489763201971073  seconds by  6.636266220994003e-07  percent.
# cost splitting :  2.1486145408679713e-05 [1.64798822 1.92236295]
# set cost params:  0.05 106.09675280435694 0.0
# interpolate adjoint :  True True True
# initial cost =  378.8026665518475
# RUN  0 , total integrated cost =  378.8026665518475
# Gradient descend method:  None
# RUN  1 , total integrated cost =  378.80266626643095
# RUN  2 , total integrated cost =  378.80266625001195
# RUN  3 , total integrated cost =  378.80266622971885
# RUN  4 , total integrated cost =  378.8026662100129
# RUN  5 , total integrated cost =  378.80266619002816
# RUN  6 , total integrated cost =  378.8026661696811
# RUN  7 , total integrated cost =  378.80266614969094
# RUN  8 , total integrated cost =  378.8026661293602
# RUN  9 , total integrated cost =  378.8026661093687
# RUN  10 , total integrated cost =  378.802666089038
# RUN  11 , total integrated cost =  378.8026660690469
# RUN  12 , total integrated cost =  378.8026660487156
# RUN  13 , total integrated cost =  378.8026660287243
# RUN  14 , total integrated cost =  378.8026660083916
# RUN  15 , total integrated cost =  378.80266598840046
# RUN  16 , total integrated cost =  378.8026659680689
# RUN  17 , total integrated cost =  378.8026659480774
# RUN  18 , total integrated cost =  378.80266592774706
# RUN  19 , total integrated cost =  378.80266590775693
# RUN  20 , total integrated cost =  378.802665887425
# RUN  30 , total integrated cost =  378.80266568581254
# RUN  40 , total integrated cost =  378.80266548419945
# RUN  50 , total integrated cost =  378.80266528258625
# RUN  60 , total integrated cost =  378.80266508097367
# RUN  70 , total integrated cost =  378.80266487936177
# RUN  80 , total integrated cost =  378.80266467774914
# RUN  80 , total integrated cost =  378.80266467774914
# Improved over  80  iterations in  21.203844684001524  seconds by  4.947426504031682e-07  percent.
# cost splitting :  3.4513460079030896e-05 [1.64798809 1.92236305]
# set cost params:  0.05 55.782468889539885 0.0
# interpolate adjoint :  True True True
# initial cost =  199.163003446978
# RUN  0 , total integrated cost =  199.163003446978
# Gradient descend method:  None
# RUN  1 , total integrated cost =  199.16300320082712
# RUN  2 , total integrated cost =  199.16300318713937
# RUN  3 , total integrated cost =  199.1630031783069
# RUN  4 , total integrated cost =  199.1630031403809
# RUN  5 , total integrated cost =  199.16300310330297
# RUN  6 , total integrated cost =  199.163003091456
# RUN  7 , total integrated cost =  199.16300307784877
# RUN  8 , total integrated cost =  199.1630030680418
# RUN  9 , total integrated cost =  199.16300305906884
# RUN  10 , total integrated cost =  199.16300304916868
# RUN  11 , total integrated cost =  199.16300304052254
# RUN  12 , total integrated cost =  199.1630030307145
# RUN  13 , total integrated cost =  199.1630030218468
# RUN  14 , total integrated cost =  199.1630030119416
# RUN  15 , total integrated cost =  199.1630030032989
# RUN  16 , total integrated cost =  199.16300299348543
# RUN  17 , total integrated cost =  199.16300298463418
# RUN  18 , total integrated cost =  199.16300297472776
# RUN  19 , total integrated cost =  199.16300296608603
# RUN  20 , total integrated cost =  199.16300295627198
# RUN  30 , total integrated cost =  199.16300286309453
# RUN  40 , total integrated cost =  199.16300277021517
# RUN  50 , total integrated cost =  199.1630026770389
# RUN  60 , total integrated cost =  199.16300258416015
# RUN  70 , total integrated cost =  199.16300249098288
# RUN  80 , total integrated cost =  199.16300239810406
# RUN  80 , total integrated cost =  199.16300239810406
# Improved over  80  iterations in  16.108905272965785  seconds by  5.266409459636634e-07  percent.
# cost splitting :  2.009479835277187e-05 [1.64798798 1.92236316]
# set cost params:  0.05 66.1586779064146 0.0
# interpolate adjoint :  True True True
# initial cost =  236.20971209067545
# RUN  0 , total integrated cost =  236.20971209067545
# Gradient descend method:  None
# RUN  1 , total integrated cost =  236.20971207300528
# RUN  2 , total integrated cost =  236.20971206158558
# RUN  3 , total integrated cost =  236.20971204882096
# RUN  4 , total integrated cost =  236.2097120367915
# RUN  5 , total integrated cost =  236.20971202404263
# RUN  6 , total integrated cost =  236.20971201197628
# RUN  7 , total integrated cost =  236.20971199923042
# RUN  8 , total integrated cost =  236.2097119871596
# RUN  9 , total integrated cost =  236.20971197441386
# RUN  10 , total integrated cost =  236.20971196234314
# RUN  11 , total integrated cost =  236.209711949597
# RUN  12 , total integrated cost =  236.20971193752587
# RUN  13 , total integrated cost =  236.20971192477973
# RUN  14 , total integrated cost =  236.2097119127088
# RUN  15 , total integrated cost =  236.20971189996285
# RUN  16 , total integrated cost =  236.20971188789136
# RUN  17 , total integrated cost =  236.20971187514579
# RUN  18 , total integrated cost =  236.20971186307472
# RUN  19 , total integrated cost =  236.20971185032863
# RUN  20 , total integrated cost =  236.20971183825722
# RUN  30 , total integrated cost =  236.2097117141714
# RUN  40 , total integrated cost =  236.2097115900859
# RUN  50 , total integrated cost =  236.20971146600033
# RUN  60 , total integrated cost =  236.20971134191427
# RUN  70 , total integrated cost =  236.20971121782893
# RUN  80 , total integrated cost =  236.2097110937435
# RUN  80 , total integrated cost =  236.2097110937435
# Improved over  80  iterations in  18.15658531000372  seconds by  4.220537590526874e-07  percent.
# cost splitting :  2.1035126411360608e-05 [1.64798786 1.92236326]
# set cost params:  0.05 23.419549318220675 0.0
# interpolate adjoint :  True True True
# initial cost =  83.61601528946753
# RUN  0 , total integrated cost =  83.61601528946753
# Gradient descend method:  None
# RUN  1 , total integrated cost =  83.61601497642624
# RUN  2 , total integrated cost =  83.61601496852502
# RUN  3 , total integrated cost =  83.61601495914849
# RUN  4 , total integrated cost =  83.61601494810337
# RUN  5 , total integrated cost =  83.61601493698019
# RUN  6 , total integrated cost =  83.61601485908888
# RUN  7 , total integrated cost =  83.61601471127341
# RUN  8 , total integrated cost =  83.61601470053282
# RUN  9 , total integrated cost =  83.61601468791918
# RUN  10 , total integrated cost =  83.61601463960947
# RUN  11 , total integrated cost =  83.6160145834296
# RUN  12 , total integrated cost =  83.61601458000042
# RUN  13 , total integrated cost =  83.61601457499226
# RUN  14 , total integrated cost =  83.61601457149297
# RUN  15 , total integrated cost =  83.61601456725403
# RUN  16 , total integrated cost =  83.61601456285206
# RUN  17 , total integrated cost =  83.61601455862517
# RUN  18 , total integrated cost =  83.6160145541994
# RUN  19 , total integrated cost =  83.61601454997341
# RUN  20 , total integrated cost =  83.61601454554511
# RUN  30 , total integrated cost =  83.61601450227276
# RUN  40 , total integrated cost =  83.61601445900027
# RUN  50 , total integrated cost =  83.61601441572803
# RUN  60 , total integrated cost =  83.6160143724559
# RUN  70 , total integrated cost =  83.61601432918322
# RUN  80 , total integrated cost =  83.61601428591123
# RUN  80 , total integrated cost =  83.61601428591123
# Improved over  80  iterations in  24.41316449799342  seconds by  1.2001962659269338e-06  percent.
# cost splitting :  6.667490714902595e-06 [1.64798769 1.92236343]
# set cost params:  0.05 35.55029941192978 0.0
# interpolate adjoint :  True True True
# initial cost =  126.92705137325444
# RUN  0 , total integrated cost =  126.92705137325444
# Gradient descend method:  None
# RUN  1 , total integrated cost =  126.92705129031317
# RUN  2 , total integrated cost =  126.92705128506125
# RUN  3 , total integrated cost =  126.92705127820011
# RUN  4 , total integrated cost =  126.92694106539432
# RUN  5 , total integrated cost =  126.92420996594075
# RUN  6 , total integrated cost =  126.92407762423313
# RUN  7 , total integrated cost =  126.92407734532736
# RUN  8 , total integrated cost =  126.92407733487964
# RUN  9 , total integrated cost =  126.9240773288365
# RUN  10 , total integrated cost =  126.92407732334534
# RUN  11 , total integrated cost =  126.92407731711917
# RUN  12 , total integrated cost =  126.92407731163742
# RUN  13 , total integrated cost =  126.92407730541234
# RUN  14 , total integrated cost =  126.92407729993039
# RUN  15 , total integrated cost =  126.92407729370514
# RUN  16 , total integrated cost =  126.9240772882232
# RUN  17 , total integrated cost =  126.92407728199785
# RUN  18 , total integrated cost =  126.92407727651604
# RUN  19 , total integrated cost =  126.92407727029092
# RUN  20 , total integrated cost =  126.92407726480884
# RUN  30 , total integrated cost =  126.92407720627325
# RUN  40 , total integrated cost =  126.92407714773812
# RUN  50 , total integrated cost =  126.92407708920202
# RUN  60 , total integrated cost =  126.92407703066735
# RUN  70 , total integrated cost =  126.92407697213123
# RUN  80 , total integrated cost =  126.92407691359591
# RUN  80 , total integrated cost =  126.92407691359591
# Improved over  80  iterations in  27.0479491869919  seconds by  0.0023434402882287486  percent.
# cost splitting :  1.0161192353926712e-05 [1.64790392 1.92236351]
# set cost params:  0.05 138.40869658982777 0.0
# interpolate adjoint :  True True True
# initial cost =  494.15606309421
# RUN  0 , total integrated cost =  494.15606309421
# Gradient descend method:  None
# RUN  1 , total integrated cost =  494.15606122094243
# RUN  2 , total integrated cost =  494.1560611961482
# RUN  3 , total integrated cost =  494.15606117222893
# RUN  4 , total integrated cost =  494.1535904028918
# RUN  5 , total integrated cost =  494.1347744987813
# RUN  6 , total integrated cost =  494.13395105789886
# RUN  7 , total integrated cost =  494.1339480906174
# RUN  8 , total integrated cost =  494.1339480701545
# RUN  9 , total integrated cost =  494.13394803951144
# RUN  10 , total integrated cost =  494.1339454939677
# RUN  11 , total integrated cost =  494.13394335201957
# RUN  12 , total integrated cost =  494.13394331913514
# RUN  13 , total integrated cost =  494.1339425712879
# RUN  14 , total integrated cost =  494.1339415241577
# RUN  15 , total integrated cost =  494.1339415029491
# RUN  16 , total integrated cost =  494.1339414708968
# RUN  17 , total integrated cost =  494.1316796845409
# RUN  18 , total integrated cost =  494.0903250101129
# RUN  19 , total integrated cost =  494.0889153353403
# RUN  20 , total integrated cost =  494.08884176977
# RUN  30 , total integrated cost =  494.08881442786964
# RUN  40 , total integrated cost =  494.0025781756187
# RUN  50 , total integrated cost =  494.00257794936056
# RUN  60 , total integrated cost =  494.00257772310204
# RUN  70 , total integrated cost =  494.00257749684016
# RUN  80 , total integrated cost =  494.0025772705814
# RUN  80 , total integrated cost =  494.0025772705814
# Improved over  80  iterations in  23.867948326049373  seconds by  0.031060192334280146  percent.
# cost splitting :  5.187622206771013e-05 [1.64299423 1.92616426]
# set cost params:  0.05 1.3905106033875911 0.0
# interpolate adjoint :  True True True
# initial cost =  4.962955320867567
# RUN  0 , total integrated cost =  4.962955320867567
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.962952859339304
# RUN  2 , total integrated cost =  4.962952859339304
# Control only changes marginally.
# RUN  2 , total integrated cost =  4.962952859339304
# Improved over  2  iterations in  1.764371367986314  seconds by  4.9598033911024686e-05  percent.
# cost splitting :  9.233313583828877e-07 [1.64299423 1.92616432]
# set cost params:  0.05 18.216400098150515 0.0
# interpolate adjoint :  True True True
# initial cost =  65.01722026206717
# RUN  0 , total integrated cost =  65.01722026206717
# Gradient descend method:  None
# RUN  1 , total integrated cost =  65.01721992773659
# RUN  2 , total integrated cost =  65.01721992733947
# RUN  3 , total integrated cost =  65.01721992283208
# RUN  4 , total integrated cost =  65.01721991999351
# RUN  5 , total integrated cost =  65.01721991756229
# RUN  6 , total integrated cost =  65.0172199146657
# RUN  7 , total integrated cost =  65.01721991195673
# RUN  8 , total integrated cost =  65.01721990906387
# RUN  9 , total integrated cost =  65.01721990634567
# RUN  10 , total integrated cost =  65.01721990345276
# RUN  11 , total integrated cost =  65.01721990073399
# RUN  12 , total integrated cost =  65.01721989784116
# RUN  13 , total integrated cost =  65.01721989512234
# RUN  14 , total integrated cost =  65.01721989222963
# RUN  15 , total integrated cost =  65.01721988951061
# RUN  16 , total integrated cost =  65.01721988661816
# RUN  17 , total integrated cost =  65.01721988389924
# RUN  18 , total integrated cost =  65.01721988100618
# RUN  19 , total integrated cost =  65.01721987828708
# RUN  20 , total integrated cost =  65.0172198753946
# RUN  30 , total integrated cost =  65.01721984733649
# RUN  40 , total integrated cost =  65.01721981927822
# RUN  50 , total integrated cost =  65.01721979122006
# RUN  60 , total integrated cost =  65.01721976316173
# RUN  70 , total integrated cost =  65.01721973510337
# RUN  80 , total integrated cost =  65.01721970704527
# RUN  80 , total integrated cost =  65.01721970704527
# Improved over  80  iterations in  26.276722412963863  seconds by  8.536536881820211e-07  percent.
# cost splitting :  5.963380938389486e-06 [1.6429941  1.92616441]
# set cost params:  0.05 177.95628070133975 0.0
# interpolate adjoint :  True True True
# initial cost =  635.1541737465983
# RUN  0 , total integrated cost =  635.1541737465983
# Gradient descend method:  None
# RUN  1 , total integrated cost =  635.1541691278381
# RUN  2 , total integrated cost =  635.1541690813578
# RUN  3 , total integrated cost =  635.1541689951321
# RUN  4 , total integrated cost =  635.1541689693416
# RUN  5 , total integrated cost =  635.15416894015
# RUN  6 , total integrated cost =  635.1541689132858
# RUN  7 , total integrated cost =  635.1541688841161
# RUN  8 , total integrated cost =  635.1541688571765
# RUN  9 , total integrated cost =  635.1541688280078
# RUN  10 , total integrated cost =  635.1541688010623
# RUN  11 , total integrated cost =  635.154168771891
# RUN  12 , total integrated cost =  635.1541687449454
# RUN  13 , total integrated cost =  635.1541687157788
# RUN  14 , total integrated cost =  635.1541686888331
# RUN  15 , total integrated cost =  635.1541686596624
# RUN  16 , total integrated cost =  635.1541686327172
# RUN  17 , total integrated cost =  635.1541686035508
# RUN  18 , total integrated cost =  635.1541685766045
# RUN  19 , total integrated cost =  635.1541685474353
# RUN  20 , total integrated cost =  635.1541685204899
# RUN  30 , total integrated cost =  635.1541682399201
# RUN  40 , total integrated cost =  635.1541679593487
# RUN  50 , total integrated cost =  635.1541676787795
# RUN  60 , total integrated cost =  635.1541673982038
# RUN  70 , total integrated cost =  635.1541671176332
# RUN  80 , total integrated cost =  635.1541668370625
# RUN  80 , total integrated cost =  635.1541668370625
# Improved over  80  iterations in  24.658812662004493  seconds by  1.0878517571200064e-06  percent.
# cost splitting :  5.8148497026196045e-05 [1.64299395 1.9261645 ]
# set cost params:  0.05 73.1613623692739 0.0
# interpolate adjoint :  True True True
# initial cost =  261.12449800516697
# RUN  0 , total integrated cost =  261.12449800516697
# Gradient descend method:  None
# RUN  1 , total integrated cost =  261.12449734878976
# RUN  2 , total integrated cost =  261.12449733577785
# RUN  3 , total integrated cost =  261.1244973231643
# RUN  4 , total integrated cost =  261.1244973107061
# RUN  5 , total integrated cost =  261.1244972986084
# RUN  6 , total integrated cost =  261.12449728614195
# RUN  7 , total integrated cost =  261.124497274061
# RUN  8 , total integrated cost =  261.1244972615962
# RUN  9 , total integrated cost =  261.12449724951523
# RUN  10 , total integrated cost =  261.1244972370508
# RUN  11 , total integrated cost =  261.12449722497007
# RUN  12 , total integrated cost =  261.12449721250454
# RUN  13 , total integrated cost =  261.12449720042315
# RUN  14 , total integrated cost =  261.12449718795915
# RUN  15 , total integrated cost =  261.1244971758779
# RUN  16 , total integrated cost =  261.12449716341297
# RUN  17 , total integrated cost =  261.1244971513315
# RUN  18 , total integrated cost =  261.1244971388665
# RUN  19 , total integrated cost =  261.124497126785
# RUN  20 , total integrated cost =  261.1244971143203
# RUN  30 , total integrated cost =  261.12449699158935
# RUN  40 , total integrated cost =  261.12449686885964
# RUN  50 , total integrated cost =  261.1244967461286
# RUN  60 , total integrated cost =  261.1244966233983
# RUN  70 , total integrated cost =  261.1244965006679
# RUN  80 , total integrated cost =  261.12449637793713
# RUN  80 , total integrated cost =  261.12449637793713
# Improved over  80  iterations in  31.27945141500095  seconds by  6.231624496422228e-07  percent.
# cost splitting :  2.6981000197423425e-05 [1.64299384 1.92616461]
# set cost params:  0.05 12.753733629099917 0.0
# interpolate adjoint :  True True True
# initial cost =  45.520097555326956
# RUN  0 , total integrated cost =  45.520097555326956
# Gradient descend method:  None
# RUN  1 , total integrated cost =  45.520096771419716
# RUN  2 , total integrated cost =  45.52009676586675
# RUN  3 , total integrated cost =  45.52009676395336
# RUN  4 , total integrated cost =  45.520096761973114
# RUN  5 , total integrated cost =  45.52009675995965
# RUN  6 , total integrated cost =  45.520096757992654
# RUN  7 , total integrated cost =  45.520096755951876
# RUN  8 , total integrated cost =  45.52009675398624
# RUN  9 , total integrated cost =  45.52009675194298
# RUN  10 , total integrated cost =  45.52009674997753
# RUN  11 , total integrated cost =  45.52009674793426
# RUN  12 , total integrated cost =  45.520096745968495
# RUN  13 , total integrated cost =  45.52009674392513
# RUN  14 , total integrated cost =  45.520096741959456
# RUN  15 , total integrated cost =  45.52009673991598
# RUN  16 , total integrated cost =  45.52009673795047
# RUN  17 , total integrated cost =  45.52009673590699
# RUN  18 , total integrated cost =  45.5200967339414
# RUN  19 , total integrated cost =  45.52009673189803
# RUN  20 , total integrated cost =  45.52009672993226
# RUN  30 , total integrated cost =  45.52009670988715
# RUN  40 , total integrated cost =  45.52009668984203
# RUN  50 , total integrated cost =  45.520096669796864
# RUN  60 , total integrated cost =  45.520096649751586
# RUN  70 , total integrated cost =  45.52009662970646
# RUN  80 , total integrated cost =  45.520096609661216
# RUN  80 , total integrated cost =  45.520096609661216
# Improved over  80  iterations in  27.193639475037344  seconds by  2.0774686078084414e-06  percent.
# cost splitting :  4.08801178358701e-06 [1.64299374 1.92616473]
# set cost params:  0.05 164.90734079724407 0.0
# interpolate adjoint :  True True True
# initial cost =  588.5804323609975
# RUN  0 , total integrated cost =  588.5804323609975
# Gradient descend method:  None
# RUN  1 , total integrated cost =  588.5804273849844
# RUN  2 , total integrated cost =  588.5804273629906
# RUN  3 , total integrated cost =  588.580427331947
# RUN  4 , total integrated cost =  588.5804272331011
# RUN  5 , total integrated cost =  588.5804271104498
# RUN  6 , total integrated cost =  588.5804270801408
# RUN  7 , total integrated cost =  588.5804270445045
# RUN  8 , total integrated cost =  588.5804270176244
# RUN  9 , total integrated cost =  588.5804269904744
# RUN  10 , total integrated cost =  588.5804269645306
# RUN  11 , total integrated cost =  588.580426937362
# RUN  12 , total integrated cost =  588.5804269114635
# RUN  13 , total integrated cost =  588.5804268842957
# RUN  14 , total integrated cost =  588.5804268584068
# RUN  15 , total integrated cost =  588.5804268312353
# RUN  16 , total integrated cost =  588.5804268053472
# RUN  17 , total integrated cost =  588.5804267781784
# RUN  18 , total integrated cost =  588.5804267522915
# RUN  19 , total integrated cost =  588.5804267251183
# RUN  20 , total integrated cost =  588.5804266992317
# RUN  30 , total integrated cost =  588.5804264339444
# RUN  40 , total integrated cost =  588.5804261686573
# RUN  50 , total integrated cost =  588.5804259033713
# RUN  60 , total integrated cost =  588.5804256380848
# RUN  70 , total integrated cost =  588.5804253727981
# RUN  80 , total integrated cost =  588.5804251075115
# RUN  80 , total integrated cost =  588.5804251075115
# Improved over  80  iterations in  31.574824830982834  seconds by  1.2323695557370229e-06  percent.
# cost splitting :  5.386462486566297e-05 [1.64299359 1.92616482]
# set cost params:  0.05 107.24789486052909 0.0
# interpolate adjoint :  True True True
# initial cost =  382.78472867862206
# RUN  0 , total integrated cost =  382.78472867862206
# Gradient descend method:  None
# RUN  1 , total integrated cost =  382.78472848988264
# RUN  2 , total integrated cost =  382.7847284699414
# RUN  3 , total integrated cost =  382.7847284548863
# RUN  4 , total integrated cost =  382.78472843618033
# RUN  5 , total integrated cost =  382.78472841892165
# RUN  6 , total integrated cost =  382.7847284002275
# RUN  7 , total integrated cost =  382.78472838294465
# RUN  8 , total integrated cost =  382.7847283642495
# RUN  9 , total integrated cost =  382.7847283469674
# RUN  10 , total integrated cost =  382.7847283282704
# RUN  11 , total integrated cost =  382.784728310987
# RUN  12 , total integrated cost =  382.78472829229236
# RUN  13 , total integrated cost =  382.7847282750107
# RUN  14 , total integrated cost =  382.7847282563158
# RUN  15 , total integrated cost =  382.78472823903286
# RUN  16 , total integrated cost =  382.7847282203364
# RUN  17 , total integrated cost =  382.7847282030534
# RUN  18 , total integrated cost =  382.7847281843578
# RUN  19 , total integrated cost =  382.78472816707637
# RUN  20 , total integrated cost =  382.78472814838045
# RUN  30 , total integrated cost =  382.78472796849076
# RUN  40 , total integrated cost =  382.78472778860265
# RUN  50 , total integrated cost =  382.78472760871176
# RUN  60 , total integrated cost =  382.78472742882263
# RUN  70 , total integrated cost =  382.7847272489332
# RUN  80 , total integrated cost =  382.78472706904273
# RUN  80 , total integrated cost =  382.78472706904273
# Improved over  80  iterations in  24.964298690028954  seconds by  4.2049204296290554e-07  percent.
# cost splitting :  4.004157068716171e-05 [1.64299348 1.92616492]
# set cost params:  0.05 78.8343297051406 0.0
# interpolate adjoint :  True True True
# initial cost =  281.3722122563104
# RUN  0 , total integrated cost =  281.3722122563104
# Gradient descend method:  None
# RUN  1 , total integrated cost =  281.3722121049821
# RUN  2 , total integrated cost =  281.37221207626567
# RUN  3 , total integrated cost =  281.37221205212774
# RUN  4 , total integrated cost =  281.372212037146
# RUN  5 , total integrated cost =  281.3722120212552
# RUN  6 , total integrated cost =  281.3722120028601
# RUN  7 , total integrated cost =  281.37221198696517
# RUN  8 , total integrated cost =  281.37221197376704
# RUN  9 , total integrated cost =  281.3722119624771
# RUN  10 , total integrated cost =  281.37221194915793
# RUN  11 , total integrated cost =  281.37221193603335
# RUN  12 , total integrated cost =  281.37221192272324
# RUN  13 , total integrated cost =  281.37221190957536
# RUN  14 , total integrated cost =  281.3722118962659
# RUN  15 , total integrated cost =  281.37221188311867
# RUN  16 , total integrated cost =  281.3722118698082
# RUN  17 , total integrated cost =  281.37221185666067
# RUN  18 , total integrated cost =  281.37221184335
# RUN  19 , total integrated cost =  281.37221183020273
# RUN  20 , total integrated cost =  281.3722118168917
# RUN  30 , total integrated cost =  281.3722116846022
# RUN  40 , total integrated cost =  281.3722115523136
# RUN  50 , total integrated cost =  281.37221142002437
# RUN  60 , total integrated cost =  281.37221128773507
# RUN  70 , total integrated cost =  281.37221115544753
# RUN  80 , total integrated cost =  281.37221102315624
# RUN  80 , total integrated cost =  281.37221102315624
# Improved over  80  iterations in  22.92297866300214  seconds by  4.382643652434126e-07  percent.
# cost splitting :  2.9193593408304e-05 [1.64299337 1.92616503]
# set cost params:  0.05 119.12371444043204 0.0
# interpolate adjoint :  True True True
# initial cost =  425.17140672029603
# RUN  0 , total integrated cost =  425.17140672029603
# Gradient descend method:  None
# RUN  1 , total integrated cost =  425.17140655603384
# RUN  2 , total integrated cost =  425.17140653966646
# RUN  3 , total integrated cost =  425.17140651878736
# RUN  4 , total integrated cost =  425.1714065001572
# RUN  5 , total integrated cost =  425.17140647985997
# RUN  6 , total integrated cost =  425.1714064605474
# RUN  7 , total integrated cost =  425.1714064402434
# RUN  8 , total integrated cost =  425.1714064209486
# RUN  9 , total integrated cost =  425.1714064006424
# RUN  10 , total integrated cost =  425.17140638134964
# RUN  11 , total integrated cost =  425.17140636104557
# RUN  12 , total integrated cost =  425.17140634175297
# RUN  13 , total integrated cost =  425.1714063214473
# RUN  14 , total integrated cost =  425.1714063021545
# RUN  15 , total integrated cost =  425.171406281849
# RUN  16 , total integrated cost =  425.1714062625559
# RUN  17 , total integrated cost =  425.17140624225203
# RUN  18 , total integrated cost =  425.17140622295983
# RUN  19 , total integrated cost =  425.1714062026532
# RUN  20 , total integrated cost =  425.1714061833598
# RUN  30 , total integrated cost =  425.17140598537094
# RUN  40 , total integrated cost =  425.17140578738014
# RUN  50 , total integrated cost =  425.17140558939104
# RUN  60 , total integrated cost =  425.1714053914
# RUN  70 , total integrated cost =  425.17140519340916
# RUN  80 , total integrated cost =  425.17140499541864
# RUN  80 , total integrated cost =  425.17140499541864
# Improved over  80  iterations in  29.20614172401838  seconds by  4.056898887938587e-07  percent.
# cost splitting :  3.8837474989124375e-05 [1.64299325 1.92616512]
# set cost params:  0.05 153.82173512744072 0.0
# interpolate adjoint :  True True True
# initial cost =  549.0141361256101
# RUN  0 , total integrated cost =  549.0141361256101
# Gradient descend method:  None
# RUN  1 , total integrated cost =  549.0141359354244
# RUN  2 , total integrated cost =  549.0141359148936
# RUN  3 , total integrated cost =  549.0141358870137
# RUN  4 , total integrated cost =  549.0141358656326
# RUN  5 , total integrated cost =  549.0141358400687
# RUN  6 , total integrated cost =  549.0141358153786
# RUN  7 , total integrated cost =  549.0141357898411
# RUN  8 , total integrated cost =  549.0141357650859
# RUN  9 , total integrated cost =  549.0141357395502
# RUN  10 , total integrated cost =  549.0141357147855
# RUN  11 , total integrated cost =  549.0141356892498
# RUN  12 , total integrated cost =  549.0141356644835
# RUN  13 , total integrated cost =  549.0141356389478
# RUN  14 , total integrated cost =  549.0141356141819
# RUN  15 , total integrated cost =  549.0141355886469
# RUN  16 , total integrated cost =  549.0141355638807
# RUN  17 , total integrated cost =  549.0141355383441
# RUN  18 , total integrated cost =  549.0141355135771
# RUN  19 , total integrated cost =  549.0141354880441
# RUN  20 , total integrated cost =  549.0141354632783
# RUN  30 , total integrated cost =  549.0141352117719
# RUN  40 , total integrated cost =  549.014134960263
# RUN  50 , total integrated cost =  549.0141347087567
# RUN  60 , total integrated cost =  549.0141344572492
# RUN  70 , total integrated cost =  549.0141342057441
# RUN  80 , total integrated cost =  549.0141339542364
# RUN  80 , total integrated cost =  549.0141339542364
# Improved over  80  iterations in  31.483869569958188  seconds by  3.9550414498989994e-07  percent.
# cost splitting :  5.02235835337542e-05 [1.64299314 1.92616521]
# set cost params:  0.05 131.7048511839315 0.0
# interpolate adjoint :  True True True
# initial cost =  470.0754727929138
# RUN  0 , total integrated cost =  470.0754727929138
# Gradient descend method:  None
# RUN  1 , total integrated cost =  470.07547276585365
# RUN  2 , total integrated cost =  470.07547274294166
# RUN  3 , total integrated cost =  470.07547271799046
# RUN  4 , total integrated cost =  470.07547269505034
# RUN  5 , total integrated cost =  470.07547267015985
# RUN  6 , total integrated cost =  470.07547264722183
# RUN  7 , total integrated cost =  470.07547262232583
# RUN  8 , total integrated cost =  470.0754725993877
# RUN  9 , total integrated cost =  470.0754725744914
# RUN  10 , total integrated cost =  470.07547255155487
# RUN  11 , total integrated cost =  470.075472526658
# RUN  12 , total integrated cost =  470.07547250372215
# RUN  13 , total integrated cost =  470.07547247882667
# RUN  14 , total integrated cost =  470.0754724558869
# RUN  15 , total integrated cost =  470.0754724309899
# RUN  16 , total integrated cost =  470.0754724080527
# RUN  17 , total integrated cost =  470.07547238315794
# RUN  18 , total integrated cost =  470.07547236022066
# RUN  19 , total integrated cost =  470.0754723353229
# RUN  20 , total integrated cost =  470.0754723123864
# RUN  30 , total integrated cost =  470.0754720732192
# RUN  40 , total integrated cost =  470.07547183405075
# RUN  50 , total integrated cost =  470.0754715948827
# RUN  60 , total integrated cost =  470.07547135571497
# RUN  70 , total integrated cost =  470.0754711165468
# RUN  80 , total integrated cost =  470.0754708773788
# RUN  80 , total integrated cost =  470.0754708773788
# Improved over  80  iterations in  28.67874868103536  seconds by  4.0749520735516853e-07  percent.
# cost splitting :  4.9914087294888816e-05 [1.64299302 1.92616532]
# set cost params:  0.05 94.2392739420286 0.0
# interpolate adjoint :  True True True
# initial cost =  336.3548932990937
# RUN  0 , total integrated cost =  336.3548932990937
# Gradient descend method:  None
# RUN  1 , total integrated cost =  336.35489308419864
# RUN  2 , total integrated cost =  336.3548930661969
# RUN  3 , total integrated cost =  336.35489281948696
# RUN  4 , total integrated cost =  336.3548924946343
# RUN  5 , total integrated cost =  336.3548924766742
# RUN  6 , total integrated cost =  336.35489245910503
# RUN  7 , total integrated cost =  336.35489244106435
# RUN  8 , total integrated cost =  336.35489242467816
# RUN  9 , total integrated cost =  336.3548924115473
# RUN  10 , total integrated cost =  336.3548923955814
# RUN  11 , total integrated cost =  336.3548923824376
# ...
# RUN  4 , total integrated cost =  668.1731998046832
# RUN  5 , total integrated cost =  668.1731996183325
# RUN  6 , total integrated cost =  668.173199469233
# RUN  7 , total integrated cost =  668.1731992691153
# RUN  8 , total integrated cost =  668.1731991092823
# RUN  9 , total integrated cost =  668.1731988969931
# RUN  10 , total integrated cost =  668.1731987223092
# RUN  11 , total integrated cost =  668.1731984782674
# RUN  12 , total integrated cost =  668.1731982430056
# RUN  13 , total integrated cost =  668.1731978953161
# RUN  14 , total integrated cost =  668.1731976731342
# RUN  15 , total integrated cost =  668.1731973598418
# RUN  16 , total integrated cost =  668.1731972080082
# RUN  17 , total integrated cost =  668.1731970108543
# RUN  18 , total integrated cost =  668.1731968536103
# RUN  19 , total integrated cost =  668.1731966385079
# RUN  20 , total integrated cost =  668.1731964601793
# RUN  30 , total integrated cost =  666.4719058578984
# RUN  40 , total integrated cost =  666.4719045144441
# RUN  50 , total integrated cost =  666.4719031708535
# RUN  60 , total integrated cost =  666.4719018272618
# RUN  70 , total integrated cost =  666.4719004836696
# RUN  80 , total integrated cost =  666.4718991400805
# RUN  80 , total integrated cost =  666.4718991400805
# Improved over  80  iterations in  24.16339592798613  seconds by  0.25461982015775675  percent.
# cost splitting :  6.756542141216198e-06 [7.45584419 4.30735341]
# set cost params:  0.05 34.35372151634756 0.0
# interpolate adjoint :  True True True
# initial cost =  404.1096147753033
# RUN  0 , total integrated cost =  404.1096147753033
# Gradient descend method:  None
# RUN  1 , total integrated cost =  404.1096147268076
# RUN  2 , total integrated cost =  404.1096146851823
# RUN  3 , total integrated cost =  404.10961463620754
# RUN  4 , total integrated cost =  404.10961459385794
# RUN  5 , total integrated cost =  404.1096145453636
# RUN  6 , total integrated cost =  404.10961450373344
# RUN  7 , total integrated cost =  404.10961445476534
# RUN  8 , total integrated cost =  404.10961441241056
# RUN  9 , total integrated cost =  404.10961436391966
# RUN  10 , total integrated cost =  404.1096143222839
# RUN  11 , total integrated cost =  404.1096142733235
# RUN  12 , total integrated cost =  404.10961423096194
# RUN  13 , total integrated cost =  404.1096141824741
# RUN  14 , total integrated cost =  404.109614140834
# RUN  15 , total integrated cost =  404.1096140918781
# RUN  16 , total integrated cost =  404.1096140495135
# RUN  17 , total integrated cost =  404.10961400102775
# RUN  18 , total integrated cost =  404.10961395938403
# RUN  19 , total integrated cost =  404.1096139104346
# RUN  20 , total integrated cost =  404.1096138680638
# RUN  30 , total integrated cost =  404.1096134150277
# RUN  40 , total integrated cost =  404.1096129608045
# RUN  50 , total integrated cost =  404.10961250776165
# RUN  60 , total integrated cost =  404.1096120535385
# RUN  70 , total integrated cost =  404.10961160048987
# RUN  80 , total integrated cost =  404.1096111363849
# RUN  80 , total integrated cost =  404.1096111363849
# Improved over  80  iterations in  33.127994512964506  seconds by  9.004780565646797e-07  percent.
# cost splitting :  6.839072202824818e-06 [7.45584419 4.3073533 ]
# set cost params:  0.05 2.398355370302779 0.0
# interpolate adjoint :  True True True
# initial cost =  28.21232821969413
# RUN  0 , total integrated cost =  28.21232821969413
# Gradient descend method:  None
# RUN  1 , total integrated cost =  28.212328161193895
# RUN  2 , total integrated cost =  28.212328161193895
# Control only changes marginally.
# RUN  2 , total integrated cost =  28.212328161193895
# Improved over  2  iterations in  1.0751104999799281  seconds by  2.07356990244989e-07  percent.
# cost splitting :  5.445912677149785e-06 [7.4558442 4.3073533]
# set cost params:  0.05 54.999189456108205 0.0
# interpolate adjoint :  True True True
# initial cost =  646.9663280202433
# RUN  0 , total integrated cost =  646.9663280202433
# Gradient descend method:  None
# RUN  1 , total integrated cost =  646.9663276274028
# RUN  2 , total integrated cost =  646.9663274809009
# RUN  3 , total integrated cost =  646.966327290836
# RUN  4 , total integrated cost =  646.9663271267896
# RUN  5 , total integrated cost =  646.9663268910654
# RUN  6 , total integrated cost =  646.9663266134174
# RUN  7 , total integrated cost =  646.9663261508955
# RUN  8 , total integrated cost =  644.6884811215816
# RUN  9 , total integrated cost =  633.0231619917515
# RUN  10 , total integrated cost =  632.4154663743159
# RUN  11 , total integrated cost =  632.4008884210024
# RUN  12 , total integrated cost =  632.4005009615371
# RUN  13 , total integrated cost =  632.4004908583868
# RUN  14 , total integrated cost =  632.4004908031503
# RUN  15 , total integrated cost =  632.4004908031503
# Control only changes marginally.
# RUN  15 , total integrated cost =  632.4004908031503
# Improved over  15  iterations in  6.443272214033641  seconds by  2.251405766613118  percent.
# cost splitting :  7.486831630875799e-06 [7.4558442  4.04251599]
# set cost params:  0.05 45.63913859130906 0.0
# interpolate adjoint :  True True True
# initial cost =  524.7752545792322
# RUN  0 , total integrated cost =  524.7752545792322
# Gradient descend method:  None
# RUN  1 , total integrated cost =  524.7752545369932
# RUN  2 , total integrated cost =  524.7752544999678
# RUN  3 , total integrated cost =  524.7752544570471
# RUN  4 , total integrated cost =  524.7752544202535
# RUN  5 , total integrated cost =  524.7752543778353
# RUN  6 , total integrated cost =  524.775254340763
# RUN  7 , total integrated cost =  524.7752542981989
# RUN  8 , total integrated cost =  524.7752542613208
# RUN  9 , total integrated cost =  524.775254218876
# RUN  10 , total integrated cost =  524.7752541820158
# RUN  11 , total integrated cost =  524.7752541388751
# RUN  12 , total integrated cost =  524.7752541020536
# RUN  13 , total integrated cost =  524.7752540597463
# RUN  14 , total integrated cost =  524.7752540225543
# RUN  15 , total integrated cost =  524.775253980105
# RUN  16 , total integrated cost =  524.7752539430593
# RUN  17 , total integrated cost =  524.7752539004769
# RUN  18 , total integrated cost =  524.7752538635953
# RUN  19 , total integrated cost =  524.7752538211837
# RUN  20 , total integrated cost =  524.7752537843048
# RUN  30 , total integrated cost =  524.7752533863261
# RUN  40 , total integrated cost =  524.7752529888211
# RUN  50 , total integrated cost =  524.7752525893096
# RUN  60 , total integrated cost =  524.77525218361
# RUN  70 , total integrated cost =  524.7752517683092
# RUN  80 , total integrated cost =  524.7752513512502
# RUN  80 , total integrated cost =  524.7752513512502
# Improved over  80  iterations in  39.928172903019004  seconds by  6.1511703108863e-07  percent.
# cost splitting :  7.846163545122268e-06 [7.4558442  4.04251592]
# set cost params:  0.05 61.4215354699006 0.0
# interpolate adjoint :  True True True
# initial cost =  706.2469341729233
# RUN  0 , total integrated cost =  706.2469341729233
# Gradient descend method:  None
# RUN  1 , total integrated cost =  706.2469340956995
# RUN  2 , total integrated cost =  706.2469340326935
# RUN  3 , total integrated cost =  706.2469339564914
# RUN  4 , total integrated cost =  706.2469338931209
# RUN  5 , total integrated cost =  706.2469338173225
# RUN  6 , total integrated cost =  706.2469337537667
# RUN  7 , total integrated cost =  706.2469336781777
# RUN  8 , total integrated cost =  706.2469336145268
# RUN  9 , total integrated cost =  706.2469335390418
# RUN  10 , total integrated cost =  706.2469334753451
# RUN  11 , total integrated cost =  706.2469333999076
# RUN  12 , total integrated cost =  706.2469333361905
# RUN  13 , total integrated cost =  706.2469332607773
# RUN  14 , total integrated cost =  706.2469331970497
# RUN  15 , total integrated cost =  706.2469331216515
# RUN  16 , total integrated cost =  706.2469330579117
# RUN  17 , total integrated cost =  706.2469329825237
# RUN  18 , total integrated cost =  706.2469329187797
# RUN  19 , total integrated cost =  706.2469328433974
# RUN  20 , total integrated cost =  706.2469327796517
# RUN  30 , total integrated cost =  706.2469320840192
# RUN  40 , total integrated cost =  706.2469313883879
# RUN  50 , total integrated cost =  706.2469306927578
# RUN  60 , total integrated cost =  706.2469299971267
# RUN  70 , total integrated cost =  706.2469293014973
# RUN  80 , total integrated cost =  706.2469286058666
# RUN  80 , total integrated cost =  706.2469286058666
# Improved over  80  iterations in  33.95608183002332  seconds by  7.882592285568535e-07  percent.
# cost splitting :  7.9096683624625e-06 [7.4558442  4.04251583]
# set cost params:  0.05 62.94008497671684 0.0
# interpolate adjoint :  True True True
# initial cost =  723.7077575532372
# RUN  0 , total integrated cost =  723.7077575532372
# Gradient descend method:  None
# RUN  1 , total integrated cost =  723.7077574726768
# RUN  2 , total integrated cost =  723.7077574103221
# RUN  3 , total integrated cost =  723.7077573345518
# RUN  4 , total integrated cost =  723.7077572706296
# RUN  5 , total integrated cost =  723.7077571967068
# RUN  6 , total integrated cost =  723.7077571319612
# RUN  7 , total integrated cost =  723.7077570515702
# RUN  8 , total integrated cost =  723.7077569891653
# RUN  9 , total integrated cost =  723.7077569134574
# RUN  10 , total integrated cost =  723.707756849515
# RUN  11 , total integrated cost =  723.7077567756156
# RUN  12 , total integrated cost =  723.707756710844
# RUN  13 , total integrated cost =  723.7077566304825
# RUN  14 , total integrated cost =  723.7077565680692
# RUN  15 , total integrated cost =  723.7077564923723
# RUN  16 , total integrated cost =  723.7077564284241
# RUN  17 , total integrated cost =  723.7077563545303
# RUN  18 , total integrated cost =  723.7077562897564
# RUN  19 , total integrated cost =  723.7077562093975
# RUN  20 , total integrated cost =  723.7077561469844
# RUN  30 , total integrated cost =  723.7077554475886
# RUN  40 , total integrated cost =  723.7077547440887
# RUN  50 , total integrated cost =  723.7077540415619
# RUN  60 , total integrated cost =  723.707753342167
# RUN  70 , total integrated cost =  723.7077526386657
# RUN  80 , total integrated cost =  723.7077519361426
# RUN  80 , total integrated cost =  723.7077519361426
# Improved over  80  iterations in  30.7126715129707  seconds by  7.76155090420616e-07  percent.
# cost splitting :  8.085726518588364e-06 [7.4558442  4.04251574]
# set cost params:  0.05 8.93165918367341 0.0
# interpolate adjoint :  True True True
# initial cost =  102.69943253337087
# RUN  0 , total integrated cost =  102.69943253337087
# Gradient descend method:  None
# RUN  1 , total integrated cost =  102.69943245113556
# RUN  2 , total integrated cost =  101.6934071360605
# RUN  3 , total integrated cost =  99.37873016748966
# RUN  4 , total integrated cost =  99.30311131073525
# RUN  5 , total integrated cost =  99.30098891783928
# RUN  6 , total integrated cost =  99.3009373541522
# RUN  7 , total integrated cost =  99.30093731421064
# RUN  8 , total integrated cost =  99.30093730003469
# RUN  9 , total integrated cost =  99.30093728117438
# RUN  10 , total integrated cost =  99.30093726970509
# RUN  11 , total integrated cost =  99.300937256526
# RUN  12 , total integrated cost =  99.30093724524451
# RUN  13 , total integrated cost =  99.3009372318695
# RUN  14 , total integrated cost =  99.30093722066016
# RUN  15 , total integrated cost =  99.30093720721268
# RUN  16 , total integrated cost =  99.30093719606923
# RUN  17 , total integrated cost =  99.30093718255578
# RUN  18 , total integrated cost =  99.30093717147672
# RUN  19 , total integrated cost =  99.3009371578969
# RUN  20 , total integrated cost =  99.3009371468528
# RUN  30 , total integrated cost =  99.30093702355207
# RUN  40 , total integrated cost =  99.30093690024535
# RUN  50 , total integrated cost =  99.3009367769385
# RUN  60 , total integrated cost =  99.3009366536313
# RUN  70 , total integrated cost =  99.30093653032421
# RUN  80 , total integrated cost =  99.30093640701732
# RUN  80 , total integrated cost =  99.30093640701732
# Improved over  80  iterations in  26.544444092025515  seconds by  3.309167385369193  percent.
# cost splitting :  4.733277212154534e-05 [8.01834929 3.09951045]
# set cost params:  0.05 26.77680806072423 0.0
# interpolate adjoint :  True True True
# initial cost =  297.700798643133
# RUN  0 , total integrated cost =  297.700798643133
# Gradient descend method:  None
# RUN  1 , total integrated cost =  297.70079834974086
# RUN  2 , total integrated cost =  297.70079827170105
# RUN  3 , total integrated cost =  297.70079816415915
# RUN  4 , total integrated cost =  297.70079800065815
# RUN  5 , total integrated cost =  297.70079771370536
# RUN  6 , total integrated cost =  297.70079766091146
# RUN  7 , total integrated cost =  297.7007975901224
# RUN  8 , total integrated cost =  297.70079755541906
# RUN  9 , total integrated cost =  297.70079751249807
# RUN  10 , total integrated cost =  297.700797485566
# RUN  11 , total integrated cost =  297.7007974530198
# RUN  12 , total integrated cost =  297.70079742389345
# RUN  13 , total integrated cost =  297.7007973900782
# RUN  14 , total integrated cost =  297.70079736199966
# RUN  15 , total integrated cost =  297.7007973270392
# RUN  16 , total integrated cost =  297.7007972990934
# RUN  17 , total integrated cost =  297.7007972675911
# RUN  18 , total integrated cost =  297.7007972377429
# RUN  19 , total integrated cost =  297.7007972009271
# RUN  20 , total integrated cost =  297.70079717298603
# RUN  30 , total integrated cost =  297.7007968594128
# RUN  40 , total integrated cost =  297.70079654242494
# RUN  50 , total integrated cost =  297.70079622885186
# RUN  60 , total integrated cost =  297.7007959118648
# RUN  70 , total integrated cost =  297.7007955982919
# RUN  80 , total integrated cost =  297.7007952813048
# RUN  80 , total integrated cost =  297.7007952813048
# Improved over  80  iterations in  28.48235919495346  seconds by  1.1292640778037821e-06  percent.
# cost splitting :  5.119094184213023e-05 [8.01834929 3.09951032]
# set cost params:  0.05 65.77038718190853 0.0
# interpolate adjoint :  True True True
# initial cost =  731.2259334945571
# RUN  0 , total integrated cost =  731.2259334945571
# Gradient descend method:  None
# RUN  1 , total integrated cost =  731.2259330012552
# RUN  2 , total integrated cost =  730.2066587813343
# RUN  3 , total integrated cost =  726.9627388331528
# RUN  4 , total integrated cost =  726.8125371251592
# RUN  5 , total integrated cost =  726.8106801829747
# RUN  6 , total integrated cost =  726.8106754362256
# RUN  7 , total integrated cost =  726.8106754101958
# RUN  8 , total integrated cost =  726.8106753801829
# RUN  9 , total integrated cost =  726.8106753543296
# RUN  10 , total integrated cost =  726.8106753235653
# RUN  11 , total integrated cost =  726.8106752967384
# RUN  12 , total integrated cost =  726.8106752647302
# RUN  13 , total integrated cost =  726.8106752370586
# RUN  14 , total integrated cost =  726.8106752016747
# RUN  15 , total integrated cost =  726.810675169777
# RUN  16 , total integrated cost =  726.810675129446
# RUN  17 , total integrated cost =  726.8106750914643
# RUN  18 , total integrated cost =  726.8106750417626
# RUN  19 , total integrated cost =  726.8106750014235
# RUN  20 , total integrated cost =  726.8106749565072
# RUN  30 , total integrated cost =  726.8106740755167
# RUN  40 , total integrated cost =  722.7842644163276
# Control only changes marginally.
# RUN  43 , total integrated cost =  722.7841446452491
# Improved over  43  iterations in  14.155465746996924  seconds by  1.1544706584686395  percent.
# cost splitting :  0.0007863297260064502 [8.40718578 2.58232084]
# set cost params:  0.05 38.66845723951009 0.0
# interpolate adjoint :  True True True
# initial cost =  424.9473061312792
# RUN  0 , total integrated cost =  424.9473061312792
# Gradient descend method:  None
# RUN  1 , total integrated cost =  424.9473061312792
# Control only changes marginally.
# RUN  1 , total integrated cost =  424.9473061312792
# Improved over  1  iterations in  0.8371380640310235  seconds by  0.0  percent.
# cost splitting :  0.0007863297260064502 [8.40718578 2.58232084]

# %%
c_var = [0,1]
conv = [None] * len(exc)

tol = 1e-12

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
        
    while not conv[i]:
        max_it = int(100)

        weight_ = random.random() * ( cost_uncontrolled[i] -
                                     costnode_[i][0][0][0] ) / sum( costnode_[i][ind_cost][0][:] )
            
        aln.params.duration = dur
        cost.setParams(wp, weight_ * factor_we, weight_ * factor_ws)
        weights_[i] = cost.getParams()

        setinit(initVars[i], aln)

        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        control0 = aln.getZeroControl()
        control0 = bestControl_[i][:,:,n_pre-1:-n_post+1]

        bestControl_[i], bestState_[i], cost_[i], runtime_, grad_, phi_, phi1_, costnode_[i] = aln.A1(
            control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
            prec_variables_ = p_var, transition_time_ = t_pen)
        
        if cost_[i][2] == 0.:
            conv[i] = True

        #print('uncontrolled cost : ', cost_uncontrolled[i])
        print('cost splitting : ', costnode_[i][0][0][0], costnode_[i][ind_cost][0][:2])

        if conv[i] and False:
            time_ = np.arange(-dur_pre,round(dur+dur_post+aln.params.dt,1),aln.params.dt)
            target_ = aln.getZeroTarget()
            target_[:,0,:] = target[i][0]
            target_[:,1,:] = target[i][1]
        
            fig, ax = plt.subplots(2,1, constrained_layout=True, figsize = (4,4) )
            ax[1].plot(time_, bestControl_[i][0,0,:], color = 'red')
            ax[0].plot(time_, bestState_[i][0,0,:], color= 'red')
            ax[1].plot(time_, bestControl_[i][0,1,:], color = 'blue')
            ax[0].plot(time_, bestState_[i][0,1,:], color= 'blue')
            ax[0].plot(time_, target_[0,0,:], linestyle = '--', color='red')
            ax[0].plot(time_, target_[0,1,:], linestyle = '--', color='blue')
            ax[0].set_xlim(-dur_pre,dur+dur_post)
            ax[1].set_xlim(-dur_pre,dur+dur_post)
            ax[0].axvspan(dur*t_pen, dur, alpha=0.2, color='gray')
            plt.show()

        with open(file_,'wb') as f:
            pickle.dump([bestControl_, bestState_, cost_, costnode_, weights_], f)
# Out:
# -------  20 0.4500000000000001 0.4750000000000002
# set cost params:  0.05 87.28832507369076 0.0
# interpolate adjoint :  True True True
# initial cost =  310.01435792380676
# RUN  0 , total integrated cost =  310.01435792380676
# Gradient descend method:  None
# RUN  1 , total integrated cost =  310.01435779025354
# RUN  2 , total integrated cost =  310.0143577901064
# RUN  3 , total integrated cost =  310.0143577901064
# Control only changes marginally.
# RUN  3 , total integrated cost =  310.0143577901064
# Improved over  3  iterations in  1.7167459379998036  seconds by  4.31271587331139e-08  percent.
# cost splitting :  3.1089728275937e-05 [1.37763074 2.17398233]
# set cost params:  0.05 33.47398328192703 0.0
# interpolate adjoint :  True True True
# initial cost =  118.88663810098599
# RUN  0 , total integrated cost =  118.88663810098599
# Gradient descend method:  None
# RUN  1 , total integrated cost =  118.88663771393578
# RUN  2 , total integrated cost =  118.88663771393546
# RUN  3 , total integrated cost =  118.88663771393142
# RUN  4 , total integrated cost =  118.88663771393101
# RUN  5 , total integrated cost =  118.88663771393101
# Control only changes marginally.
# RUN  5 , total integrated cost =  118.88663771393101
# Improved over  5  iterations in  2.2521197340101935  seconds by  3.2556643247971806e-07  percent.
# cost splitting :  1.1919036959980121e-05 [1.37763074 2.17398235]
# set cost params:  0.05 163.80068646928822 0.0
# interpolate adjoint :  True True True
# initial cost =  581.7566624170818
# RUN  0 , total integrated cost =  581.7566624170818
# Gradient descend method:  None
# RUN  1 , total integrated cost =  581.7566601053195
# RUN  2 , total integrated cost =  581.7566601037105
# RUN  3 , total integrated cost =  581.7566601037105
# Control only changes marginally.
# RUN  3 , total integrated cost =  581.7566601037105
# Improved over  3  iterations in  1.331421885988675  seconds by  3.976527267468555e-07  percent.
# cost splitting :  5.7842068567923996e-05 [1.37763071 2.17398235]
# set cost params:  0.05 122.71050262385928 0.0
# interpolate adjoint :  True True True
# initial cost =  435.8202265429809
# RUN  0 , total integrated cost =  435.8202265429809
# Gradient descend method:  None
# RUN  1 , total integrated cost =  435.8202264456603
# RUN  2 , total integrated cost =  435.82022644542644
# RUN  3 , total integrated cost =  435.82022644542644
# Control only changes marginally.
# RUN  3 , total integrated cost =  435.82022644542644
# Improved over  3  iterations in  1.5891493009985425  seconds by  2.2384099906958e-08  percent.
# cost splitting :  4.363684029370041e-05 [1.37763071 2.17398235]
# set cost params:  0.05 176.0477188814648 0.0
# interpolate adjoint :  True True True
# initial cost =  625.2533805270946
# RUN  0 , total integrated cost =  625.2533805270946
# Gradient descend method:  None
# RUN  1 , total integrated cost =  625.2533803490414
# RUN  2 , total integrated cost =  625.2533803489542
# RUN  3 , total integrated cost =  625.2533803489542
# Control only changes marginally.
# RUN  3 , total integrated cost =  625.2533803489542
# Improved over  3  iterations in  1.4284313750104047  seconds by  2.8490902082012326e-08  percent.
# cost splitting :  6.209452910116867e-05 [1.37763071 2.17398235]
# set cost params:  0.05 16.690331860173895 0.0
# interpolate adjoint :  True True True
# initial cost =  59.2776036848692
# RUN  0 , total integrated cost =  59.2776036848692
# Gradient descend method:  None
# RUN  1 , total integrated cost =  59.27760157616723
# RUN  2 , total integrated cost =  59.27760157616297
# RUN  3 , total integrated cost =  59.27760157616297
# Control only changes marginally.
# RUN  3 , total integrated cost =  59.27760157616297
# Improved over  3  iterations in  1.2731097560026683  seconds by  3.5573405483546594e-06  percent.
# cost splitting :  6.107670523050568e-06 [1.37763072 2.17398238]
# set cost params:  0.05 16.759771177121422 0.0
# interpolate adjoint :  True True True
# initial cost =  59.524223163859
# RUN  0 , total integrated cost =  59.524223163859
# Gradient descend method:  None
# RUN  1 , total integrated cost =  59.524223163853975
# RUN  2 , total integrated cost =  59.52422316385357
# RUN  3 , total integrated cost =  59.52422316385357
# Control only changes marginally.
# RUN  3 , total integrated cost =  59.52422316385357
# Improved over  3  iterations in  1.5554893329972401  seconds by  9.109157872444484e-12  percent.
# cost splitting :  6.132683842536701e-06 [1.37763072 2.17398238]
# set cost params:  0.05 127.0123455180309 0.0
# interpolate adjoint :  True True True
# initial cost =  451.0987104461819
# RUN  0 , total integrated cost =  451.0987104461819
# Gradient descend method:  None
# RUN  1 , total integrated cost =  451.0987078640826
# RUN  2 , total integrated cost =  451.0987078636725
# RUN  3 , total integrated cost =  451.09870786367094
# RUN  4 , total integrated cost =  451.09870786367094
# Control only changes marginally.
# RUN  4 , total integrated cost =  451.09870786367094
# Improved over  4  iterations in  1.9197715330519713  seconds by  5.724935334683323e-07  percent.
# cost splitting :  4.510972761839617e-05 [1.37763069 2.17398238]
# set cost params:  0.05 102.07188219288912 0.0
# interpolate adjoint :  True True True
# initial cost =  362.51983250038825
# RUN  0 , total integrated cost =  362.51983250038825
# Gradient descend method:  None
# RUN  1 , total integrated cost =  362.51983245438277
# RUN  2 , total integrated cost =  362.5198324542994
# RUN  3 , total integrated cost =  362.5198324542994
# Control only changes marginally.
# RUN  3 , total integrated cost =  362.5198324542994
# Improved over  3  iterations in  1.7104512989753857  seconds by  1.2713471164715884e-08  percent.
# cost splitting :  3.636821203990801e-05 [1.37763069 2.17398238]
# set cost params:  0.05 151.20471467648343 0.0
# interpolate adjoint :  True True True
# initial cost =  537.020642353689
# RUN  0 , total integrated cost =  537.020642353689
# Gradient descend method:  None
# RUN  1 , total integrated cost =  537.0206421722896
# RUN  2 , total integrated cost =  537.0206421722896
# Control only changes marginally.
# RUN  2 , total integrated cost =  537.0206421722896
# Improved over  2  iterations in  1.1946683309506625  seconds by  3.377884638666728e-08  percent.
# cost splitting :  5.351119308005717e-05 [1.37763068 2.17398238]
# set cost params:  0.05 66.37301292160001 0.0
# interpolate adjoint :  True True True
# initial cost =  235.73126225133024
# RUN  0 , total integrated cost =  235.73126225133024
# Gradient descend method:  None
# RUN  1 , total integrated cost =  235.73126172271324
# RUN  2 , total integrated cost =  235.73126172250332
# RUN  3 , total integrated cost =  235.73126172249962
# RUN  4 , total integrated cost =  235.73126172249962
# Control only changes marginally.
# RUN  4 , total integrated cost =  235.73126172249962
# Improved over  4  iterations in  2.213369312987197  seconds by  2.2433623314555007e-07  percent.
# cost splitting :  2.364554164231671e-05 [1.37763068 2.1739824 ]
# set cost params:  0.05 30.126719874918983 0.0
# interpolate adjoint :  True True True
# initial cost =  106.99845340630847
# RUN  0 , total integrated cost =  106.99845340630847
# Gradient descend method:  None
# RUN  1 , total integrated cost =  106.99845318430299
# RUN  2 , total integrated cost =  106.99845318425555
# RUN  3 , total integrated cost =  106.99845318425555
# Control only changes marginally.
# RUN  3 , total integrated cost =  106.99845318425555
# Improved over  3  iterations in  1.6556191419949755  seconds by  2.075290979064448e-07  percent.
# cost splitting :  1.0730618433227359e-05 [1.37763068 2.17398241]
# set cost params:  0.05 176.6708961464078 0.0
# interpolate adjoint :  True True True
# initial cost =  627.4666678018893
# RUN  0 , total integrated cost =  627.4666678018893
# Gradient descend method:  None
# RUN  1 , total integrated cost =  627.4666648499808
# RUN  2 , total integrated cost =  627.4666648499248
# RUN  3 , total integrated cost =  627.4666648499199
# RUN  4 , total integrated cost =  627.4666648499199
# Control only changes marginally.
# RUN  4 , total integrated cost =  627.4666648499199
# Improved over  4  iterations in  2.1003540700185113  seconds by  4.704583744796764e-07  percent.
# cost splitting :  6.229553155645319e-05 [1.37763066 2.1739824 ]
# set cost params:  0.05 95.6507702126877 0.0
# interpolate adjoint :  True True True
# initial cost =  339.7145276169546
# RUN  0 , total integrated cost =  339.7145276169546
# Gradient descend method:  None
# RUN  1 , total integrated cost =  339.71452723013
# RUN  2 , total integrated cost =  339.71452722971765
# RUN  3 , total integrated cost =  339.71452722971765
# Control only changes marginally.
# RUN  3 , total integrated cost =  339.71452722971765
# Improved over  3  iterations in  1.7424682170385495  seconds by  1.1398894628200651e-07  percent.
# cost splitting :  3.4047419714306836e-05 [1.37763066 2.17398241]
# set cost params:  0.05 108.13220298129163 0.0
# interpolate adjoint :  True True True
# initial cost =  384.0437469679343
# RUN  0 , total integrated cost =  384.0437469679343
# Gradient descend method:  None
# RUN  1 , total integrated cost =  384.0437469535869
# RUN  2 , total integrated cost =  384.043746953571
# RUN  3 , total integrated cost =  384.043746953571
# Control only changes marginally.
# RUN  3 , total integrated cost =  384.043746953571
# Improved over  3  iterations in  1.525993903982453  seconds by  3.740012743946863e-09  percent.
# cost splitting :  3.8499040094459476e-05 [1.37763066 2.17398241]
# set cost params:  0.05 49.92161748840443 0.0
# interpolate adjoint :  True True True
# initial cost =  177.3022709025863
# RUN  0 , total integrated cost =  177.3022709025863
# Gradient descend method:  None
# RUN  1 , total integrated cost =  177.30227055419232
# RUN  2 , total integrated cost =  177.30227055414613
# RUN  3 , total integrated cost =  177.30227055414613
# Control only changes marginally.
# RUN  3 , total integrated cost =  177.30227055414613
# Improved over  3  iterations in  1.5301898939651437  seconds by  1.9652323146601702e-07  percent.
# cost splitting :  1.7763357175645196e-05 [1.37763067 2.17398241]
# set cost params:  0.05 110.89155372504085 0.0
# interpolate adjoint :  True True True
# initial cost =  393.84389360265055
# RUN  0 , total integrated cost =  393.84389360265055
# Gradient descend method:  None
# RUN  1 , total integrated cost =  393.8438931088831
# RUN  2 , total integrated cost =  393.84389310835957
# RUN  3 , total integrated cost =  393.84389310835957
# Control only changes marginally.
# RUN  3 , total integrated cost =  393.84389310835957
# Improved over  3  iterations in  1.773509938037023  seconds by  1.255043002856837e-07  percent.
# cost splitting :  3.945589045704729e-05 [1.37763065 2.17398242]
# set cost params:  0.05 149.46780051314653 0.0
# interpolate adjoint :  True True True
# initial cost =  530.8517952440352
# RUN  0 , total integrated cost =  530.8517952440352
# Gradient descend method:  None
# RUN  1 , total integrated cost =  530.8517951372476
# RUN  2 , total integrated cost =  530.8517951370934
# RUN  3 , total integrated cost =  530.8517951370934
# Control only changes marginally.
# RUN  3 , total integrated cost =  530.8517951370934
# Improved over  3  iterations in  1.564812389027793  seconds by  2.0145321855125076e-08  percent.
# cost splitting :  5.2884385022185775e-05 [1.37763065 2.17398242]
# set cost params:  0.05 20.72233139304095 0.0
# interpolate adjoint :  True True True
# initial cost =  73.59770547292668
# RUN  0 , total integrated cost =  73.59770547292668
# Gradient descend method:  None
# RUN  1 , total integrated cost =  73.59770392658083
# RUN  2 , total integrated cost =  73.59770392510079
# RUN  3 , total integrated cost =  73.59770392510079
# Control only changes marginally.
# RUN  3 , total integrated cost =  73.59770392510079
# Improved over  3  iterations in  1.466242850990966  seconds by  2.103089869365249e-06  percent.
# cost splitting :  7.4683890006952026e-06 [1.37763066 2.17398244]
# set cost params:  0.05 164.71335282090172 0.0
# interpolate adjoint :  True True True
# initial cost =  584.9981013104223
# RUN  0 , total integrated cost =  584.9981013104223
# Gradient descend method:  None
# RUN  1 , total integrated cost =  584.9980978198266
# RUN  2 , total integrated cost =  584.998097815798
# RUN  3 , total integrated cost =  584.9980978157947
# RUN  4 , total integrated cost =  584.9980978157947
# Control only changes marginally.
# RUN  4 , total integrated cost =  584.9980978157947
# Improved over  4  iterations in  1.667013596976176  seconds by  5.973741679099476e-07  percent.
# cost splitting :  5.814806607767676e-05 [1.37763062 2.17398244]
# set cost params:  0.05 8.146918340866648 0.0
# interpolate adjoint :  True True True
# initial cost =  28.93470447931186
# RUN  0 , total integrated cost =  28.93470447931186
# Gradient descend method:  None
# RUN  1 , total integrated cost =  28.934702162334073
# RUN  2 , total integrated cost =  28.934702161873734
# RUN  3 , total integrated cost =  28.93470216187264
# RUN  4 , total integrated cost =  28.93470216187264
# Control only changes marginally.
# RUN  4 , total integrated cost =  28.93470216187264
# Improved over  4  iterations in  1.441834351979196  seconds by  8.009203014580635e-06  percent.
# cost splitting :  3.4239519714834836e-06 [1.37763064 2.17398247]
# set cost params:  0.05 127.53496143114002 0.0
# interpolate adjoint :  True True True
# initial cost =  452.9548412540547
# RUN  0 , total integrated cost =  452.9548412540547
# Gradient descend method:  None
# RUN  1 , total integrated cost =  452.95483735386966
# RUN  2 , total integrated cost =  452.95483735119615
# RUN  3 , total integrated cost =  452.95483735119615
# Control only changes marginally.
# RUN  3 , total integrated cost =  452.95483735119615
# Improved over  3  iterations in  1.538920468010474  seconds by  8.616440823061566e-07  percent.
# cost splitting :  4.52894711052266e-05 [1.37763059 2.17398247]
# set cost params:  0.05 35.321326227339505 0.0
# interpolate adjoint :  True True True
# initial cost =  125.44768591776884
# RUN  0 , total integrated cost =  125.44768591776884
# Gradient descend method:  None
# RUN  1 , total integrated cost =  125.44768508821475
# RUN  2 , total integrated cost =  125.4476850878553
# RUN  3 , total integrated cost =  125.44768508785403
# RUN  4 , total integrated cost =  125.44768508785403
# Control only changes marginally.
# RUN  4 , total integrated cost =  125.44768508785403
# Improved over  4  iterations in  1.457412766001653  seconds by  6.615624670303077e-07  percent.
# cost splitting :  1.2568315773987556e-05 [1.37763059 2.17398249]
# set cost params:  0.05 37.62564986055189 0.0
# interpolate adjoint :  True True True
# initial cost =  133.63175105896352
# RUN  0 , total integrated cost =  133.63175105896352
# Gradient descend method:  None
# RUN  1 , total integrated cost =  133.63175105760251
# RUN  2 , total integrated cost =  133.63175105759797
# RUN  3 , total integrated cost =  133.63175105759797
# Control only changes marginally.
# RUN  3 , total integrated cost =  133.63175105759797
# Improved over  3  iterations in  1.243034876009915  seconds by  1.0218741408607457e-09  percent.
# cost splitting :  1.3377422021034095e-05 [1.37763059 2.1739825 ]
# set cost params:  0.05 152.83172734141496 0.0
# interpolate adjoint :  True True True
# initial cost =  542.7991633480066
# RUN  0 , total integrated cost =  542.7991633480066
# Gradient descend method:  None
# RUN  1 , total integrated cost =  542.7991615796233
# RUN  2 , total integrated cost =  542.7991615785016
# RUN  3 , total integrated cost =  542.7991615785016
# Control only changes marginally.
# RUN  3 , total integrated cost =  542.7991615785016
# Improved over  3  iterations in  1.4175689160474576  seconds by  3.2599625399143406e-07  percent.
# cost splitting :  5.408070845544784e-05 [1.37763056 2.1739825 ]
# set cost params:  0.05 39.59911895888725 0.0
# interpolate adjoint :  True True True
# initial cost =  140.64075078010202
# RUN  0 , total integrated cost =  140.64075078010202
# Gradient descend method:  None
# RUN  1 , total integrated cost =  140.64074972877157
# RUN  2 , total integrated cost =  140.64074972839714
# RUN  3 , total integrated cost =  140.64074972839714
# Control only changes marginally.
# RUN  3 , total integrated cost =  140.64074972839714
# Improved over  3  iterations in  1.5675983460387215  seconds by  7.477952692624967e-07  percent.
# cost splitting :  1.4086290331709371e-05 [1.37763056 2.17398252]
# set cost params:  0.05 176.260279987354 0.0
# interpolate adjoint :  True True True
# initial cost =  626.0083173629032
# RUN  0 , total integrated cost =  626.0083173629032
# Gradient descend method:  None
# RUN  1 , total integrated cost =  626.0083151103395
# RUN  2 , total integrated cost =  626.0083151100704
# RUN  3 , total integrated cost =  626.0083151100704
# Control only changes marginally.
# RUN  3 , total integrated cost =  626.0083151100704
# Improved over  3  iterations in  1.5919101070030592  seconds by  3.598726721065759e-07  percent.
# cost splitting :  6.209805073123412e-05 [1.37763055 2.17398251]
# set cost params:  0.05 142.3316474878156 0.0
# interpolate adjoint :  True True True
# initial cost =  505.5069408855231
# RUN  0 , total integrated cost =  505.5069408855231
# Gradient descend method:  None
# RUN  1 , total integrated cost =  505.5069408257812
# RUN  2 , total integrated cost =  505.5069408257107
# RUN  3 , total integrated cost =  505.5069408257079
# RUN  4 , total integrated cost =  505.5069408257079
# Control only changes marginally.
# RUN  4 , total integrated cost =  505.5069408257079
# Improved over  4  iterations in  1.9998528999858536  seconds by  1.1832710811177094e-08  percent.
# cost splitting :  5.04311761770356e-05 [1.37763055 2.17398251]
# set cost params:  0.05 68.69623877651512 0.0
# interpolate adjoint :  True True True
# initial cost =  243.98246144658196
# RUN  0 , total integrated cost =  243.98246144658196
# Gradient descend method:  None
# RUN  1 , total integrated cost =  243.982461032696
# RUN  2 , total integrated cost =  243.98246103269034
# RUN  3 , total integrated cost =  243.98246103268716
# RUN  4 , total integrated cost =  243.98246103268716
# Control only changes marginally.
# RUN  4 , total integrated cost =  243.98246103268716
# Improved over  4  iterations in  2.3729988349950872  seconds by  1.696412113005863e-07  percent.
# cost splitting :  2.4477586822499684e-05 [1.37763055 2.17398252]
# set cost params:  0.05 134.85823594268683 0.0
# interpolate adjoint :  True True True
# initial cost =  478.9642752042149
# RUN  0 , total integrated cost =  478.9642752042149
# Gradient descend method:  None
# RUN  1 , total integrated cost =  478.9642747612291
# RUN  2 , total integrated cost =  478.9642747611543
# RUN  3 , total integrated cost =  478.9642747610877
# RUN  4 , total integrated cost =  478.9642747610877
# Control only changes marginally.
# RUN  4 , total integrated cost =  478.9642747610877
# Improved over  4  iterations in  2.006612083991058  seconds by  9.251779431451723e-08  percent.
# cost splitting :  4.782511530965413e-05 [1.37763054 2.17398252]
# set cost params:  0.05 159.6754693165555 0.0
# interpolate adjoint :  True True True
# initial cost =  567.1054849886834
# RUN  0 , total integrated cost =  567.1054849886834
# Gradient descend method:  None
# RUN  1 , total integrated cost =  567.1054849504276
# RUN  2 , total integrated cost =  567.1054849504189
# RUN  3 , total integrated cost =  567.1054849504189
# Control only changes marginally.
# RUN  3 , total integrated cost =  567.1054849504189
# Improved over  3  iterations in  1.586754916002974  seconds by  6.747342240487342e-09  percent.
# cost splitting :  5.645840215387163e-05 [1.37763054 2.17398252]
# set cost params:  0.05 144.85008880516554 0.0
# interpolate adjoint :  True True True
# initial cost =  514.451469912156
# RUN  0 , total integrated cost =  514.451469912156
# Gradient descend method:  None
# RUN  1 , total integrated cost =  514.4514698998266
# RUN  2 , total integrated cost =  514.4514698998089
# RUN  3 , total integrated cost =  514.4514698998008
# RUN  4 , total integrated cost =  514.4514698998008
# Control only changes marginally.
# RUN  4 , total integrated cost =  514.4514698998008
# Improved over  4  iterations in  1.9687759969965555  seconds by  2.4016060251597082e-09  percent.
# cost splitting :  5.1294554340677115e-05 [1.37763054 2.17398253]
# set cost params:  0.05 56.03605078543447 0.0
# interpolate adjoint :  True True True
# initial cost =  199.01837243956703
# RUN  0 , total integrated cost =  199.01837243956703
# Gradient descend method:  None
# RUN  1 , total integrated cost =  199.01837181433723
# RUN  2 , total integrated cost =  199.018371814303
# RUN  3 , total integrated cost =  199.0183718143019
# RUN  4 , total integrated cost =  199.0183718143019
# Control only changes marginally.
# RUN  4 , total integrated cost =  199.0183718143019
# Improved over  4  iterations in  2.0370033779763617  seconds by  3.1417457080351596e-07  percent.
# cost splitting :  1.9981128645895955e-05 [1.37763054 2.17398254]
# set cost params:  0.05 128.87109471096016 0.0
# interpolate adjoint :  True True True
# initial cost =  457.70026636499335
# RUN  0 , total integrated cost =  457.70026636499335
# Gradient descend method:  None
# RUN  1 , total integrated cost =  457.70026574962054
# RUN  2 , total integrated cost =  457.7002657494208
# RUN  3 , total integrated cost =  457.7002657494174
# RUN  4 , total integrated cost =  457.7002657494174
# Control only changes marginally.
# RUN  4 , total integrated cost =  457.7002657494174
# Improved over  4  iterations in  1.957565602962859  seconds by  1.344932485380923e-07  percent.
# cost splitting :  4.5814928230656854e-05 [1.37763052 2.17398254]
# set cost params:  0.05 39.67866660659667 0.0
# interpolate adjoint :  True True True
# initial cost =  140.92327294550753
# RUN  0 , total integrated cost =  140.92327294550753
# Gradient descend method:  None
# RUN  1 , total integrated cost =  140.92327219282046
# RUN  2 , total integrated cost =  140.92327219279673
# RUN  3 , total integrated cost =  140.92327219279673
# Control only changes marginally.
# RUN  3 , total integrated cost =  140.92327219279673
# Improved over  3  iterations in  1.6984227229841053  seconds by  5.341280910897694e-07  percent.
# cost splitting :  1.4107037820814711e-05 [1.37763053 2.17398256]
# set cost params:  0.05 4.357590336511791 0.0
# interpolate adjoint :  True True True
# initial cost =  15.47647556051324
# RUN  0 , total integrated cost =  15.47647556051324
# Gradient descend method:  None
# RUN  1 , total integrated cost =  15.476475126219121
# RUN  2 , total integrated cost =  15.476475126153762
# RUN  3 , total integrated cost =  15.476475126153609
# RUN  4 , total integrated cost =  15.476475126153609
# Control only changes marginally.
# RUN  4 , total integrated cost =  15.476475126153609
# Improved over  4  iterations in  1.715027752041351  seconds by  2.8065797579301943e-06  percent.
# cost splitting :  2.42409074481101e-06 [1.37763055 2.17398257]
# set cost params:  0.05 85.33682670219522 0.0
# interpolate adjoint :  True True True
# initial cost =  303.08339334246966
# RUN  0 , total integrated cost =  303.08339334246966
# Gradient descend method:  None
# RUN  1 , total integrated cost =  303.0833906379529
# RUN  2 , total integrated cost =  303.08339063710434
# RUN  3 , total integrated cost =  303.08339063710434
# Control only changes marginally.
# RUN  3 , total integrated cost =  303.08339063710434
# Improved over  3  iterations in  1.5920044610393234  seconds by  8.92614167469219e-07  percent.
# cost splitting :  3.0409874626341437e-05 [1.3776305  2.17398257]
# set cost params:  0.05 35.645210849665624 0.0
# interpolate adjoint :  True True True
# initial cost =  126.59799827744386
# RUN  0 , total integrated cost =  126.59799827744386
# Gradient descend method:  None
# RUN  1 , total integrated cost =  126.59799794624705
# RUN  2 , total integrated cost =  126.59799794619843
# RUN  3 , total integrated cost =  126.59799794619774
# RUN  4 , total integrated cost =  126.59799794619774
# Control only changes marginally.
# RUN  4 , total integrated cost =  126.59799794619774
# Improved over  4  iterations in  1.8289109150064178  seconds by  2.616519481080104e-07  percent.
# cost splitting :  1.269360446438043e-05 [1.3776305  2.17398259]
# set cost params:  0.05 55.8880315573178 0.0
# interpolate adjoint :  True True True
# initial cost =  198.49266487166756
# RUN  0 , total integrated cost =  198.49266487166756
# Gradient descend method:  None
# RUN  1 , total integrated cost =  198.49266478420273
# RUN  2 , total integrated cost =  198.49266478419642
# RUN  3 , total integrated cost =  198.49266478419642
# Control only changes marginally.
# RUN  3 , total integrated cost =  198.49266478419642
# Improved over  3  iterations in  1.8150223080301657  seconds by  4.406768994158483e-08  percent.
# cost splitting :  1.9923036463855487e-05 [1.37763049 2.17398259]
# set cost params:  0.05 7.779565612205698 0.0
# interpolate adjoint :  True True True
# initial cost =  27.630007966372215
# RUN  0 , total integrated cost =  27.630007966372215
# Gradient descend method:  None
# RUN  1 , total integrated cost =  27.630007392862442
# RUN  2 , total integrated cost =  27.63000739274984
# RUN  3 , total integrated cost =  27.63000739274984
# Control only changes marginally.
# RUN  3 , total integrated cost =  27.63000739274984
# Improved over  3  iterations in  1.2669395279954188  seconds by  2.0760847263545656e-06  percent.
# cost splitting :  3.3215183960017124e-06 [1.37763049 2.17398262]
# set cost params:  0.05 17.912784099474717 0.0
# interpolate adjoint :  True True True
# initial cost =  63.61927902938655
# RUN  0 , total integrated cost =  63.61927902938655
# Gradient descend method:  None
# RUN  1 , total integrated cost =  63.61927895590298
# RUN  2 , total integrated cost =  63.61927895590139
# RUN  3 , total integrated cost =  63.619278955900825
# RUN  4 , total integrated cost =  63.619278955900825
# Control only changes marginally.
# RUN  4 , total integrated cost =  63.619278955900825
# Improved over  4  iterations in  1.7329180630040355  seconds by  1.1550856982012192e-07  percent.
# cost splitting :  6.517149029948465e-06 [1.37763047 2.17398262]
# set cost params:  0.05 83.34458452834731 0.0
# interpolate adjoint :  True True True
# initial cost =  296.00771838737217
# RUN  0 , total integrated cost =  296.00771838737217
# Gradient descend method:  None
# RUN  1 , total integrated cost =  296.0077172885308
# RUN  2 , total integrated cost =  296.00771728851316
# RUN  3 , total integrated cost =  296.00771728851316
# Control only changes marginally.
# RUN  3 , total integrated cost =  296.00771728851316
# Improved over  3  iterations in  1.3691977669950575  seconds by  3.712264771138507e-07  percent.
# cost splitting :  2.973662001268546e-05 [1.37763046 2.17398261]
# set cost params:  0.05 144.49051800004733 0.0
# interpolate adjoint :  True True True
# initial cost =  513.1744138405052
# RUN  0 , total integrated cost =  513.1744138405052
# Gradient descend method:  None
# RUN  1 , total integrated cost =  513.1744135154004
# RUN  2 , total integrated cost =  513.1744135153511
# RUN  3 , total integrated cost =  513.1744135153511
# Control only changes marginally.
# RUN  3 , total integrated cost =  513.1744135153511
# Improved over  3  iterations in  1.4190151049988344  seconds by  6.336129843020899e-08  percent.
# cost splitting :  5.116291690557174e-05 [1.37763045 2.17398261]
# set cost params:  0.05 10.761971574517121 0.0
# interpolate adjoint :  True True True
# initial cost =  38.22236136711093
# RUN  0 , total integrated cost =  38.22236136711093
# Gradient descend method:  None
# RUN  1 , total integrated cost =  38.222359503323766
# RUN  2 , total integrated cost =  38.222359503323766
# Control only changes marginally.
# RUN  2 , total integrated cost =  38.222359503323766
# Improved over  2  iterations in  0.9265022350009531  seconds by  4.8761695836674335e-06  percent.
# cost splitting :  4.206703026504058e-06 [1.37763047 2.17398263]
# set cost params:  0.05 168.5790516152761 0.0
# interpolate adjoint :  True True True
# initial cost =  598.7275693638974
# RUN  0 , total integrated cost =  598.7275693638974
# Gradient descend method:  None
# RUN  1 , total integrated cost =  598.7275640898226
# RUN  2 , total integrated cost =  598.72756408946
# RUN  3 , total integrated cost =  598.7275640894563
# RUN  4 , total integrated cost =  598.7275640894563
# Control only changes marginally.
# RUN  4 , total integrated cost =  598.7275640894563
# Improved over  4  iterations in  1.9354773960076272  seconds by  8.809417266775199e-07  percent.
# cost splitting :  5.950321781168171e-05 [1.37763042 2.17398263]
# set cost params:  0.05 137.0592028019077 0.0
# interpolate adjoint :  True True True
# initial cost =  486.7812574404674
# RUN  0 , total integrated cost =  486.7812574404674
# Gradient descend method:  None
# RUN  1 , total integrated cost =  486.78125738617894
# RUN  2 , total integrated cost =  486.78125738617666
# RUN  3 , total integrated cost =  486.78125738617666
# Control only changes marginally.
# RUN  3 , total integrated cost =  486.78125738617666
# Improved over  3  iterations in  1.6085768039920367  seconds by  1.1153005630148982e-08  percent.
# cost splitting :  4.8640905019765376e-05 [1.37763042 2.17398264]
# set cost params:  0.05 119.162738440766 0.0
# interpolate adjoint :  True True True
# initial cost =  423.2199407954967
# RUN  0 , total integrated cost =  423.2199407954967
# Gradient descend method:  None
# RUN  1 , total integrated cost =  423.2199407740478
# RUN  2 , total integrated cost =  423.2199407739891
# RUN  3 , total integrated cost =  423.2199407739891
# Control only changes marginally.
# RUN  3 , total integrated cost =  423.2199407739891
# Improved over  3  iterations in  1.4734486870002002  seconds by  5.081901122139243e-09  percent.
# cost splitting :  4.235431119284136e-05 [1.37763042 2.17398264]
# set cost params:  0.05 127.0487987696712 0.0
# interpolate adjoint :  True True True
# initial cost =  451.2281756661223
# RUN  0 , total integrated cost =  451.2281756661223
# Gradient descend method:  None
# RUN  1 , total integrated cost =  451.22817566142396
# RUN  2 , total integrated cost =  451.2281756614162
# RUN  3 , total integrated cost =  451.2281756614162
# Control only changes marginally.
# RUN  3 , total integrated cost =  451.2281756614162
# Improved over  3  iterations in  2.2197342390427366  seconds by  1.0429488384033903e-09  percent.
# cost splitting :  4.510216452541177e-05 [1.37763042 2.17398264]
# set cost params:  0.05 77.02279384079613 0.0
# interpolate adjoint :  True True True
# initial cost =  273.5551630436833
# RUN  0 , total integrated cost =  273.5551630436833
# Gradient descend method:  None
# RUN  1 , total integrated cost =  273.55516284204407
# RUN  2 , total integrated cost =  273.55516284202344
# RUN  3 , total integrated cost =  273.55516284202344
# Control only changes marginally.
# RUN  3 , total integrated cost =  273.55516284202344
# Improved over  3  iterations in  2.3481914720032364  seconds by  7.371816934664821e-08  percent.
# cost splitting :  2.7445912918679883e-05 [1.37763042 2.17398265]
# set cost params:  0.05 92.47650400206231 0.0
# interpolate adjoint :  True True True
# initial cost =  328.4407618662509
# RUN  0 , total integrated cost =  328.4407618662509
# Gradient descend method:  None
# RUN  1 , total integrated cost =  328.44076183978893
# RUN  2 , total integrated cost =  328.4407618397452
# RUN  3 , total integrated cost =  328.4407618397452
# Control only changes marginally.
# RUN  3 , total integrated cost =  328.4407618397452
# Improved over  3  iterations in  1.4677909029996954  seconds by  8.07015965165192e-09  percent.
# cost splitting :  3.296206366550693e-05 [1.37763042 2.17398265]
# set cost params:  0.05 0.027834517799588926 0.0
# interpolate adjoint :  True True True
# initial cost =  0.09885908529026537
# RUN  0 , total integrated cost =  0.09885908529026537
# Gradient descend method:  None
# RUN  1 , total integrated cost =  0.09885752740393386
# RUN  2 , total integrated cost =  0.09885752740362942
# RUN  3 , total integrated cost =  0.09885752740342596
# RUN  4 , total integrated cost =  0.09885752740321206
# RUN  5 , total integrated cost =  0.09885752740292184
# RUN  6 , total integrated cost =  0.09885752740262319
# RUN  7 , total integrated cost =  0.09885752740241521
# RUN  8 , total integrated cost =  0.09885752740220553
# RUN  9 , total integrated cost =  0.09885752740191014
# RUN  10 , total integrated cost =  0.09885752740161685
# RUN  11 , total integrated cost =  0.09885752740140544
# RUN  12 , total integrated cost =  0.09885752740119952
# RUN  13 , total integrated cost =  0.09885752740089751
# RUN  14 , total integrated cost =  0.09885752740061066
# RUN  15 , total integrated cost =  0.09885752740039484
# RUN  16 , total integrated cost =  0.09885752740019299
# RUN  17 , total integrated cost =  0.09885752739988574
# RUN  18 , total integrated cost =  0.09885752739960432
# RUN  19 , total integrated cost =  0.09885752739938466
# RUN  20 , total integrated cost =  0.09885752739918685
# RUN  30 , total integrated cost =  0.09885752739632817
# RUN  40 , total integrated cost =  0.09885752739379033
# RUN  50 , total integrated cost =  0.09885752739093166
# RUN  60 , total integrated cost =  0.09885752738839396
# RUN  70 , total integrated cost =  0.09885752738575028
# RUN  80 , total integrated cost =  0.09885752738332071
# RUN  90 , total integrated cost =  0.09885752738035491
# RUN  100 , total integrated cost =  0.09885752737788216
# RUN  100 , total integrated cost =  0.09885752737788216
# Improved over  100  iterations in  28.330756675975863  seconds by  0.0015758919664676796  percent.
# cost splitting :  1.7664683711814674e-06 [1.37763045 2.17398269]
# set cost params:  0.05 131.6618220365986 0.0
# interpolate adjoint :  True True True
# initial cost =  467.6118567584223
# RUN  0 , total integrated cost =  467.6118567584223
# Gradient descend method:  None
# RUN  1 , total integrated cost =  467.6118493483324
# RUN  2 , total integrated cost =  467.611849347267
# RUN  3 , total integrated cost =  467.611849347267
# Control only changes marginally.
# RUN  3 , total integrated cost =  467.611849347267
# Improved over  3  iterations in  1.2070308290421963  seconds by  1.584894633310796e-06  percent.
# cost splitting :  4.666452680563924e-05 [1.37763037 2.17398269]
# set cost params:  0.05 138.16741829846717 0.0
# interpolate adjoint :  True True True
# initial cost =  490.71721001206515
# RUN  0 , total integrated cost =  490.71721001206515
# Gradient descend method:  None
# RUN  1 , total integrated cost =  490.71721000896025
# RUN  2 , total integrated cost =  490.71721000895553
# RUN  3 , total integrated cost =  490.71721000895553
# Control only changes marginally.
# RUN  3 , total integrated cost =  490.71721000895553
# Improved over  3  iterations in  1.5167995940428227  seconds by  6.336904334602877e-10  percent.
# cost splitting :  4.9036170717004555e-05 [1.37763037 2.17398269]
# set cost params:  0.05 128.09657360162504 0.0
# interpolate adjoint :  True True True
# initial cost =  454.9494664393346
# RUN  0 , total integrated cost =  454.9494664393346
# Gradient descend method:  None
# RUN  1 , total integrated cost =  454.9494664326603
# RUN  2 , total integrated cost =  454.9494664326603
# Control only changes marginally.
# RUN  2 , total integrated cost =  454.9494664326603
# Improved over  2  iterations in  1.213767287961673  seconds by  1.4670433756691637e-09  percent.
# cost splitting :  4.549896471089395e-05 [1.37763037 2.17398269]
# set cost params:  0.05 106.55633208749802 0.0
# interpolate adjoint :  True True True
# initial cost =  378.446863286095
# RUN  0 , total integrated cost =  378.446863286095
# Gradient descend method:  None
# RUN  1 , total integrated cost =  378.44686325237353
# RUN  2 , total integrated cost =  378.4468632523182
# RUN  3 , total integrated cost =  378.4468632523182
# Control only changes marginally.
# RUN  3 , total integrated cost =  378.4468632523182
# Improved over  3  iterations in  1.3378517290111631  seconds by  8.925098882173188e-09  percent.
# cost splitting :  3.789908003322357e-05 [1.37763037 2.1739827 ]
# set cost params:  0.05 98.96244581887707 0.0
# interpolate adjoint :  True True True
# initial cost =  351.4763175553747
# RUN  0 , total integrated cost =  351.4763175553747
# Gradient descend method:  None
# RUN  1 , total integrated cost =  351.4763175506038
# RUN  2 , total integrated cost =  351.4763175505976
# RUN  3 , total integrated cost =  351.4763175505976
# Control only changes marginally.
# RUN  3 , total integrated cost =  351.4763175505976
# Improved over  3  iterations in  1.1046434110030532  seconds by  1.3591403558166348e-09  percent.
# cost splitting :  3.526354323610125e-05 [1.37763037 2.1739827 ]
# set cost params:  0.05 82.51528612820915 0.0
# interpolate adjoint :  True True True
# initial cost =  293.06237026574996
# RUN  0 , total integrated cost =  293.06237026574996
# Gradient descend method:  None
# RUN  1 , total integrated cost =  293.0623702399818
# RUN  2 , total integrated cost =  293.0623702399709
# RUN  3 , total integrated cost =  293.0623702399709
# Control only changes marginally.
# RUN  3 , total integrated cost =  293.0623702399709
# Improved over  3  iterations in  1.1945013359654695  seconds by  8.796448014436464e-09  percent.
# cost splitting :  2.940216927598283e-05 [1.37763037 2.1739827 ]
# set cost params:  0.05 29.451954025053766 0.0
# interpolate adjoint :  True True True
# initial cost =  104.60194635184217
# RUN  0 , total integrated cost =  104.60194635184217
# Gradient descend method:  None
# RUN  1 , total integrated cost =  104.60194594674613
# RUN  2 , total integrated cost =  104.6019459467084
# RUN  3 , total integrated cost =  104.60194594670799
# RUN  4 , total integrated cost =  104.60194594670799
# Control only changes marginally.
# RUN  4 , total integrated cost =  104.60194594670799
# Improved over  4  iterations in  1.413385015039239  seconds by  3.873103793239352e-07  percent.
# cost splitting :  1.0484782330273724e-05 [1.37763037 2.17398272]
# set cost params:  0.05 23.90292630761739 0.0
# interpolate adjoint :  True True True
# initial cost =  84.89394647226645
# RUN  0 , total integrated cost =  84.89394647226645
# Gradient descend method:  None
# RUN  1 , total integrated cost =  84.89394646259476
# RUN  2 , total integrated cost =  84.89394646259218
# RUN  3 , total integrated cost =  84.89394646259218
# Control only changes marginally.
# RUN  3 , total integrated cost =  84.89394646259218
# Improved over  3  iterations in  1.070011502946727  seconds by  1.1395712817829917e-08  percent.
# cost splitting :  8.569586662128084e-06 [1.37763037 2.17398272]
# set cost params:  0.05 58.14022276958638 0.0
# interpolate adjoint :  True True True
# initial cost =  206.49157684436048
# RUN  0 , total integrated cost =  206.49157684436048
# Gradient descend method:  None
# RUN  1 , total integrated cost =  206.49157653706644
# RUN  2 , total integrated cost =  206.49157653704967
# RUN  3 , total integrated cost =  206.49157653704881
# RUN  4 , total integrated cost =  206.49157653704881
# Control only changes marginally.
# RUN  4 , total integrated cost =  206.49157653704881
# Improved over  4  iterations in  1.4092619480215944  seconds by  1.4882527921145083e-07  percent.
# cost splitting :  2.0698017338822825e-05 [1.37763036 2.17398271]
# set cost params:  0.05 98.9566018976005 0.0
# interpolate adjoint :  True True True
# initial cost =  351.4555624137189
# RUN  0 , total integrated cost =  351.4555624137189
# Gradient descend method:  None
# RUN  1 , total integrated cost =  351.45556220125127
# RUN  2 , total integrated cost =  351.45556220097853
# RUN  3 , total integrated cost =  351.45556220097853
# Control only changes marginally.
# RUN  3 , total integrated cost =  351.45556220097853
# Improved over  3  iterations in  1.1278927650419064  seconds by  6.053122092453123e-08  percent.
# cost splitting :  3.527951968501226e-05 [1.37763035 2.17398271]
# set cost params:  0.05 112.93423182455633 0.0
# interpolate adjoint :  True True True
# initial cost =  401.0986953053523
# RUN  0 , total integrated cost =  401.0986953053523
# Gradient descend method:  None
# RUN  1 , total integrated cost =  401.098695288618
# RUN  2 , total integrated cost =  401.09869528855273
# RUN  3 , total integrated cost =  401.09869528855086
# RUN  4 , total integrated cost =  401.09869528855086
# Control only changes marginally.
# RUN  4 , total integrated cost =  401.09869528855086
# Improved over  4  iterations in  1.435768826981075  seconds by  4.1888483792718034e-09  percent.
# cost splitting :  4.021203034910714e-05 [1.37763035 2.17398271]
# set cost params:  0.05 75.85457501691405 0.0
# interpolate adjoint :  True True True
# initial cost =  269.4061017103272
# RUN  0 , total integrated cost =  269.4061017103272
# Gradient descend method:  None
# RUN  1 , total integrated cost =  269.40610158798034
# RUN  2 , total integrated cost =  269.40610158797284
# RUN  3 , total integrated cost =  269.4061015879717
# RUN  4 , total integrated cost =  269.4061015879717
# Control only changes marginally.
# RUN  4 , total integrated cost =  269.4061015879717
# Improved over  4  iterations in  1.4664696520194411  seconds by  4.541675480140839e-08  percent.
# cost splitting :  2.702812432258434e-05 [1.37763035 2.17398272]
# set cost params:  0.05 148.4100486064891 0.0
# interpolate adjoint :  True True True
# initial cost =  527.0950700678036
# RUN  0 , total integrated cost =  527.0950700678036
# Gradient descend method:  None
# RUN  1 , total integrated cost =  527.0950695864339
# RUN  2 , total integrated cost =  527.0950695861546
# RUN  3 , total integrated cost =  527.0950695861546
# Control only changes marginally.
# RUN  3 , total integrated cost =  527.0950695861546
# Improved over  3  iterations in  1.1513061570003629  seconds by  9.137799850122974e-08  percent.
# cost splitting :  5.258581963512108e-05 [1.37763034 2.17398272]
# set cost params:  0.05 134.52756863890934 0.0
# interpolate adjoint :  True True True
# initial cost =  477.7898724196174
# RUN  0 , total integrated cost =  477.7898724196174
# Gradient descend method:  None
# RUN  1 , total integrated cost =  477.78987240789104
# RUN  2 , total integrated cost =  477.78987240782504
# RUN  3 , total integrated cost =  477.78987240782266
# RUN  4 , total integrated cost =  477.78987240782266
# Control only changes marginally.
# RUN  4 , total integrated cost =  477.78987240782266
# Improved over  4  iterations in  1.400036241975613  seconds by  2.4685959942871705e-09  percent.
# cost splitting :  4.772081963652242e-05 [1.37763034 2.17398272]
# set cost params:  0.05 110.41780121943498 0.0
# interpolate adjoint :  True True True
# initial cost =  392.1613075110185
# RUN  0 , total integrated cost =  392.1613075110185
# Gradient descend method:  None
# RUN  1 , total integrated cost =  392.1613074708739
# RUN  2 , total integrated cost =  392.16130747086464
# RUN  3 , total integrated cost =  392.1613074708616
# RUN  4 , total integrated cost =  392.1613074708616
# Control only changes marginally.
# RUN  4 , total integrated cost =  392.1613074708616
# Improved over  4  iterations in  1.4772562609869055  seconds by  1.0239901371278393e-08  percent.
# cost splitting :  3.927836664193103e-05 [1.37763034 2.17398273]
# set cost params:  0.05 54.073419885393356 0.0
# interpolate adjoint :  True True True
# initial cost =  192.04786654092635
# RUN  0 , total integrated cost =  192.04786654092635
# Gradient descend method:  None
# RUN  1 , total integrated cost =  192.04786622664582
# RUN  2 , total integrated cost =  192.04786622659796
# RUN  3 , total integrated cost =  192.04786622659796
# Control only changes marginally.
# RUN  3 , total integrated cost =  192.04786622659796
# Improved over  3  iterations in  1.0913291099714115  seconds by  1.6367189914490154e-07  percent.
# cost splitting :  1.9238694245485848e-05 [1.37763034 2.17398274]
# set cost params:  0.05 85.39980085495588 0.0
# interpolate adjoint :  True True True
# initial cost =  303.3070505804462
# RUN  0 , total integrated cost =  303.3070505804462
# Gradient descend method:  None
# RUN  1 , total integrated cost =  303.30705044124204
# RUN  2 , total integrated cost =  303.3070504412199
# RUN  3 , total integrated cost =  303.3070504412114
# RUN  4 , total integrated cost =  303.3070504412114
# Control only changes marginally.
# RUN  4 , total integrated cost =  303.3070504412114
# Improved over  4  iterations in  1.4207426009816118  seconds by  4.5905551360192476e-08  percent.
# cost splitting :  3.0468592162050467e-05 [1.37763033 2.17398274]
# set cost params:  0.05 118.6626628206022 0.0
# interpolate adjoint :  True True True
# initial cost =  421.4438657541065
# RUN  0 , total integrated cost =  421.4438657541065
# Gradient descend method:  None
# RUN  1 , total integrated cost =  421.4438656516018
# RUN  2 , total integrated cost =  421.44386565150216
# RUN  3 , total integrated cost =  421.44386565150216
# Control only changes marginally.
# RUN  3 , total integrated cost =  421.44386565150216
# Improved over  3  iterations in  1.1529163509840146  seconds by  2.4345908400391636e-08  percent.
# cost splitting :  4.2169918276008214e-05 [1.37763032 2.17398274]
# set cost params:  0.05 50.57705871919939 0.0
# interpolate adjoint :  True True True
# initial cost =  179.63014462001422
# RUN  0 , total integrated cost =  179.63014462001422
# Gradient descend method:  None
# RUN  1 , total integrated cost =  179.63014417853736
# RUN  2 , total integrated cost =  179.63014417853535
# RUN  3 , total integrated cost =  179.63014417853535
# Control only changes marginally.
# RUN  3 , total integrated cost =  179.63014417853535
# Improved over  3  iterations in  1.1389170730253682  seconds by  2.4577103374667786e-07  percent.
# cost splitting :  1.8002754767209058e-05 [1.37763032 2.17398276]
# set cost params:  0.05 153.4827593745809 0.0
# interpolate adjoint :  True True True
# initial cost =  545.1113765988978
# RUN  0 , total integrated cost =  545.1113765988978
# Gradient descend method:  None
# RUN  1 , total integrated cost =  545.1113753967776
# RUN  2 , total integrated cost =  545.111375396081
# RUN  3 , total integrated cost =  545.111375396081
# Control only changes marginally.
# RUN  3 , total integrated cost =  545.111375396081
# Improved over  3  iterations in  1.22207423299551  seconds by  2.2065522387038072e-07  percent.
# cost splitting :  5.428468613785606e-05 [1.37763031 2.17398275]
# set cost params:  0.05 170.37988737096828 0.0
# interpolate adjoint :  True True True
# initial cost =  605.1234358647881
# RUN  0 , total integrated cost =  605.1234358647881
# Gradient descend method:  None
# RUN  1 , total integrated cost =  605.1234358487563
# RUN  2 , total integrated cost =  605.123435848746
# RUN  3 , total integrated cost =  605.1234358487441
# RUN  4 , total integrated cost =  605.1234358487441
# Control only changes marginally.
# RUN  4 , total integrated cost =  605.1234358487441
# Improved over  4  iterations in  1.563325585972052  seconds by  2.6513617967793834e-09  percent.
# cost splitting :  6.009597644583206e-05 [1.37763031 2.17398275]
# set cost params:  0.05 34.88364444418438 0.0
# interpolate adjoint :  True True True
# initial cost =  123.89321013089626
# RUN  0 , total integrated cost =  123.89321013089626
# Gradient descend method:  None
# RUN  1 , total integrated cost =  123.8932087253556
# RUN  2 , total integrated cost =  123.89320872534647
# RUN  3 , total integrated cost =  123.89320872534647
# Control only changes marginally.
# RUN  3 , total integrated cost =  123.89320872534647
# Improved over  3  iterations in  1.2001956070307642  seconds by  1.1344849326633266e-06  percent.
# cost splitting :  1.2410497122051045e-05 [1.37763031 2.17398277]
# set cost params:  0.05 173.42941660362823 0.0
# interpolate adjoint :  True True True
# initial cost =  615.9541861744693
# RUN  0 , total integrated cost =  615.9541861744693
# Gradient descend method:  None
# RUN  1 , total integrated cost =  615.954183687688
# RUN  2 , total integrated cost =  615.9541836854979
# RUN  3 , total integrated cost =  615.9541836854835
# RUN  4 , total integrated cost =  615.9541836854835
# Control only changes marginally.
# RUN  4 , total integrated cost =  615.9541836854835
# Improved over  4  iterations in  1.4734635779750533  seconds by  4.0408619383924815e-07  percent.
# cost splitting :  6.113796389830729e-05 [1.37763028 2.17398277]
# set cost params:  0.05 121.3671743403611 0.0
# interpolate adjoint :  True True True
# initial cost =  431.0492442411684
# RUN  0 , total integrated cost =  431.0492442411684
# Gradient descend method:  None
# RUN  1 , total integrated cost =  431.0492440907113
# RUN  2 , total integrated cost =  431.04924409068843
# RUN  3 , total integrated cost =  431.04924409068843
# Control only changes marginally.
# RUN  3 , total integrated cost =  431.04924409068843
# Improved over  3  iterations in  1.1904389839619398  seconds by  3.49101583196898e-08  percent.
# ...
# interpolate adjoint :  True True True
# initial cost =  468.50603419657966
# RUN  0 , total integrated cost =  468.50603419657966
# Gradient descend method:  None
# RUN  1 , total integrated cost =  468.506034004968
# RUN  2 , total integrated cost =  468.5060340047659
# RUN  3 , total integrated cost =  468.50603400475933
# RUN  4 , total integrated cost =  468.50603400475933
# Control only changes marginally.
# RUN  4 , total integrated cost =  468.50603400475933
# Improved over  4  iterations in  1.655197613989003  seconds by  4.0942978785096784e-08  percent.
# cost splitting :  4.681844773113494e-05 [1.37762969 2.17398337]
# set cost params:  0.05 95.48325907150463 0.0
# interpolate adjoint :  True True True
# initial cost =  339.1195924388827
# RUN  0 , total integrated cost =  339.1195924388827
# Gradient descend method:  None
# RUN  1 , total integrated cost =  339.1195923413247
# RUN  2 , total integrated cost =  339.1195923412526
# RUN  3 , total integrated cost =  339.1195923412508
# RUN  4 , total integrated cost =  339.1195923412508
# Control only changes marginally.
# RUN  4 , total integrated cost =  339.1195923412508
# Improved over  4  iterations in  1.7396215639892034  seconds by  2.87898274109466e-08  percent.
# cost splitting :  3.401522549307353e-05 [1.37762969 2.17398338]
# set cost params:  0.05 33.23325955472878 0.0
# interpolate adjoint :  True True True
# initial cost =  118.03168060909181
# RUN  0 , total integrated cost =  118.03168060909181
# Gradient descend method:  None
# RUN  1 , total integrated cost =  118.03168012551002
# RUN  2 , total integrated cost =  118.03168012520686
# RUN  3 , total integrated cost =  118.03168012520686
# Control only changes marginally.
# RUN  3 , total integrated cost =  118.03168012520686
# Improved over  3  iterations in  1.5600755359628238  seconds by  4.099619133057786e-07  percent.
# cost splitting :  1.1853070031584473e-05 [1.3776297  2.17398339]
# set cost params:  0.05 69.26810548797971 0.0
# interpolate adjoint :  True True True
# initial cost =  246.0135105019149
# RUN  0 , total integrated cost =  246.0135105019149
# Gradient descend method:  None
# RUN  1 , total integrated cost =  246.01351023771326
# RUN  2 , total integrated cost =  246.01351023766986
# RUN  3 , total integrated cost =  246.01351023766827
# RUN  4 , total integrated cost =  246.01351023766827
# Control only changes marginally.
# RUN  4 , total integrated cost =  246.01351023766827
# Improved over  4  iterations in  1.8004487260477617  seconds by  1.0741143796622055e-07  percent.
# cost splitting :  2.4715224004813186e-05 [1.37762969 2.17398339]
# set cost params:  0.05 12.453384852740868 0.0
# interpolate adjoint :  True True True
# initial cost =  44.229605683447865
# RUN  0 , total integrated cost =  44.229605683447865
# Gradient descend method:  None
# RUN  1 , total integrated cost =  44.22960505483361
# RUN  2 , total integrated cost =  44.229605054797744
# RUN  3 , total integrated cost =  44.229605054797744
# Control only changes marginally.
# RUN  3 , total integrated cost =  44.229605054797744
# Improved over  3  iterations in  1.5071013800334185  seconds by  1.4213333230372882e-06  percent.
# cost splitting :  4.7320964058634725e-06 [1.3776297  2.17398341]
# set cost params:  0.05 79.72277437308556 0.0
# interpolate adjoint :  True True True
# initial cost =  283.14445029794166
# RUN  0 , total integrated cost =  283.14445029794166
# Gradient descend method:  None
# RUN  1 , total integrated cost =  283.14444890964523
# RUN  2 , total integrated cost =  283.1444489096346
# RUN  3 , total integrated cost =  283.1444489096346
# Control only changes marginally.
# RUN  3 , total integrated cost =  283.1444489096346
# Improved over  3  iterations in  1.3906383260036819  seconds by  4.90317603407675e-07  percent.
# cost splitting :  2.843363360529161e-05 [1.37762966 2.17398341]
# set cost params:  0.05 108.88516084898045 0.0
# interpolate adjoint :  True True True
# initial cost =  386.7179618873174
# RUN  0 , total integrated cost =  386.7179618873174
# Gradient descend method:  None
# RUN  1 , total integrated cost =  386.71796180207286
# RUN  2 , total integrated cost =  386.7179618017734
# RUN  3 , total integrated cost =  386.7179618017734
# Control only changes marginally.
# RUN  3 , total integrated cost =  386.7179618017734
# Improved over  3  iterations in  1.584294963045977  seconds by  2.2120516973700433e-08  percent.
# cost splitting :  3.874892445029666e-05 [1.37762966 2.17398341]
# set cost params:  0.05 11.188420804101117 0.0
# interpolate adjoint :  True True True
# initial cost =  39.73694344287919
# RUN  0 , total integrated cost =  39.73694344287919
# Gradient descend method:  None
# RUN  1 , total integrated cost =  39.736942163621066
# RUN  2 , total integrated cost =  39.73694216332297
# RUN  3 , total integrated cost =  39.73694216332297
# Control only changes marginally.
# RUN  3 , total integrated cost =  39.73694216332297
# Improved over  3  iterations in  1.1226982739754021  seconds by  3.2200670290194466e-06  percent.
# cost splitting :  4.337552656258665e-06 [1.37762966 2.17398345]
# set cost params:  0.05 154.6787446145597 0.0
# interpolate adjoint :  True True True
# initial cost =  549.3590565767174
# RUN  0 , total integrated cost =  549.3590565767174
# Gradient descend method:  None
# RUN  1 , total integrated cost =  549.359052042012
# RUN  2 , total integrated cost =  549.3590520412802
# RUN  3 , total integrated cost =  549.3590520412675
# RUN  4 , total integrated cost =  549.3590520412615
# RUN  5 , total integrated cost =  549.3590520412615
# Control only changes marginally.
# RUN  5 , total integrated cost =  549.3590520412615
# Improved over  5  iterations in  1.776731109013781  seconds by  8.255904475618081e-07  percent.
# cost splitting :  5.4723284724845566e-05 [1.37762961 2.17398345]
# set cost params:  0.05 50.40506116961128 0.0
# interpolate adjoint :  True True True
# initial cost =  179.0192762200838
# RUN  0 , total integrated cost =  179.0192762200838
# Gradient descend method:  None
# RUN  1 , total integrated cost =  179.01927538127666
# RUN  2 , total integrated cost =  179.01927538127666
# Control only changes marginally.
# RUN  2 , total integrated cost =  179.01927538127666
# Improved over  2  iterations in  0.7941789769683965  seconds by  4.685568910645088e-07  percent.
# cost splitting :  1.792178477023774e-05 [1.37762961 2.17398347]
# set cost params:  0.05 167.44547616684343 0.0
# interpolate adjoint :  True True True
# initial cost =  594.7015440277802
# RUN  0 , total integrated cost =  594.7015440277802
# Gradient descend method:  None
# RUN  1 , total integrated cost =  594.7015425279772
# RUN  2 , total integrated cost =  594.7015425278153
# RUN  3 , total integrated cost =  594.7015425278116
# RUN  4 , total integrated cost =  594.7015425278116
# Control only changes marginally.
# RUN  4 , total integrated cost =  594.7015425278116
# Improved over  4  iterations in  1.4818608979694545  seconds by  2.5222207966635324e-07  percent.
# cost splitting :  5.917339758920631e-05 [1.37762959 2.17398347]
# set cost params:  0.05 14.105393043647595 0.0
# interpolate adjoint :  True True True
# initial cost =  50.09690107329407
# RUN  0 , total integrated cost =  50.09690107329407
# Gradient descend method:  None
# RUN  1 , total integrated cost =  50.09689898803524
# RUN  2 , total integrated cost =  50.09689898789126
# RUN  3 , total integrated cost =  50.09689898789093
# RUN  4 , total integrated cost =  50.09689898789093
# Control only changes marginally.
# RUN  4 , total integrated cost =  50.09689898789093
# Improved over  4  iterations in  1.4052720349864103  seconds by  4.162738804325272e-06  percent.
# cost splitting :  5.259804431422138e-06 [1.37762959 2.17398351]
# set cost params:  0.05 86.73524884120378 0.0
# interpolate adjoint :  True True True
# initial cost =  308.0500463433227
# RUN  0 , total integrated cost =  308.0500463433227
# Gradient descend method:  None
# RUN  1 , total integrated cost =  308.0500448697519
# RUN  2 , total integrated cost =  308.05004486959075
# RUN  3 , total integrated cost =  308.05004486959075
# Control only changes marginally.
# RUN  3 , total integrated cost =  308.05004486959075
# Improved over  3  iterations in  1.1532633639872074  seconds by  4.784066760521455e-07  percent.
# cost splitting :  3.0898067877503695e-05 [1.37762956 2.17398351]
# set cost params:  0.05 93.31486327280372 0.0
# interpolate adjoint :  True True True
# initial cost =  331.4182894736386
# RUN  0 , total integrated cost =  331.4182894736386
# Gradient descend method:  None
# RUN  1 , total integrated cost =  331.41828946907833
# RUN  2 , total integrated cost =  331.41828946907833
# Control only changes marginally.
# RUN  2 , total integrated cost =  331.41828946907833
# Improved over  2  iterations in  0.7996013130177744  seconds by  1.3759944295088644e-09  percent.
# cost splitting :  3.324989469228677e-05 [1.37762956 2.17398351]
# set cost params:  0.05 62.527359811245894 0.0
# interpolate adjoint :  True True True
# initial cost =  222.07298985438607
# RUN  0 , total integrated cost =  222.07298985438607
# Gradient descend method:  None
# RUN  1 , total integrated cost =  222.07298975218598
# RUN  2 , total integrated cost =  222.07298975206436
# RUN  3 , total integrated cost =  222.07298975206226
# RUN  4 , total integrated cost =  222.07298975206197
# RUN  5 , total integrated cost =  222.07298975206197
# Control only changes marginally.
# RUN  5 , total integrated cost =  222.07298975206197
# Improved over  5  iterations in  1.8130792709998786  seconds by  4.607679215951066e-08  percent.
# cost splitting :  2.226318686694993e-05 [1.37762956 2.17398352]
# set cost params:  0.05 176.44785767484538 0.0
# interpolate adjoint :  True True True
# initial cost =  626.6745194531632
# RUN  0 , total integrated cost =  626.6745194531632
# Gradient descend method:  None
# RUN  1 , total integrated cost =  626.6745182231425
# RUN  2 , total integrated cost =  626.6745182231285
# RUN  3 , total integrated cost =  626.6745182231253
# RUN  4 , total integrated cost =  626.6745182231253
# Control only changes marginally.
# RUN  4 , total integrated cost =  626.6745182231253
# Improved over  4  iterations in  1.4689318430027924  seconds by  1.962801690069682e-07  percent.
# cost splitting :  6.22068805788362e-05 [1.37762954 2.17398352]
# set cost params:  0.05 50.94174790166735 0.0
# interpolate adjoint :  True True True
# initial cost =  180.9253800798049
# RUN  0 , total integrated cost =  180.9253800798049
# Gradient descend method:  None
# RUN  1 , total integrated cost =  180.92537899271127
# RUN  2 , total integrated cost =  180.92537899271127
# Control only changes marginally.
# RUN  2 , total integrated cost =  180.92537899271127
# Improved over  2  iterations in  0.8104252039920539  seconds by  6.008519193301254e-07  percent.
# cost splitting :  1.8138407013842085e-05 [1.37762954 2.17398354]
# set cost params:  0.05 177.2910368122534 0.0
# interpolate adjoint :  True True True
# initial cost =  629.6691659382418
# RUN  0 , total integrated cost =  629.6691659382418
# Gradient descend method:  None
# RUN  1 , total integrated cost =  629.6691642538824
# RUN  2 , total integrated cost =  629.6691642508383
# RUN  3 , total integrated cost =  629.6691642508383
# Control only changes marginally.
# RUN  3 , total integrated cost =  629.6691642508383
# Improved over  3  iterations in  1.1949823580216616  seconds by  2.6798254282311973e-07  percent.
# cost splitting :  6.254152487294267e-05 [1.37762952 2.17398354]
# set cost params:  0.05 97.64545812411603 0.0
# interpolate adjoint :  True True True
# initial cost =  346.79888709811314
# RUN  0 , total integrated cost =  346.79888709811314
# Gradient descend method:  None
# RUN  1 , total integrated cost =  346.7988867265076
# RUN  2 , total integrated cost =  346.7988867263414
# RUN  3 , total integrated cost =  346.7988867263414
# Control only changes marginally.
# RUN  3 , total integrated cost =  346.7988867263414
# Improved over  3  iterations in  1.2038585909758694  seconds by  1.072009752078884e-07  percent.
# cost splitting :  3.482608832734578e-05 [1.37762952 2.17398355]
# set cost params:  0.05 158.27648483705602 0.0
# interpolate adjoint :  True True True
# initial cost =  562.1368334521237
# RUN  0 , total integrated cost =  562.1368334521237
# Gradient descend method:  None
# RUN  1 , total integrated cost =  562.1368331739413
# RUN  2 , total integrated cost =  562.1368331739249
# RUN  3 , total integrated cost =  562.1368331739249
# Control only changes marginally.
# RUN  3 , total integrated cost =  562.1368331739249
# Improved over  3  iterations in  1.1238939890172333  seconds by  4.948952891936642e-08  percent.
# cost splitting :  5.597173115236854e-05 [1.37762951 2.17398355]
# set cost params:  0.05 56.230849845260984 0.0
# interpolate adjoint :  True True True
# initial cost =  199.71022339053496
# RUN  0 , total integrated cost =  199.71022339053496
# Gradient descend method:  None
# RUN  1 , total integrated cost =  199.71022262184275
# RUN  2 , total integrated cost =  199.71022262152772
# RUN  3 , total integrated cost =  199.71022262152664
# RUN  4 , total integrated cost =  199.71022262152664
# Control only changes marginally.
# RUN  4 , total integrated cost =  199.71022262152664
# Improved over  4  iterations in  1.4142034969991073  seconds by  3.8506206578858837e-07  percent.
# cost splitting :  2.0040439873831947e-05 [1.37762951 2.17398357]
# set cost params:  0.05 175.5363381889914 0.0
# interpolate adjoint :  True True True
# initial cost =  623.4371551348473
# RUN  0 , total integrated cost =  623.4371551348473
# Gradient descend method:  None
# RUN  1 , total integrated cost =  623.437153705902
# RUN  2 , total integrated cost =  623.4371537057793
# RUN  3 , total integrated cost =  623.4371537057793
# Control only changes marginally.
# RUN  3 , total integrated cost =  623.4371537057793
# Improved over  3  iterations in  1.1609728210023604  seconds by  2.292240566248438e-07  percent.
# cost splitting :  6.191094029558907e-05 [1.3776295  2.17398356]
# set cost params:  0.05 75.46760187071754 0.0
# interpolate adjoint :  True True True
# initial cost =  268.03172324577434
# RUN  0 , total integrated cost =  268.03172324577434
# Gradient descend method:  None
# RUN  1 , total integrated cost =  268.0317226132874
# RUN  2 , total integrated cost =  268.0317226127518
# RUN  3 , total integrated cost =  268.0317226127508
# RUN  4 , total integrated cost =  268.0317226127508
# Control only changes marginally.
# RUN  4 , total integrated cost =  268.0317226127508
# Improved over  4  iterations in  1.4968249070225284  seconds by  2.3617485567228869e-07  percent.
# cost splitting :  2.6886644196237593e-05 [1.3776295  2.17398357]
# set cost params:  0.05 145.82825990518734 0.0
# interpolate adjoint :  True True True
# initial cost =  517.9255553976391
# RUN  0 , total integrated cost =  517.9255553976391
# Gradient descend method:  None
# RUN  1 , total integrated cost =  517.9255549402806
# RUN  2 , total integrated cost =  517.9255549396855
# RUN  3 , total integrated cost =  517.9255549396855
# Control only changes marginally.
# RUN  3 , total integrated cost =  517.9255549396855
# Improved over  3  iterations in  1.1379034430137835  seconds by  8.84207196349962e-08  percent.
# cost splitting :  5.17600423134238e-05 [1.37762949 2.17398357]
# set cost params:  0.05 146.07001443039988 0.0
# interpolate adjoint :  True True True
# initial cost =  518.7841734686632
# RUN  0 , total integrated cost =  518.7841734686632
# Gradient descend method:  None
# RUN  1 , total integrated cost =  518.7841734686632
# Control only changes marginally.
# RUN  1 , total integrated cost =  518.7841734686632
# Improved over  1  iterations in  0.4373061819933355  seconds by  0.0  percent.
# cost splitting :  5.17600423134238e-05 [1.37762949 2.17398357]
# -------  50 0.47500000000000014 0.6000000000000003
# set cost params:  0.05 40.70799250171084 0.0
# interpolate adjoint :  True True True
# initial cost =  444.5374707809343
# RUN  0 , total integrated cost =  444.5374707809343
# Gradient descend method:  None
# RUN  1 , total integrated cost =  444.5374707809343
# Control only changes marginally.
# RUN  1 , total integrated cost =  444.5374707809343
# Improved over  1  iterations in  0.49841874599223956  seconds by  0.0  percent.
# cost splitting :  0.22312065683050855 [7.09114983 3.82872825]

# %%
for i in i_range:
    print("------- ", i, exc[i], inh[i])
    
    aln.params.duration = dur + dur_pre + dur_post

    time_ = np.arange(-dur_pre,round(dur+dur_post+aln.params.dt,1),aln.params.dt)
    target_ = aln.getZeroTarget()
    target_[:,0,:] = target[i][0]
    target_[:,1,:] = target[i][1]

    fig, ax = plt.subplots(2,1, constrained_layout=True, figsize = (4,4) )
    ax[1].plot(time_, bestControl_[i][0,0,:], color = 'red')
    ax[0].plot(time_, bestState_[i][0,0,:], color= 'red')
    ax[1].plot(time_, bestControl_[i][0,1,:], color = 'blue')
    ax[0].plot(time_, bestState_[i][0,1,:], color= 'blue')
    ax[0].plot(time_, target_[0,0,:], linestyle = '--', color='red')
    ax[0].plot(time_, target_[0,1,:], linestyle = '--', color='blue')
    ax[0].set_xlim(-dur_pre,dur+dur_post)
    ax[1].set_xlim(-dur_pre,dur+dur_post)
    ax[0].axvspan(dur*t_pen, dur, alpha=0.2, color='gray')
    plt.show()
# Out:
# -------  20 0.4500000000000001 0.4750000000000002
# -------  50 0.47500000000000014 0.6000000000000003
