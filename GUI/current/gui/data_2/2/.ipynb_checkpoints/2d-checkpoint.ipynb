# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import sys
import pickle
import smoothfit

path = os.getcwd().split(os.sep + 'GUI')[0]
if path not in sys.path:
    print("not here")
    sys.path.append(path)

from neurolib.models.aln import ALNModel
from neurolib.utils import plotFunctions as plotFunc
from neurolib.utils import costFunctions as cost
import neurolib.dashboard.functions as functions
import neurolib.dashboard.data as data
    
# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2 

#path = os.path.join(os.getcwd(), "plots")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
grid_data_file = os.path.join(os.getcwd().split('data')[0], 'bi.pickle')
print(grid_data_file)
with open(grid_data_file,'rb') as f:
    load_array= pickle.load(f)
exc = load_array[0]
inh = load_array[1]
print(len(exc))
# Out:
# /home/lena/Promotion/neurolib/GUI/current/gui/bi.pickle
# 147

# %% [markdown]
# ### Bistability

# %%
aln = ALNModel()
N = aln.params.N

data.set_parameters(aln)

state_vars = aln.state_vars
init_vars = aln.init_vars

##############################################################
def setinit(init_vars_, model):
    state_vars = model.state_vars
    init_vars = model.init_vars
    for iv in range(len(init_vars)):
        for sv in range(len(state_vars)):
            if state_vars[sv] in init_vars[iv]:
                #print("set init vars ", )
                if model.params[init_vars[iv]].ndim == 2:
                    model.params[init_vars[iv]][0,:] = init_vars_[sv]
                else:
                    model.params[init_vars[iv]][0] = init_vars_[sv]
                    
##############################################################               
def setmaxmincontrol(max_c_c, min_c_c, max_c_r, min_c_r):
    import numpy as np
    
    max_cntrl = np.zeros(( 6 ))
    min_cntrl = np.zeros(( 6 ))
    
    max_cntrl[0] = max_c_c
    min_cntrl[0] = min_c_c
    max_cntrl[1] = max_c_c
    min_cntrl[1] = min_c_c
    max_cntrl[2] = max_c_r
    min_cntrl[2] = min_c_r
    max_cntrl[3] = max_c_r
    min_cntrl[3] = min_c_r
    max_cntrl[4] = max_c_r
    min_cntrl[4] = min_c_r
    max_cntrl[5] = max_c_r
    min_cntrl[5] = min_c_r
            
    return max_cntrl, min_cntrl

# %%
d_array = np.arange(20., 300, 0.1)
t0_array = d_array - 20.
t_pen = np.zeros(( t0_array.shape ))
for i in range(len(t_pen)):
    t_pen[i] = t0_array[i] / d_array[i]

bestControl_ = np.array( [[None] * len(t_pen)] * len(exc) )
bestState_ = np.array( [[None] * len(t_pen)] * len(exc) )
cost_ = np.array( [[None] * len(t_pen)] * len(exc) )
costnode_ = np.array( [[None] * len(t_pen)] * len(exc) )
weights_ = np.array( [[None] * len(t_pen)] * len(exc) )
convergence_ = np.array( [[None] * len(t_pen)] * len(exc) )

initVars = [None] * len(exc)
target = [None] * len(exc)
cost_uncontrolled = [None] * len(exc)

print(bestControl_.shape)
# Out:
# (147, 2800)

# %%
file_ = '2d.pickle'
case = '1'

# %%
dur_pre = 10
dur_post = 10

n_pre = int(np.around(dur_pre/aln.params.dt + 1.,1))
n_post = int(np.around(dur_post/aln.params.dt + 1.,1))

tol = 1e-32
start_step = 10.
c_scheme = np.zeros(( 1,1 ))
c_scheme[0,0] = 1.
u_mat = np.identity(1)
u_scheme = np.array([[1.]])

c_var = [0,1]
p_var = [0]

if case in ['1', '2']:    # low to high
    max_I = [3., -3.]
else:
    max_I = [-3., 3.]
    
if case in ['1', '3']:    # sparsity
    factor_ws = 1.
    factor_we = 0.
else:
    factor_ws = 0.
    factor_we = 1.
    
maxC = [5., -5., 0.18, 0.]
max_cntrl, min_cntrl = setmaxmincontrol(maxC[0], maxC[1], maxC[2], maxC[3])

# %%
if os.path.isfile(file_) :
    print("file found")
    
    with open(file_,'rb') as f:
        load_array = pickle.load(f)

    bestControl_ = load_array[0]
    bestState_ = load_array[1]
    cost_ = load_array[2]
    costnode_ = load_array[3]
    weights_ = load_array[4]

# %%
# get initial parameters and target states

#i_stepsize = 20
#limit = 150
#start_index = 0
#i_range = range(start_index, limit,i_stepsize)
i_range = [20]

data.set_parameters(aln)

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    aln.params.duration = 3000.
    
    control0 = aln.getZeroControl()
    control0 = functions.step_control(aln, maxI_ = max_I[0])

    aln.run(control=control0)
    
    target_rates = np.zeros((2))
    target_rates[0] = aln.rates_exc[0,-1] 
    target_rates[1] = aln.rates_inh[0,-1]

    control0 = functions.step_control(aln, maxI_ = max_I[1])
    aln.run(control=control0)

    init_state_vars = np.zeros(( len(state_vars) ))
    for j in range(len(state_vars)):
        if aln.state[state_vars[j]].size == 1:
            init_state_vars[j] = aln.state[state_vars[j]][0]
        else:
            init_state_vars[j] = aln.state[state_vars[j]][0,-1]

    initVars[i] = init_state_vars
    target[i] = [target_rates[0], target_rates[1]]
# Out:
# -------  20 0.4500000000000001 0.4750000000000002

# %%
# get uncontrolled cost

data.set_parameters(aln)

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    dur = d_array[0]
    aln.params.duration = dur
    
    target_ = aln.getZeroTarget()
    target_[:,0,:] = target[i][0]
    target_[:,1,:] = target[i][1]
        
    cost.setParams(1.0, 0.0, 0.0)

    setinit(initVars[i], aln)
    control0 = aln.getZeroControl()

    # "HS", "FR", "PR", "HZ"
    cgv = None
    max_it = 0

    bestControl_init_, bestState_init_, cost_init_, runtime_init_, grad_init_, phi_init_, costnode_init_ = aln.A1(
        control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
        prec_variables_ = p_var, transition_time_ = 0.)
    
    cost_uncontrolled[i] = cost_init_[0]
# Out:
# -------  20 0.4500000000000001 0.4750000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  0 , total integrated cost =  12801.807032522984
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.

# %%
cgv = None
j = 0
k = 0

while k < 10:
    print('-------------------------------------------- k = ', k)

    for i in i_range:
        print("------- ", i, exc[i], inh[i])
        aln.params.ext_exc_current = exc[i] * 5.
        aln.params.ext_inh_current = inh[i] * 5.

        if convergence_[i][j] == True:
            print('converged')
            continue

        dur = d_array[0]
        aln.params.duration = dur
        
        setinit(initVars[i], aln)

        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        max_it = int(100)

        if type(bestControl_[i][j]) == type(None) or np.amax(np.abs(bestControl_[i][j])) < 1e-6:
            print('no solution found')
            control0 = aln.getZeroControl()
            #control0[0,0,:50] = 5.
            cost.setParams(1.0, 0., 1.)
            max_it = int(1)
            weights_[i][j] = [1., 0., 1.]
        else:
            control0 = bestControl_[i][j][:,:,n_pre-1:-n_post+1]
            l = 1
            while cost_[i][j][-l] == 0.:
                l += 1

            weight_ = ( cost_uncontrolled[i] - costnode_[i][j][0][0][0] ) / sum( costnode_[i][j][2][0][:] )
                
            print("weight = ", weight_)
            cost.setParams(1.0, weight_ * factor_we, weight_ * factor_ws)
            weights_[i][j] = cost.getParams()

        bestControl_[i][j], bestState_[i][j], cost_[i][j], runtime_, grad_, phi_, costnode_[i][j] = aln.A1(
            control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = [1],
            prec_variables_ = p_var, transition_time_ = t_pen[j])

        #if cost_[i][j][2] == 0.:
        #    print('converged')
        #    convergence_[i][j] = True

        print('uncontrolled cost : ', cost_uncontrolled[i])
        print('cost splitting : ', costnode_[i][j][0][0][0], costnode_[i][j][2][0][:2])

        time_ = np.arange(-dur_pre,dur+dur_post+aln.params.dt,aln.params.dt)
        dur += dur_pre + dur_post
        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        if True:
            fig, ax = plt.subplots(2,1, constrained_layout=True, figsize = (4,4) )
            ax[1].plot(time_, bestControl_[i][j][0,0,:], color = 'red')
            ax[0].plot(time_, bestState_[i][j][0,0,:], color= 'red')
            ax[1].plot(time_, bestControl_[i][j][0,1,:], color = 'blue')
            ax[0].plot(time_, bestState_[i][j][0,1,:], color= 'blue')
            ax[0].plot(time_, target_[0,0,:], linestyle = '--', color='red')
            ax[0].plot(time_, target_[0,1,:], linestyle = '--', color='blue')
            ax[0].set_xlim(-dur_pre,dur-dur_post)
            ax[1].set_xlim(-dur_pre,dur-dur_post)
            ax[0].axvspan(t0_array[0], dur, alpha=0.2, color='gray')
            plt.show()

        with open(file_,'wb') as f:
            pickle.dump([bestControl_, bestState_, cost_, costnode_, weights_], f)
    
    k += 1
# Out:
# -------------------------------------------- k =  0
# -------  20 0.4500000000000001 0.4750000000000002
# no solution found
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  9444.199144044613
# RUN  1 , total integrated cost =  9444.199144044613
# Improved over  1  iterations in  0.019733322085812688  seconds by  26.227608961362805  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  9438.294876277036 [0.         5.90426777]
# -------------------------------------------- k =  1
# -------  20 0.4500000000000001 0.4750000000000002
# weight =  569.6747316773378
# set cost params:  1.0 0.0 569.6747316773378
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12772.358064437001
# RUN  2 , total integrated cost =  12749.621242966616
# RUN  3 , total integrated cost =  12732.171609177196
# RUN  4 , total integrated cost =  12719.270884094178
# RUN  5 , total integrated cost =  12709.454637556424
# RUN  6 , total integrated cost =  12701.815254663874
# RUN  7 , total integrated cost =  12695.813125710483
# RUN  8 , total integrated cost =  12691.2970356773
# RUN  9 , total integrated cost =  12687.593093545522
# RUN  10 , total integrated cost =  12684.520484537754
# RUN  11 , total integrated cost =  12681.890836830436
# RUN  12 , total integrated cost =  12679.81879166343
# RUN  13 , total integrated cost =  12678.027251238937
# RUN  14 , total integrated cost =  12676.767103842818
# RUN  15 , total integrated cost =  12675.6045212568
# RUN  16 , total integrated cost =  12674.688012431805
# RUN  17 , total integrated cost =  12673.827156404384
# RUN  18 , total integrated cost =  12673.139336157492
# RUN  19 , total integrated cost =  12672.53599253744
# RUN  20 , total integrated cost =  12672.03426805036
# RUN  30 , total integrated cost =  12669.931611202326
# RUN  40 , total integrated cost =  12669.577455779488
# RUN  50 , total integrated cost =  12669.307427533315
# RUN  60 , total integrated cost =  12669.295640525826
# Control only changes marginally.
# RUN  63 , total integrated cost =  12669.295636811981
# Improved over  63  iterations in  1.3663678899174556  seconds by  1.0350991494744335  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  9339.746496766073 [0.         5.84464951]
# -------------------------------------------- k =  2
# -------  20 0.4500000000000001 0.4750000000000002
# weight =  592.3469886769187
# set cost params:  1.0 0.0 592.3469886769187
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.701855619574
# RUN  2 , total integrated cost =  12801.671802968496
# RUN  3 , total integrated cost =  12801.645871799024
# RUN  4 , total integrated cost =  12801.623668586682
# RUN  5 , total integrated cost =  12801.60645765147
# RUN  6 , total integrated cost =  12801.591388995577
# RUN  7 , total integrated cost =  12801.581351156483
# RUN  8 , total integrated cost =  12801.571089647163
# RUN  9 , total integrated cost =  12801.55958766985
# RUN  10 , total integrated cost =  12801.551476043673
# RUN  11 , total integrated cost =  12801.543800542895
# RUN  12 , total integrated cost =  12801.538986823452
# RUN  13 , total integrated cost =  12801.533734025423
# RUN  14 , total integrated cost =  12801.531193998246
# RUN  15 , total integrated cost =  12801.528260580655
# RUN  16 , total integrated cost =  12801.526379469859
# RUN  17 , total integrated cost =  12801.521544555118
# RUN  18 , total integrated cost =  12801.517850467022
# RUN  19 , total integrated cost =  12801.509300395624
# RUN  20 , total integrated cost =  12801.508315533945
# Control only changes marginally.
# RUN  29 , total integrated cost =  12801.50322642536
# Improved over  29  iterations in  0.6730436430079862  seconds by  0.002373150109605149  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  9356.479817553367 [0.         5.81588744]
# -------------------------------------------- k =  3
# -------  20 0.4500000000000001 0.4750000000000002
# weight =  592.399225949561
# set cost params:  1.0 0.0 592.399225949561
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522982
# RUN  2 , total integrated cost =  12801.807032522982
# Control only changes marginally.
# RUN  2 , total integrated cost =  12801.807032522982
# Improved over  2  iterations in  0.16091931192204356  seconds by  1.4210854715202004e-14  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  9356.47981754994 [0.         5.81588744]
# -------------------------------------------- k =  4
# -------  20 0.4500000000000001 0.4750000000000002
# weight =  592.3992259495612
# set cost params:  1.0 0.0 592.3992259495612
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.1158816689858213  seconds by  0.0  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  9356.47981754994 [0.         5.81588744]
# -------------------------------------------- k =  5
# -------  20 0.4500000000000001 0.4750000000000002
# weight =  592.3992259495612
# set cost params:  1.0 0.0 592.3992259495612
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.10962803801521659  seconds by  0.0  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  9356.47981754994 [0.         5.81588744]
# -------------------------------------------- k =  6
# -------  20 0.4500000000000001 0.4750000000000002
# weight =  592.3992259495612
# set cost params:  1.0 0.0 592.3992259495612
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.07489499705843627  seconds by  0.0  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  9356.47981754994 [0.         5.81588744]
# -------------------------------------------- k =  7
# -------  20 0.4500000000000001 0.4750000000000002
# weight =  592.3992259495612
# set cost params:  1.0 0.0 592.3992259495612
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.07805545709561557  seconds by  0.0  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  9356.47981754994 [0.         5.81588744]
# -------------------------------------------- k =  8
# -------  20 0.4500000000000001 0.4750000000000002
# weight =  592.3992259495612
# set cost params:  1.0 0.0 592.3992259495612
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.1106056529097259  seconds by  0.0  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  9356.47981754994 [0.         5.81588744]
# -------------------------------------------- k =  9
# -------  20 0.4500000000000001 0.4750000000000002
# weight =  592.3992259495612
# set cost params:  1.0 0.0 592.3992259495612
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.11364067601971328  seconds by  0.0  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  9356.47981754994 [0.         5.81588744]

# %%
for i in range(bestControl_.shape[0]):
    for j in range(1,bestControl_.shape[1]):
        bestControl_[i][j] = None
        convergence_[i][j] = None

# %%
cost.setParams(1.0, factor_we, factor_ws)

j_start = 1

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.

    for j in range(j_start,j_start+2400):
        print(i,j, '-----------------')
            
        k = 0
        while convergence_[i][j] != True:
            print('---------------------', k)

            dur = round(d_array[j],1)
            print('simulation duration : ', dur)
            aln.params.duration = dur
            max_it = int(100)  
            
            setinit(initVars[i], aln)
            target_ = aln.getZeroTarget()
            target_[:,0,:] = target[i][0]
            target_[:,1,:] = target[i][1]

            if type(bestControl_[i][j]) == type(None):
                print('no solution computed yet')
                control0 = aln.getZeroControl()
                control1 = aln.getZeroControl()
                control0[:,:,1:] = bestControl_[i][j-1][:,:,n_pre-1:-n_post+1]
                time_ = np.arange(0.,round(dur+aln.params.dt,1),aln.params.dt)
                basis, coeffs = smoothfit.fit1d(time_[1:], control0[0,0,1:],
                                        aln.params.dt, round(dur+aln.params.dt,1), int(len(time_)-2), degree=1, lmbda=2.)
                control1[0,0,1:] = coeffs[basis.nodal_dofs[0]]
                basis, coeffs = smoothfit.fit1d(time_[1:], control0[0,1,1:],
                                        aln.params.dt, round(dur+aln.params.dt,1), int(len(time_)-2), degree=1, lmbda=2.)
                control1[0,1,1:] = coeffs[basis.nodal_dofs[0]]                            
                                        
                l = 1
                while cost_[i][j-1][-l] == 0.:
                    l += 1
                    
                weight_ = ( cost_uncontrolled[i] - costnode_[i][j-1][0][0][0] ) / sum( costnode_[i][j-1][2][0][:] )
                #weight_ = (factor_we * weights_[i][j-1][1] * cost_uncontrolled[i] / cost_[i][j-1][-l]
                #           + factor_ws * weights_[i][j-1][2] * cost_uncontrolled[i] / cost_[i][j-1][-l]) - 0.1
            else:
                control1 = bestControl_[i][j][:,:,n_pre-1:-n_post+1]
                l = 1
                while cost_[i][j][-l] == 0.:
                    l += 1
                
                weight_ = ( cost_uncontrolled[i] - costnode_[i][j][0][0][0] ) / sum( costnode_[i][j][2][0][:] )
                #weight_ = (factor_we * weights_[i][j][1] * cost_uncontrolled[i] / cost_[i][j][-l]
                #           + factor_ws * weights_[i][j][2] * cost_uncontrolled[i] / cost_[i][j][-l]) - 0.1
                
            print("weight = ", weight_)
            cost.setParams(1.0, weight_ * factor_we, weight_ * factor_ws)
            weights_[i][j] = cost.getParams()

            bestControl_[i][j], bestState_[i][j], cost_[i][j], runtime_, grad_, phi_, costnode_[i][j] = aln.A1(
                control1, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
                startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
                t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = [1],
                prec_variables_ = p_var, transition_time_ = t_pen[j])

            if cost_[i][j][2] == 0.:
                print('converged')
                convergence_[i][j] = True

            print('uncontrolled cost : ', cost_uncontrolled[i])
            print('cost splitting : ', costnode_[i][j][0][0][0], costnode_[i][j][2][0][:2])
                
            time_ = np.arange(-dur_pre,round(dur+dur_post+aln.params.dt,1),aln.params.dt)
            dur += dur_pre + dur_post
            target_ = aln.getZeroTarget()
            target_[:,0,:] = target[i][0]
            target_[:,1,:] = target[i][1]

            if False:
                fig, ax = plt.subplots(2,1, constrained_layout=True, figsize = (4,4) )
                ax[1].plot(time_, bestControl_[i][j][0,0,:], color = 'red')
                ax[0].plot(time_, bestState_[i][j][0,0,:], color= 'red')
                ax[1].plot(time_, bestControl_[i][j][0,1,:], color = 'blue')
                ax[0].plot(time_, bestState_[i][j][0,1,:], color= 'blue')
                ax[0].plot(time_, target_[0,0,:], linestyle = '--', color='red')
                ax[0].plot(time_, target_[0,1,:], linestyle = '--', color='blue')
                ax[0].set_xlim(-dur_pre,dur-dur_post)
                ax[1].set_xlim(-dur_pre,dur-dur_post)
                ax[0].axvspan(t0_array[j], t0_array[j]+20, alpha=0.2, color='gray')
                plt.show()

            with open(file_,'wb') as f:
                pickle.dump([bestControl_, bestState_, cost_, costnode_, weights_], f)
                
            k += 1
# Out:
# set cost params:  1.0 0.0 1.0
# -------  20 0.4500000000000001 0.4750000000000002
# 20 1 -----------------
# --------------------- 0
# simulation duration :  20.1
# no solution computed yet
# weight =  592.3992259495612
# set cost params:  1.0 0.0 592.3992259495612
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12727.306295593462
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12725.073333392575
# RUN  2 , total integrated cost =  12723.807248706005
# RUN  3 , total integrated cost =  12723.000208086049
# RUN  4 , total integrated cost =  12722.624481826815
# RUN  5 , total integrated cost =  12722.237357689384
# RUN  6 , total integrated cost =  12721.94733095965
# RUN  7 , total integrated cost =  12721.63404611178
# RUN  8 , total integrated cost =  12721.460070054758
# RUN  9 , total integrated cost =  12721.23482536045
# RUN  10 , total integrated cost =  12721.088081167185
# RUN  11 , total integrated cost =  12720.918374594003
# RUN  12 , total integrated cost =  12720.82126009445
# RUN  13 , total integrated cost =  12720.692064485283
# RUN  14 , total integrated cost =  12720.615320063287
# RUN  15 , total integrated cost =  12720.600911521975
# RUN  16 , total integrated cost =  12720.575556011368
# RUN  17 , total integrated cost =  12720.568947502621
# RUN  18 , total integrated cost =  12720.532325640963
# RUN  19 , total integrated cost =  12720.509374836442
# RUN  20 , total integrated cost =  12720.502033348786
# RUN  30 , total integrated cost =  12720.352103156434
# RUN  40 , total integrated cost =  12720.35209923115
# Control only changes marginally.
# RUN  47 , total integrated cost =  12720.352099231102
# Improved over  47  iterations in  1.0043381170835346  seconds by  0.054639970162156715  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  9275.499002198656 [0.        5.8150871]
# --------------------- 1
# simulation duration :  20.1
# weight =  606.4067432725644
# set cost params:  1.0 0.0 606.4067432725644
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.77224948653
# RUN  2 , total integrated cost =  12801.708898067458
# RUN  3 , total integrated cost =  12801.695429162099
# RUN  4 , total integrated cost =  12801.693242351732
# RUN  5 , total integrated cost =  12801.687735110934
# RUN  6 , total integrated cost =  12801.68059055449
# RUN  7 , total integrated cost =  12801.680244538642
# RUN  8 , total integrated cost =  12801.680212014111
# RUN  9 , total integrated cost =  12801.680200809595
# RUN  10 , total integrated cost =  12801.680193122873
# RUN  11 , total integrated cost =  12801.680183725777
# RUN  12 , total integrated cost =  12801.680161951124
# RUN  13 , total integrated cost =  12801.68002395149
# RUN  14 , total integrated cost =  12801.67146657348
# RUN  15 , total integrated cost =  12801.671310887194
# RUN  16 , total integrated cost =  12801.669803897381
# RUN  17 , total integrated cost =  12801.666255359854
# RUN  18 , total integrated cost =  12801.666122701225
# RUN  19 , total integrated cost =  12801.666121161139
# RUN  20 , total integrated cost =  12801.66612111161
# Control only changes marginally.
# RUN  25 , total integrated cost =  12801.666121110342
# Improved over  25  iterations in  0.5673698720056564  seconds by  0.001100715018466758  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  9293.076465757988 [0.         5.78586847]
# --------------------- 2
# simulation duration :  20.1
# weight =  606.4310976825193
# set cost params:  1.0 0.0 606.4310976825193
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032456583
# RUN  2 , total integrated cost =  12801.807032454704
# RUN  3 , total integrated cost =  12801.80703245461
# RUN  4 , total integrated cost =  12801.807032454595
# RUN  5 , total integrated cost =  12801.807032454592
# RUN  6 , total integrated cost =  12801.807032454592
# Control only changes marginally.
# RUN  6 , total integrated cost =  12801.807032454592
# Improved over  6  iterations in  0.24982078303582966  seconds by  5.342428721633041e-10  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  9293.082071777248 [0.         5.78585922]
# --------------------- 3
# simulation duration :  20.1
# weight =  606.4310976943399
# set cost params:  1.0 0.0 606.4310976943399
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522982
# RUN  2 , total integrated cost =  12801.807032522982
# Control only changes marginally.
# RUN  2 , total integrated cost =  12801.807032522982
# Improved over  2  iterations in  0.17493901401758194  seconds by  1.4210854715202004e-14  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  9293.082071777248 [0.         5.78585922]
# --------------------- 4
# simulation duration :  20.1
# weight =  606.4310976943401
# set cost params:  1.0 0.0 606.4310976943401
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.11101519106887281  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  9293.082071777248 [0.         5.78585922]
# 20 2 -----------------
# --------------------- 0
# simulation duration :  20.2
# no solution computed yet
# weight =  606.4310976943401
# set cost params:  1.0 0.0 606.4310976943401
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12790.27888582239
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12788.014760304499
# RUN  2 , total integrated cost =  12787.432817476914
# RUN  3 , total integrated cost =  12786.874603518521
# RUN  4 , total integrated cost =  12786.559875027646
# RUN  5 , total integrated cost =  12786.115132441751
# RUN  6 , total integrated cost =  12785.83858387833
# RUN  7 , total integrated cost =  12785.368737561439
# RUN  8 , total integrated cost =  12785.00527467731
# RUN  9 , total integrated cost =  12783.653787209849
# RUN  10 , total integrated cost =  12783.599119435676
# RUN  11 , total integrated cost =  12783.589888599174
# RUN  12 , total integrated cost =  12783.584921158861
# RUN  13 , total integrated cost =  12783.554941447237
# RUN  14 , total integrated cost =  12783.548666750883
# RUN  15 , total integrated cost =  12783.54851156511
# RUN  16 , total integrated cost =  12783.548485061972
# RUN  17 , total integrated cost =  12783.5484805629
# RUN  18 , total integrated cost =  12783.54847496562
# RUN  19 , total integrated cost =  12783.54846601647
# RUN  20 , total integrated cost =  12783.548445940023
# Control only changes marginally.
# RUN  28 , total integrated cost =  12783.522887571533
# Improved over  28  iterations in  0.6983308489434421  seconds by  0.05282135214694961  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  9278.271691420574 [0.         5.78013101]
# --------------------- 1
# simulation duration :  20.2
# weight =  609.5943728700213
# set cost params:  1.0 0.0 609.5943728700213
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.806037481403
# RUN  2 , total integrated cost =  12801.806037480348
# RUN  3 , total integrated cost =  12801.806037480335
# RUN  4 , total integrated cost =  12801.806037480332
# RUN  5 , total integrated cost =  12801.806037480332
# Control only changes marginally.
# RUN  5 , total integrated cost =  12801.806037480332
# Improved over  5  iterations in  0.24328815995249897  seconds by  7.77267341334209e-06  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  9278.851315316744 [0.         5.77917855]
# --------------------- 2
# simulation duration :  20.2
# weight =  609.5945450471991
# set cost params:  1.0 0.0 609.5945450471991
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.11417006806004792  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  9278.851315316744 [0.         5.77917855]
# 20 3 -----------------
# --------------------- 0
# simulation duration :  20.3
# no solution computed yet
# weight =  609.5945450471991
# set cost params:  1.0 0.0 609.5945450471991
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12789.875024790486
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12787.589029171171
# RUN  2 , total integrated cost =  12787.077492214432
# RUN  3 , total integrated cost =  12786.50743842667
# RUN  4 , total integrated cost =  12786.243785462691
# RUN  5 , total integrated cost =  12785.647163069068
# RUN  6 , total integrated cost =  12785.255710485593
# RUN  7 , total integrated cost =  12783.117474123637
# RUN  8 , total integrated cost =  12783.013646650481
# RUN  9 , total integrated cost =  12783.005218866938
# RUN  10 , total integrated cost =  12783.003198685568
# RUN  11 , total integrated cost =  12782.991301364586
# RUN  12 , total integrated cost =  12782.948720718658
# RUN  13 , total integrated cost =  12782.946150246744
# RUN  14 , total integrated cost =  12782.946064203199
# RUN  15 , total integrated cost =  12782.946058319076
# RUN  16 , total integrated cost =  12782.94605791481
# RUN  17 , total integrated cost =  12782.94605788565
# RUN  18 , total integrated cost =  12782.946057883466
# RUN  19 , total integrated cost =  12782.946057883213
# RUN  20 , total integrated cost =  12782.946057883193
# Control only changes marginally.
# RUN  26 , total integrated cost =  12782.94605788318
# Improved over  26  iterations in  0.7064922200515866  seconds by  0.05417540745217764  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  9263.182172146022 [0.         5.77394256]
# --------------------- 1
# simulation duration :  20.3
# weight =  612.8611128136588
# set cost params:  1.0 0.0 612.8611128136588
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.80678775664
# RUN  2 , total integrated cost =  12801.806787756628
# RUN  3 , total integrated cost =  12801.806787756628
# Control only changes marginally.
# RUN  3 , total integrated cost =  12801.806787756628
# Improved over  3  iterations in  0.19676711899228394  seconds by  1.9119672316492142e-06  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  9263.432899705846 [0.         5.77353305]
# --------------------- 2
# simulation duration :  20.3
# weight =  612.8611552082122
# set cost params:  1.0 0.0 612.8611552082122
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522978
# RUN  2 , total integrated cost =  12801.807032522978
# Control only changes marginally.
# RUN  2 , total integrated cost =  12801.807032522978
# Improved over  2  iterations in  0.15700680494774133  seconds by  4.263256414560601e-14  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  9263.432899726216 [0.         5.77353305]
# --------------------- 3
# simulation duration :  20.3
# weight =  612.8611552082131
# set cost params:  1.0 0.0 612.8611552082131
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522982
# RUN  2 , total integrated cost =  12801.807032522982
# Control only changes marginally.
# RUN  2 , total integrated cost =  12801.807032522982
# Improved over  2  iterations in  0.17145998508203775  seconds by  1.4210854715202004e-14  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  9263.432899726216 [0.         5.77353305]
# --------------------- 4
# simulation duration :  20.3
# weight =  612.8611552082132
# set cost params:  1.0 0.0 612.8611552082132
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.07637388398870826  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  9263.432899726216 [0.         5.77353305]
# 20 4 -----------------
# --------------------- 0
# simulation duration :  20.4
# no solution computed yet
# weight =  612.8611552082132
# set cost params:  1.0 0.0 612.8611552082132
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12789.17276829249
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12786.863027534408
# RUN  2 , total integrated cost =  12786.512505407947
# RUN  3 , total integrated cost =  12785.894211347126
# RUN  4 , total integrated cost =  12785.620409794952
# RUN  5 , total integrated cost =  12783.389915840868
# RUN  6 , total integrated cost =  12782.921792774416
# RUN  7 , total integrated cost =  12782.722536930703
# RUN  8 , total integrated cost =  12782.492406349538
# RUN  9 , total integrated cost =  12782.480316712397
# RUN  10 , total integrated cost =  12782.467626171903
# RUN  11 , total integrated cost =  12782.304202721321
# RUN  12 , total integrated cost =  12782.273464783237
# RUN  13 , total integrated cost =  12782.273464783231
# RUN  14 , total integrated cost =  12782.273464783228
# RUN  15 , total integrated cost =  12782.273464783228
# Control only changes marginally.
# RUN  15 , total integrated cost =  12782.273464783228
# Improved over  15  iterations in  0.5947747819591314  seconds by  0.053946440745306745  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  9243.391385218494 [0.         5.77436186]
# --------------------- 1
# simulation duration :  20.4
# weight =  616.2439649829308
# set cost params:  1.0 0.0 616.2439649829308
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.806187846501
# RUN  2 , total integrated cost =  12801.8061878465
# RUN  3 , total integrated cost =  12801.8061878465
# Control only changes marginally.
# RUN  3 , total integrated cost =  12801.8061878465
# Improved over  3  iterations in  0.19679632503539324  seconds by  6.598103553301371e-06  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  9243.847560974085 [0.         5.77362024]
# --------------------- 2
# simulation duration :  20.4
# weight =  616.244111282211
# set cost params:  1.0 0.0 616.244111282211
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.11933369899634272  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  9243.847560974085 [0.         5.77362024]
# 20 5 -----------------
# --------------------- 0
# simulation duration :  20.5
# no solution computed yet
# weight =  616.244111282211
# set cost params:  1.0 0.0 616.244111282211
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12788.660418277566
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12786.349770683986
# RUN  2 , total integrated cost =  12786.029823261728
# RUN  3 , total integrated cost =  12785.322568795535
# RUN  4 , total integrated cost =  12785.053937263343
# RUN  5 , total integrated cost =  12782.476913471259
# RUN  6 , total integrated cost =  12782.125956382275
# RUN  7 , total integrated cost =  12781.787556529147
# RUN  8 , total integrated cost =  12781.779043382536
# RUN  9 , total integrated cost =  12781.778204979266
# RUN  10 , total integrated cost =  12781.777762949889
# RUN  11 , total integrated cost =  12781.776566312106
# RUN  12 , total integrated cost =  12781.77171683018
# RUN  13 , total integrated cost =  12781.63824021777
# RUN  14 , total integrated cost =  12781.625949619509
# RUN  15 , total integrated cost =  12781.62594649845
# RUN  16 , total integrated cost =  12781.625946498441
# RUN  17 , total integrated cost =  12781.625946498441
# Control only changes marginally.
# RUN  17 , total integrated cost =  12781.625946498441
# Improved over  17  iterations in  0.5973203289322555  seconds by  0.055005540447936596  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  9224.461914924279 [0.         5.77232945]
# --------------------- 1
# simulation duration :  20.5
# weight =  619.7402883804598
# set cost params:  1.0 0.0 619.7402883804598
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.805893012446
# RUN  2 , total integrated cost =  12801.805893012433
# RUN  3 , total integrated cost =  12801.80589301243
# RUN  4 , total integrated cost =  12801.80589301243
# Control only changes marginally.
# RUN  4 , total integrated cost =  12801.80589301243
# Improved over  4  iterations in  0.24085204303264618  seconds by  8.901169593400482e-06  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  9224.981903199328 [0.         5.77148857]
# --------------------- 2
# simulation duration :  20.5
# weight =  619.7404858183547
# set cost params:  1.0 0.0 619.7404858183547
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.11811657098587602  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  9224.981903199328 [0.         5.77148857]
# 20 6 -----------------
# --------------------- 0
# simulation duration :  20.6
# no solution computed yet
# weight =  619.7404858183547
# set cost params:  1.0 0.0 619.7404858183547
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12788.000470011797
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12785.64620522349
# RUN  2 , total integrated cost =  12785.403292127005
# RUN  3 , total integrated cost =  12784.516461124087
# RUN  4 , total integrated cost =  12784.160101341648
# RUN  5 , total integrated cost =  12783.711512682692
# RUN  6 , total integrated cost =  12783.014274978015
# RUN  7 , total integrated cost =  12782.924225370602
# RUN  8 , total integrated cost =  12782.34415725656
# RUN  9 , total integrated cost =  12781.647351625328
# RUN  10 , total integrated cost =  12781.614536997598
# RUN  11 , total integrated cost =  12781.5704068609
# RUN  12 , total integrated cost =  12781.337123765825
# RUN  13 , total integrated cost =  12781.312978010235
# RUN  14 , total integrated cost =  12781.311003242612
# RUN  15 , total integrated cost =  12781.310668675658
# RUN  16 , total integrated cost =  12781.310324012235
# RUN  17 , total integrated cost =  12781.309689825674
# RUN  18 , total integrated cost =  12781.305893797351
# RUN  19 , total integrated cost =  12781.015670205717
# RUN  20 , total integrated cost =  12781.015670205714
# Control only changes marginally.
# RUN  21 , total integrated cost =  12781.015670205714
# Improved over  21  iterations in  0.6244587519904599  seconds by  0.05461995268504438  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  9205.228344986434 [0.         5.76981399]
# --------------------- 1
# simulation duration :  20.6
# weight =  623.343957672638
# set cost params:  1.0 0.0 623.343957672638
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522982
# RUN  2 , total integrated cost =  12801.80703252298
# RUN  3 , total integrated cost =  12801.80703252298
# Control only changes marginally.
# RUN  3 , total integrated cost =  12801.80703252298
# Improved over  3  iterations in  0.15889206295832992  seconds by  2.842170943040401e-14  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  9205.228344986523 [0.         5.76981399]
# --------------------- 2
# simulation duration :  20.6
# weight =  623.3439576726386
# set cost params:  1.0 0.0 623.3439576726386
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.08519747701939195  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  9205.228344986523 [0.         5.76981399]
# 20 7 -----------------
# --------------------- 0
# simulation duration :  20.7
# no solution computed yet
# weight =  623.3439576726386
# set cost params:  1.0 0.0 623.3439576726386
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12787.65214789192
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12784.887970219843
# RUN  2 , total integrated cost =  12784.683038802068
# RUN  3 , total integrated cost =  12783.469558986804
# RUN  4 , total integrated cost =  12783.020226057879
# RUN  5 , total integrated cost =  12782.937898307142
# RUN  6 , total integrated cost =  12782.36534616021
# RUN  7 , total integrated cost =  12782.157470486924
# RUN  8 , total integrated cost =  12782.117159161353
# RUN  9 , total integrated cost =  12780.706250257295
# RUN  10 , total integrated cost =  12780.575611033859
# RUN  11 , total integrated cost =  12780.574498042723
# RUN  12 , total integrated cost =  12780.574339097193
# RUN  13 , total integrated cost =  12780.57432261415
# RUN  14 , total integrated cost =  12780.574321117383
# RUN  15 , total integrated cost =  12780.574320910724
# RUN  16 , total integrated cost =  12780.574320885667
# RUN  17 , total integrated cost =  12780.574320882874
# RUN  18 , total integrated cost =  12780.574320882515
# RUN  19 , total integrated cost =  12780.574320882488
# RUN  20 , total integrated cost =  12780.57432088248
# Control only changes marginally.
# RUN  23 , total integrated cost =  12780.574320882472
# Improved over  23  iterations in  0.8188002499518916  seconds by  0.05534891728045466  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  9189.597923093335 [0.         5.76082651]
# --------------------- 1
# simulation duration :  20.7
# weight =  627.0296634640403
# set cost params:  1.0 0.0 627.0296634640403
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.806927846526
# RUN  2 , total integrated cost =  12801.806926074758
# RUN  3 , total integrated cost =  12801.806925989149
# RUN  4 , total integrated cost =  12801.806925985045
# RUN  5 , total integrated cost =  12801.806925984843
# RUN  6 , total integrated cost =  12801.806925984838
# RUN  7 , total integrated cost =  12801.806925984836
# RUN  8 , total integrated cost =  12801.806925984834
# RUN  9 , total integrated cost =  12801.806925984834
# Control only changes marginally.
# RUN  9 , total integrated cost =  12801.806925984834
# Improved over  9  iterations in  0.3495183519553393  seconds by  8.322117963643905e-07  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  9189.745234427652 [0.         5.76059141]
# --------------------- 2
# simulation duration :  20.7
# weight =  627.029681958348
# set cost params:  1.0 0.0 627.029681958348
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.12749805906787515  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  9189.745234427652 [0.         5.76059141]
# 20 8 -----------------
# --------------------- 0
# simulation duration :  20.8
# no solution computed yet
# weight =  627.029681958348
# set cost params:  1.0 0.0 627.029681958348
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12786.780542700631
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12784.332707300418
# RUN  2 , total integrated cost =  12784.11815802702
# RUN  3 , total integrated cost =  12781.752090848615
# RUN  4 , total integrated cost =  12781.573581524886
# RUN  5 , total integrated cost =  12781.255800823421
# RUN  6 , total integrated cost =  12780.675085698678
# RUN  7 , total integrated cost =  12780.643156729406
# RUN  8 , total integrated cost =  12780.632112213396
# RUN  9 , total integrated cost =  12780.548617627774
# RUN  10 , total integrated cost =  12780.194788192282
# RUN  11 , total integrated cost =  12780.15585572194
# RUN  12 , total integrated cost =  12780.152134748168
# RUN  13 , total integrated cost =  12780.151165510255
# RUN  14 , total integrated cost =  12780.149456623543
# RUN  15 , total integrated cost =  12780.145023025178
# RUN  16 , total integrated cost =  12780.04562397011
# RUN  17 , total integrated cost =  12779.80991571226
# RUN  18 , total integrated cost =  12779.809357133312
# RUN  19 , total integrated cost =  12779.809344086578
# RUN  20 , total integrated cost =  12779.809343855439
# Control only changes marginally.
# RUN  25 , total integrated cost =  12779.809343850848
# Improved over  25  iterations in  0.6704153859755024  seconds by  0.054518796396834546  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  9167.75848683446 [0.         5.76057396]
# --------------------- 1
# simulation duration :  20.8
# weight =  630.8483446178491
# set cost params:  1.0 0.0 630.8483446178491
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.806456188839
# RUN  2 , total integrated cost =  12801.806456188822
# RUN  3 , total integrated cost =  12801.806456188817
# RUN  4 , total integrated cost =  12801.806456188817
# Control only changes marginally.
# RUN  4 , total integrated cost =  12801.806456188817
# Improved over  4  iterations in  0.21725551295094192  seconds by  4.501975112702894e-06  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  9168.141085372792 [0.         5.75996656]
# --------------------- 2
# simulation duration :  20.8
# weight =  630.848444676445
# set cost params:  1.0 0.0 630.848444676445
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522982
# RUN  2 , total integrated cost =  12801.807032522982
# Control only changes marginally.
# RUN  2 , total integrated cost =  12801.807032522982
# Improved over  2  iterations in  0.1745382909430191  seconds by  1.4210854715202004e-14  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  9168.141085372798 [0.         5.75996656]
# --------------------- 3
# simulation duration :  20.8
# weight =  630.8484446764452
# set cost params:  1.0 0.0 630.8484446764452
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.11015690502244979  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  9168.141085372798 [0.         5.75996656]
# 20 9 -----------------
# --------------------- 0
# simulation duration :  20.9
# no solution computed yet
# weight =  630.8484446764452
# set cost params:  1.0 0.0 630.8484446764452
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12786.189198338401
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12783.771767175804
# RUN  2 , total integrated cost =  12783.548643816208
# RUN  3 , total integrated cost =  12782.583450109672
# RUN  4 , total integrated cost =  12781.620696507933
# RUN  5 , total integrated cost =  12781.566731483537
# RUN  6 , total integrated cost =  12781.500124707736
# RUN  7 , total integrated cost =  12780.724139450005
# RUN  8 , total integrated cost =  12780.51867100047
# RUN  9 , total integrated cost =  12780.51319210622
# RUN  10 , total integrated cost =  12780.510824743089
# RUN  11 , total integrated cost =  12780.506643914363
# RUN  12 , total integrated cost =  12780.417274158348
# RUN  13 , total integrated cost =  12780.01235564643
# RUN  14 , total integrated cost =  12779.98603332652
# RUN  15 , total integrated cost =  12779.984843771206
# RUN  16 , total integrated cost =  12779.98462439278
# RUN  17 , total integrated cost =  12779.984547123137
# RUN  18 , total integrated cost =  12779.984507242156
# RUN  19 , total integrated cost =  12779.98448246313
# RUN  20 , total integrated cost =  12779.984464909414
# Control only changes marginally.
# RUN  29 , total integrated cost =  12779.984395609015
# Improved over  29  iterations in  0.9164956080494449  seconds by  0.04852738085709518  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  9155.336516304078 [0.         5.74567142]
# --------------------- 1
# simulation duration :  20.9
# weight =  634.6465450752501
# set cost params:  1.0 0.0 634.6465450752501
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.12904837599489838  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  9155.336516304078 [0.         5.74567142]
# 20 10 -----------------
# --------------------- 0
# simulation duration :  21.0
# no solution computed yet
# weight =  634.6465450752501
# set cost params:  1.0 0.0 634.6465450752501
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12785.793383878598
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12783.067725769688
# RUN  2 , total integrated cost =  12782.817256800301
# RUN  3 , total integrated cost =  12781.346815309182
# RUN  4 , total integrated cost =  12780.070728995317
# RUN  5 , total integrated cost =  12780.001804286861
# RUN  6 , total integrated cost =  12779.983461106729
# RUN  7 , total integrated cost =  12779.772976624348
# RUN  8 , total integrated cost =  12779.14325310606
# RUN  9 , total integrated cost =  12779.107177455264
# RUN  10 , total integrated cost =  12779.104674113856
# RUN  11 , total integrated cost =  12779.104071307826
# RUN  12 , total integrated cost =  12779.103468043673
# RUN  13 , total integrated cost =  12779.103064604802
# RUN  14 , total integrated cost =  12779.102356051453
# RUN  15 , total integrated cost =  12779.100639314149
# RUN  16 , total integrated cost =  12779.087467922041
# RUN  17 , total integrated cost =  12778.196521699687
# RUN  18 , total integrated cost =  12778.076973873602
# RUN  19 , total integrated cost =  12778.076656980209
# RUN  20 , total integrated cost =  12778.076655446785
# Control only changes marginally.
# RUN  25 , total integrated cost =  12778.076655428276
# Improved over  25  iterations in  0.7370906779542565  seconds by  0.0603539273522955  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  9128.643781178638 [0.         5.75033915]
# --------------------- 1
# simulation duration :  21.0
# weight =  638.7733237708536
# set cost params:  1.0 0.0 638.7733237708536
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.80637247164
# RUN  2 , total integrated cost =  12801.806372226001
# RUN  3 , total integrated cost =  12801.806372224928
# RUN  4 , total integrated cost =  12801.806372224914
# RUN  5 , total integrated cost =  12801.80637222491
# RUN  6 , total integrated cost =  12801.806372224906
# RUN  7 , total integrated cost =  12801.806372224906
# Control only changes marginally.
# RUN  7 , total integrated cost =  12801.806372224906
# Improved over  7  iterations in  0.2413479050155729  seconds by  5.1578505662064345e-06  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  9129.040676494335 [0.         5.74971678]
# --------------------- 2
# simulation duration :  21.0
# weight =  638.7734386109585
# set cost params:  1.0 0.0 638.7734386109585
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.11052275891415775  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  9129.040676494335 [0.         5.74971678]
# 20 11 -----------------
# --------------------- 0
# simulation duration :  21.1
# no solution computed yet
# weight =  638.7734386109585
# set cost params:  1.0 0.0 638.7734386109585
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12785.08681894669
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12782.582777496464
# RUN  2 , total integrated cost =  12782.393080768888
# RUN  3 , total integrated cost =  12781.28870324872
# RUN  4 , total integrated cost =  12780.22314200708
# RUN  5 , total integrated cost =  12780.192813906422
# RUN  6 , total integrated cost =  12780.18573179223
# RUN  7 , total integrated cost =  12780.174599462205
# RUN  8 , total integrated cost =  12779.734849091607
# RUN  9 , total integrated cost =  12778.91821896731
# RUN  10 , total integrated cost =  12778.902212524637
# RUN  11 , total integrated cost =  12778.901737633561
# RUN  12 , total integrated cost =  12778.90168968722
# RUN  13 , total integrated cost =  12778.901680862013
# RUN  14 , total integrated cost =  12778.901680229566
# RUN  15 , total integrated cost =  12778.901680179644
# RUN  16 , total integrated cost =  12778.901680175644
# RUN  17 , total integrated cost =  12778.901680175295
# RUN  18 , total integrated cost =  12778.901680175233
# RUN  19 , total integrated cost =  12778.90168017523
# RUN  20 , total integrated cost =  12778.90168017523
# Control only changes marginally.
# RUN  20 , total integrated cost =  12778.90168017523
# Improved over  20  iterations in  0.5968005909817293  seconds by  0.048377761207646586  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  9113.90332826409 [0.         5.73755596]
# --------------------- 1
# simulation duration :  21.1
# weight =  642.7656179455388
# set cost params:  1.0 0.0 642.7656179455388
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.806909724459
# RUN  2 , total integrated cost =  12801.806906154174
# RUN  3 , total integrated cost =  12801.806906098791
# RUN  4 , total integrated cost =  12801.806906097892
# RUN  5 , total integrated cost =  12801.806906097867
# RUN  6 , total integrated cost =  12801.806906097861
# RUN  7 , total integrated cost =  12801.80690609786
# RUN  8 , total integrated cost =  12801.80690609786
# Control only changes marginally.
# RUN  8 , total integrated cost =  12801.80690609786
# Improved over  8  iterations in  0.2689375440822914  seconds by  9.875568736106288e-07  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  9114.095499896317 [0.         5.73725679]
# --------------------- 2
# simulation duration :  21.1
# weight =  642.7656399813528
# set cost params:  1.0 0.0 642.7656399813528
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.1093039020197466  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  9114.095499896317 [0.         5.73725679]
# 20 12 -----------------
# --------------------- 0
# simulation duration :  21.2
# no solution computed yet
# weight =  642.7656399813528
# set cost params:  1.0 0.0 642.7656399813528
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12784.3256808999
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12781.73777273336
# RUN  2 , total integrated cost =  12781.525099737704
# RUN  3 , total integrated cost =  12780.805211327288
# RUN  4 , total integrated cost =  12779.679230308013
# RUN  5 , total integrated cost =  12779.595443434391
# RUN  6 , total integrated cost =  12779.586354974872
# RUN  7 , total integrated cost =  12779.574985335397
# RUN  8 , total integrated cost =  12779.46215228916
# RUN  9 , total integrated cost =  12778.780219643173
# RUN  10 , total integrated cost =  12778.718296956333
# RUN  11 , total integrated cost =  12778.714248326289
# RUN  12 , total integrated cost =  12778.713375293784
# RUN  13 , total integrated cost =  12778.713009481144
# RUN  14 , total integrated cost =  12778.712816587831
# RUN  15 , total integrated cost =  12778.712666652667
# RUN  16 , total integrated cost =  12778.71249701094
# RUN  17 , total integrated cost =  12778.712337139905
# RUN  18 , total integrated cost =  12778.712224573097
# RUN  19 , total integrated cost =  12778.71197482961
# RUN  20 , total integrated cost =  12778.711382262767
# RUN  30 , total integrated cost =  12777.941448809377
# RUN  40 , total integrated cost =  12777.94144874086
# Control only changes marginally.
# RUN  40 , total integrated cost =  12777.94144874086
# Improved over  40  iterations in  0.9600431119324639  seconds by  0.0499379655868637  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  9095.235486010468 [0.         5.72946924]
# --------------------- 1
# simulation duration :  21.2
# weight =  646.9310491637553
# set cost params:  1.0 0.0 646.9310491637553
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.80703031012
# RUN  2 , total integrated cost =  12801.807030153192
# RUN  3 , total integrated cost =  12801.807030142334
# RUN  4 , total integrated cost =  12801.807030141652
# RUN  5 , total integrated cost =  12801.80703014159
# RUN  6 , total integrated cost =  12801.807030141588
# RUN  7 , total integrated cost =  12801.807030141583
# RUN  8 , total integrated cost =  12801.807030141583
# Control only changes marginally.
# RUN  8 , total integrated cost =  12801.807030141583
# Improved over  8  iterations in  0.2952525749569759  seconds by  1.8602065665618284e-08  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  9095.264239676713 [0.         5.72942479]
# --------------------- 2
# simulation duration :  21.2
# weight =  646.9310495793993
# set cost params:  1.0 0.0 646.9310495793993
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522982
# RUN  2 , total integrated cost =  12801.807032522982
# Control only changes marginally.
# RUN  2 , total integrated cost =  12801.807032522982
# Improved over  2  iterations in  0.21897354093380272  seconds by  1.4210854715202004e-14  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  9095.26423967672 [0.         5.72942479]
# --------------------- 3
# simulation duration :  21.2
# weight =  646.9310495793994
# set cost params:  1.0 0.0 646.9310495793994
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522982
# RUN  2 , total integrated cost =  12801.807032522978
# RUN  3 , total integrated cost =  12801.807032522978
# Control only changes marginally.
# RUN  3 , total integrated cost =  12801.807032522978
# Improved over  3  iterations in  0.26031529903411865  seconds by  4.263256414560601e-14  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  9095.264239677199 [0.         5.72942479]
# --------------------- 4
# simulation duration :  21.2
# weight =  646.9310495794002
# set cost params:  1.0 0.0 646.9310495794002
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.11726361303590238  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  9095.264239677199 [0.         5.72942479]
# 20 13 -----------------
# --------------------- 0
# simulation duration :  21.3
# no solution computed yet
# weight =  646.9310495794002
# set cost params:  1.0 0.0 646.9310495794002
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12783.742731611577
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12781.091553125198
# RUN  2 , total integrated cost =  12780.79678633071
# RUN  3 , total integrated cost =  12780.25054707539
# RUN  4 , total integrated cost =  12779.011703488311
# RUN  5 , total integrated cost =  12778.879878979244
# RUN  6 , total integrated cost =  12778.866497633499
# RUN  7 , total integrated cost =  12778.849316212501
# RUN  8 , total integrated cost =  12778.654790157412
# RUN  9 , total integrated cost =  12777.870232852743
# RUN  10 , total integrated cost =  12777.824990845607
# RUN  11 , total integrated cost =  12777.822681181355
# RUN  12 , total integrated cost =  12777.822451056456
# RUN  13 , total integrated cost =  12777.822434543872
# RUN  14 , total integrated cost =  12777.822428984402
# RUN  15 , total integrated cost =  12777.822427104718
# RUN  16 , total integrated cost =  12777.822426512368
# RUN  17 , total integrated cost =  12777.822426309167
# RUN  18 , total integrated cost =  12777.822426235654
# RUN  19 , total integrated cost =  12777.822426210365
# RUN  20 , total integrated cost =  12777.822426201888
# RUN  30 , total integrated cost =  12777.822426197592
# Control only changes marginally.
# RUN  31 , total integrated cost =  12777.822426197592
# Improved over  31  iterations in  0.700634605018422  seconds by  0.046311205867326066  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  9076.406427739768 [0.     5.7215]
# --------------------- 1
# simulation duration :  21.3
# weight =  651.1230632709978
# set cost params:  1.0 0.0 651.1230632709978
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807006912808
# RUN  2 , total integrated cost =  12801.807003198512
# RUN  3 , total integrated cost =  12801.807002789765
# RUN  4 , total integrated cost =  12801.807002749194
# RUN  5 , total integrated cost =  12801.80700274527
# RUN  6 , total integrated cost =  12801.807002744756
# RUN  7 , total integrated cost =  12801.807002744688
# RUN  8 , total integrated cost =  12801.807002744685
# RUN  9 , total integrated cost =  12801.807002744676
# RUN  10 , total integrated cost =  12801.807002744672
# RUN  11 , total integrated cost =  12801.807002744672
# Control only changes marginally.
# RUN  11 , total integrated cost =  12801.807002744672
# Improved over  11  iterations in  0.21519049198832363  seconds by  2.3261021908638213e-07  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  9076.522798037748 [0.         5.72132123]
# --------------------- 2
# simulation duration :  21.3
# weight =  651.1230684757941
# set cost params:  1.0 0.0 651.1230684757941
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522982
# RUN  2 , total integrated cost =  12801.807032522982
# Control only changes marginally.
# RUN  2 , total integrated cost =  12801.807032522982
# Improved over  2  iterations in  0.14705791207961738  seconds by  1.4210854715202004e-14  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  9076.522798037748 [0.         5.72132123]
# --------------------- 3
# simulation duration :  21.3
# weight =  651.1230684757942
# set cost params:  1.0 0.0 651.1230684757942
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.09372759191319346  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  9076.522798037748 [0.         5.72132123]
# 20 14 -----------------
# --------------------- 0
# simulation duration :  21.4
# no solution computed yet
# weight =  651.1230684757942
# set cost params:  1.0 0.0 651.1230684757942
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12782.929489241822
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12780.244487305761
# RUN  2 , total integrated cost =  12779.99291780624
# RUN  3 , total integrated cost =  12779.607072030025
# RUN  4 , total integrated cost =  12778.121773940684
# RUN  5 , total integrated cost =  12777.85252102921
# RUN  6 , total integrated cost =  12777.827061838101
# RUN  7 , total integrated cost =  12777.765333772028
# RUN  8 , total integrated cost =  12774.922782813457
# RUN  9 , total integrated cost =  12774.832731363163
# RUN  10 , total integrated cost =  12774.82981212818
# RUN  11 , total integrated cost =  12774.829242556649
# RUN  12 , total integrated cost =  12774.829055974318
# RUN  13 , total integrated cost =  12774.828955803589
# RUN  14 , total integrated cost =  12774.828884734103
# RUN  15 , total integrated cost =  12774.828830083343
# RUN  16 , total integrated cost =  12774.82881569826
# RUN  17 , total integrated cost =  12774.82880395669
# RUN  18 , total integrated cost =  12774.828787902721
# RUN  19 , total integrated cost =  12774.82876495079
# RUN  20 , total integrated cost =  12774.82872945248
# Control only changes marginally.
# RUN  24 , total integrated cost =  12774.828665941246
# Improved over  24  iterations in  0.6320458569098264  seconds by  0.06337219733076438  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  9051.160573121218 [0.         5.71883915]
# --------------------- 1
# simulation duration :  21.4
# weight =  655.8405235210053
# set cost params:  1.0 0.0 655.8405235210053
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522982
# RUN  2 , total integrated cost =  12801.807032522982
# Control only changes marginally.
# RUN  2 , total integrated cost =  12801.807032522982
# Improved over  2  iterations in  0.17828406393527985  seconds by  1.4210854715202004e-14  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  9051.160573121222 [0.         5.71883915]
# --------------------- 2
# simulation duration :  21.4
# weight =  655.8405235210056
# set cost params:  1.0 0.0 655.8405235210056
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.14824869495350868  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  9051.160573121222 [0.         5.71883915]
# 20 15 -----------------
# --------------------- 0
# simulation duration :  21.5
# no solution computed yet
# weight =  655.8405235210056
# set cost params:  1.0 0.0 655.8405235210056
# ...
# RUN  5 , total integrated cost =  12756.995883222196
# RUN  6 , total integrated cost =  12756.995883222193
# RUN  7 , total integrated cost =  12756.995883222191
# RUN  8 , total integrated cost =  12756.995883222191
# Control only changes marginally.
# RUN  8 , total integrated cost =  12756.995883222191
# Improved over  8  iterations in  0.43062020605430007  seconds by  0.05846694381642692  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  8171.845851840189 [0.         5.56900539]
# --------------------- 1
# simulation duration :  24.3
# weight =  831.3802658474416
# set cost params:  1.0 0.0 831.3802658474416
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.80444205404
# RUN  2 , total integrated cost =  12801.804436694616
# RUN  3 , total integrated cost =  12801.804436689275
# RUN  4 , total integrated cost =  12801.804436689272
# RUN  5 , total integrated cost =  12801.804436689268
# RUN  6 , total integrated cost =  12801.804436689268
# Control only changes marginally.
# RUN  6 , total integrated cost =  12801.804436689268
# Improved over  6  iterations in  0.2522636209614575  seconds by  2.0277088296438706e-05  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  8172.821103200305 [0.         5.56782922]
# --------------------- 2
# simulation duration :  24.3
# weight =  831.3807320675094
# set cost params:  1.0 0.0 831.3807320675094
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522975
# RUN  2 , total integrated cost =  12801.80703252297
# RUN  3 , total integrated cost =  12801.807032522967
# RUN  4 , total integrated cost =  12801.807032522967
# Control only changes marginally.
# RUN  4 , total integrated cost =  12801.807032522967
# Improved over  4  iterations in  0.257511171977967  seconds by  1.2789769243681803e-13  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  8172.821182699289 [0.         5.56782912]
# --------------------- 3
# simulation duration :  24.3
# weight =  831.3807320675121
# set cost params:  1.0 0.0 831.3807320675121
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522982
# RUN  2 , total integrated cost =  12801.807032522982
# Control only changes marginally.
# RUN  2 , total integrated cost =  12801.807032522982
# Improved over  2  iterations in  0.2085248330840841  seconds by  1.4210854715202004e-14  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  8172.821182699289 [0.         5.56782912]
# --------------------- 4
# simulation duration :  24.3
# weight =  831.3807320675123
# set cost params:  1.0 0.0 831.3807320675123
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.11608817998785526  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  8172.821182699289 [0.         5.56782912]
# 20 44 -----------------
# --------------------- 0
# simulation duration :  24.4
# no solution computed yet
# weight =  831.3807320675123
# set cost params:  1.0 0.0 831.3807320675123
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12761.766109346561
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12761.766109346554
# RUN  2 , total integrated cost =  12761.766109346554
# Control only changes marginally.
# RUN  2 , total integrated cost =  12761.766109346554
# Improved over  2  iterations in  0.26458542502950877  seconds by  5.684341886080802e-14  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  8146.334276342507 [0.        5.5515261]
# --------------------- 1
# simulation duration :  24.4
# weight =  838.5933295508149
# set cost params:  1.0 0.0 838.5933295508149
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.11845902807544917  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  8146.334276342507 [0.        5.5515261]
# 20 45 -----------------
# --------------------- 0
# simulation duration :  24.5
# no solution computed yet
# weight =  838.5933295508149
# set cost params:  1.0 0.0 838.5933295508149
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12762.995385016719
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12755.558610745255
# RUN  2 , total integrated cost =  12755.525877547367
# RUN  3 , total integrated cost =  12755.52586410418
# RUN  4 , total integrated cost =  12755.525863863975
# RUN  5 , total integrated cost =  12755.52586386057
# RUN  6 , total integrated cost =  12755.525863860552
# RUN  7 , total integrated cost =  12755.52586386055
# RUN  8 , total integrated cost =  12755.52586386055
# Control only changes marginally.
# RUN  8 , total integrated cost =  12755.52586386055
# Improved over  8  iterations in  0.356417104951106  seconds by  0.05852482846572116  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  8095.77615173376 [0.         5.55662625]
# --------------------- 1
# simulation duration :  24.5
# weight =  846.9223346952605
# set cost params:  1.0 0.0 846.9223346952605
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.803826963387
# RUN  2 , total integrated cost =  12801.803826889669
# RUN  3 , total integrated cost =  12801.803826889547
# RUN  4 , total integrated cost =  12801.803826889543
# RUN  5 , total integrated cost =  12801.803826889542
# RUN  6 , total integrated cost =  12801.803826889542
# Control only changes marginally.
# RUN  6 , total integrated cost =  12801.803826889542
# Improved over  6  iterations in  0.26787530607543886  seconds by  2.5040476188564753e-05  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  8096.701717302365 [0.         5.55552961]
# --------------------- 2
# simulation duration :  24.5
# weight =  846.9229117119746
# set cost params:  1.0 0.0 846.9229117119746
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.11635900498367846  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  8096.701717302365 [0.         5.55552961]
# 20 46 -----------------
# --------------------- 0
# simulation duration :  24.6
# no solution computed yet
# weight =  846.9229117119746
# set cost params:  1.0 0.0 846.9229117119746
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12760.340171085541
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12760.34017108554
# RUN  2 , total integrated cost =  12760.34017108554
# Control only changes marginally.
# RUN  2 , total integrated cost =  12760.34017108554
# Improved over  2  iterations in  0.18267998495139182  seconds by  1.4210854715202004e-14  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  8068.670589061826 [0.         5.53966544]
# --------------------- 1
# simulation duration :  24.6
# weight =  854.4083568001618
# set cost params:  1.0 0.0 854.4083568001618
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.07316733105108142  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  8068.670589061826 [0.         5.53966544]
# 20 47 -----------------
# --------------------- 0
# simulation duration :  24.7
# no solution computed yet
# weight =  854.4083568001618
# set cost params:  1.0 0.0 854.4083568001618
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12761.628419771987
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12754.028439203643
# RUN  2 , total integrated cost =  12754.015735207078
# RUN  3 , total integrated cost =  12754.015734361545
# RUN  4 , total integrated cost =  12754.015734353901
# RUN  5 , total integrated cost =  12754.01573435388
# RUN  6 , total integrated cost =  12754.015734353878
# RUN  7 , total integrated cost =  12754.015734353876
# RUN  8 , total integrated cost =  12754.015734353874
# RUN  9 , total integrated cost =  12754.015734353874
# Control only changes marginally.
# RUN  9 , total integrated cost =  12754.015734353874
# Improved over  9  iterations in  0.45143323799129575  seconds by  0.05965293117544945  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  8017.618112113996 [0.         5.54348232]
# --------------------- 1
# simulation duration :  24.7
# weight =  863.0295258393238
# set cost params:  1.0 0.0 863.0295258393238
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.803749767992
# RUN  2 , total integrated cost =  12801.803745206438
# RUN  3 , total integrated cost =  12801.803745204072
# RUN  4 , total integrated cost =  12801.80374520407
# RUN  5 , total integrated cost =  12801.803745204064
# RUN  6 , total integrated cost =  12801.803745204064
# Control only changes marginally.
# RUN  6 , total integrated cost =  12801.803745204064
# Improved over  6  iterations in  0.1826885340269655  seconds by  2.5678553910779556e-05  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  8018.654240646102 [0.         5.54227794]
# --------------------- 2
# simulation duration :  24.7
# weight =  863.0301189743043
# set cost params:  1.0 0.0 863.0301189743043
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522982
# RUN  2 , total integrated cost =  12801.807032522982
# Control only changes marginally.
# RUN  2 , total integrated cost =  12801.807032522982
# Improved over  2  iterations in  0.139642178080976  seconds by  1.4210854715202004e-14  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  8018.654240646103 [0.         5.54227794]
# --------------------- 3
# simulation duration :  24.7
# weight =  863.0301189743044
# set cost params:  1.0 0.0 863.0301189743044
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.11148370895534754  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  8018.654240646103 [0.         5.54227794]
# 20 48 -----------------
# --------------------- 0
# simulation duration :  24.8
# no solution computed yet
# weight =  863.0301189743044
# set cost params:  1.0 0.0 863.0301189743044
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12759.042075772817
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12759.042075772815
# RUN  2 , total integrated cost =  12759.042075772815
# Control only changes marginally.
# RUN  2 , total integrated cost =  12759.042075772815
# Improved over  2  iterations in  0.29558231600094587  seconds by  1.4210854715202004e-14  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  7989.371356533092 [0.         5.52665616]
# --------------------- 1
# simulation duration :  24.8
# weight =  870.7680631395385
# set cost params:  1.0 0.0 870.7680631395385
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.1371875060722232  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  7989.371356533092 [0.         5.52665616]
# 20 49 -----------------
# --------------------- 0
# simulation duration :  24.9
# no solution computed yet
# weight =  870.7680631395385
# set cost params:  1.0 0.0 870.7680631395385
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12760.316631451376
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12752.636595392327
# RUN  2 , total integrated cost =  12752.591933989079
# RUN  3 , total integrated cost =  12752.5917654977
# RUN  4 , total integrated cost =  12752.591764505647
# RUN  5 , total integrated cost =  12752.591764501185
# RUN  6 , total integrated cost =  12752.591764501178
# RUN  7 , total integrated cost =  12752.591764501172
# RUN  8 , total integrated cost =  12752.591764501169
# RUN  9 , total integrated cost =  12752.591764501169
# Control only changes marginally.
# RUN  9 , total integrated cost =  12752.591764501169
# Improved over  9  iterations in  0.3590578060830012  seconds by  0.060538207423221024  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  7942.448299810634 [0.         5.52402375]
# --------------------- 1
# simulation duration :  24.9
# weight =  879.6773781998547
# set cost params:  1.0 0.0 879.6773781998547
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.804317858616
# RUN  2 , total integrated cost =  12801.804306689919
# RUN  3 , total integrated cost =  12801.804306469174
# RUN  4 , total integrated cost =  12801.804306468683
# RUN  5 , total integrated cost =  12801.804306468664
# RUN  6 , total integrated cost =  12801.80430646866
# RUN  7 , total integrated cost =  12801.80430646866
# Control only changes marginally.
# RUN  7 , total integrated cost =  12801.80430646866
# Improved over  7  iterations in  0.2553182109259069  seconds by  2.1294293190976532e-05  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  7943.276220725681 [0.         5.52307949]
# --------------------- 2
# simulation duration :  24.9
# weight =  879.6778717749203
# set cost params:  1.0 0.0 879.6778717749203
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522978
# RUN  2 , total integrated cost =  12801.807032522975
# RUN  3 , total integrated cost =  12801.807032522973
# RUN  4 , total integrated cost =  12801.807032522973
# Control only changes marginally.
# RUN  4 , total integrated cost =  12801.807032522973
# Improved over  4  iterations in  0.2550407740054652  seconds by  8.526512829121202e-14  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  7943.276285743337 [0.         5.52307942]
# --------------------- 3
# simulation duration :  24.9
# weight =  879.6778717749222
# set cost params:  1.0 0.0 879.6778717749222
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.11643161403480917  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  7943.276285743337 [0.         5.52307942]
# 20 50 -----------------
# --------------------- 0
# simulation duration :  25.0
# no solution computed yet

# %%
i = 20
for j in [0,10,100]:
    print("simulation duration = ", round(d_array[j],1))
    aln.params.duration = round(d_array[j],1)
    time_ = np.arange(-dur_pre,round(d_array[j]+dur_post+aln.params.dt,1),aln.params.dt)
    dur += dur_pre + dur_post
    target_e = [target[i][0]] * len(time_)
    target_i = [target[i][1]] * len(time_)

    fig, ax = plt.subplots(2,1, constrained_layout=True, figsize = (4,4) )
    ax[1].plot(time_, bestControl_[i][j][0,0,:], color = 'red')
    ax[0].plot(time_, bestState_[i][j][0,0,:], color= 'red')
    ax[1].plot(time_, bestControl_[i][j][0,1,:], color = 'blue')
    ax[0].plot(time_, bestState_[i][j][0,1,:], color= 'blue')
    ax[0].plot(time_, target_e, linestyle = '--', color='red')
    ax[0].plot(time_, target_i, linestyle = '--', color='blue')
    ax[0].set_xlim(-dur_pre,round(d_array[j]+dur_pre,1))
    ax[1].set_xlim(-dur_pre,round(d_array[j]+dur_pre,1))
    ax[0].axvspan(t0_array[j], t0_array[j]+20, alpha=0.2, color='gray')
    plt.show()
# Out:
# simulation duration =  20.0
# simulation duration =  21.0
# simulation duration =  30.0
