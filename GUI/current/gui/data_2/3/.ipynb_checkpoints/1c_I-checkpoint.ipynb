# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import sys
import pickle

path = os.getcwd().split(os.sep + 'GUI')[0]
if path not in sys.path:
    print("not here")
    sys.path.append(path)

from neurolib.models.aln import ALNModel
from neurolib.utils import plotFunctions as plotFunc
from neurolib.utils import costFunctions as cost
import neurolib.dashboard.functions as functions
import neurolib.dashboard.data as data
    
# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2 

#path = os.path.join(os.getcwd(), "plots")
# Out:
# not here

# %%
grid_data_file = os.path.join(os.getcwd().split('data')[0], 'bi.pickle')
print(grid_data_file)
with open(grid_data_file,'rb') as f:
    load_array= pickle.load(f)
exc = load_array[0]
inh = load_array[1]
print(len(exc))
case = '1'
# Out:
# /home/lena/Promotion/neurolib/GUI/current/gui/bi.pickle
# 147

# %% [markdown]
# ### Bistability

# %%
aln = ALNModel()
N = aln.params.N

data.set_parameters(aln)

state_vars = aln.state_vars
init_vars = aln.init_vars

##############################################################
def setinit(init_vars_, model):
    state_vars = model.state_vars
    init_vars = model.init_vars
    for iv in range(len(init_vars)):
        for sv in range(len(state_vars)):
            if state_vars[sv] in init_vars[iv]:
                #print("set init vars ", )
                if model.params[init_vars[iv]].ndim == 2:
                    model.params[init_vars[iv]][0,:] = init_vars_[sv]
                else:
                    model.params[init_vars[iv]][0] = init_vars_[sv]
                    
##############################################################               
def setmaxmincontrol(max_c_c, min_c_c, max_c_r, min_c_r):
    import numpy as np
    
    max_cntrl = np.zeros(( 6 ))
    min_cntrl = np.zeros(( 6 ))
    
    max_cntrl[0] = max_c_c
    min_cntrl[0] = min_c_c
    max_cntrl[1] = max_c_c
    min_cntrl[1] = min_c_c
    max_cntrl[2] = max_c_r
    min_cntrl[2] = min_c_r
    max_cntrl[3] = max_c_r
    min_cntrl[3] = min_c_r
    max_cntrl[4] = max_c_r
    min_cntrl[4] = min_c_r
    max_cntrl[5] = max_c_r
    min_cntrl[5] = min_c_r
            
    return max_cntrl, min_cntrl

# %%
d_array = np.arange(20., 300, 0.1)
t0_array = d_array - 20.
t_pen = np.zeros(( t0_array.shape ))
for i in range(len(t_pen)):
    t_pen[i] = t0_array[i] / d_array[i]

bestControl_ = np.array( [[None] * len(t_pen)] * len(exc) )
bestState_ = np.array( [[None] * len(t_pen)] * len(exc) )
cost_ = np.array( [[None] * len(t_pen)] * len(exc) )
costnode_ = np.array( [[None] * len(t_pen)] * len(exc) )
weights_ = np.array( [[None] * len(t_pen)] * len(exc) )
convergence_ = np.array( [[None] * len(t_pen)] * len(exc) )

initVars = [None] * len(exc)
target = [None] * len(exc)
cost_uncontrolled = [None] * len(exc)

print(bestControl_.shape)
# Out:
# (147, 2800)

# %%
dur_pre = 10
dur_post = 10

n_pre = int(np.around(dur_pre/aln.params.dt + 1.,1))
n_post = int(np.around(dur_post/aln.params.dt + 1.,1))

tol = 1e-32
start_step = 10.
c_scheme = np.zeros(( 1,1 ))
c_scheme[0,0] = 1.
u_mat = np.identity(1)
u_scheme = np.array([[1.]])

c_var = [0,1]
p_var = [0]

if case in ['1', '2']:    # low to high
    max_I = [3., -3.]
else:
    max_I = [-3., 3.]
    
if case in ['1', '3']:    # sparsity
    factor_ws = 1.
    factor_we = 0.
else:
    factor_ws = 0.
    factor_we = 1.
    
maxC = [5., -5., 0.18, 0.]
max_cntrl, min_cntrl = setmaxmincontrol(maxC[0], maxC[1], maxC[2], maxC[3])

# %%
file_ = '1b.pickle'

# %%
if os.path.isfile(file_) :
    print("file found")
    
    with open(file_,'rb') as f:
        load_array = pickle.load(f)

    bestControl_ = load_array[0]
    bestState_ = load_array[1]
    cost_ = load_array[2]
    costnode_ = load_array[3]
    weights_ = load_array[4]

# %%
# get initial parameters and target states

#i_stepsize = 20
#limit = 150
#start_index = 0
#i_range = range(start_index, limit,i_stepsize)
i_range = [20]

data.set_parameters(aln)

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    aln.params.duration = 3000.
    
    control0 = aln.getZeroControl()
    control0 = functions.step_control(aln, maxI_ = max_I[0])

    aln.run(control=control0)
    
    target_rates = np.zeros((2))
    target_rates[0] = aln.rates_exc[0,-1] 
    target_rates[1] = aln.rates_inh[0,-1]

    control0 = functions.step_control(aln, maxI_ = max_I[1])
    aln.run(control=control0)

    init_state_vars = np.zeros(( len(state_vars) ))
    for j in range(len(state_vars)):
        if aln.state[state_vars[j]].size == 1:
            init_state_vars[j] = aln.state[state_vars[j]][0]
        else:
            init_state_vars[j] = aln.state[state_vars[j]][0,-1]

    initVars[i] = init_state_vars
    target[i] = [target_rates[0], target_rates[1]]
# Out:
# -------  20 0.4500000000000001 0.4750000000000002

# %%
# get uncontrolled cost

data.set_parameters(aln)

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    dur = d_array[0]
    aln.params.duration = dur
    
    target_ = aln.getZeroTarget()
    target_[:,0,:] = target[i][0]
    target_[:,1,:] = target[i][1]
        
    cost.setParams(1.0, 0.0, 0.0)

    setinit(initVars[i], aln)
    control0 = aln.getZeroControl()

    # "HS", "FR", "PR", "HZ"
    cgv = None
    max_it = 0

    bestControl_init_, bestState_init_, cost_init_, runtime_init_, grad_init_, phi_init_, phi1_, costnode_init_ = aln.A1(
        control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
        prec_variables_ = p_var, transition_time_ = 0.)
    
    cost_uncontrolled[i] = cost_init_[0]
# Out:
# -------  20 0.4500000000000001 0.4750000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  12801.807032522984
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  0 , total integrated cost =  12801.807032522984
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.

# %%
cgv = None
j = 0
k = 0

while k < 10:
    print('-------------------------------------------- k = ', k)

    for i in i_range:
        print("------- ", i, exc[i], inh[i])
        aln.params.ext_exc_current = exc[i] * 5.
        aln.params.ext_inh_current = inh[i] * 5.

        if convergence_[i][j] == True:
            print('converged')
            continue

        dur = d_array[0]
        aln.params.duration = dur
        
        setinit(initVars[i], aln)

        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        max_it = int(100)

        if type(bestControl_[i][j]) == type(None) or np.amax(np.abs(bestControl_[i][j])) < 1e-6:
            print('no solution found')
            control0 = aln.getZeroControl()
            #control0[0,0,:50] = 5.
            cost.setParams(1.0, 0., 1.)
            max_it = int(1)
            weights_[i][j] = [1., 0., 1.]
        else:
            control0 = bestControl_[i][j][:,:,n_pre-1:-n_post+1]
            l = 1
            while cost_[i][j][-l] == 0.:
                l += 1

            weight_ = ( cost_uncontrolled[i] - costnode_[i][j][0][0][0] ) / sum( costnode_[i][j][2][0][:] )
                
            print("weight = ", weight_)
            cost.setParams(1.0, weight_ * factor_we, weight_ * factor_ws)
            weights_[i][j] = cost.getParams()

        bestControl_[i][j], bestState_[i][j], cost_[i][j], runtime_, grad_, phi_, phi1_, costnode_[i][j] = aln.A1(
            control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
            prec_variables_ = p_var, transition_time_ = t_pen[j])

        if max_it > 1:
            if cost_[i][j][2] == 0.:
                print('converged')
                convergence_[i][j] = True

        print('uncontrolled cost : ', cost_uncontrolled[i])
        print('cost splitting : ', costnode_[i][j][0][0][0], costnode_[i][j][2][0][:2])

        time_ = np.arange(-dur_pre,dur+dur_post+aln.params.dt,aln.params.dt)
        dur += dur_pre + dur_post
        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        if True:
            fig, ax = plt.subplots(2,1, constrained_layout=True, figsize = (4,4) )
            ax[1].plot(time_, bestControl_[i][j][0,0,:], color = 'red')
            ax[0].plot(time_, bestState_[i][j][0,0,:], color= 'red')
            ax[1].plot(time_, bestControl_[i][j][0,1,:], color = 'blue')
            ax[0].plot(time_, bestState_[i][j][0,1,:], color= 'blue')
            ax[0].plot(time_, target_[0,0,:], linestyle = '--', color='red')
            ax[0].plot(time_, target_[0,1,:], linestyle = '--', color='blue')
            ax[0].set_xlim(-dur_pre,dur-dur_post)
            ax[1].set_xlim(-dur_pre,dur-dur_post)
            ax[0].axvspan(t0_array[0], dur, alpha=0.2, color='gray')
            plt.show()

        with open(file_,'wb') as f:
            pickle.dump([bestControl_, bestState_, cost_, costnode_, weights_], f)
    
    k += 1
# Out:
# -------------------------------------------- k =  0
# -------  20 0.4500000000000001 0.4750000000000002
# no solution found
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  12801.807032522984
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7028.817106816711
# RUN  1 , total integrated cost =  7028.817106816711
# Improved over  1  iterations in  17.55582226102706  seconds by  45.09511751770664  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  7022.352130835234 [6.46497598 0.        ]
# -------------------------------------------- k =  1
# -------  20 0.4500000000000001 0.4750000000000002
# weight =  893.9638628582769
# set cost params:  1.0 0.0 893.9638628582769
# interpolate adjoint :  True True True
# initial cost =  12801.807032522984
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12502.573615880003
# RUN  2 , total integrated cost =  12282.402726657583
# RUN  3 , total integrated cost =  12070.565066598327
# RUN  4 , total integrated cost =  11912.290714101808
# RUN  5 , total integrated cost =  11763.917856884547
# RUN  6 , total integrated cost =  11646.507820333409
# RUN  7 , total integrated cost =  11533.963616454199
# RUN  8 , total integrated cost =  11442.194434920108
# RUN  9 , total integrated cost =  11356.349321532143
# RUN  10 , total integrated cost =  11286.475186516192
# RUN  11 , total integrated cost =  11222.547471981032
# RUN  12 , total integrated cost =  11168.019537450471
# RUN  13 , total integrated cost =  11117.332266027826
# RUN  14 , total integrated cost =  11073.718088676356
# RUN  15 , total integrated cost =  11032.612902453468
# RUN  16 , total integrated cost =  10997.852608803205
# RUN  17 , total integrated cost =  10965.253061769523
# RUN  18 , total integrated cost =  10936.228989288546
# RUN  19 , total integrated cost =  10908.858988048667
# RUN  20 , total integrated cost =  10885.87677508157
# RUN  30 , total integrated cost =  10733.168560113536
# RUN  40 , total integrated cost =  10670.430305057018
# RUN  50 , total integrated cost =  10638.961849304973
# RUN  60 , total integrated cost =  10623.562423977983
# RUN  70 , total integrated cost =  10615.713453308854
# RUN  80 , total integrated cost =  10612.004864390754
# RUN  90 , total integrated cost =  10609.909318854781
# RUN  100 , total integrated cost =  10609.14817377926
# RUN  100 , total integrated cost =  10609.14817377926
# Improved over  100  iterations in  13.650433456001338  seconds by  17.12772933675126  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  3071.823081823545 [8.43135322 0.        ]
# -------------------------------------------- k =  2
# -------  20 0.4500000000000001 0.4750000000000002
# weight =  1154.0239981687414
# set cost params:  1.0 0.0 1154.0239981687414
# interpolate adjoint :  True True True
# initial cost =  12801.807032522986
# RUN  0 , total integrated cost =  12801.807032522986
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12785.836094248247
# RUN  2 , total integrated cost =  12778.370103715728
# RUN  3 , total integrated cost =  12773.835432736056
# RUN  4 , total integrated cost =  12770.186571273547
# RUN  5 , total integrated cost =  12767.034641589044
# RUN  6 , total integrated cost =  12764.202646242386
# RUN  7 , total integrated cost =  12761.910389523739
# RUN  8 , total integrated cost =  12760.225499770086
# RUN  9 , total integrated cost =  12758.575201552198
# RUN  10 , total integrated cost =  12756.878625298035
# RUN  11 , total integrated cost =  12755.390153986784
# RUN  12 , total integrated cost =  12754.049087499221
# RUN  13 , total integrated cost =  12752.941863637352
# RUN  14 , total integrated cost =  12751.934596988276
# RUN  15 , total integrated cost =  12751.002543065502
# RUN  16 , total integrated cost =  12750.093077159714
# RUN  17 , total integrated cost =  12749.300529897811
# RUN  18 , total integrated cost =  12748.459969513224
# RUN  19 , total integrated cost =  12747.767395235394
# RUN  20 , total integrated cost =  12747.118454169604
# RUN  30 , total integrated cost =  12742.735032484801
# RUN  40 , total integrated cost =  12741.322652215014
# RUN  50 , total integrated cost =  12740.863963167296
# RUN  60 , total integrated cost =  12740.67564711551
# RUN  70 , total integrated cost =  12740.630683843116
# RUN  80 , total integrated cost =  12740.572217125915
# RUN  90 , total integrated cost =  12740.475335925696
# Control only changes marginally.
# RUN  94 , total integrated cost =  12740.47262921178
# Improved over  94  iterations in  15.555217696004547  seconds by  0.47910738816312914  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  3588.0659659360194 [7.93086338 0.        ]
# -------------------------------------------- k =  3
# -------  20 0.4500000000000001 0.4750000000000002
# weight =  1161.7576332593349
# set cost params:  1.0 0.0 1161.7576332593349
# interpolate adjoint :  True True True
# initial cost =  12801.807032522984
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.801374737839
# RUN  2 , total integrated cost =  12801.795559527665
# RUN  3 , total integrated cost =  12801.792794343208
# RUN  4 , total integrated cost =  12801.78443784566
# RUN  5 , total integrated cost =  12801.772989488614
# RUN  6 , total integrated cost =  12801.766586645432
# RUN  7 , total integrated cost =  12801.760288946669
# RUN  8 , total integrated cost =  12801.756151703112
# RUN  9 , total integrated cost =  12801.752744818927
# RUN  10 , total integrated cost =  12801.75042825797
# RUN  11 , total integrated cost =  12801.746919829122
# RUN  12 , total integrated cost =  12801.746076960735
# RUN  13 , total integrated cost =  12801.74467290628
# RUN  14 , total integrated cost =  12801.743593543812
# RUN  15 , total integrated cost =  12801.742402049651
# RUN  16 , total integrated cost =  12801.741328049331
# RUN  17 , total integrated cost =  12801.739010179976
# RUN  18 , total integrated cost =  12801.737096732073
# RUN  19 , total integrated cost =  12801.737038989333
# RUN  20 , total integrated cost =  12801.735499853168
# Control only changes marginally.
# RUN  25 , total integrated cost =  12801.73477376819
# Improved over  25  iterations in  4.377973216003738  seconds by  0.000564441837084928  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  3605.831995425745 [7.91550881 0.        ]
# -------------------------------------------- k =  4
# -------  20 0.4500000000000001 0.4750000000000002
# weight =  1161.7667620161274
# set cost params:  1.0 0.0 1161.7667620161274
# interpolate adjoint :  True True True
# initial cost =  12801.807032522984
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.20371204701950774  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  3605.831995425745 [7.91550881 0.        ]
# -------------------------------------------- k =  5
# -------  20 0.4500000000000001 0.4750000000000002
# converged
# -------------------------------------------- k =  6
# -------  20 0.4500000000000001 0.4750000000000002
# converged
# -------------------------------------------- k =  7
# -------  20 0.4500000000000001 0.4750000000000002
# converged
# -------------------------------------------- k =  8
# -------  20 0.4500000000000001 0.4750000000000002
# converged
# -------------------------------------------- k =  9
# -------  20 0.4500000000000001 0.4750000000000002
# converged

# %%
for i in range(bestControl_.shape[0]):
    for j in range(1,bestControl_.shape[1]):
        bestControl_[i][j] = None
        convergence_[i][j] = None

# %%
cost.setParams(1.0, factor_we, factor_ws)

j_start = 1

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.

    for j in range(j_start,j_start+500):
        print(i,j, '-----------------')
            
        k = 0
        while convergence_[i][j] != True:
            print('---------------------', k)

            dur = round(d_array[j],1)
            aln.params.duration = dur
            max_it = int(100)  
            
            setinit(initVars[i], aln)
            target_ = aln.getZeroTarget()
            target_[:,0,:] = target[i][0]
            target_[:,1,:] = target[i][1]

            if type(bestControl_[i][j]) == type(None):
                control0 = aln.getZeroControl()
                control0[:,:,1:] = bestControl_[i][j-1][:,:,n_pre-1:-n_post+1]
                                        
                l = 1
                while cost_[i][j-1][-l] == 0.:
                    l += 1
                    
                weight_ = ( cost_uncontrolled[i] - costnode_[i][j-1][0][0][0] ) / sum( costnode_[i][j-1][2][0][:] )
            else:
                control0 = bestControl_[i][j][:,:,n_pre-1:-n_post+1]
                l = 1
                while cost_[i][j][-l] == 0.:
                    l += 1
                
                weight_ = ( cost_uncontrolled[i] - costnode_[i][j][0][0][0] ) / sum( costnode_[i][j][2][0][:] )
                
            cost.setParams(1.0, weight_ * factor_we, weight_ * factor_ws)
            weights_[i][j] = cost.getParams()

            bestControl_[i][j], bestState_[i][j], cost_[i][j], runtime_, grad_, phi_, phi1_, costnode_[i][j] = aln.A1(
                control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
                startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
                t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
                prec_variables_ = p_var, transition_time_ = t_pen[j])

            if cost_[i][j][2] == 0.:
                #print('converged')
                convergence_[i][j] = True

            #print('uncontrolled cost : ', cost_uncontrolled[i])
            print('cost splitting : ', costnode_[i][j][0][0][0], costnode_[i][j][2][0][:2])

            if False:
                time_ = np.arange(-dur_pre,round(dur+dur_post+aln.params.dt,1),aln.params.dt)
                dur += dur_pre + dur_post
                target_ = aln.getZeroTarget()
                target_[:,0,:] = target[i][0]
                target_[:,1,:] = target[i][1]
                
                fig, ax = plt.subplots(2,1, constrained_layout=True, figsize = (4,4) )
                ax[1].plot(time_, bestControl_[i][j][0,0,:], color = 'red')
                ax[0].plot(time_, bestState_[i][j][0,0,:], color= 'red')
                ax[1].plot(time_, bestControl_[i][j][0,1,:], color = 'blue')
                ax[0].plot(time_, bestState_[i][j][0,1,:], color= 'blue')
                ax[0].plot(time_, target_[0,0,:], linestyle = '--', color='red')
                ax[0].plot(time_, target_[0,1,:], linestyle = '--', color='blue')
                ax[0].set_xlim(-dur_pre,dur-dur_post)
                ax[1].set_xlim(-dur_pre,dur-dur_post)
                ax[0].axvspan(t0_array[j], t0_array[j]+20, alpha=0.2, color='gray')
                plt.show()

            with open(file_,'wb') as f:
                pickle.dump([bestControl_, bestState_, cost_, costnode_, weights_], f)
                
            k += 1
# Out:
# set cost params:  1.0 0.0 1.0
# -------  20 0.4500000000000001 0.4750000000000002
# 20 1 -----------------
# 20 2 -----------------
# 20 3 -----------------
# 20 4 -----------------
# 20 5 -----------------
# 20 6 -----------------
# 20 7 -----------------
# 20 8 -----------------
# 20 9 -----------------
# 20 10 -----------------
# 20 11 -----------------
# 20 12 -----------------
# 20 13 -----------------
# 20 14 -----------------
# 20 15 -----------------
# 20 16 -----------------
# 20 17 -----------------
# 20 18 -----------------
# 20 19 -----------------
# 20 20 -----------------
# 20 21 -----------------
# 20 22 -----------------
# 20 23 -----------------
# 20 24 -----------------
# 20 25 -----------------
# 20 26 -----------------
# 20 27 -----------------
# 20 28 -----------------
# 20 29 -----------------
# 20 30 -----------------
# 20 31 -----------------
# 20 32 -----------------
# 20 33 -----------------
# 20 34 -----------------
# 20 35 -----------------
# 20 36 -----------------
# 20 37 -----------------
# 20 38 -----------------
# 20 39 -----------------
# 20 40 -----------------
# 20 41 -----------------
# 20 42 -----------------
# 20 43 -----------------
# 20 44 -----------------
# 20 45 -----------------
# 20 46 -----------------
# 20 47 -----------------
# 20 48 -----------------
# 20 49 -----------------
# 20 50 -----------------
# 20 51 -----------------
# 20 52 -----------------
# 20 53 -----------------
# 20 54 -----------------
# 20 55 -----------------
# 20 56 -----------------
# 20 57 -----------------
# 20 58 -----------------
# 20 59 -----------------
# 20 60 -----------------
# 20 61 -----------------
# 20 62 -----------------
# 20 63 -----------------
# 20 64 -----------------
# 20 65 -----------------
# 20 66 -----------------
# 20 67 -----------------
# 20 68 -----------------
# 20 69 -----------------
# 20 70 -----------------
# 20 71 -----------------
# 20 72 -----------------
# 20 73 -----------------
# 20 74 -----------------
# 20 75 -----------------
# 20 76 -----------------
# 20 77 -----------------
# 20 78 -----------------
# 20 79 -----------------
# 20 80 -----------------
# 20 81 -----------------
# 20 82 -----------------
# 20 83 -----------------
# 20 84 -----------------
# 20 85 -----------------
# 20 86 -----------------
# 20 87 -----------------
# 20 88 -----------------
# 20 89 -----------------
# 20 90 -----------------
# 20 91 -----------------
# 20 92 -----------------
# 20 93 -----------------
# 20 94 -----------------
# 20 95 -----------------
# 20 96 -----------------
# 20 97 -----------------
# 20 98 -----------------
# 20 99 -----------------
# 20 100 -----------------
# 20 101 -----------------
# 20 102 -----------------
# 20 103 -----------------
# 20 104 -----------------
# 20 105 -----------------
# 20 106 -----------------
# 20 107 -----------------
# 20 108 -----------------
# 20 109 -----------------
# 20 110 -----------------
# 20 111 -----------------
# 20 112 -----------------
# 20 113 -----------------
# 20 114 -----------------
# 20 115 -----------------
# 20 116 -----------------
# 20 117 -----------------
# 20 118 -----------------
# 20 119 -----------------
# 20 120 -----------------
# 20 121 -----------------
# 20 122 -----------------
# 20 123 -----------------
# 20 124 -----------------
# 20 125 -----------------
# 20 126 -----------------
# 20 127 -----------------
# 20 128 -----------------
# 20 129 -----------------
# 20 130 -----------------
# 20 131 -----------------
# 20 132 -----------------
# 20 133 -----------------
# 20 134 -----------------
# 20 135 -----------------
# 20 136 -----------------
# 20 137 -----------------
# 20 138 -----------------
# 20 139 -----------------
# 20 140 -----------------
# 20 141 -----------------
# 20 142 -----------------
# 20 143 -----------------
# 20 144 -----------------
# 20 145 -----------------
# 20 146 -----------------
# 20 147 -----------------
# 20 148 -----------------
# 20 149 -----------------
# 20 150 -----------------
# 20 151 -----------------
# 20 152 -----------------
# 20 153 -----------------
# 20 154 -----------------
# 20 155 -----------------
# 20 156 -----------------
# 20 157 -----------------
# 20 158 -----------------
# 20 159 -----------------
# 20 160 -----------------
# 20 161 -----------------
# 20 162 -----------------
# 20 163 -----------------
# 20 164 -----------------
# 20 165 -----------------
# 20 166 -----------------
# 20 167 -----------------
# 20 168 -----------------
# 20 169 -----------------
# 20 170 -----------------
# 20 171 -----------------
# 20 172 -----------------
# 20 173 -----------------
# 20 174 -----------------
# 20 175 -----------------
# 20 176 -----------------
# 20 177 -----------------
# 20 178 -----------------
# 20 179 -----------------
# 20 180 -----------------
# 20 181 -----------------
# 20 182 -----------------
# 20 183 -----------------
# 20 184 -----------------
# 20 185 -----------------
# 20 186 -----------------
# 20 187 -----------------
# 20 188 -----------------
# 20 189 -----------------
# 20 190 -----------------
# 20 191 -----------------
# 20 192 -----------------
# 20 193 -----------------
# 20 194 -----------------
# 20 195 -----------------
# 20 196 -----------------
# 20 197 -----------------
# 20 198 -----------------
# 20 199 -----------------
# 20 200 -----------------
# 20 201 -----------------
# 20 202 -----------------
# 20 203 -----------------
# 20 204 -----------------
# 20 205 -----------------
# 20 206 -----------------
# 20 207 -----------------
# 20 208 -----------------
# 20 209 -----------------
# 20 210 -----------------
# 20 211 -----------------
# 20 212 -----------------
# 20 213 -----------------
# 20 214 -----------------
# 20 215 -----------------
# 20 216 -----------------
# 20 217 -----------------
# 20 218 -----------------
# 20 219 -----------------
# 20 220 -----------------
# 20 221 -----------------
# 20 222 -----------------
# 20 223 -----------------
# 20 224 -----------------
# 20 225 -----------------
# 20 226 -----------------
# 20 227 -----------------
# 20 228 -----------------
# 20 229 -----------------
# 20 230 -----------------
# 20 231 -----------------
# 20 232 -----------------
# 20 233 -----------------
# 20 234 -----------------
# 20 235 -----------------
# 20 236 -----------------
# 20 237 -----------------
# 20 238 -----------------
# 20 239 -----------------
# 20 240 -----------------
# 20 241 -----------------
# 20 242 -----------------
# 20 243 -----------------
# 20 244 -----------------
# 20 245 -----------------
# 20 246 -----------------
# 20 247 -----------------
# 20 248 -----------------
# 20 249 -----------------
# 20 250 -----------------
# 20 251 -----------------
# 20 252 -----------------
# 20 253 -----------------
# 20 254 -----------------
# 20 255 -----------------
# 20 256 -----------------
# 20 257 -----------------
# 20 258 -----------------
# 20 259 -----------------
# 20 260 -----------------
# 20 261 -----------------
# 20 262 -----------------
# 20 263 -----------------
# 20 264 -----------------
# 20 265 -----------------
# 20 266 -----------------
# 20 267 -----------------
# 20 268 -----------------
# 20 269 -----------------
# 20 270 -----------------
# 20 271 -----------------
# 20 272 -----------------
# 20 273 -----------------
# 20 274 -----------------
# 20 275 -----------------
# 20 276 -----------------
# 20 277 -----------------
# 20 278 -----------------
# 20 279 -----------------
# 20 280 -----------------
# 20 281 -----------------
# 20 282 -----------------
# 20 283 -----------------
# 20 284 -----------------
# 20 285 -----------------
# 20 286 -----------------
# 20 287 -----------------
# 20 288 -----------------
# 20 289 -----------------
# 20 290 -----------------
# 20 291 -----------------
# 20 292 -----------------
# 20 293 -----------------
# 20 294 -----------------
# 20 295 -----------------
# 20 296 -----------------
# 20 297 -----------------
# 20 298 -----------------
# 20 299 -----------------
# 20 300 -----------------
# 20 301 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 2758.9810668765513
# interpolate adjoint :  True True True
# initial cost =  12856.203424281426
# RUN  0 , total integrated cost =  12856.203424281426
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12851.254853920878
# RUN  2 , total integrated cost =  12848.244005771992
# RUN  3 , total integrated cost =  12848.022901976312
# RUN  4 , total integrated cost =  12847.793499830244
# RUN  5 , total integrated cost =  12847.64723679053
# RUN  6 , total integrated cost =  12847.474517329989
# RUN  7 , total integrated cost =  12847.352927828806
# RUN  8 , total integrated cost =  12847.206411397057
# RUN  9 , total integrated cost =  12847.09446197861
# RUN  10 , total integrated cost =  12846.94735262062
# RUN  11 , total integrated cost =  12846.826526925355
# RUN  12 , total integrated cost =  12846.598346199396
# RUN  13 , total integrated cost =  12846.434230037754
# RUN  14 , total integrated cost =  12846.078866492368
# RUN  15 , total integrated cost =  12845.829986956145
# RUN  16 , total integrated cost =  12844.42323289517
# RUN  17 , total integrated cost =  12844.037101170841
# RUN  18 , total integrated cost =  12844.03558551276
# RUN  19 , total integrated cost =  12843.938036315978
# RUN  20 , total integrated cost =  12843.87145784981
# RUN  30 , total integrated cost =  12843.748816444902
# Control only changes marginally.
# RUN  37 , total integrated cost =  12843.748815346971
# Improved over  37  iterations in  5.886480693006888  seconds by  0.09687625905895914  percent.
# cost splitting :  35.82491649909184 [4.62282101e+00 1.97964310e-16]
# --------------------- 1
# set cost params:  1.0 0.0 2761.5133897142405
# interpolate adjoint :  True True True
# initial cost =  12855.455290563912
# RUN  0 , total integrated cost =  12855.455290563912
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12855.455290563912
# Control only changes marginally.
# RUN  1 , total integrated cost =  12855.455290563912
# Improved over  1  iterations in  0.2528852630057372  seconds by  0.0  percent.
# cost splitting :  35.82491649909184 [4.62282101e+00 1.97964310e-16]
# 20 302 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 2761.5133897142405
# interpolate adjoint :  True True True
# initial cost =  12855.63352397933
# RUN  0 , total integrated cost =  12855.63352397933
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12851.063403762053
# RUN  2 , total integrated cost =  12848.217961090882
# RUN  3 , total integrated cost =  12848.027035091605
# RUN  4 , total integrated cost =  12847.812715103839
# RUN  5 , total integrated cost =  12847.658994909596
# RUN  6 , total integrated cost =  12847.471464745668
# RUN  7 , total integrated cost =  12847.336832604176
# RUN  8 , total integrated cost =  12847.17115407986
# RUN  9 , total integrated cost =  12847.047656236615
# RUN  10 , total integrated cost =  12846.885846324463
# RUN  11 , total integrated cost =  12846.746362071683
# RUN  12 , total integrated cost =  12846.552813652981
# RUN  13 , total integrated cost =  12846.397011221496
# RUN  14 , total integrated cost =  12846.185087029795
# RUN  15 , total integrated cost =  12846.011274699937
# RUN  16 , total integrated cost =  12845.652039639948
# RUN  17 , total integrated cost =  12845.374096673642
# RUN  18 , total integrated cost =  12843.368567745341
# RUN  19 , total integrated cost =  12843.341210588032
# RUN  20 , total integrated cost =  12843.341162794113
# RUN  30 , total integrated cost =  12843.339471350691
# RUN  40 , total integrated cost =  12843.338505757885
# RUN  50 , total integrated cost =  12843.337727691442
# RUN  60 , total integrated cost =  12843.336931118585
# RUN  70 , total integrated cost =  12843.33609655229
# RUN  80 , total integrated cost =  12843.335878515863
# Control only changes marginally.
# RUN  80 , total integrated cost =  12843.335878515863
# Improved over  80  iterations in  11.13809677498648  seconds by  0.0956595833299616  percent.
# cost splitting :  35.65994010934437 [4.61851728e+00 2.80741006e-16]
# --------------------- 1
# set cost params:  1.0 0.0 2764.122402466042
# interpolate adjoint :  True True True
# initial cost =  12855.385649005682
# RUN  0 , total integrated cost =  12855.385649005682
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12855.385552510385
# RUN  2 , total integrated cost =  12855.385550678917
# RUN  3 , total integrated cost =  12855.385550678531
# RUN  4 , total integrated cost =  12855.385550678522
# RUN  5 , total integrated cost =  12855.38555067852
# RUN  6 , total integrated cost =  12855.38555067852
# Control only changes marginally.
# RUN  6 , total integrated cost =  12855.38555067852
# Improved over  6  iterations in  1.0821835760143586  seconds by  7.648713591379419e-07  percent.
# cost splitting :  35.71425006909764 [4.61846808e+00 2.80741006e-16]
# --------------------- 2
# set cost params:  1.0 0.0 2764.14009196065
# interpolate adjoint :  True True True
# initial cost =  12855.467249044714
# RUN  0 , total integrated cost =  12855.467249044714
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12855.467249044712
# RUN  2 , total integrated cost =  12855.467249044712
# Control only changes marginally.
# RUN  2 , total integrated cost =  12855.467249044712
# Improved over  2  iterations in  0.42952915496425703  seconds by  1.4210854715202004e-14  percent.
# cost splitting :  35.71425005607295 [4.61846808e+00 2.80741006e-16]
# --------------------- 3
# set cost params:  1.0 0.0 2764.140091956413
# interpolate adjoint :  True True True
# initial cost =  12855.467249025145
# RUN  0 , total integrated cost =  12855.467249025145
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12855.467249025145
# Control only changes marginally.
# RUN  1 , total integrated cost =  12855.467249025145
# Improved over  1  iterations in  0.2615407170378603  seconds by  0.0  percent.
# cost splitting :  35.71425005607295 [4.61846808e+00 2.80741006e-16]
# 20 303 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 2764.140091956413
# interpolate adjoint :  True True True
# initial cost =  12855.644931861245
# RUN  0 , total integrated cost =  12855.644931861245
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12851.310873415472
# RUN  2 , total integrated cost =  12848.298464651454
# RUN  3 , total integrated cost =  12848.125635380104
# RUN  4 , total integrated cost =  12847.908998894804
# RUN  5 , total integrated cost =  12847.76955890059
# RUN  6 , total integrated cost =  12847.57681623864
# RUN  7 , total integrated cost =  12847.44168245318
# RUN  8 , total integrated cost =  12847.24704082785
# RUN  9 , total integrated cost =  12847.105151856213
# RUN  10 , total integrated cost =  12846.834576008663
# RUN  11 , total integrated cost =  12846.612328563499
# RUN  12 , total integrated cost =  12845.592877771487
# RUN  13 , total integrated cost =  12844.987803028132
# RUN  14 , total integrated cost =  12844.594140189654
# RUN  15 , total integrated cost =  12844.277414714468
# RUN  16 , total integrated cost =  12844.244548483872
# RUN  17 , total integrated cost =  12844.198459614448
# RUN  18 , total integrated cost =  12844.172587350417
# RUN  19 , total integrated cost =  12844.11055283989
# RUN  20 , total integrated cost =  12844.077325211445
# Control only changes marginally.
# RUN  29 , total integrated cost =  12843.310173988582
# Improved over  29  iterations in  5.508707614033483  seconds by  0.09594818414821304  percent.
# cost splitting :  35.16104928492871 [4.61450749e+00 2.80741006e-16]
# --------------------- 1
# set cost params:  1.0 0.0 2766.6324117499075
# interpolate adjoint :  True True True
# initial cost =  12854.811002340562
# RUN  0 , total integrated cost =  12854.811002340562
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12854.81100234056
# RUN  2 , total integrated cost =  12854.81100234056
# Control only changes marginally.
# RUN  2 , total integrated cost =  12854.81100234056
# Improved over  2  iterations in  0.5359736990067177  seconds by  1.4210854715202004e-14  percent.
# cost splitting :  35.161049284914355 [4.61450749e+00 2.80741006e-16]
# --------------------- 2
# set cost params:  1.0 0.0 2766.632411749903
# interpolate adjoint :  True True True
# initial cost =  12854.81100234054
# RUN  0 , total integrated cost =  12854.81100234054
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12854.81100234054
# Control only changes marginally.
# RUN  1 , total integrated cost =  12854.81100234054
# Improved over  1  iterations in  0.272453207988292  seconds by  0.0  percent.
# cost splitting :  35.161049284914355 [4.61450749e+00 2.80741006e-16]
# 20 304 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 2766.632411749903
# interpolate adjoint :  True True True
# initial cost =  12854.985932933998
# RUN  0 , total integrated cost =  12854.985932933998
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12850.975128461005
# RUN  2 , total integrated cost =  12848.199857249192
# RUN  3 , total integrated cost =  12846.74692339282
# RUN  4 , total integrated cost =  12845.745701762682
# RUN  5 , total integrated cost =  12844.877560518838
# RUN  6 , total integrated cost =  12844.261361690344
# RUN  7 , total integrated cost =  12844.002030534231
# RUN  8 , total integrated cost =  12843.808310416689
# RUN  9 , total integrated cost =  12843.13308531847
# RUN  10 , total integrated cost =  12842.939478649974
# RUN  11 , total integrated cost =  12842.937961000085
# RUN  12 , total integrated cost =  12842.922795796656
# RUN  13 , total integrated cost =  12842.912792662888
# RUN  14 , total integrated cost =  12842.911573983965
# RUN  15 , total integrated cost =  12842.90499017282
# RUN  16 , total integrated cost =  12842.90130121427
# RUN  17 , total integrated cost =  12842.90003903506
# RUN  18 , total integrated cost =  12842.89508050793
# RUN  19 , total integrated cost =  12842.893156331233
# RUN  20 , total integrated cost =  12842.892104340901
# RUN  30 , total integrated cost =  12842.84652247431
# RUN  40 , total integrated cost =  12842.803334362732
# RUN  50 , total integrated cost =  12842.79562047214
# RUN  60 , total integrated cost =  12842.780482815642
# RUN  70 , total integrated cost =  12842.774865759908
# RUN  80 , total integrated cost =  12842.774819016213
# Control only changes marginally.
# RUN  88 , total integrated cost =  12842.771328174369
# Improved over  88  iterations in  15.178668807027861  seconds by  0.09501842182756093  percent.
# cost splitting :  34.90601656404152 [4.61032412e+00 2.80741006e-16]
# --------------------- 1
# set cost params:  1.0 0.0 2769.1981497171064
# interpolate adjoint :  True True True
# initial cost =  12854.600211803921
# RUN  0 , total integrated cost =  12854.600211803921
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12854.60021180392
# RUN  2 , total integrated cost =  12854.60021180392
# Control only changes marginally.
# RUN  2 , total integrated cost =  12854.60021180392
# Improved over  2  iterations in  0.4688940289779566  seconds by  1.4210854715202004e-14  percent.
# cost splitting :  34.90601656403822 [4.61032412e+00 2.80741006e-16]
# --------------------- 2
# set cost params:  1.0 0.0 2769.1981497171055
# interpolate adjoint :  True True True
# initial cost =  12854.600211803916
# RUN  0 , total integrated cost =  12854.600211803916
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12854.600211803916
# Control only changes marginally.
# RUN  1 , total integrated cost =  12854.600211803916
# Improved over  1  iterations in  0.3728590060491115  seconds by  0.0  percent.
# cost splitting :  34.90601656403822 [4.61032412e+00 2.80741006e-16]
# 20 305 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 2769.1981497171055
# interpolate adjoint :  True True True
# initial cost =  12854.773873577868
# RUN  0 , total integrated cost =  12854.773873577868
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12850.336990602433
# RUN  2 , total integrated cost =  12847.42021185788
# RUN  3 , total integrated cost =  12843.26273754325
# RUN  4 , total integrated cost =  12842.682031487937
# RUN  5 , total integrated cost =  12842.680707023255
# RUN  6 , total integrated cost =  12842.676335994825
# RUN  7 , total integrated cost =  12842.6741036669
# RUN  8 , total integrated cost =  12842.664263623028
# RUN  9 , total integrated cost =  12842.65378281893
# RUN  10 , total integrated cost =  12842.653358096013
# RUN  11 , total integrated cost =  12842.64477687035
# RUN  12 , total integrated cost =  12842.639796274245
# RUN  13 , total integrated cost =  12842.639668167429
# RUN  14 , total integrated cost =  12842.615673294062
# RUN  15 , total integrated cost =  12842.613299392207
# RUN  16 , total integrated cost =  12842.613294340947
# RUN  17 , total integrated cost =  12842.613294317049
# RUN  18 , total integrated cost =  12842.61329431696
# RUN  19 , total integrated cost =  12842.613294316958
# RUN  20 , total integrated cost =  12842.613294316958
# Control only changes marginally.
# RUN  20 , total integrated cost =  12842.613294316958
# Improved over  20  iterations in  3.423815952031873  seconds by  0.0945997135422516  percent.
# cost splitting :  34.694505910768896 [4.60612502e+00 1.78872485e-16]
# --------------------- 1
# set cost params:  1.0 0.0 2771.7685598114135
# interpolate adjoint :  True True True
# initial cost =  12854.452924576637
# RUN  0 , total integrated cost =  12854.452924576637
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12854.452924576637
# Control only changes marginally.
# RUN  1 , total integrated cost =  12854.452924576637
# Improved over  1  iterations in  0.23732650000602007  seconds by  0.0  percent.
# cost splitting :  34.694505910768896 [4.60612502e+00 1.78872485e-16]
# 20 306 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 2771.7685598114135
# interpolate adjoint :  True True True
# initial cost =  12854.625534058781
# RUN  0 , total integrated cost =  12854.625534058781
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12850.4135835573
# RUN  2 , total integrated cost =  12847.333092559264
# RUN  3 , total integrated cost =  12844.842166752003
# RUN  4 , total integrated cost =  12843.691917308537
# RUN  5 , total integrated cost =  12843.613166889618
# RUN  6 , total integrated cost =  12843.558603275282
# RUN  7 , total integrated cost =  12843.261197180515
# RUN  8 , total integrated cost =  12843.04716466178
# RUN  9 , total integrated cost =  12842.779147890598
# RUN  10 , total integrated cost =  12842.650355464131
# RUN  11 , total integrated cost =  12842.645887048453
# RUN  12 , total integrated cost =  12842.636129612269
# RUN  13 , total integrated cost =  12842.633331576906
# RUN  14 , total integrated cost =  12842.587294273488
# RUN  15 , total integrated cost =  12842.562870620912
# RUN  16 , total integrated cost =  12842.561674723573
# RUN  17 , total integrated cost =  12842.538732682624
# RUN  18 , total integrated cost =  12842.538196904141
# RUN  19 , total integrated cost =  12842.529942989038
# RUN  20 , total integrated cost =  12842.528342792797
# RUN  30 , total integrated cost =  12842.523539780412
# Control only changes marginally.
# RUN  39 , total integrated cost =  12842.507731732267
# Improved over  39  iterations in  7.155319573008455  seconds by  0.09426803055761468  percent.
# cost splitting :  34.44599858199695 [4.60197931e+00 1.78872485e-16]
# --------------------- 1
# set cost params:  1.0 0.0 2774.3195225500854
# interpolate adjoint :  True True True
# initial cost =  12854.24720946871
# RUN  0 , total integrated cost =  12854.24720946871
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12854.24720946871
# Control only changes marginally.
# RUN  1 , total integrated cost =  12854.24720946871
# Improved over  1  iterations in  0.2555641829967499  seconds by  0.0  percent.
# cost splitting :  34.44599858199695 [4.60197931e+00 1.78872485e-16]
# 20 307 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 2774.3195225500854
# interpolate adjoint :  True True True
# initial cost =  12854.418582595983
# RUN  0 , total integrated cost =  12854.418582595983
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12850.436961122663
# RUN  2 , total integrated cost =  12847.69876689806
# RUN  3 , total integrated cost =  12843.656111171103
# RUN  4 , total integrated cost =  12842.820028088747
# RUN  5 , total integrated cost =  12842.730522848651
# RUN  6 , total integrated cost =  12842.680572989519
# RUN  7 , total integrated cost =  12842.674827218325
# RUN  8 , total integrated cost =  12842.664550716121
# RUN  9 , total integrated cost =  12842.65733899861
# RUN  10 , total integrated cost =  12842.602545093097
# RUN  11 , total integrated cost =  12842.567670753326
# RUN  12 , total integrated cost =  12842.55009098291
# RUN  13 , total integrated cost =  12842.52693397878
# RUN  14 , total integrated cost =  12842.525089192839
# RUN  15 , total integrated cost =  12842.519875843904
# RUN  16 , total integrated cost =  12842.5160318937
# RUN  17 , total integrated cost =  12842.49081824875
# RUN  18 , total integrated cost =  12842.461919821113
# RUN  19 , total integrated cost =  12842.461134971702
# RUN  20 , total integrated cost =  12842.458598090729
# RUN  30 , total integrated cost =  12842.406954034575
# Control only changes marginally.
# RUN  30 , total integrated cost =  12842.406954034575
# Improved over  30  iterations in  5.02516838099109  seconds by  0.09344357727442798  percent.
# cost splitting :  34.21384016000833 [4.59786122e+00 2.75530348e-16]
# --------------------- 1
# set cost params:  1.0 0.0 2776.8548401180637
# interpolate adjoint :  True True True
# initial cost =  12854.063992369365
# RUN  0 , total integrated cost =  12854.063992369365
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12854.063992369365
# Control only changes marginally.
# RUN  1 , total integrated cost =  12854.063992369365
# Improved over  1  iterations in  0.23577135003870353  seconds by  0.0  percent.
# cost splitting :  34.21384016000833 [4.59786122e+00 2.75530348e-16]
# 20 308 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 2776.8548401180637
# interpolate adjoint :  True True True
# initial cost =  12854.234210479613
# RUN  0 , total integrated cost =  12854.234210479613
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12849.607012528799
# RUN  2 , total integrated cost =  12846.457112353482
# RUN  3 , total integrated cost =  12844.52644372148
# RUN  4 , total integrated cost =  12843.546369162927
# RUN  5 , total integrated cost =  12843.155486616177
# RUN  6 , total integrated cost =  12842.878991166455
# RUN  7 , total integrated cost =  12842.63321793727
# RUN  8 , total integrated cost =  12842.491055776938
# RUN  9 , total integrated cost =  12842.484789253369
# RUN  10 , total integrated cost =  12842.467050993224
# RUN  11 , total integrated cost =  12842.459932966856
# RUN  12 , total integrated cost =  12842.298045670728
# RUN  13 , total integrated cost =  12842.281861269295
# RUN  14 , total integrated cost =  12842.274684509866
# RUN  15 , total integrated cost =  12842.242361166514
# RUN  16 , total integrated cost =  12842.239761496636
# RUN  17 , total integrated cost =  12842.239727316266
# RUN  18 , total integrated cost =  12842.239712778206
# RUN  19 , total integrated cost =  12842.23969076796
# RUN  20 , total integrated cost =  12842.239508283415
# RUN  30 , total integrated cost =  12842.23537446258
# Control only changes marginally.
# RUN  35 , total integrated cost =  12842.23537446246
# Improved over  35  iterations in  5.3519673649570905  seconds by  0.09334539748289217  percent.
# cost splitting :  33.95209924173054 [4.59377890e+00 2.68902935e-16]
# --------------------- 1
# set cost params:  1.0 0.0 2779.3795067669485
# interpolate adjoint :  True True True
# initial cost =  12853.833134843644
# RUN  0 , total integrated cost =  12853.833134843644
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12853.833134166905
# RUN  2 , total integrated cost =  12853.833131289892
# RUN  3 , total integrated cost =  12853.83310966922
# RUN  4 , total integrated cost =  12853.83114470545
# RUN  5 , total integrated cost =  12853.827342224922
# RUN  6 , total integrated cost =  12853.827282437847
# RUN  7 , total integrated cost =  12853.827281516677
# RUN  8 , total integrated cost =  12853.827281488151
# RUN  9 , total integrated cost =  12853.827281487287
# RUN  10 , total integrated cost =  12853.82728148726
# RUN  11 , total integrated cost =  12853.827281487253
# RUN  12 , total integrated cost =  12853.827281487249
# RUN  13 , total integrated cost =  12853.827281487249
# Control only changes marginally.
# RUN  13 , total integrated cost =  12853.827281487249
# Improved over  13  iterations in  2.4108771039755084  seconds by  4.5537827773500794e-05  percent.
# cost splitting :  34.04954190800467 [4.59368801e+00 2.68902935e-16]
# --------------------- 2
# set cost params:  1.0 0.0 2779.4132853967526
# interpolate adjoint :  True True True
# initial cost =  12853.982449974057
# RUN  0 , total integrated cost =  12853.982449974057
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12853.982449974057
# Control only changes marginally.
# RUN  1 , total integrated cost =  12853.982449974057
# Improved over  1  iterations in  0.38670404301956296  seconds by  0.0  percent.
# cost splitting :  34.04954190800467 [4.59368801e+00 2.68902935e-16]
# 20 309 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 2779.4132853967526
# interpolate adjoint :  True True True
# initial cost =  12854.151850680068
# RUN  0 , total integrated cost =  12854.151850680068
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12850.617854497787
# RUN  2 , total integrated cost =  12848.066211451374
# RUN  3 , total integrated cost =  12843.436842546822
# RUN  4 , total integrated cost =  12842.479600264784
# RUN  5 , total integrated cost =  12842.475708461438
# RUN  6 , total integrated cost =  12842.462111478708
# RUN  7 , total integrated cost =  12842.455263830787
# RUN  8 , total integrated cost =  12842.443936513333
# RUN  9 , total integrated cost =  12842.424111710217
# RUN  10 , total integrated cost =  12842.421572466616
# RUN  11 , total integrated cost =  12842.387210834699
# RUN  12 , total integrated cost =  12842.366741044223
# RUN  13 , total integrated cost =  12842.36345989566
# RUN  14 , total integrated cost =  12842.355681025852
# RUN  15 , total integrated cost =  12842.35374949513
# RUN  16 , total integrated cost =  12842.25277106569
# RUN  17 , total integrated cost =  12842.2439269109
# RUN  18 , total integrated cost =  12842.243858125274
# RUN  19 , total integrated cost =  12842.24384451221
# RUN  20 , total integrated cost =  12842.243823649236
# Control only changes marginally.
# RUN  27 , total integrated cost =  12842.240992035862
# Improved over  27  iterations in  5.148979364952538  seconds by  0.09266156789313129  percent.
# cost splitting :  33.614763633882966 [4.58979953e+00 2.68902935e-16]
# --------------------- 1
# set cost params:  1.0 0.0 2781.8627318444737
# interpolate adjoint :  True True True
# initial cost =  12853.483460198953
# RUN  0 , total integrated cost =  12853.483460198953
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12853.481813565993
# RUN  2 , total integrated cost =  12853.47924268266
# RUN  3 , total integrated cost =  12853.479221686384
# RUN  4 , total integrated cost =  12853.47921786171
# RUN  5 , total integrated cost =  12853.479214047326
# RUN  6 , total integrated cost =  12853.479212790791
# RUN  7 , total integrated cost =  12853.479212783439
# RUN  8 , total integrated cost =  12853.479212783435
# RUN  9 , total integrated cost =  12853.479212783435
# Control only changes marginally.
# RUN  9 , total integrated cost =  12853.479212783435
# Improved over  9  iterations in  1.6482756299665198  seconds by  3.3044859250708214e-05  percent.
# cost splitting :  33.63011466807369 [4.58978401e+00 2.68902935e-16]
# --------------------- 2
# set cost params:  1.0 0.0 2781.8687989636574
# interpolate adjoint :  True True True
# initial cost =  12853.50705955002
# RUN  0 , total integrated cost =  12853.50705955002
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12853.50705955002
# Control only changes marginally.
# RUN  1 , total integrated cost =  12853.50705955002
# Improved over  1  iterations in  0.2409454970038496  seconds by  0.0  percent.
# cost splitting :  33.63011466807369 [4.58978401e+00 2.68902935e-16]
# 20 310 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 2781.8687989636574
# interpolate adjoint :  True True True
# initial cost =  12853.674373553344
# RUN  0 , total integrated cost =  12853.674373553344
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12848.216984805229
# RUN  2 , total integrated cost =  12845.42760883256
# RUN  3 , total integrated cost =  12845.101831571785
# RUN  4 , total integrated cost =  12844.786627094589
# RUN  5 , total integrated cost =  12844.611037226377
# RUN  6 , total integrated cost =  12844.430400750349
# RUN  7 , total integrated cost =  12844.311158785977
# RUN  8 , total integrated cost =  12844.179422283614
# RUN  9 , total integrated cost =  12844.089107189215
# RUN  10 , total integrated cost =  12843.97863562181
# RUN  11 , total integrated cost =  12843.90631634137
# RUN  12 , total integrated cost =  12843.815906823527
# RUN  13 , total integrated cost =  12843.756905150938
# RUN  14 , total integrated cost =  12843.663927799436
# RUN  15 , total integrated cost =  12843.594784232686
# RUN  16 , total integrated cost =  12843.361784254008
# RUN  17 , total integrated cost =  12843.192847793553
# RUN  18 , total integrated cost =  12841.927571605065
# RUN  19 , total integrated cost =  12841.819309116669
# RUN  20 , total integrated cost =  12841.819202029079
# Control only changes marginally.
# RUN  29 , total integrated cost =  12841.819200852116
# Improved over  29  iterations in  5.085878009034786  seconds by  0.09223178024191725  percent.
# cost splitting :  33.41439879901312 [4.58571956e+00 2.68902935e-16]
# --------------------- 1
# set cost params:  1.0 0.0 2784.3814856731015
# interpolate adjoint :  True True True
# initial cost =  12853.341677436882
# RUN  0 , total integrated cost =  12853.341677436882
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12853.341677436882
# Control only changes marginally.
# RUN  1 , total integrated cost =  12853.341677436882
# Improved over  1  iterations in  0.28606612799922004  seconds by  0.0  percent.
# cost splitting :  33.41439879901312 [4.58571956e+00 2.68902935e-16]
# 20 311 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 2784.3814856731015
# interpolate adjoint :  True True True
# initial cost =  12853.507918226927
# RUN  0 , total integrated cost =  12853.507918226927
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12849.738332776204
# RUN  2 , total integrated cost =  12846.87986044761
# RUN  3 , total integrated cost =  12846.156969040348
# RUN  4 , total integrated cost =  12845.481053941468
# RUN  5 , total integrated cost =  12844.887705069443
# RUN  6 , total integrated cost =  12844.40040848494
# RUN  7 , total integrated cost =  12843.855031826472
# RUN  8 , total integrated cost =  12843.390383848266
# RUN  9 , total integrated cost =  12843.170639834752
# RUN  10 , total integrated cost =  12842.95958043448
# RUN  11 , total integrated cost =  12842.900176559979
# RUN  12 , total integrated cost =  12842.831983872557
# RUN  13 , total integrated cost =  12842.798384787297
# RUN  14 , total integrated cost =  12842.74983345843
# RUN  15 , total integrated cost =  12842.718385243028
# RUN  16 , total integrated cost =  12842.645727270881
# RUN  17 , total integrated cost =  12842.598556616984
# RUN  18 , total integrated cost =  12842.447536189533
# RUN  19 , total integrated cost =  12842.345752506733
# RUN  20 , total integrated cost =  12842.259041135341
# RUN  30 , total integrated cost =  12841.84441738152
# RUN  40 , total integrated cost =  12841.738696800028
# RUN  50 , total integrated cost =  12841.7188162453
# RUN  60 , total integrated cost =  12841.702092273941
# RUN  70 , total integrated cost =  12841.697755756506
# Control only changes marginally.
# RUN  79 , total integrated cost =  12841.677966570232
# Improved over  79  iterations in  11.94698219402926  seconds by  0.09203675550641321  percent.
# cost splitting :  32.90589376244364 [4.58193608e+00 1.92594321e-16]
# --------------------- 1
# set cost params:  1.0 0.0 2786.791637211359
# interpolate adjoint :  True True True
# initial cost =  12852.721126851939
# RUN  0 , total integrated cost =  12852.721126851939
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12852.721126851939
# Control only changes marginally.
# RUN  1 , total integrated cost =  12852.721126851939
# Improved over  1  iterations in  0.23330856097163633  seconds by  0.0  percent.
# cost splitting :  32.90589376244364 [4.58193608e+00 1.92594321e-16]
# 20 312 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 2786.791637211359
# interpolate adjoint :  True True True
# initial cost =  12852.88483776618
# RUN  0 , total integrated cost =  12852.88483776618
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12849.174497557848
# RUN  2 , total integrated cost =  12846.274460556586
# RUN  3 , total integrated cost =  12846.040096509996
# RUN  4 , total integrated cost =  12845.798877895157
# RUN  5 , total integrated cost =  12845.640784651492
# RUN  6 , total integrated cost =  12845.474676987627
# RUN  7 , total integrated cost =  12845.343195700269
# RUN  8 , total integrated cost =  12845.19337383031
# RUN  9 , total integrated cost =  12845.063198735332
# RUN  10 , total integrated cost =  12844.898724093766
# RUN  11 , total integrated cost =  12844.768180312214
# RUN  12 , total integrated cost =  12844.602718849914
# RUN  13 , total integrated cost =  12844.469863034059
# RUN  14 , total integrated cost =  12844.286521147196
# RUN  15 , total integrated cost =  12844.13026415067
# RUN  16 , total integrated cost =  12843.889854885994
# RUN  17 , total integrated cost =  12843.702959084218
# RUN  18 , total integrated cost =  12843.165978012139
# RUN  19 , total integrated cost =  12842.735468788935
# RUN  20 , total integrated cost =  12842.421175145993
# Control only changes marginally.
# RUN  27 , total integrated cost =  12841.140959571789
# Improved over  27  iterations in  4.4073468500282615  seconds by  0.09137153520495644  percent.
# cost splitting :  32.67367618464719 [4.57793463e+00 1.92594321e-16]
# --------------------- 1
# set cost params:  1.0 0.0 2789.27822166161
# interpolate adjoint :  True True True
# initial cost =  12852.524380630495
# RUN  0 , total integrated cost =  12852.524380630495
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12852.523070404748
# RUN  2 , total integrated cost =  12852.523041478256
# RUN  3 , total integrated cost =  12852.523041478253
# RUN  4 , total integrated cost =  12852.523041478253
# Control only changes marginally.
# RUN  4 , total integrated cost =  12852.523041478253
# Improved over  4  iterations in  0.8259625970385969  seconds by  1.0419371349712492e-05  percent.
# cost splitting :  32.82917373114402 [4.57779186e+00 1.92594321e-16]
# --------------------- 2
# set cost params:  1.0 0.0 2789.3312403407776
# interpolate adjoint :  True True True
# initial cost =  12852.7657499564
# RUN  0 , total integrated cost =  12852.7657499564
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12852.765749956396
# RUN  2 , total integrated cost =  12852.765749956394
# RUN  3 , total integrated cost =  12852.765749956392
# RUN  4 , total integrated cost =  12852.765749956392
# Control only changes marginally.
# RUN  4 , total integrated cost =  12852.765749956392
# Improved over  4  iterations in  0.8647520010126755  seconds by  5.684341886080802e-14  percent.
# cost splitting :  32.829173731083266 [4.57779186e+00 1.92594321e-16]
# --------------------- 3
# set cost params:  1.0 0.0 2789.331240340759
# interpolate adjoint :  True True True
# initial cost =  12852.765749956307
# RUN  0 , total integrated cost =  12852.765749956307
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12852.765749956307
# Control only changes marginally.
# RUN  1 , total integrated cost =  12852.765749956307
# Improved over  1  iterations in  0.2439863359904848  seconds by  0.0  percent.
# cost splitting :  32.829173731083266 [4.57779186e+00 1.92594321e-16]
# 20 313 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 2789.331240340759
# interpolate adjoint :  True True True
# initial cost =  12852.92907917885
# RUN  0 , total integrated cost =  12852.92907917885
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12850.12755418269
# RUN  2 , total integrated cost =  12847.86687334458
# RUN  3 , total integrated cost =  12847.38969903434
# RUN  4 , total integrated cost =  12846.930318941428
# RUN  5 , total integrated cost =  12846.73057275036
# RUN  6 , total integrated cost =  12846.507798499064
# RUN  7 , total integrated cost =  12846.346767194644
# RUN  8 , total integrated cost =  12846.16134719506
# RUN  9 , total integrated cost =  12846.009952677867
# RUN  10 , total integrated cost =  12845.822150816208
# RUN  11 , total integrated cost =  12845.656493595492
# RUN  12 , total integrated cost =  12845.402313883707
# RUN  13 , total integrated cost =  12845.171716140201
# RUN  14 , total integrated cost =  12844.89185645119
# RUN  15 , total integrated cost =  12844.644422546513
# RUN  16 , total integrated cost =  12843.980144987605
# RUN  17 , total integrated cost =  12843.46487040589
# RUN  18 , total integrated cost =  12842.701781803195
# RUN  19 , total integrated cost =  12842.116740670164
# RUN  20 , total integrated cost =  12842.078388843935
# RUN  30 , total integrated cost =  12841.61443538989
# RUN  40 , total integrated cost =  12841.452899472259
# RUN  50 , total integrated cost =  12841.250842146912
# Control only changes marginally.
# RUN  55 , total integrated cost =  12841.250842047462
# Improved over  55  iterations in  9.258987508015707  seconds by  0.09086051171250631  percent.
# cost splitting :  32.47212817032922 [4.57393245e+00 1.92594321e-16]
# --------------------- 1
# set cost params:  1.0 0.0 2791.762898643785
# interpolate adjoint :  True True True
# initial cost =  12852.373082857874
# RUN  0 , total integrated cost =  12852.373082857874
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12852.373082857874
# Control only changes marginally.
# RUN  1 , total integrated cost =  12852.373082857874
# Improved over  1  iterations in  0.35888145497301593  seconds by  0.0  percent.
# cost splitting :  32.47212817032922 [4.57393245e+00 1.92594321e-16]
# 20 314 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 2791.762898643785
# interpolate adjoint :  True True True
# initial cost =  12852.534635734344
# RUN  0 , total integrated cost =  12852.534635734344
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12848.756498928957
# RUN  2 , total integrated cost =  12845.982235857873
# RUN  3 , total integrated cost =  12845.808904958707
# RUN  4 , total integrated cost =  12845.609646077917
# RUN  5 , total integrated cost =  12845.473050889364
# RUN  6 , total integrated cost =  12845.299140750685
# RUN  7 , total integrated cost =  12845.16828529637
# RUN  8 , total integrated cost =  12844.976639250153
# RUN  9 , total integrated cost =  12844.819328098787
# RUN  10 , total integrated cost =  12844.517286833294
# RUN  11 , total integrated cost =  12844.259244013672
# RUN  12 , total integrated cost =  12843.27926641406
# RUN  13 , total integrated cost =  12842.553573973037
# RUN  14 , total integrated cost =  12842.373398752556
# RUN  15 , total integrated cost =  12842.181642099444
# RUN  16 , total integrated cost =  12842.107979604436
# RUN  17 , total integrated cost =  12842.020057348167
# RUN  18 , total integrated cost =  12841.981503279094
# RUN  19 , total integrated cost =  12841.927680823721
# RUN  20 , total integrated cost =  12841.901728780593
# Control only changes marginally.
# RUN  28 , total integrated cost =  12840.897351440839
# Improved over  28  iterations in  4.795617813011631  seconds by  0.09054466393850191  percent.
# cost splitting :  32.26112459260586 [4.56995766e+00 1.92594321e-16]
# --------------------- 1
# set cost params:  1.0 0.0 2794.237244720589
# interpolate adjoint :  True True True
# initial cost =  12852.205008254718
# RUN  0 , total integrated cost =  12852.205008254718
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12852.205008254716
# RUN  2 , total integrated cost =  12852.205008254714
# RUN  3 , total integrated cost =  12852.205008254714
# Control only changes marginally.
# RUN  3 , total integrated cost =  12852.205008254714
# Improved over  3  iterations in  0.601469206972979  seconds by  2.842170943040401e-14  percent.
# cost splitting :  32.261124592569544 [4.56995766e+00 1.92594321e-16]
# --------------------- 2
# set cost params:  1.0 0.0 2794.2372447205767
# interpolate adjoint :  True True True
# initial cost =  12852.20500825466
# RUN  0 , total integrated cost =  12852.20500825466
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12852.20500825466
# Control only changes marginally.
# RUN  1 , total integrated cost =  12852.20500825466
# Improved over  1  iterations in  0.2578347960370593  seconds by  0.0  percent.
# cost splitting :  32.261124592569544 [4.56995766e+00 1.92594321e-16]
# 20 315 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 2794.2372447205767
# interpolate adjoint :  True True True
# initial cost =  12852.365511362086
# RUN  0 , total integrated cost =  12852.365511362086
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12847.844252158002
# RUN  2 , total integrated cost =  12844.78619477245
# RUN  3 , total integrated cost =  12844.66259496715
# RUN  4 , total integrated cost =  12844.520788245243
# RUN  5 , total integrated cost =  12844.414271750074
# RUN  6 , total integrated cost =  12844.280724232423
# RUN  7 , total integrated cost =  12844.175459659322
# RUN  8 , total integrated cost =  12844.013138761138
# RUN  9 , total integrated cost =  12843.891245176754
# RUN  10 , total integrated cost =  12843.515104143522
# RUN  11 , total integrated cost =  12843.195835924333
# RUN  12 , total integrated cost =  12842.504394813366
# RUN  13 , total integrated cost =  12842.021172260509
# RUN  14 , total integrated cost =  12841.157287180693
# RUN  15 , total integrated cost =  12840.877781960575
# RUN  16 , total integrated cost =  12840.876333716044
# RUN  17 , total integrated cost =  12840.86248674561
# RUN  18 , total integrated cost =  12840.848322467209
# RUN  19 , total integrated cost =  12840.847820876917
# RUN  20 , total integrated cost =  12840.837761736519
# RUN  30 , total integrated cost =  12840.798332474033
# Control only changes marginally.
# RUN  32 , total integrated cost =  12840.79833247403
# Improved over  32  iterations in  5.408955221995711  seconds by  0.09000038847190694  percent.
# cost splitting :  32.07402757194708 [4.56598990e+00 1.92594321e-16]
# --------------------- 1
# set cost params:  1.0 0.0 2796.7063625649084
# interpolate adjoint :  True True True
# initial cost =  12852.072299613348
# RUN  0 , total integrated cost =  12852.072299613348
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12852.072299613348
# Control only changes marginally.
# RUN  1 , total integrated cost =  12852.072299613348
# Improved over  1  iterations in  0.3691784730181098  seconds by  0.0  percent.
# cost splitting :  32.07402757194708 [4.56598990e+00 1.92594321e-16]
# 20 316 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 2796.7063625649084
# interpolate adjoint :  True True True
# initial cost =  12852.231871889826
# RUN  0 , total integrated cost =  12852.231871889826
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12849.242288675452
# RUN  2 , total integrated cost =  12846.921445434155
# RUN  3 , total integrated cost =  12846.696278652793
# RUN  4 , total integrated cost =  12846.436166013766
# RUN  5 , total integrated cost =  12846.262560747811
# RUN  6 , total integrated cost =  12846.057225430379
# RUN  7 , total integrated cost =  12845.898250941465
# RUN  8 , total integrated cost =  12845.704809749428
# RUN  9 , total integrated cost =  12845.5508971262
# RUN  10 , total integrated cost =  12845.358807162282
# RUN  11 , total integrated cost =  12845.19736984527
# RUN  12 , total integrated cost =  12844.97004138706
# RUN  13 , total integrated cost =  12844.783393290976
# RUN  14 , total integrated cost =  12844.317659894308
# RUN  15 , total integrated cost =  12843.937520577892
# RUN  16 , total integrated cost =  12843.128277845903
# RUN  17 , total integrated cost =  12842.541050952637
# RUN  18 , total integrated cost =  12842.401652463108
# RUN  19 , total integrated cost =  12842.249602541242
# RUN  20 , total integrated cost =  12842.156254323876
# ...
# RUN  13 , total integrated cost =  12830.571887014792
# RUN  14 , total integrated cost =  12830.230469592143
# RUN  15 , total integrated cost =  12829.9421278489
# RUN  16 , total integrated cost =  12829.450233090996
# RUN  17 , total integrated cost =  12829.076280153864
# RUN  18 , total integrated cost =  12828.130330953672
# RUN  19 , total integrated cost =  12827.410654878762
# RUN  20 , total integrated cost =  12827.370881820234
# RUN  30 , total integrated cost =  12826.609038686778
# RUN  40 , total integrated cost =  12826.483739570196
# RUN  50 , total integrated cost =  12826.201346255917
# RUN  60 , total integrated cost =  12826.158630865728
# RUN  70 , total integrated cost =  12826.155063765113
# Control only changes marginally.
# RUN  79 , total integrated cost =  12826.13551826752
# Improved over  79  iterations in  20.470170435030013  seconds by  0.05685790074132058  percent.
# cost splitting :  15.168824556506326 [4.26163237e+00 2.11880830e-16]
# --------------------- 1
# set cost params:  1.0 0.0 3000.408548673791
# interpolate adjoint :  True True True
# initial cost =  12833.201216679734
# RUN  0 , total integrated cost =  12833.201216679734
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12833.201216679732
# RUN  2 , total integrated cost =  12833.201216679732
# Control only changes marginally.
# RUN  2 , total integrated cost =  12833.201216679732
# Improved over  2  iterations in  0.8044387670233846  seconds by  1.4210854715202004e-14  percent.
# cost splitting :  15.168824556506003 [4.26163237e+00 2.11880830e-16]
# --------------------- 2
# set cost params:  1.0 0.0 3000.408548673791
# interpolate adjoint :  True True True
# initial cost =  12833.201216679732
# RUN  0 , total integrated cost =  12833.201216679732
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12833.201216679732
# Control only changes marginally.
# RUN  1 , total integrated cost =  12833.201216679732
# Improved over  1  iterations in  0.3711974530015141  seconds by  0.0  percent.
# cost splitting :  15.168824556506003 [4.26163237e+00 2.11880830e-16]
# 20 417 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 3000.408548673791
# interpolate adjoint :  True True True
# initial cost =  12833.276683468572
# RUN  0 , total integrated cost =  12833.276683468572
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12832.103753009762
# RUN  2 , total integrated cost =  12830.967610904912
# RUN  3 , total integrated cost =  12830.872632226958
# RUN  4 , total integrated cost =  12830.762465849724
# RUN  5 , total integrated cost =  12830.688341798563
# RUN  6 , total integrated cost =  12830.593937787182
# RUN  7 , total integrated cost =  12830.519139585138
# RUN  8 , total integrated cost =  12830.425744025802
# RUN  9 , total integrated cost =  12830.350484799575
# RUN  10 , total integrated cost =  12830.248269644771
# RUN  11 , total integrated cost =  12830.16179781863
# RUN  12 , total integrated cost =  12830.046776285362
# RUN  13 , total integrated cost =  12829.941939215993
# RUN  14 , total integrated cost =  12829.686760330096
# RUN  15 , total integrated cost =  12829.463658941979
# RUN  16 , total integrated cost =  12828.972782794272
# RUN  17 , total integrated cost =  12828.558917280898
# RUN  18 , total integrated cost =  12827.783408216874
# RUN  19 , total integrated cost =  12827.130392956476
# RUN  20 , total integrated cost =  12827.107976270468
# RUN  30 , total integrated cost =  12826.066802498219
# RUN  40 , total integrated cost =  12826.06350829685
# RUN  50 , total integrated cost =  12826.038240649028
# Control only changes marginally.
# RUN  50 , total integrated cost =  12826.038240649028
# Improved over  50  iterations in  12.098819104023278  seconds by  0.056403699523343676  percent.
# cost splitting :  15.066020051909423 [4.25932524e+00 2.11880830e-16]
# --------------------- 1
# set cost params:  1.0 0.0 3002.057908946279
# interpolate adjoint :  True True True
# initial cost =  12833.063402481423
# RUN  0 , total integrated cost =  12833.063402481423
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12833.063402481423
# Control only changes marginally.
# RUN  1 , total integrated cost =  12833.063402481423
# Improved over  1  iterations in  0.2981256140046753  seconds by  0.0  percent.
# cost splitting :  15.066020051909423 [4.25932524e+00 2.11880830e-16]
# 20 418 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 3002.057908946279
# interpolate adjoint :  True True True
# initial cost =  12833.138357805065
# RUN  0 , total integrated cost =  12833.138357805065
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12832.238043542202
# RUN  2 , total integrated cost =  12831.348285893027
# RUN  3 , total integrated cost =  12831.23754648048
# RUN  4 , total integrated cost =  12831.111523849064
# RUN  5 , total integrated cost =  12831.026639120557
# RUN  6 , total integrated cost =  12830.926385171822
# RUN  7 , total integrated cost =  12830.848544860833
# RUN  8 , total integrated cost =  12830.747200635928
# RUN  9 , total integrated cost =  12830.662102440067
# RUN  10 , total integrated cost =  12830.522596534078
# RUN  11 , total integrated cost =  12830.386722906207
# RUN  12 , total integrated cost =  12830.227692553242
# RUN  13 , total integrated cost =  12830.083804934831
# RUN  14 , total integrated cost =  12829.946666897798
# RUN  15 , total integrated cost =  12829.822347761858
# RUN  16 , total integrated cost =  12829.692860935507
# RUN  17 , total integrated cost =  12829.577611757542
# RUN  18 , total integrated cost =  12829.45780724784
# RUN  19 , total integrated cost =  12829.34825332104
# RUN  20 , total integrated cost =  12829.226165904718
# Control only changes marginally.
# RUN  29 , total integrated cost =  12825.948866088354
# Improved over  29  iterations in  6.881151755980682  seconds by  0.05602286452665339  percent.
# cost splitting :  14.994773509123808 [4.25700347e+00 2.11880830e-16]
# --------------------- 1
# set cost params:  1.0 0.0 3003.711966152539
# interpolate adjoint :  True True True
# initial cost =  12832.990193352902
# RUN  0 , total integrated cost =  12832.990193352902
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12832.990193352902
# Control only changes marginally.
# RUN  1 , total integrated cost =  12832.990193352902
# Improved over  1  iterations in  0.295844994019717  seconds by  0.0  percent.
# cost splitting :  14.994773509123808 [4.25700347e+00 2.11880830e-16]
# 20 419 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 3003.711966152539
# interpolate adjoint :  True True True
# initial cost =  12833.064794216132
# RUN  0 , total integrated cost =  12833.064794216132
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12831.63748695177
# RUN  2 , total integrated cost =  12830.527807003882
# RUN  3 , total integrated cost =  12830.450650257892
# RUN  4 , total integrated cost =  12830.352259883026
# RUN  5 , total integrated cost =  12830.283805778598
# RUN  6 , total integrated cost =  12830.190966925362
# RUN  7 , total integrated cost =  12830.123347515939
# RUN  8 , total integrated cost =  12830.011131001576
# RUN  9 , total integrated cost =  12829.918189287346
# RUN  10 , total integrated cost =  12829.73854598708
# RUN  11 , total integrated cost =  12829.584612061572
# RUN  12 , total integrated cost =  12829.31888923926
# RUN  13 , total integrated cost =  12829.09519043657
# RUN  14 , total integrated cost =  12826.938296707178
# RUN  15 , total integrated cost =  12826.226375378143
# RUN  16 , total integrated cost =  12826.206074806436
# RUN  17 , total integrated cost =  12826.187956281188
# RUN  18 , total integrated cost =  12826.182909803458
# RUN  19 , total integrated cost =  12826.173709732338
# RUN  20 , total integrated cost =  12826.17166243953
# RUN  30 , total integrated cost =  12825.870806804314
# Control only changes marginally.
# RUN  37 , total integrated cost =  12825.870806792818
# Improved over  37  iterations in  8.09609620302217  seconds by  0.05605821788225285  percent.
# cost splitting :  14.894930150833313 [4.25471097e+00 2.11880830e-16]
# --------------------- 1
# set cost params:  1.0 0.0 3005.35387703595
# interpolate adjoint :  True True True
# initial cost =  12832.856663036413
# RUN  0 , total integrated cost =  12832.856663036413
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12832.856663036411
# RUN  2 , total integrated cost =  12832.856663036411
# Control only changes marginally.
# RUN  2 , total integrated cost =  12832.856663036411
# Improved over  2  iterations in  0.7841404660139233  seconds by  1.4210854715202004e-14  percent.
# cost splitting :  14.894930150832975 [4.25471097e+00 2.11880830e-16]
# --------------------- 2
# set cost params:  1.0 0.0 3005.35387703595
# interpolate adjoint :  True True True
# initial cost =  12832.856663036411
# RUN  0 , total integrated cost =  12832.856663036411
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12832.856663036411
# Control only changes marginally.
# RUN  1 , total integrated cost =  12832.856663036411
# Improved over  1  iterations in  0.3511339009855874  seconds by  0.0  percent.
# cost splitting :  14.894930150832975 [4.25471097e+00 2.11880830e-16]
# 20 420 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 3005.35387703595
# interpolate adjoint :  True True True
# initial cost =  12832.930767166516
# RUN  0 , total integrated cost =  12832.930767166516
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12831.382980967384
# RUN  2 , total integrated cost =  12830.148768204263
# RUN  3 , total integrated cost =  12829.851115257889
# RUN  4 , total integrated cost =  12829.523813008558
# RUN  5 , total integrated cost =  12829.449424577504
# RUN  6 , total integrated cost =  12829.35867522761
# RUN  7 , total integrated cost =  12829.303032704469
# RUN  8 , total integrated cost =  12829.231154049285
# RUN  9 , total integrated cost =  12829.182002141051
# RUN  10 , total integrated cost =  12829.115658114057
# RUN  11 , total integrated cost =  12829.068357971231
# RUN  12 , total integrated cost =  12828.993988704635
# RUN  13 , total integrated cost =  12828.933847445413
# RUN  14 , total integrated cost =  12828.815903930812
# RUN  15 , total integrated cost =  12828.721370324736
# RUN  16 , total integrated cost =  12828.514861270933
# RUN  17 , total integrated cost =  12828.332356290453
# RUN  18 , total integrated cost =  12826.519835664523
# RUN  19 , total integrated cost =  12826.047600598005
# RUN  20 , total integrated cost =  12826.044680797833
# RUN  30 , total integrated cost =  12825.820102220581
# RUN  40 , total integrated cost =  12825.820082277638
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/.local/lib/python3.9/site-packages/numpy/core/fromnumeric.py in _wrapit(obj, method, *args, **kwds)
#      39     try:
# ---> 40         wrap = obj.__array_wrap__
#      41     except AttributeError:
#
# AttributeError: 'float' object has no attribute '__array_wrap__'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_208767/2747809524.py in <module>
#      44             weights_[i][j] = cost.getParams()
#      45
# ---> 46             bestControl_[i][j], bestState_[i][j], cost_[i][j], runtime_, grad_, phi_, phi1_, costnode_[i][j] = aln.A1(
#      47                 control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
#      48                 startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
#
# ~/Promotion/neurolib/neurolib/models/model.py in A1(self, control_, target_state_, c_scheme_, u_mat_, u_scheme_, max_iteration_, tolerance_, startStep_, max_control_, min_control_, t_sim_, t_sim_pre_, t_sim_post_, CGVar, line_search_, control_variables_, prec_variables_, separate_comp, transition_time_, noise_real, init_params)
#     661             if self.params.N == 1:
#     662                 if noise_real == 0:
# --> 663                     return opti1_rate_control.A1(self, control_, target_state_, c_scheme_, u_mat_, u_scheme_, max_iteration_,
#     664                                                 tolerance_, startStep_, max_control_, min_control_, t_sim_, t_sim_pre_, t_sim_post_, CGVar,
#     665                                                 line_search_, control_variables_, prec_variables_, separate_comp, transition_time_)
#
# ~/Promotion/neurolib/neurolib/utils/A1_aln_rate_control.py in A1(model, control_, target_state, c_scheme_, u_mat_, u_scheme_, max_iteration_, tolerance_, startStep_, cntrl_max_, cntrl_min_, t_sim_, t_sim_pre_, t_sim_post_, CGVar, line_search_, control_variables_, prec_variables_, separate_comp, transition_time_)
#     398                 d_inh[:,2:,:] = 0.
#     399
# --> 400                 s_inh, tc_inh, startstep_inh_ = line_search_func(model, N, n_control_vars, T, dt, state1_[:,:2,:], target_state_,
#     401                              best_control_, d_inh, ip_, ie_, is_, start_step_ = startstep_inh_, max_it_ = 500,
#     402                              max_control_ = cntrl_max_, min_control_ = cntrl_min_, tolerance_ = tolerance_step, variables_ = prec_variables, grad_ = grad1_)
#
# ~/Promotion/neurolib/neurolib/utils/func_optimize.py in step_size(model, N, V, T, dt, state_, target_, control_, dir_, ip_, ie_, is_, start_step_, max_it_, bisec_factor_, max_control_, min_control_, tolerance_, substep_, variables_, alg, control_parameter, grad_, noise_real, init_vars, startind_)
#     233                 #print(init_vars)
#     234                 set_init(model, init_vars, model.init_vars, model.state_vars, startind_)
# --> 235             state1_ = updateState(model, test_control_)
#     236             cost1_int_ = cost.f_int(N, V, T, dt, state1_, target_, test_control_, ip_, ie_, is_, v_ = variables_)
#     237         else:
#
# ~/Promotion/neurolib/neurolib/utils/func_optimize.py in updateState(model, control_)
#       8     state_ = model.getZeroState()
#       9     output_vars = model.output_vars
# ---> 10     model.run(control = control_)
#      11     for i in range(len(output_vars)):
#      12         state_[:,i,:] = model[output_vars[i]][:,:]
#
# ~/Promotion/neurolib/neurolib/models/model.py in run(self, inputs, chunkwise, chunksize, bold, append, append_outputs, continue_run, control)
#     182
#     183         if chunkwise is False:
# --> 184             self.integrate(append_outputs=append, simulate_bold=bold, control=cntrl)
#     185             if continue_run:
#     186                 self.setInitialValuesToLastState()
#
# ~/Promotion/neurolib/neurolib/models/model.py in integrate(self, append_outputs, simulate_bold, control)
#     223         # run integration
#     224         #print("before integration")
# --> 225         t, *variables = self.integration(self.params, control=control)
#     226         #print("after integration")
#     227         self.storeOutputsAndStates(t, variables, append=append_outputs)
#
# ~/Promotion/neurolib/neurolib/models/aln/timeIntegration.py in timeIntegration(params, control)
#     170     sqrt_dt = np.sqrt(dt)
#     171
# --> 172     ndt_de = np.around(de / dt).astype(int)
#     173     ndt_di = np.around(di / dt).astype(int)
#     174
#
# <__array_function__ internals> in around(*args, **kwargs)
#
# ~/.local/lib/python3.9/site-packages/numpy/core/fromnumeric.py in around(a, decimals, out)
#    3312
#    3313     """
# -> 3314     return _wrapfunc(a, 'round', decimals=decimals, out=out)
#    3315
#    3316
#
# ~/.local/lib/python3.9/site-packages/numpy/core/fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      52     bound = getattr(obj, method, None)
#      53     if bound is None:
# ---> 54         return _wrapit(obj, method, *args, **kwds)
#      55
#      56     try:
#
# ~/.local/lib/python3.9/site-packages/numpy/core/fromnumeric.py in _wrapit(obj, method, *args, **kwds)
#      38 def _wrapit(obj, method, *args, **kwds):
#      39     try:
# ---> 40         wrap = obj.__array_wrap__
#      41     except AttributeError:
#      42         wrap = None
#
# KeyboardInterrupt:

# %%
i = 20
for j in [0, 100, 200, 300]:
    print("simulation duration = ", round(d_array[j],1))
    aln.params.duration = round(d_array[j],1)
    time_ = np.arange(-dur_pre,round(d_array[j]+dur_post+aln.params.dt,1),aln.params.dt)
    dur += dur_pre + dur_post
    target_e = [target[i][0]] * len(time_)
    target_i = [target[i][1]] * len(time_)

    fig, ax = plt.subplots(2,1, constrained_layout=True, figsize = (4,4) )
    ax[1].plot(time_, bestControl_[i][j][0,0,:], color = 'red')
    ax[0].plot(time_, bestState_[i][j][0,0,:], color= 'red')
    ax[1].plot(time_, bestControl_[i][j][0,1,:], color = 'blue')
    ax[0].plot(time_, bestState_[i][j][0,1,:], color= 'blue')
    ax[0].plot(time_, target_e, linestyle = '--', color='red')
    ax[0].plot(time_, target_i, linestyle = '--', color='blue')
    ax[0].set_xlim(-dur_pre,round(d_array[j]+dur_pre,1))
    ax[1].set_xlim(-dur_pre,round(d_array[j]+dur_pre,1))
    ax[0].axvspan(t0_array[j], t0_array[j]+20, alpha=0.2, color='gray')
    plt.show()
# Out:
# simulation duration =  20.0
# simulation duration =  30.0
# simulation duration =  40.0
# simulation duration =  50.0
