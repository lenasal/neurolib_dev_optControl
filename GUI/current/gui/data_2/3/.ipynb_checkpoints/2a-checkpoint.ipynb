# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import sys
import pickle

path = os.getcwd().split(os.sep + 'GUI')[0]
if path not in sys.path:
    print("not here")
    sys.path.append(path)

from neurolib.models.aln import ALNModel
from neurolib.utils import plotFunctions as plotFunc
from neurolib.utils import costFunctions as cost
import neurolib.dashboard.functions as functions
import neurolib.dashboard.data as data
    
# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2 

#path = os.path.join(os.getcwd(), "plots")
# Out:
# not here

# %%
grid_data_file = os.path.join(os.getcwd().split('data')[0], 'bi.pickle')
print(grid_data_file)
with open(grid_data_file,'rb') as f:
    load_array= pickle.load(f)
exc = load_array[0]
inh = load_array[1]
print(len(exc))
case = '1'
# Out:
# /home/lena/Promotion/neurolib/GUI/current/gui/bi.pickle
# 147

# %% [markdown]
# ### Bistability

# %%
aln = ALNModel()
N = aln.params.N

data.set_parameters(aln)

state_vars = aln.state_vars
init_vars = aln.init_vars

##############################################################
def setinit(init_vars_, model):
    state_vars = model.state_vars
    init_vars = model.init_vars
    for iv in range(len(init_vars)):
        for sv in range(len(state_vars)):
            if state_vars[sv] in init_vars[iv]:
                #print("set init vars ", )
                if model.params[init_vars[iv]].ndim == 2:
                    model.params[init_vars[iv]][0,:] = init_vars_[sv]
                else:
                    model.params[init_vars[iv]][0] = init_vars_[sv]
                    
##############################################################               
def setmaxmincontrol(max_c_c, min_c_c, max_c_r, min_c_r):
    import numpy as np
    
    max_cntrl = np.zeros(( 6 ))
    min_cntrl = np.zeros(( 6 ))
    
    max_cntrl[0] = max_c_c
    min_cntrl[0] = min_c_c
    max_cntrl[1] = max_c_c
    min_cntrl[1] = min_c_c
    max_cntrl[2] = max_c_r
    min_cntrl[2] = min_c_r
    max_cntrl[3] = max_c_r
    min_cntrl[3] = min_c_r
    max_cntrl[4] = max_c_r
    min_cntrl[4] = min_c_r
    max_cntrl[5] = max_c_r
    min_cntrl[5] = min_c_r
            
    return max_cntrl, min_cntrl

# %%
d_array = np.arange(20., 300, 0.1)
t0_array = d_array - 20.
t_pen = np.zeros(( t0_array.shape ))
for i in range(len(t_pen)):
    t_pen[i] = t0_array[i] / d_array[i]

bestControl_ = np.array( [[None] * len(t_pen)] * len(exc) )
bestState_ = np.array( [[None] * len(t_pen)] * len(exc) )
cost_ = np.array( [[None] * len(t_pen)] * len(exc) )
costnode_ = np.array( [[None] * len(t_pen)] * len(exc) )
weights_ = np.array( [[None] * len(t_pen)] * len(exc) )
convergence_ = np.array( [[None] * len(t_pen)] * len(exc) )

initVars = [None] * len(exc)
target = [None] * len(exc)
cost_uncontrolled = [None] * len(exc)

print(bestControl_.shape)
# Out:
# (147, 2800)

# %%
dur_pre = 10
dur_post = 10

n_pre = int(np.around(dur_pre/aln.params.dt + 1.,1))
n_post = int(np.around(dur_post/aln.params.dt + 1.,1))

tol = 1e-32
start_step = 10.
c_scheme = np.zeros(( 1,1 ))
c_scheme[0,0] = 1.
u_mat = np.identity(1)
u_scheme = np.array([[1.]])

c_var = [0,1]
p_var = [0]

if case in ['1', '2']:    # low to high
    max_I = [3., -3.]
else:
    max_I = [-3., 3.]
    
if case in ['1', '3']:    # sparsity
    factor_ws = 1.
    factor_we = 0.
else:
    factor_ws = 0.
    factor_we = 1.
    
maxC = [5., -5., 0.18, 0.]
max_cntrl, min_cntrl = setmaxmincontrol(maxC[0], maxC[1], maxC[2], maxC[3])

# %%
file_ = '2a.pickle'

# %%
if os.path.isfile(file_) :
    print("file found")
    
    with open(file_,'rb') as f:
        load_array = pickle.load(f)

    bestControl_ = load_array[0]
    bestState_ = load_array[1]
    cost_ = load_array[2]
    costnode_ = load_array[3]
    weights_ = load_array[4]

# %%
# get initial parameters and target states

#i_stepsize = 20
#limit = 150
#start_index = 0
#i_range = range(start_index, limit,i_stepsize)
i_range = [20]

data.set_parameters(aln)

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    aln.params.duration = 3000.
    
    control0 = aln.getZeroControl()
    control0 = functions.step_control(aln, maxI_ = max_I[0])

    aln.run(control=control0)
    
    target_rates = np.zeros((2))
    target_rates[0] = aln.rates_exc[0,-1] 
    target_rates[1] = aln.rates_inh[0,-1]

    control0 = functions.step_control(aln, maxI_ = max_I[1])
    aln.run(control=control0)

    init_state_vars = np.zeros(( len(state_vars) ))
    for j in range(len(state_vars)):
        if aln.state[state_vars[j]].size == 1:
            init_state_vars[j] = aln.state[state_vars[j]][0]
        else:
            init_state_vars[j] = aln.state[state_vars[j]][0,-1]

    initVars[i] = init_state_vars
    target[i] = [target_rates[0], target_rates[1]]
# Out:
# -------  20 0.4500000000000001 0.4750000000000002

# %%
# get uncontrolled cost

data.set_parameters(aln)

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    dur = d_array[0]
    aln.params.duration = dur
    
    target_ = aln.getZeroTarget()
    target_[:,0,:] = target[i][0]
    target_[:,1,:] = target[i][1]
        
    cost.setParams(1.0, 0.0, 0.0)

    setinit(initVars[i], aln)
    control0 = aln.getZeroControl()

    # "HS", "FR", "PR", "HZ"
    cgv = None
    max_it = 0

    bestControl_init_, bestState_init_, cost_init_, runtime_init_, grad_init_, phi_init_, costnode_init_ = aln.A1(
        control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
        prec_variables_ = p_var, transition_time_ = 0.)
    
    cost_uncontrolled[i] = cost_init_[0]
# Out:
# -------  20 0.4500000000000001 0.4750000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  0 , total integrated cost =  12801.807032522984
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.

# %%
cgv = None
j = 0
k = 0

while k < 10:
    print('-------------------------------------------- k = ', k)

    for i in i_range:
        print("------- ", i, exc[i], inh[i])
        aln.params.ext_exc_current = exc[i] * 5.
        aln.params.ext_inh_current = inh[i] * 5.

        if convergence_[i][j] == True:
            print('converged')
            continue

        dur = d_array[0]
        aln.params.duration = dur
        
        setinit(initVars[i], aln)

        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        max_it = int(100)

        if type(bestControl_[i][j]) == type(None) or np.amax(np.abs(bestControl_[i][j])) < 1e-6:
            print('no solution found')
            control0 = aln.getZeroControl()
            #control0[0,0,:50] = 5.
            cost.setParams(1.0, 0., 1.)
            max_it = int(1)
            weights_[i][j] = [1., 0., 1.]
        else:
            control0 = bestControl_[i][j][:,:,n_pre-1:-n_post+1]
            l = 1
            while cost_[i][j][-l] == 0.:
                l += 1

            weight_ = ( cost_uncontrolled[i] - costnode_[i][j][0][0][0] ) / sum( costnode_[i][j][2][0][:] )
                
            print("weight = ", weight_)
            cost.setParams(1.0, weight_ * factor_we, weight_ * factor_ws)
            weights_[i][j] = cost.getParams()

        bestControl_[i][j], bestState_[i][j], cost_[i][j], runtime_, grad_, phi_, costnode_[i][j] = aln.A1(
            control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
            prec_variables_ = p_var, transition_time_ = t_pen[j])

        if cost_[i][j][2] == 0.:
            print('converged')
            convergence_[i][j] = True

        print('uncontrolled cost : ', cost_uncontrolled[i])
        print('cost splitting : ', costnode_[i][j][0][0][0], costnode_[i][j][2][0][:2])

        time_ = np.arange(-dur_pre,dur+dur_post+aln.params.dt,aln.params.dt)
        dur += dur_pre + dur_post
        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        if True:
            fig, ax = plt.subplots(2,1, constrained_layout=True, figsize = (4,4) )
            ax[1].plot(time_, bestControl_[i][j][0,0,:], color = 'red')
            ax[0].plot(time_, bestState_[i][j][0,0,:], color= 'red')
            ax[1].plot(time_, bestControl_[i][j][0,1,:], color = 'blue')
            ax[0].plot(time_, bestState_[i][j][0,1,:], color= 'blue')
            ax[0].plot(time_, target_[0,0,:], linestyle = '--', color='red')
            ax[0].plot(time_, target_[0,1,:], linestyle = '--', color='blue')
            ax[0].set_xlim(-dur_pre,dur-dur_post)
            ax[1].set_xlim(-dur_pre,dur-dur_post)
            ax[0].axvspan(t0_array[0], t0_array[0]+20, alpha=0.2, color='gray')
            plt.show()

        with open(file_,'wb') as f:
            pickle.dump([bestControl_, bestState_, cost_, costnode_, weights_], f)
    
    k += 1
# Out:
# -------------------------------------------- k =  0
# -------  20 0.4500000000000001 0.4750000000000002
# no solution found
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7028.817106816711
# RUN  1 , total integrated cost =  7028.817106816711
# Improved over  1  iterations in  27.004079208010808  seconds by  45.09511751770664  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  7022.352130835234 [6.46497598 0.        ]
# -------------------------------------------- k =  1
# -------  20 0.4500000000000001 0.4750000000000002
# weight =  893.9638628582769
# set cost params:  1.0 0.0 893.9638628582769
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12502.573615880003
# RUN  2 , total integrated cost =  12282.402726657583
# RUN  3 , total integrated cost =  12070.565066598327
# RUN  4 , total integrated cost =  11912.290714101808
# RUN  5 , total integrated cost =  11763.917856884547
# RUN  6 , total integrated cost =  11646.507820333409
# RUN  7 , total integrated cost =  11533.963616454199
# RUN  8 , total integrated cost =  11442.194434920108
# RUN  9 , total integrated cost =  11356.349321532143
# RUN  10 , total integrated cost =  11286.475186516192
# RUN  11 , total integrated cost =  11222.547471981032
# RUN  12 , total integrated cost =  11168.019537450471
# RUN  13 , total integrated cost =  11117.332266027826
# RUN  14 , total integrated cost =  11073.718088676356
# RUN  15 , total integrated cost =  11032.612902453468
# RUN  16 , total integrated cost =  10997.852608803205
# RUN  17 , total integrated cost =  10965.253061769523
# RUN  18 , total integrated cost =  10936.228989288546
# RUN  19 , total integrated cost =  10908.858988048667
# RUN  20 , total integrated cost =  10885.87677508157
# RUN  30 , total integrated cost =  10733.168560113536
# RUN  40 , total integrated cost =  10670.430305057018
# RUN  50 , total integrated cost =  10638.961849304973
# RUN  60 , total integrated cost =  10623.562423977983
# RUN  70 , total integrated cost =  10615.713453308854
# RUN  80 , total integrated cost =  10612.004864390754
# RUN  90 , total integrated cost =  10609.909318854781
# RUN  100 , total integrated cost =  10609.14817377926
# RUN  100 , total integrated cost =  10609.14817377926
# Improved over  100  iterations in  21.4705541159492  seconds by  17.12772933675126  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  3071.8230818235456 [8.43135322 0.        ]
# -------------------------------------------- k =  2
# -------  20 0.4500000000000001 0.4750000000000002
# weight =  1154.0239981687412
# set cost params:  1.0 0.0 1154.0239981687412
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12785.836094248247
# RUN  2 , total integrated cost =  12778.370103715726
# RUN  3 , total integrated cost =  12773.835432736054
# RUN  4 , total integrated cost =  12770.186571273553
# RUN  5 , total integrated cost =  12767.034641589038
# RUN  6 , total integrated cost =  12764.202646242406
# RUN  7 , total integrated cost =  12761.910389523762
# RUN  8 , total integrated cost =  12760.225499770073
# RUN  9 , total integrated cost =  12758.575201552201
# RUN  10 , total integrated cost =  12756.878625298043
# RUN  11 , total integrated cost =  12755.390153986791
# RUN  12 , total integrated cost =  12754.049087499212
# RUN  13 , total integrated cost =  12752.941863637363
# RUN  14 , total integrated cost =  12751.934596988296
# RUN  15 , total integrated cost =  12751.002543065526
# RUN  16 , total integrated cost =  12750.093077159729
# RUN  17 , total integrated cost =  12749.300529897831
# RUN  18 , total integrated cost =  12748.459969513278
# RUN  19 , total integrated cost =  12747.767395235427
# RUN  20 , total integrated cost =  12747.118454169686
# RUN  30 , total integrated cost =  12742.735032485954
# RUN  40 , total integrated cost =  12741.322652215262
# RUN  50 , total integrated cost =  12740.86396316635
# RUN  60 , total integrated cost =  12740.67564711678
# RUN  70 , total integrated cost =  12740.630683844709
# RUN  80 , total integrated cost =  12740.57221711784
# RUN  90 , total integrated cost =  12740.475335486011
# Control only changes marginally.
# RUN  94 , total integrated cost =  12740.472629583805
# Improved over  94  iterations in  23.04406276298687  seconds by  0.4791073852570946  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  3588.0660800363044 [7.93086328 0.        ]
# -------------------------------------------- k =  3
# -------  20 0.4500000000000001 0.4750000000000002
# weight =  1161.7576333085246
# set cost params:  1.0 0.0 1161.7576333085246
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.801374470482
# RUN  2 , total integrated cost =  12801.795558611535
# RUN  3 , total integrated cost =  12801.792794847473
# RUN  4 , total integrated cost =  12801.784410569047
# RUN  5 , total integrated cost =  12801.77299268212
# RUN  6 , total integrated cost =  12801.766586632139
# RUN  7 , total integrated cost =  12801.760295841112
# RUN  8 , total integrated cost =  12801.75615560237
# RUN  9 , total integrated cost =  12801.752741377713
# RUN  10 , total integrated cost =  12801.750430165823
# RUN  11 , total integrated cost =  12801.746919893367
# RUN  12 , total integrated cost =  12801.74607866844
# RUN  13 , total integrated cost =  12801.744675629287
# RUN  14 , total integrated cost =  12801.74359522956
# RUN  15 , total integrated cost =  12801.742410907074
# RUN  16 , total integrated cost =  12801.741329075241
# RUN  17 , total integrated cost =  12801.739030930183
# RUN  18 , total integrated cost =  12801.737097535899
# RUN  19 , total integrated cost =  12801.737039805828
# RUN  20 , total integrated cost =  12801.735507712758
# Control only changes marginally.
# RUN  29 , total integrated cost =  12801.734798753529
# Improved over  29  iterations in  7.652322929003276  seconds by  0.0005642466666841983  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  3605.8474337409616 [7.91549554 0.        ]
# -------------------------------------------- k =  4
# -------  20 0.4500000000000001 0.4750000000000002
# weight =  1161.7667589241084
# set cost params:  1.0 0.0 1161.7667589241084
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522982
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522982
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522982
# Improved over  1  iterations in  0.3300688429735601  seconds by  0.0  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  3605.8474337409616 [7.91549554 0.        ]
# -------------------------------------------- k =  5
# -------  20 0.4500000000000001 0.4750000000000002
# weight =  1161.7667589241084
# set cost params:  1.0 0.0 1161.7667589241084
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522982
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522982
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522982
# Improved over  1  iterations in  0.3734076439868659  seconds by  0.0  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  3605.8474337409616 [7.91549554 0.        ]
# -------------------------------------------- k =  6
# -------  20 0.4500000000000001 0.4750000000000002
# weight =  1161.7667589241084
# set cost params:  1.0 0.0 1161.7667589241084
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522982
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522982
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522982
# Improved over  1  iterations in  0.3441117029869929  seconds by  0.0  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  3605.8474337409616 [7.91549554 0.        ]
# -------------------------------------------- k =  7
# -------  20 0.4500000000000001 0.4750000000000002
# weight =  1161.7667589241084
# set cost params:  1.0 0.0 1161.7667589241084
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522982
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522982
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522982
# Improved over  1  iterations in  0.35656567104160786  seconds by  0.0  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  3605.8474337409616 [7.91549554 0.        ]
# -------------------------------------------- k =  8
# -------  20 0.4500000000000001 0.4750000000000002
# weight =  1161.7667589241084
# set cost params:  1.0 0.0 1161.7667589241084
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522982
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522982
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522982
# Improved over  1  iterations in  0.3843169449828565  seconds by  0.0  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  3605.8474337409616 [7.91549554 0.        ]
# -------------------------------------------- k =  9
# -------  20 0.4500000000000001 0.4750000000000002
# weight =  1161.7667589241084
# set cost params:  1.0 0.0 1161.7667589241084
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522982
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522982
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522982
# Improved over  1  iterations in  0.33324313699267805  seconds by  0.0  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  3605.8474337409616 [7.91549554 0.        ]

# %%
for i in range(bestControl_.shape[0]):
    for j in range(1,bestControl_.shape[1]):
        bestControl_[i][j] = None
        convergence_[i][j] = None

# %%
cost.setParams(1.0, factor_we, factor_ws)

j_start = 1

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.

    for j in range(j_start,j_start+1200):
        print(i,j, '-----------------')
            
        k = 0
        while convergence_[i][j] != True:
            print('---------------------', k)

            dur = round(d_array[j],1)
            print('simulation duration : ', dur)
            aln.params.duration = dur
            max_it = int(100)  
            
            setinit(initVars[i], aln)
            target_ = aln.getZeroTarget()
            target_[:,0,:] = target[i][0]
            target_[:,1,:] = target[i][1]

            if type(bestControl_[i][j]) == type(None):
                print('no solution computed yet')
                control0 = aln.getZeroControl()
                control0[:,:,1:] = bestControl_[i][j-1][:,:,n_pre-1:-n_post+1]
                                        
                l = 1
                while cost_[i][j-1][-l] == 0.:
                    l += 1
                    
                weight_ = ( cost_uncontrolled[i] - costnode_[i][j-1][0][0][0] ) / sum( costnode_[i][j-1][2][0][:] )
            else:
                control0 = bestControl_[i][j][:,:,n_pre-1:-n_post+1]
                l = 1
                while cost_[i][j][-l] == 0.:
                    l += 1
                
                weight_ = ( cost_uncontrolled[i] - costnode_[i][j][0][0][0] ) / sum( costnode_[i][j][2][0][:] )
                
            print("weight = ", weight_)
            cost.setParams(1.0, weight_ * factor_we, weight_ * factor_ws)
            weights_[i][j] = cost.getParams()

            bestControl_[i][j], bestState_[i][j], cost_[i][j], runtime_, grad_, phi_, costnode_[i][j] = aln.A1(
                control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
                startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
                t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
                prec_variables_ = p_var, transition_time_ = t_pen[j])

            if cost_[i][j][2] == 0.:
                print('converged')
                convergence_[i][j] = True

            print('uncontrolled cost : ', cost_uncontrolled[i])
            print('cost splitting : ', costnode_[i][j][0][0][0], costnode_[i][j][2][0][:2])

            time_ = np.arange(-dur_pre,round(dur+dur_post+aln.params.dt,1),aln.params.dt)
            dur += dur_pre + dur_post
            target_ = aln.getZeroTarget()
            target_[:,0,:] = target[i][0]
            target_[:,1,:] = target[i][1]

            if False:
                fig, ax = plt.subplots(2,1, constrained_layout=True, figsize = (4,4) )
                ax[1].plot(time_, bestControl_[i][j][0,0,:], color = 'red')
                ax[0].plot(time_, bestState_[i][j][0,0,:], color= 'red')
                ax[1].plot(time_, bestControl_[i][j][0,1,:], color = 'blue')
                ax[0].plot(time_, bestState_[i][j][0,1,:], color= 'blue')
                ax[0].plot(time_, target_[0,0,:], linestyle = '--', color='red')
                ax[0].plot(time_, target_[0,1,:], linestyle = '--', color='blue')
                ax[0].set_xlim(-dur_pre,dur-dur_post)
                ax[1].set_xlim(-dur_pre,dur-dur_post)
                ax[0].axvspan(t0_array[j], t0_array[j]+20, alpha=0.2, color='gray')
                plt.show()

            with open(file_,'wb') as f:
                pickle.dump([bestControl_, bestState_, cost_, costnode_, weights_], f)
                
            k += 1
# Out:
# set cost params:  1.0 0.0 1.0
# -------  20 0.4500000000000001 0.4750000000000002
# 20 1 -----------------
# 20 2 -----------------
# 20 3 -----------------
# 20 4 -----------------
# 20 5 -----------------
# 20 6 -----------------
# 20 7 -----------------
# 20 8 -----------------
# 20 9 -----------------
# 20 10 -----------------
# 20 11 -----------------
# 20 12 -----------------
# 20 13 -----------------
# 20 14 -----------------
# 20 15 -----------------
# 20 16 -----------------
# 20 17 -----------------
# 20 18 -----------------
# 20 19 -----------------
# 20 20 -----------------
# 20 21 -----------------
# 20 22 -----------------
# 20 23 -----------------
# 20 24 -----------------
# 20 25 -----------------
# 20 26 -----------------
# 20 27 -----------------
# 20 28 -----------------
# 20 29 -----------------
# 20 30 -----------------
# 20 31 -----------------
# 20 32 -----------------
# 20 33 -----------------
# 20 34 -----------------
# 20 35 -----------------
# 20 36 -----------------
# 20 37 -----------------
# 20 38 -----------------
# 20 39 -----------------
# 20 40 -----------------
# 20 41 -----------------
# 20 42 -----------------
# 20 43 -----------------
# 20 44 -----------------
# 20 45 -----------------
# 20 46 -----------------
# 20 47 -----------------
# 20 48 -----------------
# 20 49 -----------------
# 20 50 -----------------
# 20 51 -----------------
# 20 52 -----------------
# 20 53 -----------------
# 20 54 -----------------
# 20 55 -----------------
# 20 56 -----------------
# 20 57 -----------------
# 20 58 -----------------
# 20 59 -----------------
# 20 60 -----------------
# 20 61 -----------------
# 20 62 -----------------
# 20 63 -----------------
# 20 64 -----------------
# 20 65 -----------------
# 20 66 -----------------
# 20 67 -----------------
# 20 68 -----------------
# 20 69 -----------------
# 20 70 -----------------
# 20 71 -----------------
# 20 72 -----------------
# 20 73 -----------------
# 20 74 -----------------
# 20 75 -----------------
# 20 76 -----------------
# 20 77 -----------------
# 20 78 -----------------
# 20 79 -----------------
# 20 80 -----------------
# 20 81 -----------------
# 20 82 -----------------
# 20 83 -----------------
# 20 84 -----------------
# 20 85 -----------------
# 20 86 -----------------
# 20 87 -----------------
# 20 88 -----------------
# 20 89 -----------------
# 20 90 -----------------
# 20 91 -----------------
# 20 92 -----------------
# 20 93 -----------------
# 20 94 -----------------
# 20 95 -----------------
# 20 96 -----------------
# 20 97 -----------------
# 20 98 -----------------
# 20 99 -----------------
# 20 100 -----------------
# 20 101 -----------------
# 20 102 -----------------
# 20 103 -----------------
# 20 104 -----------------
# 20 105 -----------------
# 20 106 -----------------
# 20 107 -----------------
# 20 108 -----------------
# 20 109 -----------------
# 20 110 -----------------
# 20 111 -----------------
# 20 112 -----------------
# 20 113 -----------------
# 20 114 -----------------
# 20 115 -----------------
# 20 116 -----------------
# 20 117 -----------------
# 20 118 -----------------
# 20 119 -----------------
# 20 120 -----------------
# 20 121 -----------------
# 20 122 -----------------
# 20 123 -----------------
# 20 124 -----------------
# 20 125 -----------------
# 20 126 -----------------
# 20 127 -----------------
# 20 128 -----------------
# 20 129 -----------------
# 20 130 -----------------
# 20 131 -----------------
# 20 132 -----------------
# 20 133 -----------------
# 20 134 -----------------
# 20 135 -----------------
# 20 136 -----------------
# 20 137 -----------------
# 20 138 -----------------
# 20 139 -----------------
# 20 140 -----------------
# 20 141 -----------------
# 20 142 -----------------
# 20 143 -----------------
# 20 144 -----------------
# 20 145 -----------------
# 20 146 -----------------
# 20 147 -----------------
# 20 148 -----------------
# 20 149 -----------------
# 20 150 -----------------
# 20 151 -----------------
# 20 152 -----------------
# 20 153 -----------------
# 20 154 -----------------
# 20 155 -----------------
# 20 156 -----------------
# 20 157 -----------------
# 20 158 -----------------
# 20 159 -----------------
# 20 160 -----------------
# 20 161 -----------------
# 20 162 -----------------
# 20 163 -----------------
# 20 164 -----------------
# 20 165 -----------------
# 20 166 -----------------
# 20 167 -----------------
# 20 168 -----------------
# 20 169 -----------------
# 20 170 -----------------
# 20 171 -----------------
# 20 172 -----------------
# 20 173 -----------------
# 20 174 -----------------
# 20 175 -----------------
# 20 176 -----------------
# 20 177 -----------------
# 20 178 -----------------
# 20 179 -----------------
# 20 180 -----------------
# 20 181 -----------------
# 20 182 -----------------
# 20 183 -----------------
# 20 184 -----------------
# 20 185 -----------------
# 20 186 -----------------
# 20 187 -----------------
# 20 188 -----------------
# 20 189 -----------------
# 20 190 -----------------
# 20 191 -----------------
# 20 192 -----------------
# 20 193 -----------------
# 20 194 -----------------
# 20 195 -----------------
# 20 196 -----------------
# 20 197 -----------------
# 20 198 -----------------
# 20 199 -----------------
# 20 200 -----------------
# 20 201 -----------------
# 20 202 -----------------
# 20 203 -----------------
# 20 204 -----------------
# 20 205 -----------------
# 20 206 -----------------
# 20 207 -----------------
# 20 208 -----------------
# 20 209 -----------------
# 20 210 -----------------
# 20 211 -----------------
# 20 212 -----------------
# 20 213 -----------------
# 20 214 -----------------
# 20 215 -----------------
# 20 216 -----------------
# 20 217 -----------------
# 20 218 -----------------
# 20 219 -----------------
# 20 220 -----------------
# 20 221 -----------------
# 20 222 -----------------
# 20 223 -----------------
# 20 224 -----------------
# 20 225 -----------------
# 20 226 -----------------
# 20 227 -----------------
# 20 228 -----------------
# 20 229 -----------------
# 20 230 -----------------
# 20 231 -----------------
# 20 232 -----------------
# 20 233 -----------------
# 20 234 -----------------
# 20 235 -----------------
# 20 236 -----------------
# 20 237 -----------------
# 20 238 -----------------
# 20 239 -----------------
# 20 240 -----------------
# 20 241 -----------------
# 20 242 -----------------
# 20 243 -----------------
# 20 244 -----------------
# 20 245 -----------------
# 20 246 -----------------
# 20 247 -----------------
# 20 248 -----------------
# 20 249 -----------------
# 20 250 -----------------
# 20 251 -----------------
# 20 252 -----------------
# 20 253 -----------------
# 20 254 -----------------
# 20 255 -----------------
# 20 256 -----------------
# 20 257 -----------------
# 20 258 -----------------
# 20 259 -----------------
# 20 260 -----------------
# 20 261 -----------------
# 20 262 -----------------
# 20 263 -----------------
# 20 264 -----------------
# 20 265 -----------------
# 20 266 -----------------
# 20 267 -----------------
# 20 268 -----------------
# 20 269 -----------------
# 20 270 -----------------
# 20 271 -----------------
# 20 272 -----------------
# 20 273 -----------------
# 20 274 -----------------
# 20 275 -----------------
# 20 276 -----------------
# 20 277 -----------------
# 20 278 -----------------
# 20 279 -----------------
# 20 280 -----------------
# 20 281 -----------------
# 20 282 -----------------
# 20 283 -----------------
# 20 284 -----------------
# 20 285 -----------------
# 20 286 -----------------
# 20 287 -----------------
# 20 288 -----------------
# 20 289 -----------------
# 20 290 -----------------
# 20 291 -----------------
# 20 292 -----------------
# 20 293 -----------------
# 20 294 -----------------
# 20 295 -----------------
# 20 296 -----------------
# 20 297 -----------------
# 20 298 -----------------
# 20 299 -----------------
# 20 300 -----------------
# 20 301 -----------------
# 20 302 -----------------
# 20 303 -----------------
# 20 304 -----------------
# 20 305 -----------------
# 20 306 -----------------
# 20 307 -----------------
# 20 308 -----------------
# 20 309 -----------------
# 20 310 -----------------
# 20 311 -----------------
# 20 312 -----------------
# 20 313 -----------------
# 20 314 -----------------
# 20 315 -----------------
# 20 316 -----------------
# 20 317 -----------------
# 20 318 -----------------
# 20 319 -----------------
# 20 320 -----------------
# 20 321 -----------------
# 20 322 -----------------
# 20 323 -----------------
# 20 324 -----------------
# 20 325 -----------------
# 20 326 -----------------
# 20 327 -----------------
# 20 328 -----------------
# 20 329 -----------------
# 20 330 -----------------
# 20 331 -----------------
# 20 332 -----------------
# 20 333 -----------------
# 20 334 -----------------
# 20 335 -----------------
# 20 336 -----------------
# 20 337 -----------------
# 20 338 -----------------
# 20 339 -----------------
# 20 340 -----------------
# 20 341 -----------------
# 20 342 -----------------
# 20 343 -----------------
# 20 344 -----------------
# 20 345 -----------------
# 20 346 -----------------
# 20 347 -----------------
# 20 348 -----------------
# 20 349 -----------------
# 20 350 -----------------
# 20 351 -----------------
# 20 352 -----------------
# 20 353 -----------------
# 20 354 -----------------
# 20 355 -----------------
# 20 356 -----------------
# 20 357 -----------------
# 20 358 -----------------
# 20 359 -----------------
# 20 360 -----------------
# 20 361 -----------------
# 20 362 -----------------
# 20 363 -----------------
# 20 364 -----------------
# 20 365 -----------------
# 20 366 -----------------
# 20 367 -----------------
# 20 368 -----------------
# 20 369 -----------------
# 20 370 -----------------
# 20 371 -----------------
# 20 372 -----------------
# 20 373 -----------------
# 20 374 -----------------
# 20 375 -----------------
# 20 376 -----------------
# 20 377 -----------------
# 20 378 -----------------
# 20 379 -----------------
# 20 380 -----------------
# 20 381 -----------------
# 20 382 -----------------
# 20 383 -----------------
# 20 384 -----------------
# 20 385 -----------------
# 20 386 -----------------
# 20 387 -----------------
# 20 388 -----------------
# 20 389 -----------------
# 20 390 -----------------
# 20 391 -----------------
# 20 392 -----------------
# 20 393 -----------------
# 20 394 -----------------
# 20 395 -----------------
# 20 396 -----------------
# 20 397 -----------------
# 20 398 -----------------
# 20 399 -----------------
# 20 400 -----------------
# 20 401 -----------------
# 20 402 -----------------
# 20 403 -----------------
# 20 404 -----------------
# 20 405 -----------------
# 20 406 -----------------
# 20 407 -----------------
# 20 408 -----------------
# 20 409 -----------------
# 20 410 -----------------
# 20 411 -----------------
# 20 412 -----------------
# 20 413 -----------------
# 20 414 -----------------
# 20 415 -----------------
# 20 416 -----------------
# 20 417 -----------------
# 20 418 -----------------
# 20 419 -----------------
# 20 420 -----------------
# 20 421 -----------------
# 20 422 -----------------
# 20 423 -----------------
# 20 424 -----------------
# 20 425 -----------------
# 20 426 -----------------
# 20 427 -----------------
# 20 428 -----------------
# 20 429 -----------------
# 20 430 -----------------
# 20 431 -----------------
# 20 432 -----------------
# 20 433 -----------------
# 20 434 -----------------
# 20 435 -----------------
# 20 436 -----------------
# 20 437 -----------------
# 20 438 -----------------
# 20 439 -----------------
# 20 440 -----------------
# 20 441 -----------------
# 20 442 -----------------
# 20 443 -----------------
# 20 444 -----------------
# 20 445 -----------------
# 20 446 -----------------
# 20 447 -----------------
# 20 448 -----------------
# 20 449 -----------------
# 20 450 -----------------
# 20 451 -----------------
# 20 452 -----------------
# 20 453 -----------------
# 20 454 -----------------
# 20 455 -----------------
# 20 456 -----------------
# 20 457 -----------------
# 20 458 -----------------
# 20 459 -----------------
# 20 460 -----------------
# 20 461 -----------------
# 20 462 -----------------
# 20 463 -----------------
# 20 464 -----------------
# 20 465 -----------------
# 20 466 -----------------
# 20 467 -----------------
# 20 468 -----------------
# 20 469 -----------------
# 20 470 -----------------
# 20 471 -----------------
# 20 472 -----------------
# 20 473 -----------------
# 20 474 -----------------
# 20 475 -----------------
# 20 476 -----------------
# 20 477 -----------------
# 20 478 -----------------
# 20 479 -----------------
# 20 480 -----------------
# 20 481 -----------------
# 20 482 -----------------
# 20 483 -----------------
# 20 484 -----------------
# 20 485 -----------------
# 20 486 -----------------
# 20 487 -----------------
# 20 488 -----------------
# 20 489 -----------------
# 20 490 -----------------
# 20 491 -----------------
# 20 492 -----------------
# 20 493 -----------------
# 20 494 -----------------
# 20 495 -----------------
# 20 496 -----------------
# 20 497 -----------------
# 20 498 -----------------
# 20 499 -----------------
# 20 500 -----------------
# 20 501 -----------------
# 20 502 -----------------
# 20 503 -----------------
# 20 504 -----------------
# 20 505 -----------------
# 20 506 -----------------
# 20 507 -----------------
# 20 508 -----------------
# 20 509 -----------------
# 20 510 -----------------
# 20 511 -----------------
# 20 512 -----------------
# 20 513 -----------------
# 20 514 -----------------
# 20 515 -----------------
# 20 516 -----------------
# 20 517 -----------------
# 20 518 -----------------
# 20 519 -----------------
# 20 520 -----------------
# 20 521 -----------------
# 20 522 -----------------
# 20 523 -----------------
# 20 524 -----------------
# 20 525 -----------------
# 20 526 -----------------
# 20 527 -----------------
# 20 528 -----------------
# 20 529 -----------------
# 20 530 -----------------
# 20 531 -----------------
# 20 532 -----------------
# 20 533 -----------------
# 20 534 -----------------
# 20 535 -----------------
# 20 536 -----------------
# 20 537 -----------------
# 20 538 -----------------
# 20 539 -----------------
# 20 540 -----------------
# 20 541 -----------------
# 20 542 -----------------
# 20 543 -----------------
# 20 544 -----------------
# 20 545 -----------------
# 20 546 -----------------
# 20 547 -----------------
# 20 548 -----------------
# 20 549 -----------------
# 20 550 -----------------
# 20 551 -----------------
# 20 552 -----------------
# 20 553 -----------------
# 20 554 -----------------
# 20 555 -----------------
# 20 556 -----------------
# 20 557 -----------------
# 20 558 -----------------
# 20 559 -----------------
# 20 560 -----------------
# 20 561 -----------------
# 20 562 -----------------
# 20 563 -----------------
# 20 564 -----------------
# 20 565 -----------------
# 20 566 -----------------
# 20 567 -----------------
# 20 568 -----------------
# 20 569 -----------------
# 20 570 -----------------
# 20 571 -----------------
# 20 572 -----------------
# 20 573 -----------------
# 20 574 -----------------
# 20 575 -----------------
# 20 576 -----------------
# 20 577 -----------------
# 20 578 -----------------
# 20 579 -----------------
# 20 580 -----------------
# 20 581 -----------------
# 20 582 -----------------
# 20 583 -----------------
# 20 584 -----------------
# 20 585 -----------------
# 20 586 -----------------
# 20 587 -----------------
# 20 588 -----------------
# 20 589 -----------------
# 20 590 -----------------
# 20 591 -----------------
# 20 592 -----------------
# 20 593 -----------------
# 20 594 -----------------
# 20 595 -----------------
# 20 596 -----------------
# 20 597 -----------------
# 20 598 -----------------
# 20 599 -----------------
# 20 600 -----------------
# 20 601 -----------------
# 20 602 -----------------
# 20 603 -----------------
# 20 604 -----------------
# 20 605 -----------------
# 20 606 -----------------
# 20 607 -----------------
# 20 608 -----------------
# 20 609 -----------------
# 20 610 -----------------
# 20 611 -----------------
# 20 612 -----------------
# 20 613 -----------------
# 20 614 -----------------
# 20 615 -----------------
# 20 616 -----------------
# 20 617 -----------------
# 20 618 -----------------
# 20 619 -----------------
# 20 620 -----------------
# 20 621 -----------------
# 20 622 -----------------
# 20 623 -----------------
# 20 624 -----------------
# 20 625 -----------------
# 20 626 -----------------
# 20 627 -----------------
# 20 628 -----------------
# 20 629 -----------------
# 20 630 -----------------
# 20 631 -----------------
# 20 632 -----------------
# 20 633 -----------------
# 20 634 -----------------
# 20 635 -----------------
# 20 636 -----------------
# 20 637 -----------------
# 20 638 -----------------
# 20 639 -----------------
# 20 640 -----------------
# 20 641 -----------------
# 20 642 -----------------
# 20 643 -----------------
# 20 644 -----------------
# 20 645 -----------------
# 20 646 -----------------
# 20 647 -----------------
# 20 648 -----------------
# 20 649 -----------------
# 20 650 -----------------
# 20 651 -----------------
# 20 652 -----------------
# 20 653 -----------------
# 20 654 -----------------
# 20 655 -----------------
# 20 656 -----------------
# 20 657 -----------------
# 20 658 -----------------
# 20 659 -----------------
# 20 660 -----------------
# 20 661 -----------------
# 20 662 -----------------
# 20 663 -----------------
# 20 664 -----------------
# 20 665 -----------------
# 20 666 -----------------
# 20 667 -----------------
# 20 668 -----------------
# 20 669 -----------------
# 20 670 -----------------
# 20 671 -----------------
# 20 672 -----------------
# 20 673 -----------------
# 20 674 -----------------
# 20 675 -----------------
# 20 676 -----------------
# 20 677 -----------------
# 20 678 -----------------
# 20 679 -----------------
# 20 680 -----------------
# 20 681 -----------------
# 20 682 -----------------
# 20 683 -----------------
# 20 684 -----------------
# 20 685 -----------------
# 20 686 -----------------
# 20 687 -----------------
# 20 688 -----------------
# 20 689 -----------------
# 20 690 -----------------
# 20 691 -----------------
# 20 692 -----------------
# 20 693 -----------------
# 20 694 -----------------
# 20 695 -----------------
# 20 696 -----------------
# 20 697 -----------------
# 20 698 -----------------
# 20 699 -----------------
# 20 700 -----------------
# 20 701 -----------------
# 20 702 -----------------
# 20 703 -----------------
# 20 704 -----------------
# 20 705 -----------------
# 20 706 -----------------
# 20 707 -----------------
# 20 708 -----------------
# 20 709 -----------------
# 20 710 -----------------
# 20 711 -----------------
# 20 712 -----------------
# 20 713 -----------------
# 20 714 -----------------
# 20 715 -----------------
# 20 716 -----------------
# 20 717 -----------------
# 20 718 -----------------
# 20 719 -----------------
# 20 720 -----------------
# 20 721 -----------------
# 20 722 -----------------
# 20 723 -----------------
# 20 724 -----------------
# 20 725 -----------------
# 20 726 -----------------
# 20 727 -----------------
# 20 728 -----------------
# 20 729 -----------------
# 20 730 -----------------
# 20 731 -----------------
# 20 732 -----------------
# 20 733 -----------------
# 20 734 -----------------
# 20 735 -----------------
# 20 736 -----------------
# 20 737 -----------------
# 20 738 -----------------
# 20 739 -----------------
# 20 740 -----------------
# 20 741 -----------------
# 20 742 -----------------
# 20 743 -----------------
# 20 744 -----------------
# 20 745 -----------------
# 20 746 -----------------
# 20 747 -----------------
# 20 748 -----------------
# 20 749 -----------------
# 20 750 -----------------
# 20 751 -----------------
# 20 752 -----------------
# 20 753 -----------------
# 20 754 -----------------
# 20 755 -----------------
# 20 756 -----------------
# 20 757 -----------------
# 20 758 -----------------
# 20 759 -----------------
# 20 760 -----------------
# 20 761 -----------------
# 20 762 -----------------
# 20 763 -----------------
# 20 764 -----------------
# 20 765 -----------------
# 20 766 -----------------
# 20 767 -----------------
# 20 768 -----------------
# 20 769 -----------------
# 20 770 -----------------
# 20 771 -----------------
# 20 772 -----------------
# 20 773 -----------------
# 20 774 -----------------
# 20 775 -----------------
# 20 776 -----------------
# 20 777 -----------------
# 20 778 -----------------
# 20 779 -----------------
# 20 780 -----------------
# 20 781 -----------------
# 20 782 -----------------
# 20 783 -----------------
# 20 784 -----------------
# 20 785 -----------------
# 20 786 -----------------
# 20 787 -----------------
# 20 788 -----------------
# 20 789 -----------------
# 20 790 -----------------
# 20 791 -----------------
# 20 792 -----------------
# 20 793 -----------------
# 20 794 -----------------
# 20 795 -----------------
# 20 796 -----------------
# 20 797 -----------------
# 20 798 -----------------
# 20 799 -----------------
# 20 800 -----------------
# 20 801 -----------------
# 20 802 -----------------
# 20 803 -----------------
# 20 804 -----------------
# 20 805 -----------------
# 20 806 -----------------
# 20 807 -----------------
# 20 808 -----------------
# 20 809 -----------------
# 20 810 -----------------
# 20 811 -----------------
# 20 812 -----------------
# 20 813 -----------------
# 20 814 -----------------
# 20 815 -----------------
# 20 816 -----------------
# 20 817 -----------------
# 20 818 -----------------
# 20 819 -----------------
# 20 820 -----------------
# 20 821 -----------------
# 20 822 -----------------
# 20 823 -----------------
# 20 824 -----------------
# 20 825 -----------------
# 20 826 -----------------
# 20 827 -----------------
# 20 828 -----------------
# 20 829 -----------------
# 20 830 -----------------
# 20 831 -----------------
# 20 832 -----------------
# 20 833 -----------------
# 20 834 -----------------
# 20 835 -----------------
# 20 836 -----------------
# 20 837 -----------------
# 20 838 -----------------
# 20 839 -----------------
# 20 840 -----------------
# 20 841 -----------------
# 20 842 -----------------
# 20 843 -----------------
# 20 844 -----------------
# 20 845 -----------------
# 20 846 -----------------
# 20 847 -----------------
# 20 848 -----------------
# 20 849 -----------------
# 20 850 -----------------
# 20 851 -----------------
# 20 852 -----------------
# 20 853 -----------------
# 20 854 -----------------
# 20 855 -----------------
# 20 856 -----------------
# 20 857 -----------------
# 20 858 -----------------
# 20 859 -----------------
# 20 860 -----------------
# 20 861 -----------------
# 20 862 -----------------
# 20 863 -----------------
# 20 864 -----------------
# 20 865 -----------------
# 20 866 -----------------
# 20 867 -----------------
# 20 868 -----------------
# 20 869 -----------------
# 20 870 -----------------
# 20 871 -----------------
# 20 872 -----------------
# 20 873 -----------------
# 20 874 -----------------
# 20 875 -----------------
# 20 876 -----------------
# 20 877 -----------------
# 20 878 -----------------
# 20 879 -----------------
# 20 880 -----------------
# 20 881 -----------------
# 20 882 -----------------
# 20 883 -----------------
# 20 884 -----------------
# 20 885 -----------------
# 20 886 -----------------
# 20 887 -----------------
# 20 888 -----------------
# 20 889 -----------------
# 20 890 -----------------
# 20 891 -----------------
# 20 892 -----------------
# 20 893 -----------------
# 20 894 -----------------
# 20 895 -----------------
# 20 896 -----------------
# 20 897 -----------------
# 20 898 -----------------
# 20 899 -----------------
# 20 900 -----------------
# 20 901 -----------------
# 20 902 -----------------
# 20 903 -----------------
# 20 904 -----------------
# 20 905 -----------------
# 20 906 -----------------
# 20 907 -----------------
# 20 908 -----------------
# 20 909 -----------------
# 20 910 -----------------
# 20 911 -----------------
# 20 912 -----------------
# 20 913 -----------------
# 20 914 -----------------
# 20 915 -----------------
# 20 916 -----------------
# 20 917 -----------------
# 20 918 -----------------
# 20 919 -----------------
# 20 920 -----------------
# 20 921 -----------------
# 20 922 -----------------
# 20 923 -----------------
# 20 924 -----------------
# 20 925 -----------------
# 20 926 -----------------
# 20 927 -----------------
# 20 928 -----------------
# 20 929 -----------------
# 20 930 -----------------
# 20 931 -----------------
# 20 932 -----------------
# 20 933 -----------------
# 20 934 -----------------
# 20 935 -----------------
# 20 936 -----------------
# 20 937 -----------------
# 20 938 -----------------
# 20 939 -----------------
# 20 940 -----------------
# 20 941 -----------------
# 20 942 -----------------
# 20 943 -----------------
# 20 944 -----------------
# 20 945 -----------------
# 20 946 -----------------
# 20 947 -----------------
# 20 948 -----------------
# 20 949 -----------------
# 20 950 -----------------
# 20 951 -----------------
# 20 952 -----------------
# 20 953 -----------------
# 20 954 -----------------
# 20 955 -----------------
# 20 956 -----------------
# 20 957 -----------------
# 20 958 -----------------
# 20 959 -----------------
# 20 960 -----------------
# 20 961 -----------------
# 20 962 -----------------
# 20 963 -----------------
# 20 964 -----------------
# 20 965 -----------------
# 20 966 -----------------
# 20 967 -----------------
# 20 968 -----------------
# 20 969 -----------------
# 20 970 -----------------
# 20 971 -----------------
# 20 972 -----------------
# 20 973 -----------------
# 20 974 -----------------
# 20 975 -----------------
# 20 976 -----------------
# 20 977 -----------------
# 20 978 -----------------
# 20 979 -----------------
# 20 980 -----------------
# 20 981 -----------------
# 20 982 -----------------
# 20 983 -----------------
# 20 984 -----------------
# 20 985 -----------------
# 20 986 -----------------
# 20 987 -----------------
# 20 988 -----------------
# 20 989 -----------------
# 20 990 -----------------
# 20 991 -----------------
# 20 992 -----------------
# 20 993 -----------------
# 20 994 -----------------
# 20 995 -----------------
# 20 996 -----------------
# 20 997 -----------------
# 20 998 -----------------
# 20 999 -----------------
# 20 1000 -----------------
# 20 1001 -----------------
# --------------------- 0
# simulation duration :  120.1
# no solution computed yet
# weight =  2315.884937195701
# set cost params:  1.0 0.0 2315.884937195701
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12802.532841223043
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12802.532841223043
# Control only changes marginally.
# RUN  1 , total integrated cost =  12802.532841223043
# Improved over  1  iterations in  0.6892467560246587  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  872.4220574705897 [5.15142639e+00 3.26172184e-16]
# 20 1002 -----------------
# --------------------- 0
# simulation duration :  120.2
# no solution computed yet
# weight =  2315.744042491014
# set cost params:  1.0 0.0 2315.744042491014
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12802.532841223041
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12802.532841223041
# Control only changes marginally.
# RUN  1 , total integrated cost =  12802.532841223041
# Improved over  1  iterations in  0.6998055969597772  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  873.1478661706485 [5.15142639e+00 3.26172184e-16]
# 20 1003 -----------------
# --------------------- 0
# simulation duration :  120.3
# no solution computed yet
# weight =  2315.6031477863285
# set cost params:  1.0 0.0 2315.6031477863285
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12802.532841223043
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12802.532841223043
# Control only changes marginally.
# RUN  1 , total integrated cost =  12802.532841223043
# Improved over  1  iterations in  0.705723442020826  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  873.8736748707072 [5.15142639e+00 3.26172184e-16]
# 20 1004 -----------------
# --------------------- 0
# simulation duration :  120.4
# no solution computed yet
# weight =  2315.462253081642
# set cost params:  1.0 0.0 2315.462253081642
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12802.532841223043
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12802.532841223043
# Control only changes marginally.
# RUN  1 , total integrated cost =  12802.532841223043
# Improved over  1  iterations in  0.6141500059748068  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  874.5994835707659 [5.15142639e+00 3.26172184e-16]
# 20 1005 -----------------
# --------------------- 0
# simulation duration :  120.5
# no solution computed yet
# weight =  2315.3213583769557
# set cost params:  1.0 0.0 2315.3213583769557
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12802.532841223043
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12802.532841223043
# Control only changes marginally.
# RUN  1 , total integrated cost =  12802.532841223043
# Improved over  1  iterations in  0.6372693020384759  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  875.3252922708247 [5.15142639e+00 3.26172184e-16]
# 20 1006 -----------------
# --------------------- 0
# simulation duration :  120.6
# no solution computed yet
# weight =  2315.180463672269
# set cost params:  1.0 0.0 2315.180463672269
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12802.532841223041
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12802.532841223041
# Control only changes marginally.
# RUN  1 , total integrated cost =  12802.532841223041
# Improved over  1  iterations in  0.6144998520612717  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  876.0511009708833 [5.15142639e+00 3.26172184e-16]
# 20 1007 -----------------
# --------------------- 0
# simulation duration :  120.7
# no solution computed yet
# weight =  2315.0395689675834
# set cost params:  1.0 0.0 2315.0395689675834
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12802.532841223045
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12802.532841223045
# Control only changes marginally.
# RUN  1 , total integrated cost =  12802.532841223045
# Improved over  1  iterations in  0.7557395349722356  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  876.7769096709421 [5.15142639e+00 3.26172184e-16]
# 20 1008 -----------------
# --------------------- 0
# simulation duration :  120.8
# no solution computed yet
# weight =  2314.8986742628967
# set cost params:  1.0 0.0 2314.8986742628967
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12802.532841223043
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12802.532841223043
# Control only changes marginally.
# RUN  1 , total integrated cost =  12802.532841223043
# Improved over  1  iterations in  0.6610406639520079  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  877.5027183710008 [5.15142639e+00 3.26172184e-16]
# 20 1009 -----------------
# --------------------- 0
# simulation duration :  120.9
# no solution computed yet
# weight =  2314.7577795582106
# set cost params:  1.0 0.0 2314.7577795582106
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12802.532841223043
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12802.532841223043
# Control only changes marginally.
# RUN  1 , total integrated cost =  12802.532841223043
# Improved over  1  iterations in  0.6326249829726294  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  878.2285270710596 [5.15142639e+00 3.26172184e-16]
# 20 1010 -----------------
# --------------------- 0
# simulation duration :  121.0
# no solution computed yet
# weight =  2314.616884853524
# set cost params:  1.0 0.0 2314.616884853524
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12802.532841223043
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12802.532841223043
# Control only changes marginally.
# RUN  1 , total integrated cost =  12802.532841223043
# Improved over  1  iterations in  0.46350066701415926  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  878.9543357711183 [5.15142639e+00 3.26172184e-16]
# 20 1011 -----------------
# --------------------- 0
# simulation duration :  121.1
# no solution computed yet
# weight =  2314.475990148838
# set cost params:  1.0 0.0 2314.475990148838
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12802.532841223041
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12802.532841223041
# Control only changes marginally.
# RUN  1 , total integrated cost =  12802.532841223041
# Improved over  1  iterations in  0.7450929579790682  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  879.6801444711771 [5.15142639e+00 3.26172184e-16]
# 20 1012 -----------------
# --------------------- 0
# simulation duration :  121.2
# no solution computed yet
# weight =  2314.3350954441516
# set cost params:  1.0 0.0 2314.3350954441516
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12802.532841223043
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12802.532841223043
# Control only changes marginally.
# RUN  1 , total integrated cost =  12802.532841223043
# Improved over  1  iterations in  0.7089776010252535  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  880.4059531712358 [5.15142639e+00 3.26172184e-16]
# 20 1013 -----------------
# --------------------- 0
# simulation duration :  121.3
# no solution computed yet
# weight =  2314.1942007394655
# set cost params:  1.0 0.0 2314.1942007394655
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12802.532841223045
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12802.532841223045
# Control only changes marginally.
# RUN  1 , total integrated cost =  12802.532841223045
# Improved over  1  iterations in  0.735881739994511  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  881.1317618712943 [5.15142639e+00 3.26172184e-16]
# 20 1014 -----------------
# --------------------- 0
# simulation duration :  121.4
# no solution computed yet
# weight =  2314.053306034779
# set cost params:  1.0 0.0 2314.053306034779
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12802.532841223043
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12802.532841223043
# Control only changes marginally.
# RUN  1 , total integrated cost =  12802.532841223043
# Improved over  1  iterations in  0.6126927309669554  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  881.8575705713532 [5.15142639e+00 3.26172184e-16]
# 20 1015 -----------------
# --------------------- 0
# simulation duration :  121.5
# no solution computed yet
# weight =  2313.9124113300927
# set cost params:  1.0 0.0 2313.9124113300927
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12802.532841223043
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12802.532841223043
# Control only changes marginally.
# RUN  1 , total integrated cost =  12802.532841223043
# Improved over  1  iterations in  0.5769717020448297  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  882.5833792714118 [5.15142639e+00 3.26172184e-16]
# 20 1016 -----------------
# --------------------- 0
# simulation duration :  121.6
# no solution computed yet
# weight =  2313.7715166254065
# set cost params:  1.0 0.0 2313.7715166254065
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12802.532841223043
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12802.532841223043
# Control only changes marginally.
# RUN  1 , total integrated cost =  12802.532841223043
# Improved over  1  iterations in  0.6120398200582713  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  883.3091879714707 [5.15142639e+00 3.26172184e-16]
# 20 1017 -----------------
# --------------------- 0
# simulation duration :  121.7
# no solution computed yet
# weight =  2313.63062192072
# set cost params:  1.0 0.0 2313.63062192072
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12802.532841223041
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12802.532841223041
# Control only changes marginally.
# RUN  1 , total integrated cost =  12802.532841223041
# Improved over  1  iterations in  0.6384584889747202  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  884.0349966715293 [5.15142639e+00 3.26172184e-16]
# 20 1018 -----------------
# --------------------- 0
# simulation duration :  121.8
# no solution computed yet
# weight =  2313.4897272160338
# set cost params:  1.0 0.0 2313.4897272160338
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12802.532841223043
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12802.532841223043
# Control only changes marginally.
# RUN  1 , total integrated cost =  12802.532841223043
# Improved over  1  iterations in  0.7175127830123529  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  884.760805371588 [5.15142639e+00 3.26172184e-16]
# 20 1019 -----------------
# --------------------- 0
# simulation duration :  121.9
# no solution computed yet
# weight =  2313.348832511347
# set cost params:  1.0 0.0 2313.348832511347
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12802.532841223041
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12802.532841223041
# Control only changes marginally.
# RUN  1 , total integrated cost =  12802.532841223041
# Improved over  1  iterations in  0.6645254089962691  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  885.4866140716467 [5.15142639e+00 3.26172184e-16]
# 20 1020 -----------------
# --------------------- 0
# simulation duration :  122.0
# no solution computed yet
# weight =  2313.2079378066614
# set cost params:  1.0 0.0 2313.2079378066614
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12802.532841223043
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12802.532841223043
# Control only changes marginally.
# RUN  1 , total integrated cost =  12802.532841223043
# Improved over  1  iterations in  0.6073286950122565  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  886.2124227717055 [5.15142639e+00 3.26172184e-16]
# 20 1021 -----------------
# --------------------- 0
# simulation duration :  122.1
# no solution computed yet
# weight =  2313.067043101975
# set cost params:  1.0 0.0 2313.067043101975
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12802.532841223043
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12802.532841223043
# Control only changes marginally.
# RUN  1 , total integrated cost =  12802.532841223043
# Improved over  1  iterations in  0.5300407439935952  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  886.9382314717642 [5.15142639e+00 3.26172184e-16]
# 20 1022 -----------------
# --------------------- 0
# simulation duration :  122.2
# no solution computed yet
# weight =  2312.9261483972887
# set cost params:  1.0 0.0 2312.9261483972887
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12802.532841223043
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12802.532841223043
# Control only changes marginally.
# RUN  1 , total integrated cost =  12802.532841223043
# Improved over  1  iterations in  0.43526913598179817  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  887.6640401718229 [5.15142639e+00 3.26172184e-16]
# 20 1023 -----------------
# --------------------- 0
# simulation duration :  122.3
# no solution computed yet
# weight =  2312.785253692602
# set cost params:  1.0 0.0 2312.785253692602
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12802.532841223043
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12802.532841223043
# Control only changes marginally.
# RUN  1 , total integrated cost =  12802.532841223043
# Improved over  1  iterations in  0.5347954769385979  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  888.3898488718817 [5.15142639e+00 3.26172184e-16]
# 20 1024 -----------------
# --------------------- 0
# simulation duration :  122.4
# no solution computed yet
# weight =  2312.644358987916
# set cost params:  1.0 0.0 2312.644358987916
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12802.532841223041
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12802.532841223041
# Control only changes marginally.
# RUN  1 , total integrated cost =  12802.532841223041
# Improved over  1  iterations in  0.6711455850163475  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  889.1156575719403 [5.15142639e+00 3.26172184e-16]
# 20 1025 -----------------
# --------------------- 0
# simulation duration :  122.5
# no solution computed yet
# weight =  2312.5034642832297
# set cost params:  1.0 0.0 2312.5034642832297
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12802.532841223043
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12802.532841223043
# Control only changes marginally.
# RUN  1 , total integrated cost =  12802.532841223043
# Improved over  1  iterations in  0.7536741839721799  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  889.8414662719991 [5.15142639e+00 3.26172184e-16]
# 20 1026 -----------------
# --------------------- 0
# simulation duration :  122.6
# no solution computed yet
# weight =  2312.3625695785436
# set cost params:  1.0 0.0 2312.3625695785436
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12802.532841223043
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12802.532841223043
# Control only changes marginally.
# RUN  1 , total integrated cost =  12802.532841223043
# Improved over  1  iterations in  0.7044848339864984  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  890.5672749720578 [5.15142639e+00 3.26172184e-16]
# 20 1027 -----------------
# --------------------- 0
# simulation duration :  122.7
# no solution computed yet
# weight =  2312.221674873857
# set cost params:  1.0 0.0 2312.221674873857
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12802.532841223043
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12802.532841223043
# Control only changes marginally.
# RUN  1 , total integrated cost =  12802.532841223043
# Improved over  1  iterations in  0.6560793420067057  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  891.2930836721166 [5.15142639e+00 3.26172184e-16]
# 20 1028 -----------------
# --------------------- 0
# simulation duration :  122.8
# no solution computed yet
# weight =  2312.080780169171
# set cost params:  1.0 0.0 2312.080780169171
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12802.532841223041
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12802.532841223041
# Control only changes marginally.
# RUN  1 , total integrated cost =  12802.532841223041
# Improved over  1  iterations in  0.6393572600791231  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  892.0188923721753 [5.15142639e+00 3.26172184e-16]
# 20 1029 -----------------
# --------------------- 0
# simulation duration :  122.9
# no solution computed yet
# weight =  2311.9398854644846
# set cost params:  1.0 0.0 2311.9398854644846
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12802.532841223043
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12802.532841223043
# Control only changes marginally.
# RUN  1 , total integrated cost =  12802.532841223043
# Improved over  1  iterations in  0.7086097860010341  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  892.7447010722341 [5.15142639e+00 3.26172184e-16]
# 20 1030 -----------------
# --------------------- 0
# simulation duration :  123.0
# no solution computed yet
# weight =  2311.7989907597985
# set cost params:  1.0 0.0 2311.7989907597985
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12802.532841223043
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12802.532841223043
# Control only changes marginally.
# RUN  1 , total integrated cost =  12802.532841223043
# Improved over  1  iterations in  0.7576459040865302  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  893.4705097722928 [5.15142639e+00 3.26172184e-16]
# 20 1031 -----------------
# --------------------- 0
# simulation duration :  123.1
# no solution computed yet
# weight =  2311.658096055112
# set cost params:  1.0 0.0 2311.658096055112
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12802.532841223043
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12802.532841223043
# Control only changes marginally.
# RUN  1 , total integrated cost =  12802.532841223043
# Improved over  1  iterations in  0.6467372939223424  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  894.1963184723514 [5.15142639e+00 3.26172184e-16]
# 20 1032 -----------------
# --------------------- 0
# simulation duration :  123.2
# no solution computed yet
# weight =  2311.5172013504257
# set cost params:  1.0 0.0 2311.5172013504257
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12802.532841223043
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12802.532841223043
# Control only changes marginally.
# RUN  1 , total integrated cost =  12802.532841223043
# Improved over  1  iterations in  0.653354587033391  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  894.9221271724102 [5.15142639e+00 3.26172184e-16]
# 20 1033 -----------------
# --------------------- 0
# simulation duration :  123.3
# no solution computed yet
# weight =  2311.376306645739
# set cost params:  1.0 0.0 2311.376306645739
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12802.532841223041
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12802.532841223041
# Control only changes marginally.
# RUN  1 , total integrated cost =  12802.532841223041
# Improved over  1  iterations in  0.6341795030748472  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  895.6479358724689 [5.15142639e+00 3.26172184e-16]
# 20 1034 -----------------
# --------------------- 0
# simulation duration :  123.4
# no solution computed yet
# weight =  2311.2354119410534
# set cost params:  1.0 0.0 2311.2354119410534
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12802.532841223045
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12802.532841223045
# Control only changes marginally.
# RUN  1 , total integrated cost =  12802.532841223045
# Improved over  1  iterations in  0.6940990670118481  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  896.3737445725277 [5.15142639e+00 3.26172184e-16]
# 20 1035 -----------------
# --------------------- 0
# simulation duration :  123.5
# no solution computed yet
# weight =  2311.0945172363668
# set cost params:  1.0 0.0 2311.0945172363668
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12802.532841223043
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12802.532841223043
# Control only changes marginally.
# RUN  1 , total integrated cost =  12802.532841223043
# Improved over  1  iterations in  0.6976444720057771  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  897.0995532725864 [5.15142639e+00 3.26172184e-16]
# 20 1036 -----------------
# --------------------- 0
# simulation duration :  123.6
# no solution computed yet
# weight =  2310.9536225316806
# set cost params:  1.0 0.0 2310.9536225316806
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12802.532841223045
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12802.532841223045
# Control only changes marginally.
# RUN  1 , total integrated cost =  12802.532841223045
# Improved over  1  iterations in  0.5969131860183552  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  897.8253619726452 [5.15142639e+00 3.26172184e-16]
# 20 1037 -----------------
# --------------------- 0
# simulation duration :  123.7
# no solution computed yet
# weight =  2310.812727826994
# ...
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  998.7127712808082 [5.15142639e+00 3.26172184e-16]
# 20 1176 -----------------
# --------------------- 0
# simulation duration :  137.6
# no solution computed yet
# weight =  2291.228363875599
# set cost params:  1.0 0.0 2291.228363875599
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12802.532841223041
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12802.532841223041
# Control only changes marginally.
# RUN  1 , total integrated cost =  12802.532841223041
# Improved over  1  iterations in  0.7337665800005198  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  999.438579980867 [5.15142639e+00 3.26172184e-16]
# 20 1177 -----------------
# --------------------- 0
# simulation duration :  137.7
# no solution computed yet
# weight =  2291.0874691709123
# set cost params:  1.0 0.0 2291.0874691709123
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12802.53284122304
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12802.53284122304
# Control only changes marginally.
# RUN  1 , total integrated cost =  12802.53284122304
# Improved over  1  iterations in  0.8209284689510241  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  1000.1643886809256 [5.15142639e+00 3.26172184e-16]
# 20 1178 -----------------
# --------------------- 0
# simulation duration :  137.8
# no solution computed yet
# weight =  2290.9465744662266
# set cost params:  1.0 0.0 2290.9465744662266
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12802.532841223043
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12802.532841223043
# Control only changes marginally.
# RUN  1 , total integrated cost =  12802.532841223043
# Improved over  1  iterations in  0.7788338019745424  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  1000.8901973809844 [5.15142639e+00 3.26172184e-16]
# 20 1179 -----------------
# --------------------- 0
# simulation duration :  137.9
# no solution computed yet
# weight =  2290.80567976154
# set cost params:  1.0 0.0 2290.80567976154
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12802.532841223043
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12802.532841223043
# Control only changes marginally.
# RUN  1 , total integrated cost =  12802.532841223043
# Improved over  1  iterations in  0.8000962869264185  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  1001.616006081043 [5.15142639e+00 3.26172184e-16]
# 20 1180 -----------------
# --------------------- 0
# simulation duration :  138.0
# no solution computed yet
# weight =  2290.664785056854
# set cost params:  1.0 0.0 2290.664785056854
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12802.532841223043
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12802.532841223043
# Control only changes marginally.
# RUN  1 , total integrated cost =  12802.532841223043
# Improved over  1  iterations in  0.8757377360016108  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  1002.3418147811019 [5.15142639e+00 3.26172184e-16]
# 20 1181 -----------------
# --------------------- 0
# simulation duration :  138.1
# no solution computed yet
# weight =  2290.523890352167
# set cost params:  1.0 0.0 2290.523890352167
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12802.532841223041
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12802.532841223041
# Control only changes marginally.
# RUN  1 , total integrated cost =  12802.532841223041
# Improved over  1  iterations in  0.8216828090371564  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  1003.0676234811605 [5.15142639e+00 3.26172184e-16]
# 20 1182 -----------------
# --------------------- 0
# simulation duration :  138.2
# no solution computed yet
# weight =  2290.3829956474815
# set cost params:  1.0 0.0 2290.3829956474815
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12802.532841223043
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12802.532841223043
# Control only changes marginally.
# RUN  1 , total integrated cost =  12802.532841223043
# Improved over  1  iterations in  0.8255014499882236  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  1003.7934321812194 [5.15142639e+00 3.26172184e-16]
# 20 1183 -----------------
# --------------------- 0
# simulation duration :  138.3
# no solution computed yet
# weight =  2290.242100942795
# set cost params:  1.0 0.0 2290.242100942795
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12802.532841223043
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12802.532841223043
# Control only changes marginally.
# RUN  1 , total integrated cost =  12802.532841223043
# Improved over  1  iterations in  0.8158934350358322  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  1004.5192408812779 [5.15142639e+00 3.26172184e-16]
# 20 1184 -----------------
# --------------------- 0
# simulation duration :  138.4
# no solution computed yet
# weight =  2290.1012062381087
# set cost params:  1.0 0.0 2290.1012062381087
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12802.532841223043
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12802.532841223043
# Control only changes marginally.
# RUN  1 , total integrated cost =  12802.532841223043
# Improved over  1  iterations in  0.8178034829907119  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  1005.2450495813366 [5.15142639e+00 3.26172184e-16]
# 20 1185 -----------------
# --------------------- 0
# simulation duration :  138.5
# no solution computed yet
# weight =  2289.960311533422
# set cost params:  1.0 0.0 2289.960311533422
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12802.532841223041
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12802.532841223041
# Control only changes marginally.
# RUN  1 , total integrated cost =  12802.532841223041
# Improved over  1  iterations in  0.8090907109435648  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  1005.9708582813954 [5.15142639e+00 3.26172184e-16]
# 20 1186 -----------------
# --------------------- 0
# simulation duration :  138.6
# no solution computed yet
# weight =  2289.8194168287364
# set cost params:  1.0 0.0 2289.8194168287364
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12802.532841223045
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12802.532841223045
# Control only changes marginally.
# RUN  1 , total integrated cost =  12802.532841223045
# Improved over  1  iterations in  0.8313833930296823  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  1006.6966669814541 [5.15142639e+00 3.26172184e-16]
# 20 1187 -----------------
# --------------------- 0
# simulation duration :  138.7
# no solution computed yet
# weight =  2289.67852212405
# set cost params:  1.0 0.0 2289.67852212405
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12802.532841223043
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12802.532841223043
# Control only changes marginally.
# RUN  1 , total integrated cost =  12802.532841223043
# Improved over  1  iterations in  0.8807037050137296  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  1007.4224756815129 [5.15142639e+00 3.26172184e-16]
# 20 1188 -----------------
# --------------------- 0
# simulation duration :  138.8
# no solution computed yet
# weight =  2289.5376274193636
# set cost params:  1.0 0.0 2289.5376274193636
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12802.532841223045
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12802.532841223045
# Control only changes marginally.
# RUN  1 , total integrated cost =  12802.532841223045
# Improved over  1  iterations in  0.867470626020804  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  1008.1482843815716 [5.15142639e+00 3.26172184e-16]
# 20 1189 -----------------
# --------------------- 0
# simulation duration :  138.9
# no solution computed yet
# weight =  2289.396732714677
# set cost params:  1.0 0.0 2289.396732714677
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12802.532841223043
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12802.532841223043
# Control only changes marginally.
# RUN  1 , total integrated cost =  12802.532841223043
# Improved over  1  iterations in  0.973830017959699  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  1008.8740930816303 [5.15142639e+00 3.26172184e-16]
# 20 1190 -----------------
# --------------------- 0
# simulation duration :  139.0
# no solution computed yet
# weight =  2289.255838009991
# set cost params:  1.0 0.0 2289.255838009991
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12802.532841223041
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12802.532841223041
# Control only changes marginally.
# RUN  1 , total integrated cost =  12802.532841223041
# Improved over  1  iterations in  0.9502944729756564  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  1009.599901781689 [5.15142639e+00 3.26172184e-16]
# 20 1191 -----------------
# --------------------- 0
# simulation duration :  139.1
# no solution computed yet
# weight =  2289.1149433053047
# set cost params:  1.0 0.0 2289.1149433053047
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12802.532841223043
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12802.532841223043
# Control only changes marginally.
# RUN  1 , total integrated cost =  12802.532841223043
# Improved over  1  iterations in  1.0148107040440664  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  1010.3257104817478 [5.15142639e+00 3.26172184e-16]
# 20 1192 -----------------
# --------------------- 0
# simulation duration :  139.2
# no solution computed yet
# weight =  2288.974048600618
# set cost params:  1.0 0.0 2288.974048600618
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12802.532841223041
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12802.532841223041
# Control only changes marginally.
# RUN  1 , total integrated cost =  12802.532841223041
# Improved over  1  iterations in  0.9378127389354631  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  1011.0515191818065 [5.15142639e+00 3.26172184e-16]
# 20 1193 -----------------
# --------------------- 0
# simulation duration :  139.3
# no solution computed yet
# weight =  2288.833153895932
# set cost params:  1.0 0.0 2288.833153895932
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12802.532841223043
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12802.532841223043
# Control only changes marginally.
# RUN  1 , total integrated cost =  12802.532841223043
# Improved over  1  iterations in  0.90265152300708  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  1011.7773278818652 [5.15142639e+00 3.26172184e-16]
# 20 1194 -----------------
# --------------------- 0
# simulation duration :  139.4
# no solution computed yet
# weight =  2288.6922591912457
# set cost params:  1.0 0.0 2288.6922591912457
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12802.532841223043
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12802.532841223043
# Control only changes marginally.
# RUN  1 , total integrated cost =  12802.532841223043
# Improved over  1  iterations in  0.8266895139822736  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  1012.503136581924 [5.15142639e+00 3.26172184e-16]
# 20 1195 -----------------
# --------------------- 0
# simulation duration :  139.5
# no solution computed yet
# weight =  2288.5513644865596
# set cost params:  1.0 0.0 2288.5513644865596
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12802.532841223043
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12802.532841223043
# Control only changes marginally.
# RUN  1 , total integrated cost =  12802.532841223043
# Improved over  1  iterations in  0.8352018040604889  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  1013.2289452819826 [5.15142639e+00 3.26172184e-16]
# 20 1196 -----------------
# --------------------- 0
# simulation duration :  139.6
# no solution computed yet
# weight =  2288.410469781873
# set cost params:  1.0 0.0 2288.410469781873
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12802.532841223043
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12802.532841223043
# Control only changes marginally.
# RUN  1 , total integrated cost =  12802.532841223043
# Improved over  1  iterations in  0.7717749269213527  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  1013.9547539820414 [5.15142639e+00 3.26172184e-16]
# 20 1197 -----------------
# --------------------- 0
# simulation duration :  139.7
# no solution computed yet
# weight =  2288.269575077187
# set cost params:  1.0 0.0 2288.269575077187
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12802.532841223043
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12802.532841223043
# Control only changes marginally.
# RUN  1 , total integrated cost =  12802.532841223043
# Improved over  1  iterations in  0.8006488040555269  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  1014.6805626821001 [5.15142639e+00 3.26172184e-16]
# 20 1198 -----------------
# --------------------- 0
# simulation duration :  139.8
# no solution computed yet
# weight =  2288.1286803725
# set cost params:  1.0 0.0 2288.1286803725
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12802.532841223041
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12802.532841223041
# Control only changes marginally.
# RUN  1 , total integrated cost =  12802.532841223041
# Improved over  1  iterations in  0.8104139839997515  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  1015.4063713821589 [5.15142639e+00 3.26172184e-16]
# 20 1199 -----------------
# --------------------- 0
# simulation duration :  139.9
# no solution computed yet
# weight =  2287.987785667814
# set cost params:  1.0 0.0 2287.987785667814
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12802.532841223041
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12802.532841223041
# Control only changes marginally.
# RUN  1 , total integrated cost =  12802.532841223041
# Improved over  1  iterations in  0.7619645990198478  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  1016.1321800822176 [5.15142639e+00 3.26172184e-16]
# 20 1200 -----------------
# --------------------- 0
# simulation duration :  140.0
# no solution computed yet
# weight =  2287.846890963128
# set cost params:  1.0 0.0 2287.846890963128
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12802.532841223043
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12802.532841223043
# Control only changes marginally.
# RUN  1 , total integrated cost =  12802.532841223043
# Improved over  1  iterations in  0.8251142030349001  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  1016.8579887822764 [5.15142639e+00 3.26172184e-16]

# %%
i = 20
for j in [0,800,1200]:
    print("simulation duration = ", round(d_array[j],1))
    aln.params.duration = round(d_array[j],1)
    time_ = np.arange(-dur_pre,round(d_array[j]+dur_post+aln.params.dt,1),aln.params.dt)
    dur += dur_pre + dur_post
    target_e = [target[i][0]] * len(time_)
    target_i = [target[i][1]] * len(time_)

    fig, ax = plt.subplots(2,1, constrained_layout=True, figsize = (4,4) )
    ax[1].plot(time_, bestControl_[i][j][0,0,:], color = 'red')
    ax[0].plot(time_, bestState_[i][j][0,0,:], color= 'red')
    ax[1].plot(time_, bestControl_[i][j][0,1,:], color = 'blue')
    ax[0].plot(time_, bestState_[i][j][0,1,:], color= 'blue')
    ax[0].plot(time_, target_e, linestyle = '--', color='red')
    ax[0].plot(time_, target_i, linestyle = '--', color='blue')
    ax[0].set_xlim(-dur_pre,round(d_array[j]+dur_pre,1))
    ax[1].set_xlim(-dur_pre,round(d_array[j]+dur_pre,1))
    ax[0].axvspan(t0_array[j], t0_array[j]+20, alpha=0.2, color='gray')
    plt.show()
# Out:
# simulation duration =  20.0
# simulation duration =  100.0
# simulation duration =  140.0

# %%
control_diff = bestControl_[i][1200][0,0,:]
for k in range(bestControl_[i][800].shape[2]):
    control_diff[-k] = control_diff[-k] - bestControl_[i][800][0,0,-k]

fig, ax = plt.subplots(2,1, constrained_layout=True, figsize = (4,4) )
time_ = np.arange(-dur_pre,round(d_array[1200]+dur_post+aln.params.dt,1),aln.params.dt)
ax[1].plot(time_, control_diff, color = 'red')
plt.show()
