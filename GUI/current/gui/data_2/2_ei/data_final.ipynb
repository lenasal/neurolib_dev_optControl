# %%
import os
import pickle
import numpy as np

cost_index = 1

# %%
### w = 1

final_ = str(os.getcwd().split('data_2')[1][1:] + '.pickle')

bestControl = np.array( [[None] * 4801 ] * 2 )
bestState = np.array( [[None] * 4801 ] * 2 )
cost = np.array( [[None] * 4801 ] * 2 )
costnode = np.array( [[None] * 4801 ] * 2 )
weights = np.array( [[None] * 4801 ] * 2 )

for i in range(2):

    file_down = 'down.pickle'
    if os.path.isfile(file_down) :
        print("file found")

        with open(file_down,'rb') as f:
            load_array = pickle.load(f)

        bestControl_0 = load_array[0][i]
        bestState_0 = load_array[1][i]
        cost_0 = load_array[2][i]
        costnode_0 = load_array[3][i]
        weights_0 = load_array[4][i]
        
    file_up = 'up.pickle'
    if os.path.isfile(file_up) :
        print("file found")

        with open(file_up,'rb') as f:
            load_array = pickle.load(f)

        bestControl_1 = load_array[0][i]
        bestState_1 = load_array[1][i]
        cost_1 = load_array[2][i]
        costnode_1 = load_array[3][i]
        weights_1 = load_array[4][i]

    bestControl[i][len(bestControl_0)] = bestControl_1[0]
    bestState[i][len(bestControl_0)] = bestState_1[0]
    cost[i][len(bestControl_0)] = cost_1[0]
    costnode[i][len(bestControl_0)] = costnode_1[0]
    weights[i][len(bestControl_0)] = weights_1[0]

    for j in range(len(bestControl_0)):
        j_ = len(bestControl_0)

        if type(bestControl_0[j]) == type(None):
            if j < 2001:
                continue
            if type(bestControl_1[j_-j]) == type(None):
                continue     

        if j < 2001:
            bestControl[i][j] = bestControl_0[j]
            bestState[i][j] = bestState_0[j]
            cost[i][j] = cost_0[j]
            costnode[i][j] = costnode_0[j]
            weights[i][j] = weights_0[j]
            continue

        if type(bestControl_1[j_-j]) == type(None):
            bestControl[i][j] = bestControl_0[j]
            bestState[i][j] = bestState_0[j]
            cost[i][j] = cost_0[j]
            costnode[i][j] = costnode_0[j]
            weights[i][j] = weights_0[j]
            continue

        if type(bestControl_0[j]) == type(None):
            bestControl[i][j] = bestControl_1[j_-j]
            bestState[i][j] = bestState_1[j_-j]
            cost[i][j] = cost_1[j_-j]
            costnode[i][j] = costnode_1[j_-j]
            weights[i][j] = weights_1[j_-j]
            continue

        cost0 = sum(costnode_0[j][0][0][:]) + sum(costnode_0[j][cost_index][0][:])
        cost1 = sum(costnode_1[j_-j][0][0][:]) + sum(costnode_1[j_-j][cost_index][0][:])

        if np.amin([cost0, cost1]) == cost0:
            print(j, ' downwards ')
            bestControl[i][j] = bestControl_0[j]
            bestState[i][j] = bestState_0[j]
            cost[i][j] = cost_0[j]
            costnode[i][j] = costnode_0[j]
            weights[i][j] = weights_0[j]

        elif np.amin([cost0, cost1]) == cost1:
            print(j, ' upwards')
            bestControl[i][j] = bestControl_1[j_-j]
            bestState[i][j] = bestState_1[j_-j]
            cost[i][j] = cost_1[j_-j]
            costnode[i][j] = costnode_1[j_-j]
            weights[i][j] = weights_1[j_-j]
            
        #print(cost0, cost1)

    with open(final_,'wb') as f:
        pickle.dump([bestControl, bestState, cost, costnode, weights], f)
# Out:
# file found
# file found
# 2800  downwards
# 3.5546988402207615 3.634136975126523
# 2900  downwards
# 3.5556430184842216 3.6341685095867557
# 3000  downwards
# 3.558606137677032 3.634218898177155
# 3100  downwards
# result for  1 1000
# result for  1 1100
# result for  1 1200
# result for  1 1300
# result for  1 1400
# result for  1 1500
# result for  1 1600
# result for  1 1700
# result for  1 1800
# result for  1 1900
# result for  1 2000
# result for  1 2100
# result for  1 2200
# result for  1 2300
# result for  1 2400
# result for  1 2500
# result for  1 2600
# result for  1 2700
# result for  1 2800
# result for  1 2900
# result for  1 3000
# result for  1 3100
# result for  1 3200
# result for  1 3300
# result for  1 3400
# result for  1 3500
# result for  1 3600
# result for  1 3700
# result for  1 3800
# result for  1 3810
# result for  1 3820
# result for  1 3830
# result for  1 3840
# result for  1 3850
# result for  1 3860
# result for  1 3870
# result for  1 3880
# result for  1 3890
# result for  1 3900
# result for  1 3910
# result for  1 3920
# result for  1 3930
# result for  1 3940
# result for  1 3950
# result for  1 3960
# result for  1 3970
# result for  1 3980
# result for  1 3990
# result for  1 4000
# result for  1 4010
# result for  1 4020
# result for  1 4030
# result for  1 4040
# result for  1 4050
# result for  1 4060
# result for  1 4070
# result for  1 4080
# result for  1 4090
# result for  1 4100
# result for  1 4110
# result for  1 4120
# result for  1 4130
# result for  1 4140
# result for  1 4150
# result for  1 4160
# result for  1 4170
# result for  1 4180
# result for  1 4190
# result for  1 4200
# result for  1 4210
# result for  1 4220
# result for  1 4230
# result for  1 4240
# result for  1 4250
# result for  1 4260
# result for  1 4270
# result for  1 4280
# result for  1 4290
# result for  1 4300
# result for  1 4310
# result for  1 4320
# result for  1 4330
# result for  1 4340
# result for  1 4350
# result for  1 4360
# result for  1 4370
# result for  1 4380
# result for  1 4390
# result for  1 4400
# result for  1 4410
# result for  1 4420
# result for  1 4430
# result for  1 4440
# result for  1 4450
# result for  1 4460
# result for  1 4470
# result for  1 4480
# result for  1 4490
# result for  1 4500
# result for  1 4510
# result for  1 4520
# result for  1 4530
# result for  1 4540
# result for  1 4550
# result for  1 4560
# result for  1 4570
# result for  1 4580
# result for  1 4590
# result for  1 4600
# result for  1 4610
# result for  1 4620
# result for  1 4630
# result for  1 4640
# result for  1 4650
# result for  1 4660
# result for  1 4670
# result for  1 4680
# result for  1 4690
# result for  1 4700
# result for  1 4710
# result for  1 4720
# result for  1 4730
# result for  1 4740
# result for  1 4750
# result for  1 4760
# result for  1 4770
# result for  1 4780
# result for  1 4790
# result for  1 4791
# result for  1 4792
# result for  1 4793
# result for  1 4794
# result for  1 4795
# result for  1 4796
# result for  1 4797
# result for  1 4798
# result for  1 4799
# result for  1 4800

# %%
### w = max

final_ = str(os.getcwd().split('data_2')[1][1:] + '_Wmax.pickle')

bestControl = np.array( [[None] * 4801 ] * 2 )
bestState = np.array( [[None] * 4801 ] * 2 )
cost = np.array( [[None] * 4801 ] * 2 )
costnode = np.array( [[None] * 4801 ] * 2 )
weights = np.array( [[None] * 4801 ] * 2 )

for i in range(2):

    file_down = 'down_Wmax.pickle'
    if os.path.isfile(file_down) :
        print("file found down")

        with open(file_down,'rb') as f:
            load_array = pickle.load(f)

        bestControl_0_max = load_array[0][i]
        bestState_0_max = load_array[1][i]
        cost_0_max = load_array[2][i]
        costnode_0_max = load_array[3][i]
        weights_0_max = load_array[4][i]
            
    file_up = 'up_Wmax.pickle'
    if os.path.isfile(file_up) :
        print("file found up")

        with open(file_up,'rb') as f:
            load_array = pickle.load(f)

        bestControl_1_max = load_array[0][i]
        bestState_1_max = load_array[1][i]
        cost_1_max = load_array[2][i]
        costnode_1_max = load_array[3][i]
        weights_1_max = load_array[4][i]

    bestControl[i][len(bestControl_0_max)] = bestControl_1_max[0]
    bestState[i][len(bestControl_0_max)] = bestState_1_max[0]
    cost[i][len(bestControl_0_max)] = cost_1_max[0]
    costnode[i][len(bestControl_0_max)] = costnode_1_max[0]
    weights[i][len(bestControl_0_max)] = weights_1_max[0]

    for j in range(len(bestControl_0_max)):
        j_ = len(bestControl_0_max)
        
        if type(bestControl_0_max[j]) == type(None):
            if j < 2001:
                continue
            if type(bestControl_1_max[j_-j]) == type(None):
                continue     

        if j < 2001:
            bestControl[i][j] = bestControl_0_max[j]
            bestState[i][j] = bestState_0_max[j]
            cost[i][j] = cost_0_max[j]
            costnode[i][j] = costnode_0_max[j]
            weights[i][j] = weights_0_max[j]
            continue

        if type(bestControl_1_max[j_-j]) == type(None):
            bestControl[i][j] = bestControl_0_max[j]
            bestState[i][j] = bestState_0_max[j]
            cost[i][j] = cost_0_max[j]
            costnode[i][j] = costnode_0_max[j]
            weights[i][j] = weights_0_max[j]
            continue

        if type(bestControl_0_max[j]) == type(None):
            bestControl[i][j] = bestControl_1_max[j_-j]
            bestState[i][j] = bestState_1_max[j_-j]
            cost[i][j] = cost_1_max[j_-j]
            costnode[i][j] = costnode_1_max[j_-j]
            weights[i][j] = weights_1_max[j_-j]
            continue

        cost0 = sum(costnode_0_max[j][0][0][:]) + sum(costnode_0_max[j][cost_index][0][:])
        cost1 = sum(costnode_1_max[j_-j][0][0][:]) + sum(costnode_1_max[j_-j][cost_index][0][:])

        if np.amin([cost0, cost1]) == cost0:
            print(j, ' downwards ')
            bestControl[i][j] = bestControl_0_max[j]
            bestState[i][j] = bestState_0_max[j]
            cost[i][j] = cost_0_max[j]
            costnode[i][j] = costnode_0_max[j]
            weights[i][j] = weights_0_max[j]

        elif np.amin([cost0, cost1]) == cost1:
            print(j, ' upwards')
            bestControl[i][j] = bestControl_1_max[j_-j]
            bestState[i][j] = bestState_1_max[j_-j]
            cost[i][j] = cost_1_max[j_-j]
            costnode[i][j] = costnode_1_max[j_-j]
            weights[i][j] = weights_1_max[j_-j]
            
    with open(final_,'wb') as f:
        pickle.dump([bestControl, bestState, cost, costnode, weights], f)
# Out:
# file found down
# file found up
# 2800  downwards
# 2900  downwards
# 3000  downwards
# 3100  downwards
# 3200  downwards
# 3300  downwards
# 3400  downwards
# 3500  downwards
# 3600  downwards
# 3700  downwards
# 3800  downwards
# 3900  downwards
# 4000  downwards
# 4100  downwards
# 4200  downwards
# 4300  downwards
# 4400  downwards
# 4410  downwards
# 4420  downwards
# 4430  downwards
# 4440  downwards
# 4450  downwards
# 4460  downwards
# 4470  downwards
# 4480  downwards
# 4490  downwards
# 4500  downwards
# 4510  downwards
# 4520  downwards
# 4530  downwards
# 4540  downwards
# 4550  downwards
# 4560  downwards
# 4570  downwards
# 4580  downwards
# 4590  downwards
# 4600  downwards
# 4610  downwards
# 4620  downwards
# 4630  downwards
# 4640  downwards
# 4650  downwards
# 4660  downwards
