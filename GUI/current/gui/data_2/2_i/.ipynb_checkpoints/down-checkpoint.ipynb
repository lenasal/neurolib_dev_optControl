# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import sys
import pickle

path = os.getcwd().split(os.sep + 'GUI')[0]
if path not in sys.path:
    print("not here")
    sys.path.append(path)

from neurolib.models.aln import ALNModel
from neurolib.utils import plotFunctions as plotFunc
from neurolib.utils import costFunctions as cost
import neurolib.dashboard.functions as functions
import neurolib.dashboard.data as data
    
# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2 

#path = os.path.join(os.getcwd(), "plots")
# Out:
# not here

# %%
grid_data_file = os.path.join(os.getcwd().split('data')[0], 'bi.pickle')
with open(grid_data_file,'rb') as f:
    load_array= pickle.load(f)
exc = [load_array[0][20], load_array[0][50]]
inh = [load_array[1][20], load_array[1][50]]

folder = str(os.getcwd().split('data_2')[1])
print(folder)
case = str(folder[1])

file_ = 'down.pickle'

c_var = [0,1]
if len(folder) == 4:
    if folder[3] == 'e':
        p_var = [0]
    elif folder[3] == 'i':
        p_var = [1]
else:
    p_var = [0,1]
    
print(p_var)

step1 = 100
step2 = 10
step3 = 1
# Out:
# /2_i
# [1]

# %%
aln = ALNModel()
N = aln.params.N

data.set_parameters(aln)

state_vars = aln.state_vars
init_vars = aln.init_vars

##############################################################
def setinit(init_vars_, model):
    state_vars = model.state_vars
    init_vars = model.init_vars
    for iv in range(len(init_vars)):
        for sv in range(len(state_vars)):
            if state_vars[sv] in init_vars[iv]:
                #print("set init vars ", )
                if model.params[init_vars[iv]].ndim == 2:
                    model.params[init_vars[iv]][0,:] = init_vars_[sv]
                else:
                    model.params[init_vars[iv]][0] = init_vars_[sv]
                    
##############################################################               
def setmaxmincontrol(max_c_c, min_c_c, max_c_r, min_c_r):
    import numpy as np
    
    max_cntrl = np.zeros(( 6 ))
    min_cntrl = np.zeros(( 6 ))
    
    max_cntrl[0] = max_c_c
    min_cntrl[0] = min_c_c
    max_cntrl[1] = max_c_c
    min_cntrl[1] = min_c_c
    max_cntrl[2] = max_c_r
    min_cntrl[2] = min_c_r
    max_cntrl[3] = max_c_r
    min_cntrl[3] = min_c_r
    max_cntrl[4] = max_c_r
    min_cntrl[4] = min_c_r
    max_cntrl[5] = max_c_r
    min_cntrl[5] = min_c_r
            
    return max_cntrl, min_cntrl

# %%
d_array = np.arange(500., 20, -0.1)
t0_array = d_array - 20.
t_pen = np.zeros(( t0_array.shape ))
for i in range(len(t_pen)):
    t_pen[i] = t0_array[i] / d_array[i]

# %%
dur_pre = 10
dur_post = 10

n_pre = int(np.around(dur_pre/aln.params.dt + 1.,1))
n_post = int(np.around(dur_post/aln.params.dt + 1.,1))

tol = 1e-12
start_step = 10.
c_scheme = np.zeros(( 1,1 ))
c_scheme[0,0] = 1.
u_mat = np.identity(1)
u_scheme = np.array([[1.]])

if case in ['1', '2']:    # low to high
    max_I = [3., -3.]
else:
    max_I = [-3., 3.]
    
if case in ['1', '3']:    # sparsity
    factor_ws = 1.
    factor_we = 0.
    cost_index = 2
else:
    factor_ws = 0.
    factor_we = 1.
    cost_index = 1
    
maxC = [1000., -1000., 0.18, 0.]
max_cntrl, min_cntrl = setmaxmincontrol(maxC[0], maxC[1], maxC[2], maxC[3])

# %%
bestControl_ = np.array( [[None] * len(t_pen)] * len(exc) )
bestState_ = np.array( [[None] * len(t_pen)] * len(exc) )
cost_ = np.array( [[None] * len(t_pen)] * len(exc) )
costnode_ = np.array( [[None] * len(t_pen)] * len(exc) )
weights_ = np.array( [[None] * len(t_pen)] * len(exc) )
convergence_ = np.array( [[None] * len(t_pen)] * len(exc) )

initVars = [None] * len(exc)
target = [None] * len(exc)
cost_uncontrolled = [None] * len(exc)

print(bestControl_.shape)
# Out:
# (2, 4800)

# %%
if os.path.isfile(file_) :
    print("file found")
    
    with open(file_,'rb') as f:
        load_array = pickle.load(f)

    bestControl_ = load_array[0]
    bestState_ = load_array[1]
    cost_ = load_array[2]
    costnode_ = load_array[3]
    weights_ = load_array[4]
# Out:
# file found

# %%
# get initial parameters and target states

i_range = range(len(exc))
data.set_parameters(aln)
max_percent = []

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    aln.params.duration = 3000.
    
    control0 = aln.getZeroControl()
    control0 = functions.step_control(aln, maxI_ = max_I[0])

    aln.run(control=control0)
    
    target_rates = np.zeros((2))
    target_rates[0] = aln.rates_exc[0,-1] 
    target_rates[1] = aln.rates_inh[0,-1]

    control0 = functions.step_control(aln, maxI_ = max_I[1])
    aln.run(control=control0)

    init_state_vars = np.zeros(( len(state_vars) ))
    for j in range(len(state_vars)):
        if aln.state[state_vars[j]].size == 1:
            init_state_vars[j] = aln.state[state_vars[j]][0]
        else:
            init_state_vars[j] = aln.state[state_vars[j]][0,-1]

    initVars[i] = init_state_vars
    target[i] = [target_rates[0], target_rates[1]]
    
    max_percent.append( (np.argmax(np.abs(bestControl_[i][0]), axis=2)[0,1] -100) / 4800 )
# Out:
# -------  0 0.4500000000000001 0.4750000000000002
# -------  1 0.47500000000000014 0.6000000000000003

# %%
# get uncontrolled cost

data.set_parameters(aln)

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    dur = d_array[0]
    aln.params.duration = dur
    
    target_ = aln.getZeroTarget()
    target_[:,0,:] = target[i][0]
    target_[:,1,:] = target[i][1]
            
    cost.setParams(1.0, 0.0, 0.0)

    setinit(initVars[i], aln)
    control0 = aln.getZeroControl()

    # "HS", "FR", "PR", "HZ"
    cgv = None
    max_it = 0

    bestControl_init_, bestState_init_, cost_init_, runtime_init_, grad_init_, phi_init_, phi1_, costnode_init_ = aln.A1(
        control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
        prec_variables_ = p_var, transition_time_ = t_pen[0])
    
    cost_uncontrolled[i] = cost_init_[0]
# Out:
# -------  0 0.4500000000000001 0.4750000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1151956.8752274683
# RUN  0 , total integrated cost =  1151956.8752274683
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1151956.8752274683
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  1 0.47500000000000014 0.6000000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1078580.8097708924
# RUN  0 , total integrated cost =  1078580.8097708924
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1078580.8097708924
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.

# %%
for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    j = 0
    step = step1

    while j < 4799:

        if j == 0:
            j += step
            continue
            
        if not convergence_[i][j-step]:
            if j - step > 0:
                j -= step
                print('go back to -----', j)

        print('-----', j)

        if convergence_[i][j]:
            j += step
            continue

        dur = d_array[j]
        T = 5001 - j
        aln.params.duration = dur

        cost.setParams(1.0, factor_we, factor_ws)
        weights_[i][j] = cost.getParams()

        setinit(initVars[i], aln)

        max_it = 1000

        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        if type(bestControl_[i][j]) == type(None):
            max_percent_prev = (np.argmax(np.abs(bestControl_[i][j-step]), axis=2)[0,1] - 100) / (T-200)
            shift_ind = 0
            if j < 3000:
                while max_percent_prev > max_percent[i]:
                    shift_ind += 1
                    max_percent_prev = (np.argmax(np.abs(bestControl_[i][j-step]), axis=2)[0,1] - 100 - shift_ind) / (T-200)

            control0 = np.zeros(( bestControl_[i][j-step][:,:,100:-(100+step)].shape ))
            print('shift ind = ', shift_ind)
            if shift_ind != 0:
                control0[:,:,:-shift_ind] = 1. * bestControl_[i][j-step][:,:,100+shift_ind:-(100+step)]
            else:
                control0[:,:,:] = 1. * bestControl_[i][j-step][:,:,100:-(100+step)]
                #control0[0,0,:] = 0.
        else:
            if bestControl_[i][j].shape[2] == T+200:
                control0 = bestControl_[i][j][:,:,100:-100]
                #control0[0,1,:] = 0.
            else:
                control0 = bestControl_[i][j][:,:,100:-(100+j)]

        bestControl_[i][j], bestState_[i][j], cost_[i][j], runtime_, grad_, phi_, phi1_, costnode_[i][j] = aln.A1(
            control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
            prec_variables_ = p_var, transition_time_ = t_pen[j])
        
        time_ = np.arange(-dur_pre,round(dur+dur_post+aln.params.dt,1),aln.params.dt)
        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        print(costnode_[i][j][0][0][0], costnode_[i][j][cost_index][0][:2])

        if cost_[i][j][-1] == 0.:
            convergence_[i][j] = True
            if j >= 4400:
                step = step2
            if j >=4790:
                step = step3

        with open(file_,'wb') as f:
            pickle.dump([bestControl_, bestState_, cost_, costnode_, weights_], f)

        j += step
# Out:
# -------  0 0.4500000000000001 0.4750000000000002
# ----- 100
# ----- 200
# ----- 300
# ----- 400
# ----- 500
# ----- 600
# ----- 700
# ----- 800
# ----- 900
# ----- 1000
# ----- 1100
# ----- 1200
# ----- 1300
# ----- 1400
# ----- 1500
# ----- 1600
# ----- 1700
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.3311744522899303
# RUN  0 , total integrated cost =  3.3311744522899303
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.331174452289765
# RUN  2 , total integrated cost =  3.331174452289306
# RUN  3 , total integrated cost =  3.331174452289244
# RUN  4 , total integrated cost =  3.331174452289092
# RUN  5 , total integrated cost =  3.3311744522886797
# RUN  6 , total integrated cost =  3.3311744522886153
# RUN  7 , total integrated cost =  3.3311744522881903
# RUN  8 , total integrated cost =  3.3311744522873665
# RUN  9 , total integrated cost =  3.3311744522873057
# RUN  10 , total integrated cost =  3.3311744522868567
# RUN  11 , total integrated cost =  3.3311744522860582
# RUN  12 , total integrated cost =  3.331174452286001
# RUN  13 , total integrated cost =  3.3311744522859277
# RUN  14 , total integrated cost =  3.331174452285557
# RUN  15 , total integrated cost =  3.3311744522854503
# RUN  16 , total integrated cost =  3.3311744522853624
# RUN  17 , total integrated cost =  3.331174452284991
# RUN  18 , total integrated cost =  3.331174452284902
# RUN  19 , total integrated cost =  3.3311744522848072
# RUN  20 , total integrated cost =  3.3311744522844333
# RUN  30 , total integrated cost =  3.3311744522817746
# RUN  40 , total integrated cost =  3.331174452279002
# RUN  50 , total integrated cost =  3.3311744522761586
# RUN  60 , total integrated cost =  3.3311744521825006
# RUN  70 , total integrated cost =  3.331174452170447
# RUN  80 , total integrated cost =  3.3311744521655777
# RUN  90 , total integrated cost =  3.3311744521520184
# RUN  100 , total integrated cost =  3.3311744521500906
# RUN  110 , total integrated cost =  3.3311744521415663
# RUN  120 , total integrated cost =  3.331174452134351
# RUN  130 , total integrated cost =  3.3311744521305053
# RUN  140 , total integrated cost =  3.3311744521236526
# RUN  150 , total integrated cost =  3.3311744521016817
# RUN  160 , total integrated cost =  3.3311744520998925
# RUN  170 , total integrated cost =  3.331174452094563
# RUN  180 , total integrated cost =  3.331174452066757
# RUN  190 , total integrated cost =  3.331174452060711
# RUN  200 , total integrated cost =  3.3311744520400532
# RUN  300 , total integrated cost =  3.331174451976962
# RUN  400 , total integrated cost =  3.331174451821239
# RUN  500 , total integrated cost =  3.3311744516127084
# RUN  600 , total integrated cost =  3.331174451386293
# RUN  700 , total integrated cost =  3.3311744513141135
# RUN  800 , total integrated cost =  3.331174451063665
# RUN  900 , total integrated cost =  3.3311744505852583
# RUN  1000 , total integrated cost =  3.3311744504104515
# RUN  1000 , total integrated cost =  3.3311744504104515
# Improved over  1000  iterations in  539.681050377083  seconds by  5.642090172841563e-08  percent.
# 0.0 [7.52696003e-36 5.54836160e+00]
# go back to ----- 1700
# ----- 1700
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.3311744504104515
# RUN  0 , total integrated cost =  3.3311744504104515
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.3311744504026373
# RUN  2 , total integrated cost =  3.3311744503925933
# RUN  3 , total integrated cost =  3.3311744503925182
# RUN  4 , total integrated cost =  3.331174450392406
# RUN  5 , total integrated cost =  3.331174450392016
# RUN  6 , total integrated cost =  3.3311744503919396
# RUN  7 , total integrated cost =  3.3311744503918326
# RUN  8 , total integrated cost =  3.331174450391457
# RUN  9 , total integrated cost =  3.3311744503913894
# RUN  10 , total integrated cost =  3.331174450391272
# RUN  11 , total integrated cost =  3.331174450390869
# RUN  12 , total integrated cost =  3.3311744503907974
# RUN  13 , total integrated cost =  3.3311744503904546
# RUN  14 , total integrated cost =  3.331174450389793
# RUN  15 , total integrated cost =  3.3311744503897454
# RUN  16 , total integrated cost =  3.3311744503890686
# RUN  17 , total integrated cost =  3.331174450388013
# RUN  18 , total integrated cost =  3.3311744503879686
# RUN  19 , total integrated cost =  3.331174450387109
# RUN  20 , total integrated cost =  3.3311744503858605
# RUN  30 , total integrated cost =  3.3311744503828855
# RUN  40 , total integrated cost =  3.331174450378119
# RUN  50 , total integrated cost =  3.3311744503751313
# RUN  60 , total integrated cost =  3.3311744503444047
# RUN  70 , total integrated cost =  3.3311744503425884
# RUN  80 , total integrated cost =  3.331174450340297
# RUN  90 , total integrated cost =  3.3311744503375795
# RUN  100 , total integrated cost =  3.3311744503343497
# RUN  110 , total integrated cost =  3.3311744503319645
# RUN  120 , total integrated cost =  3.331174450204134
# RUN  130 , total integrated cost =  3.331174450202077
# RUN  140 , total integrated cost =  3.331174450199931
# RUN  150 , total integrated cost =  3.331174450117209
# RUN  160 , total integrated cost =  3.3311744501104
# RUN  170 , total integrated cost =  3.331174450004297
# RUN  180 , total integrated cost =  3.331174450002437
# RUN  190 , total integrated cost =  3.3311744499653835
# RUN  200 , total integrated cost =  3.331174449963003
# RUN  300 , total integrated cost =  3.3311744496921367
# RUN  400 , total integrated cost =  3.331174449581833
# RUN  500 , total integrated cost =  3.331174449434297
# RUN  600 , total integrated cost =  3.3311744492968227
# RUN  700 , total integrated cost =  3.331174449239771
# RUN  800 , total integrated cost =  3.331174449066677
# RUN  900 , total integrated cost =  3.331174448866118
# RUN  1000 , total integrated cost =  3.3311744488126163
# RUN  1000 , total integrated cost =  3.3311744488126163
# Improved over  1000  iterations in  509.29475798702333  seconds by  4.7966125293896766e-08  percent.
# 0.0 [7.52696003e-36 5.54836160e+00]
# go back to ----- 1700
# ----- 1700
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.3311744488126163
# RUN  0 , total integrated cost =  3.3311744488126163
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.331174448812571
# RUN  2 , total integrated cost =  3.331174448809775
# RUN  3 , total integrated cost =  3.331174448807534
# RUN  4 , total integrated cost =  3.331174448807488
# RUN  5 , total integrated cost =  3.3311744488019017
# RUN  6 , total integrated cost =  3.331174448795572
# RUN  7 , total integrated cost =  3.331174448795519
# RUN  8 , total integrated cost =  3.3311744487953248
# RUN  9 , total integrated cost =  3.331174448794874
# RUN  10 , total integrated cost =  3.3311744487948087
# RUN  11 , total integrated cost =  3.3311744487943473
# RUN  12 , total integrated cost =  3.331174448793572
# RUN  13 , total integrated cost =  3.3311744487935133
# RUN  14 , total integrated cost =  3.3311744487933455
# RUN  15 , total integrated cost =  3.3311744487929262
# RUN  16 , total integrated cost =  3.3311744487928587
# RUN  17 , total integrated cost =  3.331174448792467
# RUN  18 , total integrated cost =  3.331174448791739
# RUN  19 , total integrated cost =  3.331174448791685
# RUN  20 , total integrated cost =  3.3311744487914963
# RUN  30 , total integrated cost =  3.3311744487804966
# RUN  40 , total integrated cost =  3.3311744487662702
# RUN  50 , total integrated cost =  3.331174448699262
# RUN  60 , total integrated cost =  3.3311744486747354
# RUN  70 , total integrated cost =  3.3311744486722543
# RUN  80 , total integrated cost =  3.3311744486703088
# RUN  90 , total integrated cost =  3.331174448654788
# RUN  100 , total integrated cost =  3.331174448633634
# RUN  110 , total integrated cost =  3.331174448630637
# RUN  120 , total integrated cost =  3.331174448628909
# RUN  130 , total integrated cost =  3.33117444862387
# RUN  140 , total integrated cost =  3.331174448603219
# RUN  150 , total integrated cost =  3.3311744486014065
# RUN  160 , total integrated cost =  3.331174448596694
# RUN  170 , total integrated cost =  3.3311744485924706
# RUN  180 , total integrated cost =  3.3311744485907324
# RUN  190 , total integrated cost =  3.331174448587617
# RUN  200 , total integrated cost =  3.331174448584632
# RUN  300 , total integrated cost =  3.3311744485420323
# RUN  400 , total integrated cost =  3.3311744484206556
# RUN  500 , total integrated cost =  3.3311744483240973
# RUN  600 , total integrated cost =  3.331174448196976
# RUN  700 , total integrated cost =  3.3311744476051444
# RUN  800 , total integrated cost =  3.33117444745055
# RUN  900 , total integrated cost =  3.331174447293874
# RUN  1000 , total integrated cost =  3.331174447145488
# RUN  1000 , total integrated cost =  3.331174447145488
# Improved over  1000  iterations in  518.9027003239607  seconds by  5.0046253363689175e-08  percent.
# 0.0 [7.52696003e-36 5.54836159e+00]
# go back to ----- 1700
# ----- 1700
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.331174447145488
# RUN  0 , total integrated cost =  3.331174447145488
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.331174447145363
# RUN  2 , total integrated cost =  3.3311744471452913
# RUN  3 , total integrated cost =  3.3311744471448765
# RUN  4 , total integrated cost =  3.331174447144735
# RUN  5 , total integrated cost =  3.3311744471446683
# RUN  6 , total integrated cost =  3.3311744471442917
# RUN  7 , total integrated cost =  3.331174447144175
# RUN  8 , total integrated cost =  3.3311744471440985
# RUN  9 , total integrated cost =  3.331174447143721
# RUN  10 , total integrated cost =  3.3311744471436056
# RUN  11 , total integrated cost =  3.3311744471434066
# RUN  12 , total integrated cost =  3.331174447142908
# RUN  13 , total integrated cost =  3.3311744471428364
# RUN  14 , total integrated cost =  3.331174447142714
# RUN  15 , total integrated cost =  3.331174447142323
# RUN  16 , total integrated cost =  3.3311744471422644
# RUN  17 , total integrated cost =  3.331174447142092
# RUN  18 , total integrated cost =  3.3311744471416453
# RUN  19 , total integrated cost =  3.331174447141585
# RUN  20 , total integrated cost =  3.3311744471414406
# RUN  30 , total integrated cost =  3.3311744471316453
# RUN  40 , total integrated cost =  3.3311744471279936
# RUN  50 , total integrated cost =  3.331174447105926
# RUN  60 , total integrated cost =  3.331174447103742
# RUN  70 , total integrated cost =  3.3311744471014726
# RUN  80 , total integrated cost =  3.3311744470989124
# RUN  90 , total integrated cost =  3.331174447096778
# RUN  100 , total integrated cost =  3.33117444709052
# RUN  110 , total integrated cost =  3.331174447088489
# RUN  120 , total integrated cost =  3.331174447086732
# RUN  130 , total integrated cost =  3.331174447084959
# RUN  140 , total integrated cost =  3.3311744470828133
# RUN  150 , total integrated cost =  3.331174447080662
# RUN  160 , total integrated cost =  3.331174447075411
# RUN  170 , total integrated cost =  3.3311744470629767
# RUN  180 , total integrated cost =  3.33117444703393
# RUN  190 , total integrated cost =  3.331174447010185
# RUN  200 , total integrated cost =  3.3311744470080713
# RUN  300 , total integrated cost =  3.331174446974751
# RUN  400 , total integrated cost =  3.331174446860909
# RUN  500 , total integrated cost =  3.331174446632271
# RUN  600 , total integrated cost =  3.331174446562974
# RUN  700 , total integrated cost =  3.3311744464849884
# RUN  800 , total integrated cost =  3.331174446336193
# RUN  900 , total integrated cost =  3.331174446130936
# RUN  1000 , total integrated cost =  3.3311744459917443
# RUN  1000 , total integrated cost =  3.3311744459917443
# Improved over  1000  iterations in  520.1723077120259  seconds by  3.463473774445447e-08  percent.
# 0.0 [7.52696003e-36 5.54836159e+00]
# go back to ----- 1700
# ----- 1700
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.3311744459917443
# RUN  0 , total integrated cost =  3.3311744459917443
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.331174445991561
# RUN  2 , total integrated cost =  3.331174445991508
# RUN  3 , total integrated cost =  3.331174445989991
# RUN  4 , total integrated cost =  3.331174445988937
# RUN  5 , total integrated cost =  3.331174445988895
# RUN  6 , total integrated cost =  3.33117444594574
# RUN  7 , total integrated cost =  3.3311744459027155
# RUN  8 , total integrated cost =  3.3311744459026267
# RUN  9 , total integrated cost =  3.331174445902541
# RUN  10 , total integrated cost =  3.3311744459021644
# RUN  11 , total integrated cost =  3.3311744459020494
# RUN  12 , total integrated cost =  3.3311744459019823
# RUN  13 , total integrated cost =  3.3311744459014814
# RUN  14 , total integrated cost =  3.3311744459012775
# RUN  15 , total integrated cost =  3.3311744459012327
# RUN  16 , total integrated cost =  3.331174445900537
# RUN  17 , total integrated cost =  3.3311744459002344
# RUN  18 , total integrated cost =  3.331174445900158
# RUN  19 , total integrated cost =  3.331174445899772
# RUN  20 , total integrated cost =  3.331174445899643
# RUN  30 , total integrated cost =  3.3311744458974664
# RUN  40 , total integrated cost =  3.3311744458894244
# RUN  50 , total integrated cost =  3.3311744458872554
# RUN  60 , total integrated cost =  3.331174445879585
# RUN  70 , total integrated cost =  3.331174445867484
# RUN  80 , total integrated cost =  3.3311744458226236
# RUN  90 , total integrated cost =  3.3311744458045083
# RUN  100 , total integrated cost =  3.331174445793817
# RUN  110 , total integrated cost =  3.3311744457797703
# RUN  120 , total integrated cost =  3.3311744457451398
# RUN  130 , total integrated cost =  3.331174445742053
# RUN  140 , total integrated cost =  3.331174445739566
# RUN  150 , total integrated cost =  3.331174445726641
# RUN  160 , total integrated cost =  3.3311744456656327
# RUN  170 , total integrated cost =  3.3311744456636077
# RUN  180 , total integrated cost =  3.331174445661856
# RUN  190 , total integrated cost =  3.331174445659537
# RUN  200 , total integrated cost =  3.33117444565324
# RUN  300 , total integrated cost =  3.3311744455075156
# RUN  400 , total integrated cost =  3.3311744454425782
# RUN  500 , total integrated cost =  3.331174445358381
# RUN  600 , total integrated cost =  3.3311744452646477
# RUN  700 , total integrated cost =  3.3311744451650482
# RUN  800 , total integrated cost =  3.3311744450629948
# RUN  900 , total integrated cost =  3.3311744449140153
# RUN  1000 , total integrated cost =  3.33117444476713
# RUN  1000 , total integrated cost =  3.33117444476713
# Improved over  1000  iterations in  527.5836380510591  seconds by  3.6762230593012646e-08  percent.
# 0.0 [7.52696003e-36 5.54836158e+00]
# go back to ----- 1700
# ----- 1700
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.33117444476713
# RUN  0 , total integrated cost =  3.33117444476713
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.3311744447669778
# RUN  2 , total integrated cost =  3.3311744447665963
# RUN  3 , total integrated cost =  3.3311744447665124
# RUN  4 , total integrated cost =  3.3311744447663902
# RUN  5 , total integrated cost =  3.331174444766009
# RUN  6 , total integrated cost =  3.33117444476593
# RUN  7 , total integrated cost =  3.331174444765583
# RUN  8 , total integrated cost =  3.3311744447650042
# RUN  9 , total integrated cost =  3.3311744447649496
# RUN  10 , total integrated cost =  3.3311744447427842
# RUN  11 , total integrated cost =  3.331174444721898
# RUN  12 , total integrated cost =  3.3311744447218423
# RUN  13 , total integrated cost =  3.3311744447162837
# RUN  14 , total integrated cost =  3.33117444471002
# RUN  15 , total integrated cost =  3.3311744447099607
# RUN  16 , total integrated cost =  3.3311744447094096
# RUN  17 , total integrated cost =  3.331174444708496
# RUN  18 , total integrated cost =  3.331174444708451
# RUN  19 , total integrated cost =  3.331174444699979
# RUN  20 , total integrated cost =  3.3311744446907734
# RUN  30 , total integrated cost =  3.331174444687325
# RUN  40 , total integrated cost =  3.331174444636979
# RUN  50 , total integrated cost =  3.3311744446244385
# RUN  60 , total integrated cost =  3.3311744445853075
# RUN  70 , total integrated cost =  3.3311744445702587
# RUN  80 , total integrated cost =  3.3311744445435836
# RUN  90 , total integrated cost =  3.3311744445415616
# RUN  100 , total integrated cost =  3.3311744445290916
# RUN  110 , total integrated cost =  3.3311744445207565
# RUN  120 , total integrated cost =  3.3311744445049403
# RUN  130 , total integrated cost =  3.3311744444899505
# RUN  140 , total integrated cost =  3.331174444485941
# RUN  150 , total integrated cost =  3.331174444482668
# RUN  160 , total integrated cost =  3.3311744444690112
# RUN  170 , total integrated cost =  3.3311744444506344
# RUN  180 , total integrated cost =  3.3311744444484273
# RUN  190 , total integrated cost =  3.3311744444460953
# RUN  200 , total integrated cost =  3.3311744444413143
# RUN  300 , total integrated cost =  3.331174444283238
# RUN  400 , total integrated cost =  3.331174444174581
# RUN  500 , total integrated cost =  3.3311744439417392
# RUN  600 , total integrated cost =  3.331174443743962
# RUN  700 , total integrated cost =  3.331174443606878
# RUN  800 , total integrated cost =  3.3311744434365984
# RUN  900 , total integrated cost =  3.3311744432770993
# RUN  1000 , total integrated cost =  3.3311744432040586
# RUN  1000 , total integrated cost =  3.3311744432040586
# Improved over  1000  iterations in  523.36868635891  seconds by  4.692253696703119e-08  percent.
# 0.0 [7.52696003e-36 5.54836158e+00]
# go back to ----- 1700
# ----- 1700
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.3311744432040586
# RUN  0 , total integrated cost =  3.3311744432040586
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.3311744432039534
# RUN  2 , total integrated cost =  3.331174443203894
# RUN  3 , total integrated cost =  3.331174443203508
# RUN  4 , total integrated cost =  3.3311744432033987
# RUN  5 , total integrated cost =  3.3311744432033463
# RUN  6 , total integrated cost =  3.3311744432028845
# RUN  7 , total integrated cost =  3.331174443202654
# RUN  8 , total integrated cost =  3.3311744432025963
# RUN  9 , total integrated cost =  3.3311744432020576
# RUN  10 , total integrated cost =  3.331174443201793
# RUN  11 , total integrated cost =  3.3311744432017445
# RUN  12 , total integrated cost =  3.3311744432011445
# RUN  13 , total integrated cost =  3.331174443200816
# RUN  14 , total integrated cost =  3.3311744432007324
# RUN  15 , total integrated cost =  3.3311744432003825
# RUN  16 , total integrated cost =  3.3311744432002803
# RUN  17 , total integrated cost =  3.3311744432000157
# RUN  18 , total integrated cost =  3.331174443199547
# RUN  19 , total integrated cost =  3.331174443199493
# RUN  20 , total integrated cost =  3.3311744431988175
# RUN  30 , total integrated cost =  3.331174443193888
# RUN  40 , total integrated cost =  3.3311744431890857
# RUN  50 , total integrated cost =  3.331174443161064
# RUN  60 , total integrated cost =  3.3311744431472063
# RUN  70 , total integrated cost =  3.3311744430971824
# RUN  80 , total integrated cost =  3.3311744430774124
# RUN  90 , total integrated cost =  3.3311744430533428
# RUN  100 , total integrated cost =  3.331174443026927
# RUN  110 , total integrated cost =  3.331174443023086
# RUN  120 , total integrated cost =  3.331174442969222
# RUN  130 , total integrated cost =  3.3311744429445613
# RUN  140 , total integrated cost =  3.3311744429426113
# RUN  150 , total integrated cost =  3.33117444293901
# RUN  160 , total integrated cost =  3.331174442857671
# RUN  170 , total integrated cost =  3.3311744428400916
# RUN  180 , total integrated cost =  3.3311744428376087
# RUN  190 , total integrated cost =  3.3311744428358323
# RUN  200 , total integrated cost =  3.3311744428339085
# RUN  300 , total integrated cost =  3.3311744426644685
# RUN  400 , total integrated cost =  3.3311744424263208
# RUN  500 , total integrated cost =  3.3311744422475273
# RUN  600 , total integrated cost =  3.3311744420981206
# RUN  700 , total integrated cost =  3.331174442033427
# RUN  800 , total integrated cost =  3.3311744418492073
# RUN  900 , total integrated cost =  3.3311744416032774
# RUN  1000 , total integrated cost =  3.331174441385027
# RUN  1000 , total integrated cost =  3.331174441385027
# Improved over  1000  iterations in  495.4646910079755  seconds by  5.4606317689831485e-08  percent.
# 0.0 [7.52696003e-36 5.54836157e+00]
# go back to ----- 1700
# ----- 1700
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.331174441385027
# RUN  0 , total integrated cost =  3.331174441385027
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.331174441384927
# RUN  2 , total integrated cost =  3.331174441384864
# RUN  3 , total integrated cost =  3.3311744413843263
# RUN  4 , total integrated cost =  3.331174441384116
# RUN  5 , total integrated cost =  3.331174441384068
# RUN  6 , total integrated cost =  3.331174441382841
# RUN  7 , total integrated cost =  3.3311744413819997
# RUN  8 , total integrated cost =  3.3311744413819517
# RUN  9 , total integrated cost =  3.331174441381215
# RUN  10 , total integrated cost =  3.331174441380853
# RUN  11 , total integrated cost =  3.331174441380777
# RUN  12 , total integrated cost =  3.3311744413803575
# RUN  13 , total integrated cost =  3.3311744413802282
# RUN  14 , total integrated cost =  3.3311744413801585
# RUN  15 , total integrated cost =  3.3311744413797904
# RUN  16 , total integrated cost =  3.331174441379682
# RUN  17 , total integrated cost =  3.3311744413795963
# RUN  18 , total integrated cost =  3.331174441379241
# RUN  19 , total integrated cost =  3.3311744413791495
# RUN  20 , total integrated cost =  3.3311744413790985
# RUN  30 , total integrated cost =  3.3311744413767106
# RUN  40 , total integrated cost =  3.3311744413738946
# RUN  50 , total integrated cost =  3.3311744413665716
# RUN  60 , total integrated cost =  3.331174441362107
# RUN  70 , total integrated cost =  3.331174441359523
# RUN  80 , total integrated cost =  3.3311744413559112
# RUN  90 , total integrated cost =  3.331174441333585
# RUN  100 , total integrated cost =  3.3311744413315676
# RUN  110 , total integrated cost =  3.3311744413237885
# RUN  120 , total integrated cost =  3.331174441322071
# RUN  130 , total integrated cost =  3.331174441319705
# RUN  140 , total integrated cost =  3.3311744413143485
# RUN  150 , total integrated cost =  3.3311744413103948
# RUN  160 , total integrated cost =  3.3311744413086646
# RUN  170 , total integrated cost =  3.331174441306351
# RUN  180 , total integrated cost =  3.331174441261775
# RUN  190 , total integrated cost =  3.331174441260087
# RUN  200 , total integrated cost =  3.3311744412570428
# RUN  300 , total integrated cost =  3.331174441101403
# RUN  400 , total integrated cost =  3.331174440939119
# RUN  500 , total integrated cost =  3.3311744408049337
# RUN  600 , total integrated cost =  3.3311744406860138
# RUN  700 , total integrated cost =  3.331174440606301
# RUN  800 , total integrated cost =  3.331174440485866
# RUN  900 , total integrated cost =  3.3311744404396983
# RUN  1000 , total integrated cost =  3.3311744402811616
# RUN  1000 , total integrated cost =  3.3311744402811616
# Improved over  1000  iterations in  528.4123679579934  seconds by  3.3137425248241925e-08  percent.
# 0.0 [7.52696003e-36 5.54836157e+00]
# go back to ----- 1700
# ----- 1700
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.3311744402811616
# RUN  0 , total integrated cost =  3.3311744402811616
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.331174440280791
# RUN  2 , total integrated cost =  3.331174440280727
# RUN  3 , total integrated cost =  3.3311744402806713
# RUN  4 , total integrated cost =  3.331174440280248
# RUN  5 , total integrated cost =  3.3311744402800705
# RUN  6 , total integrated cost =  3.331174440280015
# RUN  7 , total integrated cost =  3.3311744402794985
# RUN  8 , total integrated cost =  3.3311744402792667
# RUN  9 , total integrated cost =  3.3311744402792063
# RUN  10 , total integrated cost =  3.3311744402787578
# RUN  11 , total integrated cost =  3.3311744402785664
# RUN  12 , total integrated cost =  3.331174440278495
# RUN  13 , total integrated cost =  3.3311744402781236
# RUN  14 , total integrated cost =  3.33117444027802
# RUN  15 , total integrated cost =  3.3311744402779295
# RUN  16 , total integrated cost =  3.3311744402775765
# RUN  17 , total integrated cost =  3.3311744402774917
# RUN  18 , total integrated cost =  3.3311744402774206
# RUN  19 , total integrated cost =  3.3311744402770738
# RUN  20 , total integrated cost =  3.3311744402769836
# RUN  30 , total integrated cost =  3.3311744402751318
# RUN  40 , total integrated cost =  3.331174440273006
# RUN  50 , total integrated cost =  3.331174440271177
# RUN  60 , total integrated cost =  3.3311744402691135
# RUN  70 , total integrated cost =  3.3311744402666332
# RUN  80 , total integrated cost =  3.3311744402535517
# RUN  90 , total integrated cost =  3.331174440251656
# RUN  100 , total integrated cost =  3.3311744402472954
# RUN  110 , total integrated cost =  3.33117444023039
# RUN  120 , total integrated cost =  3.3311744402248533
# RUN  130 , total integrated cost =  3.3311744402184407
# RUN  140 , total integrated cost =  3.3311744401859595
# RUN  150 , total integrated cost =  3.3311744388147586
# RUN  160 , total integrated cost =  3.33117443881229
# RUN  170 , total integrated cost =  3.331174438806112
# RUN  180 , total integrated cost =  3.331174438790168
# RUN  190 , total integrated cost =  3.3311744387202946
# RUN  200 , total integrated cost =  3.3311744387061997
# RUN  300 , total integrated cost =  3.331174438528292
# RUN  400 , total integrated cost =  3.3311744383087163
# RUN  500 , total integrated cost =  3.331174434868253
# RUN  600 , total integrated cost =  3.3311744346345535
# RUN  700 , total integrated cost =  3.3311744344472296
# RUN  800 , total integrated cost =  3.3311744341807485
# RUN  900 , total integrated cost =  3.3311744337919724
# RUN  1000 , total integrated cost =  3.3311744335620226
# RUN  1000 , total integrated cost =  3.3311744335620226
# Improved over  1000  iterations in  520.0585252820747  seconds by  2.017048075231287e-07  percent.
# 0.0 [7.52696003e-36 5.54836155e+00]
# go back to ----- 1700
# ----- 1700
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.3311744335620226
# RUN  0 , total integrated cost =  3.3311744335620226
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.3311744335619538
# RUN  2 , total integrated cost =  3.3311744335615545
# RUN  3 , total integrated cost =  3.3311744335608626
# RUN  4 , total integrated cost =  3.3311744335608044
# RUN  5 , total integrated cost =  3.331174433560209
# RUN  6 , total integrated cost =  3.331174433559245
# RUN  7 , total integrated cost =  3.331174433559201
# RUN  8 , total integrated cost =  3.331174433545533
# RUN  9 , total integrated cost =  3.331174433534112
# RUN  10 , total integrated cost =  3.33117443353407
# RUN  11 , total integrated cost =  3.3311744335080236
# RUN  12 , total integrated cost =  3.331174433484024
# RUN  13 , total integrated cost =  3.3311744334839792
# RUN  14 , total integrated cost =  3.3311744334777664
# RUN  15 , total integrated cost =  3.331174433472343
# RUN  16 , total integrated cost =  3.331174433472281
# RUN  17 , total integrated cost =  3.3311744334717313
# RUN  18 , total integrated cost =  3.3311744334714204
# RUN  19 , total integrated cost =  3.331174433471382
# RUN  20 , total integrated cost =  3.331174433467863
# RUN  30 , total integrated cost =  3.3311744333782434
# RUN  40 , total integrated cost =  3.3311744333543074
# RUN  50 , total integrated cost =  3.331174433349041
# RUN  60 , total integrated cost =  3.331174433315477
# RUN  70 , total integrated cost =  3.331174433313221
# RUN  80 , total integrated cost =  3.331174433255376
# RUN  90 , total integrated cost =  3.3311744332467694
# RUN  100 , total integrated cost =  3.331174433242806
# RUN  110 , total integrated cost =  3.331174433239954
# RUN  120 , total integrated cost =  3.3311744331918502
# RUN  130 , total integrated cost =  3.331174433174846
# RUN  140 , total integrated cost =  3.331174433121543
# RUN  150 , total integrated cost =  3.331174433087106
# RUN  160 , total integrated cost =  3.331174433084724
# RUN  170 , total integrated cost =  3.3311744330827344
# RUN  180 , total integrated cost =  3.331174433074276
# RUN  190 , total integrated cost =  3.331174433072387
# RUN  200 , total integrated cost =  3.331174433054084
# RUN  300 , total integrated cost =  3.331174432523375
# RUN  400 , total integrated cost =  3.331174432322386
# RUN  500 , total integrated cost =  3.331174432224345
# RUN  600 , total integrated cost =  3.3311744320777525
# RUN  700 , total integrated cost =  3.3311744317588023
# RUN  800 , total integrated cost =  3.3311744313003597
# RUN  900 , total integrated cost =  3.3311744309095084
# RUN  1000 , total integrated cost =  3.331174430812521
# RUN  1000 , total integrated cost =  3.331174430812521
# Improved over  1000  iterations in  489.0910517820157  seconds by  8.253849159700621e-08  percent.
# 0.0 [7.52696003e-36 5.54836154e+00]
# go back to ----- 1700
# ----- 1700
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.331174430812521
# RUN  0 , total integrated cost =  3.331174430812521
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.331174430812464
# RUN  2 , total integrated cost =  3.3311744308120605
# RUN  3 , total integrated cost =  3.3311744308119113
# RUN  4 , total integrated cost =  3.3311744308118527
# RUN  5 , total integrated cost =  3.3311744308114695
# RUN  6 , total integrated cost =  3.33117443081136
# RUN  7 , total integrated cost =  3.331174430811284
# RUN  8 , total integrated cost =  3.331174430810923
# RUN  9 , total integrated cost =  3.3311744308108273
# RUN  10 , total integrated cost =  3.3311744308107385
# RUN  11 , total integrated cost =  3.33117443081038
# RUN  12 , total integrated cost =  3.331174430810287
# RUN  13 , total integrated cost =  3.3311744308102402
# RUN  14 , total integrated cost =  3.3311744308097535
# RUN  15 , total integrated cost =  3.331174430809553
# RUN  16 , total integrated cost =  3.3311744308095026
# RUN  17 , total integrated cost =  3.3311744308088347
# RUN  18 , total integrated cost =  3.3311744308084754
# RUN  19 , total integrated cost =  3.3311744308084266
# RUN  20 , total integrated cost =  3.3311744308073394
# RUN  30 , total integrated cost =  3.3311744307472484
# RUN  40 , total integrated cost =  3.3311744307452473
# RUN  50 , total integrated cost =  3.3311744307427147
# RUN  60 , total integrated cost =  3.331174430737593
# RUN  70 , total integrated cost =  3.331174430660026
# RUN  80 , total integrated cost =  3.3311744306233715
# RUN  90 , total integrated cost =  3.331174430589137
# RUN  100 , total integrated cost =  3.3311744305163717
# RUN  110 , total integrated cost =  3.331174430456731
# RUN  120 , total integrated cost =  3.3311744303370983
# RUN  130 , total integrated cost =  3.3311744302619672
# RUN  140 , total integrated cost =  3.3311744302589448
# RUN  150 , total integrated cost =  3.3311744302446895
# RUN  160 , total integrated cost =  3.3311744302413966
# RUN  170 , total integrated cost =  3.3311744302128647
# RUN  180 , total integrated cost =  3.331174430210215
# RUN  190 , total integrated cost =  3.3311744302080095
# RUN  200 , total integrated cost =  3.331174430177743
# RUN  300 , total integrated cost =  3.3311744299774726
# RUN  400 , total integrated cost =  3.331174429809653
# RUN  500 , total integrated cost =  3.331174429700295
# RUN  600 , total integrated cost =  3.331174429581597
# RUN  700 , total integrated cost =  3.331174429497144
# RUN  800 , total integrated cost =  3.331174429050315
# RUN  900 , total integrated cost =  3.331174428695686
# RUN  1000 , total integrated cost =  3.3311744283709626
# RUN  1000 , total integrated cost =  3.3311744283709626
# Improved over  1000  iterations in  494.7380795070203  seconds by  7.32942311287843e-08  percent.
# 0.0 [7.52696003e-36 5.54836153e+00]
# go back to ----- 1700
# ----- 1700
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.3311744283709626
# RUN  0 , total integrated cost =  3.3311744283709626
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.3311744283709026
# RUN  2 , total integrated cost =  3.3311744283708618
# RUN  3 , total integrated cost =  3.331174428370069
# RUN  4 , total integrated cost =  3.331174428369652
# RUN  5 , total integrated cost =  3.331174428369617
# RUN  6 , total integrated cost =  3.3311744283670754
# RUN  7 , total integrated cost =  3.3311744283637648
# RUN  8 , total integrated cost =  3.331174428363731
# RUN  9 , total integrated cost =  3.3311744283635285
# RUN  10 , total integrated cost =  3.3311744283630427
# RUN  11 , total integrated cost =  3.3311744283630005
# RUN  12 , total integrated cost =  3.331174428362314
# RUN  13 , total integrated cost =  3.331174428361201
# RUN  14 , total integrated cost =  3.3311744283611544
# RUN  15 , total integrated cost =  3.331174428360939
# RUN  16 , total integrated cost =  3.331174428360411
# RUN  17 , total integrated cost =  3.331174428360362
# RUN  18 , total integrated cost =  3.331174428360283
# RUN  19 , total integrated cost =  3.3311744283599065
# RUN  20 , total integrated cost =  3.3311744283597786
# RUN  30 , total integrated cost =  3.3311744283563236
# RUN  40 , total integrated cost =  3.3311744282814977
# RUN  50 , total integrated cost =  3.3311744282326265
# RUN  60 , total integrated cost =  3.3311744282298634
# RUN  70 , total integrated cost =  3.331174428221552
# RUN  80 , total integrated cost =  3.3311744282185782
# RUN  90 , total integrated cost =  3.3311744282157356
# RUN  100 , total integrated cost =  3.3311744281964857
# RUN  110 , total integrated cost =  3.331174428190027
# RUN  120 , total integrated cost =  3.3311744281882247
# RUN  130 , total integrated cost =  3.3311744281854025
# RUN  140 , total integrated cost =  3.331174428127114
# RUN  150 , total integrated cost =  3.331174428072717
# RUN  160 , total integrated cost =  3.3311744280647178
# RUN  170 , total integrated cost =  3.331174428007628
# RUN  180 , total integrated cost =  3.3311744280041746
# RUN  190 , total integrated cost =  3.3311744279030653
# RUN  200 , total integrated cost =  3.3311744279012157
# RUN  300 , total integrated cost =  3.331174427571163
# RUN  400 , total integrated cost =  3.33117442749705
# RUN  500 , total integrated cost =  3.331174427233074
# RUN  600 , total integrated cost =  3.3311744270558967
# RUN  700 , total integrated cost =  3.331174426586556
# RUN  800 , total integrated cost =  3.331174426305779
# RUN  900 , total integrated cost =  3.3311744261858798
# RUN  1000 , total integrated cost =  3.331174425862097
# RUN  1000 , total integrated cost =  3.331174425862097
# Improved over  1000  iterations in  487.49804613599554  seconds by  7.531474466304644e-08  percent.
# 0.0 [7.52696003e-36 5.54836152e+00]
# go back to ----- 1700
# ----- 1700
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.331174425862097
# RUN  0 , total integrated cost =  3.331174425862097
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.3311744258608926
# RUN  2 , total integrated cost =  3.3311744258608624
# RUN  3 , total integrated cost =  3.331174425860684
# RUN  4 , total integrated cost =  3.3311744258601865
# RUN  5 , total integrated cost =  3.3311744258601412
# RUN  6 , total integrated cost =  3.331174425860096
# RUN  7 , total integrated cost =  3.331174425859438
# RUN  8 , total integrated cost =  3.33117442585913
# RUN  9 , total integrated cost =  3.331174425859049
# RUN  10 , total integrated cost =  3.3311744258586384
# RUN  11 , total integrated cost =  3.331174425858486
# RUN  12 , total integrated cost =  3.3311744258584324
# RUN  13 , total integrated cost =  3.3311744258580376
# RUN  14 , total integrated cost =  3.331174425857904
# RUN  15 , total integrated cost =  3.3311744258578675
# RUN  16 , total integrated cost =  3.3311744258557585
# RUN  17 , total integrated cost =  3.3311744258544103
# RUN  18 , total integrated cost =  3.3311744258543765
# RUN  19 , total integrated cost =  3.331174425851699
# RUN  20 , total integrated cost =  3.3311744258494937
# RUN  30 , total integrated cost =  3.3311744258457123
# RUN  40 , total integrated cost =  3.3311744258423683
# RUN  50 , total integrated cost =  3.331174425719126
# RUN  60 , total integrated cost =  3.3311744256601377
# RUN  70 , total integrated cost =  3.331174425656071
# RUN  80 , total integrated cost =  3.3311744256528177
# RUN  90 , total integrated cost =  3.331174425643327
# RUN  100 , total integrated cost =  3.331174425635235
# RUN  110 , total integrated cost =  3.331174425633254
# RUN  120 , total integrated cost =  3.3311744256268416
# RUN  130 , total integrated cost =  3.33117442560604
# RUN  140 , total integrated cost =  3.3311744256033027
# RUN  150 , total integrated cost =  3.331174425541035
# RUN  160 , total integrated cost =  3.3311744255289137
# RUN  170 , total integrated cost =  3.331174425523502
# RUN  180 , total integrated cost =  3.3311744255190563
# RUN  190 , total integrated cost =  3.331174425516301
# RUN  200 , total integrated cost =  3.3311744255074234
# RUN  300 , total integrated cost =  3.331174422764293
# RUN  400 , total integrated cost =  3.331174422191792
# RUN  500 , total integrated cost =  3.331174421658935
# RUN  600 , total integrated cost =  3.3311744212456085
# RUN  700 , total integrated cost =  3.331174421104542
# RUN  800 , total integrated cost =  3.3311744208157457
# RUN  900 , total integrated cost =  3.3311744205387748
# RUN  1000 , total integrated cost =  3.3311744203425384
# RUN  1000 , total integrated cost =  3.3311744203425384
# Improved over  1000  iterations in  423.43262312794104  seconds by  1.6569407534916536e-07  percent.
# 0.0 [7.52696003e-36 5.54836150e+00]
# go back to ----- 1700
# ----- 1700
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.3311744203425384
# RUN  0 , total integrated cost =  3.3311744203425384
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.3311744203425016
# RUN  2 , total integrated cost =  3.331174420339282
# RUN  3 , total integrated cost =  3.3311744203367013
# RUN  4 , total integrated cost =  3.33117442033667
# RUN  5 , total integrated cost =  3.331174420335628
# RUN  6 , total integrated cost =  3.331174420334174
# RUN  7 , total integrated cost =  3.331174420334142
# RUN  8 , total integrated cost =  3.3311744203338516
# RUN  9 , total integrated cost =  3.3311744203332845
# RUN  10 , total integrated cost =  3.331174420333232
# RUN  11 , total integrated cost =  3.3311744203330824
# RUN  12 , total integrated cost =  3.3311744203326263
# RUN  13 , total integrated cost =  3.331174420332574
# RUN  14 , total integrated cost =  3.331174420332484
# RUN  15 , total integrated cost =  3.3311744203321094
# RUN  16 , total integrated cost =  3.331174420332046
# RUN  17 , total integrated cost =  3.331174420332013
# RUN  18 , total integrated cost =  3.331174420322308
# RUN  19 , total integrated cost =  3.33117442031296
# RUN  20 , total integrated cost =  3.3311744203129092
# RUN  30 , total integrated cost =  3.3311744202128333
# RUN  40 , total integrated cost =  3.331174420143374
# RUN  50 , total integrated cost =  3.331174420140807
# RUN  60 , total integrated cost =  3.3311744201085953
# RUN  70 , total integrated cost =  3.3311744201048823
# RUN  80 , total integrated cost =  3.3311744201023656
# RUN  90 , total integrated cost =  3.331174420061231
# RUN  100 , total integrated cost =  3.3311744200553446
# RUN  110 , total integrated cost =  3.331174420025312
# RUN  120 , total integrated cost =  3.3311744200161293
# RUN  130 , total integrated cost =  3.3311744199511266
# RUN  140 , total integrated cost =  3.331174419949375
# RUN  150 , total integrated cost =  3.33117441989341
# RUN  160 , total integrated cost =  3.3311744198156714
# RUN  170 , total integrated cost =  3.331174419722053
# RUN  180 , total integrated cost =  3.331174419607082
# RUN  190 , total integrated cost =  3.331174419599902
# RUN  200 , total integrated cost =  3.3311744195327315
# RUN  300 , total integrated cost =  3.3311744193036117
# RUN  400 , total integrated cost =  3.331174418786678
# RUN  500 , total integrated cost =  3.3311744182874907
# RUN  600 , total integrated cost =  3.3311744177926155
# RUN  700 , total integrated cost =  3.33117441753132
# RUN  800 , total integrated cost =  3.3311744172731554
# RUN  900 , total integrated cost =  3.331174416563089
# RUN  1000 , total integrated cost =  3.3311744159543526
# RUN  1000 , total integrated cost =  3.3311744159543526
# Improved over  1000  iterations in  447.5360706349602  seconds by  1.317308999659872e-07  percent.
# 0.0 [7.52696003e-36 5.54836149e+00]
# go back to ----- 1700
# ----- 1700
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.3311744159543526
# RUN  0 , total integrated cost =  3.3311744159543526
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.331174415945814
# RUN  2 , total integrated cost =  3.331174415945735
# RUN  3 , total integrated cost =  3.331174415945384
# RUN  4 , total integrated cost =  3.3311744159453056
# RUN  5 , total integrated cost =  3.331174415945213
# RUN  6 , total integrated cost =  3.3311744159448526
# RUN  7 , total integrated cost =  3.3311744159447896
# RUN  8 , total integrated cost =  3.331174415944325
# RUN  9 , total integrated cost =  3.331174415943494
# RUN  10 , total integrated cost =  3.3311744159434533
# RUN  11 , total integrated cost =  3.3311744159422307
# RUN  12 , total integrated cost =  3.331174415940507
# RUN  13 , total integrated cost =  3.33117441594046
# RUN  14 , total integrated cost =  3.331174415940242
# RUN  15 , total integrated cost =  3.331174415939735
# RUN  16 , total integrated cost =  3.3311744159396803
# RUN  17 , total integrated cost =  3.3311744159395165
# RUN  18 , total integrated cost =  3.3311744159390626
# RUN  19 , total integrated cost =  3.3311744159389995
# RUN  20 , total integrated cost =  3.3311744159389636
# RUN  30 , total integrated cost =  3.331174415904901
# RUN  40 , total integrated cost =  3.331174415895608
# RUN  50 , total integrated cost =  3.331174415871189
# RUN  60 , total integrated cost =  3.3311744158666077
# RUN  70 , total integrated cost =  3.3311744158609726
# RUN  80 , total integrated cost =  3.331174415856575
# RUN  90 , total integrated cost =  3.331174415849595
# RUN  100 , total integrated cost =  3.3311744158454113
# RUN  110 , total integrated cost =  3.331174415843657
# RUN  120 , total integrated cost =  3.3311744158172645
# RUN  130 , total integrated cost =  3.331174415809773
# RUN  140 , total integrated cost =  3.3311744158046235
# RUN  150 , total integrated cost =  3.3311744158020073
# RUN  160 , total integrated cost =  3.331174415783228
# RUN  170 , total integrated cost =  3.331174415781524
# RUN  180 , total integrated cost =  3.331174415779763
# RUN  190 , total integrated cost =  3.331174415771713
# RUN  200 , total integrated cost =  3.331174415769744
# RUN  300 , total integrated cost =  3.3311744155210365
# RUN  400 , total integrated cost =  3.3311744150842992
# RUN  500 , total integrated cost =  3.3311744145535735
# RUN  600 , total integrated cost =  3.331174414000054
# RUN  700 , total integrated cost =  3.331174413763192
# RUN  800 , total integrated cost =  3.331174413411383
# RUN  900 , total integrated cost =  3.331174412944886
# RUN  1000 , total integrated cost =  3.3311744122174036
# RUN  1000 , total integrated cost =  3.3311744122174036
# Improved over  1000  iterations in  478.0371075599687  seconds by  1.121811266102668e-07  percent.
# 0.0 [7.52696003e-36 5.54836148e+00]
# go back to ----- 1700
# ----- 1700
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.3311744122174036
# RUN  0 , total integrated cost =  3.3311744122174036
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.3311744122173415
# RUN  2 , total integrated cost =  3.331174412217221
# RUN  3 , total integrated cost =  3.3311744122168636
# RUN  4 , total integrated cost =  3.3311744122168023
# RUN  5 , total integrated cost =  3.3311744122166305
# RUN  6 , total integrated cost =  3.331174412216244
# RUN  7 , total integrated cost =  3.3311744122161855
# RUN  8 , total integrated cost =  3.3311744122159825
# RUN  9 , total integrated cost =  3.331174412215524
# RUN  10 , total integrated cost =  3.3311744122154687
# RUN  11 , total integrated cost =  3.331174412215264
# RUN  12 , total integrated cost =  3.331174412214807
# RUN  13 , total integrated cost =  3.3311744122147506
# RUN  14 , total integrated cost =  3.3311744122145495
# RUN  15 , total integrated cost =  3.3311744122140916
# RUN  16 , total integrated cost =  3.3311744122140343
# RUN  17 , total integrated cost =  3.33117441221328
# RUN  18 , total integrated cost =  3.3311744122120746
# RUN  19 , total integrated cost =  3.3311744122120324
# RUN  20 , total integrated cost =  3.331174412210688
# RUN  30 , total integrated cost =  3.3311744121841294
# RUN  40 , total integrated cost =  3.331174412168616
# RUN  50 , total integrated cost =  3.3311744121135636
# RUN  60 , total integrated cost =  3.3311744120189424
# RUN  70 , total integrated cost =  3.3311744120172206
# RUN  80 , total integrated cost =  3.3311744120155486
# RUN  90 , total integrated cost =  3.3311744120135023
# RUN  100 , total integrated cost =  3.3311744119834588
# RUN  110 , total integrated cost =  3.3311744116812663
# RUN  120 , total integrated cost =  3.331174411676674
# RUN  130 , total integrated cost =  3.33117441137139
# RUN  140 , total integrated cost =  3.3311744113647284
# RUN  150 , total integrated cost =  3.3311744112809354
# RUN  160 , total integrated cost =  3.331174411277247
# RUN  170 , total integrated cost =  3.3311744112689423
# RUN  180 , total integrated cost =  3.331174411267305
# RUN  190 , total integrated cost =  3.331174411265679
# RUN  200 , total integrated cost =  3.3311744112616215
# RUN  300 , total integrated cost =  3.331174410041319
# RUN  400 , total integrated cost =  3.331174409983565
# RUN  500 , total integrated cost =  3.3311744097284524
# RUN  600 , total integrated cost =  3.331174409662192
# RUN  700 , total integrated cost =  3.3311744094717386
# RUN  800 , total integrated cost =  3.331174409252415
# RUN  900 , total integrated cost =  3.3311744092133733
# RUN  1000 , total integrated cost =  3.331174409057872
# RUN  1000 , total integrated cost =  3.331174409057872
# Improved over  1000  iterations in  465.33393197797704  seconds by  9.48473797279803e-08  percent.
# 0.0 [7.52696003e-36 5.54836147e+00]
# go back to ----- 1700
# ----- 1700
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.331174409057872
# RUN  0 , total integrated cost =  3.331174409057872
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.3311744090577955
# RUN  2 , total integrated cost =  3.3311744090574407
# RUN  3 , total integrated cost =  3.331174409057381
# RUN  4 , total integrated cost =  3.331174409056789
# RUN  5 , total integrated cost =  3.3311744090557447
# RUN  6 , total integrated cost =  3.3311744090557083
# RUN  7 , total integrated cost =  3.331174409054008
# RUN  8 , total integrated cost =  3.3311744090518496
# RUN  9 , total integrated cost =  3.3311744090518127
# RUN  10 , total integrated cost =  3.331174408800138
# RUN  11 , total integrated cost =  3.331174408513894
# RUN  12 , total integrated cost =  3.331174408513407
# RUN  13 , total integrated cost =  3.3311744085133554
# RUN  14 , total integrated cost =  3.33117440851264
# RUN  15 , total integrated cost =  3.3311744085114836
# RUN  16 , total integrated cost =  3.33117440851145
# RUN  17 , total integrated cost =  3.3311744085099857
# RUN  18 , total integrated cost =  3.331174408508062
# RUN  19 , total integrated cost =  3.331174408508024
# RUN  20 , total integrated cost =  3.3311744085005888
# RUN  30 , total integrated cost =  3.3311744084921218
# RUN  40 , total integrated cost =  3.3311744084865094
# RUN  50 , total integrated cost =  3.3311744084765413
# RUN  60 , total integrated cost =  3.3311744083388506
# RUN  70 , total integrated cost =  3.3311744083360053
# RUN  80 , total integrated cost =  3.3311744083257615
# RUN  90 , total integrated cost =  3.3311744083240424
# ...
# RUN  500 , total integrated cost =  3.3311937092462633
# RUN  600 , total integrated cost =  3.3311937015676945
# RUN  700 , total integrated cost =  3.331193694829958
# RUN  800 , total integrated cost =  3.331193688167384
# RUN  900 , total integrated cost =  3.3311936805846463
# RUN  1000 , total integrated cost =  3.3311936730077845
# RUN  1000 , total integrated cost =  3.3311936730077845
# Improved over  1000  iterations in  525.4205186010804  seconds by  2.1720714897810467e-06  percent.
# 0.0 [1.77072849e-24 5.54842555e+00]
# go back to ----- 2000
# ----- 2000
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.3311936730077845
# RUN  0 , total integrated cost =  3.3311936730077845
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.331193672946206
# RUN  2 , total integrated cost =  3.3311936729275002
# RUN  3 , total integrated cost =  3.3311936728983085
# RUN  4 , total integrated cost =  3.3311936728851985
# RUN  5 , total integrated cost =  3.3311936728555698
# RUN  6 , total integrated cost =  3.3311936728352802
# RUN  7 , total integrated cost =  3.3311936725626135
# RUN  8 , total integrated cost =  3.331193672319607
# RUN  9 , total integrated cost =  3.331193672274709
# RUN  10 , total integrated cost =  3.3311936722182374
# RUN  11 , total integrated cost =  3.3311936721980815
# RUN  12 , total integrated cost =  3.3311936721683453
# RUN  13 , total integrated cost =  3.331193672155239
# RUN  14 , total integrated cost =  3.3311936721262607
# RUN  15 , total integrated cost =  3.331193672105166
# RUN  16 , total integrated cost =  3.331193671848221
# RUN  17 , total integrated cost =  3.3311936716256687
# RUN  18 , total integrated cost =  3.331193671576852
# RUN  19 , total integrated cost =  3.331193671515367
# RUN  20 , total integrated cost =  3.3311936714966666
# RUN  30 , total integrated cost =  3.331193670737814
# RUN  40 , total integrated cost =  3.3311936700251628
# RUN  50 , total integrated cost =  3.331193669369175
# RUN  60 , total integrated cost =  3.3311936687260015
# RUN  70 , total integrated cost =  3.331193667870744
# RUN  80 , total integrated cost =  3.331193666760586
# RUN  90 , total integrated cost =  3.3311936660683936
# RUN  100 , total integrated cost =  3.331193665408186
# RUN  110 , total integrated cost =  3.331193664527559
# RUN  120 , total integrated cost =  3.3311936637516277
# RUN  130 , total integrated cost =  3.331193662917227
# RUN  140 , total integrated cost =  3.3311936618951155
# RUN  150 , total integrated cost =  3.3311936612163175
# RUN  160 , total integrated cost =  3.3311936605947166
# RUN  170 , total integrated cost =  3.3311936592867037
# RUN  180 , total integrated cost =  3.331193658303165
# RUN  190 , total integrated cost =  3.3311936573815015
# RUN  200 , total integrated cost =  3.3311936562547597
# RUN  300 , total integrated cost =  3.3311936471756964
# RUN  400 , total integrated cost =  3.331193636234029
# RUN  500 , total integrated cost =  3.331193627508858
# RUN  600 , total integrated cost =  3.3311936133201847
# RUN  700 , total integrated cost =  3.3311935912532804
# RUN  800 , total integrated cost =  3.3311935529511
# RUN  900 , total integrated cost =  3.331193307745592
# RUN  1000 , total integrated cost =  3.3311932241608293
# RUN  1000 , total integrated cost =  3.3311932241608293
# Improved over  1000  iterations in  512.3287495929981  seconds by  1.3474057624307534e-05  percent.
# 0.0 [1.77072849e-24 5.54842407e+00]
# go back to ----- 2000
# ----- 2000
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.3311932241608293
# RUN  0 , total integrated cost =  3.3311932241608293
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.3311932240534343
# RUN  2 , total integrated cost =  3.331193223962302
# RUN  3 , total integrated cost =  3.3311932239071833
# RUN  4 , total integrated cost =  3.3311932238429325
# RUN  5 , total integrated cost =  3.331193223832341
# RUN  6 , total integrated cost =  3.331193223812083
# RUN  7 , total integrated cost =  3.3311932238011144
# RUN  8 , total integrated cost =  3.3311932237701902
# RUN  9 , total integrated cost =  3.3311932237481416
# RUN  10 , total integrated cost =  3.3311932236433326
# RUN  11 , total integrated cost =  3.3311932235496173
# RUN  12 , total integrated cost =  3.3311932234957626
# RUN  13 , total integrated cost =  3.3311932234303008
# RUN  14 , total integrated cost =  3.3311932234198
# RUN  15 , total integrated cost =  3.3311932233995427
# RUN  16 , total integrated cost =  3.331193223388477
# RUN  17 , total integrated cost =  3.3311932233313994
# RUN  18 , total integrated cost =  3.3311932232848496
# RUN  19 , total integrated cost =  3.3311932231761823
# RUN  20 , total integrated cost =  3.3311932230546595
# RUN  30 , total integrated cost =  3.3311932208368056
# RUN  40 , total integrated cost =  3.331193220404406
# RUN  50 , total integrated cost =  3.3311932199704506
# RUN  60 , total integrated cost =  3.3311932176552475
# RUN  70 , total integrated cost =  3.331193217067459
# RUN  80 , total integrated cost =  3.3311932148532937
# RUN  90 , total integrated cost =  3.3311932143978584
# RUN  100 , total integrated cost =  3.33119321388948
# RUN  110 , total integrated cost =  3.3311932132879067
# RUN  120 , total integrated cost =  3.3311932126075834
# RUN  130 , total integrated cost =  3.3311932121767174
# RUN  140 , total integrated cost =  3.3311932116665335
# RUN  150 , total integrated cost =  3.33119321121307
# RUN  160 , total integrated cost =  3.331193210489546
# RUN  170 , total integrated cost =  3.3311932080218263
# RUN  180 , total integrated cost =  3.331193207530831
# RUN  190 , total integrated cost =  3.331193206908269
# RUN  200 , total integrated cost =  3.3311932062422165
# RUN  300 , total integrated cost =  3.3311931936962957
# RUN  400 , total integrated cost =  3.3311931860553523
# RUN  500 , total integrated cost =  3.3311931774892796
# RUN  600 , total integrated cost =  3.331193168897791
# RUN  700 , total integrated cost =  3.33119316142562
# RUN  800 , total integrated cost =  3.3311931545036013
# RUN  900 , total integrated cost =  3.3311931445654204
# RUN  1000 , total integrated cost =  3.331193132605843
# RUN  1000 , total integrated cost =  3.331193132605843
# Improved over  1000  iterations in  494.90107688796706  seconds by  2.748414161146684e-06  percent.
# 0.0 [1.77072849e-24 5.54842376e+00]
# go back to ----- 2000
# ----- 2000
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.331193132605843
# RUN  0 , total integrated cost =  3.331193132605843
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.331193132499074
# RUN  2 , total integrated cost =  3.3311931323615225
# RUN  3 , total integrated cost =  3.331193132212483
# RUN  4 , total integrated cost =  3.3311931322016344
# RUN  5 , total integrated cost =  3.331193132181723
# RUN  6 , total integrated cost =  3.331193132170715
# RUN  7 , total integrated cost =  3.3311931320257293
# RUN  8 , total integrated cost =  3.3311931318841053
# RUN  9 , total integrated cost =  3.3311931317787136
# RUN  10 , total integrated cost =  3.3311931316594334
# RUN  11 , total integrated cost =  3.331193131647018
# RUN  12 , total integrated cost =  3.331193131625282
# RUN  13 , total integrated cost =  3.331193131616182
# RUN  14 , total integrated cost =  3.3311931315820713
# RUN  15 , total integrated cost =  3.3311931315570256
# RUN  16 , total integrated cost =  3.331193130922563
# RUN  17 , total integrated cost =  3.331193130310256
# RUN  18 , total integrated cost =  3.33119313029635
# RUN  19 , total integrated cost =  3.3311931302743716
# RUN  20 , total integrated cost =  3.3311931302651905
# RUN  30 , total integrated cost =  3.331193127845996
# RUN  40 , total integrated cost =  3.3311931260933383
# RUN  50 , total integrated cost =  3.3311931253753775
# RUN  60 , total integrated cost =  3.3311931245684514
# RUN  70 , total integrated cost =  3.3311931234204692
# RUN  80 , total integrated cost =  3.331193122752433
# RUN  90 , total integrated cost =  3.3311931213850445
# RUN  100 , total integrated cost =  3.3311931200405227
# RUN  110 , total integrated cost =  3.33119311925734
# RUN  120 , total integrated cost =  3.331193117947679
# RUN  130 , total integrated cost =  3.331193115147762
# RUN  140 , total integrated cost =  3.331193113656131
# RUN  150 , total integrated cost =  3.3311931108848998
# RUN  160 , total integrated cost =  3.3311931072618486
# RUN  170 , total integrated cost =  3.3311931057929005
# RUN  180 , total integrated cost =  3.331193101207271
# RUN  190 , total integrated cost =  3.331193100265296
# RUN  200 , total integrated cost =  3.331193097226822
# RUN  300 , total integrated cost =  3.3311899574468837
# RUN  400 , total integrated cost =  3.3311899505304408
# RUN  500 , total integrated cost =  3.3311899481719034
# RUN  600 , total integrated cost =  3.331189945508799
# RUN  700 , total integrated cost =  3.3311899431739342
# RUN  800 , total integrated cost =  3.331189940901076
# RUN  900 , total integrated cost =  3.331189939627264
# RUN  1000 , total integrated cost =  3.3311899384726935
# RUN  1000 , total integrated cost =  3.3311899384726935
# Improved over  1000  iterations in  486.9419153740164  seconds by  9.588555879247451e-05  percent.
# 0.0 [1.77072849e-24 5.54841317e+00]
# go back to ----- 2000
# ----- 2000
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.3311899384726935
# RUN  0 , total integrated cost =  3.3311899384726935
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.331189938463991
# RUN  2 , total integrated cost =  3.3311899384522623
# RUN  3 , total integrated cost =  3.331189938451281
# RUN  4 , total integrated cost =  3.331189938447317
# RUN  5 , total integrated cost =  3.3311899384453114
# RUN  6 , total integrated cost =  3.331189938420235
# RUN  7 , total integrated cost =  3.3311899383909642
# RUN  8 , total integrated cost =  3.331189938389982
# RUN  9 , total integrated cost =  3.331189938384635
# RUN  10 , total integrated cost =  3.3311899383812245
# RUN  11 , total integrated cost =  3.331189938367642
# RUN  12 , total integrated cost =  3.3311899383504917
# RUN  13 , total integrated cost =  3.331189938349244
# RUN  14 , total integrated cost =  3.3311899383459123
# RUN  15 , total integrated cost =  3.331189938344511
# RUN  16 , total integrated cost =  3.3311899381749632
# RUN  17 , total integrated cost =  3.331189938012677
# RUN  18 , total integrated cost =  3.3311899380116956
# RUN  19 , total integrated cost =  3.331189938000143
# RUN  20 , total integrated cost =  3.331189937991273
# RUN  30 , total integrated cost =  3.331189937920638
# RUN  40 , total integrated cost =  3.331189937819864
# RUN  50 , total integrated cost =  3.3311899374446297
# RUN  60 , total integrated cost =  3.331189937301115
# RUN  70 , total integrated cost =  3.3311899372401106
# RUN  80 , total integrated cost =  3.3311899368650018
# RUN  90 , total integrated cost =  3.331189936720245
# RUN  100 , total integrated cost =  3.331189936658529
# RUN  110 , total integrated cost =  3.3311899363102926
# RUN  120 , total integrated cost =  3.3311899361985398
# RUN  130 , total integrated cost =  3.3311899360936086
# RUN  140 , total integrated cost =  3.331189935983445
# RUN  150 , total integrated cost =  3.3311899355637253
# RUN  160 , total integrated cost =  3.331189935463096
# RUN  170 , total integrated cost =  3.3311899353234944
# RUN  180 , total integrated cost =  3.3311899352162975
# RUN  190 , total integrated cost =  3.331189935094411
# RUN  200 , total integrated cost =  3.3311899348787253
# RUN  300 , total integrated cost =  3.3311899328871655
# RUN  400 , total integrated cost =  3.331189931363596
# RUN  500 , total integrated cost =  3.3311899291290574
# RUN  600 , total integrated cost =  3.3311899273777548
# RUN  700 , total integrated cost =  3.3311899263428835
# RUN  800 , total integrated cost =  3.3311899252706247
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_140593/3411843059.py in <module>
#      61                 control0 = bestControl_[i][j][:,:,100:-(100+j)]
#      62
# ---> 63         bestControl_[i][j], bestState_[i][j], cost_[i][j], runtime_, grad_, phi_, phi1_, costnode_[i][j] = aln.A1(
#      64             control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
#      65             startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
#
# ~/Promotion/neurolib/neurolib/models/model.py in A1(self, control_, target_state_, c_scheme_, u_mat_, u_scheme_, max_iteration_, tolerance_, startStep_, max_control_, min_control_, t_sim_, t_sim_pre_, t_sim_post_, CGVar, line_search_, control_variables_, prec_variables_, separate_comp, transition_time_, noise_real, init_params)
#     661             if self.params.N == 1:
#     662                 if noise_real == 0:
# --> 663                     return opti1_rate_control.A1(self, control_, target_state_, c_scheme_, u_mat_, u_scheme_, max_iteration_,
#     664                                                 tolerance_, startStep_, max_control_, min_control_, t_sim_, t_sim_pre_, t_sim_post_, CGVar,
#     665                                                 line_search_, control_variables_, prec_variables_, separate_comp, transition_time_)
#
# ~/Promotion/neurolib/neurolib/utils/A1_aln_rate_control.py in A1(model, control_, target_state, c_scheme_, u_mat_, u_scheme_, max_iteration_, tolerance_, startStep_, cntrl_max_, cntrl_min_, t_sim_, t_sim_pre_, t_sim_post_, CGVar, line_search_, control_variables_, prec_variables_, separate_comp, transition_time_)
#     483
#     484
# --> 485         step_, total_cost_[i], startStep_ = line_search_func(model, N, n_control_vars, T, dt, state1_[:,:2,:], target_state_,
#     486                      best_control_, dir0_, ip_, ie_, is_, start_step_ = startStep_, max_it_ = 500, max_control_ = cntrl_max_,
#     487                          min_control_ = cntrl_min_, tolerance_ = tolerance_step, variables_ = prec_variables, grad_ = grad1_)
#
# ~/Promotion/neurolib/neurolib/utils/func_optimize.py in step_size(model, N, V, T, dt, state_, target_, control_, dir_, ip_, ie_, is_, start_step_, max_it_, bisec_factor_, max_control_, min_control_, tolerance_, substep_, variables_, alg, control_parameter, grad_, noise_real, init_vars, startind_)
#     233                 #print(init_vars)
#     234                 set_init(model, init_vars, model.init_vars, model.state_vars, startind_)
# --> 235             state1_ = updateState(model, test_control_)
#     236             cost1_int_ = cost.f_int(N, V, T, dt, state1_, target_, test_control_, ip_, ie_, is_, v_ = variables_)
#     237         else:
#
# ~/Promotion/neurolib/neurolib/utils/func_optimize.py in updateState(model, control_)
#       8     state_ = model.getZeroState()
#       9     output_vars = model.output_vars
# ---> 10     model.run(control = control_)
#      11     for i in range(len(output_vars)):
#      12         state_[:,i,:] = model[output_vars[i]][:,:]
#
# ~/Promotion/neurolib/neurolib/models/model.py in run(self, inputs, chunkwise, chunksize, bold, append, append_outputs, continue_run, control)
#     182
#     183         if chunkwise is False:
# --> 184             self.integrate(append_outputs=append, simulate_bold=bold, control=cntrl)
#     185             if continue_run:
#     186                 self.setInitialValuesToLastState()
#
# ~/Promotion/neurolib/neurolib/models/model.py in integrate(self, append_outputs, simulate_bold, control)
#     223         # run integration
#     224         #print("before integration")
# --> 225         t, *variables = self.integration(self.params, control=control)
#     226         #print("after integration")
#     227         self.storeOutputsAndStates(t, variables, append=append_outputs)
#
# ~/Promotion/neurolib/neurolib/models/aln/timeIntegration.py in timeIntegration(params, control)
#     281     # ------------------------------------------------------------------------
#     282
# --> 283     return timeIntegration_njit_elementwise(
#     284         dt,
#     285         duration,
#
# KeyboardInterrupt:

# %%
bestControl_maxW = np.array( [[None] * len(t_pen)] * len(exc) )
bestState_maxW = np.array( [[None] * len(t_pen)] * len(exc) )
cost_maxW = np.array( [[None] * len(t_pen)] * len(exc) )
costnode_maxW = np.array( [[None] * len(t_pen)] * len(exc) )
weights_maxW = np.array( [[None] * len(t_pen)] * len(exc) )
convergence_maxW = np.array( [[None] * len(t_pen)] * len(exc) )

file_maxW = 'down_Wmax.pickle'

# %%
if os.path.isfile(file_maxW) :
    print("file found")
    
    with open(file_maxW,'rb') as f:
        load_array = pickle.load(f)

    bestControl_maxW = load_array[0]
    bestState_maxW = load_array[1]
    cost_maxW = load_array[2]
    costnode_maxW = load_array[3]
    weights_maxW = load_array[4]
  

file_maxW_save = 'down_Wmax_save.pickle'
if os.path.isfile(file_maxW) :
    print("file found")
    
    with open(file_maxW,'rb') as f:
        load_array = pickle.load(f)

    bestControl_maxW_save = load_array[0]
# Out:
# file found
# file found

# %%
bestControl_maxW[0][0] = bestControl_maxW_save[0][0].copy()

# %%
i = 0
for j in np.arange(3800,4800,1):
    bestControl_maxW[i][j] = None
    
for j in np.arange(0,3800,100):
    convergence_maxW[i][j] = None
    
convergence_maxW[0][0] = None

# %%
for i in i_range:
    print('------------', i)
    j = 0

    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.

    while not convergence_maxW[i][j]:
        dur = d_array[j]
        aln.params.duration = dur

        setinit(initVars[i], aln)

        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        control0 = aln.getZeroControl()
        if type(bestControl_maxW[i][j]) == type(None):
            max_it = 10
            control0 = bestControl_[i][0][:,:,n_pre-1:-n_post+1]
            weight_ = ( cost_uncontrolled[i] * (1. - t_pen[0]) / (1. - t_pen[j]) 
                       - sum(costnode_[i][j][0][0][:]) ) / sum( costnode_[i][j][cost_index][0][:] )
            cost.setParams(1., weight_ * factor_we, weight_ * factor_ws)
            weights_maxW[i][j] = cost.getParams()
        else:
            control0 = bestControl_maxW[i][j][:,:,n_pre-1:-n_post+1]
            weight_ = ( cost_uncontrolled[i] * (1. - t_pen[0]) / (1. - t_pen[j])
                       - sum(costnode_maxW[i][j][0][0][:]) ) / sum( costnode_maxW[i][j][cost_index][0][:] )
            cost.setParams(1., weight_ * factor_we, weight_ * factor_ws)
            weights_maxW[i][j] = cost.getParams()
            max_it = int(10)

        bestControl_maxW[i][j], bestState_maxW[i][j], cost_maxW[i][j], runtime_, grad_, phi_, phi1_, costnode_maxW[i][j] = aln.A1(
            control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
            prec_variables_ = p_var, transition_time_ = t_pen[j])

        if cost_maxW[i][j][2] == 0.:
            convergence_maxW[i][j] = True

        print('cost splitting : ', costnode_maxW[i][j][0][0][0], costnode_maxW[i][j][cost_index][0][:2])
        
        with open(file_maxW,'wb') as f:
            pickle.dump([bestControl_maxW, bestState_maxW, cost_maxW, costnode_maxW, weights_maxW], f)
# Out:
# ------------ 0
# set cost params:  1.0 324292.33103627677 0.0
# interpolate adjoint :  True True True
# initial cost =  1151956.8752274627
# RUN  0 , total integrated cost =  1151956.8752274627
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1151956.8751994243
# RUN  2 , total integrated cost =  1151956.8751989556
# RUN  3 , total integrated cost =  1151956.8751982842
# RUN  4 , total integrated cost =  1151956.875198027
# RUN  5 , total integrated cost =  1151956.8751974565
# RUN  6 , total integrated cost =  1151956.8751970893
# RUN  7 , total integrated cost =  1151956.8751935472
# RUN  8 , total integrated cost =  1151956.8751906971
# RUN  9 , total integrated cost =  1151956.8751854263
# RUN  10 , total integrated cost =  1151956.8751789713
# RUN  10 , total integrated cost =  1151956.8751789713
# Improved over  10  iterations in  8.057782060001045  seconds by  4.209482540318277e-09  percent.
# cost splitting :  0.0 [1.38090901 2.17130843]
# dump data
# set cost params:  1.0 324292.33104992664 0.0
# interpolate adjoint :  True True True
# initial cost =  1151956.87522746
# RUN  0 , total integrated cost =  1151956.87522746
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1151956.8752271973
# RUN  2 , total integrated cost =  1151956.8752266045
# RUN  3 , total integrated cost =  1151956.8752262637
# RUN  4 , total integrated cost =  1151956.8752252664
# RUN  5 , total integrated cost =  1151956.8752244976
# RUN  6 , total integrated cost =  1151956.8751869895
# RUN  7 , total integrated cost =  1151956.8751531015
# RUN  8 , total integrated cost =  1151956.8751489066
# RUN  9 , total integrated cost =  1151956.8751440367
# RUN  10 , total integrated cost =  1151956.8751437748
# RUN  10 , total integrated cost =  1151956.8751437748
# Improved over  10  iterations in  7.77167092700256  seconds by  7.264617352120695e-09  percent.
# cost splitting :  0.0 [1.38090901 2.17130843]
# dump data
# set cost params:  1.0 324292.33107348473 0.0
# interpolate adjoint :  True True True
# initial cost =  1151956.8752274583
# RUN  0 , total integrated cost =  1151956.8752274583
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1151956.8752269219
# RUN  2 , total integrated cost =  1151956.875226602
# RUN  3 , total integrated cost =  1151956.875225444
# RUN  4 , total integrated cost =  1151956.8752246199
# RUN  5 , total integrated cost =  1151956.8751931426
# RUN  6 , total integrated cost =  1151956.8751674786
# RUN  7 , total integrated cost =  1151956.8751670972
# RUN  8 , total integrated cost =  1151956.8751664984
# RUN  9 , total integrated cost =  1151956.8751662292
# RUN  10 , total integrated cost =  1151956.8751656855
# RUN  10 , total integrated cost =  1151956.8751656855
# Improved over  10  iterations in  7.9418212049640715  seconds by  5.3624233942173305e-09  percent.
# cost splitting :  0.0 [1.38090901 2.17130843]
# dump data
# set cost params:  1.0 324292.33109087474 0.0
# interpolate adjoint :  True True True
# initial cost =  1151956.875227462
# RUN  0 , total integrated cost =  1151956.875227462
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1151956.875227154
# RUN  2 , total integrated cost =  1151956.8752258823
# RUN  3 , total integrated cost =  1151956.8752249526
# RUN  4 , total integrated cost =  1151956.8751962115
# RUN  5 , total integrated cost =  1151956.875171363
# RUN  6 , total integrated cost =  1151956.8751710004
# RUN  7 , total integrated cost =  1151956.8751704332
# RUN  8 , total integrated cost =  1151956.8751701713
# RUN  9 , total integrated cost =  1151956.8751696297
# RUN  10 , total integrated cost =  1151956.8751693186
# RUN  10 , total integrated cost =  1151956.8751693186
# Improved over  10  iterations in  6.0164810119895265  seconds by  5.047368745181302e-09  percent.
# cost splitting :  0.0 [1.38090901 2.17130843]
# dump data
# set cost params:  1.0 324292.3311072418 0.0
# interpolate adjoint :  True True True

# %%
for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    j = 0
    step = step1

    while j < 4800:

        if j == 0:
            j += step
            continue
            
        if not convergence_maxW[i][j-step]:
            if j - step > 0:
                j -= step
                print('go back to -----', j)

        print('-----', j)

        if convergence_maxW[i][j]:
            j += step
            continue

        dur = d_array[j]
        T = 5001 - j
        aln.params.duration = dur
        setinit(initVars[i], aln)

        max_it = 1000

        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        if type(bestControl_maxW[i][j]) == type(None):
            max_percent_prev = (np.argmax(np.abs(bestControl_maxW[i][j-step]), axis=2)[0,1] - 100) / (T-200)
            shift_ind = 0
            if j < 4000:
                while max_percent_prev > max_percent[i]:
                    shift_ind += 1
                    max_percent_prev = (np.argmax(np.abs(bestControl_maxW[i][j-step]), axis=2)[0,1] - 100 - shift_ind) / (T-200)

            control0 = np.zeros(( bestControl_maxW[i][j-step][:,:,100:-(100+step)].shape ))
            print('shift ind = ', shift_ind)
            if shift_ind != 0:
                control0[:,:,:-shift_ind] = 1. * bestControl_maxW[i][j-step][:,:,100+shift_ind:-(100+step)]
            else:
                control0[:,:,:] = 1. * bestControl_maxW[i][j-step][:,:,100:-(100+step)]
                
            weight_ = ( cost_uncontrolled[i] * (1. - t_pen[0]) / (1. - t_pen[j])
                          - sum(costnode_maxW[i][j-step][0][0][:]) ) / sum( costnode_maxW[i][j-step][cost_index][0][:] )
            cost.setParams(1., weight_ * factor_we, weight_ * factor_ws)
            weights_maxW[i][j] = cost.getParams()
        
        else:
            if bestControl_maxW[i][j].shape[2] == T+200:
                control0 = bestControl_maxW[i][j][:,:,100:-100]
                #control0[0,1,:] = 0.
            else:
                control0 = bestControl_maxW[i][j][:,:,100:-(100+j)]
                
                weight_ = ( cost_uncontrolled[i] * (1. - t_pen[0]) / (1. - t_pen[j])
                           - sum(costnode_maxW[i][j][0][0][:]) ) / sum( costnode_maxW[i][j][cost_index][0][:] )
                cost.setParams(1., weight_ * factor_we, weight_ * factor_ws)
                weights_maxW[i][j] = cost.getParams()

        bestControl_maxW[i][j], bestState_maxW[i][j], cost_maxW[i][j], runtime_, grad_, phi_, phi1_, costnode_maxW[i][j] = aln.A1(
            control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
            prec_variables_ = p_var, transition_time_ = t_pen[j])

        print(costnode_maxW[i][j][0][0][:2], costnode_maxW[i][j][cost_index][0][:2])

        if cost_maxW[i][j][2] == 0.:
            convergence_maxW[i][j] = True
            if j >= 4400:
                step = step2
            if j >=4790:
                step = step3

        with open(file_maxW,'wb') as f:
            pickle.dump([bestControl_maxW, bestState_maxW, cost_maxW, costnode_maxW, weights_maxW], f)

        j += step

# %%
for i in i_range:
    print("------- ", i, exc[i], inh[i])
    
    for j in [0]:
        
        dur = round(d_array[j],1)

        plot_time_array = np.arange(0.,round(dur+aln.params.dt,1),aln.params.dt)

        fig, ax = plt.subplots(2,1, constrained_layout=True, figsize = (4,8) )

        ax[0].plot(plot_time_array, bestState_maxW[i][j][0,0,n_pre-1:-n_post+1], color= 'red')
        ax[0].plot(plot_time_array, bestState_maxW[i][j][0,1,n_pre-1:-n_post+1], color= 'blue')

        ax[1].plot(plot_time_array, bestControl_maxW[i][j][0,1,n_pre-1:-n_post+1], color = 'blue')
        ax[1].plot(plot_time_array, bestControl_maxW[i][j][0,0,n_pre-1:-n_post+1], color = 'red')

        for k in range(2):
            ax[k].set_xlim(0.,dur)
            ax[k].axvspan(dur*t_pen[j], dur, alpha=0.2, color='gray')
        plt.show()
# Out:
# -------  0 0.4500000000000001 0.4750000000000002
# -------  1 0.47500000000000014 0.6000000000000003
