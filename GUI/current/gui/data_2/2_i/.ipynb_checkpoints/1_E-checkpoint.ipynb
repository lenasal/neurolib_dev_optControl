# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import sys
import pickle

path = os.getcwd().split(os.sep + 'GUI')[0]
if path not in sys.path:
    print("not here")
    sys.path.append(path)

from neurolib.models.aln import ALNModel
from neurolib.utils import plotFunctions as plotFunc
from neurolib.utils import costFunctions as cost
import neurolib.dashboard.functions as functions
import neurolib.dashboard.data as data
    
# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2 

#path = os.path.join(os.getcwd(), "plots")
# Out:
# not here

# %%
grid_data_file = os.path.join(os.getcwd().split('data')[0], 'bi.pickle')
with open(grid_data_file,'rb') as f:
    load_array= pickle.load(f)
exc = load_array[0]
inh = load_array[1]

folder = str(os.getcwd().split('data_2')[1])
print(folder)
case = str(folder[1])

file_ = '1_E.pickle'
file_init = '1_E_init.pickle'

c_var = [0]
p_var = [1]
# Out:
# /1_i

# %% [markdown]
# ### Bistability

# %%
aln = ALNModel()
N = aln.params.N

data.set_parameters(aln)

state_vars = aln.state_vars
init_vars = aln.init_vars

##############################################################
def setinit(init_vars_, model):
    state_vars = model.state_vars
    init_vars = model.init_vars
    for iv in range(len(init_vars)):
        for sv in range(len(state_vars)):
            if state_vars[sv] in init_vars[iv]:
                #print("set init vars ", )
                if model.params[init_vars[iv]].ndim == 2:
                    model.params[init_vars[iv]][0,:] = init_vars_[sv]
                else:
                    model.params[init_vars[iv]][0] = init_vars_[sv]
                    
##############################################################               
def setmaxmincontrol(max_c_c, min_c_c, max_c_r, min_c_r):
    import numpy as np
    
    max_cntrl = np.zeros(( 6 ))
    min_cntrl = np.zeros(( 6 ))
    
    max_cntrl[0] = max_c_c
    min_cntrl[0] = min_c_c
    max_cntrl[1] = max_c_c
    min_cntrl[1] = min_c_c
    max_cntrl[2] = max_c_r
    min_cntrl[2] = min_c_r
    max_cntrl[3] = max_c_r
    min_cntrl[3] = min_c_r
    max_cntrl[4] = max_c_r
    min_cntrl[4] = min_c_r
    max_cntrl[5] = max_c_r
    min_cntrl[5] = min_c_r
            
    return max_cntrl, min_cntrl

# %%
d_array = np.arange(500., 20, -0.1)
t0_array = d_array - 20.
t_pen = np.zeros(( t0_array.shape ))
for i in range(len(t_pen)):
    t_pen[i] = t0_array[i] / d_array[i]

# %%
dur_pre = 10
dur_post = 10

n_pre = int(np.around(dur_pre/aln.params.dt + 1.,1))
n_post = int(np.around(dur_post/aln.params.dt + 1.,1))

tol = 1e-12
start_step = 10.
c_scheme = np.zeros(( 1,1 ))
c_scheme[0,0] = 1.
u_mat = np.identity(1)
u_scheme = np.array([[1.]])

if case in ['1', '2']:    # low to high
    max_I = [3., -3.]
else:
    max_I = [-3., 3.]
    
if case in ['1', '3']:    # sparsity
    factor_ws = 1.
    factor_we = 0.
else:
    factor_ws = 0.
    factor_we = 1.
    
maxC = [100., -100., 0.18, 0.]
max_cntrl, min_cntrl = setmaxmincontrol(maxC[0], maxC[1], maxC[2], maxC[3])

# %%
bestControl_ = np.array( [[None] * len(t_pen)] * len(exc) )
bestState_ = np.array( [[None] * len(t_pen)] * len(exc) )
cost_ = np.array( [[None] * len(t_pen)] * len(exc) )
costnode_ = np.array( [[None] * len(t_pen)] * len(exc) )
weights_ = np.array( [[None] * len(t_pen)] * len(exc) )
convergence_ = np.array( [[None] * len(t_pen)] * len(exc) )

initVars = [None] * len(exc)
target = [None] * len(exc)
cost_uncontrolled = [None] * len(exc)
ws = [None] * len(exc)
conv = [None] * len(exc)
conv_shift = [None] * len(exc)

print(bestControl_.shape)
# Out:
# (147, 4800)

# %%
if os.path.isfile(file_) :
    print("file found")
    
    with open(file_,'rb') as f:
        load_array = pickle.load(f)

    bestControl_ = load_array[0]
    bestState_ = load_array[1]
    cost_ = load_array[2]
    costnode_ = load_array[3]
    weights_ = load_array[4]

# %%
# get initial parameters and target states

i_range = [50]
data.set_parameters(aln)

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    aln.params.duration = 3000.
    
    control0 = aln.getZeroControl()
    control0 = functions.step_control(aln, maxI_ = max_I[0])

    aln.run(control=control0)
    
    target_rates = np.zeros((2))
    target_rates[0] = aln.rates_exc[0,-1] 
    target_rates[1] = aln.rates_inh[0,-1]

    control0 = functions.step_control(aln, maxI_ = max_I[1])
    aln.run(control=control0)

    init_state_vars = np.zeros(( len(state_vars) ))
    for j in range(len(state_vars)):
        if aln.state[state_vars[j]].size == 1:
            init_state_vars[j] = aln.state[state_vars[j]][0]
        else:
            init_state_vars[j] = aln.state[state_vars[j]][0,-1]

    initVars[i] = init_state_vars
    target[i] = [target_rates[0], target_rates[1]]
# Out:
# -------  0 0.4000000000000001 0.3500000000000001
# -------  1 0.4250000000000001 0.3500000000000001
# -------  2 0.4000000000000001 0.3750000000000001
# -------  3 0.4250000000000001 0.3750000000000001
# -------  4 0.4500000000000001 0.3750000000000001
# -------  5 0.4000000000000001 0.40000000000000013
# -------  6 0.4250000000000001 0.40000000000000013
# -------  7 0.4500000000000001 0.40000000000000013
# -------  8 0.47500000000000014 0.40000000000000013
# -------  9 0.4000000000000001 0.42500000000000016
# -------  10 0.4250000000000001 0.42500000000000016
# -------  11 0.4500000000000001 0.42500000000000016
# -------  12 0.47500000000000014 0.42500000000000016
# -------  13 0.4000000000000001 0.4500000000000002
# -------  14 0.4250000000000001 0.4500000000000002
# -------  15 0.4500000000000001 0.4500000000000002
# -------  16 0.47500000000000014 0.4500000000000002
# -------  17 0.5000000000000002 0.4500000000000002
# -------  18 0.4000000000000001 0.4750000000000002
# -------  19 0.4250000000000001 0.4750000000000002
# -------  20 0.4500000000000001 0.4750000000000002
# -------  21 0.47500000000000014 0.4750000000000002
# -------  22 0.5000000000000002 0.4750000000000002
# -------  23 0.5250000000000001 0.4750000000000002
# -------  24 0.4000000000000001 0.5000000000000002
# -------  25 0.4250000000000001 0.5000000000000002
# -------  26 0.4500000000000001 0.5000000000000002
# -------  27 0.47500000000000014 0.5000000000000002
# -------  28 0.5000000000000002 0.5000000000000002
# -------  29 0.5250000000000001 0.5000000000000002
# -------  30 0.4250000000000001 0.5250000000000002
# -------  31 0.4500000000000001 0.5250000000000002
# -------  32 0.47500000000000014 0.5250000000000002
# -------  33 0.5000000000000002 0.5250000000000002
# -------  34 0.5250000000000001 0.5250000000000002
# -------  35 0.5500000000000003 0.5250000000000002
# -------  36 0.4250000000000001 0.5500000000000003
# -------  37 0.4500000000000001 0.5500000000000003
# -------  38 0.47500000000000014 0.5500000000000003
# -------  39 0.5000000000000002 0.5500000000000003
# -------  40 0.5250000000000001 0.5500000000000003
# -------  41 0.5500000000000003 0.5500000000000003
# -------  42 0.4250000000000001 0.5750000000000003
# -------  43 0.4500000000000001 0.5750000000000003
# -------  44 0.47500000000000014 0.5750000000000003
# -------  45 0.5000000000000002 0.5750000000000003
# -------  46 0.5250000000000001 0.5750000000000003
# -------  47 0.5500000000000003 0.5750000000000003
# -------  48 0.4250000000000001 0.6000000000000003
# -------  49 0.4500000000000001 0.6000000000000003
# -------  50 0.47500000000000014 0.6000000000000003
# -------  51 0.5000000000000002 0.6000000000000003
# -------  52 0.5250000000000001 0.6000000000000003
# -------  53 0.5500000000000003 0.6000000000000003
# -------  54 0.5750000000000002 0.6000000000000003
# -------  55 0.4250000000000001 0.6250000000000003
# -------  56 0.4500000000000001 0.6250000000000003
# -------  57 0.47500000000000014 0.6250000000000003
# -------  58 0.5000000000000002 0.6250000000000003
# -------  59 0.5250000000000001 0.6250000000000003
# -------  60 0.5500000000000003 0.6250000000000003
# -------  61 0.5750000000000002 0.6250000000000003
# -------  62 0.4250000000000001 0.6500000000000004
# -------  63 0.4500000000000001 0.6500000000000004
# -------  64 0.47500000000000014 0.6500000000000004
# -------  65 0.5000000000000002 0.6500000000000004
# -------  66 0.5250000000000001 0.6500000000000004
# -------  67 0.5500000000000003 0.6500000000000004
# -------  68 0.5750000000000002 0.6500000000000004
# -------  69 0.4250000000000001 0.6750000000000004
# -------  70 0.4500000000000001 0.6750000000000004
# -------  71 0.47500000000000014 0.6750000000000004
# -------  72 0.5000000000000002 0.6750000000000004
# -------  73 0.5250000000000001 0.6750000000000004
# -------  74 0.5500000000000003 0.6750000000000004
# -------  75 0.5750000000000002 0.6750000000000004
# -------  76 0.4250000000000001 0.7000000000000004
# -------  77 0.4500000000000001 0.7000000000000004
# -------  78 0.47500000000000014 0.7000000000000004
# -------  79 0.5000000000000002 0.7000000000000004
# -------  80 0.5250000000000001 0.7000000000000004
# -------  81 0.5500000000000003 0.7000000000000004
# -------  82 0.5750000000000002 0.7000000000000004

# %%
# get uncontrolled cost

data.set_parameters(aln)

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    dur = d_array[0]
    aln.params.duration = dur
    
    target_ = aln.getZeroTarget()
    target_[:,0,:] = target[i][0]
    target_[:,1,:] = target[i][1]
            
    cost.setParams(1.0, 0.0, 0.0)

    setinit(initVars[i], aln)
    control0 = aln.getZeroControl()

    # "HS", "FR", "PR", "HZ"
    cgv = None
    max_it = 0

    bestControl_init_, bestState_init_, cost_init_, runtime_init_, grad_init_, phi_init_, phi1_, costnode_init_ = aln.A1(
        control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
        prec_variables_ = p_var, transition_time_ = t_pen[0])
    
    cost_uncontrolled[i] = cost_init_[0]
# Out:
# -------  0 0.4000000000000001 0.3500000000000001
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  851741.126234488
# RUN  0 , total integrated cost =  851741.126234488
# Gradient descend method:  None
# RUN  0 , total integrated cost =  851741.126234488
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  1 0.4250000000000001 0.3500000000000001
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  841862.7897650615
# RUN  0 , total integrated cost =  841862.7897650615
# Gradient descend method:  None
# RUN  0 , total integrated cost =  841862.7897650615
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  2 0.4000000000000001 0.3750000000000001
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  939937.8436775376
# RUN  0 , total integrated cost =  939937.8436775376
# Gradient descend method:  None
# RUN  0 , total integrated cost =  939937.8436775376
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  3 0.4250000000000001 0.3750000000000001
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  991241.8787598193
# RUN  0 , total integrated cost =  991241.8787598193
# Gradient descend method:  None
# RUN  0 , total integrated cost =  991241.8787598193
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  4 0.4500000000000001 0.3750000000000001
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  932063.1589089162
# RUN  0 , total integrated cost =  932063.1589089162
# Gradient descend method:  None
# RUN  0 , total integrated cost =  932063.1589089162
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  5 0.4000000000000001 0.40000000000000013
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  974684.8435280059
# RUN  0 , total integrated cost =  974684.8435280059
# Gradient descend method:  None
# RUN  0 , total integrated cost =  974684.8435280059
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  6 0.4250000000000001 0.40000000000000013
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1070952.2573424124
# RUN  0 , total integrated cost =  1070952.2573424124
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1070952.2573424124
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  7 0.4500000000000001 0.40000000000000013
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1086145.8969575337
# RUN  0 , total integrated cost =  1086145.8969575337
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1086145.8969575337
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  8 0.47500000000000014 0.40000000000000013
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  984165.1363001884
# RUN  0 , total integrated cost =  984165.1363001884
# Gradient descend method:  None
# RUN  0 , total integrated cost =  984165.1363001884
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  9 0.4000000000000001 0.42500000000000016
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  981656.7506937709
# RUN  0 , total integrated cost =  981656.7506937709
# Gradient descend method:  None
# RUN  0 , total integrated cost =  981656.7506937709
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  10 0.4250000000000001 0.42500000000000016
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1096593.7263782008
# RUN  0 , total integrated cost =  1096593.7263782008
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1096593.7263782008
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  11 0.4500000000000001 0.42500000000000016
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1146217.774481171
# RUN  0 , total integrated cost =  1146217.774481171
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1146217.774481171
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  12 0.47500000000000014 0.42500000000000016
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1146114.0090406262
# RUN  0 , total integrated cost =  1146114.0090406262
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1146114.0090406262
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  13 0.4000000000000001 0.4500000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  971773.055412297
# RUN  0 , total integrated cost =  971773.055412297
# Gradient descend method:  None
# RUN  0 , total integrated cost =  971773.055412297
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  14 0.4250000000000001 0.4500000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1100691.3054383579
# RUN  0 , total integrated cost =  1100691.3054383579
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1100691.3054383579
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  15 0.4500000000000001 0.4500000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1157783.0793728225
# RUN  0 , total integrated cost =  1157783.0793728225
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1157783.0793728225
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  16 0.47500000000000014 0.4500000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1189161.7068847383
# RUN  0 , total integrated cost =  1189161.7068847383
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1189161.7068847383
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  17 0.5000000000000002 0.4500000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1171765.0337162323
# RUN  0 , total integrated cost =  1171765.0337162323
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1171765.0337162323
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  18 0.4000000000000001 0.4750000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  946362.3828508675
# RUN  0 , total integrated cost =  946362.3828508675
# Gradient descend method:  None
# RUN  0 , total integrated cost =  946362.3828508675
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  19 0.4250000000000001 0.4750000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1092768.7723212764
# RUN  0 , total integrated cost =  1092768.7723212764
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1092768.7723212764
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  20 0.4500000000000001 0.4750000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1151956.8752274683
# RUN  0 , total integrated cost =  1151956.8752274683
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1151956.8752274683
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  21 0.47500000000000014 0.4750000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1189297.3718648755
# RUN  0 , total integrated cost =  1189297.3718648755
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1189297.3718648755
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  22 0.5000000000000002 0.4750000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1208054.7053834558
# RUN  0 , total integrated cost =  1208054.7053834558
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1208054.7053834558
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  23 0.5250000000000001 0.4750000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1151573.9710899687
# RUN  0 , total integrated cost =  1151573.9710899687
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1151573.9710899687
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  24 0.4000000000000001 0.5000000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  897733.6028776611
# RUN  0 , total integrated cost =  897733.6028776611
# Gradient descend method:  None
# RUN  0 , total integrated cost =  897733.6028776611
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  25 0.4250000000000001 0.5000000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1076642.0832543923
# RUN  0 , total integrated cost =  1076642.0832543923
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1076642.0832543923
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  26 0.4500000000000001 0.5000000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1137057.9154435426
# RUN  0 , total integrated cost =  1137057.9154435426
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1137057.9154435426
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  27 0.47500000000000014 0.5000000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1175453.3008095506
# RUN  0 , total integrated cost =  1175453.3008095506
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1175453.3008095506
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  28 0.5000000000000002 0.5000000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1201474.4034184096
# RUN  0 , total integrated cost =  1201474.4034184096
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1201474.4034184096
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  29 0.5250000000000001 0.5000000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1205084.4833184804
# RUN  0 , total integrated cost =  1205084.4833184804
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1205084.4833184804
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  30 0.4250000000000001 0.5250000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1055184.554327041
# RUN  0 , total integrated cost =  1055184.554327041
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1055184.554327041
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  31 0.4500000000000001 0.5250000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1116533.3528973474
# RUN  0 , total integrated cost =  1116533.3528973474
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1116533.3528973474
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  32 0.47500000000000014 0.5250000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1155135.458663953
# RUN  0 , total integrated cost =  1155135.458663953
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1155135.458663953
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  33 0.5000000000000002 0.5250000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1182546.3536132257
# RUN  0 , total integrated cost =  1182546.3536132257
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1182546.3536132257
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  34 0.5250000000000001 0.5250000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1198912.4703941653
# RUN  0 , total integrated cost =  1198912.4703941653
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1198912.4703941653
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  35 0.5500000000000003 0.5250000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1161897.0823752123
# RUN  0 , total integrated cost =  1161897.0823752123
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1161897.0823752123
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  36 0.4250000000000001 0.5500000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1030555.2629393265
# RUN  0 , total integrated cost =  1030555.2629393265
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1030555.2629393265
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  37 0.4500000000000001 0.5500000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1092649.0172600225
# RUN  0 , total integrated cost =  1092649.0172600225
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1092649.0172600225
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  38 0.47500000000000014 0.5500000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1131214.6459628372
# RUN  0 , total integrated cost =  1131214.6459628372
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1131214.6459628372
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  39 0.5000000000000002 0.5500000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1158803.6444893093
# RUN  0 , total integrated cost =  1158803.6444893093
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1158803.6444893093
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  40 0.5250000000000001 0.5500000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1178421.0668461532
# RUN  0 , total integrated cost =  1178421.0668461532
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1178421.0668461532
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  41 0.5500000000000003 0.5500000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1178427.9207336425
# RUN  0 , total integrated cost =  1178427.9207336425
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1178427.9207336425
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  42 0.4250000000000001 0.5750000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1004211.9254131663
# RUN  0 , total integrated cost =  1004211.9254131663
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1004211.9254131663
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  43 0.4500000000000001 0.5750000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1066927.3538116259
# RUN  0 , total integrated cost =  1066927.3538116259
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1066927.3538116259
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  44 0.47500000000000014 0.5750000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1105353.4609035773
# RUN  0 , total integrated cost =  1105353.4609035773
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1105353.4609035773
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  45 0.5000000000000002 0.5750000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1132796.4953516964
# RUN  0 , total integrated cost =  1132796.4953516964
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1132796.4953516964
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  46 0.5250000000000001 0.5750000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1153251.0426032085
# RUN  0 , total integrated cost =  1153251.0426032085
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1153251.0426032085
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  47 0.5500000000000003 0.5750000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1163289.6745019276
# RUN  0 , total integrated cost =  1163289.6745019276
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1163289.6745019276
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  48 0.4250000000000001 0.6000000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  977139.0217057094
# RUN  0 , total integrated cost =  977139.0217057094
# Gradient descend method:  None
# RUN  0 , total integrated cost =  977139.0217057094
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  49 0.4500000000000001 0.6000000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1040362.7727986862
# RUN  0 , total integrated cost =  1040362.7727986862
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1040362.7727986862
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  50 0.47500000000000014 0.6000000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1078580.8097708924
# RUN  0 , total integrated cost =  1078580.8097708924
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1078580.8097708924
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  51 0.5000000000000002 0.6000000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1105759.303066827
# RUN  0 , total integrated cost =  1105759.303066827
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1105759.303066827
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  52 0.5250000000000001 0.6000000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1126329.7086576482
# RUN  0 , total integrated cost =  1126329.7086576482
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1126329.7086576482
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  53 0.5500000000000003 0.6000000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1139797.9695023806
# RUN  0 , total integrated cost =  1139797.9695023806
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1139797.9695023806
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  54 0.5750000000000002 0.6000000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1116440.2520114803
# RUN  0 , total integrated cost =  1116440.2520114803
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1116440.2520114803
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  55 0.4250000000000001 0.6250000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  949936.2627154422
# RUN  0 , total integrated cost =  949936.2627154422
# Gradient descend method:  None
# RUN  0 , total integrated cost =  949936.2627154422
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  56 0.4500000000000001 0.6250000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1013582.6830960624
# RUN  0 , total integrated cost =  1013582.6830960624
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1013582.6830960624
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  57 0.47500000000000014 0.6250000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1051539.9719553154
# RUN  0 , total integrated cost =  1051539.9719553154
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1051539.9719553154
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  58 0.5000000000000002 0.6250000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1078418.9506294997
# RUN  0 , total integrated cost =  1078418.9506294997
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1078418.9506294997
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  59 0.5250000000000001 0.6250000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1098846.8901214038
# RUN  0 , total integrated cost =  1098846.8901214038
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1098846.8901214038
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  60 0.5500000000000003 0.6250000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1113642.602864101
# RUN  0 , total integrated cost =  1113642.602864101
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1113642.602864101
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  61 0.5750000000000002 0.6250000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1109758.57577721
# RUN  0 , total integrated cost =  1109758.57577721
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1109758.57577721
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  62 0.4250000000000001 0.6500000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  922983.6473345848
# RUN  0 , total integrated cost =  922983.6473345848
# Gradient descend method:  None
# RUN  0 , total integrated cost =  922983.6473345848
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  63 0.4500000000000001 0.6500000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  986986.0939997371
# RUN  0 , total integrated cost =  986986.0939997371
# Gradient descend method:  None
# RUN  0 , total integrated cost =  986986.0939997371
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  64 0.47500000000000014 0.6500000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1024646.3388017613
# RUN  0 , total integrated cost =  1024646.3388017613
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1024646.3388017613
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  65 0.5000000000000002 0.6500000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1051195.107614984
# RUN  0 , total integrated cost =  1051195.107614984
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1051195.107614984
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  66 0.5250000000000001 0.6500000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1071385.0508106458
# RUN  0 , total integrated cost =  1071385.0508106458
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1071385.0508106458
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  67 0.5500000000000003 0.6500000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1086641.8972488646
# RUN  0 , total integrated cost =  1086641.8972488646
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1086641.8972488646
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  68 0.5750000000000002 0.6500000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1090253.0461583156
# RUN  0 , total integrated cost =  1090253.0461583156
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1090253.0461583156
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  69 0.4250000000000001 0.6750000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  896519.1895641648
# RUN  0 , total integrated cost =  896519.1895641648
# Gradient descend method:  None
# RUN  0 , total integrated cost =  896519.1895641648
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  70 0.4500000000000001 0.6750000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  960815.1210788423
# RUN  0 , total integrated cost =  960815.1210788423
# Gradient descend method:  None
# RUN  0 , total integrated cost =  960815.1210788423
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  71 0.47500000000000014 0.6750000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  998150.415685038
# RUN  0 , total integrated cost =  998150.415685038
# Gradient descend method:  None
# RUN  0 , total integrated cost =  998150.415685038
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  72 0.5000000000000002 0.6750000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1024340.808148673
# RUN  0 , total integrated cost =  1024340.808148673
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1024340.808148673
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  73 0.5250000000000001 0.6750000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1044249.7226500798
# RUN  0 , total integrated cost =  1044249.7226500798
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1044249.7226500798
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  74 0.5500000000000003 0.6750000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1059611.740784375
# RUN  0 , total integrated cost =  1059611.740784375
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1059611.740784375
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  75 0.5750000000000002 0.6750000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1066870.1463823668
# RUN  0 , total integrated cost =  1066870.1463823668
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1066870.1463823668
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  76 0.4250000000000001 0.7000000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  870661.0376219094
# RUN  0 , total integrated cost =  870661.0376219094
# Gradient descend method:  None
# RUN  0 , total integrated cost =  870661.0376219094
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  77 0.4500000000000001 0.7000000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  935218.7010089055
# RUN  0 , total integrated cost =  935218.7010089055
# Gradient descend method:  None
# RUN  0 , total integrated cost =  935218.7010089055
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  78 0.47500000000000014 0.7000000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  972195.3005452589
# RUN  0 , total integrated cost =  972195.3005452589
# Gradient descend method:  None
# RUN  0 , total integrated cost =  972195.3005452589
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  79 0.5000000000000002 0.7000000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  998030.3624827373
# RUN  0 , total integrated cost =  998030.3624827373
# Gradient descend method:  None
# RUN  0 , total integrated cost =  998030.3624827373
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  80 0.5250000000000001 0.7000000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1017635.9866856338
# RUN  0 , total integrated cost =  1017635.9866856338
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1017635.9866856338
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  81 0.5500000000000003 0.7000000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1032928.5509545386
# RUN  0 , total integrated cost =  1032928.5509545386
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1032928.5509545386
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  82 0.5750000000000002 0.7000000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1042004.6546049776
# RUN  0 , total integrated cost =  1042004.6546049776
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1042004.6546049776
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.

# %%
cgv = None
j = 0

wp = 1.

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
        
    found_exponent = False
    found_digit_0 = False
    found_digit_1 = False
    exponent = 5
    sig_digit = [1., 0.]
    
    while not found_digit_1:
        
        ws[i] = sig_digit[0] * 10**exponent + sig_digit[1] * 10**(exponent-1.)

        aln.params.duration = dur
        setinit(initVars[i], aln)

        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        control0 = aln.getZeroControl()
        cost.setParams(wp, 0., ws[i])
        max_it = int(10)
        if found_digit_0:
            max_it = 100

        bestControl_[i][j], bestState_[i][j], cost_[i][j], runtime_, grad_, phi_, phi1_, costnode_[i][j] = aln.A1(
            control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
            prec_variables_ = p_var, transition_time_ = t_pen[j])
        
        if found_exponent == False and cost_[i][j][-1] == 0.:
            exponent -= 1
            continue
        elif found_exponent == False and found_digit_0 == False:
            found_exponent = True
            sig_digit[0] = 9.
        elif found_exponent == True and found_digit_0 == False and cost_[i][j][-1] == 0.:
            sig_digit[0] -= 1.
        elif found_exponent == True and found_digit_0 == False:
            found_digit_0 = True
            sig_digit[1] = 9.
        elif found_exponent == True and found_digit_0 == True and found_digit_1 == False and cost_[i][j][-1] == 0.:
            sig_digit[1] -= 1.
        elif found_exponent == True and found_digit_0 == True and found_digit_1 == False:
            print("sparsity weight = ", ws[i])
            
            break            

        print('uncontrolled cost : ', cost_uncontrolled[i])
        print('cost splitting : ', costnode_[i][j][0][0][0], costnode_[i][j][2][0][:2])
# Out:
# -------  0 0.4000000000000001 0.3500000000000001
# set cost params:  1.0 0.0 100000.0
# interpolate adjoint :  True True True
# initial cost =  851741.126234488
# RUN  0 , total integrated cost =  851741.126234488
# Gradient descend method:  None
# RUN  1 , total integrated cost =  254247.92183893954
# RUN  2 , total integrated cost =  215549.6721370631
# RUN  3 , total integrated cost =  189677.4405956665
# RUN  4 , total integrated cost =  180395.07083168032
# RUN  5 , total integrated cost =  172890.80147778988
# RUN  6 , total integrated cost =  169400.2331360012
# RUN  7 , total integrated cost =  166194.59264952154
# RUN  8 , total integrated cost =  164333.98865995748
# RUN  9 , total integrated cost =  162459.21161955383
# RUN  10 , total integrated cost =  161201.21986040266
# RUN  10 , total integrated cost =  161201.21986040266
# Improved over  10  iterations in  15.317140675993869  seconds by  81.07391848353424  percent.
# uncontrolled cost :  851741.126234488
# cost splitting :  0.0 [1.53985655 0.        ]
# set cost params:  1.0 0.0 900000.0
# interpolate adjoint :  True True True
# initial cost =  851741.126234488
# RUN  0 , total integrated cost =  851741.126234488
# Gradient descend method:  None
# RUN  1 , total integrated cost =  851741.126234488
# Control only changes marginally.
# RUN  1 , total integrated cost =  851741.126234488
# Improved over  1  iterations in  0.2531963799992809  seconds by  0.0  percent.
# uncontrolled cost :  851741.126234488
# cost splitting :  0.0 [0. 0.]
# set cost params:  1.0 0.0 800000.0
# interpolate adjoint :  True True True
# initial cost =  851741.126234488
# RUN  0 , total integrated cost =  851741.126234488
# Gradient descend method:  None
# RUN  1 , total integrated cost =  851741.126234488
# Control only changes marginally.
# RUN  1 , total integrated cost =  851741.126234488
# Improved over  1  iterations in  0.258497435002937  seconds by  0.0  percent.
# uncontrolled cost :  851741.126234488
# cost splitting :  0.0 [0. 0.]
# set cost params:  1.0 0.0 700000.0
# interpolate adjoint :  True True True
# initial cost =  851741.126234488
# RUN  0 , total integrated cost =  851741.126234488
# Gradient descend method:  None
# RUN  1 , total integrated cost =  851741.126234488
# Control only changes marginally.
# RUN  1 , total integrated cost =  851741.126234488
# Improved over  1  iterations in  0.28373912601091433  seconds by  0.0  percent.
# uncontrolled cost :  851741.126234488
# cost splitting :  0.0 [0. 0.]
# set cost params:  1.0 0.0 600000.0
# interpolate adjoint :  True True True
# initial cost =  851741.126234488
# RUN  0 , total integrated cost =  851741.126234488
# Gradient descend method:  None
# RUN  1 , total integrated cost =  851741.126234488
# Control only changes marginally.
# RUN  1 , total integrated cost =  851741.126234488
# Improved over  1  iterations in  0.2738943449949147  seconds by  0.0  percent.
# uncontrolled cost :  851741.126234488
# cost splitting :  0.0 [0. 0.]
# set cost params:  1.0 0.0 500000.0
# interpolate adjoint :  True True True
# initial cost =  851741.126234488
# RUN  0 , total integrated cost =  851741.126234488
# Gradient descend method:  None
# RUN  1 , total integrated cost =  851741.126234488
# Control only changes marginally.
# RUN  1 , total integrated cost =  851741.126234488
# Improved over  1  iterations in  0.27256405699881725  seconds by  0.0  percent.
# uncontrolled cost :  851741.126234488
# cost splitting :  0.0 [0. 0.]
# set cost params:  1.0 0.0 400000.0
# interpolate adjoint :  True True True
# initial cost =  851741.126234488
# RUN  0 , total integrated cost =  851741.126234488
# Gradient descend method:  None
# RUN  1 , total integrated cost =  751443.3721563736
# RUN  2 , total integrated cost =  640305.5311607195
# RUN  3 , total integrated cost =  620422.4918296972
# RUN  4 , total integrated cost =  611567.0805269954
# RUN  5 , total integrated cost =  604057.0484894275
# RUN  6 , total integrated cost =  600148.3288372678
# RUN  7 , total integrated cost =  596326.6494478422
# RUN  8 , total integrated cost =  593715.6383574463
# RUN  9 , total integrated cost =  590985.0315794694
# RUN  10 , total integrated cost =  588968.7163041923
# RUN  10 , total integrated cost =  588968.7163041923
# Improved over  10  iterations in  1.1141068740107585  seconds by  30.85120605740873  percent.
# uncontrolled cost :  851741.126234488
# cost splitting :  0.0 [1.378938 0.      ]
# set cost params:  1.0 0.0 490000.0
# interpolate adjoint :  True True True
# initial cost =  851741.126234488
# RUN  0 , total integrated cost =  851741.126234488
# Gradient descend method:  None
# RUN  1 , total integrated cost =  851741.126234488
# Control only changes marginally.
# RUN  1 , total integrated cost =  851741.126234488
# Improved over  1  iterations in  0.24442102300236002  seconds by  0.0  percent.
# uncontrolled cost :  851741.126234488
# cost splitting :  0.0 [0. 0.]
# set cost params:  1.0 0.0 480000.0
# interpolate adjoint :  True True True
# initial cost =  851741.126234488
# RUN  0 , total integrated cost =  851741.126234488
# Gradient descend method:  None
# RUN  1 , total integrated cost =  851741.126234488
# Control only changes marginally.
# RUN  1 , total integrated cost =  851741.126234488
# Improved over  1  iterations in  0.2560492409975268  seconds by  0.0  percent.
# uncontrolled cost :  851741.126234488
# cost splitting :  0.0 [0. 0.]
# set cost params:  1.0 0.0 470000.0
# interpolate adjoint :  True True True
# initial cost =  851741.126234488
# RUN  0 , total integrated cost =  851741.126234488
# Gradient descend method:  None
# RUN  1 , total integrated cost =  851741.126234488
# Control only changes marginally.
# RUN  1 , total integrated cost =  851741.126234488
# Improved over  1  iterations in  0.2516907679964788  seconds by  0.0  percent.
# uncontrolled cost :  851741.126234488
# cost splitting :  0.0 [0. 0.]
# set cost params:  1.0 0.0 460000.0
# interpolate adjoint :  True True True
# initial cost =  851741.126234488
# RUN  0 , total integrated cost =  851741.126234488
# Gradient descend method:  None
# RUN  1 , total integrated cost =  851741.126234488
# Control only changes marginally.
# RUN  1 , total integrated cost =  851741.126234488
# Improved over  1  iterations in  0.3113103119976586  seconds by  0.0  percent.
# uncontrolled cost :  851741.126234488
# cost splitting :  0.0 [0. 0.]
# set cost params:  1.0 0.0 450000.0
# interpolate adjoint :  True True True
# initial cost =  851741.126234488
# RUN  0 , total integrated cost =  851741.126234488
# Gradient descend method:  None
# RUN  1 , total integrated cost =  822077.8261467868
# RUN  2 , total integrated cost =  744441.3820839596
# RUN  3 , total integrated cost =  709576.7399355744
# RUN  4 , total integrated cost =  696491.9240329202
# RUN  5 , total integrated cost =  685212.2321671986
# RUN  6 , total integrated cost =  678946.3986114106
# RUN  7 , total integrated cost =  672689.9008570961
# RUN  8 , total integrated cost =  668713.8968098656
# RUN  9 , total integrated cost =  664734.1371737281
# RUN  10 , total integrated cost =  661837.263088498
# RUN  11 , total integrated cost =  658074.5090253148
# RUN  12 , total integrated cost =  655216.4692198713
# RUN  13 , total integrated cost =  643599.825846271
# RUN  14 , total integrated cost =  638578.9775795978
# RUN  15 , total integrated cost =  634885.0174958109
# RUN  16 , total integrated cost =  632554.5797149583
# RUN  17 , total integrated cost =  629588.0294672843
# RUN  18 , total integrated cost =  627949.9638254824
# RUN  19 , total integrated cost =  623928.4538296475
# RUN  20 , total integrated cost =  623067.0062017585
# RUN  30 , total integrated cost =  620223.6028872475
# RUN  40 , total integrated cost =  618274.5596129566
# RUN  50 , total integrated cost =  607746.2099918739
# RUN  60 , total integrated cost =  605114.7535324926
# RUN  70 , total integrated cost =  601139.5610799021
# RUN  80 , total integrated cost =  598728.9472090753
# RUN  90 , total integrated cost =  598367.0013858853
# RUN  100 , total integrated cost =  596980.4866731985
# RUN  100 , total integrated cost =  596980.4866731985
# Improved over  100  iterations in  11.323429475989542  seconds by  29.91057161787826  percent.
# sparsity weight =  450000.0
# -------  1 0.4250000000000001 0.3500000000000001
# set cost params:  1.0 0.0 100000.0
# interpolate adjoint :  True True True
# initial cost =  841862.7897650615
# RUN  0 , total integrated cost =  841862.7897650615
# Gradient descend method:  None
# RUN  1 , total integrated cost =  226143.86380983063
# RUN  2 , total integrated cost =  144772.63363562545
# RUN  3 , total integrated cost =  99979.45820802606
# RUN  4 , total integrated cost =  95810.43006749434
# RUN  5 , total integrated cost =  93779.12254060812
# RUN  6 , total integrated cost =  91599.59568422478
# RUN  7 , total integrated cost =  90240.07552436518
# RUN  8 , total integrated cost =  88691.38177665324
# RUN  9 , total integrated cost =  87638.99740199179
# RUN  10 , total integrated cost =  86429.76768953125
# RUN  10 , total integrated cost =  86429.76768953125
# Improved over  10  iterations in  1.0823234830022557  seconds by  89.73350898266318  percent.
# uncontrolled cost :  841862.7897650615
# cost splitting :  0.0 [0.78882219 0.        ]
# set cost params:  1.0 0.0 900000.0
# interpolate adjoint :  True True True
# initial cost =  841862.7897650615
# RUN  0 , total integrated cost =  841862.7897650615
# Gradient descend method:  None
# RUN  1 , total integrated cost =  841862.7897650615
# Control only changes marginally.
# RUN  1 , total integrated cost =  841862.7897650615
# Improved over  1  iterations in  0.24294065199501347  seconds by  0.0  percent.
# uncontrolled cost :  841862.7897650615
# cost splitting :  0.0 [0. 0.]
# set cost params:  1.0 0.0 800000.0
# interpolate adjoint :  True True True
# initial cost =  841862.7897650615
# RUN  0 , total integrated cost =  841862.7897650615
# Gradient descend method:  None
# RUN  1 , total integrated cost =  841862.7897650615
# Control only changes marginally.
# RUN  1 , total integrated cost =  841862.7897650615
# Improved over  1  iterations in  0.24116053100442514  seconds by  0.0  percent.
# uncontrolled cost :  841862.7897650615
# cost splitting :  0.0 [0. 0.]
# set cost params:  1.0 0.0 700000.0
# interpolate adjoint :  True True True
# initial cost =  841862.7897650615
# RUN  0 , total integrated cost =  841862.7897650615
# Gradient descend method:  None
# RUN  1 , total integrated cost =  768438.4050204414
# RUN  2 , total integrated cost =  662374.1166416468
# RUN  3 , total integrated cost =  605653.5120640135
# RUN  4 , total integrated cost =  581536.7704992386
# RUN  5 , total integrated cost =  528609.6176316408
# RUN  6 , total integrated cost =  521720.9934357473
# RUN  7 , total integrated cost =  517717.34271449194
# RUN  8 , total integrated cost =  513379.83678285615
# RUN  9 , total integrated cost =  510248.702271862
# RUN  10 , total integrated cost =  501415.0492823246
# RUN  10 , total integrated cost =  501415.0492823246
# Improved over  10  iterations in  1.1129020679945825  seconds by  40.43981330707651  percent.
# uncontrolled cost :  841862.7897650615
# cost splitting :  0.0 [0.67805017 0.        ]
# set cost params:  1.0 0.0 790000.0
# interpolate adjoint :  True True True
# initial cost =  841862.7897650615
# RUN  0 , total integrated cost =  841862.7897650615
# Gradient descend method:  None
# RUN  1 , total integrated cost =  841862.7897650615
# Control only changes marginally.
# RUN  1 , total integrated cost =  841862.7897650615
# Improved over  1  iterations in  0.2606936090014642  seconds by  0.0  percent.
# uncontrolled cost :  841862.7897650615
# cost splitting :  0.0 [0. 0.]
# set cost params:  1.0 0.0 780000.0
# interpolate adjoint :  True True True
# initial cost =  841862.7897650615
# RUN  0 , total integrated cost =  841862.7897650615
# Gradient descend method:  None
# RUN  1 , total integrated cost =  841862.7897650615
# Control only changes marginally.
# RUN  1 , total integrated cost =  841862.7897650615
# Improved over  1  iterations in  0.2603513159992872  seconds by  0.0  percent.
# uncontrolled cost :  841862.7897650615
# cost splitting :  0.0 [0. 0.]
# set cost params:  1.0 0.0 770000.0
# interpolate adjoint :  True True True
# initial cost =  841862.7897650615
# RUN  0 , total integrated cost =  841862.7897650615
# Gradient descend method:  None
# RUN  1 , total integrated cost =  841862.7897650615
# Control only changes marginally.
# RUN  1 , total integrated cost =  841862.7897650615
# Improved over  1  iterations in  0.23344961898692418  seconds by  0.0  percent.
# uncontrolled cost :  841862.7897650615
# cost splitting :  0.0 [0. 0.]
# set cost params:  1.0 0.0 760000.0
# interpolate adjoint :  True True True
# initial cost =  841862.7897650615
# RUN  0 , total integrated cost =  841862.7897650615
# Gradient descend method:  None
# RUN  1 , total integrated cost =  841862.7897650615
# Control only changes marginally.
# RUN  1 , total integrated cost =  841862.7897650615
# Improved over  1  iterations in  0.2425798120093532  seconds by  0.0  percent.
# uncontrolled cost :  841862.7897650615
# cost splitting :  0.0 [0. 0.]
# set cost params:  1.0 0.0 750000.0
# interpolate adjoint :  True True True
# initial cost =  841862.7897650615
# RUN  0 , total integrated cost =  841862.7897650615
# Gradient descend method:  None
# RUN  1 , total integrated cost =  803030.9735179624
# RUN  2 , total integrated cost =  695291.5791298735
# RUN  3 , total integrated cost =  628922.972950209
# RUN  4 , total integrated cost =  610349.5670588046
# RUN  5 , total integrated cost =  569131.4644169352
# RUN  6 , total integrated cost =  556613.089500917
# RUN  7 , total integrated cost =  544992.0811759272
# RUN  8 , total integrated cost =  539660.0575988466
# RUN  9 , total integrated cost =  534993.5984922518
# RUN  10 , total integrated cost =  532074.6566065431
# RUN  11 , total integrated cost =  529111.6422294037
# RUN  12 , total integrated cost =  527156.6669490051
# RUN  13 , total integrated cost =  525036.6974301421
# RUN  14 , total integrated cost =  523514.0975463426
# RUN  15 , total integrated cost =  521749.26377288584
# RUN  16 , total integrated cost =  520358.98899420217
# RUN  17 , total integrated cost =  518475.55230472924
# RUN  18 , total integrated cost =  517003.0074076635
# RUN  19 , total integrated cost =  495733.14036401734
# RUN  20 , total integrated cost =  494000.69552931515
# RUN  30 , total integrated cost =  474601.13195150194
# RUN  40 , total integrated cost =  471717.693576426
# RUN  50 , total integrated cost =  468864.36958904646
# RUN  60 , total integrated cost =  457322.12117403693
# RUN  70 , total integrated cost =  456346.8371378486
# RUN  80 , total integrated cost =  448277.8474343148
# RUN  90 , total integrated cost =  447722.71666509495
# RUN  100 , total integrated cost =  441989.6248401569
# RUN  100 , total integrated cost =  441989.6248401569
# Improved over  100  iterations in  11.676612486000522  seconds by  47.498614950839816  percent.
# sparsity weight =  750000.0
# -------  2 0.4000000000000001 0.3750000000000001
# set cost params:  1.0 0.0 100000.0
# interpolate adjoint :  True True True
# initial cost =  939937.8436775376
# RUN  0 , total integrated cost =  939937.8436775376
# Gradient descend method:  None
# RUN  1 , total integrated cost =  297698.69349443854
# RUN  2 , total integrated cost =  277832.408771879
# RUN  3 , total integrated cost =  262674.22524804267
# RUN  4 , total integrated cost =  255074.50065045158
# RUN  5 , total integrated cost =  249312.666604714
# RUN  6 , total integrated cost =  246681.22537423123
# RUN  7 , total integrated cost =  244217.22440013284
# RUN  8 , total integrated cost =  242779.628979986
# RUN  9 , total integrated cost =  241365.84092854487
# RUN  10 , total integrated cost =  240392.494832649
# RUN  10 , total integrated cost =  240392.494832649
# Improved over  10  iterations in  1.1964929920068244  seconds by  74.42463919825747  percent.
# uncontrolled cost :  939937.8436775376
# cost splitting :  0.0 [2.33729438 0.        ]
# set cost params:  1.0 0.0 900000.0
# interpolate adjoint :  True True True
# initial cost =  939937.8436775376
# RUN  0 , total integrated cost =  939937.8436775376
# Gradient descend method:  None
# RUN  1 , total integrated cost =  939937.8436775376
# Control only changes marginally.
# RUN  1 , total integrated cost =  939937.8436775376
# Improved over  1  iterations in  0.2454458370048087  seconds by  0.0  percent.
# uncontrolled cost :  939937.8436775376
# cost splitting :  0.0 [0. 0.]
# set cost params:  1.0 0.0 800000.0
# interpolate adjoint :  True True True
# initial cost =  939937.8436775376
# RUN  0 , total integrated cost =  939937.8436775376
# Gradient descend method:  None
# RUN  1 , total integrated cost =  939937.8436775376
# Control only changes marginally.
# RUN  1 , total integrated cost =  939937.8436775376
# Improved over  1  iterations in  0.2264559420000296  seconds by  0.0  percent.
# uncontrolled cost :  939937.8436775376
# cost splitting :  0.0 [0. 0.]
# set cost params:  1.0 0.0 700000.0
# interpolate adjoint :  True True True
# initial cost =  939937.8436775376
# RUN  0 , total integrated cost =  939937.8436775376
# Gradient descend method:  None
# RUN  1 , total integrated cost =  939937.8436775376
# Control only changes marginally.
# RUN  1 , total integrated cost =  939937.8436775376
# Improved over  1  iterations in  0.25521662799292244  seconds by  0.0  percent.
# uncontrolled cost :  939937.8436775376
# cost splitting :  0.0 [0. 0.]
# set cost params:  1.0 0.0 600000.0
# interpolate adjoint :  True True True
# initial cost =  939937.8436775376
# RUN  0 , total integrated cost =  939937.8436775376
# Gradient descend method:  None
# RUN  1 , total integrated cost =  939937.8436775376
# Control only changes marginally.
# RUN  1 , total integrated cost =  939937.8436775376
# Improved over  1  iterations in  0.23432902799686417  seconds by  0.0  percent.
# uncontrolled cost :  939937.8436775376
# cost splitting :  0.0 [0. 0.]
# set cost params:  1.0 0.0 500000.0
# interpolate adjoint :  True True True
# initial cost =  939937.8436775376
# RUN  0 , total integrated cost =  939937.8436775376
# Gradient descend method:  None
# RUN  1 , total integrated cost =  939937.8436775376
# Control only changes marginally.
# RUN  1 , total integrated cost =  939937.8436775376
# Improved over  1  iterations in  0.22452866700768936  seconds by  0.0  percent.
# uncontrolled cost :  939937.8436775376
# cost splitting :  0.0 [0. 0.]
# set cost params:  1.0 0.0 400000.0
# interpolate adjoint :  True True True
# initial cost =  939937.8436775376
# RUN  0 , total integrated cost =  939937.8436775376
# Gradient descend method:  None
# RUN  1 , total integrated cost =  939937.8436775376
# Control only changes marginally.
# RUN  1 , total integrated cost =  939937.8436775376
# Improved over  1  iterations in  0.25513067599968053  seconds by  0.0  percent.
# uncontrolled cost :  939937.8436775376
# cost splitting :  0.0 [0. 0.]
# set cost params:  1.0 0.0 300000.0
# interpolate adjoint :  True True True
# initial cost =  939937.8436775376
# RUN  0 , total integrated cost =  939937.8436775376
# Gradient descend method:  None
# RUN  1 , total integrated cost =  796885.4956798783
# RUN  2 , total integrated cost =  752084.5876204162
# RUN  3 , total integrated cost =  727729.5570868651
# RUN  4 , total integrated cost =  713966.0741978335
# RUN  5 , total integrated cost =  705227.0609548505
# RUN  6 , total integrated cost =  701251.2423121342
# RUN  7 , total integrated cost =  697741.7404444119
# RUN  8 , total integrated cost =  695180.497670471
# RUN  9 , total integrated cost =  692891.3284607695
# RUN  10 , total integrated cost =  691062.3732610048
# RUN  10 , total integrated cost =  691062.3732610048
# Improved over  10  iterations in  1.0969652780040633  seconds by  26.47786468973304  percent.
# uncontrolled cost :  939937.8436775376
# cost splitting :  0.0 [2.23052674 0.        ]
# set cost params:  1.0 0.0 390000.0
# interpolate adjoint :  True True True
# initial cost =  939937.8436775376
# RUN  0 , total integrated cost =  939937.8436775376
# Gradient descend method:  None
# RUN  1 , total integrated cost =  939937.8436775376
# Control only changes marginally.
# RUN  1 , total integrated cost =  939937.8436775376
# Improved over  1  iterations in  0.3574525040021399  seconds by  0.0  percent.
# uncontrolled cost :  939937.8436775376
# cost splitting :  0.0 [0. 0.]
# set cost params:  1.0 0.0 380000.0
# interpolate adjoint :  True True True
# initial cost =  939937.8436775376
# RUN  0 , total integrated cost =  939937.8436775376
# Gradient descend method:  None
# RUN  1 , total integrated cost =  939937.8436775376
# Control only changes marginally.
# RUN  1 , total integrated cost =  939937.8436775376
# Improved over  1  iterations in  0.24438945300062187  seconds by  0.0  percent.
# uncontrolled cost :  939937.8436775376
# cost splitting :  0.0 [0. 0.]
# set cost params:  1.0 0.0 370000.0
# interpolate adjoint :  True True True
# initial cost =  939937.8436775376
# RUN  0 , total integrated cost =  939937.8436775376
# Gradient descend method:  None
# RUN  1 , total integrated cost =  939937.8436775376
# Control only changes marginally.
# RUN  1 , total integrated cost =  939937.8436775376
# Improved over  1  iterations in  0.23521421699842904  seconds by  0.0  percent.
# uncontrolled cost :  939937.8436775376
# cost splitting :  0.0 [0. 0.]
# set cost params:  1.0 0.0 360000.0
# interpolate adjoint :  True True True
# initial cost =  939937.8436775376
# RUN  0 , total integrated cost =  939937.8436775376
# Gradient descend method:  None
# RUN  1 , total integrated cost =  939937.8436775376
# Control only changes marginally.
# RUN  1 , total integrated cost =  939937.8436775376
# Improved over  1  iterations in  0.23137975500139873  seconds by  0.0  percent.
# uncontrolled cost :  939937.8436775376
# cost splitting :  0.0 [0. 0.]
# set cost params:  1.0 0.0 350000.0
# interpolate adjoint :  True True True
# initial cost =  939937.8436775376
# RUN  0 , total integrated cost =  939937.8436775376
# Gradient descend method:  None
# RUN  1 , total integrated cost =  939937.8436775376
# Control only changes marginally.
# RUN  1 , total integrated cost =  939937.8436775376
# Improved over  1  iterations in  0.2491056459984975  seconds by  0.0  percent.
# uncontrolled cost :  939937.8436775376
# cost splitting :  0.0 [0. 0.]
# set cost params:  1.0 0.0 340000.0
# interpolate adjoint :  True True True
# initial cost =  939937.8436775376
# RUN  0 , total integrated cost =  939937.8436775376
# Gradient descend method:  None
# RUN  1 , total integrated cost =  939937.8436775376
# Control only changes marginally.
# RUN  1 , total integrated cost =  939937.8436775376
# Improved over  1  iterations in  0.24536070000613108  seconds by  0.0  percent.
# uncontrolled cost :  939937.8436775376
# cost splitting :  0.0 [0. 0.]
# set cost params:  1.0 0.0 330000.0
# interpolate adjoint :  True True True
# initial cost =  939937.8436775376
# RUN  0 , total integrated cost =  939937.8436775376
# Gradient descend method:  None
# RUN  1 , total integrated cost =  939937.8436775376
# Control only changes marginally.
# RUN  1 , total integrated cost =  939937.8436775376
# Improved over  1  iterations in  0.2285471060022246  seconds by  0.0  percent.
# uncontrolled cost :  939937.8436775376
# cost splitting :  0.0 [0. 0.]
# set cost params:  1.0 0.0 320000.0
# interpolate adjoint :  True True True
# initial cost =  939937.8436775376
# RUN  0 , total integrated cost =  939937.8436775376
# Gradient descend method:  None
# RUN  1 , total integrated cost =  939937.8436775376
# Control only changes marginally.
# RUN  1 , total integrated cost =  939937.8436775376
# Improved over  1  iterations in  0.23449933300435077  seconds by  0.0  percent.
# uncontrolled cost :  939937.8436775376
# cost splitting :  0.0 [0. 0.]
# set cost params:  1.0 0.0 310000.0
# interpolate adjoint :  True True True
# initial cost =  939937.8436775376
# RUN  0 , total integrated cost =  939937.8436775376
# Gradient descend method:  None
# RUN  1 , total integrated cost =  939937.8436775376
# Control only changes marginally.
# RUN  1 , total integrated cost =  939937.8436775376
# Improved over  1  iterations in  0.23223746499570552  seconds by  0.0  percent.
# uncontrolled cost :  939937.8436775376
# cost splitting :  0.0 [0. 0.]
# set cost params:  1.0 0.0 300000.0
# interpolate adjoint :  True True True
# initial cost =  939937.8436775376
# RUN  0 , total integrated cost =  939937.8436775376
# Gradient descend method:  None
# RUN  1 , total integrated cost =  796885.4956798783
# RUN  2 , total integrated cost =  752084.5876204162
# RUN  3 , total integrated cost =  727729.5570868651
# RUN  4 , total integrated cost =  713966.0741978335
# RUN  5 , total integrated cost =  705227.0609548505
# RUN  6 , total integrated cost =  701251.2423121342
# RUN  7 , total integrated cost =  697741.7404444119
# RUN  8 , total integrated cost =  695180.497670471
# RUN  9 , total integrated cost =  692891.3284607695
# RUN  10 , total integrated cost =  691062.3732610048
# RUN  11 , total integrated cost =  689290.4548648046
# RUN  12 , total integrated cost =  687676.8089909594
# RUN  13 , total integrated cost =  686120.3320299189
# RUN  14 , total integrated cost =  685286.2578074706
# RUN  15 , total integrated cost =  684375.6069920077
# RUN  16 , total integrated cost =  683730.2707944439
# RUN  17 , total integrated cost =  683020.8123942985
# RUN  18 , total integrated cost =  682449.372749519
# RUN  19 , total integrated cost =  681768.0172919064
# RUN  20 , total integrated cost =  681230.7862278288
# RUN  30 , total integrated cost =  666262.3856606758
# RUN  40 , total integrated cost =  654317.8259996132
# RUN  50 , total integrated cost =  650285.0281087699
# RUN  60 , total integrated cost =  646733.0412181795
# RUN  70 , total integrated cost =  643586.001146106
# RUN  80 , total integrated cost =  643218.6584766791
# RUN  90 , total integrated cost =  641210.4524691817
# RUN  100 , total integrated cost =  640658.7229749828
# RUN  100 , total integrated cost =  640658.7229749828
# Improved over  100  iterations in  10.880373036998208  seconds by  31.840309730653615  percent.
# sparsity weight =  300000.0
# -------  3 0.4250000000000001 0.3750000000000001
# set cost params:  1.0 0.0 100000.0
# interpolate adjoint :  True True True
# initial cost =  991241.8787598193
# RUN  0 , total integrated cost =  991241.8787598193
# Gradient descend method:  None
# RUN  1 , total integrated cost =  245102.39510454537
# RUN  2 , total integrated cost =  221701.3891189954
# RUN  3 , total integrated cost =  201493.22530345042
# RUN  4 , total integrated cost =  192099.69703324692
# RUN  5 , total integrated cost =  184368.79002372356
# RUN  6 , total integrated cost =  180152.5936040359
# RUN  7 , total integrated cost =  176149.08630540664
# RUN  8 , total integrated cost =  173886.8852080547
# RUN  9 , total integrated cost =  171532.63595861476
# RUN  10 , total integrated cost =  169911.2007166525
# RUN  10 , total integrated cost =  169911.2007166525
# Improved over  10  iterations in  1.061051001001033  seconds by  82.85875482488342  percent.
# uncontrolled cost :  991241.8787598193
# cost splitting :  0.0 [1.64324905 0.        ]
# set cost params:  1.0 0.0 900000.0
# interpolate adjoint :  True True True
# initial cost =  991241.8787598193
# RUN  0 , total integrated cost =  991241.8787598193
# Gradient descend method:  None
# RUN  1 , total integrated cost =  991241.8787598193
# Control only changes marginally.
# RUN  1 , total integrated cost =  991241.8787598193
# Improved over  1  iterations in  0.19092631699459162  seconds by  0.0  percent.
# uncontrolled cost :  991241.8787598193
# cost splitting :  0.0 [0. 0.]
# set cost params:  1.0 0.0 800000.0
# interpolate adjoint :  True True True
# initial cost =  991241.8787598193
# RUN  0 , total integrated cost =  991241.8787598193
# Gradient descend method:  None
# RUN  1 , total integrated cost =  991241.8787598193
# Control only changes marginally.
# RUN  1 , total integrated cost =  991241.8787598193
# Improved over  1  iterations in  0.18421056101215072  seconds by  0.0  percent.
# uncontrolled cost :  991241.8787598193
# cost splitting :  0.0 [0. 0.]
# set cost params:  1.0 0.0 700000.0
# interpolate adjoint :  True True True
# initial cost =  991241.8787598193
# RUN  0 , total integrated cost =  991241.8787598193
# Gradient descend method:  None
# RUN  1 , total integrated cost =  991241.8787598193
# Control only changes marginally.
# RUN  1 , total integrated cost =  991241.8787598193
# Improved over  1  iterations in  0.1863452180114109  seconds by  0.0  percent.
# uncontrolled cost :  991241.8787598193
# cost splitting :  0.0 [0. 0.]
# set cost params:  1.0 0.0 600000.0
# interpolate adjoint :  True True True
# initial cost =  991241.8787598193
# RUN  0 , total integrated cost =  991241.8787598193
# Gradient descend method:  None
# RUN  1 , total integrated cost =  991241.8787598193
# Control only changes marginally.
# RUN  1 , total integrated cost =  991241.8787598193
# Improved over  1  iterations in  0.20189934900554363  seconds by  0.0  percent.
# uncontrolled cost :  991241.8787598193
# cost splitting :  0.0 [0. 0.]
# set cost params:  1.0 0.0 500000.0
# interpolate adjoint :  True True True
# initial cost =  991241.8787598193
# RUN  0 , total integrated cost =  991241.8787598193
# Gradient descend method:  None
# RUN  1 , total integrated cost =  991241.8787598193
# Control only changes marginally.
# RUN  1 , total integrated cost =  991241.8787598193
# Improved over  1  iterations in  0.2081930190033745  seconds by  0.0  percent.
# uncontrolled cost :  991241.8787598193
# cost splitting :  0.0 [0. 0.]
# set cost params:  1.0 0.0 400000.0
# interpolate adjoint :  True True True
# initial cost =  991241.8787598193
# RUN  0 , total integrated cost =  991241.8787598193
# Gradient descend method:  None
# RUN  1 , total integrated cost =  792366.3843940882
# RUN  2 , total integrated cost =  735562.0393910351
# RUN  3 , total integrated cost =  692182.3369597608
# RUN  4 , total integrated cost =  675994.5481628077
# RUN  5 , total integrated cost =  659847.2446487475
# RUN  6 , total integrated cost =  651036.0075230068
# RUN  7 , total integrated cost =  641094.4191617547
# RUN  8 , total integrated cost =  634754.020891894
# RUN  9 , total integrated cost =  626336.4630981073
# RUN  10 , total integrated cost =  619857.1303799455
# RUN  10 , total integrated cost =  619857.1303799455
# Improved over  10  iterations in  0.8707116220030002  seconds by  37.46661196806248  percent.
# uncontrolled cost :  991241.8787598193
# cost splitting :  0.0 [1.45556411 0.        ]
# set cost params:  1.0 0.0 490000.0
# interpolate adjoint :  True True True
# initial cost =  991241.8787598193
# RUN  0 , total integrated cost =  991241.8787598193
# Gradient descend method:  None
# RUN  1 , total integrated cost =  991241.8787598193
# Control only changes marginally.
# RUN  1 , total integrated cost =  991241.8787598193
# Improved over  1  iterations in  0.18635932198958471  seconds by  0.0  percent.
# uncontrolled cost :  991241.8787598193
# cost splitting :  0.0 [0. 0.]
# set cost params:  1.0 0.0 480000.0
# interpolate adjoint :  True True True
# initial cost =  991241.8787598193
# RUN  0 , total integrated cost =  991241.8787598193
# Gradient descend method:  None
# RUN  1 , total integrated cost =  991241.8787598193
# Control only changes marginally.
# RUN  1 , total integrated cost =  991241.8787598193
# Improved over  1  iterations in  0.1861511530005373  seconds by  0.0  percent.
# uncontrolled cost :  991241.8787598193
# cost splitting :  0.0 [0. 0.]
# set cost params:  1.0 0.0 470000.0
# interpolate adjoint :  True True True
# initial cost =  991241.8787598193
# RUN  0 , total integrated cost =  991241.8787598193
# Gradient descend method:  None
# RUN  1 , total integrated cost =  991241.8787598193
# Control only changes marginally.
# RUN  1 , total integrated cost =  991241.8787598193
# Improved over  1  iterations in  0.18482439999934286  seconds by  0.0  percent.
# uncontrolled cost :  991241.8787598193
# cost splitting :  0.0 [0. 0.]
# set cost params:  1.0 0.0 460000.0
# interpolate adjoint :  True True True
# initial cost =  991241.8787598193
# RUN  0 , total integrated cost =  991241.8787598193
# Gradient descend method:  None
# RUN  1 , total integrated cost =  991241.8787598193
# Control only changes marginally.
# RUN  1 , total integrated cost =  991241.8787598193
# Improved over  1  iterations in  0.210242543995264  seconds by  0.0  percent.
# uncontrolled cost :  991241.8787598193
# cost splitting :  0.0 [0. 0.]
# set cost params:  1.0 0.0 450000.0
# interpolate adjoint :  True True True
# initial cost =  991241.8787598193
# RUN  0 , total integrated cost =  991241.8787598193
# Gradient descend method:  None
# RUN  1 , total integrated cost =  991241.8787598193
# Control only changes marginally.
# RUN  1 , total integrated cost =  991241.8787598193
# Improved over  1  iterations in  0.1835858079866739  seconds by  0.0  percent.
# uncontrolled cost :  991241.8787598193
# cost splitting :  0.0 [0. 0.]
# set cost params:  1.0 0.0 440000.0
# interpolate adjoint :  True True True
# initial cost =  991241.8787598193
# RUN  0 , total integrated cost =  991241.8787598193
# Gradient descend method:  None
# RUN  1 , total integrated cost =  853091.8978951052
# RUN  2 , total integrated cost =  792794.1809479934
# RUN  3 , total integrated cost =  752642.0646055762
# RUN  4 , total integrated cost =  736332.3481570595
# RUN  5 , total integrated cost =  717741.1980641263
# RUN  6 , total integrated cost =  706921.2857443322
# RUN  7 , total integrated cost =  673034.8920315863
# RUN  8 , total integrated cost =  663785.9490114461
# RUN  9 , total integrated cost =  658035.5680519606
# RUN  10 , total integrated cost =  654107.9484014921
# RUN  11 , total integrated cost =  649859.3188375027
# RUN  12 , total integrated cost =  647074.0806586861
# RUN  13 , total integrated cost =  644478.5540413222
# RUN  14 , total integrated cost =  642305.5063002263
# RUN  15 , total integrated cost =  622498.5824896675
# RUN  16 , total integrated cost =  618442.2428651414
# RUN  17 , total integrated cost =  616157.9010680639
# RUN  18 , total integrated cost =  615455.5694771924
# RUN  19 , total integrated cost =  614702.1138193215
# RUN  20 , total integrated cost =  613809.1660575472
# RUN  30 , total integrated cost =  609684.1853578009
# RUN  40 , total integrated cost =  607527.0139951349
# RUN  50 , total integrated cost =  603678.5345329813
# RUN  60 , total integrated cost =  591512.7034647968
# RUN  70 , total integrated cost =  590344.0765076708
# RUN  80 , total integrated cost =  589483.0819615513
# RUN  90 , total integrated cost =  585057.0097676177
# RUN  100 , total integrated cost =  584664.9586712971
# RUN  100 , total integrated cost =  584664.9586712971
# Improved over  100  iterations in  8.504900663989247  seconds by  41.01692319509404  percent.
# sparsity weight =  440000.0
# -------  4 0.4500000000000001 0.3750000000000001
# set cost params:  1.0 0.0 100000.0
# interpolate adjoint :  True True True
# initial cost =  932063.1589089162
# RUN  0 , total integrated cost =  932063.1589089162
# Gradient descend method:  None
# RUN  1 , total integrated cost =  169619.65029558173
# RUN  2 , total integrated cost =  146971.03143634356
# RUN  3 , total integrated cost =  127499.1742439254
# RUN  4 , total integrated cost =  119605.50795797816
# RUN  5 , total integrated cost =  96461.92723313933
# RUN  6 , total integrated cost =  92183.73614694357
# RUN  7 , total integrated cost =  86689.22627695231
# RUN  8 , total integrated cost =  83872.05574202344
# RUN  9 , total integrated cost =  79324.07964905952
# RUN  10 , total integrated cost =  77137.51890760913
# RUN  10 , total integrated cost =  77137.51890760913
# Improved over  10  iterations in  1.010538300004555  seconds by  91.72400301735912  percent.
# uncontrolled cost :  932063.1589089162
# cost splitting :  0.0 [0.74164801 0.        ]
# set cost params:  1.0 0.0 900000.0
# interpolate adjoint :  True True True
# initial cost =  932063.1589089162
# RUN  0 , total integrated cost =  932063.1589089162
# Gradient descend method:  None
# RUN  1 , total integrated cost =  932063.1589089162
# Control only changes marginally.
# RUN  1 , total integrated cost =  932063.1589089162
# Improved over  1  iterations in  0.19602956798917148  seconds by  0.0  percent.
# uncontrolled cost :  932063.1589089162
# cost splitting :  0.0 [0. 0.]
# set cost params:  1.0 0.0 800000.0
# interpolate adjoint :  True True True
# initial cost =  932063.1589089162
# RUN  0 , total integrated cost =  932063.1589089162
# Gradient descend method:  None
# RUN  1 , total integrated cost =  863329.2054346481
# RUN  2 , total integrated cost =  728131.6778897187
# RUN  3 , total integrated cost =  690278.6240627745
# RUN  4 , total integrated cost =  672018.0163568637
# RUN  5 , total integrated cost =  650202.1455875085
# RUN  6 , total integrated cost =  637074.5714614887
# RUN  7 , total integrated cost =  620585.4749953218
# RUN  8 , total integrated cost =  608736.2268993342
# RUN  9 , total integrated cost =  550935.8711863589
# RUN  10 , total integrated cost =  546540.5157278138
# RUN  10 , total integrated cost =  546540.5157278138
# Improved over  10  iterations in  0.9177600660041207  seconds by  41.36228746905945  percent.
# uncontrolled cost :  932063.1589089162
# cost splitting :  0.0 [0.65622616 0.        ]
# set cost params:  1.0 0.0 890000.0
# interpolate adjoint :  True True True
# initial cost =  932063.1589089162
# RUN  0 , total integrated cost =  932063.1589089162
# Gradient descend method:  None
# RUN  1 , total integrated cost =  932063.1589089162
# Control only changes marginally.
# RUN  1 , total integrated cost =  932063.1589089162
# Improved over  1  iterations in  0.1944135209923843  seconds by  0.0  percent.
# uncontrolled cost :  932063.1589089162
# cost splitting :  0.0 [0. 0.]
# set cost params:  1.0 0.0 880000.0
# interpolate adjoint :  True True True
# initial cost =  932063.1589089162
# RUN  0 , total integrated cost =  932063.1589089162
# Gradient descend method:  None
# RUN  1 , total integrated cost =  932063.1589089162
# Control only changes marginally.
# RUN  1 , total integrated cost =  932063.1589089162
# Improved over  1  iterations in  0.18576844400377013  seconds by  0.0  percent.
# uncontrolled cost :  932063.1589089162
# cost splitting :  0.0 [0. 0.]
# set cost params:  1.0 0.0 870000.0
# interpolate adjoint :  True True True
# initial cost =  932063.1589089162
# RUN  0 , total integrated cost =  932063.1589089162
# Gradient descend method:  None
# RUN  1 , total integrated cost =  932063.1589089162
# Control only changes marginally.
# RUN  1 , total integrated cost =  932063.1589089162
# Improved over  1  iterations in  0.19120794300397392  seconds by  0.0  percent.
# uncontrolled cost :  932063.1589089162
# cost splitting :  0.0 [0. 0.]
# set cost params:  1.0 0.0 860000.0
# interpolate adjoint :  True True True
# initial cost =  932063.1589089162
# RUN  0 , total integrated cost =  932063.1589089162
# Gradient descend method:  None
# RUN  1 , total integrated cost =  932063.1589089162
# Control only changes marginally.
# RUN  1 , total integrated cost =  932063.1589089162
# Improved over  1  iterations in  0.19300440099323168  seconds by  0.0  percent.
# uncontrolled cost :  932063.1589089162
# cost splitting :  0.0 [0. 0.]
# set cost params:  1.0 0.0 850000.0
# interpolate adjoint :  True True True
# initial cost =  932063.1589089162
# RUN  0 , total integrated cost =  932063.1589089162
# Gradient descend method:  None
# RUN  1 , total integrated cost =  932063.1589089162
# Control only changes marginally.
# RUN  1 , total integrated cost =  932063.1589089162
# Improved over  1  iterations in  0.19489137700293213  seconds by  0.0  percent.
# uncontrolled cost :  932063.1589089162
# cost splitting :  0.0 [0. 0.]
# set cost params:  1.0 0.0 840000.0
# interpolate adjoint :  True True True
# initial cost =  932063.1589089162
# RUN  0 , total integrated cost =  932063.1589089162
# Gradient descend method:  None
# RUN  1 , total integrated cost =  893617.5466006983
# RUN  2 , total integrated cost =  808687.0824658053
# RUN  3 , total integrated cost =  753725.0508639726
# RUN  4 , total integrated cost =  726997.5787464633
# RUN  5 , total integrated cost =  648336.9504103556
# RUN  6 , total integrated cost =  630813.9288345603
# RUN  7 , total integrated cost =  609125.8719932141
# RUN  8 , total integrated cost =  598105.6801079861
# RUN  9 , total integrated cost =  585481.4999980164
# RUN  10 , total integrated cost =  576414.7983796225
# RUN  11 , total integrated cost =  533395.7301418852
# RUN  12 , total integrated cost =  531024.447433284
# RUN  13 , total integrated cost =  528443.2026000657
# RUN  14 , total integrated cost =  526495.2450965897
# RUN  15 , total integrated cost =  524099.4151621532
# RUN  16 , total integrated cost =  522257.0330104749
# RUN  17 , total integrated cost =  520424.0398866342
# RUN  18 , total integrated cost =  519057.09508085967
# RUN  19 , total integrated cost =  517477.5201085756
# RUN  20 , total integrated cost =  516172.82338430575
# RUN  30 , total integrated cost =  483361.9956756418
# RUN  40 , total integrated cost =  471977.47455704666
# RUN  50 , total integrated cost =  461856.8474453672
# RUN  60 , total integrated cost =  461302.3853273446
# RUN  70 , total integrated cost =  458146.9617462771
# RUN  80 , total integrated cost =  457824.1769355509
# RUN  90 , total integrated cost =  454275.03517145355
# RUN  100 , total integrated cost =  453908.94724543014
# RUN  100 , total integrated cost =  453908.94724543014
# Improved over  100  iterations in  8.872023571995669  seconds by  51.30062347096938  percent.
# sparsity weight =  840000.0
# -------  5 0.4000000000000001 0.40000000000000013
# set cost params:  1.0 0.0 100000.0
# interpolate adjoint :  True True True
# initial cost =  974684.8435280059
# RUN  0 , total integrated cost =  974684.8435280059
# Gradient descend method:  None
# RUN  1 , total integrated cost =  403392.7844546541
# RUN  2 , total integrated cost =  386893.38332163874
# RUN  3 , total integrated cost =  371878.96985608
# RUN  4 , total integrated cost =  364216.6939605134
# RUN  5 , total integrated cost =  357077.25131314516
# RUN  6 , total integrated cost =  353151.6735447359
# RUN  7 , total integrated cost =  349373.38150937104
# RUN  8 , total integrated cost =  346929.55276463815
# RUN  9 , total integrated cost =  344375.72636227636
# RUN  10 , total integrated cost =  342710.27510595176
# RUN  10 , total integrated cost =  342710.27510595176
# Improved over  10  iterations in  1.0498939259996405  seconds by  64.83886279943937  percent.
# uncontrolled cost :  974684.8435280059
# cost splitting :  0.0 [3.34218255 0.        ]
# set cost params:  1.0 0.0 900000.0
# interpolate adjoint :  True True True
# initial cost =  974684.8435280059
# RUN  0 , total integrated cost =  974684.8435280059
# Gradient descend method:  None
# RUN  1 , total integrated cost =  974684.8435280059
# Control only changes marginally.
# RUN  1 , total integrated cost =  974684.8435280059
# Improved over  1  iterations in  0.1756646819994785  seconds by  0.0  percent.
# uncontrolled cost :  974684.8435280059
# cost splitting :  0.0 [0. 0.]
# set cost params:  1.0 0.0 800000.0
# interpolate adjoint :  True True True
# initial cost =  974684.8435280059
# RUN  0 , total integrated cost =  974684.8435280059
# Gradient descend method:  None
# RUN  1 , total integrated cost =  974684.8435280059
# Control only changes marginally.
# RUN  1 , total integrated cost =  974684.8435280059
# Improved over  1  iterations in  0.17262762000609655  seconds by  0.0  percent.
# uncontrolled cost :  974684.8435280059
# cost splitting :  0.0 [0. 0.]
# set cost params:  1.0 0.0 700000.0
# interpolate adjoint :  True True True
# initial cost =  974684.8435280059
# RUN  0 , total integrated cost =  974684.8435280059
# Gradient descend method:  None
# RUN  1 , total integrated cost =  974684.8435280059
# Control only changes marginally.
# RUN  1 , total integrated cost =  974684.8435280059
# Improved over  1  iterations in  0.17425022600218654  seconds by  0.0  percent.
# uncontrolled cost :  974684.8435280059
# cost splitting :  0.0 [0. 0.]
# set cost params:  1.0 0.0 600000.0
# interpolate adjoint :  True True True
# initial cost =  974684.8435280059
# RUN  0 , total integrated cost =  974684.8435280059
# Gradient descend method:  None
# RUN  1 , total integrated cost =  974684.8435280059
# Control only changes marginally.
# RUN  1 , total integrated cost =  974684.8435280059
# Improved over  1  iterations in  0.1809554399951594  seconds by  0.0  percent.
# uncontrolled cost :  974684.8435280059
# cost splitting :  0.0 [0. 0.]
# set cost params:  1.0 0.0 500000.0
# interpolate adjoint :  True True True
# initial cost =  974684.8435280059
# RUN  0 , total integrated cost =  974684.8435280059
# Gradient descend method:  None
# RUN  1 , total integrated cost =  974684.8435280059
# Control only changes marginally.
# RUN  1 , total integrated cost =  974684.8435280059
# Improved over  1  iterations in  0.18127649099915288  seconds by  0.0  percent.
# uncontrolled cost :  974684.8435280059
# cost splitting :  0.0 [0. 0.]
# set cost params:  1.0 0.0 400000.0
# interpolate adjoint :  True True True
# initial cost =  974684.8435280059
# RUN  0 , total integrated cost =  974684.8435280059
# Gradient descend method:  None
# RUN  1 , total integrated cost =  974684.8435280059
# Control only changes marginally.
# RUN  1 , total integrated cost =  974684.8435280059
# Improved over  1  iterations in  0.1880884340062039  seconds by  0.0  percent.
# uncontrolled cost :  974684.8435280059
# cost splitting :  0.0 [0. 0.]
# set cost params:  1.0 0.0 300000.0
# interpolate adjoint :  True True True
# initial cost =  974684.8435280059
# RUN  0 , total integrated cost =  974684.8435280059
# Gradient descend method:  None
# RUN  1 , total integrated cost =  974684.8435280059
# Control only changes marginally.
# RUN  1 , total integrated cost =  974684.8435280059
# Improved over  1  iterations in  0.23903498299478088  seconds by  0.0  percent.
# uncontrolled cost :  974684.8435280059
# cost splitting :  0.0 [0. 0.]
# set cost params:  1.0 0.0 200000.0
# interpolate adjoint :  True True True
# initial cost =  974684.8435280059
# RUN  0 , total integrated cost =  974684.8435280059
# Gradient descend method:  None
# RUN  1 , total integrated cost =  762306.2337650221
# RUN  2 , total integrated cost =  669562.9939263652
# RUN  3 , total integrated cost =  665912.6285587966
# RUN  4 , total integrated cost =  650839.8576820766
# RUN  5 , total integrated cost =  650478.0550003998
# RUN  6 , total integrated cost =  650052.1492654735
# RUN  7 , total integrated cost =  649717.6202127163
# RUN  8 , total integrated cost =  649307.6162423642
# RUN  9 , total integrated cost =  648969.1408515591
# RUN  10 , total integrated cost =  648610.8317724459
# RUN  10 , total integrated cost =  648610.8317724459
# Improved over  10  iterations in  0.8582032730046194  seconds by  33.45430206704458  percent.
# uncontrolled cost :  974684.8435280059
# cost splitting :  0.0 [3.17564632 0.        ]
# set cost params:  1.0 0.0 290000.0
# interpolate adjoint :  True True True
# initial cost =  974684.8435280059
# RUN  0 , total integrated cost =  974684.8435280059
# Gradient descend method:  None
# RUN  1 , total integrated cost =  974684.8435280059
# Control only changes marginally.
# RUN  1 , total integrated cost =  974684.8435280059
# Improved over  1  iterations in  0.1740863760060165  seconds by  0.0  percent.
# uncontrolled cost :  974684.8435280059
# cost splitting :  0.0 [0. 0.]
# set cost params:  1.0 0.0 280000.0
# interpolate adjoint :  True True True
# initial cost =  974684.8435280059
# RUN  0 , total integrated cost =  974684.8435280059
# Gradient descend method:  None
# RUN  1 , total integrated cost =  974684.8435280059
# Control only changes marginally.
# RUN  1 , total integrated cost =  974684.8435280059
# Improved over  1  iterations in  0.17378386200289242  seconds by  0.0  percent.
# uncontrolled cost :  974684.8435280059
# cost splitting :  0.0 [0. 0.]
# set cost params:  1.0 0.0 270000.0
# interpolate adjoint :  True True True
# initial cost =  974684.8435280059
# RUN  0 , total integrated cost =  974684.8435280059
# Gradient descend method:  None
# RUN  1 , total integrated cost =  974684.8435280059
# Control only changes marginally.
# RUN  1 , total integrated cost =  974684.8435280059
# Improved over  1  iterations in  0.17185956600587815  seconds by  0.0  percent.
# uncontrolled cost :  974684.8435280059
# cost splitting :  0.0 [0. 0.]
# set cost params:  1.0 0.0 260000.0
# interpolate adjoint :  True True True
# initial cost =  974684.8435280059
# RUN  0 , total integrated cost =  974684.8435280059
# Gradient descend method:  None
# RUN  1 , total integrated cost =  974684.8435280059
# Control only changes marginally.
# RUN  1 , total integrated cost =  974684.8435280059
# Improved over  1  iterations in  0.17397369700483978  seconds by  0.0  percent.
# uncontrolled cost :  974684.8435280059
# cost splitting :  0.0 [0. 0.]
# set cost params:  1.0 0.0 250000.0
# interpolate adjoint :  True True True
# ...
# RUN  2 , total integrated cost =  621109.561075151
# RUN  3 , total integrated cost =  603806.2135827285
# RUN  4 , total integrated cost =  593713.7717729651
# RUN  5 , total integrated cost =  584187.0182876812
# RUN  6 , total integrated cost =  577806.9901326324
# RUN  7 , total integrated cost =  570982.2769230779
# RUN  8 , total integrated cost =  566664.7329356003
# RUN  9 , total integrated cost =  562023.3705873997
# RUN  10 , total integrated cost =  558640.999423349
# RUN  10 , total integrated cost =  558640.999423349
# Improved over  10  iterations in  0.932416880998062  seconds by  49.966474537128335  percent.
# uncontrolled cost :  1116533.3528973474
# cost splitting :  0.0 [5.46697079 0.        ]
# set cost params:  1.0 0.0 190000.0
# interpolate adjoint :  True True True
# initial cost =  1116533.3528973474
# RUN  0 , total integrated cost =  1116533.3528973474
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1116533.3528973474
# Control only changes marginally.
# RUN  1 , total integrated cost =  1116533.3528973474
# Improved over  1  iterations in  0.15725190698867664  seconds by  0.0  percent.
# uncontrolled cost :  1116533.3528973474
# cost splitting :  0.0 [0. 0.]
# set cost params:  1.0 0.0 180000.0
# interpolate adjoint :  True True True
# initial cost =  1116533.3528973474
# RUN  0 , total integrated cost =  1116533.3528973474
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1116533.3528973474
# Control only changes marginally.
# RUN  1 , total integrated cost =  1116533.3528973474
# Improved over  1  iterations in  0.15251538901065942  seconds by  0.0  percent.
# uncontrolled cost :  1116533.3528973474
# cost splitting :  0.0 [0. 0.]
# set cost params:  1.0 0.0 170000.0
# interpolate adjoint :  True True True
# initial cost =  1116533.3528973474
# RUN  0 , total integrated cost =  1116533.3528973474
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1116533.3528973474
# Control only changes marginally.
# RUN  1 , total integrated cost =  1116533.3528973474
# Improved over  1  iterations in  0.1546728770044865  seconds by  0.0  percent.
# uncontrolled cost :  1116533.3528973474
# cost splitting :  0.0 [0. 0.]
# set cost params:  1.0 0.0 160000.0
# interpolate adjoint :  True True True
# initial cost =  1116533.3528973474
# RUN  0 , total integrated cost =  1116533.3528973474
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1116533.3528973474
# Control only changes marginally.
# RUN  1 , total integrated cost =  1116533.3528973474
# Improved over  1  iterations in  0.1546949590119766  seconds by  0.0  percent.
# uncontrolled cost :  1116533.3528973474
# cost splitting :  0.0 [0. 0.]
# set cost params:  1.0 0.0 150000.0
# interpolate adjoint :  True True True
# initial cost =  1116533.3528973474
# RUN  0 , total integrated cost =  1116533.3528973474
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1116533.3528973474
# Control only changes marginally.
# RUN  1 , total integrated cost =  1116533.3528973474
# Improved over  1  iterations in  0.15989148900553118  seconds by  0.0  percent.
# uncontrolled cost :  1116533.3528973474
# cost splitting :  0.0 [0. 0.]
# set cost params:  1.0 0.0 140000.0
# interpolate adjoint :  True True True
# initial cost =  1116533.3528973474
# RUN  0 , total integrated cost =  1116533.3528973474
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1116533.3528973474
# Control only changes marginally.
# RUN  1 , total integrated cost =  1116533.3528973474
# Improved over  1  iterations in  0.1572866780043114  seconds by  0.0  percent.
# uncontrolled cost :  1116533.3528973474
# cost splitting :  0.0 [0. 0.]
# set cost params:  1.0 0.0 130000.0
# interpolate adjoint :  True True True
# initial cost =  1116533.3528973474
# RUN  0 , total integrated cost =  1116533.3528973474
# Gradient descend method:  None
# RUN  1 , total integrated cost =  816267.0480237358
# RUN  2 , total integrated cost =  792658.8057338296
# RUN  3 , total integrated cost =  772275.6086115831
# RUN  4 , total integrated cost =  759954.4617904484
# RUN  5 , total integrated cost =  748910.9132306401
# RUN  6 , total integrated cost =  741347.1951041857
# RUN  7 , total integrated cost =  734400.2105417828
# RUN  8 , total integrated cost =  729925.4847399147
# RUN  9 , total integrated cost =  725476.9385517997
# RUN  10 , total integrated cost =  722353.4004852622
# RUN  11 , total integrated cost =  719080.419126401
# RUN  12 , total integrated cost =  716696.607459225
# RUN  13 , total integrated cost =  714142.0497183641
# RUN  14 , total integrated cost =  712255.0323317123
# RUN  15 , total integrated cost =  710172.1248903561
# RUN  16 , total integrated cost =  708627.8246248214
# RUN  17 , total integrated cost =  706841.9968329447
# RUN  18 , total integrated cost =  705488.4690086183
# RUN  19 , total integrated cost =  703791.5207183927
# RUN  20 , total integrated cost =  702511.9012234501
# RUN  30 , total integrated cost =  688895.9454036778
# RUN  40 , total integrated cost =  662126.8265645219
# RUN  50 , total integrated cost =  661789.6721859421
# RUN  60 , total integrated cost =  660921.525000891
# RUN  70 , total integrated cost =  656502.7920349864
# RUN  80 , total integrated cost =  655482.1414457236
# RUN  90 , total integrated cost =  653202.7369189746
# RUN  100 , total integrated cost =  652773.1644431947
# RUN  100 , total integrated cost =  652773.1644431947
# Improved over  100  iterations in  8.17559207699378  seconds by  41.53572190662451  percent.
# sparsity weight =  130000.0
# -------  32 0.47500000000000014 0.5250000000000002
# set cost params:  1.0 0.0 100000.0
# interpolate adjoint :  True True True
# initial cost =  1155135.458663953
# RUN  0 , total integrated cost =  1155135.458663953
# Gradient descend method:  None
# RUN  1 , total integrated cost =  538088.9592411492
# RUN  2 , total integrated cost =  519955.7314344919
# RUN  3 , total integrated cost =  503094.31131327467
# RUN  4 , total integrated cost =  493376.7138567507
# RUN  5 , total integrated cost =  482728.4197718861
# RUN  6 , total integrated cost =  475496.9468480425
# RUN  7 , total integrated cost =  464666.3496850499
# RUN  8 , total integrated cost =  458177.0384952279
# RUN  9 , total integrated cost =  451370.9790405424
# RUN  10 , total integrated cost =  447261.88113703334
# RUN  10 , total integrated cost =  447261.88113703334
# Improved over  10  iterations in  0.9553206059936201  seconds by  61.2805686309428  percent.
# uncontrolled cost :  1155135.458663953
# cost splitting :  0.0 [4.38043335 0.        ]
# set cost params:  1.0 0.0 900000.0
# interpolate adjoint :  True True True
# initial cost =  1155135.458663953
# RUN  0 , total integrated cost =  1155135.458663953
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1155135.458663953
# Control only changes marginally.
# RUN  1 , total integrated cost =  1155135.458663953
# Improved over  1  iterations in  0.17020932500599883  seconds by  0.0  percent.
# uncontrolled cost :  1155135.458663953
# cost splitting :  0.0 [0. 0.]
# set cost params:  1.0 0.0 800000.0
# interpolate adjoint :  True True True
# initial cost =  1155135.458663953
# RUN  0 , total integrated cost =  1155135.458663953
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1155135.458663953
# Control only changes marginally.
# RUN  1 , total integrated cost =  1155135.458663953
# Improved over  1  iterations in  0.16507544300111476  seconds by  0.0  percent.
# uncontrolled cost :  1155135.458663953
# cost splitting :  0.0 [0. 0.]
# set cost params:  1.0 0.0 700000.0
# interpolate adjoint :  True True True
# initial cost =  1155135.458663953
# RUN  0 , total integrated cost =  1155135.458663953
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1155135.458663953
# Control only changes marginally.
# RUN  1 , total integrated cost =  1155135.458663953
# Improved over  1  iterations in  0.16347619699081406  seconds by  0.0  percent.
# uncontrolled cost :  1155135.458663953
# cost splitting :  0.0 [0. 0.]
# set cost params:  1.0 0.0 600000.0
# interpolate adjoint :  True True True
# initial cost =  1155135.458663953
# RUN  0 , total integrated cost =  1155135.458663953
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1155135.458663953
# Control only changes marginally.
# RUN  1 , total integrated cost =  1155135.458663953
# Improved over  1  iterations in  0.1682083799969405  seconds by  0.0  percent.
# uncontrolled cost :  1155135.458663953
# cost splitting :  0.0 [0. 0.]
# set cost params:  1.0 0.0 500000.0
# interpolate adjoint :  True True True
# initial cost =  1155135.458663953
# RUN  0 , total integrated cost =  1155135.458663953
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1155135.458663953
# Control only changes marginally.
# RUN  1 , total integrated cost =  1155135.458663953
# Improved over  1  iterations in  0.1630349710030714  seconds by  0.0  percent.
# uncontrolled cost :  1155135.458663953
# cost splitting :  0.0 [0. 0.]
# set cost params:  1.0 0.0 400000.0
# interpolate adjoint :  True True True
# initial cost =  1155135.458663953
# RUN  0 , total integrated cost =  1155135.458663953
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1155135.458663953
# Control only changes marginally.
# RUN  1 , total integrated cost =  1155135.458663953
# Improved over  1  iterations in  0.17348705499898642  seconds by  0.0  percent.
# uncontrolled cost :  1155135.458663953
# cost splitting :  0.0 [0. 0.]
# set cost params:  1.0 0.0 300000.0
# interpolate adjoint :  True True True
# initial cost =  1155135.458663953
# RUN  0 , total integrated cost =  1155135.458663953
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1155135.458663953
# Control only changes marginally.
# RUN  1 , total integrated cost =  1155135.458663953
# Improved over  1  iterations in  0.16384900799312163  seconds by  0.0  percent.
# uncontrolled cost :  1155135.458663953
# cost splitting :  0.0 [0. 0.]
# set cost params:  1.0 0.0 200000.0
# interpolate adjoint :  True True True
# initial cost =  1155135.458663953
# RUN  0 , total integrated cost =  1155135.458663953
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1028223.4546461394
# RUN  2 , total integrated cost =  883973.2290274231
# RUN  3 , total integrated cost =  881601.4576242906
# RUN  4 , total integrated cost =  879753.9754050197
# RUN  5 , total integrated cost =  877575.3088713828
# RUN  6 , total integrated cost =  875945.3612766146
# RUN  7 , total integrated cost =  874017.0896211689
# RUN  8 , total integrated cost =  872481.8875350908
# RUN  9 , total integrated cost =  870664.4529390399
# RUN  10 , total integrated cost =  869098.88770144
# RUN  10 , total integrated cost =  869098.88770144
# Improved over  10  iterations in  0.8277252919942839  seconds by  24.76216696640472  percent.
# uncontrolled cost :  1155135.458663953
# cost splitting :  0.0 [4.25460786 0.        ]
# set cost params:  1.0 0.0 290000.0
# interpolate adjoint :  True True True
# initial cost =  1155135.458663953
# RUN  0 , total integrated cost =  1155135.458663953
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1155135.458663953
# Control only changes marginally.
# RUN  1 , total integrated cost =  1155135.458663953
# Improved over  1  iterations in  0.16237369700684212  seconds by  0.0  percent.
# uncontrolled cost :  1155135.458663953
# cost splitting :  0.0 [0. 0.]
# set cost params:  1.0 0.0 280000.0
# interpolate adjoint :  True True True
# initial cost =  1155135.458663953
# RUN  0 , total integrated cost =  1155135.458663953
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1155135.458663953
# Control only changes marginally.
# RUN  1 , total integrated cost =  1155135.458663953
# Improved over  1  iterations in  0.17027826100820675  seconds by  0.0  percent.
# uncontrolled cost :  1155135.458663953
# cost splitting :  0.0 [0. 0.]
# set cost params:  1.0 0.0 270000.0
# interpolate adjoint :  True True True
# initial cost =  1155135.458663953
# RUN  0 , total integrated cost =  1155135.458663953
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1155135.458663953
# Control only changes marginally.
# RUN  1 , total integrated cost =  1155135.458663953
# Improved over  1  iterations in  0.17959896399406716  seconds by  0.0  percent.
# uncontrolled cost :  1155135.458663953
# cost splitting :  0.0 [0. 0.]
# set cost params:  1.0 0.0 260000.0
# interpolate adjoint :  True True True
# initial cost =  1155135.458663953
# RUN  0 , total integrated cost =  1155135.458663953
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1155135.458663953
# Control only changes marginally.
# RUN  1 , total integrated cost =  1155135.458663953
# Improved over  1  iterations in  0.16563352599041536  seconds by  0.0  percent.
# uncontrolled cost :  1155135.458663953
# cost splitting :  0.0 [0. 0.]
# set cost params:  1.0 0.0 250000.0
# interpolate adjoint :  True True True
# initial cost =  1155135.458663953
# RUN  0 , total integrated cost =  1155135.458663953
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1155135.458663953
# Control only changes marginally.
# RUN  1 , total integrated cost =  1155135.458663953
# Improved over  1  iterations in  0.174552930999198  seconds by  0.0  percent.
# uncontrolled cost :  1155135.458663953
# cost splitting :  0.0 [0. 0.]
# set cost params:  1.0 0.0 240000.0
# interpolate adjoint :  True True True
# initial cost =  1155135.458663953
# RUN  0 , total integrated cost =  1155135.458663953
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1155135.458663953
# Control only changes marginally.
# RUN  1 , total integrated cost =  1155135.458663953
# Improved over  1  iterations in  0.18683789699571207  seconds by  0.0  percent.
# uncontrolled cost :  1155135.458663953
# cost splitting :  0.0 [0. 0.]
# set cost params:  1.0 0.0 230000.0
# interpolate adjoint :  True True True
# initial cost =  1155135.458663953
# RUN  0 , total integrated cost =  1155135.458663953
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1155135.458663953
# Control only changes marginally.
# RUN  1 , total integrated cost =  1155135.458663953
# Improved over  1  iterations in  0.1728790529887192  seconds by  0.0  percent.
# uncontrolled cost :  1155135.458663953
# cost splitting :  0.0 [0. 0.]
# set cost params:  1.0 0.0 220000.0
# interpolate adjoint :  True True True
# initial cost =  1155135.458663953
# RUN  0 , total integrated cost =  1155135.458663953
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1155135.458663953
# Control only changes marginally.
# RUN  1 , total integrated cost =  1155135.458663953
# Improved over  1  iterations in  0.16981135300011374  seconds by  0.0  percent.
# uncontrolled cost :  1155135.458663953
# cost splitting :  0.0 [0. 0.]
# set cost params:  1.0 0.0 210000.0
# interpolate adjoint :  True True True
# initial cost =  1155135.458663953
# RUN  0 , total integrated cost =  1155135.458663953
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1077236.9041866385
# RUN  2 , total integrated cost =  954459.0063340904
# RUN  3 , total integrated cost =  933082.906013872
# RUN  4 , total integrated cost =  891064.6059504956
# RUN  5 , total integrated cost =  889947.399977266
# RUN  6 , total integrated cost =  888710.9760658834
# RUN  7 , total integrated cost =  887732.8466721689
# RUN  8 , total integrated cost =  886594.2476579
# RUN  9 , total integrated cost =  885650.4195823616
# RUN  10 , total integrated cost =  884379.7578630919
# RUN  11 , total integrated cost =  883363.8418056748
# RUN  12 , total integrated cost =  881976.0637589738
# RUN  13 , total integrated cost =  880788.9785940666
# RUN  14 , total integrated cost =  879175.6365767011
# RUN  15 , total integrated cost =  877757.5981903283
# RUN  16 , total integrated cost =  871424.5764450529
# RUN  17 , total integrated cost =  866920.3112939105
# RUN  18 , total integrated cost =  852988.2746672253
# RUN  19 , total integrated cost =  850214.8707188698
# RUN  20 , total integrated cost =  850163.0870614218
# RUN  30 , total integrated cost =  849413.6370413678
# RUN  40 , total integrated cost =  836778.6785589705
# RUN  50 , total integrated cost =  836381.6689500266
# RUN  60 , total integrated cost =  835837.5532021809
# RUN  70 , total integrated cost =  832715.149570141

# %%
for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    aln.params.duration = dur
    k = 0
    
    while not conv[i]:
        
        max_it = int(100 + k*200)

        weight_ = ( cost_uncontrolled[i] - costnode_[i][0][0][0][0] ) / sum( costnode_[i][0][2][0][:] )  
        cost.setParams(1., weight_ * factor_we, weight_ * factor_ws)
        weights_[i][j] = cost.getParams()
        setinit(initVars[i], aln)

        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        control0 = aln.getZeroControl()
        control0 = bestControl_[i][0][:,:,n_pre-1:-n_post+1]

        bestControl_[i][j], bestState_[i][j], cost_[i][j], runtime_, grad_, phi_, phi1_, costnode_[i][j] = aln.A1(
            control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
            prec_variables_ = p_var, transition_time_ = t_pen[j])
        
        if cost_[i][j][2] == 0.:
            conv[i] = True

        #print('uncontrolled cost : ', cost_uncontrolled[i])
        print('cost splitting : ', costnode_[i][j][0][0][0], costnode_[i][j][2][0][:2])

        time_ = np.arange(-dur_pre,round(dur+dur_post+aln.params.dt,1),aln.params.dt)
        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        with open(file_,'wb') as f:
            pickle.dump([bestControl_, bestState_, cost_, costnode_, weights_], f)
        
        k += 1
# Out:
# -------  0 0.4000000000000001 0.3500000000000001
# -------  1 0.4250000000000001 0.3500000000000001
# -------  2 0.4000000000000001 0.3750000000000001
# -------  3 0.4250000000000001 0.3750000000000001
# -------  4 0.4500000000000001 0.3750000000000001
# -------  5 0.4000000000000001 0.40000000000000013
# -------  6 0.4250000000000001 0.40000000000000013
# -------  7 0.4500000000000001 0.40000000000000013
# -------  8 0.47500000000000014 0.40000000000000013
# -------  9 0.4000000000000001 0.42500000000000016
# -------  10 0.4250000000000001 0.42500000000000016
# -------  11 0.4500000000000001 0.42500000000000016
# -------  12 0.47500000000000014 0.42500000000000016
# -------  13 0.4000000000000001 0.4500000000000002
# -------  14 0.4250000000000001 0.4500000000000002
# -------  15 0.4500000000000001 0.4500000000000002
# -------  16 0.47500000000000014 0.4500000000000002
# -------  17 0.5000000000000002 0.4500000000000002
# -------  18 0.4000000000000001 0.4750000000000002
# -------  19 0.4250000000000001 0.4750000000000002
# -------  20 0.4500000000000001 0.4750000000000002
# -------  21 0.47500000000000014 0.4750000000000002
# -------  22 0.5000000000000002 0.4750000000000002
# -------  23 0.5250000000000001 0.4750000000000002
# -------  24 0.4000000000000001 0.5000000000000002
# -------  25 0.4250000000000001 0.5000000000000002
# -------  26 0.4500000000000001 0.5000000000000002
# -------  27 0.47500000000000014 0.5000000000000002
# -------  28 0.5000000000000002 0.5000000000000002
# -------  29 0.5250000000000001 0.5000000000000002
# -------  30 0.4250000000000001 0.5250000000000002
# -------  31 0.4500000000000001 0.5250000000000002
# -------  32 0.47500000000000014 0.5250000000000002
# -------  33 0.5000000000000002 0.5250000000000002
# -------  34 0.5250000000000001 0.5250000000000002
# -------  35 0.5500000000000003 0.5250000000000002
# -------  36 0.4250000000000001 0.5500000000000003
# -------  37 0.4500000000000001 0.5500000000000003
# -------  38 0.47500000000000014 0.5500000000000003
# -------  39 0.5000000000000002 0.5500000000000003
# -------  40 0.5250000000000001 0.5500000000000003
# -------  41 0.5500000000000003 0.5500000000000003
# -------  42 0.4250000000000001 0.5750000000000003
# -------  43 0.4500000000000001 0.5750000000000003
# -------  44 0.47500000000000014 0.5750000000000003
# -------  45 0.5000000000000002 0.5750000000000003
# -------  46 0.5250000000000001 0.5750000000000003
# -------  47 0.5500000000000003 0.5750000000000003
# -------  48 0.4250000000000001 0.6000000000000003
# -------  49 0.4500000000000001 0.6000000000000003
# -------  50 0.47500000000000014 0.6000000000000003
# -------  51 0.5000000000000002 0.6000000000000003
# -------  52 0.5250000000000001 0.6000000000000003
# -------  53 0.5500000000000003 0.6000000000000003
# -------  54 0.5750000000000002 0.6000000000000003
# -------  55 0.4250000000000001 0.6250000000000003
# -------  56 0.4500000000000001 0.6250000000000003
# -------  57 0.47500000000000014 0.6250000000000003
# -------  58 0.5000000000000002 0.6250000000000003
# -------  59 0.5250000000000001 0.6250000000000003
# -------  60 0.5500000000000003 0.6250000000000003
# -------  61 0.5750000000000002 0.6250000000000003
# -------  62 0.4250000000000001 0.6500000000000004
# -------  63 0.4500000000000001 0.6500000000000004
# -------  64 0.47500000000000014 0.6500000000000004
# -------  65 0.5000000000000002 0.6500000000000004
# -------  66 0.5250000000000001 0.6500000000000004
# -------  67 0.5500000000000003 0.6500000000000004
# -------  68 0.5750000000000002 0.6500000000000004
# -------  69 0.4250000000000001 0.6750000000000004
# -------  70 0.4500000000000001 0.6750000000000004
# -------  71 0.47500000000000014 0.6750000000000004
# -------  72 0.5000000000000002 0.6750000000000004
# -------  73 0.5250000000000001 0.6750000000000004
# -------  74 0.5500000000000003 0.6750000000000004
# -------  75 0.5750000000000002 0.6750000000000004
# -------  76 0.4250000000000001 0.7000000000000004
# -------  77 0.4500000000000001 0.7000000000000004
# -------  78 0.47500000000000014 0.7000000000000004
# -------  79 0.5000000000000002 0.7000000000000004
# -------  80 0.5250000000000001 0.7000000000000004
# -------  81 0.5500000000000003 0.7000000000000004
# -------  82 0.5750000000000002 0.7000000000000004

# %%
with open(file_init,'wb') as f:
    pickle.dump([bestControl_, bestState_, cost_, costnode_, weights_], f)

# %%
for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    aln.params.duration = dur
    max_it = int(0)
    
    for l in range( bestControl_[i][0].shape[2] ):
        if np.abs(bestControl_[i][0][0,0,l]) > 5. * 1e-6 or np.abs(bestControl_[i][0][0,1,l]) > 5. * 1e-6:
            init_ind = l
            break
            
    print("init ind = ", init_ind)

    weight_ = 1.
    cost.setParams(1., weight_ * factor_we, weight_ * factor_ws)
    weights_[i][j] = cost.getParams()

    setinit(initVars[i], aln)

    target_ = aln.getZeroTarget()
    target_[:,0,:] = target[i][0]
    target_[:,1,:] = target[i][1]

    control0 = aln.getZeroControl()
    control0[:,:,:-init_ind] = bestControl_[i][0][:,:,n_pre-1+init_ind:-n_post+1]

    bestControl_[i][0], bestState_[i][0], cost_[i][0], runtime_, grad_, phi_, phi1_, costnode_[i][0] = aln.A1(
        control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
        prec_variables_ = p_var, transition_time_ = t_pen[j])

    print('uncontrolled cost : ', cost_uncontrolled[i])
    print('cost splitting : ', costnode_[i][0][0][0][0], costnode_[i][0][2][0][:2])

    time_ = np.arange(-dur_pre,round(dur+dur_post+aln.params.dt,1),aln.params.dt)
    target_ = aln.getZeroTarget()
    target_[:,0,:] = target[i][0]
    target_[:,1,:] = target[i][1]

    with open(file_,'wb') as f:
        pickle.dump([bestControl_, bestState_, cost_, costnode_, weights_], f)
# Out:
# -------  0 0.4000000000000001 0.3500000000000001
# init ind =  137
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  1.2528440655786546
# RUN  0 , total integrated cost =  1.2528440655786546
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1.2528440655786546
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  146855.39702821904
# cost splitting :  1.7153050060070154e-17 [1.25270523e+00 1.38832350e-04]
# -------  1 0.4250000000000001 0.3500000000000001
# init ind =  100
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  0.5564401876418021
# RUN  0 , total integrated cost =  0.5564401876418021
# Gradient descend method:  None
# RUN  0 , total integrated cost =  0.5564401876418021
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  244234.70503349282
# cost splitting :  7.69910156839787e-12 [0.55259444 0.00384575]
# -------  2 0.4000000000000001 0.3750000000000001
# init ind =  100
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  2.0762655227130375
# RUN  0 , total integrated cost =  2.0762655227130375
# Gradient descend method:  None
# RUN  0 , total integrated cost =  2.0762655227130375
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  137806.3558139294
# cost splitting :  1.8778939804372866e-14 [2.07625190e+00 1.36207408e-05]
# -------  3 0.4250000000000001 0.3750000000000001
# init ind =  100
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  1.2563542196227278
# RUN  0 , total integrated cost =  1.2563542196227278
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1.2563542196227278
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  241480.3484875782
# cost splitting :  2.5737885751759055e-14 [1.25635399e+00 2.34034259e-07]
# -------  4 0.4500000000000001 0.3750000000000001
# init ind =  100
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  0.5147917265430965
# RUN  0 , total integrated cost =  0.5147917265430965
# Gradient descend method:  None
# RUN  0 , total integrated cost =  0.5147917265430965
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  338432.51439444604
# cost splitting :  5.378558709640635e-16 [0.51401201 0.00077971]
# -------  5 0.4000000000000001 0.40000000000000013
# init ind =  100
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.0747608241895406
# RUN  0 , total integrated cost =  3.0747608241895406
# Gradient descend method:  None
# RUN  0 , total integrated cost =  3.0747608241895406
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  126823.61408372025
# cost splitting :  1.5710137966909288e-11 [3.07468503e+00 7.57893112e-05]
# -------  6 0.4250000000000001 0.40000000000000013
# init ind =  100
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  2.1153629813051777
# RUN  0 , total integrated cost =  2.1153629813051777
# Gradient descend method:  None
# RUN  0 , total integrated cost =  2.1153629813051777
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  234849.86448361105
# cost splitting :  2.979259207338385e-15 [2.11536171e+00 1.26709711e-06]
# -------  7 0.4500000000000001 0.40000000000000013
# init ind =  100
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  337312.5852095806
# RUN  0 , total integrated cost =  337312.5852095806
# Gradient descend method:  None
# RUN  0 , total integrated cost =  337312.5852095806
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  337311.3569640121
# cost splitting :  13557.205225365999 [1.22523849e+00 1.10121580e-04]
# -------  8 0.47500000000000014 0.40000000000000013
# init ind =  100
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  0.3611344533672573
# RUN  0 , total integrated cost =  0.3611344533672573
# Gradient descend method:  None
# RUN  0 , total integrated cost =  0.3611344533672573
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  436683.03613383934
# cost splitting :  7.574431001369695e-17 [3.61134453e-01 1.82798827e-16]
# -------  9 0.4000000000000001 0.42500000000000016
# init ind =  100
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  4.094804778403694
# RUN  0 , total integrated cost =  4.094804778403694
# Gradient descend method:  None
# RUN  0 , total integrated cost =  4.094804778403694
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  115502.5972235114
# cost splitting :  8.293252903690698e-09 [4.09465188e+00 1.52690397e-04]
# -------  10 0.4250000000000001 0.42500000000000016
# init ind =  100
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.0782892127751897
# RUN  0 , total integrated cost =  3.0782892127751897
# Gradient descend method:  None
# RUN  0 , total integrated cost =  3.0782892127751897
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  226698.47715197233
# cost splitting :  6.776070544865089e-16 [3.07827287e+00 1.63424846e-05]
# -------  11 0.4500000000000001 0.42500000000000016
# init ind =  100
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  2.0868771263438757
# RUN  0 , total integrated cost =  2.0868771263438757
# Gradient descend method:  None
# RUN  0 , total integrated cost =  2.0868771263438757
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  331196.46910670475
# cost splitting :  7.63397016168565e-12 [2.08687713e+00 5.98817995e-15]
# -------  12 0.47500000000000014 0.42500000000000016
# init ind =  100
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  437183.33055036596
# RUN  0 , total integrated cost =  437183.33055036596
# Gradient descend method:  None
# RUN  0 , total integrated cost =  437183.33055036596
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  437181.9504061447
# cost splitting :  17571.210853078075 [1.11425065e+00 2.98890376e-16]
# -------  13 0.4000000000000001 0.4500000000000002
# init ind =  100
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  5.015546458065139
# RUN  0 , total integrated cost =  5.015546458065139
# Gradient descend method:  None
# RUN  0 , total integrated cost =  5.015546458065139
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  103932.40255255786
# cost splitting :  4.8556568421681446e-11 [5.01554646e+00 1.56854149e-16]
# -------  14 0.4250000000000001 0.4500000000000002
# init ind =  100
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.9830457032506716
# RUN  0 , total integrated cost =  3.9830457032506716
# Gradient descend method:  None
# RUN  0 , total integrated cost =  3.9830457032506716
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  218854.09939826332
# cost splitting :  8.455988159050631e-16 [3.98304570e+00 1.01667489e-15]
# -------  15 0.4500000000000001 0.4500000000000002
# init ind =  100
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  2.9603403578449914
# RUN  0 , total integrated cost =  2.9603403578449914
# Gradient descend method:  None
# RUN  0 , total integrated cost =  2.9603403578449914
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  323897.4690366888
# cost splitting :  2.1779025840257323e-13 [2.96034036e+00 8.77657769e-17]
# -------  16 0.47500000000000014 0.4500000000000002
# init ind =  100
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  1.9318782651120499
# RUN  0 , total integrated cost =  1.9318782651120499
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1.9318782651120499
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  431451.8938983858
# cost splitting :  9.935138421079414e-14 [1.93187827e+00 2.18396701e-17]
# -------  17 0.5000000000000002 0.4500000000000002
# init ind =  100
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  0.8663164595594111
# RUN  0 , total integrated cost =  0.8663164595594111
# Gradient descend method:  None
# RUN  0 , total integrated cost =  0.8663164595594111
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  541570.0682516823
# cost splitting :  4.547523516366999e-14 [8.66316460e-01 1.63695596e-16]
# -------  18 0.4000000000000001 0.4750000000000002
# init ind =  100
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  5.80272531367855
# RUN  0 , total integrated cost =  5.80272531367855
# Gradient descend method:  None
# RUN  0 , total integrated cost =  5.80272531367855
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  91340.63373509991
# cost splitting :  4.991386061504197e-10 [5.80272530e+00 1.72136501e-16]
# -------  19 0.4250000000000001 0.4750000000000002
# init ind =  100
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  4.763302340661083
# RUN  0 , total integrated cost =  4.763302340661083
# Gradient descend method:  None
# RUN  0 , total integrated cost =  4.763302340661083
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  211572.5759679924
# cost splitting :  2.385395029581436e-14 [4.76330234e+00 3.36638952e-16]
# -------  20 0.4500000000000001 0.4750000000000002
# init ind =  100
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.7343482250861704
# RUN  0 , total integrated cost =  3.7343482250861704
# Gradient descend method:  None
# RUN  0 , total integrated cost =  3.7343482250861704
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  316931.9421284
# cost splitting :  2.1524735311297465e-19 [3.73434823e+00 1.54223102e-16]
# -------  21 0.47500000000000014 0.4750000000000002
# init ind =  100
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  2.6952990286539817
# RUN  0 , total integrated cost =  2.6952990286539817
# Gradient descend method:  None
# RUN  0 , total integrated cost =  2.6952990286539817
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  424684.0949542926
# cost splitting :  7.603969773640941e-10 [2.69529901e+00 1.62288942e-17]
# -------  22 0.5000000000000002 0.4750000000000002
# init ind =  100
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  1.622668341683104
# RUN  0 , total integrated cost =  1.622668341683104
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1.622668341683104
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  536554.4931300428
# cost splitting :  9.830604127412573e-11 [1.62266834e+00 6.44039597e-17]
# -------  23 0.5250000000000001 0.4750000000000002
# init ind =  100
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  0.40915008806385916
# RUN  0 , total integrated cost =  0.40915008806385916
# Gradient descend method:  None
# RUN  0 , total integrated cost =  0.40915008806385916
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  649680.5756879131
# cost splitting :  1.9122712343594904e-14 [4.09150088e-01 2.41171018e-17]
# -------  24 0.4000000000000001 0.5000000000000002
# init ind =  100
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  6.459498703831577
# RUN  0 , total integrated cost =  6.459498703831577
# Gradient descend method:  None
# RUN  0 , total integrated cost =  6.459498703831577
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  74168.6027044929
# cost splitting :  1.0091597684548651e-08 [6.45949845e+00 2.07834181e-16]
# -------  25 0.4250000000000001 0.5000000000000002
# init ind =  100
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  5.4118880064458414
# RUN  0 , total integrated cost =  5.4118880064458414
# Gradient descend method:  None
# RUN  0 , total integrated cost =  5.4118880064458414
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  204814.76624161197
# cost splitting :  3.4896449749563064e-14 [5.41188801e+00 2.42190081e-16]
# -------  26 0.4500000000000001 0.5000000000000002
# init ind =  100
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  4.383999076058911
# RUN  0 , total integrated cost =  4.383999076058911
# Gradient descend method:  None
# RUN  0 , total integrated cost =  4.383999076058911
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  310502.0037410387
# cost splitting :  3.6069998089940084e-10 [4.38399907e+00 1.16377324e-15]
# -------  27 0.47500000000000014 0.5000000000000002
# init ind =  100
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.3465229866471002
# RUN  0 , total integrated cost =  3.3465229866471002
# Gradient descend method:  None
# RUN  0 , total integrated cost =  3.3465229866471002
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  418236.1198402083
# cost splitting :  2.222905749330965e-13 [3.34652299e+00 7.68814029e-17]
# -------  28 0.5000000000000002 0.5000000000000002
# init ind =  100
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  2.281619067432956
# RUN  0 , total integrated cost =  2.281619067432956
# Gradient descend method:  None
# RUN  0 , total integrated cost =  2.281619067432956
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  530282.4726497299
# cost splitting :  2.1754552563875015e-15 [2.28161907e+00 1.41186987e-16]
# -------  29 0.5250000000000001 0.5000000000000002
# init ind =  100
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  1.1431041809225782
# RUN  0 , total integrated cost =  1.1431041809225782
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1.1431041809225782
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  646521.6732350034
# cost splitting :  9.895471195092341e-26 [1.14310418 0.        ]
# -------  30 0.4250000000000001 0.5250000000000002
# init ind =  100
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  5.962431676604531
# RUN  0 , total integrated cost =  5.962431676604531
# Gradient descend method:  None
# RUN  0 , total integrated cost =  5.962431676604531
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  198505.2946572739
# cost splitting :  2.55481578300591e-21 [5.96243168 0.        ]
# -------  31 0.4500000000000001 0.5250000000000002
# init ind =  100
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  4.93551420270438
# RUN  0 , total integrated cost =  4.93551420270438
# Gradient descend method:  None
# RUN  0 , total integrated cost =  4.93551420270438
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  304530.5505769217
# cost splitting :  0.0 [4.9355142 0.       ]
# -------  32 0.47500000000000014 0.5250000000000002
# init ind =  100
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.8931451918021702
# RUN  0 , total integrated cost =  3.8931451918021702
# Gradient descend method:  None
# RUN  0 , total integrated cost =  3.8931451918021702
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  412227.1647591634
# cost splitting :  9.895471195092341e-26 [3.89314519 0.        ]
# -------  33 0.5000000000000002 0.5250000000000002
# init ind =  100
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  2.836311006208724
# RUN  0 , total integrated cost =  2.836311006208724
# Gradient descend method:  None
# RUN  0 , total integrated cost =  2.836311006208724
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  524212.5915485861
# cost splitting :  1.8175355256292178e-26 [2.83631101 0.        ]
# -------  34 0.5250000000000001 0.5250000000000002
# init ind =  100
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  1.7257799483865914
# RUN  0 , total integrated cost =  1.7257799483865914
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1.7257799483865914
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  640916.4738461657
# cost splitting :  8.077935669463167e-27 [1.72577995 0.        ]
# -------  35 0.5500000000000003 0.5250000000000002
# init ind =  100
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  0.41336654111367865
# RUN  0 , total integrated cost =  0.41336654111367865
# Gradient descend method:  None
# RUN  0 , total integrated cost =  0.41336654111367865
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  760013.3898018681
# cost splitting :  6.153424423044558e-08 [0.41336501 0.        ]
# -------  36 0.4250000000000001 0.5500000000000003
# init ind =  100
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  6.4026577403319145
# RUN  0 , total integrated cost =  6.4026577403319145
# Gradient descend method:  None
# RUN  0 , total integrated cost =  6.4026577403319145
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  192617.3150952127
# cost splitting :  2.1413030798165447e-21 [6.40265774 0.        ]
# -------  37 0.4500000000000001 0.5500000000000003
# init ind =  100
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  5.373554468355487
# RUN  0 , total integrated cost =  5.373554468355487
# Gradient descend method:  None
# RUN  0 , total integrated cost =  5.373554468355487
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  299002.14935773576
# cost splitting :  2.0194839173657902e-25 [5.37355447 0.        ]
# -------  38 0.47500000000000014 0.5500000000000003
# init ind =  100
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  4.338656364294081
# RUN  0 , total integrated cost =  4.338656364294081
# Gradient descend method:  None
# RUN  0 , total integrated cost =  4.338656364294081
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  406664.10745913326
# cost splitting :  6.108938850031492e-26 [4.33865636 0.        ]
# -------  39 0.5000000000000002 0.5500000000000003
# init ind =  100
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.289710186514763
# RUN  0 , total integrated cost =  3.289710186514763
# Gradient descend method:  None
# RUN  0 , total integrated cost =  3.289710186514763
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  518533.1123942334
# cost splitting :  7.270142102516871e-26 [3.28971019 0.        ]
# -------  40 0.5250000000000001 0.5500000000000003
# init ind =  100
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  2.200674682992886
# RUN  0 , total integrated cost =  2.200674682992886
# Gradient descend method:  None
# RUN  0 , total integrated cost =  2.200674682992886
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  635238.4079859259
# cost splitting :  7.270142102516871e-26 [2.20067468 0.        ]
# -------  41 0.5500000000000003 0.5500000000000003
# init ind =  100
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  0.9958380570272889
# RUN  0 , total integrated cost =  0.9958380570272889
# Gradient descend method:  None
# RUN  0 , total integrated cost =  0.9958380570272889
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  756194.7962365937
# cost splitting :  1.8406333729340703e-25 [0.99583806 0.        ]
# -------  42 0.4250000000000001 0.5750000000000003
# init ind =  100
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  6.766413786597446
# RUN  0 , total integrated cost =  6.766413786597446
# Gradient descend method:  None
# RUN  0 , total integrated cost =  6.766413786597446
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  187081.7746701702
# cost splitting :  3.506247512050851e-21 [6.76641379 0.        ]
# -------  43 0.4500000000000001 0.5750000000000003
# init ind =  100
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  5.738645990921424
# RUN  0 , total integrated cost =  5.738645990921424
# Gradient descend method:  None
# RUN  0 , total integrated cost =  5.738645990921424
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  293856.7484005505
# cost splitting :  2.226481018895792e-25 [5.73864599 0.        ]
# -------  44 0.47500000000000014 0.5750000000000003
# init ind =  100
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  4.708165930670323
# RUN  0 , total integrated cost =  4.708165930670323
# Gradient descend method:  None
# RUN  0 , total integrated cost =  4.708165930670323
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  401498.6789492869
# cost splitting :  0.0 [4.70816593 0.        ]
# -------  45 0.5000000000000002 0.5750000000000003
# init ind =  100
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.6655016933395346
# RUN  0 , total integrated cost =  3.6655016933395346
# Gradient descend method:  None
# RUN  0 , total integrated cost =  3.6655016933395346
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  513234.6635746044
# cost splitting :  3.2311742677852667e-26 [3.66550169 0.        ]
# -------  46 0.5250000000000001 0.5750000000000003
# init ind =  100
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  2.589025856926579
# RUN  0 , total integrated cost =  2.589025856926579
# Gradient descend method:  None
# RUN  0 , total integrated cost =  2.589025856926579
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  629845.1306750294
# cost splitting :  4.089454932665713e-26 [2.58902586 0.        ]
# -------  47 0.5500000000000003 0.5750000000000003
# init ind =  100
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  1.4335419075575002
# RUN  0 , total integrated cost =  1.4335419075575002
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1.4335419075575002
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  751175.9333805718
# cost splitting :  1.2621774483536189e-26 [1.43354191 0.        ]
# -------  48 0.4250000000000001 0.6000000000000003
# init ind =  100
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  7.076254786954771
# RUN  0 , total integrated cost =  7.076254786954771
# Gradient descend method:  None
# RUN  0 , total integrated cost =  7.076254786954771
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  181882.521994222
# cost splitting :  2.6457375030281738e-20 [7.07625479 0.        ]
# -------  49 0.4500000000000001 0.6000000000000003
# init ind =  100
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  6.045187451795594
# RUN  0 , total integrated cost =  6.045187451795594
# Gradient descend method:  None
# RUN  0 , total integrated cost =  6.045187451795594
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  289049.15272407274
# cost splitting :  2.443575540012597e-25 [6.04518745 0.        ]
# -------  50 0.47500000000000014 0.6000000000000003
# init ind =  100
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  5.018646275712376
# RUN  0 , total integrated cost =  5.018646275712376
# Gradient descend method:  None
# RUN  0 , total integrated cost =  5.018646275712376
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  396670.24943190784
# cost splitting :  1.135959703518257e-25 [5.01864628 0.        ]
# -------  51 0.5000000000000002 0.6000000000000003
# init ind =  100
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.97885247632073
# RUN  0 , total integrated cost =  3.97885247632073
# Gradient descend method:  None
# RUN  0 , total integrated cost =  3.97885247632073
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  508302.3902818461
# cost splitting :  3.2311742677852667e-26 [3.97885248 0.        ]
# -------  52 0.5250000000000001 0.6000000000000003
# init ind =  100
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  2.9138874743129906
# RUN  0 , total integrated cost =  2.9138874743129906
# Gradient descend method:  None
# RUN  0 , total integrated cost =  2.9138874743129906
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  624775.8829897492
# cost splitting :  7.270142102516871e-26 [2.91388747 0.        ]
# -------  53 0.5500000000000003 0.6000000000000003
# init ind =  100
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  1.786255870393806
# RUN  0 , total integrated cost =  1.786255870393806
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1.786255870393806
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  746144.5805987157
# cost splitting :  1.2621774483536189e-26 [1.78625587 0.        ]
# -------  54 0.5750000000000002 0.6000000000000003
# init ind =  100
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  0.4333675689733211
# RUN  0 , total integrated cost =  0.4333675689733211
# Gradient descend method:  None
# RUN  0 , total integrated cost =  0.4333675689733211
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  870523.2701234882
# cost splitting :  1.748614130452494e-08 [0.43336713 0.        ]
# -------  55 0.4250000000000001 0.6250000000000003
# init ind =  100
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  7.330349423691825
# RUN  0 , total integrated cost =  7.330349423691825
# Gradient descend method:  None
# RUN  0 , total integrated cost =  7.330349423691825
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  176973.53086129532
# cost splitting :  1.142336255510221e-19 [7.33034942 0.        ]
# -------  56 0.4500000000000001 0.6250000000000003
# init ind =  100
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  6.306243147281144
# RUN  0 , total integrated cost =  6.306243147281144
# Gradient descend method:  None
# RUN  0 , total integrated cost =  6.306243147281144
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  284563.6049902908
# cost splitting :  0.0 [6.30624315 0.        ]
# -------  57 0.47500000000000014 0.6250000000000003
# init ind =  100
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  5.277972998581103
# RUN  0 , total integrated cost =  5.277972998581103
# Gradient descend method:  None
# RUN  0 , total integrated cost =  5.277972998581103
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  392168.01147703634
# cost splitting :  7.270142102516871e-26 [5.277973 0.      ]
# -------  58 0.5000000000000002 0.6250000000000003
# init ind =  100
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  4.243412490914033
# RUN  0 , total integrated cost =  4.243412490914033
# Gradient descend method:  None
# RUN  0 , total integrated cost =  4.243412490914033
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  503700.90762437455
# cost splitting :  4.089454932665713e-26 [4.24341249 0.        ]
# -------  59 0.5250000000000001 0.6250000000000003
# init ind =  100
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.1867554203627604
# RUN  0 , total integrated cost =  3.1867554203627604
# Gradient descend method:  None
# RUN  0 , total integrated cost =  3.1867554203627604
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  620034.5060788749
# cost splitting :  8.532319550870494e-26 [3.18675542 0.        ]
# -------  60 0.5500000000000003 0.6250000000000003
# init ind =  100
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  2.077705333118255
# RUN  0 , total integrated cost =  2.077705333118255
# Gradient descend method:  None
# RUN  0 , total integrated cost =  2.077705333118255
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  741333.3077944894
# cost splitting :  3.2311742677852667e-26 [2.07770533 0.        ]
# -------  61 0.5750000000000002 0.6250000000000003
# init ind =  100
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  0.8178089520190891
# RUN  0 , total integrated cost =  0.8178089520190891
# Gradient descend method:  None
# RUN  0 , total integrated cost =  0.8178089520190891
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  866710.8536802017
# cost splitting :  8.539002324589772e-09 [0.81780874 0.        ]
# -------  62 0.4250000000000001 0.6500000000000004
# init ind =  100
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  7.55574749657564
# RUN  0 , total integrated cost =  7.55574749657564
# Gradient descend method:  None
# RUN  0 , total integrated cost =  7.55574749657564
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  172327.22420179544
# cost splitting :  7.453263515276961e-20 [7.5557475 0.       ]
# -------  63 0.4500000000000001 0.6500000000000004
# init ind =  100
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  6.524505613334709
# RUN  0 , total integrated cost =  6.524505613334709
# Gradient descend method:  None
# RUN  0 , total integrated cost =  6.524505613334709
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  280358.4423685195
# cost splitting :  2.114399661481985e-26 [6.52450561 0.        ]
# -------  64 0.47500000000000014 0.6500000000000004
# init ind =  100
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  5.502406472556344
# RUN  0 , total integrated cost =  5.502406472556344
# Gradient descend method:  None
# RUN  0 , total integrated cost =  5.502406472556344
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  387959.78150038864
# cost splitting :  0.0 [5.50240647 0.        ]
# -------  65 0.5000000000000002 0.6500000000000004
# init ind =  100
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  4.470185083058904
# RUN  0 , total integrated cost =  4.470185083058904
# Gradient descend method:  None
# RUN  0 , total integrated cost =  4.470185083058904
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  499381.32678329153
# cost splitting :  9.895471195092341e-26 [4.47018508 0.        ]
# -------  66 0.5250000000000001 0.6500000000000004
# init ind =  100
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.4185467684356126
# RUN  0 , total integrated cost =  3.4185467684356126
# Gradient descend method:  None
# RUN  0 , total integrated cost =  3.4185467684356126
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  615596.4660225171
# cost splitting :  5.0487097934144756e-26 [3.41854677 0.        ]
# -------  67 0.5500000000000003 0.6500000000000004
# init ind =  100
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  2.3232467080585137
# RUN  0 , total integrated cost =  2.3232467080585137
# Gradient descend method:  None
# RUN  0 , total integrated cost =  2.3232467080585137
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  736788.193418642
# cost splitting :  4.5438388140730445e-27 [2.32324671 0.        ]
# -------  68 0.5750000000000002 0.6500000000000004
# init ind =  100
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  1.1126391525969543
# RUN  0 , total integrated cost =  1.1126391525969543
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1.1126391525969543
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  862467.9253654084
# cost splitting :  8.45103532319646e-26 [1.11263915 0.        ]
# -------  69 0.4250000000000001 0.6750000000000004
# init ind =  100
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  7.738191833741346
# RUN  0 , total integrated cost =  7.738191833741346
# Gradient descend method:  None
# RUN  0 , total integrated cost =  7.738191833741346
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  167933.86239870195
# cost splitting :  9.22411255174578e-17 [7.73819183 0.        ]
# -------  70 0.4500000000000001 0.6750000000000004
# init ind =  100
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  6.715230362214494
# RUN  0 , total integrated cost =  6.715230362214494
# Gradient descend method:  None
# RUN  0 , total integrated cost =  6.715230362214494
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  276399.77278526267
# cost splitting :  5.352308908131669e-24 [6.71523036 0.        ]
# -------  71 0.47500000000000014 0.6750000000000004
# init ind =  100
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  5.696516726528845
# RUN  0 , total integrated cost =  5.696516726528845
# Gradient descend method:  None
# RUN  0 , total integrated cost =  5.696516726528845
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  384005.59692905797
# cost splitting :  1.6357819730662853e-25 [5.69651673 0.        ]
# -------  72 0.5000000000000002 0.6750000000000004
# init ind =  100
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  4.667477431483065
# RUN  0 , total integrated cost =  4.667477431483065
# Gradient descend method:  None
# RUN  0 , total integrated cost =  4.667477431483065
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  495331.1329655588
# cost splitting :  1.135959703518257e-25 [4.66747743 0.        ]
# -------  73 0.5250000000000001 0.6750000000000004
# init ind =  100
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.617075972620651
# RUN  0 , total integrated cost =  3.617075972620651
# Gradient descend method:  None
# RUN  0 , total integrated cost =  3.617075972620651
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  611432.0686370909
# cost splitting :  0.0 [3.61707597 0.        ]
# -------  74 0.5500000000000003 0.6750000000000004
# init ind =  100
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  2.5319466325659414
# RUN  0 , total integrated cost =  2.5319466325659414
# Gradient descend method:  None
# RUN  0 , total integrated cost =  2.5319466325659414
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  732509.8149166821
# cost splitting :  1.2621774483536189e-26 [2.53194663 0.        ]
# -------  75 0.5750000000000002 0.6750000000000004
# init ind =  100
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  1.3533225114487641
# RUN  0 , total integrated cost =  1.3533225114487641
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1.3533225114487641
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  858276.8196420075
# cost splitting :  8.077935669463167e-27 [1.35332251 0.        ]
# -------  76 0.4250000000000001 0.7000000000000004
# init ind =  100
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  7.900828024712452
# RUN  0 , total integrated cost =  7.900828024712452
# Gradient descend method:  None
# RUN  0 , total integrated cost =  7.900828024712452
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  163736.8297408659
# cost splitting :  1.0669688879617822e-18 [7.90082802 0.        ]
# -------  77 0.4500000000000001 0.7000000000000004
# init ind =  100
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  6.881768098613367
# RUN  0 , total integrated cost =  6.881768098613367
# Gradient descend method:  None
# RUN  0 , total integrated cost =  6.881768098613367
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  272681.6442786969
# cost splitting :  3.731400434116758e-25 [6.8817681 0.       ]
# -------  78 0.47500000000000014 0.7000000000000004
# init ind =  100
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  5.860605775993412
# RUN  0 , total integrated cost =  5.860605775993412
# Gradient descend method:  None
# RUN  0 , total integrated cost =  5.860605775993412
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  380284.89211629244
# cost splitting :  2.6707674807162475e-25 [5.86060578 0.        ]
# -------  79 0.5000000000000002 0.7000000000000004
# init ind =  100
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  4.833979034312237
# RUN  0 , total integrated cost =  4.833979034312237
# Gradient descend method:  None
# RUN  0 , total integrated cost =  4.833979034312237
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  491528.53199543635
# cost splitting :  0.0 [4.83397903 0.        ]
# -------  80 0.5250000000000001 0.7000000000000004
# init ind =  100
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  3.7920138405107773
# RUN  0 , total integrated cost =  3.7920138405107773
# Gradient descend method:  None
# RUN  0 , total integrated cost =  3.7920138405107773
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  607506.209585381
# cost splitting :  0.0 [3.79201384 0.        ]
# -------  81 0.5500000000000003 0.7000000000000004
# init ind =  100
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  2.71268122286487
# RUN  0 , total integrated cost =  2.71268122286487
# Gradient descend method:  None
# RUN  0 , total integrated cost =  2.71268122286487
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  728478.2773809158
# cost splitting :  8.077935669463167e-27 [2.71268122 0.        ]
# -------  82 0.5750000000000002 0.7000000000000004
# init ind =  100
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  1.556324862889642
# RUN  0 , total integrated cost =  1.556324862889642
# Gradient descend method:  None
# RUN  0 , total integrated cost =  1.556324862889642
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  854238.9955664313
# cost splitting :  1.8175355256292178e-26 [1.55632486 0.        ]

# %%
c_var = [0,1]
j = 0

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    aln.params.duration = dur
    
    k = 0
    
    while not conv_shift[i]:
        max_it = int(100 + 10**k)
                        
        weight_ = ( cost_uncontrolled[i] - costnode_[i][j][0][0][0] ) / sum( costnode_[i][j][2][0][:2] ) - 1.
        cost.setParams(1., weight_ * factor_we, weight_ * factor_ws)
        weights_[i][j] = cost.getParams()

        setinit(initVars[i], aln)

        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        control0 = aln.getZeroControl()
        control0 = bestControl_[i][j][:,:,n_pre-1:-n_post+1]

        bestControl_[i][j], bestState_[i][j], cost_[i][j], runtime_, grad_, phi_, phi1_, costnode_[i][j] = aln.A1(
            control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
            prec_variables_ = p_var, transition_time_ = t_pen[j])
        
        if cost_[i][j][-1] == 0.:
            conv_shift[i] = True

        print('uncontrolled cost : ', cost_uncontrolled[i])
        print('cost splitting : ', costnode_[i][j][0][0][0], costnode_[i][j][2][0][:2])

        time_ = np.arange(-dur_pre,round(dur+dur_post+aln.params.dt,1),aln.params.dt)
        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        with open(file_,'wb') as f:
            pickle.dump([bestControl_, bestState_, cost_, costnode_, weights_], f)
        
        k += 1
# Out:
# -------  0 0.4000000000000001 0.3500000000000001
# 0.008081542500347006 [1.24349818 0.00725421]
# set cost params:  1.0 0.0 117412.63803607534
# interpolate adjoint :  True True True
# initial cost =  146854.33926788406
# RUN  0 , total integrated cost =  146854.33926788406
# Gradient descend method:  None
# RUN  1 , total integrated cost =  146854.33379222377
# RUN  2 , total integrated cost =  146854.3279545286
# RUN  3 , total integrated cost =  146854.32247744178
# RUN  4 , total integrated cost =  146854.3166400713
# RUN  5 , total integrated cost =  146854.31116245457
# RUN  6 , total integrated cost =  146854.3053253026
# RUN  7 , total integrated cost =  146854.29984735913
# RUN  8 , total integrated cost =  146854.29401040133
# RUN  9 , total integrated cost =  146854.28853217736
# RUN  10 , total integrated cost =  146854.28269540909
# RUN  11 , total integrated cost =  146854.2772169153
# RUN  12 , total integrated cost =  146854.27138033404
# RUN  13 , total integrated cost =  146854.26590157286
# RUN  14 , total integrated cost =  146854.2600651788
# RUN  15 , total integrated cost =  146854.25458615067
# RUN  16 , total integrated cost =  146854.2487499438
# RUN  17 , total integrated cost =  146854.24327064902
# RUN  18 , total integrated cost =  146854.23743462926
# RUN  19 , total integrated cost =  146854.2319550675
# RUN  20 , total integrated cost =  146854.22611923478
# RUN  30 , total integrated cost =  146854.16954106858
# RUN  40 , total integrated cost =  146854.11296091185
# RUN  50 , total integrated cost =  146854.05637876433
# RUN  60 , total integrated cost =  146853.9997946257
# RUN  70 , total integrated cost =  146853.94320849533
# RUN  80 , total integrated cost =  146853.88662037326
# RUN  90 , total integrated cost =  146853.83003025936
# RUN  100 , total integrated cost =  146853.7734381541
# RUN  110 , total integrated cost =  146853.7168440655
# RUN  120 , total integrated cost =  146853.66024794112
# RUN  130 , total integrated cost =  146853.60364972104
# RUN  140 , total integrated cost =  146853.5470494053
# RUN  150 , total integrated cost =  146853.49044699327
# RUN  160 , total integrated cost =  146853.43384248498
# RUN  170 , total integrated cost =  146853.37723588027
# RUN  180 , total integrated cost =  146853.3206271784
# RUN  190 , total integrated cost =  146853.26401637666
# RUN  200 , total integrated cost =  146853.20740347568
# RUN  300 , total integrated cost =  146852.64116062774
# RUN  400 , total integrated cost =  146852.0747109189
# RUN  500 , total integrated cost =  146851.508054646
# RUN  600 , total integrated cost =  146850.94863215953
# RUN  700 , total integrated cost =  146850.39920516137
# RUN  800 , total integrated cost =  146849.8533962545
# RUN  900 , total integrated cost =  146849.30717252239
# RUN  1000 , total integrated cost =  146848.76001863985
# RUN  1100 , total integrated cost =  146848.21462449722
# RUN  1200 , total integrated cost =  146847.67849696576
# RUN  1300 , total integrated cost =  146847.14216365013
# RUN  1400 , total integrated cost =  146846.60562109193
# RUN  1500 , total integrated cost =  146846.0688687727
# RUN  1600 , total integrated cost =  146845.53190230508
# RUN  1700 , total integrated cost =  146844.9947168688
# RUN  1800 , total integrated cost =  146844.4573079478
# RUN  1900 , total integrated cost =  146843.9196685783
# RUN  2000 , total integrated cost =  146843.3817891152
# RUN  3000 , total integrated cost =  146838.00966135043
# RUN  4000 , total integrated cost =  146832.89322814092
# RUN  4000 , total integrated cost =  146832.89322814092
# Improved over  4000  iterations in  753.2790987389744  seconds by  0.014603613247004432  percent.
# uncontrolled cost :  146855.39702821904
# cost splitting :  0.00789211423227211 [1.24266909 0.00790069]
# 0.00789211423227211 [1.24266909 0.00790069]
# set cost params:  1.0 0.0 117429.78357968944
# interpolate adjoint :  True True True
# initial cost =  146854.33492683902
# RUN  0 , total integrated cost =  146854.33492683902
# Gradient descend method:  None
# RUN  1 , total integrated cost =  146854.33018270478
# RUN  2 , total integrated cost =  146854.3247212231
# RUN  3 , total integrated cost =  146854.319967408
# RUN  4 , total integrated cost =  146854.3145067544
# RUN  5 , total integrated cost =  146854.30975134711
# RUN  6 , total integrated cost =  146854.30429099407
# RUN  7 , total integrated cost =  146854.2995351149
# RUN  8 , total integrated cost =  146854.2940749907
# RUN  9 , total integrated cost =  146854.28931879587
# RUN  10 , total integrated cost =  146854.28385888843
# RUN  11 , total integrated cost =  146854.27910240006
# RUN  12 , total integrated cost =  146854.2736427091
# RUN  13 , total integrated cost =  146854.26888592995
# RUN  14 , total integrated cost =  146854.26342645523
# RUN  15 , total integrated cost =  146854.25866938554
# RUN  16 , total integrated cost =  146854.25321012735
# RUN  17 , total integrated cost =  146854.24845276686
# RUN  18 , total integrated cost =  146854.2429937238
# RUN  19 , total integrated cost =  146854.23823607268
# RUN  20 , total integrated cost =  146854.23277724636
# RUN  30 , total integrated cost =  146854.18169373792
# RUN  40 , total integrated cost =  146854.13060836226
# RUN  50 , total integrated cost =  146854.07952111878
# RUN  60 , total integrated cost =  146854.02843200805
# RUN  70 , total integrated cost =  146853.9773410369
# RUN  80 , total integrated cost =  146853.92624820495
# RUN  90 , total integrated cost =  146853.87515351188
# RUN  100 , total integrated cost =  146853.82405695738
# RUN  110 , total integrated cost =  146853.7729585413
# RUN  120 , total integrated cost =  146853.72185826092
# RUN  130 , total integrated cost =  146853.6707561108
# RUN  140 , total integrated cost =  146853.6196520916
# RUN  150 , total integrated cost =  146853.56854620186
# RUN  160 , total integrated cost =  146853.51743844218
# RUN  170 , total integrated cost =  146853.46632881227
# RUN  180 , total integrated cost =  146853.41521731167
# RUN  190 , total integrated cost =  146853.36410394133
# RUN  200 , total integrated cost =  146853.31298869962
# RUN  300 , total integrated cost =  146852.8017333506
# RUN  400 , total integrated cost =  146852.29029155028
# RUN  500 , total integrated cost =  146851.77857504165
# RUN  600 , total integrated cost =  146851.2662318997
# RUN  700 , total integrated cost =  146850.75370572862
# RUN  800 , total integrated cost =  146850.24099567556
# RUN  900 , total integrated cost =  146849.7281065864
# RUN  1000 , total integrated cost =  146849.21504549598
# RUN  1100 , total integrated cost =  146848.7018104459
# RUN  1200 , total integrated cost =  146848.18824018224
# RUN  1300 , total integrated cost =  146847.67437348154
# RUN  1400 , total integrated cost =  146847.16034762794
# RUN  1500 , total integrated cost =  146846.646162885
# RUN  1600 , total integrated cost =  146846.1318207784
# RUN  1700 , total integrated cost =  146845.61733131015
# RUN  1800 , total integrated cost =  146845.10268849757
# RUN  1900 , total integrated cost =  146844.58789262598
# RUN  2000 , total integrated cost =  146844.07295627167
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_8585/4212275498.py in <module>
#      33         control0 = bestControl_[i][j][:,:,n_pre-1:-n_post+1]
#      34
# ---> 35         bestControl_[i][j], bestState_[i][j], cost_[i][j], runtime_, grad_, phi_, phi1_, costnode_[i][j] = aln.A1(
#      36             control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
#      37             startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
#
# ~/Promotion/neurolib/neurolib/models/model.py in A1(self, control_, target_state_, c_scheme_, u_mat_, u_scheme_, max_iteration_, tolerance_, startStep_, max_control_, min_control_, t_sim_, t_sim_pre_, t_sim_post_, CGVar, line_search_, control_variables_, prec_variables_, separate_comp, transition_time_, noise_real, init_params)
#     661             if self.params.N == 1:
#     662                 if noise_real == 0:
# --> 663                     return opti1_rate_control.A1(self, control_, target_state_, c_scheme_, u_mat_, u_scheme_, max_iteration_,
#     664                                                 tolerance_, startStep_, max_control_, min_control_, t_sim_, t_sim_pre_, t_sim_post_, CGVar,
#     665                                                 line_search_, control_variables_, prec_variables_, separate_comp, transition_time_)
#
# ~/Promotion/neurolib/neurolib/utils/A1_aln_rate_control.py in A1(model, control_, target_state, c_scheme_, u_mat_, u_scheme_, max_iteration_, tolerance_, startStep_, cntrl_max_, cntrl_min_, t_sim_, t_sim_pre_, t_sim_post_, CGVar, line_search_, control_variables_, prec_variables_, separate_comp, transition_time_)
#     259         for ind_time in range(T):
#     260             f_p_grad_t_ = cost.cost_precision_gradient_t(N, V_target, state0_[:,:2,ind_time], target_state_[:,:,ind_time], ip_, transition_time_)
# --> 261             for v in prec_variables:
#     262                 full_cost_grad[0,v,ind_time] = f_p_grad_t_[0,v]
#     263
#
# ~/.local/lib/python3.9/site-packages/numba/typed/typedlist.py in __iter__(self)
#     370
#     371     def __iter__(self) -> pt.Iterator[T]:
# --> 372         for i in range(len(self)):
#     373             yield self[i]
#     374
#
# ~/.local/lib/python3.9/site-packages/numba/typed/typedlist.py in __len__(self)
#     304             return 0
#     305         else:
# --> 306             return _length(self)
#     307
#     308     def _allocated(self):
#
# ~/.local/lib/python3.9/site-packages/numba/typed/typedlist.py in _numba_type_(self)
#     278         return lsttype, opaque
#     279
# --> 280     @property
#     281     def _numba_type_(self):
#     282         if self._list_type is None:
#
# KeyboardInterrupt:

# %%
UN  0 , total integrated cost =  146855.60336671042
Gradient descend method:  None
RUN  1 , total integrated cost =  146855.59692692407
RUN  2 , total integrated cost =  146855.5896013814
RUN  3 , total integrated cost =  146855.58316115322
RUN  4 , total integrated cost =  146855.5758356881
RUN  5 , total integrated cost =  146855.56939530105

# %%
for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    aln.params.duration = dur
    max_it = int(300)
    k = 0
    
    while not conv_shift[i]:
        if k > 2:
            break
            
        weight_ = 1.
        cost.setParams(1., weight_ * factor_we, weight_ * factor_ws)
        weights_[i][j] = cost.getParams()

        setinit(initVars[i], aln)

        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        control0 = aln.getZeroControl()
        
        control0 = bestControl_[i][j][:,:,n_pre-1:-n_post+1]

        bestControl_[i][j], bestState_[i][j], cost_[i][j], runtime_, grad_, phi_, phi1_, costnode_[i][j] = aln.A1(
            control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
            prec_variables_ = p_var, transition_time_ = t_pen[j])
        
        if cost_[i][j][2] == 0.:
            conv_shift[i] = True

        print('uncontrolled cost : ', cost_uncontrolled[i])
        print('cost splitting : ', costnode_[i][j][0][0][0], costnode_[i][j][2][0][:2])

        time_ = np.arange(-dur_pre,round(dur+dur_post+aln.params.dt,1),aln.params.dt)
        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        if False:
            fig, ax = plt.subplots(2,1, constrained_layout=True, figsize = (4,4) )
            ax[1].plot(time_, bestControl_[i][j][0,0,:], color = 'red')
            ax[0].plot(time_, bestState_[i][j][0,0,:], color= 'red')
            ax[1].plot(time_, bestControl_[i][j][0,1,:], color = 'blue')
            ax[0].plot(time_, bestState_[i][j][0,1,:], color= 'blue')
            ax[0].plot(time_, target_[0,0,:], linestyle = '--', color='red')
            ax[0].plot(time_, target_[0,1,:], linestyle = '--', color='blue')
            ax[0].set_xlim(-dur_pre,dur+dur_post)
            ax[1].set_xlim(-dur_pre,dur+dur_post)
            ax[0].axvspan(dur*t_pen[j], dur, alpha=0.2, color='gray')
            plt.show()

        with open(file_,'wb') as f:
            pickle.dump([bestControl_, bestState_, cost_, costnode_, weights_], f)
        
        k += 1
