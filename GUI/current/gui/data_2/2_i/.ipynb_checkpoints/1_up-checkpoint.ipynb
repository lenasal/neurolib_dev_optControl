# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import sys
import pickle

path = os.getcwd().split(os.sep + 'GUI')[0]
if path not in sys.path:
    print("not here")
    sys.path.append(path)

from neurolib.models.aln import ALNModel
from neurolib.utils import plotFunctions as plotFunc
from neurolib.utils import costFunctions as cost
import neurolib.dashboard.functions as functions
import neurolib.dashboard.data as data
    
# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2 

#path = os.path.join(os.getcwd(), "plots")
# Out:
# not here

# %%
grid_data_file = os.path.join(os.getcwd().split('data')[0], 'bi.pickle')
with open(grid_data_file,'rb') as f:
    load_array= pickle.load(f)
exc = load_array[0]
inh = load_array[1]

folder = str(os.getcwd().split('data_2')[1])
print(folder)
case = str(folder[1])

file_ = '1_up.pickle'

c_var = [0,1]
if len(folder) == 4:
    if folder[3] == 'e':
        p_var = [0]
    elif folder[3] == 'i':
        p_var = [1]
else:
    p_var = [0,1]
    
print(p_var)
# Out:
# /1_i
# [1]

# %%
aln = ALNModel()
N = aln.params.N

data.set_parameters(aln)

state_vars = aln.state_vars
init_vars = aln.init_vars

##############################################################
def setinit(init_vars_, model):
    state_vars = model.state_vars
    init_vars = model.init_vars
    for iv in range(len(init_vars)):
        for sv in range(len(state_vars)):
            if state_vars[sv] in init_vars[iv]:
                #print("set init vars ", )
                if model.params[init_vars[iv]].ndim == 2:
                    model.params[init_vars[iv]][0,:] = init_vars_[sv]
                else:
                    model.params[init_vars[iv]][0] = init_vars_[sv]
                    
##############################################################               
def setmaxmincontrol(max_c_c, min_c_c, max_c_r, min_c_r):
    import numpy as np
    
    max_cntrl = np.zeros(( 6 ))
    min_cntrl = np.zeros(( 6 ))
    
    max_cntrl[0] = max_c_c
    min_cntrl[0] = min_c_c
    max_cntrl[1] = max_c_c
    min_cntrl[1] = min_c_c
    max_cntrl[2] = max_c_r
    min_cntrl[2] = min_c_r
    max_cntrl[3] = max_c_r
    min_cntrl[3] = min_c_r
    max_cntrl[4] = max_c_r
    min_cntrl[4] = min_c_r
    max_cntrl[5] = max_c_r
    min_cntrl[5] = min_c_r
            
    return max_cntrl, min_cntrl

# %%
d_array = np.arange(20., 300, 0.1)
t0_array = d_array - 20.
t_pen = np.zeros(( t0_array.shape ))
for i in range(len(t_pen)):
    t_pen[i] = t0_array[i] / d_array[i]

# %%
dur_pre = 10
dur_post = 10

n_pre = int(np.around(dur_pre/aln.params.dt + 1.,1))
n_post = int(np.around(dur_post/aln.params.dt + 1.,1))

tol = 1e-12
start_step = 10.
c_scheme = np.zeros(( 1,1 ))
c_scheme[0,0] = 1.
u_mat = np.identity(1)
u_scheme = np.array([[1.]])

if case in ['1', '2']:    # low to high
    max_I = [3., -3.]
else:
    max_I = [-3., 3.]
    
if case in ['1', '3']:    # sparsity
    factor_ws = 1.
    factor_we = 0.
else:
    factor_ws = 0.
    factor_we = 1.
    
maxC = [100., -100., 0.18, 0.]
max_cntrl, min_cntrl = setmaxmincontrol(maxC[0], maxC[1], maxC[2], maxC[3])

# %%
bestControl_ = np.array( [[None] * len(t_pen)] * len(exc) )
bestState_ = np.array( [[None] * len(t_pen)] * len(exc) )
cost_ = np.array( [[None] * len(t_pen)] * len(exc) )
costnode_ = np.array( [[None] * len(t_pen)] * len(exc) )
weights_ = np.array( [[None] * len(t_pen)] * len(exc) )
convergence_ = np.array( [[None] * len(t_pen)] * len(exc) )

initVars = [None] * len(exc)
target = [None] * len(exc)
cost_uncontrolled = [None] * len(exc)

print(bestControl_.shape)
# Out:
# (147, 2800)

# %%
if os.path.isfile(file_) :
    print("file found")
    
    with open(file_,'rb') as f:
        load_array = pickle.load(f)

    bestControl_ = load_array[0]
    bestState_ = load_array[1]
    cost_ = load_array[2]
    costnode_ = load_array[3]
    weights_ = load_array[4]
# Out:
# file found

# %%
# get initial parameters and target states

#i_stepsize = 20
#limit = 150
#start_index = 0
#i_range = range(start_index, limit,i_stepsize)
i_range = [20]

data.set_parameters(aln)

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    aln.params.duration = 3000.
    
    control0 = aln.getZeroControl()
    control0 = functions.step_control(aln, maxI_ = max_I[0])

    aln.run(control=control0)
    
    target_rates = np.zeros((2))
    target_rates[0] = aln.rates_exc[0,-1] 
    target_rates[1] = aln.rates_inh[0,-1]

    control0 = functions.step_control(aln, maxI_ = max_I[1])
    aln.run(control=control0)

    init_state_vars = np.zeros(( len(state_vars) ))
    for j in range(len(state_vars)):
        if aln.state[state_vars[j]].size == 1:
            init_state_vars[j] = aln.state[state_vars[j]][0]
        else:
            init_state_vars[j] = aln.state[state_vars[j]][0,-1]

    initVars[i] = init_state_vars
    target[i] = [target_rates[0], target_rates[1]]
# Out:
# -------  20 0.4500000000000001 0.4750000000000002

# %%
# get uncontrolled cost

data.set_parameters(aln)

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    dur = d_array[0]
    aln.params.duration = dur
    
    target_ = aln.getZeroTarget()
    target_[:,0,:] = target[i][0]
    target_[:,1,:] = target[i][1]
        
    cost.setParams(1.0, 0.0, 0.0)

    setinit(initVars[i], aln)
    control0 = aln.getZeroControl()

    # "HS", "FR", "PR", "HZ"
    cgv = None
    max_it = 0

    bestControl_init_, bestState_init_, cost_init_, runtime_init_, grad_init_, phi_init_, phi1_, costnode_init_ = aln.A1(
        control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
        prec_variables_ = p_var, transition_time_ = 0.)
    
    cost_uncontrolled[i] = cost_init_[0]
# Out:
# -------  20 0.4500000000000001 0.4750000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  12801.807032522984
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  0 , total integrated cost =  12801.807032522984
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.

# %%
cgv = None
j = 0
k = 0

while k < 10:
    print('-------------------------------------------- k = ', k)

    for i in i_range:
        print("------- ", i, exc[i], inh[i])
        aln.params.ext_exc_current = exc[i] * 5.
        aln.params.ext_inh_current = inh[i] * 5.

        if convergence_[i][j] == True:
            print('converged')
            continue

        dur = d_array[0]
        aln.params.duration = dur
        
        setinit(initVars[i], aln)

        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        max_it = int(100)

        if type(bestControl_[i][j]) == type(None) or np.amax(np.abs(bestControl_[i][j])) < 1e-6:
            print('no solution found')
            control0 = aln.getZeroControl()
            #control0[0,0,:50] = 5.
            cost.setParams(1.0, 0., 1.)
            max_it = int(1)
            weights_[i][j] = [1., 0., 1.]
        else:
            control0 = bestControl_[i][j][:,:,n_pre-1:-n_post+1]
            l = 1
            while cost_[i][j][-l] == 0.:
                l += 1

            weight_ = ( cost_uncontrolled[i] - costnode_[i][j][0][0][0] ) / sum( costnode_[i][j][2][0][:] )
                
            print("weight = ", weight_)
            cost.setParams(1.0, weight_ * factor_we, weight_ * factor_ws)
            weights_[i][j] = cost.getParams()

        bestControl_[i][j], bestState_[i][j], cost_[i][j], runtime_, grad_, phi_, phi1_, costnode_[i][j] = aln.A1(
            control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
            prec_variables_ = p_var, transition_time_ = t_pen[j])

        if max_it > 1:
            if cost_[i][j][2] == 0.:
                print('converged')
                convergence_[i][j] = True

        print('uncontrolled cost : ', cost_uncontrolled[i])
        print('cost splitting : ', costnode_[i][j][0][0][0], costnode_[i][j][2][0][:2])

        time_ = np.arange(-dur_pre,dur+dur_post+aln.params.dt,aln.params.dt)
        dur += dur_pre + dur_post
        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        if True:
            fig, ax = plt.subplots(2,1, constrained_layout=True, figsize = (4,4) )
            ax[1].plot(time_, bestControl_[i][j][0,0,:], color = 'red')
            ax[0].plot(time_, bestState_[i][j][0,0,:], color= 'red')
            ax[1].plot(time_, bestControl_[i][j][0,1,:], color = 'blue')
            ax[0].plot(time_, bestState_[i][j][0,1,:], color= 'blue')
            ax[0].plot(time_, target_[0,0,:], linestyle = '--', color='red')
            ax[0].plot(time_, target_[0,1,:], linestyle = '--', color='blue')
            ax[0].set_xlim(-dur_pre,dur-dur_post)
            ax[1].set_xlim(-dur_pre,dur-dur_post)
            ax[0].axvspan(t0_array[0], dur, alpha=0.2, color='gray')
            plt.show()

        with open(file_,'wb') as f:
            pickle.dump([bestControl_, bestState_, cost_, costnode_, weights_], f)
    
    k += 1
# Out:
# -------------------------------------------- k =  0
# -------  20 0.4500000000000001 0.4750000000000002
# no solution found
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  12801.807032522984
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7028.817106816711
# RUN  1 , total integrated cost =  7028.817106816711
# Improved over  1  iterations in  0.0441837590187788  seconds by  45.09511751770664  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  7022.352130835234 [6.46497598 0.        ]
# -------------------------------------------- k =  1
# -------  20 0.4500000000000001 0.4750000000000002
# weight =  893.9638628582769
# set cost params:  1.0 0.0 893.9638628582769
# interpolate adjoint :  True True True
# initial cost =  12801.807032522984
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12502.573615880003
# RUN  2 , total integrated cost =  12282.402726657583
# RUN  3 , total integrated cost =  12070.565066598327
# RUN  4 , total integrated cost =  11912.290714101808
# RUN  5 , total integrated cost =  11763.917856884547
# RUN  6 , total integrated cost =  11646.507820333409
# RUN  7 , total integrated cost =  11533.963616454199
# RUN  8 , total integrated cost =  11442.194434920108
# RUN  9 , total integrated cost =  11356.349321532143
# RUN  10 , total integrated cost =  11286.475186516192
# RUN  11 , total integrated cost =  11222.547471981032
# RUN  12 , total integrated cost =  11168.019537450471
# RUN  13 , total integrated cost =  11117.332266027826
# RUN  14 , total integrated cost =  11073.718088676356
# RUN  15 , total integrated cost =  11032.612902453468
# RUN  16 , total integrated cost =  10997.852608803205
# RUN  17 , total integrated cost =  10965.253061769523
# RUN  18 , total integrated cost =  10936.228989288546
# RUN  19 , total integrated cost =  10908.858988048667
# RUN  20 , total integrated cost =  10885.87677508157
# RUN  30 , total integrated cost =  10733.168560113536
# RUN  40 , total integrated cost =  10670.430305057018
# RUN  50 , total integrated cost =  10638.961849304973
# RUN  60 , total integrated cost =  10623.562423977983
# RUN  70 , total integrated cost =  10615.713453308854
# RUN  80 , total integrated cost =  10612.004864390754
# RUN  90 , total integrated cost =  10609.909318854781
# RUN  100 , total integrated cost =  10609.14817377926
# RUN  100 , total integrated cost =  10609.14817377926
# Improved over  100  iterations in  12.947373684000922  seconds by  17.12772933675126  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  
# -------  20 0.4500000000000001 0.4750000000000002
# weight =  1161.7667620161274
# set cost params:  1.0 0.0 1161.7667620161274
# interpolate adjoint :  True True True
# initial cost =  12801.807032522984
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.24507038301089779  seconds by  0.0  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  3605.831995425745 [7.91550881 0.        ]
# -------------------------------------------- k =  6
# -------  20 0.4500000000000001 0.4750000000000002
# weight =  1161.7667620161274
# set cost params:  1.0 0.0 1161.7667620161274
# interpolate adjoint :  True True True
# initial cost =  12801.807032522984
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.18306847900385037  seconds by  0.0  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  3605.831995425745 [7.91550881 0.        ]
# -------------------------------------------- k =  7
# -------  20 0.4500000000000001 0.4750000000000002
# weight =  1161.7667620161274
# set cost params:  1.0 0.0 1161.7667620161274
# interpolate adjoint :  True True True
# initial cost =  12801.807032522984
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.1833793020050507  seconds by  0.0  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  3605.831995425745 [7.91550881 0.        ]
# -------------------------------------------- k =  8
# -------  20 0.4500000000000001 0.4750000000000002
# weight =  1161.7667620161274
# set cost params:  1.0 0.0 1161.7667620161274
# interpolate adjoint :  True True True
# initial cost =  12801.807032522984
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.21741865400690585  seconds by  0.0  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  3605.831995425745 [7.91550881 0.        ]
# -------------------------------------------- k =  9
# -------  20 0.4500000000000001 0.4750000000000002
# weight =  1161.7667620161274
# set cost params:  1.0 0.0 1161.7667620161274
# interpolate adjoint :  True True True
# initial cost =  12801.807032522984
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.16833703601150773  seconds by  0.0  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  3605.831995425745 [7.91550881 0.        ]

# %%
for i in range(bestControl_.shape[0]):
    for j in range(1,bestControl_.shape[1]):
        bestControl_[i][j] = None
        convergence_[i][j] = None

# %%
cost.setParams(1.0, factor_we, factor_ws)

j_start = 1760

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.

    for j in range(j_start,j_start+100):
        print(i,j, '-----------------')
            
        k = 0
        while convergence_[i][j] != True:
            print('---------------------', k)

            dur = round(d_array[j],1)
            #print('simulation duration : ', dur)
            aln.params.duration = dur
            max_it = int(100)  
            
            setinit(initVars[i], aln)
            target_ = aln.getZeroTarget()
            target_[:,0,:] = target[i][0]
            target_[:,1,:] = target[i][1]

            if type(bestControl_[i][j]) == type(None):
                #print('no solution computed yet')
                control0 = aln.getZeroControl()
                control0[:,:,:-1] = bestControl_[i][j-1][:,:,n_pre-1:-n_post+1]
                                        
                l = 1
                while cost_[i][j-1][-l] == 0.:
                    l += 1
                    
                weight_ = ( cost_uncontrolled[i] - costnode_[i][j-1][0][0][0] ) / sum( costnode_[i][j-1][2][0][:] )
            else:
                control0 = bestControl_[i][j][:,:,n_pre-1:-n_post+1]
                l = 1
                while cost_[i][j][-l] == 0.:
                    l += 1
                
                weight_ = ( cost_uncontrolled[i] - costnode_[i][j][0][0][0] ) / sum( costnode_[i][j][2][0][:] )
                
            #print("weight = ", weight_)
            cost.setParams(1.0, weight_ * factor_we, weight_ * factor_ws)
            weights_[i][j] = cost.getParams()

            bestControl_[i][j], bestState_[i][j], cost_[i][j], runtime_, grad_, phi_, phi1_, costnode_[i][j] = aln.A1(
                control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
                startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
                t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
                prec_variables_ = p_var, transition_time_ = t_pen[j])

            if cost_[i][j][2] == 0.:
                #print('converged')
                convergence_[i][j] = True

            #print('uncontrolled cost : ', cost_uncontrolled[i])
            print('cost splitting : ', costnode_[i][j][0][0][0], costnode_[i][j][2][0][:2])

            if False:
                time_ = np.arange(-dur_pre,round(dur+dur_post+aln.params.dt,1),aln.params.dt)
                dur += dur_pre + dur_post
                target_ = aln.getZeroTarget()
                target_[:,0,:] = target[i][0]
                target_[:,1,:] = target[i][1]
                
                fig, ax = plt.subplots(2,1, constrained_layout=True, figsize = (4,4) )
                ax[1].plot(time_, bestControl_[i][j][0,0,:], color = 'red')
                ax[0].plot(time_, bestState_[i][j][0,0,:], color= 'red')
                ax[1].plot(time_, bestControl_[i][j][0,1,:], color = 'blue')
                ax[0].plot(time_, bestState_[i][j][0,1,:], color= 'blue')
                ax[0].plot(time_, target_[0,0,:], linestyle = '--', color='red')
                ax[0].plot(time_, target_[0,1,:], linestyle = '--', color='blue')
                ax[0].set_xlim(-dur_pre,dur-dur_post)
                ax[1].set_xlim(-dur_pre,dur-dur_post)
                ax[0].axvspan(t0_array[j], t0_array[j]+20, alpha=0.2, color='gray')
                plt.show()

            with open(file_,'wb') as f:
                pickle.dump([bestControl_, bestState_, cost_, costnode_, weights_], f)
                
            k += 1
# Out:
# set cost params:  1.0 0.0 1.0
# -------  20 0.4500000000000001 0.4750000000000002
# 20 1760 -----------------
# 20 1761 -----------------
# 20 1762 -----------------
# 20 1763 -----------------
# 20 1764 -----------------
# 20 1765 -----------------
# 20 1766 -----------------
# 20 1767 -----------------
# 20 1768 -----------------
# 20 1769 -----------------
# 20 1770 -----------------
# 20 1771 -----------------
# 20 1772 -----------------
# 20 1773 -----------------
# 20 1774 -----------------
# 20 1775 -----------------
# 20 1776 -----------------
# 20 1777 -----------------
# 20 1778 -----------------
# 20 1779 -----------------
# 20 1780 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 3423.5295891899323
# interpolate adjoint :  True True True
# initial cost =  12801.82016570886
# RUN  0 , total integrated cost =  12801.82016570886
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.82007462551
# RUN  2 , total integrated cost =  12801.820074589097
# RUN  3 , total integrated cost =  12801.82007458023
# RUN  4 , total integrated cost =  12801.820074573938
# RUN  5 , total integrated cost =  12801.820074562522
# RUN  6 , total integrated cost =  12801.820074491618
# RUN  7 , total integrated cost =  12801.820013539025
# RUN  8 , total integrated cost =  12801.819964982798
# RUN  9 , total integrated cost =  12801.819964945591
# RUN  10 , total integrated cost =  12801.819964938102
# RUN  11 , total integrated cost =  12801.819964933173
# RUN  90 , total integrated cost =  12801.822154134612
# RUN  100 , total integrated cost =  12801.822152456325
# RUN  100 , total integrated cost =  12801.822152456325
# Improved over  100  iterations in  37.03077527300047  seconds by  7.841653939522075e-07  percent.
# cost splitting :  0.0017183321134682775 [3.73935594e+00 2.18487868e-16]
# --------------------- 8
# set cost params:  1.0 0.0 3423.5321622722254
# interpolate adjoint :  True True True
# initial cost =  12801.82224959344
# RUN  0 , total integrated cost =  12801.82224959344
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.822249593288
# RUN  2 , total integrated cost =  12801.822249593068
# RUN  3 , total integrated cost =  12801.822249592758
# RUN  4 , total integrated cost =  12801.82224959216
# RUN  5 , total integrated cost =  12801.82224959081
# RUN  6 , total integrated cost =  12801.822249585843
# RUN  7 , total integrated cost =  12801.822249538467
# RUN  8 , total integrated cost =  12801.822181655838
# RUN  9 , total integrated cost =  12801.822127647667
# RUN  10 , total integrated cost =  12801.822127626792
# RUN  11 , total integrated cost =  12801.822127623576
# RUN  12 , total integrated cost =  12801.822127622409
# RUN  13 , total integrated cost =  12801.822127621841
# RUN  14 , total integrated cost =  12801.822127621419
# RUN  15 , total integrated cost =  12801.822127621223
# RUN  16 , total integrated cost =  12801.822127621053
# RUN  17 , total integrated cost =  12801.822127620851
# RUN  18 , total integrated cost =  12801.822127620548
# RUN  19 , total integrated cost =  12801.822127619975
# RUN  20 , total integrated cost =  12801.822127618732
# RUN  30 , total integrated cost =  12801.822110416271
# RUN  40 , total integrated cost =  12801.82209859113
# RUN  50 , total integrated cost =  12801.822098578632
# RUN  60 , total integrated cost =  12801.822095400888
# RUN  70 , total integrated cost =  12801.8220642118
# RUN  80 , total integrated cost =  12801.822064130254
# RUN  90 , total integrated cost =  12801.822052384121
# RUN  100 , total integrated cost =  12801.822048459511
# RUN  100 , total integrated cost =  12801.822048459511
# Improved over  100  iterations in  35.89382181499968  seconds by  1.571135157973913e-06  percent.
# cost splitting :  0.001719573304250445 [3.73935587e+00 2.18487868e-16]
# --------------------- 9
# set cost params:  1.0 0.0 3423.532219000063
# interpolate adjoint :  True True True
# initial cost =  12801.822260585082
# RUN  0 , total integrated cost =  12801.822260585082
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.822260584631
# RUN  2 , total integrated cost =  12801.82226058418
# RUN  3 , total integrated cost =  12801.822260583649
# RUN  4 , total integrated cost =  12801.822260582825
# RUN  5 , total integrated cost =  12801.822260581082
# RUN  6 , total integrated cost =  12801.822260575856
# RUN  7 , total integrated cost =  12801.822260529421
# RUN  8 , total integrated cost =  12801.822194245846
# RUN  9 , total integrated cost =  12801.822139017135
# RUN  10 , total integrated cost =  12801.822138994812
# RUN  11 , total integrated cost =  12801.822138991056
# RUN  12 , total integrated cost =  12801.82213898957
# RUN  13 , total integrated cost =  12801.82213898887
# RUN  14 , total integrated cost =  12801.822138988353
# RUN  15 , total integrated cost =  12801.822138987842
# RUN  16 , total integrated cost =  12801.822138987234
# RUN  17 , total integrated cost =  12801.82213898625
# RUN  18 , total integrated cost =  12801.822138984171
# RUN  19 , total integrated cost =  12801.822138976017
# RUN  20 , total integrated cost =  12801.822138869618
# RUN  30 , total integrated cost =  12801.822134325044
# RUN  40 , total integrated cost =  12801.822116104822
# RUN  50 , total integrated cost =  12801.822111447651
# RUN  60 , total integrated cost =  12801.822108599712
# RUN  70 , total integrated cost =  12801.822108425931
# RUN  80 , total integrated cost =  12801.82210192686
# RUN  90 , total integrated cost =  12801.821989143316
# RUN  100 , total integrated cost =  12801.821982154703
# RUN  100 , total integrated cost =  12801.821982154703
# Improved over  100  iterations in  33.65292037499967  seconds by  2.1749277010485457e-06  percent.
# cost splitting :  0.0017218611146065544 [3.73935579e+00 2.18487868e-16]
# --------------------- 10
# set cost params:  1.0 0.0 3423.532298877616
# interpolate adjoint :  True True True
# initial cost =  12801.822280845294
# RUN  0 , total integrated cost =  12801.822280845294
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.822280843313
# RUN  2 , total integrated cost =  12801.822280842363
# RUN  3 , total integrated cost =  12801.8222808417
# RUN  4 , total integrated cost =  12801.822280841083
# RUN  5 , total integrated cost =  12801.822280840375
# RUN  6 , total integrated cost =  12801.82228083921
# RUN  7 , total integrated cost =  12801.82228083654
# RUN  8 , total integrated cost =  12801.822280825894
# RUN  9 , total integrated cost =  12801.822280637312
# RUN  10 , total integrated cost =  12801.822278180975
# RUN  11 , total integrated cost =  12801.822277704108
# RUN  12 , total integrated cost =  12801.822277682995
# RUN  13 , total integrated cost =  12801.82227767971
# RUN  14 , total integrated cost =  12801.822277678411
# RUN  15 , total integrated cost =  12801.822277677655
# RUN  16 , total integrated cost =  12801.822277677044
# RUN  17 , total integrated cost =  12801.822277676423
# RUN  18 , total integrated cost =  12801.822277675636
# RUN  19 , total integrated cost =  12801.822277674299
# RUN  20 , total integrated cost =  12801.822277670872
# RUN  30 , total integrated cost =  12801.822273023057
# RUN  40 , total integrated cost =  12801.822266034775
# RUN  50 , total integrated cost =  12801.822187776796
# RUN  60 , total integrated cost =  12801.822170694351
# RUN  70 , total integrated cost =  12801.822160037455
# RUN  80 , total integrated cost =  12801.822073316722
# RUN  90 , total integrated cost =  12801.822070234672
# RUN  100 , total integrated cost =  12801.82205958626
# RUN  100 , total integrated cost =  12801.82205958626
# Improved over  100  iterations in  31.52204862200051  seconds by  1.7283401376744223e-06  percent.
# cost splitting :  0.0017211379663338697 [3.73935572e+00 2.18487868e-16]
# --------------------- 11
# set cost params:  1.0 0.0 3423.532356335384
# interpolate adjoint :  True True True
# initial cost =  12801.822274441294
# RUN  0 , total integrated cost =  12801.822274441294
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.822274438773
# RUN  2 , total integrated cost =  12801.822274436867
# RUN  3 , total integrated cost =  12801.822274434566
# RUN  4 , total integrated cost =  12801.822274429715
# RUN  5 , total integrated cost =  12801.822274409757
# RUN  6 , total integrated cost =  12801.822273717722
# RUN  7 , total integrated cost =  12801.82227095825
# RUN  8 , total integrated cost =  12801.822270857929
# RUN  9 , total integrated cost =  12801.822270848985
# RUN  10 , total integrated cost =  12801.82227084589
# RUN  11 , total integrated cost =  12801.822270843943
# RUN  12 , total integrated cost =  12801.822270841834
# RUN  13 , total integrated cost =  12801.822270838104
# RUN  14 , total integrated cost =  12801.822270824347
# RUN  15 , total integrated cost =  12801.822270597924
# RUN  16 , total integrated cost =  12801.82226826717
# RUN  17 , total integrated cost =  12801.82226793083
# RUN  18 , total integrated cost =  12801.822267915466
# RUN  19 , total integrated cost =  12801.822267911673
# RUN  20 , total integrated cost =  12801.822267909583
# RUN  30 , total integrated cost =  12801.82226199949
# RUN  40 , total integrated cost =  12801.82216685789
# RUN  50 , total integrated cost =  12801.822163769086
# Control only changes marginally.
# RUN  56 , total integrated cost =  12801.81825964221
# Improved over  56  iterations in  15.51122787499844  seconds by  3.136115310553578e-05  percent.
# cost splitting :  0.0017255150239562787 [3.73935454e+00 2.18487868e-16]
# --------------------- 12
# set cost params:  1.0 0.0 3423.5334403623315
# interpolate adjoint :  True True True
# initial cost =  12801.822313203296
# RUN  0 , total integrated cost =  12801.822313203296
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.822313203296
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.822313203296
# Improved over  1  iterations in  0.34892388499974913  seconds by  0.0  percent.
# cost splitting :  0.0017255150239562787 [3.73935454e+00 2.18487868e-16]
# 20 1781 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 3423.5334403623315
# interpolate adjoint :  True True True
# initial cost =  12801.82001123584
# RUN  0 , total integrated cost =  12801.82001123584
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.819907951605
# RUN  2 , total integrated cost =  12801.819907765972
# RUN  3 , total integrated cost =  12801.819907759516
# RUN  4 , total integrated cost =  12801.819907758536
# RUN  5 , total integrated cost =  12801.81990775834
# RUN  6 , total integrated cost =  12801.819907758276
# RUN  7 , total integrated cost =  12801.819907758234
# RUN  8 , total integrated cost =  12801.819907758234
# Control only changes marginally.
# RUN  8 , total integrated cost =  12801.819907758234
# Improved over  8  iterations in  2.2974149090005085  seconds by  8.083038665063214e-07  percent.
# cost splitting :  0.0017000680467700844 [3.73935391e+00 2.18487868e-16]
# --------------------- 1
# set cost params:  1.0 0.0 3423.5340256377094
# interpolate adjoint :  True True True
# initial cost =  12801.822096310005
# RUN  0 , total integrated cost =  12801.822096310005
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.822096310005
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.822096310005
# Improved over  1  iterations in  0.3431759319992125  seconds by  0.0  percent.
# cost splitting :  0.0017000680467700844 [3.73935391e+00 2.18487868e-16]
# 20 1782 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 3423.5340256377094
# interpolate adjoint :  True True True
# initial cost =  12801.820002729599
# RUN  0 , total integrated cost =  12801.820002729599
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.819911615248
# RUN  2 , total integrated cost =  12801.819911593297
# RUN  3 , total integrated cost =  12801.819911591196
# RUN  4 , total integrated cost =  12801.81991159076
# RUN  5 , total integrated cost =  12801.819911590625
# RUN  6 , total integrated cost =  12801.819911590585
# RUN  7 , total integrated cost =  12801.819911590565
# RUN  8 , total integrated cost =  12801.819911590552
# RUN  9 , total integrated cost =  12801.819911590552
# Control only changes marginally.
# RUN  9 , total integrated cost =  12801.819911590552
# Improved over  9  iterations in  2.8863221390001854  seconds by  7.119225813312369e-07  percent.
# cost splitting :  0.0016874281604569313 [3.73935330e+00 2.18487868e-16]
# --------------------- 1
# set cost params:  1.0 0.0 3423.5345821821847
# interpolate adjoint :  True True True
# initial cost =  12801.821992706973
# RUN  0 , total integrated cost =  12801.821992706973
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.821992706973
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.821992706973
# Improved over  1  iterations in  0.33934538699941186  seconds by  0.0  percent.
# cost splitting :  0.0016874281604569313 [3.73935330e+00 2.18487868e-16]
# 20 1783 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 3423.5345821821847
# interpolate adjoint :  True True True
# initial cost =  12801.820069948018
# RUN  0 , total integrated cost =  12801.820069948018
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.819985330647
# RUN  2 , total integrated cost =  12801.819985330632
# RUN  3 , total integrated cost =  12801.819985330632
# Control only changes marginally.
# RUN  3 , total integrated cost =  12801.819985330632
# Improved over  3  iterations in  0.9384853419996944  seconds by  6.609793388179241e-07  percent.
# cost splitting :  0.0016858339693173593 [3.73935272e+00 2.18487868e-16]
# --------------------- 1
# set cost params:  1.0 0.0 3423.5351174700136
# interpolate adjoint :  True True True
# initial cost =  12801.821986960631
# RUN  0 , total integrated cost =  12801.821986960631
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.821986960631
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.821986960631
# Improved over  1  iterations in  0.3287150640007894  seconds by  0.0  percent.
# cost splitting :  0.0016858339693173593 [3.73935272e+00 2.18487868e-16]
# 20 1784 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 3423.5351174700136
# interpolate adjoint :  True True True
# initial cost =  12801.820203716732
# RUN  0 , total integrated cost =  12801.820203716732
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.820125675295
# RUN  2 , total integrated cost =  12801.820125672037
# RUN  3 , total integrated cost =  12801.820125668188
# RUN  4 , total integrated cost =  12801.820125660088
# RUN  5 , total integrated cost =  12801.820125616288
# RUN  6 , total integrated cost =  12801.820121366181
# RUN  7 , total integrated cost =  12801.820113326732
# RUN  8 , total integrated cost =  12801.82011322926
# RUN  9 , total integrated cost =  12801.820113217605
# RUN  10 , total integrated cost =  12801.820113213425
# RUN  11 , total integrated cost =  12801.820113210351
# RUN  12 , total integrated cost =  12801.820113206495
# RUN  13 , total integrated cost =  12801.820113196889
# RUN  14 , total integrated cost =  12801.820113135065
# RUN  15 , total integrated cost =  12801.763450724484
# RUN  16 , total integrated cost =  12801.754549316089
# RUN  17 , total integrated cost =  12801.754537052424
# RUN  18 , total integrated cost =  12801.754536876755
# RUN  19 , total integrated cost =  12801.754536717157
# RUN  20 , total integrated cost =  12801.75451326308
# RUN  30 , total integrated cost =  12801.740010112775
# Control only changes marginally.
# RUN  32 , total integrated cost =  12801.740010112764
# Improved over  32  iterations in  8.21481108199987  seconds by  0.0006264234514503642  percent.
# cost splitting :  0.0024203161792052974 [3.73932665e+00 2.18487868e-16]
# --------------------- 1
# set cost params:  1.0 0.0 3423.5587859616226
# interpolate adjoint :  True True True
# initial cost =  12801.828514334245
# RUN  0 , total integrated cost =  12801.828514334245
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.828514334245
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.828514334245
# Improved over  1  iterations in  0.3683184900000924  seconds by  0.0  percent.
# cost splitting :  0.0024203161792052974 [3.73932665e+00 2.18487868e-16]
# 20 1785 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 3423.5587859616226
# interpolate adjoint :  True True True
# initial cost =  12801.822645859249
# RUN  0 , total integrated cost =  12801.822645859249
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.822394540479
# RUN  2 , total integrated cost =  12801.82239451077
# RUN  3 , total integrated cost =  12801.822394509869
# RUN  4 , total integrated cost =  12801.82239450985
# RUN  5 , total integrated cost =  12801.822394509845
# RUN  6 , total integrated cost =  12801.822394509838
# RUN  7 , total integrated cost =  12801.822394509834
# RUN  8 , total integrated cost =  12801.822394509834
# Control only changes marginally.
# RUN  8 , total integrated cost =  12801.822394509834
# Improved over  8  iterations in  2.4227522470009717  seconds by  1.9633877315072823e-06  percent.
# cost splitting :  0.0020916154467024786 [3.73932581e+00 2.18487868e-16]
# --------------------- 1
# set cost params:  1.0 0.0 3423.559645155821
# interpolate adjoint :  True True True
# initial cost =  12801.825607316876
# RUN  0 , total integrated cost =  12801.825607316876
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.825607316876
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.825607316876
# Improved over  1  iterations in  0.3580086220008525  seconds by  0.0  percent.
# cost splitting :  0.0020916154467024786 [3.73932581e+00 2.18487868e-16]
# 20 1786 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 3423.559645155821
# interpolate adjoint :  True True True
# initial cost =  12801.820714168653
# RUN  0 , total integrated cost =  12801.820714168653
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.820501039258
# RUN  2 , total integrated cost =  12801.82050103925
# RUN  3 , total integrated cost =  12801.820501039248
# RUN  4 , total integrated cost =  12801.820501039247
# RUN  5 , total integrated cost =  12801.820501039247
# Control only changes marginally.
# RUN  5 , total integrated cost =  12801.820501039247
# Improved over  5  iterations in  1.4775839200010523  seconds by  1.6648366738536424e-06  percent.
# cost splitting :  0.0018422078212000411 [3.73932503e+00 2.18487868e-16]
# --------------------- 1
# set cost params:  1.0 0.0 3423.5604208450695
# interpolate adjoint :  True True True
# initial cost =  12801.823401593474
# RUN  0 , total integrated cost =  12801.823401593474
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.823401593474
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.823401593474
# Improved over  1  iterations in  0.35166583899990655  seconds by  0.0  percent.
# cost splitting :  0.0018422078212000411 [3.73932503e+00 2.18487868e-16]
# 20 1787 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 3423.5604208450695
# interpolate adjoint :  True True True
# initial cost =  12801.819292164691
# RUN  0 , total integrated cost =  12801.819292164691
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.819110616312
# RUN  2 , total integrated cost =  12801.819110616309
# RUN  3 , total integrated cost =  12801.8191106163
# RUN  4 , total integrated cost =  12801.8191106163
# Control only changes marginally.
# RUN  4 , total integrated cost =  12801.8191106163
# Improved over  4  iterations in  1.2237217469992174  seconds by  1.418145245679625e-06  percent.
# cost splitting :  0.0016537232230541925 [3.73932432e+00 2.18487868e-16]
# --------------------- 1
# set cost params:  1.0 0.0 3423.5611226860797
# interpolate adjoint :  True True True
# initial cost =  12801.82173502746
# RUN  0 , total integrated cost =  12801.82173502746
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.82173502746
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.82173502746
# Improved over  1  iterations in  0.3638899069992476  seconds by  0.0  percent.
# cost splitting :  0.0016537232230541925 [3.73932432e+00 2.18487868e-16]
# 20 1788 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 3423.5611226860797
# interpolate adjoint :  True True True
# initial cost =  12801.818258408932
# RUN  0 , total integrated cost =  12801.818258408932
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.818102300165
# RUN  2 , total integrated cost =  12801.81810223163
# RUN  3 , total integrated cost =  12801.818102230838
# RUN  4 , total integrated cost =  12801.818102230834
# RUN  5 , total integrated cost =  12801.818102230834
# Control only changes marginally.
# RUN  5 , total integrated cost =  12801.818102230834
# Improved over  5  iterations in  1.6178158810016612  seconds by  1.2199680838875793e-06  percent.
# cost splitting :  0.001522732838422472 [3.73932364e+00 2.18487868e-16]
# --------------------- 1
# set cost params:  1.0 0.0 3423.5617847834114
# interpolate adjoint :  True True True
# initial cost =  12801.820578027038
# RUN  0 , total integrated cost =  12801.820578027038
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.820578027038
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.820578027038
# Improved over  1  iterations in  0.3943411520012887  seconds by  0.0  percent.
# cost splitting :  0.001522732838422472 [3.73932364e+00 2.18487868e-16]
# 20 1789 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 3423.5617847834114
# interpolate adjoint :  True True True
# initial cost =  12801.817602195613
# RUN  0 , total integrated cost =  12801.817602195613
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.81747492647
# RUN  2 , total integrated cost =  12801.817474913958
# RUN  3 , total integrated cost =  12801.817474913367
# RUN  4 , total integrated cost =  12801.817474913318
# RUN  5 , total integrated cost =  12801.817474913309
# RUN  6 , total integrated cost =  12801.817474913307
# RUN  7 , total integrated cost =  12801.817474913307
# Control only changes marginally.
# RUN  7 , total integrated cost =  12801.817474913307
# Improved over  7  iterations in  2.0650863439987006  seconds by  9.94251834640636e-07  percent.
# cost splitting :  0.001420376126616633 [3.73932303e+00 2.18487868e-16]
# --------------------- 1
# set cost params:  1.0 0.0 3423.562373035307
# interpolate adjoint :  True True True
# initial cost =  12801.819674577164
# RUN  0 , total integrated cost =  12801.819674577164
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.819674577164
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.819674577164
# Improved over  1  iterations in  0.3739315059992805  seconds by  0.0  percent.
# cost splitting :  0.001420376126616633 [3.73932303e+00 2.18487868e-16]
# 20 1790 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 3423.562373035307
# interpolate adjoint :  True True True
# initial cost =  12801.817114078134
# RUN  0 , total integrated cost =  12801.817114078134
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.817004100803
# RUN  2 , total integrated cost =  12801.817004100802
# RUN  3 , total integrated cost =  12801.817004100802
# Control only changes marginally.
# RUN  3 , total integrated cost =  12801.817004100802
# Improved over  3  iterations in  0.9571259439999267  seconds by  8.590759534854442e-07  percent.
# cost splitting :  0.0013479843670024124 [3.73932245e+00 2.18487868e-16]
# --------------------- 1
# set cost params:  1.0 0.0 3423.5629166792696
# interpolate adjoint :  True True True
# initial cost =  12801.819036960878
# RUN  0 , total integrated cost =  12801.819036960878
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.819036960878
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.819036960878
# Improved over  1  iterations in  0.3448072239989415  seconds by  0.0  percent.
# cost splitting :  0.0013479843670024124 [3.73932245e+00 2.18487868e-16]
# 20 1791 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 3423.5629166792696
# interpolate adjoint :  True True True
# initial cost =  12801.816813632238
# RUN  0 , total integrated cost =  12801.816813632238
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.816715213303
# RUN  2 , total integrated cost =  12801.816715177281
# RUN  3 , total integrated cost =  12801.816715176585
# RUN  4 , total integrated cost =  12801.816715176541
# RUN  5 , total integrated cost =  12801.816715176541
# Control only changes marginally.
# RUN  5 , total integrated cost =  12801.816715176541
# Improved over  5  iterations in  1.5794070350002585  seconds by  7.690759673550929e-07  percent.
# cost splitting :  0.0013057365057142494 [3.73932190e+00 2.18487868e-16]
# --------------------- 1
# set cost params:  1.0 0.0 3423.563438710649
# interpolate adjoint :  True True True
# initial cost =  12801.818667219908
# RUN  0 , total integrated cost =  12801.818667219908
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.818667219908
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.818667219908
# Improved over  1  iterations in  0.4157852989992534  seconds by  0.0  percent.
# cost splitting :  0.0013057365057142494 [3.73932190e+00 2.18487868e-16]
# 20 1792 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 3423.563438710649
# interpolate adjoint :  True True True
# initial cost =  12801.816712165306
# RUN  0 , total integrated cost =  12801.816712165306
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.816629846893
# RUN  2 , total integrated cost =  12801.816629391116
# RUN  3 , total integrated cost =  12801.816629385501
# RUN  4 , total integrated cost =  12801.816629385225
# RUN  5 , total integrated cost =  12801.816629385172
# RUN  6 , total integrated cost =  12801.816629385172
# Control only changes marginally.
# RUN  6 , total integrated cost =  12801.816629385172
# Improved over  6  iterations in  1.7907981319985993  seconds by  6.466280240147171e-07  percent.
# cost splitting :  0.0012735124018770688 [3.73932139e+00 2.18487868e-16]
# --------------------- 1
# set cost params:  1.0 0.0 3423.5639085925445
# interpolate adjoint :  True True True
# initial cost =  12801.818386424597
# RUN  0 , total integrated cost =  12801.818386424597
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.818386424595
# RUN  2 , total integrated cost =  12801.818386424595
# Control only changes marginally.
# RUN  2 , total integrated cost =  12801.818386424595
# Improved over  2  iterations in  1.0146043469994765  seconds by  1.4210854715202004e-14  percent.
# cost splitting :  0.0012735124015870773 [3.73932139e+00 2.18487868e-16]
# --------------------- 2
# set cost params:  1.0 0.0 3423.5639085925436
# interpolate adjoint :  True True True
# initial cost =  12801.818386424593
# RUN  0 , total integrated cost =  12801.818386424593
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.818386424593
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.818386424593
# Improved over  1  iterations in  0.4442910790003225  seconds by  0.0  percent.
# cost splitting :  0.0012735124015870773 [3.73932139e+00 2.18487868e-16]
# 20 1793 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 3423.5639085925436
# interpolate adjoint :  True True True
# initial cost =  12801.816656908784
# RUN  0 , total integrated cost =  12801.816656908784
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.816581770594
# RUN  2 , total integrated cost =  12801.816581670346
# RUN  3 , total integrated cost =  12801.81658166823
# RUN  4 , total integrated cost =  12801.816581668036
# RUN  5 , total integrated cost =  12801.816581668034
# RUN  6 , total integrated cost =  12801.816581668034
# Control only changes marginally.
# RUN  6 , total integrated cost =  12801.816581668034
# Improved over  6  iterations in  2.081117526999151  seconds by  5.877349451566261e-07  percent.
# cost splitting :  0.001260108872349653 [3.73932090e+00 2.18487868e-16]
# --------------------- 1
# set cost params:  1.0 0.0 3423.564360954796
# interpolate adjoint :  True True True
# initial cost =  12801.81827319566
# RUN  0 , total integrated cost =  12801.81827319566
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.818273195659
# RUN  2 , total integrated cost =  12801.818273195659
# Control only changes marginally.
# RUN  2 , total integrated cost =  12801.818273195659
# Improved over  2  iterations in  0.9307161420001648  seconds by  1.4210854715202004e-14  percent.
# cost splitting :  0.001260108872234274 [3.73932090e+00 2.18487868e-16]
# --------------------- 2
# set cost params:  1.0 0.0 3423.564360954796
# interpolate adjoint :  True True True
# initial cost =  12801.818273195659
# RUN  0 , total integrated cost =  12801.818273195659
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.818273195659
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.818273195659
# Improved over  1  iterations in  0.4539043410004524  seconds by  0.0  percent.
# cost splitting :  0.001260108872234274 [3.73932090e+00 2.18487868e-16]
# 20 1794 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 3423.564360954796
# interpolate adjoint :  True True True
# initial cost =  12801.816724423285
# RUN  0 , total integrated cost =  12801.816724423285
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.816657288418
# RUN  2 , total integrated cost =  12801.81665726479
# RUN  3 , total integrated cost =  12801.816657262472
# RUN  4 , total integrated cost =  12801.816657262103
# RUN  5 , total integrated cost =  12801.816657262007
# RUN  6 , total integrated cost =  12801.816657261996
# RUN  7 , total integrated cost =  12801.816657261992
# RUN  8 , total integrated cost =  12801.816657261987
# RUN  9 , total integrated cost =  12801.81665726198
# RUN  10 , total integrated cost =  12801.816657261976
# RUN  11 , total integrated cost =  12801.816657261976
# Control only changes marginally.
# RUN  11 , total integrated cost =  12801.816657261976
# Improved over  11  iterations in  3.7377968919990963  seconds by  5.246232603894896e-07  percent.
# cost splitting :  0.0012567573776056614 [3.73932044e+00 2.18487868e-16]
# --------------------- 1
# set cost params:  1.0 0.0 3423.564786778036
# interpolate adjoint :  True True True
# initial cost =  12801.818249551518
# RUN  0 , total integrated cost =  12801.818249551518
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.818249551518
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.818249551518
# Improved over  1  iterations in  0.4448926240002038  seconds by  0.0  percent.
# cost splitting :  0.0012567573776056614 [3.73932044e+00 2.18487868e-16]
# 20 1795 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 3423.564786778036
# interpolate adjoint :  True True True
# initial cost =  12801.816849278937
# RUN  0 , total integrated cost =  12801.816849278937
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.816787123213
# RUN  2 , total integrated cost =  12801.816787120704
# RUN  3 , total integrated cost =  12801.816787120153
# RUN  4 , total integrated cost =  12801.816787119942
# RUN  5 , total integrated cost =  12801.816787119866
# RUN  6 , total integrated cost =  12801.816787119831
# RUN  7 , total integrated cost =  12801.81678711983
# RUN  8 , total integrated cost =  12801.81678711983
# Control only changes marginally.
# RUN  8 , total integrated cost =  12801.81678711983
# Improved over  8  iterations in  2.98185235299934  seconds by  4.855491084754249e-07  percent.
# cost splitting :  0.0012618748763559963 [3.73931999e+00 2.18487868e-16]
# --------------------- 1
# set cost params:  1.0 0.0 3423.565191767515
# interpolate adjoint :  True True True
# initial cost =  12801.818301505087
# RUN  0 , total integrated cost =  12801.818301505087
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.818301505087
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.818301505087
# Improved over  1  iterations in  0.49706872499882593  seconds by  0.0  percent.
# cost splitting :  0.0012618748763559963 [3.73931999e+00 2.18487868e-16]
# 20 1796 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 3423.565191767515
# interpolate adjoint :  True True True
# initial cost =  12801.817022778205
# RUN  0 , total integrated cost =  12801.817022778205
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.816966242386
# RUN  2 , total integrated cost =  12801.816966242384
# RUN  3 , total integrated cost =  12801.816966242377
# RUN  4 , total integrated cost =  12801.816966242377
# Control only changes marginally.
# RUN  4 , total integrated cost =  12801.816966242377
# Improved over  4  iterations in  1.556941109998661  seconds by  4.416234560267185e-07  percent.
# cost splitting :  0.0012732944836388817 [3.73931957e+00 2.18487868e-16]
# --------------------- 1
# set cost params:  1.0 0.0 3423.5655778213286
# interpolate adjoint :  True True True
# initial cost =  12801.818409820957
# RUN  0 , total integrated cost =  12801.818409820957
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.818409820957
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.818409820957
# Improved over  1  iterations in  0.5014118139988568  seconds by  0.0  percent.
# cost splitting :  0.0012732944836388817 [3.73931957e+00 2.18487868e-16]
# 20 1797 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 3423.5655778213286
# interpolate adjoint :  True True True
# initial cost =  12801.817230661032
# ...
# RUN  11 , total integrated cost =  12801.818485756929
# RUN  12 , total integrated cost =  12801.818484229847
# RUN  13 , total integrated cost =  12801.818483806637
# RUN  14 , total integrated cost =  12801.818483789448
# RUN  15 , total integrated cost =  12801.818483786185
# RUN  16 , total integrated cost =  12801.818483783365
# RUN  17 , total integrated cost =  12801.818483777446
# RUN  18 , total integrated cost =  12801.81848373164
# RUN  19 , total integrated cost =  12801.818481177348
# RUN  20 , total integrated cost =  12801.818479944088
# RUN  30 , total integrated cost =  12801.818477875308
# RUN  40 , total integrated cost =  12801.81847241394
# RUN  50 , total integrated cost =  12801.818469924392
# RUN  60 , total integrated cost =  12801.818465983599
# RUN  70 , total integrated cost =  12801.81846245267
# RUN  80 , total integrated cost =  12801.81846093596
# RUN  90 , total integrated cost =  12801.818457755762
# RUN  100 , total integrated cost =  12801.818456170186
# RUN  100 , total integrated cost =  12801.818456170186
# Improved over  100  iterations in  33.2488953330012  seconds by  2.61898563280738e-07  percent.
# cost splitting :  0.0012595001023557584 [3.73924834e+00 2.18487868e-16]
# --------------------- 16
# set cost params:  1.0 0.0 3423.630792841733
# interpolate adjoint :  True True True
# initial cost =  12801.81846828262
# RUN  0 , total integrated cost =  12801.81846828262
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.818468273506
# RUN  2 , total integrated cost =  12801.818468108515
# RUN  3 , total integrated cost =  12801.818466920326
# RUN  4 , total integrated cost =  12801.818466795125
# RUN  5 , total integrated cost =  12801.818466786475
# RUN  6 , total integrated cost =  12801.818466783787
# RUN  7 , total integrated cost =  12801.818466780405
# RUN  8 , total integrated cost =  12801.818466769126
# RUN  9 , total integrated cost =  12801.818466415718
# RUN  10 , total integrated cost =  12801.818465031132
# RUN  11 , total integrated cost =  12801.818464961743
# RUN  12 , total integrated cost =  12801.818464952874
# RUN  13 , total integrated cost =  12801.818464950198
# RUN  14 , total integrated cost =  12801.818464946855
# RUN  15 , total integrated cost =  12801.818464937229
# RUN  16 , total integrated cost =  12801.818464704707
# RUN  17 , total integrated cost =  12801.818463483918
# RUN  18 , total integrated cost =  12801.818463327
# RUN  19 , total integrated cost =  12801.818463315598
# RUN  20 , total integrated cost =  12801.818463312895
# RUN  30 , total integrated cost =  12801.81846129841
# RUN  40 , total integrated cost =  12801.81845847875
# RUN  50 , total integrated cost =  12801.818456824592
# RUN  60 , total integrated cost =  12801.818452767091
# RUN  70 , total integrated cost =  12801.818450377627
# RUN  80 , total integrated cost =  12801.818445710805
# RUN  90 , total integrated cost =  12801.818443381111
# RUN  100 , total integrated cost =  12801.818439704088
# RUN  100 , total integrated cost =  12801.818439704088
# Improved over  100  iterations in  32.44514072500169  seconds by  2.232380609257234e-07  percent.
# cost splitting :  0.0012367728659488499 [3.73924840e+00 2.18487868e-16]
# --------------------- 17
# set cost params:  1.0 0.0 3423.630745298561
# interpolate adjoint :  True True True
# initial cost =  12801.818261928358
# RUN  0 , total integrated cost =  12801.818261928358
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.818258972715
# RUN  2 , total integrated cost =  12801.818258892477
# RUN  3 , total integrated cost =  12801.81825888447
# RUN  4 , total integrated cost =  12801.818258881776
# RUN  5 , total integrated cost =  12801.818258878006
# RUN  6 , total integrated cost =  12801.818258862588
# RUN  7 , total integrated cost =  12801.81825757059
# RUN  8 , total integrated cost =  12801.818254624639
# RUN  9 , total integrated cost =  12801.818254545205
# RUN  10 , total integrated cost =  12801.818254537258
# RUN  11 , total integrated cost =  12801.818254534495
# RUN  12 , total integrated cost =  12801.818254530705
# RUN  13 , total integrated cost =  12801.81825451508
# RUN  14 , total integrated cost =  12801.818253213009
# RUN  15 , total integrated cost =  12801.818250276823
# RUN  16 , total integrated cost =  12801.818250198248
# RUN  17 , total integrated cost =  12801.818250190297
# RUN  18 , total integrated cost =  12801.818250187684
# RUN  19 , total integrated cost =  12801.818250183402
# RUN  20 , total integrated cost =  12801.818250162452
# RUN  30 , total integrated cost =  12801.818211806694
# RUN  40 , total integrated cost =  12801.81821009525
# RUN  50 , total integrated cost =  12801.818054173193
# RUN  60 , total integrated cost =  12801.818044186337
# RUN  70 , total integrated cost =  12801.817196250935
# Control only changes marginally.
# RUN  77 , total integrated cost =  12801.81719624939
# Improved over  77  iterations in  29.456746507999924  seconds by  8.324434432438466e-06  percent.
# cost splitting :  0.0012601863049083316 [3.73924802e+00 2.18487868e-16]
# --------------------- 18
# set cost params:  1.0 0.0 3423.631087149026
# interpolate adjoint :  True True True
# initial cost =  12801.818474513066
# RUN  0 , total integrated cost =  12801.818474513066
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.818474513066
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.818474513066
# Improved over  1  iterations in  0.45927637799832155  seconds by  0.0  percent.
# cost splitting :  0.0012601863049083316 [3.73924802e+00 2.18487868e-16]
# 20 1826 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 3423.631087149026
# interpolate adjoint :  True True True
# initial cost =  12801.816008462683
# RUN  0 , total integrated cost =  12801.816008462683
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.815901339585
# RUN  2 , total integrated cost =  12801.815901339565
# RUN  3 , total integrated cost =  12801.815901339565
# Control only changes marginally.
# RUN  3 , total integrated cost =  12801.815901339565
# Improved over  3  iterations in  1.3626365570016787  seconds by  8.367806429987468e-07  percent.
# cost splitting :  0.0011814073142024793 [3.73924750e+00 2.18487868e-16]
# --------------------- 1
# set cost params:  1.0 0.0 3423.631585583341
# interpolate adjoint :  True True True
# initial cost =  12801.817765108832
# RUN  0 , total integrated cost =  12801.817765108832
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.817765108832
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.817765108832
# Improved over  1  iterations in  0.4865475719998358  seconds by  0.0  percent.
# cost splitting :  0.0011814073142024793 [3.73924750e+00 2.18487868e-16]
# 20 1827 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 3423.631585583341
# interpolate adjoint :  True True True
# initial cost =  12801.815666736738
# RUN  0 , total integrated cost =  12801.815666736738
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.815574115
# RUN  2 , total integrated cost =  12801.815574025448
# RUN  3 , total integrated cost =  12801.815574021519
# RUN  4 , total integrated cost =  12801.81557402102
# RUN  5 , total integrated cost =  12801.815574020966
# RUN  6 , total integrated cost =  12801.815574020935
# RUN  7 , total integrated cost =  12801.81557402093
# RUN  8 , total integrated cost =  12801.815574020928
# RUN  9 , total integrated cost =  12801.815574020928
# Control only changes marginally.
# RUN  9 , total integrated cost =  12801.815574020928
# Improved over  9  iterations in  3.3623382529985975  seconds by  7.242395412276892e-07  percent.
# cost splitting :  0.001132357325228249 [3.73924700e+00 2.18487868e-16]
# --------------------- 1
# set cost params:  1.0 0.0 3423.632053892365
# interpolate adjoint :  True True True
# initial cost =  12801.817325144044
# RUN  0 , total integrated cost =  12801.817325144044
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.817325144044
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.817325144044
# Improved over  1  iterations in  0.4467638389978674  seconds by  0.0  percent.
# cost splitting :  0.001132357325228249 [3.73924700e+00 2.18487868e-16]
# 20 1828 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 3423.632053892365
# interpolate adjoint :  True True True
# initial cost =  12801.815513532563
# RUN  0 , total integrated cost =  12801.815513532563
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.815435743638
# RUN  2 , total integrated cost =  12801.815435716231
# RUN  3 , total integrated cost =  12801.815435712979
# RUN  4 , total integrated cost =  12801.81543571207
# RUN  5 , total integrated cost =  12801.815435711684
# RUN  6 , total integrated cost =  12801.81543571145
# RUN  7 , total integrated cost =  12801.815435711289
# RUN  8 , total integrated cost =  12801.815435711143
# RUN  9 , total integrated cost =  12801.815435711025
# RUN  10 , total integrated cost =  12801.815435710903
# RUN  11 , total integrated cost =  12801.815435710761
# RUN  12 , total integrated cost =  12801.815435710576
# RUN  13 , total integrated cost =  12801.815435710254
# RUN  14 , total integrated cost =  12801.815435709721
# RUN  15 , total integrated cost =  12801.8154357087
# RUN  16 , total integrated cost =  12801.815435704963
# RUN  17 , total integrated cost =  12801.81543566608
# RUN  18 , total integrated cost =  12801.815428266364
# RUN  19 , total integrated cost =  12801.815424300912
# RUN  20 , total integrated cost =  12801.815424284685
# RUN  30 , total integrated cost =  12801.815424280503
# RUN  40 , total integrated cost =  12801.815422150894
# RUN  50 , total integrated cost =  12801.815422128215
# RUN  60 , total integrated cost =  12801.81541288901
# RUN  70 , total integrated cost =  12801.815410487794
# RUN  80 , total integrated cost =  12801.81541048437
# RUN  90 , total integrated cost =  12801.815408030676
# RUN  100 , total integrated cost =  12801.81540801632
# RUN  100 , total integrated cost =  12801.81540801632
# Improved over  100  iterations in  34.428682273999584  seconds by  8.24228735041288e-07  percent.
# cost splitting :  0.0010938110641104447 [3.73924656e+00 2.18487868e-16]
# --------------------- 1
# set cost params:  1.0 0.0 3423.6324743517525
# interpolate adjoint :  True True True
# initial cost =  12801.816980217636
# RUN  0 , total integrated cost =  12801.816980217636
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.816979807114
# RUN  2 , total integrated cost =  12801.816977979723
# RUN  3 , total integrated cost =  12801.81697783795
# RUN  4 , total integrated cost =  12801.816977833963
# RUN  5 , total integrated cost =  12801.816977832936
# RUN  6 , total integrated cost =  12801.816977832472
# RUN  7 , total integrated cost =  12801.81697783222
# RUN  8 , total integrated cost =  12801.816977832072
# RUN  9 , total integrated cost =  12801.816977831935
# RUN  10 , total integrated cost =  12801.816977831819
# RUN  11 , total integrated cost =  12801.816977831679
# RUN  12 , total integrated cost =  12801.8169778315
# RUN  13 , total integrated cost =  12801.816977831213
# RUN  14 , total integrated cost =  12801.816977830667
# RUN  15 , total integrated cost =  12801.81697782912
# RUN  16 , total integrated cost =  12801.816977822707
# RUN  17 , total integrated cost =  12801.81697769218
# RUN  18 , total integrated cost =  12801.81697601375
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_8629/3503758196.py in <module>
#      47             weights_[i][j] = cost.getParams()
#      48
# ---> 49             bestControl_[i][j], bestState_[i][j], cost_[i][j], runtime_, grad_, phi_, phi1_, costnode_[i][j] = aln.A1(
#      50                 control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
#      51                 startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
#
# ~/Promotion/neurolib/neurolib/models/model.py in A1(self, control_, target_state_, c_scheme_, u_mat_, u_scheme_, max_iteration_, tolerance_, startStep_, max_control_, min_control_, t_sim_, t_sim_pre_, t_sim_post_, CGVar, line_search_, control_variables_, prec_variables_, separate_comp, transition_time_, noise_real, init_params)
#     661             if self.params.N == 1:
#     662                 if noise_real == 0:
# --> 663                     return opti1_rate_control.A1(self, control_, target_state_, c_scheme_, u_mat_, u_scheme_, max_iteration_,
#     664                                                 tolerance_, startStep_, max_control_, min_control_, t_sim_, t_sim_pre_, t_sim_post_, CGVar,
#     665                                                 line_search_, control_variables_, prec_variables_, separate_comp, transition_time_)
#
# ~/Promotion/neurolib/neurolib/utils/A1_aln_rate_control.py in A1(model, control_, target_state, c_scheme_, u_mat_, u_scheme_, max_iteration_, tolerance_, startStep_, cntrl_max_, cntrl_min_, t_sim_, t_sim_pre_, t_sim_post_, CGVar, line_search_, control_variables_, prec_variables_, separate_comp, transition_time_)
#     384                 d_exc[:,1:,:] = 0.
#     385
# --> 386                 s_exc, tc_exc, startstep_exc_ = line_search_func(model, N, n_control_vars, T, dt, state1_[:,:2,:], target_state_,
#     387                              best_control_, d_exc, ip_, ie_, is_, start_step_ = startstep_exc_, max_it_ = 500,
#     388                              max_control_ = cntrl_max_, min_control_ = cntrl_min_, tolerance_ = tolerance_step, variables_ = prec_variables, grad_ = grad1_)
#
# ~/Promotion/neurolib/neurolib/utils/func_optimize.py in step_size(model, N, V, T, dt, state_, target_, control_, dir_, ip_, ie_, is_, start_step_, max_it_, bisec_factor_, max_control_, min_control_, tolerance_, substep_, variables_, alg, control_parameter, grad_, noise_real, init_vars, startind_)
#     233                 #print(init_vars)
#     234                 set_init(model, init_vars, model.init_vars, model.state_vars, startind_)
# --> 235             state1_ = updateState(model, test_control_)
#     236             cost1_int_ = cost.f_int(N, V, T, dt, state1_, target_, test_control_, ip_, ie_, is_, v_ = variables_)
#     237         else:
#
# ~/Promotion/neurolib/neurolib/utils/func_optimize.py in updateState(model, control_)
#       8     state_ = model.getZeroState()
#       9     output_vars = model.output_vars
# ---> 10     model.run(control = control_)
#      11     for i in range(len(output_vars)):
#      12         state_[:,i,:] = model[output_vars[i]][:,:]
#
# ~/Promotion/neurolib/neurolib/models/model.py in run(self, inputs, chunkwise, chunksize, bold, append, append_outputs, continue_run, control)
#     182
#     183         if chunkwise is False:
# --> 184             self.integrate(append_outputs=append, simulate_bold=bold, control=cntrl)
#     185             if continue_run:
#     186                 self.setInitialValuesToLastState()
#
# ~/Promotion/neurolib/neurolib/models/model.py in integrate(self, append_outputs, simulate_bold, control)
#     223         # run integration
#     224         #print("before integration")
# --> 225         t, *variables = self.integration(self.params, control=control)
#     226         #print("after integration")
#     227         self.storeOutputsAndStates(t, variables, append=append_outputs)
#
# ~/Promotion/neurolib/neurolib/models/aln/timeIntegration.py in timeIntegration(params, control)
#     270
#     271     # tile external inputs to appropriate shape
# --> 272     ext_exc_current = adjust_shape(params["ext_exc_current"], rates_exc)
#     273     ext_inh_current = adjust_shape(params["ext_inh_current"], rates_exc)
#     274     ext_ee_rate = adjust_shape(params["ext_ee_rate"], rates_exc)
#
# ~/Promotion/neurolib/neurolib/models/aln/timeIntegration.py in adjust_shape(original, target)
#     921     # tile until t
#     922
# --> 923     if target.shape[1] > original.shape[1]:
#     924         rep_x = int(target.shape[1] / original.shape[1]) + 1
#     925     else:
#
# KeyboardInterrupt:

# %%
i = 20
for j in range(1100,1800,100):
    print("simulation duration = ", round(d_array[j],1))
    print("cost splitting: ", costnode_[i][j][0][0][0], costnode_[i][j][2][0][:2])
    print("total cost: ", sum(costnode_[i][j][0][0][:] + costnode_[i][j][2][0][:2]) )
    T = bestControl_[i][j].shape[2]
    max_percent = (np.argmax(np.abs(bestControl_[i][j]), axis=2)[0,1] -100) / (T-201)
    print(max_percent)
    
    aln.params.duration = round(d_array[j],1)
    time_ = np.arange(-dur_pre,round(d_array[j]+dur_post+aln.params.dt,1),aln.params.dt)
    dur += dur_pre + dur_post
    target_e = [target[i][0]] * len(time_)
    target_i = [target[i][1]] * len(time_)

    fig, ax = plt.subplots(2,1, constrained_layout=True, figsize = (4,4) )
    ax[1].plot(time_, bestControl_[i][j][0,0,:], color = 'red')
    ax[0].plot(time_, bestState_[i][j][0,0,:], color= 'red')
    ax[1].plot(time_, bestControl_[i][j][0,1,:], color = 'blue')
    ax[0].plot(time_, bestState_[i][j][0,1,:], color= 'blue')
    ax[0].plot(time_, target_e, linestyle = '--', color='red')
    ax[0].plot(time_, target_i, linestyle = '--', color='blue')
    ax[0].set_xlim(-dur_pre,round(d_array[j]+dur_pre,1))
    ax[1].set_xlim(-dur_pre,round(d_array[j]+dur_pre,1))
    ax[0].axvspan(t0_array[j], t0_array[j]+20, alpha=0.2, color='gray')
    plt.show()
# Out:
# simulation duration =  130.0
# cost splitting:  0.2414870148430566 [3.76513336e+00 2.67452706e-16]
# total cost:  4.006620377119976
# 0.26461538461538464
# simulation duration =  140.0
# cost splitting:  0.12779252157425425 [3.75492942e+00 1.58622311e-16]
# total cost:  3.882721940436779
# 0.28285714285714286
# simulation duration =  150.0
# cost splitting:  0.07099858126581138 [3.74824829e+00 2.31077090e-16]
# total cost:  3.819246874258925
# 0.31933333333333336
# simulation duration =  160.0
# cost splitting:  0.03316653456714479 [3.74411760e+00 1.68730596e-16]
# total cost:  3.7772841361667404
# 0.286875
# simulation duration =  170.0
# cost splitting:  0.015268558065836612 [3.74175510e+00 1.68730596e-16]
# total cost:  3.7570236599306415
# 0.27
# simulation duration =  180.0
# cost splitting:  0.007246824913881769 [3.74041257e+00 2.18487868e-16]
# total cost:  3.7476593953563366
# 0.29555555555555557
# simulation duration =  190.0
# cost splitting:  0.0031675650574709445 [3.73965053e+00 2.18487868e-16]
# total cost:  3.7428180913944264
# 0.28
