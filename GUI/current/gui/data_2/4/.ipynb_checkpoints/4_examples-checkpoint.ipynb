# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import sys
import pickle

path = os.getcwd().split(os.sep + 'GUI')[0]
if path not in sys.path:
    print("not here")
    sys.path.append(path)

from neurolib.models.aln import ALNModel
from neurolib.utils import plotFunctions as plotFunc
from neurolib.utils import costFunctions as cost
import neurolib.dashboard.functions as functions
import neurolib.dashboard.data as data
    
# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2 

#path = os.path.join(os.getcwd(), "plots")
# Out:
# not here

# %%
grid_data_file = os.path.join(os.getcwd().split('data')[0], 'bi.pickle')
print(grid_data_file)
with open(grid_data_file,'rb') as f:
    load_array= pickle.load(f)
exc = load_array[0]
inh = load_array[1]
print(len(exc))
case = '1'
# Out:
# /home/lena/Promotion/neurolib/GUI/current/gui/bi.pickle
# 147

# %% [markdown]
# ### Bistability

# %%
aln = ALNModel()
N = aln.params.N

data.set_parameters(aln)

state_vars = aln.state_vars
init_vars = aln.init_vars

##############################################################
def setinit(init_vars_, model):
    state_vars = model.state_vars
    init_vars = model.init_vars
    for iv in range(len(init_vars)):
        for sv in range(len(state_vars)):
            if state_vars[sv] in init_vars[iv]:
                #print("set init vars ", )
                if model.params[init_vars[iv]].ndim == 2:
                    model.params[init_vars[iv]][0,:] = init_vars_[sv]
                else:
                    model.params[init_vars[iv]][0] = init_vars_[sv]
                    
##############################################################               
def setmaxmincontrol(max_c_c, min_c_c, max_c_r, min_c_r):
    import numpy as np
    
    max_cntrl = np.zeros(( 6 ))
    min_cntrl = np.zeros(( 6 ))
    
    max_cntrl[0] = max_c_c
    min_cntrl[0] = min_c_c
    max_cntrl[1] = max_c_c
    min_cntrl[1] = min_c_c
    max_cntrl[2] = max_c_r
    min_cntrl[2] = min_c_r
    max_cntrl[3] = max_c_r
    min_cntrl[3] = min_c_r
    max_cntrl[4] = max_c_r
    min_cntrl[4] = min_c_r
    max_cntrl[5] = max_c_r
    min_cntrl[5] = min_c_r
            
    return max_cntrl, min_cntrl

# %%
d_array = np.arange(500., 20, -0.1)
t0_array = d_array - 100.
t_pen = np.zeros(( t0_array.shape ))
for i in range(len(t_pen)):
    t_pen[i] = t0_array[i] / d_array[i]

# %%
bestControl_ = np.array( [[None] * len(t_pen)] * len(exc) )
bestState_ = np.array( [[None] * len(t_pen)] * len(exc) )
cost_ = np.array( [[None] * len(t_pen)] * len(exc) )
costnode_ = np.array( [[None] * len(t_pen)] * len(exc) )
weights_ = np.array( [[None] * len(t_pen)] * len(exc) )
convergence_ = np.array( [[None] * len(t_pen)] * len(exc) )

initVars = [None] * len(exc)
target = [None] * len(exc)
cost_uncontrolled = [None] * len(exc)
ws = [None] * len(exc)
conv = [None] * len(exc)
conv_shift = [None] * len(exc)

print(bestControl_.shape)
# Out:
# (147, 4800)

# %%
file_ = '4_examples.pickle'
case = '1'

# %%
dur_pre = 10
dur_post = 10

n_pre = int(np.around(dur_pre/aln.params.dt + 1.,1))
n_post = int(np.around(dur_post/aln.params.dt + 1.,1))

tol = 1e-32
start_step = 100.
c_scheme = np.zeros(( 1,1 ))
c_scheme[0,0] = 1.
u_mat = np.identity(1)
u_scheme = np.array([[1.]])

c_var = [0,1]
p_var = [0]

if case in ['1', '2']:    # low to high
    max_I = [3., -3.]
else:
    max_I = [-3., 3.]
    
if case in ['1', '3']:    # sparsity
    factor_ws = 1.
    factor_we = 0.
else:
    factor_ws = 0.
    factor_we = 1.
    
maxC = [5., -5., 0.18, 0.]
max_cntrl, min_cntrl = setmaxmincontrol(maxC[0], maxC[1], maxC[2], maxC[3])

# %%
if os.path.isfile(file_) :
    print("file found")
    
    with open(file_,'rb') as f:
        load_array = pickle.load(f)

    bestControl_[20][i] = load_array[0][20][i]
    bestState_[20][i] = load_array[1][20][i]
    cost_[20][i] = load_array[2][20][i]
    costnode_[20][i] = load_array[3][20][i]
    weights_[20][i] = load_array[4][20][i]
# Out:
# file found

# %%
file_opt = 'control_1.pickle'
if os.path.isfile(file_opt) :
    print("opt file found")
    
    with open(file_opt,'rb') as f:
        load_array = pickle.load(f)

    bestControl_opt = load_array[0][35]
    bestState_opt = load_array[1][35]
    cost_opt = load_array[2][35]
    costnode_opt = load_array[3][35]
    
print(bestControl_opt.shape)
# Out:
# opt file found
# (1, 6, 4201)

# %%
# get initial parameters and target states

#i_stepsize = 20
#limit = 150
#start_index = 0
#i_range = range(start_index, limit,i_stepsize)
i_range = [20,50]

data.set_parameters(aln)

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    aln.params.duration = 3000.
    
    control0 = aln.getZeroControl()
    control0 = functions.step_control(aln, maxI_ = max_I[0])

    aln.run(control=control0)
    
    target_rates = np.zeros((2))
    target_rates[0] = aln.rates_exc[0,-1] 
    target_rates[1] = aln.rates_inh[0,-1]

    control0 = functions.step_control(aln, maxI_ = max_I[1])
    aln.run(control=control0)

    init_state_vars = np.zeros(( len(state_vars) ))
    for j in range(len(state_vars)):
        if aln.state[state_vars[j]].size == 1:
            init_state_vars[j] = aln.state[state_vars[j]][0]
        else:
            init_state_vars[j] = aln.state[state_vars[j]][0,-1]

    initVars[i] = init_state_vars
    target[i] = [target_rates[0], target_rates[1]]
# Out:
# -------  20 0.4500000000000001 0.4750000000000002
# -------  50 0.47500000000000014 0.6000000000000003

# %%
# get uncontrolled cost

data.set_parameters(aln)

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    dur = d_array[0]
    aln.params.duration = dur
    
    target_ = aln.getZeroTarget()
    target_[:,0,:] = target[i][0]
    target_[:,1,:] = target[i][1]
            
    cost.setParams(1.0, 0.0, 0.0)

    setinit(initVars[i], aln)
    control0 = aln.getZeroControl()

    # "HS", "FR", "PR", "HZ"
    cgv = None
    max_it = 0

    bestControl_init_, bestState_init_, cost_init_, runtime_init_, grad_init_, phi_init_, phi1_, costnode_init_ = aln.A1(
        control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
        prec_variables_ = p_var, transition_time_ = t_pen[0])
    
    cost_uncontrolled[i] = cost_init_[0]
# Out:
# -------  20 0.4500000000000001 0.4750000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  318198.4034356064
# RUN  0 , total integrated cost =  318198.4034356064
# Gradient descend method:  None
# RUN  0 , total integrated cost =  318198.4034356064
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  50 0.47500000000000014 0.6000000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  398255.3453337311
# RUN  0 , total integrated cost =  398255.3453337311
# Gradient descend method:  None
# RUN  0 , total integrated cost =  398255.3453337311
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.

# %%
cgv = None
j = 0

dur = 500.
t0__ = 480.
t0_ = t0__ / dur
cvar = [0,1]

wp = 1.


for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.


    aln.params.duration = dur
    setinit(initVars[i], aln)

    target_ = aln.getZeroTarget()
    target_[:,0,:] = target[i][0]
    target_[:,1,:] = target[i][1]

    control0 = aln.getZeroControl()
    cost.setParams(wp, 0., ws[i])
    max_it = int(10)

    bestControl_[i][j], bestState_[i][j], cost_[i][j], runtime_, grad_, phi_, phi1_, costnode_[i][j] = aln.A1(
        control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cvar,
        prec_variables_ = p_var, transition_time_ = t0_)          

    print('uncontrolled cost : ', cost_uncontrolled[i])
    print('cost splitting : ', costnode_[i][j][0][0][0], costnode_[i][j][2][0][:2])


    if True:
        plot_time_array = np.arange(0.,round(dur+aln.params.dt,1),aln.params.dt)
        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]


        fig, ax = plt.subplots(3,1, constrained_layout=True, figsize = (4,8) )
        ax[1].plot(plot_time_array, bestControl_[i][j][0,0,n_pre-1:-n_post+1], color = 'red')
        ax[0].plot(plot_time_array, bestState_[i][j][0,0,n_pre-1:-n_post+1], color= 'red')
        ax[1].plot(plot_time_array, bestControl_[i][j][0,1,n_pre-1:-n_post+1], color = 'blue')
        ax[0].plot(plot_time_array, bestState_[i][j][0,1,n_pre-1:-n_post+1], color= 'blue')
        ax[0].plot(plot_time_array, target_[0,0,n_pre-1:-n_post+1], linestyle = '--', color='red')
        ax[0].plot(plot_time_array, target_[0,1,n_pre-1:-n_post+1], linestyle = '--', color='blue')


        ax[2].plot(plot_time_array, phi_[0,0,:], color = 'red')
        ax[2].plot(plot_time_array, phi_[0,1,:], color = 'blue')
        for k in range(3):
            ax[k].set_xlim(0.,dur)
            ax[k].axvspan(dur*t0_, dur, alpha=0.2, color='gray')

        plt.show()
# Out:
# -------  0 0.4000000000000001 0.3500000000000001
# set cost params:  1.0 0.0 100000.0
# interpolate adjoint :  True True True
# initial cost =  146855.39702821904
# RUN  0 , total integrated cost =  146855.39702821904
# Gradient descend method:  None
# RUN  1 , total integrated cost =  146855.39702821904
# Control only changes marginally.
# RUN  1 , total integrated cost =  146855.39702821904
# Improved over  1  iterations in  0.6084295139880851  seconds by  0.0  percent.
# set cost params:  1.0 0.0 10000.0
# interpolate adjoint :  True True True
# initial cost =  146855.39702821904
# RUN  0 , total integrated cost =  146855.39702821904
# Gradient descend method:  None
# RUN  1 , total integrated cost =  43990.56161123629
# RUN  2 , total integrated cost =  20530.976668443873
# RUN  3 , total integrated cost =  17457.500552754642
# RUN  4 , total integrated cost =  16258.716822601047
# RUN  5 , total integrated cost =  15534.760181178319
# RUN  6 , total integrated cost =  15141.37369268891
# RUN  7 , total integrated cost =  14854.30099492291
# RUN  8 , total integrated cost =  14656.275693954276
# RUN  9 , total integrated cost =  14495.13528389298
# RUN  10 , total integrated cost =  14378.616347370376
# RUN  10 , total integrated cost =  14378.616347370376
# Improved over  10  iterations in  1.6655986309924629  seconds by  90.20899698728304  percent.
# uncontrolled cost :  147442.23178157862
# cost splitting :  13.32197783021337 [5.80137792e-15 1.40471576e+00]
# set cost params:  1.0 0.0 90000.0
# interpolate adjoint :  True True True
# initial cost =  146855.39702821904
# RUN  0 , total integrated cost =  146855.39702821904
# Gradient descend method:  None
# RUN  1 , total integrated cost =  146855.39702821904
# Control only changes marginally.
# RUN  1 , total integrated cost =  146855.39702821904
# Improved over  1  iterations in  0.6034842710068915  seconds by  0.0  percent.
# uncontrolled cost :  147442.23178157862
# cost splitting :  5902.406479238558 [0. 0.]
# set cost params:  1.0 0.0 80000.0
# interpolate adjoint :  True True True
# initial cost =  146855.39702821904
# RUN  0 , total integrated cost =  146855.39702821904
# Gradient descend method:  None
# RUN  1 , total integrated cost =  146855.39702821904
# Control only changes marginally.
# RUN  1 , total integrated cost =  146855.39702821904
# Improved over  1  iterations in  0.6199515780026559  seconds by  0.0  percent.
# uncontrolled cost :  147442.23178157862
# cost splitting :  5902.406479238558 [0. 0.]
# set cost params:  1.0 0.0 70000.0
# interpolate adjoint :  True True True
# initial cost =  146855.39702821904
# RUN  0 , total integrated cost =  146855.39702821904
# Gradient descend method:  None
# RUN  1 , total integrated cost =  145665.54292192016
# RUN  2 , total integrated cost =  130820.17826947544
# RUN  3 , total integrated cost =  113966.61876875356
# RUN  4 , total integrated cost =  110191.63967221028
# RUN  5 , total integrated cost =  105487.32415741653
# RUN  6 , total integrated cost =  102502.72760266364
# RUN  7 , total integrated cost =  99085.84420130175
# RUN  8 , total integrated cost =  97075.97905697755
# RUN  9 , total integrated cost =  94832.9100923936
# RUN  10 , total integrated cost =  93377.22584060916
# RUN  10 , total integrated cost =  93377.22584060916
# Improved over  10  iterations in  1.789299600000959  seconds by  36.41553001782684  percent.
# uncontrolled cost :  147442.23178157862
# cost splitting :  102.54674436041846 [0.19344751 1.10406394]
# set cost params:  1.0 0.0 79000.0
# interpolate adjoint :  True True True
# initial cost =  146855.39702821904
# RUN  0 , total integrated cost =  146855.39702821904
# Gradient descend method:  None
# RUN  1 , total integrated cost =  146855.39702821904
# Control only changes marginally.
# RUN  1 , total integrated cost =  146855.39702821904
# Improved over  1  iterations in  0.6448679470049683  seconds by  0.0  percent.
# uncontrolled cost :  147442.23178157862
# cost splitting :  5902.406479238558 [0. 0.]
# set cost params:  1.0 0.0 78000.0
# interpolate adjoint :  True True True
# initial cost =  146855.39702821904
# RUN  0 , total integrated cost =  146855.39702821904
# Gradient descend method:  None
# RUN  1 , total integrated cost =  146855.39702821904
# Control only changes marginally.
# RUN  1 , total integrated cost =  146855.39702821904
# Improved over  1  iterations in  0.6140073270071298  seconds by  0.0  percent.
# uncontrolled cost :  147442.23178157862
# cost splitting :  5902.406479238558 [0. 0.]
# set cost params:  1.0 0.0 77000.0
# interpolate adjoint :  True True True
# initial cost =  146855.39702821904
# RUN  0 , total integrated cost =  146855.39702821904
# Gradient descend method:  None
# RUN  1 , total integrated cost =  146855.39702821904
# Control only changes marginally.
# RUN  1 , total integrated cost =  146855.39702821904
# Improved over  1  iterations in  0.7326697359967511  seconds by  0.0  percent.
# uncontrolled cost :  147442.23178157862
# cost splitting :  5902.406479238558 [0. 0.]
# set cost params:  1.0 0.0 76000.0
# interpolate adjoint :  True True True
# initial cost =  146855.39702821904
# RUN  0 , total integrated cost =  146855.39702821904
# Gradient descend method:  None
# RUN  1 , total integrated cost =  146855.39702821904
# Control only changes marginally.
# RUN  1 , total integrated cost =  146855.39702821904
# Improved over  1  iterations in  0.8499752770003397  seconds by  0.0  percent.
# uncontrolled cost :  147442.23178157862
# cost splitting :  5902.406479238558 [0. 0.]
# set cost params:  1.0 0.0 75000.0
# interpolate adjoint :  True True True
# initial cost =  146855.39702821904
# RUN  0 , total integrated cost =  146855.39702821904
# Gradient descend method:  None
# RUN  1 , total integrated cost =  146855.39702821904
# Control only changes marginally.
# RUN  1 , total integrated cost =  146855.39702821904
# Improved over  1  iterations in  0.8717024850193411  seconds by  0.0  percent.
# uncontrolled cost :  147442.23178157862
# cost splitting :  5902.406479238558 [0. 0.]
# set cost params:  1.0 0.0 74000.0
# interpolate adjoint :  True True True
# initial cost =  146855.39702821904
# RUN  0 , total integrated cost =  146855.39702821904
# Gradient descend method:  None
# RUN  1 , total integrated cost =  146855.39702821904
# Control only changes marginally.
# RUN  1 , total integrated cost =  146855.39702821904
# Improved over  1  iterations in  0.8352285140135791  seconds by  0.0  percent.
# uncontrolled cost :  147442.23178157862
# cost splitting :  5902.406479238558 [0. 0.]
# set cost params:  1.0 0.0 73000.0
# interpolate adjoint :  True True True
# initial cost =  146855.39702821904
# RUN  0 , total integrated cost =  146855.39702821904
# Gradient descend method:  None
# RUN  1 , total integrated cost =  146855.39702821904
# Control only changes marginally.
# RUN  1 , total integrated cost =  146855.39702821904
# Improved over  1  iterations in  0.8332149510097224  seconds by  0.0  percent.
# uncontrolled cost :  147442.23178157862
# cost splitting :  5902.406479238558 [0. 0.]
# set cost params:  1.0 0.0 72000.0
# interpolate adjoint :  True True True
# initial cost =  146855.39702821904
# RUN  0 , total integrated cost =  146855.39702821904
# Gradient descend method:  None
# RUN  1 , total integrated cost =  146855.39702821904
# Control only changes marginally.
# RUN  1 , total integrated cost =  146855.39702821904
# Improved over  1  iterations in  0.8113525839871727  seconds by  0.0  percent.
# uncontrolled cost :  147442.23178157862
# cost splitting :  5902.406479238558 [0. 0.]
# set cost params:  1.0 0.0 71000.0
# interpolate adjoint :  True True True
# initial cost =  146855.39702821904
# RUN  0 , total integrated cost =  146855.39702821904
# Gradient descend method:  None
# RUN  1 , total integrated cost =  146855.39702821904
# Control only changes marginally.
# RUN  1 , total integrated cost =  146855.39702821904
# Improved over  1  iterations in  0.8076285400020424  seconds by  0.0  percent.
# uncontrolled cost :  147442.23178157862
# cost splitting :  5902.406479238558 [0. 0.]
# set cost params:  1.0 0.0 70000.0
# interpolate adjoint :  True True True
# initial cost =  146855.39702821904
# RUN  0 , total integrated cost =  146855.39702821904
# Gradient descend method:  None
# RUN  1 , total integrated cost =  145665.54292192016
# RUN  2 , total integrated cost =  130820.17826947544
# RUN  3 , total integrated cost =  113966.61876875356
# RUN  4 , total integrated cost =  110191.63967221028
# RUN  5 , total integrated cost =  105487.32415741653
# RUN  6 , total integrated cost =  102502.72760266364
# RUN  7 , total integrated cost =  99085.84420130175
# RUN  8 , total integrated cost =  97075.97905697755
# RUN  9 , total integrated cost =  94832.9100923936
# RUN  10 , total integrated cost =  93377.22584060916
# RUN  10 , total integrated cost =  93377.22584060916
# Improved over  10  iterations in  2.419875237013912  seconds by  36.41553001782684  percent.
# sparsity weight =  70000.0
# -------  1 0.4250000000000001 0.3500000000000001
# set cost params:  1.0 0.0 100000.0
# interpolate adjoint :  True True True
# initial cost =  244234.70503349282
# RUN  0 , total integrated cost =  244234.70503349282
# Gradient descend method:  None
# RUN  1 , total integrated cost =  151746.4468337936
# RUN  2 , total integrated cost =  146317.0431420479
# RUN  3 , total integrated cost =  144160.2209231326
# RUN  4 , total integrated cost =  104751.8792256547
# RUN  5 , total integrated cost =  86407.48985244983
# RUN  6 , total integrated cost =  55730.11638018009
# RUN  7 , total integrated cost =  54950.32821099555
# RUN  8 , total integrated cost =  54699.8132216113
# RUN  9 , total integrated cost =  54327.83750958388
# RUN  10 , total integrated cost =  54102.81720995294
# RUN  10 , total integrated cost =  54102.81720995294
# Improved over  10  iterations in  3.4006656899873633  seconds by  77.8480223756351  percent.
# uncontrolled cost :  245210.66789076867
# cost splitting :  10.083421502641203 [3.60003670e-14 5.38519357e-01]
# set cost params:  1.0 0.0 900000.0
# interpolate adjoint :  True True True
# initial cost =  244234.70503349282
# RUN  0 , total integrated cost =  244234.70503349282
# Gradient descend method:  None
# RUN  1 , total integrated cost =  244234.70503349282
# Control only changes marginally.
# RUN  1 , total integrated cost =  244234.70503349282
# Improved over  1  iterations in  0.8049018699966837  seconds by  0.0  percent.
# uncontrolled cost :  245210.66789076867
# cost splitting :  9816.271887968818 [0. 0.]
# set cost params:  1.0 0.0 800000.0
# interpolate adjoint :  True True True
# initial cost =  244234.70503349282
# RUN  0 , total integrated cost =  244234.70503349282
# Gradient descend method:  None
# RUN  1 , total integrated cost =  244234.70503349282
# Control only changes marginally.
# RUN  1 , total integrated cost =  244234.70503349282
# Improved over  1  iterations in  0.8185368459962774  seconds by  0.0  percent.
# uncontrolled cost :  245210.66789076867
# cost splitting :  9816.271887968818 [0. 0.]
# set cost params:  1.0 0.0 700000.0
# interpolate adjoint :  True True True
# initial cost =  244234.70503349282
# RUN  0 , total integrated cost =  244234.70503349282
# Gradient descend method:  None
# RUN  1 , total integrated cost =  244234.70503349282
# Control only changes marginally.
# RUN  1 , total integrated cost =  244234.70503349282
# Improved over  1  iterations in  0.7930803430208471  seconds by  0.0  percent.
# uncontrolled cost :  245210.66789076867
# cost splitting :  9816.271887968818 [0. 0.]
# set cost params:  1.0 0.0 600000.0
# interpolate adjoint :  True True True
# initial cost =  244234.70503349282
# RUN  0 , total integrated cost =  244234.70503349282
# Gradient descend method:  None
# RUN  1 , total integrated cost =  244234.70503349282
# Control only changes marginally.
# RUN  1 , total integrated cost =  244234.70503349282
# Improved over  1  iterations in  0.837665469996864  seconds by  0.0  percent.
# uncontrolled cost :  245210.66789076867
# cost splitting :  9816.271887968818 [0. 0.]
# set cost params:  1.0 0.0 500000.0
# interpolate adjoint :  True True True
# initial cost =  244234.70503349282
# RUN  0 , total integrated cost =  244234.70503349282
# Gradient descend method:  None
# RUN  1 , total integrated cost =  244234.70503349282
# Control only changes marginally.
# RUN  1 , total integrated cost =  244234.70503349282
# Improved over  1  iterations in  0.8166932229942176  seconds by  0.0  percent.
# uncontrolled cost :  245210.66789076867
# cost splitting :  9816.271887968818 [0. 0.]
# set cost params:  1.0 0.0 400000.0
# interpolate adjoint :  True True True
# initial cost =  244234.70503349282
# RUN  0 , total integrated cost =  244234.70503349282
# Gradient descend method:  None
# RUN  1 , total integrated cost =  244234.70503349282
# Control only changes marginally.
# RUN  1 , total integrated cost =  244234.70503349282
# Improved over  1  iterations in  0.8046089439885691  seconds by  0.0  percent.
# uncontrolled cost :  245210.66789076867
# cost splitting :  9816.271887968818 [0. 0.]
# set cost params:  1.0 0.0 300000.0
# interpolate adjoint :  True True True
# initial cost =  244234.70503349282
# RUN  0 , total integrated cost =  244234.70503349282
# Gradient descend method:  None
# RUN  1 , total integrated cost =  244234.70503349282
# Control only changes marginally.
# RUN  1 , total integrated cost =  244234.70503349282
# Improved over  1  iterations in  0.8306060539907776  seconds by  0.0  percent.
# uncontrolled cost :  245210.66789076867
# cost splitting :  9816.271887968818 [0. 0.]
# set cost params:  1.0 0.0 200000.0
# interpolate adjoint :  True True True
# initial cost =  244234.70503349282
# RUN  0 , total integrated cost =  244234.70503349282
# Gradient descend method:  None
# RUN  1 , total integrated cost =  244234.70503349282
# Control only changes marginally.
# RUN  1 , total integrated cost =  244234.70503349282
# Improved over  1  iterations in  0.8334473060094751  seconds by  0.0  percent.
# uncontrolled cost :  245210.66789076867
# cost splitting :  9816.271887968818 [0. 0.]
# set cost params:  1.0 0.0 100000.0
# interpolate adjoint :  True True True
# initial cost =  244234.70503349282
# RUN  0 , total integrated cost =  244234.70503349282
# Gradient descend method:  None
# RUN  1 , total integrated cost =  151746.4468337936
# RUN  2 , total integrated cost =  146317.0431420479
# RUN  3 , total integrated cost =  144160.2209231326
# RUN  4 , total integrated cost =  104751.8792256547
# RUN  5 , total integrated cost =  86407.48985244983
# RUN  6 , total integrated cost =  55730.11638018009
# RUN  7 , total integrated cost =  54950.32821099555
# RUN  8 , total integrated cost =  54699.8132216113
# RUN  9 , total integrated cost =  54327.83750958388
# RUN  10 , total integrated cost =  54102.81720995294
# RUN  10 , total integrated cost =  54102.81720995294
# Improved over  10  iterations in  3.231736585003091  seconds by  77.8480223756351  percent.
# uncontrolled cost :  245210.66789076867
# cost splitting :  10.083421502641203 [3.60003670e-14 5.38519357e-01]
# set cost params:  1.0 0.0 190000.0
# interpolate adjoint :  True True True
# initial cost =  244234.70503349282
# RUN  0 , total integrated cost =  244234.70503349282
# Gradient descend method:  None
# RUN  1 , total integrated cost =  244234.70503349282
# Control only changes marginally.
# RUN  1 , total integrated cost =  244234.70503349282
# Improved over  1  iterations in  0.8027120539918542  seconds by  0.0  percent.
# uncontrolled cost :  245210.66789076867
# cost splitting :  9816.271887968818 [0. 0.]
# set cost params:  1.0 0.0 180000.0
# interpolate adjoint :  True True True
# initial cost =  244234.70503349282
# RUN  0 , total integrated cost =  244234.70503349282
# Gradient descend method:  None
# RUN  1 , total integrated cost =  244234.70503349282
# Control only changes marginally.
# RUN  1 , total integrated cost =  244234.70503349282
# Improved over  1  iterations in  0.8207510480133351  seconds by  0.0  percent.
# uncontrolled cost :  245210.66789076867
# cost splitting :  9816.271887968818 [0. 0.]
# set cost params:  1.0 0.0 170000.0
# interpolate adjoint :  True True True
# initial cost =  244234.70503349282
# RUN  0 , total integrated cost =  244234.70503349282
# Gradient descend method:  None
# RUN  1 , total integrated cost =  244234.70503349282
# Control only changes marginally.
# RUN  1 , total integrated cost =  244234.70503349282
# Improved over  1  iterations in  0.9038955669966526  seconds by  0.0  percent.
# uncontrolled cost :  245210.66789076867
# cost splitting :  9816.271887968818 [0. 0.]
# set cost params:  1.0 0.0 160000.0
# interpolate adjoint :  True True True
# initial cost =  244234.70503349282
# RUN  0 , total integrated cost =  244234.70503349282
# Gradient descend method:  None
# RUN  1 , total integrated cost =  244234.70503349282
# Control only changes marginally.
# RUN  1 , total integrated cost =  244234.70503349282
# Improved over  1  iterations in  0.8137210049899295  seconds by  0.0  percent.
# uncontrolled cost :  245210.66789076867
# cost splitting :  9816.271887968818 [0. 0.]
# set cost params:  1.0 0.0 150000.0
# interpolate adjoint :  True True True
# initial cost =  244234.70503349282
# RUN  0 , total integrated cost =  244234.70503349282
# Gradient descend method:  None
# RUN  1 , total integrated cost =  244234.70503349282
# Control only changes marginally.
# RUN  1 , total integrated cost =  244234.70503349282
# Improved over  1  iterations in  0.7793240709870588  seconds by  0.0  percent.
# uncontrolled cost :  245210.66789076867
# cost splitting :  9816.271887968818 [0. 0.]
# set cost params:  1.0 0.0 140000.0
# interpolate adjoint :  True True True
# initial cost =  244234.70503349282
# RUN  0 , total integrated cost =  244234.70503349282
# Gradient descend method:  None
# RUN  1 , total integrated cost =  244234.7050334928
# RUN  2 , total integrated cost =  167608.01968508348
# RUN  3 , total integrated cost =  153647.62346876357
# RUN  4 , total integrated cost =  122337.43114447007
# RUN  5 , total integrated cost =  115142.81572875005
# RUN  6 , total integrated cost =  103190.00060995434
# RUN  7 , total integrated cost =  98635.6308525455
# RUN  8 , total integrated cost =  95442.30722374313
# RUN  9 , total integrated cost =  93807.7857696012
# RUN  10 , total integrated cost =  92251.94298668616
# RUN  10 , total integrated cost =  92251.94298668616
# Improved over  10  iterations in  2.9413200829876587  seconds by  62.22815959998997  percent.
# sparsity weight =  140000.0
# -------  2 0.4000000000000001 0.3750000000000001
# set cost params:  1.0 0.0 100000.0
# interpolate adjoint :  True True True
# initial cost =  137806.3558139294
# RUN  0 , total integrated cost =  137806.3558139294
# Gradient descend method:  None
# RUN  1 , total integrated cost =  137806.3558139294
# Control only changes marginally.
# RUN  1 , total integrated cost =  137806.3558139294
# Improved over  1  iterations in  0.7736455980048049  seconds by  0.0  percent.
# set cost params:  1.0 0.0 10000.0
# interpolate adjoint :  True True True
# initial cost =  137806.3558139294
# RUN  0 , total integrated cost =  137806.3558139294
# Gradient descend method:  None
# RUN  1 , total integrated cost =  38039.56203703927
# RUN  2 , total integrated cost =  29068.427076509204
# RUN  3 , total integrated cost =  19646.453642982535
# RUN  4 , total integrated cost =  19380.401332411395
# RUN  5 , total integrated cost =  19007.225415195608
# RUN  6 , total integrated cost =  18767.30382598243
# RUN  7 , total integrated cost =  18708.823613429184
# RUN  8 , total integrated cost =  18657.970599602646
# RUN  9 , total integrated cost =  18630.016021624477
# RUN  10 , total integrated cost =  18602.61563264086
# RUN  10 , total integrated cost =  18602.61563264086
# Improved over  10  iterations in  1.876555032999022  seconds by  86.50090155655904  percent.
# uncontrolled cost :  138357.03056243315
# cost splitting :  13.434596451841838 [0.05671189 1.77012359]
# set cost params:  1.0 0.0 90000.0
# interpolate adjoint :  True True True
# initial cost =  137806.3558139294
# RUN  0 , total integrated cost =  137806.3558139294
# Gradient descend method:  None
# RUN  1 , total integrated cost =  137806.3558139294
# Control only changes marginally.
# RUN  1 , total integrated cost =  137806.3558139294
# Improved over  1  iterations in  0.8085976209840737  seconds by  0.0  percent.
# uncontrolled cost :  138357.03056243315
# cost splitting :  5538.707762167529 [0. 0.]
# set cost params:  1.0 0.0 80000.0
# interpolate adjoint :  True True True
# initial cost =  137806.3558139294
# RUN  0 , total integrated cost =  137806.3558139294
# Gradient descend method:  None
# RUN  1 , total integrated cost =  137806.3558139294
# Control only changes marginally.
# RUN  1 , total integrated cost =  137806.3558139294
# Improved over  1  iterations in  0.7848537339887116  seconds by  0.0  percent.
# uncontrolled cost :  138357.03056243315
# cost splitting :  5538.707762167529 [0. 0.]
# set cost params:  1.0 0.0 70000.0
# interpolate adjoint :  True True True
# initial cost =  137806.3558139294
# RUN  0 , total integrated cost =  137806.3558139294
# Gradient descend method:  None
# RUN  1 , total integrated cost =  137806.3558139294
# Control only changes marginally.
# RUN  1 , total integrated cost =  137806.3558139294
# Improved over  1  iterations in  0.7767933339928277  seconds by  0.0  percent.
# uncontrolled cost :  138357.03056243315
# cost splitting :  5538.707762167529 [0. 0.]
# set cost params:  1.0 0.0 60000.0
# interpolate adjoint :  True True True
# initial cost =  137806.3558139294
# RUN  0 , total integrated cost =  137806.3558139294
# Gradient descend method:  None
# RUN  1 , total integrated cost =  137806.3558139294
# Control only changes marginally.
# RUN  1 , total integrated cost =  137806.3558139294
# Improved over  1  iterations in  0.83078648801893  seconds by  0.0  percent.
# uncontrolled cost :  138357.03056243315
# cost splitting :  5538.707762167529 [0. 0.]
# set cost params:  1.0 0.0 50000.0
# interpolate adjoint :  True True True
# initial cost =  137806.3558139294
# RUN  0 , total integrated cost =  137806.3558139294
# Gradient descend method:  None
# RUN  1 , total integrated cost =  126546.11469086788
# RUN  2 , total integrated cost =  93888.10854972152
# RUN  3 , total integrated cost =  93329.55670774424
# RUN  4 , total integrated cost =  93159.67549851262
# RUN  5 , total integrated cost =  93017.08713230821
# RUN  6 , total integrated cost =  92920.60451773934
# RUN  7 , total integrated cost =  92826.29783272663
# RUN  8 , total integrated cost =  92768.26266397869
# RUN  9 , total integrated cost =  92711.6254055772
# RUN  10 , total integrated cost =  92669.99481995593
# RUN  10 , total integrated cost =  92669.99481995593
# Improved over  10  iterations in  4.844882835983299  seconds by  32.75346824708002  percent.
# uncontrolled cost :  138357.03056243315
# cost splitting :  84.77374741896007 [4.20385133e-16 1.81121547e+00]
# set cost params:  1.0 0.0 59000.0
# interpolate adjoint :  True True True
# initial cost =  137806.3558139294
# RUN  0 , total integrated cost =  137806.3558139294
# Gradient descend method:  None
# RUN  1 , total integrated cost =  137806.3558139294
# Control only changes marginally.
# RUN  1 , total integrated cost =  137806.3558139294
# Improved over  1  iterations in  0.7715870210085995  seconds by  0.0  percent.
# uncontrolled cost :  138357.03056243315
# cost splitting :  5538.707762167529 [0. 0.]
# set cost params:  1.0 0.0 58000.0
# interpolate adjoint :  True True True
# initial cost =  137806.3558139294
# RUN  0 , total integrated cost =  137806.3558139294
# Gradient descend method:  None
# RUN  1 , total integrated cost =  137806.3558139294
# Control only changes marginally.
# RUN  1 , total integrated cost =  137806.3558139294
# Improved over  1  iterations in  0.7650840700080153  seconds by  0.0  percent.
# uncontrolled cost :  138357.03056243315
# cost splitting :  5538.707762167529 [0. 0.]
# set cost params:  1.0 0.0 57000.0
# interpolate adjoint :  True True True
# initial cost =  137806.3558139294
# RUN  0 , total integrated cost =  137806.3558139294
# Gradient descend method:  None
# RUN  1 , total integrated cost =  137806.3558139294
# Control only changes marginally.
# RUN  1 , total integrated cost =  137806.3558139294
# Improved over  1  iterations in  0.770909204002237  seconds by  0.0  percent.
# uncontrolled cost :  138357.03056243315
# cost splitting :  5538.707762167529 [0. 0.]
# set cost params:  1.0 0.0 56000.0
# interpolate adjoint :  True True True
# initial cost =  137806.3558139294
# RUN  0 , total integrated cost =  137806.3558139294
# Gradient descend method:  None
# RUN  1 , total integrated cost =  137806.3558139294
# Control only changes marginally.
# RUN  1 , total integrated cost =  137806.3558139294
# Improved over  1  iterations in  0.7961162629944738  seconds by  0.0  percent.
# uncontrolled cost :  138357.03056243315
# cost splitting :  5538.707762167529 [0. 0.]
# set cost params:  1.0 0.0 55000.0
# interpolate adjoint :  True True True
# initial cost =  137806.3558139294
# RUN  0 , total integrated cost =  137806.3558139294
# Gradient descend method:  None
# RUN  1 , total integrated cost =  137806.3558139294
# Control only changes marginally.
# RUN  1 , total integrated cost =  137806.3558139294
# Improved over  1  iterations in  0.7577823089959566  seconds by  0.0  percent.
# uncontrolled cost :  138357.03056243315
# cost splitting :  5538.707762167529 [0. 0.]
# set cost params:  1.0 0.0 54000.0
# interpolate adjoint :  True True True
# initial cost =  137806.3558139294
# RUN  0 , total integrated cost =  137806.3558139294
# Gradient descend method:  None
# RUN  1 , total integrated cost =  137806.3558139294
# Control only changes marginally.
# RUN  1 , total integrated cost =  137806.3558139294
# Improved over  1  iterations in  0.7726129579823464  seconds by  0.0  percent.
# uncontrolled cost :  138357.03056243315
# cost splitting :  5538.707762167529 [0. 0.]
# set cost params:  1.0 0.0 53000.0
# interpolate adjoint :  True True True
# initial cost =  137806.3558139294
# RUN  0 , total integrated cost =  137806.3558139294
# Gradient descend method:  None
# RUN  1 , total integrated cost =  137806.3558139294
# Control only changes marginally.
# RUN  1 , total integrated cost =  137806.3558139294
# Improved over  1  iterations in  0.7648405749932863  seconds by  0.0  percent.
# uncontrolled cost :  138357.03056243315
# cost splitting :  5538.707762167529 [0. 0.]
# set cost params:  1.0 0.0 52000.0
# interpolate adjoint :  True True True
# initial cost =  137806.3558139294
# RUN  0 , total integrated cost =  137806.3558139294
# Gradient descend method:  None
# RUN  1 , total integrated cost =  137806.3558139294
# Control only changes marginally.
# RUN  1 , total integrated cost =  137806.3558139294
# Improved over  1  iterations in  0.7618110050098039  seconds by  0.0  percent.
# uncontrolled cost :  138357.03056243315
# cost splitting :  5538.707762167529 [0. 0.]
# set cost params:  1.0 0.0 51000.0
# interpolate adjoint :  True True True
# initial cost =  137806.3558139294
# RUN  0 , total integrated cost =  137806.3558139294
# Gradient descend method:  None
# RUN  1 , total integrated cost =  137806.3558139294
# Control only changes marginally.
# RUN  1 , total integrated cost =  137806.3558139294
# Improved over  1  iterations in  0.7651746820192784  seconds by  0.0  percent.
# uncontrolled cost :  138357.03056243315
# cost splitting :  5538.707762167529 [0. 0.]
# set cost params:  1.0 0.0 50000.0
# interpolate adjoint :  True True True
# initial cost =  137806.3558139294
# RUN  0 , total integrated cost =  137806.3558139294
# Gradient descend method:  None
# RUN  1 , total integrated cost =  126546.11469086788
# RUN  2 , total integrated cost =  93888.10854972152
# RUN  3 , total integrated cost =  93329.55670774424
# RUN  4 , total integrated cost =  93159.67549851262
# RUN  5 , total integrated cost =  93017.08713230821
# RUN  6 , total integrated cost =  92920.60451773934
# RUN  7 , total integrated cost =  92826.29783272663
# RUN  8 , total integrated cost =  92768.26266397869
# RUN  9 , total integrated cost =  92711.6254055772
# RUN  10 , total integrated cost =  92669.99481995593
# RUN  10 , total integrated cost =  92669.99481995593
# Improved over  10  iterations in  4.7755396160064265  seconds by  32.75346824708002  percent.
# sparsity weight =  50000.0
# -------  3 0.4250000000000001 0.3750000000000001
# set cost params:  1.0 0.0 100000.0
# interpolate adjoint :  True True True
# initial cost =  241480.3484875782
# RUN  0 , total integrated cost =  241480.3484875782
# Gradient descend method:  None
# RUN  1 , total integrated cost =  210997.27495643822
# RUN  2 , total integrated cost =  186861.59426063887
# RUN  3 , total integrated cost =  167134.9820650206
# RUN  4 , total integrated cost =  162724.20665892545
# RUN  5 , total integrated cost =  160224.01158368992
# RUN  6 , total integrated cost =  158627.51300735289
# RUN  7 , total integrated cost =  156712.7040360363
# RUN  8 , total integrated cost =  155264.67960968276
# RUN  9 , total integrated cost =  153008.5008226392
# RUN  10 , total integrated cost =  151082.33274649788
# RUN  10 , total integrated cost =  151082.33274649788
# Improved over  10  iterations in  2.685305321996566  seconds by  37.434936758727765  percent.
# uncontrolled cost :  242445.3049250932
# cost splitting :  258.67498984756264 [0.52520228 0.92126117]
# set cost params:  1.0 0.0 900000.0
# interpolate adjoint :  True True True
# initial cost =  241480.3484875782
# RUN  0 , total integrated cost =  241480.3484875782
# Gradient descend method:  None
# RUN  1 , total integrated cost =  241480.3484875782
# Control only changes marginally.
# RUN  1 , total integrated cost =  241480.3484875782
# Improved over  1  iterations in  0.7692656659928616  seconds by  0.0  percent.
# uncontrolled cost :  242445.3049250932
# cost splitting :  9705.568895421558 [0. 0.]
# set cost params:  1.0 0.0 800000.0
# interpolate adjoint :  True True True
# initial cost =  241480.3484875782
# RUN  0 , total integrated cost =  241480.3484875782
# Gradient descend method:  None
# RUN  1 , total integrated cost =  241480.3484875782
# Control only changes marginally.
# RUN  1 , total integrated cost =  241480.3484875782
# Improved over  1  iterations in  0.7635189090215135  seconds by  0.0  percent.
# uncontrolled cost :  242445.3049250932
# cost splitting :  9705.568895421558 [0. 0.]
# set cost params:  1.0 0.0 700000.0
# interpolate adjoint :  True True True
# initial cost =  241480.3484875782
# RUN  0 , total integrated cost =  241480.3484875782
# Gradient descend method:  None
# RUN  1 , total integrated cost =  241480.3484875782
# Control only changes marginally.
# RUN  1 , total integrated cost =  241480.3484875782
# Improved over  1  iterations in  0.7633793239947408  seconds by  0.0  percent.
# uncontrolled cost :  242445.3049250932
# cost splitting :  9705.568895421558 [0. 0.]
# set cost params:  1.0 0.0 600000.0
# interpolate adjoint :  True True True
# initial cost =  241480.3484875782
# RUN  0 , total integrated cost =  241480.3484875782
# Gradient descend method:  None
# RUN  1 , total integrated cost =  241480.3484875782
# Control only changes marginally.
# RUN  1 , total integrated cost =  241480.3484875782
# Improved over  1  iterations in  0.7611467440146953  seconds by  0.0  percent.
# uncontrolled cost :  242445.3049250932
# cost splitting :  9705.568895421558 [0. 0.]
# set cost params:  1.0 0.0 500000.0
# interpolate adjoint :  True True True
# initial cost =  241480.3484875782
# RUN  0 , total integrated cost =  241480.3484875782
# Gradient descend method:  None
# RUN  1 , total integrated cost =  241480.3484875782
# Control only changes marginally.
# RUN  1 , total integrated cost =  241480.3484875782
# Improved over  1  iterations in  0.7599385469802655  seconds by  0.0  percent.
# uncontrolled cost :  242445.3049250932
# cost splitting :  9705.568895421558 [0. 0.]
# set cost params:  1.0 0.0 400000.0
# interpolate adjoint :  True True True
# initial cost =  241480.3484875782
# RUN  0 , total integrated cost =  241480.3484875782
# Gradient descend method:  None
# RUN  1 , total integrated cost =  241480.3484875782
# Control only changes marginally.
# RUN  1 , total integrated cost =  241480.3484875782
# Improved over  1  iterations in  0.7600981790164951  seconds by  0.0  percent.
# uncontrolled cost :  242445.3049250932
# cost splitting :  9705.568895421558 [0. 0.]
# set cost params:  1.0 0.0 300000.0
# interpolate adjoint :  True True True
# initial cost =  241480.3484875782
# RUN  0 , total integrated cost =  241480.3484875782
# Gradient descend method:  None
# RUN  1 , total integrated cost =  241480.3484875782
# Control only changes marginally.
# RUN  1 , total integrated cost =  241480.3484875782
# Improved over  1  iterations in  0.7647121470072307  seconds by  0.0  percent.
# uncontrolled cost :  242445.3049250932
# cost splitting :  9705.568895421558 [0. 0.]
# set cost params:  1.0 0.0 200000.0
# interpolate adjoint :  True True True
# initial cost =  241480.3484875782
# RUN  0 , total integrated cost =  241480.3484875782
# Gradient descend method:  None
# RUN  1 , total integrated cost =  241480.3484875782
# Control only changes marginally.
# RUN  1 , total integrated cost =  241480.3484875782
# Improved over  1  iterations in  0.7769165649951901  seconds by  0.0  percent.
# uncontrolled cost :  242445.3049250932
# cost splitting :  9705.568895421558 [0. 0.]
# set cost params:  1.0 0.0 100000.0
# interpolate adjoint :  True True True
# initial cost =  241480.3484875782
# RUN  0 , total integrated cost =  241480.3484875782
# Gradient descend method:  None
# RUN  1 , total integrated cost =  210997.27495643822
# RUN  2 , total integrated cost =  186861.59426063887
# RUN  3 , total integrated cost =  167134.9820650206
# RUN  4 , total integrated cost =  162724.20665892545
# RUN  5 , total integrated cost =  160224.01158368992
# RUN  6 , total integrated cost =  158627.51300735289
# RUN  7 , total integrated cost =  156712.7040360363
# RUN  8 , total integrated cost =  155264.67960968276
# RUN  9 , total integrated cost =  153008.5008226392
# RUN  10 , total integrated cost =  151082.33274649788
# RUN  10 , total integrated cost =  151082.33274649788
# Improved over  10  iterations in  2.6997122330067214  seconds by  37.434936758727765  percent.
# uncontrolled cost :  242445.3049250932
# cost splitting :  258.67498984756264 [0.52520228 0.92126117]
# set cost params:  1.0 0.0 190000.0
# interpolate adjoint :  True True True
# initial cost =  241480.3484875782
# RUN  0 , total integrated cost =  241480.3484875782
# Gradient descend method:  None
# RUN  1 , total integrated cost =  241480.3484875782
# Control only changes marginally.
# RUN  1 , total integrated cost =  241480.3484875782
# Improved over  1  iterations in  0.7659190930135082  seconds by  0.0  percent.
# uncontrolled cost :  242445.3049250932
# cost splitting :  9705.568895421558 [0. 0.]
# set cost params:  1.0 0.0 180000.0
# interpolate adjoint :  True True True
# initial cost =  241480.3484875782
# RUN  0 , total integrated cost =  241480.3484875782
# Gradient descend method:  None
# RUN  1 , total integrated cost =  241480.3484875782
# Control only changes marginally.
# RUN  1 , total integrated cost =  241480.3484875782
# Improved over  1  iterations in  0.7660403170157224  seconds by  0.0  percent.
# uncontrolled cost :  242445.3049250932
# cost splitting :  9705.568895421558 [0. 0.]
# set cost params:  1.0 0.0 170000.0
# interpolate adjoint :  True True True
# initial cost =  241480.3484875782
# RUN  0 , total integrated cost =  241480.3484875782
# Gradient descend method:  None
# RUN  1 , total integrated cost =  241480.3484875782
# Control only changes marginally.
# RUN  1 , total integrated cost =  241480.3484875782
# Improved over  1  iterations in  0.7620065239898395  seconds by  0.0  percent.
# uncontrolled cost :  242445.3049250932
# cost splitting :  9705.568895421558 [0. 0.]
# set cost params:  1.0 0.0 160000.0
# interpolate adjoint :  True True True
# initial cost =  241480.3484875782
# RUN  0 , total integrated cost =  241480.3484875782
# Gradient descend method:  None
# RUN  1 , total integrated cost =  241480.3484875782
# Control only changes marginally.
# RUN  1 , total integrated cost =  241480.3484875782
# Improved over  1  iterations in  0.7623607169953175  seconds by  0.0  percent.
# uncontrolled cost :  242445.3049250932
# cost splitting :  9705.568895421558 [0. 0.]
# set cost params:  1.0 0.0 150000.0
# interpolate adjoint :  True True True
# initial cost =  241480.3484875782
# RUN  0 , total integrated cost =  241480.3484875782
# Gradient descend method:  None
# RUN  1 , total integrated cost =  241480.3484875782
# Control only changes marginally.
# RUN  1 , total integrated cost =  241480.3484875782
# Improved over  1  iterations in  0.7643670759862289  seconds by  0.0  percent.
# uncontrolled cost :  242445.3049250932
# cost splitting :  9705.568895421558 [0. 0.]
# set cost params:  1.0 0.0 140000.0
# interpolate adjoint :  True True True
# initial cost =  241480.3484875782
# RUN  0 , total integrated cost =  241480.3484875782
# Gradient descend method:  None
# RUN  1 , total integrated cost =  241480.3484875782
# Control only changes marginally.
# RUN  1 , total integrated cost =  241480.3484875782
# Improved over  1  iterations in  0.7599640069820452  seconds by  0.0  percent.
# uncontrolled cost :  242445.3049250932
# cost splitting :  9705.568895421558 [0. 0.]
# set cost params:  1.0 0.0 130000.0
# interpolate adjoint :  True True True
# initial cost =  241480.3484875782
# RUN  0 , total integrated cost =  241480.3484875782
# Gradient descend method:  None
# RUN  1 , total integrated cost =  241480.3484875782
# Control only changes marginally.
# RUN  1 , total integrated cost =  241480.3484875782
# Improved over  1  iterations in  0.7645692120131571  seconds by  0.0  percent.
# uncontrolled cost :  242445.3049250932
# cost splitting :  9705.568895421558 [0. 0.]
# set cost params:  1.0 0.0 120000.0
# interpolate adjoint :  True True True
# initial cost =  241480.3484875782
# RUN  0 , total integrated cost =  241480.3484875782
# Gradient descend method:  None
# RUN  1 , total integrated cost =  241480.3484875782
# Control only changes marginally.
# RUN  1 , total integrated cost =  241480.3484875782
# Improved over  1  iterations in  0.7624044650001451  seconds by  0.0  percent.
# uncontrolled cost :  242445.3049250932
# cost splitting :  9705.568895421558 [0. 0.]
# set cost params:  1.0 0.0 110000.0
# interpolate adjoint :  True True True
# initial cost =  241480.3484875782
# RUN  0 , total integrated cost =  241480.3484875782
# Gradient descend method:  None
# RUN  1 , total integrated cost =  227747.88475190746
# RUN  2 , total integrated cost =  204483.13664791966
# RUN  3 , total integrated cost =  185012.7573158081
# RUN  4 , total integrated cost =  180245.81817210774
# RUN  5 , total integrated cost =  177508.5857837296
# RUN  6 , total integrated cost =  174411.32539727748
# RUN  7 , total integrated cost =  172306.29556392424
# RUN  8 , total integrated cost =  165940.12630035126
# RUN  9 , total integrated cost =  161926.76521014515
# RUN  10 , total integrated cost =  158195.05391156094
# RUN  10 , total integrated cost =  158195.05391156094
# Improved over  10  iterations in  2.7165087109897286  seconds by  34.48947092284881  percent.
# sparsity weight =  110000.0
# -------  4 0.4500000000000001 0.3750000000000001
# set cost params:  1.0 0.0 100000.0
# interpolate adjoint :  True True True
# initial cost =  338432.51439444604
# RUN  0 , total integrated cost =  338432.51439444604
# Gradient descend method:  None
# RUN  1 , total integrated cost =  183541.43227421746
# RUN  2 , total integrated cost =  157054.10349153294
# RUN  3 , total integrated cost =  140109.58172716244
# RUN  4 , total integrated cost =  130442.51908850492
# RUN  5 , total integrated cost =  108364.46561525174
# RUN  6 , total integrated cost =  105135.65987804969
# RUN  7 , total integrated cost =  98527.0331478725
# RUN  8 , total integrated cost =  94830.92061172434
# RUN  9 , total integrated cost =  85341.84644916076
# RUN  10 , total integrated cost =  81907.77356947797
# RUN  10 , total integrated cost =  81907.77356947797
# Improved over  10  iterations in  2.1043702049937565  seconds by  75.7979005900084  percent.
# uncontrolled cost :  339784.89207433624
# cost splitting :  242.2827692035287 [0.07475053 0.68404581]
# set cost params:  1.0 0.0 900000.0
# interpolate adjoint :  True True True
# initial cost =  338432.51439444604
# RUN  0 , total integrated cost =  338432.51439444604
# Gradient descend method:  None
# RUN  1 , total integrated cost =  338432.51439444604
# Control only changes marginally.
# RUN  1 , total integrated cost =  338432.51439444604
# Improved over  1  iterations in  0.7686915440135635  seconds by  0.0  percent.
# uncontrolled cost :  339784.89207433624
# cost splitting :  13602.266625331664 [0. 0.]
# set cost params:  1.0 0.0 800000.0
# interpolate adjoint :  True True True
# initial cost =  338432.51439444604
# RUN  0 , total integrated cost =  338432.51439444604
# Gradient descend method:  None
# RUN  1 , total integrated cost =  338432.51439444604
# Control only changes marginally.
# RUN  1 , total integrated cost =  338432.51439444604
# Improved over  1  iterations in  0.7996131289983168  seconds by  0.0  percent.
# uncontrolled cost :  339784.89207433624
# cost splitting :  13602.266625331664 [0. 0.]
# set cost params:  1.0 0.0 700000.0
# interpolate adjoint :  True True True
# initial cost =  338432.51439444604
# RUN  0 , total integrated cost =  338432.51439444604
# Gradient descend method:  None
# RUN  1 , total integrated cost =  338432.51439444604
# Control only changes marginally.
# RUN  1 , total integrated cost =  338432.51439444604
# Improved over  1  iterations in  0.793261482991511  seconds by  0.0  percent.
# uncontrolled cost :  339784.89207433624
# cost splitting :  13602.266625331664 [0. 0.]
# set cost params:  1.0 0.0 600000.0
# interpolate adjoint :  True True True
# initial cost =  338432.51439444604
# RUN  0 , total integrated cost =  338432.51439444604
# Gradient descend method:  None
# RUN  1 , total integrated cost =  338432.51439444604
# Control only changes marginally.
# RUN  1 , total integrated cost =  338432.51439444604
# Improved over  1  iterations in  0.7907392460037954  seconds by  0.0  percent.
# uncontrolled cost :  339784.89207433624
# cost splitting :  13602.266625331664 [0. 0.]
# set cost params:  1.0 0.0 500000.0
# interpolate adjoint :  True True True
# initial cost =  338432.51439444604
# RUN  0 , total integrated cost =  338432.51439444604
# Gradient descend method:  None
# RUN  1 , total integrated cost =  338432.51439444604
# Control only changes marginally.
# RUN  1 , total integrated cost =  338432.51439444604
# Improved over  1  iterations in  0.7943215729901567  seconds by  0.0  percent.
# uncontrolled cost :  339784.89207433624
# cost splitting :  13602.266625331664 [0. 0.]
# set cost params:  1.0 0.0 400000.0
# interpolate adjoint :  True True True
# initial cost =  338432.51439444604
# RUN  0 , total integrated cost =  338432.51439444604
# Gradient descend method:  None
# RUN  1 , total integrated cost =  338432.51439444604
# Control only changes marginally.
# RUN  1 , total integrated cost =  338432.51439444604
# Improved over  1  iterations in  0.7668906420003623  seconds by  0.0  percent.
# uncontrolled cost :  339784.89207433624
# cost splitting :  13602.266625331664 [0. 0.]
# set cost params:  1.0 0.0 300000.0
# interpolate adjoint :  True True True
# initial cost =  338432.51439444604
# RUN  0 , total integrated cost =  338432.51439444604
# Gradient descend method:  None
# RUN  1 , total integrated cost =  338432.51439444604
# Control only changes marginally.
# RUN  1 , total integrated cost =  338432.51439444604
# Improved over  1  iterations in  0.7681115489976946  seconds by  0.0  percent.
# uncontrolled cost :  339784.89207433624
# cost splitting :  13602.266625331664 [0. 0.]
# set cost params:  1.0 0.0 200000.0
# interpolate adjoint :  True True True
# initial cost =  338432.51439444604
# RUN  0 , total integrated cost =  338432.51439444604
# Gradient descend method:  None
# RUN  1 , total integrated cost =  313880.0628407686
# RUN  2 , total integrated cost =  269289.04193683725
# RUN  3 , total integrated cost =  244605.0777484368
# RUN  4 , total integrated cost =  232485.9046249428
# RUN  5 , total integrated cost =  211258.3635583786
# RUN  6 , total integrated cost =  192484.2809955959
# RUN  7 , total integrated cost =  179810.05266668586
# RUN  8 , total integrated cost =  173601.55781841447
# RUN  9 , total integrated cost =  153830.09692800522
# RUN  10 , total integrated cost =  147070.22764160566
# RUN  10 , total integrated cost =  147070.22764160566
# Improved over  10  iterations in  3.592405316012446  seconds by  56.543706237931374  percent.
# uncontrolled cost :  339784.89207433624
# cost splitting :  156.5229160441453 [5.87979426e-16 7.15879220e-01]
# set cost params:  1.0 0.0 290000.0
# interpolate adjoint :  True True True
# initial cost =  338432.51439444604
# RUN  0 , total integrated cost =  338432.51439444604
# Gradient descend method:  None
# RUN  1 , total integrated cost =  338432.51439444604
# Control only changes marginally.
# RUN  1 , total integrated cost =  338432.51439444604
# Improved over  1  iterations in  0.7859633649932221  seconds by  0.0  percent.
# uncontrolled cost :  339784.89207433624
# cost splitting :  13602.266625331664 [0. 0.]
# set cost params:  1.0 0.0 280000.0
# interpolate adjoint :  True True True
# initial cost =  338432.51439444604
# RUN  0 , total integrated cost =  338432.51439444604
# Gradient descend method:  None
# RUN  1 , total integrated cost =  338432.51439444604
# Control only changes marginally.
# RUN  1 , total integrated cost =  338432.51439444604
# Improved over  1  iterations in  0.7694417620077729  seconds by  0.0  percent.
# uncontrolled cost :  339784.89207433624
# cost splitting :  13602.266625331664 [0. 0.]
# set cost params:  1.0 0.0 270000.0
# interpolate adjoint :  True True True
# initial cost =  338432.51439444604
# RUN  0 , total integrated cost =  338432.51439444604
# Gradient descend method:  None
# RUN  1 , total integrated cost =  338432.51439444604
# Control only changes marginally.
# RUN  1 , total integrated cost =  338432.51439444604
# Improved over  1  iterations in  0.7793428139993921  seconds by  0.0  percent.
# uncontrolled cost :  339784.89207433624
# cost splitting :  13602.266625331664 [0. 0.]
# set cost params:  1.0 0.0 260000.0
# interpolate adjoint :  True True True
# initial cost =  338432.51439444604
# RUN  0 , total integrated cost =  338432.51439444604
# Gradient descend method:  None
# RUN  1 , total integrated cost =  338432.51439444604
# Control only changes marginally.
# RUN  1 , total integrated cost =  338432.51439444604
# Improved over  1  iterations in  0.7920289920002688  seconds by  0.0  percent.
# uncontrolled cost :  339784.89207433624
# cost splitting :  13602.266625331664 [0. 0.]
# set cost params:  1.0 0.0 250000.0
# interpolate adjoint :  True True True
# initial cost =  338432.51439444604
# RUN  0 , total integrated cost =  338432.51439444604
# Gradient descend method:  None
# RUN  1 , total integrated cost =  338432.51439444604
# Control only changes marginally.
# RUN  1 , total integrated cost =  338432.51439444604
# Improved over  1  iterations in  0.7628224630025215  seconds by  0.0  percent.
# uncontrolled cost :  339784.89207433624
# cost splitting :  13602.266625331664 [0. 0.]
# set cost params:  1.0 0.0 240000.0
# interpolate adjoint :  True True True
# initial cost =  338432.51439444604
# RUN  0 , total integrated cost =  338432.51439444604
# Gradient descend method:  None
# RUN  1 , total integrated cost =  338432.51439444604
# Control only changes marginally.
# RUN  1 , total integrated cost =  338432.51439444604
# Improved over  1  iterations in  0.7695862780092284  seconds by  0.0  percent.
# uncontrolled cost :  339784.89207433624
# cost splitting :  13602.266625331664 [0. 0.]
# set cost params:  1.0 0.0 230000.0
# interpolate adjoint :  True True True
# initial cost =  338432.51439444604
# RUN  0 , total integrated cost =  338432.51439444604
# Gradient descend method:  None
# RUN  1 , total integrated cost =  338432.51439444604
# Control only changes marginally.
# RUN  1 , total integrated cost =  338432.51439444604
# Improved over  1  iterations in  0.7642667439940851  seconds by  0.0  percent.
# uncontrolled cost :  339784.89207433624
# cost splitting :  13602.266625331664 [0. 0.]
# set cost params:  1.0 0.0 220000.0
# interpolate adjoint :  True True True
# initial cost =  338432.51439444604
# RUN  0 , total integrated cost =  338432.51439444604
# Gradient descend method:  None
# RUN  1 , total integrated cost =  338432.51439444604
# Control only changes marginally.
# RUN  1 , total integrated cost =  338432.51439444604
# Improved over  1  iterations in  0.7648482979857363  seconds by  0.0  percent.
# uncontrolled cost :  339784.89207433624
# cost splitting :  13602.266625331664 [0. 0.]
# set cost params:  1.0 0.0 210000.0
# interpolate adjoint :  True True True
# initial cost =  338432.51439444604
# RUN  0 , total integrated cost =  338432.51439444604
# Gradient descend method:  None
# RUN  1 , total integrated cost =  325899.9224977922
# ...
# RUN  3 , total integrated cost =  427413.61749827734
# RUN  4 , total integrated cost =  420225.1493925134
# RUN  5 , total integrated cost =  414280.8284506203
# RUN  6 , total integrated cost =  409511.8946796816
# RUN  7 , total integrated cost =  405072.9443313173
# RUN  8 , total integrated cost =  401373.9359290415
# RUN  9 , total integrated cost =  397862.55869921396
# RUN  10 , total integrated cost =  395051.18870741467
# RUN  10 , total integrated cost =  395051.18870741467
# Improved over  10  iterations in  4.483631470007822  seconds by  34.97166243337092  percent.
# uncontrolled cost :  609933.8068264901
# cost splitting :  286.8440873441713 [4.84892921 0.        ]
# set cost params:  1.0 0.0 89000.0
# interpolate adjoint :  True True True
# initial cost =  607506.209585381
# RUN  0 , total integrated cost =  607506.209585381
# Gradient descend method:  None
# RUN  1 , total integrated cost =  607506.209585381
# Control only changes marginally.
# RUN  1 , total integrated cost =  607506.209585381
# Improved over  1  iterations in  0.7609512339986395  seconds by  0.0  percent.
# uncontrolled cost :  609933.8068264901
# cost splitting :  24416.8662520819 [0. 0.]
# set cost params:  1.0 0.0 88000.0
# interpolate adjoint :  True True True
# initial cost =  607506.209585381
# RUN  0 , total integrated cost =  607506.209585381
# Gradient descend method:  None
# RUN  1 , total integrated cost =  607506.209585381
# Control only changes marginally.
# RUN  1 , total integrated cost =  607506.209585381
# Improved over  1  iterations in  0.7596846010128502  seconds by  0.0  percent.
# uncontrolled cost :  609933.8068264901
# cost splitting :  24416.8662520819 [0. 0.]
# set cost params:  1.0 0.0 87000.0
# interpolate adjoint :  True True True
# initial cost =  607506.209585381
# RUN  0 , total integrated cost =  607506.209585381
# Gradient descend method:  None
# RUN  1 , total integrated cost =  607506.209585381
# Control only changes marginally.
# RUN  1 , total integrated cost =  607506.209585381
# Improved over  1  iterations in  0.7618210430082399  seconds by  0.0  percent.
# uncontrolled cost :  609933.8068264901
# cost splitting :  24416.8662520819 [0. 0.]
# set cost params:  1.0 0.0 86000.0
# interpolate adjoint :  True True True
# initial cost =  607506.209585381
# RUN  0 , total integrated cost =  607506.209585381
# Gradient descend method:  None
# RUN  1 , total integrated cost =  607506.209585381
# Control only changes marginally.
# RUN  1 , total integrated cost =  607506.209585381
# Improved over  1  iterations in  0.7634180249879137  seconds by  0.0  percent.
# uncontrolled cost :  609933.8068264901
# cost splitting :  24416.8662520819 [0. 0.]
# set cost params:  1.0 0.0 85000.0
# interpolate adjoint :  True True True
# initial cost =  607506.209585381
# RUN  0 , total integrated cost =  607506.209585381
# Gradient descend method:  None
# RUN  1 , total integrated cost =  607506.209585381
# Control only changes marginally.
# RUN  1 , total integrated cost =  607506.209585381
# Improved over  1  iterations in  0.7579423599818256  seconds by  0.0  percent.
# uncontrolled cost :  609933.8068264901
# cost splitting :  24416.8662520819 [0. 0.]
# set cost params:  1.0 0.0 84000.0
# interpolate adjoint :  True True True
# initial cost =  607506.209585381
# RUN  0 , total integrated cost =  607506.209585381
# Gradient descend method:  None
# RUN  1 , total integrated cost =  603866.6362736638
# RUN  2 , total integrated cost =  450489.73897363973
# RUN  3 , total integrated cost =  442752.7644221971
# RUN  4 , total integrated cost =  436690.3085548857
# RUN  5 , total integrated cost =  430971.2899202944
# RUN  6 , total integrated cost =  426343.4966656295
# RUN  7 , total integrated cost =  421878.3593224272
# RUN  8 , total integrated cost =  418215.0315487626
# RUN  9 , total integrated cost =  414490.4996105784
# RUN  10 , total integrated cost =  411342.69578444527
# RUN  10 , total integrated cost =  411342.69578444527
# Improved over  10  iterations in  4.449318956991192  seconds by  32.28996028449093  percent.
# sparsity weight =  84000.0
# -------  81 0.5500000000000003 0.7000000000000004
# set cost params:  1.0 0.0 100000.0
# interpolate adjoint :  True True True
# initial cost =  728478.2773809158
# RUN  0 , total integrated cost =  728478.2773809158
# Gradient descend method:  None
# RUN  1 , total integrated cost =  728478.2773809158
# Control only changes marginally.
# RUN  1 , total integrated cost =  728478.2773809158
# Improved over  1  iterations in  0.7615559810074046  seconds by  0.0  percent.
# set cost params:  1.0 0.0 10000.0
# interpolate adjoint :  True True True
# initial cost =  728478.2773809158
# RUN  0 , total integrated cost =  728478.2773809158
# Gradient descend method:  None
# RUN  1 , total integrated cost =  151181.5588331653
# RUN  2 , total integrated cost =  92405.02580139632
# RUN  3 , total integrated cost =  70122.38761938905
# RUN  4 , total integrated cost =  46317.34646756951
# RUN  5 , total integrated cost =  45129.78630884768
# RUN  6 , total integrated cost =  44666.92682015185
# RUN  7 , total integrated cost =  44287.96592039359
# RUN  8 , total integrated cost =  43914.553659059115
# RUN  9 , total integrated cost =  43574.245640719935
# RUN  10 , total integrated cost =  42842.84193371329
# RUN  10 , total integrated cost =  42842.84193371329
# Improved over  10  iterations in  3.4293251110066194  seconds by  94.1188579997546  percent.
# uncontrolled cost :  731389.2794883196
# cost splitting :  55.888431300176755 [4.14523044 0.        ]
# set cost params:  1.0 0.0 90000.0
# interpolate adjoint :  True True True
# initial cost =  728478.2773809158
# RUN  0 , total integrated cost =  728478.2773809158
# Gradient descend method:  None
# RUN  1 , total integrated cost =  530714.8501035323
# RUN  2 , total integrated cost =  474710.1713663841
# RUN  3 , total integrated cost =  446416.83947880275
# RUN  4 , total integrated cost =  424170.438430533
# RUN  5 , total integrated cost =  408349.53570910764
# RUN  6 , total integrated cost =  395767.5452132431
# RUN  7 , total integrated cost =  385510.43778798037
# RUN  8 , total integrated cost =  377444.0692417646
# RUN  9 , total integrated cost =  370157.9511014479
# RUN  10 , total integrated cost =  364243.67832852935
# RUN  10 , total integrated cost =  364243.67832852935
# Improved over  10  iterations in  4.582089411007473  seconds by  49.999376832746776  percent.
# uncontrolled cost :  731389.2794883196
# cost splitting :  473.2514048043269 [3.91632112 0.        ]
# set cost params:  1.0 0.0 99000.0
# interpolate adjoint :  True True True
# initial cost =  728478.2773809158
# RUN  0 , total integrated cost =  728478.2773809158
# Gradient descend method:  None
# RUN  1 , total integrated cost =  572256.3191073106
# RUN  2 , total integrated cost =  508045.8028867385
# RUN  3 , total integrated cost =  477089.4026861256
# RUN  4 , total integrated cost =  453563.0504448754
# RUN  5 , total integrated cost =  436942.5580873102
# RUN  6 , total integrated cost =  424685.00476504763
# RUN  7 , total integrated cost =  414444.4213922053
# RUN  8 , total integrated cost =  406300.80463507224
# RUN  9 , total integrated cost =  399073.4789153708
# RUN  10 , total integrated cost =  393358.27335833455
# RUN  10 , total integrated cost =  393358.27335833455
# Improved over  10  iterations in  4.504012413992314  seconds by  46.00274495863238  percent.
# sparsity weight =  99000.0
# -------  82 0.5750000000000002 0.7000000000000004
# set cost params:  1.0 0.0 100000.0
# interpolate adjoint :  True True True
# initial cost =  854238.9955664313
# RUN  0 , total integrated cost =  854238.9955664313
# Gradient descend method:  None
# RUN  1 , total integrated cost =  408851.69149008224
# RUN  2 , total integrated cost =  386608.35260303604
# RUN  3 , total integrated cost =  368098.9781377928
# RUN  4 , total integrated cost =  353141.4338650095
# RUN  5 , total integrated cost =  339359.10283035226
# RUN  6 , total integrated cost =  328384.748875176
# RUN  7 , total integrated cost =  317843.6061236195
# RUN  8 , total integrated cost =  309291.73669906467
# RUN  9 , total integrated cost =  300227.73976300657
# RUN  10 , total integrated cost =  292812.1719984417
# RUN  10 , total integrated cost =  292812.1719984417
# Improved over  10  iterations in  4.495221812976524  seconds by  65.72245314037872  percent.
# uncontrolled cost :  857652.5380062738
# cost splitting :  505.89320728700585 [2.80225247 0.        ]
# set cost params:  1.0 0.0 900000.0
# interpolate adjoint :  True True True
# initial cost =  854238.9955664313
# RUN  0 , total integrated cost =  854238.9955664313
# Gradient descend method:  None
# RUN  1 , total integrated cost =  854238.9955664313
# Control only changes marginally.
# RUN  1 , total integrated cost =  854238.9955664313
# Improved over  1  iterations in  0.8046285820018966  seconds by  0.0  percent.
# uncontrolled cost :  857652.5380062738
# cost splitting :  34333.54091358782 [0. 0.]
# set cost params:  1.0 0.0 800000.0
# interpolate adjoint :  True True True
# initial cost =  854238.9955664313
# RUN  0 , total integrated cost =  854238.9955664313
# Gradient descend method:  None
# RUN  1 , total integrated cost =  854238.9955664313
# Control only changes marginally.
# RUN  1 , total integrated cost =  854238.9955664313
# Improved over  1  iterations in  0.8027831829967909  seconds by  0.0  percent.
# uncontrolled cost :  857652.5380062738
# cost splitting :  34333.54091358782 [0. 0.]
# set cost params:  1.0 0.0 700000.0
# interpolate adjoint :  True True True
# initial cost =  854238.9955664313
# RUN  0 , total integrated cost =  854238.9955664313
# Gradient descend method:  None
# RUN  1 , total integrated cost =  854238.9955664313
# Control only changes marginally.
# RUN  1 , total integrated cost =  854238.9955664313
# Improved over  1  iterations in  0.8078216399881057  seconds by  0.0  percent.
# uncontrolled cost :  857652.5380062738
# cost splitting :  34333.54091358782 [0. 0.]
# set cost params:  1.0 0.0 600000.0
# interpolate adjoint :  True True True
# initial cost =  854238.9955664313
# RUN  0 , total integrated cost =  854238.9955664313
# Gradient descend method:  None
# RUN  1 , total integrated cost =  854238.9955664313
# Control only changes marginally.
# RUN  1 , total integrated cost =  854238.9955664313
# Improved over  1  iterations in  0.8317671800032258  seconds by  0.0  percent.
# uncontrolled cost :  857652.5380062738
# cost splitting :  34333.54091358782 [0. 0.]
# set cost params:  1.0 0.0 500000.0
# interpolate adjoint :  True True True
# initial cost =  854238.9955664313
# RUN  0 , total integrated cost =  854238.9955664313
# Gradient descend method:  None
# RUN  1 , total integrated cost =  854238.9955664313
# Control only changes marginally.
# RUN  1 , total integrated cost =  854238.9955664313
# Improved over  1  iterations in  0.8050050140009262  seconds by  0.0  percent.
# uncontrolled cost :  857652.5380062738
# cost splitting :  34333.54091358782 [0. 0.]
# set cost params:  1.0 0.0 400000.0
# interpolate adjoint :  True True True
# initial cost =  854238.9955664313
# RUN  0 , total integrated cost =  854238.9955664313
# Gradient descend method:  None
# RUN  1 , total integrated cost =  854238.9955664313
# Control only changes marginally.
# RUN  1 , total integrated cost =  854238.9955664313
# Improved over  1  iterations in  0.7746415659785271  seconds by  0.0  percent.
# uncontrolled cost :  857652.5380062738
# cost splitting :  34333.54091358782 [0. 0.]
# set cost params:  1.0 0.0 300000.0
# interpolate adjoint :  True True True
# initial cost =  854238.9955664313
# RUN  0 , total integrated cost =  854238.9955664313
# Gradient descend method:  None
# RUN  1 , total integrated cost =  854238.9955664313
# Control only changes marginally.
# RUN  1 , total integrated cost =  854238.9955664313
# Improved over  1  iterations in  0.8281305909913499  seconds by  0.0  percent.
# uncontrolled cost :  857652.5380062738
# cost splitting :  34333.54091358782 [0. 0.]
# set cost params:  1.0 0.0 200000.0
# interpolate adjoint :  True True True
# initial cost =  854238.9955664313
# RUN  0 , total integrated cost =  854238.9955664313
# Gradient descend method:  None
# RUN  1 , total integrated cost =  854238.9955664313
# Control only changes marginally.
# RUN  1 , total integrated cost =  854238.9955664313
# Improved over  1  iterations in  0.8254006629867945  seconds by  0.0  percent.
# uncontrolled cost :  857652.5380062738
# cost splitting :  34333.54091358782 [0. 0.]
# set cost params:  1.0 0.0 100000.0
# interpolate adjoint :  True True True
# initial cost =  854238.9955664313
# RUN  0 , total integrated cost =  854238.9955664313
# Gradient descend method:  None
# RUN  1 , total integrated cost =  408851.69149008224
# RUN  2 , total integrated cost =  386608.35260303604
# RUN  3 , total integrated cost =  368098.9781377928
# RUN  4 , total integrated cost =  353141.4338650095
# RUN  5 , total integrated cost =  339359.10283035226
# RUN  6 , total integrated cost =  328384.748875176
# RUN  7 , total integrated cost =  317843.6061236195
# RUN  8 , total integrated cost =  309291.73669906467
# RUN  9 , total integrated cost =  300227.73976300657
# RUN  10 , total integrated cost =  292812.1719984417
# RUN  10 , total integrated cost =  292812.1719984417
# Improved over  10  iterations in  4.452327057020739  seconds by  65.72245314037872  percent.
# uncontrolled cost :  857652.5380062738
# cost splitting :  505.89320728700585 [2.80225247 0.        ]
# set cost params:  1.0 0.0 190000.0
# interpolate adjoint :  True True True
# initial cost =  854238.9955664313
# RUN  0 , total integrated cost =  854238.9955664313
# Gradient descend method:  None
# RUN  1 , total integrated cost =  854238.9955664313
# Control only changes marginally.
# RUN  1 , total integrated cost =  854238.9955664313
# Improved over  1  iterations in  1.0112068759917747  seconds by  0.0  percent.
# uncontrolled cost :  857652.5380062738
# cost splitting :  34333.54091358782 [0. 0.]
# set cost params:  1.0 0.0 180000.0
# interpolate adjoint :  True True True
# initial cost =  854238.9955664313
# RUN  0 , total integrated cost =  854238.9955664313
# Gradient descend method:  None
# RUN  1 , total integrated cost =  854238.9955664313
# Control only changes marginally.
# RUN  1 , total integrated cost =  854238.9955664313
# Improved over  1  iterations in  0.9188520859752316  seconds by  0.0  percent.
# uncontrolled cost :  857652.5380062738
# cost splitting :  34333.54091358782 [0. 0.]
# set cost params:  1.0 0.0 170000.0
# interpolate adjoint :  True True True
# initial cost =  854238.9955664313
# RUN  0 , total integrated cost =  854238.9955664313
# Gradient descend method:  None
# RUN  1 , total integrated cost =  854238.9955664313
# Control only changes marginally.
# RUN  1 , total integrated cost =  854238.9955664313
# Improved over  1  iterations in  0.8391542480094358  seconds by  0.0  percent.
# uncontrolled cost :  857652.5380062738
# cost splitting :  34333.54091358782 [0. 0.]
# set cost params:  1.0 0.0 160000.0
# interpolate adjoint :  True True True
# initial cost =  854238.9955664313
# RUN  0 , total integrated cost =  854238.9955664313
# Gradient descend method:  None
# RUN  1 , total integrated cost =  854238.9955664313
# Control only changes marginally.
# RUN  1 , total integrated cost =  854238.9955664313
# Improved over  1  iterations in  0.918680831004167  seconds by  0.0  percent.
# uncontrolled cost :  857652.5380062738
# cost splitting :  34333.54091358782 [0. 0.]
# set cost params:  1.0 0.0 150000.0
# interpolate adjoint :  True True True
# initial cost =  854238.9955664313
# RUN  0 , total integrated cost =  854238.9955664313
# Gradient descend method:  None
# RUN  1 , total integrated cost =  580937.0754506582
# RUN  2 , total integrated cost =  536929.5929283468
# RUN  3 , total integrated cost =  507607.8355900805
# RUN  4 , total integrated cost =  483649.38271284994
# RUN  5 , total integrated cost =  461527.2450169875
# RUN  6 , total integrated cost =  444993.3850502233
# RUN  7 , total integrated cost =  429987.93036880787
# RUN  8 , total integrated cost =  418677.077544201
# RUN  9 , total integrated cost =  407442.0354758637
# RUN  10 , total integrated cost =  399061.84312419774
# RUN  10 , total integrated cost =  399061.84312419774
# Improved over  10  iterations in  4.389586512988899  seconds by  53.28452046846836  percent.
# sparsity weight =  150000.0

# %%
for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    aln.params.duration = dur
    max_it = int(30)
    k = 0
    
    while not conv[i]:
        if k > 4:
            break
        weight_ = ( cost_uncontrolled[i] - costnode_[i][0][0][0][0] ) / sum( costnode_[i][0][2][0][:] )
            # weight_ = (factor_we * weights_init[i][1] * cost_uncontrolled[i] / cost_init[i][-j]
            #           + factor_ws * weights_init[i][2] * cost_uncontrolled[i] / cost_init[i][-j]) - 1

        print("weight = ", weight_)
        cost.setParams(1., weight_ * factor_we, weight_ * factor_ws)
        weights_[i][j] = cost.getParams()

        setinit(initVars[i], aln)

        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        control0 = aln.getZeroControl()
        control0 = bestControl_[i][0][:,:,n_pre-1:-n_post+1]

        bestControl_[i][j], bestState_[i][j], cost_[i][j], runtime_, grad_, phi_, phi1_, costnode_[i][j] = aln.A1(
            control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cvar,
            prec_variables_ = p_var, transition_time_ = t0_)
        
        if cost_[i][j][2] == 0.:
            conv[i] = True

        print('uncontrolled cost : ', cost_uncontrolled[i])
        print('cost splitting : ', costnode_[i][j][0][0][0], costnode_[i][j][2][0][:2])

        time_ = np.arange(-dur_pre,round(dur+dur_post+aln.params.dt,1),aln.params.dt)
        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        if True:
            fig, ax = plt.subplots(2,1, constrained_layout=True, figsize = (4,4) )
            ax[1].plot(time_, bestControl_[i][j][0,0,:], color = 'red')
            ax[0].plot(time_, bestState_[i][j][0,0,:], color= 'red')
            ax[1].plot(time_, bestControl_[i][j][0,1,:], color = 'blue')
            ax[0].plot(time_, bestState_[i][j][0,1,:], color= 'blue')
            ax[0].plot(time_, target_[0,0,:], linestyle = '--', color='red')
            ax[0].plot(time_, target_[0,1,:], linestyle = '--', color='blue')
            ax[0].set_xlim(-dur_pre,dur+dur_post)
            ax[1].set_xlim(-dur_pre,dur+dur_post)
            ax[0].axvspan(dur*t_pen[j], dur, alpha=0.2, color='gray')
            plt.show()

        with open(file_,'wb') as f:
            pickle.dump([bestControl_, bestState_, cost_, costnode_, weights_], f)
        
        k += 1
# Out:
# -------  10 0.4250000000000001 0.42500000000000016
# weight =  92714.27506421239
# set cost params:  1.0 0.0 92714.27506421239
# interpolate adjoint :  True True True
# initial cost =  228929.43478166344
# RUN  0 , total integrated cost =  228929.43478166344
# Gradient descend method:  None
# RUN  1 , total integrated cost =  228925.51170311848
# RUN  2 , total integrated cost =  228921.87246077272
# RUN  3 , total integrated cost =  228389.90990182318
# RUN  4 , total integrated cost =  228377.05711129462
# RUN  5 , total integrated cost =  228358.23457780675
# RUN  6 , total integrated cost =  228341.27799617746
# RUN  7 , total integrated cost =  228328.69122740257
# RUN  8 , total integrated cost =  228315.91305342867
# RUN  9 , total integrated cost =  228304.87998404523
# RUN  10 , total integrated cost =  228293.57437570704
# RUN  11 , total integrated cost =  228288.01576628245
# RUN  12 , total integrated cost =  228282.81946538266
# RUN  13 , total integrated cost =  228277.66415605933
# RUN  14 , total integrated cost =  228272.64115373517
# RUN  15 , total integrated cost =  228268.6411873128
# RUN  16 , total integrated cost =  228264.78453460833
# RUN  17 , total integrated cost =  228260.8017667254
# RUN  18 , total integrated cost =  228256.4666836516
# RUN  19 , total integrated cost =  228253.56985641774
# RUN  20 , total integrated cost =  228250.57375166472
# RUN  30 , total integrated cost =  228233.50955896493
# RUN  30 , total integrated cost =  228233.50955896493
# Improved over  30  iterations in  11.667918959981762  seconds by  0.3039911505317008  percent.
# uncontrolled cost :  227604.36517255512
# cost splitting :  290.8986199297834 [1.30066082e-16 2.44601146e+00]
# weight =  92932.29843449224
# set cost params:  1.0 0.0 92932.29843449224
# interpolate adjoint :  True True True
# initial cost =  228766.79722022658
# RUN  0 , total integrated cost =  228766.79722022658
# Gradient descend method:  None
# RUN  1 , total integrated cost =  228765.7266625722
# RUN  2 , total integrated cost =  228764.5520173769
# RUN  3 , total integrated cost =  228763.51123704482
# RUN  4 , total integrated cost =  228762.37831084782
# RUN  5 , total integrated cost =  228761.38534291953
# RUN  6 , total integrated cost =  228760.26654301758
# RUN  7 , total integrated cost =  228759.30715729273
# RUN  8 , total integrated cost =  228758.23577522158
# RUN  9 , total integrated cost =  228757.3110552031
# RUN  10 , total integrated cost =  228756.12012191702
# RUN  11 , total integrated cost =  228755.09865185872
# RUN  12 , total integrated cost =  228753.8448275585
# RUN  13 , total integrated cost =  228752.74351109023
# RUN  14 , total integrated cost =  228750.977743909
# RUN  15 , total integrated cost =  228749.22668494994
# RUN  16 , total integrated cost =  228747.51384866418
# RUN  17 , total integrated cost =  228746.04533757688
# RUN  18 , total integrated cost =  228744.3555982211
# RUN  19 , total integrated cost =  228742.80204876856
# RUN  20 , total integrated cost =  228740.19992598146
# RUN  30 , total integrated cost =  228445.17118173794
# RUN  30 , total integrated cost =  228445.17118173794
# Improved over  30  iterations in  16.96805294501246  seconds by  0.14059122320054485  percent.
# uncontrolled cost :  227604.36517255512
# cost splitting :  270.01027690071714 [9.72052723e-17 2.44367354e+00]
# weight =  93029.75668016603
# set cost params:  1.0 0.0 93029.75668016603
# interpolate adjoint :  True True True
# initial cost =  228683.3273180125
# RUN  0 , total integrated cost =  228683.3273180125
# Gradient descend method:  None
# RUN  1 , total integrated cost =  228682.62148107646
# RUN  2 , total integrated cost =  228681.80877900546
# RUN  3 , total integrated cost =  228681.10367909653
# RUN  4 , total integrated cost =  228680.24794697016
# RUN  5 , total integrated cost =  228679.49611492033
# RUN  6 , total integrated cost =  228678.47911118812
# RUN  7 , total integrated cost =  228677.53541671232
# RUN  8 , total integrated cost =  228676.5171091483
# RUN  9 , total integrated cost =  228675.56396514826
# RUN  10 , total integrated cost =  228674.25537173057
# RUN  11 , total integrated cost =  228673.04437469158
# RUN  12 , total integrated cost =  228670.82764014424
# RUN  13 , total integrated cost =  228668.87851822862
# RUN  14 , total integrated cost =  228663.3759355126
# RUN  15 , total integrated cost =  228658.04453260565
# RUN  16 , total integrated cost =  228638.82417265174
# RUN  17 , total integrated cost =  228622.11983733214
# RUN  18 , total integrated cost =  228518.95891121367
# RUN  19 , total integrated cost =  228472.42071005382
# RUN  20 , total integrated cost =  228467.2382011199
# RUN  30 , total integrated cost =  228231.46838313172
# RUN  30 , total integrated cost =  228231.46838313172
# Improved over  30  iterations in  17.801566361973528  seconds by  0.19759155167984943  percent.
# uncontrolled cost :  227604.36517255512
# cost splitting :  230.7537233706112 [1.39320186e-16 2.44092460e+00]
# weight =  93150.60825820535
# set cost params:  1.0 0.0 93150.60825820535
# interpolate adjoint :  True True True
# initial cost =  228526.4579732369
# RUN  0 , total integrated cost =  228526.4579732369
# Gradient descend method:  None
# RUN  1 , total integrated cost =  228525.51128056523
# RUN  2 , total integrated cost =  228524.80240023122
# RUN  3 , total integrated cost =  228523.94696726187
# RUN  4 , total integrated cost =  228523.24382171166
# RUN  5 , total integrated cost =  228522.40632799934
# RUN  6 , total integrated cost =  228521.6871796783
# RUN  7 , total integrated cost =  228520.74540921595
# RUN  8 , total integrated cost =  228519.91375921972
# RUN  9 , total integrated cost =  228518.4713129964
# RUN  10 , total integrated cost =  228517.17194038376
# RUN  11 , total integrated cost =  228515.574026426
# RUN  12 , total integrated cost =  228514.0684843637
# RUN  13 , total integrated cost =  228510.36813400843
# RUN  14 , total integrated cost =  228507.0178626136
# RUN  15 , total integrated cost =  228504.0246411652
# RUN  16 , total integrated cost =  228501.27994682261
# RUN  17 , total integrated cost =  228497.6737635572
# RUN  18 , total integrated cost =  228494.20398711914
# RUN  19 , total integrated cost =  228462.4656695036
# RUN  20 , total integrated cost =  228442.61543358638
# RUN  30 , total integrated cost =  228421.43472615277
# RUN  30 , total integrated cost =  228421.43472615277
# Improved over  30  iterations in  17.06735806001234  seconds by  0.04595671241550292  percent.
# uncontrolled cost :  227604.36517255512
# cost splitting :  233.73635733434813 [2.60435779e-16 2.43963718e+00]
# weight =  93198.54237948883
# set cost params:  1.0 0.0 93198.54237948883
# interpolate adjoint :  True True True
# initial cost =  228538.37659047457
# RUN  0 , total integrated cost =  228538.37659047457
# Gradient descend method:  None
# RUN  1 , total integrated cost =  228538.01015111778
# RUN  2 , total integrated cost =  228537.55168766374
# RUN  3 , total integrated cost =  228537.18316343045
# RUN  4 , total integrated cost =  228536.70334188535
# RUN  5 , total integrated cost =  228536.2879577564
# RUN  6 , total integrated cost =  228535.6444790817
# RUN  7 , total integrated cost =  228535.05857740194
# RUN  8 , total integrated cost =  228534.31616962104
# RUN  9 , total integrated cost =  228533.71522676013
# RUN  10 , total integrated cost =  228532.98509781322
# RUN  11 , total integrated cost =  228532.39129303847
# RUN  12 , total integrated cost =  228531.54210709158
# RUN  13 , total integrated cost =  228530.81937344768
# RUN  14 , total integrated cost =  228529.0815194723
# RUN  15 , total integrated cost =  228527.52454181892
# RUN  16 , total integrated cost =  228525.90858181065
# RUN  17 , total integrated cost =  228524.48448221377
# RUN  18 , total integrated cost =  228523.48292653912
# RUN  19 , total integrated cost =  228522.56717929905
# RUN  20 , total integrated cost =  228517.46273605016
# RUN  30 , total integrated cost =  228103.29628351034
# RUN  30 , total integrated cost =  228103.29628351034
# Improved over  30  iterations in  15.65205857498222  seconds by  0.1903751630054984  percent.
# uncontrolled cost :  227604.36517255512
# cost splitting :  192.56089439472908 [9.32674853e-17 2.43717611e+00]
# -------  20 0.4500000000000001 0.4750000000000002
# weight =  92921.85701922739
# set cost params:  1.0 0.0 92921.85701922739
# interpolate adjoint :  True True True
# initial cost =  320839.521228785
# RUN  0 , total integrated cost =  320839.521228785
# Gradient descend method:  None
# RUN  1 , total integrated cost =  320755.9340517027
# RUN  2 , total integrated cost =  320662.82861120923
# RUN  3 , total integrated cost =  320587.1348022513
# RUN  4 , total integrated cost =  320496.67790616676
# RUN  5 , total integrated cost =  320420.2676309069
# RUN  6 , total integrated cost =  320366.3444469762
# RUN  7 , total integrated cost =  320319.60599512357
# RUN  8 , total integrated cost =  320241.9654383854
# RUN  9 , total integrated cost =  320175.6969195038
# RUN  10 , total integrated cost =  320059.6558956852
# RUN  11 , total integrated cost =  319971.82065775216
# RUN  12 , total integrated cost =  319783.5944659807
# RUN  13 , total integrated cost =  319663.9937798729
# RUN  14 , total integrated cost =  319628.5963619484
# RUN  15 , total integrated cost =  319595.19862360985
# RUN  16 , total integrated cost =  319586.15233036026
# RUN  17 , total integrated cost =  319576.83505344676
# RUN  18 , total integrated cost =  319567.97334181477
# RUN  19 , total integrated cost =  319558.56762782397
# RUN  20 , total integrated cost =  319547.9923248342
# RUN  30 , total integrated cost =  319475.50031746447
# RUN  30 , total integrated cost =  319475.50031746447
# Improved over  30  iterations in  17.080704837979283  seconds by  0.4251411752817802  percent.
# uncontrolled cost :  318198.4034356064
# cost splitting :  490.7866345965309 [1.88179105e-16 3.41172183e+00]
# weight =  93122.36822873261
# set cost params:  1.0 0.0 93122.36822873261
# interpolate adjoint :  True True True
# initial cost =  320159.58878863946
# RUN  0 , total integrated cost =  320159.58878863946
# Gradient descend method:  None
# RUN  1 , total integrated cost =  320154.85353785096
# RUN  2 , total integrated cost =  320150.08490717196
# RUN  3 , total integrated cost =  320145.0145492485
# RUN  4 , total integrated cost =  320141.1322007973
# RUN  5 , total integrated cost =  320136.8200130059
# RUN  6 , total integrated cost =  320133.2084919948
# RUN  7 , total integrated cost =  320129.23783853994
# RUN  8 , total integrated cost =  320125.85647935554
# RUN  9 , total integrated cost =  320122.1114971728
# RUN  10 , total integrated cost =  320118.78168200026
# RUN  11 , total integrated cost =  320115.23528051854
# RUN  12 , total integrated cost =  320112.0236859631
# RUN  13 , total integrated cost =  320108.2048186205
# RUN  14 , total integrated cost =  320104.80032018566
# RUN  15 , total integrated cost =  320100.4843319369
# RUN  16 , total integrated cost =  320096.4907605802
# RUN  17 , total integrated cost =  320091.71532503905
# RUN  18 , total integrated cost =  320087.4109105987
# RUN  19 , total integrated cost =  320082.7151427203
# RUN  20 , total integrated cost =  320078.6061589943
# RUN  30 , total integrated cost =  319960.1120997421
# RUN  30 , total integrated cost =  319960.1120997421
# Improved over  30  iterations in  17.98075895398506  seconds by  0.06230539264873869  percent.
# uncontrolled cost :  318198.4034356064
# cost splitting :  498.9042402214784 [1.99394386e-16 3.40914423e+00]
# weight =  93190.39546889224
# set cost params:  1.0 0.0 93190.39546889224
# interpolate adjoint :  True True True
# initial cost =  320192.02677315474
# RUN  0 , total integrated cost =  320192.02677315474
# Gradient descend method:  None
# RUN  1 , total integrated cost =  320177.9485535419
# RUN  2 , total integrated cost =  320165.2001053368
# RUN  3 , total integrated cost =  319493.4309046135
# RUN  4 , total integrated cost =  319454.0113682271
# RUN  5 , total integrated cost =  319415.9805514935
# RUN  6 , total integrated cost =  319374.3969735513
# RUN  7 , total integrated cost =  319338.64759268647
# RUN  8 , total integrated cost =  319299.3698395653
# RUN  9 , total integrated cost =  319265.7263550765
# RUN  10 , total integrated cost =  319230.69685965794
# RUN  11 , total integrated cost =  319198.5804186022
# RUN  12 , total integrated cost =  319165.2384040616
# RUN  13 , total integrated cost =  319134.7411796934
# RUN  14 , total integrated cost =  319102.86448910355
# RUN  15 , total integrated cost =  319072.73438686365
# RUN  16 , total integrated cost =  319041.3811068169
# RUN  17 , total integrated cost =  319014.41924219206
# RUN  18 , total integrated cost =  318985.85668878997
# RUN  19 , total integrated cost =  318959.96669288387
# RUN  20 , total integrated cost =  318933.18397246196
# RUN  30 , total integrated cost =  318713.8963447833
# RUN  30 , total integrated cost =  318713.8963447833
# Improved over  30  iterations in  18.07979840799817  seconds by  0.4616387370003565  percent.
# uncontrolled cost :  318198.4034356064
# cost splitting :  384.97597609972945 [2.21649137e-16 3.39939060e+00]
# weight =  93491.29429122513
# set cost params:  1.0 0.0 93491.29429122513
# interpolate adjoint :  True True True
# initial cost =  319736.7689744665
# RUN  0 , total integrated cost =  319736.7689744665
# Gradient descend method:  None
# RUN  1 , total integrated cost =  319719.77447993634
# RUN  2 , total integrated cost =  319701.68969331804
# RUN  3 , total integrated cost =  319685.34471119335
# RUN  4 , total integrated cost =  319667.9792850644
# RUN  5 , total integrated cost =  319652.44201061496
# RUN  6 , total integrated cost =  319635.53086999914
# RUN  7 , total integrated cost =  319620.57518986746
# RUN  8 , total integrated cost =  319604.3889525357
# RUN  9 , total integrated cost =  319590.09500156983
# RUN  10 , total integrated cost =  319574.1795468915
# RUN  11 , total integrated cost =  319560.4193340277
# RUN  12 , total integrated cost =  319545.11858778796
# RUN  13 , total integrated cost =  319531.74842546484
# RUN  14 , total integrated cost =  319517.2284753646
# RUN  15 , total integrated cost =  319504.499633959
# RUN  16 , total integrated cost =  319490.74575050495
# RUN  17 , total integrated cost =  319478.46281605953
# RUN  18 , total integrated cost =  319465.1142123865
# RUN  19 , total integrated cost =  319453.0052809679
# RUN  20 , total integrated cost =  319440.13494131266
# RUN  30 , total integrated cost =  319316.9713615159
# RUN  30 , total integrated cost =  319316.9713615159
# Improved over  30  iterations in  15.677759949991014  seconds by  0.13129475671411228  percent.
# uncontrolled cost :  318198.4034356064
# cost splitting :  390.66329313033856 [1.85046727e-16 3.39459645e+00]
# weight =  93621.65563480677
# set cost params:  1.0 0.0 93621.65563480677
# interpolate adjoint :  True True True
# initial cost =  319759.4955160473
# RUN  0 , total integrated cost =  319759.4955160473
# Gradient descend method:  None
# RUN  1 , total integrated cost =  319747.8190622576
# RUN  2 , total integrated cost =  319733.96828569577
# RUN  3 , total integrated cost =  319721.87474234053
# RUN  4 , total integrated cost =  319708.1480389712
# RUN  5 , total integrated cost =  319695.6161934696
# RUN  6 , total integrated cost =  319680.1200701462
# RUN  7 , total integrated cost =  319666.1803720564
# RUN  8 , total integrated cost =  319652.677371433
# RUN  9 , total integrated cost =  319640.2161077653
# RUN  10 , total integrated cost =  319626.5350429093
# RUN  11 , total integrated cost =  319614.5971223977
# RUN  12 , total integrated cost =  319601.0235782267
# RUN  13 , total integrated cost =  319588.93156864593
# RUN  14 , total integrated cost =  319578.1777399944
# RUN  15 , total integrated cost =  319568.38507456303
# RUN  16 , total integrated cost =  319557.26596886973
# RUN  17 , total integrated cost =  319546.79757302447
# RUN  18 , total integrated cost =  319535.7545836998
# RUN  19 , total integrated cost =  319526.20464729075
# RUN  20 , total integrated cost =  319515.02693928714
# RUN  30 , total integrated cost =  319405.1229977086
# RUN  30 , total integrated cost =  319405.1229977086
# Improved over  30  iterations in  18.65589100299985  seconds by  0.1108247052262783  percent.
# uncontrolled cost :  318198.4034356064
# cost splitting :  385.26818608264443 [1.85046727e-16 3.39109920e+00]
# -------  30 0.4250000000000001 0.5250000000000002
# weight =  32732.649590943518
# set cost params:  1.0 0.0 32732.649590943518
# interpolate adjoint :  True True True
# initial cost =  200290.08145948185
# RUN  0 , total integrated cost =  200290.08145948185
# Gradient descend method:  None
# RUN  1 , total integrated cost =  200269.8682830949
# RUN  2 , total integrated cost =  200244.18636057372
# RUN  3 , total integrated cost =  200220.4122680492
# RUN  4 , total integrated cost =  200195.68817594458
# RUN  5 , total integrated cost =  200172.03754774568
# RUN  6 , total integrated cost =  200046.44985073063
# RUN  7 , total integrated cost =  199946.58642561373
# RUN  8 , total integrated cost =  199905.93029631604
# RUN  9 , total integrated cost =  199867.2632593875
# RUN  10 , total integrated cost =  199733.96667035847
# RUN  11 , total integrated cost =  199646.80860821484
# RUN  12 , total integrated cost =  199614.6523464492
# RUN  13 , total integrated cost =  199582.55350762434
# RUN  14 , total integrated cost =  199536.47559890212
# RUN  15 , total integrated cost =  199492.20929640232
# RUN  16 , total integrated cost =  199477.49829368477
# RUN  17 , total integrated cost =  199461.8436228822
# RUN  18 , total integrated cost =  199456.23694162988
# RUN  19 , total integrated cost =  199450.74183313013
# RUN  20 , total integrated cost =  199443.0614589671
# RUN  30 , total integrated cost =  199377.6608818945
# RUN  30 , total integrated cost =  199377.6608818945
# Improved over  30  iterations in  18.68741868500365  seconds by  0.45554955639275363  percent.
# uncontrolled cost :  199298.52260795745
# cost splitting :  148.25498448043123 [6.06846622e+00 2.26299489e-16]
# weight =  32817.23261698805
# set cost params:  1.0 0.0 32817.23261698805
# interpolate adjoint :  True True True
# initial cost =  199890.95011836872
# RUN  0 , total integrated cost =  199890.95011836872
# Gradient descend method:  None
# RUN  1 , total integrated cost =  199884.8712653644
# RUN  2 , total integrated cost =  199881.4400696638
# RUN  3 , total integrated cost =  199878.121066919
# RUN  4 , total integrated cost =  199874.88919991188
# RUN  5 , total integrated cost =  199871.46965670807
# RUN  6 , total integrated cost =  199868.1338761032
# RUN  7 , total integrated cost =  199864.56460351884
# RUN  8 , total integrated cost =  199861.44850410827
# RUN  9 , total integrated cost =  199858.1983007525
# RUN  10 , total integrated cost =  199855.15618803079
# RUN  11 , total integrated cost =  199851.53715096816
# RUN  12 , total integrated cost =  199848.4536924174
# RUN  13 , total integrated cost =  199845.0401862426
# RUN  14 , total integrated cost =  199842.0047464914
# RUN  15 , total integrated cost =  199838.71096704464
# RUN  16 , total integrated cost =  199836.1805003106
# RUN  17 , total integrated cost =  199833.60807859508
# RUN  18 , total integrated cost =  199831.15457506524
# RUN  19 , total integrated cost =  199828.7297158877
# RUN  20 , total integrated cost =  199826.41884856857
# RUN  30 , total integrated cost =  199804.286743099
# RUN  30 , total integrated cost =  199804.286743099
# Improved over  30  iterations in  18.01995166100096  seconds by  0.043355327101309626  percent.
# uncontrolled cost :  199298.52260795745
# cost splitting :  156.35451235173414 [6.06459238e+00 2.26299489e-16]
# weight =  32836.85951249619
# set cost params:  1.0 0.0 32836.85951249619
# interpolate adjoint :  True True True
# initial cost =  199923.31586410824
# RUN  0 , total integrated cost =  199923.31586410824
# Gradient descend method:  None
# RUN  1 , total integrated cost =  199920.89810351303
# RUN  2 , total integrated cost =  199918.76407777096
# RUN  3 , total integrated cost =  199916.46706561945
# RUN  4 , total integrated cost =  199914.33943017575
# RUN  5 , total integrated cost =  199912.09260455178
# RUN  6 , total integrated cost =  199910.01637368748
# RUN  7 , total integrated cost =  199907.69319150833
# RUN  8 , total integrated cost =  199905.59775817502
# RUN  9 , total integrated cost =  199903.1561658213
# RUN  10 , total integrated cost =  199900.91074744822
# RUN  11 , total integrated cost =  199898.4228610788
# RUN  12 , total integrated cost =  199896.16891854996
# RUN  13 , total integrated cost =  199893.70056469546
# RUN  14 , total integrated cost =  199891.38910213788
# RUN  15 , total integrated cost =  199888.40395899292
# RUN  16 , total integrated cost =  199885.59784016278
# RUN  17 , total integrated cost =  199882.06735786764
# RUN  18 , total integrated cost =  199878.78530715313
# RUN  19 , total integrated cost =  199873.96941585178
# RUN  20 , total integrated cost =  199869.62564857808
# RUN  30 , total integrated cost =  199613.04768651564
# RUN  30 , total integrated cost =  199613.04768651564
# Improved over  30  iterations in  17.71194059800473  seconds by  0.15519359322925652  percent.
# uncontrolled cost :  199298.52260795745
# cost splitting :  150.60724602995285 [6.05601803e+00 2.26299489e-16]
# weight =  32884.300269267726
# set cost params:  1.0 0.0 32884.300269267726
# interpolate adjoint :  True True True
# initial cost =  199900.3497649203
# RUN  0 , total integrated cost =  199900.3497649203
# Gradient descend method:  None
# RUN  1 , total integrated cost =  199893.49665376302
# RUN  2 , total integrated cost =  199886.12491999895
# RUN  3 , total integrated cost =  199881.23184680202
# RUN  4 , total integrated cost =  199876.49414874692
# RUN  5 , total integrated cost =  199873.40077987907
# RUN  6 , total integrated cost =  199870.1689220095
# RUN  7 , total integrated cost =  199867.7875330994
# RUN  8 , total integrated cost =  199865.1049408328
# RUN  9 , total integrated cost =  199863.13263970756
# RUN  10 , total integrated cost =  199861.03856914674
# RUN  11 , total integrated cost =  199859.270513263
# RUN  12 , total integrated cost =  199857.28395624092
# RUN  13 , total integrated cost =  199855.68846138916
# RUN  14 , total integrated cost =  199853.9604539518
# RUN  15 , total integrated cost =  199852.37548716454
# RUN  16 , total integrated cost =  199850.5158194238
# RUN  17 , total integrated cost =  199848.8471777885
# RUN  18 , total integrated cost =  199847.02239957376
# RUN  19 , total integrated cost =  199845.31551503623
# RUN  20 , total integrated cost =  199843.51168438297
# RUN  30 , total integrated cost =  199821.79911773698
# RUN  30 , total integrated cost =  199821.79911773698
# Improved over  30  iterations in  18.71413815600681  seconds by  0.0392949023229221  percent.
# uncontrolled cost :  199298.52260795745
# cost splitting :  159.42126004062908 [6.05229025e+00 2.26299489e-16]
# weight =  32903.098356885755
# set cost params:  1.0 0.0 32903.098356885755
# interpolate adjoint :  True True True
# initial cost =  199935.5706001278
# RUN  0 , total integrated cost =  199935.5706001278
# Gradient descend method:  None
# RUN  1 , total integrated cost =  199932.09908669323
# RUN  2 , total integrated cost =  199927.57618895822
# RUN  3 , total integrated cost =  199923.4854339158
# RUN  4 , total integrated cost =  199918.70596891808
# RUN  5 , total integrated cost =  199914.63957684874
# RUN  6 , total integrated cost =  199909.76236995723
# RUN  7 , total integrated cost =  199905.03530040322
# RUN  8 , total integrated cost =  199901.0083480163
# RUN  9 , total integrated cost =  199897.22717564504
# RUN  10 , total integrated cost =  199893.99103056305
# RUN  11 , total integrated cost =  199890.80122685328
# RUN  12 , total integrated cost =  199886.5144590097
# RUN  13 , total integrated cost =  199882.70880682569
# RUN  14 , total integrated cost =  199878.27634281348
# RUN  15 , total integrated cost =  199873.68318168147
# RUN  16 , total integrated cost =  199855.54393127048
# RUN  17 , total integrated cost =  199837.29586822813
# RUN  18 , total integrated cost =  199789.76866953465
# RUN  19 , total integrated cost =  199749.54751511212
# RUN  20 , total integrated cost =  199747.24124204708
# RUN  30 , total integrated cost =  199730.65530076632
# RUN  30 , total integrated cost =  199730.65530076632
# Improved over  30  iterations in  17.16613988301833  seconds by  0.10249066674148821  percent.
# uncontrolled cost :  199298.52260795745
# cost splitting :  130.4817272606009 [6.05045658e+00 2.26299489e-16]
# -------  40 0.5250000000000001 0.5500000000000003
# weight =  287760.12071522506
# set cost params:  1.0 0.0 287760.12071522506
# interpolate adjoint :  True True True
# initial cost =  638427.0596983145
# RUN  0 , total integrated cost =  638427.0596983145
# Gradient descend method:  None
# RUN  1 , total integrated cost =  638424.334518904
# RUN  2 , total integrated cost =  638403.9310913963
# RUN  3 , total integrated cost =  638387.1009455423
# RUN  4 , total integrated cost =  638371.3285319002
# RUN  5 , total integrated cost =  638354.4665215452
# RUN  6 , total integrated cost =  638350.5284984858
# RUN  7 , total integrated cost =  638346.562457441
# RUN  8 , total integrated cost =  638344.8150156302
# RUN  9 , total integrated cost =  638342.8954411914
# RUN  10 , total integrated cost =  638341.8948314174
# RUN  11 , total integrated cost =  638340.7556029684
# RUN  12 , total integrated cost =  638339.9102894604
# RUN  13 , total integrated cost =  638338.8989238576
# RUN  14 , total integrated cost =  638338.1298507793
# RUN  15 , total integrated cost =  638337.0456145707
# RUN  16 , total integrated cost =  638336.2679208455
# RUN  17 , total integrated cost =  638335.0120141603
# RUN  18 , total integrated cost =  638334.2276695211
# RUN  19 , total integrated cost =  638332.7274140785
# RUN  20 , total integrated cost =  638331.7608017717
# RUN  30 , total integrated cost =  637830.614517503
# RUN  30 , total integrated cost =  637830.614517503
# Improved over  30  iterations in  18.51891306199832  seconds by  0.09342416987986724  percent.
# uncontrolled cost :  637776.8232026608
# cost splitting :  136.44499418547557 [2.21416690e+00 1.70906606e-16]
# weight =  287982.07481763937
# set cost params:  1.0 0.0 287982.07481763937
# interpolate adjoint :  True True True
# initial cost =  638322.0579446607
# RUN  0 , total integrated cost =  638322.0579446607
# Gradient descend method:  None
# RUN  1 , total integrated cost =  638319.1652495558
# RUN  2 , total integrated cost =  638315.9543564223
# RUN  3 , total integrated cost =  638314.7507700012
# RUN  4 , total integrated cost =  638313.3892467323
# RUN  5 , total integrated cost =  638312.7695470916
# RUN  6 , total integrated cost =  638312.1084659628
# RUN  7 , total integrated cost =  638311.6175016749
# RUN  8 , total integrated cost =  638311.0453228274
# RUN  9 , total integrated cost =  638310.5888199554
# RUN  10 , total integrated cost =  638309.9642549442
# RUN  11 , total integrated cost =  638309.4380363183
# RUN  12 , total integrated cost =  638308.6944321395
# RUN  13 , total integrated cost =  638308.076851695
# RUN  14 , total integrated cost =  638306.9338068818
# RUN  15 , total integrated cost =  638305.9925419661
# RUN  16 , total integrated cost =  638301.0314357812
# RUN  17 , total integrated cost =  638297.0127563634
# RUN  18 , total integrated cost =  638273.7562289725
# RUN  19 , total integrated cost =  638248.9527481018
# RUN  20 , total integrated cost =  638223.5526789553
# RUN  30 , total integrated cost =  637638.8745449813
# RUN  30 , total integrated cost =  637638.8745449813
# Improved over  30  iterations in  17.38919284401345  seconds by  0.1070280105749788  percent.
# uncontrolled cost :  637776.8232026608
# cost splitting :  65.42871967234298 [2.21302660e+00 1.70906606e-16]
# weight =  288162.5525772049
# set cost params:  1.0 0.0 288162.5525772049
# interpolate adjoint :  True True True
# initial cost =  638038.2766279249
# RUN  0 , total integrated cost =  638038.2766279249
# Gradient descend method:  None
# RUN  1 , total integrated cost =  637952.6449475035
# RUN  2 , total integrated cost =  637603.8781784881
# RUN  3 , total integrated cost =  637545.1705804382
# RUN  4 , total integrated cost =  637544.716258258
# RUN  5 , total integrated cost =  637544.4438979493
# RUN  6 , total integrated cost =  637543.8005856823
# RUN  7 , total integrated cost =  637543.3170655807
# RUN  8 , total integrated cost =  637540.0174295614
# RUN  9 , total integrated cost =  637537.0624521468
# RUN  10 , total integrated cost =  636925.131540698
# RUN  11 , total integrated cost =  636893.9245649286
# RUN  12 , total integrated cost =  636811.1046897563
# RUN  13 , total integrated cost =  636713.4733780271
# RUN  14 , total integrated cost =  636666.399279125
# RUN  15 , total integrated cost =  636613.4324861879
# RUN  16 , total integrated cost =  636608.0331782983
# RUN  17 , total integrated cost =  636601.8784783336
# RUN  18 , total integrated cost =  636599.7726884502
# RUN  19 , total integrated cost =  636597.344874241
# RUN  20 , total integrated cost =  636595.5530239173
# RUN  30 , total integrated cost =  636581.5930307539
# RUN  30 , total integrated cost =  636581.5930307539
# Improved over  30  iterations in  18.202366778015858  seconds by  0.2283066158459377  percent.
# uncontrolled cost :  637776.8232026608
# cost splitting :  70.77936069806994 [2.20787876e+00 1.70906606e-16]
# weight =  288832.0027333164
# set cost params:  1.0 0.0 288832.0027333164
# interpolate adjoint :  True True True
# initial cost =  638059.6578108448
# RUN  0 , total integrated cost =  638059.6578108448
# Gradient descend method:  None
# RUN  1 , total integrated cost =  638058.4338319426
# RUN  2 , total integrated cost =  638057.3902787359
# RUN  3 , total integrated cost =  638056.1497183915
# RUN  4 , total integrated cost =  638055.0913719512
# RUN  5 , total integrated cost =  638053.8314420122
# RUN  6 , total integrated cost =  638052.6928812618
# RUN  7 , total integrated cost =  638051.0398751482
# RUN  8 , total integrated cost =  638049.6354258189
# RUN  9 , total integrated cost =  638047.7023307226
# RUN  10 , total integrated cost =  638046.1121171503
# RUN  11 , total integrated cost =  638042.6434990367
# RUN  12 , total integrated cost =  638039.4051683588
# RUN  13 , total integrated cost =  638023.5982821214
# RUN  14 , total integrated cost =  638010.0746001953
# RUN  15 , total integrated cost =  637991.1653088629
# RUN  16 , total integrated cost =  637970.9966051549
# RUN  17 , total integrated cost =  637965.9999883326
# RUN  18 , total integrated cost =  637960.7427857531
# RUN  19 , total integrated cost =  637955.434641641
# RUN  20 , total integrated cost =  637949.7586959263
# RUN  30 , total integrated cost =  637924.6179705674
# RUN  30 , total integrated cost =  637924.6179705674
# Improved over  30  iterations in  18.843909861985594  seconds by  0.02116414015904411  percent.
# uncontrolled cost :  637776.8232026608
# cost splitting :  76.04220287655778 [2.20732019e+00 1.70906606e-16]
# weight =  288902.7084603065
# set cost params:  1.0 0.0 288902.7084603065
# interpolate adjoint :  True True True
# initial cost =  638080.6881492204
# RUN  0 , total integrated cost =  638080.6881492204
# Gradient descend method:  None
# RUN  1 , total integrated cost =  638080.0061566685
# RUN  2 , total integrated cost =  638079.1094396762
# RUN  3 , total integrated cost =  638078.2641506619
# RUN  4 , total integrated cost =  638077.2726937403
# RUN  5 , total integrated cost =  638076.3163423088
# RUN  6 , total integrated cost =  638075.2215702028
# RUN  7 , total integrated cost =  638074.1880032785
# RUN  8 , total integrated cost =  638072.6232338747
# RUN  9 , total integrated cost =  638071.1591137795
# RUN  10 , total integrated cost =  638068.9164579017
# RUN  11 , total integrated cost =  638066.911962281
# RUN  12 , total integrated cost =  638064.6894989046
# RUN  13 , total integrated cost =  638062.7114439427
# RUN  14 , total integrated cost =  638059.4150428522
# RUN  15 , total integrated cost =  638056.1719967617
# RUN  16 , total integrated cost =  638052.0362925907
# RUN  17 , total integrated cost =  638048.2638342493
# RUN  18 , total integrated cost =  638045.5442528805
# RUN  19 , total integrated cost =  638042.7547734989
# RUN  20 , total integrated cost =  638040.040584463
# RUN  30 , total integrated cost =  637885.7021810161
# RUN  30 , total integrated cost =  637885.7021810161
# Improved over  30  iterations in  17.313425330008613  seconds by  0.030558199272562092  percent.
# uncontrolled cost :  637776.8232026608
# cost splitting :  71.0073151419697 [2.20673234e+00 1.70906606e-16]
# -------  50 0.47500000000000014 0.6000000000000003
# weight =  78854.5653825778
# set cost params:  1.0 0.0 78854.5653825778
# interpolate adjoint :  True True True
# initial cost =  398681.05981396075
# RUN  0 , total integrated cost =  398681.05981396075
# Gradient descend method:  None
# RUN  1 , total integrated cost =  398680.71543014416
# RUN  2 , total integrated cost =  398680.4375848112
# RUN  3 , total integrated cost =  398680.1217789613
# RUN  4 , total integrated cost =  398679.87035941565
# RUN  5 , total integrated cost =  398679.58158012957
# RUN  6 , total integrated cost =  398679.3450164586
# RUN  7 , total integrated cost =  398679.0505745618
# RUN  8 , total integrated cost =  398678.7845230363
# RUN  9 , total integrated cost =  398678.41605561203
# RUN  10 , total integrated cost =  398678.07491473516
# RUN  11 , total integrated cost =  398677.5135599375
# RUN  12 , total integrated cost =  398677.00973476697
# RUN  13 , total integrated cost =  398671.7235254847
# RUN  14 , total integrated cost =  398666.59273193957
# RUN  15 , total integrated cost =  398149.9869569157
# RUN  16 , total integrated cost =  398073.558241905
# RUN  17 , total integrated cost =  398065.93962062517
# RUN  18 , total integrated cost =  398059.10940951895
# RUN  19 , total integrated cost =  398045.4631846134
# RUN  20 , total integrated cost =  398032.527152392
# RUN  30 , total integrated cost =  397895.3783662568
# RUN  30 , total integrated cost =  397895.3783662568
# Improved over  30  iterations in  16.90557576797437  seconds by  0.19707017134714988  percent.
# uncontrolled cost :  398255.3453337311
# cost splitting :  81.22665478185914 [5.04079336e+00 2.35228744e-16]
# weight =  78990.36722080526
# set cost params:  1.0 0.0 78990.36722080526
# interpolate adjoint :  True True True
# initial cost =  398579.9273708215
# RUN  0 , total integrated cost =  398579.9273708215
# Gradient descend method:  None
# RUN  1 , total integrated cost =  398575.68556010746
# RUN  2 , total integrated cost =  398571.9405402414
# RUN  3 , total integrated cost =  398568.3366007101
# RUN  4 , total integrated cost =  398564.96328892413
# RUN  5 , total integrated cost =  398560.2735518694
# RUN  6 , total integrated cost =  398555.9309395225
# RUN  7 , total integrated cost =  398542.4915315167
# RUN  8 , total integrated cost =  398530.01571851724
# RUN  9 , total integrated cost =  398504.8830487953
# RUN  10 , total integrated cost =  398480.3478458511
# RUN  11 , total integrated cost =  398477.8356673005
# RUN  12 , total integrated cost =  398475.1621107229
# RUN  13 , total integrated cost =  398473.3920625861
# RUN  14 , total integrated cost =  398471.42821211694
# RUN  15 , total integrated cost =  398470.2587140284
# RUN  16 , total integrated cost =  398468.94398416555
# RUN  17 , total integrated cost =  398467.94021666993
# RUN  18 , total integrated cost =  398466.8430914683
# RUN  19 , total integrated cost =  398465.9494307667
# RUN  20 , total integrated cost =  398464.8676407164
# RUN  30 , total integrated cost =  398453.3608424223
# RUN  30 , total integrated cost =  398453.3608424223
# Improved over  30  iterations in  17.66555992301437  seconds by  0.031754365864344436  percent.
# uncontrolled cost :  398255.3453337311
# cost splitting :  86.13692646210751 [5.03888049e+00 2.35228744e-16]
# weight =  79019.3792193828
# set cost params:  1.0 0.0 79019.3792193828
# interpolate adjoint :  True True True
# initial cost =  398599.54883607716
# RUN  0 , total integrated cost =  398599.54883607716
# Gradient descend method:  None
# RUN  1 , total integrated cost =  398598.02035196277
# RUN  2 , total integrated cost =  398595.6015708996
# RUN  3 , total integrated cost =  398593.43867924996
# RUN  4 , total integrated cost =  398591.09062618954
# RUN  5 , total integrated cost =  398589.0089013616
# RUN  6 , total integrated cost =  398586.3238275158
# RUN  7 , total integrated cost =  398584.11139586696
# RUN  8 , total integrated cost =  398576.96049736935
# RUN  9 , total integrated cost =  398570.4351073111
# RUN  10 , total integrated cost =  398565.87477123435
# RUN  11 , total integrated cost =  398561.8414504622
# RUN  12 , total integrated cost =  398546.7480500406
# RUN  13 , total integrated cost =  398534.3682558102
# RUN  14 , total integrated cost =  398494.79299948964
# RUN  15 , total integrated cost =  398464.9885421688
# RUN  16 , total integrated cost =  398421.01129913615
# RUN  17 , total integrated cost =  398388.8558901134
# RUN  18 , total integrated cost =  398388.27199555637
# RUN  19 , total integrated cost =  398387.69652578904
# RUN  20 , total integrated cost =  398386.8382157988
# RUN  30 , total integrated cost =  398155.9354991582
# RUN  30 , total integrated cost =  398155.9354991582
# Improved over  30  iterations in  18.281940715998644  seconds by  0.11129298520640418  percent.
# uncontrolled cost :  398255.3453337311
# cost splitting :  43.11281101129247 [5.03598671e+00 2.35228744e-16]
# weight =  79073.32868652824
# set cost params:  1.0 0.0 79073.32868652824
# interpolate adjoint :  True True True
# initial cost =  398427.62429881113
# RUN  0 , total integrated cost =  398427.62429881113
# Gradient descend method:  None
# RUN  1 , total integrated cost =  398398.54338572646
# RUN  2 , total integrated cost =  398398.4767855809
# RUN  3 , total integrated cost =  398398.3443146108
# RUN  4 , total integrated cost =  398398.2448675719
# RUN  5 , total integrated cost =  398398.0451345898
# RUN  6 , total integrated cost =  398397.88573289977
# RUN  7 , total integrated cost =  398397.04339604836
# RUN  8 , total integrated cost =  398396.2315298761
# RUN  9 , total integrated cost =  398330.8077123619
# RUN  10 , total integrated cost =  398310.4042774724
# RUN  11 , total integrated cost =  398310.15612956206
# RUN  12 , total integrated cost =  398309.93218044867
# RUN  13 , total integrated cost =  398290.8712600242
# RUN  14 , total integrated cost =  398279.4873499523
# RUN  15 , total integrated cost =  398244.1405036424
# RUN  16 , total integrated cost =  398211.32940885826
# RUN  17 , total integrated cost =  398210.4868404426
# RUN  18 , total integrated cost =  398209.57752250275
# RUN  19 , total integrated cost =  398208.8167538377
# RUN  20 , total integrated cost =  398207.9752911763
# RUN  30 , total integrated cost =  398200.85539463646
# RUN  30 , total integrated cost =  398200.85539463646
# Improved over  30  iterations in  18.817382934008492  seconds by  0.05691595922189663  percent.
# uncontrolled cost :  398255.3453337311
# cost splitting :  70.81337617530569 [5.03136871e+00 2.35228744e-16]
# weight =  79140.39999315212
# set cost params:  1.0 0.0 79140.39999315212
# interpolate adjoint :  True True True
# initial cost =  398538.31586789817
# RUN  0 , total integrated cost =  398538.31586789817
# Gradient descend method:  None
# RUN  1 , total integrated cost =  398537.57624580985
# RUN  2 , total integrated cost =  398536.6197087299
# RUN  3 , total integrated cost =  398535.7877555431
# RUN  4 , total integrated cost =  398534.62189039326
# RUN  5 , total integrated cost =  398533.5965378169
# RUN  6 , total integrated cost =  398531.92974254984
# RUN  7 , total integrated cost =  398530.4096095116
# RUN  8 , total integrated cost =  398528.0387191791
# RUN  9 , total integrated cost =  398526.09450183454
# RUN  10 , total integrated cost =  398516.3912921432
# RUN  11 , total integrated cost =  398508.1447289726
# RUN  12 , total integrated cost =  398478.1081834601
# RUN  13 , total integrated cost =  398452.7267919921
# RUN  14 , total integrated cost =  398452.32291237346
# RUN  15 , total integrated cost =  398451.88563414477
# RUN  16 , total integrated cost =  398451.50417034305
# RUN  17 , total integrated cost =  398451.0993883119
# RUN  18 , total integrated cost =  398450.7889459426
# RUN  19 , total integrated cost =  398450.42833936773
# RUN  20 , total integrated cost =  398450.1548424791
# RUN  30 , total integrated cost =  398446.9844591226
# RUN  30 , total integrated cost =  398446.9844591226
# Improved over  30  iterations in  18.296338918997208  seconds by  0.022916594249338118  percent.
# uncontrolled cost :  398255.3453337311
# cost splitting :  61.60292002014046 [5.03079610e+00 2.35228744e-16]

# %%
conv_shift = [None] * len(exc)

# %%
for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    aln.params.duration = dur
    max_it = int(0)
    for l in range( bestControl_[i][j].shape[2] ):
        if np.abs(bestControl_[i][j][0,0,l]) > 1e-6 or np.abs(bestControl_[i][j][0,1,l]) > 1e-6:
            init_ind = l
            break
            
    print("init ind = ", init_ind)

    weight_ = ( cost_uncontrolled[i] - costnode_[i][0][0][0][0] ) / sum( costnode_[i][0][2][0][:] )
    print("weight = ", weight_)
    cost.setParams(1., weight_ * factor_we, weight_ * factor_ws)
    weights_[i][j] = cost.getParams()

    setinit(initVars[i], aln)

    target_ = aln.getZeroTarget()
    target_[:,0,:] = target[i][0]
    target_[:,1,:] = target[i][1]

    control0 = aln.getZeroControl()
    control0[:,:,:-init_ind] = bestControl_[i][0][:,:,n_pre-1+init_ind:-n_post+1]

    bestControl_[i][j], bestState_[i][j], cost_[i][j], runtime_, grad_, phi_, phi1_, costnode_[i][j] = aln.A1(
        control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cvar,
        prec_variables_ = p_var, transition_time_ = t0_)

    print('uncontrolled cost : ', cost_uncontrolled[i])
    print('cost splitting : ', costnode_[i][j][0][0][0], costnode_[i][j][2][0][:2])

    time_ = np.arange(-dur_pre,round(dur+dur_post+aln.params.dt,1),aln.params.dt)
    target_ = aln.getZeroTarget()
    target_[:,0,:] = target[i][0]
    target_[:,1,:] = target[i][1]

    if True:
        fig, ax = plt.subplots(2,1, constrained_layout=True, figsize = (4,4) )
        ax[1].plot(time_, bestControl_[i][j][0,0,:], color = 'red')
        ax[0].plot(time_, bestState_[i][j][0,0,:], color= 'red')
        ax[1].plot(time_, bestControl_[i][j][0,1,:], color = 'blue')
        ax[0].plot(time_, bestState_[i][j][0,1,:], color= 'blue')
        ax[0].plot(time_, target_[0,0,:], linestyle = '--', color='red')
        ax[0].plot(time_, target_[0,1,:], linestyle = '--', color='blue')
        ax[0].set_xlim(-dur_pre,dur+dur_post)
        ax[1].set_xlim(-dur_pre,dur+dur_post)
        ax[0].axvspan(dur*t_pen[j], dur, alpha=0.2, color='gray')
        plt.show()

    with open(file_,'wb') as f:
        pickle.dump([bestControl_, bestState_, cost_, costnode_, weights_], f)
# Out:
# -------  10 0.4250000000000001 0.42500000000000016
# init ind =  1606
# weight =  93309.5491445076
# set cost params:  1.0 0.0 93309.5491445076
# interpolate adjoint :  True True True
# initial cost =  227411.80413699997
# RUN  0 , total integrated cost =  227411.80413699997
# Gradient descend method:  None
# RUN  0 , total integrated cost =  227411.80413699997
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  227604.36517255512
# cost splitting :  5.409580727343191e-22 [9.32674853e-17 2.43717611e+00]
# -------  20 0.4500000000000001 0.4750000000000002
# init ind =  1579
# weight =  93719.79893664783
# set cost params:  1.0 0.0 93719.79893664783
# interpolate adjoint :  True True True
# initial cost =  317813.1351649595
# RUN  0 , total integrated cost =  317813.1351649595
# Gradient descend method:  None
# RUN  0 , total integrated cost =  317813.1351649595
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  318198.4034356064
# cost splitting :  4.94773559754618e-25 [1.85046727e-16 3.39109920e+00]
# -------  30 0.4250000000000001 0.5250000000000002
# init ind =  1377
# weight =  32917.85308060338
# set cost params:  1.0 0.0 32917.85308060338
# interpolate adjoint :  True True True
# initial cost =  199168.04086635663
# RUN  0 , total integrated cost =  199168.04086635663
# Gradient descend method:  None
# RUN  0 , total integrated cost =  199168.04086635663
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  199298.52260795745
# cost splitting :  4.207713091095357e-18 [6.05045658e+00 2.26299489e-16]
# -------  40 0.5250000000000001 0.5500000000000003
# init ind =  1156
# weight =  288981.95081194054
# set cost params:  1.0 0.0 288981.95081194054
# interpolate adjoint :  True True True
# initial cost =  637705.8154839656
# RUN  0 , total integrated cost =  637705.8154839656
# Gradient descend method:  None
# RUN  0 , total integrated cost =  637705.8154839656
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  637776.8232026608
# cost splitting :  7.148203719698906e-16 [2.20673234e+00 1.70906606e-16]
# -------  50 0.47500000000000014 0.6000000000000003
# init ind =  1162
# weight =  79151.23851675811
# set cost params:  1.0 0.0 79151.23851675811
# interpolate adjoint :  True True True
# initial cost =  398193.7423715037
# RUN  0 , total integrated cost =  398193.7423715037
# Gradient descend method:  None
# RUN  0 , total integrated cost =  398193.7423715037
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  398255.3453337311
# cost splitting :  2.3653519551409517e-17 [5.03079610e+00 2.35228744e-16]

# %%
for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    aln.params.duration = dur
    max_it = int(30)
    k = 0
    
    while not conv_shift[i]:
        if k > 4:
            break
            
        weight_ = ( cost_uncontrolled[i] - costnode_[i][0][0][0][0] ) / sum( costnode_[i][0][2][0][:] )
        print("weight = ", weight_)
        cost.setParams(1., weight_ * factor_we, weight_ * factor_ws)
        weights_[i][j] = cost.getParams()

        setinit(initVars[i], aln)

        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        control0 = aln.getZeroControl()
        
        control0 = bestControl_[i][0][:,:,n_pre-1:-n_post+1]

        bestControl_[i][j], bestState_[i][j], cost_[i][j], runtime_, grad_, phi_, phi1_, costnode_[i][j] = aln.A1(
            control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = cvar,
            prec_variables_ = p_var, transition_time_ = t0_)
        
        if cost_[i][j][2] == 0.:
            conv_shift[i] = True

        print('uncontrolled cost : ', cost_uncontrolled[i])
        print('cost splitting : ', costnode_[i][j][0][0][0], costnode_[i][j][2][0][:2])

        time_ = np.arange(-dur_pre,round(dur+dur_post+aln.params.dt,1),aln.params.dt)
        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        if True:
            fig, ax = plt.subplots(2,1, constrained_layout=True, figsize = (4,4) )
            ax[1].plot(time_, bestControl_[i][j][0,0,:], color = 'red')
            ax[0].plot(time_, bestState_[i][j][0,0,:], color= 'red')
            ax[1].plot(time_, bestControl_[i][j][0,1,:], color = 'blue')
            ax[0].plot(time_, bestState_[i][j][0,1,:], color= 'blue')
            ax[0].plot(time_, target_[0,0,:], linestyle = '--', color='red')
            ax[0].plot(time_, target_[0,1,:], linestyle = '--', color='blue')
            ax[0].set_xlim(-dur_pre,dur+dur_post)
            ax[1].set_xlim(-dur_pre,dur+dur_post)
            ax[0].axvspan(dur*t_pen[j], dur, alpha=0.2, color='gray')
            plt.show()

        with open(file_,'wb') as f:
            pickle.dump([bestControl_, bestState_, cost_, costnode_, weights_], f)
        
        k += 1
# Out:
# -------  10 0.4250000000000001 0.42500000000000016
# weight =  93388.5590423387
# set cost params:  1.0 0.0 93388.5590423387
# interpolate adjoint :  True True True
# initial cost =  227604.36517255512
# RUN  0 , total integrated cost =  227604.36517255512
# Gradient descend method:  None
# RUN  1 , total integrated cost =  224799.57886493273
# RUN  2 , total integrated cost =  224696.46172127017
# RUN  3 , total integrated cost =  224689.3724225412
# RUN  4 , total integrated cost =  224688.91392814324
# RUN  5 , total integrated cost =  224688.91391987115
# RUN  6 , total integrated cost =  224688.91391948602
# RUN  7 , total integrated cost =  224688.91379856187
# RUN  8 , total integrated cost =  224688.91366825483
# RUN  9 , total integrated cost =  224688.9136678642
# RUN  10 , total integrated cost =  224688.91366354967
# RUN  11 , total integrated cost =  224688.9136609492
# RUN  12 , total integrated cost =  224688.91366045873
# RUN  13 , total integrated cost =  224688.9136580423
# RUN  14 , total integrated cost =  224688.91365709392
# RUN  15 , total integrated cost =  224688.9136562573
# RUN  16 , total integrated cost =  224688.9136539591
# RUN  17 , total integrated cost =  224688.9136533916
# RUN  18 , total integrated cost =  224688.91365038414
# RUN  19 , total integrated cost =  224688.91364560954
# RUN  20 , total integrated cost =  224688.91364523434
# RUN  30 , total integrated cost =  224688.91299740825
# RUN  30 , total integrated cost =  224688.91299740825
# Improved over  30  iterations in  11.696861717995489  seconds by  1.280929815619558  percent.
# uncontrolled cost :  227604.36517255512
# cost splitting :  0.0035838432437072733 [1.23192429e-16 2.40595740e+00]
# weight =  94600.3288314247
# set cost params:  1.0 0.0 94600.3288314247
# interpolate adjoint :  True True True
# initial cost =  227604.37949360703
# RUN  0 , total integrated cost =  227604.37949360703
# Gradient descend method:  None
# RUN  1 , total integrated cost =  227604.3794913481
# RUN  2 , total integrated cost =  227604.37949071874
# RUN  3 , total integrated cost =  227604.37948920394
# RUN  4 , total integrated cost =  227604.3794861867
# RUN  5 , total integrated cost =  227604.37948575974
# RUN  6 , total integrated cost =  227604.37947242867
# RUN  7 , total integrated cost =  227604.3794557767
# RUN  8 , total integrated cost =  227604.37945541143
# RUN  9 , total integrated cost =  227604.3794508718
# RUN  10 , total integrated cost =  227604.3794482892
# RUN  11 , total integrated cost =  227604.37944784932
# RUN  12 , total integrated cost =  227604.3794451602
# RUN  13 , total integrated cost =  227604.37944392383
# RUN  14 , total integrated cost =  227604.379443186
# RUN  15 , total integrated cost =  227604.37944089036
# RUN  16 , total integrated cost =  227604.37944035404
# RUN  17 , total integrated cost =  227604.379438045
# RUN  18 , total integrated cost =  227604.37943393012
# RUN  19 , total integrated cost =  227604.3794335569
# RUN  20 , total integrated cost =  227604.3794027404
# RUN  30 , total integrated cost =  227604.37936310444
# RUN  30 , total integrated cost =  227604.37936310444
# Improved over  30  iterations in  15.80703956799698  seconds by  5.733747343583673e-08  percent.
# uncontrolled cost :  227604.36517255512
# cost splitting :  0.003603800459918483 [1.23192429e-16 2.40595740e+00]
# weight =  94600.32891881267
# set cost params:  1.0 0.0 94600.32891881267
# interpolate adjoint :  True True True
# initial cost =  227604.37957335616
# RUN  0 , total integrated cost =  227604.37957335616
# Gradient descend method:  None
# RUN  1 , total integrated cost =  227604.3795659775
# RUN  2 , total integrated cost =  227604.37955541906
# RUN  3 , total integrated cost =  227604.37955505657
# RUN  4 , total integrated cost =  227604.37953057804
# RUN  5 , total integrated cost =  227604.3795107299
# RUN  6 , total integrated cost =  227604.37951035265
# RUN  7 , total integrated cost =  227604.37950654665
# RUN  8 , total integrated cost =  227604.37950446722
# RUN  9 , total integrated cost =  227604.37950397385
# RUN  10 , total integrated cost =  227604.3795015041
# RUN  11 , total integrated cost =  227604.3795005942
# RUN  12 , total integrated cost =  227604.37949959317
# RUN  13 , total integrated cost =  227604.37949711698
# RUN  14 , total integrated cost =  227604.37949661785
# RUN  15 , total integrated cost =  227604.37948975922
# RUN  16 , total integrated cost =  227604.3794802326
# RUN  17 , total integrated cost =  227604.37947987596
# RUN  18 , total integrated cost =  227604.3794711583
# RUN  19 , total integrated cost =  227604.37946511531
# RUN  20 , total integrated cost =  227604.3794647446
# RUN  30 , total integrated cost =  227604.3794448137
# RUN  30 , total integrated cost =  227604.3794448137
# Improved over  30  iterations in  17.251994516002014  seconds by  5.6476267218386056e-08  percent.
# uncontrolled cost :  227604.36517255512
# cost splitting :  0.003626495468850865 [1.23192429e-16 2.40595740e+00]
# weight =  94600.32900993306
# set cost params:  1.0 0.0 94600.32900993306
# interpolate adjoint :  True True True
# initial cost =  227604.3796640455
# RUN  0 , total integrated cost =  227604.3796640455
# Gradient descend method:  None
# RUN  1 , total integrated cost =  227604.3796636107
# RUN  2 , total integrated cost =  227604.37965443096
# RUN  3 , total integrated cost =  227604.37964224847
# RUN  4 , total integrated cost =  227604.37964188674
# RUN  5 , total integrated cost =  227604.3796172146
# RUN  6 , total integrated cost =  227604.37959688072
# RUN  7 , total integrated cost =  227604.37959650447
# RUN  8 , total integrated cost =  227604.37959271617
# RUN  9 , total integrated cost =  227604.379590618
# RUN  10 , total integrated cost =  227604.37959012738
# RUN  11 , total integrated cost =  227604.37958766095
# RUN  12 , total integrated cost =  227604.3795867451
# RUN  13 , total integrated cost =  227604.37958575043
# RUN  14 , total integrated cost =  227604.3795832697
# RUN  15 , total integrated cost =  227604.37958276953
# RUN  16 , total integrated cost =  227604.3795759717
# RUN  17 , total integrated cost =  227604.37956638465
# RUN  18 , total integrated cost =  227604.379566028
# RUN  19 , total integrated cost =  227604.3795558978
# RUN  20 , total integrated cost =  227604.3795481539
# RUN  30 , total integrated cost =  227604.37951485344
# RUN  30 , total integrated cost =  227604.37951485344
# Improved over  30  iterations in  18.614206917001866  seconds by  6.554886056164833e-08  percent.
# uncontrolled cost :  227604.36517255512
# cost splitting :  0.0036973833633032888 [1.23192429e-16 2.40595739e+00]
# weight =  94600.3291896787
# set cost params:  1.0 0.0 94600.3291896787
# interpolate adjoint :  True True True
# initial cost =  227604.3799473138
# RUN  0 , total integrated cost =  227604.3799473138
# Gradient descend method:  None
# RUN  1 , total integrated cost =  227604.37994127345
# RUN  2 , total integrated cost =  227604.37994090247
# RUN  3 , total integrated cost =  227604.3799362288
# RUN  4 , total integrated cost =  227604.37993354138
# RUN  5 , total integrated cost =  227604.37993311085
# RUN  6 , total integrated cost =  227604.37993045
# RUN  7 , total integrated cost =  227604.37992924004
# RUN  8 , total integrated cost =  227604.3799284869
# RUN  9 , total integrated cost =  227604.37992619787
# RUN  10 , total integrated cost =  227604.3799255899
# RUN  11 , total integrated cost =  227604.37992403295
# RUN  12 , total integrated cost =  227604.37992097175
# RUN  13 , total integrated cost =  227604.37992053764
# RUN  14 , total integrated cost =  227604.37991135695
# RUN  15 , total integrated cost =  227604.37989917622
# RUN  16 , total integrated cost =  227604.3798988146
# RUN  17 , total integrated cost =  227604.3798741444
# RUN  18 , total integrated cost =  227604.3798538105
# RUN  19 , total integrated cost =  227604.37985343437
# RUN  20 , total integrated cost =  227604.37984863453
# RUN  30 , total integrated cost =  227604.3798323293
# RUN  30 , total integrated cost =  227604.3798323293
# Improved over  30  iterations in  16.869039724988397  seconds by  5.0519460614850686e-08  percent.
# uncontrolled cost :  227604.36517255512
# cost splitting :  0.0036031260708944374 [1.23192429e-16 2.40595740e+00]
# -------  20 0.4500000000000001 0.4750000000000002
# weight =  93833.41055576154
# set cost params:  1.0 0.0 93833.41055576154
# interpolate adjoint :  True True True
# initial cost =  318198.4034356064
# RUN  0 , total integrated cost =  318198.4034356064
# Gradient descend method:  None
# RUN  1 , total integrated cost =  312868.3877085281
# RUN  2 , total integrated cost =  312722.6450909907
# RUN  3 , total integrated cost =  312717.11469348887
# RUN  4 , total integrated cost =  312717.01324195735
# RUN  5 , total integrated cost =  312717.012727695
# RUN  6 , total integrated cost =  312717.0121293605
# RUN  7 , total integrated cost =  312717.0121012455
# RUN  8 , total integrated cost =  312717.0120702049
# RUN  9 , total integrated cost =  312717.0120504406
# RUN  10 , total integrated cost =  312717.01202783344
# RUN  11 , total integrated cost =  312717.01201056957
# RUN  12 , total integrated cost =  312717.01199172763
# RUN  13 , total integrated cost =  312717.01197827875
# RUN  14 , total integrated cost =  312717.01196303614
# RUN  15 , total integrated cost =  312717.01195113454
# RUN  16 , total integrated cost =  312717.01193740277
# RUN  17 , total integrated cost =  312717.01192643214
# RUN  18 , total integrated cost =  312717.0119127538
# RUN  19 , total integrated cost =  312717.0119017879
# RUN  20 , total integrated cost =  312717.0118865803
# RUN  30 , total integrated cost =  312717.00592220534
# RUN  30 , total integrated cost =  312717.00592220534
# Improved over  30  iterations in  17.46820604300592  seconds by  1.7226351402829465  percent.
# uncontrolled cost :  318198.4034356064
# cost splitting :  0.003607766746519473 [2.59530327e-16 3.33268274e+00]
# weight =  95478.15515219475
# set cost params:  1.0 0.0 95478.15515219475
# interpolate adjoint :  True True True
# initial cost =  318198.4178522567
# RUN  0 , total integrated cost =  318198.4178522567
# Gradient descend method:  None
# RUN  1 , total integrated cost =  318198.41447162314
# RUN  2 , total integrated cost =  318198.4144557785
# RUN  3 , total integrated cost =  318198.4144369659
# RUN  4 , total integrated cost =  318198.4144248127
# RUN  5 , total integrated cost =  318198.414409523
# RUN  6 , total integrated cost =  318198.4143982363
# RUN  7 , total integrated cost =  318198.41438398376
# RUN  8 , total integrated cost =  318198.41437310155
# RUN  9 , total integrated cost =  318198.4143586281
# RUN  10 , total integrated cost =  318198.4143472531
# RUN  11 , total integrated cost =  318198.414332075
# RUN  12 , total integrated cost =  318198.4143198198
# RUN  13 , total integrated cost =  318198.4143025255
# RUN  14 , total integrated cost =  318198.4142873471
# RUN  15 , total integrated cost =  318198.4142646303
# RUN  16 , total integrated cost =  318198.4142442783
# RUN  17 , total integrated cost =  318198.41421821195
# RUN  18 , total integrated cost =  318198.4141959628
# RUN  19 , total integrated cost =  318198.414152658
# RUN  20 , total integrated cost =  318198.41411530686
# RUN  30 , total integrated cost =  318198.4118498168
# RUN  30 , total integrated cost =  318198.4118498168
# Improved over  30  iterations in  18.153513130004285  seconds by  1.8863826909409909e-06  percent.
# uncontrolled cost :  318198.4034356064
# cost splitting :  0.001786982590638384 [2.59530327e-16 3.33268277e+00]
# weight =  95478.15477009393
# set cost params:  1.0 0.0 95478.15477009393
# interpolate adjoint :  True True True
# initial cost =  318198.4105763959
# RUN  0 , total integrated cost =  318198.4105763959
# Gradient descend method:  None
# RUN  1 , total integrated cost =  318198.4105654865
# RUN  2 , total integrated cost =  318198.41055139166
# RUN  3 , total integrated cost =  318198.41054009437
# RUN  4 , total integrated cost =  318198.41052484716
# RUN  5 , total integrated cost =  318198.41051268054
# RUN  6 , total integrated cost =  318198.4104958439
# RUN  7 , total integrated cost =  318198.4104817838
# RUN  8 , total integrated cost =  318198.41046321933
# RUN  9 , total integrated cost =  318198.4104469938
# RUN  10 , total integrated cost =  318198.41042559216
# RUN  11 , total integrated cost =  318198.4104064813
# RUN  12 , total integrated cost =  318198.41037767637
# RUN  13 , total integrated cost =  318198.4103512918
# RUN  14 , total integrated cost =  318198.41031400795
# RUN  15 , total integrated cost =  318198.4102788096
# RUN  16 , total integrated cost =  318198.4101365005
# RUN  17 , total integrated cost =  318198.4100091033
# RUN  18 , total integrated cost =  318198.4056163324
# RUN  19 , total integrated cost =  318198.40257256967
# RUN  20 , total integrated cost =  318198.40255713667
# RUN  30 , total integrated cost =  318198.4023456971
# RUN  30 , total integrated cost =  318198.4023456971
# Improved over  30  iterations in  18.216458425013116  seconds by  2.586656165703971e-06  percent.
# uncontrolled cost :  318198.4034356064
# cost splitting :  0.00188478339681444 [2.59530327e-16 3.33268268e+00]
# weight =  95478.15735705226
# set cost params:  1.0 0.0 95478.15735705226
# interpolate adjoint :  True True True
# initial cost =  318198.4109672083
# RUN  0 , total integrated cost =  318198.4109672083
# Gradient descend method:  None
# RUN  1 , total integrated cost =  318198.41093242646
# RUN  2 , total integrated cost =  318198.41079044825
# RUN  3 , total integrated cost =  318198.410662735
# RUN  4 , total integrated cost =  318198.4069659813
# RUN  5 , total integrated cost =  318198.4043681259
# RUN  6 , total integrated cost =  318198.4042962834
# RUN  7 , total integrated cost =  318198.4042180279
# RUN  8 , total integrated cost =  318198.4041873381
# RUN  9 , total integrated cost =  318198.4041534283
# RUN  10 , total integrated cost =  318198.40413620626
# RUN  11 , total integrated cost =  318198.404116729
# RUN  12 , total integrated cost =  318198.4041018837
# RUN  13 , total integrated cost =  318198.4040840749
# RUN  14 , total integrated cost =  318198.40407194133
# RUN  15 , total integrated cost =  318198.4040566396
# RUN  16 , total integrated cost =  318198.4040453657
# RUN  17 , total integrated cost =  318198.4040311078
# RUN  18 , total integrated cost =  318198.4040202266
# RUN  19 , total integrated cost =  318198.4040057617
# RUN  20 , total integrated cost =  318198.40399425384
# RUN  30 , total integrated cost =  318198.40376031096
# RUN  30 , total integrated cost =  318198.40376031096
# Improved over  30  iterations in  16.445830026001204  seconds by  2.2649067688007563e-06  percent.
# uncontrolled cost :  318198.4034356064
# cost splitting :  0.0017407648554345978 [2.76395236e-16 3.33268261e+00]
# weight =  95478.15934686032
# set cost params:  1.0 0.0 95478.15934686032
# interpolate adjoint :  True True True
# initial cost =  318198.4103917097
# RUN  0 , total integrated cost =  318198.4103917097
# Gradient descend method:  None
# RUN  1 , total integrated cost =  318198.4102494188
# RUN  2 , total integrated cost =  318198.4101220285
# RUN  3 , total integrated cost =  318198.40571590053
# RUN  4 , total integrated cost =  318198.4026860469
# RUN  5 , total integrated cost =  318198.40267027944
# RUN  6 , total integrated cost =  318198.40265719534
# RUN  7 , total integrated cost =  318198.40263735846
# RUN  8 , total integrated cost =  318198.4026205303
# RUN  9 , total integrated cost =  318198.4025904679
# RUN  10 , total integrated cost =  318198.40256462176
# RUN  11 , total integrated cost =  318198.40252679324
# RUN  12 , total integrated cost =  318198.4024921593
# RUN  13 , total integrated cost =  318198.4023501596
# RUN  14 , total integrated cost =  318198.40222249273
# RUN  15 , total integrated cost =  318198.39843833965
# RUN  16 , total integrated cost =  318198.3954637667
# RUN  17 , total integrated cost =  318198.39544626005
# RUN  18 , total integrated cost =  318198.3954309721
# RUN  19 , total integrated cost =  318198.3954084264
# RUN  20 , total integrated cost =  318198.39538843354
# RUN  30 , total integrated cost =  318114.4302241962
# RUN  30 , total integrated cost =  318114.4302241962
# Improved over  30  iterations in  14.787201881001238  seconds by  0.026392390650258335  percent.
# uncontrolled cost :  318198.4034356064
# cost splitting :  7.614235764052882e-11 [2.76395236e-16 3.33180313e+00]
# -------  30 0.4250000000000001 0.5250000000000002
# weight =  32939.41868310182
# set cost params:  1.0 0.0 32939.41868310182
# interpolate adjoint :  True True True
# initial cost =  199298.52260795745
# RUN  0 , total integrated cost =  199298.52260795745
# Gradient descend method:  None
# RUN  1 , total integrated cost =  196014.43032757204
# RUN  2 , total integrated cost =  195874.4458298529
# RUN  3 , total integrated cost =  195873.68720364175
# RUN  4 , total integrated cost =  195873.68637324305
# RUN  5 , total integrated cost =  195873.685038266
# RUN  6 , total integrated cost =  195873.6838333645
# RUN  7 , total integrated cost =  195873.68142621726
# RUN  8 , total integrated cost =  195873.67931536888
# RUN  9 , total integrated cost =  195873.67562291407
# RUN  10 , total integrated cost =  195873.67226667865
# RUN  11 , total integrated cost =  195873.66344193215
# RUN  12 , total integrated cost =  195873.65553952768
# RUN  13 , total integrated cost =  195873.6103323143
# RUN  14 , total integrated cost =  195873.57344435932
# RUN  15 , total integrated cost =  195873.56652286314
# RUN  16 , total integrated cost =  195873.55865098687
# RUN  17 , total integrated cost =  195873.55740180303
# RUN  18 , total integrated cost =  195873.555959166
# RUN  19 , total integrated cost =  195873.5551309795
# RUN  20 , total integrated cost =  195873.55414190548
# RUN  30 , total integrated cost =  195873.53915253008
# RUN  30 , total integrated cost =  195873.53915253008
# Improved over  30  iterations in  15.761813299992355  seconds by  1.7185192396858326  percent.
# uncontrolled cost :  199298.52260795745
# cost splitting :  0.07456443004019268 [5.94646701e+00 2.26299489e-16]
# weight =  33515.43826038471
# set cost params:  1.0 0.0 33515.43826038471
# interpolate adjoint :  True True True
# initial cost =  199298.82056771783
# RUN  0 , total integrated cost =  199298.82056771783
# Gradient descend method:  None
# RUN  1 , total integrated cost =  199298.81671388252
# RUN  2 , total integrated cost =  199298.81263333894
# RUN  3 , total integrated cost =  199298.8089119637
# RUN  4 , total integrated cost =  199298.80465451593
# RUN  5 , total integrated cost =  199298.80099521825
# RUN  6 , total integrated cost =  199298.79664552718
# RUN  7 , total integrated cost =  199298.79266817943
# RUN  8 , total integrated cost =  199280.59193834805
# RUN  9 , total integrated cost =  199211.42592817836
# RUN  10 , total integrated cost =  199211.1283948376
# RUN  11 , total integrated cost =  199211.1276742597
# RUN  12 , total integrated cost =  199211.11382503784
# RUN  13 , total integrated cost =  199211.10187776366
# RUN  14 , total integrated cost =  199211.10035658954
# RUN  15 , total integrated cost =  199211.0990054395
# RUN  16 , total integrated cost =  199211.0939331642
# RUN  17 , total integrated cost =  199211.08957742873
# RUN  18 , total integrated cost =  199211.08058912153
# RUN  19 , total integrated cost =  199211.0726996469
# RUN  20 , total integrated cost =  199211.0710374294
# RUN  30 , total integrated cost =  199211.06484386363
# RUN  30 , total integrated cost =  199211.06484386363
# Improved over  30  iterations in  16.752037125988863  seconds by  0.04403223441273951  percent.
# uncontrolled cost :  199298.52260795745
# cost splitting :  0.035811022681436634 [5.94385442e+00 2.26299489e-16]
# weight =  33530.176317351485
# set cost params:  1.0 0.0 33530.176317351485
# interpolate adjoint :  True True True
# initial cost =  199298.6657089472
# RUN  0 , total integrated cost =  199298.6657089472
# Gradient descend method:  None
# RUN  1 , total integrated cost =  199298.66457815524
# RUN  2 , total integrated cost =  199298.6636487884
# RUN  3 , total integrated cost =  199298.63995837682
# RUN  4 , total integrated cost =  199298.61950071974
# RUN  5 , total integrated cost =  199254.38480229917
# RUN  6 , total integrated cost =  199233.96987430632
# RUN  7 , total integrated cost =  199233.49631391076
# RUN  8 , total integrated cost =  199233.49624552458
# RUN  9 , total integrated cost =  199233.4962439903
# RUN  10 , total integrated cost =  199233.49621194002
# RUN  11 , total integrated cost =  199233.49619009462
# RUN  12 , total integrated cost =  199233.49618801096
# RUN  13 , total integrated cost =  199233.49617868994
# RUN  14 , total integrated cost =  199233.49617485725
# RUN  15 , total integrated cost =  199233.4961660243
# RUN  16 , total integrated cost =  199233.49615039767
# RUN  17 , total integrated cost =  199233.49614883628
# RUN  18 , total integrated cost =  199233.4959197065
# RUN  19 , total integrated cost =  199233.49571209284
# RUN  20 , total integrated cost =  199233.4957105234
# RUN  30 , total integrated cost =  199233.49419400346
# RUN  30 , total integrated cost =  199233.49419400346
# Improved over  30  iterations in  16.531788517022505  seconds by  0.03270042712624388  percent.
# uncontrolled cost :  199298.52260795745
# cost splitting :  0.022953588029271162 [5.94191267e+00 2.26299489e-16]
# weight =  33541.135774379916
# set cost params:  1.0 0.0 33541.135774379916
# interpolate adjoint :  True True True
# initial cost =  199298.61433058695
# RUN  0 , total integrated cost =  199298.61433058695
# Gradient descend method:  None
# RUN  1 , total integrated cost =  199298.61414608505
# RUN  2 , total integrated cost =  199298.61414453847
# RUN  3 , total integrated cost =  199298.61408013094
# RUN  4 , total integrated cost =  199298.61403148383
# RUN  5 , total integrated cost =  199298.6140297402
# RUN  6 , total integrated cost =  199298.61401723154
# RUN  7 , total integrated cost =  199298.6140107513
# RUN  8 , total integrated cost =  199298.6140078007
# RUN  9 , total integrated cost =  199298.61399910698
# RUN  10 , total integrated cost =  199298.6139966319
# RUN  11 , total integrated cost =  199298.6139771905
# RUN  12 , total integrated cost =  199298.61394832435
# RUN  13 , total integrated cost =  199298.61394677474
# RUN  14 , total integrated cost =  199298.61371555927
# RUN  15 , total integrated cost =  199298.61351035786
# RUN  16 , total integrated cost =  199298.61350879184
# RUN  17 , total integrated cost =  199298.61329146108
# RUN  18 , total integrated cost =  199298.61311460426
# RUN  19 , total integrated cost =  199298.61311306516
# RUN  20 , total integrated cost =  199298.61304648343
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_158830/3888071031.py in <module>
#      27         control0 = bestControl_[i][0][:,:,n_pre-1:-n_post+1]
#      28
# ---> 29         bestControl_[i][j], bestState_[i][j], cost_[i][j], runtime_, grad_, phi_, phi1_, costnode_[i][j] = aln.A1(
#      30             control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
#      31             startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
#
# ~/Promotion/neurolib/neurolib/models/model.py in A1(self, control_, target_state_, c_scheme_, u_mat_, u_scheme_, max_iteration_, tolerance_, startStep_, max_control_, min_control_, t_sim_, t_sim_pre_, t_sim_post_, CGVar, line_search_, control_variables_, prec_variables_, separate_comp, transition_time_, noise_real, init_params)
#     661             if self.params.N == 1:
#     662                 if noise_real == 0:
# --> 663                     return opti1_rate_control.A1(self, control_, target_state_, c_scheme_, u_mat_, u_scheme_, max_iteration_,
#     664                                                 tolerance_, startStep_, max_control_, min_control_, t_sim_, t_sim_pre_, t_sim_post_, CGVar,
#     665                                                 line_search_, control_variables_, prec_variables_, separate_comp, transition_time_)
#
# ~/Promotion/neurolib/neurolib/utils/A1_aln_rate_control.py in A1(model, control_, target_state, c_scheme_, u_mat_, u_scheme_, max_iteration_, tolerance_, startStep_, cntrl_max_, cntrl_min_, t_sim_, t_sim_pre_, t_sim_post_, CGVar, line_search_, control_variables_, prec_variables_, separate_comp, transition_time_)
#     483
#     484
# --> 485         step_, total_cost_[i], startStep_ = line_search_func(model, N, n_control_vars, T, dt, state1_[:,:2,:], target_state_,
#     486                      best_control_, dir0_, ip_, ie_, is_, start_step_ = startStep_, max_it_ = 500, max_control_ = cntrl_max_,
#     487                          min_control_ = cntrl_min_, tolerance_ = tolerance_step, variables_ = prec_variables, grad_ = grad1_)
#
# ~/Promotion/neurolib/neurolib/utils/func_optimize.py in step_size(model, N, V, T, dt, state_, target_, control_, dir_, ip_, ie_, is_, start_step_, max_it_, bisec_factor_, max_control_, min_control_, tolerance_, substep_, variables_, alg, control_parameter, grad_, noise_real, init_vars, startind_)
#     234                 set_init(model, init_vars, model.init_vars, model.state_vars, startind_)
#     235             state1_ = updateState(model, test_control_)
# --> 236             cost1_int_ = cost.f_int(N, V, T, dt, state1_, target_, test_control_, ip_, ie_, is_, v_ = variables_)
#     237         else:
#     238             cost1_int_ = 0.
#
# ~/Promotion/neurolib/neurolib/utils/costFunctions.py in f_int(N, V, T, dt, state_, target_, control_, i_p, i_e, i_s, v_)
#     308         cost_energy = cost_energy_int(N, V, T, dt, i_e, control_)
#     309     if not i_s < 1e-12:
# --> 310         cost_sparsity = f_cost_sparsity_int(N, V, T, dt, i_s, control_)
#     311
#     312     cost_int = cost_prec + cost_energy + cost_sparsity
#
# ~/Promotion/neurolib/neurolib/utils/costFunctions.py in f_cost_sparsity_int(N, V, T, dt, i_s, control_)
#     260
#     261 def f_cost_sparsity_int(N, V, T, dt, i_s, control_):
# --> 262     cost =  numba_cost_sparsity_int(N, V, T, i_s, dt, control_)
#     263     return cost
#     264
#
# KeyboardInterrupt:
