# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import sys
import pickle

path = os.getcwd().split(os.sep + 'GUI')[0]
if path not in sys.path:
    print("not here")
    sys.path.append(path)

from neurolib.models.aln import ALNModel
from neurolib.utils import plotFunctions as plotFunc
from neurolib.utils import costFunctions as cost
import neurolib.dashboard.functions as functions
import neurolib.dashboard.data as data
    
# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2 

#path = os.path.join(os.getcwd(), "plots")
# Out:
# not here

# %%
grid_data_file = os.path.join(os.getcwd().split('data')[0], 'bi.pickle')
print(grid_data_file)
with open(grid_data_file,'rb') as f:
    load_array= pickle.load(f)
exc = load_array[0]
inh = load_array[1]
print(len(exc))
# Out:
# /mnt/antares_raid/home/salfenmoser/neurolib/GUI/current/gui/bi.pickle
# 147

# %%
aln = ALNModel()
N = aln.params.N

data.set_parameters(aln)

state_vars = aln.state_vars
init_vars = aln.init_vars

##############################################################
def setinit(init_vars_, model):
    state_vars = model.state_vars
    init_vars = model.init_vars
    for iv in range(len(init_vars)):
        for sv in range(len(state_vars)):
            if state_vars[sv] in init_vars[iv]:
                #print("set init vars ", )
                if model.params[init_vars[iv]].ndim == 2:
                    model.params[init_vars[iv]][0,:] = init_vars_[sv]
                else:
                    model.params[init_vars[iv]][0] = init_vars_[sv]
                    
##############################################################               
def setmaxmincontrol(max_c_c, min_c_c, max_c_r, min_c_r):
    import numpy as np
    
    max_cntrl = np.zeros(( 6 ))
    min_cntrl = np.zeros(( 6 ))
    
    max_cntrl[0] = max_c_c
    min_cntrl[0] = min_c_c
    max_cntrl[1] = max_c_c
    min_cntrl[1] = min_c_c
    max_cntrl[2] = max_c_r
    min_cntrl[2] = min_c_r
    max_cntrl[3] = max_c_r
    min_cntrl[3] = min_c_r
    max_cntrl[4] = max_c_r
    min_cntrl[4] = min_c_r
    max_cntrl[5] = max_c_r
    min_cntrl[5] = min_c_r
            
    return max_cntrl, min_cntrl

# %%
d_array = np.arange(500., 20, -0.1)
t0_array = d_array - 20.
t_pen = np.zeros(( t0_array.shape ))
for i in range(len(t_pen)):
    t_pen[i] = t0_array[i] / d_array[i]

# %%
bestControl_ = [None] * len(exc) 
bestState_ = [None] * len(exc) 
cost_ = [None] * len(exc) 
costnode_ = [None] * len(exc) 
weights_ = [None] * len(exc) 
convergence_ = [None] * len(exc) 

initVars = [None] * len(exc)
target = [None] * len(exc)
cost_uncontrolled = [None] * len(exc)
w_ = [None] * len(exc)
conv = [None] * len(exc)
conv_shift = [None] * len(exc)

# %%
folder = str(os.getcwd().split('data_2')[1])
print(folder)
case = str(folder[1])

file_ = str(case + '.pickle')
# Out:
# /4

# %%
dur_pre = 10
dur_post = 10

n_pre = int(np.around(dur_pre/aln.params.dt + 1.,1))
n_post = int(np.around(dur_post/aln.params.dt + 1.,1))

tol = 1e-12
start_step = 10.
c_scheme = np.zeros(( 1,1 ))
c_scheme[0,0] = 1.
u_mat = np.identity(1)
u_scheme = np.array([[1.]])

c_var = [0]
p_var = [0]

if case in ['1', '2']:    # low to high
    max_I = [3., -3.]
else:
    max_I = [-3., 3.]
    
if case in ['1', '3']:    # sparsity
    factor_ws = 1.
    factor_we = 0.
    index_cost = 2
else:
    factor_ws = 0.
    factor_we = 1.
    index_cost = 1
    
    
maxC = [5., -5., 0.18, 0.]
max_cntrl, min_cntrl = setmaxmincontrol(maxC[0], maxC[1], maxC[2], maxC[3])

# %%
if os.path.isfile(file_) :
    print("file found")
    
    with open(file_,'rb') as f:
        load_array = pickle.load(f)

    bestControl_ = load_array[0]
    bestState_ = load_array[1]
    cost_ = load_array[2]
    costnode_ = load_array[3]
    weights_ = load_array[4]
# Out:
# file found

# %%
# get initial parameters and target states

i_range = range(83)
#i_range = [50]

data.set_parameters(aln)

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    aln.params.duration = 3000.
    
    control0 = aln.getZeroControl()
    control0 = functions.step_control(aln, maxI_ = max_I[0])

    aln.run(control=control0)
    
    target_rates = np.zeros((2))
    target_rates[0] = aln.rates_exc[0,-1] 
    target_rates[1] = aln.rates_inh[0,-1]

    control0 = functions.step_control(aln, maxI_ = max_I[1])
    aln.run(control=control0)

    init_state_vars = np.zeros(( len(state_vars) ))
    for j in range(len(state_vars)):
        if aln.state[state_vars[j]].size == 1:
            init_state_vars[j] = aln.state[state_vars[j]][0]
        else:
            init_state_vars[j] = aln.state[state_vars[j]][0,-1]

    initVars[i] = init_state_vars
    target[i] = [target_rates[0], target_rates[1]]
# Out:
# -------  0 0.4000000000000001 0.3500000000000001
# -------  1 0.4250000000000001 0.3500000000000001
# -------  2 0.4000000000000001 0.3750000000000001
# -------  3 0.4250000000000001 0.3750000000000001
# -------  4 0.4500000000000001 0.3750000000000001
# -------  5 0.4000000000000001 0.40000000000000013
# -------  6 0.4250000000000001 0.40000000000000013
# -------  7 0.4500000000000001 0.40000000000000013
# -------  8 0.47500000000000014 0.40000000000000013
# -------  9 0.4000000000000001 0.42500000000000016
# -------  10 0.4250000000000001 0.42500000000000016
# -------  11 0.4500000000000001 0.42500000000000016
# -------  12 0.47500000000000014 0.42500000000000016
# -------  13 0.4000000000000001 0.4500000000000002
# -------  14 0.4250000000000001 0.4500000000000002
# -------  15 0.4500000000000001 0.4500000000000002
# -------  16 0.47500000000000014 0.4500000000000002
# -------  17 0.5000000000000002 0.4500000000000002
# -------  18 0.4000000000000001 0.4750000000000002
# -------  19 0.4250000000000001 0.4750000000000002
# -------  20 0.4500000000000001 0.4750000000000002
# -------  21 0.47500000000000014 0.4750000000000002
# -------  22 0.5000000000000002 0.4750000000000002
# -------  23 0.5250000000000001 0.4750000000000002
# -------  24 0.4000000000000001 0.5000000000000002
# -------  25 0.4250000000000001 0.5000000000000002
# -------  26 0.4500000000000001 0.5000000000000002
# -------  27 0.47500000000000014 0.5000000000000002
# -------  28 0.5000000000000002 0.5000000000000002
# -------  29 0.5250000000000001 0.5000000000000002
# -------  30 0.4250000000000001 0.5250000000000002
# -------  31 0.4500000000000001 0.5250000000000002
# -------  32 0.47500000000000014 0.5250000000000002
# -------  33 0.5000000000000002 0.5250000000000002
# -------  34 0.5250000000000001 0.5250000000000002
# -------  35 0.5500000000000003 0.5250000000000002
# -------  36 0.4250000000000001 0.5500000000000003
# -------  37 0.4500000000000001 0.5500000000000003
# -------  38 0.47500000000000014 0.5500000000000003
# -------  39 0.5000000000000002 0.5500000000000003
# -------  40 0.5250000000000001 0.5500000000000003
# -------  41 0.5500000000000003 0.5500000000000003
# -------  42 0.4250000000000001 0.5750000000000003
# -------  43 0.4500000000000001 0.5750000000000003
# -------  44 0.47500000000000014 0.5750000000000003
# -------  45 0.5000000000000002 0.5750000000000003
# -------  46 0.5250000000000001 0.5750000000000003
# -------  47 0.5500000000000003 0.5750000000000003
# -------  48 0.4250000000000001 0.6000000000000003
# -------  49 0.4500000000000001 0.6000000000000003
# -------  50 0.47500000000000014 0.6000000000000003
# -------  51 0.5000000000000002 0.6000000000000003
# -------  52 0.5250000000000001 0.6000000000000003
# -------  53 0.5500000000000003 0.6000000000000003
# -------  54 0.5750000000000002 0.6000000000000003
# -------  55 0.4250000000000001 0.6250000000000003
# -------  56 0.4500000000000001 0.6250000000000003
# -------  57 0.47500000000000014 0.6250000000000003
# -------  58 0.5000000000000002 0.6250000000000003
# -------  59 0.5250000000000001 0.6250000000000003
# -------  60 0.5500000000000003 0.6250000000000003
# -------  61 0.5750000000000002 0.6250000000000003
# -------  62 0.4250000000000001 0.6500000000000004
# -------  63 0.4500000000000001 0.6500000000000004
# -------  64 0.47500000000000014 0.6500000000000004
# -------  65 0.5000000000000002 0.6500000000000004
# -------  66 0.5250000000000001 0.6500000000000004
# -------  67 0.5500000000000003 0.6500000000000004
# -------  68 0.5750000000000002 0.6500000000000004
# -------  69 0.4250000000000001 0.6750000000000004
# -------  70 0.4500000000000001 0.6750000000000004
# -------  71 0.47500000000000014 0.6750000000000004
# -------  72 0.5000000000000002 0.6750000000000004
# -------  73 0.5250000000000001 0.6750000000000004
# -------  74 0.5500000000000003 0.6750000000000004
# -------  75 0.5750000000000002 0.6750000000000004
# -------  76 0.4250000000000001 0.7000000000000004
# -------  77 0.4500000000000001 0.7000000000000004
# -------  78 0.47500000000000014 0.7000000000000004
# -------  79 0.5000000000000002 0.7000000000000004
# -------  80 0.5250000000000001 0.7000000000000004
# -------  81 0.5500000000000003 0.7000000000000004
# -------  82 0.5750000000000002 0.7000000000000004

# %%
# get uncontrolled cost

data.set_parameters(aln)

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    dur = d_array[0]
    aln.params.duration = dur
    
    target_ = aln.getZeroTarget()
    target_[:,0,:] = target[i][0]
    target_[:,1,:] = target[i][1]
            
    cost.setParams(1.0, 0.0, 0.0)

    setinit(initVars[i], aln)
    control0 = aln.getZeroControl()

    # "HS", "FR", "PR", "HZ"
    cgv = None
    max_it = 0

    bestControl_init_, bestState_init_, cost_init_, runtime_init_, grad_init_, phi_init_, phi1_, costnode_init_ = aln.A1(
        control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
        prec_variables_ = p_var, transition_time_ = t_pen[0])
    
    cost_uncontrolled[i] = cost_init_[0]
# Out:
# -------  0 0.4000000000000001 0.3500000000000001
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  146855.39702821904
# RUN  0 , total integrated cost =  146855.39702821904
# Gradient descend method:  None
# RUN  0 , total integrated cost =  146855.39702821904
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  1 0.4250000000000001 0.3500000000000001
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  244234.70502182204
# RUN  0 , total integrated cost =  244234.70502182204
# Gradient descend method:  None
# RUN  0 , total integrated cost =  244234.70502182204
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  2 0.4000000000000001 0.3750000000000001
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  137806.3558139294
# RUN  0 , total integrated cost =  137806.3558139294
# Gradient descend method:  None
# RUN  0 , total integrated cost =  137806.3558139294
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  3 0.4250000000000001 0.3750000000000001
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  241480.3484875782
# RUN  0 , total integrated cost =  241480.3484875782
# Gradient descend method:  None
# RUN  0 , total integrated cost =  241480.3484875782
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  4 0.4500000000000001 0.3750000000000001
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  338432.51439444604
# RUN  0 , total integrated cost =  338432.51439444604
# Gradient descend method:  None
# RUN  0 , total integrated cost =  338432.51439444604
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  5 0.4000000000000001 0.40000000000000013
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  126823.61408372025
# RUN  0 , total integrated cost =  126823.61408372025
# Gradient descend method:  None
# RUN  0 , total integrated cost =  126823.61408372025
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  6 0.4250000000000001 0.40000000000000013
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  234849.86448361105
# RUN  0 , total integrated cost =  234849.86448361105
# Gradient descend method:  None
# RUN  0 , total integrated cost =  234849.86448361105
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  7 0.4500000000000001 0.40000000000000013
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  337311.3569640121
# RUN  0 , total integrated cost =  337311.3569640121
# Gradient descend method:  None
# RUN  0 , total integrated cost =  337311.3569640121
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  8 0.47500000000000014 0.40000000000000013
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  436683.03613383934
# RUN  0 , total integrated cost =  436683.03613383934
# Gradient descend method:  None
# RUN  0 , total integrated cost =  436683.03613383934
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  9 0.4000000000000001 0.42500000000000016
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  115502.5972235114
# RUN  0 , total integrated cost =  115502.5972235114
# Gradient descend method:  None
# RUN  0 , total integrated cost =  115502.5972235114
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  10 0.4250000000000001 0.42500000000000016
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  226698.47715197233
# RUN  0 , total integrated cost =  226698.47715197233
# Gradient descend method:  None
# RUN  0 , total integrated cost =  226698.47715197233
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  11 0.4500000000000001 0.42500000000000016
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  331196.46910670475
# RUN  0 , total integrated cost =  331196.46910670475
# Gradient descend method:  None
# RUN  0 , total integrated cost =  331196.46910670475
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  12 0.47500000000000014 0.42500000000000016
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  437181.9504061447
# RUN  0 , total integrated cost =  437181.9504061447
# Gradient descend method:  None
# RUN  0 , total integrated cost =  437181.9504061447
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  13 0.4000000000000001 0.4500000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  103932.40255255786
# RUN  0 , total integrated cost =  103932.40255255786
# Gradient descend method:  None
# RUN  0 , total integrated cost =  103932.40255255786
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  14 0.4250000000000001 0.4500000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  218854.09939826332
# RUN  0 , total integrated cost =  218854.09939826332
# Gradient descend method:  None
# RUN  0 , total integrated cost =  218854.09939826332
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  15 0.4500000000000001 0.4500000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  323897.4690366888
# RUN  0 , total integrated cost =  323897.4690366888
# Gradient descend method:  None
# RUN  0 , total integrated cost =  323897.4690366888
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  16 0.47500000000000014 0.4500000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  431451.8938983858
# RUN  0 , total integrated cost =  431451.8938983858
# Gradient descend method:  None
# RUN  0 , total integrated cost =  431451.8938983858
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  17 0.5000000000000002 0.4500000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  541570.0682516823
# RUN  0 , total integrated cost =  541570.0682516823
# Gradient descend method:  None
# RUN  0 , total integrated cost =  541570.0682516823
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  18 0.4000000000000001 0.4750000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  91340.63373509991
# RUN  0 , total integrated cost =  91340.63373509991
# Gradient descend method:  None
# RUN  0 , total integrated cost =  91340.63373509991
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  19 0.4250000000000001 0.4750000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  211572.5759679924
# RUN  0 , total integrated cost =  211572.5759679924
# Gradient descend method:  None
# RUN  0 , total integrated cost =  211572.5759679924
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  20 0.4500000000000001 0.4750000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  316931.9421284
# RUN  0 , total integrated cost =  316931.9421284
# Gradient descend method:  None
# RUN  0 , total integrated cost =  316931.9421284
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  21 0.47500000000000014 0.4750000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  424684.0949542926
# RUN  0 , total integrated cost =  424684.0949542926
# Gradient descend method:  None
# RUN  0 , total integrated cost =  424684.0949542926
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  22 0.5000000000000002 0.4750000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  536554.4931300428
# RUN  0 , total integrated cost =  536554.4931300428
# Gradient descend method:  None
# RUN  0 , total integrated cost =  536554.4931300428
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  23 0.5250000000000001 0.4750000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  649680.5756879131
# RUN  0 , total integrated cost =  649680.5756879131
# Gradient descend method:  None
# RUN  0 , total integrated cost =  649680.5756879131
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  24 0.4000000000000001 0.5000000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  74168.60244152801
# RUN  0 , total integrated cost =  74168.60244152801
# Gradient descend method:  None
# RUN  0 , total integrated cost =  74168.60244152801
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  25 0.4250000000000001 0.5000000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  204814.76624161197
# RUN  0 , total integrated cost =  204814.76624161197
# Gradient descend method:  None
# RUN  0 , total integrated cost =  204814.76624161197
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  26 0.4500000000000001 0.5000000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  310502.0037410387
# RUN  0 , total integrated cost =  310502.0037410387
# Gradient descend method:  None
# RUN  0 , total integrated cost =  310502.0037410387
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  27 0.47500000000000014 0.5000000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  418236.1198402083
# RUN  0 , total integrated cost =  418236.1198402083
# Gradient descend method:  None
# RUN  0 , total integrated cost =  418236.1198402083
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  28 0.5000000000000002 0.5000000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  530282.4726497299
# RUN  0 , total integrated cost =  530282.4726497299
# Gradient descend method:  None
# RUN  0 , total integrated cost =  530282.4726497299
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  29 0.5250000000000001 0.5000000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  646521.6732350034
# RUN  0 , total integrated cost =  646521.6732350034
# Gradient descend method:  None
# RUN  0 , total integrated cost =  646521.6732350034
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  30 0.4250000000000001 0.5250000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  198505.2946572739
# RUN  0 , total integrated cost =  198505.2946572739
# Gradient descend method:  None
# RUN  0 , total integrated cost =  198505.2946572739
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  31 0.4500000000000001 0.5250000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  304530.5505769217
# RUN  0 , total integrated cost =  304530.5505769217
# Gradient descend method:  None
# RUN  0 , total integrated cost =  304530.5505769217
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  32 0.47500000000000014 0.5250000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  412227.1647591634
# RUN  0 , total integrated cost =  412227.1647591634
# Gradient descend method:  None
# RUN  0 , total integrated cost =  412227.1647591634
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  33 0.5000000000000002 0.5250000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  524212.5915485861
# RUN  0 , total integrated cost =  524212.5915485861
# Gradient descend method:  None
# RUN  0 , total integrated cost =  524212.5915485861
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  34 0.5250000000000001 0.5250000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  640916.4738461657
# RUN  0 , total integrated cost =  640916.4738461657
# Gradient descend method:  None
# RUN  0 , total integrated cost =  640916.4738461657
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  35 0.5500000000000003 0.5250000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  760013.3898018681
# RUN  0 , total integrated cost =  760013.3898018681
# Gradient descend method:  None
# RUN  0 , total integrated cost =  760013.3898018681
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  36 0.4250000000000001 0.5500000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  192617.3150952127
# RUN  0 , total integrated cost =  192617.3150952127
# Gradient descend method:  None
# RUN  0 , total integrated cost =  192617.3150952127
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  37 0.4500000000000001 0.5500000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  299002.14935773576
# RUN  0 , total integrated cost =  299002.14935773576
# Gradient descend method:  None
# RUN  0 , total integrated cost =  299002.14935773576
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  38 0.47500000000000014 0.5500000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  406664.10745913326
# RUN  0 , total integrated cost =  406664.10745913326
# Gradient descend method:  None
# RUN  0 , total integrated cost =  406664.10745913326
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  39 0.5000000000000002 0.5500000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  518533.1123942334
# RUN  0 , total integrated cost =  518533.1123942334
# Gradient descend method:  None
# RUN  0 , total integrated cost =  518533.1123942334
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  40 0.5250000000000001 0.5500000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  635238.4079859259
# RUN  0 , total integrated cost =  635238.4079859259
# Gradient descend method:  None
# RUN  0 , total integrated cost =  635238.4079859259
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  41 0.5500000000000003 0.5500000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  756194.7962365937
# RUN  0 , total integrated cost =  756194.7962365937
# Gradient descend method:  None
# RUN  0 , total integrated cost =  756194.7962365937
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  42 0.4250000000000001 0.5750000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  187081.7746701702
# RUN  0 , total integrated cost =  187081.7746701702
# Gradient descend method:  None
# RUN  0 , total integrated cost =  187081.7746701702
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  43 0.4500000000000001 0.5750000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  293856.7484005505
# RUN  0 , total integrated cost =  293856.7484005505
# Gradient descend method:  None
# RUN  0 , total integrated cost =  293856.7484005505
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  44 0.47500000000000014 0.5750000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  401498.6789492869
# RUN  0 , total integrated cost =  401498.6789492869
# Gradient descend method:  None
# RUN  0 , total integrated cost =  401498.6789492869
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  45 0.5000000000000002 0.5750000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  513234.6635746044
# RUN  0 , total integrated cost =  513234.6635746044
# Gradient descend method:  None
# RUN  0 , total integrated cost =  513234.6635746044
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  46 0.5250000000000001 0.5750000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  629845.1306750294
# RUN  0 , total integrated cost =  629845.1306750294
# Gradient descend method:  None
# RUN  0 , total integrated cost =  629845.1306750294
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  47 0.5500000000000003 0.5750000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  751175.9333805718
# RUN  0 , total integrated cost =  751175.9333805718
# Gradient descend method:  None
# RUN  0 , total integrated cost =  751175.9333805718
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  48 0.4250000000000001 0.6000000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  181882.521994222
# RUN  0 , total integrated cost =  181882.521994222
# Gradient descend method:  None
# RUN  0 , total integrated cost =  181882.521994222
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  49 0.4500000000000001 0.6000000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  289049.15272407274
# RUN  0 , total integrated cost =  289049.15272407274
# Gradient descend method:  None
# RUN  0 , total integrated cost =  289049.15272407274
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  50 0.47500000000000014 0.6000000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  396670.24943190784
# RUN  0 , total integrated cost =  396670.24943190784
# Gradient descend method:  None
# RUN  0 , total integrated cost =  396670.24943190784
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  51 0.5000000000000002 0.6000000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  508302.3902818461
# RUN  0 , total integrated cost =  508302.3902818461
# Gradient descend method:  None
# RUN  0 , total integrated cost =  508302.3902818461
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  52 0.5250000000000001 0.6000000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  624775.8829897492
# RUN  0 , total integrated cost =  624775.8829897492
# Gradient descend method:  None
# RUN  0 , total integrated cost =  624775.8829897492
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  53 0.5500000000000003 0.6000000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  746144.5805987157
# RUN  0 , total integrated cost =  746144.5805987157
# Gradient descend method:  None
# RUN  0 , total integrated cost =  746144.5805987157
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  54 0.5750000000000002 0.6000000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  870523.2701234882
# RUN  0 , total integrated cost =  870523.2701234882
# Gradient descend method:  None
# RUN  0 , total integrated cost =  870523.2701234882
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  55 0.4250000000000001 0.6250000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  176973.53086129532
# RUN  0 , total integrated cost =  176973.53086129532
# Gradient descend method:  None
# RUN  0 , total integrated cost =  176973.53086129532
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  56 0.4500000000000001 0.6250000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  284563.6049902908
# RUN  0 , total integrated cost =  284563.6049902908
# Gradient descend method:  None
# RUN  0 , total integrated cost =  284563.6049902908
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  57 0.47500000000000014 0.6250000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  392168.01147703634
# RUN  0 , total integrated cost =  392168.01147703634
# Gradient descend method:  None
# RUN  0 , total integrated cost =  392168.01147703634
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  58 0.5000000000000002 0.6250000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  503700.90762437455
# RUN  0 , total integrated cost =  503700.90762437455
# Gradient descend method:  None
# RUN  0 , total integrated cost =  503700.90762437455
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  59 0.5250000000000001 0.6250000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  620034.5060788749
# RUN  0 , total integrated cost =  620034.5060788749
# Gradient descend method:  None
# RUN  0 , total integrated cost =  620034.5060788749
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  60 0.5500000000000003 0.6250000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  741333.3077944894
# RUN  0 , total integrated cost =  741333.3077944894
# Gradient descend method:  None
# RUN  0 , total integrated cost =  741333.3077944894
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  61 0.5750000000000002 0.6250000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  866710.8536802017
# RUN  0 , total integrated cost =  866710.8536802017
# Gradient descend method:  None
# RUN  0 , total integrated cost =  866710.8536802017
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  62 0.4250000000000001 0.6500000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  172327.22420179544
# RUN  0 , total integrated cost =  172327.22420179544
# Gradient descend method:  None
# RUN  0 , total integrated cost =  172327.22420179544
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  63 0.4500000000000001 0.6500000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  280358.4423685195
# RUN  0 , total integrated cost =  280358.4423685195
# Gradient descend method:  None
# RUN  0 , total integrated cost =  280358.4423685195
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  64 0.47500000000000014 0.6500000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  387959.78150038864
# RUN  0 , total integrated cost =  387959.78150038864
# Gradient descend method:  None
# RUN  0 , total integrated cost =  387959.78150038864
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  65 0.5000000000000002 0.6500000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  499381.32678329153
# RUN  0 , total integrated cost =  499381.32678329153
# Gradient descend method:  None
# RUN  0 , total integrated cost =  499381.32678329153
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  66 0.5250000000000001 0.6500000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  615596.4660225171
# RUN  0 , total integrated cost =  615596.4660225171
# Gradient descend method:  None
# RUN  0 , total integrated cost =  615596.4660225171
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  67 0.5500000000000003 0.6500000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  736788.193418642
# RUN  0 , total integrated cost =  736788.193418642
# Gradient descend method:  None
# RUN  0 , total integrated cost =  736788.193418642
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  68 0.5750000000000002 0.6500000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  862467.9253654084
# RUN  0 , total integrated cost =  862467.9253654084
# Gradient descend method:  None
# RUN  0 , total integrated cost =  862467.9253654084
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  69 0.4250000000000001 0.6750000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  167933.86239870195
# RUN  0 , total integrated cost =  167933.86239870195
# Gradient descend method:  None
# RUN  0 , total integrated cost =  167933.86239870195
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  70 0.4500000000000001 0.6750000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  276399.77278526267
# RUN  0 , total integrated cost =  276399.77278526267
# Gradient descend method:  None
# RUN  0 , total integrated cost =  276399.77278526267
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  71 0.47500000000000014 0.6750000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  384005.59692905797
# RUN  0 , total integrated cost =  384005.59692905797
# Gradient descend method:  None
# RUN  0 , total integrated cost =  384005.59692905797
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  72 0.5000000000000002 0.6750000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  495331.1329655588
# RUN  0 , total integrated cost =  495331.1329655588
# Gradient descend method:  None
# RUN  0 , total integrated cost =  495331.1329655588
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  73 0.5250000000000001 0.6750000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  611432.0686370909
# RUN  0 , total integrated cost =  611432.0686370909
# Gradient descend method:  None
# RUN  0 , total integrated cost =  611432.0686370909
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  74 0.5500000000000003 0.6750000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  732509.8149166821
# RUN  0 , total integrated cost =  732509.8149166821
# Gradient descend method:  None
# RUN  0 , total integrated cost =  732509.8149166821
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  75 0.5750000000000002 0.6750000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  858276.8196420075
# RUN  0 , total integrated cost =  858276.8196420075
# Gradient descend method:  None
# RUN  0 , total integrated cost =  858276.8196420075
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  76 0.4250000000000001 0.7000000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  163736.8297408659
# RUN  0 , total integrated cost =  163736.8297408659
# Gradient descend method:  None
# RUN  0 , total integrated cost =  163736.8297408659
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  77 0.4500000000000001 0.7000000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  272681.6442786969
# RUN  0 , total integrated cost =  272681.6442786969
# Gradient descend method:  None
# RUN  0 , total integrated cost =  272681.6442786969
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  78 0.47500000000000014 0.7000000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  380284.89211629244
# RUN  0 , total integrated cost =  380284.89211629244
# Gradient descend method:  None
# RUN  0 , total integrated cost =  380284.89211629244
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  79 0.5000000000000002 0.7000000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  491528.53199543635
# RUN  0 , total integrated cost =  491528.53199543635
# Gradient descend method:  None
# RUN  0 , total integrated cost =  491528.53199543635
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  80 0.5250000000000001 0.7000000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  607506.209585381
# RUN  0 , total integrated cost =  607506.209585381
# Gradient descend method:  None
# RUN  0 , total integrated cost =  607506.209585381
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  81 0.5500000000000003 0.7000000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  728478.2773809158
# RUN  0 , total integrated cost =  728478.2773809158
# Gradient descend method:  None
# RUN  0 , total integrated cost =  728478.2773809158
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  82 0.5750000000000002 0.7000000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  854238.9955664313
# RUN  0 , total integrated cost =  854238.9955664313
# Gradient descend method:  None
# RUN  0 , total integrated cost =  854238.9955664313
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.

# %%
bad = [41,47, 52, 53, 54, 59, 67, 68, 74, 79, 82]

# %%
cgv = None
j = 0

wp = 1.

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    
    if type(bestControl_[i]) != type(None) or i in bad:
        continue
        
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
        
    found_exponent = False
    found_digit_0 = False
    found_digit_1 = False
    exponent = 1
    sig_digit = [1., 0.]
    
    while not found_digit_1:
        
        if exponent < -10:
            bad.append(i)
            continue
        
        w_[i] = sig_digit[0] * 10**exponent + sig_digit[1] * 10**(exponent-1.)
    
        dur = d_array[0]
        aln.params.duration = dur
        setinit(initVars[i], aln)

        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        control0 = aln.getZeroControl()
        cost.setParams(wp, factor_we * w_[i], factor_ws * w_[i])
        max_it = int(100)

        bestControl_[i], bestState_[i], cost_[i], runtime_, grad_, phi_, phi1_, costnode_[i] = aln.A1(
            control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
            prec_variables_ = p_var, transition_time_ = t_pen[0])
        
        if found_exponent == False and cost_[i][-1] == 0.:
            exponent -= 1
            continue
        elif found_exponent == False and found_digit_0 == False:
            found_exponent = True
            sig_digit[0] = 9.
        elif found_exponent == True and found_digit_0 == False and cost_[i][-1] == 0.:
            sig_digit[0] -= 1.
        elif found_exponent == True and found_digit_0 == False:
            found_digit_0 = True
            sig_digit[1] = 9.
        elif found_exponent == True and found_digit_0 == True and found_digit_1 == False and cost_[i][-1] == 0.:
            sig_digit[1] -= 1.
        elif found_exponent == True and found_digit_0 == True and found_digit_1 == False:
            print("weight = ", w_[i])
                        
            if True:
                plot_time_array = np.arange(0.,round(dur+aln.params.dt,1),aln.params.dt)
                target_ = aln.getZeroTarget()
                target_[:,0,:] = target[i][0]
                target_[:,1,:] = target[i][1]

                fig, ax = plt.subplots(3,1, constrained_layout=True, figsize = (4,8) )
                ax[1].plot(plot_time_array, bestControl_[i][0,0,n_pre-1:-n_post+1], color = 'red')
                ax[0].plot(plot_time_array, bestState_[i][0,0,n_pre-1:-n_post+1], color= 'red')
                ax[1].plot(plot_time_array, bestControl_[i][0,1,n_pre-1:-n_post+1], color = 'blue')
                ax[0].plot(plot_time_array, bestState_[i][0,1,n_pre-1:-n_post+1], color= 'blue')
                ax[0].plot(plot_time_array, target_[0,0,n_pre-1:-n_post+1], linestyle = '--', color='red')
                ax[0].plot(plot_time_array, target_[0,1,n_pre-1:-n_post+1], linestyle = '--', color='blue')


                ax[2].plot(plot_time_array, phi_[0,0,:], color = 'red')
                ax[2].plot(plot_time_array, phi_[0,1,:], color = 'blue')
                for k in range(3):
                    ax[k].set_xlim(0.,dur)
                    ax[k].axvspan(dur*t_pen[0], dur, alpha=0.2, color='gray')
                plt.show()

            break    
            
        with open(file_,'wb') as f:
            pickle.dump([bestControl_, bestState_, cost_, costnode_, weights_], f)

        print('uncontrolled cost : ', cost_uncontrolled[i])
        print('cost splitting : ', costnode_[i][0][0][0], costnode_[i][2][0][:2])
# Out:
# -------  0 0.4000000000000001 0.3500000000000001
# -------  1 0.4250000000000001 0.3500000000000001
# -------  2 0.4000000000000001 0.3750000000000001
# -------  3 0.4250000000000001 0.3750000000000001
# -------  4 0.4500000000000001 0.3750000000000001
# -------  5 0.4000000000000001 0.40000000000000013
# -------  6 0.4250000000000001 0.40000000000000013
# -------  7 0.4500000000000001 0.40000000000000013
# -------  8 0.47500000000000014 0.40000000000000013
# -------  9 0.4000000000000001 0.42500000000000016
# -------  10 0.4250000000000001 0.42500000000000016
# -------  11 0.4500000000000001 0.42500000000000016
# -------  12 0.47500000000000014 0.42500000000000016
# -------  13 0.4000000000000001 0.4500000000000002
# -------  14 0.4250000000000001 0.4500000000000002
# -------  15 0.4500000000000001 0.4500000000000002
# -------  16 0.47500000000000014 0.4500000000000002
# -------  17 0.5000000000000002 0.4500000000000002
# -------  18 0.4000000000000001 0.4750000000000002
# -------  19 0.4250000000000001 0.4750000000000002
# -------  20 0.4500000000000001 0.4750000000000002
# -------  21 0.47500000000000014 0.4750000000000002
# -------  22 0.5000000000000002 0.4750000000000002
# -------  23 0.5250000000000001 0.4750000000000002
# -------  24 0.4000000000000001 0.5000000000000002
# -------  25 0.4250000000000001 0.5000000000000002
# -------  26 0.4500000000000001 0.5000000000000002
# -------  27 0.47500000000000014 0.5000000000000002
# -------  28 0.5000000000000002 0.5000000000000002
# -------  29 0.5250000000000001 0.5000000000000002
# -------  30 0.4250000000000001 0.5250000000000002
# -------  31 0.4500000000000001 0.5250000000000002
# -------  32 0.47500000000000014 0.5250000000000002
# -------  33 0.5000000000000002 0.5250000000000002
# -------  34 0.5250000000000001 0.5250000000000002
# -------  35 0.5500000000000003 0.5250000000000002
# -------  36 0.4250000000000001 0.5500000000000003
# -------  37 0.4500000000000001 0.5500000000000003
# -------  38 0.47500000000000014 0.5500000000000003
# -------  39 0.5000000000000002 0.5500000000000003
# -------  40 0.5250000000000001 0.5500000000000003
# -------  41 0.5500000000000003 0.5500000000000003
# -------  42 0.4250000000000001 0.5750000000000003
# -------  43 0.4500000000000001 0.5750000000000003
# -------  44 0.47500000000000014 0.5750000000000003
# -------  45 0.5000000000000002 0.5750000000000003
# -------  46 0.5250000000000001 0.5750000000000003
# -------  47 0.5500000000000003 0.5750000000000003
# -------  48 0.4250000000000001 0.6000000000000003
# -------  49 0.4500000000000001 0.6000000000000003
# -------  50 0.47500000000000014 0.6000000000000003
# -------  51 0.5000000000000002 0.6000000000000003
# -------  52 0.5250000000000001 0.6000000000000003
# -------  53 0.5500000000000003 0.6000000000000003
# -------  54 0.5750000000000002 0.6000000000000003
# -------  55 0.4250000000000001 0.6250000000000003
# -------  56 0.4500000000000001 0.6250000000000003
# -------  57 0.47500000000000014 0.6250000000000003
# -------  58 0.5000000000000002 0.6250000000000003
# -------  59 0.5250000000000001 0.6250000000000003
# -------  60 0.5500000000000003 0.6250000000000003
# -------  61 0.5750000000000002 0.6250000000000003
# -------  62 0.4250000000000001 0.6500000000000004
# -------  63 0.4500000000000001 0.6500000000000004
# -------  64 0.47500000000000014 0.6500000000000004
# -------  65 0.5000000000000002 0.6500000000000004
# -------  66 0.5250000000000001 0.6500000000000004
# -------  67 0.5500000000000003 0.6500000000000004
# -------  68 0.5750000000000002 0.6500000000000004
# -------  69 0.4250000000000001 0.6750000000000004
# -------  70 0.4500000000000001 0.6750000000000004
# -------  71 0.47500000000000014 0.6750000000000004
# -------  72 0.5000000000000002 0.6750000000000004
# -------  73 0.5250000000000001 0.6750000000000004
# -------  74 0.5500000000000003 0.6750000000000004
# -------  75 0.5750000000000002 0.6750000000000004
# -------  76 0.4250000000000001 0.7000000000000004
# -------  77 0.4500000000000001 0.7000000000000004
# -------  78 0.47500000000000014 0.7000000000000004
# -------  79 0.5000000000000002 0.7000000000000004
# -------  80 0.5250000000000001 0.7000000000000004
# -------  81 0.5500000000000003 0.7000000000000004
# -------  82 0.5750000000000002 0.7000000000000004

# %%
print(bad)
# Out:
# [41, 47, 52, 53, 54, 59, 67, 68, 74, 79, 82]

# %%
for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    k = 0
    
    while not conv[i]:
        max_it = min( 1000, int(100 + 100*k) )

        if k < 4:
            weight_ = max_it
        else:
            weight_ = ( cost_uncontrolled[i] - costnode_[i][0][0][0] ) / sum( costnode_[i][index_cost][0][:] ) - 100 
            
        dur = d_array[0]
        aln.params.duration = dur
        cost.setParams(1., weight_ * factor_we, weight_ * factor_ws)
        weights_[i] = cost.getParams()

        setinit(initVars[i], aln)

        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        control0 = aln.getZeroControl()
        control0 = bestControl_[i][:,:,n_pre-1:-n_post+1]

        bestControl_[i], bestState_[i], cost_[i], runtime_, grad_, phi_, phi1_, costnode_[i] = aln.A1(
            control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
            prec_variables_ = p_var, transition_time_ = t_pen[0])
        
        if max_it > 1:
            if cost_[i][2] == 0.:
                conv[i] = True
                if np.amax(np.abs(bestControl_[i])) < 1e-6:
                    bad.append(i)

        print('cost splitting : ', costnode_[i][0][0][0], costnode_[i][index_cost][0][:2])

        if conv[i]:
            time_ = np.arange(-dur_pre,round(dur+dur_post+aln.params.dt,1),aln.params.dt)
            target_ = aln.getZeroTarget()
            target_[:,0,:] = target[i][0]
            target_[:,1,:] = target[i][1]
        
            fig, ax = plt.subplots(2,1, constrained_layout=True, figsize = (4,4) )
            ax[1].plot(time_, bestControl_[i][0,0,:], color = 'red')
            ax[0].plot(time_, bestState_[i][0,0,:], color= 'red')
            ax[1].plot(time_, bestControl_[i][0,1,:], color = 'blue')
            ax[0].plot(time_, bestState_[i][0,1,:], color= 'blue')
            ax[0].plot(time_, target_[0,0,:], linestyle = '--', color='red')
            ax[0].plot(time_, target_[0,1,:], linestyle = '--', color='blue')
            ax[0].set_xlim(-dur_pre,dur+dur_post)
            ax[1].set_xlim(-dur_pre,dur+dur_post)
            ax[0].axvspan(dur*t_pen[0], dur, alpha=0.2, color='gray')
            plt.show()

        with open(file_,'wb') as f:
            pickle.dump([bestControl_, bestState_, cost_, costnode_, weights_], f)
        
        k += 1
# Out:
# -------  0 0.4000000000000001 0.3500000000000001
# -------  1 0.4250000000000001 0.3500000000000001
# set cost params:  1.0 100.0 0.0
# interpolate adjoint :  True True True
# initial cost =  170.29185137517825
# RUN  0 , total integrated cost =  170.29185137517825
# Gradient descend method:  None
# RUN  1 , total integrated cost =  170.18101910455337
# RUN  2 , total integrated cost =  170.14430380520977
# RUN  3 , total integrated cost =  170.1056790804551
# RUN  4 , total integrated cost =  170.08118160622882
# RUN  5 , total integrated cost =  170.05502269668673
# RUN  6 , total integrated cost =  170.03328387106296
# RUN  7 , total integrated cost =  170.01165893390888
# RUN  8 , total integrated cost =  169.99456831003425
# RUN  9 , total integrated cost =  169.9764906722307
# RUN  10 , total integrated cost =  169.9607571449047
# RUN  11 , total integrated cost =  169.94396514321585
# RUN  12 , total integrated cost =  169.92927484109768
# RUN  13 , total integrated cost =  169.91342679321465
# RUN  14 , total integrated cost =  169.89917159204313
# RUN  15 , total integrated cost =  169.88377353133444
# RUN  16 , total integrated cost =  169.86993988666765
# RUN  17 , total integrated cost =  169.8547659279358
# RUN  18 , total integrated cost =  169.84103804127034
# RUN  19 , total integrated cost =  169.82598577367932
# RUN  20 , total integrated cost =  169.81162991471817
# RUN  30 , total integrated cost =  169.65520363399597
# RUN  40 , total integrated cost =  169.40125148465972
# RUN  50 , total integrated cost =  168.84074358773626
# RUN  60 , total integrated cost =  168.7987864627049
# RUN  70 , total integrated cost =  168.75900352531912
# RUN  80 , total integrated cost =  168.60260418493937
# RUN  90 , total integrated cost =  168.57977651407825
# RUN  100 , total integrated cost =  168.49615588245277
# RUN  100 , total integrated cost =  168.49615588245277
# Improved over  100  iterations in  68.15308359265327  seconds by  1.0544811617376126  percent.
# cost splitting :  0.03578265025949589 [1.67605862 0.        ]
# set cost params:  1.0 200.0 0.0
# interpolate adjoint :  True True True
# initial cost =  336.102018063673
# RUN  0 , total integrated cost =  336.102018063673
# Gradient descend method:  None
# RUN  1 , total integrated cost =  336.0032071991195
# RUN  2 , total integrated cost =  335.89793507287214
# RUN  3 , total integrated cost =  335.7879371775073
# RUN  4 , total integrated cost =  335.73239544989156
# RUN  5 , total integrated cost =  335.67463353004075
# RUN  6 , total integrated cost =  335.65150166833166
# RUN  7 , total integrated cost =  335.62626841583756
# RUN  8 , total integrated cost =  335.6054887229958
# RUN  9 , total integrated cost =  335.58244453811716
# RUN  10 , total integrated cost =  335.5628048892334
# RUN  11 , total integrated cost =  335.5422718334026
# RUN  12 , total integrated cost =  335.52819700907486
# RUN  13 , total integrated cost =  335.5111447695982
# RUN  14 , total integrated cost =  335.4976969110173
# RUN  15 , total integrated cost =  335.4820234451565
# RUN  16 , total integrated cost =  335.4713280522231
# RUN  17 , total integrated cost =  335.4584919420752
# RUN  18 , total integrated cost =  335.4480556773009
# RUN  19 , total integrated cost =  335.43546760167493
# RUN  20 , total integrated cost =  335.42525340603834
# RUN  30 , total integrated cost =  335.1403649604761
# RUN  40 , total integrated cost =  333.00873559565446
# RUN  50 , total integrated cost =  333.0001357037858
# RUN  60 , total integrated cost =  332.99208111717655
# RUN  70 , total integrated cost =  332.98350551621724
# RUN  80 , total integrated cost =  332.93837062940855
# RUN  90 , total integrated cost =  332.9334012405833
# RUN  100 , total integrated cost =  332.8849103035037
# RUN  110 , total integrated cost =  332.87175728978445
# RUN  120 , total integrated cost =  332.86548070595643
# RUN  130 , total integrated cost =  332.7265282068323
# RUN  140 , total integrated cost =  332.7184443095984
# RUN  150 , total integrated cost =  331.8627617939406
# RUN  160 , total integrated cost =  331.85073430279334
# RUN  170 , total integrated cost =  331.82991110137056
# RUN  180 , total integrated cost =  331.6054841680254
# RUN  190 , total integrated cost =  331.4918744972347
# RUN  200 , total integrated cost =  331.4697240868964
# RUN  200 , total integrated cost =  331.4697240868964
# Improved over  200  iterations in  147.32766318321228  seconds by  1.3782404531409185  percent.
# cost splitting :  0.15021435083546703 [1.63866151 0.        ]
# set cost params:  1.0 300.0 0.0
# interpolate adjoint :  True True True
# initial cost =  495.33587476584677
# RUN  0 , total integrated cost =  495.33587476584677
# Gradient descend method:  None
# RUN  1 , total integrated cost =  495.3299400238655
# RUN  2 , total integrated cost =  495.3244495885381
# RUN  3 , total integrated cost =  495.3189325095449
# RUN  4 , total integrated cost =  495.31451518813566
# RUN  5 , total integrated cost =  495.3099081262885
# RUN  6 , total integrated cost =  495.3063964542997
# RUN  7 , total integrated cost =  495.30164931544044
# RUN  8 , total integrated cost =  495.29785114471275
# RUN  9 , total integrated cost =  495.2929531858351
# RUN  10 , total integrated cost =  495.2890500062333
# RUN  11 , total integrated cost =  495.2835342184071
# RUN  12 , total integrated cost =  495.27863080687536
# RUN  13 , total integrated cost =  495.27145926906536
# RUN  14 , total integrated cost =  495.2645236353202
# RUN  15 , total integrated cost =  495.22676752741614
# RUN  16 , total integrated cost =  495.1931897196722
# RUN  17 , total integrated cost =  495.15738489578996
# RUN  18 , total integrated cost =  495.1198317577737
# RUN  19 , total integrated cost =  495.1163768470846
# RUN  20 , total integrated cost =  495.11232790887965
# RUN  30 , total integrated cost =  495.0583703620297
# RUN  40 , total integrated cost =  494.1145791891439
# RUN  50 , total integrated cost =  494.09747903417735
# RUN  60 , total integrated cost =  494.0939906291282
# RUN  70 , total integrated cost =  494.0907299164019
# RUN  80 , total integrated cost =  494.087177163109
# RUN  90 , total integrated cost =  494.0746655926381
# RUN  100 , total integrated cost =  494.0640354541599
# RUN  110 , total integrated cost =  494.06040761606187
# RUN  120 , total integrated cost =  494.05607150798664
# RUN  130 , total integrated cost =  494.05229843357216
# RUN  140 , total integrated cost =  494.02525405876895
# RUN  150 , total integrated cost =  494.0064627186491
# RUN  160 , total integrated cost =  494.0004129742409
# RUN  170 , total integrated cost =  493.9955494358391
# RUN  180 , total integrated cost =  493.9922365728362
# RUN  190 , total integrated cost =  493.98937256987745
# RUN  200 , total integrated cost =  493.9864685977143
# RUN  300 , total integrated cost =  493.70554276074597
# RUN  300 , total integrated cost =  493.70554276074597
# Improved over  300  iterations in  70.22637379914522  seconds by  0.32913667031920113  percent.
# cost splitting :  0.28549872411533733 [1.62200721 0.        ]
# set cost params:  1.0 400.0 0.0
# interpolate adjoint :  True True True
# initial cost =  655.9062641133324
# RUN  0 , total integrated cost =  655.9062641133324
# Gradient descend method:  None
# RUN  1 , total integrated cost =  655.8855755952815
# RUN  2 , total integrated cost =  655.6985245186688
# RUN  3 , total integrated cost =  655.5792598976774
# RUN  4 , total integrated cost =  655.5789002823991
# RUN  5 , total integrated cost =  655.5782205182011
# RUN  6 , total integrated cost =  655.5779841893728
# RUN  7 , total integrated cost =  655.5770783767309
# RUN  8 , total integrated cost =  655.5764743102492
# RUN  9 , total integrated cost =  655.3260548333083
# RUN  10 , total integrated cost =  655.3216282759513
# RUN  11 , total integrated cost =  655.3183264084379
# RUN  12 , total integrated cost =  655.3153976256609
# RUN  13 , total integrated cost =  655.3145836477039
# RUN  14 , total integrated cost =  655.3136142590014
# RUN  15 , total integrated cost =  655.3135474200683
# RUN  16 , total integrated cost =  655.3118567401787
# RUN  17 , total integrated cost =  655.3101400468513
# RUN  18 , total integrated cost =  655.3094090187631
# RUN  19 , total integrated cost =  655.3085580336025
# RUN  20 , total integrated cost =  655.3085092632284
# RUN  30 , total integrated cost =  655.2935224738019
# RUN  40 , total integrated cost =  655.0533433992352
# RUN  50 , total integrated cost =  655.0465881828476
# RUN  60 , total integrated cost =  655.0399527900898
# RUN  70 , total integrated cost =  655.0370071084319
# RUN  80 , total integrated cost =  655.0344077410352
# RUN  90 , total integrated cost =  655.0306266578121
# RUN  100 , total integrated cost =  655.0267727416588
# RUN  110 , total integrated cost =  655.0224589475357
# RUN  120 , total integrated cost =  654.3633079660015
# RUN  130 , total integrated cost =  654.360900051815
# RUN  140 , total integrated cost =  654.3584951008984
# RUN  150 , total integrated cost =  654.3561171658508
# RUN  160 , total integrated cost =  654.3536652843709
# RUN  170 , total integrated cost =  654.309018504833
# RUN  180 , total integrated cost =  654.3034907017706
# RUN  190 , total integrated cost =  654.2880755533233
# RUN  200 , total integrated cost =  654.2797947217249
# RUN  300 , total integrated cost =  653.5283664908146
# RUN  400 , total integrated cost =  653.2529169720868
# RUN  400 , total integrated cost =  653.2529169720868
# Improved over  400  iterations in  154.01306365430355  seconds by  0.404531453108234  percent.
# cost splitting :  0.3582763379526633 [1.61084697 0.        ]
# set cost params:  1.0 151518.59032831012 0.0
# interpolate adjoint :  True True True
# initial cost =  244082.17617772208
# RUN  0 , total integrated cost =  244082.17617772208
# Gradient descend method:  None
# RUN  1 , total integrated cost =  242244.64142659045
# RUN  2 , total integrated cost =  178924.4009193218
# RUN  3 , total integrated cost =  172971.31145824847
# RUN  4 , total integrated cost =  172636.10941453578
# RUN  5 , total integrated cost =  172614.21254808397
# RUN  6 , total integrated cost =  172610.63712867917
# RUN  7 , total integrated cost =  172610.63712867917
# Control only changes marginally.
# RUN  7 , total integrated cost =  172610.63712867917
# Improved over  7  iterations in  3.944435015320778  seconds by  29.281752632770193  percent.
# cost splitting :  4438.073142112488 [0.41043629 0.        ]
# set cost params:  1.0 584148.1256386839 0.0
# interpolate adjoint :  True True True
# initial cost =  350177.4976225873
# RUN  0 , total integrated cost =  350177.4976225873
# Gradient descend method:  None
# RUN  1 , total integrated cost =  224057.20351587175
# RUN  2 , total integrated cost =  223644.20967574947
# RUN  3 , total integrated cost =  223641.10708852034
# RUN  4 , total integrated cost =  223641.10708852034
# Control only changes marginally.
# RUN  4 , total integrated cost =  223641.10708852034
# Improved over  4  iterations in  4.586955189704895  seconds by  36.13492911256244  percent.
# cost splitting :  8188.526809900527 [0.03407641 0.        ]
# set cost params:  1.0 6926867.189225139 0.0
# interpolate adjoint :  True True True
# initial cost =  439778.206273908
# RUN  0 , total integrated cost =  439778.206273908
# Gradient descend method:  None
# RUN  1 , total integrated cost =  242677.65812533826
# RUN  2 , total integrated cost =  242432.46514684433
# RUN  3 , total integrated cost =  242431.82658146654
# RUN  4 , total integrated cost =  242431.82651849152
# RUN  5 , total integrated cost =  242431.82651849123
# RUN  6 , total integrated cost =  242431.82651849123
# Control only changes marginally.
# RUN  6 , total integrated cost =  242431.82651849123
# Improved over  6  iterations in  6.030255556106567  seconds by  44.87406991525704  percent.
# cost splitting :  9671.625347869727 [0.00025928 0.        ]
# set cost params:  1.0 904662958.6372724 0.0
# interpolate adjoint :  True True True
# initial cost =  475198.86650541046
# RUN  0 , total integrated cost =  475198.86650541046
# Gradient descend method:  None
# RUN  1 , total integrated cost =  244850.31111470022
# RUN  2 , total integrated cost =  244222.72372491565
# RUN  3 , total integrated cost =  244220.99451095075
# RUN  4 , total integrated cost =  244220.99183422662
# RUN  5 , total integrated cost =  244220.99183398281
# RUN  6 , total integrated cost =  244220.9918339826
# RUN  7 , total integrated cost =  244220.9918339826
# Control only changes marginally.
# RUN  7 , total integrated cost =  244220.9918339826
# Improved over  7  iterations in  6.963618725538254  seconds by  48.60657104888065  percent.
# cost splitting :  9815.169585920023 [1.51578369e-08 0.00000000e+00]
# set cost params:  1.0 15465236719141.672 0.0
# interpolate adjoint :  True True True
# initial cost =  478626.8145348144
# RUN  0 , total integrated cost =  478626.8145348144
# Gradient descend method:  None
# RUN  1 , total integrated cost =  244263.14942290788
# RUN  2 , total integrated cost =  244234.7076872905
# RUN  3 , total integrated cost =  244234.7042202295
# RUN  4 , total integrated cost =  244234.70421961637
# RUN  5 , total integrated cost =  244234.70421961637
# Control only changes marginally.
# RUN  5 , total integrated cost =  244234.70421961637
# Improved over  5  iterations in  7.596202932298183  seconds by  48.971788290425756  percent.
# cost splitting :  9816.27182301351 [5.18744311e-17 0.00000000e+00]
# set cost params:  1.0 4.518959110627239e+21 0.0
# interpolate adjoint :  True True True
# initial cost =  478653.1366161747
# RUN  0 , total integrated cost =  478653.1366161747
# Gradient descend method:  None
# RUN  1 , total integrated cost =  244669.62139653228
# RUN  2 , total integrated cost =  244235.5119219211
# RUN  3 , total integrated cost =  244234.70651886205
# RUN  4 , total integrated cost =  244234.70651886205
# Control only changes marginally.
# RUN  4 , total integrated cost =  244234.70651886205
# Improved over  4  iterations in  6.861029297113419  seconds by  48.97459395221503  percent.
# cost splitting :  9816.271887494519 [3.31308614e-25 0.00000000e+00]
# set cost params:  1.0 7.075530892807548e+29 0.0
# interpolate adjoint :  True True True
# initial cost =  478653.13815601956
# RUN  0 , total integrated cost =  478653.13815601956
# Gradient descend method:  None
# RUN  1 , total integrated cost =  478653.13815601956
# Control only changes marginally.
# RUN  1 , total integrated cost =  478653.13815601956
# Improved over  1  iterations in  3.3235723301768303  seconds by  0.0  percent.
# cost splitting :  9816.271887494519 [3.31308614e-25 0.00000000e+00]
# -------  2 0.4000000000000001 0.3750000000000001
# set cost params:  1.0 100.0 0.0
# interpolate adjoint :  True True True
# initial cost =  127908.76991670861
# RUN  0 , total integrated cost =  127908.76991670861
# Gradient descend method:  None
# RUN  1 , total integrated cost =  25.18422314189641
# RUN  2 , total integrated cost =  25.18422313863289
# RUN  3 , total integrated cost =  25.184223138609283
# RUN  4 , total integrated cost =  25.184223138609283
# Control only changes marginally.
# RUN  4 , total integrated cost =  25.184223138609283
# Improved over  4  iterations in  5.696287080645561  seconds by  99.98031079248514  percent.
# cost splitting :  5.623428314063464e-08 [0.25184222 0.        ]
# set cost params:  1.0 200.0 0.0
# interpolate adjoint :  True True True
# initial cost =  50.36844487807603
# RUN  0 , total integrated cost =  50.36844487807603
# Gradient descend method:  None
# RUN  1 , total integrated cost =  50.36844450843953
# RUN  2 , total integrated cost =  50.368444508287844
# RUN  3 , total integrated cost =  50.368444508287844
# Control only changes marginally.
# RUN  3 , total integrated cost =  50.368444508287844
# Improved over  3  iterations in  4.041836716234684  seconds by  7.341663774695917e-07  percent.
# cost splitting :  9.292713859352858e-08 [0.25184221 0.        ]
# set cost params:  1.0 300.0 0.0
# interpolate adjoint :  True True True
# initial cost =  75.55266560639042
# RUN  0 , total integrated cost =  75.55266560639042
# Gradient descend method:  None
# RUN  1 , total integrated cost =  75.55266543267544
# RUN  2 , total integrated cost =  75.55266543255395
# RUN  3 , total integrated cost =  75.55266543255395
# Control only changes marginally.
# RUN  3 , total integrated cost =  75.55266543255395
# Improved over  3  iterations in  3.991442695260048  seconds by  2.3008648497579998e-07  percent.
# cost splitting :  1.232738506142842e-07 [0.25184221 0.        ]
# set cost params:  1.0 400.0 0.0
# interpolate adjoint :  True True True
# initial cost =  100.73688622102992
# RUN  0 , total integrated cost =  100.73688622102992
# Gradient descend method:  None
# RUN  1 , total integrated cost =  100.73688610154291
# RUN  2 , total integrated cost =  100.73688610132652
# RUN  3 , total integrated cost =  100.73688610132652
# Control only changes marginally.
# RUN  3 , total integrated cost =  100.73688610132652
# Improved over  3  iterations in  4.351129859685898  seconds by  1.1882778494509694e-07  percent.
# cost splitting :  1.511229720117486e-07 [0.25184221 0.        ]
# set cost params:  1.0 547093.2528024452 0.0
# interpolate adjoint :  True True True
# initial cost =  137781.17159695312
# RUN  0 , total integrated cost =  137781.17159695312
# Gradient descend method:  None
# RUN  1 , total integrated cost =  137781.16056622285
# RUN  2 , total integrated cost =  137781.1605634707
# RUN  3 , total integrated cost =  137781.1605634707
# Control only changes marginally.
# RUN  3 , total integrated cost =  137781.1605634707
# Improved over  3  iterations in  5.326721504330635  seconds by  8.007975466739481e-06  percent.
# cost splitting :  2.777825743557039e-05 [0.25184218 0.        ]
# set cost params:  1.0 547093.2992417548 0.0
# interpolate adjoint :  True True True
# initial cost =  137781.1722588479
# RUN  0 , total integrated cost =  137781.1722588479
# Gradient descend method:  None
# RUN  1 , total integrated cost =  137781.1722588479
# Control only changes marginally.
# RUN  1 , total integrated cost =  137781.1722588479
# Improved over  1  iterations in  1.9663881361484528  seconds by  0.0  percent.
# cost splitting :  2.777825743557039e-05 [0.25184218 0.        ]
# -------  3 0.4250000000000001 0.3750000000000001
# set cost params:  1.0 100.0 0.0
# interpolate adjoint :  True True True
# initial cost =  138.10287631593843
# RUN  0 , total integrated cost =  138.10287631593843
# Gradient descend method:  None
# RUN  1 , total integrated cost =  137.68174133002853
# RUN  2 , total integrated cost =  137.65712301674984
# RUN  3 , total integrated cost =  137.65589226891618
# RUN  4 , total integrated cost =  137.65587143690487
# RUN  5 , total integrated cost =  137.65587074463272
# RUN  6 , total integrated cost =  137.6558707220608
# RUN  7 , total integrated cost =  137.6558707220608
# Control only changes marginally.
# RUN  7 , total integrated cost =  137.6558707220608
# Improved over  7  iterations in  11.05118065327406  seconds by  0.32367580299704457  percent.
# cost splitting :  2.302413609866004e-09 [1.37655871 0.        ]
# set cost params:  1.0 200.0 0.0
# interpolate adjoint :  True True True
# initial cost =  275.31174138683616
# RUN  0 , total integrated cost =  275.31174138683616
# Gradient descend method:  None
# RUN  1 , total integrated cost =  275.31174138683616
# Control only changes marginally.
# RUN  1 , total integrated cost =  275.31174138683616
# Improved over  1  iterations in  2.3889760598540306  seconds by  0.0  percent.
# cost splitting :  2.302413609866004e-09 [1.37655871 0.        ]
# -------  4 0.4500000000000001 0.3750000000000001
# set cost params:  1.0 100.0 0.0
# interpolate adjoint :  True True True
# initial cost =  338432.5143933765
# RUN  0 , total integrated cost =  338432.5143933765
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3174.6121856259333
# RUN  2 , total integrated cost =  2353.8081893702088
# RUN  3 , total integrated cost =  1521.690175871823
# RUN  4 , total integrated cost =  1295.095704889208
# RUN  5 , total integrated cost =  1048.4521996166466
# RUN  6 , total integrated cost =  948.4720731995718
# RUN  7 , total integrated cost =  843.2043066262975
# RUN  8 , total integrated cost =  792.602645829531
# RUN  9 , total integrated cost =  731.502978540805
# RUN  10 , total integrated cost =  698.3012481460931
# RUN  11 , total integrated cost =  652.6446755186688
# RUN  12 , total integrated cost =  626.8892873309396
# RUN  13 , total integrated cost =  587.5159194424978
# RUN  14 , total integrated cost =  563.8565300044188
# RUN  15 , total integrated cost =  491.7012967968037
# RUN  16 , total integrated cost =  489.13672595301057
# RUN  17 , total integrated cost =  487.28423468998784
# RUN  18 , total integrated cost =  485.2732358511187
# RUN  19 , total integrated cost =  483.68975482383723
# RUN  20 , total integrated cost =  481.953739373674
# RUN  30 , total integrated cost =  469.27269247623855
# RUN  40 , total integrated cost =  459.04910253677116
# RUN  50 , total integrated cost =  449.0545407496103
# RUN  60 , total integrated cost =  409.97506650485747
# RUN  70 , total integrated cost =  406.44297423893164
# RUN  80 , total integrated cost =  403.8451464596926
# RUN  90 , total integrated cost =  381.27512164582726
# RUN  100 , total integrated cost =  377.10006559492496
# RUN  100 , total integrated cost =  377.10006559492496
# Improved over  100  iterations in  67.93368614464998  seconds by  99.88857451646723  percent.
# cost splitting :  0.39149636767074225 [3.67359402 0.        ]
# set cost params:  1.0 200.0 0.0
# interpolate adjoint :  True True True
# initial cost =  744.4594678330271
# RUN  0 , total integrated cost =  744.4594678330271
# Gradient descend method:  None
# RUN  1 , total integrated cost =  741.7473241734739
# RUN  2 , total integrated cost =  740.1012187463984
# RUN  3 , total integrated cost =  738.4421626046898
# RUN  4 , total integrated cost =  737.6325861335574
# RUN  5 , total integrated cost =  736.7801632016696
# RUN  6 , total integrated cost =  736.0535702088665
# RUN  7 , total integrated cost =  735.3051512008507
# RUN  8 , total integrated cost =  734.6609928346046
# RUN  9 , total integrated cost =  733.9936563525149
# RUN  10 , total integrated cost =  733.4766777893861
# RUN  11 , total integrated cost =  732.9116322487383
# RUN  12 , total integrated cost =  732.3720233160542
# RUN  13 , total integrated cost =  731.8257065009096
# RUN  14 , total integrated cost =  731.435910097942
# RUN  15 , total integrated cost =  731.0061627157959
# RUN  16 , total integrated cost =  730.5929936685211
# RUN  17 , total integrated cost =  730.1680408865137
# RUN  18 , total integrated cost =  729.7946093578458
# RUN  19 , total integrated cost =  729.382230360043
# RUN  20 , total integrated cost =  729.0691208611465
# RUN  30 , total integrated cost =  726.5208882157624
# RUN  40 , total integrated cost =  722.5997888486907
# RUN  50 , total integrated cost =  718.1976324651846
# RUN  60 , total integrated cost =  717.0445930865995
# RUN  70 , total integrated cost =  713.0799206175408
# RUN  80 , total integrated cost =  684.3930286975113
# RUN  90 , total integrated cost =  680.754669862794
# RUN  100 , total integrated cost =  679.0518091824564
# RUN  110 , total integrated cost =  667.706212192895
# RUN  120 , total integrated cost =  666.7648183363533
# RUN  130 , total integrated cost =  666.352625437335
# RUN  140 , total integrated cost =  666.094821463665
# RUN  150 , total integrated cost =  665.5229459921837
# RUN  160 , total integrated cost =  665.2008954243873
# RUN  170 , total integrated cost =  664.3564739748413
# RUN  180 , total integrated cost =  663.7832965391713
# RUN  190 , total integrated cost =  659.0693268146158
# RUN  200 , total integrated cost =  653.8221720551722
# RUN  200 , total integrated cost =  653.8221720551722
# Improved over  200  iterations in  91.28577936440706  seconds by  12.17491343641339  percent.
# cost splitting :  0.302705136540578 [3.23145344 0.        ]
# set cost params:  1.0 300.0 0.0
# interpolate adjoint :  True True True
# initial cost =  976.9675158244523
# RUN  0 , total integrated cost =  976.9675158244523
# Gradient descend method:  None
# RUN  1 , total integrated cost =  976.5603125218486
# RUN  2 , total integrated cost =  976.5388662731909
# RUN  3 , total integrated cost =  976.5105219786083
# RUN  4 , total integrated cost =  976.4961590255497
# RUN  5 , total integrated cost =  976.4764374886101
# RUN  6 , total integrated cost =  976.4627774135015
# RUN  7 , total integrated cost =  976.440793355012
# RUN  8 , total integrated cost =  976.423155784735
# RUN  9 , total integrated cost =  976.3835636646598
# RUN  10 , total integrated cost =  976.348755350838
# RUN  11 , total integrated cost =  975.5727314100566
# RUN  12 , total integrated cost =  975.2412204930336
# RUN  13 , total integrated cost =  975.2086301668894
# RUN  14 , total integrated cost =  975.1792343987798
# RUN  15 , total integrated cost =  975.1337229205312
# RUN  16 , total integrated cost =  975.0874523790919
# RUN  17 , total integrated cost =  975.082039681444
# RUN  18 , total integrated cost =  975.0731310351028
# RUN  19 , total integrated cost =  975.0692125990374
# RUN  20 , total integrated cost =  975.0595583271689
# RUN  30 , total integrated cost =  970.1994994350456
# RUN  40 , total integrated cost =  964.1579542761559
# RUN  50 , total integrated cost =  963.4790479481164
# RUN  60 , total integrated cost =  961.8848482379752
# RUN  70 , total integrated cost =  960.8263941618428
# RUN  80 , total integrated cost =  960.689617900275
# RUN  90 , total integrated cost =  960.5137039233593
# RUN  100 , total integrated cost =  960.4245692295514
# RUN  110 , total integrated cost =  957.5634632919771
# RUN  120 , total integrated cost =  957.4779631024195
# RUN  130 , total integrated cost =  957.4148217944371
# RUN  140 , total integrated cost =  957.2679591759281
# RUN  150 , total integrated cost =  955.6963198426089
# RUN  160 , total integrated cost =  955.5816203526747
# RUN  170 , total integrated cost =  955.538110644337
# RUN  180 , total integrated cost =  955.1075963854415
# RUN  190 , total integrated cost =  955.0756760613077
# RUN  200 , total integrated cost =  955.0298704488324
# RUN  300 , total integrated cost =  948.6208206385353
# RUN  300 , total integrated cost =  948.6208206385353
# Improved over  300  iterations in  80.75731789320707  seconds by  2.9014982306751023  percent.
# cost splitting :  0.2360620756200212 [3.14249152 0.        ]
# set cost params:  1.0 400.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1262.8699723933767
# RUN  0 , total integrated cost =  1262.8699723933767
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1262.7319470984046
# RUN  2 , total integrated cost =  1262.7103165991439
# RUN  3 , total integrated cost =  1262.6919343011093
# RUN  4 , total integrated cost =  1262.67857387818
# RUN  5 , total integrated cost =  1262.6618336963145
# RUN  6 , total integrated cost =  1262.6571176157631
# RUN  7 , total integrated cost =  1262.6490264262245
# RUN  8 , total integrated cost =  1262.646841878358
# RUN  9 , total integrated cost =  1262.6428618258117
# RUN  10 , total integrated cost =  1262.6402991991697
# RUN  11 , total integrated cost =  1262.602795195975
# RUN  12 , total integrated cost =  1262.5763660127272
# RUN  13 , total integrated cost =  1262.4961555609098
# RUN  14 , total integrated cost =  1262.4194594067037
# RUN  15 , total integrated cost =  1262.4148701804634
# RUN  16 , total integrated cost =  1262.408484803865
# RUN  17 , total integrated cost =  1262.4076196356837
# RUN  18 , total integrated cost =  1262.4043589560947
# RUN  19 , total integrated cost =  1262.4025539920297
# RUN  20 , total integrated cost =  1262.3869337801452
# RUN  30 , total integrated cost =  1262.3006548181663
# RUN  40 , total integrated cost =  1262.2575432225256
# RUN  50 , total integrated cost =  1262.2212684964563
# RUN  60 , total integrated cost =  1262.1891008794419
# RUN  70 , total integrated cost =  1261.6856155073667
# RUN  80 , total integrated cost =  1261.6144046720456
# RUN  90 , total integrated cost =  1260.8196517071287
# RUN  100 , total integrated cost =  1260.1716572986809
# RUN  110 , total integrated cost =  1259.3802867191805
# RUN  120 , total integrated cost =  1259.2139325503706
# RUN  130 , total integrated cost =  1259.1100183428493
# RUN  140 , total integrated cost =  1257.302784064858
# RUN  150 , total integrated cost =  1256.8570756750246
# RUN  160 , total integrated cost =  1256.8314807891531
# RUN  170 , total integrated cost =  1256.8128511178288
# RUN  180 , total integrated cost =  1256.7991679921402
# RUN  190 , total integrated cost =  1256.4192748637004
# RUN  200 , total integrated cost =  1256.4025041459129
# RUN  300 , total integrated cost =  1256.1096691110897
# RUN  400 , total integrated cost =  1252.7765829012474
# RUN  400 , total integrated cost =  1252.7765829012474
# Improved over  400  iterations in  163.00512593239546  seconds by  0.7992421795412952  percent.
# cost splitting :  0.260000711396378 [3.11576902 0.        ]
# set cost params:  1.0 108519.17288617732 0.0
# interpolate adjoint :  True True True
# initial cost =  338127.14646416483
# RUN  0 , total integrated cost =  338127.14646416483
# Gradient descend method:  None
# RUN  1 , total integrated cost =  334195.9895595043
# RUN  2 , total integrated cost =  334179.0392733596
# RUN  3 , total integrated cost =  333985.64017612266
# RUN  4 , total integrated cost =  333849.4982101754
# RUN  5 , total integrated cost =  333843.67935765366
# RUN  6 , total integrated cost =  333838.5409694413
# RUN  7 , total integrated cost =  333809.81623309973
# RUN  8 , total integrated cost =  333786.76331429393
# RUN  9 , total integrated cost =  333742.37867462786
# RUN  10 , total integrated cost =  333695.4487111175
# RUN  11 , total integrated cost =  333677.27321099996
# RUN  12 , total integrated cost =  333659.52611349506
# RUN  13 , total integrated cost =  333652.73095667583
# RUN  14 , total integrated cost =  333645.1393084565
# RUN  15 , total integrated cost =  333643.5945629771
# RUN  16 , total integrated cost =  333641.44283411955
# RUN  17 , total integrated cost =  333640.970653861
# RUN  18 , total integrated cost =  333639.9873495265
# RUN  19 , total integrated cost =  333639.4135565829
# RUN  20 , total integrated cost =  333632.1912461505
# Control only changes marginally.
# RUN  24 , total integrated cost =  333477.88213482924
# Improved over  24  iterations in  13.853185556828976  seconds by  1.375004751305383  percent.
# cost splitting :  32.78430846231445 [3.06546926 0.        ]
# set cost params:  1.0 110290.84101444729 0.0
# interpolate adjoint :  True True True
# initial cost =  338908.8763269123
# RUN  0 , total integrated cost =  338908.8763269123
# Gradient descend method:  None
# RUN  1 , total integrated cost =  338908.7107240419
# RUN  2 , total integrated cost =  338908.7076271358
# RUN  3 , total integrated cost =  338908.7076095815
# RUN  4 , total integrated cost =  338908.7076095815
# Control only changes marginally.
# RUN  4 , total integrated cost =  338908.7076095815
# Improved over  4  iterations in  3.2080229222774506  seconds by  4.978250572662546e-05  percent.
# cost splitting :  33.37681201239372 [3.06533407 0.        ]
# set cost params:  1.0 110295.51638581656 0.0
# interpolate adjoint :  True True True
# initial cost =  338923.03918472957
# RUN  0 , total integrated cost =  338923.03918472957
# Gradient descend method:  None
# RUN  1 , total integrated cost =  338923.03918472957
# Control only changes marginally.
# RUN  1 , total integrated cost =  338923.03918472957
# Improved over  1  iterations in  3.5448360294103622  seconds by  0.0  percent.
# cost splitting :  33.37681201239372 [3.06533407 0.        ]
# -------  5 0.4000000000000001 0.40000000000000013
# set cost params:  1.0 100.0 0.0
# interpolate adjoint :  True True True
# initial cost =  16.73842857162701
# RUN  0 , total integrated cost =  16.73842857162701
# Gradient descend method:  None
# RUN  1 , total integrated cost =  16.736833888000437
# RUN  2 , total integrated cost =  16.736833887031136
# RUN  3 , total integrated cost =  16.73683388700936
# RUN  4 , total integrated cost =  16.736833887006252
# RUN  5 , total integrated cost =  16.736833869782448
# RUN  6 , total integrated cost =  16.73683385181786
# RUN  7 , total integrated cost =  16.73683385176274
# RUN  8 , total integrated cost =  16.736833851685844
# RUN  9 , total integrated cost =  16.73683385122883
# RUN  10 , total integrated cost =  16.736833851154454
# RUN  11 , total integrated cost =  16.736833851152017
# RUN  12 , total integrated cost =  16.736833851147203
# RUN  13 , total integrated cost =  16.73683385069222
# RUN  14 , total integrated cost =  16.736833850258318
# RUN  15 , total integrated cost =  16.736833850255564
# RUN  16 , total integrated cost =  16.736833848876454
# RUN  17 , total integrated cost =  16.736833846872496
# RUN  18 , total integrated cost =  16.73683384686987
# RUN  19 , total integrated cost =  16.736833846229633
# RUN  20 , total integrated cost =  16.736833845578257
# RUN  30 , total integrated cost =  16.73683384134408
# RUN  40 , total integrated cost =  16.736833838743703
# RUN  50 , total integrated cost =  16.736833825444858
# RUN  60 , total integrated cost =  16.736833816517112
# RUN  70 , total integrated cost =  16.736833813907957
# RUN  80 , total integrated cost =  16.736833810171774
# RUN  90 , total integrated cost =  16.736833805717275
# RUN  100 , total integrated cost =  16.73683380157232
# RUN  100 , total integrated cost =  16.73683380157232
# Improved over  100  iterations in  44.03224804997444  seconds by  0.009527597216589356  percent.
# cost splitting :  2.3063129778406083e-07 [0.16736828 0.        ]
# set cost params:  1.0 200.0 0.0
# interpolate adjoint :  True True True
# initial cost =  33.47366186490026
# RUN  0 , total integrated cost =  33.47366186490026
# Gradient descend method:  None
# RUN  1 , total integrated cost =  33.47366054322134
# RUN  2 , total integrated cost =  33.47366054244725
# RUN  3 , total integrated cost =  33.47366054242833
# RUN  4 , total integrated cost =  33.47366054238569
# RUN  5 , total integrated cost =  33.47366054207783
# RUN  6 , total integrated cost =  33.47366054187306
# RUN  7 , total integrated cost =  33.47366054184661
# RUN  8 , total integrated cost =  33.473660541814354
# RUN  9 , total integrated cost =  33.473660541484904
# RUN  10 , total integrated cost =  33.473660541276665
# RUN  11 , total integrated cost =  33.47366054120401
# RUN  12 , total integrated cost =  33.473660540510004
# RUN  13 , total integrated cost =  33.473660540346934
# RUN  14 , total integrated cost =  33.473660540279866
# RUN  15 , total integrated cost =  33.47366053992461
# RUN  16 , total integrated cost =  33.47366053878409
# RUN  17 , total integrated cost =  33.47366053870644
# RUN  18 , total integrated cost =  33.47366053857692
# RUN  19 , total integrated cost =  33.473660538267026
# RUN  20 , total integrated cost =  33.473660538057594
# RUN  30 , total integrated cost =  33.47365778816433
# RUN  40 , total integrated cost =  33.473657752025616
# RUN  50 , total integrated cost =  33.47365774837532
# RUN  60 , total integrated cost =  33.473657620149105
# RUN  70 , total integrated cost =  33.47365761769327
# RUN  80 , total integrated cost =  33.47365761427289
# RUN  90 , total integrated cost =  33.47365742978344
# RUN  100 , total integrated cost =  33.473657425806316
# RUN  110 , total integrated cost =  33.473657422811876
# RUN  120 , total integrated cost =  33.473657421038894
# RUN  130 , total integrated cost =  33.47365741932271
# RUN  140 , total integrated cost =  33.473657409236495
# RUN  150 , total integrated cost =  33.473657404679614
# RUN  160 , total integrated cost =  33.47365740282886
# RUN  170 , total integrated cost =  33.473657401241496
# RUN  180 , total integrated cost =  33.47365739923361
# RUN  190 , total integrated cost =  33.47365739710413
# RUN  200 , total integrated cost =  33.473657393920625
# RUN  200 , total integrated cost =  33.473657393920625
# Improved over  200  iterations in  122.49335872381926  seconds by  1.3356709075651452e-05  percent.
# cost splitting :  3.6030828018504783e-07 [0.16736824 0.        ]
# set cost params:  1.0 300.0 0.0
# interpolate adjoint :  True True True
# initial cost =  50.21048160853855
# RUN  0 , total integrated cost =  50.21048160853855
# Gradient descend method:  None
# RUN  1 , total integrated cost =  50.210481000550566
# RUN  2 , total integrated cost =  50.21048099929577
# RUN  3 , total integrated cost =  50.210480999264746
# RUN  4 , total integrated cost =  50.210480999236914
# RUN  5 , total integrated cost =  50.210480998468945
# RUN  6 , total integrated cost =  50.21048099815871
# RUN  7 , total integrated cost =  50.21048099806898
# RUN  8 , total integrated cost =  50.210480996470785
# RUN  9 , total integrated cost =  50.210480995895104
# RUN  10 , total integrated cost =  50.21048099584787
# RUN  11 , total integrated cost =  50.21048099582323
# RUN  12 , total integrated cost =  50.21048099537657
# RUN  13 , total integrated cost =  50.21048099505629
# RUN  14 , total integrated cost =  50.21048099501533
# RUN  15 , total integrated cost =  50.210480994994754
# RUN  16 , total integrated cost =  50.21048099441117
# RUN  17 , total integrated cost =  50.2104809940966
# RUN  18 , total integrated cost =  50.21048099404391
# RUN  19 , total integrated cost =  50.21048099401254
# RUN  20 , total integrated cost =  50.21048099362277
# RUN  30 , total integrated cost =  50.21048099139964
# RUN  40 , total integrated cost =  50.21048098902847
# RUN  50 , total integrated cost =  50.21048098591162
# RUN  60 , total integrated cost =  50.21048093585974
# RUN  70 , total integrated cost =  50.2104809321643
# RUN  80 , total integrated cost =  50.21048093006061
# RUN  90 , total integrated cost =  50.21048092756031
# RUN  100 , total integrated cost =  50.21048092446263
# RUN  110 , total integrated cost =  50.21048092063892
# RUN  120 , total integrated cost =  50.210480917596
# RUN  130 , total integrated cost =  50.21048091423927
# RUN  140 , total integrated cost =  50.21048091113229
# RUN  150 , total integrated cost =  50.21048090748771
# RUN  160 , total integrated cost =  50.21048090440565
# RUN  170 , total integrated cost =  50.21048090075253
# RUN  180 , total integrated cost =  50.21048089768091
# RUN  190 , total integrated cost =  50.21048089403763
# RUN  200 , total integrated cost =  50.210480890954365
# Control only changes marginally.
# RUN  296 , total integrated cost =  50.20939090002033
# Improved over  296  iterations in  209.71512725949287  seconds by  0.002172272567960931  percent.
# cost splitting :  4.7211625050141356e-07 [0.1673646 0.       ]
# set cost params:  1.0 400.0 0.0
# interpolate adjoint :  True True True
# initial cost =  66.94585061784912
# RUN  0 , total integrated cost =  66.94585061784912
# Gradient descend method:  None
# RUN  1 , total integrated cost =  66.9458502460904
# RUN  2 , total integrated cost =  66.94585024577947
# RUN  3 , total integrated cost =  66.94585024577947
# Control only changes marginally.
# RUN  3 , total integrated cost =  66.94585024577947
# Improved over  3  iterations in  2.753695547580719  seconds by  5.557770066388912e-07  percent.
# cost splitting :  5.684712295471895e-07 [0.16736459 0.        ]
# set cost params:  1.0 757668.497447134 0.0
# interpolate adjoint :  True True True
# initial cost =  126806.87763827016
# RUN  0 , total integrated cost =  126806.87763827016
# Gradient descend method:  None
# RUN  1 , total integrated cost =  126806.83496566104
# RUN  2 , total integrated cost =  126806.83464987343
# RUN  3 , total integrated cost =  126806.83464955846
# RUN  4 , total integrated cost =  126806.83464955846
# Control only changes marginally.
# RUN  4 , total integrated cost =  126806.83464955846
# Improved over  4  iterations in  2.576968587934971  seconds by  3.3900930702657206e-05  percent.
# cost splitting :  6.330212170675955e-05 [0.16736453 0.        ]
# set cost params:  1.0 757668.763290251 0.0
# interpolate adjoint :  True True True
# initial cost =  126806.87914226706
# RUN  0 , total integrated cost =  126806.87914226706
# Gradient descend method:  None
# RUN  1 , total integrated cost =  126806.87914226706
# Control only changes marginally.
# RUN  1 , total integrated cost =  126806.87914226706
# Improved over  1  iterations in  1.7800892367959023  seconds by  0.0  percent.
# cost splitting :  6.330212170675955e-05 [0.16736453 0.        ]
# -------  6 0.4250000000000001 0.40000000000000013
# set cost params:  1.0 100.0 0.0
# interpolate adjoint :  True True True
# initial cost =  234971.12367450516
# RUN  0 , total integrated cost =  234971.12367450516
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1853.7305589422565
# RUN  2 , total integrated cost =  1428.4284717293717
# RUN  3 , total integrated cost =  895.0759313031763
# RUN  4 , total integrated cost =  723.7894057721728
# RUN  5 , total integrated cost =  526.0592669239616
# RUN  6 , total integrated cost =  458.6141874203104
# RUN  7 , total integrated cost =  379.0262652759946
# RUN  8 , total integrated cost =  344.73264911108384
# RUN  9 , total integrated cost =  250.29023354753994
# RUN  10 , total integrated cost =  237.22279930571526
# RUN  11 , total integrated cost =  202.79290350282758
# RUN  12 , total integrated cost =  200.57194074477198
# RUN  13 , total integrated cost =  198.81366521592975
# RUN  14 , total integrated cost =  197.00190235071165
# RUN  15 , total integrated cost =  195.94800050882242
# RUN  16 , total integrated cost =  194.83819060977248
# RUN  17 , total integrated cost =  193.9533347819014
# RUN  18 , total integrated cost =  192.96551688655225
# RUN  19 , total integrated cost =  192.19137090651728
# RUN  20 , total integrated cost =  191.32741706640806
# RUN  30 , total integrated cost =  184.97389174273238
# RUN  40 , total integrated cost =  179.72111916451678
# RUN  50 , total integrated cost =  173.66264728865545
# RUN  60 , total integrated cost =  155.84658892709248
# RUN  70 , total integrated cost =  152.1238209273391
# RUN  80 , total integrated cost =  143.90338851650478
# RUN  90 , total integrated cost =  142.64744100524726
# RUN  100 , total integrated cost =  137.02567389059922
# RUN  100 , total integrated cost =  137.02567389059922
# Improved over  100  iterations in  74.36348614096642  seconds by  99.94168403685194  percent.
# cost splitting :  0.06871712183255382 [1.35315951 0.        ]
# set cost params:  1.0 200.0 0.0
# interpolate adjoint :  True True True
# initial cost =  272.3416247648571
# RUN  0 , total integrated cost =  272.3416247648571
# Gradient descend method:  None
# RUN  1 , total integrated cost =  271.4852933264256
# RUN  2 , total integrated cost =  271.4461288568031
# RUN  3 , total integrated cost =  271.4033012721166
# RUN  4 , total integrated cost =  271.3718519473182
# RUN  5 , total integrated cost =  271.33429857198007
# RUN  6 , total integrated cost =  271.30949186740025
# RUN  7 , total integrated cost =  271.2792161433531
# RUN  8 , total integrated cost =  271.2546026902209
# RUN  9 , total integrated cost =  271.22456198041186
# RUN  10 , total integrated cost =  271.20195038937175
# RUN  11 , total integrated cost =  271.17017512659845
# RUN  12 , total integrated cost =  271.1456462143882
# RUN  13 , total integrated cost =  271.1112067488931
# RUN  14 , total integrated cost =  271.08263661358336
# RUN  15 , total integrated cost =  271.0271707900209
# RUN  16 , total integrated cost =  270.97990756751364
# RUN  17 , total integrated cost =  270.7065189202599
# RUN  18 , total integrated cost =  270.4707188201938
# RUN  19 , total integrated cost =  268.9508131024975
# RUN  20 , total integrated cost =  268.2583372562068
# RUN  30 , total integrated cost =  261.4024819919796
# RUN  40 , total integrated cost =  260.93453951247216
# RUN  50 , total integrated cost =  260.67826175727055
# RUN  60 , total integrated cost =  260.17540361142596
# RUN  70 , total integrated cost =  259.7893748072892
# RUN  80 , total integrated cost =  259.3268406136531
# RUN  90 , total integrated cost =  256.05666163549836
# RUN  100 , total integrated cost =  255.39481420640243
# RUN  110 , total integrated cost =  254.67285767737616
# RUN  120 , total integrated cost =  252.3507057596898
# RUN  130 , total integrated cost =  251.23188102921134
# RUN  140 , total integrated cost =  251.11782438507794
# RUN  150 , total integrated cost =  251.06528294116035
# RUN  160 , total integrated cost =  250.34113008052458
# RUN  170 , total integrated cost =  249.75535119995985
# RUN  180 , total integrated cost =  249.71791877233494
# RUN  190 , total integrated cost =  249.0543766626125
# RUN  200 , total integrated cost =  248.95858006344986
# RUN  200 , total integrated cost =  248.95858006344986
# Improved over  200  iterations in  187.08370923995972  seconds by  8.58592391875331  percent.
# cost splitting :  0.030577118675747927 [1.24098902 0.        ]
# set cost params:  1.0 300.0 0.0
# interpolate adjoint :  True True True
# initial cost =  373.0574816113504
# RUN  0 , total integrated cost =  373.0574816113504
# Gradient descend method:  None
# RUN  1 , total integrated cost =  372.9733592369953
# RUN  2 , total integrated cost =  372.9731693654597
# RUN  3 , total integrated cost =  372.97233864076065
# RUN  4 , total integrated cost =  372.9719079099441
# RUN  5 , total integrated cost =  372.96911678326694
# RUN  6 , total integrated cost =  372.9657718741675
# RUN  7 , total integrated cost =  372.9655878377602
# RUN  8 , total integrated cost =  372.9646101378682
# RUN  9 , total integrated cost =  372.9638082807336
# RUN  10 , total integrated cost =  372.9628090363658
# RUN  11 , total integrated cost =  372.96126875918316
# RUN  12 , total integrated cost =  372.9610829487383
# RUN  13 , total integrated cost =  372.9602182912504
# RUN  14 , total integrated cost =  372.9597551795893
# RUN  15 , total integrated cost =  372.9552069398336
# RUN  16 , total integrated cost =  372.9493551881991
# RUN  17 , total integrated cost =  372.9491616390098
# RUN  18 , total integrated cost =  372.94823879167114
# RUN  19 , total integrated cost =  372.9477650503448
# RUN  20 , total integrated cost =  372.93990740413335
# RUN  30 , total integrated cost =  372.90031507314916
# RUN  40 , total integrated cost =  371.6603792485098
# RUN  50 , total integrated cost =  371.6315990261087
# RUN  60 , total integrated cost =  371.610414462755
# RUN  70 , total integrated cost =  371.5182695685233
# RUN  80 , total integrated cost =  371.50311858446986
# RUN  90 , total integrated cost =  371.49527022964685
# RUN  100 , total integrated cost =  371.4846143329475
# RUN  110 , total integrated cost =  371.4742203493599
# RUN  120 , total integrated cost =  371.45257323356617
# RUN  130 , total integrated cost =  371.44504607470907
# RUN  140 , total integrated cost =  371.4308045417565
# RUN  150 , total integrated cost =  371.17184115370856
# RUN  160 , total integrated cost =  371.15670827320423
# RUN  170 , total integrated cost =  371.10880893641774
# RUN  180 , total integrated cost =  371.09991717061035
# RUN  190 , total integrated cost =  370.9988053209918
# RUN  200 , total integrated cost =  370.63406413258326
# RUN  300 , total integrated cost =  370.104023093902
# RUN  300 , total integrated cost =  370.104023093902
# Improved over  300  iterations in  177.0894563421607  seconds by  0.7916899306486158  percent.
# cost splitting :  0.0310552662308109 [1.2311045 0.       ]
# set cost params:  1.0 400.0 0.0
# interpolate adjoint :  True True True
# initial cost =  493.21447293711014
# RUN  0 , total integrated cost =  493.21447293711014
# Gradient descend method:  None
# RUN  1 , total integrated cost =  493.1803747521082
# RUN  2 , total integrated cost =  493.1802337033164
# RUN  3 , total integrated cost =  493.1798240941224
# RUN  4 , total integrated cost =  493.17971332995666
# RUN  5 , total integrated cost =  493.1791964874301
# RUN  6 , total integrated cost =  493.1782976366476
# RUN  7 , total integrated cost =  493.17819736205195
# RUN  8 , total integrated cost =  493.17464784584087
# RUN  9 , total integrated cost =  493.1699785182238
# RUN  10 , total integrated cost =  493.1698779092319
# RUN  11 , total integrated cost =  493.1691383993543
# RUN  12 , total integrated cost =  493.1688085792846
# RUN  13 , total integrated cost =  493.16866301161855
# RUN  14 , total integrated cost =  493.1682545610279
# RUN  15 , total integrated cost =  493.16812997230574
# RUN  16 , total integrated cost =  493.16750052839603
# RUN  17 , total integrated cost =  493.1665884617566
# RUN  18 , total integrated cost =  493.1664890521359
# RUN  19 , total integrated cost =  493.13617988232016
# RUN  20 , total integrated cost =  493.10895462083124
# RUN  30 , total integrated cost =  492.4247739164195
# RUN  40 , total integrated cost =  492.3326101030578
# ...
# RUN  4 , total integrated cost =  211700.7399901941
# RUN  5 , total integrated cost =  211700.7399901941
# Control only changes marginally.
# RUN  5 , total integrated cost =  211700.7399901941
# Improved over  5  iterations in  3.344566136598587  seconds by  2.8286171314562125e-05  percent.
# cost splitting :  8.99165058287987 [0.8581419 0.       ]
# set cost params:  1.0 246436.83176775737 0.0
# interpolate adjoint :  True True True
# initial cost =  211701.48776243257
# RUN  0 , total integrated cost =  211701.48776243257
# Gradient descend method:  None
# RUN  1 , total integrated cost =  211701.48776243257
# Control only changes marginally.
# RUN  1 , total integrated cost =  211701.48776243257
# Improved over  1  iterations in  1.9537855237722397  seconds by  0.0  percent.
# cost splitting :  8.99165058287987 [0.8581419 0.       ]
# -------  20 0.4500000000000001 0.4750000000000002
# set cost params:  1.0 100.0 0.0
# interpolate adjoint :  True True True
# initial cost =  317162.6316928645
# RUN  0 , total integrated cost =  317162.6316928645
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3051.1424940190677
# RUN  2 , total integrated cost =  2378.5543034614834
# RUN  3 , total integrated cost =  1497.3353739918482
# RUN  4 , total integrated cost =  1269.2240880032411
# RUN  5 , total integrated cost =  1001.5072040284015
# RUN  6 , total integrated cost =  898.4682482445687
# RUN  7 , total integrated cost =  777.4963382689123
# RUN  8 , total integrated cost =  722.5040517833354
# RUN  9 , total integrated cost =  654.7153929121081
# RUN  10 , total integrated cost =  616.360727088166
# RUN  11 , total integrated cost =  567.3823956512272
# RUN  12 , total integrated cost =  538.250190049737
# RUN  13 , total integrated cost =  508.1321917777068
# RUN  14 , total integrated cost =  490.1753168920898
# RUN  15 , total integrated cost =  469.60919115264795
# RUN  16 , total integrated cost =  455.6173730715289
# RUN  17 , total integrated cost =  434.232253697385
# RUN  18 , total integrated cost =  417.02576899636136
# RUN  19 , total integrated cost =  385.1011114739674
# RUN  20 , total integrated cost =  374.5685549699259
# RUN  30 , total integrated cost =  347.9725474222839
# RUN  40 , total integrated cost =  337.9828725513716
# RUN  50 , total integrated cost =  304.1157375922248
# RUN  60 , total integrated cost =  299.01090029277367
# RUN  70 , total integrated cost =  296.4104642524963
# RUN  80 , total integrated cost =  278.96343034817164
# RUN  90 , total integrated cost =  277.669818756312
# RUN  100 , total integrated cost =  268.58708859167234
# RUN  100 , total integrated cost =  268.58708859167234
# Improved over  100  iterations in  46.70833296328783  seconds by  99.91531565772485  percent.
# cost splitting :  0.19845038023572076 [2.63649525 0.        ]
# set cost params:  1.0 200.0 0.0
# interpolate adjoint :  True True True
# initial cost =  532.2366132452411
# RUN  0 , total integrated cost =  532.2366132452411
# Gradient descend method:  None
# RUN  1 , total integrated cost =  529.4242053496456
# RUN  2 , total integrated cost =  529.3159075677017
# RUN  3 , total integrated cost =  529.1854128048099
# RUN  4 , total integrated cost =  529.0878305070324
# RUN  5 , total integrated cost =  528.9741078920214
# RUN  6 , total integrated cost =  528.8884668000563
# RUN  7 , total integrated cost =  528.7873354147983
# RUN  8 , total integrated cost =  528.7084150852426
# RUN  9 , total integrated cost =  528.6050492223499
# RUN  10 , total integrated cost =  528.5233060117401
# RUN  11 , total integrated cost =  528.41005552168
# RUN  12 , total integrated cost =  528.3186567467176
# RUN  13 , total integrated cost =  528.1877577070254
# RUN  14 , total integrated cost =  528.0810747418766
# RUN  15 , total integrated cost =  527.929771903039
# RUN  16 , total integrated cost =  527.7986382817287
# RUN  17 , total integrated cost =  527.5623301866102
# RUN  18 , total integrated cost =  527.3541174015126
# RUN  19 , total integrated cost =  516.9193812007446
# RUN  20 , total integrated cost =  516.8222501025726
# RUN  30 , total integrated cost =  514.5721104000099
# RUN  40 , total integrated cost =  512.2742442857306
# RUN  50 , total integrated cost =  502.82184727151616
# RUN  60 , total integrated cost =  501.74089048254876
# RUN  70 , total integrated cost =  500.63050296324855
# RUN  80 , total integrated cost =  497.0812686717961
# RUN  90 , total integrated cost =  496.3380714133364
# RUN  100 , total integrated cost =  495.91163427230435
# RUN  110 , total integrated cost =  494.8468511522838
# RUN  120 , total integrated cost =  492.91366792932007
# RUN  130 , total integrated cost =  492.16578833988694
# RUN  140 , total integrated cost =  486.6859338444492
# RUN  150 , total integrated cost =  485.9996613005946
# RUN  160 , total integrated cost =  485.59050515189426
# RUN  170 , total integrated cost =  484.2488785704687
# RUN  180 , total integrated cost =  483.9318005245489
# RUN  190 , total integrated cost =  480.98068184220085
# RUN  200 , total integrated cost =  480.1002420315079
# RUN  200 , total integrated cost =  480.1002420315079
# Improved over  200  iterations in  146.95788264274597  seconds by  9.795713018658887  percent.
# cost splitting :  0.11483834182999364 [2.38621498 0.        ]
# set cost params:  1.0 300.0 0.0
# interpolate adjoint :  True True True
# initial cost =  718.7217397947944
# RUN  0 , total integrated cost =  718.7217397947944
# Gradient descend method:  None
# RUN  1 , total integrated cost =  718.459072037744
# RUN  2 , total integrated cost =  718.4570998963851
# RUN  3 , total integrated cost =  718.4439448536107
# RUN  4 , total integrated cost =  718.4323090785426
# RUN  5 , total integrated cost =  717.352123355888
# RUN  6 , total integrated cost =  717.0661726181278
# RUN  7 , total integrated cost =  717.0634448024921
# RUN  8 , total integrated cost =  717.0585334690758
# RUN  9 , total integrated cost =  717.057052393104
# RUN  10 , total integrated cost =  717.0529477999036
# RUN  11 , total integrated cost =  717.0498049908978
# RUN  12 , total integrated cost =  715.1336920681026
# RUN  13 , total integrated cost =  715.0747047491255
# RUN  14 , total integrated cost =  715.0677252176964
# RUN  15 , total integrated cost =  715.0589013312928
# RUN  16 , total integrated cost =  715.0549524624121
# RUN  17 , total integrated cost =  715.0471166026025
# RUN  18 , total integrated cost =  715.0427930053817
# RUN  19 , total integrated cost =  715.031685401871
# RUN  20 , total integrated cost =  715.023399808515
# RUN  30 , total integrated cost =  714.383388581865
# RUN  40 , total integrated cost =  713.9877136632572
# RUN  50 , total integrated cost =  711.7163100682905
# RUN  60 , total integrated cost =  711.554936434676
# RUN  70 , total integrated cost =  711.5068746486793
# RUN  80 , total integrated cost =  711.4735912821168
# RUN  90 , total integrated cost =  711.4419119075425
# RUN  100 , total integrated cost =  711.4214207482673
# RUN  110 , total integrated cost =  711.3996013042643
# RUN  120 , total integrated cost =  711.3561051617032
# RUN  130 , total integrated cost =  711.2824359725239
# RUN  140 , total integrated cost =  710.9128252979765
# RUN  150 , total integrated cost =  709.7910029730547
# RUN  160 , total integrated cost =  709.7473021313522
# RUN  170 , total integrated cost =  709.6968394927565
# RUN  180 , total integrated cost =  709.4821787345485
# RUN  190 , total integrated cost =  707.7927168358608
# RUN  200 , total integrated cost =  707.7008405142261
# RUN  300 , total integrated cost =  704.943046461106
# RUN  300 , total integrated cost =  704.943046461106
# Improved over  300  iterations in  81.97487919777632  seconds by  1.917110972268972  percent.
# cost splitting :  0.08319413967531471 [2.34291042 0.        ]
# set cost params:  1.0 400.0 0.0
# interpolate adjoint :  True True True
# initial cost =  939.234088660386
# RUN  0 , total integrated cost =  939.234088660386
# Gradient descend method:  None
# RUN  1 , total integrated cost =  939.1563345452198
# RUN  2 , total integrated cost =  939.1548460926248
# RUN  3 , total integrated cost =  939.1538478676399
# RUN  4 , total integrated cost =  939.1536932499221
# RUN  5 , total integrated cost =  939.1528188808935
# RUN  6 , total integrated cost =  939.1523447335237
# RUN  7 , total integrated cost =  939.1521842336123
# RUN  8 , total integrated cost =  939.1513261126673
# RUN  9 , total integrated cost =  939.1508689474683
# RUN  10 , total integrated cost =  939.1505394242297
# RUN  11 , total integrated cost =  939.1494311077773
# RUN  12 , total integrated cost =  939.1491161686795
# RUN  13 , total integrated cost =  939.14893076867
# RUN  14 , total integrated cost =  939.1480241711657
# RUN  15 , total integrated cost =  939.1476629584513
# RUN  16 , total integrated cost =  939.1473458651446
# RUN  17 , total integrated cost =  939.1463140847476
# RUN  18 , total integrated cost =  939.1460315052576
# RUN  19 , total integrated cost =  939.1457581310187
# RUN  20 , total integrated cost =  939.1447691867693
# RUN  30 , total integrated cost =  939.140388668178
# RUN  40 , total integrated cost =  939.1363065234981
# RUN  50 , total integrated cost =  939.1312331710928
# RUN  60 , total integrated cost =  939.1264140478071
# RUN  70 , total integrated cost =  939.122061548963
# RUN  80 , total integrated cost =  939.115884413429
# RUN  90 , total integrated cost =  939.1093245813453
# RUN  100 , total integrated cost =  939.1036667759578
# RUN  110 , total integrated cost =  939.0963079141126
# RUN  120 , total integrated cost =  939.0838548819983
# RUN  130 , total integrated cost =  939.052141019364
# RUN  140 , total integrated cost =  939.0432496489293
# RUN  150 , total integrated cost =  938.728798249216
# RUN  160 , total integrated cost =  937.5410551010573
# RUN  170 , total integrated cost =  937.5330359859872
# RUN  180 , total integrated cost =  937.5173619522135
# RUN  190 , total integrated cost =  937.0795336668374
# RUN  200 , total integrated cost =  937.0333629924103
# RUN  300 , total integrated cost =  935.9456329531811
# RUN  400 , total integrated cost =  934.7128095845296
# RUN  400 , total integrated cost =  934.7128095845296
# Improved over  400  iterations in  252.66098414361477  seconds by  0.48137936329641207  percent.
# cost splitting :  0.07784849076150213 [2.33193973 0.        ]
# set cost params:  1.0 135809.11462212185 0.0
# interpolate adjoint :  True True True
# initial cost =  316700.6072236725
# RUN  0 , total integrated cost =  316700.6072236725
# Gradient descend method:  None
# RUN  1 , total integrated cost =  314179.454373404
# RUN  2 , total integrated cost =  314166.1359695657
# RUN  3 , total integrated cost =  314166.09359414363
# RUN  4 , total integrated cost =  314161.7972466294
# RUN  5 , total integrated cost =  314158.68439902255
# RUN  6 , total integrated cost =  314126.11970060074
# RUN  7 , total integrated cost =  314124.7271211344
# RUN  8 , total integrated cost =  314124.7211004812
# RUN  9 , total integrated cost =  314124.7211004812
# Control only changes marginally.
# RUN  9 , total integrated cost =  314124.7211004812
# Improved over  9  iterations in  9.878313682973385  seconds by  0.8133505476268397  percent.
# cost splitting :  17.854249085301394 [2.30971609 0.        ]
# set cost params:  1.0 137109.10970132332 0.0
# interpolate adjoint :  True True True
# initial cost =  317127.34064716793
# RUN  0 , total integrated cost =  317127.34064716793
# Gradient descend method:  None
# RUN  1 , total integrated cost =  317127.27866423
# RUN  2 , total integrated cost =  317127.26417205384
# RUN  3 , total integrated cost =  317127.2641609879
# RUN  4 , total integrated cost =  317127.26416056714
# RUN  5 , total integrated cost =  317127.2641605547
# RUN  6 , total integrated cost =  317127.2641605545
# RUN  7 , total integrated cost =  317127.26416055375
# RUN  8 , total integrated cost =  317127.26416055375
# Control only changes marginally.
# RUN  8 , total integrated cost =  317127.26416055375
# Improved over  8  iterations in  8.23765990883112  seconds by  2.411858088180452e-05  percent.
# cost splitting :  17.97907272716303 [2.30969288 0.        ]
# set cost params:  1.0 137110.43441017915 0.0
# interpolate adjoint :  True True True
# initial cost =  317130.32383116416
# RUN  0 , total integrated cost =  317130.32383116416
# Gradient descend method:  None
# RUN  1 , total integrated cost =  317130.3238311636
# RUN  2 , total integrated cost =  317130.3238311636
# Control only changes marginally.
# RUN  2 , total integrated cost =  317130.3238311636
# Improved over  2  iterations in  4.0221453085541725  seconds by  1.8474111129762605e-13  percent.
# cost splitting :  17.97907253917298 [2.30969288 0.        ]
# set cost params:  1.0 137110.43440823408 0.0
# interpolate adjoint :  True True True
# initial cost =  317130.3238266711
# RUN  0 , total integrated cost =  317130.3238266711
# Gradient descend method:  None
# RUN  1 , total integrated cost =  317130.3238266708
# RUN  2 , total integrated cost =  317130.3238266708
# Control only changes marginally.
# RUN  2 , total integrated cost =  317130.3238266708
# Improved over  2  iterations in  3.211394302546978  seconds by  8.526512829121202e-14  percent.
# cost splitting :  17.97907244517676 [2.30969288 0.        ]
# set cost params:  1.0 137110.43440726135 0.0
# interpolate adjoint :  True True True
# initial cost =  317130.32382442465
# RUN  0 , total integrated cost =  317130.32382442465
# Gradient descend method:  None
# RUN  1 , total integrated cost =  317130.32382442453
# RUN  2 , total integrated cost =  317130.32382442453
# Control only changes marginally.
# RUN  2 , total integrated cost =  317130.32382442453
# Improved over  2  iterations in  4.115216322243214  seconds by  2.842170943040401e-14  percent.
# cost splitting :  17.9790723511901 [2.30969288 0.        ]
# set cost params:  1.0 137110.43440628875 0.0
# interpolate adjoint :  True True True
# initial cost =  317130.323822178
# RUN  0 , total integrated cost =  317130.323822178
# Gradient descend method:  None
# RUN  1 , total integrated cost =  317130.323822178
# Control only changes marginally.
# RUN  1 , total integrated cost =  317130.323822178
# Improved over  1  iterations in  2.071596711874008  seconds by  0.0  percent.
# cost splitting :  17.9790723511901 [2.30969288 0.        ]
# -------  21 0.47500000000000014 0.4750000000000002
# set cost params:  1.0 100.0 0.0
# interpolate adjoint :  True True True
# initial cost =  425105.60809716827
# RUN  0 , total integrated cost =  425105.60809716827
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4728.825457883782
# RUN  2 , total integrated cost =  3515.539690733409
# RUN  3 , total integrated cost =  2099.788235347949
# RUN  4 , total integrated cost =  1737.3671554860207
# RUN  5 , total integrated cost =  1298.6521002483637
# RUN  6 , total integrated cost =  1164.9281061193446
# RUN  7 , total integrated cost =  1007.4923953762155
# RUN  8 , total integrated cost =  930.6295890888618
# RUN  9 , total integrated cost =  860.9917554373046
# RUN  10 , total integrated cost =  821.9167876501571
# RUN  11 , total integrated cost =  720.3560691284544
# RUN  12 , total integrated cost =  709.132900684236
# RUN  13 , total integrated cost =  696.9683575526788
# RUN  14 , total integrated cost =  689.1577887453907
# RUN  15 , total integrated cost =  670.8853217308848
# RUN  16 , total integrated cost =  657.8192271700733
# RUN  17 , total integrated cost =  648.8074577825013
# RUN  18 , total integrated cost =  640.5204280046026
# RUN  19 , total integrated cost =  617.1140364469672
# RUN  20 , total integrated cost =  604.1106782031119
# RUN  30 , total integrated cost =  523.086918526798
# RUN  40 , total integrated cost =  520.6419631281464
# RUN  50 , total integrated cost =  501.82411429688693
# RUN  60 , total integrated cost =  499.5984770311036
# RUN  70 , total integrated cost =  488.43562319794785
# RUN  80 , total integrated cost =  475.4184414156723
# RUN  90 , total integrated cost =  472.27696162659714
# RUN  100 , total integrated cost =  466.1032561690966
# RUN  100 , total integrated cost =  466.1032561690966
# Improved over  100  iterations in  61.37606351822615  seconds by  99.89035589103248  percent.
# cost splitting :  0.3285679352369264 [4.5792829 0.       ]

# %%
for i in i_range:
    print("------- ", i, exc[i], inh[i])
    
    if i in bad:
        continue
        
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    dur = d_array[0]
    aln.params.duration = dur
    max_it = int(0)
    
    for l in range( bestControl_[i].shape[2] ):
        if np.abs(bestControl_[i][0,0,l]) > 5. * 1e-6 or np.abs(bestControl_[i][0,1,l]) > 5. * 1e-6:
            init_ind = l
            break
        if l == bestControl_[i].shape[2] - 1:
            bad.append(i)
            break
            
    if i in bad:
        continue
            
    print("init ind = ", init_ind)

    weight_ = 1.
    cost.setParams(1., weight_ * factor_we, weight_ * factor_ws)
    weights_[i] = cost.getParams()

    setinit(initVars[i], aln)

    target_ = aln.getZeroTarget()
    target_[:,0,:] = target[i][0]
    target_[:,1,:] = target[i][1]

    control0 = aln.getZeroControl()
    if init_ind != 0:
        control0[:,:,:-init_ind] = bestControl_[i][:,:,n_pre-1+init_ind:-n_post+1]
    else:
        control0 = bestControl_[i][:,:,n_pre-1:-n_post+1]

    bestControl_[i], bestState_[i], cost_[i], runtime_, grad_, phi_, phi1_, costnode_[i] = aln.A1(
        control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
        prec_variables_ = p_var, transition_time_ = t_pen[j])

    print('uncontrolled cost : ', cost_uncontrolled[i])
    print('cost splitting : ', costnode_[i][0][0][0], costnode_[i][index_cost][0][:2])

    time_ = np.arange(-dur_pre,round(dur+dur_post+aln.params.dt,1),aln.params.dt)
    target_ = aln.getZeroTarget()
    target_[:,0,:] = target[i][0]
    target_[:,1,:] = target[i][1]

    if True:
        fig, ax = plt.subplots(2,1, constrained_layout=True, figsize = (4,4) )
        ax[1].plot(time_, bestControl_[i][0,0,:], color = 'red')
        ax[0].plot(time_, bestState_[i][0,0,:], color= 'red')
        ax[1].plot(time_, bestControl_[i][0,1,:], color = 'blue')
        ax[0].plot(time_, bestState_[i][0,1,:], color= 'blue')
        ax[0].plot(time_, target_[0,0,:], linestyle = '--', color='red')
        ax[0].plot(time_, target_[0,1,:], linestyle = '--', color='blue')
        ax[0].set_xlim(-dur_pre,dur+dur_post)
        ax[1].set_xlim(-dur_pre,dur+dur_post)
        ax[0].axvspan(dur*t_pen[j], dur, alpha=0.2, color='gray')
        plt.show()

    with open(file_,'wb') as f:
        pickle.dump([bestControl_, bestState_, cost_, costnode_, weights_], f)

# %%
for i in i_range:
    print("------- ", i, exc[i], inh[i])
    
    if i in bad:
        continue
        
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    aln.params.duration = dur
    max_it = int(1000)
    
    while not conv_shift[i]:
        
        if True:
            time_ = np.arange(-dur_pre,round(dur+dur_post+aln.params.dt,1),aln.params.dt)
        
            fig, ax = plt.subplots(2,1, constrained_layout=True, figsize = (4,4) )
            ax[1].plot(time_, bestControl_[i][0,0,:], color = 'red')
            ax[0].plot(time_, bestState_[i][0,0,:], color= 'red')
            ax[1].plot(time_, bestControl_[i][0,1,:], color = 'blue')
            ax[0].plot(time_, bestState_[i][0,1,:], color= 'blue')
            ax[0].set_xlim(-dur_pre,dur+dur_post)
            ax[1].set_xlim(-dur_pre,dur+dur_post)
            ax[0].axvspan(dur*t_pen[0], dur, alpha=0.2, color='gray')
            plt.show()
            
        weight_ = 1.
        cost.setParams(1., weight_ * factor_we, weight_ * factor_ws)
        weights_[i] = cost.getParams()

        setinit(initVars[i], aln)

        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        control0 = aln.getZeroControl()
        control0 = bestControl_[i][:,:,n_pre-1:-n_post+1]

        bestControl_[i], bestState_[i], cost_[i], runtime_, grad_, phi_, phi1_, costnode_[i]= aln.A1(
            control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
            prec_variables_ = p_var, transition_time_ = t_pen[0])
        
        if cost_[i][-1] == 0.:
            conv_shift[i] = True

        print('uncontrolled cost : ', cost_uncontrolled[i])
        print('cost splitting : ', costnode_[i][0][0][0], costnode_[i][index_cost][0][:2])

        if True:
            time_ = np.arange(-dur_pre,round(dur+dur_post+aln.params.dt,1),aln.params.dt)
            target_ = aln.getZeroTarget()
            target_[:,0,:] = target[i][0]
            target_[:,1,:] = target[i][1]
        
            fig, ax = plt.subplots(2,1, constrained_layout=True, figsize = (4,4) )
            ax[1].plot(time_, bestControl_[i][0,0,:], color = 'red')
            ax[0].plot(time_, bestState_[i][0,0,:], color= 'red')
            ax[1].plot(time_, bestControl_[i][0,1,:], color = 'blue')
            ax[0].plot(time_, bestState_[i][0,1,:], color= 'blue')
            ax[0].plot(time_, target_[0,0,:], linestyle = '--', color='red')
            ax[0].plot(time_, target_[0,1,:], linestyle = '--', color='blue')
            ax[0].set_xlim(-dur_pre,dur+dur_post)
            ax[1].set_xlim(-dur_pre,dur+dur_post)
            ax[0].axvspan(dur*t_pen[0], dur, alpha=0.2, color='gray')
            plt.show()

        with open(file_,'wb') as f:
            pickle.dump([bestControl_, bestState_, cost_, costnode_, weights_], f)
