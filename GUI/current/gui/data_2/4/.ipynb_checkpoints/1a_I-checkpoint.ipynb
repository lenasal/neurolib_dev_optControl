# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import sys
import pickle

path = os.getcwd().split(os.sep + 'GUI')[0]
if path not in sys.path:
    print("not here")
    sys.path.append(path)

from neurolib.models.aln import ALNModel
from neurolib.utils import plotFunctions as plotFunc
from neurolib.utils import costFunctions as cost
import neurolib.dashboard.functions as functions
import neurolib.dashboard.data as data
    
# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2 

#path = os.path.join(os.getcwd(), "plots")
# Out:
# not here

# %%
grid_data_file = os.path.join(os.getcwd().split('data')[0], 'bi.pickle')
print(grid_data_file)
with open(grid_data_file,'rb') as f:
    load_array= pickle.load(f)
exc = load_array[0]
inh = load_array[1]
print(len(exc))
case = '1'
# Out:
# /home/lena/Promotion/neurolib/GUI/current/gui/bi.pickle
# 147

# %% [markdown]
# ### Bistability

# %%
aln = ALNModel()
N = aln.params.N

data.set_parameters(aln)

state_vars = aln.state_vars
init_vars = aln.init_vars

##############################################################
def setinit(init_vars_, model):
    state_vars = model.state_vars
    init_vars = model.init_vars
    for iv in range(len(init_vars)):
        for sv in range(len(state_vars)):
            if state_vars[sv] in init_vars[iv]:
                #print("set init vars ", )
                if model.params[init_vars[iv]].ndim == 2:
                    model.params[init_vars[iv]][0,:] = init_vars_[sv]
                else:
                    model.params[init_vars[iv]][0] = init_vars_[sv]
                    
##############################################################               
def setmaxmincontrol(max_c_c, min_c_c, max_c_r, min_c_r):
    import numpy as np
    
    max_cntrl = np.zeros(( 6 ))
    min_cntrl = np.zeros(( 6 ))
    
    max_cntrl[0] = max_c_c
    min_cntrl[0] = min_c_c
    max_cntrl[1] = max_c_c
    min_cntrl[1] = min_c_c
    max_cntrl[2] = max_c_r
    min_cntrl[2] = min_c_r
    max_cntrl[3] = max_c_r
    min_cntrl[3] = min_c_r
    max_cntrl[4] = max_c_r
    min_cntrl[4] = min_c_r
    max_cntrl[5] = max_c_r
    min_cntrl[5] = min_c_r
            
    return max_cntrl, min_cntrl

# %%
d_array = np.arange(20., 300, 0.1)
t0_array = d_array - 20.
t_pen = np.zeros(( t0_array.shape ))
for i in range(len(t_pen)):
    t_pen[i] = t0_array[i] / d_array[i]

bestControl_ = np.array( [[None] * len(t_pen)] * len(exc) )
bestState_ = np.array( [[None] * len(t_pen)] * len(exc) )
cost_ = np.array( [[None] * len(t_pen)] * len(exc) )
costnode_ = np.array( [[None] * len(t_pen)] * len(exc) )
weights_ = np.array( [[None] * len(t_pen)] * len(exc) )
convergence_ = np.array( [[None] * len(t_pen)] * len(exc) )

initVars = [None] * len(exc)
target = [None] * len(exc)
cost_uncontrolled = [None] * len(exc)

print(bestControl_.shape)
# Out:
# (147, 2800)

# %%
dur_pre = 10
dur_post = 10

n_pre = int(np.around(dur_pre/aln.params.dt + 1.,1))
n_post = int(np.around(dur_post/aln.params.dt + 1.,1))

tol = 1e-32
start_step = 10.
c_scheme = np.zeros(( 1,1 ))
c_scheme[0,0] = 1.
u_mat = np.identity(1)
u_scheme = np.array([[1.]])

c_var = [1]
p_var = [0]

if case in ['1', '2']:    # low to high
    max_I = [3., -3.]
else:
    max_I = [-3., 3.]
    
if case in ['1', '3']:    # sparsity
    factor_ws = 1.
    factor_we = 0.
else:
    factor_ws = 0.
    factor_we = 1.
    
maxC = [5., -5., 0.18, 0.]
max_cntrl, min_cntrl = setmaxmincontrol(maxC[0], maxC[1], maxC[2], maxC[3])

# %%
file_ = '1a_I.pickle'

# %%
if os.path.isfile(file_) :
    print("file found")
    
    with open(file_,'rb') as f:
        load_array = pickle.load(f)

    bestControl_ = load_array[0]
    bestState_ = load_array[1]
    cost_ = load_array[2]
    costnode_ = load_array[3]
    weights_ = load_array[4]
# Out:
# file found

# %%
# get initial parameters and target states

#i_stepsize = 20
#limit = 150
#start_index = 0
#i_range = range(start_index, limit,i_stepsize)
i_range = [20]

data.set_parameters(aln)

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    aln.params.duration = 3000.
    
    control0 = aln.getZeroControl()
    control0 = functions.step_control(aln, maxI_ = max_I[0])

    aln.run(control=control0)
    
    target_rates = np.zeros((2))
    target_rates[0] = aln.rates_exc[0,-1] 
    target_rates[1] = aln.rates_inh[0,-1]

    control0 = functions.step_control(aln, maxI_ = max_I[1])
    aln.run(control=control0)

    init_state_vars = np.zeros(( len(state_vars) ))
    for j in range(len(state_vars)):
        if aln.state[state_vars[j]].size == 1:
            init_state_vars[j] = aln.state[state_vars[j]][0]
        else:
            init_state_vars[j] = aln.state[state_vars[j]][0,-1]

    initVars[i] = init_state_vars
    target[i] = [target_rates[0], target_rates[1]]
# Out:
# -------  20 0.4500000000000001 0.4750000000000002

# %%
# get uncontrolled cost

data.set_parameters(aln)

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    dur = d_array[0]
    aln.params.duration = dur
    
    target_ = aln.getZeroTarget()
    target_[:,0,:] = target[i][0]
    target_[:,1,:] = target[i][1]
        
    cost.setParams(1.0, 0.0, 0.0)

    setinit(initVars[i], aln)
    control0 = aln.getZeroControl()

    # "HS", "FR", "PR", "HZ"
    cgv = None
    max_it = 0

    bestControl_init_, bestState_init_, cost_init_, runtime_init_, grad_init_, phi_init_, phi1_, costnode_init_ = aln.A1(
        control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
        prec_variables_ = p_var, transition_time_ = 0.)
    
    cost_uncontrolled[i] = cost_init_[0]
# Out:
# -------  20 0.4500000000000001 0.4750000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  12801.807032522984
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  0 , total integrated cost =  12801.807032522984
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.

# %%
cgv = None
j = 0
k = 0

while k < 10:
    print('-------------------------------------------- k = ', k)

    for i in i_range:
        print("------- ", i, exc[i], inh[i])
        aln.params.ext_exc_current = exc[i] * 5.
        aln.params.ext_inh_current = inh[i] * 5.

        if convergence_[i][j] == True:
            print('converged')
            continue

        dur = d_array[0]
        aln.params.duration = dur
        
        setinit(initVars[i], aln)

        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        max_it = int(100)

        if type(bestControl_[i][j]) == type(None) or np.amax(np.abs(bestControl_[i][j])) < 1e-6:
            print('no solution found')
            control0 = aln.getZeroControl()
            #control0[0,0,:50] = 5.
            cost.setParams(1.0, 0., 1.)
            max_it = int(1)
            weights_[i][j] = [1., 0., 1.]
        else:
            control0 = bestControl_[i][j][:,:,n_pre-1:-n_post+1]
            l = 1
            while cost_[i][j][-l] == 0.:
                l += 1

            weight_ = ( cost_uncontrolled[i] - costnode_[i][j][0][0][0] ) / sum( costnode_[i][j][2][0][:] )
                
            print("weight = ", weight_)
            cost.setParams(1.0, weight_ * factor_we, weight_ * factor_ws)
            weights_[i][j] = cost.getParams()

        bestControl_[i][j], bestState_[i][j], cost_[i][j], runtime_, grad_, phi_, phi1_, costnode_[i][j] = aln.A1(
            control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
            prec_variables_ = p_var, transition_time_ = t_pen[j])

        if max_it > 1:
            if cost_[i][j][2] == 0.:
                print('converged')
                convergence_[i][j] = True

        print('uncontrolled cost : ', cost_uncontrolled[i])
        print('cost splitting : ', costnode_[i][j][0][0][0], costnode_[i][j][2][0][:2])

        time_ = np.arange(-dur_pre,dur+dur_post+aln.params.dt,aln.params.dt)
        dur += dur_pre + dur_post
        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        if True:
            fig, ax = plt.subplots(2,1, constrained_layout=True, figsize = (4,4) )
            ax[1].plot(time_, bestControl_[i][j][0,0,:], color = 'red')
            ax[0].plot(time_, bestState_[i][j][0,0,:], color= 'red')
            ax[1].plot(time_, bestControl_[i][j][0,1,:], color = 'blue')
            ax[0].plot(time_, bestState_[i][j][0,1,:], color= 'blue')
            ax[0].plot(time_, target_[0,0,:], linestyle = '--', color='red')
            ax[0].plot(time_, target_[0,1,:], linestyle = '--', color='blue')
            ax[0].set_xlim(-dur_pre,dur-dur_post)
            ax[1].set_xlim(-dur_pre,dur-dur_post)
            ax[0].axvspan(t0_array[0], dur, alpha=0.2, color='gray')
            plt.show()

        with open(file_,'wb') as f:
            pickle.dump([bestControl_, bestState_, cost_, costnode_, weights_], f)
    
    k += 1
# Out:
# -------------------------------------------- k =  0
# -------  20 0.4500000000000001 0.4750000000000002
# no solution found
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  12801.807032522984
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  9444.199144044613
# RUN  1 , total integrated cost =  9444.199144044613
# Improved over  1  iterations in  16.014700016006827  seconds by  26.227608961362805  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  9438.294876277036 [0.         5.90426777]
# -------------------------------------------- k =  1
# -------  20 0.4500000000000001 0.4750000000000002
# weight =  569.6747316773378
# set cost params:  1.0 0.0 569.6747316773378
# interpolate adjoint :  True True True
# initial cost =  12801.807032522984
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12772.358064437001
# RUN  2 , total integrated cost =  12749.621242966616
# RUN  3 , total integrated cost =  12732.171609177196
# RUN  4 , total integrated cost =  12719.270884094178
# RUN  5 , total integrated cost =  12709.454637556424
# RUN  6 , total integrated cost =  12701.815254663874
# RUN  7 , total integrated cost =  12695.813125710483
# RUN  8 , total integrated cost =  12691.2970356773
# RUN  9 , total integrated cost =  12687.593093545522
# RUN  10 , total integrated cost =  12684.520484537754
# RUN  11 , total integrated cost =  12681.890836830436
# RUN  12 , total integrated cost =  12679.81879166343
# RUN  13 , total integrated cost =  12678.027251238937
# RUN  14 , total integrated cost =  12676.767103842818
# RUN  15 , total integrated cost =  12675.6045212568
# RUN  16 , total integrated cost =  12674.688012431805
# RUN  17 , total integrated cost =  12673.827156404384
# RUN  18 , total integrated cost =  12673.139336157492
# RUN  19 , total integrated cost =  12672.53599253744
# RUN  20 , total integrated cost =  12672.03426805036
# RUN  30 , total integrated cost =  12669.931611202326
# RUN  40 , total integrated cost =  12669.577455779488
# RUN  50 , total integrated cost =  12669.307427533315
# RUN  60 , total integrated cost =  12669.295640525826
# Control only changes marginally.
# RUN  63 , total integrated cost =  12669.295636811981
# Improved over  63  iterations in  0.841338023004937  seconds by  1.0350991494744335  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  9339.746496766073 [0.         5.84464951]
# -------------------------------------------- k =  2
# -------  20 0.4500000000000001 0.4750000000000002
# weight =  592.3469886769187
# set cost params:  1.0 0.0 592.3469886769187
# interpolate adjoint :  True True True
# initial cost =  12801.807032522984
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.701855619574
# RUN  2 , total integrated cost =  12801.671802968496
# RUN  3 , total integrated cost =  12801.645871799024
# RUN  4 , total integrated cost =  12801.623668586682
# RUN  5 , total integrated cost =  12801.60645765147
# RUN  6 , total integrated cost =  12801.591388995577
# RUN  7 , total integrated cost =  12801.581351156483
# RUN  8 , total integrated cost =  12801.571089647163
# RUN  9 , total integrated cost =  12801.55958766985
# RUN  10 , total integrated cost =  12801.551476043673
# RUN  11 , total integrated cost =  12801.543800542895
# RUN  12 , total integrated cost =  12801.538986823452
# RUN  13 , total integrated cost =  12801.533734025423
# RUN  14 , total integrated cost =  12801.531193998246
# RUN  15 , total integrated cost =  12801.528260580655
# RUN  16 , total integrated cost =  12801.526379469859
# RUN  17 , total integrated cost =  12801.521544555118
# RUN  18 , total integrated cost =  12801.517850467022
# RUN  19 , total integrated cost =  12801.509300395624
# RUN  20 , total integrated cost =  12801.508315533945
# Control only changes marginally.
# RUN  29 , total integrated cost =  12801.50322642536
# Improved over  29  iterations in  0.5877640149992658  seconds by  0.002373150109605149  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  9356.479817553367 [0.         5.81588744]
# -------------------------------------------- k =  3
# -------  20 0.4500000000000001 0.4750000000000002
# weight =  592.399225949561
# set cost params:  1.0 0.0 592.399225949561
# interpolate adjoint :  True True True
# initial cost =  12801.807032522984
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522982
# RUN  2 , total integrated cost =  12801.807032522982
# Control only changes marginally.
# RUN  2 , total integrated cost =  12801.807032522982
# Improved over  2  iterations in  0.09656633199483622  seconds by  1.4210854715202004e-14  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  9356.47981754994 [0.         5.81588744]
# -------------------------------------------- k =  4
# -------  20 0.4500000000000001 0.4750000000000002
# weight =  592.3992259495612
# set cost params:  1.0 0.0 592.3992259495612
# interpolate adjoint :  True True True
# initial cost =  12801.807032522984
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.06640100799268112  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  9356.47981754994 [0.         5.81588744]
# -------------------------------------------- k =  5
# -------  20 0.4500000000000001 0.4750000000000002
# converged
# -------------------------------------------- k =  6
# -------  20 0.4500000000000001 0.4750000000000002
# converged
# -------------------------------------------- k =  7
# -------  20 0.4500000000000001 0.4750000000000002
# converged
# -------------------------------------------- k =  8
# -------  20 0.4500000000000001 0.4750000000000002
# converged
# -------------------------------------------- k =  9
# -------  20 0.4500000000000001 0.4750000000000002
# converged

# %%
cost.setParams(1.0, factor_we, factor_ws)
c_var = [0,1]

j_start = 1600

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.

    for j in range(j_start,j_start+200):
        print(i,j, '-----------------')
            
        k = 0
        while convergence_[i][j] != True:
            print('---------------------', k)

            dur = round(d_array[j],1)
            #print('simulation duration : ', dur)
            aln.params.duration = dur
            max_it = int(100)  
            
            setinit(initVars[i], aln)
            target_ = aln.getZeroTarget()
            target_[:,0,:] = target[i][0]
            target_[:,1,:] = target[i][1]

            if type(bestControl_[i][j]) == type(None):
                #print('no solution computed yet')
                control0 = aln.getZeroControl()
                control0[:,:,:-1] = bestControl_[i][j-1][:,:,n_pre-1:-n_post+1]
                                        
                l = 1
                while cost_[i][j-1][-l] == 0.:
                    l += 1
                    
                weight_ = ( cost_uncontrolled[i] - costnode_[i][j-1][0][0][0] ) / sum( costnode_[i][j-1][2][0][:] )
            else:
                control0 = bestControl_[i][j][:,:,n_pre-1:-n_post+1]
                l = 1
                while cost_[i][j][-l] == 0.:
                    l += 1
                
                weight_ = ( cost_uncontrolled[i] - costnode_[i][j][0][0][0] ) / sum( costnode_[i][j][2][0][:] )
                
            #print("weight = ", weight_)
            cost.setParams(1.0, weight_ * factor_we, weight_ * factor_ws)
            weights_[i][j] = cost.getParams()

            bestControl_[i][j], bestState_[i][j], cost_[i][j], runtime_, grad_, phi_, phi1_, costnode_[i][j] = aln.A1(
                control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
                startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
                t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
                prec_variables_ = p_var, transition_time_ = t_pen[j])

            if cost_[i][j][2] == 0.:
                #print('converged')
                convergence_[i][j] = True

            T = bestControl_[i][j].shape[2]
            max_percent = (np.argmax(np.abs(bestControl_[i][j]), axis=2)[0,1] -100) / (T-201)
            print(max_percent)

            print('cost splitting : ', costnode_[i][j][0][0][0], costnode_[i][j][2][0][:2])

            if False:
                time_ = np.arange(-dur_pre,round(dur+dur_post+aln.params.dt,1),aln.params.dt)
                dur += dur_pre + dur_post
                target_ = aln.getZeroTarget()
                target_[:,0,:] = target[i][0]
                target_[:,1,:] = target[i][1]
                
                fig, ax = plt.subplots(2,1, constrained_layout=True, figsize = (4,4) )
                ax[1].plot(time_, bestControl_[i][j][0,0,:], color = 'red')
                ax[0].plot(time_, bestState_[i][j][0,0,:], color= 'red')
                ax[1].plot(time_, bestControl_[i][j][0,1,:], color = 'blue')
                ax[0].plot(time_, bestState_[i][j][0,1,:], color= 'blue')
                ax[0].plot(time_, target_[0,0,:], linestyle = '--', color='red')
                ax[0].plot(time_, target_[0,1,:], linestyle = '--', color='blue')
                ax[0].set_xlim(-dur_pre,dur-dur_post)
                ax[1].set_xlim(-dur_pre,dur-dur_post)
                ax[0].axvspan(t0_array[j], t0_array[j]+20, alpha=0.2, color='gray')
                plt.show()

            with open(file_,'wb') as f:
                pickle.dump([bestControl_, bestState_, cost_, costnode_, weights_], f)
                
            k += 1
# Out:
# set cost params:  1.0 0.0 1.0
# -------  20 0.4500000000000001 0.4750000000000002
# 20 1600 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 3832.19273526571
# interpolate adjoint :  True True True
# initial cost =  12801.944845523454
# RUN  0 , total integrated cost =  12801.944845523454
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.944670749
# RUN  2 , total integrated cost =  12801.944670742829
# RUN  3 , total integrated cost =  12801.944670742345
# RUN  4 , total integrated cost =  12801.94467074226
# RUN  5 , total integrated cost =  12801.944670742258
# RUN  6 , total integrated cost =  12801.944670742258
# Control only changes marginally.
# RUN  6 , total integrated cost =  12801.944670742258
# Improved over  6  iterations in  2.133127669003443  seconds by  1.3652706627453881e-06  percent.
# cost splitting :  0.018148897827891267 [1.83127433e-16 3.34058930e+00]
# --------------------- 1
# set cost params:  1.0 0.0 3832.1947800004978
# interpolate adjoint :  True True True
# initial cost =  12801.951501361415
# RUN  0 , total integrated cost =  12801.951501361415
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.951501361415
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.951501361415
# Improved over  1  iterations in  0.5645366640092107  seconds by  0.0  percent.
# cost splitting :  0.018148897827891267 [1.83127433e-16 3.34058930e+00]
# 20 1601 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 3832.1947800004978
# interpolate adjoint :  True True True
# initial cost =  12801.943843865569
# RUN  0 , total integrated cost =  12801.943843865569
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.943673401687
# RUN  2 , total integrated cost =  12801.943672683861
# RUN  3 , total integrated cost =  12801.943672655932
# RUN  4 , total integrated cost =  12801.943672652846
# RUN  5 , total integrated cost =  12801.943672652322
# RUN  6 , total integrated cost =  12801.943672652227
# RUN  7 , total integrated cost =  12801.943672652207
# RUN  8 , total integrated cost =  12801.943672652196
# RUN  9 , total integrated cost =  12801.943672652187
# RUN  10 , total integrated cost =  12801.943672652184
# RUN  11 , total integrated cost =  12801.943672652182
# RUN  12 , total integrated cost =  12801.94367265218
# RUN  13 , total integrated cost =  12801.94367265218
# Control only changes marginally.
# RUN  13 , total integrated cost =  12801.94367265218
# Improved over  13  iterations in  4.403710353988572  seconds by  1.3374014997680206e-06  percent.
# cost splitting :  0.018005957769529676 [1.83127433e-16 3.34058757e+00]
# --------------------- 1
# set cost params:  1.0 0.0 3832.1968097212166
# interpolate adjoint :  True True True
# initial cost =  12801.950453111984
# RUN  0 , total integrated cost =  12801.950453111984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.950453111984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.950453111984
# Improved over  1  iterations in  0.4729511409968836  seconds by  0.0  percent.
# cost splitting :  0.018005957769529676 [1.83127433e-16 3.34058757e+00]
# 20 1602 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 3832.1968097212166
# interpolate adjoint :  True True True
# initial cost =  12801.942863379607
# RUN  0 , total integrated cost =  12801.942863379607
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.94269921438
# RUN  2 , total integrated cost =  12801.942699188958
# RUN  3 , total integrated cost =  12801.942699186902
# RUN  4 , total integrated cost =  12801.942699186628
# RUN  5 , total integrated cost =  12801.942699186578
# RUN  6 , total integrated cost =  12801.94269918657
# RUN  7 , total integrated cost =  12801.942699186562
# RUN  8 , total integrated cost =  12801.942699186553
# RUN  9 , total integrated cost =  12801.942699186553
# Control only changes marginally.
# RUN  9 , total integrated cost =  12801.942699186553
# Improved over  9  iterations in  3.7813955080055166  seconds by  1.282563559357186e-06  percent.
# cost splitting :  0.017862213185100857 [1.83127433e-16 3.34058586e+00]
# --------------------- 1
# set cost params:  1.0 0.0 3832.1988147112993
# interpolate adjoint :  True True True
# initial cost =  12801.949397028071
# RUN  0 , total integrated cost =  12801.949397028071
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.949397028071
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.949397028071
# Improved over  1  iterations in  0.49582893899059854  seconds by  0.0  percent.
# cost splitting :  0.017862213185100857 [1.83127433e-16 3.34058586e+00]
# 20 1603 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 3832.1988147112993
# interpolate adjoint :  True True True
# initial cost =  12801.941875268078
# RUN  0 , total integrated cost =  12801.941875268078
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.941714431356
# RUN  2 , total integrated cost =  12801.9417143107
# RUN  3 , total integrated cost =  12801.941714302706
# RUN  4 , total integrated cost =  12801.941714301496
# RUN  5 , total integrated cost =  12801.941714301234
# RUN  6 , total integrated cost =  12801.941714301198
# RUN  7 , total integrated cost =  12801.941714301185
# RUN  8 , total integrated cost =  12801.941714301181
# RUN  9 , total integrated cost =  12801.941714301181
# Control only changes marginally.
# RUN  9 , total integrated cost =  12801.941714301181
# Improved over  9  iterations in  3.2696355570078595  seconds by  1.2573631238410599e-06  percent.
# cost splitting :  0.017707130784031883 [1.83127433e-16 3.34058419e+00]
# --------------------- 1
# set cost params:  1.0 0.0 3832.200770893752
# interpolate adjoint :  True True True
# initial cost =  12801.948249093366
# RUN  0 , total integrated cost =  12801.948249093366
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.948249093366
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.948249093366
# Improved over  1  iterations in  0.5892494360014098  seconds by  0.0  percent.
# cost splitting :  0.017707130784031883 [1.83127433e-16 3.34058419e+00]
# 20 1604 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 3832.200770893752
# interpolate adjoint :  True True True
# initial cost =  12801.940799721204
# RUN  0 , total integrated cost =  12801.940799721204
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.940635704934
# RUN  2 , total integrated cost =  12801.940635594025
# RUN  3 , total integrated cost =  12801.940635588875
# RUN  4 , total integrated cost =  12801.940635588388
# RUN  5 , total integrated cost =  12801.940635588337
# RUN  6 , total integrated cost =  12801.940635588318
# RUN  7 , total integrated cost =  12801.940635588311
# RUN  8 , total integrated cost =  12801.940635588311
# Control only changes marginally.
# RUN  8 , total integrated cost =  12801.940635588311
# Improved over  8  iterations in  3.0018181370105594  seconds by  1.2820938337654297e-06  percent.
# cost splitting :  0.01757053629227755 [1.83127433e-16 3.34058250e+00]
# --------------------- 1
# set cost params:  1.0 0.0 3832.20275005834
# interpolate adjoint :  True True True
# initial cost =  12801.947247150907
# RUN  0 , total integrated cost =  12801.947247150907
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.947247150907
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.947247150907
# Improved over  1  iterations in  0.44610464699508157  seconds by  0.0  percent.
# cost splitting :  0.01757053629227755 [1.83127433e-16 3.34058250e+00]
# 20 1605 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 3832.20275005834
# interpolate adjoint :  True True True
# initial cost =  12801.939862210087
# RUN  0 , total integrated cost =  12801.939862210087
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.939702491332
# RUN  2 , total integrated cost =  12801.939702179834
# RUN  3 , total integrated cost =  12801.939702170852
# RUN  4 , total integrated cost =  12801.939702170055
# RUN  5 , total integrated cost =  12801.939702169944
# RUN  6 , total integrated cost =  12801.93970216993
# RUN  7 , total integrated cost =  12801.939702169922
# RUN  8 , total integrated cost =  12801.939702169922
# Control only changes marginally.
# RUN  8 , total integrated cost =  12801.939702169922
# Improved over  8  iterations in  3.0773647710011574  seconds by  1.2501243276119567e-06  percent.
# cost splitting :  0.01741690255736894 [1.83127433e-16 3.34058087e+00]
# --------------------- 1
# set cost params:  1.0 0.0 3832.204667575081
# interpolate adjoint :  True True True
# initial cost =  12801.946107789672
# RUN  0 , total integrated cost =  12801.946107789672
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.946107789672
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.946107789672
# Improved over  1  iterations in  0.521486678000656  seconds by  0.0  percent.
# cost splitting :  0.01741690255736894 [1.83127433e-16 3.34058087e+00]
# 20 1606 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 3832.204667575081
# interpolate adjoint :  True True True
# initial cost =  12801.938793858873
# RUN  0 , total integrated cost =  12801.938793858873
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.938630685236
# RUN  2 , total integrated cost =  12801.93863037185
# RUN  3 , total integrated cost =  12801.938630353692
# RUN  4 , total integrated cost =  12801.938630353672
# RUN  5 , total integrated cost =  12801.938630353668
# RUN  6 , total integrated cost =  12801.938630353668
# Control only changes marginally.
# RUN  6 , total integrated cost =  12801.938630353668
# Improved over  6  iterations in  2.1763263039902085  seconds by  1.2771909609909926e-06  percent.
# cost splitting :  0.017269374458268136 [1.83127433e-16 3.34057925e+00]
# --------------------- 1
# set cost params:  1.0 0.0 3832.206579019157
# interpolate adjoint :  True True True
# initial cost =  12801.945015684078
# RUN  0 , total integrated cost =  12801.945015684078
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.945015684072
# RUN  2 , total integrated cost =  12801.945015684072
# Control only changes marginally.
# RUN  2 , total integrated cost =  12801.945015684072
# Improved over  2  iterations in  0.8692350409983192  seconds by  4.263256414560601e-14  percent.
# cost splitting :  0.017269374454102402 [1.83127433e-16 3.34057925e+00]
# --------------------- 2
# set cost params:  1.0 0.0 3832.206579019149
# interpolate adjoint :  True True True
# initial cost =  12801.945015684045
# RUN  0 , total integrated cost =  12801.945015684045
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.945015684045
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.945015684045
# Improved over  1  iterations in  0.5094662540068384  seconds by  0.0  percent.
# cost splitting :  0.017269374454102402 [1.83127433e-16 3.34057925e+00]
# 20 1607 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 3832.206579019149
# interpolate adjoint :  True True True
# initial cost =  12801.93776976741
# RUN  0 , total integrated cost =  12801.93776976741
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.937605110956
# RUN  2 , total integrated cost =  12801.937605006742
# RUN  3 , total integrated cost =  12801.937605002093
# RUN  4 , total integrated cost =  12801.937605001662
# RUN  5 , total integrated cost =  12801.937605001653
# RUN  6 , total integrated cost =  12801.93760500165
# RUN  7 , total integrated cost =  12801.93760500165
# Control only changes marginally.
# RUN  7 , total integrated cost =  12801.93760500165
# Improved over  7  iterations in  2.754258945991751  seconds by  1.2870376480123014e-06  percent.
# cost splitting :  0.01715456912181408 [1.83127433e-16 3.34057756e+00]
# --------------------- 1
# set cost params:  1.0 0.0 3832.208548357707
# interpolate adjoint :  True True True
# initial cost =  12801.944183729844
# RUN  0 , total integrated cost =  12801.944183729844
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.944183729844
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.944183729844
# Improved over  1  iterations in  0.582803255005274  seconds by  0.0  percent.
# cost splitting :  0.01715456912181408 [1.83127433e-16 3.34057756e+00]
# 20 1608 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 3832.208548357707
# interpolate adjoint :  True True True
# initial cost =  12801.93699185082
# RUN  0 , total integrated cost =  12801.93699185082
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.936840212862
# RUN  2 , total integrated cost =  12801.93683988403
# RUN  3 , total integrated cost =  12801.936839866472
# RUN  4 , total integrated cost =  12801.936839865337
# RUN  5 , total integrated cost =  12801.936839865295
# RUN  6 , total integrated cost =  12801.936839865291
# RUN  7 , total integrated cost =  12801.936839865291
# Control only changes marginally.
# RUN  7 , total integrated cost =  12801.936839865291
# Improved over  7  iterations in  2.383693249008502  seconds by  1.1872072889218543e-06  percent.
# cost splitting :  0.017014660025447537 [1.83127433e-16 3.34057595e+00]
# --------------------- 1
# set cost params:  1.0 0.0 3832.210437234952
# interpolate adjoint :  True True True
# initial cost =  12801.943149803188
# RUN  0 , total integrated cost =  12801.943149803188
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.943149803188
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.943149803188
# Improved over  1  iterations in  0.567034755993518  seconds by  0.0  percent.
# cost splitting :  0.017014660025447537 [1.83127433e-16 3.34057595e+00]
# 20 1609 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 3832.210437234952
# interpolate adjoint :  True True True
# initial cost =  12801.936021739832
# RUN  0 , total integrated cost =  12801.936021739832
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.935870152472
# RUN  2 , total integrated cost =  12801.935869551466
# RUN  3 , total integrated cost =  12801.935869527377
# RUN  4 , total integrated cost =  12801.93586952537
# RUN  5 , total integrated cost =  12801.935869525194
# RUN  6 , total integrated cost =  12801.93586952517
# RUN  7 , total integrated cost =  12801.935869525165
# RUN  8 , total integrated cost =  12801.935869525165
# Control only changes marginally.
# RUN  8 , total integrated cost =  12801.935869525165
# Improved over  8  iterations in  2.8012975009914953  seconds by  1.188997245549217e-06  percent.
# cost splitting :  0.016877391409234485 [1.83127433e-16 3.34057435e+00]
# --------------------- 1
# set cost params:  1.0 0.0 3832.212312989107
# interpolate adjoint :  True True True
# initial cost =  12801.94213562138
# RUN  0 , total integrated cost =  12801.94213562138
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.942135621379
# RUN  2 , total integrated cost =  12801.942135621379
# Control only changes marginally.
# RUN  2 , total integrated cost =  12801.942135621379
# Improved over  2  iterations in  1.129945950990077  seconds by  1.4210854715202004e-14  percent.
# cost splitting :  0.016877391398198778 [1.83127433e-16 3.34057435e+00]
# --------------------- 2
# set cost params:  1.0 0.0 3832.2123129890806
# interpolate adjoint :  True True True
# initial cost =  12801.942135621292
# RUN  0 , total integrated cost =  12801.942135621292
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.942135621292
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.942135621292
# Improved over  1  iterations in  0.5349110609968193  seconds by  0.0  percent.
# cost splitting :  0.016877391398198778 [1.83127433e-16 3.34057435e+00]
# 20 1610 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 3832.2123129890806
# interpolate adjoint :  True True True
# initial cost =  12801.935069733481
# RUN  0 , total integrated cost =  12801.935069733481
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.934918437264
# RUN  2 , total integrated cost =  12801.934917858458
# RUN  3 , total integrated cost =  12801.93491783552
# RUN  4 , total integrated cost =  12801.934917834315
# RUN  5 , total integrated cost =  12801.934917834196
# RUN  6 , total integrated cost =  12801.93491783419
# RUN  7 , total integrated cost =  12801.934917834184
# RUN  8 , total integrated cost =  12801.93491783418
# RUN  9 , total integrated cost =  12801.93491783418
# Control only changes marginally.
# RUN  9 , total integrated cost =  12801.93491783418
# Improved over  9  iterations in  3.2354333459952613  seconds by  1.1865339217820292e-06  percent.
# cost splitting :  0.016739454936262853 [1.83127433e-16 3.34057277e+00]
# --------------------- 1
# set cost params:  1.0 0.0 3832.214168027262
# interpolate adjoint :  True True True
# initial cost =  12801.941114724214
# RUN  0 , total integrated cost =  12801.941114724214
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.941114724214
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.941114724214
# Improved over  1  iterations in  0.5666189839976141  seconds by  0.0  percent.
# cost splitting :  0.016739454936262853 [1.83127433e-16 3.34057277e+00]
# 20 1611 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 3832.214168027262
# interpolate adjoint :  True True True
# initial cost =  12801.934110731747
# RUN  0 , total integrated cost =  12801.934110731747
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.933958273157
# RUN  2 , total integrated cost =  12801.933957457224
# RUN  3 , total integrated cost =  12801.933957439707
# RUN  4 , total integrated cost =  12801.933957437932
# RUN  5 , total integrated cost =  12801.933957437843
# RUN  6 , total integrated cost =  12801.933957437835
# RUN  7 , total integrated cost =  12801.933957437834
# RUN  8 , total integrated cost =  12801.933957437834
# Control only changes marginally.
# RUN  8 , total integrated cost =  12801.933957437834
# Improved over  8  iterations in  2.8721874010079773  seconds by  1.197427764054737e-06  percent.
# cost splitting :  0.016597949706243655 [1.83127433e-16 3.34057121e+00]
# --------------------- 1
# set cost params:  1.0 0.0 3832.2159959821247
# interpolate adjoint :  True True True
# initial cost =  12801.940063851225
# RUN  0 , total integrated cost =  12801.940063851225
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.940063851225
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.940063851225
# Improved over  1  iterations in  0.4363098909961991  seconds by  0.0  percent.
# cost splitting :  0.016597949706243655 [1.83127433e-16 3.34057121e+00]
# 20 1612 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 3832.2159959821247
# interpolate adjoint :  True True True
# initial cost =  12801.933122673006
# RUN  0 , total integrated cost =  12801.933122673006
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.932967515255
# RUN  2 , total integrated cost =  12801.93296749534
# RUN  3 , total integrated cost =  12801.932967492923
# RUN  4 , total integrated cost =  12801.932967492194
# RUN  5 , total integrated cost =  12801.932967491985
# RUN  6 , total integrated cost =  12801.932967491934
# RUN  7 , total integrated cost =  12801.932967491903
# RUN  8 , total integrated cost =  12801.932967491886
# RUN  9 , total integrated cost =  12801.932967491874
# RUN  10 , total integrated cost =  12801.932967491868
# RUN  11 , total integrated cost =  12801.932967491868
# Control only changes marginally.
# RUN  11 , total integrated cost =  12801.932967491868
# Improved over  11  iterations in  3.563384164997842  seconds by  1.2121695789346631e-06  percent.
# cost splitting :  0.016460823388115366 [1.83127433e-16 3.34056966e+00]
# --------------------- 1
# set cost params:  1.0 0.0 3832.217815790544
# interpolate adjoint :  True True True
# initial cost =  12801.939046688663
# RUN  0 , total integrated cost =  12801.939046688663
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.939046688663
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.939046688663
# Improved over  1  iterations in  0.5059279909910401  seconds by  0.0  percent.
# cost splitting :  0.016460823388115366 [1.83127433e-16 3.34056966e+00]
# 20 1613 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 3832.217815790544
# interpolate adjoint :  True True True
# initial cost =  12801.932165993196
# RUN  0 , total integrated cost =  12801.932165993196
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.932010218618
# RUN  2 , total integrated cost =  12801.932009444638
# RUN  3 , total integrated cost =  12801.93200941445
# RUN  4 , total integrated cost =  12801.932009412034
# RUN  5 , total integrated cost =  12801.932009411694
# RUN  6 , total integrated cost =  12801.932009411654
# RUN  7 , total integrated cost =  12801.932009411643
# RUN  8 , total integrated cost =  12801.932009411636
# RUN  9 , total integrated cost =  12801.93200941163
# RUN  10 , total integrated cost =  12801.93200941163
# Control only changes marginally.
# RUN  10 , total integrated cost =  12801.93200941163
# Improved over  10  iterations in  3.718153390000225  seconds by  1.2231088533098955e-06  percent.
# cost splitting :  0.01635255330190856 [1.83127433e-16 3.34056806e+00]
# --------------------- 1
# set cost params:  1.0 0.0 3832.2196868249284
# interpolate adjoint :  True True True
# initial cost =  12801.938259729332
# RUN  0 , total integrated cost =  12801.938259729332
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.938259729332
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.938259729332
# Improved over  1  iterations in  0.45191119000082836  seconds by  0.0  percent.
# cost splitting :  0.01635255330190856 [1.83127433e-16 3.34056806e+00]
# 20 1614 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 3832.2196868249284
# interpolate adjoint :  True True True
# initial cost =  12801.931427139527
# RUN  0 , total integrated cost =  12801.931427139527
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.931282179987
# RUN  2 , total integrated cost =  12801.931282154663
# RUN  3 , total integrated cost =  12801.931282152615
# RUN  4 , total integrated cost =  12801.931282152424
# RUN  5 , total integrated cost =  12801.931282152389
# RUN  6 , total integrated cost =  12801.931282152384
# RUN  7 , total integrated cost =  12801.93128215238
# RUN  8 , total integrated cost =  12801.93128215238
# Control only changes marginally.
# RUN  8 , total integrated cost =  12801.93128215238
# Improved over  8  iterations in  2.9562877519929316  seconds by  1.1325412003770907e-06  percent.
# cost splitting :  0.016225372942797023 [1.83127433e-16 3.34056652e+00]
# --------------------- 1
# set cost params:  1.0 0.0 3832.2214942110727
# interpolate adjoint :  True True True
# initial cost =  12801.937319846016
# RUN  0 , total integrated cost =  12801.937319846016
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.937319846014
# RUN  2 , total integrated cost =  12801.937319846014
# Control only changes marginally.
# RUN  2 , total integrated cost =  12801.937319846014
# Improved over  2  iterations in  0.9561987429915462  seconds by  1.4210854715202004e-14  percent.
# cost splitting :  0.016225372942043598 [1.83127433e-16 3.34056652e+00]
# --------------------- 2
# set cost params:  1.0 0.0 3832.2214942110713
# interpolate adjoint :  True True True
# initial cost =  12801.93731984601
# RUN  0 , total integrated cost =  12801.93731984601
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.93731984601
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.93731984601
# Improved over  1  iterations in  0.4824309849936981  seconds by  0.0  percent.
# cost splitting :  0.016225372942043598 [1.83127433e-16 3.34056652e+00]
# 20 1615 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 3832.2214942110713
# interpolate adjoint :  True True True
# initial cost =  12801.930542644066
# RUN  0 , total integrated cost =  12801.930542644066
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.930398791708
# RUN  2 , total integrated cost =  12801.930398694274
# RUN  3 , total integrated cost =  12801.930398686745
# RUN  4 , total integrated cost =  12801.930398685976
# RUN  5 , total integrated cost =  12801.930398685883
# RUN  6 , total integrated cost =  12801.93039868586
# RUN  7 , total integrated cost =  12801.930398685852
# RUN  8 , total integrated cost =  12801.93039868585
# RUN  9 , total integrated cost =  12801.93039868585
# Control only changes marginally.
# RUN  9 , total integrated cost =  12801.93039868585
# Improved over  9  iterations in  3.4158681800035993  seconds by  1.1245039530649592e-06  percent.
# cost splitting :  0.01608836506176636 [1.83127433e-16 3.34056501e+00]
# --------------------- 1
# set cost params:  1.0 0.0 3832.223260693366
# interpolate adjoint :  True True True
# initial cost =  12801.936299734798
# RUN  0 , total integrated cost =  12801.936299734798
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.936299734798
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.936299734798
# Improved over  1  iterations in  0.5078027530107647  seconds by  0.0  percent.
# cost splitting :  0.01608836506176636 [1.83127433e-16 3.34056501e+00]
# 20 1616 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 3832.223260693366
# interpolate adjoint :  True True True
# initial cost =  12801.929581494634
# RUN  0 , total integrated cost =  12801.929581494634
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.929434069712
# RUN  2 , total integrated cost =  12801.92943380961
# RUN  3 , total integrated cost =  12801.92943379404
# RUN  4 , total integrated cost =  12801.929433790914
# RUN  5 , total integrated cost =  12801.929433790194
# RUN  6 , total integrated cost =  12801.929433790003
# RUN  7 , total integrated cost =  12801.929433789943
# RUN  8 , total integrated cost =  12801.92943378992
# RUN  9 , total integrated cost =  12801.929433789917
# RUN  10 , total integrated cost =  12801.929433789915
# RUN  11 , total integrated cost =  12801.929433789915
# Control only changes marginally.
# RUN  11 , total integrated cost =  12801.929433789915
# Improved over  11  iterations in  4.26179018500261  seconds by  1.1537691904095482e-06  percent.
# cost splitting :  0.015946532913212748 [1.83127433e-16 3.34056353e+00]
# --------------------- 1
# set cost params:  1.0 0.0 3832.2249986289544
# interpolate adjoint :  True True True
# initial cost =  12801.935239474167
# RUN  0 , total integrated cost =  12801.935239474167
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.935239474165
# RUN  2 , total integrated cost =  12801.935239474164
# RUN  3 , total integrated cost =  12801.935239474164
# Control only changes marginally.
# RUN  3 , total integrated cost =  12801.935239474164
# Improved over  3  iterations in  1.30221839499427  seconds by  2.842170943040401e-14  percent.
# cost splitting :  0.015946532364814945 [1.83127433e-16 3.34056353e+00]
# --------------------- 2
# set cost params:  1.0 0.0 3832.2249986276356
# interpolate adjoint :  True True True
# initial cost =  12801.935239469758
# RUN  0 , total integrated cost =  12801.935239469758
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.935239469758
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.935239469758
# Improved over  1  iterations in  0.5680313789926004  seconds by  0.0  percent.
# cost splitting :  0.015946532364814945 [1.83127433e-16 3.34056353e+00]
# 20 1617 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 3832.2249986276356
# interpolate adjoint :  True True True
# initial cost =  12801.928581733686
# RUN  0 , total integrated cost =  12801.928581733686
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.928427851131
# RUN  2 , total integrated cost =  12801.928427653658
# RUN  3 , total integrated cost =  12801.92842764401
# RUN  4 , total integrated cost =  12801.928427642973
# RUN  5 , total integrated cost =  12801.928427642866
# RUN  6 , total integrated cost =  12801.928427642843
# RUN  7 , total integrated cost =  12801.928427642835
# RUN  8 , total integrated cost =  12801.928427642833
# RUN  9 , total integrated cost =  12801.928427642833
# Control only changes marginally.
# RUN  9 , total integrated cost =  12801.928427642833
# Improved over  9  iterations in  4.144263686001068  seconds by  1.2036534258186293e-06  percent.
# cost splitting :  0.01583388481438577 [1.83127433e-16 3.34056200e+00]
# --------------------- 1
# set cost params:  1.0 0.0 3832.2267902239537
# interpolate adjoint :  True True True
# initial cost =  12801.934412581417
# RUN  0 , total integrated cost =  12801.934412581417
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.934412581417
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.934412581417
# Improved over  1  iterations in  0.4661240809946321  seconds by  0.0  percent.
# cost splitting :  0.01583388481438577 [1.83127433e-16 3.34056200e+00]
# 20 1618 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 3832.2267902239537
# interpolate adjoint :  True True True
# initial cost =  12801.927802931801
# RUN  0 , total integrated cost =  12801.927802931801
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.927655008581
# RUN  2 , total integrated cost =  12801.92765483971
# RUN  3 , total integrated cost =  12801.927654832936
# RUN  4 , total integrated cost =  12801.927654831923
# RUN  5 , total integrated cost =  12801.9276548317
# RUN  6 , total integrated cost =  12801.927654831645
# RUN  7 , total integrated cost =  12801.927654831623
# RUN  8 , total integrated cost =  12801.927654831623
# Control only changes marginally.
# RUN  8 , total integrated cost =  12801.927654831623
# Improved over  8  iterations in  3.0316838449944044  seconds by  1.1568584028509576e-06  percent.
# cost splitting :  0.015719255661945715 [1.83127433e-16 3.34056049e+00]
# --------------------- 1
# set cost params:  1.0 0.0 3832.22856052244
# interpolate adjoint :  True True True
# initial cost =  12801.9335686208
# RUN  0 , total integrated cost =  12801.9335686208
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.9335686208
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.9335686208
# Improved over  1  iterations in  0.5281127980124438  seconds by  0.0  percent.
# cost splitting :  0.015719255661945715 [1.83127433e-16 3.34056049e+00]
# 20 1619 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 3832.22856052244
# interpolate adjoint :  True True True
# initial cost =  12801.927007484475
# RUN  0 , total integrated cost =  12801.927007484475
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.926865585961
# RUN  2 , total integrated cost =  12801.92686544117
# RUN  3 , total integrated cost =  12801.926865428319
# RUN  4 , total integrated cost =  12801.926865423435
# RUN  5 , total integrated cost =  12801.926865422689
# RUN  6 , total integrated cost =  12801.926865422529
# RUN  7 , total integrated cost =  12801.926865422503
# RUN  8 , total integrated cost =  12801.926865422496
# RUN  9 , total integrated cost =  12801.926865422494
# RUN  10 , total integrated cost =  12801.926865422494
# Control only changes marginally.
# RUN  10 , total integrated cost =  12801.926865422494
# Improved over  10  iterations in  3.4995457920012996  seconds by  1.1096921639364155e-06  percent.
# cost splitting :  0.015598558987002482 [1.83127433e-16 3.34055900e+00]
# --------------------- 1
# set cost params:  1.0 0.0 3832.230299520272
# interpolate adjoint :  True True True
# initial cost =  12801.932674647362
# RUN  0 , total integrated cost =  12801.932674647362
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.932674647362
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.932674647362
# Improved over  1  iterations in  0.4497700430074474  seconds by  0.0  percent.
# cost splitting :  0.015598558987002482 [1.83127433e-16 3.34055900e+00]
# 20 1620 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 3832.230299520272
# interpolate adjoint :  True True True
# initial cost =  12801.926164160868
# RUN  0 , total integrated cost =  12801.926164160868
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.926023971133
# RUN  2 , total integrated cost =  12801.926023496371
# RUN  3 , total integrated cost =  12801.92602346718
# RUN  4 , total integrated cost =  12801.926023462896
# RUN  5 , total integrated cost =  12801.9260234621
# RUN  6 , total integrated cost =  12801.92602346192
# RUN  7 , total integrated cost =  12801.926023461885
# RUN  8 , total integrated cost =  12801.926023461878
# RUN  9 , total integrated cost =  12801.926023461876
# RUN  10 , total integrated cost =  12801.926023461876
# Control only changes marginally.
# RUN  10 , total integrated cost =  12801.926023461876
# Improved over  10  iterations in  3.4967942789953668  seconds by  1.0990454910597691e-06  percent.
# cost splitting :  0.015471796929640977 [1.83127433e-16 3.34055755e+00]
# --------------------- 1
# set cost params:  1.0 0.0 3832.2320079554156
# interpolate adjoint :  True True True
# initial cost =  12801.93173058779
# RUN  0 , total integrated cost =  12801.93173058779
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.931730587788
# RUN  2 , total integrated cost =  12801.931730587788
# Control only changes marginally.
# RUN  2 , total integrated cost =  12801.931730587788
# Improved over  2  iterations in  1.0459703249944141  seconds by  1.4210854715202004e-14  percent.
# cost splitting :  0.015471796929273435 [1.83127433e-16 3.34055755e+00]
# --------------------- 2
# set cost params:  1.0 0.0 3832.2320079554147
# interpolate adjoint :  True True True
# initial cost =  12801.931730587787
# RUN  0 , total integrated cost =  12801.931730587787
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.931730587787
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.931730587787
# Improved over  1  iterations in  0.5473182879941305  seconds by  0.0  percent.
# cost splitting :  0.015471796929273435 [1.83127433e-16 3.34055755e+00]
# 20 1621 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 3832.2320079554147
# interpolate adjoint :  True True True
# initial cost =  12801.925272917508
# RUN  0 , total integrated cost =  12801.925272917508
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.925130993279
# RUN  2 , total integrated cost =  12801.925130398758
# RUN  3 , total integrated cost =  12801.92513038214
# RUN  4 , total integrated cost =  12801.925130380447
# RUN  5 , total integrated cost =  12801.925130380283
# RUN  6 , total integrated cost =  12801.925130380254
# RUN  7 , total integrated cost =  12801.925130380247
# RUN  8 , total integrated cost =  12801.925130380245
# RUN  9 , total integrated cost =  12801.925130380245
# Control only changes marginally.
# RUN  9 , total integrated cost =  12801.925130380245
# Improved over  9  iterations in  3.0333608660002938  seconds by  1.1134049060501638e-06  percent.
# cost splitting :  0.015358890312251195 [1.83127433e-16 3.34055607e+00]
# --------------------- 1
# set cost params:  1.0 0.0 3832.2337342028345
# interpolate adjoint :  True True True
# initial cost =  12801.930897006547
# RUN  0 , total integrated cost =  12801.930897006547
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.930897006547
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.930897006547
# Improved over  1  iterations in  0.4767782260023523  seconds by  0.0  percent.
# cost splitting :  0.015358890312251195 [1.83127433e-16 3.34055607e+00]
# 20 1622 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 3832.2337342028345
# interpolate adjoint :  True True True
# initial cost =  12801.924486145255
# RUN  0 , total integrated cost =  12801.924486145255
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.924347637882
# RUN  2 , total integrated cost =  12801.924347637869
# RUN  3 , total integrated cost =  12801.924347637869
# Control only changes marginally.
# RUN  3 , total integrated cost =  12801.924347637869
# Improved over  3  iterations in  1.399832018010784  seconds by  1.0819262996619727e-06  percent.
# cost splitting :  0.015227958803775924 [1.83127433e-16 3.34055465e+00]
# --------------------- 1
# set cost params:  1.0 0.0 3832.2354013539425
# interpolate adjoint :  True True True
# initial cost =  12801.92991684726
# RUN  0 , total integrated cost =  12801.92991684726
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.92991684726
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.92991684726
# Improved over  1  iterations in  0.5073167569935322  seconds by  0.0  percent.
# cost splitting :  0.015227958803775924 [1.83127433e-16 3.34055465e+00]
# 20 1623 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 3832.2354013539425
# interpolate adjoint :  True True True
# initial cost =  12801.923559942335
# RUN  0 , total integrated cost =  12801.923559942335
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.923417187598
# RUN  2 , total integrated cost =  12801.923417182465
# RUN  3 , total integrated cost =  12801.923417181808
# RUN  4 , total integrated cost =  12801.923417181628
# RUN  5 , total integrated cost =  12801.923417181608
# RUN  6 , total integrated cost =  12801.9234171816
# RUN  7 , total integrated cost =  12801.9234171816
# Control only changes marginally.
# RUN  7 , total integrated cost =  12801.9234171816
# Improved over  7  iterations in  2.8120943829999305  seconds by  1.1151506669193623e-06  percent.
# cost splitting :  0.015104760374868902 [1.83127433e-16 3.34055323e+00]
# --------------------- 1
# set cost params:  1.0 0.0 3832.2370719291202
# interpolate adjoint :  True True True
# initial cost =  12801.928997826906
# RUN  0 , total integrated cost =  12801.928997826906
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.928997826906
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.928997826906
# Improved over  1  iterations in  0.46040068700676784  seconds by  0.0  percent.
# cost splitting :  0.015104760374868902 [1.83127433e-16 3.34055323e+00]
# 20 1624 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 3832.2370719291202
# interpolate adjoint :  True True True
# initial cost =  12801.922691448564
# RUN  0 , total integrated cost =  12801.922691448564
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.922547420047
# RUN  2 , total integrated cost =  12801.922546872509
# RUN  3 , total integrated cost =  12801.922546859418
# RUN  4 , total integrated cost =  12801.922546858328
# RUN  5 , total integrated cost =  12801.922546858195
# RUN  6 , total integrated cost =  12801.922546858179
# RUN  7 , total integrated cost =  12801.922546858177
# RUN  8 , total integrated cost =  12801.922546858175
# RUN  9 , total integrated cost =  12801.922546858172
# RUN  10 , total integrated cost =  12801.922546858172
# Control only changes marginally.
# RUN  10 , total integrated cost =  12801.922546858172
# Improved over  10  iterations in  3.5088520419958513  seconds by  1.1294427793018258e-06  percent.
# cost splitting :  0.015012254322541897 [1.38763207e-16 3.34055175e+00]
# --------------------- 1
# set cost params:  1.0 0.0 3832.2388017944695
# interpolate adjoint :  True True True
# initial cost =  12801.928325562883
# RUN  0 , total integrated cost =  12801.928325562883
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.928325562883
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.928325562883
# Improved over  1  iterations in  0.46727229899261147  seconds by  0.0  percent.
# cost splitting :  0.015012254322541897 [1.38763207e-16 3.34055175e+00]
# 20 1625 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 3832.2388017944695
# interpolate adjoint :  True True True
# initial cost =  12801.922056839698
# RUN  0 , total integrated cost =  12801.922056839698
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.92192536689
# RUN  2 , total integrated cost =  12801.92192536683
# RUN  3 , total integrated cost =  12801.921925366813
# RUN  4 , total integrated cost =  12801.921925366802
# RUN  5 , total integrated cost =  12801.921925366802
# Control only changes marginally.
# RUN  5 , total integrated cost =  12801.921925366802
# Improved over  5  iterations in  1.9862400620040717  seconds by  1.026977798801454e-06  percent.
# cost splitting :  0.014895297919855737 [1.38763207e-16 3.34055033e+00]
# --------------------- 1
# set cost params:  1.0 0.0 3832.240457013013
# interpolate adjoint :  True True True
# initial cost =  12801.927454707658
# RUN  0 , total integrated cost =  12801.927454707658
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.927454707658
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.927454707658
# Improved over  1  iterations in  0.49777620600070804  seconds by  0.0  percent.
# cost splitting :  0.014895297919855737 [1.38763207e-16 3.34055033e+00]
# 20 1626 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 3832.240457013013
# interpolate adjoint :  True True True
# initial cost =  12801.921233521798
# RUN  0 , total integrated cost =  12801.921233521798
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.921102089129
# RUN  2 , total integrated cost =  12801.921102049118
# RUN  3 , total integrated cost =  12801.921102045626
# RUN  4 , total integrated cost =  12801.921102045133
# RUN  5 , total integrated cost =  12801.921102045055
# RUN  6 , total integrated cost =  12801.921102045031
# RUN  7 , total integrated cost =  12801.921102045031
# Control only changes marginally.
# RUN  7 , total integrated cost =  12801.921102045031
# Improved over  7  iterations in  2.5893143260036595  seconds by  1.0270080963437067e-06  percent.
# cost splitting :  0.014771372752244863 [1.38763207e-16 3.34054895e+00]
# --------------------- 1
# set cost params:  1.0 0.0 3832.2420807789117
# interpolate adjoint :  True True True
# initial cost =  12801.9265263145
# RUN  0 , total integrated cost =  12801.9265263145
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.9265263145
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.9265263145
# Improved over  1  iterations in  0.5126043560012477  seconds by  0.0  percent.
# cost splitting :  0.014771372752244863 [1.38763207e-16 3.34054895e+00]
# 20 1627 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 3832.2420807789117
# interpolate adjoint :  True True True
# initial cost =  12801.920355373673
# RUN  0 , total integrated cost =  12801.920355373673
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.920220558595
# RUN  2 , total integrated cost =  12801.920220402719
# RUN  3 , total integrated cost =  12801.920220392003
# RUN  4 , total integrated cost =  12801.92022039031
# RUN  5 , total integrated cost =  12801.920220389904
# RUN  6 , total integrated cost =  12801.92022038974
# RUN  7 , total integrated cost =  12801.920220389682
# RUN  8 , total integrated cost =  12801.920220389671
# RUN  9 , total integrated cost =  12801.92022038966
# RUN  10 , total integrated cost =  12801.920220389657
# RUN  11 , total integrated cost =  12801.920220389657
# Control only changes marginally.
# RUN  11 , total integrated cost =  12801.920220389657
# Improved over  11  iterations in  4.205268812002032  seconds by  1.05440443576299e-06  percent.
# cost splitting :  0.014642825040211851 [1.38763207e-16 3.34054759e+00]
# --------------------- 1
# set cost params:  1.0 0.0 3832.2436789843387
# interpolate adjoint :  True True True
# initial cost =  12801.925559270945
# RUN  0 , total integrated cost =  12801.925559270945
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.925559270945
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.925559270945
# Improved over  1  iterations in  0.4844405929907225  seconds by  0.0  percent.
# cost splitting :  0.014642825040211851 [1.38763207e-16 3.34054759e+00]
# 20 1628 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 3832.2436789843387
# interpolate adjoint :  True True True
# initial cost =  12801.919440340884
# RUN  0 , total integrated cost =  12801.919440340884
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.91929950011
# RUN  2 , total integrated cost =  12801.919299403713
# RUN  3 , total integrated cost =  12801.91929939766
# RUN  4 , total integrated cost =  12801.919299397412
# RUN  5 , total integrated cost =  12801.919299397357
# RUN  6 , total integrated cost =  12801.919299397354
# RUN  7 , total integrated cost =  12801.919299397347
# RUN  8 , total integrated cost =  12801.919299397347
# Control only changes marginally.
# RUN  8 , total integrated cost =  12801.919299397347
# Improved over  8  iterations in  3.0963355760031845  seconds by  1.10095629679563e-06  percent.
# cost splitting :  0.014539751703809256 [1.38763207e-16 3.34054618e+00]
# --------------------- 1
# set cost params:  1.0 0.0 3832.245324787278
# interpolate adjoint :  True True True
# initial cost =  12801.924797278076
# RUN  0 , total integrated cost =  12801.924797278076
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.924797278076
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.924797278076
# Improved over  1  iterations in  0.46965969499433413  seconds by  0.0  percent.
# cost splitting :  0.014539751703809256 [1.38763207e-16 3.34054618e+00]
# 20 1629 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 3832.245324787278
# interpolate adjoint :  True True True
# initial cost =  12801.918719727755
# RUN  0 , total integrated cost =  12801.918719727755
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.918584106865
# RUN  2 , total integrated cost =  12801.918583951308
# RUN  3 , total integrated cost =  12801.91858394302
# RUN  4 , total integrated cost =  12801.918583942854
# RUN  5 , total integrated cost =  12801.918583942854
# Control only changes marginally.
# RUN  5 , total integrated cost =  12801.918583942854
# Improved over  5  iterations in  1.950300544995116  seconds by  1.060660551388537e-06  percent.
# cost splitting :  0.014424730267634085 [1.38763207e-16 3.34054482e+00]
# --------------------- 1
# set cost params:  1.0 0.0 3832.246927365282
# interpolate adjoint :  True True True
# initial cost =  12801.923937426496
# RUN  0 , total integrated cost =  12801.923937426496
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.923937426496
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.923937426496
# Improved over  1  iterations in  0.5191364600032102  seconds by  0.0  percent.
# cost splitting :  0.014424730267634085 [1.38763207e-16 3.34054482e+00]
# 20 1630 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 3832.246927365282
# interpolate adjoint :  True True True
# initial cost =  12801.917906092955
# RUN  0 , total integrated cost =  12801.917906092955
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.91777117162
# RUN  2 , total integrated cost =  12801.91777106617
# RUN  3 , total integrated cost =  12801.917771061711
# RUN  4 , total integrated cost =  12801.917771061371
# RUN  5 , total integrated cost =  12801.91777106134
# RUN  6 , total integrated cost =  12801.917771061328
# RUN  7 , total integrated cost =  12801.917771061328
# Control only changes marginally.
# RUN  7 , total integrated cost =  12801.917771061328
# Improved over  7  iterations in  2.882195837009931  seconds by  1.0547765469937076e-06  percent.
# cost splitting :  0.01433626550704371 [1.38763207e-16 3.34054340e+00]
# --------------------- 1
# set cost params:  1.0 0.0 3832.248580009341
# interpolate adjoint :  True True True
# initial cost =  12801.923291790528
# RUN  0 , total integrated cost =  12801.923291790528
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.923291790528
# Control only changes marginally.
# ...
# RUN  9 , total integrated cost =  12801.842678747154
# Control only changes marginally.
# RUN  9 , total integrated cost =  12801.842678747154
# Improved over  9  iterations in  3.30937707699195  seconds by  3.240513422042568e-07  percent.
# cost splitting :  0.004194549736547179 [2.01157922e-16 3.34023392e+00]
# --------------------- 1
# set cost params:  1.0 0.0 3832.606683794336
# interpolate adjoint :  True True True
# initial cost =  12801.84436610248
# RUN  0 , total integrated cost =  12801.84436610248
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.84436610248
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.84436610248
# Improved over  1  iterations in  0.4875457419984741  seconds by  0.0  percent.
# cost splitting :  0.004194549736547179 [2.01157922e-16 3.34023392e+00]
# 20 1790 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 3832.606683794336
# interpolate adjoint :  True True True
# initial cost =  12801.842494676986
# RUN  0 , total integrated cost =  12801.842494676986
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.842455927084
# RUN  2 , total integrated cost =  12801.842455920392
# RUN  3 , total integrated cost =  12801.842455919843
# RUN  4 , total integrated cost =  12801.842455919821
# RUN  5 , total integrated cost =  12801.842455919816
# RUN  6 , total integrated cost =  12801.842455919816
# Control only changes marginally.
# RUN  6 , total integrated cost =  12801.842455919816
# Improved over  6  iterations in  2.3835379109950736  seconds by  3.0274681250830326e-07  percent.
# cost splitting :  0.004162338898907286 [2.01157922e-16 3.34023350e+00]
# --------------------- 1
# set cost params:  1.0 0.0 3832.607176034875
# interpolate adjoint :  True True True
# initial cost =  12801.844100118153
# RUN  0 , total integrated cost =  12801.844100118153
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.844100118153
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.844100118153
# Improved over  1  iterations in  0.5298205330036581  seconds by  0.0  percent.
# cost splitting :  0.004162338898907286 [2.01157922e-16 3.34023350e+00]
# 20 1791 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 3832.607176034875
# interpolate adjoint :  True True True
# initial cost =  12801.842242177185
# RUN  0 , total integrated cost =  12801.842242177185
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.842203972592
# RUN  2 , total integrated cost =  12801.842203898166
# RUN  3 , total integrated cost =  12801.842203895189
# RUN  4 , total integrated cost =  12801.842203894788
# RUN  5 , total integrated cost =  12801.842203894685
# RUN  6 , total integrated cost =  12801.842203894646
# RUN  7 , total integrated cost =  12801.842203894643
# RUN  8 , total integrated cost =  12801.842203894641
# RUN  9 , total integrated cost =  12801.842203894641
# Control only changes marginally.
# RUN  9 , total integrated cost =  12801.842203894641
# Improved over  9  iterations in  3.2389739439968253  seconds by  2.990393426216542e-07  percent.
# cost splitting :  0.004125615303953268 [2.01157922e-16 3.34023309e+00]
# --------------------- 1
# set cost params:  1.0 0.0 3832.6076519621374
# interpolate adjoint :  True True True
# initial cost =  12801.843793602633
# RUN  0 , total integrated cost =  12801.843793602633
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.843793602633
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.843793602633
# Improved over  1  iterations in  0.4554233410017332  seconds by  0.0  percent.
# cost splitting :  0.004125615303953268 [2.01157922e-16 3.34023309e+00]
# 20 1792 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 3832.6076519621374
# interpolate adjoint :  True True True
# initial cost =  12801.84195116521
# RUN  0 , total integrated cost =  12801.84195116521
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.841911231035
# RUN  2 , total integrated cost =  12801.841911161575
# RUN  3 , total integrated cost =  12801.841911156267
# RUN  4 , total integrated cost =  12801.841911155661
# RUN  5 , total integrated cost =  12801.841911155601
# RUN  6 , total integrated cost =  12801.841911155601
# Control only changes marginally.
# RUN  6 , total integrated cost =  12801.841911155601
# Improved over  6  iterations in  2.4230781759979436  seconds by  3.125300906958728e-07  percent.
# cost splitting :  0.004092769091368314 [2.01157922e-16 3.34023268e+00]
# --------------------- 1
# set cost params:  1.0 0.0 3832.608134004785
# interpolate adjoint :  True True True
# initial cost =  12801.843521290206
# RUN  0 , total integrated cost =  12801.843521290206
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.843521290199
# RUN  2 , total integrated cost =  12801.843521290193
# RUN  3 , total integrated cost =  12801.843521290193
# Control only changes marginally.
# RUN  3 , total integrated cost =  12801.843521290193
# Improved over  3  iterations in  1.3832253120053792  seconds by  9.947598300641403e-14  percent.
# cost splitting :  0.004092695532420825 [2.01157922e-16 3.34023268e+00]
# --------------------- 2
# set cost params:  1.0 0.0 3832.6081338084527
# interpolate adjoint :  True True True
# initial cost =  12801.843520634398
# RUN  0 , total integrated cost =  12801.843520634398
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.843520634398
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.843520634398
# Improved over  1  iterations in  0.6648791219922714  seconds by  0.0  percent.
# cost splitting :  0.004092695532420825 [2.01157922e-16 3.34023268e+00]
# 20 1793 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 3832.6081338084527
# interpolate adjoint :  True True True
# initial cost =  12801.841692013766
# RUN  0 , total integrated cost =  12801.841692013766
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.84165205557
# RUN  2 , total integrated cost =  12801.841651986875
# RUN  3 , total integrated cost =  12801.841651982983
# RUN  4 , total integrated cost =  12801.841651982579
# RUN  5 , total integrated cost =  12801.841651982504
# RUN  6 , total integrated cost =  12801.841651982495
# RUN  7 , total integrated cost =  12801.841651982495
# Control only changes marginally.
# RUN  7 , total integrated cost =  12801.841651982495
# Improved over  7  iterations in  2.6064404169883346  seconds by  3.126993135538214e-07  percent.
# cost splitting :  0.0040616033322883 [2.01157922e-16 3.34023227e+00]
# --------------------- 1
# set cost params:  1.0 0.0 3832.608616307465
# interpolate adjoint :  True True True
# initial cost =  12801.843263641265
# RUN  0 , total integrated cost =  12801.843263641265
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.843263641265
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.843263641265
# Improved over  1  iterations in  0.5026263230101904  seconds by  0.0  percent.
# cost splitting :  0.0040616033322883 [2.01157922e-16 3.34023227e+00]
# 20 1794 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 3832.608616307465
# interpolate adjoint :  True True True
# initial cost =  12801.841448029978
# RUN  0 , total integrated cost =  12801.841448029978
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.841408958842
# RUN  2 , total integrated cost =  12801.841408868791
# RUN  3 , total integrated cost =  12801.841408865133
# RUN  4 , total integrated cost =  12801.841408864664
# RUN  5 , total integrated cost =  12801.841408864519
# RUN  6 , total integrated cost =  12801.841408864459
# RUN  7 , total integrated cost =  12801.84140886444
# RUN  8 , total integrated cost =  12801.841408864431
# RUN  9 , total integrated cost =  12801.841408864431
# Control only changes marginally.
# RUN  9 , total integrated cost =  12801.841408864431
# Improved over  9  iterations in  3.312088416001643  seconds by  3.0593682254220766e-07  percent.
# cost splitting :  0.0040278695065062795 [2.01157922e-16 3.34023187e+00]
# --------------------- 1
# set cost params:  1.0 0.0 3832.609087501351
# interpolate adjoint :  True True True
# initial cost =  12801.842982761265
# RUN  0 , total integrated cost =  12801.842982761265
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.842982761265
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.842982761265
# Improved over  1  iterations in  0.4832149889989523  seconds by  0.0  percent.
# cost splitting :  0.0040278695065062795 [2.01157922e-16 3.34023187e+00]
# 20 1795 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 3832.609087501351
# interpolate adjoint :  True True True
# initial cost =  12801.841181346288
# RUN  0 , total integrated cost =  12801.841181346288
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.841141804145
# RUN  2 , total integrated cost =  12801.841141783892
# RUN  3 , total integrated cost =  12801.84114178327
# RUN  4 , total integrated cost =  12801.84114178322
# RUN  5 , total integrated cost =  12801.841141783218
# RUN  6 , total integrated cost =  12801.841141783209
# RUN  7 , total integrated cost =  12801.841141783209
# Control only changes marginally.
# RUN  7 , total integrated cost =  12801.841141783209
# Improved over  7  iterations in  2.7038943840016145  seconds by  3.0904210746030003e-07  percent.
# cost splitting :  0.004002807277347604 [2.01157922e-16 3.34023145e+00]
# --------------------- 1
# set cost params:  1.0 0.0 3832.609577647857
# interpolate adjoint :  True True True
# initial cost =  12801.842778985982
# RUN  0 , total integrated cost =  12801.842778985982
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.842778985982
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.842778985982
# Improved over  1  iterations in  0.5814988399943104  seconds by  0.0  percent.
# cost splitting :  0.004002807277347604 [2.01157922e-16 3.34023145e+00]
# 20 1796 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 3832.609577647857
# interpolate adjoint :  True True True
# initial cost =  12801.840987903208
# RUN  0 , total integrated cost =  12801.840987903208
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.840951997136
# RUN  2 , total integrated cost =  12801.840951920616
# RUN  3 , total integrated cost =  12801.840951917144
# RUN  4 , total integrated cost =  12801.84095191686
# RUN  5 , total integrated cost =  12801.840951916827
# RUN  6 , total integrated cost =  12801.840951916818
# RUN  7 , total integrated cost =  12801.840951916814
# RUN  8 , total integrated cost =  12801.840951916809
# RUN  9 , total integrated cost =  12801.840951916809
# Control only changes marginally.
# RUN  9 , total integrated cost =  12801.840951916809
# Improved over  9  iterations in  3.5380629830033286  seconds by  2.81103311294828e-07  percent.
# cost splitting :  0.003970766403578358 [2.01157922e-16 3.34023105e+00]
# --------------------- 1
# set cost params:  1.0 0.0 3832.610044887412
# interpolate adjoint :  True True True
# initial cost =  12801.842512604879
# RUN  0 , total integrated cost =  12801.842512604879
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.842512604873
# RUN  2 , total integrated cost =  12801.842512604873
# Control only changes marginally.
# RUN  2 , total integrated cost =  12801.842512604873
# Improved over  2  iterations in  0.9618283279996831  seconds by  4.263256414560601e-14  percent.
# cost splitting :  0.003970766399857839 [2.01157922e-16 3.34023105e+00]
# --------------------- 2
# set cost params:  1.0 0.0 3832.610044887403
# interpolate adjoint :  True True True
# initial cost =  12801.842512604844
# RUN  0 , total integrated cost =  12801.842512604844
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.842512604844
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.842512604844
# Improved over  1  iterations in  0.5952775819896488  seconds by  0.0  percent.
# cost splitting :  0.003970766399857839 [2.01157922e-16 3.34023105e+00]
# 20 1797 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 3832.610044887403
# interpolate adjoint :  True True True
# initial cost =  12801.840734978881
# RUN  0 , total integrated cost =  12801.840734978881
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.840698975691
# RUN  2 , total integrated cost =  12801.840698974687
# RUN  3 , total integrated cost =  12801.840698974494
# RUN  4 , total integrated cost =  12801.84069897446
# RUN  5 , total integrated cost =  12801.840698974444
# RUN  6 , total integrated cost =  12801.840698974434
# RUN  7 , total integrated cost =  12801.840698974434
# Control only changes marginally.
# RUN  7 , total integrated cost =  12801.840698974434
# Improved over  7  iterations in  3.1895741789921885  seconds by  2.8124429718445754e-07  percent.
# cost splitting :  0.003934675861943259 [2.01157922e-16 3.34023066e+00]
# --------------------- 1
# set cost params:  1.0 0.0 3832.6104971691284
# interpolate adjoint :  True True True
# initial cost =  12801.84220969972
# RUN  0 , total integrated cost =  12801.84220969972
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.84220969972
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.84220969972
# Improved over  1  iterations in  0.5574916820041835  seconds by  0.0  percent.
# cost splitting :  0.003934675861943259 [2.01157922e-16 3.34023066e+00]
# 20 1798 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 3832.6104971691284
# interpolate adjoint :  True True True
# initial cost =  12801.840447350882
# RUN  0 , total integrated cost =  12801.840447350882
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.840409283837
# RUN  2 , total integrated cost =  12801.840409278711
# RUN  3 , total integrated cost =  12801.840409278171
# RUN  4 , total integrated cost =  12801.840409278077
# RUN  5 , total integrated cost =  12801.840409278055
# RUN  6 , total integrated cost =  12801.840409278055
# Control only changes marginally.
# RUN  6 , total integrated cost =  12801.840409278055
# Improved over  6  iterations in  2.623936574003892  seconds by  2.97401200555214e-07  percent.
# cost splitting :  0.0039026453252772294 [2.01157922e-16 3.34023027e+00]
# --------------------- 1
# set cost params:  1.0 0.0 3832.610956261804
# interpolate adjoint :  True True True
# initial cost =  12801.841942753306
# RUN  0 , total integrated cost =  12801.841942753306
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.841942753306
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.841942753306
# Improved over  1  iterations in  0.5072591569914948  seconds by  0.0  percent.
# cost splitting :  0.0039026453252772294 [2.01157922e-16 3.34023027e+00]
# 20 1799 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 3832.610956261804
# interpolate adjoint :  True True True
# initial cost =  12801.840193877215
# RUN  0 , total integrated cost =  12801.840193877215
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.840155554035
# RUN  2 , total integrated cost =  12801.840155553431
# RUN  3 , total integrated cost =  12801.840155553382
# RUN  4 , total integrated cost =  12801.840155553373
# RUN  5 , total integrated cost =  12801.840155553373
# Control only changes marginally.
# RUN  5 , total integrated cost =  12801.840155553373
# Improved over  5  iterations in  1.8188346800016006  seconds by  2.9936198586710816e-07  percent.
# cost splitting :  0.00387294979437622 [2.01157922e-16 3.34022988e+00]
# --------------------- 1
# set cost params:  1.0 0.0 3832.611417557508
# interpolate adjoint :  True True True
# initial cost =  12801.841696387064
# RUN  0 , total integrated cost =  12801.841696387064
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.841696387064
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.841696387064
# Improved over  1  iterations in  0.5023897879873402  seconds by  0.0  percent.
# cost splitting :  0.00387294979437622 [2.01157922e-16 3.34022988e+00]

# %%
i = 20
for j in range(1500,1800,50):
    print("simulation duration = ", round(d_array[j],1))
    print("cost splitting: ", costnode_[i][j][0][0][0], costnode_[i][j][2][0][:2])
    print("total cost: ", sum(costnode_[i][j][0][0][:] + costnode_[i][j][2][0][:2]) )
    aln.params.duration = round(d_array[j],1)
    time_ = np.arange(-dur_pre,round(d_array[j]+dur_post+aln.params.dt,1),aln.params.dt)
    dur += dur_pre + dur_post
    target_e = [target[i][0]] * len(time_)
    target_i = [target[i][1]] * len(time_)

    fig, ax = plt.subplots(2,1, constrained_layout=True, figsize = (4,4) )
    ax[1].plot(time_, bestControl_[i][j][0,0,:], color = 'red')
    ax[0].plot(time_, bestState_[i][j][0,0,:], color= 'red')
    ax[1].plot(time_, bestControl_[i][j][0,1,:], color = 'blue')
    ax[0].plot(time_, bestState_[i][j][0,1,:], color= 'blue')
    ax[0].plot(time_, target_e, linestyle = '--', color='red')
    ax[0].plot(time_, target_i, linestyle = '--', color='blue')
    ax[0].set_xlim(-dur_pre,round(d_array[j]+dur_pre,1))
    ax[1].set_xlim(-dur_pre,round(d_array[j]+dur_pre,1))
    ax[0].axvspan(t0_array[j], t0_array[j]+20, alpha=0.2, color='gray')
    plt.show()
# Out:
# simulation duration =  170.0
# cost splitting:  0.04098424791333283 [1.62060184e-16 3.34101065e+00]
# total cost:  3.381994894544665
# simulation duration =  175.0
# cost splitting:  0.027665739930548723 [2.35609704e-16 3.34085965e+00]
# total cost:  3.368525388188044
# simulation duration =  180.0
# cost splitting:  0.018148897827891267 [1.83127433e-16 3.34058930e+00]
# total cost:  3.3587381994039176
# simulation duration =  185.0
# cost splitting:  0.012256975997409228 [1.33097429e-16 3.34051822e+00]
# total cost:  3.35277519693506
# simulation duration =  190.0
# cost splitting:  0.00845843277919552 [2.10348160e-16 3.34029271e+00]
# total cost:  3.3487511410443505
# simulation duration =  195.0
# cost splitting:  0.00570256692431097 [1.94268616e-16 3.34025295e+00]
# total cost:  3.3459555121278264
