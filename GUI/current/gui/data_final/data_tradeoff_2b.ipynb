# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import sys
import pickle

path = os.getcwd().split(os.sep + 'GUI')[0]
if path not in sys.path:
    print("not here")
    sys.path.append(path)

from neurolib.models.aln import ALNModel
from neurolib.utils import plotFunctions as plotFunc
from neurolib.utils import costFunctions as cost
import neurolib.dashboard.functions as functions
import neurolib.dashboard.data as data
    
# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2 

#path = os.path.join(os.getcwd(), "plots")
# Out:
# not here

# %% [markdown]
# ### Bistability

# %%
aln = ALNModel()
N = aln.params.N

data.set_parameters(aln)

state_vars = aln.state_vars
init_vars = aln.init_vars

##############################################################
def setinit(init_vars_, model):
    state_vars = model.state_vars
    init_vars = model.init_vars
    for iv in range(len(init_vars)):
        for sv in range(len(state_vars)):
            if state_vars[sv] in init_vars[iv]:
                #print("set init vars ", )
                if model.params[init_vars[iv]].ndim == 2:
                    model.params[init_vars[iv]][0,:] = init_vars_[sv]
                else:
                    model.params[init_vars[iv]][0] = init_vars_[sv]
                    
##############################################################               
def setmaxmincontrol(max_c_c, min_c_c, max_c_r, min_c_r):
    import numpy as np
    
    max_cntrl = np.zeros(( 6 ))
    min_cntrl = np.zeros(( 6 ))
    
    max_cntrl[0] = max_c_c
    min_cntrl[0] = min_c_c
    max_cntrl[1] = max_c_c
    min_cntrl[1] = min_c_c
    max_cntrl[2] = max_c_r
    min_cntrl[2] = min_c_r
    max_cntrl[3] = max_c_r
    min_cntrl[3] = min_c_r
    max_cntrl[4] = max_c_r
    min_cntrl[4] = min_c_r
    max_cntrl[5] = max_c_r
    min_cntrl[5] = min_c_r
            
    return max_cntrl, min_cntrl

# %%
##### LOAD BOUNDARIES
data_file = 'bi.pickle'
with open(data_file,'rb') as f:
    load_array= pickle.load(f)
exc = load_array[0]
inh = load_array[1]
print(len(exc))
# Out:
# 147

# %%
t0_array = np.arange(380., -1, -1.)
t_pen = t0_array / 400.

bestControl_1 = [None] * len(t_pen)
bestState_1 = [None] * len(t_pen)
cost_1 = [None] * len(t_pen)
runtime_1 = [None] * len(t_pen)
grad_1 = [None] * len(t_pen)
phi_1 = [None] * len(t_pen)
costnode_1 = [None] * len(t_pen)
weights_1 = [None] * len(t_pen)

# %%
initVars = [None] * len(exc)
target = [None] * len(exc)
cost_uncontrolled = [None] * len(exc)

cgv_list = [None, "HS", "FR", "PR", "CD", "LS", "DY", "WYL", "HZ", None]

# %%
dur_pre = 10
dur_post = 10

i = 50

n_pre = int(np.around(dur_pre/aln.params.dt + 1.,1))
n_post = int(np.around(dur_post/aln.params.dt + 1.,1))

tol = 1e-32
start_step = 10.
c_scheme = np.zeros(( 1,1 ))
c_scheme[0,0] = 1.
u_mat = np.identity(1)
u_scheme = np.array([[1.]])

c_var = [ [0], [1], [0,1]]
p_var = [ [0], [0], [0]]

### CURRENTS
cntrl_vars_0 = [0,1]
prec_vars = [0]

max_I = [3., -3.]
factor_wp = 1. / 0.05
factor_ws = 0.
factor_we = 1.
dur = 400
trans_time = 0.95
    
maxC = [5., -5., 0.18, 0.]

n_dur = int(np.around(dur/aln.params.dt + 1.,1))
max_cntrl, min_cntrl = setmaxmincontrol(maxC[0], maxC[1], maxC[2], maxC[3])

# %%
init_file = 'control_2.pickle'
final_file_1 = 'control_tradeoff_2b.pickle'

# %%
if os.path.isfile(init_file) :
    print("init file found")
    
    with open(init_file,'rb') as f:
        load_array = pickle.load(f)

    print(len(load_array[0]))

    bestControl_1[0] = load_array[0][i]
    bestState_1[0] = load_array[1][i]
    cost_1 [0]= load_array[2][i]
    runtime_1[0] = load_array[3][i]
    grad_1 [0]= load_array[4][i]
    phi_1[0] = load_array[5][i]
    costnode_1[0] = load_array[6][i]
    weights_1[0] = load_array[7][i]
# Out:
# init file found
# 147

# %%
if os.path.isfile(final_file_1) :
    print("final file found")
    
    with open(final_file_1,'rb') as f:
        load_array = pickle.load(f)

    print(len(load_array[0]))

    bestControl_1 = load_array[0]
    bestState_1 = load_array[1]
    cost_1 = load_array[2]
    runtime_1 = load_array[3]
    grad_1 = load_array[4]
    phi_1 = load_array[5]
    costnode_1 = load_array[6]
    weights_1 = load_array[7]

# %%
# get initial parameters and target states

print("------- ", i, exc[i], inh[i])
aln.params.ext_exc_current = exc[i] * 5.
aln.params.ext_inh_current = inh[i] * 5.

aln.params.duration = 3000.

control0 = aln.getZeroControl()
control0 = functions.step_control(aln, maxI_ = max_I[0])

aln.run(control=control0)

target_rates = np.zeros((2))
target_rates[0] = aln.rates_exc[0,-1] 
target_rates[1] = aln.rates_inh[0,-1]

control0 = functions.step_control(aln, maxI_ = max_I[1])
aln.run(control=control0)

init_state_vars = np.zeros(( len(state_vars) ))
for j in range(len(state_vars)):
    if aln.state[state_vars[j]].size == 1:
        init_state_vars[j] = aln.state[state_vars[j]][0]
    else:
        init_state_vars[j] = aln.state[state_vars[j]][0,-1]

initVars[i] = init_state_vars

aln.params.duration = dur

target[i] = aln.getZeroTarget()
target[i][:,0,:] = target_rates[0]
target[i][:,1,:] = target_rates[1]
# Out:
# -------  50 0.47500000000000014 0.6000000000000003

# %%
# get uncontrolled cost

data.set_parameters(aln)
aln.params.ext_exc_current = exc[i] * 5.
aln.params.ext_inh_current = inh[i] * 5.
aln.params.duration = dur

cgv = None

# %%
print(np.argmax(np.abs(bestControl_1[0]), axis=2))
print(bestControl_1[0][0,0,1650:1700]/5.)
print(bestControl_1[0][0,0,1674]/5.)

max_percent = (np.argmax(np.abs(bestControl_1[0]), axis=2)[0,0] -100) / 3800
print(max_percent)
# Out:
# [[1598 1546    0    0    0    0]]
# [0.15017195 0.14919272 0.14823187 0.14727697 0.14633858 0.14537923
#  0.14443629 0.14331204 0.14221236 0.14113332 0.14005669 0.13899877
#  0.1379408  0.13688459 0.13584404 0.13482264 0.13382036 0.13279856
#  0.1317934  0.13080617 0.12983707 0.12887027 0.1279198  0.12698051
#  0.12605777 0.12515148 0.12407316 0.12299684 0.12193738 0.12089338
#  0.11983845 0.11879648 0.11776968 0.11675683 0.11574677 0.11475066
#  0.11376807 0.11280113 0.1118507  0.11091606 0.10999628 0.10907247
#  0.10815928 0.10726081 0.10637676 0.10548422 0.10460328 0.10373605
#  0.10288035 0.10202751]
# 0.12605777100697313
# 0.39421052631578946

# %%
factor_iteration = 1.

##### initial guess
weight_ = 1.
cost.setParams(weight_ * factor_wp, weight_ * factor_we, weight_ * factor_ws)

setinit(initVars[i], aln)

weights_1[0] = cost.getParams()

for j in range(1, 381):

    dur = 400. - np.around(j/10., 1)
    T = 4001 - j
    aln.params.duration = dur

    factor_wp = dur / 20.
    cost.setParams(weight_ * factor_wp, weight_ * factor_we, weight_ * factor_ws)

    print('-----', j)
    setinit(initVars[i], aln)

    max_it = 3.
    if j > 170:
        max_it = 40.
    elif j > 140:
        max_it = 30.
    elif j > 100.:
        max_it = 20.
    
    if type(bestControl_1[j]) == type(None):
        total_shift = round(j * max_percent * 10)
        prev_shift = round( (j-1) * max_percent * 10)
        shift_ind = total_shift - prev_shift
        #print(total_shift, prev_shift, shift_ind)
        control0 = np.zeros(( bestControl_1[j-1][:,:,100:-101].shape ))
        control0[:,:,:-shift_ind] = 1. * bestControl_1[j-1][:,:,100+shift_ind:-101]
    else:
        if bestControl_1[j].shape[2] == T+200:
            control0 = bestControl_1[j][:,:,100:-100]
        else:
            control0 = bestControl_1[j][:,:,100:-(100+j)]

    bestControl_1[j], bestState_1[j], cost_1[j], runtime_1[j], grad_1[j], phi_1[j], costnode_1[j] = aln.A1(
        control0, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = [0,1],
        prec_variables_ = prec_vars, transition_time_ = t_pen[j])

    print(costnode_1[j][0][0][0], costnode_1[j][2][0][1])

    print(costnode_1[0][0][0][0], costnode_1[0][2][0][1])
        
    with open(final_file_1,'wb') as f:
        pickle.dump([bestControl_1, bestState_1, cost_1, runtime_1, grad_1, phi_1,
                costnode_1, weights_1], f)
# Out:
# set cost params:  20.0 1.0 0.0
# set cost params:  19.994999999999997 1.0 0.0
# ----- 1
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  334729.3192492649
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.01942994073995
# RUN  2 , total integrated cost =  11.019427959902716
# RUN  3 , total integrated cost =  11.019427959832004
# RUN  3 , total integrated cost =  11.019427959832004
# Improved over  3  iterations in  18.279196019000665  seconds by  99.99670795854257  percent.
# 7.21356118423157e-07 1.9830238921708963
# 4.058942200395397e-07 1.9830238693113347
# set cost params:  19.990000000000002 1.0 0.0
# ----- 2
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  348987.1014406777
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.019439269775763
# RUN  2 , total integrated cost =  11.019434890641492
# RUN  3 , total integrated cost =  11.019434890478411
# RUN  3 , total integrated cost =  11.019434890478411
# Improved over  3  iterations in  1.2581108400008816  seconds by  99.99684245210067  percent.
# 1.0596544754225412e-06 1.9830240235819507
# 4.058942200395397e-07 1.9830238693113347
# set cost params:  19.985 1.0 0.0
# ----- 3
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  364830.8084054655
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.019443915106388
# RUN  2 , total integrated cost =  11.019442886535584
# RUN  3 , total integrated cost =  11.01944288537846
# RUN  3 , total integrated cost =  11.01944288537846
# Improved over  3  iterations in  1.3973934030000237  seconds by  99.99697957446809  percent.
# 1.4509491727314253e-06 1.9830241584513737
# 4.058942200395397e-07 1.9830238693113347
# set cost params:  19.98 1.0 0.0
# ----- 4
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  380666.5434386294
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.019450617596943
# RUN  2 , total integrated cost =  11.019449918538388
# RUN  3 , total integrated cost =  11.01944991850155
# RUN  3 , total integrated cost =  11.01944991850155
# Improved over  3  iterations in  1.5122181289989385  seconds by  99.99710522237679  percent.
# 1.7939273646119593e-06 1.9830242986127602
# 4.058942200395397e-07 1.9830238693113347
# set cost params:  19.975 1.0 0.0
# ----- 5
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  396494.30670732394
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.019456356714729
# RUN  2 , total integrated cost =  11.01945573127269
# RUN  3 , total integrated cost =  11.019455731195858
# RUN  3 , total integrated cost =  11.019455731195858
# Improved over  3  iterations in  1.421068915999058  seconds by  99.9972207783202  percent.
# 2.07559458944644e-06 1.9830244440689093
# 4.058942200395397e-07 1.9830238693113347
# set cost params:  19.97 1.0 0.0
# ----- 6
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  412314.09821850766
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.01946104244174
# RUN  2 , total integrated cost =  11.019460446665994
# RUN  3 , total integrated cost =  11.019460446654927
# RUN  3 , total integrated cost =  11.019460446654927
# Improved over  3  iterations in  1.1747064199989836  seconds by  99.99732741119107  percent.
# 2.3020758431977857e-06 1.9830245963339428
# 4.058942200395397e-07 1.9830238693113347
# set cost params:  19.965 1.0 0.0
# ----- 7
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  428125.91795303364
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.019465034108556
# RUN  2 , total integrated cost =  11.019464354194584
# RUN  3 , total integrated cost =  11.019464354142679
# RUN  3 , total integrated cost =  11.019464354142679
# Improved over  3  iterations in  1.207166075000714  seconds by  99.99742611603455  percent.
# 2.487795444676386e-06 1.9830247556979494
# 4.058942200395397e-07 1.9830238693113347
# set cost params:  19.96 1.0 0.0
# ----- 8
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  443929.76583577396
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.01946843496236
# RUN  2 , total integrated cost =  11.019467710132446
# RUN  3 , total integrated cost =  11.019467709989321
# RUN  3 , total integrated cost =  11.019467709989321
# Improved over  3  iterations in  1.2225109870014421  seconds by  99.99751774524755  percent.
# 2.6455237754090206e-06 1.983024921580861
# 4.058942200395397e-07 1.9830238693113347
# set cost params:  19.955000000000002 1.0 0.0
# ----- 9
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  459725.5935014769
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.019470915006657
# RUN  2 , total integrated cost =  11.019470910990023
# RUN  3 , total integrated cost =  11.019470909283983
# RUN  3 , total integrated cost =  11.019470909283983
# Improved over  3  iterations in  1.1729330140005914  seconds by  99.99760303296901  percent.
# 2.796423980023046e-06 1.9830249446345662
# 4.058942200395397e-07 1.9830238693113347
# set cost params:  19.95 1.0 0.0
# ----- 10
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  475513.5427560343
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.01947336638951
# RUN  2 , total integrated cost =  11.019473314096485
# RUN  3 , total integrated cost =  11.019468859231374
# RUN  3 , total integrated cost =  11.019468859231374
# Improved over  3  iterations in  1.4023355379977147  seconds by  99.99768261724043  percent.
# 1.1465014578022773e-06 1.9830249382032954
# 4.058942200395397e-07 1.9830238693113347
# set cost params:  19.945 1.0 0.0
# ----- 11
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11.019468788295692
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.019436202594333
# RUN  2 , total integrated cost =  11.019433286771577
# RUN  3 , total integrated cost =  11.019433259727634
# RUN  3 , total integrated cost =  11.019433259727634
# Improved over  3  iterations in  1.664971948001039  seconds by  0.00032241634093566063  percent.
# 9.105134100123154e-07 1.9830249325067444
# 4.058942200395397e-07 1.9830238693113347
# set cost params:  19.94 1.0 0.0
# ----- 12
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  507065.4188808873
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.019434123965166
# RUN  2 , total integrated cost =  11.019434109976858
# RUN  3 , total integrated cost =  11.01943410974746
# RUN  3 , total integrated cost =  11.01943410974746
# Improved over  3  iterations in  1.4836463399988133  seconds by  99.99782682200374  percent.
# 9.391668252711081e-07 1.983025028186984
# 4.058942200395397e-07 1.9830238693113347
# set cost params:  19.935 1.0 0.0
# ----- 13
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  522829.40105128236
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.019434876128798
# RUN  2 , total integrated cost =  11.019434839405225
# RUN  3 , total integrated cost =  11.019434838966431
# RUN  3 , total integrated cost =  11.019434838966431
# Improved over  3  iterations in  1.5386496640021505  seconds by  99.99789234598957  percent.
# 9.623546434598821e-07 1.9830252325172486
# 4.058942200395397e-07 1.9830238693113347
# set cost params:  19.93 1.0 0.0
# ----- 14
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  536996.6944888947
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.019435455657657
# RUN  2 , total integrated cost =  11.019435454093774
# RUN  3 , total integrated cost =  11.019435453483103
# RUN  3 , total integrated cost =  11.019435453483103
# Improved over  3  iterations in  1.1802443619999394  seconds by  99.99794795097128  percent.
# 9.7794899628783e-07 1.983025335048042
# 4.058942200395397e-07 1.9830238693113347
# set cost params:  19.925 1.0 0.0
# ----- 15
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  552745.1252007806
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.019436040123306
# RUN  2 , total integrated cost =  11.019436033490594
# RUN  3 , total integrated cost =  11.01943490044894
# RUN  3 , total integrated cost =  11.01943490044894
# Improved over  3  iterations in  1.0189671439984522  seconds by  99.99800641662893  percent.
# 5.258540338311836e-07 1.9830255523392
# 4.058942200395397e-07 1.9830238693113347
# set cost params:  19.919999999999998 1.0 0.0
# ----- 16
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11.019434755141493
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.019426341852196
# RUN  2 , total integrated cost =  11.019426255280548
# RUN  3 , total integrated cost =  11.019426254450774
# RUN  3 , total integrated cost =  11.019426254450774
# Improved over  3  iterations in  0.9981359749981493  seconds by  7.714271110614845e-05  percent.
# 4.937117917878965e-07 1.9830248507815624
# 4.058942200395397e-07 1.9830238693113347
# set cost params:  19.915 1.0 0.0
# ----- 17
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  584218.007674522
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.019426678085722
# RUN  2 , total integrated cost =  11.01942667627005
# RUN  3 , total integrated cost =  11.019426674088102
# RUN  3 , total integrated cost =  11.019426674088102
# Improved over  3  iterations in  1.2591775669970957  seconds by  99.9981138159849  percent.
# 4.989481395106684e-07 1.983025084837104
# 4.058942200395397e-07 1.9830238693113347
# set cost params:  19.91 1.0 0.0
# ----- 18
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  599942.4851806952
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.019427097244932
# RUN  2 , total integrated cost =  11.019427090112162
# RUN  3 , total integrated cost =  11.019427086834309
# RUN  3 , total integrated cost =  11.019427086834309
# Improved over  3  iterations in  1.0106858550025208  seconds by  99.99816325275188  percent.
# 5.020864567205611e-07 1.9830253377117892
# 4.058942200395397e-07 1.9830238693113347
# set cost params:  19.905 1.0 0.0
# ----- 19
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  615658.81357044
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.01942750627691
# RUN  2 , total integrated cost =  11.019427503858388
# RUN  3 , total integrated cost =  11.01942750170796
# RUN  3 , total integrated cost =  11.01942750170796
# Improved over  3  iterations in  1.3886242549997405  seconds by  99.99821014054233  percent.
# 5.055621186596235e-07 1.9830255875323535
# 4.058942200395397e-07 1.9830238693113347
# set cost params:  19.9 1.0 0.0
# ----- 20
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  631367.0922115172
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.019427934505725
# RUN  2 , total integrated cost =  11.019427917445224
# RUN  3 , total integrated cost =  11.019427911117823
# RUN  3 , total integrated cost =  11.019427911117823
# Improved over  3  iterations in  1.0340515339994454  seconds by  99.99825467179917  percent.
# 5.073750854766038e-07 1.983025862455874
# 4.058942200395397e-07 1.9830238693113347
# set cost params:  19.895 1.0 0.0
# ----- 21
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  645478.7965985829
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.01942832319394
# RUN  2 , total integrated cost =  11.019428319916692
# RUN  3 , total integrated cost =  11.019428316316214
# RUN  3 , total integrated cost =  11.019428316316214
# Improved over  3  iterations in  1.006821826002124  seconds by  99.99829282876922  percent.
# 5.106300397538787e-07 1.9830261149802653
# 4.058942200395397e-07 1.9830238693113347
# set cost params:  19.89 1.0 0.0
# ----- 22
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  661173.5566970076
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.019428753630676
# RUN  2 , total integrated cost =  11.019428745919411
# RUN  3 , total integrated cost =  11.019428736034854
# RUN  3 , total integrated cost =  11.019428736034854
# Improved over  3  iterations in  1.4387242989978404  seconds by  99.99833335307736  percent.
# 5.129886325613705e-07 1.9830264081847528
# 4.058942200395397e-07 1.9830238693113347
# set cost params:  19.884999999999998 1.0 0.0
# ----- 23
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  676856.3018032097
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.019429173000097
# RUN  2 , total integrated cost =  11.019429161824611
# RUN  3 , total integrated cost =  11.01942915463821
# RUN  3 , total integrated cost =  11.01942915463821
# Improved over  3  iterations in  1.5825319760006096  seconds by  99.99837196918678  percent.
# 5.112980925042733e-07 1.9830267276327926
# 4.058942200395397e-07 1.9830238693113347
# set cost params:  19.880000000000003 1.0 0.0
# ----- 24
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12.315722677731813
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.01942960942691
# RUN  2 , total integrated cost =  11.019429596786697
# RUN  3 , total integrated cost =  11.019429588155427
# RUN  3 , total integrated cost =  11.019429588155427
# Improved over  3  iterations in  1.4661346190005133  seconds by  10.52551379644352  percent.
# 5.117776177705283e-07 1.9830270363196947
# 4.058942200395397e-07 1.9830238693113347
# set cost params:  19.875 1.0 0.0
# ----- 25
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11.101255450144125
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.01943005082737
# RUN  2 , total integrated cost =  11.01943004414007
# RUN  3 , total integrated cost =  11.019430038275345
# RUN  3 , total integrated cost =  11.019430038275345
# Improved over  3  iterations in  1.3745931639969058  seconds by  0.7370825059945503  percent.
# 5.129474731900361e-07 1.9830273450884943
# 4.058942200395397e-07 1.9830238693113347
# set cost params:  19.869999999999997 1.0 0.0
# ----- 26
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11.019543451065235
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.019430425670382
# RUN  2 , total integrated cost =  11.019430418077071
# RUN  3 , total integrated cost =  11.01943041128961
# RUN  3 , total integrated cost =  11.01943041128961
# Improved over  3  iterations in  1.5892194519983605  seconds by  0.0010258117872865569  percent.
# 5.139997105888437e-07 1.9830275973250728
# 4.058942200395397e-07 1.9830238693113347
# set cost params:  19.865000000000002 1.0 0.0
# ----- 27
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11.027322988762162
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.019430898250143
# RUN  2 , total integrated cost =  11.019430881094179
# RUN  3 , total integrated cost =  11.019430865110927
# RUN  3 , total integrated cost =  11.019430865110927
# Improved over  3  iterations in  1.151289760000509  seconds by  0.07156880830713419  percent.
# 5.116612777485078e-07 1.9830279486284341
# 4.058942200395397e-07 1.9830238693113347
# set cost params:  19.86 1.0 0.0
# ----- 28
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11.020556963244768
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.01943136624112
# RUN  2 , total integrated cost =  11.019428556955242
# RUN  3 , total integrated cost =  11.019423599496204
# RUN  3 , total integrated cost =  11.019423599496204
# Improved over  3  iterations in  1.386130528000649  seconds by  0.010284087749326432  percent.
# 1.607130424572021e-07 1.983028269583777
# 4.058942200395397e-07 1.9830238693113347
# set cost params:  19.855 1.0 0.0
# ----- 29
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11.447052875650362
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.01942406634336
# RUN  2 , total integrated cost =  11.019424060487477
# RUN  3 , total integrated cost =  11.019424056276128
# RUN  3 , total integrated cost =  11.019424056276128
# Improved over  3  iterations in  1.2657577019999735  seconds by  3.735711051740381  percent.
# 1.531979127536132e-07 1.9830286852876235
# 4.058942200395397e-07 1.9830238693113347
# set cost params:  19.85 1.0 0.0
# ----- 30
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11.020894456783829
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.019424603661205
# RUN  2 , total integrated cost =  11.019424593626718
# RUN  3 , total integrated cost =  11.019424588362495
# RUN  3 , total integrated cost =  11.019424588362495
# Improved over  3  iterations in  1.144145687998389  seconds by  0.013337106412706135  percent.
# 1.533852944641214e-07 1.9830290704392506
# 4.058942200395397e-07 1.9830238693113347
# set cost params:  19.845 1.0 0.0
# ----- 31
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11.020215908437882
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.019425155024066
# RUN  2 , total integrated cost =  11.019425122101666
# RUN  3 , total integrated cost =  11.01942509074196
# RUN  3 , total integrated cost =  11.01942509074196
# Improved over  3  iterations in  1.3440102669992484  seconds by  0.0071760635407969176  percent.
# 1.5356897961362957e-07 1.9830295292708762
# 4.058942200395397e-07 1.9830238693113347
# set cost params:  19.84 1.0 0.0
# ----- 32
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11.020191188442064
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.019425668149001
# RUN  2 , total integrated cost =  11.019425660720637
# RUN  3 , total integrated cost =  11.019425651683491
# RUN  3 , total integrated cost =  11.019425651683491
# Improved over  3  iterations in  1.4567972219992953  seconds by  0.0069466740229984225  percent.
# 1.5412082156944587e-07 1.9830299593241347
# 4.058942200395397e-07 1.9830238693113347
# set cost params:  19.835 1.0 0.0
# ----- 33
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11.020051048473226
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.019426264347436
# RUN  2 , total integrated cost =  11.019426241316959
# RUN  3 , total integrated cost =  11.019426216248327
# RUN  3 , total integrated cost =  11.019426216248327
# Improved over  3  iterations in  1.1208959609975864  seconds by  0.005669957626793121  percent.
# 1.5377874640349372e-07 1.9830304457423353
# 4.058942200395397e-07 1.9830238693113347
# set cost params:  19.830000000000002 1.0 0.0
# ----- 34
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11.019846672773838
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.019426851839041
# RUN  2 , total integrated cost =  11.019426847868125
# RUN  3 , total integrated cost =  11.01942684445798
# RUN  3 , total integrated cost =  11.01942684445798
# Improved over  3  iterations in  0.9739362700020138  seconds by  0.00380974734335382  percent.
# 1.5445372880070147e-07 1.9830308860446475
# 4.058942200395397e-07 1.9830238693113347
# set cost params:  19.825 1.0 0.0
# ----- 35
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11.01972796997847
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.019427512468294
# RUN  2 , total integrated cost =  11.019427504763689
# RUN  3 , total integrated cost =  11.019427500594976
# RUN  3 , total integrated cost =  11.019427500594976
# Improved over  3  iterations in  0.8897354130021995  seconds by  0.0027266497350240115  percent.
# 1.5730192889133994e-07 1.9830313426793145
# 4.058942200395397e-07 1.9830238693113347
# set cost params:  19.82 1.0 0.0
# ----- 36
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11.019797998661607
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.019428186319622
# RUN  2 , total integrated cost =  11.019428178497837
# RUN  3 , total integrated cost =  11.019428169753036
# RUN  3 , total integrated cost =  11.019428169753036
# Improved over  3  iterations in  0.9885642270019162  seconds by  0.0033560407242987367  percent.
# 1.5747950012785755e-07 1.9830318196765215
# 4.058942200395397e-07 1.9830238693113347
# set cost params:  19.815 1.0 0.0
# ----- 37
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11.019676354730121
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.019428867428974
# RUN  2 , total integrated cost =  11.019428857741765
# RUN  3 , total integrated cost =  11.019428844543702
# RUN  3 , total integrated cost =  11.019428844543702
# Improved over  3  iterations in  1.0749326080003812  seconds by  0.0022460749159165516  percent.
# 1.5341235436647792e-07 1.9830323373755596
# 4.058942200395397e-07 1.9830238693113347
# set cost params:  19.81 1.0 0.0
# ----- 38
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11.019523648235634
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.019429586601508
# RUN  2 , total integrated cost =  11.01942958204993
# RUN  3 , total integrated cost =  11.019429306700205
# RUN  3 , total integrated cost =  11.019429306700205
# Improved over  3  iterations in  0.9346787009999389  seconds by  0.0008561307951282515  percent.
# 1.7467572021191228e-07 1.9830325069453016
# 4.058942200395397e-07 1.9830238693113347
# set cost params:  19.805 1.0 0.0
# ----- 39
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11.021635807037788
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.019429907741843
# RUN  2 , total integrated cost =  11.019429899907692
# RUN  3 , total integrated cost =  11.019429894420016
# RUN  3 , total integrated cost =  11.019429894420016
# Improved over  3  iterations in  1.1476498960000754  seconds by  0.020014384946037467  percent.
# 1.5752940094397598e-07 1.9830331566267643
# 4.058942200395397e-07 1.9830238693113347
# set cost params:  19.8 1.0 0.0
# ----- 40
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11.019589739134254
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.019430693843942
# RUN  2 , total integrated cost =  11.01943068621946
# RUN  3 , total integrated cost =  11.019430680358766
# RUN  3 , total integrated cost =  11.019430680358766
# Improved over  3  iterations in  0.9532190220015764  seconds by  0.001443418305512978  percent.
# 1.5529898708066446e-07 1.9830337414568917
# 4.058942200395397e-07 1.9830238693113347
# set cost params:  19.794999999999998 1.0 0.0
# ----- 41
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11.019509575100123
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.019431497456408
# RUN  2 , total integrated cost =  11.019431093371276
# RUN  3 , total integrated cost =  11.019430850931824
# RUN  3 , total integrated cost =  11.019430850931824
# Improved over  3  iterations in  0.9296448870009044  seconds by  0.0007144071862938972  percent.
# 1.3387117597280272e-07 1.9830344503419721
# 4.058942200395397e-07 1.9830238693113347
# set cost params:  19.79 1.0 0.0
# ----- 42
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11.019525504862266
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.019431730306392
# RUN  2 , total integrated cost =  11.019431703993321
# RUN  3 , total integrated cost =  11.019431652936529
# RUN  3 , total integrated cost =  11.019431652936529
# Improved over  3  iterations in  1.2118648720024794  seconds by  0.0008516875404041002  percent.
# 1.2463551899511152e-07 1.9830350905315823
# 4.058942200395397e-07 1.9830238693113347
# set cost params:  19.785 1.0 0.0
# ----- 43
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11.019460686050614
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.019432520144425
# RUN  2 , total integrated cost =  11.019432336651118
# RUN  3 , total integrated cost =  11.019432188341254
# RUN  3 , total integrated cost =  11.019432188341254
# Improved over  3  iterations in  1.168644958997902  seconds by  0.00025861255983272713  percent.
# 1.2166936457574134e-07 1.9830357624466242
# 4.058942200395397e-07 1.9830238693113347
# set cost params:  19.78 1.0 0.0
# ----- 44
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11.019446671298555
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.019432957737589
# RUN  2 , total integrated cost =  11.01943294380982
# RUN  3 , total integrated cost =  11.01943292915846
# RUN  3 , total integrated cost =  11.01943292915846
# Improved over  3  iterations in  0.9417550219986879  seconds by  0.00012470807749309643  percent.
# 1.2320220625140478e-07 1.9830363345965976
# 4.058942200395397e-07 1.9830238693113347
# set cost params:  19.775 1.0 0.0
# ----- 45
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11.019489759992387
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.019433882438461
# RUN  2 , total integrated cost =  11.019433826790427
# RUN  3 , total integrated cost =  11.019433771857729
# RUN  3 , total integrated cost =  11.019433771857729
# Improved over  3  iterations in  0.8553685189981479  seconds by  0.000508082823046152  percent.
# 1.2249789410805004e-07 1.9830371451853293
# 4.058942200395397e-07 1.9830238693113347
# set cost params:  19.77 1.0 0.0
# ----- 46
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11.019492953123699
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.019434788307754
# RUN  2 , total integrated cost =  11.019434781036825
# RUN  3 , total integrated cost =  11.019434773940064
# RUN  3 , total integrated cost =  11.019434773940064
# Improved over  3  iterations in  0.937991258000693  seconds by  0.0005279660677928177  percent.
# 1.2249640535036512e-07 1.9830378473087678
# 4.058942200395397e-07 1.9830238693113347
# set cost params:  19.765 1.0 0.0
# ----- 47
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11.019481762429324
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.019435832952247
# RUN  2 , total integrated cost =  11.019435682118713
# RUN  3 , total integrated cost =  11.019435555639763
# RUN  3 , total integrated cost =  11.019435555639763
# Improved over  3  iterations in  0.8554352290011593  seconds by  0.00041931908012315944  percent.
# 1.1917664352109079e-07 1.9830389110964945
# 4.058942200395397e-07 1.9830238693113347
# set cost params:  19.759999999999998 1.0 0.0
# ----- 48
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11.019485546894407
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.019436668327305
# RUN  2 , total integrated cost =  11.01943663791758
# RUN  3 , total integrated cost =  11.019436626744241
# RUN  3 , total integrated cost =  11.019436626744241
# Improved over  3  iterations in  1.0903625309983909  seconds by  0.00044394223266408517  percent.
# 1.1783351548906466e-07 1.9830397195320084
# 4.058942200395397e-07 1.9830238693113347
# set cost params:  19.755000000000003 1.0 0.0
# ----- 49
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11.019471643466105
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.019437741261974
# RUN  2 , total integrated cost =  11.019437733138396
# RUN  3 , total integrated cost =  11.019437725773649
# RUN  3 , total integrated cost =  11.019437725773649
# Improved over  3  iterations in  1.0810441900030128  seconds by  0.00030779781057788114  percent.
# 1.2103731294511263e-07 1.9830405096506714
# 4.058942200395397e-07 1.9830238693113347
# set cost params:  19.75 1.0 0.0
# ----- 50
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11.0194786759185
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.019438923541303
# RUN  2 , total integrated cost =  11.01943890412565
# RUN  3 , total integrated cost =  11.019438890230067
# RUN  3 , total integrated cost =  11.019438890230067
# Improved over  3  iterations in  0.8881797869980801  seconds by  0.0003610487356269232  percent.
# 1.2002510573226208e-07 1.983041353880999
# 4.058942200395397e-07 1.9830238693113347
# set cost params:  19.744999999999997 1.0 0.0
# ----- 51
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11.019471286571335
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.019440133572305
# RUN  2 , total integrated cost =  11.019439832220536
# RUN  3 , total integrated cost =  11.019439365589626
# RUN  3 , total integrated cost =  11.019439365589626
# Improved over  3  iterations in  0.8494619049997709  seconds by  0.00028967797889833946  percent.
# 1.0726546642709951e-07 1.983043020790855
# 4.058942200395397e-07 1.9830238693113347
# set cost params:  19.740000000000002 1.0 0.0
# ----- 52
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11.019479078431015
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.019440625474004
# RUN  2 , total integrated cost =  11.019440010192394
# RUN  3 , total integrated cost =  11.019439582665898
# RUN  3 , total integrated cost =  11.019439582665898
# Improved over  3  iterations in  1.2662604069992085  seconds by  0.00035841771499178776  percent.
# 7.891625104566832e-08 1.9830441574538094
# 4.058942200395397e-07 1.9830238693113347
# set cost params:  19.735 1.0 0.0
# ----- 53
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11.019485656412284
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.019440936554526
# RUN  2 , total integrated cost =  11.019440888699187
# RUN  3 , total integrated cost =  11.019440828647626
# RUN  3 , total integrated cost =  11.019440828647626
# Improved over  3  iterations in  1.2452641279996897  seconds by  0.00040680451024854847  percent.
# 8.136388761403312e-08 1.9830452492835533
# 4.058942200395397e-07 1.9830238693113347
# set cost params:  19.73 1.0 0.0
# ----- 54
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11.019487062249077
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.01944226633348
# RUN  2 , total integrated cost =  11.019442226780525
# RUN  3 , total integrated cost =  11.019442213575669
# RUN  3 , total integrated cost =  11.019442213575669
# Improved over  3  iterations in  1.1522079040005337  seconds by  0.00040699420176792955  percent.
# 8.090669105305326e-08 1.9830462741482042
# 4.058942200395397e-07 1.9830238693113347
# set cost params:  19.725 1.0 0.0
# ----- 55
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11.019475581826592
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.019443654488523
# RUN  2 , total integrated cost =  11.019443642772327
# RUN  3 , total integrated cost =  11.019443630672344
# RUN  3 , total integrated cost =  11.019443630672344
# Improved over  3  iterations in  0.890154264998273  seconds by  0.0002899516770185073  percent.
# 8.991937951944441e-08 1.9830471818730584
# 4.058942200395397e-07 1.9830238693113347
# set cost params:  19.72 1.0 0.0
# ----- 56
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11.019491556795385
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.019445168706826
# RUN  2 , total integrated cost =  11.019445138874762
# RUN  3 , total integrated cost =  11.01944510396373
# RUN  3 , total integrated cost =  11.01944510396373
# Improved over  3  iterations in  1.162375064999651  seconds by  0.00042155149732536756  percent.
# 8.871256228119611e-08 1.9830483816912257
# 4.058942200395397e-07 1.9830238693113347
# set cost params:  19.715 1.0 0.0
# ----- 57
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11.019481353525082
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.01944671197771
# RUN  2 , total integrated cost =  11.0194466915869
# RUN  3 , total integrated cost =  11.019446666090849
# RUN  3 , total integrated cost =  11.019446666090849
# Improved over  3  iterations in  1.1355410320029478  seconds by  0.00031478282072328057  percent.
# 8.614426386225682e-08 1.9830494921634354
# 4.058942200395397e-07 1.9830238693113347
# set cost params:  19.71 1.0 0.0
# ----- 58
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11.01947199152185
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.019448280142756
# RUN  2 , total integrated cost =  11.019448254939416
# RUN  3 , total integrated cost =  11.019448227027532
# RUN  3 , total integrated cost =  11.019448227027532
# Improved over  3  iterations in  1.1855012619998888  seconds by  0.00021565910178367176  percent.
# 8.697579261872735e-08 1.983050582629316
# 4.058942200395397e-07 1.9830238693113347
# set cost params:  19.705000000000002 1.0 0.0
# ----- 59
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11.01947383220603
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.019449954078773
# RUN  2 , total integrated cost =  11.019449937943513
# RUN  3 , total integrated cost =  11.019449923342727
# RUN  3 , total integrated cost =  11.019449923342727
# Improved over  3  iterations in  1.0003239380021114  seconds by  0.00021696919169755802  percent.
# 9.318082023274982e-08 1.983051706127723
# 4.058942200395397e-07 1.9830238693113347
# set cost params:  19.7 1.0 0.0
# ----- 60
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11.01947807899465
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.019451731000991
# RUN  2 , total integrated cost =  11.019451692616395
# RUN  3 , total integrated cost =  11.019451645354486
# RUN  3 , total integrated cost =  11.019451645354486
# Improved over  3  iterations in  0.8894791689999693  seconds by  0.00023988105401429038  percent.
# 9.770815728268836e-08 1.9830530672246305
# 4.058942200395397e-07 1.9830238693113347
# set cost params:  19.695 1.0 0.0
# ----- 61
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11.019462140847697
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.01945316028647
# RUN  2 , total integrated cost =  11.01945313605623
# RUN  3 , total integrated cost =  11.019453109171167
# RUN  3 , total integrated cost =  11.019453109171167
# Improved over  3  iterations in  1.6153457680011343  seconds by  8.196113762437562e-05  percent.
# 1.0160891400909486e-07 1.9830541718763264
# 4.058942200395397e-07 1.9830238693113347
# set cost params:  19.69 1.0 0.0
# ----- 62
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11.019479578397203
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.019455060446633
# RUN  2 , total integrated cost =  11.019454839497092
# RUN  3 , total integrated cost =  11.019454610660164
# RUN  3 , total integrated cost =  11.019454610660164
# Improved over  3  iterations in  1.3162830340006622  seconds by  0.00022657818693971876  percent.
# 9.863971157661798e-08 1.9830561370115685
# 4.058942200395397e-07 1.9830238693113347
# set cost params:  19.685 1.0 0.0
# ----- 63
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11.019481171197814
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.019456640147169
# RUN  2 , total integrated cost =  11.01945589753435
# RUN  3 , total integrated cost =  11.019453881475705
# RUN  3 , total integrated cost =  11.019453881475705
# Improved over  3  iterations in  1.2001357629997074  seconds by  0.00024764979117719577  percent.
# 1.0270103770902456e-07 1.9830577534904263
# 4.058942200395397e-07 1.9830238693113347
# set cost params:  19.68 1.0 0.0
# ----- 64
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11.019483507917629
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.019455918740135
# RUN  2 , total integrated cost =  11.019455896506482
# RUN  3 , total integrated cost =  11.01945588065674
# RUN  3 , total integrated cost =  11.01945588065674
# Improved over  3  iterations in  0.9688152439994155  seconds by  0.00025071284755995293  percent.
# 9.824930412481086e-08 1.9830592115633676
# 4.058942200395397e-07 1.9830238693113347
# set cost params:  19.675 1.0 0.0
# ----- 65
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11.019480958353263
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.019458092834373
# RUN  2 , total integrated cost =  11.019458060782677
# RUN  3 , total integrated cost =  11.019458032592889
# RUN  3 , total integrated cost =  11.019458032592889
# Improved over  3  iterations in  0.8565991100003885  seconds by  0.00020804755197900704  percent.
# 9.82366347431922e-08 1.9830607074799549
# 4.058942200395397e-07 1.9830238693113347
# set cost params:  19.669999999999998 1.0 0.0
# ----- 66
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11.019480069171998
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.019460337405835
# RUN  2 , total integrated cost =  11.019459413625336
# RUN  3 , total integrated cost =  11.0194583737101
# RUN  3 , total integrated cost =  11.0194583737101
# Improved over  3  iterations in  1.105442412001139  seconds by  0.00019688280900709287  percent.
# 7.375976079585319e-08 1.9830621109459654
# 4.058942200395397e-07 1.9830238693113347
# set cost params:  19.665 1.0 0.0
# ----- 67
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11.019498840044728
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.019460688941464
# RUN  2 , total integrated cost =  11.019460673690416
# RUN  3 , total integrated cost =  11.019460661685725
# RUN  3 , total integrated cost =  11.019460661685725
# Improved over  3  iterations in  1.2609711839977535  seconds by  0.00034646184509767863  percent.
# 7.286464395207804e-08 1.983063798260546
# 4.058942200395397e-07 1.9830238693113347
# set cost params:  19.66 1.0 0.0
# ----- 68
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11.019496221349517
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.01946322218744
# RUN  2 , total integrated cost =  11.019463160681818
# RUN  3 , total integrated cost =  11.019463087125587
# RUN  3 , total integrated cost =  11.019463087125587
# Improved over  3  iterations in  0.870444720996602  seconds by  0.0003006872842803432  percent.
# 8.05894680410107e-08 1.9830657192912897
# 4.058942200395397e-07 1.9830238693113347
# set cost params:  19.655 1.0 0.0
# ----- 69
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11.019494769403595
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.019465667749948
# RUN  2 , total integrated cost =  11.019465633462245
# RUN  3 , total integrated cost =  11.019465579603017
# RUN  3 , total integrated cost =  11.019465579603017
# Improved over  3  iterations in  0.7595392859984713  seconds by  0.0002648923674684056  percent.
# 7.609611468769592e-08 1.9830674629916443
# 4.058942200395397e-07 1.9830238693113347
# set cost params:  19.65 1.0 0.0
# ----- 70
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11.01949139782088
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.01946836518341
# RUN  2 , total integrated cost =  11.019468313319521
# RUN  3 , total integrated cost =  11.019468218215854
# RUN  3 , total integrated cost =  11.019468218215854
# Improved over  3  iterations in  0.808120682999288  seconds by  0.00021035095168997486  percent.
# 7.525380636520342e-08 1.9830692405333612
# 4.058942200395397e-07 1.9830238693113347
# set cost params:  19.645 1.0 0.0
# ----- 71
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11.019489766097198
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.019471067881941
# RUN  2 , total integrated cost =  11.019471028879027
# RUN  3 , total integrated cost =  11.019470984308409
# RUN  3 , total integrated cost =  11.019470984308409
# Improved over  3  iterations in  0.9001661549991695  seconds by  0.00017044154664347388  percent.
# 1.0119048836324647e-07 1.9830711146061475
# 4.058942200395397e-07 1.9830238693113347
# set cost params:  19.64 1.0 0.0
# ----- 72
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11.019499145515136
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.019473882731424
# RUN  2 , total integrated cost =  11.01947385501772
# RUN  3 , total integrated cost =  11.01947383378127
# RUN  3 , total integrated cost =  11.01947383378127
# Improved over  3  iterations in  0.8086219659999188  seconds by  0.00022969949479545448  percent.
# 1.0700447209667621e-07 1.9830730427397318
# 4.058942200395397e-07 1.9830238693113347
# set cost params:  19.634999999999998 1.0 0.0
# ----- 73
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11.019502283268501
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.019476971697983
# RUN  2 , total integrated cost =  11.019476928718548
# RUN  3 , total integrated cost =  11.019476881480346
# RUN  3 , total integrated cost =  11.019476881480346
# Improved over  3  iterations in  1.0208174099971075  seconds by  0.0002305166558471683  percent.
# 1.1692822304303486e-07 1.9830752655388832
# 4.058942200395397e-07 1.9830238693113347
# set cost params:  19.630000000000003 1.0 0.0
# ----- 74
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11.019502697127482
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.019480017009881
# RUN  2 , total integrated cost =  11.019479585698448
# RUN  3 , total integrated cost =  11.019479171130923
# RUN  3 , total integrated cost =  11.019479171130923
# Improved over  3  iterations in  0.9932440820011834  seconds by  0.00021349417669114246  percent.
# 1.1332211842103668e-07 1.9830785210919117
# 4.058942200395397e-07 1.9830238693113347
# set cost params:  19.625 1.0 0.0
# ----- 75
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11.019507958817398
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.019482570759376
# RUN  2 , total integrated cost =  11.01948224952549
# RUN  3 , total integrated cost =  11.019481922352076
# RUN  3 , total integrated cost =  11.019481922352076
# Improved over  3  iterations in  0.8830983650004782  seconds by  0.00023627611521703784  percent.
# 1.1486689089934183e-07 1.9830816663155562
# 4.058942200395397e-07 1.9830238693113347
# set cost params:  19.619999999999997 1.0 0.0
# ----- 76
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11.019510906697075
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.019485488407348
# RUN  2 , total integrated cost =  11.019484614918111
# RUN  3 , total integrated cost =  11.019483756509196
# RUN  3 , total integrated cost =  11.019483756509196
# Improved over  3  iterations in  0.9518124979986169  seconds by  0.0002463828758720865  percent.
# 9.979076017766046e-08 1.9830838301946514
# 4.058942200395397e-07 1.9830238693113347
# set cost params:  19.615000000000002 1.0 0.0
# ----- 77
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11.019520044454797
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.01948731319424
# RUN  2 , total integrated cost =  11.019487285058553
# RUN  3 , total integrated cost =  11.019487255712411
# RUN  3 , total integrated cost =  11.019487255712411
# Improved over  3  iterations in  0.7918500369996764  seconds by  0.0002975514564553805  percent.
# 1.013925221659895e-07 1.9830862031389964
# 4.058942200395397e-07 1.9830238693113347
# set cost params:  19.61 1.0 0.0
# ----- 78
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11.019504467304918
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.019490703563058
# RUN  2 , total integrated cost =  11.019490518001062
# RUN  3 , total integrated cost =  11.019490308640696
# RUN  3 , total integrated cost =  11.019490308640696
# Improved over  3  iterations in  0.9787105830000655  seconds by  0.00012848730415271348  percent.
# 1.2048212814674154e-07 1.9830888332592143
# 4.058942200395397e-07 1.9830238693113347
# set cost params:  19.605 1.0 0.0
# ----- 79
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11.019521319514368
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.019494236728626
# RUN  2 , total integrated cost =  11.019494182771128
# RUN  3 , total integrated cost =  11.019494131016085
# RUN  3 , total integrated cost =  11.019494131016085
# Improved over  3  iterations in  0.7185961779978243  seconds by  0.00024673030247868155  percent.
# 1.2302459247726387e-07 1.9830914223053921
# 4.058942200395397e-07 1.9830238693113347
# set cost params:  19.6 1.0 0.0
# ----- 80
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11.019522864917418
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.01949841353398
# RUN  2 , total integrated cost =  11.019498345538038
# RUN  3 , total integrated cost =  11.019498281119086
# RUN  3 , total integrated cost =  11.019498281119086
# Improved over  3  iterations in  0.7087599680016865  seconds by  0.00022309312875279375  percent.
# 1.352460215838837e-07 1.9830941115884697
# 4.058942200395397e-07 1.9830238693113347
# set cost params:  19.595 1.0 0.0
# ----- 81
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11.019523371114811
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.019502503673733
# RUN  2 , total integrated cost =  11.019480767793684
# RUN  3 , total integrated cost =  11.019435103758166
# RUN  3 , total integrated cost =  11.019435103758166
# Improved over  3  iterations in  0.8355714240024099  seconds by  0.0008010088428704876  percent.
# 1.6644989036004754e-07 1.9831782139290932
# 4.058942200395397e-07 1.9830238693113347
# set cost params:  19.59 1.0 0.0
# ----- 82
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11.019736025005473
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.019440497068587
# RUN  2 , total integrated cost =  11.019440466324504
# RUN  3 , total integrated cost =  11.019440446912057
# RUN  3 , total integrated cost =  11.019440446912057
# Improved over  3  iterations in  0.9950401689966384  seconds by  0.002682261106301098  percent.
# 2.1685289336073285e-07 1.983181175416879
# 4.058942200395397e-07 1.9830238693113347
# set cost params:  19.585 1.0 0.0
# ----- 83
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11.019634031025678
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.019446745078136
# RUN  2 , total integrated cost =  11.019446709239821
# RUN  3 , total integrated cost =  11.019446673264216
# RUN  3 , total integrated cost =  11.019446673264216
# Improved over  3  iterations in  0.9501686959993094  seconds by  0.0017002176382163725  percent.
# 3.173341625946715e-07 1.9831840958783276
# 4.058942200395397e-07 1.9830238693113347
# set cost params:  19.580000000000002 1.0 0.0
# ----- 84
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11.019620917318212
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.019454062208725
# RUN  2 , total integrated cost =  11.019454035142902
# RUN  3 , total integrated cost =  11.019454005765606
# RUN  3 , total integrated cost =  11.019454005765606
# Improved over  3  iterations in  0.9331545659988478  seconds by  0.0015146759934765441  percent.
# 4.6698743159319255e-07 1.983187115540123
# 4.058942200395397e-07 1.9830238693113347
# set cost params:  19.575 1.0 0.0
# ----- 85
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11.019605780040855
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.019460950194443
# RUN  2 , total integrated cost =  11.019460822739944
# RUN  3 , total integrated cost =  11.019460731028069
# RUN  3 , total integrated cost =  11.019460731028069
# Improved over  3  iterations in  0.9149160099987057  seconds by  0.001316281323326507  percent.
# 5.449213356297922e-07 1.9831905977116489
# 4.058942200395397e-07 1.9830238693113347
# set cost params:  19.57 1.0 0.0
# ----- 86
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11.019561479947384
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.019468061704508
# RUN  2 , total integrated cost =  11.019464634308674
# RUN  3 , total integrated cost =  11.019462492221129
# RUN  3 , total integrated cost =  11.019462492221129
# Improved over  3  iterations in  1.193298665999464  seconds by  0.0008982909749732926  percent.
# 4.444541180866304e-07 1.983197125291548
# 4.058942200395397e-07 1.9830238693113347
# set cost params:  19.565 1.0 0.0
# ----- 87
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11.019545437769867
# Gradient descend method:  None
# ...
# RUN  1 , total integrated cost =  11.18181018705506
# RUN  2 , total integrated cost =  11.166684218750655
# RUN  3 , total integrated cost =  11.16066810894616
# RUN  4 , total integrated cost =  11.158067686650412
# RUN  5 , total integrated cost =  11.156971049793642
# RUN  6 , total integrated cost =  11.156092584534226
# RUN  7 , total integrated cost =  11.155360500971291
# RUN  8 , total integrated cost =  11.154636841048182
# RUN  9 , total integrated cost =  11.153967231704296
# RUN  10 , total integrated cost =  11.153387075471525
# RUN  11 , total integrated cost =  11.15286101307949
# RUN  12 , total integrated cost =  11.152384434894236
# RUN  13 , total integrated cost =  11.151929713789196
# RUN  14 , total integrated cost =  11.15150250290919
# RUN  15 , total integrated cost =  11.15110878180389
# RUN  16 , total integrated cost =  11.150720915817347
# RUN  17 , total integrated cost =  11.150355801531564
# RUN  18 , total integrated cost =  11.15002649156158
# RUN  19 , total integrated cost =  11.149708932335772
# RUN  20 , total integrated cost =  11.149406515335139
# RUN  30 , total integrated cost =  11.147103508688565
# RUN  40 , total integrated cost =  11.14537364717285
# RUN  40 , total integrated cost =  11.14537364717285
# Improved over  40  iterations in  6.229251347998797  seconds by  2.1968165628520637  percent.
# 0.0001871888489021896 2.0565220980453227
# 4.058942200395397e-07 1.9830238693113347
# set cost params:  18.71 1.0 0.0
# ----- 258
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11.487460206797424
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.20989646973257
# RUN  2 , total integrated cost =  11.197014843065237
# RUN  3 , total integrated cost =  11.189156725099018
# RUN  4 , total integrated cost =  11.183533517270499
# RUN  5 , total integrated cost =  11.179370131357246
# RUN  6 , total integrated cost =  11.175908795518858
# RUN  7 , total integrated cost =  11.172975673324919
# RUN  8 , total integrated cost =  11.170080764568707
# RUN  9 , total integrated cost =  11.167857462393842
# RUN  10 , total integrated cost =  11.165586109095617
# RUN  11 , total integrated cost =  11.16378672506429
# RUN  12 , total integrated cost =  11.162142725462015
# RUN  13 , total integrated cost =  11.16071027778074
# RUN  14 , total integrated cost =  11.159446010900274
# RUN  15 , total integrated cost =  11.158331964771778
# RUN  16 , total integrated cost =  11.157348172562171
# RUN  17 , total integrated cost =  11.156546488509875
# RUN  18 , total integrated cost =  11.155693199205745
# RUN  19 , total integrated cost =  11.154899656189615
# RUN  20 , total integrated cost =  11.154398572699595
# RUN  30 , total integrated cost =  11.151936703701226
# RUN  40 , total integrated cost =  11.150649007178933
# RUN  40 , total integrated cost =  11.150649007178933
# Improved over  40  iterations in  7.53405086299972  seconds by  2.9319901314582353  percent.
# 0.00014909776539979557 2.0600011993120004
# 4.058942200395397e-07 1.9830238693113347
# set cost params:  18.705000000000002 1.0 0.0
# ----- 259
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11.489243431894359
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.216315594952196
# RUN  2 , total integrated cost =  11.190499545934458
# RUN  3 , total integrated cost =  11.183562333772931
# RUN  4 , total integrated cost =  11.179741128917568
# RUN  5 , total integrated cost =  11.177458053580846
# RUN  6 , total integrated cost =  11.175619448328366
# RUN  7 , total integrated cost =  11.173905614098118
# RUN  8 , total integrated cost =  11.172467648288606
# RUN  9 , total integrated cost =  11.171147314683417
# RUN  10 , total integrated cost =  11.169937095117685
# RUN  11 , total integrated cost =  11.168772404919292
# RUN  12 , total integrated cost =  11.167850832882086
# RUN  13 , total integrated cost =  11.166976166683337
# RUN  14 , total integrated cost =  11.166138284117043
# RUN  15 , total integrated cost =  11.165378957778742
# RUN  16 , total integrated cost =  11.164710976149845
# RUN  17 , total integrated cost =  11.164051695955234
# RUN  18 , total integrated cost =  11.163504657784923
# RUN  19 , total integrated cost =  11.163006938168339
# RUN  20 , total integrated cost =  11.162568660972681
# RUN  30 , total integrated cost =  11.15952780090286
# RUN  40 , total integrated cost =  11.15779120014903
# RUN  40 , total integrated cost =  11.15779120014903
# Improved over  40  iterations in  12.156298071000492  seconds by  2.8848917138026025  percent.
# 0.00018652548874375935 2.063336040190582
# 4.058942200395397e-07 1.9830238693113347
# set cost params:  18.7 1.0 0.0
# ----- 260
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11.430490331513427
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.209556495246602
# RUN  2 , total integrated cost =  11.201890141443794
# RUN  3 , total integrated cost =  11.196807629567596
# RUN  4 , total integrated cost =  11.192483037367687
# RUN  5 , total integrated cost =  11.188814169985049
# RUN  6 , total integrated cost =  11.185787244986223
# RUN  7 , total integrated cost =  11.183459275334902
# RUN  8 , total integrated cost =  11.181418043012123
# RUN  9 , total integrated cost =  11.179579220913716
# RUN  10 , total integrated cost =  11.178000961073499
# RUN  11 , total integrated cost =  11.17662920171006
# RUN  12 , total integrated cost =  11.175272744702857
# RUN  13 , total integrated cost =  11.174156315187513
# RUN  14 , total integrated cost =  11.173065393163258
# RUN  15 , total integrated cost =  11.172072707389423
# RUN  16 , total integrated cost =  11.171265822002612
# RUN  17 , total integrated cost =  11.170508698562147
# RUN  18 , total integrated cost =  11.16978297981282
# RUN  19 , total integrated cost =  11.169134613525642
# RUN  20 , total integrated cost =  11.168548031028699
# RUN  30 , total integrated cost =  11.164838413362714
# RUN  40 , total integrated cost =  11.163113188889882
# RUN  40 , total integrated cost =  11.163113188889882
# Improved over  40  iterations in  8.700602732002153  seconds by  2.339157244080738  percent.
# 0.0001921514681707322 2.066702106762057
# 4.058942200395397e-07 1.9830238693113347
# set cost params:  18.695 1.0 0.0
# ----- 261
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11.537587469654708
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.23659242139789
# RUN  2 , total integrated cost =  11.204966716094935
# RUN  3 , total integrated cost =  11.199058872333058
# RUN  4 , total integrated cost =  11.195551337345215
# RUN  5 , total integrated cost =  11.193133295759868
# RUN  6 , total integrated cost =  11.191088555085225
# RUN  7 , total integrated cost =  11.18935431242388
# RUN  8 , total integrated cost =  11.18773033957924
# RUN  9 , total integrated cost =  11.186327864927604
# RUN  10 , total integrated cost =  11.185009655191404
# RUN  11 , total integrated cost =  11.183853219257154
# RUN  12 , total integrated cost =  11.182751249534435
# RUN  13 , total integrated cost =  11.181754165405227
# RUN  14 , total integrated cost =  11.180856805564634
# RUN  15 , total integrated cost =  11.180028165607615
# RUN  16 , total integrated cost =  11.179256255469454
# RUN  17 , total integrated cost =  11.178564699792325
# RUN  18 , total integrated cost =  11.177918885161276
# RUN  19 , total integrated cost =  11.177324452973934
# RUN  20 , total integrated cost =  11.176766357756364
# RUN  30 , total integrated cost =  11.17281094909534
# RUN  40 , total integrated cost =  11.17058595727478
# RUN  40 , total integrated cost =  11.17058595727478
# Improved over  40  iterations in  7.673590000998956  seconds by  3.1809207370708066  percent.
# 0.00022275921387318254 2.070566156465175
# 4.058942200395397e-07 1.9830238693113347
# set cost params:  18.69 1.0 0.0
# ----- 262
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11.479902490039697
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.225851845932157
# RUN  2 , total integrated cost =  11.204010851252443
# RUN  3 , total integrated cost =  11.198801598944344
# RUN  4 , total integrated cost =  11.196133212290064
# RUN  5 , total integrated cost =  11.194269467320217
# RUN  6 , total integrated cost =  11.192742357256797
# RUN  7 , total integrated cost =  11.191403327857842
# RUN  8 , total integrated cost =  11.190236112648037
# RUN  9 , total integrated cost =  11.189148692373259
# RUN  10 , total integrated cost =  11.18817611830503
# RUN  11 , total integrated cost =  11.187274494002278
# RUN  12 , total integrated cost =  11.186444278814706
# RUN  13 , total integrated cost =  11.185670850600044
# RUN  14 , total integrated cost =  11.184975135172223
# RUN  15 , total integrated cost =  11.18432313686522
# RUN  16 , total integrated cost =  11.183716477293773
# RUN  17 , total integrated cost =  11.183148567722249
# RUN  18 , total integrated cost =  11.182631211078652
# RUN  19 , total integrated cost =  11.182143202798262
# RUN  20 , total integrated cost =  11.18169269754533
# RUN  30 , total integrated cost =  11.178391458416344
# RUN  40 , total integrated cost =  11.176395441152057
# RUN  40 , total integrated cost =  11.176395441152057
# Improved over  40  iterations in  7.419861898000818  seconds by  2.643812080729532  percent.
# 0.00020416901016687185 2.0740574436310526
# 4.058942200395397e-07 1.9830238693113347
# set cost params:  18.685 1.0 0.0
# ----- 263
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11.55681879823113
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.255984928102016
# RUN  2 , total integrated cost =  11.21927005047136
# RUN  3 , total integrated cost =  11.21106641090805
# RUN  4 , total integrated cost =  11.207428535671108
# RUN  5 , total integrated cost =  11.204730174332578
# RUN  6 , total integrated cost =  11.202359419003953
# RUN  7 , total integrated cost =  11.200641123289088
# RUN  8 , total integrated cost =  11.199046265942412
# RUN  9 , total integrated cost =  11.197464141458472
# RUN  10 , total integrated cost =  11.196062782412556
# RUN  11 , total integrated cost =  11.194914678907542
# RUN  12 , total integrated cost =  11.193832733438098
# RUN  13 , total integrated cost =  11.19284741823582
# RUN  14 , total integrated cost =  11.191901407853383
# RUN  15 , total integrated cost =  11.191138832227244
# RUN  16 , total integrated cost =  11.190410782688584
# RUN  17 , total integrated cost =  11.189725499989866
# RUN  18 , total integrated cost =  11.189085279399801
# RUN  19 , total integrated cost =  11.188539116994816
# RUN  20 , total integrated cost =  11.188036887127526
# RUN  30 , total integrated cost =  11.184485984992437
# RUN  40 , total integrated cost =  11.18252722106515
# RUN  40 , total integrated cost =  11.18252722106515
# Improved over  40  iterations in  7.6846313109999755  seconds by  3.2387076729391  percent.
# 0.00016302890780610428 2.078136846290757
# 4.058942200395397e-07 1.9830238693113347
# set cost params:  18.68 1.0 0.0
# ----- 264
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11.582784126358279
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.260667785065179
# RUN  2 , total integrated cost =  11.248035053091192
# RUN  3 , total integrated cost =  11.23936076670088
# RUN  4 , total integrated cost =  11.23162703300209
# RUN  5 , total integrated cost =  11.22591144343212
# RUN  6 , total integrated cost =  11.220522425929698
# RUN  7 , total integrated cost =  11.216532121764896
# RUN  8 , total integrated cost =  11.212570229496219
# RUN  9 , total integrated cost =  11.209389803254384
# RUN  10 , total integrated cost =  11.20682061949979
# RUN  11 , total integrated cost =  11.204651586364001
# RUN  12 , total integrated cost =  11.202506044008556
# RUN  13 , total integrated cost =  11.20080621280426
# RUN  14 , total integrated cost =  11.199292087435161
# RUN  15 , total integrated cost =  11.1980826136665
# RUN  16 , total integrated cost =  11.196867922518326
# RUN  17 , total integrated cost =  11.19589437741519
# RUN  18 , total integrated cost =  11.195034940549364
# RUN  19 , total integrated cost =  11.194255193170163
# RUN  20 , total integrated cost =  11.193619483052753
# RUN  30 , total integrated cost =  11.189696544900722
# RUN  40 , total integrated cost =  11.187892313870876
# RUN  40 , total integrated cost =  11.187892313870876
# Improved over  40  iterations in  8.605137459999241  seconds by  3.4092995965345665  percent.
# 0.00011837208995379465 2.082425733322335
# 4.058942200395397e-07 1.9830238693113347
# set cost params:  18.675 1.0 0.0
# ----- 265
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11.54841932642038
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.245087753109607
# RUN  2 , total integrated cost =  11.225542773512537
# RUN  3 , total integrated cost =  11.220789973916048
# RUN  4 , total integrated cost =  11.21828173150992
# RUN  5 , total integrated cost =  11.216434327876073
# RUN  6 , total integrated cost =  11.214825446120035
# RUN  7 , total integrated cost =  11.213373642455304
# RUN  8 , total integrated cost =  11.212123516863507
# RUN  9 , total integrated cost =  11.211000405408225
# RUN  10 , total integrated cost =  11.209878434638911
# RUN  11 , total integrated cost =  11.208892730045823
# RUN  12 , total integrated cost =  11.207996160462807
# RUN  13 , total integrated cost =  11.207126676561604
# RUN  14 , total integrated cost =  11.206388278739643
# RUN  15 , total integrated cost =  11.205712836237355
# RUN  16 , total integrated cost =  11.205112115956615
# RUN  17 , total integrated cost =  11.204543606488317
# RUN  18 , total integrated cost =  11.203994746000518
# RUN  19 , total integrated cost =  11.203463583936548
# RUN  20 , total integrated cost =  11.20292607600217
# RUN  30 , total integrated cost =  11.198933290119307
# RUN  40 , total integrated cost =  11.196692432761441
# RUN  40 , total integrated cost =  11.196692432761441
# Improved over  40  iterations in  8.952391463000822  seconds by  3.0456713054596207  percent.
# 0.00024184968048694973 2.0862293389420774
# 4.058942200395397e-07 1.9830238693113347
# set cost params:  18.669999999999998 1.0 0.0
# ----- 266
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11.675142071292717
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.29491520432954
# RUN  2 , total integrated cost =  11.271512965200861
# RUN  3 , total integrated cost =  11.25935512640281
# RUN  4 , total integrated cost =  11.247111861450353
# RUN  5 , total integrated cost =  11.238984376686254
# RUN  6 , total integrated cost =  11.229739040409493
# RUN  7 , total integrated cost =  11.22422683212097
# RUN  8 , total integrated cost =  11.22173615091044
# RUN  9 , total integrated cost =  11.219715950783945
# RUN  10 , total integrated cost =  11.217732079869894
# RUN  11 , total integrated cost =  11.216017343776466
# RUN  12 , total integrated cost =  11.214597468430687
# RUN  13 , total integrated cost =  11.213371146835179
# RUN  14 , total integrated cost =  11.212121608271824
# RUN  15 , total integrated cost =  11.211005220680123
# RUN  16 , total integrated cost =  11.210171338400688
# RUN  17 , total integrated cost =  11.209419668556412
# RUN  18 , total integrated cost =  11.208605733380756
# RUN  19 , total integrated cost =  11.207938074280035
# RUN  20 , total integrated cost =  11.207357836301219
# RUN  30 , total integrated cost =  11.20396472330999
# RUN  40 , total integrated cost =  11.202358810823872
# RUN  40 , total integrated cost =  11.202358810823872
# Improved over  40  iterations in  10.452297128998907  seconds by  4.049486143995978  percent.
# 0.00014376301746224688 2.0906241627971975
# 4.058942200395397e-07 1.9830238693113347
# set cost params:  18.665 1.0 0.0
# ----- 267
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  11.70930659572407
# Gradient descend method:  None
# RUN  1 , total integrated cost =  11.29536351068887
# RUN  2 , total integrated cost =  11.274124294392347
# RUN  3 , total integrated cost =  11.262126168195003
# RUN  4 , total integrated cost =  11.251875937565249
# RUN  5 , total integrated cost =  11.244516591462833
