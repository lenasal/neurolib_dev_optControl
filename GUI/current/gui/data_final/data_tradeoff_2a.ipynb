# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import sys
import pickle

path = os.getcwd().split(os.sep + 'GUI')[0]
if path not in sys.path:
    print("not here")
    sys.path.append(path)

from neurolib.models.aln import ALNModel
from neurolib.utils import plotFunctions as plotFunc
from neurolib.utils import costFunctions as cost
import neurolib.dashboard.functions as functions
import neurolib.dashboard.data as data
    
# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2 

#path = os.path.join(os.getcwd(), "plots")
# Out:
# not here

# %% [markdown]
# ### Bistability

# %%
aln = ALNModel()
N = aln.params.N

data.set_parameters(aln)

state_vars = aln.state_vars
init_vars = aln.init_vars

##############################################################
def setinit(init_vars_, model):
    state_vars = model.state_vars
    init_vars = model.init_vars
    for iv in range(len(init_vars)):
        for sv in range(len(state_vars)):
            if state_vars[sv] in init_vars[iv]:
                #print("set init vars ", )
                if model.params[init_vars[iv]].ndim == 2:
                    model.params[init_vars[iv]][0,:] = init_vars_[sv]
                else:
                    model.params[init_vars[iv]][0] = init_vars_[sv]
                    
##############################################################               
def setmaxmincontrol(max_c_c, min_c_c, max_c_r, min_c_r):
    import numpy as np
    
    max_cntrl = np.zeros(( 6 ))
    min_cntrl = np.zeros(( 6 ))
    
    max_cntrl[0] = max_c_c
    min_cntrl[0] = min_c_c
    max_cntrl[1] = max_c_c
    min_cntrl[1] = min_c_c
    max_cntrl[2] = max_c_r
    min_cntrl[2] = min_c_r
    max_cntrl[3] = max_c_r
    min_cntrl[3] = min_c_r
    max_cntrl[4] = max_c_r
    min_cntrl[4] = min_c_r
    max_cntrl[5] = max_c_r
    min_cntrl[5] = min_c_r
            
    return max_cntrl, min_cntrl

# %%
##### LOAD BOUNDARIES
data_file = 'bi.pickle'
with open(data_file,'rb') as f:
    load_array= pickle.load(f)
exc = load_array[0]
inh = load_array[1]
print(len(exc))
# Out:
# 147

# %%
t0_array = np.arange(380., -1, -1.)
t_pen = t0_array / 400.

bestControl_1 = [None] * len(t_pen)
bestState_1 = [None] * len(t_pen)
cost_1 = [None] * len(t_pen)
runtime_1 = [None] * len(t_pen)
grad_1 = [None] * len(t_pen)
phi_1 = [None] * len(t_pen)
costnode_1 = [None] * len(t_pen)
weights_1 = [None] * len(t_pen)

# %%
initVars = [None] * len(exc)
target = [None] * len(exc)
cost_uncontrolled = [None] * len(exc)

cgv_list = [None, "HS", "FR", "PR", "CD", "LS", "DY", "WYL", "HZ", None]

# %%
dur_pre = 10
dur_post = 10

i = 20

n_pre = int(np.around(dur_pre/aln.params.dt + 1.,1))
n_post = int(np.around(dur_post/aln.params.dt + 1.,1))

tol = 1e-32
start_step = 10.
c_scheme = np.zeros(( 1,1 ))
c_scheme[0,0] = 1.
u_mat = np.identity(1)
u_scheme = np.array([[1.]])

c_var = [ [0], [1], [0,1]]
p_var = [ [0], [0], [0]]

### CURRENTS
cntrl_vars_0 = [0,1]
prec_vars = [0]

max_I = [3., -3.]
factor_wp = 1. / 0.05
factor_ws = 0.
factor_we = 1.
dur = 400
trans_time = 0.95
    
maxC = [5., -5., 0.18, 0.]

n_dur = int(np.around(dur/aln.params.dt + 1.,1))
max_cntrl, min_cntrl = setmaxmincontrol(maxC[0], maxC[1], maxC[2], maxC[3])

# %%
init_file = 'control_2.pickle'
final_file_1 = 'control_tradeoff_2a.pickle'

# %%
if os.path.isfile(init_file) :
    print("init file found")
    
    with open(init_file,'rb') as f:
        load_array = pickle.load(f)

    print(len(load_array[0]))

    bestControl_1[0] = load_array[0][i]
    bestState_1[0] = load_array[1][i]
    cost_1 [0]= load_array[2][i]
    runtime_1[0] = load_array[3][i]
    grad_1 [0]= load_array[4][i]
    phi_1[0] = load_array[5][i]
    costnode_1[0] = load_array[6][i]
    weights_1[0] = load_array[7][i]
# Out:
# init file found
# 147

# %%
if os.path.isfile(final_file_1) :
    print("final file found")
    
    with open(final_file_1,'rb') as f:
        load_array = pickle.load(f)

    print(len(load_array[0]))

    bestControl_1 = load_array[0]
    bestState_1 = load_array[1]
    cost_1 = load_array[2]
    runtime_1 = load_array[3]
    grad_1 = load_array[4]
    phi_1 = load_array[5]
    costnode_1 = load_array[6]
    weights_1 = load_array[7]

# %%
# get initial parameters and target states

print("------- ", i, exc[i], inh[i])
aln.params.ext_exc_current = exc[i] * 5.
aln.params.ext_inh_current = inh[i] * 5.

aln.params.duration = 3000.

control0 = aln.getZeroControl()
control0 = functions.step_control(aln, maxI_ = max_I[0])

aln.run(control=control0)

target_rates = np.zeros((2))
target_rates[0] = aln.rates_exc[0,-1] 
target_rates[1] = aln.rates_inh[0,-1]

control0 = functions.step_control(aln, maxI_ = max_I[1])
aln.run(control=control0)

init_state_vars = np.zeros(( len(state_vars) ))
for j in range(len(state_vars)):
    if aln.state[state_vars[j]].size == 1:
        init_state_vars[j] = aln.state[state_vars[j]][0]
    else:
        init_state_vars[j] = aln.state[state_vars[j]][0,-1]

initVars[i] = init_state_vars

aln.params.duration = dur

target[i] = aln.getZeroTarget()
target[i][:,0,:] = target_rates[0]
target[i][:,1,:] = target_rates[1]
# Out:
# -------  20 0.4500000000000001 0.4750000000000002

# %%
# get uncontrolled cost

data.set_parameters(aln)
aln.params.ext_exc_current = exc[i] * 5.
aln.params.ext_inh_current = inh[i] * 5.
aln.params.duration = dur

cgv = None

# %%
print(np.argmax(np.abs(bestControl_1[0]), axis=2))
print(bestControl_1[0][0,1,1000:1700:20]/5.)

max_percent = (np.argmax(np.abs(bestControl_1[0]), axis=2)[0,1] -100) / 3800
print(max_percent)
# Out:
# [[1711 1657    0    0    0    0]]
# [-0.00210008 -0.00230754 -0.0025357  -0.00278996 -0.00308148 -0.00342206
#  -0.00435344 -0.00482297 -0.00533246 -0.00589373 -0.00650912 -0.00719364
#  -0.00795574 -0.00880522 -0.00975432 -0.0108192  -0.01201979 -0.01337018
#  -0.01488114 -0.01659439 -0.0185507  -0.02079193 -0.02335371 -0.026315
#  -0.02975702 -0.03385268 -0.03896993 -0.04576486 -0.05513826 -0.06769919
#  -0.08278901 -0.09777724 -0.1087061  -0.11201214 -0.10595553]
# 0.4097368421052632

# %%
factor_iteration = 1.

##### initial guess
weight_ = 1.
cost.setParams(weight_ * factor_wp, weight_ * factor_we, weight_ * factor_ws)

setinit(initVars[i], aln)

weights_1[0] = cost.getParams()

for j in range(1, 381):

    dur = 400. - np.around(j/10., 1)
    T = 4001 - j
    aln.params.duration = dur

    factor_wp = dur / 20.
    cost.setParams(weight_ * factor_wp, weight_ * factor_we, weight_ * factor_ws)

    print('-----', j)
    setinit(initVars[i], aln)

    max_it = 3.
    if j > 250:
        max_it = 40.
    elif j > 200:
        max_it = 30.
    elif j > 100.:
        max_it = 10.
    
    if type(bestControl_1[j]) == type(None):
        total_shift = round(j * max_percent * 10)
        prev_shift = round( (j-1) * max_percent * 10)
        shift_ind = total_shift - prev_shift
        #print(total_shift, prev_shift, shift_ind)
        control0 = np.zeros(( bestControl_1[j-1][:,:,100:-101].shape ))
        control0[:,:,:-shift_ind] = 1. * bestControl_1[j-1][:,:,100+shift_ind:-101]
    else:
        if bestControl_1[j].shape[2] == T+200:
            control0 = bestControl_1[j][:,:,100:-100]
        else:
            control0 = bestControl_1[j][:,:,100:-(100+j)]

    bestControl_1[j], bestState_1[j], cost_1[j], runtime_1[j], grad_1[j], phi_1[j], costnode_1[j] = aln.A1(
        control0, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = [0,1],
        prec_variables_ = prec_vars, transition_time_ = t_pen[j])

    print(costnode_1[j][0][0][0], costnode_1[j][2][0][1])

    print(costnode_1[0][0][0][0], costnode_1[0][2][0][1])
        
    with open(final_file_1,'wb') as f:
        pickle.dump([bestControl_1, bestState_1, cost_1, runtime_1, grad_1, phi_1,
                costnode_1, weights_1], f)
# Out:
# set cost params:  20.0 1.0 0.0
# set cost params:  19.994999999999997 1.0 0.0
# ----- 1
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.5521399325439047
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.552090656290715
# RUN  2 , total integrated cost =  3.55209064126111
# RUN  3 , total integrated cost =  3.552090641223742
# RUN  3 , total integrated cost =  3.552090641223742
# Improved over  3  iterations in  20.259042359997693  seconds by  0.0013876514185540145  percent.
# 1.745721978548565e-06 2.070501407942441
# 9.165187696302029e-07 2.070501409603934
# set cost params:  19.990000000000002 1.0 0.0
# ----- 2
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.552152281912287
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.5521095583695437
# RUN  2 , total integrated cost =  3.5521095479315776
# RUN  3 , total integrated cost =  3.552109547697372
# RUN  3 , total integrated cost =  3.552109547697372
# Improved over  3  iterations in  1.7392560430016601  seconds by  0.0012030513199619008  percent.
# 2.6902901193916762e-06 2.070501405421367
# 9.165187696302029e-07 2.070501409603934
# set cost params:  19.985 1.0 0.0
# ----- 3
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.552180278055155
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.5521329396966927
# RUN  2 , total integrated cost =  3.5521329336530303
# RUN  3 , total integrated cost =  3.5521329334516114
# RUN  3 , total integrated cost =  3.5521329334516114
# Improved over  3  iterations in  1.4423555989997112  seconds by  0.0013328322280159455  percent.
# 3.859105286307082e-06 2.0705014287263444
# 9.165187696302029e-07 2.070501409603934
# set cost params:  19.98 1.0 0.0
# ----- 4
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.552195158814587
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.5521549722881733
# RUN  2 , total integrated cost =  3.5521549720362424
# RUN  3 , total integrated cost =  3.55215497178578
# RUN  3 , total integrated cost =  3.55215497178578
# Improved over  3  iterations in  1.0492583859995648  seconds by  0.0011313294177313082  percent.
# 4.960789499312858e-06 2.0705014262569463
# 9.165187696302029e-07 2.070501409603934
# set cost params:  19.975 1.0 0.0
# ----- 5
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.5522067891154734
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.5521743804272727
# RUN  2 , total integrated cost =  3.552174379687292
# RUN  3 , total integrated cost =  3.5521743790585183
# RUN  3 , total integrated cost =  3.5521743790585183
# Improved over  3  iterations in  1.1215087519994995  seconds by  0.000912392179813537  percent.
# 5.931163149105214e-06 2.070501453447573
# 9.165187696302029e-07 2.070501409603934
# set cost params:  19.97 1.0 0.0
# ----- 6
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.552218101936259
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.5521888153272223
# RUN  2 , total integrated cost =  3.5521888107387354
# RUN  3 , total integrated cost =  3.552151374458581
# RUN  3 , total integrated cost =  3.552151374458581
# Improved over  3  iterations in  1.0112896530008584  seconds by  0.0018784735554788767  percent.
# 2.3004094780735e-06 2.070501470277319
# 9.165187696302029e-07 2.070501409603934
# set cost params:  19.965 1.0 0.0
# ----- 7
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.5521534762942
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.552069288775231
# RUN  2 , total integrated cost =  3.5520629324176625
# RUN  3 , total integrated cost =  3.552062930253476
# RUN  3 , total integrated cost =  3.552062930253476
# Improved over  3  iterations in  0.930994266000198  seconds by  0.0025490464116728617  percent.
# 3.333196006244708e-07 2.070501091648409
# 9.165187696302029e-07 2.070501409603934
# set cost params:  19.96 1.0 0.0
# ----- 8
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.552065068218143
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.55206399555651
# RUN  2 , total integrated cost =  3.5520639943103545
# RUN  3 , total integrated cost =  3.5520639930190994
# RUN  3 , total integrated cost =  3.5520639930190994
# Improved over  3  iterations in  1.0395238780001819  seconds by  3.0269688849671184e-05  percent.
# 3.8291711929230225e-07 2.0705011316287654
# 9.165187696302029e-07 2.070501409603934
# set cost params:  19.955000000000002 1.0 0.0
# ----- 9
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.5520662772887226
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.552065178075334
# RUN  2 , total integrated cost =  3.552065175792918
# RUN  3 , total integrated cost =  3.552065173563903
# RUN  3 , total integrated cost =  3.552065173563903
# Improved over  3  iterations in  0.9674249419986154  seconds by  3.1072754097749566e-05  percent.
# 4.3761699858216176e-07 2.070501179832307
# 9.165187696302029e-07 2.070501409603934
# set cost params:  19.95 1.0 0.0
# ----- 10
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.552067258099032
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.552066325646921
# RUN  2 , total integrated cost =  3.5520662912909255
# RUN  3 , total integrated cost =  3.552066251292449
# RUN  3 , total integrated cost =  3.552066251292449
# Improved over  3  iterations in  0.9631662200008577  seconds by  2.8344243219180498e-05  percent.
# 4.868866506745756e-07 2.0705012313337425
# 9.165187696302029e-07 2.070501409603934
# set cost params:  19.945 1.0 0.0
# ----- 11
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.5520681031457904
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.5520672711205012
# RUN  2 , total integrated cost =  3.5520672611882342
# RUN  3 , total integrated cost =  3.552067252437529
# RUN  3 , total integrated cost =  3.552067252437529
# Improved over  3  iterations in  0.8598714509971614  seconds by  2.3949660771904746e-05  percent.
# 5.314954489151647e-07 2.070501260010183
# 9.165187696302029e-07 2.070501409603934
# set cost params:  19.94 1.0 0.0
# ----- 12
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.5520687495204224
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.5520681191933523
# RUN  2 , total integrated cost =  3.5520608171325287
# RUN  3 , total integrated cost =  3.5520580569909486
# RUN  3 , total integrated cost =  3.5520580569909486
# Improved over  3  iterations in  0.8549292749994493  seconds by  0.0003010225935327071  percent.
# 5.5690141560099034e-08 2.070502105471302
# 9.165187696302029e-07 2.070501409603934
# set cost params:  19.935 1.0 0.0
# ----- 13
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.5520583903960516
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.552058250764511
# RUN  2 , total integrated cost =  3.55205823695454
# RUN  3 , total integrated cost =  3.5520582244605765
# RUN  3 , total integrated cost =  3.5520582244605765
# Improved over  3  iterations in  0.8728310920014337  seconds by  4.671530049904504e-06  percent.
# 5.879527408262564e-08 2.0705021820588496
# 9.165187696302029e-07 2.070501409603934
# set cost params:  19.93 1.0 0.0
# ----- 14
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.5520585760789016
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.552058453772844
# RUN  2 , total integrated cost =  3.552058438919948
# RUN  3 , total integrated cost =  3.552058425391033
# RUN  3 , total integrated cost =  3.552058425391033
# Improved over  3  iterations in  0.9625260709981376  seconds by  4.242268687448814e-06  percent.
# 6.347557728438331e-08 2.0705022392120362
# 9.165187696302029e-07 2.070501409603934
# set cost params:  19.925 1.0 0.0
# ----- 15
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.552058893450728
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.552058729325221
# RUN  2 , total integrated cost =  3.552058723621662
# RUN  3 , total integrated cost =  3.552058718889858
# RUN  3 , total integrated cost =  3.552058718889858
# Improved over  3  iterations in  1.1764337650020025  seconds by  4.914357418783766e-06  percent.
# 7.117494181319502e-08 2.070502312131756
# 9.165187696302029e-07 2.070501409603934
# set cost params:  19.919999999999998 1.0 0.0
# ----- 16
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.552059144342247
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.5520590024546417
# RUN  2 , total integrated cost =  3.5520589947337626
# RUN  3 , total integrated cost =  3.552058986140956
# RUN  3 , total integrated cost =  3.552058986140956
# Improved over  3  iterations in  1.1109257930002059  seconds by  4.453791007108521e-06  percent.
# 7.830180314615542e-08 2.070502379883056
# 9.165187696302029e-07 2.070501409603934
# set cost params:  19.915 1.0 0.0
# ----- 17
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.552059476724688
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.552059303895439
# RUN  2 , total integrated cost =  3.5520592819948846
# RUN  3 , total integrated cost =  3.5520592638650053
# RUN  3 , total integrated cost =  3.5520592638650053
# Improved over  3  iterations in  1.2649786260008113  seconds by  5.9925709052777165e-06  percent.
# 8.361896099612537e-08 2.0705024678858006
# 9.165187696302029e-07 2.070501409603934
# set cost params:  19.91 1.0 0.0
# ----- 18
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.5520597049341474
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.5520595701319273
# RUN  2 , total integrated cost =  3.5520595556792607
# RUN  3 , total integrated cost =  3.5520595426046793
# RUN  3 , total integrated cost =  3.5520595426046793
# Improved over  3  iterations in  0.8974957560021721  seconds by  4.570009565441069e-06  percent.
# 8.926875083530008e-08 2.070502555658719
# 9.165187696302029e-07 2.070501409603934
# set cost params:  19.905 1.0 0.0
# ----- 19
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.552059965616002
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.55205984024058
# RUN  2 , total integrated cost =  3.552059585501151
# RUN  3 , total integrated cost =  3.5520594133659684
# RUN  3 , total integrated cost =  3.5520594133659684
# Improved over  3  iterations in  0.809506636000151  seconds by  1.554731730379899e-05  percent.
# 7.387484406997324e-08 2.070502802249669
# 9.165187696302029e-07 2.070501409603934
# set cost params:  19.9 1.0 0.0
# ----- 20
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.5520597948767323
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.552059694983712
# RUN  2 , total integrated cost =  3.552059679656173
# RUN  3 , total integrated cost =  3.5520596660053005
# RUN  3 , total integrated cost =  3.5520596660053005
# Improved over  3  iterations in  1.0492620910008554  seconds by  3.628076086670262e-06  percent.
# 7.807710696456448e-08 2.070502891795438
# 9.165187696302029e-07 2.070501409603934
# set cost params:  19.895 1.0 0.0
# ----- 21
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.5520600096819255
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.55205992371042
# RUN  2 , total integrated cost =  3.552059880940616
# RUN  3 , total integrated cost =  3.5520598433396025
# RUN  3 , total integrated cost =  3.5520598433396025
# Improved over  3  iterations in  1.6313793099980103  seconds by  4.6829817819116215e-06  percent.
# 7.886458745814691e-08 2.0705028870140603
# 9.165187696302029e-07 2.070501409603934
# set cost params:  19.89 1.0 0.0
# ----- 22
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.5520602665090335
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.5520601492993387
# RUN  2 , total integrated cost =  3.552060071086212
# RUN  3 , total integrated cost =  3.5520600119057577
# RUN  3 , total integrated cost =  3.5520600119057577
# Improved over  3  iterations in  1.7455239810005878  seconds by  7.167763399706928e-06  percent.
# 7.718826790718839e-08 2.0705029921678606
# 9.165187696302029e-07 2.070501409603934
# set cost params:  19.884999999999998 1.0 0.0
# ----- 23
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.5520604321811593
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.552060323959201
# RUN  2 , total integrated cost =  3.552060239023156
# RUN  3 , total integrated cost =  3.5520601761196673
# RUN  3 , total integrated cost =  3.5520601761196673
# Improved over  3  iterations in  1.4616331630022614  seconds by  7.208815759440768e-06  percent.
# 7.517961338373523e-08 2.070502987011442
# 9.165187696302029e-07 2.070501409603934
# set cost params:  19.880000000000003 1.0 0.0
# ----- 24
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.5520606023741967
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.552060493076567
# RUN  2 , total integrated cost =  3.552059333012952
# RUN  3 , total integrated cost =  3.552059218634512
# RUN  3 , total integrated cost =  3.552059218634512
# Improved over  3  iterations in  1.375177750000148  seconds by  3.895597060932232e-05  percent.
# 2.6734195695752104e-08 2.0705036732481026
# 9.165187696302029e-07 2.070501409603934
# set cost params:  19.875 1.0 0.0
# ----- 25
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.5520596171179095
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.5520594858439716
# RUN  2 , total integrated cost =  3.5520594153722267
# RUN  3 , total integrated cost =  3.552059353980611
# RUN  3 , total integrated cost =  3.552059353980611
# Improved over  3  iterations in  1.7446351189973939  seconds by  7.408020337607013e-06  percent.
# 2.512191527564686e-08 2.070503781918526
# 9.165187696302029e-07 2.070501409603934
# set cost params:  19.869999999999997 1.0 0.0
# ----- 26
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.552059776284316
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.552059654372805
# RUN  2 , total integrated cost =  3.5520596507379976
# RUN  3 , total integrated cost =  3.552059647394687
# RUN  3 , total integrated cost =  3.552059647394687
# Improved over  3  iterations in  1.5831197680017794  seconds by  3.6285884021936e-06  percent.
# 2.9586395098348037e-08 2.070503891955254
# 9.165187696302029e-07 2.070501409603934
# set cost params:  19.865000000000002 1.0 0.0
# ----- 27
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.5520600867053043
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.552059975827944
# RUN  2 , total integrated cost =  3.552059841266622
# RUN  3 , total integrated cost =  3.5520597438831225
# RUN  3 , total integrated cost =  3.5520597438831225
# Improved over  3  iterations in  1.3827620899974136  seconds by  9.651362120166596e-06  percent.
# 2.8327204835018478e-08 2.070504105397603
# 9.165187696302029e-07 2.070501409603934
# set cost params:  19.86 1.0 0.0
# ----- 28
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.55206030338829
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.5520601418982856
# RUN  2 , total integrated cost =  3.5520600005617773
# RUN  3 , total integrated cost =  3.552059878066136
# RUN  3 , total integrated cost =  3.552059878066136
# Improved over  3  iterations in  1.2649945780030976  seconds by  1.1973956446809098e-05  percent.
# 2.8193603917828686e-08 2.0705042312876527
# 9.165187696302029e-07 2.070501409603934
# set cost params:  19.855 1.0 0.0
# ----- 29
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.552060511229501
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.552060298127876
# RUN  2 , total integrated cost =  3.5520602948419744
# RUN  3 , total integrated cost =  3.552060291928366
# RUN  3 , total integrated cost =  3.552060291928366
# Improved over  3  iterations in  1.2245274859997153  seconds by  6.1739132632965266e-06  percent.
# 3.443836444154431e-08 2.070504382195871
# 9.165187696302029e-07 2.070501409603934
# set cost params:  19.85 1.0 0.0
# ----- 30
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.5520609402260708
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.552060759961944
# RUN  2 , total integrated cost =  3.5520607491273624
# RUN  3 , total integrated cost =  3.552060738432299
# RUN  3 , total integrated cost =  3.552060738432299
# Improved over  3  iterations in  1.4269909360009478  seconds by  5.6810334996271195e-06  percent.
# 4.325661498726769e-08 2.0705045284175676
# 9.165187696302029e-07 2.070501409603934
# set cost params:  19.845 1.0 0.0
# ----- 31
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.552061425204324
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.5520612292195963
# RUN  2 , total integrated cost =  3.5520611573750367
# RUN  3 , total integrated cost =  3.552061085136952
# RUN  3 , total integrated cost =  3.552061085136952
# Improved over  3  iterations in  1.1663269860000582  seconds by  9.573803254170343e-06  percent.
# 4.691287296530936e-08 2.0705046823867
# 9.165187696302029e-07 2.070501409603934
# set cost params:  19.84 1.0 0.0
# ----- 32
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.5520616723632834
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.552061515126979
# RUN  2 , total integrated cost =  3.552061402199531
# RUN  3 , total integrated cost =  3.552061285072253
# RUN  3 , total integrated cost =  3.552061285072253
# Improved over  3  iterations in  0.9138184000003093  seconds by  1.0903274386464545e-05  percent.
# 4.584744956073135e-08 2.0705048267997537
# 9.165187696302029e-07 2.070501409603934
# set cost params:  19.835 1.0 0.0
# ----- 33
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.552062007257269
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.552061787359664
# RUN  2 , total integrated cost =  3.5520617596463495
# RUN  3 , total integrated cost =  3.552061728958457
# RUN  3 , total integrated cost =  3.552061728958457
# Improved over  3  iterations in  1.0721623150020605  seconds by  7.834852297605721e-06  percent.
# 5.2355716426632315e-08 2.0705049988399415
# 9.165187696302029e-07 2.070501409603934
# set cost params:  19.830000000000002 1.0 0.0
# ----- 34
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.552062491187475
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.55206226315719
# RUN  2 , total integrated cost =  3.5520622456221287
# RUN  3 , total integrated cost =  3.5520622301117557
# RUN  3 , total integrated cost =  3.5520622301117557
# Improved over  3  iterations in  0.942717066998739  seconds by  7.349975390980035e-06  percent.
# 5.779616670859441e-08 2.070505202847822
# 9.165187696302029e-07 2.070501409603934
# set cost params:  19.825 1.0 0.0
# ----- 35
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.5520629695473724
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.552062790625951
# RUN  2 , total integrated cost =  3.552062122304695
# RUN  3 , total integrated cost =  3.5520617784212276
# RUN  3 , total integrated cost =  3.5520617784212276
# Improved over  3  iterations in  0.7671141949977027  seconds by  3.3533362298499014e-05  percent.
# 2.9672927410090737e-08 2.070505382143234
# 9.165187696302029e-07 2.070501409603934
# set cost params:  19.82 1.0 0.0
# ----- 36
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.552062423995568
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.5520622342612964
# RUN  2 , total integrated cost =  3.5520622268081885
# RUN  3 , total integrated cost =  3.5520622201448293
# RUN  3 , total integrated cost =  3.5520622201448293
# Improved over  3  iterations in  0.9509536599980493  seconds by  5.738940203059428e-06  percent.
# 3.5030686215197293e-08 2.07050556242906
# 9.165187696302029e-07 2.070501409603934
# set cost params:  19.815 1.0 0.0
# ----- 37
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.5520629089287907
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.552062743147161
# RUN  2 , total integrated cost =  3.5520627085615675
# RUN  3 , total integrated cost =  3.552062680707034
# RUN  3 , total integrated cost =  3.552062680707034
# Improved over  3  iterations in  1.0585314390009444  seconds by  6.425048269420586e-06  percent.
# 4.2495310480973244e-08 2.070505736443274
# 9.165187696302029e-07 2.070501409603934
# set cost params:  19.81 1.0 0.0
# ----- 38
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.5520635787936716
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.552063339446964
# RUN  2 , total integrated cost =  3.5520632405123913
# RUN  3 , total integrated cost =  3.5520631343062017
# RUN  3 , total integrated cost =  3.5520631343062017
# Improved over  3  iterations in  0.9157630370027618  seconds by  1.251349983988348e-05  percent.
# 4.9258714590689225e-08 2.070505943931016
# 9.165187696302029e-07 2.070501409603934
# set cost params:  19.805 1.0 0.0
# ----- 39
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.552064111666234
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.5520638198411967
# RUN  2 , total integrated cost =  3.5520637646180298
# RUN  3 , total integrated cost =  3.5520637188051785
# RUN  3 , total integrated cost =  3.5520637188051785
# Improved over  3  iterations in  1.4186772190005286  seconds by  1.1060077838465077e-05  percent.
# 5.619913321582696e-08 2.0705061905780515
# 9.165187696302029e-07 2.070501409603934
# set cost params:  19.8 1.0 0.0
# ----- 40
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.552064700651702
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.5520644403363972
# RUN  2 , total integrated cost =  3.552064399165663
# RUN  3 , total integrated cost =  3.5520643627862603
# RUN  3 , total integrated cost =  3.5520643627862603
# Improved over  3  iterations in  0.982320619001257  seconds by  9.511804265116552e-06  percent.
# 6.495329467167016e-08 2.070506441732086
# 9.165187696302029e-07 2.070501409603934
# set cost params:  19.794999999999998 1.0 0.0
# ----- 41
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.552065197778288
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.552065010092347
# RUN  2 , total integrated cost =  3.5520641297764386
# RUN  3 , total integrated cost =  3.5520637228752676
# RUN  3 , total integrated cost =  3.5520637228752676
# Improved over  3  iterations in  0.815118626000185  seconds by  4.152240846622135e-05  percent.
# 3.4117484817209767e-08 2.0705064313637065
# 9.165187696302029e-07 2.070501409603934
# set cost params:  19.79 1.0 0.0
# ----- 42
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.552064763235017
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.5520644192826523
# RUN  2 , total integrated cost =  3.552064389923217
# RUN  3 , total integrated cost =  3.5520643587468457
# RUN  3 , total integrated cost =  3.5520643587468457
# Improved over  3  iterations in  0.7890326349988754  seconds by  1.1387409813323757e-05  percent.
# 4.2883060783141596e-08 2.0705066812576502
# 9.165187696302029e-07 2.070501409603934
# set cost params:  19.785 1.0 0.0
# ----- 43
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.5520655727133135
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.5520652164362505
# RUN  2 , total integrated cost =  3.5520651888541894
# RUN  3 , total integrated cost =  3.552065166432818
# RUN  3 , total integrated cost =  3.552065166432818
# Improved over  3  iterations in  0.997520238001016  seconds by  1.1437865865104868e-05  percent.
# 5.6781049702892996e-08 2.0705069645738807
# 9.165187696302029e-07 2.070501409603934
# set cost params:  19.78 1.0 0.0
# ----- 44
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.552066463553069
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.5520661153998283
# RUN  2 , total integrated cost =  3.552066070966761
# RUN  3 , total integrated cost =  3.5520660321517186
# RUN  3 , total integrated cost =  3.5520660321517186
# Improved over  3  iterations in  0.9981229670011089  seconds by  1.2145081043968275e-05  percent.
# 7.162760316477365e-08 2.070507264684632
# 9.165187696302029e-07 2.070501409603934
# set cost params:  19.775 1.0 0.0
# ----- 45
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.5520671414072815
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.5520668882050006
# RUN  2 , total integrated cost =  3.5520659648809407
# RUN  3 , total integrated cost =  3.552065540485714
# RUN  3 , total integrated cost =  3.552065540485714
# Improved over  3  iterations in  0.8807117780015687  seconds by  4.507013812826699e-05  percent.
# 4.166906363861905e-08 2.070507838284169
# 9.165187696302029e-07 2.070501409603934
# set cost params:  19.77 1.0 0.0
# ----- 46
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.5520668338340076
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.552066449424751
# RUN  2 , total integrated cost =  3.5520664328023934
# RUN  3 , total integrated cost =  3.5520664145946825
# RUN  3 , total integrated cost =  3.5520664145946825
# Improved over  3  iterations in  0.9052818929994828  seconds by  1.180268685629926e-05  percent.
# 5.9048617115306226e-08 2.0705081182189615
# 9.165187696302029e-07 2.070501409603934
# set cost params:  19.765 1.0 0.0
# ----- 47
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.552067782940263
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.552067365256469
# RUN  2 , total integrated cost =  3.5520665568376897
# RUN  3 , total integrated cost =  3.5520660760194502
# RUN  3 , total integrated cost =  3.5520660760194502
# Improved over  3  iterations in  0.9050797409981897  seconds by  4.80542860401556e-05  percent.
# 3.4548228785350386e-08 2.07050843577395
# 9.165187696302029e-07 2.070501409603934
# set cost params:  19.759999999999998 1.0 0.0
# ----- 48
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.552067597614433
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.552067154153913
# RUN  2 , total integrated cost =  3.5520671216095803
# RUN  3 , total integrated cost =  3.552067087829472
# RUN  3 , total integrated cost =  3.552067087829472
# Improved over  3  iterations in  0.7764450750000833  seconds by  1.4351780961874283e-05  percent.
# 5.873387950231913e-08 2.0705087286533357
# 9.165187696302029e-07 2.070501409603934
# set cost params:  19.755000000000003 1.0 0.0
# ----- 49
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.552068717011757
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.5520682394416814
# RUN  2 , total integrated cost =  3.5520681870521047
# RUN  3 , total integrated cost =  3.5520681418771254
# RUN  3 , total integrated cost =  3.5520681418771254
# Improved over  3  iterations in  1.0258183789992472  seconds by  1.6191540126442305e-05  percent.
# 8.009982117886429e-08 2.070509065444631
# 9.165187696302029e-07 2.070501409603934
# set cost params:  19.75 1.0 0.0
# ----- 50
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.5520701779257475
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.552069597287251
# RUN  2 , total integrated cost =  3.552069116544787
# RUN  3 , total integrated cost =  3.5520686738770193
# RUN  3 , total integrated cost =  3.5520686738770193
# Improved over  3  iterations in  0.9034658790005778  seconds by  4.234287762017175e-05  percent.
# 7.709411058414485e-08 2.0705094444740513
# 9.165187696302029e-07 2.070501409603934
# set cost params:  19.744999999999997 1.0 0.0
# ----- 51
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.552070669562251
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.552070066606488
# RUN  2 , total integrated cost =  3.5520700215551297
# RUN  3 , total integrated cost =  3.552069983393838
# RUN  3 , total integrated cost =  3.552069983393838
# Improved over  3  iterations in  1.0783415910009353  seconds by  1.9317420097308968e-05  percent.
# 1.0216933422358292e-07 2.0705098684901597
# 9.165187696302029e-07 2.070501409603934
# set cost params:  19.740000000000002 1.0 0.0
# ----- 52
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.5520717125308097
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.552071292155725
# RUN  2 , total integrated cost =  3.552070271221754
# RUN  3 , total integrated cost =  3.5520696130244014
# RUN  3 , total integrated cost =  3.5520696130244014
# Improved over  3  iterations in  0.8808949750018655  seconds by  5.9106532134478584e-05  percent.
# 6.619162744959783e-08 2.0705098526343932
# 9.165187696302029e-07 2.070501409603934
# set cost params:  19.735 1.0 0.0
# ----- 53
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.5520716756026895
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.552070988614706
# RUN  2 , total integrated cost =  3.5520708412250825
# RUN  3 , total integrated cost =  3.5520706923849077
# RUN  3 , total integrated cost =  3.5520706923849077
# Improved over  3  iterations in  0.9084074500024144  seconds by  2.768012224407812e-05  percent.
# 8.261948219479595e-08 2.0705102892876694
# 9.165187696302029e-07 2.070501409603934
# set cost params:  19.73 1.0 0.0
# ----- 54
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.552073009015952
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.552072308135351
# RUN  2 , total integrated cost =  3.552070791927867
# RUN  3 , total integrated cost =  3.552070156657526
# RUN  3 , total integrated cost =  3.552070156657526
# Improved over  3  iterations in  0.7771723519981606  seconds by  8.030123306923542e-05  percent.
# 4.257158308060543e-08 2.0705107571699224
# 9.165187696302029e-07 2.070501409603934
# set cost params:  19.725 1.0 0.0
# ----- 55
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.5520719621347374
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.5520714292958937
# RUN  2 , total integrated cost =  3.5520714107429856
# RUN  3 , total integrated cost =  3.552071394064855
# RUN  3 , total integrated cost =  3.552071394064855
# Improved over  3  iterations in  1.1347141619989998  seconds by  1.5992634388339866e-05  percent.
# 6.777839183884536e-08 2.0705111466292245
# 9.165187696302029e-07 2.070501409603934
# set cost params:  19.72 1.0 0.0
# ----- 56
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.552074135754178
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.5520733484812004
# RUN  2 , total integrated cost =  3.55207321965021
# RUN  3 , total integrated cost =  3.55207308937002
# RUN  3 , total integrated cost =  3.55207308937002
# Improved over  3  iterations in  0.9500506820004375  seconds by  2.9458398614679027e-05  percent.
# 1.1156526388641414e-07 2.070511611186517
# 9.165187696302029e-07 2.070501409603934
# set cost params:  19.715 1.0 0.0
# ----- 57
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.552075830635392
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.5520749870927855
# RUN  2 , total integrated cost =  3.5520742202715136
# RUN  3 , total integrated cost =  3.5520735220382162
# RUN  3 , total integrated cost =  3.5520735220382162
# Improved over  3  iterations in  1.2013373160007177  seconds by  6.49929023381901e-05  percent.
# 9.639410791878249e-08 2.0705121172074032
# 9.165187696302029e-07 2.070501409603934
# set cost params:  19.71 1.0 0.0
# ----- 58
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.552075981241679
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.552075280437537
# RUN  2 , total integrated cost =  3.5520751114074485
# RUN  3 , total integrated cost =  3.5520749752515273
# RUN  3 , total integrated cost =  3.5520749752515273
# Improved over  3  iterations in  1.1133021929999813  seconds by  2.8321188977997735e-05  percent.
# 1.2378991175539758e-07 2.070512609923394
# 9.165187696302029e-07 2.070501409603934
# set cost params:  19.705000000000002 1.0 0.0
# ----- 59
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.5520781293220827
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.5520772407521455
# RUN  2 , total integrated cost =  3.552074301449836
# RUN  3 , total integrated cost =  3.552074040131835
# RUN  3 , total integrated cost =  3.552074040131835
# Improved over  3  iterations in  1.4356941449987062  seconds by  0.00011512106713951198  percent.
# 5.209004482514847e-08 2.070512903264843
# 9.165187696302029e-07 2.070501409603934
# set cost params:  19.7 1.0 0.0
# ----- 60
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.552076599613965
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.552075812795853
# RUN  2 , total integrated cost =  3.5520757144742716
# RUN  3 , total integrated cost =  3.5520756091954033
# RUN  3 , total integrated cost =  3.5520756091954033
# Improved over  3  iterations in  1.1015740719994938  seconds by  2.7882804147338902e-05  percent.
# 8.876957048176053e-08 2.070513386132573
# 9.165187696302029e-07 2.070501409603934
# set cost params:  19.695 1.0 0.0
# ----- 61
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.552078675062425
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.552077779975264
# RUN  2 , total integrated cost =  3.5520748085790848
# RUN  3 , total integrated cost =  3.5520745574264008
# RUN  3 , total integrated cost =  3.5520745574264008
# Improved over  3  iterations in  1.1542187589984678  seconds by  0.00011592187000530885  percent.
# 6.672225812540842e-08 2.0705156049894513
# 9.165187696302029e-07 2.070501409603934
# set cost params:  19.69 1.0 0.0
# ----- 62
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.55207844107729
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.5520770778054778
# RUN  2 , total integrated cost =  3.5520769672435244
# RUN  3 , total integrated cost =  3.55207687878328
# RUN  3 , total integrated cost =  3.55207687878328
# Improved over  3  iterations in  0.9571915829983482  seconds by  4.398253123838458e-05  percent.
# 1.3322675264195664e-07 2.0705161325322554
# 9.165187696302029e-07 2.070501409603934
# set cost params:  19.685 1.0 0.0
# ----- 63
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.5520827354938347
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.5520808177684073
# RUN  2 , total integrated cost =  3.552078811177134
# RUN  3 , total integrated cost =  3.5520783973926404
# RUN  3 , total integrated cost =  3.5520783973926404
# Improved over  3  iterations in  1.1515573249998852  seconds by  0.00012212838261405068  percent.
# 1.3971683768823018e-07 2.0705167842958296
# 9.165187696302029e-07 2.070501409603934
# set cost params:  19.68 1.0 0.0
# ----- 64
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.552082895968698
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.552081547611247
# RUN  2 , total integrated cost =  3.5520813006483904
# RUN  3 , total integrated cost =  3.5520811060650916
# RUN  3 , total integrated cost =  3.5520811060650916
# Improved over  3  iterations in  1.1471561079997628  seconds by  5.039025435848998e-05  percent.
# 2.1773964553248755e-07 2.070517403313828
# 9.165187696302029e-07 2.070501409603934
# set cost params:  19.675 1.0 0.0
# ----- 65
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.5520871509346232
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.552085262615193
# RUN  2 , total integrated cost =  3.5520844951735784
# RUN  3 , total integrated cost =  3.55208390915965
# RUN  3 , total integrated cost =  3.55208390915965
# Improved over  3  iterations in  1.0109215839984245  seconds by  9.126394809300109e-05  percent.
# 2.794480149490778e-07 2.0705181885103108
# 9.165187696302029e-07 2.070501409603934
# set cost params:  19.669999999999998 1.0 0.0
# ----- 66
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.5520896954775822
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.552087992397814
# RUN  2 , total integrated cost =  3.5520876981300966
# RUN  3 , total integrated cost =  3.552087439958126
# RUN  3 , total integrated cost =  3.552087439958126
# Improved over  3  iterations in  1.0756319409993012  seconds by  6.349838122332585e-05  percent.
# 3.725745219999402e-07 2.0705181613536245
# 9.165187696302029e-07 2.070501409603934
# set cost params:  19.665 1.0 0.0
# ----- 67
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.5520914367327245
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.5520904215939733
# RUN  2 , total integrated cost =  3.5520879410200856
# RUN  3 , total integrated cost =  3.552086596609866
# RUN  3 , total integrated cost =  3.552086596609866
# Improved over  3  iterations in  1.538300430001982  seconds by  0.0001362612124324869  percent.
# 2.647680864917749e-07 2.070518125933565
# 9.165187696302029e-07 2.070501409603934
# set cost params:  19.66 1.0 0.0
# ----- 68
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.5520917706015456
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.5520901386255552
# RUN  2 , total integrated cost =  3.5520893047410595
# RUN  3 , total integrated cost =  3.552088681538209
# RUN  3 , total integrated cost =  3.552088681538209
# Improved over  3  iterations in  1.4583551030009403  seconds by  8.696462636237356e-05  percent.
# 2.7574725037968966e-07 2.070518096368923
# 9.165187696302029e-07 2.070501409603934
# set cost params:  19.655 1.0 0.0
# ----- 69
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.552092905576243
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.552091868579612
# RUN  2 , total integrated cost =  3.552091122011249
# RUN  3 , total integrated cost =  3.5520905772115325
# RUN  3 , total integrated cost =  3.5520905772115325
# Improved over  3  iterations in  0.9744615569979942  seconds by  6.554909379019591e-05  percent.
# 2.9309429548077887e-07 2.070518065666633
# 9.165187696302029e-07 2.070501409603934
# set cost params:  19.65 1.0 0.0
# ----- 70
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.552095900630316
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.552094459996005
# RUN  2 , total integrated cost =  3.552090835176955
# RUN  3 , total integrated cost =  3.5520892683634555
# RUN  3 , total integrated cost =  3.5520892683634555
# Improved over  3  iterations in  1.030143936000968  seconds by  0.00018671418357030234  percent.
# 1.4335772002748037e-07 2.0705180337829185
# 9.165187696302029e-07 2.070501409603934
# set cost params:  19.645 1.0 0.0
# ----- 71
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.552093948414081
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.5520926881229022
# RUN  2 , total integrated cost =  3.5520921623381443
# RUN  3 , total integrated cost =  3.5520917686519913
# RUN  3 , total integrated cost =  3.5520917686519913
# Improved over  3  iterations in  1.277851096001541  seconds by  6.136555286673229e-05  percent.
# 1.902432995827634e-07 2.0705180006723167
# 9.165187696302029e-07 2.070501409603934
# set cost params:  19.64 1.0 0.0
# ----- 72
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.5520964609729755
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.552095262870587
# RUN  2 , total integrated cost =  3.5520949610290944
# RUN  3 , total integrated cost =  3.5520947267606395
# RUN  3 , total integrated cost =  3.5520947267606395
# Improved over  3  iterations in  1.0600538600010623  seconds by  4.8822219639532705e-05  percent.
# 2.470670954775718e-07 2.0705179662876154
# 9.165187696302029e-07 2.070501409603934
# set cost params:  19.634999999999998 1.0 0.0
# ----- 73
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.552100766639777
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.552099177063334
# RUN  2 , total integrated cost =  3.5520928481805054
# RUN  3 , total integrated cost =  3.5520926852728434
# RUN  3 , total integrated cost =  3.5520926852728434
# Improved over  3  iterations in  1.0196707480026816  seconds by  0.00022750950674321757  percent.
# 1.248342983115737e-07 2.0705179305797854
# 9.165187696302029e-07 2.070501409603934
# set cost params:  19.630000000000003 1.0 0.0
# ----- 74
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.552096855532286
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.5520954614812075
# RUN  2 , total integrated cost =  3.552094424926372
# RUN  3 , total integrated cost =  3.552093746732308
# RUN  3 , total integrated cost =  3.552093746732308
# Improved over  3  iterations in  1.5157116189984663  seconds by  8.752013540913595e-05  percent.
# 1.3749763114732247e-07 2.0705178934979114
# 9.165187696302029e-07 2.070501409603934
# set cost params:  19.625 1.0 0.0
# ----- 75
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.5521012829531986
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.5520988926464323
# RUN  2 , total integrated cost =  3.5520959320959546
# RUN  3 , total integrated cost =  3.5520944552827616
# RUN  3 , total integrated cost =  3.5520944552827616
# Improved over  3  iterations in  1.0597777779985336  seconds by  0.00019221497061039372  percent.
# 1.225997609199622e-07 2.0705190569398964
# 9.165187696302029e-07 2.070501409603934
# set cost params:  19.619999999999997 1.0 0.0
# ----- 76
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.5521024321454022
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.5520997536493217
# RUN  2 , total integrated cost =  3.5520976438766056
# RUN  3 , total integrated cost =  3.5520963222095103
# RUN  3 , total integrated cost =  3.5520963222095103
# Improved over  3  iterations in  1.4221800159975828  seconds by  0.00017200900053637724  percent.
# 1.471915613845713e-07 2.070520215341801
# 9.165187696302029e-07 2.070501409603934
# set cost params:  19.615000000000002 1.0 0.0
# ----- 77
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.5521039012586804
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.552101535609784
# RUN  2 , total integrated cost =  3.5521006822977443
# RUN  3 , total integrated cost =  3.5521001180815346
# RUN  3 , total integrated cost =  3.5521001180815346
# Improved over  3  iterations in  0.9532969069987303  seconds by  0.00010650525015876156  percent.
# 2.3987354562811346e-07 2.070521304326696
# 9.165187696302029e-07 2.070501409603934
# set cost params:  19.61 1.0 0.0
# ----- 78
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.5521093391400638
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.5521065722938605
# RUN  2 , total integrated cost =  3.5521062248645734
# RUN  3 , total integrated cost =  3.552105948481809
# RUN  3 , total integrated cost =  3.552105948481809
# Improved over  3  iterations in  1.0025094500015257  seconds by  9.545478279449071e-05  percent.
# 4.116829646341468e-07 2.0705212501603016
# 9.165187696302029e-07 2.070501409603934
# set cost params:  19.605 1.0 0.0
# ----- 79
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.5521158408397433
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.552113183843063
# RUN  2 , total integrated cost =  3.552110279442722
# RUN  3 , total integrated cost =  3.552108600240816
# RUN  3 , total integrated cost =  3.552108600240816
# Improved over  3  iterations in  1.3502872749995731  seconds by  0.0002038390427401282  percent.
# 4.069619468511658e-07 2.070521204948308
# 9.165187696302029e-07 2.070501409603934
# set cost params:  19.6 1.0 0.0
# ----- 80
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.5521194881343456
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.5521163099787896
# RUN  2 , total integrated cost =  3.5521066598344064
# RUN  3 , total integrated cost =  3.5521064762520624
# RUN  3 , total integrated cost =  3.5521064762520624
# Improved over  3  iterations in  1.0849805690013454  seconds by  0.00036631319207458546  percent.
# 1.3158082221101892e-07 2.0705211885440216
# 9.165187696302029e-07 2.070501409603934
# set cost params:  19.595 1.0 0.0
# ----- 81
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.5521118545056716
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.5521107315820615
# RUN  2 , total integrated cost =  3.55210919321399
# RUN  3 , total integrated cost =  3.5521084842765966
# RUN  3 , total integrated cost =  3.5521084842765966
# Improved over  3  iterations in  1.2856540130014764  seconds by  9.487958749332392e-05  percent.
# 1.9884474086557359e-07 2.070521139785531
# 9.165187696302029e-07 2.070501409603934
# set cost params:  19.59 1.0 0.0
# ----- 82
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.5521196061385916
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.5521162318447512
# RUN  2 , total integrated cost =  3.5521092798045015
# RUN  3 , total integrated cost =  3.5521086073601627
# RUN  3 , total integrated cost =  3.5521086073601627
# Improved over  3  iterations in  1.0470382060011616  seconds by  0.0003096398671402767  percent.
# 1.4385326380656705e-07 2.0705227930643715
# 9.165187696302029e-07 2.070501409603934
# set cost params:  19.585 1.0 0.0
# ----- 83
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.5521163569538445
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.5521138600997744
# RUN  2 , total integrated cost =  3.552111658937398
# RUN  3 , total integrated cost =  3.552111232851711
# RUN  3 , total integrated cost =  3.552111232851711
# Improved over  3  iterations in  1.5301725699973758  seconds by  0.0001442549066155152  percent.
# 2.245789582143102e-07 2.070522740482977
# 9.165187696302029e-07 2.070501409603934
# set cost params:  19.580000000000002 1.0 0.0
# ----- 84
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.5521264088594737
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.552121490918532
# RUN  2 , total integrated cost =  3.5521207936501176
# RUN  3 , total integrated cost =  3.5521202367419025
# RUN  3 , total integrated cost =  3.5521202367419025
# Improved over  3  iterations in  1.5221719080000184  seconds by  0.00017375838753252992  percent.
# 5.152891621352146e-07 2.0705226858744616
# 9.165187696302029e-07 2.070501409603934
# set cost params:  19.575 1.0 0.0
# ----- 85
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.5521357551879333
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.552131239677482
# RUN  2 , total integrated cost =  3.5521212481635285
# RUN  3 , total integrated cost =  3.5521208500858505
# RUN  3 , total integrated cost =  3.5521208500858505
# Improved over  3  iterations in  0.9458014039992122  seconds by  0.00041960958448328256  percent.
# 3.4840490306135623e-07 2.070522629164568
# 9.165187696302029e-07 2.070501409603934
# set cost params:  19.57 1.0 0.0
# ----- 86
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.552134970575939
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.5521300127744335
# RUN  2 , total integrated cost =  3.552128627459343
# RUN  3 , total integrated cost =  3.5521277050759257
# RUN  3 , total integrated cost =  3.5521277050759257
# Improved over  3  iterations in  1.19286351700066  seconds by  0.00020453896243566305  percent.
# 5.118650220965551e-07 2.07052257027243
# 9.165187696302029e-07 2.070501409603934
# set cost params:  19.565 1.0 0.0
# ----- 87
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  3.5521415038887785
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3.552137610620341
# RUN  2 , total integrated cost =  3.5521271439684665
# RUN  3 , total integrated cost =  3.5521247239223888
# ...
# RUN  20 , total integrated cost =  582.3789587416577
# RUN  30 , total integrated cost =  371.2239136944044
# RUN  40 , total integrated cost =  242.0073653852367
# RUN  40 , total integrated cost =  242.0073653852367
# Improved over  40  iterations in  12.777704378000635  seconds by  95.19728562668251  percent.
# 12.25288281415718 2.9718676083232975
# 9.165187696302029e-07 2.070501409603934
# set cost params:  18.145 1.0 0.0
# ----- 371
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5800.84891958002
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2103.7280764596444
# RUN  2 , total integrated cost =  1765.4401732606725
# RUN  3 , total integrated cost =  1549.477849445416
# RUN  4 , total integrated cost =  1388.4800125491722
# RUN  5 , total integrated cost =  1280.0538235801143
# RUN  6 , total integrated cost =  1184.4622619657682
# RUN  7 , total integrated cost =  1101.914023119462
# RUN  8 , total integrated cost =  1044.3695797927016
# RUN  9 , total integrated cost =  994.2877851227177
# RUN  10 , total integrated cost =  948.331423600264
# RUN  11 , total integrated cost =  904.6597167837098
# RUN  12 , total integrated cost =  860.4413656221312
# RUN  13 , total integrated cost =  818.9309454754915
# RUN  14 , total integrated cost =  781.5350537784165
# RUN  15 , total integrated cost =  747.1330896584265
# RUN  16 , total integrated cost =  712.9916565931633
# RUN  17 , total integrated cost =  681.2994988497837
# RUN  18 , total integrated cost =  652.1017507824225
# RUN  19 , total integrated cost =  624.8180792700492
# RUN  20 , total integrated cost =  598.9494288332338
# RUN  30 , total integrated cost =  393.4387767620813
# RUN  40 , total integrated cost =  272.13176889049043
# RUN  40 , total integrated cost =  272.13176889049043
# Improved over  40  iterations in  12.86885292900115  seconds by  95.30875958565402  percent.
# 13.740817678024646 2.854436562123463
# 9.165187696302029e-07 2.070501409603934
# set cost params:  18.14 1.0 0.0
# ----- 372
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  6923.660836713957
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2308.4496701302296
# RUN  2 , total integrated cost =  1946.6980780140775
# RUN  3 , total integrated cost =  1805.9425672139319
# RUN  4 , total integrated cost =  1700.86308488725
# RUN  5 , total integrated cost =  1611.568035038211
# RUN  6 , total integrated cost =  1530.979757837864
# RUN  7 , total integrated cost =  1454.7658110117127
# RUN  8 , total integrated cost =  1381.9158002216757
# RUN  9 , total integrated cost =  1314.4062211957946
# RUN  10 , total integrated cost =  1251.6739145184579
# RUN  11 , total integrated cost =  1191.0436857039058
# RUN  12 , total integrated cost =  1131.2615602666037
# RUN  13 , total integrated cost =  1074.4185940494438
# RUN  14 , total integrated cost =  1026.8682638060009
# RUN  15 , total integrated cost =  980.4066613374732
# RUN  16 , total integrated cost =  932.809196898422
# RUN  17 , total integrated cost =  889.4993799294947
# RUN  18 , total integrated cost =  848.7904434575705
# RUN  19 , total integrated cost =  811.1777583429515
# RUN  20 , total integrated cost =  774.8428249859307
# RUN  30 , total integrated cost =  502.4560999856054
# RUN  40 , total integrated cost =  338.4281687389842
# RUN  40 , total integrated cost =  338.4281687389842
# Improved over  40  iterations in  12.18048216799798  seconds by  95.1120053867398  percent.
# 17.184534404066348 2.761465265331832
# 9.165187696302029e-07 2.070501409603934
# set cost params:  18.134999999999998 1.0 0.0
# ----- 373
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7878.710100506036
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2654.0892488565696
# RUN  2 , total integrated cost =  2275.28983705497
# RUN  3 , total integrated cost =  2124.1042610504487
# RUN  4 , total integrated cost =  2000.4955425135288
# RUN  5 , total integrated cost =  1894.2325016032437
# RUN  6 , total integrated cost =  1794.2727895353016
# RUN  7 , total integrated cost =  1705.144572410169
# RUN  8 , total integrated cost =  1622.4424147295397
# RUN  9 , total integrated cost =  1543.6203003098724
# RUN  10 , total integrated cost =  1470.1158360870784
# RUN  11 , total integrated cost =  1398.147141025882
# RUN  12 , total integrated cost =  1330.5033780150427
# RUN  13 , total integrated cost =  1266.3872008862259
# RUN  14 , total integrated cost =  1207.5506628757992
# RUN  15 , total integrated cost =  1152.155697648503
# RUN  16 , total integrated cost =  1097.6662162724676
# RUN  17 , total integrated cost =  1047.4686965239723
# RUN  18 , total integrated cost =  998.7100876448244
# RUN  19 , total integrated cost =  952.0825930848087
# RUN  20 , total integrated cost =  907.8807333670518
# RUN  30 , total integrated cost =  580.0553613586612
# RUN  40 , total integrated cost =  387.911160449563
# RUN  40 , total integrated cost =  387.911160449563
# Improved over  40  iterations in  12.472469893997186  seconds by  95.07646358983753  percent.
# 19.663555710910025 2.6631258214546727
# 9.165187696302029e-07 2.070501409603934
# set cost params:  18.130000000000003 1.0 0.0
# ----- 374
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  9045.14121193338
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3011.316475790687
# RUN  2 , total integrated cost =  2581.7428064702285
# RUN  3 , total integrated cost =  2415.638767716801
# RUN  4 , total integrated cost =  2286.2861449093502
# RUN  5 , total integrated cost =  2170.46463850817
# RUN  6 , total integrated cost =  2059.303907048036
# RUN  7 , total integrated cost =  1957.2478139002396
# RUN  8 , total integrated cost =  1865.4278330273194
# RUN  9 , total integrated cost =  1778.1317006543582
# RUN  10 , total integrated cost =  1693.0454829413331
# RUN  11 , total integrated cost =  1613.374107755159
# RUN  12 , total integrated cost =  1538.1628660677975
# RUN  13 , total integrated cost =  1467.075406777201
# RUN  14 , total integrated cost =  1398.302514525194
# RUN  15 , total integrated cost =  1332.968094617437
# RUN  16 , total integrated cost =  1272.1307847239366
# RUN  17 , total integrated cost =  1214.5795004533613
# RUN  18 , total integrated cost =  1156.9035327705305
# RUN  19 , total integrated cost =  1102.8342230735802
# RUN  20 , total integrated cost =  1051.3995390746143
# RUN  30 , total integrated cost =  677.5594337991157
# RUN  40 , total integrated cost =  452.8543334226805
# RUN  40 , total integrated cost =  452.8543334226805
# Improved over  40  iterations in  12.092162809000001  seconds by  94.99339675509738  percent.
# 22.947887002569534 2.5649126951337227
# 9.165187696302029e-07 2.070501409603934
# set cost params:  18.125 1.0 0.0
# ----- 375
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  13451.644619824196
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3190.3686109728274
# RUN  2 , total integrated cost =  2441.6229203350654
# RUN  3 , total integrated cost =  2229.6483954912337
# RUN  4 , total integrated cost =  2104.3417837251536
# RUN  5 , total integrated cost =  1999.3892948443984
# RUN  6 , total integrated cost =  1905.2000994549235
# RUN  7 , total integrated cost =  1818.389858059484
# RUN  8 , total integrated cost =  1732.7977117225287
# RUN  9 , total integrated cost =  1653.2022220316842
# RUN  10 , total integrated cost =  1578.7947022827195
# RUN  11 , total integrated cost =  1505.5532721881877
# RUN  12 , total integrated cost =  1429.9741335717188
# RUN  13 , total integrated cost =  1357.894082896189
# RUN  14 , total integrated cost =  1292.072986118184
# RUN  15 , total integrated cost =  1228.6158846081264
# RUN  16 , total integrated cost =  1168.7818469640006
# RUN  17 , total integrated cost =  1110.3053273133805
# RUN  18 , total integrated cost =  1053.3323595286754
# RUN  19 , total integrated cost =  988.0615941429046
# RUN  20 , total integrated cost =  922.1699174908747
# RUN  30 , total integrated cost =  566.1125260664612
# RUN  40 , total integrated cost =  399.3820217734755
# RUN  40 , total integrated cost =  399.3820217734755
# Improved over  40  iterations in  12.263122091993864  seconds by  97.03097998006213  percent.
# 19.616348145146286 2.422132393475737
# 9.165187696302029e-07 2.070501409603934
# set cost params:  18.119999999999997 1.0 0.0
# ----- 376
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12556.148599968987
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4080.2378748069873
# RUN  2 , total integrated cost =  3330.6259000400405
# RUN  3 , total integrated cost =  3116.866364199471
# RUN  4 , total integrated cost =  2970.5767897882283
# RUN  5 , total integrated cost =  2847.9875168997655
# RUN  6 , total integrated cost =  2732.336438843262
# RUN  7 , total integrated cost =  2630.173838346986
# RUN  8 , total integrated cost =  2533.0587898857243
# RUN  9 , total integrated cost =  2442.477667340694
# RUN  10 , total integrated cost =  2354.8385517556026
# RUN  11 , total integrated cost =  2268.9883375028726
# RUN  12 , total integrated cost =  2187.9008460733207
# RUN  13 , total integrated cost =  2104.8857490381033
# RUN  14 , total integrated cost =  2024.0944510591496
# RUN  15 , total integrated cost =  1948.8771286135432
# RUN  16 , total integrated cost =  1872.7944074700904
# RUN  17 , total integrated cost =  1803.5180126316093
# RUN  18 , total integrated cost =  1739.3319518982205
# RUN  19 , total integrated cost =  1679.8045679483355
# RUN  20 , total integrated cost =  1622.1228825712008
# RUN  30 , total integrated cost =  1145.2606534737681
# RUN  40 , total integrated cost =  826.471878903582
# RUN  40 , total integrated cost =  826.471878903582
# Improved over  40  iterations in  12.32335935899755  seconds by  93.41779151207542  percent.
# 42.74899446848166 2.32459575957904
# 9.165187696302029e-07 2.070501409603934
# set cost params:  18.115000000000002 1.0 0.0
# ----- 377
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  16714.938635592152
# Gradient descend method:  None
# RUN  1 , total integrated cost =  7222.488642882486
# RUN  2 , total integrated cost =  6027.576144320158
# RUN  3 , total integrated cost =  5759.945548030859
# RUN  4 , total integrated cost =  5684.892227526917
# RUN  5 , total integrated cost =  5638.704379600335
# RUN  6 , total integrated cost =  5612.630247937356
# RUN  7 , total integrated cost =  5599.8330341684195
# RUN  8 , total integrated cost =  5592.224425513406
# RUN  9 , total integrated cost =  5586.061642399546
# RUN  10 , total integrated cost =  5580.63481629378
# RUN  11 , total integrated cost =  5575.881526831388
# RUN  12 , total integrated cost =  5571.508227748248
# RUN  13 , total integrated cost =  5567.533299620689
# RUN  14 , total integrated cost =  5563.850383257946
# RUN  15 , total integrated cost =  5560.366771419646
# RUN  16 , total integrated cost =  5557.150679142698
# RUN  17 , total integrated cost =  5554.0075455141305
# RUN  18 , total integrated cost =  5551.139372316983
# RUN  19 , total integrated cost =  5548.231232994698
# RUN  20 , total integrated cost =  5545.427695824516
# RUN  30 , total integrated cost =  5528.155974864133
# RUN  40 , total integrated cost =  5512.618310794415
# RUN  40 , total integrated cost =  5512.618310794415
# Improved over  40  iterations in  12.272884592995979  seconds by  67.0198112540117  percent.
# 301.3149501958519 2.3357016899218506
# 9.165187696302029e-07 2.070501409603934
# set cost params:  18.11 1.0 0.0
# ----- 378
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  31075.566067521388
# Gradient descend method:  None
# RUN  1 , total integrated cost =  20365.131437729076
# RUN  2 , total integrated cost =  17816.68027623212
# RUN  3 , total integrated cost =  17018.500679392953
# RUN  4 , total integrated cost =  16609.933080202623
# RUN  5 , total integrated cost =  16338.72877586759
# RUN  6 , total integrated cost =  16151.215381267133
# RUN  7 , total integrated cost =  16041.420409842149
# RUN  8 , total integrated cost =  15951.543298575027
# RUN  9 , total integrated cost =  15879.004776360629
# RUN  10 , total integrated cost =  15816.024773031464
# RUN  11 , total integrated cost =  15766.67038008593
# RUN  12 , total integrated cost =  15723.800401395561
# RUN  13 , total integrated cost =  15683.479800323186
# RUN  14 , total integrated cost =  15646.333137440492
# RUN  15 , total integrated cost =  15616.74346747886
# RUN  16 , total integrated cost =  15587.81965170178
# RUN  17 , total integrated cost =  15562.580562797026
# RUN  18 , total integrated cost =  15539.248458502641
# RUN  19 , total integrated cost =  15516.945548792071
# RUN  20 , total integrated cost =  15495.670131238361
# RUN  30 , total integrated cost =  15397.791974224816
# RUN  40 , total integrated cost =  15340.291466938788
# RUN  40 , total integrated cost =  15340.291466938788
# Improved over  40  iterations in  12.35390619199461  seconds by  50.635520416242116  percent.
# 844.0776975363086 2.275786476970481
# 9.165187696302029e-07 2.070501409603934
# set cost params:  18.105 1.0 0.0
# ----- 379
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  41166.601883965865
# Gradient descend method:  None
# RUN  1 , total integrated cost =  30643.50398242386
# RUN  2 , total integrated cost =  28126.593857961594
# RUN  3 , total integrated cost =  27354.568115581624
# RUN  4 , total integrated cost =  26927.951866233117
# RUN  5 , total integrated cost =  26660.071178686
# RUN  6 , total integrated cost =  26476.628718201537
# RUN  7 , total integrated cost =  26349.41659950171
# RUN  8 , total integrated cost =  26243.798821127584
# RUN  9 , total integrated cost =  26158.488419495126
# RUN  10 , total integrated cost =  26094.076275258354
# RUN  11 , total integrated cost =  26051.468430210218
# RUN  12 , total integrated cost =  26012.467015653165
# RUN  13 , total integrated cost =  25978.21408529352
# RUN  14 , total integrated cost =  25938.190072245336
# RUN  15 , total integrated cost =  25904.422814639962
# RUN  16 , total integrated cost =  25851.05393510723
# RUN  17 , total integrated cost =  25813.365540115454
# RUN  18 , total integrated cost =  25790.948471689713
# RUN  19 , total integrated cost =  25773.809063014247
# RUN  20 , total integrated cost =  25759.20529613397
# RUN  30 , total integrated cost =  25664.332245995312
# RUN  40 , total integrated cost =  25614.529814442223
# RUN  40 , total integrated cost =  25614.529814442223
# Improved over  40  iterations in  11.714969872999063  seconds by  37.77837217013794  percent.
# 1411.8195330400958 2.186517771392746
# 9.165187696302029e-07 2.070501409603934
# set cost params:  18.1 1.0 0.0
# ----- 380
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  54932.50448413935
# Gradient descend method:  None
# RUN  1 , total integrated cost =  42608.21246818995
# RUN  2 , total integrated cost =  39824.690385016984
# RUN  3 , total integrated cost =  38957.48912984206
# RUN  4 , total integrated cost =  38483.356189296064
# RUN  5 , total integrated cost =  38222.87380850381
# RUN  6 , total integrated cost =  38018.78503376242
# RUN  7 , total integrated cost =  37871.54970527622
# RUN  8 , total integrated cost =  37770.81001078347
# RUN  9 , total integrated cost =  37691.121528654156
# RUN  10 , total integrated cost =  37626.27371431173
# RUN  11 , total integrated cost =  37579.26496677392
# RUN  12 , total integrated cost =  37544.170403408905
# RUN  13 , total integrated cost =  37511.25168682461
# RUN  14 , total integrated cost =  37481.14896527016
# RUN  15 , total integrated cost =  37453.20989829168
# RUN  16 , total integrated cost =  37429.82233698642
# RUN  17 , total integrated cost =  37407.74141516752
# RUN  18 , total integrated cost =  37383.12566388064
# RUN  19 , total integrated cost =  37359.48383087131
# RUN  20 , total integrated cost =  37288.8083549807
# RUN  30 , total integrated cost =  37131.880593208036
# RUN  40 , total integrated cost =  37069.471325693376
# RUN  40 , total integrated cost =  37069.471325693376
# Improved over  40  iterations in  11.327000006996968  seconds by  32.51814809136103  percent.
# 2045.0722984980812 2.2877485364261916
# 9.165187696302029e-07 2.070501409603934
