# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import sys
import pickle

path = os.getcwd().split(os.sep + 'GUI')[0]
if path not in sys.path:
    print("not here")
    sys.path.append(path)

from neurolib.models.aln import ALNModel
from neurolib.utils import plotFunctions as plotFunc
from neurolib.utils import costFunctions as cost
import neurolib.dashboard.functions as functions
import neurolib.dashboard.data as data
    
# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2 

#path = os.path.join(os.getcwd(), "plots")
# Out:
# not here

# %% [markdown]
# ### Bistability

# %%
aln = ALNModel()
N = aln.params.N

data.set_parameters(aln)

state_vars = aln.state_vars
init_vars = aln.init_vars

##############################################################
def setinit(init_vars_, model):
    state_vars = model.state_vars
    init_vars = model.init_vars
    for iv in range(len(init_vars)):
        for sv in range(len(state_vars)):
            if state_vars[sv] in init_vars[iv]:
                #print("set init vars ", )
                if model.params[init_vars[iv]].ndim == 2:
                    model.params[init_vars[iv]][0,:] = init_vars_[sv]
                else:
                    model.params[init_vars[iv]][0] = init_vars_[sv]
                    
##############################################################               
def setmaxmincontrol(max_c_c, min_c_c, max_c_r, min_c_r):
    import numpy as np
    
    max_cntrl = np.zeros(( 6 ))
    min_cntrl = np.zeros(( 6 ))
    
    max_cntrl[0] = max_c_c
    min_cntrl[0] = min_c_c
    max_cntrl[1] = max_c_c
    min_cntrl[1] = min_c_c
    max_cntrl[2] = max_c_r
    min_cntrl[2] = min_c_r
    max_cntrl[3] = max_c_r
    min_cntrl[3] = min_c_r
    max_cntrl[4] = max_c_r
    min_cntrl[4] = min_c_r
    max_cntrl[5] = max_c_r
    min_cntrl[5] = min_c_r
            
    return max_cntrl, min_cntrl

# %%
##### LOAD BOUNDARIES
data_file = 'bi.pickle'
with open(data_file,'rb') as f:
    load_array= pickle.load(f)
exc = load_array[0]
inh = load_array[1]
print(len(exc))
# Out:
# 147

# %%
t0_array = np.arange(380., -1, -1.)
t_pen = t0_array / 400.

bestControl_1 = [None] * len(t_pen)
bestState_1 = [None] * len(t_pen)
cost_1 = [None] * len(t_pen)
runtime_1 = [None] * len(t_pen)
grad_1 = [None] * len(t_pen)
phi_1 = [None] * len(t_pen)
costnode_1 = [None] * len(t_pen)
weights_1 = [None] * len(t_pen)

# %%
initVars = [None] * len(exc)
target = [None] * len(exc)
cost_uncontrolled = [None] * len(exc)

cgv_list = [None, "HS", "FR", "PR", "CD", "LS", "DY", "WYL", "HZ", None]

# %%
dur_pre = 10
dur_post = 10

i = 20

n_pre = int(np.around(dur_pre/aln.params.dt + 1.,1))
n_post = int(np.around(dur_post/aln.params.dt + 1.,1))

tol = 1e-32
start_step = 10.
c_scheme = np.zeros(( 1,1 ))
c_scheme[0,0] = 1.
u_mat = np.identity(1)
u_scheme = np.array([[1.]])

c_var = [ [0], [1], [0,1]]
p_var = [ [0], [0], [0]]

### CURRENTS
cntrl_vars_0 = [0,1]
prec_vars = [0]

max_I = [3., -3.]
factor_wp = 1. / 0.05
factor_ws = 1.
factor_we = 0.
dur = 400
trans_time = 0.95
    
maxC = [5., -5., 0.18, 0.]

n_dur = int(np.around(dur/aln.params.dt + 1.,1))
max_cntrl, min_cntrl = setmaxmincontrol(maxC[0], maxC[1], maxC[2], maxC[3])

# %%
init_file = 'control_1.pickle'
final_file_1 = 'control_tradeoff_1a.pickle'

# %%
if os.path.isfile(init_file) :
    print("init file found")
    
    with open(init_file,'rb') as f:
        load_array = pickle.load(f)

    print(len(load_array[0]))

    bestControl_1[0] = load_array[0][i]
    bestState_1[0] = load_array[1][i]
    cost_1 [0]= load_array[2][i]
    runtime_1[0] = load_array[3][i]
    grad_1 [0]= load_array[4][i]
    phi_1[0] = load_array[5][i]
    costnode_1[0] = load_array[6][i]
    weights_1[0] = load_array[7][i]
# Out:
# init file found
# 147

# %%
if os.path.isfile(final_file_1) :
    print("final file found")
    
    with open(final_file_1,'rb') as f:
        load_array = pickle.load(f)

    print(len(load_array[0]))

    bestControl_1 = load_array[0]
    bestState_1 = load_array[1]
    cost_1 = load_array[2]
    runtime_1 = load_array[3]
    grad_1 = load_array[4]
    phi_1 = load_array[5]
    costnode_1 = load_array[6]
    weights_1 = load_array[7]
# Out:
# final file found
# 381

# %%
# get initial parameters and target states

print("------- ", i, exc[i], inh[i])
aln.params.ext_exc_current = exc[i] * 5.
aln.params.ext_inh_current = inh[i] * 5.

aln.params.duration = 3000.

control0 = aln.getZeroControl()
control0 = functions.step_control(aln, maxI_ = max_I[0])

aln.run(control=control0)

target_rates = np.zeros((2))
target_rates[0] = aln.rates_exc[0,-1] 
target_rates[1] = aln.rates_inh[0,-1]

control0 = functions.step_control(aln, maxI_ = max_I[1])
aln.run(control=control0)

init_state_vars = np.zeros(( len(state_vars) ))
for j in range(len(state_vars)):
    if aln.state[state_vars[j]].size == 1:
        init_state_vars[j] = aln.state[state_vars[j]][0]
    else:
        init_state_vars[j] = aln.state[state_vars[j]][0,-1]

initVars[i] = init_state_vars

aln.params.duration = dur

target[i] = aln.getZeroTarget()
target[i][:,0,:] = target_rates[0]
target[i][:,1,:] = target_rates[1]
# Out:
# -------  20 0.4500000000000001 0.4750000000000002

# %%
# get uncontrolled cost

data.set_parameters(aln)
aln.params.ext_exc_current = exc[i] * 5.
aln.params.ext_inh_current = inh[i] * 5.
aln.params.duration = dur

cgv = None

# %%
print(np.argmax(np.abs(bestControl_1[0]), axis=2))
print(bestControl_1[0][0,1,1650:1700]/5.)
print(bestControl_1[0][0,1,1674]/5.)

max_percent = (np.argmax(np.abs(bestControl_1[0]), axis=2)[0,1] -100) / 3800
print(max_percent)
# Out:
# [[1729 1674    0    0    0    0]]
# [-0.1633104  -0.16379484 -0.16425582 -0.16469311 -0.16509954 -0.16548749
#  -0.16585186 -0.16619199 -0.16650851 -0.16680346 -0.16707971 -0.16733875
#  -0.1675742  -0.16778295 -0.16795832 -0.16819977 -0.16841262 -0.16860169
#  -0.16876577 -0.16890939 -0.1690244  -0.16912678 -0.16920045 -0.16924691
#  -0.16926188 -0.16925026 -0.16921142 -0.16914676 -0.16905532 -0.16894278
#  -0.16879886 -0.16862746 -0.1684289  -0.16820321 -0.16795549 -0.16767893
#  -0.16737551 -0.16704399 -0.16668665 -0.16630856 -0.16590178 -0.16546897
#  -0.16501036 -0.16452214 -0.16400294 -0.16345805 -0.16288765 -0.16229229
#  -0.1616851  -0.16105491]
# -0.16926188242134096
# 0.4142105263157895

# %%
factor_iteration = 1.

##### initial guess
weight_ = 1.
cost.setParams(weight_ * factor_wp, weight_ * factor_we, weight_ * factor_ws)

setinit(initVars[i], aln)

weights_1[0] = cost.getParams()

for j in range(300, 381):

    dur = 400. - np.around(j/10., 1)
    T = 4001 - j
    aln.params.duration = dur

    #factor_wp = dur / 20.
    factor_wp = 1.
    cost.setParams(weight_ * factor_wp, weight_ * factor_we, weight_ * factor_ws)

    print('-----', j)
    setinit(initVars[i], aln)

    max_it = 10.
    if j > 170:
        max_it = 40.
    elif j > 140:
        max_it = 30.
    elif j > 100.:
        max_it = 20.
    
    if type(bestControl_1[j]) == type(None):
        total_shift = round(j * max_percent * 10)
        prev_shift = round( (j-1) * max_percent * 10)
        shift_ind = total_shift - prev_shift
        #print(total_shift, prev_shift, shift_ind)
        control0 = np.zeros(( bestControl_1[j-1][:,:,100:-101].shape ))
        control0[:,:,:-shift_ind] = 1. * bestControl_1[j-1][:,:,100+shift_ind:-101]
    else:
        if bestControl_1[j].shape[2] == T+200:
            control0 = bestControl_1[j][:,:,100:-100]
        else:
            control0 = bestControl_1[j][:,:,100:-(100+j)]

    bestControl_1[j], bestState_1[j], cost_1[j], runtime_1[j], grad_1[j], phi_1[j], costnode_1[j] = aln.A1(
        control0, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = [0,1],
        prec_variables_ = prec_vars, transition_time_ = t_pen[j])

    print(costnode_1[j][0][0][0], costnode_1[j][2][0][1])

    print(costnode_1[0][0][0][0], costnode_1[0][2][0][1])
        
    with open(final_file_1,'wb') as f:
        pickle.dump([bestControl_1, bestState_1, cost_1, runtime_1, grad_1, phi_1,
                costnode_1, weights_1], f)
# Out:
# set cost params:  18.5 0.0 1.0
# set cost params:  18.494999999999997 0.0 1.0
# ----- 301
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5.001295989747373
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.508989682450757
# RUN  2 , total integrated cost =  4.303431730525783
# RUN  3 , total integrated cost =  4.175085007792193
# RUN  4 , total integrated cost =  4.085114818292185
# RUN  5 , total integrated cost =  4.016020152008475
# RUN  6 , total integrated cost =  3.9612605305653363
# RUN  7 , total integrated cost =  3.9159313437893974
# RUN  8 , total integrated cost =  3.878467096479052
# RUN  9 , total integrated cost =  3.8468145411188286
# RUN  10 , total integrated cost =  3.8192871477375885
# RUN  11 , total integrated cost =  3.795672678936014
# RUN  12 , total integrated cost =  3.7753242208400613
# RUN  13 , total integrated cost =  3.757267104762338
# RUN  14 , total integrated cost =  3.7416913212967517
# RUN  15 , total integrated cost =  3.7280279867136343
# RUN  16 , total integrated cost =  3.715861702804045
# RUN  17 , total integrated cost =  3.7049945416355885
# RUN  18 , total integrated cost =  3.6953046597936448
# RUN  19 , total integrated cost =  3.686564575857441
# RUN  20 , total integrated cost =  3.6787194096527744
# RUN  30 , total integrated cost =  3.6307304159631872
# RUN  40 , total integrated cost =  3.610047004059871
# RUN  40 , total integrated cost =  3.610047004059871
# Improved over  40  iterations in  4.799294167998596  seconds by  27.81776940496131  percent.
# 0.0014345122118120954 3.3296602153952177
# 5.7868700186056746e-08 3.3312300207483534
# set cost params:  18.490000000000002 0.0 1.0
# ----- 302
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  4.626510353586458
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.281351683104595
# RUN  2 , total integrated cost =  4.111131801771673
# RUN  3 , total integrated cost =  4.02133702994447
# RUN  4 , total integrated cost =  3.9623130040046406
# RUN  5 , total integrated cost =  3.9158901796840864
# RUN  6 , total integrated cost =  3.880143221198478
# RUN  7 , total integrated cost =  3.850039587367652
# RUN  8 , total integrated cost =  3.82485766418227
# RUN  9 , total integrated cost =  3.803047593441926
# RUN  10 , total integrated cost =  3.7837437612448377
# RUN  11 , total integrated cost =  3.7669647335066276
# RUN  12 , total integrated cost =  3.75218030550614
# RUN  13 , total integrated cost =  3.7390152515184294
# RUN  14 , total integrated cost =  3.72737714342217
# RUN  15 , total integrated cost =  3.716907410282634
# RUN  16 , total integrated cost =  3.7075496781991184
# RUN  17 , total integrated cost =  3.6991339852828586
# RUN  18 , total integrated cost =  3.691483824587693
# RUN  19 , total integrated cost =  3.684658712678662
# RUN  20 , total integrated cost =  3.6782866567297394
# RUN  30 , total integrated cost =  3.638431382189859
# RUN  40 , total integrated cost =  3.6202098113423644
# RUN  40 , total integrated cost =  3.6202098113423644
# Improved over  40  iterations in  4.75512400399748  seconds by  21.750746574337867  percent.
# 0.0015652623617188471 3.3293785846243265
# 5.7868700186056746e-08 3.3312300207483534
# set cost params:  18.485 0.0 1.0
# ----- 303
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5.217459672194823
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.647108934283354
# RUN  2 , total integrated cost =  4.350957243082828
# RUN  3 , total integrated cost =  4.214417259920901
# RUN  4 , total integrated cost =  4.117546384297565
# RUN  5 , total integrated cost =  4.042461967368367
# RUN  6 , total integrated cost =  3.9810875303697126
# RUN  7 , total integrated cost =  3.929898114136583
# RUN  8 , total integrated cost =  3.8906181029682116
# RUN  9 , total integrated cost =  3.8590696733367746
# RUN  10 , total integrated cost =  3.8329600894933034
# RUN  11 , total integrated cost =  3.8103521902312925
# RUN  12 , total integrated cost =  3.7896842873696226
# RUN  13 , total integrated cost =  3.771465800677021
# RUN  14 , total integrated cost =  3.7564153137604213
# RUN  15 , total integrated cost =  3.7431352249932566
# RUN  16 , total integrated cost =  3.7304342954778797
# RUN  17 , total integrated cost =  3.7195786201927947
# RUN  18 , total integrated cost =  3.709920269208094
# RUN  19 , total integrated cost =  3.7009513442999773
# RUN  20 , total integrated cost =  3.693399194540722
# RUN  30 , total integrated cost =  3.6478861972602346
# RUN  40 , total integrated cost =  3.628090305476147
# RUN  40 , total integrated cost =  3.628090305476147
# Improved over  40  iterations in  4.625614960001258  seconds by  30.462513686283614  percent.
# 0.0014621070603932514 3.3294627326764115
# 5.7868700186056746e-08 3.3312300207483534
# set cost params:  18.48 0.0 1.0
# ----- 304
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  4.7647888632709465
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.375663729966136
# RUN  2 , total integrated cost =  4.1918490035722495
# RUN  3 , total integrated cost =  4.100852936211953
# RUN  4 , total integrated cost =  4.028510882611373
# RUN  5 , total integrated cost =  3.97612103942496
# RUN  6 , total integrated cost =  3.928529442969378
# RUN  7 , total integrated cost =  3.891994039106724
# RUN  8 , total integrated cost =  3.8606836436385716
# RUN  9 , total integrated cost =  3.834410702669266
# RUN  10 , total integrated cost =  3.8115845734829117
# RUN  11 , total integrated cost =  3.7925315174151075
# RUN  12 , total integrated cost =  3.7747100085221947
# RUN  13 , total integrated cost =  3.7590982762189644
# RUN  14 , total integrated cost =  3.7463951301973726
# RUN  15 , total integrated cost =  3.735058527901265
# RUN  16 , total integrated cost =  3.7242543546340423
# RUN  17 , total integrated cost =  3.7149451077639557
# RUN  18 , total integrated cost =  3.706712232659579
# RUN  19 , total integrated cost =  3.699035401166355
# RUN  20 , total integrated cost =  3.692575223972603
# RUN  30 , total integrated cost =  3.65414462005863
# RUN  40 , total integrated cost =  3.6378556486229017
# RUN  40 , total integrated cost =  3.6378556486229017
# Improved over  40  iterations in  4.584981175998109  seconds by  23.651272847259477  percent.
# 0.0015433022615064622 3.329113936122328
# 5.7868700186056746e-08 3.3312300207483534
# set cost params:  18.475 0.0 1.0
# ----- 305
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5.412254338811912
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.775710285065123
# RUN  2 , total integrated cost =  4.5101339271111645
# RUN  3 , total integrated cost =  4.350193460237197
# RUN  4 , total integrated cost =  4.232519891679798
# RUN  5 , total integrated cost =  4.139025112920308
# RUN  6 , total integrated cost =  4.070668259080714
# RUN  7 , total integrated cost =  4.0121841510407235
# RUN  8 , total integrated cost =  3.964354851671695
# RUN  9 , total integrated cost =  3.9219644588308493
# RUN  10 , total integrated cost =  3.889482736886178
# RUN  11 , total integrated cost =  3.862194621975592
# RUN  12 , total integrated cost =  3.839892238613616
# RUN  13 , total integrated cost =  3.820537548534813
# RUN  14 , total integrated cost =  3.8034204439438524
# RUN  15 , total integrated cost =  3.787973654021693
# RUN  16 , total integrated cost =  3.7744730730031653
# RUN  17 , total integrated cost =  3.762418633723562
# RUN  18 , total integrated cost =  3.7515807323224633
# RUN  19 , total integrated cost =  3.741799394913481
# RUN  20 , total integrated cost =  3.7329044453419367
# RUN  30 , total integrated cost =  3.6757864374807347
# RUN  40 , total integrated cost =  3.6520733800409406
# RUN  40 , total integrated cost =  3.6520733800409406
# Improved over  40  iterations in  4.799921124998946  seconds by  32.52214047201194  percent.
# 0.0017627983193796706 3.3284241261283993
# 5.7868700186056746e-08 3.3312300207483534
# set cost params:  18.47 0.0 1.0
# ----- 306
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  4.973337521332648
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.5147027266192605
# RUN  2 , total integrated cost =  4.33238017933693
# RUN  3 , total integrated cost =  4.220478082244979
# RUN  4 , total integrated cost =  4.127905396664542
# RUN  5 , total integrated cost =  4.056100727568734
# RUN  6 , total integrated cost =  4.00574993813964
# RUN  7 , total integrated cost =  3.961986361706314
# RUN  8 , total integrated cost =  3.9239355457562466
# RUN  9 , total integrated cost =  3.8927230010753897
# RUN  10 , total integrated cost =  3.865191961767684
# RUN  11 , total integrated cost =  3.842712275131811
# RUN  12 , total integrated cost =  3.821271770148358
# RUN  13 , total integrated cost =  3.802983440875954
# RUN  14 , total integrated cost =  3.7877953955975454
# RUN  15 , total integrated cost =  3.7745518331750487
# RUN  16 , total integrated cost =  3.7616729069987307
# RUN  17 , total integrated cost =  3.7508379003330257
# RUN  18 , total integrated cost =  3.741044327525623
# RUN  19 , total integrated cost =  3.7321427711476014
# RUN  20 , total integrated cost =  3.724503749171926
# RUN  30 , total integrated cost =  3.6809074741581713
# RUN  40 , total integrated cost =  3.661326244731693
# RUN  40 , total integrated cost =  3.661326244731693
# Improved over  40  iterations in  5.250065051001002  seconds by  26.38090157712422  percent.
# 0.0017668122306681016 3.3303481502545034
# 5.7868700186056746e-08 3.3312300207483534
# set cost params:  18.465 0.0 1.0
# ----- 307
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  4.607367396916426
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.23252367112298
# RUN  2 , total integrated cost =  4.131373324219252
# RUN  3 , total integrated cost =  4.063025019482373
# RUN  4 , total integrated cost =  4.012642512334395
# RUN  5 , total integrated cost =  3.9727005137409765
# RUN  6 , total integrated cost =  3.940100707936257
# RUN  7 , total integrated cost =  3.912487732143292
# RUN  8 , total integrated cost =  3.888227413630784
# RUN  9 , total integrated cost =  3.8673725105641985
# RUN  10 , total integrated cost =  3.848894467259147
# RUN  11 , total integrated cost =  3.832641411539443
# RUN  12 , total integrated cost =  3.818019581432605
# RUN  13 , total integrated cost =  3.80510622838608
# RUN  14 , total integrated cost =  3.793188554240008
# RUN  15 , total integrated cost =  3.782414996499083
# RUN  16 , total integrated cost =  3.772909956183781
# RUN  17 , total integrated cost =  3.764160235109299
# RUN  18 , total integrated cost =  3.756157589867102
# RUN  19 , total integrated cost =  3.748702767426844
# RUN  20 , total integrated cost =  3.742103063462539
# RUN  30 , total integrated cost =  3.6958518021396833
# RUN  40 , total integrated cost =  3.672957069915606
# RUN  40 , total integrated cost =  3.672957069915606
# Improved over  40  iterations in  5.126955413001269  seconds by  20.280786108487746  percent.
# 0.0019669540639327262 3.334390352980592
# 5.7868700186056746e-08 3.3312300207483534
# set cost params:  18.46 0.0 1.0
# ----- 308
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5.715009161574246
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.963795299200468
# RUN  2 , total integrated cost =  4.588480217815711
# RUN  3 , total integrated cost =  4.417644168951735
# RUN  4 , total integrated cost =  4.296057538467595
# RUN  5 , total integrated cost =  4.203798654770314
# RUN  6 , total integrated cost =  4.125804088579284
# RUN  7 , total integrated cost =  4.063362071435317
# RUN  8 , total integrated cost =  4.01250410213971
# RUN  9 , total integrated cost =  3.969522780273864
# RUN  10 , total integrated cost =  3.932918611963031
# RUN  11 , total integrated cost =  3.9029789932145498
# RUN  12 , total integrated cost =  3.874424349629963
# RUN  13 , total integrated cost =  3.850957193443355
# RUN  14 , total integrated cost =  3.830706519314275
# RUN  15 , total integrated cost =  3.812223406090163
# RUN  16 , total integrated cost =  3.7971906159484545
# RUN  17 , total integrated cost =  3.784338151529142
# RUN  18 , total integrated cost =  3.770988919427477
# RUN  19 , total integrated cost =  3.7597100405929877
# RUN  20 , total integrated cost =  3.7505059629215913
# RUN  30 , total integrated cost =  3.6989733303823034
# RUN  40 , total integrated cost =  3.675831238209398
# RUN  40 , total integrated cost =  3.675831238209398
# Improved over  40  iterations in  5.275184194000758  seconds by  35.68109631521814  percent.
# 0.0015147674538141791 3.3344997856066882
# 5.7868700186056746e-08 3.3312300207483534
# set cost params:  18.455000000000002 0.0 1.0
# ----- 309
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5.095848324620642
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.583460515517892
# RUN  2 , total integrated cost =  4.398210265763667
# RUN  3 , total integrated cost =  4.279409282909231
# RUN  4 , total integrated cost =  4.193743378702915
# RUN  5 , total integrated cost =  4.12794154466595
# RUN  6 , total integrated cost =  4.075239333316916
# RUN  7 , total integrated cost =  4.031548872795835
# RUN  8 , total integrated cost =  3.993557769489446
# RUN  9 , total integrated cost =  3.9605694450152966
# RUN  10 , total integrated cost =  3.9310084702554793
# RUN  11 , total integrated cost =  3.9055117048666173
# RUN  12 , total integrated cost =  3.883949134761415
# RUN  13 , total integrated cost =  3.8638732407288847
# RUN  14 , total integrated cost =  3.847335876062518
# RUN  15 , total integrated cost =  3.832282101929213
# RUN  16 , total integrated cost =  3.818482043195126
# RUN  17 , total integrated cost =  3.8064269399413644
# RUN  18 , total integrated cost =  3.7953096571015905
# RUN  19 , total integrated cost =  3.7856006455646676
# RUN  20 , total integrated cost =  3.7764678013488813
# RUN  30 , total integrated cost =  3.715981846775254
# RUN  40 , total integrated cost =  3.6908809176437534
# RUN  40 , total integrated cost =  3.6908809176437534
# Improved over  40  iterations in  5.197788352998032  seconds by  27.57082466895207  percent.
# 0.0017825367473022996 3.339492514725359
# 5.7868700186056746e-08 3.3312300207483534
# set cost params:  18.45 0.0 1.0
# ----- 310
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5.8163403820855075
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.029935542902761
# RUN  2 , total integrated cost =  4.664960375489076
# RUN  3 , total integrated cost =  4.491156763803025
# RUN  4 , total integrated cost =  4.352871772776045
# RUN  5 , total integrated cost =  4.247501193667587
# RUN  6 , total integrated cost =  4.171828706470956
# RUN  7 , total integrated cost =  4.110546049286932
# RUN  8 , total integrated cost =  4.0519236173889945
# RUN  9 , total integrated cost =  4.00552658212879
# RUN  10 , total integrated cost =  3.9686030319273833
# RUN  11 , total integrated cost =  3.9368570781392815
# RUN  12 , total integrated cost =  3.907644658367125
# RUN  13 , total integrated cost =  3.8831187226981156
# RUN  14 , total integrated cost =  3.862066412147403
# RUN  15 , total integrated cost =  3.843010855000176
# RUN  16 , total integrated cost =  3.827189211588843
# RUN  17 , total integrated cost =  3.812359917425855
# RUN  18 , total integrated cost =  3.8000397885066484
# RUN  19 , total integrated cost =  3.7885003590391944
# RUN  20 , total integrated cost =  3.7786281905003767
# RUN  30 , total integrated cost =  3.7197418145254333
# RUN  40 , total integrated cost =  3.696650788420354
# RUN  40 , total integrated cost =  3.696650788420354
# Improved over  40  iterations in  5.008433166000032  seconds by  36.443699206357614  percent.
# 0.0014724748508982346 3.339028996977341
# 5.7868700186056746e-08 3.3312300207483534
# set cost params:  18.445 0.0 1.0
# ----- 311
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5.2340923659909535
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.6629600486633045
# RUN  2 , total integrated cost =  4.462974026783771
# RUN  3 , total integrated cost =  4.335645023942497
# RUN  4 , total integrated cost =  4.231691322030218
# RUN  5 , total integrated cost =  4.158825975903344
# RUN  6 , total integrated cost =  4.096946974519491
# RUN  7 , total integrated cost =  4.045222541011973
# RUN  8 , total integrated cost =  4.006387813153148
# RUN  9 , total integrated cost =  3.973075247151316
# RUN  10 , total integrated cost =  3.941916852249902
# RUN  11 , total integrated cost =  3.9141303512747085
# RUN  12 , total integrated cost =  3.8935267174452113
# RUN  13 , total integrated cost =  3.8754150188792984
# RUN  14 , total integrated cost =  3.85653429429947
# RUN  15 , total integrated cost =  3.839705166362088
# RUN  16 , total integrated cost =  3.827604925192471
# RUN  17 , total integrated cost =  3.8166437939597566
# RUN  18 , total integrated cost =  3.804765739626694
# RUN  19 , total integrated cost =  3.7945431799798004
# RUN  20 , total integrated cost =  3.786545827086839
# RUN  30 , total integrated cost =  3.7339964188256474
# RUN  40 , total integrated cost =  3.711266759592702
# RUN  40 , total integrated cost =  3.711266759592702
# Improved over  40  iterations in  5.042848267003137  seconds by  29.09435867607087  percent.
# 0.001688288675860086 3.344214279413416
# 5.7868700186056746e-08 3.3312300207483534
# set cost params:  18.44 0.0 1.0
# ----- 312
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5.288380984545416
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.697412541452118
# RUN  2 , total integrated cost =  4.437884716397444
# RUN  3 , total integrated cost =  4.309157372703322
# RUN  4 , total integrated cost =  4.223594088691974
# RUN  5 , total integrated cost =  4.152762702790005
# RUN  6 , total integrated cost =  4.095702388872299
# RUN  7 , total integrated cost =  4.047120673388223
# RUN  8 , total integrated cost =  4.008534237850158
# RUN  9 , total integrated cost =  3.9745005330734204
# RUN  10 , total integrated cost =  3.9458276591411288
# RUN  11 , total integrated cost =  3.921642667653758
# RUN  12 , total integrated cost =  3.898854971934528
# RUN  13 , total integrated cost =  3.8794115862860923
# RUN  14 , total integrated cost =  3.8628948103072918
# RUN  15 , total integrated cost =  3.848927595218733
# RUN  16 , total integrated cost =  3.834583759183689
# RUN  17 , total integrated cost =  3.822019815169576
# RUN  18 , total integrated cost =  3.8121584790744616
# RUN  19 , total integrated cost =  3.803159023550035
# RUN  20 , total integrated cost =  3.794150632021179
# RUN  30 , total integrated cost =  3.7445393385660433
# RUN  40 , total integrated cost =  3.7247925547571876
# RUN  40 , total integrated cost =  3.7247925547571876
# Improved over  40  iterations in  4.893418750998535  seconds by  29.566486120376084  percent.
# 0.0018311487896917283 3.349823850258717
# 5.7868700186056746e-08 3.3312300207483534
# set cost params:  18.435 0.0 1.0
# ----- 313
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  6.066992992214223
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.182892794682621
# RUN  2 , total integrated cost =  4.8370833582298225
# RUN  3 , total integrated cost =  4.6249503474937805
# RUN  4 , total integrated cost =  4.463027014610174
# RUN  5 , total integrated cost =  4.345064281373214
# RUN  6 , total integrated cost =  4.253318065076061
# RUN  7 , total integrated cost =  4.182225651486132
# RUN  8 , total integrated cost =  4.117668585123562
# RUN  9 , total integrated cost =  4.0619800261691115
# RUN  10 , total integrated cost =  4.0236232495600825
# RUN  11 , total integrated cost =  3.98910013922151
# RUN  12 , total integrated cost =  3.9563920348731934
# RUN  13 , total integrated cost =  3.9288098524575354
# RUN  14 , total integrated cost =  3.906596196496369
# RUN  15 , total integrated cost =  3.886892616125907
# RUN  16 , total integrated cost =  3.86882805630455
# RUN  17 , total integrated cost =  3.852957983105561
# RUN  18 , total integrated cost =  3.8396856529358785
# RUN  19 , total integrated cost =  3.828302329741036
# RUN  20 , total integrated cost =  3.816750231609567
# RUN  30 , total integrated cost =  3.75481258986795
# RUN  40 , total integrated cost =  3.7311314425622513
# RUN  40 , total integrated cost =  3.7311314425622513
# Improved over  40  iterations in  4.969162712997786  seconds by  38.50114138337698  percent.
# 0.0014863027938484905 3.3525188326935105
# 5.7868700186056746e-08 3.3312300207483534
# set cost params:  18.43 0.0 1.0
# ----- 314
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  4.90969464521643
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.379062847227808
# RUN  2 , total integrated cost =  4.267726154777681
# RUN  3 , total integrated cost =  4.191637081230996
# RUN  4 , total integrated cost =  4.133551713936951
# RUN  5 , total integrated cost =  4.085510355275158
# RUN  6 , total integrated cost =  4.049377261012533
# RUN  7 , total integrated cost =  4.018982676594169
# RUN  8 , total integrated cost =  3.9933499247974535
# RUN  9 , total integrated cost =  3.971026411957457
# RUN  10 , total integrated cost =  3.950775467278484
# RUN  11 , total integrated cost =  3.9331812707706275
# RUN  12 , total integrated cost =  3.9172919927522107
# RUN  13 , total integrated cost =  3.9031404266224006
# RUN  14 , total integrated cost =  3.890328229380804
# RUN  15 , total integrated cost =  3.8787855751009412
# RUN  16 , total integrated cost =  3.8682374449490315
# RUN  17 , total integrated cost =  3.8587238667528
# RUN  18 , total integrated cost =  3.849894440643942
# RUN  19 , total integrated cost =  3.841644353638812
# RUN  20 , total integrated cost =  3.833426314048378
# RUN  30 , total integrated cost =  3.783142978222802
# RUN  40 , total integrated cost =  3.758595009743094
# RUN  40 , total integrated cost =  3.758595009743094
# Improved over  40  iterations in  5.064277491997927  seconds by  23.445442510256015  percent.
# 0.0024808559363805674 3.357466451356947
# 5.7868700186056746e-08 3.3312300207483534
# set cost params:  18.425 0.0 1.0
# ----- 315
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  6.4286603346309406
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.395128814489533
# RUN  2 , total integrated cost =  4.905006605286668
# RUN  3 , total integrated cost =  4.667312319552841
# RUN  4 , total integrated cost =  4.515703877774213
# RUN  5 , total integrated cost =  4.393963295563585
# RUN  6 , total integrated cost =  4.296089131474208
# RUN  7 , total integrated cost =  4.218555774822781
# RUN  8 , total integrated cost =  4.1537828734929905
# RUN  9 , total integrated cost =  4.103077495929748
# RUN  10 , total integrated cost =  4.055345525667839
# RUN  11 , total integrated cost =  4.013258327831532
# RUN  12 , total integrated cost =  3.98404536647956
# RUN  13 , total integrated cost =  3.9595063275251436
# RUN  14 , total integrated cost =  3.9386782166408243
# RUN  15 , total integrated cost =  3.9204178580606825
# RUN  16 , total integrated cost =  3.9030822023015284
# RUN  17 , total integrated cost =  3.887829515617235
# RUN  18 , total integrated cost =  3.874850024424404
# RUN  19 , total integrated cost =  3.863369262133971
# RUN  20 , total integrated cost =  3.852138384095719
# RUN  30 , total integrated cost =  3.7873391662332643
# RUN  40 , total integrated cost =  3.760938319699102
# RUN  40 , total integrated cost =  3.760938319699102
# Improved over  40  iterations in  4.366087259000778  seconds by  41.49732410905153  percent.
# 0.0018334048187250676 3.3649947062208594
# 5.7868700186056746e-08 3.3312300207483534
# set cost params:  18.419999999999998 0.0 1.0
# ----- 316
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5.526658666199706
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.826633369481693
# RUN  2 , total integrated cost =  4.593436679559231
# RUN  3 , total integrated cost =  4.4516011977258065
# RUN  4 , total integrated cost =  4.352377134774077
# RUN  5 , total integrated cost =  4.276296715746849
# RUN  6 , total integrated cost =  4.215686716221092
# RUN  7 , total integrated cost =  4.165241358460444
# RUN  8 , total integrated cost =  4.121536151904798
# RUN  9 , total integrated cost =  4.084726342459605
# RUN  10 , total integrated cost =  4.052688144199788
# RUN  11 , total integrated cost =  4.024955301646339
# RUN  12 , total integrated cost =  4.000438700522169
# RUN  13 , total integrated cost =  3.9790315555709728
# RUN  14 , total integrated cost =  3.9596095978434263
# RUN  15 , total integrated cost =  3.9421307358739335
# RUN  16 , total integrated cost =  3.9270833539086953
# RUN  17 , total integrated cost =  3.9136946254126435
# RUN  18 , total integrated cost =  3.901520975029847
# RUN  19 , total integrated cost =  3.8904883730995783
# RUN  20 , total integrated cost =  3.880507098722289
# RUN  30 , total integrated cost =  3.8158644852842176
# RUN  40 , total integrated cost =  3.7836056857332303
# RUN  40 , total integrated cost =  3.7836056857332303
# Improved over  40  iterations in  4.732740953997563  seconds by  31.53900187697046  percent.
# 0.0024306528345326706 3.3708907491088103
# 5.7868700186056746e-08 3.3312300207483534
# set cost params:  18.415 0.0 1.0
# ----- 317
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5.6797731379129495
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.935166454575895
# RUN  2 , total integrated cost =  4.554222662334918
# RUN  3 , total integrated cost =  4.402378611695349
# RUN  4 , total integrated cost =  4.304620010354692
# RUN  5 , total integrated cost =  4.232578069438989
# RUN  6 , total integrated cost =  4.166930647458213
# RUN  7 , total integrated cost =  4.112782036178787
# RUN  8 , total integrated cost =  4.073321822636218
# RUN  9 , total integrated cost =  4.040160422931349
# RUN  10 , total integrated cost =  4.006238150199996
# RUN  11 , total integrated cost =  3.977370290419899
# RUN  12 , total integrated cost =  3.956616404465231
# RUN  13 , total integrated cost =  3.9386235591977017
# RUN  14 , total integrated cost =  3.918889319992506
# RUN  15 , total integrated cost =  3.901403893790029
# RUN  16 , total integrated cost =  3.8896570277511917
# RUN  17 , total integrated cost =  3.878778911471373
# RUN  18 , total integrated cost =  3.8669873255648195
# RUN  19 , total integrated cost =  3.8562911025565194
# RUN  20 , total integrated cost =  3.8488641022148333
# RUN  30 , total integrated cost =  3.806328794065647
# RUN  40 , total integrated cost =  3.785847944519526
# RUN  40 , total integrated cost =  3.785847944519526
# Improved over  40  iterations in  5.478549417999602  seconds by  33.345085224466416  percent.
# 0.0018511137091650252 3.3795796060443117
# 5.7868700186056746e-08 3.3312300207483534
# set cost params:  18.41 0.0 1.0
# ----- 318
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  6.392977047032375
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.347661573147192
# RUN  2 , total integrated cost =  4.890422190618966
# RUN  3 , total integrated cost =  4.660452652045595
# RUN  4 , total integrated cost =  4.507696130338
# RUN  5 , total integrated cost =  4.3890078648389865
# RUN  6 , total integrated cost =  4.297450385345103
# RUN  7 , total integrated cost =  4.228831205064203
# RUN  8 , total integrated cost =  4.161598935238245
# RUN  9 , total integrated cost =  4.10491059236976
# RUN  10 , total integrated cost =  4.068586306479627
# RUN  11 , total integrated cost =  4.038497154310065
# RUN  12 , total integrated cost =  4.012349562956976
# RUN  13 , total integrated cost =  3.9885754064161456
# RUN  14 , total integrated cost =  3.9690289496936026
# RUN  15 , total integrated cost =  3.9520775865708275
# RUN  16 , total integrated cost =  3.937451220933184
# RUN  17 , total integrated cost =  3.9243200451497255
# RUN  18 , total integrated cost =  3.9120251306486593
# RUN  19 , total integrated cost =  3.900816654947993
# RUN  20 , total integrated cost =  3.8897424461882175
# RUN  30 , total integrated cost =  3.8233959198325307
# RUN  40 , total integrated cost =  3.798986901410891
# RUN  40 , total integrated cost =  3.798986901410891
# Improved over  40  iterations in  5.798666193000827  seconds by  40.57562113140413  percent.
# 0.0017697276526106014 3.387479503375585
# 5.7868700186056746e-08 3.3312300207483534
# set cost params:  18.405 0.0 1.0
# ----- 319
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5.660336197716584
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.892897113806529
# RUN  2 , total integrated cost =  4.665180064948273
# RUN  3 , total integrated cost =  4.517826123140045
# RUN  4 , total integrated cost =  4.409414138872387
# RUN  5 , total integrated cost =  4.326788076549557
# RUN  6 , total integrated cost =  4.260162449713647
# RUN  7 , total integrated cost =  4.2074734668747835
# RUN  8 , total integrated cost =  4.159373528397219
# RUN  9 , total integrated cost =  4.119968367187591
# RUN  10 , total integrated cost =  4.087196651719977
# RUN  11 , total integrated cost =  4.059851669014935
# RUN  12 , total integrated cost =  4.036539579185228
# RUN  13 , total integrated cost =  4.015812227452601
# RUN  14 , total integrated cost =  3.9968607725237426
# RUN  15 , total integrated cost =  3.979361853176557
# RUN  16 , total integrated cost =  3.9628383336914466
# RUN  17 , total integrated cost =  3.9487501802198888
# RUN  18 , total integrated cost =  3.9356929054736094
# RUN  19 , total integrated cost =  3.924251995140753
# RUN  20 , total integrated cost =  3.913723841704788
# RUN  30 , total integrated cost =  3.84905490073079
# RUN  40 , total integrated cost =  3.8222523371196417
# RUN  40 , total integrated cost =  3.8222523371196417
# Improved over  40  iterations in  5.177536252998834  seconds by  32.47305100602394  percent.
# 0.0023656501671304314 3.3939879518453986
# 5.7868700186056746e-08 3.3312300207483534
# set cost params:  18.4 0.0 1.0
# ----- 320
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5.852506849841898
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.0105260591890595
# RUN  2 , total integrated cost =  4.761095584141765
# RUN  3 , total integrated cost =  4.59793914434791
# RUN  4 , total integrated cost =  4.478995865331236
# RUN  5 , total integrated cost =  4.3875870834566095
# RUN  6 , total integrated cost =  4.314370415340548
# RUN  7 , total integrated cost =  4.256230936946731
# RUN  8 , total integrated cost =  4.20334059024541
# RUN  9 , total integrated cost =  4.159963651441969
# RUN  10 , total integrated cost =  4.123866444972695
# RUN  11 , total integrated cost =  4.09382759110458
# RUN  12 , total integrated cost =  4.068234510061584
# RUN  13 , total integrated cost =  4.045507578589793
# RUN  14 , total integrated cost =  4.024723731587014
# RUN  15 , total integrated cost =  4.005578818106237
# RUN  16 , total integrated cost =  3.987489037476387
# RUN  17 , total integrated cost =  3.9721098199607225
# RUN  18 , total integrated cost =  3.9578388206496697
# RUN  19 , total integrated cost =  3.9453832587089916
# RUN  20 , total integrated cost =  3.9338926910170198
# RUN  30 , total integrated cost =  3.8604562916035823
# RUN  40 , total integrated cost =  3.827977301619939
# RUN  40 , total integrated cost =  3.827977301619939
# Improved over  40  iterations in  4.377388510001765  seconds by  34.59251907200502  percent.
# 0.0019723359905303 3.4008114432402836
# 5.7868700186056746e-08 3.3312300207483534
# set cost params:  18.395 0.0 1.0
# ----- 321
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  6.098670580632564
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.0047723774899255
# RUN  2 , total integrated cost =  4.765413237653203
# RUN  3 , total integrated cost =  4.610984657717195
# RUN  4 , total integrated cost =  4.500484058511234
# RUN  5 , total integrated cost =  4.414623946385684
# RUN  6 , total integrated cost =  4.343084268531287
# RUN  7 , total integrated cost =  4.283770646316127
# RUN  8 , total integrated cost =  4.236030030359905
# RUN  9 , total integrated cost =  4.1954280920197835
# RUN  10 , total integrated cost =  4.1602253781300185
# RUN  11 , total integrated cost =  4.129307257069195
# RUN  12 , total integrated cost =  4.102410638809733
# RUN  13 , total integrated cost =  4.078580691088393
# RUN  14 , total integrated cost =  4.057333740133081
# RUN  15 , total integrated cost =  4.0383224144309535
# RUN  16 , total integrated cost =  4.021223013160118
# RUN  17 , total integrated cost =  4.005804693374777
# RUN  18 , total integrated cost =  3.9918450037175712
# RUN  19 , total integrated cost =  3.9791790515649033
# RUN  20 , total integrated cost =  3.9676467896420515
# RUN  30 , total integrated cost =  3.89362296999317
# RUN  40 , total integrated cost =  3.858737713169759
# RUN  40 , total integrated cost =  3.858737713169759
# Improved over  40  iterations in  4.389515262999339  seconds by  36.72821540117478  percent.
# 0.002920398086220459 3.4083858434918763
# 5.7868700186056746e-08 3.3312300207483534
# set cost params:  18.39 0.0 1.0
# ----- 322
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  6.154463944897081
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.164970733554142
# RUN  2 , total integrated cost =  4.885181784580377
# RUN  3 , total integrated cost =  4.705897583448423
# RUN  4 , total integrated cost =  4.571843326762889
# RUN  5 , total integrated cost =  4.471720205537612
# RUN  6 , total integrated cost =  4.388883984910177
# RUN  7 , total integrated cost =  4.318100774208119
# RUN  8 , total integrated cost =  4.247286569980738
# RUN  9 , total integrated cost =  4.189941261308502
# RUN  10 , total integrated cost =  4.150924299550677
# RUN  11 , total integrated cost =  4.117006172462868
# RUN  12 , total integrated cost =  4.082287785818158
# RUN  13 , total integrated cost =  4.05347847173558
# RUN  14 , total integrated cost =  4.031506271292059
# RUN  15 , total integrated cost =  4.0117401932527255
# RUN  16 , total integrated cost =  3.993029879148779
# RUN  17 , total integrated cost =  3.9759559685166703
# RUN  18 , total integrated cost =  3.963111369110512
# RUN  19 , total integrated cost =  3.951307926900297
# RUN  20 , total integrated cost =  3.9397083190233655
# RUN  30 , total integrated cost =  3.8754302249463413
# RUN  40 , total integrated cost =  3.8506575776095295
# RUN  40 , total integrated cost =  3.8506575776095295
# Improved over  40  iterations in  4.563027938998857  seconds by  37.433095520816764  percent.
# 0.0017221100132624259 3.4156935914500033
# 5.7868700186056746e-08 3.3312300207483534
# set cost params:  18.384999999999998 0.0 1.0
# ----- 323
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  6.065368624893049
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.079963316711352
# RUN  2 , total integrated cost =  4.828242108563173
# RUN  3 , total integrated cost =  4.665528568859253
# RUN  4 , total integrated cost =  4.545446514908144
# RUN  5 , total integrated cost =  4.454188891030212
# RUN  6 , total integrated cost =  4.379692954844351
# RUN  7 , total integrated cost =  4.3215533138088995
# RUN  8 , total integrated cost =  4.274306790973383
# RUN  9 , total integrated cost =  4.233979153317301
# RUN  10 , total integrated cost =  4.198802804761081
# RUN  11 , total integrated cost =  4.167820615892414
# RUN  12 , total integrated cost =  4.140714035572295
# RUN  13 , total integrated cost =  4.116363226193435
# RUN  14 , total integrated cost =  4.094886906894584
# RUN  15 , total integrated cost =  4.075617776519785
# RUN  16 , total integrated cost =  4.058245683173385
# RUN  17 , total integrated cost =  4.042543490834691
# RUN  18 , total integrated cost =  4.02829629202511
# RUN  19 , total integrated cost =  4.0153403047077205
# RUN  20 , total integrated cost =  4.003520158517853
# RUN  30 , total integrated cost =  3.9268725832178055
# RUN  40 , total integrated cost =  3.8899538472506205
# RUN  40 , total integrated cost =  3.8899538472506205
# Improved over  40  iterations in  4.277591660000326  seconds by  35.86615937429174  percent.
# 0.0031368117145512816 3.4228833301548676
# 5.7868700186056746e-08 3.3312300207483534
# set cost params:  18.380000000000003 0.0 1.0
# ----- 324
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7.485162572066992
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.916035309414791
# RUN  2 , total integrated cost =  5.301018626407492
# RUN  3 , total integrated cost =  5.0098363391575
# RUN  4 , total integrated cost =  4.79932066292881
# RUN  5 , total integrated cost =  4.650926884411256
# RUN  6 , total integrated cost =  4.522982258847541
# RUN  7 , total integrated cost =  4.428385711243695
# RUN  8 , total integrated cost =  4.348017292660521
# RUN  9 , total integrated cost =  4.285348596910037
# RUN  10 , total integrated cost =  4.228769358441585
# RUN  11 , total integrated cost =  4.181605117914593
# RUN  12 , total integrated cost =  4.144639527492396
# RUN  13 , total integrated cost =  4.112435144047806
# RUN  14 , total integrated cost =  4.083156205738165
# RUN  15 , total integrated cost =  4.058390222310742
# RUN  16 , total integrated cost =  4.037302625388639
# RUN  17 , total integrated cost =  4.01811368193038
# RUN  18 , total integrated cost =  4.002383887536414
# RUN  19 , total integrated cost =  3.9890732352496077
# RUN  20 , total integrated cost =  3.97527300128648
# RUN  30 , total integrated cost =  3.904543926430497
# RUN  40 , total integrated cost =  3.8785686508594197
# RUN  40 , total integrated cost =  3.8785686508594197
# Improved over  40  iterations in  4.237452348002989  seconds by  48.18324099821961  percent.
# 0.0015709629257495332 3.432204073393536
# 5.7868700186056746e-08 3.3312300207483534
# set cost params:  18.375 0.0 1.0
# ----- 325
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  6.289084803059531
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.159577417641438
# RUN  2 , total integrated cost =  4.902986874160432
# RUN  3 , total integrated cost =  4.739443912836541
# RUN  4 , total integrated cost =  4.621620857498188
# RUN  5 , total integrated cost =  4.529943432638102
# RUN  6 , total integrated cost =  4.453695839341308
# RUN  7 , total integrated cost =  4.3898475441188864
# RUN  8 , total integrated cost =  4.33215426804522
# RUN  9 , total integrated cost =  4.2844022145672565
# RUN  10 , total integrated cost =  4.24510139460308
# RUN  11 , total integrated cost =  4.211902124018029
# RUN  12 , total integrated cost =  4.183797499338459
# RUN  13 , total integrated cost =  4.1586024838196884
# RUN  14 , total integrated cost =  4.135891051235696
# RUN  15 , total integrated cost =  4.114451334211253
# RUN  16 , total integrated cost =  4.094580880131581
# RUN  17 , total integrated cost =  4.077241958855206
# RUN  18 , total integrated cost =  4.06147062293651
# RUN  19 , total integrated cost =  4.047315347324482
# RUN  20 , total integrated cost =  4.034543072964546
# RUN  30 , total integrated cost =  3.9542662822200088
# RUN  40 , total integrated cost =  3.9195337537614527
# RUN  40 , total integrated cost =  3.9195337537614527
# Improved over  40  iterations in  4.5495846690027975  seconds by  37.67719983908203  percent.
# 0.003043158053070026 3.439858321252741
# 5.7868700186056746e-08 3.3312300207483534
# set cost params:  18.369999999999997 0.0 1.0
# ----- 326
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  6.685340935251533
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.395467573326329
# RUN  2 , total integrated cost =  4.931186552713257
# RUN  3 , total integrated cost =  4.730532606158358
# RUN  4 , total integrated cost =  4.610779611403097
# RUN  5 , total integrated cost =  4.52121796466731
# RUN  6 , total integrated cost =  4.45024206457475
# RUN  7 , total integrated cost =  4.390558561922025
# RUN  8 , total integrated cost =  4.336435976225043
# RUN  9 , total integrated cost =  4.290441158372019
# RUN  10 , total integrated cost =  4.252172993807588
# RUN  11 , total integrated cost =  4.219672305059343
# RUN  12 , total integrated cost =  4.191943806593811
# RUN  13 , total integrated cost =  4.167046999934885
# RUN  14 , total integrated cost =  4.144376856850839
# RUN  15 , total integrated cost =  4.123072946045404
# RUN  16 , total integrated cost =  4.1031826972258045
# RUN  17 , total integrated cost =  4.085863288520809
# RUN  18 , total integrated cost =  4.070088753176991
# RUN  19 , total integrated cost =  4.055903006963232
# RUN  20 , total integrated cost =  4.043173196980973
# RUN  30 , total integrated cost =  3.963501953827983
# RUN  40 , total integrated cost =  3.926394115542309
# RUN  40 , total integrated cost =  3.926394115542309
# Improved over  40  iterations in  4.761864596999658  seconds by  41.26860314874008  percent.
# 0.0025996562612920927 3.44824582791812
# 5.7868700186056746e-08 3.3312300207483534
# set cost params:  18.365000000000002 0.0 1.0
# ----- 327
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7.94056412192672
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.065770324467753
# RUN  2 , total integrated cost =  5.268850440545946
# RUN  3 , total integrated cost =  4.981926455692521
# RUN  4 , total integrated cost =  4.82820892607122
# RUN  5 , total integrated cost =  4.711254389125445
# RUN  6 , total integrated cost =  4.614542259346919
# RUN  7 , total integrated cost =  4.5340839708712455
# RUN  8 , total integrated cost =  4.4646393883139055
# RUN  9 , total integrated cost =  4.40451993898623
# RUN  10 , total integrated cost =  4.354473708137061
# RUN  11 , total integrated cost =  4.310378115944173
# RUN  12 , total integrated cost =  4.271324545450907
# RUN  13 , total integrated cost =  4.2369348532516415
# RUN  14 , total integrated cost =  4.207224540126397
# RUN  15 , total integrated cost =  4.181170592589023
# RUN  16 , total integrated cost =  4.158268052150965
# RUN  17 , total integrated cost =  4.137743390706744
# RUN  18 , total integrated cost =  4.119281481745978
# RUN  19 , total integrated cost =  4.102640502791144
# RUN  20 , total integrated cost =  4.087591303480892
# RUN  30 , total integrated cost =  3.994016678343684
# RUN  40 , total integrated cost =  3.9521973882505073
# RUN  40 , total integrated cost =  3.9521973882505073
# Improved over  40  iterations in  4.39261565400011  seconds by  50.22775047761298  percent.
# 0.002981565975574189 3.4619737546740117
# 5.7868700186056746e-08 3.3312300207483534
# set cost params:  18.36 0.0 1.0
# ----- 328
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  6.282702507822725
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4.905663512609489
# RUN  2 , total integrated cost =  4.729360791441216
# RUN  3 , total integrated cost =  4.611290998368419
# RUN  4 , total integrated cost =  4.518426422909249
# RUN  5 , total integrated cost =  4.44229428826787
# RUN  6 , total integrated cost =  4.370685616967185
# RUN  7 , total integrated cost =  4.315961352629122
# RUN  8 , total integrated cost =  4.2731061349864214
# RUN  9 , total integrated cost =  4.235992422898743
# RUN  10 , total integrated cost =  4.2032088652922
# RUN  11 , total integrated cost =  4.174487596469465
# RUN  12 , total integrated cost =  4.151281898897198
# RUN  13 , total integrated cost =  4.131113815812406
# RUN  14 , total integrated cost =  4.111327572613388
# RUN  15 , total integrated cost =  4.0936135713293424
# RUN  16 , total integrated cost =  4.080011884033067
# RUN  17 , total integrated cost =  4.067511012524592
# RUN  18 , total integrated cost =  4.055190391096962
# RUN  19 , total integrated cost =  4.044081965791617
# RUN  20 , total integrated cost =  4.0351584539506264
# RUN  30 , total integrated cost =  3.97661519223638
# RUN  40 , total integrated cost =  3.95074985795
# RUN  40 , total integrated cost =  3.95074985795
# Improved over  40  iterations in  4.53754696499891  seconds by  37.117031197468954  percent.
# 0.002179432150438949 3.4695796684429623
# 5.7868700186056746e-08 3.3312300207483534
# set cost params:  18.355 0.0 1.0
# ----- 329
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  6.983623286907618
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.425380392997849
# RUN  2 , total integrated cost =  5.006667810253159
# RUN  3 , total integrated cost =  4.809823210413808
# RUN  4 , total integrated cost =  4.688389043660583
# RUN  5 , total integrated cost =  4.597654050478535
# RUN  6 , total integrated cost =  4.5259800709437314
# RUN  7 , total integrated cost =  4.465266661697795
# RUN  8 , total integrated cost =  4.41114934402113
# RUN  9 , total integrated cost =  4.363855902136406
# RUN  10 , total integrated cost =  4.325399473913921
# RUN  11 , total integrated cost =  4.291803951721223
# RUN  12 , total integrated cost =  4.259450154755378
# RUN  13 , total integrated cost =  4.232405417552979
# RUN  14 , total integrated cost =  4.207844137843001
# RUN  15 , total integrated cost =  4.185733531138048
# RUN  16 , total integrated cost =  4.166507244379636
# RUN  17 , total integrated cost =  4.148271957722435
# RUN  18 , total integrated cost =  4.132844011341857
# RUN  19 , total integrated cost =  4.119277141539797
# RUN  20 , total integrated cost =  4.107118372222436
# RUN  30 , total integrated cost =  4.027452712259407
# RUN  40 , total integrated cost =  3.9889134653029577
# RUN  40 , total integrated cost =  3.9889134653029577
# Improved over  40  iterations in  5.5131650020011875  seconds by  42.8818923726731  percent.
# 0.003427384700486566 3.47821465833724
# 5.7868700186056746e-08 3.3312300207483534
# set cost params:  18.35 0.0 1.0
# ----- 330
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  8.786549105947616
# Gradient descend method:  None
# RUN  1 , total integrated cost =  6.396734546199247
# RUN  2 , total integrated cost =  5.838851033269895
# RUN  3 , total integrated cost =  5.487459428960227
# RUN  4 , total integrated cost =  5.23070799190999
# RUN  5 , total integrated cost =  5.031773618423807
# RUN  6 , total integrated cost =  4.887377367105192
# RUN  7 , total integrated cost =  4.77263622112179
# RUN  8 , total integrated cost =  4.676857453733401
# RUN  9 , total integrated cost =  4.595687028901641
# RUN  10 , total integrated cost =  4.527462401468881
# RUN  11 , total integrated cost =  4.46795480002601
# RUN  12 , total integrated cost =  4.416848141493866
# RUN  13 , total integrated cost =  4.372204562070275
# RUN  14 , total integrated cost =  4.33266732248965
# RUN  15 , total integrated cost =  4.297158785355944
# RUN  16 , total integrated cost =  4.267169675328061
# RUN  17 , total integrated cost =  4.2407547393563565
# RUN  18 , total integrated cost =  4.216993771637392
# RUN  19 , total integrated cost =  4.195715327743945
# RUN  20 , total integrated cost =  4.176595446246693
# RUN  30 , total integrated cost =  4.059781407290637
# RUN  40 , total integrated cost =  4.009432470071874
# RUN  40 , total integrated cost =  4.009432470071874
# Improved over  40  iterations in  4.573992835001263  seconds by  54.3685191794138  percent.
# 0.0035064439191663434 3.4888634262143814
# 5.7868700186056746e-08 3.3312300207483534
# set cost params:  18.345 0.0 1.0
# ----- 331
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7.755807433323982
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.761065317367789
# RUN  2 , total integrated cost =  5.391383243754275
# RUN  3 , total integrated cost =  5.150321734553591
# RUN  4 , total integrated cost =  4.978618774872213
# RUN  5 , total integrated cost =  4.844840130599257
# RUN  6 , total integrated cost =  4.735294133890195
# RUN  7 , total integrated cost =  4.647022896706153
# RUN  8 , total integrated cost =  4.571633782710082
# RUN  9 , total integrated cost =  4.510287632671536
# RUN  10 , total integrated cost =  4.453836083089342
# RUN  11 , total integrated cost =  4.404999659143092
# RUN  12 , total integrated cost =  4.365647592917464
# RUN  13 , total integrated cost =  4.3302506268964605
# RUN  14 , total integrated cost =  4.298021210171589
# RUN  15 , total integrated cost =  4.268946655460985
# RUN  16 , total integrated cost =  4.244969972480802
# RUN  17 , total integrated cost =  4.223483235182791
# RUN  18 , total integrated cost =  4.202714742373836
# RUN  19 , total integrated cost =  4.1848126141331266
# RUN  20 , total integrated cost =  4.168668260838379
# ...
# RUN  30 , total integrated cost =  387.3384053346983
# RUN  40 , total integrated cost =  253.7105520884379
# RUN  40 , total integrated cost =  253.7105520884379
# Improved over  40  iterations in  4.73355979400003  seconds by  96.07314896322227  percent.
# 13.474547030984423 3.513177241553689
# 5.7868700186056746e-08 3.3312300207483534
# set cost params:  18.145 0.0 1.0
# ----- 371
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  6102.117901512938
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2200.3562294918197
# RUN  2 , total integrated cost =  1922.163176060204
# RUN  3 , total integrated cost =  1799.1822650552324
# RUN  4 , total integrated cost =  1700.9243179547573
# RUN  5 , total integrated cost =  1615.2457132836
# RUN  6 , total integrated cost =  1537.2067336466955
# RUN  7 , total integrated cost =  1464.4986042336707
# RUN  8 , total integrated cost =  1388.835490734834
# RUN  9 , total integrated cost =  1320.2369135037789
# RUN  10 , total integrated cost =  1248.5914371281447
# RUN  11 , total integrated cost =  1178.2039117225474
# RUN  12 , total integrated cost =  1100.4547308138115
# RUN  13 , total integrated cost =  1024.9295584712115
# RUN  14 , total integrated cost =  936.597497714627
# RUN  15 , total integrated cost =  852.8024297964752
# RUN  16 , total integrated cost =  797.2987105785825
# RUN  17 , total integrated cost =  747.5853184409573
# RUN  18 , total integrated cost =  705.9133335487616
# RUN  19 , total integrated cost =  667.8192476731691
# RUN  20 , total integrated cost =  636.439187914223
# RUN  30 , total integrated cost =  388.1798074763992
# RUN  40 , total integrated cost =  266.65750262354686
# RUN  40 , total integrated cost =  266.65750262354686
# Improved over  40  iterations in  4.945887021996896  seconds by  95.630082752786  percent.
# 14.160945837704109 3.435607068540094
# 5.7868700186056746e-08 3.3312300207483534
# set cost params:  18.14 0.0 1.0
# ----- 372
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  6737.080240489954
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2337.235445202404
# RUN  2 , total integrated cost =  2000.9060568529553
# RUN  3 , total integrated cost =  1834.7279239722563
# RUN  4 , total integrated cost =  1700.5754603913879
# RUN  5 , total integrated cost =  1592.2665378970669
# RUN  6 , total integrated cost =  1491.8690493460751
# RUN  7 , total integrated cost =  1413.9515492470264
# RUN  8 , total integrated cost =  1343.3423680362187
# RUN  9 , total integrated cost =  1279.3778467408918
# RUN  10 , total integrated cost =  1220.2289638934114
# RUN  11 , total integrated cost =  1166.2027029230085
# RUN  12 , total integrated cost =  1114.649295350003
# RUN  13 , total integrated cost =  1062.6945268872091
# RUN  14 , total integrated cost =  1015.4013497594334
# RUN  15 , total integrated cost =  969.5933355429772
# RUN  16 , total integrated cost =  925.9611009744798
# RUN  17 , total integrated cost =  885.0421448338604
# RUN  18 , total integrated cost =  846.4304075425437
# RUN  19 , total integrated cost =  809.9306688839013
# RUN  20 , total integrated cost =  775.1999729529588
# RUN  30 , total integrated cost =  502.0898020516228
# RUN  40 , total integrated cost =  333.5994480297609
# RUN  40 , total integrated cost =  333.5994480297609
# Improved over  40  iterations in  4.521335334000469  seconds by  95.04830822668812  percent.
# 17.823298248233918 3.354774724480378
# 5.7868700186056746e-08 3.3312300207483534
# set cost params:  18.134999999999998 0.0 1.0
# ----- 373
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  7185.044720641594
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2635.638405593543
# RUN  2 , total integrated cost =  2294.9617848599223
# RUN  3 , total integrated cost =  2135.9415108249436
# RUN  4 , total integrated cost =  2008.1084315885544
# RUN  5 , total integrated cost =  1904.09322585849
# RUN  6 , total integrated cost =  1810.8436216693308
# RUN  7 , total integrated cost =  1726.0607169408793
# RUN  8 , total integrated cost =  1639.1052193967632
# RUN  9 , total integrated cost =  1561.0524130042177
# RUN  10 , total integrated cost =  1487.6249120130792
# RUN  11 , total integrated cost =  1417.8443430601465
# RUN  12 , total integrated cost =  1351.8525182092917
# RUN  13 , total integrated cost =  1285.6153958814637
# RUN  14 , total integrated cost =  1224.7186781168948
# RUN  15 , total integrated cost =  1160.8245447710544
# RUN  16 , total integrated cost =  1093.905179459362
# RUN  17 , total integrated cost =  1039.0097061187378
# RUN  18 , total integrated cost =  986.4918831582494
# RUN  19 , total integrated cost =  935.8373248630719
# RUN  20 , total integrated cost =  890.3759093864109
# RUN  30 , total integrated cost =  573.3565567035133
# RUN  40 , total integrated cost =  365.74270538411247
# RUN  40 , total integrated cost =  365.74270538411247
# Improved over  40  iterations in  4.577109701000154  seconds by  94.90966695957526  percent.
# 19.568765050817433 3.270753214492382
# 5.7868700186056746e-08 3.3312300207483534
# set cost params:  18.130000000000003 0.0 1.0
# ----- 374
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  9077.599150682849
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2955.1867614097773
# RUN  2 , total integrated cost =  2564.678026083151
# RUN  3 , total integrated cost =  2399.9834846525378
# RUN  4 , total integrated cost =  2271.3008940888144
# RUN  5 , total integrated cost =  2158.002283572309
# RUN  6 , total integrated cost =  2055.3394925572775
# RUN  7 , total integrated cost =  1953.4255422484991
# RUN  8 , total integrated cost =  1857.3106444555347
# RUN  9 , total integrated cost =  1761.8551895528512
# RUN  10 , total integrated cost =  1666.0092855809382
# RUN  11 , total integrated cost =  1585.1084369461303
# RUN  12 , total integrated cost =  1509.7764990095905
# RUN  13 , total integrated cost =  1433.7988829928022
# RUN  14 , total integrated cost =  1357.779466695783
# RUN  15 , total integrated cost =  1272.8579469293095
# RUN  16 , total integrated cost =  1195.5449244406682
# RUN  17 , total integrated cost =  1124.5012438335561
# RUN  18 , total integrated cost =  1063.155364454382
# RUN  19 , total integrated cost =  1001.1763933156407
# RUN  20 , total integrated cost =  940.6176356904662
# RUN  30 , total integrated cost =  537.2277273281687
# RUN  40 , total integrated cost =  334.25608333353244
# RUN  40 , total integrated cost =  334.25608333353244
# Improved over  40  iterations in  4.717068701000244  seconds by  96.31779198678994  percent.
# 17.800416471344377 3.1835090732743345
# 5.7868700186056746e-08 3.3312300207483534
# set cost params:  18.125 0.0 1.0
# ----- 375
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  10390.793264058715
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3225.65702257374
# RUN  2 , total integrated cost =  2759.086910193536
# RUN  3 , total integrated cost =  2592.252552349499
# RUN  4 , total integrated cost =  2463.026692612345
# RUN  5 , total integrated cost =  2348.5835719951524
# RUN  6 , total integrated cost =  2244.409302873777
# RUN  7 , total integrated cost =  2148.3289508532685
# RUN  8 , total integrated cost =  2050.664599979628
# RUN  9 , total integrated cost =  1958.026907709738
# RUN  10 , total integrated cost =  1869.9132520262317
# RUN  11 , total integrated cost =  1781.5803986455498
# RUN  12 , total integrated cost =  1699.904729649556
# RUN  13 , total integrated cost =  1626.0234206249108
# RUN  14 , total integrated cost =  1557.3307567162492
# RUN  15 , total integrated cost =  1490.2033312298583
# RUN  16 , total integrated cost =  1423.63153586699
# RUN  17 , total integrated cost =  1361.0004306224494
# RUN  18 , total integrated cost =  1300.8145760470402
# RUN  19 , total integrated cost =  1241.0838501039862
# RUN  20 , total integrated cost =  1188.4365366562317
# RUN  30 , total integrated cost =  771.0150618165569
# RUN  40 , total integrated cost =  527.6245227727157
# RUN  40 , total integrated cost =  527.6245227727157
# Improved over  40  iterations in  4.522756712001865  seconds by  94.92219208520157  percent.
# 28.43601800376688 3.0930063902973
# 5.7868700186056746e-08 3.3312300207483534
# set cost params:  18.119999999999997 0.0 1.0
# ----- 376
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  13010.189081023433
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4295.054542706831
# RUN  2 , total integrated cost =  3645.5646510767097
# RUN  3 , total integrated cost =  3438.9502108540296
# RUN  4 , total integrated cost =  3277.1502653766584
# RUN  5 , total integrated cost =  3139.9665094527154
# RUN  6 , total integrated cost =  3019.177744570017
# RUN  7 , total integrated cost =  2901.7971386340514
# RUN  8 , total integrated cost =  2788.8394001206793
# RUN  9 , total integrated cost =  2680.0380725227633
# RUN  10 , total integrated cost =  2577.7553726393603
# RUN  11 , total integrated cost =  2480.6265158692777
# RUN  12 , total integrated cost =  2385.440223534586
# RUN  13 , total integrated cost =  2298.695314313688
# RUN  14 , total integrated cost =  2211.109491685002
# RUN  15 , total integrated cost =  2124.9830167253444
# RUN  16 , total integrated cost =  2043.727722936776
# RUN  17 , total integrated cost =  1966.9184864205229
# RUN  18 , total integrated cost =  1891.0428192517122
# RUN  19 , total integrated cost =  1821.2881799218897
# RUN  20 , total integrated cost =  1755.2430176618395
# RUN  30 , total integrated cost =  1221.2657894360564
# RUN  40 , total integrated cost =  872.0119570673223
# RUN  40 , total integrated cost =  872.0119570673223
# Improved over  40  iterations in  4.796740578000026  seconds by  93.29746899421137  percent.
# 47.40546859413725 3.006789540514386
# 5.7868700186056746e-08 3.3312300207483534
# set cost params:  18.115000000000002 0.0 1.0
# ----- 377
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  22620.724862252067
# Gradient descend method:  None
# RUN  1 , total integrated cost =  8080.683787860189
# RUN  2 , total integrated cost =  6194.041495029853
# RUN  3 , total integrated cost =  5846.1301967557665
# RUN  4 , total integrated cost =  5730.252510396949
# RUN  5 , total integrated cost =  5670.551412533016
# RUN  6 , total integrated cost =  5629.966300753779
# RUN  7 , total integrated cost =  5597.812515227226
# RUN  8 , total integrated cost =  5575.935458586806
# RUN  9 , total integrated cost =  5562.210700149135
# RUN  10 , total integrated cost =  5538.039051961042
# RUN  11 , total integrated cost =  5519.68063314335
# RUN  12 , total integrated cost =  5495.068964913725
# RUN  13 , total integrated cost =  5481.461026444519
# RUN  14 , total integrated cost =  5468.763925781451
# RUN  15 , total integrated cost =  5460.462287457972
# RUN  16 , total integrated cost =  5455.511111354026
# RUN  17 , total integrated cost =  5451.317671749694
# RUN  18 , total integrated cost =  5447.2370348843815
# RUN  19 , total integrated cost =  5443.5268056605455
# RUN  20 , total integrated cost =  5439.7112907501605
# RUN  30 , total integrated cost =  5414.904354106782
# RUN  40 , total integrated cost =  5398.0211566446515
# RUN  40 , total integrated cost =  5398.0211566446515
# Improved over  40  iterations in  4.740738361000695  seconds by  76.13683385693575  percent.
# 297.25207599822556 3.054671588070236
# 5.7868700186056746e-08 3.3312300207483534
# set cost params:  18.11 0.0 1.0
# ----- 378
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  33266.59403871855
# Gradient descend method:  None
# RUN  1 , total integrated cost =  21057.693325734956
# RUN  2 , total integrated cost =  17982.219632496846
# RUN  3 , total integrated cost =  17061.167821298077
# RUN  4 , total integrated cost =  16624.071969588294
# RUN  5 , total integrated cost =  16359.616998198962
# RUN  6 , total integrated cost =  16169.679621635678
# RUN  7 , total integrated cost =  16033.100368857531
# RUN  8 , total integrated cost =  15923.64210459892
# RUN  9 , total integrated cost =  15832.475639772772
# RUN  10 , total integrated cost =  15754.581113786562
# RUN  11 , total integrated cost =  15702.985383582247
# RUN  12 , total integrated cost =  15659.675903948826
# RUN  13 , total integrated cost =  15620.049439980165
# RUN  14 , total integrated cost =  15585.471648324687
# RUN  15 , total integrated cost =  15555.987179065642
# RUN  16 , total integrated cost =  15528.708611167252
# RUN  17 , total integrated cost =  15503.110986237552
# RUN  18 , total integrated cost =  15479.728432717595
# RUN  19 , total integrated cost =  15459.37007399385
# RUN  20 , total integrated cost =  15440.262317990511
# RUN  30 , total integrated cost =  15311.903679005525
# RUN  40 , total integrated cost =  15234.252945301187
# RUN  40 , total integrated cost =  15234.252945301187
# Improved over  40  iterations in  4.713824675000069  seconds by  54.20555249037445  percent.
# 840.4823471357564 2.893479998873951
# 5.7868700186056746e-08 3.3312300207483534
# set cost params:  18.105 0.0 1.0
# ----- 379
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  42991.19561465679
# Gradient descend method:  None
# RUN  1 , total integrated cost =  31098.66718430142
# RUN  2 , total integrated cost =  28160.91614878959
# RUN  3 , total integrated cost =  27289.574129125456
# RUN  4 , total integrated cost =  26849.225027006843
# RUN  5 , total integrated cost =  26587.183262264032
# RUN  6 , total integrated cost =  26425.444219114754
# RUN  7 , total integrated cost =  26303.852431874428
# RUN  8 , total integrated cost =  26207.083013918116
# RUN  9 , total integrated cost =  26128.69672881585
# RUN  10 , total integrated cost =  26062.28187037425
# RUN  11 , total integrated cost =  26008.85486071156
# RUN  12 , total integrated cost =  25972.82926697011
# RUN  13 , total integrated cost =  25941.191622962102
# RUN  14 , total integrated cost =  25911.859452600096
# RUN  15 , total integrated cost =  25886.18290405568
# RUN  16 , total integrated cost =  25862.26043544037
# RUN  17 , total integrated cost =  25840.538508512396
# RUN  18 , total integrated cost =  25817.695648570156
# RUN  19 , total integrated cost =  25796.11789787844
# RUN  20 , total integrated cost =  25778.544748131535
# RUN  30 , total integrated cost =  25647.611559689933
# RUN  40 , total integrated cost =  25462.56657063777
# RUN  40 , total integrated cost =  25462.56657063777
# Improved over  40  iterations in  5.074107161999564  seconds by  40.77260190931528  percent.
# 1405.664068237015 2.884948139331652
# 5.7868700186056746e-08 3.3312300207483534
# set cost params:  18.1 0.0 1.0
# ----- 380
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  62643.836846371145
# Gradient descend method:  None
# RUN  1 , total integrated cost =  44280.64054990347
# RUN  2 , total integrated cost =  40123.56636076756
# RUN  3 , total integrated cost =  38912.64496568005
# RUN  4 , total integrated cost =  38402.898394223834
# RUN  5 , total integrated cost =  38131.63382996719
# RUN  6 , total integrated cost =  37959.68978901852
# RUN  7 , total integrated cost =  37834.16147219212
# RUN  8 , total integrated cost =  37734.01491385425
# RUN  9 , total integrated cost =  37652.80192442661
# RUN  10 , total integrated cost =  37584.00220799975
# RUN  11 , total integrated cost =  37525.98321954161
# RUN  12 , total integrated cost =  37474.66264605097
# RUN  13 , total integrated cost =  37433.71581595745
# RUN  14 , total integrated cost =  37399.295774623606
# RUN  15 , total integrated cost =  37368.60654866467
# RUN  16 , total integrated cost =  37327.38343656242
# RUN  17 , total integrated cost =  37294.59947177228
# RUN  18 , total integrated cost =  37259.08805072671
# RUN  19 , total integrated cost =  37233.56872789009
# RUN  20 , total integrated cost =  37215.2549835474
# RUN  30 , total integrated cost =  37119.593876147424
# RUN  40 , total integrated cost =  37066.11613083568
# RUN  40 , total integrated cost =  37066.11613083568
# Improved over  40  iterations in  4.723223545999645  seconds by  40.83038652032557  percent.
# 2047.1637092692802 2.3515090027627004
# 5.7868700186056746e-08 3.3312300207483534

# %%
final_file_2 = 'control_tradeoff_1a_2.pickle'
cost_node_array = np.zeros(( len(t_pen),3 )) # S i, S e, P

bestControl_2 = [None] * len(t_pen)
bestState_2 = [None] * len(t_pen)
cost_2 = [None] * len(t_pen)
runtime_2 = [None] * len(t_pen)
grad_2 = [None] * len(t_pen)
phi_2 = [None] * len(t_pen)
costnode_2 = [None] * len(t_pen)
weights_2 = [None] * len(t_pen)

bestControl_2[0], bestState_2[0], cost_2[0], runtime_2[0], grad_2[0], phi_2[0], costnode_2[0], weights_2[0] = bestControl_1[0], bestState_1[0], cost_1[0], runtime_1[0], grad_1[0], phi_1[0], costnode_1[0], weights_1[0]

# %%
if os.path.isfile(final_file_2) :
    print("final file 2 found")
    
    with open(final_file_2,'rb') as f:
        load_array = pickle.load(f)

    print(len(load_array[0]))

    bestControl_2 = load_array[0]
    bestState_2 = load_array[1]
    cost_2 = load_array[2]
    runtime_2 = load_array[3]
    grad_2 = load_array[4]
    phi_2 = load_array[5]
    costnode_2 = load_array[6]
    weights_2 = load_array[7]

    cost_node_array[0] = [costnode_1[0][2][0][1], costnode_1[0][2][0][0], costnode_1[0][0][0][0]]

    for j in range(1, len(costnode_2)):
        if type(costnode_2[j]) != type(None):
            cost_node_array[j] = [costnode_2[j][2][0][1], costnode_2[j][2][0][0], costnode_2[j][0][0][0]]

# %%
##### initial guess
weight_ = 1.
w_p, w_s, w_e = 1., 1., 0.
cost.setParams(weight_ * factor_wp, weight_ * factor_we, weight_ * factor_ws)

maxcost_s = 1.01 * ( costnode_1[0][2][0][0] + costnode_1[0][2][0][1] )
maxcost_p = 1e10 * costnode_1[0][0][0][0]

w_s = weights_2[269][2]

for j in range(270, 281):

    dur = 400. - np.around(j/10., 1)
    T = 4001 - j
    aln.params.duration = dur

    w_p = dur / 20.
    cost.setParams(w_p, w_e, w_s)

    print('-----', j)
    setinit(initVars[i], aln)

    max_it = 10.
    
    if type(bestControl_2[j]) == type(None):
        if w_s > 1.:
            total_shift = round(j * max_percent * 10)
            prev_shift = round( (j-1) * max_percent * 10)
            shift_ind = total_shift - prev_shift
            #print(total_shift, prev_shift, shift_ind)
            control0 = np.zeros(( bestControl_2[j-1][:,:,100:-101].shape ))
            control0[:,:,:] = 1. * bestControl_2[j-1][:,:,100+shift_ind:-101+shift_ind]
        elif w_s == 1.:
            control0 = np.zeros(( bestControl_1[j][:,:,100:-100].shape ))
            control0[:,:,:] = 1. * bestControl_1[j][:,:,100:-100]
    else:
        cost.setParams(weights_2[j][0], weights_2[j][1], weights_2[j][2])
        if bestControl_2[j].shape[2] == T+200:
            control0 = bestControl_2[j][:,:,100:-100]
        else:
            control0 = bestControl_2[j][:,:,100:-(100+j)]

    bestControl_2[j], bestState_2[j], cost_2[j], runtime_2[j], grad_2[j], phi_2[j], costnode_2[j] = aln.A1(
        control0, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = [0,1],
        prec_variables_ = prec_vars, transition_time_ = t_pen[j])
        
    sumcost_s =  (costnode_2[j][2][0][0] + costnode_2[j][2][0][1])
    cost_p = costnode_2[j][0][0][0]

    print("costs = ", sumcost_s, cost_p)
    print('cost limits = ', maxcost_s, maxcost_p)

    if cost_p > maxcost_p:
        print("beyond max precision cost, break")
        break
    elif sumcost_s < maxcost_s:
        print("within sparsity cost limit, continue")
        cost_node_array[j] = [costnode_2[j][2][0][1], costnode_2[j][2][0][0], cost_p]
        weights_2[j] = cost.getParams()
        with open(final_file_2,'wb') as f:
            pickle.dump([bestControl_2, bestState_2, cost_2, runtime_2, grad_2, phi_2,
                costnode_2, weights_2], f)
        continue

    counter = 0
    while sumcost_s >= maxcost_s:
        print("iteration ", counter)
        counter += 1
        print("increase sparsity weight at t_ = ", t0_array[j])
        
        w_s = round(w_s * 1.5)

        max_it = 60

        cost.setParams(w_p, w_e, w_s)
        setinit(initVars[i], aln)
        control0[:,:,:] = 1. * bestControl_2[j][:,:,100:-100]

        bestControl_2[j], bestState_2[j], cost_2[j], runtime_2[j], grad_2[j], phi_2[j], costnode_2[j] = aln.A1(
        control0, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = [0,1],
        prec_variables_ = prec_vars, transition_time_ = t_pen[j])

        sumcost_s =  (costnode_2[j][2][0][0] + costnode_2[j][2][0][1])
        cost_p = costnode_2[j][0][0][0]

        print("costs = ", sumcost_s, cost_p)
        print('cost limits = ', maxcost_s, maxcost_p)

    cost_node_array[j] = [costnode_2[j][2][0][1], costnode_2[j][2][0][0], cost_p]
    weights_2[j] = cost.getParams()

    with open(final_file_2,'wb') as f:
        pickle.dump([bestControl_2, bestState_2, cost_2, runtime_2, grad_2, phi_2,
                costnode_2, weights_2], f)
# Out:
# set cost params:  18.605 0.0 1.0
# set cost params:  18.65 0.0 13986
# ----- 270
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  47108.903084299935
# Gradient descend method:  None
# RUN  1 , total integrated cost =  47105.09525190344
# RUN  2 , total integrated cost =  47105.05271821566
# RUN  3 , total integrated cost =  47105.00168071528
# RUN  4 , total integrated cost =  47104.936035252824
# RUN  5 , total integrated cost =  47104.871870919815
# RUN  6 , total integrated cost =  47104.832763630446
# RUN  7 , total integrated cost =  47104.788899604006
# RUN  8 , total integrated cost =  47104.76231458074
# RUN  9 , total integrated cost =  47104.73126965594
# RUN  10 , total integrated cost =  47104.70976996257
# RUN  10 , total integrated cost =  47104.70976996257
# Improved over  10  iterations in  8.286527188000036  seconds by  0.008901320266076596  percent.
# costs =  3.3626848715312883 3.9785070630546726
# cost limits =  3.364542320955837 578.6870018605674
# within sparsity cost limit, continue
# set cost params:  18.645 0.0 13986
# ----- 271
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  47128.45574157771
# Gradient descend method:  None
# RUN  1 , total integrated cost =  47125.23414137484
# RUN  2 , total integrated cost =  47125.211294550434
# RUN  3 , total integrated cost =  47125.19087376551
# RUN  4 , total integrated cost =  47125.16476161075
# RUN  5 , total integrated cost =  47125.1398041404
# RUN  6 , total integrated cost =  47125.10929255196
# RUN  7 , total integrated cost =  47125.08274549248
# RUN  8 , total integrated cost =  47125.05374670173
# RUN  9 , total integrated cost =  47125.02963782517
# RUN  10 , total integrated cost =  47124.99923679265
# RUN  10 , total integrated cost =  47124.99923679265
# Improved over  10  iterations in  8.157050449997769  seconds by  0.007334220336034036  percent.
# costs =  3.363730638719285 4.2833211941398295
# cost limits =  3.364542320955837 578.6870018605674
# within sparsity cost limit, continue
# set cost params:  18.64 0.0 13986
# ----- 272
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  47154.443511856945
# Gradient descend method:  None
# RUN  1 , total integrated cost =  47149.29298376198
# RUN  2 , total integrated cost =  47149.263041409766
# RUN  3 , total integrated cost =  47149.238563921775
# RUN  4 , total integrated cost =  47149.20703072197
# RUN  5 , total integrated cost =  47149.178492648585
# RUN  6 , total integrated cost =  47149.1449009649
# RUN  7 , total integrated cost =  47149.11611878086
# RUN  8 , total integrated cost =  47149.0655670841
# RUN  9 , total integrated cost =  47149.022110412596
# RUN  10 , total integrated cost =  47148.95277864033
# RUN  10 , total integrated cost =  47148.95277864033
# Improved over  10  iterations in  9.680136129994935  seconds by  0.011644148054131165  percent.
# costs =  3.3650978864672747 4.543655499410852
# cost limits =  3.364542320955837 578.6870018605674
# iteration  0
# increase sparsity weight at t_ =  108.0
# set cost params:  18.64 0.0 20979
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  70681.08229870597
# Gradient descend method:  None
# RUN  1 , total integrated cost =  70675.01057175198
# RUN  2 , total integrated cost =  70674.9824208866
# RUN  3 , total integrated cost =  70674.96137694517
# RUN  4 , total integrated cost =  70674.93240234278
# RUN  5 , total integrated cost =  70674.9096453593
# RUN  6 , total integrated cost =  70674.86674346321
# RUN  7 , total integrated cost =  70674.82891739013
# RUN  8 , total integrated cost =  70674.68880150621
# RUN  9 , total integrated cost =  70674.54479924678
# RUN  10 , total integrated cost =  70674.48392891334
# RUN  11 , total integrated cost =  70674.43579216953
# RUN  12 , total integrated cost =  70674.34426242883
# RUN  13 , total integrated cost =  70674.26074969454
# RUN  14 , total integrated cost =  70674.15439596032
# RUN  15 , total integrated cost =  70674.0641416457
# RUN  16 , total integrated cost =  70674.00543764341
# RUN  17 , total integrated cost =  70673.95203531982
# RUN  18 , total integrated cost =  70673.88439784516
# RUN  19 , total integrated cost =  70673.82059268345
# RUN  20 , total integrated cost =  70673.76888081321
# RUN  30 , total integrated cost =  70673.27633051338
# RUN  40 , total integrated cost =  70672.82836208784
# RUN  50 , total integrated cost =  70671.57278766244
# RUN  60 , total integrated cost =  70671.37867259629
# RUN  60 , total integrated cost =  70671.37867259629
# Improved over  60  iterations in  51.50302556999668  seconds by  0.01372874578896699  percent.
# costs =  3.363215138895162 6.142074770100808
# cost limits =  3.364542320955837 578.6870018605674
# set cost params:  18.634999999999998 0.0 20979
# ----- 273
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  70707.42767730333
# Gradient descend method:  None
# RUN  1 , total integrated cost =  70702.63688926928
# RUN  2 , total integrated cost =  70702.59439482237
# RUN  3 , total integrated cost =  70702.55310021662
# RUN  4 , total integrated cost =  70702.52694007449
# RUN  5 , total integrated cost =  70702.49916003071
# RUN  6 , total integrated cost =  70702.47239409665
# RUN  7 , total integrated cost =  70702.4460420812
# RUN  8 , total integrated cost =  70702.42520513579
# RUN  9 , total integrated cost =  70702.40313171201
# RUN  10 , total integrated cost =  70702.38421033071
# RUN  10 , total integrated cost =  70702.38421033071
# Improved over  10  iterations in  9.070070178000606  seconds by  0.007132867279011634  percent.
# costs =  3.3645041449900592 6.356412803018648
# cost limits =  3.364542320955837 578.6870018605674
# within sparsity cost limit, continue
# set cost params:  18.630000000000003 0.0 20979
# ----- 274
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  70746.09893476531
# Gradient descend method:  None
# RUN  1 , total integrated cost =  70739.64820442215
# RUN  2 , total integrated cost =  70739.62005565585
# RUN  3 , total integrated cost =  70739.59566652284
# RUN  4 , total integrated cost =  70739.56743737235
# RUN  5 , total integrated cost =  70739.54189521243
# RUN  6 , total integrated cost =  70739.5118865606
# RUN  7 , total integrated cost =  70739.48458730728
# RUN  8 , total integrated cost =  70739.45053889537
# RUN  9 , total integrated cost =  70739.41861173837
# RUN  10 , total integrated cost =  70739.37993128048
# RUN  10 , total integrated cost =  70739.37993128048
# Improved over  10  iterations in  9.378525257001456  seconds by  0.009497348385281157  percent.
# costs =  3.3658434983145793 6.835704784697599
# cost limits =  3.364542320955837 578.6870018605674
# iteration  0
# increase sparsity weight at t_ =  106.0
# set cost params:  18.630000000000003 0.0 31468
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  106043.7123851021
# Gradient descend method:  None
# RUN  1 , total integrated cost =  106033.23156377344
# RUN  2 , total integrated cost =  106033.16780357131
# RUN  3 , total integrated cost =  106033.10090557573
# RUN  4 , total integrated cost =  106033.0245746943
# RUN  5 , total integrated cost =  106032.9547789494
# RUN  6 , total integrated cost =  106032.8811476722
# RUN  7 , total integrated cost =  106032.81228097633
# RUN  8 , total integrated cost =  106032.7803074241
# RUN  9 , total integrated cost =  106032.74499507833
# RUN  10 , total integrated cost =  106032.7181420555
# RUN  11 , total integrated cost =  106032.68608853858
# RUN  12 , total integrated cost =  106032.66312405183
# RUN  13 , total integrated cost =  106032.63258226142
# RUN  14 , total integrated cost =  106032.61035291901
# RUN  15 , total integrated cost =  106032.57777499387
# RUN  16 , total integrated cost =  106032.552445444
# RUN  17 , total integrated cost =  106032.5117982901
# RUN  18 , total integrated cost =  106032.47934841756
# RUN  19 , total integrated cost =  106032.41378072443
# RUN  20 , total integrated cost =  106032.35648247245
# RUN  30 , total integrated cost =  106026.20424090157
# RUN  40 , total integrated cost =  106023.66578097754
# RUN  50 , total integrated cost =  106006.274796988
# RUN  60 , total integrated cost =  106006.06234120364
# RUN  60 , total integrated cost =  106006.06234120364
# Improved over  60  iterations in  50.790135957999155  seconds by  0.03550426805290385  percent.
# costs =  3.3632400849062503 9.212203401704537
# cost limits =  3.364542320955837 578.6870018605674
# set cost params:  18.625 0.0 31468
# ----- 275
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  106061.21682957489
# Gradient descend method:  None
# RUN  1 , total integrated cost =  106053.41982817407
# RUN  2 , total integrated cost =  106053.39345546432
# RUN  3 , total integrated cost =  106053.37171410586
# RUN  4 , total integrated cost =  106053.34534874106
# RUN  5 , total integrated cost =  106053.3231936872
# RUN  6 , total integrated cost =  106053.2960185981
# RUN  7 , total integrated cost =  106053.274246766
# RUN  8 , total integrated cost =  106053.24709711217
# RUN  9 , total integrated cost =  106053.22575351209
# RUN  10 , total integrated cost =  106053.19834286955
# RUN  10 , total integrated cost =  106053.19834286955
# Improved over  10  iterations in  9.075062283998705  seconds by  0.0075602439280118006  percent.
# costs =  3.364457738228189 9.688173761336493
# cost limits =  3.364542320955837 578.6870018605674
# within sparsity cost limit, continue
# set cost params:  18.619999999999997 0.0 31468
# ----- 276
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  106120.40985447999
# Gradient descend method:  None
# RUN  1 , total integrated cost =  106108.87761004828
# RUN  2 , total integrated cost =  106108.82880432032
# RUN  3 , total integrated cost =  106108.7903505516
# RUN  4 , total integrated cost =  106108.69397911528
# RUN  5 , total integrated cost =  106108.60281641796
# RUN  6 , total integrated cost =  106108.3592606917
# RUN  7 , total integrated cost =  106108.14541337421
# RUN  8 , total integrated cost =  106107.95389511445
# RUN  9 , total integrated cost =  106107.78107864475
# RUN  10 , total integrated cost =  106107.47343156698
# RUN  10 , total integrated cost =  106107.47343156698
# Improved over  10  iterations in  9.34213371599617  seconds by  0.012190325056934626  percent.
# costs =  3.3656878524077256 10.526750375976173
# cost limits =  3.364542320955837 578.6870018605674
# iteration  0
# increase sparsity weight at t_ =  104.0
# set cost params:  18.619999999999997 0.0 47202
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  159063.20610135014
# Gradient descend method:  None
# RUN  1 , total integrated cost =  159050.38628003714
# RUN  2 , total integrated cost =  159050.33115425636
# RUN  3 , total integrated cost =  159050.29981310797
# RUN  4 , total integrated cost =  159050.26056028614
# RUN  5 , total integrated cost =  159050.2328791868
# RUN  6 , total integrated cost =  159050.19711317032
# RUN  7 , total integrated cost =  159050.17234054412
# RUN  8 , total integrated cost =  159050.13828952564
# RUN  9 , total integrated cost =  159050.11499903764
# RUN  10 , total integrated cost =  159050.07534425543
# RUN  11 , total integrated cost =  159050.04417789873
# RUN  12 , total integrated cost =  159049.8983157377
# RUN  13 , total integrated cost =  159049.73333500687
# RUN  14 , total integrated cost =  159049.5241895164
# RUN  15 , total integrated cost =  159049.32548625546
# RUN  16 , total integrated cost =  159049.1710197231
# RUN  17 , total integrated cost =  159049.0174537851
# RUN  18 , total integrated cost =  159048.3360911086
# RUN  19 , total integrated cost =  159047.6162296992
# RUN  20 , total integrated cost =  159047.59133744595
# RUN  30 , total integrated cost =  159046.6514558977
# RUN  40 , total integrated cost =  159045.00084172614
# RUN  50 , total integrated cost =  159032.65462518152
# RUN  60 , total integrated cost =  159030.57010460043
# RUN  60 , total integrated cost =  159030.57010460043
# Improved over  60  iterations in  53.63390032100142  seconds by  0.020517627897504553  percent.
# costs =  3.363640621596213 13.963774651770267
# cost limits =  3.364542320955837 578.6870018605674
# set cost params:  18.615000000000002 0.0 47202
# ----- 277
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  159129.55606668652
# Gradient descend method:  None
# RUN  1 , total integrated cost =  159114.29051047823
# RUN  2 , total integrated cost =  159114.2320201406
# RUN  3 , total integrated cost =  159114.18046042108
# RUN  4 , total integrated cost =  159114.11933646278
# RUN  5 , total integrated cost =  159114.06165194488
# RUN  6 , total integrated cost =  159113.96829504517
# RUN  7 , total integrated cost =  159113.89292923274
# RUN  8 , total integrated cost =  159113.7597129882
# RUN  9 , total integrated cost =  159113.65305753125
# RUN  10 , total integrated cost =  159113.45649023974
# RUN  10 , total integrated cost =  159113.45649023974
# Improved over  10  iterations in  8.554559624993999  seconds by  0.010117276038926093  percent.
# costs =  3.3649346162112317 15.139013475002491
# cost limits =  3.364542320955837 578.6870018605674
# iteration  0
# increase sparsity weight at t_ =  103.0
# set cost params:  18.615000000000002 0.0 70803
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  238529.27836744103
# Gradient descend method:  None
# RUN  1 , total integrated cost =  238507.9636275889
# RUN  2 , total integrated cost =  238507.91122821378
# RUN  3 , total integrated cost =  238507.86983648053
# RUN  4 , total integrated cost =  238507.80306308006
# RUN  5 , total integrated cost =  238507.73835182778
# RUN  6 , total integrated cost =  238507.65206755375
# RUN  7 , total integrated cost =  238507.56233486257
# RUN  8 , total integrated cost =  238507.17863843672
# RUN  9 , total integrated cost =  238506.80672367383
# RUN  10 , total integrated cost =  238496.0354671718
# RUN  11 , total integrated cost =  238493.17036230583
# RUN  12 , total integrated cost =  238493.14699922546
# RUN  13 , total integrated cost =  238493.12124739581
# RUN  14 , total integrated cost =  238493.09881968942
# RUN  15 , total integrated cost =  238493.07445244095
# RUN  16 , total integrated cost =  238493.05269079065
# RUN  17 , total integrated cost =  238493.02792882614
# RUN  18 , total integrated cost =  238493.00573604563
# RUN  19 , total integrated cost =  238492.97990307186
# RUN  20 , total integrated cost =  238492.95641831402
# RUN  30 , total integrated cost =  238491.86745791414
# RUN  40 , total integrated cost =  238487.32077062692
# RUN  50 , total integrated cost =  238485.44249424653
# RUN  60 , total integrated cost =  238484.94622808837
# RUN  60 , total integrated cost =  238484.94622808837
# Improved over  60  iterations in  51.761153018000186  seconds by  0.018585617520869846  percent.
# costs =  3.362801124658934 20.87231796195982
# cost limits =  3.364542320955837 578.6870018605674
# set cost params:  18.61 0.0 70803
# ----- 278
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  238599.2012516814
# Gradient descend method:  None
# RUN  1 , total integrated cost =  238580.26166265534
# RUN  2 , total integrated cost =  238580.19531466786
# RUN  3 , total integrated cost =  238580.14164663985
# RUN  4 , total integrated cost =  238580.07895273776
# RUN  5 , total integrated cost =  238580.03129006812
# RUN  6 , total integrated cost =  238579.9736417614
# RUN  7 , total integrated cost =  238579.92916748975
# RUN  8 , total integrated cost =  238579.87188508353
# RUN  9 , total integrated cost =  238579.83022047055
# RUN  10 , total integrated cost =  238579.7699242422
# RUN  10 , total integrated cost =  238579.7699242422
# Improved over  10  iterations in  7.746149765996961  seconds by  0.008143919735374539  percent.
# costs =  3.363975056095177 21.506933236720254
# cost limits =  3.364542320955837 578.6870018605674
# within sparsity cost limit, continue
# set cost params:  18.605 0.0 70803
# ----- 279
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  238728.5308864436
# Gradient descend method:  None
# RUN  1 , total integrated cost =  238702.33809499684
# RUN  2 , total integrated cost =  238702.26837259327
# RUN  3 , total integrated cost =  238702.20919274352
# RUN  4 , total integrated cost =  238702.12357076025
# RUN  5 , total integrated cost =  238702.0483206714
# RUN  6 , total integrated cost =  238701.95090485032
# RUN  7 , total integrated cost =  238701.86819724485
# RUN  8 , total integrated cost =  238701.71836635063
# RUN  9 , total integrated cost =  238701.59920117896
# RUN  10 , total integrated cost =  238701.4434725561
# RUN  10 , total integrated cost =  238701.4434725561
# Improved over  10  iterations in  7.468819490997703  seconds by  0.011346533984408325  percent.
# costs =  3.3653518499446253 22.813030955484678
# cost limits =  3.364542320955837 578.6870018605674
# iteration  0
# increase sparsity weight at t_ =  101.0
# set cost params:  18.605 0.0 106204
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  357838.26431244577
# Gradient descend method:  None
# RUN  1 , total integrated cost =  357804.13259972766
# RUN  2 , total integrated cost =  357803.9735928997
# RUN  3 , total integrated cost =  357803.7968280217
# RUN  4 , total integrated cost =  357803.61816645775
# RUN  5 , total integrated cost =  357803.4896629885
# RUN  6 , total integrated cost =  357803.35357241606
# RUN  7 , total integrated cost =  357803.1644815749
# RUN  8 , total integrated cost =  357802.9960562212
# RUN  9 , total integrated cost =  357802.8550138006
# RUN  10 , total integrated cost =  357802.705393935
# RUN  11 , total integrated cost =  357802.53003905265
# RUN  12 , total integrated cost =  357802.36119219626
# RUN  13 , total integrated cost =  357799.59656880406
# RUN  14 , total integrated cost =  357797.497653448
# RUN  15 , total integrated cost =  357797.24922620837
# RUN  16 , total integrated cost =  357797.0138846803
# RUN  17 , total integrated cost =  357796.81136832753
# RUN  18 , total integrated cost =  357796.63608942565
# RUN  19 , total integrated cost =  357796.31256548665
# RUN  20 , total integrated cost =  357796.02487308334
# RUN  30 , total integrated cost =  357790.6318703336
# RUN  40 , total integrated cost =  357790.1340545439
# RUN  50 , total integrated cost =  357785.52888507384
# RUN  60 , total integrated cost =  357784.2474616713
# RUN  60 , total integrated cost =  357784.2474616713
# Improved over  60  iterations in  44.8900233999957  seconds by  0.015095325503622803  percent.
# costs =  3.363310019244399 31.56518021172636
# cost limits =  3.364542320955837 578.6870018605674
# set cost params:  18.6 0.0 106204
# ----- 280
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  357974.7824386927
# Gradient descend method:  None
# RUN  1 , total integrated cost =  357946.43199060194
# RUN  2 , total integrated cost =  357946.3265181785
# RUN  3 , total integrated cost =  357946.25563586614
# RUN  4 , total integrated cost =  357946.1391911136
# RUN  5 , total integrated cost =  357946.0436693531
# RUN  6 , total integrated cost =  357945.8187185136
# RUN  7 , total integrated cost =  357945.6072274496
# RUN  8 , total integrated cost =  357944.65730762004
# RUN  9 , total integrated cost =  357943.82489694096
# RUN  10 , total integrated cost =  357939.63994472154
# RUN  10 , total integrated cost =  357939.63994472154
# Improved over  10  iterations in  8.455142218001129  seconds by  0.009817030610861366  percent.
# costs =  3.36509054657156 29.761480464278506
# cost limits =  3.364542320955837 578.6870018605674
# iteration  0
# increase sparsity weight at t_ =  100.0
# set cost params:  18.6 0.0 159306
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  536632.6781487645
# Gradient descend method:  None
# RUN  1 , total integrated cost =  536542.5365510341
# RUN  2 , total integrated cost =  536542.409353322
# RUN  3 , total integrated cost =  536542.1947680766
# RUN  4 , total integrated cost =  536541.9834293511
# RUN  5 , total integrated cost =  536541.666295054
# RUN  6 , total integrated cost =  536541.3268674356
# RUN  7 , total integrated cost =  536540.3169152457
# RUN  8 , total integrated cost =  536539.2990520224
# RUN  9 , total integrated cost =  536539.1456860561
# RUN  10 , total integrated cost =  536539.0101985082
# RUN  11 , total integrated cost =  536538.8379173254
# RUN  12 , total integrated cost =  536538.6806440076
# RUN  13 , total integrated cost =  536538.490702853
# RUN  14 , total integrated cost =  536538.3065612405
# RUN  15 , total integrated cost =  536538.1299469381
# RUN  16 , total integrated cost =  536537.9599761426
# RUN  17 , total integrated cost =  536537.7632112501
# RUN  18 , total integrated cost =  536537.5537786264
# RUN  19 , total integrated cost =  536537.3318819322
# RUN  20 , total integrated cost =  536537.1284159807
# RUN  30 , total integrated cost =  536535.2602334288
# RUN  40 , total integrated cost =  536533.7062192945
# RUN  50 , total integrated cost =  536523.7060911743
# RUN  60 , total integrated cost =  536514.7871378576
# RUN  60 , total integrated cost =  536514.7871378576
# Improved over  60  iterations in  50.07177751299605  seconds by  0.02196866044639023  percent.
# costs =  3.362288946538819 47.418506480889484
# cost limits =  3.364542320955837 578.6870018605674
