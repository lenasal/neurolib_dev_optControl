# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import sys
import pickle

path = os.getcwd().split(os.sep + 'GUI')[0]
if path not in sys.path:
    print("not here")
    sys.path.append(path)

from neurolib.models.aln import ALNModel
from neurolib.utils import plotFunctions as plotFunc
from neurolib.utils import costFunctions as cost
import neurolib.dashboard.functions as functions
import neurolib.dashboard.data as data
    
# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2 

#path = os.path.join(os.getcwd(), "plots")
# Out:
# not here

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import sys
import pickle

path = os.getcwd().split(os.sep + 'GUI')[0]
if path not in sys.path:
    print("not here")
    sys.path.append(path)

from neurolib.models.aln import ALNModel
from neurolib.utils import plotFunctions as plotFunc
from neurolib.utils import costFunctions as cost
import neurolib.dashboard.functions as functions
import neurolib.dashboard.data as data
    
# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2 

#path = os.path.join(os.getcwd(), "plots")
# Out:
# not here

# %%
aln = ALNModel()
N = aln.params.N

data.set_parameters(aln)

state_vars = aln.state_vars
init_vars = aln.init_vars

##############################################################
def setinit(init_vars_, model):
    state_vars = model.state_vars
    init_vars = model.init_vars
    for iv in range(len(init_vars)):
        for sv in range(len(state_vars)):
            if state_vars[sv] in init_vars[iv]:
                #print("set init vars ", )
                if model.params[init_vars[iv]].ndim == 2:
                    model.params[init_vars[iv]][0,:] = init_vars_[sv]
                else:
                    model.params[init_vars[iv]][0] = init_vars_[sv]
                    
##############################################################               
def setmaxmincontrol(max_c_c, min_c_c, max_c_r, min_c_r):
    import numpy as np
    
    max_cntrl = np.zeros(( 6 ))
    min_cntrl = np.zeros(( 6 ))
    
    max_cntrl[0] = max_c_c
    min_cntrl[0] = min_c_c
    max_cntrl[1] = max_c_c
    min_cntrl[1] = min_c_c
    max_cntrl[2] = max_c_r
    min_cntrl[2] = min_c_r
    max_cntrl[3] = max_c_r
    min_cntrl[3] = min_c_r
    max_cntrl[4] = max_c_r
    min_cntrl[4] = min_c_r
    max_cntrl[5] = max_c_r
    min_cntrl[5] = min_c_r
            
    return max_cntrl, min_cntrl

# %%
##### LOAD BOUNDARIES
data_file = 'bi.pickle'
with open(data_file,'rb') as f:
    load_array= pickle.load(f)
exc = load_array[0]
inh = load_array[1]
print(len(exc))
# Out:
# 147

# %%
t0_array = np.arange(380., -1, -1.)
t_pen = t0_array / 400.

bestControl_1 = [None] * len(t_pen)
bestState_1 = [None] * len(t_pen)
cost_1 = [None] * len(t_pen)
runtime_1 = [None] * len(t_pen)
grad_1 = [None] * len(t_pen)
phi_1 = [None] * len(t_pen)
costnode_1 = [None] * len(t_pen)
weights_1 = [None] * len(t_pen)

# %%
initVars = [None] * len(exc)
target = [None] * len(exc)
cost_uncontrolled = [None] * len(exc)

cgv_list = [None, "HS", "FR", "PR", "CD", "LS", "DY", "WYL", "HZ", None]

# %%
dur_pre = 10
dur_post = 10

i = 50

n_pre = int(np.around(dur_pre/aln.params.dt + 1.,1))
n_post = int(np.around(dur_post/aln.params.dt + 1.,1))

tol = 1e-32
start_step = 10.
c_scheme = np.zeros(( 1,1 ))
c_scheme[0,0] = 1.
u_mat = np.identity(1)
u_scheme = np.array([[1.]])

c_var = [ [0], [1], [0,1]]
p_var = [ [0], [0], [0]]

### CURRENTS
cntrl_vars_0 = [0,1]
prec_vars = [0]

max_I = [3., -3.]
factor_wp = 1. / 0.05
factor_ws = 1.
factor_we = 0.
dur = 400
trans_time = 0.95
    
maxC = [5., -5., 0.18, 0.]

n_dur = int(np.around(dur/aln.params.dt + 1.,1))
max_cntrl, min_cntrl = setmaxmincontrol(maxC[0], maxC[1], maxC[2], maxC[3])

# %%
init_file = 'control_1.pickle'
final_file_1 = 'control_tradeoff_1b.pickle'

# %%
if os.path.isfile(init_file) :
    print("init file found")
    
    with open(init_file,'rb') as f:
        load_array = pickle.load(f)

    print(len(load_array[0]))

    bestControl_1[0] = load_array[0][i]
    bestState_1[0] = load_array[1][i]
    cost_1 [0]= load_array[2][i]
    runtime_1[0] = load_array[3][i]
    grad_1 [0]= load_array[4][i]
    phi_1[0] = load_array[5][i]
    costnode_1[0] = load_array[6][i]
    weights_1[0] = load_array[7][i]
# Out:
# init file found
# 147

# %%
if os.path.isfile(final_file_1) :
    print("final file found")
    
    with open(final_file_1,'rb') as f:
        load_array = pickle.load(f)

    print(len(load_array[0]))

    bestControl_1 = load_array[0]
    bestState_1 = load_array[1]
    cost_1 = load_array[2]
    runtime_1 = load_array[3]
    grad_1 = load_array[4]
    phi_1 = load_array[5]
    costnode_1 = load_array[6]
    weights_1 = load_array[7]

# %%
# get initial parameters and target states

print("------- ", i, exc[i], inh[i])
aln.params.ext_exc_current = exc[i] * 5.
aln.params.ext_inh_current = inh[i] * 5.

aln.params.duration = 3000.

control0 = aln.getZeroControl()
control0 = functions.step_control(aln, maxI_ = max_I[0])

aln.run(control=control0)

target_rates = np.zeros((2))
target_rates[0] = aln.rates_exc[0,-1] 
target_rates[1] = aln.rates_inh[0,-1]

control0 = functions.step_control(aln, maxI_ = max_I[1])
aln.run(control=control0)

init_state_vars = np.zeros(( len(state_vars) ))
for j in range(len(state_vars)):
    if aln.state[state_vars[j]].size == 1:
        init_state_vars[j] = aln.state[state_vars[j]][0]
    else:
        init_state_vars[j] = aln.state[state_vars[j]][0,-1]

initVars[i] = init_state_vars

aln.params.duration = dur

target[i] = aln.getZeroTarget()
target[i][:,0,:] = target_rates[0]
target[i][:,1,:] = target_rates[1]
# Out:
# -------  50 0.47500000000000014 0.6000000000000003

# %%
# get uncontrolled cost

data.set_parameters(aln)
aln.params.ext_exc_current = exc[i] * 5.
aln.params.ext_inh_current = inh[i] * 5.
aln.params.duration = dur

cgv = None

# %%
plt.plot(np.arange(bestControl_1[0].shape[2]), bestControl_1[0][0,0,:])

print(np.argmax(np.abs(bestControl_1[0]), axis=2))
print(bestControl_1[0][0,0,1450:1550]/5.)
print(bestControl_1[0][0,0,1674]/5.)

max_percent = (np.argmax(np.abs(bestControl_1[0]), axis=2)[0,0] -100) / 3800
print(max_percent)
# Out:
# [[1493 1459    0    0    0    0]]
# [0.1887449  0.18940443 0.19006721 0.19073437 0.19127412 0.19183752
#  0.19240474 0.19297604 0.19355152 0.19413113 0.19471516 0.19530369
#  0.19589545 0.1964921  0.19691366 0.1973731  0.19783702 0.19830555
#  0.19877894 0.19925729 0.19974076 0.20022948 0.20072142 0.20121898
#  0.20152361 0.20184686 0.20217555 0.20250963 0.20284957 0.20319537
#  0.20354711 0.20390511 0.20426777 0.20463704 0.20476406 0.2049196
#  0.20508167 0.20525061 0.20542685 0.2056105  0.20580174 0.20600069
#  0.20620717 0.20641946 0.20636298 0.20632224 0.20628986 0.20626639
#  0.20625222 0.2062474  0.20625182 0.20626579 0.20628947 0.20632172
#  0.20604377 0.20578487 0.2055366  0.20529999 0.20507479 0.20486131
#  0.20465961 0.20446969 0.2042916  0.2041248  0.20359193 0.20310032
#  0.20262138 0.20215605 0.20170431 0.20126577 0.20084105 0.20043026
#  0.20003361 0.19965103 0.19928252 0.19854003 0.19782553 0.19712711
#  0.19644444 0.19577736 0.19512554 0.19448925 0.19386852 0.19326305
#  0.19267297 0.19209824 0.19154053 0.19060978 0.18970241 0.18881112
#  0.18793767 0.18708173 0.18624288 0.18542116 0.1846164  0.18382785
#  0.18305728 0.18230505 0.1815708  0.18044129]
# 0.06504576710188348
# 0.36657894736842106

# %%
factor_iteration = 1.

##### initial guess
weight_ = 1.
cost.setParams(weight_ * factor_wp, weight_ * factor_we, weight_ * factor_ws)

setinit(initVars[i], aln)

weights_1[0] = cost.getParams()

for j in range(1, 381):

    dur = 400. - np.around(j/10., 1)
    T = 4001 - j
    aln.params.duration = dur

    factor_wp = dur / 20.
    cost.setParams(weight_ * factor_wp, weight_ * factor_we, weight_ * factor_ws)

    print('-----', j)
    setinit(initVars[i], aln)

    max_it = 3.
    if j > 170:
        max_it = 40.
    elif j > 140:
        max_it = 30.
    elif j > 100.:
        max_it = 20.
    
    if type(bestControl_1[j]) == type(None):
        total_shift = round(j * max_percent * 10)
        prev_shift = round( (j-1) * max_percent * 10)
        shift_ind = total_shift - prev_shift
        #print(total_shift, prev_shift, shift_ind)
        control0 = np.zeros(( bestControl_1[j-1][:,:,100:-101].shape ))
        control0[:,:,:-shift_ind] = 1. * bestControl_1[j-1][:,:,100+shift_ind:-101]
    else:
        if bestControl_1[j].shape[2] == T+200:
            control0 = bestControl_1[j][:,:,100:-100]
        else:
            control0 = bestControl_1[j][:,:,100:-(100+j)]

    bestControl_1[j], bestState_1[j], cost_1[j], runtime_1[j], grad_1[j], phi_1[j], costnode_1[j] = aln.A1(
        control0, target[i], c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = [0,1],
        prec_variables_ = prec_vars, transition_time_ = t_pen[j])

    print(costnode_1[j][0][0][0], costnode_1[j][2][0][0])

    print(costnode_1[0][0][0][0], costnode_1[0][2][0][0])
        
    with open(final_file_1,'wb') as f:
        pickle.dump([bestControl_1, bestState_1, cost_1, runtime_1, grad_1, phi_1,
                costnode_1, weights_1], f)
# Out:
# set cost params:  20.0 0.0 1.0
# set cost params:  19.994999999999997 0.0 1.0
# ----- 1
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  334723.35576641635
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.00642479298991
# RUN  2 , total integrated cost =  5.006408600845563
# RUN  3 , total integrated cost =  5.006408599633838
# RUN  3 , total integrated cost =  5.006408599633838
# Improved over  3  iterations in  15.922768608001206  seconds by  99.99850431452919  percent.
# 3.991681368602697e-07 9.555140072036126e-07
# 2.6910949261846287e-07 1.1991608351392206e-16
# set cost params:  19.990000000000002 0.0 1.0
# ----- 2
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  348981.13770886185
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.006429153164384
# RUN  2 , total integrated cost =  5.006414468048698
# RUN  3 , total integrated cost =  5.006414442303933
# RUN  3 , total integrated cost =  5.006414442303933
# Improved over  3  iterations in  1.1027693180003553  seconds by  99.99856541976017  percent.
# 6.596993300433746e-07 1.6995655885726554e-06
# 2.6910949261846287e-07 1.1991608351392206e-16
# set cost params:  19.985 0.0 1.0
# ----- 3
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  364824.8500929532
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.006447906080388
# RUN  2 , total integrated cost =  5.006421477278713
# RUN  3 , total integrated cost =  5.006420571283316
# RUN  3 , total integrated cost =  5.006420571283316
# Improved over  3  iterations in  1.1828903530004027  seconds by  99.99862771941933  percent.
# 9.5948309158418e-07 1.690637919724315e-06
# 2.6910949261846287e-07 1.1991608351392206e-16
# set cost params:  19.98 0.0 1.0
# ----- 4
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  380660.58853985317
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.006447443487756
# RUN  2 , total integrated cost =  5.006426615356931
# RUN  3 , total integrated cost =  5.006426202038529
# RUN  3 , total integrated cost =  5.006426202038529
# Improved over  3  iterations in  1.1270819179990212  seconds by  99.99868480574224  percent.
# 1.2349310929439392e-06 1.6611736713372669e-06
# 2.6910949261846287e-07 1.1991608351392206e-16
# set cost params:  19.975 0.0 1.0
# ----- 5
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  396488.35253071896
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.006447739134684
# RUN  2 , total integrated cost =  5.006431610010151
# RUN  3 , total integrated cost =  5.006431411763972
# RUN  3 , total integrated cost =  5.006431411763972
# Improved over  3  iterations in  1.40969058599876  seconds by  99.99873730681372  percent.
# 1.490094895430317e-06 1.6611736139042233e-06
# 2.6910949261846287e-07 1.1991608351392206e-16
# set cost params:  19.97 0.0 1.0
# ----- 6
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  412308.15081748395
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.006438976227428
# RUN  2 , total integrated cost =  5.0064358577870145
# RUN  3 , total integrated cost =  5.006435853787146
# RUN  3 , total integrated cost =  5.006435853787146
# Improved over  3  iterations in  0.9325016860020696  seconds by  99.99878575384847  percent.
# 1.6646686115427657e-06 2.784944953721277e-06
# 2.6910949261846287e-07 1.1991608351392206e-16
# set cost params:  19.965 0.0 1.0
# ----- 7
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  428119.97482651996
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.006450370657335
# RUN  2 , total integrated cost =  5.006439036276093
# RUN  3 , total integrated cost =  5.006438958788326
# RUN  3 , total integrated cost =  5.006438958788326
# Improved over  3  iterations in  0.9182082270017418  seconds by  99.99883059907195  percent.
# 1.8109680807941755e-06 2.8169406690521735e-06
# 2.6910949261846287e-07 1.1991608351392206e-16
# set cost params:  19.96 0.0 1.0
# ----- 8
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  443923.82398971566
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.006450663168038
# RUN  2 , total integrated cost =  5.006442102308591
# RUN  3 , total integrated cost =  5.006442088314895
# RUN  3 , total integrated cost =  5.006442088314895
# Improved over  3  iterations in  1.006730859997333  seconds by  99.99887222946421  percent.
# 1.959129968559248e-06 2.8861324025392815e-06
# 2.6910949261846287e-07 1.1991608351392206e-16
# set cost params:  19.955000000000002 0.0 1.0
# ----- 9
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  459719.7081980878
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.006444750134228
# RUN  2 , total integrated cost =  5.006444599623826
# RUN  3 , total integrated cost =  5.0064445995261115
# RUN  3 , total integrated cost =  5.0064445995261115
# Improved over  3  iterations in  0.9844358459995419  seconds by  99.99891097890513  percent.
# 2.073063906708714e-06 2.9790050867775036e-06
# 2.6910949261846287e-07 1.1991608351392206e-16
# set cost params:  19.95 0.0 1.0
# ----- 10
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  475507.6177580538
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.006451271413876
# RUN  2 , total integrated cost =  5.006446696272174
# RUN  3 , total integrated cost =  5.006446670543375
# RUN  3 , total integrated cost =  5.006446670543375
# Improved over  3  iterations in  0.9497317550012667  seconds by  99.99894713638992  percent.
# 2.1697563449311187e-06 2.9284171809547652e-06
# 2.6910949261846287e-07 1.1991608351392206e-16
# set cost params:  19.945 0.0 1.0
# ----- 11
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  491287.55205292074
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.006449454277806
# RUN  2 , total integrated cost =  5.006449269783837
# RUN  3 , total integrated cost =  5.006449269536547
# RUN  3 , total integrated cost =  5.006449269536547
# Improved over  3  iterations in  0.8909130440006265  seconds by  99.99898095336457  percent.
# 2.2576525704669677e-06 3.925916694743647e-06
# 2.6910949261846287e-07 1.1991608351392206e-16
# set cost params:  19.94 0.0 1.0
# ----- 12
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  507059.5221955419
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.006453750116355
# RUN  2 , total integrated cost =  5.006450673520942
# RUN  3 , total integrated cost =  5.006450640404159
# RUN  3 , total integrated cost =  5.006450640404159
# Improved over  3  iterations in  1.0462964069993177  seconds by  99.99901265030607  percent.
# 2.3162321445586484e-06 3.943739711527727e-06
# 2.6910949261846287e-07 1.1991608351392206e-16
# set cost params:  19.935 0.0 1.0
# ----- 13
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  522823.51729705994
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.006453035692223
# RUN  2 , total integrated cost =  5.006451780726389
# RUN  3 , total integrated cost =  5.006451779676521
# RUN  3 , total integrated cost =  5.006451779676521
# Improved over  3  iterations in  1.358009037998272  seconds by  99.99904242031698  percent.
# 2.360774824010299e-06 4.019197303087018e-06
# 2.6910949261846287e-07 1.1991608351392206e-16
# set cost params:  19.93 0.0 1.0
# ----- 14
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  536990.8213088056
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.006452688442993
# RUN  2 , total integrated cost =  5.006452607253448
# RUN  3 , total integrated cost =  5.006452607119717
# RUN  3 , total integrated cost =  5.006452607119717
# Improved over  3  iterations in  1.1461770899986732  seconds by  99.99906768376508  percent.
# 2.3947084136554308e-06 4.019160134039745e-06
# 2.6910949261846287e-07 1.1991608351392206e-16
# set cost params:  19.925 0.0 1.0
# ----- 15
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  552739.2760048925
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.006453798624249
# RUN  2 , total integrated cost =  5.006453319019195
# RUN  3 , total integrated cost =  5.006453318630986
# RUN  3 , total integrated cost =  5.006453318630986
# Improved over  3  iterations in  0.971866444000625  seconds by  99.9990942468654  percent.
# 2.4208917858007605e-06 3.988511358657742e-06
# 2.6910949261846287e-07 1.1991608351392206e-16
# set cost params:  19.919999999999998 0.0 1.0
# ----- 16
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  568479.7552199138
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.006454877993262
# RUN  2 , total integrated cost =  5.006453990631815
# RUN  3 , total integrated cost =  5.006453967684552
# RUN  3 , total integrated cost =  5.006453967684552
# Improved over  3  iterations in  0.9134116290006205  seconds by  99.99911932590005  percent.
# 2.4411817837281236e-06 4.023095771904658e-06
# 2.6910949261846287e-07 1.1991608351392206e-16
# set cost params:  19.915 0.0 1.0
# ----- 17
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  584212.2580714246
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.006454826470608
# RUN  2 , total integrated cost =  5.006454526827154
# RUN  3 , total integrated cost =  5.006453490800822
# RUN  3 , total integrated cost =  5.006453490800822
# Improved over  3  iterations in  0.8134630130007281  seconds by  99.99914304203281  percent.
# 1.6565732079071245e-06 3.237859864282654e-06
# 2.6910949261846287e-07 1.1991608351392206e-16
# set cost params:  19.91 0.0 1.0
# ----- 18
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5.0064532475206445
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.0064193121417215
# RUN  2 , total integrated cost =  5.006417971025778
# RUN  3 , total integrated cost =  5.006417942725855
# RUN  3 , total integrated cost =  5.006417942725855
# Improved over  3  iterations in  0.7014553570006683  seconds by  0.00070518574815992  percent.
# 7.540907715608163e-07 2.205068424724835e-09
# 2.6910949261846287e-07 1.1991608351392206e-16
# set cost params:  19.905 0.0 1.0
# ----- 19
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  615653.3629639017
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.006418267051481
# RUN  2 , total integrated cost =  5.006418189736179
# RUN  3 , total integrated cost =  5.006415678309672
# RUN  3 , total integrated cost =  5.006415678309672
# Improved over  3  iterations in  0.7679280669981381  seconds by  99.99918681258326  percent.
# 2.961887513312634e-07 7.424967979514054e-12
# 2.6910949261846287e-07 1.1991608351392206e-16
# set cost params:  19.9 0.0 1.0
# ----- 20
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5.006415484486293
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.006408184424117
# RUN  2 , total integrated cost =  5.0064081753056096
# RUN  3 , total integrated cost =  5.006408165786669
# RUN  3 , total integrated cost =  5.006408165786669
# Improved over  3  iterations in  0.8451639269987936  seconds by  0.00014618642113362057  percent.
# 2.398260348201556e-07 6.11160525906326e-15
# 2.6910949261846287e-07 1.1991608351392206e-16
# set cost params:  19.895 0.0 1.0
# ----- 21
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  645476.6519997502
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.006408466619447
# RUN  2 , total integrated cost =  5.0064084292680056
# RUN  3 , total integrated cost =  5.006406047804809
# RUN  3 , total integrated cost =  5.006406047804809
# Improved over  3  iterations in  0.9328834459993232  seconds by  99.99922438619085  percent.
# 4.9289794124532386e-08 3.019820824555223e-16
# 2.6910949261846287e-07 1.1991608351392206e-16
# set cost params:  19.89 0.0 1.0
# ----- 22
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5.006405773419878
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.006404919017819
# RUN  2 , total integrated cost =  5.006404918542523
# RUN  3 , total integrated cost =  5.006404918123199
# RUN  3 , total integrated cost =  5.006404918123199
# Improved over  3  iterations in  1.1637676999998803  seconds by  1.708404629141569e-05  percent.
# 4.830631606931065e-08 3.019820754958037e-16
# 2.6910949261846287e-07 1.1991608351392206e-16
# set cost params:  19.884999999999998 0.0 1.0
# ----- 23
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  676854.7704119865
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.006405147391583
# RUN  2 , total integrated cost =  5.006405144533008
# RUN  3 , total integrated cost =  5.00640514386498
# RUN  3 , total integrated cost =  5.00640514386498
# Improved over  3  iterations in  1.0280574110001908  seconds by  99.99926034278508  percent.
# 4.826520777585672e-08 3.019820708966228e-16
# 2.6910949261846287e-07 1.1991608351392206e-16
# set cost params:  19.880000000000003 0.0 1.0
# ----- 24
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  692531.8833100824
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.006405478662116
# RUN  2 , total integrated cost =  5.006405451294324
# RUN  3 , total integrated cost =  5.006405449406793
# RUN  3 , total integrated cost =  5.006405449406793
# Improved over  3  iterations in  0.9002415760005533  seconds by  99.99927708664828  percent.
# 4.8031810616074004e-08 3.019820645622929e-16
# 2.6910949261846287e-07 1.1991608351392206e-16
# set cost params:  19.875 0.0 1.0
# ----- 25
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  708201.0174395102
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.006405785599916
# RUN  2 , total integrated cost =  5.006405767346899
# RUN  3 , total integrated cost =  5.006405751112963
# RUN  3 , total integrated cost =  5.006405751112963
# Improved over  3  iterations in  1.0923594570012938  seconds by  99.99929308125408  percent.
# 4.833475067257823e-08 3.0198205798902395e-16
# 2.6910949261846287e-07 1.1991608351392206e-16
# set cost params:  19.869999999999997 0.0 1.0
# ----- 26
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  723862.1727887744
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.006405992534971
# RUN  2 , total integrated cost =  5.006405991868138
# RUN  3 , total integrated cost =  5.006405991081859
# RUN  3 , total integrated cost =  5.006405991081859
# Improved over  3  iterations in  1.1437334190013644  seconds by  99.99930837579593  percent.
# 4.7310006188111016e-08 3.0198205289685877e-16
# 2.6910949261846287e-07 1.1991608351392206e-16
# set cost params:  19.865000000000002 0.0 1.0
# ----- 27
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  737931.8376363184
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.006406360386132
# RUN  2 , total integrated cost =  5.006406330586708
# RUN  3 , total integrated cost =  5.00640632849762
# RUN  3 , total integrated cost =  5.00640632849762
# Improved over  3  iterations in  1.0298282449984981  seconds by  99.99932156249763  percent.
# 4.742323646075741e-08 3.019820458835529e-16
# 2.6910949261846287e-07 1.1991608351392206e-16
# set cost params:  19.86 0.0 1.0
# ----- 28
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  753577.4561588002
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.00640668337986
# RUN  2 , total integrated cost =  5.006406681905833
# RUN  3 , total integrated cost =  5.006406680442382
# RUN  3 , total integrated cost =  5.006406680442382
# Improved over  3  iterations in  0.9847818000016559  seconds by  99.99933564802934  percent.
# 4.6693581280880734e-08 3.0198203860569403e-16
# 2.6910949261846287e-07 1.1991608351392206e-16
# set cost params:  19.855 0.0 1.0
# ----- 29
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  769215.092206947
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.006406979362892
# RUN  2 , total integrated cost =  5.006406958759866
# RUN  3 , total integrated cost =  5.006406957608605
# RUN  3 , total integrated cost =  5.006406957608605
# Improved over  3  iterations in  1.6372927379998146  seconds by  99.99934915383118  percent.
# 4.675087204882616e-08 3.019820329676972e-16
# 2.6910949261846287e-07 1.1991608351392206e-16
# set cost params:  19.85 0.0 1.0
# ----- 30
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  784844.7772830307
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.006407349482135
# RUN  2 , total integrated cost =  5.006407335893083
# RUN  3 , total integrated cost =  5.0064073343817
# RUN  3 , total integrated cost =  5.0064073343817
# Improved over  3  iterations in  0.9733855159975064  seconds by  99.9993621149711  percent.
# 4.6662773315914625e-08 3.019820252026297e-16
# 2.6910949261846287e-07 1.1991608351392206e-16
# set cost params:  19.845 0.0 1.0
# ----- 31
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  800466.4810315763
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.0064077282479955
# RUN  2 , total integrated cost =  5.006407726886267
# RUN  3 , total integrated cost =  5.006407725928011
# RUN  3 , total integrated cost =  5.006407725928011
# Improved over  3  iterations in  0.9630112550003105  seconds by  99.99937456372696  percent.
# 4.6846749533130814e-08 3.01982017144649e-16
# 2.6910949261846287e-07 1.1991608351392206e-16
# set cost params:  19.84 0.0 1.0
# ----- 32
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  814498.660928885
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.00640803552886
# RUN  2 , total integrated cost =  5.006408034210573
# RUN  3 , total integrated cost =  5.006408032889722
# RUN  3 , total integrated cost =  5.006408032889722
# Improved over  3  iterations in  0.9919495870017272  seconds by  99.99938533870305  percent.
# 4.737994183668607e-08 3.019820109023074e-16
# 2.6910949261846287e-07 1.1991608351392206e-16
# set cost params:  19.835 0.0 1.0
# ----- 33
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  830104.8317877392
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.006408453998222
# RUN  2 , total integrated cost =  5.006408452625071
# RUN  3 , total integrated cost =  5.006408451484652
# RUN  3 , total integrated cost =  5.006408451484652
# Improved over  3  iterations in  1.0357364730007248  seconds by  99.99939689443312  percent.
# 4.686019145879044e-08 3.019820023048891e-16
# 2.6910949261846287e-07 1.1991608351392206e-16
# set cost params:  19.830000000000002 0.0 1.0
# ----- 34
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  845703.0191930782
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.006408890223973
# RUN  2 , total integrated cost =  5.006408887261485
# RUN  3 , total integrated cost =  5.006408884601223
# RUN  3 , total integrated cost =  5.006408884601223
# Improved over  3  iterations in  1.5106930139991164  seconds by  99.99940801809016  percent.
# 4.6475783892331335e-08 3.019819933831571e-16
# 2.6910949261846287e-07 1.1991608351392206e-16
# set cost params:  19.825 0.0 1.0
# ----- 35
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  861293.2215832236
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.00640923666538
# RUN  2 , total integrated cost =  5.006409227080107
# RUN  3 , total integrated cost =  5.006409223105946
# RUN  3 , total integrated cost =  5.006409223105946
# Improved over  3  iterations in  1.5794731459973264  seconds by  99.9994187334699  percent.
# 4.757797321260244e-08 3.0198198647168443e-16
# 2.6910949261846287e-07 1.1991608351392206e-16
# set cost params:  19.82 0.0 1.0
# ----- 36
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  876875.480438711
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.006409687406845
# RUN  2 , total integrated cost =  5.006409685162329
# RUN  3 , total integrated cost =  5.006409683271573
# RUN  3 , total integrated cost =  5.006409683271573
# Improved over  3  iterations in  1.3798837800022739  seconds by  99.99942906264401  percent.
# 4.6651189447943695e-08 3.0198197695268635e-16
# 2.6910949261846287e-07 1.1991608351392206e-16
# set cost params:  19.815 0.0 1.0
# ----- 37
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  890870.205110253
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.00641016694546
# RUN  2 , total integrated cost =  5.0064101644282735
# RUN  3 , total integrated cost =  5.006410162063108
# RUN  3 , total integrated cost =  5.006410162063108
# Improved over  3  iterations in  1.1351415770004678  seconds by  99.9994380314738  percent.
# 4.616613813190586e-08 3.019819670746075e-16
# 2.6910949261846287e-07 1.1991608351392206e-16
# set cost params:  19.81 0.0 1.0
# ----- 38
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  906436.8897149768
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.006410545058471
# RUN  2 , total integrated cost =  5.006410542578734
# RUN  3 , total integrated cost =  5.006410540762051
# RUN  3 , total integrated cost =  5.006410540762051
# Improved over  3  iterations in  1.0379871230034041  seconds by  99.99944768239273  percent.
# 4.624131956395453e-08 3.019819594222716e-16
# 2.6910949261846287e-07 1.1991608351392206e-16
# set cost params:  19.805 0.0 1.0
# ----- 39
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  921995.6333216
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.006411058001904
# RUN  2 , total integrated cost =  5.006411056267085
# RUN  3 , total integrated cost =  5.006411054149421
# RUN  3 , total integrated cost =  5.006411054149421
# Improved over  3  iterations in  1.031385283000418  seconds by  99.99945700273697  percent.
# 4.687246087799987e-08 3.0198194888289833e-16
# 2.6910949261846287e-07 1.1991608351392206e-16
# set cost params:  19.8 0.0 1.0
# ----- 40
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  937546.391245203
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.006411628936283
# RUN  2 , total integrated cost =  5.006411590077008
# RUN  3 , total integrated cost =  5.006411581526419
# RUN  3 , total integrated cost =  5.006411581526419
# Improved over  3  iterations in  1.0411546420000377  seconds by  99.99946600918864  percent.
# 4.456148444578609e-08 3.019819379459498e-16
# 2.6910949261846287e-07 1.1991608351392206e-16
# set cost params:  19.794999999999998 0.0 1.0
# ----- 41
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  951511.202322326
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.006411998152892
# RUN  2 , total integrated cost =  5.006411991759789
# RUN  3 , total integrated cost =  5.006411986575895
# RUN  3 , total integrated cost =  5.006411986575895
# Improved over  3  iterations in  1.328425398998661  seconds by  99.99947384623803  percent.
# 4.457041780886644e-08 3.0198192947332784e-16
# 2.6910949261846287e-07 1.1991608351392206e-16
# set cost params:  19.79 0.0 1.0
# ----- 42
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  967046.4343061364
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.006412607983933
# RUN  2 , total integrated cost =  5.006412556631349
# RUN  3 , total integrated cost =  5.006412550002639
# RUN  3 , total integrated cost =  5.006412550002639
# Improved over  3  iterations in  1.0332822279997345  seconds by  99.9994822986392  percent.
# 4.629976851524392e-08 3.0198191780419174e-16
# 2.6910949261846287e-07 1.1991608351392206e-16
# set cost params:  19.785 0.0 1.0
# ----- 43
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  982573.6775009414
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.006413188297775
# RUN  2 , total integrated cost =  5.006413140977207
# RUN  3 , total integrated cost =  5.006413138195093
# RUN  3 , total integrated cost =  5.006413138195093
# Improved over  3  iterations in  1.0248394670015841  seconds by  99.99949047961971  percent.
# 4.431036748761314e-08 3.019819056948587e-16
# 2.6910949261846287e-07 1.1991608351392206e-16
# set cost params:  19.78 0.0 1.0
# ----- 44
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  998092.9242736793
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.00641361448483
# RUN  2 , total integrated cost =  5.006413608252288
# RUN  3 , total integrated cost =  5.006413604394359
# RUN  3 , total integrated cost =  5.006413604394359
# Improved over  3  iterations in  0.9437152909995348  seconds by  99.9994984020543  percent.
# 4.405430734238366e-08 3.019818963140128e-16
# 2.6910949261846287e-07 1.1991608351392206e-16
# set cost params:  19.775 0.0 1.0
# ----- 45
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1012027.8834835968
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.006414238381095
# RUN  2 , total integrated cost =  5.00641423467609
# RUN  3 , total integrated cost =  5.0064142317045395
# RUN  3 , total integrated cost =  5.0064142317045395
# Improved over  3  iterations in  0.9663488989972393  seconds by  99.99950530866654  percent.
# 4.4046160320651146e-08 3.0198188339399825e-16
# 2.6910949261846287e-07 1.1991608351392206e-16
# set cost params:  19.77 0.0 1.0
# ----- 46
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1027531.6090710098
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.006414924910546
# RUN  2 , total integrated cost =  5.006414892219077
# RUN  3 , total integrated cost =  5.006414847854593
# RUN  3 , total integrated cost =  5.006414847854593
# Improved over  3  iterations in  0.9350850839982741  seconds by  99.99951277266766  percent.
# 4.556087340441205e-08 3.0198186998659537e-16
# 2.6910949261846287e-07 1.1991608351392206e-16
# set cost params:  19.765 0.0 1.0
# ----- 47
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1043027.3448492803
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.00641534438837
# RUN  2 , total integrated cost =  5.006415338131273
# RUN  3 , total integrated cost =  5.006415332365993
# RUN  3 , total integrated cost =  5.006415332365993
# Improved over  3  iterations in  0.9643913559993962  seconds by  99.99952001111409  percent.
# 4.101458326901977e-08 3.0198185960015913e-16
# 2.6910949261846287e-07 1.1991608351392206e-16
# set cost params:  19.759999999999998 0.0 1.0
# ----- 48
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1058515.1446954662
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.006416061906579
# RUN  2 , total integrated cost =  5.0064160405955525
# RUN  3 , total integrated cost =  5.006416031394795
# RUN  3 , total integrated cost =  5.006416031394795
# Improved over  3  iterations in  1.3219913330030977  seconds by  99.99952703406687  percent.
# 3.88820253266865e-08 3.01981845295165e-16
# 2.6910949261846287e-07 1.1991608351392206e-16
# set cost params:  19.755000000000003 0.0 1.0
# ----- 49
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1072420.1883967232
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.006416753938448
# RUN  2 , total integrated cost =  5.0064167512985485
# RUN  3 , total integrated cost =  5.006416748234189
# RUN  3 , total integrated cost =  5.006416748234189
# Improved over  3  iterations in  1.149629809002363  seconds by  99.99953316649552  percent.
# 4.082841407345012e-08 3.019818304505314e-16
# 2.6910949261846287e-07 1.1991608351392206e-16
# set cost params:  19.75 0.0 1.0
# ----- 50
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1087892.3997951967
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.006417335367202
# RUN  2 , total integrated cost =  5.006417042813353
# RUN  3 , total integrated cost =  5.006416930512411
# RUN  3 , total integrated cost =  5.006416930512411
# Improved over  3  iterations in  0.8727849850001803  seconds by  99.99953980587313  percent.
# 2.2372197432592465e-08 3.0198181895069913e-16
# 2.6910949261846287e-07 1.1991608351392206e-16
# set cost params:  19.744999999999997 0.0 1.0
# ----- 51
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1103356.694849211
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.0064177640588
# RUN  2 , total integrated cost =  5.006417721653281
# RUN  3 , total integrated cost =  5.006417706204253
# RUN  3 , total integrated cost =  5.006417706204253
# Improved over  3  iterations in  1.2129843269976845  seconds by  99.99954625573673  percent.
# 1.9764350755134948e-08 3.0198180311224624e-16
# 2.6910949261846287e-07 1.1991608351392206e-16
# set cost params:  19.740000000000002 0.0 1.0
# ----- 52
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1117239.4177071573
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.0064185296768295
# RUN  2 , total integrated cost =  5.006418507850137
# RUN  3 , total integrated cost =  5.006418439581837
# RUN  3 , total integrated cost =  5.006418439581837
# Improved over  3  iterations in  1.3879645060005714  seconds by  99.99955189385908  percent.
# 1.3596693638197299e-08 3.019817866763004e-16
# 2.6910949261846287e-07 1.1991608351392206e-16
# set cost params:  19.735 0.0 1.0
# ----- 53
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1132688.0952243644
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.006419029437934
# RUN  2 , total integrated cost =  5.006419028746538
# RUN  3 , total integrated cost =  5.00641902796125
# RUN  3 , total integrated cost =  5.00641902796125
# Improved over  3  iterations in  1.2486272550013382  seconds by  99.99955800550487  percent.
# 1.6914611347030105e-08 3.0198177394370746e-16
# 2.6910949261846287e-07 1.1991608351392206e-16
# set cost params:  19.73 0.0 1.0
# ----- 54
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1148128.8912977143
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.006419921855136
# RUN  2 , total integrated cost =  5.006419919110991
# RUN  3 , total integrated cost =  5.00641991682151
# RUN  3 , total integrated cost =  5.00641991682151
# Improved over  3  iterations in  1.0074518859983073  seconds by  99.9995639496615  percent.
# 1.8293515587496595e-08 3.019817564073966e-16
# 2.6910949261846287e-07 1.1991608351392206e-16
# set cost params:  19.725 0.0 1.0
# ----- 55
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1161989.2963663093
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.00642088357456
# RUN  2 , total integrated cost =  5.00642083097029
# RUN  3 , total integrated cost =  5.006420828590531
# RUN  3 , total integrated cost =  5.006420828590531
# Improved over  3  iterations in  1.3285913830004574  seconds by  99.99956915086531  percent.
# 1.9032733258621135e-08 3.019817382095362e-16
# 2.6910949261846287e-07 1.1991608351392206e-16
# set cost params:  19.72 0.0 1.0
# ----- 56
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1177414.4640453623
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.006421575360429
# RUN  2 , total integrated cost =  5.0064215695368235
# RUN  3 , total integrated cost =  5.006421560777097
# RUN  3 , total integrated cost =  5.006421560777097
# Improved over  3  iterations in  1.226676269001473  seconds by  99.9995747953067  percent.
# 2.058121615777893e-08 3.019817241120196e-16
# 2.6910949261846287e-07 1.1991608351392206e-16
# set cost params:  19.715 0.0 1.0
# ----- 57
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1192831.7342236033
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.006422566376155
# RUN  2 , total integrated cost =  5.006422539373662
# RUN  3 , total integrated cost =  5.006422529210357
# RUN  3 , total integrated cost =  5.006422529210357
# Improved over  3  iterations in  0.9812640310010465  seconds by  99.99958029096766  percent.
# 2.094431740276268e-08 3.0198170469582437e-16
# 2.6910949261846287e-07 1.1991608351392206e-16
# set cost params:  19.71 0.0 1.0
# ----- 58
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1206669.818589905
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.006423539537615
# RUN  2 , total integrated cost =  5.00642353348795
# RUN  3 , total integrated cost =  5.006423531349825
# RUN  3 , total integrated cost =  5.006423531349825
# Improved over  3  iterations in  0.9102209929988021  seconds by  99.999585104106  percent.
# 1.849504366492738e-08 3.019816845471544e-16
# 2.6910949261846287e-07 1.1991608351392206e-16
# set cost params:  19.705000000000002 0.0 1.0
# ----- 59
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1222071.451524371
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.0064243680674885
# RUN  2 , total integrated cost =  5.006424352562419
# RUN  3 , total integrated cost =  5.006424337125356
# RUN  3 , total integrated cost =  5.006424337125356
# Improved over  3  iterations in  1.0229118409988587  seconds by  99.99959033292768  percent.
# 1.6420149434842047e-08 3.0198166893837986e-16
# 2.6910949261846287e-07 1.1991608351392206e-16
# set cost params:  19.7 0.0 1.0
# ----- 60
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1237465.2159156643
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.006425424938819
# RUN  2 , total integrated cost =  5.006425413431357
# RUN  3 , total integrated cost =  5.006425363836589
# RUN  3 , total integrated cost =  5.006425363836589
# Improved over  3  iterations in  1.151430332000018  seconds by  99.99959542900281  percent.
# 1.2188275925571126e-08 3.0198164744075554e-16
# 2.6910949261846287e-07 1.1991608351392206e-16
# set cost params:  19.695 0.0 1.0
# ----- 61
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1251280.9765212105
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.006426465603497
# RUN  2 , total integrated cost =  5.006426435734474
# RUN  3 , total integrated cost =  5.006426416535276
# RUN  3 , total integrated cost =  5.006426416535276
# Improved over  3  iterations in  1.562224466000771  seconds by  99.99959989590583  percent.
# 1.8753878779629316e-08 3.01981625132126e-16
# 2.6910949261846287e-07 1.1991608351392206e-16
# set cost params:  19.69 0.0 1.0
# ----- 62
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1266659.104324986
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.006427348226831
# RUN  2 , total integrated cost =  5.0064273218382045
# RUN  3 , total integrated cost =  5.006427087976706
# RUN  3 , total integrated cost =  5.006427087976706
# Improved over  3  iterations in  1.649009812001168  seconds by  99.99960475339648  percent.
# 4.147303575491207e-09 3.0198160785006756e-16
# 2.6910949261846287e-07 1.1991608351392206e-16
# set cost params:  19.685 0.0 1.0
# ----- 63
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1282029.3545624157
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.006428311157016
# RUN  2 , total integrated cost =  5.006428239360045
# RUN  3 , total integrated cost =  5.006428238685977
# RUN  3 , total integrated cost =  5.006428238685977
# Improved over  3  iterations in  1.9714596120029455  seconds by  99.99960949191835  percent.
# 8.139403126421271e-09 3.0198158404785725e-16
# 2.6910949261846287e-07 1.1991608351392206e-16
# set cost params:  19.68 0.0 1.0
# ----- 64
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1295822.80505162
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.006429531401716
# RUN  2 , total integrated cost =  5.006429517927949
# RUN  3 , total integrated cost =  5.006429516381792
# RUN  3 , total integrated cost =  5.006429516381792
# Improved over  3  iterations in  1.2603642510002828  seconds by  99.9996136486025  percent.
# 1.0154213743243601e-08 3.0198155934769007e-16
# 2.6910949261846287e-07 1.1991608351392206e-16
# set cost params:  19.675 0.0 1.0
# ----- 65
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1311177.388234827
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.006430626816254
# RUN  2 , total integrated cost =  5.0064305835062415
# RUN  3 , total integrated cost =  5.0064305804472164
# RUN  3 , total integrated cost =  5.0064305804472164
# Improved over  3  iterations in  0.9523501140029111  seconds by  99.9996181729013  percent.
# 1.5353960546183163e-08 3.01981540212947e-16
# 2.6910949261846287e-07 1.1991608351392206e-16
# set cost params:  19.669999999999998 0.0 1.0
# ----- 66
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1326524.1434984785
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.006432013153049
# RUN  2 , total integrated cost =  5.006431969596496
# RUN  3 , total integrated cost =  5.006431963228753
# RUN  3 , total integrated cost =  5.006431963228753
# Improved over  3  iterations in  1.1688353029967402  seconds by  99.99962259021159  percent.
# 1.465425163624088e-08 3.0198151385906377e-16
# 2.6910949261846287e-07 1.1991608351392206e-16
# set cost params:  19.665 0.0 1.0
# ----- 67
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1340295.259936026
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.006433374525053
# RUN  2 , total integrated cost =  5.006433371641678
# RUN  3 , total integrated cost =  5.0064333682608035
# RUN  3 , total integrated cost =  5.0064333682608035
# Improved over  3  iterations in  1.282536878999963  seconds by  99.9996264678748  percent.
# 1.8728491626248153e-08 3.019814865109482e-16
# 2.6910949261846287e-07 1.1991608351392206e-16
# set cost params:  19.66 0.0 1.0
# ----- 68
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1355626.294891852
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.006434539709313
# RUN  2 , total integrated cost =  5.006434535190554
# RUN  3 , total integrated cost =  5.0064345315983285
# RUN  3 , total integrated cost =  5.0064345315983285
# Improved over  3  iterations in  1.423851324001589  seconds by  99.99963069213466  percent.
# 1.972251222457961e-08 3.0198146532488325e-16
# 2.6910949261846287e-07 1.1991608351392206e-16
# set cost params:  19.655 0.0 1.0
# ----- 69
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1369382.7680326677
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.006436079015447
# RUN  2 , total integrated cost =  5.006436035433676
# RUN  3 , total integrated cost =  5.006435979928087
# RUN  3 , total integrated cost =  5.006435979928087
# Improved over  3  iterations in  1.317481460999261  seconds by  99.99963440200236  percent.
# 1.3328795583222239e-08 3.0198143614574835e-16
# 2.6910949261846287e-07 1.1991608351392206e-16
# set cost params:  19.65 0.0 1.0
# ----- 70
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1384698.3499496127
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.006437544512813
# RUN  2 , total integrated cost =  5.006437504215931
# RUN  3 , total integrated cost =  5.006437465741263
# RUN  3 , total integrated cost =  5.006437465741263
# Improved over  3  iterations in  1.4433238019992132  seconds by  99.99963844562494  percent.
# 2.3566540709390488e-08 3.0198140586578685e-16
# 2.6910949261846287e-07 1.1991608351392206e-16
# set cost params:  19.645 0.0 1.0
# ----- 71
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1400005.8584295332
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.006438757961902
# RUN  2 , total integrated cost =  5.006438732822454
# RUN  3 , total integrated cost =  5.006438727438507
# RUN  3 , total integrated cost =  5.006438727438507
# Improved over  3  iterations in  1.2057886919974408  seconds by  99.99964239873017  percent.
# 1.8483814720762022e-08 3.019813824084731e-16
# 2.6910949261846287e-07 1.1991608351392206e-16
# set cost params:  19.64 0.0 1.0
# ----- 72
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1413740.027520677
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.006440496125047
# RUN  2 , total integrated cost =  5.006440398049859
# RUN  3 , total integrated cost =  5.006440390186988
# RUN  3 , total integrated cost =  5.006440390186988
# Improved over  3  iterations in  1.396716455998103  seconds by  99.99964587262915  percent.
# 1.9379138682144672e-08 3.0198135010119245e-16
# 2.6910949261846287e-07 1.1991608351392206e-16
# set cost params:  19.634999999999998 0.0 1.0
# ----- 73
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1429032.100905953
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.006442166491254
# RUN  2 , total integrated cost =  5.0064421473410725
# RUN  3 , total integrated cost =  5.006442123641119
# RUN  3 , total integrated cost =  5.006442123641119
# Improved over  3  iterations in  1.2780065490005654  seconds by  99.99964966202505  percent.
# 2.7711074006202163e-08 3.019813165750776e-16
# 2.6910949261846287e-07 1.1991608351392206e-16
# set cost params:  19.630000000000003 0.0 1.0
# ----- 74
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1442751.1696444321
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.006443521546557
# RUN  2 , total integrated cost =  5.006443511673755
# RUN  3 , total integrated cost =  5.006443501476285
# RUN  3 , total integrated cost =  5.006443501476285
# Improved over  3  iterations in  1.2234512449977046  seconds by  99.99965299328069  percent.
# 2.524516553225382e-08 3.0198129060304146e-16
# 2.6910949261846287e-07 1.1991608351392206e-16
# set cost params:  19.625 0.0 1.0
# ----- 75
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1458027.932486486
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.006445404129837
# RUN  2 , total integrated cost =  5.006445380188252
# RUN  3 , total integrated cost =  5.006445367477734
# RUN  3 , total integrated cost =  5.006445367477734
# Improved over  3  iterations in  1.163937667002756  seconds by  99.99965662898111  percent.
# 2.2831565614233197e-08 3.0198125483231006e-16
# 2.6910949261846287e-07 1.1991608351392206e-16
# set cost params:  19.619999999999997 0.0 1.0
# ----- 76
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1473296.4714474934
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.00644733633245
# RUN  2 , total integrated cost =  5.006447308308058
# RUN  3 , total integrated cost =  5.006447290158534
# RUN  3 , total integrated cost =  5.006447290158534
# Improved over  3  iterations in  1.6178582050015393  seconds by  99.99966018738338  percent.
# 2.2790819245557205e-08 3.01981217712109e-16
# 2.6910949261846287e-07 1.1991608351392206e-16
# set cost params:  19.615000000000002 0.0 1.0
# ----- 77
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1486991.836722242
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.006448872682169
# RUN  2 , total integrated cost =  5.00644883729504
# RUN  3 , total integrated cost =  5.006448810089927
# RUN  3 , total integrated cost =  5.006448810089927
# Improved over  3  iterations in  1.0975222999986727  seconds by  99.99966331699432  percent.
# 2.194583033891007e-08 3.019811889558062e-16
# 2.6910949261846287e-07 1.1991608351392206e-16
# set cost params:  19.61 0.0 1.0
# ----- 78
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1502246.4269966036
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.0064509258512
# RUN  2 , total integrated cost =  5.006450870705891
# RUN  3 , total integrated cost =  5.0064508071655
# RUN  3 , total integrated cost =  5.0064508071655
# Improved over  3  iterations in  0.9505595839982561  seconds by  99.99966673571545  percent.
# 1.6499275033612725e-08 3.01981149350327e-16
# 2.6910949261846287e-07 1.1991608351392206e-16
# set cost params:  19.605 0.0 1.0
# ----- 79
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1515928.622822177
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.006452886052677
# RUN  2 , total integrated cost =  5.006452871117871
# RUN  3 , total integrated cost =  5.006452852321517
# RUN  3 , total integrated cost =  5.006452852321517
# Improved over  3  iterations in  0.9480288289996679  seconds by  99.99966974349735  percent.
# 3.1003722977404005e-08 3.019811082506369e-16
# 2.6910949261846287e-07 1.1991608351392206e-16
# set cost params:  19.6 0.0 1.0
# ----- 80
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1531164.608905289
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.00645464960118
# RUN  2 , total integrated cost =  5.006454622774381
# RUN  3 , total integrated cost =  5.0064545850787665
# RUN  3 , total integrated cost =  5.0064545850787665
# Improved over  3  iterations in  0.9608469869999681  seconds by  99.99967302963013  percent.
# 3.5199293502185466e-08 3.0198107641145437e-16
# 2.6910949261846287e-07 1.1991608351392206e-16
# set cost params:  19.595 0.0 1.0
# ----- 81
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1544833.6396221325
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.0064568610268765
# RUN  2 , total integrated cost =  5.006456847563156
# RUN  3 , total integrated cost =  5.006456832639801
# RUN  3 , total integrated cost =  5.006456832639801
# Improved over  3  iterations in  1.20789013600006  seconds by  99.999675922591  percent.
# 3.237979623878301e-08 3.019810325599455e-16
# 2.6910949261846287e-07 1.1991608351392206e-16
# set cost params:  19.59 0.0 1.0
# ----- 82
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1560055.531161996
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.006459262882264
# RUN  2 , total integrated cost =  5.006459246373251
# RUN  3 , total integrated cost =  5.006459227368395
# RUN  3 , total integrated cost =  5.006459227368395
# Improved over  3  iterations in  0.9876482340005168  seconds by  99.99967908455004  percent.
# 3.526108869637752e-08 3.019809870540036e-16
# 2.6910949261846287e-07 1.1991608351392206e-16
# set cost params:  19.585 0.0 1.0
# ----- 83
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1573595.649423194
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.006461189141973
# RUN  2 , total integrated cost =  5.006461165932712
# RUN  3 , total integrated cost =  5.0064611473879275
# RUN  3 , total integrated cost =  5.0064611473879275
# Improved over  3  iterations in  1.0266606779987342  seconds by  99.99968184576836  percent.
# 2.8824252152008127e-08 3.0198095180135767e-16
# 2.6910949261846287e-07 1.1991608351392206e-16
# set cost params:  19.580000000000002 0.0 1.0
# ----- 84
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1588914.4699074011
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.006463740794993
# RUN  2 , total integrated cost =  5.006463710781732
# RUN  3 , total integrated cost =  5.006463678362989
# RUN  3 , total integrated cost =  5.006463678362989
# Improved over  3  iterations in  1.163188718001038  seconds by  99.99968491295327  percent.
# 3.652977709933023e-08 3.019809032485215e-16
# 2.6910949261846287e-07 1.1991608351392206e-16
# set cost params:  19.575 0.0 1.0
# ----- 85
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1602552.491825523
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.006466397161404
# RUN  2 , total integrated cost =  5.0064663197609365
# RUN  3 , total integrated cost =  5.006466212654482
# RUN  3 , total integrated cost =  5.006466212654482
# Improved over  3  iterations in  1.3483320550003555  seconds by  99.99968759424492  percent.
# 1.8441750110333556e-08 3.019808528638463e-16
# 2.6910949261846287e-07 1.1991608351392206e-16
# set cost params:  19.57 0.0 1.0
# ----- 86
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  5.100670223608763
# Gradient descend method:  None
# RUN  1 , total integrated cost =  5.006468350793618
# RUN  2 , total integrated cost =  5.006468331111215
# RUN  3 , total integrated cost =  5.0064683092265145
# RUN  3 , total integrated cost =  5.0064683092265145
# Improved over  3  iterations in  1.403083034001611  seconds by  1.846853653589065  percent.
# 3.816237498175434e-08 3.01980813831709e-16
# 2.6910949261846287e-07 1.1991608351392206e-16
# set cost params:  19.565 0.0 1.0
# ----- 87
# ...
# RUN  30 , total integrated cost =  200.89421319114427
# RUN  40 , total integrated cost =  124.51459035335093
# RUN  40 , total integrated cost =  124.51459035335093
# Improved over  40  iterations in  5.442752551000012  seconds by  98.02375972801738  percent.
# 6.262382761841861 4.159627302131185
# 2.6910949261846287e-07 1.1991608351392206e-16
# set cost params:  18.145 0.0 1.0
# ----- 371
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  9534.235104907979
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2137.8750982901306
# RUN  2 , total integrated cost =  1661.6145286826381
# RUN  3 , total integrated cost =  1501.4904671973732
# RUN  4 , total integrated cost =  1377.0138816614146
# RUN  5 , total integrated cost =  1274.0289436903774
# RUN  6 , total integrated cost =  1183.036715630173
# RUN  7 , total integrated cost =  1103.1103272885923
# RUN  8 , total integrated cost =  1031.802300551143
# RUN  9 , total integrated cost =  965.9123908572366
# RUN  10 , total integrated cost =  906.1303202066499
# RUN  11 , total integrated cost =  849.6247387386385
# RUN  12 , total integrated cost =  793.0665515016117
# RUN  13 , total integrated cost =  744.1776790768872
# RUN  14 , total integrated cost =  698.61507332188
# RUN  15 , total integrated cost =  654.0187345327583
# RUN  16 , total integrated cost =  616.7234951461108
# RUN  17 , total integrated cost =  583.285271507936
# RUN  18 , total integrated cost =  550.0611306466599
# RUN  19 , total integrated cost =  518.0403062283264
# RUN  20 , total integrated cost =  483.59288930698347
# RUN  30 , total integrated cost =  271.1396345481449
# RUN  40 , total integrated cost =  164.09814017601957
# RUN  40 , total integrated cost =  164.09814017601957
# Improved over  40  iterations in  5.074981476998801  seconds by  98.27885364299915  percent.
# 8.418496980150755 3.967561205594509
# 2.6910949261846287e-07 1.1991608351392206e-16
# set cost params:  18.14 0.0 1.0
# ----- 372
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  10762.325594496078
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2598.9417466157847
# RUN  2 , total integrated cost =  2082.429582278645
# RUN  3 , total integrated cost =  1899.3644741068356
# RUN  4 , total integrated cost =  1762.3234604541026
# RUN  5 , total integrated cost =  1649.5645341144877
# RUN  6 , total integrated cost =  1555.0676027620395
# RUN  7 , total integrated cost =  1466.651197622038
# RUN  8 , total integrated cost =  1384.3930646405463
# RUN  9 , total integrated cost =  1309.971043832278
# RUN  10 , total integrated cost =  1243.017794762789
# RUN  11 , total integrated cost =  1179.092673261878
# RUN  12 , total integrated cost =  1113.9179937470485
# RUN  13 , total integrated cost =  1056.337859907225
# RUN  14 , total integrated cost =  1000.742102056676
# RUN  15 , total integrated cost =  949.136677361162
# RUN  16 , total integrated cost =  897.9021563600645
# RUN  17 , total integrated cost =  849.4398550377033
# RUN  18 , total integrated cost =  803.5825781544906
# RUN  19 , total integrated cost =  760.9384825426414
# RUN  20 , total integrated cost =  725.4263975922441
# RUN  30 , total integrated cost =  449.6840853281962
# RUN  40 , total integrated cost =  292.1027165911808
# RUN  40 , total integrated cost =  292.1027165911808
# Improved over  40  iterations in  4.983753766999143  seconds by  97.2858773503325  percent.
# 15.448194824192406 3.7602971934898117
# 2.6910949261846287e-07 1.1991608351392206e-16
# set cost params:  18.134999999999998 0.0 1.0
# ----- 373
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  9666.221012758882
# Gradient descend method:  None
# RUN  1 , total integrated cost =  3887.334957644564
# RUN  2 , total integrated cost =  3349.523603422805
# RUN  3 , total integrated cost =  3103.4695147499338
# RUN  4 , total integrated cost =  2902.084309548995
# RUN  5 , total integrated cost =  2730.6400016613775
# RUN  6 , total integrated cost =  2564.9369563604882
# RUN  7 , total integrated cost =  2422.2145526769805
# RUN  8 , total integrated cost =  2293.8258228971813
# RUN  9 , total integrated cost =  2160.186742041027
# RUN  10 , total integrated cost =  2037.3254744227233
# RUN  11 , total integrated cost =  1923.6399203629132
# RUN  12 , total integrated cost =  1807.091183156122
# RUN  13 , total integrated cost =  1706.2392501461334
# RUN  14 , total integrated cost =  1618.29824796445
# RUN  15 , total integrated cost =  1529.4679151726245
# RUN  16 , total integrated cost =  1438.9569608777833
# RUN  17 , total integrated cost =  1357.304085079626
# RUN  18 , total integrated cost =  1287.4335280699265
# RUN  19 , total integrated cost =  1218.235133259495
# RUN  20 , total integrated cost =  1149.0571233263254
# RUN  30 , total integrated cost =  671.3368973951001
# RUN  40 , total integrated cost =  409.97899987106985
# RUN  40 , total integrated cost =  409.97899987106985
# Improved over  40  iterations in  4.526698233999923  seconds by  95.75864239675546  percent.
# 21.91678143925744 3.601781249238543
# 2.6910949261846287e-07 1.1991608351392206e-16
# set cost params:  18.130000000000003 0.0 1.0
# ----- 374
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  14204.508896009414
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4103.655052947534
# RUN  2 , total integrated cost =  3319.001922746269
# RUN  3 , total integrated cost =  2970.5751367149146
# RUN  4 , total integrated cost =  2718.8869545048856
# RUN  5 , total integrated cost =  2515.5505048637806
# RUN  6 , total integrated cost =  2317.4804766907596
# RUN  7 , total integrated cost =  2149.023415675621
# RUN  8 , total integrated cost =  1987.5772661978688
# RUN  9 , total integrated cost =  1852.9773811271275
# RUN  10 , total integrated cost =  1730.7554807553843
# RUN  11 , total integrated cost =  1625.9266190029282
# RUN  12 , total integrated cost =  1532.341591860088
# RUN  13 , total integrated cost =  1454.838598698172
# RUN  14 , total integrated cost =  1383.065862624153
# RUN  15 , total integrated cost =  1309.0284683960595
# RUN  16 , total integrated cost =  1243.5231202028897
# RUN  17 , total integrated cost =  1186.0881989604377
# RUN  18 , total integrated cost =  1130.8020413741083
# RUN  19 , total integrated cost =  1077.8602498115852
# RUN  20 , total integrated cost =  1025.3314221590742
# RUN  30 , total integrated cost =  643.7013551860676
# RUN  40 , total integrated cost =  420.21006950246715
# RUN  40 , total integrated cost =  420.21006950246715
# Improved over  40  iterations in  5.092654633997881  seconds by  97.04171349689872  percent.
# 22.450169194317116 3.295754790487095
# 2.6910949261846287e-07 1.1991608351392206e-16
# set cost params:  18.125 0.0 1.0
# ----- 375
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  15791.4201661912
# Gradient descend method:  None
# RUN  1 , total integrated cost =  4710.673246582435
# RUN  2 , total integrated cost =  3799.7492593203265
# RUN  3 , total integrated cost =  3460.2628877297234
# RUN  4 , total integrated cost =  3250.9603983920097
# RUN  5 , total integrated cost =  3074.497313416552
# RUN  6 , total integrated cost =  2922.9776397842943
# RUN  7 , total integrated cost =  2783.7621846227194
# RUN  8 , total integrated cost =  2649.643402722852
# RUN  9 , total integrated cost =  2527.8498096574976
# RUN  10 , total integrated cost =  2416.5852965247072
# RUN  11 , total integrated cost =  2305.9896810037435
# RUN  12 , total integrated cost =  2201.137024486823
# RUN  13 , total integrated cost =  2099.0648464995
# RUN  14 , total integrated cost =  2002.0027572378374
# RUN  15 , total integrated cost =  1909.6778583501334
# RUN  16 , total integrated cost =  1826.907286471942
# RUN  17 , total integrated cost =  1744.0401642883512
# RUN  18 , total integrated cost =  1667.0438303251067
# RUN  19 , total integrated cost =  1590.8210044455288
# RUN  20 , total integrated cost =  1516.6099603539399
# RUN  30 , total integrated cost =  944.3698251255099
# RUN  40 , total integrated cost =  335.37292832732896
# RUN  40 , total integrated cost =  335.37292832732896
# Improved over  40  iterations in  5.407763696999609  seconds by  97.87623326592659  percent.
# 17.72837832115509 3.029925430563145
# 2.6910949261846287e-07 1.1991608351392206e-16
# set cost params:  18.119999999999997 0.0 1.0
# ----- 376
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  14371.876047937965
# Gradient descend method:  None
# RUN  1 , total integrated cost =  8596.925735274632
# RUN  2 , total integrated cost =  7778.695047062293
# RUN  3 , total integrated cost =  7493.544310115618
# RUN  4 , total integrated cost =  7374.469182304702
# RUN  5 , total integrated cost =  7296.431282731953
# RUN  6 , total integrated cost =  7242.218314659161
# RUN  7 , total integrated cost =  7201.1238946133335
# RUN  8 , total integrated cost =  7167.372432773227
# RUN  9 , total integrated cost =  7138.953963971043
# RUN  10 , total integrated cost =  7114.256800071135
# RUN  11 , total integrated cost =  7091.647506058521
# RUN  12 , total integrated cost =  7070.787433082767
# RUN  13 , total integrated cost =  7052.243366879061
# RUN  14 , total integrated cost =  7034.970474635267
# RUN  15 , total integrated cost =  7018.598925355051
# RUN  16 , total integrated cost =  7003.292148392951
# RUN  17 , total integrated cost =  6987.264442059572
# RUN  18 , total integrated cost =  6971.99666864267
# RUN  19 , total integrated cost =  6957.316889167826
# RUN  20 , total integrated cost =  6943.284925841977
# RUN  30 , total integrated cost =  6820.167221189246
# RUN  40 , total integrated cost =  6720.593844317033
# RUN  40 , total integrated cost =  6720.593844317033
# Improved over  40  iterations in  5.134961416999431  seconds by  53.23788055296174  percent.
# 370.08745420380393 3.6536621161333316
# 2.6910949261846287e-07 1.1991608351392206e-16
# set cost params:  18.115000000000002 0.0 1.0
# ----- 377
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  42065.35063304395
# Gradient descend method:  None
# RUN  1 , total integrated cost =  24456.22739245462
# RUN  2 , total integrated cost =  22031.49536032364
# RUN  3 , total integrated cost =  21117.495468015557
# RUN  4 , total integrated cost =  20604.62297780866
# RUN  5 , total integrated cost =  20286.8175608285
# RUN  6 , total integrated cost =  20049.393745477173
# RUN  7 , total integrated cost =  19874.08750647846
# RUN  8 , total integrated cost =  19685.28115265571
# RUN  9 , total integrated cost =  19536.893450498665
# RUN  10 , total integrated cost =  19390.775659517185
# RUN  11 , total integrated cost =  19277.370490744037
# RUN  12 , total integrated cost =  19129.164781143452
# RUN  13 , total integrated cost =  19039.444648172743
# RUN  14 , total integrated cost =  18979.446543894555
# RUN  15 , total integrated cost =  18926.659416923776
# RUN  16 , total integrated cost =  18886.706760776793
# RUN  17 , total integrated cost =  18856.058432692782
# RUN  18 , total integrated cost =  18832.430720436616
# RUN  19 , total integrated cost =  18808.44634876256
# RUN  20 , total integrated cost =  18790.756736585423
# RUN  30 , total integrated cost =  18637.267373203813
# RUN  40 , total integrated cost =  18551.293921669843
# RUN  40 , total integrated cost =  18551.293921669843
# Improved over  40  iterations in  5.631480531999841  seconds by  55.898872486523175  percent.
# 1023.2403988952262 4.4362862160276215
# 2.6910949261846287e-07 1.1991608351392206e-16
# set cost params:  18.11 0.0 1.0
# ----- 378
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  67621.57638503239
# Gradient descend method:  None
# RUN  1 , total integrated cost =  37851.43151068583
# RUN  2 , total integrated cost =  34744.96444168852
# RUN  3 , total integrated cost =  33646.65344993429
# RUN  4 , total integrated cost =  33095.82055856815
# RUN  5 , total integrated cost =  32650.629769688978
# RUN  6 , total integrated cost =  32408.40028356564
# RUN  7 , total integrated cost =  32247.42704447332
# RUN  8 , total integrated cost =  32128.64180429857
# RUN  9 , total integrated cost =  32042.615056948594
# RUN  10 , total integrated cost =  31973.378567189153
# RUN  11 , total integrated cost =  31912.37736928838
# RUN  12 , total integrated cost =  31860.932547905697
# RUN  13 , total integrated cost =  31814.270820372636
# RUN  14 , total integrated cost =  31774.40358079539
# RUN  15 , total integrated cost =  31738.448236063403
# RUN  16 , total integrated cost =  31706.03841221126
# RUN  17 , total integrated cost =  31675.26908408866
# RUN  18 , total integrated cost =  31656.163248697063
# RUN  19 , total integrated cost =  31639.04962684688
# RUN  20 , total integrated cost =  31623.940689089653
# RUN  30 , total integrated cost =  31503.783583057102
# RUN  40 , total integrated cost =  31461.130900323195
# RUN  40 , total integrated cost =  31461.130900323195
# Improved over  40  iterations in  5.319448993999686  seconds by  53.47471534649565  percent.
# 1736.3620551861131 4.735628159894301
# 2.6910949261846287e-07 1.1991608351392206e-16
# set cost params:  18.105 0.0 1.0
# ----- 379
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  63203.97042261197
# Gradient descend method:  None
# RUN  1 , total integrated cost =  48144.42389040439
# RUN  2 , total integrated cost =  46597.433088347745
# RUN  3 , total integrated cost =  46010.21834010325
# RUN  4 , total integrated cost =  45658.404011845516
# RUN  5 , total integrated cost =  45429.56913996706
# RUN  6 , total integrated cost =  45261.09263314274
# RUN  7 , total integrated cost =  45138.96861587804
# RUN  8 , total integrated cost =  45045.331028785185
# RUN  9 , total integrated cost =  44970.21517089043
# RUN  10 , total integrated cost =  44911.74218333554
# RUN  11 , total integrated cost =  44874.70131300866
# RUN  12 , total integrated cost =  44840.507127258
# RUN  13 , total integrated cost =  44806.52957101776
# RUN  14 , total integrated cost =  44780.70518299844
# RUN  15 , total integrated cost =  44758.68710654865
# RUN  16 , total integrated cost =  44731.872679700034
# RUN  17 , total integrated cost =  44709.315802774145
# RUN  18 , total integrated cost =  44691.63915773324
# RUN  19 , total integrated cost =  44675.9208687789
# RUN  20 , total integrated cost =  44657.040360106235
# RUN  30 , total integrated cost =  44539.2271136164
# RUN  40 , total integrated cost =  44497.71519540095
# RUN  40 , total integrated cost =  44497.71519540095
# Improved over  40  iterations in  5.70200185000067  seconds by  29.596645752050136  percent.
# 2456.909492746918 4.457190682904748
# 2.6910949261846287e-07 1.1991608351392206e-16
# set cost params:  18.1 0.0 1.0
# ----- 380
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  95172.59625126525
# Gradient descend method:  None
# RUN  1 , total integrated cost =  65231.987781002004
# RUN  2 , total integrated cost =  62293.78828101604
# RUN  3 , total integrated cost =  61223.82855648352
# RUN  4 , total integrated cost =  60620.70133818332
# RUN  5 , total integrated cost =  60229.63576386353
# RUN  6 , total integrated cost =  59946.64508759832
# RUN  7 , total integrated cost =  59762.776695250905
# RUN  8 , total integrated cost =  59633.62751486298
# RUN  9 , total integrated cost =  59534.433694983316
# RUN  10 , total integrated cost =  59446.55151665509
# RUN  11 , total integrated cost =  59383.640060638674
# RUN  12 , total integrated cost =  59330.82523291553
# RUN  13 , total integrated cost =  59283.438252297616
# RUN  14 , total integrated cost =  59242.233516328095
# RUN  15 , total integrated cost =  59211.32728344643
# RUN  16 , total integrated cost =  59186.735915181285
# RUN  17 , total integrated cost =  59164.260640119275
# RUN  18 , total integrated cost =  59144.388966614104
# RUN  19 , total integrated cost =  59125.439247809816
# RUN  20 , total integrated cost =  59108.31390465895
# RUN  30 , total integrated cost =  58992.277140287086
# RUN  40 , total integrated cost =  58936.56247503037
# RUN  40 , total integrated cost =  58936.56247503037
# Improved over  40  iterations in  5.299904688999959  seconds by  38.074020467580915  percent.
# 3255.3136654862237 4.455983825194286
# 2.6910949261846287e-07 1.1991608351392206e-16
