# %%
import os
import pickle
import numpy as np

# %%
### comprise data from three files:

# TASK 1

final_file_ = '.' + os.sep + 'data_final_2' + os.sep + 'control_1.pickle'
file_E = '.' + os.sep + 'data_2' + os.sep + '1' + os.sep + '1_E.pickle'

if os.path.isfile(file_E) :
    print("file found")
    
    with open(file_E,'rb') as f:
        load_array = pickle.load(f)

    bestControl_0 = [None] * len(load_array[0])
    bestState_0 = bestControl_0.copy()
    cost_0 = bestControl_0.copy()
    costnode_0 = bestControl_0.copy()
    weights_0 = bestControl_0.copy()
    
    for i in range(len(bestControl_0)):
        bestControl_0[i] = load_array[0][i]
        bestState_0[i] = load_array[1][i]
        cost_0[i] = load_array[2][i]
        costnode_0[i] = load_array[3][i]
        weights_0[i] = load_array[4][i]

file_I = '.' + os.sep + 'data_2' + os.sep + '1' + os.sep + '1_I.pickle'

if os.path.isfile(file_I) :
    print("file found")
    
    with open(file_I,'rb') as f:
        load_array = pickle.load(f)

    bestControl_1 = [None] * len(load_array[0])
    bestState_1 = bestControl_1.copy()
    cost_1 = bestControl_1.copy()
    costnode_1 = bestControl_1.copy()
    weights_1 = bestControl_1.copy()
    
    for i in range(len(bestControl_1)):
        bestControl_1[i] = load_array[0][i]
        bestState_1[i] = load_array[1][i]
        cost_1[i] = load_array[2][i]
        costnode_1[i] = load_array[3][i]
        weights_1[i] = load_array[4][i]
        
bestControl = [None] * len(bestControl_0)
bestState = bestControl.copy()
cost = bestControl.copy()
costnode = bestControl.copy()
weights = bestControl.copy()
    
for i in range(len(bestControl_0)):
    if type(bestControl_0[i]) == type(None) and type(bestControl_1[i]) == type(None):
        continue
        
    if type(bestControl_0[i]) == type(None):
        print(i, ' inh init')
        bestControl[i] = bestControl_1[i]
        bestState[i] = bestState_1[i]
        cost[i] = cost_1[i]
        costnode[i] = costnode_1[i]
        weights[i] = weights_1[i]
        continue
        
    if type(bestControl_1[i]) == type(None):
        print(i, ' exc init')
        bestControl[i] = bestControl_0[i]
        bestState[i] = bestState_0[i]
        cost[i] = cost_0[i]
        costnode[i] = costnode_0[i]
        weights[i] = weights_0[i]
        continue
        
    cost0 = sum(costnode_0[i][0][0][:]) + sum(costnode_0[i][2][0][:])
    cost1 = sum(costnode_1[i][0][0][:]) + sum(costnode_1[i][2][0][:])
    if np.isnan(cost1):
        cost1 = 1000.
            
    if np.amin([cost0, cost1]) == cost0:
        print(i, ' exc init, cost compared')
        bestControl[i] = bestControl_0[i]
        bestState[i] = bestState_0[i]
        cost[i] = cost_0[i]
        costnode[i] = costnode_0[i]
        weights[i] = weights_0[i]
            
    elif np.amin([cost0, cost1]) == cost1:
        print(i, ' inh init, cost compared')
        bestControl[i] = bestControl_1[i]
        bestState[i] = bestState_1[i]
        cost[i] = cost_1[i]
        costnode[i] = costnode_1[i]
        weights[i] = weights_1[i]
    
with open(final_file_,'wb') as f:
    pickle.dump([bestControl, bestState, cost, costnode, weights], f)
# Out:
# file found
# file found
# 0  exc init, cost compared
# 1  exc init, cost compared
# 2  exc init, cost compared
# 3  inh init, cost compared
# 4  exc init, cost compared
# 5  exc init, cost compared
# 6  inh init, cost compared
# 7  inh init, cost compared
# 8  exc init, cost compared
# 9  inh init, cost compared
# 10  inh init, cost compared
# 11  exc init, cost compared
# 12  inh init, cost compared
# 13  exc init, cost compared
# 14  inh init, cost compared
# 15  exc init, cost compared
# 16  inh init, cost compared
# 17  exc init, cost compared
# 18  inh init, cost compared
# 19  inh init, cost compared
# 20  inh init, cost compared
# 21  inh init, cost compared
# 22  exc init, cost compared
# 23  inh init, cost compared
# 24  exc init, cost compared
# 25  inh init, cost compared
# 26  inh init, cost compared
# 27  exc init, cost compared
# 28  exc init, cost compared
# 29  exc init, cost compared
# 30  inh init, cost compared
# 31  exc init, cost compared
# 32  exc init, cost compared
# 33  exc init, cost compared
# 34  exc init, cost compared
# 35  exc init, cost compared
# 36  inh init, cost compared
# 37  exc init, cost compared
# 38  exc init, cost compared
# 39  exc init, cost compared
# 40  exc init, cost compared
# 41  exc init, cost compared
# 42  inh init, cost compared
# 43  exc init, cost compared
# 44  exc init, cost compared
# 45  exc init, cost compared
# 46  exc init, cost compared
# 47  exc init, cost compared
# 48  exc init, cost compared
# 49  exc init, cost compared
# 50  exc init, cost compared
# 51  exc init, cost compared
# 52  exc init, cost compared
# 53  inh init, cost compared
# 54  exc init, cost compared
# 55  exc init, cost compared
# 56  exc init, cost compared
# 57  exc init, cost compared
# 58  exc init, cost compared
# 59  exc init, cost compared
# 60  inh init, cost compared
# 61  exc init, cost compared
# 62  exc init, cost compared
# 63  exc init, cost compared
# 64  exc init, cost compared
# 65  exc init, cost compared
# 66  exc init, cost compared
# 67  exc init, cost compared
# 68  exc init, cost compared
# 69  exc init, cost compared
# 70  exc init, cost compared
# 71  exc init, cost compared
# 72  exc init, cost compared
# 73  exc init, cost compared
# 74  exc init, cost compared
# 75  inh init, cost compared
# 76  exc init, cost compared
# 77  exc init, cost compared
# 78  exc init, cost compared
# 79  inh init, cost compared
# 80  exc init, cost compared
# 81  exc init, cost compared
# 82  exc init, cost compared

# %%
### comprise data from three files:

# TASK 2

final_file_ = '.' + os.sep + 'data_final_2' + os.sep + 'control_2.pickle'
file_E = '.' + os.sep + 'data_2' + os.sep + '2' + os.sep + '2_E.pickle'

if os.path.isfile(file_E) :
    print("file found")
    
    with open(file_E,'rb') as f:
        load_array = pickle.load(f)

    bestControl_0 = [None] * len(load_array[0])
    bestState_0 = bestControl_0.copy()
    cost_0 = bestControl_0.copy()
    costnode_0 = bestControl_0.copy()
    weights_0 = bestControl_0.copy()
    
    for i in range(len(bestControl_0)):
        bestControl_0[i] = load_array[0][i]
        bestState_0[i] = load_array[1][i]
        cost_0[i] = load_array[2][i]
        costnode_0[i] = load_array[3][i]
        weights_0[i] = load_array[4][i]

file_I = '.' + os.sep + 'data_2' + os.sep + '2' + os.sep + '2_I.pickle'

if os.path.isfile(file_I) :
    print("file found")
    
    with open(file_I,'rb') as f:
        load_array = pickle.load(f)

    bestControl_1 = [None] * len(load_array[0])
    bestState_1 = bestControl_1.copy()
    cost_1 = bestControl_1.copy()
    costnode_1 = bestControl_1.copy()
    weights_1 = bestControl_1.copy()
    
    for i in range(len(bestControl_1)):
        bestControl_1[i] = load_array[0][i]
        bestState_1[i] = load_array[1][i]
        cost_1[i] = load_array[2][i]
        costnode_1[i] = load_array[3][i]
        weights_1[i] = load_array[4][i]     

file_EI = '.' + os.sep + 'data_2' + os.sep + '2' + os.sep + '2_EI.pickle'

if os.path.isfile(file_I) :
    print("file found")
    
    with open(file_EI,'rb') as f:
        load_array = pickle.load(f)

    bestControl_2 = [None] * len(load_array[0])
    bestState_2 = bestControl_1.copy()
    cost_2 = bestControl_1.copy()
    costnode_2 = bestControl_1.copy()
    weights_2 = bestControl_1.copy()
    
    for i in range(len(bestControl_2)):
        bestControl_2[i] = load_array[0][i]
        bestState_2[i] = load_array[1][i]
        cost_2[i] = load_array[2][i]
        costnode_2[i] = load_array[3][i]
        weights_2[i] = load_array[4][i]
        
        
bestControl = [None] * len(bestControl_0)
bestState = bestControl.copy()
cost = bestControl.copy()
costnode = bestControl.copy()
weights = bestControl.copy()
    
for i in range(len(bestControl_0)):
    if type(bestControl_0[i]) == type(None) and type(bestControl_1[i]) == type(None) and type(bestControl_2[i]) == type(None):
        continue
        
    if type(bestControl_0[i]) == type(None) and type(bestControl_2[i]) == type(None):
        print(i, ' inh init')
        bestControl[i] = bestControl_1[i]
        bestState[i] = bestState_1[i]
        cost[i] = cost_1[i]
        costnode[i] = costnode_1[i]
        weights[i] = weights_1[i]
        continue
        
    if type(bestControl_1[i]) == type(None) and type(bestControl_2[i]) == type(None):
        print(i, ' exc init')
        bestControl[i] = bestControl_0[i]
        bestState[i] = bestState_0[i]
        cost[i] = cost_0[i]
        costnode[i] = costnode_0[i]
        weights[i] = weights_0[i]
        continue
        
    if type(bestControl_1[i]) == type(None) and type(bestControl_0[i]) == type(None):
        print(i, ' exc init')
        bestControl[i] = bestControl_2[i]
        bestState[i] = bestState_2[i]
        cost[i] = cost_2[i]
        costnode[i] = costnode_2[i]
        weights[i] = weights_2[i]
        continue
        
    cost0 = sum(costnode_0[i][0][0][:]) + sum(costnode_0[i][1][0][:])
    cost1 = sum(costnode_1[i][0][0][:]) + sum(costnode_1[i][1][0][:])
    cost2 = sum(costnode_2[i][0][0][:]) + sum(costnode_2[i][1][0][:])
    
    if np.isnan(cost1):
        cost1 = 1000.
    if np.isnan(cost0):
        cost0 = 1000.
    if np.isnan(cost2):
        cost2 = 1000.
        
    if np.amin([cost0, cost1, cost2]) == cost0:
        print(i, ' exc init, cost compared')
        bestControl[i] = bestControl_0[i]
        bestState[i] = bestState_0[i]
        cost[i] = cost_0[i]
        costnode[i] = costnode_0[i]
        weights[i] = weights_0[i]
            
    elif np.amin([cost0, cost1, cost2]) == cost1:
        print(i, ' inh init, cost compared')
        bestControl[i] = bestControl_1[i]
        bestState[i] = bestState_1[i]
        cost[i] = cost_1[i]
        costnode[i] = costnode_1[i]
        weights[i] = weights_1[i]
        
    elif np.amin([cost0, cost1, cost2]) == cost2:
        print(i, ' both init, cost compared', cost2)
        bestControl[i] = bestControl_2[i]
        bestState[i] = bestState_2[i]
        cost[i] = cost_2[i]
        costnode[i] = costnode_2[i]
        weights[i] = weights_2[i]
    
with open(final_file_,'wb') as f:
    pickle.dump([bestControl, bestState, cost, costnode, weights], f)
# Out:
# file found
# file found
# file found
# 0  inh init, cost compared
# 1  exc init, cost compared
# 2  exc init, cost compared
# 3  exc init, cost compared
# 4  inh init, cost compared
# 5  inh init, cost compared
# 6  inh init, cost compared
# 7  exc init, cost compared
# 8  exc init, cost compared
# 9  exc init, cost compared
# 10  both init, cost compared 1.9064319433553
# 11  both init, cost compared 0.9619461567440608
# 12  exc init, cost compared
# 13  exc init, cost compared
# 14  exc init, cost compared
# 15  both init, cost compared 2.048652201429195
# 16  inh init, cost compared
# 17  inh init, cost compared
# 18  exc init, cost compared
# 19  exc init, cost compared
# 20  both init, cost compared 3.551622984533928
# 21  both init, cost compared 2.051189118972767
# 22  both init, cost compared 0.8450134098235799
# 23  inh init, cost compared
# 24  exc init, cost compared
# 25  inh init, cost compared
# 26  both init, cost compared 5.392190625473704
# 27  both init, cost compared 3.4611226510517468
# 28  exc init, cost compared
# 29  exc init, cost compared
# 30  both init, cost compared 10.118816824593612
# 31  both init, cost compared 7.488076083441665
# 32  both init, cost compared 5.130486940345106
# 33  both init, cost compared 2.9807352351227516
# 34  exc init, cost compared
# 35  exc init, cost compared
# 36  both init, cost compared 12.809170306938608
# 37  both init, cost compared 9.817417318691554
# 38  both init, cost compared 6.980787863571834
# 39  both init, cost compared 4.330989354732193
# 40  exc init, cost compared
# 41  exc init, cost compared
# 42  inh init, cost compared
# 43  both init, cost compared 12.318341410277815
# 44  both init, cost compared 8.927624924477936
# 45  both init, cost compared 5.733385114763201
# 46  inh init, cost compared
# 47  exc init, cost compared
# 48  both init, cost compared 18.488762386917017
# 49  both init, cost compared 14.717870076280507
# 50  both init, cost compared 10.900475104450708
# 51  both init, cost compared 7.085272922466719
# 52  both init, cost compared 3.8564637243066953
# 53  both init, cost compared 1.4664733750896135
# 54  inh init, cost compared
# 55  inh init, cost compared
# 56  both init, cost compared 17.068654882520917
# 57  both init, cost compared 12.716137395395146
# 58  both init, cost compared 8.323036321151346
# 59  both init, cost compared 4.72991405403362
# 60  exc init, cost compared
# 61  both init, cost compared 0.32795008489805505
# 62  both init, cost compared 25.172191698650927
# 63  both init, cost compared 19.518410619572638
# 64  exc init, cost compared
# 65  both init, cost compared 9.432366508907819
# 66  both init, cost compared 5.541025416543733
# 67  exc init, cost compared
# 68  inh init, cost compared
# 69  both init, cost compared 28.733301936842683
# 70  both init, cost compared 21.501863821016627
# 71  inh init, cost compared
# 72  inh init, cost compared
# 73  inh init, cost compared
# 74  exc init, cost compared
# 75  inh init, cost compared
# 76  inh init, cost compared
# 77  both init, cost compared 22.901396360257944
# 78  exc init, cost compared
# 79  inh init, cost compared
# 80  inh init, cost compared
# 81  both init, cost compared 3.5714509148776536
# 82  both init, cost compared 1.1784463611147469

# %%
# TASK 3

final_file_ = '.' + os.sep + 'data_final_2' + os.sep + 'control_3.pickle'
file_E = '.' + os.sep + 'data_2' + os.sep + '3' + os.sep + '3.pickle'

if os.path.isfile(file_E) :
    print("file found")
    
    with open(file_E,'rb') as f:
        load_array = pickle.load(f)

    bestControl_0 = [None] * len(load_array[0])
    bestState_0 = bestControl_0.copy()
    cost_0 = bestControl_0.copy()
    costnode_0 = bestControl_0.copy()
    weights_0 = bestControl_0.copy()
    
    for i in range(len(bestControl_0)):
        bestControl_0[i] = load_array[0][i]
        bestState_0[i] = load_array[1][i]
        cost_0[i] = load_array[2][i]
        costnode_0[i] = load_array[3][i]
        weights_0[i] = load_array[4][i]
    
    
with open(final_file_,'wb') as f:
    pickle.dump([bestControl_0, bestState_0, cost_0, costnode_0, weights_0], f)
# Out:
# file found

# %%
# TASK 4

final_file_ = '.' + os.sep + 'data_final_2' + os.sep + 'control_4.pickle'
file_E = '.' + os.sep + 'data_2' + os.sep + '4' + os.sep + '4.pickle'

if os.path.isfile(file_E) :
    print("file found")
    
    with open(file_E,'rb') as f:
        load_array = pickle.load(f)

    bestControl_0 = [None] * len(load_array[0])
    bestState_0 = bestControl_0.copy()
    cost_0 = bestControl_0.copy()
    costnode_0 = bestControl_0.copy()
    weights_0 = bestControl_0.copy()
    
    for i in range(len(bestControl_0)):
        bestControl_0[i] = load_array[0][i]
        bestState_0[i] = load_array[1][i]
        cost_0[i] = load_array[2][i]
        costnode_0[i] = load_array[3][i]
        weights_0[i] = load_array[4][i]
    
with open(final_file_,'wb') as f:
    pickle.dump([bestControl_0, bestState_0, cost_0, costnode_0, weights_0], f)
# Out:
# file found
