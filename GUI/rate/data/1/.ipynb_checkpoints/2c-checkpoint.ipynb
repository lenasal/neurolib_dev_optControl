# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import sys
import pickle

path = os.getcwd().split(os.sep + 'GUI')[0]
if path not in sys.path:
    print("not here")
    sys.path.append(path)

from neurolib.models.aln import ALNModel
from neurolib.utils import plotFunctions as plotFunc
from neurolib.utils import costFunctions as cost
import neurolib.dashboard.functions as functions
import neurolib.dashboard.data as data
    
# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2 

#path = os.path.join(os.getcwd(), "plots")
# Out:
# not here

# %%
grid_data_file = os.path.join(os.getcwd().split('data')[0], 'bi.pickle')
print(grid_data_file)
with open(grid_data_file,'rb') as f:
    load_array= pickle.load(f)
exc = load_array[0]
inh = load_array[1]
print(len(exc))
# Out:
# /home/lena/Promotion/neurolib/GUI/current/gui/bi.pickle
# 147

# %% [markdown]
# ### Bistability

# %%
aln = ALNModel()
N = aln.params.N

data.set_parameters(aln)

state_vars = aln.state_vars
init_vars = aln.init_vars

##############################################################
def setinit(init_vars_, model):
    state_vars = model.state_vars
    init_vars = model.init_vars
    for iv in range(len(init_vars)):
        for sv in range(len(state_vars)):
            if state_vars[sv] in init_vars[iv]:
                #print("set init vars ", )
                if model.params[init_vars[iv]].ndim == 2:
                    model.params[init_vars[iv]][0,:] = init_vars_[sv]
                else:
                    model.params[init_vars[iv]][0] = init_vars_[sv]
                    
##############################################################               
def setmaxmincontrol(max_c_c, min_c_c, max_c_r, min_c_r):
    import numpy as np
    
    max_cntrl = np.zeros(( 6 ))
    min_cntrl = np.zeros(( 6 ))
    
    max_cntrl[0] = max_c_c
    min_cntrl[0] = min_c_c
    max_cntrl[1] = max_c_c
    min_cntrl[1] = min_c_c
    max_cntrl[2] = max_c_r
    min_cntrl[2] = min_c_r
    max_cntrl[3] = max_c_r
    min_cntrl[3] = min_c_r
    max_cntrl[4] = max_c_r
    min_cntrl[4] = min_c_r
    max_cntrl[5] = max_c_r
    min_cntrl[5] = min_c_r
            
    return max_cntrl, min_cntrl

# %%
d_array = np.arange(20., 300, 0.1)
t0_array = d_array - 20.
t_pen = np.zeros(( t0_array.shape ))
for i in range(len(t_pen)):
    t_pen[i] = t0_array[i] / d_array[i]

bestControl_ = np.array( [[None] * len(t_pen)] * len(exc) )
bestState_ = np.array( [[None] * len(t_pen)] * len(exc) )
cost_ = np.array( [[None] * len(t_pen)] * len(exc) )
costnode_ = np.array( [[None] * len(t_pen)] * len(exc) )
weights_ = np.array( [[None] * len(t_pen)] * len(exc) )
convergence_ = np.array( [[None] * len(t_pen)] * len(exc) )

initVars = [None] * len(exc)
target = [None] * len(exc)
cost_uncontrolled = [None] * len(exc)

print(bestControl_.shape)
# Out:
# (147, 2800)

# %%
file_ = '2c.pickle'
case = '1'

# %%
dur_pre = 10
dur_post = 10

n_pre = int(np.around(dur_pre/aln.params.dt + 1.,1))
n_post = int(np.around(dur_post/aln.params.dt + 1.,1))

tol = 1e-32
start_step = 10.
c_scheme = np.zeros(( 1,1 ))
c_scheme[0,0] = 1.
u_mat = np.identity(1)
u_scheme = np.array([[1.]])

c_var = [1]
p_var = [0]

if case in ['1', '2']:    # low to high
    max_I = [3., -3.]
else:
    max_I = [-3., 3.]
    
if case in ['1', '3']:    # sparsity
    factor_ws = 1.
    factor_we = 0.
else:
    factor_ws = 0.
    factor_we = 1.
    
maxC = [5., -5., 0.18, 0.]
max_cntrl, min_cntrl = setmaxmincontrol(maxC[0], maxC[1], maxC[2], maxC[3])

# %%
if os.path.isfile(file_) :
    print("file found")
    
    with open(file_,'rb') as f:
        load_array = pickle.load(f)

    bestControl_ = load_array[0]
    bestState_ = load_array[1]
    cost_ = load_array[2]
    costnode_ = load_array[3]
    weights_ = load_array[4]
# Out:
# file found

# %%
# get initial parameters and target states

#i_stepsize = 20
#limit = 150
#start_index = 0
#i_range = range(start_index, limit,i_stepsize)
i_range = [20]

data.set_parameters(aln)

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    aln.params.duration = 3000.
    
    control0 = aln.getZeroControl()
    control0 = functions.step_control(aln, maxI_ = max_I[0])

    aln.run(control=control0)
    
    target_rates = np.zeros((2))
    target_rates[0] = aln.rates_exc[0,-1] 
    target_rates[1] = aln.rates_inh[0,-1]

    control0 = functions.step_control(aln, maxI_ = max_I[1])
    aln.run(control=control0)

    init_state_vars = np.zeros(( len(state_vars) ))
    for j in range(len(state_vars)):
        if aln.state[state_vars[j]].size == 1:
            init_state_vars[j] = aln.state[state_vars[j]][0]
        else:
            init_state_vars[j] = aln.state[state_vars[j]][0,-1]

    initVars[i] = init_state_vars
    target[i] = [target_rates[0], target_rates[1]]
# Out:
# -------  20 0.4500000000000001 0.4750000000000002

# %%
# get uncontrolled cost

data.set_parameters(aln)

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    dur = d_array[0]
    aln.params.duration = dur
    
    target_ = aln.getZeroTarget()
    target_[:,0,:] = target[i][0]
    target_[:,1,:] = target[i][1]
        
    cost.setParams(1.0, 0.0, 0.0)

    setinit(initVars[i], aln)
    control0 = aln.getZeroControl()

    # "HS", "FR", "PR", "HZ"
    cgv = None
    max_it = 0

    bestControl_init_, bestState_init_, cost_init_, runtime_init_, grad_init_, phi_init_, costnode_init_ = aln.A1(
        control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
        prec_variables_ = p_var, transition_time_ = 0.)
    
    cost_uncontrolled[i] = cost_init_[0]
# Out:
# -------  20 0.4500000000000001 0.4750000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  0 , total integrated cost =  12801.807032522984
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.

# %%
cgv = None
j = 0
k = 0

while k < 10:
    print('-------------------------------------------- k = ', k)

    for i in i_range:
        print("------- ", i, exc[i], inh[i])
        aln.params.ext_exc_current = exc[i] * 5.
        aln.params.ext_inh_current = inh[i] * 5.

        if convergence_[i][j] == True:
            print('converged')
            continue

        dur = d_array[0]
        aln.params.duration = dur
        
        setinit(initVars[i], aln)

        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        max_it = int(100)

        if type(bestControl_[i][j]) == type(None) or np.amax(np.abs(bestControl_[i][j])) < 1e-6:
            print('no solution found')
            control0 = aln.getZeroControl()
            #control0[0,0,:50] = 5.
            cost.setParams(1.0, 0., 1.)
            max_it = int(1)
            weights_[i][j] = [1., 0., 1.]
        else:
            control0 = bestControl_[i][j][:,:,n_pre-1:-n_post+1]
            l = 1
            while cost_[i][j][-l] == 0.:
                l += 1

            weight_ = ( cost_uncontrolled[i] - costnode_[i][j][0][0][0] ) / sum( costnode_[i][j][2][0][:] )
                
            print("weight = ", weight_)
            cost.setParams(1.0, weight_ * factor_we, weight_ * factor_ws)
            weights_[i][j] = cost.getParams()

        bestControl_[i][j], bestState_[i][j], cost_[i][j], runtime_, grad_, phi_, costnode_[i][j] = aln.A1(
            control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = [1],
            prec_variables_ = p_var, transition_time_ = t_pen[j])

        #if cost_[i][j][2] == 0.:
        #    print('converged')
        #    convergence_[i][j] = True

        print('uncontrolled cost : ', cost_uncontrolled[i])
        print('cost splitting : ', costnode_[i][j][0][0][0], costnode_[i][j][2][0][:2])

        time_ = np.arange(-dur_pre,dur+dur_post+aln.params.dt,aln.params.dt)
        dur += dur_pre + dur_post
        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        if True:
            fig, ax = plt.subplots(2,1, constrained_layout=True, figsize = (4,4) )
            ax[1].plot(time_, bestControl_[i][j][0,0,:], color = 'red')
            ax[0].plot(time_, bestState_[i][j][0,0,:], color= 'red')
            ax[1].plot(time_, bestControl_[i][j][0,1,:], color = 'blue')
            ax[0].plot(time_, bestState_[i][j][0,1,:], color= 'blue')
            ax[0].plot(time_, target_[0,0,:], linestyle = '--', color='red')
            ax[0].plot(time_, target_[0,1,:], linestyle = '--', color='blue')
            ax[0].set_xlim(-dur_pre,dur-dur_post)
            ax[1].set_xlim(-dur_pre,dur-dur_post)
            ax[0].axvspan(t0_array[0], dur, alpha=0.2, color='gray')
            plt.show()

        with open(file_,'wb') as f:
            pickle.dump([bestControl_, bestState_, cost_, costnode_, weights_], f)
    
    k += 1
# Out:
# -------------------------------------------- k =  0
# -------  20 0.4500000000000001 0.4750000000000002
# weight =  592.3992259495612
# set cost params:  1.0 0.0 592.3992259495612
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  25.470978680998087  seconds by  0.0  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  9356.47981754994 [0.         5.81588744]
# -------------------------------------------- k =  1
# -------  20 0.4500000000000001 0.4750000000000002
# weight =  592.3992259495612
# set cost params:  1.0 0.0 592.3992259495612
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.12624534300994128  seconds by  0.0  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  9356.47981754994 [0.         5.81588744]
# -------------------------------------------- k =  2
# -------  20 0.4500000000000001 0.4750000000000002
# weight =  592.3992259495612
# set cost params:  1.0 0.0 592.3992259495612
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.1454634559340775  seconds by  0.0  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  9356.47981754994 [0.         5.81588744]
# -------------------------------------------- k =  3
# -------  20 0.4500000000000001 0.4750000000000002
# weight =  592.3992259495612
# set cost params:  1.0 0.0 592.3992259495612
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.13021848199423403  seconds by  0.0  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  9356.47981754994 [0.         5.81588744]
# -------------------------------------------- k =  4
# -------  20 0.4500000000000001 0.4750000000000002
# weight =  592.3992259495612
# set cost params:  1.0 0.0 592.3992259495612
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.11726106097921729  seconds by  0.0  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  9356.47981754994 [0.         5.81588744]
# -------------------------------------------- k =  5
# -------  20 0.4500000000000001 0.4750000000000002
# weight =  592.3992259495612
# set cost params:  1.0 0.0 592.3992259495612
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.11328217305708677  seconds by  0.0  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  9356.47981754994 [0.         5.81588744]
# -------------------------------------------- k =  6
# -------  20 0.4500000000000001 0.4750000000000002
# weight =  592.3992259495612
# set cost params:  1.0 0.0 592.3992259495612
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.1289514929521829  seconds by  0.0  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  9356.47981754994 [0.         5.81588744]
# -------------------------------------------- k =  7
# -------  20 0.4500000000000001 0.4750000000000002
# weight =  592.3992259495612
# set cost params:  1.0 0.0 592.3992259495612
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.1182208969257772  seconds by  0.0  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  9356.47981754994 [0.         5.81588744]
# -------------------------------------------- k =  8
# -------  20 0.4500000000000001 0.4750000000000002
# weight =  592.3992259495612
# set cost params:  1.0 0.0 592.3992259495612
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.11149803490843624  seconds by  0.0  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  9356.47981754994 [0.         5.81588744]
# -------------------------------------------- k =  9
# -------  20 0.4500000000000001 0.4750000000000002
# weight =  592.3992259495612
# set cost params:  1.0 0.0 592.3992259495612
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.11356583703309298  seconds by  0.0  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  9356.47981754994 [0.         5.81588744]

# %%
for i in range(bestControl_.shape[0]):
    for j in range(1,bestControl_.shape[1]):
        bestControl_[i][j] = None
        convergence_[i][j] = None

# %%
cost.setParams(1.0, factor_we, factor_ws)

j_start = 1

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.

    for j in range(j_start,j_start+1400):
        print(i,j, '-----------------')
            
        k = 0
        while convergence_[i][j] != True:
            print('---------------------', k)

            dur = round(d_array[j],1)
            print('simulation duration : ', dur)
            aln.params.duration = dur
            max_it = int(100)  
            
            setinit(initVars[i], aln)
            target_ = aln.getZeroTarget()
            target_[:,0,:] = target[i][0]
            target_[:,1,:] = target[i][1]

            if type(bestControl_[i][j]) == type(None):
                print('no solution computed yet')
                control0 = aln.getZeroControl()
                control0[:,:,1:] = bestControl_[i][j-1][:,:,n_pre-1:-n_post+1]
                                        
                l = 1
                while cost_[i][j-1][-l] == 0.:
                    l += 1
                    
                weight_ = ( cost_uncontrolled[i] - costnode_[i][j-1][0][0][0] ) / sum( costnode_[i][j-1][2][0][:] )
            else:
                control0 = bestControl_[i][j][:,:,n_pre-1:-n_post+1]
                l = 1
                while cost_[i][j][-l] == 0.:
                    l += 1
                
                weight_ = ( cost_uncontrolled[i] - costnode_[i][j][0][0][0] ) / sum( costnode_[i][j][2][0][:] )
                
            print("weight = ", weight_)
            cost.setParams(1.0, weight_ * factor_we, weight_ * factor_ws)
            weights_[i][j] = cost.getParams()

            bestControl_[i][j], bestState_[i][j], cost_[i][j], runtime_, grad_, phi_, costnode_[i][j] = aln.A1(
                control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
                startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
                t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = [1],
                prec_variables_ = p_var, transition_time_ = t_pen[j])

            if cost_[i][j][2] == 0.:
                print('converged')
                convergence_[i][j] = True

            print('uncontrolled cost : ', cost_uncontrolled[i])
            print('cost splitting : ', costnode_[i][j][0][0][0], costnode_[i][j][2][0][:2])

            time_ = np.arange(-dur_pre,round(dur+dur_post+aln.params.dt,1),aln.params.dt)
            dur += dur_pre + dur_post
            target_ = aln.getZeroTarget()
            target_[:,0,:] = target[i][0]
            target_[:,1,:] = target[i][1]

            if False:
                fig, ax = plt.subplots(2,1, constrained_layout=True, figsize = (4,4) )
                ax[1].plot(time_, bestControl_[i][j][0,0,:], color = 'red')
                ax[0].plot(time_, bestState_[i][j][0,0,:], color= 'red')
                ax[1].plot(time_, bestControl_[i][j][0,1,:], color = 'blue')
                ax[0].plot(time_, bestState_[i][j][0,1,:], color= 'blue')
                ax[0].plot(time_, target_[0,0,:], linestyle = '--', color='red')
                ax[0].plot(time_, target_[0,1,:], linestyle = '--', color='blue')
                ax[0].set_xlim(-dur_pre,dur-dur_post)
                ax[1].set_xlim(-dur_pre,dur-dur_post)
                ax[0].axvspan(t0_array[j], t0_array[j]+20, alpha=0.2, color='gray')
                plt.show()

            with open(file_,'wb') as f:
                pickle.dump([bestControl_, bestState_, cost_, costnode_, weights_], f)
                
            k += 1
# Out:
# set cost params:  1.0 0.0 1.0
# -------  20 0.4500000000000001 0.4750000000000002
# 20 1 -----------------
# 20 2 -----------------
# 20 3 -----------------
# 20 4 -----------------
# 20 5 -----------------
# 20 6 -----------------
# 20 7 -----------------
# 20 8 -----------------
# 20 9 -----------------
# 20 10 -----------------
# 20 11 -----------------
# 20 12 -----------------
# 20 13 -----------------
# 20 14 -----------------
# 20 15 -----------------
# 20 16 -----------------
# 20 17 -----------------
# 20 18 -----------------
# 20 19 -----------------
# 20 20 -----------------
# 20 21 -----------------
# 20 22 -----------------
# 20 23 -----------------
# 20 24 -----------------
# 20 25 -----------------
# 20 26 -----------------
# 20 27 -----------------
# 20 28 -----------------
# 20 29 -----------------
# 20 30 -----------------
# 20 31 -----------------
# 20 32 -----------------
# 20 33 -----------------
# 20 34 -----------------
# 20 35 -----------------
# 20 36 -----------------
# 20 37 -----------------
# 20 38 -----------------
# 20 39 -----------------
# 20 40 -----------------
# 20 41 -----------------
# 20 42 -----------------
# 20 43 -----------------
# 20 44 -----------------
# 20 45 -----------------
# 20 46 -----------------
# 20 47 -----------------
# 20 48 -----------------
# 20 49 -----------------
# 20 50 -----------------
# 20 51 -----------------
# 20 52 -----------------
# 20 53 -----------------
# 20 54 -----------------
# 20 55 -----------------
# 20 56 -----------------
# 20 57 -----------------
# 20 58 -----------------
# 20 59 -----------------
# 20 60 -----------------
# 20 61 -----------------
# 20 62 -----------------
# 20 63 -----------------
# 20 64 -----------------
# 20 65 -----------------
# 20 66 -----------------
# 20 67 -----------------
# 20 68 -----------------
# 20 69 -----------------
# 20 70 -----------------
# 20 71 -----------------
# 20 72 -----------------
# 20 73 -----------------
# 20 74 -----------------
# 20 75 -----------------
# 20 76 -----------------
# 20 77 -----------------
# 20 78 -----------------
# 20 79 -----------------
# 20 80 -----------------
# 20 81 -----------------
# 20 82 -----------------
# 20 83 -----------------
# 20 84 -----------------
# 20 85 -----------------
# 20 86 -----------------
# 20 87 -----------------
# 20 88 -----------------
# 20 89 -----------------
# 20 90 -----------------
# 20 91 -----------------
# 20 92 -----------------
# 20 93 -----------------
# 20 94 -----------------
# 20 95 -----------------
# 20 96 -----------------
# 20 97 -----------------
# 20 98 -----------------
# 20 99 -----------------
# 20 100 -----------------
# 20 101 -----------------
# 20 102 -----------------
# 20 103 -----------------
# 20 104 -----------------
# 20 105 -----------------
# 20 106 -----------------
# 20 107 -----------------
# 20 108 -----------------
# 20 109 -----------------
# 20 110 -----------------
# 20 111 -----------------
# 20 112 -----------------
# 20 113 -----------------
# 20 114 -----------------
# 20 115 -----------------
# 20 116 -----------------
# 20 117 -----------------
# 20 118 -----------------
# 20 119 -----------------
# 20 120 -----------------
# 20 121 -----------------
# 20 122 -----------------
# 20 123 -----------------
# 20 124 -----------------
# 20 125 -----------------
# 20 126 -----------------
# 20 127 -----------------
# 20 128 -----------------
# 20 129 -----------------
# 20 130 -----------------
# 20 131 -----------------
# 20 132 -----------------
# 20 133 -----------------
# 20 134 -----------------
# 20 135 -----------------
# 20 136 -----------------
# 20 137 -----------------
# 20 138 -----------------
# 20 139 -----------------
# 20 140 -----------------
# 20 141 -----------------
# 20 142 -----------------
# 20 143 -----------------
# 20 144 -----------------
# 20 145 -----------------
# 20 146 -----------------
# 20 147 -----------------
# 20 148 -----------------
# 20 149 -----------------
# 20 150 -----------------
# 20 151 -----------------
# 20 152 -----------------
# 20 153 -----------------
# 20 154 -----------------
# 20 155 -----------------
# 20 156 -----------------
# 20 157 -----------------
# 20 158 -----------------
# 20 159 -----------------
# 20 160 -----------------
# 20 161 -----------------
# 20 162 -----------------
# 20 163 -----------------
# 20 164 -----------------
# 20 165 -----------------
# 20 166 -----------------
# 20 167 -----------------
# 20 168 -----------------
# 20 169 -----------------
# 20 170 -----------------
# 20 171 -----------------
# 20 172 -----------------
# 20 173 -----------------
# 20 174 -----------------
# 20 175 -----------------
# 20 176 -----------------
# 20 177 -----------------
# 20 178 -----------------
# 20 179 -----------------
# 20 180 -----------------
# 20 181 -----------------
# 20 182 -----------------
# 20 183 -----------------
# 20 184 -----------------
# 20 185 -----------------
# 20 186 -----------------
# 20 187 -----------------
# 20 188 -----------------
# 20 189 -----------------
# 20 190 -----------------
# 20 191 -----------------
# 20 192 -----------------
# 20 193 -----------------
# 20 194 -----------------
# 20 195 -----------------
# 20 196 -----------------
# 20 197 -----------------
# 20 198 -----------------
# 20 199 -----------------
# 20 200 -----------------
# 20 201 -----------------
# 20 202 -----------------
# 20 203 -----------------
# 20 204 -----------------
# 20 205 -----------------
# 20 206 -----------------
# 20 207 -----------------
# 20 208 -----------------
# 20 209 -----------------
# 20 210 -----------------
# 20 211 -----------------
# 20 212 -----------------
# 20 213 -----------------
# 20 214 -----------------
# 20 215 -----------------
# 20 216 -----------------
# 20 217 -----------------
# 20 218 -----------------
# 20 219 -----------------
# 20 220 -----------------
# 20 221 -----------------
# 20 222 -----------------
# 20 223 -----------------
# 20 224 -----------------
# 20 225 -----------------
# 20 226 -----------------
# 20 227 -----------------
# 20 228 -----------------
# 20 229 -----------------
# 20 230 -----------------
# 20 231 -----------------
# 20 232 -----------------
# 20 233 -----------------
# 20 234 -----------------
# 20 235 -----------------
# 20 236 -----------------
# 20 237 -----------------
# 20 238 -----------------
# 20 239 -----------------
# 20 240 -----------------
# 20 241 -----------------
# 20 242 -----------------
# 20 243 -----------------
# 20 244 -----------------
# 20 245 -----------------
# 20 246 -----------------
# 20 247 -----------------
# 20 248 -----------------
# 20 249 -----------------
# 20 250 -----------------
# 20 251 -----------------
# 20 252 -----------------
# 20 253 -----------------
# 20 254 -----------------
# 20 255 -----------------
# 20 256 -----------------
# 20 257 -----------------
# 20 258 -----------------
# 20 259 -----------------
# 20 260 -----------------
# 20 261 -----------------
# 20 262 -----------------
# 20 263 -----------------
# 20 264 -----------------
# 20 265 -----------------
# 20 266 -----------------
# 20 267 -----------------
# 20 268 -----------------
# 20 269 -----------------
# 20 270 -----------------
# 20 271 -----------------
# 20 272 -----------------
# 20 273 -----------------
# 20 274 -----------------
# 20 275 -----------------
# 20 276 -----------------
# 20 277 -----------------
# 20 278 -----------------
# 20 279 -----------------
# 20 280 -----------------
# 20 281 -----------------
# 20 282 -----------------
# 20 283 -----------------
# 20 284 -----------------
# 20 285 -----------------
# 20 286 -----------------
# 20 287 -----------------
# 20 288 -----------------
# 20 289 -----------------
# 20 290 -----------------
# 20 291 -----------------
# 20 292 -----------------
# 20 293 -----------------
# 20 294 -----------------
# 20 295 -----------------
# 20 296 -----------------
# 20 297 -----------------
# 20 298 -----------------
# 20 299 -----------------
# 20 300 -----------------
# 20 301 -----------------
# 20 302 -----------------
# 20 303 -----------------
# 20 304 -----------------
# 20 305 -----------------
# 20 306 -----------------
# 20 307 -----------------
# 20 308 -----------------
# 20 309 -----------------
# 20 310 -----------------
# 20 311 -----------------
# 20 312 -----------------
# 20 313 -----------------
# 20 314 -----------------
# 20 315 -----------------
# 20 316 -----------------
# 20 317 -----------------
# 20 318 -----------------
# 20 319 -----------------
# 20 320 -----------------
# 20 321 -----------------
# 20 322 -----------------
# 20 323 -----------------
# 20 324 -----------------
# 20 325 -----------------
# 20 326 -----------------
# 20 327 -----------------
# 20 328 -----------------
# 20 329 -----------------
# 20 330 -----------------
# 20 331 -----------------
# 20 332 -----------------
# 20 333 -----------------
# 20 334 -----------------
# 20 335 -----------------
# 20 336 -----------------
# 20 337 -----------------
# 20 338 -----------------
# 20 339 -----------------
# 20 340 -----------------
# 20 341 -----------------
# 20 342 -----------------
# 20 343 -----------------
# 20 344 -----------------
# 20 345 -----------------
# 20 346 -----------------
# 20 347 -----------------
# 20 348 -----------------
# 20 349 -----------------
# 20 350 -----------------
# 20 351 -----------------
# 20 352 -----------------
# 20 353 -----------------
# 20 354 -----------------
# 20 355 -----------------
# 20 356 -----------------
# 20 357 -----------------
# 20 358 -----------------
# 20 359 -----------------
# 20 360 -----------------
# 20 361 -----------------
# 20 362 -----------------
# 20 363 -----------------
# 20 364 -----------------
# 20 365 -----------------
# 20 366 -----------------
# 20 367 -----------------
# 20 368 -----------------
# 20 369 -----------------
# 20 370 -----------------
# 20 371 -----------------
# 20 372 -----------------
# 20 373 -----------------
# 20 374 -----------------
# 20 375 -----------------
# 20 376 -----------------
# 20 377 -----------------
# 20 378 -----------------
# 20 379 -----------------
# 20 380 -----------------
# 20 381 -----------------
# 20 382 -----------------
# 20 383 -----------------
# 20 384 -----------------
# 20 385 -----------------
# 20 386 -----------------
# 20 387 -----------------
# 20 388 -----------------
# 20 389 -----------------
# 20 390 -----------------
# 20 391 -----------------
# 20 392 -----------------
# 20 393 -----------------
# 20 394 -----------------
# 20 395 -----------------
# 20 396 -----------------
# 20 397 -----------------
# 20 398 -----------------
# 20 399 -----------------
# 20 400 -----------------
# 20 401 -----------------
# 20 402 -----------------
# 20 403 -----------------
# 20 404 -----------------
# 20 405 -----------------
# 20 406 -----------------
# 20 407 -----------------
# 20 408 -----------------
# 20 409 -----------------
# 20 410 -----------------
# 20 411 -----------------
# 20 412 -----------------
# 20 413 -----------------
# 20 414 -----------------
# 20 415 -----------------
# 20 416 -----------------
# 20 417 -----------------
# 20 418 -----------------
# 20 419 -----------------
# 20 420 -----------------
# 20 421 -----------------
# 20 422 -----------------
# 20 423 -----------------
# 20 424 -----------------
# 20 425 -----------------
# 20 426 -----------------
# 20 427 -----------------
# 20 428 -----------------
# 20 429 -----------------
# 20 430 -----------------
# 20 431 -----------------
# 20 432 -----------------
# 20 433 -----------------
# 20 434 -----------------
# 20 435 -----------------
# 20 436 -----------------
# 20 437 -----------------
# 20 438 -----------------
# 20 439 -----------------
# 20 440 -----------------
# 20 441 -----------------
# 20 442 -----------------
# 20 443 -----------------
# 20 444 -----------------
# 20 445 -----------------
# 20 446 -----------------
# 20 447 -----------------
# 20 448 -----------------
# 20 449 -----------------
# 20 450 -----------------
# 20 451 -----------------
# 20 452 -----------------
# 20 453 -----------------
# 20 454 -----------------
# 20 455 -----------------
# 20 456 -----------------
# 20 457 -----------------
# 20 458 -----------------
# 20 459 -----------------
# 20 460 -----------------
# 20 461 -----------------
# 20 462 -----------------
# 20 463 -----------------
# 20 464 -----------------
# 20 465 -----------------
# 20 466 -----------------
# 20 467 -----------------
# 20 468 -----------------
# 20 469 -----------------
# 20 470 -----------------
# 20 471 -----------------
# 20 472 -----------------
# 20 473 -----------------
# 20 474 -----------------
# 20 475 -----------------
# 20 476 -----------------
# 20 477 -----------------
# 20 478 -----------------
# 20 479 -----------------
# 20 480 -----------------
# 20 481 -----------------
# 20 482 -----------------
# 20 483 -----------------
# 20 484 -----------------
# 20 485 -----------------
# 20 486 -----------------
# 20 487 -----------------
# 20 488 -----------------
# 20 489 -----------------
# 20 490 -----------------
# 20 491 -----------------
# 20 492 -----------------
# 20 493 -----------------
# 20 494 -----------------
# 20 495 -----------------
# 20 496 -----------------
# 20 497 -----------------
# 20 498 -----------------
# 20 499 -----------------
# 20 500 -----------------
# 20 501 -----------------
# 20 502 -----------------
# 20 503 -----------------
# 20 504 -----------------
# 20 505 -----------------
# 20 506 -----------------
# 20 507 -----------------
# 20 508 -----------------
# 20 509 -----------------
# 20 510 -----------------
# 20 511 -----------------
# 20 512 -----------------
# 20 513 -----------------
# 20 514 -----------------
# 20 515 -----------------
# 20 516 -----------------
# 20 517 -----------------
# 20 518 -----------------
# 20 519 -----------------
# 20 520 -----------------
# 20 521 -----------------
# 20 522 -----------------
# 20 523 -----------------
# 20 524 -----------------
# 20 525 -----------------
# 20 526 -----------------
# 20 527 -----------------
# 20 528 -----------------
# 20 529 -----------------
# 20 530 -----------------
# 20 531 -----------------
# 20 532 -----------------
# 20 533 -----------------
# 20 534 -----------------
# 20 535 -----------------
# 20 536 -----------------
# 20 537 -----------------
# 20 538 -----------------
# 20 539 -----------------
# 20 540 -----------------
# 20 541 -----------------
# 20 542 -----------------
# 20 543 -----------------
# 20 544 -----------------
# 20 545 -----------------
# 20 546 -----------------
# 20 547 -----------------
# 20 548 -----------------
# 20 549 -----------------
# 20 550 -----------------
# 20 551 -----------------
# 20 552 -----------------
# 20 553 -----------------
# 20 554 -----------------
# 20 555 -----------------
# 20 556 -----------------
# 20 557 -----------------
# 20 558 -----------------
# 20 559 -----------------
# 20 560 -----------------
# 20 561 -----------------
# 20 562 -----------------
# 20 563 -----------------
# 20 564 -----------------
# 20 565 -----------------
# 20 566 -----------------
# 20 567 -----------------
# 20 568 -----------------
# 20 569 -----------------
# 20 570 -----------------
# 20 571 -----------------
# 20 572 -----------------
# 20 573 -----------------
# 20 574 -----------------
# 20 575 -----------------
# 20 576 -----------------
# 20 577 -----------------
# 20 578 -----------------
# 20 579 -----------------
# 20 580 -----------------
# 20 581 -----------------
# 20 582 -----------------
# 20 583 -----------------
# 20 584 -----------------
# 20 585 -----------------
# 20 586 -----------------
# 20 587 -----------------
# 20 588 -----------------
# 20 589 -----------------
# 20 590 -----------------
# 20 591 -----------------
# 20 592 -----------------
# 20 593 -----------------
# 20 594 -----------------
# 20 595 -----------------
# 20 596 -----------------
# 20 597 -----------------
# 20 598 -----------------
# 20 599 -----------------
# 20 600 -----------------
# 20 601 -----------------
# 20 602 -----------------
# 20 603 -----------------
# 20 604 -----------------
# 20 605 -----------------
# 20 606 -----------------
# 20 607 -----------------
# 20 608 -----------------
# 20 609 -----------------
# 20 610 -----------------
# 20 611 -----------------
# 20 612 -----------------
# 20 613 -----------------
# 20 614 -----------------
# 20 615 -----------------
# 20 616 -----------------
# 20 617 -----------------
# 20 618 -----------------
# 20 619 -----------------
# 20 620 -----------------
# 20 621 -----------------
# 20 622 -----------------
# 20 623 -----------------
# 20 624 -----------------
# 20 625 -----------------
# 20 626 -----------------
# 20 627 -----------------
# 20 628 -----------------
# 20 629 -----------------
# 20 630 -----------------
# 20 631 -----------------
# 20 632 -----------------
# 20 633 -----------------
# 20 634 -----------------
# 20 635 -----------------
# 20 636 -----------------
# 20 637 -----------------
# 20 638 -----------------
# 20 639 -----------------
# 20 640 -----------------
# 20 641 -----------------
# 20 642 -----------------
# 20 643 -----------------
# 20 644 -----------------
# 20 645 -----------------
# 20 646 -----------------
# 20 647 -----------------
# 20 648 -----------------
# 20 649 -----------------
# 20 650 -----------------
# 20 651 -----------------
# 20 652 -----------------
# 20 653 -----------------
# 20 654 -----------------
# 20 655 -----------------
# 20 656 -----------------
# 20 657 -----------------
# 20 658 -----------------
# 20 659 -----------------
# 20 660 -----------------
# 20 661 -----------------
# 20 662 -----------------
# 20 663 -----------------
# 20 664 -----------------
# 20 665 -----------------
# 20 666 -----------------
# 20 667 -----------------
# 20 668 -----------------
# 20 669 -----------------
# 20 670 -----------------
# 20 671 -----------------
# 20 672 -----------------
# 20 673 -----------------
# 20 674 -----------------
# 20 675 -----------------
# 20 676 -----------------
# 20 677 -----------------
# 20 678 -----------------
# 20 679 -----------------
# 20 680 -----------------
# 20 681 -----------------
# 20 682 -----------------
# 20 683 -----------------
# 20 684 -----------------
# 20 685 -----------------
# 20 686 -----------------
# 20 687 -----------------
# 20 688 -----------------
# 20 689 -----------------
# 20 690 -----------------
# 20 691 -----------------
# 20 692 -----------------
# 20 693 -----------------
# 20 694 -----------------
# 20 695 -----------------
# 20 696 -----------------
# 20 697 -----------------
# 20 698 -----------------
# 20 699 -----------------
# 20 700 -----------------
# 20 701 -----------------
# 20 702 -----------------
# 20 703 -----------------
# 20 704 -----------------
# 20 705 -----------------
# 20 706 -----------------
# 20 707 -----------------
# 20 708 -----------------
# 20 709 -----------------
# 20 710 -----------------
# 20 711 -----------------
# 20 712 -----------------
# 20 713 -----------------
# 20 714 -----------------
# 20 715 -----------------
# 20 716 -----------------
# 20 717 -----------------
# 20 718 -----------------
# 20 719 -----------------
# 20 720 -----------------
# 20 721 -----------------
# 20 722 -----------------
# 20 723 -----------------
# 20 724 -----------------
# 20 725 -----------------
# 20 726 -----------------
# 20 727 -----------------
# 20 728 -----------------
# 20 729 -----------------
# 20 730 -----------------
# 20 731 -----------------
# 20 732 -----------------
# 20 733 -----------------
# 20 734 -----------------
# 20 735 -----------------
# 20 736 -----------------
# 20 737 -----------------
# 20 738 -----------------
# 20 739 -----------------
# 20 740 -----------------
# 20 741 -----------------
# 20 742 -----------------
# 20 743 -----------------
# 20 744 -----------------
# 20 745 -----------------
# 20 746 -----------------
# 20 747 -----------------
# 20 748 -----------------
# 20 749 -----------------
# 20 750 -----------------
# 20 751 -----------------
# 20 752 -----------------
# 20 753 -----------------
# 20 754 -----------------
# 20 755 -----------------
# 20 756 -----------------
# 20 757 -----------------
# 20 758 -----------------
# 20 759 -----------------
# 20 760 -----------------
# 20 761 -----------------
# 20 762 -----------------
# 20 763 -----------------
# 20 764 -----------------
# 20 765 -----------------
# 20 766 -----------------
# 20 767 -----------------
# 20 768 -----------------
# 20 769 -----------------
# 20 770 -----------------
# 20 771 -----------------
# 20 772 -----------------
# 20 773 -----------------
# 20 774 -----------------
# 20 775 -----------------
# 20 776 -----------------
# 20 777 -----------------
# 20 778 -----------------
# 20 779 -----------------
# 20 780 -----------------
# 20 781 -----------------
# 20 782 -----------------
# 20 783 -----------------
# 20 784 -----------------
# 20 785 -----------------
# 20 786 -----------------
# 20 787 -----------------
# 20 788 -----------------
# 20 789 -----------------
# 20 790 -----------------
# 20 791 -----------------
# 20 792 -----------------
# 20 793 -----------------
# 20 794 -----------------
# 20 795 -----------------
# 20 796 -----------------
# 20 797 -----------------
# 20 798 -----------------
# 20 799 -----------------
# 20 800 -----------------
# 20 801 -----------------
# 20 802 -----------------
# 20 803 -----------------
# 20 804 -----------------
# 20 805 -----------------
# 20 806 -----------------
# 20 807 -----------------
# 20 808 -----------------
# 20 809 -----------------
# 20 810 -----------------
# 20 811 -----------------
# 20 812 -----------------
# 20 813 -----------------
# 20 814 -----------------
# 20 815 -----------------
# 20 816 -----------------
# 20 817 -----------------
# 20 818 -----------------
# 20 819 -----------------
# 20 820 -----------------
# 20 821 -----------------
# 20 822 -----------------
# 20 823 -----------------
# 20 824 -----------------
# 20 825 -----------------
# 20 826 -----------------
# 20 827 -----------------
# 20 828 -----------------
# 20 829 -----------------
# 20 830 -----------------
# 20 831 -----------------
# 20 832 -----------------
# 20 833 -----------------
# 20 834 -----------------
# 20 835 -----------------
# 20 836 -----------------
# 20 837 -----------------
# 20 838 -----------------
# 20 839 -----------------
# 20 840 -----------------
# 20 841 -----------------
# 20 842 -----------------
# 20 843 -----------------
# 20 844 -----------------
# 20 845 -----------------
# 20 846 -----------------
# 20 847 -----------------
# 20 848 -----------------
# 20 849 -----------------
# 20 850 -----------------
# 20 851 -----------------
# 20 852 -----------------
# 20 853 -----------------
# 20 854 -----------------
# 20 855 -----------------
# 20 856 -----------------
# 20 857 -----------------
# 20 858 -----------------
# 20 859 -----------------
# 20 860 -----------------
# 20 861 -----------------
# 20 862 -----------------
# 20 863 -----------------
# 20 864 -----------------
# 20 865 -----------------
# 20 866 -----------------
# 20 867 -----------------
# 20 868 -----------------
# 20 869 -----------------
# 20 870 -----------------
# 20 871 -----------------
# 20 872 -----------------
# 20 873 -----------------
# 20 874 -----------------
# 20 875 -----------------
# 20 876 -----------------
# 20 877 -----------------
# 20 878 -----------------
# 20 879 -----------------
# 20 880 -----------------
# 20 881 -----------------
# 20 882 -----------------
# 20 883 -----------------
# 20 884 -----------------
# 20 885 -----------------
# 20 886 -----------------
# 20 887 -----------------
# 20 888 -----------------
# 20 889 -----------------
# 20 890 -----------------
# 20 891 -----------------
# 20 892 -----------------
# 20 893 -----------------
# 20 894 -----------------
# 20 895 -----------------
# 20 896 -----------------
# 20 897 -----------------
# 20 898 -----------------
# 20 899 -----------------
# 20 900 -----------------
# 20 901 -----------------
# 20 902 -----------------
# 20 903 -----------------
# 20 904 -----------------
# 20 905 -----------------
# 20 906 -----------------
# 20 907 -----------------
# 20 908 -----------------
# 20 909 -----------------
# 20 910 -----------------
# 20 911 -----------------
# 20 912 -----------------
# 20 913 -----------------
# 20 914 -----------------
# 20 915 -----------------
# 20 916 -----------------
# 20 917 -----------------
# 20 918 -----------------
# 20 919 -----------------
# 20 920 -----------------
# 20 921 -----------------
# 20 922 -----------------
# 20 923 -----------------
# 20 924 -----------------
# 20 925 -----------------
# 20 926 -----------------
# 20 927 -----------------
# 20 928 -----------------
# 20 929 -----------------
# 20 930 -----------------
# 20 931 -----------------
# 20 932 -----------------
# 20 933 -----------------
# 20 934 -----------------
# 20 935 -----------------
# 20 936 -----------------
# 20 937 -----------------
# 20 938 -----------------
# 20 939 -----------------
# 20 940 -----------------
# 20 941 -----------------
# 20 942 -----------------
# 20 943 -----------------
# 20 944 -----------------
# 20 945 -----------------
# 20 946 -----------------
# 20 947 -----------------
# 20 948 -----------------
# 20 949 -----------------
# 20 950 -----------------
# 20 951 -----------------
# 20 952 -----------------
# 20 953 -----------------
# 20 954 -----------------
# 20 955 -----------------
# 20 956 -----------------
# 20 957 -----------------
# 20 958 -----------------
# 20 959 -----------------
# 20 960 -----------------
# 20 961 -----------------
# 20 962 -----------------
# 20 963 -----------------
# 20 964 -----------------
# 20 965 -----------------
# 20 966 -----------------
# 20 967 -----------------
# 20 968 -----------------
# 20 969 -----------------
# 20 970 -----------------
# 20 971 -----------------
# 20 972 -----------------
# 20 973 -----------------
# 20 974 -----------------
# 20 975 -----------------
# 20 976 -----------------
# 20 977 -----------------
# 20 978 -----------------
# 20 979 -----------------
# 20 980 -----------------
# 20 981 -----------------
# 20 982 -----------------
# 20 983 -----------------
# 20 984 -----------------
# 20 985 -----------------
# 20 986 -----------------
# 20 987 -----------------
# 20 988 -----------------
# 20 989 -----------------
# 20 990 -----------------
# 20 991 -----------------
# 20 992 -----------------
# 20 993 -----------------
# 20 994 -----------------
# 20 995 -----------------
# 20 996 -----------------
# 20 997 -----------------
# 20 998 -----------------
# 20 999 -----------------
# 20 1000 -----------------
# 20 1001 -----------------
# 20 1002 -----------------
# 20 1003 -----------------
# 20 1004 -----------------
# 20 1005 -----------------
# 20 1006 -----------------
# 20 1007 -----------------
# 20 1008 -----------------
# 20 1009 -----------------
# 20 1010 -----------------
# 20 1011 -----------------
# 20 1012 -----------------
# 20 1013 -----------------
# 20 1014 -----------------
# 20 1015 -----------------
# 20 1016 -----------------
# 20 1017 -----------------
# 20 1018 -----------------
# 20 1019 -----------------
# 20 1020 -----------------
# 20 1021 -----------------
# 20 1022 -----------------
# 20 1023 -----------------
# 20 1024 -----------------
# 20 1025 -----------------
# 20 1026 -----------------
# 20 1027 -----------------
# 20 1028 -----------------
# 20 1029 -----------------
# 20 1030 -----------------
# 20 1031 -----------------
# 20 1032 -----------------
# 20 1033 -----------------
# 20 1034 -----------------
# 20 1035 -----------------
# 20 1036 -----------------
# 20 1037 -----------------
# 20 1038 -----------------
# 20 1039 -----------------
# 20 1040 -----------------
# 20 1041 -----------------
# 20 1042 -----------------
# 20 1043 -----------------
# 20 1044 -----------------
# 20 1045 -----------------
# 20 1046 -----------------
# 20 1047 -----------------
# 20 1048 -----------------
# 20 1049 -----------------
# 20 1050 -----------------
# 20 1051 -----------------
# 20 1052 -----------------
# 20 1053 -----------------
# 20 1054 -----------------
# 20 1055 -----------------
# 20 1056 -----------------
# 20 1057 -----------------
# 20 1058 -----------------
# 20 1059 -----------------
# 20 1060 -----------------
# 20 1061 -----------------
# 20 1062 -----------------
# 20 1063 -----------------
# 20 1064 -----------------
# 20 1065 -----------------
# 20 1066 -----------------
# 20 1067 -----------------
# 20 1068 -----------------
# 20 1069 -----------------
# 20 1070 -----------------
# 20 1071 -----------------
# 20 1072 -----------------
# 20 1073 -----------------
# 20 1074 -----------------
# 20 1075 -----------------
# 20 1076 -----------------
# 20 1077 -----------------
# 20 1078 -----------------
# 20 1079 -----------------
# 20 1080 -----------------
# 20 1081 -----------------
# 20 1082 -----------------
# 20 1083 -----------------
# 20 1084 -----------------
# 20 1085 -----------------
# 20 1086 -----------------
# 20 1087 -----------------
# 20 1088 -----------------
# 20 1089 -----------------
# 20 1090 -----------------
# 20 1091 -----------------
# 20 1092 -----------------
# --------------------- 0
# simulation duration :  129.2
# no solution computed yet
# weight =  2484.6074332893318
# set cost params:  1.0 0.0 2484.6074332893318
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12803.272339498173
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12803.272339498173
# Control only changes marginally.
# RUN  1 , total integrated cost =  12803.272339498173
# Improved over  1  iterations in  0.3243882580427453  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  1894.6419189194864 [0.        4.3904845]
# 20 1093 -----------------
# --------------------- 0
# simulation duration :  129.3
# no solution computed yet
# weight =  2484.273687212855
# set cost params:  1.0 0.0 2484.273687212855
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12803.272339498173
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12803.272339498173
# Control only changes marginally.
# RUN  1 , total integrated cost =  12803.272339498173
# Improved over  1  iterations in  0.2854202010203153  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  1896.1072258946754 [0.        4.3904845]
# 20 1094 -----------------
# --------------------- 0
# simulation duration :  129.4
# no solution computed yet
# weight =  2483.9399411363775
# set cost params:  1.0 0.0 2483.9399411363775
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12803.272339498173
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12803.272339498173
# Control only changes marginally.
# RUN  1 , total integrated cost =  12803.272339498173
# Improved over  1  iterations in  0.26596882101148367  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  1897.5725328698645 [0.        4.3904845]
# 20 1095 -----------------
# --------------------- 0
# simulation duration :  129.5
# no solution computed yet
# weight =  2483.6061950599005
# set cost params:  1.0 0.0 2483.6061950599005
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12803.272339498173
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12803.272339498173
# Control only changes marginally.
# RUN  1 , total integrated cost =  12803.272339498173
# Improved over  1  iterations in  0.2555041970917955  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  1899.0378398450537 [0.        4.3904845]
# 20 1096 -----------------
# --------------------- 0
# simulation duration :  129.6
# no solution computed yet
# weight =  2483.2724489834236
# set cost params:  1.0 0.0 2483.2724489834236
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12803.272339498173
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12803.272339498173
# Control only changes marginally.
# RUN  1 , total integrated cost =  12803.272339498173
# Improved over  1  iterations in  0.28561628505121917  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  1900.5031468202426 [0.        4.3904845]
# 20 1097 -----------------
# --------------------- 0
# simulation duration :  129.7
# no solution computed yet
# weight =  2482.9387029069467
# set cost params:  1.0 0.0 2482.9387029069467
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12803.272339498173
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12803.272339498173
# Control only changes marginally.
# RUN  1 , total integrated cost =  12803.272339498173
# Improved over  1  iterations in  0.2625207150122151  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  1901.968453795432 [0.        4.3904845]
# 20 1098 -----------------
# --------------------- 0
# simulation duration :  129.8
# no solution computed yet
# weight =  2482.6049568304693
# set cost params:  1.0 0.0 2482.6049568304693
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12803.272339498171
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12803.272339498171
# Control only changes marginally.
# RUN  1 , total integrated cost =  12803.272339498171
# Improved over  1  iterations in  0.2414290780434385  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  1903.433760770621 [0.        4.3904845]
# 20 1099 -----------------
# --------------------- 0
# simulation duration :  129.9
# no solution computed yet
# weight =  2482.271210753993
# set cost params:  1.0 0.0 2482.271210753993
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12803.272339498173
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12803.272339498173
# Control only changes marginally.
# RUN  1 , total integrated cost =  12803.272339498173
# Improved over  1  iterations in  0.27638629998546094  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  1904.8990677458098 [0.        4.3904845]
# 20 1100 -----------------
# --------------------- 0
# simulation duration :  130.0
# no solution computed yet
# weight =  2481.937464677516
# set cost params:  1.0 0.0 2481.937464677516
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12803.272339498173
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12803.272339498173
# Control only changes marginally.
# RUN  1 , total integrated cost =  12803.272339498173
# Improved over  1  iterations in  0.3019891780568287  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  1906.3643747209992 [0.        4.3904845]
# 20 1101 -----------------
# --------------------- 0
# simulation duration :  130.1
# no solution computed yet
# weight =  2481.603718601039
# set cost params:  1.0 0.0 2481.603718601039
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12803.272339498175
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12803.272339498175
# Control only changes marginally.
# RUN  1 , total integrated cost =  12803.272339498175
# Improved over  1  iterations in  0.2993132589617744  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  1907.8296816961881 [0.        4.3904845]
# 20 1102 -----------------
# --------------------- 0
# simulation duration :  130.2
# no solution computed yet
# weight =  2481.2699725245616
# set cost params:  1.0 0.0 2481.2699725245616
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12803.272339498173
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12803.272339498173
# Control only changes marginally.
# RUN  1 , total integrated cost =  12803.272339498173
# Improved over  1  iterations in  0.2966073539573699  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  1909.2949886713773 [0.        4.3904845]
# 20 1103 -----------------
# --------------------- 0
# simulation duration :  130.3
# no solution computed yet
# weight =  2480.9362264480847
# set cost params:  1.0 0.0 2480.9362264480847
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12803.272339498173
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12803.272339498173
# Control only changes marginally.
# RUN  1 , total integrated cost =  12803.272339498173
# Improved over  1  iterations in  0.31220270099584013  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  1910.7602956465664 [0.        4.3904845]
# 20 1104 -----------------
# --------------------- 0
# simulation duration :  130.4
# no solution computed yet
# weight =  2480.6024803716077
# set cost params:  1.0 0.0 2480.6024803716077
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12803.272339498171
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12803.272339498171
# Control only changes marginally.
# RUN  1 , total integrated cost =  12803.272339498171
# Improved over  1  iterations in  0.28491864900570363  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  1912.2256026217553 [0.        4.3904845]
# 20 1105 -----------------
# --------------------- 0
# simulation duration :  130.5
# no solution computed yet
# weight =  2480.268734295131
# set cost params:  1.0 0.0 2480.268734295131
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12803.272339498173
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12803.272339498173
# Control only changes marginally.
# RUN  1 , total integrated cost =  12803.272339498173
# Improved over  1  iterations in  0.26670284499414265  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  1913.6909095969445 [0.        4.3904845]
# 20 1106 -----------------
# --------------------- 0
# simulation duration :  130.6
# no solution computed yet
# weight =  2479.934988218654
# set cost params:  1.0 0.0 2479.934988218654
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12803.272339498173
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12803.272339498173
# Control only changes marginally.
# RUN  1 , total integrated cost =  12803.272339498173
# Improved over  1  iterations in  0.28123498300556093  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  1915.1562165721334 [0.        4.3904845]
# 20 1107 -----------------
# --------------------- 0
# simulation duration :  130.7
# no solution computed yet
# weight =  2479.601242142177
# set cost params:  1.0 0.0 2479.601242142177
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12803.272339498173
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12803.272339498173
# Control only changes marginally.
# RUN  1 , total integrated cost =  12803.272339498173
# Improved over  1  iterations in  0.3158011579653248  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  1916.6215235473226 [0.        4.3904845]
# 20 1108 -----------------
# --------------------- 0
# simulation duration :  130.8
# no solution computed yet
# weight =  2479.2674960657
# set cost params:  1.0 0.0 2479.2674960657
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12803.272339498173
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12803.272339498173
# Control only changes marginally.
# RUN  1 , total integrated cost =  12803.272339498173
# Improved over  1  iterations in  0.281534309964627  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  1918.0868305225117 [0.        4.3904845]
# 20 1109 -----------------
# --------------------- 0
# simulation duration :  130.9
# no solution computed yet
# weight =  2478.9337499892226
# set cost params:  1.0 0.0 2478.9337499892226
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12803.272339498173
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12803.272339498173
# Control only changes marginally.
# RUN  1 , total integrated cost =  12803.272339498173
# Improved over  1  iterations in  0.27468693198170513  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  1919.5521374977006 [0.        4.3904845]
# 20 1110 -----------------
# --------------------- 0
# simulation duration :  131.0
# no solution computed yet
# weight =  2478.6000039127457
# set cost params:  1.0 0.0 2478.6000039127457
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12803.272339498173
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12803.272339498173
# Control only changes marginally.
# RUN  1 , total integrated cost =  12803.272339498173
# Improved over  1  iterations in  0.32982318894937634  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  1921.01744447289 [0.        4.3904845]
# 20 1111 -----------------
# --------------------- 0
# simulation duration :  131.1
# no solution computed yet
# weight =  2478.2662578362692
# set cost params:  1.0 0.0 2478.2662578362692
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12803.272339498173
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12803.272339498173
# Control only changes marginally.
# RUN  1 , total integrated cost =  12803.272339498173
# Improved over  1  iterations in  0.3007435010513291  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  1922.482751448079 [0.        4.3904845]
# 20 1112 -----------------
# --------------------- 0
# simulation duration :  131.2
# no solution computed yet
# weight =  2477.9325117597923
# set cost params:  1.0 0.0 2477.9325117597923
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12803.272339498173
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12803.272339498173
# Control only changes marginally.
# RUN  1 , total integrated cost =  12803.272339498173
# Improved over  1  iterations in  0.2916428339667618  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  1923.9480584232679 [0.        4.3904845]
# 20 1113 -----------------
# --------------------- 0
# simulation duration :  131.3
# no solution computed yet
# weight =  2477.598765683315
# set cost params:  1.0 0.0 2477.598765683315
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12803.272339498173
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12803.272339498173
# Control only changes marginally.
# RUN  1 , total integrated cost =  12803.272339498173
# Improved over  1  iterations in  0.26206791307777166  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  1925.4133653984572 [0.        4.3904845]
# 20 1114 -----------------
# --------------------- 0
# simulation duration :  131.4
# no solution computed yet
# weight =  2477.265019606838
# set cost params:  1.0 0.0 2477.265019606838
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12803.272339498173
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12803.272339498173
# Control only changes marginally.
# RUN  1 , total integrated cost =  12803.272339498173
# Improved over  1  iterations in  0.35788542800582945  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  1926.8786723736462 [0.        4.3904845]
# 20 1115 -----------------
# --------------------- 0
# simulation duration :  131.5
# no solution computed yet
# weight =  2476.931273530361
# set cost params:  1.0 0.0 2476.931273530361
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12803.272339498173
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12803.272339498173
# Control only changes marginally.
# RUN  1 , total integrated cost =  12803.272339498173
# Improved over  1  iterations in  0.2791081500472501  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  1928.3439793488353 [0.        4.3904845]
# 20 1116 -----------------
# --------------------- 0
# simulation duration :  131.6
# no solution computed yet
# weight =  2476.597527453884
# set cost params:  1.0 0.0 2476.597527453884
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12803.272339498173
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12803.272339498173
# Control only changes marginally.
# RUN  1 , total integrated cost =  12803.272339498173
# Improved over  1  iterations in  0.34353045804891735  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  1929.8092863240245 [0.        4.3904845]
# 20 1117 -----------------
# --------------------- 0
# simulation duration :  131.7
# no solution computed yet
# weight =  2476.2637813774068
# set cost params:  1.0 0.0 2476.2637813774068
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12803.272339498171
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12803.272339498171
# Control only changes marginally.
# RUN  1 , total integrated cost =  12803.272339498171
# Improved over  1  iterations in  0.29071439197286963  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  1931.2745932992134 [0.        4.3904845]
# 20 1118 -----------------
# --------------------- 0
# simulation duration :  131.8
# no solution computed yet
# weight =  2475.9300353009303
# set cost params:  1.0 0.0 2475.9300353009303
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12803.272339498173
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12803.272339498173
# Control only changes marginally.
# RUN  1 , total integrated cost =  12803.272339498173
# Improved over  1  iterations in  0.296340997912921  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  1932.7399002744025 [0.        4.3904845]
# 20 1119 -----------------
# --------------------- 0
# simulation duration :  131.9
# no solution computed yet
# weight =  2475.5962892244534
# set cost params:  1.0 0.0 2475.5962892244534
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12803.272339498173
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12803.272339498173
# Control only changes marginally.
# RUN  1 , total integrated cost =  12803.272339498173
# Improved over  1  iterations in  0.2610887329792604  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  1934.2052072495917 [0.        4.3904845]
# 20 1120 -----------------
# --------------------- 0
# simulation duration :  132.0
# no solution computed yet
# weight =  2475.262543147976
# set cost params:  1.0 0.0 2475.262543147976
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12803.272339498171
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12803.272339498171
# Control only changes marginally.
# RUN  1 , total integrated cost =  12803.272339498171
# Improved over  1  iterations in  0.2479866980575025  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  1935.6705142247808 [0.        4.3904845]
# 20 1121 -----------------
# --------------------- 0
# simulation duration :  132.1
# no solution computed yet
# weight =  2474.928797071499
# set cost params:  1.0 0.0 2474.928797071499
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12803.272339498173
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12803.272339498173
# Control only changes marginally.
# RUN  1 , total integrated cost =  12803.272339498173
# Improved over  1  iterations in  0.32319192797876894  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  1937.1358211999698 [0.        4.3904845]
# 20 1122 -----------------
# --------------------- 0
# simulation duration :  132.2
# no solution computed yet
# weight =  2474.595050995022
# set cost params:  1.0 0.0 2474.595050995022
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12803.272339498171
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12803.272339498171
# Control only changes marginally.
# RUN  1 , total integrated cost =  12803.272339498171
# Improved over  1  iterations in  0.413442745921202  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  1938.6011281751587 [0.        4.3904845]
# 20 1123 -----------------
# --------------------- 0
# simulation duration :  132.3
# no solution computed yet
# weight =  2474.2613049185456
# set cost params:  1.0 0.0 2474.2613049185456
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12803.272339498173
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12803.272339498173
# Control only changes marginally.
# RUN  1 , total integrated cost =  12803.272339498173
# Improved over  1  iterations in  0.2886685049161315  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  1940.066435150348 [0.        4.3904845]
# 20 1124 -----------------
# --------------------- 0
# simulation duration :  132.4
# no solution computed yet
# weight =  2473.9275588420683
# set cost params:  1.0 0.0 2473.9275588420683
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12803.272339498173
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12803.272339498173
# Control only changes marginally.
# RUN  1 , total integrated cost =  12803.272339498173
# Improved over  1  iterations in  0.26153052202425897  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# ...
# RUN  1 , total integrated cost =  12803.272339498173
# Control only changes marginally.
# RUN  1 , total integrated cost =  12803.272339498173
# Improved over  1  iterations in  0.31694966403301805  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  2309.3237928979975 [0.        4.3904845]
# 20 1376 -----------------
# --------------------- 0
# simulation duration :  157.6
# no solution computed yet
# weight =  2389.823547569871
# set cost params:  1.0 0.0 2389.823547569871
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12803.272339498173
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12803.272339498173
# Control only changes marginally.
# RUN  1 , total integrated cost =  12803.272339498173
# Improved over  1  iterations in  0.31195377197582275  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  2310.7890998731864 [0.        4.3904845]
# 20 1377 -----------------
# --------------------- 0
# simulation duration :  157.7
# no solution computed yet
# weight =  2389.489801493394
# set cost params:  1.0 0.0 2389.489801493394
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12803.272339498173
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12803.272339498173
# Control only changes marginally.
# RUN  1 , total integrated cost =  12803.272339498173
# Improved over  1  iterations in  0.32874928298406303  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  2312.2544068483753 [0.        4.3904845]
# 20 1378 -----------------
# --------------------- 0
# simulation duration :  157.8
# no solution computed yet
# weight =  2389.1560554169173
# set cost params:  1.0 0.0 2389.1560554169173
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12803.272339498173
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12803.272339498173
# Control only changes marginally.
# RUN  1 , total integrated cost =  12803.272339498173
# Improved over  1  iterations in  0.30335150205064565  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  2313.7197138235647 [0.        4.3904845]
# 20 1379 -----------------
# --------------------- 0
# simulation duration :  157.9
# no solution computed yet
# weight =  2388.8223093404404
# set cost params:  1.0 0.0 2388.8223093404404
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12803.272339498173
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12803.272339498173
# Control only changes marginally.
# RUN  1 , total integrated cost =  12803.272339498173
# Improved over  1  iterations in  0.3463933099992573  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  2315.1850207987536 [0.        4.3904845]
# 20 1380 -----------------
# --------------------- 0
# simulation duration :  158.0
# no solution computed yet
# weight =  2388.4885632639634
# set cost params:  1.0 0.0 2388.4885632639634
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12803.272339498173
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12803.272339498173
# Control only changes marginally.
# RUN  1 , total integrated cost =  12803.272339498173
# Improved over  1  iterations in  0.3623093510977924  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  2316.650327773943 [0.        4.3904845]
# 20 1381 -----------------
# --------------------- 0
# simulation duration :  158.1
# no solution computed yet
# weight =  2388.154817187486
# set cost params:  1.0 0.0 2388.154817187486
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12803.272339498173
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12803.272339498173
# Control only changes marginally.
# RUN  1 , total integrated cost =  12803.272339498173
# Improved over  1  iterations in  0.31687821995001286  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  2318.115634749132 [0.        4.3904845]
# 20 1382 -----------------
# --------------------- 0
# simulation duration :  158.2
# no solution computed yet
# weight =  2387.821071111009
# set cost params:  1.0 0.0 2387.821071111009
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12803.272339498173
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12803.272339498173
# Control only changes marginally.
# RUN  1 , total integrated cost =  12803.272339498173
# Improved over  1  iterations in  0.30444744694978  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  2319.580941724321 [0.        4.3904845]
# 20 1383 -----------------
# --------------------- 0
# simulation duration :  158.3
# no solution computed yet
# weight =  2387.4873250345327
# set cost params:  1.0 0.0 2387.4873250345327
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12803.272339498173
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12803.272339498173
# Control only changes marginally.
# RUN  1 , total integrated cost =  12803.272339498173
# Improved over  1  iterations in  0.33875339396763593  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  2321.04624869951 [0.        4.3904845]
# 20 1384 -----------------
# --------------------- 0
# simulation duration :  158.4
# no solution computed yet
# weight =  2387.1535789580553
# set cost params:  1.0 0.0 2387.1535789580553
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12803.272339498171
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12803.272339498171
# Control only changes marginally.
# RUN  1 , total integrated cost =  12803.272339498171
# Improved over  1  iterations in  0.3089833869598806  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  2322.511555674699 [0.        4.3904845]
# 20 1385 -----------------
# --------------------- 0
# simulation duration :  158.5
# no solution computed yet
# weight =  2386.8198328815783
# set cost params:  1.0 0.0 2386.8198328815783
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12803.272339498173
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12803.272339498173
# Control only changes marginally.
# RUN  1 , total integrated cost =  12803.272339498173
# Improved over  1  iterations in  0.3350570140173659  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  2323.976862649888 [0.        4.3904845]
# 20 1386 -----------------
# --------------------- 0
# simulation duration :  158.6
# no solution computed yet
# weight =  2386.4860868051014
# set cost params:  1.0 0.0 2386.4860868051014
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12803.272339498173
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12803.272339498173
# Control only changes marginally.
# RUN  1 , total integrated cost =  12803.272339498173
# Improved over  1  iterations in  0.28277602803427726  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  2325.4421696250774 [0.        4.3904845]
# 20 1387 -----------------
# --------------------- 0
# simulation duration :  158.7
# no solution computed yet
# weight =  2386.1523407286245
# set cost params:  1.0 0.0 2386.1523407286245
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12803.272339498173
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12803.272339498173
# Control only changes marginally.
# RUN  1 , total integrated cost =  12803.272339498173
# Improved over  1  iterations in  0.3251024150522426  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  2326.9074766002664 [0.        4.3904845]
# 20 1388 -----------------
# --------------------- 0
# simulation duration :  158.8
# no solution computed yet
# weight =  2385.8185946521476
# set cost params:  1.0 0.0 2385.8185946521476
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12803.272339498173
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12803.272339498173
# Control only changes marginally.
# RUN  1 , total integrated cost =  12803.272339498173
# Improved over  1  iterations in  0.32573781604878604  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  2328.3727835754553 [0.        4.3904845]
# 20 1389 -----------------
# --------------------- 0
# simulation duration :  158.9
# no solution computed yet
# weight =  2385.48484857567
# set cost params:  1.0 0.0 2385.48484857567
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12803.272339498171
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12803.272339498171
# Control only changes marginally.
# RUN  1 , total integrated cost =  12803.272339498171
# Improved over  1  iterations in  0.3318191940197721  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  2329.838090550644 [0.        4.3904845]
# 20 1390 -----------------
# --------------------- 0
# simulation duration :  159.0
# no solution computed yet
# weight =  2385.1511024991937
# set cost params:  1.0 0.0 2385.1511024991937
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12803.272339498173
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12803.272339498173
# Control only changes marginally.
# RUN  1 , total integrated cost =  12803.272339498173
# Improved over  1  iterations in  0.3229565469082445  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  2331.3033975258336 [0.        4.3904845]
# 20 1391 -----------------
# --------------------- 0
# simulation duration :  159.1
# no solution computed yet
# weight =  2384.817356422717
# set cost params:  1.0 0.0 2384.817356422717
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12803.272339498173
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12803.272339498173
# Control only changes marginally.
# RUN  1 , total integrated cost =  12803.272339498173
# Improved over  1  iterations in  0.31176144897472113  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  2332.7687045010225 [0.        4.3904845]
# 20 1392 -----------------
# --------------------- 0
# simulation duration :  159.2
# no solution computed yet
# weight =  2384.48361034624
# set cost params:  1.0 0.0 2384.48361034624
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12803.272339498175
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12803.272339498175
# Control only changes marginally.
# RUN  1 , total integrated cost =  12803.272339498175
# Improved over  1  iterations in  0.33084349404089153  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  2334.2340114762114 [0.        4.3904845]
# 20 1393 -----------------
# --------------------- 0
# simulation duration :  159.3
# no solution computed yet
# weight =  2384.1498642697625
# set cost params:  1.0 0.0 2384.1498642697625
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12803.272339498173
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12803.272339498173
# Control only changes marginally.
# RUN  1 , total integrated cost =  12803.272339498173
# Improved over  1  iterations in  0.29363152605947107  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  2335.699318451401 [0.        4.3904845]
# 20 1394 -----------------
# --------------------- 0
# simulation duration :  159.4
# no solution computed yet
# weight =  2383.8161181932855
# set cost params:  1.0 0.0 2383.8161181932855
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12803.272339498173
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12803.272339498173
# Control only changes marginally.
# RUN  1 , total integrated cost =  12803.272339498173
# Improved over  1  iterations in  0.307710591936484  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  2337.1646254265897 [0.        4.3904845]
# 20 1395 -----------------
# --------------------- 0
# simulation duration :  159.5
# no solution computed yet
# weight =  2383.482372116809
# set cost params:  1.0 0.0 2383.482372116809
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12803.272339498173
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12803.272339498173
# Control only changes marginally.
# RUN  1 , total integrated cost =  12803.272339498173
# Improved over  1  iterations in  0.30885057197883725  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  2338.629932401779 [0.        4.3904845]
# 20 1396 -----------------
# --------------------- 0
# simulation duration :  159.6
# no solution computed yet
# weight =  2383.1486260403317
# set cost params:  1.0 0.0 2383.1486260403317
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12803.272339498173
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12803.272339498173
# Control only changes marginally.
# RUN  1 , total integrated cost =  12803.272339498173
# Improved over  1  iterations in  0.3102476429194212  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  2340.095239376968 [0.        4.3904845]
# 20 1397 -----------------
# --------------------- 0
# simulation duration :  159.7
# no solution computed yet
# weight =  2382.8148799638548
# set cost params:  1.0 0.0 2382.8148799638548
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12803.272339498173
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12803.272339498173
# Control only changes marginally.
# RUN  1 , total integrated cost =  12803.272339498173
# Improved over  1  iterations in  0.3058043950004503  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  2341.560546352157 [0.        4.3904845]
# 20 1398 -----------------
# --------------------- 0
# simulation duration :  159.8
# no solution computed yet
# weight =  2382.481133887378
# set cost params:  1.0 0.0 2382.481133887378
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12803.272339498173
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12803.272339498173
# Control only changes marginally.
# RUN  1 , total integrated cost =  12803.272339498173
# Improved over  1  iterations in  0.3306516499724239  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  2343.0258533273463 [0.        4.3904845]
# 20 1399 -----------------
# --------------------- 0
# simulation duration :  159.9
# no solution computed yet
# weight =  2382.147387810901
# set cost params:  1.0 0.0 2382.147387810901
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12803.272339498173
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12803.272339498173
# Control only changes marginally.
# RUN  1 , total integrated cost =  12803.272339498173
# Improved over  1  iterations in  0.2948118500644341  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  2344.4911603025353 [0.        4.3904845]
# 20 1400 -----------------
# --------------------- 0
# simulation duration :  160.0
# no solution computed yet
# weight =  2381.8136417344235
# set cost params:  1.0 0.0 2381.8136417344235
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12803.272339498173
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12803.272339498173
# Control only changes marginally.
# RUN  1 , total integrated cost =  12803.272339498173
# Improved over  1  iterations in  0.3411198580870405  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  2345.9564672777246 [0.        4.3904845]

# %%
i = 20
for j in [0,200,1000]:
    print("simulation duration = ", round(d_array[j],1))
    aln.params.duration = round(d_array[j],1)
    time_ = np.arange(-dur_pre,round(d_array[j]+dur_post+aln.params.dt,1),aln.params.dt)
    dur += dur_pre + dur_post
    target_e = [target[i][0]] * len(time_)
    target_i = [target[i][1]] * len(time_)

    fig, ax = plt.subplots(2,1, constrained_layout=True, figsize = (4,4) )
    ax[1].plot(time_, bestControl_[i][j][0,0,:], color = 'red')
    ax[0].plot(time_, bestState_[i][j][0,0,:], color= 'red')
    ax[1].plot(time_, bestControl_[i][j][0,1,:], color = 'blue')
    ax[0].plot(time_, bestState_[i][j][0,1,:], color= 'blue')
    ax[0].plot(time_, target_e, linestyle = '--', color='red')
    ax[0].plot(time_, target_i, linestyle = '--', color='blue')
    ax[0].set_xlim(-dur_pre,round(d_array[j]+dur_pre,1))
    ax[1].set_xlim(-dur_pre,round(d_array[j]+dur_pre,1))
    ax[0].axvspan(t0_array[j], t0_array[j]+20, alpha=0.2, color='gray')
    plt.show()
# Out:
# simulation duration =  20.0
# simulation duration =  40.0
# simulation duration =  120.0
