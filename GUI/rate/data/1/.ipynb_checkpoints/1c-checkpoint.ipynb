# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import sys
import pickle

path = os.getcwd().split(os.sep + 'GUI')[0]
if path not in sys.path:
    print("not here")
    sys.path.append(path)

from neurolib.models.aln import ALNModel
from neurolib.utils import plotFunctions as plotFunc
from neurolib.utils import costFunctions as cost
import neurolib.dashboard.functions as functions
import neurolib.dashboard.data as data
    
# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2 

#path = os.path.join(os.getcwd(), "plots")
# Out:
# not here

# %%
grid_data_file = os.path.join(os.getcwd().split('data')[0], 'bi.pickle')
print(grid_data_file)
with open(grid_data_file,'rb') as f:
    load_array= pickle.load(f)
exc = load_array[0]
inh = load_array[1]
print(len(exc))
# Out:
# /home/lena/Promotion/neurolib/GUI/current/gui/bi.pickle
# 147

# %% [markdown]
# ### Bistability

# %%
aln = ALNModel()
N = aln.params.N

data.set_parameters(aln)

state_vars = aln.state_vars
init_vars = aln.init_vars

##############################################################
def setinit(init_vars_, model):
    state_vars = model.state_vars
    init_vars = model.init_vars
    for iv in range(len(init_vars)):
        for sv in range(len(state_vars)):
            if state_vars[sv] in init_vars[iv]:
                #print("set init vars ", )
                if model.params[init_vars[iv]].ndim == 2:
                    model.params[init_vars[iv]][0,:] = init_vars_[sv]
                else:
                    model.params[init_vars[iv]][0] = init_vars_[sv]
                    
##############################################################               
def setmaxmincontrol(max_c_c, min_c_c, max_c_r, min_c_r):
    import numpy as np
    
    max_cntrl = np.zeros(( 6 ))
    min_cntrl = np.zeros(( 6 ))
    
    max_cntrl[0] = max_c_c
    min_cntrl[0] = min_c_c
    max_cntrl[1] = max_c_c
    min_cntrl[1] = min_c_c
    max_cntrl[2] = max_c_r
    min_cntrl[2] = min_c_r
    max_cntrl[3] = max_c_r
    min_cntrl[3] = min_c_r
    max_cntrl[4] = max_c_r
    min_cntrl[4] = min_c_r
    max_cntrl[5] = max_c_r
    min_cntrl[5] = min_c_r
            
    return max_cntrl, min_cntrl

# %%
d_array = np.arange(20., 300, 0.1)
t0_array = d_array - 20.
t_pen = np.zeros(( t0_array.shape ))
for i in range(len(t_pen)):
    t_pen[i] = t0_array[i] / d_array[i]

bestControl_ = np.array( [[None] * len(t_pen)] * len(exc) )
bestState_ = np.array( [[None] * len(t_pen)] * len(exc) )
cost_ = np.array( [[None] * len(t_pen)] * len(exc) )
costnode_ = np.array( [[None] * len(t_pen)] * len(exc) )
weights_ = np.array( [[None] * len(t_pen)] * len(exc) )
convergence_ = np.array( [[None] * len(t_pen)] * len(exc) )

initVars = [None] * len(exc)
target = [None] * len(exc)
cost_uncontrolled = [None] * len(exc)

print(bestControl_.shape)
# Out:
# (147, 2800)

# %%
file_ = '1c.pickle'
case = '1'

# %%
dur_pre = 10
dur_post = 10

n_pre = int(np.around(dur_pre/aln.params.dt + 1.,1))
n_post = int(np.around(dur_post/aln.params.dt + 1.,1))

tol = 1e-32
start_step = 10.
c_scheme = np.zeros(( 1,1 ))
c_scheme[0,0] = 1.
u_mat = np.identity(1)
u_scheme = np.array([[1.]])

c_var = [0,1]
p_var = [0]

if case in ['1', '2']:    # low to high
    max_I = [3., -3.]
else:
    max_I = [-3., 3.]
    
if case in ['1', '3']:    # sparsity
    factor_ws = 1.
    factor_we = 0.
else:
    factor_ws = 0.
    factor_we = 1.
    
maxC = [5., -5., 0.18, 0.]
max_cntrl, min_cntrl = setmaxmincontrol(maxC[0], maxC[1], maxC[2], maxC[3])

# %%
if os.path.isfile(file_) :
    print("file found")
    
    with open(file_,'rb') as f:
        load_array = pickle.load(f)

    bestControl_ = load_array[0]
    bestState_ = load_array[1]
    cost_ = load_array[2]
    costnode_ = load_array[3]
    weights_ = load_array[4]

# %%
# get initial parameters and target states

#i_stepsize = 20
#limit = 150
#start_index = 0
#i_range = range(start_index, limit,i_stepsize)
i_range = [20]

data.set_parameters(aln)

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    aln.params.duration = 3000.
    
    control0 = aln.getZeroControl()
    control0 = functions.step_control(aln, maxI_ = max_I[0])

    aln.run(control=control0)
    
    target_rates = np.zeros((2))
    target_rates[0] = aln.rates_exc[0,-1] 
    target_rates[1] = aln.rates_inh[0,-1]

    control0 = functions.step_control(aln, maxI_ = max_I[1])
    aln.run(control=control0)

    init_state_vars = np.zeros(( len(state_vars) ))
    for j in range(len(state_vars)):
        if aln.state[state_vars[j]].size == 1:
            init_state_vars[j] = aln.state[state_vars[j]][0]
        else:
            init_state_vars[j] = aln.state[state_vars[j]][0,-1]

    initVars[i] = init_state_vars
    target[i] = [target_rates[0], target_rates[1]]
# Out:
# -------  20 0.4500000000000001 0.4750000000000002

# %%
# get uncontrolled cost

data.set_parameters(aln)

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    dur = d_array[0]
    aln.params.duration = dur
    
    target_ = aln.getZeroTarget()
    target_[:,0,:] = target[i][0]
    target_[:,1,:] = target[i][1]
        
    cost.setParams(1.0, 0.0, 0.0)

    setinit(initVars[i], aln)
    control0 = aln.getZeroControl()

    # "HS", "FR", "PR", "HZ"
    cgv = None
    max_it = 0

    bestControl_init_, bestState_init_, cost_init_, runtime_init_, grad_init_, phi_init_, costnode_init_ = aln.A1(
        control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
        prec_variables_ = p_var, transition_time_ = 0.)
    
    cost_uncontrolled[i] = cost_init_[0]
# Out:
# -------  20 0.4500000000000001 0.4750000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  0 , total integrated cost =  12801.807032522984
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.

# %%
cgv = None
j = 0
k = 0

while k < 10:
    print('-------------------------------------------- k = ', k)

    for i in i_range:
        print("------- ", i, exc[i], inh[i])
        aln.params.ext_exc_current = exc[i] * 5.
        aln.params.ext_inh_current = inh[i] * 5.

        if convergence_[i][j] == True:
            print('converged')
            continue

        dur = d_array[0]
        aln.params.duration = dur
        
        setinit(initVars[i], aln)

        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        max_it = int(100)

        if type(bestControl_[i][j]) == type(None) or np.amax(np.abs(bestControl_[i][j])) < 1e-6:
            print('no solution found')
            control0 = aln.getZeroControl()
            #control0[0,0,:50] = 5.
            cost.setParams(1.0, 0., 1.)
            max_it = int(1)
            weights_[i][j] = [1., 0., 1.]
        else:
            control0 = bestControl_[i][j][:,:,n_pre-1:-n_post+1]
            l = 1
            while cost_[i][j][-l] == 0.:
                l += 1

            weight_ = ( cost_uncontrolled[i] - costnode_[i][j][0][0][0] ) / sum( costnode_[i][j][2][0][:] )
                
            print("weight = ", weight_)
            cost.setParams(1.0, weight_ * factor_we, weight_ * factor_ws)
            weights_[i][j] = cost.getParams()

        bestControl_[i][j], bestState_[i][j], cost_[i][j], runtime_, grad_, phi_, costnode_[i][j] = aln.A1(
            control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = [1],
            prec_variables_ = p_var, transition_time_ = t_pen[j])

        #if cost_[i][j][2] == 0.:
        #    print('converged')
        #    convergence_[i][j] = True

        print('uncontrolled cost : ', cost_uncontrolled[i])
        print('cost splitting : ', costnode_[i][j][0][0][0], costnode_[i][j][2][0][:2])

        time_ = np.arange(-dur_pre,dur+dur_post+aln.params.dt,aln.params.dt)
        dur += dur_pre + dur_post
        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        if True:
            fig, ax = plt.subplots(2,1, constrained_layout=True, figsize = (4,4) )
            ax[1].plot(time_, bestControl_[i][j][0,0,:], color = 'red')
            ax[0].plot(time_, bestState_[i][j][0,0,:], color= 'red')
            ax[1].plot(time_, bestControl_[i][j][0,1,:], color = 'blue')
            ax[0].plot(time_, bestState_[i][j][0,1,:], color= 'blue')
            ax[0].plot(time_, target_[0,0,:], linestyle = '--', color='red')
            ax[0].plot(time_, target_[0,1,:], linestyle = '--', color='blue')
            ax[0].set_xlim(-dur_pre,dur-dur_post)
            ax[1].set_xlim(-dur_pre,dur-dur_post)
            ax[0].axvspan(t0_array[0], dur, alpha=0.2, color='gray')
            plt.show()

        with open(file_,'wb') as f:
            pickle.dump([bestControl_, bestState_, cost_, costnode_, weights_], f)
    
    k += 1
# Out:
# -------------------------------------------- k =  0
# -------  20 0.4500000000000001 0.4750000000000002
# no solution found
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  9444.199144044613
# RUN  1 , total integrated cost =  9444.199144044613
# Improved over  1  iterations in  11.895573071902618  seconds by  26.227608961362805  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  9438.294876277036 [0.         5.90426777]
# -------------------------------------------- k =  1
# -------  20 0.4500000000000001 0.4750000000000002
# weight =  569.6747316773378
# set cost params:  1.0 0.0 569.6747316773378
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12772.358064437001
# RUN  2 , total integrated cost =  12749.621242966616
# RUN  3 , total integrated cost =  12732.171609177196
# RUN  4 , total integrated cost =  12719.270884094178
# RUN  5 , total integrated cost =  12709.454637556424
# RUN  6 , total integrated cost =  12701.815254663874
# RUN  7 , total integrated cost =  12695.813125710483
# RUN  8 , total integrated cost =  12691.2970356773
# RUN  9 , total integrated cost =  12687.593093545522
# RUN  10 , total integrated cost =  12684.520484537754
# RUN  11 , total integrated cost =  12681.890836830436
# RUN  12 , total integrated cost =  12679.81879166343
# RUN  13 , total integrated cost =  12678.027251238937
# RUN  14 , total integrated cost =  12676.767103842818
# RUN  15 , total integrated cost =  12675.6045212568
# RUN  16 , total integrated cost =  12674.688012431805
# RUN  17 , total integrated cost =  12673.827156404384
# RUN  18 , total integrated cost =  12673.139336157492
# RUN  19 , total integrated cost =  12672.53599253744
# RUN  20 , total integrated cost =  12672.03426805036
# RUN  30 , total integrated cost =  12669.931611202326
# RUN  40 , total integrated cost =  12669.577455779488
# RUN  50 , total integrated cost =  12669.307427533315
# RUN  60 , total integrated cost =  12669.295640525826
# Control only changes marginally.
# RUN  63 , total integrated cost =  12669.295636811981
# Improved over  63  iterations in  0.6853671509306878  seconds by  1.0350991494744335  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  9339.746496766073 [0.         5.84464951]
# -------------------------------------------- k =  2
# -------  20 0.4500000000000001 0.4750000000000002
# weight =  592.3469886769187
# set cost params:  1.0 0.0 592.3469886769187
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.701855619574
# RUN  2 , total integrated cost =  12801.671802968496
# RUN  3 , total integrated cost =  12801.645871799024
# RUN  4 , total integrated cost =  12801.623668586682
# RUN  5 , total integrated cost =  12801.60645765147
# RUN  6 , total integrated cost =  12801.591388995577
# RUN  7 , total integrated cost =  12801.581351156483
# RUN  8 , total integrated cost =  12801.571089647163
# RUN  9 , total integrated cost =  12801.55958766985
# RUN  10 , total integrated cost =  12801.551476043673
# RUN  11 , total integrated cost =  12801.543800542895
# RUN  12 , total integrated cost =  12801.538986823452
# RUN  13 , total integrated cost =  12801.533734025423
# RUN  14 , total integrated cost =  12801.531193998246
# RUN  15 , total integrated cost =  12801.528260580655
# RUN  16 , total integrated cost =  12801.526379469859
# RUN  17 , total integrated cost =  12801.521544555118
# RUN  18 , total integrated cost =  12801.517850467022
# RUN  19 , total integrated cost =  12801.509300395624
# RUN  20 , total integrated cost =  12801.508315533945
# Control only changes marginally.
# RUN  29 , total integrated cost =  12801.50322642536
# Improved over  29  iterations in  0.3420983349205926  seconds by  0.002373150109605149  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  9356.479817553367 [0.         5.81588744]
# -------------------------------------------- k =  3
# -------  20 0.4500000000000001 0.4750000000000002
# weight =  592.399225949561
# set cost params:  1.0 0.0 592.399225949561
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522982
# RUN  2 , total integrated cost =  12801.807032522982
# Control only changes marginally.
# RUN  2 , total integrated cost =  12801.807032522982
# Improved over  2  iterations in  0.08807190100196749  seconds by  1.4210854715202004e-14  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  9356.47981754994 [0.         5.81588744]
# -------------------------------------------- k =  4
# -------  20 0.4500000000000001 0.4750000000000002
# weight =  592.3992259495612
# set cost params:  1.0 0.0 592.3992259495612
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.06194750498980284  seconds by  0.0  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  9356.47981754994 [0.         5.81588744]
# -------------------------------------------- k =  5
# -------  20 0.4500000000000001 0.4750000000000002
# weight =  592.3992259495612
# set cost params:  1.0 0.0 592.3992259495612
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.06069642398506403  seconds by  0.0  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  9356.47981754994 [0.         5.81588744]
# -------------------------------------------- k =  6
# -------  20 0.4500000000000001 0.4750000000000002
# weight =  592.3992259495612
# set cost params:  1.0 0.0 592.3992259495612
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.058869358035735786  seconds by  0.0  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  9356.47981754994 [0.         5.81588744]
# -------------------------------------------- k =  7
# -------  20 0.4500000000000001 0.4750000000000002
# weight =  592.3992259495612
# set cost params:  1.0 0.0 592.3992259495612
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.058807916007936  seconds by  0.0  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  9356.47981754994 [0.         5.81588744]
# -------------------------------------------- k =  8
# -------  20 0.4500000000000001 0.4750000000000002
# weight =  592.3992259495612
# set cost params:  1.0 0.0 592.3992259495612
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.053772398037835956  seconds by  0.0  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  9356.47981754994 [0.         5.81588744]
# -------------------------------------------- k =  9
# -------  20 0.4500000000000001 0.4750000000000002
# weight =  592.3992259495612
# set cost params:  1.0 0.0 592.3992259495612
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.06513107300270349  seconds by  0.0  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  9356.47981754994 [0.         5.81588744]

# %%
for i in range(bestControl_.shape[0]):
    for j in range(1,bestControl_.shape[1]):
        bestControl_[i][j] = None
        convergence_[i][j] = None

# %%
cost.setParams(1.0, factor_we, factor_ws)

j_start = 1

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.

    for j in range(j_start,j_start+1000):
        print(i,j, '-----------------')
            
        k = 0
        while convergence_[i][j] != True:
            print('---------------------', k)

            dur = round(d_array[j],1)
            print('simulation duration : ', dur)
            aln.params.duration = dur
            max_it = int(100)  
            
            setinit(initVars[i], aln)
            target_ = aln.getZeroTarget()
            target_[:,0,:] = target[i][0]
            target_[:,1,:] = target[i][1]

            if type(bestControl_[i][j]) == type(None):
                print('no solution computed yet')
                control0 = aln.getZeroControl()
                control0[:,:,:-1] = bestControl_[i][j-1][:,:,n_pre-1:-n_post+1]
                                
                #for l in [5,4,3,2,1]:
                #    control0[0,0,l] = 2. * control0[0,0,l+1] - control0[0,0,l+2]
                #    control0[0,1,l] = 2. * control0[0,1,l+1] - control0[0,1,l+2]
                                        
                l = 1
                while cost_[i][j-1][-l] == 0.:
                    l += 1
                    
                weight_ = ( cost_uncontrolled[i] - costnode_[i][j-1][0][0][0] ) / sum( costnode_[i][j-1][2][0][:] )
                #weight_ = (factor_we * weights_[i][j-1][1] * cost_uncontrolled[i] / cost_[i][j-1][-l]
                #           + factor_ws * weights_[i][j-1][2] * cost_uncontrolled[i] / cost_[i][j-1][-l]) - 0.1
            else:
                control0 = bestControl_[i][j][:,:,n_pre-1:-n_post+1]
                l = 1
                while cost_[i][j][-l] == 0.:
                    l += 1
                
                weight_ = ( cost_uncontrolled[i] - costnode_[i][j][0][0][0] ) / sum( costnode_[i][j][2][0][:] )
                #weight_ = (factor_we * weights_[i][j][1] * cost_uncontrolled[i] / cost_[i][j][-l]
                #           + factor_ws * weights_[i][j][2] * cost_uncontrolled[i] / cost_[i][j][-l]) - 0.1
                
            print("weight = ", weight_)
            cost.setParams(1.0, weight_ * factor_we, weight_ * factor_ws)
            weights_[i][j] = cost.getParams()

            bestControl_[i][j], bestState_[i][j], cost_[i][j], runtime_, grad_, phi_, costnode_[i][j] = aln.A1(
                control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
                startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
                t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = [1],
                prec_variables_ = p_var, transition_time_ = t_pen[j])

            if cost_[i][j][2] == 0.:
                print('converged')
                convergence_[i][j] = True

            print('uncontrolled cost : ', cost_uncontrolled[i])
            print('cost splitting : ', costnode_[i][j][0][0][0], costnode_[i][j][2][0][:2])

            time_ = np.arange(-dur_pre,round(dur+dur_post+aln.params.dt,1),aln.params.dt)
            dur += dur_pre + dur_post
            target_ = aln.getZeroTarget()
            target_[:,0,:] = target[i][0]
            target_[:,1,:] = target[i][1]

            if False:
                fig, ax = plt.subplots(2,1, constrained_layout=True, figsize = (4,4) )
                ax[1].plot(time_, bestControl_[i][j][0,0,:], color = 'red')
                ax[0].plot(time_, bestState_[i][j][0,0,:], color= 'red')
                ax[1].plot(time_, bestControl_[i][j][0,1,:], color = 'blue')
                ax[0].plot(time_, bestState_[i][j][0,1,:], color= 'blue')
                ax[0].plot(time_, target_[0,0,:], linestyle = '--', color='red')
                ax[0].plot(time_, target_[0,1,:], linestyle = '--', color='blue')
                ax[0].set_xlim(-dur_pre,dur-dur_post)
                ax[1].set_xlim(-dur_pre,dur-dur_post)
                ax[0].axvspan(t0_array[j], t0_array[j]+20, alpha=0.2, color='gray')
                plt.show()

            with open(file_,'wb') as f:
                pickle.dump([bestControl_, bestState_, cost_, costnode_, weights_], f)
                
            k += 1
# Out:
# set cost params:  1.0 0.0 1.0
# -------  20 0.4500000000000001 0.4750000000000002
# 20 1 -----------------
# 20 2 -----------------
# 20 3 -----------------
# 20 4 -----------------
# 20 5 -----------------
# 20 6 -----------------
# 20 7 -----------------
# 20 8 -----------------
# 20 9 -----------------
# 20 10 -----------------
# 20 11 -----------------
# --------------------- 0
# simulation duration :  21.1
# no solution computed yet
# weight =  638.8538324987841
# set cost params:  1.0 0.0 638.8538324987841
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12777.836529757918
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12777.836470673501
# RUN  2 , total integrated cost =  12777.836470673494
# RUN  3 , total integrated cost =  12777.836470673492
# RUN  4 , total integrated cost =  12777.836470673488
# RUN  5 , total integrated cost =  12777.836470673488
# Control only changes marginally.
# RUN  5 , total integrated cost =  12777.836470673488
# Improved over  5  iterations in  0.09164222795516253  seconds by  4.623977645223931e-07  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  9083.00613583832 [0.         5.78353005]
# --------------------- 1
# simulation duration :  21.1
# weight =  642.9984572628282
# set cost params:  1.0 0.0 642.9984572628282
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.803774241715
# RUN  2 , total integrated cost =  12801.803766672238
# RUN  3 , total integrated cost =  12801.803766633926
# RUN  4 , total integrated cost =  12801.803766633862
# RUN  5 , total integrated cost =  12801.803766633848
# RUN  6 , total integrated cost =  12801.803766633844
# RUN  7 , total integrated cost =  12801.803766633844
# Control only changes marginally.
# RUN  7 , total integrated cost =  12801.803766633844
# Improved over  7  iterations in  0.10112254694104195  seconds by  2.551115737503551e-05  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  9084.048228816608 [0.         5.78190429]
# --------------------- 2
# simulation duration :  21.1
# weight =  642.999022109456
# set cost params:  1.0 0.0 642.999022109456
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522936
# RUN  2 , total integrated cost =  12801.807032522935
# RUN  3 , total integrated cost =  12801.807032522933
# RUN  4 , total integrated cost =  12801.807032522931
# RUN  5 , total integrated cost =  12801.807032522931
# Control only changes marginally.
# RUN  5 , total integrated cost =  12801.807032522931
# Improved over  5  iterations in  0.10630007809959352  seconds by  4.121147867408581e-13  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  9084.04836948432 [0.         5.78190407]
# --------------------- 3
# simulation duration :  21.1
# weight =  642.999022109465
# set cost params:  1.0 0.0 642.999022109465
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.049249344039708376  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  9084.04836948432 [0.         5.78190407]
# 20 12 -----------------
# --------------------- 0
# simulation duration :  21.2
# no solution computed yet
# weight =  642.999022109465
# set cost params:  1.0 0.0 642.999022109465
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12777.218179511525
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12777.218179511525
# Control only changes marginally.
# RUN  1 , total integrated cost =  12777.218179511525
# Improved over  1  iterations in  0.0498212919337675  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  9059.459516472862 [0.         5.78190407]
# 20 13 -----------------
# --------------------- 0
# simulation duration :  21.3
# no solution computed yet
# weight =  647.2517479785076
# set cost params:  1.0 0.0 647.2517479785076
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12776.597550164986
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12776.597163905424
# RUN  2 , total integrated cost =  12776.597163905422
# RUN  3 , total integrated cost =  12776.597163905422
# Control only changes marginally.
# RUN  3 , total integrated cost =  12776.597163905422
# Improved over  3  iterations in  0.09198981407098472  seconds by  3.023180170202977e-06  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  9034.542280338974 [0.         5.78145195]
# --------------------- 1
# simulation duration :  21.3
# weight =  651.6122215783691
# set cost params:  1.0 0.0 651.6122215783691
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.80340348784
# RUN  2 , total integrated cost =  12801.803403487833
# RUN  3 , total integrated cost =  12801.803403487833
# Control only changes marginally.
# RUN  3 , total integrated cost =  12801.803403487833
# Improved over  3  iterations in  0.09429353498853743  seconds by  2.8347835126396603e-05  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  9035.599819959676 [0.         5.77982343]
# --------------------- 2
# simulation duration :  21.3
# weight =  651.6128494583029
# set cost params:  1.0 0.0 651.6128494583029
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522982
# RUN  2 , total integrated cost =  12801.807032522982
# Control only changes marginally.
# RUN  2 , total integrated cost =  12801.807032522982
# Improved over  2  iterations in  0.07717225002124906  seconds by  1.4210854715202004e-14  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  9035.599819961462 [0.         5.77982343]
# --------------------- 3
# simulation duration :  21.3
# weight =  651.612849458303
# set cost params:  1.0 0.0 651.612849458303
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522982
# RUN  2 , total integrated cost =  12801.807032522982
# Control only changes marginally.
# RUN  2 , total integrated cost =  12801.807032522982
# Improved over  2  iterations in  0.09572345810011029  seconds by  1.4210854715202004e-14  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  9035.599819961464 [0.         5.77982343]
# --------------------- 4
# simulation duration :  21.3
# weight =  651.6128494583031
# set cost params:  1.0 0.0 651.6128494583031
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.05792953504715115  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  9035.599819961464 [0.         5.77982343]
# 20 14 -----------------
# --------------------- 0
# simulation duration :  21.4
# no solution computed yet
# weight =  651.6128494583031
# set cost params:  1.0 0.0 651.6128494583031
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12775.979914586835
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12775.979914586835
# Control only changes marginally.
# RUN  1 , total integrated cost =  12775.979914586835
# Improved over  1  iterations in  0.05709556303918362  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  9009.772702025315 [0.         5.77982343]
# 20 15 -----------------
# --------------------- 0
# simulation duration :  21.5
# no solution computed yet
# weight =  656.081345470827
# set cost params:  1.0 0.0 656.081345470827
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12775.359287767973
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12775.35878233146
# RUN  2 , total integrated cost =  12775.358782331452
# RUN  3 , total integrated cost =  12775.358782331452
# Control only changes marginally.
# RUN  3 , total integrated cost =  12775.358782331452
# Improved over  3  iterations in  0.09739663999062032  seconds by  3.956338986199626e-06  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  8983.786936623017 [0.         5.77911851]
# --------------------- 1
# simulation duration :  21.5
# weight =  660.6578652565853
# set cost params:  1.0 0.0 660.6578652565853
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.801603615975
# RUN  2 , total integrated cost =  12801.801592037742
# RUN  3 , total integrated cost =  12801.801591923671
# RUN  4 , total integrated cost =  12801.801591922549
# RUN  5 , total integrated cost =  12801.80159192254
# RUN  6 , total integrated cost =  12801.801591922529
# RUN  7 , total integrated cost =  12801.801591922525
# RUN  8 , total integrated cost =  12801.801591922522
# RUN  9 , total integrated cost =  12801.801591922522
# Control only changes marginally.
# RUN  9 , total integrated cost =  12801.801591922522
# Improved over  9  iterations in  0.1296943969791755  seconds by  4.2498691371406494e-05  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  8985.349611219013 [0.         5.77674494]
# --------------------- 2
# simulation duration :  21.5
# weight =  660.6588070673312
# set cost params:  1.0 0.0 660.6588070673312
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522795
# RUN  2 , total integrated cost =  12801.807032522787
# RUN  3 , total integrated cost =  12801.807032522787
# Control only changes marginally.
# RUN  3 , total integrated cost =  12801.807032522787
# Improved over  3  iterations in  0.09636225504800677  seconds by  1.5347723092418164e-12  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  8985.349885634087 [0.         5.77674453]
# --------------------- 3
# simulation duration :  21.5
# weight =  660.658807067365
# set cost params:  1.0 0.0 660.658807067365
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522982
# RUN  2 , total integrated cost =  12801.807032522982
# Control only changes marginally.
# RUN  2 , total integrated cost =  12801.807032522982
# Improved over  2  iterations in  0.0918877620715648  seconds by  1.4210854715202004e-14  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  8985.349885634087 [0.         5.77674453]
# --------------------- 4
# simulation duration :  21.5
# weight =  660.6588070673653
# set cost params:  1.0 0.0 660.6588070673653
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.05509318097028881  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  8985.349885634087 [0.         5.77674453]
# 20 16 -----------------
# --------------------- 0
# simulation duration :  21.6
# no solution computed yet
# weight =  660.6588070673653
# set cost params:  1.0 0.0 660.6588070673653
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12774.741954725812
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12774.741954725812
# Control only changes marginally.
# RUN  1 , total integrated cost =  12774.741954725812
# Improved over  1  iterations in  0.05579324800055474  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  8958.284807836915 [0.         5.77674453]
# 20 17 -----------------
# --------------------- 0
# simulation duration :  21.7
# no solution computed yet
# weight =  665.3439853157942
# set cost params:  1.0 0.0 665.3439853157942
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12774.119876062972
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12774.118850737228
# RUN  2 , total integrated cost =  12774.118841683268
# RUN  3 , total integrated cost =  12774.118841673333
# RUN  4 , total integrated cost =  12774.118841673235
# RUN  5 , total integrated cost =  12774.118841673233
# RUN  6 , total integrated cost =  12774.118841673233
# Control only changes marginally.
# RUN  6 , total integrated cost =  12774.118841673233
# Improved over  6  iterations in  0.12243432505056262  seconds by  8.097542135487856e-06  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  8931.329010800338 [0.         5.77564375]
# --------------------- 1
# simulation duration :  21.7
# weight =  670.137942845856
# set cost params:  1.0 0.0 670.137942845856
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.801743380802
# RUN  2 , total integrated cost =  12801.801708972616
# RUN  3 , total integrated cost =  12801.80170851011
# RUN  4 , total integrated cost =  12801.801708503514
# RUN  5 , total integrated cost =  12801.801708503368
# RUN  6 , total integrated cost =  12801.801708503366
# RUN  7 , total integrated cost =  12801.801708503366
# Control only changes marginally.
# RUN  7 , total integrated cost =  12801.801708503366
# Improved over  7  iterations in  0.12870092201046646  seconds by  4.1588032090089655e-05  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  8933.020995049957 [0.         5.77311098]
# --------------------- 2
# simulation duration :  21.7
# weight =  670.138865055673
# set cost params:  1.0 0.0 670.138865055673
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522764
# RUN  2 , total integrated cost =  12801.807032522762
# RUN  3 , total integrated cost =  12801.807032522762
# Control only changes marginally.
# RUN  3 , total integrated cost =  12801.807032522762
# Improved over  3  iterations in  0.10612477199174464  seconds by  1.7337242752546445e-12  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  8933.021306697721 [0.         5.77311051]
# --------------------- 3
# simulation duration :  21.7
# weight =  670.1388650557116
# set cost params:  1.0 0.0 670.1388650557116
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.06474254000931978  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  8933.021306697721 [0.         5.77311051]
# 20 18 -----------------
# --------------------- 0
# simulation duration :  21.8
# no solution computed yet
# weight =  670.1388650557116
# set cost params:  1.0 0.0 670.1388650557116
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12773.501286543493
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12773.501286543493
# Control only changes marginally.
# RUN  1 , total integrated cost =  12773.501286543493
# Improved over  1  iterations in  0.05852521490305662  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  8904.71556071823 [0.         5.77311051]
# 20 19 -----------------
# --------------------- 0
# simulation duration :  21.9
# no solution computed yet
# weight =  675.0418971256009
# set cost params:  1.0 0.0 675.0418971256009
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12772.876718313617
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12772.876095814294
# RUN  2 , total integrated cost =  12772.876092372786
# RUN  3 , total integrated cost =  12772.876092372786
# Control only changes marginally.
# RUN  3 , total integrated cost =  12772.876092372786
# Improved over  3  iterations in  0.0935909339459613  seconds by  4.900547040165293e-06  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  8876.162773890208 [0.         5.77255032]
# --------------------- 1
# simulation duration :  21.9
# weight =  680.0537096784991
# set cost params:  1.0 0.0 680.0537096784991
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.801901611374
# RUN  2 , total integrated cost =  12801.801828311187
# RUN  3 , total integrated cost =  12801.801825460656
# RUN  4 , total integrated cost =  12801.801825343204
# RUN  5 , total integrated cost =  12801.801825340784
# RUN  6 , total integrated cost =  12801.801825340724
# RUN  7 , total integrated cost =  12801.801825340724
# Control only changes marginally.
# RUN  7 , total integrated cost =  12801.801825340724
# Improved over  7  iterations in  0.1288142700213939  seconds by  4.067536907825797e-05  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  8877.82725194412 [0.         5.77009509]
# --------------------- 2
# simulation duration :  21.9
# weight =  680.0546121215568
# set cost params:  1.0 0.0 680.0546121215568
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522804
# RUN  2 , total integrated cost =  12801.807032522802
# RUN  3 , total integrated cost =  12801.8070325228
# RUN  4 , total integrated cost =  12801.8070325228
# Control only changes marginally.
# RUN  4 , total integrated cost =  12801.8070325228
# Improved over  4  iterations in  0.1654299789806828  seconds by  1.4352963262354024e-12  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  8877.827570948506 [0.         5.77009462]
# --------------------- 3
# simulation duration :  21.9
# weight =  680.0546121215885
# set cost params:  1.0 0.0 680.0546121215885
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522982
# RUN  2 , total integrated cost =  12801.807032522982
# Control only changes marginally.
# RUN  2 , total integrated cost =  12801.807032522982
# Improved over  2  iterations in  0.0949422309640795  seconds by  1.4210854715202004e-14  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  8877.827570948508 [0.         5.77009462]
# --------------------- 4
# simulation duration :  21.9
# weight =  680.0546121215887
# set cost params:  1.0 0.0 680.0546121215887
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522982
# RUN  2 , total integrated cost =  12801.807032522982
# Control only changes marginally.
# RUN  2 , total integrated cost =  12801.807032522982
# Improved over  2  iterations in  0.09718428004998714  seconds by  1.4210854715202004e-14  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  8877.827570948508 [0.         5.77009462]
# --------------------- 5
# simulation duration :  21.9
# weight =  680.0546121215888
# set cost params:  1.0 0.0 680.0546121215888
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.06529744202271104  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  8877.827570948508 [0.         5.77009462]
# 20 20 -----------------
# --------------------- 0
# simulation duration :  22.0
# no solution computed yet
# weight =  680.0546121215888
# set cost params:  1.0 0.0 680.0546121215888
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12772.254662874366
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12772.254662874366
# Control only changes marginally.
# RUN  1 , total integrated cost =  12772.254662874366
# Improved over  1  iterations in  0.06375054502859712  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  8848.27520129989 [0.         5.77009462]
# 20 21 -----------------
# --------------------- 0
# simulation duration :  22.1
# no solution computed yet
# weight =  685.1762559720387
# set cost params:  1.0 0.0 685.1762559720387
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12771.626955100046
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12771.626233519262
# RUN  2 , total integrated cost =  12771.62623074298
# RUN  3 , total integrated cost =  12771.626230705706
# RUN  4 , total integrated cost =  12771.626230705187
# RUN  5 , total integrated cost =  12771.626230705184
# RUN  6 , total integrated cost =  12771.626230705184
# Control only changes marginally.
# RUN  6 , total integrated cost =  12771.626230705184
# Improved over  6  iterations in  0.11843625199981034  seconds by  5.671907459259273e-06  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  8818.588818518287 [0.         5.76937303]
# --------------------- 1
# simulation duration :  22.1
# weight =  690.4074659595793
# set cost params:  1.0 0.0 690.4074659595793
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.803640942853
# RUN  2 , total integrated cost =  12801.803622738973
# RUN  3 , total integrated cost =  12801.803622713622
# RUN  4 , total integrated cost =  12801.803622713245
# RUN  5 , total integrated cost =  12801.803622713236
# RUN  6 , total integrated cost =  12801.803622713229
# RUN  7 , total integrated cost =  12801.803622713227
# RUN  8 , total integrated cost =  12801.803622713225
# RUN  9 , total integrated cost =  12801.803622713225
# Control only changes marginally.
# RUN  9 , total integrated cost =  12801.803622713225
# Improved over  9  iterations in  0.14509221201296896  seconds by  2.6635378503669926e-05  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  8819.404441140266 [0.         5.76818673]
# --------------------- 2
# simulation duration :  22.1
# weight =  690.4080571002478
# set cost params:  1.0 0.0 690.4080571002478
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.80703252293
# RUN  2 , total integrated cost =  12801.807032522927
# RUN  3 , total integrated cost =  12801.807032522924
# RUN  4 , total integrated cost =  12801.807032522924
# Control only changes marginally.
# RUN  4 , total integrated cost =  12801.807032522924
# Improved over  4  iterations in  0.12976662698201835  seconds by  4.689582056016661e-13  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  8819.40466731147 [0.        5.7681864]
# --------------------- 3
# simulation duration :  22.1
# weight =  690.408057100258
# set cost params:  1.0 0.0 690.408057100258
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.052908487035892904  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  8819.40466731147 [0.        5.7681864]
# 20 22 -----------------
# --------------------- 0
# simulation duration :  22.2
# no solution computed yet
# weight =  690.408057100258
# set cost params:  1.0 0.0 690.408057100258
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12771.00024232705
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12771.00024232705
# Control only changes marginally.
# RUN  1 , total integrated cost =  12771.00024232705
# Improved over  1  iterations in  0.05785234400536865  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  8788.597877115537 [0.        5.7681864]
# 20 23 -----------------
# --------------------- 0
# simulation duration :  22.3
# no solution computed yet
# weight =  695.7488675493648
# set cost params:  1.0 0.0 695.7488675493648
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12770.369222763513
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12770.368628879323
# RUN  2 , total integrated cost =  12770.368622627939
# RUN  3 , total integrated cost =  12770.36862261021
# RUN  4 , total integrated cost =  12770.36862260882
# RUN  5 , total integrated cost =  12770.368622608752
# RUN  6 , total integrated cost =  12770.368622608741
# RUN  7 , total integrated cost =  12770.368622608741
# Control only changes marginally.
# RUN  7 , total integrated cost =  12770.368622608741
# Improved over  7  iterations in  0.1245140889659524  seconds by  4.699588245671293e-06  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  8757.730274620253 [0.         5.76736598]
# --------------------- 1
# simulation duration :  22.3
# weight =  701.1999538916841
# set cost params:  1.0 0.0 701.1999538916841
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.804035670875
# RUN  2 , total integrated cost =  12801.804010206051
# RUN  3 , total integrated cost =  12801.804009301295
# RUN  4 , total integrated cost =  12801.80400926794
# RUN  5 , total integrated cost =  12801.80400926685
# RUN  6 , total integrated cost =  12801.804009266809
# RUN  7 , total integrated cost =  12801.804009266809
# Control only changes marginally.
# RUN  7 , total integrated cost =  12801.804009266809
# Improved over  7  iterations in  0.12250812200363725  seconds by  2.3615854914282863e-05  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  8758.559323093597 [0.         5.76617934]
# --------------------- 2
# simulation duration :  22.3
# weight =  701.2004782000689
# set cost params:  1.0 0.0 701.2004782000689
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522906
# RUN  2 , total integrated cost =  12801.807032522906
# Control only changes marginally.
# RUN  2 , total integrated cost =  12801.807032522906
# Improved over  2  iterations in  0.08048048696946353  seconds by  6.110667527536862e-13  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  8758.559530000666 [0.         5.76617904]
# --------------------- 3
# simulation duration :  22.3
# weight =  701.2004782000824
# set cost params:  1.0 0.0 701.2004782000824
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522982
# RUN  2 , total integrated cost =  12801.807032522982
# Control only changes marginally.
# RUN  2 , total integrated cost =  12801.807032522982
# Improved over  2  iterations in  0.07894547807518393  seconds by  1.4210854715202004e-14  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  8758.559533592734 [0.         5.76617904]
# --------------------- 4
# simulation duration :  22.3
# weight =  701.2004782000827
# set cost params:  1.0 0.0 701.2004782000827
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522982
# RUN  2 , total integrated cost =  12801.80703252298
# RUN  3 , total integrated cost =  12801.807032522978
# RUN  4 , total integrated cost =  12801.807032522978
# Control only changes marginally.
# RUN  4 , total integrated cost =  12801.807032522978
# Improved over  4  iterations in  0.12430601404048502  seconds by  4.263256414560601e-14  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  8758.559562329274 [0.       5.766179]
# --------------------- 5
# simulation duration :  22.3
# weight =  701.2004782000835
# set cost params:  1.0 0.0 701.2004782000835
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.053299790946766734  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  8758.559562329274 [0.       5.766179]
# 20 24 -----------------
# --------------------- 0
# simulation duration :  22.4
# no solution computed yet
# weight =  701.2004782000835
# set cost params:  1.0 0.0 701.2004782000835
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12769.739541475317
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12769.739541475317
# Control only changes marginally.
# RUN  1 , total integrated cost =  12769.739541475317
# Improved over  1  iterations in  0.052991851000115275  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  8726.492071281607 [0.       5.766179]
# 20 25 -----------------
# --------------------- 0
# simulation duration :  22.5
# no solution computed yet
# weight =  706.761785100802
# set cost params:  1.0 0.0 706.761785100802
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12769.105302104064
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12769.104617638928
# RUN  2 , total integrated cost =  12769.10460702154
# RUN  3 , total integrated cost =  12769.10460680787
# RUN  4 , total integrated cost =  12769.104606797919
# RUN  5 , total integrated cost =  12769.104606797811
# RUN  6 , total integrated cost =  12769.1046067978
# RUN  7 , total integrated cost =  12769.104606797797
# RUN  8 , total integrated cost =  12769.104606797795
# RUN  9 , total integrated cost =  12769.104606797795
# Control only changes marginally.
# RUN  9 , total integrated cost =  12769.104606797795
# Improved over  9  iterations in  0.1408386389957741  seconds by  5.445223081324002e-06  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  8694.253943380108 [0.         5.76552206]
# --------------------- 1
# simulation duration :  22.5
# weight =  712.4338518074809
# set cost params:  1.0 0.0 712.4338518074809
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.803450265183
# RUN  2 , total integrated cost =  12801.80341058643
# RUN  3 , total integrated cost =  12801.803409856228
# RUN  4 , total integrated cost =  12801.803409856224
# RUN  5 , total integrated cost =  12801.803409856224
# Control only changes marginally.
# RUN  5 , total integrated cost =  12801.803409856224
# Improved over  5  iterations in  0.10309079196304083  seconds by  2.8298089091549627e-05  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  8695.416821299112 [0.         5.76388471]
# --------------------- 2
# simulation duration :  22.5
# weight =  712.4344803187954
# set cost params:  1.0 0.0 712.4344803187954
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.058208030997775495  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  8695.416821299112 [0.         5.76388471]
# 20 26 -----------------
# --------------------- 0
# simulation duration :  22.6
# no solution computed yet
# weight =  712.4344803187954
# set cost params:  1.0 0.0 712.4344803187954
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12768.473369368048
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12768.473369368046
# RUN  2 , total integrated cost =  12768.473369368046
# Control only changes marginally.
# RUN  2 , total integrated cost =  12768.473369368046
# Improved over  2  iterations in  0.10571972909383476  seconds by  1.4210854715202004e-14  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  8662.083158144298 [0.         5.76388471]
# --------------------- 1
# simulation duration :  22.6
# weight =  718.2176742593031
# set cost params:  1.0 0.0 718.2176742593031
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.805095005575
# RUN  2 , total integrated cost =  12801.805075435754
# RUN  3 , total integrated cost =  12801.80507522122
# RUN  4 , total integrated cost =  12801.805075216325
# RUN  5 , total integrated cost =  12801.805075216258
# RUN  6 , total integrated cost =  12801.805075216245
# RUN  7 , total integrated cost =  12801.805075216242
# RUN  8 , total integrated cost =  12801.805075216242
# Control only changes marginally.
# RUN  8 , total integrated cost =  12801.805075216242
# Improved over  8  iterations in  0.16456374700646847  seconds by  1.528930046390542e-05  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  8663.043028076721 [0.         5.76254553]
# --------------------- 2
# simulation duration :  22.6
# weight =  718.2180139193946
# set cost params:  1.0 0.0 718.2180139193946
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522982
# RUN  2 , total integrated cost =  12801.807032522982
# Control only changes marginally.
# RUN  2 , total integrated cost =  12801.807032522982
# Improved over  2  iterations in  0.09073220705613494  seconds by  1.4210854715202004e-14  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  8663.043028076721 [0.         5.76254553]
# --------------------- 3
# simulation duration :  22.6
# weight =  718.2180139193948
# set cost params:  1.0 0.0 718.2180139193948
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.06089801201596856  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  8663.043028076721 [0.         5.76254553]
# 20 27 -----------------
# --------------------- 0
# simulation duration :  22.7
# no solution computed yet
# weight =  718.2180139193948
# set cost params:  1.0 0.0 718.2180139193948
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12767.838832915035
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12767.838832915033
# RUN  2 , total integrated cost =  12767.838832915033
# Control only changes marginally.
# RUN  2 , total integrated cost =  12767.838832915033
# Improved over  2  iterations in  0.09212141297757626  seconds by  1.4210854715202004e-14  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  8629.074828468772 [0.         5.76254553]
# --------------------- 1
# simulation duration :  22.7
# weight =  724.1126657605314
# set cost params:  1.0 0.0 724.1126657605314
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.804163714518
# RUN  2 , total integrated cost =  12801.804099937042
# RUN  3 , total integrated cost =  12801.80409937715
# RUN  4 , total integrated cost =  12801.804099373809
# RUN  5 , total integrated cost =  12801.804099373758
# RUN  6 , total integrated cost =  12801.804099373756
# RUN  7 , total integrated cost =  12801.804099373756
# Control only changes marginally.
# RUN  7 , total integrated cost =  12801.804099373756
# Improved over  7  iterations in  0.13388238102197647  seconds by  2.291199375292763e-05  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  8630.231051828952 [0.         5.76094473]
# --------------------- 2
# simulation duration :  22.7
# weight =  724.1131749043203
# set cost params:  1.0 0.0 724.1131749043203
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522938
# RUN  2 , total integrated cost =  12801.807032522931
# RUN  3 , total integrated cost =  12801.807032522931
# Control only changes marginally.
# RUN  3 , total integrated cost =  12801.807032522931
# Improved over  3  iterations in  0.08774000802077353  seconds by  4.121147867408581e-13  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  8630.23127463949 [0.         5.76094442]
# --------------------- 3
# simulation duration :  22.7
# weight =  724.1131749043292
# set cost params:  1.0 0.0 724.1131749043292
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522982
# RUN  2 , total integrated cost =  12801.807032522982
# Control only changes marginally.
# RUN  2 , total integrated cost =  12801.807032522982
# Improved over  2  iterations in  0.08049635600764304  seconds by  1.4210854715202004e-14  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  8630.231274641616 [0.         5.76094442]
# --------------------- 4
# simulation duration :  22.7
# weight =  724.1131749043293
# set cost params:  1.0 0.0 724.1131749043293
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522982
# RUN  2 , total integrated cost =  12801.807032522978
# RUN  3 , total integrated cost =  12801.807032522978
# Control only changes marginally.
# RUN  3 , total integrated cost =  12801.807032522978
# Improved over  3  iterations in  0.10488862707279623  seconds by  4.263256414560601e-14  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  8630.231274659143 [0.         5.76094442]
# --------------------- 5
# simulation duration :  22.7
# weight =  724.1131749043302
# set cost params:  1.0 0.0 724.1131749043302
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522982
# RUN  2 , total integrated cost =  12801.807032522982
# Control only changes marginally.
# RUN  2 , total integrated cost =  12801.807032522982
# Improved over  2  iterations in  0.0908325279597193  seconds by  1.4210854715202004e-14  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  8630.231274659143 [0.         5.76094442]
# --------------------- 6
# simulation duration :  22.7
# weight =  724.1131749043304
# set cost params:  1.0 0.0 724.1131749043304
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.054839484044350684  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  8630.231274659143 [0.         5.76094442]
# 20 28 -----------------
# --------------------- 0
# simulation duration :  22.8
# no solution computed yet
# weight =  724.1131749043304
# set cost params:  1.0 0.0 724.1131749043304
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12767.203869692901
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12767.203869692898
# RUN  2 , total integrated cost =  12767.203869692898
# Control only changes marginally.
# RUN  2 , total integrated cost =  12767.203869692898
# Improved over  2  iterations in  0.09526230103801936  seconds by  2.842170943040401e-14  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  8595.628111829326 [0.         5.76094442]
# --------------------- 1
# simulation duration :  22.8
# weight =  730.1196836082397
# set cost params:  1.0 0.0 730.1196836082397
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.803611470055
# RUN  2 , total integrated cost =  12801.803534399025
# RUN  3 , total integrated cost =  12801.803533752685
# RUN  4 , total integrated cost =  12801.80353374337
# RUN  5 , total integrated cost =  12801.8035337433
# RUN  6 , total integrated cost =  12801.803533743296
# RUN  7 , total integrated cost =  12801.803533743292
# RUN  8 , total integrated cost =  12801.803533743292
# Control only changes marginally.
# RUN  8 , total integrated cost =  12801.803533743292
# Improved over  8  iterations in  0.13041449803858995  seconds by  2.7330357994514998e-05  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  8597.091269175364 [0.         5.75893564]
# --------------------- 2
# simulation duration :  22.8
# weight =  730.1202911475341
# set cost params:  1.0 0.0 730.1202911475341
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.80703252288
# RUN  2 , total integrated cost =  12801.807032522876
# RUN  3 , total integrated cost =  12801.807032522873
# RUN  4 , total integrated cost =  12801.80703252287
# RUN  5 , total integrated cost =  12801.80703252287
# Control only changes marginally.
# RUN  5 , total integrated cost =  12801.80703252287
# Improved over  5  iterations in  0.13143632502760738  seconds by  8.952838470577262e-13  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  8597.091535412921 [0.         5.75893527]
# --------------------- 3
# simulation duration :  22.8
# weight =  730.1202911475541
# set cost params:  1.0 0.0 730.1202911475541
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.05890104698482901  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  8597.091535412921 [0.         5.75893527]
# 20 29 -----------------
# --------------------- 0
# simulation duration :  22.9
# no solution computed yet
# weight =  730.1202911475541
# set cost params:  1.0 0.0 730.1202911475541
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12766.56904480795
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12766.56904480795
# Control only changes marginally.
# RUN  1 , total integrated cost =  12766.56904480795
# Improved over  1  iterations in  0.05431440391112119  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  8561.853547697887 [0.         5.75893527]
# 20 30 -----------------
# --------------------- 0
# simulation duration :  23.0
# no solution computed yet
# weight =  736.2391284072065
# set cost params:  1.0 0.0 736.2391284072065
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12765.929768662869
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12765.929125460885
# RUN  2 , total integrated cost =  12765.92912195273
# RUN  3 , total integrated cost =  12765.929121933143
# RUN  4 , total integrated cost =  12765.929121932986
# RUN  5 , total integrated cost =  12765.929121932979
# RUN  6 , total integrated cost =  12765.929121932979
# Control only changes marginally.
# RUN  6 , total integrated cost =  12765.929121932979
# Improved over  6  iterations in  0.12070538906846195  seconds by  5.066061788738807e-06  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  8526.616679149924 [0.         5.75806457]
# --------------------- 1
# simulation duration :  23.0
# weight =  742.4700259827849
# set cost params:  1.0 0.0 742.4700259827849
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.800981289682
# RUN  2 , total integrated cost =  12801.800840449901
# RUN  3 , total integrated cost =  12801.800835271888
# RUN  4 , total integrated cost =  12801.800835146903
# RUN  5 , total integrated cost =  12801.800835143413
# RUN  6 , total integrated cost =  12801.800835143325
# RUN  7 , total integrated cost =  12801.800835143325
# Control only changes marginally.
# RUN  7 , total integrated cost =  12801.800835143325
# Improved over  7  iterations in  0.11221542104613036  seconds by  4.8410194295911424e-05  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  8528.466682792538 [0.         5.75556454]
# --------------------- 2
# simulation duration :  23.0
# weight =  742.4711027459099
# set cost params:  1.0 0.0 742.4711027459099
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522698
# RUN  2 , total integrated cost =  12801.807032522682
# RUN  3 , total integrated cost =  12801.807032522682
# Control only changes marginally.
# RUN  3 , total integrated cost =  12801.807032522682
# Improved over  3  iterations in  0.088801070000045  seconds by  2.3590018827235326e-12  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  8528.46710453715 [0.         5.75556397]
# --------------------- 3
# simulation duration :  23.0
# weight =  742.4711027459624
# set cost params:  1.0 0.0 742.4711027459624
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.08165114594157785  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  8528.46710453715 [0.         5.75556397]
# 20 31 -----------------
# --------------------- 0
# simulation duration :  23.1
# no solution computed yet
# weight =  742.4711027459624
# set cost params:  1.0 0.0 742.4711027459624
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12765.297046212318
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12765.297046212318
# Control only changes marginally.
# RUN  1 , total integrated cost =  12765.297046212318
# Improved over  1  iterations in  0.06136163603514433  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  8491.957118226484 [0.         5.75556397]
# 20 32 -----------------
# --------------------- 0
# simulation duration :  23.2
# no solution computed yet
# weight =  748.8145273866736
# set cost params:  1.0 0.0 748.8145273866736
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12764.657148873264
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12764.656635833202
# RUN  2 , total integrated cost =  12764.656629572502
# RUN  3 , total integrated cost =  12764.65662943725
# RUN  4 , total integrated cost =  12764.656629435616
# RUN  5 , total integrated cost =  12764.65662943559
# RUN  6 , total integrated cost =  12764.656629435583
# RUN  7 , total integrated cost =  12764.65662943558
# RUN  8 , total integrated cost =  12764.65662943558
# Control only changes marginally.
# RUN  8 , total integrated cost =  12764.65662943558
# Improved over  8  iterations in  0.14159765001386404  seconds by  4.069343020773886e-06  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  8455.411318433718 [0.         5.75475656]
# ...
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.0718979430384934  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  3.0202771487792313 [0.         3.72654856]
# 20 956 -----------------
# --------------------- 0
# simulation duration :  115.6
# no solution computed yet
# weight =  3434.4881195274384
# set cost params:  1.0 0.0 3434.4881195274384
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.67439884218
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.672193026743
# RUN  2 , total integrated cost =  12801.672191964964
# RUN  3 , total integrated cost =  12801.672191960082
# RUN  4 , total integrated cost =  12801.672191960077
# RUN  5 , total integrated cost =  12801.672191960068
# RUN  6 , total integrated cost =  12801.672191960068
# Control only changes marginally.
# RUN  6 , total integrated cost =  12801.672191960068
# Improved over  6  iterations in  0.21271276695188135  seconds by  1.723901142725026e-05  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  2.9974371704306435 [0.         3.72651595]
# --------------------- 1
# simulation duration :  115.6
# weight =  3434.5243036105753
# set cost params:  1.0 0.0 3434.5243036105753
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522844
# RUN  2 , total integrated cost =  12801.807032522835
# RUN  3 , total integrated cost =  12801.807032522831
# RUN  4 , total integrated cost =  12801.807032522831
# Control only changes marginally.
# RUN  4 , total integrated cost =  12801.807032522831
# Improved over  4  iterations in  0.22715126804541796  seconds by  1.1937117960769683e-12  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  2.997463954978751 [0.         3.72651594]
# --------------------- 2
# simulation duration :  115.6
# weight =  3434.5243036106162
# set cost params:  1.0 0.0 3434.5243036106162
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.0954382480122149  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  2.997463954978751 [0.         3.72651594]
# 20 957 -----------------
# --------------------- 0
# simulation duration :  115.7
# no solution computed yet
# weight =  3434.5243036106162
# set cost params:  1.0 0.0 3434.5243036106162
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.675387605997
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.673157732075
# RUN  2 , total integrated cost =  12801.673157732073
# RUN  3 , total integrated cost =  12801.673157732073
# Control only changes marginally.
# RUN  3 , total integrated cost =  12801.673157732073
# Improved over  3  iterations in  0.17897265905048698  seconds by  1.741861012760637e-05  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  2.9731880111729017 [0.         3.72648403]
# --------------------- 1
# simulation duration :  115.7
# weight =  3434.5602288392806
# set cost params:  1.0 0.0 3434.5602288392806
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.07608358911238611  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  2.9731880111729017 [0.         3.72648403]
# 20 958 -----------------
# --------------------- 0
# simulation duration :  115.8
# no solution computed yet
# weight =  3434.5602288392806
# set cost params:  1.0 0.0 3434.5602288392806
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.676440157275
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.674155887998
# RUN  2 , total integrated cost =  12801.674155887991
# RUN  3 , total integrated cost =  12801.674155887988
# RUN  4 , total integrated cost =  12801.674155887988
# Control only changes marginally.
# RUN  4 , total integrated cost =  12801.674155887988
# Improved over  4  iterations in  0.17723335605114698  seconds by  1.7843516815219118e-05  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  2.9499444595544997 [0.         3.72645211]
# --------------------- 1
# simulation duration :  115.8
# weight =  3434.5958865187777
# set cost params:  1.0 0.0 3434.5958865187777
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.0754786980105564  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  2.9499444595544997 [0.         3.72645211]
# 20 959 -----------------
# --------------------- 0
# simulation duration :  115.9
# no solution computed yet
# weight =  3434.5958865187777
# set cost params:  1.0 0.0 3434.5958865187777
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.677447925433
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.675176976418
# RUN  2 , total integrated cost =  12801.675176976416
# RUN  3 , total integrated cost =  12801.675176976416
# Control only changes marginally.
# RUN  3 , total integrated cost =  12801.675176976416
# Improved over  3  iterations in  0.14144014206249267  seconds by  1.773946442540364e-05  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  2.9277402580644507 [0.         3.72642018]
# --------------------- 1
# simulation duration :  115.9
# weight =  3434.6312704905367
# set cost params:  1.0 0.0 3434.6312704905367
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522982
# RUN  2 , total integrated cost =  12801.807032522982
# Control only changes marginally.
# RUN  2 , total integrated cost =  12801.807032522982
# Improved over  2  iterations in  0.11570333095733076  seconds by  1.4210854715202004e-14  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  2.9277402584016285 [0.         3.72642018]
# --------------------- 2
# simulation duration :  115.9
# weight =  3434.631270490537
# set cost params:  1.0 0.0 3434.631270490537
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.06965843494981527  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  2.9277402584016285 [0.         3.72642018]
# 20 960 -----------------
# --------------------- 0
# simulation duration :  116.0
# no solution computed yet
# weight =  3434.631270490537
# set cost params:  1.0 0.0 3434.631270490537
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.678410679742
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.676142528206
# RUN  2 , total integrated cost =  12801.676142528204
# RUN  3 , total integrated cost =  12801.676142528204
# Control only changes marginally.
# RUN  3 , total integrated cost =  12801.676142528204
# Improved over  3  iterations in  0.13978075794875622  seconds by  1.7717610660383798e-05  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  2.9065204717608815 [0.         3.72638825]
# --------------------- 1
# simulation duration :  116.0
# weight =  3434.6663956535285
# set cost params:  1.0 0.0 3434.6663956535285
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.80703252298
# RUN  2 , total integrated cost =  12801.80703252298
# Control only changes marginally.
# RUN  2 , total integrated cost =  12801.80703252298
# Improved over  2  iterations in  0.12214533193036914  seconds by  2.842170943040401e-14  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  2.906520471778506 [0.         3.72638825]
# --------------------- 2
# simulation duration :  116.0
# weight =  3434.6663956535294
# set cost params:  1.0 0.0 3434.6663956535294
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.07496647606603801  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  2.906520471778506 [0.         3.72638825]
# 20 961 -----------------
# --------------------- 0
# simulation duration :  116.1
# no solution computed yet
# weight =  3434.6663956535294
# set cost params:  1.0 0.0 3434.6663956535294
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.679330728866
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.677155747755
# RUN  2 , total integrated cost =  12801.677155747751
# RUN  3 , total integrated cost =  12801.67715574775
# RUN  4 , total integrated cost =  12801.67715574775
# Control only changes marginally.
# RUN  4 , total integrated cost =  12801.67715574775
# Improved over  4  iterations in  0.17548256099689752  seconds by  1.6989810944778583e-05  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  2.8863484475551764 [0.         3.72635631]
# --------------------- 1
# simulation duration :  116.1
# weight =  3434.7012492113527
# set cost params:  1.0 0.0 3434.7012492113527
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.07006966404151171  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  2.8863484475551764 [0.         3.72635631]
# 20 962 -----------------
# --------------------- 0
# simulation duration :  116.2
# no solution computed yet
# weight =  3434.7012492113527
# set cost params:  1.0 0.0 3434.7012492113527
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.680205425593
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.678130119162
# RUN  2 , total integrated cost =  12801.678129524662
# RUN  3 , total integrated cost =  12801.678129523696
# RUN  4 , total integrated cost =  12801.678129523694
# RUN  5 , total integrated cost =  12801.678129523692
# RUN  6 , total integrated cost =  12801.67812952369
# RUN  7 , total integrated cost =  12801.67812952369
# Control only changes marginally.
# RUN  7 , total integrated cost =  12801.67812952369
# Improved over  7  iterations in  0.27628371794708073  seconds by  1.621585502675771e-05  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  2.8597901881466625 [0.         3.72632652]
# --------------------- 1
# simulation duration :  116.2
# weight =  3434.73584172458
# set cost params:  1.0 0.0 3434.73584172458
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522867
# RUN  2 , total integrated cost =  12801.807032522858
# RUN  3 , total integrated cost =  12801.807032522856
# RUN  4 , total integrated cost =  12801.807032522853
# RUN  5 , total integrated cost =  12801.807032522853
# Control only changes marginally.
# RUN  5 , total integrated cost =  12801.807032522853
# Improved over  5  iterations in  0.26584383903536946  seconds by  1.0231815394945443e-12  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  2.8598148026397174 [0.         3.72632651]
# --------------------- 2
# simulation duration :  116.2
# weight =  3434.735841724615
# set cost params:  1.0 0.0 3434.735841724615
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.0821572319837287  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  2.8598148026397174 [0.         3.72632651]
# 20 963 -----------------
# --------------------- 0
# simulation duration :  116.3
# no solution computed yet
# weight =  3434.735841724615
# set cost params:  1.0 0.0 3434.735841724615
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.681357175907
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.679025147272
# RUN  2 , total integrated cost =  12801.679025147268
# RUN  3 , total integrated cost =  12801.679025147268
# Control only changes marginally.
# RUN  3 , total integrated cost =  12801.679025147268
# Improved over  3  iterations in  0.1642458930145949  seconds by  1.8216580883745337e-05  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  2.841582705854276 [0.         3.72629455]
# --------------------- 1
# simulation duration :  116.3
# weight =  3434.7701941822775
# set cost params:  1.0 0.0 3434.7701941822775
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.07493976899422705  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  2.841582705854276 [0.         3.72629455]
# 20 964 -----------------
# --------------------- 0
# simulation duration :  116.4
# no solution computed yet
# weight =  3434.7701941822775
# set cost params:  1.0 0.0 3434.7701941822775
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.68214771834
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.679940485063
# RUN  2 , total integrated cost =  12801.679938232222
# RUN  3 , total integrated cost =  12801.679938228499
# RUN  4 , total integrated cost =  12801.679938228493
# RUN  5 , total integrated cost =  12801.679938228488
# RUN  6 , total integrated cost =  12801.679938228486
# RUN  7 , total integrated cost =  12801.679938228486
# Control only changes marginally.
# RUN  7 , total integrated cost =  12801.679938228486
# Improved over  7  iterations in  0.2280432479456067  seconds by  1.7259371304589877e-05  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  2.8183605175259365 [0.         3.72626431]
# --------------------- 1
# simulation duration :  116.4
# weight =  3434.80430187943
# set cost params:  1.0 0.0 3434.80430187943
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522902
# RUN  2 , total integrated cost =  12801.807032522898
# RUN  3 , total integrated cost =  12801.807032522893
# RUN  4 , total integrated cost =  12801.807032522893
# Control only changes marginally.
# RUN  4 , total integrated cost =  12801.807032522893
# Improved over  4  iterations in  0.1721949599450454  seconds by  7.105427357601002e-13  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  2.8183861041084857 [0.        3.7262643]

# %%
i = 20
for j in [0,1,10]:
    print("simulation duration = ", round(d_array[j],1))
    aln.params.duration = round(d_array[j],1)
    time_ = np.arange(-dur_pre,round(d_array[j]+dur_post+aln.params.dt,1),aln.params.dt)
    dur += dur_pre + dur_post
    target_e = [target[i][0]] * len(time_)
    target_i = [target[i][1]] * len(time_)

    fig, ax = plt.subplots(2,1, constrained_layout=True, figsize = (4,4) )
    ax[1].plot(time_, bestControl_[i][j][0,0,:], color = 'red')
    ax[0].plot(time_, bestState_[i][j][0,0,:], color= 'red')
    ax[1].plot(time_, bestControl_[i][j][0,1,:], color = 'blue')
    ax[0].plot(time_, bestState_[i][j][0,1,:], color= 'blue')
    ax[0].plot(time_, target_e, linestyle = '--', color='red')
    ax[0].plot(time_, target_i, linestyle = '--', color='blue')
    ax[0].set_xlim(-dur_pre,round(d_array[j]+dur_pre,1))
    ax[1].set_xlim(-dur_pre,round(d_array[j]+dur_pre,1))
    ax[0].axvspan(t0_array[j], t0_array[j]+20, alpha=0.2, color='gray')
    plt.show()
# Out:
# simulation duration =  20.0
# simulation duration =  20.1
# simulation duration =  21.0
