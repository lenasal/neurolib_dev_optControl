# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import sys
import pickle

path = os.getcwd().split(os.sep + 'GUI')[0]
if path not in sys.path:
    print("not here")
    sys.path.append(path)

from neurolib.models.aln import ALNModel
from neurolib.utils import plotFunctions as plotFunc
from neurolib.utils import costFunctions as cost
import neurolib.dashboard.functions as functions
import neurolib.dashboard.data as data
    
# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2 

#path = os.path.join(os.getcwd(), "plots")
# Out:
# not here

# %%
grid_data_file = os.path.join(os.getcwd().split('data')[0], 'bi.pickle')
print(grid_data_file)
with open(grid_data_file,'rb') as f:
    load_array= pickle.load(f)
exc = load_array[0]
inh = load_array[1]
print(len(exc))
# Out:
# /home/lena/Promotion/neurolib/GUI/rate/bi.pickle
# 147

# %%
aln = ALNModel()
N = aln.params.N

data.set_parameters(aln)

state_vars = aln.state_vars
init_vars = aln.init_vars

##############################################################
def setinit(init_vars_, model):
    state_vars = model.state_vars
    init_vars = model.init_vars
    for iv in range(len(init_vars)):
        for sv in range(len(state_vars)):
            if state_vars[sv] in init_vars[iv]:
                #print("set init vars ", )
                if model.params[init_vars[iv]].ndim == 2:
                    model.params[init_vars[iv]][0,:] = init_vars_[sv]
                else:
                    model.params[init_vars[iv]][0] = init_vars_[sv]
                    
##############################################################               
def setmaxmincontrol(max_c_c, min_c_c, max_c_r, min_c_r):
    import numpy as np
    
    max_cntrl = np.zeros(( 6 ))
    min_cntrl = np.zeros(( 6 ))
    
    max_cntrl[0] = max_c_c
    min_cntrl[0] = min_c_c
    max_cntrl[1] = max_c_c
    min_cntrl[1] = min_c_c
    max_cntrl[2] = max_c_r
    min_cntrl[2] = min_c_r
    max_cntrl[3] = max_c_r
    min_cntrl[3] = min_c_r
    max_cntrl[4] = max_c_r
    min_cntrl[4] = min_c_r
    max_cntrl[5] = max_c_r
    min_cntrl[5] = min_c_r
            
    return max_cntrl, min_cntrl

# %%
dur = 500.
t0_ = dur - 20.
t_pen = t0_/dur

# %%
bestControl_ = [None] * len(exc) 
bestState_ = [None] * len(exc) 
cost_ = [None] * len(exc) 
costnode_ = [None] * len(exc) 
weights_ = [None] * len(exc) 
convergence_ = [None] * len(exc) 

initVars = [None] * len(exc)
target = [None] * len(exc)
cost_uncontrolled = [None] * len(exc)
ws = [None] * len(exc)
conv = [None] * len(exc)
conv_shift = [None] * len(exc)

# %%
file_ = '1_I.pickle'
folder = str(os.getcwd().split('data')[1])
print(folder)
case = str(folder[1])
# Out:
# /1

# %%
dur_pre = 10
dur_post = 10

n_pre = int(np.around(dur_pre/aln.params.dt + 1.,1))
n_post = int(np.around(dur_post/aln.params.dt + 1.,1))

tol = 1e-12
start_step = 10.
c_scheme = np.zeros(( 1,1 ))
c_scheme[0,0] = 1.
u_mat = np.identity(1)
u_scheme = np.array([[1.]])

if 'E' in file_:
    if case in ['1', '2']:
        c_var = [2]
    else:
        c_var = [3]
elif 'I' in file_:
    if case in ['1', '2']:
        c_var = [5]
    else:
        c_var = [4]
    
    
p_var = [0]

if case in ['1', '2']:    # low to high
    max_I = [3., -3.]
else:
    max_I = [-3., 3.]
    
if case in ['1', '3']:    # sparsity
    factor_ws = 1.
    factor_we = 0.
    cost_index = 2
else:
    factor_ws = 0.
    factor_we = 1.
    cost_index = 1
    
maxC = [5., -5., 0.5, 0.]
max_cntrl, min_cntrl = setmaxmincontrol(maxC[0], maxC[1], maxC[2], maxC[3])

# %%
if os.path.isfile(file_) :
    print("file found")
    
    with open(file_,'rb') as f:
        load_array = pickle.load(f)

    bestControl_ = load_array[0]
    bestState_ = load_array[1]
    cost_ = load_array[2]
    costnode_ = load_array[3]
    weights_ = load_array[4]
# Out:
# file found

# %%
# get initial parameters and target states

i_range = np.arange(0, 83, 12)
i_range = np.arange(6, 70, 12)
print(i_range)
#i_range = [50]

data.set_parameters(aln)

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    aln.params.duration = 3000.
    
    control0 = aln.getZeroControl()
    control0 = functions.step_control(aln, maxI_ = max_I[0])

    aln.run(control=control0)
    
    target_rates = np.zeros((2))
    target_rates[0] = aln.rates_exc[0,-1] 
    target_rates[1] = aln.rates_inh[0,-1]

    control0 = functions.step_control(aln, maxI_ = max_I[1])
    aln.run(control=control0)

    init_state_vars = np.zeros(( len(state_vars) ))
    for j in range(len(state_vars)):
        if aln.state[state_vars[j]].size == 1:
            init_state_vars[j] = aln.state[state_vars[j]][0]
        else:
            init_state_vars[j] = aln.state[state_vars[j]][0,-1]

    initVars[i] = init_state_vars
    target[i] = [target_rates[0], target_rates[1]]
# Out:
# [ 6 18 30 42 54 66]
# -------  6 0.4250000000000001 0.40000000000000013
# -------  18 0.4000000000000001 0.4750000000000002
# -------  30 0.4250000000000001 0.5250000000000002
# -------  42 0.4250000000000001 0.5750000000000003
# -------  54 0.5750000000000002 0.6000000000000003
# -------  66 0.5250000000000001 0.6500000000000004

# %%
# get uncontrolled cost

data.set_parameters(aln)

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    aln.params.duration = dur
    
    target_ = aln.getZeroTarget()
    target_[:,0,:] = target[i][0]
    target_[:,1,:] = target[i][1]
            
    cost.setParams(1.0, 0.0, 0.0)

    setinit(initVars[i], aln)
    control0 = aln.getZeroControl()

    # "HS", "FR", "PR", "HZ"
    cgv = None
    max_it = 0

    bestControl_init_, bestState_init_, cost_init_, runtime_init_, grad_init_, phi_init_, phi1_, costnode_init_ = aln.A1(
        control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
        prec_variables_ = p_var, transition_time_ = t_pen)
    
    cost_uncontrolled[i] = cost_init_[0]
# Out:
# -------  6 0.4250000000000001 0.40000000000000013
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  234849.86448361105
# RUN  0 , total integrated cost =  234849.86448361105
# Gradient descend method:  None
# RUN  0 , total integrated cost =  234849.86448361105
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  18 0.4000000000000001 0.4750000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  91340.63373509991
# RUN  0 , total integrated cost =  91340.63373509991
# Gradient descend method:  None
# RUN  0 , total integrated cost =  91340.63373509991
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  30 0.4250000000000001 0.5250000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  198505.2946572739
# RUN  0 , total integrated cost =  198505.2946572739
# Gradient descend method:  None
# RUN  0 , total integrated cost =  198505.2946572739
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  42 0.4250000000000001 0.5750000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  187081.7746701702
# RUN  0 , total integrated cost =  187081.7746701702
# Gradient descend method:  None
# RUN  0 , total integrated cost =  187081.7746701702
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  54 0.5750000000000002 0.6000000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  870523.2701234882
# RUN  0 , total integrated cost =  870523.2701234882
# Gradient descend method:  None
# RUN  0 , total integrated cost =  870523.2701234882
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  66 0.5250000000000001 0.6500000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  615596.4660225171
# RUN  0 , total integrated cost =  615596.4660225171
# Gradient descend method:  None
# RUN  0 , total integrated cost =  615596.4660225171
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.

# %%
bad = []

# %%
cgv = None
j = 0
c_var = [5]

wp = 1.

for i in i_range:

    print("------- ", i, exc[i], inh[i])
    
    if type(bestControl_[i]) != type(None) or i in bad:
        continue
        
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
        
    found_exponent = False
    found_digit_0 = False
    found_digit_1 = False
    exponent = 5
    sig_digit = [1., 0.]
    
    while not found_digit_1:
        
        if exponent < -10:
            bad.append(i)
            break
        
        ws[i] = sig_digit[0] * 10**exponent + sig_digit[1] * 10**(exponent-1.)
    
        aln.params.duration = dur
        setinit(initVars[i], aln)

        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        control0 = aln.getZeroControl()
        if i == 12:
            control0[:,5,-1100:-800] = 0.04
        
        cost.setParams(wp, 0., ws[i])
        max_it = int(10)
        if found_digit_0:
            max_it = int(100)

        bestControl_[i], bestState_[i], cost_[i], runtime_, grad_, phi_, phi1_, costnode_[i] = aln.A1(
            control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
            prec_variables_ = p_var, transition_time_ = t_pen)
        
        if True:
            plot_time_array = np.arange(0.,round(dur+aln.params.dt,1),aln.params.dt)
            target_ = aln.getZeroTarget()
            target_[:,0,:] = target[i][0]
            target_[:,1,:] = target[i][1]

            fig, ax = plt.subplots(3,1, constrained_layout=True, figsize = (4,8) )

            ax[0].plot(plot_time_array, bestState_[i][0,0,n_pre-1:-n_post+1], color= 'red')
            ax[0].plot(plot_time_array, bestState_[i][0,1,n_pre-1:-n_post+1], color= 'blue')
            ax[0].plot(plot_time_array, target_[0,0,n_pre-1:-n_post+1], linestyle = '--', color='red')
            ax[0].plot(plot_time_array, target_[0,1,n_pre-1:-n_post+1], linestyle = '--', color='blue')

            ax[1].plot(plot_time_array, bestControl_[i][0,3,n_pre-1:-n_post+1], color = 'blue')
            ax[1].plot(plot_time_array, bestControl_[i][0,2,n_pre-1:-n_post+1], color = 'red')

            ax[2].plot(plot_time_array, bestControl_[i][0,4,n_pre-1:-n_post+1], color = 'red')
            ax[2].plot(plot_time_array, bestControl_[i][0,5,n_pre-1:-n_post+1], color = 'blue')

            for k in range(3):
                ax[k].set_xlim(0.,dur)
                ax[k].axvspan(dur*t_pen, dur, alpha=0.2, color='gray')
            plt.show()
        
        if found_exponent == False and cost_[i][-1] == 0.:
            exponent -= 1
            continue
        elif found_exponent == False and found_digit_0 == False:
            found_exponent = True
            sig_digit[0] = 9.
        elif found_exponent == True and found_digit_0 == False and cost_[i][-1] == 0.:
            sig_digit[0] -= 1.
        elif found_exponent == True and found_digit_0 == False:
            found_digit_0 = True
            sig_digit[1] = 9.
        elif found_exponent == True and found_digit_0 == True and found_digit_1 == False and cost_[i][-1] == 0.:
            sig_digit[1] -= 1.
        elif found_exponent == True and found_digit_0 == True and found_digit_1 == False:
            print("sparsity weight = ", ws[i])
            
            if True:
                plot_time_array = np.arange(0.,round(dur+aln.params.dt,1),aln.params.dt)
                target_ = aln.getZeroTarget()
                target_[:,0,:] = target[i][0]
                target_[:,1,:] = target[i][1]

                fig, ax = plt.subplots(3,1, constrained_layout=True, figsize = (4,8) )
                
                ax[0].plot(plot_time_array, bestState_[i][0,0,n_pre-1:-n_post+1], color= 'red')
                ax[0].plot(plot_time_array, bestState_[i][0,1,n_pre-1:-n_post+1], color= 'blue')
                ax[0].plot(plot_time_array, target_[0,0,n_pre-1:-n_post+1], linestyle = '--', color='red')
                ax[0].plot(plot_time_array, target_[0,1,n_pre-1:-n_post+1], linestyle = '--', color='blue')
                
                ax[1].plot(plot_time_array, bestControl_[i][0,3,n_pre-1:-n_post+1], color = 'blue')
                ax[1].plot(plot_time_array, bestControl_[i][0,2,n_pre-1:-n_post+1], color = 'red')

                ax[2].plot(plot_time_array, bestControl_[i][0,4,n_pre-1:-n_post+1], color = 'red')
                ax[2].plot(plot_time_array, bestControl_[i][0,5,n_pre-1:-n_post+1], color = 'blue')
                
                for k in range(3):
                    ax[k].set_xlim(0.,dur)
                    ax[k].axvspan(dur*t_pen, dur, alpha=0.2, color='gray')
                plt.show()
                
            with open(file_,'wb') as f:
                pickle.dump([bestControl_, bestState_, cost_, costnode_, weights_], f)

            print('uncontrolled cost : ', cost_uncontrolled[i])
            print('cost splitting : ', costnode_[i][0][0][0], costnode_[i][cost_index][0][2:])    

            break
# Out:
# -------  6 0.4250000000000001 0.40000000000000013
# -------  18 0.4000000000000001 0.4750000000000002
# -------  30 0.4250000000000001 0.5250000000000002
# -------  42 0.4250000000000001 0.5750000000000003
# -------  54 0.5750000000000002 0.6000000000000003
# -------  66 0.5250000000000001 0.6500000000000004
# set cost params:  1.0 0.0 100000.0
# interpolate adjoint :  True True True
# initial cost =  615596.4660225171
# RUN  0 , total integrated cost =  615596.4660225171
# Gradient descend method:  None
# RUN  1 , total integrated cost =  615596.4660225171
# Control only changes marginally.
# RUN  1 , total integrated cost =  615596.4660225171
# Improved over  1  iterations in  0.22527406198787503  seconds by  0.0  percent.
# set cost params:  1.0 0.0 10000.0
# interpolate adjoint :  True True True
# initial cost =  615596.4660225171
# RUN  0 , total integrated cost =  615596.4660225171
# Gradient descend method:  None
# RUN  1 , total integrated cost =  615596.4660225171
# Control only changes marginally.
# RUN  1 , total integrated cost =  615596.4660225171
# Improved over  1  iterations in  0.15320885099936277  seconds by  0.0  percent.
# set cost params:  1.0 0.0 1000.0
# interpolate adjoint :  True True True
# initial cost =  615596.4660225171
# RUN  0 , total integrated cost =  615596.4660225171
# Gradient descend method:  None
# RUN  1 , total integrated cost =  615596.4660225171
# Control only changes marginally.
# RUN  1 , total integrated cost =  615596.4660225171
# Improved over  1  iterations in  0.1531209209933877  seconds by  0.0  percent.
# set cost params:  1.0 0.0 100.0
# interpolate adjoint :  True True True
# initial cost =  615596.4660225171
# RUN  0 , total integrated cost =  615596.4660225171
# Gradient descend method:  None
# RUN  1 , total integrated cost =  615596.4660225171
# Control only changes marginally.
# RUN  1 , total integrated cost =  615596.4660225171
# Improved over  1  iterations in  0.23448200902203098  seconds by  0.0  percent.
# set cost params:  1.0 0.0 10.0
# interpolate adjoint :  True True True
# initial cost =  615596.4660225171
# RUN  0 , total integrated cost =  615596.4660225171
# Gradient descend method:  None
# RUN  1 , total integrated cost =  615596.4660225171
# Control only changes marginally.
# RUN  1 , total integrated cost =  615596.4660225171
# Improved over  1  iterations in  0.17158474601455964  seconds by  0.0  percent.
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  615596.4660225171
# RUN  0 , total integrated cost =  615596.4660225171
# Gradient descend method:  None
# RUN  1 , total integrated cost =  615595.7843367076
# RUN  2 , total integrated cost =  615595.7427796881
# RUN  3 , total integrated cost =  615595.7419289195
# RUN  4 , total integrated cost =  615595.741863326
# RUN  5 , total integrated cost =  615595.7418610513
# RUN  6 , total integrated cost =  615595.741861051
# RUN  7 , total integrated cost =  615595.741861051
# Control only changes marginally.
# RUN  7 , total integrated cost =  615595.741861051
# Improved over  7  iterations in  0.6731390240020119  seconds by  0.00011763574127598986  percent.
# set cost params:  1.0 0.0 0.1
# interpolate adjoint :  True True True
# initial cost =  615596.4660225171
# RUN  0 , total integrated cost =  615596.4660225171
# Gradient descend method:  None
# RUN  1 , total integrated cost =  615594.6904996571
# RUN  2 , total integrated cost =  615594.6904996571
# Control only changes marginally.
# RUN  2 , total integrated cost =  615594.6904996571
# Improved over  2  iterations in  0.4866326809860766  seconds by  0.000288423172960961  percent.
# set cost params:  1.0 0.0 0.01
# interpolate adjoint :  True True True
# initial cost =  615596.4660225171
# RUN  0 , total integrated cost =  615596.4660225171
# Gradient descend method:  None
# RUN  1 , total integrated cost =  615594.5132375968
# RUN  2 , total integrated cost =  615594.5132375968
# Control only changes marginally.
# RUN  2 , total integrated cost =  615594.5132375968
# Improved over  2  iterations in  0.43556142901070416  seconds by  0.0003172183448185706  percent.
# set cost params:  1.0 0.0 0.001
# interpolate adjoint :  True True True
# initial cost =  615596.4660225171
# RUN  0 , total integrated cost =  615596.4660225171
# Gradient descend method:  None
# RUN  1 , total integrated cost =  615594.4955113909
# RUN  2 , total integrated cost =  615594.4955113909
# Control only changes marginally.
# RUN  2 , total integrated cost =  615594.4955113909
# Improved over  2  iterations in  0.448263009020593  seconds by  0.0003200978619872785  percent.
# set cost params:  1.0 0.0 0.0001
# interpolate adjoint :  True True True
# initial cost =  615596.4660225171
# RUN  0 , total integrated cost =  615596.4660225171
# Gradient descend method:  None
# RUN  1 , total integrated cost =  615594.4937387703
# RUN  2 , total integrated cost =  615594.4937387703
# Control only changes marginally.
# RUN  2 , total integrated cost =  615594.4937387703
# Improved over  2  iterations in  0.4463523860031273  seconds by  0.0003203858136942017  percent.
# set cost params:  1.0 0.0 1e-05
# interpolate adjoint :  True True True
# initial cost =  615596.4660225171
# RUN  0 , total integrated cost =  615596.4660225171
# Gradient descend method:  None
# RUN  1 , total integrated cost =  615594.4935615083
# RUN  2 , total integrated cost =  615594.4935615083
# Control only changes marginally.
# RUN  2 , total integrated cost =  615594.4935615083
# Improved over  2  iterations in  0.4475493589998223  seconds by  0.00032041460886489403  percent.
# set cost params:  1.0 0.0 1e-06
# interpolate adjoint :  True True True
# initial cost =  615596.4660225171
# RUN  0 , total integrated cost =  615596.4660225171
# Gradient descend method:  None
# RUN  1 , total integrated cost =  615594.493543782
# RUN  2 , total integrated cost =  615594.493543782
# Control only changes marginally.
# RUN  2 , total integrated cost =  615594.493543782
# Improved over  2  iterations in  0.4864148030173965  seconds by  0.00032041748838196327  percent.
# set cost params:  1.0 0.0 1e-07
# interpolate adjoint :  True True True
# initial cost =  615596.4660225171
# RUN  0 , total integrated cost =  615596.4660225171
# Gradient descend method:  None
# RUN  1 , total integrated cost =  615594.4935420094
# RUN  2 , total integrated cost =  615594.4935420094
# Control only changes marginally.
# RUN  2 , total integrated cost =  615594.4935420094
# Improved over  2  iterations in  0.49154886801261455  seconds by  0.0003204177763507232  percent.
# set cost params:  1.0 0.0 1e-08
# interpolate adjoint :  True True True
# initial cost =  615596.4660225171
# RUN  0 , total integrated cost =  615596.4660225171
# Gradient descend method:  None
# RUN  1 , total integrated cost =  615594.4935418321
# RUN  2 , total integrated cost =  615594.4935418321
# Control only changes marginally.
# RUN  2 , total integrated cost =  615594.4935418321
# Improved over  2  iterations in  0.42451901599997655  seconds by  0.00032041780514191487  percent.
# set cost params:  1.0 0.0 1e-09
# interpolate adjoint :  True True True
# initial cost =  615596.4660225171
# RUN  0 , total integrated cost =  615596.4660225171
# Gradient descend method:  None
# RUN  1 , total integrated cost =  615594.4935418144
# RUN  2 , total integrated cost =  615594.4935418144
# Control only changes marginally.
# RUN  2 , total integrated cost =  615594.4935418144
# Improved over  2  iterations in  0.5521735439833719  seconds by  0.0003204178080125075  percent.
# set cost params:  1.0 0.0 1e-10
# interpolate adjoint :  True True True
# initial cost =  615596.4660225171
# RUN  0 , total integrated cost =  615596.4660225171
# Gradient descend method:  None
# RUN  1 , total integrated cost =  615594.4935418126
# RUN  2 , total integrated cost =  615594.4935418126
# Control only changes marginally.
# RUN  2 , total integrated cost =  615594.4935418126
# Improved over  2  iterations in  0.5337869839859195  seconds by  0.00032041780831093547  percent.

# %%
conv = [None] * len(exc)
c_var = [2,3,4,5]

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    k = 0
    if i in bad:
        continue
        
    while not conv[i]:
        max_it = min(1000, int(100*k))
        
        if k == 0:
            max_it = 100
            weight_ = ws[i]
        else:
            weight_ = ( cost_uncontrolled[i] - costnode_[i][0][0][0] ) / sum( costnode_[i][2][0][:] )
            if k < 10:
                weight_ = ws[i] + 0.2 * (weight_ - ws[i])
            
        aln.params.duration = dur
        cost.setParams(1., weight_ * factor_we, weight_ * factor_ws)
        weights_[i] = cost.getParams()

        setinit(initVars[i], aln)

        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        control0 = aln.getZeroControl()
        control0 = bestControl_[i][:,:,n_pre-1:-n_post+1]

        bestControl_[i], bestState_[i], cost_[i], runtime_, grad_, phi_, phi1_, costnode_[i] = aln.A1(
            control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
            prec_variables_ = p_var, transition_time_ = t_pen)
        
        if cost_[i][2] == 0.:
            conv[i] = True

        #print('uncontrolled cost : ', cost_uncontrolled[i])
        print('cost splitting : ', costnode_[i][0][0][0], costnode_[i][cost_index][0][2:])

        if True:
            plot_time_array = np.arange(0.,round(dur+aln.params.dt,1),aln.params.dt)
            target_ = aln.getZeroTarget()
            target_[:,0,:] = target[i][0]
            target_[:,1,:] = target[i][1]

            fig, ax = plt.subplots(3,1, constrained_layout=True, figsize = (4,8) )

            ax[0].plot(plot_time_array, bestState_[i][0,0,n_pre-1:-n_post+1], color= 'red')
            ax[0].plot(plot_time_array, bestState_[i][0,1,n_pre-1:-n_post+1], color= 'blue')
            ax[0].plot(plot_time_array, target_[0,0,n_pre-1:-n_post+1], linestyle = '--', color='red')
            ax[0].plot(plot_time_array, target_[0,1,n_pre-1:-n_post+1], linestyle = '--', color='blue')

            ax[1].plot(plot_time_array, bestControl_[i][0,3,n_pre-1:-n_post+1], color = 'blue')
            ax[1].plot(plot_time_array, bestControl_[i][0,2,n_pre-1:-n_post+1], color = 'red')

            ax[2].plot(plot_time_array, bestControl_[i][0,4,n_pre-1:-n_post+1], color = 'red')
            ax[2].plot(plot_time_array, bestControl_[i][0,5,n_pre-1:-n_post+1], color = 'blue')

            for k in range(3):
                ax[k].set_xlim(0.,dur)
                ax[k].axvspan(dur*t_pen, dur, alpha=0.2, color='gray')
            plt.show()
            
        if np.amax(np.abs(bestControl_[i])) > 1e-4:
            with open(file_,'wb') as f:
                pickle.dump([bestControl_, bestState_, cost_, costnode_, weights_], f)
        
        k += 1
# Out:
# -------  6 0.4250000000000001 0.40000000000000013
# set cost params:  1.0 0.0 110000.0
# interpolate adjoint :  True True True
# initial cost =  234849.86448361105
# RUN  0 , total integrated cost =  234849.86448361105
# Gradient descend method:  None
# RUN  1 , total integrated cost =  8937.136131478233
# RUN  2 , total integrated cost =  8163.454789853554
# RUN  3 , total integrated cost =  3462.653373634607
# RUN  4 , total integrated cost =  3318.928267705388
# RUN  5 , total integrated cost =  3261.6398007071875
# RUN  6 , total integrated cost =  3182.76526411719
# RUN  7 , total integrated cost =  3146.0099143295624
# RUN  8 , total integrated cost =  3101.7468035476795
# RUN  9 , total integrated cost =  3077.8683778424115
# RUN  10 , total integrated cost =  3050.0902874881176
# RUN  11 , total integrated cost =  3034.1340979235983
# RUN  12 , total integrated cost =  3016.162666577325
# RUN  13 , total integrated cost =  3004.749687645268
# RUN  14 , total integrated cost =  2992.13835958625
# RUN  15 , total integrated cost =  2983.465682190641
# RUN  16 , total integrated cost =  2973.774328089706
# RUN  17 , total integrated cost =  2966.738460768656
# RUN  18 , total integrated cost =  2959.001769347085
# RUN  19 , total integrated cost =  2953.5665634928873
# RUN  20 , total integrated cost =  2947.5071727074937
# RUN  30 , total integrated cost =  2910.071610696896
# RUN  40 , total integrated cost =  2886.5632369960376
# RUN  50 , total integrated cost =  2865.8615681732017
# RUN  60 , total integrated cost =  2700.956797685786
# RUN  70 , total integrated cost =  2671.825215821076
# RUN  80 , total integrated cost =  2669.0752864815645
# RUN  90 , total integrated cost =  2641.4596109477443
# RUN  100 , total integrated cost =  2621.622713282887
# RUN  100 , total integrated cost =  2621.622713282887
# Improved over  100  iterations in  97.13098319500568  seconds by  98.8837026927619  percent.
# cost splitting :  0.8036326687867011 [0.02365116 0.         0.         0.        ]
# set cost params:  1.0 0.0 2073940.9689795473
# interpolate adjoint :  True True True
# initial cost =  49071.109312930785
# RUN  0 , total integrated cost =  49071.109312930785
# Gradient descend method:  None
# RUN  1 , total integrated cost =  48480.31672074849
# RUN  2 , total integrated cost =  48446.459369820965
# RUN  3 , total integrated cost =  48407.73097001133
# RUN  4 , total integrated cost =  48300.223941481665
# RUN  5 , total integrated cost =  48206.12078220242
# RUN  6 , total integrated cost =  48170.261619224024
# RUN  7 , total integrated cost =  48144.081237640086
# RUN  8 , total integrated cost =  48064.15358610773
# RUN  9 , total integrated cost =  48025.74008394586
# RUN  10 , total integrated cost =  48023.05943147366
# RUN  11 , total integrated cost =  48020.24073644901
# RUN  12 , total integrated cost =  48019.41857157725
# RUN  13 , total integrated cost =  48018.42344055926
# RUN  14 , total integrated cost =  48017.783577541275
# RUN  15 , total integrated cost =  48016.94906038288
# RUN  16 , total integrated cost =  48016.36489613057
# RUN  17 , total integrated cost =  48015.60115003886
# RUN  18 , total integrated cost =  48015.02745211603
# RUN  19 , total integrated cost =  48014.18630845063
# RUN  20 , total integrated cost =  48013.51296764947
# RUN  30 , total integrated cost =  47952.17009916023
# RUN  40 , total integrated cost =  47901.539758279796
# RUN  50 , total integrated cost =  47880.90348590795
# RUN  60 , total integrated cost =  47861.61553927026
# RUN  70 , total integrated cost =  47849.32295596792
# RUN  80 , total integrated cost =  47739.28032841956
# RUN  90 , total integrated cost =  47732.55876589256
# RUN  100 , total integrated cost =  47726.62084499366
# RUN  110 , total integrated cost =  47636.8301482542
# RUN  120 , total integrated cost =  47597.05741056456
# RUN  130 , total integrated cost =  47594.70244598628
# RUN  140 , total integrated cost =  47574.82584165238
# RUN  150 , total integrated cost =  47571.446897735754
# RUN  160 , total integrated cost =  47569.47132979641
# RUN  170 , total integrated cost =  47565.148066552436
# RUN  180 , total integrated cost =  47541.48876779392
# RUN  190 , total integrated cost =  47529.56967321203
# RUN  200 , total integrated cost =  47496.27548714704
# RUN  300 , total integrated cost =  47441.72452136131
# RUN  300 , total integrated cost =  47441.72452136131
# Improved over  300  iterations in  354.0861614710011  seconds by  3.320456403744089  percent.
# cost splitting :  6.408334229594835 [0.02279828 0.         0.         0.        ]
# set cost params:  1.0 0.0 2148185.9775085826
# interpolate adjoint :  True True True
# initial cost =  49134.38281485039
# RUN  0 , total integrated cost =  49134.38281485039
# Gradient descend method:  None
# RUN  1 , total integrated cost =  49134.285087823744
# RUN  2 , total integrated cost =  49134.247290808955
# RUN  3 , total integrated cost =  49134.16540455536
# RUN  4 , total integrated cost =  49134.11742484262
# RUN  5 , total integrated cost =  49133.88859423888
# RUN  6 , total integrated cost =  49133.69577096127
# RUN  7 , total integrated cost =  49132.65096346977
# RUN  8 , total integrated cost =  49131.62563620147
# RUN  9 , total integrated cost =  49129.59234052522
# RUN  10 , total integrated cost =  49127.225879212885
# RUN  11 , total integrated cost =  49118.50665542606
# RUN  12 , total integrated cost =  49113.32001730602
# RUN  13 , total integrated cost =  49113.24346564998
# RUN  14 , total integrated cost =  49113.19251941585
# RUN  15 , total integrated cost =  49087.664142088404
# RUN  16 , total integrated cost =  49081.895338244045
# RUN  17 , total integrated cost =  49076.01149879964
# RUN  18 , total integrated cost =  49075.134332856214
# RUN  19 , total integrated cost =  49075.0860587934
# RUN  20 , total integrated cost =  49074.99512019544
# RUN  30 , total integrated cost =  49069.93916256674
# RUN  40 , total integrated cost =  49021.793352334214
# RUN  50 , total integrated cost =  49012.95789940281
# RUN  60 , total integrated cost =  49009.80245125258
# RUN  70 , total integrated cost =  48996.30217861124
# RUN  80 , total integrated cost =  48992.48475678974
# RUN  90 , total integrated cost =  48988.29084703478
# RUN  100 , total integrated cost =  48986.68623835103
# RUN  110 , total integrated cost =  48985.9593718293
# RUN  120 , total integrated cost =  48985.02810057043
# RUN  130 , total integrated cost =  48984.30555360439
# RUN  140 , total integrated cost =  48965.80196874146
# RUN  150 , total integrated cost =  48939.210057171134
# RUN  160 , total integrated cost =  48935.47865549291
# RUN  170 , total integrated cost =  48934.064009767724
# RUN  180 , total integrated cost =  48928.96596951216
# RUN  190 , total integrated cost =  48928.26625240826
# RUN  200 , total integrated cost =  48926.93558711105
# RUN  300 , total integrated cost =  48875.11055096402
# RUN  300 , total integrated cost =  48875.11055096402
# Improved over  300  iterations in  356.4597553269996  seconds by  0.5276799036295472  percent.
# cost splitting :  4.501907401429822 [0.02269966 0.         0.         0.        ]
# set cost params:  1.0 0.0 2157152.742779942
# interpolate adjoint :  True True True
# initial cost =  49078.653111911844
# RUN  0 , total integrated cost =  49078.653111911844
# Gradient descend method:  None
# RUN  1 , total integrated cost =  49078.263317074154
# RUN  2 , total integrated cost =  49077.90117763517
# RUN  3 , total integrated cost =  49077.86702691093
# RUN  4 , total integrated cost =  49077.82100608038
# RUN  5 , total integrated cost =  49077.81069110183
# RUN  6 , total integrated cost =  49077.77430143567
# RUN  7 , total integrated cost =  49077.75248113839
# RUN  8 , total integrated cost =  49048.67580272999
# RUN  9 , total integrated cost =  49046.23617093321
# RUN  10 , total integrated cost =  49045.609217505575
# RUN  11 , total integrated cost =  49045.0317393892
# RUN  12 , total integrated cost =  49044.98076178338
# RUN  13 , total integrated cost =  49044.91020381053
# RUN  14 , total integrated cost =  49044.87464461137
# RUN  15 , total integrated cost =  49044.79085621558
# RUN  16 , total integrated cost =  49044.73035010547
# RUN  17 , total integrated cost =  49044.32123285601
# RUN  18 , total integrated cost =  49044.01678003456
# RUN  19 , total integrated cost =  49043.4270885368
# RUN  20 , total integrated cost =  49042.92913392188
# RUN  30 , total integrated cost =  49039.18072167755
# RUN  40 , total integrated cost =  49038.70829031504
# RUN  50 , total integrated cost =  49014.42263565221
# RUN  60 , total integrated cost =  49007.114724380954
# RUN  70 , total integrated cost =  49005.02363963001
# RUN  80 , total integrated cost =  49004.077429147495
# RUN  90 , total integrated cost =  49003.06227012332
# RUN  100 , total integrated cost =  49000.07728511989
# RUN  110 , total integrated cost =  48995.00089871308
# RUN  120 , total integrated cost =  48994.24111891012
# RUN  130 , total integrated cost =  48993.98569739618
# RUN  140 , total integrated cost =  48990.66463625859
# RUN  150 , total integrated cost =  48978.108008643976
# RUN  160 , total integrated cost =  48970.56886157066
# RUN  170 , total integrated cost =  48969.314449976104
# RUN  180 , total integrated cost =  48968.28976346591
# RUN  190 , total integrated cost =  48967.14470822741
# RUN  200 , total integrated cost =  48966.7144254166
# RUN  300 , total integrated cost =  48939.569746638655
# RUN  300 , total integrated cost =  48939.569746638655
# Improved over  300  iterations in  324.30447367500165  seconds by  0.2833887167931124  percent.
# cost splitting :  3.464556632147446 [0.02264715 0.         0.         0.        ]
# set cost params:  1.0 0.0 2161959.527555917
# interpolate adjoint :  True True True
# initial cost =  49048.429739793086
# RUN  0 , total integrated cost =  49048.429739793086
# Gradient descend method:  None
# RUN  1 , total integrated cost =  49048.42730069297
# RUN  2 , total integrated cost =  49048.42186910329
# RUN  3 , total integrated cost =  49048.40678474712
# RUN  4 , total integrated cost =  49048.40432786166
# RUN  5 , total integrated cost =  49048.39919686062
# RUN  6 , total integrated cost =  49048.3835245031
# RUN  7 , total integrated cost =  49048.38107268609
# RUN  8 , total integrated cost =  49048.37422319302
# RUN  9 , total integrated cost =  49048.35756161068
# RUN  10 , total integrated cost =  49048.35473170373
# RUN  11 , total integrated cost =  49048.339225366486
# RUN  12 , total integrated cost =  49048.31059371399
# RUN  13 , total integrated cost =  49048.30769541641
# RUN  14 , total integrated cost =  49047.99594298308
# RUN  15 , total integrated cost =  49047.70685857711
# RUN  16 , total integrated cost =  49047.69538931016
# RUN  17 , total integrated cost =  49047.67543747277
# RUN  18 , total integrated cost =  49047.6718847596
# RUN  19 , total integrated cost =  49047.63392268004
# RUN  20 , total integrated cost =  49047.605516593656
# RUN  30 , total integrated cost =  49047.33727727685
# RUN  40 , total integrated cost =  49038.83108855599
# RUN  50 , total integrated cost =  49037.23940187582
# RUN  60 , total integrated cost =  49025.72535507243
# RUN  70 , total integrated cost =  49023.14019054971
# RUN  80 , total integrated cost =  49019.97662157814
# RUN  90 , total integrated cost =  49019.80146339123
# RUN  100 , total integrated cost =  49018.8891904942
# RUN  110 , total integrated cost =  49018.492915797
# RUN  120 , total integrated cost =  49017.82977042033
# RUN  130 , total integrated cost =  49016.89960408668
# RUN  140 , total integrated cost =  49016.57155750637
# RUN  150 , total integrated cost =  49012.056764378285
# RUN  160 , total integrated cost =  49011.09780412449
# RUN  170 , total integrated cost =  49010.66991160719
# RUN  180 , total integrated cost =  49008.78419039252
# RUN  190 , total integrated cost =  49006.84250891793
# RUN  200 , total integrated cost =  49006.575279367215
# RUN  300 , total integrated cost =  48998.75341038507
# RUN  300 , total integrated cost =  48998.75341038507
# Improved over  300  iterations in  297.8500503099931  seconds by  0.10128016263018935  percent.
# cost splitting :  3.0028587638555195 [0.02262949 0.         0.         0.        ]
# set cost params:  1.0 0.0 2163582.4944333234
# interpolate adjoint :  True True True
# initial cost =  49035.480322343734
# RUN  0 , total integrated cost =  49035.480322343734
# Gradient descend method:  None
# RUN  1 , total integrated cost =  49035.458178527304
# RUN  2 , total integrated cost =  49035.455413185344
# RUN  3 , total integrated cost =  49031.09984668055
# RUN  4 , total integrated cost =  49028.69899497134
# RUN  5 , total integrated cost =  49027.18837993614
# RUN  6 , total integrated cost =  49025.849307253935
# RUN  7 , total integrated cost =  49007.07000584206
# RUN  8 , total integrated cost =  49004.398053783785
# RUN  9 , total integrated cost =  49004.38370844232
# RUN  10 , total integrated cost =  49004.35531613989
# RUN  11 , total integrated cost =  49004.3422415732
# RUN  12 , total integrated cost =  49004.27549520216
# RUN  13 , total integrated cost =  49004.22296432505
# RUN  14 , total integrated cost =  49002.76453098858
# RUN  15 , total integrated cost =  49002.16110615341
# RUN  16 , total integrated cost =  49002.157719570845
# RUN  17 , total integrated cost =  49002.14507138901
# RUN  18 , total integrated cost =  49002.12083053695
# RUN  19 , total integrated cost =  49002.11877855311
# RUN  20 , total integrated cost =  49001.95456946591
# RUN  30 , total integrated cost =  49001.31556269097
# RUN  40 , total integrated cost =  48998.78603659922
# RUN  50 , total integrated cost =  48997.55706625442
# RUN  60 , total integrated cost =  48997.195900437546
# RUN  70 , total integrated cost =  48996.53418582342
# RUN  80 , total integrated cost =  48996.339894599165
# RUN  90 , total integrated cost =  48990.34132043291
# RUN  100 , total integrated cost =  48989.24089834015
# RUN  110 , total integrated cost =  48988.869199492125
# RUN  120 , total integrated cost =  48986.760154287345
# RUN  130 , total integrated cost =  48986.67160212576
# RUN  140 , total integrated cost =  48986.21497572746
# RUN  150 , total integrated cost =  48985.84150394672
# RUN  160 , total integrated cost =  48985.6924217183
# RUN  170 , total integrated cost =  48980.9938858865
# RUN  180 , total integrated cost =  48980.67493866499
# RUN  190 , total integrated cost =  48980.604689307926
# RUN  200 , total integrated cost =  48980.545780841014
# RUN  300 , total integrated cost =  48972.460550389245
# RUN  300 , total integrated cost =  48972.460550389245
# Improved over  300  iterations in  299.990408726997  seconds by  0.12851872060846858  percent.
# cost splitting :  2.4293481801253733 [0.02260696 0.         0.         0.        ]
# set cost params:  1.0 0.0 2165656.2961228294
# interpolate adjoint :  True True True
# initial cost =  49019.342896489405
# RUN  0 , total integrated cost =  49019.342896489405
# Gradient descend method:  None
# RUN  1 , total integrated cost =  49019.219080667695
# RUN  2 , total integrated cost =  49019.21741485299
# RUN  3 , total integrated cost =  49019.182628502596
# RUN  4 , total integrated cost =  49019.159583283385
# RUN  5 , total integrated cost =  49019.157804720366
# RUN  6 , total integrated cost =  49019.12427742167
# RUN  7 , total integrated cost =  49019.10416361243
# RUN  8 , total integrated cost =  49019.09884257366
# RUN  9 , total integrated cost =  49019.08665049458
# RUN  10 , total integrated cost =  49019.08399728998
# RUN  11 , total integrated cost =  49018.93837150026
# RUN  12 , total integrated cost =  49018.79602072708
# RUN  13 , total integrated cost =  49018.79420591718
# RUN  14 , total integrated cost =  49018.76998280104
# RUN  15 , total integrated cost =  49018.75508669973
# RUN  16 , total integrated cost =  49018.75112658341
# RUN  17 , total integrated cost =  49018.7416353009
# RUN  18 , total integrated cost =  49018.73941343416
# RUN  19 , total integrated cost =  49018.60726014331
# RUN  20 , total integrated cost =  49018.47730007703
# RUN  30 , total integrated cost =  49017.913445461636
# RUN  40 , total integrated cost =  49017.81112294299
# RUN  50 , total integrated cost =  49017.76182321948
# RUN  60 , total integrated cost =  49011.460663707374
# RUN  70 , total integrated cost =  49010.02742801174
# RUN  80 , total integrated cost =  49007.732211890085
# RUN  90 , total integrated cost =  49006.197317161714
# RUN  100 , total integrated cost =  49005.98391449124
# RUN  110 , total integrated cost =  49005.56448911434
# RUN  120 , total integrated cost =  49005.52717542933
# RUN  130 , total integrated cost =  49005.42468559643
# RUN  140 , total integrated cost =  49005.346318699216
# RUN  150 , total integrated cost =  49005.311491561326
# RUN  160 , total integrated cost =  49005.259147009856
# RUN  170 , total integrated cost =  49003.571220075224
# RUN  180 , total integrated cost =  49002.68385007301
# RUN  190 , total integrated cost =  49002.55309990405
# RUN  200 , total integrated cost =  49002.08860727846
# RUN  300 , total integrated cost =  48990.64339693274
# RUN  300 , total integrated cost =  48990.64339693274
# Improved over  300  iterations in  326.3708081309742  seconds by  0.05854729553854554  percent.
# cost splitting :  2.3438700553899987 [0.02259469 0.         0.         0.        ]
# set cost params:  1.0 0.0 2166785.326240735
# interpolate adjoint :  True True True
# initial cost =  49016.15347924294
# RUN  0 , total integrated cost =  49016.15347924294
# Gradient descend method:  None
# RUN  1 , total integrated cost =  49015.910475584584
# RUN  2 , total integrated cost =  49015.778433346306
# RUN  3 , total integrated cost =  49015.77773927337
# RUN  4 , total integrated cost =  49015.71551817295
# RUN  5 , total integrated cost =  49015.66014089045
# RUN  6 , total integrated cost =  49015.65993436876
# RUN  7 , total integrated cost =  49015.6591407737
# RUN  8 , total integrated cost =  49015.65372991045
# RUN  9 , total integrated cost =  49015.65231060862
# RUN  10 , total integrated cost =  49015.65211992745
# RUN  11 , total integrated cost =  49015.651150805614
# RUN  12 , total integrated cost =  49015.64590288505
# RUN  13 , total integrated cost =  49015.64493129085
# RUN  14 , total integrated cost =  49015.644649238486
# RUN  15 , total integrated cost =  49007.94670008505
# RUN  16 , total integrated cost =  49007.78616862421
# RUN  17 , total integrated cost =  49007.76712026265
# RUN  18 , total integrated cost =  49007.735248025056
# RUN  19 , total integrated cost =  49007.72027593087
# RUN  20 , total integrated cost =  49007.67693454868
# RUN  30 , total integrated cost =  49005.26096315661
# RUN  40 , total integrated cost =  49005.21079707016
# RUN  50 , total integrated cost =  49005.098567766065
# RUN  60 , total integrated cost =  49004.79585921175
# RUN  70 , total integrated cost =  49001.88766299269
# RUN  80 , total integrated cost =  49000.456232890516
# RUN  90 , total integrated cost =  49000.418916999115
# RUN  100 , total integrated cost =  48999.89872599303
# RUN  110 , total integrated cost =  48999.16188571296
# RUN  120 , total integrated cost =  48998.93918803804
# RUN  130 , total integrated cost =  48998.84332900871
# RUN  140 , total integrated cost =  48998.53300388387
# RUN  150 , total integrated cost =  48998.48116354035
# RUN  160 , total integrated cost =  48998.44546478154
# RUN  170 , total integrated cost =  48998.409015923666
# RUN  180 , total integrated cost =  48998.34159207949
# RUN  190 , total integrated cost =  48998.11015894755
# RUN  200 , total integrated cost =  48998.014065352465
# RUN  300 , total integrated cost =  48994.50261490212
# RUN  300 , total integrated cost =  48994.50261490212
# Improved over  300  iterations in  256.85692095098784  seconds by  0.04417087593375868  percent.
# cost splitting :  2.1830455557177206 [0.02258654 0.         0.         0.        ]
# set cost params:  1.0 0.0 2167536.4292541025
# interpolate adjoint :  True True True
# initial cost =  49011.467434438724
# RUN  0 , total integrated cost =  49011.467434438724
# Gradient descend method:  None
# RUN  1 , total integrated cost =  49011.46708585061
# RUN  2 , total integrated cost =  49011.115996921544
# RUN  3 , total integrated cost =  49010.73479435061
# RUN  4 , total integrated cost =  49010.73403421167
# RUN  5 , total integrated cost =  49010.733864830414
# RUN  6 , total integrated cost =  49010.73139507914
# RUN  7 , total integrated cost =  49010.72469295018
# RUN  8 , total integrated cost =  49010.72430304278
# RUN  9 , total integrated cost =  49010.72413529259
# RUN  10 , total integrated cost =  49010.71741088626
# RUN  11 , total integrated cost =  49010.70558042468
# RUN  12 , total integrated cost =  49010.705214007765
# RUN  13 , total integrated cost =  49010.70506183822
# RUN  14 , total integrated cost =  49010.702506808484
# RUN  15 , total integrated cost =  49010.69538440404
# RUN  16 , total integrated cost =  49010.69496586954
# RUN  17 , total integrated cost =  49010.69482981584
# RUN  18 , total integrated cost =  49010.693426244914
# RUN  19 , total integrated cost =  49010.687895673334
# RUN  20 , total integrated cost =  49010.68729502824
# RUN  30 , total integrated cost =  49010.67169481905
# RUN  40 , total integrated cost =  49010.648928771596
# RUN  50 , total integrated cost =  49010.600317577926
# RUN  60 , total integrated cost =  49010.512946441835
# RUN  70 , total integrated cost =  49006.25127385643
# RUN  80 , total integrated cost =  49003.93875724588
# RUN  90 , total integrated cost =  49003.90920882965
# RUN  100 , total integrated cost =  49003.8684935091
# RUN  110 , total integrated cost =  49003.74652541677
# RUN  120 , total integrated cost =  49003.70068356073
# RUN  130 , total integrated cost =  49003.63625850303
# RUN  140 , total integrated cost =  49003.560054364025
# RUN  150 , total integrated cost =  49003.54336907457
# RUN  160 , total integrated cost =  49003.514704417605
# RUN  170 , total integrated cost =  49003.47770202628
# RUN  180 , total integrated cost =  49003.466003972666
# RUN  190 , total integrated cost =  49003.45470171045
# RUN  200 , total integrated cost =  49001.92975629258
# RUN  300 , total integrated cost =  48997.970158150856
# RUN  300 , total integrated cost =  48997.970158150856
# Improved over  300  iterations in  252.7016294299974  seconds by  0.027539016875849143  percent.
# cost splitting :  2.1023048818237937 [0.02258124 0.         0.         0.        ]
# set cost params:  1.0 0.0 2168025.24780289
# interpolate adjoint :  True True True
# initial cost =  49009.00828784812
# RUN  0 , total integrated cost =  49009.00828784812
# Gradient descend method:  None
# RUN  1 , total integrated cost =  49009.00532075816
# RUN  2 , total integrated cost =  49009.00526723401
# RUN  3 , total integrated cost =  49009.00524639194
# RUN  4 , total integrated cost =  49009.00521448383
# RUN  5 , total integrated cost =  49009.00487988008
# RUN  6 , total integrated cost =  49009.00099580967
# RUN  7 , total integrated cost =  49009.00014562193
# RUN  8 , total integrated cost =  49009.00009795157
# RUN  9 , total integrated cost =  49009.000079794074
# RUN  10 , total integrated cost =  49009.00005413306
# RUN  11 , total integrated cost =  49008.99985653196
# RUN  12 , total integrated cost =  49008.99482909158
# RUN  13 , total integrated cost =  49008.993492758265
# RUN  14 , total integrated cost =  49008.993442951214
# RUN  15 , total integrated cost =  49008.99342752566
# RUN  16 , total integrated cost =  49008.99341264656
# RUN  17 , total integrated cost =  49008.99337520497
# RUN  18 , total integrated cost =  49008.992869119356
# RUN  19 , total integrated cost =  49008.98903935687
# RUN  20 , total integrated cost =  49008.98851922956
# RUN  30 , total integrated cost =  49008.982743833236
# RUN  40 , total integrated cost =  49005.55248607549
# RUN  50 , total integrated cost =  49004.546018941175
# RUN  60 , total integrated cost =  49002.77188746635
# RUN  70 , total integrated cost =  49002.33941871887
# RUN  80 , total integrated cost =  49001.77569018438
# RUN  90 , total integrated cost =  49001.764527402716
# RUN  100 , total integrated cost =  49001.671907451404
# RUN  110 , total integrated cost =  49001.66435972828
# RUN  120 , total integrated cost =  49001.65242097644
# RUN  130 , total integrated cost =  49001.63848204303
# RUN  140 , total integrated cost =  49001.52414521335
# RUN  150 , total integrated cost =  49001.501855103445
# RUN  160 , total integrated cost =  49001.438307283
# RUN  170 , total integrated cost =  49001.39625363881
# RUN  180 , total integrated cost =  49001.372916053704
# RUN  190 , total integrated cost =  49000.79000096952
# RUN  200 , total integrated cost =  49000.752846790216
# RUN  300 , total integrated cost =  48985.47441569781
# RUN  300 , total integrated cost =  48985.47441569781
# Improved over  300  iterations in  253.64060369401705  seconds by  0.04801948248388044  percent.
# cost splitting :  1.8338466993283205 [0.02257347 0.         0.         0.        ]
# set cost params:  1.0 0.0 2168743.969554996
# interpolate adjoint :  True True True
# initial cost =  49001.69845772583
# RUN  0 , total integrated cost =  49001.69845772583
# Gradient descend method:  None
# RUN  1 , total integrated cost =  49001.66286011225
# RUN  2 , total integrated cost =  49001.66219725871
# RUN  3 , total integrated cost =  49001.64441761546
# RUN  4 , total integrated cost =  49001.62501759236
# RUN  5 , total integrated cost =  49001.62458859449
# RUN  6 , total integrated cost =  49001.299558567836
# RUN  7 , total integrated cost =  49001.28634463891
# RUN  8 , total integrated cost =  49001.28579951907
# RUN  9 , total integrated cost =  49001.28371493848
# RUN  10 , total integrated cost =  49001.27760087715
# RUN  11 , total integrated cost =  49001.27681519768
# RUN  12 , total integrated cost =  49001.27561713144
# RUN  13 , total integrated cost =  49001.27012315397
# RUN  14 , total integrated cost =  49001.26904643914
# RUN  15 , total integrated cost =  49001.268217870354
# RUN  16 , total integrated cost =  49001.262415847435
# RUN  17 , total integrated cost =  49001.26078853189
# RUN  18 , total integrated cost =  49001.2601881022
# RUN  19 , total integrated cost =  49001.25090911767
# RUN  20 , total integrated cost =  49001.246637849195
# RUN  30 , total integrated cost =  49001.063819182025
# RUN  40 , total integrated cost =  49001.03612326819
# RUN  50 , total integrated cost =  49000.971454135084
# RUN  60 , total integrated cost =  48995.19707261351
# RUN  70 , total integrated cost =  48994.70163106219
# RUN  80 , total integrated cost =  48994.52911788281
# RUN  90 , total integrated cost =  48994.51154296918
# RUN  100 , total integrated cost =  48994.49135697461
# RUN  110 , total integrated cost =  48994.44988473862
# RUN  120 , total integrated cost =  48994.438607349395
# RUN  130 , total integrated cost =  48994.41135021802
# RUN  140 , total integrated cost =  48994.2710558016
# RUN  150 , total integrated cost =  48994.24672580983
# RUN  160 , total integrated cost =  48994.01360569384
# RUN  170 , total integrated cost =  48993.992454950145
# RUN  180 , total integrated cost =  48993.96949111915
# RUN  190 , total integrated cost =  48993.85976934879
# RUN  200 , total integrated cost =  48993.83498007516
# RUN  300 , total integrated cost =  48991.407283965724
# RUN  300 , total integrated cost =  48991.407283965724
# Improved over  300  iterations in  252.22846468398347  seconds by  0.021001667460538442  percent.
# cost splitting :  1.8341016604019937 [0.02256872 0.         0.         0.        ]
# set cost params:  1.0 0.0 2169181.727197556
# interpolate adjoint :  True True True
# initial cost =  49001.28691329326
# RUN  0 , total integrated cost =  49001.28691329326
# Gradient descend method:  None
# RUN  1 , total integrated cost =  49001.28533488813
# RUN  2 , total integrated cost =  49001.28528816118
# RUN  3 , total integrated cost =  49001.28527250488
# RUN  4 , total integrated cost =  49001.28525339308
# RUN  5 , total integrated cost =  49001.28515298677
# RUN  6 , total integrated cost =  49001.27292190174
# RUN  7 , total integrated cost =  49001.26505670549
# RUN  8 , total integrated cost =  49001.26501144314
# RUN  9 , total integrated cost =  49001.26498710831
# RUN  10 , total integrated cost =  49001.26492813645
# RUN  11 , total integrated cost =  49001.23837942332
# RUN  12 , total integrated cost =  49001.206601141435
# RUN  13 , total integrated cost =  49001.206588598514
# RUN  14 , total integrated cost =  49001.206583129824
# RUN  15 , total integrated cost =  49001.20657831353
# RUN  16 , total integrated cost =  49001.206572200375
# RUN  17 , total integrated cost =  49001.20654711381
# RUN  18 , total integrated cost =  49001.20553631449
# RUN  19 , total integrated cost =  49001.20215358234
# RUN  20 , total integrated cost =  49001.202062121934
# RUN  30 , total integrated cost =  49001.19872268597
# RUN  40 , total integrated cost =  49001.18925485534
# RUN  50 , total integrated cost =  49001.182494321256
# RUN  60 , total integrated cost =  49001.10530382822
# Control only changes marginally.
# RUN  60 , total integrated cost =  49001.10530382822
# Improved over  60  iterations in  50.406086146016605  seconds by  0.00037062182747149564  percent.
# cost splitting :  1.816055124448458 [0.02256884 0.         0.         0.        ]
# set cost params:  1.0 0.0 2169170.519627196
# interpolate adjoint :  True True True
# initial cost =  49000.85236193788
# RUN  0 , total integrated cost =  49000.85236193788
# Gradient descend method:  None
# RUN  1 , total integrated cost =  49000.85236193788
# Control only changes marginally.
# RUN  1 , total integrated cost =  49000.85236193788
# Improved over  1  iterations in  1.077260527992621  seconds by  0.0  percent.
# cost splitting :  1.816055124448458 [0.02256884 0.         0.         0.        ]
# -------  18 0.4000000000000001 0.4750000000000002
# -------  30 0.4250000000000001 0.5250000000000002
# -------  42 0.4250000000000001 0.5750000000000003
# -------  54 0.5750000000000002 0.6000000000000003
# set cost params:  1.0 0.0 600000.0
# interpolate adjoint :  True True True
# initial cost =  870523.2701234882
# RUN  0 , total integrated cost =  870523.2701234882
# Gradient descend method:  None
# RUN  1 , total integrated cost =  8709.194312013198
# RUN  2 , total integrated cost =  8194.554735852003
# RUN  3 , total integrated cost =  2232.455561251571
# RUN  4 , total integrated cost =  2202.5166085249016
# RUN  5 , total integrated cost =  2200.257199614872
# RUN  6 , total integrated cost =  2197.2946241631735
# RUN  7 , total integrated cost =  2195.587856657478
# RUN  8 , total integrated cost =  2193.239267748731
# RUN  9 , total integrated cost =  2191.6064117962087
# RUN  10 , total integrated cost =  2189.4476538603267
# RUN  11 , total integrated cost =  2187.8352352444545
# RUN  12 , total integrated cost =  2185.731349509609
# RUN  13 , total integrated cost =  2184.1708959161047
# RUN  14 , total integrated cost =  2182.0795754104483
# RUN  15 , total integrated cost =  2180.5855066016647
# RUN  16 , total integrated cost =  2178.680861118345
# RUN  17 , total integrated cost =  2177.189242483472
# RUN  18 , total integrated cost =  2175.3323598092
# RUN  19 , total integrated cost =  2173.8605282969274
# RUN  20 , total integrated cost =  2172.0402604621568
# RUN  30 , total integrated cost =  2157.050310618432
# RUN  40 , total integrated cost =  2139.0839128796642
# RUN  50 , total integrated cost =  1974.2176557247574
# RUN  60 , total integrated cost =  1883.831770818388
# RUN  70 , total integrated cost =  1880.738544154512
# RUN  80 , total integrated cost =  1852.9091603615643
# RUN  90 , total integrated cost =  1850.042626988177
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer pre
# RUN  100 , total integrated cost =  1844.424230744494
# RUN  100 , total integrated cost =  1844.424230744494
# Improved over  100  iterations in  70.51403828398907  seconds by  99.7881246493867  percent.
# Problem in initial value trasfer pre:  sigmae_f 1.5123408346431673 1.512340797165876
# Problem in initial value trasfer pre:  tau_exc 19.119345246399707 19.119345647268727
# cost splitting :  0.021828296428136416 [0.00307314 0.         0.         0.        ]
# set cost params:  1.0 0.0 57133755.01324119
# interpolate adjoint :  True True True
# initial cost =  175580.29766384335
# RUN  0 , total integrated cost =  175580.29766384335
# Gradient descend method:  None
# RUN  1 , total integrated cost =  175104.5599529591
# RUN  2 , total integrated cost =  175102.41759558654
# RUN  3 , total integrated cost =  174891.3317058528
# RUN  4 , total integrated cost =  174788.18223588198
# RUN  5 , total integrated cost =  174787.57594420444
# RUN  6 , total integrated cost =  174787.42465551663
# RUN  7 , total integrated cost =  174787.04553395146
# RUN  8 , total integrated cost =  174786.792515104
# RUN  9 , total integrated cost =  174785.0741159292
# RUN  10 , total integrated cost =  174783.70286141886
# RUN  11 , total integrated cost =  174777.78273716045
# RUN  12 , total integrated cost =  174770.7619210905
# RUN  13 , total integrated cost =  174656.37002147708
# RUN  14 , total integrated cost =  174588.3220353039
# RUN  15 , total integrated cost =  174588.09597818446
# RUN  16 , total integrated cost =  174546.94335916187
# RUN  17 , total integrated cost =  174504.8965065534
# RUN  18 , total integrated cost =  174504.67503524502
# RUN  19 , total integrated cost =  174504.28103845628
# RUN  20 , total integrated cost =  174504.16352378653
# RUN  30 , total integrated cost =  174496.56037727316
# RUN  40 , total integrated cost =  174484.28334676416
# RUN  50 , total integrated cost =  174446.34370256116
# RUN  60 , total integrated cost =  174413.2917491894
# RUN  70 , total integrated cost =  174408.42603349808
# RUN  80 , total integrated cost =  173811.06385948297
# RUN  90 , total integrated cost =  173800.52011908658
# RUN  100 , total integrated cost =  173785.17009142778
# RUN  110 , total integrated cost =  173779.6896927577
# RUN  120 , total integrated cost =  173358.77489531584
# RUN  130 , total integrated cost =  173356.63268882583
# RUN  140 , total integrated cost =  173343.51066143275
# RUN  150 , total integrated cost =  173340.1039218965
# RUN  160 , total integrated cost =  173337.25721563637
# RUN  170 , total integrated cost =  173335.7054856657
# RUN  180 , total integrated cost =  173333.7486584816
# RUN  190 , total integrated cost =  173330.61620373843
# RUN  200 , total integrated cost =  173325.54763564636
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer pre
# RUN  300 , total integrated cost =  173283.73325009897
# RUN  300 , total integrated cost =  173283.73325009897
# Improved over  300  iterations in  240.47422284897766  seconds by  1.307985260476812  percent.
# Problem in initial value trasfer pre:  sigmae_f 1.5123408346431673 1.5123407488241505
# Problem in initial value trasfer pre:  tau_exc 19.119345246399707 19.11934616434719
# cost splitting :  2.0349262937635775 [0.00303206 0.         0.         0.        ]
# set cost params:  1.0 0.0 57901065.72525239
# interpolate adjoint :  True True True
# initial cost =  175610.2671113689
# RUN  0 , total integrated cost =  175610.2671113689
# Gradient descend method:  None
# RUN  1 , total integrated cost =  175610.11950706472
# RUN  2 , total integrated cost =  175610.00901217252
# RUN  3 , total integrated cost =  175609.91649272546
# RUN  4 , total integrated cost =  175609.7490435826
# RUN  5 , total integrated cost =  175609.73065141035
# RUN  6 , total integrated cost =  175609.57554363422
# RUN  7 , total integrated cost =  175609.45186769817
# RUN  8 , total integrated cost =  175609.346247079
# RUN  9 , total integrated cost =  175609.1726976172
# RUN  10 , total integrated cost =  175609.15456471403
# RUN  11 , total integrated cost =  175609.03989609028
# RUN  12 , total integrated cost =  175608.96416325626
# RUN  13 , total integrated cost =  175608.01550223015
# RUN  14 , total integrated cost =  175606.80970929188
# RUN  15 , total integrated cost =  175606.79416354443
# RUN  16 , total integrated cost =  175606.6596893257
# RUN  17 , total integrated cost =  175606.56717404423
# RUN  18 , total integrated cost =  175606.52624544792
# RUN  19 , total integrated cost =  175606.43217890253
# RUN  20 , total integrated cost =  175606.40887403683
# RUN  30 , total integrated cost =  175599.30577288478
# RUN  40 , total integrated cost =  175592.41381033103
# RUN  50 , total integrated cost =  175589.85260988917
# RUN  60 , total integrated cost =  175587.18330210896
# RUN  70 , total integrated cost =  175582.67136549862
# RUN  80 , total integrated cost =  175335.81317699028
# RUN  90 , total integrated cost =  175332.99707478276
# RUN  100 , total integrated cost =  175326.493356097
# RUN  110 , total integrated cost =  175316.84632294317
# RUN  120 , total integrated cost =  175312.15368348316
# RUN  130 , total integrated cost =  175307.98825847873
# RUN  140 , total integrated cost =  175306.04129281268
# RUN  150 , total integrated cost =  175303.18402742193
# RUN  160 , total integrated cost =  175289.1862412368
# RUN  170 , total integrated cost =  175287.86976355547
# RUN  180 , total integrated cost =  175286.56789989438
# RUN  190 , total integrated cost =  175225.31098746686
# RUN  200 , total integrated cost =  175222.20833255578
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer pre
# RUN  300 , total integrated cost =  175126.65109118118
# RUN  300 , total integrated cost =  175126.65109118118
# Improved over  300  iterations in  251.9019025590096  seconds by  0.275391654567116  percent.
# Problem in initial value trasfer pre:  sigmae_f 1.5123408346431673 1.5123407100133808
# Problem in initial value trasfer pre:  tau_exc 19.119345246399707 19.11934657947952
# cost splitting :  1.4373752471345036 [0.00302397 0.         0.         0.        ]
# set cost params:  1.0 0.0 58054831.37128055
# interpolate adjoint :  True True True
# initial cost =  175591.63326761505
# RUN  0 , total integrated cost =  175591.63326761505
# Gradient descend method:  None
# RUN  1 , total integrated cost =  175591.59218638323
# RUN  2 , total integrated cost =  175591.58029664203
# RUN  3 , total integrated cost =  175591.5704509494
# RUN  4 , total integrated cost =  175591.53025824745
# RUN  5 , total integrated cost =  175591.51566977124
# RUN  6 , total integrated cost =  175591.50649067335
# RUN  7 , total integrated cost =  175591.46610570402
# RUN  8 , total integrated cost =  175591.4512031384
# RUN  9 , total integrated cost =  175591.44209509785
# RUN  10 , total integrated cost =  175591.40160613495
# RUN  11 , total integrated cost =  175591.38686056258
# RUN  12 , total integrated cost =  175591.37780262766
# RUN  13 , total integrated cost =  175591.33721986262
# RUN  14 , total integrated cost =  175591.3226408281
# RUN  15 , total integrated cost =  175591.31363160134
# RUN  16 , total integrated cost =  175591.2729569988
# RUN  17 , total integrated cost =  175591.2585441484
# RUN  18 , total integrated cost =  175591.24936406218
# RUN  19 , total integrated cost =  175591.20845397434
# RUN  20 , total integrated cost =  175591.19408859257
# RUN  30 , total integrated cost =  175590.99251218946
# RUN  40 , total integrated cost =  175590.75683369706
# RUN  50 , total integrated cost =  175590.55102261782
# RUN  60 , total integrated cost =  175590.34136043946
# RUN  70 , total integrated cost =  175590.0999308647
# RUN  80 , total integrated cost =  175589.88527226012
# RUN  90 , total integrated cost =  175589.67687866034
# RUN  100 , total integrated cost =  175589.43781621274
# RUN  110 , total integrated cost =  175589.22696758615
# RUN  120 , total integrated cost =  175589.0159972588
# RUN  130 , total integrated cost =  175588.76988713618
# RUN  140 , total integrated cost =  175588.546315141
# RUN  150 , total integrated cost =  175588.33099029787
# RUN  160 , total integrated cost =  175588.07718863618
# RUN  170 , total integrated cost =  175587.85188607452
# RUN  180 , total integrated cost =  175587.63517464555
# RUN  190 , total integrated cost =  175587.37933453353
# RUN  200 , total integrated cost =  175587.1463046719
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer pre
# RUN  300 , total integrated cost =  175376.45993565797
# RUN  300 , total integrated cost =  175376.45993565797
# Improved over  300  iterations in  314.383408624999  seconds by  0.1225419047325147  percent.
# Problem in initial value trasfer pre:  sigmae_f 1.5123408346431673 1.5123406811179987
# Problem in initial value trasfer pre:  tau_exc 19.119345246399707 19.119346888553714
# cost splitting :  1.1796499270108807 [0.00302037 0.         0.         0.        ]
# set cost params:  1.0 0.0 58123394.635531366
# interpolate adjoint :  True True True
# initial cost =  175583.5464075866
# RUN  0 , total integrated cost =  175583.5464075866
# Gradient descend method:  None
# RUN  1 , total integrated cost =  175583.54039634904
# RUN  2 , total integrated cost =  175583.51398081667
# RUN  3 , total integrated cost =  175583.50719775827
# RUN  4 , total integrated cost =  175583.49397770007
# RUN  5 , total integrated cost =  175583.45949613967
# RUN  6 , total integrated cost =  175583.45325641413
# RUN  7 , total integrated cost =  175583.437666652
# RUN  8 , total integrated cost =  175583.39557138438
# RUN  9 , total integrated cost =  175583.39020483848
# RUN  10 , total integrated cost =  175583.3833451468
# RUN  11 , total integrated cost =  175583.35588112666
# RUN  12 , total integrated cost =  175583.34869103573
# RUN  13 , total integrated cost =  175583.34386722706
# RUN  14 , total integrated cost =  175583.31723436178
# RUN  15 , total integrated cost =  175583.31027471367
# RUN  16 , total integrated cost =  175583.30574054565
# RUN  17 , total integrated cost =  175583.2777506049
# RUN  18 , total integrated cost =  175583.26747086464
# RUN  19 , total integrated cost =  175583.26343431935
# RUN  20 , total integrated cost =  175583.23007916426
# RUN  30 , total integrated cost =  175582.63063609082
# RUN  40 , total integrated cost =  175579.6076354253
# RUN  50 , total integrated cost =  175579.1448558835
# RUN  60 , total integrated cost =  175578.90702437895
# RUN  70 , total integrated cost =  175578.62225068605
# RUN  80 , total integrated cost =  175578.40947561906
# RUN  90 , total integrated cost =  175578.0748871283
# RUN  100 , total integrated cost =  175577.2091705909
# RUN  110 , total integrated cost =  175569.7877586455
# RUN  120 , total integrated cost =  175568.87338193232
# RUN  130 , total integrated cost =  175568.6465947296
# RUN  140 , total integrated cost =  175568.26127359393
# RUN  150 , total integrated cost =  175567.97304516513
# RUN  160 , total integrated cost =  175567.75099408822
# RUN  170 , total integrated cost =  175567.49924181867
# RUN  180 , total integrated cost =  175566.91450588944
# RUN  190 , total integrated cost =  175566.42516112307
# RUN  200 , total integrated cost =  175566.18512978774
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer pre
# RUN  300 , total integrated cost =  175546.06423956223
# RUN  300 , total integrated cost =  175546.06423956223
# Improved over  300  iterations in  322.9173306079756  seconds by  0.021347198408534496  percent.
# Problem in initial value trasfer pre:  sigmae_f 1.5123408346431673 1.5123406749070603
# Problem in initial value trasfer pre:  tau_exc 19.119345246399707 19.119346954987883
# cost splitting :  1.0954152531061323 [0.00301976 0.         0.         0.        ]
# set cost params:  1.0 0.0 58135021.70310545
# interpolate adjoint :  True True True
# initial cost =  175581.17521463806
# RUN  0 , total integrated cost =  175581.17521463806
# Gradient descend method:  None
# RUN  1 , total integrated cost =  175581.11986611935
# RUN  2 , total integrated cost =  175581.11836924727
# RUN  3 , total integrated cost =  175581.11733793718
# RUN  4 , total integrated cost =  175581.02868959794
# RUN  5 , total integrated cost =  175580.96852525495
# RUN  6 , total integrated cost =  175580.9671644383
# RUN  7 , total integrated cost =  175580.9651080443
# RUN  8 , total integrated cost =  175580.94106343674
# RUN  9 , total integrated cost =  175580.93657708864
# RUN  10 , total integrated cost =  175580.93533355798
# RUN  11 , total integrated cost =  175580.91106986368
# RUN  12 , total integrated cost =  175580.8631630966
# RUN  13 , total integrated cost =  175580.86147656324
# RUN  14 , total integrated cost =  175580.86055128643
# RUN  15 , total integrated cost =  175580.69276087396
# RUN  16 , total integrated cost =  175580.4637965828
# RUN  17 , total integrated cost =  175580.46167479036
# RUN  18 , total integrated cost =  175580.4608416222
# RUN  19 , total integrated cost =  175580.44452846114
# RUN  20 , total integrated cost =  175580.40696209253
# RUN  30 , total integrated cost =  175580.11700646434
# RUN  40 , total integrated cost =  175576.60217104567
# RUN  50 , total integrated cost =  175574.79197141842
# RUN  60 , total integrated cost =  175460.4334361162
# RUN  70 , total integrated cost =  175445.46487978572
# RUN  80 , total integrated cost =  175445.32392988788
# RUN  90 , total integrated cost =  175445.20848714793
# RUN  100 , total integrated cost =  175445.05588036776
# RUN  110 , total integrated cost =  175444.93322922563
# RUN  120 , total integrated cost =  175444.73519331476
# RUN  130 , total integrated cost =  175444.55860676602
# RUN  140 , total integrated cost =  175444.4287661082
# RUN  150 , total integrated cost =  175444.24903942124
# RUN  160 , total integrated cost =  175444.01458020543
# RUN  170 , total integrated cost =  175443.87647409414
# RUN  180 , total integrated cost =  175443.57959108465
# RUN  190 , total integrated cost =  175443.45659001367
# RUN  200 , total integrated cost =  175442.43483971845
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer pre
# RUN  300 , total integrated cost =  175426.9388236159
# RUN  300 , total integrated cost =  175426.9388236159
# Improved over  300  iterations in  307.76705251599196  seconds by  0.08784335270203769  percent.
# Problem in initial value trasfer pre:  sigmae_f 1.5123408346431673 1.512340639296436
# Problem in initial value trasfer pre:  tau_exc 19.119345246399707 19.11934733589044
# cost splitting :  0.943167782404436 [0.00301717 0.         0.         0.        ]
# set cost params:  1.0 0.0 58184484.09322384
# interpolate adjoint :  True True True
# initial cost =  175576.17545788886
# RUN  0 , total integrated cost =  175576.17545788886
# Gradient descend method:  None
# RUN  1 , total integrated cost =  175576.15900014958
# RUN  2 , total integrated cost =  175576.1572286999
# RUN  3 , total integrated cost =  175576.15643897286
# RUN  4 , total integrated cost =  175576.14961065244
# RUN  5 , total integrated cost =  175576.12469002433
# RUN  6 , total integrated cost =  175576.1229555908
# RUN  7 , total integrated cost =  175576.1221806464
# RUN  8 , total integrated cost =  175576.11546124355
# RUN  9 , total integrated cost =  175576.09188194748
# RUN  10 , total integrated cost =  175576.09046246184
# RUN  11 , total integrated cost =  175576.08968034454
# RUN  12 , total integrated cost =  175576.07774471358
# RUN  13 , total integrated cost =  175576.04506235966
# RUN  14 , total integrated cost =  175576.04395064455
# RUN  15 , total integrated cost =  175576.04316840024
# RUN  16 , total integrated cost =  175576.00922039492
# RUN  17 , total integrated cost =  175575.94902475938
# RUN  18 , total integrated cost =  175575.9483341642
# RUN  19 , total integrated cost =  175575.94701524585
# RUN  20 , total integrated cost =  175575.73988367073
# RUN  30 , total integrated cost =  175539.40956482227
# RUN  40 , total integrated cost =  175539.0069695649
# RUN  50 , total integrated cost =  175538.6089892726
# RUN  60 , total integrated cost =  175538.3304751192
# RUN  70 , total integrated cost =  175537.66757463032
# RUN  80 , total integrated cost =  175537.50183013032
# RUN  90 , total integrated cost =  175537.3685540667
# RUN  100 , total integrated cost =  175537.22869273022
# RUN  110 , total integrated cost =  175535.67520591966
# RUN  120 , total integrated cost =  175535.42665744945
# RUN  130 , total integrated cost =  175529.799290133
# RUN  140 , total integrated cost =  175529.6260995778
# RUN  150 , total integrated cost =  175529.57851090145
# RUN  160 , total integrated cost =  175529.52454355688
# RUN  170 , total integrated cost =  175529.48621316554
# RUN  180 , total integrated cost =  175529.43512509743
# RUN  190 , total integrated cost =  175529.3986043069
# RUN  200 , total integrated cost =  175529.3480490852
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer pre
# RUN  300 , total integrated cost =  175528.53017252526
# RUN  300 , total integrated cost =  175528.53017252526
# Improved over  300  iterations in  337.28801224799827  seconds by  0.027136532185721762  percent.
# Problem in initial value trasfer pre:  sigmae_f 1.5123408346431673 1.5123406264394932
# Problem in initial value trasfer pre:  tau_exc 19.119345246399707 19.11934747341239
# cost splitting :  0.9350471175344629 [0.00301636 0.         0.         0.        ]
# set cost params:  1.0 0.0 58200083.523151934
# interpolate adjoint :  True True True
# initial cost =  175575.58364624874
# RUN  0 , total integrated cost =  175575.58364624874
# Gradient descend method:  None
# RUN  1 , total integrated cost =  175575.56894889055
# RUN  2 , total integrated cost =  175575.5684969771
# RUN  3 , total integrated cost =  175575.56822640824
# RUN  4 , total integrated cost =  175575.56545451257
# RUN  5 , total integrated cost =  175575.55263153397
# RUN  6 , total integrated cost =  175575.55120958344
# RUN  7 , total integrated cost =  175575.55099718954
# RUN  8 , total integrated cost =  175575.5502437359
# RUN  9 , total integrated cost =  175575.45004581264
# RUN  10 , total integrated cost =  175575.39545180107
# RUN  11 , total integrated cost =  175575.3949456587
# RUN  12 , total integrated cost =  175575.39472793558
# RUN  13 , total integrated cost =  175575.39274561527
# RUN  14 , total integrated cost =  175575.37987518313
# RUN  15 , total integrated cost =  175575.37800619288
# RUN  16 , total integrated cost =  175575.3777869037
# RUN  17 , total integrated cost =  175575.3775560843
# RUN  18 , total integrated cost =  175575.37542067943
# RUN  19 , total integrated cost =  175575.36266020298
# RUN  20 , total integrated cost =  175575.3608199824
# RUN  30 , total integrated cost =  175575.32650219544
# RUN  40 , total integrated cost =  175575.29226275996
# RUN  50 , total integrated cost =  175575.25621331466
# RUN  60 , total integrated cost =  175575.21316688418
# RUN  70 , total integrated cost =  175575.17793379963
# RUN  80 , total integrated cost =  175575.12590244837
# RUN  90 , total integrated cost =  175574.9871527685
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer pre
# Control only changes marginally.
# RUN  97 , total integrated cost =  175574.0756767399
# Improved over  97  iterations in  101.70930215300177  seconds by  0.000858871989777299  percent.
# Problem in initial value trasfer pre:  sigmae_f 1.5123408346431673 1.5123406260606131
# Problem in initial value trasfer pre:  tau_exc 19.119345246399707 19.11934747746501
# cost splitting :  0.8970389440392172 [0.00301635 0.         0.         0.        ]
# set cost params:  1.0 0.0 58200270.92440096
# interpolate adjoint :  True True True
# initial cost =  175574.64094428773
# RUN  0 , total integrated cost =  175574.64094428773
# Gradient descend method:  None
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer pre
# RUN  1 , total integrated cost =  175574.64094428773
# Control only changes marginally.
# RUN  1 , total integrated cost =  175574.64094428773
# Improved over  1  iterations in  1.4634496579819825  seconds by  0.0  percent.
# Problem in initial value trasfer pre:  sigmae_f 1.5123408346431673 1.5123406260606131
# Problem in initial value trasfer pre:  tau_exc 19.119345246399707 19.11934747746501
# cost splitting :  0.8970389440392172 [0.00301635 0.         0.         0.        ]
# -------  66 0.5250000000000001 0.6500000000000004

# %%
for i in i_range:
    print("------- ", i, exc[i], inh[i])
    
    if i in bad:
        continue
        
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    aln.params.duration = dur
    max_it = int(0)
    limit = 1e-6
        
    for l in range( bestControl_[i].shape[2] ):
        if ( np.abs(bestControl_[i][0,2,l]) > limit or np.abs(bestControl_[i][0,3,l]) > limit
            or np.abs(bestControl_[i][0,4,l]) > limit or np.abs(bestControl_[i][0,5,l]) > limit ):
            init_ind = l - n_pre
            break
            
    if init_ind == -1:
        init_ind = 0
            
    print("init ind = ", init_ind)

    weight_ = 1.
    cost.setParams(1., weight_ * factor_we, weight_ * factor_ws)
    weights_[i] = cost.getParams()

    setinit(initVars[i], aln)

    target_ = aln.getZeroTarget()
    target_[:,0,:] = target[i][0]
    target_[:,1,:] = target[i][1]

    control0 = aln.getZeroControl()
    if init_ind != 0:
        control0[:,:,:-init_ind] = bestControl_[i][:,:,n_pre-1+init_ind:-n_post+1]
    else:
        control0 = bestControl_[i][:,:,n_pre-1:-n_post+1]

    bestControl_[i], bestState_[i], cost_[i], runtime_, grad_, phi_, phi1_, costnode_[i] = aln.A1(
        control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
        prec_variables_ = p_var, transition_time_ = t_pen)

    print('uncontrolled cost : ', cost_uncontrolled[i])
    print('cost splitting : ', costnode_[i][0][0][0], costnode_[i][2][0][:2])

    plot_time_array = np.arange(0.,round(dur+aln.params.dt,1),aln.params.dt)
    target_ = aln.getZeroTarget()
    target_[:,0,:] = target[i][0]
    target_[:,1,:] = target[i][1]

    fig, ax = plt.subplots(3,1, constrained_layout=True, figsize = (4,8) )

    ax[0].plot(plot_time_array, bestState_[i][0,0,n_pre-1:-n_post+1], color= 'red')
    ax[0].plot(plot_time_array, bestState_[i][0,1,n_pre-1:-n_post+1], color= 'blue')
    ax[0].plot(plot_time_array, target_[0,0,n_pre-1:-n_post+1], linestyle = '--', color='red')
    ax[0].plot(plot_time_array, target_[0,1,n_pre-1:-n_post+1], linestyle = '--', color='blue')

    ax[1].plot(plot_time_array, bestControl_[i][0,3,n_pre-1:-n_post+1], color = 'blue')
    ax[1].plot(plot_time_array, bestControl_[i][0,2,n_pre-1:-n_post+1], color = 'red')

    ax[2].plot(plot_time_array, bestControl_[i][0,4,n_pre-1:-n_post+1], color = 'red')
    ax[2].plot(plot_time_array, bestControl_[i][0,5,n_pre-1:-n_post+1], color = 'blue')

    for k in range(3):
        ax[k].set_xlim(0.,dur)
        ax[k].axvspan(dur*t_pen, dur, alpha=0.2, color='gray')
    plt.show()
# Out:
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer pre
# -------  6 0.4250000000000001 0.40000000000000013
# init ind =  1126
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  0.022568842328515727
# RUN  0 , total integrated cost =  0.022568842328515727
# Gradient descend method:  None
# RUN  0 , total integrated cost =  0.022568842328515727
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# Problem in initial value trasfer pre:  sigmae_f 1.5683257737518672 1.5683256503151797
# Problem in initial value trasfer pre:  tau_exc 19.657394330624978 19.657395422062255
# uncontrolled cost :  234849.86448361105
# cost splitting :  3.5454564524253274e-25 [0. 0.]
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer pre
# -------  18 0.4000000000000001 0.4750000000000002
# -------  30 0.4250000000000001 0.5250000000000002
# -------  42 0.4250000000000001 0.5750000000000003
# -------  54 0.5750000000000002 0.6000000000000003
# init ind =  183
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  0.0030168939200063316
# RUN  0 , total integrated cost =  0.0030168939200063316
# Gradient descend method:  None
# RUN  0 , total integrated cost =  0.0030168939200063316
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# Problem in initial value trasfer pre:  sigmae_f 1.5123408346431673 1.5123404716777793
# Problem in initial value trasfer pre:  tau_exc 19.119345246399707 19.119349128792877
# uncontrolled cost :  870523.2701234882
# cost splitting :  2.197965413309902e-08 [0. 0.]
# -------  66 0.5250000000000001 0.6500000000000004

# %%
    with open(file_,'wb') as f:
        pickle.dump([bestControl_, bestState_, cost_, costnode_, weights_], f)

# %%
tol = 1e-10
conv_shift = [None] * len(exc)

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    
    if i in bad:
        continue
        
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    aln.params.duration = dur
    max_it = int(1000)
    k = 0
    
    while not conv_shift[i]:
            
        weight_ = 1.
        cost.setParams(1., weight_ * factor_we, weight_ * factor_ws)
        weights_[i] = cost.getParams()

        setinit(initVars[i], aln)

        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        control0 = aln.getZeroControl()
        control0 = bestControl_[i][:,:,n_pre-1:-n_post+1]

        bestControl_[i], bestState_[i], cost_[i], runtime_, grad_, phi_, phi1_, costnode_[i]= aln.A1(
            control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
            prec_variables_ = p_var, transition_time_ = t_pen)
                
        if cost_[i][-1] == 0.:
            conv_shift[i] = True

        print('uncontrolled cost : ', cost_uncontrolled[i])
        print('cost splitting : ', costnode_[i][0][0][0], costnode_[i][2][0][:2])

        if conv_shift[i]:
            plot_time_array = np.arange(0.,round(dur+aln.params.dt,1),aln.params.dt)
            target_ = aln.getZeroTarget()
            target_[:,0,:] = target[i][0]
            target_[:,1,:] = target[i][1]

            fig, ax = plt.subplots(3,1, constrained_layout=True, figsize = (4,8) )

            ax[0].plot(plot_time_array, bestState_[i][0,0,n_pre-1:-n_post+1], color= 'red')
            ax[0].plot(plot_time_array, bestState_[i][0,1,n_pre-1:-n_post+1], color= 'blue')
            ax[0].plot(plot_time_array, target_[0,0,n_pre-1:-n_post+1], linestyle = '--', color='red')
            ax[0].plot(plot_time_array, target_[0,1,n_pre-1:-n_post+1], linestyle = '--', color='blue')

            ax[1].plot(plot_time_array, bestControl_[i][0,3,n_pre-1:-n_post+1], color = 'blue')
            ax[1].plot(plot_time_array, bestControl_[i][0,2,n_pre-1:-n_post+1], color = 'red')

            ax[2].plot(plot_time_array, bestControl_[i][0,4,n_pre-1:-n_post+1], color = 'red')
            ax[2].plot(plot_time_array, bestControl_[i][0,5,n_pre-1:-n_post+1], color = 'blue')

        with open(file_,'wb') as f:
            pickle.dump([bestControl_, bestState_, cost_, costnode_, weights_], f)
        
        k += 1
# Out:
# -------  6 0.4250000000000001 0.40000000000000013
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  0.022568842328515727
# RUN  0 , total integrated cost =  0.022568842328515727
# Gradient descend method:  None
# RUN  1 , total integrated cost =  0.02248491898867201
# RUN  2 , total integrated cost =  0.022480150617089967
# RUN  3 , total integrated cost =  0.02248009846302581
# RUN  4 , total integrated cost =  0.022480095203396833
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer pre
# RUN  5 , total integrated cost =  0.022480095203396833
# Control only changes marginally.
# RUN  5 , total integrated cost =  0.022480095203396833
# Improved over  5  iterations in  1.820139110001037  seconds by  0.39322852199097724  percent.
# Problem in initial value trasfer pre:  sigmae_f 1.5683257737518672 1.5683256508005412
# Problem in initial value trasfer pre:  tau_exc 19.657394330624978 19.65739541777065
# uncontrolled cost :  234849.86448361105
# cost splitting :  1.0197264892222418e-18 [0. 0.]
# -------  18 0.4000000000000001 0.4750000000000002
# -------  30 0.4250000000000001 0.5250000000000002
# -------  42 0.4250000000000001 0.5750000000000003
# -------  54 0.5750000000000002 0.6000000000000003
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  0.0030168939200063316
# RUN  0 , total integrated cost =  0.0030168939200063316
# Gradient descend method:  None
# RUN  1 , total integrated cost =  0.0030168613741519265
# RUN  2 , total integrated cost =  0.003016437450462694
# RUN  3 , total integrated cost =  0.0030162669074084835
# RUN  4 , total integrated cost =  0.0030160305514709616
# RUN  5 , total integrated cost =  0.0030159255226162866
# RUN  6 , total integrated cost =  0.0030159253198776023
# RUN  7 , total integrated cost =  0.0030159239054454315
# RUN  8 , total integrated cost =  0.0030159227142355625
# RUN  9 , total integrated cost =  0.003015921127743716
# RUN  10 , total integrated cost =  0.0030159191370679843
# RUN  11 , total integrated cost =  0.0030159189347530725
# RUN  12 , total integrated cost =  0.003015918555462603
# RUN  13 , total integrated cost =  0.003015918349629999
# RUN  14 , total integrated cost =  0.0030159175022324513
# RUN  15 , total integrated cost =  0.0030159168543893956
# RUN  16 , total integrated cost =  0.003015913655966644
# RUN  17 , total integrated cost =  0.0030159101489225276
# RUN  18 , total integrated cost =  0.003015909902943994
# RUN  19 , total integrated cost =  0.003015909485029519
# RUN  20 , total integrated cost =  0.0030159093211958193
# RUN  30 , total integrated cost =  0.003015885015808421
# RUN  40 , total integrated cost =  0.0030158751047861376
# RUN  50 , total integrated cost =  0.003015868813984499
# RUN  60 , total integrated cost =  0.0030158332692587614
# RUN  70 , total integrated cost =  0.003015830337036665
# RUN  80 , total integrated cost =  0.0030158113863731507
# RUN  90 , total integrated cost =  0.003015807718970234
# RUN  100 , total integrated cost =  0.0030158035687252093
# RUN  110 , total integrated cost =  0.0030157985504987756
# RUN  120 , total integrated cost =  0.0030157846716169453
# RUN  130 , total integrated cost =  0.0030157810145670662
# RUN  140 , total integrated cost =  0.0030157779307881994
# RUN  150 , total integrated cost =  0.0030155550024579436
# RUN  160 , total integrated cost =  0.003015554602374482
# RUN  170 , total integrated cost =  0.0030155535570951914
# RUN  180 , total integrated cost =  0.0030155531909339946
# RUN  190 , total integrated cost =  0.0030155522655786193
# RUN  200 , total integrated cost =  0.0030155515066877386
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer pre
# Control only changes marginally.
# RUN  286 , total integrated cost =  0.00301542086133508
# Improved over  286  iterations in  186.2306890960026  seconds by  0.048826995920634886  percent.
# Problem in initial value trasfer pre:  sigmae_f 1.5123408346431673 1.5123404675821883
# Problem in initial value trasfer pre:  tau_exc 19.119345246399707 19.119349172600618
# uncontrolled cost :  870523.2701234882
# cost splitting :  1.4643995434489069e-09 [0. 0.]
# -------  66 0.5250000000000001 0.6500000000000004
