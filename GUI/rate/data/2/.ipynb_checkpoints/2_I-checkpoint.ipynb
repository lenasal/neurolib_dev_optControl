# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import sys
import pickle

path = os.getcwd().split(os.sep + 'GUI')[0]
if path not in sys.path:
    print("not here")
    sys.path.append(path)

from neurolib.models.aln import ALNModel
from neurolib.utils import plotFunctions as plotFunc
from neurolib.utils import costFunctions as cost
import neurolib.dashboard.functions as functions
import neurolib.dashboard.data as data
    
# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2 

#path = os.path.join(os.getcwd(), "plots")
# Out:
# not here

# %%
grid_data_file = os.path.join(os.getcwd().split('data')[0], 'bi.pickle')
print(grid_data_file)
with open(grid_data_file,'rb') as f:
    load_array= pickle.load(f)
exc = load_array[0]
inh = load_array[1]
print(len(exc))
# Out:
# /home/lena/Promotion/neurolib/GUI/rate/bi.pickle
# 147

# %%
aln = ALNModel()
N = aln.params.N

data.set_parameters(aln)

state_vars = aln.state_vars
init_vars = aln.init_vars

##############################################################
def setinit(init_vars_, model):
    state_vars = model.state_vars
    init_vars = model.init_vars
    for iv in range(len(init_vars)):
        for sv in range(len(state_vars)):
            if state_vars[sv] in init_vars[iv]:
                #print("set init vars ", )
                if model.params[init_vars[iv]].ndim == 2:
                    model.params[init_vars[iv]][0,:] = init_vars_[sv]
                else:
                    model.params[init_vars[iv]][0] = init_vars_[sv]
                    
##############################################################               
def setmaxmincontrol(max_c_c, min_c_c, max_c_r, min_c_r):
    import numpy as np
    
    max_cntrl = np.zeros(( 6 ))
    min_cntrl = np.zeros(( 6 ))
    
    max_cntrl[0] = max_c_c
    min_cntrl[0] = min_c_c
    max_cntrl[1] = max_c_c
    min_cntrl[1] = min_c_c
    max_cntrl[2] = max_c_r
    min_cntrl[2] = min_c_r
    max_cntrl[3] = max_c_r
    min_cntrl[3] = min_c_r
    max_cntrl[4] = max_c_r
    min_cntrl[4] = min_c_r
    max_cntrl[5] = max_c_r
    min_cntrl[5] = min_c_r
            
    return max_cntrl, min_cntrl

# %%
dur = 500.
t0_ = dur - 20.
t_pen = t0_/dur

# %%
bestControl_ = [None] * len(exc) 
bestState_ = [None] * len(exc) 
cost_ = [None] * len(exc) 
costnode_ = [None] * len(exc) 
weights_ = [None] * len(exc) 
convergence_ = [None] * len(exc) 

initVars = [None] * len(exc)
target = [None] * len(exc)
cost_uncontrolled = [None] * len(exc)
w_ = [None] * len(exc)
conv = [None] * len(exc)
conv_shift = [None] * len(exc)

# %%
file_ = '2_I.pickle'
folder = str(os.getcwd().split('data')[1])
print(folder)
case = str(folder[1])
# Out:
# /2

# %%
dur_pre = 10
dur_post = 10

n_pre = int(np.around(dur_pre/aln.params.dt + 1.,1))
n_post = int(np.around(dur_post/aln.params.dt + 1.,1))

tol = 1e-12
start_step = 10.
c_scheme = np.zeros(( 1,1 ))
c_scheme[0,0] = 1.
u_mat = np.identity(1)
u_scheme = np.array([[1.]])

if 'E' in file_:
    if case in ['1', '2']:
        c_var = [2]
    else:
        c_var = [3]
elif 'I' in file_:
    if case in ['1', '2']:
        c_var = [5]
    else:
        c_var = [4]
    
    
p_var = [0]

if case in ['1', '2']:    # low to high
    max_I = [3., -3.]
else:
    max_I = [-3., 3.]
    
if case in ['1', '3']:    # sparsity
    factor_ws = 1.
    factor_we = 0.
    cost_index = 2
else:
    factor_ws = 0.
    factor_we = 1.
    cost_index = 1
    
maxC = [5., -5., 0.2, 0.]
max_cntrl, min_cntrl = setmaxmincontrol(maxC[0], maxC[1], maxC[2], maxC[3])

# %%
if os.path.isfile(file_) :
    print("file found")
    
    with open(file_,'rb') as f:
        load_array = pickle.load(f)

    bestControl_ = load_array[0]
    bestState_ = load_array[1]
    cost_ = load_array[2]
    costnode_ = load_array[3]
    weights_ = load_array[4]

# %%
# get initial parameters and target states
i_range = np.arange(0, 73, 6)
#i_range = [1,2,3,4,5]
print(i_range)
#i_range = [50]

data.set_parameters(aln)

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    aln.params.duration = 3000.
    
    control0 = aln.getZeroControl()
    control0 = functions.step_control(aln, maxI_ = max_I[0])

    aln.run(control=control0)
    
    target_rates = np.zeros((2))
    target_rates[0] = aln.rates_exc[0,-1] 
    target_rates[1] = aln.rates_inh[0,-1]

    control0 = functions.step_control(aln, maxI_ = max_I[1])
    aln.run(control=control0)

    init_state_vars = np.zeros(( len(state_vars) ))
    for j in range(len(state_vars)):
        if aln.state[state_vars[j]].size == 1:
            init_state_vars[j] = aln.state[state_vars[j]][0]
        else:
            init_state_vars[j] = aln.state[state_vars[j]][0,-1]

    initVars[i] = init_state_vars
    target[i] = [target_rates[0], target_rates[1]]
# Out:
# [ 0  6 12 18 24 30 36 42 48 54 60 66 72]
# -------  0 0.4000000000000001 0.3500000000000001
# -------  6 0.4250000000000001 0.40000000000000013
# -------  12 0.47500000000000014 0.42500000000000016
# -------  18 0.4000000000000001 0.4750000000000002
# -------  24 0.4000000000000001 0.5000000000000002
# -------  30 0.4250000000000001 0.5250000000000002
# -------  36 0.4250000000000001 0.5500000000000003
# -------  42 0.4250000000000001 0.5750000000000003
# -------  48 0.4250000000000001 0.6000000000000003
# -------  54 0.5750000000000002 0.6000000000000003
# -------  60 0.5500000000000003 0.6250000000000003
# -------  66 0.5250000000000001 0.6500000000000004
# -------  72 0.5000000000000002 0.6750000000000004

# %%
# get uncontrolled cost

data.set_parameters(aln)

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    aln.params.duration = dur
    
    target_ = aln.getZeroTarget()
    target_[:,0,:] = target[i][0]
    target_[:,1,:] = target[i][1]
            
    cost.setParams(1.0, 0.0, 0.0)

    setinit(initVars[i], aln)
    control0 = aln.getZeroControl()

    # "HS", "FR", "PR", "HZ"
    cgv = None
    max_it = 0

    bestControl_init_, bestState_init_, cost_init_, runtime_init_, grad_init_, phi_init_, phi1_, costnode_init_ = aln.A1(
        control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
        prec_variables_ = p_var, transition_time_ = t_pen)
    
    cost_uncontrolled[i] = cost_init_[0]
# Out:
# -------  0 0.4000000000000001 0.3500000000000001
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  146855.39702821904
# RUN  0 , total integrated cost =  146855.39702821904
# Gradient descend method:  None
# RUN  0 , total integrated cost =  146855.39702821904
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  6 0.4250000000000001 0.40000000000000013
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  234849.86448361105
# RUN  0 , total integrated cost =  234849.86448361105
# Gradient descend method:  None
# RUN  0 , total integrated cost =  234849.86448361105
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  12 0.47500000000000014 0.42500000000000016
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  437181.9504061447
# RUN  0 , total integrated cost =  437181.9504061447
# Gradient descend method:  None
# RUN  0 , total integrated cost =  437181.9504061447
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  18 0.4000000000000001 0.4750000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  91340.63373509991
# RUN  0 , total integrated cost =  91340.63373509991
# Gradient descend method:  None
# RUN  0 , total integrated cost =  91340.63373509991
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  24 0.4000000000000001 0.5000000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  74168.6027044929
# RUN  0 , total integrated cost =  74168.6027044929
# Gradient descend method:  None
# RUN  0 , total integrated cost =  74168.6027044929
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  30 0.4250000000000001 0.5250000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  198505.2946572739
# RUN  0 , total integrated cost =  198505.2946572739
# Gradient descend method:  None
# RUN  0 , total integrated cost =  198505.2946572739
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  36 0.4250000000000001 0.5500000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  192617.3150952127
# RUN  0 , total integrated cost =  192617.3150952127
# Gradient descend method:  None
# RUN  0 , total integrated cost =  192617.3150952127
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  42 0.4250000000000001 0.5750000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  187081.7746701702
# RUN  0 , total integrated cost =  187081.7746701702
# Gradient descend method:  None
# RUN  0 , total integrated cost =  187081.7746701702
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  48 0.4250000000000001 0.6000000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  181882.521994222
# RUN  0 , total integrated cost =  181882.521994222
# Gradient descend method:  None
# RUN  0 , total integrated cost =  181882.521994222
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  54 0.5750000000000002 0.6000000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  870523.2701234882
# RUN  0 , total integrated cost =  870523.2701234882
# Gradient descend method:  None
# RUN  0 , total integrated cost =  870523.2701234882
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  60 0.5500000000000003 0.6250000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  741333.3077944894
# RUN  0 , total integrated cost =  741333.3077944894
# Gradient descend method:  None
# RUN  0 , total integrated cost =  741333.3077944894
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  66 0.5250000000000001 0.6500000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  615596.4660225171
# RUN  0 , total integrated cost =  615596.4660225171
# Gradient descend method:  None
# RUN  0 , total integrated cost =  615596.4660225171
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  72 0.5000000000000002 0.6750000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  495331.1329655588
# RUN  0 , total integrated cost =  495331.1329655588
# Gradient descend method:  None
# RUN  0 , total integrated cost =  495331.1329655588
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.

# %%
bad = [18, 24, 30, 36, 42, 48, 54, 60, 66, 72]

# %%
cgv = None
j = 0
c_var = [5]

wp = 1.

for i in i_range:

    print("------- ", i, exc[i], inh[i])
    
    if type(bestControl_[i]) != type(None) or i in bad:
        continue
        
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
        
    found_exponent = False
    found_digit_0 = False
    found_digit_1 = False
    exponent = 6
    sig_digit = [1., 0.]
    
    while not found_digit_1:
        
        if exponent < -10:
            bad.append(i)
            break
            
        if found_digit_0 and np.amax(np.abs(bestControl_[i])) < 1e-8:
            bad.append(i)
            break
        
        w_[i] = sig_digit[0] * 10**exponent + sig_digit[1] * 10**(exponent-1.)
    
        aln.params.duration = dur
        setinit(initVars[i], aln)

        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        control0 = aln.getZeroControl()
        cost.setParams(wp, factor_we * w_[i], factor_ws * w_[i])
        max_it = int(10)
        if found_digit_0:
            max_it = int(50)

        bestControl_[i], bestState_[i], cost_[i], runtime_, grad_, phi_, phi1_, costnode_[i] = aln.A1(
            control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
            prec_variables_ = p_var, transition_time_ = t_pen)
        
        if found_exponent == False and cost_[i][-1] == 0.:
            exponent -= 1
            continue
        elif found_exponent == False and found_digit_0 == False:
            found_exponent = True
            sig_digit[0] = 9.
        elif found_exponent == True and found_digit_0 == False and cost_[i][-1] == 0.:
            sig_digit[0] -= 1.
        elif found_exponent == True and found_digit_0 == False:
            found_digit_0 = True
            sig_digit[1] = 9.
        elif found_exponent == True and found_digit_0 == True and found_digit_1 == False and cost_[i][-1] == 0.:
            sig_digit[1] -= 1.
        elif found_exponent == True and found_digit_0 == True and found_digit_1 == False:
            print("weight = ", w_[i])
            
            if True:
                plot_time_array = np.arange(0.,round(dur+aln.params.dt,1),aln.params.dt)
                target_ = aln.getZeroTarget()
                target_[:,0,:] = target[i][0]
                target_[:,1,:] = target[i][1]

                fig, ax = plt.subplots(3,1, constrained_layout=True, figsize = (4,8) )
                
                ax[0].plot(plot_time_array, bestState_[i][0,0,n_pre-1:-n_post+1], color= 'red')
                ax[0].plot(plot_time_array, bestState_[i][0,1,n_pre-1:-n_post+1], color= 'blue')
                ax[0].plot(plot_time_array, target_[0,0,n_pre-1:-n_post+1], linestyle = '--', color='red')
                ax[0].plot(plot_time_array, target_[0,1,n_pre-1:-n_post+1], linestyle = '--', color='blue')
                
                ax[1].plot(plot_time_array, bestControl_[i][0,3,n_pre-1:-n_post+1], color = 'blue')
                ax[1].plot(plot_time_array, bestControl_[i][0,2,n_pre-1:-n_post+1], color = 'red')

                ax[2].plot(plot_time_array, bestControl_[i][0,4,n_pre-1:-n_post+1], color = 'red')
                ax[2].plot(plot_time_array, bestControl_[i][0,5,n_pre-1:-n_post+1], color = 'blue')
                
                for k in range(3):
                    ax[k].set_xlim(0.,dur)
                    ax[k].axvspan(dur*t_pen, dur, alpha=0.2, color='gray')
                plt.show()
             
            if np.amax(np.abs(bestControl_[i])) > 1e-4:
                with open(file_,'wb') as f:
                    pickle.dump([bestControl_, bestState_, cost_, costnode_, weights_], f)

            print('uncontrolled cost : ', cost_uncontrolled[i])
            print('cost splitting : ', costnode_[i][0][0][0], costnode_[i][cost_index][0][2:])    

            break
# Out:
# -------  0 0.4000000000000001 0.3500000000000001
# set cost params:  1.0 1000000.0 0.0
# interpolate adjoint :  True True True
# initial cost =  146855.39702821904
# RUN  0 , total integrated cost =  146855.39702821904
# Gradient descend method:  None
# RUN  1 , total integrated cost =  28392.451885111135
# RUN  2 , total integrated cost =  15639.887992440414
# RUN  3 , total integrated cost =  15165.219929626635
# RUN  4 , total integrated cost =  3371.285504346405
# RUN  5 , total integrated cost =  2714.2793168784665
# RUN  6 , total integrated cost =  2681.7995175724022
# RUN  7 , total integrated cost =  2650.066330325562
# RUN  8 , total integrated cost =  2618.1514862806594
# RUN  9 , total integrated cost =  2590.1639790972226
# RUN  10 , total integrated cost =  2562.417685918906
# RUN  10 , total integrated cost =  2562.417685918906
# Improved over  10  iterations in  11.247370722994674  seconds by  98.25514231157162  percent.
# set cost params:  1.0 9000000.0 0.0
# interpolate adjoint :  True True True
# initial cost =  146855.39702821904
# RUN  0 , total integrated cost =  146855.39702821904
# Gradient descend method:  None
# RUN  1 , total integrated cost =  61390.04059110536
# RUN  2 , total integrated cost =  48031.208621247744
# RUN  3 , total integrated cost =  22768.64351575804
# RUN  4 , total integrated cost =  21201.85750231626
# RUN  5 , total integrated cost =  20425.901303015908
# RUN  6 , total integrated cost =  19672.109320163298
# RUN  7 , total integrated cost =  19210.59973208861
# RUN  8 , total integrated cost =  18789.078346403538
# RUN  9 , total integrated cost =  18538.111089767393
# RUN  10 , total integrated cost =  18304.337610297
# RUN  10 , total integrated cost =  18304.337610297
# Improved over  10  iterations in  0.7805505050346255  seconds by  87.53580870658793  percent.
# set cost params:  1.0 9900000.0 0.0
# interpolate adjoint :  True True True
# initial cost =  146855.39702821904
# RUN  0 , total integrated cost =  146855.39702821904
# Gradient descend method:  None
# RUN  1 , total integrated cost =  64602.52217977059
# RUN  2 , total integrated cost =  50211.251995225495
# RUN  3 , total integrated cost =  23042.389318006575
# RUN  4 , total integrated cost =  21073.465868060415
# RUN  5 , total integrated cost =  20415.140515501556
# RUN  6 , total integrated cost =  19948.48358359896
# RUN  7 , total integrated cost =  19651.14436162252
# RUN  8 , total integrated cost =  19332.927876152273
# RUN  9 , total integrated cost =  19128.2588740902
# RUN  10 , total integrated cost =  18811.94318963051
# RUN  11 , total integrated cost =  18695.6980216245
# RUN  12 , total integrated cost =  18564.538669842612
# RUN  13 , total integrated cost =  18490.848688881943
# RUN  14 , total integrated cost =  18407.262705272955
# RUN  15 , total integrated cost =  18351.357149716372
# RUN  16 , total integrated cost =  18331.173964156114
# RUN  17 , total integrated cost =  18315.000475600362
# RUN  18 , total integrated cost =  18296.534512501843
# RUN  19 , total integrated cost =  18280.045236674825
# RUN  20 , total integrated cost =  18260.65219126518
# RUN  30 , total integrated cost =  18082.606013706394
# RUN  40 , total integrated cost =  17058.2891020581
# RUN  50 , total integrated cost =  16174.589344903352
# RUN  50 , total integrated cost =  16174.589344903352
# Improved over  50  iterations in  3.5754108669934794  seconds by  88.98604363733713  percent.
# weight =  9900000.0
# uncontrolled cost :  146855.39702821904
# cost splitting :  64.8807529739598 [0.         0.         0.         0.00147074]
# -------  6 0.4250000000000001 0.40000000000000013
# set cost params:  1.0 1000000.0 0.0
# interpolate adjoint :  True True True
# initial cost =  234849.86448361105
# RUN  0 , total integrated cost =  234849.86448361105
# Gradient descend method:  None
# RUN  1 , total integrated cost =  228992.39936372457
# RUN  2 , total integrated cost =  119797.52407084568
# RUN  3 , total integrated cost =  75246.7354772824
# RUN  4 , total integrated cost =  53819.77652224081
# RUN  5 , total integrated cost =  46535.06500473922
# RUN  6 , total integrated cost =  44214.98105807263
# RUN  7 , total integrated cost =  42145.76501924711
# RUN  8 , total integrated cost =  40788.76916782227
# RUN  9 , total integrated cost =  39089.574532718754
# RUN  10 , total integrated cost =  37845.109275101844
# RUN  10 , total integrated cost =  37845.109275101844
# Improved over  10  iterations in  0.7259079799987376  seconds by  83.88540297508119  percent.
# set cost params:  1.0 9000000.0 0.0
# interpolate adjoint :  True True True
# initial cost =  234849.86448361105
# RUN  0 , total integrated cost =  234849.86448361105
# Gradient descend method:  None
# RUN  1 , total integrated cost =  234832.07739918915
# RUN  2 , total integrated cost =  234832.0771454258
# RUN  3 , total integrated cost =  234832.0771452466
# RUN  4 , total integrated cost =  234832.07714524656
# RUN  5 , total integrated cost =  234832.07714524656
# Control only changes marginally.
# RUN  5 , total integrated cost =  234832.07714524656
# Improved over  5  iterations in  0.5242869170033373  seconds by  0.007573918939058899  percent.
# set cost params:  1.0 8000000.0 0.0
# interpolate adjoint :  True True True
# initial cost =  234849.86448361105
# RUN  0 , total integrated cost =  234849.86448361105
# Gradient descend method:  None
# RUN  1 , total integrated cost =  234829.88474099888
# RUN  2 , total integrated cost =  234829.83441567732
# RUN  3 , total integrated cost =  234829.83441567732
# Control only changes marginally.
# RUN  3 , total integrated cost =  234829.83441567732
# Improved over  3  iterations in  0.3322883730288595  seconds by  0.008528882048864261  percent.
# set cost params:  1.0 7000000.0 0.0
# interpolate adjoint :  True True True
# initial cost =  234849.86448361105
# RUN  0 , total integrated cost =  234849.86448361105
# Gradient descend method:  None
# RUN  1 , total integrated cost =  234826.9790805277
# RUN  2 , total integrated cost =  234826.9450520471
# RUN  3 , total integrated cost =  234826.94505178067
# RUN  4 , total integrated cost =  234826.94505178058
# RUN  5 , total integrated cost =  234826.94505178058
# Control only changes marginally.
# RUN  5 , total integrated cost =  234826.94505178058
# Improved over  5  iterations in  0.45415711001260206  seconds by  0.009759184609649196  percent.
# set cost params:  1.0 6000000.0 0.0
# interpolate adjoint :  True True True
# initial cost =  234849.86448361105
# RUN  0 , total integrated cost =  234849.86448361105
# Gradient descend method:  None
# RUN  1 , total integrated cost =  234823.09725977242
# RUN  2 , total integrated cost =  234823.08180748762
# RUN  3 , total integrated cost =  234823.08176600962
# RUN  4 , total integrated cost =  234823.08176600962
# Control only changes marginally.
# RUN  4 , total integrated cost =  234823.08176600962
# Improved over  4  iterations in  0.37379370303824544  seconds by  0.01140418695165124  percent.
# set cost params:  1.0 5000000.0 0.0
# interpolate adjoint :  True True True
# initial cost =  234849.86448361105
# RUN  0 , total integrated cost =  234849.86448361105
# Gradient descend method:  None
# RUN  1 , total integrated cost =  234817.69242781567
# RUN  2 , total integrated cost =  234817.65247519128
# RUN  3 , total integrated cost =  234817.6524230429
# RUN  4 , total integrated cost =  234817.6524230427
# RUN  5 , total integrated cost =  234817.6524230427
# Control only changes marginally.
# RUN  5 , total integrated cost =  234817.6524230427
# Improved over  5  iterations in  0.46008698199875653  seconds by  0.013716022633943226  percent.
# set cost params:  1.0 4000000.0 0.0
# interpolate adjoint :  True True True
# initial cost =  234849.86448361105
# RUN  0 , total integrated cost =  234849.86448361105
# Gradient descend method:  None
# RUN  1 , total integrated cost =  234809.6104042463
# RUN  2 , total integrated cost =  234809.48110253038
# RUN  3 , total integrated cost =  234809.48110253038
# Control only changes marginally.
# RUN  3 , total integrated cost =  234809.48110253038
# Improved over  3  iterations in  0.31305896799312904  seconds by  0.0171954031863919  percent.
# set cost params:  1.0 3000000.0 0.0
# interpolate adjoint :  True True True
# initial cost =  234849.86448361105
# RUN  0 , total integrated cost =  234849.86448361105
# Gradient descend method:  None
# RUN  1 , total integrated cost =  234783.7858539804
# RUN  2 , total integrated cost =  234783.73991035513
# RUN  3 , total integrated cost =  234783.73991035504
# RUN  4 , total integrated cost =  234783.73991035504
# Control only changes marginally.
# RUN  4 , total integrated cost =  234783.73991035504
# Improved over  4  iterations in  0.3989066799986176  seconds by  0.02815610449739836  percent.
# set cost params:  1.0 2000000.0 0.0
# interpolate adjoint :  True True True
# initial cost =  234849.86448361105
# RUN  0 , total integrated cost =  234849.86448361105
# Gradient descend method:  None
# RUN  1 , total integrated cost =  234723.40357384403
# RUN  2 , total integrated cost =  234722.61656244175
# RUN  3 , total integrated cost =  234722.61590422338
# RUN  4 , total integrated cost =  234722.61590422338
# Control only changes marginally.
# RUN  4 , total integrated cost =  234722.61590422338
# Improved over  4  iterations in  0.3710642569931224  seconds by  0.05418294776004018  percent.
# set cost params:  1.0 1000000.0 0.0
# interpolate adjoint :  True True True
# initial cost =  234849.86448361105
# RUN  0 , total integrated cost =  234849.86448361105
# Gradient descend method:  None
# RUN  1 , total integrated cost =  228992.39936372457
# RUN  2 , total integrated cost =  119797.52407084568
# RUN  3 , total integrated cost =  75246.7354772824
# RUN  4 , total integrated cost =  53819.77652224081
# RUN  5 , total integrated cost =  46535.06500473922
# RUN  6 , total integrated cost =  44214.98105807263
# RUN  7 , total integrated cost =  42145.76501924711
# RUN  8 , total integrated cost =  40788.76916782227
# RUN  9 , total integrated cost =  39089.574532718754
# RUN  10 , total integrated cost =  37845.109275101844
# RUN  10 , total integrated cost =  37845.109275101844
# Improved over  10  iterations in  0.7375421759788878  seconds by  83.88540297508119  percent.
# set cost params:  1.0 1900000.0 0.0
# interpolate adjoint :  True True True
# initial cost =  234849.86448361105
# RUN  0 , total integrated cost =  234849.86448361105
# Gradient descend method:  None
# RUN  1 , total integrated cost =  234708.18871240108
# RUN  2 , total integrated cost =  234706.74977101208
# RUN  3 , total integrated cost =  234706.73597057688
# RUN  4 , total integrated cost =  234706.73270322103
# RUN  5 , total integrated cost =  234706.73254584117
# RUN  6 , total integrated cost =  234706.73252133615
# RUN  7 , total integrated cost =  234706.7323219032
# RUN  8 , total integrated cost =  234706.73218829604
# RUN  9 , total integrated cost =  234706.73218829604
# Control only changes marginally.
# RUN  9 , total integrated cost =  234706.73218829604
# Improved over  9  iterations in  0.6771971129928716  seconds by  0.060946296745683526  percent.
# set cost params:  1.0 1800000.0 0.0
# interpolate adjoint :  True True True
# initial cost =  234849.86448361105
# RUN  0 , total integrated cost =  234849.86448361105
# Gradient descend method:  None
# RUN  1 , total integrated cost =  234689.72494807348
# RUN  2 , total integrated cost =  234688.66711895406
# RUN  3 , total integrated cost =  179174.08231036988
# RUN  4 , total integrated cost =  127296.11571331705
# RUN  5 , total integrated cost =  87475.00968225472
# RUN  6 , total integrated cost =  78071.41965291467
# RUN  7 , total integrated cost =  72625.69818135754
# RUN  8 , total integrated cost =  70066.69085120557
# RUN  9 , total integrated cost =  67654.85603241772
# RUN  10 , total integrated cost =  66033.90385835826
# RUN  11 , total integrated cost =  64215.39941056828
# RUN  12 , total integrated cost =  62822.38168575729
# RUN  13 , total integrated cost =  60957.06086651521
# RUN  14 , total integrated cost =  59524.02404859408
# RUN  15 , total integrated cost =  57821.04139161302
# RUN  16 , total integrated cost =  56441.48101715853
# RUN  17 , total integrated cost =  52732.460687076935
# RUN  18 , total integrated cost =  51133.1504322901
# RUN  19 , total integrated cost =  49862.727768878234
# RUN  20 , total integrated cost =  49220.2324872842
# RUN  30 , total integrated cost =  40359.573055031404
# RUN  40 , total integrated cost =  38936.25733071664
# RUN  50 , total integrated cost =  38076.93246070227
# RUN  50 , total integrated cost =  38076.93246070227
# Improved over  50  iterations in  3.583861425984651  seconds by  83.78669174690562  percent.
# weight =  1800000.0
# uncontrolled cost :  234849.86448361105
# cost splitting :  127.31158470034998 [0.         0.         0.         0.01939408]
# -------  12 0.47500000000000014 0.42500000000000016
# set cost params:  1.0 1000000.0 0.0
# interpolate adjoint :  True True True
# initial cost =  437181.9504061447
# RUN  0 , total integrated cost =  437181.9504061447
# Gradient descend method:  None
# RUN  1 , total integrated cost =  432313.088045245
# RUN  2 , total integrated cost =  385679.7709711089
# RUN  3 , total integrated cost =  263460.37731642975
# RUN  4 , total integrated cost =  210395.9400712204
# RUN  5 , total integrated cost =  164703.7644613234
# RUN  6 , total integrated cost =  125247.44548095275
# RUN  7 , total integrated cost =  92426.60926269232
# RUN  8 , total integrated cost =  74974.63217568294
# RUN  9 , total integrated cost =  65490.44021160408
# RUN  10 , total integrated cost =  61930.31385693835
# RUN  10 , total integrated cost =  61930.31385693835
# Improved over  10  iterations in  0.7158818859606981  seconds by  85.83420157227334  percent.
# set cost params:  1.0 9000000.0 0.0
# interpolate adjoint :  True True True
# initial cost =  437181.9504061447
# RUN  0 , total integrated cost =  437181.9504061447
# Gradient descend method:  None
# RUN  1 , total integrated cost =  437004.5469216567
# RUN  2 , total integrated cost =  437003.92388070765
# RUN  3 , total integrated cost =  437003.9188783586
# RUN  4 , total integrated cost =  437003.9188783586
# Control only changes marginally.
# RUN  4 , total integrated cost =  437003.9188783586
# Improved over  4  iterations in  0.3883407019893639  seconds by  0.04072252471098636  percent.
# set cost params:  1.0 8000000.0 0.0
# interpolate adjoint :  True True True
# initial cost =  437181.9504061447
# RUN  0 , total integrated cost =  437181.9504061447
# Gradient descend method:  None
# RUN  1 , total integrated cost =  436981.9539873254
# RUN  2 , total integrated cost =  436981.4001891539
# RUN  3 , total integrated cost =  436981.39660272445
# RUN  4 , total integrated cost =  436981.39660272445
# Control only changes marginally.
# RUN  4 , total integrated cost =  436981.39660272445
# Improved over  4  iterations in  0.4098207239876501  seconds by  0.04587421855681839  percent.
# set cost params:  1.0 7000000.0 0.0
# interpolate adjoint :  True True True
# initial cost =  437181.9504061447
# RUN  0 , total integrated cost =  437181.9504061447
# Gradient descend method:  None
# RUN  1 , total integrated cost =  436953.45192089584
# RUN  2 , total integrated cost =  436952.5866895485
# RUN  3 , total integrated cost =  436952.58452715806
# RUN  4 , total integrated cost =  436952.58452715806
# Control only changes marginally.
# RUN  4 , total integrated cost =  436952.58452715806
# Improved over  4  iterations in  0.3836424420005642  seconds by  0.052464626861564057  percent.
# set cost params:  1.0 6000000.0 0.0
# interpolate adjoint :  True True True
# initial cost =  437181.9504061447
# RUN  0 , total integrated cost =  437181.9504061447
# Gradient descend method:  None
# RUN  1 , total integrated cost =  436915.51806159713
# RUN  2 , total integrated cost =  436914.4285022496
# RUN  3 , total integrated cost =  436914.4220582039
# RUN  4 , total integrated cost =  436914.42205294897
# RUN  5 , total integrated cost =  436914.42205292877
# RUN  6 , total integrated cost =  436914.4220529286
# RUN  7 , total integrated cost =  436914.4220529285
# RUN  8 , total integrated cost =  436914.4220529285
# Control only changes marginally.
# RUN  8 , total integrated cost =  436914.4220529285
# Improved over  8  iterations in  0.641371771984268  seconds by  0.06119382398283335  percent.
# set cost params:  1.0 5000000.0 0.0
# interpolate adjoint :  True True True
# initial cost =  437181.9504061447
# RUN  0 , total integrated cost =  437181.9504061447
# Gradient descend method:  None
# RUN  1 , total integrated cost =  436863.749624997
# RUN  2 , total integrated cost =  436861.4861691624
# RUN  3 , total integrated cost =  436861.4759897345
# RUN  4 , total integrated cost =  436861.4759897345
# Control only changes marginally.
# RUN  4 , total integrated cost =  436861.4759897345
# Improved over  4  iterations in  0.3663734039873816  seconds by  0.07330458545062868  percent.
# set cost params:  1.0 4000000.0 0.0
# interpolate adjoint :  True True True
# initial cost =  437181.9504061447
# RUN  0 , total integrated cost =  437181.9504061447
# Gradient descend method:  None
# RUN  1 , total integrated cost =  436785.95951262343
# RUN  2 , total integrated cost =  436783.0974354216
# RUN  3 , total integrated cost =  436783.08720379724
# RUN  4 , total integrated cost =  436783.08720379724
# Control only changes marginally.
# RUN  4 , total integrated cost =  436783.08720379724
# Improved over  4  iterations in  0.5183500029961579  seconds by  0.0912350571602758  percent.
# set cost params:  1.0 3000000.0 0.0
# interpolate adjoint :  True True True
# initial cost =  437181.9504061447
# RUN  0 , total integrated cost =  437181.9504061447
# Gradient descend method:  None
# RUN  1 , total integrated cost =  436575.8248677349
# RUN  2 , total integrated cost =  436564.5804962494
# RUN  3 , total integrated cost =  436564.53155182843
# RUN  4 , total integrated cost =  436564.531551828
# RUN  5 , total integrated cost =  436564.531551828
# Control only changes marginally.
# RUN  5 , total integrated cost =  436564.531551828
# Improved over  5  iterations in  0.48473336797906086  seconds by  0.1412269774045143  percent.
# set cost params:  1.0 2000000.0 0.0
# interpolate adjoint :  True True True
# initial cost =  437181.9504061447
# RUN  0 , total integrated cost =  437181.9504061447
# Gradient descend method:  None
# RUN  1 , total integrated cost =  436061.0255744051
# RUN  2 , total integrated cost =  435989.837478195
# RUN  3 , total integrated cost =  435987.376099426
# RUN  4 , total integrated cost =  435960.19901485275
# RUN  5 , total integrated cost =  435947.73451193975
# RUN  6 , total integrated cost =  435945.9133444266
# RUN  7 , total integrated cost =  435945.74039442616
# RUN  8 , total integrated cost =  435945.7389473279
# RUN  9 , total integrated cost =  435945.7389473278
# RUN  10 , total integrated cost =  435945.7389473278
# Control only changes marginally.
# RUN  10 , total integrated cost =  435945.7389473278
# Improved over  10  iterations in  0.8654125210014172  seconds by  0.28276818328582465  percent.
# set cost params:  1.0 2900000.0 0.0
# interpolate adjoint :  True True True
# initial cost =  437181.9504061447
# RUN  0 , total integrated cost =  437181.9504061447
# Gradient descend method:  None
# RUN  1 , total integrated cost =  436548.0996980276
# RUN  2 , total integrated cost =  436535.0161293744
# RUN  3 , total integrated cost =  436534.9840805987
# RUN  4 , total integrated cost =  436534.9840805987
# Control only changes marginally.
# RUN  4 , total integrated cost =  436534.9840805987
# Improved over  4  iterations in  0.4094023850047961  seconds by  0.14798559843218584  percent.
# set cost params:  1.0 2800000.0 0.0
# interpolate adjoint :  True True True
# initial cost =  437181.9504061447
# RUN  0 , total integrated cost =  437181.9504061447
# Gradient descend method:  None
# RUN  1 , total integrated cost =  436518.35664280347
# RUN  2 , total integrated cost =  436503.55447353167
# RUN  3 , total integrated cost =  436503.4468315635
# RUN  4 , total integrated cost =  436503.4468193893
# RUN  5 , total integrated cost =  436503.44681934937
# RUN  6 , total integrated cost =  436503.446819349
# RUN  7 , total integrated cost =  436503.446819349
# Control only changes marginally.
# RUN  7 , total integrated cost =  436503.446819349
# Improved over  7  iterations in  0.5781384349684231  seconds by  0.15519935948073282  percent.
# set cost params:  1.0 2700000.0 0.0
# interpolate adjoint :  True True True
# initial cost =  437181.9504061447
# RUN  0 , total integrated cost =  437181.9504061447
# Gradient descend method:  None
# RUN  1 , total integrated cost =  436484.12803822657
# RUN  2 , total integrated cost =  436469.82377257146
# RUN  3 , total integrated cost =  436469.7285082065
# RUN  4 , total integrated cost =  436469.72801772895
# RUN  5 , total integrated cost =  436469.7280177288
# RUN  6 , total integrated cost =  436469.7280177286
# RUN  7 , total integrated cost =  436469.7280177286
# Control only changes marginally.
# RUN  7 , total integrated cost =  436469.7280177286
# Improved over  7  iterations in  0.5919838040135801  seconds by  0.16291212108698971  percent.
# set cost params:  1.0 2600000.0 0.0
# interpolate adjoint :  True True True
# initial cost =  437181.9504061447
# RUN  0 , total integrated cost =  437181.9504061447
# Gradient descend method:  None
# RUN  1 , total integrated cost =  436449.8994336496
# RUN  2 , total integrated cost =  436433.67005082325
# RUN  3 , total integrated cost =  436433.6027911591
# RUN  4 , total integrated cost =  436433.6026305849
# RUN  5 , total integrated cost =  436433.6026305847
# RUN  6 , total integrated cost =  436433.6026305847
# Control only changes marginally.
# RUN  6 , total integrated cost =  436433.6026305847
# Improved over  6  iterations in  0.7476863760384731  seconds by  0.1711753595647849  percent.
# set cost params:  1.0 2500000.0 0.0
# interpolate adjoint :  True True True
# initial cost =  437181.9504061447
# RUN  0 , total integrated cost =  437181.9504061447
# Gradient descend method:  None
# RUN  1 , total integrated cost =  436413.16250476945
# RUN  2 , total integrated cost =  436394.96028189233
# RUN  3 , total integrated cost =  436394.7954823956
# RUN  4 , total integrated cost =  436394.7952675927
# RUN  5 , total integrated cost =  436394.79526681703
# RUN  6 , total integrated cost =  436394.7952668165
# RUN  7 , total integrated cost =  436394.7952668163
# RUN  8 , total integrated cost =  436394.7952668162
# RUN  9 , total integrated cost =  436394.7952668162
# Control only changes marginally.
# RUN  9 , total integrated cost =  436394.7952668162
# Improved over  9  iterations in  0.7455961860250682  seconds by  0.1800520672450574  percent.
# set cost params:  1.0 2400000.0 0.0
# interpolate adjoint :  True True True
# initial cost =  437181.9504061447
# RUN  0 , total integrated cost =  437181.9504061447
# Gradient descend method:  None
# RUN  1 , total integrated cost =  436362.90560029645
# RUN  2 , total integrated cost =  436322.36945510446
# RUN  3 , total integrated cost =  436319.95505289687
# RUN  4 , total integrated cost =  436319.78023693507
# RUN  5 , total integrated cost =  436319.7798676461
# RUN  6 , total integrated cost =  436319.7798668653
# RUN  7 , total integrated cost =  436319.7798668653
# Control only changes marginally.
# RUN  7 , total integrated cost =  436319.7798668653
# Improved over  7  iterations in  0.5812176140025258  seconds by  0.1972109183552675  percent.
# set cost params:  1.0 2300000.0 0.0
# interpolate adjoint :  True True True
# initial cost =  437181.9504061447
# RUN  0 , total integrated cost =  437181.9504061447
# Gradient descend method:  None
# RUN  1 , total integrated cost =  436297.63993911364
# RUN  2 , total integrated cost =  436249.3761090455
# RUN  3 , total integrated cost =  436247.9309725402
# RUN  4 , total integrated cost =  436247.87141114264
# RUN  5 , total integrated cost =  436247.8713936018
# RUN  6 , total integrated cost =  436247.8713936015
# Control only changes marginally.
# RUN  6 , total integrated cost =  436247.8713936015
# Improved over  6  iterations in  0.5262796679744497  seconds by  0.2136590981570663  percent.
# set cost params:  1.0 2200000.0 0.0
# interpolate adjoint :  True True True
# initial cost =  437181.9504061447
# RUN  0 , total integrated cost =  437181.9504061447
# Gradient descend method:  None
# RUN  1 , total integrated cost =  436225.847276271
# RUN  2 , total integrated cost =  436170.5960764417
# RUN  3 , total integrated cost =  436168.9527287153
# RUN  4 , total integrated cost =  436168.9003570907
# RUN  5 , total integrated cost =  436168.9001823662
# RUN  6 , total integrated cost =  436168.9001823498
# RUN  7 , total integrated cost =  436168.9001823494
# RUN  8 , total integrated cost =  436168.9001823494
# Control only changes marginally.
# RUN  8 , total integrated cost =  436168.9001823494
# Improved over  8  iterations in  0.7290474770125002  seconds by  0.2317227925018841  percent.
# set cost params:  1.0 2100000.0 0.0
# interpolate adjoint :  True True True
# initial cost =  437181.9504061447
# RUN  0 , total integrated cost =  437181.9504061447
# Gradient descend method:  None
# RUN  1 , total integrated cost =  436148.6508021221
# RUN  2 , total integrated cost =  436084.272690782
# RUN  3 , total integrated cost =  436082.5502985291
# RUN  4 , total integrated cost =  436082.52636451565
# RUN  5 , total integrated cost =  436082.52636451565
# Control only changes marginally.
# RUN  5 , total integrated cost =  436082.52636451565
# Improved over  5  iterations in  0.43847014202037826  seconds by  0.2514797421548849  percent.
# set cost params:  1.0 2000000.0 0.0
# interpolate adjoint :  True True True
# initial cost =  437181.9504061447
# RUN  0 , total integrated cost =  437181.9504061447
# Gradient descend method:  None
# RUN  1 , total integrated cost =  436061.0255744051
# RUN  2 , total integrated cost =  435989.837478195
# RUN  3 , total integrated cost =  435987.376099426
# RUN  4 , total integrated cost =  435960.19901485275
# RUN  5 , total integrated cost =  435947.73451193975
# RUN  6 , total integrated cost =  435945.9133444266
# RUN  7 , total integrated cost =  435945.74039442616
# RUN  8 , total integrated cost =  435945.7389473279
# RUN  9 , total integrated cost =  435945.7389473278
# RUN  10 , total integrated cost =  435945.7389473278
# Control only changes marginally.
# RUN  10 , total integrated cost =  435945.7389473278
# Improved over  10  iterations in  0.8025484150275588  seconds by  0.28276818328582465  percent.
# set cost params:  1.0 1900000.0 0.0
# interpolate adjoint :  True True True
# initial cost =  437181.9504061447
# RUN  0 , total integrated cost =  437181.9504061447
# Gradient descend method:  None
# RUN  1 , total integrated cost =  435962.3746309895
# RUN  2 , total integrated cost =  435806.04963594145
# RUN  3 , total integrated cost =  435791.318464962
# RUN  4 , total integrated cost =  435790.05983804894
# RUN  5 , total integrated cost =  435790.0093732496
# RUN  6 , total integrated cost =  435790.00937324954
# RUN  7 , total integrated cost =  435790.0093732495
# Control only changes marginally.
# RUN  7 , total integrated cost =  435790.0093732495
# Improved over  7  iterations in  0.7081718510016799  seconds by  0.3183894100847766  percent.
# set cost params:  1.0 1800000.0 0.0
# interpolate adjoint :  True True True
# initial cost =  437181.9504061447
# RUN  0 , total integrated cost =  437181.9504061447
# Gradient descend method:  None
# RUN  1 , total integrated cost =  435825.3907255492
# RUN  2 , total integrated cost =  435627.6854838925
# RUN  3 , total integrated cost =  399023.0839943321
# RUN  4 , total integrated cost =  320529.4148112752
# RUN  5 , total integrated cost =  250316.84491614922
# RUN  6 , total integrated cost =  206975.80765417317
# RUN  7 , total integrated cost =  165474.74341960478
# RUN  8 , total integrated cost =  141985.2302985381
# RUN  9 , total integrated cost =  123779.9468486505
# RUN  10 , total integrated cost =  115969.03893154368
# RUN  11 , total integrated cost =  105038.52117377572
# RUN  12 , total integrated cost =  98909.88957071371
# RUN  13 , total integrated cost =  88057.26218142002
# RUN  14 , total integrated cost =  83410.9546477667
# RUN  15 , total integrated cost =  79682.48186112937
# RUN  16 , total integrated cost =  77622.65359499637
# RUN  17 , total integrated cost =  74999.77140114894
# RUN  18 , total integrated cost =  73230.8797431952
# RUN  19 , total integrated cost =  67812.34473382494
# RUN  20 , total integrated cost =  65580.20939687044
# RUN  30 , total integrated cost =  54160.58949824017
# RUN  40 , total integrated cost =  51346.03086664345
# RUN  50 , total integrated cost =  46838.298847462254
# RUN  50 , total integrated cost =  46838.298847462254
# Improved over  50  iterations in  3.7523430829751305  seconds by  89.2863145873362  percent.
# weight =  1800000.0
# uncontrolled cost :  437181.9504061447
# cost splitting :  64.46094453316732 [0.         0.         0.         0.02513026]
# -------  18 0.4000000000000001 0.4750000000000002
# -------  24 0.4000000000000001 0.5000000000000002
# -------  30 0.4250000000000001 0.5250000000000002
# -------  36 0.4250000000000001 0.5500000000000003
# -------  42 0.4250000000000001 0.5750000000000003
# -------  48 0.4250000000000001 0.6000000000000003
# -------  54 0.5750000000000002 0.6000000000000003
# -------  60 0.5500000000000003 0.6250000000000003
# -------  66 0.5250000000000001 0.6500000000000004
# -------  72 0.5000000000000002 0.6750000000000004

# %%
print(bad)
# Out:
# [18, 24, 30, 42, 48, 54, 60, 66]

# %%
if os.path.isfile(file_) :
    print("file found")
    
    with open(file_,'rb') as f:
        load_array = pickle.load(f)

    bestControl_ = load_array[0]
    bestState_ = load_array[1]
    cost_ = load_array[2]
    costnode_ = load_array[3]
    weights_ = load_array[4]
# Out:
# file found

# %%
tol = 1e-6
conv = [None] * len(exc)
c_var = [2,3,4,5]

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    k = 0
    if i in bad:
        continue
        
    while not conv[i]:
        print('--------------- k ', k)
        max_it = min(1000, int(100*k))
        
        if k == 0:
            max_it = 100
            weight_ = w_[i]
        else:
            weight_ = ( cost_uncontrolled[i] - costnode_[i][0][0][0] ) / sum( costnode_[i][cost_index][0][:] )
            if k < 100:
                weight_ = w_[i] + 0.01 *k * (weight_ - w_[i])
            
        aln.params.duration = dur
        cost.setParams(1., weight_ * factor_we, weight_ * factor_ws)
        weights_[i] = cost.getParams()

        setinit(initVars[i], aln)

        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        control0 = aln.getZeroControl()
        control0 = bestControl_[i][:,:,n_pre-1:-n_post+1]

        bestControl_[i], bestState_[i], cost_[i], runtime_, grad_, phi_, phi1_, costnode_[i] = aln.A1(
            control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
            prec_variables_ = p_var, transition_time_ = t_pen)
        
        if cost_[i][2] == 0.:
            if k > 100:
                conv[i] = True
            else: 
                k += 10
        

        #print('uncontrolled cost : ', cost_uncontrolled[i])
        print('cost splitting : ', costnode_[i][0][0][0], costnode_[i][cost_index][0][2:])

        if conv[i]:
            plot_time_array = np.arange(0.,round(dur+aln.params.dt,1),aln.params.dt)
            target_ = aln.getZeroTarget()
            target_[:,0,:] = target[i][0]
            target_[:,1,:] = target[i][1]

            fig, ax = plt.subplots(3,1, constrained_layout=True, figsize = (4,8) )

            ax[0].plot(plot_time_array, bestState_[i][0,0,n_pre-1:-n_post+1], color= 'red')
            ax[0].plot(plot_time_array, bestState_[i][0,1,n_pre-1:-n_post+1], color= 'blue')
            ax[0].plot(plot_time_array, target_[0,0,n_pre-1:-n_post+1], linestyle = '--', color='red')
            ax[0].plot(plot_time_array, target_[0,1,n_pre-1:-n_post+1], linestyle = '--', color='blue')

            ax[1].plot(plot_time_array, bestControl_[i][0,3,n_pre-1:-n_post+1], color = 'blue')
            ax[1].plot(plot_time_array, bestControl_[i][0,2,n_pre-1:-n_post+1], color = 'red')

            ax[2].plot(plot_time_array, bestControl_[i][0,4,n_pre-1:-n_post+1], color = 'red')
            ax[2].plot(plot_time_array, bestControl_[i][0,5,n_pre-1:-n_post+1], color = 'blue')

            for k in range(3):
                ax[k].set_xlim(0.,dur)
                ax[k].axvspan(dur*t_pen, dur, alpha=0.2, color='gray')
            plt.show()

        if np.amax(np.abs(bestControl_[i])) > 1e-4:
            with open(file_,'wb') as f:
                pickle.dump([bestControl_, bestState_, cost_, costnode_, weights_], f)
        else:
            print("converged to zero, break")
            break
        
        k += 1
# Out:
# -------  0 0.4000000000000001 0.3500000000000001
# --------------- k  0
# set cost params:  1.0 9900000.0 0.0
# interpolate adjoint :  True True True
# initial cost =  1596.8178512576162
# RUN  0 , total integrated cost =  1596.8178512576162
# Gradient descend method:  None
# RUN  1 , total integrated cost =  836.3764279467042
# RUN  2 , total integrated cost =  836.3292416357774
# RUN  3 , total integrated cost =  836.2719086411107
# RUN  4 , total integrated cost =  836.2277458476192
# RUN  5 , total integrated cost =  836.1713810360703
# RUN  6 , total integrated cost =  836.1273981020449
# RUN  7 , total integrated cost =  836.0586809679373
# RUN  8 , total integrated cost =  836.0016522175523
# RUN  9 , total integrated cost =  835.8064038138829
# RUN  10 , total integrated cost =  835.660281588007
# RUN  11 , total integrated cost =  834.5872619579345
# RUN  12 , total integrated cost =  834.4949534421899
# RUN  13 , total integrated cost =  834.49143202738
# RUN  14 , total integrated cost =  834.485976979346
# RUN  15 , total integrated cost =  834.483322849768
# Control only changes marginally.
# RUN  15 , total integrated cost =  834.483322849768
# Improved over  15  iterations in  5.339491882012226  seconds by  47.740857093215205  percent.
# cost splitting :  0.4510404238052857 [6.62415447e-05 3.61020048e-07 4.44913930e-06 1.21288023e-05]
# --------------- k  1
# set cost params:  1.0 27455971.383963875 0.0
# interpolate adjoint :  True True True
# initial cost =  2294.797912595911
# RUN  0 , total integrated cost =  2294.797912595911
# Gradient descend method:  None
# RUN  1 , total integrated cost =  2285.411831744883
# RUN  2 , total integrated cost =  2285.370421768619
# RUN  3 , total integrated cost =  2285.3473204703414
# RUN  4 , total integrated cost =  2285.315323190855
# RUN  5 , total integrated cost =  2285.294471345254
# RUN  6 , total integrated cost =  2285.257508820948
# RUN  7 , total integrated cost =  2285.2318769929943
# RUN  8 , total integrated cost =  2285.1754409862942
# RUN  9 , total integrated cost =  2285.1324020939196
# RUN  10 , total integrated cost =  2285.049892590136

# %%
for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    aln.params.duration = dur
    max_it = int(0)
    limit = 1e-6
        
    for l in range( bestControl_[i].shape[2] ):
        if ( np.abs(bestControl_[i][0,2,l]) > limit or np.abs(bestControl_[i][0,3,l]) > limit
            or np.abs(bestControl_[i][0,4,l]) > limit or np.abs(bestControl_[i][0,5,l]) > limit ):
            init_ind = l - n_pre
            break
            
    if init_ind == -1:
        init_ind = 0
            
    print("init ind = ", init_ind)

    weight_ = 1.
    cost.setParams(1., weight_ * factor_we, weight_ * factor_ws)
    weights_[i] = cost.getParams()

    setinit(initVars[i], aln)

    target_ = aln.getZeroTarget()
    target_[:,0,:] = target[i][0]
    target_[:,1,:] = target[i][1]

    control0 = aln.getZeroControl()
    if init_ind != 0:
        control0[:,:,:-init_ind] = bestControl_[i][:,:,n_pre-1+init_ind:-n_post+1]
    else:
        control0 = bestControl_[i][:,:,n_pre-1:-n_post+1]

    bestControl_[i], bestState_[i], cost_[i], runtime_, grad_, phi_, phi1_, costnode_[i] = aln.A1(
        control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
        prec_variables_ = p_var, transition_time_ = t_pen)

    print('uncontrolled cost : ', cost_uncontrolled[i])
    print('cost splitting : ', costnode_[i][0][0][0], costnode_[i][cost_index][0][:2])

    if True:
        plot_time_array = np.arange(0.,round(dur+aln.params.dt,1),aln.params.dt)
        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        fig, ax = plt.subplots(3,1, constrained_layout=True, figsize = (4,8) )

        ax[0].plot(plot_time_array, bestState_[i][0,0,n_pre-1:-n_post+1], color= 'red')
        ax[0].plot(plot_time_array, bestState_[i][0,1,n_pre-1:-n_post+1], color= 'blue')
        ax[0].plot(plot_time_array, target_[0,0,n_pre-1:-n_post+1], linestyle = '--', color='red')
        ax[0].plot(plot_time_array, target_[0,1,n_pre-1:-n_post+1], linestyle = '--', color='blue')

        ax[1].plot(plot_time_array, bestControl_[i][0,3,n_pre-1:-n_post+1], color = 'blue')
        ax[1].plot(plot_time_array, bestControl_[i][0,2,n_pre-1:-n_post+1], color = 'red')

        ax[2].plot(plot_time_array, bestControl_[i][0,4,n_pre-1:-n_post+1], color = 'red')
        ax[2].plot(plot_time_array, bestControl_[i][0,5,n_pre-1:-n_post+1], color = 'blue')

        for k in range(3):
            ax[k].set_xlim(0.,dur)
            ax[k].axvspan(dur*t_pen, dur, alpha=0.2, color='gray')
        plt.show()
# Out:
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer pre
# -------  0 0.4000000000000001 0.3500000000000001
# [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 9.89300307e-08 1.00591258e-07
#  1.02250688e-07 1.03908051e-07 1.05563077e-07 1.07215493e-07
#  1.08865026e-07 1.10511399e-07 1.12154334e-07 1.13793552e-07
#  1.15428773e-07 1.17059711e-07 1.18686084e-07 1.20307605e-07
#  1.21923986e-07 1.23534937e-07 1.25140169e-07 1.26739387e-07
#  1.28332299e-07 1.29918608e-07]
# init ind =  546
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  0.014977660709451151
# RUN  0 , total integrated cost =  0.014977660709451151
# Gradient descend method:  None
# RUN  0 , total integrated cost =  0.014977660709451151
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# Problem in initial value trasfer pre:  sigmae_f 1.6092409664223357 1.6092399486179167
# Problem in initial value trasfer pre:  tau_exc 17.220111838880037 17.22012344318507
# uncontrolled cost :  146855.39702821904
# cost splitting :  8.905924075583168e-25 [0. 0.]
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer pre
# -------  12 0.47500000000000014 0.42500000000000016
# [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 5.81217536e-08 1.33027280e-07
#  2.09816874e-07 3.20748870e-07 4.59651903e-07 6.03291382e-07
#  7.55774048e-07 9.13074585e-07 1.07423449e-06 1.23932699e-06
#  1.40842652e-06 1.58160867e-06 1.75895023e-06 1.94052916e-06
#  2.12642466e-06 2.31671711e-06 2.51148807e-06 2.71082032e-06
#  2.91479783e-06 3.12376994e-06]
# init ind =  7
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  0.010247329980302238
# RUN  0 , total integrated cost =  0.010247329980302238
# Gradient descend method:  None
# RUN  0 , total integrated cost =  0.010247329980302238
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# Problem in initial value trasfer pre:  sigmae_f 1.551285259516954 1.5512848315160281
# Problem in initial value trasfer pre:  tau_exc 18.66653930129543 18.666543908410084
# uncontrolled cost :  437181.9504061447
# cost splitting :  0.0 [0. 0.]
# -------  24 0.4000000000000001 0.5000000000000002
# [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 9.97726845e-08 1.00233944e-07
#  1.00697335e-07 1.01162869e-07 1.01630555e-07 1.02100403e-07
#  1.02572424e-07 1.03046626e-07 1.03523021e-07 1.04001618e-07
#  1.04482428e-07 1.04965460e-07 1.05450726e-07 1.05938235e-07
#  1.06427997e-07 1.06920024e-07 1.07414326e-07 1.07910913e-07
#  1.08409795e-07 1.08910984e-07]
# init ind =  499
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  0.10910789215146882
# RUN  0 , total integrated cost =  0.10910789215146882
# Gradient descend method:  None
# RUN  0 , total integrated cost =  0.10910789215146882
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  74168.6027044929
# cost splitting :  5.443446027837956e-09 [0. 0.]
# -------  36 0.4250000000000001 0.5500000000000003
# [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 9.96930956e-08 1.00153280e-07
#  1.00615588e-07 1.01080030e-07 1.01546616e-07 1.02015356e-07
#  1.02486259e-07 1.02959336e-07 1.03434597e-07 1.03912052e-07
#  1.04391710e-07 1.04873583e-07 1.05357680e-07 1.05844011e-07
#  1.06332588e-07 1.06823419e-07 1.07316517e-07 1.07811890e-07
#  1.08309550e-07 1.08809507e-07]
# init ind =  500
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  0.09606061417638372
# RUN  0 , total integrated cost =  0.09606061417638372
# Gradient descend method:  None
# RUN  0 , total integrated cost =  0.09606061417638372
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  192617.3150952127
# cost splitting :  0.0 [0. 0.]
# -------  48 0.4250000000000001 0.6000000000000003
# [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 9.97625812e-08 1.00222102e-07
#  1.00683740e-07 1.01147504e-07 1.01613404e-07 1.02081450e-07
#  1.02551651e-07 1.03024019e-07 1.03498563e-07 1.03975292e-07
#  1.04454217e-07 1.04935348e-07 1.05418695e-07 1.05904269e-07
#  1.06392079e-07 1.06882136e-07 1.07374450e-07 1.07869032e-07
#  1.08365892e-07 1.08865041e-07]
# init ind =  501
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  0.10366622411051973
# RUN  0 , total integrated cost =  0.10366622411051973
# Gradient descend method:  None
# RUN  0 , total integrated cost =  0.10366622411051973
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  181882.521994222
# cost splitting :  2.4667617397388613e-25 [0. 0.]
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer pre
# -------  60 0.5500000000000003 0.6250000000000003
# [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 9.98703665e-08 1.00341114e-07
#  1.00814081e-07 1.01289277e-07 1.01766712e-07 1.02246398e-07
#  1.02728345e-07 1.03212564e-07 1.03699065e-07 1.04187860e-07
#  1.04678958e-07 1.05172371e-07 1.05668110e-07 1.06166186e-07
#  1.06666609e-07 1.07169391e-07 1.07674543e-07 1.08182076e-07
#  1.08692001e-07 1.09204329e-07]
# init ind =  489
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  0.016398952801528182
# RUN  0 , total integrated cost =  0.016398952801528182
# Gradient descend method:  None
# RUN  0 , total integrated cost =  0.016398952801528182
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# Problem in initial value trasfer pre:  sigmae_f 1.5052570472916957 1.5052570296713128
# Problem in initial value trasfer pre:  tau_exc 20.743830391558397 20.74383052569798
# uncontrolled cost :  741333.3077944894
# cost splitting :  3.2311742677852667e-26 [0. 0.]
# -------  72 0.5000000000000002 0.6750000000000004
# [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 9.97702696e-08 1.00233840e-07
#  1.00699565e-07 1.01167453e-07 1.01637516e-07 1.02109762e-07
#  1.02584203e-07 1.03060848e-07 1.03539707e-07 1.04020792e-07
#  1.04504112e-07 1.04989678e-07 1.05477499e-07 1.05967588e-07
#  1.06459953e-07 1.06954606e-07 1.07451557e-07 1.07950818e-07
#  1.08452398e-07 1.08956309e-07]
# init ind =  497
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  0.04715453706409655
# RUN  0 , total integrated cost =  0.04715453706409655
# Gradient descend method:  None
# RUN  0 , total integrated cost =  0.04715453706409655
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# uncontrolled cost :  495331.1329655588
# cost splitting :  1.135959703518257e-25 [0. 0.]

# %%
tol = 1e-6
conv_shift = [None] * len(exc)

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    aln.params.duration = dur
    max_it = int(10000)
    k = 0
    
    while not conv_shift[i]:
            
        weight_ = 1.
        cost.setParams(1., weight_ * factor_we, weight_ * factor_ws)
        weights_[i] = cost.getParams()

        setinit(initVars[i], aln)

        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        control0 = aln.getZeroControl()
        control0 = bestControl_[i][:,:,n_pre-1:-n_post+1]

        bestControl_[i], bestState_[i], cost_[i], runtime_, grad_, phi_, phi1_, costnode_[i]= aln.A1(
            control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
            prec_variables_ = p_var, transition_time_ = t_pen)
        
        if cost_[i][-1] == 0.:
            conv_shift[i] = True

        print('uncontrolled cost : ', cost_uncontrolled[i])
        print('cost splitting : ', costnode_[i][0][0][0], costnode_[i][2][0][:2])

        if conv_shift[i]:
            plot_time_array = np.arange(0.,round(dur+aln.params.dt,1),aln.params.dt)
            target_ = aln.getZeroTarget()
            target_[:,0,:] = target[i][0]
            target_[:,1,:] = target[i][1]

            fig, ax = plt.subplots(3,1, constrained_layout=True, figsize = (4,8) )

            ax[0].plot(plot_time_array, bestState_[i][0,0,n_pre-1:-n_post+1], color= 'red')
            ax[0].plot(plot_time_array, bestState_[i][0,1,n_pre-1:-n_post+1], color= 'blue')
            ax[0].plot(plot_time_array, target_[0,0,n_pre-1:-n_post+1], linestyle = '--', color='red')
            ax[0].plot(plot_time_array, target_[0,1,n_pre-1:-n_post+1], linestyle = '--', color='blue')

            ax[1].plot(plot_time_array, bestControl_[i][0,3,n_pre-1:-n_post+1], color = 'blue')
            ax[1].plot(plot_time_array, bestControl_[i][0,2,n_pre-1:-n_post+1], color = 'red')

            ax[2].plot(plot_time_array, bestControl_[i][0,4,n_pre-1:-n_post+1], color = 'red')
            ax[2].plot(plot_time_array, bestControl_[i][0,5,n_pre-1:-n_post+1], color = 'blue')

            for k in range(3):
                ax[k].set_xlim(0.,dur)
                ax[k].axvspan(dur*t_pen, dur, alpha=0.2, color='gray')
            plt.show()
            
        break

        with open(file_,'wb') as f:
            pickle.dump([bestControl_, bestState_, cost_, costnode_, weights_], f)
        
        k += 1
# Out:
# -------  0 0.4000000000000001 0.3500000000000001
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  0.01459297300060943
# RUN  0 , total integrated cost =  0.01459297300060943
# Gradient descend method:  None
# RUN  1 , total integrated cost =  0.014592958043047855
# RUN  2 , total integrated cost =  0.014592944650674294
# RUN  3 , total integrated cost =  0.014592942201446723
# RUN  4 , total integrated cost =  0.014592941971593262
# RUN  5 , total integrated cost =  0.014592941714140823
# RUN  6 , total integrated cost =  0.014592941484625916
# RUN  7 , total integrated cost =  0.014592941228887527
# RUN  8 , total integrated cost =  0.014592940999339742
# RUN  9 , total integrated cost =  0.014592940745949863
# RUN  10 , total integrated cost =  0.014592940514318954
# RUN  11 , total integrated cost =  0.014592940255712136
# RUN  12 , total integrated cost =  0.01459294001866606
# RUN  13 , total integrated cost =  0.014592939750463352
# RUN  14 , total integrated cost =  0.014592939508387201
# RUN  15 , total integrated cost =  0.01459293921413817
# RUN  16 , total integrated cost =  0.014592938937672844
# RUN  17 , total integrated cost =  0.014592938629300046
# RUN  18 , total integrated cost =  0.014592938346092382
# RUN  19 , total integrated cost =  0.01459293804948347
# RUN  20 , total integrated cost =  0.014592937755033591
# RUN  30 , total integrated cost =  0.014592916334560465
# RUN  40 , total integrated cost =  0.014592912834970126
# RUN  50 , total integrated cost =  0.014592903757119701
# RUN  60 , total integrated cost =  0.014592900629998844
# RUN  70 , total integrated cost =  0.014592895024823258
# RUN  80 , total integrated cost =  0.014592620739336516
# RUN  90 , total integrated cost =  0.014592618208958746
# RUN  100 , total integrated cost =  0.014592617292049536
# RUN  110 , total integrated cost =  0.014592616392922243
# RUN  120 , total integrated cost =  0.01459261550734467
# RUN  130 , total integrated cost =  0.014592614631646239
# RUN  140 , total integrated cost =  0.014592612714871743
# RUN  150 , total integrated cost =  0.014592610083754924
# RUN  160 , total integrated cost =  0.01459260810460362
# RUN  170 , total integrated cost =  0.014592606259417018
# RUN  180 , total integrated cost =  0.014592604544366108
# RUN  190 , total integrated cost =  0.014592602922005525
# RUN  200 , total integrated cost =  0.014592601385906763
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer pre
# Control only changes marginally.
# RUN  223 , total integrated cost =  0.014592598259683846
# Improved over  223  iterations in  69.95695994998096  seconds by  0.0025679546283470245  percent.
# Problem in initial value trasfer pre:  sigmae_f 1.6092409664223357 1.609239972872345
# Problem in initial value trasfer pre:  tau_exc 17.220111838880037 17.220123166652787
# uncontrolled cost :  146855.39702821904
# cost splitting :  4.09601409230966e-10 [0. 0.]
# -------  12 0.47500000000000014 0.42500000000000016
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  0.0101665247084383
# RUN  0 , total integrated cost =  0.0101665247084383
# Gradient descend method:  None
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer pre
# RUN  1 , total integrated cost =  0.0101665247084383
# Control only changes marginally.
# RUN  1 , total integrated cost =  0.0101665247084383
# Improved over  1  iterations in  0.30018238999764435  seconds by  0.0  percent.
# Problem in initial value trasfer pre:  sigmae_f 1.551285259516954 1.5512848348908597
# Problem in initial value trasfer pre:  tau_exc 18.66653930129543 18.666543872082514
# uncontrolled cost :  437181.9504061447
# cost splitting :  8.077935669463167e-27 [0. 0.]
# -------  24 0.4000000000000001 0.5000000000000002
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  0.09873697758090144
# RUN  0 , total integrated cost =  0.09873697758090144
# Gradient descend method:  None
# RUN  1 , total integrated cost =  0.0987369727939737
# RUN  2 , total integrated cost =  0.09873696819832224
# RUN  3 , total integrated cost =  0.09873696361260162
# RUN  4 , total integrated cost =  0.0987369591382684
# RUN  5 , total integrated cost =  0.0987369545793957
# RUN  6 , total integrated cost =  0.09873695010894681
# RUN  7 , total integrated cost =  0.09873694552178151
# RUN  8 , total integrated cost =  0.09873694093544497
# RUN  9 , total integrated cost =  0.0987369363250837
# RUN  10 , total integrated cost =  0.0987369317651968
# RUN  11 , total integrated cost =  0.09873692713067041
# RUN  12 , total integrated cost =  0.09873692259859738
# RUN  13 , total integrated cost =  0.09873691793874705
# RUN  14 , total integrated cost =  0.09873691343258723
# RUN  15 , total integrated cost =  0.09873690887092527
# RUN  16 , total integrated cost =  0.09873690440987325
# RUN  17 , total integrated cost =  0.0987368998331746
# RUN  18 , total integrated cost =  0.09873689536024033
# RUN  19 , total integrated cost =  0.09873689080128122
# RUN  20 , total integrated cost =  0.09873688634196762
# RUN  30 , total integrated cost =  0.09873684079843481
# RUN  40 , total integrated cost =  0.09873679430229365
# RUN  50 , total integrated cost =  0.09873674151543659
# RUN  60 , total integrated cost =  0.09873669368591423
# RUN  70 , total integrated cost =  0.09873664537049284
# RUN  80 , total integrated cost =  0.098736595103414
# RUN  90 , total integrated cost =  0.09873654240111802
# RUN  100 , total integrated cost =  0.09873649465578548
# RUN  110 , total integrated cost =  0.09873643756307374
# RUN  120 , total integrated cost =  0.09873638935639523
# RUN  130 , total integrated cost =  0.09873633231238903
# RUN  140 , total integrated cost =  0.09873628287398206
# RUN  150 , total integrated cost =  0.09873622934857516
# RUN  160 , total integrated cost =  0.09873617649475347
# RUN  170 , total integrated cost =  0.09873612301187575
# RUN  180 , total integrated cost =  0.09873606955994162
# RUN  190 , total integrated cost =  0.09873602150166186
# RUN  200 , total integrated cost =  0.09873596982454029
# RUN  300 , total integrated cost =  0.09873545211956315
# RUN  400 , total integrated cost =  0.09873495833428489
# RUN  500 , total integrated cost =  0.09873447053003301
# RUN  600 , total integrated cost =  0.09873396651106718
# RUN  700 , total integrated cost =  0.09873302989440684
# RUN  800 , total integrated cost =  0.09873222179681054
# RUN  900 , total integrated cost =  0.09873164007660139
# RUN  1000 , total integrated cost =  0.09873113920103888
# RUN  1100 , total integrated cost =  0.09873065524334583
# RUN  1200 , total integrated cost =  0.09873017604204089
# RUN  1300 , total integrated cost =  0.09872969953710053
# RUN  1400 , total integrated cost =  0.09872906108732395
# RUN  1500 , total integrated cost =  0.09872850388167154
# RUN  1600 , total integrated cost =  0.09872803607531569
# RUN  1700 , total integrated cost =  0.09872758548430122
# RUN  1800 , total integrated cost =  0.09872713241757025
# RUN  1900 , total integrated cost =  0.09872668284399135
# RUN  2000 , total integrated cost =  0.0987262419826516
# RUN  3000 , total integrated cost =  0.09871734048860512
# RUN  4000 , total integrated cost =  0.09870990851547756
# RUN  5000 , total integrated cost =  0.09870408080884448
# RUN  6000 , total integrated cost =  0.09869993433830813
# RUN  7000 , total integrated cost =  0.09869475255009691
# RUN  8000 , total integrated cost =  0.09869006219020512
# RUN  9000 , total integrated cost =  0.09868557839810929
# RUN  10000 , total integrated cost =  0.09868099149559888
# RUN  10000 , total integrated cost =  0.09868099149559888
# Improved over  10000  iterations in  4798.242952248984  seconds by  0.056702247399357475  percent.
# uncontrolled cost :  74168.6027044929
# cost splitting :  4.4276643785174524e-08 [0. 0.]
# -------  36 0.4250000000000001 0.5500000000000003
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  0.08504953868991703
# RUN  0 , total integrated cost =  0.08504953868991703
# Gradient descend method:  None
# RUN  1 , total integrated cost =  0.08504953830449685
# RUN  2 , total integrated cost =  0.08504953789815349
# RUN  3 , total integrated cost =  0.08504953746015377
# RUN  4 , total integrated cost =  0.08504953737368268
# RUN  5 , total integrated cost =  0.08504953727506719
# RUN  6 , total integrated cost =  0.08504953719907724
# RUN  7 , total integrated cost =  0.08504953711309737
# RUN  8 , total integrated cost =  0.08504953704301631
# RUN  9 , total integrated cost =  0.08504953696386543
# RUN  10 , total integrated cost =  0.08504953689949539
# RUN  11 , total integrated cost =  0.08504953682276083
# RUN  12 , total integrated cost =  0.08504953675844809
# RUN  13 , total integrated cost =  0.08504953668071065
# RUN  14 , total integrated cost =  0.08504953661553293
# RUN  15 , total integrated cost =  0.08504953653534722
# RUN  16 , total integrated cost =  0.0850495364682102
# RUN  17 , total integrated cost =  0.08504953638256786
# RUN  18 , total integrated cost =  0.08504953630849475
# RUN  19 , total integrated cost =  0.08504953621707972
# RUN  20 , total integrated cost =  0.08504953613426537
# RUN  30 , total integrated cost =  0.08504953067213175
# RUN  40 , total integrated cost =  0.08504952811213802
# RUN  50 , total integrated cost =  0.08504952613261331
# RUN  60 , total integrated cost =  0.08504952447800002
# RUN  70 , total integrated cost =  0.08504952300651711
# RUN  80 , total integrated cost =  0.0850495216787855
# RUN  90 , total integrated cost =  0.085049520459517
# RUN  100 , total integrated cost =  0.0850495193297615
# RUN  110 , total integrated cost =  0.08504951847014866
# Control only changes marginally.
# RUN  119 , total integrated cost =  0.08504951785318726
# Improved over  119  iterations in  77.88624020601856  seconds by  2.4499521217080655e-05  percent.
# uncontrolled cost :  192617.3150952127
# cost splitting :  6.53993847544789e-10 [0. 0.]
# -------  48 0.4250000000000001 0.6000000000000003
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  0.09985372912542397
# RUN  0 , total integrated cost =  0.09985372912542397
# Gradient descend method:  None
# RUN  1 , total integrated cost =  0.09985372566151592
# RUN  2 , total integrated cost =  0.0998537221237835
# RUN  3 , total integrated cost =  0.09985354433465049
# RUN  4 , total integrated cost =  0.09985348866155083
# RUN  5 , total integrated cost =  0.09985348844988967
# RUN  6 , total integrated cost =  0.09985348826680772
# RUN  7 , total integrated cost =  0.09985348794699359
# RUN  8 , total integrated cost =  0.099853487638724
# RUN  9 , total integrated cost =  0.09985348688239122
# RUN  10 , total integrated cost =  0.09985348609907431
# RUN  11 , total integrated cost =  0.09985348584120163
# RUN  12 , total integrated cost =  0.09985348559455921
# RUN  13 , total integrated cost =  0.09985348471205026
# RUN  14 , total integrated cost =  0.09985348381391922
# RUN  15 , total integrated cost =  0.09985348166852359
# RUN  16 , total integrated cost =  0.09985347934839973
# RUN  17 , total integrated cost =  0.09985347917737698
# RUN  18 , total integrated cost =  0.09985347899239254
# RUN  19 , total integrated cost =  0.09985347883944337
# RUN  20 , total integrated cost =  0.09985347866430426
# RUN  30 , total integrated cost =  0.0998534773107104
# RUN  40 , total integrated cost =  0.09985175527874489
# Control only changes marginally.
# RUN  42 , total integrated cost =  0.09985174748159979
# Improved over  42  iterations in  26.583489295007894  seconds by  0.001984546637899598  percent.
# uncontrolled cost :  181882.521994222
# cost splitting :  3.0014415296176444e-09 [0. 0.]
# -------  60 0.5500000000000003 0.6250000000000003
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  0.016294495661559313
# RUN  0 , total integrated cost =  0.016294495661559313
# Gradient descend method:  None
# ERROR:root:Problem in initial value trasfer pre
# ERROR:root:Problem in initial value trasfer pre
# RUN  1 , total integrated cost =  0.016294495661559313
# Control only changes marginally.
# RUN  1 , total integrated cost =  0.016294495661559313
# Improved over  1  iterations in  0.3939956609974615  seconds by  0.0  percent.
# Problem in initial value trasfer pre:  sigmae_f 1.5052570472916957 1.505257029783544
# Problem in initial value trasfer pre:  tau_exc 20.743830391558397 20.743830524843588
# uncontrolled cost :  741333.3077944894
# cost splitting :  3.6484501322109866e-23 [0. 0.]
# -------  72 0.5000000000000002 0.6750000000000004
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  0.04682553432609761
# RUN  0 , total integrated cost =  0.04682553432609761
# Gradient descend method:  None
# RUN  1 , total integrated cost =  0.04682553083376939
# RUN  2 , total integrated cost =  0.04682553083376939
# Control only changes marginally.
# RUN  2 , total integrated cost =  0.04682553083376939
# Improved over  2  iterations in  1.4389203760074452  seconds by  7.458170571794653e-06  percent.
# uncontrolled cost :  495331.1329655588
# cost splitting :  5.281209999105117e-15 [0. 0.]

# %%
for i in i_range:
    print("------- ", i, exc[i], inh[i])
    plot_time_array = np.arange(0.,round(dur+aln.params.dt,1),aln.params.dt)


    fig, ax = plt.subplots(3,1, constrained_layout=True, figsize = (4,8) )

    ax[0].plot(plot_time_array, bestState_[i][0,0,n_pre-1:-n_post+1], color= 'red')
    ax[0].plot(plot_time_array, bestState_[i][0,1,n_pre-1:-n_post+1], color= 'blue')

    ax[1].plot(plot_time_array, bestControl_[i][0,3,n_pre-1:-n_post+1], color = 'blue')
    ax[1].plot(plot_time_array, bestControl_[i][0,2,n_pre-1:-n_post+1], color = 'red')

    ax[2].plot(plot_time_array, bestControl_[i][0,4,n_pre-1:-n_post+1], color = 'red')
    ax[2].plot(plot_time_array, bestControl_[i][0,5,n_pre-1:-n_post+1], color = 'blue')

    for k in range(3):
        ax[k].set_xlim(0.,dur)
        ax[k].axvspan(dur*t_pen, dur, alpha=0.2, color='gray')
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_146139/2534450533.py in <module>
# ----> 1 for i in i_range:
#       2     print("------- ", i, exc[i], inh[i])
#       3     plot_time_array = np.arange(0.,round(dur+aln.params.dt,1),aln.params.dt)
#       4
#       5
#
# NameError: name 'i_range' is not defined
