# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import sys
import pickle

path = os.getcwd().split(os.sep + 'GUI')[0]
if path not in sys.path:
    print("not here")
    sys.path.append(path)

from neurolib.models.aln import ALNModel
from neurolib.utils import plotFunctions as plotFunc
from neurolib.utils import costFunctions as cost
import neurolib.dashboard.functions as functions
import neurolib.dashboard.data as data
    
# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2 

#path = os.path.join(os.getcwd(), "plots")
# Out:
# not here

# %%
grid_data_file = os.path.join(os.getcwd().split('data')[0], 'bi.pickle')
print(grid_data_file)
with open(grid_data_file,'rb') as f:
    load_array= pickle.load(f)
exc = load_array[0]
inh = load_array[1]
print(len(exc))
case = '1'
# Out:
# /home/lena/Promotion/neurolib/GUI/current/gui/bi.pickle
# 147

# %% [markdown]
# ### Bistability

# %%
aln = ALNModel()
N = aln.params.N

data.set_parameters(aln)

state_vars = aln.state_vars
init_vars = aln.init_vars

##############################################################
def setinit(init_vars_, model):
    state_vars = model.state_vars
    init_vars = model.init_vars
    for iv in range(len(init_vars)):
        for sv in range(len(state_vars)):
            if state_vars[sv] in init_vars[iv]:
                #print("set init vars ", )
                if model.params[init_vars[iv]].ndim == 2:
                    model.params[init_vars[iv]][0,:] = init_vars_[sv]
                else:
                    model.params[init_vars[iv]][0] = init_vars_[sv]
                    
##############################################################               
def setmaxmincontrol(max_c_c, min_c_c, max_c_r, min_c_r):
    import numpy as np
    
    max_cntrl = np.zeros(( 6 ))
    min_cntrl = np.zeros(( 6 ))
    
    max_cntrl[0] = max_c_c
    min_cntrl[0] = min_c_c
    max_cntrl[1] = max_c_c
    min_cntrl[1] = min_c_c
    max_cntrl[2] = max_c_r
    min_cntrl[2] = min_c_r
    max_cntrl[3] = max_c_r
    min_cntrl[3] = min_c_r
    max_cntrl[4] = max_c_r
    min_cntrl[4] = min_c_r
    max_cntrl[5] = max_c_r
    min_cntrl[5] = min_c_r
            
    return max_cntrl, min_cntrl

# %%
d_array = np.arange(20., 300, 0.1)
t0_array = d_array - 20.
t_pen = np.zeros(( t0_array.shape ))
for i in range(len(t_pen)):
    t_pen[i] = t0_array[i] / d_array[i]

bestControl_ = np.array( [[None] * len(t_pen)] * len(exc) )
bestState_ = np.array( [[None] * len(t_pen)] * len(exc) )
cost_ = np.array( [[None] * len(t_pen)] * len(exc) )
costnode_ = np.array( [[None] * len(t_pen)] * len(exc) )
weights_ = np.array( [[None] * len(t_pen)] * len(exc) )
convergence_ = np.array( [[None] * len(t_pen)] * len(exc) )

initVars = [None] * len(exc)
target = [None] * len(exc)
cost_uncontrolled = [None] * len(exc)

print(bestControl_.shape)
# Out:
# (147, 2800)

# %%
dur_pre = 10
dur_post = 10

n_pre = int(np.around(dur_pre/aln.params.dt + 1.,1))
n_post = int(np.around(dur_post/aln.params.dt + 1.,1))

tol = 1e-32
start_step = 10.
c_scheme = np.zeros(( 1,1 ))
c_scheme[0,0] = 1.
u_mat = np.identity(1)
u_scheme = np.array([[1.]])

c_var = [1]
p_var = [0]

if case in ['1', '2']:    # low to high
    max_I = [3., -3.]
else:
    max_I = [-3., 3.]
    
if case in ['1', '3']:    # sparsity
    factor_ws = 1.
    factor_we = 0.
else:
    factor_ws = 0.
    factor_we = 1.
    
maxC = [5., -5., 0.18, 0.]
max_cntrl, min_cntrl = setmaxmincontrol(maxC[0], maxC[1], maxC[2], maxC[3])

# %%
file_ = '1b.pickle'

# %%
if os.path.isfile(file_) :
    print("file found")
    
    with open(file_,'rb') as f:
        load_array = pickle.load(f)

    bestControl_ = load_array[0]
    bestState_ = load_array[1]
    cost_ = load_array[2]
    costnode_ = load_array[3]
    weights_ = load_array[4]

# %%
# get initial parameters and target states

#i_stepsize = 20
#limit = 150
#start_index = 0
#i_range = range(start_index, limit,i_stepsize)
i_range = [20]

data.set_parameters(aln)

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    aln.params.duration = 3000.
    
    control0 = aln.getZeroControl()
    control0 = functions.step_control(aln, maxI_ = max_I[0])

    aln.run(control=control0)
    
    target_rates = np.zeros((2))
    target_rates[0] = aln.rates_exc[0,-1] 
    target_rates[1] = aln.rates_inh[0,-1]

    control0 = functions.step_control(aln, maxI_ = max_I[1])
    aln.run(control=control0)

    init_state_vars = np.zeros(( len(state_vars) ))
    for j in range(len(state_vars)):
        if aln.state[state_vars[j]].size == 1:
            init_state_vars[j] = aln.state[state_vars[j]][0]
        else:
            init_state_vars[j] = aln.state[state_vars[j]][0,-1]

    initVars[i] = init_state_vars
    target[i] = [target_rates[0], target_rates[1]]
# Out:
# -------  20 0.4500000000000001 0.4750000000000002

# %%
# get uncontrolled cost

data.set_parameters(aln)

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    dur = d_array[0]
    aln.params.duration = dur
    
    target_ = aln.getZeroTarget()
    target_[:,0,:] = target[i][0]
    target_[:,1,:] = target[i][1]
        
    cost.setParams(1.0, 0.0, 0.0)

    setinit(initVars[i], aln)
    control0 = aln.getZeroControl()

    # "HS", "FR", "PR", "HZ"
    cgv = None
    max_it = 0

    bestControl_init_, bestState_init_, cost_init_, runtime_init_, grad_init_, phi_init_, phi1_, costnode_init_ = aln.A1(
        control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
        prec_variables_ = p_var, transition_time_ = 0.)
    
    cost_uncontrolled[i] = cost_init_[0]
# Out:
# -------  20 0.4500000000000001 0.4750000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  12801.807032522984
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  0 , total integrated cost =  12801.807032522984
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.

# %%
cgv = None
j = 0
k = 0

while k < 10:
    print('-------------------------------------------- k = ', k)

    for i in i_range:
        print("------- ", i, exc[i], inh[i])
        aln.params.ext_exc_current = exc[i] * 5.
        aln.params.ext_inh_current = inh[i] * 5.

        if convergence_[i][j] == True:
            print('converged')
            continue

        dur = d_array[0]
        aln.params.duration = dur
        
        setinit(initVars[i], aln)

        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        max_it = int(100)

        if type(bestControl_[i][j]) == type(None) or np.amax(np.abs(bestControl_[i][j])) < 1e-6:
            print('no solution found')
            control0 = aln.getZeroControl()
            #control0[0,0,:50] = 5.
            cost.setParams(1.0, 0., 1.)
            max_it = int(1)
            weights_[i][j] = [1., 0., 1.]
        else:
            control0 = bestControl_[i][j][:,:,n_pre-1:-n_post+1]
            l = 1
            while cost_[i][j][-l] == 0.:
                l += 1

            weight_ = ( cost_uncontrolled[i] - costnode_[i][j][0][0][0] ) / sum( costnode_[i][j][2][0][:] )
                
            print("weight = ", weight_)
            cost.setParams(1.0, weight_ * factor_we, weight_ * factor_ws)
            weights_[i][j] = cost.getParams()

        bestControl_[i][j], bestState_[i][j], cost_[i][j], runtime_, grad_, phi_, phi1_, costnode_[i][j] = aln.A1(
            control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
            prec_variables_ = p_var, transition_time_ = t_pen[j])

        if max_it > 1:
            if cost_[i][j][2] == 0.:
                print('converged')
                convergence_[i][j] = True

        print('uncontrolled cost : ', cost_uncontrolled[i])
        print('cost splitting : ', costnode_[i][j][0][0][0], costnode_[i][j][2][0][:2])

        time_ = np.arange(-dur_pre,dur+dur_post+aln.params.dt,aln.params.dt)
        dur += dur_pre + dur_post
        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        if True:
            fig, ax = plt.subplots(2,1, constrained_layout=True, figsize = (4,4) )
            ax[1].plot(time_, bestControl_[i][j][0,0,:], color = 'red')
            ax[0].plot(time_, bestState_[i][j][0,0,:], color= 'red')
            ax[1].plot(time_, bestControl_[i][j][0,1,:], color = 'blue')
            ax[0].plot(time_, bestState_[i][j][0,1,:], color= 'blue')
            ax[0].plot(time_, target_[0,0,:], linestyle = '--', color='red')
            ax[0].plot(time_, target_[0,1,:], linestyle = '--', color='blue')
            ax[0].set_xlim(-dur_pre,dur-dur_post)
            ax[1].set_xlim(-dur_pre,dur-dur_post)
            ax[0].axvspan(t0_array[0], dur, alpha=0.2, color='gray')
            plt.show()

        with open(file_,'wb') as f:
            pickle.dump([bestControl_, bestState_, cost_, costnode_, weights_], f)
    
    k += 1
# Out:
# -------------------------------------------- k =  0
# -------  20 0.4500000000000001 0.4750000000000002
# no solution found
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  12801.807032522984
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  9444.199144044613
# RUN  1 , total integrated cost =  9444.199144044613
# Improved over  1  iterations in  16.014700016006827  seconds by  26.227608961362805  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  9438.294876277036 [0.         5.90426777]
# -------------------------------------------- k =  1
# -------  20 0.4500000000000001 0.4750000000000002
# weight =  569.6747316773378
# set cost params:  1.0 0.0 569.6747316773378
# interpolate adjoint :  True True True
# initial cost =  12801.807032522984
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12772.358064437001
# RUN  2 , total integrated cost =  12749.621242966616
# RUN  3 , total integrated cost =  12732.171609177196
# RUN  4 , total integrated cost =  12719.270884094178
# RUN  5 , total integrated cost =  12709.454637556424
# RUN  6 , total integrated cost =  12701.815254663874
# RUN  7 , total integrated cost =  12695.813125710483
# RUN  8 , total integrated cost =  12691.2970356773
# RUN  9 , total integrated cost =  12687.593093545522
# RUN  10 , total integrated cost =  12684.520484537754
# RUN  11 , total integrated cost =  12681.890836830436
# RUN  12 , total integrated cost =  12679.81879166343
# RUN  13 , total integrated cost =  12678.027251238937
# RUN  14 , total integrated cost =  12676.767103842818
# RUN  15 , total integrated cost =  12675.6045212568
# RUN  16 , total integrated cost =  12674.688012431805
# RUN  17 , total integrated cost =  12673.827156404384
# RUN  18 , total integrated cost =  12673.139336157492
# RUN  19 , total integrated cost =  12672.53599253744
# RUN  20 , total integrated cost =  12672.03426805036
# RUN  30 , total integrated cost =  12669.931611202326
# RUN  40 , total integrated cost =  12669.577455779488
# RUN  50 , total integrated cost =  12669.307427533315
# RUN  60 , total integrated cost =  12669.295640525826
# Control only changes marginally.
# RUN  63 , total integrated cost =  12669.295636811981
# Improved over  63  iterations in  0.841338023004937  seconds by  1.0350991494744335  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  9339.746496766073 [0.         5.84464951]
# -------------------------------------------- k =  2
# -------  20 0.4500000000000001 0.4750000000000002
# weight =  592.3469886769187
# set cost params:  1.0 0.0 592.3469886769187
# interpolate adjoint :  True True True
# initial cost =  12801.807032522984
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.701855619574
# RUN  2 , total integrated cost =  12801.671802968496
# RUN  3 , total integrated cost =  12801.645871799024
# RUN  4 , total integrated cost =  12801.623668586682
# RUN  5 , total integrated cost =  12801.60645765147
# RUN  6 , total integrated cost =  12801.591388995577
# RUN  7 , total integrated cost =  12801.581351156483
# RUN  8 , total integrated cost =  12801.571089647163
# RUN  9 , total integrated cost =  12801.55958766985
# RUN  10 , total integrated cost =  12801.551476043673
# RUN  11 , total integrated cost =  12801.543800542895
# RUN  12 , total integrated cost =  12801.538986823452
# RUN  13 , total integrated cost =  12801.533734025423
# RUN  14 , total integrated cost =  12801.531193998246
# RUN  15 , total integrated cost =  12801.528260580655
# RUN  16 , total integrated cost =  12801.526379469859
# RUN  17 , total integrated cost =  12801.521544555118
# RUN  18 , total integrated cost =  12801.517850467022
# RUN  19 , total integrated cost =  12801.509300395624
# RUN  20 , total integrated cost =  12801.508315533945
# Control only changes marginally.
# RUN  29 , total integrated cost =  12801.50322642536
# Improved over  29  iterations in  0.5877640149992658  seconds by  0.002373150109605149  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  9356.479817553367 [0.         5.81588744]
# -------------------------------------------- k =  3
# -------  20 0.4500000000000001 0.4750000000000002
# weight =  592.399225949561
# set cost params:  1.0 0.0 592.399225949561
# interpolate adjoint :  True True True
# initial cost =  12801.807032522984
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522982
# RUN  2 , total integrated cost =  12801.807032522982
# Control only changes marginally.
# RUN  2 , total integrated cost =  12801.807032522982
# Improved over  2  iterations in  0.09656633199483622  seconds by  1.4210854715202004e-14  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  9356.47981754994 [0.         5.81588744]
# -------------------------------------------- k =  4
# -------  20 0.4500000000000001 0.4750000000000002
# weight =  592.3992259495612
# set cost params:  1.0 0.0 592.3992259495612
# interpolate adjoint :  True True True
# initial cost =  12801.807032522984
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.06640100799268112  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  9356.47981754994 [0.         5.81588744]
# -------------------------------------------- k =  5
# -------  20 0.4500000000000001 0.4750000000000002
# converged
# -------------------------------------------- k =  6
# -------  20 0.4500000000000001 0.4750000000000002
# converged
# -------------------------------------------- k =  7
# -------  20 0.4500000000000001 0.4750000000000002
# converged
# -------------------------------------------- k =  8
# -------  20 0.4500000000000001 0.4750000000000002
# converged
# -------------------------------------------- k =  9
# -------  20 0.4500000000000001 0.4750000000000002
# converged

# %%
for i in range(bestControl_.shape[0]):
    for j in range(1,bestControl_.shape[1]):
        bestControl_[i][j] = None
        convergence_[i][j] = None

# %%
cost.setParams(1.0, factor_we, factor_ws)

j_start = 100

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.

    for j in range(j_start,j_start+400):
        print(i,j, '-----------------')
            
        k = 0
        while convergence_[i][j] != True:
            print('---------------------', k)

            dur = round(d_array[j],1)
            #print('simulation duration : ', dur)
            aln.params.duration = dur
            max_it = int(100)  
            
            setinit(initVars[i], aln)
            target_ = aln.getZeroTarget()
            target_[:,0,:] = target[i][0]
            target_[:,1,:] = target[i][1]

            if type(bestControl_[i][j]) == type(None):
                #print('no solution computed yet')
                control0 = aln.getZeroControl()
                control0[:,:,:-1] = bestControl_[i][j-1][:,:,n_pre-1:-n_post+1]
                                        
                l = 1
                while cost_[i][j-1][-l] == 0.:
                    l += 1
                    
                weight_ = ( cost_uncontrolled[i] - costnode_[i][j-1][0][0][0] ) / sum( costnode_[i][j-1][2][0][:] )
            else:
                control0 = bestControl_[i][j][:,:,n_pre-1:-n_post+1]
                l = 1
                while cost_[i][j][-l] == 0.:
                    l += 1
                
                weight_ = ( cost_uncontrolled[i] - costnode_[i][j][0][0][0] ) / sum( costnode_[i][j][2][0][:] )
                
            #print("weight = ", weight_)
            cost.setParams(1.0, weight_ * factor_we, weight_ * factor_ws)
            weights_[i][j] = cost.getParams()

            bestControl_[i][j], bestState_[i][j], cost_[i][j], runtime_, grad_, phi_, phi1_, costnode_[i][j] = aln.A1(
                control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
                startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
                t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
                prec_variables_ = p_var, transition_time_ = t_pen[j])

            if cost_[i][j][2] == 0.:
                #print('converged')
                convergence_[i][j] = True

            #print('uncontrolled cost : ', cost_uncontrolled[i])
            print('cost splitting : ', costnode_[i][j][0][0][0], costnode_[i][j][2][0][:2])

            if False:
                time_ = np.arange(-dur_pre,round(dur+dur_post+aln.params.dt,1),aln.params.dt)
                dur += dur_pre + dur_post
                target_ = aln.getZeroTarget()
                target_[:,0,:] = target[i][0]
                target_[:,1,:] = target[i][1]
                
                fig, ax = plt.subplots(2,1, constrained_layout=True, figsize = (4,4) )
                ax[1].plot(time_, bestControl_[i][j][0,0,:], color = 'red')
                ax[0].plot(time_, bestState_[i][j][0,0,:], color= 'red')
                ax[1].plot(time_, bestControl_[i][j][0,1,:], color = 'blue')
                ax[0].plot(time_, bestState_[i][j][0,1,:], color= 'blue')
                ax[0].plot(time_, target_[0,0,:], linestyle = '--', color='red')
                ax[0].plot(time_, target_[0,1,:], linestyle = '--', color='blue')
                ax[0].set_xlim(-dur_pre,dur-dur_post)
                ax[1].set_xlim(-dur_pre,dur-dur_post)
                ax[0].axvspan(t0_array[j], t0_array[j]+20, alpha=0.2, color='gray')
                plt.show()

            with open(file_,'wb') as f:
                pickle.dump([bestControl_, bestState_, cost_, costnode_, weights_], f)
                
            k += 1
# Out:
# set cost params:  1.0 0.0 1.0
# -------  20 0.4500000000000001 0.4750000000000002
# 20 100 -----------------
# 20 101 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 1789.4890845507493
# interpolate adjoint :  True True True
# initial cost =  14420.99510797307
# RUN  0 , total integrated cost =  14420.99510797307
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14420.994676557093
# RUN  2 , total integrated cost =  14420.99467001279
# RUN  3 , total integrated cost =  14420.994666805193
# RUN  4 , total integrated cost =  14420.994664516438
# RUN  5 , total integrated cost =  14420.994662436831
# RUN  6 , total integrated cost =  14420.994660059172
# RUN  7 , total integrated cost =  14420.994656585606
# RUN  8 , total integrated cost =  14420.99464984596
# RUN  9 , total integrated cost =  14420.994630106143
# RUN  10 , total integrated cost =  14420.994514214963
# RUN  11 , total integrated cost =  14420.994315095448
# RUN  12 , total integrated cost =  14420.994302850875
# RUN  13 , total integrated cost =  14420.994263675326
# RUN  14 , total integrated cost =  14420.994253052486
# RUN  15 , total integrated cost =  14420.99425305248
# RUN  16 , total integrated cost =  14420.994253052479
# RUN  17 , total integrated cost =  14420.994253052479
# Control only changes marginally.
# RUN  17 , total integrated cost =  14420.994253052479
# Improved over  17  iterations in  0.2780049169959966  seconds by  5.928305128577449e-06  percent.
# cost splitting :  3346.036812775044 [0.         5.24932822]
# --------------------- 1
# set cost params:  1.0 0.0 1801.3295825833984
# interpolate adjoint :  True True True
# initial cost =  14483.14891356915
# RUN  0 , total integrated cost =  14483.14891356915
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14483.129510802959
# RUN  2 , total integrated cost =  14483.127761577663
# RUN  3 , total integrated cost =  14483.120647808577
# RUN  4 , total integrated cost =  14483.11503840324
# RUN  5 , total integrated cost =  14483.114961581245
# RUN  6 , total integrated cost =  14483.114956260793
# RUN  7 , total integrated cost =  14483.114955731482
# RUN  8 , total integrated cost =  14483.114955659228
# RUN  9 , total integrated cost =  14483.114955646743
# RUN  10 , total integrated cost =  14483.11495564476
# RUN  11 , total integrated cost =  14483.114955644425
# RUN  12 , total integrated cost =  14483.11495564437
# RUN  13 , total integrated cost =  14483.114955644336
# RUN  14 , total integrated cost =  14483.114955644334
# RUN  15 , total integrated cost =  14483.114955644334
# Control only changes marginally.
# RUN  15 , total integrated cost =  14483.114955644334
# Improved over  15  iterations in  0.2677362149988767  seconds by  0.00023446506708069137  percent.
# cost splitting :  3350.7790899314696 [0.         5.24535384]
# --------------------- 2
# set cost params:  1.0 0.0 1801.7903509670941
# interpolate adjoint :  True True True
# initial cost =  14485.531848856706
# RUN  0 , total integrated cost =  14485.531848856706
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14485.531846766295
# RUN  2 , total integrated cost =  14485.53184533539
# RUN  3 , total integrated cost =  14485.531844035755
# RUN  4 , total integrated cost =  14485.531842473492
# RUN  5 , total integrated cost =  14485.531839940286
# RUN  6 , total integrated cost =  14485.53183368656
# RUN  7 , total integrated cost =  14485.531802222238
# RUN  8 , total integrated cost =  14485.530903467195
# RUN  9 , total integrated cost =  14485.527526346614
# RUN  10 , total integrated cost =  14485.527365574286
# RUN  11 , total integrated cost =  14485.527357679519
# RUN  12 , total integrated cost =  14485.527353486914
# RUN  13 , total integrated cost =  14485.527347323423
# RUN  14 , total integrated cost =  14485.527329405326
# RUN  15 , total integrated cost =  14485.527152392999
# RUN  16 , total integrated cost =  14485.524130601927
# RUN  17 , total integrated cost =  14485.523161521105
# RUN  18 , total integrated cost =  14485.5231476302
# RUN  19 , total integrated cost =  14485.523147083095
# RUN  20 , total integrated cost =  14485.523147062722
# Control only changes marginally.
# RUN  25 , total integrated cost =  14485.523147062551
# Improved over  25  iterations in  0.4438248929945985  seconds by  6.00723138433068e-05  percent.
# cost splitting :  3351.9144010073474 [0.         5.24440229]
# --------------------- 3
# set cost params:  1.0 0.0 1801.9007890030275
# interpolate adjoint :  True True True
# initial cost =  14486.102328551551
# RUN  0 , total integrated cost =  14486.102328551551
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14486.102328551551
# Control only changes marginally.
# RUN  1 , total integrated cost =  14486.102328551551
# Improved over  1  iterations in  0.08193057200696785  seconds by  0.0  percent.
# cost splitting :  3351.9144010073474 [0.         5.24440229]
# 20 102 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 1801.9007890030275
# interpolate adjoint :  True True True
# initial cost =  14407.447856014236
# RUN  0 , total integrated cost =  14407.447856014236
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14407.446625026492
# RUN  2 , total integrated cost =  14407.446621103249
# RUN  3 , total integrated cost =  14407.446621103245
# RUN  4 , total integrated cost =  14407.446621103245
# Control only changes marginally.
# RUN  4 , total integrated cost =  14407.446621103245
# Improved over  4  iterations in  0.1439317609911086  seconds by  8.57133757392603e-06  percent.
# cost splitting :  3288.1723869710363 [0.        5.2448223]
# --------------------- 1
# set cost params:  1.0 0.0 1813.9098145150524
# interpolate adjoint :  True True True
# initial cost =  14470.43182591127
# RUN  0 , total integrated cost =  14470.43182591127
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14470.42187860136
# RUN  2 , total integrated cost =  14470.4202459146
# RUN  3 , total integrated cost =  14470.412631883091
# RUN  4 , total integrated cost =  14470.39922571635
# RUN  5 , total integrated cost =  14470.399225716345
# RUN  6 , total integrated cost =  14470.39922571634
# RUN  7 , total integrated cost =  14470.39922571634
# Control only changes marginally.
# RUN  7 , total integrated cost =  14470.39922571634
# Improved over  7  iterations in  0.20217721299559344  seconds by  0.00022528833500246037  percent.
# cost splitting :  3292.3371654557923 [0.         5.24134316]
# --------------------- 2
# set cost params:  1.0 0.0 1814.3192648808638
# interpolate adjoint :  True True True
# initial cost =  14472.545295590102
# RUN  0 , total integrated cost =  14472.545295590102
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14472.545295590102
# Control only changes marginally.
# RUN  1 , total integrated cost =  14472.545295590102
# Improved over  1  iterations in  0.07614207400183659  seconds by  0.0  percent.
# cost splitting :  3292.3371654557923 [0.         5.24134316]
# 20 103 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 1814.3192648808638
# interpolate adjoint :  True True True
# initial cost =  14393.352596513983
# RUN  0 , total integrated cost =  14393.352596513983
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14393.35156164398
# RUN  2 , total integrated cost =  14393.351561643973
# RUN  3 , total integrated cost =  14393.351561643973
# Control only changes marginally.
# RUN  3 , total integrated cost =  14393.351561643973
# Improved over  3  iterations in  0.1263007610104978  seconds by  7.189916345851088e-06  percent.
# cost splitting :  3228.5362120317645 [0.         5.24185104]
# --------------------- 1
# set cost params:  1.0 0.0 1826.314931961632
# interpolate adjoint :  True True True
# initial cost =  14456.231061574086
# RUN  0 , total integrated cost =  14456.231061574086
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14456.218560125653
# RUN  2 , total integrated cost =  14456.217038368259
# RUN  3 , total integrated cost =  14456.2155781762
# RUN  4 , total integrated cost =  14456.206466462863
# RUN  5 , total integrated cost =  14456.203898282389
# RUN  6 , total integrated cost =  14456.203681556752
# RUN  7 , total integrated cost =  14456.19710121912
# RUN  8 , total integrated cost =  14456.195863025343
# RUN  9 , total integrated cost =  14456.194412215784
# RUN  10 , total integrated cost =  14456.194404731115
# RUN  11 , total integrated cost =  14456.194404712249
# RUN  12 , total integrated cost =  14456.194404711165
# RUN  13 , total integrated cost =  14456.194404711088
# RUN  14 , total integrated cost =  14456.194404711077
# RUN  15 , total integrated cost =  14456.194404711077
# Control only changes marginally.
# RUN  15 , total integrated cost =  14456.194404711077
# Improved over  15  iterations in  0.3103247730032308  seconds by  0.0002535713690008379  percent.
# cost splitting :  3234.003546347184 [0.         5.23730327]
# --------------------- 2
# set cost params:  1.0 0.0 1826.8568760779808
# interpolate adjoint :  True True True
# initial cost =  14459.032730402385
# RUN  0 , total integrated cost =  14459.032730402385
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14459.032730402385
# Control only changes marginally.
# RUN  1 , total integrated cost =  14459.032730402385
# Improved over  1  iterations in  0.07666358699498232  seconds by  0.0  percent.
# cost splitting :  3234.003546347184 [0.         5.23730327]
# 20 104 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 1826.8568760779808
# interpolate adjoint :  True True True
# initial cost =  14379.309959228176
# RUN  0 , total integrated cost =  14379.309959228176
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14379.309432584108
# RUN  2 , total integrated cost =  14379.309432212176
# RUN  3 , total integrated cost =  14379.309432205657
# RUN  4 , total integrated cost =  14379.309432205599
# RUN  5 , total integrated cost =  14379.309432205599
# Control only changes marginally.
# RUN  5 , total integrated cost =  14379.309432205599
# Improved over  5  iterations in  0.16556547899381258  seconds by  3.6651451154057213e-06  percent.
# cost splitting :  3170.490836767261 [0.         5.23761098]
# --------------------- 1
# set cost params:  1.0 0.0 1838.8758234333948
# interpolate adjoint :  True True True
# initial cost =  14442.260002790621
# RUN  0 , total integrated cost =  14442.260002790621
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14442.25342000114
# RUN  2 , total integrated cost =  14442.253129554985
# RUN  3 , total integrated cost =  14442.25303446855
# RUN  4 , total integrated cost =  14442.252699541561
# RUN  5 , total integrated cost =  14442.24340940016
# RUN  6 , total integrated cost =  14442.242528786266
# RUN  7 , total integrated cost =  14442.242528786257
# RUN  8 , total integrated cost =  14442.242528786255
# RUN  9 , total integrated cost =  14442.242528786255
# Control only changes marginally.
# RUN  9 , total integrated cost =  14442.242528786255
# Improved over  9  iterations in  0.25151773399556987  seconds by  0.00012099217408945151  percent.
# cost splitting :  3175.27270551942 [0.         5.23365555]
# --------------------- 2
# set cost params:  1.0 0.0 1839.3519103156345
# interpolate adjoint :  True True True
# initial cost =  14444.734203538006
# RUN  0 , total integrated cost =  14444.734203538006
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14444.734203538006
# Control only changes marginally.
# RUN  1 , total integrated cost =  14444.734203538006
# Improved over  1  iterations in  0.07499590200313833  seconds by  0.0  percent.
# cost splitting :  3175.27270551942 [0.         5.23365555]
# 20 105 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 1839.3519103156345
# interpolate adjoint :  True True True
# initial cost =  14364.498506191108
# RUN  0 , total integrated cost =  14364.498506191108
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14364.496607773657
# RUN  2 , total integrated cost =  14364.496525280443
# RUN  3 , total integrated cost =  14364.496516570347
# RUN  4 , total integrated cost =  14364.49651614576
# RUN  5 , total integrated cost =  14364.496516145755
# RUN  6 , total integrated cost =  14364.496516145751
# RUN  7 , total integrated cost =  14364.496516145751
# Control only changes marginally.
# RUN  7 , total integrated cost =  14364.496516145751
# Improved over  7  iterations in  0.19248253099794965  seconds by  1.3853914609285312e-05  percent.
# cost splitting :  3111.1363648994297 [0.         5.23452832]
# --------------------- 1
# set cost params:  1.0 0.0 1851.2977823598344
# interpolate adjoint :  True True True
# initial cost =  14427.02752164955
# RUN  0 , total integrated cost =  14427.02752164955
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14427.015806712176
# RUN  2 , total integrated cost =  14427.015701275466
# RUN  3 , total integrated cost =  14427.015700199652
# RUN  4 , total integrated cost =  14427.015700192132
# RUN  5 , total integrated cost =  14427.015700191909
# RUN  6 , total integrated cost =  14427.015700191894
# RUN  7 , total integrated cost =  14427.015700191889
# RUN  8 , total integrated cost =  14427.015700191887
# RUN  9 , total integrated cost =  14427.015700191887
# Control only changes marginally.
# RUN  9 , total integrated cost =  14427.015700191887
# Improved over  9  iterations in  0.21410867899248842  seconds by  8.193966252179052e-05  percent.
# cost splitting :  3113.201819386365 [0.         5.23282344]
# --------------------- 2
# set cost params:  1.0 0.0 1851.5062339219396
# interpolate adjoint :  True True True
# initial cost =  14428.106490411385
# RUN  0 , total integrated cost =  14428.106490411385
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14428.106490411385
# Control only changes marginally.
# RUN  1 , total integrated cost =  14428.106490411385
# Improved over  1  iterations in  0.06988425699819345  seconds by  0.0  percent.
# cost splitting :  3113.201819386365 [0.         5.23282344]
# 20 106 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 1851.5062339219396
# interpolate adjoint :  True True True
# initial cost =  14347.349161188857
# RUN  0 , total integrated cost =  14347.349161188857
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14347.347458815817
# RUN  2 , total integrated cost =  14347.347458815817
# Control only changes marginally.
# RUN  2 , total integrated cost =  14347.347458815817
# Improved over  2  iterations in  0.12974799898802303  seconds by  1.186541862807644e-05  percent.
# cost splitting :  3049.245537986518 [0.         5.23359949]
# --------------------- 1
# set cost params:  1.0 0.0 1863.4520103915536
# interpolate adjoint :  True True True
# initial cost =  14409.86686847607
# RUN  0 , total integrated cost =  14409.86686847607
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14409.85207933027
# RUN  2 , total integrated cost =  14409.850608734028
# RUN  3 , total integrated cost =  14409.850452389861
# RUN  4 , total integrated cost =  14409.850172944109
# RUN  5 , total integrated cost =  14409.837105450591
# RUN  6 , total integrated cost =  14409.833976680271
# RUN  7 , total integrated cost =  14409.83397668027
# RUN  8 , total integrated cost =  14409.83397668027
# Control only changes marginally.
# RUN  8 , total integrated cost =  14409.83397668027
# Improved over  8  iterations in  0.2114029080112232  seconds by  0.00022825884585131462  percent.
# cost splitting :  3052.8500424594 [0.         5.23062744]
# --------------------- 2
# set cost params:  1.0 0.0 1863.8217126451552
# interpolate adjoint :  True True True
# initial cost =  14411.76775143192
# RUN  0 , total integrated cost =  14411.76775143192
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14411.76775143192
# Control only changes marginally.
# RUN  1 , total integrated cost =  14411.76775143192
# Improved over  1  iterations in  0.09121098199102562  seconds by  0.0  percent.
# cost splitting :  3052.8500424594 [0.         5.23062744]
# 20 107 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 1863.8217126451552
# interpolate adjoint :  True True True
# initial cost =  14330.49853066665
# RUN  0 , total integrated cost =  14330.49853066665
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14330.497528976834
# RUN  2 , total integrated cost =  14330.497525568282
# RUN  3 , total integrated cost =  14330.497525435225
# RUN  4 , total integrated cost =  14330.497525434843
# RUN  5 , total integrated cost =  14330.497525434817
# RUN  6 , total integrated cost =  14330.497525434814
# RUN  7 , total integrated cost =  14330.497525434812
# RUN  8 , total integrated cost =  14330.497525434803
# RUN  9 , total integrated cost =  14330.4975254348
# RUN  10 , total integrated cost =  14330.4975254348
# Control only changes marginally.
# RUN  10 , total integrated cost =  14330.4975254348
# Improved over  10  iterations in  0.269890306997695  seconds by  7.0146327999509595e-06  percent.
# cost splitting :  2989.3012930245195 [0.         5.23112086]
# --------------------- 1
# set cost params:  1.0 0.0 1875.7941182871857
# interpolate adjoint :  True True True
# initial cost =  14393.126626322108
# RUN  0 , total integrated cost =  14393.126626322108
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14393.117434707423
# RUN  2 , total integrated cost =  14393.116972563806
# RUN  3 , total integrated cost =  14393.116955169633
# RUN  4 , total integrated cost =  14393.11695230723
# RUN  5 , total integrated cost =  14393.116951767286
# RUN  6 , total integrated cost =  14393.116951634736
# RUN  7 , total integrated cost =  14393.116951598375
# RUN  8 , total integrated cost =  14393.116951589041
# RUN  9 , total integrated cost =  14393.116951586508
# RUN  10 , total integrated cost =  14393.116951585755
# RUN  11 , total integrated cost =  14393.116951585565
# RUN  12 , total integrated cost =  14393.116951585527
# RUN  13 , total integrated cost =  14393.116951585507
# RUN  14 , total integrated cost =  14393.116951585507
# Control only changes marginally.
# RUN  14 , total integrated cost =  14393.116951585507
# Improved over  14  iterations in  0.2681500740000047  seconds by  6.721775504558991e-05  percent.
# cost splitting :  2990.900597553378 [0.         5.22980923]
# --------------------- 2
# set cost params:  1.0 0.0 1875.9587602017764
# interpolate adjoint :  True True True
# initial cost =  14393.977997389706
# RUN  0 , total integrated cost =  14393.977997389706
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14393.977997251022
# RUN  2 , total integrated cost =  14393.977997195972
# RUN  3 , total integrated cost =  14393.977997174046
# RUN  4 , total integrated cost =  14393.977997164857
# RUN  5 , total integrated cost =  14393.97799716101
# RUN  6 , total integrated cost =  14393.977997159382
# RUN  7 , total integrated cost =  14393.977997158621
# RUN  8 , total integrated cost =  14393.977997158301
# RUN  9 , total integrated cost =  14393.977997158145
# RUN  10 , total integrated cost =  14393.977997158083
# RUN  11 , total integrated cost =  14393.977997158041
# RUN  12 , total integrated cost =  14393.977997158014
# RUN  13 , total integrated cost =  14393.977997158
# RUN  14 , total integrated cost =  14393.977997158
# Control only changes marginally.
# RUN  14 , total integrated cost =  14393.977997158
# Improved over  14  iterations in  0.25152737699681893  seconds by  1.6097487787192222e-09  percent.
# cost splitting :  2990.8828827062334 [0.        5.2298237]
# --------------------- 3
# set cost params:  1.0 0.0 1875.9569570702367
# interpolate adjoint :  True True True
# initial cost =  14393.968567097945
# RUN  0 , total integrated cost =  14393.968567097945
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14393.968567097943
# RUN  2 , total integrated cost =  14393.96856709794
# RUN  3 , total integrated cost =  14393.96856709794
# Control only changes marginally.
# RUN  3 , total integrated cost =  14393.96856709794
# Improved over  3  iterations in  0.14478885701100808  seconds by  2.842170943040401e-14  percent.
# cost splitting :  2990.8828826934614 [0.        5.2298237]
# --------------------- 4
# set cost params:  1.0 0.0 1875.9569570689378
# interpolate adjoint :  True True True
# initial cost =  14393.968567091146
# RUN  0 , total integrated cost =  14393.968567091146
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14393.968567091146
# Control only changes marginally.
# RUN  1 , total integrated cost =  14393.968567091146
# Improved over  1  iterations in  0.08545748599863146  seconds by  0.0  percent.
# cost splitting :  2990.8828826934614 [0.        5.2298237]
# 20 108 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 1875.9569570689378
# interpolate adjoint :  True True True
# initial cost =  14312.206242214963
# RUN  0 , total integrated cost =  14312.206242214963
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14312.205202297237
# RUN  2 , total integrated cost =  14312.205201429253
# RUN  3 , total integrated cost =  14312.205201428533
# RUN  4 , total integrated cost =  14312.205201428525
# RUN  5 , total integrated cost =  14312.205201428522
# RUN  6 , total integrated cost =  14312.205201428518
# RUN  7 , total integrated cost =  14312.205201428518
# Control only changes marginally.
# RUN  7 , total integrated cost =  14312.205201428518
# Improved over  7  iterations in  0.17352213599951938  seconds by  7.272019615811587e-06  percent.
# cost splitting :  2927.3087024658084 [0.         5.23040477]
# --------------------- 1
# set cost params:  1.0 0.0 1887.9032827873484
# interpolate adjoint :  True True True
# initial cost =  14374.689320415058
# RUN  0 , total integrated cost =  14374.689320415058
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14374.673112429642
# RUN  2 , total integrated cost =  14374.668964834957
# RUN  3 , total integrated cost =  14374.643750389332
# RUN  4 , total integrated cost =  14374.634274560038
# RUN  5 , total integrated cost =  14374.634233589237
# RUN  6 , total integrated cost =  14374.634232917984
# RUN  7 , total integrated cost =  14374.634232867804
# RUN  8 , total integrated cost =  14374.6342328632
# RUN  9 , total integrated cost =  14374.634232862856
# RUN  10 , total integrated cost =  14374.634232862849
# RUN  11 , total integrated cost =  14374.634232862845
# RUN  12 , total integrated cost =  14374.634232862845
# Control only changes marginally.
# RUN  12 , total integrated cost =  14374.634232862845
# Improved over  12  iterations in  0.35359923700161744  seconds by  0.00038322603698759394  percent.
# cost splitting :  2933.7431435581198 [0.         5.22513604]
# --------------------- 2
# set cost params:  1.0 0.0 1888.5754947938062
# interpolate adjoint :  True True True
# initial cost =  14378.146632046748
# RUN  0 , total integrated cost =  14378.146632046748
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14378.146632046748
# Control only changes marginally.
# RUN  1 , total integrated cost =  14378.146632046748
# Improved over  1  iterations in  0.09428749699145555  seconds by  0.0  percent.
# cost splitting :  2933.7431435581198 [0.         5.22513604]
# 20 109 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 1888.5754947938062
# interpolate adjoint :  True True True
# initial cost =  14295.917719935278
# RUN  0 , total integrated cost =  14295.917719935278
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14295.9166314545
# RUN  2 , total integrated cost =  14295.916618454932
# RUN  3 , total integrated cost =  14295.916617392506
# RUN  4 , total integrated cost =  14295.916617232466
# RUN  5 , total integrated cost =  14295.91661720481
# RUN  6 , total integrated cost =  14295.916617199971
# RUN  7 , total integrated cost =  14295.916617199025
# RUN  8 , total integrated cost =  14295.916617198813
# RUN  9 , total integrated cost =  14295.916617198767
# RUN  10 , total integrated cost =  14295.916617198764
# RUN  11 , total integrated cost =  14295.91661719876
# RUN  12 , total integrated cost =  14295.916617198756
# RUN  13 , total integrated cost =  14295.916617198756
# Control only changes marginally.
# RUN  13 , total integrated cost =  14295.916617198756
# Improved over  13  iterations in  0.27458468299300876  seconds by  7.713646255069762e-06  percent.
# cost splitting :  2870.116737561653 [0.         5.22582679]
# --------------------- 1
# set cost params:  1.0 0.0 1900.5012402271216
# interpolate adjoint :  True True True
# initial cost =  14358.238497170845
# RUN  0 , total integrated cost =  14358.238497170845
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14358.226207564116
# RUN  2 , total integrated cost =  14358.225525727523
# RUN  3 , total integrated cost =  14358.225274076984
# RUN  4 , total integrated cost =  14358.223574151327
# RUN  5 , total integrated cost =  14358.219550772708
# RUN  6 , total integrated cost =  14358.219486778882
# RUN  7 , total integrated cost =  14358.21948677888
# RUN  8 , total integrated cost =  14358.219486778875
# RUN  9 , total integrated cost =  14358.219486778875
# Control only changes marginally.
# RUN  9 , total integrated cost =  14358.219486778875
# Improved over  9  iterations in  0.25762177098658867  seconds by  0.0001324005864233868  percent.
# cost splitting :  2873.0802079417886 [0.         5.22341188]
# --------------------- 2
# set cost params:  1.0 0.0 1900.8125437401886
# interpolate adjoint :  True True True
# initial cost =  14359.845553247636
# RUN  0 , total integrated cost =  14359.845553247636
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14359.845553247636
# Control only changes marginally.
# RUN  1 , total integrated cost =  14359.845553247636
# Improved over  1  iterations in  0.08160889499413315  seconds by  0.0  percent.
# cost splitting :  2873.0802079417886 [0.         5.22341188]
# 20 110 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 1900.8125437401886
# interpolate adjoint :  True True True
# initial cost =  14277.141065233376
# RUN  0 , total integrated cost =  14277.141065233376
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14277.138905381995
# RUN  2 , total integrated cost =  14277.138905381984
# RUN  3 , total integrated cost =  14277.138905381984
# Control only changes marginally.
# RUN  3 , total integrated cost =  14277.138905381984
# Improved over  3  iterations in  0.13532211199344601  seconds by  1.5128038469924832e-05  percent.
# cost splitting :  2809.5677957548237 [0.         5.22407995]
# --------------------- 1
# set cost params:  1.0 0.0 1912.7270901008226
# interpolate adjoint :  True True True
# initial cost =  14339.381448110202
# RUN  0 , total integrated cost =  14339.381448110202
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14339.367897019049
# RUN  2 , total integrated cost =  14339.366185401454
# RUN  3 , total integrated cost =  14339.36588817634
# RUN  4 , total integrated cost =  14339.36236308063
# RUN  5 , total integrated cost =  14339.356546322342
# RUN  6 , total integrated cost =  14339.356415702536
# RUN  7 , total integrated cost =  14339.356412374029
# RUN  8 , total integrated cost =  14339.35641223232
# RUN  9 , total integrated cost =  14339.356412225956
# RUN  10 , total integrated cost =  14339.356412225701
# RUN  11 , total integrated cost =  14339.35641222568
# RUN  12 , total integrated cost =  14339.356412225674
# RUN  13 , total integrated cost =  14339.356412225674
# Control only changes marginally.
# RUN  13 , total integrated cost =  14339.356412225674
# Improved over  13  iterations in  0.27930028100672644  seconds by  0.00017459528933727597  percent.
# cost splitting :  2812.44481854852 [0.         5.22173955]
# --------------------- 2
# set cost params:  1.0 0.0 1913.0334106203334
# interpolate adjoint :  True True True
# initial cost =  14340.955938196303
# RUN  0 , total integrated cost =  14340.955938196303
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14340.955938196303
# Control only changes marginally.
# RUN  1 , total integrated cost =  14340.955938196303
# Improved over  1  iterations in  0.07395343299140222  seconds by  0.0  percent.
# cost splitting :  2812.44481854852 [0.         5.22173955]
# 20 111 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 1913.0334106203334
# interpolate adjoint :  True True True
# initial cost =  14257.807234201042
# RUN  0 , total integrated cost =  14257.807234201042
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14257.805717689582
# RUN  2 , total integrated cost =  14257.805717689582
# Control only changes marginally.
# RUN  2 , total integrated cost =  14257.805717689582
# Improved over  2  iterations in  0.09916553299990483  seconds by  1.0636358283022673e-05  percent.
# cost splitting :  2749.050498591011 [0.         5.22239852]
# --------------------- 1
# set cost params:  1.0 0.0 1924.9309476384983
# interpolate adjoint :  True True True
# initial cost =  14319.939397416529
# RUN  0 , total integrated cost =  14319.939397416529
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14319.924508986884
# RUN  2 , total integrated cost =  14319.921847390284
# RUN  3 , total integrated cost =  14319.91908503116
# RUN  4 , total integrated cost =  14319.909496138716
# RUN  5 , total integrated cost =  14319.908430130017
# RUN  6 , total integrated cost =  14319.908408563155
# RUN  7 , total integrated cost =  14319.908406117234
# RUN  8 , total integrated cost =  14319.908405559547
# RUN  9 , total integrated cost =  14319.90840539373
# RUN  10 , total integrated cost =  14319.908405359818
# RUN  11 , total integrated cost =  14319.908405352015
# RUN  12 , total integrated cost =  14319.908405350317
# RUN  13 , total integrated cost =  14319.908405349892
# RUN  14 , total integrated cost =  14319.908405349786
# RUN  15 , total integrated cost =  14319.908405349779
# RUN  16 , total integrated cost =  14319.908405349775
# RUN  17 , total integrated cost =  14319.908405349774
# RUN  18 , total integrated cost =  14319.908405349772
# RUN  19 , total integrated cost =  14319.90840534977
# RUN  20 , total integrated cost =  14319.908405349768
# Control only changes marginally.
# RUN  21 , total integrated cost =  14319.908405349768
# Improved over  21  iterations in  0.46216100399033166  seconds by  0.00021642596313142803  percent.
# cost splitting :  2752.532519041544 [0.         5.21957457]
# --------------------- 2
# set cost params:  1.0 0.0 1925.305288278375
# interpolate adjoint :  True True True
# initial cost =  14321.862304232494
# RUN  0 , total integrated cost =  14321.862304232494
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14321.862304120821
# RUN  2 , total integrated cost =  14321.862304069124
# RUN  3 , total integrated cost =  14321.862304046079
# RUN  4 , total integrated cost =  14321.862304035363
# RUN  5 , total integrated cost =  14321.86230403026
# RUN  6 , total integrated cost =  14321.862304027763
# RUN  7 , total integrated cost =  14321.862304026485
# RUN  8 , total integrated cost =  14321.862304025824
# RUN  9 , total integrated cost =  14321.86230402549
# RUN  10 , total integrated cost =  14321.862304025306
# RUN  11 , total integrated cost =  14321.862304025195
# RUN  12 , total integrated cost =  14321.862304025173
# RUN  13 , total integrated cost =  14321.86230402514
# RUN  14 , total integrated cost =  14321.862304025133
# RUN  15 , total integrated cost =  14321.862304025131
# RUN  16 , total integrated cost =  14321.862304025131
# Control only changes marginally.
# RUN  16 , total integrated cost =  14321.862304025131
# Improved over  16  iterations in  0.40835122398857493  seconds by  1.4478729326583561e-09  percent.
# cost splitting :  2752.514229437863 [0.         5.21958931]
# --------------------- 3
# set cost params:  1.0 0.0 1925.3033532561087
# interpolate adjoint :  True True True
# initial cost =  14321.852204003595
# RUN  0 , total integrated cost =  14321.852204003595
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14321.852204003595
# Control only changes marginally.
# RUN  1 , total integrated cost =  14321.852204003595
# Improved over  1  iterations in  0.0774426179996226  seconds by  0.0  percent.
# cost splitting :  2752.514229437863 [0.         5.21958931]
# 20 112 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 1925.3033532561087
# interpolate adjoint :  True True True
# initial cost =  14238.268652671293
# RUN  0 , total integrated cost =  14238.268652671293
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14238.267621413563
# RUN  2 , total integrated cost =  14238.267619951494
# RUN  3 , total integrated cost =  14238.2676199341
# RUN  4 , total integrated cost =  14238.267619933802
# RUN  5 , total integrated cost =  14238.267619933791
# RUN  6 , total integrated cost =  14238.267619933791
# Control only changes marginally.
# RUN  6 , total integrated cost =  14238.267619933791
# Improved over  6  iterations in  0.1349814800050808  seconds by  7.253251979477682e-06  percent.
# cost splitting :  2689.5136622416085 [0.         5.22001869]
# --------------------- 1
# set cost params:  1.0 0.0 1937.214017718868
# interpolate adjoint :  True True True
# initial cost =  14300.44151098597
# RUN  0 , total integrated cost =  14300.44151098597
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14300.425806048022
# RUN  2 , total integrated cost =  14300.42332040046
# RUN  3 , total integrated cost =  14300.409877542817
# RUN  4 , total integrated cost =  14300.379886050892
# RUN  5 , total integrated cost =  14300.376746244114
# RUN  6 , total integrated cost =  14300.339357445926
# RUN  7 , total integrated cost =  14300.336620720416
# RUN  8 , total integrated cost =  14300.329335996696
# RUN  9 , total integrated cost =  14300.328982327876
# RUN  10 , total integrated cost =  14300.32897290745
# RUN  11 , total integrated cost =  14300.328972422427
# RUN  12 , total integrated cost =  14300.328972385822
# RUN  13 , total integrated cost =  14300.328972382806
# RUN  14 , total integrated cost =  14300.328972382496
# RUN  15 , total integrated cost =  14300.328972382444
# RUN  16 , total integrated cost =  14300.328972382438
# RUN  17 , total integrated cost =  14300.328972382436
# RUN  18 , total integrated cost =  14300.328972382435
# RUN  19 , total integrated cost =  14300.328972382435
# Control only changes marginally.
# RUN  19 , total integrated cost =  14300.328972382435
# Improved over  19  iterations in  0.3174923670012504  seconds by  0.0007869589442321967  percent.
# cost splitting :  2699.9730777434697 [0.         5.21155288]
# --------------------- 2
# set cost params:  1.0 0.0 1938.3539218446813
# interpolate adjoint :  True True True
# initial cost =  14306.269643006908
# RUN  0 , total integrated cost =  14306.269643006908
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14306.269643006905
# RUN  2 , total integrated cost =  14306.269643006905
# Control only changes marginally.
# RUN  2 , total integrated cost =  14306.269643006905
# Improved over  2  iterations in  0.18605446501169354  seconds by  2.842170943040401e-14  percent.
# cost splitting :  2699.9730777434524 [0.         5.21155288]
# --------------------- 3
# set cost params:  1.0 0.0 1938.35392184468
# interpolate adjoint :  True True True
# initial cost =  14306.269643006897
# RUN  0 , total integrated cost =  14306.269643006897
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14306.269643006897
# Control only changes marginally.
# RUN  1 , total integrated cost =  14306.269643006897
# Improved over  1  iterations in  0.0757367879996309  seconds by  0.0  percent.
# cost splitting :  2699.9730777434524 [0.         5.21155288]
# 20 113 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 1938.35392184468
# interpolate adjoint :  True True True
# initial cost =  14222.280060510559
# RUN  0 , total integrated cost =  14222.280060510559
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14222.278626296245
# RUN  2 , total integrated cost =  14222.27859310283
# RUN  3 , total integrated cost =  14222.278544716499
# RUN  4 , total integrated cost =  14222.278143837177
# RUN  5 , total integrated cost =  14222.27601891828
# RUN  6 , total integrated cost =  14222.275783276222
# RUN  7 , total integrated cost =  14222.275783276209
# RUN  8 , total integrated cost =  14222.275783276207
# RUN  9 , total integrated cost =  14222.275783276205
# RUN  10 , total integrated cost =  14222.275783276205
# Control only changes marginally.
# RUN  10 , total integrated cost =  14222.275783276205
# Improved over  10  iterations in  0.22107907799363602  seconds by  3.0074181751160722e-05  percent.
# cost splitting :  2636.4915160581213 [0.         5.21245242]
# --------------------- 1
# set cost params:  1.0 0.0 1950.1982357029094
# interpolate adjoint :  True True True
# initial cost =  14284.013705729789
# RUN  0 , total integrated cost =  14284.013705729789
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14283.998657362616
# RUN  2 , total integrated cost =  14283.997501139904
# RUN  3 , total integrated cost =  14283.997046463523
# RUN  4 , total integrated cost =  14283.988109724021
# RUN  5 , total integrated cost =  14283.97936558703
# RUN  6 , total integrated cost =  14283.979284622568
# RUN  7 , total integrated cost =  14283.979276294729
# RUN  8 , total integrated cost =  14283.979274190286
# RUN  9 , total integrated cost =  14283.979273208639
# RUN  10 , total integrated cost =  14283.97927260683
# RUN  11 , total integrated cost =  14283.979272126579
# RUN  12 , total integrated cost =  14283.979271960048
# RUN  13 , total integrated cost =  14283.979271955739
# RUN  14 , total integrated cost =  14283.979271955684
# RUN  15 , total integrated cost =  14283.979271955668
# RUN  16 , total integrated cost =  14283.979271955654
# RUN  17 , total integrated cost =  14283.979271955652
# RUN  18 , total integrated cost =  14283.97927195565
# RUN  19 , total integrated cost =  14283.979271955648
# RUN  20 , total integrated cost =  14283.979271955648
# Control only changes marginally.
# RUN  20 , total integrated cost =  14283.979271955648
# Improved over  20  iterations in  0.47260739699413534  seconds by  0.00024106511553156906  percent.
# cost splitting :  2640.3158640647403 [0.        5.2093713]
# --------------------- 2
# set cost params:  1.0 0.0 1950.617564684669
# interpolate adjoint :  True True True
# initial cost =  14286.163712320575
# RUN  0 , total integrated cost =  14286.163712320575
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14286.163712320573
# RUN  2 , total integrated cost =  14286.16371232057
# RUN  3 , total integrated cost =  14286.16371232057
# Control only changes marginally.
# RUN  3 , total integrated cost =  14286.16371232057
# Improved over  3  iterations in  0.1448210699891206  seconds by  2.842170943040401e-14  percent.
# cost splitting :  2640.3158640641573 [0.        5.2093713]
# --------------------- 3
# set cost params:  1.0 0.0 1950.617564684607
# interpolate adjoint :  True True True
# initial cost =  14286.163712320245
# RUN  0 , total integrated cost =  14286.163712320245
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14286.163712320245
# Control only changes marginally.
# RUN  1 , total integrated cost =  14286.163712320245
# Improved over  1  iterations in  0.08351653099816758  seconds by  0.0  percent.
# cost splitting :  2640.3158640641573 [0.        5.2093713]
# 20 114 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 1950.617564684607
# interpolate adjoint :  True True True
# initial cost =  14201.783823447626
# RUN  0 , total integrated cost =  14201.783823447626
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14201.783146549855
# RUN  2 , total integrated cost =  14201.783122087725
# RUN  3 , total integrated cost =  14201.783112317964
# RUN  4 , total integrated cost =  14201.783100411356
# RUN  5 , total integrated cost =  14201.78310041135
# RUN  6 , total integrated cost =  14201.78310041135
# Control only changes marginally.
# RUN  6 , total integrated cost =  14201.78310041135
# Improved over  6  iterations in  0.17310236699995585  seconds by  5.0911652067497926e-06  percent.
# cost splitting :  2577.2398494132312 [0.         5.21005517]
# --------------------- 1
# set cost params:  1.0 0.0 1962.4681216644503
# interpolate adjoint :  True True True
# initial cost =  14263.525156070787
# RUN  0 , total integrated cost =  14263.525156070787
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14263.511668193025
# RUN  2 , total integrated cost =  14263.51066631602
# RUN  3 , total integrated cost =  14263.509960699643
# RUN  4 , total integrated cost =  14263.500964672341
# RUN  5 , total integrated cost =  14263.498925169748
# RUN  6 , total integrated cost =  14263.498921338323
# RUN  7 , total integrated cost =  14263.498921284543
# RUN  8 , total integrated cost =  14263.49892128332
# RUN  9 , total integrated cost =  14263.498921283279
# RUN  10 , total integrated cost =  14263.498921283279
# Control only changes marginally.
# RUN  10 , total integrated cost =  14263.498921283279
# Improved over  10  iterations in  0.25073681100911926  seconds by  0.0001839291985845648  percent.
# cost splitting :  2580.84821727466 [0.         5.20716027]
# --------------------- 2
# set cost params:  1.0 0.0 1962.8661835012674
# interpolate adjoint :  True True True
# initial cost =  14265.57169306682
# RUN  0 , total integrated cost =  14265.57169306682
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14265.57169306682
# Control only changes marginally.
# RUN  1 , total integrated cost =  14265.57169306682
# Improved over  1  iterations in  0.07449593700584956  seconds by  0.0  percent.
# cost splitting :  2580.84821727466 [0.         5.20716027]
# 20 115 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 1962.8661835012674
# interpolate adjoint :  True True True
# initial cost =  14180.814626016974
# RUN  0 , total integrated cost =  14180.814626016974
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14180.81363227546
# RUN  2 , total integrated cost =  14180.813628599968
# RUN  3 , total integrated cost =  14180.813628587057
# RUN  4 , total integrated cost =  14180.813628586986
# RUN  5 , total integrated cost =  14180.813628586984
# RUN  6 , total integrated cost =  14180.813628586984
# Control only changes marginally.
# RUN  6 , total integrated cost =  14180.813628586984
# Improved over  6  iterations in  0.16829797999525908  seconds by  7.033657908550595e-06  percent.
# cost splitting :  2518.078746126621 [0.         5.20771265]
# --------------------- 1
# set cost params:  1.0 0.0 1974.7111580522608
# interpolate adjoint :  True True True
# initial cost =  14242.498852446175
# RUN  0 , total integrated cost =  14242.498852446175
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14242.485438615804
# RUN  2 , total integrated cost =  14242.483635003575
# RUN  3 , total integrated cost =  14242.47188024572
# RUN  4 , total integrated cost =  14242.467807350182
# RUN  5 , total integrated cost =  14242.467807350176
# RUN  6 , total integrated cost =  14242.467807350176
# Control only changes marginally.
# RUN  6 , total integrated cost =  14242.467807350176
# Improved over  6  iterations in  0.19146424299106002  seconds by  0.00021797506406073808  percent.
# cost splitting :  2522.691934968072 [0.         5.20402421]
# --------------------- 2
# set cost params:  1.0 0.0 1975.2243055014299
# interpolate adjoint :  True True True
# initial cost =  14245.138239096756
# RUN  0 , total integrated cost =  14245.138239096756
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14245.138239096756
# Control only changes marginally.
# RUN  1 , total integrated cost =  14245.138239096756
# Improved over  1  iterations in  0.07118424501095433  seconds by  0.0  percent.
# cost splitting :  2522.691934968072 [0.         5.20402421]
# 20 116 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 1975.2243055014299
# interpolate adjoint :  True True True
# initial cost =  14160.014552191407
# RUN  0 , total integrated cost =  14160.014552191407
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14160.013761095272
# RUN  2 , total integrated cost =  14160.0137516795
# RUN  3 , total integrated cost =  14160.01375103344
# RUN  4 , total integrated cost =  14160.013750985989
# RUN  5 , total integrated cost =  14160.013750982838
# RUN  6 , total integrated cost =  14160.013750982565
# RUN  7 , total integrated cost =  14160.013750982544
# RUN  8 , total integrated cost =  14160.013750982542
# RUN  9 , total integrated cost =  14160.01375098254
# RUN  10 , total integrated cost =  14160.01375098254
# Control only changes marginally.
# RUN  10 , total integrated cost =  14160.01375098254
# Improved over  10  iterations in  0.21033643200644292  seconds by  5.658248909412578e-06  percent.
# cost splitting :  2460.024080103721 [0.         5.20461107]
# --------------------- 1
# set cost params:  1.0 0.0 1987.0424164523477
# interpolate adjoint :  True True True
# initial cost =  14221.522422035578
# RUN  0 , total integrated cost =  14221.522422035578
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14221.509059380993
# RUN  2 , total integrated cost =  14221.509020314617
# RUN  3 , total integrated cost =  14221.50901552696
# RUN  4 , total integrated cost =  14221.509015355572
# RUN  5 , total integrated cost =  14221.509015355557
# RUN  6 , total integrated cost =  14221.509015355557
# Control only changes marginally.
# RUN  6 , total integrated cost =  14221.509015355557
# Improved over  6  iterations in  0.19360417600546498  seconds by  9.427035743669876e-05  percent.
# cost splitting :  2461.9715572362284 [0.         5.20305861]
# --------------------- 2
# set cost params:  1.0 0.0 1987.2610040018217
# interpolate adjoint :  True True True
# initial cost =  14222.646339186678
# RUN  0 , total integrated cost =  14222.646339186678
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14222.646339186678
# Control only changes marginally.
# RUN  1 , total integrated cost =  14222.646339186678
# Improved over  1  iterations in  0.07127130900335032  seconds by  0.0  percent.
# cost splitting :  2461.9715572362284 [0.         5.20305861]
# 20 117 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 1987.2610040018217
# interpolate adjoint :  True True True
# initial cost =  14137.202232587864
# RUN  0 , total integrated cost =  14137.202232587864
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14137.200642927344
# RUN  2 , total integrated cost =  14137.200615367716
# RUN  3 , total integrated cost =  14137.20061536771
# RUN  4 , total integrated cost =  14137.200615367705
# RUN  5 , total integrated cost =  14137.200615367705
# Control only changes marginally.
# RUN  5 , total integrated cost =  14137.200615367705
# Improved over  5  iterations in  0.14943216400570236  seconds by  1.1439464003615285e-05  percent.
# cost splitting :  2399.362992574549 [0.         5.20374197]
# --------------------- 1
# set cost params:  1.0 0.0 1999.0314852264928
# interpolate adjoint :  True True True
# initial cost =  14198.451162529063
# RUN  0 , total integrated cost =  14198.451162529063
# Gradient descend method:  None
# RUN  1 , total integrated cost =  14198.436113949432
# RUN  2 , total integrated cost =  14198.433605178705
# RUN  3 , total integrated cost =  14198.433090599112
# RUN  4 , total integrated cost =  14198.41742215168
# RUN  5 , total integrated cost =  14198.409033855402
# RUN  6 , total integrated cost =  14198.408704987723
# RUN  7 , total integrated cost =  14198.408609355025
# RUN  8 , total integrated cost =  14198.408600263272
# RUN  9 , total integrated cost =  14198.408598033919
# RUN  10 , total integrated cost =  14198.408596057734
# RUN  11 , total integrated cost =  14198.408593950446
# RUN  12 , total integrated cost =  14198.408591234213
# RUN  13 , total integrated cost =  14198.408586828165
# RUN  14 , total integrated cost =  14198.40857721153
# RUN  15 , total integrated cost =  14198.408550354281
# RUN  16 , total integrated cost =  14198.40854730067
# RUN  17 , total integrated cost =  14198.408547300663
# RUN  18 , total integrated cost =  14198.408547300663
# Control only changes marginally.
# RUN  18 , total integrated cost =  14198.408547300663
# Improved over  18  iterations in  0.3402229339990299  seconds by  0.00030013997943001414  percent.
# cost splitting :  2403.1566684848735 [0.         5.20071823]
# --------------------- 2
# set cost params:  1.0 0.0 1999.4642858975492
# interpolate adjoint :  True True True
# initial cost =  14200.659421641045
# RUN  0 , total integrated cost =  14200.659421641045
# ...
# RUN  1 , total integrated cost =  13190.885946731501
# Control only changes marginally.
# RUN  1 , total integrated cost =  13190.885946731501
# Improved over  1  iterations in  0.0781061210000189  seconds by  0.0  percent.
# cost splitting :  465.50512949947847 [0.         4.78969921]
# 20 169 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 2575.590109274581
# interpolate adjoint :  True True True
# initial cost =  13136.523511715552
# RUN  0 , total integrated cost =  13136.523511715552
# Gradient descend method:  None
# RUN  1 , total integrated cost =  13136.334357189427
# RUN  2 , total integrated cost =  13136.244071674675
# RUN  3 , total integrated cost =  13136.139563817536
# RUN  4 , total integrated cost =  13136.09627719526
# RUN  5 , total integrated cost =  13135.992594361775
# RUN  6 , total integrated cost =  13135.968590468314
# RUN  7 , total integrated cost =  13135.967061440839
# RUN  8 , total integrated cost =  13135.955950307436
# RUN  9 , total integrated cost =  13135.94486252656
# RUN  10 , total integrated cost =  13135.94466528913
# RUN  11 , total integrated cost =  13135.944633770867
# RUN  12 , total integrated cost =  13135.944603840651
# RUN  13 , total integrated cost =  13135.944533125157
# RUN  14 , total integrated cost =  13135.943003611228
# RUN  15 , total integrated cost =  13135.937845895163
# RUN  16 , total integrated cost =  13135.937491372373
# RUN  17 , total integrated cost =  13135.937483232081
# RUN  18 , total integrated cost =  13135.93748250449
# RUN  19 , total integrated cost =  13135.937482442183
# RUN  20 , total integrated cost =  13135.937482435904
# Control only changes marginally.
# RUN  26 , total integrated cost =  13135.93748243502
# Improved over  26  iterations in  0.5417355640092865  seconds by  0.004461068257583634  percent.
# cost splitting :  448.91648256418284 [0.         4.77932174]
# --------------------- 1
# set cost params:  1.0 0.0 2584.6534752149505
# interpolate adjoint :  True True True
# initial cost =  13179.254224330682
# RUN  0 , total integrated cost =  13179.254224330682
# Gradient descend method:  None
# RUN  1 , total integrated cost =  13179.242936678396
# RUN  2 , total integrated cost =  13179.241299776962
# RUN  3 , total integrated cost =  13179.241088747958
# RUN  4 , total integrated cost =  13179.239904772438
# RUN  5 , total integrated cost =  13179.232692378107
# RUN  6 , total integrated cost =  13179.231947820641
# RUN  7 , total integrated cost =  13179.231928410341
# RUN  8 , total integrated cost =  13179.231927330478
# RUN  9 , total integrated cost =  13179.2319272603
# RUN  10 , total integrated cost =  13179.231927254019
# RUN  11 , total integrated cost =  13179.231927253693
# RUN  12 , total integrated cost =  13179.231927253633
# RUN  13 , total integrated cost =  13179.231927253624
# RUN  14 , total integrated cost =  13179.231927253622
# RUN  15 , total integrated cost =  13179.23192725362
# RUN  16 , total integrated cost =  13179.231927253619
# RUN  17 , total integrated cost =  13179.231927253617
# RUN  18 , total integrated cost =  13179.231927253617
# Control only changes marginally.
# RUN  18 , total integrated cost =  13179.231927253617
# Improved over  18  iterations in  0.34335065398772713  seconds by  0.00016918314712199845  percent.
# cost splitting :  451.12040405051573 [0.         4.77774348]
# --------------------- 2
# set cost params:  1.0 0.0 2585.045992205398
# interpolate adjoint :  True True True
# initial cost =  13181.10727274456
# RUN  0 , total integrated cost =  13181.10727274456
# Gradient descend method:  None
# RUN  1 , total integrated cost =  13181.10727274456
# Control only changes marginally.
# RUN  1 , total integrated cost =  13181.10727274456
# Improved over  1  iterations in  0.09494609200919513  seconds by  0.0  percent.
# cost splitting :  451.12040405051573 [0.         4.77774348]
# 20 170 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 2585.045992205398
# interpolate adjoint :  True True True
# initial cost =  13127.646751412105
# RUN  0 , total integrated cost =  13127.646751412105
# Gradient descend method:  None
# RUN  1 , total integrated cost =  13127.401794595107
# RUN  2 , total integrated cost =  13127.294802202225
# RUN  3 , total integrated cost =  13127.173438422893
# RUN  4 , total integrated cost =  13127.124784467567
# RUN  5 , total integrated cost =  13127.03733521094
# RUN  6 , total integrated cost =  13127.002938308739
# RUN  7 , total integrated cost =  13127.000389432933
# RUN  8 , total integrated cost =  13126.972605051687
# RUN  9 , total integrated cost =  13126.960616693888
# RUN  10 , total integrated cost =  13126.960334204487
# RUN  11 , total integrated cost =  13126.960321221868
# RUN  12 , total integrated cost =  13126.960319012713
# RUN  13 , total integrated cost =  13126.96031838151
# RUN  14 , total integrated cost =  13126.960318160158
# RUN  15 , total integrated cost =  13126.960318080986
# RUN  16 , total integrated cost =  13126.960318050942
# RUN  17 , total integrated cost =  13126.960318039048
# RUN  18 , total integrated cost =  13126.960318033924
# RUN  19 , total integrated cost =  13126.960318031708
# RUN  20 , total integrated cost =  13126.960318030779
# RUN  30 , total integrated cost =  13126.960318030033
# Control only changes marginally.
# RUN  30 , total integrated cost =  13126.960318030033
# Improved over  30  iterations in  0.5033031360071618  seconds by  0.005228914176854005  percent.
# cost splitting :  436.74335008051395 [0.         4.76619452]
# --------------------- 1
# set cost params:  1.0 0.0 2594.3262759307577
# interpolate adjoint :  True True True
# initial cost =  13171.191955476654
# RUN  0 , total integrated cost =  13171.191955476654
# Gradient descend method:  None
# RUN  1 , total integrated cost =  13171.182739717255
# RUN  2 , total integrated cost =  13171.182669282953
# RUN  3 , total integrated cost =  13171.18266766902
# RUN  4 , total integrated cost =  13171.182667586312
# RUN  5 , total integrated cost =  13171.182667581235
# RUN  6 , total integrated cost =  13171.182667580912
# RUN  7 , total integrated cost =  13171.18266758088
# RUN  8 , total integrated cost =  13171.182667580872
# RUN  9 , total integrated cost =  13171.18266758087
# RUN  10 , total integrated cost =  13171.182667580866
# RUN  11 , total integrated cost =  13171.182667580866
# Control only changes marginally.
# RUN  11 , total integrated cost =  13171.182667580866
# Improved over  11  iterations in  0.27262253100343514  seconds by  7.051674457159152e-05  percent.
# cost splitting :  438.1906863913386 [0.         4.76516121]
# --------------------- 2
# set cost params:  1.0 0.0 2594.5851135919643
# interpolate adjoint :  True True True
# initial cost =  13172.416070764413
# RUN  0 , total integrated cost =  13172.416070764413
# Gradient descend method:  None
# RUN  1 , total integrated cost =  13172.416070764413
# Control only changes marginally.
# RUN  1 , total integrated cost =  13172.416070764413
# Improved over  1  iterations in  0.07940689800307155  seconds by  0.0  percent.
# cost splitting :  438.1906863913386 [0.         4.76516121]
# 20 171 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 2594.5851135919643
# interpolate adjoint :  True True True
# initial cost =  13119.809164505286
# RUN  0 , total integrated cost =  13119.809164505286
# Gradient descend method:  None
# RUN  1 , total integrated cost =  13119.618475260659
# RUN  2 , total integrated cost =  13119.526039362965
# RUN  3 , total integrated cost =  13119.38798274388
# RUN  4 , total integrated cost =  13119.322832570848
# RUN  5 , total integrated cost =  13119.223329670098
# RUN  6 , total integrated cost =  13119.173352762076
# RUN  7 , total integrated cost =  13119.166788791614
# RUN  8 , total integrated cost =  13119.143026364894
# RUN  9 , total integrated cost =  13119.135553338638
# RUN  10 , total integrated cost =  13119.133962430162
# RUN  11 , total integrated cost =  13119.10294644766
# RUN  12 , total integrated cost =  13119.092563431628
# RUN  13 , total integrated cost =  13119.092432755653
# RUN  14 , total integrated cost =  13119.092402086751
# RUN  15 , total integrated cost =  13119.092401681964
# RUN  16 , total integrated cost =  13119.092401681957
# RUN  17 , total integrated cost =  13119.092401681955
# RUN  18 , total integrated cost =  13119.092401681952
# RUN  19 , total integrated cost =  13119.092401681952
# Control only changes marginally.
# RUN  19 , total integrated cost =  13119.092401681952
# Improved over  19  iterations in  0.4580148120003287  seconds by  0.005463210739947044  percent.
# cost splitting :  424.79175094922454 [0.         4.75332668]
# --------------------- 1
# set cost params:  1.0 0.0 2603.8638000471074
# interpolate adjoint :  True True True
# initial cost =  13163.197029599187
# RUN  0 , total integrated cost =  13163.197029599187
# Gradient descend method:  None
# RUN  1 , total integrated cost =  13163.184722817175
# RUN  2 , total integrated cost =  13163.182461072307
# RUN  3 , total integrated cost =  13163.182152505007
# RUN  4 , total integrated cost =  13163.180554026276
# RUN  5 , total integrated cost =  13163.170974938243
# RUN  6 , total integrated cost =  13163.169566606433
# RUN  7 , total integrated cost =  13163.169490750332
# RUN  8 , total integrated cost =  13163.169469456547
# RUN  9 , total integrated cost =  13163.169457297587
# RUN  10 , total integrated cost =  13163.169444122655
# RUN  11 , total integrated cost =  13163.16941836813
# RUN  12 , total integrated cost =  13163.169301051705
# RUN  13 , total integrated cost =  13163.163212312547
# RUN  14 , total integrated cost =  13163.155879356082
# RUN  15 , total integrated cost =  13163.155872392532
# RUN  16 , total integrated cost =  13163.155872225514
# RUN  17 , total integrated cost =  13163.155872220499
# RUN  18 , total integrated cost =  13163.155872220237
# RUN  19 , total integrated cost =  13163.15587222022
# RUN  20 , total integrated cost =  13163.155872220217
# Control only changes marginally.
# RUN  21 , total integrated cost =  13163.155872220217
# Improved over  21  iterations in  0.4315835680026794  seconds by  0.0003126700821809436  percent.
# cost splitting :  428.48451258742745 [0.         4.75068618]
# --------------------- 2
# set cost params:  1.0 0.0 2604.5337581217354
# interpolate adjoint :  True True True
# initial cost =  13166.338632783929
# RUN  0 , total integrated cost =  13166.338632783929
# Gradient descend method:  None
# RUN  1 , total integrated cost =  13166.338632783929
# Control only changes marginally.
# RUN  1 , total integrated cost =  13166.338632783929
# Improved over  1  iterations in  0.07721284999570344  seconds by  0.0  percent.
# cost splitting :  428.48451258742745 [0.         4.75068618]
# 20 172 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 2604.5337581217354
# interpolate adjoint :  True True True
# initial cost =  13114.342118309387
# RUN  0 , total integrated cost =  13114.342118309387
# Gradient descend method:  None
# RUN  1 , total integrated cost =  13114.144036741674
# RUN  2 , total integrated cost =  13114.083622292057
# RUN  3 , total integrated cost =  13113.997030409726
# RUN  4 , total integrated cost =  13113.96145218699
# RUN  5 , total integrated cost =  13113.891675423814
# RUN  6 , total integrated cost =  13113.887637761401
# RUN  7 , total integrated cost =  13113.88749368914
# RUN  8 , total integrated cost =  13113.887428672908
# RUN  9 , total integrated cost =  13113.887103244282
# RUN  10 , total integrated cost =  13113.879158870972
# RUN  11 , total integrated cost =  13113.87896607222
# RUN  12 , total integrated cost =  13113.878964198091
# RUN  13 , total integrated cost =  13113.878964187732
# RUN  14 , total integrated cost =  13113.878964187616
# RUN  15 , total integrated cost =  13113.878964187605
# RUN  16 , total integrated cost =  13113.878964187605
# Control only changes marginally.
# RUN  16 , total integrated cost =  13113.878964187605
# Improved over  16  iterations in  0.32116358701023273  seconds by  0.003531661120348417  percent.
# cost splitting :  409.81396158283576 [0.         4.74302872]
# --------------------- 1
# set cost params:  1.0 0.0 2612.675105068948
# interpolate adjoint :  True True True
# initial cost =  13152.49360661377
# RUN  0 , total integrated cost =  13152.49360661377
# Gradient descend method:  None
# RUN  1 , total integrated cost =  13152.490863503768
# RUN  2 , total integrated cost =  13152.490825028544
# RUN  3 , total integrated cost =  13152.490825027884
# RUN  4 , total integrated cost =  13152.49082502788
# RUN  5 , total integrated cost =  13152.490825027879
# RUN  6 , total integrated cost =  13152.490825027875
# RUN  7 , total integrated cost =  13152.490825027875
# Control only changes marginally.
# RUN  7 , total integrated cost =  13152.490825027875
# Improved over  7  iterations in  0.20191535000049043  seconds by  2.114873406355855e-05  percent.
# cost splitting :  410.546185026768 [0.         4.74250758]
# --------------------- 2
# set cost params:  1.0 0.0 2612.8078114148834
# interpolate adjoint :  True True True
# initial cost =  13153.120185879223
# RUN  0 , total integrated cost =  13153.120185879223
# Gradient descend method:  None
# RUN  1 , total integrated cost =  13153.120185879223
# Control only changes marginally.
# RUN  1 , total integrated cost =  13153.120185879223
# Improved over  1  iterations in  0.0873241740046069  seconds by  0.0  percent.
# cost splitting :  410.546185026768 [0.         4.74250758]
# 20 173 -----------------
# --------------------- 0
# set cost params:  1.0 0.0 2612.8078114148834
# interpolate adjoint :  True True True
# initial cost =  13102.373456505136
# RUN  0 , total integrated cost =  13102.373456505136
# Gradient descend method:  None
# RUN  1 , total integrated cost =  13102.165763188925
# RUN  2 , total integrated cost =  13102.068323984433
# RUN  3 , total integrated cost =  13101.924709617431
# RUN  4 , total integrated cost =  13101.866707931476
# RUN  5 , total integrated cost =  13101.713613839358
# RUN  6 , total integrated cost =  13101.693707605187
# RUN  7 , total integrated cost =  13101.688302442763
# RUN  8 , total integrated cost =  13101.672655441562
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_48903/2329827525.py in <module>
#      47             weights_[i][j] = cost.getParams()
#      48
# ---> 49             bestControl_[i][j], bestState_[i][j], cost_[i][j], runtime_, grad_, phi_, phi1_, costnode_[i][j] = aln.A1(
#      50                 control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
#      51                 startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
#
# ~/Promotion/neurolib/neurolib/models/model.py in A1(self, control_, target_state_, c_scheme_, u_mat_, u_scheme_, max_iteration_, tolerance_, startStep_, max_control_, min_control_, t_sim_, t_sim_pre_, t_sim_post_, CGVar, line_search_, control_variables_, prec_variables_, separate_comp, transition_time_, noise_real, init_params)
#     661             if self.params.N == 1:
#     662                 if noise_real == 0:
# --> 663                     return opti1_rate_control.A1(self, control_, target_state_, c_scheme_, u_mat_, u_scheme_, max_iteration_,
#     664                                                 tolerance_, startStep_, max_control_, min_control_, t_sim_, t_sim_pre_, t_sim_post_, CGVar,
#     665                                                 line_search_, control_variables_, prec_variables_, separate_comp, transition_time_)
#
# ~/Promotion/neurolib/neurolib/utils/A1_aln_rate_control.py in A1(model, control_, target_state, c_scheme_, u_mat_, u_scheme_, max_iteration_, tolerance_, startStep_, cntrl_max_, cntrl_min_, t_sim_, t_sim_pre_, t_sim_post_, CGVar, line_search_, control_variables_, prec_variables_, separate_comp, transition_time_)
#     258
#     259         for ind_time in range(T):
# --> 260             f_p_grad_t_ = cost.cost_precision_gradient_t(N, V_target, state0_[:,:2,ind_time], target_state_[:,:,ind_time], ip_, transition_time_)
#     261             for v in prec_variables:
#     262                 full_cost_grad[0,v,ind_time] = f_p_grad_t_[0,v]
#
# KeyboardInterrupt:

# %%
i = 20
for j in [0, 10, 100]:
    print("simulation duration = ", round(d_array[j],1))
    aln.params.duration = round(d_array[j],1)
    time_ = np.arange(-dur_pre,round(d_array[j]+dur_post+aln.params.dt,1),aln.params.dt)
    dur += dur_pre + dur_post
    target_e = [target[i][0]] * len(time_)
    target_i = [target[i][1]] * len(time_)

    fig, ax = plt.subplots(2,1, constrained_layout=True, figsize = (4,4) )
    ax[1].plot(time_, bestControl_[i][j][0,0,:], color = 'red')
    ax[0].plot(time_, bestState_[i][j][0,0,:], color= 'red')
    ax[1].plot(time_, bestControl_[i][j][0,1,:], color = 'blue')
    ax[0].plot(time_, bestState_[i][j][0,1,:], color= 'blue')
    ax[0].plot(time_, target_e, linestyle = '--', color='red')
    ax[0].plot(time_, target_i, linestyle = '--', color='blue')
    ax[0].set_xlim(-dur_pre,round(d_array[j]+dur_pre,1))
    ax[1].set_xlim(-dur_pre,round(d_array[j]+dur_pre,1))
    ax[0].axvspan(t0_array[j], t0_array[j]+20, alpha=0.2, color='gray')
    plt.show()
# Out:
# simulation duration =  20.0
# simulation duration =  21.0
# simulation duration =  30.0
