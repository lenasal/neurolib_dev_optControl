# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import sys
import pickle

path = os.getcwd().split(os.sep + 'GUI')[0]
if path not in sys.path:
    print("not here")
    sys.path.append(path)

from neurolib.models.aln import ALNModel
from neurolib.utils import plotFunctions as plotFunc
from neurolib.utils import costFunctions as cost
import neurolib.dashboard.functions as functions
import neurolib.dashboard.data as data
    
# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2 

#path = os.path.join(os.getcwd(), "plots")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
grid_data_file = os.path.join(os.getcwd().split('data')[0], 'bi.pickle')
print(grid_data_file)
with open(grid_data_file,'rb') as f:
    load_array= pickle.load(f)
exc = load_array[0]
inh = load_array[1]
print(len(exc))
case = '1'
# Out:
# /home/lena/Promotion/neurolib/GUI/current/gui/bi.pickle
# 147

# %%
aln = ALNModel()
N = aln.params.N

data.set_parameters(aln)

state_vars = aln.state_vars
init_vars = aln.init_vars

##############################################################
def setinit(init_vars_, model):
    state_vars = model.state_vars
    init_vars = model.init_vars
    for iv in range(len(init_vars)):
        for sv in range(len(state_vars)):
            if state_vars[sv] in init_vars[iv]:
                #print("set init vars ", )
                if model.params[init_vars[iv]].ndim == 2:
                    model.params[init_vars[iv]][0,:] = init_vars_[sv]
                else:
                    model.params[init_vars[iv]][0] = init_vars_[sv]
                    
##############################################################               
def setmaxmincontrol(max_c_c, min_c_c, max_c_r, min_c_r):
    import numpy as np
    
    max_cntrl = np.zeros(( 6 ))
    min_cntrl = np.zeros(( 6 ))
    
    max_cntrl[0] = max_c_c
    min_cntrl[0] = min_c_c
    max_cntrl[1] = max_c_c
    min_cntrl[1] = min_c_c
    max_cntrl[2] = max_c_r
    min_cntrl[2] = min_c_r
    max_cntrl[3] = max_c_r
    min_cntrl[3] = min_c_r
    max_cntrl[4] = max_c_r
    min_cntrl[4] = min_c_r
    max_cntrl[5] = max_c_r
    min_cntrl[5] = min_c_r
            
    return max_cntrl, min_cntrl

# %%
d_array = np.arange(500., 20, -0.1)
t0_array = d_array - 20.
t_pen = np.zeros(( t0_array.shape ))
for i in range(len(t_pen)):
    t_pen[i] = t0_array[i] / d_array[i]

# %%
bestControl_ = [None] * len(exc) 
bestState_ = [None] * len(exc) 
cost_ = [None] * len(exc) 
costnode_ = [None] * len(exc) 
weights_ = [None] * len(exc) 
convergence_ = [None] * len(exc) 

initVars = [None] * len(exc)
target = [None] * len(exc)
cost_uncontrolled = [None] * len(exc)
ws = [None] * len(exc)
conv = [None] * len(exc)
conv_shift = [None] * len(exc)

# %%
file_ = '1_I.pickle'
file_init = '1_I_init.pickle'
folder = str(os.getcwd().split('data_2')[1])
print(folder)
case = str(folder[1])
# Out:
# /1

# %%
dur_pre = 10
dur_post = 10

n_pre = int(np.around(dur_pre/aln.params.dt + 1.,1))
n_post = int(np.around(dur_post/aln.params.dt + 1.,1))

tol = 1e-12
start_step = 10.
c_scheme = np.zeros(( 1,1 ))
c_scheme[0,0] = 1.
u_mat = np.identity(1)
u_scheme = np.array([[1.]])

c_var = [1]
p_var = [0]

if case in ['1', '2']:    # low to high
    max_I = [3., -3.]
else:
    max_I = [-3., 3.]
    
if case in ['1', '3']:    # sparsity
    factor_ws = 1.
    factor_we = 0.
else:
    factor_ws = 0.
    factor_we = 1.
    
maxC = [5., -5., 0.18, 0.]
max_cntrl, min_cntrl = setmaxmincontrol(maxC[0], maxC[1], maxC[2], maxC[3])

# %%
if os.path.isfile(file_) :
    print("file found")
    
    with open(file_,'rb') as f:
        load_array = pickle.load(f)

for i in range(len(exc)):
    bestControl_[i] = load_array[0][i][0]
    bestState_[i] = load_array[1][i][0]
    cost_[i] = load_array[2][i][0]
    costnode_[i] = load_array[3][i][0]
    weights_[i] = load_array[4][i][0]
# Out:
# file found

# %%
if os.path.isfile(file_) :
    print("file found")
    
    with open(file_,'rb') as f:
        load_array = pickle.load(f)

    bestControl_ = load_array[0]
    bestState_ = load_array[1]
    cost_ = load_array[2]
    costnode_ = load_array[3]
    weights_ = load_array[4]
# Out:
# file found
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# /tmp/ipykernel_4036/4059814665.py in <module>
#       3
#       4     with open(file_,'rb') as f:
# ----> 5         load_array = pickle.load(f)
#       6
#       7     bestControl_ = load_array[0]
#
# EOFError: Ran out of input

# %%
# get initial parameters and target states

#i_range = range(83)
i_range = [20]

data.set_parameters(aln)

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    aln.params.duration = 3000.
    
    control0 = aln.getZeroControl()
    control0 = functions.step_control(aln, maxI_ = max_I[0])

    aln.run(control=control0)
    
    target_rates = np.zeros((2))
    target_rates[0] = aln.rates_exc[0,-1] 
    target_rates[1] = aln.rates_inh[0,-1]

    control0 = functions.step_control(aln, maxI_ = max_I[1])
    aln.run(control=control0)

    init_state_vars = np.zeros(( len(state_vars) ))
    for j in range(len(state_vars)):
        if aln.state[state_vars[j]].size == 1:
            init_state_vars[j] = aln.state[state_vars[j]][0]
        else:
            init_state_vars[j] = aln.state[state_vars[j]][0,-1]

    initVars[i] = init_state_vars
    target[i] = [target_rates[0], target_rates[1]]
# Out:
# -------  20 0.4500000000000001 0.4750000000000002

# %%
# get uncontrolled cost

data.set_parameters(aln)

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    dur = d_array[0]
    aln.params.duration = dur
    
    target_ = aln.getZeroTarget()
    target_[:,0,:] = target[i][0]
    target_[:,1,:] = target[i][1]
            
    cost.setParams(1.0, 0.0, 0.0)

    setinit(initVars[i], aln)
    control0 = aln.getZeroControl()

    # "HS", "FR", "PR", "HZ"
    cgv = None
    max_it = 0

    bestControl_init_, bestState_init_, cost_init_, runtime_init_, grad_init_, phi_init_, phi1_, costnode_init_ = aln.A1(
        control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
        prec_variables_ = p_var, transition_time_ = t_pen[0])
    
    cost_uncontrolled[i] = cost_init_[0]
# Out:
# -------  0 0.4000000000000001 0.3500000000000001
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  146855.39702821904
# RUN  0 , total integrated cost =  146855.39702821904
# Gradient descend method:  None
# RUN  0 , total integrated cost =  146855.39702821904
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  1 0.4250000000000001 0.3500000000000001
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  244234.70503349282
# RUN  0 , total integrated cost =  244234.70503349282
# Gradient descend method:  None
# RUN  0 , total integrated cost =  244234.70503349282
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  2 0.4000000000000001 0.3750000000000001
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  137806.3558139294
# RUN  0 , total integrated cost =  137806.3558139294
# Gradient descend method:  None
# RUN  0 , total integrated cost =  137806.3558139294
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  3 0.4250000000000001 0.3750000000000001
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  241480.3484875782
# RUN  0 , total integrated cost =  241480.3484875782
# Gradient descend method:  None
# RUN  0 , total integrated cost =  241480.3484875782
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  4 0.4500000000000001 0.3750000000000001
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  338432.51439444604
# RUN  0 , total integrated cost =  338432.51439444604
# Gradient descend method:  None
# RUN  0 , total integrated cost =  338432.51439444604
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  5 0.4000000000000001 0.40000000000000013
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  126823.61408372025
# RUN  0 , total integrated cost =  126823.61408372025
# Gradient descend method:  None
# RUN  0 , total integrated cost =  126823.61408372025
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  6 0.4250000000000001 0.40000000000000013
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  234849.86448361105
# RUN  0 , total integrated cost =  234849.86448361105
# Gradient descend method:  None
# RUN  0 , total integrated cost =  234849.86448361105
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  7 0.4500000000000001 0.40000000000000013
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  337311.3569640121
# RUN  0 , total integrated cost =  337311.3569640121
# Gradient descend method:  None
# RUN  0 , total integrated cost =  337311.3569640121
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  8 0.47500000000000014 0.40000000000000013
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  436683.03613383934
# RUN  0 , total integrated cost =  436683.03613383934
# Gradient descend method:  None
# RUN  0 , total integrated cost =  436683.03613383934
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  9 0.4000000000000001 0.42500000000000016
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  115502.5972235114
# RUN  0 , total integrated cost =  115502.5972235114
# Gradient descend method:  None
# RUN  0 , total integrated cost =  115502.5972235114
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  10 0.4250000000000001 0.42500000000000016
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  226698.47715197233
# RUN  0 , total integrated cost =  226698.47715197233
# Gradient descend method:  None
# RUN  0 , total integrated cost =  226698.47715197233
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  11 0.4500000000000001 0.42500000000000016
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  331196.46910670475
# RUN  0 , total integrated cost =  331196.46910670475
# Gradient descend method:  None
# RUN  0 , total integrated cost =  331196.46910670475
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  12 0.47500000000000014 0.42500000000000016
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  437181.9504061447
# RUN  0 , total integrated cost =  437181.9504061447
# Gradient descend method:  None
# RUN  0 , total integrated cost =  437181.9504061447
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  13 0.4000000000000001 0.4500000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  103932.40255255786
# RUN  0 , total integrated cost =  103932.40255255786
# Gradient descend method:  None
# RUN  0 , total integrated cost =  103932.40255255786
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  14 0.4250000000000001 0.4500000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  218854.09939826332
# RUN  0 , total integrated cost =  218854.09939826332
# Gradient descend method:  None
# RUN  0 , total integrated cost =  218854.09939826332
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  15 0.4500000000000001 0.4500000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  323897.4690366888
# RUN  0 , total integrated cost =  323897.4690366888
# Gradient descend method:  None
# RUN  0 , total integrated cost =  323897.4690366888
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  16 0.47500000000000014 0.4500000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  431451.8938983858
# RUN  0 , total integrated cost =  431451.8938983858
# Gradient descend method:  None
# RUN  0 , total integrated cost =  431451.8938983858
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  17 0.5000000000000002 0.4500000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  541570.0682516823
# RUN  0 , total integrated cost =  541570.0682516823
# Gradient descend method:  None
# RUN  0 , total integrated cost =  541570.0682516823
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  18 0.4000000000000001 0.4750000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  91340.63373509991
# RUN  0 , total integrated cost =  91340.63373509991
# Gradient descend method:  None
# RUN  0 , total integrated cost =  91340.63373509991
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  19 0.4250000000000001 0.4750000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  211572.5759679924
# RUN  0 , total integrated cost =  211572.5759679924
# Gradient descend method:  None
# RUN  0 , total integrated cost =  211572.5759679924
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  20 0.4500000000000001 0.4750000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  316931.9421284
# RUN  0 , total integrated cost =  316931.9421284
# Gradient descend method:  None
# RUN  0 , total integrated cost =  316931.9421284
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  21 0.47500000000000014 0.4750000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  424684.0949542926
# RUN  0 , total integrated cost =  424684.0949542926
# Gradient descend method:  None
# RUN  0 , total integrated cost =  424684.0949542926
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  22 0.5000000000000002 0.4750000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  536554.4931300428
# RUN  0 , total integrated cost =  536554.4931300428
# Gradient descend method:  None
# RUN  0 , total integrated cost =  536554.4931300428
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  23 0.5250000000000001 0.4750000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  649680.5756879131
# RUN  0 , total integrated cost =  649680.5756879131
# Gradient descend method:  None
# RUN  0 , total integrated cost =  649680.5756879131
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  24 0.4000000000000001 0.5000000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  74168.6027044929
# RUN  0 , total integrated cost =  74168.6027044929
# Gradient descend method:  None
# RUN  0 , total integrated cost =  74168.6027044929
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  25 0.4250000000000001 0.5000000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  204814.76624161197
# RUN  0 , total integrated cost =  204814.76624161197
# Gradient descend method:  None
# RUN  0 , total integrated cost =  204814.76624161197
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  26 0.4500000000000001 0.5000000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  310502.0037410387
# RUN  0 , total integrated cost =  310502.0037410387
# Gradient descend method:  None
# RUN  0 , total integrated cost =  310502.0037410387
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  27 0.47500000000000014 0.5000000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  418236.1198402083
# RUN  0 , total integrated cost =  418236.1198402083
# Gradient descend method:  None
# RUN  0 , total integrated cost =  418236.1198402083
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  28 0.5000000000000002 0.5000000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  530282.4726497299
# RUN  0 , total integrated cost =  530282.4726497299
# Gradient descend method:  None
# RUN  0 , total integrated cost =  530282.4726497299
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  29 0.5250000000000001 0.5000000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  646521.6732350034
# RUN  0 , total integrated cost =  646521.6732350034
# Gradient descend method:  None
# RUN  0 , total integrated cost =  646521.6732350034
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  30 0.4250000000000001 0.5250000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  198505.2946572739
# RUN  0 , total integrated cost =  198505.2946572739
# Gradient descend method:  None
# RUN  0 , total integrated cost =  198505.2946572739
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  31 0.4500000000000001 0.5250000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  304530.5505769217
# RUN  0 , total integrated cost =  304530.5505769217
# Gradient descend method:  None
# RUN  0 , total integrated cost =  304530.5505769217
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  32 0.47500000000000014 0.5250000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  412227.1647591634
# RUN  0 , total integrated cost =  412227.1647591634
# Gradient descend method:  None
# RUN  0 , total integrated cost =  412227.1647591634
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  33 0.5000000000000002 0.5250000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  524212.5915485861
# RUN  0 , total integrated cost =  524212.5915485861
# Gradient descend method:  None
# RUN  0 , total integrated cost =  524212.5915485861
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  34 0.5250000000000001 0.5250000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  640916.4738461657
# RUN  0 , total integrated cost =  640916.4738461657
# Gradient descend method:  None
# RUN  0 , total integrated cost =  640916.4738461657
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  35 0.5500000000000003 0.5250000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  760013.3898018681
# RUN  0 , total integrated cost =  760013.3898018681
# Gradient descend method:  None
# RUN  0 , total integrated cost =  760013.3898018681
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  36 0.4250000000000001 0.5500000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  192617.3150952127
# RUN  0 , total integrated cost =  192617.3150952127
# Gradient descend method:  None
# RUN  0 , total integrated cost =  192617.3150952127
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  37 0.4500000000000001 0.5500000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  299002.14935773576
# RUN  0 , total integrated cost =  299002.14935773576
# Gradient descend method:  None
# RUN  0 , total integrated cost =  299002.14935773576
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  38 0.47500000000000014 0.5500000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  406664.10745913326
# RUN  0 , total integrated cost =  406664.10745913326
# Gradient descend method:  None
# RUN  0 , total integrated cost =  406664.10745913326
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  39 0.5000000000000002 0.5500000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  518533.1123942334
# RUN  0 , total integrated cost =  518533.1123942334
# Gradient descend method:  None
# RUN  0 , total integrated cost =  518533.1123942334
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  40 0.5250000000000001 0.5500000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  635238.4079859259
# RUN  0 , total integrated cost =  635238.4079859259
# Gradient descend method:  None
# RUN  0 , total integrated cost =  635238.4079859259
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  41 0.5500000000000003 0.5500000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  756194.7962365937
# RUN  0 , total integrated cost =  756194.7962365937
# Gradient descend method:  None
# RUN  0 , total integrated cost =  756194.7962365937
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  42 0.4250000000000001 0.5750000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  187081.7746701702
# RUN  0 , total integrated cost =  187081.7746701702
# Gradient descend method:  None
# RUN  0 , total integrated cost =  187081.7746701702
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  43 0.4500000000000001 0.5750000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  293856.7484005505
# RUN  0 , total integrated cost =  293856.7484005505
# Gradient descend method:  None
# RUN  0 , total integrated cost =  293856.7484005505
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  44 0.47500000000000014 0.5750000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  401498.6789492869
# RUN  0 , total integrated cost =  401498.6789492869
# Gradient descend method:  None
# RUN  0 , total integrated cost =  401498.6789492869
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  45 0.5000000000000002 0.5750000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  513234.6635746044
# RUN  0 , total integrated cost =  513234.6635746044
# Gradient descend method:  None
# RUN  0 , total integrated cost =  513234.6635746044
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  46 0.5250000000000001 0.5750000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  629845.1306750294
# RUN  0 , total integrated cost =  629845.1306750294
# Gradient descend method:  None
# RUN  0 , total integrated cost =  629845.1306750294
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  47 0.5500000000000003 0.5750000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  751175.9333805718
# RUN  0 , total integrated cost =  751175.9333805718
# Gradient descend method:  None
# RUN  0 , total integrated cost =  751175.9333805718
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  48 0.4250000000000001 0.6000000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  181882.521994222
# RUN  0 , total integrated cost =  181882.521994222
# Gradient descend method:  None
# RUN  0 , total integrated cost =  181882.521994222
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  49 0.4500000000000001 0.6000000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  289049.15272407274
# RUN  0 , total integrated cost =  289049.15272407274
# Gradient descend method:  None
# RUN  0 , total integrated cost =  289049.15272407274
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  50 0.47500000000000014 0.6000000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  396670.24943190784
# RUN  0 , total integrated cost =  396670.24943190784
# Gradient descend method:  None
# RUN  0 , total integrated cost =  396670.24943190784
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  51 0.5000000000000002 0.6000000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  508302.3902818461
# RUN  0 , total integrated cost =  508302.3902818461
# Gradient descend method:  None
# RUN  0 , total integrated cost =  508302.3902818461
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  52 0.5250000000000001 0.6000000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  624775.8829897492
# RUN  0 , total integrated cost =  624775.8829897492
# Gradient descend method:  None
# RUN  0 , total integrated cost =  624775.8829897492
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  53 0.5500000000000003 0.6000000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  746144.5805987157
# RUN  0 , total integrated cost =  746144.5805987157
# Gradient descend method:  None
# RUN  0 , total integrated cost =  746144.5805987157
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  54 0.5750000000000002 0.6000000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  870523.2701234882
# RUN  0 , total integrated cost =  870523.2701234882
# Gradient descend method:  None
# RUN  0 , total integrated cost =  870523.2701234882
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  55 0.4250000000000001 0.6250000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  176973.53086129532
# RUN  0 , total integrated cost =  176973.53086129532
# Gradient descend method:  None
# RUN  0 , total integrated cost =  176973.53086129532
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  56 0.4500000000000001 0.6250000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  284563.6049902908
# RUN  0 , total integrated cost =  284563.6049902908
# Gradient descend method:  None
# RUN  0 , total integrated cost =  284563.6049902908
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  57 0.47500000000000014 0.6250000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  392168.01147703634
# RUN  0 , total integrated cost =  392168.01147703634
# Gradient descend method:  None
# RUN  0 , total integrated cost =  392168.01147703634
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  58 0.5000000000000002 0.6250000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  503700.90762437455
# RUN  0 , total integrated cost =  503700.90762437455
# Gradient descend method:  None
# RUN  0 , total integrated cost =  503700.90762437455
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  59 0.5250000000000001 0.6250000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  620034.5060788749
# RUN  0 , total integrated cost =  620034.5060788749
# Gradient descend method:  None
# RUN  0 , total integrated cost =  620034.5060788749
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  60 0.5500000000000003 0.6250000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  741333.3077944894
# RUN  0 , total integrated cost =  741333.3077944894
# Gradient descend method:  None
# RUN  0 , total integrated cost =  741333.3077944894
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  61 0.5750000000000002 0.6250000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  866710.8536802017
# RUN  0 , total integrated cost =  866710.8536802017
# Gradient descend method:  None
# RUN  0 , total integrated cost =  866710.8536802017
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  62 0.4250000000000001 0.6500000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  172327.22420179544
# RUN  0 , total integrated cost =  172327.22420179544
# Gradient descend method:  None
# RUN  0 , total integrated cost =  172327.22420179544
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  63 0.4500000000000001 0.6500000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  280358.4423685195
# RUN  0 , total integrated cost =  280358.4423685195
# Gradient descend method:  None
# RUN  0 , total integrated cost =  280358.4423685195
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  64 0.47500000000000014 0.6500000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  387959.78150038864
# RUN  0 , total integrated cost =  387959.78150038864
# Gradient descend method:  None
# RUN  0 , total integrated cost =  387959.78150038864
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  65 0.5000000000000002 0.6500000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  499381.32678329153
# RUN  0 , total integrated cost =  499381.32678329153
# Gradient descend method:  None
# RUN  0 , total integrated cost =  499381.32678329153
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  66 0.5250000000000001 0.6500000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  615596.4660225171
# RUN  0 , total integrated cost =  615596.4660225171
# Gradient descend method:  None
# RUN  0 , total integrated cost =  615596.4660225171
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  67 0.5500000000000003 0.6500000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  736788.193418642
# RUN  0 , total integrated cost =  736788.193418642
# Gradient descend method:  None
# RUN  0 , total integrated cost =  736788.193418642
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  68 0.5750000000000002 0.6500000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  862467.9253654084
# RUN  0 , total integrated cost =  862467.9253654084
# Gradient descend method:  None
# RUN  0 , total integrated cost =  862467.9253654084
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  69 0.4250000000000001 0.6750000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  167933.86239870195
# RUN  0 , total integrated cost =  167933.86239870195
# Gradient descend method:  None
# RUN  0 , total integrated cost =  167933.86239870195
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  70 0.4500000000000001 0.6750000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  276399.77278526267
# RUN  0 , total integrated cost =  276399.77278526267
# Gradient descend method:  None
# RUN  0 , total integrated cost =  276399.77278526267
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  71 0.47500000000000014 0.6750000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  384005.59692905797
# RUN  0 , total integrated cost =  384005.59692905797
# Gradient descend method:  None
# RUN  0 , total integrated cost =  384005.59692905797
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  72 0.5000000000000002 0.6750000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  495331.1329655588
# RUN  0 , total integrated cost =  495331.1329655588
# Gradient descend method:  None
# RUN  0 , total integrated cost =  495331.1329655588
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  73 0.5250000000000001 0.6750000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  611432.0686370909
# RUN  0 , total integrated cost =  611432.0686370909
# Gradient descend method:  None
# RUN  0 , total integrated cost =  611432.0686370909
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  74 0.5500000000000003 0.6750000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  732509.8149166821
# RUN  0 , total integrated cost =  732509.8149166821
# Gradient descend method:  None
# RUN  0 , total integrated cost =  732509.8149166821
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  75 0.5750000000000002 0.6750000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  858276.8196420075
# RUN  0 , total integrated cost =  858276.8196420075
# Gradient descend method:  None
# RUN  0 , total integrated cost =  858276.8196420075
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  76 0.4250000000000001 0.7000000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  163736.8297408659
# RUN  0 , total integrated cost =  163736.8297408659
# Gradient descend method:  None
# RUN  0 , total integrated cost =  163736.8297408659
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  77 0.4500000000000001 0.7000000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  272681.6442786969
# RUN  0 , total integrated cost =  272681.6442786969
# Gradient descend method:  None
# RUN  0 , total integrated cost =  272681.6442786969
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  78 0.47500000000000014 0.7000000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  380284.89211629244
# RUN  0 , total integrated cost =  380284.89211629244
# Gradient descend method:  None
# RUN  0 , total integrated cost =  380284.89211629244
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  79 0.5000000000000002 0.7000000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  491528.53199543635
# RUN  0 , total integrated cost =  491528.53199543635
# Gradient descend method:  None
# RUN  0 , total integrated cost =  491528.53199543635
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  80 0.5250000000000001 0.7000000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  607506.209585381
# RUN  0 , total integrated cost =  607506.209585381
# Gradient descend method:  None
# RUN  0 , total integrated cost =  607506.209585381
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  81 0.5500000000000003 0.7000000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  728478.2773809158
# RUN  0 , total integrated cost =  728478.2773809158
# Gradient descend method:  None
# RUN  0 , total integrated cost =  728478.2773809158
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  82 0.5750000000000002 0.7000000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  854238.9955664313
# RUN  0 , total integrated cost =  854238.9955664313
# Gradient descend method:  None
# RUN  0 , total integrated cost =  854238.9955664313
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.

# %%
cgv = None
j = 0

wp = 1.

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
        
    found_exponent = False
    found_digit_0 = False
    found_digit_1 = False
    exponent = 5
    sig_digit = [1., 0.]
    
    while not found_digit_1:
        
        ws[i] = sig_digit[0] * 10**exponent + sig_digit[1] * 10**(exponent-1.)
    
        dur = d_array[0]
        aln.params.duration = dur
        setinit(initVars[i], aln)

        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        control0 = aln.getZeroControl()
        cost.setParams(wp, 0., ws[i])
        max_it = int(10)
        if found_digit_0:
            max_it = 100

        bestControl_[i], bestState_[i], cost_[i], runtime_, grad_, phi_, phi1_, costnode_[i] = aln.A1(
            control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
            prec_variables_ = p_var, transition_time_ = t_pen[0])
        
        if found_exponent == False and cost_[i][-1] == 0.:
            exponent -= 1
            continue
        elif found_exponent == False and found_digit_0 == False:
            found_exponent = True
            sig_digit[0] = 9.
        elif found_exponent == True and found_digit_0 == False and cost_[i][-1] == 0.:
            sig_digit[0] -= 1.
        elif found_exponent == True and found_digit_0 == False:
            found_digit_0 = True
            sig_digit[1] = 9.
        elif found_exponent == True and found_digit_0 == True and found_digit_1 == False and cost_[i][-1] == 0.:
            sig_digit[1] -= 1.
        elif found_exponent == True and found_digit_0 == True and found_digit_1 == False:
            print("sparsity weight = ", ws[i])
            
            if True:
                plot_time_array = np.arange(0.,round(dur+aln.params.dt,1),aln.params.dt)
                target_ = aln.getZeroTarget()
                target_[:,0,:] = target[i][0]
                target_[:,1,:] = target[i][1]

                fig, ax = plt.subplots(3,1, constrained_layout=True, figsize = (4,8) )
                ax[1].plot(plot_time_array, bestControl_[i][0,0,n_pre-1:-n_post+1], color = 'red')
                ax[0].plot(plot_time_array, bestState_[i][0,0,n_pre-1:-n_post+1], color= 'red')
                ax[1].plot(plot_time_array, bestControl_[i][0,1,n_pre-1:-n_post+1], color = 'blue')
                ax[0].plot(plot_time_array, bestState_[i][0,1,n_pre-1:-n_post+1], color= 'blue')
                ax[0].plot(plot_time_array, target_[0,0,n_pre-1:-n_post+1], linestyle = '--', color='red')
                ax[0].plot(plot_time_array, target_[0,1,n_pre-1:-n_post+1], linestyle = '--', color='blue')


                ax[2].plot(plot_time_array, phi_[0,0,:], color = 'red')
                ax[2].plot(plot_time_array, phi_[0,1,:], color = 'blue')
                for k in range(3):
                    ax[k].set_xlim(0.,dur)
                    ax[k].axvspan(dur*t_pen[0], dur, alpha=0.2, color='gray')
                plt.show()

            break            

        print('uncontrolled cost : ', cost_uncontrolled[i])
        print('cost splitting : ', costnode_[i][0][0][0], costnode_[i][2][0][:2])
# Out:
# -------  70 0.4500000000000001 0.6750000000000004
# set cost params:  1.0 0.0 100000.0
# interpolate adjoint :  True True True
# initial cost =  276399.77278526267
# RUN  0 , total integrated cost =  276399.77278526267
# Gradient descend method:  None
# RUN  1 , total integrated cost =  276399.77278526267
# Control only changes marginally.
# RUN  1 , total integrated cost =  276399.77278526267
# Improved over  1  iterations in  0.2884127659999649  seconds by  0.0  percent.
# set cost params:  1.0 0.0 10000.0
# interpolate adjoint :  True True True
# initial cost =  276399.77278526267
# RUN  0 , total integrated cost =  276399.77278526267
# Gradient descend method:  None
# RUN  1 , total integrated cost =  276399.77278526267
# Control only changes marginally.
# RUN  1 , total integrated cost =  276399.77278526267
# Improved over  1  iterations in  0.30321165600071254  seconds by  0.0  percent.
# set cost params:  1.0 0.0 1000.0
# interpolate adjoint :  True True True
# initial cost =  276399.77278526267
# RUN  0 , total integrated cost =  276399.77278526267
# Gradient descend method:  None
# RUN  1 , total integrated cost =  276399.77278526267
# Control only changes marginally.
# RUN  1 , total integrated cost =  276399.77278526267
# Improved over  1  iterations in  0.37799939199976507  seconds by  0.0  percent.
# set cost params:  1.0 0.0 100.0
# interpolate adjoint :  True True True
# initial cost =  276399.77278526267
# RUN  0 , total integrated cost =  276399.77278526267
# Gradient descend method:  None
# RUN  1 , total integrated cost =  276399.77278526267
# Control only changes marginally.
# RUN  1 , total integrated cost =  276399.77278526267
# Improved over  1  iterations in  0.33903129900045315  seconds by  0.0  percent.
# set cost params:  1.0 0.0 10.0
# interpolate adjoint :  True True True
# initial cost =  276399.77278526267
# RUN  0 , total integrated cost =  276399.77278526267
# Gradient descend method:  None
# RUN  1 , total integrated cost =  276399.77278526267
# Control only changes marginally.
# RUN  1 , total integrated cost =  276399.77278526267
# Improved over  1  iterations in  0.3340132459998131  seconds by  0.0  percent.
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  276399.77278526267
# RUN  0 , total integrated cost =  276399.77278526267
# Gradient descend method:  None
# RUN  1 , total integrated cost =  276399.77278526267
# Control only changes marginally.
# RUN  1 , total integrated cost =  276399.77278526267
# Improved over  1  iterations in  0.3683108280001761  seconds by  0.0  percent.
# set cost params:  1.0 0.0 0.1
# interpolate adjoint :  True True True
# initial cost =  276399.77278526267
# RUN  0 , total integrated cost =  276399.77278526267
# Gradient descend method:  None
# RUN  1 , total integrated cost =  276399.77278526267
# Control only changes marginally.
# RUN  1 , total integrated cost =  276399.77278526267
# Improved over  1  iterations in  0.3441142130004664  seconds by  0.0  percent.
# set cost params:  1.0 0.0 0.01
# interpolate adjoint :  True True True
# initial cost =  276399.77278526267
# RUN  0 , total integrated cost =  276399.77278526267
# Gradient descend method:  None
# RUN  1 , total integrated cost =  276399.77278526267
# Control only changes marginally.
# RUN  1 , total integrated cost =  276399.77278526267
# Improved over  1  iterations in  0.42163919399990846  seconds by  0.0  percent.
# set cost params:  1.0 0.0 0.001
# interpolate adjoint :  True True True
# initial cost =  276399.77278526267
# RUN  0 , total integrated cost =  276399.77278526267
# Gradient descend method:  None
# RUN  1 , total integrated cost =  276399.77278526267
# Control only changes marginally.
# RUN  1 , total integrated cost =  276399.77278526267
# Improved over  1  iterations in  0.3211473870005648  seconds by  0.0  percent.
# set cost params:  1.0 0.0 0.0001
# interpolate adjoint :  True True True
# initial cost =  276399.77278526267
# RUN  0 , total integrated cost =  276399.77278526267
# Gradient descend method:  None
# RUN  1 , total integrated cost =  276399.7727852617
# RUN  2 , total integrated cost =  276399.7727852617
# Control only changes marginally.
# RUN  2 , total integrated cost =  276399.7727852617
# Improved over  2  iterations in  0.4104714659997626  seconds by  3.552713678800501e-13  percent.
# set cost params:  1.0 0.0 1e-05
# interpolate adjoint :  True True True
# initial cost =  276399.77278526267
# RUN  0 , total integrated cost =  276399.77278526267
# Gradient descend method:  None
# RUN  1 , total integrated cost =  101220.44924072397
# RUN  2 , total integrated cost =  76675.60464647529
# RUN  3 , total integrated cost =  14.447468576490555
# RUN  4 , total integrated cost =  14.447468576490555
# RUN  5 , total integrated cost =  nan
# RUN  6 , total integrated cost =  nan
# RUN  7 , total integrated cost =  nan
# RUN  8 , total integrated cost =  nan
# RUN  9 , total integrated cost =  nan
# RUN  10 , total integrated cost =  nan
# RUN  10 , total integrated cost =  nan
# Improved over  10  iterations in  3.727122722999411  seconds by  nan  percent.
# uncontrolled cost :  276399.77278526267
# cost splitting :  92950.30414676908 [ 0. nan]
# set cost params:  1.0 0.0 9e-05
# interpolate adjoint :  True True True
# initial cost =  276399.77278526267
# RUN  0 , total integrated cost =  276399.77278526267
# Gradient descend method:  None
# RUN  1 , total integrated cost =  276399.77278526145
# RUN  2 , total integrated cost =  276399.7727852612
# RUN  3 , total integrated cost =  276399.7727852612
# Control only changes marginally.
# RUN  3 , total integrated cost =  276399.7727852612
# Improved over  3  iterations in  0.5035401129998718  seconds by  5.258016244624741e-13  percent.
# uncontrolled cost :  276399.77278526267
# cost splitting :  11109.049056156107 [0.00000000e+00 4.47574132e-05]
# set cost params:  1.0 0.0 8e-05
# interpolate adjoint :  True True True
# initial cost =  276399.77278526267
# RUN  0 , total integrated cost =  276399.77278526267
# Gradient descend method:  None
# RUN  1 , total integrated cost =  101220.4500070696
# RUN  2 , total integrated cost =  76675.6114448116
# RUN  3 , total integrated cost =  14.455125001618795
# RUN  4 , total integrated cost =  14.455125001618795
# RUN  5 , total integrated cost =  nan
# RUN  6 , total integrated cost =  nan
# RUN  7 , total integrated cost =  nan
# RUN  8 , total integrated cost =  nan
# RUN  9 , total integrated cost =  nan
# RUN  10 , total integrated cost =  nan
# RUN  10 , total integrated cost =  nan
# Improved over  10  iterations in  3.2049296109998977  seconds by  nan  percent.
# uncontrolled cost :  276399.77278526267
# cost splitting :  92950.30414676908 [ 0. nan]
# set cost params:  1.0 0.0 8.900000000000001e-05
# interpolate adjoint :  True True True
# initial cost =  276399.77278526267
# RUN  0 , total integrated cost =  276399.77278526267
# Gradient descend method:  None
# RUN  1 , total integrated cost =  276399.7727852614
# RUN  2 , total integrated cost =  276399.77278526116
# RUN  3 , total integrated cost =  276399.77278526116
# Control only changes marginally.
# RUN  3 , total integrated cost =  276399.77278526116
# Improved over  3  iterations in  0.5347858690001885  seconds by  5.400124791776761e-13  percent.
# uncontrolled cost :  276399.77278526267
# cost splitting :  11109.04905615611 [0.00000000e+00 4.39037345e-05]
# set cost params:  1.0 0.0 8.800000000000001e-05
# interpolate adjoint :  True True True
# initial cost =  276399.77278526267
# RUN  0 , total integrated cost =  276399.77278526267
# Gradient descend method:  None
# RUN  1 , total integrated cost =  276399.77278526133
# RUN  2 , total integrated cost =  276399.7727852611
# RUN  3 , total integrated cost =  276399.7727852611
# Control only changes marginally.
# RUN  3 , total integrated cost =  276399.7727852611
# Improved over  3  iterations in  0.5633564859999751  seconds by  5.684341886080801e-13  percent.
# uncontrolled cost :  276399.77278526267
# cost splitting :  11109.04905615611 [0.00000000e+00 4.39069895e-05]
# set cost params:  1.0 0.0 8.7e-05
# interpolate adjoint :  True True True
# initial cost =  276399.77278526267
# RUN  0 , total integrated cost =  276399.77278526267
# Gradient descend method:  None
# RUN  1 , total integrated cost =  276399.7727852613
# RUN  2 , total integrated cost =  276399.7727852611
# RUN  3 , total integrated cost =  276399.77278526104
# RUN  4 , total integrated cost =  276399.77278526104
# Control only changes marginally.
# RUN  4 , total integrated cost =  276399.77278526104
# Improved over  4  iterations in  0.594933826999295  seconds by  5.826450433232822e-13  percent.
# uncontrolled cost :  276399.77278526267
# cost splitting :  11109.049056156111 [0.00000000e+00 4.37259852e-05]
# set cost params:  1.0 0.0 8.6e-05
# interpolate adjoint :  True True True
# initial cost =  276399.77278526267
# RUN  0 , total integrated cost =  276399.77278526267
# Gradient descend method:  None
# RUN  1 , total integrated cost =  276399.7727852612
# RUN  2 , total integrated cost =  276399.77278526104
# RUN  3 , total integrated cost =  276399.77278526104
# Control only changes marginally.
# RUN  3 , total integrated cost =  276399.77278526104
# Improved over  3  iterations in  0.5041306690000056  seconds by  5.826450433232822e-13  percent.
# uncontrolled cost :  276399.77278526267
# cost splitting :  11109.04905615611 [0.00000000e+00 4.38903871e-05]
# set cost params:  1.0 0.0 8.5e-05
# interpolate adjoint :  True True True
# initial cost =  276399.77278526267
# RUN  0 , total integrated cost =  276399.77278526267
# Gradient descend method:  None
# RUN  1 , total integrated cost =  276399.7727852612
# RUN  2 , total integrated cost =  276399.77278526104
# RUN  3 , total integrated cost =  276399.772785261
# RUN  4 , total integrated cost =  276399.772785261
# Control only changes marginally.
# RUN  4 , total integrated cost =  276399.772785261
# Improved over  4  iterations in  0.7212077479998698  seconds by  6.110667527536862e-13  percent.
# uncontrolled cost :  276399.77278526267
# cost splitting :  11109.049056156107 [0.00000000e+00 4.46797624e-05]
# set cost params:  1.0 0.0 8.400000000000001e-05
# interpolate adjoint :  True True True
# initial cost =  276399.77278526267
# RUN  0 , total integrated cost =  276399.77278526267
# Gradient descend method:  None
# RUN  1 , total integrated cost =  276399.77278526226
# RUN  2 , total integrated cost =  276399.77278526215
# RUN  3 , total integrated cost =  276399.77278526215
# Control only changes marginally.
# RUN  3 , total integrated cost =  276399.77278526215
# Improved over  3  iterations in  0.5269010539996088  seconds by  1.8474111129762605e-13  percent.
# uncontrolled cost :  276399.77278526267
# cost splitting :  11109.049056155056 [0.         0.00037073]
# set cost params:  1.0 0.0 8.300000000000001e-05
# interpolate adjoint :  True True True
# initial cost =  276399.77278526267
# RUN  0 , total integrated cost =  276399.77278526267
# Gradient descend method:  None
# RUN  1 , total integrated cost =  276399.7727852619
# RUN  2 , total integrated cost =  276399.77278526186
# RUN  3 , total integrated cost =  276399.77278526186
# Control only changes marginally.
# RUN  3 , total integrated cost =  276399.77278526186
# Improved over  3  iterations in  0.5124866340001972  seconds by  2.984279490192421e-13  percent.
# uncontrolled cost :  276399.77278526267
# cost splitting :  11109.049056154901 [0.         0.00041829]
# set cost params:  1.0 0.0 8.2e-05
# interpolate adjoint :  True True True
# initial cost =  276399.77278526267
# RUN  0 , total integrated cost =  276399.77278526267
# Gradient descend method:  None
# RUN  1 , total integrated cost =  101220.45002896518
# RUN  2 , total integrated cost =  76675.61163904978
# RUN  3 , total integrated cost =  4.0475838882165585
# RUN  4 , total integrated cost =  4.0475838882165585
# RUN  5 , total integrated cost =  nan
# RUN  6 , total integrated cost =  nan
# RUN  7 , total integrated cost =  nan
# RUN  8 , total integrated cost =  nan
# RUN  9 , total integrated cost =  nan
# RUN  10 , total integrated cost =  nan
# RUN  11 , total integrated cost =  nan
# RUN  12 , total integrated cost =  nan
# RUN  13 , total integrated cost =  nan
# RUN  14 , total integrated cost =  nan
# RUN  15 , total integrated cost =  nan
# RUN  16 , total integrated cost =  nan
# RUN  17 , total integrated cost =  nan
# RUN  18 , total integrated cost =  nan
# RUN  19 , total integrated cost =  nan
# RUN  20 , total integrated cost =  nan
# RUN  30 , total integrated cost =  nan
# RUN  40 , total integrated cost =  nan
# RUN  50 , total integrated cost =  nan
# RUN  60 , total integrated cost =  nan
# RUN  70 , total integrated cost =  nan
# RUN  80 , total integrated cost =  nan
# RUN  90 , total integrated cost =  nan
# RUN  100 , total integrated cost =  nan
# RUN  100 , total integrated cost =  nan
# Improved over  100  iterations in  43.69004403500003  seconds by  nan  percent.
# sparsity weight =  8.2e-05
# -------  71 0.47500000000000014 0.6750000000000004
# set cost params:  1.0 0.0 100000.0
# interpolate adjoint :  True True True
# initial cost =  384005.59692905797
# RUN  0 , total integrated cost =  384005.59692905797
# Gradient descend method:  None
# RUN  1 , total integrated cost =  384005.59692905797
# Control only changes marginally.
# RUN  1 , total integrated cost =  384005.59692905797
# Improved over  1  iterations in  0.3509120230000917  seconds by  0.0  percent.
# set cost params:  1.0 0.0 10000.0
# interpolate adjoint :  True True True
# initial cost =  384005.59692905797
# RUN  0 , total integrated cost =  384005.59692905797
# Gradient descend method:  None
# RUN  1 , total integrated cost =  384005.59692905797
# Control only changes marginally.
# RUN  1 , total integrated cost =  384005.59692905797
# Improved over  1  iterations in  0.3565967399999863  seconds by  0.0  percent.
# set cost params:  1.0 0.0 1000.0
# interpolate adjoint :  True True True
# initial cost =  384005.59692905797
# RUN  0 , total integrated cost =  384005.59692905797
# Gradient descend method:  None
# RUN  1 , total integrated cost =  384005.59692905797
# Control only changes marginally.
# RUN  1 , total integrated cost =  384005.59692905797
# Improved over  1  iterations in  0.35531656199964345  seconds by  0.0  percent.
# set cost params:  1.0 0.0 100.0
# interpolate adjoint :  True True True
# initial cost =  384005.59692905797
# RUN  0 , total integrated cost =  384005.59692905797
# Gradient descend method:  None
# RUN  1 , total integrated cost =  384005.59692905797
# Control only changes marginally.
# RUN  1 , total integrated cost =  384005.59692905797
# Improved over  1  iterations in  0.3539088890001949  seconds by  0.0  percent.
# set cost params:  1.0 0.0 10.0
# interpolate adjoint :  True True True
# initial cost =  384005.59692905797
# RUN  0 , total integrated cost =  384005.59692905797
# Gradient descend method:  None
# RUN  1 , total integrated cost =  384005.59692905797
# Control only changes marginally.
# RUN  1 , total integrated cost =  384005.59692905797
# Improved over  1  iterations in  0.3452297779995206  seconds by  0.0  percent.
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  384005.59692905797
# RUN  0 , total integrated cost =  384005.59692905797
# Gradient descend method:  None
# RUN  1 , total integrated cost =  384005.59692905797
# Control only changes marginally.
# RUN  1 , total integrated cost =  384005.59692905797
# Improved over  1  iterations in  0.3685872679998283  seconds by  0.0  percent.
# set cost params:  1.0 0.0 0.1
# interpolate adjoint :  True True True
# initial cost =  384005.59692905797
# RUN  0 , total integrated cost =  384005.59692905797
# Gradient descend method:  None
# RUN  1 , total integrated cost =  384005.59692905797
# Control only changes marginally.
# RUN  1 , total integrated cost =  384005.59692905797
# Improved over  1  iterations in  0.34572398199998133  seconds by  0.0  percent.
# set cost params:  1.0 0.0 0.01
# interpolate adjoint :  True True True
# initial cost =  384005.59692905797
# RUN  0 , total integrated cost =  384005.59692905797
# Gradient descend method:  None
# RUN  1 , total integrated cost =  384005.59692905797
# Control only changes marginally.
# RUN  1 , total integrated cost =  384005.59692905797
# Improved over  1  iterations in  0.3795021750001979  seconds by  0.0  percent.
# set cost params:  1.0 0.0 0.001
# interpolate adjoint :  True True True
# initial cost =  384005.59692905797
# RUN  0 , total integrated cost =  384005.59692905797
# Gradient descend method:  None
# RUN  1 , total integrated cost =  115834.91462792967
# RUN  2 , total integrated cost =  1970.2211219949606
# RUN  3 , total integrated cost =  9.893276208046514
# RUN  4 , total integrated cost =  0.3386111310314356
# RUN  5 , total integrated cost =  0.3261363871338388
# RUN  6 , total integrated cost =  0.3260266146877694
# RUN  7 , total integrated cost =  0.320657689830359
# RUN  8 , total integrated cost =  0.320657689830359
# Control only changes marginally.
# RUN  8 , total integrated cost =  0.320657689830359
# Improved over  8  iterations in  1.2180815390001953  seconds by  99.99991649661037  percent.
# set cost params:  1.0 0.0 0.0001
# interpolate adjoint :  True True True
# initial cost =  384005.59692905797
# RUN  0 , total integrated cost =  384005.59692905797
# Gradient descend method:  None
# RUN  1 , total integrated cost =  115834.90493132263
# RUN  2 , total integrated cost =  1970.1376376104176
# RUN  3 , total integrated cost =  1.7209706980180945
# RUN  4 , total integrated cost =  0.19315989530551747
# RUN  5 , total integrated cost =  0.1477083546125427
# RUN  6 , total integrated cost =  0.14765012271945047
# RUN  7 , total integrated cost =  0.035210397913675105
# RUN  8 , total integrated cost =  0.03519984684356823
# RUN  9 , total integrated cost =  0.03514711983486182
# RUN  10 , total integrated cost =  0.03514711983485973
# RUN  10 , total integrated cost =  0.03514711983485973
# Improved over  10  iterations in  1.6254829600002267  seconds by  99.99999084723761  percent.
# uncontrolled cost :  384005.59692905797
# cost splitting :  0.0009769776757825952 [  0.         108.39331991]
# set cost params:  1.0 0.0 0.0009000000000000001
# interpolate adjoint :  True True True
# initial cost =  384005.59692905797
# RUN  0 , total integrated cost =  384005.59692905797
# Gradient descend method:  None
# RUN  1 , total integrated cost =  115834.91355052889
# RUN  2 , total integrated cost =  1970.2118459523538
# RUN  3 , total integrated cost =  16.084019259546544
# RUN  4 , total integrated cost =  1.1781301977972705
# RUN  5 , total integrated cost =  0.3854122469525658
# RUN  6 , total integrated cost =  0.2268178070202282
# RUN  7 , total integrated cost =  0.16208258203328652
# RUN  8 , total integrated cost =  0.13348209342079426
# RUN  9 , total integrated cost =  0.11941385320098612
# RUN  10 , total integrated cost =  0.11207453968926363
# RUN  10 , total integrated cost =  0.11207453968926363
# Improved over  10  iterations in  0.9905244060000769  seconds by  99.99997081434735  percent.
# uncontrolled cost :  384005.59692905797
# cost splitting :  0.0005677028733202221 [  0.         108.83305919]
# set cost params:  1.0 0.0 0.00099
# interpolate adjoint :  True True True
# initial cost =  384005.59692905797
# RUN  0 , total integrated cost =  384005.59692905797
# Gradient descend method:  None
# RUN  1 , total integrated cost =  115834.91452018959
# RUN  2 , total integrated cost =  1970.2201943907012
# RUN  3 , total integrated cost =  17.161294053129094
# RUN  4 , total integrated cost =  0.4330120010521213
# RUN  5 , total integrated cost =  0.18770528454601781
# RUN  6 , total integrated cost =  0.14472775233351182
# RUN  7 , total integrated cost =  0.14472775233351182
# RUN  8 , total integrated cost =  nan
# RUN  9 , total integrated cost =  nan
# RUN  10 , total integrated cost =  nan
# RUN  11 , total integrated cost =  nan
# RUN  12 , total integrated cost =  nan
# RUN  13 , total integrated cost =  nan
# RUN  14 , total integrated cost =  nan
# RUN  15 , total integrated cost =  nan
# RUN  16 , total integrated cost =  nan
# RUN  17 , total integrated cost =  nan
# RUN  18 , total integrated cost =  nan
# RUN  19 , total integrated cost =  nan
# RUN  20 , total integrated cost =  nan
# RUN  30 , total integrated cost =  nan
# RUN  40 , total integrated cost =  nan
# RUN  50 , total integrated cost =  nan
# RUN  60 , total integrated cost =  nan
# RUN  70 , total integrated cost =  nan
# RUN  80 , total integrated cost =  nan
# RUN  90 , total integrated cost =  nan
# RUN  100 , total integrated cost =  nan
# RUN  100 , total integrated cost =  nan
# Improved over  100  iterations in  34.25157161900006  seconds by  nan  percent.
# sparsity weight =  0.00099
# -------  72 0.5000000000000002 0.6750000000000004
# set cost params:  1.0 0.0 100000.0
# interpolate adjoint :  True True True
# initial cost =  495331.1329655588
# RUN  0 , total integrated cost =  495331.1329655588
# Gradient descend method:  None
# RUN  1 , total integrated cost =  495331.1329655588
# Control only changes marginally.
# RUN  1 , total integrated cost =  495331.1329655588
# Improved over  1  iterations in  0.3456516879996343  seconds by  0.0  percent.
# set cost params:  1.0 0.0 10000.0
# interpolate adjoint :  True True True
# initial cost =  495331.1329655588
# RUN  0 , total integrated cost =  495331.1329655588
# Gradient descend method:  None
# RUN  1 , total integrated cost =  495331.1329655588
# Control only changes marginally.
# RUN  1 , total integrated cost =  495331.1329655588
# Improved over  1  iterations in  0.35916367299978447  seconds by  0.0  percent.
# set cost params:  1.0 0.0 1000.0
# interpolate adjoint :  True True True
# initial cost =  495331.1329655588
# RUN  0 , total integrated cost =  495331.1329655588
# Gradient descend method:  None
# RUN  1 , total integrated cost =  495331.1329655588
# Control only changes marginally.
# RUN  1 , total integrated cost =  495331.1329655588
# Improved over  1  iterations in  0.3447823030001018  seconds by  0.0  percent.
# set cost params:  1.0 0.0 100.0
# interpolate adjoint :  True True True
# initial cost =  495331.1329655588
# RUN  0 , total integrated cost =  495331.1329655588
# Gradient descend method:  None
# RUN  1 , total integrated cost =  495331.1329655588
# Control only changes marginally.
# RUN  1 , total integrated cost =  495331.1329655588
# Improved over  1  iterations in  0.34174908400018467  seconds by  0.0  percent.
# set cost params:  1.0 0.0 10.0
# interpolate adjoint :  True True True
# initial cost =  495331.1329655588
# RUN  0 , total integrated cost =  495331.1329655588
# Gradient descend method:  None
# RUN  1 , total integrated cost =  495331.1329655588
# Control only changes marginally.
# RUN  1 , total integrated cost =  495331.1329655588
# Improved over  1  iterations in  0.3389793919996009  seconds by  0.0  percent.
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  495331.1329655588
# RUN  0 , total integrated cost =  495331.1329655588
# Gradient descend method:  None
# RUN  1 , total integrated cost =  495331.1329655588
# Control only changes marginally.
# RUN  1 , total integrated cost =  495331.1329655588
# Improved over  1  iterations in  0.3830060929994943  seconds by  0.0  percent.
# set cost params:  1.0 0.0 0.1
# interpolate adjoint :  True True True
# initial cost =  495331.1329655588
# RUN  0 , total integrated cost =  495331.1329655588
# Gradient descend method:  None
# RUN  1 , total integrated cost =  495331.1329655588
# Control only changes marginally.
# RUN  1 , total integrated cost =  495331.1329655588
# Improved over  1  iterations in  0.327378425000461  seconds by  0.0  percent.
# set cost params:  1.0 0.0 0.01
# interpolate adjoint :  True True True
# initial cost =  495331.1329655588
# RUN  0 , total integrated cost =  495331.1329655588
# Gradient descend method:  None
# RUN  1 , total integrated cost =  123071.19255749354
# RUN  2 , total integrated cost =  991.2293880851515
# RUN  3 , total integrated cost =  991.2293880851515
# Control only changes marginally.
# RUN  3 , total integrated cost =  991.2293880851515
# Improved over  3  iterations in  0.6007399390000501  seconds by  99.79988550645895  percent.
# set cost params:  1.0 0.0 0.001
# interpolate adjoint :  True True True
# initial cost =  495331.1329655588
# RUN  0 , total integrated cost =  495331.1329655588
# Gradient descend method:  None
# RUN  1 , total integrated cost =  123071.09858570517
# RUN  2 , total integrated cost =  990.9272801663592
# RUN  3 , total integrated cost =  990.9272801663592
# Control only changes marginally.
# RUN  3 , total integrated cost =  990.9272801663592
# Improved over  3  iterations in  0.593004110000038  seconds by  99.79994649756141  percent.
# set cost params:  1.0 0.0 0.0001
# interpolate adjoint :  True True True
# initial cost =  495331.1329655588
# RUN  0 , total integrated cost =  495331.1329655588
# Gradient descend method:  None
# RUN  1 , total integrated cost =  123071.08918852634
# RUN  2 , total integrated cost =  1574.205103375647
# RUN  3 , total integrated cost =  1574.205103375647
# Control only changes marginally.
# RUN  3 , total integrated cost =  1574.205103375647
# Improved over  3  iterations in  0.530962916000135  seconds by  99.68219136682347  percent.
# set cost params:  1.0 0.0 1e-05
# interpolate adjoint :  True True True
# initial cost =  495331.1329655588
# RUN  0 , total integrated cost =  495331.1329655588
# Gradient descend method:  None
# RUN  1 , total integrated cost =  123071.08824880845
# RUN  2 , total integrated cost =  1574.1974356239277
# RUN  3 , total integrated cost =  1574.1974356239277
# Control only changes marginally.
# RUN  3 , total integrated cost =  1574.1974356239277
# Improved over  3  iterations in  0.5307232839995777  seconds by  99.68219291482868  percent.
# set cost params:  1.0 0.0 1e-06
# interpolate adjoint :  True True True
# initial cost =  495331.1329655588
# RUN  0 , total integrated cost =  495331.1329655588
# Gradient descend method:  None
# RUN  1 , total integrated cost =  123071.08815483666
# RUN  2 , total integrated cost =  1574.1966688487553
# RUN  3 , total integrated cost =  1574.1966688487553
# Control only changes marginally.
# RUN  3 , total integrated cost =  1574.1966688487553
# Improved over  3  iterations in  0.5275800319996051  seconds by  99.6821930696292  percent.
# set cost params:  1.0 0.0 1e-07
# interpolate adjoint :  True True True
# initial cost =  495331.1329655588
# RUN  0 , total integrated cost =  495331.1329655588
# Gradient descend method:  None
# RUN  1 , total integrated cost =  123071.08814543948
# RUN  2 , total integrated cost =  1574.1965921712383
# RUN  3 , total integrated cost =  1574.1965921712383
# Control only changes marginally.
# RUN  3 , total integrated cost =  1574.1965921712383
# Improved over  3  iterations in  0.547030196000378  seconds by  99.68219308510925  percent.
# set cost params:  1.0 0.0 1e-08
# interpolate adjoint :  True True True
# initial cost =  495331.1329655588
# RUN  0 , total integrated cost =  495331.1329655588
# Gradient descend method:  None
# RUN  1 , total integrated cost =  123071.08814449976
# RUN  2 , total integrated cost =  1574.1965845034865
# RUN  3 , total integrated cost =  1574.1965845034865
# Control only changes marginally.
# RUN  3 , total integrated cost =  1574.1965845034865
# Improved over  3  iterations in  0.5747634819999803  seconds by  99.68219308665725  percent.
# set cost params:  1.0 0.0 1e-09
# interpolate adjoint :  True True True
# initial cost =  495331.1329655588
# RUN  0 , total integrated cost =  495331.1329655588
# Gradient descend method:  None
# RUN  1 , total integrated cost =  123071.0881444058
# RUN  2 , total integrated cost =  1574.196583736711
# RUN  3 , total integrated cost =  1574.196583736711
# Control only changes marginally.
# RUN  3 , total integrated cost =  1574.196583736711
# Improved over  3  iterations in  0.5438793009998335  seconds by  99.68219308681206  percent.
# set cost params:  1.0 0.0 1e-10
# interpolate adjoint :  True True True
# initial cost =  495331.1329655588
# RUN  0 , total integrated cost =  495331.1329655588
# Gradient descend method:  None
# RUN  1 , total integrated cost =  123071.0881443964
# RUN  2 , total integrated cost =  1574.1965836600336
# RUN  3 , total integrated cost =  1574.1965836600336
# Control only changes marginally.
# RUN  3 , total integrated cost =  1574.1965836600336
# Improved over  3  iterations in  0.5770635269991544  seconds by  99.68219308682754  percent.
# set cost params:  1.0 0.0 1e-11
# interpolate adjoint :  True True True
# initial cost =  495331.1329655588
# RUN  0 , total integrated cost =  495331.1329655588
# Gradient descend method:  None
# RUN  1 , total integrated cost =  123071.08814439546
# RUN  2 , total integrated cost =  1574.196583652366
# RUN  3 , total integrated cost =  1574.196583652366
# Control only changes marginally.
# RUN  3 , total integrated cost =  1574.196583652366
# Improved over  3  iterations in  0.6464913010004238  seconds by  99.68219308682909  percent.
# set cost params:  1.0 0.0 1e-12
# interpolate adjoint :  True True True
# initial cost =  495331.1329655588
# RUN  0 , total integrated cost =  495331.1329655588
# Gradient descend method:  None
# RUN  1 , total integrated cost =  123071.08814439537
# RUN  2 , total integrated cost =  1574.1965836515992
# RUN  3 , total integrated cost =  1574.1965836515992
# Control only changes marginally.
# RUN  3 , total integrated cost =  1574.1965836515992
# Improved over  3  iterations in  0.7397655349996057  seconds by  99.68219308682924  percent.
# set cost params:  1.0 0.0 1e-13
# interpolate adjoint :  True True True
# initial cost =  495331.1329655588
# RUN  0 , total integrated cost =  495331.1329655588
# Gradient descend method:  None
# RUN  1 , total integrated cost =  123071.08814439535
# RUN  2 , total integrated cost =  1574.196583651514
# RUN  3 , total integrated cost =  1574.196583651514
# Control only changes marginally.
# RUN  3 , total integrated cost =  1574.196583651514
# Improved over  3  iterations in  0.8462016740004401  seconds by  99.68219308682926  percent.
# set cost params:  1.0 0.0 1e-14
# interpolate adjoint :  True True True
# initial cost =  495331.1329655588
# RUN  0 , total integrated cost =  495331.1329655588
# Gradient descend method:  None
# RUN  1 , total integrated cost =  123071.08814439535
# RUN  2 , total integrated cost =  1574.196583651514
# RUN  3 , total integrated cost =  1574.196583651514
# Control only changes marginally.
# RUN  3 , total integrated cost =  1574.196583651514
# Improved over  3  iterations in  0.7934491280002476  seconds by  99.68219308682926  percent.
# set cost params:  1.0 0.0 1e-15
# interpolate adjoint :  True True True
# initial cost =  495331.1329655588
# RUN  0 , total integrated cost =  495331.1329655588
# Gradient descend method:  None
# RUN  1 , total integrated cost =  123071.08814439535
# RUN  2 , total integrated cost =  1574.196583651514
# RUN  3 , total integrated cost =  1574.196583651514
# Control only changes marginally.
# RUN  3 , total integrated cost =  1574.196583651514
# Improved over  3  iterations in  0.7722879450002438  seconds by  99.68219308682926  percent.
# set cost params:  1.0 0.0 1e-16
# interpolate adjoint :  True True True
# initial cost =  495331.1329655588
# RUN  0 , total integrated cost =  495331.1329655588
# Gradient descend method:  None
# RUN  1 , total integrated cost =  123071.08814439535
# RUN  2 , total integrated cost =  1574.196583651514
# RUN  3 , total integrated cost =  1574.196583651514
# Control only changes marginally.
# RUN  3 , total integrated cost =  1574.196583651514
# Improved over  3  iterations in  0.7070276139993439  seconds by  99.68219308682926  percent.
# set cost params:  1.0 0.0 1e-17
# interpolate adjoint :  True True True
# initial cost =  495331.1329655588
# RUN  0 , total integrated cost =  495331.1329655588
# Gradient descend method:  None
# RUN  1 , total integrated cost =  123071.08814439535
# RUN  2 , total integrated cost =  1574.196583651514
# RUN  3 , total integrated cost =  1574.196583651514
# Control only changes marginally.
# RUN  3 , total integrated cost =  1574.196583651514
# Improved over  3  iterations in  0.8530853189995469  seconds by  99.68219308682926  percent.
# set cost params:  1.0 0.0 1e-18
# interpolate adjoint :  True True True
# initial cost =  495331.1329655588
# RUN  0 , total integrated cost =  495331.1329655588
# Gradient descend method:  None
# RUN  1 , total integrated cost =  123071.08814439535
# RUN  2 , total integrated cost =  1574.196583651514
# RUN  3 , total integrated cost =  1574.196583651514
# Control only changes marginally.
# RUN  3 , total integrated cost =  1574.196583651514
# Improved over  3  iterations in  0.8406815529997402  seconds by  99.68219308682926  percent.
# set cost params:  1.0 0.0 1e-19
# interpolate adjoint :  True True True
# initial cost =  495331.1329655588
# RUN  0 , total integrated cost =  495331.1329655588
# Gradient descend method:  None
# RUN  1 , total integrated cost =  123071.08814439535
# RUN  2 , total integrated cost =  1574.196583651514
# RUN  3 , total integrated cost =  1574.196583651514
# Control only changes marginally.
# RUN  3 , total integrated cost =  1574.196583651514
# Improved over  3  iterations in  0.7295115369997802  seconds by  99.68219308682926  percent.
# set cost params:  1.0 0.0 1e-20
# interpolate adjoint :  True True True
# initial cost =  495331.1329655588
# RUN  0 , total integrated cost =  495331.1329655588
# Gradient descend method:  None
# RUN  1 , total integrated cost =  123071.08814439535
# RUN  2 , total integrated cost =  1574.196583651514
# RUN  3 , total integrated cost =  1574.196583651514
# Control only changes marginally.
# RUN  3 , total integrated cost =  1574.196583651514
# Improved over  3  iterations in  0.7810041289994842  seconds by  99.68219308682926  percent.
# set cost params:  1.0 0.0 1e-21
# interpolate adjoint :  True True True
# initial cost =  495331.1329655588
# RUN  0 , total integrated cost =  495331.1329655588
# Gradient descend method:  None
# RUN  1 , total integrated cost =  123071.08814439535
# RUN  2 , total integrated cost =  1574.196583651514
# RUN  3 , total integrated cost =  1574.196583651514
# Control only changes marginally.
# RUN  3 , total integrated cost =  1574.196583651514
# Improved over  3  iterations in  0.7357893289999993  seconds by  99.68219308682926  percent.
# set cost params:  1.0 0.0 1e-22
# interpolate adjoint :  True True True
# initial cost =  495331.1329655588
# RUN  0 , total integrated cost =  495331.1329655588
# Gradient descend method:  None
# RUN  1 , total integrated cost =  123071.08814439535
# RUN  2 , total integrated cost =  1574.196583651514
# RUN  3 , total integrated cost =  1574.196583651514
# Control only changes marginally.
# RUN  3 , total integrated cost =  1574.196583651514
# Improved over  3  iterations in  0.6880908110006203  seconds by  99.68219308682926  percent.
# set cost params:  1.0 0.0 1e-23
# interpolate adjoint :  True True True
# initial cost =  495331.1329655588
# RUN  0 , total integrated cost =  495331.1329655588
# Gradient descend method:  None
# RUN  1 , total integrated cost =  123071.08814439535
# RUN  2 , total integrated cost =  1574.196583651514
# RUN  3 , total integrated cost =  1574.196583651514
# Control only changes marginally.
# RUN  3 , total integrated cost =  1574.196583651514
# Improved over  3  iterations in  0.7323445479996735  seconds by  99.68219308682926  percent.
# set cost params:  1.0 0.0 1e-24
# interpolate adjoint :  True True True
# initial cost =  495331.1329655588
# RUN  0 , total integrated cost =  495331.1329655588
# Gradient descend method:  None
# RUN  1 , total integrated cost =  123071.08814439535
# RUN  2 , total integrated cost =  1574.196583651514
# RUN  3 , total integrated cost =  1574.196583651514
# Control only changes marginally.
# RUN  3 , total integrated cost =  1574.196583651514
# Improved over  3  iterations in  0.6679058939998868  seconds by  99.68219308682926  percent.
# set cost params:  1.0 0.0 1e-25
# interpolate adjoint :  True True True
# initial cost =  495331.1329655588
# RUN  0 , total integrated cost =  495331.1329655588
# Gradient descend method:  None
# RUN  1 , total integrated cost =  123071.08814439535
# RUN  2 , total integrated cost =  1574.196583651514
# RUN  3 , total integrated cost =  1574.196583651514
# Control only changes marginally.
# RUN  3 , total integrated cost =  1574.196583651514
# Improved over  3  iterations in  0.72080901299978  seconds by  99.68219308682926  percent.
# set cost params:  1.0 0.0 1e-26
# interpolate adjoint :  True True True
# initial cost =  495331.1329655588
# RUN  0 , total integrated cost =  495331.1329655588
# Gradient descend method:  None
# RUN  1 , total integrated cost =  123071.08814439535
# RUN  2 , total integrated cost =  1574.196583651514
# RUN  3 , total integrated cost =  1574.196583651514
# Control only changes marginally.
# RUN  3 , total integrated cost =  1574.196583651514
# Improved over  3  iterations in  0.6858555999997407  seconds by  99.68219308682926  percent.
# set cost params:  1.0 0.0 1e-27
# interpolate adjoint :  True True True
# initial cost =  495331.1329655588
# RUN  0 , total integrated cost =  495331.1329655588
# Gradient descend method:  None
# RUN  1 , total integrated cost =  123071.08814439535
# RUN  2 , total integrated cost =  1574.196583651514
# RUN  3 , total integrated cost =  1574.196583651514
# Control only changes marginally.
# RUN  3 , total integrated cost =  1574.196583651514
# Improved over  3  iterations in  0.7262359810001726  seconds by  99.68219308682926  percent.
# set cost params:  1.0 0.0 1e-28
# interpolate adjoint :  True True True
# initial cost =  495331.1329655588
# RUN  0 , total integrated cost =  495331.1329655588
# Gradient descend method:  None
# RUN  1 , total integrated cost =  123071.08814439535
# RUN  2 , total integrated cost =  1574.196583651514
# RUN  3 , total integrated cost =  1574.196583651514
# Control only changes marginally.
# RUN  3 , total integrated cost =  1574.196583651514
# Improved over  3  iterations in  0.7803807059999599  seconds by  99.68219308682926  percent.
# set cost params:  1.0 0.0 1e-29
# interpolate adjoint :  True True True
# initial cost =  495331.1329655588
# RUN  0 , total integrated cost =  495331.1329655588
# Gradient descend method:  None
# RUN  1 , total integrated cost =  123071.08814439535
# RUN  2 , total integrated cost =  1574.196583651514
# RUN  3 , total integrated cost =  1574.196583651514
# Control only changes marginally.
# RUN  3 , total integrated cost =  1574.196583651514
# Improved over  3  iterations in  0.8364442659994893  seconds by  99.68219308682926  percent.
# set cost params:  1.0 0.0 1e-30
# interpolate adjoint :  True True True
# initial cost =  495331.1329655588
# RUN  0 , total integrated cost =  495331.1329655588
# Gradient descend method:  None
# RUN  1 , total integrated cost =  123071.08814439535
# RUN  2 , total integrated cost =  1574.196583651514
# RUN  3 , total integrated cost =  1574.196583651514
# Control only changes marginally.
# RUN  3 , total integrated cost =  1574.196583651514
# Improved over  3  iterations in  0.70543284499945  seconds by  99.68219308682926  percent.
# set cost params:  1.0 0.0 1e-31
# interpolate adjoint :  True True True
# initial cost =  495331.1329655588
# RUN  0 , total integrated cost =  495331.1329655588
# Gradient descend method:  None
# RUN  1 , total integrated cost =  123071.08814439535
# RUN  2 , total integrated cost =  1574.196583651514
# RUN  3 , total integrated cost =  1574.196583651514
# Control only changes marginally.
# RUN  3 , total integrated cost =  1574.196583651514
# Improved over  3  iterations in  0.7993133620002482  seconds by  99.68219308682926  percent.
# set cost params:  1.0 0.0 1e-32
# interpolate adjoint :  True True True
# initial cost =  495331.1329655588
# RUN  0 , total integrated cost =  495331.1329655588
# Gradient descend method:  None
# RUN  1 , total integrated cost =  123071.08814439535
# RUN  2 , total integrated cost =  1574.196583651514
# RUN  3 , total integrated cost =  1574.196583651514
# Control only changes marginally.
# RUN  3 , total integrated cost =  1574.196583651514
# Improved over  3  iterations in  0.7380500789995494  seconds by  99.68219308682926  percent.
# set cost params:  1.0 0.0 1e-33
# interpolate adjoint :  True True True
# initial cost =  495331.1329655588
# RUN  0 , total integrated cost =  495331.1329655588
# Gradient descend method:  None
# RUN  1 , total integrated cost =  123071.08814439535
# RUN  2 , total integrated cost =  1574.196583651514
# RUN  3 , total integrated cost =  1574.196583651514
# Control only changes marginally.
# RUN  3 , total integrated cost =  1574.196583651514
# Improved over  3  iterations in  0.7567034650001006  seconds by  99.68219308682926  percent.
# set cost params:  1.0 0.0 1e-34
# interpolate adjoint :  True True True
# initial cost =  495331.1329655588
# RUN  0 , total integrated cost =  495331.1329655588
# Gradient descend method:  None
# RUN  1 , total integrated cost =  123071.08814439535
# RUN  2 , total integrated cost =  1574.196583651514
# RUN  3 , total integrated cost =  1574.196583651514
# Control only changes marginally.
# RUN  3 , total integrated cost =  1574.196583651514
# Improved over  3  iterations in  0.8544950479999898  seconds by  99.68219308682926  percent.
# set cost params:  1.0 0.0 1e-35
# interpolate adjoint :  True True True
# initial cost =  495331.1329655588
# RUN  0 , total integrated cost =  495331.1329655588
# Gradient descend method:  None
# RUN  1 , total integrated cost =  123071.08814439535
# RUN  2 , total integrated cost =  1574.196583651514
# RUN  3 , total integrated cost =  1574.196583651514
# Control only changes marginally.
# RUN  3 , total integrated cost =  1574.196583651514
# Improved over  3  iterations in  0.9314110000004803  seconds by  99.68219308682926  percent.
# set cost params:  1.0 0.0 1e-36
# interpolate adjoint :  True True True
# initial cost =  495331.1329655588
# RUN  0 , total integrated cost =  495331.1329655588
# Gradient descend method:  None
# RUN  1 , total integrated cost =  123071.08814439535
# RUN  2 , total integrated cost =  1574.196583651514
# RUN  3 , total integrated cost =  1574.196583651514
# Control only changes marginally.
# RUN  3 , total integrated cost =  1574.196583651514
# Improved over  3  iterations in  0.7017604969996682  seconds by  99.68219308682926  percent.
# set cost params:  1.0 0.0 1e-37
# interpolate adjoint :  True True True
# initial cost =  495331.1329655588
# RUN  0 , total integrated cost =  495331.1329655588
# Gradient descend method:  None
# RUN  1 , total integrated cost =  123071.08814439535
# RUN  2 , total integrated cost =  1574.196583651514
# RUN  3 , total integrated cost =  1574.196583651514
# Control only changes marginally.
# RUN  3 , total integrated cost =  1574.196583651514
# Improved over  3  iterations in  0.6482789239998965  seconds by  99.68219308682926  percent.
# set cost params:  1.0 0.0 1e-38
# interpolate adjoint :  True True True
# initial cost =  495331.1329655588
# RUN  0 , total integrated cost =  495331.1329655588
# Gradient descend method:  None
# RUN  1 , total integrated cost =  123071.08814439535
# RUN  2 , total integrated cost =  1574.196583651514
# RUN  3 , total integrated cost =  1574.196583651514
# Control only changes marginally.
# RUN  3 , total integrated cost =  1574.196583651514
# Improved over  3  iterations in  0.9196846250006274  seconds by  99.68219308682926  percent.
# set cost params:  1.0 0.0 1e-39
# interpolate adjoint :  True True True
# initial cost =  495331.1329655588
# RUN  0 , total integrated cost =  495331.1329655588
# Gradient descend method:  None
# RUN  1 , total integrated cost =  123071.08814439535
# RUN  2 , total integrated cost =  1574.196583651514
# RUN  3 , total integrated cost =  1574.196583651514
# Control only changes marginally.
# RUN  3 , total integrated cost =  1574.196583651514
# Improved over  3  iterations in  0.8764842459995634  seconds by  99.68219308682926  percent.
# set cost params:  1.0 0.0 1e-40
# interpolate adjoint :  True True True
# initial cost =  495331.1329655588
# RUN  0 , total integrated cost =  495331.1329655588
# Gradient descend method:  None
# RUN  1 , total integrated cost =  123071.08814439535
# RUN  2 , total integrated cost =  1574.196583651514
# RUN  3 , total integrated cost =  1574.196583651514
# Control only changes marginally.
# RUN  3 , total integrated cost =  1574.196583651514
# Improved over  3  iterations in  0.645100356000512  seconds by  99.68219308682926  percent.
# set cost params:  1.0 0.0 1e-41
# interpolate adjoint :  True True True
# initial cost =  495331.1329655588
# RUN  0 , total integrated cost =  495331.1329655588
# Gradient descend method:  None
# RUN  1 , total integrated cost =  123071.08814439535
# RUN  2 , total integrated cost =  1574.196583651514
# RUN  3 , total integrated cost =  1574.196583651514
# Control only changes marginally.
# RUN  3 , total integrated cost =  1574.196583651514
# Improved over  3  iterations in  0.683495144000517  seconds by  99.68219308682926  percent.
# set cost params:  1.0 0.0 1e-42
# interpolate adjoint :  True True True
# initial cost =  495331.1329655588
# RUN  0 , total integrated cost =  495331.1329655588
# Gradient descend method:  None
# RUN  1 , total integrated cost =  123071.08814439535
# RUN  2 , total integrated cost =  1574.196583651514
# RUN  3 , total integrated cost =  1574.196583651514
# Control only changes marginally.
# RUN  3 , total integrated cost =  1574.196583651514
# Improved over  3  iterations in  0.6392701859995213  seconds by  99.68219308682926  percent.
# set cost params:  1.0 0.0 1e-43
# interpolate adjoint :  True True True
# initial cost =  495331.1329655588
# RUN  0 , total integrated cost =  495331.1329655588
# Gradient descend method:  None
# RUN  1 , total integrated cost =  123071.08814439535
# RUN  2 , total integrated cost =  1574.196583651514
# RUN  3 , total integrated cost =  1574.196583651514
# Control only changes marginally.
# RUN  3 , total integrated cost =  1574.196583651514
# Improved over  3  iterations in  0.6623810150003919  seconds by  99.68219308682926  percent.
# set cost params:  1.0 0.0 1e-44
# interpolate adjoint :  True True True
# initial cost =  495331.1329655588
# RUN  0 , total integrated cost =  495331.1329655588
# Gradient descend method:  None
# RUN  1 , total integrated cost =  123071.08814439535
# RUN  2 , total integrated cost =  1574.196583651514
# RUN  3 , total integrated cost =  1574.196583651514
# Control only changes marginally.
# RUN  3 , total integrated cost =  1574.196583651514
# Improved over  3  iterations in  0.9384929550005836  seconds by  99.68219308682926  percent.
# set cost params:  1.0 0.0 1e-45
# interpolate adjoint :  True True True
# initial cost =  495331.1329655588
# RUN  0 , total integrated cost =  495331.1329655588
# Gradient descend method:  None
# RUN  1 , total integrated cost =  123071.08814439535
# RUN  2 , total integrated cost =  1574.196583651514
# RUN  3 , total integrated cost =  1574.196583651514
# Control only changes marginally.
# RUN  3 , total integrated cost =  1574.196583651514
# Improved over  3  iterations in  0.9980439569999362  seconds by  99.68219308682926  percent.
# set cost params:  1.0 0.0 1e-46
# interpolate adjoint :  True True True
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_12889/2317555454.py in <module>
#      32             max_it = 100
#      33
# ---> 34         bestControl_[i][j], bestState_[i][j], cost_[i][j], runtime_, grad_, phi_, phi1_, costnode_[i][j] = aln.A1(
#      35             control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
#      36             startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
#
# ~/Promotion/neurolib/neurolib/models/model.py in A1(self, control_, target_state_, c_scheme_, u_mat_, u_scheme_, max_iteration_, tolerance_, startStep_, max_control_, min_control_, t_sim_, t_sim_pre_, t_sim_post_, CGVar, line_search_, control_variables_, prec_variables_, separate_comp, transition_time_, noise_real, init_params)
#     661             if self.params.N == 1:
#     662                 if noise_real == 0:
# --> 663                     return opti1_rate_control.A1(self, control_, target_state_, c_scheme_, u_mat_, u_scheme_, max_iteration_,
#     664                                                 tolerance_, startStep_, max_control_, min_control_, t_sim_, t_sim_pre_, t_sim_post_, CGVar,
#     665                                                 line_search_, control_variables_, prec_variables_, separate_comp, transition_time_)
#
# ~/Promotion/neurolib/neurolib/utils/A1_aln_rate_control.py in A1(model, control_, target_state, c_scheme_, u_mat_, u_scheme_, max_iteration_, tolerance_, startStep_, cntrl_max_, cntrl_min_, t_sim_, t_sim_pre_, t_sim_post_, CGVar, line_search_, control_variables_, prec_variables_, separate_comp, transition_time_)
#     178     model.params['duration'] = t_sim_
#     179     #control_[:,2:,-2:] = 0.
# --> 180     state0_ = fo.updateFullState(model, control_, state_vars)
#     181
#     182     state1_ = state0_.copy()
#
# ~/Promotion/neurolib/neurolib/utils/func_optimize.py in updateFullState(model, control_, state_vars_)
#      16 def updateFullState(model, control_, state_vars_):
#      17     state_ = model.getZeroFullState()
# ---> 18     model.run(control=control_)
#      19     for sv in range(len(state_vars_)):
#      20         state_[:,sv,:] = model.state[state_vars_[sv]][:,:]
#
# ~/Promotion/neurolib/neurolib/models/model.py in run(self, inputs, chunkwise, chunksize, bold, append, append_outputs, continue_run, control)
#     182
#     183         if chunkwise is False:
# --> 184             self.integrate(append_outputs=append, simulate_bold=bold, control=cntrl)
#     185             if continue_run:
#     186                 self.setInitialValuesToLastState()
#
# ~/Promotion/neurolib/neurolib/models/model.py in integrate(self, append_outputs, simulate_bold, control)
#     223         # run integration
#     224         #print("before integration")
# --> 225         t, *variables = self.integration(self.params, control=control)
#     226         #print("after integration")
#     227         self.storeOutputsAndStates(t, variables, append=append_outputs)
#
# ~/Promotion/neurolib/neurolib/models/aln/timeIntegration.py in timeIntegration(params, control)
#     281     # ------------------------------------------------------------------------
#     282
# --> 283     return timeIntegration_njit_elementwise(
#     284         dt,
#     285         duration,
#
# KeyboardInterrupt:

# %%
bad = [18, 25, 30, 31, 36, 37, 43, 44, 48, 49, 50, 56, 57, 58, 62, 63, 64, 65,
       69, 70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82]

# %%
for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
   
    k = 0
    
    while not conv[i]:
        max_it = int(100 + 10**k)
        weight_ = ( cost_uncontrolled[i] - costnode_[i][0][0][0] ) / sum( costnode_[i][2][0][:] )
            
        dur = d_array[0]
        aln.params.duration = dur
        cost.setParams(1., weight_ * factor_we, weight_ * factor_ws)
        weights_[i] = cost.getParams()

        setinit(initVars[i], aln)

        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        control0 = aln.getZeroControl()
        control0 = bestControl_[i][:,:,n_pre-1:-n_post+1]

        bestControl_[i], bestState_[i], cost_[i], runtime_, grad_, phi_, phi1_, costnode_[i] = aln.A1(
            control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
            prec_variables_ = p_var, transition_time_ = t_pen[0])
        
        if cost_[i][2] == 0.:
            conv[i] = True

        #print('uncontrolled cost : ', cost_uncontrolled[i])
        print('cost splitting : ', costnode_[i][0][0][0], costnode_[i][2][0][:2])

        time_ = np.arange(-dur_pre,round(dur+dur_post+aln.params.dt,1),aln.params.dt)
        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        if False:
            fig, ax = plt.subplots(2,1, constrained_layout=True, figsize = (4,4) )
            ax[1].plot(time_, bestControl_[i][0,0,:], color = 'red')
            ax[0].plot(time_, bestState_[i][0,0,:], color= 'red')
            ax[1].plot(time_, bestControl_[i][0,1,:], color = 'blue')
            ax[0].plot(time_, bestState_[i][0,1,:], color= 'blue')
            ax[0].plot(time_, target_[0,0,:], linestyle = '--', color='red')
            ax[0].plot(time_, target_[0,1,:], linestyle = '--', color='blue')
            ax[0].set_xlim(-dur_pre,dur+dur_post)
            ax[1].set_xlim(-dur_pre,dur+dur_post)
            ax[0].axvspan(dur*t_pen[0], dur, alpha=0.2, color='gray')
            plt.show()

        with open(file_,'wb') as f:
            pickle.dump([bestControl_, bestState_, cost_, costnode_, weights_], f)
        
        k += 1
# Out:
# -------  0 0.4000000000000001 0.3500000000000001
# set cost params:  1.0 0.0 153458.28796112418
# interpolate adjoint :  True True True
# initial cost =  147859.9020552954
# RUN  0 , total integrated cost =  147859.9020552954
# Gradient descend method:  None
# RUN  1 , total integrated cost =  147859.17340896447
# RUN  2 , total integrated cost =  147858.29107218335
# RUN  3 , total integrated cost =  147858.12877167427
# RUN  4 , total integrated cost =  147857.68079853832
# RUN  5 , total integrated cost =  147857.43422519276
# RUN  6 , total integrated cost =  147802.22308147926
# RUN  7 , total integrated cost =  147785.48504280613
# RUN  8 , total integrated cost =  147772.01924827707
# RUN  9 , total integrated cost =  147760.43120194227
# RUN  10 , total integrated cost =  147741.75661072088
# RUN  11 , total integrated cost =  147728.6426501745
# RUN  12 , total integrated cost =  147719.47918816213
# RUN  13 , total integrated cost =  147712.38485941786
# RUN  14 , total integrated cost =  147690.54129199625
# RUN  15 , total integrated cost =  147674.32244748698
# RUN  16 , total integrated cost =  147639.69069220737
# RUN  17 , total integrated cost =  147623.81203721053
# RUN  18 , total integrated cost =  147623.45981815713
# RUN  19 , total integrated cost =  147622.81453606352
# RUN  20 , total integrated cost =  147622.41653211918
# RUN  30 , total integrated cost =  147509.95672288595
# RUN  40 , total integrated cost =  147453.51830468472
# RUN  50 , total integrated cost =  147447.5171767084
# RUN  60 , total integrated cost =  147440.60042882417
# RUN  70 , total integrated cost =  147433.1550091087
# RUN  80 , total integrated cost =  147271.78276495278
# RUN  90 , total integrated cost =  147208.05006767472
# RUN  100 , total integrated cost =  147197.80427681375
# RUN  110 , total integrated cost =  147151.8489822584
# RUN  120 , total integrated cost =  147116.5486376677
# RUN  130 , total integrated cost =  147022.46668359704
# RUN  140 , total integrated cost =  147014.69548445372
# RUN  150 , total integrated cost =  146942.4138995022
# RUN  160 , total integrated cost =  146930.12386209858
# RUN  170 , total integrated cost =  146921.7252730279
# RUN  180 , total integrated cost =  146919.39428632293
# RUN  190 , total integrated cost =  146908.1729435785
# RUN  200 , total integrated cost =  146905.83231920312
# RUN  300 , total integrated cost =  146843.7159209509
# RUN  400 , total integrated cost =  146555.8652820422
# RUN  500 , total integrated cost =  146346.50605118633
# RUN  600 , total integrated cost =  146285.32852921844
# RUN  700 , total integrated cost =  146243.0221222249
# RUN  800 , total integrated cost =  146021.70021207424
# RUN  900 , total integrated cost =  145776.678867665
# RUN  1000 , total integrated cost =  145746.4547140326
# RUN  1000 , total integrated cost =  145746.4547140326
# Improved over  1000  iterations in  431.4199916709913  seconds by  1.4293580016524317  percent.
# cost splitting :  19.356141261816028 [0.         0.94660813]
# set cost params:  1.0 0.0 155118.0862245371
# interpolate adjoint :  True True True
# initial cost =  147317.63323745644
# RUN  0 , total integrated cost =  147317.63323745644
# Gradient descend method:  None
# RUN  1 , total integrated cost =  147317.50566839456
# RUN  2 , total integrated cost =  147317.43546220247
# RUN  3 , total integrated cost =  147317.42675067138
# RUN  4 , total integrated cost =  147317.31756048
# RUN  5 , total integrated cost =  147317.2578800682
# RUN  6 , total integrated cost =  147317.25131530163
# RUN  7 , total integrated cost =  147317.08786725966
# RUN  8 , total integrated cost =  147316.985062497
# RUN  9 , total integrated cost =  147316.97843363337
# RUN  10 , total integrated cost =  147253.30590293976
# RUN  11 , total integrated cost =  147251.7495820394
# RUN  12 , total integrated cost =  147251.35645450663
# RUN  13 , total integrated cost =  147250.83017038263
# RUN  14 , total integrated cost =  147250.80883356335
# RUN  15 , total integrated cost =  147250.6347115
# RUN  16 , total integrated cost =  147250.52860459662
# RUN  17 , total integrated cost =  147250.43925487626
# RUN  18 , total integrated cost =  147250.28703757765
# RUN  19 , total integrated cost =  147250.26946661057
# RUN  20 , total integrated cost =  147249.73483251152
# RUN  30 , total integrated cost =  147248.456196559
# RUN  40 , total integrated cost =  147234.15393758484
# RUN  50 , total integrated cost =  147230.1131529033
# RUN  60 , total integrated cost =  147229.73396647337
# RUN  70 , total integrated cost =  147227.56728818236
# RUN  80 , total integrated cost =  147226.83407333633
# RUN  90 , total integrated cost =  147156.43085093464
# RUN  100 , total integrated cost =  147145.73293781382
# RUN  110 , total integrated cost =  147137.459490329
# RUN  120 , total integrated cost =  147136.95983028458
# RUN  130 , total integrated cost =  147136.1499441152
# RUN  140 , total integrated cost =  147135.54242731174
# RUN  150 , total integrated cost =  147135.05276801257
# RUN  160 , total integrated cost =  147112.14492442913
# RUN  170 , total integrated cost =  147096.056955767
# RUN  180 , total integrated cost =  147095.02195920885
# RUN  190 , total integrated cost =  147094.21245199925
# RUN  200 , total integrated cost =  147093.95120995407
# RUN  300 , total integrated cost =  147054.43369475644
# RUN  400 , total integrated cost =  146971.99528676082
# RUN  500 , total integrated cost =  146857.07721409886
# RUN  600 , total integrated cost =  146839.58316719288
# RUN  700 , total integrated cost =  146818.7552016118
# RUN  800 , total integrated cost =  146799.80198553673
# RUN  900 , total integrated cost =  146757.19263100007
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_63766/3754351904.py in <module>
#      28         control0 = bestControl_[i][:,:,n_pre-1:-n_post+1]
#      29
# ---> 30         bestControl_[i], bestState_[i], cost_[i], runtime_, grad_, phi_, phi1_, costnode_[i] = aln.A1(
#      31             control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
#      32             startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
#
# ~/Promotion/neurolib/neurolib/models/model.py in A1(self, control_, target_state_, c_scheme_, u_mat_, u_scheme_, max_iteration_, tolerance_, startStep_, max_control_, min_control_, t_sim_, t_sim_pre_, t_sim_post_, CGVar, line_search_, control_variables_, prec_variables_, separate_comp, transition_time_, noise_real, init_params)
#     661             if self.params.N == 1:
#     662                 if noise_real == 0:
# --> 663                     return opti1_rate_control.A1(self, control_, target_state_, c_scheme_, u_mat_, u_scheme_, max_iteration_,
#     664                                                 tolerance_, startStep_, max_control_, min_control_, t_sim_, t_sim_pre_, t_sim_post_, CGVar,
#     665                                                 line_search_, control_variables_, prec_variables_, separate_comp, transition_time_)
#
# ~/Promotion/neurolib/neurolib/utils/A1_aln_rate_control.py in A1(model, control_, target_state, c_scheme_, u_mat_, u_scheme_, max_iteration_, tolerance_, startStep_, cntrl_max_, cntrl_min_, t_sim_, t_sim_pre_, t_sim_post_, CGVar, line_search_, control_variables_, prec_variables_, separate_comp, transition_time_)
#     260             f_p_grad_t_ = cost.cost_precision_gradient_t(N, V_target, state0_[:,:2,ind_time], target_state_[:,:,ind_time], ip_, transition_time_)
#     261             for v in prec_variables:
# --> 262                 full_cost_grad[0,v,ind_time] = f_p_grad_t_[0,v]
#     263
#     264             rd_exc[0,0, ind_time] = state0_[0,0,ind_time] * 1e-3
#
# KeyboardInterrupt:

# %%
file_init = '1_I_init.pickle'

with open(file_init,'wb') as f:
    pickle.dump([bestControl_, bestState_, cost_, costnode_, weights_], f)

# %%
#for i in i_range:
for i in i_range:
    if i in bad:
        continue
        
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    aln.params.duration = dur
    max_it = int(0)
    
    for l in range( bestControl_[i][j].shape[2] ):
        if np.abs(bestControl_[i][j][0,0,l]) > 5. * 1e-6 or np.abs(bestControl_[i][j][0,1,l]) > 5. * 1e-6:
            init_ind = l
            break
            
    print("init ind = ", init_ind)

    weight_ = 1.
    cost.setParams(1., weight_ * factor_we, weight_ * factor_ws)
    weights_[i][j] = cost.getParams()

    setinit(initVars[i], aln)

    target_ = aln.getZeroTarget()
    target_[:,0,:] = target[i][0]
    target_[:,1,:] = target[i][1]

    control0 = aln.getZeroControl()
    control0[:,:,:-init_ind] = bestControl_[i][0][:,:,n_pre-1+init_ind:-n_post+1]

    bestControl_[i][j], bestState_[i][j], cost_[i][j], runtime_, grad_, phi_, phi1_, costnode_[i][j] = aln.A1(
        control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
        prec_variables_ = p_var, transition_time_ = t_pen[j])

    print('uncontrolled cost : ', cost_uncontrolled[i])
    print('cost splitting : ', costnode_[i][j][0][0][0], costnode_[i][j][2][0][:2])

    time_ = np.arange(-dur_pre,round(dur+dur_post+aln.params.dt,1),aln.params.dt)
    target_ = aln.getZeroTarget()
    target_[:,0,:] = target[i][0]
    target_[:,1,:] = target[i][1]

    if True:
        fig, ax = plt.subplots(2,1, constrained_layout=True, figsize = (4,4) )
        ax[1].plot(time_, bestControl_[i][j][0,0,:], color = 'red')
        ax[0].plot(time_, bestState_[i][j][0,0,:], color= 'red')
        ax[1].plot(time_, bestControl_[i][j][0,1,:], color = 'blue')
        ax[0].plot(time_, bestState_[i][j][0,1,:], color= 'blue')
        ax[0].plot(time_, target_[0,0,:], linestyle = '--', color='red')
        ax[0].plot(time_, target_[0,1,:], linestyle = '--', color='blue')
        ax[0].set_xlim(-dur_pre,dur+dur_post)
        ax[1].set_xlim(-dur_pre,dur+dur_post)
        ax[0].axvspan(dur*t_pen[j], dur, alpha=0.2, color='gray')
        plt.show()

    with open(file_,'wb') as f:
        pickle.dump([bestControl_, bestState_, cost_, costnode_, weights_], f)
# Out:
# -------  0 0.4000000000000001 0.3500000000000001
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_63766/1908962923.py in <module>
#      11     max_it = int(0)
#      12
# ---> 13     for l in range( bestControl_[i][j].shape[2] ):
#      14         if np.abs(bestControl_[i][j][0,0,l]) > 5. * 1e-6 or np.abs(bestControl_[i][j][0,1,l]) > 5. * 1e-6:
#      15             init_ind = l
#
# IndexError: index 19 is out of bounds for axis 0 with size 1

# %%
c_var = [0,1]

#for i in i_range:
for i in i_range:
    if i in bad:
        continue
        
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    dur = d_array[0]    
    aln.params.duration = dur
    max_it = int(30)
    k = 0
    
    while not conv_shift[i]:
        if k > 0:
            break
            
        weight_ = 1.
        cost.setParams(1., weight_ * factor_we, weight_ * factor_ws)
        weights_[i] = cost.getParams()

        setinit(initVars[i], aln)

        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        control0 = aln.getZeroControl()
        control0 = bestControl_[i][:,:,n_pre-1:-n_post+1]

        bestControl_[i], bestState_[i], cost_[i], runtime_, grad_, phi_, phi1_, costnode_[i] = aln.A1(
            control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
            prec_variables_ = p_var, transition_time_ = t_pen[0])
        
        if cost_[i][2] == 0.:
            conv_shift[i] = True

        print('uncontrolled cost : ', cost_uncontrolled[i])
        print('cost splitting : ', costnode_[i][0][0][0], costnode_[i][2][0][:2])

        if False:
            time_ = np.arange(-dur_pre,round(dur+dur_post+aln.params.dt,1),aln.params.dt)
            target_ = aln.getZeroTarget()
            target_[:,0,:] = target[i][0]
            target_[:,1,:] = target[i][1]

            fig, ax = plt.subplots(2,1, constrained_layout=True, figsize = (4,4) )
            ax[1].plot(time_, bestControl_[i][0,0,:], color = 'red')
            ax[0].plot(time_, bestState_[i][0,0,:], color= 'red')
            ax[1].plot(time_, bestControl_[i][0,1,:], color = 'blue')
            ax[0].plot(time_, bestState_[i][0,1,:], color= 'blue')
            ax[0].plot(time_, target_[0,0,:], linestyle = '--', color='red')
            ax[0].plot(time_, target_[0,1,:], linestyle = '--', color='blue')
            ax[0].set_xlim(-dur_pre,dur+dur_post)
            ax[1].set_xlim(-dur_pre,dur+dur_post)
            ax[0].axvspan(dur*t_pen[0], dur, alpha=0.2, color='gray')
            plt.show()

        with open(file_,'wb') as f:
            pickle.dump([bestControl_, bestState_, cost_, costnode_, weights_], f)
        
        k += 1
# Out:
# -------  0 0.4000000000000001 0.3500000000000001
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  1047.525373712097
# RUN  0 , total integrated cost =  1047.525373712097
# Gradient descend method:  None
# RUN  1 , total integrated cost =  1.155112937830208
# RUN  2 , total integrated cost =  1.1426215336114833
# RUN  3 , total integrated cost =  1.1401981653646946
# RUN  4 , total integrated cost =  1.1381795198654883
# RUN  5 , total integrated cost =  1.1362768675676342
# RUN  6 , total integrated cost =  1.134442515700412
# RUN  7 , total integrated cost =  1.13263181194455
# RUN  8 , total integrated cost =  1.1307196030086242
# RUN  9 , total integrated cost =  1.1288413795010037
# RUN  10 , total integrated cost =  1.1267739913603179
# RUN  11 , total integrated cost =  1.1246323119760238
# RUN  12 , total integrated cost =  1.1222724902110335
# RUN  13 , total integrated cost =  1.1199878343487133
# RUN  14 , total integrated cost =  1.1180300964911538
# RUN  15 , total integrated cost =  1.1160222007306715
# RUN  16 , total integrated cost =  1.1140431016574537
# RUN  17 , total integrated cost =  1.1120054225582898
# RUN  18 , total integrated cost =  1.1102825831250864
# RUN  19 , total integrated cost =  1.1086143674649391
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_63766/1900249334.py in <module>
#      32         control0 = bestControl_[i][:,:,n_pre-1:-n_post+1]
#      33
# ---> 34         bestControl_[i], bestState_[i], cost_[i], runtime_, grad_, phi_, phi1_, costnode_[i] = aln.A1(
#      35             control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
#      36             startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
#
# ~/Promotion/neurolib/neurolib/models/model.py in A1(self, control_, target_state_, c_scheme_, u_mat_, u_scheme_, max_iteration_, tolerance_, startStep_, max_control_, min_control_, t_sim_, t_sim_pre_, t_sim_post_, CGVar, line_search_, control_variables_, prec_variables_, separate_comp, transition_time_, noise_real, init_params)
#     661             if self.params.N == 1:
#     662                 if noise_real == 0:
# --> 663                     return opti1_rate_control.A1(self, control_, target_state_, c_scheme_, u_mat_, u_scheme_, max_iteration_,
#     664                                                 tolerance_, startStep_, max_control_, min_control_, t_sim_, t_sim_pre_, t_sim_post_, CGVar,
#     665                                                 line_search_, control_variables_, prec_variables_, separate_comp, transition_time_)
#
# ~/Promotion/neurolib/neurolib/utils/A1_aln_rate_control.py in A1(model, control_, target_state, c_scheme_, u_mat_, u_scheme_, max_iteration_, tolerance_, startStep_, cntrl_max_, cntrl_min_, t_sim_, t_sim_pre_, t_sim_post_, CGVar, line_search_, control_variables_, prec_variables_, separate_comp, transition_time_)
#     398                 d_inh[:,2:,:] = 0.
#     399
# --> 400                 s_inh, tc_inh, startstep_inh_ = line_search_func(model, N, n_control_vars, T, dt, state1_[:,:2,:], target_state_,
#     401                              best_control_, d_inh, ip_, ie_, is_, start_step_ = startstep_inh_, max_it_ = 500,
#     402                              max_control_ = cntrl_max_, min_control_ = cntrl_min_, tolerance_ = tolerance_step, variables_ = prec_variables, grad_ = grad1_)
#
# ~/Promotion/neurolib/neurolib/utils/func_optimize.py in step_size(model, N, V, T, dt, state_, target_, control_, dir_, ip_, ie_, is_, start_step_, max_it_, bisec_factor_, max_control_, min_control_, tolerance_, substep_, variables_, alg, control_parameter, grad_, noise_real, init_vars, startind_)
#     233                 #print(init_vars)
#     234                 set_init(model, init_vars, model.init_vars, model.state_vars, startind_)
# --> 235             state1_ = updateState(model, test_control_)
#     236             cost1_int_ = cost.f_int(N, V, T, dt, state1_, target_, test_control_, ip_, ie_, is_, v_ = variables_)
#     237         else:
#
# ~/Promotion/neurolib/neurolib/utils/func_optimize.py in updateState(model, control_)
#       8     state_ = model.getZeroState()
#       9     output_vars = model.output_vars
# ---> 10     model.run(control = control_)
#      11     for i in range(len(output_vars)):
#      12         state_[:,i,:] = model[output_vars[i]][:,:]
#
# ~/Promotion/neurolib/neurolib/models/model.py in run(self, inputs, chunkwise, chunksize, bold, append, append_outputs, continue_run, control)
#     182
#     183         if chunkwise is False:
# --> 184             self.integrate(append_outputs=append, simulate_bold=bold, control=cntrl)
#     185             if continue_run:
#     186                 self.setInitialValuesToLastState()
#
# ~/Promotion/neurolib/neurolib/models/model.py in integrate(self, append_outputs, simulate_bold, control)
#     223         # run integration
#     224         #print("before integration")
# --> 225         t, *variables = self.integration(self.params, control=control)
#     226         #print("after integration")
#     227         self.storeOutputsAndStates(t, variables, append=append_outputs)
#
# ~/Promotion/neurolib/neurolib/models/aln/timeIntegration.py in timeIntegration(params, control)
#     281     # ------------------------------------------------------------------------
#     282
# --> 283     return timeIntegration_njit_elementwise(
#     284         dt,
#     285         duration,
#
# KeyboardInterrupt:

# %%
for i in range(10):
    dur = d_array[0]    
    aln.params.duration = dur + 20
    time_ = np.arange(-dur_pre,round(dur+dur_post+aln.params.dt,1),aln.params.dt)
    target_ = aln.getZeroTarget()
    target_[:,0,:] = target[i][0]
    target_[:,1,:] = target[i][1]

    fig, ax = plt.subplots(2,1, constrained_layout=True, figsize = (4,4) )
    ax[1].plot(time_, bestControl_[i][0,0,:], color = 'red')
    ax[0].plot(time_, bestState_[i][0,0,:], color= 'red')
    ax[1].plot(time_, bestControl_[i][0,1,:], color = 'blue')
    ax[0].plot(time_, bestState_[i][0,1,:], color= 'blue')
    ax[0].plot(time_, target_[0,0,:], linestyle = '--', color='red')
    ax[0].plot(time_, target_[0,1,:], linestyle = '--', color='blue')
    ax[0].set_xlim(-dur_pre,dur+dur_post)
    ax[1].set_xlim(-dur_pre,dur+dur_post)
    ax[0].axvspan(dur*t_pen[0], dur, alpha=0.2, color='gray')
    plt.show()
