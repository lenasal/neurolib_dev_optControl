# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import sys
import pickle

path = os.getcwd().split(os.sep + 'GUI')[0]
if path not in sys.path:
    print("not here")
    sys.path.append(path)

from neurolib.models.aln import ALNModel
from neurolib.utils import plotFunctions as plotFunc
from neurolib.utils import costFunctions as cost
import neurolib.dashboard.functions as functions
import neurolib.dashboard.data as data
    
# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2 

#path = os.path.join(os.getcwd(), "plots")
# Out:
# not here

# %%
# read case
print(os.getcwd())
case = os.getcwd().split(os.sep)[-1]
print(case)
grid_data_file = os.path.join(os.getcwd().split('data')[0], 'bi.pickle')
print(grid_data_file)
with open(grid_data_file,'rb') as f:
    load_array= pickle.load(f)
exc = load_array[0]
inh = load_array[1]
print(len(exc))
# Out:
# /home/lena/Promotion/neurolib/GUI/current/gui/data_2/1
# 1
# /home/lena/Promotion/neurolib/GUI/current/gui/bi.pickle
# 147

# %% [markdown]
# ### Bistability

# %%
aln = ALNModel()
N = aln.params.N

data.set_parameters(aln)

state_vars = aln.state_vars
init_vars = aln.init_vars

##############################################################
def setinit(init_vars_, model):
    state_vars = model.state_vars
    init_vars = model.init_vars
    for iv in range(len(init_vars)):
        for sv in range(len(state_vars)):
            if state_vars[sv] in init_vars[iv]:
                #print("set init vars ", )
                if model.params[init_vars[iv]].ndim == 2:
                    model.params[init_vars[iv]][0,:] = init_vars_[sv]
                else:
                    model.params[init_vars[iv]][0] = init_vars_[sv]
                    
##############################################################               
def setmaxmincontrol(max_c_c, min_c_c, max_c_r, min_c_r):
    import numpy as np
    
    max_cntrl = np.zeros(( 6 ))
    min_cntrl = np.zeros(( 6 ))
    
    max_cntrl[0] = max_c_c
    min_cntrl[0] = min_c_c
    max_cntrl[1] = max_c_c
    min_cntrl[1] = min_c_c
    max_cntrl[2] = max_c_r
    min_cntrl[2] = min_c_r
    max_cntrl[3] = max_c_r
    min_cntrl[3] = min_c_r
    max_cntrl[4] = max_c_r
    min_cntrl[4] = min_c_r
    max_cntrl[5] = max_c_r
    min_cntrl[5] = min_c_r
            
    return max_cntrl, min_cntrl

# %%
d_array = np.arange(200, 402, 1)
t0_array = d_array - 20.
t_pen = np.zeros(( t0_array.shape ))
for i in range(len(t_pen)):
    t_pen[i] = t0_array[i] / d_array[i]

bestControl_ = np.array( [[None] * len(t_pen)] * len(exc) )
bestState_ = np.array( [[None] * len(t_pen)] * len(exc) )
cost_ = np.array( [[None] * len(t_pen)] * len(exc) )
costnode_ = np.array( [[None] * len(t_pen)] * len(exc) )
weights_ = np.array( [[None] * len(t_pen)] * len(exc) )
convergence_ = np.array( [[None] * len(t_pen)] * len(exc) )

initVars = [None] * len(exc)
target = [None] * len(exc)
cost_uncontrolled = [None] * len(exc)

print(bestControl_.shape)
# Out:
# (147, 202)

# %%
dur_pre = 10
dur_post = 10

n_pre = int(np.around(dur_pre/aln.params.dt + 1.,1))
n_post = int(np.around(dur_post/aln.params.dt + 1.,1))

tol = 1e-32
start_step = 10.
c_scheme = np.zeros(( 1,1 ))
c_scheme[0,0] = 1.
u_mat = np.identity(1)
u_scheme = np.array([[1.]])

c_var = [0,1]
p_var = [0]

if case in ['1', '2']:    # low to high
    max_I = [3., -3.]
else:
    max_I = [-3., 3.]
    
if case in ['1', '3']:    # sparsity
    factor_ws = 1.
    factor_we = 0.
else:
    factor_ws = 0.
    factor_we = 1.
    
maxC = [5., -5., 0.18, 0.]
max_cntrl, min_cntrl = setmaxmincontrol(maxC[0], maxC[1], maxC[2], maxC[3])

# %%
file_ = '1.pickle'

# %%
if os.path.isfile(file_) :
    print("file found")
    
    with open(file_,'rb') as f:
        load_array = pickle.load(f)

    bestControl_ = load_array[0]
    bestState_ = load_array[1]
    cost_ = load_array[2]
    costnode_ = load_array[3]
    weights_ = load_array[4]
# Out:
# file found

# %%
# get initial parameters and target states

i_stepsize = 20
limit = 150
start_index = 0
i_range = range(start_index, limit,i_stepsize)
i_range = [20]

data.set_parameters(aln)

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    aln.params.duration = 3000.
    
    control0 = aln.getZeroControl()
    control0 = functions.step_control(aln, maxI_ = max_I[0])

    aln.run(control=control0)
    
    target_rates = np.zeros((2))
    target_rates[0] = aln.rates_exc[0,-1] 
    target_rates[1] = aln.rates_inh[0,-1]

    control0 = functions.step_control(aln, maxI_ = max_I[1])
    aln.run(control=control0)

    init_state_vars = np.zeros(( len(state_vars) ))
    for j in range(len(state_vars)):
        if aln.state[state_vars[j]].size == 1:
            init_state_vars[j] = aln.state[state_vars[j]][0]
        else:
            init_state_vars[j] = aln.state[state_vars[j]][0,-1]

    initVars[i] = init_state_vars
    target[i] = [target_rates[0], target_rates[1]]
# Out:
# -------  20 0.4500000000000001 0.4750000000000002

# %%
# get uncontrolled cost

data.set_parameters(aln)

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    dur = d_array[0]
    aln.params.duration = dur
    
    target_ = aln.getZeroTarget()
    target_[:,0,:] = target[i][0]
    target_[:,1,:] = target[i][1]
        
    cost.setParams(1.0, 0.0, 0.0)

    setinit(initVars[i], aln)
    control0 = aln.getZeroControl()

    # "HS", "FR", "PR", "HZ"
    cgv = None
    max_it = 0

    bestControl_init_, bestState_init_, cost_init_, runtime_init_, grad_init_, phi_init_, costnode_init_ = aln.A1(
        control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
        prec_variables_ = p_var, transition_time_ = 0.)
    
    cost_uncontrolled[i] = cost_init_[0]
# Out:
# -------  20 0.4500000000000001 0.4750000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  127444.85508496055
# Gradient descend method:  None
# RUN  0 , total integrated cost =  127444.85508496055
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.

# %%
cgv = None
j = 0
k = 0

while k < 10:
    print('-------------------------------------------- k = ', k)

    for i in i_range:
        print("------- ", i, exc[i], inh[i])
        aln.params.ext_exc_current = exc[i] * 5.
        aln.params.ext_inh_current = inh[i] * 5.

        if convergence_[i][j] == True:
            print('converged')
            continue

        dur = d_array[0]
        aln.params.duration = dur
        
        setinit(initVars[i], aln)

        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        max_it = int(10)

        if type(bestControl_[i][j]) == type(None) or np.amax(np.abs(bestControl_[i][j])) < 1e-6:
            print('no solution found')
            control0 = aln.getZeroControl()
            #control0[0,0,:50] = 5.
            cost.setParams(1.0, 0., 1.)
            max_it = int(1)
            weights_[i][j] = [1., 0., 1.]
        else:
            control0 = bestControl_[i][j][:,:,n_pre-1:-n_post+1]
            l = 1
            while cost_[i][j][-l] == 0.:
                l += 1

            weight_ = ( cost_uncontrolled[i] - costnode_[i][j][0][0][0] ) / sum( costnode_[i][j][2][0][:] )
                
            print("weight = ", weight_)
            cost.setParams(1.0, weight_ * factor_we, weight_ * factor_ws)
            weights_[i][j] = cost.getParams()

        bestControl_[i][j], bestState_[i][j], cost_[i][j], runtime_, grad_, phi_, costnode_[i][j] = aln.A1(
            control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
            prec_variables_ = p_var, transition_time_ = t_pen[j])

        #if cost_[i][j][2] == 0.:
        #    print('converged')
        #    convergence_[i][j] = True

        print('uncontrolled cost : ', cost_uncontrolled[i])
        print('cost splitting : ', costnode_[i][j][0][0][0], costnode_[i][j][2][0][:2])

        time_ = np.arange(-dur_pre,dur+dur_post+aln.params.dt,aln.params.dt)
        dur += dur_pre + dur_post
        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        if True:
            fig, ax = plt.subplots(2,1, constrained_layout=True, figsize = (4,4) )
            ax[1].plot(time_, bestControl_[i][j][0,0,:], color = 'red')
            ax[0].plot(time_, bestState_[i][j][0,0,:], color= 'red')
            ax[1].plot(time_, bestControl_[i][j][0,1,:], color = 'blue')
            ax[0].plot(time_, bestState_[i][j][0,1,:], color= 'blue')
            ax[0].plot(time_, target_[0,0,:], linestyle = '--', color='red')
            ax[0].plot(time_, target_[0,1,:], linestyle = '--', color='blue')
            ax[0].set_xlim(-dur_pre,dur-dur_post)
            ax[1].set_xlim(-dur_pre,dur-dur_post)
            ax[0].axvspan(t0_array[0], dur, alpha=0.2, color='gray')
            plt.show()

        with open(file_,'wb') as f:
            pickle.dump([bestControl_, bestState_, cost_, costnode_, weights_], f)
    
    k += 1
# Out:
# -------------------------------------------- k =  0
# -------  20 0.4500000000000001 0.4750000000000002
# no solution found
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  126810.80107956976
# Gradient descend method:  None
# RUN  1 , total integrated cost =  16367.04249982331
# RUN  1 , total integrated cost =  16367.04249982331
# Improved over  1  iterations in  0.06688980100443587  seconds by  87.09333719171642  percent.
# uncontrolled cost :  127444.85508496055
# cost splitting :  16362.10575487578 [0.         4.93674495]
# -------------------------------------------- k =  1
# -------  20 0.4500000000000001 0.4750000000000002
# weight =  22501.212947134958
# set cost params:  1.0 0.0 22501.212947134958
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  127444.85508496055
# Gradient descend method:  None
# RUN  1 , total integrated cost =  121924.52119675213
# RUN  2 , total integrated cost =  121725.4061178522
# RUN  3 , total integrated cost =  121579.71137601792
# RUN  4 , total integrated cost =  121579.64778535024
# RUN  5 , total integrated cost =  121579.6477853502
# RUN  6 , total integrated cost =  121579.64778535016
# RUN  7 , total integrated cost =  121579.64778535016
# Control only changes marginally.
# RUN  7 , total integrated cost =  121579.64778535016
# Improved over  7  iterations in  1.217338819988072  seconds by  4.602153061181156  percent.
# uncontrolled cost :  127444.85508496055
# cost splitting :  19053.246565502603 [0.15386166 4.40262165]
# -------------------------------------------- k =  2
# -------  20 0.4500000000000001 0.4750000000000002
# weight =  23788.435329442433
# set cost params:  1.0 0.0 23788.435329442433
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  127444.85508496057
# Gradient descend method:  None
# RUN  1 , total integrated cost =  127435.06207937645
# RUN  2 , total integrated cost =  127435.06207937635
# RUN  3 , total integrated cost =  127435.06207937634
# RUN  4 , total integrated cost =  127435.06207937632
# RUN  5 , total integrated cost =  127435.06207937632
# Control only changes marginally.
# RUN  5 , total integrated cost =  127435.06207937632
# Improved over  5  iterations in  1.0548071640077978  seconds by  0.007684112142243293  percent.
# uncontrolled cost :  127444.85508496055
# cost splitting :  19464.505034368005 [0.15386166 4.38492181]
# -------------------------------------------- k =  3
# -------  20 0.4500000000000001 0.4750000000000002
# weight =  23790.59295728466
# set cost params:  1.0 0.0 23790.59295728466
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  127444.85508496055
# Gradient descend method:  None
# RUN  1 , total integrated cost =  127444.85508496055
# Control only changes marginally.
# RUN  1 , total integrated cost =  127444.85508496055
# Improved over  1  iterations in  0.31360528100049123  seconds by  0.0  percent.
# uncontrolled cost :  127444.85508496055
# cost splitting :  19464.505034368005 [0.15386166 4.38492181]
# -------------------------------------------- k =  4
# -------  20 0.4500000000000001 0.4750000000000002
# weight =  23790.59295728466
# set cost params:  1.0 0.0 23790.59295728466
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  127444.85508496055
# Gradient descend method:  None
# RUN  1 , total integrated cost =  127444.85508496055
# Control only changes marginally.
# RUN  1 , total integrated cost =  127444.85508496055
# Improved over  1  iterations in  0.31960421398980543  seconds by  0.0  percent.
# uncontrolled cost :  127444.85508496055
# cost splitting :  19464.505034368005 [0.15386166 4.38492181]
# -------------------------------------------- k =  5
# -------  20 0.4500000000000001 0.4750000000000002
# weight =  23790.59295728466
# set cost params:  1.0 0.0 23790.59295728466
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  127444.85508496055
# Gradient descend method:  None
# RUN  1 , total integrated cost =  127444.85508496055
# Control only changes marginally.
# RUN  1 , total integrated cost =  127444.85508496055
# Improved over  1  iterations in  0.2962769690202549  seconds by  0.0  percent.
# uncontrolled cost :  127444.85508496055
# cost splitting :  19464.505034368005 [0.15386166 4.38492181]
# -------------------------------------------- k =  6
# -------  20 0.4500000000000001 0.4750000000000002
# weight =  23790.59295728466
# set cost params:  1.0 0.0 23790.59295728466
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  127444.85508496055
# Gradient descend method:  None
# RUN  1 , total integrated cost =  127444.85508496055
# Control only changes marginally.
# RUN  1 , total integrated cost =  127444.85508496055
# Improved over  1  iterations in  0.298788727959618  seconds by  0.0  percent.
# uncontrolled cost :  127444.85508496055
# cost splitting :  19464.505034368005 [0.15386166 4.38492181]
# -------------------------------------------- k =  7
# -------  20 0.4500000000000001 0.4750000000000002
# weight =  23790.59295728466
# set cost params:  1.0 0.0 23790.59295728466
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  127444.85508496055
# Gradient descend method:  None
# RUN  1 , total integrated cost =  127444.85508496055
# Control only changes marginally.
# RUN  1 , total integrated cost =  127444.85508496055
# Improved over  1  iterations in  0.29037417203653604  seconds by  0.0  percent.
# uncontrolled cost :  127444.85508496055
# cost splitting :  19464.505034368005 [0.15386166 4.38492181]
# -------------------------------------------- k =  8
# -------  20 0.4500000000000001 0.4750000000000002
# weight =  23790.59295728466
# set cost params:  1.0 0.0 23790.59295728466
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  127444.85508496055
# Gradient descend method:  None
# RUN  1 , total integrated cost =  127444.85508496055
# Control only changes marginally.
# RUN  1 , total integrated cost =  127444.85508496055
# Improved over  1  iterations in  0.3048816649825312  seconds by  0.0  percent.
# uncontrolled cost :  127444.85508496055
# cost splitting :  19464.505034368005 [0.15386166 4.38492181]
# -------------------------------------------- k =  9
# -------  20 0.4500000000000001 0.4750000000000002
# weight =  23790.59295728466
# set cost params:  1.0 0.0 23790.59295728466
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  127444.85508496055
# Gradient descend method:  None
# RUN  1 , total integrated cost =  127444.85508496055
# Control only changes marginally.
# RUN  1 , total integrated cost =  127444.85508496055
# Improved over  1  iterations in  0.29026381100993603  seconds by  0.0  percent.
# uncontrolled cost :  127444.85508496055
# cost splitting :  19464.505034368005 [0.15386166 4.38492181]

# %%
print(bestControl_[20][0][:,0,n_pre-1:n_pre+5])
print(bestControl_[20][0][:,1,n_pre-1:n_pre+5])
# Out:
# [[0.00000000e+00 6.24641869e-08 6.27596847e-08 6.30565805e-08
#   6.33548808e-08 6.36545922e-08]]
# [[ 0.00000000e+00 -2.17226933e-06 -2.18254564e-06 -2.19287056e-06
#   -2.20324432e-06 -2.21366716e-06]]

# %%
cgv = None
j = 0

for i in i_range:
    
    bestControl_[i][0] = None
    convergence_[i][0] = None
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.

    dur = d_array[0]
    aln.params.duration = dur
        
    setinit(initVars[i], aln)

    target_ = aln.getZeroTarget()
    target_[:,0,:] = target[i][0]
    target_[:,1,:] = target[i][1]

    control0 = aln.getZeroControl()
    max_it = int(1)

    for w in np.arange(10):
        cost.setParams(1.0, 0., w)
        weights_[i][j] = cost.getParams()

        bestControl_[i][j], bestState_[i][j], cost_[i][j], runtime_, grad_, phi_, costnode_[i][j] = aln.A1(
            control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
            prec_variables_ = p_var, transition_time_ = t_pen[j])
        
        if True:
            time_ = np.arange(-dur_pre,dur+dur_post+aln.params.dt,aln.params.dt)
            dur_plot = dur + dur_pre + dur_post
            target_ = aln.getZeroTarget()
            target_[:,0,:] = target[i][0]
            target_[:,1,:] = target[i][1]
            
            fig, ax = plt.subplots(2,1, constrained_layout=True, figsize = (4,4) )
            ax[1].plot(time_, bestControl_[i][j][0,0,:], color = 'red')
            ax[0].plot(time_, bestState_[i][j][0,0,:], color= 'red')
            ax[1].plot(time_, bestControl_[i][j][0,1,:], color = 'blue')
            ax[0].plot(time_, bestState_[i][j][0,1,:], color= 'blue')
            ax[0].plot(time_, target_[0,0,:], linestyle = '--', color='red')
            ax[0].plot(time_, target_[0,1,:], linestyle = '--', color='blue')
            ax[0].set_xlim(-dur_pre,dur-dur_post)
            ax[1].set_xlim(-dur_pre,dur-dur_post)
            ax[0].axvspan(t0_array[0], t0_array[0]+20, alpha=0.2, color='gray')
            plt.show()

        control0 = bestControl_[i][j][:,:,n_pre-1:-n_post+1]

    print('uncontrolled cost : ', cost_uncontrolled[i])
    print('cost splitting : ', costnode_[i][j][0][0][0], costnode_[i][j][2][0][:2])

    control0[:,:,:] = bestControl_[i][j][:,:,n_pre-1:-n_post+1]

    time_ = np.arange(-dur_pre,dur+dur_post+aln.params.dt,aln.params.dt)
    dur_plot = dur + dur_pre + dur_post
    target_ = aln.getZeroTarget()
    target_[:,0,:] = target[i][0]
    target_[:,1,:] = target[i][1]

    if True:
        fig, ax = plt.subplots(2,1, constrained_layout=True, figsize = (4,4) )
        ax[1].plot(time_, bestControl_[i][j][0,0,:], color = 'red')
        ax[0].plot(time_, bestState_[i][j][0,0,:], color= 'red')
        ax[1].plot(time_, bestControl_[i][j][0,1,:], color = 'blue')
        ax[0].plot(time_, bestState_[i][j][0,1,:], color= 'blue')
        ax[0].plot(time_, target_[0,0,:], linestyle = '--', color='red')
        ax[0].plot(time_, target_[0,1,:], linestyle = '--', color='blue')
        ax[0].set_xlim(-dur_pre,dur-dur_post)
        ax[1].set_xlim(-dur_pre,dur-dur_post)
        ax[0].axvspan(t0_array[0], t0_array[0]+20, alpha=0.2, color='gray')
        plt.show()

    with open(file_,'wb') as f:
        pickle.dump([bestControl_, bestState_, cost_, costnode_, weights_], f)
# Out:
# -------  20 0.4500000000000001 0.4750000000000002
# set cost params:  1.0 0.0 0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  126810.80107956976
# Gradient descend method:  None
# RUN  1 , total integrated cost =  16362.10575487578
# RUN  1 , total integrated cost =  16362.10575487578
# Improved over  1  iterations in  0.061679064005147666  seconds by  87.09723019208035  percent.
# ERROR:root:Wrong dimension in control array input
# set cost params:  1.0 0.0 1
# interpolate adjoint :  True True True
# 1 1
# 6 6
# 2001 2201
# RUN  0 , total integrated cost =  914.7124640365287
# Gradient descend method:  None
# WARNING: sigma i smaller zero
# WARNING: sigma i smaller zero
# WARNING: sigma i smaller zero
# WARNING: sigma i smaller zero
# WARNING: sigma i smaller zero
# WARNING: sigma i smaller zero
# WARNING: sigma i smaller zero
# WARNING: sigma i smaller zero
# WARNING: sigma i smaller zero
# WARNING: sigma i smaller zero
# WARNING: sigma i smaller zero
# WARNING: sigma i smaller zero
# WARNING: sigma i smaller zero
# WARNING: sigma i smaller zero
# WARNING: sigma i smaller zero
# WARNING: sigma i smaller zero
# WARNING: sigma i smaller zero
# WARNING: sigma i smaller zero
# WARNING: sigma i smaller zero
# WARNING: sigma i smaller zero
# WARNING: sigma i smaller zero
# WARNING: sigma i smaller zero
# WARNING: sigma i smaller zero
# WARNING: sigma i smaller zero
# WARNING: sigma i smaller zero
# WARNING: sigma i smaller zero
# WARNING: sigma i smaller zero
# WARNING: sigma i smaller zero
# WARNING: sigma i smaller zero
# WARNING: sigma i smaller zero
# WARNING: sigma i smaller zero
# WARNING: sigma i smaller zero
# WARNING: sigma i smaller zero
# WARNING: sigma i smaller zero
# WARNING: sigma i smaller zero
# WARNING: sigma i smaller zero
# WARNING: sigma i smaller zero
# WARNING: sigma i smaller zero
# WARNING: sigma i smaller zero
# WARNING: sigma i smaller zero
# WARNING: sigma i smaller zero
# WARNING: sigma i smaller zero
# WARNING: sigma i smaller zero
# WARNING: sigma i smaller zero
# WARNING: sigma i smaller zero
# WARNING: sigma i smaller zero
# WARNING: sigma i smaller zero
# WARNING: sigma i smaller zero
# WARNING: sigma i smaller zero
# WARNING: sigma i smaller zero
# WARNING: sigma i smaller zero
# WARNING: sigma i smaller zero
# WARNING: sigma i smaller zero
# WARNING: sigma i smaller zero
# WARNING: sigma i smaller zero
# WARNING: sigma i smaller zero
# WARNING: sigma i smaller zero
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_206155/2332693941.py in <module>
#      26         weights_[i][j] = cost.getParams()
#      27
# ---> 28         bestControl_[i][j], bestState_[i][j], cost_[i][j], runtime_, grad_, phi_, costnode_[i][j] = aln.A1(
#      29             control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
#      30             startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
#
# ~/Promotion/neurolib/neurolib/models/model.py in A1(self, control_, target_state_, c_scheme_, u_mat_, u_scheme_, max_iteration_, tolerance_, startStep_, max_control_, min_control_, t_sim_, t_sim_pre_, t_sim_post_, CGVar, line_search_, control_variables_, prec_variables_, separate_comp, transition_time_, noise_real, init_params)
#     661             if self.params.N == 1:
#     662                 if noise_real == 0:
# --> 663                     return opti1_rate_control.A1(self, control_, target_state_, c_scheme_, u_mat_, u_scheme_, max_iteration_,
#     664                                                 tolerance_, startStep_, max_control_, min_control_, t_sim_, t_sim_pre_, t_sim_post_, CGVar,
#     665                                                 line_search_, control_variables_, prec_variables_, separate_comp, transition_time_)
#
# ~/Promotion/neurolib/neurolib/utils/A1_aln_rate_control.py in A1(model, control_, target_state, c_scheme_, u_mat_, u_scheme_, max_iteration_, tolerance_, startStep_, cntrl_max_, cntrl_min_, t_sim_, t_sim_pre_, t_sim_post_, CGVar, line_search_, control_variables_, prec_variables_, separate_comp, transition_time_)
#     375         #print(phi1_[0,3,:])
#     376
# --> 377         grad1_ = fo.compute_gradient(N, n_control_vars, T, dt, best_control_, grad1_, phi1_, control_variables, ie_, is_)
#     378         dir0_ = fo.set_direction(N, T, n_control_vars, grad0_, grad1_, dir0_, i, CGVar, tolerance_dir)
#     379
#
# ~/Promotion/neurolib/neurolib/utils/func_optimize.py in compute_gradient(N, n_control_vars, T, dt, best_control_, grad1_, phi1_, control_variables, ie_, is_)
#     690 def compute_gradient(N, n_control_vars, T, dt, best_control_, grad1_, phi1_, control_variables, ie_, is_):
#     691     grad_cost_e_ = cost.cost_energy_gradient(best_control_, ie_)
# --> 692     grad_cost_s_ = cost.cost_sparsity_gradient(N, n_control_vars, T, dt, best_control_, is_)
#     693
#     694     for n in range(N):
#
# ~/Promotion/neurolib/neurolib/utils/costFunctions.py in cost_sparsity_gradient(N, V, T, dt, control_, i_s)
#     299 def cost_sparsity_gradient(N, V, T, dt, control_, i_s):
#     300     control_energy = control_energy_components(N, V, T, dt, control_)
# --> 301     cost_gradient_s_ =  numba_cost_sparsity_gradient(N, V, T, i_s, control_, control_energy)
#     302     return cost_gradient_s_
#     303
#
# ValueError: cannot assign slice from input of different size

# %%
for i in range(bestControl_.shape[0]):
    for j in range(0,bestControl_.shape[1]):
        bestControl_[i][j] = None
        convergence_[i][j] = None
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_206155/2768118243.py in <module>
#       2     for j in range(0,bestControl_.shape[1]):
#       3         bestControl_[i][j] = None
# ----> 4         convergence_[i][j] = None
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
cost.setParams(1.0, factor_we, factor_ws)

j_start = 1

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.

    for j in range(j_start,j_start+20):
        print(i,j, '-----------------')
            
        k = 0
        while k < 1:

            if convergence_[i][j] == True:
                print('converged')
                print('uncontrolled cost : ', cost_uncontrolled[i])
                print('cost splitting : ', costnode_[i][j][0][0][0], costnode_[i][j][2][0][:2])
                k += 1
                continue

            dur = d_array[j]
            print('simulation duration : ', dur)
            aln.params.duration = dur
            max_it = int(100)  
            
            setinit(initVars[i], aln)
            target_ = aln.getZeroTarget()
            target_[:,0,:] = target[i][0]
            target_[:,1,:] = target[i][1]

            if type(bestControl_[i][j]) == type(None):
                print('no solution computed yet')
                control0 = aln.getZeroControl()
                control0[:,:,:-10] = bestControl_[i][j-1][:,:,n_pre-1:-n_post+1]
                                
                #for l in [5,4,3,2,1]:
                #    control0[0,0,l] = 2. * control0[0,0,l+1] - control0[0,0,l+2]
                #    control0[0,1,l] = 2. * control0[0,1,l+1] - control0[0,1,l+2]
                                        
                l = 1
                while cost_[i][j-1][-l] == 0.:
                    l += 1
                    
                weight_ = ( cost_uncontrolled[i] - costnode_[i][j-1][0][0][0] ) / sum( costnode_[i][j-1][2][0][:] )
                #weight_ = (factor_we * weights_[i][j-1][1] * cost_uncontrolled[i] / cost_[i][j-1][-l]
                #           + factor_ws * weights_[i][j-1][2] * cost_uncontrolled[i] / cost_[i][j-1][-l]) - 0.1
            else:
                control0 = bestControl_[i][j][:,:,n_pre-1:-n_post+1]
                l = 1
                while cost_[i][j][-l] == 0.:
                    l += 1
                
                weight_ = ( cost_uncontrolled[i] - costnode_[i][j][0][0][0] ) / sum( costnode_[i][j][2][0][:] )
                #weight_ = (factor_we * weights_[i][j][1] * cost_uncontrolled[i] / cost_[i][j][-l]
                #           + factor_ws * weights_[i][j][2] * cost_uncontrolled[i] / cost_[i][j][-l]) - 0.1
                
            print("weight = ", weight_)
            cost.setParams(1.0, weight_ * factor_we, weight_ * factor_ws)
            weights_[i][j] = cost.getParams()

            bestControl_[i][j], bestState_[i][j], cost_[i][j], runtime_, grad_, phi_, costnode_[i][j] = aln.A1(
                control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
                startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
                t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
                prec_variables_ = p_var, transition_time_ = t_pen[j])

            if cost_[i][j][2] == 0.:
                print('converged')
                convergence_[i][j] = True

            print('uncontrolled cost : ', cost_uncontrolled[i])
            print('cost splitting : ', costnode_[i][j][0][0][0], costnode_[i][j][2][0][:2])

            time_ = np.arange(-dur_pre,dur+dur_post+aln.params.dt,aln.params.dt)
            dur += dur_pre + dur_post
            target_ = aln.getZeroTarget()
            target_[:,0,:] = target[i][0]
            target_[:,1,:] = target[i][1]

            if True:
                fig, ax = plt.subplots(2,1, constrained_layout=True, figsize = (4,4) )
                ax[1].plot(time_, bestControl_[i][j][0,0,:], color = 'red')
                ax[0].plot(time_, bestState_[i][j][0,0,:], color= 'red')
                ax[1].plot(time_, bestControl_[i][j][0,1,:], color = 'blue')
                ax[0].plot(time_, bestState_[i][j][0,1,:], color= 'blue')
                ax[0].plot(time_, target_[0,0,:], linestyle = '--', color='red')
                ax[0].plot(time_, target_[0,1,:], linestyle = '--', color='blue')
                ax[0].set_xlim(-dur_pre,dur-dur_post)
                ax[1].set_xlim(-dur_pre,dur-dur_post)
                ax[0].axvspan(t0_array[j], t0_array[j]+20, alpha=0.2, color='gray')
                plt.show()

            with open(file_,'wb') as f:
                pickle.dump([bestControl_, bestState_, cost_, costnode_, weights_], f)
                
            k += 1
# Out:
# set cost params:  1.0 0.0 1.0
# -------  20 0.4500000000000001 0.4750000000000002
# 20 1 -----------------
# simulation duration :  141
# weight =  17529.19144944401
# set cost params:  1.0 0.0 17529.19144944401
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  89230.50573415004
# Gradient descend method:  None
# RUN  1 , total integrated cost =  89226.99724508688
# RUN  2 , total integrated cost =  89226.97537468198
# RUN  3 , total integrated cost =  89226.97071033031
# RUN  4 , total integrated cost =  89226.97071033028
# RUN  5 , total integrated cost =  89226.97071033025
# RUN  6 , total integrated cost =  89226.97071033025
# Control only changes marginally.
# RUN  6 , total integrated cost =  89226.97071033025
# Improved over  6  iterations in  0.7596466669929214  seconds by  0.003961676324365726  percent.
# uncontrolled cost :  89230.50573415004
# cost splitting :  10414.056304572576 [0.17568062 4.32041463]
# 20 2 -----------------
# simulation duration :  142
# weight =  18267.849042227983
# set cost params:  1.0 0.0 18267.849042227983
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  89230.50573415005
# Gradient descend method:  None
# RUN  1 , total integrated cost =  89214.30947177537
# RUN  2 , total integrated cost =  89214.30947177537
# Control only changes marginally.
# RUN  2 , total integrated cost =  89214.30947177537
# Improved over  2  iterations in  0.359261324047111  seconds by  0.018151037295396577  percent.
# uncontrolled cost :  89230.50573415004
# cost splitting :  9588.20485225175 [0.02598217 4.33282901]
# 20 3 -----------------
# simulation duration :  143
# weight =  18984.367368745163
# set cost params:  1.0 0.0 18984.367368745163
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  89230.50573415004
# Gradient descend method:  None
# RUN  1 , total integrated cost =  89230.49095974103
# RUN  2 , total integrated cost =  89230.49095974097
# RUN  3 , total integrated cost =  89230.49095974097
# Control only changes marginally.
# RUN  3 , total integrated cost =  89230.49095974097
# Improved over  3  iterations in  0.5249413829878904  seconds by  1.655757630203425e-05  percent.
# uncontrolled cost :  89230.50573415004
# cost splitting :  6985.853767165191 [3.40888380e-15 4.33222954e+00]
# 20 4 -----------------
# simulation duration :  144
# weight =  19609.028432910767
# set cost params:  1.0 0.0 19609.028432910767
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  89230.50573415004
# Gradient descend method:  None
# RUN  1 , total integrated cost =  89228.2516026229
# RUN  2 , total integrated cost =  89228.24808405977
# RUN  3 , total integrated cost =  89228.24808405971
# RUN  4 , total integrated cost =  89228.24808405968
# RUN  5 , total integrated cost =  89228.24808405968
# Control only changes marginally.
# RUN  5 , total integrated cost =  89228.24808405968
# Improved over  5  iterations in  0.8853342619840987  seconds by  0.0025301325726871937  percent.
# uncontrolled cost :  89230.50573415004
# cost splitting :  5231.466094064835 [2.42020723e-16 4.28357694e+00]
# 20 5 -----------------
# simulation duration :  145
# weight =  20154.23718166938
# set cost params:  1.0 0.0 20154.23718166938
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  89230.50573415004
# Gradient descend method:  None
# RUN  1 , total integrated cost =  89228.77715238572
# RUN  2 , total integrated cost =  89228.77384617359
# RUN  3 , total integrated cost =  89228.77384474152
# RUN  4 , total integrated cost =  89228.77384474018
# RUN  5 , total integrated cost =  89228.77384474012
# RUN  6 , total integrated cost =  89228.77384474012
# Control only changes marginally.
# RUN  6 , total integrated cost =  89228.77384474012
# Improved over  6  iterations in  1.0165096140117384  seconds by  0.001940916277078486  percent.
# uncontrolled cost :  89230.50573415004
# cost splitting :  3973.411154799375 [2.42020723e-16 4.23014585e+00]
# 20 6 -----------------
# simulation duration :  146
# weight =  20620.62549172244
# set cost params:  1.0 0.0 20620.62549172244
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  89230.50573415004
# Gradient descend method:  None
# RUN  1 , total integrated cost =  89229.44048668843
# RUN  2 , total integrated cost =  89229.43983166077
# RUN  3 , total integrated cost =  89229.43983061815
# RUN  4 , total integrated cost =  89229.43983058244
# RUN  5 , total integrated cost =  89229.43983058196
# RUN  6 , total integrated cost =  89229.43983058193
# RUN  7 , total integrated cost =  89229.43983058192
# RUN  8 , total integrated cost =  89229.43983058192
# Control only changes marginally.
# RUN  8 , total integrated cost =  89229.43983058192
# Improved over  8  iterations in  1.3311269980040379  seconds by  0.0011945506296768826  percent.
# uncontrolled cost :  89230.50573415004
# cost splitting :  3098.229072915875 [2.42020723e-16 4.17694462e+00]
# 20 7 -----------------
# simulation duration :  147
# weight =  21012.898961286694
# set cost params:  1.0 0.0 21012.898961286694
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  89230.50573415004
# Gradient descend method:  None
# RUN  1 , total integrated cost =  89229.9428292229
# RUN  2 , total integrated cost =  89229.94261070371
# RUN  3 , total integrated cost =  89229.94260905895
# RUN  4 , total integrated cost =  89229.94260905891
# RUN  5 , total integrated cost =  89229.94260905891
# Control only changes marginally.
# RUN  5 , total integrated cost =  89229.94260905891
# Improved over  5  iterations in  0.8829354519839399  seconds by  0.0006310903277864099  percent.
# uncontrolled cost :  89230.50573415004
# cost splitting :  2537.8621506115037 [2.42020723e-16 4.12566018e+00]
# 20 8 -----------------
# simulation duration :  148
# weight =  21339.496849250885
# set cost params:  1.0 0.0 21339.496849250885
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  89230.50573415004
# Gradient descend method:  None
# RUN  1 , total integrated cost =  89230.28969211529
# RUN  2 , total integrated cost =  89230.28935360786
# RUN  3 , total integrated cost =  89230.2893536078
# RUN  4 , total integrated cost =  89230.2893536077
# RUN  5 , total integrated cost =  89230.2893536077
# Control only changes marginally.
# RUN  5 , total integrated cost =  89230.2893536077
# Improved over  5  iterations in  0.883610549964942  seconds by  0.0002424961514577717  percent.
# uncontrolled cost :  89230.50573415004
# cost splitting :  2226.4495402605885 [2.42020723e-16 4.07712705e+00]
# 20 9 -----------------
# simulation duration :  149
# weight =  21610.325039306226
# set cost params:  1.0 0.0 21610.325039306226
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  89230.50573415004
# Gradient descend method:  None
# RUN  1 , total integrated cost =  89230.49448131466
# RUN  2 , total integrated cost =  89230.49446983077
# RUN  3 , total integrated cost =  89230.49446981993
# RUN  4 , total integrated cost =  89230.49446981988
# RUN  5 , total integrated cost =  89230.49446981988
# Control only changes marginally.
# RUN  5 , total integrated cost =  89230.49446981988
# Improved over  5  iterations in  0.9776176620507613  seconds by  1.262385555378387e-05  percent.
# uncontrolled cost :  89230.50573415004
# cost splitting :  2083.8246226880788 [2.42020723e-16 4.03264040e+00]
# 20 10 -----------------
# simulation duration :  150
# weight =  21837.204444410214
# set cost params:  1.0 0.0 21837.204444410214
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  89230.50573415002
# Gradient descend method:  None
# RUN  1 , total integrated cost =  89230.35491693208
# RUN  2 , total integrated cost =  89230.35491693208
# Control only changes marginally.
# RUN  2 , total integrated cost =  89230.35491693208
# Improved over  2  iterations in  0.4094563139951788  seconds by  0.00016901979508077147  percent.
# uncontrolled cost :  89230.50573415004
# cost splitting :  2034.4928981172245 [2.42020723e-16 3.99299563e+00]
# 20 11 -----------------
# simulation duration :  151
# weight =  22033.118380619857
# set cost params:  1.0 0.0 22033.118380619857
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  89230.50573415002
# Gradient descend method:  None
# RUN  1 , total integrated cost =  89230.43047499901
# RUN  2 , total integrated cost =  89230.43047210437
# RUN  3 , total integrated cost =  89230.4304721043
# RUN  4 , total integrated cost =  89230.4304721043
# Control only changes marginally.
# RUN  4 , total integrated cost =  89230.4304721043
# Improved over  4  iterations in  0.7245625120121986  seconds by  8.434564513493115e-05  percent.
# uncontrolled cost :  89230.50573415004
# cost splitting :  2028.9708468530796 [2.42020723e-16 3.95774480e+00]
# 20 12 -----------------
# simulation duration :  152
# weight =  22210.874270441804
# set cost params:  1.0 0.0 22210.874270441804
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  89230.50573415004
# Gradient descend method:  None
# RUN  1 , total integrated cost =  89230.43148623429
# RUN  2 , total integrated cost =  89230.43148623419
# RUN  3 , total integrated cost =  89230.43148623416
# RUN  4 , total integrated cost =  89230.43148623416
# Control only changes marginally.
# RUN  4 , total integrated cost =  89230.43148623416
# Improved over  4  iterations in  0.7715522110229358  seconds by  8.320911696557687e-05  percent.
# uncontrolled cost :  89230.50573415004
# cost splitting :  2028.1117305667867 [2.70112721e-16 3.92610929e+00]
# 20 13 -----------------
# simulation duration :  153
# weight =  22379.89825311253
# set cost params:  1.0 0.0 22379.89825311253
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  89230.50573415004
# Gradient descend method:  None
# RUN  1 , total integrated cost =  89230.43449579834
# RUN  2 , total integrated cost =  89230.43447764496
# RUN  3 , total integrated cost =  89230.43447762396
# RUN  4 , total integrated cost =  89230.4344776239
# RUN  5 , total integrated cost =  89230.43447762386
# RUN  6 , total integrated cost =  89230.43447762384
# RUN  7 , total integrated cost =  89230.43447762384
# Control only changes marginally.
# RUN  7 , total integrated cost =  89230.43447762384
# Improved over  7  iterations in  1.2593483229866251  seconds by  7.985668759147302e-05  percent.
# uncontrolled cost :  89230.50573415004
# cost splitting :  2013.1557278710886 [1.40932846e-16 3.89712579e+00]
# 20 14 -----------------
# simulation duration :  154
# weight =  22544.793519038263
# set cost params:  1.0 0.0 22544.793519038263
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  89230.50573415004
# Gradient descend method:  None
# RUN  1 , total integrated cost =  89230.44649370943
# RUN  2 , total integrated cost =  89230.44649370939
# RUN  3 , total integrated cost =  89230.44649370939
# Control only changes marginally.
# RUN  3 , total integrated cost =  89230.44649370939
# Improved over  3  iterations in  0.6374197960249148  seconds by  6.639034505440122e-05  percent.
# uncontrolled cost :  89230.50573415004
# cost splitting :  1976.4191661258715 [7.19561600e-17 3.87025178e+00]
# 20 15 -----------------
# simulation duration :  155
# weight =  22705.844791685784
# set cost params:  1.0 0.0 22705.844791685784
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  89230.50573415004
# Gradient descend method:  None
# RUN  1 , total integrated cost =  89230.4453249043
# RUN  2 , total integrated cost =  89230.445258015
# RUN  3 , total integrated cost =  89230.44525801497
# RUN  4 , total integrated cost =  89230.44525801492
# RUN  5 , total integrated cost =  89230.44525801492
# Control only changes marginally.
# RUN  5 , total integrated cost =  89230.44525801492
# Improved over  5  iterations in  0.9737491210107692  seconds by  6.777517914713371e-05  percent.
# uncontrolled cost :  89230.50573415004
# cost splitting :  1932.202210678703 [7.19561600e-17 3.84474763e+00]
# 20 16 -----------------
# simulation duration :  156
# weight =  22861.70713653289
# set cost params:  1.0 0.0 22861.70713653289
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  89230.50573415004
# Gradient descend method:  None
# RUN  1 , total integrated cost =  89230.48029064781
# RUN  2 , total integrated cost =  89230.48029064779
# RUN  3 , total integrated cost =  89230.48029064779
# Control only changes marginally.
# RUN  3 , total integrated cost =  89230.48029064779
# Improved over  3  iterations in  0.663109251006972  seconds by  2.851435397133173e-05  percent.
# uncontrolled cost :  89230.50573415004
# cost splitting :  1881.59028131592 [7.19561600e-17 3.82075098e+00]
# 20 17 -----------------
# simulation duration :  157
# weight =  23011.72490131694
# set cost params:  1.0 0.0 23011.72490131694
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  89230.50573415004
# Gradient descend method:  None
# RUN  1 , total integrated cost =  89230.46357802507
# RUN  2 , total integrated cost =  89230.463578025
# RUN  3 , total integrated cost =  89230.463578025
# Control only changes marginally.
# RUN  3 , total integrated cost =  89230.463578025
# Improved over  3  iterations in  0.6117968769976869  seconds by  4.724407274636633e-05  percent.
# uncontrolled cost :  89230.50573415004
# cost splitting :  1836.26330575077 [7.1956160e-17 3.7978118e+00]
# 20 18 -----------------
# simulation duration :  158
# weight =  23156.62177879758
# set cost params:  1.0 0.0 23156.62177879758
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  89230.50573415004
# Gradient descend method:  None
# RUN  1 , total integrated cost =  89230.50573415002
# RUN  2 , total integrated cost =  89230.50573415002
# Control only changes marginally.
# RUN  2 , total integrated cost =  89230.50573415002
# Improved over  2  iterations in  0.4529177329968661  seconds by  1.4210854715202004e-14  percent.
# uncontrolled cost :  89230.50573415004
# cost splitting :  1787.2087860389465 [7.19561600e-17 3.77616812e+00]
# 20 19 -----------------
# simulation duration :  159
# weight =  23297.67160390319
# set cost params:  1.0 0.0 23297.67160390319
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  89230.50573415004
# Gradient descend method:  None
# RUN  1 , total integrated cost =  89230.50138676233
# RUN  2 , total integrated cost =  89230.50138676225
# RUN  3 , total integrated cost =  89230.50138676222
# RUN  4 , total integrated cost =  89230.50138676222
# Control only changes marginally.
# RUN  4 , total integrated cost =  89230.50138676222
# Improved over  4  iterations in  0.8023572439560667  seconds by  4.872086947216303e-06  percent.
# uncontrolled cost :  89230.50573415004
# cost splitting :  1721.8908908620308 [7.19561600e-17 3.75610971e+00]
# 20 20 -----------------
# simulation duration :  160
# weight =  23435.74409524183
# set cost params:  1.0 0.0 23435.74409524183
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  89230.50573415004
# Gradient descend method:  None
# RUN  1 , total integrated cost =  89230.50573415004
# Control only changes marginally.
# RUN  1 , total integrated cost =  89230.50573415004
# Improved over  1  iterations in  0.23867370001971722  seconds by  0.0  percent.
# converged
# uncontrolled cost :  89230.50573415004
# cost splitting :  1668.9715685736633 [7.1956160e-17 3.7362387e+00]

# %%
0 5 -----------------
converged
uncontrolled cost :  5931.918511634751
cost splitting :  0.005141356040024772 [4.29783714e+00 1.68784644e-16]
-------  20 0.4500000000000001 0.4750000000000002
20 5 -----------------
converged
uncontrolled cost :  12801.807032522984
cost splitting :  0.002562901587679188 [9.10740695e+00 5.68177680e-16]
-------  60 0.5500000000000003 0.6250000000000003
60 5 -----------------
converged
uncontrolled cost :  29944.61804459625
cost splitting :  0.0011211248706594424 [8.17034860e+00 2.67205143e-16]
-------  100 0.4500000000000001 0.7750000000000005
100 5 -----------------
converged
uncontrolled cost :  10612.507794560857
cost splitting :  164.21515358393515 [12.04597265  6.75988095]
    
-----------------------------------------------------------------------
0 6 -----------------
converged
uncontrolled cost :  5931.918511634751
cost splitting :  0.005094511772419305 [3.96016481e+00 1.24211820e-15]
-------  20 0.4500000000000001 0.4750000000000002
20 6 -----------------
converged
uncontrolled cost :  12801.807032522984
cost splitting :  0.0018080373509090338 [8.54268136e+00 7.14069726e-16]
-------  60 0.5500000000000003 0.6250000000000003
60 6 -----------------
converged
uncontrolled cost :  29944.61804459625
cost splitting :  0.0009045751705091117 [7.67527974e+00 2.37253068e-16]
-------  100 0.4500000000000001 0.7750000000000005
100 6 -----------------
converged
uncontrolled cost :  10612.507794560857
cost splitting :  0.054637694410420774 [12.74498805  2.9482137 ]
