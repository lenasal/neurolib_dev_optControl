# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import sys
import pickle

path = os.getcwd().split(os.sep + 'GUI')[0]
if path not in sys.path:
    print("not here")
    sys.path.append(path)

from neurolib.models.aln import ALNModel
from neurolib.utils import plotFunctions as plotFunc
from neurolib.utils import costFunctions as cost
import neurolib.dashboard.functions as functions
import neurolib.dashboard.data as data
    
# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2 

#path = os.path.join(os.getcwd(), "plots")
# Out:
# not here

# %%
grid_data_file = os.path.join(os.getcwd().split('data')[0], 'bi.pickle')
print(grid_data_file)
with open(grid_data_file,'rb') as f:
    load_array= pickle.load(f)
exc = load_array[0]
inh = load_array[1]
print(len(exc))
case = '1'
# Out:
# /home/lena/Promotion/neurolib/GUI/current/gui/bi.pickle
# 147

# %% [markdown]
# ### Bistability

# %%
aln = ALNModel()
N = aln.params.N

data.set_parameters(aln)

state_vars = aln.state_vars
init_vars = aln.init_vars

##############################################################
def setinit(init_vars_, model):
    state_vars = model.state_vars
    init_vars = model.init_vars
    for iv in range(len(init_vars)):
        for sv in range(len(state_vars)):
            if state_vars[sv] in init_vars[iv]:
                #print("set init vars ", )
                if model.params[init_vars[iv]].ndim == 2:
                    model.params[init_vars[iv]][0,:] = init_vars_[sv]
                else:
                    model.params[init_vars[iv]][0] = init_vars_[sv]
                    
##############################################################               
def setmaxmincontrol(max_c_c, min_c_c, max_c_r, min_c_r):
    import numpy as np
    
    max_cntrl = np.zeros(( 6 ))
    min_cntrl = np.zeros(( 6 ))
    
    max_cntrl[0] = max_c_c
    min_cntrl[0] = min_c_c
    max_cntrl[1] = max_c_c
    min_cntrl[1] = min_c_c
    max_cntrl[2] = max_c_r
    min_cntrl[2] = min_c_r
    max_cntrl[3] = max_c_r
    min_cntrl[3] = min_c_r
    max_cntrl[4] = max_c_r
    min_cntrl[4] = min_c_r
    max_cntrl[5] = max_c_r
    min_cntrl[5] = min_c_r
            
    return max_cntrl, min_cntrl

# %%
d_array = np.arange(20., 300, 0.1)
t0_array = d_array - 20.
t_pen = np.zeros(( t0_array.shape ))
for i in range(len(t_pen)):
    t_pen[i] = t0_array[i] / d_array[i]

bestControl_ = np.array( [[None] * len(t_pen)] * len(exc) )
bestState_ = np.array( [[None] * len(t_pen)] * len(exc) )
cost_ = np.array( [[None] * len(t_pen)] * len(exc) )
costnode_ = np.array( [[None] * len(t_pen)] * len(exc) )
weights_ = np.array( [[None] * len(t_pen)] * len(exc) )
convergence_ = np.array( [[None] * len(t_pen)] * len(exc) )

initVars = [None] * len(exc)
target = [None] * len(exc)
cost_uncontrolled = [None] * len(exc)

print(bestControl_.shape)
# Out:
# (147, 2800)

# %%
file_ = '3a.pickle'
case = '1'

# %%
dur_pre = 10
dur_post = 10

n_pre = int(np.around(dur_pre/aln.params.dt + 1.,1))
n_post = int(np.around(dur_post/aln.params.dt + 1.,1))

tol = 1e-32
start_step = 10.
c_scheme = np.zeros(( 1,1 ))
c_scheme[0,0] = 1.
u_mat = np.identity(1)
u_scheme = np.array([[1.]])

c_var = [0,1]
p_var = [0]

if case in ['1', '2']:    # low to high
    max_I = [3., -3.]
else:
    max_I = [-3., 3.]
    
if case in ['1', '3']:    # sparsity
    factor_ws = 1.
    factor_we = 0.
else:
    factor_ws = 0.
    factor_we = 1.
    
maxC = [5., -5., 0.18, 0.]
max_cntrl, min_cntrl = setmaxmincontrol(maxC[0], maxC[1], maxC[2], maxC[3])

# %%
if os.path.isfile(file_) :
    print("file found")
    
    with open(file_,'rb') as f:
        load_array = pickle.load(f)

    bestControl_ = load_array[0]
    bestState_ = load_array[1]
    cost_ = load_array[2]
    costnode_ = load_array[3]
    weights_ = load_array[4]

# %%
# get initial parameters and target states

#i_stepsize = 20
#limit = 150
#start_index = 0
#i_range = range(start_index, limit,i_stepsize)
i_range = [20]

data.set_parameters(aln)

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    aln.params.duration = 3000.
    
    control0 = aln.getZeroControl()
    control0 = functions.step_control(aln, maxI_ = max_I[0])

    aln.run(control=control0)
    
    target_rates = np.zeros((2))
    target_rates[0] = aln.rates_exc[0,-1] 
    target_rates[1] = aln.rates_inh[0,-1]

    control0 = functions.step_control(aln, maxI_ = max_I[1])
    aln.run(control=control0)

    init_state_vars = np.zeros(( len(state_vars) ))
    for j in range(len(state_vars)):
        if aln.state[state_vars[j]].size == 1:
            init_state_vars[j] = aln.state[state_vars[j]][0]
        else:
            init_state_vars[j] = aln.state[state_vars[j]][0,-1]

    initVars[i] = init_state_vars
    target[i] = [target_rates[0], target_rates[1]]
# Out:
# -------  20 0.4500000000000001 0.4750000000000002

# %%
# get uncontrolled cost

data.set_parameters(aln)

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    dur = d_array[0]
    aln.params.duration = dur
    
    target_ = aln.getZeroTarget()
    target_[:,0,:] = target[i][0]
    target_[:,1,:] = target[i][1]
        
    cost.setParams(1.0, 0.0, 0.0)

    setinit(initVars[i], aln)
    control0 = aln.getZeroControl()

    # "HS", "FR", "PR", "HZ"
    cgv = None
    max_it = 0

    bestControl_init_, bestState_init_, cost_init_, runtime_init_, grad_init_, phi_init_, costnode_init_ = aln.A1(
        control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
        prec_variables_ = p_var, transition_time_ = 0.)
    
    cost_uncontrolled[i] = cost_init_[0]
# Out:
# -------  20 0.4500000000000001 0.4750000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  0 , total integrated cost =  12801.807032522984
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.

# %%
cgv = None
j = 0
k = 0

while k < 10:
    print('-------------------------------------------- k = ', k)

    for i in i_range:
        print("------- ", i, exc[i], inh[i])
        aln.params.ext_exc_current = exc[i] * 5.
        aln.params.ext_inh_current = inh[i] * 5.

        if convergence_[i][j] == True:
            print('converged')
            continue

        dur = d_array[0]
        aln.params.duration = dur
        
        setinit(initVars[i], aln)

        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        max_it = int(100)

        if type(bestControl_[i][j]) == type(None) or np.amax(np.abs(bestControl_[i][j])) < 1e-6:
            print('no solution found')
            control0 = aln.getZeroControl()
            #control0[0,0,:50] = 5.
            cost.setParams(1.0, 0., 1.)
            max_it = int(1)
            weights_[i][j] = [1., 0., 1.]
        else:
            control0 = bestControl_[i][j][:,:,n_pre-1:-n_post+1]
            l = 1
            while cost_[i][j][-l] == 0.:
                l += 1

            weight_ = ( cost_uncontrolled[i] - costnode_[i][j][0][0][0] ) / sum( costnode_[i][j][2][0][:] )
                
            print("weight = ", weight_)
            cost.setParams(1.0, weight_ * factor_we, weight_ * factor_ws)
            weights_[i][j] = cost.getParams()

        bestControl_[i][j], bestState_[i][j], cost_[i][j], runtime_, grad_, phi_, costnode_[i][j] = aln.A1(
            control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
            prec_variables_ = p_var, transition_time_ = t_pen[j])

        if cost_[i][j][2] == 0.:
            print('converged')
            convergence_[i][j] = True

        print('uncontrolled cost : ', cost_uncontrolled[i])
        print('cost splitting : ', costnode_[i][j][0][0][0], costnode_[i][j][2][0][:2])

        time_ = np.arange(-dur_pre,dur+dur_post+aln.params.dt,aln.params.dt)
        dur += dur_pre + dur_post
        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        if True:
            fig, ax = plt.subplots(2,1, constrained_layout=True, figsize = (4,4) )
            ax[1].plot(time_, bestControl_[i][j][0,0,:], color = 'red')
            ax[0].plot(time_, bestState_[i][j][0,0,:], color= 'red')
            ax[1].plot(time_, bestControl_[i][j][0,1,:], color = 'blue')
            ax[0].plot(time_, bestState_[i][j][0,1,:], color= 'blue')
            ax[0].plot(time_, target_[0,0,:], linestyle = '--', color='red')
            ax[0].plot(time_, target_[0,1,:], linestyle = '--', color='blue')
            ax[0].set_xlim(-dur_pre,dur-dur_post)
            ax[1].set_xlim(-dur_pre,dur-dur_post)
            ax[0].axvspan(t0_array[0], t0_array[0]+20, alpha=0.2, color='gray')
            plt.show()

        with open(file_,'wb') as f:
            pickle.dump([bestControl_, bestState_, cost_, costnode_, weights_], f)
    
    k += 1
# Out:
# -------------------------------------------- k =  0
# -------  20 0.4500000000000001 0.4750000000000002
# weight =  893.9638628582769
# set cost params:  1.0 0.0 893.9638628582769
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12502.573615880003
# RUN  2 , total integrated cost =  12282.402726657583
# RUN  3 , total integrated cost =  12070.565066598327
# RUN  4 , total integrated cost =  11912.290714101808
# RUN  5 , total integrated cost =  11763.917856884547
# RUN  6 , total integrated cost =  11646.507820333409
# RUN  7 , total integrated cost =  11533.963616454199
# RUN  8 , total integrated cost =  11442.194434920108
# RUN  9 , total integrated cost =  11356.349321532143
# RUN  10 , total integrated cost =  11286.475186516192
# RUN  11 , total integrated cost =  11222.547471981032
# RUN  12 , total integrated cost =  11168.019537450471
# RUN  13 , total integrated cost =  11117.332266027826
# RUN  14 , total integrated cost =  11073.718088676356
# RUN  15 , total integrated cost =  11032.612902453468
# RUN  16 , total integrated cost =  10997.852608803205
# RUN  17 , total integrated cost =  10965.253061769523
# RUN  18 , total integrated cost =  10936.228989288546
# RUN  19 , total integrated cost =  10908.858988048667
# RUN  20 , total integrated cost =  10885.87677508157
# RUN  30 , total integrated cost =  10733.168560113536
# RUN  40 , total integrated cost =  10670.430305057018
# RUN  50 , total integrated cost =  10638.961849304973
# RUN  60 , total integrated cost =  10623.562423977983
# RUN  70 , total integrated cost =  10615.713453308854
# RUN  80 , total integrated cost =  10612.004864390754

# %%
for i in range(bestControl_.shape[0]):
    for j in range(1,bestControl_.shape[1]):
        bestControl_[i][j] = None
        convergence_[i][j] = None

# %%
cost.setParams(1.0, factor_we, factor_ws)

j_start = 1

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.

    for j in range(j_start,j_start+1000):
        print(i,j, '-----------------')
            
        k = 0
        while convergence_[i][j] != True:
            print('---------------------', k)

            dur = round(d_array[j],1)
            print('simulation duration : ', dur)
            aln.params.duration = dur
            max_it = int(100)  
            
            setinit(initVars[i], aln)
            target_ = aln.getZeroTarget()
            target_[:,0,:] = target[i][0]
            target_[:,1,:] = target[i][1]

            if type(bestControl_[i][j]) == type(None):
                print('no solution computed yet')
                control0 = aln.getZeroControl()
                if j%2 == 0:
                    control0[:,:,1:] = bestControl_[i][j-1][:,:,n_pre-1:-n_post+1]
                else:
                    control0[:,:,:-1] = bestControl_[i][j-1][:,:,n_pre-1:-n_post+1]
                                        
                l = 1
                while cost_[i][j-1][-l] == 0.:
                    l += 1
                    
                weight_ = ( cost_uncontrolled[i] - costnode_[i][j-1][0][0][0] ) / sum( costnode_[i][j-1][2][0][:] )
            else:
                control0 = bestControl_[i][j][:,:,n_pre-1:-n_post+1]
                l = 1
                while cost_[i][j][-l] == 0.:
                    l += 1
                
                weight_ = ( cost_uncontrolled[i] - costnode_[i][j][0][0][0] ) / sum( costnode_[i][j][2][0][:] )
                
            print("weight = ", weight_)
            cost.setParams(1.0, weight_ * factor_we, weight_ * factor_ws)
            weights_[i][j] = cost.getParams()

            bestControl_[i][j], bestState_[i][j], cost_[i][j], runtime_, grad_, phi_, costnode_[i][j] = aln.A1(
                control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
                startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
                t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
                prec_variables_ = p_var, transition_time_ = t_pen[j])

            if cost_[i][j][2] == 0.:
                print('converged')
                convergence_[i][j] = True

            print('uncontrolled cost : ', cost_uncontrolled[i])
            print('cost splitting : ', costnode_[i][j][0][0][0], costnode_[i][j][2][0][:2])

            time_ = np.arange(-dur_pre,round(dur+dur_post+aln.params.dt,1),aln.params.dt)
            dur += dur_pre + dur_post
            target_ = aln.getZeroTarget()
            target_[:,0,:] = target[i][0]
            target_[:,1,:] = target[i][1]

            if False:
                fig, ax = plt.subplots(2,1, constrained_layout=True, figsize = (4,4) )
                ax[1].plot(time_, bestControl_[i][j][0,0,:], color = 'red')
                ax[0].plot(time_, bestState_[i][j][0,0,:], color= 'red')
                ax[1].plot(time_, bestControl_[i][j][0,1,:], color = 'blue')
                ax[0].plot(time_, bestState_[i][j][0,1,:], color= 'blue')
                ax[0].plot(time_, target_[0,0,:], linestyle = '--', color='red')
                ax[0].plot(time_, target_[0,1,:], linestyle = '--', color='blue')
                ax[0].set_xlim(-dur_pre,dur-dur_post)
                ax[1].set_xlim(-dur_pre,dur-dur_post)
                ax[0].axvspan(t0_array[j], t0_array[j]+20, alpha=0.2, color='gray')
                plt.show()

            with open(file_,'wb') as f:
                pickle.dump([bestControl_, bestState_, cost_, costnode_, weights_], f)
                
            k += 1
# Out:
# set cost params:  1.0 0.0 1.0
# -------  20 0.4500000000000001 0.4750000000000002
# 20 1 -----------------
# 20 2 -----------------
# 20 3 -----------------
# 20 4 -----------------
# 20 5 -----------------
# 20 6 -----------------
# 20 7 -----------------
# 20 8 -----------------
# 20 9 -----------------
# 20 10 -----------------
# 20 11 -----------------
# 20 12 -----------------
# 20 13 -----------------
# 20 14 -----------------
# 20 15 -----------------
# 20 16 -----------------
# 20 17 -----------------
# 20 18 -----------------
# 20 19 -----------------
# 20 20 -----------------
# 20 21 -----------------
# 20 22 -----------------
# 20 23 -----------------
# 20 24 -----------------
# 20 25 -----------------
# 20 26 -----------------
# 20 27 -----------------
# 20 28 -----------------
# 20 29 -----------------
# 20 30 -----------------
# 20 31 -----------------
# 20 32 -----------------
# 20 33 -----------------
# 20 34 -----------------
# 20 35 -----------------
# 20 36 -----------------
# 20 37 -----------------
# 20 38 -----------------
# 20 39 -----------------
# 20 40 -----------------
# 20 41 -----------------
# 20 42 -----------------
# 20 43 -----------------
# 20 44 -----------------
# 20 45 -----------------
# 20 46 -----------------
# 20 47 -----------------
# 20 48 -----------------
# 20 49 -----------------
# 20 50 -----------------
# 20 51 -----------------
# 20 52 -----------------
# 20 53 -----------------
# 20 54 -----------------
# 20 55 -----------------
# 20 56 -----------------
# 20 57 -----------------
# 20 58 -----------------
# 20 59 -----------------
# 20 60 -----------------
# 20 61 -----------------
# 20 62 -----------------
# 20 63 -----------------
# 20 64 -----------------
# 20 65 -----------------
# 20 66 -----------------
# 20 67 -----------------
# 20 68 -----------------
# 20 69 -----------------
# 20 70 -----------------
# 20 71 -----------------
# 20 72 -----------------
# 20 73 -----------------
# 20 74 -----------------
# 20 75 -----------------
# 20 76 -----------------
# 20 77 -----------------
# 20 78 -----------------
# 20 79 -----------------
# 20 80 -----------------
# 20 81 -----------------
# 20 82 -----------------
# 20 83 -----------------
# 20 84 -----------------
# 20 85 -----------------
# 20 86 -----------------
# 20 87 -----------------
# 20 88 -----------------
# 20 89 -----------------
# 20 90 -----------------
# 20 91 -----------------
# 20 92 -----------------
# 20 93 -----------------
# 20 94 -----------------
# 20 95 -----------------
# 20 96 -----------------
# 20 97 -----------------
# 20 98 -----------------
# 20 99 -----------------
# 20 100 -----------------
# 20 101 -----------------
# --------------------- 0
# simulation duration :  30.1
# no solution computed yet
# weight =  1866.3811289267626
# set cost params:  1.0 0.0 1866.3811289267626
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12805.083642414078
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12805.0304739488
# RUN  2 , total integrated cost =  12805.025220859272
# RUN  3 , total integrated cost =  12805.024659125227
# RUN  4 , total integrated cost =  12805.024587864853
# RUN  5 , total integrated cost =  12805.024576554239
# RUN  6 , total integrated cost =  12805.024575009811
# RUN  7 , total integrated cost =  12805.024574922083
# RUN  8 , total integrated cost =  12805.024574918534
# RUN  9 , total integrated cost =  12805.02457491843
# RUN  10 , total integrated cost =  12805.024574918418
# RUN  11 , total integrated cost =  12805.024574918412
# RUN  12 , total integrated cost =  12805.024574918412
# Control only changes marginally.
# RUN  12 , total integrated cost =  12805.024574918412
# Improved over  12  iterations in  1.8896612459793687  seconds by  0.0004612816074853754  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  998.5841777628744 [6.32584643e+00 2.62546306e-16]
# --------------------- 1
# simulation duration :  30.1
# weight =  1865.8724946384975
# set cost params:  1.0 0.0 1865.8724946384975
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.20177365699782968  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  998.5841777628744 [6.32584643e+00 2.62546306e-16]
# 20 102 -----------------
# --------------------- 0
# simulation duration :  30.2
# no solution computed yet
# weight =  1865.8724946384975
# set cost params:  1.0 0.0 1865.8724946384975
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12805.113602648027
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12805.038460249996
# RUN  2 , total integrated cost =  12805.024628100098
# RUN  3 , total integrated cost =  12805.022913171919
# RUN  4 , total integrated cost =  12805.022639954916
# RUN  5 , total integrated cost =  12805.022594273418
# RUN  6 , total integrated cost =  12805.022586557907
# RUN  7 , total integrated cost =  12805.022585531455
# RUN  8 , total integrated cost =  12805.02258536598
# RUN  9 , total integrated cost =  12805.022585340774
# RUN  10 , total integrated cost =  12805.022585336905
# RUN  11 , total integrated cost =  12805.022585336303
# RUN  12 , total integrated cost =  12805.02258533622
# RUN  13 , total integrated cost =  12805.02258533621
# RUN  14 , total integrated cost =  12805.022585336192
# RUN  15 , total integrated cost =  12805.022585336192
# Control only changes marginally.
# RUN  15 , total integrated cost =  12805.022585336192
# Improved over  15  iterations in  2.1174451609840617  seconds by  0.0007107887884529873  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  1015.64346073267 [6.31842699e+00 2.62546306e-16]
# --------------------- 1
# simulation duration :  30.2
# weight =  1865.3635779698748
# set cost params:  1.0 0.0 1865.3635779698748
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.2095940299332142  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  1015.64346073267 [6.31842699e+00 2.62546306e-16]
# 20 103 -----------------
# --------------------- 0
# simulation duration :  30.3
# no solution computed yet
# weight =  1865.3635779698748
# set cost params:  1.0 0.0 1865.3635779698748
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12805.158991139264
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12805.029231310953
# RUN  2 , total integrated cost =  12805.007814188592
# RUN  3 , total integrated cost =  12804.992308332665
# RUN  4 , total integrated cost =  12804.984684746527
# RUN  5 , total integrated cost =  12804.981054607804
# RUN  6 , total integrated cost =  12804.97986533095
# RUN  7 , total integrated cost =  12804.979789579931
# RUN  8 , total integrated cost =  12804.979674267594
# RUN  9 , total integrated cost =  12804.97940193206
# RUN  10 , total integrated cost =  12804.977512592208
# RUN  11 , total integrated cost =  12804.97621209107
# RUN  12 , total integrated cost =  12804.975766482865
# RUN  13 , total integrated cost =  12804.975624408928
# RUN  14 , total integrated cost =  12804.975577997448
# RUN  15 , total integrated cost =  12804.975560927145
# RUN  16 , total integrated cost =  12804.975554695326
# RUN  17 , total integrated cost =  12804.975552390788
# RUN  18 , total integrated cost =  12804.975551570275
# RUN  19 , total integrated cost =  12804.975551291043
# RUN  20 , total integrated cost =  12804.9755512005
# RUN  30 , total integrated cost =  12804.975551154994
# Control only changes marginally.
# RUN  33 , total integrated cost =  12804.975551154985
# Improved over  33  iterations in  4.958366842009127  seconds by  0.001432547494388814  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  1049.2969608921928 [6.30208434e+00 2.62546306e-16]
# --------------------- 1
# simulation duration :  30.3
# weight =  1864.860804845646
# set cost params:  1.0 0.0 1864.860804845646
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807030059299
# RUN  2 , total integrated cost =  12801.807029163227
# RUN  3 , total integrated cost =  12801.807028827423
# RUN  4 , total integrated cost =  12801.807028700852
# RUN  5 , total integrated cost =  12801.807028653595
# RUN  6 , total integrated cost =  12801.807028635547
# RUN  7 , total integrated cost =  12801.807028629277
# RUN  8 , total integrated cost =  12801.807028626965
# RUN  9 , total integrated cost =  12801.807028626114
# RUN  10 , total integrated cost =  12801.807028625797
# RUN  11 , total integrated cost =  12801.807028625673
# RUN  12 , total integrated cost =  12801.807028625626
# RUN  13 , total integrated cost =  12801.807028625606
# RUN  14 , total integrated cost =  12801.807028625604
# RUN  15 , total integrated cost =  12801.8070286256
# RUN  16 , total integrated cost =  12801.8070286256
# Control only changes marginally.
# RUN  16 , total integrated cost =  12801.8070286256
# Improved over  16  iterations in  2.510040119988844  seconds by  3.0443999321505544e-08  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  1049.4258814935224 [6.30201520e+00 2.62546306e-16]
# --------------------- 2
# simulation duration :  30.3
# weight =  1864.8608054640806
# set cost params:  1.0 0.0 1864.8608054640806
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522982
# RUN  2 , total integrated cost =  12801.807032522982
# Control only changes marginally.
# RUN  2 , total integrated cost =  12801.807032522982
# Improved over  2  iterations in  0.4406965320231393  seconds by  1.4210854715202004e-14  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  1049.4258815045423 [6.30201520e+00 2.62546306e-16]
# --------------------- 3
# simulation duration :  30.3
# weight =  1864.8608054640808
# set cost params:  1.0 0.0 1864.8608054640808
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522986
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522986
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522986
# Improved over  1  iterations in  0.22605335502885282  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  1049.4258815045423 [6.30201520e+00 2.62546306e-16]
# 20 104 -----------------
# --------------------- 0
# simulation duration :  30.4
# no solution computed yet
# weight =  1864.8608054640808
# set cost params:  1.0 0.0 1864.8608054640808
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12805.259091343723
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12805.052293818522
# RUN  2 , total integrated cost =  12804.67313191072
# RUN  3 , total integrated cost =  12803.580699403143
# RUN  4 , total integrated cost =  12792.670836842817
# RUN  5 , total integrated cost =  12624.713592232374
# RUN  6 , total integrated cost =  12601.796361176066
# RUN  7 , total integrated cost =  12601.74473164879
# RUN  8 , total integrated cost =  12601.743564821869
# RUN  9 , total integrated cost =  12601.743527567887
# RUN  10 , total integrated cost =  12601.743527501128
# RUN  11 , total integrated cost =  12601.743527500888
# RUN  12 , total integrated cost =  12601.743527500883
# RUN  13 , total integrated cost =  12601.743527500883
# Control only changes marginally.
# RUN  13 , total integrated cost =  12601.743527500883
# Improved over  13  iterations in  1.9555261690402403  seconds by  1.5893123473028083  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  937.2142124840798 [6.25490615e+00 2.62546306e-16]
# --------------------- 1
# simulation duration :  30.4
# weight =  1896.8458585291169
# set cost params:  1.0 0.0 1896.8458585291169
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.784681821167
# RUN  2 , total integrated cost =  12801.78465342384
# RUN  3 , total integrated cost =  12801.784653140136
# RUN  4 , total integrated cost =  12801.784653137285
# RUN  5 , total integrated cost =  12801.784653137252
# RUN  6 , total integrated cost =  12801.78465313725
# RUN  7 , total integrated cost =  12801.784653137249
# RUN  8 , total integrated cost =  12801.784653137249
# Control only changes marginally.
# RUN  8 , total integrated cost =  12801.784653137249
# Improved over  8  iterations in  1.1837034850614145  seconds by  0.0001748142717445944  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  941.7944475167425 [6.25247969e+00 2.62546306e-16]
# --------------------- 2
# simulation duration :  30.4
# weight =  1896.849437810753
# set cost params:  1.0 0.0 1896.849437810753
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522636
# RUN  2 , total integrated cost =  12801.807032522636
# Control only changes marginally.
# RUN  2 , total integrated cost =  12801.807032522636
# Improved over  2  iterations in  0.3605177979916334  seconds by  2.7142732506035827e-12  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  941.7950360740113 [6.25247938e+00 2.62546306e-16]
# --------------------- 3
# simulation duration :  30.4
# weight =  1896.8494378108085
# set cost params:  1.0 0.0 1896.8494378108085
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.1981050259200856  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  941.7950360740113 [6.25247938e+00 2.62546306e-16]
# 20 105 -----------------
# --------------------- 0
# simulation duration :  30.5
# no solution computed yet
# weight =  1896.8494378108085
# set cost params:  1.0 0.0 1896.8494378108085
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12804.894885100277
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12804.856627136734
# RUN  2 , total integrated cost =  12804.855808400964
# RUN  3 , total integrated cost =  12804.855790328245
# RUN  4 , total integrated cost =  12804.855790206519
# RUN  5 , total integrated cost =  12804.85579020594
# RUN  6 , total integrated cost =  12804.855790205935
# RUN  7 , total integrated cost =  12804.855790205922
# RUN  8 , total integrated cost =  12804.855790205922
# Control only changes marginally.
# RUN  8 , total integrated cost =  12804.855790205922
# Improved over  8  iterations in  1.169007068965584  seconds by  0.0003053121068603559  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  951.5908192554461 [6.24892242e+00 2.62546306e-16]
# --------------------- 1
# simulation duration :  30.5
# weight =  1896.3615524635154
# set cost params:  1.0 0.0 1896.3615524635154
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522982
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522982
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522982
# Improved over  1  iterations in  0.20967853197362274  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  951.5908192554461 [6.24892242e+00 2.62546306e-16]
# 20 106 -----------------
# --------------------- 0
# simulation duration :  30.6
# no solution computed yet
# weight =  1896.3615524635154
# set cost params:  1.0 0.0 1896.3615524635154
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12804.916806442117
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12804.865355771624
# RUN  2 , total integrated cost =  12804.863915653556
# RUN  3 , total integrated cost =  12804.863856921007
# RUN  4 , total integrated cost =  12804.863854134668
# RUN  5 , total integrated cost =  12804.863854063997
# RUN  6 , total integrated cost =  12804.863854060924
# RUN  7 , total integrated cost =  12804.863854060848
# RUN  8 , total integrated cost =  12804.86385406084
# RUN  9 , total integrated cost =  12804.86385406084
# Control only changes marginally.
# RUN  9 , total integrated cost =  12804.86385406084
# Improved over  9  iterations in  1.5986330249579623  seconds by  0.00041353163067014975  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  963.0352514329561 [6.24449941e+00 2.62546306e-16]
# --------------------- 1
# simulation duration :  30.6
# weight =  1895.8720301919425
# set cost params:  1.0 0.0 1895.8720301919425
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522986
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# RUN  2 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  2 , total integrated cost =  12801.807032522984
# Improved over  2  iterations in  0.43801369809079915  seconds by  1.4210854715202004e-14  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  963.0352514329559 [6.24449941e+00 2.62546306e-16]
# --------------------- 2
# simulation duration :  30.6
# weight =  1895.8720301919425
# set cost params:  1.0 0.0 1895.8720301919425
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.24373260897118598  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  963.0352514329559 [6.24449941e+00 2.62546306e-16]
# 20 107 -----------------
# --------------------- 0
# simulation duration :  30.7
# no solution computed yet
# weight =  1895.8720301919425
# set cost params:  1.0 0.0 1895.8720301919425
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12804.943955166089
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12804.892577676284
# RUN  2 , total integrated cost =  12804.884907940293
# RUN  3 , total integrated cost =  12804.884616020363
# RUN  4 , total integrated cost =  12804.884575361477
# RUN  5 , total integrated cost =  12804.884573050174
# RUN  6 , total integrated cost =  12804.884571958639
# RUN  7 , total integrated cost =  12804.884571559951
# RUN  8 , total integrated cost =  12804.884571513918
# RUN  9 , total integrated cost =  12804.884571508208
# RUN  10 , total integrated cost =  12804.884571507426
# RUN  11 , total integrated cost =  12804.884571507308
# RUN  12 , total integrated cost =  12804.884571507291
# RUN  13 , total integrated cost =  12804.884571507282
# RUN  14 , total integrated cost =  12804.88457150728
# RUN  15 , total integrated cost =  12804.88457150728
# Control only changes marginally.
# RUN  15 , total integrated cost =  12804.88457150728
# Improved over  15  iterations in  2.4516915450803936  seconds by  0.00046375571042744923  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  975.6678589552431 [6.23945948e+00 2.62546306e-16]
# --------------------- 1
# simulation duration :  30.7
# weight =  1895.3787921167652
# set cost params:  1.0 0.0 1895.3787921167652
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.20761723793111742  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  975.6678589552431 [6.23945948e+00 2.62546306e-16]
# 20 108 -----------------
# --------------------- 0
# simulation duration :  30.8
# no solution computed yet
# weight =  1895.3787921167652
# set cost params:  1.0 0.0 1895.3787921167652
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12804.974785311799
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12804.90588839938
# RUN  2 , total integrated cost =  12804.899170808036
# RUN  3 , total integrated cost =  12804.89763803011
# RUN  4 , total integrated cost =  12804.897131567974
# RUN  5 , total integrated cost =  12804.897033829156
# RUN  6 , total integrated cost =  12804.89703382915
# RUN  7 , total integrated cost =  12804.89703382915
# Control only changes marginally.
# RUN  7 , total integrated cost =  12804.89703382915
# Improved over  7  iterations in  1.0498112679924816  seconds by  0.0006071974678008019  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  990.9908961337302 [6.23300534e+00 2.62546306e-16]
# --------------------- 1
# simulation duration :  30.8
# weight =  1894.8830438964005
# set cost params:  1.0 0.0 1894.8830438964005
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.20081750093959272  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  990.9908961337302 [6.23300534e+00 2.62546306e-16]
# 20 109 -----------------
# --------------------- 0
# simulation duration :  30.9
# no solution computed yet
# weight =  1894.8830438964005
# set cost params:  1.0 0.0 1894.8830438964005
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12805.014122801735
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12804.9347790025
# RUN  2 , total integrated cost =  12804.888475827029
# RUN  3 , total integrated cost =  12804.871256430926
# RUN  4 , total integrated cost =  12804.86531352358
# RUN  5 , total integrated cost =  12804.861215546043
# RUN  6 , total integrated cost =  12804.85805239339
# RUN  7 , total integrated cost =  12804.855455884446
# RUN  8 , total integrated cost =  12804.85478670662
# RUN  9 , total integrated cost =  12804.853597635738
# RUN  10 , total integrated cost =  12804.852171091685
# RUN  11 , total integrated cost =  12804.851236591809
# RUN  12 , total integrated cost =  12804.850619094781
# RUN  13 , total integrated cost =  12804.850180867264
# RUN  14 , total integrated cost =  12804.84995114761
# RUN  15 , total integrated cost =  12804.84990929639
# RUN  16 , total integrated cost =  12804.849828646788
# RUN  17 , total integrated cost =  12804.849676423082
# RUN  18 , total integrated cost =  12804.849446068829
# RUN  19 , total integrated cost =  12804.8492437342
# RUN  20 , total integrated cost =  12804.849089773554
# Control only changes marginally.
# RUN  25 , total integrated cost =  12804.848809809224
# Improved over  25  iterations in  3.6553822490386665  seconds by  0.0012910020319054638  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  1029.0049575851697 [6.21454917e+00 2.62546306e-16]
# --------------------- 1
# simulation duration :  30.9
# weight =  1894.393583244974
# set cost params:  1.0 0.0 1894.393583244974
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807030274487
# RUN  2 , total integrated cost =  12801.807026597384
# RUN  3 , total integrated cost =  12801.807020584823
# RUN  4 , total integrated cost =  12801.807010326207
# RUN  5 , total integrated cost =  12801.806993340213
# RUN  6 , total integrated cost =  12801.806965236852
# RUN  7 , total integrated cost =  12801.80691639985
# RUN  8 , total integrated cost =  12801.80682923057
# RUN  9 , total integrated cost =  12801.806697274882
# RUN  10 , total integrated cost =  12801.80658374173
# RUN  11 , total integrated cost =  12801.80648773131
# RUN  12 , total integrated cost =  12801.806453448671
# RUN  13 , total integrated cost =  12801.806451291128
# RUN  14 , total integrated cost =  12801.806447213254
# RUN  15 , total integrated cost =  12801.806439763834
# RUN  16 , total integrated cost =  12801.80642556461
# RUN  17 , total integrated cost =  12801.80639953053
# RUN  18 , total integrated cost =  12801.806351786316
# RUN  19 , total integrated cost =  12801.80626448934
# RUN  20 , total integrated cost =  12801.80614106059
# RUN  30 , total integrated cost =  12801.805277653797
# Control only changes marginally.
# RUN  37 , total integrated cost =  12801.805276344778
# Improved over  37  iterations in  5.392508500022814  seconds by  1.3718205565282915e-05  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  1035.5714877810979 [6.21108195e+00 2.62546306e-16]
# --------------------- 2
# simulation duration :  30.9
# weight =  1894.3938659941343
# set cost params:  1.0 0.0 1894.3938659941343
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522982
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522982
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522982
# Improved over  1  iterations in  0.21316511393524706  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  1035.5714877810979 [6.21108195e+00 2.62546306e-16]
# 20 110 -----------------
# --------------------- 0
# simulation duration :  31.0
# no solution computed yet
# weight =  1894.3938659941343
# set cost params:  1.0 0.0 1894.3938659941343
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12805.147585709374
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12804.875969717468
# RUN  2 , total integrated cost =  12804.174355524958
# RUN  3 , total integrated cost =  12799.491589768348
# RUN  4 , total integrated cost =  12485.06984589988
# RUN  5 , total integrated cost =  12485.069845899876
# RUN  6 , total integrated cost =  12485.069845899876
# Control only changes marginally.
# RUN  6 , total integrated cost =  12485.069845899876
# Improved over  6  iterations in  0.9688287139870226  seconds by  2.499602114439554  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  856.4645951228883 [6.13843059e+00 2.62546306e-16]
# --------------------- 1
# simulation duration :  31.0
# weight =  1945.9929159688475
# set cost params:  1.0 0.0 1945.9929159688475
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.22073459101375192  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  856.4645951228883 [6.13843059e+00 2.62546306e-16]
# 20 111 -----------------
# --------------------- 0
# simulation duration :  31.1
# no solution computed yet
# weight =  1945.9929159688475
# set cost params:  1.0 0.0 1945.9929159688475
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12804.56093797354
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12804.560937973538
# RUN  2 , total integrated cost =  12804.560937973538
# Control only changes marginally.
# RUN  2 , total integrated cost =  12804.560937973538
# Improved over  2  iterations in  0.39017720404081047  seconds by  1.4210854715202004e-14  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  859.2185005734451 [6.13843059e+00 2.62546306e-16]
# --------------------- 1
# simulation duration :  31.1
# weight =  1945.5442824929876
# set cost params:  1.0 0.0 1945.5442824929876
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.21088858996517956  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  859.2185005734451 [6.13843059e+00 2.62546306e-16]
# 20 112 -----------------
# --------------------- 0
# simulation duration :  31.2
# no solution computed yet
# weight =  1945.5442824929876
# set cost params:  1.0 0.0 1945.5442824929876
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12804.56093797354
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12804.56093797354
# Control only changes marginally.
# RUN  1 , total integrated cost =  12804.56093797354
# Improved over  1  iterations in  0.2096172400051728  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  861.9724060240011 [6.13843059e+00 2.62546306e-16]
# 20 113 -----------------
# --------------------- 0
# simulation duration :  31.3
# no solution computed yet
# weight =  1945.0956490171275
# set cost params:  1.0 0.0 1945.0956490171275
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12804.56093797354
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12804.56093797354
# Control only changes marginally.
# RUN  1 , total integrated cost =  12804.56093797354
# Improved over  1  iterations in  0.20967404393013567  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  864.726311474557 [6.13843059e+00 2.62546306e-16]
# 20 114 -----------------
# --------------------- 0
# simulation duration :  31.4
# no solution computed yet
# weight =  1944.6470155412674
# set cost params:  1.0 0.0 1944.6470155412674
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12804.56093797354
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12804.560937973538
# RUN  2 , total integrated cost =  12804.560937973538
# Control only changes marginally.
# RUN  2 , total integrated cost =  12804.560937973538
# Improved over  2  iterations in  0.38977241795510054  seconds by  1.4210854715202004e-14  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  867.4802169251129 [6.13843059e+00 2.62546306e-16]
# --------------------- 1
# simulation duration :  31.4
# weight =  1944.1983820654077
# set cost params:  1.0 0.0 1944.1983820654077
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.21041192603297532  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  867.4802169251129 [6.13843059e+00 2.62546306e-16]
# 20 115 -----------------
# --------------------- 0
# simulation duration :  31.5
# no solution computed yet
# weight =  1944.1983820654077
# set cost params:  1.0 0.0 1944.1983820654077
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12804.56093797354
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12804.56093797354
# Control only changes marginally.
# RUN  1 , total integrated cost =  12804.56093797354
# Improved over  1  iterations in  0.20659587800037116  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  870.2341223756688 [6.13843059e+00 2.62546306e-16]
# 20 116 -----------------
# --------------------- 0
# simulation duration :  31.6
# no solution computed yet
# weight =  1943.7497485895476
# set cost params:  1.0 0.0 1943.7497485895476
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12804.56093797354
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12804.56020996789
# RUN  2 , total integrated cost =  12804.56011617695
# RUN  3 , total integrated cost =  12804.560096030073
# RUN  4 , total integrated cost =  12804.56009375261
# RUN  5 , total integrated cost =  12804.560093563528
# RUN  6 , total integrated cost =  12804.560093542324
# RUN  7 , total integrated cost =  12804.560093540533
# RUN  8 , total integrated cost =  12804.560093540336
# RUN  9 , total integrated cost =  12804.560093540309
# RUN  10 , total integrated cost =  12804.560093540305
# RUN  11 , total integrated cost =  12804.560093540305
# Control only changes marginally.
# RUN  11 , total integrated cost =  12804.560093540305
# Improved over  11  iterations in  1.6141121790278703  seconds by  6.5947847645020374e-06  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  874.2158369604435 [6.13779848e+00 1.33758207e-16]
# --------------------- 1
# simulation duration :  31.6
# weight =  1943.3012064900754
# set cost params:  1.0 0.0 1943.3012064900754
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522982
# RUN  2 , total integrated cost =  12801.80703252298
# RUN  3 , total integrated cost =  12801.80703252298
# Control only changes marginally.
# RUN  3 , total integrated cost =  12801.80703252298
# Improved over  3  iterations in  0.633427191991359  seconds by  2.842170943040401e-14  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  874.2158369605303 [6.13779848e+00 1.33758207e-16]
# --------------------- 2
# simulation duration :  31.6
# weight =  1943.3012064900759
# set cost params:  1.0 0.0 1943.3012064900759
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.22116036398801953  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  874.2158369605303 [6.13779848e+00 1.33758207e-16]
# 20 117 -----------------
# --------------------- 0
# simulation duration :  31.7
# no solution computed yet
# weight =  1943.3012064900759
# set cost params:  1.0 0.0 1943.3012064900759
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12804.564811188475
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12804.51259034065
# RUN  2 , total integrated cost =  12804.502950581335
# RUN  3 , total integrated cost =  12804.501712278112
# RUN  4 , total integrated cost =  12804.500970859182
# RUN  5 , total integrated cost =  12804.500943025181
# RUN  6 , total integrated cost =  12804.50094235695
# RUN  7 , total integrated cost =  12804.500942356946
# RUN  8 , total integrated cost =  12804.500942356946
# Control only changes marginally.
# RUN  8 , total integrated cost =  12804.500942356946
# Improved over  8  iterations in  1.295936209964566  seconds by  0.0004987973622689879  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  888.1206898939453 [6.13202946e+00 1.33758207e-16]
# --------------------- 1
# simulation duration :  31.7
# weight =  1942.861888667079
# set cost params:  1.0 0.0 1942.861888667079
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.23092559596989304  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  888.1206898939453 [6.13202946e+00 1.33758207e-16]
# 20 118 -----------------
# --------------------- 0
# simulation duration :  31.8
# no solution computed yet
# weight =  1942.861888667079
# set cost params:  1.0 0.0 1942.861888667079
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12804.59986488114
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12804.535344068005
# RUN  2 , total integrated cost =  12804.508494980595
# RUN  3 , total integrated cost =  12804.498097243586
# RUN  4 , total integrated cost =  12804.494637676475
# RUN  5 , total integrated cost =  12804.493352307109
# RUN  6 , total integrated cost =  12804.492566139115
# RUN  7 , total integrated cost =  12804.492015940188
# RUN  8 , total integrated cost =  12804.491428547846
# RUN  9 , total integrated cost =  12804.491139145603
# RUN  10 , total integrated cost =  12804.49099396968
# RUN  11 , total integrated cost =  12804.49092072955
# RUN  12 , total integrated cost =  12804.490881660147
# RUN  13 , total integrated cost =  12804.490861067563
# RUN  14 , total integrated cost =  12804.490850460152
# RUN  15 , total integrated cost =  12804.490845147597
# RUN  16 , total integrated cost =  12804.490842318715
# RUN  17 , total integrated cost =  12804.490840843177
# RUN  18 , total integrated cost =  12804.490840074368
# RUN  19 , total integrated cost =  12804.49083969124
# RUN  20 , total integrated cost =  12804.490839487706
# RUN  30 , total integrated cost =  12804.490839273032
# Control only changes marginally.
# RUN  37 , total integrated cost =  12804.490839272736
# Improved over  37  iterations in  5.510322884074412  seconds by  0.000851456582438459  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  914.4311048641933 [6.11986874e+00 1.33758207e-16]
# --------------------- 1
# simulation duration :  31.8
# weight =  1942.4233487465813
# set cost params:  1.0 0.0 1942.4233487465813
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032307832
# RUN  2 , total integrated cost =  12801.807032195207
# RUN  3 , total integrated cost =  12801.807032137855
# RUN  4 , total integrated cost =  12801.80703210709
# RUN  5 , total integrated cost =  12801.807032091623
# RUN  6 , total integrated cost =  12801.807032083669
# RUN  7 , total integrated cost =  12801.807032079616
# RUN  8 , total integrated cost =  12801.807032077499
# RUN  9 , total integrated cost =  12801.807032076389
# RUN  10 , total integrated cost =  12801.807032075792
# RUN  11 , total integrated cost =  12801.807032075492
# RUN  12 , total integrated cost =  12801.807032075309
# RUN  13 , total integrated cost =  12801.807032075218
# RUN  14 , total integrated cost =  12801.807032075158
# RUN  15 , total integrated cost =  12801.80703207513
# RUN  16 , total integrated cost =  12801.807032075116
# RUN  17 , total integrated cost =  12801.807032075109
# RUN  18 , total integrated cost =  12801.807032075103
# RUN  19 , total integrated cost =  12801.8070320751
# RUN  20 , total integrated cost =  12801.8070320751
# Control only changes marginally.
# RUN  20 , total integrated cost =  12801.8070320751
# Improved over  20  iterations in  2.831328865024261  seconds by  3.4985987440450117e-09  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  914.4860866542311 [6.11984043e+00 1.33758207e-16]
# --------------------- 2
# simulation duration :  31.8
# weight =  1942.4233488197667
# set cost params:  1.0 0.0 1942.4233488197667
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522982
# RUN  2 , total integrated cost =  12801.80703252298
# RUN  3 , total integrated cost =  12801.807032522976
# RUN  4 , total integrated cost =  12801.807032522976
# Control only changes marginally.
# RUN  4 , total integrated cost =  12801.807032522976
# Improved over  4  iterations in  0.7769459780538455  seconds by  5.684341886080802e-14  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  914.4861460688285 [6.11984040e+00 1.33758207e-16]
# --------------------- 3
# simulation duration :  31.8
# weight =  1942.4233488197679
# set cost params:  1.0 0.0 1942.4233488197679
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.22063390293624252  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  914.4861460688285 [6.11984040e+00 1.33758207e-16]
# 20 119 -----------------
# --------------------- 0
# simulation duration :  31.9
# no solution computed yet
# weight =  1942.4233488197679
# set cost params:  1.0 0.0 1942.4233488197679
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12804.673760253607
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12804.548502921727
# RUN  2 , total integrated cost =  12804.41979174876
# RUN  3 , total integrated cost =  12804.327881327696
# RUN  4 , total integrated cost =  12804.071003409557
# RUN  5 , total integrated cost =  12803.263753750478
# RUN  6 , total integrated cost =  12794.477490999825
# RUN  7 , total integrated cost =  12563.267583341416
# RUN  8 , total integrated cost =  12532.722545479734
# RUN  9 , total integrated cost =  12532.677230831488
# RUN  10 , total integrated cost =  12532.677225924584
# RUN  11 , total integrated cost =  12532.677225759739
# RUN  12 , total integrated cost =  12532.67722575284
# RUN  13 , total integrated cost =  12532.677225752475
# RUN  14 , total integrated cost =  12532.677225752454
# RUN  15 , total integrated cost =  12532.67722575245
# RUN  16 , total integrated cost =  12532.67722575245
# Control only changes marginally.
# RUN  16 , total integrated cost =  12532.67722575245
# Improved over  16  iterations in  2.427682942012325  seconds by  2.1241973016559683  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  807.774788856836 [6.03622400e+00 1.33758207e-16]
# --------------------- 1
# simulation duration :  31.9
# weight =  1987.0091373453438
# set cost params:  1.0 0.0 1987.0091373453438
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.760484008712
# RUN  2 , total integrated cost =  12801.760431844608
# RUN  3 , total integrated cost =  12801.760427503626
# RUN  4 , total integrated cost =  12801.760427303161
# RUN  5 , total integrated cost =  12801.76042729279
# RUN  6 , total integrated cost =  12801.760427292254
# RUN  7 , total integrated cost =  12801.760427292205
# RUN  8 , total integrated cost =  12801.760427292202
# RUN  9 , total integrated cost =  12801.760427292202
# Control only changes marginally.
# RUN  9 , total integrated cost =  12801.760427292202
# Improved over  9  iterations in  1.5129286540905014  seconds by  0.0003640519706635814  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  813.0424217869603 [6.03354951e+00 1.33758207e-16]
# --------------------- 2
# simulation duration :  31.9
# weight =  1987.016861692465
# set cost params:  1.0 0.0 1987.016861692465
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032521367
# RUN  2 , total integrated cost =  12801.807032521285
# RUN  3 , total integrated cost =  12801.807032521283
# RUN  4 , total integrated cost =  12801.80703252128
# RUN  5 , total integrated cost =  12801.80703252128
# Control only changes marginally.
# RUN  5 , total integrated cost =  12801.80703252128
# Improved over  5  iterations in  0.8622406959766522  seconds by  1.3315570868144277e-11  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  813.0438618260982 [6.03354878e+00 1.33758207e-16]
# --------------------- 3
# simulation duration :  31.9
# weight =  1987.0168616927474
# set cost params:  1.0 0.0 1987.0168616927474
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.22139678697567433  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  813.0438618260982 [6.03354878e+00 1.33758207e-16]
# 20 120 -----------------
# --------------------- 0
# simulation duration :  32.0
# no solution computed yet
# weight =  1987.0168616927474
# set cost params:  1.0 0.0 1987.0168616927474
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12804.34779459119
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12804.3327482811
# RUN  2 , total integrated cost =  12804.332447637784
# RUN  3 , total integrated cost =  12804.332442134379
# RUN  4 , total integrated cost =  12804.332442028974
# RUN  5 , total integrated cost =  12804.332442026149
# RUN  6 , total integrated cost =  12804.332442026134
# RUN  7 , total integrated cost =  12804.332442026134
# Control only changes marginally.
# RUN  7 , total integrated cost =  12804.332442026134
# Improved over  7  iterations in  1.0978199749952182  seconds by  0.0001199011874888356  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  819.4777608371342 [6.03158177e+00 1.33758207e-16]
# --------------------- 1
# simulation duration :  32.0
# weight =  1986.598163978096
# set cost params:  1.0 0.0 1986.598163978096
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522982
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522982
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522982
# Improved over  1  iterations in  0.21842010808177292  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  819.4777608371342 [6.03158177e+00 1.33758207e-16]
# 20 121 -----------------
# --------------------- 0
# simulation duration :  32.1
# no solution computed yet
# weight =  1986.598163978096
# set cost params:  1.0 0.0 1986.598163978096
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12804.359922743659
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12804.34264496668
# RUN  2 , total integrated cost =  12804.34228345132
# RUN  3 , total integrated cost =  12804.34228162598
# RUN  4 , total integrated cost =  12804.342281611951
# RUN  5 , total integrated cost =  12804.342281611698
# RUN  6 , total integrated cost =  12804.342281611698
# Control only changes marginally.
# RUN  6 , total integrated cost =  12804.342281611698
# Improved over  6  iterations in  0.9436985779320821  seconds by  0.00013777441486695352  percent.
# uncontrolled cost :  12801.807032522984
# cost splitting :  826.2031138850718 [6.02947259e+00 1.33758207e-16]
# --------------------- 1
# simulation duration :  32.1
# weight =  1986.1776878829075
# set cost params:  1.0 0.0 1986.1776878829075
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12801.807032522984
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12801.807032522984
# Control only changes marginally.
# RUN  1 , total integrated cost =  12801.807032522984
# Improved over  1  iterations in  0.20155379304196686  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  826.2031138850718 [6.02947259e+00 1.33758207e-16]
# 20 122 -----------------
# --------------------- 0
# simulation duration :  32.2
# no solution computed yet
# weight =  1986.1776878829075
# set cost params:  1.0 0.0 1986.1776878829075
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12804.372880702751
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12804.349320797448
# RUN  2 , total integrated cost =  12804.348965602176
# RUN  3 , total integrated cost =  12804.348933945512
# RUN  4 , total integrated cost =  12804.348930425387
# RUN  5 , total integrated cost =  12804.348930150227
# RUN  6 , total integrated cost =  12804.348930124563
# RUN  7 , total integrated cost =  12804.348930122656
# RUN  8 , total integrated cost =  12804.348930122458
# RUN  9 , total integrated cost =  12804.348930122434
# RUN  10 , total integrated cost =  12804.348930122425
# RUN  11 , total integrated cost =  12804.348930122422
# RUN  12 , total integrated cost =  12804.348930122418
# RUN  13 , total integrated cost =  12804.348930122418
# Control only changes marginally.
# RUN  13 , total integrated cost =  12804.348930122418
# ...
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  853.5510312690628 [5.15142639e+00 3.26172184e-16]
# 20 976 -----------------
# --------------------- 0
# simulation duration :  117.6
# no solution computed yet
# weight =  2319.4073048128585
# set cost params:  1.0 0.0 2319.4073048128585
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12802.532841223043
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12802.532841223043
# Control only changes marginally.
# RUN  1 , total integrated cost =  12802.532841223043
# Improved over  1  iterations in  0.37039377994369715  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  854.2768399691215 [5.15142639e+00 3.26172184e-16]
# 20 977 -----------------
# --------------------- 0
# simulation duration :  117.7
# no solution computed yet
# weight =  2319.266410108172
# set cost params:  1.0 0.0 2319.266410108172
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12802.532841223043
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12802.532841223043
# Control only changes marginally.
# RUN  1 , total integrated cost =  12802.532841223043
# Improved over  1  iterations in  0.359434945974499  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  855.0026486691802 [5.15142639e+00 3.26172184e-16]
# 20 978 -----------------
# --------------------- 0
# simulation duration :  117.8
# no solution computed yet
# weight =  2319.1255154034857
# set cost params:  1.0 0.0 2319.1255154034857
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12802.532841223043
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12802.532841223043
# Control only changes marginally.
# RUN  1 , total integrated cost =  12802.532841223043
# Improved over  1  iterations in  0.35423189599532634  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  855.728457369239 [5.15142639e+00 3.26172184e-16]
# 20 979 -----------------
# --------------------- 0
# simulation duration :  117.9
# no solution computed yet
# weight =  2318.984620698799
# set cost params:  1.0 0.0 2318.984620698799
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12802.532841223041
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12802.532841223041
# Control only changes marginally.
# RUN  1 , total integrated cost =  12802.532841223041
# Improved over  1  iterations in  0.3721049759769812  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  856.4542660692977 [5.15142639e+00 3.26172184e-16]
# 20 980 -----------------
# --------------------- 0
# simulation duration :  118.0
# no solution computed yet
# weight =  2318.8437259941134
# set cost params:  1.0 0.0 2318.8437259941134
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12802.532841223045
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12802.532841223045
# Control only changes marginally.
# RUN  1 , total integrated cost =  12802.532841223045
# Improved over  1  iterations in  0.3882311439374462  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  857.1800747693565 [5.15142639e+00 3.26172184e-16]
# 20 981 -----------------
# --------------------- 0
# simulation duration :  118.1
# no solution computed yet
# weight =  2318.7028312894267
# set cost params:  1.0 0.0 2318.7028312894267
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12802.532841223043
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12802.532841223043
# Control only changes marginally.
# RUN  1 , total integrated cost =  12802.532841223043
# Improved over  1  iterations in  0.38302347995340824  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  857.9058834694151 [5.15142639e+00 3.26172184e-16]
# 20 982 -----------------
# --------------------- 0
# simulation duration :  118.2
# no solution computed yet
# weight =  2318.5619365847406
# set cost params:  1.0 0.0 2318.5619365847406
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12802.532841223043
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12802.532841223043
# Control only changes marginally.
# RUN  1 , total integrated cost =  12802.532841223043
# Improved over  1  iterations in  0.38453311601188034  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  858.6316921694739 [5.15142639e+00 3.26172184e-16]
# 20 983 -----------------
# --------------------- 0
# simulation duration :  118.3
# no solution computed yet
# weight =  2318.421041880054
# set cost params:  1.0 0.0 2318.421041880054
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12802.532841223043
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12802.532841223043
# Control only changes marginally.
# RUN  1 , total integrated cost =  12802.532841223043
# Improved over  1  iterations in  0.3676655350718647  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  859.3575008695326 [5.15142639e+00 3.26172184e-16]
# 20 984 -----------------
# --------------------- 0
# simulation duration :  118.4
# no solution computed yet
# weight =  2318.280147175368
# set cost params:  1.0 0.0 2318.280147175368
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12802.532841223041
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12802.532841223041
# Control only changes marginally.
# RUN  1 , total integrated cost =  12802.532841223041
# Improved over  1  iterations in  0.3524875770090148  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  860.0833095695914 [5.15142639e+00 3.26172184e-16]
# 20 985 -----------------
# --------------------- 0
# simulation duration :  118.5
# no solution computed yet
# weight =  2318.1392524706816
# set cost params:  1.0 0.0 2318.1392524706816
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12802.532841223043
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12802.532841223043
# Control only changes marginally.
# RUN  1 , total integrated cost =  12802.532841223043
# Improved over  1  iterations in  0.3647690910147503  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  860.8091182696501 [5.15142639e+00 3.26172184e-16]
# 20 986 -----------------
# --------------------- 0
# simulation duration :  118.6
# no solution computed yet
# weight =  2317.9983577659955
# set cost params:  1.0 0.0 2317.9983577659955
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12802.532841223045
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12802.532841223045
# Control only changes marginally.
# RUN  1 , total integrated cost =  12802.532841223045
# Improved over  1  iterations in  0.3666541139828041  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  861.5349269697087 [5.15142639e+00 3.26172184e-16]
# 20 987 -----------------
# --------------------- 0
# simulation duration :  118.7
# no solution computed yet
# weight =  2317.857463061309
# set cost params:  1.0 0.0 2317.857463061309
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12802.532841223043
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12802.532841223043
# Control only changes marginally.
# RUN  1 , total integrated cost =  12802.532841223043
# Improved over  1  iterations in  0.4396856240928173  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  862.2607356697675 [5.15142639e+00 3.26172184e-16]
# 20 988 -----------------
# --------------------- 0
# simulation duration :  118.8
# no solution computed yet
# weight =  2317.7165683566227
# set cost params:  1.0 0.0 2317.7165683566227
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12802.532841223041
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12802.532841223041
# Control only changes marginally.
# RUN  1 , total integrated cost =  12802.532841223041
# Improved over  1  iterations in  0.4023437980795279  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  862.9865443698262 [5.15142639e+00 3.26172184e-16]
# 20 989 -----------------
# --------------------- 0
# simulation duration :  118.9
# no solution computed yet
# weight =  2317.5756736519365
# set cost params:  1.0 0.0 2317.5756736519365
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12802.532841223043
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12802.532841223043
# Control only changes marginally.
# RUN  1 , total integrated cost =  12802.532841223043
# Improved over  1  iterations in  0.38543963991105556  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  863.712353069885 [5.15142639e+00 3.26172184e-16]
# 20 990 -----------------
# --------------------- 0
# simulation duration :  119.0
# no solution computed yet
# weight =  2317.43477894725
# set cost params:  1.0 0.0 2317.43477894725
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12802.532841223041
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12802.532841223041
# Control only changes marginally.
# RUN  1 , total integrated cost =  12802.532841223041
# Improved over  1  iterations in  0.3738404280738905  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  864.4381617699437 [5.15142639e+00 3.26172184e-16]
# 20 991 -----------------
# --------------------- 0
# simulation duration :  119.1
# no solution computed yet
# weight =  2317.2938842425638
# set cost params:  1.0 0.0 2317.2938842425638
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12802.532841223043
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12802.532841223043
# Control only changes marginally.
# RUN  1 , total integrated cost =  12802.532841223043
# Improved over  1  iterations in  0.35685797804035246  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  865.1639704700025 [5.15142639e+00 3.26172184e-16]
# 20 992 -----------------
# --------------------- 0
# simulation duration :  119.2
# no solution computed yet
# weight =  2317.1529895378776
# set cost params:  1.0 0.0 2317.1529895378776
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12802.532841223045
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12802.532841223045
# Control only changes marginally.
# RUN  1 , total integrated cost =  12802.532841223045
# Improved over  1  iterations in  0.37857949594035745  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  865.8897791700612 [5.15142639e+00 3.26172184e-16]
# 20 993 -----------------
# --------------------- 0
# simulation duration :  119.3
# no solution computed yet
# weight =  2317.012094833191
# set cost params:  1.0 0.0 2317.012094833191
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12802.532841223041
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12802.532841223041
# Control only changes marginally.
# RUN  1 , total integrated cost =  12802.532841223041
# Improved over  1  iterations in  0.38626883702818304  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  866.61558787012 [5.15142639e+00 3.26172184e-16]
# 20 994 -----------------
# --------------------- 0
# simulation duration :  119.4
# no solution computed yet
# weight =  2316.871200128505
# set cost params:  1.0 0.0 2316.871200128505
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12802.532841223043
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12802.532841223043
# Control only changes marginally.
# RUN  1 , total integrated cost =  12802.532841223043
# Improved over  1  iterations in  0.3577947140438482  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  867.3413965701786 [5.15142639e+00 3.26172184e-16]
# 20 995 -----------------
# --------------------- 0
# simulation duration :  119.5
# no solution computed yet
# weight =  2316.7303054238187
# set cost params:  1.0 0.0 2316.7303054238187
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12802.532841223043
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12802.532841223043
# Control only changes marginally.
# RUN  1 , total integrated cost =  12802.532841223043
# Improved over  1  iterations in  0.35404226498212665  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  868.0672052702373 [5.15142639e+00 3.26172184e-16]
# 20 996 -----------------
# --------------------- 0
# simulation duration :  119.6
# no solution computed yet
# weight =  2316.589410719132
# set cost params:  1.0 0.0 2316.589410719132
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12802.532841223041
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12802.532841223041
# Control only changes marginally.
# RUN  1 , total integrated cost =  12802.532841223041
# Improved over  1  iterations in  0.3517517199506983  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  868.7930139702961 [5.15142639e+00 3.26172184e-16]
# 20 997 -----------------
# --------------------- 0
# simulation duration :  119.7
# no solution computed yet
# weight =  2316.448516014446
# set cost params:  1.0 0.0 2316.448516014446
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12802.532841223041
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12802.532841223041
# Control only changes marginally.
# RUN  1 , total integrated cost =  12802.532841223041
# Improved over  1  iterations in  0.353207197971642  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  869.5188226703548 [5.15142639e+00 3.26172184e-16]
# 20 998 -----------------
# --------------------- 0
# simulation duration :  119.8
# no solution computed yet
# weight =  2316.3076213097597
# set cost params:  1.0 0.0 2316.3076213097597
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12802.532841223043
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12802.532841223043
# Control only changes marginally.
# RUN  1 , total integrated cost =  12802.532841223043
# Improved over  1  iterations in  0.38278406800236553  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  870.2446313704136 [5.15142639e+00 3.26172184e-16]
# 20 999 -----------------
# --------------------- 0
# simulation duration :  119.9
# no solution computed yet
# weight =  2316.1667266050736
# set cost params:  1.0 0.0 2316.1667266050736
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12802.532841223043
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12802.532841223043
# Control only changes marginally.
# RUN  1 , total integrated cost =  12802.532841223043
# Improved over  1  iterations in  0.3703396039782092  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  870.9704400704723 [5.15142639e+00 3.26172184e-16]
# 20 1000 -----------------
# --------------------- 0
# simulation duration :  120.0
# no solution computed yet
# weight =  2316.025831900387
# set cost params:  1.0 0.0 2316.025831900387
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  12802.532841223043
# Gradient descend method:  None
# RUN  1 , total integrated cost =  12802.532841223043
# Control only changes marginally.
# RUN  1 , total integrated cost =  12802.532841223043
# Improved over  1  iterations in  0.3946194869931787  seconds by  0.0  percent.
# converged
# uncontrolled cost :  12801.807032522984
# cost splitting :  871.696248770531 [5.15142639e+00 3.26172184e-16]

# %%
i = 20
for j in [0,200,1000]:
    print("simulation duration = ", round(d_array[j],1))
    aln.params.duration = round(d_array[j],1)
    time_ = np.arange(-dur_pre,round(d_array[j]+dur_post+aln.params.dt,1),aln.params.dt)
    dur += dur_pre + dur_post
    target_e = [target[i][0]] * len(time_)
    target_i = [target[i][1]] * len(time_)

    fig, ax = plt.subplots(2,1, constrained_layout=True, figsize = (4,4) )
    ax[1].plot(time_, bestControl_[i][j][0,0,:], color = 'red')
    ax[0].plot(time_, bestState_[i][j][0,0,:], color= 'red')
    ax[1].plot(time_, bestControl_[i][j][0,1,:], color = 'blue')
    ax[0].plot(time_, bestState_[i][j][0,1,:], color= 'blue')
    ax[0].plot(time_, target_e, linestyle = '--', color='red')
    ax[0].plot(time_, target_i, linestyle = '--', color='blue')
    ax[0].set_xlim(-dur_pre,round(d_array[j]+dur_pre,1))
    ax[1].set_xlim(-dur_pre,round(d_array[j]+dur_pre,1))
    ax[0].axvspan(t0_array[j], t0_array[j]+20, alpha=0.2, color='gray')
    plt.show()
# Out:
# simulation duration =  20.0
# simulation duration =  40.0
# simulation duration =  120.0
