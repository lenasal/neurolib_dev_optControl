# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import sys
import pickle

path = os.getcwd().split(os.sep + 'GUI')[0]
if path not in sys.path:
    print("not here")
    sys.path.append(path)

from neurolib.models.aln import ALNModel
from neurolib.utils import plotFunctions as plotFunc
from neurolib.utils import costFunctions as cost
import neurolib.dashboard.functions as functions
import neurolib.dashboard.data as data
    
# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2 

#path = os.path.join(os.getcwd(), "plots")
# Out:
# not here

# %%
grid_data_file = os.path.join(os.getcwd().split('data')[0], 'bi.pickle')
print(grid_data_file)
with open(grid_data_file,'rb') as f:
    load_array= pickle.load(f)
exc = load_array[0]
inh = load_array[1]
print(len(exc))
# Out:
# /home/lena/Promotion/neurolib/GUI/current/gui/bi.pickle
# 147

# %%
aln = ALNModel()
N = aln.params.N

data.set_parameters(aln)

state_vars = aln.state_vars
init_vars = aln.init_vars

##############################################################
def setinit(init_vars_, model):
    state_vars = model.state_vars
    init_vars = model.init_vars
    for iv in range(len(init_vars)):
        for sv in range(len(state_vars)):
            if state_vars[sv] in init_vars[iv]:
                #print("set init vars ", )
                if model.params[init_vars[iv]].ndim == 2:
                    model.params[init_vars[iv]][0,:] = init_vars_[sv]
                else:
                    model.params[init_vars[iv]][0] = init_vars_[sv]
                    
##############################################################               
def setmaxmincontrol(max_c_c, min_c_c, max_c_r, min_c_r):
    import numpy as np
    
    max_cntrl = np.zeros(( 6 ))
    min_cntrl = np.zeros(( 6 ))
    
    max_cntrl[0] = max_c_c
    min_cntrl[0] = min_c_c
    max_cntrl[1] = max_c_c
    min_cntrl[1] = min_c_c
    max_cntrl[2] = max_c_r
    min_cntrl[2] = min_c_r
    max_cntrl[3] = max_c_r
    min_cntrl[3] = min_c_r
    max_cntrl[4] = max_c_r
    min_cntrl[4] = min_c_r
    max_cntrl[5] = max_c_r
    min_cntrl[5] = min_c_r
            
    return max_cntrl, min_cntrl

# %%
d_array = np.arange(500., 20, -0.1)
t0_array = d_array - 20.
t_pen = np.zeros(( t0_array.shape ))
for i in range(len(t_pen)):
    t_pen[i] = t0_array[i] / d_array[i]

# %%
bestControl_ = [None] * len(exc) 
bestState_ = [None] * len(exc) 
cost_ = [None] * len(exc) 
costnode_ = [None] * len(exc) 
weights_ = [None] * len(exc) 
convergence_ = [None] * len(exc) 

initVars = [None] * len(exc)
target = [None] * len(exc)
cost_uncontrolled = [None] * len(exc)
ws = [None] * len(exc)
conv = [None] * len(exc)
conv_shift = [None] * len(exc)

# %%
folder = str(os.getcwd().split('data_2')[1])
print(folder)
case = str(folder[1])

file_ = str(case + '_I.pickle')
# Out:
# /2

# %%
dur_pre = 10
dur_post = 10

n_pre = int(np.around(dur_pre/aln.params.dt + 1.,1))
n_post = int(np.around(dur_post/aln.params.dt + 1.,1))

tol = 1e-12
start_step = 10.
c_scheme = np.zeros(( 1,1 ))
c_scheme[0,0] = 1.
u_mat = np.identity(1)
u_scheme = np.array([[1.]])

c_var = [1]
p_var = [0]

if case in ['1', '2']:    # low to high
    max_I = [3., -3.]
else:
    max_I = [-3., 3.]
    
if case in ['1', '3']:    # sparsity
    factor_ws = 1.
    factor_we = 0.
    index_cost = 2
else:
    factor_ws = 0.
    factor_we = 1.
    index_cost = 1
    
    
maxC = [5., -5., 0.18, 0.]
max_cntrl, min_cntrl = setmaxmincontrol(maxC[0], maxC[1], maxC[2], maxC[3])

# %%
if os.path.isfile(file_) :
    print("file found")
    
    with open(file_,'rb') as f:
        load_array = pickle.load(f)

    bestControl_ = load_array[0]
    bestState_ = load_array[1]
    cost_ = load_array[2]
    costnode_ = load_array[3]
    weights_ = load_array[4]
# Out:
# file found

# %%
# get initial parameters and target states

i_range = range(83)
#i_range = [20]

data.set_parameters(aln)

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    aln.params.duration = 3000.
    
    control0 = aln.getZeroControl()
    control0 = functions.step_control(aln, maxI_ = max_I[0])

    aln.run(control=control0)
    
    target_rates = np.zeros((2))
    target_rates[0] = aln.rates_exc[0,-1] 
    target_rates[1] = aln.rates_inh[0,-1]

    control0 = functions.step_control(aln, maxI_ = max_I[1])
    aln.run(control=control0)

    init_state_vars = np.zeros(( len(state_vars) ))
    for j in range(len(state_vars)):
        if aln.state[state_vars[j]].size == 1:
            init_state_vars[j] = aln.state[state_vars[j]][0]
        else:
            init_state_vars[j] = aln.state[state_vars[j]][0,-1]

    initVars[i] = init_state_vars
    target[i] = [target_rates[0], target_rates[1]]
# Out:
# -------  0 0.4000000000000001 0.3500000000000001
# -------  1 0.4250000000000001 0.3500000000000001
# -------  2 0.4000000000000001 0.3750000000000001
# -------  3 0.4250000000000001 0.3750000000000001
# -------  4 0.4500000000000001 0.3750000000000001
# -------  5 0.4000000000000001 0.40000000000000013
# -------  6 0.4250000000000001 0.40000000000000013
# -------  7 0.4500000000000001 0.40000000000000013
# -------  8 0.47500000000000014 0.40000000000000013
# -------  9 0.4000000000000001 0.42500000000000016
# -------  10 0.4250000000000001 0.42500000000000016
# -------  11 0.4500000000000001 0.42500000000000016
# -------  12 0.47500000000000014 0.42500000000000016
# -------  13 0.4000000000000001 0.4500000000000002
# -------  14 0.4250000000000001 0.4500000000000002
# -------  15 0.4500000000000001 0.4500000000000002
# -------  16 0.47500000000000014 0.4500000000000002
# -------  17 0.5000000000000002 0.4500000000000002
# -------  18 0.4000000000000001 0.4750000000000002
# -------  19 0.4250000000000001 0.4750000000000002
# -------  20 0.4500000000000001 0.4750000000000002
# -------  21 0.47500000000000014 0.4750000000000002
# -------  22 0.5000000000000002 0.4750000000000002
# -------  23 0.5250000000000001 0.4750000000000002
# -------  24 0.4000000000000001 0.5000000000000002
# -------  25 0.4250000000000001 0.5000000000000002
# -------  26 0.4500000000000001 0.5000000000000002
# -------  27 0.47500000000000014 0.5000000000000002
# -------  28 0.5000000000000002 0.5000000000000002
# -------  29 0.5250000000000001 0.5000000000000002
# -------  30 0.4250000000000001 0.5250000000000002
# -------  31 0.4500000000000001 0.5250000000000002
# -------  32 0.47500000000000014 0.5250000000000002
# -------  33 0.5000000000000002 0.5250000000000002
# -------  34 0.5250000000000001 0.5250000000000002
# -------  35 0.5500000000000003 0.5250000000000002
# -------  36 0.4250000000000001 0.5500000000000003
# -------  37 0.4500000000000001 0.5500000000000003
# -------  38 0.47500000000000014 0.5500000000000003
# -------  39 0.5000000000000002 0.5500000000000003
# -------  40 0.5250000000000001 0.5500000000000003
# -------  41 0.5500000000000003 0.5500000000000003
# -------  42 0.4250000000000001 0.5750000000000003
# -------  43 0.4500000000000001 0.5750000000000003
# -------  44 0.47500000000000014 0.5750000000000003
# -------  45 0.5000000000000002 0.5750000000000003
# -------  46 0.5250000000000001 0.5750000000000003
# -------  47 0.5500000000000003 0.5750000000000003
# -------  48 0.4250000000000001 0.6000000000000003
# -------  49 0.4500000000000001 0.6000000000000003
# -------  50 0.47500000000000014 0.6000000000000003
# -------  51 0.5000000000000002 0.6000000000000003
# -------  52 0.5250000000000001 0.6000000000000003
# -------  53 0.5500000000000003 0.6000000000000003
# -------  54 0.5750000000000002 0.6000000000000003
# -------  55 0.4250000000000001 0.6250000000000003
# -------  56 0.4500000000000001 0.6250000000000003
# -------  57 0.47500000000000014 0.6250000000000003
# -------  58 0.5000000000000002 0.6250000000000003
# -------  59 0.5250000000000001 0.6250000000000003
# -------  60 0.5500000000000003 0.6250000000000003
# -------  61 0.5750000000000002 0.6250000000000003
# -------  62 0.4250000000000001 0.6500000000000004
# -------  63 0.4500000000000001 0.6500000000000004
# -------  64 0.47500000000000014 0.6500000000000004
# -------  65 0.5000000000000002 0.6500000000000004
# -------  66 0.5250000000000001 0.6500000000000004
# -------  67 0.5500000000000003 0.6500000000000004
# -------  68 0.5750000000000002 0.6500000000000004
# -------  69 0.4250000000000001 0.6750000000000004
# -------  70 0.4500000000000001 0.6750000000000004
# -------  71 0.47500000000000014 0.6750000000000004
# -------  72 0.5000000000000002 0.6750000000000004
# -------  73 0.5250000000000001 0.6750000000000004
# -------  74 0.5500000000000003 0.6750000000000004
# -------  75 0.5750000000000002 0.6750000000000004
# -------  76 0.4250000000000001 0.7000000000000004
# -------  77 0.4500000000000001 0.7000000000000004
# -------  78 0.47500000000000014 0.7000000000000004
# -------  79 0.5000000000000002 0.7000000000000004
# -------  80 0.5250000000000001 0.7000000000000004
# -------  81 0.5500000000000003 0.7000000000000004
# -------  82 0.5750000000000002 0.7000000000000004

# %%
# get uncontrolled cost

data.set_parameters(aln)

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    dur = d_array[0]
    aln.params.duration = dur
    
    target_ = aln.getZeroTarget()
    target_[:,0,:] = target[i][0]
    target_[:,1,:] = target[i][1]
            
    cost.setParams(1.0, 0.0, 0.0)

    setinit(initVars[i], aln)
    control0 = aln.getZeroControl()

    # "HS", "FR", "PR", "HZ"
    cgv = None
    max_it = 0

    bestControl_init_, bestState_init_, cost_init_, runtime_init_, grad_init_, phi_init_, phi1_, costnode_init_ = aln.A1(
        control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
        prec_variables_ = p_var, transition_time_ = t_pen[0])
    
    cost_uncontrolled[i] = cost_init_[0]
# Out:
# -------  0 0.4000000000000001 0.3500000000000001
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  146855.39702821904
# RUN  0 , total integrated cost =  146855.39702821904
# Gradient descend method:  None
# RUN  0 , total integrated cost =  146855.39702821904
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  1 0.4250000000000001 0.3500000000000001
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  244234.70503349282
# RUN  0 , total integrated cost =  244234.70503349282
# Gradient descend method:  None
# RUN  0 , total integrated cost =  244234.70503349282
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  2 0.4000000000000001 0.3750000000000001
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  137806.3558139294
# RUN  0 , total integrated cost =  137806.3558139294
# Gradient descend method:  None
# RUN  0 , total integrated cost =  137806.3558139294
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  3 0.4250000000000001 0.3750000000000001
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  241480.3484875782
# RUN  0 , total integrated cost =  241480.3484875782
# Gradient descend method:  None
# RUN  0 , total integrated cost =  241480.3484875782
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  4 0.4500000000000001 0.3750000000000001
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  338432.51439444604
# RUN  0 , total integrated cost =  338432.51439444604
# Gradient descend method:  None
# RUN  0 , total integrated cost =  338432.51439444604
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  5 0.4000000000000001 0.40000000000000013
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  126823.61408372025
# RUN  0 , total integrated cost =  126823.61408372025
# Gradient descend method:  None
# RUN  0 , total integrated cost =  126823.61408372025
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  6 0.4250000000000001 0.40000000000000013
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  234849.86448361105
# RUN  0 , total integrated cost =  234849.86448361105
# Gradient descend method:  None
# RUN  0 , total integrated cost =  234849.86448361105
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  7 0.4500000000000001 0.40000000000000013
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  337311.3569640121
# RUN  0 , total integrated cost =  337311.3569640121
# Gradient descend method:  None
# RUN  0 , total integrated cost =  337311.3569640121
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  8 0.47500000000000014 0.40000000000000013
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  436683.03613383934
# RUN  0 , total integrated cost =  436683.03613383934
# Gradient descend method:  None
# RUN  0 , total integrated cost =  436683.03613383934
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  9 0.4000000000000001 0.42500000000000016
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  115502.5972235114
# RUN  0 , total integrated cost =  115502.5972235114
# Gradient descend method:  None
# RUN  0 , total integrated cost =  115502.5972235114
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  10 0.4250000000000001 0.42500000000000016
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  226698.47715197233
# RUN  0 , total integrated cost =  226698.47715197233
# Gradient descend method:  None
# RUN  0 , total integrated cost =  226698.47715197233
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  11 0.4500000000000001 0.42500000000000016
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  331196.46910670475
# RUN  0 , total integrated cost =  331196.46910670475
# Gradient descend method:  None
# RUN  0 , total integrated cost =  331196.46910670475
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  12 0.47500000000000014 0.42500000000000016
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  437181.9504061447
# RUN  0 , total integrated cost =  437181.9504061447
# Gradient descend method:  None
# RUN  0 , total integrated cost =  437181.9504061447
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  13 0.4000000000000001 0.4500000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  103932.40255255786
# RUN  0 , total integrated cost =  103932.40255255786
# Gradient descend method:  None
# RUN  0 , total integrated cost =  103932.40255255786
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  14 0.4250000000000001 0.4500000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  218854.09939826332
# RUN  0 , total integrated cost =  218854.09939826332
# Gradient descend method:  None
# RUN  0 , total integrated cost =  218854.09939826332
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  15 0.4500000000000001 0.4500000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  323897.4690366888
# RUN  0 , total integrated cost =  323897.4690366888
# Gradient descend method:  None
# RUN  0 , total integrated cost =  323897.4690366888
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  16 0.47500000000000014 0.4500000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  431451.8938983858
# RUN  0 , total integrated cost =  431451.8938983858
# Gradient descend method:  None
# RUN  0 , total integrated cost =  431451.8938983858
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  17 0.5000000000000002 0.4500000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  541570.0682516823
# RUN  0 , total integrated cost =  541570.0682516823
# Gradient descend method:  None
# RUN  0 , total integrated cost =  541570.0682516823
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  18 0.4000000000000001 0.4750000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  91340.63373509991
# RUN  0 , total integrated cost =  91340.63373509991
# Gradient descend method:  None
# RUN  0 , total integrated cost =  91340.63373509991
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  19 0.4250000000000001 0.4750000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  211572.5759679924
# RUN  0 , total integrated cost =  211572.5759679924
# Gradient descend method:  None
# RUN  0 , total integrated cost =  211572.5759679924
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  20 0.4500000000000001 0.4750000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  316931.9421284
# RUN  0 , total integrated cost =  316931.9421284
# Gradient descend method:  None
# RUN  0 , total integrated cost =  316931.9421284
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  21 0.47500000000000014 0.4750000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  424684.0949542926
# RUN  0 , total integrated cost =  424684.0949542926
# Gradient descend method:  None
# RUN  0 , total integrated cost =  424684.0949542926
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  22 0.5000000000000002 0.4750000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  536554.4931300428
# RUN  0 , total integrated cost =  536554.4931300428
# Gradient descend method:  None
# RUN  0 , total integrated cost =  536554.4931300428
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  23 0.5250000000000001 0.4750000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  649680.5756879131
# RUN  0 , total integrated cost =  649680.5756879131
# Gradient descend method:  None
# RUN  0 , total integrated cost =  649680.5756879131
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  24 0.4000000000000001 0.5000000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  74168.6027044929
# RUN  0 , total integrated cost =  74168.6027044929
# Gradient descend method:  None
# RUN  0 , total integrated cost =  74168.6027044929
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  25 0.4250000000000001 0.5000000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  204814.76624161197
# RUN  0 , total integrated cost =  204814.76624161197
# Gradient descend method:  None
# RUN  0 , total integrated cost =  204814.76624161197
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  26 0.4500000000000001 0.5000000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  310502.0037410387
# RUN  0 , total integrated cost =  310502.0037410387
# Gradient descend method:  None
# RUN  0 , total integrated cost =  310502.0037410387
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  27 0.47500000000000014 0.5000000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  418236.1198402083
# RUN  0 , total integrated cost =  418236.1198402083
# Gradient descend method:  None
# RUN  0 , total integrated cost =  418236.1198402083
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  28 0.5000000000000002 0.5000000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  530282.4726497299
# RUN  0 , total integrated cost =  530282.4726497299
# Gradient descend method:  None
# RUN  0 , total integrated cost =  530282.4726497299
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  29 0.5250000000000001 0.5000000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  646521.6732350034
# RUN  0 , total integrated cost =  646521.6732350034
# Gradient descend method:  None
# RUN  0 , total integrated cost =  646521.6732350034
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  30 0.4250000000000001 0.5250000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  198505.2946572739
# RUN  0 , total integrated cost =  198505.2946572739
# Gradient descend method:  None
# RUN  0 , total integrated cost =  198505.2946572739
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  31 0.4500000000000001 0.5250000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  304530.5505769217
# RUN  0 , total integrated cost =  304530.5505769217
# Gradient descend method:  None
# RUN  0 , total integrated cost =  304530.5505769217
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  32 0.47500000000000014 0.5250000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  412227.1647591634
# RUN  0 , total integrated cost =  412227.1647591634
# Gradient descend method:  None
# RUN  0 , total integrated cost =  412227.1647591634
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  33 0.5000000000000002 0.5250000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  524212.5915485861
# RUN  0 , total integrated cost =  524212.5915485861
# Gradient descend method:  None
# RUN  0 , total integrated cost =  524212.5915485861
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  34 0.5250000000000001 0.5250000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  640916.4738461657
# RUN  0 , total integrated cost =  640916.4738461657
# Gradient descend method:  None
# RUN  0 , total integrated cost =  640916.4738461657
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  35 0.5500000000000003 0.5250000000000002
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  760013.3898018681
# RUN  0 , total integrated cost =  760013.3898018681
# Gradient descend method:  None
# RUN  0 , total integrated cost =  760013.3898018681
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  36 0.4250000000000001 0.5500000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  192617.3150952127
# RUN  0 , total integrated cost =  192617.3150952127
# Gradient descend method:  None
# RUN  0 , total integrated cost =  192617.3150952127
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  37 0.4500000000000001 0.5500000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  299002.14935773576
# RUN  0 , total integrated cost =  299002.14935773576
# Gradient descend method:  None
# RUN  0 , total integrated cost =  299002.14935773576
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  38 0.47500000000000014 0.5500000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  406664.10745913326
# RUN  0 , total integrated cost =  406664.10745913326
# Gradient descend method:  None
# RUN  0 , total integrated cost =  406664.10745913326
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  39 0.5000000000000002 0.5500000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  518533.1123942334
# RUN  0 , total integrated cost =  518533.1123942334
# Gradient descend method:  None
# RUN  0 , total integrated cost =  518533.1123942334
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  40 0.5250000000000001 0.5500000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  635238.4079859259
# RUN  0 , total integrated cost =  635238.4079859259
# Gradient descend method:  None
# RUN  0 , total integrated cost =  635238.4079859259
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  41 0.5500000000000003 0.5500000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  756194.7962365937
# RUN  0 , total integrated cost =  756194.7962365937
# Gradient descend method:  None
# RUN  0 , total integrated cost =  756194.7962365937
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  42 0.4250000000000001 0.5750000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  187081.7746701702
# RUN  0 , total integrated cost =  187081.7746701702
# Gradient descend method:  None
# RUN  0 , total integrated cost =  187081.7746701702
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  43 0.4500000000000001 0.5750000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  293856.7484005505
# RUN  0 , total integrated cost =  293856.7484005505
# Gradient descend method:  None
# RUN  0 , total integrated cost =  293856.7484005505
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  44 0.47500000000000014 0.5750000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  401498.6789492869
# RUN  0 , total integrated cost =  401498.6789492869
# Gradient descend method:  None
# RUN  0 , total integrated cost =  401498.6789492869
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  45 0.5000000000000002 0.5750000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  513234.6635746044
# RUN  0 , total integrated cost =  513234.6635746044
# Gradient descend method:  None
# RUN  0 , total integrated cost =  513234.6635746044
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  46 0.5250000000000001 0.5750000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  629845.1306750294
# RUN  0 , total integrated cost =  629845.1306750294
# Gradient descend method:  None
# RUN  0 , total integrated cost =  629845.1306750294
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  47 0.5500000000000003 0.5750000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  751175.9333805718
# RUN  0 , total integrated cost =  751175.9333805718
# Gradient descend method:  None
# RUN  0 , total integrated cost =  751175.9333805718
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  48 0.4250000000000001 0.6000000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  181882.521994222
# RUN  0 , total integrated cost =  181882.521994222
# Gradient descend method:  None
# RUN  0 , total integrated cost =  181882.521994222
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  49 0.4500000000000001 0.6000000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  289049.15272407274
# RUN  0 , total integrated cost =  289049.15272407274
# Gradient descend method:  None
# RUN  0 , total integrated cost =  289049.15272407274
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  50 0.47500000000000014 0.6000000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  396670.24943190784
# RUN  0 , total integrated cost =  396670.24943190784
# Gradient descend method:  None
# RUN  0 , total integrated cost =  396670.24943190784
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  51 0.5000000000000002 0.6000000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  508302.3902818461
# RUN  0 , total integrated cost =  508302.3902818461
# Gradient descend method:  None
# RUN  0 , total integrated cost =  508302.3902818461
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  52 0.5250000000000001 0.6000000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  624775.8829897492
# RUN  0 , total integrated cost =  624775.8829897492
# Gradient descend method:  None
# RUN  0 , total integrated cost =  624775.8829897492
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  53 0.5500000000000003 0.6000000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  746144.5805987157
# RUN  0 , total integrated cost =  746144.5805987157
# Gradient descend method:  None
# RUN  0 , total integrated cost =  746144.5805987157
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  54 0.5750000000000002 0.6000000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  870523.2701234882
# RUN  0 , total integrated cost =  870523.2701234882
# Gradient descend method:  None
# RUN  0 , total integrated cost =  870523.2701234882
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  55 0.4250000000000001 0.6250000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  176973.53086129532
# RUN  0 , total integrated cost =  176973.53086129532
# Gradient descend method:  None
# RUN  0 , total integrated cost =  176973.53086129532
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  56 0.4500000000000001 0.6250000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  284563.6049902908
# RUN  0 , total integrated cost =  284563.6049902908
# Gradient descend method:  None
# RUN  0 , total integrated cost =  284563.6049902908
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  57 0.47500000000000014 0.6250000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  392168.01147703634
# RUN  0 , total integrated cost =  392168.01147703634
# Gradient descend method:  None
# RUN  0 , total integrated cost =  392168.01147703634
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  58 0.5000000000000002 0.6250000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  503700.90762437455
# RUN  0 , total integrated cost =  503700.90762437455
# Gradient descend method:  None
# RUN  0 , total integrated cost =  503700.90762437455
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  59 0.5250000000000001 0.6250000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  620034.5060788749
# RUN  0 , total integrated cost =  620034.5060788749
# Gradient descend method:  None
# RUN  0 , total integrated cost =  620034.5060788749
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  60 0.5500000000000003 0.6250000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  741333.3077944894
# RUN  0 , total integrated cost =  741333.3077944894
# Gradient descend method:  None
# RUN  0 , total integrated cost =  741333.3077944894
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  61 0.5750000000000002 0.6250000000000003
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  866710.8536802017
# RUN  0 , total integrated cost =  866710.8536802017
# Gradient descend method:  None
# RUN  0 , total integrated cost =  866710.8536802017
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  62 0.4250000000000001 0.6500000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  172327.22420179544
# RUN  0 , total integrated cost =  172327.22420179544
# Gradient descend method:  None
# RUN  0 , total integrated cost =  172327.22420179544
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  63 0.4500000000000001 0.6500000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  280358.4423685195
# RUN  0 , total integrated cost =  280358.4423685195
# Gradient descend method:  None
# RUN  0 , total integrated cost =  280358.4423685195
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  64 0.47500000000000014 0.6500000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  387959.78150038864
# RUN  0 , total integrated cost =  387959.78150038864
# Gradient descend method:  None
# RUN  0 , total integrated cost =  387959.78150038864
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  65 0.5000000000000002 0.6500000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  499381.32678329153
# RUN  0 , total integrated cost =  499381.32678329153
# Gradient descend method:  None
# RUN  0 , total integrated cost =  499381.32678329153
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  66 0.5250000000000001 0.6500000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  615596.4660225171
# RUN  0 , total integrated cost =  615596.4660225171
# Gradient descend method:  None
# RUN  0 , total integrated cost =  615596.4660225171
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  67 0.5500000000000003 0.6500000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  736788.193418642
# RUN  0 , total integrated cost =  736788.193418642
# Gradient descend method:  None
# RUN  0 , total integrated cost =  736788.193418642
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  68 0.5750000000000002 0.6500000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  862467.9253654084
# RUN  0 , total integrated cost =  862467.9253654084
# Gradient descend method:  None
# RUN  0 , total integrated cost =  862467.9253654084
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  69 0.4250000000000001 0.6750000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  167933.86239870195
# RUN  0 , total integrated cost =  167933.86239870195
# Gradient descend method:  None
# RUN  0 , total integrated cost =  167933.86239870195
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  70 0.4500000000000001 0.6750000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  276399.77278526267
# RUN  0 , total integrated cost =  276399.77278526267
# Gradient descend method:  None
# RUN  0 , total integrated cost =  276399.77278526267
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  71 0.47500000000000014 0.6750000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  384005.59692905797
# RUN  0 , total integrated cost =  384005.59692905797
# Gradient descend method:  None
# RUN  0 , total integrated cost =  384005.59692905797
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  72 0.5000000000000002 0.6750000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  495331.1329655588
# RUN  0 , total integrated cost =  495331.1329655588
# Gradient descend method:  None
# RUN  0 , total integrated cost =  495331.1329655588
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  73 0.5250000000000001 0.6750000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  611432.0686370909
# RUN  0 , total integrated cost =  611432.0686370909
# Gradient descend method:  None
# RUN  0 , total integrated cost =  611432.0686370909
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  74 0.5500000000000003 0.6750000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  732509.8149166821
# RUN  0 , total integrated cost =  732509.8149166821
# Gradient descend method:  None
# RUN  0 , total integrated cost =  732509.8149166821
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  75 0.5750000000000002 0.6750000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  858276.8196420075
# RUN  0 , total integrated cost =  858276.8196420075
# Gradient descend method:  None
# RUN  0 , total integrated cost =  858276.8196420075
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  76 0.4250000000000001 0.7000000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  163736.8297408659
# RUN  0 , total integrated cost =  163736.8297408659
# Gradient descend method:  None
# RUN  0 , total integrated cost =  163736.8297408659
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  77 0.4500000000000001 0.7000000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  272681.6442786969
# RUN  0 , total integrated cost =  272681.6442786969
# Gradient descend method:  None
# RUN  0 , total integrated cost =  272681.6442786969
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  78 0.47500000000000014 0.7000000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  380284.89211629244
# RUN  0 , total integrated cost =  380284.89211629244
# Gradient descend method:  None
# RUN  0 , total integrated cost =  380284.89211629244
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  79 0.5000000000000002 0.7000000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  491528.53199543635
# RUN  0 , total integrated cost =  491528.53199543635
# Gradient descend method:  None
# RUN  0 , total integrated cost =  491528.53199543635
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  80 0.5250000000000001 0.7000000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  607506.209585381
# RUN  0 , total integrated cost =  607506.209585381
# Gradient descend method:  None
# RUN  0 , total integrated cost =  607506.209585381
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  81 0.5500000000000003 0.7000000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  728478.2773809158
# RUN  0 , total integrated cost =  728478.2773809158
# Gradient descend method:  None
# RUN  0 , total integrated cost =  728478.2773809158
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.
# -------  82 0.5750000000000002 0.7000000000000004
# set cost params:  1.0 0.0 0.0
# interpolate adjoint :  True True True
# initial cost =  854238.9955664313
# RUN  0 , total integrated cost =  854238.9955664313
# Gradient descend method:  None
# RUN  0 , total integrated cost =  854238.9955664313
# Improved over  0  iterations in  0.0  seconds by  0.0  percent.

# %%
bad = []

# %%
cgv = None
j = 0

wp = 1.

for i in i_range:
    print("------- ", i, exc[i], inh[i])
     
    if type(bestControl_[i]) != type(None) or i in bad:
        continue
    
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
        
    found_exponent = False
    found_digit_0 = False
    found_digit_1 = False
    exponent = 5
    sig_digit = [1., 0.]
    
    while not found_digit_1:
        
        if exponent < -10:
            bad.append(i)
            break
        
        ws[i] = sig_digit[0] * 10**exponent + sig_digit[1] * 10**(exponent-1.)
    
        dur = d_array[0]
        aln.params.duration = dur
        setinit(initVars[i], aln)

        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        control0 = aln.getZeroControl()
        cost.setParams(wp, 0., ws[i])
        max_it = int(10)
        if found_digit_0:
            max_it = int(50)

        bestControl_[i], bestState_[i], cost_[i], runtime_, grad_, phi_, phi1_, costnode_[i] = aln.A1(
            control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
            prec_variables_ = p_var, transition_time_ = t_pen[0])
        
        if found_exponent == False and cost_[i][-1] == 0.:
            exponent -= 1
            continue
        elif found_exponent == False and found_digit_0 == False:
            found_exponent = True
            sig_digit[0] = 9.
        elif found_exponent == True and found_digit_0 == False and cost_[i][-1] == 0.:
            sig_digit[0] -= 1.
        elif found_exponent == True and found_digit_0 == False:
            found_digit_0 = True
            sig_digit[1] = 9.
        elif found_exponent == True and found_digit_0 == True and found_digit_1 == False and cost_[i][-1] == 0.:
            sig_digit[1] -= 1.
        elif found_exponent == True and found_digit_0 == True and found_digit_1 == False:
            print("sparsity weight = ", ws[i])
                        
            if True:
                plot_time_array = np.arange(0.,round(dur+aln.params.dt,1),aln.params.dt)
                target_ = aln.getZeroTarget()
                target_[:,0,:] = target[i][0]
                target_[:,1,:] = target[i][1]

                fig, ax = plt.subplots(3,1, constrained_layout=True, figsize = (4,8) )
                ax[1].plot(plot_time_array, bestControl_[i][0,0,n_pre-1:-n_post+1], color = 'red')
                ax[0].plot(plot_time_array, bestState_[i][0,0,n_pre-1:-n_post+1], color= 'red')
                ax[1].plot(plot_time_array, bestControl_[i][0,1,n_pre-1:-n_post+1], color = 'blue')
                ax[0].plot(plot_time_array, bestState_[i][0,1,n_pre-1:-n_post+1], color= 'blue')
                ax[0].plot(plot_time_array, target_[0,0,n_pre-1:-n_post+1], linestyle = '--', color='red')
                ax[0].plot(plot_time_array, target_[0,1,n_pre-1:-n_post+1], linestyle = '--', color='blue')


                ax[2].plot(plot_time_array, phi_[0,0,:], color = 'red')
                ax[2].plot(plot_time_array, phi_[0,1,:], color = 'blue')
                for k in range(3):
                    ax[k].set_xlim(0.,dur)
                    ax[k].axvspan(dur*t_pen[0], dur, alpha=0.2, color='gray')
                plt.show()

            break   
            
        with open(file_,'wb') as f:
            pickle.dump([bestControl_, bestState_, cost_, costnode_, weights_], f)

        print('uncontrolled cost : ', cost_uncontrolled[i])
        print('cost splitting : ', costnode_[i][0][0][0], costnode_[i][2][0][:2])
# Out:
# -------  0 0.4000000000000001 0.3500000000000001
# -------  1 0.4250000000000001 0.3500000000000001
# -------  2 0.4000000000000001 0.3750000000000001
# -------  3 0.4250000000000001 0.3750000000000001
# -------  4 0.4500000000000001 0.3750000000000001
# -------  5 0.4000000000000001 0.40000000000000013
# -------  6 0.4250000000000001 0.40000000000000013
# -------  7 0.4500000000000001 0.40000000000000013
# -------  8 0.47500000000000014 0.40000000000000013
# -------  9 0.4000000000000001 0.42500000000000016
# -------  10 0.4250000000000001 0.42500000000000016
# -------  11 0.4500000000000001 0.42500000000000016
# -------  12 0.47500000000000014 0.42500000000000016
# -------  13 0.4000000000000001 0.4500000000000002
# -------  14 0.4250000000000001 0.4500000000000002
# -------  15 0.4500000000000001 0.4500000000000002
# -------  16 0.47500000000000014 0.4500000000000002
# -------  17 0.5000000000000002 0.4500000000000002
# -------  18 0.4000000000000001 0.4750000000000002
# -------  19 0.4250000000000001 0.4750000000000002
# -------  20 0.4500000000000001 0.4750000000000002
# -------  21 0.47500000000000014 0.4750000000000002
# -------  22 0.5000000000000002 0.4750000000000002
# -------  23 0.5250000000000001 0.4750000000000002
# -------  24 0.4000000000000001 0.5000000000000002
# -------  25 0.4250000000000001 0.5000000000000002
# -------  26 0.4500000000000001 0.5000000000000002
# -------  27 0.47500000000000014 0.5000000000000002
# -------  28 0.5000000000000002 0.5000000000000002
# -------  29 0.5250000000000001 0.5000000000000002
# -------  30 0.4250000000000001 0.5250000000000002
# -------  31 0.4500000000000001 0.5250000000000002
# -------  32 0.47500000000000014 0.5250000000000002
# -------  33 0.5000000000000002 0.5250000000000002
# -------  34 0.5250000000000001 0.5250000000000002
# -------  35 0.5500000000000003 0.5250000000000002
# -------  36 0.4250000000000001 0.5500000000000003
# -------  37 0.4500000000000001 0.5500000000000003
# -------  38 0.47500000000000014 0.5500000000000003
# -------  39 0.5000000000000002 0.5500000000000003
# -------  40 0.5250000000000001 0.5500000000000003
# -------  41 0.5500000000000003 0.5500000000000003
# -------  42 0.4250000000000001 0.5750000000000003
# -------  43 0.4500000000000001 0.5750000000000003
# -------  44 0.47500000000000014 0.5750000000000003
# -------  45 0.5000000000000002 0.5750000000000003
# -------  46 0.5250000000000001 0.5750000000000003
# -------  47 0.5500000000000003 0.5750000000000003
# -------  48 0.4250000000000001 0.6000000000000003
# -------  49 0.4500000000000001 0.6000000000000003
# -------  50 0.47500000000000014 0.6000000000000003
# -------  51 0.5000000000000002 0.6000000000000003
# -------  52 0.5250000000000001 0.6000000000000003
# -------  53 0.5500000000000003 0.6000000000000003
# -------  54 0.5750000000000002 0.6000000000000003
# -------  55 0.4250000000000001 0.6250000000000003
# -------  56 0.4500000000000001 0.6250000000000003
# -------  57 0.47500000000000014 0.6250000000000003
# -------  58 0.5000000000000002 0.6250000000000003
# -------  59 0.5250000000000001 0.6250000000000003
# -------  60 0.5500000000000003 0.6250000000000003
# -------  61 0.5750000000000002 0.6250000000000003
# -------  62 0.4250000000000001 0.6500000000000004
# -------  63 0.4500000000000001 0.6500000000000004
# -------  64 0.47500000000000014 0.6500000000000004
# -------  65 0.5000000000000002 0.6500000000000004
# -------  66 0.5250000000000001 0.6500000000000004
# -------  67 0.5500000000000003 0.6500000000000004
# -------  68 0.5750000000000002 0.6500000000000004
# -------  69 0.4250000000000001 0.6750000000000004
# -------  70 0.4500000000000001 0.6750000000000004
# set cost params:  1.0 0.0 100000.0
# interpolate adjoint :  True True True
# initial cost =  276399.77278526267
# RUN  0 , total integrated cost =  276399.77278526267
# Gradient descend method:  None
# RUN  1 , total integrated cost =  276399.77278526267
# Control only changes marginally.
# RUN  1 , total integrated cost =  276399.77278526267
# Improved over  1  iterations in  0.09749604100943543  seconds by  0.0  percent.
# set cost params:  1.0 0.0 10000.0
# interpolate adjoint :  True True True
# initial cost =  276399.77278526267
# RUN  0 , total integrated cost =  276399.77278526267
# Gradient descend method:  None
# RUN  1 , total integrated cost =  276399.77278526267
# Control only changes marginally.
# RUN  1 , total integrated cost =  276399.77278526267
# Improved over  1  iterations in  0.1111702150083147  seconds by  0.0  percent.
# set cost params:  1.0 0.0 1000.0
# interpolate adjoint :  True True True
# initial cost =  276399.77278526267
# RUN  0 , total integrated cost =  276399.77278526267
# Gradient descend method:  None
# RUN  1 , total integrated cost =  276399.77278526267
# Control only changes marginally.
# RUN  1 , total integrated cost =  276399.77278526267
# Improved over  1  iterations in  0.10496870297356509  seconds by  0.0  percent.
# set cost params:  1.0 0.0 100.0
# interpolate adjoint :  True True True
# initial cost =  276399.77278526267
# RUN  0 , total integrated cost =  276399.77278526267
# Gradient descend method:  None
# RUN  1 , total integrated cost =  276399.77278526267
# Control only changes marginally.
# RUN  1 , total integrated cost =  276399.77278526267
# Improved over  1  iterations in  0.10695702099474147  seconds by  0.0  percent.
# set cost params:  1.0 0.0 10.0
# interpolate adjoint :  True True True
# initial cost =  276399.77278526267
# RUN  0 , total integrated cost =  276399.77278526267
# Gradient descend method:  None
# RUN  1 , total integrated cost =  276399.77278526267
# Control only changes marginally.
# RUN  1 , total integrated cost =  276399.77278526267
# Improved over  1  iterations in  0.10599210701184347  seconds by  0.0  percent.
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  276399.77278526267
# RUN  0 , total integrated cost =  276399.77278526267
# Gradient descend method:  None
# RUN  1 , total integrated cost =  276399.77278526267
# Control only changes marginally.
# RUN  1 , total integrated cost =  276399.77278526267
# Improved over  1  iterations in  0.10937031000503339  seconds by  0.0  percent.
# set cost params:  1.0 0.0 0.1
# interpolate adjoint :  True True True
# initial cost =  276399.77278526267
# RUN  0 , total integrated cost =  276399.77278526267
# Gradient descend method:  None
# RUN  1 , total integrated cost =  276399.77278526267
# Control only changes marginally.
# RUN  1 , total integrated cost =  276399.77278526267
# Improved over  1  iterations in  0.17244353497517295  seconds by  0.0  percent.
# set cost params:  1.0 0.0 0.01
# interpolate adjoint :  True True True
# initial cost =  276399.77278526267
# RUN  0 , total integrated cost =  276399.77278526267
# Gradient descend method:  None
# RUN  1 , total integrated cost =  276399.77278526267
# Control only changes marginally.
# RUN  1 , total integrated cost =  276399.77278526267
# Improved over  1  iterations in  0.11105073598446324  seconds by  0.0  percent.
# set cost params:  1.0 0.0 0.001
# interpolate adjoint :  True True True
# initial cost =  276399.77278526267
# RUN  0 , total integrated cost =  276399.77278526267
# Gradient descend method:  None
# RUN  1 , total integrated cost =  276399.77278526267
# Control only changes marginally.
# RUN  1 , total integrated cost =  276399.77278526267
# Improved over  1  iterations in  0.11221376300090924  seconds by  0.0  percent.
# set cost params:  1.0 0.0 0.0001
# interpolate adjoint :  True True True
# initial cost =  276399.77278526267
# RUN  0 , total integrated cost =  276399.77278526267
# Gradient descend method:  None
# RUN  1 , total integrated cost =  276399.7727852617
# RUN  2 , total integrated cost =  276399.7727852617
# Control only changes marginally.
# RUN  2 , total integrated cost =  276399.7727852617
# Improved over  2  iterations in  0.22615457698702812  seconds by  3.552713678800501e-13  percent.
# set cost params:  1.0 0.0 1e-05
# interpolate adjoint :  True True True
# initial cost =  276399.77278526267
# RUN  0 , total integrated cost =  276399.77278526267
# Gradient descend method:  None
# RUN  1 , total integrated cost =  101220.44924072403
# RUN  2 , total integrated cost =  76675.60464647529
# RUN  3 , total integrated cost =  14.447468576498759
# RUN  4 , total integrated cost =  14.447468576498759
# RUN  5 , total integrated cost =  nan
# RUN  6 , total integrated cost =  nan
# RUN  7 , total integrated cost =  nan
# RUN  8 , total integrated cost =  nan
# RUN  9 , total integrated cost =  nan
# RUN  10 , total integrated cost =  nan
# RUN  10 , total integrated cost =  nan
# Improved over  10  iterations in  3.1399116160173435  seconds by  nan  percent.
# uncontrolled cost :  276399.77278526267
# cost splitting :  92950.30414676908 [ 0. nan]
# set cost params:  1.0 0.0 9e-05
# interpolate adjoint :  True True True
# initial cost =  276399.77278526267
# RUN  0 , total integrated cost =  276399.77278526267
# Gradient descend method:  None
# RUN  1 , total integrated cost =  276399.77278526145
# RUN  2 , total integrated cost =  276399.7727852612
# RUN  3 , total integrated cost =  276399.7727852612
# Control only changes marginally.
# RUN  3 , total integrated cost =  276399.7727852612
# Improved over  3  iterations in  0.31156109998119064  seconds by  5.258016244624741e-13  percent.
# uncontrolled cost :  276399.77278526267
# cost splitting :  11109.049056156107 [0.00000000e+00 4.47574132e-05]
# set cost params:  1.0 0.0 8e-05
# interpolate adjoint :  True True True
# initial cost =  276399.77278526267
# RUN  0 , total integrated cost =  276399.77278526267
# Gradient descend method:  None
# RUN  1 , total integrated cost =  101220.45000706965
# RUN  2 , total integrated cost =  76675.6114448116
# RUN  3 , total integrated cost =  14.455125001628343
# RUN  4 , total integrated cost =  14.455125001628343
# RUN  5 , total integrated cost =  nan
# RUN  6 , total integrated cost =  nan
# RUN  7 , total integrated cost =  nan
# RUN  8 , total integrated cost =  nan
# RUN  9 , total integrated cost =  nan
# RUN  10 , total integrated cost =  nan
# RUN  10 , total integrated cost =  nan
# Improved over  10  iterations in  2.6212074770010076  seconds by  nan  percent.
# uncontrolled cost :  276399.77278526267
# cost splitting :  92950.30414676908 [ 0. nan]
# set cost params:  1.0 0.0 8.900000000000001e-05
# interpolate adjoint :  True True True
# initial cost =  276399.77278526267
# RUN  0 , total integrated cost =  276399.77278526267
# Gradient descend method:  None
# RUN  1 , total integrated cost =  276399.7727852614
# RUN  2 , total integrated cost =  276399.77278526116
# RUN  3 , total integrated cost =  276399.77278526116
# Control only changes marginally.
# RUN  3 , total integrated cost =  276399.77278526116
# Improved over  3  iterations in  0.23901230399496853  seconds by  5.400124791776761e-13  percent.
# uncontrolled cost :  276399.77278526267
# cost splitting :  11109.04905615611 [0.00000000e+00 4.39037345e-05]
# set cost params:  1.0 0.0 8.800000000000001e-05
# interpolate adjoint :  True True True
# initial cost =  276399.77278526267
# RUN  0 , total integrated cost =  276399.77278526267
# Gradient descend method:  None
# RUN  1 , total integrated cost =  276399.77278526133
# RUN  2 , total integrated cost =  276399.7727852611
# RUN  3 , total integrated cost =  276399.7727852611
# Control only changes marginally.
# RUN  3 , total integrated cost =  276399.7727852611
# Improved over  3  iterations in  0.37293371101259254  seconds by  5.684341886080801e-13  percent.
# uncontrolled cost :  276399.77278526267
# cost splitting :  11109.04905615611 [0.00000000e+00 4.39069895e-05]
# set cost params:  1.0 0.0 8.7e-05
# interpolate adjoint :  True True True
# initial cost =  276399.77278526267
# RUN  0 , total integrated cost =  276399.77278526267
# Gradient descend method:  None
# RUN  1 , total integrated cost =  276399.7727852613
# RUN  2 , total integrated cost =  276399.7727852611
# RUN  3 , total integrated cost =  276399.77278526104
# RUN  4 , total integrated cost =  276399.77278526104
# Control only changes marginally.
# RUN  4 , total integrated cost =  276399.77278526104
# Improved over  4  iterations in  0.3151269429945387  seconds by  5.826450433232822e-13  percent.
# uncontrolled cost :  276399.77278526267
# cost splitting :  11109.049056156111 [0.00000000e+00 4.37259852e-05]
# set cost params:  1.0 0.0 8.6e-05
# interpolate adjoint :  True True True
# initial cost =  276399.77278526267
# RUN  0 , total integrated cost =  276399.77278526267
# Gradient descend method:  None
# RUN  1 , total integrated cost =  276399.7727852612
# RUN  2 , total integrated cost =  276399.77278526104
# RUN  3 , total integrated cost =  276399.77278526104
# Control only changes marginally.
# RUN  3 , total integrated cost =  276399.77278526104
# Improved over  3  iterations in  0.23340027200174518  seconds by  5.826450433232822e-13  percent.
# uncontrolled cost :  276399.77278526267
# cost splitting :  11109.04905615611 [0.00000000e+00 4.38903871e-05]
# set cost params:  1.0 0.0 8.5e-05
# interpolate adjoint :  True True True
# initial cost =  276399.77278526267
# RUN  0 , total integrated cost =  276399.77278526267
# Gradient descend method:  None
# RUN  1 , total integrated cost =  276399.7727852612
# RUN  2 , total integrated cost =  276399.77278526104
# RUN  3 , total integrated cost =  276399.772785261
# RUN  4 , total integrated cost =  276399.772785261
# Control only changes marginally.
# RUN  4 , total integrated cost =  276399.772785261
# Improved over  4  iterations in  0.3075775190081913  seconds by  6.110667527536862e-13  percent.
# uncontrolled cost :  276399.77278526267
# cost splitting :  11109.049056156107 [0.00000000e+00 4.46797624e-05]
# set cost params:  1.0 0.0 8.400000000000001e-05
# interpolate adjoint :  True True True
# initial cost =  276399.77278526267
# RUN  0 , total integrated cost =  276399.77278526267
# Gradient descend method:  None
# RUN  1 , total integrated cost =  276399.77278526226
# RUN  2 , total integrated cost =  276399.77278526215
# RUN  3 , total integrated cost =  276399.77278526215
# Control only changes marginally.
# RUN  3 , total integrated cost =  276399.77278526215
# Improved over  3  iterations in  0.21912714399513789  seconds by  1.8474111129762605e-13  percent.
# uncontrolled cost :  276399.77278526267
# cost splitting :  11109.049056155056 [0.         0.00037073]
# set cost params:  1.0 0.0 8.300000000000001e-05
# interpolate adjoint :  True True True
# initial cost =  276399.77278526267
# RUN  0 , total integrated cost =  276399.77278526267
# Gradient descend method:  None
# RUN  1 , total integrated cost =  276399.7727852619
# RUN  2 , total integrated cost =  276399.77278526186
# RUN  3 , total integrated cost =  276399.77278526186
# Control only changes marginally.
# RUN  3 , total integrated cost =  276399.77278526186
# Improved over  3  iterations in  0.2824818399967626  seconds by  2.984279490192421e-13  percent.
# uncontrolled cost :  276399.77278526267
# cost splitting :  11109.049056154901 [0.         0.00041829]
# set cost params:  1.0 0.0 8.2e-05
# interpolate adjoint :  True True True
# initial cost =  276399.77278526267
# RUN  0 , total integrated cost =  276399.77278526267
# Gradient descend method:  None
# RUN  1 , total integrated cost =  101220.45002896524
# RUN  2 , total integrated cost =  76675.61163904978
# RUN  3 , total integrated cost =  4.047583888218433
# RUN  4 , total integrated cost =  4.047583888218433
# RUN  5 , total integrated cost =  nan
# RUN  6 , total integrated cost =  nan
# RUN  7 , total integrated cost =  nan
# RUN  8 , total integrated cost =  nan
# RUN  9 , total integrated cost =  nan
# RUN  10 , total integrated cost =  nan
# RUN  11 , total integrated cost =  nan
# RUN  12 , total integrated cost =  nan
# RUN  13 , total integrated cost =  nan
# RUN  14 , total integrated cost =  nan
# RUN  15 , total integrated cost =  nan
# RUN  16 , total integrated cost =  nan
# RUN  17 , total integrated cost =  nan
# RUN  18 , total integrated cost =  nan
# RUN  19 , total integrated cost =  nan
# RUN  20 , total integrated cost =  nan
# RUN  30 , total integrated cost =  nan
# RUN  40 , total integrated cost =  nan
# RUN  50 , total integrated cost =  nan
# RUN  50 , total integrated cost =  nan
# Improved over  50  iterations in  15.201080924016424  seconds by  nan  percent.
# sparsity weight =  8.2e-05
# -------  71 0.47500000000000014 0.6750000000000004
# set cost params:  1.0 0.0 100000.0
# interpolate adjoint :  True True True
# initial cost =  384005.59692905797
# RUN  0 , total integrated cost =  384005.59692905797
# Gradient descend method:  None
# RUN  1 , total integrated cost =  384005.59692905797
# Control only changes marginally.
# RUN  1 , total integrated cost =  384005.59692905797
# Improved over  1  iterations in  0.12040494100074284  seconds by  0.0  percent.
# set cost params:  1.0 0.0 10000.0
# interpolate adjoint :  True True True
# initial cost =  384005.59692905797
# RUN  0 , total integrated cost =  384005.59692905797
# Gradient descend method:  None
# RUN  1 , total integrated cost =  384005.59692905797
# Control only changes marginally.
# RUN  1 , total integrated cost =  384005.59692905797
# Improved over  1  iterations in  0.12359398999251425  seconds by  0.0  percent.
# set cost params:  1.0 0.0 1000.0
# interpolate adjoint :  True True True
# initial cost =  384005.59692905797
# RUN  0 , total integrated cost =  384005.59692905797
# Gradient descend method:  None
# RUN  1 , total integrated cost =  384005.59692905797
# Control only changes marginally.
# RUN  1 , total integrated cost =  384005.59692905797
# Improved over  1  iterations in  0.11932186898775399  seconds by  0.0  percent.
# set cost params:  1.0 0.0 100.0
# interpolate adjoint :  True True True
# initial cost =  384005.59692905797
# RUN  0 , total integrated cost =  384005.59692905797
# Gradient descend method:  None
# RUN  1 , total integrated cost =  384005.59692905797
# Control only changes marginally.
# RUN  1 , total integrated cost =  384005.59692905797
# Improved over  1  iterations in  0.1227218399872072  seconds by  0.0  percent.
# set cost params:  1.0 0.0 10.0
# interpolate adjoint :  True True True
# initial cost =  384005.59692905797
# RUN  0 , total integrated cost =  384005.59692905797
# Gradient descend method:  None
# RUN  1 , total integrated cost =  384005.59692905797
# Control only changes marginally.
# RUN  1 , total integrated cost =  384005.59692905797
# Improved over  1  iterations in  0.11821580500691198  seconds by  0.0  percent.
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  384005.59692905797
# RUN  0 , total integrated cost =  384005.59692905797
# Gradient descend method:  None
# RUN  1 , total integrated cost =  384005.59692905797
# Control only changes marginally.
# RUN  1 , total integrated cost =  384005.59692905797
# Improved over  1  iterations in  0.12742749997414649  seconds by  0.0  percent.
# set cost params:  1.0 0.0 0.1
# interpolate adjoint :  True True True
# initial cost =  384005.59692905797
# RUN  0 , total integrated cost =  384005.59692905797
# Gradient descend method:  None
# RUN  1 , total integrated cost =  384005.59692905797
# Control only changes marginally.
# RUN  1 , total integrated cost =  384005.59692905797
# Improved over  1  iterations in  0.14072116298484616  seconds by  0.0  percent.
# set cost params:  1.0 0.0 0.01
# interpolate adjoint :  True True True
# initial cost =  384005.59692905797
# RUN  0 , total integrated cost =  384005.59692905797
# Gradient descend method:  None
# RUN  1 , total integrated cost =  384005.59692905797
# Control only changes marginally.
# RUN  1 , total integrated cost =  384005.59692905797
# Improved over  1  iterations in  0.1284496290027164  seconds by  0.0  percent.
# set cost params:  1.0 0.0 0.001
# interpolate adjoint :  True True True
# initial cost =  384005.59692905797
# RUN  0 , total integrated cost =  384005.59692905797
# Gradient descend method:  None
# RUN  1 , total integrated cost =  115834.91462792967
# RUN  2 , total integrated cost =  1970.2211219949606
# RUN  3 , total integrated cost =  9.893276208018056
# RUN  4 , total integrated cost =  0.3386111310307898
# RUN  5 , total integrated cost =  0.3261363871331632
# RUN  6 , total integrated cost =  0.32602661468806976
# RUN  7 , total integrated cost =  0.3206576898583657
# RUN  8 , total integrated cost =  0.3206576898583657
# Control only changes marginally.
# RUN  8 , total integrated cost =  0.3206576898583657
# Improved over  8  iterations in  0.8908088010211941  seconds by  99.99991649661035  percent.
# set cost params:  1.0 0.0 0.0001
# interpolate adjoint :  True True True
# initial cost =  384005.59692905797
# RUN  0 , total integrated cost =  384005.59692905797
# Gradient descend method:  None
# RUN  1 , total integrated cost =  115834.90493132263
# RUN  2 , total integrated cost =  1970.1376376104176
# RUN  3 , total integrated cost =  1.7209706980065067
# RUN  4 , total integrated cost =  0.1931598953055844
# RUN  5 , total integrated cost =  0.14770835461265897
# RUN  6 , total integrated cost =  0.14765012271280506
# RUN  7 , total integrated cost =  0.035210403893356994
# RUN  8 , total integrated cost =  0.035199852811629594
# RUN  9 , total integrated cost =  0.03514712553577269
# RUN  10 , total integrated cost =  0.035147125535769416
# RUN  10 , total integrated cost =  0.035147125535769416
# Improved over  10  iterations in  1.2223210550146177  seconds by  99.99999084723613  percent.
# uncontrolled cost :  384005.59692905797
# cost splitting :  0.0009769779161445393 [  0.         108.39331712]
# set cost params:  1.0 0.0 0.0009000000000000001
# interpolate adjoint :  True True True
# initial cost =  384005.59692905797
# RUN  0 , total integrated cost =  384005.59692905797
# Gradient descend method:  None
# RUN  1 , total integrated cost =  115834.91355052889
# RUN  2 , total integrated cost =  1970.2118459523538
# RUN  3 , total integrated cost =  16.084019259592353
# RUN  4 , total integrated cost =  1.1781301977990772
# RUN  5 , total integrated cost =  0.38541224695339166
# RUN  6 , total integrated cost =  0.22681780702035856
# RUN  7 , total integrated cost =  0.1620825820334186
# RUN  8 , total integrated cost =  0.13348209342083217
# RUN  9 , total integrated cost =  0.11941385320106991
# RUN  10 , total integrated cost =  0.11207453968930046
# RUN  10 , total integrated cost =  0.11207453968930046
# Improved over  10  iterations in  0.7730895460117608  seconds by  99.99997081434735  percent.
# uncontrolled cost :  384005.59692905797
# cost splitting :  0.0005677028733218156 [  0.         108.83305919]
# set cost params:  1.0 0.0 0.00099
# interpolate adjoint :  True True True
# initial cost =  384005.59692905797
# RUN  0 , total integrated cost =  384005.59692905797
# Gradient descend method:  None
# RUN  1 , total integrated cost =  115834.91452018959
# RUN  2 , total integrated cost =  1970.2201943907012
# RUN  3 , total integrated cost =  17.161294053092433
# RUN  4 , total integrated cost =  0.43301200105070503
# RUN  5 , total integrated cost =  0.18770528454585217
# RUN  6 , total integrated cost =  0.1447277523334195
# RUN  7 , total integrated cost =  0.1447277523334195
# RUN  8 , total integrated cost =  nan
# RUN  9 , total integrated cost =  nan
# RUN  10 , total integrated cost =  nan
# RUN  11 , total integrated cost =  nan
# RUN  12 , total integrated cost =  nan
# RUN  13 , total integrated cost =  nan
# RUN  14 , total integrated cost =  nan
# RUN  15 , total integrated cost =  nan
# RUN  16 , total integrated cost =  nan
# RUN  17 , total integrated cost =  nan
# RUN  18 , total integrated cost =  nan
# RUN  19 , total integrated cost =  nan
# RUN  20 , total integrated cost =  nan
# RUN  30 , total integrated cost =  nan
# RUN  40 , total integrated cost =  nan
# RUN  50 , total integrated cost =  nan
# RUN  50 , total integrated cost =  nan
# Improved over  50  iterations in  12.221139797999058  seconds by  nan  percent.
# sparsity weight =  0.00099
# -------  72 0.5000000000000002 0.6750000000000004
# set cost params:  1.0 0.0 100000.0
# interpolate adjoint :  True True True
# initial cost =  495331.1329655588
# RUN  0 , total integrated cost =  495331.1329655588
# Gradient descend method:  None
# RUN  1 , total integrated cost =  495331.1329655588
# Control only changes marginally.
# RUN  1 , total integrated cost =  495331.1329655588
# Improved over  1  iterations in  0.12850304201128893  seconds by  0.0  percent.
# set cost params:  1.0 0.0 10000.0
# interpolate adjoint :  True True True
# initial cost =  495331.1329655588
# RUN  0 , total integrated cost =  495331.1329655588
# Gradient descend method:  None
# RUN  1 , total integrated cost =  495331.1329655588
# Control only changes marginally.
# RUN  1 , total integrated cost =  495331.1329655588
# Improved over  1  iterations in  0.12825857897405513  seconds by  0.0  percent.
# set cost params:  1.0 0.0 1000.0
# interpolate adjoint :  True True True
# initial cost =  495331.1329655588
# RUN  0 , total integrated cost =  495331.1329655588
# Gradient descend method:  None
# RUN  1 , total integrated cost =  495331.1329655588
# Control only changes marginally.
# RUN  1 , total integrated cost =  495331.1329655588
# Improved over  1  iterations in  0.1259899470023811  seconds by  0.0  percent.
# set cost params:  1.0 0.0 100.0
# interpolate adjoint :  True True True
# initial cost =  495331.1329655588
# RUN  0 , total integrated cost =  495331.1329655588
# Gradient descend method:  None
# RUN  1 , total integrated cost =  495331.1329655588
# Control only changes marginally.
# RUN  1 , total integrated cost =  495331.1329655588
# Improved over  1  iterations in  0.1311554120038636  seconds by  0.0  percent.
# set cost params:  1.0 0.0 10.0
# interpolate adjoint :  True True True
# initial cost =  495331.1329655588
# RUN  0 , total integrated cost =  495331.1329655588
# Gradient descend method:  None
# RUN  1 , total integrated cost =  495331.1329655588
# Control only changes marginally.
# RUN  1 , total integrated cost =  495331.1329655588
# Improved over  1  iterations in  0.1252139809948858  seconds by  0.0  percent.
# set cost params:  1.0 0.0 1.0
# interpolate adjoint :  True True True
# initial cost =  495331.1329655588
# RUN  0 , total integrated cost =  495331.1329655588
# Gradient descend method:  None
# RUN  1 , total integrated cost =  495331.1329655588
# Control only changes marginally.
# RUN  1 , total integrated cost =  495331.1329655588
# Improved over  1  iterations in  0.13410991901764646  seconds by  0.0  percent.
# set cost params:  1.0 0.0 0.1
# interpolate adjoint :  True True True
# initial cost =  495331.1329655588
# RUN  0 , total integrated cost =  495331.1329655588
# Gradient descend method:  None
# RUN  1 , total integrated cost =  495331.1329655588
# Control only changes marginally.
# RUN  1 , total integrated cost =  495331.1329655588
# Improved over  1  iterations in  0.1307437060168013  seconds by  0.0  percent.
# set cost params:  1.0 0.0 0.01
# interpolate adjoint :  True True True
# initial cost =  495331.1329655588
# RUN  0 , total integrated cost =  495331.1329655588
# Gradient descend method:  None
# RUN  1 , total integrated cost =  123071.1925574936
# RUN  2 , total integrated cost =  991.229388083604
# RUN  3 , total integrated cost =  991.229388083604
# Control only changes marginally.
# RUN  3 , total integrated cost =  991.229388083604
# Improved over  3  iterations in  0.4431033029977698  seconds by  99.79988550645926  percent.
# set cost params:  1.0 0.0 0.001
# interpolate adjoint :  True True True
# initial cost =  495331.1329655588
# RUN  0 , total integrated cost =  495331.1329655588
# Gradient descend method:  None
# RUN  1 , total integrated cost =  123071.09858570523
# RUN  2 , total integrated cost =  990.9272801648102
# RUN  3 , total integrated cost =  990.9272801648102
# Control only changes marginally.
# RUN  3 , total integrated cost =  990.9272801648102
# Improved over  3  iterations in  0.44415383899468  seconds by  99.79994649756172  percent.
# set cost params:  1.0 0.0 0.0001
# interpolate adjoint :  True True True
# initial cost =  495331.1329655588
# RUN  0 , total integrated cost =  495331.1329655588
# Gradient descend method:  None
# RUN  1 , total integrated cost =  123071.0891885264
# RUN  2 , total integrated cost =  1574.205103375647
# RUN  3 , total integrated cost =  1574.205103375647
# Control only changes marginally.
# RUN  3 , total integrated cost =  1574.205103375647
# Improved over  3  iterations in  0.4226155770011246  seconds by  99.68219136682347  percent.
# set cost params:  1.0 0.0 1e-05
# interpolate adjoint :  True True True
# initial cost =  495331.1329655588
# RUN  0 , total integrated cost =  495331.1329655588
# Gradient descend method:  None
# RUN  1 , total integrated cost =  123071.0882488085
# RUN  2 , total integrated cost =  1574.1974356239277
# RUN  3 , total integrated cost =  1574.1974356239277
# Control only changes marginally.
# RUN  3 , total integrated cost =  1574.1974356239277
# Improved over  3  iterations in  0.4530656500137411  seconds by  99.68219291482868  percent.
# set cost params:  1.0 0.0 1e-06
# interpolate adjoint :  True True True
# initial cost =  495331.1329655588
# RUN  0 , total integrated cost =  495331.1329655588
# Gradient descend method:  None
# RUN  1 , total integrated cost =  123071.08815483672
# RUN  2 , total integrated cost =  1574.1966688487553
# RUN  3 , total integrated cost =  1574.1966688487553
# Control only changes marginally.
# RUN  3 , total integrated cost =  1574.1966688487553
# Improved over  3  iterations in  0.42767768798512407  seconds by  99.6821930696292  percent.
# set cost params:  1.0 0.0 1e-07
# interpolate adjoint :  True True True
# initial cost =  495331.1329655588
# RUN  0 , total integrated cost =  495331.1329655588
# Gradient descend method:  None
# RUN  1 , total integrated cost =  123071.08814543954
# RUN  2 , total integrated cost =  1574.1965921712383
# RUN  3 , total integrated cost =  1574.1965921712383
# Control only changes marginally.
# RUN  3 , total integrated cost =  1574.1965921712383
# Improved over  3  iterations in  0.5851352009922266  seconds by  99.68219308510925  percent.
# set cost params:  1.0 0.0 1e-08
# interpolate adjoint :  True True True
# initial cost =  495331.1329655588
# RUN  0 , total integrated cost =  495331.1329655588
# Gradient descend method:  None
# RUN  1 , total integrated cost =  123071.08814449982
# RUN  2 , total integrated cost =  1574.1965845034865
# RUN  3 , total integrated cost =  1574.1965845034865
# Control only changes marginally.
# RUN  3 , total integrated cost =  1574.1965845034865
# Improved over  3  iterations in  0.4734302110155113  seconds by  99.68219308665725  percent.
# set cost params:  1.0 0.0 1e-09
# interpolate adjoint :  True True True
# initial cost =  495331.1329655588
# RUN  0 , total integrated cost =  495331.1329655588
# Gradient descend method:  None
# RUN  1 , total integrated cost =  123071.08814440586
# RUN  2 , total integrated cost =  1574.196583736711
# RUN  3 , total integrated cost =  1574.196583736711
# Control only changes marginally.
# RUN  3 , total integrated cost =  1574.196583736711
# Improved over  3  iterations in  0.4430409039778169  seconds by  99.68219308681206  percent.
# set cost params:  1.0 0.0 1e-10
# interpolate adjoint :  True True True
# initial cost =  495331.1329655588
# RUN  0 , total integrated cost =  495331.1329655588
# Gradient descend method:  None
# RUN  1 , total integrated cost =  123071.08814439646
# RUN  2 , total integrated cost =  1574.1965836600336
# RUN  3 , total integrated cost =  1574.1965836600336
# Control only changes marginally.
# RUN  3 , total integrated cost =  1574.1965836600336
# Improved over  3  iterations in  0.41622425499372184  seconds by  99.68219308682754  percent.
# -------  73 0.5250000000000001 0.6750000000000004
# set cost params:  1.0 0.0 100000.0
# interpolate adjoint :  True True True
# initial cost =  611432.0686370909
# RUN  0 , total integrated cost =  611432.0686370909
# Gradient descend method:  None
# RUN  1 , total integrated cost =  611432.0686370909
# Control only changes marginally.
# RUN  1 , total integrated cost =  611432.0686370909
# Improved over  1  iterations in  0.18640272799530067  seconds by  0.0  percent.
# set cost params:  1.0 0.0 10000.0
# interpolate adjoint :  True True True
# initial cost =  611432.0686370909
# RUN  0 , total integrated cost =  611432.0686370909
# Gradient descend method:  None
# RUN  1 , total integrated cost =  217743.11385583784
# RUN  2 , total integrated cost =  157505.38545894672
# RUN  3 , total integrated cost =  99336.15644017268
# RUN  4 , total integrated cost =  94273.72160405485
# RUN  5 , total integrated cost =  85517.10093159946
# RUN  6 , total integrated cost =  83611.55352805024
# RUN  7 , total integrated cost =  78091.14106886098
# RUN  8 , total integrated cost =  77646.95159284702
# RUN  9 , total integrated cost =  77461.39196067268
# RUN  10 , total integrated cost =  77302.78804891284
# RUN  10 , total integrated cost =  77302.78804891284
# Improved over  10  iterations in  0.8941610130132176  seconds by  87.35709296026553  percent.
# uncontrolled cost :  611432.0686370909
# cost splitting :  52.27786196317213 [0.         7.60020836]
# set cost params:  1.0 0.0 90000.0
# interpolate adjoint :  True True True
# initial cost =  611432.0686370909
# RUN  0 , total integrated cost =  611432.0686370909
# Gradient descend method:  None
# RUN  1 , total integrated cost =  611432.0686370909
# Control only changes marginally.
# RUN  1 , total integrated cost =  611432.0686370909
# Improved over  1  iterations in  0.14269915901240893  seconds by  0.0  percent.
# uncontrolled cost :  611432.0686370909
# cost splitting :  24574.65422836538 [0. 0.]
# set cost params:  1.0 0.0 80000.0
# interpolate adjoint :  True True True
# initial cost =  611432.0686370909
# RUN  0 , total integrated cost =  611432.0686370909
# Gradient descend method:  None
# RUN  1 , total integrated cost =  611432.0686370909
# Control only changes marginally.
# RUN  1 , total integrated cost =  611432.0686370909
# Improved over  1  iterations in  0.13624244299717247  seconds by  0.0  percent.
# uncontrolled cost :  611432.0686370909
# cost splitting :  24574.65422836538 [0. 0.]
# set cost params:  1.0 0.0 70000.0
# interpolate adjoint :  True True True
# initial cost =  611432.0686370909
# RUN  0 , total integrated cost =  611432.0686370909
# Gradient descend method:  None
# RUN  1 , total integrated cost =  611432.0686370909
# Control only changes marginally.
# RUN  1 , total integrated cost =  611432.0686370909
# Improved over  1  iterations in  0.14193999499548227  seconds by  0.0  percent.
# uncontrolled cost :  611432.0686370909
# cost splitting :  24574.65422836538 [0. 0.]
# set cost params:  1.0 0.0 60000.0
# interpolate adjoint :  True True True
# initial cost =  611432.0686370909
# RUN  0 , total integrated cost =  611432.0686370909
# Gradient descend method:  None
# RUN  1 , total integrated cost =  611432.0686370909
# Control only changes marginally.
# RUN  1 , total integrated cost =  611432.0686370909
# Improved over  1  iterations in  0.14146886198432185  seconds by  0.0  percent.
# uncontrolled cost :  611432.0686370909
# cost splitting :  24574.65422836538 [0. 0.]
# set cost params:  1.0 0.0 50000.0
# interpolate adjoint :  True True True
# initial cost =  611432.0686370909
# RUN  0 , total integrated cost =  611432.0686370909
# Gradient descend method:  None
# RUN  1 , total integrated cost =  611432.0686370909
# Control only changes marginally.
# RUN  1 , total integrated cost =  611432.0686370909
# Improved over  1  iterations in  0.13826010801130906  seconds by  0.0  percent.
# uncontrolled cost :  611432.0686370909
# cost splitting :  24574.65422836538 [0. 0.]
# set cost params:  1.0 0.0 40000.0
# interpolate adjoint :  True True True
# initial cost =  611432.0686370909
# RUN  0 , total integrated cost =  611432.0686370909
# Gradient descend method:  None
# RUN  1 , total integrated cost =  499899.0771193965
# RUN  2 , total integrated cost =  424086.9974733711
# RUN  3 , total integrated cost =  396243.03583727113
# RUN  4 , total integrated cost =  382478.95778398693
# RUN  5 , total integrated cost =  373014.33314872545
# RUN  6 , total integrated cost =  366620.5788765934
# RUN  7 , total integrated cost =  361267.16592331114
# RUN  8 , total integrated cost =  357337.5658427957
# RUN  9 , total integrated cost =  353556.6380648867
# RUN  10 , total integrated cost =  350586.2461107384
# RUN  10 , total integrated cost =  350586.2461107384
# Improved over  10  iterations in  0.9257701149908826  seconds by  42.66145593373756  percent.
# uncontrolled cost :  611432.0686370909
# cost splitting :  133.09007289432375 [0.         8.68187214]
# set cost params:  1.0 0.0 49000.0
# interpolate adjoint :  True True True
# initial cost =  611432.0686370909
# RUN  0 , total integrated cost =  611432.0686370909
# Gradient descend method:  None
# RUN  1 , total integrated cost =  611432.0686370909
# Control only changes marginally.
# RUN  1 , total integrated cost =  611432.0686370909
# Improved over  1  iterations in  0.1976772769994568  seconds by  0.0  percent.
# uncontrolled cost :  611432.0686370909
# cost splitting :  24574.65422836538 [0. 0.]
# set cost params:  1.0 0.0 48000.0
# interpolate adjoint :  True True True
# initial cost =  611432.0686370909
# RUN  0 , total integrated cost =  611432.0686370909
# Gradient descend method:  None
# RUN  1 , total integrated cost =  611432.0686370909
# Control only changes marginally.
# RUN  1 , total integrated cost =  611432.0686370909
# Improved over  1  iterations in  0.13938956701895222  seconds by  0.0  percent.
# uncontrolled cost :  611432.0686370909
# cost splitting :  24574.65422836538 [0. 0.]
# set cost params:  1.0 0.0 47000.0
# interpolate adjoint :  True True True
# initial cost =  611432.0686370909
# RUN  0 , total integrated cost =  611432.0686370909
# Gradient descend method:  None
# RUN  1 , total integrated cost =  565735.4685475603
# RUN  2 , total integrated cost =  479684.2453390414
# RUN  3 , total integrated cost =  452342.06136634276
# RUN  4 , total integrated cost =  438443.3270101668
# RUN  5 , total integrated cost =  428565.85526949336
# RUN  6 , total integrated cost =  421417.76733145217
# RUN  7 , total integrated cost =  414857.2044932078
# RUN  8 , total integrated cost =  410426.6679784961
# RUN  9 , total integrated cost =  406208.87244942045
# RUN  10 , total integrated cost =  403137.643641687
# RUN  11 , total integrated cost =  400100.7926039233
# RUN  12 , total integrated cost =  397548.8146239329
# RUN  13 , total integrated cost =  394992.6064083676
# RUN  14 , total integrated cost =  393065.79744516837
# RUN  15 , total integrated cost =  391045.9417989398
# RUN  16 , total integrated cost =  389311.49099630135
# RUN  17 , total integrated cost =  387637.14713780384
# RUN  18 , total integrated cost =  386301.67589776317
# RUN  19 , total integrated cost =  384910.63031673536
# RUN  20 , total integrated cost =  383786.4294578625
# RUN  30 , total integrated cost =  375585.31302383397
# RUN  40 , total integrated cost =  371492.39954674174
# RUN  50 , total integrated cost =  361927.2775985848
# RUN  50 , total integrated cost =  361927.2775985848
# Improved over  50  iterations in  4.321257900999626  seconds by  40.80662494439705  percent.
# sparsity weight =  47000.0
# -------  74 0.5500000000000003 0.6750000000000004
# set cost params:  1.0 0.0 100000.0
# interpolate adjoint :  True True True
# initial cost =  732509.8149166821
# RUN  0 , total integrated cost =  732509.8149166821
# Gradient descend method:  None
# RUN  1 , total integrated cost =  732509.8149166821
# Control only changes marginally.
# RUN  1 , total integrated cost =  732509.8149166821
# Improved over  1  iterations in  0.16009997599758208  seconds by  0.0  percent.
# set cost params:  1.0 0.0 10000.0
# interpolate adjoint :  True True True
# initial cost =  732509.8149166821
# RUN  0 , total integrated cost =  732509.8149166821
# Gradient descend method:  None
# RUN  1 , total integrated cost =  167681.65577631933
# RUN  2 , total integrated cost =  102890.7673902869
# RUN  3 , total integrated cost =  81799.88824347251
# RUN  4 , total integrated cost =  81080.05828774403
# RUN  5 , total integrated cost =  80199.37194945166
# RUN  6 , total integrated cost =  79603.38520049439
# RUN  7 , total integrated cost =  78851.50075158973
# RUN  8 , total integrated cost =  78338.27780130928
# RUN  9 , total integrated cost =  77716.39765882531
# RUN  10 , total integrated cost =  77248.04198856579
# RUN  10 , total integrated cost =  77248.04198856579
# Improved over  10  iterations in  0.8347079379891511  seconds by  89.45433352352389  percent.
# uncontrolled cost :  732509.8149166821
# cost splitting :  29.134025006132703 [0.         7.65231701]
# set cost params:  1.0 0.0 90000.0
# interpolate adjoint :  True True True
# initial cost =  732509.8149166821
# RUN  0 , total integrated cost =  732509.8149166821
# Gradient descend method:  None
# RUN  1 , total integrated cost =  732509.8149166821
# Control only changes marginally.
# RUN  1 , total integrated cost =  732509.8149166821
# Improved over  1  iterations in  0.23565877898363397  seconds by  0.0  percent.
# uncontrolled cost :  732509.8149166821
# cost splitting :  29441.00635837894 [0. 0.]
# set cost params:  1.0 0.0 80000.0
# interpolate adjoint :  True True True
# initial cost =  732509.8149166821
# RUN  0 , total integrated cost =  732509.8149166821
# Gradient descend method:  None
# RUN  1 , total integrated cost =  732509.8149166821
# Control only changes marginally.
# RUN  1 , total integrated cost =  732509.8149166821
# Improved over  1  iterations in  0.15511381000396796  seconds by  0.0  percent.
# uncontrolled cost :  732509.8149166821
# cost splitting :  29441.00635837894 [0. 0.]
# set cost params:  1.0 0.0 70000.0
# interpolate adjoint :  True True True
# initial cost =  732509.8149166821
# RUN  0 , total integrated cost =  732509.8149166821
# Gradient descend method:  None
# RUN  1 , total integrated cost =  732509.8149166821
# Control only changes marginally.
# RUN  1 , total integrated cost =  732509.8149166821
# Improved over  1  iterations in  0.15305908999289386  seconds by  0.0  percent.
# uncontrolled cost :  732509.8149166821
# cost splitting :  29441.00635837894 [0. 0.]
# set cost params:  1.0 0.0 60000.0
# interpolate adjoint :  True True True
# initial cost =  732509.8149166821
# RUN  0 , total integrated cost =  732509.8149166821
# Gradient descend method:  None
# RUN  1 , total integrated cost =  732509.8149166821
# Control only changes marginally.
# RUN  1 , total integrated cost =  732509.8149166821
# Improved over  1  iterations in  0.15881487299338914  seconds by  0.0  percent.
# uncontrolled cost :  732509.8149166821
# cost splitting :  29441.00635837894 [0. 0.]
# set cost params:  1.0 0.0 50000.0
# interpolate adjoint :  True True True
# initial cost =  732509.8149166821
# RUN  0 , total integrated cost =  732509.8149166821
# Gradient descend method:  None
# RUN  1 , total integrated cost =  543973.9681747318
# RUN  2 , total integrated cost =  486002.2542237184
# RUN  3 , total integrated cost =  451658.6951283474
# RUN  4 , total integrated cost =  435904.8912463372
# RUN  5 , total integrated cost =  423974.47479387344
# RUN  6 , total integrated cost =  415904.06468412804
# RUN  7 , total integrated cost =  407913.3552231694
# RUN  8 , total integrated cost =  401358.0541292547
# RUN  9 , total integrated cost =  394833.8347119715
# RUN  10 , total integrated cost =  389771.5041590141
# RUN  10 , total integrated cost =  389771.5041590141
# Improved over  10  iterations in  0.797820252017118  seconds by  46.7895861295254  percent.
# uncontrolled cost :  732509.8149166821
# cost splitting :  154.67021220390973 [0.         7.71846434]
# set cost params:  1.0 0.0 59000.0
# interpolate adjoint :  True True True
# initial cost =  732509.8149166821
# RUN  0 , total integrated cost =  732509.8149166821
# Gradient descend method:  None
# RUN  1 , total integrated cost =  732509.8149166821
# Control only changes marginally.
# RUN  1 , total integrated cost =  732509.8149166821
# Improved over  1  iterations in  0.17000322198146023  seconds by  0.0  percent.
# uncontrolled cost :  732509.8149166821
# cost splitting :  29441.00635837894 [0. 0.]
# set cost params:  1.0 0.0 58000.0
# interpolate adjoint :  True True True
# initial cost =  732509.8149166821
# RUN  0 , total integrated cost =  732509.8149166821
# Gradient descend method:  None
# RUN  1 , total integrated cost =  732509.8149166821
# Control only changes marginally.
# RUN  1 , total integrated cost =  732509.8149166821
# Improved over  1  iterations in  0.161902566003846  seconds by  0.0  percent.
# uncontrolled cost :  732509.8149166821
# cost splitting :  29441.00635837894 [0. 0.]
# set cost params:  1.0 0.0 57000.0
# interpolate adjoint :  True True True
# initial cost =  732509.8149166821
# RUN  0 , total integrated cost =  732509.8149166821
# Gradient descend method:  None
# RUN  1 , total integrated cost =  605260.3260907576
# RUN  2 , total integrated cost =  544359.8632628869
# RUN  3 , total integrated cost =  512769.4718190847
# RUN  4 , total integrated cost =  498068.29200716096
# RUN  5 , total integrated cost =  485741.05090648006
# RUN  6 , total integrated cost =  477151.25689123356
# RUN  7 , total integrated cost =  468692.0033772088
# RUN  8 , total integrated cost =  462310.72196040786
# RUN  9 , total integrated cost =  455846.676753814
# RUN  10 , total integrated cost =  450891.4628637893
# RUN  11 , total integrated cost =  446025.2663390603
# RUN  12 , total integrated cost =  442266.3258070414
# RUN  13 , total integrated cost =  438367.30725794553
# RUN  14 , total integrated cost =  435211.9360647685
# RUN  15 , total integrated cost =  431617.4027307174
# RUN  16 , total integrated cost =  428699.7717958794
# RUN  17 , total integrated cost =  425868.35698696296
# RUN  18 , total integrated cost =  423688.6884861199
# RUN  19 , total integrated cost =  421223.27016898163
# RUN  20 , total integrated cost =  419051.9588529486
# RUN  30 , total integrated cost =  404862.2927755974
# RUN  40 , total integrated cost =  385304.585600493
# RUN  50 , total integrated cost =  379372.4004812528
# RUN  50 , total integrated cost =  379372.4004812528
# Improved over  50  iterations in  4.078170030988986  seconds by  48.20923996432679  percent.
# sparsity weight =  57000.0
# -------  75 0.5750000000000002 0.6750000000000004
# set cost params:  1.0 0.0 100000.0
# interpolate adjoint :  True True True
# initial cost =  858276.8196420075
# RUN  0 , total integrated cost =  858276.8196420075
# Gradient descend method:  None
# RUN  1 , total integrated cost =  858276.8196420075
# Control only changes marginally.
# RUN  1 , total integrated cost =  858276.8196420075
# Improved over  1  iterations in  0.1622195320087485  seconds by  0.0  percent.
# set cost params:  1.0 0.0 10000.0
# interpolate adjoint :  True True True
# initial cost =  858276.8196420075
# RUN  0 , total integrated cost =  858276.8196420075
# Gradient descend method:  None
# RUN  1 , total integrated cost =  103686.35840274554
# RUN  2 , total integrated cost =  93857.27742837789
# RUN  3 , total integrated cost =  86584.00427776313
# RUN  4 , total integrated cost =  85217.75362228348
# RUN  5 , total integrated cost =  83076.56389122963
# RUN  6 , total integrated cost =  81837.83268461551
# RUN  7 , total integrated cost =  79759.64161540204
# RUN  8 , total integrated cost =  78896.07333220259
# RUN  9 , total integrated cost =  77666.22608982745
# RUN  10 , total integrated cost =  76845.30671449174
# RUN  10 , total integrated cost =  76845.30671449174
# Improved over  10  iterations in  0.8054047070036177  seconds by  91.04655922706331  percent.
# uncontrolled cost :  858276.8196420075
# cost splitting :  11.615355705654702 [0.         7.65563097]
# set cost params:  1.0 0.0 90000.0
# interpolate adjoint :  True True True
# initial cost =  858276.8196420075
# RUN  0 , total integrated cost =  858276.8196420075
# Gradient descend method:  None
# RUN  1 , total integrated cost =  792729.7023993543
# RUN  2 , total integrated cost =  745721.7577235199
# RUN  3 , total integrated cost =  714560.7741009227
# RUN  4 , total integrated cost =  694022.9061699908
# RUN  5 , total integrated cost =  674357.4669816217
# RUN  6 , total integrated cost =  659947.5738713281
# RUN  7 , total integrated cost =  645319.8853889912
# RUN  8 , total integrated cost =  634407.591950082
# RUN  9 , total integrated cost =  623055.846899225
# RUN  10 , total integrated cost =  614638.3925001398
# RUN  10 , total integrated cost =  614638.3925001398
# Improved over  10  iterations in  0.7727149150159676  seconds by  28.386928502099224  percent.
# uncontrolled cost :  858276.8196420075
# cost splitting :  331.83395603332804 [0.         6.73757962]
# set cost params:  1.0 0.0 99000.0
# interpolate adjoint :  True True True
# initial cost =  858276.8196420075
# RUN  0 , total integrated cost =  858276.8196420075
# Gradient descend method:  None
# RUN  1 , total integrated cost =  858276.8196420075
# Control only changes marginally.
# RUN  1 , total integrated cost =  858276.8196420075
# Improved over  1  iterations in  0.15487948901136406  seconds by  0.0  percent.
# ...
# Gradient descend method:  None
# RUN  1 , total integrated cost =  123999.1165075554
# RUN  2 , total integrated cost =  544.8137117750211
# RUN  3 , total integrated cost =  544.8137117750211
# Control only changes marginally.
# RUN  3 , total integrated cost =  544.8137117750211
# Improved over  3  iterations in  0.8663625980261713  seconds by  99.9103196472433  percent.
# uncontrolled cost :  607506.209585381
# cost splitting :  18.371832093638247 [ 0.         32.48576334]
# set cost params:  1.0 0.0 2.6
# interpolate adjoint :  True True True
# initial cost =  607506.209585381
# RUN  0 , total integrated cost =  607506.209585381
# Gradient descend method:  None
# RUN  1 , total integrated cost =  123998.02041814731
# RUN  2 , total integrated cost =  541.568400284829
# RUN  3 , total integrated cost =  537.9290486177921
# RUN  4 , total integrated cost =  537.9290486177921
# RUN  5 , total integrated cost =  nan
# RUN  6 , total integrated cost =  nan
# RUN  7 , total integrated cost =  nan
# RUN  8 , total integrated cost =  nan
# RUN  9 , total integrated cost =  nan
# RUN  10 , total integrated cost =  nan
# RUN  11 , total integrated cost =  nan
# RUN  12 , total integrated cost =  nan
# RUN  13 , total integrated cost =  nan
# RUN  14 , total integrated cost =  nan
# RUN  15 , total integrated cost =  nan
# RUN  16 , total integrated cost =  nan
# RUN  17 , total integrated cost =  nan
# RUN  18 , total integrated cost =  nan
# RUN  19 , total integrated cost =  nan
# RUN  20 , total integrated cost =  nan
# RUN  30 , total integrated cost =  nan
# RUN  40 , total integrated cost =  nan
# RUN  50 , total integrated cost =  nan
# RUN  50 , total integrated cost =  nan
# Improved over  50  iterations in  23.46043806200032  seconds by  nan  percent.
# sparsity weight =  2.6
# -------  81 0.5500000000000003 0.7000000000000004
# set cost params:  1.0 0.0 100000.0
# interpolate adjoint :  True True True
# initial cost =  728478.2773809158
# RUN  0 , total integrated cost =  728478.2773809158
# Gradient descend method:  None
# RUN  1 , total integrated cost =  728478.2773809158
# Control only changes marginally.
# RUN  1 , total integrated cost =  728478.2773809158
# Improved over  1  iterations in  0.26966151999658905  seconds by  0.0  percent.
# set cost params:  1.0 0.0 10000.0
# interpolate adjoint :  True True True
# initial cost =  728478.2773809158
# RUN  0 , total integrated cost =  728478.2773809158
# Gradient descend method:  None
# RUN  1 , total integrated cost =  198276.21481656507
# RUN  2 , total integrated cost =  140493.1647558752
# RUN  3 , total integrated cost =  114388.57556909956
# RUN  4 , total integrated cost =  106973.06822922739
# RUN  5 , total integrated cost =  101515.67820994751
# RUN  6 , total integrated cost =  98796.94550961677
# RUN  7 , total integrated cost =  96914.63923095608
# RUN  8 , total integrated cost =  95555.48776751228
# RUN  9 , total integrated cost =  94540.29002180428
# RUN  10 , total integrated cost =  93715.40365221577
# RUN  10 , total integrated cost =  93715.40365221577
# Improved over  10  iterations in  1.3945371439913288  seconds by  87.13545666877687  percent.
# uncontrolled cost :  728478.2773809158
# cost splitting :  38.34944791584871 [0.         9.27612465]
# set cost params:  1.0 0.0 90000.0
# interpolate adjoint :  True True True
# initial cost =  728478.2773809158
# RUN  0 , total integrated cost =  728478.2773809158
# Gradient descend method:  None
# RUN  1 , total integrated cost =  728478.2773809158
# Control only changes marginally.
# RUN  1 , total integrated cost =  728478.2773809158
# Improved over  1  iterations in  0.2531335369858425  seconds by  0.0  percent.
# uncontrolled cost :  728478.2773809158
# cost splitting :  29278.970956521513 [0. 0.]
# set cost params:  1.0 0.0 80000.0
# interpolate adjoint :  True True True
# initial cost =  728478.2773809158
# RUN  0 , total integrated cost =  728478.2773809158
# Gradient descend method:  None
# RUN  1 , total integrated cost =  728478.2773809158
# Control only changes marginally.
# RUN  1 , total integrated cost =  728478.2773809158
# Improved over  1  iterations in  0.272473176009953  seconds by  0.0  percent.
# uncontrolled cost :  728478.2773809158
# cost splitting :  29278.970956521513 [0. 0.]
# set cost params:  1.0 0.0 70000.0
# interpolate adjoint :  True True True
# initial cost =  728478.2773809158
# RUN  0 , total integrated cost =  728478.2773809158
# Gradient descend method:  None
# RUN  1 , total integrated cost =  728478.2773809158
# Control only changes marginally.
# RUN  1 , total integrated cost =  728478.2773809158
# Improved over  1  iterations in  0.27856768999481574  seconds by  0.0  percent.
# uncontrolled cost :  728478.2773809158
# cost splitting :  29278.970956521513 [0. 0.]
# set cost params:  1.0 0.0 60000.0
# interpolate adjoint :  True True True
# initial cost =  728478.2773809158
# RUN  0 , total integrated cost =  728478.2773809158
# Gradient descend method:  None
# RUN  1 , total integrated cost =  728478.2773809158
# Control only changes marginally.
# RUN  1 , total integrated cost =  728478.2773809158
# Improved over  1  iterations in  0.26145134400576353  seconds by  0.0  percent.
# uncontrolled cost :  728478.2773809158
# cost splitting :  29278.970956521513 [0. 0.]
# set cost params:  1.0 0.0 50000.0
# interpolate adjoint :  True True True
# initial cost =  728478.2773809158
# RUN  0 , total integrated cost =  728478.2773809158
# Gradient descend method:  None
# RUN  1 , total integrated cost =  728478.2773809158
# Control only changes marginally.
# RUN  1 , total integrated cost =  728478.2773809158
# Improved over  1  iterations in  0.25222041399683803  seconds by  0.0  percent.
# uncontrolled cost :  728478.2773809158
# cost splitting :  29278.970956521513 [0. 0.]
# set cost params:  1.0 0.0 40000.0
# interpolate adjoint :  True True True
# initial cost =  728478.2773809158
# RUN  0 , total integrated cost =  728478.2773809158
# Gradient descend method:  None
# RUN  1 , total integrated cost =  492464.7771465408
# RUN  2 , total integrated cost =  421857.25979367376
# RUN  3 , total integrated cost =  399077.9883050065
# RUN  4 , total integrated cost =  387699.22954603884
# RUN  5 , total integrated cost =  379102.1433252126
# RUN  6 , total integrated cost =  373041.4431336205
# RUN  7 , total integrated cost =  367388.1444612276
# RUN  8 , total integrated cost =  363139.10619813495
# RUN  9 , total integrated cost =  358885.70915652916
# RUN  10 , total integrated cost =  355445.8765114655
# RUN  10 , total integrated cost =  355445.8765114655
# Improved over  10  iterations in  1.5652361509855837  seconds by  51.2070726680563  percent.
# uncontrolled cost :  728478.2773809158
# cost splitting :  88.2941097763413 [0.         8.83122666]
# set cost params:  1.0 0.0 49000.0
# interpolate adjoint :  True True True
# initial cost =  728478.2773809158
# RUN  0 , total integrated cost =  728478.2773809158
# Gradient descend method:  None
# RUN  1 , total integrated cost =  728478.2773809158
# Control only changes marginally.
# RUN  1 , total integrated cost =  728478.2773809158
# Improved over  1  iterations in  0.3385335080092773  seconds by  0.0  percent.
# uncontrolled cost :  728478.2773809158
# cost splitting :  29278.970956521513 [0. 0.]
# set cost params:  1.0 0.0 48000.0
# interpolate adjoint :  True True True
# initial cost =  728478.2773809158
# RUN  0 , total integrated cost =  728478.2773809158
# Gradient descend method:  None
# RUN  1 , total integrated cost =  728478.2773809158
# Control only changes marginally.
# RUN  1 , total integrated cost =  728478.2773809158
# Improved over  1  iterations in  0.2602027060056571  seconds by  0.0  percent.
# uncontrolled cost :  728478.2773809158
# cost splitting :  29278.970956521513 [0. 0.]
# set cost params:  1.0 0.0 47000.0
# interpolate adjoint :  True True True
# initial cost =  728478.2773809158
# RUN  0 , total integrated cost =  728478.2773809158
# Gradient descend method:  None
# RUN  1 , total integrated cost =  561108.7750235351
# RUN  2 , total integrated cost =  482158.87258706975
# RUN  3 , total integrated cost =  459701.45525819657
# RUN  4 , total integrated cost =  447055.2101870143
# RUN  5 , total integrated cost =  436979.87590990536
# RUN  6 , total integrated cost =  429793.1522213405
# RUN  7 , total integrated cost =  423068.76884078846
# RUN  8 , total integrated cost =  418075.74723156367
# RUN  9 , total integrated cost =  412817.2803529515
# RUN  10 , total integrated cost =  408833.0106531219
# RUN  11 , total integrated cost =  404761.2310966859
# RUN  12 , total integrated cost =  401626.50912050094
# RUN  13 , total integrated cost =  398355.1253949399
# RUN  14 , total integrated cost =  395751.8634857
# RUN  15 , total integrated cost =  392991.9194516836
# RUN  16 , total integrated cost =  390744.62775038154
# RUN  17 , total integrated cost =  388314.39449699345
# RUN  18 , total integrated cost =  386243.01503995404
# RUN  19 , total integrated cost =  384080.4744718919
# RUN  20 , total integrated cost =  382387.8289697381
# RUN  30 , total integrated cost =  370683.02594676276
# RUN  40 , total integrated cost =  365044.617562235
# RUN  50 , total integrated cost =  359309.9157123034
# RUN  50 , total integrated cost =  359309.9157123034
# Improved over  50  iterations in  7.234065438999096  seconds by  50.67664652896397  percent.
# sparsity weight =  47000.0
# -------  82 0.5750000000000002 0.7000000000000004
# set cost params:  1.0 0.0 100000.0
# interpolate adjoint :  True True True
# initial cost =  854238.9955664313
# RUN  0 , total integrated cost =  854238.9955664313
# Gradient descend method:  None
# RUN  1 , total integrated cost =  854238.9955664313
# Control only changes marginally.
# RUN  1 , total integrated cost =  854238.9955664313
# Improved over  1  iterations in  0.2605336279957555  seconds by  0.0  percent.
# set cost params:  1.0 0.0 10000.0
# interpolate adjoint :  True True True
# initial cost =  854238.9955664313
# RUN  0 , total integrated cost =  854238.9955664313
# Gradient descend method:  None
# RUN  1 , total integrated cost =  128259.82562407063
# RUN  2 , total integrated cost =  109126.17443289227
# RUN  3 , total integrated cost =  77066.68725011768
# RUN  4 , total integrated cost =  68195.31375348089
# RUN  5 , total integrated cost =  62332.86332524392
# RUN  6 , total integrated cost =  62198.14448778538
# RUN  7 , total integrated cost =  61973.76901090535
# RUN  8 , total integrated cost =  61815.345960005485
# RUN  9 , total integrated cost =  61641.0056739225
# RUN  10 , total integrated cost =  61508.25535313806
# RUN  10 , total integrated cost =  61508.25535313806
# Improved over  10  iterations in  1.9142668499844149  seconds by  92.79964322954456  percent.
# uncontrolled cost :  854238.9955664313
# cost splitting :  47.25891334298179 [0.         6.03324254]
# set cost params:  1.0 0.0 90000.0
# interpolate adjoint :  True True True
# initial cost =  854238.9955664313
# RUN  0 , total integrated cost =  854238.9955664313
# Gradient descend method:  None
# RUN  1 , total integrated cost =  854238.9955664313
# Control only changes marginally.
# RUN  1 , total integrated cost =  854238.9955664313
# Improved over  1  iterations in  0.3482871429878287  seconds by  0.0  percent.
# uncontrolled cost :  854238.9955664313
# cost splitting :  34333.54091358782 [0. 0.]
# set cost params:  1.0 0.0 80000.0
# interpolate adjoint :  True True True
# initial cost =  854238.9955664313
# RUN  0 , total integrated cost =  854238.9955664313
# Gradient descend method:  None
# RUN  1 , total integrated cost =  791016.803468339
# RUN  2 , total integrated cost =  737960.643020629
# RUN  3 , total integrated cost =  700699.8313551673
# RUN  4 , total integrated cost =  677253.1428053704
# RUN  5 , total integrated cost =  656863.4751030836
# RUN  6 , total integrated cost =  641862.441610578
# RUN  7 , total integrated cost =  625919.6801305152
# RUN  8 , total integrated cost =  614990.7236902738
# RUN  9 , total integrated cost =  602369.4613394974
# RUN  10 , total integrated cost =  593482.7038431885
# RUN  10 , total integrated cost =  593482.7038431885
# Improved over  10  iterations in  1.444801486999495  seconds by  30.524981073983852  percent.
# uncontrolled cost :  854238.9955664313
# cost splitting :  443.0216954318507 [0.         7.28075074]
# set cost params:  1.0 0.0 89000.0
# interpolate adjoint :  True True True
# initial cost =  854238.9955664313
# RUN  0 , total integrated cost =  854238.9955664313
# Gradient descend method:  None
# RUN  1 , total integrated cost =  854238.9955664313
# Control only changes marginally.
# RUN  1 , total integrated cost =  854238.9955664313
# Improved over  1  iterations in  0.27848976699169725  seconds by  0.0  percent.
# uncontrolled cost :  854238.9955664313
# cost splitting :  34333.54091358782 [0. 0.]
# set cost params:  1.0 0.0 88000.0
# interpolate adjoint :  True True True
# initial cost =  854238.9955664313
# RUN  0 , total integrated cost =  854238.9955664313
# Gradient descend method:  None
# RUN  1 , total integrated cost =  854238.9955664313
# Control only changes marginally.
# RUN  1 , total integrated cost =  854238.9955664313
# Improved over  1  iterations in  0.27711201398051344  seconds by  0.0  percent.
# uncontrolled cost :  854238.9955664313
# cost splitting :  34333.54091358782 [0. 0.]
# set cost params:  1.0 0.0 87000.0
# interpolate adjoint :  True True True
# initial cost =  854238.9955664313
# RUN  0 , total integrated cost =  854238.9955664313
# Gradient descend method:  None
# RUN  1 , total integrated cost =  854238.9955664313
# Control only changes marginally.
# RUN  1 , total integrated cost =  854238.9955664313
# Improved over  1  iterations in  0.3499863430042751  seconds by  0.0  percent.
# uncontrolled cost :  854238.9955664313
# cost splitting :  34333.54091358782 [0. 0.]
# set cost params:  1.0 0.0 86000.0
# interpolate adjoint :  True True True
# initial cost =  854238.9955664313
# RUN  0 , total integrated cost =  854238.9955664313
# Gradient descend method:  None
# RUN  1 , total integrated cost =  854238.9955664313
# Control only changes marginally.
# RUN  1 , total integrated cost =  854238.9955664313
# Improved over  1  iterations in  0.2654821120086126  seconds by  0.0  percent.
# uncontrolled cost :  854238.9955664313
# cost splitting :  34333.54091358782 [0. 0.]
# set cost params:  1.0 0.0 85000.0
# interpolate adjoint :  True True True
# initial cost =  854238.9955664313
# RUN  0 , total integrated cost =  854238.9955664313
# Gradient descend method:  None
# RUN  1 , total integrated cost =  854238.9955664313
# Control only changes marginally.
# RUN  1 , total integrated cost =  854238.9955664313
# Improved over  1  iterations in  0.22704812299343757  seconds by  0.0  percent.
# uncontrolled cost :  854238.9955664313
# cost splitting :  34333.54091358782 [0. 0.]
# set cost params:  1.0 0.0 84000.0
# interpolate adjoint :  True True True
# initial cost =  854238.9955664313
# RUN  0 , total integrated cost =  854238.9955664313
# Gradient descend method:  None
# RUN  1 , total integrated cost =  825923.6400069387
# RUN  2 , total integrated cost =  771387.9365580296
# RUN  3 , total integrated cost =  729948.1026176929
# RUN  4 , total integrated cost =  702982.714016111
# RUN  5 , total integrated cost =  669296.546004641
# RUN  6 , total integrated cost =  647352.2352955773
# RUN  7 , total integrated cost =  590809.3750917685
# RUN  8 , total integrated cost =  575595.2659851294
# RUN  9 , total integrated cost =  566942.872124484
# RUN  10 , total integrated cost =  562130.7142063099
# RUN  11 , total integrated cost =  560089.1921811688
# RUN  12 , total integrated cost =  557902.8069177127
# RUN  13 , total integrated cost =  555883.690191539
# RUN  14 , total integrated cost =  553852.2352605953
# RUN  15 , total integrated cost =  552701.4887669827
# RUN  16 , total integrated cost =  551423.6989279145
# RUN  17 , total integrated cost =  550357.6426860614
# RUN  18 , total integrated cost =  549177.2114439863
# RUN  19 , total integrated cost =  548385.2849350575
# RUN  20 , total integrated cost =  547498.4206363747
# RUN  30 , total integrated cost =  541287.9747789907
# RUN  40 , total integrated cost =  536989.5390992226
# RUN  50 , total integrated cost =  530677.5173496514
# RUN  50 , total integrated cost =  530677.5173496514
# Improved over  50  iterations in  6.992438705987297  seconds by  37.877160829239806  percent.
# sparsity weight =  84000.0

# %%
bad = [0, 1, 2, 70, 71, 72, 76, 78, 79, 80]

# %%
c_var = [0,1]

for i in i_range:
    print("------- ", i, exc[i], inh[i])
    
    if i in bad:
        continue
        
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    k = 0
    
    while not conv[i]:
        max_it = min( 1000, int(100 + 100*k) )
        
        weight_ = ( cost_uncontrolled[i] - costnode_[i][0][0][0] ) / sum( costnode_[i][index_cost][0][:] )       
            
        dur = d_array[0]
        aln.params.duration = dur
        cost.setParams(1., weight_ * factor_we, weight_ * factor_ws)
        weights_[i] = cost.getParams()

        setinit(initVars[i], aln)

        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        control0 = aln.getZeroControl()
        control0 = bestControl_[i][:,:,n_pre-1:-n_post+1]

        bestControl_[i], bestState_[i], cost_[i], runtime_, grad_, phi_, phi1_, costnode_[i] = aln.A1(
            control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
            prec_variables_ = p_var, transition_time_ = t_pen[0])
        
        if max_it > 1:
            if cost_[i][2] == 0.:
                conv[i] = True

        print('cost splitting : ', costnode_[i][0][0][0], costnode_[i][index_cost][0][:2])

        if conv[i]:
            time_ = np.arange(-dur_pre,round(dur+dur_post+aln.params.dt,1),aln.params.dt)
            target_ = aln.getZeroTarget()
            target_[:,0,:] = target[i][0]
            target_[:,1,:] = target[i][1]
        
            fig, ax = plt.subplots(2,1, constrained_layout=True, figsize = (4,4) )
            ax[1].plot(time_, bestControl_[i][0,0,:], color = 'red')
            ax[0].plot(time_, bestState_[i][0,0,:], color= 'red')
            ax[1].plot(time_, bestControl_[i][0,1,:], color = 'blue')
            ax[0].plot(time_, bestState_[i][0,1,:], color= 'blue')
            ax[0].plot(time_, target_[0,0,:], linestyle = '--', color='red')
            ax[0].plot(time_, target_[0,1,:], linestyle = '--', color='blue')
            ax[0].set_xlim(-dur_pre,dur+dur_post)
            ax[1].set_xlim(-dur_pre,dur+dur_post)
            ax[0].axvspan(dur*t_pen[0], dur, alpha=0.2, color='gray')
            plt.show()

        with open(file_,'wb') as f:
            pickle.dump([bestControl_, bestState_, cost_, costnode_, weights_], f)
        
        k += 1
# Out:
# -------  0 0.4000000000000001 0.3500000000000001
# -------  1 0.4250000000000001 0.3500000000000001
# -------  2 0.4000000000000001 0.3750000000000001
# -------  3 0.4250000000000001 0.3750000000000001
# set cost params:  1.0 773173.9897690467 0.0
# interpolate adjoint :  True True True
# initial cost =  242223.944970472
# RUN  0 , total integrated cost =  242223.944970472
# Gradient descend method:  None
# RUN  1 , total integrated cost =  242223.7276612719
# RUN  2 , total integrated cost =  242223.6222562541
# RUN  3 , total integrated cost =  242223.59182184268
# RUN  4 , total integrated cost =  242223.47501208732
# RUN  5 , total integrated cost =  242223.44314182954
# RUN  6 , total integrated cost =  242223.40482789127
# RUN  7 , total integrated cost =  242223.28451042456
# RUN  8 , total integrated cost =  242223.2554974162
# RUN  9 , total integrated cost =  242223.21624558876
# RUN  10 , total integrated cost =  242223.09327782074
# RUN  11 , total integrated cost =  242223.06198843577
# RUN  12 , total integrated cost =  242223.0319943335
# RUN  13 , total integrated cost =  242222.91239208958
# RUN  14 , total integrated cost =  242222.87758331286
# RUN  15 , total integrated cost =  242222.85389636905
# RUN  16 , total integrated cost =  242222.7214102376
# RUN  17 , total integrated cost =  242222.67603818435
# RUN  18 , total integrated cost =  242222.6599730506
# RUN  19 , total integrated cost =  242222.4355340377
# RUN  20 , total integrated cost =  242222.31654857023
# RUN  30 , total integrated cost =  242172.66535265453
# RUN  40 , total integrated cost =  242165.90642097878
# RUN  50 , total integrated cost =  242148.9805535903
# RUN  60 , total integrated cost =  242147.97970998325
# RUN  70 , total integrated cost =  242147.14007159782
# RUN  80 , total integrated cost =  242146.1661611796
# RUN  90 , total integrated cost =  242133.27002591453
# RUN  100 , total integrated cost =  242122.13300312406
# RUN  100 , total integrated cost =  242122.13300312406
# Improved over  100  iterations in  32.35381791301188  seconds by  0.042032164640176006  percent.
# cost splitting :  30.513854320930598 [0.11391355 0.19825801]
# set cost params:  1.0 773452.3768938255 0.0
# interpolate adjoint :  True True True
# initial cost =  242209.0375459884
# RUN  0 , total integrated cost =  242209.0375459884
# Gradient descend method:  None
# RUN  1 , total integrated cost =  242208.94032994696
# RUN  2 , total integrated cost =  242208.71494062254
# RUN  3 , total integrated cost =  242208.66711005155
# RUN  4 , total integrated cost =  242201.97863898665
# RUN  5 , total integrated cost =  242195.81195748303
# RUN  6 , total integrated cost =  242195.78401796846
# RUN  7 , total integrated cost =  242188.60398295708
# RUN  8 , total integrated cost =  242182.94485516052
# RUN  9 , total integrated cost =  242182.9127919601
# RUN  10 , total integrated cost =  242182.78513287826
# RUN  11 , total integrated cost =  242182.75220334352
# RUN  12 , total integrated cost =  242182.72597697197
# RUN  13 , total integrated cost =  242182.59201844095
# RUN  14 , total integrated cost =  242182.54778991532
# RUN  15 , total integrated cost =  242182.52942717023
# RUN  16 , total integrated cost =  242182.36238297125
# RUN  17 , total integrated cost =  242182.29472673827
# RUN  18 , total integrated cost =  242182.28002859352
# RUN  19 , total integrated cost =  242182.01180032338
# RUN  20 , total integrated cost =  242181.87408295853
# RUN  30 , total integrated cost =  242180.3115572536
# RUN  40 , total integrated cost =  242179.5684666048

# %%
for i in i_range:
    print("------- ", i, exc[i], inh[i])
    
    if i in bad:
        continue
        
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    dur = d_array[0]
    aln.params.duration = dur
    max_it = int(0)
    
    for l in range( bestControl_[i].shape[2] ):
        if np.abs(bestControl_[i][0,0,l]) > 5. * 1e-6 or np.abs(bestControl_[i][0,1,l]) > 5. * 1e-6:
            init_ind = l
            break
            
    print("init ind = ", init_ind)

    weight_ = 1.
    cost.setParams(1., weight_ * factor_we, weight_ * factor_ws)
    weights_[i] = cost.getParams()

    setinit(initVars[i], aln)

    target_ = aln.getZeroTarget()
    target_[:,0,:] = target[i][0]
    target_[:,1,:] = target[i][1]

    control0 = aln.getZeroControl()
    if init_ind != 0:
        control0[:,:,:-init_ind] = bestControl_[i][:,:,n_pre-1+init_ind:-n_post+1]
    else:
        control0 = bestControl_[i][:,:,n_pre-1:-n_post+1]

    bestControl_[i], bestState_[i], cost_[i], runtime_, grad_, phi_, phi1_, costnode_[i] = aln.A1(
        control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
        prec_variables_ = p_var, transition_time_ = t_pen[j])

    print('uncontrolled cost : ', cost_uncontrolled[i])
    print('cost splitting : ', costnode_[i][0][0][0], costnode_[i][index_cost][0][:2])

    if True:
        time_ = np.arange(-dur_pre,round(dur+dur_post+aln.params.dt,1),aln.params.dt)
        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]
    
        fig, ax = plt.subplots(2,1, constrained_layout=True, figsize = (4,4) )
        ax[1].plot(time_, bestControl_[i][0,0,:], color = 'red')
        ax[0].plot(time_, bestState_[i][0,0,:], color= 'red')
        ax[1].plot(time_, bestControl_[i][0,1,:], color = 'blue')
        ax[0].plot(time_, bestState_[i][0,1,:], color= 'blue')
        ax[0].plot(time_, target_[0,0,:], linestyle = '--', color='red')
        ax[0].plot(time_, target_[0,1,:], linestyle = '--', color='blue')
        ax[0].set_xlim(-dur_pre,dur+dur_post)
        ax[1].set_xlim(-dur_pre,dur+dur_post)
        ax[0].axvspan(dur*t_pen[j], dur, alpha=0.2, color='gray')
        plt.show()

    with open(file_,'wb') as f:
        pickle.dump([bestControl_, bestState_, cost_, costnode_, weights_], f)

# %%
for i in i_range:
    print("------- ", i, exc[i], inh[i])
    
    if i in bad:
        continue
        
    aln.params.ext_exc_current = exc[i] * 5.
    aln.params.ext_inh_current = inh[i] * 5.
    
    aln.params.duration = dur
    max_it = int(10000)
    
    while not conv_shift[i]:
            
        weight_ = 1.
        cost.setParams(1., weight_ * factor_we, weight_ * factor_ws)
        weights_[i] = cost.getParams()

        setinit(initVars[i], aln)

        target_ = aln.getZeroTarget()
        target_[:,0,:] = target[i][0]
        target_[:,1,:] = target[i][1]

        control0 = aln.getZeroControl()
        control0 = bestControl_[i][:,:,n_pre-1:-n_post+1]

        bestControl_[i], bestState_[i], cost_[i], runtime_, grad_, phi_, phi1_, costnode_[i]= aln.A1(
            control0, target_, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
            startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
            t_sim_pre_ = dur_pre, t_sim_post_ = dur_post, CGVar = cgv, control_variables_ = c_var,
            prec_variables_ = p_var, transition_time_ = t_pen[0])
        
        if cost_[i][-1] == 0.:
            conv_shift[i] = True

        print('uncontrolled cost : ', cost_uncontrolled[i])
        print('cost splitting : ', costnode_[i][0][0][0], costnode_[i][index_cost][0][:2])

        if False:
            time_ = np.arange(-dur_pre,round(dur+dur_post+aln.params.dt,1),aln.params.dt)
            target_ = aln.getZeroTarget()
            target_[:,0,:] = target[i][0]
            target_[:,1,:] = target[i][1]

            fig, ax = plt.subplots(2,1, constrained_layout=True, figsize = (4,4) )
            ax[1].plot(time_, bestControl_[i][0,0,:], color = 'red')
            ax[0].plot(time_, bestState_[i][0,0,:], color= 'red')
            ax[1].plot(time_, bestControl_[i][0,1,:], color = 'blue')
            ax[0].plot(time_, bestState_[i][0,1,:], color= 'blue')
            ax[0].plot(time_, target_[0,0,:], linestyle = '--', color='red')
            ax[0].plot(time_, target_[0,1,:], linestyle = '--', color='blue')
            ax[0].set_xlim(-dur_pre,dur+dur_post)
            ax[1].set_xlim(-dur_pre,dur+dur_post)
            ax[0].axvspan(dur*t_pen[0], dur, alpha=0.2, color='gray')
            plt.show()

        with open(file_,'wb') as f:
            pickle.dump([bestControl_, bestState_, cost_, costnode_, weights_], f)
