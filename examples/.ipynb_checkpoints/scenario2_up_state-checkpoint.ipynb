# %%
#Scenario 2: bistable state
#2.1.a: short simulation duration, constant target
#2.1.b: long simulation duration, constant target
#2.2.a: short simulation duration, sin target
#2.2.b: long simulation duration, sin target

# %%
# change to the root directory of the project
import os
if os.getcwd().split(os.sep)[-1] == "examples":
    os.chdir('..')
    
path = os.getcwd()
import sys
if path not in sys.path:
    sys.path.append(path)
    
# This will reload all imports as soon as the code changes
# %load_ext autoreload
# %autoreload 2    

import matplotlib.pyplot as plt
import numpy as np
#import testing
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Let's import the aln model
from neurolib.models.aln import ALNModel

# Some useful functions are provided here
import neurolib.utils.functions as func

aln = ALNModel()

# %%
def plot_rate(model, control_, target_ = None):
    aln.run( control = control_ )
    time = model['t']

    fig, ax = plt.subplots()

    ax.plot(time, model['rates_exc'].T, lw=2, c='k', label='Exc activity')
    ax.set_xlabel("t [ms]")
    ax.set_ylabel("Rate [Hz]")
    ax.set_xlim([0,model.params['duration']])
    
    if type(target_) != type(None):
        ax.plot(time, target_[0,0,:], lw=2, c='yellow', label='Target')

    #ax2 = ax.twinx()
    #ax2.plot(time, control_[0,0,:]/5., lw=1, c='red', label='Exc control')
    #ax2.plot(time, control_[0,1,:]/5., lw=1, c='blue', label='Inh control')
    #ax2.set_xlabel("t [ms]")
    #ax2.set_ylabel("Control current [nA]")

    plt.legend()
    plt.show()

# %%
#initialize model

def set_aln_init_zero():
    N = aln.params.N
    aln.params.mufe_init = 0 * np.random.uniform(0, 1, (N,))  # mV/ms
    aln.params.mufi_init = 0 * np.random.uniform(0, 1, (N,))  # mV/ms
    aln.params.seem_init = 0. * np.random.uniform(0, 1, (N,))
    aln.params.seim_init = 0. * np.random.uniform(0, 1, (N,))
    aln.params.seev_init = 0. * np.random.uniform(0, 1, (N,))
    aln.params.seiv_init = 0. * np.random.uniform(0, 1, (N,))
    aln.params.siim_init = 0. * np.random.uniform(0, 1, (N,))
    aln.params.siem_init = 0. * np.random.uniform(0, 1, (N,))
    aln.params.siiv_init = 0. * np.random.uniform(0, 1, (N,))
    aln.params.siev_init = 0. * np.random.uniform(0, 1, (N,))
    aln.params.rates_exc_init = 0. * np.random.uniform(0, 1, (N, 1))
    aln.params.rates_inh_init = 0. * np.random.uniform(0, 1, (N, 1))
    aln.params.IA_init = 0.0 * np.zeros((N, 1))  # pA
    aln.params.mue_ou = 0. * np.random.uniform(0, 1, (N,))
    aln.params.mui_ou = 0. * np.random.uniform(0, 1, (N,))

# reads final state of model dynamics
# set before simulation such that system begins in stable state
def read_state():
    init_state_vars = np.zeros(( len(state_vars) ))
    for j in range(len(state_vars)):
        if aln.state[state_vars[j]].size == 1:
            init_state_vars[j] = aln.state[state_vars[j]][0]
        else:
            init_state_vars[j] = aln.state[state_vars[j]][0,-1]
    return init_state_vars
    
aln = ALNModel()
set_aln_init_zero()
aln.params.a = 0. # no adaptation
aln.params.b = 0. # no adaptation
aln.params.ext_exc_current = 0.
aln.params.ext_inh_current = 0.
aln.params['duration'] = 1000. 

control0 = aln.getZeroControl()
control0[0,0,1000:2000] = 5.
control0[0,0,5000:6000] = -5.

state_vars = aln.state_vars

# up state
print("up state")
aln.params.mue_ext_mean = 0.5 * 5.
aln.params.mui_ext_mean = 0. * 5.
    
plot_rate(aln, control0)
init_up = read_state()
# Out:
# up state

# %%
 # to set initial parameters
def setinit(init_vars_, model):
    
    for iv in range(len(model.init_vars)):
        for sv in range(len(model.state_vars)):
            if model.state_vars[sv] in model.init_vars[iv]:
                if model.params[model.init_vars[iv]].ndim == 2:
                    model.params[model.init_vars[iv]][0,:] = init_vars_[sv]
                else:
                    model.params[model.init_vars[iv]][0] = init_vars_[sv]

# %%
# fixed initialization should imply reproducibility, try also for other cases

aln = ALNModel()
set_aln_init_zero()
aln.params.a = 0. # no adaptation
aln.params.b = 0. # no adaptation
aln.params.ext_exc_current = 0.
aln.params.ext_inh_current = 0.
aln.params['duration'] = 1000. 
aln.params.mue_ext_mean = 0.5 * 5.  # try also other cases parameters
aln.params.mui_ext_mean = 0. * 5.
setinit(init_up, aln)

control0 = aln.getZeroControl()
plot_rate(aln, control0)

# %%
# set parameters
tol = 1e-12 # algorithm tolerance for convergence

start_step = 10. # start step of gradient descent

c_scheme = np.zeros(( 1,1 )) # coupling scheme, only relevant for networks
c_scheme[0,0] = 1. # coupling scheme, only relevant for networks
u_mat = np.identity(1) # control matrix
u_scheme = np.array([[1.]]) # control scheme

max_it = 1000 # maximum number of iterations

max_cntrl = [5., 5., 0., 0., 0., 0.] # maximum value of control current in input nodes (exc current, inh current, rates)
min_cntrl = [-5., -5., 0., 0., 0., 0.]

cgv_list = [None, "HS", "FR", "PR", "CD", "LS", "DY", "WYL", "HZ"] # different gradient descent methods
cgv = cgv_list[0]

# %%
# scenario 2.1.a
# const target, short sim time
dur = 20. # simulation duration
aln.params.duration = dur
setinit(init_up, aln)

control0 = aln.getZeroControl()
control0[0,0,1000:2000] = 0.1

target_const = aln.getZeroTarget()
target_const[0,0,:] = 50

# oscillation should be somewhat realistic, so roughly like what we find in stable oscillatory states.
# One period is roughly 40ms
target_osc = aln.getZeroTarget()
x_osc = np.arange(0.,dur+aln.params.dt,aln.params.dt)
target_osc[0,0,:] = 25. + 25. * np.sin(0.2 * x_osc)

# %%
#scenario 2.1.a

max_it_ = 400
cost_list_21a = []
runtime_list_21a = []
termination_it_21a = []
best_control_list_21a = []

for cgv_tmp in cgv_list:
    setinit(init_up, aln)
    bestControl, bestState, cost, runtime, gradient, adjoint, costnode = aln.A1(
        control0, target_const, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = 0., t_sim_post_ = 0., CGVar = cgv_tmp, control_variables_ = [0],
        prec_variables_ = [0], transition_time_ = 0.25)
    
    best_control_list_21a.append(bestControl)
    cost_list_21a.append(cost)
    runtime_list_21a.append(runtime)
    
    for cost_ind in range(len(cost)):
        if cost[cost_ind] == 0.:
            termination_it_21a.append(cost_ind-1)
            break
# Out:
# ERROR:root:Not possible to set up initial conditions without sufficient simulation time before control
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1716.483763719746
# Gradient descend method:  None
# RUN  1 , total integrated cost =  200.519347627535
# RUN  2 , total integrated cost =  53.99358995856628
# RUN  3 , total integrated cost =  24.670323671726894
# RUN  4 , total integrated cost =  14.045544875038502
# RUN  5 , total integrated cost =  9.938113673778354
# RUN  6 , total integrated cost =  7.775758437296569
# RUN  7 , total integrated cost =  6.621716007393649
# RUN  8 , total integrated cost =  5.884794242272416
# RUN  9 , total integrated cost =  5.398531375133706
# RUN  10 , total integrated cost =  5.050274536964639
# RUN  11 , total integrated cost =  4.799518864435869
# RUN  12 , total integrated cost =  4.617523342859408
# RUN  13 , total integrated cost =  4.470524078862778
# RUN  14 , total integrated cost =  4.360010168366858
# RUN  15 , total integrated cost =  4.264307513061368
# RUN  16 , total integrated cost =  4.191766932380743
# RUN  17 , total integrated cost =  4.124790004423084
# RUN  18 , total integrated cost =  4.074431468482434
# RUN  19 , total integrated cost =  4.024858074910774
# RUN  20 , total integrated cost =  3.9877131839355107
# RUN  30 , total integrated cost =  3.6121671489242186
# RUN  40 , total integrated cost =  3.6043491919646367
# RUN  50 , total integrated cost =  3.6009237623772536
# ERROR:root:Not possible to set up initial conditions without sufficient simulation time before control
# RUN  60 , total integrated cost =  3.595064744379429
# Control only changes marginally.
# RUN  65 , total integrated cost =  3.591192495423865
# Improved over  65  iterations in  0.8330971000000318  seconds by  99.79078202944132  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1716.483763719746
# Gradient descend method:  HS
# RUN  1 , total integrated cost =  200.519347627535
# RUN  2 , total integrated cost =  52.42768327302667
# RUN  3 , total integrated cost =  17.52611762724235
# RUN  4 , total integrated cost =  10.234311793813319
# RUN  5 , total integrated cost =  6.6627021116197405
# RUN  6 , total integrated cost =  5.479624996471889
# RUN  7 , total integrated cost =  4.744255043288499
# RUN  8 , total integrated cost =  4.39439193171392
# RUN  9 , total integrated cost =  4.124125089028002
# RUN  10 , total integrated cost =  4.010552482654415
# RUN  11 , total integrated cost =  3.8735757584234443
# RUN  12 , total integrated cost =  3.8107780842067296
# RUN  13 , total integrated cost =  3.7560362132964107
# RUN  14 , total integrated cost =  3.7238040788936333
# RUN  15 , total integrated cost =  3.7007922094297254
# RUN  16 , total integrated cost =  3.6668085395917793
# RUN  17 , total integrated cost =  3.642476677494497
# RUN  18 , total integrated cost =  3.633527014807556
# RUN  19 , total integrated cost =  3.62527356357724
# RUN  20 , total integrated cost =  3.617260085540032
# ERROR:root:Not possible to set up initial conditions without sufficient simulation time before control
# RUN  30 , total integrated cost =  3.5955601706508453
# Control only changes marginally.
# RUN  30 , total integrated cost =  3.5955601706508453
# Improved over  30  iterations in  0.5122749000000226  seconds by  99.7905275746472  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1716.483763719746
# Gradient descend method:  FR
# RUN  1 , total integrated cost =  200.519347627535
# RUN  2 , total integrated cost =  32.61208608207264
# RUN  3 , total integrated cost =  12.598561622373829
# RUN  4 , total integrated cost =  7.805763844077383
# RUN  5 , total integrated cost =  5.781611645681185
# RUN  6 , total integrated cost =  4.86489573440435
# RUN  7 , total integrated cost =  4.477874422721712
# RUN  8 , total integrated cost =  4.141969555876464
# RUN  9 , total integrated cost =  3.980107749974515
# RUN  10 , total integrated cost =  3.8652599608167657
# RUN  11 , total integrated cost =  3.8249515251202446
# RUN  12 , total integrated cost =  3.7602440482285746
# RUN  13 , total integrated cost =  3.7312774990794524
# RUN  14 , total integrated cost =  3.7055827661857483
# RUN  15 , total integrated cost =  3.6824619547651207
# RUN  16 , total integrated cost =  3.6755272436020654
# RUN  17 , total integrated cost =  3.6690288634175756
# RUN  18 , total integrated cost =  3.6553798168068883
# RUN  19 , total integrated cost =  3.645872821050073
# RUN  20 , total integrated cost =  3.6381539449152642
# RUN  30 , total integrated cost =  3.6035087441297016
# RUN  40 , total integrated cost =  3.59753831137016
# RUN  50 , total integrated cost =  3.5905968922740437
# RUN  60 , total integrated cost =  3.5903319246450733
# RUN  70 , total integrated cost =  3.5903281967991134
# RUN  80 , total integrated cost =  3.5903275367390624
# RUN  90 , total integrated cost =  3.5903272785834726
# RUN  100 , total integrated cost =  3.5903271463871027
# RUN  110 , total integrated cost =  3.5903270636785063
# RUN  120 , total integrated cost =  3.5903270100479316
# RUN  130 , total integrated cost =  3.5903269718863795
# RUN  140 , total integrated cost =  3.590326941225874
# RUN  150 , total integrated cost =  3.5903269178559296
# RUN  160 , total integrated cost =  3.59032689948175
# RUN  170 , total integrated cost =  3.590326884009568
# RUN  180 , total integrated cost =  3.590326871410558
# RUN  190 , total integrated cost =  3.5903268608826915
# RUN  200 , total integrated cost =  3.5903268511947
# RUN  300 , total integrated cost =  3.5903267965629
# RUN  400 , total integrated cost =  3.590326771535945
# RUN  500 , total integrated cost =  3.5903267563437096
# RUN  600 , total integrated cost =  3.590326745919871
# RUN  700 , total integrated cost =  3.590326738032676
# RUN  800 , total integrated cost =  3.5903267320204844
# RUN  900 , total integrated cost =  3.5903267270054786
# ERROR:root:Not possible to set up initial conditions without sufficient simulation time before control
# RUN  1000 , total integrated cost =  3.5903267228236047
# RUN  1000 , total integrated cost =  3.5903267228236047
# Improved over  1000  iterations in  11.521202700000003  seconds by  99.79083246817068  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1716.483763719746
# Gradient descend method:  PR
# RUN  1 , total integrated cost =  200.519347627535
# RUN  2 , total integrated cost =  63.59456744614554
# RUN  3 , total integrated cost =  19.364227415757675
# RUN  4 , total integrated cost =  9.623266456101506
# RUN  5 , total integrated cost =  6.391731223469835
# RUN  6 , total integrated cost =  5.408961627155858
# RUN  7 , total integrated cost =  4.595656338923796
# RUN  8 , total integrated cost =  4.324931127079382
# RUN  9 , total integrated cost =  4.138199474788385
# RUN  10 , total integrated cost =  3.968265328699456
# RUN  11 , total integrated cost =  3.885761802797565
# RUN  12 , total integrated cost =  3.807121948398974
# RUN  13 , total integrated cost =  3.770782829321738
# RUN  14 , total integrated cost =  3.7371521382081454
# RUN  15 , total integrated cost =  3.7036972777982444
# RUN  16 , total integrated cost =  3.678326885567012
# RUN  17 , total integrated cost =  3.6530827421121543
# RUN  18 , total integrated cost =  3.6430871175668607
# RUN  19 , total integrated cost =  3.6403805877998567
# RUN  20 , total integrated cost =  3.637318019365604
# ERROR:root:Not possible to set up initial conditions without sufficient simulation time before control
# RUN  30 , total integrated cost =  3.6042303226615706
# Control only changes marginally.
# RUN  35 , total integrated cost =  3.59332135680884
# Improved over  35  iterations in  0.4646285999999691  seconds by  99.79065800488425  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1716.483763719746
# Gradient descend method:  CD
# RUN  1 , total integrated cost =  200.519347627535
# RUN  2 , total integrated cost =  32.61208608207264
# RUN  3 , total integrated cost =  12.1779104961486
# RUN  4 , total integrated cost =  7.790183421467374
# RUN  5 , total integrated cost =  5.758898294628729
# RUN  6 , total integrated cost =  5.040378548003076
# RUN  7 , total integrated cost =  4.710547049969786
# RUN  8 , total integrated cost =  4.482267624931105
# RUN  9 , total integrated cost =  4.2658180012553775
# RUN  10 , total integrated cost =  4.185786473879009
# RUN  11 , total integrated cost =  4.160385754423667
# RUN  12 , total integrated cost =  4.142478222855218
# RUN  13 , total integrated cost =  4.124838660045297
# RUN  14 , total integrated cost =  4.109016489078629
# RUN  15 , total integrated cost =  4.101684540973931
# RUN  16 , total integrated cost =  4.101590847273371
# RUN  17 , total integrated cost =  4.0965633470860325
# RUN  18 , total integrated cost =  4.078015536581663
# RUN  19 , total integrated cost =  4.0473864064294
# RUN  20 , total integrated cost =  4.017146489421544
# RUN  30 , total integrated cost =  3.864228977871306
# RUN  40 , total integrated cost =  3.7495241541089435
# ERROR:root:Not possible to set up initial conditions without sufficient simulation time before control
# RUN  50 , total integrated cost =  3.6704915501825672
# RUN  60 , total integrated cost =  3.6264200272548965
# Control only changes marginally.
# RUN  61 , total integrated cost =  3.626420027254895
# Improved over  61  iterations in  0.7665839999999662  seconds by  99.78872972154446  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1716.483763719746
# Gradient descend method:  LS
# RUN  1 , total integrated cost =  200.519347627535
# RUN  2 , total integrated cost =  63.59456744614554
# RUN  3 , total integrated cost =  19.133830316382017
# RUN  4 , total integrated cost =  9.841574598979669
# RUN  5 , total integrated cost =  6.539561392958443
# RUN  6 , total integrated cost =  5.5421118715189674
# RUN  7 , total integrated cost =  4.643934870493494
# RUN  8 , total integrated cost =  4.382826702573357
# RUN  9 , total integrated cost =  4.128089028098021
# RUN  10 , total integrated cost =  3.981710617459174
# RUN  11 , total integrated cost =  3.89238278400134
# RUN  12 , total integrated cost =  3.8084507219450385
# RUN  13 , total integrated cost =  3.7693190881579897
# RUN  14 , total integrated cost =  3.7510227935127785
# RUN  15 , total integrated cost =  3.7252920405350176
# RUN  16 , total integrated cost =  3.705501295856849
# RUN  17 , total integrated cost =  3.6943716482793887
# RUN  18 , total integrated cost =  3.6733628916357577
# RUN  19 , total integrated cost =  3.6654323254324677
# RUN  20 , total integrated cost =  3.661159228471406
# RUN  30 , total integrated cost =  3.614589100906234
# ERROR:root:Not possible to set up initial conditions without sufficient simulation time before control
# Control only changes marginally.
# RUN  39 , total integrated cost =  3.5938998054808726
# Improved over  39  iterations in  0.46382740000001377  seconds by  99.79062430525457  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1716.483763719746
# Gradient descend method:  DY
# RUN  1 , total integrated cost =  200.519347627535
# RUN  2 , total integrated cost =  33.86341170721261
# RUN  3 , total integrated cost =  13.475104569218692
# RUN  4 , total integrated cost =  7.893364676645027
# RUN  5 , total integrated cost =  5.721398592986784
# RUN  6 , total integrated cost =  4.792659851352449
# RUN  7 , total integrated cost =  4.237665918461307
# RUN  8 , total integrated cost =  4.066927325830697
# RUN  9 , total integrated cost =  3.9075621918467744
# RUN  10 , total integrated cost =  3.797303726852914
# RUN  11 , total integrated cost =  3.738908342141745
# RUN  12 , total integrated cost =  3.702336966760014
# RUN  13 , total integrated cost =  3.670998084534564
# RUN  14 , total integrated cost =  3.6535931253880793
# RUN  15 , total integrated cost =  3.639855735082431
# RUN  16 , total integrated cost =  3.62273016226927
# RUN  17 , total integrated cost =  3.615788449006107
# RUN  18 , total integrated cost =  3.6146627978153267
# RUN  19 , total integrated cost =  3.6139063201292694
# RUN  20 , total integrated cost =  3.6115589298538655
# RUN  30 , total integrated cost =  3.592822872410311
# ERROR:root:Not possible to set up initial conditions without sufficient simulation time before control
# RUN  40 , total integrated cost =  3.5928225272709495
# Control only changes marginally.
# RUN  44 , total integrated cost =  3.5928225272709367
# Improved over  44  iterations in  0.4790222999999969  seconds by  99.79068706601191  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1716.483763719746
# Gradient descend method:  WYL
# RUN  1 , total integrated cost =  200.519347627535
# RUN  2 , total integrated cost =  31.541421014381243
# RUN  3 , total integrated cost =  13.128967489315194
# RUN  4 , total integrated cost =  8.128152278993962
# RUN  5 , total integrated cost =  6.206577819712133
# RUN  6 , total integrated cost =  5.086995639227895
# RUN  7 , total integrated cost =  4.717169208731721
# RUN  8 , total integrated cost =  4.438295459343598
# RUN  9 , total integrated cost =  4.196556903060558
# RUN  10 , total integrated cost =  4.064278672407406
# RUN  11 , total integrated cost =  3.920802988055118
# RUN  12 , total integrated cost =  3.848848552137882
# RUN  13 , total integrated cost =  3.7870699326983326
# RUN  14 , total integrated cost =  3.7452011061263795
# RUN  15 , total integrated cost =  3.692030646622487
# RUN  16 , total integrated cost =  3.665109965807085
# RUN  17 , total integrated cost =  3.649112240800602
# RUN  18 , total integrated cost =  3.6446246632586323
# RUN  19 , total integrated cost =  3.6378277785943607
# RUN  20 , total integrated cost =  3.6362386582180823
# RUN  30 , total integrated cost =  3.609857366559786
# ERROR:root:Not possible to set up initial conditions without sufficient simulation time before control
# Control only changes marginally.
# RUN  38 , total integrated cost =  3.6098573645726506
# Improved over  38  iterations in  0.42161590000000615  seconds by  99.78969463965393  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  1716.483763719746
# Gradient descend method:  HZ
# RUN  1 , total integrated cost =  200.519347627535
# RUN  2 , total integrated cost =  53.99469904878169
# RUN  3 , total integrated cost =  24.67115489653875
# RUN  4 , total integrated cost =  14.046414058417492
# RUN  5 , total integrated cost =  9.938748066706655
# RUN  6 , total integrated cost =  7.776348593721618
# RUN  7 , total integrated cost =  6.622263680153265
# RUN  8 , total integrated cost =  5.885299208264505
# RUN  9 , total integrated cost =  5.399148845316054
# RUN  10 , total integrated cost =  5.05073155098562
# RUN  11 , total integrated cost =  4.800036655793234
# RUN  12 , total integrated cost =  4.617979874199664
# RUN  13 , total integrated cost =  4.471022772088902
# RUN  14 , total integrated cost =  4.360448809757553
# RUN  15 , total integrated cost =  4.264771828503137
# RUN  16 , total integrated cost =  4.192189759562459
# RUN  17 , total integrated cost =  4.125222374018212
# RUN  18 , total integrated cost =  4.074814741203411
# RUN  19 , total integrated cost =  4.025337961396882
# RUN  20 , total integrated cost =  3.988027762130962
# RUN  30 , total integrated cost =  3.6609133860944807
# RUN  40 , total integrated cost =  3.6216546852411016
# RUN  50 , total integrated cost =  3.587275184572502
# RUN  60 , total integrated cost =  3.5872751787328596
# Control only changes marginally.
# RUN  68 , total integrated cost =  3.587275178732763
# Improved over  68  iterations in  0.7405014000000278  seconds by  99.79101024696214  percent.

# %%
for cgv_ind in range(len(cgv_list)):
    plot_rate(aln, best_control_list_21a[cgv_ind], target_const)

# %%
marker_ = '.'
markersize_ = 3
linestyle_ = ''

fig, ax = plt.subplots(2, figsize=(8,8))

for i in range(len(termination_it_21a)):
    ax[0].plot(runtime_list_21a[i][:termination_it_21a[i]], cost_list_21a[i][:termination_it_21a[i]], marker=marker_,
             markersize = markersize_, linestyle=linestyle_, label = str(cgv_list[i]))
    performance = []
    for j in range(termination_it_21a[i]):
        performance.append( 100. * ( cost_list_21a[i][0] - cost_list_21a[i][j]) / cost_list_21a[i][0] ) 
    ax[1].plot(runtime_list_21a[i][:termination_it_21a[i]], performance, marker=marker_,
            markersize = markersize_, linestyle=linestyle_,
            label = str(cgv_list[i]) + ', termination at {:.2f}'.format(performance[-1]) + '% after ' + str(termination_it_21a[i]) + ' iterations' )
ax[0].legend()
ax[0].set_xlabel('Runtime [s]')
ax[0].set_ylabel('Cost')
#ax[0].title.set_text('Cost per runtime')
ax[1].legend()
ax[1].set_xlabel('Runtime [s]')
ax[1].set_ylabel('Improvement [%]')
#ax[0].title.set_text('Cost per runtime')


plt.show()

# %%
#scenario 2.2.a

max_it_ = 400
cost_list_22a = []
runtime_list_22a = []
termination_it_22a = []
best_control_list_22a = []

for cgv_tmp in cgv_list:
    setinit(init_up, aln)
    bestControl, bestState, cost, runtime, gradient, adjoint, costnode = aln.A1(
        control0, target_osc, c_scheme, u_mat, u_scheme, max_iteration_ = max_it, tolerance_ = tol,
        startStep_ = start_step, max_control_ = max_cntrl, min_control_ = min_cntrl, t_sim_ = dur,
        t_sim_pre_ = 0., t_sim_post_ = 0., CGVar = cgv_tmp, control_variables_ = [0],
        prec_variables_ = [0], transition_time_ = 0.25)
    
    best_control_list_22a.append(bestControl)
    cost_list_22a.append(cost)
    runtime_list_22a.append(runtime)
    
    for cost_ind in range(len(cost)):
        if cost[cost_ind] == 0.:
            termination_it_22a.append(cost_ind-1)
            break
# Out:
# interpolate adjoint :  True
# ERROR:root:Not possible to set up initial conditions without sufficient simulation time before control
#  True True
# RUN  0 , total integrated cost =  8478.947114591461
# Gradient descend method:  None
# RUN  1 , total integrated cost =  288.8120649888661
# RUN  2 , total integrated cost =  54.39114100399323
# RUN  3 , total integrated cost =  34.667224270281864
# RUN  4 , total integrated cost =  27.15417603208909
# RUN  5 , total integrated cost =  23.646070813073315
# RUN  6 , total integrated cost =  21.6037382888156
# RUN  7 , total integrated cost =  20.39007110730956
# RUN  8 , total integrated cost =  19.48074828560667
# RUN  9 , total integrated cost =  18.893469878124066
# RUN  10 , total integrated cost =  18.39381056756724
# RUN  11 , total integrated cost =  18.054970550971298
# RUN  12 , total integrated cost =  17.73475149746344
# RUN  13 , total integrated cost =  17.5124446460772
# RUN  14 , total integrated cost =  17.27206805556315
# RUN  15 , total integrated cost =  17.1051436037977
# RUN  16 , total integrated cost =  16.908880545381855
# RUN  17 , total integrated cost =  16.77450823444668
# RUN  18 , total integrated cost =  16.5487980053603
# RUN  19 , total integrated cost =  16.406451380686548
# RUN  20 , total integrated cost =  15.796977566221695
# RUN  30 , total integrated cost =  15.676593607338358
# RUN  40 , total integrated cost =  15.626494873565072
# RUN  50 , total integrated cost =  15.601247203270038
# ERROR:root:Not possible to set up initial conditions without sufficient simulation time before control
# RUN  60 , total integrated cost =  15.595836027607938
# Control only changes marginally.
# RUN  63 , total integrated cost =  15.595836027607813
# Improved over  63  iterations in  0.6925597000000039  seconds by  99.8160640016168  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  8478.947114591461
# Gradient descend method:  HS
# RUN  1 , total integrated cost =  288.8120649888661
# RUN  2 , total integrated cost =  55.377652293870014
# RUN  3 , total integrated cost =  31.864352498586783
# RUN  4 , total integrated cost =  23.01209777915468
# RUN  5 , total integrated cost =  20.072148856949514
# RUN  6 , total integrated cost =  18.758412414163885
# RUN  7 , total integrated cost =  17.800914009773074
# RUN  8 , total integrated cost =  17.317217840645533
# RUN  9 , total integrated cost =  16.429348001760776
# RUN  10 , total integrated cost =  16.285464762761094
# RUN  11 , total integrated cost =  16.12555761012426
# RUN  12 , total integrated cost =  15.967189570892302
# RUN  13 , total integrated cost =  15.834795857261863
# RUN  14 , total integrated cost =  15.790030011949117
# RUN  15 , total integrated cost =  15.760307442587862
# RUN  16 , total integrated cost =  15.722641239880144
# RUN  17 , total integrated cost =  15.696218301304889
# RUN  18 , total integrated cost =  15.66757075049733
# RUN  19 , total integrated cost =  15.642842938111299
# RUN  20 , total integrated cost =  15.632157694822133
# ERROR:root:Not possible to set up initial conditions without sufficient simulation time before control
# RUN  30 , total integrated cost =  15.623896267687392
# Control only changes marginally.
# RUN  38 , total integrated cost =  15.623896267586396
# Improved over  38  iterations in  0.48412270000000035  seconds by  99.81573306147058  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  8478.947114591461
# Gradient descend method:  FR
# RUN  1 , total integrated cost =  288.8120649888661
# RUN  2 , total integrated cost =  56.78858376701476
# RUN  3 , total integrated cost =  32.17967083632415
# RUN  4 , total integrated cost =  22.36026860559464
# RUN  5 , total integrated cost =  18.82676122232364
# RUN  6 , total integrated cost =  17.645020188459565
# RUN  7 , total integrated cost =  16.84161359109473
# RUN  8 , total integrated cost =  16.43966078553757
# RUN  9 , total integrated cost =  16.27938651217494
# RUN  10 , total integrated cost =  16.055911915481833
# RUN  11 , total integrated cost =  15.969175566483152
# RUN  12 , total integrated cost =  15.89140796897443
# RUN  13 , total integrated cost =  15.842379837399626
# RUN  14 , total integrated cost =  15.769634796846073
# RUN  15 , total integrated cost =  15.724104858719219
# RUN  16 , total integrated cost =  15.703816099828142
# RUN  17 , total integrated cost =  15.693448048435684
# RUN  18 , total integrated cost =  15.663561539876765
# RUN  19 , total integrated cost =  15.64796418667251
# RUN  20 , total integrated cost =  15.62886878068824
# RUN  30 , total integrated cost =  15.585497720310531
# RUN  40 , total integrated cost =  15.579741377091805
# RUN  50 , total integrated cost =  15.573940997762339
# RUN  60 , total integrated cost =  15.572722991334341
# RUN  70 , total integrated cost =  15.572592551497817
# RUN  80 , total integrated cost =  15.572286986171504
# RUN  90 , total integrated cost =  15.572044239287699
# RUN  100 , total integrated cost =  15.571776023386237
# RUN  110 , total integrated cost =  15.571216300152301
# RUN  120 , total integrated cost =  15.571122609168645
# RUN  130 , total integrated cost =  15.571087777777457
# RUN  140 , total integrated cost =  15.571066336461776
# RUN  150 , total integrated cost =  15.571054660208404
# RUN  160 , total integrated cost =  15.571038660138925
# RUN  170 , total integrated cost =  15.57097951412317
# RUN  180 , total integrated cost =  15.570839540988061
# RUN  190 , total integrated cost =  15.570696320499433
# RUN  200 , total integrated cost =  15.570617096297196
# RUN  300 , total integrated cost =  15.57020283084029
# RUN  400 , total integrated cost =  15.570160607046823
# RUN  500 , total integrated cost =  15.570147456335977
# RUN  600 , total integrated cost =  15.570104777660632
# RUN  700 , total integrated cost =  15.570055318359524
# RUN  800 , total integrated cost =  15.570019797816986
# RUN  900 , total integrated cost =  15.57001042323412
# ERROR:root:Not possible to set up initial conditions without sufficient simulation time before control
# RUN  1000 , total integrated cost =  15.569985849910594
# RUN  1000 , total integrated cost =  15.569985849910594
# Improved over  1000  iterations in  10.749242700000025  seconds by  99.81636887647151  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  8478.947114591461
# Gradient descend method:  PR
# RUN  1 , total integrated cost =  288.8120649888661
# RUN  2 , total integrated cost =  55.374060185575466
# RUN  3 , total integrated cost =  32.01996611009868
# RUN  4 , total integrated cost =  23.531126960622736
# RUN  5 , total integrated cost =  20.611248607345075
# RUN  6 , total integrated cost =  19.252786266482886
# RUN  7 , total integrated cost =  18.394352142820935
# RUN  8 , total integrated cost =  17.764234122108505
# RUN  9 , total integrated cost =  17.200049394901008
# RUN  10 , total integrated cost =  16.902341722285872
# RUN  11 , total integrated cost =  16.702781839506113
# RUN  12 , total integrated cost =  16.512624668667456
# RUN  13 , total integrated cost =  16.302869909015797
# RUN  14 , total integrated cost =  16.15869605532849
# RUN  15 , total integrated cost =  16.03083485304364
# RUN  16 , total integrated cost =  15.988968773267608
# RUN  17 , total integrated cost =  15.94467062694223
# RUN  18 , total integrated cost =  15.925569746042395
# RUN  19 , total integrated cost =  15.867269933782378
# RUN  20 , total integrated cost =  15.811205172251114
# ERROR:root:Not possible to set up initial conditions without sufficient simulation time before control
# RUN  30 , total integrated cost =  15.584389658282781
# Control only changes marginally.
# RUN  30 , total integrated cost =  15.584389658282781
# Improved over  30  iterations in  0.4154819000000316  seconds by  99.81619899914857  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  8478.947114591461
# Gradient descend method:  CD
# RUN  1 , total integrated cost =  288.8120649888661
# RUN  2 , total integrated cost =  56.78858376701476
# RUN  3 , total integrated cost =  32.1789925097266
# RUN  4 , total integrated cost =  22.371714158773674
# RUN  5 , total integrated cost =  18.955089623017656
# RUN  6 , total integrated cost =  18.092377293707706
# RUN  7 , total integrated cost =  17.19985772741505
# RUN  8 , total integrated cost =  16.747087905897473
# RUN  9 , total integrated cost =  16.44638347766599
# RUN  10 , total integrated cost =  16.26761651771994
# RUN  11 , total integrated cost =  16.13700927477628
# RUN  12 , total integrated cost =  15.970816230412138
# RUN  13 , total integrated cost =  15.908077083997895
# RUN  14 , total integrated cost =  15.825648129338497
# RUN  15 , total integrated cost =  15.775592369013797
# RUN  16 , total integrated cost =  15.729474914767685
# RUN  17 , total integrated cost =  15.711290579539632
# RUN  18 , total integrated cost =  15.684179529175001
# RUN  19 , total integrated cost =  15.65699297560215
# RUN  20 , total integrated cost =  15.631475708428194
# RUN  30 , total integrated cost =  15.576695662058942
# RUN  40 , total integrated cost =  15.576585497415195
# RUN  50 , total integrated cost =  15.57658005699632
# RUN  60 , total integrated cost =  15.576572602886147
# RUN  70 , total integrated cost =  15.571103136688954
# RUN  80 , total integrated cost =  15.57110078613556
# Control only changes marginally.
# ERROR:root:Not possible to set up initial conditions without sufficient simulation time before control
# RUN  89 , total integrated cost =  15.571100786124477
# Improved over  89  iterations in  1.0791035999999963  seconds by  99.81635572700615  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  8478.947114591461
# Gradient descend method:  LS
# RUN  1 , total integrated cost =  288.8120649888661
# RUN  2 , total integrated cost =  55.374060185575466
# RUN  3 , total integrated cost =  32.01503018253994
# RUN  4 , total integrated cost =  24.010318463973054
# RUN  5 , total integrated cost =  20.942689841598025
# RUN  6 , total integrated cost =  19.626961161591147
# RUN  7 , total integrated cost =  18.75058927906537
# RUN  8 , total integrated cost =  17.81761064805411
# RUN  9 , total integrated cost =  17.139735554293217
# RUN  10 , total integrated cost =  16.696391281665626
# RUN  11 , total integrated cost =  16.453792084134534
# RUN  12 , total integrated cost =  16.312662240928436
# RUN  13 , total integrated cost =  16.145145507040517
# RUN  14 , total integrated cost =  16.060978199622994
# RUN  15 , total integrated cost =  15.955064189182458
# RUN  16 , total integrated cost =  15.882300965322997
# RUN  17 , total integrated cost =  15.787976931718607
# RUN  18 , total integrated cost =  15.720443755413296
# RUN  19 , total integrated cost =  15.70442635221092
# RUN  20 , total integrated cost =  15.696931975580668
# RUN  30 , total integrated cost =  15.61239380294912
# RUN  40 , total integrated cost =  15.57690460662651
# ERROR:root:Not possible to set up initial conditions without sufficient simulation time before control
# Control only changes marginally.
# RUN  43 , total integrated cost =  15.57630580970335
# Improved over  43  iterations in  0.6669080000000349  seconds by  99.81629433938917  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  8478.947114591461
# Gradient descend method:  DY
# RUN  1 , total integrated cost =  288.8120649888661
# RUN  2 , total integrated cost =  56.79826399877174
# RUN  3 , total integrated cost =  32.182479977375735
# RUN  4 , total integrated cost =  22.412754889899965
# RUN  5 , total integrated cost =  19.482838765008708
# RUN  6 , total integrated cost =  18.165446901693887
# RUN  7 , total integrated cost =  17.114482875572413
# RUN  8 , total integrated cost =  16.585152579057624
# RUN  9 , total integrated cost =  16.319534316642745
# RUN  10 , total integrated cost =  16.196947650207427
# RUN  11 , total integrated cost =  16.016393857765706
# RUN  12 , total integrated cost =  15.928709173068647
# RUN  13 , total integrated cost =  15.831821723565223
# RUN  14 , total integrated cost =  15.809647445323282
# RUN  15 , total integrated cost =  15.747900977030337
# RUN  16 , total integrated cost =  15.712613377124839
# RUN  17 , total integrated cost =  15.678167774524074
# RUN  18 , total integrated cost =  15.669632116104246
# RUN  19 , total integrated cost =  15.63090840951518
# RUN  20 , total integrated cost =  15.618877766172789
# RUN  30 , total integrated cost =  15.601504339098469
# ERROR:root:Not possible to set up initial conditions without sufficient simulation time before control
# RUN  40 , total integrated cost =  15.573879408293227
# Control only changes marginally.
# RUN  46 , total integrated cost =  15.573879408131823
# Improved over  46  iterations in  0.8956697000000418  seconds by  99.81632295616834  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  8478.947114591461
# Gradient descend method:  WYL
# RUN  1 , total integrated cost =  288.8120649888661
# RUN  2 , total integrated cost =  56.665517708166306
# RUN  3 , total integrated cost =  32.26762888252246
# RUN  4 , total integrated cost =  22.667640488115026
# RUN  5 , total integrated cost =  19.88215741728585
# RUN  6 , total integrated cost =  18.581445073545005
# RUN  7 , total integrated cost =  17.807848431929663
# RUN  8 , total integrated cost =  17.182855061525053
# RUN  9 , total integrated cost =  16.809309194156356
# RUN  10 , total integrated cost =  16.49265301277137
# RUN  11 , total integrated cost =  16.3222044711049
# RUN  12 , total integrated cost =  16.13642328101521
# RUN  13 , total integrated cost =  16.085076234567396
# RUN  14 , total integrated cost =  16.00074581087052
# RUN  15 , total integrated cost =  15.960369910387705
# RUN  16 , total integrated cost =  15.879843816378237
# RUN  17 , total integrated cost =  15.793614227095205
# RUN  18 , total integrated cost =  15.74877036904601
# RUN  19 , total integrated cost =  15.69938989693954
# RUN  20 , total integrated cost =  15.675427723703088
# RUN  30 , total integrated cost =  15.61223944411996
# ERROR:root:Not possible to set up initial conditions without sufficient simulation time before control
# RUN  40 , total integrated cost =  15.590618208673224
# Control only changes marginally.
# RUN  47 , total integrated cost =  15.590618208526681
# Improved over  47  iterations in  0.6363741000000118  seconds by  99.81612554014288  percent.
# interpolate adjoint :  True True True
# RUN  0 , total integrated cost =  8478.947114591461
# Gradient descend method:  HZ
# RUN  1 , total integrated cost =  288.8120649888661
# RUN  2 , total integrated cost =  58.5991977744723
# RUN  3 , total integrated cost =  35.12013684746315
# RUN  4 , total integrated cost =  27.505256980822036
# RUN  5 , total integrated cost =  23.7921594452462
# RUN  6 , total integrated cost =  21.55030322849054
# RUN  7 , total integrated cost =  20.24154277414331
# RUN  8 , total integrated cost =  18.62292108022583
# RUN  9 , total integrated cost =  17.72698836871504
# RUN  10 , total integrated cost =  17.09875434951602
# RUN  11 , total integrated cost =  16.445766251968543
# RUN  12 , total integrated cost =  16.14553550870754
# RUN  13 , total integrated cost =  16.031393110094424
# RUN  14 , total integrated cost =  15.970132213738665
# RUN  15 , total integrated cost =  15.898542608430336
# RUN  16 , total integrated cost =  15.851501096877172
# RUN  17 , total integrated cost =  15.759864655763359
# RUN  18 , total integrated cost =  15.724196885520833
# RUN  19 , total integrated cost =  15.687158164092915
# RUN  20 , total integrated cost =  15.666542733028475
# RUN  30 , total integrated cost =  15.60014145772649
# RUN  40 , total integrated cost =  15.59269271607598
# Control only changes marginally.
# RUN  44 , total integrated cost =  15.585259031605016
# Improved over  44  iterations in  0.5529758000000129  seconds by  99.81618874583161  percent.

# %%
for cgv_ind in range(len(cgv_list)):
    plot_rate(aln, best_control_list_22a[cgv_ind], target_osc)

# %%
marker_ = '.'
markersize_ = 3
linestyle_ = ''

fig, ax = plt.subplots(2, figsize=(8,8))

for i in range(len(termination_it_22a)):
    ax[0].plot(runtime_list_22a[i][:termination_it_22a[i]], cost_list_22a[i][:termination_it_22a[i]], marker=marker_,
             markersize = markersize_, linestyle=linestyle_, label = str(cgv_list[i]))
    performance = []
    for j in range(termination_it_22a[i]):
        performance.append( 100. * ( cost_list_22a[i][0] - cost_list_22a[i][j]) / cost_list_22a[i][0] ) 
    ax[1].plot(runtime_list_22a[i][:termination_it_22a[i]], performance, marker=marker_,
            markersize = markersize_, linestyle=linestyle_,
            label = str(cgv_list[i]) + ', termination at {:.2f}'.format(performance[-1]) + '% after ' + str(termination_it_22a[i]) + ' iterations' )
ax[0].legend()
ax[0].set_xlabel('Runtime [s]')
ax[0].set_ylabel('Cost')
#ax[0].title.set_text('Cost per runtime')
ax[1].legend()
ax[1].set_xlabel('Runtime [s]')
ax[1].set_ylabel('Improvement [%]')
#ax[0].title.set_text('Cost per runtime')


plt.show()
